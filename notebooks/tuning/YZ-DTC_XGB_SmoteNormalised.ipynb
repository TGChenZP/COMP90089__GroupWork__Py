# %% [markdown]
# # Tuning Script

# %%
# Parameters subject to change in every script - involved in naming

MODEL = 'dtc'
PREPROCESSING = 'smote_normalise'
TUNER = 'yangzhoub'
OPTIMISED_METRIC = 'f1'

# %% [markdown]
# ---

# %%
# detect whether this is a google environment

COLAB_ENVIRONMENT = False

try:
    from google.colab import drive
    drive.mount('/content/drive')
    COLAB_ENVIRONMENT = True
except:
    pass
# Out:
# Mounted at /content/drive

# %%
import sys
import os
import pickle

if COLAB_ENVIRONMENT:
    home_directory = './drive/MyDrive/LAB/COMP90089__GroupWork__Py/' # my home directory is stored in ./LAB of google drive
    if MODEL == 'ebr':
        # !pip install interpret==0.5.0
    elif MODEL == 'cbr':
        # !pip install catboost
    elif MODEL in ['tf', 'mlp']:
        # !pip install PyTorch2Sklearn
    # !pip install JXAutoML
else:
    home_directory = '../../'

from JXAutoML.YangZhouB_10CV import YangZhouB_10CV as Tuner

import pandas as pd
# Out:
# Collecting JXAutoML
#   Downloading JXAutoML-0.4.4-py3-none-any.whl.metadata (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.2/67.2 kB 215.5 kB/s eta 0:00:00
# Downloading JXAutoML-0.4.4-py3-none-any.whl (52 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.1/52.1 kB 1.1 MB/s eta 0:00:00
# Installing collected packages: JXAutoML
# Successfully installed JXAutoML-0.4.4

# %%
# Parameters that are same for every script

FOLDS = 10  # we have decided to do 10 fold validation

SEED = 42

TASK_TYPE = 'Classification'  # this task is a classification task

# we have decided to tune features as hp
TUNE_FEATURES_AS_HYPERPARAMETERS = True

# %% [markdown]
# ---

# %%
# model to use to tune
from sklearn.tree import DecisionTreeClassifier as clf

# what values to try for each hyperparameter
parameter_choices = {
    'max_depth': (3, 6, 12, 24, 48, 96, 192),
    'max_features': (0.4, 0.55, 0.7, 0.85, 1),
    'ccp_alpha': (0.00000001, 0.000001, 0.0001, 0.01, 0.1),
    'splitter': ('best', 'random')
}

# what values to set non-tuneable parameters/hyperparameters
non_tunable_hyperparameters_dict = {
                                    'random_state': SEED,
                                    }

# %% [markdown]
# ---

# %% [markdown]
# Read in and Prepare Data

# %%
# Import data and store as lists

train_x_list = []
train_y_list = []
val_x_list = []
val_y_list = []

for i in range(FOLDS):
    train_data = pd.read_csv(
        f'{home_directory}data/curated/modelling/{PREPROCESSING}/train_{i}.csv')
    val_data = pd.read_csv(
        f'{home_directory}data/curated/modelling/{PREPROCESSING}/val_{i}.csv')

    # get the correct rows for X and y
    train_x = train_data.drop(
        ['mortality_status', 'subject_id', 'hadm_id', 'stay_id'], axis=1)
    train_y = train_data['mortality_status']
    val_x = val_data.drop(
        ['mortality_status', 'subject_id', 'hadm_id', 'stay_id'], axis=1)
    val_y = val_data['mortality_status']

    train_x_list.append(train_x)
    train_y_list.append(train_y)
    val_x_list.append(val_x)
    val_y_list.append(val_y)

# %%
# Import feature importance ordering

with open(f'{home_directory}models/xgb_feature_importance_ordering_{PREPROCESSING}.pickle', 'rb') as f:
    feature_importance_ordering = pickle.load(f)

# %% [markdown]
# Set parameters

# %%
# initialisation
tuner = Tuner()

print('---')

# define what model we are tuning
tuner.read_in_model(clf, TASK_TYPE, optimised_metric=OPTIMISED_METRIC)

print('---')

# read in the data for training and validation
tuner.read_in_data(train_x_list, train_y_list, val_x_list, val_y_list)

print('---')

# set what hp values to tune
tuner.set_hyperparameters(parameter_choices)
# WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

# set up hp values that need to be changed from default but NOT to be tuned
tuner.set_non_tuneable_hyperparameters(non_tunable_hyperparameters_dict)

print('---')

# set up feature importance ordering

if TUNE_FEATURES_AS_HYPERPARAMETERS:
    tuner.set_features(feature_importance_ordering)
    # WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

try:  # try to read in previous results to continue tuning ...
    tuner.read_in_tuning_result_df(
        f'{home_directory}models/tuning/{TUNER}_{MODEL}_{PREPROCESSING}.csv')
except:
    print('No previous tuning data read in')

print('---')

# set up where to save the tuning result csv
tuner.set_tuning_result_saving_address(
    f'{home_directory}models/tuning/{TUNER}_{MODEL}_{PREPROCESSING}.csv')

print('---')

# set up where to save the current best model
tuner.set_best_model_saving_address(
    f'{home_directory}models/tmp_models/{TUNER}_{MODEL}_{PREPROCESSING}')
# Out:
# YangZhouB Initialised
# ---
# Successfully read in model <class 'sklearn.tree._classes.DecisionTreeClassifier'>, which is a Classification model optimising for f1
# ---
# Read in Train X data list
# Read in Train y data list
# Read in Val X data list
# Read in Val y data list
# ---
# Successfully recorded hyperparameter choices
# ---
# Successfully recorded non_tuneable_hyperparameter choices
# ---
# Successfully recorded tuneable feature combination choices and updated relevant internal structures
# ---
# No previous tuning data read in
# ---
# Successfully set tuning output address
# ---
# Successfully set best model output address

# %%
# ignore warnings

import warnings
warnings.filterwarnings("ignore")

# %%
# begin tuning ... (or continue training)

tuner.tune()
# Out:
# Streaming output truncated to the last 5000 lines.
# Already Trained and Tested combination (val score of 0.38):
#             {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 25}
#             Current best combo (with val score 0.4774):
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 63}
#         Has trained 1072 of 25200 combinations so far
# Trained and Tested combination 1073 of 25200, taking 0.01 seconds to get val score of 0.38:
#                 {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 0.0001, 'splitter': 'best', 'features': 25},
#             Current best combo with val score 0.4774:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 63}
# Trained and Tested combination 1074 of 25200, taking 0.01 seconds to get val score of 0.2908:
#                 {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-06, 'splitter': 'random', 'features': 25},
#             Current best combo with val score 0.4774:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 63}
# Trained and Tested combination 1075 of 25200, taking 0.01 seconds to get val score of 0.1628:
#                 {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-06, 'splitter': 'best', 'features': 24},
#             Current best combo with val score 0.4774:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 63}
# Trained and Tested combination 1076 of 25200, taking 0.01 seconds to get val score of 0.3116:
#                 {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-06, 'splitter': 'best', 'features': 26},
#             Current best combo with val score 0.4774:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 63}
# % Combos Checked Thus Far: 1076 out of 25200 which is 4.2698409999999996%
# Cruising Coordrdinate 144 of 384
#
# Cruising Coordrdinate 145 of 384
#
# Cruising Coordrdinate 146 of 384
#
# Cruising Coordrdinate 147 of 384
#
# Cruising Coordrdinate 148 of 384
#
# Cruising Coordrdinate 149 of 384
#
# Cruising Coordrdinate 150 of 384
#
# Cruise suspended due to suspicious case
# Guidance: round 47
#
# 	round 47 iteration:  0
#
# Trained and Tested combination 1077 of 25200, taking 0.01 seconds to get val score of 0.3265:
#                 {'max_depth': 96, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 30},
#             Current best combo with val score 0.4774:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 63}
# Trained and Tested combination 1078 of 25200, taking 0.02 seconds to get val score of 0.3762:
#                 {'max_depth': 192, 'max_features': 0.85, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 30},
#             Current best combo with val score 0.4774:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 63}
# Trained and Tested combination 1079 of 25200, taking 0.01 seconds to get val score of 0.3265:
#                 {'max_depth': 192, 'max_features': 1, 'ccp_alpha': 1e-06, 'splitter': 'random', 'features': 30},
#             Current best combo with val score 0.4774:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 63}
# Already Trained and Tested combination (val score of 0.3097):
#             {'max_depth': 192, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 30}
#             Current best combo (with val score 0.4774):
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 63}
#         Has trained 1079 of 25200 combinations so far
# Trained and Tested combination 1080 of 25200, taking 0.01 seconds to get val score of 0.3533:
#                 {'max_depth': 192, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 29},
#             Current best combo with val score 0.4774:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 63}
# Trained and Tested combination 1081 of 25200, taking 0.01 seconds to get val score of 0.3131:
#                 {'max_depth': 192, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 31},
#             Current best combo with val score 0.4774:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 63}
# 	round 47 iteration:  1
#
# Trained and Tested combination 1082 of 25200, taking 0.01 seconds to get val score of 0.3199:
#                 {'max_depth': 48, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 30},
#             Current best combo with val score 0.4774:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 63}
# Already Trained and Tested combination (val score of 0.3265):
#             {'max_depth': 192, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 30}
#             Current best combo (with val score 0.4774):
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 63}
#         Has trained 1082 of 25200 combinations so far
# Trained and Tested combination 1083 of 25200, taking 0.03 seconds to get val score of 0.3762:
#                 {'max_depth': 96, 'max_features': 0.85, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 30},
#             Current best combo with val score 0.4774:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 63}
# Trained and Tested combination 1084 of 25200, taking 0.01 seconds to get val score of 0.3265:
#                 {'max_depth': 96, 'max_features': 1, 'ccp_alpha': 1e-06, 'splitter': 'random', 'features': 30},
#             Current best combo with val score 0.4774:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 63}
# Trained and Tested combination 1085 of 25200, taking 0.01 seconds to get val score of 0.3097:
#                 {'max_depth': 96, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 30},
#             Current best combo with val score 0.4774:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 63}
# Trained and Tested combination 1086 of 25200, taking 0.01 seconds to get val score of 0.3533:
#                 {'max_depth': 96, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 29},
#             Current best combo with val score 0.4774:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 63}
# Trained and Tested combination 1087 of 25200, taking 0.01 seconds to get val score of 0.3131:
#                 {'max_depth': 96, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 31},
#             Current best combo with val score 0.4774:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 63}
# Already Trained and Tested combination (val score of 0.3762):
#             {'max_depth': 96, 'max_features': 0.85, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 30}
#             Current best combo (with val score 0.4774):
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 63}
#         Has trained 1087 of 25200 combinations so far
# Trained and Tested combination 1088 of 25200, taking 0.02 seconds to get val score of 0.3648:
#                 {'max_depth': 192, 'max_features': 0.7, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 30},
#             Current best combo with val score 0.4774:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 63}
# Already Trained and Tested combination (val score of 0.3265):
#             {'max_depth': 192, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 30}
#             Current best combo (with val score 0.4774):
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 63}
#         Has trained 1088 of 25200 combinations so far
# Trained and Tested combination 1089 of 25200, taking 0.02 seconds to get val score of 0.3762:
#                 {'max_depth': 192, 'max_features': 0.85, 'ccp_alpha': 1e-06, 'splitter': 'random', 'features': 30},
#             Current best combo with val score 0.4774:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 63}
# Trained and Tested combination 1090 of 25200, taking 0.06 seconds to get val score of 0.266:
#                 {'max_depth': 192, 'max_features': 0.85, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 30},
#             Current best combo with val score 0.4774:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 63}
# Trained and Tested combination 1091 of 25200, taking 0.02 seconds to get val score of 0.3431:
#                 {'max_depth': 192, 'max_features': 0.85, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 29},
#             Current best combo with val score 0.4774:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 63}
# Trained and Tested combination 1092 of 25200, taking 0.02 seconds to get val score of 0.347:
#                 {'max_depth': 192, 'max_features': 0.85, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 31},
#             Current best combo with val score 0.4774:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 63}
# Already Trained and Tested combination (val score of 0.3265):
#             {'max_depth': 96, 'max_features': 1, 'ccp_alpha': 1e-06, 'splitter': 'random', 'features': 30}
#             Current best combo (with val score 0.4774):
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 63}
#         Has trained 1092 of 25200 combinations so far
# Already Trained and Tested combination (val score of 0.3762):
#             {'max_depth': 192, 'max_features': 0.85, 'ccp_alpha': 1e-06, 'splitter': 'random', 'features': 30}
#             Current best combo (with val score 0.4774):
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 63}
#         Has trained 1092 of 25200 combinations so far
# Already Trained and Tested combination (val score of 0.3265):
#             {'max_depth': 192, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 30}
#             Current best combo (with val score 0.4774):
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 63}
#         Has trained 1092 of 25200 combinations so far
# Trained and Tested combination 1093 of 25200, taking 0.01 seconds to get val score of 0.3272:
#                 {'max_depth': 192, 'max_features': 1, 'ccp_alpha': 0.0001, 'splitter': 'random', 'features': 30},
#             Current best combo with val score 0.4774:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 63}
# Trained and Tested combination 1094 of 25200, taking 0.01 seconds to get val score of 0.3097:
#                 {'max_depth': 192, 'max_features': 1, 'ccp_alpha': 1e-06, 'splitter': 'best', 'features': 30},
#             Current best combo with val score 0.4774:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 63}
# Trained and Tested combination 1095 of 25200, taking 0.01 seconds to get val score of 0.3533:
#                 {'max_depth': 192, 'max_features': 1, 'ccp_alpha': 1e-06, 'splitter': 'random', 'features': 29},
#             Current best combo with val score 0.4774:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 63}
# Trained and Tested combination 1096 of 25200, taking 0.01 seconds to get val score of 0.3131:
#                 {'max_depth': 192, 'max_features': 1, 'ccp_alpha': 1e-06, 'splitter': 'random', 'features': 31},
#             Current best combo with val score 0.4774:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 63}
# Already Trained and Tested combination (val score of 0.3533):
#             {'max_depth': 96, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 29}
#             Current best combo (with val score 0.4774):
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 63}
#         Has trained 1096 of 25200 combinations so far
# Already Trained and Tested combination (val score of 0.3431):
#             {'max_depth': 192, 'max_features': 0.85, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 29}
#             Current best combo (with val score 0.4774):
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 63}
#         Has trained 1096 of 25200 combinations so far
# Already Trained and Tested combination (val score of 0.3533):
#             {'max_depth': 192, 'max_features': 1, 'ccp_alpha': 1e-06, 'splitter': 'random', 'features': 29}
#             Current best combo (with val score 0.4774):
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 63}
#         Has trained 1096 of 25200 combinations so far
# Trained and Tested combination 1097 of 25200, taking 0.01 seconds to get val score of 0.3077:
#                 {'max_depth': 192, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 29},
#             Current best combo with val score 0.4774:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 63}
# Trained and Tested combination 1098 of 25200, taking 0.01 seconds to get val score of 0.3339:
#                 {'max_depth': 192, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 28},
#             Current best combo with val score 0.4774:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 63}
# Already Trained and Tested combination (val score of 0.3265):
#             {'max_depth': 192, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 30}
#             Current best combo (with val score 0.4774):
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 63}
#         Has trained 1098 of 25200 combinations so far
# % Combos Checked Thus Far: 1098 out of 25200 which is 4.357143%
# Cruising Coordrdinate 151 of 384
#
# Cruising Coordrdinate 152 of 384
#
# Cruising Coordrdinate 153 of 384
#
# Cruise suspended due to suspicious case
# Guidance: round 48
#
# 	round 48 iteration:  0
#
# Trained and Tested combination 1099 of 25200, taking 0.03 seconds to get val score of 0.3642:
#                 {'max_depth': 96, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 30},
#             Current best combo with val score 0.4774:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 63}
# Trained and Tested combination 1100 of 25200, taking 0.06 seconds to get val score of 0.3094:
#                 {'max_depth': 192, 'max_features': 0.55, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 30},
#             Current best combo with val score 0.4774:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 63}
# Trained and Tested combination 1101 of 25200, taking 0.04 seconds to get val score of 0.3642:
#                 {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 1e-06, 'splitter': 'best', 'features': 30},
#             Current best combo with val score 0.4774:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 63}
# Already Trained and Tested combination (val score of 0.3767):
#             {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 30}
#             Current best combo (with val score 0.4774):
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 63}
#         Has trained 1101 of 25200 combinations so far
# Trained and Tested combination 1102 of 25200, taking 0.04 seconds to get val score of 0.3535:
#                 {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 29},
#             Current best combo with val score 0.4774:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 63}
# Trained and Tested combination 1103 of 25200, taking 0.03 seconds to get val score of 0.2598:
#                 {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 31},
#             Current best combo with val score 0.4774:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 63}
# 	round 48 iteration:  1
#
# Trained and Tested combination 1104 of 25200, taking 0.03 seconds to get val score of 0.3642:
#                 {'max_depth': 48, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 30},
#             Current best combo with val score 0.4774:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 63}
# Already Trained and Tested combination (val score of 0.3642):
#             {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 30}
#             Current best combo (with val score 0.4774):
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 63}
#         Has trained 1104 of 25200 combinations so far
# Trained and Tested combination 1105 of 25200, taking 0.04 seconds to get val score of 0.3094:
#                 {'max_depth': 96, 'max_features': 0.55, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 30},
#             Current best combo with val score 0.4774:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 63}
# Trained and Tested combination 1106 of 25200, taking 0.03 seconds to get val score of 0.3642:
#                 {'max_depth': 96, 'max_features': 0.4, 'ccp_alpha': 1e-06, 'splitter': 'best', 'features': 30},
#             Current best combo with val score 0.4774:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 63}
# Trained and Tested combination 1107 of 25200, taking 0.01 seconds to get val score of 0.3767:
#                 {'max_depth': 96, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 30},
#             Current best combo with val score 0.4774:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 63}
# Trained and Tested combination 1108 of 25200, taking 0.03 seconds to get val score of 0.3535:
#                 {'max_depth': 96, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 29},
#             Current best combo with val score 0.4774:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 63}
# Trained and Tested combination 1109 of 25200, taking 0.03 seconds to get val score of 0.2598:
#                 {'max_depth': 96, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 31},
#             Current best combo with val score 0.4774:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 63}
# Already Trained and Tested combination (val score of 0.3642):
#             {'max_depth': 96, 'max_features': 0.4, 'ccp_alpha': 1e-06, 'splitter': 'best', 'features': 30}
#             Current best combo (with val score 0.4774):
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 63}
#         Has trained 1109 of 25200 combinations so far
# Trained and Tested combination 1110 of 25200, taking 0.04 seconds to get val score of 0.3094:
#                 {'max_depth': 192, 'max_features': 0.55, 'ccp_alpha': 1e-06, 'splitter': 'best', 'features': 30},
#             Current best combo with val score 0.4774:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 63}
# Already Trained and Tested combination (val score of 0.3642):
#             {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 30}
#             Current best combo (with val score 0.4774):
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 63}
#         Has trained 1110 of 25200 combinations so far
# Trained and Tested combination 1111 of 25200, taking 0.03 seconds to get val score of 0.3642:
#                 {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 0.0001, 'splitter': 'best', 'features': 30},
#             Current best combo with val score 0.4774:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 63}
# Trained and Tested combination 1112 of 25200, taking 0.02 seconds to get val score of 0.3767:
#                 {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 1e-06, 'splitter': 'random', 'features': 30},
#             Current best combo with val score 0.4774:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 63}
# Trained and Tested combination 1113 of 25200, taking 0.03 seconds to get val score of 0.3535:
#                 {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 1e-06, 'splitter': 'best', 'features': 29},
#             Current best combo with val score 0.4774:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 63}
# Trained and Tested combination 1114 of 25200, taking 0.04 seconds to get val score of 0.2598:
#                 {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 1e-06, 'splitter': 'best', 'features': 31},
#             Current best combo with val score 0.4774:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 63}
# Already Trained and Tested combination (val score of 0.3767):
#             {'max_depth': 96, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 30}
#             Current best combo (with val score 0.4774):
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 63}
#         Has trained 1114 of 25200 combinations so far
# Trained and Tested combination 1115 of 25200, taking 0.03 seconds to get val score of 0.3119:
#                 {'max_depth': 192, 'max_features': 0.55, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 30},
#             Current best combo with val score 0.4774:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 63}
# Already Trained and Tested combination (val score of 0.3767):
#             {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 1e-06, 'splitter': 'random', 'features': 30}
#             Current best combo (with val score 0.4774):
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 63}
#         Has trained 1115 of 25200 combinations so far
# Already Trained and Tested combination (val score of 0.3642):
#             {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 30}
#             Current best combo (with val score 0.4774):
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 63}
#         Has trained 1115 of 25200 combinations so far
# Trained and Tested combination 1116 of 25200, taking 0.02 seconds to get val score of 0.3736:
#                 {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 29},
#             Current best combo with val score 0.4774:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 63}
# Trained and Tested combination 1117 of 25200, taking 0.03 seconds to get val score of 0.3625:
#                 {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 31},
#             Current best combo with val score 0.4774:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 63}
# % Combos Checked Thus Far: 1117 out of 25200 which is 4.43254%
# Cruising Coordrdinate 154 of 384
#
# Cruise suspended due to suspicious case
# Guidance: round 49
#
# 	round 49 iteration:  0
#
# % Combos Checked Thus Far: 1117 out of 25200 which is 4.43254%
# Cruising Coordrdinate 155 of 384
#
# Cruising Coordrdinate 156 of 384
#
# Cruising Coordrdinate 157 of 384
#
# Cruising Coordrdinate 158 of 384
#
# Cruise suspended due to suspicious case
# Guidance: round 50
#
# 	round 50 iteration:  0
#
# Trained and Tested combination 1118 of 25200, taking 0.0 seconds to get val score of 0.3424:
#                 {'max_depth': 12, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 30},
#             Current best combo with val score 0.4774:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 63}
# Trained and Tested combination 1119 of 25200, taking 0.01 seconds to get val score of 0.3097:
#                 {'max_depth': 48, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 30},
#             Current best combo with val score 0.4774:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 63}
# Trained and Tested combination 1120 of 25200, taking 0.06 seconds to get val score of 0.266:
#                 {'max_depth': 24, 'max_features': 0.85, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 30},
#             Current best combo with val score 0.4774:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 63}
# Trained and Tested combination 1121 of 25200, taking 0.01 seconds to get val score of 0.3328:
#                 {'max_depth': 24, 'max_features': 1, 'ccp_alpha': 1e-06, 'splitter': 'best', 'features': 30},
#             Current best combo with val score 0.4774:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 63}
# Already Trained and Tested combination (val score of 0.3637):
#             {'max_depth': 24, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 30}
#             Current best combo (with val score 0.4774):
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 63}
#         Has trained 1121 of 25200 combinations so far
# Trained and Tested combination 1122 of 25200, taking 0.01 seconds to get val score of 0.3431:
#                 {'max_depth': 24, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 29},
#             Current best combo with val score 0.4774:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 63}
# Trained and Tested combination 1123 of 25200, taking 0.01 seconds to get val score of 0.2453:
#                 {'max_depth': 24, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 31},
#             Current best combo with val score 0.4774:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 63}
# 	round 50 iteration:  1
#
# Trained and Tested combination 1124 of 25200, taking 0.0 seconds to get val score of 0.3103:
#                 {'max_depth': 6, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 30},
#             Current best combo with val score 0.4774:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 63}
# Already Trained and Tested combination (val score of 0.3328):
#             {'max_depth': 24, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 30}
#             Current best combo (with val score 0.4774):
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 63}
#         Has trained 1124 of 25200 combinations so far
# Trained and Tested combination 1125 of 25200, taking 0.05 seconds to get val score of 0.2824:
#                 {'max_depth': 12, 'max_features': 0.85, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 30},
#             Current best combo with val score 0.4774:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 63}
# Trained and Tested combination 1126 of 25200, taking 0.0 seconds to get val score of 0.3424:
#                 {'max_depth': 12, 'max_features': 1, 'ccp_alpha': 1e-06, 'splitter': 'best', 'features': 30},
#             Current best combo with val score 0.4774:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 63}
# Trained and Tested combination 1127 of 25200, taking 0.0 seconds to get val score of 0.3404:
#                 {'max_depth': 12, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 30},
#             Current best combo with val score 0.4774:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 63}
# Trained and Tested combination 1128 of 25200, taking 0.01 seconds to get val score of 0.306:
#                 {'max_depth': 12, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 29},
#             Current best combo with val score 0.4774:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 63}
# Trained and Tested combination 1129 of 25200, taking 0.01 seconds to get val score of 0.2258:
#                 {'max_depth': 12, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 31},
#             Current best combo with val score 0.4774:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 63}
# Already Trained and Tested combination (val score of 0.3424):
#             {'max_depth': 12, 'max_features': 1, 'ccp_alpha': 1e-06, 'splitter': 'best', 'features': 30}
#             Current best combo (with val score 0.4774):
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 63}
#         Has trained 1129 of 25200 combinations so far
# Trained and Tested combination 1130 of 25200, taking 0.01 seconds to get val score of 0.3097:
#                 {'max_depth': 48, 'max_features': 1, 'ccp_alpha': 1e-06, 'splitter': 'best', 'features': 30},
#             Current best combo with val score 0.4774:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 63}
# Trained and Tested combination 1131 of 25200, taking 0.08 seconds to get val score of 0.266:
#                 {'max_depth': 24, 'max_features': 0.85, 'ccp_alpha': 1e-06, 'splitter': 'best', 'features': 30},
#             Current best combo with val score 0.4774:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 63}
# Already Trained and Tested combination (val score of 0.3328):
#             {'max_depth': 24, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 30}
#             Current best combo (with val score 0.4774):
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 63}
#         Has trained 1131 of 25200 combinations so far
# Trained and Tested combination 1132 of 25200, taking 0.02 seconds to get val score of 0.3299:
#                 {'max_depth': 24, 'max_features': 1, 'ccp_alpha': 0.0001, 'splitter': 'best', 'features': 30},
#             Current best combo with val score 0.4774:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 63}
# Trained and Tested combination 1133 of 25200, taking 0.01 seconds to get val score of 0.3637:
#                 {'max_depth': 24, 'max_features': 1, 'ccp_alpha': 1e-06, 'splitter': 'random', 'features': 30},
#             Current best combo with val score 0.4774:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 63}
# Trained and Tested combination 1134 of 25200, taking 0.01 seconds to get val score of 0.3431:
#                 {'max_depth': 24, 'max_features': 1, 'ccp_alpha': 1e-06, 'splitter': 'best', 'features': 29},
#             Current best combo with val score 0.4774:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 63}
# Trained and Tested combination 1135 of 25200, taking 0.01 seconds to get val score of 0.2453:
#                 {'max_depth': 24, 'max_features': 1, 'ccp_alpha': 1e-06, 'splitter': 'best', 'features': 31},
#             Current best combo with val score 0.4774:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 63}
# Already Trained and Tested combination (val score of 0.3404):
#             {'max_depth': 12, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 30}
#             Current best combo (with val score 0.4774):
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 63}
#         Has trained 1135 of 25200 combinations so far
# Already Trained and Tested combination (val score of 0.3199):
#             {'max_depth': 48, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 30}
#             Current best combo (with val score 0.4774):
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 63}
#         Has trained 1135 of 25200 combinations so far
# Trained and Tested combination 1136 of 25200, taking 0.02 seconds to get val score of 0.38:
#                 {'max_depth': 24, 'max_features': 0.85, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 30},
#             Current best combo with val score 0.4774:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 63}
# Already Trained and Tested combination (val score of 0.3637):
#             {'max_depth': 24, 'max_features': 1, 'ccp_alpha': 1e-06, 'splitter': 'random', 'features': 30}
#             Current best combo (with val score 0.4774):
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 63}
#         Has trained 1136 of 25200 combinations so far
# Already Trained and Tested combination (val score of 0.3328):
#             {'max_depth': 24, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 30}
#             Current best combo (with val score 0.4774):
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 63}
#         Has trained 1136 of 25200 combinations so far
# Trained and Tested combination 1137 of 25200, taking 0.01 seconds to get val score of 0.3587:
#                 {'max_depth': 24, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 29},
#             Current best combo with val score 0.4774:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 63}
# Trained and Tested combination 1138 of 25200, taking 0.01 seconds to get val score of 0.3062:
#                 {'max_depth': 24, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 31},
#             Current best combo with val score 0.4774:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 63}
# Already Trained and Tested combination (val score of 0.306):
#             {'max_depth': 12, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 29}
#             Current best combo (with val score 0.4774):
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 63}
#         Has trained 1138 of 25200 combinations so far
# Trained and Tested combination 1139 of 25200, taking 0.01 seconds to get val score of 0.3077:
#                 {'max_depth': 48, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 29},
#             Current best combo with val score 0.4774:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 63}
# Trained and Tested combination 1140 of 25200, taking 0.05 seconds to get val score of 0.3445:
#                 {'max_depth': 24, 'max_features': 0.85, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 29},
#             Current best combo with val score 0.4774:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 63}
# Already Trained and Tested combination (val score of 0.3431):
#             {'max_depth': 24, 'max_features': 1, 'ccp_alpha': 1e-06, 'splitter': 'best', 'features': 29}
#             Current best combo (with val score 0.4774):
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 63}
#         Has trained 1140 of 25200 combinations so far
# Already Trained and Tested combination (val score of 0.3587):
#             {'max_depth': 24, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 29}
#             Current best combo (with val score 0.4774):
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 63}
#         Has trained 1140 of 25200 combinations so far
# Trained and Tested combination 1141 of 25200, taking 0.01 seconds to get val score of 0.2911:
#                 {'max_depth': 24, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 28},
#             Current best combo with val score 0.4774:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 63}
# Already Trained and Tested combination (val score of 0.3328):
#             {'max_depth': 24, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 30}
#             Current best combo (with val score 0.4774):
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 63}
#         Has trained 1141 of 25200 combinations so far
# % Combos Checked Thus Far: 1141 out of 25200 which is 4.527778%
# Cruising Coordrdinate 159 of 384
#
# Cruising Coordrdinate 160 of 384
#
# Cruise suspended due to suspicious case
# Guidance: round 51
#
# 	round 51 iteration:  0
#
# % Combos Checked Thus Far: 1141 out of 25200 which is 4.527778%
# Cruising Coordrdinate 161 of 384
#
# Cruising Coordrdinate 162 of 384
#
# Cruise suspended due to suspicious case
# Guidance: round 52
#
# 	round 52 iteration:  0
#
# Already Trained and Tested combination (val score of 0.3103):
#             {'max_depth': 6, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 30}
#             Current best combo (with val score 0.4774):
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 63}
#         Has trained 1141 of 25200 combinations so far
# Trained and Tested combination 1142 of 25200, taking 0.02 seconds to get val score of 0.328:
#                 {'max_depth': 3, 'max_features': 0.85, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 30},
#             Current best combo with val score 0.4774:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 63}
# Trained and Tested combination 1143 of 25200, taking 0.0 seconds to get val score of 0.3185:
#                 {'max_depth': 3, 'max_features': 1, 'ccp_alpha': 1e-06, 'splitter': 'best', 'features': 30},
#             Current best combo with val score 0.4774:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 63}
# Already Trained and Tested combination (val score of 0.2533):
#             {'max_depth': 3, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 30}
#             Current best combo (with val score 0.4774):
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 63}
#         Has trained 1143 of 25200 combinations so far
# Trained and Tested combination 1144 of 25200, taking 0.0 seconds to get val score of 0.3267:
#                 {'max_depth': 3, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 29},
#             Current best combo with val score 0.4774:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 63}
# Trained and Tested combination 1145 of 25200, taking 0.0 seconds to get val score of 0.0:
#                 {'max_depth': 3, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 31},
#             Current best combo with val score 0.4774:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 63}
# 	round 52 iteration:  1
#
# Trained and Tested combination 1146 of 25200, taking 0.03 seconds to get val score of 0.319:
#                 {'max_depth': 6, 'max_features': 0.85, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 30},
#             Current best combo with val score 0.4774:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 63}
# Trained and Tested combination 1147 of 25200, taking 0.02 seconds to get val score of 0.2816:
#                 {'max_depth': 3, 'max_features': 0.7, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 30},
#             Current best combo with val score 0.4774:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 63}
# Already Trained and Tested combination (val score of 0.3185):
#             {'max_depth': 3, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 30}
#             Current best combo (with val score 0.4774):
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 63}
#         Has trained 1147 of 25200 combinations so far
# Trained and Tested combination 1148 of 25200, taking 0.02 seconds to get val score of 0.328:
#                 {'max_depth': 3, 'max_features': 0.85, 'ccp_alpha': 1e-06, 'splitter': 'best', 'features': 30},
#             Current best combo with val score 0.4774:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 63}
# Trained and Tested combination 1149 of 25200, taking 0.01 seconds to get val score of 0.3496:
#                 {'max_depth': 3, 'max_features': 0.85, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 30},
#             Current best combo with val score 0.4774:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 63}
# Trained and Tested combination 1150 of 25200, taking 0.03 seconds to get val score of 0.314:
#                 {'max_depth': 3, 'max_features': 0.85, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 29},
#             Current best combo with val score 0.4774:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 63}
# Trained and Tested combination 1151 of 25200, taking 0.02 seconds to get val score of 0.3454:
#                 {'max_depth': 3, 'max_features': 0.85, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 31},
#             Current best combo with val score 0.4774:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 63}
# Trained and Tested combination 1152 of 25200, taking 0.0 seconds to get val score of 0.3103:
#                 {'max_depth': 6, 'max_features': 1, 'ccp_alpha': 1e-06, 'splitter': 'best', 'features': 30},
#             Current best combo with val score 0.4774:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 63}
# Already Trained and Tested combination (val score of 0.328):
#             {'max_depth': 3, 'max_features': 0.85, 'ccp_alpha': 1e-06, 'splitter': 'best', 'features': 30}
#             Current best combo (with val score 0.4774):
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 63}
#         Has trained 1152 of 25200 combinations so far
# Already Trained and Tested combination (val score of 0.3185):
#             {'max_depth': 3, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 30}
#             Current best combo (with val score 0.4774):
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 63}
#         Has trained 1152 of 25200 combinations so far
# Trained and Tested combination 1153 of 25200, taking 0.0 seconds to get val score of 0.3185:
#                 {'max_depth': 3, 'max_features': 1, 'ccp_alpha': 0.0001, 'splitter': 'best', 'features': 30},
#             Current best combo with val score 0.4774:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 63}
# Trained and Tested combination 1154 of 25200, taking 0.0 seconds to get val score of 0.2533:
#                 {'max_depth': 3, 'max_features': 1, 'ccp_alpha': 1e-06, 'splitter': 'random', 'features': 30},
#             Current best combo with val score 0.4774:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 63}
# Trained and Tested combination 1155 of 25200, taking 0.0 seconds to get val score of 0.3267:
#                 {'max_depth': 3, 'max_features': 1, 'ccp_alpha': 1e-06, 'splitter': 'best', 'features': 29},
#             Current best combo with val score 0.4774:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 63}
# Trained and Tested combination 1156 of 25200, taking 0.0 seconds to get val score of 0.0:
#                 {'max_depth': 3, 'max_features': 1, 'ccp_alpha': 1e-06, 'splitter': 'best', 'features': 31},
#             Current best combo with val score 0.4774:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 63}
# Trained and Tested combination 1157 of 25200, taking 0.01 seconds to get val score of 0.2891:
# ...
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 63}
# Trained and Tested combination 1717 of 25200, taking 0.02 seconds to get val score of 0.4103:
#                 {'max_depth': 12, 'max_features': 0.4, 'ccp_alpha': 1e-06, 'splitter': 'random', 'features': 63},
#             Current best combo with val score 0.4774:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 63}
# Trained and Tested combination 1718 of 25200, taking 0.07 seconds to get val score of 0.2997:
#                 {'max_depth': 12, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 63},
#             Current best combo with val score 0.4774:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 63}
# Trained and Tested combination 1719 of 25200, taking 0.02 seconds to get val score of 0.3198:
#                 {'max_depth': 12, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 62},
#             Current best combo with val score 0.4774:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 63}
# Trained and Tested combination 1720 of 25200, taking 0.02 seconds to get val score of 0.3683:
#                 {'max_depth': 12, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 64},
#             Current best combo with val score 0.4774:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 63}
# Already Trained and Tested combination (val score of 0.4103):
#             {'max_depth': 12, 'max_features': 0.4, 'ccp_alpha': 1e-06, 'splitter': 'random', 'features': 63}
#             Current best combo (with val score 0.4774):
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 63}
#         Has trained 1720 of 25200 combinations so far
# Trained and Tested combination 1721 of 25200, taking 0.02 seconds to get val score of 0.3496:
#                 {'max_depth': 48, 'max_features': 0.4, 'ccp_alpha': 1e-06, 'splitter': 'random', 'features': 63},
#             Current best combo with val score 0.4774:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 63}
# Trained and Tested combination 1722 of 25200, taking 0.02 seconds to get val score of 0.3042:
#                 {'max_depth': 24, 'max_features': 0.55, 'ccp_alpha': 1e-06, 'splitter': 'random', 'features': 63},
#             Current best combo with val score 0.4774:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 63}
# Already Trained and Tested combination (val score of 0.3584):
#             {'max_depth': 24, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 63}
#             Current best combo (with val score 0.4774):
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 63}
#         Has trained 1722 of 25200 combinations so far
# Trained and Tested combination 1723 of 25200, taking 0.02 seconds to get val score of 0.3584:
#                 {'max_depth': 24, 'max_features': 0.4, 'ccp_alpha': 0.0001, 'splitter': 'random', 'features': 63},
#             Current best combo with val score 0.4774:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 63}
# Trained and Tested combination 1724 of 25200, taking 0.1 seconds to get val score of 0.2529:
#                 {'max_depth': 24, 'max_features': 0.4, 'ccp_alpha': 1e-06, 'splitter': 'best', 'features': 63},
#             Current best combo with val score 0.4774:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 63}
# Trained and Tested combination 1725 of 25200, taking 0.03 seconds to get val score of 0.3545:
#                 {'max_depth': 24, 'max_features': 0.4, 'ccp_alpha': 1e-06, 'splitter': 'random', 'features': 62},
#             Current best combo with val score 0.4774:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 63}
# Trained and Tested combination 1726 of 25200, taking 0.03 seconds to get val score of 0.3321:
#                 {'max_depth': 24, 'max_features': 0.4, 'ccp_alpha': 1e-06, 'splitter': 'random', 'features': 64},
#             Current best combo with val score 0.4774:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 63}
# Already Trained and Tested combination (val score of 0.3198):
#             {'max_depth': 12, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 62}
#             Current best combo (with val score 0.4774):
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 63}
#         Has trained 1726 of 25200 combinations so far
# Trained and Tested combination 1727 of 25200, taking 0.02 seconds to get val score of 0.3484:
#                 {'max_depth': 48, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 62},
#             Current best combo with val score 0.4774:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 63}
# Trained and Tested combination 1728 of 25200, taking 0.02 seconds to get val score of 0.3442:
#                 {'max_depth': 24, 'max_features': 0.55, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 62},
#             Current best combo with val score 0.4774:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 63}
# Already Trained and Tested combination (val score of 0.3545):
#             {'max_depth': 24, 'max_features': 0.4, 'ccp_alpha': 1e-06, 'splitter': 'random', 'features': 62}
#             Current best combo (with val score 0.4774):
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 63}
#         Has trained 1728 of 25200 combinations so far
# Trained and Tested combination 1729 of 25200, taking 0.06 seconds to get val score of 0.2704:
#                 {'max_depth': 24, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 62},
#             Current best combo with val score 0.4774:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 63}
# Already Trained and Tested combination (val score of 0.3487):
#             {'max_depth': 24, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 61}
#             Current best combo (with val score 0.4774):
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 63}
#         Has trained 1729 of 25200 combinations so far
# Already Trained and Tested combination (val score of 0.3584):
#             {'max_depth': 24, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 63}
#             Current best combo (with val score 0.4774):
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 63}
#         Has trained 1729 of 25200 combinations so far
# % Combos Checked Thus Far: 1729 out of 25200 which is 6.861111%
# Cruising Coordrdinate 383 of 384
#
# Cruising Coordrdinate 384 of 384
#
# Cruise suspended due to suspicious case
# Guidance: round 88
#
# 	round 88 iteration:  0
#
# Already Trained and Tested combination (val score of 0.4283):
#             {'max_depth': 6, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 63}
#             Current best combo (with val score 0.4774):
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 63}
#         Has trained 1729 of 25200 combinations so far
# Already Trained and Tested combination (val score of 0.2816):
#             {'max_depth': 3, 'max_features': 0.55, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 63}
#             Current best combo (with val score 0.4774):
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 63}
#         Has trained 1729 of 25200 combinations so far
# Already Trained and Tested combination (val score of 0.4774):
#             {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-06, 'splitter': 'random', 'features': 63}
#             Current best combo (with val score 0.4774):
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 63}
#         Has trained 1729 of 25200 combinations so far
# Already Trained and Tested combination (val score of 0.2587):
#             {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 63}
#             Current best combo (with val score 0.4774):
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 63}
#         Has trained 1729 of 25200 combinations so far
# Already Trained and Tested combination (val score of 0.2974):
#             {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 62}
#             Current best combo (with val score 0.4774):
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 63}
#         Has trained 1729 of 25200 combinations so far
# Already Trained and Tested combination (val score of 0.3491):
#             {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 64}
#             Current best combo (with val score 0.4774):
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 63}
#         Has trained 1729 of 25200 combinations so far
# 	round 88 iteration:  1
#
# Trained and Tested combination 1730 of 25200, taking 0.01 seconds to get val score of 0.4283:
#                 {'max_depth': 6, 'max_features': 0.4, 'ccp_alpha': 1e-06, 'splitter': 'random', 'features': 63},
#             Current best combo with val score 0.4774:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 63}
# Trained and Tested combination 1731 of 25200, taking 0.01 seconds to get val score of 0.2816:
#                 {'max_depth': 3, 'max_features': 0.55, 'ccp_alpha': 1e-06, 'splitter': 'random', 'features': 63},
#             Current best combo with val score 0.4774:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 63}
# Already Trained and Tested combination (val score of 0.4774):
#             {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 63}
#             Current best combo (with val score 0.4774):
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 63}
#         Has trained 1731 of 25200 combinations so far
# Trained and Tested combination 1732 of 25200, taking 0.01 seconds to get val score of 0.4774:
#                 {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 0.0001, 'splitter': 'random', 'features': 63},
#             Current best combo with val score 0.4774:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 63}
# Trained and Tested combination 1733 of 25200, taking 0.02 seconds to get val score of 0.2587:
#                 {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-06, 'splitter': 'best', 'features': 63},
#             Current best combo with val score 0.4774:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 63}
# Trained and Tested combination 1734 of 25200, taking 0.01 seconds to get val score of 0.2974:
#                 {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-06, 'splitter': 'random', 'features': 62},
#             Current best combo with val score 0.4774:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 63}
# Trained and Tested combination 1735 of 25200, taking 0.01 seconds to get val score of 0.3491:
#                 {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-06, 'splitter': 'random', 'features': 64},
#             Current best combo with val score 0.4774:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 63}
# % Combos Checked Thus Far: 1735 out of 25200 which is 6.884920999999999%
# FINAL STAGE: Begin final Guidance system
#
#
# Guidance: round FINAL
#
# 	round FINAL iteration:  0
#
# % Combos Checked Thus Far: 1735 out of 25200 which is 6.884920999999999%
# Max Val Score:
#  0.477369
# Max Val Score Std:
#  0.048809
# Best Combo Train Score:
#  0.746277
# Best Combo Train Score Std:
#  0.029536
# Max Combo Index:
#  (0, 0, 0, 1, 63) out of [7, 5, 5, 2, 72] (note best combo is 0-indexed)
# Max Combo Hyperparamer Combination:
#  {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 63}
# Max Combo Features:
#  ('procedure_225469', 'lods_score', 'procedure_224274', 'marital_status_0', 'marital_status_DIVORCED', 'marital_status_MARRIED', 'marital_status_WIDOWED', 'marital_status_SINGLE', 'procedure_223253', 'race_AMERICAN INDIAN/ALASKA NATIVE', 'race_ASIAN', 'race_ASIAN - ASIAN INDIAN', 'race_ASIAN - CHINESE', 'race_ASIAN - KOREAN', 'race_ASIAN - SOUTH EAST ASIAN', 'race_BLACK/AFRICAN', 'race_BLACK/AFRICAN AMERICAN', 'race_BLACK/CAPE VERDEAN', 'race_BLACK/CARIBBEAN ISLAND', 'race_HISPANIC OR LATINO', 'race_HISPANIC/LATINO - CENTRAL AMERICAN', 'race_HISPANIC/LATINO - COLUMBIAN', 'race_HISPANIC/LATINO - CUBAN', 'race_HISPANIC/LATINO - DOMINICAN', 'race_HISPANIC/LATINO - GUATEMALAN', 'race_HISPANIC/LATINO - HONDURAN', 'race_HISPANIC/LATINO - MEXICAN', 'race_HISPANIC/LATINO - PUERTO RICAN', 'race_HISPANIC/LATINO - SALVADORAN', 'race_MULTIPLE RACE/ETHNICITY', 'race_NATIVE HAWAIIAN OR OTHER PACIFIC ISLANDER', 'race_OTHER', 'race_PATIENT DECLINED TO ANSWER', 'race_PORTUGUESE', 'race_SOUTH AMERICAN', 'race_UNABLE TO OBTAIN', 'race_UNKNOWN', 'race_WHITE', 'race_WHITE - BRAZILIAN', 'race_WHITE - EASTERN EUROPEAN', 'race_WHITE - RUSSIAN', 'race_WHITE - OTHER EUROPEAN', 'procedure_227712', 'procedure_224276', 'admission_type_DIRECT OBSERVATION', 'admission_type_ELECTIVE', 'admission_type_EU OBSERVATION', 'admission_type_EW EMER.', 'admission_type_OBSERVATION ADMIT', 'admission_type_SURGICAL SAME DAY ADMISSION', 'admission_type_URGENT', 'admission_type_DIRECT EMER.', 'insurance_Medicare', 'insurance_Other', 'insurance_Medicaid', 'procedure_225792', 'procedure_228130', 'procedure_225817', 'procedure_224267', 'gender_F', 'gender_M', 'ventilation_used', 'hospital_stay_duration', 'oasis_score', 'procedure_228125', 'procedure_226124', 'procedure_225451', 'procedure_224275', 'procedure_229582', 'procedure_225427', 'procedure_229581', 'glucose', 'item_51301', 'spo2', 'procedure_228128', 'procedure_225401', 'procedure_225470', 'icu_stay_duration', 'unique_drugs', 'procedure_227194', 'procedure_224385', 'bun', 'anchor_age', 'heart_rate', 'procedure_225432', 'procedure_229614', 'pt', 'procedure_225454', 'creatinine', 'potassium', 'resp_rate', 'urine_output_total', 'procedure_221223', 'procedure_225444', 'procedure_224263', 'item_51265', 'mean_arterial_pressure', 'procedure_229351', 'procedure_225459', 'item_51222', 'systolic_bp', 'procedure_221214', 'procedure_225752', 'procedure_225802', 'procedure_225400', 'procedure_224270', 'procedure_228127', 'procedure_225446', 'procedure_229519', 'procedure_225457')
# % Combos Checked: 1735 out of 25200 which is 6.884920999999999%
