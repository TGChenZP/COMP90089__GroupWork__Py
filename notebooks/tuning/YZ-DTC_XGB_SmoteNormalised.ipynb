# %% [markdown]
# # Tuning Script

# %%
# Parameters subject to change in every script - involved in naming

MODEL = 'dtc'
PREPROCESSING = 'smote_normalise'
TUNER = 'yangzhoub'
OPTIMISED_METRIC = 'f1'

# %% [markdown]
# ---

# %%
# detect whether this is a google environment

COLAB_ENVIRONMENT = False

try:
    from google.colab import drive
    drive.mount('/content/drive')
    COLAB_ENVIRONMENT = True
except:
    pass
# Out:
# Mounted at /content/drive

# %%
import sys
import os
import pickle

if COLAB_ENVIRONMENT:
    home_directory = './drive/MyDrive/LAB/COMP90089__GroupWork__Py/' # my home directory is stored in ./LAB of google drive
    if MODEL == 'ebr':
        # !pip install interpret==0.5.0
    elif MODEL == 'cbr':
        # !pip install catboost
    elif MODEL in ['tf', 'mlp']:
        # !pip install PyTorch2Sklearn
    # !pip install JXAutoML
else:
    home_directory = '../../'

from JXAutoML.YangZhouB_10CV import YangZhouB_10CV as Tuner

import pandas as pd
# Out:
# Collecting JXAutoML
#   Downloading JXAutoML-0.4.4-py3-none-any.whl.metadata (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.2/67.2 kB 2.7 MB/s eta 0:00:00
# Downloading JXAutoML-0.4.4-py3-none-any.whl (52 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.1/52.1 kB 3.2 MB/s eta 0:00:00
# Installing collected packages: JXAutoML
# Successfully installed JXAutoML-0.4.4

# %%
# Parameters that are same for every script

FOLDS = 10  # we have decided to do 10 fold validation

SEED = 42

TASK_TYPE = 'Classification'  # this task is a classification task

# we have decided to tune features as hp
TUNE_FEATURES_AS_HYPERPARAMETERS = True

# %% [markdown]
# ---

# %%
# model to use to tune
from sklearn.tree import DecisionTreeClassifier as clf

# what values to try for each hyperparameter
parameter_choices = {
    'max_depth': (3, 6, 12, 24, 48, 96, 192),
    'max_features': (0.4, 0.55, 0.7, 0.85, 1),
    'ccp_alpha': (0.00000001, 0.000001, 0.0001, 0.01, 0.1),
    'splitter': ('best', 'random')
}

# what values to set non-tuneable parameters/hyperparameters
non_tunable_hyperparameters_dict = {
                                    'random_state': SEED,
                                    }

# %% [markdown]
# ---

# %% [markdown]
# Read in and Prepare Data

# %%
# Import data and store as lists

train_x_list = []
train_y_list = []
val_x_list = []
val_y_list = []

for i in range(FOLDS):
    train_data = pd.read_csv(
        f'{home_directory}data/curated/modelling/{PREPROCESSING}/train_{i}.csv')
    val_data = pd.read_csv(
        f'{home_directory}data/curated/modelling/{PREPROCESSING}/val_{i}.csv')

    # get the correct rows for X and y
    train_x = train_data.drop(
        ['mortality_status', 'subject_id', 'hadm_id', 'stay_id'], axis=1)
    train_y = train_data['mortality_status']
    val_x = val_data.drop(
        ['mortality_status', 'subject_id', 'hadm_id', 'stay_id'], axis=1)
    val_y = val_data['mortality_status']

    train_x_list.append(train_x)
    train_y_list.append(train_y)
    val_x_list.append(val_x)
    val_y_list.append(val_y)

# %%
# Import feature importance ordering

with open(f'{home_directory}models/xgb_feature_importance_ordering_{PREPROCESSING}.pickle', 'rb') as f:
    feature_importance_ordering = pickle.load(f)

# %% [markdown]
# Set parameters

# %%
# initialisation
tuner = Tuner()

print('---')

# define what model we are tuning
tuner.read_in_model(clf, TASK_TYPE, optimised_metric=OPTIMISED_METRIC)

print('---')

# read in the data for training and validation
tuner.read_in_data(train_x_list, train_y_list, val_x_list, val_y_list)

print('---')

# set what hp values to tune
tuner.set_hyperparameters(parameter_choices)
# WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

# set up hp values that need to be changed from default but NOT to be tuned
tuner.set_non_tuneable_hyperparameters(non_tunable_hyperparameters_dict)

print('---')

# set up feature importance ordering

if TUNE_FEATURES_AS_HYPERPARAMETERS:
    tuner.set_features(feature_importance_ordering)
    # WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

try:  # try to read in previous results to continue tuning ...
    tuner.read_in_tuning_result_df(
        f'{home_directory}models/tuning/{TUNER}_{MODEL}_{PREPROCESSING}.csv')
except:
    print('No previous tuning data read in')

print('---')

# set up where to save the tuning result csv
tuner.set_tuning_result_saving_address(
    f'{home_directory}models/tuning/{TUNER}_{MODEL}_{PREPROCESSING}.csv')

print('---')

# set up where to save the current best model
tuner.set_best_model_saving_address(
    f'{home_directory}models/tmp_models/{TUNER}_{MODEL}_{PREPROCESSING}')
# Out:
# YangZhouB Initialised
# ---
# Successfully read in model <class 'sklearn.tree._classes.DecisionTreeClassifier'>, which is a Classification model optimising for f1
# ---
# Read in Train X data list
# Read in Train y data list
# Read in Val X data list
# Read in Val y data list
# ---
# Successfully recorded hyperparameter choices
# ---
# Successfully recorded non_tuneable_hyperparameter choices
# ---
# Successfully recorded tuneable feature combination choices and updated relevant internal structures
# ---
# No previous tuning data read in
# ---
# Successfully set tuning output address
# ---
# Successfully set best model output address

# %%
# ignore warnings

import warnings
warnings.filterwarnings("ignore")

# %%
# begin tuning ... (or continue training)

tuner.tune()
# Out:
# Streaming output truncated to the last 5000 lines.
# 	round 61 iteration:  1
#
# Trained and Tested combination 1063 of 16800, taking 0.04 seconds to get val score of 0.1934:
#                 {'max_depth': 48, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 35},
#             Current best combo with val score 0.436:
#                     {'max_depth': 24, 'max_features': 0.7, 'ccp_alpha': 0.01, 'splitter': 'random', 'features': 24}
# Already Trained and Tested combination (val score of 0.1934):
#             {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 35}
#             Current best combo (with val score 0.436):
#                     {'max_depth': 24, 'max_features': 0.7, 'ccp_alpha': 0.01, 'splitter': 'random', 'features': 24}
#         Has trained 1063 of 16800 combinations so far
# Trained and Tested combination 1064 of 16800, taking 0.06 seconds to get val score of 0.2265:
#                 {'max_depth': 96, 'max_features': 0.55, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 35},
#             Current best combo with val score 0.436:
#                     {'max_depth': 24, 'max_features': 0.7, 'ccp_alpha': 0.01, 'splitter': 'random', 'features': 24}
# Trained and Tested combination 1065 of 16800, taking 0.04 seconds to get val score of 0.1934:
#                 {'max_depth': 96, 'max_features': 0.4, 'ccp_alpha': 1e-06, 'splitter': 'best', 'features': 35},
#             Current best combo with val score 0.436:
#                     {'max_depth': 24, 'max_features': 0.7, 'ccp_alpha': 0.01, 'splitter': 'random', 'features': 24}
# Trained and Tested combination 1066 of 16800, taking 0.01 seconds to get val score of 0.2821:
#                 {'max_depth': 96, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 35},
#             Current best combo with val score 0.436:
#                     {'max_depth': 24, 'max_features': 0.7, 'ccp_alpha': 0.01, 'splitter': 'random', 'features': 24}
# Trained and Tested combination 1067 of 16800, taking 0.04 seconds to get val score of 0.1863:
#                 {'max_depth': 96, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 34},
#             Current best combo with val score 0.436:
#                     {'max_depth': 24, 'max_features': 0.7, 'ccp_alpha': 0.01, 'splitter': 'random', 'features': 24}
# Trained and Tested combination 1068 of 16800, taking 0.07 seconds to get val score of 0.2107:
#                 {'max_depth': 96, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 36},
#             Current best combo with val score 0.436:
#                     {'max_depth': 24, 'max_features': 0.7, 'ccp_alpha': 0.01, 'splitter': 'random', 'features': 24}
# Already Trained and Tested combination (val score of 0.2265):
#             {'max_depth': 96, 'max_features': 0.55, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 35}
#             Current best combo (with val score 0.436):
#                     {'max_depth': 24, 'max_features': 0.7, 'ccp_alpha': 0.01, 'splitter': 'random', 'features': 24}
#         Has trained 1068 of 16800 combinations so far
# Already Trained and Tested combination (val score of 0.1934):
#             {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 35}
#             Current best combo (with val score 0.436):
#                     {'max_depth': 24, 'max_features': 0.7, 'ccp_alpha': 0.01, 'splitter': 'random', 'features': 24}
#         Has trained 1068 of 16800 combinations so far
# Trained and Tested combination 1069 of 16800, taking 0.1 seconds to get val score of 0.2689:
#                 {'max_depth': 192, 'max_features': 0.7, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 35},
#             Current best combo with val score 0.436:
#                     {'max_depth': 24, 'max_features': 0.7, 'ccp_alpha': 0.01, 'splitter': 'random', 'features': 24}
# Trained and Tested combination 1070 of 16800, taking 0.06 seconds to get val score of 0.2265:
#                 {'max_depth': 192, 'max_features': 0.55, 'ccp_alpha': 1e-06, 'splitter': 'best', 'features': 35},
#             Current best combo with val score 0.436:
#                     {'max_depth': 24, 'max_features': 0.7, 'ccp_alpha': 0.01, 'splitter': 'random', 'features': 24}
# Trained and Tested combination 1071 of 16800, taking 0.02 seconds to get val score of 0.2766:
#                 {'max_depth': 192, 'max_features': 0.55, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 35},
#             Current best combo with val score 0.436:
#                     {'max_depth': 24, 'max_features': 0.7, 'ccp_alpha': 0.01, 'splitter': 'random', 'features': 24}
# Trained and Tested combination 1072 of 16800, taking 0.06 seconds to get val score of 0.2027:
#                 {'max_depth': 192, 'max_features': 0.55, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 34},
#             Current best combo with val score 0.436:
#                     {'max_depth': 24, 'max_features': 0.7, 'ccp_alpha': 0.01, 'splitter': 'random', 'features': 24}
# Trained and Tested combination 1073 of 16800, taking 0.06 seconds to get val score of 0.1931:
#                 {'max_depth': 192, 'max_features': 0.55, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 36},
#             Current best combo with val score 0.436:
#                     {'max_depth': 24, 'max_features': 0.7, 'ccp_alpha': 0.01, 'splitter': 'random', 'features': 24}
# Already Trained and Tested combination (val score of 0.1934):
#             {'max_depth': 96, 'max_features': 0.4, 'ccp_alpha': 1e-06, 'splitter': 'best', 'features': 35}
#             Current best combo (with val score 0.436):
#                     {'max_depth': 24, 'max_features': 0.7, 'ccp_alpha': 0.01, 'splitter': 'random', 'features': 24}
#         Has trained 1073 of 16800 combinations so far
# Already Trained and Tested combination (val score of 0.2265):
#             {'max_depth': 192, 'max_features': 0.55, 'ccp_alpha': 1e-06, 'splitter': 'best', 'features': 35}
#             Current best combo (with val score 0.436):
#                     {'max_depth': 24, 'max_features': 0.7, 'ccp_alpha': 0.01, 'splitter': 'random', 'features': 24}
#         Has trained 1073 of 16800 combinations so far
# Already Trained and Tested combination (val score of 0.1934):
#             {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 35}
#             Current best combo (with val score 0.436):
#                     {'max_depth': 24, 'max_features': 0.7, 'ccp_alpha': 0.01, 'splitter': 'random', 'features': 24}
#         Has trained 1073 of 16800 combinations so far
# Trained and Tested combination 1074 of 16800, taking 0.04 seconds to get val score of 0.1934:
#                 {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 0.0001, 'splitter': 'best', 'features': 35},
#             Current best combo with val score 0.436:
#                     {'max_depth': 24, 'max_features': 0.7, 'ccp_alpha': 0.01, 'splitter': 'random', 'features': 24}
# Trained and Tested combination 1075 of 16800, taking 0.01 seconds to get val score of 0.2821:
#                 {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 1e-06, 'splitter': 'random', 'features': 35},
#             Current best combo with val score 0.436:
#                     {'max_depth': 24, 'max_features': 0.7, 'ccp_alpha': 0.01, 'splitter': 'random', 'features': 24}
# Trained and Tested combination 1076 of 16800, taking 0.04 seconds to get val score of 0.1863:
#                 {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 1e-06, 'splitter': 'best', 'features': 34},
#             Current best combo with val score 0.436:
#                     {'max_depth': 24, 'max_features': 0.7, 'ccp_alpha': 0.01, 'splitter': 'random', 'features': 24}
# Trained and Tested combination 1077 of 16800, taking 0.06 seconds to get val score of 0.2107:
#                 {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 1e-06, 'splitter': 'best', 'features': 36},
#             Current best combo with val score 0.436:
#                     {'max_depth': 24, 'max_features': 0.7, 'ccp_alpha': 0.01, 'splitter': 'random', 'features': 24}
# Already Trained and Tested combination (val score of 0.2821):
#             {'max_depth': 96, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 35}
#             Current best combo (with val score 0.436):
#                     {'max_depth': 24, 'max_features': 0.7, 'ccp_alpha': 0.01, 'splitter': 'random', 'features': 24}
#         Has trained 1077 of 16800 combinations so far
# Already Trained and Tested combination (val score of 0.2766):
#             {'max_depth': 192, 'max_features': 0.55, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 35}
#             Current best combo (with val score 0.436):
#                     {'max_depth': 24, 'max_features': 0.7, 'ccp_alpha': 0.01, 'splitter': 'random', 'features': 24}
#         Has trained 1077 of 16800 combinations so far
# Already Trained and Tested combination (val score of 0.2821):
#             {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 1e-06, 'splitter': 'random', 'features': 35}
#             Current best combo (with val score 0.436):
#                     {'max_depth': 24, 'max_features': 0.7, 'ccp_alpha': 0.01, 'splitter': 'random', 'features': 24}
#         Has trained 1077 of 16800 combinations so far
# Already Trained and Tested combination (val score of 0.1934):
#             {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 35}
#             Current best combo (with val score 0.436):
#                     {'max_depth': 24, 'max_features': 0.7, 'ccp_alpha': 0.01, 'splitter': 'random', 'features': 24}
#         Has trained 1077 of 16800 combinations so far
# Trained and Tested combination 1078 of 16800, taking 0.01 seconds to get val score of 0.2619:
#                 {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 34},
#             Current best combo with val score 0.436:
#                     {'max_depth': 24, 'max_features': 0.7, 'ccp_alpha': 0.01, 'splitter': 'random', 'features': 24}
# Trained and Tested combination 1079 of 16800, taking 0.02 seconds to get val score of 0.2647:
#                 {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 36},
#             Current best combo with val score 0.436:
#                     {'max_depth': 24, 'max_features': 0.7, 'ccp_alpha': 0.01, 'splitter': 'random', 'features': 24}
# Already Trained and Tested combination (val score of 0.2107):
#             {'max_depth': 96, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 36}
#             Current best combo (with val score 0.436):
#                     {'max_depth': 24, 'max_features': 0.7, 'ccp_alpha': 0.01, 'splitter': 'random', 'features': 24}
#         Has trained 1079 of 16800 combinations so far
# Already Trained and Tested combination (val score of 0.1931):
#             {'max_depth': 192, 'max_features': 0.55, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 36}
#             Current best combo (with val score 0.436):
#                     {'max_depth': 24, 'max_features': 0.7, 'ccp_alpha': 0.01, 'splitter': 'random', 'features': 24}
#         Has trained 1079 of 16800 combinations so far
# Already Trained and Tested combination (val score of 0.2107):
#             {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 1e-06, 'splitter': 'best', 'features': 36}
#             Current best combo (with val score 0.436):
#                     {'max_depth': 24, 'max_features': 0.7, 'ccp_alpha': 0.01, 'splitter': 'random', 'features': 24}
#         Has trained 1079 of 16800 combinations so far
# Already Trained and Tested combination (val score of 0.2647):
#             {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 36}
#             Current best combo (with val score 0.436):
#                     {'max_depth': 24, 'max_features': 0.7, 'ccp_alpha': 0.01, 'splitter': 'random', 'features': 24}
#         Has trained 1079 of 16800 combinations so far
# Already Trained and Tested combination (val score of 0.1934):
#             {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 35}
#             Current best combo (with val score 0.436):
#                     {'max_depth': 24, 'max_features': 0.7, 'ccp_alpha': 0.01, 'splitter': 'random', 'features': 24}
#         Has trained 1079 of 16800 combinations so far
# Trained and Tested combination 1080 of 16800, taking 0.06 seconds to get val score of 0.2562:
#                 {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 37},
#             Current best combo with val score 0.436:
#                     {'max_depth': 24, 'max_features': 0.7, 'ccp_alpha': 0.01, 'splitter': 'random', 'features': 24}
# % Combos Checked Thus Far: 1080 out of 16800 which is 6.428571%
# Cruising Coordrdinate 148 of 264
#
# Cruise suspended due to suspicious case
# Guidance: round 62
#
# 	round 62 iteration:  0
#
# Trained and Tested combination 1081 of 16800, taking 0.01 seconds to get val score of 0.2285:
#                 {'max_depth': 96, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 35},
#             Current best combo with val score 0.436:
#                     {'max_depth': 24, 'max_features': 0.7, 'ccp_alpha': 0.01, 'splitter': 'random', 'features': 24}
# Trained and Tested combination 1082 of 16800, taking 0.13 seconds to get val score of 0.2448:
#                 {'max_depth': 192, 'max_features': 0.85, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 35},
#             Current best combo with val score 0.436:
#                     {'max_depth': 24, 'max_features': 0.7, 'ccp_alpha': 0.01, 'splitter': 'random', 'features': 24}
# Trained and Tested combination 1083 of 16800, taking 0.01 seconds to get val score of 0.2285:
#                 {'max_depth': 192, 'max_features': 1, 'ccp_alpha': 1e-06, 'splitter': 'best', 'features': 35},
#             Current best combo with val score 0.436:
#                     {'max_depth': 24, 'max_features': 0.7, 'ccp_alpha': 0.01, 'splitter': 'random', 'features': 24}
# Already Trained and Tested combination (val score of 0.2853):
#             {'max_depth': 192, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 35}
#             Current best combo (with val score 0.436):
#                     {'max_depth': 24, 'max_features': 0.7, 'ccp_alpha': 0.01, 'splitter': 'random', 'features': 24}
#         Has trained 1083 of 16800 combinations so far
# Trained and Tested combination 1084 of 16800, taking 0.01 seconds to get val score of 0.247:
#                 {'max_depth': 192, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 34},
#             Current best combo with val score 0.436:
#                     {'max_depth': 24, 'max_features': 0.7, 'ccp_alpha': 0.01, 'splitter': 'random', 'features': 24}
# Trained and Tested combination 1085 of 16800, taking 0.01 seconds to get val score of 0.2533:
#                 {'max_depth': 192, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 36},
#             Current best combo with val score 0.436:
#                     {'max_depth': 24, 'max_features': 0.7, 'ccp_alpha': 0.01, 'splitter': 'random', 'features': 24}
# 	round 62 iteration:  1
#
# Trained and Tested combination 1086 of 16800, taking 0.01 seconds to get val score of 0.2285:
#                 {'max_depth': 48, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 35},
#             Current best combo with val score 0.436:
#                     {'max_depth': 24, 'max_features': 0.7, 'ccp_alpha': 0.01, 'splitter': 'random', 'features': 24}
# Already Trained and Tested combination (val score of 0.2285):
#             {'max_depth': 192, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 35}
#             Current best combo (with val score 0.436):
#                     {'max_depth': 24, 'max_features': 0.7, 'ccp_alpha': 0.01, 'splitter': 'random', 'features': 24}
#         Has trained 1086 of 16800 combinations so far
# Trained and Tested combination 1087 of 16800, taking 0.09 seconds to get val score of 0.2448:
#                 {'max_depth': 96, 'max_features': 0.85, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 35},
#             Current best combo with val score 0.436:
#                     {'max_depth': 24, 'max_features': 0.7, 'ccp_alpha': 0.01, 'splitter': 'random', 'features': 24}
# Trained and Tested combination 1088 of 16800, taking 0.01 seconds to get val score of 0.2285:
#                 {'max_depth': 96, 'max_features': 1, 'ccp_alpha': 1e-06, 'splitter': 'best', 'features': 35},
#             Current best combo with val score 0.436:
#                     {'max_depth': 24, 'max_features': 0.7, 'ccp_alpha': 0.01, 'splitter': 'random', 'features': 24}
# Trained and Tested combination 1089 of 16800, taking 0.01 seconds to get val score of 0.2853:
#                 {'max_depth': 96, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 35},
#             Current best combo with val score 0.436:
#                     {'max_depth': 24, 'max_features': 0.7, 'ccp_alpha': 0.01, 'splitter': 'random', 'features': 24}
# Trained and Tested combination 1090 of 16800, taking 0.01 seconds to get val score of 0.247:
#                 {'max_depth': 96, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 34},
#             Current best combo with val score 0.436:
#                     {'max_depth': 24, 'max_features': 0.7, 'ccp_alpha': 0.01, 'splitter': 'random', 'features': 24}
# Trained and Tested combination 1091 of 16800, taking 0.01 seconds to get val score of 0.2533:
#                 {'max_depth': 96, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 36},
#             Current best combo with val score 0.436:
#                     {'max_depth': 24, 'max_features': 0.7, 'ccp_alpha': 0.01, 'splitter': 'random', 'features': 24}
# Already Trained and Tested combination (val score of 0.2448):
#             {'max_depth': 96, 'max_features': 0.85, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 35}
#             Current best combo (with val score 0.436):
#                     {'max_depth': 24, 'max_features': 0.7, 'ccp_alpha': 0.01, 'splitter': 'random', 'features': 24}
#         Has trained 1091 of 16800 combinations so far
# Already Trained and Tested combination (val score of 0.2689):
#             {'max_depth': 192, 'max_features': 0.7, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 35}
#             Current best combo (with val score 0.436):
#                     {'max_depth': 24, 'max_features': 0.7, 'ccp_alpha': 0.01, 'splitter': 'random', 'features': 24}
#         Has trained 1091 of 16800 combinations so far
# Already Trained and Tested combination (val score of 0.2285):
#             {'max_depth': 192, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 35}
#             Current best combo (with val score 0.436):
#                     {'max_depth': 24, 'max_features': 0.7, 'ccp_alpha': 0.01, 'splitter': 'random', 'features': 24}
#         Has trained 1091 of 16800 combinations so far
# Trained and Tested combination 1092 of 16800, taking 0.09 seconds to get val score of 0.2448:
#                 {'max_depth': 192, 'max_features': 0.85, 'ccp_alpha': 1e-06, 'splitter': 'best', 'features': 35},
#             Current best combo with val score 0.436:
#                     {'max_depth': 24, 'max_features': 0.7, 'ccp_alpha': 0.01, 'splitter': 'random', 'features': 24}
# Trained and Tested combination 1093 of 16800, taking 0.02 seconds to get val score of 0.2056:
#                 {'max_depth': 192, 'max_features': 0.85, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 35},
#             Current best combo with val score 0.436:
#                     {'max_depth': 24, 'max_features': 0.7, 'ccp_alpha': 0.01, 'splitter': 'random', 'features': 24}
# Trained and Tested combination 1094 of 16800, taking 0.12 seconds to get val score of 0.3115:
#                 {'max_depth': 192, 'max_features': 0.85, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 34},
#             Current best combo with val score 0.436:
#                     {'max_depth': 24, 'max_features': 0.7, 'ccp_alpha': 0.01, 'splitter': 'random', 'features': 24}
# Trained and Tested combination 1095 of 16800, taking 0.14 seconds to get val score of 0.2475:
#                 {'max_depth': 192, 'max_features': 0.85, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 36},
#             Current best combo with val score 0.436:
#                     {'max_depth': 24, 'max_features': 0.7, 'ccp_alpha': 0.01, 'splitter': 'random', 'features': 24}
# Already Trained and Tested combination (val score of 0.2285):
#             {'max_depth': 96, 'max_features': 1, 'ccp_alpha': 1e-06, 'splitter': 'best', 'features': 35}
#             Current best combo (with val score 0.436):
#                     {'max_depth': 24, 'max_features': 0.7, 'ccp_alpha': 0.01, 'splitter': 'random', 'features': 24}
#         Has trained 1095 of 16800 combinations so far
# Already Trained and Tested combination (val score of 0.2448):
#             {'max_depth': 192, 'max_features': 0.85, 'ccp_alpha': 1e-06, 'splitter': 'best', 'features': 35}
#             Current best combo (with val score 0.436):
#                     {'max_depth': 24, 'max_features': 0.7, 'ccp_alpha': 0.01, 'splitter': 'random', 'features': 24}
#         Has trained 1095 of 16800 combinations so far
# Already Trained and Tested combination (val score of 0.2285):
#             {'max_depth': 192, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 35}
#             Current best combo (with val score 0.436):
#                     {'max_depth': 24, 'max_features': 0.7, 'ccp_alpha': 0.01, 'splitter': 'random', 'features': 24}
#         Has trained 1095 of 16800 combinations so far
# Trained and Tested combination 1096 of 16800, taking 0.01 seconds to get val score of 0.2285:
#                 {'max_depth': 192, 'max_features': 1, 'ccp_alpha': 0.0001, 'splitter': 'best', 'features': 35},
#             Current best combo with val score 0.436:
#                     {'max_depth': 24, 'max_features': 0.7, 'ccp_alpha': 0.01, 'splitter': 'random', 'features': 24}
# Trained and Tested combination 1097 of 16800, taking 0.01 seconds to get val score of 0.2853:
#                 {'max_depth': 192, 'max_features': 1, 'ccp_alpha': 1e-06, 'splitter': 'random', 'features': 35},
#             Current best combo with val score 0.436:
#                     {'max_depth': 24, 'max_features': 0.7, 'ccp_alpha': 0.01, 'splitter': 'random', 'features': 24}
# Trained and Tested combination 1098 of 16800, taking 0.01 seconds to get val score of 0.247:
#                 {'max_depth': 192, 'max_features': 1, 'ccp_alpha': 1e-06, 'splitter': 'best', 'features': 34},
#             Current best combo with val score 0.436:
#                     {'max_depth': 24, 'max_features': 0.7, 'ccp_alpha': 0.01, 'splitter': 'random', 'features': 24}
# Trained and Tested combination 1099 of 16800, taking 0.01 seconds to get val score of 0.2533:
#                 {'max_depth': 192, 'max_features': 1, 'ccp_alpha': 1e-06, 'splitter': 'best', 'features': 36},
#             Current best combo with val score 0.436:
#                     {'max_depth': 24, 'max_features': 0.7, 'ccp_alpha': 0.01, 'splitter': 'random', 'features': 24}
# Already Trained and Tested combination (val score of 0.2853):
#             {'max_depth': 96, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 35}
#             Current best combo (with val score 0.436):
#                     {'max_depth': 24, 'max_features': 0.7, 'ccp_alpha': 0.01, 'splitter': 'random', 'features': 24}
#         Has trained 1099 of 16800 combinations so far
# Already Trained and Tested combination (val score of 0.2056):
#             {'max_depth': 192, 'max_features': 0.85, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 35}
#             Current best combo (with val score 0.436):
#                     {'max_depth': 24, 'max_features': 0.7, 'ccp_alpha': 0.01, 'splitter': 'random', 'features': 24}
#         Has trained 1099 of 16800 combinations so far
# Already Trained and Tested combination (val score of 0.2853):
#             {'max_depth': 192, 'max_features': 1, 'ccp_alpha': 1e-06, 'splitter': 'random', 'features': 35}
#             Current best combo (with val score 0.436):
#                     {'max_depth': 24, 'max_features': 0.7, 'ccp_alpha': 0.01, 'splitter': 'random', 'features': 24}
#         Has trained 1099 of 16800 combinations so far
# Already Trained and Tested combination (val score of 0.2285):
#             {'max_depth': 192, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 35}
#             Current best combo (with val score 0.436):
#                     {'max_depth': 24, 'max_features': 0.7, 'ccp_alpha': 0.01, 'splitter': 'random', 'features': 24}
#         Has trained 1099 of 16800 combinations so far
# Trained and Tested combination 1100 of 16800, taking 0.01 seconds to get val score of 0.2265:
#                 {'max_depth': 192, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 34},
#             Current best combo with val score 0.436:
#                     {'max_depth': 24, 'max_features': 0.7, 'ccp_alpha': 0.01, 'splitter': 'random', 'features': 24}
# Trained and Tested combination 1101 of 16800, taking 0.01 seconds to get val score of 0.2735:
#                 {'max_depth': 192, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 36},
#             Current best combo with val score 0.436:
#                     {'max_depth': 24, 'max_features': 0.7, 'ccp_alpha': 0.01, 'splitter': 'random', 'features': 24}
# Already Trained and Tested combination (val score of 0.247):
#             {'max_depth': 96, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 34}
#             Current best combo (with val score 0.436):
#                     {'max_depth': 24, 'max_features': 0.7, 'ccp_alpha': 0.01, 'splitter': 'random', 'features': 24}
#         Has trained 1101 of 16800 combinations so far
# Already Trained and Tested combination (val score of 0.3115):
#             {'max_depth': 192, 'max_features': 0.85, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 34}
#             Current best combo (with val score 0.436):
#                     {'max_depth': 24, 'max_features': 0.7, 'ccp_alpha': 0.01, 'splitter': 'random', 'features': 24}
#         Has trained 1101 of 16800 combinations so far
# Already Trained and Tested combination (val score of 0.247):
#             {'max_depth': 192, 'max_features': 1, 'ccp_alpha': 1e-06, 'splitter': 'best', 'features': 34}
#             Current best combo (with val score 0.436):
#                     {'max_depth': 24, 'max_features': 0.7, 'ccp_alpha': 0.01, 'splitter': 'random', 'features': 24}
#         Has trained 1101 of 16800 combinations so far
# Already Trained and Tested combination (val score of 0.2265):
#             {'max_depth': 192, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 34}
#             Current best combo (with val score 0.436):
#                     {'max_depth': 24, 'max_features': 0.7, 'ccp_alpha': 0.01, 'splitter': 'random', 'features': 24}
#         Has trained 1101 of 16800 combinations so far
# Trained and Tested combination 1102 of 16800, taking 0.01 seconds to get val score of 0.263:
#                 {'max_depth': 192, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 33},
#             Current best combo with val score 0.436:
#                     {'max_depth': 24, 'max_features': 0.7, 'ccp_alpha': 0.01, 'splitter': 'random', 'features': 24}
# Already Trained and Tested combination (val score of 0.2285):
#             {'max_depth': 192, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 35}
#             Current best combo (with val score 0.436):
#                     {'max_depth': 24, 'max_features': 0.7, 'ccp_alpha': 0.01, 'splitter': 'random', 'features': 24}
#         Has trained 1102 of 16800 combinations so far
# Already Trained and Tested combination (val score of 0.2533):
#             {'max_depth': 96, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 36}
#             Current best combo (with val score 0.436):
#                     {'max_depth': 24, 'max_features': 0.7, 'ccp_alpha': 0.01, 'splitter': 'random', 'features': 24}
#         Has trained 1102 of 16800 combinations so far
# Already Trained and Tested combination (val score of 0.2475):
#             {'max_depth': 192, 'max_features': 0.85, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 36}
#             Current best combo (with val score 0.436):
#                     {'max_depth': 24, 'max_features': 0.7, 'ccp_alpha': 0.01, 'splitter': 'random', 'features': 24}
#         Has trained 1102 of 16800 combinations so far
# Already Trained and Tested combination (val score of 0.2533):
#             {'max_depth': 192, 'max_features': 1, 'ccp_alpha': 1e-06, 'splitter': 'best', 'features': 36}
#             Current best combo (with val score 0.436):
#                     {'max_depth': 24, 'max_features': 0.7, 'ccp_alpha': 0.01, 'splitter': 'random', 'features': 24}
#         Has trained 1102 of 16800 combinations so far
# Already Trained and Tested combination (val score of 0.2735):
#             {'max_depth': 192, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 36}
#             Current best combo (with val score 0.436):
#                     {'max_depth': 24, 'max_features': 0.7, 'ccp_alpha': 0.01, 'splitter': 'random', 'features': 24}
#         Has trained 1102 of 16800 combinations so far
# Already Trained and Tested combination (val score of 0.2285):
#             {'max_depth': 192, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 35}
#             Current best combo (with val score 0.436):
#                     {'max_depth': 24, 'max_features': 0.7, 'ccp_alpha': 0.01, 'splitter': 'random', 'features': 24}
#         Has trained 1102 of 16800 combinations so far
# Trained and Tested combination 1103 of 16800, taking 0.01 seconds to get val score of 0.2761:
#                 {'max_depth': 192, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 37},
#             Current best combo with val score 0.436:
#                     {'max_depth': 24, 'max_features': 0.7, 'ccp_alpha': 0.01, 'splitter': 'random', 'features': 24}
# % Combos Checked Thus Far: 1103 out of 16800 which is 6.565476%
# Cruising Coordrdinate 149 of 264
#
# Cruise suspended due to suspicious case
# Guidance: round 63
#
# 	round 63 iteration:  0
#
# % Combos Checked Thus Far: 1103 out of 16800 which is 6.565476%
# Cruising Coordrdinate 150 of 264
#
# Cruise suspended due to suspicious case
# Guidance: round 64
#
# 	round 64 iteration:  0
#
# Trained and Tested combination 1104 of 16800, taking 0.0 seconds to get val score of 0.2636:
#                 {'max_depth': 6, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 35},
#             Current best combo with val score 0.436:
#                     {'max_depth': 24, 'max_features': 0.7, 'ccp_alpha': 0.01, 'splitter': 'random', 'features': 24}
# Trained and Tested combination 1105 of 16800, taking 0.01 seconds to get val score of 0.214:
#                 {'max_depth': 3, 'max_features': 0.85, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 35},
#             Current best combo with val score 0.436:
#                     {'max_depth': 24, 'max_features': 0.7, 'ccp_alpha': 0.01, 'splitter': 'random', 'features': 24}
# Trained and Tested combination 1106 of 16800, taking 0.0 seconds to get val score of 0.2525:
#                 {'max_depth': 3, 'max_features': 1, 'ccp_alpha': 1e-06, 'splitter': 'random', 'features': 35},
#             Current best combo with val score 0.436:
#                     {'max_depth': 24, 'max_features': 0.7, 'ccp_alpha': 0.01, 'splitter': 'random', 'features': 24}
# Already Trained and Tested combination (val score of 0.0746):
#             {'max_depth': 3, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 35}
#             Current best combo (with val score 0.436):
#                     {'max_depth': 24, 'max_features': 0.7, 'ccp_alpha': 0.01, 'splitter': 'random', 'features': 24}
#         Has trained 1106 of 16800 combinations so far
# Trained and Tested combination 1107 of 16800, taking 0.0 seconds to get val score of 0.2252:
#                 {'max_depth': 3, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 34},
#             Current best combo with val score 0.436:
#                     {'max_depth': 24, 'max_features': 0.7, 'ccp_alpha': 0.01, 'splitter': 'random', 'features': 24}
# Trained and Tested combination 1108 of 16800, taking 0.0 seconds to get val score of 0.2185:
#                 {'max_depth': 3, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 36},
#             Current best combo with val score 0.436:
#                     {'max_depth': 24, 'max_features': 0.7, 'ccp_alpha': 0.01, 'splitter': 'random', 'features': 24}
# 	round 64 iteration:  1
#
# Already Trained and Tested combination (val score of 0.2525):
#             {'max_depth': 3, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 35}
#             Current best combo (with val score 0.436):
#                     {'max_depth': 24, 'max_features': 0.7, 'ccp_alpha': 0.01, 'splitter': 'random', 'features': 24}
#         Has trained 1108 of 16800 combinations so far
# Trained and Tested combination 1109 of 16800, taking 0.01 seconds to get val score of 0.2387:
#                 {'max_depth': 12, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 35},
#             Current best combo with val score 0.436:
#                     {'max_depth': 24, 'max_features': 0.7, 'ccp_alpha': 0.01, 'splitter': 'random', 'features': 24}
# Trained and Tested combination 1110 of 16800, taking 0.02 seconds to get val score of 0.2317:
#                 {'max_depth': 6, 'max_features': 0.85, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 35},
#             Current best combo with val score 0.436:
#                     {'max_depth': 24, 'max_features': 0.7, 'ccp_alpha': 0.01, 'splitter': 'random', 'features': 24}
# Trained and Tested combination 1111 of 16800, taking 0.01 seconds to get val score of 0.2636:
#                 {'max_depth': 6, 'max_features': 1, 'ccp_alpha': 1e-06, 'splitter': 'random', 'features': 35},
#             Current best combo with val score 0.436:
#                     {'max_depth': 24, 'max_features': 0.7, 'ccp_alpha': 0.01, 'splitter': 'random', 'features': 24}
# Trained and Tested combination 1112 of 16800, taking 0.01 seconds to get val score of 0.1975:
#                 {'max_depth': 6, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 35},
#             Current best combo with val score 0.436:
#                     {'max_depth': 24, 'max_features': 0.7, 'ccp_alpha': 0.01, 'splitter': 'random', 'features': 24}
# Trained and Tested combination 1113 of 16800, taking 0.0 seconds to get val score of 0.24:
#                 {'max_depth': 6, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 34},
#             Current best combo with val score 0.436:
#                     {'max_depth': 24, 'max_features': 0.7, 'ccp_alpha': 0.01, 'splitter': 'random', 'features': 24}
# Trained and Tested combination 1114 of 16800, taking 0.0 seconds to get val score of 0.2703:
#                 {'max_depth': 6, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 36},
#             Current best combo with val score 0.436:
#                     {'max_depth': 24, 'max_features': 0.7, 'ccp_alpha': 0.01, 'splitter': 'random', 'features': 24}
# Already Trained and Tested combination (val score of 0.2636):
#             {'max_depth': 6, 'max_features': 1, 'ccp_alpha': 1e-06, 'splitter': 'random', 'features': 35}
#             Current best combo (with val score 0.436):
#                     {'max_depth': 24, 'max_features': 0.7, 'ccp_alpha': 0.01, 'splitter': 'random', 'features': 24}
#         Has trained 1114 of 16800 combinations so far
# Trained and Tested combination 1115 of 16800, taking 0.01 seconds to get val score of 0.214:
#                 {'max_depth': 3, 'max_features': 0.85, 'ccp_alpha': 1e-06, 'splitter': 'random', 'features': 35},
#             Current best combo with val score 0.436:
#                     {'max_depth': 24, 'max_features': 0.7, 'ccp_alpha': 0.01, 'splitter': 'random', 'features': 24}
# Already Trained and Tested combination (val score of 0.2525):
#             {'max_depth': 3, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 35}
#             Current best combo (with val score 0.436):
#                     {'max_depth': 24, 'max_features': 0.7, 'ccp_alpha': 0.01, 'splitter': 'random', 'features': 24}
#         Has trained 1115 of 16800 combinations so far
# Trained and Tested combination 1116 of 16800, taking 0.0 seconds to get val score of 0.2525:
#                 {'max_depth': 3, 'max_features': 1, 'ccp_alpha': 0.0001, 'splitter': 'random', 'features': 35},
#             Current best combo with val score 0.436:
#                     {'max_depth': 24, 'max_features': 0.7, 'ccp_alpha': 0.01, 'splitter': 'random', 'features': 24}
# Trained and Tested combination 1117 of 16800, taking 0.0 seconds to get val score of 0.0746:
#                 {'max_depth': 3, 'max_features': 1, 'ccp_alpha': 1e-06, 'splitter': 'best', 'features': 35},
#             Current best combo with val score 0.436:
#                     {'max_depth': 24, 'max_features': 0.7, 'ccp_alpha': 0.01, 'splitter': 'random', 'features': 24}
# Trained and Tested combination 1118 of 16800, taking 0.0 seconds to get val score of 0.2252:
#                 {'max_depth': 3, 'max_features': 1, 'ccp_alpha': 1e-06, 'splitter': 'random', 'features': 34},
#             Current best combo with val score 0.436:
#                     {'max_depth': 24, 'max_features': 0.7, 'ccp_alpha': 0.01, 'splitter': 'random', 'features': 24}
# Trained and Tested combination 1119 of 16800, taking 0.0 seconds to get val score of 0.2185:
#                 {'max_depth': 3, 'max_features': 1, 'ccp_alpha': 1e-06, 'splitter': 'random', 'features': 36},
#             Current best combo with val score 0.436:
#                     {'max_depth': 24, 'max_features': 0.7, 'ccp_alpha': 0.01, 'splitter': 'random', 'features': 24}
# % Combos Checked Thus Far: 1119 out of 16800 which is 6.660714%
# Cruising Coordrdinate 151 of 264
#
# Cruise suspended due to suspicious case
# Guidance: round 65
#
# 	round 65 iteration:  0
#
# % Combos Checked Thus Far: 1119 out of 16800 which is 6.660714%
# Cruising Coordrdinate 152 of 264
#
# Cruise suspended due to suspicious case
# Guidance: round 66
#
# 	round 66 iteration:  0
#
# % Combos Checked Thus Far: 1119 out of 16800 which is 6.660714%
# Cruising Coordrdinate 153 of 264
#
# Cruising Coordrdinate 154 of 264
#
# Cruising Coordrdinate 155 of 264
#
# Cruising Coordrdinate 156 of 264
#
# Cruising Coordrdinate 157 of 264
#
# Cruising Coordrdinate 158 of 264
#
# Cruising Coordrdinate 159 of 264
#
# Cruise suspended due to suspicious case
# Guidance: round 67
#
# 	round 67 iteration:  0
#
# Trained and Tested combination 1120 of 16800, taking 0.04 seconds to get val score of 0.169:
#                 {'max_depth': 12, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 35},
#             Current best combo with val score 0.436:
#                     {'max_depth': 24, 'max_features': 0.7, 'ccp_alpha': 0.01, 'splitter': 'random', 'features': 24}
# Already Trained and Tested combination (val score of 0.1934):
#             {'max_depth': 48, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 35}
#             Current best combo (with val score 0.436):
#                     {'max_depth': 24, 'max_features': 0.7, 'ccp_alpha': 0.01, 'splitter': 'random', 'features': 24}
#         Has trained 1120 of 16800 combinations so far
# Trained and Tested combination 1121 of 16800, taking 0.06 seconds to get val score of 0.2265:
#                 {'max_depth': 24, 'max_features': 0.55, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 35},
#             Current best combo with val score 0.436:
#                     {'max_depth': 24, 'max_features': 0.7, 'ccp_alpha': 0.01, 'splitter': 'random', 'features': 24}
# Trained and Tested combination 1122 of 16800, taking 0.04 seconds to get val score of 0.1934:
#                 {'max_depth': 24, 'max_features': 0.4, 'ccp_alpha': 1e-06, 'splitter': 'best', 'features': 35},
#             Current best combo with val score 0.436:
#                     {'max_depth': 24, 'max_features': 0.7, 'ccp_alpha': 0.01, 'splitter': 'random', 'features': 24}
# Already Trained and Tested combination (val score of 0.2709):
#             {'max_depth': 24, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 35}
#             Current best combo (with val score 0.436):
#                     {'max_depth': 24, 'max_features': 0.7, 'ccp_alpha': 0.01, 'splitter': 'random', 'features': 24}
#         Has trained 1122 of 16800 combinations so far
# Trained and Tested combination 1123 of 16800, taking 0.04 seconds to get val score of 0.1828:
#                 {'max_depth': 24, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 34},
#             Current best combo with val score 0.436:
#                     {'max_depth': 24, 'max_features': 0.7, 'ccp_alpha': 0.01, 'splitter': 'random', 'features': 24}
# Trained and Tested combination 1124 of 16800, taking 0.07 seconds to get val score of 0.2112:
#                 {'max_depth': 24, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 36},
#             Current best combo with val score 0.436:
#                     {'max_depth': 24, 'max_features': 0.7, 'ccp_alpha': 0.01, 'splitter': 'random', 'features': 24}
# 	round 67 iteration:  1
#
# Trained and Tested combination 1125 of 16800, taking 0.07 seconds to get val score of 0.2285:
#                 {'max_depth': 12, 'max_features': 0.55, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 35},
#             Current best combo with val score 0.436:
#                     {'max_depth': 24, 'max_features': 0.7, 'ccp_alpha': 0.01, 'splitter': 'random', 'features': 24}
# Trained and Tested combination 1126 of 16800, taking 0.08 seconds to get val score of 0.2265:
#                 {'max_depth': 48, 'max_features': 0.55, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 35},
#             Current best combo with val score 0.436:
#                     {'max_depth': 24, 'max_features': 0.7, 'ccp_alpha': 0.01, 'splitter': 'random', 'features': 24}
# Already Trained and Tested combination (val score of 0.1934):
#             {'max_depth': 24, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 35}
#             Current best combo (with val score 0.436):
#                     {'max_depth': 24, 'max_features': 0.7, 'ccp_alpha': 0.01, 'splitter': 'random', 'features': 24}
#         Has trained 1126 of 16800 combinations so far
# Trained and Tested combination 1127 of 16800, taking 0.07 seconds to get val score of 0.2689:
#                 {'max_depth': 24, 'max_features': 0.7, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 35},
#             Current best combo with val score 0.436:
#                     {'max_depth': 24, 'max_features': 0.7, 'ccp_alpha': 0.01, 'splitter': 'random', 'features': 24}
# Trained and Tested combination 1128 of 16800, taking 0.06 seconds to get val score of 0.2265:
#                 {'max_depth': 24, 'max_features': 0.55, 'ccp_alpha': 1e-06, 'splitter': 'best', 'features': 35},
#             Current best combo with val score 0.436:
#                     {'max_depth': 24, 'max_features': 0.7, 'ccp_alpha': 0.01, 'splitter': 'random', 'features': 24}
# Trained and Tested combination 1129 of 16800, taking 0.02 seconds to get val score of 0.2588:
#                 {'max_depth': 24, 'max_features': 0.55, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 35},
#             Current best combo with val score 0.436:
#                     {'max_depth': 24, 'max_features': 0.7, 'ccp_alpha': 0.01, 'splitter': 'random', 'features': 24}
# Trained and Tested combination 1130 of 16800, taking 0.06 seconds to get val score of 0.2027:
#                 {'max_depth': 24, 'max_features': 0.55, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 34},
#             Current best combo with val score 0.436:
#                     {'max_depth': 24, 'max_features': 0.7, 'ccp_alpha': 0.01, 'splitter': 'random', 'features': 24}
# Trained and Tested combination 1131 of 16800, taking 0.07 seconds to get val score of 0.1931:
#                 {'max_depth': 24, 'max_features': 0.55, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 36},
#             Current best combo with val score 0.436:
#                     {'max_depth': 24, 'max_features': 0.7, 'ccp_alpha': 0.01, 'splitter': 'random', 'features': 24}
# Trained and Tested combination 1132 of 16800, taking 0.04 seconds to get val score of 0.169:
#                 {'max_depth': 12, 'max_features': 0.4, 'ccp_alpha': 1e-06, 'splitter': 'best', 'features': 35},
#             Current best combo with val score 0.436:
#                     {'max_depth': 24, 'max_features': 0.7, 'ccp_alpha': 0.01, 'splitter': 'random', 'features': 24}
# Trained and Tested combination 1133 of 16800, taking 0.04 seconds to get val score of 0.1934:
#                 {'max_depth': 48, 'max_features': 0.4, 'ccp_alpha': 1e-06, 'splitter': 'best', 'features': 35},
#             Current best combo with val score 0.436:
#                     {'max_depth': 24, 'max_features': 0.7, 'ccp_alpha': 0.01, 'splitter': 'random', 'features': 24}
# Already Trained and Tested combination (val score of 0.2265):
#             {'max_depth': 24, 'max_features': 0.55, 'ccp_alpha': 1e-06, 'splitter': 'best', 'features': 35}
#             Current best combo (with val score 0.436):
#                     {'max_depth': 24, 'max_features': 0.7, 'ccp_alpha': 0.01, 'splitter': 'random', 'features': 24}
#         Has trained 1133 of 16800 combinations so far
# Already Trained and Tested combination (val score of 0.1934):
#             {'max_depth': 24, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 35}
#             Current best combo (with val score 0.436):
#                     {'max_depth': 24, 'max_features': 0.7, 'ccp_alpha': 0.01, 'splitter': 'random', 'features': 24}
#         Has trained 1133 of 16800 combinations so far
# Trained and Tested combination 1134 of 16800, taking 0.04 seconds to get val score of 0.1934:
#                 {'max_depth': 24, 'max_features': 0.4, 'ccp_alpha': 0.0001, 'splitter': 'best', 'features': 35},
#             Current best combo with val score 0.436:
#                     {'max_depth': 24, 'max_features': 0.7, 'ccp_alpha': 0.01, 'splitter': 'random', 'features': 24}
# Trained and Tested combination 1135 of 16800, taking 0.01 seconds to get val score of 0.2709:
#                 {'max_depth': 24, 'max_features': 0.4, 'ccp_alpha': 1e-06, 'splitter': 'random', 'features': 35},
#             Current best combo with val score 0.436:
#                     {'max_depth': 24, 'max_features': 0.7, 'ccp_alpha': 0.01, 'splitter': 'random', 'features': 24}
# Trained and Tested combination 1136 of 16800, taking 0.05 seconds to get val score of 0.1828:
#                 {'max_depth': 24, 'max_features': 0.4, 'ccp_alpha': 1e-06, 'splitter': 'best', 'features': 34},
#             Current best combo with val score 0.436:
#                     {'max_depth': 24, 'max_features': 0.7, 'ccp_alpha': 0.01, 'splitter': 'random', 'features': 24}
# Trained and Tested combination 1137 of 16800, taking 0.07 seconds to get val score of 0.2112:
#                 {'max_depth': 24, 'max_features': 0.4, 'ccp_alpha': 1e-06, 'splitter': 'best', 'features': 36},
#             Current best combo with val score 0.436:
# ...
#             Current best combo with val score 0.4545:
#                     {'max_depth': 3, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 26}
# Already Trained and Tested combination (val score of 0.271):
#             {'max_depth': 24, 'max_features': 0.7, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 20}
#             Current best combo (with val score 0.4545):
#                     {'max_depth': 3, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 26}
#         Has trained 1684 of 16800 combinations so far
# Already Trained and Tested combination (val score of 0.3005):
#             {'max_depth': 24, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 20}
#             Current best combo (with val score 0.4545):
#                     {'max_depth': 3, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 26}
#         Has trained 1684 of 16800 combinations so far
# Trained and Tested combination 1685 of 16800, taking 0.03 seconds to get val score of 0.3092:
#                 {'max_depth': 24, 'max_features': 0.85, 'ccp_alpha': 1e-06, 'splitter': 'random', 'features': 20},
#             Current best combo with val score 0.4545:
#                     {'max_depth': 3, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 26}
# Trained and Tested combination 1686 of 16800, taking 0.05 seconds to get val score of 0.296:
#                 {'max_depth': 24, 'max_features': 0.85, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 20},
#             Current best combo with val score 0.4545:
#                     {'max_depth': 3, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 26}
# Trained and Tested combination 1687 of 16800, taking 0.02 seconds to get val score of 0.2548:
#                 {'max_depth': 24, 'max_features': 0.85, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 19},
#             Current best combo with val score 0.4545:
#                     {'max_depth': 3, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 26}
# Trained and Tested combination 1688 of 16800, taking 0.02 seconds to get val score of 0.206:
#                 {'max_depth': 24, 'max_features': 0.85, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 21},
#             Current best combo with val score 0.4545:
#                     {'max_depth': 3, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 26}
# Trained and Tested combination 1689 of 16800, taking 0.0 seconds to get val score of 0.2401:
#                 {'max_depth': 12, 'max_features': 1, 'ccp_alpha': 1e-06, 'splitter': 'random', 'features': 20},
#             Current best combo with val score 0.4545:
#                     {'max_depth': 3, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 26}
# Trained and Tested combination 1690 of 16800, taking 0.01 seconds to get val score of 0.2645:
#                 {'max_depth': 48, 'max_features': 1, 'ccp_alpha': 1e-06, 'splitter': 'random', 'features': 20},
#             Current best combo with val score 0.4545:
#                     {'max_depth': 3, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 26}
# Already Trained and Tested combination (val score of 0.3092):
#             {'max_depth': 24, 'max_features': 0.85, 'ccp_alpha': 1e-06, 'splitter': 'random', 'features': 20}
#             Current best combo (with val score 0.4545):
#                     {'max_depth': 3, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 26}
#         Has trained 1690 of 16800 combinations so far
# Already Trained and Tested combination (val score of 0.3005):
#             {'max_depth': 24, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 20}
#             Current best combo (with val score 0.4545):
#                     {'max_depth': 3, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 26}
#         Has trained 1690 of 16800 combinations so far
# Trained and Tested combination 1691 of 16800, taking 0.01 seconds to get val score of 0.2888:
#                 {'max_depth': 24, 'max_features': 1, 'ccp_alpha': 0.0001, 'splitter': 'random', 'features': 20},
#             Current best combo with val score 0.4545:
#                     {'max_depth': 3, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 26}
# Trained and Tested combination 1692 of 16800, taking 0.01 seconds to get val score of 0.3007:
#                 {'max_depth': 24, 'max_features': 1, 'ccp_alpha': 1e-06, 'splitter': 'best', 'features': 20},
#             Current best combo with val score 0.4545:
#                     {'max_depth': 3, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 26}
# Trained and Tested combination 1693 of 16800, taking 0.01 seconds to get val score of 0.2993:
#                 {'max_depth': 24, 'max_features': 1, 'ccp_alpha': 1e-06, 'splitter': 'random', 'features': 19},
#             Current best combo with val score 0.4545:
#                     {'max_depth': 3, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 26}
# Trained and Tested combination 1694 of 16800, taking 0.01 seconds to get val score of 0.3229:
#                 {'max_depth': 24, 'max_features': 1, 'ccp_alpha': 1e-06, 'splitter': 'random', 'features': 21},
#             Current best combo with val score 0.4545:
#                     {'max_depth': 3, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 26}
# Already Trained and Tested combination (val score of 0.3063):
#             {'max_depth': 12, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 20}
#             Current best combo (with val score 0.4545):
#                     {'max_depth': 3, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 26}
#         Has trained 1694 of 16800 combinations so far
# Already Trained and Tested combination (val score of 0.2872):
#             {'max_depth': 48, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 20}
#             Current best combo (with val score 0.4545):
#                     {'max_depth': 3, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 26}
#         Has trained 1694 of 16800 combinations so far
# Already Trained and Tested combination (val score of 0.296):
#             {'max_depth': 24, 'max_features': 0.85, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 20}
#             Current best combo (with val score 0.4545):
#                     {'max_depth': 3, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 26}
#         Has trained 1694 of 16800 combinations so far
# Already Trained and Tested combination (val score of 0.3007):
#             {'max_depth': 24, 'max_features': 1, 'ccp_alpha': 1e-06, 'splitter': 'best', 'features': 20}
#             Current best combo (with val score 0.4545):
#                     {'max_depth': 3, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 26}
#         Has trained 1694 of 16800 combinations so far
# Already Trained and Tested combination (val score of 0.3005):
#             {'max_depth': 24, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 20}
#             Current best combo (with val score 0.4545):
#                     {'max_depth': 3, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 26}
#         Has trained 1694 of 16800 combinations so far
# Trained and Tested combination 1695 of 16800, taking 0.01 seconds to get val score of 0.2706:
#                 {'max_depth': 24, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 19},
#             Current best combo with val score 0.4545:
#                     {'max_depth': 3, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 26}
# Trained and Tested combination 1696 of 16800, taking 0.01 seconds to get val score of 0.3123:
#                 {'max_depth': 24, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 21},
#             Current best combo with val score 0.4545:
#                     {'max_depth': 3, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 26}
# Trained and Tested combination 1697 of 16800, taking 0.0 seconds to get val score of 0.325:
#                 {'max_depth': 12, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 19},
#             Current best combo with val score 0.4545:
#                     {'max_depth': 3, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 26}
# Trained and Tested combination 1698 of 16800, taking 0.01 seconds to get val score of 0.2699:
#                 {'max_depth': 48, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 19},
#             Current best combo with val score 0.4545:
#                     {'max_depth': 3, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 26}
# Already Trained and Tested combination (val score of 0.2548):
#             {'max_depth': 24, 'max_features': 0.85, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 19}
#             Current best combo (with val score 0.4545):
#                     {'max_depth': 3, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 26}
#         Has trained 1698 of 16800 combinations so far
# Already Trained and Tested combination (val score of 0.2993):
#             {'max_depth': 24, 'max_features': 1, 'ccp_alpha': 1e-06, 'splitter': 'random', 'features': 19}
#             Current best combo (with val score 0.4545):
#                     {'max_depth': 3, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 26}
#         Has trained 1698 of 16800 combinations so far
# Already Trained and Tested combination (val score of 0.2706):
#             {'max_depth': 24, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 19}
#             Current best combo (with val score 0.4545):
#                     {'max_depth': 3, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 26}
#         Has trained 1698 of 16800 combinations so far
# Trained and Tested combination 1699 of 16800, taking 0.01 seconds to get val score of 0.2808:
#                 {'max_depth': 24, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 18},
#             Current best combo with val score 0.4545:
#                     {'max_depth': 3, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 26}
# Already Trained and Tested combination (val score of 0.3005):
#             {'max_depth': 24, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 20}
#             Current best combo (with val score 0.4545):
#                     {'max_depth': 3, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 26}
#         Has trained 1699 of 16800 combinations so far
# Trained and Tested combination 1700 of 16800, taking 0.01 seconds to get val score of 0.3992:
#                 {'max_depth': 12, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 21},
#             Current best combo with val score 0.4545:
#                     {'max_depth': 3, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 26}
# Trained and Tested combination 1701 of 16800, taking 0.01 seconds to get val score of 0.3177:
#                 {'max_depth': 48, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 21},
#             Current best combo with val score 0.4545:
#                     {'max_depth': 3, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 26}
# Already Trained and Tested combination (val score of 0.206):
#             {'max_depth': 24, 'max_features': 0.85, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 21}
#             Current best combo (with val score 0.4545):
#                     {'max_depth': 3, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 26}
#         Has trained 1701 of 16800 combinations so far
# Already Trained and Tested combination (val score of 0.3229):
#             {'max_depth': 24, 'max_features': 1, 'ccp_alpha': 1e-06, 'splitter': 'random', 'features': 21}
#             Current best combo (with val score 0.4545):
#                     {'max_depth': 3, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 26}
#         Has trained 1701 of 16800 combinations so far
# Already Trained and Tested combination (val score of 0.3123):
#             {'max_depth': 24, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 21}
#             Current best combo (with val score 0.4545):
#                     {'max_depth': 3, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 26}
#         Has trained 1701 of 16800 combinations so far
# Already Trained and Tested combination (val score of 0.3005):
#             {'max_depth': 24, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 20}
#             Current best combo (with val score 0.4545):
#                     {'max_depth': 3, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 26}
#         Has trained 1701 of 16800 combinations so far
# Trained and Tested combination 1702 of 16800, taking 0.01 seconds to get val score of 0.3378:
#                 {'max_depth': 24, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 22},
#             Current best combo with val score 0.4545:
#                     {'max_depth': 3, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 26}
# % Combos Checked Thus Far: 1702 out of 16800 which is 10.130952%
# Cruising Coordrdinate 262 of 264
#
# Cruise suspended due to suspicious case
# Guidance: round 105
#
# 	round 105 iteration:  0
#
# % Combos Checked Thus Far: 1702 out of 16800 which is 10.130952%
# Cruising Coordrdinate 263 of 264
#
# Cruising Coordrdinate 264 of 264
#
# FINAL STAGE: Begin final Guidance system
#
#
# Guidance: round FINAL
#
# 	round FINAL iteration:  0
#
# % Combos Checked Thus Far: 1702 out of 16800 which is 10.130952%
# Max Val Score:
#  0.454503
# Max Val Score Std:
#  0.038494
# Best Combo Train Score:
#  0.685094
# Best Combo Train Score Std:
#  0.008218
# Max Combo Index:
#  (0, 4, 0, 0, 26) out of [7, 5, 5, 2, 48] (note best combo is 0-indexed)
# Max Combo Hyperparamer Combination:
#  {'max_depth': 3, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 26}
# Max Combo Features:
#  ('procedure_224274', 'lods_score', 'procedure_224276', 'procedure_224267', 'race_AMERICAN INDIAN/ALASKA NATIVE', 'race_ASIAN', 'race_ASIAN - ASIAN INDIAN', 'race_ASIAN - CHINESE', 'race_ASIAN - KOREAN', 'race_ASIAN - SOUTH EAST ASIAN', 'race_BLACK/AFRICAN', 'race_BLACK/AFRICAN AMERICAN', 'race_BLACK/CAPE VERDEAN', 'race_BLACK/CARIBBEAN ISLAND', 'race_HISPANIC OR LATINO', 'race_HISPANIC/LATINO - CENTRAL AMERICAN', 'race_HISPANIC/LATINO - COLUMBIAN', 'race_HISPANIC/LATINO - CUBAN', 'race_HISPANIC/LATINO - DOMINICAN', 'race_HISPANIC/LATINO - GUATEMALAN', 'race_HISPANIC/LATINO - HONDURAN', 'race_HISPANIC/LATINO - MEXICAN', 'race_HISPANIC/LATINO - PUERTO RICAN', 'race_HISPANIC/LATINO - SALVADORAN', 'race_MULTIPLE RACE/ETHNICITY', 'race_NATIVE HAWAIIAN OR OTHER PACIFIC ISLANDER', 'race_OTHER', 'race_PATIENT DECLINED TO ANSWER', 'race_PORTUGUESE', 'race_SOUTH AMERICAN', 'race_UNABLE TO OBTAIN', 'race_WHITE', 'race_WHITE - BRAZILIAN', 'race_WHITE - EASTERN EUROPEAN', 'race_WHITE - OTHER EUROPEAN', 'race_WHITE - RUSSIAN', 'race_UNKNOWN', 'procedure_227712', 'procedure_225430', 'gender_F', 'gender_M', 'oasis_score', 'procedure_225446', 'procedure_224275', 'procedure_225802', 'hospital_stay_duration', 'procedure_226475', 'ventilation_used', 'procedure_224270', 'procedure_227194', 'icu_stay_duration', 'procedure_225400', 'procedure_221223', 'procedure_225792', 'unique_drugs', 'procedure_229351', 'glucose', 'item_51301', 'procedure_226236', 'potassium')
# % Combos Checked: 1702 out of 16800 which is 10.130952%
