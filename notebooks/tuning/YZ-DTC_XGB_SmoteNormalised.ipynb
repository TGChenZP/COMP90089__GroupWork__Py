# %% [markdown]
# # Tuning Script

# %%
# Parameters subject to change in every script - involved in naming

MODEL = 'dtc'
PREPROCESSING = 'smote_normalise'
TUNER = 'yangzhoub'
OPTIMISED_METRIC = 'f1'

# %% [markdown]
# ---

# %%
# detect whether this is a google environment

COLAB_ENVIRONMENT = False

try:
    from google.colab import drive
    drive.mount('/content/drive')
    COLAB_ENVIRONMENT = True
except:
    pass
# Out:
# Mounted at /content/drive

# %%
import sys
import os
import pickle

if COLAB_ENVIRONMENT:
    home_directory = './drive/MyDrive/LAB/COMP90089__GroupWork__Py/' # my home directory is stored in ./LAB of google drive
    if MODEL == 'ebr':
        # !pip install interpret==0.5.0
    elif MODEL == 'cbr':
        # !pip install catboost
    elif MODEL in ['tf', 'mlp']:
        # !pip install PyTorch2Sklearn
    # !pip install JXAutoML
else:
    home_directory = '../../'

from JXAutoML.YangZhouB_10CV import YangZhouB_10CV as Tuner

import pandas as pd
# Out:
# Collecting JXAutoML
#   Downloading JXAutoML-0.4.4-py3-none-any.whl.metadata (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.2/67.2 kB 4.4 MB/s eta 0:00:00
# Downloading JXAutoML-0.4.4-py3-none-any.whl (52 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.1/52.1 kB 3.7 MB/s eta 0:00:00
# Installing collected packages: JXAutoML
# Successfully installed JXAutoML-0.4.4

# %%
# Parameters that are same for every script

FOLDS = 10  # we have decided to do 10 fold validation

SEED = 42

TASK_TYPE = 'Classification'  # this task is a classification task

# we have decided to tune features as hp
TUNE_FEATURES_AS_HYPERPARAMETERS = True

# %% [markdown]
# ---

# %%
# model to use to tune
from sklearn.tree import DecisionTreeClassifier as clf

# what values to try for each hyperparameter
parameter_choices = {
    'max_depth': (3, 6, 12, 24, 48, 96, 192),
    'max_features': (0.4, 0.55, 0.7, 0.85, 1),
    'ccp_alpha': (0.00000001, 0.000001, 0.0001, 0.01, 0.1),
    'splitter': ('best', 'random')
}

# what values to set non-tuneable parameters/hyperparameters
non_tunable_hyperparameters_dict = {
                                    'random_state': SEED,
                                    }

# %% [markdown]
# ---

# %% [markdown]
# Read in and Prepare Data

# %%
# Import data and store as lists

train_x_list = []
train_y_list = []
val_x_list = []
val_y_list = []

for i in range(FOLDS):
    train_data = pd.read_csv(
        f'{home_directory}data/curated/modelling/{PREPROCESSING}/train_{i}.csv')
    val_data = pd.read_csv(
        f'{home_directory}data/curated/modelling/{PREPROCESSING}/val_{i}.csv')

    # get the correct rows for X and y
    train_x = train_data.drop(
        ['mortality_status', 'subject_id', 'hadm_id', 'stay_id'], axis=1)
    train_y = train_data['mortality_status']
    val_x = val_data.drop(
        ['mortality_status', 'subject_id', 'hadm_id', 'stay_id'], axis=1)
    val_y = val_data['mortality_status']

    train_x_list.append(train_x)
    train_y_list.append(train_y)
    val_x_list.append(val_x)
    val_y_list.append(val_y)

# %%
# Import feature importance ordering

with open(f'{home_directory}models/xgb_feature_importance_ordering_{PREPROCESSING}.pickle', 'rb') as f:
    feature_importance_ordering = pickle.load(f)

# %% [markdown]
# Set parameters

# %%
# initialisation
tuner = Tuner()

print('---')

# define what model we are tuning
tuner.read_in_model(clf, TASK_TYPE, optimised_metric=OPTIMISED_METRIC)

print('---')

# read in the data for training and validation
tuner.read_in_data(train_x_list, train_y_list, val_x_list, val_y_list)

print('---')

# set what hp values to tune
tuner.set_hyperparameters(parameter_choices)
# WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

# set up hp values that need to be changed from default but NOT to be tuned
tuner.set_non_tuneable_hyperparameters(non_tunable_hyperparameters_dict)

print('---')

# set up feature importance ordering

if TUNE_FEATURES_AS_HYPERPARAMETERS:
    tuner.set_features(feature_importance_ordering)
    # WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

try:  # try to read in previous results to continue tuning ...
    tuner.read_in_tuning_result_df(
        f'{home_directory}models/tuning/{TUNER}_{MODEL}_{PREPROCESSING}.csv')
except:
    print('No previous tuning data read in')

print('---')

# set up where to save the tuning result csv
tuner.set_tuning_result_saving_address(
    f'{home_directory}models/tuning/{TUNER}_{MODEL}_{PREPROCESSING}.csv')

print('---')

# set up where to save the current best model
tuner.set_best_model_saving_address(
    f'{home_directory}models/tmp_models/{TUNER}_{MODEL}_{PREPROCESSING}')
# Out:
# YangZhouB Initialised
# ---
# Successfully read in model <class 'sklearn.tree._classes.DecisionTreeClassifier'>, which is a Classification model optimising for f1
# ---
# Read in Train X data list
# Read in Train y data list
# Read in Val X data list
# Read in Val y data list
# ---
# Successfully recorded hyperparameter choices
# ---
# Successfully recorded non_tuneable_hyperparameter choices
# ---
# Successfully recorded tuneable feature combination choices and updated relevant internal structures
# ---
# No previous tuning data read in
# ---
# Successfully set tuning output address
# ---
# Successfully set best model output address

# %%
# ignore warnings

import warnings
warnings.filterwarnings("ignore")

# %%
# begin tuning ... (or continue training)

tuner.tune()
# Out:
# Streaming output truncated to the last 5000 lines.
# Cruising Coordrdinate 65 of 264
#
# Cruise suspended due to suspicious case
# Guidance: round 28
#
# 	round 28 iteration:  0
#
# Trained and Tested combination 588 of 17850, taking 0.0 seconds to get val score of 0.3111:
#                 {'max_depth': 96, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 5},
#             Current best combo with val score 0.4318:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 25}
# Trained and Tested combination 589 of 17850, taking 0.01 seconds to get val score of 0.3714:
#                 {'max_depth': 192, 'max_features': 0.55, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 5},
#             Current best combo with val score 0.4318:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 25}
# Trained and Tested combination 590 of 17850, taking 0.0 seconds to get val score of 0.3111:
#                 {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 1e-06, 'splitter': 'random', 'features': 5},
#             Current best combo with val score 0.4318:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 25}
# Already Trained and Tested combination (val score of 0.3208):
#             {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 5}
#             Current best combo (with val score 0.4318):
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 25}
#         Has trained 590 of 17850 combinations so far
# Trained and Tested combination 591 of 17850, taking 0.0 seconds to get val score of 0.3006:
#                 {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 4},
#             Current best combo with val score 0.4318:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 25}
# Trained and Tested combination 592 of 17850, taking 0.0 seconds to get val score of 0.3429:
#                 {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 6},
#             Current best combo with val score 0.4318:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 25}
# 	round 28 iteration:  1
#
# Trained and Tested combination 593 of 17850, taking 0.0 seconds to get val score of 0.3111:
#                 {'max_depth': 48, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 5},
#             Current best combo with val score 0.4318:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 25}
# Already Trained and Tested combination (val score of 0.3111):
#             {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 5}
#             Current best combo (with val score 0.4318):
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 25}
#         Has trained 593 of 17850 combinations so far
# Trained and Tested combination 594 of 17850, taking 0.01 seconds to get val score of 0.3714:
#                 {'max_depth': 96, 'max_features': 0.55, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 5},
#             Current best combo with val score 0.4318:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 25}
# Trained and Tested combination 595 of 17850, taking 0.01 seconds to get val score of 0.3111:
#                 {'max_depth': 96, 'max_features': 0.4, 'ccp_alpha': 1e-06, 'splitter': 'random', 'features': 5},
#             Current best combo with val score 0.4318:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 25}
# Trained and Tested combination 596 of 17850, taking 0.0 seconds to get val score of 0.3208:
#                 {'max_depth': 96, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 5},
#             Current best combo with val score 0.4318:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 25}
# Trained and Tested combination 597 of 17850, taking 0.0 seconds to get val score of 0.3006:
#                 {'max_depth': 96, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 4},
#             Current best combo with val score 0.4318:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 25}
# Trained and Tested combination 598 of 17850, taking 0.0 seconds to get val score of 0.3429:
#                 {'max_depth': 96, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 6},
#             Current best combo with val score 0.4318:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 25}
# Already Trained and Tested combination (val score of 0.3714):
#             {'max_depth': 96, 'max_features': 0.55, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 5}
#             Current best combo (with val score 0.4318):
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 25}
#         Has trained 598 of 17850 combinations so far
# Already Trained and Tested combination (val score of 0.3111):
#             {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 5}
#             Current best combo (with val score 0.4318):
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 25}
#         Has trained 598 of 17850 combinations so far
# Already Trained and Tested combination (val score of 0.3288):
#             {'max_depth': 192, 'max_features': 0.7, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 5}
#             Current best combo (with val score 0.4318):
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 25}
#         Has trained 598 of 17850 combinations so far
# Trained and Tested combination 599 of 17850, taking 0.01 seconds to get val score of 0.3714:
#                 {'max_depth': 192, 'max_features': 0.55, 'ccp_alpha': 1e-06, 'splitter': 'random', 'features': 5},
#             Current best combo with val score 0.4318:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 25}
# Trained and Tested combination 600 of 17850, taking 0.01 seconds to get val score of 0.4053:
#                 {'max_depth': 192, 'max_features': 0.55, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 5},
#             Current best combo with val score 0.4318:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 25}
# Trained and Tested combination 601 of 17850, taking 0.0 seconds to get val score of 0.3611:
#                 {'max_depth': 192, 'max_features': 0.55, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 4},
#             Current best combo with val score 0.4318:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 25}
# Trained and Tested combination 602 of 17850, taking 0.01 seconds to get val score of 0.3292:
#                 {'max_depth': 192, 'max_features': 0.55, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 6},
#             Current best combo with val score 0.4318:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 25}
# Already Trained and Tested combination (val score of 0.3111):
#             {'max_depth': 96, 'max_features': 0.4, 'ccp_alpha': 1e-06, 'splitter': 'random', 'features': 5}
#             Current best combo (with val score 0.4318):
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 25}
#         Has trained 602 of 17850 combinations so far
# Already Trained and Tested combination (val score of 0.3714):
#             {'max_depth': 192, 'max_features': 0.55, 'ccp_alpha': 1e-06, 'splitter': 'random', 'features': 5}
#             Current best combo (with val score 0.4318):
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 25}
#         Has trained 602 of 17850 combinations so far
# Already Trained and Tested combination (val score of 0.3111):
#             {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 5}
#             Current best combo (with val score 0.4318):
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 25}
#         Has trained 602 of 17850 combinations so far
# Trained and Tested combination 603 of 17850, taking 0.01 seconds to get val score of 0.3111:
#                 {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 0.0001, 'splitter': 'random', 'features': 5},
#             Current best combo with val score 0.4318:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 25}
# Trained and Tested combination 604 of 17850, taking 0.01 seconds to get val score of 0.3208:
#                 {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 1e-06, 'splitter': 'best', 'features': 5},
#             Current best combo with val score 0.4318:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 25}
# Trained and Tested combination 605 of 17850, taking 0.01 seconds to get val score of 0.3006:
#                 {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 1e-06, 'splitter': 'random', 'features': 4},
#             Current best combo with val score 0.4318:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 25}
# Trained and Tested combination 606 of 17850, taking 0.01 seconds to get val score of 0.3429:
#                 {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 1e-06, 'splitter': 'random', 'features': 6},
#             Current best combo with val score 0.4318:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 25}
# Already Trained and Tested combination (val score of 0.3208):
#             {'max_depth': 96, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 5}
#             Current best combo (with val score 0.4318):
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 25}
#         Has trained 606 of 17850 combinations so far
# Already Trained and Tested combination (val score of 0.4053):
#             {'max_depth': 192, 'max_features': 0.55, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 5}
#             Current best combo (with val score 0.4318):
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 25}
#         Has trained 606 of 17850 combinations so far
# Already Trained and Tested combination (val score of 0.3208):
#             {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 1e-06, 'splitter': 'best', 'features': 5}
#             Current best combo (with val score 0.4318):
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 25}
#         Has trained 606 of 17850 combinations so far
# Already Trained and Tested combination (val score of 0.3111):
#             {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 5}
#             Current best combo (with val score 0.4318):
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 25}
#         Has trained 606 of 17850 combinations so far
# Trained and Tested combination 607 of 17850, taking 0.01 seconds to get val score of 0.3618:
#                 {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 4},
#             Current best combo with val score 0.4318:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 25}
# Trained and Tested combination 608 of 17850, taking 0.01 seconds to get val score of 0.4056:
#                 {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 6},
#             Current best combo with val score 0.4318:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 25}
# Already Trained and Tested combination (val score of 0.3429):
#             {'max_depth': 96, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 6}
#             Current best combo (with val score 0.4318):
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 25}
#         Has trained 608 of 17850 combinations so far
# Already Trained and Tested combination (val score of 0.3292):
#             {'max_depth': 192, 'max_features': 0.55, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 6}
#             Current best combo (with val score 0.4318):
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 25}
#         Has trained 608 of 17850 combinations so far
# Already Trained and Tested combination (val score of 0.3429):
#             {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 1e-06, 'splitter': 'random', 'features': 6}
#             Current best combo (with val score 0.4318):
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 25}
#         Has trained 608 of 17850 combinations so far
# Already Trained and Tested combination (val score of 0.4056):
#             {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 6}
#             Current best combo (with val score 0.4318):
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 25}
#         Has trained 608 of 17850 combinations so far
# Already Trained and Tested combination (val score of 0.3111):
#             {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 5}
#             Current best combo (with val score 0.4318):
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 25}
#         Has trained 608 of 17850 combinations so far
# Trained and Tested combination 609 of 17850, taking 0.01 seconds to get val score of 0.2088:
#                 {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 7},
#             Current best combo with val score 0.4318:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 25}
# % Combos Checked Thus Far: 609 out of 17850 which is 3.411765%
# Cruising Coordrdinate 66 of 264
#
# Cruise suspended due to suspicious case
# Guidance: round 29
#
# 	round 29 iteration:  0
#
# Trained and Tested combination 610 of 17850, taking 0.02 seconds to get val score of 0.2745:
#                 {'max_depth': 96, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 45},
#             Current best combo with val score 0.4318:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 25}
# Trained and Tested combination 611 of 17850, taking 0.02 seconds to get val score of 0.2875:
#                 {'max_depth': 192, 'max_features': 0.55, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 45},
#             Current best combo with val score 0.4318:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 25}
# Trained and Tested combination 612 of 17850, taking 0.02 seconds to get val score of 0.2745:
#                 {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 1e-06, 'splitter': 'random', 'features': 45},
#             Current best combo with val score 0.4318:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 25}
# Already Trained and Tested combination (val score of 0.2524):
#             {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 45}
#             Current best combo (with val score 0.4318):
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 25}
#         Has trained 612 of 17850 combinations so far
# Trained and Tested combination 613 of 17850, taking 0.02 seconds to get val score of 0.2812:
#                 {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 44},
#             Current best combo with val score 0.4318:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 25}
# Trained and Tested combination 614 of 17850, taking 0.02 seconds to get val score of 0.2451:
#                 {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 46},
#             Current best combo with val score 0.4318:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 25}
# 	round 29 iteration:  1
#
# Trained and Tested combination 615 of 17850, taking 0.02 seconds to get val score of 0.2745:
#                 {'max_depth': 48, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 45},
#             Current best combo with val score 0.4318:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 25}
# Already Trained and Tested combination (val score of 0.2745):
#             {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 45}
#             Current best combo (with val score 0.4318):
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 25}
#         Has trained 615 of 17850 combinations so far
# Trained and Tested combination 616 of 17850, taking 0.02 seconds to get val score of 0.2875:
#                 {'max_depth': 96, 'max_features': 0.55, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 45},
#             Current best combo with val score 0.4318:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 25}
# Trained and Tested combination 617 of 17850, taking 0.02 seconds to get val score of 0.2745:
#                 {'max_depth': 96, 'max_features': 0.4, 'ccp_alpha': 1e-06, 'splitter': 'random', 'features': 45},
#             Current best combo with val score 0.4318:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 25}
# Trained and Tested combination 618 of 17850, taking 0.06 seconds to get val score of 0.2524:
#                 {'max_depth': 96, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 45},
#             Current best combo with val score 0.4318:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 25}
# Trained and Tested combination 619 of 17850, taking 0.02 seconds to get val score of 0.2812:
#                 {'max_depth': 96, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 44},
#             Current best combo with val score 0.4318:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 25}
# Trained and Tested combination 620 of 17850, taking 0.02 seconds to get val score of 0.2451:
#                 {'max_depth': 96, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 46},
#             Current best combo with val score 0.4318:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 25}
# Already Trained and Tested combination (val score of 0.2875):
#             {'max_depth': 96, 'max_features': 0.55, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 45}
#             Current best combo (with val score 0.4318):
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 25}
#         Has trained 620 of 17850 combinations so far
# Already Trained and Tested combination (val score of 0.2745):
#             {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 45}
#             Current best combo (with val score 0.4318):
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 25}
#         Has trained 620 of 17850 combinations so far
# Already Trained and Tested combination (val score of 0.2718):
#             {'max_depth': 192, 'max_features': 0.7, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 45}
#             Current best combo (with val score 0.4318):
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 25}
#         Has trained 620 of 17850 combinations so far
# Trained and Tested combination 621 of 17850, taking 0.02 seconds to get val score of 0.2875:
#                 {'max_depth': 192, 'max_features': 0.55, 'ccp_alpha': 1e-06, 'splitter': 'random', 'features': 45},
#             Current best combo with val score 0.4318:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 25}
# Trained and Tested combination 622 of 17850, taking 0.11 seconds to get val score of 0.2535:
#                 {'max_depth': 192, 'max_features': 0.55, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 45},
#             Current best combo with val score 0.4318:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 25}
# Trained and Tested combination 623 of 17850, taking 0.03 seconds to get val score of 0.2849:
#                 {'max_depth': 192, 'max_features': 0.55, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 44},
#             Current best combo with val score 0.4318:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 25}
# Trained and Tested combination 624 of 17850, taking 0.03 seconds to get val score of 0.2846:
#                 {'max_depth': 192, 'max_features': 0.55, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 46},
#             Current best combo with val score 0.4318:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 25}
# Already Trained and Tested combination (val score of 0.2745):
#             {'max_depth': 96, 'max_features': 0.4, 'ccp_alpha': 1e-06, 'splitter': 'random', 'features': 45}
#             Current best combo (with val score 0.4318):
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 25}
#         Has trained 624 of 17850 combinations so far
# Already Trained and Tested combination (val score of 0.2875):
#             {'max_depth': 192, 'max_features': 0.55, 'ccp_alpha': 1e-06, 'splitter': 'random', 'features': 45}
#             Current best combo (with val score 0.4318):
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 25}
#         Has trained 624 of 17850 combinations so far
# Already Trained and Tested combination (val score of 0.2745):
#             {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 45}
#             Current best combo (with val score 0.4318):
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 25}
#         Has trained 624 of 17850 combinations so far
# Trained and Tested combination 625 of 17850, taking 0.02 seconds to get val score of 0.2745:
#                 {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 0.0001, 'splitter': 'random', 'features': 45},
#             Current best combo with val score 0.4318:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 25}
# Trained and Tested combination 626 of 17850, taking 0.06 seconds to get val score of 0.2524:
#                 {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 1e-06, 'splitter': 'best', 'features': 45},
#             Current best combo with val score 0.4318:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 25}
# Trained and Tested combination 627 of 17850, taking 0.02 seconds to get val score of 0.2812:
#                 {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 1e-06, 'splitter': 'random', 'features': 44},
#             Current best combo with val score 0.4318:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 25}
# Trained and Tested combination 628 of 17850, taking 0.02 seconds to get val score of 0.2451:
#                 {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 1e-06, 'splitter': 'random', 'features': 46},
#             Current best combo with val score 0.4318:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 25}
# Already Trained and Tested combination (val score of 0.2812):
#             {'max_depth': 96, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 44}
#             Current best combo (with val score 0.4318):
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 25}
#         Has trained 628 of 17850 combinations so far
# Already Trained and Tested combination (val score of 0.2849):
#             {'max_depth': 192, 'max_features': 0.55, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 44}
#             Current best combo (with val score 0.4318):
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 25}
#         Has trained 628 of 17850 combinations so far
# Already Trained and Tested combination (val score of 0.2812):
#             {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 1e-06, 'splitter': 'random', 'features': 44}
#             Current best combo (with val score 0.4318):
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 25}
#         Has trained 628 of 17850 combinations so far
# Trained and Tested combination 629 of 17850, taking 0.07 seconds to get val score of 0.2568:
#                 {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 44},
#             Current best combo with val score 0.4318:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 25}
# Trained and Tested combination 630 of 17850, taking 0.02 seconds to get val score of 0.2312:
#                 {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 43},
#             Current best combo with val score 0.4318:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 25}
# Already Trained and Tested combination (val score of 0.2745):
#             {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 45}
#             Current best combo (with val score 0.4318):
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 25}
#         Has trained 630 of 17850 combinations so far
# % Combos Checked Thus Far: 630 out of 17850 which is 3.5294119999999998%
# Cruising Coordrdinate 67 of 264
#
# Cruise suspended due to suspicious case
# Guidance: round 30
#
# 	round 30 iteration:  0
#
# % Combos Checked Thus Far: 630 out of 17850 which is 3.5294119999999998%
# Cruising Coordrdinate 68 of 264
#
# Cruise suspended due to suspicious case
# Guidance: round 31
#
# 	round 31 iteration:  0
#
# Already Trained and Tested combination (val score of 0.2524):
#             {'max_depth': 96, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 45}
#             Current best combo (with val score 0.4318):
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 25}
#         Has trained 630 of 17850 combinations so far
# Already Trained and Tested combination (val score of 0.2535):
#             {'max_depth': 192, 'max_features': 0.55, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 45}
#             Current best combo (with val score 0.4318):
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 25}
#         Has trained 630 of 17850 combinations so far
# Already Trained and Tested combination (val score of 0.2524):
#             {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 1e-06, 'splitter': 'best', 'features': 45}
#             Current best combo (with val score 0.4318):
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 25}
#         Has trained 630 of 17850 combinations so far
# Already Trained and Tested combination (val score of 0.2745):
#             {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 45}
#             Current best combo (with val score 0.4318):
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 25}
#         Has trained 630 of 17850 combinations so far
# Already Trained and Tested combination (val score of 0.2568):
#             {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 44}
#             Current best combo (with val score 0.4318):
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 25}
#         Has trained 630 of 17850 combinations so far
# Trained and Tested combination 631 of 17850, taking 0.05 seconds to get val score of 0.2474:
#                 {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 46},
#             Current best combo with val score 0.4318:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 25}
# 	round 31 iteration:  1
#
# Trained and Tested combination 632 of 17850, taking 0.06 seconds to get val score of 0.2524:
#                 {'max_depth': 48, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 45},
#             Current best combo with val score 0.4318:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 25}
# Already Trained and Tested combination (val score of 0.2524):
#             {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 45}
#             Current best combo (with val score 0.4318):
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 25}
#         Has trained 632 of 17850 combinations so far
# Trained and Tested combination 633 of 17850, taking 0.08 seconds to get val score of 0.2535:
#                 {'max_depth': 96, 'max_features': 0.55, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 45},
#             Current best combo with val score 0.4318:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 25}
# Trained and Tested combination 634 of 17850, taking 0.06 seconds to get val score of 0.2524:
#                 {'max_depth': 96, 'max_features': 0.4, 'ccp_alpha': 1e-06, 'splitter': 'best', 'features': 45},
#             Current best combo with val score 0.4318:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 25}
# Already Trained and Tested combination (val score of 0.2745):
#             {'max_depth': 96, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 45}
#             Current best combo (with val score 0.4318):
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 25}
#         Has trained 634 of 17850 combinations so far
# Trained and Tested combination 635 of 17850, taking 0.08 seconds to get val score of 0.2568:
#                 {'max_depth': 96, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 44},
#             Current best combo with val score 0.4318:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 25}
# Trained and Tested combination 636 of 17850, taking 0.08 seconds to get val score of 0.2474:
#                 {'max_depth': 96, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 46},
#             Current best combo with val score 0.4318:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 25}
# Already Trained and Tested combination (val score of 0.2535):
#             {'max_depth': 96, 'max_features': 0.55, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 45}
#             Current best combo (with val score 0.4318):
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 25}
#         Has trained 636 of 17850 combinations so far
# Already Trained and Tested combination (val score of 0.2524):
#             {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 45}
#             Current best combo (with val score 0.4318):
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 25}
#         Has trained 636 of 17850 combinations so far
# Trained and Tested combination 637 of 17850, taking 0.17 seconds to get val score of 0.2865:
#                 {'max_depth': 192, 'max_features': 0.7, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 45},
#             Current best combo with val score 0.4318:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 25}
# Trained and Tested combination 638 of 17850, taking 0.08 seconds to get val score of 0.2535:
#                 {'max_depth': 192, 'max_features': 0.55, 'ccp_alpha': 1e-06, 'splitter': 'best', 'features': 45},
#             Current best combo with val score 0.4318:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 25}
# Already Trained and Tested combination (val score of 0.2875):
#             {'max_depth': 192, 'max_features': 0.55, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 45}
#             Current best combo (with val score 0.4318):
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 25}
#         Has trained 638 of 17850 combinations so far
# Trained and Tested combination 639 of 17850, taking 0.09 seconds to get val score of 0.2811:
#                 {'max_depth': 192, 'max_features': 0.55, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 44},
#             Current best combo with val score 0.4318:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 25}
# Trained and Tested combination 640 of 17850, taking 0.07 seconds to get val score of 0.2026:
#                 {'max_depth': 192, 'max_features': 0.55, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 46},
#             Current best combo with val score 0.4318:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 25}
# Already Trained and Tested combination (val score of 0.2524):
#             {'max_depth': 96, 'max_features': 0.4, 'ccp_alpha': 1e-06, 'splitter': 'best', 'features': 45}
#             Current best combo (with val score 0.4318):
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 25}
#         Has trained 640 of 17850 combinations so far
# Already Trained and Tested combination (val score of 0.2535):
#             {'max_depth': 192, 'max_features': 0.55, 'ccp_alpha': 1e-06, 'splitter': 'best', 'features': 45}
#             Current best combo (with val score 0.4318):
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 25}
#         Has trained 640 of 17850 combinations so far
# Already Trained and Tested combination (val score of 0.2524):
#             {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 45}
#             Current best combo (with val score 0.4318):
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 25}
#         Has trained 640 of 17850 combinations so far
# Trained and Tested combination 641 of 17850, taking 0.06 seconds to get val score of 0.2524:
#                 {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 0.0001, 'splitter': 'best', 'features': 45},
#             Current best combo with val score 0.4318:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 25}
# Already Trained and Tested combination (val score of 0.2745):
#             {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 1e-06, 'splitter': 'random', 'features': 45}
#             Current best combo (with val score 0.4318):
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 25}
#         Has trained 641 of 17850 combinations so far
# Trained and Tested combination 642 of 17850, taking 0.06 seconds to get val score of 0.2568:
#                 {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 1e-06, 'splitter': 'best', 'features': 44},
#             Current best combo with val score 0.4318:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 25}
# Trained and Tested combination 643 of 17850, taking 0.05 seconds to get val score of 0.2474:
#                 {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 1e-06, 'splitter': 'best', 'features': 46},
#             Current best combo with val score 0.4318:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 25}
# Already Trained and Tested combination (val score of 0.2568):
#             {'max_depth': 96, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 44}
#             Current best combo (with val score 0.4318):
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 25}
#         Has trained 643 of 17850 combinations so far
# Already Trained and Tested combination (val score of 0.2811):
#             {'max_depth': 192, 'max_features': 0.55, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 44}
#             Current best combo (with val score 0.4318):
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 25}
#         Has trained 643 of 17850 combinations so far
# Already Trained and Tested combination (val score of 0.2568):
#             {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 1e-06, 'splitter': 'best', 'features': 44}
#             Current best combo (with val score 0.4318):
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 25}
#         Has trained 643 of 17850 combinations so far
# Already Trained and Tested combination (val score of 0.2812):
#             {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 44}
#             Current best combo (with val score 0.4318):
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 25}
#         Has trained 643 of 17850 combinations so far
# Trained and Tested combination 644 of 17850, taking 0.06 seconds to get val score of 0.2122:
#                 {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 43},
#             Current best combo with val score 0.4318:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 25}
# Already Trained and Tested combination (val score of 0.2524):
#             {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 45}
#             Current best combo (with val score 0.4318):
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 25}
#         Has trained 644 of 17850 combinations so far
# % Combos Checked Thus Far: 644 out of 17850 which is 3.6078430000000004%
# Cruising Coordrdinate 69 of 264
#
# Cruising Coordrdinate 70 of 264
#
# Cruising Coordrdinate 71 of 264
#
# Cruising Coordrdinate 72 of 264
#
# Cruising Coordrdinate 73 of 264
#
# Cruising Coordrdinate 74 of 264
#
# Cruising Coordrdinate 75 of 264
#
# Cruise suspended due to suspicious case
# Guidance: round 32
#
# 	round 32 iteration:  0
#
# Trained and Tested combination 645 of 17850, taking 0.0 seconds to get val score of 0.1672:
#                 {'max_depth': 12, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 5},
#             Current best combo with val score 0.4318:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 25}
# Already Trained and Tested combination (val score of 0.2829):
#             {'max_depth': 48, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 5}
#             Current best combo (with val score 0.4318):
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 25}
#         Has trained 645 of 17850 combinations so far
# Trained and Tested combination 646 of 17850, taking 0.01 seconds to get val score of 0.3569:
#                 {'max_depth': 24, 'max_features': 0.85, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 5},
#             Current best combo with val score 0.4318:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 25}
# Trained and Tested combination 647 of 17850, taking 0.0 seconds to get val score of 0.2895:
#                 {'max_depth': 24, 'max_features': 1, 'ccp_alpha': 1e-06, 'splitter': 'random', 'features': 5},
#             Current best combo with val score 0.4318:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 25}
# Already Trained and Tested combination (val score of 0.2997):
#             {'max_depth': 24, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 5}
#             Current best combo (with val score 0.4318):
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 25}
#         Has trained 647 of 17850 combinations so far
# Trained and Tested combination 648 of 17850, taking 0.01 seconds to get val score of 0.2862:
#                 {'max_depth': 24, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 4},
#             Current best combo with val score 0.4318:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 25}
# Trained and Tested combination 649 of 17850, taking 0.01 seconds to get val score of 0.2867:
#                 {'max_depth': 24, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 6},
#             Current best combo with val score 0.4318:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 25}
# 	round 32 iteration:  1
#
# Trained and Tested combination 650 of 17850, taking 0.01 seconds to get val score of 0.3243:
#                 {'max_depth': 12, 'max_features': 0.85, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 5},
#             Current best combo with val score 0.4318:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 25}
# Trained and Tested combination 651 of 17850, taking 0.01 seconds to get val score of 0.3569:
#                 {'max_depth': 48, 'max_features': 0.85, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 5},
#             Current best combo with val score 0.4318:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 25}
# Trained and Tested combination 652 of 17850, taking 0.01 seconds to get val score of 0.3262:
#                 {'max_depth': 24, 'max_features': 0.7, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 5},
#             Current best combo with val score 0.4318:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 25}
# Already Trained and Tested combination (val score of 0.2895):
#             {'max_depth': 24, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 5}
#             Current best combo (with val score 0.4318):
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 25}
#         Has trained 652 of 17850 combinations so far
# Trained and Tested combination 653 of 17850, taking 0.01 seconds to get val score of 0.3569:
#                 {'max_depth': 24, 'max_features': 0.85, 'ccp_alpha': 1e-06, 'splitter': 'random', 'features': 5},
#             Current best combo with val score 0.4318:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 25}
# Trained and Tested combination 654 of 17850, taking 0.01 seconds to get val score of 0.3944:
#                 {'max_depth': 24, 'max_features': 0.85, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 5},
#             Current best combo with val score 0.4318:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 25}
# Trained and Tested combination 655 of 17850, taking 0.01 seconds to get val score of 0.324:
#                 {'max_depth': 24, 'max_features': 0.85, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 4},
#             Current best combo with val score 0.4318:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 25}
# Trained and Tested combination 656 of 17850, taking 0.01 seconds to get val score of 0.3688:
#                 {'max_depth': 24, 'max_features': 0.85, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 6},
#             Current best combo with val score 0.4318:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 25}
# Trained and Tested combination 657 of 17850, taking 0.0 seconds to get val score of 0.1672:
#                 {'max_depth': 12, 'max_features': 1, 'ccp_alpha': 1e-06, 'splitter': 'random', 'features': 5},
#             Current best combo with val score 0.4318:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 25}
# Trained and Tested combination 658 of 17850, taking 0.0 seconds to get val score of 0.2829:
# ...
#             Current best combo with val score 0.4456:
#                     {'max_depth': 3, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 31}
# Trained and Tested combination 1231 of 17850, taking 0.01 seconds to get val score of 0.2694:
#                 {'max_depth': 6, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 31},
#             Current best combo with val score 0.4456:
#                     {'max_depth': 3, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 31}
# Already Trained and Tested combination (val score of 0.3157):
#             {'max_depth': 6, 'max_features': 0.55, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 30}
#             Current best combo (with val score 0.4456):
#                     {'max_depth': 3, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 31}
#         Has trained 1231 of 17850 combinations so far
# Already Trained and Tested combination (val score of 0.3134):
#             {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 30}
#             Current best combo (with val score 0.4456):
#                     {'max_depth': 3, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 31}
#         Has trained 1231 of 17850 combinations so far
# Trained and Tested combination 1232 of 17850, taking 0.01 seconds to get val score of 0.2697:
#                 {'max_depth': 3, 'max_features': 0.7, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 30},
#             Current best combo with val score 0.4456:
#                     {'max_depth': 3, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 31}
# Trained and Tested combination 1233 of 17850, taking 0.01 seconds to get val score of 0.3254:
#                 {'max_depth': 3, 'max_features': 0.55, 'ccp_alpha': 1e-06, 'splitter': 'random', 'features': 30},
#             Current best combo with val score 0.4456:
#                     {'max_depth': 3, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 31}
# Trained and Tested combination 1234 of 17850, taking 0.01 seconds to get val score of 0.0722:
#                 {'max_depth': 3, 'max_features': 0.55, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 30},
#             Current best combo with val score 0.4456:
#                     {'max_depth': 3, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 31}
# Trained and Tested combination 1235 of 17850, taking 0.01 seconds to get val score of 0.3262:
#                 {'max_depth': 3, 'max_features': 0.55, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 29},
#             Current best combo with val score 0.4456:
#                     {'max_depth': 3, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 31}
# Trained and Tested combination 1236 of 17850, taking 0.01 seconds to get val score of 0.3183:
#                 {'max_depth': 3, 'max_features': 0.55, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 31},
#             Current best combo with val score 0.4456:
#                     {'max_depth': 3, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 31}
# Already Trained and Tested combination (val score of 0.3274):
#             {'max_depth': 6, 'max_features': 0.4, 'ccp_alpha': 1e-06, 'splitter': 'random', 'features': 30}
#             Current best combo (with val score 0.4456):
#                     {'max_depth': 3, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 31}
#         Has trained 1236 of 17850 combinations so far
# Already Trained and Tested combination (val score of 0.3254):
#             {'max_depth': 3, 'max_features': 0.55, 'ccp_alpha': 1e-06, 'splitter': 'random', 'features': 30}
#             Current best combo (with val score 0.4456):
#                     {'max_depth': 3, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 31}
#         Has trained 1236 of 17850 combinations so far
# Already Trained and Tested combination (val score of 0.3134):
#             {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 30}
#             Current best combo (with val score 0.4456):
#                     {'max_depth': 3, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 31}
#         Has trained 1236 of 17850 combinations so far
# Trained and Tested combination 1237 of 17850, taking 0.01 seconds to get val score of 0.3134:
#                 {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 0.0001, 'splitter': 'random', 'features': 30},
#             Current best combo with val score 0.4456:
#                     {'max_depth': 3, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 31}
# Trained and Tested combination 1238 of 17850, taking 0.02 seconds to get val score of 0.1829:
#                 {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-06, 'splitter': 'best', 'features': 30},
#             Current best combo with val score 0.4456:
#                     {'max_depth': 3, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 31}
# Trained and Tested combination 1239 of 17850, taking 0.01 seconds to get val score of 0.442:
#                 {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-06, 'splitter': 'random', 'features': 29},
#             Current best combo with val score 0.4456:
#                     {'max_depth': 3, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 31}
# Trained and Tested combination 1240 of 17850, taking 0.01 seconds to get val score of 0.2614:
#                 {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-06, 'splitter': 'random', 'features': 31},
#             Current best combo with val score 0.4456:
#                     {'max_depth': 3, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 31}
# Already Trained and Tested combination (val score of 0.4359):
#             {'max_depth': 6, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 29}
#             Current best combo (with val score 0.4456):
#                     {'max_depth': 3, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 31}
#         Has trained 1240 of 17850 combinations so far
# Already Trained and Tested combination (val score of 0.3262):
#             {'max_depth': 3, 'max_features': 0.55, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 29}
#             Current best combo (with val score 0.4456):
#                     {'max_depth': 3, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 31}
#         Has trained 1240 of 17850 combinations so far
# Already Trained and Tested combination (val score of 0.442):
#             {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-06, 'splitter': 'random', 'features': 29}
#             Current best combo (with val score 0.4456):
#                     {'max_depth': 3, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 31}
#         Has trained 1240 of 17850 combinations so far
# Trained and Tested combination 1241 of 17850, taking 0.01 seconds to get val score of 0.0734:
#                 {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 29},
#             Current best combo with val score 0.4456:
#                     {'max_depth': 3, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 31}
# Trained and Tested combination 1242 of 17850, taking 0.01 seconds to get val score of 0.3049:
#                 {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 28},
#             Current best combo with val score 0.4456:
#                     {'max_depth': 3, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 31}
# Already Trained and Tested combination (val score of 0.3134):
#             {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 30}
#             Current best combo (with val score 0.4456):
#                     {'max_depth': 3, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 31}
#         Has trained 1242 of 17850 combinations so far
# % Combos Checked Thus Far: 1242 out of 17850 which is 6.957983%
# Cruising Coordrdinate 261 of 264
#
# Cruising Coordrdinate 262 of 264
#
# Cruising Coordrdinate 263 of 264
#
# Cruise suspended due to suspicious case
# Guidance: round 72
#
# 	round 72 iteration:  0
#
# Trained and Tested combination 1243 of 17850, taking 0.0 seconds to get val score of 0.1502:
#                 {'max_depth': 6, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 35},
#             Current best combo with val score 0.4456:
#                     {'max_depth': 3, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 31}
# Trained and Tested combination 1244 of 17850, taking 0.03 seconds to get val score of 0.0914:
#                 {'max_depth': 3, 'max_features': 0.85, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 35},
#             Current best combo with val score 0.4456:
#                     {'max_depth': 3, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 31}
# Trained and Tested combination 1245 of 17850, taking 0.0 seconds to get val score of 0.2686:
#                 {'max_depth': 3, 'max_features': 1, 'ccp_alpha': 1e-06, 'splitter': 'best', 'features': 35},
#             Current best combo with val score 0.4456:
#                     {'max_depth': 3, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 31}
# Already Trained and Tested combination (val score of 0.0847):
#             {'max_depth': 3, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 35}
#             Current best combo (with val score 0.4456):
#                     {'max_depth': 3, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 31}
#         Has trained 1245 of 17850 combinations so far
# Trained and Tested combination 1246 of 17850, taking 0.0 seconds to get val score of 0.1969:
#                 {'max_depth': 3, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 34},
#             Current best combo with val score 0.4456:
#                     {'max_depth': 3, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 31}
# Trained and Tested combination 1247 of 17850, taking 0.0 seconds to get val score of 0.2428:
#                 {'max_depth': 3, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 36},
#             Current best combo with val score 0.4456:
#                     {'max_depth': 3, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 31}
# 	round 72 iteration:  1
#
# Trained and Tested combination 1248 of 17850, taking 0.0 seconds to get val score of 0.1502:
#                 {'max_depth': 6, 'max_features': 1, 'ccp_alpha': 1e-06, 'splitter': 'best', 'features': 35},
#             Current best combo with val score 0.4456:
#                     {'max_depth': 3, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 31}
# Trained and Tested combination 1249 of 17850, taking 0.02 seconds to get val score of 0.0914:
#                 {'max_depth': 3, 'max_features': 0.85, 'ccp_alpha': 1e-06, 'splitter': 'best', 'features': 35},
#             Current best combo with val score 0.4456:
#                     {'max_depth': 3, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 31}
# Already Trained and Tested combination (val score of 0.2686):
#             {'max_depth': 3, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 35}
#             Current best combo (with val score 0.4456):
#                     {'max_depth': 3, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 31}
#         Has trained 1249 of 17850 combinations so far
# Trained and Tested combination 1250 of 17850, taking 0.0 seconds to get val score of 0.2686:
#                 {'max_depth': 3, 'max_features': 1, 'ccp_alpha': 0.0001, 'splitter': 'best', 'features': 35},
#             Current best combo with val score 0.4456:
#                     {'max_depth': 3, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 31}
# Trained and Tested combination 1251 of 17850, taking 0.0 seconds to get val score of 0.0847:
#                 {'max_depth': 3, 'max_features': 1, 'ccp_alpha': 1e-06, 'splitter': 'random', 'features': 35},
#             Current best combo with val score 0.4456:
#                     {'max_depth': 3, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 31}
# Trained and Tested combination 1252 of 17850, taking 0.0 seconds to get val score of 0.1969:
#                 {'max_depth': 3, 'max_features': 1, 'ccp_alpha': 1e-06, 'splitter': 'best', 'features': 34},
#             Current best combo with val score 0.4456:
#                     {'max_depth': 3, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 31}
# Trained and Tested combination 1253 of 17850, taking 0.0 seconds to get val score of 0.2428:
#                 {'max_depth': 3, 'max_features': 1, 'ccp_alpha': 1e-06, 'splitter': 'best', 'features': 36},
#             Current best combo with val score 0.4456:
#                     {'max_depth': 3, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 31}
# % Combos Checked Thus Far: 1253 out of 17850 which is 7.019608%
# Cruising Coordrdinate 264 of 264
#
# FINAL STAGE: Begin final Guidance system
#
#
# Guidance: round FINAL
#
# 	round FINAL iteration:  0
#
# % Combos Checked Thus Far: 1253 out of 17850 which is 7.019608%
# Max Val Score:
#  0.445618
# Max Val Score Std:
#  0.034442
# Best Combo Train Score:
#  0.669994
# Best Combo Train Score Std:
#  0.007574
# Max Combo Index:
#  (0, 4, 0, 0, 31) out of [7, 5, 5, 2, 51] (note best combo is 0-indexed)
# Max Combo Hyperparamer Combination:
#  {'max_depth': 3, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 31}
# Max Combo Features:
#  ('marital_status_DIVORCED', 'marital_status_MARRIED', 'marital_status_SINGLE', 'marital_status_WIDOWED', 'marital_status_0', 'procedure_224276', 'lods_score', 'procedure_227712', 'procedure_224274', 'procedure_224267', 'procedure_229519', 'admission_type_DIRECT EMER.', 'admission_type_DIRECT OBSERVATION', 'admission_type_ELECTIVE', 'admission_type_EU OBSERVATION', 'admission_type_OBSERVATION ADMIT', 'admission_type_SURGICAL SAME DAY ADMISSION', 'admission_type_URGENT', 'admission_type_EW EMER.', 'gender_M', 'gender_F', 'oasis_score', 'procedure_224275', 'race_AMERICAN INDIAN/ALASKA NATIVE', 'race_ASIAN - ASIAN INDIAN', 'race_ASIAN - CHINESE', 'race_ASIAN - KOREAN', 'race_ASIAN - SOUTH EAST ASIAN', 'race_BLACK/AFRICAN', 'race_BLACK/AFRICAN AMERICAN', 'race_BLACK/CAPE VERDEAN', 'race_BLACK/CARIBBEAN ISLAND', 'race_HISPANIC OR LATINO', 'race_HISPANIC/LATINO - CENTRAL AMERICAN', 'race_HISPANIC/LATINO - COLUMBIAN', 'race_HISPANIC/LATINO - CUBAN', 'race_HISPANIC/LATINO - DOMINICAN', 'race_HISPANIC/LATINO - GUATEMALAN', 'race_HISPANIC/LATINO - HONDURAN', 'race_HISPANIC/LATINO - MEXICAN', 'race_HISPANIC/LATINO - PUERTO RICAN', 'race_HISPANIC/LATINO - SALVADORAN', 'race_MULTIPLE RACE/ETHNICITY', 'race_NATIVE HAWAIIAN OR OTHER PACIFIC ISLANDER', 'race_OTHER', 'race_PATIENT DECLINED TO ANSWER', 'race_PORTUGUESE', 'race_SOUTH AMERICAN', 'race_UNABLE TO OBTAIN', 'race_UNKNOWN', 'race_WHITE', 'race_WHITE - BRAZILIAN', 'race_WHITE - EASTERN EUROPEAN', 'race_WHITE - OTHER EUROPEAN', 'race_WHITE - RUSSIAN', 'race_ASIAN', 'hospital_stay_duration', 'insurance_Medicaid', 'insurance_Medicare', 'insurance_Other', 'procedure_226124', 'unique_drugs', 'ventilation_used', 'item_51301', 'procedure_226236', 'procedure_227194', 'spo2', 'procedure_225400', 'anchor_age', 'procedure_229351', 'glucose', 'procedure_225792', 'icu_stay_duration', 'procedure_225446', 'creatinine', 'procedure_224270', 'pt', 'procedure_221223')
# % Combos Checked: 1253 out of 17850 which is 7.019608%
