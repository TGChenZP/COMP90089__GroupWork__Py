# %% [markdown]
# # Tuning Script

# %%
# Parameters subject to change in every script - involved in naming

MODEL = 'nb(bernoulli)'
PREPROCESSING = 'smote_normalise'
TUNER = 'yangzhoub'
OPTIMISED_METRIC = 'f1'

# %% [markdown]
# ---

# %%
# detect whether this is a google environment

COLAB_ENVIRONMENT = False

try:
    from google.colab import drive
    drive.mount('/content/drive')
    COLAB_ENVIRONMENT = True
except:
    pass
# Out:
# Mounted at /content/drive

# %%
import sys
import os
import pickle

if COLAB_ENVIRONMENT:
    home_directory = './drive/MyDrive/LAB/COMP90089__GroupWork__Py/' # my home directory is stored in ./LAB of google drive
    if MODEL == 'ebr':
        # !pip install interpret==0.5.0
    elif MODEL == 'cbr':
        # !pip install catboost
    elif MODEL in ['tf', 'mlp']:
        # !pip install PyTorch2Sklearn
    # !pip install JXAutoML
else:
    home_directory = '../../'

from JXAutoML.YangZhouB_10CV import YangZhouB_10CV as Tuner

import pandas as pd
# Out:
# Collecting JXAutoML
#   Downloading JXAutoML-0.4.4-py3-none-any.whl.metadata (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.2/67.2 kB 2.6 MB/s eta 0:00:00
# Downloading JXAutoML-0.4.4-py3-none-any.whl (52 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.1/52.1 kB 4.7 MB/s eta 0:00:00
# Installing collected packages: JXAutoML
# Successfully installed JXAutoML-0.4.4

# %%
# Parameters that are same for every script

FOLDS = 10  # we have decided to do 10 fold validation

SEED = 42

TASK_TYPE = 'Classification'  # this task is a classification task

# we have decided to tune features as hp
TUNE_FEATURES_AS_HYPERPARAMETERS = True

# %% [markdown]
# ---

# %%
# model to use to tune
from sklearn.naive_bayes import BernoulliNB as clf

# what values to try for each hyperparameter
parameter_choices = {
    'alpha': (0.0001, 0.001, 0.01, 0.1, 1, 10, 100),
    'fit_prior': (False, True)
}

# what values to set non-tuneable parameters/hyperparameters
non_tunable_hyperparameters_dict = {}

# %% [markdown]
# ---

# %% [markdown]
# Read in and Prepare Data

# %%
# Import data and store as lists

train_x_list = []
train_y_list = []
val_x_list = []
val_y_list = []

for i in range(FOLDS):
    train_data = pd.read_csv(
        f'{home_directory}data/curated/modelling/{PREPROCESSING}/train_{i}.csv')
    val_data = pd.read_csv(
        f'{home_directory}data/curated/modelling/{PREPROCESSING}/val_{i}.csv')

    # get the correct rows for X and y
    train_x = train_data.drop(
        ['mortality_status', 'subject_id', 'hadm_id', 'stay_id'], axis=1)
    train_y = train_data['mortality_status']
    val_x = val_data.drop(
        ['mortality_status', 'subject_id', 'hadm_id', 'stay_id'], axis=1)
    val_y = val_data['mortality_status']

    train_x_list.append(train_x)
    train_y_list.append(train_y)
    val_x_list.append(val_x)
    val_y_list.append(val_y)

# %%
# Import feature importance ordering

with open(f'{home_directory}models/xgb_feature_importance_ordering_{PREPROCESSING}.pickle', 'rb') as f:
    feature_importance_ordering = pickle.load(f)

# %% [markdown]
# Set parameters

# %%
# initialisation
tuner = Tuner()

print('---')

# define what model we are tuning
tuner.read_in_model(clf, TASK_TYPE, optimised_metric=OPTIMISED_METRIC)

print('---')

# read in the data for training and validation
tuner.read_in_data(train_x_list, train_y_list, val_x_list, val_y_list)

print('---')

# set what hp values to tune
tuner.set_hyperparameters(parameter_choices)
# WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

# set up hp values that need to be changed from default but NOT to be tuned
tuner.set_non_tuneable_hyperparameters(non_tunable_hyperparameters_dict)

print('---')

# set up feature importance ordering

if TUNE_FEATURES_AS_HYPERPARAMETERS:
    tuner.set_features(feature_importance_ordering)
    # WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

try:  # try to read in previous results to continue tuning ...
    tuner.read_in_tuning_result_df(
        f'{home_directory}models/tuning/{TUNER}_{MODEL}_{PREPROCESSING}.csv')
except:
    print('No previous tuning data read in')

print('---')

# set up where to save the tuning result csv
tuner.set_tuning_result_saving_address(
    f'{home_directory}models/tuning/{TUNER}_{MODEL}_{PREPROCESSING}.csv')

print('---')

# set up where to save the current best model
tuner.set_best_model_saving_address(
    f'{home_directory}models/tmp_models/{TUNER}_{MODEL}_{PREPROCESSING}')
# Out:
# YangZhouB Initialised
# ---
# Successfully read in model <class 'sklearn.naive_bayes.BernoulliNB'>, which is a Classification model optimising for f1
# ---
# Read in Train X data list
# Read in Train y data list
# Read in Val X data list
# Read in Val y data list
# ---
# Successfully recorded hyperparameter choices
# ---
# Successfully recorded non_tuneable_hyperparameter choices
# ---
# Successfully recorded tuneable feature combination choices and updated relevant internal structures
# ---
# No previous tuning data read in
# ---
# Successfully set tuning output address
# ---
# Successfully set best model output address

# %%
# ignore warnings

import warnings
warnings.filterwarnings("ignore")

# %%
# begin tuning ... (or continue training)

tuner.tune()
# Out:
# BEGIN TUNING
#
#
# STAGE ZERO: Tune all Cruise combinations
#
#
# Trained and Tested combination 1 of 672, taking 0.03 seconds to get val score of 0.0033:
#                 {'alpha': 100, 'fit_prior': False, 'features': 35},
#             Current best combo with val score 0.0033:
#                     {'alpha': 100, 'fit_prior': False, 'features': 35}
# Trained and Tested combination 2 of 672, taking 0.05 seconds to get val score of 0.0033:
#                 {'alpha': 100, 'fit_prior': True, 'features': 47},
#             Current best combo with val score 0.0033:
#                     {'alpha': 100, 'fit_prior': False, 'features': 35}
# Trained and Tested combination 3 of 672, taking 0.03 seconds to get val score of 0.0033:
#                 {'alpha': 0.0001, 'fit_prior': True, 'features': 39},
#             Current best combo with val score 0.0033:
#                     {'alpha': 0.0001, 'fit_prior': True, 'features': 39}
# Trained and Tested combination 4 of 672, taking 0.02 seconds to get val score of 0.0033:
#                 {'alpha': 100, 'fit_prior': False, 'features': 30},
#             Current best combo with val score 0.0033:
#                     {'alpha': 0.0001, 'fit_prior': True, 'features': 39}
# Trained and Tested combination 5 of 672, taking 0.02 seconds to get val score of 0.0033:
#                 {'alpha': 0.0001, 'fit_prior': True, 'features': 30},
#             Current best combo with val score 0.0033:
#                     {'alpha': 0.0001, 'fit_prior': True, 'features': 39}
# Trained and Tested combination 6 of 672, taking 0.05 seconds to get val score of 0.0033:
#                 {'alpha': 0.0001, 'fit_prior': True, 'features': 47},
#             Current best combo with val score 0.0033:
#                     {'alpha': 0.0001, 'fit_prior': True, 'features': 39}
# Trained and Tested combination 7 of 672, taking 0.03 seconds to get val score of 0.0033:
#                 {'alpha': 0.0001, 'fit_prior': False, 'features': 47},
#             Current best combo with val score 0.0033:
#                     {'alpha': 0.0001, 'fit_prior': True, 'features': 39}
# Trained and Tested combination 8 of 672, taking 0.07 seconds to get val score of 0.0033:
#                 {'alpha': 0.0001, 'fit_prior': False, 'features': 39},
#             Current best combo with val score 0.0033:
#                     {'alpha': 0.0001, 'fit_prior': True, 'features': 39}
# Trained and Tested combination 9 of 672, taking 0.01 seconds to get val score of 0.0518:
#                 {'alpha': 0.1, 'fit_prior': True, 'features': 25},
#             Current best combo with val score 0.0518:
#                     {'alpha': 0.1, 'fit_prior': True, 'features': 25}
# Trained and Tested combination 10 of 672, taking 0.02 seconds to get val score of 0.0033:
#                 {'alpha': 0.0001, 'fit_prior': False, 'features': 43},
#             Current best combo with val score 0.0518:
#                     {'alpha': 0.1, 'fit_prior': True, 'features': 25}
# Trained and Tested combination 11 of 672, taking 0.01 seconds to get val score of 0.1669:
#                 {'alpha': 0.1, 'fit_prior': False, 'features': 15},
#             Current best combo with val score 0.1669:
#                     {'alpha': 0.1, 'fit_prior': False, 'features': 15}
# Trained and Tested combination 12 of 672, taking 0.01 seconds to get val score of 0.0595:
#                 {'alpha': 0.0001, 'fit_prior': True, 'features': 10},
#             Current best combo with val score 0.1669:
#                     {'alpha': 0.1, 'fit_prior': False, 'features': 15}
# Trained and Tested combination 13 of 672, taking 0.01 seconds to get val score of 0.0033:
#                 {'alpha': 0.1, 'fit_prior': True, 'features': 30},
#             Current best combo with val score 0.1669:
#                     {'alpha': 0.1, 'fit_prior': False, 'features': 15}
# Trained and Tested combination 14 of 672, taking 0.01 seconds to get val score of 0.281:
#                 {'alpha': 0.1, 'fit_prior': True, 'features': 20},
#             Current best combo with val score 0.281:
#                     {'alpha': 0.1, 'fit_prior': True, 'features': 20}
# Trained and Tested combination 15 of 672, taking 0.0 seconds to get val score of 0.3108:
#                 {'alpha': 100, 'fit_prior': False, 'features': 0},
#             Current best combo with val score 0.3108:
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
# Trained and Tested combination 16 of 672, taking 0.01 seconds to get val score of 0.281:
#                 {'alpha': 0.1, 'fit_prior': False, 'features': 20},
#             Current best combo with val score 0.3108:
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
# Trained and Tested combination 17 of 672, taking 0.01 seconds to get val score of 0.1115:
#                 {'alpha': 100, 'fit_prior': True, 'features': 15},
#             Current best combo with val score 0.3108:
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
# Trained and Tested combination 18 of 672, taking 0.01 seconds to get val score of 0.243:
#                 {'alpha': 100, 'fit_prior': True, 'features': 5},
#             Current best combo with val score 0.3108:
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
# Trained and Tested combination 19 of 672, taking 0.0 seconds to get val score of 0.3108:
#                 {'alpha': 0.0001, 'fit_prior': True, 'features': 0},
#             Current best combo with val score 0.3108:
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
# Trained and Tested combination 20 of 672, taking 0.02 seconds to get val score of 0.0662:
#                 {'alpha': 100, 'fit_prior': False, 'features': 10},
#             Current best combo with val score 0.3108:
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
# Trained and Tested combination 21 of 672, taking 0.02 seconds to get val score of 0.0033:
#                 {'alpha': 0.1, 'fit_prior': False, 'features': 35},
#             Current best combo with val score 0.3108:
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
# Trained and Tested combination 22 of 672, taking 0.01 seconds to get val score of 0.0033:
#                 {'alpha': 100, 'fit_prior': True, 'features': 30},
#             Current best combo with val score 0.3108:
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
# Trained and Tested combination 23 of 672, taking 0.0 seconds to get val score of 0.3108:
#                 {'alpha': 0.1, 'fit_prior': False, 'features': 0},
#             Current best combo with val score 0.3108:
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
# Trained and Tested combination 24 of 672, taking 0.03 seconds to get val score of 0.0033:
#                 {'alpha': 100, 'fit_prior': True, 'features': 39},
#             Current best combo with val score 0.3108:
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
# Trained and Tested combination 25 of 672, taking 0.01 seconds to get val score of 0.2672:
#                 {'alpha': 0.1, 'fit_prior': True, 'features': 5},
#             Current best combo with val score 0.3108:
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
# Trained and Tested combination 26 of 672, taking 0.01 seconds to get val score of 0.0518:
#                 {'alpha': 0.0001, 'fit_prior': True, 'features': 25},
#             Current best combo with val score 0.3108:
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
# Trained and Tested combination 27 of 672, taking 0.01 seconds to get val score of 0.281:
#                 {'alpha': 0.0001, 'fit_prior': False, 'features': 20},
#             Current best combo with val score 0.3108:
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
# Trained and Tested combination 28 of 672, taking 0.01 seconds to get val score of 0.0595:
#                 {'alpha': 0.1, 'fit_prior': True, 'features': 10},
#             Current best combo with val score 0.3108:
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
# Trained and Tested combination 29 of 672, taking 0.01 seconds to get val score of 0.2678:
#                 {'alpha': 100, 'fit_prior': False, 'features': 20},
#             Current best combo with val score 0.3108:
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
# Trained and Tested combination 30 of 672, taking 0.02 seconds to get val score of 0.0033:
#                 {'alpha': 100, 'fit_prior': False, 'features': 39},
#             Current best combo with val score 0.3108:
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
# Trained and Tested combination 31 of 672, taking 0.02 seconds to get val score of 0.0033:
#                 {'alpha': 0.0001, 'fit_prior': True, 'features': 35},
#             Current best combo with val score 0.3108:
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
# Trained and Tested combination 32 of 672, taking 0.02 seconds to get val score of 0.0033:
#                 {'alpha': 0.1, 'fit_prior': True, 'features': 47},
#             Current best combo with val score 0.3108:
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
# Trained and Tested combination 33 of 672, taking 0.03 seconds to get val score of 0.0548:
#                 {'alpha': 100, 'fit_prior': False, 'features': 25},
#             Current best combo with val score 0.3108:
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
# Trained and Tested combination 34 of 672, taking 0.02 seconds to get val score of 0.0033:
#                 {'alpha': 100, 'fit_prior': False, 'features': 43},
#             Current best combo with val score 0.3108:
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
# Trained and Tested combination 35 of 672, taking 0.03 seconds to get val score of 0.0033:
#                 {'alpha': 0.0001, 'fit_prior': True, 'features': 43},
#             Current best combo with val score 0.3108:
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
# Trained and Tested combination 36 of 672, taking 0.02 seconds to get val score of 0.0033:
#                 {'alpha': 100, 'fit_prior': True, 'features': 35},
#             Current best combo with val score 0.3108:
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
# Trained and Tested combination 37 of 672, taking 0.02 seconds to get val score of 0.0033:
#                 {'alpha': 0.1, 'fit_prior': False, 'features': 43},
#             Current best combo with val score 0.3108:
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
# Trained and Tested combination 38 of 672, taking 0.01 seconds to get val score of 0.0518:
#                 {'alpha': 0.1, 'fit_prior': False, 'features': 25},
#             Current best combo with val score 0.3108:
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
# Trained and Tested combination 39 of 672, taking 0.01 seconds to get val score of 0.0595:
#                 {'alpha': 0.1, 'fit_prior': False, 'features': 10},
#             Current best combo with val score 0.3108:
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
# Trained and Tested combination 40 of 672, taking 0.02 seconds to get val score of 0.0033:
#                 {'alpha': 0.1, 'fit_prior': False, 'features': 47},
#             Current best combo with val score 0.3108:
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
# Trained and Tested combination 41 of 672, taking 0.01 seconds to get val score of 0.1669:
#                 {'alpha': 0.0001, 'fit_prior': True, 'features': 15},
#             Current best combo with val score 0.3108:
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
# Trained and Tested combination 42 of 672, taking 0.01 seconds to get val score of 0.0595:
#                 {'alpha': 0.0001, 'fit_prior': False, 'features': 10},
#             Current best combo with val score 0.3108:
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
# Trained and Tested combination 43 of 672, taking 0.01 seconds to get val score of 0.0033:
#                 {'alpha': 0.0001, 'fit_prior': False, 'features': 30},
#             Current best combo with val score 0.3108:
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
# Trained and Tested combination 44 of 672, taking 0.0 seconds to get val score of 0.3108:
#                 {'alpha': 0.0001, 'fit_prior': False, 'features': 0},
#             Current best combo with val score 0.3108:
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
# Trained and Tested combination 45 of 672, taking 0.03 seconds to get val score of 0.0033:
#                 {'alpha': 100, 'fit_prior': False, 'features': 47},
#             Current best combo with val score 0.3108:
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
# Trained and Tested combination 46 of 672, taking 0.01 seconds to get val score of 0.2672:
#                 {'alpha': 0.1, 'fit_prior': False, 'features': 5},
#             Current best combo with val score 0.3108:
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
# Trained and Tested combination 47 of 672, taking 0.01 seconds to get val score of 0.0662:
#                 {'alpha': 100, 'fit_prior': True, 'features': 10},
#             Current best combo with val score 0.3108:
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
# Trained and Tested combination 48 of 672, taking 0.0 seconds to get val score of 0.3108:
#                 {'alpha': 0.1, 'fit_prior': True, 'features': 0},
#             Current best combo with val score 0.3108:
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
# Trained and Tested combination 49 of 672, taking 0.01 seconds to get val score of 0.2672:
#                 {'alpha': 0.0001, 'fit_prior': True, 'features': 5},
#             Current best combo with val score 0.3108:
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
# Trained and Tested combination 50 of 672, taking 0.0 seconds to get val score of 0.3108:
#                 {'alpha': 100, 'fit_prior': True, 'features': 0},
#             Current best combo with val score 0.3108:
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
# Trained and Tested combination 51 of 672, taking 0.02 seconds to get val score of 0.1669:
#                 {'alpha': 0.0001, 'fit_prior': False, 'features': 15},
#             Current best combo with val score 0.3108:
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
# Trained and Tested combination 52 of 672, taking 0.04 seconds to get val score of 0.0033:
#                 {'alpha': 0.1, 'fit_prior': False, 'features': 39},
#             Current best combo with val score 0.3108:
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
# Trained and Tested combination 53 of 672, taking 0.02 seconds to get val score of 0.281:
#                 {'alpha': 0.0001, 'fit_prior': True, 'features': 20},
#             Current best combo with val score 0.3108:
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
# Trained and Tested combination 54 of 672, taking 0.03 seconds to get val score of 0.243:
#                 {'alpha': 100, 'fit_prior': False, 'features': 5},
#             Current best combo with val score 0.3108:
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
# Trained and Tested combination 55 of 672, taking 0.01 seconds to get val score of 0.0548:
#                 {'alpha': 100, 'fit_prior': True, 'features': 25},
#             Current best combo with val score 0.3108:
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
# Trained and Tested combination 56 of 672, taking 0.02 seconds to get val score of 0.0033:
#                 {'alpha': 0.0001, 'fit_prior': False, 'features': 35},
#             Current best combo with val score 0.3108:
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
# Trained and Tested combination 57 of 672, taking 0.02 seconds to get val score of 0.0033:
#                 {'alpha': 0.1, 'fit_prior': True, 'features': 35},
#             Current best combo with val score 0.3108:
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
# Trained and Tested combination 58 of 672, taking 0.01 seconds to get val score of 0.0033:
#                 {'alpha': 0.1, 'fit_prior': False, 'features': 30},
#             Current best combo with val score 0.3108:
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
# Trained and Tested combination 59 of 672, taking 0.01 seconds to get val score of 0.0518:
#                 {'alpha': 0.0001, 'fit_prior': False, 'features': 25},
#             Current best combo with val score 0.3108:
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
# Trained and Tested combination 60 of 672, taking 0.01 seconds to get val score of 0.2672:
#                 {'alpha': 0.0001, 'fit_prior': False, 'features': 5},
#             Current best combo with val score 0.3108:
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
# Trained and Tested combination 61 of 672, taking 0.01 seconds to get val score of 0.2678:
#                 {'alpha': 100, 'fit_prior': True, 'features': 20},
#             Current best combo with val score 0.3108:
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
# Trained and Tested combination 62 of 672, taking 0.02 seconds to get val score of 0.0033:
#                 {'alpha': 0.1, 'fit_prior': True, 'features': 39},
#             Current best combo with val score 0.3108:
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
# Trained and Tested combination 63 of 672, taking 0.01 seconds to get val score of 0.1669:
#                 {'alpha': 0.1, 'fit_prior': True, 'features': 15},
#             Current best combo with val score 0.3108:
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
# Trained and Tested combination 64 of 672, taking 0.02 seconds to get val score of 0.0033:
#                 {'alpha': 0.1, 'fit_prior': True, 'features': 43},
#             Current best combo with val score 0.3108:
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
# Trained and Tested combination 65 of 672, taking 0.01 seconds to get val score of 0.0518:
#                 {'alpha': 0.1, 'fit_prior': True, 'features': 24},
#             Current best combo with val score 0.3108:
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
# Trained and Tested combination 66 of 672, taking 0.01 seconds to get val score of 0.1115:
#                 {'alpha': 100, 'fit_prior': False, 'features': 15},
#             Current best combo with val score 0.3108:
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
# Trained and Tested combination 67 of 672, taking 0.02 seconds to get val score of 0.0033:
#                 {'alpha': 100, 'fit_prior': True, 'features': 43},
#             Current best combo with val score 0.3108:
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
#
#
# STAGE ONE: Begin initial Guidance system
#
#
# Guidance: initial round
#
# 	round 0 iteration:  0
#
# Trained and Tested combination 68 of 672, taking 0.02 seconds to get val score of 0.0518:
#                 {'alpha': 0.01, 'fit_prior': True, 'features': 24},
#             Current best combo with val score 0.3108:
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
# Trained and Tested combination 69 of 672, taking 0.01 seconds to get val score of 0.0518:
#                 {'alpha': 1, 'fit_prior': True, 'features': 24},
#             Current best combo with val score 0.3108:
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
# Trained and Tested combination 70 of 672, taking 0.01 seconds to get val score of 0.0518:
#                 {'alpha': 0.1, 'fit_prior': False, 'features': 24},
#             Current best combo with val score 0.3108:
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
# Trained and Tested combination 71 of 672, taking 0.01 seconds to get val score of 0.1225:
#                 {'alpha': 0.1, 'fit_prior': True, 'features': 23},
#             Current best combo with val score 0.3108:
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
# Already Trained and Tested combination (val score of 0.0518):
#             {'alpha': 0.1, 'fit_prior': True, 'features': 25}
#             Current best combo (with val score 0.3108):
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
#         Has trained 71 of 672 combinations so far
# 	round 0 iteration:  1
#
# Trained and Tested combination 72 of 672, taking 0.01 seconds to get val score of 0.0518:
#                 {'alpha': 0.001, 'fit_prior': True, 'features': 24},
#             Current best combo with val score 0.3108:
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
# Already Trained and Tested combination (val score of 0.0518):
#             {'alpha': 0.1, 'fit_prior': True, 'features': 24}
#             Current best combo (with val score 0.3108):
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
#         Has trained 72 of 672 combinations so far
# Trained and Tested combination 73 of 672, taking 0.01 seconds to get val score of 0.0518:
#                 {'alpha': 0.01, 'fit_prior': False, 'features': 24},
#             Current best combo with val score 0.3108:
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
# Trained and Tested combination 74 of 672, taking 0.01 seconds to get val score of 0.1225:
#                 {'alpha': 0.01, 'fit_prior': True, 'features': 23},
#             Current best combo with val score 0.3108:
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
# Trained and Tested combination 75 of 672, taking 0.01 seconds to get val score of 0.0518:
#                 {'alpha': 0.01, 'fit_prior': True, 'features': 25},
#             Current best combo with val score 0.3108:
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
# Already Trained and Tested combination (val score of 0.0518):
#             {'alpha': 0.1, 'fit_prior': True, 'features': 24}
#             Current best combo (with val score 0.3108):
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
#         Has trained 75 of 672 combinations so far
# Trained and Tested combination 76 of 672, taking 0.01 seconds to get val score of 0.0518:
#                 {'alpha': 10, 'fit_prior': True, 'features': 24},
#             Current best combo with val score 0.3108:
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
# Trained and Tested combination 77 of 672, taking 0.01 seconds to get val score of 0.0518:
#                 {'alpha': 1, 'fit_prior': False, 'features': 24},
#             Current best combo with val score 0.3108:
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
# Trained and Tested combination 78 of 672, taking 0.01 seconds to get val score of 0.1225:
#                 {'alpha': 1, 'fit_prior': True, 'features': 23},
#             Current best combo with val score 0.3108:
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
# Trained and Tested combination 79 of 672, taking 0.02 seconds to get val score of 0.0518:
#                 {'alpha': 1, 'fit_prior': True, 'features': 25},
#             Current best combo with val score 0.3108:
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
# Already Trained and Tested combination (val score of 0.0518):
#             {'alpha': 0.01, 'fit_prior': False, 'features': 24}
#             Current best combo (with val score 0.3108):
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
#         Has trained 79 of 672 combinations so far
# Already Trained and Tested combination (val score of 0.0518):
#             {'alpha': 1, 'fit_prior': False, 'features': 24}
#             Current best combo (with val score 0.3108):
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
#         Has trained 79 of 672 combinations so far
# Already Trained and Tested combination (val score of 0.0518):
#             {'alpha': 0.1, 'fit_prior': True, 'features': 24}
#             Current best combo (with val score 0.3108):
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
#         Has trained 79 of 672 combinations so far
# Trained and Tested combination 80 of 672, taking 0.01 seconds to get val score of 0.1225:
#                 {'alpha': 0.1, 'fit_prior': False, 'features': 23},
#             Current best combo with val score 0.3108:
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
# Already Trained and Tested combination (val score of 0.0518):
#             {'alpha': 0.1, 'fit_prior': False, 'features': 25}
#             Current best combo (with val score 0.3108):
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
#         Has trained 80 of 672 combinations so far
# Already Trained and Tested combination (val score of 0.1225):
#             {'alpha': 0.01, 'fit_prior': True, 'features': 23}
#             Current best combo (with val score 0.3108):
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
#         Has trained 80 of 672 combinations so far
# Already Trained and Tested combination (val score of 0.1225):
#             {'alpha': 1, 'fit_prior': True, 'features': 23}
#             Current best combo (with val score 0.3108):
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
#         Has trained 80 of 672 combinations so far
# Already Trained and Tested combination (val score of 0.1225):
#             {'alpha': 0.1, 'fit_prior': False, 'features': 23}
#             Current best combo (with val score 0.3108):
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
#         Has trained 80 of 672 combinations so far
# Trained and Tested combination 81 of 672, taking 0.02 seconds to get val score of 0.2091:
#                 {'alpha': 0.1, 'fit_prior': True, 'features': 22},
#             Current best combo with val score 0.3108:
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
# Already Trained and Tested combination (val score of 0.0518):
#             {'alpha': 0.1, 'fit_prior': True, 'features': 24}
#             Current best combo (with val score 0.3108):
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
#         Has trained 81 of 672 combinations so far
# Already Trained and Tested combination (val score of 0.0518):
#             {'alpha': 0.01, 'fit_prior': True, 'features': 25}
#             Current best combo (with val score 0.3108):
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
#         Has trained 81 of 672 combinations so far
# Already Trained and Tested combination (val score of 0.0518):
#             {'alpha': 1, 'fit_prior': True, 'features': 25}
#             Current best combo (with val score 0.3108):
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
#         Has trained 81 of 672 combinations so far
# Already Trained and Tested combination (val score of 0.0518):
#             {'alpha': 0.1, 'fit_prior': False, 'features': 25}
#             Current best combo (with val score 0.3108):
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
#         Has trained 81 of 672 combinations so far
# Already Trained and Tested combination (val score of 0.0518):
#             {'alpha': 0.1, 'fit_prior': True, 'features': 24}
#             Current best combo (with val score 0.3108):
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
#         Has trained 81 of 672 combinations so far
# Trained and Tested combination 82 of 672, taking 0.01 seconds to get val score of 0.0456:
#                 {'alpha': 0.1, 'fit_prior': True, 'features': 26},
#             Current best combo with val score 0.3108:
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
# Trained and Tested combination 83 of 672, taking 0.0 seconds to get val score of 0.3108:
#                 {'alpha': 10, 'fit_prior': False, 'features': 0},
#             Current best combo with val score 0.3108:
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
# Already Trained and Tested combination (val score of 0.3108):
#             {'alpha': 100, 'fit_prior': True, 'features': 0}
#             Current best combo (with val score 0.3108):
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
#         Has trained 83 of 672 combinations so far
# Trained and Tested combination 84 of 672, taking 0.01 seconds to get val score of 0.0067:
#                 {'alpha': 100, 'fit_prior': False, 'features': 1},
#             Current best combo with val score 0.3108:
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
# % Combos Checked Thus Far: 84 out of 672 which is 12.5%
# STAGE TWO: Begin Cruise system
#
#
# Cruising Coordrdinate 1 of 66
#
# Cruising Coordrdinate 2 of 66
#
# Cruising Coordrdinate 3 of 66
#
# Cruising Coordrdinate 4 of 66
#
# Cruising Coordrdinate 5 of 66
#
# Cruising Coordrdinate 6 of 66
#
# Cruising Coordrdinate 7 of 66
#
# Cruising Coordrdinate 8 of 66
#
# Cruising Coordrdinate 9 of 66
#
# Cruising Coordrdinate 10 of 66
#
# Cruising Coordrdinate 11 of 66
#
# Cruising Coordrdinate 12 of 66
#
# Cruising Coordrdinate 13 of 66
#
# Cruising Coordrdinate 14 of 66
#
# Cruising Coordrdinate 15 of 66
#
# Cruising Coordrdinate 16 of 66
#
# Cruising Coordrdinate 17 of 66
#
# Cruising Coordrdinate 18 of 66
#
# Cruising Coordrdinate 19 of 66
#
# Cruising Coordrdinate 20 of 66
#
# Cruising Coordrdinate 21 of 66
#
# Cruising Coordrdinate 22 of 66
#
# Cruising Coordrdinate 23 of 66
#
# Cruising Coordrdinate 24 of 66
#
# Cruising Coordrdinate 25 of 66
#
# Cruising Coordrdinate 26 of 66
#
# Cruising Coordrdinate 27 of 66
#
# Cruising Coordrdinate 28 of 66
#
# Cruising Coordrdinate 29 of 66
#
# Cruising Coordrdinate 30 of 66
#
# Cruising Coordrdinate 31 of 66
#
# Cruising Coordrdinate 32 of 66
#
# Cruising Coordrdinate 33 of 66
#
# Cruising Coordrdinate 34 of 66
#
# Cruising Coordrdinate 35 of 66
#
# Cruising Coordrdinate 36 of 66
#
# Cruising Coordrdinate 37 of 66
#
# Cruise suspended due to suspicious case
# Guidance: round 1
#
# 	round 1 iteration:  0
#
# Trained and Tested combination 85 of 672, taking 0.02 seconds to get val score of 0.281:
#                 {'alpha': 0.001, 'fit_prior': True, 'features': 20},
#             Current best combo with val score 0.3108:
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
# Already Trained and Tested combination (val score of 0.281):
#             {'alpha': 0.0001, 'fit_prior': False, 'features': 20}
#             Current best combo (with val score 0.3108):
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
#         Has trained 85 of 672 combinations so far
# Trained and Tested combination 86 of 672, taking 0.01 seconds to get val score of 0.1312:
#                 {'alpha': 0.0001, 'fit_prior': True, 'features': 19},
#             Current best combo with val score 0.3108:
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
# Trained and Tested combination 87 of 672, taking 0.01 seconds to get val score of 0.2428:
#                 {'alpha': 0.0001, 'fit_prior': True, 'features': 21},
#             Current best combo with val score 0.3108:
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
# 	round 1 iteration:  1
#
# Already Trained and Tested combination (val score of 0.281):
#             {'alpha': 0.0001, 'fit_prior': True, 'features': 20}
#             Current best combo (with val score 0.3108):
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
#         Has trained 87 of 672 combinations so far
# Trained and Tested combination 88 of 672, taking 0.01 seconds to get val score of 0.281:
#                 {'alpha': 0.01, 'fit_prior': True, 'features': 20},
#             Current best combo with val score 0.3108:
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
# Trained and Tested combination 89 of 672, taking 0.01 seconds to get val score of 0.281:
#                 {'alpha': 0.001, 'fit_prior': False, 'features': 20},
#             Current best combo with val score 0.3108:
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
# Trained and Tested combination 90 of 672, taking 0.01 seconds to get val score of 0.1312:
#                 {'alpha': 0.001, 'fit_prior': True, 'features': 19},
#             Current best combo with val score 0.3108:
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
# Trained and Tested combination 91 of 672, taking 0.01 seconds to get val score of 0.2428:
#                 {'alpha': 0.001, 'fit_prior': True, 'features': 21},
#             Current best combo with val score 0.3108:
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
# Already Trained and Tested combination (val score of 0.281):
#             {'alpha': 0.001, 'fit_prior': False, 'features': 20}
#             Current best combo (with val score 0.3108):
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
#         Has trained 91 of 672 combinations so far
# Already Trained and Tested combination (val score of 0.281):
#             {'alpha': 0.0001, 'fit_prior': True, 'features': 20}
#             Current best combo (with val score 0.3108):
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
#         Has trained 91 of 672 combinations so far
# Trained and Tested combination 92 of 672, taking 0.01 seconds to get val score of 0.1312:
#                 {'alpha': 0.0001, 'fit_prior': False, 'features': 19},
#             Current best combo with val score 0.3108:
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
# Trained and Tested combination 93 of 672, taking 0.01 seconds to get val score of 0.2428:
#                 {'alpha': 0.0001, 'fit_prior': False, 'features': 21},
#             Current best combo with val score 0.3108:
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
# % Combos Checked Thus Far: 93 out of 672 which is 13.839286000000001%
# Cruising Coordrdinate 38 of 66
#
# Cruise suspended due to suspicious case
# Guidance: round 2
#
# 	round 2 iteration:  0
#
# % Combos Checked Thus Far: 93 out of 672 which is 13.839286000000001%
# Cruising Coordrdinate 39 of 66
#
# Cruise suspended due to suspicious case
# Guidance: round 3
#
# 	round 3 iteration:  0
#
# Already Trained and Tested combination (val score of 0.281):
#             {'alpha': 0.01, 'fit_prior': True, 'features': 20}
#             Current best combo (with val score 0.3108):
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
#         Has trained 93 of 672 combinations so far
# Trained and Tested combination 94 of 672, taking 0.01 seconds to get val score of 0.2806:
#                 {'alpha': 1, 'fit_prior': True, 'features': 20},
#             Current best combo with val score 0.3108:
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
# Already Trained and Tested combination (val score of 0.281):
#             {'alpha': 0.1, 'fit_prior': False, 'features': 20}
#             Current best combo (with val score 0.3108):
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
#         Has trained 94 of 672 combinations so far
# Trained and Tested combination 95 of 672, taking 0.01 seconds to get val score of 0.1341:
#                 {'alpha': 0.1, 'fit_prior': True, 'features': 19},
#             Current best combo with val score 0.3108:
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
# Trained and Tested combination 96 of 672, taking 0.01 seconds to get val score of 0.2428:
#                 {'alpha': 0.1, 'fit_prior': True, 'features': 21},
#             Current best combo with val score 0.3108:
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
# 	round 3 iteration:  1
#
# Already Trained and Tested combination (val score of 0.281):
#             {'alpha': 0.1, 'fit_prior': True, 'features': 20}
#             Current best combo (with val score 0.3108):
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
#         Has trained 96 of 672 combinations so far
# Trained and Tested combination 97 of 672, taking 0.01 seconds to get val score of 0.2696:
#                 {'alpha': 10, 'fit_prior': True, 'features': 20},
#             Current best combo with val score 0.3108:
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
# Trained and Tested combination 98 of 672, taking 0.02 seconds to get val score of 0.2806:
#                 {'alpha': 1, 'fit_prior': False, 'features': 20},
#             Current best combo with val score 0.3108:
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
# Trained and Tested combination 99 of 672, taking 0.02 seconds to get val score of 0.1344:
#                 {'alpha': 1, 'fit_prior': True, 'features': 19},
#             Current best combo with val score 0.3108:
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
# Trained and Tested combination 100 of 672, taking 0.02 seconds to get val score of 0.2432:
#                 {'alpha': 1, 'fit_prior': True, 'features': 21},
#             Current best combo with val score 0.3108:
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
# Trained and Tested combination 101 of 672, taking 0.01 seconds to get val score of 0.281:
#                 {'alpha': 0.01, 'fit_prior': False, 'features': 20},
#             Current best combo with val score 0.3108:
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
# Already Trained and Tested combination (val score of 0.2806):
#             {'alpha': 1, 'fit_prior': False, 'features': 20}
#             Current best combo (with val score 0.3108):
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
#         Has trained 101 of 672 combinations so far
# Already Trained and Tested combination (val score of 0.281):
#             {'alpha': 0.1, 'fit_prior': True, 'features': 20}
#             Current best combo (with val score 0.3108):
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
#         Has trained 101 of 672 combinations so far
# Trained and Tested combination 102 of 672, taking 0.01 seconds to get val score of 0.1341:
#                 {'alpha': 0.1, 'fit_prior': False, 'features': 19},
#             Current best combo with val score 0.3108:
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
# Trained and Tested combination 103 of 672, taking 0.01 seconds to get val score of 0.2428:
#                 {'alpha': 0.1, 'fit_prior': False, 'features': 21},
#             Current best combo with val score 0.3108:
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
# % Combos Checked Thus Far: 103 out of 672 which is 15.327381%
# Cruising Coordrdinate 40 of 66
#
# Cruise suspended due to suspicious case
# Guidance: round 4
#
# 	round 4 iteration:  0
#
# % Combos Checked Thus Far: 103 out of 672 which is 15.327381%
# Cruising Coordrdinate 41 of 66
#
# Cruise suspended due to suspicious case
# Guidance: round 5
#
# 	round 5 iteration:  0
#
# Already Trained and Tested combination (val score of 0.2696):
#             {'alpha': 10, 'fit_prior': True, 'features': 20}
#             Current best combo (with val score 0.3108):
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
#         Has trained 103 of 672 combinations so far
# Already Trained and Tested combination (val score of 0.2678):
#             {'alpha': 100, 'fit_prior': False, 'features': 20}
#             Current best combo (with val score 0.3108):
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
#         Has trained 103 of 672 combinations so far
# Trained and Tested combination 104 of 672, taking 0.01 seconds to get val score of 0.0781:
#                 {'alpha': 100, 'fit_prior': True, 'features': 19},
#             Current best combo with val score 0.3108:
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
# Trained and Tested combination 105 of 672, taking 0.01 seconds to get val score of 0.2311:
#                 {'alpha': 100, 'fit_prior': True, 'features': 21},
#             Current best combo with val score 0.3108:
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
# 	round 5 iteration:  1
#
# Already Trained and Tested combination (val score of 0.2806):
#             {'alpha': 1, 'fit_prior': True, 'features': 20}
#             Current best combo (with val score 0.3108):
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
#         Has trained 105 of 672 combinations so far
# Already Trained and Tested combination (val score of 0.2678):
#             {'alpha': 100, 'fit_prior': True, 'features': 20}
#             Current best combo (with val score 0.3108):
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
#         Has trained 105 of 672 combinations so far
# Trained and Tested combination 106 of 672, taking 0.01 seconds to get val score of 0.2696:
#                 {'alpha': 10, 'fit_prior': False, 'features': 20},
#             Current best combo with val score 0.3108:
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
# Trained and Tested combination 107 of 672, taking 0.01 seconds to get val score of 0.1348:
#                 {'alpha': 10, 'fit_prior': True, 'features': 19},
#             Current best combo with val score 0.3108:
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
# Trained and Tested combination 108 of 672, taking 0.01 seconds to get val score of 0.2321:
#                 {'alpha': 10, 'fit_prior': True, 'features': 21},
#             Current best combo with val score 0.3108:
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
# Already Trained and Tested combination (val score of 0.2696):
#             {'alpha': 10, 'fit_prior': False, 'features': 20}
#             Current best combo (with val score 0.3108):
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
#         Has trained 108 of 672 combinations so far
# Already Trained and Tested combination (val score of 0.2678):
#             {'alpha': 100, 'fit_prior': True, 'features': 20}
#             Current best combo (with val score 0.3108):
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
#         Has trained 108 of 672 combinations so far
# Trained and Tested combination 109 of 672, taking 0.01 seconds to get val score of 0.0781:
#                 {'alpha': 100, 'fit_prior': False, 'features': 19},
#             Current best combo with val score 0.3108:
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
# Trained and Tested combination 110 of 672, taking 0.01 seconds to get val score of 0.2311:
#                 {'alpha': 100, 'fit_prior': False, 'features': 21},
#             Current best combo with val score 0.3108:
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
# % Combos Checked Thus Far: 110 out of 672 which is 16.369048%
# Cruising Coordrdinate 42 of 66
#
# Cruise suspended due to suspicious case
# Guidance: round 6
#
# 	round 6 iteration:  0
#
# % Combos Checked Thus Far: 110 out of 672 which is 16.369048%
# Cruising Coordrdinate 43 of 66
#
# Cruise suspended due to suspicious case
# Guidance: round 7
#
# 	round 7 iteration:  0
#
# Trained and Tested combination 111 of 672, taking 0.01 seconds to get val score of 0.1669:
#                 {'alpha': 0.001, 'fit_prior': True, 'features': 15},
#             Current best combo with val score 0.3108:
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
# Already Trained and Tested combination (val score of 0.1669):
#             {'alpha': 0.0001, 'fit_prior': False, 'features': 15}
#             Current best combo (with val score 0.3108):
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
#         Has trained 111 of 672 combinations so far
# Trained and Tested combination 112 of 672, taking 0.01 seconds to get val score of 0.1744:
#                 {'alpha': 0.0001, 'fit_prior': True, 'features': 14},
#             Current best combo with val score 0.3108:
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
# Trained and Tested combination 113 of 672, taking 0.01 seconds to get val score of 0.1845:
#                 {'alpha': 0.0001, 'fit_prior': True, 'features': 16},
#             Current best combo with val score 0.3108:
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
# 	round 7 iteration:  1
#
# Already Trained and Tested combination (val score of 0.1669):
#             {'alpha': 0.0001, 'fit_prior': True, 'features': 15}
#             Current best combo (with val score 0.3108):
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
#         Has trained 113 of 672 combinations so far
# Trained and Tested combination 114 of 672, taking 0.02 seconds to get val score of 0.1669:
#                 {'alpha': 0.01, 'fit_prior': True, 'features': 15},
#             Current best combo with val score 0.3108:
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
# Trained and Tested combination 115 of 672, taking 0.02 seconds to get val score of 0.1669:
#                 {'alpha': 0.001, 'fit_prior': False, 'features': 15},
#             Current best combo with val score 0.3108:
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
# Trained and Tested combination 116 of 672, taking 0.02 seconds to get val score of 0.1744:
#                 {'alpha': 0.001, 'fit_prior': True, 'features': 14},
#             Current best combo with val score 0.3108:
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
# Trained and Tested combination 117 of 672, taking 0.02 seconds to get val score of 0.1845:
#                 {'alpha': 0.001, 'fit_prior': True, 'features': 16},
#             Current best combo with val score 0.3108:
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
# Already Trained and Tested combination (val score of 0.1669):
#             {'alpha': 0.001, 'fit_prior': False, 'features': 15}
#             Current best combo (with val score 0.3108):
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
#         Has trained 117 of 672 combinations so far
# Already Trained and Tested combination (val score of 0.1669):
#             {'alpha': 0.0001, 'fit_prior': True, 'features': 15}
#             Current best combo (with val score 0.3108):
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
#         Has trained 117 of 672 combinations so far
# Trained and Tested combination 118 of 672, taking 0.01 seconds to get val score of 0.1744:
#                 {'alpha': 0.0001, 'fit_prior': False, 'features': 14},
#             Current best combo with val score 0.3108:
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
# Trained and Tested combination 119 of 672, taking 0.01 seconds to get val score of 0.1845:
#                 {'alpha': 0.0001, 'fit_prior': False, 'features': 16},
#             Current best combo with val score 0.3108:
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
# Already Trained and Tested combination (val score of 0.1744):
#             {'alpha': 0.001, 'fit_prior': True, 'features': 14}
#             Current best combo (with val score 0.3108):
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
#         Has trained 119 of 672 combinations so far
# Already Trained and Tested combination (val score of 0.1744):
#             {'alpha': 0.0001, 'fit_prior': False, 'features': 14}
#             Current best combo (with val score 0.3108):
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
#         Has trained 119 of 672 combinations so far
# ...
# Trained and Tested combination 164 of 672, taking 0.01 seconds to get val score of 0.2644:
#                 {'alpha': 10, 'fit_prior': True, 'features': 5},
#             Current best combo with val score 0.3108:
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
# Trained and Tested combination 165 of 672, taking 0.01 seconds to get val score of 0.2643:
#                 {'alpha': 1, 'fit_prior': False, 'features': 5},
#             Current best combo with val score 0.3108:
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
# Trained and Tested combination 166 of 672, taking 0.01 seconds to get val score of 0.2635:
#                 {'alpha': 1, 'fit_prior': True, 'features': 4},
#             Current best combo with val score 0.3108:
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
# Trained and Tested combination 167 of 672, taking 0.03 seconds to get val score of 0.2555:
#                 {'alpha': 1, 'fit_prior': True, 'features': 6},
#             Current best combo with val score 0.3108:
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
# Trained and Tested combination 168 of 672, taking 0.01 seconds to get val score of 0.2672:
#                 {'alpha': 0.01, 'fit_prior': False, 'features': 5},
#             Current best combo with val score 0.3108:
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
# Already Trained and Tested combination (val score of 0.2643):
#             {'alpha': 1, 'fit_prior': False, 'features': 5}
#             Current best combo (with val score 0.3108):
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
#         Has trained 168 of 672 combinations so far
# Already Trained and Tested combination (val score of 0.2672):
#             {'alpha': 0.1, 'fit_prior': True, 'features': 5}
#             Current best combo (with val score 0.3108):
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
#         Has trained 168 of 672 combinations so far
# Trained and Tested combination 169 of 672, taking 0.01 seconds to get val score of 0.2653:
#                 {'alpha': 0.1, 'fit_prior': False, 'features': 4},
#             Current best combo with val score 0.3108:
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
# Trained and Tested combination 170 of 672, taking 0.01 seconds to get val score of 0.2584:
#                 {'alpha': 0.1, 'fit_prior': False, 'features': 6},
#             Current best combo with val score 0.3108:
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
# Trained and Tested combination 171 of 672, taking 0.01 seconds to get val score of 0.2653:
#                 {'alpha': 0.01, 'fit_prior': True, 'features': 4},
#             Current best combo with val score 0.3108:
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
# Already Trained and Tested combination (val score of 0.2635):
#             {'alpha': 1, 'fit_prior': True, 'features': 4}
#             Current best combo (with val score 0.3108):
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
#         Has trained 171 of 672 combinations so far
# Already Trained and Tested combination (val score of 0.2653):
#             {'alpha': 0.1, 'fit_prior': False, 'features': 4}
#             Current best combo (with val score 0.3108):
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
#         Has trained 171 of 672 combinations so far
# Trained and Tested combination 172 of 672, taking 0.0 seconds to get val score of 0.0067:
#                 {'alpha': 0.1, 'fit_prior': True, 'features': 3},
#             Current best combo with val score 0.3108:
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
# Already Trained and Tested combination (val score of 0.2672):
#             {'alpha': 0.1, 'fit_prior': True, 'features': 5}
#             Current best combo (with val score 0.3108):
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
#         Has trained 172 of 672 combinations so far
# % Combos Checked Thus Far: 172 out of 672 which is 25.595238%
# Cruising Coordrdinate 60 of 66
#
# Cruise suspended due to suspicious case
# Guidance: round 18
#
# 	round 18 iteration:  0
#
# % Combos Checked Thus Far: 172 out of 672 which is 25.595238%
# Cruising Coordrdinate 61 of 66
#
# Cruise suspended due to suspicious case
# Guidance: round 19
#
# 	round 19 iteration:  0
#
# Already Trained and Tested combination (val score of 0.2644):
#             {'alpha': 10, 'fit_prior': True, 'features': 5}
#             Current best combo (with val score 0.3108):
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
#         Has trained 172 of 672 combinations so far
# Already Trained and Tested combination (val score of 0.243):
#             {'alpha': 100, 'fit_prior': False, 'features': 5}
#             Current best combo (with val score 0.3108):
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
#         Has trained 172 of 672 combinations so far
# Trained and Tested combination 173 of 672, taking 0.01 seconds to get val score of 0.2423:
#                 {'alpha': 100, 'fit_prior': True, 'features': 4},
#             Current best combo with val score 0.3108:
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
# Trained and Tested combination 174 of 672, taking 0.01 seconds to get val score of 0.243:
#                 {'alpha': 100, 'fit_prior': True, 'features': 6},
#             Current best combo with val score 0.3108:
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
# 	round 19 iteration:  1
#
# Trained and Tested combination 175 of 672, taking 0.01 seconds to get val score of 0.2644:
#                 {'alpha': 10, 'fit_prior': False, 'features': 5},
#             Current best combo with val score 0.3108:
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
# Already Trained and Tested combination (val score of 0.243):
#             {'alpha': 100, 'fit_prior': True, 'features': 5}
#             Current best combo (with val score 0.3108):
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
#         Has trained 175 of 672 combinations so far
# Trained and Tested combination 176 of 672, taking 0.01 seconds to get val score of 0.2423:
#                 {'alpha': 100, 'fit_prior': False, 'features': 4},
#             Current best combo with val score 0.3108:
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
# Trained and Tested combination 177 of 672, taking 0.01 seconds to get val score of 0.243:
#                 {'alpha': 100, 'fit_prior': False, 'features': 6},
#             Current best combo with val score 0.3108:
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
# Trained and Tested combination 178 of 672, taking 0.01 seconds to get val score of 0.2645:
#                 {'alpha': 10, 'fit_prior': True, 'features': 4},
#             Current best combo with val score 0.3108:
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
# Already Trained and Tested combination (val score of 0.2423):
#             {'alpha': 100, 'fit_prior': False, 'features': 4}
#             Current best combo (with val score 0.3108):
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
#         Has trained 178 of 672 combinations so far
# Trained and Tested combination 179 of 672, taking 0.0 seconds to get val score of 0.0067:
#                 {'alpha': 100, 'fit_prior': True, 'features': 3},
#             Current best combo with val score 0.3108:
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
# Already Trained and Tested combination (val score of 0.243):
#             {'alpha': 100, 'fit_prior': True, 'features': 5}
#             Current best combo (with val score 0.3108):
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
#         Has trained 179 of 672 combinations so far
# Trained and Tested combination 180 of 672, taking 0.01 seconds to get val score of 0.2609:
#                 {'alpha': 10, 'fit_prior': True, 'features': 6},
#             Current best combo with val score 0.3108:
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
# Already Trained and Tested combination (val score of 0.243):
#             {'alpha': 100, 'fit_prior': False, 'features': 6}
#             Current best combo (with val score 0.3108):
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
#         Has trained 180 of 672 combinations so far
# Already Trained and Tested combination (val score of 0.243):
#             {'alpha': 100, 'fit_prior': True, 'features': 5}
#             Current best combo (with val score 0.3108):
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
#         Has trained 180 of 672 combinations so far
# Trained and Tested combination 181 of 672, taking 0.02 seconds to get val score of 0.243:
#                 {'alpha': 100, 'fit_prior': True, 'features': 7},
#             Current best combo with val score 0.3108:
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
# % Combos Checked Thus Far: 181 out of 672 which is 26.934524%
# Cruising Coordrdinate 62 of 66
#
# Cruise suspended due to suspicious case
# Guidance: round 20
#
# 	round 20 iteration:  0
#
# % Combos Checked Thus Far: 181 out of 672 which is 26.934524%
# Cruising Coordrdinate 63 of 66
#
# Cruise suspended due to suspicious case
# Guidance: round 21
#
# 	round 21 iteration:  0
#
# Already Trained and Tested combination (val score of 0.3108):
#             {'alpha': 0.01, 'fit_prior': True, 'features': 0}
#             Current best combo (with val score 0.3108):
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
#         Has trained 181 of 672 combinations so far
# Trained and Tested combination 182 of 672, taking 0.0 seconds to get val score of 0.3108:
#                 {'alpha': 1, 'fit_prior': True, 'features': 0},
#             Current best combo with val score 0.3108:
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
# Already Trained and Tested combination (val score of 0.3108):
#             {'alpha': 0.1, 'fit_prior': False, 'features': 0}
#             Current best combo (with val score 0.3108):
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
#         Has trained 182 of 672 combinations so far
# Trained and Tested combination 183 of 672, taking 0.0 seconds to get val score of 0.0067:
#                 {'alpha': 0.1, 'fit_prior': True, 'features': 1},
#             Current best combo with val score 0.3108:
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
# 	round 21 iteration:  1
#
# Already Trained and Tested combination (val score of 0.3108):
#             {'alpha': 0.1, 'fit_prior': True, 'features': 0}
#             Current best combo (with val score 0.3108):
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
#         Has trained 183 of 672 combinations so far
# Trained and Tested combination 184 of 672, taking 0.0 seconds to get val score of 0.3108:
#                 {'alpha': 10, 'fit_prior': True, 'features': 0},
#             Current best combo with val score 0.3108:
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
# Trained and Tested combination 185 of 672, taking 0.0 seconds to get val score of 0.3108:
#                 {'alpha': 1, 'fit_prior': False, 'features': 0},
#             Current best combo with val score 0.3108:
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
# Trained and Tested combination 186 of 672, taking 0.01 seconds to get val score of 0.0067:
#                 {'alpha': 1, 'fit_prior': True, 'features': 1},
#             Current best combo with val score 0.3108:
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
# Trained and Tested combination 187 of 672, taking 0.0 seconds to get val score of 0.3108:
#                 {'alpha': 0.01, 'fit_prior': False, 'features': 0},
#             Current best combo with val score 0.3108:
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
# Already Trained and Tested combination (val score of 0.3108):
#             {'alpha': 1, 'fit_prior': False, 'features': 0}
#             Current best combo (with val score 0.3108):
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
#         Has trained 187 of 672 combinations so far
# Already Trained and Tested combination (val score of 0.3108):
#             {'alpha': 0.1, 'fit_prior': True, 'features': 0}
#             Current best combo (with val score 0.3108):
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
#         Has trained 187 of 672 combinations so far
# Trained and Tested combination 188 of 672, taking 0.01 seconds to get val score of 0.0067:
#                 {'alpha': 0.1, 'fit_prior': False, 'features': 1},
#             Current best combo with val score 0.3108:
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
# % Combos Checked Thus Far: 188 out of 672 which is 27.976190000000003%
# Cruising Coordrdinate 64 of 66
#
# Cruise suspended due to suspicious case
# Guidance: round 22
#
# 	round 22 iteration:  0
#
# % Combos Checked Thus Far: 188 out of 672 which is 27.976190000000003%
# Cruising Coordrdinate 65 of 66
#
# Cruise suspended due to suspicious case
# Guidance: round 23
#
# 	round 23 iteration:  0
#
# Already Trained and Tested combination (val score of 0.3108):
#             {'alpha': 10, 'fit_prior': True, 'features': 0}
#             Current best combo (with val score 0.3108):
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
#         Has trained 188 of 672 combinations so far
# Already Trained and Tested combination (val score of 0.3108):
#             {'alpha': 100, 'fit_prior': False, 'features': 0}
#             Current best combo (with val score 0.3108):
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
#         Has trained 188 of 672 combinations so far
# Trained and Tested combination 189 of 672, taking 0.01 seconds to get val score of 0.0067:
#                 {'alpha': 100, 'fit_prior': True, 'features': 1},
#             Current best combo with val score 0.3108:
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
# 	round 23 iteration:  1
#
# Already Trained and Tested combination (val score of 0.3108):
#             {'alpha': 10, 'fit_prior': False, 'features': 0}
#             Current best combo (with val score 0.3108):
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
#         Has trained 189 of 672 combinations so far
# Already Trained and Tested combination (val score of 0.3108):
#             {'alpha': 100, 'fit_prior': True, 'features': 0}
#             Current best combo (with val score 0.3108):
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
#         Has trained 189 of 672 combinations so far
# Already Trained and Tested combination (val score of 0.0067):
#             {'alpha': 100, 'fit_prior': False, 'features': 1}
#             Current best combo (with val score 0.3108):
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
#         Has trained 189 of 672 combinations so far
# % Combos Checked Thus Far: 189 out of 672 which is 28.125%
# Cruising Coordrdinate 66 of 66
#
# Cruise suspended due to suspicious case
# Guidance: round 24
#
# 	round 24 iteration:  0
#
# % Combos Checked Thus Far: 189 out of 672 which is 28.125%
# FINAL STAGE: Begin final Guidance system
#
#
# Guidance: round FINAL
#
# 	round FINAL iteration:  0
#
# % Combos Checked Thus Far: 189 out of 672 which is 28.125%
# Max Val Score:
#  0.310811
# Max Val Score Std:
#  0.016704
# Best Combo Train Score:
#  0.691408
# Best Combo Train Score Std:
#  0.001442
# Max Combo Index:
#  (6, 0, 0) out of [7, 2, 48] (note best combo is 0-indexed)
# Max Combo Hyperparamer Combination:
#  {'alpha': 100, 'fit_prior': False, 'features': 0}
# Max Combo Features:
#  ('procedure_224274',)
# % Combos Checked: 189 out of 672 which is 28.125%
