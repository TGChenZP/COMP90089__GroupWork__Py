# %% [markdown]
# # Tuning Script

# %%
# Parameters subject to change in every script - involved in naming

MODEL = 'extrfc'
PREPROCESSING = 'smote_normalise'
TUNER = 'yangzhoub'
OPTIMISED_METRIC = 'f1'

# %% [markdown]
# ---

# %%
# detect whether this is a google environment

COLAB_ENVIRONMENT = False

try:
    from google.colab import drive
    drive.mount('/content/drive')
    COLAB_ENVIRONMENT = True
except:
    pass
# Out:
# Mounted at /content/drive

# %%
import sys
import os
import pickle

if COLAB_ENVIRONMENT:
    home_directory = './drive/MyDrive/LAB/COMP90089__GroupWork__Py/' # my home directory is stored in ./LAB of google drive
    if MODEL == 'ebr':
        # !pip install interpret==0.5.0
    elif MODEL == 'cbr':
        # !pip install catboost
    elif MODEL in ['tf', 'mlp']:
        # !pip install PyTorch2Sklearn
    # !pip install JXAutoML
else:
    home_directory = '../../'

from JXAutoML.YangZhouB_10CV import YangZhouB_10CV as Tuner

import pandas as pd
# Out:
# Collecting JXAutoML
#   Downloading JXAutoML-0.4.4-py3-none-any.whl.metadata (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.2/67.2 kB 1.8 MB/s eta 0:00:00
# Downloading JXAutoML-0.4.4-py3-none-any.whl (52 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.1/52.1 kB 3.7 MB/s eta 0:00:00
# Installing collected packages: JXAutoML
# Successfully installed JXAutoML-0.4.4

# %%
# Parameters that are same for every script

FOLDS = 10  # we have decided to do 10 fold validation

SEED = 42

TASK_TYPE = 'Classification'  # this task is a classification task

# we have decided to tune features as hp
TUNE_FEATURES_AS_HYPERPARAMETERS = True

# %% [markdown]
# ---

# %%
# model to use to tune
from sklearn.ensemble import ExtraTreesClassifier as clf

# what values to try for each hyperparameter
parameter_choices = {
    'n_estimators': (25, 50, 100, 200, 400, 800),
    'max_depth': (3, 6, 12, 24, 48, 96, 192),
    'max_samples': (0.4, 0.55, 0.7, 0.85, 1),
    'max_features': (0.4, 0.55, 0.7, 0.85, 1),
    'ccp_alpha': (0.00000001, 0.000001, 0.0001, 0.01, 0.1)
}

# what values to set non-tuneable parameters/hyperparameters
non_tunable_hyperparameters_dict = {
                                    'random_state': SEED,
                                    'n_jobs': -1,
                                    'bootstrap': True
                                    }

# %% [markdown]
# ---

# %% [markdown]
# Read in and Prepare Data

# %%
# Import data and store as lists

train_x_list = []
train_y_list = []
val_x_list = []
val_y_list = []

for i in range(FOLDS):
    train_data = pd.read_csv(
        f'{home_directory}data/curated/modelling/{PREPROCESSING}/train_{i}.csv')
    val_data = pd.read_csv(
        f'{home_directory}data/curated/modelling/{PREPROCESSING}/val_{i}.csv')

    # get the correct rows for X and y
    train_x = train_data.drop(
        ['mortality_status', 'subject_id', 'hadm_id', 'stay_id'], axis=1)
    train_y = train_data['mortality_status']
    val_x = val_data.drop(
        ['mortality_status', 'subject_id', 'hadm_id', 'stay_id'], axis=1)
    val_y = val_data['mortality_status']

    train_x_list.append(train_x)
    train_y_list.append(train_y)
    val_x_list.append(val_x)
    val_y_list.append(val_y)

# %%
# Import feature importance ordering

with open(f'{home_directory}models/xgb_feature_importance_ordering_{PREPROCESSING}.pickle', 'rb') as f:
    feature_importance_ordering = pickle.load(f)

# %% [markdown]
# Set parameters

# %%
# initialisation
tuner = Tuner()

print('---')

# define what model we are tuning
tuner.read_in_model(clf, TASK_TYPE, optimised_metric=OPTIMISED_METRIC)

print('---')

# read in the data for training and validation
tuner.read_in_data(train_x_list, train_y_list, val_x_list, val_y_list)

print('---')

# set what hp values to tune
tuner.set_hyperparameters(parameter_choices)
# WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

# set up hp values that need to be changed from default but NOT to be tuned
tuner.set_non_tuneable_hyperparameters(non_tunable_hyperparameters_dict)

print('---')

# set up feature importance ordering

if TUNE_FEATURES_AS_HYPERPARAMETERS:
    tuner.set_features(feature_importance_ordering)
    # WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

try:  # try to read in previous results to continue tuning ...
    tuner.read_in_tuning_result_df(
        f'{home_directory}models/tuning/{TUNER}_{MODEL}_{PREPROCESSING}.csv')
except:
    print('No previous tuning data read in')

print('---')

# set up where to save the tuning result csv
tuner.set_tuning_result_saving_address(
    f'{home_directory}models/tuning/{TUNER}_{MODEL}_{PREPROCESSING}.csv')

print('---')

# set up where to save the current best model
tuner.set_best_model_saving_address(
    f'{home_directory}models/tmp_models/{TUNER}_{MODEL}_{PREPROCESSING}')
# Out:
# YangZhouB Initialised
# ---
# Successfully read in model <class 'sklearn.ensemble._forest.ExtraTreesClassifier'>, which is a Classification model optimising for f1
# ---
# Read in Train X data list
# Read in Train y data list
# Read in Val X data list
# Read in Val y data list
# ---
# Successfully recorded hyperparameter choices
# ---
# Successfully recorded non_tuneable_hyperparameter choices
# ---
# Successfully recorded tuneable feature combination choices and updated relevant internal structures
# ---
# Successfully read in tuning result of 1046 rows, for 1046.0 combos
# ---
# Successfully set tuning output address
# ---
# Successfully set best model output address

# %%
# ignore warnings

import warnings
warnings.filterwarnings("ignore")

# %%
# begin tuning ... (or continue training)

tuner.tune()
# Out:
# Streaming output truncated to the last 5000 lines.
#             {'n_estimators': 100, 'max_depth': 12, 'max_samples': 0.7, 'max_features': 0.7, 'ccp_alpha': 0.0001, 'features': 25}
#             Current best combo (with val score 0.3503):
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1046 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.0485):
#             {'n_estimators': 400, 'max_depth': 12, 'max_samples': 0.7, 'max_features': 0.7, 'ccp_alpha': 0.0001, 'features': 25}
#             Current best combo (with val score 0.3503):
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1046 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.181):
#             {'n_estimators': 200, 'max_depth': 6, 'max_samples': 0.7, 'max_features': 0.7, 'ccp_alpha': 0.0001, 'features': 25}
#             Current best combo (with val score 0.3503):
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1046 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.0449):
#             {'n_estimators': 200, 'max_depth': 24, 'max_samples': 0.7, 'max_features': 0.7, 'ccp_alpha': 0.0001, 'features': 25}
#             Current best combo (with val score 0.3503):
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1046 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.0388):
#             {'n_estimators': 200, 'max_depth': 12, 'max_samples': 0.55, 'max_features': 0.7, 'ccp_alpha': 0.0001, 'features': 25}
#             Current best combo (with val score 0.3503):
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1046 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.0353):
#             {'n_estimators': 200, 'max_depth': 12, 'max_samples': 0.85, 'max_features': 0.7, 'ccp_alpha': 0.0001, 'features': 25}
#             Current best combo (with val score 0.3503):
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1046 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.0443):
#             {'n_estimators': 200, 'max_depth': 12, 'max_samples': 0.7, 'max_features': 0.55, 'ccp_alpha': 0.0001, 'features': 25}
#             Current best combo (with val score 0.3503):
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1046 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.0424):
#             {'n_estimators': 200, 'max_depth': 12, 'max_samples': 0.7, 'max_features': 0.85, 'ccp_alpha': 0.0001, 'features': 25}
#             Current best combo (with val score 0.3503):
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1046 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.0452):
#             {'n_estimators': 200, 'max_depth': 12, 'max_samples': 0.7, 'max_features': 0.7, 'ccp_alpha': 1e-06, 'features': 25}
#             Current best combo (with val score 0.3503):
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1046 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.3127):
#             {'n_estimators': 200, 'max_depth': 12, 'max_samples': 0.7, 'max_features': 0.7, 'ccp_alpha': 0.01, 'features': 25}
#             Current best combo (with val score 0.3503):
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1046 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.0231):
#             {'n_estimators': 200, 'max_depth': 12, 'max_samples': 0.7, 'max_features': 0.7, 'ccp_alpha': 0.0001, 'features': 24}
#             Current best combo (with val score 0.3503):
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1046 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.0418):
#             {'n_estimators': 200, 'max_depth': 12, 'max_samples': 0.7, 'max_features': 0.7, 'ccp_alpha': 0.0001, 'features': 26}
#             Current best combo (with val score 0.3503):
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1046 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.0453):
#             {'n_estimators': 100, 'max_depth': 48, 'max_samples': 0.7, 'max_features': 0.7, 'ccp_alpha': 0.0001, 'features': 25}
#             Current best combo (with val score 0.3503):
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1046 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.0482):
#             {'n_estimators': 400, 'max_depth': 48, 'max_samples': 0.7, 'max_features': 0.7, 'ccp_alpha': 0.0001, 'features': 25}
#             Current best combo (with val score 0.3503):
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1046 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.0449):
#             {'n_estimators': 200, 'max_depth': 24, 'max_samples': 0.7, 'max_features': 0.7, 'ccp_alpha': 0.0001, 'features': 25}
#             Current best combo (with val score 0.3503):
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1046 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.0445):
#             {'n_estimators': 200, 'max_depth': 96, 'max_samples': 0.7, 'max_features': 0.7, 'ccp_alpha': 0.0001, 'features': 25}
#             Current best combo (with val score 0.3503):
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1046 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.0421):
#             {'n_estimators': 200, 'max_depth': 48, 'max_samples': 0.55, 'max_features': 0.7, 'ccp_alpha': 0.0001, 'features': 25}
#             Current best combo (with val score 0.3503):
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1046 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.0575):
#             {'n_estimators': 200, 'max_depth': 48, 'max_samples': 0.85, 'max_features': 0.7, 'ccp_alpha': 0.0001, 'features': 25}
#             Current best combo (with val score 0.3503):
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1046 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.0478):
#             {'n_estimators': 200, 'max_depth': 48, 'max_samples': 0.7, 'max_features': 0.55, 'ccp_alpha': 0.0001, 'features': 25}
#             Current best combo (with val score 0.3503):
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1046 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.0552):
#             {'n_estimators': 200, 'max_depth': 48, 'max_samples': 0.7, 'max_features': 0.85, 'ccp_alpha': 0.0001, 'features': 25}
#             Current best combo (with val score 0.3503):
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1046 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.0445):
#             {'n_estimators': 200, 'max_depth': 48, 'max_samples': 0.7, 'max_features': 0.7, 'ccp_alpha': 1e-06, 'features': 25}
#             Current best combo (with val score 0.3503):
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1046 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.3127):
#             {'n_estimators': 200, 'max_depth': 48, 'max_samples': 0.7, 'max_features': 0.7, 'ccp_alpha': 0.01, 'features': 25}
#             Current best combo (with val score 0.3503):
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1046 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.01):
#             {'n_estimators': 200, 'max_depth': 48, 'max_samples': 0.7, 'max_features': 0.7, 'ccp_alpha': 0.0001, 'features': 24}
#             Current best combo (with val score 0.3503):
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1046 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.0285):
#             {'n_estimators': 200, 'max_depth': 48, 'max_samples': 0.7, 'max_features': 0.7, 'ccp_alpha': 0.0001, 'features': 26}
#             Current best combo (with val score 0.3503):
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1046 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.0388):
#             {'n_estimators': 100, 'max_depth': 24, 'max_samples': 0.55, 'max_features': 0.7, 'ccp_alpha': 0.0001, 'features': 25}
#             Current best combo (with val score 0.3503):
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1046 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.0226):
#             {'n_estimators': 400, 'max_depth': 24, 'max_samples': 0.55, 'max_features': 0.7, 'ccp_alpha': 0.0001, 'features': 25}
#             Current best combo (with val score 0.3503):
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1046 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.0388):
#             {'n_estimators': 200, 'max_depth': 12, 'max_samples': 0.55, 'max_features': 0.7, 'ccp_alpha': 0.0001, 'features': 25}
#             Current best combo (with val score 0.3503):
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1046 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.0421):
#             {'n_estimators': 200, 'max_depth': 48, 'max_samples': 0.55, 'max_features': 0.7, 'ccp_alpha': 0.0001, 'features': 25}
#             Current best combo (with val score 0.3503):
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1046 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.0442):
#             {'n_estimators': 200, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.7, 'ccp_alpha': 0.0001, 'features': 25}
#             Current best combo (with val score 0.3503):
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1046 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.0449):
#             {'n_estimators': 200, 'max_depth': 24, 'max_samples': 0.7, 'max_features': 0.7, 'ccp_alpha': 0.0001, 'features': 25}
#             Current best combo (with val score 0.3503):
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1046 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.0417):
#             {'n_estimators': 200, 'max_depth': 24, 'max_samples': 0.55, 'max_features': 0.55, 'ccp_alpha': 0.0001, 'features': 25}
#             Current best combo (with val score 0.3503):
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1046 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.0357):
#             {'n_estimators': 200, 'max_depth': 24, 'max_samples': 0.55, 'max_features': 0.85, 'ccp_alpha': 0.0001, 'features': 25}
#             Current best combo (with val score 0.3503):
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1046 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.0422):
#             {'n_estimators': 200, 'max_depth': 24, 'max_samples': 0.55, 'max_features': 0.7, 'ccp_alpha': 1e-06, 'features': 25}
#             Current best combo (with val score 0.3503):
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1046 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.3127):
#             {'n_estimators': 200, 'max_depth': 24, 'max_samples': 0.55, 'max_features': 0.7, 'ccp_alpha': 0.01, 'features': 25}
#             Current best combo (with val score 0.3503):
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1046 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.0165):
#             {'n_estimators': 200, 'max_depth': 24, 'max_samples': 0.55, 'max_features': 0.7, 'ccp_alpha': 0.0001, 'features': 24}
#             Current best combo (with val score 0.3503):
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1046 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.0319):
#             {'n_estimators': 200, 'max_depth': 24, 'max_samples': 0.55, 'max_features': 0.7, 'ccp_alpha': 0.0001, 'features': 26}
#             Current best combo (with val score 0.3503):
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1046 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.0543):
#             {'n_estimators': 100, 'max_depth': 24, 'max_samples': 0.85, 'max_features': 0.7, 'ccp_alpha': 0.0001, 'features': 25}
#             Current best combo (with val score 0.3503):
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1046 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.0422):
#             {'n_estimators': 400, 'max_depth': 24, 'max_samples': 0.85, 'max_features': 0.7, 'ccp_alpha': 0.0001, 'features': 25}
#             Current best combo (with val score 0.3503):
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1046 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.0353):
#             {'n_estimators': 200, 'max_depth': 12, 'max_samples': 0.85, 'max_features': 0.7, 'ccp_alpha': 0.0001, 'features': 25}
#             Current best combo (with val score 0.3503):
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1046 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.0575):
#             {'n_estimators': 200, 'max_depth': 48, 'max_samples': 0.85, 'max_features': 0.7, 'ccp_alpha': 0.0001, 'features': 25}
#             Current best combo (with val score 0.3503):
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1046 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.0449):
#             {'n_estimators': 200, 'max_depth': 24, 'max_samples': 0.7, 'max_features': 0.7, 'ccp_alpha': 0.0001, 'features': 25}
#             Current best combo (with val score 0.3503):
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1046 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.2805):
#             {'n_estimators': 200, 'max_depth': 24, 'max_samples': 1, 'max_features': 0.7, 'ccp_alpha': 0.0001, 'features': 25}
#             Current best combo (with val score 0.3503):
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1046 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.029):
#             {'n_estimators': 200, 'max_depth': 24, 'max_samples': 0.85, 'max_features': 0.55, 'ccp_alpha': 0.0001, 'features': 25}
#             Current best combo (with val score 0.3503):
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1046 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.0321):
#             {'n_estimators': 200, 'max_depth': 24, 'max_samples': 0.85, 'max_features': 0.85, 'ccp_alpha': 0.0001, 'features': 25}
#             Current best combo (with val score 0.3503):
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1046 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.0484):
#             {'n_estimators': 200, 'max_depth': 24, 'max_samples': 0.85, 'max_features': 0.7, 'ccp_alpha': 1e-06, 'features': 25}
#             Current best combo (with val score 0.3503):
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1046 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.3127):
#             {'n_estimators': 200, 'max_depth': 24, 'max_samples': 0.85, 'max_features': 0.7, 'ccp_alpha': 0.01, 'features': 25}
#             Current best combo (with val score 0.3503):
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1046 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.0165):
#             {'n_estimators': 200, 'max_depth': 24, 'max_samples': 0.85, 'max_features': 0.7, 'ccp_alpha': 0.0001, 'features': 24}
#             Current best combo (with val score 0.3503):
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1046 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.0384):
#             {'n_estimators': 200, 'max_depth': 24, 'max_samples': 0.85, 'max_features': 0.7, 'ccp_alpha': 0.0001, 'features': 26}
#             Current best combo (with val score 0.3503):
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1046 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.0608):
#             {'n_estimators': 100, 'max_depth': 24, 'max_samples': 0.7, 'max_features': 0.55, 'ccp_alpha': 0.0001, 'features': 25}
#             Current best combo (with val score 0.3503):
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1046 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.0422):
#             {'n_estimators': 400, 'max_depth': 24, 'max_samples': 0.7, 'max_features': 0.55, 'ccp_alpha': 0.0001, 'features': 25}
#             Current best combo (with val score 0.3503):
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1046 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.0443):
#             {'n_estimators': 200, 'max_depth': 12, 'max_samples': 0.7, 'max_features': 0.55, 'ccp_alpha': 0.0001, 'features': 25}
#             Current best combo (with val score 0.3503):
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1046 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.0478):
#             {'n_estimators': 200, 'max_depth': 48, 'max_samples': 0.7, 'max_features': 0.55, 'ccp_alpha': 0.0001, 'features': 25}
#             Current best combo (with val score 0.3503):
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1046 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.0417):
#             {'n_estimators': 200, 'max_depth': 24, 'max_samples': 0.55, 'max_features': 0.55, 'ccp_alpha': 0.0001, 'features': 25}
#             Current best combo (with val score 0.3503):
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1046 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.029):
#             {'n_estimators': 200, 'max_depth': 24, 'max_samples': 0.85, 'max_features': 0.55, 'ccp_alpha': 0.0001, 'features': 25}
#             Current best combo (with val score 0.3503):
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1046 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.0392):
#             {'n_estimators': 200, 'max_depth': 24, 'max_samples': 0.7, 'max_features': 0.4, 'ccp_alpha': 0.0001, 'features': 25}
#             Current best combo (with val score 0.3503):
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1046 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.0449):
#             {'n_estimators': 200, 'max_depth': 24, 'max_samples': 0.7, 'max_features': 0.7, 'ccp_alpha': 0.0001, 'features': 25}
#             Current best combo (with val score 0.3503):
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1046 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.0445):
#             {'n_estimators': 200, 'max_depth': 24, 'max_samples': 0.7, 'max_features': 0.55, 'ccp_alpha': 1e-06, 'features': 25}
#             Current best combo (with val score 0.3503):
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1046 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.3132):
#             {'n_estimators': 200, 'max_depth': 24, 'max_samples': 0.7, 'max_features': 0.55, 'ccp_alpha': 0.01, 'features': 25}
#             Current best combo (with val score 0.3503):
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1046 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.0099):
#             {'n_estimators': 200, 'max_depth': 24, 'max_samples': 0.7, 'max_features': 0.55, 'ccp_alpha': 0.0001, 'features': 24}
#             Current best combo (with val score 0.3503):
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1046 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.0572):
#             {'n_estimators': 200, 'max_depth': 24, 'max_samples': 0.7, 'max_features': 0.55, 'ccp_alpha': 0.0001, 'features': 26}
#             Current best combo (with val score 0.3503):
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1046 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.0688):
#             {'n_estimators': 100, 'max_depth': 24, 'max_samples': 0.7, 'max_features': 0.85, 'ccp_alpha': 0.0001, 'features': 25}
#             Current best combo (with val score 0.3503):
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1046 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.0507):
#             {'n_estimators': 400, 'max_depth': 24, 'max_samples': 0.7, 'max_features': 0.85, 'ccp_alpha': 0.0001, 'features': 25}
#             Current best combo (with val score 0.3503):
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1046 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.0424):
#             {'n_estimators': 200, 'max_depth': 12, 'max_samples': 0.7, 'max_features': 0.85, 'ccp_alpha': 0.0001, 'features': 25}
#             Current best combo (with val score 0.3503):
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1046 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.0552):
#             {'n_estimators': 200, 'max_depth': 48, 'max_samples': 0.7, 'max_features': 0.85, 'ccp_alpha': 0.0001, 'features': 25}
#             Current best combo (with val score 0.3503):
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1046 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.0357):
#             {'n_estimators': 200, 'max_depth': 24, 'max_samples': 0.55, 'max_features': 0.85, 'ccp_alpha': 0.0001, 'features': 25}
#             Current best combo (with val score 0.3503):
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1046 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.0321):
#             {'n_estimators': 200, 'max_depth': 24, 'max_samples': 0.85, 'max_features': 0.85, 'ccp_alpha': 0.0001, 'features': 25}
#             Current best combo (with val score 0.3503):
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1046 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.0449):
#             {'n_estimators': 200, 'max_depth': 24, 'max_samples': 0.7, 'max_features': 0.7, 'ccp_alpha': 0.0001, 'features': 25}
#             Current best combo (with val score 0.3503):
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1046 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.1053):
#             {'n_estimators': 200, 'max_depth': 24, 'max_samples': 0.7, 'max_features': 1, 'ccp_alpha': 0.0001, 'features': 25}
#             Current best combo (with val score 0.3503):
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1046 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.0648):
#             {'n_estimators': 200, 'max_depth': 24, 'max_samples': 0.7, 'max_features': 0.85, 'ccp_alpha': 1e-06, 'features': 25}
#             Current best combo (with val score 0.3503):
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1046 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.3127):
#             {'n_estimators': 200, 'max_depth': 24, 'max_samples': 0.7, 'max_features': 0.85, 'ccp_alpha': 0.01, 'features': 25}
#             Current best combo (with val score 0.3503):
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1046 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.0067):
#             {'n_estimators': 200, 'max_depth': 24, 'max_samples': 0.7, 'max_features': 0.85, 'ccp_alpha': 0.0001, 'features': 24}
#             Current best combo (with val score 0.3503):
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1046 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.0479):
#             {'n_estimators': 200, 'max_depth': 24, 'max_samples': 0.7, 'max_features': 0.85, 'ccp_alpha': 0.0001, 'features': 26}
#             Current best combo (with val score 0.3503):
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1046 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.0514):
#             {'n_estimators': 100, 'max_depth': 24, 'max_samples': 0.7, 'max_features': 0.7, 'ccp_alpha': 1e-06, 'features': 25}
#             Current best combo (with val score 0.3503):
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1046 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.0389):
#             {'n_estimators': 400, 'max_depth': 24, 'max_samples': 0.7, 'max_features': 0.7, 'ccp_alpha': 1e-06, 'features': 25}
#             Current best combo (with val score 0.3503):
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1046 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.0452):
#             {'n_estimators': 200, 'max_depth': 12, 'max_samples': 0.7, 'max_features': 0.7, 'ccp_alpha': 1e-06, 'features': 25}
#             Current best combo (with val score 0.3503):
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1046 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.0445):
#             {'n_estimators': 200, 'max_depth': 48, 'max_samples': 0.7, 'max_features': 0.7, 'ccp_alpha': 1e-06, 'features': 25}
#             Current best combo (with val score 0.3503):
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1046 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.0422):
#             {'n_estimators': 200, 'max_depth': 24, 'max_samples': 0.55, 'max_features': 0.7, 'ccp_alpha': 1e-06, 'features': 25}
#             Current best combo (with val score 0.3503):
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1046 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.0484):
#             {'n_estimators': 200, 'max_depth': 24, 'max_samples': 0.85, 'max_features': 0.7, 'ccp_alpha': 1e-06, 'features': 25}
#             Current best combo (with val score 0.3503):
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1046 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.0445):
#             {'n_estimators': 200, 'max_depth': 24, 'max_samples': 0.7, 'max_features': 0.55, 'ccp_alpha': 1e-06, 'features': 25}
#             Current best combo (with val score 0.3503):
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1046 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.0648):
#             {'n_estimators': 200, 'max_depth': 24, 'max_samples': 0.7, 'max_features': 0.85, 'ccp_alpha': 1e-06, 'features': 25}
#             Current best combo (with val score 0.3503):
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1046 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.0449):
#             {'n_estimators': 200, 'max_depth': 24, 'max_samples': 0.7, 'max_features': 0.7, 'ccp_alpha': 1e-08, 'features': 25}
#             Current best combo (with val score 0.3503):
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1046 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.0449):
#             {'n_estimators': 200, 'max_depth': 24, 'max_samples': 0.7, 'max_features': 0.7, 'ccp_alpha': 0.0001, 'features': 25}
#             Current best combo (with val score 0.3503):
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1046 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.0199):
#             {'n_estimators': 200, 'max_depth': 24, 'max_samples': 0.7, 'max_features': 0.7, 'ccp_alpha': 1e-06, 'features': 24}
#             Current best combo (with val score 0.3503):
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1046 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.035):
#             {'n_estimators': 200, 'max_depth': 24, 'max_samples': 0.7, 'max_features': 0.7, 'ccp_alpha': 1e-06, 'features': 26}
#             Current best combo (with val score 0.3503):
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1046 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.3127):
#             {'n_estimators': 100, 'max_depth': 24, 'max_samples': 0.7, 'max_features': 0.7, 'ccp_alpha': 0.01, 'features': 25}
#             Current best combo (with val score 0.3503):
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1046 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.3127):
#             {'n_estimators': 400, 'max_depth': 24, 'max_samples': 0.7, 'max_features': 0.7, 'ccp_alpha': 0.01, 'features': 25}
#             Current best combo (with val score 0.3503):
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1046 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.3127):
#             {'n_estimators': 200, 'max_depth': 12, 'max_samples': 0.7, 'max_features': 0.7, 'ccp_alpha': 0.01, 'features': 25}
#             Current best combo (with val score 0.3503):
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1046 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.3127):
#             {'n_estimators': 200, 'max_depth': 48, 'max_samples': 0.7, 'max_features': 0.7, 'ccp_alpha': 0.01, 'features': 25}
#             Current best combo (with val score 0.3503):
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1046 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.3127):
#             {'n_estimators': 200, 'max_depth': 24, 'max_samples': 0.55, 'max_features': 0.7, 'ccp_alpha': 0.01, 'features': 25}
#             Current best combo (with val score 0.3503):
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1046 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.3127):
#             {'n_estimators': 200, 'max_depth': 24, 'max_samples': 0.85, 'max_features': 0.7, 'ccp_alpha': 0.01, 'features': 25}
#             Current best combo (with val score 0.3503):
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1046 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.3132):
#             {'n_estimators': 200, 'max_depth': 24, 'max_samples': 0.7, 'max_features': 0.55, 'ccp_alpha': 0.01, 'features': 25}
#             Current best combo (with val score 0.3503):
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1046 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.3127):
#             {'n_estimators': 200, 'max_depth': 24, 'max_samples': 0.7, 'max_features': 0.85, 'ccp_alpha': 0.01, 'features': 25}
#             Current best combo (with val score 0.3503):
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1046 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.0449):
#             {'n_estimators': 200, 'max_depth': 24, 'max_samples': 0.7, 'max_features': 0.7, 'ccp_alpha': 0.0001, 'features': 25}
#             Current best combo (with val score 0.3503):
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1046 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.0378):
#             {'n_estimators': 200, 'max_depth': 24, 'max_samples': 0.7, 'max_features': 0.7, 'ccp_alpha': 0.1, 'features': 25}
#             Current best combo (with val score 0.3503):
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1046 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.3127):
#             {'n_estimators': 200, 'max_depth': 24, 'max_samples': 0.7, 'max_features': 0.7, 'ccp_alpha': 0.01, 'features': 24}
#             Current best combo (with val score 0.3503):
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1046 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.3127):
#             {'n_estimators': 200, 'max_depth': 24, 'max_samples': 0.7, 'max_features': 0.7, 'ccp_alpha': 0.01, 'features': 26}
#             Current best combo (with val score 0.3503):
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1046 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.1989):
#             {'n_estimators': 50, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#             Current best combo (with val score 0.3503):
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1046 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.2536):
#             {'n_estimators': 25, 'max_depth': 6, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#             Current best combo (with val score 0.3503):
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1046 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.345):
#             {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#             Current best combo (with val score 0.3503):
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1046 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.2461):
#             {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 0.85, 'ccp_alpha': 1e-08, 'features': 30}
#             Current best combo (with val score 0.3503):
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1046 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.3503):
#             {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-06, 'features': 30}
#             Current best combo (with val score 0.3503):
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1046 of 267750 combinations so far
# As new Best Combo (0, 0, 0, 4, 0, 29) was read in, best_clf is set to None
# Already Trained and Tested combination (val score of 0.3527):
#             {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 29}
#             Current best combo (with val score 0.3527):
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 29}
#         Has trained 1046 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 31}
#             Current best combo (with val score 0.3527):
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 29}
#         Has trained 1046 of 267750 combinations so far
# As new Best Combo (1, 0, 0, 4, 0, 29) was read in, best_clf is set to None
# Already Trained and Tested combination (val score of 0.367):
#             {'n_estimators': 50, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 29}
#             Current best combo (with val score 0.367):
#                     {'n_estimators': 50, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 29}
#         Has trained 1046 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.3655):
#             {'n_estimators': 25, 'max_depth': 6, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 29}
#             Current best combo (with val score 0.367):
#                     {'n_estimators': 50, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 29}
#         Has trained 1046 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.3404):
#             {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 29}
#             Current best combo (with val score 0.367):
#                     {'n_estimators': 50, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 29}
#         Has trained 1046 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.2524):
#             {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 0.85, 'ccp_alpha': 1e-08, 'features': 29}
#             Current best combo (with val score 0.367):
#                     {'n_estimators': 50, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 29}
#         Has trained 1046 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.3527):
#             {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-06, 'features': 29}
#             Current best combo (with val score 0.367):
#                     {'n_estimators': 50, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 29}
#         Has trained 1046 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.1741):
#             {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 28}
#             Current best combo (with val score 0.367):
#                     {'n_estimators': 50, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 29}
#         Has trained 1046 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.3503):
#             {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#             Current best combo (with val score 0.367):
#                     {'n_estimators': 50, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 29}
#         Has trained 1046 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.3527):
# ...
#             {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 0.85, 'ccp_alpha': 1e-06, 'features': 30}
#             Current best combo (with val score 0.4131):
#                     {'n_estimators': 25, 'max_depth': 6, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 29}
#         Has trained 1046 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.3503):
#             {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#             Current best combo (with val score 0.4131):
#                     {'n_estimators': 25, 'max_depth': 6, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 29}
#         Has trained 1046 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.3394):
#             {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 0.0001, 'features': 30}
#             Current best combo (with val score 0.4131):
#                     {'n_estimators': 25, 'max_depth': 6, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 29}
#         Has trained 1046 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.3527):
#             {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-06, 'features': 29}
#             Current best combo (with val score 0.4131):
#                     {'n_estimators': 25, 'max_depth': 6, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 29}
#         Has trained 1046 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-06, 'features': 31}
#             Current best combo (with val score 0.4131):
#                     {'n_estimators': 25, 'max_depth': 6, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 29}
#         Has trained 1046 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.367):
#             {'n_estimators': 50, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 29}
#             Current best combo (with val score 0.4131):
#                     {'n_estimators': 25, 'max_depth': 6, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 29}
#         Has trained 1046 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.3655):
#             {'n_estimators': 25, 'max_depth': 6, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 29}
#             Current best combo (with val score 0.4131):
#                     {'n_estimators': 25, 'max_depth': 6, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 29}
#         Has trained 1046 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.3404):
#             {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 29}
#             Current best combo (with val score 0.4131):
#                     {'n_estimators': 25, 'max_depth': 6, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 29}
#         Has trained 1046 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.2524):
#             {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 0.85, 'ccp_alpha': 1e-08, 'features': 29}
#             Current best combo (with val score 0.4131):
#                     {'n_estimators': 25, 'max_depth': 6, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 29}
#         Has trained 1046 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.3527):
#             {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-06, 'features': 29}
#             Current best combo (with val score 0.4131):
#                     {'n_estimators': 25, 'max_depth': 6, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 29}
#         Has trained 1046 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.1741):
#             {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 28}
#             Current best combo (with val score 0.4131):
#                     {'n_estimators': 25, 'max_depth': 6, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 29}
#         Has trained 1046 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.3503):
#             {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#             Current best combo (with val score 0.4131):
#                     {'n_estimators': 25, 'max_depth': 6, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 29}
#         Has trained 1046 of 267750 combinations so far
# % Combos Checked Thus Far: 1046 out of 267750 which is 0.39066300000000004%
# FINAL STAGE: Begin final Guidance system
#
#
# Guidance: round FINAL
#
# 	round FINAL iteration:  0
#
# Already Trained and Tested combination (val score of 0.4009):
#             {'n_estimators': 50, 'max_depth': 6, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 29}
#             Current best combo (with val score 0.4131):
#                     {'n_estimators': 25, 'max_depth': 6, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 29}
#         Has trained 1046 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.3404):
#             {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 29}
#             Current best combo (with val score 0.4131):
#                     {'n_estimators': 25, 'max_depth': 6, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 29}
#         Has trained 1046 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.3828):
#             {'n_estimators': 25, 'max_depth': 12, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 29}
#             Current best combo (with val score 0.4131):
#                     {'n_estimators': 25, 'max_depth': 6, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 29}
#         Has trained 1046 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.3655):
#             {'n_estimators': 25, 'max_depth': 6, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 29}
#             Current best combo (with val score 0.4131):
#                     {'n_estimators': 25, 'max_depth': 6, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 29}
#         Has trained 1046 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.4018):
#             {'n_estimators': 25, 'max_depth': 6, 'max_samples': 0.7, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 29}
#             Current best combo (with val score 0.4131):
#                     {'n_estimators': 25, 'max_depth': 6, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 29}
#         Has trained 1046 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.1682):
#             {'n_estimators': 25, 'max_depth': 6, 'max_samples': 0.55, 'max_features': 0.85, 'ccp_alpha': 1e-08, 'features': 29}
#             Current best combo (with val score 0.4131):
#                     {'n_estimators': 25, 'max_depth': 6, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 29}
#         Has trained 1046 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.4131):
#             {'n_estimators': 25, 'max_depth': 6, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-06, 'features': 29}
#             Current best combo (with val score 0.4131):
#                     {'n_estimators': 25, 'max_depth': 6, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 29}
#         Has trained 1046 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.2361):
#             {'n_estimators': 25, 'max_depth': 6, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 28}
#             Current best combo (with val score 0.4131):
#                     {'n_estimators': 25, 'max_depth': 6, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 29}
#         Has trained 1046 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.3017):
#             {'n_estimators': 25, 'max_depth': 6, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#             Current best combo (with val score 0.4131):
#                     {'n_estimators': 25, 'max_depth': 6, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 29}
#         Has trained 1046 of 267750 combinations so far
# 	round FINAL iteration:  1
#
# Already Trained and Tested combination (val score of 0.3986):
#             {'n_estimators': 50, 'max_depth': 6, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-06, 'features': 29}
#             Current best combo (with val score 0.4131):
#                     {'n_estimators': 25, 'max_depth': 6, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 29}
#         Has trained 1046 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.3409):
#             {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-06, 'features': 29}
#             Current best combo (with val score 0.4131):
#                     {'n_estimators': 25, 'max_depth': 6, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 29}
#         Has trained 1046 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.3828):
#             {'n_estimators': 25, 'max_depth': 12, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-06, 'features': 29}
#             Current best combo (with val score 0.4131):
#                     {'n_estimators': 25, 'max_depth': 6, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 29}
#         Has trained 1046 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.3655):
#             {'n_estimators': 25, 'max_depth': 6, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-06, 'features': 29}
#             Current best combo (with val score 0.4131):
#                     {'n_estimators': 25, 'max_depth': 6, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 29}
#         Has trained 1046 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.4018):
#             {'n_estimators': 25, 'max_depth': 6, 'max_samples': 0.7, 'max_features': 1, 'ccp_alpha': 1e-06, 'features': 29}
#             Current best combo (with val score 0.4131):
#                     {'n_estimators': 25, 'max_depth': 6, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 29}
#         Has trained 1046 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.1682):
#             {'n_estimators': 25, 'max_depth': 6, 'max_samples': 0.55, 'max_features': 0.85, 'ccp_alpha': 1e-06, 'features': 29}
#             Current best combo (with val score 0.4131):
#                     {'n_estimators': 25, 'max_depth': 6, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 29}
#         Has trained 1046 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.4131):
#             {'n_estimators': 25, 'max_depth': 6, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 29}
#             Current best combo (with val score 0.4131):
#                     {'n_estimators': 25, 'max_depth': 6, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 29}
#         Has trained 1046 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.4115):
#             {'n_estimators': 25, 'max_depth': 6, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 0.0001, 'features': 29}
#             Current best combo (with val score 0.4131):
#                     {'n_estimators': 25, 'max_depth': 6, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 29}
#         Has trained 1046 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.2361):
#             {'n_estimators': 25, 'max_depth': 6, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-06, 'features': 28}
#             Current best combo (with val score 0.4131):
#                     {'n_estimators': 25, 'max_depth': 6, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 29}
#         Has trained 1046 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.3017):
#             {'n_estimators': 25, 'max_depth': 6, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-06, 'features': 30}
#             Current best combo (with val score 0.4131):
#                     {'n_estimators': 25, 'max_depth': 6, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 29}
#         Has trained 1046 of 267750 combinations so far
# % Combos Checked Thus Far: 1046 out of 267750 which is 0.39066300000000004%
# Max Val Score:
#  0.413098
# Max Val Score Std:
#  0.080012
# Best Combo Train Score:
#  0.848183
# Best Combo Train Score Std:
#  0.00478
# Max Combo Index:
#  (0, 1, 1, 4, 0, 29) out of [6, 7, 5, 5, 5, 51] (note best combo is 0-indexed)
# Max Combo Hyperparamer Combination:
#  {'n_estimators': 25, 'max_depth': 6, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 29}
# Max Combo Features:
#  ('marital_status_DIVORCED', 'marital_status_MARRIED', 'marital_status_SINGLE', 'marital_status_WIDOWED', 'marital_status_0', 'procedure_224276', 'lods_score', 'procedure_227712', 'procedure_224274', 'procedure_224267', 'procedure_229519', 'admission_type_DIRECT EMER.', 'admission_type_DIRECT OBSERVATION', 'admission_type_ELECTIVE', 'admission_type_EU OBSERVATION', 'admission_type_OBSERVATION ADMIT', 'admission_type_SURGICAL SAME DAY ADMISSION', 'admission_type_URGENT', 'admission_type_EW EMER.', 'gender_M', 'gender_F', 'oasis_score', 'procedure_224275', 'race_AMERICAN INDIAN/ALASKA NATIVE', 'race_ASIAN - ASIAN INDIAN', 'race_ASIAN - CHINESE', 'race_ASIAN - KOREAN', 'race_ASIAN - SOUTH EAST ASIAN', 'race_BLACK/AFRICAN', 'race_BLACK/AFRICAN AMERICAN', 'race_BLACK/CAPE VERDEAN', 'race_BLACK/CARIBBEAN ISLAND', 'race_HISPANIC OR LATINO', 'race_HISPANIC/LATINO - CENTRAL AMERICAN', 'race_HISPANIC/LATINO - COLUMBIAN', 'race_HISPANIC/LATINO - CUBAN', 'race_HISPANIC/LATINO - DOMINICAN', 'race_HISPANIC/LATINO - GUATEMALAN', 'race_HISPANIC/LATINO - HONDURAN', 'race_HISPANIC/LATINO - MEXICAN', 'race_HISPANIC/LATINO - PUERTO RICAN', 'race_HISPANIC/LATINO - SALVADORAN', 'race_MULTIPLE RACE/ETHNICITY', 'race_NATIVE HAWAIIAN OR OTHER PACIFIC ISLANDER', 'race_OTHER', 'race_PATIENT DECLINED TO ANSWER', 'race_PORTUGUESE', 'race_SOUTH AMERICAN', 'race_UNABLE TO OBTAIN', 'race_UNKNOWN', 'race_WHITE', 'race_WHITE - BRAZILIAN', 'race_WHITE - EASTERN EUROPEAN', 'race_WHITE - OTHER EUROPEAN', 'race_WHITE - RUSSIAN', 'race_ASIAN', 'hospital_stay_duration', 'insurance_Medicaid', 'insurance_Medicare', 'insurance_Other', 'procedure_226124', 'unique_drugs', 'ventilation_used', 'item_51301', 'procedure_226236', 'procedure_227194', 'spo2', 'procedure_225400', 'anchor_age', 'procedure_229351', 'glucose', 'procedure_225792', 'icu_stay_duration', 'procedure_225446', 'creatinine', 'procedure_224270')
# % Combos Checked: 1046 out of 267750 which is 0.39066300000000004%
