# %% [markdown]
# # Tuning Script

# %%
# Parameters subject to change in every script - involved in naming

MODEL = 'extrfc'
PREPROCESSING = 'smote_normalise'
TUNER = 'yangzhoub'
OPTIMISED_METRIC = 'f1'

# %% [markdown]
# ---

# %%
# detect whether this is a google environment

COLAB_ENVIRONMENT = False

try:
    from google.colab import drive
    drive.mount('/content/drive')
    COLAB_ENVIRONMENT = True
except:
    pass
# Out:
# Mounted at /content/drive

# %%
import sys
import os
import pickle

if COLAB_ENVIRONMENT:
    home_directory = './drive/MyDrive/LAB/COMP90089__GroupWork__Py/' # my home directory is stored in ./LAB of google drive
    if MODEL == 'ebr':
        # !pip install interpret==0.5.0
    elif MODEL == 'cbr':
        # !pip install catboost
    elif MODEL in ['tf', 'mlp']:
        # !pip install PyTorch2Sklearn
    # !pip install JXAutoML
else:
    home_directory = '../../'

from JXAutoML.YangZhouB_10CV import YangZhouB_10CV as Tuner

import pandas as pd
# Out:
# Collecting JXAutoML
#   Downloading JXAutoML-0.4.4-py3-none-any.whl.metadata (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.2/67.2 kB 2.2 MB/s eta 0:00:00
# Downloading JXAutoML-0.4.4-py3-none-any.whl (52 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.1/52.1 kB 4.1 MB/s eta 0:00:00
# Installing collected packages: JXAutoML
# Successfully installed JXAutoML-0.4.4

# %%
# Parameters that are same for every script

FOLDS = 10  # we have decided to do 10 fold validation

SEED = 42

TASK_TYPE = 'Classification'  # this task is a classification task

# we have decided to tune features as hp
TUNE_FEATURES_AS_HYPERPARAMETERS = True

# %% [markdown]
# ---

# %%
# model to use to tune
from sklearn.ensemble import ExtraTreesClassifier as clf

# what values to try for each hyperparameter
parameter_choices = {
    'n_estimators': (25, 50, 100, 200, 400, 800),
    'max_depth': (3, 6, 12, 24, 48, 96, 192),
    'max_samples': (0.4, 0.55, 0.7, 0.85, 1),
    'max_features': (0.4, 0.55, 0.7, 0.85, 1),
    'ccp_alpha': (0.00000001, 0.000001, 0.0001, 0.01, 0.1)
}

# what values to set non-tuneable parameters/hyperparameters
non_tunable_hyperparameters_dict = {
                                    'random_state': SEED,
                                    'n_jobs': -1,
                                    'bootstrap': True
                                    }

# %% [markdown]
# ---

# %% [markdown]
# Read in and Prepare Data

# %%
# Import data and store as lists

train_x_list = []
train_y_list = []
val_x_list = []
val_y_list = []

for i in range(FOLDS):
    train_data = pd.read_csv(
        f'{home_directory}data/curated/modelling/{PREPROCESSING}/train_{i}.csv')
    val_data = pd.read_csv(
        f'{home_directory}data/curated/modelling/{PREPROCESSING}/val_{i}.csv')

    # get the correct rows for X and y
    train_x = train_data.drop(
        ['mortality_status', 'subject_id', 'hadm_id', 'stay_id'], axis=1)
    train_y = train_data['mortality_status']
    val_x = val_data.drop(
        ['mortality_status', 'subject_id', 'hadm_id', 'stay_id'], axis=1)
    val_y = val_data['mortality_status']

    train_x_list.append(train_x)
    train_y_list.append(train_y)
    val_x_list.append(val_x)
    val_y_list.append(val_y)

# %%
# Import feature importance ordering

with open(f'{home_directory}models/xgb_feature_importance_ordering_{PREPROCESSING}.pickle', 'rb') as f:
    feature_importance_ordering = pickle.load(f)

# %% [markdown]
# Set parameters

# %%
# initialisation
tuner = Tuner()

print('---')

# define what model we are tuning
tuner.read_in_model(clf, TASK_TYPE, optimised_metric=OPTIMISED_METRIC)

print('---')

# read in the data for training and validation
tuner.read_in_data(train_x_list, train_y_list, val_x_list, val_y_list)

print('---')

# set what hp values to tune
tuner.set_hyperparameters(parameter_choices)
# WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

# set up hp values that need to be changed from default but NOT to be tuned
tuner.set_non_tuneable_hyperparameters(non_tunable_hyperparameters_dict)

print('---')

# set up feature importance ordering

if TUNE_FEATURES_AS_HYPERPARAMETERS:
    tuner.set_features(feature_importance_ordering)
    # WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

try:  # try to read in previous results to continue tuning ...
    tuner.read_in_tuning_result_df(
        f'{home_directory}models/tuning/{TUNER}_{MODEL}_{PREPROCESSING}.csv')
except:
    print('No previous tuning data read in')

print('---')

# set up where to save the tuning result csv
tuner.set_tuning_result_saving_address(
    f'{home_directory}models/tuning/{TUNER}_{MODEL}_{PREPROCESSING}.csv')

print('---')

# set up where to save the current best model
tuner.set_best_model_saving_address(
    f'{home_directory}models/tmp_models/{TUNER}_{MODEL}_{PREPROCESSING}')
# Out:
# YangZhouB Initialised
# ---
# Successfully read in model <class 'sklearn.ensemble._forest.ExtraTreesClassifier'>, which is a Classification model optimising for f1
# ---
# Read in Train X data list
# Read in Train y data list
# Read in Val X data list
# Read in Val y data list
# ---
# Successfully recorded hyperparameter choices
# ---
# Successfully recorded non_tuneable_hyperparameter choices
# ---
# Successfully recorded tuneable feature combination choices and updated relevant internal structures
# ---
# Successfully read in tuning result of 1036 rows, for 1036.0 combos
# ---
# Successfully set tuning output address
# ---
# Successfully set best model output address

# %%
# ignore warnings

import warnings
warnings.filterwarnings("ignore")

# %%
# begin tuning ... (or continue training)

tuner.tune()
# Out:
# Streaming output truncated to the last 5000 lines.
#             Current best combo (with val score 0.4954):
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1036 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.0925):
#             {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 0.1, 'features': 59}
#             Current best combo (with val score 0.4954):
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1036 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'n_estimators': 800, 'max_depth': 24, 'max_samples': 1, 'max_features': 1, 'ccp_alpha': 0.1, 'features': 63}
#             Current best combo (with val score 0.4954):
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1036 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'n_estimators': 800, 'max_depth': 24, 'max_samples': 1, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 15}
#             Current best combo (with val score 0.4954):
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1036 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'n_estimators': 800, 'max_depth': 24, 'max_samples': 1, 'max_features': 1, 'ccp_alpha': 0.1, 'features': 35}
#             Current best combo (with val score 0.4954):
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1036 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.3342):
#             {'n_estimators': 25, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#             Current best combo (with val score 0.4954):
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1036 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.0473):
#             {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 0.1, 'features': 67}
#             Current best combo (with val score 0.4954):
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1036 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.4713):
#             {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 15}
#             Current best combo (with val score 0.4954):
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1036 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.1543):
#             {'n_estimators': 25, 'max_depth': 3, 'max_samples': 1, 'max_features': 0.4, 'ccp_alpha': 0.1, 'features': 0}
#             Current best combo (with val score 0.4954):
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1036 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'n_estimators': 800, 'max_depth': 192, 'max_samples': 1, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 10}
#             Current best combo (with val score 0.4954):
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1036 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'n_estimators': 800, 'max_depth': 3, 'max_samples': 1, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 59}
#             Current best combo (with val score 0.4954):
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1036 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.2342):
#             {'n_estimators': 25, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 40}
#             Current best combo (with val score 0.4954):
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1036 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.1421):
#             {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 45}
#             Current best combo (with val score 0.4954):
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1036 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.248):
#             {'n_estimators': 25, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 45}
#             Current best combo (with val score 0.4954):
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1036 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.0958):
#             {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 0.1, 'features': 40}
#             Current best combo (with val score 0.4954):
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1036 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.1543):
#             {'n_estimators': 25, 'max_depth': 192, 'max_samples': 1, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 10}
#             Current best combo (with val score 0.4954):
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1036 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.1431):
#             {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 0.1, 'features': 63}
#             Current best combo (with val score 0.4954):
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1036 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'n_estimators': 800, 'max_depth': 3, 'max_samples': 1, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 40}
#             Current best combo (with val score 0.4954):
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1036 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'n_estimators': 25, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 0.1, 'features': 0}
#             Current best combo (with val score 0.4954):
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1036 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.1543):
#             {'n_estimators': 25, 'max_depth': 3, 'max_samples': 1, 'max_features': 1, 'ccp_alpha': 0.1, 'features': 5}
#             Current best combo (with val score 0.4954):
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1036 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'n_estimators': 800, 'max_depth': 3, 'max_samples': 1, 'max_features': 0.4, 'ccp_alpha': 0.1, 'features': 67}
#             Current best combo (with val score 0.4954):
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1036 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.0383):
#             {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 0.1, 'features': 59}
#             Current best combo (with val score 0.4954):
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1036 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.1543):
#             {'n_estimators': 25, 'max_depth': 24, 'max_samples': 1, 'max_features': 1, 'ccp_alpha': 0.1, 'features': 40}
#             Current best combo (with val score 0.4954):
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1036 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.314):
#             {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 35}
#             Current best combo (with val score 0.4954):
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1036 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'n_estimators': 800, 'max_depth': 24, 'max_samples': 1, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 0}
#             Current best combo (with val score 0.4954):
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1036 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.1543):
#             {'n_estimators': 25, 'max_depth': 3, 'max_samples': 1, 'max_features': 1, 'ccp_alpha': 0.1, 'features': 10}
#             Current best combo (with val score 0.4954):
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1036 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.2043):
#             {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 67}
#             Current best combo (with val score 0.4954):
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1036 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'n_estimators': 800, 'max_depth': 24, 'max_samples': 1, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#             Current best combo (with val score 0.4954):
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1036 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.319):
#             {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 45}
#             Current best combo (with val score 0.4954):
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1036 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.2125):
#             {'n_estimators': 25, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 5}
#             Current best combo (with val score 0.4954):
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1036 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.0469):
#             {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 0.1, 'features': 35}
#             Current best combo (with val score 0.4954):
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1036 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.1543):
#             {'n_estimators': 25, 'max_depth': 192, 'max_samples': 1, 'max_features': 0.4, 'ccp_alpha': 0.1, 'features': 71}
#             Current best combo (with val score 0.4954):
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1036 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.1543):
#             {'n_estimators': 25, 'max_depth': 24, 'max_samples': 1, 'max_features': 1, 'ccp_alpha': 0.1, 'features': 45}
#             Current best combo (with val score 0.4954):
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1036 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.1234):
#             {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 0.1, 'features': 45}
#             Current best combo (with val score 0.4954):
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1036 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.0677):
#             {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 0.1, 'features': 15}
#             Current best combo (with val score 0.4954):
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1036 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.3442):
#             {'n_estimators': 25, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 25}
#             Current best combo (with val score 0.4954):
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1036 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.2653):
#             {'n_estimators': 25, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 0.1, 'features': 10}
#             Current best combo (with val score 0.4954):
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1036 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.1543):
#             {'n_estimators': 25, 'max_depth': 24, 'max_samples': 1, 'max_features': 1, 'ccp_alpha': 0.1, 'features': 67}
#             Current best combo (with val score 0.4954):
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1036 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.1919):
#             {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 40}
#             Current best combo (with val score 0.4954):
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1036 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'n_estimators': 800, 'max_depth': 192, 'max_samples': 1, 'max_features': 1, 'ccp_alpha': 0.1, 'features': 59}
#             Current best combo (with val score 0.4954):
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1036 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.4736):
#             {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 35}
#             Current best combo (with val score 0.4954):
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1036 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'n_estimators': 800, 'max_depth': 24, 'max_samples': 1, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 55}
#             Current best combo (with val score 0.4954):
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1036 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'n_estimators': 800, 'max_depth': 24, 'max_samples': 1, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 40}
#             Current best combo (with val score 0.4954):
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1036 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.2043):
#             {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 67}
#             Current best combo (with val score 0.4954):
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1036 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'n_estimators': 800, 'max_depth': 24, 'max_samples': 1, 'max_features': 0.4, 'ccp_alpha': 0.1, 'features': 25}
#             Current best combo (with val score 0.4954):
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1036 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.1919):
#             {'n_estimators': 25, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 40}
#             Current best combo (with val score 0.4954):
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1036 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'n_estimators': 25, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 0.1, 'features': 10}
#             Current best combo (with val score 0.4954):
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1036 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.2199):
#             {'n_estimators': 25, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 0.1, 'features': 45}
#             Current best combo (with val score 0.4954):
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1036 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.1543):
#             {'n_estimators': 25, 'max_depth': 3, 'max_samples': 1, 'max_features': 0.4, 'ccp_alpha': 0.1, 'features': 45}
#             Current best combo (with val score 0.4954):
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1036 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.2034):
#             {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 40}
#             Current best combo (with val score 0.4954):
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1036 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.1948):
#             {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 55}
#             Current best combo (with val score 0.4954):
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1036 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.4361):
#             {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 10}
#             Current best combo (with val score 0.4954):
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1036 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.2926):
#             {'n_estimators': 25, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 0.1, 'features': 40}
#             Current best combo (with val score 0.4954):
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1036 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.1234):
#             {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 0.1, 'features': 0}
#             Current best combo (with val score 0.4954):
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1036 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.1543):
#             {'n_estimators': 25, 'max_depth': 192, 'max_samples': 1, 'max_features': 0.4, 'ccp_alpha': 0.1, 'features': 10}
#             Current best combo (with val score 0.4954):
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1036 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.1543):
#             {'n_estimators': 25, 'max_depth': 24, 'max_samples': 1, 'max_features': 0.4, 'ccp_alpha': 0.1, 'features': 71}
#             Current best combo (with val score 0.4954):
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1036 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.3439):
#             {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 55}
#             Current best combo (with val score 0.4954):
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1036 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.1234):
#             {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 0.1, 'features': 71}
#             Current best combo (with val score 0.4954):
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1036 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.1543):
#             {'n_estimators': 25, 'max_depth': 3, 'max_samples': 1, 'max_features': 0.4, 'ccp_alpha': 0.1, 'features': 40}
#             Current best combo (with val score 0.4954):
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1036 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'n_estimators': 800, 'max_depth': 3, 'max_samples': 1, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 15}
#             Current best combo (with val score 0.4954):
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1036 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'n_estimators': 800, 'max_depth': 192, 'max_samples': 1, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 25}
#             Current best combo (with val score 0.4954):
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1036 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.1543):
#             {'n_estimators': 25, 'max_depth': 192, 'max_samples': 1, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 35}
#             Current best combo (with val score 0.4954):
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1036 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.3856):
#             {'n_estimators': 25, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 35}
#             Current best combo (with val score 0.4954):
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1036 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.3368):
#             {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 35}
#             Current best combo (with val score 0.4954):
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1036 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.2715):
#             {'n_estimators': 25, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 71}
#             Current best combo (with val score 0.4954):
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1036 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'n_estimators': 800, 'max_depth': 24, 'max_samples': 1, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 59}
#             Current best combo (with val score 0.4954):
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1036 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.1543):
#             {'n_estimators': 25, 'max_depth': 192, 'max_samples': 1, 'max_features': 1, 'ccp_alpha': 0.1, 'features': 35}
#             Current best combo (with val score 0.4954):
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1036 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.1543):
#             {'n_estimators': 25, 'max_depth': 3, 'max_samples': 1, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 59}
#             Current best combo (with val score 0.4954):
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1036 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.4005):
#             {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 71}
#             Current best combo (with val score 0.4954):
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1036 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'n_estimators': 800, 'max_depth': 192, 'max_samples': 1, 'max_features': 1, 'ccp_alpha': 0.1, 'features': 71}
#             Current best combo (with val score 0.4954):
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1036 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'n_estimators': 25, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 0.1, 'features': 59}
#             Current best combo (with val score 0.4954):
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1036 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'n_estimators': 800, 'max_depth': 24, 'max_samples': 1, 'max_features': 1, 'ccp_alpha': 0.1, 'features': 10}
#             Current best combo (with val score 0.4954):
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1036 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.0958):
#             {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 0.1, 'features': 40}
#             Current best combo (with val score 0.4954):
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1036 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.1543):
#             {'n_estimators': 25, 'max_depth': 24, 'max_samples': 1, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 0}
#             Current best combo (with val score 0.4954):
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1036 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.2034):
#             {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 40}
#             Current best combo (with val score 0.4954):
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1036 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.0551):
#             {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 0.1, 'features': 30}
#             Current best combo (with val score 0.4954):
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1036 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 0.1, 'features': 55}
#             Current best combo (with val score 0.4954):
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1036 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.1543):
#             {'n_estimators': 25, 'max_depth': 24, 'max_samples': 1, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 25}
#             Current best combo (with val score 0.4954):
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1036 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.0379):
#             {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 0.1, 'features': 25}
#             Current best combo (with val score 0.4954):
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1036 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'n_estimators': 800, 'max_depth': 3, 'max_samples': 1, 'max_features': 0.4, 'ccp_alpha': 0.1, 'features': 45}
#             Current best combo (with val score 0.4954):
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1036 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.1543):
#             {'n_estimators': 25, 'max_depth': 192, 'max_samples': 1, 'max_features': 0.4, 'ccp_alpha': 0.1, 'features': 50}
#             Current best combo (with val score 0.4954):
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1036 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.1543):
#             {'n_estimators': 25, 'max_depth': 24, 'max_samples': 1, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 55}
#             Current best combo (with val score 0.4954):
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1036 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.4018):
#             {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 20}
#             Current best combo (with val score 0.4954):
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1036 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.1543):
#             {'n_estimators': 25, 'max_depth': 24, 'max_samples': 1, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 15}
#             Current best combo (with val score 0.4954):
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1036 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.1543):
#             {'n_estimators': 25, 'max_depth': 3, 'max_samples': 1, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 0}
#             Current best combo (with val score 0.4954):
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1036 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'n_estimators': 800, 'max_depth': 24, 'max_samples': 1, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 5}
#             Current best combo (with val score 0.4954):
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1036 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'n_estimators': 800, 'max_depth': 24, 'max_samples': 1, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 30}
#             Current best combo (with val score 0.4954):
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1036 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'n_estimators': 800, 'max_depth': 3, 'max_samples': 1, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 15}
#             Current best combo (with val score 0.4954):
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1036 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'n_estimators': 800, 'max_depth': 3, 'max_samples': 1, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 35}
#             Current best combo (with val score 0.4954):
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1036 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.1543):
#             {'n_estimators': 25, 'max_depth': 192, 'max_samples': 1, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 55}
#             Current best combo (with val score 0.4954):
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1036 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'n_estimators': 800, 'max_depth': 3, 'max_samples': 1, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 25}
#             Current best combo (with val score 0.4954):
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1036 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'n_estimators': 800, 'max_depth': 192, 'max_samples': 1, 'max_features': 0.4, 'ccp_alpha': 0.1, 'features': 25}
#             Current best combo (with val score 0.4954):
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1036 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.4212):
#             {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 40}
#             Current best combo (with val score 0.4954):
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1036 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.187):
#             {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 0.1, 'features': 50}
#             Current best combo (with val score 0.4954):
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1036 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.0551):
#             {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 0.1, 'features': 30}
#             Current best combo (with val score 0.4954):
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1036 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'n_estimators': 800, 'max_depth': 192, 'max_samples': 1, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 5}
#             Current best combo (with val score 0.4954):
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1036 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.2663):
#             {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 59}
#             Current best combo (with val score 0.4954):
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1036 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.3012):
#             {'n_estimators': 25, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 35}
#             Current best combo (with val score 0.4954):
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1036 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'n_estimators': 800, 'max_depth': 192, 'max_samples': 1, 'max_features': 0.4, 'ccp_alpha': 0.1, 'features': 71}
#             Current best combo (with val score 0.4954):
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1036 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.119):
#             {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 0.1, 'features': 20}
#             Current best combo (with val score 0.4954):
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1036 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.2859):
#             {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 30}
#             Current best combo (with val score 0.4954):
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1036 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.187):
#             {'n_estimators': 25, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 0.1, 'features': 50}
#             Current best combo (with val score 0.4954):
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1036 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.2653):
#             {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 0.1, 'features': 10}
#             Current best combo (with val score 0.4954):
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1036 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.3376):
#             {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 67}
#             Current best combo (with val score 0.4954):
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1036 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'n_estimators': 800, 'max_depth': 192, 'max_samples': 1, 'max_features': 1, 'ccp_alpha': 0.1, 'features': 15}
#             Current best combo (with val score 0.4954):
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1036 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.1543):
#             {'n_estimators': 25, 'max_depth': 3, 'max_samples': 1, 'max_features': 1, 'ccp_alpha': 0.1, 'features': 50}
#             Current best combo (with val score 0.4954):
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1036 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.1543):
#             {'n_estimators': 25, 'max_depth': 24, 'max_samples': 1, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 45}
#             Current best combo (with val score 0.4954):
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1036 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.3818):
#             {'n_estimators': 25, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 20}
#             Current best combo (with val score 0.4954):
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1036 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.1543):
#             {'n_estimators': 25, 'max_depth': 192, 'max_samples': 1, 'max_features': 0.4, 'ccp_alpha': 0.1, 'features': 35}
#             Current best combo (with val score 0.4954):
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1036 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.1212):
#             {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 0.1, 'features': 25}
#             Current best combo (with val score 0.4954):
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1036 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.2199):
#             {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 0.1, 'features': 45}
#             Current best combo (with val score 0.4954):
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#         Has trained 1036 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.0925):
#             {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 0.1, 'features': 35}
#             Current best combo (with val score 0.4954):
# ...
#             Current best combo (with val score 0.5075):
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 31}
#         Has trained 1036 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.5057):
#             {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.7, 'max_features': 1, 'ccp_alpha': 1e-06, 'features': 31}
#             Current best combo (with val score 0.5075):
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 31}
#         Has trained 1036 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.5021):
#             {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.7, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#             Current best combo (with val score 0.5075):
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 31}
#         Has trained 1036 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.4835):
#             {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.7, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 32}
#             Current best combo (with val score 0.5075):
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 31}
#         Has trained 1036 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.461):
#             {'n_estimators': 400, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-06, 'features': 31}
#             Current best combo (with val score 0.5075):
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 31}
#         Has trained 1036 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.4979):
#             {'n_estimators': 800, 'max_depth': 6, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-06, 'features': 31}
#             Current best combo (with val score 0.5075):
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 31}
#         Has trained 1036 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.4932):
#             {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-06, 'features': 31}
#             Current best combo (with val score 0.5075):
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 31}
#         Has trained 1036 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.5057):
#             {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.7, 'max_features': 1, 'ccp_alpha': 1e-06, 'features': 31}
#             Current best combo (with val score 0.5075):
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 31}
#         Has trained 1036 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.262):
#             {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 0.85, 'ccp_alpha': 1e-06, 'features': 31}
#             Current best combo (with val score 0.5075):
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 31}
#         Has trained 1036 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.5075):
#             {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 31}
#             Current best combo (with val score 0.5075):
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 31}
#         Has trained 1036 of 378000 combinations so far
# As new Best Combo (5, 0, 1, 4, 2, 31) was read in, best_clf is set to None
# Already Trained and Tested combination (val score of 0.5095):
#             {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 0.0001, 'features': 31}
#             Current best combo (with val score 0.5095):
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 0.0001, 'features': 31}
#         Has trained 1036 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.4941):
#             {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-06, 'features': 30}
#             Current best combo (with val score 0.5095):
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 0.0001, 'features': 31}
#         Has trained 1036 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.4877):
#             {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-06, 'features': 32}
#             Current best combo (with val score 0.5095):
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 0.0001, 'features': 31}
#         Has trained 1036 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.4607):
#             {'n_estimators': 400, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 0.0001, 'features': 31}
#             Current best combo (with val score 0.5095):
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 0.0001, 'features': 31}
#         Has trained 1036 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.4977):
#             {'n_estimators': 800, 'max_depth': 6, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 0.0001, 'features': 31}
#             Current best combo (with val score 0.5095):
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 0.0001, 'features': 31}
#         Has trained 1036 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.494):
#             {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 0.0001, 'features': 31}
#             Current best combo (with val score 0.5095):
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 0.0001, 'features': 31}
#         Has trained 1036 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.5022):
#             {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.7, 'max_features': 1, 'ccp_alpha': 0.0001, 'features': 31}
#             Current best combo (with val score 0.5095):
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 0.0001, 'features': 31}
#         Has trained 1036 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.262):
#             {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 0.85, 'ccp_alpha': 0.0001, 'features': 31}
#             Current best combo (with val score 0.5095):
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 0.0001, 'features': 31}
#         Has trained 1036 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.5075):
#             {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-06, 'features': 31}
#             Current best combo (with val score 0.5095):
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 0.0001, 'features': 31}
#         Has trained 1036 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.4558):
#             {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 0.01, 'features': 31}
#             Current best combo (with val score 0.5095):
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 0.0001, 'features': 31}
#         Has trained 1036 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.4932):
#             {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 0.0001, 'features': 30}
#             Current best combo (with val score 0.5095):
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 0.0001, 'features': 31}
#         Has trained 1036 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.4881):
#             {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 0.0001, 'features': 32}
#             Current best combo (with val score 0.5095):
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 0.0001, 'features': 31}
#         Has trained 1036 of 378000 combinations so far
# % Combos Checked Thus Far: 1036 out of 378000 which is 0.27407400000000004%
# Guidance: round FINAL
#
# 	round FINAL iteration:  0
#
# Already Trained and Tested combination (val score of 0.4607):
#             {'n_estimators': 400, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 0.0001, 'features': 31}
#             Current best combo (with val score 0.5095):
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 0.0001, 'features': 31}
#         Has trained 1036 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.4977):
#             {'n_estimators': 800, 'max_depth': 6, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 0.0001, 'features': 31}
#             Current best combo (with val score 0.5095):
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 0.0001, 'features': 31}
#         Has trained 1036 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.494):
#             {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 0.0001, 'features': 31}
#             Current best combo (with val score 0.5095):
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 0.0001, 'features': 31}
#         Has trained 1036 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.5022):
#             {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.7, 'max_features': 1, 'ccp_alpha': 0.0001, 'features': 31}
#             Current best combo (with val score 0.5095):
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 0.0001, 'features': 31}
#         Has trained 1036 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.262):
#             {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 0.85, 'ccp_alpha': 0.0001, 'features': 31}
#             Current best combo (with val score 0.5095):
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 0.0001, 'features': 31}
#         Has trained 1036 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.5075):
#             {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-06, 'features': 31}
#             Current best combo (with val score 0.5095):
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 0.0001, 'features': 31}
#         Has trained 1036 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.4558):
#             {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 0.01, 'features': 31}
#             Current best combo (with val score 0.5095):
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 0.0001, 'features': 31}
#         Has trained 1036 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.4932):
#             {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 0.0001, 'features': 30}
#             Current best combo (with val score 0.5095):
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 0.0001, 'features': 31}
#         Has trained 1036 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.4881):
#             {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 0.0001, 'features': 32}
#             Current best combo (with val score 0.5095):
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 0.0001, 'features': 31}
#         Has trained 1036 of 378000 combinations so far
# % Combos Checked Thus Far: 1036 out of 378000 which is 0.27407400000000004%
# Max Val Score:
#  0.509488
# Max Val Score Std:
#  0.034639
# Best Combo Train Score:
#  0.888696
# Best Combo Train Score Std:
#  0.002411
# Max Combo Index:
#  (5, 0, 1, 4, 2, 31) out of [6, 7, 5, 5, 5, 72] (note best combo is 0-indexed)
# Max Combo Hyperparamer Combination:
#  {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 0.0001, 'features': 31}
# Max Combo Features:
#  ('procedure_225469', 'lods_score', 'procedure_224274', 'marital_status_0', 'marital_status_DIVORCED', 'marital_status_MARRIED', 'marital_status_WIDOWED', 'marital_status_SINGLE', 'procedure_223253', 'race_AMERICAN INDIAN/ALASKA NATIVE', 'race_ASIAN', 'race_ASIAN - ASIAN INDIAN', 'race_ASIAN - CHINESE', 'race_ASIAN - KOREAN', 'race_ASIAN - SOUTH EAST ASIAN', 'race_BLACK/AFRICAN', 'race_BLACK/AFRICAN AMERICAN', 'race_BLACK/CAPE VERDEAN', 'race_BLACK/CARIBBEAN ISLAND', 'race_HISPANIC OR LATINO', 'race_HISPANIC/LATINO - CENTRAL AMERICAN', 'race_HISPANIC/LATINO - COLUMBIAN', 'race_HISPANIC/LATINO - CUBAN', 'race_HISPANIC/LATINO - DOMINICAN', 'race_HISPANIC/LATINO - GUATEMALAN', 'race_HISPANIC/LATINO - HONDURAN', 'race_HISPANIC/LATINO - MEXICAN', 'race_HISPANIC/LATINO - PUERTO RICAN', 'race_HISPANIC/LATINO - SALVADORAN', 'race_MULTIPLE RACE/ETHNICITY', 'race_NATIVE HAWAIIAN OR OTHER PACIFIC ISLANDER', 'race_OTHER', 'race_PATIENT DECLINED TO ANSWER', 'race_PORTUGUESE', 'race_SOUTH AMERICAN', 'race_UNABLE TO OBTAIN', 'race_UNKNOWN', 'race_WHITE', 'race_WHITE - BRAZILIAN', 'race_WHITE - EASTERN EUROPEAN', 'race_WHITE - RUSSIAN', 'race_WHITE - OTHER EUROPEAN', 'procedure_227712', 'procedure_224276', 'admission_type_DIRECT OBSERVATION', 'admission_type_ELECTIVE', 'admission_type_EU OBSERVATION', 'admission_type_EW EMER.', 'admission_type_OBSERVATION ADMIT', 'admission_type_SURGICAL SAME DAY ADMISSION', 'admission_type_URGENT', 'admission_type_DIRECT EMER.', 'insurance_Medicare', 'insurance_Other', 'insurance_Medicaid', 'procedure_225792', 'procedure_228130', 'procedure_225817', 'procedure_224267', 'gender_F', 'gender_M', 'ventilation_used', 'hospital_stay_duration', 'oasis_score', 'procedure_228125', 'procedure_226124', 'procedure_225451', 'procedure_224275', 'procedure_229582', 'procedure_225427', 'procedure_229581', 'glucose', 'item_51301', 'spo2', 'procedure_228128', 'procedure_225401', 'procedure_225470', 'icu_stay_duration')
# % Combos Checked: 1036 out of 378000 which is 0.27407400000000004%
