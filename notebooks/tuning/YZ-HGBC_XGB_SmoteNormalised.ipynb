# %% [markdown]
# # Tuning Script

# %%
# Parameters subject to change in every script - involved in naming

MODEL = 'hgbc'
PREPROCESSING = 'smote_normalise'
TUNER = 'yangzhoub'
OPTIMISED_METRIC = 'f1'

# %% [markdown]
# ---

# %%
# detect whether this is a google environment

COLAB_ENVIRONMENT = False

try:
    from google.colab import drive
    drive.mount('/content/drive')
    COLAB_ENVIRONMENT = True
except:
    pass
# Out:
# Mounted at /content/drive

# %%
import sys
import os
import pickle

if COLAB_ENVIRONMENT:
    home_directory = './drive/MyDrive/LAB/COMP90089__GroupWork__Py/' # my home directory is stored in ./LAB of google drive
    if MODEL == 'ebr':
        # !pip install interpret==0.5.0
    elif MODEL == 'cbr':
        # !pip install catboost
    elif MODEL in ['tf', 'mlp']:
        # !pip install PyTorch2Sklearn
    # !pip install JXAutoML
else:
    home_directory = '../../'

from JXAutoML.YangZhouB_10CV import YangZhouB_10CV as Tuner

import pandas as pd
# Out:
# Collecting JXAutoML
#   Downloading JXAutoML-0.4.4-py3-none-any.whl.metadata (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.2/67.2 kB 2.0 MB/s eta 0:00:00
# Downloading JXAutoML-0.4.4-py3-none-any.whl (52 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.1/52.1 kB 3.8 MB/s eta 0:00:00
# Installing collected packages: JXAutoML
# Successfully installed JXAutoML-0.4.4

# %%
# Parameters that are same for every script

FOLDS = 10  # we have decided to do 10 fold validation

SEED = 42

TASK_TYPE = 'Classification'  # this task is a classification task

# we have decided to tune features as hp
TUNE_FEATURES_AS_HYPERPARAMETERS = True

# %% [markdown]
# ---

# %%
# model to use to tune
from sklearn.ensemble import HistGradientBoostingClassifier as clf

# what values to try for each hyperparameter
parameter_choices = {
    'max_depth': (3, 6, 12, 24, 48, 96, 192),
    'max_bins': (4, 16, 64, 255),
    'interaction_cst': ('no_interactions', 'pairwise'),
    'learning_rate': (0.00000001, 0.000001, 0.0001, 0.01, 0.1),
    'l2_regularization': (0.0001, 0.001, 0.01, 0.1, 1, 10),
    'max_iter': (25, 50, 100, 200, 400)

}

# what values to set non-tuneable parameters/hyperparameters
non_tunable_hyperparameters_dict = {
                                    'random_state': SEED,
                                    }

# %% [markdown]
# ---

# %% [markdown]
# Read in and Prepare Data

# %%
# Import data and store as lists

train_x_list = []
train_y_list = []
val_x_list = []
val_y_list = []

for i in range(FOLDS):
    train_data = pd.read_csv(
        f'{home_directory}data/curated/modelling/{PREPROCESSING}/train_{i}.csv')
    val_data = pd.read_csv(
        f'{home_directory}data/curated/modelling/{PREPROCESSING}/val_{i}.csv')

    # get the correct rows for X and y
    train_x = train_data.drop(
        ['mortality_status', 'subject_id', 'hadm_id', 'stay_id'], axis=1)
    train_y = train_data['mortality_status']
    val_x = val_data.drop(
        ['mortality_status', 'subject_id', 'hadm_id', 'stay_id'], axis=1)
    val_y = val_data['mortality_status']

    train_x_list.append(train_x)
    train_y_list.append(train_y)
    val_x_list.append(val_x)
    val_y_list.append(val_y)

# %%
# Import feature importance ordering

with open(f'{home_directory}models/xgb_feature_importance_ordering_{PREPROCESSING}.pickle', 'rb') as f:
    feature_importance_ordering = pickle.load(f)

# %% [markdown]
# Set parameters

# %%
# initialisation
tuner = Tuner()

print('---')

# define what model we are tuning
tuner.read_in_model(clf, TASK_TYPE, optimised_metric=OPTIMISED_METRIC)

print('---')

# read in the data for training and validation
tuner.read_in_data(train_x_list, train_y_list, val_x_list, val_y_list)

print('---')

# set what hp values to tune
tuner.set_hyperparameters(parameter_choices)
# WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

# set up hp values that need to be changed from default but NOT to be tuned
tuner.set_non_tuneable_hyperparameters(non_tunable_hyperparameters_dict)

print('---')

# set up feature importance ordering

if TUNE_FEATURES_AS_HYPERPARAMETERS:
    tuner.set_features(feature_importance_ordering)
    # WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

try:  # try to read in previous results to continue tuning ...
    tuner.read_in_tuning_result_df(
        f'{home_directory}models/tuning/{TUNER}_{MODEL}_{PREPROCESSING}.csv')
except:
    print('No previous tuning data read in')

print('---')

# set up where to save the tuning result csv
tuner.set_tuning_result_saving_address(
    f'{home_directory}models/tuning/{TUNER}_{MODEL}_{PREPROCESSING}.csv')

print('---')

# set up where to save the current best model
tuner.set_best_model_saving_address(
    f'{home_directory}models/tmp_models/{TUNER}_{MODEL}_{PREPROCESSING}')
# Out:
# YangZhouB Initialised
# ---
# Successfully read in model <class 'sklearn.ensemble._hist_gradient_boosting.gradient_boosting.HistGradientBoostingClassifier'>, which is a Classification model optimising for f1
# ---
# Read in Train X data list
# Read in Train y data list
# Read in Val X data list
# Read in Val y data list
# ---
# Successfully recorded hyperparameter choices
# ---
# Successfully recorded non_tuneable_hyperparameter choices
# ---
# Successfully recorded tuneable feature combination choices and updated relevant internal structures
# ---
# Successfully read in tuning result of 3679 rows, for 3679.0 combos
# ---
# Successfully set tuning output address
# ---
# Successfully set best model output address

# %%
# ignore warnings

import warnings
warnings.filterwarnings("ignore")

# %%
# begin tuning ... (or continue training)

tuner.tune()
# Out:
# Streaming output truncated to the last 5000 lines.
#         Has trained 3679 of 403200 combinations so far
# Already Trained and Tested combination (val score of 0.3378):
#             {'max_depth': 12, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.01, 'l2_regularization': 0.0001, 'max_iter': 25, 'features': 25}
#             Current best combo (with val score 0.4779):
#                     {'max_depth': 12, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 20}
#         Has trained 3679 of 403200 combinations so far
# Already Trained and Tested combination (val score of 0.4301):
#             {'max_depth': 12, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.001, 'max_iter': 25, 'features': 25}
#             Current best combo (with val score 0.4779):
#                     {'max_depth': 12, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 20}
#         Has trained 3679 of 403200 combinations so far
# Already Trained and Tested combination (val score of 0.429):
#             {'max_depth': 12, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 50, 'features': 25}
#             Current best combo (with val score 0.4779):
#                     {'max_depth': 12, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 20}
#         Has trained 3679 of 403200 combinations so far
# Already Trained and Tested combination (val score of 0.4301):
#             {'max_depth': 12, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 25, 'features': 24}
#             Current best combo (with val score 0.4779):
#                     {'max_depth': 12, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 20}
#         Has trained 3679 of 403200 combinations so far
# Already Trained and Tested combination (val score of 0.4301):
#             {'max_depth': 12, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 25, 'features': 26}
#             Current best combo (with val score 0.4779):
#                     {'max_depth': 12, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 20}
#         Has trained 3679 of 403200 combinations so far
# Already Trained and Tested combination (val score of 0.4301):
#             {'max_depth': 12, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.001, 'max_iter': 25, 'features': 25}
#             Current best combo (with val score 0.4779):
#                     {'max_depth': 12, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 20}
#         Has trained 3679 of 403200 combinations so far
# Already Trained and Tested combination (val score of 0.4301):
#             {'max_depth': 48, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.001, 'max_iter': 25, 'features': 25}
#             Current best combo (with val score 0.4779):
#                     {'max_depth': 12, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 20}
#         Has trained 3679 of 403200 combinations so far
# Already Trained and Tested combination (val score of 0.3985):
#             {'max_depth': 24, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.001, 'max_iter': 25, 'features': 25}
#             Current best combo (with val score 0.4779):
#                     {'max_depth': 12, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 20}
#         Has trained 3679 of 403200 combinations so far
# Already Trained and Tested combination (val score of 0.1826):
#             {'max_depth': 24, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 0.001, 'max_iter': 25, 'features': 25}
#             Current best combo (with val score 0.4779):
#                     {'max_depth': 12, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 20}
#         Has trained 3679 of 403200 combinations so far
# Already Trained and Tested combination (val score of 0.3763):
#             {'max_depth': 24, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.01, 'l2_regularization': 0.001, 'max_iter': 25, 'features': 25}
#             Current best combo (with val score 0.4779):
#                     {'max_depth': 12, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 20}
#         Has trained 3679 of 403200 combinations so far
# Already Trained and Tested combination (val score of 0.4301):
#             {'max_depth': 24, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 25, 'features': 25}
#             Current best combo (with val score 0.4779):
#                     {'max_depth': 12, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 20}
#         Has trained 3679 of 403200 combinations so far
# Already Trained and Tested combination (val score of 0.4301):
#             {'max_depth': 24, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.01, 'max_iter': 25, 'features': 25}
#             Current best combo (with val score 0.4779):
#                     {'max_depth': 12, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 20}
#         Has trained 3679 of 403200 combinations so far
# Already Trained and Tested combination (val score of 0.4293):
#             {'max_depth': 24, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.001, 'max_iter': 50, 'features': 25}
#             Current best combo (with val score 0.4779):
#                     {'max_depth': 12, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 20}
#         Has trained 3679 of 403200 combinations so far
# Already Trained and Tested combination (val score of 0.4301):
#             {'max_depth': 24, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.001, 'max_iter': 25, 'features': 24}
#             Current best combo (with val score 0.4779):
#                     {'max_depth': 12, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 20}
#         Has trained 3679 of 403200 combinations so far
# Already Trained and Tested combination (val score of 0.4301):
#             {'max_depth': 24, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.001, 'max_iter': 25, 'features': 26}
#             Current best combo (with val score 0.4779):
#                     {'max_depth': 12, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 20}
#         Has trained 3679 of 403200 combinations so far
# Already Trained and Tested combination (val score of 0.429):
#             {'max_depth': 12, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 50, 'features': 25}
#             Current best combo (with val score 0.4779):
#                     {'max_depth': 12, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 20}
#         Has trained 3679 of 403200 combinations so far
# Already Trained and Tested combination (val score of 0.4293):
#             {'max_depth': 48, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 50, 'features': 25}
#             Current best combo (with val score 0.4779):
#                     {'max_depth': 12, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 20}
#         Has trained 3679 of 403200 combinations so far
# Already Trained and Tested combination (val score of 0.4015):
#             {'max_depth': 24, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 50, 'features': 25}
#             Current best combo (with val score 0.4779):
#                     {'max_depth': 12, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 20}
#         Has trained 3679 of 403200 combinations so far
# Already Trained and Tested combination (val score of 0.2517):
#             {'max_depth': 24, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 50, 'features': 25}
#             Current best combo (with val score 0.4779):
#                     {'max_depth': 12, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 20}
#         Has trained 3679 of 403200 combinations so far
# Already Trained and Tested combination (val score of 0.4267):
#             {'max_depth': 24, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.01, 'l2_regularization': 0.0001, 'max_iter': 50, 'features': 25}
#             Current best combo (with val score 0.4779):
#                     {'max_depth': 12, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 20}
#         Has trained 3679 of 403200 combinations so far
# Already Trained and Tested combination (val score of 0.4293):
#             {'max_depth': 24, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.001, 'max_iter': 50, 'features': 25}
#             Current best combo (with val score 0.4779):
#                     {'max_depth': 12, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 20}
#         Has trained 3679 of 403200 combinations so far
# Already Trained and Tested combination (val score of 0.4301):
#             {'max_depth': 24, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 25, 'features': 25}
#             Current best combo (with val score 0.4779):
#                     {'max_depth': 12, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 20}
#         Has trained 3679 of 403200 combinations so far
# Already Trained and Tested combination (val score of 0.4471):
#             {'max_depth': 24, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 100, 'features': 25}
#             Current best combo (with val score 0.4779):
#                     {'max_depth': 12, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 20}
#         Has trained 3679 of 403200 combinations so far
# Already Trained and Tested combination (val score of 0.4293):
#             {'max_depth': 24, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 50, 'features': 24}
#             Current best combo (with val score 0.4779):
#                     {'max_depth': 12, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 20}
#         Has trained 3679 of 403200 combinations so far
# Already Trained and Tested combination (val score of 0.4293):
#             {'max_depth': 24, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 50, 'features': 26}
#             Current best combo (with val score 0.4779):
#                     {'max_depth': 12, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 20}
#         Has trained 3679 of 403200 combinations so far
# Already Trained and Tested combination (val score of 0.4301):
#             {'max_depth': 12, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 25, 'features': 24}
#             Current best combo (with val score 0.4779):
#                     {'max_depth': 12, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 20}
#         Has trained 3679 of 403200 combinations so far
# Already Trained and Tested combination (val score of 0.4301):
#             {'max_depth': 48, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 25, 'features': 24}
#             Current best combo (with val score 0.4779):
#                     {'max_depth': 12, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 20}
#         Has trained 3679 of 403200 combinations so far
# Already Trained and Tested combination (val score of 0.3985):
#             {'max_depth': 24, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 25, 'features': 24}
#             Current best combo (with val score 0.4779):
#                     {'max_depth': 12, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 20}
#         Has trained 3679 of 403200 combinations so far
# Already Trained and Tested combination (val score of 0.1826):
#             {'max_depth': 24, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 25, 'features': 24}
#             Current best combo (with val score 0.4779):
#                     {'max_depth': 12, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 20}
#         Has trained 3679 of 403200 combinations so far
# Already Trained and Tested combination (val score of 0.3763):
#             {'max_depth': 24, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.01, 'l2_regularization': 0.0001, 'max_iter': 25, 'features': 24}
#             Current best combo (with val score 0.4779):
#                     {'max_depth': 12, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 20}
#         Has trained 3679 of 403200 combinations so far
# Already Trained and Tested combination (val score of 0.4301):
#             {'max_depth': 24, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.001, 'max_iter': 25, 'features': 24}
#             Current best combo (with val score 0.4779):
#                     {'max_depth': 12, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 20}
#         Has trained 3679 of 403200 combinations so far
# Already Trained and Tested combination (val score of 0.4293):
#             {'max_depth': 24, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 50, 'features': 24}
#             Current best combo (with val score 0.4779):
#                     {'max_depth': 12, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 20}
#         Has trained 3679 of 403200 combinations so far
# Already Trained and Tested combination (val score of 0.4301):
#             {'max_depth': 24, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 25, 'features': 23}
#             Current best combo (with val score 0.4779):
#                     {'max_depth': 12, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 20}
#         Has trained 3679 of 403200 combinations so far
# Already Trained and Tested combination (val score of 0.4301):
#             {'max_depth': 24, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 25, 'features': 25}
#             Current best combo (with val score 0.4779):
#                     {'max_depth': 12, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 20}
#         Has trained 3679 of 403200 combinations so far
# Already Trained and Tested combination (val score of 0.4301):
#             {'max_depth': 12, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 25, 'features': 26}
#             Current best combo (with val score 0.4779):
#                     {'max_depth': 12, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 20}
#         Has trained 3679 of 403200 combinations so far
# Already Trained and Tested combination (val score of 0.4301):
#             {'max_depth': 48, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 25, 'features': 26}
#             Current best combo (with val score 0.4779):
#                     {'max_depth': 12, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 20}
#         Has trained 3679 of 403200 combinations so far
# Already Trained and Tested combination (val score of 0.3985):
#             {'max_depth': 24, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 25, 'features': 26}
#             Current best combo (with val score 0.4779):
#                     {'max_depth': 12, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 20}
#         Has trained 3679 of 403200 combinations so far
# Already Trained and Tested combination (val score of 0.1826):
#             {'max_depth': 24, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 25, 'features': 26}
#             Current best combo (with val score 0.4779):
#                     {'max_depth': 12, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 20}
#         Has trained 3679 of 403200 combinations so far
# Already Trained and Tested combination (val score of 0.3763):
#             {'max_depth': 24, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.01, 'l2_regularization': 0.0001, 'max_iter': 25, 'features': 26}
#             Current best combo (with val score 0.4779):
#                     {'max_depth': 12, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 20}
#         Has trained 3679 of 403200 combinations so far
# Already Trained and Tested combination (val score of 0.4301):
#             {'max_depth': 24, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.001, 'max_iter': 25, 'features': 26}
#             Current best combo (with val score 0.4779):
#                     {'max_depth': 12, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 20}
#         Has trained 3679 of 403200 combinations so far
# Already Trained and Tested combination (val score of 0.4293):
#             {'max_depth': 24, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 50, 'features': 26}
#             Current best combo (with val score 0.4779):
#                     {'max_depth': 12, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 20}
#         Has trained 3679 of 403200 combinations so far
# Already Trained and Tested combination (val score of 0.4301):
#             {'max_depth': 24, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 25, 'features': 25}
#             Current best combo (with val score 0.4779):
#                     {'max_depth': 12, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 20}
#         Has trained 3679 of 403200 combinations so far
# Already Trained and Tested combination (val score of 0.4301):
#             {'max_depth': 24, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 25, 'features': 27}
#             Current best combo (with val score 0.4779):
#                     {'max_depth': 12, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 20}
#         Has trained 3679 of 403200 combinations so far
# % Combos Checked Thus Far: 3679 out of 403200 which is 0.9124500000000001%
# Cruising Coordrdinate 862 of 1056
#
# Cruising Coordrdinate 863 of 1056
#
# Cruising Coordrdinate 864 of 1056
#
# Cruising Coordrdinate 865 of 1056
#
# Cruising Coordrdinate 866 of 1056
#
# Cruising Coordrdinate 867 of 1056
#
# Cruising Coordrdinate 868 of 1056
#
# Cruising Coordrdinate 869 of 1056
#
# Cruising Coordrdinate 870 of 1056
#
# Cruising Coordrdinate 871 of 1056
#
# Cruising Coordrdinate 872 of 1056
#
# Cruising Coordrdinate 873 of 1056
#
# Cruising Coordrdinate 874 of 1056
#
# Cruising Coordrdinate 875 of 1056
#
# Cruise suspended due to suspicious case
# Guidance: round 64
#
# 	round 64 iteration:  0
#
# Already Trained and Tested combination (val score of 0.422):
#             {'max_depth': 96, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 400, 'features': 15}
#             Current best combo (with val score 0.4779):
#                     {'max_depth': 12, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 20}
#         Has trained 3679 of 403200 combinations so far
# Already Trained and Tested combination (val score of 0.4585):
#             {'max_depth': 192, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 400, 'features': 15}
#             Current best combo (with val score 0.4779):
#                     {'max_depth': 12, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 20}
#         Has trained 3679 of 403200 combinations so far
# Already Trained and Tested combination (val score of 0.3994):
#             {'max_depth': 192, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 400, 'features': 15}
#             Current best combo (with val score 0.4779):
#                     {'max_depth': 12, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 20}
#         Has trained 3679 of 403200 combinations so far
# Already Trained and Tested combination (val score of 0.431):
#             {'max_depth': 192, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.01, 'l2_regularization': 0.0001, 'max_iter': 400, 'features': 15}
#             Current best combo (with val score 0.4779):
#                     {'max_depth': 12, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 20}
#         Has trained 3679 of 403200 combinations so far
# Already Trained and Tested combination (val score of 0.419):
#             {'max_depth': 192, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.001, 'max_iter': 400, 'features': 15}
#             Current best combo (with val score 0.4779):
#                     {'max_depth': 12, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 20}
#         Has trained 3679 of 403200 combinations so far
# Already Trained and Tested combination (val score of 0.4442):
#             {'max_depth': 192, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 200, 'features': 15}
#             Current best combo (with val score 0.4779):
#                     {'max_depth': 12, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 20}
#         Has trained 3679 of 403200 combinations so far
# Already Trained and Tested combination (val score of 0.422):
#             {'max_depth': 192, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 400, 'features': 14}
#             Current best combo (with val score 0.4779):
#                     {'max_depth': 12, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 20}
#         Has trained 3679 of 403200 combinations so far
# Already Trained and Tested combination (val score of 0.4205):
#             {'max_depth': 192, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 400, 'features': 16}
#             Current best combo (with val score 0.4779):
#                     {'max_depth': 12, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 20}
#         Has trained 3679 of 403200 combinations so far
# 	round 64 iteration:  1
#
# Already Trained and Tested combination (val score of 0.422):
#             {'max_depth': 48, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 400, 'features': 15}
#             Current best combo (with val score 0.4779):
#                     {'max_depth': 12, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 20}
#         Has trained 3679 of 403200 combinations so far
# Already Trained and Tested combination (val score of 0.422):
#             {'max_depth': 192, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 400, 'features': 15}
#             Current best combo (with val score 0.4779):
#                     {'max_depth': 12, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 20}
#         Has trained 3679 of 403200 combinations so far
# Already Trained and Tested combination (val score of 0.4585):
#             {'max_depth': 96, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 400, 'features': 15}
#             Current best combo (with val score 0.4779):
#                     {'max_depth': 12, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 20}
#         Has trained 3679 of 403200 combinations so far
# Already Trained and Tested combination (val score of 0.3994):
#             {'max_depth': 96, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 400, 'features': 15}
#             Current best combo (with val score 0.4779):
#                     {'max_depth': 12, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 20}
#         Has trained 3679 of 403200 combinations so far
# Already Trained and Tested combination (val score of 0.431):
#             {'max_depth': 96, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.01, 'l2_regularization': 0.0001, 'max_iter': 400, 'features': 15}
#             Current best combo (with val score 0.4779):
#                     {'max_depth': 12, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 20}
#         Has trained 3679 of 403200 combinations so far
# Already Trained and Tested combination (val score of 0.419):
#             {'max_depth': 96, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.001, 'max_iter': 400, 'features': 15}
#             Current best combo (with val score 0.4779):
#                     {'max_depth': 12, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 20}
#         Has trained 3679 of 403200 combinations so far
# Already Trained and Tested combination (val score of 0.4442):
#             {'max_depth': 96, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 200, 'features': 15}
#             Current best combo (with val score 0.4779):
#                     {'max_depth': 12, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 20}
#         Has trained 3679 of 403200 combinations so far
# Already Trained and Tested combination (val score of 0.422):
#             {'max_depth': 96, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 400, 'features': 14}
#             Current best combo (with val score 0.4779):
#                     {'max_depth': 12, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 20}
#         Has trained 3679 of 403200 combinations so far
# Already Trained and Tested combination (val score of 0.4205):
#             {'max_depth': 96, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 400, 'features': 16}
#             Current best combo (with val score 0.4779):
#                     {'max_depth': 12, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 20}
#         Has trained 3679 of 403200 combinations so far
# Already Trained and Tested combination (val score of 0.4585):
#             {'max_depth': 96, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 400, 'features': 15}
#             Current best combo (with val score 0.4779):
#                     {'max_depth': 12, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 20}
#         Has trained 3679 of 403200 combinations so far
# Already Trained and Tested combination (val score of 0.3205):
#             {'max_depth': 192, 'max_bins': 16, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 400, 'features': 15}
#             Current best combo (with val score 0.4779):
#                     {'max_depth': 12, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 20}
#         Has trained 3679 of 403200 combinations so far
# Already Trained and Tested combination (val score of 0.422):
#             {'max_depth': 192, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 400, 'features': 15}
#             Current best combo (with val score 0.4779):
#                     {'max_depth': 12, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 20}
#         Has trained 3679 of 403200 combinations so far
# Already Trained and Tested combination (val score of 0.3894):
#             {'max_depth': 192, 'max_bins': 64, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 400, 'features': 15}
#             Current best combo (with val score 0.4779):
#                     {'max_depth': 12, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 20}
#         Has trained 3679 of 403200 combinations so far
# Already Trained and Tested combination (val score of 0.3973):
#             {'max_depth': 192, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.01, 'l2_regularization': 0.0001, 'max_iter': 400, 'features': 15}
#             Current best combo (with val score 0.4779):
#                     {'max_depth': 12, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 20}
#         Has trained 3679 of 403200 combinations so far
# Already Trained and Tested combination (val score of 0.4547):
#             {'max_depth': 192, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.001, 'max_iter': 400, 'features': 15}
#             Current best combo (with val score 0.4779):
#                     {'max_depth': 12, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 20}
#         Has trained 3679 of 403200 combinations so far
# Already Trained and Tested combination (val score of 0.4428):
#             {'max_depth': 192, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 200, 'features': 15}
#             Current best combo (with val score 0.4779):
#                     {'max_depth': 12, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 20}
#         Has trained 3679 of 403200 combinations so far
# Already Trained and Tested combination (val score of 0.4585):
#             {'max_depth': 192, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 400, 'features': 14}
#             Current best combo (with val score 0.4779):
#                     {'max_depth': 12, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 20}
#         Has trained 3679 of 403200 combinations so far
# Already Trained and Tested combination (val score of 0.4597):
#             {'max_depth': 192, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 400, 'features': 16}
#             Current best combo (with val score 0.4779):
#                     {'max_depth': 12, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 20}
#         Has trained 3679 of 403200 combinations so far
# Already Trained and Tested combination (val score of 0.431):
#             {'max_depth': 96, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.01, 'l2_regularization': 0.0001, 'max_iter': 400, 'features': 15}
#             Current best combo (with val score 0.4779):
#                     {'max_depth': 12, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 20}
#         Has trained 3679 of 403200 combinations so far
# Already Trained and Tested combination (val score of 0.3973):
#             {'max_depth': 192, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.01, 'l2_regularization': 0.0001, 'max_iter': 400, 'features': 15}
#             Current best combo (with val score 0.4779):
#                     {'max_depth': 12, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 20}
#         Has trained 3679 of 403200 combinations so far
# Already Trained and Tested combination (val score of 0.3499):
#             {'max_depth': 192, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.01, 'l2_regularization': 0.0001, 'max_iter': 400, 'features': 15}
#             Current best combo (with val score 0.4779):
#                     {'max_depth': 12, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 20}
#         Has trained 3679 of 403200 combinations so far
# Already Trained and Tested combination (val score of 0.2997):
#             {'max_depth': 192, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.0001, 'l2_regularization': 0.0001, 'max_iter': 400, 'features': 15}
#             Current best combo (with val score 0.4779):
#                     {'max_depth': 12, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 20}
#         Has trained 3679 of 403200 combinations so far
# Already Trained and Tested combination (val score of 0.422):
#             {'max_depth': 192, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 400, 'features': 15}
#             Current best combo (with val score 0.4779):
#                     {'max_depth': 12, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 20}
#         Has trained 3679 of 403200 combinations so far
# Already Trained and Tested combination (val score of 0.431):
#             {'max_depth': 192, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.01, 'l2_regularization': 0.001, 'max_iter': 400, 'features': 15}
#             Current best combo (with val score 0.4779):
#                     {'max_depth': 12, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 20}
#         Has trained 3679 of 403200 combinations so far
# Already Trained and Tested combination (val score of 0.4301):
#             {'max_depth': 192, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.01, 'l2_regularization': 0.0001, 'max_iter': 200, 'features': 15}
#             Current best combo (with val score 0.4779):
#                     {'max_depth': 12, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 20}
#         Has trained 3679 of 403200 combinations so far
# Already Trained and Tested combination (val score of 0.431):
#             {'max_depth': 192, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.01, 'l2_regularization': 0.0001, 'max_iter': 400, 'features': 14}
#             Current best combo (with val score 0.4779):
#                     {'max_depth': 12, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 20}
#         Has trained 3679 of 403200 combinations so far
# Already Trained and Tested combination (val score of 0.431):
#             {'max_depth': 192, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.01, 'l2_regularization': 0.0001, 'max_iter': 400, 'features': 16}
#             Current best combo (with val score 0.4779):
#                     {'max_depth': 12, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 20}
#         Has trained 3679 of 403200 combinations so far
# Already Trained and Tested combination (val score of 0.419):
#             {'max_depth': 96, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.001, 'max_iter': 400, 'features': 15}
#             Current best combo (with val score 0.4779):
#                     {'max_depth': 12, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 20}
#         Has trained 3679 of 403200 combinations so far
# Already Trained and Tested combination (val score of 0.4547):
#             {'max_depth': 192, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.001, 'max_iter': 400, 'features': 15}
#             Current best combo (with val score 0.4779):
#                     {'max_depth': 12, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 20}
#         Has trained 3679 of 403200 combinations so far
# Already Trained and Tested combination (val score of 0.4034):
#             {'max_depth': 192, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 0.001, 'max_iter': 400, 'features': 15}
#             Current best combo (with val score 0.4779):
#                     {'max_depth': 12, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 20}
#         Has trained 3679 of 403200 combinations so far
# Already Trained and Tested combination (val score of 0.431):
#             {'max_depth': 192, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.01, 'l2_regularization': 0.001, 'max_iter': 400, 'features': 15}
#             Current best combo (with val score 0.4779):
#                     {'max_depth': 12, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 20}
#         Has trained 3679 of 403200 combinations so far
# Already Trained and Tested combination (val score of 0.422):
#             {'max_depth': 192, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 400, 'features': 15}
#             Current best combo (with val score 0.4779):
#                     {'max_depth': 12, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 20}
#         Has trained 3679 of 403200 combinations so far
# Already Trained and Tested combination (val score of 0.4224):
#             {'max_depth': 192, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.01, 'max_iter': 400, 'features': 15}
#             Current best combo (with val score 0.4779):
#                     {'max_depth': 12, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 20}
#         Has trained 3679 of 403200 combinations so far
# Already Trained and Tested combination (val score of 0.4407):
#             {'max_depth': 192, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.001, 'max_iter': 200, 'features': 15}
#             Current best combo (with val score 0.4779):
#                     {'max_depth': 12, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 20}
#         Has trained 3679 of 403200 combinations so far
# Already Trained and Tested combination (val score of 0.419):
#             {'max_depth': 192, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.001, 'max_iter': 400, 'features': 14}
#             Current best combo (with val score 0.4779):
#                     {'max_depth': 12, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 20}
#         Has trained 3679 of 403200 combinations so far
# Already Trained and Tested combination (val score of 0.4247):
#             {'max_depth': 192, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.001, 'max_iter': 400, 'features': 16}
#             Current best combo (with val score 0.4779):
#                     {'max_depth': 12, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 20}
#         Has trained 3679 of 403200 combinations so far
# Already Trained and Tested combination (val score of 0.4442):
#             {'max_depth': 96, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 200, 'features': 15}
#             Current best combo (with val score 0.4779):
#                     {'max_depth': 12, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 20}
#         Has trained 3679 of 403200 combinations so far
# Already Trained and Tested combination (val score of 0.4428):
#             {'max_depth': 192, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 200, 'features': 15}
#             Current best combo (with val score 0.4779):
#                     {'max_depth': 12, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 20}
#         Has trained 3679 of 403200 combinations so far
# Already Trained and Tested combination (val score of 0.4102):
#             {'max_depth': 192, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 200, 'features': 15}
#             Current best combo (with val score 0.4779):
#                     {'max_depth': 12, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 20}
#         Has trained 3679 of 403200 combinations so far
# Already Trained and Tested combination (val score of 0.4301):
#             {'max_depth': 192, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.01, 'l2_regularization': 0.0001, 'max_iter': 200, 'features': 15}
#             Current best combo (with val score 0.4779):
#                     {'max_depth': 12, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 20}
#         Has trained 3679 of 403200 combinations so far
# Already Trained and Tested combination (val score of 0.4407):
#             {'max_depth': 192, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.001, 'max_iter': 200, 'features': 15}
#             Current best combo (with val score 0.4779):
#                     {'max_depth': 12, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 20}
#         Has trained 3679 of 403200 combinations so far
# Already Trained and Tested combination (val score of 0.4315):
#             {'max_depth': 192, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 100, 'features': 15}
#             Current best combo (with val score 0.4779):
#                     {'max_depth': 12, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 20}
#         Has trained 3679 of 403200 combinations so far
# ...
#
# Cruising Coordrdinate 1055 of 1056
#
# Cruise suspended due to suspicious case
# Guidance: round 84
#
# 	round 84 iteration:  0
#
# Already Trained and Tested combination (val score of 0.4696):
#             {'max_depth': 12, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 20}
#             Current best combo (with val score 0.4779):
#                     {'max_depth': 12, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 20}
#         Has trained 3679 of 403200 combinations so far
# Already Trained and Tested combination (val score of 0.469):
#             {'max_depth': 48, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 20}
#             Current best combo (with val score 0.4779):
#                     {'max_depth': 12, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 20}
#         Has trained 3679 of 403200 combinations so far
# Already Trained and Tested combination (val score of 0.4366):
#             {'max_depth': 24, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 20}
#             Current best combo (with val score 0.4779):
#                     {'max_depth': 12, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 20}
#         Has trained 3679 of 403200 combinations so far
# Already Trained and Tested combination (val score of 0.4671):
#             {'max_depth': 24, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 20}
#             Current best combo (with val score 0.4779):
#                     {'max_depth': 12, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 20}
#         Has trained 3679 of 403200 combinations so far
# Already Trained and Tested combination (val score of 0.4278):
#             {'max_depth': 24, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.01, 'l2_regularization': 10, 'max_iter': 400, 'features': 20}
#             Current best combo (with val score 0.4779):
#                     {'max_depth': 12, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 20}
#         Has trained 3679 of 403200 combinations so far
# Already Trained and Tested combination (val score of 0.4554):
#             {'max_depth': 24, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 1, 'max_iter': 400, 'features': 20}
#             Current best combo (with val score 0.4779):
#                     {'max_depth': 12, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 20}
#         Has trained 3679 of 403200 combinations so far
# Already Trained and Tested combination (val score of 0.4383):
#             {'max_depth': 24, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 20}
#             Current best combo (with val score 0.4779):
#                     {'max_depth': 12, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 20}
#         Has trained 3679 of 403200 combinations so far
# Already Trained and Tested combination (val score of 0.4507):
#             {'max_depth': 24, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 19}
#             Current best combo (with val score 0.4779):
#                     {'max_depth': 12, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 20}
#         Has trained 3679 of 403200 combinations so far
# Already Trained and Tested combination (val score of 0.435):
#             {'max_depth': 24, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 21}
#             Current best combo (with val score 0.4779):
#                     {'max_depth': 12, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 20}
#         Has trained 3679 of 403200 combinations so far
# 	round 84 iteration:  1
#
# Already Trained and Tested combination (val score of 0.4779):
#             {'max_depth': 12, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 20}
#             Current best combo (with val score 0.4779):
#                     {'max_depth': 12, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 20}
#         Has trained 3679 of 403200 combinations so far
# Already Trained and Tested combination (val score of 0.4659):
#             {'max_depth': 48, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 20}
#             Current best combo (with val score 0.4779):
#                     {'max_depth': 12, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 20}
#         Has trained 3679 of 403200 combinations so far
# Already Trained and Tested combination (val score of 0.426):
#             {'max_depth': 24, 'max_bins': 64, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 20}
#             Current best combo (with val score 0.4779):
#                     {'max_depth': 12, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 20}
#         Has trained 3679 of 403200 combinations so far
# Already Trained and Tested combination (val score of 0.4693):
#             {'max_depth': 24, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 20}
#             Current best combo (with val score 0.4779):
#                     {'max_depth': 12, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 20}
#         Has trained 3679 of 403200 combinations so far
# Already Trained and Tested combination (val score of 0.2991):
#             {'max_depth': 24, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.01, 'l2_regularization': 10, 'max_iter': 400, 'features': 20}
#             Current best combo (with val score 0.4779):
#                     {'max_depth': 12, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 20}
#         Has trained 3679 of 403200 combinations so far
# Already Trained and Tested combination (val score of 0.4486):
#             {'max_depth': 24, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 1, 'max_iter': 400, 'features': 20}
#             Current best combo (with val score 0.4779):
#                     {'max_depth': 12, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 20}
#         Has trained 3679 of 403200 combinations so far
# Already Trained and Tested combination (val score of 0.4436):
#             {'max_depth': 24, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 20}
#             Current best combo (with val score 0.4779):
#                     {'max_depth': 12, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 20}
#         Has trained 3679 of 403200 combinations so far
# Already Trained and Tested combination (val score of 0.4284):
#             {'max_depth': 24, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 19}
#             Current best combo (with val score 0.4779):
#                     {'max_depth': 12, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 20}
#         Has trained 3679 of 403200 combinations so far
# Already Trained and Tested combination (val score of 0.4532):
#             {'max_depth': 24, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 21}
#             Current best combo (with val score 0.4779):
#                     {'max_depth': 12, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 20}
#         Has trained 3679 of 403200 combinations so far
# % Combos Checked Thus Far: 3679 out of 403200 which is 0.9124500000000001%
# Cruising Coordrdinate 1056 of 1056
#
# Cruise suspended due to suspicious case
# Guidance: round 85
#
# 	round 85 iteration:  0
#
# % Combos Checked Thus Far: 3679 out of 403200 which is 0.9124500000000001%
# FINAL STAGE: Begin final Guidance system
#
#
# Guidance: round FINAL
#
# 	round FINAL iteration:  0
#
# Already Trained and Tested combination (val score of 0.4722):
#             {'max_depth': 6, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 20}
#             Current best combo (with val score 0.4779):
#                     {'max_depth': 12, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 20}
#         Has trained 3679 of 403200 combinations so far
# Already Trained and Tested combination (val score of 0.4671):
#             {'max_depth': 24, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 20}
#             Current best combo (with val score 0.4779):
#                     {'max_depth': 12, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 20}
#         Has trained 3679 of 403200 combinations so far
# Already Trained and Tested combination (val score of 0.432):
#             {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 20}
#             Current best combo (with val score 0.4779):
#                     {'max_depth': 12, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 20}
#         Has trained 3679 of 403200 combinations so far
# Already Trained and Tested combination (val score of 0.4696):
#             {'max_depth': 12, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 20}
#             Current best combo (with val score 0.4779):
#                     {'max_depth': 12, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 20}
#         Has trained 3679 of 403200 combinations so far
# Already Trained and Tested combination (val score of 0.3017):
#             {'max_depth': 12, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.01, 'l2_regularization': 10, 'max_iter': 400, 'features': 20}
#             Current best combo (with val score 0.4779):
#                     {'max_depth': 12, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 20}
#         Has trained 3679 of 403200 combinations so far
# Already Trained and Tested combination (val score of 0.4497):
#             {'max_depth': 12, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 1, 'max_iter': 400, 'features': 20}
#             Current best combo (with val score 0.4779):
#                     {'max_depth': 12, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 20}
#         Has trained 3679 of 403200 combinations so far
# Already Trained and Tested combination (val score of 0.4547):
#             {'max_depth': 12, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 20}
#             Current best combo (with val score 0.4779):
#                     {'max_depth': 12, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 20}
#         Has trained 3679 of 403200 combinations so far
# Already Trained and Tested combination (val score of 0.4521):
#             {'max_depth': 12, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 19}
#             Current best combo (with val score 0.4779):
#                     {'max_depth': 12, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 20}
#         Has trained 3679 of 403200 combinations so far
# Already Trained and Tested combination (val score of 0.459):
#             {'max_depth': 12, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 21}
#             Current best combo (with val score 0.4779):
#                     {'max_depth': 12, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 20}
#         Has trained 3679 of 403200 combinations so far
# % Combos Checked Thus Far: 3679 out of 403200 which is 0.9124500000000001%
# Max Val Score:
#  0.477885
# Max Val Score Std:
#  0.061118
# Best Combo Train Score:
#  0.957212
# Best Combo Train Score Std:
#  0.001892
# Max Combo Index:
#  (2, 3, 1, 4, 5, 4, 20) out of [7, 4, 2, 5, 6, 5, 48] (note best combo is 0-indexed)
# Max Combo Hyperparamer Combination:
#  {'max_depth': 12, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 20}
# Max Combo Features:
#  ('procedure_224274', 'lods_score', 'procedure_224276', 'procedure_224267', 'race_AMERICAN INDIAN/ALASKA NATIVE', 'race_ASIAN', 'race_ASIAN - ASIAN INDIAN', 'race_ASIAN - CHINESE', 'race_ASIAN - KOREAN', 'race_ASIAN - SOUTH EAST ASIAN', 'race_BLACK/AFRICAN', 'race_BLACK/AFRICAN AMERICAN', 'race_BLACK/CAPE VERDEAN', 'race_BLACK/CARIBBEAN ISLAND', 'race_HISPANIC OR LATINO', 'race_HISPANIC/LATINO - CENTRAL AMERICAN', 'race_HISPANIC/LATINO - COLUMBIAN', 'race_HISPANIC/LATINO - CUBAN', 'race_HISPANIC/LATINO - DOMINICAN', 'race_HISPANIC/LATINO - GUATEMALAN', 'race_HISPANIC/LATINO - HONDURAN', 'race_HISPANIC/LATINO - MEXICAN', 'race_HISPANIC/LATINO - PUERTO RICAN', 'race_HISPANIC/LATINO - SALVADORAN', 'race_MULTIPLE RACE/ETHNICITY', 'race_NATIVE HAWAIIAN OR OTHER PACIFIC ISLANDER', 'race_OTHER', 'race_PATIENT DECLINED TO ANSWER', 'race_PORTUGUESE', 'race_SOUTH AMERICAN', 'race_UNABLE TO OBTAIN', 'race_WHITE', 'race_WHITE - BRAZILIAN', 'race_WHITE - EASTERN EUROPEAN', 'race_WHITE - OTHER EUROPEAN', 'race_WHITE - RUSSIAN', 'race_UNKNOWN', 'procedure_227712', 'procedure_225430', 'gender_F', 'gender_M', 'oasis_score', 'procedure_225446', 'procedure_224275', 'procedure_225802', 'hospital_stay_duration', 'procedure_226475', 'ventilation_used', 'procedure_224270', 'procedure_227194', 'icu_stay_duration', 'procedure_225400', 'procedure_221223', 'procedure_225792')
# % Combos Checked: 3679 out of 403200 which is 0.9124500000000001%
