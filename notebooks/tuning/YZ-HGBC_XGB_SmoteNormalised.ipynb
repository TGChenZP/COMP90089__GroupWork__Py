# %% [markdown]
# # Tuning Script

# %%
# Parameters subject to change in every script - involved in naming

MODEL = 'hgbc'
PREPROCESSING = 'smote_normalise'
TUNER = 'yangzhoub'
OPTIMISED_METRIC = 'f1'

# %% [markdown]
# ---

# %%
# detect whether this is a google environment

COLAB_ENVIRONMENT = False

try:
    from google.colab import drive
    drive.mount('/content/drive')
    COLAB_ENVIRONMENT = True
except:
    pass
# Out:
# Mounted at /content/drive

# %%
import sys
import os
import pickle

if COLAB_ENVIRONMENT:
    home_directory = './drive/MyDrive/LAB/COMP90089__GroupWork__Py/' # my home directory is stored in ./LAB of google drive
    if MODEL == 'ebr':
        # !pip install interpret==0.5.0
    elif MODEL == 'cbr':
        # !pip install catboost
    elif MODEL in ['tf', 'mlp']:
        # !pip install PyTorch2Sklearn
    # !pip install JXAutoML
else:
    home_directory = '../../'

from JXAutoML.YangZhouB_10CV import YangZhouB_10CV as Tuner

import pandas as pd
# Out:
# Collecting JXAutoML
#   Downloading JXAutoML-0.4.4-py3-none-any.whl.metadata (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.2/67.2 kB 1.8 MB/s eta 0:00:00
# Downloading JXAutoML-0.4.4-py3-none-any.whl (52 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.1/52.1 kB 3.9 MB/s eta 0:00:00
# Installing collected packages: JXAutoML
# Successfully installed JXAutoML-0.4.4

# %%
# Parameters that are same for every script

FOLDS = 10  # we have decided to do 10 fold validation

SEED = 42

TASK_TYPE = 'Classification'  # this task is a classification task

# we have decided to tune features as hp
TUNE_FEATURES_AS_HYPERPARAMETERS = True

# %% [markdown]
# ---

# %%
# model to use to tune
from sklearn.ensemble import HistGradientBoostingClassifier as clf

# what values to try for each hyperparameter
parameter_choices = {
    'max_depth': (3, 6, 12, 24, 48, 96, 192),
    'max_bins': (4, 16, 64, 255),
    'interaction_cst': ('no_interactions', 'pairwise'),
    'learning_rate': (0.00000001, 0.000001, 0.0001, 0.01, 0.1),
    'l2_regularization': (0.0001, 0.001, 0.01, 0.1, 1, 10),
    'max_iter': (25, 50, 100, 200, 400)

}

# what values to set non-tuneable parameters/hyperparameters
non_tunable_hyperparameters_dict = {
                                    'random_state': SEED,
                                    }

# %% [markdown]
# ---

# %% [markdown]
# Read in and Prepare Data

# %%
# Import data and store as lists

train_x_list = []
train_y_list = []
val_x_list = []
val_y_list = []

for i in range(FOLDS):
    train_data = pd.read_csv(
        f'{home_directory}data/curated/modelling/{PREPROCESSING}/train_{i}.csv')
    val_data = pd.read_csv(
        f'{home_directory}data/curated/modelling/{PREPROCESSING}/val_{i}.csv')

    # get the correct rows for X and y
    train_x = train_data.drop(
        ['mortality_status', 'subject_id', 'hadm_id', 'stay_id'], axis=1)
    train_y = train_data['mortality_status']
    val_x = val_data.drop(
        ['mortality_status', 'subject_id', 'hadm_id', 'stay_id'], axis=1)
    val_y = val_data['mortality_status']

    train_x_list.append(train_x)
    train_y_list.append(train_y)
    val_x_list.append(val_x)
    val_y_list.append(val_y)

# %%
# Import feature importance ordering

with open(f'{home_directory}models/xgb_feature_importance_ordering_{PREPROCESSING}.pickle', 'rb') as f:
    feature_importance_ordering = pickle.load(f)

# %% [markdown]
# Set parameters

# %%
# initialisation
tuner = Tuner()

print('---')

# define what model we are tuning
tuner.read_in_model(clf, TASK_TYPE, optimised_metric=OPTIMISED_METRIC)

print('---')

# read in the data for training and validation
tuner.read_in_data(train_x_list, train_y_list, val_x_list, val_y_list)

print('---')

# set what hp values to tune
tuner.set_hyperparameters(parameter_choices)
# WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

# set up hp values that need to be changed from default but NOT to be tuned
tuner.set_non_tuneable_hyperparameters(non_tunable_hyperparameters_dict)

print('---')

# set up feature importance ordering

if TUNE_FEATURES_AS_HYPERPARAMETERS:
    tuner.set_features(feature_importance_ordering)
    # WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

try:  # try to read in previous results to continue tuning ...
    tuner.read_in_tuning_result_df(
        f'{home_directory}models/tuning/{TUNER}_{MODEL}_{PREPROCESSING}.csv')
except:
    print('No previous tuning data read in')

print('---')

# set up where to save the tuning result csv
tuner.set_tuning_result_saving_address(
    f'{home_directory}models/tuning/{TUNER}_{MODEL}_{PREPROCESSING}.csv')

print('---')

# set up where to save the current best model
tuner.set_best_model_saving_address(
    f'{home_directory}models/tmp_models/{TUNER}_{MODEL}_{PREPROCESSING}')
# Out:
# YangZhouB Initialised
# ---
# Successfully read in model <class 'sklearn.ensemble._hist_gradient_boosting.gradient_boosting.HistGradientBoostingClassifier'>, which is a Classification model optimising for f1
# ---
# Read in Train X data list
# Read in Train y data list
# Read in Val X data list
# Read in Val y data list
# ---
# Successfully recorded hyperparameter choices
# ---
# Successfully recorded non_tuneable_hyperparameter choices
# ---
# Successfully recorded tuneable feature combination choices and updated relevant internal structures
# ---
# No previous tuning data read in
# ---
# Successfully set tuning output address
# ---
# Successfully set best model output address

# %%
# ignore warnings

import warnings
warnings.filterwarnings("ignore")

# %%
# begin tuning ... (or continue training)

tuner.tune()
# Out:
# Streaming output truncated to the last 5000 lines.
#             Current best combo with val score 0.4763:
#                     {'max_depth': 192, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 40}
# Trained and Tested combination 738 of 428400, taking 0.15 seconds to get val score of 0.1253:
#                 {'max_depth': 3, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 1e-08, 'l2_regularization': 10, 'max_iter': 25, 'features': 40},
#             Current best combo with val score 0.4763:
#                     {'max_depth': 192, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 40}
# Trained and Tested combination 739 of 428400, taking 0.84 seconds to get val score of 0.0033:
#                 {'max_depth': 192, 'max_bins': 4, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 20},
#             Current best combo with val score 0.4763:
#                     {'max_depth': 192, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 40}
# Trained and Tested combination 740 of 428400, taking 1.42 seconds to get val score of 0.1038:
#                 {'max_depth': 3, 'max_bins': 4, 'interaction_cst': 'pairwise', 'learning_rate': 1e-08, 'l2_regularization': 10, 'max_iter': 400, 'features': 35},
#             Current best combo with val score 0.4763:
#                     {'max_depth': 192, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 40}
# Trained and Tested combination 741 of 428400, taking 0.11 seconds to get val score of 0.0063:
#                 {'max_depth': 3, 'max_bins': 4, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 25, 'features': 30},
#             Current best combo with val score 0.4763:
#                     {'max_depth': 192, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 40}
# Trained and Tested combination 742 of 428400, taking 0.02 seconds to get val score of 0.3388:
#                 {'max_depth': 3, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 1e-08, 'l2_regularization': 0.0001, 'max_iter': 25, 'features': 0},
#             Current best combo with val score 0.4763:
#                     {'max_depth': 192, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 40}
# Trained and Tested combination 743 of 428400, taking 0.21 seconds to get val score of 0.1038:
#                 {'max_depth': 192, 'max_bins': 4, 'interaction_cst': 'pairwise', 'learning_rate': 1e-08, 'l2_regularization': 0.0001, 'max_iter': 25, 'features': 50},
#             Current best combo with val score 0.4763:
#                     {'max_depth': 192, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 40}
# Trained and Tested combination 744 of 428400, taking 0.1 seconds to get val score of 0.0:
#                 {'max_depth': 3, 'max_bins': 4, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 25, 'features': 25},
#             Current best combo with val score 0.4763:
#                     {'max_depth': 192, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 40}
# Trained and Tested combination 745 of 428400, taking 0.15 seconds to get val score of 0.4301:
#                 {'max_depth': 24, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 25, 'features': 25},
#             Current best combo with val score 0.4763:
#                     {'max_depth': 192, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 40}
# Trained and Tested combination 746 of 428400, taking 1.55 seconds to get val score of 0.4433:
#                 {'max_depth': 192, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 400, 'features': 25},
#             Current best combo with val score 0.4763:
#                     {'max_depth': 192, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 40}
# Trained and Tested combination 747 of 428400, taking 0.05 seconds to get val score of 0.0325:
#                 {'max_depth': 24, 'max_bins': 4, 'interaction_cst': 'no_interactions', 'learning_rate': 1e-08, 'l2_regularization': 0.0001, 'max_iter': 25, 'features': 10},
#             Current best combo with val score 0.4763:
#                     {'max_depth': 192, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 40}
# Trained and Tested combination 748 of 428400, taking 0.11 seconds to get val score of 0.1038:
#                 {'max_depth': 24, 'max_bins': 4, 'interaction_cst': 'pairwise', 'learning_rate': 1e-08, 'l2_regularization': 0.0001, 'max_iter': 25, 'features': 25},
#             Current best combo with val score 0.4763:
#                     {'max_depth': 192, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 40}
# Trained and Tested combination 749 of 428400, taking 0.1 seconds to get val score of 0.0156:
#                 {'max_depth': 24, 'max_bins': 4, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 25, 'features': 20},
#             Current best combo with val score 0.4763:
#                     {'max_depth': 192, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 40}
# Trained and Tested combination 750 of 428400, taking 0.15 seconds to get val score of 0.1418:
#                 {'max_depth': 3, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 1e-08, 'l2_regularization': 0.0001, 'max_iter': 25, 'features': 40},
#             Current best combo with val score 0.4763:
#                     {'max_depth': 192, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 40}
# Trained and Tested combination 751 of 428400, taking 0.1 seconds to get val score of 0.1038:
#                 {'max_depth': 3, 'max_bins': 4, 'interaction_cst': 'pairwise', 'learning_rate': 1e-08, 'l2_regularization': 10, 'max_iter': 25, 'features': 15},
#             Current best combo with val score 0.4763:
#                     {'max_depth': 192, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 40}
# Trained and Tested combination 752 of 428400, taking 0.12 seconds to get val score of 0.3929:
#                 {'max_depth': 24, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 25, 'features': 40},
#             Current best combo with val score 0.4763:
#                     {'max_depth': 192, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 40}
# Trained and Tested combination 753 of 428400, taking 0.27 seconds to get val score of 0.1284:
#                 {'max_depth': 24, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 25, 'features': 45},
#             Current best combo with val score 0.4763:
#                     {'max_depth': 192, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 40}
# Trained and Tested combination 754 of 428400, taking 1.58 seconds to get val score of 0.1038:
#                 {'max_depth': 24, 'max_bins': 4, 'interaction_cst': 'pairwise', 'learning_rate': 1e-08, 'l2_regularization': 10, 'max_iter': 400, 'features': 25},
#             Current best combo with val score 0.4763:
#                     {'max_depth': 192, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 40}
# Trained and Tested combination 755 of 428400, taking 0.74 seconds to get val score of 0.0325:
#                 {'max_depth': 192, 'max_bins': 4, 'interaction_cst': 'no_interactions', 'learning_rate': 1e-08, 'l2_regularization': 0.0001, 'max_iter': 400, 'features': 20},
#             Current best combo with val score 0.4763:
#                     {'max_depth': 192, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 40}
# Trained and Tested combination 756 of 428400, taking 0.2 seconds to get val score of 0.3127:
#                 {'max_depth': 192, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 0},
#             Current best combo with val score 0.4763:
#                     {'max_depth': 192, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 40}
# Trained and Tested combination 757 of 428400, taking 1.9 seconds to get val score of 0.0594:
#                 {'max_depth': 192, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 400, 'features': 30},
#             Current best combo with val score 0.4763:
#                     {'max_depth': 192, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 40}
# Trained and Tested combination

#             Current best combo with val score 0.4763:
#                     {'max_depth': 192, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 40}
# Trained and Tested combination 799 of 428400, taking 0.02 seconds to get val score of 0.3127:
#                 {'max_depth': 24, 'max_bins': 4, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 25, 'features': 0},
#             Current best combo with val score 0.4763:
#                     {'max_depth': 192, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 40}
# Trained and Tested combination 800 of 428400, taking 0.15 seconds to get val score of 0.2385:
#                 {'max_depth': 24, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 25, 'features': 25},
#             Current best combo with val score 0.4763:
#                     {'max_depth': 192, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 40}
# Trained and Tested combination 801 of 428400, taking 1.38 seconds to get val score of 0.1418:
#                 {'max_depth': 3, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 1e-08, 'l2_regularization': 0.0001, 'max_iter': 400, 'features': 25},
#             Current best combo with val score 0.4763:
#                     {'max_depth': 192, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 40}
# Trained and Tested combination 802 of 428400, taking 0.74 seconds to get val score of 0.0325:
#                 {'max_depth': 192, 'max_bins': 4, 'interaction_cst': 'no_interactions', 'learning_rate': 1e-08, 'l2_regularization': 10, 'max_iter': 400, 'features': 20},
#             Current best combo with val score 0.4763:
#                     {'max_depth': 192, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 40}
# Trained and Tested combination 803 of 428400, taking 0.11 seconds to get val score of 0.2997:
#                 {'max_depth': 192, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 1e-08, 'l2_regularization': 0.0001, 'max_iter': 25, 'features': 15},
#             Current best combo with val score 0.4763:
#                     {'max_depth': 192, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 40}
# Trained and Tested combination 804 of 428400, taking 0.14 seconds to get val score of 0.0:
#                 {'max_depth': 3, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 25, 'features': 40},
#             Current best combo with val score 0.4763:
#                     {'max_depth': 192, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 40}
# Trained and Tested combination 805 of 428400, taking 2.08 seconds to get val score of 0.3924:
#                 {'max_depth': 192, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 400, 'features': 15},
#             Current best combo with val score 0.4763:
#                     {'max_depth': 192, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 40}
# Trained and Tested combination 806 of 428400, taking 0.19 seconds to get val score of 0.1284:
#                 {'max_depth': 24, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 25, 'features': 50},
#             Current best combo with val score 0.4763:
#                     {'max_depth': 192, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 40}
# Trained and Tested combination 807 of 428400, taking 0.07 seconds to get val score of 0.2388:
#                 {'max_depth': 3, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 25, 'features': 15},
#             Current best combo with val score 0.4763:
#                     {'max_depth': 192, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 40}
# Trained and Tested combination 808 of 428400, taking 0.95 seconds to get val score of 0.0325:
#                 {'max_depth': 24, 'max_bins': 4, 'interaction_cst': 'no_interactions', 'learning_rate': 1e-08, 'l2_regularization': 10, 'max_iter': 400, 'features': 50},
#             Current best combo with val score 0.4763:
#                     {'max_depth': 192, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 40}
# Trained and Tested combination 809 of 428400, taking 1.7 seconds to get val score of 0.2534:
#                 {'max_depth': 192, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 1e-08, 'l2_regularization': 10, 'max_iter': 400, 'features': 20},
#             Current best combo with val score 0.4763:
#                     {'max_depth': 192, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 40}
# Trained and Tested combination 810 of 428400, taking 0.03 seconds to get val score of 0.3388:
#                 {'max_depth': 3, 'max_bins': 4, 'interaction_cst': 'pairwise', 'learning_rate': 1e-08, 'l2_regularization': 0.0001, 'max_iter': 25, 'features': 0},
#             Current best combo with val score 0.4763:
#                     {'max_depth': 192, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 40}
# Trained and Tested combination 811 of 428400, taking 1.71 seconds to get val score of 0.1038:
#                 {'max_depth': 24, 'max_bins': 4, 'interaction_cst': 'pairwise', 'learning_rate': 1e-08, 'l2_regularization': 10, 'max_iter': 400, 'features': 50},
#             Current best combo with val score 0.4763:
#                     {'max_depth': 192, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 40}
# Trained and Tested combination 812 of 428400, taking 0.73 seconds to get val score of 0.4259:
#                 {'max_depth': 24, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 5},
#             Current best combo with val score 0.4763:
#                     {'max_depth': 192, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 40}
# Trained and Tested combination 813 of 428400, taking 0.14 seconds to get val score of 0.4301:
#                 {'max_depth': 192, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 25, 'features': 40},
#             Current best combo with val score 0.4763:
#                     {'max_depth': 192, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 40}
# Trained and Tested combination 814 of 428400, taking 1.33 seconds to get val score of 0.2442:
#                 {'max_depth': 24, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 1e-08, 'l2_regularization': 0.0001, 'max_iter': 400, 'features': 10},
#             Current best combo with val score 0.4763:
#                     {'max_depth': 192, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 40}
# Trained and Tested combination 815 of 428400, taking 1.0 seconds to get val score of 0.0:
#                 {'max_depth': 192, 'max_bins': 4, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 35},
#             Current best combo with val score 0.4763:
#                     {'max_depth': 192, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 40}
# Trained and Tested combination 816 of 428400, taking 0.36 seconds to get val score of 0.0577:
#                 {'max_depth': 192, 'max_bins': 4, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 400, 'features': 5},
#             Current best combo with val score 0.4763:
#                     {'max_depth': 192, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 40}
# Trained and Tested combination 817 of 428400, taking 0.08 seconds to get val score of 0.0325:
#                 {'max_depth': 24, 'max_bins': 4, 'interaction_cst': 'no_interactions', 'learning_rate': 1e-08, 'l2_regularization': 0.0001, 'max_iter': 25, 'features': 35},
#             Current best combo with val score 0.4763:
#                     {'max_depth': 192, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 40}
# Trained and Tested combination 818 of 428400, taking 0.66 seconds to get val score of 0.0067:
#                 {'max_depth': 3, 'max_bins': 4, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 10},
#             Current best combo with val score 0.4763:
#                     {'max_depth': 192, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 40}
# Trained and Tested combination 819 of 428400, taking 0.04 seconds to get val score of 0.4301:
#                 {'max_depth': 24, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 1e-08, 'l2_regularization': 10, 'max_iter': 25, 'features': 5},
#             Current best combo with val score 0.4763:
#                     {'max_depth': 192, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 40}
# Trained and Tested combination 820 of 428400, taking 0.14 seconds to get val score of 0.1418:
#                 {'max_depth': 3, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 1e-08, 'l2_regularization': 0.0001, 'max_iter': 25, 'features': 35},
#             Current best combo with val score 0.4763:
#                     {'max_depth': 192, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 40}
# Trained and Tested combination 821 of 428400, taking 0.71 seconds to get val score of 0.2997:
#                 {'max_depth': 192, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 1e-08, 'l2_regularization': 10, 'max_iter': 400, 'features': 10},
#             Current best combo with val score 0.4763:
#                     {'max_depth': 192, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 40}
# Trained and Tested combination 822 of 428400, taking 0.03 seconds to get val score of 0.0325:
#                 {'max_depth': 24, 'max_bins': 4, 'interaction_cst': 'no_interactions', 'learning_rate': 1e-08, 'l2_regularization': 10, 'max_iter': 25, 'features': 5},
#             Current best combo with val score 0.4763:
#                     {'max_depth': 192, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 40}
# Trained and Tested combination 823 of 428400, taking 0.09 seconds to get val score of 0.0359:
#                 {'max_depth': 3, 'max_bins': 4, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 25, 'features': 50},
#             Current best combo with val score 0.4763:
#                     {'max_depth': 192, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 40}
# Trained and Tested combination 824 of 428400, taking 0.06 seconds to get val score of 0.0359:
#                 {'max_depth': 3, 'max_bins': 4, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 25, 'features': 15},
#             Current best combo with val score 0.4763:
#                     {'max_depth': 192, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 40}
# Trained and Tested combination 825 of 428400, taking 0.04 seconds to get val score of 0.0325:
#                 {'max_depth': 24, 'max_bins': 4, 'interaction_cst': 'no_interactions', 'learning_rate': 1e-08, 'l2_regularization': 10, 'max_iter': 25, 'features': 10},
#             Current best combo with val score 0.4763:
#                     {'max_depth': 192, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 40}
# Trained and Tested combination 826 of 428400, taking 0.6 seconds to get val score of 0.2578:
#                 {'max_depth': 3, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 1e-08, 'l2_regularization': 0.0001, 'max_iter': 400, 'features': 5},
#             Current best combo with val score 0.4763:
#                     {'max_depth': 192, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 40}
# Trained and Tested combination 827 of 428400, taking 0.21 seconds to get val score of 0.2153:
#                 {'max_depth': 24, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 25, 'features': 50},
#             Current best combo with val score 0.4763:
#                     {'max_depth': 192, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 40}
# Trained and Tested combination 828 of 428400, taking 1.37 seconds to get val score of 0.2997:
#                 {'max_depth': 192, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 1e-08, 'l2_regularization': 0.0001, 'max_iter': 400, 'features': 15},
#             Current best combo with val score 0.4763:
#                     {'max_depth': 192, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 40}
# Trained and Tested combination 829 of 428400, taking 0.02 seconds to get val score of 0.3388:
#                 {'max_depth': 24, 'max_bins': 4, 'interaction_cst': 'pairwise', 'learning_rate': 1e-08, 'l2_regularization': 0.0001, 'max_iter': 25, 'features': 0},
#             Current best combo with val score 0.4763:
#                     {'max_depth': 192, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 40}
# Trained and Tested combination 830 of 428400, taking 0.84 seconds to get val score of 0.1742:
#                 {'max_depth': 3, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 1e-08, 'l2_regularization': 0.0001, 'max_iter': 400, 'features': 25},
#             Current best combo with val score 0.4763:
#                     {'max_depth': 192, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 40}
# Trained and Tested combination 831 of 428400, taking 1.0 seconds to get val score of 0.0:
#                 {'max_depth': 24, 'max_bins': 4, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 15},
#             Current best combo with val score 0.4763:
#                     {'max_depth': 192, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 40}
# Trained and Tested combination 832 of 428400, taking 0.09 seconds to get val score of 0.3992:
#                 {'max_depth': 192, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 25, 'features': 15},
#             Current best combo with val score 0.4763:
#                     {'max_depth': 192, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 40}
# Trained and Tested combination 833 of 428400, taking 1.45 seconds to get val score of 0.3905:
#                 {'max_depth': 192, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 15},
#             Current best combo with val score 0.4763:
#                     {'max_depth': 192, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 40}
# Trained and Tested combination 834 of 428400, taking 1.05 seconds to get val score of 0.1742:
#                 {'max_depth': 3, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 1e-08, 'l2_regularization': 0.0001, 'max_iter': 400, 'features': 50},
#             Current best combo with val score 0.4763:
# ...
# Trained and Tested combination 1518 of 428400, taking 0.69 seconds to get val score of 0.4301:
#                 {'max_depth': 48, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 400, 'features': 5},
#             Current best combo with val score 0.4763:
#                     {'max_depth': 192, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 40}
# Trained and Tested combination 1519 of 428400, taking 0.57 seconds to get val score of 0.3988:
#                 {'max_depth': 24, 'max_bins': 64, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 400, 'features': 5},
#             Current best combo with val score 0.4763:
#                     {'max_depth': 192, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 40}
# Already Trained and Tested combination (val score of 0.4301):
#             {'max_depth': 24, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 400, 'features': 5}
#             Current best combo (with val score 0.4763):
#                     {'max_depth': 192, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 40}
#         Has trained 1519 of 428400 combinations so far
# Trained and Tested combination 1520 of 428400, taking 0.89 seconds to get val score of 0.4333:
#                 {'max_depth': 24, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.01, 'l2_regularization': 0.0001, 'max_iter': 400, 'features': 5},
#             Current best combo with val score 0.4763:
#                     {'max_depth': 192, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 40}
# Trained and Tested combination 1521 of 428400, taking 0.67 seconds to get val score of 0.4301:
#                 {'max_depth': 24, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 0.001, 'max_iter': 400, 'features': 5},
#             Current best combo with val score 0.4763:
#                     {'max_depth': 192, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 40}
# Trained and Tested combination 1522 of 428400, taking 0.36 seconds to get val score of 0.4301:
#                 {'max_depth': 24, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 200, 'features': 5},
#             Current best combo with val score 0.4763:
#                     {'max_depth': 192, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 40}
# Trained and Tested combination 1523 of 428400, taking 0.63 seconds to get val score of 0.4301:
#                 {'max_depth': 24, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 400, 'features': 4},
#             Current best combo with val score 0.4763:
#                     {'max_depth': 192, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 40}
# Trained and Tested combination 1524 of 428400, taking 1.06 seconds to get val score of 0.4301:
#                 {'max_depth': 24, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 400, 'features': 6},
#             Current best combo with val score 0.4763:
#                     {'max_depth': 192, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 40}
# 	round 13 iteration:  1
#
# Already Trained and Tested combination (val score of 0.4301):
#             {'max_depth': 24, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 400, 'features': 5}
#             Current best combo (with val score 0.4763):
#                     {'max_depth': 192, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 40}
#         Has trained 1524 of 428400 combinations so far
# Trained and Tested combination 1525 of 428400, taking 0.68 seconds to get val score of 0.4301:
#                 {'max_depth': 96, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 400, 'features': 5},
#             Current best combo with val score 0.4763:
#                     {'max_depth': 192, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 40}
# Trained and Tested combination 1526 of 428400, taking 0.57 seconds to get val score of 0.3988:
#                 {'max_depth': 48, 'max_bins': 64, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 400, 'features': 5},
#             Current best combo with val score 0.4763:
#                     {'max_depth': 192, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 40}
# Trained and Tested combination 1527 of 428400, taking 0.31 seconds to get val score of 0.4301:
#                 {'max_depth': 48, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 400, 'features': 5},
#             Current best combo with val score 0.4763:
#                     {'max_depth': 192, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 40}
# Trained and Tested combination 1528 of 428400, taking 0.88 seconds to get val score of 0.4333:
#                 {'max_depth': 48, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.01, 'l2_regularization': 0.0001, 'max_iter': 400, 'features': 5},
#             Current best combo with val score 0.4763:
#                     {'max_depth': 192, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 40}
# Trained and Tested combination 1529 of 428400, taking 0.66 seconds to get val score of 0.4301:
#                 {'max_depth': 48, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 0.001, 'max_iter': 400, 'features': 5},
#             Current best combo with val score 0.4763:
#                     {'max_depth': 192, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 40}
# Trained and Tested combination 1530 of 428400, taking 0.36 seconds to get val score of 0.4301:
#                 {'max_depth': 48, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 200, 'features': 5},
#             Current best combo with val score 0.4763:
#                     {'max_depth': 192, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 40}
# Trained and Tested combination 1531 of 428400, taking 0.62 seconds to get val score of 0.4301:
#                 {'max_depth': 48, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 400, 'features': 4},
#             Current best combo with val score 0.4763:
#                     {'max_depth': 192, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 40}
# Trained and Tested combination 1532 of 428400, taking 1.02 seconds to get val score of 0.4301:
#                 {'max_depth': 48, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 400, 'features': 6},
#             Current best combo with val score 0.4763:
#                     {'max_depth': 192, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 40}
# Trained and Tested combination 1533 of 428400, taking 0.3 seconds to get val score of 0.4301:
#                 {'max_depth': 12, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 400, 'features': 5},
#             Current best combo with val score 0.4763:
#                     {'max_depth': 192, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 40}
# Already Trained and Tested combination (val score of 0.4301):
#             {'max_depth': 48, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 400, 'features': 5}
#             Current best combo (with val score 0.4763):
#                     {'max_depth': 192, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 40}
#         Has trained 1533 of 428400 combinations so far
# Trained and Tested combination 1534 of 428400, taking 0.28 seconds to get val score of 0.3985:
#                 {'max_depth': 24, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 400, 'features': 5},
#             Current best combo with val score 0.4763:
#                     {'max_depth': 192, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 40}
# Already Trained and Tested combination (val score of 0.4301):
#             {'max_depth': 24, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 400, 'features': 5}
#             Current best combo (with val score 0.4763):
#                     {'max_depth': 192, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 40}
#         Has trained 1534 of 428400 combinations so far
# Trained and Tested combination 1535 of 428400, taking 0.61 seconds to get val score of 0.4301:
#                 {'max_depth': 24, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.01, 'l2_regularization': 0.0001, 'max_iter': 400, 'features': 5},
#             Current best combo with val score 0.4763:
#                     {'max_depth': 192, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 40}
# Trained and Tested combination 1536 of 428400, taking 0.3 seconds to get val score of 0.4301:
#                 {'max_depth': 24, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.001, 'max_iter': 400, 'features': 5},
#             Current best combo with val score 0.4763:
#                     {'max_depth': 192, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 40}
# Trained and Tested combination 1537 of 428400, taking 0.26 seconds to get val score of 0.4301:
#                 {'max_depth': 24, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 200, 'features': 5},
#             Current best combo with val score 0.4763:
#                     {'max_depth': 192, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 40}
# Trained and Tested combination 1538 of 428400, taking 0.31 seconds to get val score of 0.4301:
#                 {'max_depth': 24, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 400, 'features': 4},
#             Current best combo with val score 0.4763:
#                     {'max_depth': 192, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 40}
# Trained and Tested combination 1539 of 428400, taking 0.31 seconds to get val score of 0.4301:
#                 {'max_depth': 24, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 400, 'features': 6},
#             Current best combo with val score 0.4763:
#                     {'max_depth': 192, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 40}
# Trained and Tested combination 1540 of 428400, taking 0.83 seconds to get val score of 0.4333:
#                 {'max_depth': 12, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.01, 'l2_regularization': 0.0001, 'max_iter': 400, 'features': 5},
#             Current best combo with val score 0.4763:
#                     {'max_depth': 192, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 40}
# Already Trained and Tested combination (val score of 0.4333):
#             {'max_depth': 48, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.01, 'l2_regularization': 0.0001, 'max_iter': 400, 'features': 5}
#             Current best combo (with val score 0.4763):
#                     {'max_depth': 192, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 40}
#         Has trained 1540 of 428400 combinations so far
# Trained and Tested combination 1541 of 428400, taking 0.76 seconds to get val score of 0.4038:
#                 {'max_depth': 24, 'max_bins': 64, 'interaction_cst': 'pairwise', 'learning_rate': 0.01, 'l2_regularization': 0.0001, 'max_iter': 400, 'features': 5},
#             Current best combo with val score 0.4763:
#                     {'max_depth': 192, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 40}
# Already Trained and Tested combination (val score of 0.4301):
#             {'max_depth': 24, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.01, 'l2_regularization': 0.0001, 'max_iter': 400, 'features': 5}
#             Current best combo (with val score 0.4763):
#                     {'max_depth': 192, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 40}
#         Has trained 1541 of 428400 combinations so far
# Trained and Tested combination 1542 of 428400, taking 1.52 seconds to get val score of 0.3683:
#                 {'max_depth': 24, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.0001, 'l2_regularization': 0.0001, 'max_iter': 400, 'features': 5},
#             Current best combo with val score 0.4763:
#                     {'max_depth': 192, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 40}
# Already Trained and Tested combination (val score of 0.4301):
#             {'max_depth': 24, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 400, 'features': 5}
#             Current best combo (with val score 0.4763):
#                     {'max_depth': 192, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 40}
#         Has trained 1542 of 428400 combinations so far
