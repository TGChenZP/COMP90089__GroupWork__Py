# %% [markdown]
# # Tuning Script

# %%
# Parameters subject to change in every script - involved in naming

MODEL = 'hgbc'
PREPROCESSING = 'smote_normalise'
TUNER = 'yangzhoub'
OPTIMISED_METRIC = 'f1'

# %% [markdown]
# ---

# %%
# detect whether this is a google environment

COLAB_ENVIRONMENT = False

try:
    from google.colab import drive
    drive.mount('/content/drive')
    COLAB_ENVIRONMENT = True
except:
    pass
# Out:
# Mounted at /content/drive

# %%
import sys
import os
import pickle

if COLAB_ENVIRONMENT:
    home_directory = './drive/MyDrive/LAB/COMP90089__GroupWork__Py/' # my home directory is stored in ./LAB of google drive
    if MODEL == 'ebr':
        # !pip install interpret==0.5.0
    elif MODEL == 'cbr':
        # !pip install catboost
    elif MODEL in ['tf', 'mlp']:
        # !pip install PyTorch2Sklearn
    # !pip install JXAutoML
else:
    home_directory = '../../'

from JXAutoML.YangZhouB_10CV import YangZhouB_10CV as Tuner

import pandas as pd
# Out:
# Collecting JXAutoML
#   Downloading JXAutoML-0.4.4-py3-none-any.whl.metadata (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.2/67.2 kB 716.5 kB/s eta 0:00:00
# Downloading JXAutoML-0.4.4-py3-none-any.whl (52 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.1/52.1 kB 2.0 MB/s eta 0:00:00
# Installing collected packages: JXAutoML
# Successfully installed JXAutoML-0.4.4

# %%
# Parameters that are same for every script

FOLDS = 10  # we have decided to do 10 fold validation

SEED = 42

TASK_TYPE = 'Classification'  # this task is a classification task

# we have decided to tune features as hp
TUNE_FEATURES_AS_HYPERPARAMETERS = True

# %% [markdown]
# ---

# %%
# model to use to tune
from sklearn.ensemble import HistGradientBoostingClassifier as clf

# what values to try for each hyperparameter
parameter_choices = {
    'max_depth': (3, 6, 12, 24, 48, 96, 192),
    'max_bins': (4, 16, 64, 255),
    'interaction_cst': ('no_interactions', 'pairwise'),
    'learning_rate': (0.00000001, 0.000001, 0.0001, 0.01, 0.1),
    'l2_regularization': (0.0001, 0.001, 0.01, 0.1, 1, 10),
    'max_iter': (25, 50, 100, 200, 400)

}

# what values to set non-tuneable parameters/hyperparameters
non_tunable_hyperparameters_dict = {
                                    'random_state': SEED,
                                    }

# %% [markdown]
# ---

# %% [markdown]
# Read in and Prepare Data

# %%
# Import data and store as lists

train_x_list = []
train_y_list = []
val_x_list = []
val_y_list = []

for i in range(FOLDS):
    train_data = pd.read_csv(
        f'{home_directory}data/curated/modelling/{PREPROCESSING}/train_{i}.csv')
    val_data = pd.read_csv(
        f'{home_directory}data/curated/modelling/{PREPROCESSING}/val_{i}.csv')

    # get the correct rows for X and y
    train_x = train_data.drop(
        ['mortality_status', 'subject_id', 'hadm_id', 'stay_id'], axis=1)
    train_y = train_data['mortality_status']
    val_x = val_data.drop(
        ['mortality_status', 'subject_id', 'hadm_id', 'stay_id'], axis=1)
    val_y = val_data['mortality_status']

    train_x_list.append(train_x)
    train_y_list.append(train_y)
    val_x_list.append(val_x)
    val_y_list.append(val_y)

# %%
# Import feature importance ordering

with open(f'{home_directory}models/xgb_feature_importance_ordering_{PREPROCESSING}.pickle', 'rb') as f:
    feature_importance_ordering = pickle.load(f)

# %% [markdown]
# Set parameters

# %%
# initialisation
tuner = Tuner()

print('---')

# define what model we are tuning
tuner.read_in_model(clf, TASK_TYPE, optimised_metric=OPTIMISED_METRIC)

print('---')

# read in the data for training and validation
tuner.read_in_data(train_x_list, train_y_list, val_x_list, val_y_list)

print('---')

# set what hp values to tune
tuner.set_hyperparameters(parameter_choices)
# WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

# set up hp values that need to be changed from default but NOT to be tuned
tuner.set_non_tuneable_hyperparameters(non_tunable_hyperparameters_dict)

print('---')

# set up feature importance ordering

if TUNE_FEATURES_AS_HYPERPARAMETERS:
    tuner.set_features(feature_importance_ordering)
    # WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

try:  # try to read in previous results to continue tuning ...
    tuner.read_in_tuning_result_df(
        f'{home_directory}models/tuning/{TUNER}_{MODEL}_{PREPROCESSING}.csv')
except:
    print('No previous tuning data read in')

print('---')

# set up where to save the tuning result csv
tuner.set_tuning_result_saving_address(
    f'{home_directory}models/tuning/{TUNER}_{MODEL}_{PREPROCESSING}.csv')

print('---')

# set up where to save the current best model
tuner.set_best_model_saving_address(
    f'{home_directory}models/tmp_models/{TUNER}_{MODEL}_{PREPROCESSING}')
# Out:
# YangZhouB Initialised
# ---
# Successfully read in model <class 'sklearn.ensemble._hist_gradient_boosting.gradient_boosting.HistGradientBoostingClassifier'>, which is a Classification model optimising for f1
# ---
# Read in Train X data list
# Read in Train y data list
# Read in Val X data list
# Read in Val y data list
# ---
# Successfully recorded hyperparameter choices
# ---
# Successfully recorded non_tuneable_hyperparameter choices
# ---
# Successfully recorded tuneable feature combination choices and updated relevant internal structures
# ---
# Successfully read in tuning result of 9620 rows, for 9620.0 combos
# ---
# Successfully set tuning output address
# ---
# Successfully set best model output address

# %%
# ignore warnings

import warnings
warnings.filterwarnings("ignore")

# %%
# begin tuning ... (or continue training)

tuner.tune()
# Out:
# Streaming output truncated to the last 5000 lines.
#         Has trained 9620 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.5986):
#             {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 1, 'max_iter': 400, 'features': 23}
#             Current best combo (with val score 0.5986):
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 1, 'max_iter': 400, 'features': 22}
#         Has trained 9620 of 604800 combinations so far
# % Combos Checked Thus Far: 9620 out of 604800 which is 1.590608%
# Cruising Coordrdinate 1353 of 1536
#
# Cruising Coordrdinate 1354 of 1536
#
# Cruising Coordrdinate 1355 of 1536
#
# Cruising Coordrdinate 1356 of 1536
#
# Cruising Coordrdinate 1357 of 1536
#
# Cruising Coordrdinate 1358 of 1536
#
# Cruising Coordrdinate 1359 of 1536
#
# Cruising Coordrdinate 1360 of 1536
#
# Cruising Coordrdinate 1361 of 1536
#
# Cruising Coordrdinate 1362 of 1536
#
# Cruising Coordrdinate 1363 of 1536
#
# Cruising Coordrdinate 1364 of 1536
#
# Cruising Coordrdinate 1365 of 1536
#
# Cruising Coordrdinate 1366 of 1536
#
# Cruising Coordrdinate 1367 of 1536
#
# Cruising Coordrdinate 1368 of 1536
#
# Cruising Coordrdinate 1369 of 1536
#
# Cruising Coordrdinate 1370 of 1536
#
# Cruising Coordrdinate 1371 of 1536
#
# Cruising Coordrdinate 1372 of 1536
#
# Cruising Coordrdinate 1373 of 1536
#
# Cruising Coordrdinate 1374 of 1536
#
# Cruising Coordrdinate 1375 of 1536
#
# Cruising Coordrdinate 1376 of 1536
#
# Cruising Coordrdinate 1377 of 1536
#
# Cruising Coordrdinate 1378 of 1536
#
# Cruising Coordrdinate 1379 of 1536
#
# Cruising Coordrdinate 1380 of 1536
#
# Cruising Coordrdinate 1381 of 1536
#
# Cruising Coordrdinate 1382 of 1536
#
# Cruising Coordrdinate 1383 of 1536
#
# Cruising Coordrdinate 1384 of 1536
#
# Cruising Coordrdinate 1385 of 1536
#
# Cruising Coordrdinate 1386 of 1536
#
# Cruising Coordrdinate 1387 of 1536
#
# Cruising Coordrdinate 1388 of 1536
#
# Cruising Coordrdinate 1389 of 1536
#
# Cruising Coordrdinate 1390 of 1536
#
# Cruising Coordrdinate 1391 of 1536
#
# Cruising Coordrdinate 1392 of 1536
#
# Cruise suspended due to suspicious case
# Guidance: round 245
#
# 	round 245 iteration:  0
#
# % Combos Checked Thus Far: 9620 out of 604800 which is 1.590608%
# Cruising Coordrdinate 1393 of 1536
#
# Cruising Coordrdinate 1394 of 1536
#
# Cruising Coordrdinate 1395 of 1536
#
# Cruising Coordrdinate 1396 of 1536
#
# Cruising Coordrdinate 1397 of 1536
#
# Cruising Coordrdinate 1398 of 1536
#
# Cruising Coordrdinate 1399 of 1536
#
# Cruising Coordrdinate 1400 of 1536
#
# Cruising Coordrdinate 1401 of 1536
#
# Cruising Coordrdinate 1402 of 1536
#
# Cruising Coordrdinate 1403 of 1536
#
# Cruising Coordrdinate 1404 of 1536
#
# Cruising Coordrdinate 1405 of 1536
#
# Cruising Coordrdinate 1406 of 1536
#
# Cruising Coordrdinate 1407 of 1536
#
# Cruising Coordrdinate 1408 of 1536
#
# Cruising Coordrdinate 1409 of 1536
#
# Cruising Coordrdinate 1410 of 1536
#
# Cruise suspended due to suspicious case
# Guidance: round 246
#
# 	round 246 iteration:  0
#
# Already Trained and Tested combination (val score of 0.535):
#             {'max_depth': 6, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 400, 'features': 30}
#             Current best combo (with val score 0.5986):
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 1, 'max_iter': 400, 'features': 22}
#         Has trained 9620 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.5302):
#             {'max_depth': 3, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 400, 'features': 30}
#             Current best combo (with val score 0.5986):
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 1, 'max_iter': 400, 'features': 22}
#         Has trained 9620 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.4333):
#             {'max_depth': 3, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 400, 'features': 30}
#             Current best combo (with val score 0.5986):
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 1, 'max_iter': 400, 'features': 22}
#         Has trained 9620 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.3743):
#             {'max_depth': 3, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.01, 'l2_regularization': 0.0001, 'max_iter': 400, 'features': 30}
#             Current best combo (with val score 0.5986):
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 1, 'max_iter': 400, 'features': 22}
#         Has trained 9620 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.5596):
#             {'max_depth': 3, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.001, 'max_iter': 400, 'features': 30}
#             Current best combo (with val score 0.5986):
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 1, 'max_iter': 400, 'features': 22}
#         Has trained 9620 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.5292):
#             {'max_depth': 3, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 200, 'features': 30}
#             Current best combo (with val score 0.5986):
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 1, 'max_iter': 400, 'features': 22}
#         Has trained 9620 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.5596):
#             {'max_depth': 3, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 400, 'features': 29}
#             Current best combo (with val score 0.5986):
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 1, 'max_iter': 400, 'features': 22}
#         Has trained 9620 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.5532):
#             {'max_depth': 3, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 400, 'features': 31}
#             Current best combo (with val score 0.5986):
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 1, 'max_iter': 400, 'features': 22}
#         Has trained 9620 of 604800 combinations so far
# 	round 246 iteration:  1
#
# Already Trained and Tested combination (val score of 0.5346):
#             {'max_depth': 6, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.001, 'max_iter': 400, 'features': 30}
#             Current best combo (with val score 0.5986):
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 1, 'max_iter': 400, 'features': 22}
#         Has trained 9620 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.5302):
#             {'max_depth': 3, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.001, 'max_iter': 400, 'features': 30}
#             Current best combo (with val score 0.5986):
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 1, 'max_iter': 400, 'features': 22}
#         Has trained 9620 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.436):
#             {'max_depth': 3, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 0.001, 'max_iter': 400, 'features': 30}
#             Current best combo (with val score 0.5986):
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 1, 'max_iter': 400, 'features': 22}
#         Has trained 9620 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.3743):
#             {'max_depth': 3, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.01, 'l2_regularization': 0.001, 'max_iter': 400, 'features': 30}
#             Current best combo (with val score 0.5986):
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 1, 'max_iter': 400, 'features': 22}
#         Has trained 9620 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.5596):
#             {'max_depth': 3, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 400, 'features': 30}
#             Current best combo (with val score 0.5986):
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 1, 'max_iter': 400, 'features': 22}
#         Has trained 9620 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.5575):
#             {'max_depth': 3, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.01, 'max_iter': 400, 'features': 30}
#             Current best combo (with val score 0.5986):
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 1, 'max_iter': 400, 'features': 22}
#         Has trained 9620 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.5292):
#             {'max_depth': 3, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.001, 'max_iter': 200, 'features': 30}
#             Current best combo (with val score 0.5986):
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 1, 'max_iter': 400, 'features': 22}
#         Has trained 9620 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.5596):
#             {'max_depth': 3, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.001, 'max_iter': 400, 'features': 29}
#             Current best combo (with val score 0.5986):
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 1, 'max_iter': 400, 'features': 22}
#         Has trained 9620 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.5539):
#             {'max_depth': 3, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.001, 'max_iter': 400, 'features': 31}
#             Current best combo (with val score 0.5986):
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 1, 'max_iter': 400, 'features': 22}
#         Has trained 9620 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.535):
#             {'max_depth': 6, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 400, 'features': 29}
#             Current best combo (with val score 0.5986):
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 1, 'max_iter': 400, 'features': 22}
#         Has trained 9620 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.5302):
#             {'max_depth': 3, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 400, 'features': 29}
#             Current best combo (with val score 0.5986):
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 1, 'max_iter': 400, 'features': 22}
#         Has trained 9620 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.4123):
#             {'max_depth': 3, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 400, 'features': 29}
#             Current best combo (with val score 0.5986):
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 1, 'max_iter': 400, 'features': 22}
#         Has trained 9620 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.3743):
#             {'max_depth': 3, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.01, 'l2_regularization': 0.0001, 'max_iter': 400, 'features': 29}
#             Current best combo (with val score 0.5986):
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 1, 'max_iter': 400, 'features': 22}
#         Has trained 9620 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.5596):
#             {'max_depth': 3, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.001, 'max_iter': 400, 'features': 29}
#             Current best combo (with val score 0.5986):
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 1, 'max_iter': 400, 'features': 22}
#         Has trained 9620 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.5292):
#             {'max_depth': 3, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 200, 'features': 29}
#             Current best combo (with val score 0.5986):
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 1, 'max_iter': 400, 'features': 22}
#         Has trained 9620 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.5596):
#             {'max_depth': 3, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 400, 'features': 28}
#             Current best combo (with val score 0.5986):
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 1, 'max_iter': 400, 'features': 22}
#         Has trained 9620 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.5596):
#             {'max_depth': 3, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 400, 'features': 30}
#             Current best combo (with val score 0.5986):
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 1, 'max_iter': 400, 'features': 22}
#         Has trained 9620 of 604800 combinations so far
# % Combos Checked Thus Far: 9620 out of 604800 which is 1.590608%
# Cruising Coordrdinate 1411 of 1536
#
# Cruising Coordrdinate 1412 of 1536
#
# Cruising Coordrdinate 1413 of 1536
#
# Cruising Coordrdinate 1414 of 1536
#
# Cruising Coordrdinate 1415 of 1536
#
# Cruising Coordrdinate 1416 of 1536
#
# Cruising Coordrdinate 1417 of 1536
#
# Cruise suspended due to suspicious case
# Guidance: round 247
#
# 	round 247 iteration:  0
#
# Already Trained and Tested combination (val score of 0.5282):
#             {'max_depth': 12, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 400, 'features': 30}
#             Current best combo (with val score 0.5986):
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 1, 'max_iter': 400, 'features': 22}
#         Has trained 9620 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.5057):
#             {'max_depth': 48, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 400, 'features': 30}
#             Current best combo (with val score 0.5986):
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 1, 'max_iter': 400, 'features': 22}
#         Has trained 9620 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.4849):
#             {'max_depth': 24, 'max_bins': 64, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 400, 'features': 30}
#             Current best combo (with val score 0.5986):
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 1, 'max_iter': 400, 'features': 22}
#         Has trained 9620 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.4795):
#             {'max_depth': 24, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 400, 'features': 30}
#             Current best combo (with val score 0.5986):
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 1, 'max_iter': 400, 'features': 22}
#         Has trained 9620 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.4344):
#             {'max_depth': 24, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.01, 'l2_regularization': 0.0001, 'max_iter': 400, 'features': 30}
#             Current best combo (with val score 0.5986):
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 1, 'max_iter': 400, 'features': 22}
#         Has trained 9620 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.5229):
#             {'max_depth': 24, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 0.001, 'max_iter': 400, 'features': 30}
#             Current best combo (with val score 0.5986):
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 1, 'max_iter': 400, 'features': 22}
#         Has trained 9620 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.5099):
#             {'max_depth': 24, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 200, 'features': 30}
#             Current best combo (with val score 0.5986):
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 1, 'max_iter': 400, 'features': 22}
#         Has trained 9620 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.5038):
#             {'max_depth': 24, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 400, 'features': 29}
#             Current best combo (with val score 0.5986):
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 1, 'max_iter': 400, 'features': 22}
#         Has trained 9620 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.4992):
#             {'max_depth': 24, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 400, 'features': 31}
#             Current best combo (with val score 0.5986):
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 1, 'max_iter': 400, 'features': 22}
#         Has trained 9620 of 604800 combinations so far
# 	round 247 iteration:  1
#
# Already Trained and Tested combination (val score of 0.5083):
#             {'max_depth': 6, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 400, 'features': 30}
#             Current best combo (with val score 0.5986):
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 1, 'max_iter': 400, 'features': 22}
#         Has trained 9620 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.5057):
#             {'max_depth': 24, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 400, 'features': 30}
#             Current best combo (with val score 0.5986):
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 1, 'max_iter': 400, 'features': 22}
#         Has trained 9620 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.4768):
#             {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 400, 'features': 30}
#             Current best combo (with val score 0.5986):
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 1, 'max_iter': 400, 'features': 22}
#         Has trained 9620 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.4885):
#             {'max_depth': 12, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 400, 'features': 30}
#             Current best combo (with val score 0.5986):
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 1, 'max_iter': 400, 'features': 22}
#         Has trained 9620 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.4316):
#             {'max_depth': 12, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.01, 'l2_regularization': 0.0001, 'max_iter': 400, 'features': 30}
#             Current best combo (with val score 0.5986):
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 1, 'max_iter': 400, 'features': 22}
#         Has trained 9620 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.5199):
#             {'max_depth': 12, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 0.001, 'max_iter': 400, 'features': 30}
#             Current best combo (with val score 0.5986):
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 1, 'max_iter': 400, 'features': 22}
#         Has trained 9620 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.513):
#             {'max_depth': 12, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 200, 'features': 30}
#             Current best combo (with val score 0.5986):
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 1, 'max_iter': 400, 'features': 22}
#         Has trained 9620 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.5106):
#             {'max_depth': 12, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 400, 'features': 29}
#             Current best combo (with val score 0.5986):
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 1, 'max_iter': 400, 'features': 22}
#         Has trained 9620 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.4914):
#             {'max_depth': 12, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 400, 'features': 31}
#             Current best combo (with val score 0.5986):
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 1, 'max_iter': 400, 'features': 22}
#         Has trained 9620 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.5057):
#             {'max_depth': 24, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 400, 'features': 30}
#             Current best combo (with val score 0.5986):
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 1, 'max_iter': 400, 'features': 22}
#         Has trained 9620 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.5057):
#             {'max_depth': 96, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 400, 'features': 30}
#             Current best combo (with val score 0.5986):
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 1, 'max_iter': 400, 'features': 22}
#         Has trained 9620 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.4849):
#             {'max_depth': 48, 'max_bins': 64, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 400, 'features': 30}
#             Current best combo (with val score 0.5986):
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 1, 'max_iter': 400, 'features': 22}
#         Has trained 9620 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.4795):
#             {'max_depth': 48, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 400, 'features': 30}
#             Current best combo (with val score 0.5986):
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 1, 'max_iter': 400, 'features': 22}
#         Has trained 9620 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.4344):
#             {'max_depth': 48, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.01, 'l2_regularization': 0.0001, 'max_iter': 400, 'features': 30}
#             Current best combo (with val score 0.5986):
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 1, 'max_iter': 400, 'features': 22}
#         Has trained 9620 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.5229):
#             {'max_depth': 48, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 0.001, 'max_iter': 400, 'features': 30}
#             Current best combo (with val score 0.5986):
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 1, 'max_iter': 400, 'features': 22}
#         Has trained 9620 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.5099):
#             {'max_depth': 48, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 200, 'features': 30}
#             Current best combo (with val score 0.5986):
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 1, 'max_iter': 400, 'features': 22}
#         Has trained 9620 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.5038):
#             {'max_depth': 48, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 400, 'features': 29}
#             Current best combo (with val score 0.5986):
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 1, 'max_iter': 400, 'features': 22}
#         Has trained 9620 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.501):
#             {'max_depth': 48, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 400, 'features': 31}
#             Current best combo (with val score 0.5986):
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 1, 'max_iter': 400, 'features': 22}
#         Has trained 9620 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.5199):
#             {'max_depth': 12, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 0.001, 'max_iter': 400, 'features': 30}
#             Current best combo (with val score 0.5986):
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 1, 'max_iter': 400, 'features': 22}
#         Has trained 9620 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.5229):
#             {'max_depth': 48, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 0.001, 'max_iter': 400, 'features': 30}
#             Current best combo (with val score 0.5986):
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 1, 'max_iter': 400, 'features': 22}
#         Has trained 9620 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.4796):
#             {'max_depth': 24, 'max_bins': 64, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 0.001, 'max_iter': 400, 'features': 30}
#             Current best combo (with val score 0.5986):
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 1, 'max_iter': 400, 'features': 22}
#         Has trained 9620 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.4799):
#             {'max_depth': 24, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.001, 'max_iter': 400, 'features': 30}
#             Current best combo (with val score 0.5986):
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 1, 'max_iter': 400, 'features': 22}
#         Has trained 9620 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.4337):
#             {'max_depth': 24, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.01, 'l2_regularization': 0.001, 'max_iter': 400, 'features': 30}
#             Current best combo (with val score 0.5986):
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 1, 'max_iter': 400, 'features': 22}
#         Has trained 9620 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.5057):
#             {'max_depth': 24, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 400, 'features': 30}
#             Current best combo (with val score 0.5986):
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 1, 'max_iter': 400, 'features': 22}
#         Has trained 9620 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.5088):
#             {'max_depth': 24, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 0.01, 'max_iter': 400, 'features': 30}
#             Current best combo (with val score 0.5986):
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 1, 'max_iter': 400, 'features': 22}
#         Has trained 9620 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.5209):
#             {'max_depth': 24, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 0.001, 'max_iter': 200, 'features': 30}
#             Current best combo (with val score 0.5986):
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 1, 'max_iter': 400, 'features': 22}
#         Has trained 9620 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.5191):
#             {'max_depth': 24, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 0.001, 'max_iter': 400, 'features': 29}
#             Current best combo (with val score 0.5986):
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 1, 'max_iter': 400, 'features': 22}
#         Has trained 9620 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.4911):
#             {'max_depth': 24, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 0.001, 'max_iter': 400, 'features': 31}
#             Current best combo (with val score 0.5986):
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 1, 'max_iter': 400, 'features': 22}
#         Has trained 9620 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.513):
#             {'max_depth': 12, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 200, 'features': 30}
#             Current best combo (with val score 0.5986):
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 1, 'max_iter': 400, 'features': 22}
#         Has trained 9620 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.5099):
#             {'max_depth': 48, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 200, 'features': 30}
#             Current best combo (with val score 0.5986):
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 1, 'max_iter': 400, 'features': 22}
#         Has trained 9620 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.4227):
#             {'max_depth': 24, 'max_bins': 64, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 200, 'features': 30}
#             Current best combo (with val score 0.5986):
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 1, 'max_iter': 400, 'features': 22}
#         Has trained 9620 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.5357):
#             {'max_depth': 24, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 200, 'features': 30}
#             Current best combo (with val score 0.5986):
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 1, 'max_iter': 400, 'features': 22}
#         Has trained 9620 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.3899):
#             {'max_depth': 24, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.01, 'l2_regularization': 0.0001, 'max_iter': 200, 'features': 30}
#             Current best combo (with val score 0.5986):
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 1, 'max_iter': 400, 'features': 22}
#         Has trained 9620 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.5209):
#             {'max_depth': 24, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 0.001, 'max_iter': 200, 'features': 30}
#             Current best combo (with val score 0.5986):
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 1, 'max_iter': 400, 'features': 22}
#         Has trained 9620 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.4873):
#             {'max_depth': 24, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 100, 'features': 30}
#             Current best combo (with val score 0.5986):
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 1, 'max_iter': 400, 'features': 22}
#         Has trained 9620 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.5057):
#             {'max_depth': 24, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 400, 'features': 30}
#             Current best combo (with val score 0.5986):
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 1, 'max_iter': 400, 'features': 22}
#         Has trained 9620 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.5208):
#             {'max_depth': 24, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 200, 'features': 29}
#             Current best combo (with val score 0.5986):
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 1, 'max_iter': 400, 'features': 22}
#         Has trained 9620 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.4986):
#             {'max_depth': 24, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 200, 'features': 31}
#             Current best combo (with val score 0.5986):
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 1, 'max_iter': 400, 'features': 22}
#         Has trained 9620 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.5106):
#             {'max_depth': 12, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 400, 'features': 29}
#             Current best combo (with val score 0.5986):
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 1, 'max_iter': 400, 'features': 22}
#         Has trained 9620 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.5038):
#             {'max_depth': 48, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 400, 'features': 29}
#             Current best combo (with val score 0.5986):
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 1, 'max_iter': 400, 'features': 22}
#         Has trained 9620 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.4778):
#             {'max_depth': 24, 'max_bins': 64, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 400, 'features': 29}
#             Current best combo (with val score 0.5986):
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 1, 'max_iter': 400, 'features': 22}
#         Has trained 9620 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.4795):
#             {'max_depth': 24, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 400, 'features': 29}
#             Current best combo (with val score 0.5986):
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 1, 'max_iter': 400, 'features': 22}
#         Has trained 9620 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.4344):
#             {'max_depth': 24, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.01, 'l2_regularization': 0.0001, 'max_iter': 400, 'features': 29}
#             Current best combo (with val score 0.5986):
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 1, 'max_iter': 400, 'features': 22}
#         Has trained 9620 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.5191):
#             {'max_depth': 24, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 0.001, 'max_iter': 400, 'features': 29}
#             Current best combo (with val score 0.5986):
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 1, 'max_iter': 400, 'features': 22}
#         Has trained 9620 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.5208):
#             {'max_depth': 24, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 200, 'features': 29}
#             Current best combo (with val score 0.5986):
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 1, 'max_iter': 400, 'features': 22}
#         Has trained 9620 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.5121):
#             {'max_depth': 24, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 400, 'features': 28}
#             Current best combo (with val score 0.5986):
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 1, 'max_iter': 400, 'features': 22}
#         Has trained 9620 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.5057):
#             {'max_depth': 24, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 400, 'features': 30}
#             Current best combo (with val score 0.5986):
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 1, 'max_iter': 400, 'features': 22}
#         Has trained 9620 of 604800 combinations so far
# % Combos Checked Thus Far: 9620 out of 604800 which is 1.590608%
# Cruising Coordrdinate 1418 of 1536
#
# Cruise suspended due to suspicious case
# Guidance: round 248
#
# 	round 248 iteration:  0
#
# Already Trained and Tested combination (val score of 0.5168):
#             {'max_depth': 96, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 30}
#             Current best combo (with val score 0.5986):
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 1, 'max_iter': 400, 'features': 22}
#         Has trained 9620 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.4411):
#             {'max_depth': 192, 'max_bins': 64, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 30}
#             Current best combo (with val score 0.5986):
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 1, 'max_iter': 400, 'features': 22}
#         Has trained 9620 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.5382):
#             {'max_depth': 192, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 30}
#             Current best combo (with val score 0.5986):
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 1, 'max_iter': 400, 'features': 22}
#         Has trained 9620 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.2991):
#             {'max_depth': 192, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.01, 'l2_regularization': 10, 'max_iter': 400, 'features': 30}
#             Current best combo (with val score 0.5986):
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 1, 'max_iter': 400, 'features': 22}
#         Has trained 9620 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.5407):
#             {'max_depth': 192, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 1, 'max_iter': 400, 'features': 30}
#             Current best combo (with val score 0.5986):
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 1, 'max_iter': 400, 'features': 22}
#         Has trained 9620 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.4838):
#             {'max_depth': 192, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 30}
#             Current best combo (with val score 0.5986):
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 1, 'max_iter': 400, 'features': 22}
#         Has trained 9620 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.5214):
# ...
# Trained and Tested combination 9663 of 604800, taking 1.05 seconds to get val score of 0.592:
#                 {'max_depth': 24, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.1, 'max_iter': 400, 'features': 22},
#             Current best combo with val score 0.5986:
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 1, 'max_iter': 400, 'features': 22}
# Trained and Tested combination 9664 of 604800, taking 1.06 seconds to get val score of 0.5277:
#                 {'max_depth': 24, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 22},
#             Current best combo with val score 0.5986:
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 1, 'max_iter': 400, 'features': 22}
# Trained and Tested combination 9665 of 604800, taking 0.45 seconds to get val score of 0.5488:
#                 {'max_depth': 24, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 1, 'max_iter': 200, 'features': 22},
#             Current best combo with val score 0.5986:
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 1, 'max_iter': 400, 'features': 22}
# Already Trained and Tested combination (val score of 0.5962):
#             {'max_depth': 24, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 1, 'max_iter': 400, 'features': 21}
#             Current best combo (with val score 0.5986):
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 1, 'max_iter': 400, 'features': 22}
#         Has trained 9665 of 604800 combinations so far
# Trained and Tested combination 9666 of 604800, taking 0.82 seconds to get val score of 0.5948:
#                 {'max_depth': 24, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 1, 'max_iter': 400, 'features': 23},
#             Current best combo with val score 0.5986:
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 1, 'max_iter': 400, 'features': 22}
# Already Trained and Tested combination (val score of 0.5833):
#             {'max_depth': 6, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 1, 'max_iter': 400, 'features': 21}
#             Current best combo (with val score 0.5986):
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 1, 'max_iter': 400, 'features': 22}
#         Has trained 9666 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.5962):
#             {'max_depth': 24, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 1, 'max_iter': 400, 'features': 21}
#             Current best combo (with val score 0.5986):
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 1, 'max_iter': 400, 'features': 22}
#         Has trained 9666 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.3588):
#             {'max_depth': 12, 'max_bins': 16, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 1, 'max_iter': 400, 'features': 21}
#             Current best combo (with val score 0.5986):
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 1, 'max_iter': 400, 'features': 22}
#         Has trained 9666 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.5472):
#             {'max_depth': 12, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 1, 'max_iter': 400, 'features': 21}
#             Current best combo (with val score 0.5986):
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 1, 'max_iter': 400, 'features': 22}
#         Has trained 9666 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.5563):
#             {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 1, 'max_iter': 400, 'features': 21}
#             Current best combo (with val score 0.5986):
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 1, 'max_iter': 400, 'features': 22}
#         Has trained 9666 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.2761):
#             {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.01, 'l2_regularization': 1, 'max_iter': 400, 'features': 21}
#             Current best combo (with val score 0.5986):
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 1, 'max_iter': 400, 'features': 22}
#         Has trained 9666 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.5873):
#             {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.1, 'max_iter': 400, 'features': 21}
#             Current best combo (with val score 0.5986):
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 1, 'max_iter': 400, 'features': 22}
#         Has trained 9666 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.5229):
#             {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 21}
#             Current best combo (with val score 0.5986):
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 1, 'max_iter': 400, 'features': 22}
#         Has trained 9666 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.5438):
#             {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 1, 'max_iter': 200, 'features': 21}
#             Current best combo (with val score 0.5986):
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 1, 'max_iter': 400, 'features': 22}
#         Has trained 9666 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.5902):
#             {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 1, 'max_iter': 400, 'features': 20}
#             Current best combo (with val score 0.5986):
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 1, 'max_iter': 400, 'features': 22}
#         Has trained 9666 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.5986):
#             {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 1, 'max_iter': 400, 'features': 22}
#             Current best combo (with val score 0.5986):
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 1, 'max_iter': 400, 'features': 22}
#         Has trained 9666 of 604800 combinations so far
# Trained and Tested combination 9667 of 604800, taking 0.77 seconds to get val score of 0.5868:
#                 {'max_depth': 6, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 1, 'max_iter': 400, 'features': 23},
#             Current best combo with val score 0.5986:
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 1, 'max_iter': 400, 'features': 22}
# Already Trained and Tested combination (val score of 0.5948):
#             {'max_depth': 24, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 1, 'max_iter': 400, 'features': 23}
#             Current best combo (with val score 0.5986):
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 1, 'max_iter': 400, 'features': 22}
#         Has trained 9667 of 604800 combinations so far
# Trained and Tested combination 9668 of 604800, taking 0.75 seconds to get val score of 0.3588:
#                 {'max_depth': 12, 'max_bins': 16, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 1, 'max_iter': 400, 'features': 23},
#             Current best combo with val score 0.5986:
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 1, 'max_iter': 400, 'features': 22}
# Trained and Tested combination 9669 of 604800, taking 1.03 seconds to get val score of 0.5466:
#                 {'max_depth': 12, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 1, 'max_iter': 400, 'features': 23},
#             Current best combo with val score 0.5986:
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 1, 'max_iter': 400, 'features': 22}
# Trained and Tested combination 9670 of 604800, taking 1.33 seconds to get val score of 0.5582:
#                 {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 1, 'max_iter': 400, 'features': 23},
#             Current best combo with val score 0.5986:
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 1, 'max_iter': 400, 'features': 22}
# Trained and Tested combination 9671 of 604800, taking 1.07 seconds to get val score of 0.2761:
#                 {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.01, 'l2_regularization': 1, 'max_iter': 400, 'features': 23},
#             Current best combo with val score 0.5986:
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 1, 'max_iter': 400, 'features': 22}
# Trained and Tested combination 9672 of 604800, taking 0.85 seconds to get val score of 0.5874:
#                 {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.1, 'max_iter': 400, 'features': 23},
#             Current best combo with val score 0.5986:
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 1, 'max_iter': 400, 'features': 22}
# Trained and Tested combination 9673 of 604800, taking 0.84 seconds to get val score of 0.5229:
#                 {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 23},
#             Current best combo with val score 0.5986:
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 1, 'max_iter': 400, 'features': 22}
# Trained and Tested combination 9674 of 604800, taking 0.62 seconds to get val score of 0.5438:
#                 {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 1, 'max_iter': 200, 'features': 23},
#             Current best combo with val score 0.5986:
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 1, 'max_iter': 400, 'features': 22}
# Already Trained and Tested combination (val score of 0.5986):
#             {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 1, 'max_iter': 400, 'features': 22}
#             Current best combo (with val score 0.5986):
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 1, 'max_iter': 400, 'features': 22}
#         Has trained 9674 of 604800 combinations so far
# Trained and Tested combination 9675 of 604800, taking 1.03 seconds to get val score of 0.5986:
#                 {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 1, 'max_iter': 400, 'features': 24},
#             Current best combo with val score 0.5986:
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 1, 'max_iter': 400, 'features': 22}
# % Combos Checked Thus Far: 9675 out of 604800 which is 1.5997020000000002%
# Max Val Score:
#  0.59856
# Max Val Score Std:
#  0.038777
# Best Combo Train Score:
#  0.925277
# Best Combo Train Score Std:
#  0.001522
# Max Combo Index:
#  (2, 2, 0, 4, 4, 4, 22) out of [7, 4, 2, 5, 6, 5, 72] (note best combo is 0-indexed)
# Max Combo Hyperparamer Combination:
#  {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 1, 'max_iter': 400, 'features': 22}
# Max Combo Features:
#  ('procedure_225469', 'lods_score', 'procedure_224274', 'marital_status_0', 'marital_status_DIVORCED', 'marital_status_MARRIED', 'marital_status_WIDOWED', 'marital_status_SINGLE', 'procedure_223253', 'race_AMERICAN INDIAN/ALASKA NATIVE', 'race_ASIAN', 'race_ASIAN - ASIAN INDIAN', 'race_ASIAN - CHINESE', 'race_ASIAN - KOREAN', 'race_ASIAN - SOUTH EAST ASIAN', 'race_BLACK/AFRICAN', 'race_BLACK/AFRICAN AMERICAN', 'race_BLACK/CAPE VERDEAN', 'race_BLACK/CARIBBEAN ISLAND', 'race_HISPANIC OR LATINO', 'race_HISPANIC/LATINO - CENTRAL AMERICAN', 'race_HISPANIC/LATINO - COLUMBIAN', 'race_HISPANIC/LATINO - CUBAN', 'race_HISPANIC/LATINO - DOMINICAN', 'race_HISPANIC/LATINO - GUATEMALAN', 'race_HISPANIC/LATINO - HONDURAN', 'race_HISPANIC/LATINO - MEXICAN', 'race_HISPANIC/LATINO - PUERTO RICAN', 'race_HISPANIC/LATINO - SALVADORAN', 'race_MULTIPLE RACE/ETHNICITY', 'race_NATIVE HAWAIIAN OR OTHER PACIFIC ISLANDER', 'race_OTHER', 'race_PATIENT DECLINED TO ANSWER', 'race_PORTUGUESE', 'race_SOUTH AMERICAN', 'race_UNABLE TO OBTAIN', 'race_UNKNOWN', 'race_WHITE', 'race_WHITE - BRAZILIAN', 'race_WHITE - EASTERN EUROPEAN', 'race_WHITE - RUSSIAN', 'race_WHITE - OTHER EUROPEAN', 'procedure_227712', 'procedure_224276', 'admission_type_DIRECT OBSERVATION', 'admission_type_ELECTIVE', 'admission_type_EU OBSERVATION', 'admission_type_EW EMER.', 'admission_type_OBSERVATION ADMIT', 'admission_type_SURGICAL SAME DAY ADMISSION', 'admission_type_URGENT', 'admission_type_DIRECT EMER.', 'insurance_Medicare', 'insurance_Other', 'insurance_Medicaid', 'procedure_225792', 'procedure_228130', 'procedure_225817', 'procedure_224267', 'gender_F', 'gender_M', 'ventilation_used', 'hospital_stay_duration', 'oasis_score', 'procedure_228125', 'procedure_226124', 'procedure_225451', 'procedure_224275', 'procedure_229582')
# % Combos Checked: 9675 out of 604800 which is 1.5997020000000002%
