# %% [markdown]
# # Tuning Script

# %%
# Parameters subject to change in every script - involved in naming

MODEL = 'knnc'
PREPROCESSING = 'normalise'
TUNER = 'yangzhoub'
OPTIMISED_METRIC = 'f1'

# %% [markdown]
# ---

# %%
# detect whether this is a google environment

COLAB_ENVIRONMENT = False

try:
    from google.colab import drive
    drive.mount('/content/drive')
    COLAB_ENVIRONMENT = True
except:
    pass
# Out:
# Mounted at /content/drive

# %%
import sys
import os
import pickle

if COLAB_ENVIRONMENT:
    home_directory = './drive/MyDrive/LAB/COMP90089__GroupWork__Py/' # my home directory is stored in ./LAB of google drive
    if MODEL == 'ebr':
        # !pip install interpret==0.5.0
    elif MODEL == 'cbr':
        # !pip install catboost
    elif MODEL in ['tf', 'mlp']:
        # !pip install PyTorch2Sklearn
    # !pip install JXAutoML
else:
    home_directory = '../../'

from JXAutoML.YangZhouB_10CV import YangZhouB_10CV as Tuner

import pandas as pd
# Out:
# Collecting JXAutoML
#   Downloading JXAutoML-0.4.4-py3-none-any.whl.metadata (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.2/67.2 kB 679.1 kB/s eta 0:00:00
# Downloading JXAutoML-0.4.4-py3-none-any.whl (52 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.1/52.1 kB 1.9 MB/s eta 0:00:00
# Installing collected packages: JXAutoML
# Successfully installed JXAutoML-0.4.4

# %%
# Parameters that are same for every script

FOLDS = 10  # we have decided to do 10 fold validation

SEED = 42

TASK_TYPE = 'Classification'  # this task is a classification task

# we have decided to tune features as hp
TUNE_FEATURES_AS_HYPERPARAMETERS = True

# %% [markdown]
# ---

# %%
# model to use to tune
from sklearn.neighbors import KNeighborsClassifier as clf

# what values to try for each hyperparameter
parameter_choices = {
    'n_neighbors': [i for i in range(1, 101)],
    'p': (1, 2),
    'weights': ('uniform', 'distance')
}

# what values to set non-tuneable parameters/hyperparameters
non_tunable_hyperparameters_dict = {
                                    'n_jobs': -1
                                    }

# %% [markdown]
# ---

# %% [markdown]
# Read in and Prepare Data

# %%
# Import data and store as lists

train_x_list = []
train_y_list = []
val_x_list = []
val_y_list = []

for i in range(FOLDS):
    train_data = pd.read_csv(
        f'{home_directory}data/curated/modelling/{PREPROCESSING}/train_{i}.csv')
    val_data = pd.read_csv(
        f'{home_directory}data/curated/modelling/{PREPROCESSING}/val_{i}.csv')

    # get the correct rows for X and y
    train_x = train_data.drop(
        ['mortality_status', 'subject_id', 'hadm_id', 'stay_id'], axis=1)
    train_y = train_data['mortality_status']
    val_x = val_data.drop(
        ['mortality_status', 'subject_id', 'hadm_id', 'stay_id'], axis=1)
    val_y = val_data['mortality_status']

    train_x_list.append(train_x)
    train_y_list.append(train_y)
    val_x_list.append(val_x)
    val_y_list.append(val_y)

# %%
# Import feature importance ordering

with open(f'{home_directory}models/xgb_feature_importance_ordering_{PREPROCESSING}.pickle', 'rb') as f:
    feature_importance_ordering = pickle.load(f)

# %% [markdown]
# Set parameters

# %%
# initialisation
tuner = Tuner()

print('---')

# define what model we are tuning
tuner.read_in_model(clf, TASK_TYPE, optimised_metric=OPTIMISED_METRIC)

print('---')

# read in the data for training and validation
tuner.read_in_data(train_x_list, train_y_list, val_x_list, val_y_list)

print('---')

# set what hp values to tune
tuner.set_hyperparameters(parameter_choices)
# WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

# set up hp values that need to be changed from default but NOT to be tuned
tuner.set_non_tuneable_hyperparameters(non_tunable_hyperparameters_dict)

print('---')

# set up feature importance ordering

if TUNE_FEATURES_AS_HYPERPARAMETERS:
    tuner.set_features(feature_importance_ordering)
    # WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

try:  # try to read in previous results to continue tuning ...
    tuner.read_in_tuning_result_df(
        f'{home_directory}models/tuning/{TUNER}_{MODEL}_{PREPROCESSING}.csv')
except:
    print('No previous tuning data read in')

print('---')

# set up where to save the tuning result csv
tuner.set_tuning_result_saving_address(
    f'{home_directory}models/tuning/{TUNER}_{MODEL}_{PREPROCESSING}.csv')

print('---')

# set up where to save the current best model
tuner.set_best_model_saving_address(
    f'{home_directory}models/tmp_models/{TUNER}_{MODEL}_{PREPROCESSING}')
# Out:
# YangZhouB Initialised
# ---
# Successfully read in model <class 'sklearn.neighbors._classification.KNeighborsClassifier'>, which is a Classification model optimising for f1
# ---
# Read in Train X data list
# Read in Train y data list
# Read in Val X data list
# Read in Val y data list
# ---
# Successfully recorded hyperparameter choices
# ---
# Successfully recorded non_tuneable_hyperparameter choices
# ---
# Successfully recorded tuneable feature combination choices and updated relevant internal structures
# ---
# No previous tuning data read in
# ---
# Successfully set tuning output address
# ---
# Successfully set best model output address

# %%
# ignore warnings

import warnings
warnings.filterwarnings("ignore")

# %%
# begin tuning ... (or continue training)

tuner.tune()
# Out:
# Streaming output truncated to the last 5000 lines.
#                 {'n_neighbors': 100, 'p': 1, 'weights': 'distance', 'features': 40},
#             Current best combo with val score 0.3989:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 5}
# Trained and Tested combination 424 of 20400, taking 0.0 seconds to get val score of 0.0:
#                 {'n_neighbors': 96, 'p': 2, 'weights': 'distance', 'features': 40},
#             Current best combo with val score 0.3989:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 5}
# Trained and Tested combination 425 of 20400, taking 0.0 seconds to get val score of 0.0:
#                 {'n_neighbors': 26, 'p': 1, 'weights': 'distance', 'features': 25},
#             Current best combo with val score 0.3989:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 5}
# Trained and Tested combination 426 of 20400, taking 0.0 seconds to get val score of 0.0:
#                 {'n_neighbors': 91, 'p': 2, 'weights': 'uniform', 'features': 35},
#             Current best combo with val score 0.3989:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 5}
# Trained and Tested combination 427 of 20400, taking 0.0 seconds to get val score of 0.0:
#                 {'n_neighbors': 56, 'p': 2, 'weights': 'uniform', 'features': 0},
#             Current best combo with val score 0.3989:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 5}
# Trained and Tested combination 428 of 20400, taking 0.01 seconds to get val score of 0.0:
#                 {'n_neighbors': 41, 'p': 2, 'weights': 'uniform', 'features': 45},
#             Current best combo with val score 0.3989:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 5}
# Trained and Tested combination 429 of 20400, taking 0.0 seconds to get val score of 0.0:
#                 {'n_neighbors': 66, 'p': 2, 'weights': 'uniform', 'features': 30},
#             Current best combo with val score 0.3989:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 5}
# Trained and Tested combination 430 of 20400, taking 0.01 seconds to get val score of 0.0:
#                 {'n_neighbors': 91, 'p': 2, 'weights': 'uniform', 'features': 15},
#             Current best combo with val score 0.3989:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 5}
# Trained and Tested combination 431 of 20400, taking 0.0 seconds to get val score of 0.2591:
#                 {'n_neighbors': 71, 'p': 1, 'weights': 'distance', 'features': 10},
#             Current best combo with val score 0.3989:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 5}
# Trained and Tested combination 432 of 20400, taking 0.0 seconds to get val score of 0.0:
#                 {'n_neighbors': 91, 'p': 2, 'weights': 'uniform', 'features': 0},
#             Current best combo with val score 0.3989:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 5}
# Trained and Tested combination 433 of 20400, taking 0.0 seconds to get val score of 0.2874:
#                 {'n_neighbors': 86, 'p': 1, 'weights': 'uniform', 'features': 5},
#             Current best combo with val score 0.3989:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 5}
# Trained and Tested combination 434 of 20400, taking 0.0 seconds to get val score of 0.1544:
#                 {'n_neighbors': 86, 'p': 2, 'weights': 'distance', 'features': 10},
#             Current best combo with val score 0.3989:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 5}
# Trained and Tested combination 435 of 20400, taking 0.0 seconds to get val score of 0.0:
#                 {'n_neighbors': 21, 'p': 2, 'weights': 'distance', 'features': 20},
#             Current best combo with val score 0.3989:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 5}
# Trained and Tested combination 436 of 20400, taking 0.0 seconds to get val score of 0.0:
#                 {'n_neighbors': 61, 'p': 2, 'weights': 'distance', 'features': 45},
#             Current best combo with val score 0.3989:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 5}
# Trained and Tested combination 437 of 20400, taking 0.01 seconds to get val score of 0.0:
#                 {'n_neighbors': 31, 'p': 2, 'weights': 'uniform', 'features': 35},
#             Current best combo with val score 0.3989:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 5}
# Trained and Tested combination 438 of 20400, taking 0.01 seconds to get val score of 0.0:
#                 {'n_neighbors': 96, 'p': 1, 'weights': 'distance', 'features': 50},
#             Current best combo with val score 0.3989:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 5}
# Trained and Tested combination 439 of 20400, taking 0.0 seconds to get val score of 0.0:
#                 {'n_neighbors': 46, 'p': 2, 'weights': 'uniform', 'features': 50},
#             Current best combo with val score 0.3989:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 5}
# Trained and Tested combination 440 of 20400, taking 0.0 seconds to get val score of 0.0:
#                 {'n_neighbors': 91, 'p': 2, 'weights': 'uniform', 'features': 45},
#             Current best combo with val score 0.3989:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 5}
# Trained and Tested combination 441 of 20400, taking 0.01 seconds to get val score of 0.0352:
#                 {'n_neighbors': 16, 'p': 1, 'weights': 'distance', 'features': 15},
#             Current best combo with val score 0.3989:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 5}
# Trained and Tested combination 442 of 20400, taking 0.01 seconds to get val score of 0.0:
#                 {'n_neighbors': 96, 'p': 1, 'weights': 'distance', 'features': 45},
#             Current best combo with val score 0.3989:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 5}
# Trained and Tested combination 443 of 20400, taking 0.0 seconds to get val score of 0.2773:
#                 {'n_neighbors': 31, 'p': 1, 'weights': 'uniform', 'features': 10},
#             Current best combo with val score 0.3989:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 5}
# Trained and Tested combination 444 of 20400, taking 0.0 seconds to get val score of 0.0:
#                 {'n_neighbors': 61, 'p': 1, 'weights': 'distance', 'features': 25},
#             Current best combo with val score 0.3989:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 5}
# Trained and Tested combination 445 of 20400, taking 0.01 seconds to get val score of 0.0:
#                 {'n_neighbors': 71, 'p': 2, 'weights': 'distance', 'features': 45},
#             Current best combo with val score 0.3989:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 5}
# Trained and Tested combination 446 of 20400, taking 0.0 seconds to get val score of 0.0:
#                 {'n_neighbors': 91, 'p': 1, 'weights': 'uniform', 'features': 50},
#             Current best combo with val score 0.3989:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 5}
# Trained and Tested combination 447 of 20400, taking 0.0 seconds to get val score of 0.0922:
#                 {'n_neighbors': 86, 'p': 2, 'weights': 'uniform', 'features': 10},
#             Current best combo with val score 0.3989:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 5}
# Trained and Tested combination 448 of 20400, taking 0.01 seconds to get val score of 0.0:
#                 {'n_neighbors': 46, 'p': 2, 'weights': 'distance', 'features': 20},
#             Current best combo with val score 0.3989:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 5}
# Trained and Tested combination 449 of 20400, taking 0.0 seconds to get val score of 0.2535:
#                 {'n_neighbors': 46, 'p': 1, 'weights': 'uniform', 'features': 10},
#             Current best combo with val score 0.3989:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 5}
# Trained and Tested combination 450 of 20400, taking 0.01 seconds to get val score of 0.0:
#                 {'n_neighbors': 31, 'p': 2, 'weights': 'uniform', 'features': 45},
#             Current best combo with val score 0.3989:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 5}
# Trained and Tested combination 451 of 20400, taking 0.0 seconds to get val score of 0.0:
#                 {'n_neighbors': 81, 'p': 1, 'weights': 'uniform', 'features': 40},
#             Current best combo with val score 0.3989:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 5}
# Trained and Tested combination 452 of 20400, taking 0.0 seconds to get val score of 0.0:
#                 {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 20},
#             Current best combo with val score 0.3989:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 5}
# Trained and Tested combination 453 of 20400, taking 0.0 seconds to get val score of 0.1941:
#                 {'n_neighbors': 1, 'p': 1, 'weights': 'distance', 'features': 20},
#             Current best combo with val score 0.3989:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 5}
# Trained and Tested combination 454 of 20400, taking 0.0 seconds to get val score of 0.3746:
#                 {'n_neighbors': 1, 'p': 1, 'weights': 'uniform', 'features': 10},
#             Current best combo with val score 0.3989:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 5}
# Trained and Tested combination 455 of 20400, taking 0.0 seconds to get val score of 0.0226:
#                 {'n_neighbors': 31, 'p': 1, 'weights': 'distance', 'features': 20},
#             Current best combo with val score 0.3989:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 5}
# Trained and Tested combination 456 of 20400, taking 0.0 seconds to get val score of 0.1522:
#                 {'n_neighbors': 96, 'p': 2, 'weights': 'distance', 'features': 10},
#             Current best combo with val score 0.3989:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 5}
# Trained and Tested combination 457 of 20400, taking 0.0 seconds to get val score of 0.0:
#                 {'n_neighbors': 36, 'p': 2, 'weights': 'uniform', 'features': 45},
#             Current best combo with val score 0.3989:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 5}
# Trained and Tested combination

#             Current best combo with val score 0.3989:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 5}
# Trained and Tested combination 539 of 20400, taking 0.0 seconds to get val score of 0.0404:
#                 {'n_neighbors': 11, 'p': 2, 'weights': 'uniform', 'features': 0},
#             Current best combo with val score 0.3989:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 5}
# Trained and Tested combination 540 of 20400, taking 0.0 seconds to get val score of 0.0:
#                 {'n_neighbors': 26, 'p': 2, 'weights': 'uniform', 'features': 0},
#             Current best combo with val score 0.3989:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 5}
# Trained and Tested combination 541 of 20400, taking 0.0 seconds to get val score of 0.0:
#                 {'n_neighbors': 31, 'p': 2, 'weights': 'uniform', 'features': 20},
#             Current best combo with val score 0.3989:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 5}
# Trained and Tested combination 542 of 20400, taking 0.01 seconds to get val score of 0.0:
#                 {'n_neighbors': 46, 'p': 1, 'weights': 'uniform', 'features': 20},
#             Current best combo with val score 0.3989:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 5}
# Trained and Tested combination 543 of 20400, taking 0.0 seconds to get val score of 0.0:
#                 {'n_neighbors': 71, 'p': 2, 'weights': 'uniform', 'features': 15},
#             Current best combo with val score 0.3989:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 5}
# Trained and Tested combination 544 of 20400, taking 0.0 seconds to get val score of 0.0:
#                 {'n_neighbors': 86, 'p': 1, 'weights': 'uniform', 'features': 35},
#             Current best combo with val score 0.3989:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 5}
# Trained and Tested combination 545 of 20400, taking 0.0 seconds to get val score of 0.0:
#                 {'n_neighbors': 81, 'p': 2, 'weights': 'uniform', 'features': 35},
#             Current best combo with val score 0.3989:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 5}
# Trained and Tested combination 546 of 20400, taking 0.0 seconds to get val score of 0.0133:
#                 {'n_neighbors': 26, 'p': 1, 'weights': 'uniform', 'features': 20},
#             Current best combo with val score 0.3989:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 5}
# Trained and Tested combination 547 of 20400, taking 0.0 seconds to get val score of 0.0:
#                 {'n_neighbors': 46, 'p': 2, 'weights': 'uniform', 'features': 45},
#             Current best combo with val score 0.3989:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 5}
# Trained and Tested combination 548 of 20400, taking 0.0 seconds to get val score of 0.0:
#                 {'n_neighbors': 11, 'p': 2, 'weights': 'uniform', 'features': 45},
#             Current best combo with val score 0.3989:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 5}
# Trained and Tested combination 549 of 20400, taking 0.0 seconds to get val score of 0.0:
#                 {'n_neighbors': 36, 'p': 1, 'weights': 'uniform', 'features': 50},
#             Current best combo with val score 0.3989:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 5}
# Trained and Tested combination 550 of 20400, taking 0.01 seconds to get val score of 0.0:
#                 {'n_neighbors': 21, 'p': 2, 'weights': 'uniform', 'features': 40},
#             Current best combo with val score 0.3989:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 5}
# Trained and Tested combination 551 of 20400, taking 0.0 seconds to get val score of 0.0:
#                 {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 45},
#             Current best combo with val score 0.3989:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 5}
# Trained and Tested combination 552 of 20400, taking 0.0 seconds to get val score of 0.0:
#                 {'n_neighbors': 66, 'p': 1, 'weights': 'uniform', 'features': 0},
#             Current best combo with val score 0.3989:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 5}
# Trained and Tested combination 553 of 20400, taking 0.0 seconds to get val score of 0.0:
#                 {'n_neighbors': 61, 'p': 1, 'weights': 'uniform', 'features': 50},
#             Current best combo with val score 0.3989:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 5}
# Trained and Tested combination 554 of 20400, taking 0.0 seconds to get val score of 0.0:
#                 {'n_neighbors': 41, 'p': 1, 'weights': 'distance', 'features': 40},
#             Current best combo with val score 0.3989:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 5}
# Trained and Tested combination 555 of 20400, taking 0.0 seconds to get val score of 0.0:
#                 {'n_neighbors': 36, 'p': 2, 'weights': 'distance', 'features': 15},
#             Current best combo with val score 0.3989:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 5}
# Trained and Tested combination 556 of 20400, taking 0.0 seconds to get val score of 0.0:
#                 {'n_neighbors': 91, 'p': 2, 'weights': 'distance', 'features': 15},
#             Current best combo with val score 0.3989:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 5}
# Trained and Tested combination 557 of 20400, taking 0.0 seconds to get val score of 0.0:
#                 {'n_neighbors': 81, 'p': 2, 'weights': 'distance', 'features': 50},
#             Current best combo with val score 0.3989:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 5}
# Trained and Tested combination 558 of 20400, taking 0.0 seconds to get val score of 0.0:
#                 {'n_neighbors': 96, 'p': 2, 'weights': 'uniform', 'features': 40},
#             Current best combo with val score 0.3989:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 5}
# Trained and Tested combination 559 of 20400, taking 0.0 seconds to get val score of 0.0:
#                 {'n_neighbors': 31, 'p': 2, 'weights': 'distance', 'features': 25},
#             Current best combo with val score 0.3989:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 5}
# Trained and Tested combination 560 of 20400, taking 0.0 seconds to get val score of 0.0:
#                 {'n_neighbors': 86, 'p': 2, 'weights': 'uniform', 'features': 35},
#             Current best combo with val score 0.3989:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 5}
# Trained and Tested combination 561 of 20400, taking 0.0 seconds to get val score of 0.0:
#                 {'n_neighbors': 81, 'p': 1, 'weights': 'uniform', 'features': 35},
#             Current best combo with val score 0.3989:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 5}
# Trained and Tested combination 562 of 20400, taking 0.0 seconds to get val score of 0.0:
#                 {'n_neighbors': 46, 'p': 1, 'weights': 'distance', 'features': 0},
#             Current best combo with val score 0.3989:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 5}
# Trained and Tested combination 563 of 20400, taking 0.0 seconds to get val score of 0.0602:
#                 {'n_neighbors': 11, 'p': 1, 'weights': 'distance', 'features': 15},
#             Current best combo with val score 0.3989:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 5}
# Trained and Tested combination 564 of 20400, taking 0.0 seconds to get val score of 0.0:
#                 {'n_neighbors': 91, 'p': 1, 'weights': 'uniform', 'features': 20},
#             Current best combo with val score 0.3989:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 5}
# Trained and Tested combination 565 of 20400, taking 0.0 seconds to get val score of 0.3597:
#                 {'n_neighbors': 16, 'p': 1, 'weights': 'distance', 'features': 5},
#             Current best combo with val score 0.3989:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 5}
# Trained and Tested combination 566 of 20400, taking 0.0 seconds to get val score of 0.0:
#                 {'n_neighbors': 81, 'p': 1, 'weights': 'uniform', 'features': 15},
#             Current best combo with val score 0.3989:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 5}
# Trained and Tested combination 567 of 20400, taking 0.01 seconds to get val score of 0.0:
#                 {'n_neighbors': 100, 'p': 1, 'weights': 'uniform', 'features': 30},
#             Current best combo with val score 0.3989:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 5}
# Trained and Tested combination 568 of 20400, taking 0.0 seconds to get val score of 0.0:
#                 {'n_neighbors': 6, 'p': 2, 'weights': 'uniform', 'features': 30},
#             Current best combo with val score 0.3989:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 5}
# Trained and Tested combination 569 of 20400, taking 0.0 seconds to get val score of 0.0:
#                 {'n_neighbors': 36, 'p': 2, 'weights': 'uniform', 'features': 40},
#             Current best combo with val score 0.3989:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 5}
# Trained and Tested combination 570 of 20400, taking 0.0 seconds to get val score of 0.0:
#                 {'n_neighbors': 76, 'p': 2, 'weights': 'distance', 'features': 35},
#             Current best combo with val score 0.3989:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 5}
# Trained and Tested combination 571 of 20400, taking 0.0 seconds to get val score of 0.1844:
#                 {'n_neighbors': 46, 'p': 2, 'weights': 'distance', 'features': 5},
#             Current best combo with val score 0.3989:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 5}
# Trained and Tested combination 572 of 20400, taking 0.01 seconds to get val score of 0.0:
#                 {'n_neighbors': 76, 'p': 2, 'weights': 'uniform', 'features': 25},
#             Current best combo with val score 0.3989:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 5}
# Trained and Tested combination 573 of 20400, taking 0.0 seconds to get val score of 0.0:
#                 {'n_neighbors': 46, 'p': 2, 'weights': 'uniform', 'features': 35},
#             Current best combo with val score 0.3989:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 5}
# Trained and Tested combination 574 of 20400, taking 0.01 seconds to get val score of 0.0:
#                 {'n_neighbors': 91, 'p': 1, 'weights': 'distance', 'features': 20},
#             Current best combo with val score 0.3989:
# ...
#         Has trained 1024 of 20400 combinations so far
# Already Trained and Tested combination (val score of 0.4185):
#             {'n_neighbors': 4, 'p': 2, 'weights': 'distance', 'features': 7}
#             Current best combo (with val score 0.423):
#                     {'n_neighbors': 4, 'p': 2, 'weights': 'distance', 'features': 6}
#         Has trained 1024 of 20400 combinations so far
# 	round FINAL iteration:  1
#
# Already Trained and Tested combination (val score of 0.4096):
#             {'n_neighbors': 3, 'p': 1, 'weights': 'distance', 'features': 6}
#             Current best combo (with val score 0.423):
#                     {'n_neighbors': 4, 'p': 2, 'weights': 'distance', 'features': 6}
#         Has trained 1024 of 20400 combinations so far
# Already Trained and Tested combination (val score of 0.4032):
#             {'n_neighbors': 5, 'p': 1, 'weights': 'distance', 'features': 6}
#             Current best combo (with val score 0.423):
#                     {'n_neighbors': 4, 'p': 2, 'weights': 'distance', 'features': 6}
#         Has trained 1024 of 20400 combinations so far
# Already Trained and Tested combination (val score of 0.423):
#             {'n_neighbors': 4, 'p': 2, 'weights': 'distance', 'features': 6}
#             Current best combo (with val score 0.423):
#                     {'n_neighbors': 4, 'p': 2, 'weights': 'distance', 'features': 6}
#         Has trained 1024 of 20400 combinations so far
# Already Trained and Tested combination (val score of 0.3514):
#             {'n_neighbors': 4, 'p': 1, 'weights': 'uniform', 'features': 6}
#             Current best combo (with val score 0.423):
#                     {'n_neighbors': 4, 'p': 2, 'weights': 'distance', 'features': 6}
#         Has trained 1024 of 20400 combinations so far
# Already Trained and Tested combination (val score of 0.4176):
#             {'n_neighbors': 4, 'p': 1, 'weights': 'distance', 'features': 5}
#             Current best combo (with val score 0.423):
#                     {'n_neighbors': 4, 'p': 2, 'weights': 'distance', 'features': 6}
#         Has trained 1024 of 20400 combinations so far
# Already Trained and Tested combination (val score of 0.4185):
#             {'n_neighbors': 4, 'p': 1, 'weights': 'distance', 'features': 7}
#             Current best combo (with val score 0.423):
#                     {'n_neighbors': 4, 'p': 2, 'weights': 'distance', 'features': 6}
#         Has trained 1024 of 20400 combinations so far
# Trained and Tested combination 1025 of 20400, taking 0.0 seconds to get val score of 0.4151:
#                 {'n_neighbors': 3, 'p': 2, 'weights': 'distance', 'features': 5},
#             Current best combo with val score 0.423:
#                     {'n_neighbors': 4, 'p': 2, 'weights': 'distance', 'features': 6}
# Already Trained and Tested combination (val score of 0.3909):
#             {'n_neighbors': 5, 'p': 2, 'weights': 'distance', 'features': 5}
#             Current best combo (with val score 0.423):
#                     {'n_neighbors': 4, 'p': 2, 'weights': 'distance', 'features': 6}
#         Has trained 1025 of 20400 combinations so far
# Already Trained and Tested combination (val score of 0.4176):
#             {'n_neighbors': 4, 'p': 1, 'weights': 'distance', 'features': 5}
#             Current best combo (with val score 0.423):
#                     {'n_neighbors': 4, 'p': 2, 'weights': 'distance', 'features': 6}
#         Has trained 1025 of 20400 combinations so far
# Trained and Tested combination 1026 of 20400, taking 0.0 seconds to get val score of 0.3311:
#                 {'n_neighbors': 4, 'p': 2, 'weights': 'uniform', 'features': 5},
#             Current best combo with val score 0.423:
#                     {'n_neighbors': 4, 'p': 2, 'weights': 'distance', 'features': 6}
# Trained and Tested combination 1027 of 20400, taking 0.0 seconds to get val score of 0.0281:
#                 {'n_neighbors': 4, 'p': 2, 'weights': 'distance', 'features': 4},
#             Current best combo with val score 0.423:
#                     {'n_neighbors': 4, 'p': 2, 'weights': 'distance', 'features': 6}
# Already Trained and Tested combination (val score of 0.423):
#             {'n_neighbors': 4, 'p': 2, 'weights': 'distance', 'features': 6}
#             Current best combo (with val score 0.423):
#                     {'n_neighbors': 4, 'p': 2, 'weights': 'distance', 'features': 6}
#         Has trained 1027 of 20400 combinations so far
# Trained and Tested combination 1028 of 20400, taking 0.0 seconds to get val score of 0.4171:
#                 {'n_neighbors': 3, 'p': 2, 'weights': 'distance', 'features': 7},
#             Current best combo with val score 0.423:
#                     {'n_neighbors': 4, 'p': 2, 'weights': 'distance', 'features': 6}
# Trained and Tested combination 1029 of 20400, taking 0.0 seconds to get val score of 0.3851:
#                 {'n_neighbors': 5, 'p': 2, 'weights': 'distance', 'features': 7},
#             Current best combo with val score 0.423:
#                     {'n_neighbors': 4, 'p': 2, 'weights': 'distance', 'features': 6}
# Already Trained and Tested combination (val score of 0.4185):
#             {'n_neighbors': 4, 'p': 1, 'weights': 'distance', 'features': 7}
#             Current best combo (with val score 0.423):
#                     {'n_neighbors': 4, 'p': 2, 'weights': 'distance', 'features': 6}
#         Has trained 1029 of 20400 combinations so far
# Trained and Tested combination 1030 of 20400, taking 0.0 seconds to get val score of 0.3294:
#                 {'n_neighbors': 4, 'p': 2, 'weights': 'uniform', 'features': 7},
#             Current best combo with val score 0.423:
#                     {'n_neighbors': 4, 'p': 2, 'weights': 'distance', 'features': 6}
# Already Trained and Tested combination (val score of 0.423):
#             {'n_neighbors': 4, 'p': 2, 'weights': 'distance', 'features': 6}
#             Current best combo (with val score 0.423):
#                     {'n_neighbors': 4, 'p': 2, 'weights': 'distance', 'features': 6}
#         Has trained 1030 of 20400 combinations so far
# Trained and Tested combination 1031 of 20400, taking 0.0 seconds to get val score of 0.4263:
#                 {'n_neighbors': 4, 'p': 2, 'weights': 'distance', 'features': 8},
#             Current best combo with val score 0.4263:
#                     {'n_neighbors': 4, 'p': 2, 'weights': 'distance', 'features': 8}
# Trained and Tested combination 1032 of 20400, taking 0.0 seconds to get val score of 0.4214:
#                 {'n_neighbors': 3, 'p': 2, 'weights': 'distance', 'features': 8},
#             Current best combo with val score 0.4263:
#                     {'n_neighbors': 4, 'p': 2, 'weights': 'distance', 'features': 8}
# Trained and Tested combination 1033 of 20400, taking 0.0 seconds to get val score of 0.3846:
#                 {'n_neighbors': 5, 'p': 2, 'weights': 'distance', 'features': 8},
#             Current best combo with val score 0.4263:
#                     {'n_neighbors': 4, 'p': 2, 'weights': 'distance', 'features': 8}
# Trained and Tested combination 1034 of 20400, taking 0.0 seconds to get val score of 0.4218:
#                 {'n_neighbors': 4, 'p': 1, 'weights': 'distance', 'features': 8},
#             Current best combo with val score 0.4263:
#                     {'n_neighbors': 4, 'p': 2, 'weights': 'distance', 'features': 8}
# Trained and Tested combination 1035 of 20400, taking 0.0 seconds to get val score of 0.3359:
#                 {'n_neighbors': 4, 'p': 2, 'weights': 'uniform', 'features': 8},
#             Current best combo with val score 0.4263:
#                     {'n_neighbors': 4, 'p': 2, 'weights': 'distance', 'features': 8}
# Already Trained and Tested combination (val score of 0.4185):
#             {'n_neighbors': 4, 'p': 2, 'weights': 'distance', 'features': 7}
#             Current best combo (with val score 0.4263):
#                     {'n_neighbors': 4, 'p': 2, 'weights': 'distance', 'features': 8}
#         Has trained 1035 of 20400 combinations so far
# Trained and Tested combination 1036 of 20400, taking 0.0 seconds to get val score of 0.3832:
#                 {'n_neighbors': 4, 'p': 2, 'weights': 'distance', 'features': 9},
#             Current best combo with val score 0.4263:
#                     {'n_neighbors': 4, 'p': 2, 'weights': 'distance', 'features': 8}
# % Combos Checked Thus Far: 1036 out of 20400 which is 5.078431%
# Guidance: round FINAL
#
# 	round FINAL iteration:  0
#
# Already Trained and Tested combination (val score of 0.4214):
#             {'n_neighbors': 3, 'p': 2, 'weights': 'distance', 'features': 8}
#             Current best combo (with val score 0.4263):
#                     {'n_neighbors': 4, 'p': 2, 'weights': 'distance', 'features': 8}
#         Has trained 1036 of 20400 combinations so far
# Already Trained and Tested combination (val score of 0.3846):
#             {'n_neighbors': 5, 'p': 2, 'weights': 'distance', 'features': 8}
#             Current best combo (with val score 0.4263):
#                     {'n_neighbors': 4, 'p': 2, 'weights': 'distance', 'features': 8}
#         Has trained 1036 of 20400 combinations so far
# Already Trained and Tested combination (val score of 0.4218):
#             {'n_neighbors': 4, 'p': 1, 'weights': 'distance', 'features': 8}
#             Current best combo (with val score 0.4263):
#                     {'n_neighbors': 4, 'p': 2, 'weights': 'distance', 'features': 8}
#         Has trained 1036 of 20400 combinations so far
# Already Trained and Tested combination (val score of 0.3359):
#             {'n_neighbors': 4, 'p': 2, 'weights': 'uniform', 'features': 8}
#             Current best combo (with val score 0.4263):
#                     {'n_neighbors': 4, 'p': 2, 'weights': 'distance', 'features': 8}
#         Has trained 1036 of 20400 combinations so far
# Already Trained and Tested combination (val score of 0.4185):
#             {'n_neighbors': 4, 'p': 2, 'weights': 'distance', 'features': 7}
#             Current best combo (with val score 0.4263):
#                     {'n_neighbors': 4, 'p': 2, 'weights': 'distance', 'features': 8}
#         Has trained 1036 of 20400 combinations so far
# Already Trained and Tested combination (val score of 0.3832):
#             {'n_neighbors': 4, 'p': 2, 'weights': 'distance', 'features': 9}
#             Current best combo (with val score 0.4263):
#                     {'n_neighbors': 4, 'p': 2, 'weights': 'distance', 'features': 8}
#         Has trained 1036 of 20400 combinations so far
# 	round FINAL iteration:  1
#
# Trained and Tested combination 1037 of 20400, taking 0.0 seconds to get val score of 0.3752:
#                 {'n_neighbors': 2, 'p': 2, 'weights': 'distance', 'features': 8},
#             Current best combo with val score 0.4263:
#                     {'n_neighbors': 4, 'p': 2, 'weights': 'distance', 'features': 8}
# Already Trained and Tested combination (val score of 0.4263):
#             {'n_neighbors': 4, 'p': 2, 'weights': 'distance', 'features': 8}
#             Current best combo (with val score 0.4263):
#                     {'n_neighbors': 4, 'p': 2, 'weights': 'distance', 'features': 8}
#         Has trained 1037 of 20400 combinations so far
# Trained and Tested combination 1038 of 20400, taking 0.0 seconds to get val score of 0.4141:
#                 {'n_neighbors': 3, 'p': 1, 'weights': 'distance', 'features': 8},
#             Current best combo with val score 0.4263:
#                     {'n_neighbors': 4, 'p': 2, 'weights': 'distance', 'features': 8}
# Trained and Tested combination 1039 of 20400, taking 0.0 seconds to get val score of 0.4227:
#                 {'n_neighbors': 3, 'p': 2, 'weights': 'uniform', 'features': 8},
#             Current best combo with val score 0.4263:
#                     {'n_neighbors': 4, 'p': 2, 'weights': 'distance', 'features': 8}
# Already Trained and Tested combination (val score of 0.4171):
#             {'n_neighbors': 3, 'p': 2, 'weights': 'distance', 'features': 7}
#             Current best combo (with val score 0.4263):
#                     {'n_neighbors': 4, 'p': 2, 'weights': 'distance', 'features': 8}
#         Has trained 1039 of 20400 combinations so far
# Trained and Tested combination 1040 of 20400, taking 0.0 seconds to get val score of 0.3693:
#                 {'n_neighbors': 3, 'p': 2, 'weights': 'distance', 'features': 9},
#             Current best combo with val score 0.4263:
#                     {'n_neighbors': 4, 'p': 2, 'weights': 'distance', 'features': 8}
# Already Trained and Tested combination (val score of 0.4141):
#             {'n_neighbors': 3, 'p': 1, 'weights': 'distance', 'features': 8}
#             Current best combo (with val score 0.4263):
#                     {'n_neighbors': 4, 'p': 2, 'weights': 'distance', 'features': 8}
#         Has trained 1040 of 20400 combinations so far
# Trained and Tested combination 1041 of 20400, taking 0.0 seconds to get val score of 0.4047:
#                 {'n_neighbors': 5, 'p': 1, 'weights': 'distance', 'features': 8},
#             Current best combo with val score 0.4263:
#                     {'n_neighbors': 4, 'p': 2, 'weights': 'distance', 'features': 8}
# Already Trained and Tested combination (val score of 0.4263):
#             {'n_neighbors': 4, 'p': 2, 'weights': 'distance', 'features': 8}
#             Current best combo (with val score 0.4263):
#                     {'n_neighbors': 4, 'p': 2, 'weights': 'distance', 'features': 8}
#         Has trained 1041 of 20400 combinations so far
# Trained and Tested combination 1042 of 20400, taking 0.0 seconds to get val score of 0.3531:
#                 {'n_neighbors': 4, 'p': 1, 'weights': 'uniform', 'features': 8},
#             Current best combo with val score 0.4263:
#                     {'n_neighbors': 4, 'p': 2, 'weights': 'distance', 'features': 8}
# Already Trained and Tested combination (val score of 0.4185):
#             {'n_neighbors': 4, 'p': 1, 'weights': 'distance', 'features': 7}
#             Current best combo (with val score 0.4263):
#                     {'n_neighbors': 4, 'p': 2, 'weights': 'distance', 'features': 8}
#         Has trained 1042 of 20400 combinations so far
# Trained and Tested combination 1043 of 20400, taking 0.0 seconds to get val score of 0.3714:
#                 {'n_neighbors': 4, 'p': 1, 'weights': 'distance', 'features': 9},
#             Current best combo with val score 0.4263:
#                     {'n_neighbors': 4, 'p': 2, 'weights': 'distance', 'features': 8}
# % Combos Checked Thus Far: 1043 out of 20400 which is 5.112744999999999%
# Max Val Score:
#  0.426273
# Max Val Score Std:
#  0.065356
# Best Combo Train Score:
#  1.0
# Best Combo Train Score Std:
#  0.0
# Max Combo Index:
#  (3, 1, 0, 8) out of [100, 2, 2, 51] (note best combo is 0-indexed)
# Max Combo Hyperparamer Combination:
#  {'n_neighbors': 4, 'p': 2, 'weights': 'distance', 'features': 8}
# Max Combo Features:
#  ('procedure_225792', 'ventilation_used', 'lods_score', 'race_AMERICAN INDIAN/ALASKA NATIVE', 'race_ASIAN', 'race_ASIAN - ASIAN INDIAN', 'race_ASIAN - CHINESE', 'race_ASIAN - KOREAN', 'race_ASIAN - SOUTH EAST ASIAN', 'race_BLACK/AFRICAN', 'race_BLACK/AFRICAN AMERICAN', 'race_BLACK/CAPE VERDEAN', 'race_BLACK/CARIBBEAN ISLAND', 'race_HISPANIC/LATINO - CENTRAL AMERICAN', 'race_HISPANIC/LATINO - COLUMBIAN', 'race_HISPANIC/LATINO - CUBAN', 'race_HISPANIC/LATINO - DOMINICAN', 'race_HISPANIC/LATINO - GUATEMALAN', 'race_HISPANIC/LATINO - HONDURAN', 'race_HISPANIC/LATINO - MEXICAN', 'race_HISPANIC/LATINO - PUERTO RICAN', 'race_HISPANIC/LATINO - SALVADORAN', 'race_MULTIPLE RACE/ETHNICITY', 'race_NATIVE HAWAIIAN OR OTHER PACIFIC ISLANDER', 'race_OTHER', 'race_PATIENT DECLINED TO ANSWER', 'race_PORTUGUESE', 'race_SOUTH AMERICAN', 'race_UNABLE TO OBTAIN', 'race_UNKNOWN', 'race_WHITE', 'race_WHITE - BRAZILIAN', 'race_WHITE - EASTERN EUROPEAN', 'race_WHITE - OTHER EUROPEAN', 'race_WHITE - RUSSIAN', 'race_HISPANIC OR LATINO', 'marital_status_DIVORCED', 'marital_status_MARRIED', 'marital_status_SINGLE', 'marital_status_WIDOWED', 'marital_status_0', 'hospital_stay_duration', 'procedure_225464', 'procedure_225802', 'procedure_227712')
# % Combos Checked: 1043 out of 20400 which is 5.112744999999999%
