# %% [markdown]
# # Tuning Script

# %%
# Parameters subject to change in every script - involved in naming

MODEL = 'nb(gaussian)'
PREPROCESSING = 'normalise'
TUNER = 'yangzhoub'
OPTIMISED_METRIC = 'f1'

# %% [markdown]
# ---

# %%
# detect whether this is a google environment

COLAB_ENVIRONMENT = False

try:
    from google.colab import drive
    drive.mount('/content/drive')
    COLAB_ENVIRONMENT = True
except:
    pass
# Out:
# Mounted at /content/drive

# %%
import sys
import os
import pickle

if COLAB_ENVIRONMENT:
    home_directory = './drive/MyDrive/LAB/COMP90089__GroupWork__Py/' # my home directory is stored in ./LAB of google drive
    if MODEL == 'ebr':
        # !pip install interpret==0.5.0
    elif MODEL == 'cbr':
        # !pip install catboost
    elif MODEL in ['tf', 'mlp']:
        # !pip install PyTorch2Sklearn
    # !pip install JXAutoML
else:
    home_directory = '../../'

from JXAutoML.YangZhouB_10CV import YangZhouB_10CV as Tuner

import pandas as pd
# Out:
# Collecting JXAutoML
#   Downloading JXAutoML-0.4.4-py3-none-any.whl.metadata (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.2/67.2 kB 1.6 MB/s eta 0:00:00
# Downloading JXAutoML-0.4.4-py3-none-any.whl (52 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.1/52.1 kB 5.1 MB/s eta 0:00:00
# Installing collected packages: JXAutoML
# Successfully installed JXAutoML-0.4.4

# %%
# Parameters that are same for every script

FOLDS = 10  # we have decided to do 10 fold validation

SEED = 42

TASK_TYPE = 'Classification'  # this task is a classification task

# we have decided to tune features as hp
TUNE_FEATURES_AS_HYPERPARAMETERS = True

# %% [markdown]
# ---

# %%
# model to use to tune
from sklearn.naive_bayes import GaussianNB as clf

# what values to try for each hyperparameter
parameter_choices = {
    'var_smoothing': (0.00001, 0.0001, 0.001, 0.01, 0.1, 1, 10, 100),
}

# what values to set non-tuneable parameters/hyperparameters
non_tunable_hyperparameters_dict = {}

# %% [markdown]
# ---

# %% [markdown]
# Read in and Prepare Data

# %%
# Import data and store as lists

train_x_list = []
train_y_list = []
val_x_list = []
val_y_list = []

for i in range(FOLDS):
    train_data = pd.read_csv(
        f'{home_directory}data/curated/modelling/{PREPROCESSING}/train_{i}.csv')
    val_data = pd.read_csv(
        f'{home_directory}data/curated/modelling/{PREPROCESSING}/val_{i}.csv')

    # get the correct rows for X and y
    train_x = train_data.drop(
        ['mortality_status', 'subject_id', 'hadm_id', 'stay_id'], axis=1)
    train_y = train_data['mortality_status']
    val_x = val_data.drop(
        ['mortality_status', 'subject_id', 'hadm_id', 'stay_id'], axis=1)
    val_y = val_data['mortality_status']

    train_x_list.append(train_x)
    train_y_list.append(train_y)
    val_x_list.append(val_x)
    val_y_list.append(val_y)

# %%
# Import feature importance ordering

with open(f'{home_directory}models/xgb_feature_importance_ordering_{PREPROCESSING}.pickle', 'rb') as f:
    feature_importance_ordering = pickle.load(f)

# %% [markdown]
# Set parameters

# %%
# initialisation
tuner = Tuner()

print('---')

# define what model we are tuning
tuner.read_in_model(clf, TASK_TYPE, optimised_metric=OPTIMISED_METRIC)

print('---')

# read in the data for training and validation
tuner.read_in_data(train_x_list, train_y_list, val_x_list, val_y_list)

print('---')

# set what hp values to tune
tuner.set_hyperparameters(parameter_choices)
# WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

# set up hp values that need to be changed from default but NOT to be tuned
tuner.set_non_tuneable_hyperparameters(non_tunable_hyperparameters_dict)

print('---')

# set up feature importance ordering

if TUNE_FEATURES_AS_HYPERPARAMETERS:
    tuner.set_features(feature_importance_ordering)
    # WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

try:  # try to read in previous results to continue tuning ...
    tuner.read_in_tuning_result_df(
        f'{home_directory}models/tuning/{TUNER}_{MODEL}_{PREPROCESSING}.csv')
except:
    print('No previous tuning data read in')

print('---')

# set up where to save the tuning result csv
tuner.set_tuning_result_saving_address(
    f'{home_directory}models/tuning/{TUNER}_{MODEL}_{PREPROCESSING}.csv')

print('---')

# set up where to save the current best model
tuner.set_best_model_saving_address(
    f'{home_directory}models/tmp_models/{TUNER}_{MODEL}_{PREPROCESSING}')
# Out:
# YangZhouB Initialised
# ---
# Successfully read in model <class 'sklearn.naive_bayes.GaussianNB'>, which is a Classification model optimising for f1
# ---
# Read in Train X data list
# Read in Train y data list
# Read in Val X data list
# Read in Val y data list
# ---
# Successfully recorded hyperparameter choices
# ---
# Successfully recorded non_tuneable_hyperparameter choices
# ---
# Successfully recorded tuneable feature combination choices and updated relevant internal structures
# ---
# No previous tuning data read in
# ---
# Successfully set tuning output address
# ---
# Successfully set best model output address

# %%
# ignore warnings

import warnings
warnings.filterwarnings("ignore")

# %%
# begin tuning ... (or continue training)

tuner.tune()
# Out:
# BEGIN TUNING
#
#
# STAGE ZERO: Tune all Cruise combinations
#
#
# Trained and Tested combination 1 of 384, taking 0.01 seconds to get val score of 0.3138:
#                 {'var_smoothing': 1e-05, 'features': 43},
#             Current best combo with val score 0.3138:
#                     {'var_smoothing': 1e-05, 'features': 43}
# Trained and Tested combination 2 of 384, taking 0.01 seconds to get val score of 0.0:
#                 {'var_smoothing': 100, 'features': 25},
#             Current best combo with val score 0.3138:
#                     {'var_smoothing': 1e-05, 'features': 43}
# Trained and Tested combination 3 of 384, taking 0.03 seconds to get val score of 0.314:
#                 {'var_smoothing': 1e-05, 'features': 47},
#             Current best combo with val score 0.314:
#                     {'var_smoothing': 1e-05, 'features': 47}
# Trained and Tested combination 4 of 384, taking 0.02 seconds to get val score of 0.3222:
#                 {'var_smoothing': 1e-05, 'features': 20},
#             Current best combo with val score 0.3222:
#                     {'var_smoothing': 1e-05, 'features': 20}
# Trained and Tested combination 5 of 384, taking 0.02 seconds to get val score of 0.0:
#                 {'var_smoothing': 100, 'features': 43},
#             Current best combo with val score 0.3222:
#                     {'var_smoothing': 1e-05, 'features': 20}
# Trained and Tested combination 6 of 384, taking 0.01 seconds to get val score of 0.0:
#                 {'var_smoothing': 100, 'features': 15},
#             Current best combo with val score 0.3222:
#                     {'var_smoothing': 1e-05, 'features': 20}
# Trained and Tested combination 7 of 384, taking 0.01 seconds to get val score of 0.3138:
#                 {'var_smoothing': 1e-05, 'features': 39},
#             Current best combo with val score 0.3222:
#                     {'var_smoothing': 1e-05, 'features': 20}
# Trained and Tested combination 8 of 384, taking 0.01 seconds to get val score of 0.3117:
#                 {'var_smoothing': 0.1, 'features': 30},
#             Current best combo with val score 0.3222:
#                     {'var_smoothing': 1e-05, 'features': 20}
# Trained and Tested combination 9 of 384, taking 0.01 seconds to get val score of 0.0:
#                 {'var_smoothing': 100, 'features': 39},
#             Current best combo with val score 0.3222:
#                     {'var_smoothing': 1e-05, 'features': 20}
# Trained and Tested combination 10 of 384, taking 0.0 seconds to get val score of 0.0:
#                 {'var_smoothing': 0.1, 'features': 0},
#             Current best combo with val score 0.3222:
#                     {'var_smoothing': 1e-05, 'features': 20}
# Trained and Tested combination 11 of 384, taking 0.03 seconds to get val score of 0.3117:
#                 {'var_smoothing': 0.1, 'features': 39},
#             Current best combo with val score 0.3222:
#                     {'var_smoothing': 1e-05, 'features': 20}
# Trained and Tested combination 12 of 384, taking 0.01 seconds to get val score of 0.0:
#                 {'var_smoothing': 0.1, 'features': 10},
#             Current best combo with val score 0.3222:
#                     {'var_smoothing': 1e-05, 'features': 20}
# Trained and Tested combination 13 of 384, taking 0.01 seconds to get val score of 0.0:
#                 {'var_smoothing': 0.1, 'features': 24},
#             Current best combo with val score 0.3222:
#                     {'var_smoothing': 1e-05, 'features': 20}
# Trained and Tested combination 14 of 384, taking 0.0 seconds to get val score of 0.127:
#                 {'var_smoothing': 0.1, 'features': 5},
#             Current best combo with val score 0.3222:
#                     {'var_smoothing': 1e-05, 'features': 20}
# Trained and Tested combination 15 of 384, taking 0.01 seconds to get val score of 0.3138:
#                 {'var_smoothing': 1e-05, 'features': 25},
#             Current best combo with val score 0.3222:
#                     {'var_smoothing': 1e-05, 'features': 20}
# Trained and Tested combination 16 of 384, taking 0.0 seconds to get val score of 0.0:
#                 {'var_smoothing': 100, 'features': 20},
#             Current best combo with val score 0.3222:
#                     {'var_smoothing': 1e-05, 'features': 20}
# Trained and Tested combination 17 of 384, taking 0.01 seconds to get val score of 0.3117:
#                 {'var_smoothing': 0.1, 'features': 25},
#             Current best combo with val score 0.3222:
#                     {'var_smoothing': 1e-05, 'features': 20}
# Trained and Tested combination 18 of 384, taking 0.01 seconds to get val score of 0.3138:
#                 {'var_smoothing': 1e-05, 'features': 30},
#             Current best combo with val score 0.3222:
#                     {'var_smoothing': 1e-05, 'features': 20}
# Trained and Tested combination 19 of 384, taking 0.01 seconds to get val score of 0.0:
#                 {'var_smoothing': 100, 'features': 10},
#             Current best combo with val score 0.3222:
#                     {'var_smoothing': 1e-05, 'features': 20}
# Trained and Tested combination 20 of 384, taking 0.0 seconds to get val score of 0.1713:
#                 {'var_smoothing': 1e-05, 'features': 5},
#             Current best combo with val score 0.3222:
#                     {'var_smoothing': 1e-05, 'features': 20}
# Trained and Tested combination 21 of 384, taking 0.01 seconds to get val score of 0.0167:
#                 {'var_smoothing': 0.1, 'features': 20},
#             Current best combo with val score 0.3222:
#                     {'var_smoothing': 1e-05, 'features': 20}
# Trained and Tested combination 22 of 384, taking 0.01 seconds to get val score of 0.3138:
#                 {'var_smoothing': 1e-05, 'features': 35},
#             Current best combo with val score 0.3222:
#                     {'var_smoothing': 1e-05, 'features': 20}
# Trained and Tested combination 23 of 384, taking 0.0 seconds to get val score of 0.0:
#                 {'var_smoothing': 100, 'features': 0},
#             Current best combo with val score 0.3222:
#                     {'var_smoothing': 1e-05, 'features': 20}
# Trained and Tested combination 24 of 384, taking 0.01 seconds to get val score of 0.0:
#                 {'var_smoothing': 100, 'features': 30},
#             Current best combo with val score 0.3222:
#                     {'var_smoothing': 1e-05, 'features': 20}
# Trained and Tested combination 25 of 384, taking 0.01 seconds to get val score of 0.3211:
#                 {'var_smoothing': 1e-05, 'features': 15},
#             Current best combo with val score 0.3222:
#                     {'var_smoothing': 1e-05, 'features': 20}
# Trained and Tested combination 26 of 384, taking 0.01 seconds to get val score of 0.0:
#                 {'var_smoothing': 100, 'features': 35},
#             Current best combo with val score 0.3222:
#                     {'var_smoothing': 1e-05, 'features': 20}
# Trained and Tested combination 27 of 384, taking 0.0 seconds to get val score of 0.0133:
#                 {'var_smoothing': 0.1, 'features': 15},
#             Current best combo with val score 0.3222:
#                     {'var_smoothing': 1e-05, 'features': 20}
# Trained and Tested combination 28 of 384, taking 0.0 seconds to get val score of 0.3144:
#                 {'var_smoothing': 1e-05, 'features': 10},
#             Current best combo with val score 0.3222:
#                     {'var_smoothing': 1e-05, 'features': 20}
# Trained and Tested combination 29 of 384, taking 0.0 seconds to get val score of 0.0:
#                 {'var_smoothing': 1e-05, 'features': 0},
#             Current best combo with val score 0.3222:
#                     {'var_smoothing': 1e-05, 'features': 20}
# Trained and Tested combination 30 of 384, taking 0.01 seconds to get val score of 0.3117:
#                 {'var_smoothing': 0.1, 'features': 43},
#             Current best combo with val score 0.3222:
#                     {'var_smoothing': 1e-05, 'features': 20}
# Trained and Tested combination 31 of 384, taking 0.01 seconds to get val score of 0.3117:
#                 {'var_smoothing': 0.1, 'features': 35},
#             Current best combo with val score 0.3222:
#                     {'var_smoothing': 1e-05, 'features': 20}
# Trained and Tested combination 32 of 384, taking 0.01 seconds to get val score of 0.3117:
#                 {'var_smoothing': 0.1, 'features': 47},
#             Current best combo with val score 0.3222:
#                     {'var_smoothing': 1e-05, 'features': 20}
# Trained and Tested combination 33 of 384, taking 0.0 seconds to get val score of 0.0:
#                 {'var_smoothing': 100, 'features': 5},
#             Current best combo with val score 0.3222:
#                     {'var_smoothing': 1e-05, 'features': 20}
# Trained and Tested combination 34 of 384, taking 0.01 seconds to get val score of 0.0:
#                 {'var_smoothing': 100, 'features': 47},
#             Current best combo with val score 0.3222:
#                     {'var_smoothing': 1e-05, 'features': 20}
#
#
# STAGE ONE: Begin initial Guidance system
#
#
# Guidance: initial round
#
# 	round 0 iteration:  0
#
# Trained and Tested combination 35 of 384, taking 0.01 seconds to get val score of 0.2257:
#                 {'var_smoothing': 0.01, 'features': 24},
#             Current best combo with val score 0.3222:
#                     {'var_smoothing': 1e-05, 'features': 20}
# Trained and Tested combination 36 of 384, taking 0.0 seconds to get val score of 0.0:
#                 {'var_smoothing': 1, 'features': 24},
#             Current best combo with val score 0.3222:
#                     {'var_smoothing': 1e-05, 'features': 20}
# Trained and Tested combination 37 of 384, taking 0.01 seconds to get val score of 0.0671:
#                 {'var_smoothing': 0.1, 'features': 23},
#             Current best combo with val score 0.3222:
#                     {'var_smoothing': 1e-05, 'features': 20}
# Already Trained and Tested combination (val score of 0.3117):
#             {'var_smoothing': 0.1, 'features': 25}
#             Current best combo (with val score 0.3222):
#                     {'var_smoothing': 1e-05, 'features': 20}
#         Has trained 37 of 384 combinations so far
# 	round 0 iteration:  1
#
# Trained and Tested combination 38 of 384, taking 0.01 seconds to get val score of 0.3275:
#                 {'var_smoothing': 0.001, 'features': 24},
#             Current best combo with val score 0.3275:
#                     {'var_smoothing': 0.001, 'features': 24}
# Already Trained and Tested combination (val score of 0.0):
#             {'var_smoothing': 0.1, 'features': 24}
#             Current best combo (with val score 0.3275):
#                     {'var_smoothing': 0.001, 'features': 24}
#         Has trained 38 of 384 combinations so far
# Trained and Tested combination 39 of 384, taking 0.01 seconds to get val score of 0.3044:
#                 {'var_smoothing': 0.01, 'features': 23},
#             Current best combo with val score 0.3275:
#                     {'var_smoothing': 0.001, 'features': 24}
# Trained and Tested combination 40 of 384, taking 0.01 seconds to get val score of 0.3117:
#                 {'var_smoothing': 0.01, 'features': 25},
#             Current best combo with val score 0.3275:
#                     {'var_smoothing': 0.001, 'features': 24}
# Already Trained and Tested combination (val score of 0.0):
#             {'var_smoothing': 0.1, 'features': 24}
#             Current best combo (with val score 0.3275):
#                     {'var_smoothing': 0.001, 'features': 24}
#         Has trained 40 of 384 combinations so far
# Trained and Tested combination 41 of 384, taking 0.01 seconds to get val score of 0.0:
#                 {'var_smoothing': 10, 'features': 24},
#             Current best combo with val score 0.3275:
#                     {'var_smoothing': 0.001, 'features': 24}
# Trained and Tested combination 42 of 384, taking 0.01 seconds to get val score of 0.0:
#                 {'var_smoothing': 1, 'features': 23},
#             Current best combo with val score 0.3275:
#                     {'var_smoothing': 0.001, 'features': 24}
# Trained and Tested combination 43 of 384, taking 0.01 seconds to get val score of 0.3117:
#                 {'var_smoothing': 1, 'features': 25},
#             Current best combo with val score 0.3275:
#                     {'var_smoothing': 0.001, 'features': 24}
# Already Trained and Tested combination (val score of 0.3044):
#             {'var_smoothing': 0.01, 'features': 23}
#             Current best combo (with val score 0.3275):
#                     {'var_smoothing': 0.001, 'features': 24}
#         Has trained 43 of 384 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'var_smoothing': 1, 'features': 23}
#             Current best combo (with val score 0.3275):
#                     {'var_smoothing': 0.001, 'features': 24}
#         Has trained 43 of 384 combinations so far
# Trained and Tested combination 44 of 384, taking 0.01 seconds to get val score of 0.0793:
#                 {'var_smoothing': 0.1, 'features': 22},
#             Current best combo with val score 0.3275:
#                     {'var_smoothing': 0.001, 'features': 24}
# Already Trained and Tested combination (val score of 0.0):
#             {'var_smoothing': 0.1, 'features': 24}
#             Current best combo (with val score 0.3275):
#                     {'var_smoothing': 0.001, 'features': 24}
#         Has trained 44 of 384 combinations so far
# Already Trained and Tested combination (val score of 0.3117):
#             {'var_smoothing': 0.01, 'features': 25}
#             Current best combo (with val score 0.3275):
#                     {'var_smoothing': 0.001, 'features': 24}
#         Has trained 44 of 384 combinations so far
# Already Trained and Tested combination (val score of 0.3117):
#             {'var_smoothing': 1, 'features': 25}
#             Current best combo (with val score 0.3275):
#                     {'var_smoothing': 0.001, 'features': 24}
#         Has trained 44 of 384 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'var_smoothing': 0.1, 'features': 24}
#             Current best combo (with val score 0.3275):
#                     {'var_smoothing': 0.001, 'features': 24}
#         Has trained 44 of 384 combinations so far
# Trained and Tested combination 45 of 384, taking 0.0 seconds to get val score of 0.3117:
#                 {'var_smoothing': 0.1, 'features': 26},
#             Current best combo with val score 0.3275:
#                     {'var_smoothing': 0.001, 'features': 24}
# Trained and Tested combination 46 of 384, taking 0.01 seconds to get val score of 0.41:
#                 {'var_smoothing': 0.0001, 'features': 24},
#             Current best combo with val score 0.41:
#                     {'var_smoothing': 0.0001, 'features': 24}
# Already Trained and Tested combination (val score of 0.2257):
#             {'var_smoothing': 0.01, 'features': 24}
#             Current best combo (with val score 0.41):
#                     {'var_smoothing': 0.0001, 'features': 24}
#         Has trained 46 of 384 combinations so far
# Trained and Tested combination 47 of 384, taking 0.01 seconds to get val score of 0.439:
#                 {'var_smoothing': 0.001, 'features': 23},
#             Current best combo with val score 0.439:
#                     {'var_smoothing': 0.001, 'features': 23}
# Trained and Tested combination 48 of 384, taking 0.01 seconds to get val score of 0.3121:
#                 {'var_smoothing': 0.001, 'features': 25},
#             Current best combo with val score 0.439:
#                     {'var_smoothing': 0.001, 'features': 23}
# Trained and Tested combination 49 of 384, taking 0.01 seconds to get val score of 0.3777:
#                 {'var_smoothing': 0.0001, 'features': 23},
#             Current best combo with val score 0.439:
#                     {'var_smoothing': 0.001, 'features': 23}
# Already Trained and Tested combination (val score of 0.3044):
#             {'var_smoothing': 0.01, 'features': 23}
#             Current best combo (with val score 0.439):
#                     {'var_smoothing': 0.001, 'features': 23}
#         Has trained 49 of 384 combinations so far
# Trained and Tested combination 50 of 384, taking 0.01 seconds to get val score of 0.4459:
#                 {'var_smoothing': 0.001, 'features': 22},
#             Current best combo with val score 0.4459:
#                     {'var_smoothing': 0.001, 'features': 22}
# Already Trained and Tested combination (val score of 0.3275):
#             {'var_smoothing': 0.001, 'features': 24}
#             Current best combo (with val score 0.4459):
#                     {'var_smoothing': 0.001, 'features': 22}
#         Has trained 50 of 384 combinations so far
# Trained and Tested combination 51 of 384, taking 0.01 seconds to get val score of 0.3771:
#                 {'var_smoothing': 0.0001, 'features': 22},
#             Current best combo with val score 0.4459:
#                     {'var_smoothing': 0.001, 'features': 22}
# Trained and Tested combination 52 of 384, taking 0.01 seconds to get val score of 0.312:
#                 {'var_smoothing': 0.01, 'features': 22},
#             Current best combo with val score 0.4459:
#                     {'var_smoothing': 0.001, 'features': 22}
# Trained and Tested combination 53 of 384, taking 0.01 seconds to get val score of 0.3999:
#                 {'var_smoothing': 0.001, 'features': 21},
#             Current best combo with val score 0.4459:
#                     {'var_smoothing': 0.001, 'features': 22}
# Already Trained and Tested combination (val score of 0.439):
#             {'var_smoothing': 0.001, 'features': 23}
#             Current best combo (with val score 0.4459):
#                     {'var_smoothing': 0.001, 'features': 22}
#         Has trained 53 of 384 combinations so far
# % Combos Checked Thus Far: 53 out of 384 which is 13.802083000000001%
# STAGE TWO: Begin Cruise system
#
#
# Cruising Coordrdinate 1 of 33
#
# Cruising Coordrdinate 2 of 33
#
# Cruising Coordrdinate 3 of 33
#
# Cruising Coordrdinate 4 of 33
#
# Cruising Coordrdinate 5 of 33
#
# Cruising Coordrdinate 6 of 33
#
# Cruising Coordrdinate 7 of 33
#
# Cruising Coordrdinate 8 of 33
#
# Cruising Coordrdinate 9 of 33
#
# Cruising Coordrdinate 10 of 33
#
# Cruising Coordrdinate 11 of 33
#
# Cruising Coordrdinate 12 of 33
#
# Cruising Coordrdinate 13 of 33
#
# Cruising Coordrdinate 14 of 33
#
# Cruising Coordrdinate 15 of 33
#
# Cruising Coordrdinate 16 of 33
#
# Cruising Coordrdinate 17 of 33
#
# Cruising Coordrdinate 18 of 33
#
# Cruising Coordrdinate 19 of 33
#
# Cruising Coordrdinate 20 of 33
#
# Cruising Coordrdinate 21 of 33
#
# Cruising Coordrdinate 22 of 33
#
# Cruising Coordrdinate 23 of 33
#
# Cruising Coordrdinate 24 of 33
#
# Cruising Coordrdinate 25 of 33
#
# Cruising Coordrdinate 26 of 33
#
# Cruising Coordrdinate 27 of 33
#
# Cruising Coordrdinate 28 of 33
#
# Cruising Coordrdinate 29 of 33
#
# Cruising Coordrdinate 30 of 33
#
# Cruising Coordrdinate 31 of 33
#
# Cruising Coordrdinate 32 of 33
#
# Cruising Coordrdinate 33 of 33
#
# FINAL STAGE: Begin final Guidance system
#
#
# Guidance: round FINAL
#
# 	round FINAL iteration:  0
#
# Already Trained and Tested combination (val score of 0.3771):
#             {'var_smoothing': 0.0001, 'features': 22}
#             Current best combo (with val score 0.4459):
#                     {'var_smoothing': 0.001, 'features': 22}
#         Has trained 53 of 384 combinations so far
# Already Trained and Tested combination (val score of 0.312):
#             {'var_smoothing': 0.01, 'features': 22}
#             Current best combo (with val score 0.4459):
#                     {'var_smoothing': 0.001, 'features': 22}
#         Has trained 53 of 384 combinations so far
# Already Trained and Tested combination (val score of 0.3999):
#             {'var_smoothing': 0.001, 'features': 21}
#             Current best combo (with val score 0.4459):
#                     {'var_smoothing': 0.001, 'features': 22}
#         Has trained 53 of 384 combinations so far
# Already Trained and Tested combination (val score of 0.439):
#             {'var_smoothing': 0.001, 'features': 23}
#             Current best combo (with val score 0.4459):
#                     {'var_smoothing': 0.001, 'features': 22}
#         Has trained 53 of 384 combinations so far
# % Combos Checked Thus Far: 53 out of 384 which is 13.802083000000001%
# Max Val Score:
#  0.445913
# Max Val Score Std:
#  0.053543
# Best Combo Train Score:
#  0.499727
# Best Combo Train Score Std:
#  0.010706
# Max Combo Index:
#  (2, 22) out of [8, 48] (note best combo is 0-indexed)
# Max Combo Hyperparamer Combination:
#  {'var_smoothing': 0.001, 'features': 22}
# Max Combo Features:
#  ('procedure_225792', 'ventilation_used', 'procedure_226475', 'lods_score', 'procedure_225802', 'hospital_stay_duration', 'procedure_224276', 'procedure_229519', 'procedure_226236', 'race_AMERICAN INDIAN/ALASKA NATIVE', 'race_ASIAN', 'race_ASIAN - ASIAN INDIAN', 'race_ASIAN - CHINESE', 'race_ASIAN - KOREAN', 'race_ASIAN - SOUTH EAST ASIAN', 'race_BLACK/AFRICAN', 'race_BLACK/AFRICAN AMERICAN', 'race_BLACK/CAPE VERDEAN', 'race_BLACK/CARIBBEAN ISLAND', 'race_HISPANIC OR LATINO', 'race_HISPANIC/LATINO - CENTRAL AMERICAN', 'race_HISPANIC/LATINO - COLUMBIAN', 'race_HISPANIC/LATINO - CUBAN', 'race_HISPANIC/LATINO - DOMINICAN', 'race_HISPANIC/LATINO - GUATEMALAN', 'race_HISPANIC/LATINO - HONDURAN', 'race_HISPANIC/LATINO - MEXICAN', 'race_HISPANIC/LATINO - PUERTO RICAN', 'race_HISPANIC/LATINO - SALVADORAN', 'race_MULTIPLE RACE/ETHNICITY', 'race_NATIVE HAWAIIAN OR OTHER PACIFIC ISLANDER', 'race_OTHER', 'race_PATIENT DECLINED TO ANSWER', 'race_PORTUGUESE', 'race_SOUTH AMERICAN', 'race_UNABLE TO OBTAIN', 'race_WHITE', 'race_WHITE - BRAZILIAN', 'race_WHITE - EASTERN EUROPEAN', 'race_WHITE - OTHER EUROPEAN', 'race_WHITE - RUSSIAN', 'race_UNKNOWN', 'oasis_score', 'procedure_224267', 'icu_stay_duration', 'procedure_229580', 'procedure_224270', 'procedure_225446', 'procedure_225400', 'procedure_221223', 'unique_drugs', 'procedure_227712', 'procedure_224263', 'creatinine', 'heart_rate')
# % Combos Checked: 53 out of 384 which is 13.802083000000001%
