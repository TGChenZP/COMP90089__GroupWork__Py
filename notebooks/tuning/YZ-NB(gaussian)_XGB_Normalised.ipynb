# %% [markdown]
# # Tuning Script

# %%
# Parameters subject to change in every script - involved in naming

MODEL = 'nb(gaussian)'
PREPROCESSING = 'normalise'
TUNER = 'yangzhoub'
OPTIMISED_METRIC = 'f1'

# %% [markdown]
# ---

# %%
# detect whether this is a google environment

COLAB_ENVIRONMENT = False

try:
    from google.colab import drive
    drive.mount('/content/drive')
    COLAB_ENVIRONMENT = True
except:
    pass
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import sys
import os
import pickle

if COLAB_ENVIRONMENT:
    home_directory = './drive/MyDrive/LAB/COMP90089__GroupWork__Py/' # my home directory is stored in ./LAB of google drive
    if MODEL == 'ebr':
        # !pip install interpret==0.5.0
    elif MODEL == 'cbr':
        # !pip install catboost
    elif MODEL in ['tf', 'mlp']:
        # !pip install PyTorch2Sklearn
    # !pip install JXAutoML
else:
    home_directory = '../../'

from JXAutoML.YangZhouB_10CV import YangZhouB_10CV as Tuner

import pandas as pd
# Out:
# Requirement already satisfied: JXAutoML in /usr/local/lib/python3.10/dist-packages (0.4.4)

# %%
# Parameters that are same for every script

FOLDS = 10  # we have decided to do 10 fold validation

SEED = 42

TASK_TYPE = 'Classification'  # this task is a classification task

# we have decided to tune features as hp
TUNE_FEATURES_AS_HYPERPARAMETERS = True

# %% [markdown]
# ---

# %%
# model to use to tune
from sklearn.naive_bayes import GaussianNB as clf

# what values to try for each hyperparameter
parameter_choices = {
    'var_smoothing': (0.00001, 0.0001, 0.001, 0.01, 0.1, 1, 10, 100),
}

# what values to set non-tuneable parameters/hyperparameters
non_tunable_hyperparameters_dict = {}

# %% [markdown]
# ---

# %% [markdown]
# Read in and Prepare Data

# %%
# Import data and store as lists

train_x_list = []
train_y_list = []
val_x_list = []
val_y_list = []

for i in range(FOLDS):
    train_data = pd.read_csv(
        f'{home_directory}data/curated/modelling/{PREPROCESSING}/train_{i}.csv')
    val_data = pd.read_csv(
        f'{home_directory}data/curated/modelling/{PREPROCESSING}/val_{i}.csv')

    # get the correct rows for X and y
    train_x = train_data.drop(
        ['mortality_status', 'subject_id', 'hadm_id', 'stay_id'], axis=1)
    train_y = train_data['mortality_status']
    val_x = val_data.drop(
        ['mortality_status', 'subject_id', 'hadm_id', 'stay_id'], axis=1)
    val_y = val_data['mortality_status']

    train_x_list.append(train_x)
    train_y_list.append(train_y)
    val_x_list.append(val_x)
    val_y_list.append(val_y)

# %%
# Import feature importance ordering

with open(f'{home_directory}models/xgb_feature_importance_ordering_{PREPROCESSING}.pickle', 'rb') as f:
    feature_importance_ordering = pickle.load(f)

# %% [markdown]
# Set parameters

# %%
# initialisation
tuner = Tuner()

print('---')

# define what model we are tuning
tuner.read_in_model(clf, TASK_TYPE, optimised_metric=OPTIMISED_METRIC)

print('---')

# read in the data for training and validation
tuner.read_in_data(train_x_list, train_y_list, val_x_list, val_y_list)

print('---')

# set what hp values to tune
tuner.set_hyperparameters(parameter_choices)
# WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

# set up hp values that need to be changed from default but NOT to be tuned
tuner.set_non_tuneable_hyperparameters(non_tunable_hyperparameters_dict)

print('---')

# set up feature importance ordering

if TUNE_FEATURES_AS_HYPERPARAMETERS:
    tuner.set_features(feature_importance_ordering)
    # WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

try:  # try to read in previous results to continue tuning ...
    tuner.read_in_tuning_result_df(
        f'{home_directory}models/tuning/{TUNER}_{MODEL}_{PREPROCESSING}.csv')
except:
    print('No previous tuning data read in')

print('---')

# set up where to save the tuning result csv
tuner.set_tuning_result_saving_address(
    f'{home_directory}models/tuning/{TUNER}_{MODEL}_{PREPROCESSING}.csv')

print('---')

# set up where to save the current best model
tuner.set_best_model_saving_address(
    f'{home_directory}models/tmp_models/{TUNER}_{MODEL}_{PREPROCESSING}')
# Out:
# YangZhouB Initialised
# ---
# Successfully read in model <class 'sklearn.naive_bayes.GaussianNB'>, which is a Classification model optimising for f1
# ---
# Read in Train X data list
# Read in Train y data list
# Read in Val X data list
# Read in Val y data list
# ---
# Successfully recorded hyperparameter choices
# ---
# Successfully recorded non_tuneable_hyperparameter choices
# ---
# Successfully recorded tuneable feature combination choices and updated relevant internal structures
# ---
# No previous tuning data read in
# ---
# Successfully set tuning output address
# ---
# Successfully set best model output address

# %%
# ignore warnings

import warnings
warnings.filterwarnings("ignore")

# %%
# begin tuning ... (or continue training)

tuner.tune()
# Out:
# BEGIN TUNING
#
#
# STAGE ZERO: Tune all Cruise combinations
#
#
# Trained and Tested combination 1 of 576, taking 0.01 seconds to get val score of 0.0:
#                 {'var_smoothing': 100, 'features': 59},
#             Current best combo with val score 0.0:
#                     {'var_smoothing': 100, 'features': 59}
# Trained and Tested combination 2 of 576, taking 0.02 seconds to get val score of 0.3958:
#                 {'var_smoothing': 0.1, 'features': 5},
#             Current best combo with val score 0.3958:
#                     {'var_smoothing': 0.1, 'features': 5}
# Trained and Tested combination 3 of 576, taking 0.01 seconds to get val score of 0.4645:
#                 {'var_smoothing': 1e-05, 'features': 20},
#             Current best combo with val score 0.4645:
#                     {'var_smoothing': 1e-05, 'features': 20}
# Trained and Tested combination 4 of 576, taking 0.02 seconds to get val score of 0.0:
#                 {'var_smoothing': 100, 'features': 40},
#             Current best combo with val score 0.4645:
#                     {'var_smoothing': 1e-05, 'features': 20}
# Trained and Tested combination 5 of 576, taking 0.0 seconds to get val score of 0.4251:
#                 {'var_smoothing': 0.1, 'features': 10},
#             Current best combo with val score 0.4645:
#                     {'var_smoothing': 1e-05, 'features': 20}
# Trained and Tested combination 6 of 576, taking 0.01 seconds to get val score of 0.0232:
#                 {'var_smoothing': 0.1, 'features': 30},
#             Current best combo with val score 0.4645:
#                     {'var_smoothing': 1e-05, 'features': 20}
# Trained and Tested combination 7 of 576, taking 0.02 seconds to get val score of 0.3093:
#                 {'var_smoothing': 1e-05, 'features': 67},
#             Current best combo with val score 0.4645:
#                     {'var_smoothing': 1e-05, 'features': 20}
# Trained and Tested combination 8 of 576, taking 0.01 seconds to get val score of 0.3086:
#                 {'var_smoothing': 0.1, 'features': 45},
#             Current best combo with val score 0.4645:
#                     {'var_smoothing': 1e-05, 'features': 20}
# Trained and Tested combination 9 of 576, taking 0.02 seconds to get val score of 0.0:
#                 {'var_smoothing': 100, 'features': 67},
#             Current best combo with val score 0.4645:
#                     {'var_smoothing': 1e-05, 'features': 20}
# Trained and Tested combination 10 of 576, taking 0.02 seconds to get val score of 0.3086:
#                 {'var_smoothing': 1e-05, 'features': 40},
#             Current best combo with val score 0.4645:
#                     {'var_smoothing': 1e-05, 'features': 20}
# Trained and Tested combination 11 of 576, taking 0.01 seconds to get val score of 0.4574:
#                 {'var_smoothing': 1e-05, 'features': 10},
#             Current best combo with val score 0.4645:
#                     {'var_smoothing': 1e-05, 'features': 20}
# Trained and Tested combination 12 of 576, taking 0.02 seconds to get val score of 0.42:
#                 {'var_smoothing': 0.1, 'features': 15},
#             Current best combo with val score 0.4645:
#                     {'var_smoothing': 1e-05, 'features': 20}
# Trained and Tested combination 13 of 576, taking 0.01 seconds to get val score of 0.4657:
#                 {'var_smoothing': 1e-05, 'features': 30},
#             Current best combo with val score 0.4657:
#                     {'var_smoothing': 1e-05, 'features': 30}
# Trained and Tested combination 14 of 576, taking 0.01 seconds to get val score of 0.3086:
#                 {'var_smoothing': 0.1, 'features': 63},
#             Current best combo with val score 0.4657:
#                     {'var_smoothing': 1e-05, 'features': 30}
# Trained and Tested combination 15 of 576, taking 0.01 seconds to get val score of 0.3086:
#                 {'var_smoothing': 1e-05, 'features': 45},
#             Current best combo with val score 0.4657:
#                     {'var_smoothing': 1e-05, 'features': 30}
# Trained and Tested combination 16 of 576, taking 0.01 seconds to get val score of 0.3086:
#                 {'var_smoothing': 0.1, 'features': 55},
#             Current best combo with val score 0.4657:
#                     {'var_smoothing': 1e-05, 'features': 30}
# Trained and Tested combination 17 of 576, taking 0.01 seconds to get val score of 0.3086:
#                 {'var_smoothing': 0.1, 'features': 50},
#             Current best combo with val score 0.4657:
#                     {'var_smoothing': 1e-05, 'features': 30}
# Trained and Tested combination 18 of 576, taking 0.01 seconds to get val score of 0.0:
#                 {'var_smoothing': 100, 'features': 15},
#             Current best combo with val score 0.4657:
#                     {'var_smoothing': 1e-05, 'features': 30}
# Trained and Tested combination 19 of 576, taking 0.01 seconds to get val score of 0.3093:
#                 {'var_smoothing': 1e-05, 'features': 50},
#             Current best combo with val score 0.4657:
#                     {'var_smoothing': 1e-05, 'features': 30}
# Trained and Tested combination 20 of 576, taking 0.01 seconds to get val score of 0.159:
#                 {'var_smoothing': 0.1, 'features': 20},
#             Current best combo with val score 0.4657:
#                     {'var_smoothing': 1e-05, 'features': 30}
# Trained and Tested combination 21 of 576, taking 0.01 seconds to get val score of 0.0:
#                 {'var_smoothing': 100, 'features': 55},
#             Current best combo with val score 0.4657:
#                     {'var_smoothing': 1e-05, 'features': 30}
# Trained and Tested combination 22 of 576, taking 0.02 seconds to get val score of 0.3093:
#                 {'var_smoothing': 1e-05, 'features': 63},
#             Current best combo with val score 0.4657:
#                     {'var_smoothing': 1e-05, 'features': 30}
# Trained and Tested combination 23 of 576, taking 0.01 seconds to get val score of 0.0:
#                 {'var_smoothing': 100, 'features': 63},
#             Current best combo with val score 0.4657:
#                     {'var_smoothing': 1e-05, 'features': 30}
# Trained and Tested combination 24 of 576, taking 0.0 seconds to get val score of 0.2933:
#                 {'var_smoothing': 0.1, 'features': 0},
#             Current best combo with val score 0.4657:
#                     {'var_smoothing': 1e-05, 'features': 30}
# Trained and Tested combination 25 of 576, taking 0.0 seconds to get val score of 0.0:
#                 {'var_smoothing': 100, 'features': 5},
#             Current best combo with val score 0.4657:
#                     {'var_smoothing': 1e-05, 'features': 30}
# Trained and Tested combination 26 of 576, taking 0.0 seconds to get val score of 0.0:
#                 {'var_smoothing': 100, 'features': 25},
#             Current best combo with val score 0.4657:
#                     {'var_smoothing': 1e-05, 'features': 30}
# Trained and Tested combination 27 of 576, taking 0.0 seconds to get val score of 0.0:
#                 {'var_smoothing': 100, 'features': 10},
#             Current best combo with val score 0.4657:
#                     {'var_smoothing': 1e-05, 'features': 30}
# Trained and Tested combination 28 of 576, taking 0.01 seconds to get val score of 0.3086:
#                 {'var_smoothing': 0.1, 'features': 71},
#             Current best combo with val score 0.4657:
#                     {'var_smoothing': 1e-05, 'features': 30}
# Trained and Tested combination 29 of 576, taking 0.0 seconds to get val score of 0.2933:
#                 {'var_smoothing': 1e-05, 'features': 0},
#             Current best combo with val score 0.4657:
#                     {'var_smoothing': 1e-05, 'features': 30}
# Trained and Tested combination 30 of 576, taking 0.0 seconds to get val score of 0.3086:
#                 {'var_smoothing': 0.1, 'features': 40},
#             Current best combo with val score 0.4657:
#                     {'var_smoothing': 1e-05, 'features': 30}
# Trained and Tested combination 31 of 576, taking 0.01 seconds to get val score of 0.3093:
#                 {'var_smoothing': 1e-05, 'features': 55},
#             Current best combo with val score 0.4657:
#                     {'var_smoothing': 1e-05, 'features': 30}
# Trained and Tested combination 32 of 576, taking 0.0 seconds to get val score of 0.0:
#                 {'var_smoothing': 100, 'features': 35},
#             Current best combo with val score 0.4657:
#                     {'var_smoothing': 1e-05, 'features': 30}
# Trained and Tested combination 33 of 576, taking 0.01 seconds to get val score of 0.3093:
#                 {'var_smoothing': 1e-05, 'features': 59},
#             Current best combo with val score 0.4657:
#                     {'var_smoothing': 1e-05, 'features': 30}
# Trained and Tested combination 34 of 576, taking 0.0 seconds to get val score of 0.0:
#                 {'var_smoothing': 100, 'features': 30},
#             Current best combo with val score 0.4657:
#                     {'var_smoothing': 1e-05, 'features': 30}
# Trained and Tested combination 35 of 576, taking 0.0 seconds to get val score of 0.4909:
#                 {'var_smoothing': 1e-05, 'features': 15},
#             Current best combo with val score 0.4909:
#                     {'var_smoothing': 1e-05, 'features': 15}
# Trained and Tested combination 36 of 576, taking 0.01 seconds to get val score of 0.3086:
#                 {'var_smoothing': 0.1, 'features': 67},
#             Current best combo with val score 0.4909:
#                     {'var_smoothing': 1e-05, 'features': 15}
# Trained and Tested combination 37 of 576, taking 0.01 seconds to get val score of 0.3091:
#                 {'var_smoothing': 1e-05, 'features': 71},
#             Current best combo with val score 0.4909:
#                     {'var_smoothing': 1e-05, 'features': 15}
# Trained and Tested combination 38 of 576, taking 0.01 seconds to get val score of 0.0:
#                 {'var_smoothing': 100, 'features': 50},
#             Current best combo with val score 0.4909:
#                     {'var_smoothing': 1e-05, 'features': 15}
# Trained and Tested combination 39 of 576, taking 0.0 seconds to get val score of 0.3086:
#                 {'var_smoothing': 1e-05, 'features': 35},
#             Current best combo with val score 0.4909:
#                     {'var_smoothing': 1e-05, 'features': 15}
# Trained and Tested combination 40 of 576, taking 0.01 seconds to get val score of 0.3086:
#                 {'var_smoothing': 0.1, 'features': 59},
#             Current best combo with val score 0.4909:
#                     {'var_smoothing': 1e-05, 'features': 15}
# Trained and Tested combination 41 of 576, taking 0.0 seconds to get val score of 0.4764:
#                 {'var_smoothing': 1e-05, 'features': 25},
#             Current best combo with val score 0.4909:
#                     {'var_smoothing': 1e-05, 'features': 15}
# Trained and Tested combination 42 of 576, taking 0.0 seconds to get val score of 0.423:
#                 {'var_smoothing': 1e-05, 'features': 5},
#             Current best combo with val score 0.4909:
#                     {'var_smoothing': 1e-05, 'features': 15}
# Trained and Tested combination 43 of 576, taking 0.01 seconds to get val score of 0.0:
#                 {'var_smoothing': 100, 'features': 45},
#             Current best combo with val score 0.4909:
#                     {'var_smoothing': 1e-05, 'features': 15}
# Trained and Tested combination 44 of 576, taking 0.0 seconds to get val score of 0.0:
#                 {'var_smoothing': 100, 'features': 20},
#             Current best combo with val score 0.4909:
#                     {'var_smoothing': 1e-05, 'features': 15}
# Trained and Tested combination 45 of 576, taking 0.01 seconds to get val score of 0.1606:
#                 {'var_smoothing': 0.1, 'features': 25},
#             Current best combo with val score 0.4909:
#                     {'var_smoothing': 1e-05, 'features': 15}
# Trained and Tested combination 46 of 576, taking 0.02 seconds to get val score of 0.0:
#                 {'var_smoothing': 100, 'features': 71},
#             Current best combo with val score 0.4909:
#                     {'var_smoothing': 1e-05, 'features': 15}
# Trained and Tested combination 47 of 576, taking 0.01 seconds to get val score of 0.3086:
#                 {'var_smoothing': 0.1, 'features': 35},
#             Current best combo with val score 0.4909:
#                     {'var_smoothing': 1e-05, 'features': 15}
# Trained and Tested combination 48 of 576, taking 0.0 seconds to get val score of 0.0:
#                 {'var_smoothing': 100, 'features': 0},
#             Current best combo with val score 0.4909:
#                     {'var_smoothing': 1e-05, 'features': 15}
# Trained and Tested combination 49 of 576, taking 0.01 seconds to get val score of 0.3086:
#                 {'var_smoothing': 0.1, 'features': 36},
#             Current best combo with val score 0.4909:
#                     {'var_smoothing': 1e-05, 'features': 15}
#
#
# STAGE ONE: Begin initial Guidance system
#
#
# Guidance: initial round
#
# 	round 0 iteration:  0
#
# Trained and Tested combination 50 of 576, taking 0.01 seconds to get val score of 0.3086:
#                 {'var_smoothing': 0.01, 'features': 36},
#             Current best combo with val score 0.4909:
#                     {'var_smoothing': 1e-05, 'features': 15}
# Trained and Tested combination 51 of 576, taking 0.0 seconds to get val score of 0.3086:
#                 {'var_smoothing': 1, 'features': 36},
#             Current best combo with val score 0.4909:
#                     {'var_smoothing': 1e-05, 'features': 15}
# Already Trained and Tested combination (val score of 0.3086):
#             {'var_smoothing': 0.1, 'features': 35}
#             Current best combo (with val score 0.4909):
#                     {'var_smoothing': 1e-05, 'features': 15}
#         Has trained 51 of 576 combinations so far
# Trained and Tested combination 52 of 576, taking 0.0 seconds to get val score of 0.3086:
#                 {'var_smoothing': 0.1, 'features': 37},
#             Current best combo with val score 0.4909:
#                     {'var_smoothing': 1e-05, 'features': 15}
# 	round 0 iteration:  1
#
# Trained and Tested combination 53 of 576, taking 0.0 seconds to get val score of 0.3086:
#                 {'var_smoothing': 0.001, 'features': 36},
#             Current best combo with val score 0.4909:
#                     {'var_smoothing': 1e-05, 'features': 15}
# Already Trained and Tested combination (val score of 0.3086):
#             {'var_smoothing': 0.1, 'features': 36}
#             Current best combo (with val score 0.4909):
#                     {'var_smoothing': 1e-05, 'features': 15}
#         Has trained 53 of 576 combinations so far
# Trained and Tested combination 54 of 576, taking 0.0 seconds to get val score of 0.3086:
#                 {'var_smoothing': 0.01, 'features': 35},
#             Current best combo with val score 0.4909:
#                     {'var_smoothing': 1e-05, 'features': 15}
# Trained and Tested combination 55 of 576, taking 0.0 seconds to get val score of 0.3086:
#                 {'var_smoothing': 0.01, 'features': 37},
#             Current best combo with val score 0.4909:
#                     {'var_smoothing': 1e-05, 'features': 15}
# Already Trained and Tested combination (val score of 0.3086):
#             {'var_smoothing': 0.1, 'features': 36}
#             Current best combo (with val score 0.4909):
#                     {'var_smoothing': 1e-05, 'features': 15}
#         Has trained 55 of 576 combinations so far
# Trained and Tested combination 56 of 576, taking 0.0 seconds to get val score of 0.3086:
#                 {'var_smoothing': 10, 'features': 36},
#             Current best combo with val score 0.4909:
#                     {'var_smoothing': 1e-05, 'features': 15}
# Trained and Tested combination 57 of 576, taking 0.01 seconds to get val score of 0.3086:
#                 {'var_smoothing': 1, 'features': 35},
#             Current best combo with val score 0.4909:
#                     {'var_smoothing': 1e-05, 'features': 15}
# Trained and Tested combination 58 of 576, taking 0.0 seconds to get val score of 0.3086:
#                 {'var_smoothing': 1, 'features': 37},
#             Current best combo with val score 0.4909:
#                     {'var_smoothing': 1e-05, 'features': 15}
# Already Trained and Tested combination (val score of 0.3086):
#             {'var_smoothing': 0.01, 'features': 35}
#             Current best combo (with val score 0.4909):
#                     {'var_smoothing': 1e-05, 'features': 15}
#         Has trained 58 of 576 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'var_smoothing': 1, 'features': 35}
#             Current best combo (with val score 0.4909):
#                     {'var_smoothing': 1e-05, 'features': 15}
#         Has trained 58 of 576 combinations so far
# Trained and Tested combination 59 of 576, taking 0.0 seconds to get val score of 0.3086:
#                 {'var_smoothing': 0.1, 'features': 34},
#             Current best combo with val score 0.4909:
#                     {'var_smoothing': 1e-05, 'features': 15}
# Already Trained and Tested combination (val score of 0.3086):
#             {'var_smoothing': 0.1, 'features': 36}
#             Current best combo (with val score 0.4909):
#                     {'var_smoothing': 1e-05, 'features': 15}
#         Has trained 59 of 576 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'var_smoothing': 0.01, 'features': 37}
#             Current best combo (with val score 0.4909):
#                     {'var_smoothing': 1e-05, 'features': 15}
#         Has trained 59 of 576 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'var_smoothing': 1, 'features': 37}
#             Current best combo (with val score 0.4909):
#                     {'var_smoothing': 1e-05, 'features': 15}
#         Has trained 59 of 576 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'var_smoothing': 0.1, 'features': 36}
#             Current best combo (with val score 0.4909):
#                     {'var_smoothing': 1e-05, 'features': 15}
#         Has trained 59 of 576 combinations so far
# Trained and Tested combination 60 of 576, taking 0.01 seconds to get val score of 0.3086:
#                 {'var_smoothing': 0.1, 'features': 38},
#             Current best combo with val score 0.4909:
#                     {'var_smoothing': 1e-05, 'features': 15}
# Trained and Tested combination 61 of 576, taking 0.0 seconds to get val score of 0.4616:
#                 {'var_smoothing': 0.0001, 'features': 15},
#             Current best combo with val score 0.4909:
#                     {'var_smoothing': 1e-05, 'features': 15}
# Trained and Tested combination 62 of 576, taking 0.01 seconds to get val score of 0.4807:
#                 {'var_smoothing': 1e-05, 'features': 14},
#             Current best combo with val score 0.4909:
#                     {'var_smoothing': 1e-05, 'features': 15}
# Trained and Tested combination 63 of 576, taking 0.0 seconds to get val score of 0.4916:
#                 {'var_smoothing': 1e-05, 'features': 16},
#             Current best combo with val score 0.4916:
#                     {'var_smoothing': 1e-05, 'features': 16}
# Trained and Tested combination 64 of 576, taking 0.0 seconds to get val score of 0.4792:
#                 {'var_smoothing': 0.0001, 'features': 16},
#             Current best combo with val score 0.4916:
#                     {'var_smoothing': 1e-05, 'features': 16}
# Already Trained and Tested combination (val score of 0.4909):
#             {'var_smoothing': 1e-05, 'features': 15}
#             Current best combo (with val score 0.4916):
#                     {'var_smoothing': 1e-05, 'features': 16}
#         Has trained 64 of 576 combinations so far
# Trained and Tested combination 65 of 576, taking 0.0 seconds to get val score of 0.4619:
#                 {'var_smoothing': 1e-05, 'features': 17},
#             Current best combo with val score 0.4916:
#                     {'var_smoothing': 1e-05, 'features': 16}
# % Combos Checked Thus Far: 65 out of 576 which is 11.284722%
# STAGE TWO: Begin Cruise system
#
#
# Cruising Coordrdinate 1 of 48
#
# Cruising Coordrdinate 2 of 48
#
# Cruising Coordrdinate 3 of 48
#
# Cruising Coordrdinate 4 of 48
#
# Cruising Coordrdinate 5 of 48
#
# Cruising Coordrdinate 6 of 48
#
# Cruising Coordrdinate 7 of 48
#
# Cruising Coordrdinate 8 of 48
#
# Cruising Coordrdinate 9 of 48
#
# Cruising Coordrdinate 10 of 48
#
# Cruising Coordrdinate 11 of 48
#
# Cruising Coordrdinate 12 of 48
#
# Cruising Coordrdinate 13 of 48
#
# Cruising Coordrdinate 14 of 48
#
# Cruising Coordrdinate 15 of 48
#
# Cruising Coordrdinate 16 of 48
#
# Cruising Coordrdinate 17 of 48
#
# Cruising Coordrdinate 18 of 48
#
# Cruising Coordrdinate 19 of 48
#
# Cruising Coordrdinate 20 of 48
#
# Cruising Coordrdinate 21 of 48
#
# Cruising Coordrdinate 22 of 48
#
# Cruising Coordrdinate 23 of 48
#
# Cruising Coordrdinate 24 of 48
#
# Cruising Coordrdinate 25 of 48
#
# Cruising Coordrdinate 26 of 48
#
# Cruising Coordrdinate 27 of 48
#
# Cruising Coordrdinate 28 of 48
#
# Cruising Coordrdinate 29 of 48
#
# Cruising Coordrdinate 30 of 48
#
# Cruising Coordrdinate 31 of 48
#
# Cruising Coordrdinate 32 of 48
#
# Cruising Coordrdinate 33 of 48
#
# Cruise suspended due to suspicious case
# Guidance: round 1
#
# 	round 1 iteration:  0
#
# Trained and Tested combination 66 of 576, taking 0.0 seconds to get val score of 0.4558:
#                 {'var_smoothing': 0.0001, 'features': 30},
#             Current best combo with val score 0.4916:
#                     {'var_smoothing': 1e-05, 'features': 16}
# Trained and Tested combination 67 of 576, taking 0.0 seconds to get val score of 0.4678:
#                 {'var_smoothing': 1e-05, 'features': 29},
#             Current best combo with val score 0.4916:
#                     {'var_smoothing': 1e-05, 'features': 16}
# Trained and Tested combination 68 of 576, taking 0.0 seconds to get val score of 0.3086:
#                 {'var_smoothing': 1e-05, 'features': 31},
#             Current best combo with val score 0.4916:
#                     {'var_smoothing': 1e-05, 'features': 16}
# 	round 1 iteration:  1
#
# Trained and Tested combination 69 of 576, taking 0.0 seconds to get val score of 0.4578:
#                 {'var_smoothing': 0.0001, 'features': 29},
#             Current best combo with val score 0.4916:
#                     {'var_smoothing': 1e-05, 'features': 16}
# Trained and Tested combination 70 of 576, taking 0.0 seconds to get val score of 0.4697:
#                 {'var_smoothing': 1e-05, 'features': 28},
#             Current best combo with val score 0.4916:
#                     {'var_smoothing': 1e-05, 'features': 16}
# Already Trained and Tested combination (val score of 0.4657):
#             {'var_smoothing': 1e-05, 'features': 30}
#             Current best combo (with val score 0.4916):
#                     {'var_smoothing': 1e-05, 'features': 16}
#         Has trained 70 of 576 combinations so far
# % Combos Checked Thus Far: 70 out of 576 which is 12.152778%
# Cruising Coordrdinate 34 of 48
#
# Cruising Coordrdinate 35 of 48
#
# Cruising Coordrdinate 36 of 48
#
# Cruising Coordrdinate 37 of 48
#
# Cruising Coordrdinate 38 of 48
#
# Cruising Coordrdinate 39 of 48
#
# Cruising Coordrdinate 40 of 48
#
# Cruise suspended due to suspicious case
# Guidance: round 2
#
# 	round 2 iteration:  0
#
# Trained and Tested combination 71 of 576, taking 0.0 seconds to get val score of 0.4631:
#                 {'var_smoothing': 0.0001, 'features': 25},
#             Current best combo with val score 0.4916:
#                     {'var_smoothing': 1e-05, 'features': 16}
# Trained and Tested combination 72 of 576, taking 0.0 seconds to get val score of 0.4751:
#                 {'var_smoothing': 1e-05, 'features': 24},
#             Current best combo with val score 0.4916:
#                     {'var_smoothing': 1e-05, 'features': 16}
# Trained and Tested combination 73 of 576, taking 0.0 seconds to get val score of 0.4733:
#                 {'var_smoothing': 1e-05, 'features': 26},
#             Current best combo with val score 0.4916:
#                     {'var_smoothing': 1e-05, 'features': 16}
# 	round 2 iteration:  1
#
# Trained and Tested combination 74 of 576, taking 0.0 seconds to get val score of 0.4597:
#                 {'var_smoothing': 0.0001, 'features': 24},
#             Current best combo with val score 0.4916:
#                     {'var_smoothing': 1e-05, 'features': 16}
# Trained and Tested combination 75 of 576, taking 0.01 seconds to get val score of 0.4778:
#                 {'var_smoothing': 1e-05, 'features': 23},
#             Current best combo with val score 0.4916:
#                     {'var_smoothing': 1e-05, 'features': 16}
# Already Trained and Tested combination (val score of 0.4764):
#             {'var_smoothing': 1e-05, 'features': 25}
#             Current best combo (with val score 0.4916):
#                     {'var_smoothing': 1e-05, 'features': 16}
#         Has trained 75 of 576 combinations so far
# Trained and Tested combination 76 of 576, taking 0.01 seconds to get val score of 0.4616:
#                 {'var_smoothing': 0.0001, 'features': 26},
#             Current best combo with val score 0.4916:
#                     {'var_smoothing': 1e-05, 'features': 16}
# Already Trained and Tested combination (val score of 0.4764):
#             {'var_smoothing': 1e-05, 'features': 25}
#             Current best combo (with val score 0.4916):
#                     {'var_smoothing': 1e-05, 'features': 16}
#         Has trained 76 of 576 combinations so far
# Trained and Tested combination 77 of 576, taking 0.01 seconds to get val score of 0.4794:
#                 {'var_smoothing': 1e-05, 'features': 27},
#             Current best combo with val score 0.4916:
#                     {'var_smoothing': 1e-05, 'features': 16}
# % Combos Checked Thus Far: 77 out of 576 which is 13.368056000000001%
# Cruising Coordrdinate 41 of 48
#
# Cruising Coordrdinate 42 of 48
#
# Cruising Coordrdinate 43 of 48
#
# Cruising Coordrdinate 44 of 48
#
# Cruising Coordrdinate 45 of 48
#
# Cruising Coordrdinate 46 of 48
#
# Cruising Coordrdinate 47 of 48
#
# Cruising Coordrdinate 48 of 48
#
# Cruise suspended due to suspicious case
# Guidance: round 3
#
# 	round 3 iteration:  0
#
# Already Trained and Tested combination (val score of 0.4616):
#             {'var_smoothing': 0.0001, 'features': 15}
#             Current best combo (with val score 0.4916):
#                     {'var_smoothing': 1e-05, 'features': 16}
#         Has trained 77 of 576 combinations so far
# Already Trained and Tested combination (val score of 0.4807):
#             {'var_smoothing': 1e-05, 'features': 14}
#             Current best combo (with val score 0.4916):
#                     {'var_smoothing': 1e-05, 'features': 16}
#         Has trained 77 of 576 combinations so far
# Already Trained and Tested combination (val score of 0.4916):
#             {'var_smoothing': 1e-05, 'features': 16}
#             Current best combo (with val score 0.4916):
#                     {'var_smoothing': 1e-05, 'features': 16}
#         Has trained 77 of 576 combinations so far
# 	round 3 iteration:  1
#
# Already Trained and Tested combination (val score of 0.4792):
#             {'var_smoothing': 0.0001, 'features': 16}
#             Current best combo (with val score 0.4916):
#                     {'var_smoothing': 1e-05, 'features': 16}
#         Has trained 77 of 576 combinations so far
# Already Trained and Tested combination (val score of 0.4909):
#             {'var_smoothing': 1e-05, 'features': 15}
#             Current best combo (with val score 0.4916):
#                     {'var_smoothing': 1e-05, 'features': 16}
#         Has trained 77 of 576 combinations so far
# Already Trained and Tested combination (val score of 0.4619):
#             {'var_smoothing': 1e-05, 'features': 17}
#             Current best combo (with val score 0.4916):
#                     {'var_smoothing': 1e-05, 'features': 16}
#         Has trained 77 of 576 combinations so far
# % Combos Checked Thus Far: 77 out of 576 which is 13.368056000000001%
# FINAL STAGE: Begin final Guidance system
#
#
# Guidance: round FINAL
#
# 	round FINAL iteration:  0
#
# % Combos Checked Thus Far: 77 out of 576 which is 13.368056000000001%
# Max Val Score:
#  0.49158
# Max Val Score Std:
#  0.035259
# Best Combo Train Score:
#  0.552075
# Best Combo Train Score Std:
#  0.005718
# Max Combo Index:
#  (0, 16) out of [8, 72] (note best combo is 0-indexed)
# Max Combo Hyperparamer Combination:
#  {'var_smoothing': 1e-05, 'features': 16}
# Max Combo Features:
#  ('procedure_228130', 'procedure_225792', 'procedure_228125', 'lods_score', 'ventilation_used', 'procedure_226236', 'hospital_stay_duration', 'procedure_225469', 'procedure_224270', 'procedure_225446', 'procedure_225802', 'procedure_227712', 'procedure_229580', 'procedure_225451', 'admission_type_DIRECT EMER.', 'admission_type_DIRECT OBSERVATION', 'admission_type_ELECTIVE', 'admission_type_EU OBSERVATION', 'admission_type_EW EMER.', 'admission_type_OBSERVATION ADMIT', 'admission_type_URGENT', 'admission_type_SURGICAL SAME DAY ADMISSION', 'procedure_224385', 'procedure_224267')
# % Combos Checked: 77 out of 576 which is 13.368056000000001%
