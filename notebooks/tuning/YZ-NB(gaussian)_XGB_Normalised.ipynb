# %% [markdown]
# # Tuning Script

# %%
# Parameters subject to change in every script - involved in naming

MODEL = 'nb(gaussian)'
PREPROCESSING = 'normalise'
TUNER = 'yangzhoub'
OPTIMISED_METRIC = 'f1'

# %% [markdown]
# ---

# %%
# detect whether this is a google environment

COLAB_ENVIRONMENT = False

try:
    from google.colab import drive
    drive.mount('/content/drive')
    COLAB_ENVIRONMENT = True
except:
    pass
# Out:
# Mounted at /content/drive

# %%
import sys
import os
import pickle

if COLAB_ENVIRONMENT:
    home_directory = './drive/MyDrive/LAB/COMP90089__GroupWork__Py/' # my home directory is stored in ./LAB of google drive
    if MODEL == 'ebr':
        # !pip install interpret==0.5.0
    elif MODEL == 'cbr':
        # !pip install catboost
    elif MODEL in ['tf', 'mlp']:
        # !pip install PyTorch2Sklearn
    # !pip install JXAutoML
else:
    home_directory = '../../'

from JXAutoML.YangZhouB_10CV import YangZhouB_10CV as Tuner

import pandas as pd
# Out:
# Collecting JXAutoML
#   Downloading JXAutoML-0.4.4-py3-none-any.whl.metadata (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.2/67.2 kB 1.9 MB/s eta 0:00:00
# Downloading JXAutoML-0.4.4-py3-none-any.whl (52 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.1/52.1 kB 3.2 MB/s eta 0:00:00
# Installing collected packages: JXAutoML
# Successfully installed JXAutoML-0.4.4

# %%
# Parameters that are same for every script

FOLDS = 10  # we have decided to do 10 fold validation

SEED = 42

TASK_TYPE = 'Classification'  # this task is a classification task

# we have decided to tune features as hp
TUNE_FEATURES_AS_HYPERPARAMETERS = True

# %% [markdown]
# ---

# %%
# model to use to tune
from sklearn.naive_bayes import GaussianNB as clf

# what values to try for each hyperparameter
parameter_choices = {
    'var_smoothing': (0.00001, 0.0001, 0.001, 0.01, 0.1, 1, 10, 100),
}

# what values to set non-tuneable parameters/hyperparameters
non_tunable_hyperparameters_dict = {}

# %% [markdown]
# ---

# %% [markdown]
# Read in and Prepare Data

# %%
# Import data and store as lists

train_x_list = []
train_y_list = []
val_x_list = []
val_y_list = []

for i in range(FOLDS):
    train_data = pd.read_csv(
        f'{home_directory}data/curated/modelling/{PREPROCESSING}/train_{i}.csv')
    val_data = pd.read_csv(
        f'{home_directory}data/curated/modelling/{PREPROCESSING}/val_{i}.csv')

    # get the correct rows for X and y
    train_x = train_data.drop(
        ['mortality_status', 'subject_id', 'hadm_id', 'stay_id'], axis=1)
    train_y = train_data['mortality_status']
    val_x = val_data.drop(
        ['mortality_status', 'subject_id', 'hadm_id', 'stay_id'], axis=1)
    val_y = val_data['mortality_status']

    train_x_list.append(train_x)
    train_y_list.append(train_y)
    val_x_list.append(val_x)
    val_y_list.append(val_y)

# %%
# Import feature importance ordering

with open(f'{home_directory}models/xgb_feature_importance_ordering_{PREPROCESSING}.pickle', 'rb') as f:
    feature_importance_ordering = pickle.load(f)

# %% [markdown]
# Set parameters

# %%
# initialisation
tuner = Tuner()

print('---')

# define what model we are tuning
tuner.read_in_model(clf, TASK_TYPE, optimised_metric=OPTIMISED_METRIC)

print('---')

# read in the data for training and validation
tuner.read_in_data(train_x_list, train_y_list, val_x_list, val_y_list)

print('---')

# set what hp values to tune
tuner.set_hyperparameters(parameter_choices)
# WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

# set up hp values that need to be changed from default but NOT to be tuned
tuner.set_non_tuneable_hyperparameters(non_tunable_hyperparameters_dict)

print('---')

# set up feature importance ordering

if TUNE_FEATURES_AS_HYPERPARAMETERS:
    tuner.set_features(feature_importance_ordering)
    # WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

try:  # try to read in previous results to continue tuning ...
    tuner.read_in_tuning_result_df(
        f'{home_directory}models/tuning/{TUNER}_{MODEL}_{PREPROCESSING}.csv')
except:
    print('No previous tuning data read in')

print('---')

# set up where to save the tuning result csv
tuner.set_tuning_result_saving_address(
    f'{home_directory}models/tuning/{TUNER}_{MODEL}_{PREPROCESSING}.csv')

print('---')

# set up where to save the current best model
tuner.set_best_model_saving_address(
    f'{home_directory}models/tmp_models/{TUNER}_{MODEL}_{PREPROCESSING}')
# Out:
# YangZhouB Initialised
# ---
# Successfully read in model <class 'sklearn.naive_bayes.GaussianNB'>, which is a Classification model optimising for f1
# ---
# Read in Train X data list
# Read in Train y data list
# Read in Val X data list
# Read in Val y data list
# ---
# Successfully recorded hyperparameter choices
# ---
# Successfully recorded non_tuneable_hyperparameter choices
# ---
# Successfully recorded tuneable feature combination choices and updated relevant internal structures
# ---
# No previous tuning data read in
# ---
# Successfully set tuning output address
# ---
# Successfully set best model output address

# %%
# ignore warnings

import warnings
warnings.filterwarnings("ignore")

# %%
# begin tuning ... (or continue training)

tuner.tune()
# Out:
# BEGIN TUNING
#
#
# STAGE ZERO: Tune all Cruise combinations
#
#
# Trained and Tested combination 1 of 408, taking 0.01 seconds to get val score of 0.3135:
#                 {'var_smoothing': 1e-05, 'features': 45},
#             Current best combo with val score 0.3135:
#                     {'var_smoothing': 1e-05, 'features': 45}
# Trained and Tested combination 2 of 408, taking 0.01 seconds to get val score of 0.0:
#                 {'var_smoothing': 100, 'features': 25},
#             Current best combo with val score 0.3135:
#                     {'var_smoothing': 1e-05, 'features': 45}
# Trained and Tested combination 3 of 408, taking 0.01 seconds to get val score of 0.3135:
#                 {'var_smoothing': 1e-05, 'features': 50},
#             Current best combo with val score 0.3135:
#                     {'var_smoothing': 1e-05, 'features': 45}
# Trained and Tested combination 4 of 408, taking 0.01 seconds to get val score of 0.3318:
#                 {'var_smoothing': 1e-05, 'features': 20},
#             Current best combo with val score 0.3318:
#                     {'var_smoothing': 1e-05, 'features': 20}
# Trained and Tested combination 5 of 408, taking 0.02 seconds to get val score of 0.0:
#                 {'var_smoothing': 100, 'features': 45},
#             Current best combo with val score 0.3318:
#                     {'var_smoothing': 1e-05, 'features': 20}
# Trained and Tested combination 6 of 408, taking 0.01 seconds to get val score of 0.0:
#                 {'var_smoothing': 100, 'features': 15},
#             Current best combo with val score 0.3318:
#                     {'var_smoothing': 1e-05, 'features': 20}
# Trained and Tested combination 7 of 408, taking 0.01 seconds to get val score of 0.3135:
#                 {'var_smoothing': 1e-05, 'features': 40},
#             Current best combo with val score 0.3318:
#                     {'var_smoothing': 1e-05, 'features': 20}
# Trained and Tested combination 8 of 408, taking 0.01 seconds to get val score of 0.2987:
#                 {'var_smoothing': 0.1, 'features': 30},
#             Current best combo with val score 0.3318:
#                     {'var_smoothing': 1e-05, 'features': 20}
# Trained and Tested combination 9 of 408, taking 0.01 seconds to get val score of 0.0:
#                 {'var_smoothing': 100, 'features': 40},
#             Current best combo with val score 0.3318:
#                     {'var_smoothing': 1e-05, 'features': 20}
# Trained and Tested combination 10 of 408, taking 0.0 seconds to get val score of 0.0:
#                 {'var_smoothing': 0.1, 'features': 0},
#             Current best combo with val score 0.3318:
#                     {'var_smoothing': 1e-05, 'features': 20}
# Trained and Tested combination 11 of 408, taking 0.01 seconds to get val score of 0.3117:
#                 {'var_smoothing': 0.1, 'features': 40},
#             Current best combo with val score 0.3318:
#                     {'var_smoothing': 1e-05, 'features': 20}
# Trained and Tested combination 12 of 408, taking 0.01 seconds to get val score of 0.3445:
#                 {'var_smoothing': 0.1, 'features': 10},
#             Current best combo with val score 0.3445:
#                     {'var_smoothing': 0.1, 'features': 10}
# Trained and Tested combination 13 of 408, taking 0.01 seconds to get val score of 0.0:
#                 {'var_smoothing': 0.1, 'features': 25},
#             Current best combo with val score 0.3445:
#                     {'var_smoothing': 0.1, 'features': 10}
# Trained and Tested combination 14 of 408, taking 0.01 seconds to get val score of 0.2861:
#                 {'var_smoothing': 0.1, 'features': 5},
#             Current best combo with val score 0.3445:
#                     {'var_smoothing': 0.1, 'features': 10}
# Trained and Tested combination 15 of 408, taking 0.01 seconds to get val score of 0.3349:
#                 {'var_smoothing': 1e-05, 'features': 25},
#             Current best combo with val score 0.3445:
#                     {'var_smoothing': 0.1, 'features': 10}
# Trained and Tested combination 16 of 408, taking 0.02 seconds to get val score of 0.0:
#                 {'var_smoothing': 100, 'features': 20},
#             Current best combo with val score 0.3445:
#                     {'var_smoothing': 0.1, 'features': 10}
# Already Trained and Tested combination (val score of 0.0):
#             {'var_smoothing': 0.1, 'features': 25}
#             Current best combo (with val score 0.3445):
#                     {'var_smoothing': 0.1, 'features': 10}
#         Has trained 16 of 408 combinations so far
# Trained and Tested combination 17 of 408, taking 0.02 seconds to get val score of 0.3292:
#                 {'var_smoothing': 1e-05, 'features': 30},
#             Current best combo with val score 0.3445:
#                     {'var_smoothing': 0.1, 'features': 10}
# Trained and Tested combination 18 of 408, taking 0.01 seconds to get val score of 0.0:
#                 {'var_smoothing': 100, 'features': 10},
#             Current best combo with val score 0.3445:
#                     {'var_smoothing': 0.1, 'features': 10}
# Trained and Tested combination 19 of 408, taking 0.01 seconds to get val score of 0.3144:
#                 {'var_smoothing': 1e-05, 'features': 5},
#             Current best combo with val score 0.3445:
#                     {'var_smoothing': 0.1, 'features': 10}
# Trained and Tested combination 20 of 408, taking 0.02 seconds to get val score of 0.023:
#                 {'var_smoothing': 0.1, 'features': 20},
#             Current best combo with val score 0.3445:
#                     {'var_smoothing': 0.1, 'features': 10}
# Trained and Tested combination 21 of 408, taking 0.02 seconds to get val score of 0.3134:
#                 {'var_smoothing': 1e-05, 'features': 35},
#             Current best combo with val score 0.3445:
#                     {'var_smoothing': 0.1, 'features': 10}
# Trained and Tested combination 22 of 408, taking 0.0 seconds to get val score of 0.0:
#                 {'var_smoothing': 100, 'features': 0},
#             Current best combo with val score 0.3445:
#                     {'var_smoothing': 0.1, 'features': 10}
# Trained and Tested combination 23 of 408, taking 0.01 seconds to get val score of 0.0:
#                 {'var_smoothing': 100, 'features': 30},
#             Current best combo with val score 0.3445:
#                     {'var_smoothing': 0.1, 'features': 10}
# Trained and Tested combination 24 of 408, taking 0.01 seconds to get val score of 0.3304:
#                 {'var_smoothing': 1e-05, 'features': 15},
#             Current best combo with val score 0.3445:
#                     {'var_smoothing': 0.1, 'features': 10}
# Trained and Tested combination 25 of 408, taking 0.01 seconds to get val score of 0.0:
#                 {'var_smoothing': 100, 'features': 35},
#             Current best combo with val score 0.3445:
#                     {'var_smoothing': 0.1, 'features': 10}
# Trained and Tested combination 26 of 408, taking 0.01 seconds to get val score of 0.023:
#                 {'var_smoothing': 0.1, 'features': 15},
#             Current best combo with val score 0.3445:
#                     {'var_smoothing': 0.1, 'features': 10}
# Trained and Tested combination 27 of 408, taking 0.01 seconds to get val score of 0.3278:
#                 {'var_smoothing': 1e-05, 'features': 10},
#             Current best combo with val score 0.3445:
#                     {'var_smoothing': 0.1, 'features': 10}
# Trained and Tested combination 28 of 408, taking 0.0 seconds to get val score of 0.0:
#                 {'var_smoothing': 1e-05, 'features': 0},
#             Current best combo with val score 0.3445:
#                     {'var_smoothing': 0.1, 'features': 10}
# Trained and Tested combination 29 of 408, taking 0.01 seconds to get val score of 0.3117:
#                 {'var_smoothing': 0.1, 'features': 45},
#             Current best combo with val score 0.3445:
#                     {'var_smoothing': 0.1, 'features': 10}
# Trained and Tested combination 30 of 408, taking 0.01 seconds to get val score of 0.3117:
#                 {'var_smoothing': 0.1, 'features': 35},
#             Current best combo with val score 0.3445:
#                     {'var_smoothing': 0.1, 'features': 10}
# Trained and Tested combination 31 of 408, taking 0.02 seconds to get val score of 0.3117:
#                 {'var_smoothing': 0.1, 'features': 50},
#             Current best combo with val score 0.3445:
#                     {'var_smoothing': 0.1, 'features': 10}
# Trained and Tested combination 32 of 408, taking 0.0 seconds to get val score of 0.0:
#                 {'var_smoothing': 100, 'features': 5},
#             Current best combo with val score 0.3445:
#                     {'var_smoothing': 0.1, 'features': 10}
# Trained and Tested combination 33 of 408, taking 0.01 seconds to get val score of 0.0:
#                 {'var_smoothing': 100, 'features': 50},
#             Current best combo with val score 0.3445:
#                     {'var_smoothing': 0.1, 'features': 10}
#
#
# STAGE ONE: Begin initial Guidance system
#
#
# Guidance: initial round
#
# 	round 0 iteration:  0
#
# Trained and Tested combination 34 of 408, taking 0.01 seconds to get val score of 0.3043:
#                 {'var_smoothing': 0.01, 'features': 25},
#             Current best combo with val score 0.3445:
#                     {'var_smoothing': 0.1, 'features': 10}
# Trained and Tested combination 35 of 408, taking 0.02 seconds to get val score of 0.0:
#                 {'var_smoothing': 1, 'features': 25},
#             Current best combo with val score 0.3445:
#                     {'var_smoothing': 0.1, 'features': 10}
# Trained and Tested combination 36 of 408, taking 0.01 seconds to get val score of 0.0:
#                 {'var_smoothing': 0.1, 'features': 24},
#             Current best combo with val score 0.3445:
#                     {'var_smoothing': 0.1, 'features': 10}
# Trained and Tested combination 37 of 408, taking 0.01 seconds to get val score of 0.0263:
#                 {'var_smoothing': 0.1, 'features': 26},
#             Current best combo with val score 0.3445:
#                     {'var_smoothing': 0.1, 'features': 10}
# 	round 0 iteration:  1
#
# Trained and Tested combination 38 of 408, taking 0.01 seconds to get val score of 0.4062:
#                 {'var_smoothing': 0.001, 'features': 25},
#             Current best combo with val score 0.4062:
#                     {'var_smoothing': 0.001, 'features': 25}
# Already Trained and Tested combination (val score of 0.0):
#             {'var_smoothing': 0.1, 'features': 25}
#             Current best combo (with val score 0.4062):
#                     {'var_smoothing': 0.001, 'features': 25}
#         Has trained 38 of 408 combinations so far
# Trained and Tested combination 39 of 408, taking 0.01 seconds to get val score of 0.2685:
#                 {'var_smoothing': 0.01, 'features': 24},
#             Current best combo with val score 0.4062:
#                     {'var_smoothing': 0.001, 'features': 25}
# Trained and Tested combination 40 of 408, taking 0.01 seconds to get val score of 0.3621:
#                 {'var_smoothing': 0.01, 'features': 26},
#             Current best combo with val score 0.4062:
#                     {'var_smoothing': 0.001, 'features': 25}
# Already Trained and Tested combination (val score of 0.0):
#             {'var_smoothing': 0.1, 'features': 25}
#             Current best combo (with val score 0.4062):
#                     {'var_smoothing': 0.001, 'features': 25}
#         Has trained 40 of 408 combinations so far
# Trained and Tested combination 41 of 408, taking 0.01 seconds to get val score of 0.0:
#                 {'var_smoothing': 10, 'features': 25},
#             Current best combo with val score 0.4062:
#                     {'var_smoothing': 0.001, 'features': 25}
# Trained and Tested combination 42 of 408, taking 0.01 seconds to get val score of 0.0:
#                 {'var_smoothing': 1, 'features': 24},
#             Current best combo with val score 0.4062:
#                     {'var_smoothing': 0.001, 'features': 25}
# Trained and Tested combination 43 of 408, taking 0.01 seconds to get val score of 0.0:
#                 {'var_smoothing': 1, 'features': 26},
#             Current best combo with val score 0.4062:
#                     {'var_smoothing': 0.001, 'features': 25}
# Already Trained and Tested combination (val score of 0.2685):
#             {'var_smoothing': 0.01, 'features': 24}
#             Current best combo (with val score 0.4062):
#                     {'var_smoothing': 0.001, 'features': 25}
#         Has trained 43 of 408 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'var_smoothing': 1, 'features': 24}
#             Current best combo (with val score 0.4062):
#                     {'var_smoothing': 0.001, 'features': 25}
#         Has trained 43 of 408 combinations so far
# Trained and Tested combination 44 of 408, taking 0.01 seconds to get val score of 0.0:
#                 {'var_smoothing': 0.1, 'features': 23},
#             Current best combo with val score 0.4062:
#                     {'var_smoothing': 0.001, 'features': 25}
# Already Trained and Tested combination (val score of 0.0):
#             {'var_smoothing': 0.1, 'features': 25}
#             Current best combo (with val score 0.4062):
#                     {'var_smoothing': 0.001, 'features': 25}
#         Has trained 44 of 408 combinations so far
# Already Trained and Tested combination (val score of 0.3621):
#             {'var_smoothing': 0.01, 'features': 26}
#             Current best combo (with val score 0.4062):
#                     {'var_smoothing': 0.001, 'features': 25}
#         Has trained 44 of 408 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'var_smoothing': 1, 'features': 26}
#             Current best combo (with val score 0.4062):
#                     {'var_smoothing': 0.001, 'features': 25}
#         Has trained 44 of 408 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'var_smoothing': 0.1, 'features': 25}
#             Current best combo (with val score 0.4062):
#                     {'var_smoothing': 0.001, 'features': 25}
#         Has trained 44 of 408 combinations so far
# Trained and Tested combination 45 of 408, taking 0.01 seconds to get val score of 0.0199:
#                 {'var_smoothing': 0.1, 'features': 27},
#             Current best combo with val score 0.4062:
#                     {'var_smoothing': 0.001, 'features': 25}
# Trained and Tested combination 46 of 408, taking 0.01 seconds to get val score of 0.4062:
#                 {'var_smoothing': 0.0001, 'features': 25},
#             Current best combo with val score 0.4062:
#                     {'var_smoothing': 0.0001, 'features': 25}
# Already Trained and Tested combination (val score of 0.3043):
#             {'var_smoothing': 0.01, 'features': 25}
#             Current best combo (with val score 0.4062):
#                     {'var_smoothing': 0.0001, 'features': 25}
#         Has trained 46 of 408 combinations so far
# Trained and Tested combination 47 of 408, taking 0.01 seconds to get val score of 0.3784:
#                 {'var_smoothing': 0.001, 'features': 24},
#             Current best combo with val score 0.4062:
#                     {'var_smoothing': 0.0001, 'features': 25}
# Trained and Tested combination 48 of 408, taking 0.01 seconds to get val score of 0.4659:
#                 {'var_smoothing': 0.001, 'features': 26},
#             Current best combo with val score 0.4659:
#                     {'var_smoothing': 0.001, 'features': 26}
# Trained and Tested combination 49 of 408, taking 0.01 seconds to get val score of 0.392:
#                 {'var_smoothing': 0.0001, 'features': 26},
#             Current best combo with val score 0.4659:
#                     {'var_smoothing': 0.001, 'features': 26}
# Already Trained and Tested combination (val score of 0.3621):
#             {'var_smoothing': 0.01, 'features': 26}
#             Current best combo (with val score 0.4659):
#                     {'var_smoothing': 0.001, 'features': 26}
#         Has trained 49 of 408 combinations so far
# Already Trained and Tested combination (val score of 0.4062):
#             {'var_smoothing': 0.001, 'features': 25}
#             Current best combo (with val score 0.4659):
#                     {'var_smoothing': 0.001, 'features': 26}
#         Has trained 49 of 408 combinations so far
# Trained and Tested combination 50 of 408, taking 0.01 seconds to get val score of 0.459:
#                 {'var_smoothing': 0.001, 'features': 27},
#             Current best combo with val score 0.4659:
#                     {'var_smoothing': 0.001, 'features': 26}
# % Combos Checked Thus Far: 50 out of 408 which is 12.254902%
# STAGE TWO: Begin Cruise system
#
#
# Cruising Coordrdinate 1 of 33
#
# Cruising Coordrdinate 2 of 33
#
# Cruising Coordrdinate 3 of 33
#
# Cruising Coordrdinate 4 of 33
#
# Cruising Coordrdinate 5 of 33
#
# Cruising Coordrdinate 6 of 33
#
# Cruising Coordrdinate 7 of 33
#
# Cruising Coordrdinate 8 of 33
#
# Cruising Coordrdinate 9 of 33
#
# Cruising Coordrdinate 10 of 33
#
# Cruising Coordrdinate 11 of 33
#
# Cruising Coordrdinate 12 of 33
#
# Cruising Coordrdinate 13 of 33
#
# Cruising Coordrdinate 14 of 33
#
# Cruising Coordrdinate 15 of 33
#
# Cruising Coordrdinate 16 of 33
#
# Cruising Coordrdinate 17 of 33
#
# Cruising Coordrdinate 18 of 33
#
# Cruising Coordrdinate 19 of 33
#
# Cruising Coordrdinate 20 of 33
#
# Cruising Coordrdinate 21 of 33
#
# Cruising Coordrdinate 22 of 33
#
# Cruising Coordrdinate 23 of 33
#
# Cruising Coordrdinate 24 of 33
#
# Cruising Coordrdinate 25 of 33
#
# Cruising Coordrdinate 26 of 33
#
# Cruising Coordrdinate 27 of 33
#
# Cruising Coordrdinate 28 of 33
#
# Cruising Coordrdinate 29 of 33
#
# Cruising Coordrdinate 30 of 33
#
# Cruising Coordrdinate 31 of 33
#
# Cruising Coordrdinate 32 of 33
#
# FINAL STAGE: Begin final Guidance system
#
#
# Guidance: round FINAL
#
# 	round FINAL iteration:  0
#
# Already Trained and Tested combination (val score of 0.392):
#             {'var_smoothing': 0.0001, 'features': 26}
#             Current best combo (with val score 0.4659):
#                     {'var_smoothing': 0.001, 'features': 26}
#         Has trained 50 of 408 combinations so far
# Already Trained and Tested combination (val score of 0.3621):
#             {'var_smoothing': 0.01, 'features': 26}
#             Current best combo (with val score 0.4659):
#                     {'var_smoothing': 0.001, 'features': 26}
#         Has trained 50 of 408 combinations so far
# Already Trained and Tested combination (val score of 0.4062):
#             {'var_smoothing': 0.001, 'features': 25}
#             Current best combo (with val score 0.4659):
#                     {'var_smoothing': 0.001, 'features': 26}
#         Has trained 50 of 408 combinations so far
# Already Trained and Tested combination (val score of 0.459):
#             {'var_smoothing': 0.001, 'features': 27}
#             Current best combo (with val score 0.4659):
#                     {'var_smoothing': 0.001, 'features': 26}
#         Has trained 50 of 408 combinations so far
# % Combos Checked Thus Far: 50 out of 408 which is 12.254902%
# Max Val Score:
#  0.465852
# Max Val Score Std:
#  0.053063
# Best Combo Train Score:
#  0.499695
# Best Combo Train Score Std:
#  0.013333
# Max Combo Index:
#  (2, 26) out of [8, 51] (note best combo is 0-indexed)
# Max Combo Hyperparamer Combination:
#  {'var_smoothing': 0.001, 'features': 26}
# Max Combo Features:
#  ('procedure_225792', 'ventilation_used', 'lods_score', 'race_AMERICAN INDIAN/ALASKA NATIVE', 'race_ASIAN', 'race_ASIAN - ASIAN INDIAN', 'race_ASIAN - CHINESE', 'race_ASIAN - KOREAN', 'race_ASIAN - SOUTH EAST ASIAN', 'race_BLACK/AFRICAN', 'race_BLACK/AFRICAN AMERICAN', 'race_BLACK/CAPE VERDEAN', 'race_BLACK/CARIBBEAN ISLAND', 'race_HISPANIC/LATINO - CENTRAL AMERICAN', 'race_HISPANIC/LATINO - COLUMBIAN', 'race_HISPANIC/LATINO - CUBAN', 'race_HISPANIC/LATINO - DOMINICAN', 'race_HISPANIC/LATINO - GUATEMALAN', 'race_HISPANIC/LATINO - HONDURAN', 'race_HISPANIC/LATINO - MEXICAN', 'race_HISPANIC/LATINO - PUERTO RICAN', 'race_HISPANIC/LATINO - SALVADORAN', 'race_MULTIPLE RACE/ETHNICITY', 'race_NATIVE HAWAIIAN OR OTHER PACIFIC ISLANDER', 'race_OTHER', 'race_PATIENT DECLINED TO ANSWER', 'race_PORTUGUESE', 'race_SOUTH AMERICAN', 'race_UNABLE TO OBTAIN', 'race_UNKNOWN', 'race_WHITE', 'race_WHITE - BRAZILIAN', 'race_WHITE - EASTERN EUROPEAN', 'race_WHITE - OTHER EUROPEAN', 'race_WHITE - RUSSIAN', 'race_HISPANIC OR LATINO', 'marital_status_DIVORCED', 'marital_status_MARRIED', 'marital_status_SINGLE', 'marital_status_WIDOWED', 'marital_status_0', 'hospital_stay_duration', 'procedure_225464', 'procedure_225802', 'procedure_227712', 'admission_type_DIRECT EMER.', 'admission_type_DIRECT OBSERVATION', 'admission_type_ELECTIVE', 'admission_type_EU OBSERVATION', 'admission_type_EW EMER.', 'admission_type_OBSERVATION ADMIT', 'admission_type_URGENT', 'admission_type_SURGICAL SAME DAY ADMISSION', 'procedure_225446', 'oasis_score', 'procedure_225400', 'procedure_224263', 'procedure_224276', 'unique_drugs', 'procedure_224267', 'procedure_229351', 'insurance_Medicare', 'insurance_Other', 'insurance_Medicaid', 'icu_stay_duration', 'gender_M', 'gender_F', 'anchor_age', 'item_51301', 'procedure_224275', 'resp_rate', 'item_51265', 'mean_arterial_pressure')
# % Combos Checked: 50 out of 408 which is 12.254902%
