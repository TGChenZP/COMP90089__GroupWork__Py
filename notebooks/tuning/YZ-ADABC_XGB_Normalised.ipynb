# %% [markdown]
# # Tuning Script

# %%
# Parameters subject to change in every script - involved in naming

MODEL = 'adabc'
PREPROCESSING = 'normalise'
TUNER = 'yangzhoub'
OPTIMISED_METRIC = 'f1'

# %% [markdown]
# ---

# %%
# detect whether this is a google environment

COLAB_ENVIRONMENT = False

try:
    from google.colab import drive
    drive.mount('/content/drive')
    COLAB_ENVIRONMENT = True
except:
    pass
# Out:
# Mounted at /content/drive

# %%
import sys
import os
import pickle

if COLAB_ENVIRONMENT:
    home_directory = './drive/MyDrive/LAB/COMP90089__GroupWork__Py/' # my home directory is stored in ./LAB of google drive
    if MODEL == 'ebr':
        # !pip install interpret==0.5.0
    elif MODEL == 'cbr':
        # !pip install catboost
    elif MODEL in ['tf', 'mlp']:
        # !pip install PyTorch2Sklearn
    # !pip install JXAutoML
else:
    home_directory = '../../'

from JXAutoML.YangZhouB_10CV import YangZhouB_10CV as Tuner

import pandas as pd
# Out:
# Collecting JXAutoML
#   Downloading JXAutoML-0.4.4-py3-none-any.whl.metadata (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.2/67.2 kB 4.0 MB/s eta 0:00:00
# Downloading JXAutoML-0.4.4-py3-none-any.whl (52 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.1/52.1 kB 3.7 MB/s eta 0:00:00
# Installing collected packages: JXAutoML
# Successfully installed JXAutoML-0.4.4

# %%
# Parameters that are same for every script

FOLDS = 10  # we have decided to do 10 fold validation

SEED = 42

TASK_TYPE = 'Classification'  # this task is a classification task

# we have decided to tune features as hp
TUNE_FEATURES_AS_HYPERPARAMETERS = True

# %% [markdown]
# ---

# %%
# model to use to tune
from sklearn.ensemble import AdaBoostClassifier as clf

# what values to try for each hyperparameter
parameter_choices = {
    'n_estimators': (25, 50, 100, 200, 400, 800),
    'learning_rate': (0.0001, 0.001, 0.01, 0.1, 1, 10, 100),
    'algorithm': {'SAMME', 'SAMME.R'},

}

# what values to set non-tuneable parameters/hyperparameters
non_tunable_hyperparameters_dict = {
                                    'random_state': 42,
                                    }

# %% [markdown]
# ---

# %% [markdown]
# Read in and Prepare Data

# %%
# Import data and store as lists

train_x_list = []
train_y_list = []
val_x_list = []
val_y_list = []

for i in range(FOLDS):
    train_data = pd.read_csv(
        f'{home_directory}data/curated/modelling/{PREPROCESSING}/train_{i}.csv')
    val_data = pd.read_csv(
        f'{home_directory}data/curated/modelling/{PREPROCESSING}/val_{i}.csv')

    # get the correct rows for X and y
    train_x = train_data.drop(
        ['mortality_status', 'subject_id', 'hadm_id', 'stay_id'], axis=1)
    train_y = train_data['mortality_status']
    val_x = val_data.drop(
        ['mortality_status', 'subject_id', 'hadm_id', 'stay_id'], axis=1)
    val_y = val_data['mortality_status']

    train_x_list.append(train_x)
    train_y_list.append(train_y)
    val_x_list.append(val_x)
    val_y_list.append(val_y)

# %%
# Import feature importance ordering

with open(f'{home_directory}models/xgb_feature_importance_ordering_{PREPROCESSING}.pickle', 'rb') as f:
    feature_importance_ordering = pickle.load(f)

# %% [markdown]
# Set parameters

# %%
# initialisation
tuner = Tuner()

print('---')

# define what model we are tuning
tuner.read_in_model(clf, TASK_TYPE, optimised_metric=OPTIMISED_METRIC)

print('---')

# read in the data for training and validation
tuner.read_in_data(train_x_list, train_y_list, val_x_list, val_y_list)

print('---')

# set what hp values to tune
tuner.set_hyperparameters(parameter_choices)
# WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

# set up hp values that need to be changed from default but NOT to be tuned
tuner.set_non_tuneable_hyperparameters(non_tunable_hyperparameters_dict)

print('---')

# set up feature importance ordering

if TUNE_FEATURES_AS_HYPERPARAMETERS:
    tuner.set_features(feature_importance_ordering)
    # WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

try:  # try to read in previous results to continue tuning ...
    tuner.read_in_tuning_result_df(
        f'{home_directory}models/tuning/{TUNER}_{MODEL}_{PREPROCESSING}.csv')
except:
    print('No previous tuning data read in')

print('---')

# set up where to save the tuning result csv
tuner.set_tuning_result_saving_address(
    f'{home_directory}models/tuning/{TUNER}_{MODEL}_{PREPROCESSING}.csv')

print('---')

# set up where to save the current best model
tuner.set_best_model_saving_address(
    f'{home_directory}models/tmp_models/{TUNER}_{MODEL}_{PREPROCESSING}')
# Out:
# YangZhouB Initialised
# ---
# Successfully read in model <class 'sklearn.ensemble._weight_boosting.AdaBoostClassifier'>, which is a Classification model optimising for f1
# ---
# Read in Train X data list
# Read in Train y data list
# Read in Val X data list
# Read in Val y data list
# ---
# Successfully recorded hyperparameter choices
# ---
# Successfully recorded non_tuneable_hyperparameter choices
# ---
# Successfully recorded tuneable feature combination choices and updated relevant internal structures
# ---
# No previous tuning data read in
# ---
# Successfully set tuning output address
# ---
# Successfully set best model output address

# %%
# ignore warnings

import warnings
warnings.filterwarnings("ignore")

# %%
# begin tuning ... (or continue training)

tuner.tune()
# Out:
# BEGIN TUNING
#
#
# STAGE ZERO: Tune all Cruise combinations
#
#
# Trained and Tested combination 1 of 6048, taking 0.1 seconds to get val score of 0.2933:
#                 {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME', 'features': 0},
#             Current best combo with val score 0.2933:
#                     {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME', 'features': 0}
# Trained and Tested combination 2 of 6048, taking 4.8 seconds to get val score of 0.3058:
#                 {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME', 'features': 35},
#             Current best combo with val score 0.3058:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME', 'features': 35}
# Trained and Tested combination 3 of 6048, taking 5.58 seconds to get val score of 0.2933:
#                 {'n_estimators': 800, 'learning_rate': 0.0001, 'algorithm': 'SAMME', 'features': 45},
#             Current best combo with val score 0.3058:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME', 'features': 35}
# Trained and Tested combination 4 of 6048, taking 7.04 seconds to get val score of 0.3092:
#                 {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME', 'features': 45},
#             Current best combo with val score 0.3092:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME', 'features': 45}
# Trained and Tested combination 5 of 6048, taking 0.01 seconds to get val score of 0.262:
#                 {'n_estimators': 800, 'learning_rate': 100, 'algorithm': 'SAMME', 'features': 10},
#             Current best combo with val score 0.3092:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME', 'features': 45}
# Trained and Tested combination 6 of 6048, taking 0.08 seconds to get val score of 0.2933:
#                 {'n_estimators': 25, 'learning_rate': 0.0001, 'algorithm': 'SAMME', 'features': 15},
#             Current best combo with val score 0.3092:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME', 'features': 45}
# Trained and Tested combination 7 of 6048, taking 7.44 seconds to get val score of 0.3278:
#                 {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 71},
#             Current best combo with val score 0.3278:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 71}
# Trained and Tested combination 8 of 6048, taking 0.11 seconds to get val score of 0.2933:
#                 {'n_estimators': 25, 'learning_rate': 0.0001, 'algorithm': 'SAMME.R', 'features': 20},
#             Current best combo with val score 0.3278:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 71}
# Trained and Tested combination 9 of 6048, taking 2.62 seconds to get val score of 0.3426:
#                 {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 10},
#             Current best combo with val score 0.3426:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 10}
# Trained and Tested combination 10 of 6048, taking 0.01 seconds to get val score of 0.262:
#                 {'n_estimators': 25, 'learning_rate': 100, 'algorithm': 'SAMME', 'features': 30},
#             Current best combo with val score 0.3426:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 10}
# Trained and Tested combination 11 of 6048, taking 0.21 seconds to get val score of 0.0:
#                 {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME', 'features': 59},
#             Current best combo with val score 0.3426:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 10}
# Trained and Tested combination 12 of 6048, taking 0.01 seconds to get val score of 0.262:
#                 {'n_estimators': 25, 'learning_rate': 100, 'algorithm': 'SAMME.R', 'features': 30},
#             Current best combo with val score 0.3426:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 10}
# Trained and Tested combination 13 of 6048, taking 7.06 seconds to get val score of 0.2933:
#                 {'n_estimators': 800, 'learning_rate': 0.0001, 'algorithm': 'SAMME.R', 'features': 59},
#             Current best combo with val score 0.3426:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 10}
# Trained and Tested combination 14 of 6048, taking 3.5 seconds to get val score of 0.2933:
#                 {'n_estimators': 800, 'learning_rate': 0.0001, 'algorithm': 'SAMME', 'features': 15},
#             Current best combo with val score 0.3426:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 10}
# Trained and Tested combination 15 of 6048, taking 0.22 seconds to get val score of 0.0:
#                 {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME', 'features': 71},
#             Current best combo with val score 0.3426:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 10}
# Trained and Tested combination 16 of 6048, taking 0.02 seconds to get val score of 0.262:
#                 {'n_estimators': 800, 'learning_rate': 100, 'algorithm': 'SAMME', 'features': 50},
#             Current best combo with val score 0.3426:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 10}
# Trained and Tested combination 17 of 6048, taking 0.22 seconds to get val score of 0.2933:
#                 {'n_estimators': 25, 'learning_rate': 0.0001, 'algorithm': 'SAMME', 'features': 63},
#             Current best combo with val score 0.3426:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 10}
# Trained and Tested combination 18 of 6048, taking 0.01 seconds to get val score of 0.262:
#                 {'n_estimators': 800, 'learning_rate': 100, 'algorithm': 'SAMME', 'features': 0},
#             Current best combo with val score 0.3426:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 10}
# Trained and Tested combination 19 of 6048, taking 0.11 seconds to get val score of 0.0:
#                 {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME', 'features': 25},
#             Current best combo with val score 0.3426:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 10}
# Trained and Tested combination 20 of 6048, taking 0.03 seconds to get val score of 0.262:
#                 {'n_estimators': 25, 'learning_rate': 100, 'algorithm': 'SAMME.R', 'features': 55},
#             Current best combo with val score 0.3426:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 10}
# Trained and Tested combination 21 of 6048, taking 0.01 seconds to get val score of 0.262:
#                 {'n_estimators': 800, 'learning_rate': 100, 'algorithm': 'SAMME.R', 'features': 15},
#             Current best combo with val score 0.3426:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 10}
# Trained and Tested combination 22 of 6048, taking 0.21 seconds to get val score of 0.0797:
#                 {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 55},
#             Current best combo with val score 0.3426:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 10}
# Trained and Tested combination 23 of 6048, taking 0.02 seconds to get val score of 0.262:
#                 {'n_estimators': 800, 'learning_rate': 100, 'algorithm': 'SAMME', 'features': 40},
#             Current best combo with val score 0.3426:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 10}
# Trained and Tested combination 24 of 6048, taking 0.16 seconds to get val score of 0.2933:
#                 {'n_estimators': 25, 'learning_rate': 0.0001, 'algorithm': 'SAMME', 'features': 40},
#             Current best combo with val score 0.3426:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 10}
# Trained and Tested combination 25 of 6048, taking 5.39 seconds to get val score of 0.2933:
#                 {'n_estimators': 800, 'learning_rate': 0.0001, 'algorithm': 'SAMME', 'features': 35},
#             Current best combo with val score 0.3426:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 10}
# Trained and Tested combination 26 of 6048, taking 0.06 seconds to get val score of 0.2933:
#                 {'n_estimators': 25, 'learning_rate': 0.0001, 'algorithm': 'SAMME.R', 'features': 5},
#             Current best combo with val score 0.3426:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 10}
# Trained and Tested combination 27 of 6048, taking 8.0 seconds to get val score of 0.2933:
#                 {'n_estimators': 800, 'learning_rate': 0.0001, 'algorithm': 'SAMME', 'features': 71},
#             Current best combo with val score 0.3426:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 10}
# Trained and Tested combination 28 of 6048, taking 0.06 seconds to get val score of 0.2933:
#                 {'n_estimators': 25, 'learning_rate': 0.0001, 'algorithm': 'SAMME.R', 'features': 0},
#             Current best combo with val score 0.3426:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 10}
# Trained and Tested combination 29 of 6048, taking 2.88 seconds to get val score of 0.343:
#                 {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 15},
#             Current best combo with val score 0.343:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 15}
# Trained and Tested combination 30 of 6048, taking 0.32 seconds to get val score of 0.0:
#                 {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME', 'features': 67},
#             Current best combo with val score 0.343:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 15}
# Trained and Tested combination 31 of 6048, taking 7.7 seconds to get val score of 0.2933:
#                 {'n_estimators': 800, 'learning_rate': 0.0001, 'algorithm': 'SAMME', 'features': 50},
#             Current best combo with val score 0.343:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 15}
# Trained and Tested combination 32 of 6048, taking 7.25 seconds to get val score of 0.3145:
#                 {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME', 'features': 59},
#             Current best combo with val score 0.343:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 15}
# Trained and Tested combination 33 of 6048, taking 0.03 seconds to get val score of 0.262:
#                 {'n_estimators': 800, 'learning_rate': 100, 'algorithm': 'SAMME.R', 'features': 55},
#             Current best combo with val score 0.343:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 15}
# Trained and Tested combination 34 of 6048, taking 0.1 seconds to get val score of 0.2307:
#                 {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 15},
#             Current best combo with val score 0.343:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 15}
# Trained and Tested combination 35 of 6048, taking 0.21 seconds to get val score of 0.0:
#                 {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME', 'features': 50},
#             Current best combo with val score 0.343:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 15}
# Trained and Tested combination 36 of 6048, taking 0.18 seconds to get val score of 0.0797:
#                 {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 45},
#             Current best combo with val score 0.343:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 15}
# Trained and Tested combination 37 of 6048, taking 0.02 seconds to get val score of 0.262:
#                 {'n_estimators': 25, 'learning_rate': 100, 'algorithm': 'SAMME.R', 'features': 50},
#             Current best combo with val score 0.343:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 15}
# Trained and Tested combination 38 of 6048, taking 0.02 seconds to get val score of 0.262:
#                 {'n_estimators': 800, 'learning_rate': 100, 'algorithm': 'SAMME', 'features': 63},
#             Current best combo with val score 0.343:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 15}
# Trained and Tested combination 39 of 6048, taking 0.02 seconds to get val score of 0.262:
#                 {'n_estimators': 25, 'learning_rate': 100, 'algorithm': 'SAMME.R', 'features': 59},
#             Current best combo with val score 0.343:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 15}
# Trained and Tested combination 40 of 6048, taking 3.22 seconds to get val score of 0.2933:
#                 {'n_estimators': 800, 'learning_rate': 0.0001, 'algorithm': 'SAMME', 'features': 20},
#             Current best combo with val score 0.343:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 15}
# Trained and Tested combination 41 of 6048, taking 0.01 seconds to get val score of 0.262:
#                 {'n_estimators': 25, 'learning_rate': 100, 'algorithm': 'SAMME', 'features': 10},
#             Current best combo with val score 0.343:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 15}
# Trained and Tested combination 42 of 6048, taking 4.21 seconds to get val score of 0.2933:
#                 {'n_estimators': 800, 'learning_rate': 0.0001, 'algorithm': 'SAMME', 'features': 30},
#             Current best combo with val score 0.343:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 15}
# Trained and Tested combination 43 of 6048, taking 6.99 seconds to get val score of 0.3145:
#                 {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME', 'features': 71},
#             Current best combo with val score 0.343:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 15}
# Trained and Tested combination 44 of 6048, taking 6.95 seconds to get val score of 0.3281:
#                 {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 55},
#             Current best combo with val score 0.343:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 15}
# Trained and Tested combination 45 of 6048, taking 3.5 seconds to get val score of 0.2933:
#                 {'n_estimators': 800, 'learning_rate': 0.0001, 'algorithm': 'SAMME', 'features': 25},
#             Current best combo with val score 0.343:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 15}
# Trained and Tested combination 46 of 6048, taking 6.13 seconds to get val score of 0.3311:
#                 {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 45},
#             Current best combo with val score 0.343:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 15}
# Trained and Tested combination 47 of 6048, taking 0.01 seconds to get val score of 0.262:
#                 {'n_estimators': 800, 'learning_rate': 100, 'algorithm': 'SAMME.R', 'features': 5},
#             Current best combo with val score 0.343:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 15}
# Trained and Tested combination 48 of 6048, taking 0.02 seconds to get val score of 0.262:
#                 {'n_estimators': 800, 'learning_rate': 100, 'algorithm': 'SAMME.R', 'features': 40},
#             Current best combo with val score 0.343:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 15}
# Trained and Tested combination 49 of 6048, taking 0.22 seconds to get val score of 0.2933:
#                 {'n_estimators': 25, 'learning_rate': 0.0001, 'algorithm': 'SAMME', 'features': 55},
#             Current best combo with val score 0.343:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 15}
# Trained and Tested combination 50 of 6048, taking 7.63 seconds to get val score of 0.2933:
#                 {'n_estimators': 800, 'learning_rate': 0.0001, 'algorithm': 'SAMME', 'features': 63},
#             Current best combo with val score 0.343:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 15}
# Trained and Tested combination 51 of 6048, taking 0.03 seconds to get val score of 0.262:
#                 {'n_estimators': 800, 'learning_rate': 100, 'algorithm': 'SAMME', 'features': 55},
#             Current best combo with val score 0.343:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 15}
# Trained and Tested combination 52 of 6048, taking 0.02 seconds to get val score of 0.262:
#                 {'n_estimators': 25, 'learning_rate': 100, 'algorithm': 'SAMME', 'features': 71},
#             Current best combo with val score 0.343:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 15}
# Trained and Tested combination 53 of 6048, taking 0.12 seconds to get val score of 0.0797:
#                 {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 25},
#             Current best combo with val score 0.343:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 15}
# Trained and Tested combination 54 of 6048, taking 0.21 seconds to get val score of 0.0:
#                 {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME', 'features': 55},
#             Current best combo with val score 0.343:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 15}
# Trained and Tested combination 55 of 6048, taking 0.02 seconds to get val score of 0.262:
#                 {'n_estimators': 25, 'learning_rate': 100, 'algorithm': 'SAMME', 'features': 45},
#             Current best combo with val score 0.343:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 15}
# Trained and Tested combination 56 of 6048, taking 0.01 seconds to get val score of 0.262:
#                 {'n_estimators': 25, 'learning_rate': 100, 'algorithm': 'SAMME', 'features': 20},
#             Current best combo with val score 0.343:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 15}
# Trained and Tested combination 57 of 6048, taking 0.01 seconds to get val score of 0.262:
#                 {'n_estimators': 25, 'learning_rate': 100, 'algorithm': 'SAMME.R', 'features': 5},
#             Current best combo with val score 0.343:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 15}
# Trained and Tested combination 58 of 6048, taking 5.04 seconds to get val score of 0.3427:
#                 {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME', 'features': 40},
#             Current best combo with val score 0.343:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 15}
# Trained and Tested combination 59 of 6048, taking 6.99 seconds to get val score of 0.3135:
#                 {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME', 'features': 67},
#             Current best combo with val score 0.343:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 15}
# Trained and Tested combination 60 of 6048, taking 0.11 seconds to get val score of 0.0:
#                 {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME', 'features': 20},
#             Current best combo with val score 0.343:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 15}
# Trained and Tested combination 61 of 6048, taking 0.02 seconds to get val score of 0.262:
#                 {'n_estimators': 25, 'learning_rate': 100, 'algorithm': 'SAMME.R', 'features': 40},
#             Current best combo with val score 0.343:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 15}
# Trained and Tested combination 62 of 6048, taking 0.01 seconds to get val score of 0.262:
#                 {'n_estimators': 800, 'learning_rate': 100, 'algorithm': 'SAMME.R', 'features': 10},
#             Current best combo with val score 0.343:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 15}
# Trained and Tested combination 63 of 6048, taking 0.13 seconds to get val score of 0.2307:
#                 {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 10},
#             Current best combo with val score 0.343:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 15}
# Trained and Tested combination 64 of 6048, taking 0.01 seconds to get val score of 0.262:
#                 {'n_estimators': 800, 'learning_rate': 100, 'algorithm': 'SAMME.R', 'features': 0},
#             Current best combo with val score 0.343:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 15}
# Trained and Tested combination 65 of 6048, taking 0.22 seconds to get val score of 0.0797:
#                 {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 59},
#             Current best combo with val score 0.343:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 15}
# Trained and Tested combination 66 of 6048, taking 2.04 seconds to get val score of 0.2523:
#                 {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 5},
#             Current best combo with val score 0.343:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 15}
# Trained and Tested combination 67 of 6048, taking 8.34 seconds to get val score of 0.2933:
#                 {'n_estimators': 800, 'learning_rate': 0.0001, 'algorithm': 'SAMME', 'features': 67},
#             Current best combo with val score 0.343:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 15}
# Trained and Tested combination 68 of 6048, taking 0.23 seconds to get val score of 0.0797:
#                 {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 67},
#             Current best combo with val score 0.343:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 15}
# Trained and Tested combination 69 of 6048, taking 0.02 seconds to get val score of 0.262:
#                 {'n_estimators': 800, 'learning_rate': 100, 'algorithm': 'SAMME', 'features': 67},
#             Current best combo with val score 0.343:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 15}
# Trained and Tested combination 70 of 6048, taking 1.76 seconds to get val score of 0.2933:
#                 {'n_estimators': 800, 'learning_rate': 0.0001, 'algorithm': 'SAMME', 'features': 0},
#             Current best combo with val score 0.343:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 15}
# Trained and Tested combination 71 of 6048, taking 0.22 seconds to get val score of 0.0797:
#                 {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 35},
#             Current best combo with val score 0.343:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 15}
# Trained and Tested combination 72 of 6048, taking 0.22 seconds to get val score of 0.2933:
#                 {'n_estimators': 25, 'learning_rate': 0.0001, 'algorithm': 'SAMME.R', 'features': 63},
#             Current best combo with val score 0.343:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 15}
# Trained and Tested combination 73 of 6048, taking 0.09 seconds to get val score of 0.2933:
#                 {'n_estimators': 25, 'learning_rate': 0.0001, 'algorithm': 'SAMME.R', 'features': 15},
#             Current best combo with val score 0.343:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 15}
# Trained and Tested combination 74 of 6048, taking 0.24 seconds to get val score of 0.2933:
#                 {'n_estimators': 25, 'learning_rate': 0.0001, 'algorithm': 'SAMME.R', 'features': 67},
#             Current best combo with val score 0.343:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 15}
# Trained and Tested combination 75 of 6048, taking 0.06 seconds to get val score of 0.0:
#                 {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME', 'features': 5},
#             Current best combo with val score 0.343:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 15}
# Trained and Tested combination 76 of 6048, taking 4.3 seconds to get val score of 0.3241:
#                 {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 30},
#             Current best combo with val score 0.343:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 15}
# Trained and Tested combination 77 of 6048, taking 0.18 seconds to get val score of 0.2933:
#                 {'n_estimators': 25, 'learning_rate': 0.0001, 'algorithm': 'SAMME', 'features': 45},
#             Current best combo with val score 0.343:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 15}
# Trained and Tested combination 78 of 6048, taking 4.39 seconds to get val score of 0.2933:
#                 {'n_estimators': 800, 'learning_rate': 0.0001, 'algorithm': 'SAMME.R', 'features': 25},
#             Current best combo with val score 0.343:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 15}
# Trained and Tested combination 79 of 6048, taking 0.01 seconds to get val score of 0.262:
#                 {'n_estimators': 800, 'learning_rate': 100, 'algorithm': 'SAMME', 'features': 35},
#             Current best combo with val score 0.343:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 15}
# Trained and Tested combination 80 of 6048, taking 0.01 seconds to get val score of 0.262:
#                 {'n_estimators': 25, 'learning_rate': 100, 'algorithm': 'SAMME.R', 'features': 10},
#             Current best combo with val score 0.343:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 15}
# Trained and Tested combination 81 of 6048, taking 0.08 seconds to get val score of 0.1437:
#                 {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 5},
#             Current best combo with val score 0.343:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 15}
# Trained and Tested combination 82 of 6048, taking 0.02 seconds to get val score of 0.262:
#                 {'n_estimators': 25, 'learning_rate': 100, 'algorithm': 'SAMME.R', 'features': 45},
#             Current best combo with val score 0.343:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 15}
# Trained and Tested combination 83 of 6048, taking 4.72 seconds to get val score of 0.2933:
#                 {'n_estimators': 800, 'learning_rate': 0.0001, 'algorithm': 'SAMME.R', 'features': 35},
#             Current best combo with val score 0.343:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 15}
# Trained and Tested combination 84 of 6048, taking 0.24 seconds to get val score of 0.0:
#                 {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME', 'features': 40},
#             Current best combo with val score 0.343:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 15}
# Trained and Tested combination 85 of 6048, taking 0.03 seconds to get val score of 0.262:
#                 {'n_estimators': 25, 'learning_rate': 100, 'algorithm': 'SAMME', 'features': 63},
#             Current best combo with val score 0.343:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 15}
# Trained and Tested combination 86 of 6048, taking 0.02 seconds to get val score of 0.262:
#                 {'n_estimators': 25, 'learning_rate': 100, 'algorithm': 'SAMME', 'features': 35},
#             Current best combo with val score 0.343:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 15}
# Trained and Tested combination 87 of 6048, taking 6.37 seconds to get val score of 0.2933:
#                 {'n_estimators': 800, 'learning_rate': 0.0001, 'algorithm': 'SAMME', 'features': 40},
#             Current best combo with val score 0.343:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 15}
# Trained and Tested combination 88 of 6048, taking 8.52 seconds to get val score of 0.3291:
#                 {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 59},
#             Current best combo with val score 0.343:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 15}
# Trained and Tested combination 89 of 6048, taking 0.02 seconds to get val score of 0.262:
#                 {'n_estimators': 800, 'learning_rate': 100, 'algorithm': 'SAMME.R', 'features': 45},
#             Current best combo with val score 0.343:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 15}
# Trained and Tested combination 90 of 6048, taking 0.21 seconds to get val score of 0.2933:
#                 {'n_estimators': 25, 'learning_rate': 0.0001, 'algorithm': 'SAMME.R', 'features': 50},
#             Current best combo with val score 0.343:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 15}
# Trained and Tested combination 91 of 6048, taking 7.3 seconds to get val score of 0.3292:
#                 {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 67},
#             Current best combo with val score 0.343:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 15}
# Trained and Tested combination 92 of 6048, taking 0.12 seconds to get val score of 0.0:
#                 {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME', 'features': 10},
#             Current best combo with val score 0.343:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 15}
# Trained and Tested combination 93 of 6048, taking 0.01 seconds to get val score of 0.262:
#                 {'n_estimators': 25, 'learning_rate': 100, 'algorithm': 'SAMME', 'features': 15},
#             Current best combo with val score 0.343:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 15}
# Trained and Tested combination 94 of 6048, taking 0.02 seconds to get val score of 0.262:
#                 {'n_estimators': 25, 'learning_rate': 100, 'algorithm': 'SAMME.R', 'features': 63},
#             Current best combo with val score 0.343:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 15}
# Trained and Tested combination 95 of 6048, taking 5.38 seconds to get val score of 0.3262:
#                 {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 40},
#             Current best combo with val score 0.343:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 15}
# Trained and Tested combination 96 of 6048, taking 5.9 seconds to get val score of 0.2933:
#                 {'n_estimators': 800, 'learning_rate': 0.0001, 'algorithm': 'SAMME.R', 'features': 45},
#             Current best combo with val score 0.343:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 15}
# Trained and Tested combination 97 of 6048, taking 0.13 seconds to get val score of 0.2933:
#                 {'n_estimators': 25, 'learning_rate': 0.0001, 'algorithm': 'SAMME.R', 'features': 10},
#             Current best combo with val score 0.343:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 15}
# Trained and Tested combination 98 of 6048, taking 0.02 seconds to get val score of 0.262:
#                 {'n_estimators': 800, 'learning_rate': 100, 'algorithm': 'SAMME', 'features': 25},
#             Current best combo with val score 0.343:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 15}
# Trained and Tested combination 99 of 6048, taking 6.7 seconds to get val score of 0.3191:
#                 {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME', 'features': 55},
#             Current best combo with val score 0.343:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 15}
# Trained and Tested combination 100 of 6048, taking 0.11 seconds to get val score of 0.2933:
#                 {'n_estimators': 25, 'learning_rate': 0.0001, 'algorithm': 'SAMME', 'features': 25},
#             Current best combo with val score 0.343:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 15}
# Trained and Tested combination 101 of 6048, taking 0.13 seconds to get val score of 0.0:
#                 {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME', 'features': 15},
#             Current best combo with val score 0.343:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 15}
# Trained and Tested combination 102 of 6048, taking 0.02 seconds to get val score of 0.262:
#                 {'n_estimators': 800, 'learning_rate': 100, 'algorithm': 'SAMME.R', 'features': 20},
#             Current best combo with val score 0.343:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 15}
# Trained and Tested combination 103 of 6048, taking 2.68 seconds to get val score of 0.2933:
#                 {'n_estimators': 800, 'learning_rate': 0.0001, 'algorithm': 'SAMME.R', 'features': 10},
#             Current best combo with val score 0.343:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 15}
# Trained and Tested combination 104 of 6048, taking 4.78 seconds to get val score of 0.3211:
#                 {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 35},
#             Current best combo with val score 0.343:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 15}
# Trained and Tested combination 105 of 6048, taking 0.2 seconds to get val score of 0.2933:
#                 {'n_estimators': 25, 'learning_rate': 0.0001, 'algorithm': 'SAMME.R', 'features': 30},
#             Current best combo with val score 0.343:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 15}
# Trained and Tested combination 106 of 6048, taking 0.02 seconds to get val score of 0.262:
#                 {'n_estimators': 25, 'learning_rate': 100, 'algorithm': 'SAMME.R', 'features': 25},
#             Current best combo with val score 0.343:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 15}
# Trained and Tested combination 107 of 6048, taking 0.02 seconds to get val score of 0.262:
#                 {'n_estimators': 25, 'learning_rate': 100, 'algorithm': 'SAMME.R', 'features': 35},
#             Current best combo with val score 0.343:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 15}
# Trained and Tested combination 108 of 6048, taking 0.01 seconds to get val score of 0.262:
#                 {'n_estimators': 25, 'learning_rate': 100, 'algorithm': 'SAMME', 'features': 5},
#             Current best combo with val score 0.343:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 15}
# Trained and Tested combination 109 of 6048, taking 6.95 seconds to get val score of 0.2933:
#                 {'n_estimators': 800, 'learning_rate': 0.0001, 'algorithm': 'SAMME', 'features': 55},
#             Current best combo with val score 0.343:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 15}
# Trained and Tested combination 110 of 6048, taking 0.12 seconds to get val score of 0.0797:
#                 {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 20},
#             Current best combo with val score 0.343:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 15}
# Trained and Tested combination 111 of 6048, taking 0.01 seconds to get val score of 0.262:
#                 {'n_estimators': 25, 'learning_rate': 100, 'algorithm': 'SAMME', 'features': 0},
#             Current best combo with val score 0.343:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 15}
# Trained and Tested combination 112 of 6048, taking 2.7 seconds to get val score of 0.5635:
#                 {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME', 'features': 10},
#             Current best combo with val score 0.5635:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME', 'features': 10}
# Trained and Tested combination 113 of 6048, taking 0.03 seconds to get val score of 0.262:
#                 {'n_estimators': 25, 'learning_rate': 100, 'algorithm': 'SAMME', 'features': 59},
#             Current best combo with val score 0.5635:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME', 'features': 10}
# Trained and Tested combination 114 of 6048, taking 3.89 seconds to get val score of 0.3381:
#                 {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 25},
#             Current best combo with val score 0.5635:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME', 'features': 10}
# Trained and Tested combination 115 of 6048, taking 0.22 seconds to get val score of 0.2933:
#                 {'n_estimators': 25, 'learning_rate': 0.0001, 'algorithm': 'SAMME', 'features': 59},
#             Current best combo with val score 0.5635:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME', 'features': 10}
# Trained and Tested combination 116 of 6048, taking 3.59 seconds to get val score of 0.5502:
#                 {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME', 'features': 25},
#             Current best combo with val score 0.5635:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME', 'features': 10}
# Trained and Tested combination 117 of 6048, taking 3.29 seconds to get val score of 0.527:
#                 {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME', 'features': 20},
#             Current best combo with val score 0.5635:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME', 'features': 10}
# Trained and Tested combination 118 of 6048, taking 0.02 seconds to get val score of 0.262:
#                 {'n_estimators': 800, 'learning_rate': 100, 'algorithm': 'SAMME', 'features': 45},
#             Current best combo with val score 0.5635:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME', 'features': 10}
# Trained and Tested combination 119 of 6048, taking 0.02 seconds to get val score of 0.262:
#                 {'n_estimators': 800, 'learning_rate': 100, 'algorithm': 'SAMME', 'features': 59},
#             Current best combo with val score 0.5635:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME', 'features': 10}
# Trained and Tested combination 120 of 6048, taking 0.01 seconds to get val score of 0.262:
#                 {'n_estimators': 800, 'learning_rate': 100, 'algorithm': 'SAMME', 'features': 15},
#             Current best combo with val score 0.5635:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME', 'features': 10}
# Trained and Tested combination 121 of 6048, taking 7.05 seconds to get val score of 0.3135:
#                 {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME', 'features': 63},
#             Current best combo with val score 0.5635:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME', 'features': 10}
# Trained and Tested combination 122 of 6048, taking 0.22 seconds to get val score of 0.2933:
#                 {'n_estimators': 25, 'learning_rate': 0.0001, 'algorithm': 'SAMME.R', 'features': 55},
#             Current best combo with val score 0.5635:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME', 'features': 10}
# Trained and Tested combination 123 of 6048, taking 0.16 seconds to get val score of 0.2933:
#                 {'n_estimators': 25, 'learning_rate': 0.0001, 'algorithm': 'SAMME', 'features': 20},
#             Current best combo with val score 0.5635:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME', 'features': 10}
# Trained and Tested combination 124 of 6048, taking 0.03 seconds to get val score of 0.262:
#                 {'n_estimators': 800, 'learning_rate': 100, 'algorithm': 'SAMME', 'features': 71},
#             Current best combo with val score 0.5635:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME', 'features': 10}
# Trained and Tested combination 125 of 6048, taking 0.18 seconds to get val score of 0.0:
#                 {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME', 'features': 45},
#             Current best combo with val score 0.5635:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME', 'features': 10}
# Trained and Tested combination 126 of 6048, taking 0.03 seconds to get val score of 0.262:
#                 {'n_estimators': 25, 'learning_rate': 100, 'algorithm': 'SAMME', 'features': 67},
#             Current best combo with val score 0.5635:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME', 'features': 10}
# Trained and Tested combination 127 of 6048, taking 5.64 seconds to get val score of 0.2933:
#                 {'n_estimators': 800, 'learning_rate': 0.0001, 'algorithm': 'SAMME.R', 'features': 30},
#             Current best combo with val score 0.5635:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME', 'features': 10}
# Trained and Tested combination 128 of 6048, taking 0.2 seconds to get val score of 0.0797:
#                 {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 50},
#             Current best combo with val score 0.5635:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME', 'features': 10}
# Trained and Tested combination 129 of 6048, taking 0.01 seconds to get val score of 0.262:
#                 {'n_estimators': 25, 'learning_rate': 100, 'algorithm': 'SAMME.R', 'features': 15},
#             Current best combo with val score 0.5635:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME', 'features': 10}
# Trained and Tested combination 130 of 6048, taking 3.54 seconds to get val score of 0.2933:
#                 {'n_estimators': 800, 'learning_rate': 0.0001, 'algorithm': 'SAMME.R', 'features': 20},
#             Current best combo with val score 0.5635:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME', 'features': 10}
# Trained and Tested combination 131 of 6048, taking 0.01 seconds to get val score of 0.262:
#                 {'n_estimators': 25, 'learning_rate': 100, 'algorithm': 'SAMME', 'features': 40},
#             Current best combo with val score 0.5635:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME', 'features': 10}
# Trained and Tested combination 132 of 6048, taking 7.03 seconds to get val score of 0.2933:
#                 {'n_estimators': 800, 'learning_rate': 0.0001, 'algorithm': 'SAMME.R', 'features': 55},
#             Current best combo with val score 0.5635:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME', 'features': 10}
# Trained and Tested combination 133 of 6048, taking 0.35 seconds to get val score of 0.0797:
#                 {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 63},
#             Current best combo with val score 0.5635:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME', 'features': 10}
# Trained and Tested combination 134 of 6048, taking 0.03 seconds to get val score of 0.262:
#                 {'n_estimators': 25, 'learning_rate': 100, 'algorithm': 'SAMME', 'features': 50},
#             Current best combo with val score 0.5635:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME', 'features': 10}
# Trained and Tested combination 135 of 6048, taking 0.02 seconds to get val score of 0.262:
#                 {'n_estimators': 25, 'learning_rate': 100, 'algorithm': 'SAMME', 'features': 55},
#             Current best combo with val score 0.5635:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME', 'features': 10}
# Trained and Tested combination 136 of 6048, taking 0.01 seconds to get val score of 0.262:
#                 {'n_estimators': 25, 'learning_rate': 100, 'algorithm': 'SAMME', 'features': 25},
#             Current best combo with val score 0.5635:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME', 'features': 10}
# Trained and Tested combination 137 of 6048, taking 0.02 seconds to get val score of 0.262:
# ...
#         Has trained 280 of 6048 combinations so far
# Trained and Tested combination 281 of 6048, taking 3.94 seconds to get val score of 0.3426:
#                 {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 9},
#             Current best combo with val score 0.5726:
#                     {'n_estimators': 400, 'learning_rate': 0.1, 'algorithm': 'SAMME', 'features': 16}
# Already Trained and Tested combination (val score of 0.3419):
#             {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 11}
#             Current best combo (with val score 0.5726):
#                     {'n_estimators': 400, 'learning_rate': 0.1, 'algorithm': 'SAMME', 'features': 16}
#         Has trained 281 of 6048 combinations so far
# 	round 6 iteration:  1
#
# Trained and Tested combination 282 of 6048, taking 0.66 seconds to get val score of 0.3547:
#                 {'n_estimators': 200, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 10},
#             Current best combo with val score 0.5726:
#                     {'n_estimators': 400, 'learning_rate': 0.1, 'algorithm': 'SAMME', 'features': 16}
# Already Trained and Tested combination (val score of 0.3426):
#             {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 10}
#             Current best combo (with val score 0.5726):
#                     {'n_estimators': 400, 'learning_rate': 0.1, 'algorithm': 'SAMME', 'features': 16}
#         Has trained 282 of 6048 combinations so far
# Trained and Tested combination 283 of 6048, taking 1.98 seconds to get val score of 0.3009:
#                 {'n_estimators': 400, 'learning_rate': 0.01, 'algorithm': 'SAMME.R', 'features': 10},
#             Current best combo with val score 0.5726:
#                     {'n_estimators': 400, 'learning_rate': 0.1, 'algorithm': 'SAMME', 'features': 16}
# Trained and Tested combination 284 of 6048, taking 1.3 seconds to get val score of 0.329:
#                 {'n_estimators': 400, 'learning_rate': 1, 'algorithm': 'SAMME.R', 'features': 10},
#             Current best combo with val score 0.5726:
#                     {'n_estimators': 400, 'learning_rate': 0.1, 'algorithm': 'SAMME', 'features': 16}
# Already Trained and Tested combination (val score of 0.5046):
#             {'n_estimators': 400, 'learning_rate': 0.1, 'algorithm': 'SAMME', 'features': 10}
#             Current best combo (with val score 0.5726):
#                     {'n_estimators': 400, 'learning_rate': 0.1, 'algorithm': 'SAMME', 'features': 16}
#         Has trained 284 of 6048 combinations so far
# Trained and Tested combination 285 of 6048, taking 1.33 seconds to get val score of 0.3202:
#                 {'n_estimators': 400, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 9},
#             Current best combo with val score 0.5726:
#                     {'n_estimators': 400, 'learning_rate': 0.1, 'algorithm': 'SAMME', 'features': 16}
# Trained and Tested combination 286 of 6048, taking 1.53 seconds to get val score of 0.3211:
#                 {'n_estimators': 400, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 11},
#             Current best combo with val score 0.5726:
#                     {'n_estimators': 400, 'learning_rate': 0.1, 'algorithm': 'SAMME', 'features': 16}
# Already Trained and Tested combination (val score of 0.3009):
#             {'n_estimators': 400, 'learning_rate': 0.01, 'algorithm': 'SAMME.R', 'features': 10}
#             Current best combo (with val score 0.5726):
#                     {'n_estimators': 400, 'learning_rate': 0.1, 'algorithm': 'SAMME', 'features': 16}
#         Has trained 286 of 6048 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 800, 'learning_rate': 0.001, 'algorithm': 'SAMME.R', 'features': 10}
#             Current best combo (with val score 0.5726):
#                     {'n_estimators': 400, 'learning_rate': 0.1, 'algorithm': 'SAMME', 'features': 16}
#         Has trained 286 of 6048 combinations so far
# Already Trained and Tested combination (val score of 0.3426):
#             {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 10}
#             Current best combo (with val score 0.5726):
#                     {'n_estimators': 400, 'learning_rate': 0.1, 'algorithm': 'SAMME', 'features': 16}
#         Has trained 286 of 6048 combinations so far
# Already Trained and Tested combination (val score of 0.203):
#             {'n_estimators': 800, 'learning_rate': 0.01, 'algorithm': 'SAMME', 'features': 10}
#             Current best combo (with val score 0.5726):
#                     {'n_estimators': 400, 'learning_rate': 0.1, 'algorithm': 'SAMME', 'features': 16}
#         Has trained 286 of 6048 combinations so far
# Trained and Tested combination 287 of 6048, taking 3.01 seconds to get val score of 0.5079:
#                 {'n_estimators': 800, 'learning_rate': 0.01, 'algorithm': 'SAMME.R', 'features': 9},
#             Current best combo with val score 0.5726:
#                     {'n_estimators': 400, 'learning_rate': 0.1, 'algorithm': 'SAMME', 'features': 16}
# Trained and Tested combination 288 of 6048, taking 3.91 seconds to get val score of 0.5041:
#                 {'n_estimators': 800, 'learning_rate': 0.01, 'algorithm': 'SAMME.R', 'features': 11},
#             Current best combo with val score 0.5726:
#                     {'n_estimators': 400, 'learning_rate': 0.1, 'algorithm': 'SAMME', 'features': 16}
# Already Trained and Tested combination (val score of 0.5046):
#             {'n_estimators': 400, 'learning_rate': 0.1, 'algorithm': 'SAMME', 'features': 10}
#             Current best combo (with val score 0.5726):
#                     {'n_estimators': 400, 'learning_rate': 0.1, 'algorithm': 'SAMME', 'features': 16}
#         Has trained 288 of 6048 combinations so far
# Already Trained and Tested combination (val score of 0.203):
#             {'n_estimators': 800, 'learning_rate': 0.01, 'algorithm': 'SAMME', 'features': 10}
#             Current best combo (with val score 0.5726):
#                     {'n_estimators': 400, 'learning_rate': 0.1, 'algorithm': 'SAMME', 'features': 16}
#         Has trained 288 of 6048 combinations so far
# Already Trained and Tested combination (val score of 0.3495):
#             {'n_estimators': 800, 'learning_rate': 1, 'algorithm': 'SAMME', 'features': 10}
#             Current best combo (with val score 0.5726):
#                     {'n_estimators': 400, 'learning_rate': 0.1, 'algorithm': 'SAMME', 'features': 16}
#         Has trained 288 of 6048 combinations so far
# Already Trained and Tested combination (val score of 0.3426):
#             {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 10}
#             Current best combo (with val score 0.5726):
#                     {'n_estimators': 400, 'learning_rate': 0.1, 'algorithm': 'SAMME', 'features': 16}
#         Has trained 288 of 6048 combinations so far
# Already Trained and Tested combination (val score of 0.5639):
#             {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME', 'features': 9}
#             Current best combo (with val score 0.5726):
#                     {'n_estimators': 400, 'learning_rate': 0.1, 'algorithm': 'SAMME', 'features': 16}
#         Has trained 288 of 6048 combinations so far
# Already Trained and Tested combination (val score of 0.5652):
#             {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME', 'features': 11}
#             Current best combo (with val score 0.5726):
#                     {'n_estimators': 400, 'learning_rate': 0.1, 'algorithm': 'SAMME', 'features': 16}
#         Has trained 288 of 6048 combinations so far
# Already Trained and Tested combination (val score of 0.3202):
#             {'n_estimators': 400, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 9}
#             Current best combo (with val score 0.5726):
#                     {'n_estimators': 400, 'learning_rate': 0.1, 'algorithm': 'SAMME', 'features': 16}
#         Has trained 288 of 6048 combinations so far
# Already Trained and Tested combination (val score of 0.5079):
#             {'n_estimators': 800, 'learning_rate': 0.01, 'algorithm': 'SAMME.R', 'features': 9}
#             Current best combo (with val score 0.5726):
#                     {'n_estimators': 400, 'learning_rate': 0.1, 'algorithm': 'SAMME', 'features': 16}
#         Has trained 288 of 6048 combinations so far
# Trained and Tested combination 289 of 6048, taking 3.28 seconds to get val score of 0.3287:
#                 {'n_estimators': 800, 'learning_rate': 1, 'algorithm': 'SAMME.R', 'features': 9},
#             Current best combo with val score 0.5726:
#                     {'n_estimators': 400, 'learning_rate': 0.1, 'algorithm': 'SAMME', 'features': 16}
# Already Trained and Tested combination (val score of 0.5639):
#             {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME', 'features': 9}
#             Current best combo (with val score 0.5726):
#                     {'n_estimators': 400, 'learning_rate': 0.1, 'algorithm': 'SAMME', 'features': 16}
#         Has trained 289 of 6048 combinations so far
# Trained and Tested combination 290 of 6048, taking 2.97 seconds to get val score of 0.3384:
#                 {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 8},
#             Current best combo with val score 0.5726:
#                     {'n_estimators': 400, 'learning_rate': 0.1, 'algorithm': 'SAMME', 'features': 16}
# Already Trained and Tested combination (val score of 0.3426):
#             {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 10}
#             Current best combo (with val score 0.5726):
#                     {'n_estimators': 400, 'learning_rate': 0.1, 'algorithm': 'SAMME', 'features': 16}
#         Has trained 290 of 6048 combinations so far
# Already Trained and Tested combination (val score of 0.3211):
#             {'n_estimators': 400, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 11}
#             Current best combo (with val score 0.5726):
#                     {'n_estimators': 400, 'learning_rate': 0.1, 'algorithm': 'SAMME', 'features': 16}
#         Has trained 290 of 6048 combinations so far
# Already Trained and Tested combination (val score of 0.5041):
#             {'n_estimators': 800, 'learning_rate': 0.01, 'algorithm': 'SAMME.R', 'features': 11}
#             Current best combo (with val score 0.5726):
#                     {'n_estimators': 400, 'learning_rate': 0.1, 'algorithm': 'SAMME', 'features': 16}
#         Has trained 290 of 6048 combinations so far
# Trained and Tested combination 291 of 6048, taking 3.68 seconds to get val score of 0.3265:
#                 {'n_estimators': 800, 'learning_rate': 1, 'algorithm': 'SAMME.R', 'features': 11},
#             Current best combo with val score 0.5726:
#                     {'n_estimators': 400, 'learning_rate': 0.1, 'algorithm': 'SAMME', 'features': 16}
# Already Trained and Tested combination (val score of 0.5652):
#             {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME', 'features': 11}
#             Current best combo (with val score 0.5726):
#                     {'n_estimators': 400, 'learning_rate': 0.1, 'algorithm': 'SAMME', 'features': 16}
#         Has trained 291 of 6048 combinations so far
# Already Trained and Tested combination (val score of 0.3426):
#             {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 10}
#             Current best combo (with val score 0.5726):
#                     {'n_estimators': 400, 'learning_rate': 0.1, 'algorithm': 'SAMME', 'features': 16}
#         Has trained 291 of 6048 combinations so far
# Trained and Tested combination 292 of 6048, taking 4.3 seconds to get val score of 0.3414:
#                 {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 12},
#             Current best combo with val score 0.5726:
#                     {'n_estimators': 400, 'learning_rate': 0.1, 'algorithm': 'SAMME', 'features': 16}
# % Combos Checked Thus Far: 292 out of 6048 which is 4.828042%
# Cruising Coordrdinate 192 of 192
#
# Cruise suspended due to suspicious case
# Guidance: round 7
#
# 	round 7 iteration:  0
#
# % Combos Checked Thus Far: 292 out of 6048 which is 4.828042%
# FINAL STAGE: Begin final Guidance system
#
#
# Guidance: round FINAL
#
# 	round FINAL iteration:  0
#
# Already Trained and Tested combination (val score of 0.4151):
#             {'n_estimators': 200, 'learning_rate': 0.1, 'algorithm': 'SAMME', 'features': 16}
#             Current best combo (with val score 0.5726):
#                     {'n_estimators': 400, 'learning_rate': 0.1, 'algorithm': 'SAMME', 'features': 16}
#         Has trained 292 of 6048 combinations so far
# Already Trained and Tested combination (val score of 0.5606):
#             {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME', 'features': 16}
#             Current best combo (with val score 0.5726):
#                     {'n_estimators': 400, 'learning_rate': 0.1, 'algorithm': 'SAMME', 'features': 16}
#         Has trained 292 of 6048 combinations so far
# Already Trained and Tested combination (val score of 0.0185):
#             {'n_estimators': 400, 'learning_rate': 0.01, 'algorithm': 'SAMME', 'features': 16}
#             Current best combo (with val score 0.5726):
#                     {'n_estimators': 400, 'learning_rate': 0.1, 'algorithm': 'SAMME', 'features': 16}
#         Has trained 292 of 6048 combinations so far
# Already Trained and Tested combination (val score of 0.3563):
#             {'n_estimators': 400, 'learning_rate': 1, 'algorithm': 'SAMME', 'features': 16}
#             Current best combo (with val score 0.5726):
#                     {'n_estimators': 400, 'learning_rate': 0.1, 'algorithm': 'SAMME', 'features': 16}
#         Has trained 292 of 6048 combinations so far
# Already Trained and Tested combination (val score of 0.347):
#             {'n_estimators': 400, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 16}
#             Current best combo (with val score 0.5726):
#                     {'n_estimators': 400, 'learning_rate': 0.1, 'algorithm': 'SAMME', 'features': 16}
#         Has trained 292 of 6048 combinations so far
# Already Trained and Tested combination (val score of 0.5518):
#             {'n_estimators': 400, 'learning_rate': 0.1, 'algorithm': 'SAMME', 'features': 15}
#             Current best combo (with val score 0.5726):
#                     {'n_estimators': 400, 'learning_rate': 0.1, 'algorithm': 'SAMME', 'features': 16}
#         Has trained 292 of 6048 combinations so far
# Already Trained and Tested combination (val score of 0.4296):
#             {'n_estimators': 400, 'learning_rate': 0.1, 'algorithm': 'SAMME', 'features': 17}
#             Current best combo (with val score 0.5726):
#                     {'n_estimators': 400, 'learning_rate': 0.1, 'algorithm': 'SAMME', 'features': 16}
#         Has trained 292 of 6048 combinations so far
# % Combos Checked Thus Far: 292 out of 6048 which is 4.828042%
# Max Val Score:
#  0.572586
# Max Val Score Std:
#  0.029434
# Best Combo Train Score:
#  0.554948
# Best Combo Train Score Std:
#  0.009438
# Max Combo Index:
#  (4, 3, 0, 16) out of [6, 7, 2, 72] (note best combo is 0-indexed)
# Max Combo Hyperparamer Combination:
#  {'n_estimators': 400, 'learning_rate': 0.1, 'algorithm': 'SAMME', 'features': 16}
# Max Combo Features:
#  ('procedure_228130', 'procedure_225792', 'procedure_228125', 'lods_score', 'ventilation_used', 'procedure_226236', 'hospital_stay_duration', 'procedure_225469', 'procedure_224270', 'procedure_225446', 'procedure_225802', 'procedure_227712', 'procedure_229580', 'procedure_225451', 'admission_type_DIRECT EMER.', 'admission_type_DIRECT OBSERVATION', 'admission_type_ELECTIVE', 'admission_type_EU OBSERVATION', 'admission_type_EW EMER.', 'admission_type_OBSERVATION ADMIT', 'admission_type_URGENT', 'admission_type_SURGICAL SAME DAY ADMISSION', 'procedure_224385', 'procedure_224267')
# % Combos Checked: 292 out of 6048 which is 4.828042%
