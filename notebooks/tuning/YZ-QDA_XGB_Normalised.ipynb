# %% [markdown]
# # Tuning Script

# %%
# Parameters subject to change in every script - involved in naming

MODEL = 'qda'
PREPROCESSING = 'normalise'
TUNER = 'yangzhoub'
OPTIMISED_METRIC = 'f1'

# %% [markdown]
# ---

# %%
# detect whether this is a google environment

COLAB_ENVIRONMENT = False

try:
    from google.colab import drive
    drive.mount('/content/drive')
    COLAB_ENVIRONMENT = True
except:
    pass
# Out:
# Mounted at /content/drive

# %%
import sys
import os
import pickle

if COLAB_ENVIRONMENT:
    home_directory = './drive/MyDrive/LAB/COMP90089__GroupWork__Py/' # my home directory is stored in ./LAB of google drive
    if MODEL == 'ebr':
        # !pip install interpret==0.5.0
    elif MODEL == 'cbr':
        # !pip install catboost
    elif MODEL in ['tf', 'mlp']:
        # !pip install PyTorch2Sklearn
    # !pip install JXAutoML
else:
    home_directory = '../../'

from JXAutoML.YangZhouB_10CV import YangZhouB_10CV as Tuner

import pandas as pd
# Out:
# Collecting JXAutoML
#   Downloading JXAutoML-0.4.4-py3-none-any.whl.metadata (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.2/67.2 kB 2.6 MB/s eta 0:00:00
# Downloading JXAutoML-0.4.4-py3-none-any.whl (52 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.1/52.1 kB 3.9 MB/s eta 0:00:00
# Installing collected packages: JXAutoML
# Successfully installed JXAutoML-0.4.4

# %%
# Parameters that are same for every script

FOLDS = 10  # we have decided to do 10 fold validation

SEED = 42

TASK_TYPE = 'Classification'  # this task is a classification task

# we have decided to tune features as hp
TUNE_FEATURES_AS_HYPERPARAMETERS = True

# %% [markdown]
# ---

# %%
# model to use to tune
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis as clf

# what values to try for each hyperparameter
parameter_choices = {
    'tol': (0.00001, 0.0001, 0.001, 0.01, 0.1, 1, 10),
    'reg_param': (0.00001, 0.0001, 0.001, 0.01, 0.1, 1)
}

# what values to set non-tuneable parameters/hyperparameters
non_tunable_hyperparameters_dict = {}

# %% [markdown]
# ---

# %% [markdown]
# Read in and Prepare Data

# %%
# Import data and store as lists

train_x_list = []
train_y_list = []
val_x_list = []
val_y_list = []

for i in range(FOLDS):
    train_data = pd.read_csv(
        f'{home_directory}data/curated/modelling/{PREPROCESSING}/train_{i}.csv')
    val_data = pd.read_csv(
        f'{home_directory}data/curated/modelling/{PREPROCESSING}/val_{i}.csv')

    # get the correct rows for X and y
    train_x = train_data.drop(
        ['mortality_status', 'subject_id', 'hadm_id', 'stay_id'], axis=1)
    train_y = train_data['mortality_status']
    val_x = val_data.drop(
        ['mortality_status', 'subject_id', 'hadm_id', 'stay_id'], axis=1)
    val_y = val_data['mortality_status']

    train_x_list.append(train_x)
    train_y_list.append(train_y)
    val_x_list.append(val_x)
    val_y_list.append(val_y)

# %%
# Import feature importance ordering

with open(f'{home_directory}models/xgb_feature_importance_ordering_{PREPROCESSING}.pickle', 'rb') as f:
    feature_importance_ordering = pickle.load(f)

# %% [markdown]
# Set parameters

# %%
# initialisation
tuner = Tuner()

print('---')

# define what model we are tuning
tuner.read_in_model(clf, TASK_TYPE, optimised_metric=OPTIMISED_METRIC)

print('---')

# read in the data for training and validation
tuner.read_in_data(train_x_list, train_y_list, val_x_list, val_y_list)

print('---')

# set what hp values to tune
tuner.set_hyperparameters(parameter_choices)
# WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

# set up hp values that need to be changed from default but NOT to be tuned
tuner.set_non_tuneable_hyperparameters(non_tunable_hyperparameters_dict)

print('---')

# set up feature importance ordering

if TUNE_FEATURES_AS_HYPERPARAMETERS:
    tuner.set_features(feature_importance_ordering)
    # WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

try:  # try to read in previous results to continue tuning ...
    tuner.read_in_tuning_result_df(
        f'{home_directory}models/tuning/{TUNER}_{MODEL}_{PREPROCESSING}.csv')
except:
    print('No previous tuning data read in')

print('---')

# set up where to save the tuning result csv
tuner.set_tuning_result_saving_address(
    f'{home_directory}models/tuning/{TUNER}_{MODEL}_{PREPROCESSING}.csv')

print('---')

# set up where to save the current best model
tuner.set_best_model_saving_address(
    f'{home_directory}models/tmp_models/{TUNER}_{MODEL}_{PREPROCESSING}')
# Out:
# YangZhouB Initialised
# ---
# Successfully read in model <class 'sklearn.discriminant_analysis.QuadraticDiscriminantAnalysis'>, which is a Classification model optimising for f1
# ---
# Read in Train X data list
# Read in Train y data list
# Read in Val X data list
# Read in Val y data list
# ---
# Successfully recorded hyperparameter choices
# ---
# Successfully recorded non_tuneable_hyperparameter choices
# ---
# Successfully recorded tuneable feature combination choices and updated relevant internal structures
# ---
# No previous tuning data read in
# ---
# Successfully set tuning output address
# ---
# Successfully set best model output address

# %%
# ignore warnings

import warnings
warnings.filterwarnings("ignore")

# %%
# begin tuning ... (or continue training)

tuner.tune()
# Out:
# BEGIN TUNING
#
#
# STAGE ZERO: Tune all Cruise combinations
#
#
# Trained and Tested combination 1 of 3024, taking 0.02 seconds to get val score of 0.0:
#                 {'tol': 0.01, 'reg_param': 1, 'features': 20},
#             Current best combo with val score 0.0:
#                     {'tol': 0.01, 'reg_param': 1, 'features': 20}
# Trained and Tested combination 2 of 3024, taking 0.02 seconds to get val score of 0.0:
#                 {'tol': 0.01, 'reg_param': 1, 'features': 15},
#             Current best combo with val score 0.0:
#                     {'tol': 0.01, 'reg_param': 1, 'features': 20}
# Trained and Tested combination 3 of 3024, taking 0.01 seconds to get val score of 0.5051:
#                 {'tol': 0.01, 'reg_param': 1e-05, 'features': 20},
#             Current best combo with val score 0.5051:
#                     {'tol': 0.01, 'reg_param': 1e-05, 'features': 20}
# Trained and Tested combination 4 of 3024, taking 0.03 seconds to get val score of 0.4597:
#                 {'tol': 1e-05, 'reg_param': 1e-05, 'features': 10},
#             Current best combo with val score 0.5051:
#                     {'tol': 0.01, 'reg_param': 1e-05, 'features': 20}
# Trained and Tested combination 5 of 3024, taking 0.09 seconds to get val score of 0.3092:
#                 {'tol': 0.01, 'reg_param': 1e-05, 'features': 59},
#             Current best combo with val score 0.5051:
#                     {'tol': 0.01, 'reg_param': 1e-05, 'features': 20}
# Trained and Tested combination 6 of 3024, taking 0.03 seconds to get val score of 0.5051:
#                 {'tol': 1e-05, 'reg_param': 1e-05, 'features': 20},
#             Current best combo with val score 0.5051:
#                     {'tol': 0.01, 'reg_param': 1e-05, 'features': 20}
# Trained and Tested combination 7 of 3024, taking 0.02 seconds to get val score of 0.0:
#                 {'tol': 0.01, 'reg_param': 1, 'features': 25},
#             Current best combo with val score 0.5051:
#                     {'tol': 0.01, 'reg_param': 1e-05, 'features': 20}
# Trained and Tested combination 8 of 3024, taking 0.02 seconds to get val score of 0.0:
#                 {'tol': 1e-05, 'reg_param': 1, 'features': 20},
#             Current best combo with val score 0.5051:
#                     {'tol': 0.01, 'reg_param': 1e-05, 'features': 20}
# Trained and Tested combination 9 of 3024, taking 0.09 seconds to get val score of 0.3086:
#                 {'tol': 1e-05, 'reg_param': 1e-05, 'features': 40},
#             Current best combo with val score 0.5051:
#                     {'tol': 0.01, 'reg_param': 1e-05, 'features': 20}
# Trained and Tested combination 10 of 3024, taking 0.08 seconds to get val score of 0.3093:
#                 {'tol': 10, 'reg_param': 1e-05, 'features': 50},
#             Current best combo with val score 0.5051:
#                     {'tol': 0.01, 'reg_param': 1e-05, 'features': 20}
# Trained and Tested combination 11 of 3024, taking 0.15 seconds to get val score of 0.3092:
#                 {'tol': 0.01, 'reg_param': 1e-05, 'features': 67},
#             Current best combo with val score 0.5051:
#                     {'tol': 0.01, 'reg_param': 1e-05, 'features': 20}
# Trained and Tested combination 12 of 3024, taking 0.04 seconds to get val score of 0.0:
#                 {'tol': 1e-05, 'reg_param': 1, 'features': 45},
#             Current best combo with val score 0.5051:
#                     {'tol': 0.01, 'reg_param': 1e-05, 'features': 20}
# Trained and Tested combination 13 of 3024, taking 0.0 seconds to get val score of 0.0:
#                 {'tol': 1e-05, 'reg_param': 1, 'features': 0},
#             Current best combo with val score 0.5051:
#                     {'tol': 0.01, 'reg_param': 1e-05, 'features': 20}
# Trained and Tested combination 14 of 3024, taking 0.08 seconds to get val score of 0.0:
#                 {'tol': 1e-05, 'reg_param': 1, 'features': 50},
#             Current best combo with val score 0.5051:
#                     {'tol': 0.01, 'reg_param': 1e-05, 'features': 20}
# Trained and Tested combination 15 of 3024, taking 0.0 seconds to get val score of 0.4244:
#                 {'tol': 10, 'reg_param': 1e-05, 'features': 5},
#             Current best combo with val score 0.5051:
#                     {'tol': 0.01, 'reg_param': 1e-05, 'features': 20}
# Trained and Tested combination 16 of 3024, taking 0.0 seconds to get val score of 0.0:
#                 {'tol': 0.01, 'reg_param': 1, 'features': 0},
#             Current best combo with val score 0.5051:
#                     {'tol': 0.01, 'reg_param': 1e-05, 'features': 20}
# Trained and Tested combination 17 of 3024, taking 0.05 seconds to get val score of 0.0:
#                 {'tol': 1e-05, 'reg_param': 1, 'features': 55},
#             Current best combo with val score 0.5051:
#                     {'tol': 0.01, 'reg_param': 1e-05, 'features': 20}
# Trained and Tested combination 18 of 3024, taking 0.01 seconds to get val score of 0.3086:
#                 {'tol': 0.01, 'reg_param': 1e-05, 'features': 35},
#             Current best combo with val score 0.5051:
#                     {'tol': 0.01, 'reg_param': 1e-05, 'features': 20}
# Trained and Tested combination 19 of 3024, taking 0.05 seconds to get val score of 0.0:
#                 {'tol': 0.01, 'reg_param': 1, 'features': 55},
#             Current best combo with val score 0.5051:
#                     {'tol': 0.01, 'reg_param': 1e-05, 'features': 20}
# Trained and Tested combination 20 of 3024, taking 0.06 seconds to get val score of 0.3092:
#                 {'tol': 10, 'reg_param': 1e-05, 'features': 67},
#             Current best combo with val score 0.5051:
#                     {'tol': 0.01, 'reg_param': 1e-05, 'features': 20}
# Trained and Tested combination 21 of 3024, taking 0.01 seconds to get val score of 0.5051:
#                 {'tol': 10, 'reg_param': 1e-05, 'features': 20},
#             Current best combo with val score 0.5051:
#                     {'tol': 0.01, 'reg_param': 1e-05, 'features': 20}
# Trained and Tested combination 22 of 3024, taking 0.01 seconds to get val score of 0.0:
#                 {'tol': 1e-05, 'reg_param': 1, 'features': 15},
#             Current best combo with val score 0.5051:
#                     {'tol': 0.01, 'reg_param': 1e-05, 'features': 20}
# Trained and Tested combination 23 of 3024, taking 0.05 seconds to get val score of 0.0:
#                 {'tol': 10, 'reg_param': 1, 'features': 55},
#             Current best combo with val score 0.5051:
#                     {'tol': 0.01, 'reg_param': 1e-05, 'features': 20}
# Trained and Tested combination 24 of 3024, taking 0.02 seconds to get val score of 0.5213:
#                 {'tol': 0.01, 'reg_param': 1e-05, 'features': 15},
#             Current best combo with val score 0.5213:
#                     {'tol': 0.01, 'reg_param': 1e-05, 'features': 15}
# Trained and Tested combination 25 of 3024, taking 0.02 seconds to get val score of 0.0:
#                 {'tol': 10, 'reg_param': 1, 'features': 45},
#             Current best combo with val score 0.5213:
#                     {'tol': 0.01, 'reg_param': 1e-05, 'features': 15}
# Trained and Tested combination 26 of 3024, taking 0.0 seconds to get val score of 0.0:
#                 {'tol': 10, 'reg_param': 1, 'features': 5},
#             Current best combo with val score 0.5213:
#                     {'tol': 0.01, 'reg_param': 1e-05, 'features': 15}
# Trained and Tested combination 27 of 3024, taking 0.12 seconds to get val score of 0.0:
#                 {'tol': 1e-05, 'reg_param': 1, 'features': 63},
#             Current best combo with val score 0.5213:
#                     {'tol': 0.01, 'reg_param': 1e-05, 'features': 15}
# Trained and Tested combination 28 of 3024, taking 0.04 seconds to get val score of 0.3086:
#                 {'tol': 0.01, 'reg_param': 1e-05, 'features': 45},
#             Current best combo with val score 0.5213:
#                     {'tol': 0.01, 'reg_param': 1e-05, 'features': 15}
# Trained and Tested combination 29 of 3024, taking 0.03 seconds to get val score of 0.0:
#                 {'tol': 0.01, 'reg_param': 1, 'features': 35},
#             Current best combo with val score 0.5213:
#                     {'tol': 0.01, 'reg_param': 1e-05, 'features': 15}
# Trained and Tested combination 30 of 3024, taking 0.03 seconds to get val score of 0.0:
#                 {'tol': 1e-05, 'reg_param': 1, 'features': 30},
#             Current best combo with val score 0.5213:
#                     {'tol': 0.01, 'reg_param': 1e-05, 'features': 15}
# Trained and Tested combination 31 of 3024, taking 0.01 seconds to get val score of 0.4473:
#                 {'tol': 10, 'reg_param': 1e-05, 'features': 30},
#             Current best combo with val score 0.5213:
#                     {'tol': 0.01, 'reg_param': 1e-05, 'features': 15}
# Trained and Tested combination 32 of 3024, taking 0.04 seconds to get val score of 0.3086:
#                 {'tol': 10, 'reg_param': 1e-05, 'features': 35},
#             Current best combo with val score 0.5213:
#                     {'tol': 0.01, 'reg_param': 1e-05, 'features': 15}
# Trained and Tested combination 33 of 3024, taking 0.0 seconds to get val score of 0.4244:
#                 {'tol': 0.01, 'reg_param': 1e-05, 'features': 5},
#             Current best combo with val score 0.5213:
#                     {'tol': 0.01, 'reg_param': 1e-05, 'features': 15}
# Trained and Tested combination 34 of 3024, taking 0.01 seconds to get val score of 0.0:
#                 {'tol': 1e-05, 'reg_param': 1, 'features': 10},
#             Current best combo with val score 0.5213:
#                     {'tol': 0.01, 'reg_param': 1e-05, 'features': 15}
# Trained and Tested combination 35 of 3024, taking 0.0 seconds to get val score of 0.0:
#                 {'tol': 1e-05, 'reg_param': 1, 'features': 5},
#             Current best combo with val score 0.5213:
#                     {'tol': 0.01, 'reg_param': 1e-05, 'features': 15}
# Trained and Tested combination 36 of 3024, taking 0.01 seconds to get val score of 0.0:
#                 {'tol': 1e-05, 'reg_param': 1, 'features': 25},
#             Current best combo with val score 0.5213:
#                     {'tol': 0.01, 'reg_param': 1e-05, 'features': 15}
# Trained and Tested combination 37 of 3024, taking 0.06 seconds to get val score of 0.309:
#                 {'tol': 10, 'reg_param': 1e-05, 'features': 71},
#             Current best combo with val score 0.5213:
#                     {'tol': 0.01, 'reg_param': 1e-05, 'features': 15}
# Trained and Tested combination 38 of 3024, taking 0.05 seconds to get val score of 0.0:
#                 {'tol': 0.01, 'reg_param': 1, 'features': 63},
#             Current best combo with val score 0.5213:
#                     {'tol': 0.01, 'reg_param': 1e-05, 'features': 15}
# Trained and Tested combination 39 of 3024, taking 0.05 seconds to get val score of 0.3092:
#                 {'tol': 10, 'reg_param': 1e-05, 'features': 59},
#             Current best combo with val score 0.5213:
#                     {'tol': 0.01, 'reg_param': 1e-05, 'features': 15}
# Trained and Tested combination 40 of 3024, taking 0.01 seconds to get val score of 0.4473:
#                 {'tol': 1e-05, 'reg_param': 1e-05, 'features': 30},
#             Current best combo with val score 0.5213:
#                     {'tol': 0.01, 'reg_param': 1e-05, 'features': 15}
# Trained and Tested combination 41 of 3024, taking 0.02 seconds to get val score of 0.0:
#                 {'tol': 10, 'reg_param': 1, 'features': 40},
#             Current best combo with val score 0.5213:
#                     {'tol': 0.01, 'reg_param': 1e-05, 'features': 15}
# Trained and Tested combination 42 of 3024, taking 0.01 seconds to get val score of 0.5373:
#                 {'tol': 10, 'reg_param': 1e-05, 'features': 25},
#             Current best combo with val score 0.5373:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 25}
# Trained and Tested combination 43 of 3024, taking 0.0 seconds to get val score of 0.4597:
#                 {'tol': 0.01, 'reg_param': 1e-05, 'features': 10},
#             Current best combo with val score 0.5373:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 25}
# Trained and Tested combination 44 of 3024, taking 0.14 seconds to get val score of 0.0:
#                 {'tol': 10, 'reg_param': 1, 'features': 63},
#             Current best combo with val score 0.5373:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 25}
# Trained and Tested combination 45 of 3024, taking 0.08 seconds to get val score of 0.3092:
#                 {'tol': 1e-05, 'reg_param': 1e-05, 'features': 55},
#             Current best combo with val score 0.5373:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 25}
# Trained and Tested combination 46 of 3024, taking 0.04 seconds to get val score of 0.4473:
#                 {'tol': 0.01, 'reg_param': 1e-05, 'features': 30},
#             Current best combo with val score 0.5373:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 25}
# Trained and Tested combination 47 of 3024, taking 0.05 seconds to get val score of 0.3092:
#                 {'tol': 0.01, 'reg_param': 1e-05, 'features': 55},
#             Current best combo with val score 0.5373:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 25}
# Trained and Tested combination 48 of 3024, taking 0.05 seconds to get val score of 0.0:
#                 {'tol': 10, 'reg_param': 1, 'features': 59},
#             Current best combo with val score 0.5373:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 25}
# Trained and Tested combination 49 of 3024, taking 0.01 seconds to get val score of 0.0:
#                 {'tol': 1e-05, 'reg_param': 1, 'features': 35},
#             Current best combo with val score 0.5373:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 25}
# Trained and Tested combination 50 of 3024, taking 0.01 seconds to get val score of 0.0:
#                 {'tol': 10, 'reg_param': 1, 'features': 15},
#             Current best combo with val score 0.5373:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 25}
# Trained and Tested combination 51 of 3024, taking 0.01 seconds to get val score of 0.0:
#                 {'tol': 10, 'reg_param': 1, 'features': 20},
#             Current best combo with val score 0.5373:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 25}
# Trained and Tested combination 52 of 3024, taking 0.02 seconds to get val score of 0.3086:
#                 {'tol': 10, 'reg_param': 1e-05, 'features': 45},
#             Current best combo with val score 0.5373:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 25}
# Trained and Tested combination 53 of 3024, taking 0.05 seconds to get val score of 0.3092:
#                 {'tol': 0.01, 'reg_param': 1e-05, 'features': 63},
#             Current best combo with val score 0.5373:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 25}
# Trained and Tested combination 54 of 3024, taking 0.08 seconds to get val score of 0.3092:
#                 {'tol': 1e-05, 'reg_param': 1e-05, 'features': 63},
#             Current best combo with val score 0.5373:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 25}
# Trained and Tested combination 55 of 3024, taking 0.0 seconds to get val score of 0.4597:
#                 {'tol': 10, 'reg_param': 1e-05, 'features': 10},
#             Current best combo with val score 0.5373:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 25}
# Trained and Tested combination 56 of 3024, taking 0.0 seconds to get val score of 0.0:
#                 {'tol': 0.01, 'reg_param': 1, 'features': 10},
#             Current best combo with val score 0.5373:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 25}
# Trained and Tested combination 57 of 3024, taking 0.0 seconds to get val score of 0.2933:
#                 {'tol': 0.01, 'reg_param': 1e-05, 'features': 0},
#             Current best combo with val score 0.5373:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 25}
# Trained and Tested combination 58 of 3024, taking 0.02 seconds to get val score of 0.3086:
#                 {'tol': 1e-05, 'reg_param': 1e-05, 'features': 45},
#             Current best combo with val score 0.5373:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 25}
# Trained and Tested combination 59 of 3024, taking 0.01 seconds to get val score of 0.4244:
#                 {'tol': 1e-05, 'reg_param': 1e-05, 'features': 5},
#             Current best combo with val score 0.5373:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 25}
# Trained and Tested combination 60 of 3024, taking 0.07 seconds to get val score of 0.0:
#                 {'tol': 0.01, 'reg_param': 1, 'features': 50},
#             Current best combo with val score 0.5373:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 25}
# Trained and Tested combination 61 of 3024, taking 0.04 seconds to get val score of 0.0:
#                 {'tol': 10, 'reg_param': 1, 'features': 35},
#             Current best combo with val score 0.5373:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 25}
# Trained and Tested combination 62 of 3024, taking 0.06 seconds to get val score of 0.0:
#                 {'tol': 1e-05, 'reg_param': 1, 'features': 67},
#             Current best combo with val score 0.5373:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 25}
# Trained and Tested combination 63 of 3024, taking 0.01 seconds to get val score of 0.5373:
#                 {'tol': 0.01, 'reg_param': 1e-05, 'features': 25},
#             Current best combo with val score 0.5373:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 25}
# Trained and Tested combination 64 of 3024, taking 0.05 seconds to get val score of 0.3092:
#                 {'tol': 10, 'reg_param': 1e-05, 'features': 55},
#             Current best combo with val score 0.5373:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 25}
# Trained and Tested combination 65 of 3024, taking 0.09 seconds to get val score of 0.309:
#                 {'tol': 1e-05, 'reg_param': 1e-05, 'features': 71},
#             Current best combo with val score 0.5373:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 25}
# Trained and Tested combination 66 of 3024, taking 0.05 seconds to get val score of 0.3092:
#                 {'tol': 10, 'reg_param': 1e-05, 'features': 63},
#             Current best combo with val score 0.5373:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 25}
# Trained and Tested combination 67 of 3024, taking 0.02 seconds to get val score of 0.3086:
#                 {'tol': 0.01, 'reg_param': 1e-05, 'features': 40},
#             Current best combo with val score 0.5373:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 25}
# Trained and Tested combination 68 of 3024, taking 0.06 seconds to get val score of 0.0:
#                 {'tol': 0.01, 'reg_param': 1, 'features': 71},
#             Current best combo with val score 0.5373:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 25}
# Trained and Tested combination 69 of 3024, taking 0.06 seconds to get val score of 0.0:
#                 {'tol': 0.01, 'reg_param': 1, 'features': 67},
#             Current best combo with val score 0.5373:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 25}
# Trained and Tested combination 70 of 3024, taking 0.01 seconds to get val score of 0.0:
#                 {'tol': 0.01, 'reg_param': 1, 'features': 30},
#             Current best combo with val score 0.5373:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 25}
# Trained and Tested combination 71 of 3024, taking 0.0 seconds to get val score of 0.0:
#                 {'tol': 0.01, 'reg_param': 1, 'features': 5},
#             Current best combo with val score 0.5373:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 25}
# Trained and Tested combination 72 of 3024, taking 0.14 seconds to get val score of 0.0:
#                 {'tol': 10, 'reg_param': 1, 'features': 67},
#             Current best combo with val score 0.5373:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 25}
# Trained and Tested combination 73 of 3024, taking 0.14 seconds to get val score of 0.0:
#                 {'tol': 1e-05, 'reg_param': 1, 'features': 59},
#             Current best combo with val score 0.5373:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 25}
# Trained and Tested combination 74 of 3024, taking 0.01 seconds to get val score of 0.5373:
#                 {'tol': 1e-05, 'reg_param': 1e-05, 'features': 25},
#             Current best combo with val score 0.5373:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 25}
# Trained and Tested combination 75 of 3024, taking 0.05 seconds to get val score of 0.3092:
#                 {'tol': 1e-05, 'reg_param': 1e-05, 'features': 59},
#             Current best combo with val score 0.5373:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 25}
# Trained and Tested combination 76 of 3024, taking 0.0 seconds to get val score of 0.2933:
#                 {'tol': 1e-05, 'reg_param': 1e-05, 'features': 0},
#             Current best combo with val score 0.5373:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 25}
# Trained and Tested combination 77 of 3024, taking 0.01 seconds to get val score of 0.0:
#                 {'tol': 10, 'reg_param': 1, 'features': 25},
#             Current best combo with val score 0.5373:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 25}
# Trained and Tested combination 78 of 3024, taking 0.06 seconds to get val score of 0.0:
#                 {'tol': 10, 'reg_param': 1, 'features': 71},
#             Current best combo with val score 0.5373:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 25}
# Trained and Tested combination 79 of 3024, taking 0.02 seconds to get val score of 0.0:
#                 {'tol': 0.01, 'reg_param': 1, 'features': 40},
#             Current best combo with val score 0.5373:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 25}
# Trained and Tested combination 80 of 3024, taking 0.01 seconds to get val score of 0.5213:
#                 {'tol': 10, 'reg_param': 1e-05, 'features': 15},
#             Current best combo with val score 0.5373:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 25}
# Trained and Tested combination 81 of 3024, taking 0.02 seconds to get val score of 0.0:
#                 {'tol': 1e-05, 'reg_param': 1, 'features': 40},
#             Current best combo with val score 0.5373:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 25}
# Trained and Tested combination 82 of 3024, taking 0.01 seconds to get val score of 0.0:
#                 {'tol': 10, 'reg_param': 1, 'features': 30},
#             Current best combo with val score 0.5373:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 25}
# Trained and Tested combination 83 of 3024, taking 0.01 seconds to get val score of 0.3086:
#                 {'tol': 1e-05, 'reg_param': 1e-05, 'features': 35},
#             Current best combo with val score 0.5373:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 25}
# Trained and Tested combination 84 of 3024, taking 0.08 seconds to get val score of 0.0:
#                 {'tol': 0.01, 'reg_param': 1, 'features': 59},
#             Current best combo with val score 0.5373:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 25}
# Trained and Tested combination 85 of 3024, taking 0.06 seconds to get val score of 0.0:
#                 {'tol': 1e-05, 'reg_param': 1, 'features': 71},
#             Current best combo with val score 0.5373:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 25}
# Trained and Tested combination 86 of 3024, taking 0.13 seconds to get val score of 0.0:
#                 {'tol': 10, 'reg_param': 1, 'features': 50},
#             Current best combo with val score 0.5373:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 25}
# Trained and Tested combination 87 of 3024, taking 0.14 seconds to get val score of 0.3092:
#                 {'tol': 1e-05, 'reg_param': 1e-05, 'features': 67},
#             Current best combo with val score 0.5373:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 25}
# Trained and Tested combination 88 of 3024, taking 0.0 seconds to get val score of 0.0:
#                 {'tol': 10, 'reg_param': 1, 'features': 0},
#             Current best combo with val score 0.5373:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 25}
# Trained and Tested combination 89 of 3024, taking 0.02 seconds to get val score of 0.0:
#                 {'tol': 0.01, 'reg_param': 1, 'features': 45},
#             Current best combo with val score 0.5373:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 25}
# Trained and Tested combination 90 of 3024, taking 0.05 seconds to get val score of 0.3093:
#                 {'tol': 1e-05, 'reg_param': 1e-05, 'features': 50},
#             Current best combo with val score 0.5373:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 25}
# Trained and Tested combination 91 of 3024, taking 0.01 seconds to get val score of 0.5213:
#                 {'tol': 1e-05, 'reg_param': 1e-05, 'features': 15},
#             Current best combo with val score 0.5373:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 25}
# Trained and Tested combination 92 of 3024, taking 0.0 seconds to get val score of 0.0:
#                 {'tol': 10, 'reg_param': 1, 'features': 10},
#             Current best combo with val score 0.5373:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 25}
# Trained and Tested combination 93 of 3024, taking 0.02 seconds to get val score of 0.3086:
#                 {'tol': 10, 'reg_param': 1e-05, 'features': 40},
#             Current best combo with val score 0.5373:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 25}
# Trained and Tested combination 94 of 3024, taking 0.06 seconds to get val score of 0.3093:
#                 {'tol': 0.01, 'reg_param': 1e-05, 'features': 50},
#             Current best combo with val score 0.5373:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 25}
# Trained and Tested combination 95 of 3024, taking 0.01 seconds to get val score of 0.3086:
#                 {'tol': 0.01, 'reg_param': 0.01, 'features': 36},
#             Current best combo with val score 0.5373:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 25}
# Trained and Tested combination 96 of 3024, taking 0.06 seconds to get val score of 0.309:
#                 {'tol': 0.01, 'reg_param': 1e-05, 'features': 71},
#             Current best combo with val score 0.5373:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 25}
# Trained and Tested combination 97 of 3024, taking 0.0 seconds to get val score of 0.2933:
#                 {'tol': 10, 'reg_param': 1e-05, 'features': 0},
#             Current best combo with val score 0.5373:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 25}
#
#
# STAGE ONE: Begin initial Guidance system
#
#
# Guidance: initial round
#
# 	round 0 iteration:  0
#
# Trained and Tested combination 98 of 3024, taking 0.01 seconds to get val score of 0.3086:
#                 {'tol': 0.001, 'reg_param': 0.01, 'features': 36},
#             Current best combo with val score 0.5373:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 25}
# Trained and Tested combination 99 of 3024, taking 0.01 seconds to get val score of 0.3086:
#                 {'tol': 0.1, 'reg_param': 0.01, 'features': 36},
#             Current best combo with val score 0.5373:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 25}
# Trained and Tested combination 100 of 3024, taking 0.01 seconds to get val score of 0.3086:
#                 {'tol': 0.01, 'reg_param': 0.001, 'features': 36},
#             Current best combo with val score 0.5373:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 25}
# Trained and Tested combination 101 of 3024, taking 0.03 seconds to get val score of 0.3086:
#                 {'tol': 0.01, 'reg_param': 0.1, 'features': 36},
#             Current best combo with val score 0.5373:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 25}
# Trained and Tested combination 102 of 3024, taking 0.03 seconds to get val score of 0.3086:
#                 {'tol': 0.01, 'reg_param': 0.01, 'features': 35},
#             Current best combo with val score 0.5373:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 25}
# Trained and Tested combination 103 of 3024, taking 0.03 seconds to get val score of 0.3086:
#                 {'tol': 0.01, 'reg_param': 0.01, 'features': 37},
#             Current best combo with val score 0.5373:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 25}
# 	round 0 iteration:  1
#
# Trained and Tested combination 104 of 3024, taking 0.03 seconds to get val score of 0.3086:
#                 {'tol': 0.0001, 'reg_param': 0.01, 'features': 36},
#             Current best combo with val score 0.5373:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 25}
# Already Trained and Tested combination (val score of 0.3086):
#             {'tol': 0.01, 'reg_param': 0.01, 'features': 36}
#             Current best combo (with val score 0.5373):
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 25}
#         Has trained 104 of 3024 combinations so far
# Trained and Tested combination 105 of 3024, taking 0.01 seconds to get val score of 0.3086:
#                 {'tol': 0.001, 'reg_param': 0.001, 'features': 36},
#             Current best combo with val score 0.5373:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 25}
# Trained and Tested combination 106 of 3024, taking 0.01 seconds to get val score of 0.3086:
#                 {'tol': 0.001, 'reg_param': 0.1, 'features': 36},
#             Current best combo with val score 0.5373:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 25}
# Trained and Tested combination 107 of 3024, taking 0.01 seconds to get val score of 0.3086:
#                 {'tol': 0.001, 'reg_param': 0.01, 'features': 35},
#             Current best combo with val score 0.5373:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 25}
# Trained and Tested combination 108 of 3024, taking 0.01 seconds to get val score of 0.3086:
#                 {'tol': 0.001, 'reg_param': 0.01, 'features': 37},
#             Current best combo with val score 0.5373:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 25}
# Already Trained and Tested combination (val score of 0.3086):
#             {'tol': 0.01, 'reg_param': 0.01, 'features': 36}
#             Current best combo (with val score 0.5373):
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 25}
#         Has trained 108 of 3024 combinations so far
# Trained and Tested combination 109 of 3024, taking 0.01 seconds to get val score of 0.3086:
#                 {'tol': 1, 'reg_param': 0.01, 'features': 36},
#             Current best combo with val score 0.5373:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 25}
# Trained and Tested combination 110 of 3024, taking 0.01 seconds to get val score of 0.3086:
#                 {'tol': 0.1, 'reg_param': 0.001, 'features': 36},
#             Current best combo with val score 0.5373:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 25}
# Trained and Tested combination 111 of 3024, taking 0.01 seconds to get val score of 0.3086:
#                 {'tol': 0.1, 'reg_param': 0.1, 'features': 36},
#             Current best combo with val score 0.5373:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 25}
# Trained and Tested combination 112 of 3024, taking 0.01 seconds to get val score of 0.3086:
#                 {'tol': 0.1, 'reg_param': 0.01, 'features': 35},
#             Current best combo with val score 0.5373:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 25}
# Trained and Tested combination 113 of 3024, taking 0.01 seconds to get val score of 0.3086:
#                 {'tol': 0.1, 'reg_param': 0.01, 'features': 37},
#             Current best combo with val score 0.5373:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 25}
# Already Trained and Tested combination (val score of 0.3086):
#             {'tol': 0.001, 'reg_param': 0.001, 'features': 36}
#             Current best combo (with val score 0.5373):
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 25}
#         Has trained 113 of 3024 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'tol': 0.1, 'reg_param': 0.001, 'features': 36}
#             Current best combo (with val score 0.5373):
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 25}
#         Has trained 113 of 3024 combinations so far
# Trained and Tested combination 114 of 3024, taking 0.01 seconds to get val score of 0.3086:
#                 {'tol': 0.01, 'reg_param': 0.0001, 'features': 36},
#             Current best combo with val score 0.5373:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 25}
# Already Trained and Tested combination (val score of 0.3086):
#             {'tol': 0.01, 'reg_param': 0.01, 'features': 36}
#             Current best combo (with val score 0.5373):
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 25}
#         Has trained 114 of 3024 combinations so far
# Trained and Tested combination 115 of 3024, taking 0.01 seconds to get val score of 0.3086:
#                 {'tol': 0.01, 'reg_param': 0.001, 'features': 35},
#             Current best combo with val score 0.5373:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 25}
# Trained and Tested combination 116 of 3024, taking 0.01 seconds to get val score of 0.3086:
#                 {'tol': 0.01, 'reg_param': 0.001, 'features': 37},
#             Current best combo with val score 0.5373:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 25}
# Already Trained and Tested combination (val score of 0.3086):
#             {'tol': 0.001, 'reg_param': 0.1, 'features': 36}
#             Current best combo (with val score 0.5373):
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 25}
#         Has trained 116 of 3024 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'tol': 0.1, 'reg_param': 0.1, 'features': 36}
#             Current best combo (with val score 0.5373):
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 25}
#         Has trained 116 of 3024 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'tol': 0.01, 'reg_param': 0.01, 'features': 36}
#             Current best combo (with val score 0.5373):
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 25}
#         Has trained 116 of 3024 combinations so far
# Trained and Tested combination 117 of 3024, taking 0.01 seconds to get val score of 0.0:
#                 {'tol': 0.01, 'reg_param': 1, 'features': 36},
#             Current best combo with val score 0.5373:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 25}
# Trained and Tested combination 118 of 3024, taking 0.01 seconds to get val score of 0.3086:
#                 {'tol': 0.01, 'reg_param': 0.1, 'features': 35},
#             Current best combo with val score 0.5373:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 25}
# Trained and Tested combination 119 of 3024, taking 0.03 seconds to get val score of 0.3086:
#                 {'tol': 0.01, 'reg_param': 0.1, 'features': 37},
#             Current best combo with val score 0.5373:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 25}
# Already Trained and Tested combination (val score of 0.3086):
#             {'tol': 0.001, 'reg_param': 0.01, 'features': 35}
#             Current best combo (with val score 0.5373):
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 25}
#         Has trained 119 of 3024 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'tol': 0.1, 'reg_param': 0.01, 'features': 35}
#             Current best combo (with val score 0.5373):
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 25}
#         Has trained 119 of 3024 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'tol': 0.01, 'reg_param': 0.001, 'features': 35}
#             Current best combo (with val score 0.5373):
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 25}
#         Has trained 119 of 3024 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'tol': 0.01, 'reg_param': 0.1, 'features': 35}
#             Current best combo (with val score 0.5373):
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 25}
#         Has trained 119 of 3024 combinations so far
# Trained and Tested combination 120 of 3024, taking 0.03 seconds to get val score of 0.3086:
#                 {'tol': 0.01, 'reg_param': 0.01, 'features': 34},
#             Current best combo with val score 0.5373:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 25}
# Already Trained and Tested combination (val score of 0.3086):
#             {'tol': 0.01, 'reg_param': 0.01, 'features': 36}
#             Current best combo (with val score 0.5373):
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 25}
#         Has trained 120 of 3024 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'tol': 0.001, 'reg_param': 0.01, 'features': 37}
#             Current best combo (with val score 0.5373):
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 25}
#         Has trained 120 of 3024 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'tol': 0.1, 'reg_param': 0.01, 'features': 37}
#             Current best combo (with val score 0.5373):
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 25}
#         Has trained 120 of 3024 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'tol': 0.01, 'reg_param': 0.001, 'features': 37}
#             Current best combo (with val score 0.5373):
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 25}
#         Has trained 120 of 3024 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'tol': 0.01, 'reg_param': 0.1, 'features': 37}
#             Current best combo (with val score 0.5373):
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 25}
#         Has trained 120 of 3024 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'tol': 0.01, 'reg_param': 0.01, 'features': 36}
#             Current best combo (with val score 0.5373):
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 25}
#         Has trained 120 of 3024 combinations so far
# Trained and Tested combination 121 of 3024, taking 0.04 seconds to get val score of 0.3086:
#                 {'tol': 0.01, 'reg_param': 0.01, 'features': 38},
#             Current best combo with val score 0.5373:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 25}
# Trained and Tested combination 122 of 3024, taking 0.02 seconds to get val score of 0.5373:
#                 {'tol': 1, 'reg_param': 1e-05, 'features': 25},
#             Current best combo with val score 0.5373:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 25}
# Trained and Tested combination 123 of 3024, taking 0.01 seconds to get val score of 0.5312:
#                 {'tol': 10, 'reg_param': 0.0001, 'features': 25},
#             Current best combo with val score 0.5373:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 25}
# Trained and Tested combination 124 of 3024, taking 0.01 seconds to get val score of 0.5372:
#                 {'tol': 10, 'reg_param': 1e-05, 'features': 24},
#             Current best combo with val score 0.5373:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 25}
# Trained and Tested combination 125 of 3024, taking 0.01 seconds to get val score of 0.5419:
#                 {'tol': 10, 'reg_param': 1e-05, 'features': 26},
#             Current best combo with val score 0.5419:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 26}
# Trained and Tested combination 126 of 3024, taking 0.01 seconds to get val score of 0.5419:
#                 {'tol': 1, 'reg_param': 1e-05, 'features': 26},
#             Current best combo with val score 0.5419:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 26}
# Trained and Tested combination 127 of 3024, taking 0.01 seconds to get val score of 0.5333:
#                 {'tol': 10, 'reg_param': 0.0001, 'features': 26},
#             Current best combo with val score 0.5419:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 26}
# Already Trained and Tested combination (val score of 0.5373):
#             {'tol': 10, 'reg_param': 1e-05, 'features': 25}
#             Current best combo (with val score 0.5419):
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 26}
#         Has trained 127 of 3024 combinations so far
# Trained and Tested combination 128 of 3024, taking 0.01 seconds to get val score of 0.5494:
#                 {'tol': 10, 'reg_param': 1e-05, 'features': 27},
#             Current best combo with val score 0.5494:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 27}
# Trained and Tested combination 129 of 3024, taking 0.01 seconds to get val score of 0.5494:
#                 {'tol': 1, 'reg_param': 1e-05, 'features': 27},
#             Current best combo with val score 0.5494:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 27}
# Trained and Tested combination 130 of 3024, taking 0.01 seconds to get val score of 0.5464:
#                 {'tol': 10, 'reg_param': 0.0001, 'features': 27},
#             Current best combo with val score 0.5494:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 27}
# Already Trained and Tested combination (val score of 0.5419):
#             {'tol': 10, 'reg_param': 1e-05, 'features': 26}
#             Current best combo (with val score 0.5494):
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 27}
#         Has trained 130 of 3024 combinations so far
# Trained and Tested combination 131 of 3024, taking 0.01 seconds to get val score of 0.4859:
#                 {'tol': 10, 'reg_param': 1e-05, 'features': 28},
#             Current best combo with val score 0.5494:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 27}
# % Combos Checked Thus Far: 131 out of 3024 which is 4.3320110000000005%
# STAGE TWO: Begin Cruise system
#
#
# Cruising Coordrdinate 1 of 96
#
# Cruising Coordrdinate 2 of 96
#
# Cruising Coordrdinate 3 of 96
#
# Cruising Coordrdinate 4 of 96
#
# Cruising Coordrdinate 5 of 96
#
# Cruising Coordrdinate 6 of 96
#
# Cruising Coordrdinate 7 of 96
#
# Cruising Coordrdinate 8 of 96
#
# Cruising Coordrdinate 9 of 96
#
# Cruising Coordrdinate 10 of 96
#
# Cruising Coordrdinate 11 of 96
#
# Cruising Coordrdinate 12 of 96
#
# Cruising Coordrdinate 13 of 96
#
# Cruising Coordrdinate 14 of 96
#
# Cruising Coordrdinate 15 of 96
#
# Cruising Coordrdinate 16 of 96
#
# Cruising Coordrdinate 17 of 96
#
# Cruising Coordrdinate 18 of 96
#
# Cruising Coordrdinate 19 of 96
#
# Cruising Coordrdinate 20 of 96
#
# Cruising Coordrdinate 21 of 96
#
# Cruising Coordrdinate 22 of 96
#
# Cruising Coordrdinate 23 of 96
#
# Cruising Coordrdinate 24 of 96
#
# Cruising Coordrdinate 25 of 96
#
# Cruising Coordrdinate 26 of 96
#
# Cruising Coordrdinate 27 of 96
#
# Cruising Coordrdinate 28 of 96
#
# Cruising Coordrdinate 29 of 96
#
# Cruising Coordrdinate 30 of 96
#
# Cruising Coordrdinate 31 of 96
#
# Cruising Coordrdinate 32 of 96
#
# Cruising Coordrdinate 33 of 96
#
# Cruising Coordrdinate 34 of 96
#
# Cruising Coordrdinate 35 of 96
#
# Cruising Coordrdinate 36 of 96
#
# Cruising Coordrdinate 37 of 96
#
# Cruising Coordrdinate 38 of 96
#
# Cruising Coordrdinate 39 of 96
#
# Cruising Coordrdinate 40 of 96
#
# Cruising Coordrdinate 41 of 96
#
# Cruising Coordrdinate 42 of 96
#
# Cruising Coordrdinate 43 of 96
#
# Cruising Coordrdinate 44 of 96
#
# Cruising Coordrdinate 45 of 96
#
# Cruising Coordrdinate 46 of 96
#
# Cruising Coordrdinate 47 of 96
#
# Cruising Coordrdinate 48 of 96
#
# Cruising Coordrdinate 49 of 96
#
# Cruising Coordrdinate 50 of 96
#
# Cruising Coordrdinate 51 of 96
#
# Cruising Coordrdinate 52 of 96
#
# Cruising Coordrdinate 53 of 96
#
# Cruising Coordrdinate 54 of 96
#
# Cruising Coordrdinate 55 of 96
#
# Cruising Coordrdinate 56 of 96
#
# Cruising Coordrdinate 57 of 96
#
# Cruising Coordrdinate 58 of 96
#
# Cruising Coordrdinate 59 of 96
#
# Cruising Coordrdinate 60 of 96
#
# Cruising Coordrdinate 61 of 96
#
# Cruising Coordrdinate 62 of 96
#
# Cruising Coordrdinate 63 of 96
#
# Cruising Coordrdinate 64 of 96
#
# Cruising Coordrdinate 65 of 96
#
# Cruising Coordrdinate 66 of 96
#
# Cruise suspended due to suspicious case
# Guidance: round 1
#
# 	round 1 iteration:  0
#
# Trained and Tested combination 132 of 3024, taking 0.01 seconds to get val score of 0.5213:
#                 {'tol': 0.0001, 'reg_param': 1e-05, 'features': 15},
#             Current best combo with val score 0.5494:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 27}
# Trained and Tested combination 133 of 3024, taking 0.01 seconds to get val score of 0.4893:
#                 {'tol': 1e-05, 'reg_param': 0.0001, 'features': 15},
#             Current best combo with val score 0.5494:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 27}
# Trained and Tested combination 134 of 3024, taking 0.01 seconds to get val score of 0.5227:
#                 {'tol': 1e-05, 'reg_param': 1e-05, 'features': 14},
#             Current best combo with val score 0.5494:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 27}
# Trained and Tested combination 135 of 3024, taking 0.01 seconds to get val score of 0.5108:
#                 {'tol': 1e-05, 'reg_param': 1e-05, 'features': 16},
#             Current best combo with val score 0.5494:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 27}
# 	round 1 iteration:  1
#
# Already Trained and Tested combination (val score of 0.5213):
#             {'tol': 1e-05, 'reg_param': 1e-05, 'features': 15}
#             Current best combo (with val score 0.5494):
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 27}
#         Has trained 135 of 3024 combinations so far
# Trained and Tested combination 136 of 3024, taking 0.01 seconds to get val score of 0.5213:
#                 {'tol': 0.001, 'reg_param': 1e-05, 'features': 15},
#             Current best combo with val score 0.5494:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 27}
# Trained and Tested combination 137 of 3024, taking 0.01 seconds to get val score of 0.4893:
#                 {'tol': 0.0001, 'reg_param': 0.0001, 'features': 15},
#             Current best combo with val score 0.5494:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 27}
# Trained and Tested combination 138 of 3024, taking 0.01 seconds to get val score of 0.5227:
#                 {'tol': 0.0001, 'reg_param': 1e-05, 'features': 14},
#             Current best combo with val score 0.5494:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 27}
# Trained and Tested combination 139 of 3024, taking 0.01 seconds to get val score of 0.5108:
#                 {'tol': 0.0001, 'reg_param': 1e-05, 'features': 16},
#             Current best combo with val score 0.5494:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 27}
# Already Trained and Tested combination (val score of 0.5227):
# ...
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 27}
#         Has trained 169 of 3024 combinations so far
# Trained and Tested combination 170 of 3024, taking 0.01 seconds to get val score of 0.5494:
#                 {'tol': 1e-05, 'reg_param': 1e-05, 'features': 27},
#             Current best combo with val score 0.5494:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 27}
# % Combos Checked Thus Far: 170 out of 3024 which is 5.621693%
# Cruising Coordrdinate 90 of 96
#
# Cruising Coordrdinate 91 of 96
#
# Cruising Coordrdinate 92 of 96
#
# Cruising Coordrdinate 93 of 96
#
# Cruising Coordrdinate 94 of 96
#
# Cruise suspended due to suspicious case
# Guidance: round 5
#
# 	round 5 iteration:  0
#
# Already Trained and Tested combination (val score of 0.5373):
#             {'tol': 0.001, 'reg_param': 1e-05, 'features': 25}
#             Current best combo (with val score 0.5494):
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 27}
#         Has trained 170 of 3024 combinations so far
# Trained and Tested combination 171 of 3024, taking 0.01 seconds to get val score of 0.5373:
#                 {'tol': 0.1, 'reg_param': 1e-05, 'features': 25},
#             Current best combo with val score 0.5494:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 27}
# Trained and Tested combination 172 of 3024, taking 0.01 seconds to get val score of 0.5312:
#                 {'tol': 0.01, 'reg_param': 0.0001, 'features': 25},
#             Current best combo with val score 0.5494:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 27}
# Trained and Tested combination 173 of 3024, taking 0.01 seconds to get val score of 0.5372:
#                 {'tol': 0.01, 'reg_param': 1e-05, 'features': 24},
#             Current best combo with val score 0.5494:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 27}
# Trained and Tested combination 174 of 3024, taking 0.01 seconds to get val score of 0.5419:
#                 {'tol': 0.01, 'reg_param': 1e-05, 'features': 26},
#             Current best combo with val score 0.5494:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 27}
# 	round 5 iteration:  1
#
# Already Trained and Tested combination (val score of 0.5373):
#             {'tol': 0.01, 'reg_param': 1e-05, 'features': 25}
#             Current best combo (with val score 0.5494):
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 27}
#         Has trained 174 of 3024 combinations so far
# Already Trained and Tested combination (val score of 0.5373):
#             {'tol': 1, 'reg_param': 1e-05, 'features': 25}
#             Current best combo (with val score 0.5494):
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 27}
#         Has trained 174 of 3024 combinations so far
# Trained and Tested combination 175 of 3024, taking 0.01 seconds to get val score of 0.5312:
#                 {'tol': 0.1, 'reg_param': 0.0001, 'features': 25},
#             Current best combo with val score 0.5494:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 27}
# Trained and Tested combination 176 of 3024, taking 0.01 seconds to get val score of 0.5372:
#                 {'tol': 0.1, 'reg_param': 1e-05, 'features': 24},
#             Current best combo with val score 0.5494:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 27}
# Trained and Tested combination 177 of 3024, taking 0.01 seconds to get val score of 0.5419:
#                 {'tol': 0.1, 'reg_param': 1e-05, 'features': 26},
#             Current best combo with val score 0.5494:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 27}
# Trained and Tested combination 178 of 3024, taking 0.03 seconds to get val score of 0.5372:
#                 {'tol': 0.001, 'reg_param': 1e-05, 'features': 24},
#             Current best combo with val score 0.5494:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 27}
# Already Trained and Tested combination (val score of 0.5372):
#             {'tol': 0.1, 'reg_param': 1e-05, 'features': 24}
#             Current best combo (with val score 0.5494):
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 27}
#         Has trained 178 of 3024 combinations so far
# Trained and Tested combination 179 of 3024, taking 0.02 seconds to get val score of 0.5312:
#                 {'tol': 0.01, 'reg_param': 0.0001, 'features': 24},
#             Current best combo with val score 0.5494:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 27}
# Trained and Tested combination 180 of 3024, taking 0.02 seconds to get val score of 0.5341:
#                 {'tol': 0.01, 'reg_param': 1e-05, 'features': 23},
#             Current best combo with val score 0.5494:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 27}
# Already Trained and Tested combination (val score of 0.5373):
#             {'tol': 0.01, 'reg_param': 1e-05, 'features': 25}
#             Current best combo (with val score 0.5494):
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 27}
#         Has trained 180 of 3024 combinations so far
# Trained and Tested combination 181 of 3024, taking 0.01 seconds to get val score of 0.5419:
#                 {'tol': 0.001, 'reg_param': 1e-05, 'features': 26},
#             Current best combo with val score 0.5494:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 27}
# Already Trained and Tested combination (val score of 0.5419):
#             {'tol': 0.1, 'reg_param': 1e-05, 'features': 26}
#             Current best combo (with val score 0.5494):
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 27}
#         Has trained 181 of 3024 combinations so far
# Trained and Tested combination 182 of 3024, taking 0.02 seconds to get val score of 0.5333:
#                 {'tol': 0.01, 'reg_param': 0.0001, 'features': 26},
#             Current best combo with val score 0.5494:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 27}
# Already Trained and Tested combination (val score of 0.5373):
#             {'tol': 0.01, 'reg_param': 1e-05, 'features': 25}
#             Current best combo (with val score 0.5494):
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 27}
#         Has trained 182 of 3024 combinations so far
# Trained and Tested combination 183 of 3024, taking 0.01 seconds to get val score of 0.5494:
#                 {'tol': 0.01, 'reg_param': 1e-05, 'features': 27},
#             Current best combo with val score 0.5494:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 27}
# % Combos Checked Thus Far: 183 out of 3024 which is 6.051587%
# Cruising Coordrdinate 95 of 96
#
# Cruising Coordrdinate 96 of 96
#
# Cruise suspended due to suspicious case
# Guidance: round 6
#
# 	round 6 iteration:  0
#
# Already Trained and Tested combination (val score of 0.5373):
#             {'tol': 1, 'reg_param': 1e-05, 'features': 25}
#             Current best combo (with val score 0.5494):
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 27}
#         Has trained 183 of 3024 combinations so far
# Already Trained and Tested combination (val score of 0.5312):
#             {'tol': 10, 'reg_param': 0.0001, 'features': 25}
#             Current best combo (with val score 0.5494):
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 27}
#         Has trained 183 of 3024 combinations so far
# Already Trained and Tested combination (val score of 0.5372):
#             {'tol': 10, 'reg_param': 1e-05, 'features': 24}
#             Current best combo (with val score 0.5494):
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 27}
#         Has trained 183 of 3024 combinations so far
# Already Trained and Tested combination (val score of 0.5419):
#             {'tol': 10, 'reg_param': 1e-05, 'features': 26}
#             Current best combo (with val score 0.5494):
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 27}
#         Has trained 183 of 3024 combinations so far
# 	round 6 iteration:  1
#
# Trained and Tested combination 184 of 3024, taking 0.01 seconds to get val score of 0.5372:
#                 {'tol': 1, 'reg_param': 1e-05, 'features': 24},
#             Current best combo with val score 0.5494:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 27}
# Trained and Tested combination 185 of 3024, taking 0.01 seconds to get val score of 0.5312:
#                 {'tol': 10, 'reg_param': 0.0001, 'features': 24},
#             Current best combo with val score 0.5494:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 27}
# Trained and Tested combination 186 of 3024, taking 0.01 seconds to get val score of 0.5341:
#                 {'tol': 10, 'reg_param': 1e-05, 'features': 23},
#             Current best combo with val score 0.5494:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 27}
# Already Trained and Tested combination (val score of 0.5373):
#             {'tol': 10, 'reg_param': 1e-05, 'features': 25}
#             Current best combo (with val score 0.5494):
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 27}
#         Has trained 186 of 3024 combinations so far
# Already Trained and Tested combination (val score of 0.5419):
#             {'tol': 1, 'reg_param': 1e-05, 'features': 26}
#             Current best combo (with val score 0.5494):
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 27}
#         Has trained 186 of 3024 combinations so far
# Already Trained and Tested combination (val score of 0.5333):
#             {'tol': 10, 'reg_param': 0.0001, 'features': 26}
#             Current best combo (with val score 0.5494):
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 27}
#         Has trained 186 of 3024 combinations so far
# Already Trained and Tested combination (val score of 0.5373):
#             {'tol': 10, 'reg_param': 1e-05, 'features': 25}
#             Current best combo (with val score 0.5494):
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 27}
#         Has trained 186 of 3024 combinations so far
# Already Trained and Tested combination (val score of 0.5494):
#             {'tol': 10, 'reg_param': 1e-05, 'features': 27}
#             Current best combo (with val score 0.5494):
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 27}
#         Has trained 186 of 3024 combinations so far
# % Combos Checked Thus Far: 186 out of 3024 which is 6.150793999999999%
# FINAL STAGE: Begin final Guidance system
#
#
# Guidance: round FINAL
#
# 	round FINAL iteration:  0
#
# Already Trained and Tested combination (val score of 0.5494):
#             {'tol': 1, 'reg_param': 1e-05, 'features': 27}
#             Current best combo (with val score 0.5494):
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 27}
#         Has trained 186 of 3024 combinations so far
# Already Trained and Tested combination (val score of 0.5464):
#             {'tol': 10, 'reg_param': 0.0001, 'features': 27}
#             Current best combo (with val score 0.5494):
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 27}
#         Has trained 186 of 3024 combinations so far
# Already Trained and Tested combination (val score of 0.5419):
#             {'tol': 10, 'reg_param': 1e-05, 'features': 26}
#             Current best combo (with val score 0.5494):
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 27}
#         Has trained 186 of 3024 combinations so far
# Already Trained and Tested combination (val score of 0.4859):
#             {'tol': 10, 'reg_param': 1e-05, 'features': 28}
#             Current best combo (with val score 0.5494):
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 27}
#         Has trained 186 of 3024 combinations so far
# 	round FINAL iteration:  1
#
# Trained and Tested combination 187 of 3024, taking 0.02 seconds to get val score of 0.5494:
#                 {'tol': 0.1, 'reg_param': 1e-05, 'features': 27},
#             Current best combo with val score 0.5494:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 27}
# Already Trained and Tested combination (val score of 0.5494):
#             {'tol': 10, 'reg_param': 1e-05, 'features': 27}
#             Current best combo (with val score 0.5494):
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 27}
#         Has trained 187 of 3024 combinations so far
# Trained and Tested combination 188 of 3024, taking 0.02 seconds to get val score of 0.5464:
#                 {'tol': 1, 'reg_param': 0.0001, 'features': 27},
#             Current best combo with val score 0.5494:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 27}
# Already Trained and Tested combination (val score of 0.5419):
#             {'tol': 1, 'reg_param': 1e-05, 'features': 26}
#             Current best combo (with val score 0.5494):
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 27}
#         Has trained 188 of 3024 combinations so far
# Trained and Tested combination 189 of 3024, taking 0.01 seconds to get val score of 0.4859:
#                 {'tol': 1, 'reg_param': 1e-05, 'features': 28},
#             Current best combo with val score 0.5494:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 27}
# Already Trained and Tested combination (val score of 0.5464):
#             {'tol': 1, 'reg_param': 0.0001, 'features': 27}
#             Current best combo (with val score 0.5494):
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 27}
#         Has trained 189 of 3024 combinations so far
# Already Trained and Tested combination (val score of 0.5494):
#             {'tol': 10, 'reg_param': 1e-05, 'features': 27}
#             Current best combo (with val score 0.5494):
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 27}
#         Has trained 189 of 3024 combinations so far
# Trained and Tested combination 190 of 3024, taking 0.01 seconds to get val score of 0.5341:
#                 {'tol': 10, 'reg_param': 0.001, 'features': 27},
#             Current best combo with val score 0.5494:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 27}
# Already Trained and Tested combination (val score of 0.5333):
#             {'tol': 10, 'reg_param': 0.0001, 'features': 26}
#             Current best combo (with val score 0.5494):
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 27}
#         Has trained 190 of 3024 combinations so far
# Trained and Tested combination 191 of 3024, taking 0.02 seconds to get val score of 0.4772:
#                 {'tol': 10, 'reg_param': 0.0001, 'features': 28},
#             Current best combo with val score 0.5494:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 27}
# % Combos Checked Thus Far: 191 out of 3024 which is 6.3161380000000005%
# Max Val Score:
#  0.54937
# Max Val Score Std:
#  0.037495
# Best Combo Train Score:
#  0.625376
# Best Combo Train Score Std:
#  0.007194
# Max Combo Index:
#  (6, 0, 27) out of [7, 6, 72] (note best combo is 0-indexed)
# Max Combo Hyperparamer Combination:
#  {'tol': 10, 'reg_param': 1e-05, 'features': 27}
# Max Combo Features:
#  ('procedure_228130', 'procedure_225792', 'procedure_228125', 'lods_score', 'ventilation_used', 'procedure_226236', 'hospital_stay_duration', 'procedure_225469', 'procedure_224270', 'procedure_225446', 'procedure_225802', 'procedure_227712', 'procedure_229580', 'procedure_225451', 'admission_type_DIRECT EMER.', 'admission_type_DIRECT OBSERVATION', 'admission_type_ELECTIVE', 'admission_type_EU OBSERVATION', 'admission_type_EW EMER.', 'admission_type_OBSERVATION ADMIT', 'admission_type_URGENT', 'admission_type_SURGICAL SAME DAY ADMISSION', 'procedure_224385', 'procedure_224267', 'oasis_score', 'procedure_225470', 'procedure_224276', 'icu_stay_duration', 'marital_status_DIVORCED', 'marital_status_MARRIED', 'marital_status_SINGLE', 'marital_status_WIDOWED', 'marital_status_0', 'procedure_225432', 'gender_M', 'gender_F', 'procedure_225457', 'procedure_224275', 'item_51301', 'procedure_225400')
# % Combos Checked: 191 out of 3024 which is 6.3161380000000005%
