# %% [markdown]
# # Tuning Script

# %%
# Parameters subject to change in every script - involved in naming

MODEL = 'logrc'
PREPROCESSING = 'normalise'
TUNER = 'yangzhoub'
OPTIMISED_METRIC = 'f1'

# %% [markdown]
# ---

# %%
# detect whether this is a google environment

COLAB_ENVIRONMENT = False

try:
    from google.colab import drive
    drive.mount('/content/drive')
    COLAB_ENVIRONMENT = True
except:
    pass
# Out:
# Mounted at /content/drive

# %%
import sys
import os
import pickle

if COLAB_ENVIRONMENT:
    home_directory = './drive/MyDrive/LAB/COMP90089__GroupWork__Py/' # my home directory is stored in ./LAB of google drive
    if MODEL == 'ebr':
        # !pip install interpret==0.5.0
    elif MODEL == 'cbr':
        # !pip install catboost
    elif MODEL in ['tf', 'mlp']:
        # !pip install PyTorch2Sklearn
    # !pip install JXAutoML
else:
    home_directory = '../../'

from JXAutoML.YangZhouB_10CV import YangZhouB_10CV as Tuner

import pandas as pd
# Out:
# Requirement already satisfied: JXAutoML in /usr/local/lib/python3.10/dist-packages (0.4.4)

# %%
# Parameters that are same for every script

FOLDS = 10  # we have decided to do 10 fold validation

SEED = 42

TASK_TYPE = 'Classification'  # this task is a classification task

# we have decided to tune features as hp
TUNE_FEATURES_AS_HYPERPARAMETERS = True

# %% [markdown]
# ---

# %%
# model to use to tune
from sklearn.linear_model import LogisticRegression as clf

# what values to try for each hyperparameter
parameter_choices = {
    'C': (0.0001, 0.001, 0.01, 0.1, 1, 10),
    'max_iter': (50, 100, 200, 400, 800, 1600),
    'penalty': ('l1', 'l2'),
    'tol': (0.00001, 0.0001, 0.001, 0.01, 0.1, 1)
}

# what values to set non-tuneable parameters/hyperparameters
non_tunable_hyperparameters_dict = {
                                    'random_state': 42,
                                    'n_jobs': -1,
                                    'verbose': 0,
                                    'multi_class': 'ovr',
                                    'solver': 'liblinear'
                                    }

# %% [markdown]
# ---

# %% [markdown]
# Read in and Prepare Data

# %%
# Import data and store as lists

train_x_list = []
train_y_list = []
val_x_list = []
val_y_list = []

for i in range(FOLDS):
    train_data = pd.read_csv(
        f'{home_directory}data/curated/modelling/{PREPROCESSING}/train_{i}.csv')
    val_data = pd.read_csv(
        f'{home_directory}data/curated/modelling/{PREPROCESSING}/val_{i}.csv')

    # get the correct rows for X and y
    train_x = train_data.drop(
        ['mortality_status', 'subject_id', 'hadm_id', 'stay_id'], axis=1)
    train_y = train_data['mortality_status']
    val_x = val_data.drop(
        ['mortality_status', 'subject_id', 'hadm_id', 'stay_id'], axis=1)
    val_y = val_data['mortality_status']

    train_x_list.append(train_x)
    train_y_list.append(train_y)
    val_x_list.append(val_x)
    val_y_list.append(val_y)

# %%
# Import feature importance ordering

with open(f'{home_directory}models/xgb_feature_importance_ordering_{PREPROCESSING}.pickle', 'rb') as f:
    feature_importance_ordering = pickle.load(f)

# %% [markdown]
# Set parameters

# %%
# initialisation
tuner = Tuner()

print('---')

# define what model we are tuning
tuner.read_in_model(clf, TASK_TYPE, optimised_metric=OPTIMISED_METRIC)

print('---')

# read in the data for training and validation
tuner.read_in_data(train_x_list, train_y_list, val_x_list, val_y_list)

print('---')

# set what hp values to tune
tuner.set_hyperparameters(parameter_choices)
# WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

# set up hp values that need to be changed from default but NOT to be tuned
tuner.set_non_tuneable_hyperparameters(non_tunable_hyperparameters_dict)

print('---')

# set up feature importance ordering

if TUNE_FEATURES_AS_HYPERPARAMETERS:
    tuner.set_features(feature_importance_ordering)
    # WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

try:  # try to read in previous results to continue tuning ...
    tuner.read_in_tuning_result_df(
        f'{home_directory}models/tuning/{TUNER}_{MODEL}_{PREPROCESSING}.csv')
except:
    print('No previous tuning data read in')

print('---')

# set up where to save the tuning result csv
tuner.set_tuning_result_saving_address(
    f'{home_directory}models/tuning/{TUNER}_{MODEL}_{PREPROCESSING}.csv')

print('---')

# set up where to save the current best model
tuner.set_best_model_saving_address(
    f'{home_directory}models/tmp_models/{TUNER}_{MODEL}_{PREPROCESSING}')
# Out:
# YangZhouB Initialised
# ---
# Successfully read in model <class 'sklearn.linear_model._logistic.LogisticRegression'>, which is a Classification model optimising for f1
# ---
# Read in Train X data list
# Read in Train y data list
# Read in Val X data list
# Read in Val y data list
# ---
# Successfully recorded hyperparameter choices
# ---
# Successfully recorded non_tuneable_hyperparameter choices
# ---
# Successfully recorded tuneable feature combination choices and updated relevant internal structures
# ---
# No previous tuning data read in
# ---
# Successfully set tuning output address
# ---
# Successfully set best model output address

# %%
# ignore warnings

import warnings
warnings.filterwarnings("ignore")

# %%
# begin tuning ... (or continue training)

tuner.tune()
# Out:
# BEGIN TUNING
#
#
# STAGE ZERO: Tune all Cruise combinations
#
#
# Trained and Tested combination 1 of 31104, taking 0.01 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1e-05, 'features': 40},
#             Current best combo with val score 0.0:
#                     {'C': 0.0001, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1e-05, 'features': 40}
# Trained and Tested combination 2 of 31104, taking 0.01 seconds to get val score of 0.2933:
#                 {'C': 10, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1e-05, 'features': 0},
#             Current best combo with val score 0.2933:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1e-05, 'features': 0}
# Trained and Tested combination 3 of 31104, taking 0.11 seconds to get val score of 0.0166:
#                 {'C': 10, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1e-05, 'features': 45},
#             Current best combo with val score 0.2933:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1e-05, 'features': 0}
# Trained and Tested combination 4 of 31104, taking 0.01 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1, 'features': 35},
#             Current best combo with val score 0.2933:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1e-05, 'features': 0}
# Trained and Tested combination 5 of 31104, taking 0.01 seconds to get val score of 0.2647:
#                 {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1, 'features': 5},
#             Current best combo with val score 0.2933:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1e-05, 'features': 0}
# Trained and Tested combination 6 of 31104, taking 1.23 seconds to get val score of 0.1248:
#                 {'C': 10, 'max_iter': 50, 'penalty': 'l1', 'tol': 1e-05, 'features': 35},
#             Current best combo with val score 0.2933:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1e-05, 'features': 0}
# Trained and Tested combination 7 of 31104, taking 0.01 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'max_iter': 50, 'penalty': 'l2', 'tol': 1e-05, 'features': 20},
#             Current best combo with val score 0.2933:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1e-05, 'features': 0}
# Trained and Tested combination 8 of 31104, taking 0.01 seconds to get val score of 0.1843:
#                 {'C': 10, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1, 'features': 5},
#             Current best combo with val score 0.2933:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1e-05, 'features': 0}
# Trained and Tested combination 9 of 31104, taking 0.01 seconds to get val score of 0.359:
#                 {'C': 10, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1, 'features': 10},
#             Current best combo with val score 0.359:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1, 'features': 10}
# Trained and Tested combination 10 of 31104, taking 1.98 seconds to get val score of 0.0456:
#                 {'C': 10, 'max_iter': 50, 'penalty': 'l1', 'tol': 1e-05, 'features': 63},
#             Current best combo with val score 0.359:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1, 'features': 10}
# Trained and Tested combination 11 of 31104, taking 0.03 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1e-05, 'features': 67},
#             Current best combo with val score 0.359:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1, 'features': 10}
# Trained and Tested combination 12 of 31104, taking 0.02 seconds to get val score of 0.0262:
#                 {'C': 10, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 45},
#             Current best combo with val score 0.359:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1, 'features': 10}
# Trained and Tested combination 13 of 31104, taking 0.01 seconds to get val score of 0.2748:
#                 {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1e-05, 'features': 5},
#             Current best combo with val score 0.359:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1, 'features': 10}
# Trained and Tested combination 14 of 31104, taking 0.02 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1, 'features': 59},
#             Current best combo with val score 0.359:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1, 'features': 10}
# Trained and Tested combination 15 of 31104, taking 0.01 seconds to get val score of 0.1224:
#                 {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1, 'features': 30},
#             Current best combo with val score 0.359:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1, 'features': 10}
# Trained and Tested combination 16 of 31104, taking 0.02 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1, 'features': 50},
#             Current best combo with val score 0.359:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1, 'features': 10}
# Trained and Tested combination 17 of 31104, taking 0.02 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'max_iter': 50, 'penalty': 'l2', 'tol': 1e-05, 'features': 59},
#             Current best combo with val score 0.359:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1, 'features': 10}
# Trained and Tested combination 18 of 31104, taking 0.07 seconds to get val score of 0.122:
#                 {'C': 10, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1e-05, 'features': 40},
#             Current best combo with val score 0.359:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1, 'features': 10}
# Trained and Tested combination 19 of 31104, taking 0.12 seconds to get val score of 0.0456:
#                 {'C': 10, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1e-05, 'features': 59},
#             Current best combo with val score 0.359:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1, 'features': 10}
# Trained and Tested combination 20 of 31104, taking 0.01 seconds to get val score of 0.2741:
#                 {'C': 10, 'max_iter': 50, 'penalty': 'l1', 'tol': 1, 'features': 10},
#             Current best combo with val score 0.359:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1, 'features': 10}
# Trained and Tested combination 21 of 31104, taking 0.02 seconds to get val score of 0.0:
#                 {'C': 10, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1, 'features': 71},
#             Current best combo with val score 0.359:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1, 'features': 10}
# Trained and Tested combination 22 of 31104, taking 0.02 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1e-05, 'features': 55},
#             Current best combo with val score 0.359:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1, 'features': 10}
# Trained and Tested combination 23 of 31104, taking 0.01 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 10},
#             Current best combo with val score 0.359:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1, 'features': 10}
# Trained and Tested combination 24 of 31104, taking 0.02 seconds to get val score of 0.1322:
#                 {'C': 10, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1, 'features': 35},
#             Current best combo with val score 0.359:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1, 'features': 10}
# Trained and Tested combination 25 of 31104, taking 0.02 seconds to get val score of 0.0:
#                 {'C': 10, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1, 'features': 55},
#             Current best combo with val score 0.359:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1, 'features': 10}
# Trained and Tested combination 26 of 31104, taking 0.02 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 45},
#             Current best combo with val score 0.359:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1, 'features': 10}
# Trained and Tested combination 27 of 31104, taking 0.01 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1, 'features': 

#             Current best combo (with val score 0.3726):
#                     {'C': 10, 'max_iter': 50, 'penalty': 'l2', 'tol': 1e-05, 'features': 14}
#         Has trained 391 of 31104 combinations so far
# Already Trained and Tested combination (val score of 0.3702):
#             {'C': 10, 'max_iter': 50, 'penalty': 'l2', 'tol': 0.0001, 'features': 15}
#             Current best combo (with val score 0.3726):
#                     {'C': 10, 'max_iter': 50, 'penalty': 'l2', 'tol': 1e-05, 'features': 14}
#         Has trained 391 of 31104 combinations so far
# Already Trained and Tested combination (val score of 0.3683):
#             {'C': 10, 'max_iter': 50, 'penalty': 'l1', 'tol': 1e-05, 'features': 15}
#             Current best combo (with val score 0.3726):
#                     {'C': 10, 'max_iter': 50, 'penalty': 'l2', 'tol': 1e-05, 'features': 14}
#         Has trained 391 of 31104 combinations so far
# Trained and Tested combination 392 of 31104, taking 0.1 seconds to get val score of 0.3683:
#                 {'C': 10, 'max_iter': 50, 'penalty': 'l1', 'tol': 0.001, 'features': 15},
#             Current best combo with val score 0.3726:
#                     {'C': 10, 'max_iter': 50, 'penalty': 'l2', 'tol': 1e-05, 'features': 14}
# Trained and Tested combination 393 of 31104, taking 0.14 seconds to get val score of 0.3726:
#                 {'C': 10, 'max_iter': 50, 'penalty': 'l1', 'tol': 0.0001, 'features': 14},
#             Current best combo with val score 0.3726:
#                     {'C': 10, 'max_iter': 50, 'penalty': 'l2', 'tol': 1e-05, 'features': 14}
# Trained and Tested combination 394 of 31104, taking 0.14 seconds to get val score of 0.3688:
#                 {'C': 10, 'max_iter': 50, 'penalty': 'l1', 'tol': 0.0001, 'features': 16},
#             Current best combo with val score 0.3726:
#                     {'C': 10, 'max_iter': 50, 'penalty': 'l2', 'tol': 1e-05, 'features': 14}
# Trained and Tested combination 395 of 31104, taking 0.05 seconds to get val score of 0.3554:
#                 {'C': 1, 'max_iter': 50, 'penalty': 'l1', 'tol': 1e-05, 'features': 14},
#             Current best combo with val score 0.3726:
#                     {'C': 10, 'max_iter': 50, 'penalty': 'l2', 'tol': 1e-05, 'features': 14}
# Already Trained and Tested combination (val score of 0.3726):
#             {'C': 10, 'max_iter': 100, 'penalty': 'l1', 'tol': 1e-05, 'features': 14}
#             Current best combo (with val score 0.3726):
#                     {'C': 10, 'max_iter': 50, 'penalty': 'l2', 'tol': 1e-05, 'features': 14}
#         Has trained 395 of 31104 combinations so far
# Already Trained and Tested combination (val score of 0.3726):
#             {'C': 10, 'max_iter': 50, 'penalty': 'l2', 'tol': 1e-05, 'features': 14}
#             Current best combo (with val score 0.3726):
#                     {'C': 10, 'max_iter': 50, 'penalty': 'l2', 'tol': 1e-05, 'features': 14}
#         Has trained 395 of 31104 combinations so far
# Already Trained and Tested combination (val score of 0.3726):
#             {'C': 10, 'max_iter': 50, 'penalty': 'l1', 'tol': 0.0001, 'features': 14}
#             Current best combo (with val score 0.3726):
#                     {'C': 10, 'max_iter': 50, 'penalty': 'l2', 'tol': 1e-05, 'features': 14}
#         Has trained 395 of 31104 combinations so far
# Trained and Tested combination 396 of 31104, taking 0.02 seconds to get val score of 0.3649:
#                 {'C': 10, 'max_iter': 50, 'penalty': 'l1', 'tol': 1e-05, 'features': 13},
#             Current best combo with val score 0.3726:
#                     {'C': 10, 'max_iter': 50, 'penalty': 'l2', 'tol': 1e-05, 'features': 14}
# Already Trained and Tested combination (val score of 0.3683):
#             {'C': 10, 'max_iter': 50, 'penalty': 'l1', 'tol': 1e-05, 'features': 15}
#             Current best combo (with val score 0.3726):
#                     {'C': 10, 'max_iter': 50, 'penalty': 'l2', 'tol': 1e-05, 'features': 14}
#         Has trained 396 of 31104 combinations so far
# Trained and Tested combination 397 of 31104, taking 0.06 seconds to get val score of 0.3543:
#                 {'C': 1, 'max_iter': 50, 'penalty': 'l1', 'tol': 1e-05, 'features': 16},
#             Current best combo with val score 0.3726:
#                     {'C': 10, 'max_iter': 50, 'penalty': 'l2', 'tol': 1e-05, 'features': 14}
# Already Trained and Tested combination (val score of 0.3688):
#             {'C': 10, 'max_iter': 100, 'penalty': 'l1', 'tol': 1e-05, 'features': 16}
#             Current best combo (with val score 0.3726):
#                     {'C': 10, 'max_iter': 50, 'penalty': 'l2', 'tol': 1e-05, 'features': 14}
#         Has trained 397 of 31104 combinations so far
# Already Trained and Tested combination (val score of 0.3688):
#             {'C': 10, 'max_iter': 50, 'penalty': 'l2', 'tol': 1e-05, 'features': 16}
#             Current best combo (with val score 0.3726):
#                     {'C': 10, 'max_iter': 50, 'penalty': 'l2', 'tol': 1e-05, 'features': 14}
#         Has trained 397 of 31104 combinations so far
# Already Trained and Tested combination (val score of 0.3688):
#             {'C': 10, 'max_iter': 50, 'penalty': 'l1', 'tol': 0.0001, 'features': 16}
#             Current best combo (with val score 0.3726):
#                     {'C': 10, 'max_iter': 50, 'penalty': 'l2', 'tol': 1e-05, 'features': 14}
#         Has trained 397 of 31104 combinations so far
# Already Trained and Tested combination (val score of 0.3683):
#             {'C': 10, 'max_iter': 50, 'penalty': 'l1', 'tol': 1e-05, 'features': 15}
#             Current best combo (with val score 0.3726):
#                     {'C': 10, 'max_iter': 50, 'penalty': 'l2', 'tol': 1e-05, 'features': 14}
#         Has trained 397 of 31104 combinations so far
# Trained and Tested combination 398 of 31104, taking 0.28 seconds to get val score of 0.2697:
#                 {'C': 10, 'max_iter': 50, 'penalty': 'l1', 'tol': 1e-05, 'features': 17},
#             Current best combo with val score 0.3726:
#                     {'C': 10, 'max_iter': 50, 'penalty': 'l2', 'tol': 1e-05, 'features': 14}
# % Combos Checked Thus Far: 398 out of 31104 which is 1.2795779999999999%
# Cruising Coordrdinate 256 of 256
#
# Cruise suspended due to suspicious case
# Guidance: round 8
#
# 	round 8 iteration:  0
#
# % Combos Checked Thus Far: 398 out of 31104 which is 1.2795779999999999%
# FINAL STAGE: Begin final Guidance system
#
#
# Guidance: round FINAL
#
# 	round FINAL iteration:  0
#
# Already Trained and Tested combination (val score of 0.3509):
#             {'C': 1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1e-05, 'features': 14}
#             Current best combo (with val score 0.3726):
#                     {'C': 10, 'max_iter': 50, 'penalty': 'l2', 'tol': 1e-05, 'features': 14}
#         Has trained 398 of 31104 combinations so far
# Already Trained and Tested combination (val score of 0.3726):
#             {'C': 10, 'max_iter': 100, 'penalty': 'l2', 'tol': 1e-05, 'features': 14}
#             Current best combo (with val score 0.3726):
#                     {'C': 10, 'max_iter': 50, 'penalty': 'l2', 'tol': 1e-05, 'features': 14}
#         Has trained 398 of 31104 combinations so far
# Already Trained and Tested combination (val score of 0.3726):
#             {'C': 10, 'max_iter': 50, 'penalty': 'l1', 'tol': 1e-05, 'features': 14}
#             Current best combo (with val score 0.3726):
#                     {'C': 10, 'max_iter': 50, 'penalty': 'l2', 'tol': 1e-05, 'features': 14}
#         Has trained 398 of 31104 combinations so far
# Already Trained and Tested combination (val score of 0.3726):
#             {'C': 10, 'max_iter': 50, 'penalty': 'l2', 'tol': 0.0001, 'features': 14}
#             Current best combo (with val score 0.3726):
#                     {'C': 10, 'max_iter': 50, 'penalty': 'l2', 'tol': 1e-05, 'features': 14}
#         Has trained 398 of 31104 combinations so far
# Already Trained and Tested combination (val score of 0.3649):
#             {'C': 10, 'max_iter': 50, 'penalty': 'l2', 'tol': 1e-05, 'features': 13}
#             Current best combo (with val score 0.3726):
#                     {'C': 10, 'max_iter': 50, 'penalty': 'l2', 'tol': 1e-05, 'features': 14}
#         Has trained 398 of 31104 combinations so far
# Already Trained and Tested combination (val score of 0.3702):
#             {'C': 10, 'max_iter': 50, 'penalty': 'l2', 'tol': 1e-05, 'features': 15}
#             Current best combo (with val score 0.3726):
#                     {'C': 10, 'max_iter': 50, 'penalty': 'l2', 'tol': 1e-05, 'features': 14}
#         Has trained 398 of 31104 combinations so far
# 	round FINAL iteration:  1
#
# Trained and Tested combination 399 of 31104, taking 0.02 seconds to get val score of 0.3509:
#                 {'C': 1, 'max_iter': 100, 'penalty': 'l2', 'tol': 1e-05, 'features': 14},
#             Current best combo with val score 0.3726:
#                     {'C': 10, 'max_iter': 50, 'penalty': 'l2', 'tol': 1e-05, 'features': 14}
# Already Trained and Tested combination (val score of 0.3726):
#             {'C': 10, 'max_iter': 50, 'penalty': 'l2', 'tol': 1e-05, 'features': 14}
#             Current best combo (with val score 0.3726):
#                     {'C': 10, 'max_iter': 50, 'penalty': 'l2', 'tol': 1e-05, 'features': 14}
#         Has trained 399 of 31104 combinations so far
# Trained and Tested combination 400 of 31104, taking 0.02 seconds to get val score of 0.3726:
#                 {'C': 10, 'max_iter': 200, 'penalty': 'l2', 'tol': 1e-05, 'features': 14},
#             Current best combo with val score 0.3726:
#                     {'C': 10, 'max_iter': 50, 'penalty': 'l2', 'tol': 1e-05, 'features': 14}
# Already Trained and Tested combination (val score of 0.3726):
#             {'C': 10, 'max_iter': 100, 'penalty': 'l1', 'tol': 1e-05, 'features': 14}
#             Current best combo (with val score 0.3726):
#                     {'C': 10, 'max_iter': 50, 'penalty': 'l2', 'tol': 1e-05, 'features': 14}
#         Has trained 400 of 31104 combinations so far
# Trained and Tested combination 401 of 31104, taking 0.02 seconds to get val score of 0.3726:
#                 {'C': 10, 'max_iter': 100, 'penalty': 'l2', 'tol': 0.0001, 'features': 14},
#             Current best combo with val score 0.3726:
#                     {'C': 10, 'max_iter': 50, 'penalty': 'l2', 'tol': 1e-05, 'features': 14}
# Trained and Tested combination 402 of 31104, taking 0.02 seconds to get val score of 0.3649:
#                 {'C': 10, 'max_iter': 100, 'penalty': 'l2', 'tol': 1e-05, 'features': 13},
#             Current best combo with val score 0.3726:
#                     {'C': 10, 'max_iter': 50, 'penalty': 'l2', 'tol': 1e-05, 'features': 14}
# Already Trained and Tested combination (val score of 0.3702):
#             {'C': 10, 'max_iter': 100, 'penalty': 'l2', 'tol': 1e-05, 'features': 15}
#             Current best combo (with val score 0.3726):
#                     {'C': 10, 'max_iter': 50, 'penalty': 'l2', 'tol': 1e-05, 'features': 14}
#         Has trained 402 of 31104 combinations so far
# Trained and Tested combination 403 of 31104, taking 0.01 seconds to get val score of 0.3509:
#                 {'C': 1, 'max_iter': 50, 'penalty': 'l2', 'tol': 0.0001, 'features': 14},
#             Current best combo with val score 0.3726:
#                     {'C': 10, 'max_iter': 50, 'penalty': 'l2', 'tol': 1e-05, 'features': 14}
# Already Trained and Tested combination (val score of 0.3726):
#             {'C': 10, 'max_iter': 100, 'penalty': 'l2', 'tol': 0.0001, 'features': 14}
#             Current best combo (with val score 0.3726):
#                     {'C': 10, 'max_iter': 50, 'penalty': 'l2', 'tol': 1e-05, 'features': 14}
#         Has trained 403 of 31104 combinations so far
# Already Trained and Tested combination (val score of 0.3726):
#             {'C': 10, 'max_iter': 50, 'penalty': 'l1', 'tol': 0.0001, 'features': 14}
#             Current best combo (with val score 0.3726):
#                     {'C': 10, 'max_iter': 50, 'penalty': 'l2', 'tol': 1e-05, 'features': 14}
#         Has trained 403 of 31104 combinations so far
# Already Trained and Tested combination (val score of 0.3726):
#             {'C': 10, 'max_iter': 50, 'penalty': 'l2', 'tol': 1e-05, 'features': 14}
#             Current best combo (with val score 0.3726):
#                     {'C': 10, 'max_iter': 50, 'penalty': 'l2', 'tol': 1e-05, 'features': 14}
#         Has trained 403 of 31104 combinations so far
# Trained and Tested combination 404 of 31104, taking 0.02 seconds to get val score of 0.3726:
#                 {'C': 10, 'max_iter': 50, 'penalty': 'l2', 'tol': 0.001, 'features': 14},
#             Current best combo with val score 0.3726:
#                     {'C': 10, 'max_iter': 50, 'penalty': 'l2', 'tol': 1e-05, 'features': 14}
# Trained and Tested combination 405 of 31104, taking 0.01 seconds to get val score of 0.3649:
#                 {'C': 10, 'max_iter': 50, 'penalty': 'l2', 'tol': 0.0001, 'features': 13},
#             Current best combo with val score 0.3726:
#                     {'C': 10, 'max_iter': 50, 'penalty': 'l2', 'tol': 1e-05, 'features': 14}
# Already Trained and Tested combination (val score of 0.3702):
#             {'C': 10, 'max_iter': 50, 'penalty': 'l2', 'tol': 0.0001, 'features': 15}
#             Current best combo (with val score 0.3726):
#                     {'C': 10, 'max_iter': 50, 'penalty': 'l2', 'tol': 1e-05, 'features': 14}
#         Has trained 405 of 31104 combinations so far
# % Combos Checked Thus Far: 405 out of 31104 which is 1.302083%
# Max Val Score:
#  0.372616
# Max Val Score Std:
#  0.029379
# Best Combo Train Score:
#  0.574963
# Best Combo Train Score Std:
#  0.008913
# Max Combo Index:
#  (5, 0, 1, 0, 14) out of [6, 6, 2, 6, 72] (note best combo is 0-indexed)
# Max Combo Hyperparamer Combination:
#  {'C': 10, 'max_iter': 50, 'penalty': 'l2', 'tol': 1e-05, 'features': 14}
# Max Combo Features:
#  ('procedure_228130', 'procedure_225792', 'procedure_228125', 'lods_score', 'ventilation_used', 'procedure_226236', 'hospital_stay_duration', 'procedure_225469', 'procedure_224270', 'procedure_225446', 'procedure_225802', 'procedure_227712', 'procedure_229580', 'procedure_225451', 'admission_type_DIRECT EMER.', 'admission_type_DIRECT OBSERVATION', 'admission_type_ELECTIVE', 'admission_type_EU OBSERVATION', 'admission_type_EW EMER.', 'admission_type_OBSERVATION ADMIT', 'admission_type_URGENT', 'admission_type_SURGICAL SAME DAY ADMISSION')
# % Combos Checked: 405 out of 31104 which is 1.302083%
