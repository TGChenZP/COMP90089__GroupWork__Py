# %% [markdown]
# # Tuning Script

# %%
# Parameters subject to change in every script - involved in naming

MODEL = 'logrc'
PREPROCESSING = 'normalise'
TUNER = 'yangzhoub'
OPTIMISED_METRIC = 'f1'

# %% [markdown]
# ---

# %%
# detect whether this is a google environment

COLAB_ENVIRONMENT = False

try:
    from google.colab import drive
    drive.mount('/content/drive')
    COLAB_ENVIRONMENT = True
except:
    pass
# Out:
# Mounted at /content/drive

# %%
import sys
import os
import pickle

if COLAB_ENVIRONMENT:
    home_directory = './drive/MyDrive/LAB/COMP90089__GroupWork__Py/' # my home directory is stored in ./LAB of google drive
    if MODEL == 'ebr':
        # !pip install interpret==0.5.0
    elif MODEL == 'cbr':
        # !pip install catboost
    elif MODEL in ['tf', 'mlp']:
        # !pip install PyTorch2Sklearn
    # !pip install JXAutoML
else:
    home_directory = '../../'

from JXAutoML.YangZhouB_10CV import YangZhouB_10CV as Tuner

import pandas as pd
# Out:
# Collecting JXAutoML
#   Downloading JXAutoML-0.4.4-py3-none-any.whl.metadata (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.2/67.2 kB 1.8 MB/s eta 0:00:00
# Downloading JXAutoML-0.4.4-py3-none-any.whl (52 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.1/52.1 kB 2.9 MB/s eta 0:00:00
# Installing collected packages: JXAutoML
# Successfully installed JXAutoML-0.4.4

# %%
# Parameters that are same for every script

FOLDS = 10  # we have decided to do 10 fold validation

SEED = 42

TASK_TYPE = 'Classification'  # this task is a classification task

# we have decided to tune features as hp
TUNE_FEATURES_AS_HYPERPARAMETERS = True

# %% [markdown]
# ---

# %%
# model to use to tune
from sklearn.linear_model import LogisticRegression as clf

# what values to try for each hyperparameter
parameter_choices = {
    'C': (0.0001, 0.001, 0.01, 0.1, 1, 10),
    'max_iter': (50, 100, 200, 400, 800, 1600),
    'penalty': ('l1', 'l2'),
    'tol': (0.00001, 0.0001, 0.001, 0.01, 0.1, 1)
}

# what values to set non-tuneable parameters/hyperparameters
non_tunable_hyperparameters_dict = {
                                    'random_state': 42,
                                    'n_jobs': -1,
                                    'verbose': 0,
                                    'multi_class': 'ovr',
                                    'solver': 'liblinear'
                                    }

# %% [markdown]
# ---

# %% [markdown]
# Read in and Prepare Data

# %%
# Import data and store as lists

train_x_list = []
train_y_list = []
val_x_list = []
val_y_list = []

for i in range(FOLDS):
    train_data = pd.read_csv(
        f'{home_directory}data/curated/modelling/{PREPROCESSING}/train_{i}.csv')
    val_data = pd.read_csv(
        f'{home_directory}data/curated/modelling/{PREPROCESSING}/val_{i}.csv')

    # get the correct rows for X and y
    train_x = train_data.drop(
        ['mortality_status', 'subject_id', 'hadm_id', 'stay_id'], axis=1)
    train_y = train_data['mortality_status']
    val_x = val_data.drop(
        ['mortality_status', 'subject_id', 'hadm_id', 'stay_id'], axis=1)
    val_y = val_data['mortality_status']

    train_x_list.append(train_x)
    train_y_list.append(train_y)
    val_x_list.append(val_x)
    val_y_list.append(val_y)

# %%
# Import feature importance ordering

with open(f'{home_directory}models/xgb_feature_importance_ordering_{PREPROCESSING}.pickle', 'rb') as f:
    feature_importance_ordering = pickle.load(f)

# %% [markdown]
# Set parameters

# %%
# initialisation
tuner = Tuner()

print('---')

# define what model we are tuning
tuner.read_in_model(clf, TASK_TYPE, optimised_metric=OPTIMISED_METRIC)

print('---')

# read in the data for training and validation
tuner.read_in_data(train_x_list, train_y_list, val_x_list, val_y_list)

print('---')

# set what hp values to tune
tuner.set_hyperparameters(parameter_choices)
# WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

# set up hp values that need to be changed from default but NOT to be tuned
tuner.set_non_tuneable_hyperparameters(non_tunable_hyperparameters_dict)

print('---')

# set up feature importance ordering

if TUNE_FEATURES_AS_HYPERPARAMETERS:
    tuner.set_features(feature_importance_ordering)
    # WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

try:  # try to read in previous results to continue tuning ...
    tuner.read_in_tuning_result_df(
        f'{home_directory}models/tuning/{TUNER}_{MODEL}_{PREPROCESSING}.csv')
except:
    print('No previous tuning data read in')

print('---')

# set up where to save the tuning result csv
tuner.set_tuning_result_saving_address(
    f'{home_directory}models/tuning/{TUNER}_{MODEL}_{PREPROCESSING}.csv')

print('---')

# set up where to save the current best model
tuner.set_best_model_saving_address(
    f'{home_directory}models/tmp_models/{TUNER}_{MODEL}_{PREPROCESSING}')
# Out:
# YangZhouB Initialised
# ---
# Successfully read in model <class 'sklearn.linear_model._logistic.LogisticRegression'>, which is a Classification model optimising for f1
# ---
# Read in Train X data list
# Read in Train y data list
# Read in Val X data list
# Read in Val y data list
# ---
# Successfully recorded hyperparameter choices
# ---
# Successfully recorded non_tuneable_hyperparameter choices
# ---
# Successfully recorded tuneable feature combination choices and updated relevant internal structures
# ---
# No previous tuning data read in
# ---
# Successfully set tuning output address
# ---
# Successfully set best model output address

# %%
# ignore warnings

import warnings
warnings.filterwarnings("ignore")

# %%
# begin tuning ... (or continue training)

tuner.tune()
# Out:
# BEGIN TUNING
#
#
# STAGE ZERO: Tune all Cruise combinations
#
#
# Trained and Tested combination 1 of 22032, taking 0.01 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'max_iter': 50, 'penalty': 'l1', 'tol': 1, 'features': 40},
#             Current best combo with val score 0.0:
#                     {'C': 0.0001, 'max_iter': 50, 'penalty': 'l1', 'tol': 1, 'features': 40}
# Trained and Tested combination 2 of 22032, taking 0.05 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1e-05, 'features': 25},
#             Current best combo with val score 0.0:
#                     {'C': 0.0001, 'max_iter': 50, 'penalty': 'l1', 'tol': 1, 'features': 40}
# Trained and Tested combination 3 of 22032, taking 0.37 seconds to get val score of 0.0099:
#                 {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1e-05, 'features': 15},
#             Current best combo with val score 0.0099:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1e-05, 'features': 15}
# Trained and Tested combination 4 of 22032, taking 0.01 seconds to get val score of 0.0:
#                 {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1, 'features': 0},
#             Current best combo with val score 0.0099:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1e-05, 'features': 15}
# Trained and Tested combination 5 of 22032, taking 0.02 seconds to get val score of 0.0291:
#                 {'C': 10, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1, 'features': 10},
#             Current best combo with val score 0.0291:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1, 'features': 10}
# Trained and Tested combination 6 of 22032, taking 0.01 seconds to get val score of 0.0:
#                 {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1e-05, 'features': 0},
#             Current best combo with val score 0.0291:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1, 'features': 10}
# Trained and Tested combination 7 of 22032, taking 0.01 seconds to get val score of 0.0:
#                 {'C': 10, 'max_iter': 50, 'penalty': 'l1', 'tol': 1, 'features': 25},
#             Current best combo with val score 0.0291:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1, 'features': 10}
# Trained and Tested combination 8 of 22032, taking 0.01 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1e-05, 'features': 10},
#             Current best combo with val score 0.0291:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1, 'features': 10}
# Trained and Tested combination 9 of 22032, taking 0.03 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'max_iter': 50, 'penalty': 'l1', 'tol': 1e-05, 'features': 40},
#             Current best combo with val score 0.0291:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1, 'features': 10}
# Trained and Tested combination 10 of 22032, taking 0.02 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'max_iter': 50, 'penalty': 'l1', 'tol': 1e-05, 'features': 10},
#             Current best combo with val score 0.0291:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1, 'features': 10}
# Trained and Tested combination 11 of 22032, taking 0.02 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1, 'features': 10},
#             Current best combo with val score 0.0291:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1, 'features': 10}
# Trained and Tested combination 12 of 22032, taking 0.0 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 0},
#             Current best combo with val score 0.0291:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1, 'features': 10}
# Trained and Tested combination 13 of 22032, taking 0.12 seconds to get val score of 0.0:
#                 {'C': 10, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1e-05, 'features': 45},
#             Current best combo with val score 0.0291:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1, 'features': 10}
# Trained and Tested combination 14 of 22032, taking 0.02 seconds to get val score of 0.0:
#                 {'C': 10, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 45},
#             Current best combo with val score 0.0291:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1, 'features': 10}
# Trained and Tested combination 15 of 22032, taking 0.01 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1e-05, 'features': 45},
#             Current best combo with val score 0.0291:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1, 'features': 10}
# Trained and Tested combination 16 of 22032, taking 0.01 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1e-05, 'features': 35},
#             Current best combo with val score 0.0291:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1, 'features': 10}
# Trained and Tested combination 17 of 22032, taking 0.01 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1, 'features': 35},
#             Current best combo with val score 0.0291:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1, 'features': 10}
# Trained and Tested combination 18 of 22032, taking 0.01 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'max_iter': 50, 'penalty': 'l1', 'tol': 1, 'features': 10},
#             Current best combo with val score 0.0291:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1, 'features': 10}
# Trained and Tested combination 19 of 22032, taking 0.81 seconds to get val score of 0.0:
#                 {'C': 10, 'max_iter': 50, 'penalty': 'l1', 'tol': 1e-05, 'features': 25},
#             Current best combo with val score 0.0291:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1, 'features': 10}
# Trained and Tested combination 20 of 22032, taking 0.01 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'max_iter': 50, 'penalty': 'l1', 'tol': 1, 'features': 30},
#             Current best combo with val score 0.0291:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1, 'features': 10}
# Trained and Tested combination 21 of 22032, taking 0.02 seconds to get val score of 0.0:
#                 {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1, 'features': 45},
#             Current best combo with val score 0.0291:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1, 'features': 10}
# Trained and Tested combination 22 of 22032, taking 0.0 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1, 'features': 0},
#             Current best combo with val score 0.0291:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1, 'features': 10}
# Trained and Tested combination 23 of 22032, taking 0.0 seconds to get val score of 0.0:
#                 {'C': 10, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1e-05, 'features': 0},
#             Current best combo with val score 0.0291:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1, 'features': 10}
# Trained and Tested combination 24 of 22032, taking 0.0 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'max_iter': 50, 'penalty': 'l1', 'tol': 1, 'features': 0},
#             Current best combo with val score 0.0291:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1, 'features': 10}
# Trained and Tested combination 25 of 22032, taking 0.02 seconds to get val score of 0.0:
#                 {'C': 10, 'max_iter': 50, 'penalty': 'l1', 'tol': 1, 'features': 50},
#             Current best combo with val score 0.0291:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1, 'features': 10}
# Trained and Tested combination 26 of 22032, taking 0.0 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1e-05, 'features': 0},
#             Current best combo with val score 0.0291:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1, 'features': 10}
# Trained and Tested combination 27 of 22032, taking 0.24 seconds to get val score of 0.0099:
#                 {'C': 10, 'max_iter': 50, 'penalty': 'l1', 'tol': 1e-05, 'features': 15},
#             Current best combo with val score 0.0291:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1, 'features': 10}
# Trained and Tested combination 28 of 22032, taking 0.01 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1e-05, 'features': 30},
#             Current best combo with val score 0.0291:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1, 'features': 10}
# Trained and Tested combination 29 of 22032, taking 0.01 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1, 'features': 25},
#             Current best combo with val score 0.0291:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1, 'features': 10}
# Trained and Tested combination 30 of 22032, taking 0.01 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1, 'features': 25},
#             Current best combo with val score 0.0291:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1, 'features': 10}
# Trained and Tested combination 31 of 22032, taking 0.03 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1, 'features': 45},
#             Current best combo with val score 0.0291:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1, 'features': 10}
# Trained and Tested combination 32 of 22032, taking 0.03 seconds to get val score of 0.0:
#                 {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1, 'features': 25},
#             Current best combo with val score 0.0291:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1, 'features': 10}
# Trained and Tested combination 33 of 22032, taking 0.01 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1e-05, 'features': 0},
#             Current best combo with val score 0.0291:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1, 'features': 10}
# Trained and Tested combination 34 of 22032, taking 0.05 seconds to get val score of 0.0163:
#                 {'C': 10, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1e-05, 'features': 20},
#             Current best combo with val score 0.0291:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1, 'features': 10}
# Trained and Tested combination 35 of 22032, taking 0.08 seconds to get val score of 0.0:
#                 {'C': 10, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1e-05, 'features': 30},
#             Current best combo with val score 0.0291:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1, 'features': 10}
# Trained and Tested combination 36 of 22032, taking 0.01 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1e-05, 'features': 10},
#             Current best combo with val score 0.0291:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1, 'features': 10}
# Trained and Tested combination 37 of 22032, taking 1.09 seconds to get val score of 0.0196:
#                 {'C': 10, 'max_iter': 50, 'penalty': 'l1', 'tol': 1e-05, 'features': 20},
#             Current best combo with val score 0.0291:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1, 'features': 10}
# Trained and Tested combination 38 of 22032, taking 0.02 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1e-05, 'features': 15},
#             Current best combo with val score 0.0291:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1, 'features': 10}
# Trained and Tested combination 39 of 22032, taking 0.05 seconds to get val score of 0.0163:
#                 {'C': 10, 'max_iter': 50, 'penalty': 'l2', 'tol': 1e-05, 'features': 20},
#             Current best combo with val score 0.0291:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1, 'features': 10}
# Trained and Tested combination 40 of 22032, taking 0.02 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1e-05, 'features': 35},
#             Current best combo with val score 0.0291:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1, 'features': 10}
# Trained and Tested combination 41 of 22032, taking 0.01 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1, 'features': 20},
#             Current best combo with val score 0.0291:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1, 'features': 10}
# Trained and Tested combination 42 of 22032, taking 1.19 seconds to get val score of 0.0:
#                 {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1e-05, 'features': 25},
#             Current best combo with val score 0.0291:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1, 'features': 10}
# Trained and Tested combination 43 of 22032, taking 0.14 seconds to get val score of 0.0:
#                 {'C': 10, 'max_iter': 50, 'penalty': 'l2', 'tol': 1e-05, 'features': 40},
#             Current best combo with val score 0.0291:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1, 'features': 10}
# Trained and Tested combination 44 of 22032, taking 0.01 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'max_iter': 50, 'penalty': 'l1', 'tol': 1e-05, 'features': 15},
#             Current best combo with val score 0.0291:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1, 'features': 10}
# Trained and Tested combination 45 of 22032, taking 0.02 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'max_iter': 50, 'penalty': 'l2', 'tol': 1e-05, 'features': 50},
#             Current best combo with val score 0.0291:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1, 'features': 10}
# Trained and Tested combination 46 of 22032, taking 0.01 seconds to get val score of 0.0:
#                 {'C': 10, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1, 'features': 35},
#             Current best combo with val score 0.0291:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1, 'features': 10}
# Trained and Tested combination 47 of 22032, taking 0.01 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1, 'features': 10},
#             Current best combo with val score 0.0291:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1, 'features': 10}
# Trained and Tested combination 48 of 22032, taking 0.01 seconds to get val score of 0.0:
#                 {'C': 10, 'max_iter': 50, 'penalty': 'l1', 'tol': 1, 'features': 20},
#             Current best combo with val score 0.0291:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1, 'features': 10}
# Trained and Tested combination 49 of 22032, taking 0.03 seconds to get val score of 0.0099:
#                 {'C': 10, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1e-05, 'features': 15},
#             Current best combo with val score 0.0291:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1, 'features': 10}
# Trained and Tested combination 50 of 22032, taking 0.11 seconds to get val score of 0.0:
#                 {'C': 10, 'max_iter': 50, 'penalty': 'l2', 'tol': 1e-05, 'features': 45},
#             Current best combo with val score 0.0291:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1, 'features': 10}
# Trained and Tested combination 51 of 22032, taking 0.01 seconds to get val score of 0.0:
#                 {'C': 10, 'max_iter': 50, 'penalty': 'l1', 'tol': 1, 'features': 35},
#             Current best combo with val score 0.0291:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1, 'features': 10}
# Trained and Tested combination 52 of 22032, taking 0.01 seconds to get val score of 0.0:
#                 {'C': 10, 'max_iter': 50, 'penalty': 'l1', 'tol': 1, 'features': 30},
#             Current best combo with val score 0.0291:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1, 'features': 10}
# Trained and Tested combination 53 of 22032, taking 0.01 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1, 'features': 20},
#             Current best combo with val score 0.0291:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1, 'features': 10}
# Trained and Tested combination 54 of 22032, taking 0.0 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1, 'features': 0},
#             Current best combo with val score 0.0291:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1, 'features': 10}
# Trained and Tested combination 55 of 22032, taking 0.02 seconds to get val score of 0.0:
#                 {'C': 10, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1, 'features': 40},
#             Current best combo with val score 0.0291:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1, 'features': 10}
# Trained and Tested combination 56 of 22032, taking 0.01 seconds to get val score of 0.0:
#                 {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1, 'features': 15},
#             Current best combo with val score 0.0291:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1, 'features': 10}
# Trained and Tested combination 57 of 22032, taking 0.01 seconds to get val score of 0.0262:
#                 {'C': 10, 'max_iter': 50, 'penalty': 'l1', 'tol': 1, 'features': 10},
#             Current best combo with val score 0.0291:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1, 'features': 10}
# Trained and Tested combination 58 of 22032, taking 0.03 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1e-05, 'features': 20},
#             Current best combo with val score 0.0291:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1, 'features': 10}
# Trained and Tested combination 59 of 22032, taking 0.01 seconds to get val score of 0.0:
#                 {'C': 10, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 15},
#             Current best combo with val score 0.0291:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1, 'features': 10}
# Trained and Tested combination 60 of 22032, taking 0.16 seconds to get val score of 0.0:
#                 {'C': 10, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1e-05, 'features': 40},
#             Current best combo with val score 0.0291:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1, 'features': 10}
# Trained and Tested combination 61 of 22032, taking 0.01 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'max_iter': 50, 'penalty': 'l1', 'tol': 1, 'features': 25},
#             Current best combo with val score 0.0291:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1, 'features': 10}
# Trained and Tested combination 62 of 22032, taking 0.01 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 50},
#             Current best combo with val score 0.0291:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1, 'features': 10}
# Trained and Tested combination 63 of 22032, taking 0.01 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'max_iter': 50, 'penalty': 'l1', 'tol': 1, 'features': 45},
#             Current best combo with val score 0.0291:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1, 'features': 10}
# Trained and Tested combination 64 of 22032, taking 0.01 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'max_iter': 50, 'penalty': 'l1', 'tol': 1e-05, 'features': 45},
#             Current best combo with val score 0.0291:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1, 'features': 10}
# Trained and Tested combination 65 of 22032, taking 0.0 seconds to get val score of 0.0:
#                 {'C': 10, 'max_iter': 50, 'penalty': 'l1', 'tol': 1, 'features': 0},
#             Current best combo with val score 0.0291:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1, 'features': 10}
# Trained and Tested combination 66 of 22032, taking 1.6 seconds to get val score of 0.0:
#                 {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1e-05, 'features': 40},
#             Current best combo with val score 0.0291:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1, 'features': 10}
# Trained and Tested combination 67 of 22032, taking 0.01 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1e-05, 'features': 15},
#             Current best combo with val score 0.0291:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1, 'features': 10}
# Trained and Tested combination 68 of 22032, taking 0.01 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1e-05, 'features': 25},
#             Current best combo with val score 0.0291:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1, 'features': 10}
# Trained and Tested combination 69 of 22032, taking 0.19 seconds to get val score of 0.0696:
#                 {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1e-05, 'features': 5},
#             Current best combo with val score 0.0696:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1e-05, 'features': 5}
# Trained and Tested combination 70 of 22032, taking 0.02 seconds to get val score of 0.0099:
#                 {'C': 10, 'max_iter': 50, 'penalty': 'l1', 'tol': 1, 'features': 5},
#             Current best combo with val score 0.0696:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1e-05, 'features': 5}
# Trained and Tested combination 71 of 22032, taking 0.02 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 35},
#             Current best combo with val score 0.0696:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1e-05, 'features': 5}
# Trained and Tested combination 72 of 22032, taking 0.07 seconds to get val score of 0.0:
#                 {'C': 10, 'max_iter': 50, 'penalty': 'l2', 'tol': 1e-05, 'features': 30},
#             Current best combo with val score 0.0696:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1e-05, 'features': 5}
# Trained and Tested combination 73 of 22032, taking 1.5 seconds to get val score of 0.0:
#                 {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1e-05, 'features': 50},
#             Current best combo with val score 0.0696:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1e-05, 'features': 5}
# Trained and Tested combination 74 of 22032, taking 0.01 seconds to get val score of 0.0:
#                 {'C': 10, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1, 'features': 20},
#             Current best combo with val score 0.0696:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1e-05, 'features': 5}
# Trained and Tested combination 75 of 22032, taking 0.01 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'max_iter': 50, 'penalty': 'l2', 'tol': 1e-05, 'features': 20},
#             Current best combo with val score 0.0696:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1e-05, 'features': 5}
# Trained and Tested combination 76 of 22032, taking 1.83 seconds to get val score of 0.0:
#                 {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1e-05, 'features': 45},
#             Current best combo with val score 0.0696:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1e-05, 'features': 5}
# Trained and Tested combination 77 of 22032, taking 0.01 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1e-05, 'features': 5},
#             Current best combo with val score 0.0696:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1e-05, 'features': 5}
# Trained and Tested combination 78 of 22032, taking 1.5 seconds to get val score of 0.0:
#                 {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1e-05, 'features': 35},
#             Current best combo with val score 0.0696:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1e-05, 'features': 5}
# Trained and Tested combination 79 of 22032, taking 0.02 seconds to get val score of 0.0696:
#                 {'C': 10, 'max_iter': 50, 'penalty': 'l2', 'tol': 1e-05, 'features': 5},
#             Current best combo with val score 0.0696:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1e-05, 'features': 5}
# Trained and Tested combination 80 of 22032, taking 0.01 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'max_iter': 50, 'penalty': 'l1', 'tol': 1, 'features': 35},
#             Current best combo with val score 0.0696:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1e-05, 'features': 5}
# Trained and Tested combination 81 of 22032, taking 0.22 seconds to get val score of 0.1658:
#                 {'C': 10, 'max_iter': 50, 'penalty': 'l1', 'tol': 1e-05, 'features': 10},
#             Current best combo with val score 0.1658:
#                     {'C': 10, 'max_iter': 50, 'penalty': 'l1', 'tol': 1e-05, 'features': 10}
# Trained and Tested combination 82 of 22032, taking 0.07 seconds to get val score of 0.0:
#                 {'C': 10, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1e-05, 'features': 25},
#             Current best combo with val score 0.1658:
#                     {'C': 10, 'max_iter': 50, 'penalty': 'l1', 'tol': 1e-05, 'features': 10}
# Trained and Tested combination 83 of 22032, taking 0.01 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'max_iter': 50, 'penalty': 'l1', 'tol': 1e-05, 'features': 25},
#             Current best combo with val score 0.1658:
#                     {'C': 10, 'max_iter': 50, 'penalty': 'l1', 'tol': 1e-05, 'features': 10}
# Trained and Tested combination 84 of 22032, taking 0.01 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 10},
#             Current best combo with val score 0.1658:
#                     {'C': 10, 'max_iter': 50, 'penalty': 'l1', 'tol': 1e-05, 'features': 10}
# Trained and Tested combination 85 of 22032, taking 0.01 seconds to get val score of 0.0:
#                 {'C': 10, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1, 'features': 30},
#             Current best combo with val score 0.1658:
#                     {'C': 10, 'max_iter': 50, 'penalty': 'l1', 'tol': 1e-05, 'features': 10}
# Trained and Tested combination 86 of 22032, taking 0.13 seconds to get val score of 0.0:
#                 {'C': 10, 'max_iter': 50, 'penalty': 'l2', 'tol': 1e-05, 'features': 35},
#             Current best combo with val score 0.1658:
#                     {'C': 10, 'max_iter': 50, 'penalty': 'l1', 'tol': 1e-05, 'features': 10}
# Trained and Tested combination 87 of 22032, taking 1.65 seconds to get val score of 0.0:
#                 {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1e-05, 'features': 30},
#             Current best combo with val score 0.1658:
#                     {'C': 10, 'max_iter': 50, 'penalty': 'l1', 'tol': 1e-05, 'features': 10}
# Trained and Tested combination 88 of 22032, taking 0.0 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'max_iter': 50, 'penalty': 'l2', 'tol': 1e-05, 'features': 0},
#             Current best combo with val score 0.1658:
#                     {'C': 10, 'max_iter': 50, 'penalty': 'l1', 'tol': 1e-05, 'features': 10}
# Trained and Tested combination 89 of 22032, taking 0.01 seconds to get val score of 0.0:
#                 {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1, 'features': 30},
#             Current best combo with val score 0.1658:
#                     {'C': 10, 'max_iter': 50, 'penalty': 'l1', 'tol': 1e-05, 'features': 10}
# Trained and Tested combination 90 of 22032, taking 0.02 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1, 'features': 50},
#             Current best combo with val score 0.1658:
#                     {'C': 10, 'max_iter': 50, 'penalty': 'l1', 'tol': 1e-05, 'features': 10}
# Trained and Tested combination 91 of 22032, taking 0.01 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1, 'features': 50},
#             Current best combo with val score 0.1658:
#                     {'C': 10, 'max_iter': 50, 'penalty': 'l1', 'tol': 1e-05, 'features': 10}
# Trained and Tested combination 92 of 22032, taking 0.01 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1e-05, 'features': 40},
#             Current best combo with val score 0.1658:
#                     {'C': 10, 'max_iter': 50, 'penalty': 'l1', 'tol': 1e-05, 'features': 10}
# Trained and Tested combination 93 of 22032, taking 0.01 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1, 'features': 45},
#             Current best combo with val score 0.1658:
#                     {'C': 10, 'max_iter': 50, 'penalty': 'l1', 'tol': 1e-05, 'features': 10}
# Trained and Tested combination 94 of 22032, taking 0.01 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1e-05, 'features': 30},
#             Current best combo with val score 0.1658:
#                     {'C': 10, 'max_iter': 50, 'penalty': 'l1', 'tol': 1e-05, 'features': 10}
# Trained and Tested combination 95 of 22032, taking 0.02 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1e-05, 'features': 50},
#             Current best combo with val score 0.1658:
#                     {'C': 10, 'max_iter': 50, 'penalty': 'l1', 'tol': 1e-05, 'features': 10}
# Trained and Tested combination 96 of 22032, taking 0.73 seconds to get val score of 0.0196:
#                 {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1e-05, 'features': 20},
#             Current best combo with val score 0.1658:
#                     {'C': 10, 'max_iter': 50, 'penalty': 'l1', 'tol': 1e-05, 'features': 10}
# Trained and Tested combination 97 of 22032, taking 0.01 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'max_iter': 50, 'penalty': 'l1', 'tol': 1, 'features': 5},
#             Current best combo with val score 0.1658:
#                     {'C': 10, 'max_iter': 50, 'penalty': 'l1', 'tol': 1e-05, 'features': 10}
# Trained and Tested combination 98 of 22032, taking 0.02 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1e-05, 'features': 40},
#             Current best combo with val score 0.1658:
#                     {'C': 10, 'max_iter': 50, 'penalty': 'l1', 'tol': 1e-05, 'features': 10}
# Trained and Tested combination 99 of 22032, taking 0.01 seconds to get val score of 0.0:
#                 {'C': 10, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1, 'features': 15},
#             Current best combo with val score 0.1658:
#                     {'C': 10, 'max_iter': 50, 'penalty': 'l1', 'tol': 1e-05, 'features': 10}
# Trained and Tested combination 100 of 22032, taking 0.02 seconds to get val score of 0.0:
#                 {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1, 'features': 50},
#             Current best combo with val score 0.1658:
#                     {'C': 10, 'max_iter': 50, 'penalty': 'l1', 'tol': 1e-05, 'features': 10}
# Trained and Tested combination 101 of 22032, taking 0.02 seconds to get val score of 0.1658:
#                 {'C': 10, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1e-05, 'features': 10},
#             Current best combo with val score 0.1658:
#                     {'C': 10, 'max_iter': 50, 'penalty': 'l1', 'tol': 1e-05, 'features': 10}
# Trained and Tested combination 102 of 22032, taking 0.01 seconds to get val score of 0.0:
#                 {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1, 'features': 40},
#             Current best combo with val score 0.1658:
#                     {'C': 10, 'max_iter': 50, 'penalty': 'l1', 'tol': 1e-05, 'features': 10}
# Trained and Tested combination 103 of 22032, taking 0.01 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'max_iter': 50, 'penalty': 'l2', 'tol': 1e-05, 'features': 25},
#             Current best combo with val score 0.1658:
#                     {'C': 10, 'max_iter': 50, 'penalty': 'l1', 'tol': 1e-05, 'features': 10}
# Trained and Tested combination 104 of 22032, taking 0.02 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'max_iter': 50, 'penalty': 'l1', 'tol': 1e-05, 'features': 20},
#             Current best combo with val score 0.1658:
#                     {'C': 10, 'max_iter': 50, 'penalty': 'l1', 'tol': 1e-05, 'features': 10}
# Trained and Tested combination 105 of 22032, taking 0.01 seconds to get val score of 0.0291:
#                 {'C': 10, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 10},
#             Current best combo with val score 0.1658:
#                     {'C': 10, 'max_iter': 50, 'penalty': 'l1', 'tol': 1e-05, 'features': 10}
# Trained and Tested combination 106 of 22032, taking 0.01 seconds to get val score of 0.0:
#                 {'C': 10, 'max_iter': 50, 'penalty': 'l2', 'tol': 1e-05, 'features': 0},
#             Current best combo with val score 0.1658:
#                     {'C': 10, 'max_iter': 50, 'penalty': 'l1', 'tol': 1e-05, 'features': 10}
# Trained and Tested combination 107 of 22032, taking 0.01 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1, 'features': 5},
#             Current best combo with val score 0.1658:
#                     {'C': 10, 'max_iter': 50, 'penalty': 'l1', 'tol': 1e-05, 'features': 10}
# Trained and Tested combination 108 of 22032, taking 0.03 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'max_iter': 50, 'penalty': 'l2', 'tol': 1e-05, 'features': 35},
#             Current best combo with val score 0.1658:
#                     {'C': 10, 'max_iter': 50, 'penalty': 'l1', 'tol': 1e-05, 'features': 10}
# Trained and Tested combination 109 of 22032, taking 0.01 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1, 'features': 40},
#             Current best combo with val score 0.1658:
#                     {'C': 10, 'max_iter': 50, 'penalty': 'l1', 'tol': 1e-05, 'features': 10}
# Trained and Tested combination 110 of 22032, taking 0.02 seconds to get val score of 0.0:
#                 {'C': 10, 'max_iter': 50, 'penalty': 'l1', 'tol': 1, 'features': 40},
#             Current best combo with val score 0.1658:
#                     {'C': 10, 'max_iter': 50, 'penalty': 'l1', 'tol': 1e-05, 'features': 10}
# Trained and Tested combination 111 of 22032, taking 0.01 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 40},
#             Current best combo with val score 0.1658:
#                     {'C': 10, 'max_iter': 50, 'penalty': 'l1', 'tol': 1e-05, 'features': 10}
# Trained and Tested combination 112 of 22032, taking 0.01 seconds to get val score of 0.0:
#                 {'C': 10, 'max_iter': 50, 'penalty': 'l1', 'tol': 1, 'features': 15},
#             Current best combo with val score 0.1658:
#                     {'C': 10, 'max_iter': 50, 'penalty': 'l1', 'tol': 1e-05, 'features': 10}
# Trained and Tested combination 113 of 22032, taking 0.01 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1, 'features': 15},
#             Current best combo with val score 0.1658:
#                     {'C': 10, 'max_iter': 50, 'penalty': 'l1', 'tol': 1e-05, 'features': 10}
# Trained and Tested combination 114 of 22032, taking 0.01 seconds to get val score of 0.0:
#                 {'C': 10, 'max_iter': 50, 'penalty': 'l1', 'tol': 1e-05, 'features': 0},
#             Current best combo with val score 0.1658:
#                     {'C': 10, 'max_iter': 50, 'penalty': 'l1', 'tol': 1e-05, 'features': 10}
# Trained and Tested combination 115 of 22032, taking 0.01 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 15},
#             Current best combo with val score 0.1658:
#                     {'C': 10, 'max_iter': 50, 'penalty': 'l1', 'tol': 1e-05, 'features': 10}
# Trained and Tested combination 116 of 22032, taking 0.01 seconds to get val score of 0.0:
#                 {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1, 'features': 20},
#             Current best combo with val score 0.1658:
#                     {'C': 10, 'max_iter': 50, 'penalty': 'l1', 'tol': 1e-05, 'features': 10}
# Trained and Tested combination 117 of 22032, taking 0.14 seconds to get val score of 0.0696:
#                 {'C': 10, 'max_iter': 50, 'penalty': 'l1', 'tol': 1e-05, 'features': 5},
#             Current best combo with val score 0.1658:
#                     {'C': 10, 'max_iter': 50, 'penalty': 'l1', 'tol': 1e-05, 'features': 10}
# Trained and Tested combination 118 of 22032, taking 2.4 seconds to get val score of 0.0:
#                 {'C': 10, 'max_iter': 50, 'penalty': 'l1', 'tol': 1e-05, 'features': 40},
#             Current best combo with val score 0.1658:
#                     {'C': 10, 'max_iter': 50, 'penalty': 'l1', 'tol': 1e-05, 'features': 10}
# Trained and Tested combination 119 of 22032, taking 0.04 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'max_iter': 50, 'penalty': 'l2', 'tol': 1e-05, 'features': 40},
#             Current best combo with val score 0.1658:
#                     {'C': 10, 'max_iter': 50, 'penalty': 'l1', 'tol': 1e-05, 'features': 10}
# Trained and Tested combination 120 of 22032, taking 0.01 seconds to get val score of 0.0:
#                 {'C': 10, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 0},
#             Current best combo with val score 0.1658:
#                     {'C': 10, 'max_iter': 50, 'penalty': 'l1', 'tol': 1e-05, 'features': 10}
# Trained and Tested combination 121 of 22032, taking 0.01 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1, 'features': 30},
#             Current best combo with val score 0.1658:
#                     {'C': 10, 'max_iter': 50, 'penalty': 'l1', 'tol': 1e-05, 'features': 10}
# Trained and Tested combination 122 of 22032, taking 0.01 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 20},
#             Current best combo with val score 0.1658:
#                     {'C': 10, 'max_iter': 50, 'penalty': 'l1', 'tol': 1e-05, 'features': 10}
# Trained and Tested combination 123 of 22032, taking 0.01 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 5},
#             Current best combo with val score 0.1658:
#                     {'C': 10, 'max_iter': 50, 'penalty': 'l1', 'tol': 1e-05, 'features': 10}
# Trained and Tested combination 124 of 22032, taking 0.02 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1e-05, 'features': 45},
#             Current best combo with val score 0.1658:
#                     {'C': 10, 'max_iter': 50, 'penalty': 'l1', 'tol': 1e-05, 'features': 10}
# Trained and Tested combination 125 of 22032, taking 0.02 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 45},
#             Current best combo with val score 0.1658:
#                     {'C': 10, 'max_iter': 50, 'penalty': 'l1', 'tol': 1e-05, 'features': 10}
# Trained and Tested combination 126 of 22032, taking 0.02 seconds to get val score of 0.0696:
#                 {'C': 10, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1e-05, 'features': 5},
#             Current best combo with val score 0.1658:
#                     {'C': 10, 'max_iter': 50, 'penalty': 'l1', 'tol': 1e-05, 'features': 10}
# Trained and Tested combination 127 of 22032, taking 0.01 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1, 'features': 30},
#             Current best combo with val score 0.1658:
#                     {'C': 10, 'max_iter': 50, 'penalty': 'l1', 'tol': 1e-05, 'features': 10}
# Trained and Tested combination 128 of 22032, taking 0.02 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'max_iter': 50, 'penalty': 'l1', 'tol': 1, 'features': 15},
#             Current best combo with val score 0.1658:
#                     {'C': 10, 'max_iter': 50, 'penalty': 'l1', 'tol': 1e-05, 'features': 10}
# Trained and Tested combination 129 of 22032, taking 0.01 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'max_iter': 50, 'penalty': 'l2', 'tol': 1e-05, 'features': 10},
#             Current best combo with val score 0.1658:
#                     {'C': 10, 'max_iter': 50, 'penalty': 'l1', 'tol': 1e-05, 'features': 10}
# Trained and Tested combination 130 of 22032, taking 0.01 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 25},
#             Current best combo with val score 0.1658:
#                     {'C': 10, 'max_iter': 50, 'penalty': 'l1', 'tol': 1e-05, 'features': 10}
# Trained and Tested combination 131 of 22032, taking 0.01 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1e-05, 'features': 5},
#             Current best combo with val score 0.1658:
#                     {'C': 10, 'max_iter': 50, 'penalty': 'l1', 'tol': 1e-05, 'features': 10}
# Trained and Tested combination 132 of 22032, taking 0.04 seconds to get val score of 0.0099:
#                 {'C': 10, 'max_iter': 50, 'penalty': 'l2', 'tol': 1e-05, 'features': 15},
#             Current best combo with val score 0.1658:
#                     {'C': 10, 'max_iter': 50, 'penalty': 'l1', 'tol': 1e-05, 'features': 10}
# Trained and Tested combination 133 of 22032, taking 0.01 seconds to get val score of 0.0262:
#                 {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1, 'features': 10},
#             Current best combo with val score 0.1658:
#                     {'C': 10, 'max_iter': 50, 'penalty': 'l1', 'tol': 1e-05, 'features': 10}
# Trained and Tested combination 134 of 22032, taking 1.7 seconds to get val score of 0.0:
#                 {'C': 10, 'max_iter': 50, 'penalty': 'l1', 'tol': 1e-05, 'features': 45},
#             Current best combo with val score 0.1658:
#                     {'C': 10, 'max_iter': 50, 'penalty': 'l1', 'tol': 1e-05, 'features': 10}
# Trained and Tested combination 135 of 22032, taking 0.01 seconds to get val score of 0.0:
#                 {'C': 10, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 30},
#             Current best combo with val score 0.1658:
#                     {'C': 10, 'max_iter': 50, 'penalty': 'l1', 'tol': 1e-05, 'features': 10}
# Trained and Tested combination 136 of 22032, taking 0.02 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'max_iter': 50, 'penalty': 'l2', 'tol': 1e-05, 'features': 5},
#             Current best combo with val score 0.1658:
#                     {'C': 10, 'max_iter': 50, 'penalty': 'l1', 'tol': 1e-05, 'features': 10}
# Trained and Tested combination 137 of 22032, taking 0.01 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1e-05, 'features': 50},
#             Current best combo with val score 0.1658:
#                     {'C': 10, 'max_iter': 50, 'penalty': 'l1', 'tol': 1e-05, 'features': 10}
# Trained and Tested combination 138 of 22032, taking 0.02 seconds to get val score of 0.0:
#                 {'C': 10, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1, 'features': 45},
#             Current best combo with val score 0.1658:
#                     {'C': 10, 'max_iter': 50, 'penalty': 'l1', 'tol': 1e-05, 'features': 10}
# Trained and Tested combination 139 of 22032, taking 0.01 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 30},
#             Current best combo with val score 0.1658:
#                     {'C': 10, 'max_iter': 50, 'penalty': 'l1', 'tol': 1e-05, 'features': 10}
# Trained and Tested combination 140 of 22032, taking 0.01 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'max_iter': 50, 'penalty': 'l1', 'tol': 1e-05, 'features': 30},
#             Current best combo with val score 0.1658:
#                     {'C': 10, 'max_iter': 50, 'penalty': 'l1', 'tol': 1e-05, 'features': 10}
# Trained and Tested combination 141 of 22032, taking 0.01 seconds to get val score of 0.0:
#                 {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1, 'features': 35},
#             Current best combo with val score 0.1658:
#                     {'C': 10, 'max_iter': 50, 'penalty': 'l1', 'tol': 1e-05, 'features': 10}
# Trained and Tested combination 142 of 22032, taking 0.01 seconds to get val score of 0.029:
#                 {'C': 10, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 5},
#             Current best combo with val score 0.1658:
#                     {'C': 10, 'max_iter': 50, 'penalty': 'l1', 'tol': 1e-05, 'features': 10}
# Trained and Tested combination 143 of 22032, taking 0.0 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'max_iter': 50, 'penalty': 'l1', 'tol': 1e-05, 'features': 0},
#             Current best combo with val score 0.1658:
#                     {'C': 10, 'max_iter': 50, 'penalty': 'l1', 'tol': 1e-05, 'features': 10}
# Trained and Tested combination 144 of 22032, taking 0.02 seconds to get val score of 0.0:
#                 {'C': 10, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 50},
#             Current best combo with val score 0.1658:
#                     {'C': 10, 'max_iter': 50, 'penalty': 'l1', 'tol': 1e-05, 'features': 10}
# Trained and Tested combination 145 of 22032, taking 0.02 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'max_iter': 50, 'penalty': 'l2', 'tol': 1e-05, 'features': 45},
#             Current best combo with val score 0.1658:
# ...
#                 {'C': 10, 'max_iter': 100, 'penalty': 'l2', 'tol': 1e-05, 'features': 11},
#             Current best combo with val score 0.1706:
#                     {'C': 10, 'max_iter': 50, 'penalty': 'l1', 'tol': 1e-05, 'features': 9}
# Already Trained and Tested combination (val score of 0.1306):
#             {'C': 1, 'max_iter': 50, 'penalty': 'l1', 'tol': 1e-05, 'features': 10}
#             Current best combo (with val score 0.1706):
#                     {'C': 10, 'max_iter': 50, 'penalty': 'l1', 'tol': 1e-05, 'features': 9}
#         Has trained 266 of 22032 combinations so far
# Already Trained and Tested combination (val score of 0.1658):
#             {'C': 10, 'max_iter': 100, 'penalty': 'l1', 'tol': 1e-05, 'features': 10}
#             Current best combo (with val score 0.1706):
#                     {'C': 10, 'max_iter': 50, 'penalty': 'l1', 'tol': 1e-05, 'features': 9}
#         Has trained 266 of 22032 combinations so far
# Already Trained and Tested combination (val score of 0.1658):
#             {'C': 10, 'max_iter': 50, 'penalty': 'l2', 'tol': 1e-05, 'features': 10}
#             Current best combo (with val score 0.1706):
#                     {'C': 10, 'max_iter': 50, 'penalty': 'l1', 'tol': 1e-05, 'features': 9}
#         Has trained 266 of 22032 combinations so far
# Already Trained and Tested combination (val score of 0.1658):
#             {'C': 10, 'max_iter': 50, 'penalty': 'l1', 'tol': 0.0001, 'features': 10}
#             Current best combo (with val score 0.1706):
#                     {'C': 10, 'max_iter': 50, 'penalty': 'l1', 'tol': 1e-05, 'features': 9}
#         Has trained 266 of 22032 combinations so far
# Already Trained and Tested combination (val score of 0.1706):
#             {'C': 10, 'max_iter': 50, 'penalty': 'l1', 'tol': 1e-05, 'features': 9}
#             Current best combo (with val score 0.1706):
#                     {'C': 10, 'max_iter': 50, 'penalty': 'l1', 'tol': 1e-05, 'features': 9}
#         Has trained 266 of 22032 combinations so far
# Already Trained and Tested combination (val score of 0.0292):
#             {'C': 10, 'max_iter': 50, 'penalty': 'l1', 'tol': 1e-05, 'features': 11}
#             Current best combo (with val score 0.1706):
#                     {'C': 10, 'max_iter': 50, 'penalty': 'l1', 'tol': 1e-05, 'features': 9}
#         Has trained 266 of 22032 combinations so far
# Trained and Tested combination 267 of 22032, taking 0.02 seconds to get val score of 0.1395:
#                 {'C': 1, 'max_iter': 50, 'penalty': 'l2', 'tol': 0.0001, 'features': 10},
#             Current best combo with val score 0.1706:
#                     {'C': 10, 'max_iter': 50, 'penalty': 'l1', 'tol': 1e-05, 'features': 9}
# Already Trained and Tested combination (val score of 0.1658):
#             {'C': 10, 'max_iter': 100, 'penalty': 'l2', 'tol': 0.0001, 'features': 10}
#             Current best combo (with val score 0.1706):
#                     {'C': 10, 'max_iter': 50, 'penalty': 'l1', 'tol': 1e-05, 'features': 9}
#         Has trained 267 of 22032 combinations so far
# Already Trained and Tested combination (val score of 0.1658):
#             {'C': 10, 'max_iter': 50, 'penalty': 'l1', 'tol': 0.0001, 'features': 10}
#             Current best combo (with val score 0.1706):
#                     {'C': 10, 'max_iter': 50, 'penalty': 'l1', 'tol': 1e-05, 'features': 9}
#         Has trained 267 of 22032 combinations so far
# Already Trained and Tested combination (val score of 0.1658):
#             {'C': 10, 'max_iter': 50, 'penalty': 'l2', 'tol': 1e-05, 'features': 10}
#             Current best combo (with val score 0.1706):
#                     {'C': 10, 'max_iter': 50, 'penalty': 'l1', 'tol': 1e-05, 'features': 9}
#         Has trained 267 of 22032 combinations so far
# Trained and Tested combination 268 of 22032, taking 0.03 seconds to get val score of 0.1658:
#                 {'C': 10, 'max_iter': 50, 'penalty': 'l2', 'tol': 0.001, 'features': 10},
#             Current best combo with val score 0.1706:
#                     {'C': 10, 'max_iter': 50, 'penalty': 'l1', 'tol': 1e-05, 'features': 9}
# Trained and Tested combination 269 of 22032, taking 0.02 seconds to get val score of 0.1657:
#                 {'C': 10, 'max_iter': 50, 'penalty': 'l2', 'tol': 0.0001, 'features': 9},
#             Current best combo with val score 0.1706:
#                     {'C': 10, 'max_iter': 50, 'penalty': 'l1', 'tol': 1e-05, 'features': 9}
# Trained and Tested combination 270 of 22032, taking 0.02 seconds to get val score of 0.0292:
#                 {'C': 10, 'max_iter': 50, 'penalty': 'l2', 'tol': 0.0001, 'features': 11},
#             Current best combo with val score 0.1706:
#                     {'C': 10, 'max_iter': 50, 'penalty': 'l1', 'tol': 1e-05, 'features': 9}
# Trained and Tested combination 271 of 22032, taking 0.02 seconds to get val score of 0.1501:
#                 {'C': 1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1e-05, 'features': 9},
#             Current best combo with val score 0.1706:
#                     {'C': 10, 'max_iter': 50, 'penalty': 'l1', 'tol': 1e-05, 'features': 9}
# Already Trained and Tested combination (val score of 0.1657):
#             {'C': 10, 'max_iter': 100, 'penalty': 'l2', 'tol': 1e-05, 'features': 9}
#             Current best combo (with val score 0.1706):
#                     {'C': 10, 'max_iter': 50, 'penalty': 'l1', 'tol': 1e-05, 'features': 9}
#         Has trained 271 of 22032 combinations so far
# Already Trained and Tested combination (val score of 0.1706):
#             {'C': 10, 'max_iter': 50, 'penalty': 'l1', 'tol': 1e-05, 'features': 9}
#             Current best combo (with val score 0.1706):
#                     {'C': 10, 'max_iter': 50, 'penalty': 'l1', 'tol': 1e-05, 'features': 9}
#         Has trained 271 of 22032 combinations so far
# Already Trained and Tested combination (val score of 0.1657):
#             {'C': 10, 'max_iter': 50, 'penalty': 'l2', 'tol': 0.0001, 'features': 9}
#             Current best combo (with val score 0.1706):
#                     {'C': 10, 'max_iter': 50, 'penalty': 'l1', 'tol': 1e-05, 'features': 9}
#         Has trained 271 of 22032 combinations so far
# Trained and Tested combination 272 of 22032, taking 0.02 seconds to get val score of 0.1505:
#                 {'C': 10, 'max_iter': 50, 'penalty': 'l2', 'tol': 1e-05, 'features': 8},
#             Current best combo with val score 0.1706:
#                     {'C': 10, 'max_iter': 50, 'penalty': 'l1', 'tol': 1e-05, 'features': 9}
# Already Trained and Tested combination (val score of 0.1658):
#             {'C': 10, 'max_iter': 50, 'penalty': 'l2', 'tol': 1e-05, 'features': 10}
#             Current best combo (with val score 0.1706):
#                     {'C': 10, 'max_iter': 50, 'penalty': 'l1', 'tol': 1e-05, 'features': 9}
#         Has trained 272 of 22032 combinations so far
# % Combos Checked Thus Far: 272 out of 22032 which is 1.2345679999999999%
# Cruising Coordrdinate 176 of 176
#
# Cruise suspended due to suspicious case
# Guidance: round 4
#
# 	round 4 iteration:  0
#
# % Combos Checked Thus Far: 272 out of 22032 which is 1.2345679999999999%
# FINAL STAGE: Begin final Guidance system
#
#
# Guidance: round FINAL
#
# 	round FINAL iteration:  0
#
# Already Trained and Tested combination (val score of 0.1411):
#             {'C': 1, 'max_iter': 50, 'penalty': 'l1', 'tol': 1e-05, 'features': 9}
#             Current best combo (with val score 0.1706):
#                     {'C': 10, 'max_iter': 50, 'penalty': 'l1', 'tol': 1e-05, 'features': 9}
#         Has trained 272 of 22032 combinations so far
# Already Trained and Tested combination (val score of 0.1706):
#             {'C': 10, 'max_iter': 100, 'penalty': 'l1', 'tol': 1e-05, 'features': 9}
#             Current best combo (with val score 0.1706):
#                     {'C': 10, 'max_iter': 50, 'penalty': 'l1', 'tol': 1e-05, 'features': 9}
#         Has trained 272 of 22032 combinations so far
# Already Trained and Tested combination (val score of 0.1657):
#             {'C': 10, 'max_iter': 50, 'penalty': 'l2', 'tol': 1e-05, 'features': 9}
#             Current best combo (with val score 0.1706):
#                     {'C': 10, 'max_iter': 50, 'penalty': 'l1', 'tol': 1e-05, 'features': 9}
#         Has trained 272 of 22032 combinations so far
# Already Trained and Tested combination (val score of 0.1706):
#             {'C': 10, 'max_iter': 50, 'penalty': 'l1', 'tol': 0.0001, 'features': 9}
#             Current best combo (with val score 0.1706):
#                     {'C': 10, 'max_iter': 50, 'penalty': 'l1', 'tol': 1e-05, 'features': 9}
#         Has trained 272 of 22032 combinations so far
# Already Trained and Tested combination (val score of 0.1562):
#             {'C': 10, 'max_iter': 50, 'penalty': 'l1', 'tol': 1e-05, 'features': 8}
#             Current best combo (with val score 0.1706):
#                     {'C': 10, 'max_iter': 50, 'penalty': 'l1', 'tol': 1e-05, 'features': 9}
#         Has trained 272 of 22032 combinations so far
# Already Trained and Tested combination (val score of 0.1658):
#             {'C': 10, 'max_iter': 50, 'penalty': 'l1', 'tol': 1e-05, 'features': 10}
#             Current best combo (with val score 0.1706):
#                     {'C': 10, 'max_iter': 50, 'penalty': 'l1', 'tol': 1e-05, 'features': 9}
#         Has trained 272 of 22032 combinations so far
# 	round FINAL iteration:  1
#
# Trained and Tested combination 273 of 22032, taking 0.05 seconds to get val score of 0.1411:
#                 {'C': 1, 'max_iter': 100, 'penalty': 'l1', 'tol': 1e-05, 'features': 9},
#             Current best combo with val score 0.1706:
#                     {'C': 10, 'max_iter': 50, 'penalty': 'l1', 'tol': 1e-05, 'features': 9}
# Already Trained and Tested combination (val score of 0.1706):
#             {'C': 10, 'max_iter': 50, 'penalty': 'l1', 'tol': 1e-05, 'features': 9}
#             Current best combo (with val score 0.1706):
#                     {'C': 10, 'max_iter': 50, 'penalty': 'l1', 'tol': 1e-05, 'features': 9}
#         Has trained 273 of 22032 combinations so far
# Trained and Tested combination 274 of 22032, taking 0.21 seconds to get val score of 0.1706:
#                 {'C': 10, 'max_iter': 200, 'penalty': 'l1', 'tol': 1e-05, 'features': 9},
#             Current best combo with val score 0.1706:
#                     {'C': 10, 'max_iter': 50, 'penalty': 'l1', 'tol': 1e-05, 'features': 9}
# Already Trained and Tested combination (val score of 0.1657):
#             {'C': 10, 'max_iter': 100, 'penalty': 'l2', 'tol': 1e-05, 'features': 9}
#             Current best combo (with val score 0.1706):
#                     {'C': 10, 'max_iter': 50, 'penalty': 'l1', 'tol': 1e-05, 'features': 9}
#         Has trained 274 of 22032 combinations so far
# Trained and Tested combination 275 of 22032, taking 0.27 seconds to get val score of 0.1706:
#                 {'C': 10, 'max_iter': 100, 'penalty': 'l1', 'tol': 0.0001, 'features': 9},
#             Current best combo with val score 0.1706:
#                     {'C': 10, 'max_iter': 50, 'penalty': 'l1', 'tol': 1e-05, 'features': 9}
# Trained and Tested combination 276 of 22032, taking 0.22 seconds to get val score of 0.1562:
#                 {'C': 10, 'max_iter': 100, 'penalty': 'l1', 'tol': 1e-05, 'features': 8},
#             Current best combo with val score 0.1706:
#                     {'C': 10, 'max_iter': 50, 'penalty': 'l1', 'tol': 1e-05, 'features': 9}
# Already Trained and Tested combination (val score of 0.1658):
#             {'C': 10, 'max_iter': 100, 'penalty': 'l1', 'tol': 1e-05, 'features': 10}
#             Current best combo (with val score 0.1706):
#                     {'C': 10, 'max_iter': 50, 'penalty': 'l1', 'tol': 1e-05, 'features': 9}
#         Has trained 276 of 22032 combinations so far
# Trained and Tested combination 277 of 22032, taking 0.04 seconds to get val score of 0.1411:
#                 {'C': 1, 'max_iter': 50, 'penalty': 'l1', 'tol': 0.0001, 'features': 9},
#             Current best combo with val score 0.1706:
#                     {'C': 10, 'max_iter': 50, 'penalty': 'l1', 'tol': 1e-05, 'features': 9}
# Already Trained and Tested combination (val score of 0.1706):
#             {'C': 10, 'max_iter': 100, 'penalty': 'l1', 'tol': 0.0001, 'features': 9}
#             Current best combo (with val score 0.1706):
#                     {'C': 10, 'max_iter': 50, 'penalty': 'l1', 'tol': 1e-05, 'features': 9}
#         Has trained 277 of 22032 combinations so far
# Already Trained and Tested combination (val score of 0.1657):
#             {'C': 10, 'max_iter': 50, 'penalty': 'l2', 'tol': 0.0001, 'features': 9}
#             Current best combo (with val score 0.1706):
#                     {'C': 10, 'max_iter': 50, 'penalty': 'l1', 'tol': 1e-05, 'features': 9}
#         Has trained 277 of 22032 combinations so far
# Already Trained and Tested combination (val score of 0.1706):
#             {'C': 10, 'max_iter': 50, 'penalty': 'l1', 'tol': 1e-05, 'features': 9}
#             Current best combo (with val score 0.1706):
#                     {'C': 10, 'max_iter': 50, 'penalty': 'l1', 'tol': 1e-05, 'features': 9}
#         Has trained 277 of 22032 combinations so far
# Trained and Tested combination 278 of 22032, taking 0.04 seconds to get val score of 0.1659:
#                 {'C': 10, 'max_iter': 50, 'penalty': 'l1', 'tol': 0.001, 'features': 9},
#             Current best combo with val score 0.1706:
#                     {'C': 10, 'max_iter': 50, 'penalty': 'l1', 'tol': 1e-05, 'features': 9}
# Trained and Tested combination 279 of 22032, taking 0.19 seconds to get val score of 0.1565:
#                 {'C': 10, 'max_iter': 50, 'penalty': 'l1', 'tol': 0.0001, 'features': 8},
#             Current best combo with val score 0.1706:
#                     {'C': 10, 'max_iter': 50, 'penalty': 'l1', 'tol': 1e-05, 'features': 9}
# Already Trained and Tested combination (val score of 0.1658):
#             {'C': 10, 'max_iter': 50, 'penalty': 'l1', 'tol': 0.0001, 'features': 10}
#             Current best combo (with val score 0.1706):
#                     {'C': 10, 'max_iter': 50, 'penalty': 'l1', 'tol': 1e-05, 'features': 9}
#         Has trained 279 of 22032 combinations so far
# % Combos Checked Thus Far: 279 out of 22032 which is 1.26634%
# Max Val Score:
#  0.170581
# Max Val Score Std:
#  0.067746
# Best Combo Train Score:
#  0.515738
# Best Combo Train Score Std:
#  0.013691
# Max Combo Index:
#  (5, 0, 0, 0, 9) out of [6, 6, 2, 6, 51] (note best combo is 0-indexed)
# Max Combo Hyperparamer Combination:
#  {'C': 10, 'max_iter': 50, 'penalty': 'l1', 'tol': 1e-05, 'features': 9}
# Max Combo Features:
#  ('procedure_225792', 'ventilation_used', 'lods_score', 'race_AMERICAN INDIAN/ALASKA NATIVE', 'race_ASIAN', 'race_ASIAN - ASIAN INDIAN', 'race_ASIAN - CHINESE', 'race_ASIAN - KOREAN', 'race_ASIAN - SOUTH EAST ASIAN', 'race_BLACK/AFRICAN', 'race_BLACK/AFRICAN AMERICAN', 'race_BLACK/CAPE VERDEAN', 'race_BLACK/CARIBBEAN ISLAND', 'race_HISPANIC/LATINO - CENTRAL AMERICAN', 'race_HISPANIC/LATINO - COLUMBIAN', 'race_HISPANIC/LATINO - CUBAN', 'race_HISPANIC/LATINO - DOMINICAN', 'race_HISPANIC/LATINO - GUATEMALAN', 'race_HISPANIC/LATINO - HONDURAN', 'race_HISPANIC/LATINO - MEXICAN', 'race_HISPANIC/LATINO - PUERTO RICAN', 'race_HISPANIC/LATINO - SALVADORAN', 'race_MULTIPLE RACE/ETHNICITY', 'race_NATIVE HAWAIIAN OR OTHER PACIFIC ISLANDER', 'race_OTHER', 'race_PATIENT DECLINED TO ANSWER', 'race_PORTUGUESE', 'race_SOUTH AMERICAN', 'race_UNABLE TO OBTAIN', 'race_UNKNOWN', 'race_WHITE', 'race_WHITE - BRAZILIAN', 'race_WHITE - EASTERN EUROPEAN', 'race_WHITE - OTHER EUROPEAN', 'race_WHITE - RUSSIAN', 'race_HISPANIC OR LATINO', 'marital_status_DIVORCED', 'marital_status_MARRIED', 'marital_status_SINGLE', 'marital_status_WIDOWED', 'marital_status_0', 'hospital_stay_duration', 'procedure_225464', 'procedure_225802', 'procedure_227712', 'admission_type_DIRECT EMER.', 'admission_type_DIRECT OBSERVATION', 'admission_type_ELECTIVE', 'admission_type_EU OBSERVATION', 'admission_type_EW EMER.', 'admission_type_OBSERVATION ADMIT', 'admission_type_URGENT', 'admission_type_SURGICAL SAME DAY ADMISSION')
# % Combos Checked: 279 out of 22032 which is 1.26634%
