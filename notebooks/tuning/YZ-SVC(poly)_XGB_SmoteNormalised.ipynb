# %% [markdown]
# # Tuning Script

# %%
# Parameters subject to change in every script - involved in naming

MODEL = 'svc(poly)'
PREPROCESSING = 'smote_normalise'
TUNER = 'yangzhoub'
OPTIMISED_METRIC = 'f1'

# %% [markdown]
# ---

# %%
# detect whether this is a google environment

COLAB_ENVIRONMENT = False

try:
    from google.colab import drive
    drive.mount('/content/drive')
    COLAB_ENVIRONMENT = True
except:
    pass
# Out:
# Mounted at /content/drive

# %%
import sys
import os
import pickle

if COLAB_ENVIRONMENT:
    home_directory = './drive/MyDrive/LAB/COMP90089__GroupWork__Py/' # my home directory is stored in ./LAB of google drive
    if MODEL == 'ebr':
        # !pip install interpret==0.5.0
    elif MODEL == 'cbr':
        # !pip install catboost
    elif MODEL in ['tf', 'mlp']:
        # !pip install PyTorch2Sklearn
    # !pip install JXAutoML
else:
    home_directory = '../../'

from JXAutoML.YangZhouB_10CV import YangZhouB_10CV as Tuner

import pandas as pd
# Out:
# Collecting JXAutoML
#   Downloading JXAutoML-0.4.4-py3-none-any.whl.metadata (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.2/67.2 kB 5.3 MB/s eta 0:00:00
# Downloading JXAutoML-0.4.4-py3-none-any.whl (52 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.1/52.1 kB 4.2 MB/s eta 0:00:00
# Installing collected packages: JXAutoML
# Successfully installed JXAutoML-0.4.4

# %%
# Parameters that are same for every script

FOLDS = 10  # we have decided to do 10 fold validation

SEED = 42

TASK_TYPE = 'Classification'  # this task is a classification task

# we have decided to tune features as hp
TUNE_FEATURES_AS_HYPERPARAMETERS = True

# %% [markdown]
# ---

# %%
# model to use to tune
from sklearn.svm import SVC as clf

# what values to try for each hyperparameter
parameter_choices = {
    'C': (0.0001, 0.001, 0.01, 0.1, 1, 10),
    'degree': list(range(1, 10)),
    'tol': (0.0001, 0.001, 0.01, 0.1, 1, 10),
    'max_iter': (50, 100, 200, 400, 800, 1600),
    'gamma': ('scale', 'auto')
}

# what values to set non-tuneable parameters/hyperparameters
non_tunable_hyperparameters_dict = {
                                    'verbose': False,
                                    'decision_function_shape': 'ovr',
                                    'random_state': 42,
                                    'kernel': 'poly'
                                    }

# %% [markdown]
# ---

# %% [markdown]
# Read in and Prepare Data

# %%
# Import data and store as lists

train_x_list = []
train_y_list = []
val_x_list = []
val_y_list = []

for i in range(FOLDS):
    train_data = pd.read_csv(
        f'{home_directory}data/curated/modelling/{PREPROCESSING}/train_{i}.csv')
    val_data = pd.read_csv(
        f'{home_directory}data/curated/modelling/{PREPROCESSING}/val_{i}.csv')

    # get the correct rows for X and y
    train_x = train_data.drop(
        ['mortality_status', 'subject_id', 'hadm_id', 'stay_id'], axis=1)
    train_y = train_data['mortality_status']
    val_x = val_data.drop(
        ['mortality_status', 'subject_id', 'hadm_id', 'stay_id'], axis=1)
    val_y = val_data['mortality_status']

    train_x_list.append(train_x)
    train_y_list.append(train_y)
    val_x_list.append(val_x)
    val_y_list.append(val_y)

# %%
# Import feature importance ordering

with open(f'{home_directory}models/xgb_feature_importance_ordering_{PREPROCESSING}.pickle', 'rb') as f:
    feature_importance_ordering = pickle.load(f)

# %% [markdown]
# Set parameters

# %%
# initialisation
tuner = Tuner()

print('---')

# define what model we are tuning
tuner.read_in_model(clf, TASK_TYPE, optimised_metric=OPTIMISED_METRIC)

print('---')

# read in the data for training and validation
tuner.read_in_data(train_x_list, train_y_list, val_x_list, val_y_list)

print('---')

# set what hp values to tune
tuner.set_hyperparameters(parameter_choices)
# WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

# set up hp values that need to be changed from default but NOT to be tuned
tuner.set_non_tuneable_hyperparameters(non_tunable_hyperparameters_dict)

print('---')

# set up feature importance ordering

if TUNE_FEATURES_AS_HYPERPARAMETERS:
    tuner.set_features(feature_importance_ordering)
    # WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

try:  # try to read in previous results to continue tuning ...
    tuner.read_in_tuning_result_df(
        f'{home_directory}models/tuning/{TUNER}_{MODEL}_{PREPROCESSING}.csv')
except:
    print('No previous tuning data read in')

print('---')

# set up where to save the tuning result csv
tuner.set_tuning_result_saving_address(
    f'{home_directory}models/tuning/{TUNER}_{MODEL}_{PREPROCESSING}.csv')

print('---')

# set up where to save the current best model
tuner.set_best_model_saving_address(
    f'{home_directory}models/tmp_models/{TUNER}_{MODEL}_{PREPROCESSING}')
# Out:
# YangZhouB Initialised
# ---
# Successfully read in model <class 'sklearn.svm._classes.SVC'>, which is a Classification model optimising for f1
# ---
# Read in Train X data list
# Read in Train y data list
# Read in Val X data list
# Read in Val y data list
# ---
# Successfully recorded hyperparameter choices
# ---
# Successfully recorded non_tuneable_hyperparameter choices
# ---
# Successfully recorded tuneable feature combination choices and updated relevant internal structures
# ---
# No previous tuning data read in
# ---
# Successfully set tuning output address
# ---
# Successfully set best model output address

# %%
# ignore warnings

import warnings
warnings.filterwarnings("ignore")

# %%
# begin tuning ... (or continue training)

tuner.tune()
# Out:
# BEGIN TUNING
#
#
# STAGE ZERO: Tune all Cruise combinations
#
#
# Trained and Tested combination 1 of 186624, taking 0.08 seconds to get val score of 0.2767:
#                 {'C': 10, 'degree': 1, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 5},
#             Current best combo with val score 0.2767:
#                     {'C': 10, 'degree': 1, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 5}
# Trained and Tested combination 2 of 186624, taking 1.08 seconds to get val score of 0.0:
#                 {'C': 10, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 43},
#             Current best combo with val score 0.2767:
#                     {'C': 10, 'degree': 1, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 5}
# Trained and Tested combination 3 of 186624, taking 0.86 seconds to get val score of 0.3117:
#                 {'C': 10, 'degree': 9, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 20},
#             Current best combo with val score 0.3117:
#                     {'C': 10, 'degree': 9, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 20}
# Trained and Tested combination 4 of 186624, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 10, 'degree': 5, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 0},
#             Current best combo with val score 0.3117:
#                     {'C': 10, 'degree': 5, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 0}
# Trained and Tested combination 5 of 186624, taking 0.03 seconds to get val score of 0.1581:
#                 {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 35},
#             Current best combo with val score 0.3117:
#                     {'C': 10, 'degree': 5, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 0}
# Trained and Tested combination 6 of 186624, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 0.0001, 'degree': 1, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 15},
#             Current best combo with val score 0.3117:
#                     {'C': 10, 'degree': 5, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 0}
# Trained and Tested combination 7 of 186624, taking 0.03 seconds to get val score of 0.3119:
#                 {'C': 10, 'degree': 5, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 20},
#             Current best combo with val score 0.3119:
#                     {'C': 10, 'degree': 5, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 20}
# Trained and Tested combination 8 of 186624, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 10, 'degree': 1, 'tol': 10, 'max_iter': 50, 'gamma': 'scale', 'features': 5},
#             Current best combo with val score 0.3119:
#                     {'C': 10, 'degree': 5, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 20}
# Trained and Tested combination 9 of 186624, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 10, 'degree': 5, 'tol': 10, 'max_iter': 50, 'gamma': 'auto', 'features': 43},
#             Current best combo with val score 0.3119:
#                     {'C': 10, 'degree': 5, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 20}
# Trained and Tested combination 10 of 186624, taking 0.99 seconds to get val score of 0.2801:
#                 {'C': 0.0001, 'degree': 9, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 39},
#             Current best combo with val score 0.3119:
#                     {'C': 10, 'degree': 5, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 20}
# Trained and Tested combination 11 of 186624, taking 0.02 seconds to get val score of 0.1482:
#                 {'C': 10, 'degree': 1, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 15},
#             Current best combo with val score 0.3119:
#                     {'C': 10, 'degree': 5, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 20}
# Trained and Tested combination 12 of 186624, taking 0.91 seconds to get val score of 0.0:
#                 {'C': 10, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 47},
#             Current best combo with val score 0.3119:
#                     {'C': 10, 'degree': 5, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 20}
# Trained and Tested combination 13 of 186624, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 10, 'degree': 9, 'tol': 10, 'max_iter': 1600, 'gamma': 'scale', 'features': 39},
#             Current best combo with val score 0.3119:
#                     {'C': 10, 'degree': 5, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 20}
# Trained and Tested combination 14 of 186624, taking 0.03 seconds to get val score of 0.1869:
#                 {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 10},
#             Current best combo with val score 0.3119:
#                     {'C': 10, 'degree': 5, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 20}
# Trained and Tested combination 15 of 186624, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 10, 'degree': 5, 'tol': 10, 'max_iter': 1600, 'gamma': 'scale', 'features': 39},
#             Current best combo with val score 0.3119:
#                     {'C': 10, 'degree': 5, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 20}
# Trained and Tested combination 16 of 186624, taking 0.03 seconds to get val score of 0.2305:
#                 {'C': 10, 'degree': 9, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 30},
#             Current best combo with val score 0.3119:
#                     {'C': 10, 'degree': 5, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 20}
# Trained and Tested combination 17 of 186624, taking 0.98 seconds to get val score of 0.1838:
#                 {'C': 10, 'degree': 9, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 39},
#             Current best combo with val score 0.3119:
#                     {'C': 10, 'degree': 5, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 20}
# Trained and Tested combination 18 of 186624, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 10, 'degree': 5, 'tol': 10, 'max_iter': 50, 'gamma': 'auto', 'features': 20},
#             Current best combo with val score 0.3119:
#                     {'C': 10, 'degree': 5, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 20}
# Trained and Tested combination 19 of 186624, taking 0.82 seconds to get val score of 0.0:
#                 {'C': 10, 'degree': 9, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 39},
#             Current best combo with val score 0.3119:
#                     {'C': 10, 'degree': 5, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 20}
# Trained and Tested combination 20 of 186624, taking 0.02 seconds to get val score of 0.3117:
#                 {'C': 10, 'degree': 5, 'tol': 10, 'max_iter': 50, 'gamma': 'scale', 'features': 47},
#             Current best combo with val score 0.3119:
#                     {'C': 10, 'degree': 5, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 20}
# Trained and Tested combination 21 of 186624, taking 0.04 seconds to get val score of 0.3117:
#                 {'C': 0.0001, 'degree': 5, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 5},
#             Current best combo with val score 0.3119:
#                     {'C': 10, 'degree': 5, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 20}
# Trained and Tested combination 22 of 186624, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 10, 'degree': 1, 'tol': 10, 'max_iter': 50, 'gamma': 'scale', 'features': 35},
#             Current best combo with val score 0.3119:
#                     {'C': 10, 'degree': 5, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 20}
# Trained and Tested combination 23 of 186624, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 10, 'degree': 1, 'tol': 10, 'max_iter': 50, 'gamma': 'auto', 'features': 0},
#             Current best combo with val score 0.3119:
#                     {'C': 10, 'degree': 5, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 20}
# Trained and Tested combination 24 of 186624, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 0.0001, 'degree': 9, 'tol': 10, 'max_iter': 1600, 'gamma': 'scale', 'features': 39},
#             Current best combo with val score 0.3119:
#                     {'C': 10, 'degree': 5, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 20}
# Trained and Tested combination 25 of 186624, taking 0.03 seconds to get val score of 0.3117:
#                 {'C': 0.0001, 'degree': 9, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 25},
#             Current best combo with val score 0.3119:
#                     {'C': 10, 'degree': 5, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 20}
# Trained and Tested combination 26 of 186624, taking 0.0 seconds to get val score of 0.3117:
#                 {'C': 0.0001, 'degree': 9, 'tol': 10, 'max_iter': 50, 'gamma': 'scale', 'features': 0},
#             Current best combo with val score 0.3119:
#                     {'C': 10, 'degree': 5, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 20}
# Trained and Tested combination 27 of 186624, taking 0.0 seconds to get val score of 0.3117:
#                 {'C': 0.0001, 'degree': 1, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 5},
#             Current best combo with val score 0.3119:
#                     {'C': 10, 'degree': 5, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 20}
# Trained and Tested combination 28 of 186624, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 0.0001, 'degree': 9, 'tol': 10, 'max_iter': 50, 'gamma': 'auto', 'features': 15},
#             Current best combo with val score 0.3119:
#                     {'C': 10, 'degree': 5, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 20}
# Trained and Tested combination 29 of 186624, taking 0.02 seconds to get val score of 0.1123:
#                 {'C': 10, 'degree': 5, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 10},
#             Current best combo with val score 0.3119:
#                     {'C': 10, 'degree': 5, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 20}
# Trained and Tested combination 30 of 186624, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 10, 'degree': 9, 'tol': 10, 'max_iter': 50, 'gamma': 'auto', 'features': 25},
#             Current best combo with val score 0.3119:
#                     {'C': 10, 'degree': 5, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 20}
# Trained and Tested combination 31 of 186624, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 10, 'degree': 1, 'tol': 10, 'max_iter': 50, 'gamma': 'scale', 'features': 20},
#             Current best combo with val score 0.3119:
#                     {'C': 10, 'degree': 5, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 20}
# Trained and Tested combination 32 of 186624, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 10, 'degree': 5, 'tol': 10, 'max_iter': 1600, 'gamma': 'scale', 'features': 43},
#             Current best combo with val score 0.3119:
#                     {'C': 10, 'degree': 5, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 20}
# Trained and Tested combination 33 of 186624, taking 0.0 seconds to get val score of 0.3117:
#                 {'C': 10, 'degree': 5, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 0},
#             Current best combo with val score 0.3119:
#                     {'C': 10, 'degree': 5, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 20}
# Trained and Tested combination 34 of 186624, taking 0.01 seconds to get val score of 0.3103:
#                 {'C': 10, 'degree': 9, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 0},
#             Current best combo with val score 0.3119:
#                     {'C': 10, 'degree': 5, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 20}
# Trained and Tested combination 35 of 186624, taking 0.03 seconds to get val score of 0.3117:
#                 {'C': 10, 'degree': 9, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 20},
#             Current best combo with val score 0.3119:
#                     {'C': 10, 'degree': 5, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 20}
# Trained and Tested combination 36 of 186624, taking 0.52 seconds to get val score of 0.0:
#                 {'C': 10, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 30},
#             Current best combo with val score 0.3119:
#                     {'C': 10, 'degree': 5, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 20}
# Trained and Tested combination 37 of 186624, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 0.0001, 'degree': 1, 'tol': 10, 'max_iter': 1600, 'gamma': 'scale', 'features': 35},
#             Current best combo with val score 0.3119:
#                     {'C': 10, 'degree': 5, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 20}
# Trained and Tested combination 38 of 186624, taking 1.08 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 43},
#             Current best combo with val score 0.3119:
#                     {'C': 10, 'degree': 5, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 20}
# Trained and Tested combination 39 of 186624, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 0.0001, 'degree': 1, 'tol': 10, 'max_iter': 1600, 'gamma': 'scale', 'features': 43},
#             Current best combo with val score 0.3119:
#                     {'C': 10, 'degree': 5, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 20}
# Trained and Tested combination 40 of 186624, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 0.0001, 'degree': 1, 'tol': 10, 'max_iter': 50, 'gamma': 'auto', 'features': 30},
#             Current best combo with val score 0.3119:
#                     {'C': 10, 'degree': 5, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 20}
# Trained and Tested combination 41 of 186624, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 0.0001, 'degree': 1, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 20},
#             Current best combo with val score 0.3119:
#                     {'C': 10, 'degree': 5, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 20}
# Trained and Tested combination 42 of 186624, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 10, 'degree': 9, 'tol': 10, 'max_iter': 1600, 'gamma': 'scale', 'features': 25},
#             Current best combo with val score 0.3119:
#                     {'C': 10, 'degree': 5, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 20}
# Trained and Tested combination 43 of 186624, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 10, 'degree': 9, 'tol': 10, 'max_iter': 50, 'gamma': 'auto', 'features': 30},
#             Current best combo with val score 0.3119:
#                     {'C': 10, 'degree': 5, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 20}
# Trained and Tested combination 44 of 186624, taking 1.47 seconds to get val score of 0.3118:
#                 {'C': 0.0001, 'degree': 9, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 10},
#             Current best combo with val score 0.3119:
#                     {'C': 10, 'degree': 5, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 20}
# Trained and Tested combination 45 of 186624, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 10, 'degree': 9, 'tol': 10, 'max_iter': 1600, 'gamma': 'scale', 'features': 47},
#             Current best combo with val score 0.3119:
#                     {'C': 10, 'degree': 5, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 20}
# Trained and Tested combination 46 of 186624, taking 0.03 seconds to get val score of 0.3117:
#                 {'C': 0.0001, 'degree': 9, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 20},
#             Current best combo with val score 0.3119:
#                     {'C': 10, 'degree': 5, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 20}
# Trained and Tested combination 47 of 186624, taking 0.03 seconds to get val score of 0.0736:
#                 {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 47},
#             Current best combo with val score 0.3119:
#                     {'C': 10, 'degree': 5, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 20}
# Trained and Tested combination 48 of 186624, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 0.0001, 'degree': 5, 'tol': 10, 'max_iter': 50, 'gamma': 'scale', 'features': 43},
#             Current best combo with val score 0.3119:
#                     {'C': 10, 'degree': 5, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 20}
# Trained and Tested combination 49 of 186624, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 10, 'degree': 1, 'tol': 10, 'max_iter': 50, 'gamma': 'auto', 'features': 43},
#             Current best combo with val score 0.3119:
#                     {'C': 10, 'degree': 5, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 20}
# Trained and Tested combination 50 of 186624, taking 0.0 seconds to get val score of 0.3117:
#                 {'C': 10, 'degree': 9, 'tol': 10, 'max_iter': 50, 'gamma': 'auto', 'features': 0},
#             Current best combo with val score 0.3119:
#                     {'C': 10, 'degree': 5, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 20}
# Trained and Tested combination 51 of 186624, taking 0.86 seconds to get val score of 0.3117:
#                 {'C': 0.0001, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 20},
#             Current best combo with val score 0.3119:
#                     {'C': 10, 'degree': 5, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 20}
# Trained and Tested combination 52 of 186624, taking 0.0 seconds to get val score of 0.3117:
#                 {'C': 10, 'degree': 1, 'tol': 10, 'max_iter': 1600, 'gamma': 'scale', 'features': 0},
#             Current best combo with val score 0.3119:
#                     {'C': 10, 'degree': 5, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 20}
# Trained and Tested combination 53 of 186624, taking 0.75 seconds to get val score of 0.0:
#                 {'C': 10, 'degree': 9, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 35},
#             Current best combo with val score 0.3119:
#                     {'C': 10, 'degree': 5, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 20}
# Trained and Tested combination 54 of 186624, taking 0.74 seconds to get val score of 0.3117:
#                 {'C': 10, 'degree': 9, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 5},
#             Current best combo with val score 0.3119:
#                     {'C': 10, 'degree': 5, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 20}
# Trained and Tested combination 55 of 186624, taking 0.03 seconds to get val score of 0.3117:
#                 {'C': 10, 'degree': 5, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 10},
#             Current best combo with val score 0.3119:
#                     {'C': 10, 'degree': 5, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 20}
# Trained and Tested combination 56 of 186624, taking 0.34 seconds to get val score of 0.081:
#                 {'C': 10, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 35},
#             Current best combo with val score 0.3119:
#                     {'C': 10, 'degree': 5, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 20}
# Trained and Tested combination 57 of 186624, taking 0.03 seconds to get val score of 0.1061:
#                 {'C': 10, 'degree': 1, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 10},
#             Current best combo with val score 0.3119:
#                     {'C': 10, 'degree': 5, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 20}
# Trained and Tested combination 58 of 186624, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 0.0001, 'degree': 1, 'tol': 10, 'max_iter': 50, 'gamma': 'scale', 'features': 25},
#             Current best combo with val score 0.3119:
#                     {'C': 10, 'degree': 5, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 20}
# Trained and Tested combination 59 of 186624, taking 0.61 seconds to get val score of 0.1066:
#                 {'C': 10, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 20},
#             Current best combo with val score 0.3119:
#                     {'C': 10, 'degree': 5, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 20}
# Trained and Tested combination 60 of 186624, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 10, 'degree': 1, 'tol': 10, 'max_iter': 50, 'gamma': 'auto', 'features': 25},
#             Current best combo with val score 0.3119:
#                     {'C': 10, 'degree': 5, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 20}
# Trained and Tested combination 61 of 186624, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 10, 'degree': 5, 'tol': 10, 'max_iter': 50, 'gamma': 'scale', 'features': 30},
#             Current best combo with val score 0.3119:
#                     {'C': 10, 'degree': 5, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 20}
# Trained and Tested combination 62 of 186624, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 10, 'degree': 1, 'tol': 10, 'max_iter': 50, 'gamma': 'auto', 'features': 15},
#             Current best combo with val score 0.3119:
#                     {'C': 10, 'degree': 5, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 20}
# Trained and Tested combination 63 of 186624, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 0.0001, 'degree': 9, 'tol': 10, 'max_iter': 50, 'gamma': 'auto', 'features': 20},
#             Current best combo with val score 0.3119:
#                     {'C': 10, 'degree': 5, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 20}
# Trained and Tested combination 64 of 186624, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 10, 'degree': 1, 'tol': 10, 'max_iter': 1600, 'gamma': 'scale', 'features': 25},
#             Current best combo with val score 0.3119:
#                     {'C': 10, 'degree': 5, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 20}
# Trained and Tested combination 65 of 186624, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 0.0001, 'degree': 5, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 43},
#             Current best combo with val score 0.3119:
#                     {'C': 10, 'degree': 5, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 20}
# Trained and Tested combination 66 of 186624, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 0.0001, 'degree': 5, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 20},
#             Current best combo with val score 0.3119:
#                     {'C': 10, 'degree': 5, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 20}
# Trained and Tested combination 67 of 186624, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 10, 'degree': 9, 'tol': 10, 'max_iter': 50, 'gamma': 'scale', 'features': 5},
#             Current best combo with val score 0.3119:
#                     {'C': 10, 'degree': 5, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 20}
# Trained and Tested combination 68 of 186624, taking 0.76 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 30},
#             Current best combo with val score 0.3119:
#                     {'C': 10, 'degree': 5, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 20}
# Trained and Tested combination 69 of 186624, taking 0.04 seconds to get val score of 0.0136:
#                 {'C': 10, 'degree': 5, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 43},
#             Current best combo with val score 0.3119:
#                     {'C': 10, 'degree': 5, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 20}
# Trained and Tested combination 70 of 186624, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 10, 'degree': 9, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 15},
#             Current best combo with val score 0.3119:
#                     {'C': 10, 'degree': 5, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 20}
# Trained and Tested combination 71 of 186624, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 10, 'degree': 1, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 35},
#             Current best combo with val score 0.3119:
#                     {'C': 10, 'degree': 5, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 20}
# Trained and Tested combination 72 of 186624, taking 0.99 seconds to get val score of 0.3117:
#                 {'C': 0.0001, 'degree': 9, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 25},
#             Current best combo with val score 0.3119:
#                     {'C': 10, 'degree': 5, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 20}
# Trained and Tested combination 73 of 186624, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 0.0001, 'degree': 5, 'tol': 10, 'max_iter': 50, 'gamma': 'auto', 'features': 0},
#             Current best combo with val score 0.3119:
#                     {'C': 10, 'degree': 5, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 20}
# Trained and Tested combination 74 of 186624, taking 1.46 seconds to get val score of 0.0937:
#                 {'C': 0.0001, 'degree': 9, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 47},
#             Current best combo with val score 0.3119:
#                     {'C': 10, 'degree': 5, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 20}
# Trained and Tested combination 75 of 186624, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 10, 'degree': 5, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 35},
#             Current best combo with val score 0.3119:
#                     {'C': 10, 'degree': 5, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 20}
# Trained and Tested combination 76 of 186624, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 0.0001, 'degree': 9, 'tol': 10, 'max_iter': 1600, 'gamma': 'scale', 'features': 15},
#             Current best combo with val score 0.3119:
#                     {'C': 10, 'degree': 5, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 20}
# Trained and Tested combination 77 of 186624, taking 1.0 seconds to get val score of 0.0292:
#                 {'C': 0.0001, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 39},
#             Current best combo with val score 0.3119:
#                     {'C': 10, 'degree': 5, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 20}
# Trained and Tested combination 78 of 186624, taking 0.03 seconds to get val score of 0.3118:
#                 {'C': 10, 'degree': 9, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 30},
#             Current best combo with val score 0.3119:
#                     {'C': 10, 'degree': 5, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 20}
# Trained and Tested combination 79 of 186624, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 10, 'degree': 9, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 47},
#             Current best combo with val score 0.3119:
#                     {'C': 10, 'degree': 5, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 20}
# Trained and Tested combination 80 of 186624, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 10, 'degree': 9, 'tol': 10, 'max_iter': 50, 'gamma': 'scale', 'features': 30},
#             Current best combo with val score 0.3119:
#                     {'C': 10, 'degree': 5, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 20}
# Trained and Tested combination 81 of 186624, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 0.0001, 'degree': 9, 'tol': 10, 'max_iter': 1600, 'gamma': 'scale', 'features': 5},
#             Current best combo with val score 0.3119:
#                     {'C': 10, 'degree': 5, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 20}
# Trained and Tested combination 82 of 186624, taking 0.03 seconds to get val score of 0.1581:
#                 {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 35},
#             Current best combo with val score 0.3119:
#                     {'C': 10, 'degree': 5, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 20}
# Trained and Tested combination 83 of 186624, taking 0.29 seconds to get val score of 0.3108:
#                 {'C': 10, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 0},
#             Current best combo with val score 0.3119:
#                     {'C': 10, 'degree': 5, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 20}
# Trained and Tested combination 84 of 186624, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 10, 'degree': 5, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 39},
#             Current best combo with val score 0.3119:
#                     {'C': 10, 'degree': 5, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 20}
# Trained and Tested combination 85 of 186624, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 10, 'degree': 1, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 0},
#             Current best combo with val score 0.3119:
#                     {'C': 10, 'degree': 5, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 20}
# Trained and Tested combination 86 of 186624, taking 0.03 seconds to get val score of 0.2797:
#                 {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 30},
#             Current best combo with val score 0.3119:
#                     {'C': 10, 'degree': 5, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 20}
# Trained and Tested combination 87 of 186624, taking 0.03 seconds to get val score of 0.3117:
#                 {'C': 0.0001, 'degree': 9, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 25},
#             Current best combo with val score 0.3119:
#                     {'C': 10, 'degree': 5, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 20}
# Trained and Tested combination 88 of 186624, taking 0.02 seconds to get val score of 0.2498:
#                 {'C': 10, 'degree': 9, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 5},
#             Current best combo with val score 0.3119:
#                     {'C': 10, 'degree': 5, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 20}
# Trained and Tested combination 89 of 186624, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 0.0001, 'degree': 1, 'tol': 10, 'max_iter': 50, 'gamma': 'auto', 'features': 39},
#             Current best combo with val score 0.3119:
#                     {'C': 10, 'degree': 5, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 20}
# Trained and Tested combination 90 of 186624, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 10, 'degree': 5, 'tol': 10, 'max_iter': 50, 'gamma': 'scale', 'features': 15},
#             Current best combo with val score 0.3119:
#                     {'C': 10, 'degree': 5, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 20}
# Trained and Tested combination 91 of 186624, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 10, 'degree': 5, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 47},
#             Current best combo with val score 0.3119:
#                     {'C': 10, 'degree': 5, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 20}
# Trained and Tested combination 92 of 186624, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 10, 'degree': 5, 'tol': 10, 'max_iter': 1600, 'gamma': 'scale', 'features': 47},
#             Current best combo with val score 0.3119:
#                     {'C': 10, 'degree': 5, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 20}
# Trained and Tested combination 93 of 186624, taking 0.04 seconds to get val score of 0.3117:
#                 {'C': 0.0001, 'degree': 9, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 15},
#             Current best combo with val score 0.3119:
#                     {'C': 10, 'degree': 5, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 20}
# Trained and Tested combination 94 of 186624, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 0.0001, 'degree': 5, 'tol': 10, 'max_iter': 1600, 'gamma': 'scale', 'features': 35},
#             Current best combo with val score 0.3119:
#                     {'C': 10, 'degree': 5, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 20}
# Trained and Tested combination 95 of 186624, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 0.0001, 'degree': 1, 'tol': 10, 'max_iter': 1600, 'gamma': 'scale', 'features': 10},
#             Current best combo with val score 0.3119:
#                     {'C': 10, 'degree': 5, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 20}
# Trained and Tested combination 96 of 186624, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 10, 'degree': 5, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 30},
#             Current best combo with val score 0.3119:
#                     {'C': 10, 'degree': 5, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 20}
# Trained and Tested combination 97 of 186624, taking 1.24 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 35},
#             Current best combo with val score 0.3119:
#                     {'C': 10, 'degree': 5, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 20}
# Trained and Tested combination 98 of 186624, taking 0.02 seconds to get val score of 0.2581:
#                 {'C': 10, 'degree': 5, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 15},
#             Current best combo with val score 0.3119:
#                     {'C': 10, 'degree': 5, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 20}
# Trained and Tested combination 99 of 186624, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 0.0001, 'degree': 5, 'tol': 10, 'max_iter': 1600, 'gamma': 'scale', 'features': 43},
#             Current best combo with val score 0.3119:
#                     {'C': 10, 'degree': 5, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 20}
# Trained and Tested combination 100 of 186624, taking 0.39 seconds to get val score of 0.0:
#                 {'C': 10, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 20},
#             Current best combo with val score 0.3119:
#                     {'C': 10, 'degree': 5, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 20}
# Trained and Tested combination 101 of 186624, taking 0.05 seconds to get val score of 0.2806:
#                 {'C': 0.0001, 'degree': 9, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 39},
#             Current best combo with val score 0.3119:
#                     {'C': 10, 'degree': 5, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 20}
# Trained and Tested combination 102 of 186624, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 0.0001, 'degree': 1, 'tol': 10, 'max_iter': 50, 'gamma': 'scale', 'features': 0},
#             Current best combo with val score 0.3119:
#                     {'C': 10, 'degree': 5, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 20}
# Trained and Tested combination 103 of 186624, taking 1.06 seconds to get val score of 0.3117:
#                 {'C': 10, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 15},
#             Current best combo with val score 0.3119:
#                     {'C': 10, 'degree': 5, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 20}
# Trained and Tested combination 104 of 186624, taking 1.11 seconds to get val score of 0.0965:
#                 {'C': 0.0001, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 43},
#             Current best combo with val score 0.3119:
#                     {'C': 10, 'degree': 5, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 20}
# Trained and Tested combination 105 of 186624, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 0.0001, 'degree': 1, 'tol': 10, 'max_iter': 50, 'gamma': 'auto', 'features': 15},
#             Current best combo with val score 0.3119:
#                     {'C': 10, 'degree': 5, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 20}
# Trained and Tested combination 106 of 186624, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 0.0001, 'degree': 5, 'tol': 10, 'max_iter': 50, 'gamma': 'scale', 'features': 30},
#             Current best combo with val score 0.3119:
#                     {'C': 10, 'degree': 5, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 20}
# Trained and Tested combination 107 of 186624, taking 0.71 seconds to get val score of 0.0065:
#                 {'C': 10, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10},
#             Current best combo with val score 0.3119:
#                     {'C': 10, 'degree': 5, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 20}
# Trained and Tested combination 108 of 186624, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 0.0001, 'degree': 9, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 25},
#             Current best combo with val score 0.3119:
#                     {'C': 10, 'degree': 5, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 20}
# Trained and Tested combination 109 of 186624, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 0.0001, 'degree': 1, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 25},
#             Current best combo with val score 0.3119:
#                     {'C': 10, 'degree': 5, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 20}
# Trained and Tested combination 110 of 186624, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 10, 'degree': 9, 'tol': 10, 'max_iter': 50, 'gamma': 'scale', 'features': 20},
#             Current best combo with val score 0.3119:
#                     {'C': 10, 'degree': 5, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 20}
# Trained and Tested combination 111 of 186624, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 0.0001, 'degree': 5, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 5},
#             Current best combo with val score 0.3119:
#                     {'C': 10, 'degree': 5, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 20}
# Trained and Tested combination 112 of 186624, taking 0.9 seconds to get val score of 0.2805:
#                 {'C': 0.0001, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 47},
#             Current best combo with val score 0.3119:
#                     {'C': 10, 'degree': 5, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 20}
# Trained and Tested combination 113 of 186624, taking 0.03 seconds to get val score of 0.3117:
#                 {'C': 0.0001, 'degree': 9, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 10},
#             Current best combo with val score 0.3119:
#                     {'C': 10, 'degree': 5, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 20}
# Trained and Tested combination 114 of 186624, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 0.0001, 'degree': 1, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 10},
#             Current best combo with val score 0.3119:
#                     {'C': 10, 'degree': 5, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 20}
# Trained and Tested combination 115 of 186624, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 10, 'degree': 5, 'tol': 10, 'max_iter': 50, 'gamma': 'scale', 'features': 5},
#             Current best combo with val score 0.3119:
#                     {'C': 10, 'degree': 5, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 20}
# Trained and Tested combination 116 of 186624, taking 0.03 seconds to get val score of 0.2797:
#                 {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 30},
#             Current best combo with val score 0.3119:
#                     {'C': 10, 'degree': 5, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 20}
# Trained and Tested combination 117 of 186624, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 10, 'degree': 1, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 15},
#             Current best combo with val score 0.3119:
#                     {'C': 10, 'degree': 5, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 20}
# Trained and Tested combination 118 of 186624, taking 0.02 seconds to get val score of 0.2455:
#                 {'C': 10, 'degree': 1, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 5},
#             Current best combo with val score 0.3119:
#                     {'C': 10, 'degree': 5, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 20}
# Trained and Tested combination 119 of 186624, taking 0.04 seconds to get val score of 0.2044:
#                 {'C': 10, 'degree': 1, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 20},
#             Current best combo with val score 0.3119:
#                     {'C': 10, 'degree': 5, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 20}
# Trained and Tested combination 120 of 186624, taking 0.04 seconds to get val score of 0.3119:
#                 {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 20},
#             Current best combo with val score 0.3119:
#                     {'C': 10, 'degree': 5, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 20}
# Trained and Tested combination 121 of 186624, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 0.0001, 'degree': 1, 'tol': 10, 'max_iter': 50, 'gamma': 'auto', 'features': 20},
#             Current best combo with val score 0.3119:
#                     {'C': 10, 'degree': 5, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 20}
# Trained and Tested combination 122 of 186624, taking 1.28 seconds to get val score of 0.3118:
#                 {'C': 0.0001, 'degree': 9, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 30},
#             Current best combo with val score 0.3119:
#                     {'C': 10, 'degree': 5, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 20}
# Trained and Tested combination 123 of 186624, taking 0.0 seconds to get val score of 0.3117:
#                 {'C': 0.0001, 'degree': 5, 'tol': 10, 'max_iter': 50, 'gamma': 'scale', 'features': 0},
#             Current best combo with val score 0.3119:
#                     {'C': 10, 'degree': 5, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 20}
# Trained and Tested combination 124 of 186624, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 10, 'degree': 5, 'tol': 10, 'max_iter': 50, 'gamma': 'auto', 'features': 35},
#             Current best combo with val score 0.3119:
#                     {'C': 10, 'degree': 5, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 20}
# Trained and Tested combination 125 of 186624, taking 0.01 seconds to get val score of 0.3068:
#                 {'C': 0.0001, 'degree': 9, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 0},
#             Current best combo with val score 0.3119:
#                     {'C': 10, 'degree': 5, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 20}
# Trained and Tested combination 126 of 186624, taking 0.0 seconds to get val score of 0.3117:
#                 {'C': 10, 'degree': 1, 'tol': 10, 'max_iter': 50, 'gamma': 'auto', 'features': 5},
#             Current best combo with val score 0.3119:
#                     {'C': 10, 'degree': 5, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 20}
# Trained and Tested combination 127 of 186624, taking 0.03 seconds to get val score of 0.2805:
#                 {'C': 0.0001, 'degree': 5, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 35},
#             Current best combo with val score 0.3119:
#                     {'C': 10, 'degree': 5, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 20}
# Trained and Tested combination 128 of 186624, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 0.0001, 'degree': 9, 'tol': 10, 'max_iter': 50, 'gamma': 'scale', 'features': 20},
#             Current best combo with val score 0.3119:
#                     {'C': 10, 'degree': 5, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 20}
# Trained and Tested combination 129 of 186624, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 0.0001, 'degree': 5, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 15},
#             Current best combo with val score 0.3119:
#                     {'C': 10, 'degree': 5, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 20}
# Trained and Tested combination 130 of 186624, taking 0.0 seconds to get val score of 0.3117:
#                 {'C': 0.0001, 'degree': 9, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 5},
#             Current best combo with val score 0.3119:
#                     {'C': 10, 'degree': 5, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 20}
# Trained and Tested combination 131 of 186624, taking 0.59 seconds to get val score of 0.0:
#                 {'C': 10, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 39},
#             Current best combo with val score 0.3119:
#                     {'C': 10, 'degree': 5, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 20}
# Trained and Tested combination 132 of 186624, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 10, 'degree': 5, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 5},
#             Current best combo with val score 0.3119:
# ...
#
# Cruising Coordrdinate 375 of 528
#
# Cruising Coordrdinate 376 of 528
#
# Cruising Coordrdinate 377 of 528
#
# Cruising Coordrdinate 378 of 528
#
# Cruising Coordrdinate 379 of 528
#
# Cruising Coordrdinate 380 of 528
#
# Cruising Coordrdinate 381 of 528
#
# Cruising Coordrdinate 382 of 528
#
# Cruising Coordrdinate 383 of 528
#
# Cruising Coordrdinate 384 of 528
#
# Cruising Coordrdinate 385 of 528
#
# Cruising Coordrdinate 386 of 528
#
# Cruising Coordrdinate 387 of 528
#
# Cruising Coordrdinate 388 of 528
#
# Cruising Coordrdinate 389 of 528
#
# Cruising Coordrdinate 390 of 528
#
# Cruising Coordrdinate 391 of 528
#
# Cruising Coordrdinate 392 of 528
#
# Cruising Coordrdinate 393 of 528
#
# Cruising Coordrdinate 394 of 528
#
# Cruising Coordrdinate 395 of 528
#
# Cruising Coordrdinate 396 of 528
#
# Cruising Coordrdinate 397 of 528
#
# Cruising Coordrdinate 398 of 528
#
# Cruising Coordrdinate 399 of 528
#
# Cruising Coordrdinate 400 of 528
#
# Cruising Coordrdinate 401 of 528
#
# Cruising Coordrdinate 402 of 528
#
# Cruising Coordrdinate 403 of 528
#
# Cruising Coordrdinate 404 of 528
#
# Cruising Coordrdinate 405 of 528
#
# Cruising Coordrdinate 406 of 528
#
# Cruising Coordrdinate 407 of 528
#
# Cruising Coordrdinate 408 of 528
#
# Cruising Coordrdinate 409 of 528
#
# Cruising Coordrdinate 410 of 528
#
# Cruising Coordrdinate 411 of 528
#
# Cruising Coordrdinate 412 of 528
#
# Cruising Coordrdinate 413 of 528
#
# Cruising Coordrdinate 414 of 528
#
# Cruising Coordrdinate 415 of 528
#
# Cruising Coordrdinate 416 of 528
#
# Cruising Coordrdinate 417 of 528
#
# Cruising Coordrdinate 418 of 528
#
# Cruising Coordrdinate 419 of 528
#
# Cruising Coordrdinate 420 of 528
#
# Cruising Coordrdinate 421 of 528
#
# Cruising Coordrdinate 422 of 528
#
# Cruising Coordrdinate 423 of 528
#
# Cruising Coordrdinate 424 of 528
#
# Cruising Coordrdinate 425 of 528
#
# Cruising Coordrdinate 426 of 528
#
# Cruising Coordrdinate 427 of 528
#
# Cruising Coordrdinate 428 of 528
#
# Cruising Coordrdinate 429 of 528
#
# Cruising Coordrdinate 430 of 528
#
# Cruising Coordrdinate 431 of 528
#
# Cruising Coordrdinate 432 of 528
#
# Cruising Coordrdinate 433 of 528
#
# Cruising Coordrdinate 434 of 528
#
# Cruising Coordrdinate 435 of 528
#
# Cruising Coordrdinate 436 of 528
#
# Cruising Coordrdinate 437 of 528
#
# Cruising Coordrdinate 438 of 528
#
# Cruising Coordrdinate 439 of 528
#
# Cruising Coordrdinate 440 of 528
#
# Cruising Coordrdinate 441 of 528
#
# Cruising Coordrdinate 442 of 528
#
# Cruising Coordrdinate 443 of 528
#
# Cruising Coordrdinate 444 of 528
#
# Cruising Coordrdinate 445 of 528
#
# Cruising Coordrdinate 446 of 528
#
# Cruising Coordrdinate 447 of 528
#
# Cruising Coordrdinate 448 of 528
#
# Cruising Coordrdinate 449 of 528
#
# Cruising Coordrdinate 450 of 528
#
# Cruising Coordrdinate 451 of 528
#
# Cruising Coordrdinate 452 of 528
#
# Cruising Coordrdinate 453 of 528
#
# Cruising Coordrdinate 454 of 528
#
# Cruising Coordrdinate 455 of 528
#
# Cruising Coordrdinate 456 of 528
#
# Cruising Coordrdinate 457 of 528
#
# Cruising Coordrdinate 458 of 528
#
# Cruising Coordrdinate 459 of 528
#
# Cruising Coordrdinate 460 of 528
#
# Cruising Coordrdinate 461 of 528
#
# Cruising Coordrdinate 462 of 528
#
# Cruising Coordrdinate 463 of 528
#
# Cruising Coordrdinate 464 of 528
#
# Cruising Coordrdinate 465 of 528
#
# Cruising Coordrdinate 466 of 528
#
# Cruising Coordrdinate 467 of 528
#
# Cruising Coordrdinate 468 of 528
#
# Cruising Coordrdinate 469 of 528
#
# Cruising Coordrdinate 470 of 528
#
# Cruising Coordrdinate 471 of 528
#
# Cruising Coordrdinate 472 of 528
#
# Cruising Coordrdinate 473 of 528
#
# Cruising Coordrdinate 474 of 528
#
# Cruising Coordrdinate 475 of 528
#
# Cruising Coordrdinate 476 of 528
#
# Cruising Coordrdinate 477 of 528
#
# Cruising Coordrdinate 478 of 528
#
# Cruising Coordrdinate 479 of 528
#
# Cruising Coordrdinate 480 of 528
#
# Cruising Coordrdinate 481 of 528
#
# Cruising Coordrdinate 482 of 528
#
# Cruising Coordrdinate 483 of 528
#
# Cruising Coordrdinate 484 of 528
#
# Cruising Coordrdinate 485 of 528
#
# Cruising Coordrdinate 486 of 528
#
# Cruising Coordrdinate 487 of 528
#
# Cruising Coordrdinate 488 of 528
#
# Cruising Coordrdinate 489 of 528
#
# Cruising Coordrdinate 490 of 528
#
# Cruising Coordrdinate 491 of 528
#
# Cruising Coordrdinate 492 of 528
#
# Cruising Coordrdinate 493 of 528
#
# Cruising Coordrdinate 494 of 528
#
# Cruising Coordrdinate 495 of 528
#
# Cruising Coordrdinate 496 of 528
#
# Cruising Coordrdinate 497 of 528
#
# Cruising Coordrdinate 498 of 528
#
# Cruising Coordrdinate 499 of 528
#
# Cruising Coordrdinate 500 of 528
#
# Cruising Coordrdinate 501 of 528
#
# Cruising Coordrdinate 502 of 528
#
# Cruising Coordrdinate 503 of 528
#
# Cruising Coordrdinate 504 of 528
#
# Cruising Coordrdinate 505 of 528
#
# Cruising Coordrdinate 506 of 528
#
# Cruising Coordrdinate 507 of 528
#
# Cruising Coordrdinate 508 of 528
#
# Cruising Coordrdinate 509 of 528
#
# Cruising Coordrdinate 510 of 528
#
# Cruising Coordrdinate 511 of 528
#
# Cruising Coordrdinate 512 of 528
#
# Cruising Coordrdinate 513 of 528
#
# Cruising Coordrdinate 514 of 528
#
# Cruising Coordrdinate 515 of 528
#
# Cruising Coordrdinate 516 of 528
#
# Cruising Coordrdinate 517 of 528
#
# Cruising Coordrdinate 518 of 528
#
# Cruising Coordrdinate 519 of 528
#
# Cruising Coordrdinate 520 of 528
#
# Cruising Coordrdinate 521 of 528
#
# Cruising Coordrdinate 522 of 528
#
# Cruising Coordrdinate 523 of 528
#
# Cruising Coordrdinate 524 of 528
#
# Cruising Coordrdinate 525 of 528
#
# Cruising Coordrdinate 526 of 528
#
# Cruising Coordrdinate 527 of 528
#
# Cruise suspended due to suspicious case
# Guidance: round 1
#
# 	round 1 iteration:  0
#
# Trained and Tested combination 607 of 186624, taking 0.82 seconds to get val score of 0.4468:
#                 {'C': 0.001, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 20},
#             Current best combo with val score 0.4621:
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 20}
# Trained and Tested combination 608 of 186624, taking 1.29 seconds to get val score of 0.3476:
#                 {'C': 0.0001, 'degree': 2, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 20},
#             Current best combo with val score 0.4621:
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 20}
# Trained and Tested combination 609 of 186624, taking 0.82 seconds to get val score of 0.4529:
#                 {'C': 0.0001, 'degree': 1, 'tol': 0.001, 'max_iter': 1600, 'gamma': 'scale', 'features': 20},
#             Current best combo with val score 0.4621:
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 20}
# Trained and Tested combination 610 of 186624, taking 0.38 seconds to get val score of 0.3117:
#                 {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 800, 'gamma': 'scale', 'features': 20},
#             Current best combo with val score 0.4621:
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 20}
# Already Trained and Tested combination (val score of 0.4621):
#             {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 20}
#             Current best combo (with val score 0.4621):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 20}
#         Has trained 610 of 186624 combinations so far
# Trained and Tested combination 611 of 186624, taking 0.8 seconds to get val score of 0.3624:
#                 {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 19},
#             Current best combo with val score 0.4621:
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 20}
# Trained and Tested combination 612 of 186624, taking 1.3 seconds to get val score of 0.247:
#                 {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 21},
#             Current best combo with val score 0.4621:
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 20}
# 	round 1 iteration:  1
#
# Trained and Tested combination 613 of 186624, taking 0.83 seconds to get val score of 0.4468:
#                 {'C': 0.001, 'degree': 1, 'tol': 0.001, 'max_iter': 1600, 'gamma': 'scale', 'features': 20},
#             Current best combo with val score 0.4621:
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 20}
# Trained and Tested combination 614 of 186624, taking 0.85 seconds to get val score of 0.3476:
#                 {'C': 0.0001, 'degree': 2, 'tol': 0.001, 'max_iter': 1600, 'gamma': 'scale', 'features': 20},
#             Current best combo with val score 0.4621:
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 20}
# Already Trained and Tested combination (val score of 0.4529):
#             {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 20}
#             Current best combo (with val score 0.4621):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 20}
#         Has trained 614 of 186624 combinations so far
# Trained and Tested combination 615 of 186624, taking 0.82 seconds to get val score of 0.4529:
#                 {'C': 0.0001, 'degree': 1, 'tol': 0.01, 'max_iter': 1600, 'gamma': 'scale', 'features': 20},
#             Current best combo with val score 0.4621:
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 20}
# Trained and Tested combination 616 of 186624, taking 0.61 seconds to get val score of 0.3117:
#                 {'C': 0.0001, 'degree': 1, 'tol': 0.001, 'max_iter': 800, 'gamma': 'scale', 'features': 20},
#             Current best combo with val score 0.4621:
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 20}
# Already Trained and Tested combination (val score of 0.4621):
#             {'C': 0.0001, 'degree': 1, 'tol': 0.001, 'max_iter': 1600, 'gamma': 'auto', 'features': 20}
#             Current best combo (with val score 0.4621):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 20}
#         Has trained 616 of 186624 combinations so far
# Trained and Tested combination 617 of 186624, taking 0.81 seconds to get val score of 0.3624:
#                 {'C': 0.0001, 'degree': 1, 'tol': 0.001, 'max_iter': 1600, 'gamma': 'scale', 'features': 19},
#             Current best combo with val score 0.4621:
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 20}
# Trained and Tested combination 618 of 186624, taking 0.86 seconds to get val score of 0.247:
#                 {'C': 0.0001, 'degree': 1, 'tol': 0.001, 'max_iter': 1600, 'gamma': 'scale', 'features': 21},
#             Current best combo with val score 0.4621:
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 20}
# Already Trained and Tested combination (val score of 0.4543):
#             {'C': 0.001, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 20}
#             Current best combo (with val score 0.4621):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 20}
#         Has trained 618 of 186624 combinations so far
# Already Trained and Tested combination (val score of 0.3467):
#             {'C': 0.0001, 'degree': 2, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 20}
#             Current best combo (with val score 0.4621):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 20}
#         Has trained 618 of 186624 combinations so far
# Already Trained and Tested combination (val score of 0.4621):
#             {'C': 0.0001, 'degree': 1, 'tol': 0.001, 'max_iter': 1600, 'gamma': 'auto', 'features': 20}
#             Current best combo (with val score 0.4621):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 20}
#         Has trained 618 of 186624 combinations so far
# Already Trained and Tested combination (val score of 0.3117):
#             {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 800, 'gamma': 'auto', 'features': 20}
#             Current best combo (with val score 0.4621):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 20}
#         Has trained 618 of 186624 combinations so far
# Already Trained and Tested combination (val score of 0.4529):
#             {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 20}
#             Current best combo (with val score 0.4621):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 20}
#         Has trained 618 of 186624 combinations so far
# Already Trained and Tested combination (val score of 0.3598):
#             {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 19}
#             Current best combo (with val score 0.4621):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 20}
#         Has trained 618 of 186624 combinations so far
# Already Trained and Tested combination (val score of 0.2666):
#             {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 21}
#             Current best combo (with val score 0.4621):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 20}
#         Has trained 618 of 186624 combinations so far
# % Combos Checked Thus Far: 618 out of 186624 which is 0.33114699999999997%
# Cruising Coordrdinate 528 of 528
#
# Cruise suspended due to suspicious case
# Guidance: round 2
#
# 	round 2 iteration:  0
#
# % Combos Checked Thus Far: 618 out of 186624 which is 0.33114699999999997%
# FINAL STAGE: Begin final Guidance system
#
#
# Guidance: round FINAL
#
# 	round FINAL iteration:  0
#
# % Combos Checked Thus Far: 618 out of 186624 which is 0.33114699999999997%
# Max Val Score:
#  0.462105
# Max Val Score Std:
#  0.046137
# Best Combo Train Score:
#  0.670004
# Best Combo Train Score Std:
#  0.001137
# Max Combo Index:
#  (0, 0, 0, 5, 0, 20) out of [6, 9, 6, 6, 2, 48] (note best combo is 0-indexed)
# Max Combo Hyperparamer Combination:
#  {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 20}
# Max Combo Features:
#  ('procedure_224274', 'lods_score', 'procedure_224276', 'procedure_224267', 'race_AMERICAN INDIAN/ALASKA NATIVE', 'race_ASIAN', 'race_ASIAN - ASIAN INDIAN', 'race_ASIAN - CHINESE', 'race_ASIAN - KOREAN', 'race_ASIAN - SOUTH EAST ASIAN', 'race_BLACK/AFRICAN', 'race_BLACK/AFRICAN AMERICAN', 'race_BLACK/CAPE VERDEAN', 'race_BLACK/CARIBBEAN ISLAND', 'race_HISPANIC OR LATINO', 'race_HISPANIC/LATINO - CENTRAL AMERICAN', 'race_HISPANIC/LATINO - COLUMBIAN', 'race_HISPANIC/LATINO - CUBAN', 'race_HISPANIC/LATINO - DOMINICAN', 'race_HISPANIC/LATINO - GUATEMALAN', 'race_HISPANIC/LATINO - HONDURAN', 'race_HISPANIC/LATINO - MEXICAN', 'race_HISPANIC/LATINO - PUERTO RICAN', 'race_HISPANIC/LATINO - SALVADORAN', 'race_MULTIPLE RACE/ETHNICITY', 'race_NATIVE HAWAIIAN OR OTHER PACIFIC ISLANDER', 'race_OTHER', 'race_PATIENT DECLINED TO ANSWER', 'race_PORTUGUESE', 'race_SOUTH AMERICAN', 'race_UNABLE TO OBTAIN', 'race_WHITE', 'race_WHITE - BRAZILIAN', 'race_WHITE - EASTERN EUROPEAN', 'race_WHITE - OTHER EUROPEAN', 'race_WHITE - RUSSIAN', 'race_UNKNOWN', 'procedure_227712', 'procedure_225430', 'gender_F', 'gender_M', 'oasis_score', 'procedure_225446', 'procedure_224275', 'procedure_225802', 'hospital_stay_duration', 'procedure_226475', 'ventilation_used', 'procedure_224270', 'procedure_227194', 'icu_stay_duration', 'procedure_225400', 'procedure_221223', 'procedure_225792')
# % Combos Checked: 618 out of 186624 which is 0.33114699999999997%
