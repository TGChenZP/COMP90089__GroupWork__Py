# %% [markdown]
# # Tuning Script

# %%
# Parameters subject to change in every script - involved in naming

MODEL = 'svc(poly)'
PREPROCESSING = 'smote_normalise'
TUNER = 'yangzhoub'
OPTIMISED_METRIC = 'f1'

# %% [markdown]
# ---

# %%
# detect whether this is a google environment

COLAB_ENVIRONMENT = False

try:
    from google.colab import drive
    drive.mount('/content/drive')
    COLAB_ENVIRONMENT = True
except:
    pass
# Out:
# Mounted at /content/drive

# %%
import sys
import os
import pickle

if COLAB_ENVIRONMENT:
    home_directory = './drive/MyDrive/LAB/COMP90089__GroupWork__Py/' # my home directory is stored in ./LAB of google drive
    if MODEL == 'ebr':
        # !pip install interpret==0.5.0
    elif MODEL == 'cbr':
        # !pip install catboost
    elif MODEL in ['tf', 'mlp']:
        # !pip install PyTorch2Sklearn
    # !pip install JXAutoML
else:
    home_directory = '../../'

from JXAutoML.YangZhouB_10CV import YangZhouB_10CV as Tuner

import pandas as pd
# Out:
# Collecting JXAutoML
#   Downloading JXAutoML-0.4.4-py3-none-any.whl.metadata (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.2/67.2 kB 665.4 kB/s eta 0:00:00
# Downloading JXAutoML-0.4.4-py3-none-any.whl (52 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.1/52.1 kB 1.9 MB/s eta 0:00:00
# Installing collected packages: JXAutoML
# Successfully installed JXAutoML-0.4.4

# %%
# Parameters that are same for every script

FOLDS = 10  # we have decided to do 10 fold validation

SEED = 42

TASK_TYPE = 'Classification'  # this task is a classification task

# we have decided to tune features as hp
TUNE_FEATURES_AS_HYPERPARAMETERS = True

# %% [markdown]
# ---

# %%
# model to use to tune
from sklearn.svm import SVC as clf

# what values to try for each hyperparameter
parameter_choices = {
    'C': (0.0001, 0.001, 0.01, 0.1, 1, 10),
    'degree': list(range(1, 10)),
    'tol': (0.0001, 0.001, 0.01, 0.1, 1, 10),
    'max_iter': (50, 100, 200, 400, 800, 1600),
    'gamma': ('scale', 'auto')
}

# what values to set non-tuneable parameters/hyperparameters
non_tunable_hyperparameters_dict = {
                                    'verbose': False,
                                    'decision_function_shape': 'ovr',
                                    'random_state': 42,
                                    'kernel': 'poly'
                                    }

# %% [markdown]
# ---

# %% [markdown]
# Read in and Prepare Data

# %%
# Import data and store as lists

train_x_list = []
train_y_list = []
val_x_list = []
val_y_list = []

for i in range(FOLDS):
    train_data = pd.read_csv(
        f'{home_directory}data/curated/modelling/{PREPROCESSING}/train_{i}.csv')
    val_data = pd.read_csv(
        f'{home_directory}data/curated/modelling/{PREPROCESSING}/val_{i}.csv')

    # get the correct rows for X and y
    train_x = train_data.drop(
        ['mortality_status', 'subject_id', 'hadm_id', 'stay_id'], axis=1)
    train_y = train_data['mortality_status']
    val_x = val_data.drop(
        ['mortality_status', 'subject_id', 'hadm_id', 'stay_id'], axis=1)
    val_y = val_data['mortality_status']

    train_x_list.append(train_x)
    train_y_list.append(train_y)
    val_x_list.append(val_x)
    val_y_list.append(val_y)

# %%
# Import feature importance ordering

with open(f'{home_directory}models/xgb_feature_importance_ordering_{PREPROCESSING}.pickle', 'rb') as f:
    feature_importance_ordering = pickle.load(f)

# %% [markdown]
# Set parameters

# %%
# initialisation
tuner = Tuner()

print('---')

# define what model we are tuning
tuner.read_in_model(clf, TASK_TYPE, optimised_metric=OPTIMISED_METRIC)

print('---')

# read in the data for training and validation
tuner.read_in_data(train_x_list, train_y_list, val_x_list, val_y_list)

print('---')

# set what hp values to tune
tuner.set_hyperparameters(parameter_choices)
# WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

# set up hp values that need to be changed from default but NOT to be tuned
tuner.set_non_tuneable_hyperparameters(non_tunable_hyperparameters_dict)

print('---')

# set up feature importance ordering

if TUNE_FEATURES_AS_HYPERPARAMETERS:
    tuner.set_features(feature_importance_ordering)
    # WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

try:  # try to read in previous results to continue tuning ...
    tuner.read_in_tuning_result_df(
        f'{home_directory}models/tuning/{TUNER}_{MODEL}_{PREPROCESSING}.csv')
except:
    print('No previous tuning data read in')

print('---')

# set up where to save the tuning result csv
tuner.set_tuning_result_saving_address(
    f'{home_directory}models/tuning/{TUNER}_{MODEL}_{PREPROCESSING}.csv')

print('---')

# set up where to save the current best model
tuner.set_best_model_saving_address(
    f'{home_directory}models/tmp_models/{TUNER}_{MODEL}_{PREPROCESSING}')
# Out:
# YangZhouB Initialised
# ---
# Successfully read in model <class 'sklearn.svm._classes.SVC'>, which is a Classification model optimising for f1
# ---
# Read in Train X data list
# Read in Train y data list
# Read in Val X data list
# Read in Val y data list
# ---
# Successfully recorded hyperparameter choices
# ---
# Successfully recorded non_tuneable_hyperparameter choices
# ---
# Successfully recorded tuneable feature combination choices and updated relevant internal structures
# ---
# Successfully read in tuning result of 1066 rows, for 1066.0 combos
# ---
# Successfully set tuning output address
# ---
# Successfully set best model output address

# %%
# ignore warnings

import warnings
warnings.filterwarnings("ignore")

# %%
# begin tuning ... (or continue training)

tuner.tune()
# Out:
# Streaming output truncated to the last 5000 lines.
#             {'C': 10, 'degree': 1, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 55}
#             Current best combo (with val score 0.5141):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 20}
#         Has trained 1066 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'C': 10, 'degree': 9, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 71}
#             Current best combo (with val score 0.5141):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 20}
#         Has trained 1066 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'C': 0.0001, 'degree': 1, 'tol': 10, 'max_iter': 50, 'gamma': 'scale', 'features': 40}
#             Current best combo (with val score 0.5141):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 20}
#         Has trained 1066 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'C': 10, 'degree': 1, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 15}
#             Current best combo (with val score 0.5141):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 20}
#         Has trained 1066 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'C': 10, 'degree': 9, 'tol': 10, 'max_iter': 50, 'gamma': 'auto', 'features': 25}
#             Current best combo (with val score 0.5141):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 20}
#         Has trained 1066 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'C': 0.0001, 'degree': 9, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 35}
#             Current best combo (with val score 0.5141):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 20}
#         Has trained 1066 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.2777):
#             {'C': 0.0001, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 35}
#             Current best combo (with val score 0.5141):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 20}
#         Has trained 1066 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.0281):
#             {'C': 10, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 35}
#             Current best combo (with val score 0.5141):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 20}
#         Has trained 1066 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.3087):
#             {'C': 0.0001, 'degree': 9, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 71}
#             Current best combo (with val score 0.5141):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 20}
#         Has trained 1066 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'C': 10, 'degree': 5, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 59}
#             Current best combo (with val score 0.5141):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 20}
#         Has trained 1066 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'C': 0.0001, 'degree': 9, 'tol': 10, 'max_iter': 1600, 'gamma': 'scale', 'features': 35}
#             Current best combo (with val score 0.5141):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 20}
#         Has trained 1066 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'C': 0.0001, 'degree': 1, 'tol': 10, 'max_iter': 50, 'gamma': 'auto', 'features': 59}
#             Current best combo (with val score 0.5141):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 20}
#         Has trained 1066 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 71}
#             Current best combo (with val score 0.5141):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 20}
#         Has trained 1066 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'C': 10, 'degree': 9, 'tol': 10, 'max_iter': 1600, 'gamma': 'scale', 'features': 71}
#             Current best combo (with val score 0.5141):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 20}
#         Has trained 1066 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.2449):
#             {'C': 0.0001, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 59}
#             Current best combo (with val score 0.5141):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 20}
#         Has trained 1066 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'C': 10, 'degree': 5, 'tol': 10, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
#             Current best combo (with val score 0.5141):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 20}
#         Has trained 1066 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.1306):
#             {'C': 10, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 40}
#             Current best combo (with val score 0.5141):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 20}
#         Has trained 1066 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'C': 0.0001, 'degree': 5, 'tol': 10, 'max_iter': 50, 'gamma': 'auto', 'features': 0}
#             Current best combo (with val score 0.5141):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 20}
#         Has trained 1066 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.1235):
#             {'C': 10, 'degree': 5, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 40}
#             Current best combo (with val score 0.5141):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 20}
#         Has trained 1066 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.0244):
#             {'C': 10, 'degree': 9, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 30}
#             Current best combo (with val score 0.5141):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 20}
#         Has trained 1066 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 55}
#             Current best combo (with val score 0.5141):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 20}
#         Has trained 1066 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'C': 0.0001, 'degree': 5, 'tol': 10, 'max_iter': 50, 'gamma': 'auto', 'features': 25}
#             Current best combo (with val score 0.5141):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 20}
#         Has trained 1066 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.316):
#             {'C': 10, 'degree': 9, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 25}
#             Current best combo (with val score 0.5141):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 20}
#         Has trained 1066 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'C': 10, 'degree': 1, 'tol': 10, 'max_iter': 50, 'gamma': 'scale', 'features': 45}
#             Current best combo (with val score 0.5141):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 20}
#         Has trained 1066 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'C': 0.0001, 'degree': 9, 'tol': 10, 'max_iter': 50, 'gamma': 'scale', 'features': 50}
#             Current best combo (with val score 0.5141):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 20}
#         Has trained 1066 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'C': 0.0001, 'degree': 5, 'tol': 10, 'max_iter': 50, 'gamma': 'auto', 'features': 55}
#             Current best combo (with val score 0.5141):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 20}
#         Has trained 1066 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.2764):
#             {'C': 10, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 20}
#             Current best combo (with val score 0.5141):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 20}
#         Has trained 1066 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'C': 0.0001, 'degree': 5, 'tol': 10, 'max_iter': 50, 'gamma': 'auto', 'features': 15}
#             Current best combo (with val score 0.5141):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 20}
#         Has trained 1066 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'C': 0.0001, 'degree': 1, 'tol': 10, 'max_iter': 50, 'gamma': 'auto', 'features': 0}
#             Current best combo (with val score 0.5141):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 20}
#         Has trained 1066 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'C': 10, 'degree': 5, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 5}
#             Current best combo (with val score 0.5141):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 20}
#         Has trained 1066 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'C': 10, 'degree': 5, 'tol': 10, 'max_iter': 50, 'gamma': 'auto', 'features': 30}
#             Current best combo (with val score 0.5141):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 20}
#         Has trained 1066 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'C': 10, 'degree': 1, 'tol': 10, 'max_iter': 50, 'gamma': 'auto', 'features': 15}
#             Current best combo (with val score 0.5141):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 20}
#         Has trained 1066 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'C': 10, 'degree': 1, 'tol': 10, 'max_iter': 50, 'gamma': 'auto', 'features': 35}
#             Current best combo (with val score 0.5141):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 20}
#         Has trained 1066 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'C': 0.0001, 'degree': 9, 'tol': 10, 'max_iter': 50, 'gamma': 'auto', 'features': 55}
#             Current best combo (with val score 0.5141):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 20}
#         Has trained 1066 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'C': 10, 'degree': 1, 'tol': 10, 'max_iter': 50, 'gamma': 'auto', 'features': 25}
#             Current best combo (with val score 0.5141):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 20}
#         Has trained 1066 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'C': 10, 'degree': 9, 'tol': 10, 'max_iter': 50, 'gamma': 'scale', 'features': 25}
#             Current best combo (with val score 0.5141):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 20}
#         Has trained 1066 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.2152):
#             {'C': 10, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 40}
#             Current best combo (with val score 0.5141):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 20}
#         Has trained 1066 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.2027):
#             {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 50}
#             Current best combo (with val score 0.5141):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 20}
#         Has trained 1066 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'C': 10, 'degree': 5, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 30}
#             Current best combo (with val score 0.5141):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 20}
#         Has trained 1066 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'C': 10, 'degree': 9, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 5}
#             Current best combo (with val score 0.5141):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 20}
#         Has trained 1066 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 59}
#             Current best combo (with val score 0.5141):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 20}
#         Has trained 1066 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.2772):
#             {'C': 0.0001, 'degree': 9, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 35}
#             Current best combo (with val score 0.5141):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 20}
#         Has trained 1066 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'C': 10, 'degree': 9, 'tol': 10, 'max_iter': 50, 'gamma': 'scale', 'features': 71}
#             Current best combo (with val score 0.5141):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 20}
#         Has trained 1066 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.1297):
#             {'C': 10, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 20}
#             Current best combo (with val score 0.5141):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 20}
#         Has trained 1066 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.0617):
#             {'C': 10, 'degree': 5, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 30}
#             Current best combo (with val score 0.5141):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 20}
#         Has trained 1066 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.2761):
#             {'C': 0.0001, 'degree': 5, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 50}
#             Current best combo (with val score 0.5141):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 20}
#         Has trained 1066 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.3463):
#             {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 10}
#             Current best combo (with val score 0.5141):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 20}
#         Has trained 1066 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.0723):
#             {'C': 10, 'degree': 1, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 67}
#             Current best combo (with val score 0.5141):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 20}
#         Has trained 1066 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'C': 10, 'degree': 9, 'tol': 10, 'max_iter': 1600, 'gamma': 'scale', 'features': 15}
#             Current best combo (with val score 0.5141):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 20}
#         Has trained 1066 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'C': 0.0001, 'degree': 1, 'tol': 10, 'max_iter': 1600, 'gamma': 'scale', 'features': 50}
#             Current best combo (with val score 0.5141):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 20}
#         Has trained 1066 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'C': 0.0001, 'degree': 5, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 45}
#             Current best combo (with val score 0.5141):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 20}
#         Has trained 1066 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.3116):
#             {'C': 0.0001, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 20}
#             Current best combo (with val score 0.5141):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 20}
#         Has trained 1066 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'C': 0.0001, 'degree': 9, 'tol': 10, 'max_iter': 50, 'gamma': 'scale', 'features': 35}
#             Current best combo (with val score 0.5141):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 20}
#         Has trained 1066 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.299):
#             {'C': 10, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 25}
#             Current best combo (with val score 0.5141):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 20}
#         Has trained 1066 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.0956):
#             {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 45}
#             Current best combo (with val score 0.5141):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 20}
#         Has trained 1066 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.0462):
#             {'C': 10, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 35}
#             Current best combo (with val score 0.5141):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 20}
#         Has trained 1066 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'C': 0.0001, 'degree': 9, 'tol': 10, 'max_iter': 50, 'gamma': 'scale', 'features': 25}
#             Current best combo (with val score 0.5141):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 20}
#         Has trained 1066 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'C': 0.0001, 'degree': 5, 'tol': 10, 'max_iter': 50, 'gamma': 'auto', 'features': 71}
#             Current best combo (with val score 0.5141):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 20}
#         Has trained 1066 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'C': 0.0001, 'degree': 5, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 71}
#             Current best combo (with val score 0.5141):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 20}
#         Has trained 1066 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'C': 0.0001, 'degree': 9, 'tol': 10, 'max_iter': 1600, 'gamma': 'scale', 'features': 15}
#             Current best combo (with val score 0.5141):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 20}
#         Has trained 1066 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.3099):
#             {'C': 0.0001, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 15}
#             Current best combo (with val score 0.5141):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 20}
#         Has trained 1066 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'C': 10, 'degree': 9, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 35}
#             Current best combo (with val score 0.5141):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 20}
#         Has trained 1066 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'C': 10, 'degree': 1, 'tol': 10, 'max_iter': 50, 'gamma': 'auto', 'features': 30}
#             Current best combo (with val score 0.5141):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 20}
#         Has trained 1066 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'C': 10, 'degree': 5, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 71}
#             Current best combo (with val score 0.5141):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 20}
#         Has trained 1066 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.0807):
#             {'C': 0.0001, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 40}
#             Current best combo (with val score 0.5141):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 20}
#         Has trained 1066 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.0807):
#             {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 59}
#             Current best combo (with val score 0.5141):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 20}
#         Has trained 1066 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'C': 10, 'degree': 9, 'tol': 10, 'max_iter': 50, 'gamma': 'scale', 'features': 59}
#             Current best combo (with val score 0.5141):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 20}
#         Has trained 1066 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'C': 10, 'degree': 1, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 25}
#             Current best combo (with val score 0.5141):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 20}
#         Has trained 1066 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'C': 0.0001, 'degree': 5, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 25}
#             Current best combo (with val score 0.5141):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 20}
#         Has trained 1066 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.1087):
#             {'C': 10, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 59}
#             Current best combo (with val score 0.5141):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 20}
#         Has trained 1066 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.2252):
#             {'C': 0.0001, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 55}
#             Current best combo (with val score 0.5141):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 20}
#         Has trained 1066 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'C': 0.0001, 'degree': 1, 'tol': 10, 'max_iter': 50, 'gamma': 'auto', 'features': 30}
#             Current best combo (with val score 0.5141):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 20}
#         Has trained 1066 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'C': 10, 'degree': 5, 'tol': 10, 'max_iter': 50, 'gamma': 'auto', 'features': 50}
#             Current best combo (with val score 0.5141):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 20}
#         Has trained 1066 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'C': 0.0001, 'degree': 9, 'tol': 10, 'max_iter': 50, 'gamma': 'scale', 'features': 20}
#             Current best combo (with val score 0.5141):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 20}
#         Has trained 1066 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'C': 0.0001, 'degree': 5, 'tol': 10, 'max_iter': 1600, 'gamma': 'scale', 'features': 55}
#             Current best combo (with val score 0.5141):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 20}
#         Has trained 1066 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.3143):
#             {'C': 10, 'degree': 1, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 25}
#             Current best combo (with val score 0.5141):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 20}
#         Has trained 1066 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'C': 10, 'degree': 9, 'tol': 10, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
#             Current best combo (with val score 0.5141):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 20}
#         Has trained 1066 of 279936 combinations so far
# As new Best Combo (0, 0, 0, 5, 1, 20) was read in, best_clf is set to None
# Already Trained and Tested combination (val score of 0.515):
#             {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 20}
#             Current best combo (with val score 0.515):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 20}
#         Has trained 1066 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'C': 10, 'degree': 9, 'tol': 10, 'max_iter': 50, 'gamma': 'scale', 'features': 15}
#             Current best combo (with val score 0.515):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 20}
#         Has trained 1066 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'C': 10, 'degree': 1, 'tol': 10, 'max_iter': 1600, 'gamma': 'scale', 'features': 30}
#             Current best combo (with val score 0.515):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 20}
#         Has trained 1066 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'C': 0.0001, 'degree': 1, 'tol': 10, 'max_iter': 50, 'gamma': 'auto', 'features': 55}
#             Current best combo (with val score 0.515):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 20}
#         Has trained 1066 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.3087):
#             {'C': 0.0001, 'degree': 5, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 15}
#             Current best combo (with val score 0.515):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 20}
#         Has trained 1066 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'C': 10, 'degree': 5, 'tol': 10, 'max_iter': 50, 'gamma': 'scale', 'features': 0}
#             Current best combo (with val score 0.515):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 20}
#         Has trained 1066 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.0316):
#             {'C': 10, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 50}
#             Current best combo (with val score 0.515):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 20}
#         Has trained 1066 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.3174):
#             {'C': 10, 'degree': 9, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 15}
#             Current best combo (with val score 0.515):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 20}
#         Has trained 1066 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.3077):
#             {'C': 0.0001, 'degree': 5, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 63}
#             Current best combo (with val score 0.515):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 20}
#         Has trained 1066 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'C': 10, 'degree': 5, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 35}
#             Current best combo (with val score 0.515):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 20}
#         Has trained 1066 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'C': 0.0001, 'degree': 5, 'tol': 10, 'max_iter': 1600, 'gamma': 'scale', 'features': 30}
#             Current best combo (with val score 0.515):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 20}
#         Has trained 1066 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.2778):
#             {'C': 0.0001, 'degree': 9, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 50}
#             Current best combo (with val score 0.515):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 20}
#         Has trained 1066 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'C': 0.0001, 'degree': 9, 'tol': 10, 'max_iter': 50, 'gamma': 'auto', 'features': 0}
#             Current best combo (with val score 0.515):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 20}
#         Has trained 1066 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'C': 0.0001, 'degree': 1, 'tol': 10, 'max_iter': 50, 'gamma': 'auto', 'features': 63}
#             Current best combo (with val score 0.515):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 20}
#         Has trained 1066 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'C': 0.0001, 'degree': 1, 'tol': 10, 'max_iter': 50, 'gamma': 'scale', 'features': 10}
#             Current best combo (with val score 0.515):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 20}
#         Has trained 1066 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'C': 10, 'degree': 1, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 45}
#             Current best combo (with val score 0.515):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 20}
#         Has trained 1066 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'C': 10, 'degree': 9, 'tol': 10, 'max_iter': 50, 'gamma': 'auto', 'features': 10}
#             Current best combo (with val score 0.515):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 20}
#         Has trained 1066 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.2174):
#             {'C': 10, 'degree': 1, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 71}
#             Current best combo (with val score 0.515):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 20}
#         Has trained 1066 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'C': 0.0001, 'degree': 5, 'tol': 10, 'max_iter': 50, 'gamma': 'scale', 'features': 5}
#             Current best combo (with val score 0.515):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 20}
#         Has trained 1066 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.0033):
#             {'C': 10, 'degree': 9, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 20}
#             Current best combo (with val score 0.515):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 20}
#         Has trained 1066 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'C': 0.0001, 'degree': 9, 'tol': 10, 'max_iter': 50, 'gamma': 'auto', 'features': 25}
#             Current best combo (with val score 0.515):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 20}
#         Has trained 1066 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'C': 10, 'degree': 5, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 63}
#             Current best combo (with val score 0.515):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 20}
#         Has trained 1066 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.0097):
#             {'C': 10, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 45}
#             Current best combo (with val score 0.515):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 20}
#         Has trained 1066 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.0308):
#             {'C': 0.0001, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 35}
#             Current best combo (with val score 0.515):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 20}
#         Has trained 1066 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'C': 10, 'degree': 9, 'tol': 10, 'max_iter': 50, 'gamma': 'scale', 'features': 45}
#             Current best combo (with val score 0.515):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 20}
#         Has trained 1066 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.284):
#             {'C': 0.0001, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 67}
#             Current best combo (with val score 0.515):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 20}
#         Has trained 1066 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'C': 0.0001, 'degree': 5, 'tol': 10, 'max_iter': 50, 'gamma': 'scale', 'features': 25}
#             Current best combo (with val score 0.515):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 20}
#         Has trained 1066 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'C': 10, 'degree': 5, 'tol': 10, 'max_iter': 50, 'gamma': 'scale', 'features': 59}
#             Current best combo (with val score 0.515):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 20}
#         Has trained 1066 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'C': 0.0001, 'degree': 9, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 15}
#             Current best combo (with val score 0.515):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 20}
#         Has trained 1066 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'C': 10, 'degree': 5, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 45}
#             Current best combo (with val score 0.515):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 20}
#         Has trained 1066 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 35}
#             Current best combo (with val score 0.515):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 20}
#         Has trained 1066 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'C': 0.0001, 'degree': 5, 'tol': 10, 'max_iter': 50, 'gamma': 'scale', 'features': 40}
#             Current best combo (with val score 0.515):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 20}
#         Has trained 1066 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.1851):
#             {'C': 0.0001, 'degree': 5, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 30}
#             Current best combo (with val score 0.515):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 20}
#         Has trained 1066 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.1083):
#             {'C': 10, 'degree': 5, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 71}
#             Current best combo (with val score 0.515):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 20}
#         Has trained 1066 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'C': 0.0001, 'degree': 1, 'tol': 10, 'max_iter': 1600, 'gamma': 'scale', 'features': 30}
#             Current best combo (with val score 0.515):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 20}
#         Has trained 1066 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 63}
#             Current best combo (with val score 0.515):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 20}
#         Has trained 1066 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.0925):
#             {'C': 0.0001, 'degree': 9, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 63}
#             Current best combo (with val score 0.515):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 20}
#         Has trained 1066 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'C': 10, 'degree': 1, 'tol': 10, 'max_iter': 1600, 'gamma': 'scale', 'features': 55}
#             Current best combo (with val score 0.515):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 20}
#         Has trained 1066 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'C': 0.0001, 'degree': 1, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 15}
#             Current best combo (with val score 0.515):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 20}
#         Has trained 1066 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.0457):
#             {'C': 0.0001, 'degree': 9, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 67}
#             Current best combo (with val score 0.515):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 20}
#         Has trained 1066 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.0617):
#             {'C': 0.0001, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 30}
#             Current best combo (with val score 0.515):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 20}
#         Has trained 1066 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.0304):
#             {'C': 10, 'degree': 5, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 45}
#             Current best combo (with val score 0.515):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 20}
#         Has trained 1066 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.2425):
#             {'C': 10, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 25}
#             Current best combo (with val score 0.515):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 20}
#         Has trained 1066 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'C': 10, 'degree': 9, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 30}
#             Current best combo (with val score 0.515):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 20}
#         Has trained 1066 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'C': 10, 'degree': 5, 'tol': 10, 'max_iter': 50, 'gamma': 'auto', 'features': 25}
#             Current best combo (with val score 0.515):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 20}
#         Has trained 1066 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'C': 10, 'degree': 5, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 25}
#             Current best combo (with val score 0.515):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 20}
#         Has trained 1066 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.272):
#             {'C': 10, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 15}
#             Current best combo (with val score 0.515):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 20}
# ...
#             Current best combo (with val score 0.5281):
#                     {'C': 0.01, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 19}
#         Has trained 1066 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.494):
#             {'C': 0.01, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 21}
#             Current best combo (with val score 0.5281):
#                     {'C': 0.01, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 19}
#         Has trained 1066 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.5111):
#             {'C': 0.001, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 19}
#             Current best combo (with val score 0.5281):
#                     {'C': 0.01, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 19}
#         Has trained 1066 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'C': 0.1, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 19}
#             Current best combo (with val score 0.5281):
#                     {'C': 0.01, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 19}
#         Has trained 1066 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.3667):
#             {'C': 0.01, 'degree': 2, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 19}
#             Current best combo (with val score 0.5281):
#                     {'C': 0.01, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 19}
#         Has trained 1066 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.5281):
#             {'C': 0.01, 'degree': 1, 'tol': 0.001, 'max_iter': 1600, 'gamma': 'auto', 'features': 19}
#             Current best combo (with val score 0.5281):
#                     {'C': 0.01, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 19}
#         Has trained 1066 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.3111):
#             {'C': 0.01, 'degree': 1, 'tol': 0.0001, 'max_iter': 800, 'gamma': 'auto', 'features': 19}
#             Current best combo (with val score 0.5281):
#                     {'C': 0.01, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 19}
#         Has trained 1066 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'C': 0.01, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 19}
#             Current best combo (with val score 0.5281):
#                     {'C': 0.01, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 19}
#         Has trained 1066 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.5239):
#             {'C': 0.01, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 18}
#             Current best combo (with val score 0.5281):
#                     {'C': 0.01, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 19}
#         Has trained 1066 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.5272):
#             {'C': 0.01, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 20}
#             Current best combo (with val score 0.5281):
#                     {'C': 0.01, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 19}
#         Has trained 1066 of 279936 combinations so far
# % Combos Checked Thus Far: 1066 out of 279936 which is 0.380801%
# Cruising Coordrdinate 768 of 768
#
# Cruise suspended due to suspicious case
# Guidance: round 11
#
# 	round 11 iteration:  0
#
# % Combos Checked Thus Far: 1066 out of 279936 which is 0.380801%
# FINAL STAGE: Begin final Guidance system
#
#
# Guidance: round FINAL
#
# 	round FINAL iteration:  0
#
# Already Trained and Tested combination (val score of 0.5111):
#             {'C': 0.001, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 19}
#             Current best combo (with val score 0.5281):
#                     {'C': 0.01, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 19}
#         Has trained 1066 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'C': 0.1, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 19}
#             Current best combo (with val score 0.5281):
#                     {'C': 0.01, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 19}
#         Has trained 1066 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.3667):
#             {'C': 0.01, 'degree': 2, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 19}
#             Current best combo (with val score 0.5281):
#                     {'C': 0.01, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 19}
#         Has trained 1066 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.5281):
#             {'C': 0.01, 'degree': 1, 'tol': 0.001, 'max_iter': 1600, 'gamma': 'auto', 'features': 19}
#             Current best combo (with val score 0.5281):
#                     {'C': 0.01, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 19}
#         Has trained 1066 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.3111):
#             {'C': 0.01, 'degree': 1, 'tol': 0.0001, 'max_iter': 800, 'gamma': 'auto', 'features': 19}
#             Current best combo (with val score 0.5281):
#                     {'C': 0.01, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 19}
#         Has trained 1066 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'C': 0.01, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 19}
#             Current best combo (with val score 0.5281):
#                     {'C': 0.01, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 19}
#         Has trained 1066 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.5239):
#             {'C': 0.01, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 18}
#             Current best combo (with val score 0.5281):
#                     {'C': 0.01, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 19}
#         Has trained 1066 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.5272):
#             {'C': 0.01, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 20}
#             Current best combo (with val score 0.5281):
#                     {'C': 0.01, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 19}
#         Has trained 1066 of 279936 combinations so far
# 	round FINAL iteration:  1
#
# Already Trained and Tested combination (val score of 0.5111):
#             {'C': 0.001, 'degree': 1, 'tol': 0.001, 'max_iter': 1600, 'gamma': 'auto', 'features': 19}
#             Current best combo (with val score 0.5281):
#                     {'C': 0.01, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 19}
#         Has trained 1066 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'C': 0.1, 'degree': 1, 'tol': 0.001, 'max_iter': 1600, 'gamma': 'auto', 'features': 19}
#             Current best combo (with val score 0.5281):
#                     {'C': 0.01, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 19}
#         Has trained 1066 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.3667):
#             {'C': 0.01, 'degree': 2, 'tol': 0.001, 'max_iter': 1600, 'gamma': 'auto', 'features': 19}
#             Current best combo (with val score 0.5281):
#                     {'C': 0.01, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 19}
#         Has trained 1066 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.5281):
#             {'C': 0.01, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 19}
#             Current best combo (with val score 0.5281):
#                     {'C': 0.01, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 19}
#         Has trained 1066 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.5281):
#             {'C': 0.01, 'degree': 1, 'tol': 0.01, 'max_iter': 1600, 'gamma': 'auto', 'features': 19}
#             Current best combo (with val score 0.5281):
#                     {'C': 0.01, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 19}
#         Has trained 1066 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.3111):
#             {'C': 0.01, 'degree': 1, 'tol': 0.001, 'max_iter': 800, 'gamma': 'auto', 'features': 19}
#             Current best combo (with val score 0.5281):
#                     {'C': 0.01, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 19}
#         Has trained 1066 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'C': 0.01, 'degree': 1, 'tol': 0.001, 'max_iter': 1600, 'gamma': 'scale', 'features': 19}
#             Current best combo (with val score 0.5281):
#                     {'C': 0.01, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 19}
#         Has trained 1066 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.5239):
#             {'C': 0.01, 'degree': 1, 'tol': 0.001, 'max_iter': 1600, 'gamma': 'auto', 'features': 18}
#             Current best combo (with val score 0.5281):
#                     {'C': 0.01, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 19}
#         Has trained 1066 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.5272):
#             {'C': 0.01, 'degree': 1, 'tol': 0.001, 'max_iter': 1600, 'gamma': 'auto', 'features': 20}
#             Current best combo (with val score 0.5281):
#                     {'C': 0.01, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 19}
#         Has trained 1066 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.5091):
#             {'C': 0.001, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 18}
#             Current best combo (with val score 0.5281):
#                     {'C': 0.01, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 19}
#         Has trained 1066 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'C': 0.1, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 18}
#             Current best combo (with val score 0.5281):
#                     {'C': 0.01, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 19}
#         Has trained 1066 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.3662):
#             {'C': 0.01, 'degree': 2, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 18}
#             Current best combo (with val score 0.5281):
#                     {'C': 0.01, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 19}
#         Has trained 1066 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.5239):
#             {'C': 0.01, 'degree': 1, 'tol': 0.001, 'max_iter': 1600, 'gamma': 'auto', 'features': 18}
#             Current best combo (with val score 0.5281):
#                     {'C': 0.01, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 19}
#         Has trained 1066 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.3116):
#             {'C': 0.01, 'degree': 1, 'tol': 0.0001, 'max_iter': 800, 'gamma': 'auto', 'features': 18}
#             Current best combo (with val score 0.5281):
#                     {'C': 0.01, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 19}
#         Has trained 1066 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'C': 0.01, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 18}
#             Current best combo (with val score 0.5281):
#                     {'C': 0.01, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 19}
#         Has trained 1066 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.5191):
#             {'C': 0.01, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 17}
#             Current best combo (with val score 0.5281):
#                     {'C': 0.01, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 19}
#         Has trained 1066 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.5281):
#             {'C': 0.01, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 19}
#             Current best combo (with val score 0.5281):
#                     {'C': 0.01, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 19}
#         Has trained 1066 of 279936 combinations so far
# % Combos Checked Thus Far: 1066 out of 279936 which is 0.380801%
# Max Val Score:
#  0.528098
# Max Val Score Std:
#  0.049205
# Best Combo Train Score:
#  0.679176
# Best Combo Train Score Std:
#  0.006676
# Max Combo Index:
#  (2, 0, 0, 5, 0, 19) out of [6, 9, 6, 6, 2, 72] (note best combo is 0-indexed)
# Max Combo Hyperparamer Combination:
#  {'C': 0.01, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 19}
# Max Combo Features:
#  ('procedure_225469', 'lods_score', 'procedure_224274', 'marital_status_0', 'marital_status_DIVORCED', 'marital_status_MARRIED', 'marital_status_WIDOWED', 'marital_status_SINGLE', 'procedure_223253', 'race_AMERICAN INDIAN/ALASKA NATIVE', 'race_ASIAN', 'race_ASIAN - ASIAN INDIAN', 'race_ASIAN - CHINESE', 'race_ASIAN - KOREAN', 'race_ASIAN - SOUTH EAST ASIAN', 'race_BLACK/AFRICAN', 'race_BLACK/AFRICAN AMERICAN', 'race_BLACK/CAPE VERDEAN', 'race_BLACK/CARIBBEAN ISLAND', 'race_HISPANIC OR LATINO', 'race_HISPANIC/LATINO - CENTRAL AMERICAN', 'race_HISPANIC/LATINO - COLUMBIAN', 'race_HISPANIC/LATINO - CUBAN', 'race_HISPANIC/LATINO - DOMINICAN', 'race_HISPANIC/LATINO - GUATEMALAN', 'race_HISPANIC/LATINO - HONDURAN', 'race_HISPANIC/LATINO - MEXICAN', 'race_HISPANIC/LATINO - PUERTO RICAN', 'race_HISPANIC/LATINO - SALVADORAN', 'race_MULTIPLE RACE/ETHNICITY', 'race_NATIVE HAWAIIAN OR OTHER PACIFIC ISLANDER', 'race_OTHER', 'race_PATIENT DECLINED TO ANSWER', 'race_PORTUGUESE', 'race_SOUTH AMERICAN', 'race_UNABLE TO OBTAIN', 'race_UNKNOWN', 'race_WHITE', 'race_WHITE - BRAZILIAN', 'race_WHITE - EASTERN EUROPEAN', 'race_WHITE - RUSSIAN', 'race_WHITE - OTHER EUROPEAN', 'procedure_227712', 'procedure_224276', 'admission_type_DIRECT OBSERVATION', 'admission_type_ELECTIVE', 'admission_type_EU OBSERVATION', 'admission_type_EW EMER.', 'admission_type_OBSERVATION ADMIT', 'admission_type_SURGICAL SAME DAY ADMISSION', 'admission_type_URGENT', 'admission_type_DIRECT EMER.', 'insurance_Medicare', 'insurance_Other', 'insurance_Medicaid', 'procedure_225792', 'procedure_228130', 'procedure_225817', 'procedure_224267', 'gender_F', 'gender_M', 'ventilation_used', 'hospital_stay_duration', 'oasis_score', 'procedure_228125', 'procedure_226124')
# % Combos Checked: 1066 out of 279936 which is 0.380801%
