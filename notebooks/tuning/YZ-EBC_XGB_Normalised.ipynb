# %% [markdown]
# # Tuning Script

# %%
# Parameters subject to change in every script - involved in naming

MODEL = 'ebc'
PREPROCESSING = 'normalise'
TUNER = 'yangzhoub'
OPTIMISED_METRIC = 'f1'

# %% [markdown]
# ---

# %%
# detect whether this is a google environment

COLAB_ENVIRONMENT = False

try:
    from google.colab import drive
    drive.mount('/content/drive')
    COLAB_ENVIRONMENT = True
except:
    pass
# Out:
# Mounted at /content/drive

# %%
import sys
import os
import pickle

if COLAB_ENVIRONMENT:
    home_directory = './drive/MyDrive/LAB/COMP90089__GroupWork__Py/' # my home directory is stored in ./LAB of google drive
    if MODEL == 'ebc':
        # !pip install interpret==0.5.0
    elif MODEL == 'cbc':
        # !pip install catboost
    elif MODEL in ['tf', 'mlp']:
        # !pip install PyTorch2Sklearn
    # !pip install JXAutoML
else:
    home_directory = '../../'

from JXAutoML.YangZhouB_10CV import YangZhouB_10CV as Tuner

import pandas as pd
# Out:
# Collecting interpret==0.5.0
#   Downloading interpret-0.5.0-py3-none-any.whl.metadata (1.1 kB)
# Collecting interpret-core==0.5.0 (from interpret-core[dash,debug,linear,notebook,plotly,sensitivity,shap]==0.5.0->interpret==0.5.0)
#   Downloading interpret_core-0.5.0-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: numpy>=1.11.1 in /usr/local/lib/python3.10/dist-packages (from interpret-core==0.5.0->interpret-core[dash,debug,linear,notebook,plotly,sensitivity,shap]==0.5.0->interpret==0.5.0) (1.26.4)
# Requirement already satisfied: scipy>=0.18.1 in /usr/local/lib/python3.10/dist-packages (from interpret-core==0.5.0->interpret-core[dash,debug,linear,notebook,plotly,sensitivity,shap]==0.5.0->interpret==0.5.0) (1.13.1)
# Requirement already satisfied: pandas>=0.19.2 in /usr/local/lib/python3.10/dist-packages (from interpret-core==0.5.0->interpret-core[dash,debug,linear,notebook,plotly,sensitivity,shap]==0.5.0->interpret==0.5.0) (2.2.2)
# Requirement already satisfied: scikit-learn>=0.18.1 in /usr/local/lib/python3.10/dist-packages (from interpret-core==0.5.0->interpret-core[dash,debug,linear,notebook,plotly,sensitivity,shap]==0.5.0->interpret==0.5.0) (1.5.2)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.10/dist-packages (from interpret-core==0.5.0->interpret-core[dash,debug,linear,notebook,plotly,sensitivity,shap]==0.5.0->interpret==0.5.0) (1.4.2)
# Requirement already satisfied: plotly>=3.8.1 in /usr/local/lib/python3.10/dist-packages (from interpret-core[dash,debug,linear,notebook,plotly,sensitivity,shap]==0.5.0->interpret==0.5.0) (5.24.1)
# Requirement already satisfied: ipykernel>=4.10.0 in /usr/local/lib/python3.10/dist-packages (from interpret-core[dash,debug,linear,notebook,plotly,sensitivity,shap]==0.5.0->interpret==0.5.0) (5.5.6)
# Requirement already satisfied: ipython>=5.5.0 in /usr/local/lib/python3.10/dist-packages (from interpret-core[dash,debug,linear,notebook,plotly,sensitivity,shap]==0.5.0->interpret==0.5.0) (7.34.0)
# Requirement already satisfied: psutil>=5.6.2 in /usr/local/lib/python3.10/dist-packages (from interpret-core[dash,debug,linear,notebook,plotly,sensitivity,shap]==0.5.0->interpret==0.5.0) (5.9.5)
# Collecting SALib>=1.3.3 (from interpret-core[dash,debug,linear,notebook,plotly,sensitivity,shap]==0.5.0->interpret==0.5.0)
#   Downloading salib-1.5.1-py3-none-any.whl.metadata (11 kB)
# Collecting shap>=0.28.5 (from interpret-core[dash,debug,linear,notebook,plotly,sensitivity,shap]==0.5.0->interpret==0.5.0)
#   Downloading shap-0.46.0-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (24 kB)
# Collecting dill>=0.2.5 (from interpret-core[dash,debug,linear,notebook,plotly,sensitivity,shap]==0.5.0->interpret==0.5.0)
#   Downloading dill-0.3.9-py3-none-any.whl.metadata (10 kB)
# Collecting dash>=1.0.0 (from interpret-core[dash,debug,linear,notebook,plotly,sensitivity,shap]==0.5.0->interpret==0.5.0)
#   Downloading dash-2.18.1-py3-none-any.whl.metadata (10 kB)
# Collecting dash-core-components>=1.0.0 (from interpret-core[dash,debug,linear,notebook,plotly,sensitivity,shap]==0.5.0->interpret==0.5.0)
#   Downloading dash_core_components-2.0.0-py3-none-any.whl.metadata (2.9 kB)
# Collecting dash-html-components>=1.0.0 (from interpret-core[dash,debug,linear,notebook,plotly,sensitivity,shap]==0.5.0->interpret==0.5.0)
#   Downloading dash_html_components-2.0.0-py3-none-any.whl.metadata (3.8 kB)
# Collecting dash-table>=4.1.0 (from interpret-core[dash,debug,linear,notebook,plotly,sensitivity,shap]==0.5.0->interpret==0.5.0)
#   Downloading dash_table-5.0.0-py3-none-any.whl.metadata (2.4 kB)
# Collecting dash-cytoscape>=0.1.1 (from interpret-core[dash,debug,linear,notebook,plotly,sensitivity,shap]==0.5.0->interpret==0.5.0)
#   Downloading dash_cytoscape-1.0.2.tar.gz (4.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.0/4.0 MB 56.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting gevent>=1.3.6 (from interpret-core[dash,debug,linear,notebook,plotly,sensitivity,shap]==0.5.0->interpret==0.5.0)
#   Downloading gevent-24.2.1-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (13 kB)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from interpret-core[dash,debug,linear,notebook,plotly,sensitivity,shap]==0.5.0->interpret==0.5.0) (2.32.3)
# Requirement already satisfied: Flask<3.1,>=1.0.4 in /usr/local/lib/python3.10/dist-packages (from dash>=1.0.0->interpret-core[dash,debug,linear,notebook,plotly,sensitivity,shap]==0.5.0->interpret==0.5.0) (2.2.5)
# Requirement already satisfied: Werkzeug<3.1 in /usr/local/lib/python3.10/dist-packages (from dash>=1.0.0->interpret-core[dash,debug,linear,notebook,plotly,sensitivity,shap]==0.5.0->interpret==0.5.0) (3.0.4)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.10/dist-packages (from dash>=1.0.0->interpret-core[dash,debug,linear,notebook,plotly,sensitivity,shap]==0.5.0->interpret==0.5.0) (8.4.0)
# Requirement already satisfied: typing-extensions>=4.1.1 in /usr/local/lib/python3.10/dist-packages (from dash>=1.0.0->interpret-core[dash,debug,linear,notebook,plotly,sensitivity,shap]==0.5.0->interpret==0.5.0) (4.12.2)
# Collecting retrying (from dash>=1.0.0->interpret-core[dash,debug,linear,notebook,plotly,sensitivity,shap]==0.5.0->interpret==0.5.0)
#   Downloading retrying-1.3.4-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.10/dist-packages (from dash>=1.0.0->interpret-core[dash,debug,linear,notebook,plotly,sensitivity,shap]==0.5.0->interpret==0.5.0) (1.6.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from dash>=1.0.0->interpret-core[dash,debug,linear,notebook,plotly,sensitivity,shap]==0.5.0->interpret==0.5.0) (71.0.4)
# Collecting zope.event (from gevent>=1.3.6->interpret-core[dash,debug,linear,notebook,plotly,sensitivity,shap]==0.5.0->interpret==0.5.0)
#   Downloading zope.event-5.0-py3-none-any.whl.metadata (4.4 kB)
# Collecting zope.interface (from gevent>=1.3.6->interpret-core[dash,debug,linear,notebook,plotly,sensitivity,shap]==0.5.0->interpret==0.5.0)
#   Downloading zope.interface-7.0.3-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 3.3 MB/s eta 0:00:00
# Requirement already satisfied: greenlet>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from gevent>=1.3.6->interpret-core[dash,debug,linear,notebook,plotly,sensitivity,shap]==0.5.0->interpret==0.5.0) (3.1.1)
# Requirement already satisfied: ipython-genutils in /usr/local/lib/python3.10/dist-packages (from ipykernel>=4.10.0->interpret-core[dash,debug,linear,notebook,plotly,sensitivity,shap]==0.5.0->interpret==0.5.0) (0.2.0)
# Requirement already satisfied: traitlets>=4.1.0 in /usr/local/lib/python3.10/dist-packages (from ipykernel>=4.10.0->interpret-core[dash,debug,linear,notebook,plotly,sensitivity,shap]==0.5.0->interpret==0.5.0) (5.7.1)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.10/dist-packages (from ipykernel>=4.10.0->interpret-core[dash,debug,linear,notebook,plotly,sensitivity,shap]==0.5.0->interpret==0.5.0) (6.1.12)
# Requirement already satisfied: tornado>=4.2 in /usr/local/lib/python3.10/dist-packages (from ipykernel>=4.10.0->interpret-core[dash,debug,linear,notebook,plotly,sensitivity,shap]==0.5.0->interpret==0.5.0) (6.3.3)
# Collecting jedi>=0.16 (from ipython>=5.5.0->interpret-core[dash,debug,linear,notebook,plotly,sensitivity,shap]==0.5.0->interpret==0.5.0)
#   Using cached jedi-0.19.1-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython>=5.5.0->interpret-core[dash,debug,linear,notebook,plotly,sensitivity,shap]==0.5.0->interpret==0.5.0) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython>=5.5.0->interpret-core[dash,debug,linear,notebook,plotly,sensitivity,shap]==0.5.0->interpret==0.5.0) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ipython>=5.5.0->interpret-core[dash,debug,linear,notebook,plotly,sensitivity,shap]==0.5.0->interpret==0.5.0) (3.0.48)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from ipython>=5.5.0->interpret-core[dash,debug,linear,notebook,plotly,sensitivity,shap]==0.5.0->interpret==0.5.0) (2.18.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython>=5.5.0->interpret-core[dash,debug,linear,notebook,plotly,sensitivity,shap]==0.5.0->interpret==0.5.0) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython>=5.5.0->interpret-core[dash,debug,linear,notebook,plotly,sensitivity,shap]==0.5.0->interpret==0.5.0) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython>=5.5.0->interpret-core[dash,debug,linear,notebook,plotly,sensitivity,shap]==0.5.0->interpret==0.5.0) (4.9.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.19.2->interpret-core==0.5.0->interpret-core[dash,debug,linear,notebook,plotly,sensitivity,shap]==0.5.0->interpret==0.5.0) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.19.2->interpret-core==0.5.0->interpret-core[dash,debug,linear,notebook,plotly,sensitivity,shap]==0.5.0->interpret==0.5.0) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.19.2->interpret-core==0.5.0->interpret-core[dash,debug,linear,notebook,plotly,sensitivity,shap]==0.5.0->interpret==0.5.0) (2024.2)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly>=3.8.1->interpret-core[dash,debug,linear,notebook,plotly,sensitivity,shap]==0.5.0->interpret==0.5.0) (9.0.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from plotly>=3.8.1->interpret-core[dash,debug,linear,notebook,plotly,sensitivity,shap]==0.5.0->interpret==0.5.0) (24.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->interpret-core[dash,debug,linear,notebook,plotly,sensitivity,shap]==0.5.0->interpret==0.5.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->interpret-core[dash,debug,linear,notebook,plotly,sensitivity,shap]==0.5.0->interpret==0.5.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->interpret-core[dash,debug,linear,notebook,plotly,sensitivity,shap]==0.5.0->interpret==0.5.0) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->interpret-core[dash,debug,linear,notebook,plotly,sensitivity,shap]==0.5.0->interpret==0.5.0) (2024.8.30)
# Requirement already satisfied: matplotlib>=3.5 in /usr/local/lib/python3.10/dist-packages (from SALib>=1.3.3->interpret-core[dash,debug,linear,notebook,plotly,sensitivity,shap]==0.5.0->interpret==0.5.0) (3.7.1)
# Collecting multiprocess (from SALib>=1.3.3->interpret-core[dash,debug,linear,notebook,plotly,sensitivity,shap]==0.5.0->interpret==0.5.0)
#   Downloading multiprocess-0.70.17-py310-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.18.1->interpret-core==0.5.0->interpret-core[dash,debug,linear,notebook,plotly,sensitivity,shap]==0.5.0->interpret==0.5.0) (3.5.0)
# Requirement already satisfied: tqdm>=4.27.0 in /usr/local/lib/python3.10/dist-packages (from shap>=0.28.5->interpret-core[dash,debug,linear,notebook,plotly,sensitivity,shap]==0.5.0->interpret==0.5.0) (4.66.5)
# Collecting slicer==0.0.8 (from shap>=0.28.5->interpret-core[dash,debug,linear,notebook,plotly,sensitivity,shap]==0.5.0->interpret==0.5.0)
#   Downloading slicer-0.0.8-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: numba in /usr/local/lib/python3.10/dist-packages (from shap>=0.28.5->interpret-core[dash,debug,linear,notebook,plotly,sensitivity,shap]==0.5.0->interpret==0.5.0) (0.60.0)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.10/dist-packages (from shap>=0.28.5->interpret-core[dash,debug,linear,notebook,plotly,sensitivity,shap]==0.5.0->interpret==0.5.0) (2.2.1)
# Requirement already satisfied: Jinja2>=3.0 in /usr/local/lib/python3.10/dist-packages (from Flask<3.1,>=1.0.4->dash>=1.0.0->interpret-core[dash,debug,linear,notebook,plotly,sensitivity,shap]==0.5.0->interpret==0.5.0) (3.1.4)
# Requirement already satisfied: itsdangerous>=2.0 in /usr/local/lib/python3.10/dist-packages (from Flask<3.1,>=1.0.4->dash>=1.0.0->interpret-core[dash,debug,linear,notebook,plotly,sensitivity,shap]==0.5.0->interpret==0.5.0) (2.2.0)
# Requirement already satisfied: click>=8.0 in /usr/local/lib/python3.10/dist-packages (from Flask<3.1,>=1.0.4->dash>=1.0.0->interpret-core[dash,debug,linear,notebook,plotly,sensitivity,shap]==0.5.0->interpret==0.5.0) (8.1.7)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython>=5.5.0->interpret-core[dash,debug,linear,notebook,plotly,sensitivity,shap]==0.5.0->interpret==0.5.0) (0.8.4)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.5->SALib>=1.3.3->interpret-core[dash,debug,linear,notebook,plotly,sensitivity,shap]==0.5.0->interpret==0.5.0) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.5->SALib>=1.3.3->interpret-core[dash,debug,linear,notebook,plotly,sensitivity,shap]==0.5.0->interpret==0.5.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.5->SALib>=1.3.3->interpret-core[dash,debug,linear,notebook,plotly,sensitivity,shap]==0.5.0->interpret==0.5.0) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.5->SALib>=1.3.3->interpret-core[dash,debug,linear,notebook,plotly,sensitivity,shap]==0.5.0->interpret==0.5.0) (1.4.7)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.5->SALib>=1.3.3->interpret-core[dash,debug,linear,notebook,plotly,sensitivity,shap]==0.5.0->interpret==0.5.0) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.5->SALib>=1.3.3->interpret-core[dash,debug,linear,notebook,plotly,sensitivity,shap]==0.5.0->interpret==0.5.0) (3.1.4)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython>=5.5.0->interpret-core[dash,debug,linear,notebook,plotly,sensitivity,shap]==0.5.0->interpret==0.5.0) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.5.0->interpret-core[dash,debug,linear,notebook,plotly,sensitivity,shap]==0.5.0->interpret==0.5.0) (0.2.13)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas>=0.19.2->interpret-core==0.5.0->interpret-core[dash,debug,linear,notebook,plotly,sensitivity,shap]==0.5.0->interpret==0.5.0) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from Werkzeug<3.1->dash>=1.0.0->interpret-core[dash,debug,linear,notebook,plotly,sensitivity,shap]==0.5.0->interpret==0.5.0) (2.1.5)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata->dash>=1.0.0->interpret-core[dash,debug,linear,notebook,plotly,sensitivity,shap]==0.5.0->interpret==0.5.0) (3.20.2)
# Requirement already satisfied: jupyter-core>=4.6.0 in /usr/local/lib/python3.10/dist-packages (from jupyter-client->ipykernel>=4.10.0->interpret-core[dash,debug,linear,notebook,plotly,sensitivity,shap]==0.5.0->interpret==0.5.0) (5.7.2)
# Requirement already satisfied: pyzmq>=13 in /usr/local/lib/python3.10/dist-packages (from jupyter-client->ipykernel>=4.10.0->interpret-core[dash,debug,linear,notebook,plotly,sensitivity,shap]==0.5.0->interpret==0.5.0) (24.0.1)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba->shap>=0.28.5->interpret-core[dash,debug,linear,notebook,plotly,sensitivity,shap]==0.5.0->interpret==0.5.0) (0.43.0)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.10/dist-packages (from jupyter-core>=4.6.0->jupyter-client->ipykernel>=4.10.0->interpret-core[dash,debug,linear,notebook,plotly,sensitivity,shap]==0.5.0->interpret==0.5.0) (4.3.6)
# Downloading interpret-0.5.0-py3-none-any.whl (1.4 kB)
# Downloading interpret_core-0.5.0-py3-none-any.whl (15.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.8/15.8 MB 50.6 MB/s eta 0:00:00
# Downloading dash-2.18.1-py3-none-any.whl (7.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.5/7.5 MB 63.7 MB/s eta 0:00:00
# Downloading dash_core_components-2.0.0-py3-none-any.whl (3.8 kB)
# Downloading dash_html_components-2.0.0-py3-none-any.whl (4.1 kB)
# Downloading dash_table-5.0.0-py3-none-any.whl (3.9 kB)
# Downloading dill-0.3.9-py3-none-any.whl (119 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.4/119.4 kB 9.5 MB/s eta 0:00:00
# Downloading gevent-24.2.1-cp310-cp310-manylinux_2_28_x86_64.whl (6.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.5/6.5 MB 55.1 MB/s eta 0:00:00
# Downloading salib-1.5.1-py3-none-any.whl (778 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 778.9/778.9 kB 35.6 MB/s eta 0:00:00
# Downloading shap-0.46.0-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (540 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 540.1/540.1 kB 30.5 MB/s eta 0:00:00
# Downloading slicer-0.0.8-py3-none-any.whl (15 kB)
# Using cached jedi-0.19.1-py2.py3-none-any.whl (1.6 MB)
# Downloading multiprocess-0.70.17-py310-none-any.whl (134 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 7.0 MB/s eta 0:00:00
# Downloading retrying-1.3.4-py3-none-any.whl (11 kB)
# Downloading zope.event-5.0-py3-none-any.whl (6.8 kB)
# Downloading zope.interface-7.0.3-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (254 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 254.1/254.1 kB 17.9 MB/s eta 0:00:00
# Building wheels for collected packages: dash-cytoscape
#   Building wheel for dash-cytoscape (setup.py) ... done
#   Created wheel for dash-cytoscape: filename=dash_cytoscape-1.0.2-py3-none-any.whl size=4010717 sha256=e8afbea3fb780c35b701627e72834602a14bc10c996b5aa288e6f2e77a99e87f
#   Stored in directory: /root/.cache/pip/wheels/91/23/5e/56fa701c668444b121ad2353a96478179dc49086a9c44ee930
# Successfully built dash-cytoscape
# Installing collected packages: dash-table, dash-html-components, dash-core-components, zope.interface, zope.event, slicer, retrying, jedi, dill, multiprocess, gevent, shap, SALib, interpret-core, dash, dash-cytoscape, interpret
# Successfully installed SALib-1.5.1 dash-2.18.1 dash-core-components-2.0.0 dash-cytoscape-1.0.2 dash-html-components-2.0.0 dash-table-5.0.0 dill-0.3.9 gevent-24.2.1 interpret-0.5.0 interpret-core-0.5.0 jedi-0.19.1 multiprocess-0.70.17 retrying-1.3.4 shap-0.46.0 slicer-0.0.8 zope.event-5.0 zope.interface-7.0.3
# Collecting JXAutoML
#   Downloading JXAutoML-0.4.4-py3-none-any.whl.metadata (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.2/67.2 kB 5.3 MB/s eta 0:00:00
# Downloading JXAutoML-0.4.4-py3-none-any.whl (52 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.1/52.1 kB 4.6 MB/s eta 0:00:00
# Installing collected packages: JXAutoML
# Successfully installed JXAutoML-0.4.4

# %%
# Parameters that are same for every script

FOLDS = 10  # we have decided to do 10 fold validation

SEED = 42

TASK_TYPE = 'Classification'  # this task is a classification task

# we have decided to tune features as hp
TUNE_FEATURES_AS_HYPERPARAMETERS = True

# %% [markdown]
# ---

# %%
# model to use to tune
from interpret.glassbox import ExplainableBoostingClassifier as clf

# what values to try for each hyperparameter
parameter_choices = {
    'max_bins': (4, 6, 64, 256, 1024, 4096),
    'min_samples_leaf': (2, 4, 8, 16, 32),
    'interactions': (2, 4, 8),
    'max_leaves': (100, 1000, 10000),
    'learning_rate': (0.001, 0.01, 0.1, 1),
    'max_rounds': (25, 50, 100, 200),

}

# what values to set non-tuneable parameters/hyperparameters
non_tunable_hyperparameters_dict = {
                                    'random_state': SEED,
                                    'n_jobs': -1
                                    }

# %% [markdown]
# ---

# %% [markdown]
# Read in and Prepare Data

# %%
# Import data and store as lists

train_x_list = []
train_y_list = []
val_x_list = []
val_y_list = []

for i in range(FOLDS):
    train_data = pd.read_csv(
        f'{home_directory}data/curated/modelling/{PREPROCESSING}/train_{i}.csv')
    val_data = pd.read_csv(
        f'{home_directory}data/curated/modelling/{PREPROCESSING}/val_{i}.csv')

    # get the correct rows for X and y
    train_x = train_data.drop(
        ['mortality_status', 'subject_id', 'hadm_id', 'stay_id'], axis=1)
    train_y = train_data['mortality_status']
    val_x = val_data.drop(
        ['mortality_status', 'subject_id', 'hadm_id', 'stay_id'], axis=1)
    val_y = val_data['mortality_status']

    train_x_list.append(train_x)
    train_y_list.append(train_y)
    val_x_list.append(val_x)
    val_y_list.append(val_y)

# %%
# Import feature importance ordering

with open(f'{home_directory}models/xgb_feature_importance_ordering_{PREPROCESSING}.pickle', 'rb') as f:
    feature_importance_ordering = pickle.load(f)

# %% [markdown]
# Set parameters

# %%
# initialisation
tuner = Tuner()

print('---')

# define what model we are tuning
tuner.read_in_model(clf, TASK_TYPE, optimised_metric=OPTIMISED_METRIC)

print('---')

# read in the data for training and validation
tuner.read_in_data(train_x_list, train_y_list, val_x_list, val_y_list)

print('---')

# set what hp values to tune
tuner.set_hyperparameters(parameter_choices)
# WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

# set up hp values that need to be changed from default but NOT to be tuned
tuner.set_non_tuneable_hyperparameters(non_tunable_hyperparameters_dict)

print('---')

# set up feature importance ordering

if TUNE_FEATURES_AS_HYPERPARAMETERS:
    tuner.set_features(feature_importance_ordering)
    # WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

try:  # try to read in previous results to continue tuning ...
    tuner.read_in_tuning_result_df(
        f'{home_directory}models/tuning/{TUNER}_{MODEL}_{PREPROCESSING}.csv')
except:
    print('No previous tuning data read in')

print('---')

# set up where to save the tuning result csv
tuner.set_tuning_result_saving_address(
    f'{home_directory}models/tuning/{TUNER}_{MODEL}_{PREPROCESSING}.csv')

print('---')

# set up where to save the current best model
tuner.set_best_model_saving_address(
    f'{home_directory}models/tmp_models/{TUNER}_{MODEL}_{PREPROCESSING}')
# Out:
# YangZhouB Initialised
# ---
# Successfully read in model <class 'interpret.glassbox._ebm._ebm.ExplainableBoostingClassifier'>, which is a Classification model optimising for f1
# ---
# Read in Train X data list
# Read in Train y data list
# Read in Val X data list
# Read in Val y data list
# ---
# Successfully recorded hyperparameter choices
# ---
# Successfully recorded non_tuneable_hyperparameter choices
# ---
# Successfully recorded tuneable feature combination choices and updated relevant internal structures
# ---
# Successfully read in tuning result of 839 rows, for 839.0 combos
# ---
# Successfully set tuning output address
# ---
# Successfully set best model output address

# %%
# ignore warnings

import warnings
warnings.filterwarnings("ignore")

# %%
# begin tuning ... (or continue training)

tuner.tune()
# Out:
# Streaming output truncated to the last 5000 lines.
#                     {'max_bins': 1024, 'min_samples_leaf': 32, 'interactions': 2, 'max_leaves': 100, 'learning_rate': 0.001, 'max_rounds': 200, 'features': 49}
# Already Trained and Tested combination (val score of 0.436):
#             {'max_bins': 6, 'min_samples_leaf': 2, 'interactions': 2, 'max_leaves': 10000, 'learning_rate': 1, 'max_rounds': 50, 'features': 5}
#             Current best combo (with val score 0.516):
#                     {'max_bins': 1024, 'min_samples_leaf': 32, 'interactions': 2, 'max_leaves': 100, 'learning_rate': 0.001, 'max_rounds': 200, 'features': 49}
#         Has trained 1125 of 220320 combinations so far
# Already Trained and Tested combination (val score of 0.425):
#             {'max_bins': 4, 'min_samples_leaf': 4, 'interactions': 2, 'max_leaves': 10000, 'learning_rate': 1, 'max_rounds': 50, 'features': 5}
#             Current best combo (with val score 0.516):
#                     {'max_bins': 1024, 'min_samples_leaf': 32, 'interactions': 2, 'max_leaves': 100, 'learning_rate': 0.001, 'max_rounds': 200, 'features': 49}
#         Has trained 1125 of 220320 combinations so far
# Already Trained and Tested combination (val score of 0.4132):
#             {'max_bins': 4, 'min_samples_leaf': 2, 'interactions': 4, 'max_leaves': 10000, 'learning_rate': 1, 'max_rounds': 50, 'features': 5}
#             Current best combo (with val score 0.516):
#                     {'max_bins': 1024, 'min_samples_leaf': 32, 'interactions': 2, 'max_leaves': 100, 'learning_rate': 0.001, 'max_rounds': 200, 'features': 49}
#         Has trained 1125 of 220320 combinations so far
# Already Trained and Tested combination (val score of 0.418):
#             {'max_bins': 4, 'min_samples_leaf': 2, 'interactions': 2, 'max_leaves': 1000, 'learning_rate': 1, 'max_rounds': 50, 'features': 5}
#             Current best combo (with val score 0.516):
#                     {'max_bins': 1024, 'min_samples_leaf': 32, 'interactions': 2, 'max_leaves': 100, 'learning_rate': 0.001, 'max_rounds': 200, 'features': 49}
#         Has trained 1125 of 220320 combinations so far
# Already Trained and Tested combination (val score of 0.4431):
#             {'max_bins': 4, 'min_samples_leaf': 2, 'interactions': 2, 'max_leaves': 10000, 'learning_rate': 0.1, 'max_rounds': 50, 'features': 5}
#             Current best combo (with val score 0.516):
#                     {'max_bins': 1024, 'min_samples_leaf': 32, 'interactions': 2, 'max_leaves': 100, 'learning_rate': 0.001, 'max_rounds': 200, 'features': 49}
#         Has trained 1125 of 220320 combinations so far
# Already Trained and Tested combination (val score of 0.4179):
#             {'max_bins': 4, 'min_samples_leaf': 2, 'interactions': 2, 'max_leaves': 10000, 'learning_rate': 1, 'max_rounds': 25, 'features': 5}
#             Current best combo (with val score 0.516):
#                     {'max_bins': 1024, 'min_samples_leaf': 32, 'interactions': 2, 'max_leaves': 100, 'learning_rate': 0.001, 'max_rounds': 200, 'features': 49}
#         Has trained 1125 of 220320 combinations so far
# Trained and Tested combination 1126 of 220320, taking 1.23 seconds to get val score of 0.418:
#                 {'max_bins': 4, 'min_samples_leaf': 2, 'interactions': 2, 'max_leaves': 10000, 'learning_rate': 1, 'max_rounds': 100, 'features': 5},
#             Current best combo with val score 0.516:
#                     {'max_bins': 1024, 'min_samples_leaf': 32, 'interactions': 2, 'max_leaves': 100, 'learning_rate': 0.001, 'max_rounds': 200, 'features': 49}
# Trained and Tested combination 1127 of 220320, taking 1.12 seconds to get val score of 0.0033:
#                 {'max_bins': 4, 'min_samples_leaf': 2, 'interactions': 2, 'max_leaves': 10000, 'learning_rate': 1, 'max_rounds': 50, 'features': 4},
#             Current best combo with val score 0.516:
#                     {'max_bins': 1024, 'min_samples_leaf': 32, 'interactions': 2, 'max_leaves': 100, 'learning_rate': 0.001, 'max_rounds': 200, 'features': 49}
# Trained and Tested combination 1128 of 220320, taking 1.56 seconds to get val score of 0.4135:
#                 {'max_bins': 4, 'min_samples_leaf': 2, 'interactions': 2, 'max_leaves': 10000, 'learning_rate': 1, 'max_rounds': 50, 'features': 6},
#             Current best combo with val score 0.516:
#                     {'max_bins': 1024, 'min_samples_leaf': 32, 'interactions': 2, 'max_leaves': 100, 'learning_rate': 0.001, 'max_rounds': 200, 'features': 49}
# Already Trained and Tested combination (val score of 0.4341):
#             {'max_bins': 6, 'min_samples_leaf': 2, 'interactions': 2, 'max_leaves': 10000, 'learning_rate': 1, 'max_rounds': 25, 'features': 6}
#             Current best combo (with val score 0.516):
#                     {'max_bins': 1024, 'min_samples_leaf': 32, 'interactions': 2, 'max_leaves': 100, 'learning_rate': 0.001, 'max_rounds': 200, 'features': 49}
#         Has trained 1128 of 220320 combinations so far
# Already Trained and Tested combination (val score of 0.416):
#             {'max_bins': 4, 'min_samples_leaf': 4, 'interactions': 2, 'max_leaves': 10000, 'learning_rate': 1, 'max_rounds': 25, 'features': 6}
#             Current best combo (with val score 0.516):
#                     {'max_bins': 1024, 'min_samples_leaf': 32, 'interactions': 2, 'max_leaves': 100, 'learning_rate': 0.001, 'max_rounds': 200, 'features': 49}
#         Has trained 1128 of 220320 combinations so far
# Already Trained and Tested combination (val score of 0.423):
#             {'max_bins': 4, 'min_samples_leaf': 2, 'interactions': 4, 'max_leaves': 10000, 'learning_rate': 1, 'max_rounds': 25, 'features': 6}
#             Current best combo (with val score 0.516):
#                     {'max_bins': 1024, 'min_samples_leaf': 32, 'interactions': 2, 'max_leaves': 100, 'learning_rate': 0.001, 'max_rounds': 200, 'features': 49}
#         Has trained 1128 of 220320 combinations so far
# Already Trained and Tested combination (val score of 0.4135):
#             {'max_bins': 4, 'min_samples_leaf': 2, 'interactions': 2, 'max_leaves': 1000, 'learning_rate': 1, 'max_rounds': 25, 'features': 6}
#             Current best combo (with val score 0.516):
#                     {'max_bins': 1024, 'min_samples_leaf': 32, 'interactions': 2, 'max_leaves': 100, 'learning_rate': 0.001, 'max_rounds': 200, 'features': 49}
#         Has trained 1128 of 220320 combinations so far
# Already Trained and Tested combination (val score of 0.4449):
#             {'max_bins': 4, 'min_samples_leaf': 2, 'interactions': 2, 'max_leaves': 10000, 'learning_rate': 0.1, 'max_rounds': 25, 'features': 6}
#             Current best combo (with val score 0.516):
#                     {'max_bins': 1024, 'min_samples_leaf': 32, 'interactions': 2, 'max_leaves': 100, 'learning_rate': 0.001, 'max_rounds': 200, 'features': 49}
#         Has trained 1128 of 220320 combinations so far
# Already Trained and Tested combination (val score of 0.4135):
#             {'max_bins': 4, 'min_samples_leaf': 2, 'interactions': 2, 'max_leaves': 10000, 'learning_rate': 1, 'max_rounds': 50, 'features': 6}
#             Current best combo (with val score 0.516):
#                     {'max_bins': 1024, 'min_samples_leaf': 32, 'interactions': 2, 'max_leaves': 100, 'learning_rate': 0.001, 'max_rounds': 200, 'features': 49}
#         Has trained 1128 of 220320 combinations so far
# Already Trained and Tested combination (val score of 0.4179):
#             {'max_bins': 4, 'min_samples_leaf': 2, 'interactions': 2, 'max_leaves': 10000, 'learning_rate': 1, 'max_rounds': 25, 'features': 5}
#             Current best combo (with val score 0.516):
#                     {'max_bins': 1024, 'min_samples_leaf': 32, 'interactions': 2, 'max_leaves': 100, 'learning_rate': 0.001, 'max_rounds': 200, 'features': 49}
#         Has trained 1128 of 220320 combinations so far
# Trained and Tested combination 1129 of 220320, taking 0.81 seconds to get val score of 0.4112:
#                 {'max_bins': 4, 'min_samples_leaf': 2, 'interactions': 2, 'max_leaves': 10000, 'learning_rate': 1, 'max_rounds': 25, 'features': 7},
#             Current best combo with val score 0.516:
#                     {'max_bins': 1024, 'min_samples_leaf': 32, 'interactions': 2, 'max_leaves': 100, 'learning_rate': 0.001, 'max_rounds': 200, 'features': 49}
# % Combos Checked Thus Far: 1129 out of 220320 which is 0.512436%
# Cruising Coordrdinate 81 of 704
#
# Cruise suspended due to suspicious case
# Guidance: round 13
#
# 	round 13 iteration:  0
#
# Trained and Tested combination 1130 of 220320, taking 0.86 seconds to get val score of 0.4408:
#                 {'max_bins': 6, 'min_samples_leaf': 2, 'interactions': 8, 'max_leaves': 100, 'learning_rate': 1, 'max_rounds': 25, 'features': 5},
#             Current best combo with val score 0.516:
#                     {'max_bins': 1024, 'min_samples_leaf': 32, 'interactions': 2, 'max_leaves': 100, 'learning_rate': 0.001, 'max_rounds': 200, 'features': 49}
# Trained and Tested combination 1131 of 220320, taking 0.86 seconds to get val score of 0.4138:
#                 {'max_bins': 4, 'min_samples_leaf': 4, 'interactions': 8, 'max_leaves': 100, 'learning_rate': 1, 'max_rounds': 25, 'features': 5},
#             Current best combo with val score 0.516:
#                     {'max_bins': 1024, 'min_samples_leaf': 32, 'interactions': 2, 'max_leaves': 100, 'learning_rate': 0.001, 'max_rounds': 200, 'features': 49}
# Trained and Tested combination 1132 of 220320, taking 1.29 seconds to get val score of 0.4109:
#                 {'max_bins': 4, 'min_samples_leaf': 2, 'interactions': 4, 'max_leaves': 100, 'learning_rate': 1, 'max_rounds': 25, 'features': 5},
#             Current best combo with val score 0.516:
#                     {'max_bins': 1024, 'min_samples_leaf': 32, 'interactions': 2, 'max_leaves': 100, 'learning_rate': 0.001, 'max_rounds': 200, 'features': 49}
# Already Trained and Tested combination (val score of 0.4136):
#             {'max_bins': 4, 'min_samples_leaf': 2, 'interactions': 8, 'max_leaves': 1000, 'learning_rate': 1, 'max_rounds': 25, 'features': 5}
#             Current best combo (with val score 0.516):
#                     {'max_bins': 1024, 'min_samples_leaf': 32, 'interactions': 2, 'max_leaves': 100, 'learning_rate': 0.001, 'max_rounds': 200, 'features': 49}
#         Has trained 1132 of 220320 combinations so far
# Trained and Tested combination 1133 of 220320, taking 1.28 seconds to get val score of 0.4343:
#                 {'max_bins': 4, 'min_samples_leaf': 2, 'interactions': 8, 'max_leaves': 100, 'learning_rate': 0.1, 'max_rounds': 25, 'features': 5},
#             Current best combo with val score 0.516:
#                     {'max_bins': 1024, 'min_samples_leaf': 32, 'interactions': 2, 'max_leaves': 100, 'learning_rate': 0.001, 'max_rounds': 200, 'features': 49}
# Trained and Tested combination 1134 of 220320, taking 1.31 seconds to get val score of 0.4136:
#                 {'max_bins': 4, 'min_samples_leaf': 2, 'interactions': 8, 'max_leaves': 100, 'learning_rate': 1, 'max_rounds': 50, 'features': 5},
#             Current best combo with val score 0.516:
#                     {'max_bins': 1024, 'min_samples_leaf': 32, 'interactions': 2, 'max_leaves': 100, 'learning_rate': 0.001, 'max_rounds': 200, 'features': 49}
# Trained and Tested combination 1135 of 220320, taking 0.83 seconds to get val score of 0.0033:
#                 {'max_bins': 4, 'min_samples_leaf': 2, 'interactions': 8, 'max_leaves': 100, 'learning_rate': 1, 'max_rounds': 25, 'features': 4},
#             Current best combo with val score 0.516:
#                     {'max_bins': 1024, 'min_samples_leaf': 32, 'interactions': 2, 'max_leaves': 100, 'learning_rate': 0.001, 'max_rounds': 200, 'features': 49}
# Trained and Tested combination 1136 of 220320, taking 1.36 seconds to get val score of 0.4181:
#                 {'max_bins': 4, 'min_samples_leaf': 2, 'interactions': 8, 'max_leaves': 100, 'learning_rate': 1, 'max_rounds': 25, 'features': 6},
#             Current best combo with val score 0.516:
#                     {'max_bins': 1024, 'min_samples_leaf': 32, 'interactions': 2, 'max_leaves': 100, 'learning_rate': 0.001, 'max_rounds': 200, 'features': 49}
# 	round 13 iteration:  1
#
# Already Trained and Tested combination (val score of 0.4136):
#             {'max_bins': 4, 'min_samples_leaf': 2, 'interactions': 8, 'max_leaves': 100, 'learning_rate': 1, 'max_rounds': 25, 'features': 5}
#             Current best combo (with val score 0.516):
#                     {'max_bins': 1024, 'min_samples_leaf': 32, 'interactions': 2, 'max_leaves': 100, 'learning_rate': 0.001, 'max_rounds': 200, 'features': 49}
#         Has trained 1136 of 220320 combinations so far
# Trained and Tested combination 1137 of 220320, taking 0.85 seconds to get val score of 0.4435:
#                 {'max_bins': 64, 'min_samples_leaf': 2, 'interactions': 8, 'max_leaves': 100, 'learning_rate': 1, 'max_rounds': 25, 'features': 5},
#             Current best combo with val score 0.516:
#                     {'max_bins': 1024, 'min_samples_leaf': 32, 'interactions': 2, 'max_leaves': 100, 'learning_rate': 0.001, 'max_rounds': 200, 'features': 49}
# Trained and Tested combination 1138 of 220320, taking 0.85 seconds to get val score of 0.4362:
#                 {'max_bins': 6, 'min_samples_leaf': 4, 'interactions': 8, 'max_leaves': 100, 'learning_rate': 1, 'max_rounds': 25, 'features': 5},
#             Current best combo with val score 0.516:
#                     {'max_bins': 1024, 'min_samples_leaf': 32, 'interactions': 2, 'max_leaves': 100, 'learning_rate': 0.001, 'max_rounds': 200, 'features': 49}
# Trained and Tested combination 1139 of 220320, taking 0.82 seconds to get val score of 0.4406:
#                 {'max_bins': 6, 'min_samples_leaf': 2, 'interactions': 4, 'max_leaves': 100, 'learning_rate': 1, 'max_rounds': 25, 'features': 5},
#             Current best combo with val score 0.516:
#                     {'max_bins': 1024, 'min_samples_leaf': 32, 'interactions': 2, 'max_leaves': 100, 'learning_rate': 0.001, 'max_rounds': 200, 'features': 49}
# Already Trained and Tested combination (val score of 0.4408):
#             {'max_bins': 6, 'min_samples_leaf': 2, 'interactions': 8, 'max_leaves': 1000, 'learning_rate': 1, 'max_rounds': 25, 'features': 5}
#             Current best combo (with val score 0.516):
#                     {'max_bins': 1024, 'min_samples_leaf': 32, 'interactions': 2, 'max_leaves': 100, 'learning_rate': 0.001, 'max_rounds': 200, 'features': 49}
#         Has trained 1139 of 220320 combinations so far
# Trained and Tested combination 1140 of 220320, taking 1.18 seconds to get val score of 0.4427:
#                 {'max_bins': 6, 'min_samples_leaf': 2, 'interactions': 8, 'max_leaves': 100, 'learning_rate': 0.1, 'max_rounds': 25, 'features': 5},
#             Current best combo with val score 0.516:
#                     {'max_bins': 1024, 'min_samples_leaf': 32, 'interactions': 2, 'max_leaves': 100, 'learning_rate': 0.001, 'max_rounds': 200, 'features': 49}
# Trained and Tested combination 1141 of 220320, taking 1.86 seconds to get val score of 0.4408:
#                 {'max_bins': 6, 'min_samples_leaf': 2, 'interactions': 8, 'max_leaves': 100, 'learning_rate': 1, 'max_rounds': 50, 'features': 5},
#             Current best combo with val score 0.516:
#                     {'max_bins': 1024, 'min_samples_leaf': 32, 'interactions': 2, 'max_leaves': 100, 'learning_rate': 0.001, 'max_rounds': 200, 'features': 49}
# Trained and Tested combination 1142 of 220320, taking 0.84 seconds to get val score of 0.0:
#                 {'max_bins': 6, 'min_samples_leaf': 2, 'interactions': 8, 'max_leaves': 100, 'learning_rate': 1, 'max_rounds': 25, 'features': 4},
#             Current best combo with val score 0.516:
#                     {'max_bins': 1024, 'min_samples_leaf': 32, 'interactions': 2, 'max_leaves': 100, 'learning_rate': 0.001, 'max_rounds': 200, 'features': 49}
# Trained and Tested combination 1143 of 220320, taking 0.88 seconds to get val score of 0.4375:
#                 {'max_bins': 6, 'min_samples_leaf': 2, 'interactions': 8, 'max_leaves': 100, 'learning_rate': 1, 'max_rounds': 25, 'features': 6},
#             Current best combo with val score 0.516:
#                     {'max_bins': 1024, 'min_samples_leaf': 32, 'interactions': 2, 'max_leaves': 100, 'learning_rate': 0.001, 'max_rounds': 200, 'features': 49}
# Already Trained and Tested combination (val score of 0.4362):
#             {'max_bins': 6, 'min_samples_leaf': 4, 'interactions': 8, 'max_leaves': 100, 'learning_rate': 1, 'max_rounds': 25, 'features': 5}
#             Current best combo (with val score 0.516):
#                     {'max_bins': 1024, 'min_samples_leaf': 32, 'interactions': 2, 'max_leaves': 100, 'learning_rate': 0.001, 'max_rounds': 200, 'features': 49}
#         Has trained 1143 of 220320 combinations so far
# Already Trained and Tested combination (val score of 0.4136):
#             {'max_bins': 4, 'min_samples_leaf': 2, 'interactions': 8, 'max_leaves': 100, 'learning_rate': 1, 'max_rounds': 25, 'features': 5}
#             Current best combo (with val score 0.516):
#                     {'max_bins': 1024, 'min_samples_leaf': 32, 'interactions': 2, 'max_leaves': 100, 'learning_rate': 0.001, 'max_rounds': 200, 'features': 49}
#         Has trained 1143 of 220320 combinations so far
# Trained and Tested combination 1144 of 220320, taking 1.46 seconds to get val score of 0.4209:
#                 {'max_bins': 4, 'min_samples_leaf': 8, 'interactions': 8, 'max_leaves': 100, 'learning_rate': 1, 'max_rounds': 25, 'features': 5},
#             Current best combo with val score 0.516:
#                     {'max_bins': 1024, 'min_samples_leaf': 32, 'interactions': 2, 'max_leaves': 100, 'learning_rate': 0.001, 'max_rounds': 200, 'features': 49}
# Trained and Tested combination 1145 of 220320, taking 0.8 seconds to get val score of 0.4184:
#                 {'max_bins': 4, 'min_samples_leaf': 4, 'interactions': 4, 'max_leaves': 100, 'learning_rate': 1, 'max_rounds': 25, 'features': 5},
#             Current best combo with val score 0.516:
#                     {'max_bins': 1024, 'min_samples_leaf': 32, 'interactions': 2, 'max_leaves': 100, 'learning_rate': 0.001, 'max_rounds': 200, 'features': 49}
# Already Trained and Tested combination (val score of 0.4138):
#             {'max_bins': 4, 'min_samples_leaf': 4, 'interactions': 8, 'max_leaves': 1000, 'learning_rate': 1, 'max_rounds': 25, 'features': 5}
#             Current best combo (with val score 0.516):
#                     {'max_bins': 1024, 'min_samples_leaf': 32, 'interactions': 2, 'max_leaves': 100, 'learning_rate': 0.001, 'max_rounds': 200, 'features': 49}
#         Has trained 1145 of 220320 combinations so far
# Trained and Tested combination 1146 of 220320, taking 0.88 seconds to get val score of 0.4404:
#                 {'max_bins': 4, 'min_samples_leaf': 4, 'interactions': 8, 'max_leaves': 100, 'learning_rate': 0.1, 'max_rounds': 25, 'features': 5},
#             Current best combo with val score 0.516:
#                     {'max_bins': 1024, 'min_samples_leaf': 32, 'interactions': 2, 'max_leaves': 100, 'learning_rate': 0.001, 'max_rounds': 200, 'features': 49}
# Trained and Tested combination 1147 of 220320, taking 1.31 seconds to get val score of 0.4115:
#                 {'max_bins': 4, 'min_samples_leaf': 4, 'interactions': 8, 'max_leaves': 100, 'learning_rate': 1, 'max_rounds': 50, 'features': 5},
#             Current best combo with val score 0.516:
#                     {'max_bins': 1024, 'min_samples_leaf': 32, 'interactions': 2, 'max_leaves': 100, 'learning_rate': 0.001, 'max_rounds': 200, 'features': 49}
# Trained and Tested combination 1148 of 220320, taking 1.47 seconds to get val score of 0.0033:
#                 {'max_bins': 4, 'min_samples_leaf': 4, 'interactions': 8, 'max_leaves': 100, 'learning_rate': 1, 'max_rounds': 25, 'features': 4},
#             Current best combo with val score 0.516:
#                     {'max_bins': 1024, 'min_samples_leaf': 32, 'interactions': 2, 'max_leaves': 100, 'learning_rate': 0.001, 'max_rounds': 200, 'features': 49}
# Trained and Tested combination 1149 of 220320, taking 0.87 seconds to get val score of 0.4195:
#                 {'max_bins': 4, 'min_samples_leaf': 4, 'interactions': 8, 'max_leaves': 100, 'learning_rate': 1, 'max_rounds': 25, 'features': 6},
#             Current best combo with val score 0.516:
#                     {'max_bins': 1024, 'min_samples_leaf': 32, 'interactions': 2, 'max_leaves': 100, 'learning_rate': 0.001, 'max_rounds': 200, 'features': 49}
# Already Trained and Tested combination (val score of 0.4406):
#             {'max_bins': 6, 'min_samples_leaf': 2, 'interactions': 4, 'max_leaves': 100, 'learning_rate': 1, 'max_rounds': 25, 'features': 5}
#             Current best combo (with val score 0.516):
#                     {'max_bins': 1024, 'min_samples_leaf': 32, 'interactions': 2, 'max_leaves': 100, 'learning_rate': 0.001, 'max_rounds': 200, 'features': 49}
#         Has trained 1149 of 220320 combinations so far
# Already Trained and Tested combination (val score of 0.4184):
#             {'max_bins': 4, 'min_samples_leaf': 4, 'interactions': 4, 'max_leaves': 100, 'learning_rate': 1, 'max_rounds': 25, 'features': 5}
#             Current best combo (with val score 0.516):
#                     {'max_bins': 1024, 'min_samples_leaf': 32, 'interactions': 2, 'max_leaves': 100, 'learning_rate': 0.001, 'max_rounds': 200, 'features': 49}
#         Has trained 1149 of 220320 combinations so far
# Already Trained and Tested combination (val score of 0.4179):
#             {'max_bins': 4, 'min_samples_leaf': 2, 'interactions': 2, 'max_leaves': 100, 'learning_rate': 1, 'max_rounds': 25, 'features': 5}
#             Current best combo (with val score 0.516):
#                     {'max_bins': 1024, 'min_samples_leaf': 32, 'interactions': 2, 'max_leaves': 100, 'learning_rate': 0.001, 'max_rounds': 200, 'features': 49}
#         Has trained 1149 of 220320 combinations so far
# Already Trained and Tested combination (val score of 0.4136):
#             {'max_bins': 4, 'min_samples_leaf': 2, 'interactions': 8, 'max_leaves': 100, 'learning_rate': 1, 'max_rounds': 25, 'features': 5}
#             Current best combo (with val score 0.516):
#                     {'max_bins': 1024, 'min_samples_leaf': 32, 'interactions': 2, 'max_leaves': 100, 'learning_rate': 0.001, 'max_rounds': 200, 'features': 49}
#         Has trained 1149 of 220320 combinations so far
# Already Trained and Tested combination (val score of 0.4109):
#             {'max_bins': 4, 'min_samples_leaf': 2, 'interactions': 4, 'max_leaves': 1000, 'learning_rate': 1, 'max_rounds': 25, 'features': 5}
#             Current best combo (with val score 0.516):
#                     {'max_bins': 1024, 'min_samples_leaf': 32, 'interactions': 2, 'max_leaves': 100, 'learning_rate': 0.001, 'max_rounds': 200, 'features': 49}
#         Has trained 1149 of 220320 combinations so far
# Trained and Tested combination 1150 of 220320, taking 0.9 seconds to get val score of 0.4452:
#                 {'max_bins': 4, 'min_samples_leaf': 2, 'interactions': 4, 'max_leaves': 100, 'learning_rate': 0.1, 'max_rounds': 25, 'features': 5},
#             Current best combo with val score 0.516:
#                     {'max_bins': 1024, 'min_samples_leaf': 32, 'interactions': 2, 'max_leaves': 100, 'learning_rate': 0.001, 'max_rounds': 200, 'features': 49}
# Trained and Tested combination 1151 of 220320, taking 1.23 seconds to get val score of 0.4132:
#                 {'max_bins': 4, 'min_samples_leaf': 2, 'interactions': 4, 'max_leaves': 100, 'learning_rate': 1, 'max_rounds': 50, 'features': 5},
#             Current best combo with val score 0.516:
#                     {'max_bins': 1024, 'min_samples_leaf': 32, 'interactions': 2, 'max_leaves': 100, 'learning_rate': 0.001, 'max_rounds': 200, 'features': 49}
# Trained and Tested combination 1152 of 220320, taking 1.37 seconds to get val score of 0.0033:
#                 {'max_bins': 4, 'min_samples_leaf': 2, 'interactions': 4, 'max_leaves': 100, 'learning_rate': 1, 'max_rounds': 25, 'features': 4},
#             Current best combo with val score 0.516:
#                     {'max_bins': 1024, 'min_samples_leaf': 32, 'interactions': 2, 'max_leaves': 100, 'learning_rate': 0.001, 'max_rounds': 200, 'features': 49}
# Trained and Tested combination 1153 of 220320, taking 0.82 seconds to get val score of 0.423:
#                 {'max_bins': 4, 'min_samples_leaf': 2, 'interactions': 4, 'max_leaves': 100, 'learning_rate': 1, 'max_rounds': 25, 'features': 6},
#             Current best combo with val score 0.516:
#                     {'max_bins': 1024, 'min_samples_leaf': 32, 'interactions': 2, 'max_leaves': 100, 'learning_rate': 0.001, 'max_rounds': 200, 'features': 49}
# Already Trained and Tested combination (val score of 0.4427):
#             {'max_bins': 6, 'min_samples_leaf': 2, 'interactions': 8, 'max_leaves': 100, 'learning_rate': 0.1, 'max_rounds': 25, 'features': 5}
#             Current best combo (with val score 0.516):
#                     {'max_bins': 1024, 'min_samples_leaf': 32, 'interactions': 2, 'max_leaves': 100, 'learning_rate': 0.001, 'max_rounds': 200, 'features': 49}
#         Has trained 1153 of 220320 combinations so far
# Already Trained and Tested combination (val score of 0.4404):
#             {'max_bins': 4, 'min_samples_leaf': 4, 'interactions': 8, 'max_leaves': 100, 'learning_rate': 0.1, 'max_rounds': 25, 'features': 5}
#             Current best combo (with val score 0.516):
#                     {'max_bins': 1024, 'min_samples_leaf': 32, 'interactions': 2, 'max_leaves': 100, 'learning_rate': 0.001, 'max_rounds': 200, 'features': 49}
#         Has trained 1153 of 220320 combinations so far
# Already Trained and Tested combination (val score of 0.4452):
#             {'max_bins': 4, 'min_samples_leaf': 2, 'interactions': 4, 'max_leaves': 100, 'learning_rate': 0.1, 'max_rounds': 25, 'features': 5}
#             Current best combo (with val score 0.516):
#                     {'max_bins': 1024, 'min_samples_leaf': 32, 'interactions': 2, 'max_leaves': 100, 'learning_rate': 0.001, 'max_rounds': 200, 'features': 49}
#         Has trained 1153 of 220320 combinations so far
# Already Trained and Tested combination (val score of 0.4343):
#             {'max_bins': 4, 'min_samples_leaf': 2, 'interactions': 8, 'max_leaves': 1000, 'learning_rate': 0.1, 'max_rounds': 25, 'features': 5}
#             Current best combo (with val score 0.516):
#                     {'max_bins': 1024, 'min_samples_leaf': 32, 'interactions': 2, 'max_leaves': 100, 'learning_rate': 0.001, 'max_rounds': 200, 'features': 49}
#         Has trained 1153 of 220320 combinations so far
# Trained and Tested combination 1154 of 220320, taking 0.86 seconds to get val score of 0.4508:
#                 {'max_bins': 4, 'min_samples_leaf': 2, 'interactions': 8, 'max_leaves': 100, 'learning_rate': 0.01, 'max_rounds': 25, 'features': 5},
#             Current best combo with val score 0.516:
#                     {'max_bins': 1024, 'min_samples_leaf': 32, 'interactions': 2, 'max_leaves': 100, 'learning_rate': 0.001, 'max_rounds': 200, 'features': 49}
# Already Trained and Tested combination (val score of 0.4136):
#             {'max_bins': 4, 'min_samples_leaf': 2, 'interactions': 8, 'max_leaves': 100, 'learning_rate': 1, 'max_rounds': 25, 'features': 5}
#             Current best combo (with val score 0.516):
#                     {'max_bins': 1024, 'min_samples_leaf': 32, 'interactions': 2, 'max_leaves': 100, 'learning_rate': 0.001, 'max_rounds': 200, 'features': 49}
#         Has trained 1154 of 220320 combinations so far
# Trained and Tested combination 1155 of 220320, taking 1.42 seconds to get val score of 0.4366:
#                 {'max_bins': 4, 'min_samples_leaf': 2, 'interactions': 8, 'max_leaves': 100, 'learning_rate': 0.1, 'max_rounds': 50, 'features': 5},
#             Current best combo with val score 0.516:
#                     {'max_bins': 1024, 'min_samples_leaf': 32, 'interactions': 2, 'max_leaves': 100, 'learning_rate': 0.001, 'max_rounds': 200, 'features': 49}
# Trained and Tested combination 1156 of 220320, taking 0.83 seconds to get val score of 0.0033:
#                 {'max_bins': 4, 'min_samples_leaf': 2, 'interactions': 8, 'max_leaves': 100, 'learning_rate': 0.1, 'max_rounds': 25, 'features': 4},
#             Current best combo with val score 0.516:
#                     {'max_bins': 1024, 'min_samples_leaf': 32, 'interactions': 2, 'max_leaves': 100, 'learning_rate': 0.001, 'max_rounds': 200, 'features': 49}
# Trained and Tested combination 1157 of 220320, taking 1.63 seconds to get val score of 0.4343:
#                 {'max_bins': 4, 'min_samples_leaf': 2, 'interactions': 8, 'max_leaves': 100, 'learning_rate': 0.1, 'max_rounds': 25, 'features': 6},
#             Current best combo with val score 0.516:
#                     {'max_bins': 1024, 'min_samples_leaf': 32, 'interactions': 2, 'max_leaves': 100, 'learning_rate': 0.001, 'max_rounds': 200, 'features': 49}
# Already Trained and Tested combination (val score of 0.4408):
#             {'max_bins': 6, 'min_samples_leaf': 2, 'interactions': 8, 'max_leaves': 100, 'learning_rate': 1, 'max_rounds': 50, 'features': 5}
#             Current best combo (with val score 0.516):
#                     {'max_bins': 1024, 'min_samples_leaf': 32, 'interactions': 2, 'max_leaves': 100, 'learning_rate': 0.001, 'max_rounds': 200, 'features': 49}
#         Has trained 1157 of 220320 combinations so far
# Already Trained and Tested combination (val score of 0.4115):
#             {'max_bins': 4, 'min_samples_leaf': 4, 'interactions': 8, 'max_leaves': 100, 'learning_rate': 1, 'max_rounds': 50, 'features': 5}
#             Current best combo (with val score 0.516):
#                     {'max_bins': 1024, 'min_samples_leaf': 32, 'interactions': 2, 'max_leaves': 100, 'learning_rate': 0.001, 'max_rounds': 200, 'features': 49}
#         Has trained 1157 of 220320 combinations so far
# Already Trained and Tested combination (val score of 0.4132):
#             {'max_bins': 4, 'min_samples_leaf': 2, 'interactions': 4, 'max_leaves': 100, 'learning_rate': 1, 'max_rounds': 50, 'features': 5}
#             Current best combo (with val score 0.516):
#                     {'max_bins': 1024, 'min_samples_leaf': 32, 'interactions': 2, 'max_leaves': 100, 'learning_rate': 0.001, 'max_rounds': 200, 'features': 49}
#         Has trained 1157 of 220320 combinations so far
# Already Trained and Tested combination (val score of 0.4136):
#             {'max_bins': 4, 'min_samples_leaf': 2, 'interactions': 8, 'max_leaves': 1000, 'learning_rate': 1, 'max_rounds': 50, 'features': 5}
#             Current best combo (with val score 0.516):
#                     {'max_bins': 1024, 'min_samples_leaf': 32, 'interactions': 2, 'max_leaves': 100, 'learning_rate': 0.001, 'max_rounds': 200, 'features': 49}
#         Has trained 1157 of 220320 combinations so far
# Already Trained and Tested combination (val score of 0.4366):
#             {'max_bins': 4, 'min_samples_leaf': 2, 'interactions': 8, 'max_leaves': 100, 'learning_rate': 0.1, 'max_rounds': 50, 'features': 5}
#             Current best combo (with val score 0.516):
#                     {'max_bins': 1024, 'min_samples_leaf': 32, 'interactions': 2, 'max_leaves': 100, 'learning_rate': 0.001, 'max_rounds': 200, 'features': 49}
#         Has trained 1157 of 220320 combinations so far
# Already Trained and Tested combination (val score of 0.4136):
#             {'max_bins': 4, 'min_samples_leaf': 2, 'interactions': 8, 'max_leaves': 100, 'learning_rate': 1, 'max_rounds': 25, 'features': 5}
#             Current best combo (with val score 0.516):
#                     {'max_bins': 1024, 'min_samples_leaf': 32, 'interactions': 2, 'max_leaves': 100, 'learning_rate': 0.001, 'max_rounds': 200, 'features': 49}
#         Has trained 1157 of 220320 combinations so far
# Trained and Tested combination 1158 of 220320, taking 2.24 seconds to get val score of 0.4136:
#                 {'max_bins': 4, 'min_samples_leaf': 2, 'interactions': 8, 'max_leaves': 100, 'learning_rate': 1, 'max_rounds': 100, 'features': 5},
#             Current best combo with val score 0.516:
#                     {'max_bins': 1024, 'min_samples_leaf': 32, 'interactions': 2, 'max_leaves': 100, 'learning_rate': 0.001, 'max_rounds': 200, 'features': 49}
# Trained and Tested combination 1159 of 220320, taking 2.05 seconds to get val score of 0.0033:
#                 {'max_bins': 4, 'min_samples_leaf': 2, 'interactions': 8, 'max_leaves': 100, 'learning_rate': 1, 'max_rounds': 50, 'features': 4},
#             Current best combo with val score 0.516:
#                     {'max_bins': 1024, 'min_samples_leaf': 32, 'interactions': 2, 'max_leaves': 100, 'learning_rate': 0.001, 'max_rounds': 200, 'features': 49}
# Trained and Tested combination 1160 of 220320, taking 2.32 seconds to get val score of 0.4178:
#                 {'max_bins': 4, 'min_samples_leaf': 2, 'interactions': 8, 'max_leaves': 100, 'learning_rate': 1, 'max_rounds': 50, 'features': 6},
#             Current best combo with val score 0.516:
#                     {'max_bins': 1024, 'min_samples_leaf': 32, 'interactions': 2, 'max_leaves': 100, 'learning_rate': 0.001, 'max_rounds': 200, 'features': 49}
# Already Trained and Tested combination (val score of 0.4375):
#             {'max_bins': 6, 'min_samples_leaf': 2, 'interactions': 8, 'max_leaves': 100, 'learning_rate': 1, 'max_rounds': 25, 'features': 6}
#             Current best combo (with val score 0.516):
#                     {'max_bins': 1024, 'min_samples_leaf': 32, 'interactions': 2, 'max_leaves': 100, 'learning_rate': 0.001, 'max_rounds': 200, 'features': 49}
#         Has trained 1160 of 220320 combinations so far
# Already Trained and Tested combination (val score of 0.4195):
#             {'max_bins': 4, 'min_samples_leaf': 4, 'interactions': 8, 'max_leaves': 100, 'learning_rate': 1, 'max_rounds': 25, 'features': 6}
#             Current best combo (with val score 0.516):
#                     {'max_bins': 1024, 'min_samples_leaf': 32, 'interactions': 2, 'max_leaves': 100, 'learning_rate': 0.001, 'max_rounds': 200, 'features': 49}
#         Has trained 1160 of 220320 combinations so far
# Already Trained and Tested combination (val score of 0.423):
#             {'max_bins': 4, 'min_samples_leaf': 2, 'interactions': 4, 'max_leaves': 100, 'learning_rate': 1, 'max_rounds': 25, 'features': 6}
#             Current best combo (with val score 0.516):
#                     {'max_bins': 1024, 'min_samples_leaf': 32, 'interactions': 2, 'max_leaves': 100, 'learning_rate': 0.001, 'max_rounds': 200, 'features': 49}
#         Has trained 1160 of 220320 combinations so far
# Already Trained and Tested combination (val score of 0.4181):
#             {'max_bins': 4, 'min_samples_leaf': 2, 'interactions': 8, 'max_leaves': 1000, 'learning_rate': 1, 'max_rounds': 25, 'features': 6}
#             Current best combo (with val score 0.516):
#                     {'max_bins': 1024, 'min_samples_leaf': 32, 'interactions': 2, 'max_leaves': 100, 'learning_rate': 0.001, 'max_rounds': 200, 'features': 49}
#         Has trained 1160 of 220320 combinations so far
# Already Trained and Tested combination (val score of 0.4343):
#             {'max_bins': 4, 'min_samples_leaf': 2, 'interactions': 8, 'max_leaves': 100, 'learning_rate': 0.1, 'max_rounds': 25, 'features': 6}
#             Current best combo (with val score 0.516):
#                     {'max_bins': 1024, 'min_samples_leaf': 32, 'interactions': 2, 'max_leaves': 100, 'learning_rate': 0.001, 'max_rounds': 200, 'features': 49}
#         Has trained 1160 of 220320 combinations so far
# Already Trained and Tested combination (val score of 0.4178):
#             {'max_bins': 4, 'min_samples_leaf': 2, 'interactions': 8, 'max_leaves': 100, 'learning_rate': 1, 'max_rounds': 50, 'features': 6}
#             Current best combo (with val score 0.516):
#                     {'max_bins': 1024, 'min_samples_leaf': 32, 'interactions': 2, 'max_leaves': 100, 'learning_rate': 0.001, 'max_rounds': 200, 'features': 49}
#         Has trained 1160 of 220320 combinations so far
# Already Trained and Tested combination (val score of 0.4136):
#             {'max_bins': 4, 'min_samples_leaf': 2, 'interactions': 8, 'max_leaves': 100, 'learning_rate': 1, 'max_rounds': 25, 'features': 5}
#             Current best combo (with val score 0.516):
#                     {'max_bins': 1024, 'min_samples_leaf': 32, 'interactions': 2, 'max_leaves': 100, 'learning_rate': 0.001, 'max_rounds': 200, 'features': 49}
#         Has trained 1160 of 220320 combinations so far
# Trained and Tested combination 1161 of 220320, taking 0.89 seconds to get val score of 0.4066:
#                 {'max_bins': 4, 'min_samples_leaf': 2, 'interactions': 8, 'max_leaves': 100, 'learning_rate': 1, 'max_rounds': 25, 'features': 7},
#             Current best combo with val score 0.516:
#                     {'max_bins': 1024, 'min_samples_leaf': 32, 'interactions': 2, 'max_leaves': 100, 'learning_rate': 0.001, 'max_rounds': 200, 'features': 49}
# % Combos Checked Thus Far: 1161 out of 220320 which is 0.526961%
# Cruising Coordrdinate 82 of 704
#
# Cruise suspended due to suspicious case
# Guidance: round 14
#
# 	round 14 iteration:  0
#
# Trained and Tested combination 1162 of 220320, taking 0.79 seconds to get val score of 0.436:
#                 {'max_bins': 6, 'min_samples_leaf': 2, 'interactions': 2, 'max_leaves': 100, 'learning_rate': 1, 'max_rounds': 25, 'features': 5},
#             Current best combo with val score 0.516:
#                     {'max_bins': 1024, 'min_samples_leaf': 32, 'interactions': 2, 'max_leaves': 100, 'learning_rate': 0.001, 'max_rounds': 200, 'features': 49}
# Trained and Tested combination 1163 of 220320, taking 1.3 seconds to get val score of 0.4219:
#                 {'max_bins': 4, 'min_samples_leaf': 4, 'interactions': 2, 'max_leaves': 100, 'learning_rate': 1, 'max_rounds': 25, 'features': 5},
#             Current best combo with val score 0.516:
#                     {'max_bins': 1024, 'min_samples_leaf': 32, 'interactions': 2, 'max_leaves': 100, 'learning_rate': 0.001, 'max_rounds': 200, 'features': 49}
# Already Trained and Tested combination (val score of 0.4109):
#             {'max_bins': 4, 'min_samples_leaf': 2, 'interactions': 4, 'max_leaves': 100, 'learning_rate': 1, 'max_rounds': 25, 'features': 5}
#             Current best combo (with val score 0.516):
#                     {'max_bins': 1024, 'min_samples_leaf': 32, 'interactions': 2, 'max_leaves': 100, 'learning_rate': 0.001, 'max_rounds': 200, 'features': 49}
#         Has trained 1163 of 220320 combinations so far
# Already Trained and Tested combination (val score of 0.4179):
#             {'max_bins': 4, 'min_samples_leaf': 2, 'interactions': 2, 'max_leaves': 1000, 'learning_rate': 1, 'max_rounds': 25, 'features': 5}
#             Current best combo (with val score 0.516):
#                     {'max_bins': 1024, 'min_samples_leaf': 32, 'interactions': 2, 'max_leaves': 100, 'learning_rate': 0.001, 'max_rounds': 200, 'features': 49}
#         Has trained 1163 of 220320 combinations so far
# Trained and Tested combination 1164 of 220320, taking 0.79 seconds to get val score of 0.445:
#                 {'max_bins': 4, 'min_samples_leaf': 2, 'interactions': 2, 'max_leaves': 100, 'learning_rate': 0.1, 'max_rounds': 25, 'features': 5},
#             Current best combo with val score 0.516:
#                     {'max_bins': 1024, 'min_samples_leaf': 32, 'interactions': 2, 'max_leaves': 100, 'learning_rate': 0.001, 'max_rounds': 200, 'features': 49}
# Trained and Tested combination 1165 of 220320, taking 1.2 seconds to get val score of 0.418:
#                 {'max_bins': 4, 'min_samples_leaf': 2, 'interactions': 2, 'max_leaves': 100, 'learning_rate': 1, 'max_rounds': 50, 'features': 5},
#             Current best combo with val score 0.516:
#                     {'max_bins': 1024, 'min_samples_leaf': 32, 'interactions': 2, 'max_leaves': 100, 'learning_rate': 0.001, 'max_rounds': 200, 'features': 49}
# Trained and Tested combination 1166 of 220320, taking 0.76 seconds to get val score of 0.0033:
#                 {'max_bins': 4, 'min_samples_leaf': 2, 'interactions': 2, 'max_leaves': 100, 'learning_rate': 1, 'max_rounds': 25, 'features': 4},
#             Current best combo with val score 0.516:
#                     {'max_bins': 1024, 'min_samples_leaf': 32, 'interactions': 2, 'max_leaves': 100, 'learning_rate': 0.001, 'max_rounds': 200, 'features': 49}
# Trained and Tested combination 1167 of 220320, taking 1.17 seconds to get val score of 0.4135:
#                 {'max_bins': 4, 'min_samples_leaf': 2, 'interactions': 2, 'max_leaves': 100, 'learning_rate': 1, 'max_rounds': 25, 'features': 6},
#             Current best combo with val score 0.516:
#                     {'max_bins': 1024, 'min_samples_leaf': 32, 'interactions': 2, 'max_leaves': 100, 'learning_rate': 0.001, 'max_rounds': 200, 'features': 49}
# 	round 14 iteration:  1
#
# Already Trained and Tested combination (val score of 0.4179):
#             {'max_bins': 4, 'min_samples_leaf': 2, 'interactions': 2, 'max_leaves': 100, 'learning_rate': 1, 'max_rounds': 25, 'features': 5}
#             Current best combo (with val score 0.516):
#                     {'max_bins': 1024, 'min_samples_leaf': 32, 'interactions': 2, 'max_leaves': 100, 'learning_rate': 0.001, 'max_rounds': 200, 'features': 49}
#         Has trained 1167 of 220320 combinations so far
# Trained and Tested combination 1168 of 220320, taking 0.78 seconds to get val score of 0.4407:
#                 {'max_bins': 64, 'min_samples_leaf': 2, 'interactions': 2, 'max_leaves': 100, 'learning_rate': 1, 'max_rounds': 25, 'features': 5},
#             Current best combo with val score 0.516:
#                     {'max_bins': 1024, 'min_samples_leaf': 32, 'interactions': 2, 'max_leaves': 100, 'learning_rate': 0.001, 'max_rounds': 200, 'features': 49}
# Trained and Tested combination 1169 of 220320, taking 0.81 seconds to get val score of 0.4315:
#                 {'max_bins': 6, 'min_samples_leaf': 4, 'interactions': 2, 'max_leaves': 100, 'learning_rate': 1, 'max_rounds': 25, 'features': 5},
#             Current best combo with val score 0.516:
#                     {'max_bins': 1024, 'min_samples_leaf': 32, 'interactions': 2, 'max_leaves': 100, 'learning_rate': 0.001, 'max_rounds': 200, 'features': 49}
# Already Trained and Tested combination (val score of 0.4406):
#             {'max_bins': 6, 'min_samples_leaf': 2, 'interactions': 4, 'max_leaves': 100, 'learning_rate': 1, 'max_rounds': 25, 'features': 5}
#             Current best combo (with val score 0.516):
#                     {'max_bins': 1024, 'min_samples_leaf': 32, 'interactions': 2, 'max_leaves': 100, 'learning_rate': 0.001, 'max_rounds': 200, 'features': 49}
#         Has trained 1169 of 220320 combinations so far
# Already Trained and Tested combination (val score of 0.436):
#             {'max_bins': 6, 'min_samples_leaf': 2, 'interactions': 2, 'max_leaves': 1000, 'learning_rate': 1, 'max_rounds': 25, 'features': 5}
#             Current best combo (with val score 0.516):
#                     {'max_bins': 1024, 'min_samples_leaf': 32, 'interactions': 2, 'max_leaves': 100, 'learning_rate': 0.001, 'max_rounds': 200, 'features': 49}
#         Has trained 1169 of 220320 combinations so far
# Trained and Tested combination 1170 of 220320, taking 0.79 seconds to get val score of 0.4434:
#                 {'max_bins': 6, 'min_samples_leaf': 2, 'interactions': 2, 'max_leaves': 100, 'learning_rate': 0.1, 'max_rounds': 25, 'features': 5},
#             Current best combo with val score 0.516:
#                     {'max_bins': 1024, 'min_samples_leaf': 32, 'interactions': 2, 'max_leaves': 100, 'learning_rate': 0.001, 'max_rounds': 200, 'features': 49}
# Trained and Tested combination 1171 of 220320, taking 1.19 seconds to get val score of 0.436:
#                 {'max_bins': 6, 'min_samples_leaf': 2, 'interactions': 2, 'max_leaves': 100, 'learning_rate': 1, 'max_rounds': 50, 'features': 5},
#             Current best combo with val score 0.516:
#                     {'max_bins': 1024, 'min_samples_leaf': 32, 'interactions': 2, 'max_leaves': 100, 'learning_rate': 0.001, 'max_rounds': 200, 'features': 49}
# Trained and Tested combination 1172 of 220320, taking 0.76 seconds to get val score of 0.0:
#                 {'max_bins': 6, 'min_samples_leaf': 2, 'interactions': 2, 'max_leaves': 100, 'learning_rate': 1, 'max_rounds': 25, 'features': 4},
#             Current best combo with val score 0.516:
#                     {'max_bins': 1024, 'min_samples_leaf': 32, 'interactions': 2, 'max_leaves': 100, 'learning_rate': 0.001, 'max_rounds': 200, 'features': 49}
# Trained and Tested combination 1173 of 220320, taking 1.34 seconds to get val score of 0.4341:
#                 {'max_bins': 6, 'min_samples_leaf': 2, 'interactions': 2, 'max_leaves': 100, 'learning_rate': 1, 'max_rounds': 25, 'features': 6},
#             Current best combo with val score 0.516:
#                     {'max_bins': 1024, 'min_samples_leaf': 32, 'interactions': 2, 'max_leaves': 100, 'learning_rate': 0.001, 'max_rounds': 200, 'features': 49}
# Already Trained and Tested combination (val score of 0.4315):
#             {'max_bins': 6, 'min_samples_leaf': 4, 'interactions': 2, 'max_leaves': 100, 'learning_rate': 1, 'max_rounds': 25, 'features': 5}
#             Current best combo (with val score 0.516):
#                     {'max_bins': 1024, 'min_samples_leaf': 32, 'interactions': 2, 'max_leaves': 100, 'learning_rate': 0.001, 'max_rounds': 200, 'features': 49}
#         Has trained 1173 of 220320 combinations so far
# Already Trained and Tested combination (val score of 0.4179):
#             {'max_bins': 4, 'min_samples_leaf': 2, 'interactions': 2, 'max_leaves': 100, 'learning_rate': 1, 'max_rounds': 25, 'features': 5}
#             Current best combo (with val score 0.516):
#                     {'max_bins': 1024, 'min_samples_leaf': 32, 'interactions': 2, 'max_leaves': 100, 'learning_rate': 0.001, 'max_rounds': 200, 'features': 49}
#         Has trained 1173 of 220320 combinations so far
# Trained and Tested combination 1174 of 220320, taking 0.79 seconds to get val score of 0.4203:
#                 {'max_bins': 4, 'min_samples_leaf': 8, 'interactions': 2, 'max_leaves': 100, 'learning_rate': 1, 'max_rounds': 25, 'features': 5},
#             Current best combo with val score 0.516:
#                     {'max_bins': 1024, 'min_samples_leaf': 32, 'interactions': 2, 'max_leaves': 100, 'learning_rate': 0.001, 'max_rounds': 200, 'features': 49}
# Already Trained and Tested combination (val score of 0.4184):
#             {'max_bins': 4, 'min_samples_leaf': 4, 'interactions': 4, 'max_leaves': 100, 'learning_rate': 1, 'max_rounds': 25, 'features': 5}
#             Current best combo (with val score 0.516):
#                     {'max_bins': 1024, 'min_samples_leaf': 32, 'interactions': 2, 'max_leaves': 100, 'learning_rate': 0.001, 'max_rounds': 200, 'features': 49}
#         Has trained 1174 of 220320 combinations so far
# Already Trained and Tested combination (val score of 0.4219):
#             {'max_bins': 4, 'min_samples_leaf': 4, 'interactions': 2, 'max_leaves': 1000, 'learning_rate': 1, 'max_rounds': 25, 'features': 5}
#             Current best combo (with val score 0.516):
#                     {'max_bins': 1024, 'min_samples_leaf': 32, 'interactions': 2, 'max_leaves': 100, 'learning_rate': 0.001, 'max_rounds': 200, 'features': 49}
#         Has trained 1174 of 220320 combinations so far
# Trained and Tested combination 1175 of 220320, taking 0.79 seconds to get val score of 0.4463:
#                 {'max_bins': 4, 'min_samples_leaf': 4, 'interactions': 2, 'max_leaves': 100, 'learning_rate': 0.1, 'max_rounds': 25, 'features': 5},
#             Current best combo with val score 0.516:
#                     {'max_bins': 1024, 'min_samples_leaf': 32, 'interactions': 2, 'max_leaves': 100, 'learning_rate': 0.001, 'max_rounds': 200, 'features': 49}
# Trained and Tested combination 1176 of 220320, taking 1.19 seconds to get val score of 0.425:
# ...
#             Current best combo with val score 0.516:
#                     {'max_bins': 1024, 'min_samples_leaf': 32, 'interactions': 2, 'max_leaves': 100, 'learning_rate': 0.001, 'max_rounds': 200, 'features': 49}
# Trained and Tested combination 1744 of 220320, taking 1.77 seconds to get val score of 0.4351:
#                 {'max_bins': 6, 'min_samples_leaf': 32, 'interactions': 8, 'max_leaves': 100, 'learning_rate': 1, 'max_rounds': 200, 'features': 6},
#             Current best combo with val score 0.516:
#                     {'max_bins': 1024, 'min_samples_leaf': 32, 'interactions': 2, 'max_leaves': 100, 'learning_rate': 0.001, 'max_rounds': 200, 'features': 49}
# Already Trained and Tested combination (val score of 0.4446):
#             {'max_bins': 6, 'min_samples_leaf': 32, 'interactions': 4, 'max_leaves': 100, 'learning_rate': 1, 'max_rounds': 200, 'features': 5}
#             Current best combo (with val score 0.516):
#                     {'max_bins': 1024, 'min_samples_leaf': 32, 'interactions': 2, 'max_leaves': 100, 'learning_rate': 0.001, 'max_rounds': 200, 'features': 49}
#         Has trained 1744 of 220320 combinations so far
# Trained and Tested combination 1745 of 220320, taking 1.29 seconds to get val score of 0.4184:
#                 {'max_bins': 4, 'min_samples_leaf': 16, 'interactions': 4, 'max_leaves': 100, 'learning_rate': 1, 'max_rounds': 200, 'features': 5},
#             Current best combo with val score 0.516:
#                     {'max_bins': 1024, 'min_samples_leaf': 32, 'interactions': 2, 'max_leaves': 100, 'learning_rate': 0.001, 'max_rounds': 200, 'features': 49}
# Already Trained and Tested combination (val score of 0.4431):
#             {'max_bins': 4, 'min_samples_leaf': 32, 'interactions': 2, 'max_leaves': 100, 'learning_rate': 1, 'max_rounds': 200, 'features': 5}
#             Current best combo (with val score 0.516):
#                     {'max_bins': 1024, 'min_samples_leaf': 32, 'interactions': 2, 'max_leaves': 100, 'learning_rate': 0.001, 'max_rounds': 200, 'features': 49}
#         Has trained 1745 of 220320 combinations so far
# Already Trained and Tested combination (val score of 0.4417):
#             {'max_bins': 4, 'min_samples_leaf': 32, 'interactions': 8, 'max_leaves': 100, 'learning_rate': 1, 'max_rounds': 200, 'features': 5}
#             Current best combo (with val score 0.516):
#                     {'max_bins': 1024, 'min_samples_leaf': 32, 'interactions': 2, 'max_leaves': 100, 'learning_rate': 0.001, 'max_rounds': 200, 'features': 49}
#         Has trained 1745 of 220320 combinations so far
# Already Trained and Tested combination (val score of 0.4436):
#             {'max_bins': 4, 'min_samples_leaf': 32, 'interactions': 4, 'max_leaves': 1000, 'learning_rate': 1, 'max_rounds': 200, 'features': 5}
#             Current best combo (with val score 0.516):
#                     {'max_bins': 1024, 'min_samples_leaf': 32, 'interactions': 2, 'max_leaves': 100, 'learning_rate': 0.001, 'max_rounds': 200, 'features': 49}
#         Has trained 1745 of 220320 combinations so far
# Trained and Tested combination 1746 of 220320, taking 2.03 seconds to get val score of 0.449:
#                 {'max_bins': 4, 'min_samples_leaf': 32, 'interactions': 4, 'max_leaves': 100, 'learning_rate': 0.1, 'max_rounds': 200, 'features': 5},
#             Current best combo with val score 0.516:
#                     {'max_bins': 1024, 'min_samples_leaf': 32, 'interactions': 2, 'max_leaves': 100, 'learning_rate': 0.001, 'max_rounds': 200, 'features': 49}
# Trained and Tested combination 1747 of 220320, taking 1.29 seconds to get val score of 0.4436:
#                 {'max_bins': 4, 'min_samples_leaf': 32, 'interactions': 4, 'max_leaves': 100, 'learning_rate': 1, 'max_rounds': 100, 'features': 5},
#             Current best combo with val score 0.516:
#                     {'max_bins': 1024, 'min_samples_leaf': 32, 'interactions': 2, 'max_leaves': 100, 'learning_rate': 0.001, 'max_rounds': 200, 'features': 49}
# Trained and Tested combination 1748 of 220320, taking 1.24 seconds to get val score of 0.0033:
#                 {'max_bins': 4, 'min_samples_leaf': 32, 'interactions': 4, 'max_leaves': 100, 'learning_rate': 1, 'max_rounds': 200, 'features': 4},
#             Current best combo with val score 0.516:
#                     {'max_bins': 1024, 'min_samples_leaf': 32, 'interactions': 2, 'max_leaves': 100, 'learning_rate': 0.001, 'max_rounds': 200, 'features': 49}
# Trained and Tested combination 1749 of 220320, taking 1.32 seconds to get val score of 0.4439:
#                 {'max_bins': 4, 'min_samples_leaf': 32, 'interactions': 4, 'max_leaves': 100, 'learning_rate': 1, 'max_rounds': 200, 'features': 6},
#             Current best combo with val score 0.516:
#                     {'max_bins': 1024, 'min_samples_leaf': 32, 'interactions': 2, 'max_leaves': 100, 'learning_rate': 0.001, 'max_rounds': 200, 'features': 49}
# Already Trained and Tested combination (val score of 0.4489):
#             {'max_bins': 6, 'min_samples_leaf': 32, 'interactions': 8, 'max_leaves': 100, 'learning_rate': 0.1, 'max_rounds': 200, 'features': 5}
#             Current best combo (with val score 0.516):
#                     {'max_bins': 1024, 'min_samples_leaf': 32, 'interactions': 2, 'max_leaves': 100, 'learning_rate': 0.001, 'max_rounds': 200, 'features': 49}
#         Has trained 1749 of 220320 combinations so far
# Trained and Tested combination 1750 of 220320, taking 2.12 seconds to get val score of 0.4455:
#                 {'max_bins': 4, 'min_samples_leaf': 16, 'interactions': 8, 'max_leaves': 100, 'learning_rate': 0.1, 'max_rounds': 200, 'features': 5},
#             Current best combo with val score 0.516:
#                     {'max_bins': 1024, 'min_samples_leaf': 32, 'interactions': 2, 'max_leaves': 100, 'learning_rate': 0.001, 'max_rounds': 200, 'features': 49}
# Already Trained and Tested combination (val score of 0.449):
#             {'max_bins': 4, 'min_samples_leaf': 32, 'interactions': 4, 'max_leaves': 100, 'learning_rate': 0.1, 'max_rounds': 200, 'features': 5}
#             Current best combo (with val score 0.516):
#                     {'max_bins': 1024, 'min_samples_leaf': 32, 'interactions': 2, 'max_leaves': 100, 'learning_rate': 0.001, 'max_rounds': 200, 'features': 49}
#         Has trained 1750 of 220320 combinations so far
# Already Trained and Tested combination (val score of 0.4452):
#             {'max_bins': 4, 'min_samples_leaf': 32, 'interactions': 8, 'max_leaves': 1000, 'learning_rate': 0.1, 'max_rounds': 200, 'features': 5}
#             Current best combo (with val score 0.516):
#                     {'max_bins': 1024, 'min_samples_leaf': 32, 'interactions': 2, 'max_leaves': 100, 'learning_rate': 0.001, 'max_rounds': 200, 'features': 49}
#         Has trained 1750 of 220320 combinations so far
# Trained and Tested combination 1751 of 220320, taking 4.76 seconds to get val score of 0.4391:
#                 {'max_bins': 4, 'min_samples_leaf': 32, 'interactions': 8, 'max_leaves': 100, 'learning_rate': 0.01, 'max_rounds': 200, 'features': 5},
#             Current best combo with val score 0.516:
#                     {'max_bins': 1024, 'min_samples_leaf': 32, 'interactions': 2, 'max_leaves': 100, 'learning_rate': 0.001, 'max_rounds': 200, 'features': 49}
# Already Trained and Tested combination (val score of 0.4417):
#             {'max_bins': 4, 'min_samples_leaf': 32, 'interactions': 8, 'max_leaves': 100, 'learning_rate': 1, 'max_rounds': 200, 'features': 5}
#             Current best combo (with val score 0.516):
#                     {'max_bins': 1024, 'min_samples_leaf': 32, 'interactions': 2, 'max_leaves': 100, 'learning_rate': 0.001, 'max_rounds': 200, 'features': 49}
#         Has trained 1751 of 220320 combinations so far
# Trained and Tested combination 1752 of 220320, taking 1.98 seconds to get val score of 0.4452:
#                 {'max_bins': 4, 'min_samples_leaf': 32, 'interactions': 8, 'max_leaves': 100, 'learning_rate': 0.1, 'max_rounds': 100, 'features': 5},
#             Current best combo with val score 0.516:
#                     {'max_bins': 1024, 'min_samples_leaf': 32, 'interactions': 2, 'max_leaves': 100, 'learning_rate': 0.001, 'max_rounds': 200, 'features': 49}
# Trained and Tested combination 1753 of 220320, taking 1.6 seconds to get val score of 0.0033:
#                 {'max_bins': 4, 'min_samples_leaf': 32, 'interactions': 8, 'max_leaves': 100, 'learning_rate': 0.1, 'max_rounds': 200, 'features': 4},
#             Current best combo with val score 0.516:
#                     {'max_bins': 1024, 'min_samples_leaf': 32, 'interactions': 2, 'max_leaves': 100, 'learning_rate': 0.001, 'max_rounds': 200, 'features': 49}
# Trained and Tested combination 1754 of 220320, taking 2.2 seconds to get val score of 0.4454:
#                 {'max_bins': 4, 'min_samples_leaf': 32, 'interactions': 8, 'max_leaves': 100, 'learning_rate': 0.1, 'max_rounds': 200, 'features': 6},
#             Current best combo with val score 0.516:
#                     {'max_bins': 1024, 'min_samples_leaf': 32, 'interactions': 2, 'max_leaves': 100, 'learning_rate': 0.001, 'max_rounds': 200, 'features': 49}
# Already Trained and Tested combination (val score of 0.4351):
#             {'max_bins': 6, 'min_samples_leaf': 32, 'interactions': 8, 'max_leaves': 100, 'learning_rate': 1, 'max_rounds': 200, 'features': 6}
#             Current best combo (with val score 0.516):
#                     {'max_bins': 1024, 'min_samples_leaf': 32, 'interactions': 2, 'max_leaves': 100, 'learning_rate': 0.001, 'max_rounds': 200, 'features': 49}
#         Has trained 1754 of 220320 combinations so far
# Trained and Tested combination 1755 of 220320, taking 2.38 seconds to get val score of 0.4199:
#                 {'max_bins': 4, 'min_samples_leaf': 16, 'interactions': 8, 'max_leaves': 100, 'learning_rate': 1, 'max_rounds': 200, 'features': 6},
#             Current best combo with val score 0.516:
#                     {'max_bins': 1024, 'min_samples_leaf': 32, 'interactions': 2, 'max_leaves': 100, 'learning_rate': 0.001, 'max_rounds': 200, 'features': 49}
# Already Trained and Tested combination (val score of 0.4439):
#             {'max_bins': 4, 'min_samples_leaf': 32, 'interactions': 4, 'max_leaves': 100, 'learning_rate': 1, 'max_rounds': 200, 'features': 6}
#             Current best combo (with val score 0.516):
#                     {'max_bins': 1024, 'min_samples_leaf': 32, 'interactions': 2, 'max_leaves': 100, 'learning_rate': 0.001, 'max_rounds': 200, 'features': 49}
#         Has trained 1755 of 220320 combinations so far
# Already Trained and Tested combination (val score of 0.4382):
#             {'max_bins': 4, 'min_samples_leaf': 32, 'interactions': 8, 'max_leaves': 1000, 'learning_rate': 1, 'max_rounds': 200, 'features': 6}
#             Current best combo (with val score 0.516):
#                     {'max_bins': 1024, 'min_samples_leaf': 32, 'interactions': 2, 'max_leaves': 100, 'learning_rate': 0.001, 'max_rounds': 200, 'features': 49}
#         Has trained 1755 of 220320 combinations so far
# Already Trained and Tested combination (val score of 0.4454):
#             {'max_bins': 4, 'min_samples_leaf': 32, 'interactions': 8, 'max_leaves': 100, 'learning_rate': 0.1, 'max_rounds': 200, 'features': 6}
#             Current best combo (with val score 0.516):
#                     {'max_bins': 1024, 'min_samples_leaf': 32, 'interactions': 2, 'max_leaves': 100, 'learning_rate': 0.001, 'max_rounds': 200, 'features': 49}
#         Has trained 1755 of 220320 combinations so far
# Trained and Tested combination 1756 of 220320, taking 2.14 seconds to get val score of 0.4382:
#                 {'max_bins': 4, 'min_samples_leaf': 32, 'interactions': 8, 'max_leaves': 100, 'learning_rate': 1, 'max_rounds': 100, 'features': 6},
#             Current best combo with val score 0.516:
#                     {'max_bins': 1024, 'min_samples_leaf': 32, 'interactions': 2, 'max_leaves': 100, 'learning_rate': 0.001, 'max_rounds': 200, 'features': 49}
# Already Trained and Tested combination (val score of 0.4417):
#             {'max_bins': 4, 'min_samples_leaf': 32, 'interactions': 8, 'max_leaves': 100, 'learning_rate': 1, 'max_rounds': 200, 'features': 5}
#             Current best combo (with val score 0.516):
#                     {'max_bins': 1024, 'min_samples_leaf': 32, 'interactions': 2, 'max_leaves': 100, 'learning_rate': 0.001, 'max_rounds': 200, 'features': 49}
#         Has trained 1756 of 220320 combinations so far
# Trained and Tested combination 1757 of 220320, taking 1.42 seconds to get val score of 0.439:
#                 {'max_bins': 4, 'min_samples_leaf': 32, 'interactions': 8, 'max_leaves': 100, 'learning_rate': 1, 'max_rounds': 200, 'features': 7},
#             Current best combo with val score 0.516:
#                     {'max_bins': 1024, 'min_samples_leaf': 32, 'interactions': 2, 'max_leaves': 100, 'learning_rate': 0.001, 'max_rounds': 200, 'features': 49}
# % Combos Checked Thus Far: 1757 out of 220320 which is 0.797476%
# Cruising Coordrdinate 115 of 704
#
# Cruise suspended due to suspicious case
# Guidance: round 35
#
# 	round 35 iteration:  0
#
# Trained and Tested combination 1758 of 220320, taking 1.52 seconds to get val score of 0.4356:
#                 {'max_bins': 1024, 'min_samples_leaf': 32, 'interactions': 8, 'max_leaves': 10000, 'learning_rate': 1, 'max_rounds': 25, 'features': 5},
#             Current best combo with val score 0.516:
#                     {'max_bins': 1024, 'min_samples_leaf': 32, 'interactions': 2, 'max_leaves': 100, 'learning_rate': 0.001, 'max_rounds': 200, 'features': 49}
# Trained and Tested combination 1759 of 220320, taking 0.95 seconds to get val score of 0.4403:
#                 {'max_bins': 4096, 'min_samples_leaf': 16, 'interactions': 8, 'max_leaves': 10000, 'learning_rate': 1, 'max_rounds': 25, 'features': 5},
#             Current best combo with val score 0.516:
#                     {'max_bins': 1024, 'min_samples_leaf': 32, 'interactions': 2, 'max_leaves': 100, 'learning_rate': 0.001, 'max_rounds': 200, 'features': 49}
# Trained and Tested combination 1760 of 220320, taking 0.89 seconds to get val score of 0.443:
#                 {'max_bins': 4096, 'min_samples_leaf': 32, 'interactions': 4, 'max_leaves': 10000, 'learning_rate': 1, 'max_rounds': 25, 'features': 5},
#             Current best combo with val score 0.516:
#                     {'max_bins': 1024, 'min_samples_leaf': 32, 'interactions': 2, 'max_leaves': 100, 'learning_rate': 0.001, 'max_rounds': 200, 'features': 49}
# Trained and Tested combination 1761 of 220320, taking 0.93 seconds to get val score of 0.4364:
#                 {'max_bins': 4096, 'min_samples_leaf': 32, 'interactions': 8, 'max_leaves': 1000, 'learning_rate': 1, 'max_rounds': 25, 'features': 5},
#             Current best combo with val score 0.516:
#                     {'max_bins': 1024, 'min_samples_leaf': 32, 'interactions': 2, 'max_leaves': 100, 'learning_rate': 0.001, 'max_rounds': 200, 'features': 49}
# Trained and Tested combination 1762 of 220320, taking 1.61 seconds to get val score of 0.4247:
#                 {'max_bins': 4096, 'min_samples_leaf': 32, 'interactions': 8, 'max_leaves': 10000, 'learning_rate': 0.1, 'max_rounds': 25, 'features': 5},
#             Current best combo with val score 0.516:
#                     {'max_bins': 1024, 'min_samples_leaf': 32, 'interactions': 2, 'max_leaves': 100, 'learning_rate': 0.001, 'max_rounds': 200, 'features': 49}
# Trained and Tested combination 1763 of 220320, taking 1.52 seconds to get val score of 0.4364:
#                 {'max_bins': 4096, 'min_samples_leaf': 32, 'interactions': 8, 'max_leaves': 10000, 'learning_rate': 1, 'max_rounds': 50, 'features': 5},
#             Current best combo with val score 0.516:
#                     {'max_bins': 1024, 'min_samples_leaf': 32, 'interactions': 2, 'max_leaves': 100, 'learning_rate': 0.001, 'max_rounds': 200, 'features': 49}
