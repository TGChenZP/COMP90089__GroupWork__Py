# %% [markdown]
# # Tuning Script

# %%
# Parameters subject to change in every script - involved in naming

MODEL = 'xgbc'
PREPROCESSING = 'normalise'
TUNER = 'yangzhoub'
OPTIMISED_METRIC = 'f1'

# %% [markdown]
# ---

# %%
# detect whether this is a google environment

COLAB_ENVIRONMENT = False

try:
    from google.colab import drive
    drive.mount('/content/drive')
    COLAB_ENVIRONMENT = True
except:
    pass
# Out:
# Mounted at /content/drive

# %%
import sys
import os
import pickle

if COLAB_ENVIRONMENT:
    home_directory = './drive/MyDrive/LAB/COMP90089__GroupWork__Py/' # my home directory is stored in ./LAB of google drive
    if MODEL == 'ebr':
        # !pip install interpret==0.5.0
    elif MODEL == 'cbr':
        # !pip install catboost
    elif MODEL in ['tf', 'mlp']:
        # !pip install PyTorch2Sklearn
    # !pip install JXAutoML
else:
    home_directory = '../../'

from JXAutoML.YangZhouB_10CV import YangZhouB_10CV as Tuner

import pandas as pd
# Out:
# Collecting JXAutoML
#   Downloading JXAutoML-0.4.4-py3-none-any.whl.metadata (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.2/67.2 kB 4.6 MB/s eta 0:00:00
# Downloading JXAutoML-0.4.4-py3-none-any.whl (52 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.1/52.1 kB 4.4 MB/s eta 0:00:00
# Installing collected packages: JXAutoML
# Successfully installed JXAutoML-0.4.4

# %%
# Parameters that are same for every script

FOLDS = 10  # we have decided to do 10 fold validation

SEED = 42

TASK_TYPE = 'Classification'  # this task is a classification task

# we have decided to tune features as hp
TUNE_FEATURES_AS_HYPERPARAMETERS = True

# %% [markdown]
# ---

# %%
# model to use to tune
from xgboost import XGBClassifier as clf

# what values to try for each hyperparameter
parameter_choices = {
        'n_estimators': (25, 50, 100, 200, 400, 800),
        'max_depth': (3, 6, 12, 24, 48, 96, 192),
        'subsample': (0.4, 0.55, 0.7, 0.85, 1),
        'colsample_bytree': (0.4, 0.55, 0.7, 0.85, 1),
        'gamma': (0.00000001, 0.000001, 0.0001, 0.01, 0.1),
        'eta': (0.0001, 0.001, 0.01, 0.1, 1, 10)
}

# what values to set non-tuneable parameters/hyperparameters
non_tunable_hyperparameters_dict = {
                                    'random_state': SEED,
                                    'n_jobs': -1
                                    }

# %% [markdown]
# ---

# %% [markdown]
# Read in and Prepare Data

# %%
# Import data and store as lists

train_x_list = []
train_y_list = []
val_x_list = []
val_y_list = []

for i in range(FOLDS):
    train_data = pd.read_csv(
        f'{home_directory}data/curated/modelling/{PREPROCESSING}/train_{i}.csv')
    val_data = pd.read_csv(
        f'{home_directory}data/curated/modelling/{PREPROCESSING}/val_{i}.csv')

    # get the correct rows for X and y
    train_x = train_data.drop(
        ['mortality_status', 'subject_id', 'hadm_id', 'stay_id'], axis=1)
    train_y = train_data['mortality_status']
    val_x = val_data.drop(
        ['mortality_status', 'subject_id', 'hadm_id', 'stay_id'], axis=1)
    val_y = val_data['mortality_status']

    train_x_list.append(train_x)
    train_y_list.append(train_y)
    val_x_list.append(val_x)
    val_y_list.append(val_y)

# %%
# Import feature importance ordering

with open(f'{home_directory}models/xgb_feature_importance_ordering_{PREPROCESSING}.pickle', 'rb') as f:
    feature_importance_ordering = pickle.load(f)

# %% [markdown]
# Set parameters

# %%
# initialisation
tuner = Tuner()

print('---')

# define what model we are tuning
tuner.read_in_model(clf, TASK_TYPE, optimised_metric=OPTIMISED_METRIC)

print('---')

# read in the data for training and validation
tuner.read_in_data(train_x_list, train_y_list, val_x_list, val_y_list)

print('---')

# set what hp values to tune
tuner.set_hyperparameters(parameter_choices)
# WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

# set up hp values that need to be changed from default but NOT to be tuned
tuner.set_non_tuneable_hyperparameters(non_tunable_hyperparameters_dict)

print('---')

# set up feature importance ordering

if TUNE_FEATURES_AS_HYPERPARAMETERS:
    tuner.set_features(feature_importance_ordering)
    # WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

try:  # try to read in previous results to continue tuning ...
    tuner.read_in_tuning_result_df(
        f'{home_directory}models/tuning/{TUNER}_{MODEL}_{PREPROCESSING}.csv')
except:
    print('No previous tuning data read in')

print('---')

# set up where to save the tuning result csv
tuner.set_tuning_result_saving_address(
    f'{home_directory}models/tuning/{TUNER}_{MODEL}_{PREPROCESSING}.csv')

print('---')

# set up where to save the current best model
tuner.set_best_model_saving_address(
    f'{home_directory}models/tmp_models/{TUNER}_{MODEL}_{PREPROCESSING}')
# Out:
# YangZhouB Initialised
# ---
# Successfully read in model <class 'xgboost.sklearn.XGBClassifier'>, which is a Classification model optimising for f1
# ---
# Read in Train X data list
# Read in Train y data list
# Read in Val X data list
# Read in Val y data list
# ---
# Successfully recorded hyperparameter choices
# ---
# Successfully recorded non_tuneable_hyperparameter choices
# ---
# Successfully recorded tuneable feature combination choices and updated relevant internal structures
# ---
# Successfully read in tuning result of 1056 rows, for 1056.0 combos
# ---
# Successfully set tuning output address
# ---
# Successfully set best model output address

# %%
# ignore warnings

import warnings
warnings.filterwarnings("ignore")

# %%
# begin tuning ... (or continue training)

tuner.tune()
# Out:
# Streaming output truncated to the last 5000 lines.
#                 {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.7, 'gamma': 0.0001, 'eta': 1, 'features': 26},
#             Current best combo with val score 0.2583:
#                     {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.85, 'gamma': 0.0001, 'eta': 1, 'features': 25}
# Trained and Tested combination 1143 of 1606500, taking 0.2 seconds to get val score of 0.2387:
#                 {'n_estimators': 100, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.85, 'gamma': 0.0001, 'eta': 1, 'features': 25},
#             Current best combo with val score 0.2583:
#                     {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.85, 'gamma': 0.0001, 'eta': 1, 'features': 25}
# Trained and Tested combination 1144 of 1606500, taking 1.08 seconds to get val score of 0.2488:
#                 {'n_estimators': 400, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.85, 'gamma': 0.0001, 'eta': 1, 'features': 25},
#             Current best combo with val score 0.2583:
#                     {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.85, 'gamma': 0.0001, 'eta': 1, 'features': 25}
# Trained and Tested combination 1145 of 1606500, taking 0.32 seconds to get val score of 0.1156:
#                 {'n_estimators': 200, 'max_depth': 12, 'subsample': 0.7, 'colsample_bytree': 0.85, 'gamma': 0.0001, 'eta': 1, 'features': 25},
#             Current best combo with val score 0.2583:
#                     {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.85, 'gamma': 0.0001, 'eta': 1, 'features': 25}
# Trained and Tested combination 1146 of 1606500, taking 0.31 seconds to get val score of 0.2583:
#                 {'n_estimators': 200, 'max_depth': 48, 'subsample': 0.7, 'colsample_bytree': 0.85, 'gamma': 0.0001, 'eta': 1, 'features': 25},
#             Current best combo with val score 0.2583:
#                     {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.85, 'gamma': 0.0001, 'eta': 1, 'features': 25}
# Trained and Tested combination 1147 of 1606500, taking 0.31 seconds to get val score of 0.2098:
#                 {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.55, 'colsample_bytree': 0.85, 'gamma': 0.0001, 'eta': 1, 'features': 25},
#             Current best combo with val score 0.2583:
#                     {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.85, 'gamma': 0.0001, 'eta': 1, 'features': 25}
# Trained and Tested combination 1148 of 1606500, taking 0.3 seconds to get val score of 0.2004:
#                 {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.85, 'colsample_bytree': 0.85, 'gamma': 0.0001, 'eta': 1, 'features': 25},
#             Current best combo with val score 0.2583:
#                     {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.85, 'gamma': 0.0001, 'eta': 1, 'features': 25}
# Already Trained and Tested combination (val score of 0.1907):
#             {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.7, 'gamma': 0.0001, 'eta': 1, 'features': 25}
#             Current best combo (with val score 0.2583):
#                     {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.85, 'gamma': 0.0001, 'eta': 1, 'features': 25}
#         Has trained 1148 of 1606500 combinations so far
# Trained and Tested combination 1149 of 1606500, taking 1.33 seconds to get val score of 0.1741:
#                 {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 1, 'gamma': 0.0001, 'eta': 1, 'features': 25},
#             Current best combo with val score 0.2583:
#                     {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.85, 'gamma': 0.0001, 'eta': 1, 'features': 25}
# Trained and Tested combination 1150 of 1606500, taking 0.3 seconds to get val score of 0.2448:
#                 {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.85, 'gamma': 1e-06, 'eta': 1, 'features': 25},
#             Current best combo with val score 0.2583:
#                     {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.85, 'gamma': 0.0001, 'eta': 1, 'features': 25}
# Trained and Tested combination 1151 of 1606500, taking 0.33 seconds to get val score of 0.1984:
#                 {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.85, 'gamma': 0.01, 'eta': 1, 'features': 25},
#             Current best combo with val score 0.2583:
#                     {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.85, 'gamma': 0.0001, 'eta': 1, 'features': 25}
# Already Trained and Tested combination (val score of 0.0363):
#             {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.85, 'gamma': 0.0001, 'eta': 0.1, 'features': 25}
#             Current best combo (with val score 0.2583):
#                     {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.85, 'gamma': 0.0001, 'eta': 1, 'features': 25}
#         Has trained 1151 of 1606500 combinations so far
# Trained and Tested combination 1152 of 1606500, taking 0.21 seconds to get val score of 0.1084:
#                 {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.85, 'gamma': 0.0001, 'eta': 10, 'features': 25},
#             Current best combo with val score 0.2583:
#                     {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.85, 'gamma': 0.0001, 'eta': 1, 'features': 25}
# Trained and Tested combination 1153 of 1606500, taking 0.3 seconds to get val score of 0.1019:
#                 {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.85, 'gamma': 0.0001, 'eta': 1, 'features': 24},
#             Current best combo with val score 0.2583:
#                     {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.85, 'gamma': 0.0001, 'eta': 1, 'features': 25}
# Trained and Tested combination 1154 of 1606500, taking 0.33 seconds to get val score of 0.4076:
#                 {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.85, 'gamma': 0.0001, 'eta': 1, 'features': 26},
#             Current best combo with val score 0.4076:
#                     {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.85, 'gamma': 0.0001, 'eta': 1, 'features': 26}
# Trained and Tested combination 1155 of 1606500, taking 0.22 seconds to get val score of 0.3801:
#                 {'n_estimators': 100, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.85, 'gamma': 0.0001, 'eta': 1, 'features': 26},
#             Current best combo with val score 0.4076:
#                     {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.85, 'gamma': 0.0001, 'eta': 1, 'features': 26}
# Trained and Tested combination 1156 of 1606500, taking 0.53 seconds to get val score of 0.3917:
#                 {'n_estimators': 400, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.85, 'gamma': 0.0001, 'eta': 1, 'features': 26},
#             Current best combo with val score 0.4076:
#                     {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.85, 'gamma': 0.0001, 'eta': 1, 'features': 26}
# Trained and Tested combination 1157 of 1606500, taking 0.34 seconds to get val score of 0.2924:
#                 {'n_estimators': 200, 'max_depth': 12, 'subsample': 0.7, 'colsample_bytree': 0.85, 'gamma': 0.0001, 'eta': 1, 'features': 26},
#             Current best combo with val score 0.4076:
#                     {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.85, 'gamma': 0.0001, 'eta': 1, 'features': 26}
# Trained and Tested combination 1158 of 1606500, taking 0.3 seconds to get val score of 0.4076:
#                 {'n_estimators': 200, 'max_depth': 48, 'subsample': 0.7, 'colsample_bytree': 0.85, 'gamma': 0.0001, 'eta': 1, 'features': 26},
#             Current best combo with val score 0.4076:
#                     {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.85, 'gamma': 0.0001, 'eta': 1, 'features': 26}
# Trained and Tested combination 1159 of 1606500, taking 1.33 seconds to get val score of 0.2389:
#                 {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.55, 'colsample_bytree': 0.85, 'gamma': 0.0001, 'eta': 1, 'features': 26},
#             Current best combo with val score 0.4076:
#                     {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.85, 'gamma': 0.0001, 'eta': 1, 'features': 26}
# Trained and Tested combination 1160 of 1606500, taking 0.31 seconds to get val score of 0.2971:
#                 {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.85, 'colsample_bytree': 0.85, 'gamma': 0.0001, 'eta': 1, 'features': 26},
#             Current best combo with val score 0.4076:
#                     {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.85, 'gamma': 0.0001, 'eta': 1, 'features': 26}
# Already Trained and Tested combination (val score of 0.1136):
#             {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.7, 'gamma': 0.0001, 'eta': 1, 'features': 26}
#             Current best combo (with val score 0.4076):
#                     {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.85, 'gamma': 0.0001, 'eta': 1, 'features': 26}
#         Has trained 1160 of 1606500 combinations so far
# Trained and Tested combination 1161 of 1606500, taking 0.31 seconds to get val score of 0.1636:
#                 {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 1, 'gamma': 0.0001, 'eta': 1, 'features': 26},
#             Current best combo with val score 0.4076:
#                     {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.85, 'gamma': 0.0001, 'eta': 1, 'features': 26}
# Trained and Tested combination 1162 of 1606500, taking 0.31 seconds to get val score of 0.4095:
#                 {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.85, 'gamma': 1e-06, 'eta': 1, 'features': 26},
#             Current best combo with val score 0.4095:
#                     {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.85, 'gamma': 1e-06, 'eta': 1, 'features': 26}
# Trained and Tested combination 1163 of 1606500, taking 0.32 seconds to get val score of 0.335:
#                 {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.85, 'gamma': 0.01, 'eta': 1, 'features': 26},
#             Current best combo with val score 0.4095:
#                     {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.85, 'gamma': 1e-06, 'eta': 1, 'features': 26}
# Trained and Tested combination 1164 of 1606500, taking 0.57 seconds to get val score of 0.0398:
#                 {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.85, 'gamma': 0.0001, 'eta': 0.1, 'features': 26},
#             Current best combo with val score 0.4095:
#                     {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.85, 'gamma': 1e-06, 'eta': 1, 'features': 26}
# Trained and Tested combination 1165 of 1606500, taking 0.21 seconds to get val score of 0.1313:
#                 {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.85, 'gamma': 0.0001, 'eta': 10, 'features': 26},
#             Current best combo with val score 0.4095:
#                     {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.85, 'gamma': 1e-06, 'eta': 1, 'features': 26}
# Already Trained and Tested combination (val score of 0.2583):
#             {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.85, 'gamma': 0.0001, 'eta': 1, 'features': 25}
#             Current best combo (with val score 0.4095):
#                     {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.85, 'gamma': 1e-06, 'eta': 1, 'features': 26}
#         Has trained 1165 of 1606500 combinations so far
# Trained and Tested combination 1166 of 1606500, taking 0.34 seconds to get val score of 0.1471:
#                 {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.85, 'gamma': 0.0001, 'eta': 1, 'features': 27},
#             Current best combo with val score 0.4095:
#                     {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.85, 'gamma': 1e-06, 'eta': 1, 'features': 26}
# Trained and Tested combination 1167 of 1606500, taking 0.21 seconds to get val score of 0.3835:
#                 {'n_estimators': 100, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.85, 'gamma': 1e-06, 'eta': 1, 'features': 26},
#             Current best combo with val score 0.4095:
#                     {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.85, 'gamma': 1e-06, 'eta': 1, 'features': 26}
# Trained and Tested combination 1168 of 1606500, taking 2.82 seconds to get val score of 0.399:
#                 {'n_estimators': 400, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.85, 'gamma': 1e-06, 'eta': 1, 'features': 26},
#             Current best combo with val score 0.4095:
#                     {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.85, 'gamma': 1e-06, 'eta': 1, 'features': 26}
# Trained and Tested combination 1169 of 1606500, taking 0.33 seconds to get val score of 0.2798:
#                 {'n_estimators': 200, 'max_depth': 12, 'subsample': 0.7, 'colsample_bytree': 0.85, 'gamma': 1e-06, 'eta': 1, 'features': 26},
#             Current best combo with val score 0.4095:
#                     {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.85, 'gamma': 1e-06, 'eta': 1, 'features': 26}
# Trained and Tested combination 1170 of 1606500, taking 0.32 seconds to get val score of 0.4095:
#                 {'n_estimators': 200, 'max_depth': 48, 'subsample': 0.7, 'colsample_bytree': 0.85, 'gamma': 1e-06, 'eta': 1, 'features': 26},
#             Current best combo with val score 0.4095:
#                     {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.85, 'gamma': 1e-06, 'eta': 1, 'features': 26}
# Trained and Tested combination 1171 of 1606500, taking 0.34 seconds to get val score of 0.2471:
#                 {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.55, 'colsample_bytree': 0.85, 'gamma': 1e-06, 'eta': 1, 'features': 26},
#             Current best combo with val score 0.4095:
#                     {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.85, 'gamma': 1e-06, 'eta': 1, 'features': 26}
# Trained and Tested combination 1172 of 1606500, taking 0.31 seconds to get val score of 0.2962:
#                 {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.85, 'colsample_bytree': 0.85, 'gamma': 1e-06, 'eta': 1, 'features': 26},
#             Current best combo with val score 0.4095:
#                     {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.85, 'gamma': 1e-06, 'eta': 1, 'features': 26}
# Trained and Tested combination 1173 of 1606500, taking 3.41 seconds to get val score of 0.1103:
#                 {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.7, 'gamma': 1e-06, 'eta': 1, 'features': 26},
#             Current best combo with val score 0.4095:
#                     {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.85, 'gamma': 1e-06, 'eta': 1, 'features': 26}
# Trained and Tested combination 1174 of 1606500, taking 0.32 seconds to get val score of 0.1666:
#                 {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 1, 'gamma': 1e-06, 'eta': 1, 'features': 26},
#             Current best combo with val score 0.4095:
#                     {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.85, 'gamma': 1e-06, 'eta': 1, 'features': 26}
# Trained and Tested combination 1175 of 1606500, taking 0.3 seconds to get val score of 0.4095:
#                 {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.85, 'gamma': 1e-08, 'eta': 1, 'features': 26},
#             Current best combo with val score 0.4095:
#                     {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.85, 'gamma': 1e-06, 'eta': 1, 'features': 26}
# Already Trained and Tested combination (val score of 0.4076):
#             {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.85, 'gamma': 0.0001, 'eta': 1, 'features': 26}
#             Current best combo (with val score 0.4095):
#                     {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.85, 'gamma': 1e-06, 'eta': 1, 'features': 26}
#         Has trained 1175 of 1606500 combinations so far
# Trained and Tested combination 1176 of 1606500, taking 0.56 seconds to get val score of 0.0398:
#                 {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.85, 'gamma': 1e-06, 'eta': 0.1, 'features': 26},
#             Current best combo with val score 0.4095:
#                     {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.85, 'gamma': 1e-06, 'eta': 1, 'features': 26}
# Trained and Tested combination 1177 of 1606500, taking 0.21 seconds to get val score of 0.1313:
#                 {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.85, 'gamma': 1e-06, 'eta': 10, 'features': 26},
#             Current best combo with val score 0.4095:
#                     {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.85, 'gamma': 1e-06, 'eta': 1, 'features': 26}
# Already Trained and Tested combination (val score of 0.2448):
#             {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.85, 'gamma': 1e-06, 'eta': 1, 'features': 25}
#             Current best combo (with val score 0.4095):
#                     {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.85, 'gamma': 1e-06, 'eta': 1, 'features': 26}
#         Has trained 1177 of 1606500 combinations so far
# Trained and Tested combination 1178 of 1606500, taking 0.31 seconds to get val score of 0.1467:
#                 {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.85, 'gamma': 1e-06, 'eta': 1, 'features': 27},
#             Current best combo with val score 0.4095:
#                     {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.85, 'gamma': 1e-06, 'eta': 1, 'features': 26}
# % Combos Checked Thus Far: 1178 out of 1606500 which is 0.07332699999999999%
# STAGE TWO: Begin Cruise system
#
#
# Cruising Coordrdinate 1 of 1056
#
# Cruising Coordrdinate 2 of 1056
#
# Cruising Coordrdinate 3 of 1056
#
# Cruising Coordrdinate 4 of 1056
#
# Cruising Coordrdinate 5 of 1056
#
# Cruising Coordrdinate 6 of 1056
#
# Cruising Coordrdinate 7 of 1056
#
# Cruising Coordrdinate 8 of 1056
#
# Cruising Coordrdinate 9 of 1056
#
# Cruising Coordrdinate 10 of 1056
#
# Cruising Coordrdinate 11 of 1056
#
# Cruising Coordrdinate 12 of 1056
#
# Cruising Coordrdinate 13 of 1056
#
# Cruising Coordrdinate 14 of 1056
#
# Cruising Coordrdinate 15 of 1056
#
# Cruising Coordrdinate 16 of 1056
#
# Cruising Coordrdinate 17 of 1056
#
# Cruising Coordrdinate 18 of 1056
#
# Cruising Coordrdinate 19 of 1056
#
# Cruising Coordrdinate 20 of 1056
#
# Cruising Coordrdinate 21 of 1056
#
# Cruising Coordrdinate 22 of 1056
#
# Cruising Coordrdinate 23 of 1056
#
# Cruising Coordrdinate 24 of 1056
#
# Cruising Coordrdinate 25 of 1056
#
# Cruising Coordrdinate 26 of 1056
#
# Cruising Coordrdinate 27 of 1056
#
# Cruising Coordrdinate 28 of 1056
#
# Cruising Coordrdinate 29 of 1056
#
# Cruising Coordrdinate 30 of 1056
#
# Cruising Coordrdinate 31 of 1056
#
# Cruising Coordrdinate 32 of 1056
#
# Cruising Coordrdinate 33 of 1056
#
# Cruising Coordrdinate 34 of 1056
#
# Cruising Coordrdinate 35 of 1056
#
# Cruising Coordrdinate 36 of 1056
#
# Cruising Coordrdinate 37 of 1056
#
# Cruising Coordrdinate 38 of 1056
#
# Cruising Coordrdinate 39 of 1056
#
# Cruising Coordrdinate 40 of 1056
#
# Cruising Coordrdinate 41 of 1056
#
# Cruising Coordrdinate 42 of 1056
#
# Cruising Coordrdinate 43 of 1056
#
# Cruising Coordrdinate 44 of 1056
#
# Cruising Coordrdinate 45 of 1056
#
# Cruising Coordrdinate 46 of 1056
#
# Cruising Coordrdinate 47 of 1056
#
# Cruising Coordrdinate 48 of 1056
#
# Cruising Coordrdinate 49 of 1056
#
# Cruising Coordrdinate 50 of 1056
#
# Cruising Coordrdinate 51 of 1056
#
# Cruising Coordrdinate 52 of 1056
#
# Cruising Coordrdinate 53 of 1056
#
# Cruising Coordrdinate 54 of 1056
#
# Cruising Coordrdinate 55 of 1056
#
# Cruising Coordrdinate 56 of 1056
#
# Cruising Coordrdinate 57 of 1056
#
# Cruising Coordrdinate 58 of 1056
#
# Cruising Coordrdinate 59 of 1056
#
# Cruising Coordrdinate 60 of 1056
#
# Cruising Coordrdinate 61 of 1056
#
# Cruising Coordrdinate 62 of 1056
#
# Cruising Coordrdinate 63 of 1056
#
# Cruising Coordrdinate 64 of 1056
#
# Cruising Coordrdinate 65 of 1056
#
# Cruising Coordrdinate 66 of 1056
#
# Cruising Coordrdinate 67 of 1056
#
# Cruising Coordrdinate 68 of 1056
#
# Cruising Coordrdinate 69 of 1056
#
# Cruising Coordrdinate 70 of 1056
#
# Cruising Coordrdinate 71 of 1056
#
# Cruising Coordrdinate 72 of 1056
#
# Cruising Coordrdinate 73 of 1056
#
# Cruising Coordrdinate 74 of 1056
#
# Cruising Coordrdinate 75 of 1056
#
# Cruising Coordrdinate 76 of 1056
#
# Cruising Coordrdinate 77 of 1056
#
# Cruising Coordrdinate 78 of 1056
#
# Cruising Coordrdinate 79 of 1056
#
# Cruising Coordrdinate 80 of 1056
#
# Cruising Coordrdinate 81 of 1056
#
# Cruising Coordrdinate 82 of 1056
#
# Cruising Coordrdinate 83 of 1056
#
# Cruising Coordrdinate 84 of 1056
#
# Cruising Coordrdinate 85 of 1056
#
# Cruising Coordrdinate 86 of 1056
#
# Cruising Coordrdinate 87 of 1056
#
# Cruising Coordrdinate 88 of 1056
#
# Cruising Coordrdinate 89 of 1056
#
# Cruising Coordrdinate 90 of 1056
#
# Cruising Coordrdinate 91 of 1056
#
# Cruising Coordrdinate 92 of 1056
#
# Cruising Coordrdinate 93 of 1056
#
# Cruising Coordrdinate 94 of 1056
#
# Cruising Coordrdinate 95 of 1056
#
# Cruising Coordrdinate 96 of 1056
#
# Cruising Coordrdinate 97 of 1056
#
# Cruising Coordrdinate 98 of 1056
#
# Cruising Coordrdinate 99 of 1056
#
# Cruising Coordrdinate 100 of 1056
#
# Cruising Coordrdinate 101 of 1056
#
# Cruising Coordrdinate 102 of 1056
#
# Cruising Coordrdinate 103 of 1056
#
# Cruising Coordrdinate 104 of 1056
#
# Cruising Coordrdinate 105 of 1056
#
# Cruising Coordrdinate 106 of 1056
#
# Cruising Coordrdinate 107 of 1056
#
# Cruising Coordrdinate 108 of 1056
#
# Cruising Coordrdinate 109 of 1056
#
# Cruising Coordrdinate 110 of 1056
#
# Cruising Coordrdinate 111 of 1056
#
# Cruising Coordrdinate 112 of 1056
#
# Cruising Coordrdinate 113 of 1056
#
# Cruising Coordrdinate 114 of 1056
#
# Cruising Coordrdinate 115 of 1056
#
# Cruising Coordrdinate 116 of 1056
#
# Cruising Coordrdinate 117 of 1056
#
# Cruising Coordrdinate 118 of 1056
#
# Cruising Coordrdinate 119 of 1056
#
# Cruising Coordrdinate 120 of 1056
#
# Cruising Coordrdinate 121 of 1056
#
# Cruising Coordrdinate 122 of 1056
#
# Cruising Coordrdinate 123 of 1056
#
# Cruising Coordrdinate 124 of 1056
#
# Cruising Coordrdinate 125 of 1056
#
# Cruising Coordrdinate 126 of 1056
#
# Cruise suspended due to suspicious case
# Guidance: round 1
#
# 	round 1 iteration:  0
#
# Trained and Tested combination 1179 of 1606500, taking 0.1 seconds to get val score of 0.2244:
#                 {'n_estimators': 50, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 0.1, 'eta': 10, 'features': 50},
#             Current best combo with val score 0.4095:
#                     {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.85, 'gamma': 1e-06, 'eta': 1, 'features': 26}
# Trained and Tested combination 1180 of 1606500, taking 0.09 seconds to get val score of 0.1183:
#                 {'n_estimators': 25, 'max_depth': 6, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 0.1, 'eta': 10, 'features': 50},
#             Current best combo with val score 0.4095:
#                     {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.85, 'gamma': 1e-06, 'eta': 1, 'features': 26}
# Trained and Tested combination 1181 of 1606500, taking 0.09 seconds to get val score of 0.1674:
#                 {'n_estimators': 25, 'max_depth': 3, 'subsample': 0.85, 'colsample_bytree': 0.4, 'gamma': 0.1, 'eta': 10, 'features': 50},
#             Current best combo with val score 0.4095:
#                     {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.85, 'gamma': 1e-06, 'eta': 1, 'features': 26}
# Trained and Tested combination 1182 of 1606500, taking 0.38 seconds to get val score of 0.0553:
#                 {'n_estimators': 25, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 0.55, 'gamma': 0.1, 'eta': 10, 'features': 50},
#             Current best combo with val score 0.4095:
#                     {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.85, 'gamma': 1e-06, 'eta': 1, 'features': 26}
# Trained and Tested combination 1183 of 1606500, taking 0.08 seconds to get val score of 0.2244:
#                 {'n_estimators': 25, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 0.01, 'eta': 10, 'features': 50},
#             Current best combo with val score 0.4095:
#                     {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.85, 'gamma': 1e-06, 'eta': 1, 'features': 26}
# Trained and Tested combination 1184 of 1606500, taking 0.09 seconds to get val score of 0.1874:
#                 {'n_estimators': 25, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 0.1, 'eta': 1, 'features': 50},
#             Current best combo with val score 0.4095:
#                     {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.85, 'gamma': 1e-06, 'eta': 1, 'features': 26}
# Trained and Tested combination 1185 of 1606500, taking 0.08 seconds to get val score of 0.1014:
#                 {'n_estimators': 25, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 0.1, 'eta': 10, 'features': 49},
#             Current best combo with val score 0.4095:
#                     {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.85, 'gamma': 1e-06, 'eta': 1, 'features': 26}
# 	round 1 iteration:  1
#
# Already Trained and Tested combination (val score of 0.2244):
#             {'n_estimators': 25, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 0.1, 'eta': 10, 'features': 50}
#             Current best combo (with val score 0.4095):
#                     {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.85, 'gamma': 1e-06, 'eta': 1, 'features': 26}
#         Has trained 1185 of 1606500 combinations so far
# Trained and Tested combination 1186 of 1606500, taking 0.14 seconds to get val score of 0.2244:
#                 {'n_estimators': 100, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 0.1, 'eta': 10, 'features': 50},
#             Current best combo with val score 0.4095:
#                     {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.85, 'gamma': 1e-06, 'eta': 1, 'features': 26}
# Trained and Tested combination 1187 of 1606500, taking 0.12 seconds to get val score of 0.1183:
#                 {'n_estimators': 50, 'max_depth': 6, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 0.1, 'eta': 10, 'features': 50},
#             Current best combo with val score 0.4095:
#                     {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.85, 'gamma': 1e-06, 'eta': 1, 'features': 26}
# Trained and Tested combination 1188 of 1606500, taking 0.11 seconds to get val score of 0.1674:
#                 {'n_estimators': 50, 'max_depth': 3, 'subsample': 0.85, 'colsample_bytree': 0.4, 'gamma': 0.1, 'eta': 10, 'features': 50},
#             Current best combo with val score 0.4095:
#                     {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.85, 'gamma': 1e-06, 'eta': 1, 'features': 26}
# Trained and Tested combination 1189 of 1606500, taking 0.11 seconds to get val score of 0.0553:
#                 {'n_estimators': 50, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 0.55, 'gamma': 0.1, 'eta': 10, 'features': 50},
#             Current best combo with val score 0.4095:
#                     {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.85, 'gamma': 1e-06, 'eta': 1, 'features': 26}
# Trained and Tested combination 1190 of 1606500, taking 0.13 seconds to get val score of 0.2244:
#                 {'n_estimators': 50, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 0.01, 'eta': 10, 'features': 50},
#             Current best combo with val score 0.4095:
#                     {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.85, 'gamma': 1e-06, 'eta': 1, 'features': 26}
# Trained and Tested combination 1191 of 1606500, taking 0.13 seconds to get val score of 0.2218:
#                 {'n_estimators': 50, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 0.1, 'eta': 1, 'features': 50},
#             Current best combo with val score 0.4095:
#                     {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.85, 'gamma': 1e-06, 'eta': 1, 'features': 26}
# Trained and Tested combination 1192 of 1606500, taking 0.11 seconds to get val score of 0.1014:
#                 {'n_estimators': 50, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 0.1, 'eta': 10, 'features': 49},
#             Current best combo with val score 0.4095:
#                     {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.85, 'gamma': 1e-06, 'eta': 1, 'features': 26}
# Already Trained and Tested combination (val score of 0.2244):
#             {'n_estimators': 50, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 0.01, 'eta': 10, 'features': 50}
#             Current best combo (with val score 0.4095):
#                     {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.85, 'gamma': 1e-06, 'eta': 1, 'features': 26}
#         Has trained 1192 of 1606500 combinations so far
# Trained and Tested combination 1193 of 1606500, taking 0.09 seconds to get val score of 0.1183:
#                 {'n_estimators': 25, 'max_depth': 6, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 0.01, 'eta': 10, 'features': 50},
#             Current best combo with val score 0.4095:
#                     {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.85, 'gamma': 1e-06, 'eta': 1, 'features': 26}
# Trained and Tested combination 1194 of 1606500, taking 0.09 seconds to get val score of 0.1674:
#                 {'n_estimators': 25, 'max_depth': 3, 'subsample': 0.85, 'colsample_bytree': 0.4, 'gamma': 0.01, 'eta': 10, 'features': 50},
#             Current best combo with val score 0.4095:
#                     {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.85, 'gamma': 1e-06, 'eta': 1, 'features': 26}
# Trained and Tested combination 1195 of 1606500, taking 0.09 seconds to get val score of 0.0553:
#                 {'n_estimators': 25, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 0.55, 'gamma': 0.01, 'eta': 10, 'features': 50},
#             Current best combo with val score 0.4095:
#                     {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.85, 'gamma': 1e-06, 'eta': 1, 'features': 26}
# Trained and Tested combination 1196 of 1606500, taking 0.08 seconds to get val score of 0.2244:
#                 {'n_estimators': 25, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 0.0001, 'eta': 10, 'features': 50},
#             Current best combo with val score 0.4095:
#                     {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.85, 'gamma': 1e-06, 'eta': 1, 'features': 26}
# Already Trained and Tested combination (val score of 0.2244):
#             {'n_estimators': 25, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 0.1, 'eta': 10, 'features': 50}
#             Current best combo (with val score 0.4095):
#                     {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.85, 'gamma': 1e-06, 'eta': 1, 'features': 26}
#         Has trained 1196 of 1606500 combinations so far
# Trained and Tested combination 1197 of 1606500, taking 0.09 seconds to get val score of 0.1794:
#                 {'n_estimators': 25, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 0.01, 'eta': 1, 'features': 50},
#             Current best combo with val score 0.4095:
#                     {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.85, 'gamma': 1e-06, 'eta': 1, 'features': 26}
# Trained and Tested combination 1198 of 1606500, taking 0.1 seconds to get val score of 0.1014:
#                 {'n_estimators': 25, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 0.01, 'eta': 10, 'features': 49},
#             Current best combo with val score 0.4095:
#                     {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.85, 'gamma': 1e-06, 'eta': 1, 'features': 26}
# % Combos Checked Thus Far: 1198 out of 1606500 which is 0.074572%
# Cruising Coordrdinate 127 of 1056
#
# Cruising Coordrdinate 128 of 1056
#
# Cruising Coordrdinate 129 of 1056
#
# Cruising Coordrdinate 130 of 1056
#
# Cruising Coordrdinate 131 of 1056
#
# Cruising Coordrdinate 132 of 1056
#
# Cruising Coordrdinate 133 of 1056
#
# Cruising Coordrdinate 134 of 1056
#
# Cruising Coordrdinate 135 of 1056
#
# Cruising Coordrdinate 136 of 1056
#
# Cruising Coordrdinate 137 of 1056
#
# Cruising Coordrdinate 138 of 1056
#
# Cruise suspended due to suspicious case
# Guidance: round 2
#
# 	round 2 iteration:  0
#
# Trained and Tested combination 1199 of 1606500, taking 0.4 seconds to get val score of 0.2244:
#                 {'n_estimators': 400, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 0.1, 'eta': 10, 'features': 50},
#             Current best combo with val score 0.4095:
#                     {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.85, 'gamma': 1e-06, 'eta': 1, 'features': 26}
# Trained and Tested combination 1200 of 1606500, taking 0.83 seconds to get val score of 0.1183:
#                 {'n_estimators': 800, 'max_depth': 6, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 0.1, 'eta': 10, 'features': 50},
#             Current best combo with val score 0.4095:
#                     {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.85, 'gamma': 1e-06, 'eta': 1, 'features': 26}
# Trained and Tested combination 1201 of 1606500, taking 0.8 seconds to get val score of 0.1674:
#                 {'n_estimators': 800, 'max_depth': 3, 'subsample': 0.85, 'colsample_bytree': 0.4, 'gamma': 0.1, 'eta': 10, 'features': 50},
#             Current best combo with val score 0.4095:
#                     {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.85, 'gamma': 1e-06, 'eta': 1, 'features': 26}
# Trained and Tested combination 1202 of 1606500, taking 0.82 seconds to get val score of 0.0553:
#                 {'n_estimators': 800, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 0.55, 'gamma': 0.1, 'eta': 10, 'features': 50},
#             Current best combo with val score 0.4095:
#                     {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.85, 'gamma': 1e-06, 'eta': 1, 'features': 26}
# Trained and Tested combination 1203 of 1606500, taking 0.69 seconds to get val score of 0.2244:
#                 {'n_estimators': 800, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 0.01, 'eta': 10, 'features': 50},
#             Current best combo with val score 0.4095:
#                     {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.85, 'gamma': 1e-06, 'eta': 1, 'features': 26}
# Trained and Tested combination 1204 of 1606500, taking 0.73 seconds to get val score of 0.1913:
#                 {'n_estimators': 800, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 0.1, 'eta': 1, 'features': 50},
#             Current best combo with val score 0.4095:
#                     {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.85, 'gamma': 1e-06, 'eta': 1, 'features': 26}
# Trained and Tested combination 1205 of 1606500, taking 1.84 seconds to get val score of 0.1014:
#                 {'n_estimators': 800, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 0.1, 'eta': 10, 'features': 49},
#             Current best combo with val score 0.4095:
#                     {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.85, 'gamma': 1e-06, 'eta': 1, 'features': 26}
# 	round 2 iteration:  1
#
# Trained and Tested combination 1206 of 1606500, taking 0.21 seconds to get val score of 0.2244:
#                 {'n_estimators': 200, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 0.1, 'eta': 10, 'features': 50},
#             Current best combo with val score 0.4095:
#                     {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.85, 'gamma': 1e-06, 'eta': 1, 'features': 26}
# Already Trained and Tested combination (val score of 0.2244):
#             {'n_estimators': 800, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 0.1, 'eta': 10, 'features': 50}
#             Current best combo (with val score 0.4095):
#                     {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.85, 'gamma': 1e-06, 'eta': 1, 'features': 26}
#         Has trained 1206 of 1606500 combinations so far
# Trained and Tested combination 1207 of 1606500, taking 0.46 seconds to get val score of 0.1183:
#                 {'n_estimators': 400, 'max_depth': 6, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 0.1, 'eta': 10, 'features': 50},
#             Current best combo with val score 0.4095:
#                     {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.85, 'gamma': 1e-06, 'eta': 1, 'features': 26}
# Trained and Tested combination 1208 of 1606500, taking 0.43 seconds to get val score of 0.1674:
#                 {'n_estimators': 400, 'max_depth': 3, 'subsample': 0.85, 'colsample_bytree': 0.4, 'gamma': 0.1, 'eta': 10, 'features': 50},
#             Current best combo with val score 0.4095:
#                     {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.85, 'gamma': 1e-06, 'eta': 1, 'features': 26}
# Trained and Tested combination 1209 of 1606500, taking 0.45 seconds to get val score of 0.0553:
#                 {'n_estimators': 400, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 0.55, 'gamma': 0.1, 'eta': 10, 'features': 50},
#             Current best combo with val score 0.4095:
#                     {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.85, 'gamma': 1e-06, 'eta': 1, 'features': 26}
# Trained and Tested combination 1210 of 1606500, taking 0.39 seconds to get val score of 0.2244:
#                 {'n_estimators': 400, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 0.01, 'eta': 10, 'features': 50},
#             Current best combo with val score 0.4095:
#                     {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.85, 'gamma': 1e-06, 'eta': 1, 'features': 26}
# Trained and Tested combination 1211 of 1606500, taking 0.41 seconds to get val score of 0.1913:
#                 {'n_estimators': 400, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 0.1, 'eta': 1, 'features': 50},
#             Current best combo with val score 0.4095:
#                     {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.85, 'gamma': 1e-06, 'eta': 1, 'features': 26}
# Trained and Tested combination 1212 of 1606500, taking 0.42 seconds to get val score of 0.1014:
#                 {'n_estimators': 400, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 0.1, 'eta': 10, 'features': 49},
#             Current best combo with val score 0.4095:
#                     {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.85, 'gamma': 1e-06, 'eta': 1, 'features': 26}
# Already Trained and Tested combination (val score of 0.2244):
#             {'n_estimators': 400, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 0.01, 'eta': 10, 'features': 50}
#             Current best combo (with val score 0.4095):
#                     {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.85, 'gamma': 1e-06, 'eta': 1, 'features': 26}
#         Has trained 1212 of 1606500 combinations so far
# Trained and Tested combination 1213 of 1606500, taking 0.82 seconds to get val score of 0.1183:
#                 {'n_estimators': 800, 'max_depth': 6, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 0.01, 'eta': 10, 'features': 50},
#             Current best combo with val score 0.4095:
#                     {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.85, 'gamma': 1e-06, 'eta': 1, 'features': 26}
# Trained and Tested combination 1214 of 1606500, taking 0.83 seconds to get val score of 0.1674:
#                 {'n_estimators': 800, 'max_depth': 3, 'subsample': 0.85, 'colsample_bytree': 0.4, 'gamma': 0.01, 'eta': 10, 'features': 50},
#             Current best combo with val score 0.4095:
#                     {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.85, 'gamma': 1e-06, 'eta': 1, 'features': 26}
# Trained and Tested combination 1215 of 1606500, taking 4.01 seconds to get val score of 0.0553:
#                 {'n_estimators': 800, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 0.55, 'gamma': 0.01, 'eta': 10, 'features': 50},
#             Current best combo with val score 0.4095:
#                     {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.85, 'gamma': 1e-06, 'eta': 1, 'features': 26}
# Trained and Tested combination 1216 of 1606500, taking 0.67 seconds to get val score of 0.2244:
#                 {'n_estimators': 800, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 0.0001, 'eta': 10, 'features': 50},
#             Current best combo with val score 0.4095:
#                     {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.85, 'gamma': 1e-06, 'eta': 1, 'features': 26}
# Already Trained and Tested combination (val score of 0.2244):
#             {'n_estimators': 800, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 0.1, 'eta': 10, 'features': 50}
#             Current best combo (with val score 0.4095):
#                     {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.85, 'gamma': 1e-06, 'eta': 1, 'features': 26}
#         Has trained 1216 of 1606500 combinations so far
# Trained and Tested combination 1217 of 1606500, taking 0.78 seconds to get val score of 0.1256:
#                 {'n_estimators': 800, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 0.01, 'eta': 1, 'features': 50},
#             Current best combo with val score 0.4095:
#                     {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.85, 'gamma': 1e-06, 'eta': 1, 'features': 26}
# Trained and Tested combination 1218 of 1606500, taking 0.8 seconds to get val score of 0.1014:
#                 {'n_estimators': 800, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 0.01, 'eta': 10, 'features': 49},
#             Current best combo with val score 0.4095:
#                     {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.85, 'gamma': 1e-06, 'eta': 1, 'features': 26}
# % Combos Checked Thus Far: 1218 out of 1606500 which is 0.075817%
# Cruising Coordrdinate 139 of 1056
#
# Cruising Coordrdinate 140 of 1056
#
# Cruising Coordrdinate 141 of 1056
#
# Cruising Coordrdinate 142 of 1056
#
# Cruising Coordrdinate 143 of 1056
#
# Cruising Coordrdinate 144 of 1056
#
# Cruising Coordrdinate 145 of 1056
#
# Cruising Coordrdinate 146 of 1056
#
# Cruising Coordrdinate 147 of 1056
#
# Cruising Coordrdinate 148 of 1056
#
# Cruising Coordrdinate 149 of 1056
#
# Cruising Coordrdinate 150 of 1056
#
# Cruising Coordrdinate 151 of 1056
#
# Cruise suspended due to suspicious case
# Guidance: round 3
#
# 	round 3 iteration:  0
#
# Trained and Tested combination 1219 of 1606500, taking 0.1 seconds to get val score of 0.2244:
#                 {'n_estimators': 50, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 10, 'features': 50},
#             Current best combo with val score 0.4095:
#                     {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.85, 'gamma': 1e-06, 'eta': 1, 'features': 26}
# Trained and Tested combination 1220 of 1606500, taking 0.44 seconds to get val score of 0.1183:
#                 {'n_estimators': 25, 'max_depth': 6, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 10, 'features': 50},
#             Current best combo with val score 0.4095:
#                     {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.85, 'gamma': 1e-06, 'eta': 1, 'features': 26}
# Trained and Tested combination 1221 of 1606500, taking 0.09 seconds to get val score of 0.1674:
#                 {'n_estimators': 25, 'max_depth': 3, 'subsample': 0.85, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 10, 'features': 50},
#             Current best combo with val score 0.4095:
#                     {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.85, 'gamma': 1e-06, 'eta': 1, 'features': 26}
# Trained and Tested combination 1222 of 1606500, taking 0.08 seconds to get val score of 0.0553:
#                 {'n_estimators': 25, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 0.55, 'gamma': 1e-08, 'eta': 10, 'features': 50},
#             Current best combo with val score 0.4095:
#                     {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.85, 'gamma': 1e-06, 'eta': 1, 'features': 26}
# Trained and Tested combination 1223 of 1606500, taking 0.08 seconds to get val score of 0.2244:
#                 {'n_estimators': 25, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-06, 'eta': 10, 'features': 50},
#             Current best combo with val score 0.4095:
#                     {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.85, 'gamma': 1e-06, 'eta': 1, 'features': 26}
# Trained and Tested combination 1224 of 1606500, taking 0.09 seconds to get val score of 0.1794:
#                 {'n_estimators': 25, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 1, 'features': 50},
#             Current best combo with val score 0.4095:
#                     {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.85, 'gamma': 1e-06, 'eta': 1, 'features': 26}
# Trained and Tested combination 1225 of 1606500, taking 0.13 seconds to get val score of 0.1014:
#                 {'n_estimators': 25, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 10, 'features': 49},
#             Current best combo with val score 0.4095:
# ...
# Already Trained and Tested combination (val score of 0.5139):
#             {'n_estimators': 100, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 0.1, 'eta': 0.1, 'features': 12}
#             Current best combo (with val score 0.524):
#                     {'n_estimators': 100, 'max_depth': 6, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 0.1, 'eta': 0.1, 'features': 12}
#         Has trained 1621 of 1606500 combinations so far
# Trained and Tested combination 1622 of 1606500, taking 0.19 seconds to get val score of 0.4991:
#                 {'n_estimators': 100, 'max_depth': 12, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 0.1, 'eta': 0.1, 'features': 12},
#             Current best combo with val score 0.524:
#                     {'n_estimators': 100, 'max_depth': 6, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 0.1, 'eta': 0.1, 'features': 12}
# Trained and Tested combination 1623 of 1606500, taking 0.15 seconds to get val score of 0.4702:
#                 {'n_estimators': 100, 'max_depth': 6, 'subsample': 0.85, 'colsample_bytree': 0.4, 'gamma': 0.1, 'eta': 0.1, 'features': 12},
#             Current best combo with val score 0.524:
#                     {'n_estimators': 100, 'max_depth': 6, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 0.1, 'eta': 0.1, 'features': 12}
# Trained and Tested combination 1624 of 1606500, taking 0.13 seconds to get val score of 0.4001:
#                 {'n_estimators': 100, 'max_depth': 6, 'subsample': 1, 'colsample_bytree': 0.55, 'gamma': 0.1, 'eta': 0.1, 'features': 12},
#             Current best combo with val score 0.524:
#                     {'n_estimators': 100, 'max_depth': 6, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 0.1, 'eta': 0.1, 'features': 12}
# Trained and Tested combination 1625 of 1606500, taking 0.13 seconds to get val score of 0.5067:
#                 {'n_estimators': 100, 'max_depth': 6, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 0.01, 'eta': 0.1, 'features': 12},
#             Current best combo with val score 0.524:
#                     {'n_estimators': 100, 'max_depth': 6, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 0.1, 'eta': 0.1, 'features': 12}
# Trained and Tested combination 1626 of 1606500, taking 0.15 seconds to get val score of 0.0:
#                 {'n_estimators': 100, 'max_depth': 6, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 0.1, 'eta': 0.01, 'features': 12},
#             Current best combo with val score 0.524:
#                     {'n_estimators': 100, 'max_depth': 6, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 0.1, 'eta': 0.1, 'features': 12}
# Trained and Tested combination 1627 of 1606500, taking 1.16 seconds to get val score of 0.4265:
#                 {'n_estimators': 100, 'max_depth': 6, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 0.1, 'eta': 1, 'features': 12},
#             Current best combo with val score 0.524:
#                     {'n_estimators': 100, 'max_depth': 6, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 0.1, 'eta': 0.1, 'features': 12}
# Already Trained and Tested combination (val score of 0.5064):
#             {'n_estimators': 100, 'max_depth': 6, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 0.1, 'eta': 0.1, 'features': 11}
#             Current best combo (with val score 0.524):
#                     {'n_estimators': 100, 'max_depth': 6, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 0.1, 'eta': 0.1, 'features': 12}
#         Has trained 1627 of 1606500 combinations so far
# Trained and Tested combination 1628 of 1606500, taking 0.14 seconds to get val score of 0.4414:
#                 {'n_estimators': 100, 'max_depth': 6, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 0.1, 'eta': 0.1, 'features': 13},
#             Current best combo with val score 0.524:
#                     {'n_estimators': 100, 'max_depth': 6, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 0.1, 'eta': 0.1, 'features': 12}
# % Combos Checked Thus Far: 1628 out of 1606500 which is 0.101338%
# Guidance: round FINAL
#
# 	round FINAL iteration:  0
#
# Already Trained and Tested combination (val score of 0.4479):
#             {'n_estimators': 50, 'max_depth': 6, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 0.1, 'eta': 0.1, 'features': 12}
#             Current best combo (with val score 0.524):
#                     {'n_estimators': 100, 'max_depth': 6, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 0.1, 'eta': 0.1, 'features': 12}
#         Has trained 1628 of 1606500 combinations so far
# Already Trained and Tested combination (val score of 0.5217):
#             {'n_estimators': 200, 'max_depth': 6, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 0.1, 'eta': 0.1, 'features': 12}
#             Current best combo (with val score 0.524):
#                     {'n_estimators': 100, 'max_depth': 6, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 0.1, 'eta': 0.1, 'features': 12}
#         Has trained 1628 of 1606500 combinations so far
# Already Trained and Tested combination (val score of 0.5139):
#             {'n_estimators': 100, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 0.1, 'eta': 0.1, 'features': 12}
#             Current best combo (with val score 0.524):
#                     {'n_estimators': 100, 'max_depth': 6, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 0.1, 'eta': 0.1, 'features': 12}
#         Has trained 1628 of 1606500 combinations so far
# Already Trained and Tested combination (val score of 0.4991):
#             {'n_estimators': 100, 'max_depth': 12, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 0.1, 'eta': 0.1, 'features': 12}
#             Current best combo (with val score 0.524):
#                     {'n_estimators': 100, 'max_depth': 6, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 0.1, 'eta': 0.1, 'features': 12}
#         Has trained 1628 of 1606500 combinations so far
# Already Trained and Tested combination (val score of 0.4702):
#             {'n_estimators': 100, 'max_depth': 6, 'subsample': 0.85, 'colsample_bytree': 0.4, 'gamma': 0.1, 'eta': 0.1, 'features': 12}
#             Current best combo (with val score 0.524):
#                     {'n_estimators': 100, 'max_depth': 6, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 0.1, 'eta': 0.1, 'features': 12}
#         Has trained 1628 of 1606500 combinations so far
# Already Trained and Tested combination (val score of 0.4001):
#             {'n_estimators': 100, 'max_depth': 6, 'subsample': 1, 'colsample_bytree': 0.55, 'gamma': 0.1, 'eta': 0.1, 'features': 12}
#             Current best combo (with val score 0.524):
#                     {'n_estimators': 100, 'max_depth': 6, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 0.1, 'eta': 0.1, 'features': 12}
#         Has trained 1628 of 1606500 combinations so far
# Already Trained and Tested combination (val score of 0.5067):
#             {'n_estimators': 100, 'max_depth': 6, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 0.01, 'eta': 0.1, 'features': 12}
#             Current best combo (with val score 0.524):
#                     {'n_estimators': 100, 'max_depth': 6, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 0.1, 'eta': 0.1, 'features': 12}
#         Has trained 1628 of 1606500 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 100, 'max_depth': 6, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 0.1, 'eta': 0.01, 'features': 12}
#             Current best combo (with val score 0.524):
#                     {'n_estimators': 100, 'max_depth': 6, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 0.1, 'eta': 0.1, 'features': 12}
#         Has trained 1628 of 1606500 combinations so far
# Already Trained and Tested combination (val score of 0.4265):
#             {'n_estimators': 100, 'max_depth': 6, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 0.1, 'eta': 1, 'features': 12}
#             Current best combo (with val score 0.524):
#                     {'n_estimators': 100, 'max_depth': 6, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 0.1, 'eta': 0.1, 'features': 12}
#         Has trained 1628 of 1606500 combinations so far
# Already Trained and Tested combination (val score of 0.5064):
#             {'n_estimators': 100, 'max_depth': 6, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 0.1, 'eta': 0.1, 'features': 11}
#             Current best combo (with val score 0.524):
#                     {'n_estimators': 100, 'max_depth': 6, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 0.1, 'eta': 0.1, 'features': 12}
#         Has trained 1628 of 1606500 combinations so far
# Already Trained and Tested combination (val score of 0.4414):
#             {'n_estimators': 100, 'max_depth': 6, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 0.1, 'eta': 0.1, 'features': 13}
#             Current best combo (with val score 0.524):
#                     {'n_estimators': 100, 'max_depth': 6, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 0.1, 'eta': 0.1, 'features': 12}
#         Has trained 1628 of 1606500 combinations so far
# 	round FINAL iteration:  1
#
# Already Trained and Tested combination (val score of 0.524):
#             {'n_estimators': 100, 'max_depth': 6, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 0.1, 'eta': 0.1, 'features': 12}
#             Current best combo (with val score 0.524):
#                     {'n_estimators': 100, 'max_depth': 6, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 0.1, 'eta': 0.1, 'features': 12}
#         Has trained 1628 of 1606500 combinations so far
# Trained and Tested combination 1629 of 1606500, taking 0.32 seconds to get val score of 0.5219:
#                 {'n_estimators': 400, 'max_depth': 6, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 0.1, 'eta': 0.1, 'features': 12},
#             Current best combo with val score 0.524:
#                     {'n_estimators': 100, 'max_depth': 6, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 0.1, 'eta': 0.1, 'features': 12}
# Already Trained and Tested combination (val score of 0.5166):
#             {'n_estimators': 200, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 0.1, 'eta': 0.1, 'features': 12}
#             Current best combo (with val score 0.524):
#                     {'n_estimators': 100, 'max_depth': 6, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 0.1, 'eta': 0.1, 'features': 12}
#         Has trained 1629 of 1606500 combinations so far
# Trained and Tested combination 1630 of 1606500, taking 0.98 seconds to get val score of 0.5217:
#                 {'n_estimators': 200, 'max_depth': 12, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 0.1, 'eta': 0.1, 'features': 12},
#             Current best combo with val score 0.524:
#                     {'n_estimators': 100, 'max_depth': 6, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 0.1, 'eta': 0.1, 'features': 12}
# Trained and Tested combination 1631 of 1606500, taking 0.23 seconds to get val score of 0.4891:
#                 {'n_estimators': 200, 'max_depth': 6, 'subsample': 0.85, 'colsample_bytree': 0.4, 'gamma': 0.1, 'eta': 0.1, 'features': 12},
#             Current best combo with val score 0.524:
#                     {'n_estimators': 100, 'max_depth': 6, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 0.1, 'eta': 0.1, 'features': 12}
# Trained and Tested combination 1632 of 1606500, taking 0.21 seconds to get val score of 0.4284:
#                 {'n_estimators': 200, 'max_depth': 6, 'subsample': 1, 'colsample_bytree': 0.55, 'gamma': 0.1, 'eta': 0.1, 'features': 12},
#             Current best combo with val score 0.524:
#                     {'n_estimators': 100, 'max_depth': 6, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 0.1, 'eta': 0.1, 'features': 12}
# Trained and Tested combination 1633 of 1606500, taking 3.32 seconds to get val score of 0.5122:
#                 {'n_estimators': 200, 'max_depth': 6, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 0.01, 'eta': 0.1, 'features': 12},
#             Current best combo with val score 0.524:
#                     {'n_estimators': 100, 'max_depth': 6, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 0.1, 'eta': 0.1, 'features': 12}
# Trained and Tested combination 1634 of 1606500, taking 0.25 seconds to get val score of 0.0198:
#                 {'n_estimators': 200, 'max_depth': 6, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 0.1, 'eta': 0.01, 'features': 12},
#             Current best combo with val score 0.524:
#                     {'n_estimators': 100, 'max_depth': 6, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 0.1, 'eta': 0.1, 'features': 12}
# Trained and Tested combination 1635 of 1606500, taking 0.15 seconds to get val score of 0.4265:
#                 {'n_estimators': 200, 'max_depth': 6, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 0.1, 'eta': 1, 'features': 12},
#             Current best combo with val score 0.524:
#                     {'n_estimators': 100, 'max_depth': 6, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 0.1, 'eta': 0.1, 'features': 12}
# Trained and Tested combination 1636 of 1606500, taking 0.23 seconds to get val score of 0.4914:
#                 {'n_estimators': 200, 'max_depth': 6, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 0.1, 'eta': 0.1, 'features': 11},
#             Current best combo with val score 0.524:
#                     {'n_estimators': 100, 'max_depth': 6, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 0.1, 'eta': 0.1, 'features': 12}
# Trained and Tested combination 1637 of 1606500, taking 0.21 seconds to get val score of 0.494:
#                 {'n_estimators': 200, 'max_depth': 6, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 0.1, 'eta': 0.1, 'features': 13},
#             Current best combo with val score 0.524:
#                     {'n_estimators': 100, 'max_depth': 6, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 0.1, 'eta': 0.1, 'features': 12}
# % Combos Checked Thus Far: 1637 out of 1606500 which is 0.101899%
# Max Val Score:
#  0.524005
# Max Val Score Std:
#  0.070779
# Best Combo Train Score:
#  0.731751
# Best Combo Train Score Std:
#  0.011594
# Max Combo Index:
#  (2, 1, 4, 0, 4, 3, 12) out of [6, 7, 5, 5, 5, 6, 51] (note best combo is 0-indexed)
# Max Combo Hyperparamer Combination:
#  {'n_estimators': 100, 'max_depth': 6, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 0.1, 'eta': 0.1, 'features': 12}
# Max Combo Features:
#  ('procedure_225792', 'ventilation_used', 'lods_score', 'race_AMERICAN INDIAN/ALASKA NATIVE', 'race_ASIAN', 'race_ASIAN - ASIAN INDIAN', 'race_ASIAN - CHINESE', 'race_ASIAN - KOREAN', 'race_ASIAN - SOUTH EAST ASIAN', 'race_BLACK/AFRICAN', 'race_BLACK/AFRICAN AMERICAN', 'race_BLACK/CAPE VERDEAN', 'race_BLACK/CARIBBEAN ISLAND', 'race_HISPANIC/LATINO - CENTRAL AMERICAN', 'race_HISPANIC/LATINO - COLUMBIAN', 'race_HISPANIC/LATINO - CUBAN', 'race_HISPANIC/LATINO - DOMINICAN', 'race_HISPANIC/LATINO - GUATEMALAN', 'race_HISPANIC/LATINO - HONDURAN', 'race_HISPANIC/LATINO - MEXICAN', 'race_HISPANIC/LATINO - PUERTO RICAN', 'race_HISPANIC/LATINO - SALVADORAN', 'race_MULTIPLE RACE/ETHNICITY', 'race_NATIVE HAWAIIAN OR OTHER PACIFIC ISLANDER', 'race_OTHER', 'race_PATIENT DECLINED TO ANSWER', 'race_PORTUGUESE', 'race_SOUTH AMERICAN', 'race_UNABLE TO OBTAIN', 'race_UNKNOWN', 'race_WHITE', 'race_WHITE - BRAZILIAN', 'race_WHITE - EASTERN EUROPEAN', 'race_WHITE - OTHER EUROPEAN', 'race_WHITE - RUSSIAN', 'race_HISPANIC OR LATINO', 'marital_status_DIVORCED', 'marital_status_MARRIED', 'marital_status_SINGLE', 'marital_status_WIDOWED', 'marital_status_0', 'hospital_stay_duration', 'procedure_225464', 'procedure_225802', 'procedure_227712', 'admission_type_DIRECT EMER.', 'admission_type_DIRECT OBSERVATION', 'admission_type_ELECTIVE', 'admission_type_EU OBSERVATION', 'admission_type_EW EMER.', 'admission_type_OBSERVATION ADMIT', 'admission_type_URGENT', 'admission_type_SURGICAL SAME DAY ADMISSION', 'procedure_225446', 'oasis_score', 'procedure_225400')
# % Combos Checked: 1637 out of 1606500 which is 0.101899%
