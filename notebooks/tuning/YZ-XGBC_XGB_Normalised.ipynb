# %% [markdown]
# # Tuning Script

# %%
# Parameters subject to change in every script - involved in naming

MODEL = 'xgbc'
PREPROCESSING = 'normalise'
TUNER = 'yangzhoub'
OPTIMISED_METRIC = 'f1'

# %% [markdown]
# ---

# %%
# detect whether this is a google environment

COLAB_ENVIRONMENT = False

try:
    from google.colab import drive
    drive.mount('/content/drive')
    COLAB_ENVIRONMENT = True
except:
    pass
# Out:
# Mounted at /content/drive

# %%
import sys
import os
import pickle

if COLAB_ENVIRONMENT:
    home_directory = './drive/MyDrive/LAB/COMP90089__GroupWork__Py/' # my home directory is stored in ./LAB of google drive
    if MODEL == 'ebr':
        # !pip install interpret==0.5.0
    elif MODEL == 'cbr':
        # !pip install catboost
    elif MODEL in ['tf', 'mlp']:
        # !pip install PyTorch2Sklearn
    # !pip install JXAutoML
else:
    home_directory = '../../'

from JXAutoML.YangZhouB_10CV import YangZhouB_10CV as Tuner

import pandas as pd
# Out:
# Collecting JXAutoML
#   Downloading JXAutoML-0.4.4-py3-none-any.whl.metadata (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.2/67.2 kB 1.8 MB/s eta 0:00:00
# Downloading JXAutoML-0.4.4-py3-none-any.whl (52 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.1/52.1 kB 4.1 MB/s eta 0:00:00
# Installing collected packages: JXAutoML
# Successfully installed JXAutoML-0.4.4

# %%
# Parameters that are same for every script

FOLDS = 10  # we have decided to do 10 fold validation

SEED = 42

TASK_TYPE = 'Classification'  # this task is a classification task

# we have decided to tune features as hp
TUNE_FEATURES_AS_HYPERPARAMETERS = True

# %% [markdown]
# ---

# %%
# model to use to tune
from xgboost import XGBClassifier as clf

# what values to try for each hyperparameter
parameter_choices = {
        'n_estimators': (25, 50, 100, 200, 400, 800),
        'max_depth': (3, 6, 12, 24, 48, 96, 192),
        'subsample': (0.4, 0.55, 0.7, 0.85, 1),
        'colsample_bytree': (0.4, 0.55, 0.7, 0.85, 1),
        'gamma': (0.00000001, 0.000001, 0.0001, 0.01, 0.1),
        'eta': (0.0001, 0.001, 0.01, 0.1, 1, 10)
}

# what values to set non-tuneable parameters/hyperparameters
non_tunable_hyperparameters_dict = {
                                    'random_state': SEED,
                                    'n_jobs': -1
                                    }

# %% [markdown]
# ---

# %% [markdown]
# Read in and Prepare Data

# %%
# Import data and store as lists

train_x_list = []
train_y_list = []
val_x_list = []
val_y_list = []

for i in range(FOLDS):
    train_data = pd.read_csv(
        f'{home_directory}data/curated/modelling/{PREPROCESSING}/train_{i}.csv')
    val_data = pd.read_csv(
        f'{home_directory}data/curated/modelling/{PREPROCESSING}/val_{i}.csv')

    # get the correct rows for X and y
    train_x = train_data.drop(
        ['mortality_status', 'subject_id', 'hadm_id', 'stay_id'], axis=1)
    train_y = train_data['mortality_status']
    val_x = val_data.drop(
        ['mortality_status', 'subject_id', 'hadm_id', 'stay_id'], axis=1)
    val_y = val_data['mortality_status']

    train_x_list.append(train_x)
    train_y_list.append(train_y)
    val_x_list.append(val_x)
    val_y_list.append(val_y)

# %%
# Import feature importance ordering

with open(f'{home_directory}models/xgb_feature_importance_ordering_{PREPROCESSING}.pickle', 'rb') as f:
    feature_importance_ordering = pickle.load(f)

# %% [markdown]
# Set parameters

# %%
# initialisation
tuner = Tuner()

print('---')

# define what model we are tuning
tuner.read_in_model(clf, TASK_TYPE, optimised_metric=OPTIMISED_METRIC)

print('---')

# read in the data for training and validation
tuner.read_in_data(train_x_list, train_y_list, val_x_list, val_y_list)

print('---')

# set what hp values to tune
tuner.set_hyperparameters(parameter_choices)
# WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

# set up hp values that need to be changed from default but NOT to be tuned
tuner.set_non_tuneable_hyperparameters(non_tunable_hyperparameters_dict)

print('---')

# set up feature importance ordering

if TUNE_FEATURES_AS_HYPERPARAMETERS:
    tuner.set_features(feature_importance_ordering)
    # WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

try:  # try to read in previous results to continue tuning ...
    tuner.read_in_tuning_result_df(
        f'{home_directory}models/tuning/{TUNER}_{MODEL}_{PREPROCESSING}.csv')
except:
    print('No previous tuning data read in')

print('---')

# set up where to save the tuning result csv
tuner.set_tuning_result_saving_address(
    f'{home_directory}models/tuning/{TUNER}_{MODEL}_{PREPROCESSING}.csv')

print('---')

# set up where to save the current best model
tuner.set_best_model_saving_address(
    f'{home_directory}models/tmp_models/{TUNER}_{MODEL}_{PREPROCESSING}')
# Out:
# YangZhouB Initialised
# ---
# Successfully read in model <class 'xgboost.sklearn.XGBClassifier'>, which is a Classification model optimising for f1
# ---
# Read in Train X data list
# Read in Train y data list
# Read in Val X data list
# Read in Val y data list
# ---
# Successfully recorded hyperparameter choices
# ---
# Successfully recorded non_tuneable_hyperparameter choices
# ---
# Successfully recorded tuneable feature combination choices and updated relevant internal structures
# ---
# Successfully read in tuning result of 1004 rows, for 1004.0 combos
# ---
# Successfully set tuning output address
# ---
# Successfully set best model output address

# %%
# ignore warnings

import warnings
warnings.filterwarnings("ignore")

# %%
# begin tuning ... (or continue training)

tuner.tune()
# Out:
# Streaming output truncated to the last 5000 lines.
#             {'n_estimators': 25, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.4, 'gamma': 0.1, 'eta': 10, 'features': 25}
#             Current best combo (with val score 0.2685):
#                     {'n_estimators': 25, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 1, 'gamma': 1e-08, 'eta': 10, 'features': 10}
#         Has trained 1004 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.0713):
#             {'n_estimators': 25, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 1, 'gamma': 1e-08, 'eta': 10, 'features': 47}
#             Current best combo (with val score 0.2685):
#                     {'n_estimators': 25, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 1, 'gamma': 1e-08, 'eta': 10, 'features': 10}
#         Has trained 1004 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.118):
#             {'n_estimators': 25, 'max_depth': 24, 'subsample': 1, 'colsample_bytree': 1, 'gamma': 1e-08, 'eta': 10, 'features': 20}
#             Current best combo (with val score 0.2685):
#                     {'n_estimators': 25, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 1, 'gamma': 1e-08, 'eta': 10, 'features': 10}
#         Has trained 1004 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.1009):
#             {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 0.1, 'eta': 10, 'features': 47}
#             Current best combo (with val score 0.2685):
#                     {'n_estimators': 25, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 1, 'gamma': 1e-08, 'eta': 10, 'features': 10}
#         Has trained 1004 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.0649):
#             {'n_estimators': 800, 'max_depth': 192, 'subsample': 0.4, 'colsample_bytree': 1, 'gamma': 1e-08, 'eta': 10, 'features': 47}
#             Current best combo (with val score 0.2685):
#                     {'n_estimators': 25, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 1, 'gamma': 1e-08, 'eta': 10, 'features': 10}
#         Has trained 1004 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 800, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 47}
#             Current best combo (with val score 0.2685):
#                     {'n_estimators': 25, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 1, 'gamma': 1e-08, 'eta': 10, 'features': 10}
#         Has trained 1004 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.2014):
#             {'n_estimators': 25, 'max_depth': 192, 'subsample': 0.4, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 10, 'features': 35}
#             Current best combo (with val score 0.2685):
#                     {'n_estimators': 25, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 1, 'gamma': 1e-08, 'eta': 10, 'features': 10}
#         Has trained 1004 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 25, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 1, 'gamma': 1e-08, 'eta': 0.0001, 'features': 0}
#             Current best combo (with val score 0.2685):
#                     {'n_estimators': 25, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 1, 'gamma': 1e-08, 'eta': 10, 'features': 10}
#         Has trained 1004 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.0312):
#             {'n_estimators': 25, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 1, 'gamma': 0.1, 'eta': 10, 'features': 35}
#             Current best combo (with val score 0.2685):
#                     {'n_estimators': 25, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 1, 'gamma': 1e-08, 'eta': 10, 'features': 10}
#         Has trained 1004 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 800, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 0.1, 'eta': 0.0001, 'features': 47}
#             Current best combo (with val score 0.2685):
#                     {'n_estimators': 25, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 1, 'gamma': 1e-08, 'eta': 10, 'features': 10}
#         Has trained 1004 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 25, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 0.1, 'eta': 0.0001, 'features': 43}
#             Current best combo (with val score 0.2685):
#                     {'n_estimators': 25, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 1, 'gamma': 1e-08, 'eta': 10, 'features': 10}
#         Has trained 1004 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 25, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 1, 'gamma': 0.1, 'eta': 0.0001, 'features': 5}
#             Current best combo (with val score 0.2685):
#                     {'n_estimators': 25, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 1, 'gamma': 1e-08, 'eta': 10, 'features': 10}
#         Has trained 1004 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 25, 'max_depth': 24, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 0.1, 'eta': 0.0001, 'features': 39}
#             Current best combo (with val score 0.2685):
#                     {'n_estimators': 25, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 1, 'gamma': 1e-08, 'eta': 10, 'features': 10}
#         Has trained 1004 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.0937):
#             {'n_estimators': 800, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 1, 'gamma': 0.1, 'eta': 10, 'features': 20}
#             Current best combo (with val score 0.2685):
#                     {'n_estimators': 25, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 1, 'gamma': 1e-08, 'eta': 10, 'features': 10}
#         Has trained 1004 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.1539):
#             {'n_estimators': 25, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 0.1, 'eta': 10, 'features': 35}
#             Current best combo (with val score 0.2685):
#                     {'n_estimators': 25, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 1, 'gamma': 1e-08, 'eta': 10, 'features': 10}
#         Has trained 1004 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 25, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 1, 'gamma': 0.1, 'eta': 0.0001, 'features': 30}
#             Current best combo (with val score 0.2685):
#                     {'n_estimators': 25, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 1, 'gamma': 1e-08, 'eta': 10, 'features': 10}
#         Has trained 1004 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 25, 'max_depth': 24, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 0}
#             Current best combo (with val score 0.2685):
#                     {'n_estimators': 25, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 1, 'gamma': 1e-08, 'eta': 10, 'features': 10}
#         Has trained 1004 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 800, 'max_depth': 24, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 47}
#             Current best combo (with val score 0.2685):
#                     {'n_estimators': 25, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 1, 'gamma': 1e-08, 'eta': 10, 'features': 10}
#         Has trained 1004 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 25, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 1, 'gamma': 1e-08, 'eta': 0.0001, 'features': 25}
#             Current best combo (with val score 0.2685):
#                     {'n_estimators': 25, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 1, 'gamma': 1e-08, 'eta': 10, 'features': 10}
#         Has trained 1004 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 800, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 1, 'gamma': 1e-08, 'eta': 0.0001, 'features': 25}
#             Current best combo (with val score 0.2685):
#                     {'n_estimators': 25, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 1, 'gamma': 1e-08, 'eta': 10, 'features': 10}
#         Has trained 1004 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.0675):
#             {'n_estimators': 800, 'max_depth': 192, 'subsample': 0.4, 'colsample_bytree': 1, 'gamma': 1e-08, 'eta': 10, 'features': 25}
#             Current best combo (with val score 0.2685):
#                     {'n_estimators': 25, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 1, 'gamma': 1e-08, 'eta': 10, 'features': 10}
#         Has trained 1004 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 25, 'max_depth': 192, 'subsample': 0.4, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 10}
#             Current best combo (with val score 0.2685):
#                     {'n_estimators': 25, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 1, 'gamma': 1e-08, 'eta': 10, 'features': 10}
#         Has trained 1004 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 25, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 25}
#             Current best combo (with val score 0.2685):
#                     {'n_estimators': 25, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 1, 'gamma': 1e-08, 'eta': 10, 'features': 10}
#         Has trained 1004 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 25, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 1, 'gamma': 1e-08, 'eta': 0.0001, 'features': 20}
#             Current best combo (with val score 0.2685):
#                     {'n_estimators': 25, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 1, 'gamma': 1e-08, 'eta': 10, 'features': 10}
#         Has trained 1004 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 25, 'max_depth': 24, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 39}
#             Current best combo (with val score 0.2685):
#                     {'n_estimators': 25, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 1, 'gamma': 1e-08, 'eta': 10, 'features': 10}
#         Has trained 1004 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 25, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 0.1, 'eta': 0.0001, 'features': 15}
#             Current best combo (with val score 0.2685):
#                     {'n_estimators': 25, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 1, 'gamma': 1e-08, 'eta': 10, 'features': 10}
#         Has trained 1004 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 800, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 1, 'gamma': 0.1, 'eta': 0.0001, 'features': 39}
#             Current best combo (with val score 0.2685):
#                     {'n_estimators': 25, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 1, 'gamma': 1e-08, 'eta': 10, 'features': 10}
#         Has trained 1004 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 800, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 1, 'gamma': 0.1, 'eta': 0.0001, 'features': 43}
#             Current best combo (with val score 0.2685):
#                     {'n_estimators': 25, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 1, 'gamma': 1e-08, 'eta': 10, 'features': 10}
#         Has trained 1004 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.1249):
#             {'n_estimators': 25, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 0.1, 'eta': 10, 'features': 25}
#             Current best combo (with val score 0.2685):
#                     {'n_estimators': 25, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 1, 'gamma': 1e-08, 'eta': 10, 'features': 10}
#         Has trained 1004 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.1249):
#             {'n_estimators': 800, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 10, 'features': 20}
#             Current best combo (with val score 0.2685):
#                     {'n_estimators': 25, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 1, 'gamma': 1e-08, 'eta': 10, 'features': 10}
#         Has trained 1004 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 800, 'max_depth': 192, 'subsample': 0.4, 'colsample_bytree': 1, 'gamma': 0.1, 'eta': 10, 'features': 0}
#             Current best combo (with val score 0.2685):
#                     {'n_estimators': 25, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 1, 'gamma': 1e-08, 'eta': 10, 'features': 10}
#         Has trained 1004 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.062):
#             {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 1, 'gamma': 1e-08, 'eta': 10, 'features': 30}
#             Current best combo (with val score 0.2685):
#                     {'n_estimators': 25, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 1, 'gamma': 1e-08, 'eta': 10, 'features': 10}
#         Has trained 1004 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 25, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 35}
#             Current best combo (with val score 0.2685):
#                     {'n_estimators': 25, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 1, 'gamma': 1e-08, 'eta': 10, 'features': 10}
#         Has trained 1004 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 800, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 1, 'gamma': 1e-08, 'eta': 0.0001, 'features': 25}
#             Current best combo (with val score 0.2685):
#                     {'n_estimators': 25, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 1, 'gamma': 1e-08, 'eta': 10, 'features': 10}
#         Has trained 1004 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.0409):
#             {'n_estimators': 800, 'max_depth': 24, 'subsample': 1, 'colsample_bytree': 1, 'gamma': 0.1, 'eta': 10, 'features': 10}
#             Current best combo (with val score 0.2685):
#                     {'n_estimators': 25, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 1, 'gamma': 1e-08, 'eta': 10, 'features': 10}
#         Has trained 1004 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.0713):
#             {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 1, 'gamma': 1e-08, 'eta': 10, 'features': 47}
#             Current best combo (with val score 0.2685):
#                     {'n_estimators': 25, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 1, 'gamma': 1e-08, 'eta': 10, 'features': 10}
#         Has trained 1004 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 25, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 0.1, 'eta': 0.0001, 'features': 20}
#             Current best combo (with val score 0.2685):
#                     {'n_estimators': 25, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 1, 'gamma': 1e-08, 'eta': 10, 'features': 10}
#         Has trained 1004 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.0708):
#             {'n_estimators': 25, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 1, 'gamma': 0.1, 'eta': 10, 'features': 43}
#             Current best combo (with val score 0.2685):
#                     {'n_estimators': 25, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 1, 'gamma': 1e-08, 'eta': 10, 'features': 10}
#         Has trained 1004 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 800, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 1, 'gamma': 1e-08, 'eta': 0.0001, 'features': 39}
#             Current best combo (with val score 0.2685):
#                     {'n_estimators': 25, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 1, 'gamma': 1e-08, 'eta': 10, 'features': 10}
#         Has trained 1004 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 800, 'max_depth': 24, 'subsample': 1, 'colsample_bytree': 1, 'gamma': 1e-08, 'eta': 0.0001, 'features': 15}
#             Current best combo (with val score 0.2685):
#                     {'n_estimators': 25, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 1, 'gamma': 1e-08, 'eta': 10, 'features': 10}
#         Has trained 1004 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 25, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 43}
#             Current best combo (with val score 0.2685):
#                     {'n_estimators': 25, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 1, 'gamma': 1e-08, 'eta': 10, 'features': 10}
#         Has trained 1004 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.1847):
#             {'n_estimators': 25, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 0.1, 'eta': 10, 'features': 39}
#             Current best combo (with val score 0.2685):
#                     {'n_estimators': 25, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 1, 'gamma': 1e-08, 'eta': 10, 'features': 10}
#         Has trained 1004 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 800, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 1, 'gamma': 0.1, 'eta': 0.0001, 'features': 10}
#             Current best combo (with val score 0.2685):
#                     {'n_estimators': 25, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 1, 'gamma': 1e-08, 'eta': 10, 'features': 10}
#         Has trained 1004 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.0314):
#             {'n_estimators': 25, 'max_depth': 24, 'subsample': 1, 'colsample_bytree': 1, 'gamma': 0.1, 'eta': 10, 'features': 47}
#             Current best combo (with val score 0.2685):
#                     {'n_estimators': 25, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 1, 'gamma': 1e-08, 'eta': 10, 'features': 10}
#         Has trained 1004 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 25, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 1, 'gamma': 0.1, 'eta': 0.0001, 'features': 35}
#             Current best combo (with val score 0.2685):
#                     {'n_estimators': 25, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 1, 'gamma': 1e-08, 'eta': 10, 'features': 10}
#         Has trained 1004 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 25, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 5}
#             Current best combo (with val score 0.2685):
#                     {'n_estimators': 25, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 1, 'gamma': 1e-08, 'eta': 10, 'features': 10}
#         Has trained 1004 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 25, 'max_depth': 192, 'subsample': 0.4, 'colsample_bytree': 1, 'gamma': 1e-08, 'eta': 0.0001, 'features': 35}
#             Current best combo (with val score 0.2685):
#                     {'n_estimators': 25, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 1, 'gamma': 1e-08, 'eta': 10, 'features': 10}
#         Has trained 1004 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 25, 'max_depth': 24, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 0.1, 'eta': 0.0001, 'features': 35}
#             Current best combo (with val score 0.2685):
#                     {'n_estimators': 25, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 1, 'gamma': 1e-08, 'eta': 10, 'features': 10}
#         Has trained 1004 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 800, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 1, 'gamma': 1e-08, 'eta': 0.0001, 'features': 0}
#             Current best combo (with val score 0.2685):
#                     {'n_estimators': 25, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 1, 'gamma': 1e-08, 'eta': 10, 'features': 10}
#         Has trained 1004 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 25, 'max_depth': 24, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 47}
#             Current best combo (with val score 0.2685):
#                     {'n_estimators': 25, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 1, 'gamma': 1e-08, 'eta': 10, 'features': 10}
#         Has trained 1004 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.1076):
#             {'n_estimators': 800, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 10, 'features': 30}
#             Current best combo (with val score 0.2685):
#                     {'n_estimators': 25, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 1, 'gamma': 1e-08, 'eta': 10, 'features': 10}
#         Has trained 1004 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.1973):
#             {'n_estimators': 25, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 1, 'gamma': 0.1, 'eta': 10, 'features': 5}
#             Current best combo (with val score 0.2685):
#                     {'n_estimators': 25, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 1, 'gamma': 1e-08, 'eta': 10, 'features': 10}
#         Has trained 1004 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 800, 'max_depth': 24, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 39}
#             Current best combo (with val score 0.2685):
#                     {'n_estimators': 25, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 1, 'gamma': 1e-08, 'eta': 10, 'features': 10}
#         Has trained 1004 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 800, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 30}
#             Current best combo (with val score 0.2685):
#                     {'n_estimators': 25, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 1, 'gamma': 1e-08, 'eta': 10, 'features': 10}
#         Has trained 1004 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 800, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 0.1, 'eta': 0.0001, 'features': 5}
#             Current best combo (with val score 0.2685):
#                     {'n_estimators': 25, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 1, 'gamma': 1e-08, 'eta': 10, 'features': 10}
#         Has trained 1004 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.133):
#             {'n_estimators': 800, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 1, 'gamma': 0.1, 'eta': 10, 'features': 43}
#             Current best combo (with val score 0.2685):
#                     {'n_estimators': 25, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 1, 'gamma': 1e-08, 'eta': 10, 'features': 10}
#         Has trained 1004 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 800, 'max_depth': 24, 'subsample': 1, 'colsample_bytree': 1, 'gamma': 1e-08, 'eta': 0.0001, 'features': 0}
#             Current best combo (with val score 0.2685):
#                     {'n_estimators': 25, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 1, 'gamma': 1e-08, 'eta': 10, 'features': 10}
#         Has trained 1004 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 25, 'max_depth': 192, 'subsample': 0.4, 'colsample_bytree': 1, 'gamma': 0.1, 'eta': 0.0001, 'features': 25}
#             Current best combo (with val score 0.2685):
#                     {'n_estimators': 25, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 1, 'gamma': 1e-08, 'eta': 10, 'features': 10}
#         Has trained 1004 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.1229):
#             {'n_estimators': 800, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 1, 'gamma': 0.1, 'eta': 10, 'features': 30}
#             Current best combo (with val score 0.2685):
#                     {'n_estimators': 25, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 1, 'gamma': 1e-08, 'eta': 10, 'features': 10}
#         Has trained 1004 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 800, 'max_depth': 24, 'subsample': 1, 'colsample_bytree': 1, 'gamma': 1e-08, 'eta': 0.0001, 'features': 35}
#             Current best combo (with val score 0.2685):
#                     {'n_estimators': 25, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 1, 'gamma': 1e-08, 'eta': 10, 'features': 10}
#         Has trained 1004 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.2086):
#             {'n_estimators': 800, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 1, 'gamma': 1e-08, 'eta': 10, 'features': 30}
#             Current best combo (with val score 0.2685):
#                     {'n_estimators': 25, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 1, 'gamma': 1e-08, 'eta': 10, 'features': 10}
#         Has trained 1004 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 800, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 43}
#             Current best combo (with val score 0.2685):
#                     {'n_estimators': 25, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 1, 'gamma': 1e-08, 'eta': 10, 'features': 10}
#         Has trained 1004 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 800, 'max_depth': 192, 'subsample': 0.4, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 35}
#             Current best combo (with val score 0.2685):
#                     {'n_estimators': 25, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 1, 'gamma': 1e-08, 'eta': 10, 'features': 10}
#         Has trained 1004 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 800, 'max_depth': 24, 'subsample': 1, 'colsample_bytree': 1, 'gamma': 0.1, 'eta': 0.0001, 'features': 5}
#             Current best combo (with val score 0.2685):
#                     {'n_estimators': 25, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 1, 'gamma': 1e-08, 'eta': 10, 'features': 10}
#         Has trained 1004 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 25, 'max_depth': 24, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 0.1, 'eta': 0.0001, 'features': 47}
#             Current best combo (with val score 0.2685):
#                     {'n_estimators': 25, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 1, 'gamma': 1e-08, 'eta': 10, 'features': 10}
#         Has trained 1004 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 800, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 35}
#             Current best combo (with val score 0.2685):
#                     {'n_estimators': 25, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 1, 'gamma': 1e-08, 'eta': 10, 'features': 10}
#         Has trained 1004 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 800, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 1, 'gamma': 0.1, 'eta': 0.0001, 'features': 5}
#             Current best combo (with val score 0.2685):
#                     {'n_estimators': 25, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 1, 'gamma': 1e-08, 'eta': 10, 'features': 10}
#         Has trained 1004 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 25, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 10}
#             Current best combo (with val score 0.2685):
#                     {'n_estimators': 25, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 1, 'gamma': 1e-08, 'eta': 10, 'features': 10}
#         Has trained 1004 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.0634):
#             {'n_estimators': 25, 'max_depth': 24, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 10, 'features': 30}
#             Current best combo (with val score 0.2685):
#                     {'n_estimators': 25, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 1, 'gamma': 1e-08, 'eta': 10, 'features': 10}
#         Has trained 1004 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 25, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 5}
#             Current best combo (with val score 0.2685):
#                     {'n_estimators': 25, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 1, 'gamma': 1e-08, 'eta': 10, 'features': 10}
#         Has trained 1004 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.0775):
#             {'n_estimators': 25, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'gamma': 0.1, 'eta': 10, 'features': 35}
#             Current best combo (with val score 0.2685):
#                     {'n_estimators': 25, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 1, 'gamma': 1e-08, 'eta': 10, 'features': 10}
#         Has trained 1004 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 800, 'max_depth': 192, 'subsample': 0.4, 'colsample_bytree': 1, 'gamma': 1e-08, 'eta': 0.0001, 'features': 30}
#             Current best combo (with val score 0.2685):
#                     {'n_estimators': 25, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 1, 'gamma': 1e-08, 'eta': 10, 'features': 10}
#         Has trained 1004 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 800, 'max_depth': 192, 'subsample': 0.4, 'colsample_bytree': 1, 'gamma': 1e-08, 'eta': 0.0001, 'features': 43}
#             Current best combo (with val score 0.2685):
#                     {'n_estimators': 25, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 1, 'gamma': 1e-08, 'eta': 10, 'features': 10}
#         Has trained 1004 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 25, 'max_depth': 192, 'subsample': 0.4, 'colsample_bytree': 1, 'gamma': 0.1, 'eta': 0.0001, 'features': 0}
#             Current best combo (with val score 0.2685):
#                     {'n_estimators': 25, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 1, 'gamma': 1e-08, 'eta': 10, 'features': 10}
#         Has trained 1004 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 800, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 1, 'gamma': 1e-08, 'eta': 0.0001, 'features': 25}
#             Current best combo (with val score 0.2685):
#                     {'n_estimators': 25, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 1, 'gamma': 1e-08, 'eta': 10, 'features': 10}
#         Has trained 1004 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.2335):
#             {'n_estimators': 25, 'max_depth': 24, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 10, 'features': 25}
#             Current best combo (with val score 0.2685):
#                     {'n_estimators': 25, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 1, 'gamma': 1e-08, 'eta': 10, 'features': 10}
#         Has trained 1004 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.1621):
#             {'n_estimators': 800, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.4, 'gamma': 0.1, 'eta': 10, 'features': 20}
#             Current best combo (with val score 0.2685):
#                     {'n_estimators': 25, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 1, 'gamma': 1e-08, 'eta': 10, 'features': 10}
#         Has trained 1004 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 800, 'max_depth': 192, 'subsample': 0.4, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 15}
#             Current best combo (with val score 0.2685):
#                     {'n_estimators': 25, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 1, 'gamma': 1e-08, 'eta': 10, 'features': 10}
#         Has trained 1004 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 25, 'max_depth': 24, 'subsample': 1, 'colsample_bytree': 1, 'gamma': 0.1, 'eta': 0.0001, 'features': 39}
#             Current best combo (with val score 0.2685):
#                     {'n_estimators': 25, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 1, 'gamma': 1e-08, 'eta': 10, 'features': 10}
#         Has trained 1004 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.0364):
#             {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 1, 'gamma': 1e-08, 'eta': 10, 'features': 15}
#             Current best combo (with val score 0.2685):
#                     {'n_estimators': 25, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 1, 'gamma': 1e-08, 'eta': 10, 'features': 10}
#         Has trained 1004 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 800, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 1, 'gamma': 0.1, 'eta': 0.0001, 'features': 47}
#             Current best combo (with val score 0.2685):
#                     {'n_estimators': 25, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 1, 'gamma': 1e-08, 'eta': 10, 'features': 10}
#         Has trained 1004 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 25, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 1, 'gamma': 1e-08, 'eta': 0.0001, 'features': 15}
#             Current best combo (with val score 0.2685):
#                     {'n_estimators': 25, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 1, 'gamma': 1e-08, 'eta': 10, 'features': 10}
#         Has trained 1004 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.0541):
#             {'n_estimators': 25, 'max_depth': 192, 'subsample': 0.4, 'colsample_bytree': 0.4, 'gamma': 0.1, 'eta': 10, 'features': 47}
#             Current best combo (with val score 0.2685):
#                     {'n_estimators': 25, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 1, 'gamma': 1e-08, 'eta': 10, 'features': 10}
#         Has trained 1004 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.0934):
#             {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 0.1, 'eta': 10, 'features': 20}
#             Current best combo (with val score 0.2685):
#                     {'n_estimators': 25, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 1, 'gamma': 1e-08, 'eta': 10, 'features': 10}
#         Has trained 1004 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 25, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 0}
#             Current best combo (with val score 0.2685):
#                     {'n_estimators': 25, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 1, 'gamma': 1e-08, 'eta': 10, 'features': 10}
#         Has trained 1004 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.1009):
#             {'n_estimators': 25, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 0.1, 'eta': 10, 'features': 47}
#             Current best combo (with val score 0.2685):
#                     {'n_estimators': 25, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 1, 'gamma': 1e-08, 'eta': 10, 'features': 10}
#         Has trained 1004 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.2202):
#             {'n_estimators': 800, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 1, 'gamma': 0.1, 'eta': 10, 'features': 5}
#             Current best combo (with val score 0.2685):
#                     {'n_estimators': 25, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 1, 'gamma': 1e-08, 'eta': 10, 'features': 10}
#         Has trained 1004 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 800, 'max_depth': 192, 'subsample': 0.4, 'colsample_bytree': 1, 'gamma': 1e-08, 'eta': 0.0001, 'features': 39}
#             Current best combo (with val score 0.2685):
#                     {'n_estimators': 25, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 1, 'gamma': 1e-08, 'eta': 10, 'features': 10}
#         Has trained 1004 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.1551):
#             {'n_estimators': 800, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 10, 'features': 10}
#             Current best combo (with val score 0.2685):
#                     {'n_estimators': 25, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 1, 'gamma': 1e-08, 'eta': 10, 'features': 10}
#         Has trained 1004 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.1561):
#             {'n_estimators': 800, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 1, 'gamma': 0.1, 'eta': 10, 'features': 35}
#             Current best combo (with val score 0.2685):
#                     {'n_estimators': 25, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 1, 'gamma': 1e-08, 'eta': 10, 'features': 10}
#         Has trained 1004 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.1226):
#             {'n_estimators': 800, 'max_depth': 24, 'subsample': 1, 'colsample_bytree': 1, 'gamma': 1e-08, 'eta': 10, 'features': 5}
#             Current best combo (with val score 0.2685):
#                     {'n_estimators': 25, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 1, 'gamma': 1e-08, 'eta': 10, 'features': 10}
#         Has trained 1004 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 25, 'max_depth': 192, 'subsample': 0.4, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 35}
#             Current best combo (with val score 0.2685):
#                     {'n_estimators': 25, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 1, 'gamma': 1e-08, 'eta': 10, 'features': 10}
#         Has trained 1004 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.2685):
#             {'n_estimators': 25, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 1, 'gamma': 0.1, 'eta': 10, 'features': 10}
#             Current best combo (with val score 0.2685):
#                     {'n_estimators': 25, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 1, 'gamma': 1e-08, 'eta': 10, 'features': 10}
#         Has trained 1004 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 800, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'gamma': 0.1, 'eta': 0.0001, 'features': 5}
#             Current best combo (with val score 0.2685):
#                     {'n_estimators': 25, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 1, 'gamma': 1e-08, 'eta': 10, 'features': 10}
#         Has trained 1004 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 25, 'max_depth': 24, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 35}
#             Current best combo (with val score 0.2685):
#                     {'n_estimators': 25, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 1, 'gamma': 1e-08, 'eta': 10, 'features': 10}
#         Has trained 1004 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.05):
#             {'n_estimators': 800, 'max_depth': 192, 'subsample': 0.4, 'colsample_bytree': 0.4, 'gamma': 0.1, 'eta': 10, 'features': 10}
#             Current best combo (with val score 0.2685):
#                     {'n_estimators': 25, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 1, 'gamma': 1e-08, 'eta': 10, 'features': 10}
#         Has trained 1004 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 25, 'max_depth': 192, 'subsample': 0.4, 'colsample_bytree': 0.4, 'gamma': 0.1, 'eta': 0.0001, 'features': 5}
#             Current best combo (with val score 0.2685):
#                     {'n_estimators': 25, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 1, 'gamma': 1e-08, 'eta': 10, 'features': 10}
#         Has trained 1004 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 25, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 1, 'gamma': 0.1, 'eta': 0.0001, 'features': 47}
#             Current best combo (with val score 0.2685):
#                     {'n_estimators': 25, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 1, 'gamma': 1e-08, 'eta': 10, 'features': 10}
#         Has trained 1004 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 25, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 1, 'gamma': 1e-08, 'eta': 0.0001, 'features': 15}
#             Current best combo (with val score 0.2685):
#                     {'n_estimators': 25, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 1, 'gamma': 1e-08, 'eta': 10, 'features': 10}
#         Has trained 1004 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 25, 'max_depth': 192, 'subsample': 0.4, 'colsample_bytree': 0.4, 'gamma': 0.1, 'eta': 0.0001, 'features': 10}
#             Current best combo (with val score 0.2685):
#                     {'n_estimators': 25, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 1, 'gamma': 1e-08, 'eta': 10, 'features': 10}
#         Has trained 1004 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.0313):
#             {'n_estimators': 25, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 10, 'features': 5}
#             Current best combo (with val score 0.2685):
#                     {'n_estimators': 25, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 1, 'gamma': 1e-08, 'eta': 10, 'features': 10}
#         Has trained 1004 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 800, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 1, 'gamma': 1e-08, 'eta': 0.0001, 'features': 47}
#             Current best combo (with val score 0.2685):
#                     {'n_estimators': 25, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 1, 'gamma': 1e-08, 'eta': 10, 'features': 10}
#         Has trained 1004 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.1864):
#             {'n_estimators': 800, 'max_depth': 192, 'subsample': 0.4, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 10, 'features': 15}
#             Current best combo (with val score 0.2685):
#                     {'n_estimators': 25, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 1, 'gamma': 1e-08, 'eta': 10, 'features': 10}
#         Has trained 1004 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 25, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 0}
#             Current best combo (with val score 0.2685):
#                     {'n_estimators': 25, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 1, 'gamma': 1e-08, 'eta': 10, 'features': 10}
#         Has trained 1004 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.1468):
#             {'n_estimators': 25, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 10, 'features': 25}
#             Current best combo (with val score 0.2685):
#                     {'n_estimators': 25, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 1, 'gamma': 1e-08, 'eta': 10, 'features': 10}
#         Has trained 1004 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.0794):
#             {'n_estimators': 25, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 1, 'gamma': 0.1, 'eta': 10, 'features': 15}
#             Current best combo (with val score 0.2685):
#                     {'n_estimators': 25, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 1, 'gamma': 1e-08, 'eta': 10, 'features': 10}
#         Has trained 1004 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 800, 'max_depth': 192, 'subsample': 0.4, 'colsample_bytree': 1, 'gamma': 0.1, 'eta': 0.0001, 'features': 15}
#             Current best combo (with val score 0.2685):
#                     {'n_estimators': 25, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 1, 'gamma': 1e-08, 'eta': 10, 'features': 10}
#         Has trained 1004 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.0794):
# ...
#
# Cruising Coordrdinate 946 of 1056
#
# Cruising Coordrdinate 947 of 1056
#
# Cruising Coordrdinate 948 of 1056
#
# Cruising Coordrdinate 949 of 1056
#
# Cruising Coordrdinate 950 of 1056
#
# Cruising Coordrdinate 951 of 1056
#
# Cruising Coordrdinate 952 of 1056
#
# Cruising Coordrdinate 953 of 1056
#
# Cruising Coordrdinate 954 of 1056
#
# Cruising Coordrdinate 955 of 1056
#
# Cruising Coordrdinate 956 of 1056
#
# Cruising Coordrdinate 957 of 1056
#
# Cruising Coordrdinate 958 of 1056
#
# Cruising Coordrdinate 959 of 1056
#
# Cruising Coordrdinate 960 of 1056
#
# Cruising Coordrdinate 961 of 1056
#
# Cruising Coordrdinate 962 of 1056
#
# Cruising Coordrdinate 963 of 1056
#
# Cruising Coordrdinate 964 of 1056
#
# Cruising Coordrdinate 965 of 1056
#
# Cruising Coordrdinate 966 of 1056
#
# Cruising Coordrdinate 967 of 1056
#
# Cruising Coordrdinate 968 of 1056
#
# Cruising Coordrdinate 969 of 1056
#
# Cruising Coordrdinate 970 of 1056
#
# Cruising Coordrdinate 971 of 1056
#
# Cruising Coordrdinate 972 of 1056
#
# Cruising Coordrdinate 973 of 1056
#
# Cruising Coordrdinate 974 of 1056
#
# Cruising Coordrdinate 975 of 1056
#
# Cruising Coordrdinate 976 of 1056
#
# Cruising Coordrdinate 977 of 1056
#
# Cruising Coordrdinate 978 of 1056
#
# Cruising Coordrdinate 979 of 1056
#
# Cruising Coordrdinate 980 of 1056
#
# Cruising Coordrdinate 981 of 1056
#
# Cruising Coordrdinate 982 of 1056
#
# Cruising Coordrdinate 983 of 1056
#
# Cruising Coordrdinate 984 of 1056
#
# Cruising Coordrdinate 985 of 1056
#
# Cruising Coordrdinate 986 of 1056
#
# Cruising Coordrdinate 987 of 1056
#
# Cruising Coordrdinate 988 of 1056
#
# Cruising Coordrdinate 989 of 1056
#
# Cruising Coordrdinate 990 of 1056
#
# Cruising Coordrdinate 991 of 1056
#
# Cruising Coordrdinate 992 of 1056
#
# Cruising Coordrdinate 993 of 1056
#
# Cruising Coordrdinate 994 of 1056
#
# Cruising Coordrdinate 995 of 1056
#
# Cruising Coordrdinate 996 of 1056
#
# Cruising Coordrdinate 997 of 1056
#
# Cruising Coordrdinate 998 of 1056
#
# Cruising Coordrdinate 999 of 1056
#
# Cruising Coordrdinate 1000 of 1056
#
# Cruising Coordrdinate 1001 of 1056
#
# Cruising Coordrdinate 1002 of 1056
#
# Cruising Coordrdinate 1003 of 1056
#
# Cruising Coordrdinate 1004 of 1056
#
# Cruising Coordrdinate 1005 of 1056
#
# Cruising Coordrdinate 1006 of 1056
#
# Cruising Coordrdinate 1007 of 1056
#
# Cruising Coordrdinate 1008 of 1056
#
# Cruising Coordrdinate 1009 of 1056
#
# Cruising Coordrdinate 1010 of 1056
#
# Cruising Coordrdinate 1011 of 1056
#
# Cruising Coordrdinate 1012 of 1056
#
# Cruising Coordrdinate 1013 of 1056
#
# Cruising Coordrdinate 1014 of 1056
#
# Cruising Coordrdinate 1015 of 1056
#
# Cruising Coordrdinate 1016 of 1056
#
# Cruising Coordrdinate 1017 of 1056
#
# Cruising Coordrdinate 1018 of 1056
#
# Cruising Coordrdinate 1019 of 1056
#
# Cruising Coordrdinate 1020 of 1056
#
# Cruising Coordrdinate 1021 of 1056
#
# Cruising Coordrdinate 1022 of 1056
#
# Cruising Coordrdinate 1023 of 1056
#
# Cruising Coordrdinate 1024 of 1056
#
# Cruising Coordrdinate 1025 of 1056
#
# Cruising Coordrdinate 1026 of 1056
#
# Cruising Coordrdinate 1027 of 1056
#
# Cruising Coordrdinate 1028 of 1056
#
# Cruising Coordrdinate 1029 of 1056
#
# Cruising Coordrdinate 1030 of 1056
#
# Cruising Coordrdinate 1031 of 1056
#
# Cruising Coordrdinate 1032 of 1056
#
# Cruising Coordrdinate 1033 of 1056
#
# Cruising Coordrdinate 1034 of 1056
#
# Cruising Coordrdinate 1035 of 1056
#
# Cruising Coordrdinate 1036 of 1056
#
# Cruising Coordrdinate 1037 of 1056
#
# Cruising Coordrdinate 1038 of 1056
#
# Cruising Coordrdinate 1039 of 1056
#
# Cruising Coordrdinate 1040 of 1056
#
# Cruising Coordrdinate 1041 of 1056
#
# Cruising Coordrdinate 1042 of 1056
#
# Cruising Coordrdinate 1043 of 1056
#
# Cruising Coordrdinate 1044 of 1056
#
# Cruising Coordrdinate 1045 of 1056
#
# Cruising Coordrdinate 1046 of 1056
#
# Cruising Coordrdinate 1047 of 1056
#
# Cruising Coordrdinate 1048 of 1056
#
# Cruising Coordrdinate 1049 of 1056
#
# Cruising Coordrdinate 1050 of 1056
#
# Cruising Coordrdinate 1051 of 1056
#
# Cruising Coordrdinate 1052 of 1056
#
# Cruising Coordrdinate 1053 of 1056
#
# Cruising Coordrdinate 1054 of 1056
#
# Cruising Coordrdinate 1055 of 1056
#
# Cruising Coordrdinate 1056 of 1056
#
# FINAL STAGE: Begin final Guidance system
#
#
# Guidance: round FINAL
#
# 	round FINAL iteration:  0
#
# Already Trained and Tested combination (val score of 0.4374):
#             {'n_estimators': 25, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 0.85, 'gamma': 1e-08, 'eta': 1, 'features': 11}
#             Current best combo (with val score 0.4586):
#                     {'n_estimators': 50, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 0.85, 'gamma': 1e-08, 'eta': 1, 'features': 11}
#         Has trained 1210 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.4324):
#             {'n_estimators': 100, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 0.85, 'gamma': 1e-08, 'eta': 1, 'features': 11}
#             Current best combo (with val score 0.4586):
#                     {'n_estimators': 50, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 0.85, 'gamma': 1e-08, 'eta': 1, 'features': 11}
#         Has trained 1210 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.222):
#             {'n_estimators': 50, 'max_depth': 6, 'subsample': 1, 'colsample_bytree': 0.85, 'gamma': 1e-08, 'eta': 1, 'features': 11}
#             Current best combo (with val score 0.4586):
#                     {'n_estimators': 50, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 0.85, 'gamma': 1e-08, 'eta': 1, 'features': 11}
#         Has trained 1210 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.3644):
#             {'n_estimators': 50, 'max_depth': 3, 'subsample': 0.85, 'colsample_bytree': 0.85, 'gamma': 1e-08, 'eta': 1, 'features': 11}
#             Current best combo (with val score 0.4586):
#                     {'n_estimators': 50, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 0.85, 'gamma': 1e-08, 'eta': 1, 'features': 11}
#         Has trained 1210 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.3454):
#             {'n_estimators': 50, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 0.7, 'gamma': 1e-08, 'eta': 1, 'features': 11}
#             Current best combo (with val score 0.4586):
#                     {'n_estimators': 50, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 0.85, 'gamma': 1e-08, 'eta': 1, 'features': 11}
#         Has trained 1210 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.3627):
#             {'n_estimators': 50, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 1, 'gamma': 1e-08, 'eta': 1, 'features': 11}
#             Current best combo (with val score 0.4586):
#                     {'n_estimators': 50, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 0.85, 'gamma': 1e-08, 'eta': 1, 'features': 11}
#         Has trained 1210 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.4586):
#             {'n_estimators': 50, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 0.85, 'gamma': 1e-06, 'eta': 1, 'features': 11}
#             Current best combo (with val score 0.4586):
#                     {'n_estimators': 50, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 0.85, 'gamma': 1e-08, 'eta': 1, 'features': 11}
#         Has trained 1210 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.3709):
#             {'n_estimators': 50, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 0.85, 'gamma': 1e-08, 'eta': 0.1, 'features': 11}
#             Current best combo (with val score 0.4586):
#                     {'n_estimators': 50, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 0.85, 'gamma': 1e-08, 'eta': 1, 'features': 11}
#         Has trained 1210 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.1001):
#             {'n_estimators': 50, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 0.85, 'gamma': 1e-08, 'eta': 10, 'features': 11}
#             Current best combo (with val score 0.4586):
#                     {'n_estimators': 50, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 0.85, 'gamma': 1e-08, 'eta': 1, 'features': 11}
#         Has trained 1210 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.4252):
#             {'n_estimators': 50, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 0.85, 'gamma': 1e-08, 'eta': 1, 'features': 10}
#             Current best combo (with val score 0.4586):
#                     {'n_estimators': 50, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 0.85, 'gamma': 1e-08, 'eta': 1, 'features': 11}
#         Has trained 1210 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.3408):
#             {'n_estimators': 50, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 0.85, 'gamma': 1e-08, 'eta': 1, 'features': 12}
#             Current best combo (with val score 0.4586):
#                     {'n_estimators': 50, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 0.85, 'gamma': 1e-08, 'eta': 1, 'features': 11}
#         Has trained 1210 of 1512000 combinations so far
# 	round FINAL iteration:  1
#
# Already Trained and Tested combination (val score of 0.4374):
#             {'n_estimators': 25, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 0.85, 'gamma': 1e-06, 'eta': 1, 'features': 11}
#             Current best combo (with val score 0.4586):
#                     {'n_estimators': 50, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 0.85, 'gamma': 1e-08, 'eta': 1, 'features': 11}
#         Has trained 1210 of 1512000 combinations so far
# Trained and Tested combination 1211 of 1512000, taking 0.09 seconds to get val score of 0.4324:
#                 {'n_estimators': 100, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 0.85, 'gamma': 1e-06, 'eta': 1, 'features': 11},
#             Current best combo with val score 0.4586:
#                     {'n_estimators': 50, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 0.85, 'gamma': 1e-08, 'eta': 1, 'features': 11}
# Trained and Tested combination 1212 of 1512000, taking 0.08 seconds to get val score of 0.222:
#                 {'n_estimators': 50, 'max_depth': 6, 'subsample': 1, 'colsample_bytree': 0.85, 'gamma': 1e-06, 'eta': 1, 'features': 11},
#             Current best combo with val score 0.4586:
#                     {'n_estimators': 50, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 0.85, 'gamma': 1e-08, 'eta': 1, 'features': 11}
# Trained and Tested combination 1213 of 1512000, taking 0.06 seconds to get val score of 0.3644:
#                 {'n_estimators': 50, 'max_depth': 3, 'subsample': 0.85, 'colsample_bytree': 0.85, 'gamma': 1e-06, 'eta': 1, 'features': 11},
#             Current best combo with val score 0.4586:
#                     {'n_estimators': 50, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 0.85, 'gamma': 1e-08, 'eta': 1, 'features': 11}
# Trained and Tested combination 1214 of 1512000, taking 0.06 seconds to get val score of 0.3454:
#                 {'n_estimators': 50, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 0.7, 'gamma': 1e-06, 'eta': 1, 'features': 11},
#             Current best combo with val score 0.4586:
#                     {'n_estimators': 50, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 0.85, 'gamma': 1e-08, 'eta': 1, 'features': 11}
# Trained and Tested combination 1215 of 1512000, taking 0.06 seconds to get val score of 0.3627:
#                 {'n_estimators': 50, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 1, 'gamma': 1e-06, 'eta': 1, 'features': 11},
#             Current best combo with val score 0.4586:
#                     {'n_estimators': 50, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 0.85, 'gamma': 1e-08, 'eta': 1, 'features': 11}
# Already Trained and Tested combination (val score of 0.4586):
#             {'n_estimators': 50, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 0.85, 'gamma': 1e-08, 'eta': 1, 'features': 11}
#             Current best combo (with val score 0.4586):
#                     {'n_estimators': 50, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 0.85, 'gamma': 1e-08, 'eta': 1, 'features': 11}
#         Has trained 1215 of 1512000 combinations so far
# Trained and Tested combination 1216 of 1512000, taking 0.06 seconds to get val score of 0.4586:
#                 {'n_estimators': 50, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 0.85, 'gamma': 0.0001, 'eta': 1, 'features': 11},
#             Current best combo with val score 0.4586:
#                     {'n_estimators': 50, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 0.85, 'gamma': 1e-08, 'eta': 1, 'features': 11}
# Trained and Tested combination 1217 of 1512000, taking 0.14 seconds to get val score of 0.3709:
#                 {'n_estimators': 50, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 0.85, 'gamma': 1e-06, 'eta': 0.1, 'features': 11},
#             Current best combo with val score 0.4586:
#                     {'n_estimators': 50, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 0.85, 'gamma': 1e-08, 'eta': 1, 'features': 11}
# Trained and Tested combination 1218 of 1512000, taking 0.06 seconds to get val score of 0.1001:
#                 {'n_estimators': 50, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 0.85, 'gamma': 1e-06, 'eta': 10, 'features': 11},
#             Current best combo with val score 0.4586:
#                     {'n_estimators': 50, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 0.85, 'gamma': 1e-08, 'eta': 1, 'features': 11}
# Trained and Tested combination 1219 of 1512000, taking 0.06 seconds to get val score of 0.4252:
#                 {'n_estimators': 50, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 0.85, 'gamma': 1e-06, 'eta': 1, 'features': 10},
#             Current best combo with val score 0.4586:
#                     {'n_estimators': 50, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 0.85, 'gamma': 1e-08, 'eta': 1, 'features': 11}
# Trained and Tested combination 1220 of 1512000, taking 0.07 seconds to get val score of 0.3408:
#                 {'n_estimators': 50, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 0.85, 'gamma': 1e-06, 'eta': 1, 'features': 12},
#             Current best combo with val score 0.4586:
#                     {'n_estimators': 50, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 0.85, 'gamma': 1e-08, 'eta': 1, 'features': 11}
# % Combos Checked Thus Far: 1220 out of 1512000 which is 0.08068800000000001%
# Max Val Score:
#  0.458556
# Max Val Score Std:
#  0.079652
# Best Combo Train Score:
#  0.74331
# Best Combo Train Score Std:
#  0.00811
# Max Combo Index:
#  (1, 0, 4, 3, 0, 4, 11) out of [6, 7, 5, 5, 5, 6, 48] (note best combo is 0-indexed)
# Max Combo Hyperparamer Combination:
#  {'n_estimators': 50, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 0.85, 'gamma': 1e-08, 'eta': 1, 'features': 11}
# Max Combo Features:
#  ('procedure_225792', 'ventilation_used', 'procedure_226475', 'lods_score', 'procedure_225802', 'hospital_stay_duration', 'procedure_224276', 'procedure_229519', 'procedure_226236', 'race_AMERICAN INDIAN/ALASKA NATIVE', 'race_ASIAN', 'race_ASIAN - ASIAN INDIAN', 'race_ASIAN - CHINESE', 'race_ASIAN - KOREAN', 'race_ASIAN - SOUTH EAST ASIAN', 'race_BLACK/AFRICAN', 'race_BLACK/AFRICAN AMERICAN', 'race_BLACK/CAPE VERDEAN', 'race_BLACK/CARIBBEAN ISLAND', 'race_HISPANIC OR LATINO', 'race_HISPANIC/LATINO - CENTRAL AMERICAN', 'race_HISPANIC/LATINO - COLUMBIAN', 'race_HISPANIC/LATINO - CUBAN', 'race_HISPANIC/LATINO - DOMINICAN', 'race_HISPANIC/LATINO - GUATEMALAN', 'race_HISPANIC/LATINO - HONDURAN', 'race_HISPANIC/LATINO - MEXICAN', 'race_HISPANIC/LATINO - PUERTO RICAN', 'race_HISPANIC/LATINO - SALVADORAN', 'race_MULTIPLE RACE/ETHNICITY', 'race_NATIVE HAWAIIAN OR OTHER PACIFIC ISLANDER', 'race_OTHER', 'race_PATIENT DECLINED TO ANSWER', 'race_PORTUGUESE', 'race_SOUTH AMERICAN', 'race_UNABLE TO OBTAIN', 'race_WHITE', 'race_WHITE - BRAZILIAN', 'race_WHITE - EASTERN EUROPEAN', 'race_WHITE - OTHER EUROPEAN', 'race_WHITE - RUSSIAN', 'race_UNKNOWN', 'oasis_score', 'procedure_224267')
# % Combos Checked: 1220 out of 1512000 which is 0.08068800000000001%
