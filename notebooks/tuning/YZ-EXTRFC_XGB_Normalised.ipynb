# %% [markdown]
# # Tuning Script

# %%
# Parameters subject to change in every script - involved in naming

MODEL = 'extrfc'
PREPROCESSING = 'normalise'
TUNER = 'yangzhoub'
OPTIMISED_METRIC = 'f1'

# %% [markdown]
# ---

# %%
# detect whether this is a google environment

COLAB_ENVIRONMENT = False

try:
    from google.colab import drive
    drive.mount('/content/drive')
    COLAB_ENVIRONMENT = True
except:
    pass
# Out:
# Mounted at /content/drive

# %%
import sys
import os
import pickle

if COLAB_ENVIRONMENT:
    home_directory = './drive/MyDrive/LAB/COMP90089__GroupWork__Py/' # my home directory is stored in ./LAB of google drive
    if MODEL == 'ebr':
        # !pip install interpret==0.5.0
    elif MODEL == 'cbr':
        # !pip install catboost
    elif MODEL in ['tf', 'mlp']:
        # !pip install PyTorch2Sklearn
    # !pip install JXAutoML
else:
    home_directory = '../../'

from JXAutoML.YangZhouB_10CV import YangZhouB_10CV as Tuner

import pandas as pd
# Out:
# Collecting JXAutoML
#   Downloading JXAutoML-0.4.4-py3-none-any.whl.metadata (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.2/67.2 kB 1.6 MB/s eta 0:00:00
# Downloading JXAutoML-0.4.4-py3-none-any.whl (52 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.1/52.1 kB 3.9 MB/s eta 0:00:00
# Installing collected packages: JXAutoML
# Successfully installed JXAutoML-0.4.4

# %%
# Parameters that are same for every script

FOLDS = 10  # we have decided to do 10 fold validation

SEED = 42

TASK_TYPE = 'Classification'  # this task is a classification task

# we have decided to tune features as hp
TUNE_FEATURES_AS_HYPERPARAMETERS = True

# %% [markdown]
# ---

# %%
# model to use to tune
from sklearn.ensemble import ExtraTreesClassifier as clf

# what values to try for each hyperparameter
parameter_choices = {
    'n_estimators': (25, 50, 100, 200, 400, 800),
    'max_depth': (3, 6, 12, 24, 48, 96, 192),
    'max_samples': (0.4, 0.55, 0.7, 0.85, 1),
    'max_features': (0.4, 0.55, 0.7, 0.85, 1),
    'ccp_alpha': (0.00000001, 0.000001, 0.0001, 0.01, 0.1)
}

# what values to set non-tuneable parameters/hyperparameters
non_tunable_hyperparameters_dict = {
                                    'random_state': SEED,
                                    'n_jobs': -1,
                                    'bootstrap': True
                                    }

# %% [markdown]
# ---

# %% [markdown]
# Read in and Prepare Data

# %%
# Import data and store as lists

train_x_list = []
train_y_list = []
val_x_list = []
val_y_list = []

for i in range(FOLDS):
    train_data = pd.read_csv(
        f'{home_directory}data/curated/modelling/{PREPROCESSING}/train_{i}.csv')
    val_data = pd.read_csv(
        f'{home_directory}data/curated/modelling/{PREPROCESSING}/val_{i}.csv')

    # get the correct rows for X and y
    train_x = train_data.drop(
        ['mortality_status', 'subject_id', 'hadm_id', 'stay_id'], axis=1)
    train_y = train_data['mortality_status']
    val_x = val_data.drop(
        ['mortality_status', 'subject_id', 'hadm_id', 'stay_id'], axis=1)
    val_y = val_data['mortality_status']

    train_x_list.append(train_x)
    train_y_list.append(train_y)
    val_x_list.append(val_x)
    val_y_list.append(val_y)

# %%
# Import feature importance ordering

with open(f'{home_directory}models/xgb_feature_importance_ordering_{PREPROCESSING}.pickle', 'rb') as f:
    feature_importance_ordering = pickle.load(f)

# %% [markdown]
# Set parameters

# %%
# initialisation
tuner = Tuner()

print('---')

# define what model we are tuning
tuner.read_in_model(clf, TASK_TYPE, optimised_metric=OPTIMISED_METRIC)

print('---')

# read in the data for training and validation
tuner.read_in_data(train_x_list, train_y_list, val_x_list, val_y_list)

print('---')

# set what hp values to tune
tuner.set_hyperparameters(parameter_choices)
# WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

# set up hp values that need to be changed from default but NOT to be tuned
tuner.set_non_tuneable_hyperparameters(non_tunable_hyperparameters_dict)

print('---')

# set up feature importance ordering

if TUNE_FEATURES_AS_HYPERPARAMETERS:
    tuner.set_features(feature_importance_ordering)
    # WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

try:  # try to read in previous results to continue tuning ...
    tuner.read_in_tuning_result_df(
        f'{home_directory}models/tuning/{TUNER}_{MODEL}_{PREPROCESSING}.csv')
except:
    print('No previous tuning data read in')

print('---')

# set up where to save the tuning result csv
tuner.set_tuning_result_saving_address(
    f'{home_directory}models/tuning/{TUNER}_{MODEL}_{PREPROCESSING}.csv')

print('---')

# set up where to save the current best model
tuner.set_best_model_saving_address(
    f'{home_directory}models/tmp_models/{TUNER}_{MODEL}_{PREPROCESSING}')
# Out:
# YangZhouB Initialised
# ---
# Successfully read in model <class 'sklearn.ensemble._forest.ExtraTreesClassifier'>, which is a Classification model optimising for f1
# ---
# Read in Train X data list
# Read in Train y data list
# Read in Val X data list
# Read in Val y data list
# ---
# Successfully recorded hyperparameter choices
# ---
# Successfully recorded non_tuneable_hyperparameter choices
# ---
# Successfully recorded tuneable feature combination choices and updated relevant internal structures
# ---
# Successfully read in tuning result of 761 rows, for 761.0 combos
# ---
# Successfully set tuning output address
# ---
# Successfully set best model output address

# %%
# ignore warnings

import warnings
warnings.filterwarnings("ignore")

# %%
# begin tuning ... (or continue training)

tuner.tune()
# Out:
# Streaming output truncated to the last 5000 lines.
#                     {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 10}
#         Has trained 761 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 0.1, 'features': 5}
#             Current best combo (with val score 0.4393):
#                     {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 10}
#         Has trained 761 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 25, 'max_depth': 3, 'max_samples': 1, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 40}
#             Current best combo (with val score 0.4393):
#                     {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 10}
#         Has trained 761 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 800, 'max_depth': 24, 'max_samples': 1, 'max_features': 0.4, 'ccp_alpha': 0.1, 'features': 15}
#             Current best combo (with val score 0.4393):
#                     {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 10}
#         Has trained 761 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 800, 'max_depth': 24, 'max_samples': 1, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 50}
#             Current best combo (with val score 0.4393):
#                     {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 10}
#         Has trained 761 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 800, 'max_depth': 24, 'max_samples': 1, 'max_features': 1, 'ccp_alpha': 0.1, 'features': 50}
#             Current best combo (with val score 0.4393):
#                     {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 10}
#         Has trained 761 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 25, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 0.1, 'features': 15}
#             Current best combo (with val score 0.4393):
#                     {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 10}
#         Has trained 761 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 25, 'max_depth': 24, 'max_samples': 1, 'max_features': 1, 'ccp_alpha': 0.1, 'features': 35}
#             Current best combo (with val score 0.4393):
#                     {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 10}
#         Has trained 761 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 25, 'max_depth': 3, 'max_samples': 1, 'max_features': 1, 'ccp_alpha': 0.1, 'features': 10}
#             Current best combo (with val score 0.4393):
#                     {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 10}
#         Has trained 761 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 800, 'max_depth': 24, 'max_samples': 1, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#             Current best combo (with val score 0.4393):
#                     {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 10}
#         Has trained 761 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 25, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 0.1, 'features': 35}
#             Current best combo (with val score 0.4393):
#                     {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 10}
#         Has trained 761 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 0.1, 'features': 15}
#             Current best combo (with val score 0.4393):
#                     {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 10}
#         Has trained 761 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 25, 'max_depth': 24, 'max_samples': 1, 'max_features': 1, 'ccp_alpha': 0.1, 'features': 45}
#             Current best combo (with val score 0.4393):
#                     {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 10}
#         Has trained 761 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 0.1, 'features': 20}
#             Current best combo (with val score 0.4393):
#                     {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 10}
#         Has trained 761 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.2671):
#             {'n_estimators': 25, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 40}
#             Current best combo (with val score 0.4393):
#                     {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 10}
#         Has trained 761 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 25, 'max_depth': 3, 'max_samples': 1, 'max_features': 0.4, 'ccp_alpha': 0.1, 'features': 0}
#             Current best combo (with val score 0.4393):
#                     {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 10}
#         Has trained 761 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.1365):
#             {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 15}
#             Current best combo (with val score 0.4393):
#                     {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 10}
#         Has trained 761 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 25, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 0.1, 'features': 45}
#             Current best combo (with val score 0.4393):
#                     {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 10}
#         Has trained 761 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 25, 'max_depth': 3, 'max_samples': 1, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 15}
#             Current best combo (with val score 0.4393):
#                     {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 10}
#         Has trained 761 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 25, 'max_depth': 24, 'max_samples': 1, 'max_features': 0.4, 'ccp_alpha': 0.1, 'features': 30}
#             Current best combo (with val score 0.4393):
#                     {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 10}
#         Has trained 761 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 0.1, 'features': 10}
#             Current best combo (with val score 0.4393):
#                     {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 10}
#         Has trained 761 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 25, 'max_depth': 192, 'max_samples': 1, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 25}
#             Current best combo (with val score 0.4393):
#                     {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 10}
#         Has trained 761 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 25, 'max_depth': 3, 'max_samples': 1, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 25}
#             Current best combo (with val score 0.4393):
#                     {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 10}
#         Has trained 761 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 800, 'max_depth': 192, 'max_samples': 1, 'max_features': 0.4, 'ccp_alpha': 0.1, 'features': 20}
#             Current best combo (with val score 0.4393):
#                     {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 10}
#         Has trained 761 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 25, 'max_depth': 24, 'max_samples': 1, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 5}
#             Current best combo (with val score 0.4393):
#                     {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 10}
#         Has trained 761 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.0094):
#             {'n_estimators': 25, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 50}
#             Current best combo (with val score 0.4393):
#                     {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 10}
#         Has trained 761 of 267750 combinations so far
# As new Best Combo (0, 6, 0, 0, 0, 10) was read in, best_clf is set to None
# Already Trained and Tested combination (val score of 0.4441):
#             {'n_estimators': 25, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 10}
#             Current best combo (with val score 0.4441):
#                     {'n_estimators': 25, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 10}
#         Has trained 761 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 25, 'max_depth': 3, 'max_samples': 1, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 10}
#             Current best combo (with val score 0.4441):
#                     {'n_estimators': 25, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 10}
#         Has trained 761 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 800, 'max_depth': 24, 'max_samples': 1, 'max_features': 0.4, 'ccp_alpha': 0.1, 'features': 5}
#             Current best combo (with val score 0.4441):
#                     {'n_estimators': 25, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 10}
#         Has trained 761 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 0.1, 'features': 30}
#             Current best combo (with val score 0.4441):
#                     {'n_estimators': 25, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 10}
#         Has trained 761 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 800, 'max_depth': 3, 'max_samples': 1, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 15}
#             Current best combo (with val score 0.4441):
#                     {'n_estimators': 25, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 10}
#         Has trained 761 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 0.1, 'features': 5}
#             Current best combo (with val score 0.4441):
#                     {'n_estimators': 25, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 10}
#         Has trained 761 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 0.1, 'features': 20}
#             Current best combo (with val score 0.4441):
#                     {'n_estimators': 25, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 10}
#         Has trained 761 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 0.1, 'features': 20}
#             Current best combo (with val score 0.4441):
#                     {'n_estimators': 25, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 10}
#         Has trained 761 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 25, 'max_depth': 3, 'max_samples': 1, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#             Current best combo (with val score 0.4441):
#                     {'n_estimators': 25, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 10}
#         Has trained 761 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.0552):
#             {'n_estimators': 25, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#             Current best combo (with val score 0.4441):
#                     {'n_estimators': 25, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 10}
#         Has trained 761 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 25, 'max_depth': 24, 'max_samples': 1, 'max_features': 0.4, 'ccp_alpha': 0.1, 'features': 0}
#             Current best combo (with val score 0.4441):
#                     {'n_estimators': 25, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 10}
#         Has trained 761 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 800, 'max_depth': 24, 'max_samples': 1, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 35}
#             Current best combo (with val score 0.4441):
#                     {'n_estimators': 25, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 10}
#         Has trained 761 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 25, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 0}
#             Current best combo (with val score 0.4441):
#                     {'n_estimators': 25, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 10}
#         Has trained 761 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 800, 'max_depth': 3, 'max_samples': 1, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 5}
#             Current best combo (with val score 0.4441):
#                     {'n_estimators': 25, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 10}
#         Has trained 761 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.2522):
#             {'n_estimators': 25, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 35}
#             Current best combo (with val score 0.4441):
#                     {'n_estimators': 25, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 10}
#         Has trained 761 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 25, 'max_depth': 192, 'max_samples': 1, 'max_features': 0.4, 'ccp_alpha': 0.1, 'features': 20}
#             Current best combo (with val score 0.4441):
#                     {'n_estimators': 25, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 10}
#         Has trained 761 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 25, 'max_depth': 24, 'max_samples': 1, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 15}
#             Current best combo (with val score 0.4441):
#                     {'n_estimators': 25, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 10}
#         Has trained 761 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 25, 'max_depth': 192, 'max_samples': 1, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 5}
#             Current best combo (with val score 0.4441):
#                     {'n_estimators': 25, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 10}
#         Has trained 761 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 0.1, 'features': 40}
#             Current best combo (with val score 0.4441):
#                     {'n_estimators': 25, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 10}
#         Has trained 761 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 800, 'max_depth': 24, 'max_samples': 1, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 5}
#             Current best combo (with val score 0.4441):
#                     {'n_estimators': 25, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 10}
#         Has trained 761 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 25, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 0.1, 'features': 15}
#             Current best combo (with val score 0.4441):
#                     {'n_estimators': 25, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 10}
#         Has trained 761 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 25, 'max_depth': 3, 'max_samples': 1, 'max_features': 0.4, 'ccp_alpha': 0.1, 'features': 40}
#             Current best combo (with val score 0.4441):
#                     {'n_estimators': 25, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 10}
#         Has trained 761 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 25, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 0.1, 'features': 40}
#             Current best combo (with val score 0.4441):
#                     {'n_estimators': 25, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 10}
#         Has trained 761 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 25, 'max_depth': 192, 'max_samples': 1, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 40}
#             Current best combo (with val score 0.4441):
#                     {'n_estimators': 25, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 10}
#         Has trained 761 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 25, 'max_depth': 3, 'max_samples': 1, 'max_features': 0.4, 'ccp_alpha': 0.1, 'features': 15}
#             Current best combo (with val score 0.4441):
#                     {'n_estimators': 25, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 10}
#         Has trained 761 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 45}
#             Current best combo (with val score 0.4441):
#                     {'n_estimators': 25, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 10}
#         Has trained 761 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 25, 'max_depth': 192, 'max_samples': 1, 'max_features': 0.4, 'ccp_alpha': 0.1, 'features': 35}
#             Current best combo (with val score 0.4441):
#                     {'n_estimators': 25, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 10}
#         Has trained 761 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 800, 'max_depth': 192, 'max_samples': 1, 'max_features': 0.4, 'ccp_alpha': 0.1, 'features': 35}
#             Current best combo (with val score 0.4441):
#                     {'n_estimators': 25, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 10}
#         Has trained 761 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 25, 'max_depth': 3, 'max_samples': 1, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 50}
#             Current best combo (with val score 0.4441):
#                     {'n_estimators': 25, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 10}
#         Has trained 761 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.0066):
#             {'n_estimators': 25, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 35}
#             Current best combo (with val score 0.4441):
#                     {'n_estimators': 25, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 10}
#         Has trained 761 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.1913):
#             {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 35}
#             Current best combo (with val score 0.4441):
#                     {'n_estimators': 25, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 10}
#         Has trained 761 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 45}
#             Current best combo (with val score 0.4441):
#                     {'n_estimators': 25, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 10}
#         Has trained 761 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 0.1, 'features': 5}
#             Current best combo (with val score 0.4441):
#                     {'n_estimators': 25, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 10}
#         Has trained 761 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.365):
#             {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 10}
#             Current best combo (with val score 0.4441):
#                     {'n_estimators': 25, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 10}
#         Has trained 761 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 25, 'max_depth': 3, 'max_samples': 1, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 5}
#             Current best combo (with val score 0.4441):
#                     {'n_estimators': 25, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 10}
#         Has trained 761 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 800, 'max_depth': 24, 'max_samples': 1, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 5}
#             Current best combo (with val score 0.4441):
#                     {'n_estimators': 25, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 10}
#         Has trained 761 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 25, 'max_depth': 24, 'max_samples': 1, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 45}
#             Current best combo (with val score 0.4441):
#                     {'n_estimators': 25, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 10}
#         Has trained 761 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 800, 'max_depth': 3, 'max_samples': 1, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 35}
#             Current best combo (with val score 0.4441):
#                     {'n_estimators': 25, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 10}
#         Has trained 761 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 25, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 0.1, 'features': 30}
#             Current best combo (with val score 0.4441):
#                     {'n_estimators': 25, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 10}
#         Has trained 761 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 0.1, 'features': 25}
#             Current best combo (with val score 0.4441):
#                     {'n_estimators': 25, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 10}
#         Has trained 761 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.1018):
#             {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 20}
#             Current best combo (with val score 0.4441):
#                     {'n_estimators': 25, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 10}
#         Has trained 761 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.2592):
#             {'n_estimators': 25, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 35}
#             Current best combo (with val score 0.4441):
#                     {'n_estimators': 25, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 10}
#         Has trained 761 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 25, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 0.1, 'features': 0}
#             Current best combo (with val score 0.4441):
#                     {'n_estimators': 25, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 10}
#         Has trained 761 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 800, 'max_depth': 24, 'max_samples': 1, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 25}
#             Current best combo (with val score 0.4441):
#                     {'n_estimators': 25, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 10}
#         Has trained 761 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 25, 'max_depth': 192, 'max_samples': 1, 'max_features': 1, 'ccp_alpha': 0.1, 'features': 25}
#             Current best combo (with val score 0.4441):
#                     {'n_estimators': 25, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 10}
#         Has trained 761 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 25, 'max_depth': 192, 'max_samples': 1, 'max_features': 0.4, 'ccp_alpha': 0.1, 'features': 30}
#             Current best combo (with val score 0.4441):
#                     {'n_estimators': 25, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 10}
#         Has trained 761 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 800, 'max_depth': 24, 'max_samples': 1, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 15}
#             Current best combo (with val score 0.4441):
#                     {'n_estimators': 25, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 10}
#         Has trained 761 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 0.1, 'features': 0}
#             Current best combo (with val score 0.4441):
#                     {'n_estimators': 25, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 10}
#         Has trained 761 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 800, 'max_depth': 24, 'max_samples': 1, 'max_features': 0.4, 'ccp_alpha': 0.1, 'features': 25}
#             Current best combo (with val score 0.4441):
#                     {'n_estimators': 25, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 10}
#         Has trained 761 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 5}
#             Current best combo (with val score 0.4441):
#                     {'n_estimators': 25, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 10}
#         Has trained 761 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 5}
#             Current best combo (with val score 0.4441):
#                     {'n_estimators': 25, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 10}
#         Has trained 761 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 800, 'max_depth': 24, 'max_samples': 1, 'max_features': 0.4, 'ccp_alpha': 0.1, 'features': 20}
#             Current best combo (with val score 0.4441):
#                     {'n_estimators': 25, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 10}
#         Has trained 761 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 0.1, 'features': 40}
#             Current best combo (with val score 0.4441):
#                     {'n_estimators': 25, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 10}
#         Has trained 761 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 800, 'max_depth': 192, 'max_samples': 1, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 50}
#             Current best combo (with val score 0.4441):
#                     {'n_estimators': 25, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 10}
#         Has trained 761 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 25, 'max_depth': 24, 'max_samples': 1, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 10}
#             Current best combo (with val score 0.4441):
#                     {'n_estimators': 25, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 10}
#         Has trained 761 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.0063):
#             {'n_estimators': 25, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 50}
#             Current best combo (with val score 0.4441):
#                     {'n_estimators': 25, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 10}
#         Has trained 761 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.3251):
#             {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 15}
#             Current best combo (with val score 0.4441):
#                     {'n_estimators': 25, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 10}
#         Has trained 761 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.0033):
#             {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 25}
#             Current best combo (with val score 0.4441):
#                     {'n_estimators': 25, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 10}
#         Has trained 761 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.0377):
#             {'n_estimators': 25, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 45}
#             Current best combo (with val score 0.4441):
#                     {'n_estimators': 25, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 10}
#         Has trained 761 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 0.1, 'features': 10}
#             Current best combo (with val score 0.4441):
#                     {'n_estimators': 25, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 10}
#         Has trained 761 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.2917):
#             {'n_estimators': 25, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 50}
#             Current best combo (with val score 0.4441):
#                     {'n_estimators': 25, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 10}
#         Has trained 761 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 800, 'max_depth': 24, 'max_samples': 1, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 15}
#             Current best combo (with val score 0.4441):
#                     {'n_estimators': 25, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 10}
#         Has trained 761 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 25, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 0}
#             Current best combo (with val score 0.4441):
#                     {'n_estimators': 25, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 10}
#         Has trained 761 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 0.1, 'features': 15}
#             Current best combo (with val score 0.4441):
#                     {'n_estimators': 25, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 10}
#         Has trained 761 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 25, 'max_depth': 24, 'max_samples': 1, 'max_features': 0.4, 'ccp_alpha': 0.1, 'features': 10}
#             Current best combo (with val score 0.4441):
#                     {'n_estimators': 25, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 10}
#         Has trained 761 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 0.1, 'features': 50}
#             Current best combo (with val score 0.4441):
#                     {'n_estimators': 25, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 10}
#         Has trained 761 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.1599):
#             {'n_estimators': 25, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 20}
#             Current best combo (with val score 0.4441):
#                     {'n_estimators': 25, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 10}
#         Has trained 761 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 800, 'max_depth': 24, 'max_samples': 1, 'max_features': 1, 'ccp_alpha': 0.1, 'features': 35}
#             Current best combo (with val score 0.4441):
#                     {'n_estimators': 25, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 10}
#         Has trained 761 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#             Current best combo (with val score 0.4441):
#                     {'n_estimators': 25, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 10}
#         Has trained 761 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.2172):
#             {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 45}
#             Current best combo (with val score 0.4441):
#                     {'n_estimators': 25, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 10}
#         Has trained 761 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 25, 'max_depth': 3, 'max_samples': 1, 'max_features': 0.4, 'ccp_alpha': 0.1, 'features': 50}
#             Current best combo (with val score 0.4441):
#                     {'n_estimators': 25, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 10}
#         Has trained 761 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 25, 'max_depth': 192, 'max_samples': 1, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#             Current best combo (with val score 0.4441):
#                     {'n_estimators': 25, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 10}
#         Has trained 761 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 800, 'max_depth': 192, 'max_samples': 1, 'max_features': 0.4, 'ccp_alpha': 0.1, 'features': 40}
#             Current best combo (with val score 0.4441):
#                     {'n_estimators': 25, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 10}
#         Has trained 761 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 0.1, 'features': 35}
#             Current best combo (with val score 0.4441):
#                     {'n_estimators': 25, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 10}
#         Has trained 761 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 25, 'max_depth': 24, 'max_samples': 1, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 0}
#             Current best combo (with val score 0.4441):
#                     {'n_estimators': 25, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 10}
#         Has trained 761 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 800, 'max_depth': 192, 'max_samples': 1, 'max_features': 1, 'ccp_alpha': 0.1, 'features': 20}
#             Current best combo (with val score 0.4441):
#                     {'n_estimators': 25, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 10}
#         Has trained 761 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 800, 'max_depth': 24, 'max_samples': 1, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 10}
#             Current best combo (with val score 0.4441):
#                     {'n_estimators': 25, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 10}
#         Has trained 761 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.2445):
#             {'n_estimators': 25, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 25}
#             Current best combo (with val score 0.4441):
#                     {'n_estimators': 25, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 10}
#         Has trained 761 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 40}
#             Current best combo (with val score 0.4441):
#                     {'n_estimators': 25, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 10}
#         Has trained 761 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 0.1, 'features': 35}
#             Current best combo (with val score 0.4441):
#                     {'n_estimators': 25, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 10}
#         Has trained 761 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 25, 'max_depth': 192, 'max_samples': 1, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 35}
#             Current best combo (with val score 0.4441):
#                     {'n_estimators': 25, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 10}
#         Has trained 761 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 25, 'max_depth': 3, 'max_samples': 1, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#             Current best combo (with val score 0.4441):
#                     {'n_estimators': 25, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 10}
#         Has trained 761 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 25, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 0}
#             Current best combo (with val score 0.4441):
#                     {'n_estimators': 25, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 10}
#         Has trained 761 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 15}
#             Current best combo (with val score 0.4441):
#                     {'n_estimators': 25, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 10}
#         Has trained 761 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 800, 'max_depth': 3, 'max_samples': 1, 'max_features': 0.4, 'ccp_alpha': 0.1, 'features': 25}
#             Current best combo (with val score 0.4441):
#                     {'n_estimators': 25, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 10}
#         Has trained 761 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.3683):
#             {'n_estimators': 25, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#             Current best combo (with val score 0.4441):
# ...
#             Current best combo (with val score 0.4707):
#                     {'n_estimators': 400, 'max_depth': 24, 'max_samples': 0.55, 'max_features': 0.55, 'ccp_alpha': 1e-08, 'features': 10}
#         Has trained 761 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.4621):
#             {'n_estimators': 200, 'max_depth': 48, 'max_samples': 0.55, 'max_features': 0.55, 'ccp_alpha': 1e-08, 'features': 10}
#             Current best combo (with val score 0.4707):
#                     {'n_estimators': 400, 'max_depth': 24, 'max_samples': 0.55, 'max_features': 0.55, 'ccp_alpha': 1e-08, 'features': 10}
#         Has trained 761 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.459):
#             {'n_estimators': 200, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.55, 'ccp_alpha': 1e-08, 'features': 10}
#             Current best combo (with val score 0.4707):
#                     {'n_estimators': 400, 'max_depth': 24, 'max_samples': 0.55, 'max_features': 0.55, 'ccp_alpha': 1e-08, 'features': 10}
#         Has trained 761 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.4551):
#             {'n_estimators': 200, 'max_depth': 24, 'max_samples': 0.7, 'max_features': 0.55, 'ccp_alpha': 1e-08, 'features': 10}
#             Current best combo (with val score 0.4707):
#                     {'n_estimators': 400, 'max_depth': 24, 'max_samples': 0.55, 'max_features': 0.55, 'ccp_alpha': 1e-08, 'features': 10}
#         Has trained 761 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.4407):
#             {'n_estimators': 200, 'max_depth': 24, 'max_samples': 0.55, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 10}
#             Current best combo (with val score 0.4707):
#                     {'n_estimators': 400, 'max_depth': 24, 'max_samples': 0.55, 'max_features': 0.55, 'ccp_alpha': 1e-08, 'features': 10}
#         Has trained 761 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.468):
#             {'n_estimators': 200, 'max_depth': 24, 'max_samples': 0.55, 'max_features': 0.7, 'ccp_alpha': 1e-08, 'features': 10}
#             Current best combo (with val score 0.4707):
#                     {'n_estimators': 400, 'max_depth': 24, 'max_samples': 0.55, 'max_features': 0.55, 'ccp_alpha': 1e-08, 'features': 10}
#         Has trained 761 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.4669):
#             {'n_estimators': 200, 'max_depth': 24, 'max_samples': 0.55, 'max_features': 0.55, 'ccp_alpha': 1e-06, 'features': 10}
#             Current best combo (with val score 0.4707):
#                     {'n_estimators': 400, 'max_depth': 24, 'max_samples': 0.55, 'max_features': 0.55, 'ccp_alpha': 1e-08, 'features': 10}
#         Has trained 761 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.4534):
#             {'n_estimators': 200, 'max_depth': 24, 'max_samples': 0.55, 'max_features': 0.55, 'ccp_alpha': 1e-08, 'features': 9}
#             Current best combo (with val score 0.4707):
#                     {'n_estimators': 400, 'max_depth': 24, 'max_samples': 0.55, 'max_features': 0.55, 'ccp_alpha': 1e-08, 'features': 10}
#         Has trained 761 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.3002):
#             {'n_estimators': 200, 'max_depth': 24, 'max_samples': 0.55, 'max_features': 0.55, 'ccp_alpha': 1e-08, 'features': 11}
#             Current best combo (with val score 0.4707):
#                     {'n_estimators': 400, 'max_depth': 24, 'max_samples': 0.55, 'max_features': 0.55, 'ccp_alpha': 1e-08, 'features': 10}
#         Has trained 761 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.4621):
#             {'n_estimators': 200, 'max_depth': 48, 'max_samples': 0.55, 'max_features': 0.55, 'ccp_alpha': 1e-08, 'features': 10}
#             Current best combo (with val score 0.4707):
#                     {'n_estimators': 400, 'max_depth': 24, 'max_samples': 0.55, 'max_features': 0.55, 'ccp_alpha': 1e-08, 'features': 10}
#         Has trained 761 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.4616):
#             {'n_estimators': 800, 'max_depth': 48, 'max_samples': 0.55, 'max_features': 0.55, 'ccp_alpha': 1e-08, 'features': 10}
#             Current best combo (with val score 0.4707):
#                     {'n_estimators': 400, 'max_depth': 24, 'max_samples': 0.55, 'max_features': 0.55, 'ccp_alpha': 1e-08, 'features': 10}
#         Has trained 761 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.4707):
#             {'n_estimators': 400, 'max_depth': 24, 'max_samples': 0.55, 'max_features': 0.55, 'ccp_alpha': 1e-08, 'features': 10}
#             Current best combo (with val score 0.4707):
#                     {'n_estimators': 400, 'max_depth': 24, 'max_samples': 0.55, 'max_features': 0.55, 'ccp_alpha': 1e-08, 'features': 10}
#         Has trained 761 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.4674):
#             {'n_estimators': 400, 'max_depth': 96, 'max_samples': 0.55, 'max_features': 0.55, 'ccp_alpha': 1e-08, 'features': 10}
#             Current best combo (with val score 0.4707):
#                     {'n_estimators': 400, 'max_depth': 24, 'max_samples': 0.55, 'max_features': 0.55, 'ccp_alpha': 1e-08, 'features': 10}
#         Has trained 761 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.4586):
#             {'n_estimators': 400, 'max_depth': 48, 'max_samples': 0.4, 'max_features': 0.55, 'ccp_alpha': 1e-08, 'features': 10}
#             Current best combo (with val score 0.4707):
#                     {'n_estimators': 400, 'max_depth': 24, 'max_samples': 0.55, 'max_features': 0.55, 'ccp_alpha': 1e-08, 'features': 10}
#         Has trained 761 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.4457):
#             {'n_estimators': 400, 'max_depth': 48, 'max_samples': 0.7, 'max_features': 0.55, 'ccp_alpha': 1e-08, 'features': 10}
#             Current best combo (with val score 0.4707):
#                     {'n_estimators': 400, 'max_depth': 24, 'max_samples': 0.55, 'max_features': 0.55, 'ccp_alpha': 1e-08, 'features': 10}
#         Has trained 761 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.4515):
#             {'n_estimators': 400, 'max_depth': 48, 'max_samples': 0.55, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 10}
#             Current best combo (with val score 0.4707):
#                     {'n_estimators': 400, 'max_depth': 24, 'max_samples': 0.55, 'max_features': 0.55, 'ccp_alpha': 1e-08, 'features': 10}
#         Has trained 761 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.4676):
#             {'n_estimators': 400, 'max_depth': 48, 'max_samples': 0.55, 'max_features': 0.7, 'ccp_alpha': 1e-08, 'features': 10}
#             Current best combo (with val score 0.4707):
#                     {'n_estimators': 400, 'max_depth': 24, 'max_samples': 0.55, 'max_features': 0.55, 'ccp_alpha': 1e-08, 'features': 10}
#         Has trained 761 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.4674):
#             {'n_estimators': 400, 'max_depth': 48, 'max_samples': 0.55, 'max_features': 0.55, 'ccp_alpha': 1e-06, 'features': 10}
#             Current best combo (with val score 0.4707):
#                     {'n_estimators': 400, 'max_depth': 24, 'max_samples': 0.55, 'max_features': 0.55, 'ccp_alpha': 1e-08, 'features': 10}
#         Has trained 761 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.4594):
#             {'n_estimators': 400, 'max_depth': 48, 'max_samples': 0.55, 'max_features': 0.55, 'ccp_alpha': 1e-08, 'features': 9}
#             Current best combo (with val score 0.4707):
#                     {'n_estimators': 400, 'max_depth': 24, 'max_samples': 0.55, 'max_features': 0.55, 'ccp_alpha': 1e-08, 'features': 10}
#         Has trained 761 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.3096):
#             {'n_estimators': 400, 'max_depth': 48, 'max_samples': 0.55, 'max_features': 0.55, 'ccp_alpha': 1e-08, 'features': 11}
#             Current best combo (with val score 0.4707):
#                     {'n_estimators': 400, 'max_depth': 24, 'max_samples': 0.55, 'max_features': 0.55, 'ccp_alpha': 1e-08, 'features': 10}
#         Has trained 761 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.4669):
#             {'n_estimators': 200, 'max_depth': 24, 'max_samples': 0.55, 'max_features': 0.55, 'ccp_alpha': 1e-06, 'features': 10}
#             Current best combo (with val score 0.4707):
#                     {'n_estimators': 400, 'max_depth': 24, 'max_samples': 0.55, 'max_features': 0.55, 'ccp_alpha': 1e-08, 'features': 10}
#         Has trained 761 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.4695):
#             {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.55, 'max_features': 0.55, 'ccp_alpha': 1e-06, 'features': 10}
#             Current best combo (with val score 0.4707):
#                     {'n_estimators': 400, 'max_depth': 24, 'max_samples': 0.55, 'max_features': 0.55, 'ccp_alpha': 1e-08, 'features': 10}
#         Has trained 761 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.4273):
#             {'n_estimators': 400, 'max_depth': 12, 'max_samples': 0.55, 'max_features': 0.55, 'ccp_alpha': 1e-06, 'features': 10}
#             Current best combo (with val score 0.4707):
#                     {'n_estimators': 400, 'max_depth': 24, 'max_samples': 0.55, 'max_features': 0.55, 'ccp_alpha': 1e-08, 'features': 10}
#         Has trained 761 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.4674):
#             {'n_estimators': 400, 'max_depth': 48, 'max_samples': 0.55, 'max_features': 0.55, 'ccp_alpha': 1e-06, 'features': 10}
#             Current best combo (with val score 0.4707):
#                     {'n_estimators': 400, 'max_depth': 24, 'max_samples': 0.55, 'max_features': 0.55, 'ccp_alpha': 1e-08, 'features': 10}
#         Has trained 761 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.463):
#             {'n_estimators': 400, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.55, 'ccp_alpha': 1e-06, 'features': 10}
#             Current best combo (with val score 0.4707):
#                     {'n_estimators': 400, 'max_depth': 24, 'max_samples': 0.55, 'max_features': 0.55, 'ccp_alpha': 1e-08, 'features': 10}
#         Has trained 761 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.4506):
#             {'n_estimators': 400, 'max_depth': 24, 'max_samples': 0.7, 'max_features': 0.55, 'ccp_alpha': 1e-06, 'features': 10}
#             Current best combo (with val score 0.4707):
#                     {'n_estimators': 400, 'max_depth': 24, 'max_samples': 0.55, 'max_features': 0.55, 'ccp_alpha': 1e-08, 'features': 10}
#         Has trained 761 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.4482):
#             {'n_estimators': 400, 'max_depth': 24, 'max_samples': 0.55, 'max_features': 0.4, 'ccp_alpha': 1e-06, 'features': 10}
#             Current best combo (with val score 0.4707):
#                     {'n_estimators': 400, 'max_depth': 24, 'max_samples': 0.55, 'max_features': 0.55, 'ccp_alpha': 1e-08, 'features': 10}
#         Has trained 761 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.4644):
#             {'n_estimators': 400, 'max_depth': 24, 'max_samples': 0.55, 'max_features': 0.7, 'ccp_alpha': 1e-06, 'features': 10}
#             Current best combo (with val score 0.4707):
#                     {'n_estimators': 400, 'max_depth': 24, 'max_samples': 0.55, 'max_features': 0.55, 'ccp_alpha': 1e-08, 'features': 10}
#         Has trained 761 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.4707):
#             {'n_estimators': 400, 'max_depth': 24, 'max_samples': 0.55, 'max_features': 0.55, 'ccp_alpha': 1e-08, 'features': 10}
#             Current best combo (with val score 0.4707):
#                     {'n_estimators': 400, 'max_depth': 24, 'max_samples': 0.55, 'max_features': 0.55, 'ccp_alpha': 1e-08, 'features': 10}
#         Has trained 761 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.4707):
#             {'n_estimators': 400, 'max_depth': 24, 'max_samples': 0.55, 'max_features': 0.55, 'ccp_alpha': 0.0001, 'features': 10}
#             Current best combo (with val score 0.4707):
#                     {'n_estimators': 400, 'max_depth': 24, 'max_samples': 0.55, 'max_features': 0.55, 'ccp_alpha': 1e-08, 'features': 10}
#         Has trained 761 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.4611):
#             {'n_estimators': 400, 'max_depth': 24, 'max_samples': 0.55, 'max_features': 0.55, 'ccp_alpha': 1e-06, 'features': 9}
#             Current best combo (with val score 0.4707):
#                     {'n_estimators': 400, 'max_depth': 24, 'max_samples': 0.55, 'max_features': 0.55, 'ccp_alpha': 1e-08, 'features': 10}
#         Has trained 761 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.3054):
#             {'n_estimators': 400, 'max_depth': 24, 'max_samples': 0.55, 'max_features': 0.55, 'ccp_alpha': 1e-06, 'features': 11}
#             Current best combo (with val score 0.4707):
#                     {'n_estimators': 400, 'max_depth': 24, 'max_samples': 0.55, 'max_features': 0.55, 'ccp_alpha': 1e-08, 'features': 10}
#         Has trained 761 of 267750 combinations so far
# % Combos Checked Thus Far: 761 out of 267750 which is 0.28422000000000003%
# Max Val Score:
#  0.470686
# Max Val Score Std:
#  0.062218
# Best Combo Train Score:
#  0.872337
# Best Combo Train Score Std:
#  0.00824
# Max Combo Index:
#  (4, 3, 1, 1, 0, 10) out of [6, 7, 5, 5, 5, 51] (note best combo is 0-indexed)
# Max Combo Hyperparamer Combination:
#  {'n_estimators': 400, 'max_depth': 24, 'max_samples': 0.55, 'max_features': 0.55, 'ccp_alpha': 1e-08, 'features': 10}
# Max Combo Features:
#  ('procedure_225792', 'ventilation_used', 'lods_score', 'race_AMERICAN INDIAN/ALASKA NATIVE', 'race_ASIAN', 'race_ASIAN - ASIAN INDIAN', 'race_ASIAN - CHINESE', 'race_ASIAN - KOREAN', 'race_ASIAN - SOUTH EAST ASIAN', 'race_BLACK/AFRICAN', 'race_BLACK/AFRICAN AMERICAN', 'race_BLACK/CAPE VERDEAN', 'race_BLACK/CARIBBEAN ISLAND', 'race_HISPANIC/LATINO - CENTRAL AMERICAN', 'race_HISPANIC/LATINO - COLUMBIAN', 'race_HISPANIC/LATINO - CUBAN', 'race_HISPANIC/LATINO - DOMINICAN', 'race_HISPANIC/LATINO - GUATEMALAN', 'race_HISPANIC/LATINO - HONDURAN', 'race_HISPANIC/LATINO - MEXICAN', 'race_HISPANIC/LATINO - PUERTO RICAN', 'race_HISPANIC/LATINO - SALVADORAN', 'race_MULTIPLE RACE/ETHNICITY', 'race_NATIVE HAWAIIAN OR OTHER PACIFIC ISLANDER', 'race_OTHER', 'race_PATIENT DECLINED TO ANSWER', 'race_PORTUGUESE', 'race_SOUTH AMERICAN', 'race_UNABLE TO OBTAIN', 'race_UNKNOWN', 'race_WHITE', 'race_WHITE - BRAZILIAN', 'race_WHITE - EASTERN EUROPEAN', 'race_WHITE - OTHER EUROPEAN', 'race_WHITE - RUSSIAN', 'race_HISPANIC OR LATINO', 'marital_status_DIVORCED', 'marital_status_MARRIED', 'marital_status_SINGLE', 'marital_status_WIDOWED', 'marital_status_0', 'hospital_stay_duration', 'procedure_225464', 'procedure_225802', 'procedure_227712', 'admission_type_DIRECT EMER.', 'admission_type_DIRECT OBSERVATION', 'admission_type_ELECTIVE', 'admission_type_EU OBSERVATION', 'admission_type_EW EMER.', 'admission_type_OBSERVATION ADMIT', 'admission_type_URGENT', 'admission_type_SURGICAL SAME DAY ADMISSION', 'procedure_225446')
# % Combos Checked: 761 out of 267750 which is 0.28422000000000003%
