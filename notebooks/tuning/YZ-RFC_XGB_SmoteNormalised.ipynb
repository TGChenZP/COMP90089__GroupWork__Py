# %% [markdown]
# # Tuning Script

# %%
# Parameters subject to change in every script - involved in naming

MODEL = 'rfc'
PREPROCESSING = 'smote_normalise'
TUNER = 'yangzhoub'
OPTIMISED_METRIC = 'f1'

# %% [markdown]
# ---

# %%
# detect whether this is a google environment

COLAB_ENVIRONMENT = False

try:
    from google.colab import drive
    drive.mount('/content/drive')
    COLAB_ENVIRONMENT = True
except:
    pass
# Out:
# Mounted at /content/drive

# %%
import sys
import os
import pickle

if COLAB_ENVIRONMENT:
    home_directory = './drive/MyDrive/LAB/COMP90089__GroupWork__Py/' # my home directory is stored in ./LAB of google drive
    if MODEL == 'ebr':
        # !pip install interpret==0.5.0
    elif MODEL == 'cbr':
        # !pip install catboost
    elif MODEL in ['tf', 'mlp']:
        # !pip install PyTorch2Sklearn
    # !pip install JXAutoML
else:
    home_directory = '../../'

from JXAutoML.YangZhouB_10CV import YangZhouB_10CV as Tuner

import pandas as pd
# Out:
# Collecting JXAutoML
#   Downloading JXAutoML-0.4.4-py3-none-any.whl.metadata (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.2/67.2 kB 2.2 MB/s eta 0:00:00
# Downloading JXAutoML-0.4.4-py3-none-any.whl (52 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.1/52.1 kB 3.9 MB/s eta 0:00:00
# Installing collected packages: JXAutoML
# Successfully installed JXAutoML-0.4.4

# %%
# Parameters that are same for every script

FOLDS = 10  # we have decided to do 10 fold validation

SEED = 42

TASK_TYPE = 'Classification'  # this task is a classification task

# we have decided to tune features as hp
TUNE_FEATURES_AS_HYPERPARAMETERS = True

# %% [markdown]
# ---

# %%
# model to use to tune
from sklearn.ensemble import RandomForestClassifier as clf

# what values to try for each hyperparameter
parameter_choices = {
    'n_estimators': (25, 50, 100, 200, 400, 800),
    'max_depth': (3, 6, 12, 24, 48, 96, 192),
    'max_samples': (0.4, 0.55, 0.7, 0.85, 1),
    'max_features': (0.4, 0.55, 0.7, 0.85, 1),
    'ccp_alpha': (0.00000001, 0.000001, 0.0001, 0.01, 0.1)
}

# what values to set non-tuneable parameters/hyperparameters
non_tunable_hyperparameters_dict = {
    'random_state': SEED,
    'n_jobs': -1
}

# %% [markdown]
# ---

# %% [markdown]
# Read in and Prepare Data

# %%
# Import data and store as lists

train_x_list = []
train_y_list = []
val_x_list = []
val_y_list = []

for i in range(FOLDS):
    train_data = pd.read_csv(
        f'{home_directory}data/curated/modelling/{PREPROCESSING}/train_{i}.csv')
    val_data = pd.read_csv(
        f'{home_directory}data/curated/modelling/{PREPROCESSING}/val_{i}.csv')

    # get the correct rows for X and y
    train_x = train_data.drop(
        ['mortality_status', 'subject_id', 'hadm_id', 'stay_id'], axis=1)
    train_y = train_data['mortality_status']
    val_x = val_data.drop(
        ['mortality_status', 'subject_id', 'hadm_id', 'stay_id'], axis=1)
    val_y = val_data['mortality_status']

    train_x_list.append(train_x)
    train_y_list.append(train_y)
    val_x_list.append(val_x)
    val_y_list.append(val_y)

# %%
# Import feature importance ordering

with open(f'{home_directory}models/xgb_feature_importance_ordering_{PREPROCESSING}.pickle', 'rb') as f:
    feature_importance_ordering = pickle.load(f)

# %% [markdown]
# Set parameters

# %%
# initialisation
tuner = Tuner()

print('---')

# define what model we are tuning
tuner.read_in_model(clf, TASK_TYPE, optimised_metric=OPTIMISED_METRIC)

print('---')

# read in the data for training and validation
tuner.read_in_data(train_x_list, train_y_list, val_x_list, val_y_list)

print('---')

# set what hp values to tune
tuner.set_hyperparameters(parameter_choices)
# WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

# set up hp values that need to be changed from default but NOT to be tuned
tuner.set_non_tuneable_hyperparameters(non_tunable_hyperparameters_dict)

print('---')

# set up feature importance ordering

if TUNE_FEATURES_AS_HYPERPARAMETERS:
    tuner.set_features(feature_importance_ordering)
    # WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

try:  # try to read in previous results to continue tuning ...
    tuner.read_in_tuning_result_df(
        f'{home_directory}models/tuning/{TUNER}_{MODEL}_{PREPROCESSING}.csv')
except:
    print('No previous tuning data read in')

print('---')

# set up where to save the tuning result csv
tuner.set_tuning_result_saving_address(
    f'{home_directory}models/tuning/{TUNER}_{MODEL}_{PREPROCESSING}.csv')

print('---')

# set up where to save the current best model
tuner.set_best_model_saving_address(
    f'{home_directory}models/tmp_models/{TUNER}_{MODEL}_{PREPROCESSING}')
# Out:
# YangZhouB Initialised
# ---
# Successfully read in model <class 'sklearn.ensemble._forest.RandomForestClassifier'>, which is a Classification model optimising for f1
# ---
# Read in Train X data list
# Read in Train y data list
# Read in Val X data list
# Read in Val y data list
# ---
# Successfully recorded hyperparameter choices
# ---
# Successfully recorded non_tuneable_hyperparameter choices
# ---
# Successfully recorded tuneable feature combination choices and updated relevant internal structures
# ---
# Successfully read in tuning result of 563 rows, for 563.0 combos
# ---
# Successfully set tuning output address
# ---
# Successfully set best model output address

# %%
# ignore warnings

import warnings
warnings.filterwarnings("ignore")

# %%
# begin tuning ... (or continue training)

tuner.tune()
# Out:
# Streaming output truncated to the last 5000 lines.
#                 {'n_estimators': 25, 'max_depth': 12, 'max_samples': 0.55, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 0},
#             Current best combo with val score 0.4371:
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 20}
# Trained and Tested combination 793 of 252000, taking 0.08 seconds to get val score of 0.3108:
#                 {'n_estimators': 25, 'max_depth': 12, 'max_samples': 0.4, 'max_features': 0.55, 'ccp_alpha': 1e-08, 'features': 0},
#             Current best combo with val score 0.4371:
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 20}
# Trained and Tested combination 794 of 252000, taking 0.08 seconds to get val score of 0.3108:
#                 {'n_estimators': 25, 'max_depth': 12, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-06, 'features': 0},
#             Current best combo with val score 0.4371:
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 20}
# Trained and Tested combination 795 of 252000, taking 0.09 seconds to get val score of 0.4233:
#                 {'n_estimators': 25, 'max_depth': 12, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 1},
#             Current best combo with val score 0.4371:
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 20}
# Already Trained and Tested combination (val score of 0.3108):
#             {'n_estimators': 50, 'max_depth': 24, 'max_samples': 0.55, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 0}
#             Current best combo (with val score 0.4371):
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 795 of 252000 combinations so far
# Already Trained and Tested combination (val score of 0.3108):
#             {'n_estimators': 25, 'max_depth': 12, 'max_samples': 0.55, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 0}
#             Current best combo (with val score 0.4371):
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 795 of 252000 combinations so far
# Trained and Tested combination 796 of 252000, taking 0.08 seconds to get val score of 0.3108:
#                 {'n_estimators': 25, 'max_depth': 48, 'max_samples': 0.55, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 0},
#             Current best combo with val score 0.4371:
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 20}
# Already Trained and Tested combination (val score of 0.3108):
#             {'n_estimators': 25, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 0}
#             Current best combo (with val score 0.4371):
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 796 of 252000 combinations so far
# Trained and Tested combination 797 of 252000, taking 0.09 seconds to get val score of 0.3108:
#                 {'n_estimators': 25, 'max_depth': 24, 'max_samples': 0.7, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 0},
#             Current best combo with val score 0.4371:
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 20}
# Trained and Tested combination 798 of 252000, taking 0.1 seconds to get val score of 0.3108:
#                 {'n_estimators': 25, 'max_depth': 24, 'max_samples': 0.55, 'max_features': 0.55, 'ccp_alpha': 1e-08, 'features': 0},
#             Current best combo with val score 0.4371:
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 20}
# Trained and Tested combination 799 of 252000, taking 0.07 seconds to get val score of 0.3108:
#                 {'n_estimators': 25, 'max_depth': 24, 'max_samples': 0.55, 'max_features': 0.4, 'ccp_alpha': 1e-06, 'features': 0},
#             Current best combo with val score 0.4371:
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 20}
# Trained and Tested combination 800 of 252000, taking 0.1 seconds to get val score of 0.4258:
#                 {'n_estimators': 25, 'max_depth': 24, 'max_samples': 0.55, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 1},
#             Current best combo with val score 0.4371:
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 20}
# Already Trained and Tested combination (val score of 0.3108):
#             {'n_estimators': 50, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.55, 'ccp_alpha': 1e-08, 'features': 0}
#             Current best combo (with val score 0.4371):
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 800 of 252000 combinations so far
# Already Trained and Tested combination (val score of 0.3108):
#             {'n_estimators': 25, 'max_depth': 12, 'max_samples': 0.4, 'max_features': 0.55, 'ccp_alpha': 1e-08, 'features': 0}
#             Current best combo (with val score 0.4371):
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 800 of 252000 combinations so far
# Trained and Tested combination 801 of 252000, taking 0.08 seconds to get val score of 0.3108:
#                 {'n_estimators': 25, 'max_depth': 48, 'max_samples': 0.4, 'max_features': 0.55, 'ccp_alpha': 1e-08, 'features': 0},
#             Current best combo with val score 0.4371:
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 20}
# Already Trained and Tested combination (val score of 0.3108):
#             {'n_estimators': 25, 'max_depth': 24, 'max_samples': 0.55, 'max_features': 0.55, 'ccp_alpha': 1e-08, 'features': 0}
#             Current best combo (with val score 0.4371):
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 801 of 252000 combinations so far
# Already Trained and Tested combination (val score of 0.3108):
#             {'n_estimators': 25, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 0}
#             Current best combo (with val score 0.4371):
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 801 of 252000 combinations so far
# Trained and Tested combination 802 of 252000, taking 0.08 seconds to get val score of 0.3108:
#                 {'n_estimators': 25, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.7, 'ccp_alpha': 1e-08, 'features': 0},
#             Current best combo with val score 0.4371:
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 20}
# Trained and Tested combination 803 of 252000, taking 0.08 seconds to get val score of 0.3108:
#                 {'n_estimators': 25, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.55, 'ccp_alpha': 1e-06, 'features': 0},
#             Current best combo with val score 0.4371:
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 20}
# Trained and Tested combination 804 of 252000, taking 0.08 seconds to get val score of 0.4233:
#                 {'n_estimators': 25, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.55, 'ccp_alpha': 1e-08, 'features': 1},
#             Current best combo with val score 0.4371:
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 20}
# Already Trained and Tested combination (val score of 0.3108):
#             {'n_estimators': 50, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-06, 'features': 0}
#             Current best combo (with val score 0.4371):
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 804 of 252000 combinations so far
# Already Trained and Tested combination (val score of 0.3108):
#             {'n_estimators': 25, 'max_depth': 12, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-06, 'features': 0}
#             Current best combo (with val score 0.4371):
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 804 of 252000 combinations so far
# Trained and Tested combination 805 of 252000, taking 0.1 seconds to get val score of 0.3108:
#                 {'n_estimators': 25, 'max_depth': 48, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-06, 'features': 0},
#             Current best combo with val score 0.4371:
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 20}
# Already Trained and Tested combination (val score of 0.3108):
#             {'n_estimators': 25, 'max_depth': 24, 'max_samples': 0.55, 'max_features': 0.4, 'ccp_alpha': 1e-06, 'features': 0}
#             Current best combo (with val score 0.4371):
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 805 of 252000 combinations so far
# Already Trained and Tested combination (val score of 0.3108):
#             {'n_estimators': 25, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.55, 'ccp_alpha': 1e-06, 'features': 0}
#             Current best combo (with val score 0.4371):
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 805 of 252000 combinations so far
# Already Trained and Tested combination (val score of 0.3108):
#             {'n_estimators': 25, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 0}
#             Current best combo (with val score 0.4371):
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 805 of 252000 combinations so far
# Trained and Tested combination 806 of 252000, taking 0.11 seconds to get val score of 0.3108:
#                 {'n_estimators': 25, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 0.0001, 'features': 0},
#             Current best combo with val score 0.4371:
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 20}
# Trained and Tested combination 807 of 252000, taking 0.09 seconds to get val score of 0.4233:
#                 {'n_estimators': 25, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-06, 'features': 1},
#             Current best combo with val score 0.4371:
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 20}
# Already Trained and Tested combination (val score of 0.422):
#             {'n_estimators': 50, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 1}
#             Current best combo (with val score 0.4371):
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 807 of 252000 combinations so far
# Already Trained and Tested combination (val score of 0.4233):
#             {'n_estimators': 25, 'max_depth': 12, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 1}
#             Current best combo (with val score 0.4371):
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 807 of 252000 combinations so far
# Trained and Tested combination 808 of 252000, taking 0.08 seconds to get val score of 0.4233:
#                 {'n_estimators': 25, 'max_depth': 48, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 1},
#             Current best combo with val score 0.4371:
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 20}
# Already Trained and Tested combination (val score of 0.4258):
#             {'n_estimators': 25, 'max_depth': 24, 'max_samples': 0.55, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 1}
#             Current best combo (with val score 0.4371):
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 808 of 252000 combinations so far
# Already Trained and Tested combination (val score of 0.4233):
#             {'n_estimators': 25, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.55, 'ccp_alpha': 1e-08, 'features': 1}
#             Current best combo (with val score 0.4371):
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 808 of 252000 combinations so far
# Already Trained and Tested combination (val score of 0.4233):
#             {'n_estimators': 25, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-06, 'features': 1}
#             Current best combo (with val score 0.4371):
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 808 of 252000 combinations so far
# Already Trained and Tested combination (val score of 0.3108):
#             {'n_estimators': 25, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 0}
#             Current best combo (with val score 0.4371):
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 808 of 252000 combinations so far
# Trained and Tested combination 809 of 252000, taking 0.09 seconds to get val score of 0.4144:
#                 {'n_estimators': 25, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 2},
#             Current best combo with val score 0.4371:
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 20}
# % Combos Checked Thus Far: 809 out of 252000 which is 0.321032%
# Cruising Coordrdinate 147 of 528
#
# Cruising Coordrdinate 148 of 528
#
# Cruise suspended due to suspicious case
# Guidance: round 9
#
# 	round 9 iteration:  0
#
# Trained and Tested combination 810 of 252000, taking 1.02 seconds to get val score of 0.3108:
#                 {'n_estimators': 400, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 0},
#             Current best combo with val score 0.4371:
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 20}
# Already Trained and Tested combination (val score of 0.3108):
#             {'n_estimators': 800, 'max_depth': 6, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 0}
#             Current best combo (with val score 0.4371):
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 810 of 252000 combinations so far
# Trained and Tested combination 811 of 252000, taking 2.04 seconds to get val score of 0.3108:
#                 {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 0},
#             Current best combo with val score 0.4371:
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 20}
# Trained and Tested combination 812 of 252000, taking 2.38 seconds to get val score of 0.3108:
#                 {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 0.85, 'ccp_alpha': 1e-08, 'features': 0},
#             Current best combo with val score 0.4371:
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 20}
# Trained and Tested combination 813 of 252000, taking 2.76 seconds to get val score of 0.3108:
#                 {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-06, 'features': 0},
#             Current best combo with val score 0.4371:
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 20}
# Trained and Tested combination 814 of 252000, taking 2.9 seconds to get val score of 0.1172:
#                 {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 1},
#             Current best combo with val score 0.4371:
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 20}
# 	round 9 iteration:  1
#
# Trained and Tested combination 815 of 252000, taking 0.53 seconds to get val score of 0.3108:
#                 {'n_estimators': 200, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 0},
#             Current best combo with val score 0.4371:
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 20}
# Already Trained and Tested combination (val score of 0.3108):
#             {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 0}
#             Current best combo (with val score 0.4371):
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 815 of 252000 combinations so far
# Trained and Tested combination 816 of 252000, taking 1.03 seconds to get val score of 0.3108:
#                 {'n_estimators': 400, 'max_depth': 6, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 0},
#             Current best combo with val score 0.4371:
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 20}
# Trained and Tested combination 817 of 252000, taking 1.01 seconds to get val score of 0.3108:
#                 {'n_estimators': 400, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 0},
#             Current best combo with val score 0.4371:
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 20}
# Trained and Tested combination 818 of 252000, taking 1.0 seconds to get val score of 0.3108:
#                 {'n_estimators': 400, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 0.85, 'ccp_alpha': 1e-08, 'features': 0},
#             Current best combo with val score 0.4371:
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 20}
# Trained and Tested combination 819 of 252000, taking 1.03 seconds to get val score of 0.3108:
#                 {'n_estimators': 400, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-06, 'features': 0},
#             Current best combo with val score 0.4371:
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 20}
# Trained and Tested combination 820 of 252000, taking 1.1 seconds to get val score of 0.1016:
#                 {'n_estimators': 400, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 1},
#             Current best combo with val score 0.4371:
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 20}
# Already Trained and Tested combination (val score of 0.3108):
#             {'n_estimators': 400, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 0}
#             Current best combo (with val score 0.4371):
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 820 of 252000 combinations so far
# Trained and Tested combination 821 of 252000, taking 2.19 seconds to get val score of 0.3108:
#                 {'n_estimators': 800, 'max_depth': 6, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 0},
#             Current best combo with val score 0.4371:
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 20}
# Already Trained and Tested combination (val score of 0.3108):
#             {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 0}
#             Current best combo (with val score 0.4371):
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 821 of 252000 combinations so far
# Trained and Tested combination 822 of 252000, taking 2.07 seconds to get val score of 0.3108:
#                 {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.7, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 0},
#             Current best combo with val score 0.4371:
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 20}
# Trained and Tested combination 823 of 252000, taking 2.08 seconds to get val score of 0.3108:
#                 {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 0.85, 'ccp_alpha': 1e-08, 'features': 0},
#             Current best combo with val score 0.4371:
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 20}
# Trained and Tested combination 824 of 252000, taking 2.09 seconds to get val score of 0.3108:
#                 {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-06, 'features': 0},
#             Current best combo with val score 0.4371:
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 20}
# Trained and Tested combination 825 of 252000, taking 2.11 seconds to get val score of 0.1203:
#                 {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 1},
#             Current best combo with val score 0.4371:
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 20}
# Already Trained and Tested combination (val score of 0.3108):
#             {'n_estimators': 400, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 0.85, 'ccp_alpha': 1e-08, 'features': 0}
#             Current best combo (with val score 0.4371):
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 825 of 252000 combinations so far
# Trained and Tested combination 826 of 252000, taking 2.07 seconds to get val score of 0.3108:
#                 {'n_estimators': 800, 'max_depth': 6, 'max_samples': 0.4, 'max_features': 0.85, 'ccp_alpha': 1e-08, 'features': 0},
#             Current best combo with val score 0.4371:
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 20}
# Already Trained and Tested combination (val score of 0.3108):
#             {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 0.85, 'ccp_alpha': 1e-08, 'features': 0}
#             Current best combo (with val score 0.4371):
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 826 of 252000 combinations so far
# Already Trained and Tested combination (val score of 0.3108):
#             {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 0.7, 'ccp_alpha': 1e-08, 'features': 0}
#             Current best combo (with val score 0.4371):
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 826 of 252000 combinations so far
# Already Trained and Tested combination (val score of 0.3108):
#             {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 0}
#             Current best combo (with val score 0.4371):
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 826 of 252000 combinations so far
# Trained and Tested combination 827 of 252000, taking 2.07 seconds to get val score of 0.3108:
#                 {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 0.85, 'ccp_alpha': 1e-06, 'features': 0},
#             Current best combo with val score 0.4371:
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 20}
# Trained and Tested combination 828 of 252000, taking 2.11 seconds to get val score of 0.1172:
#                 {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 0.85, 'ccp_alpha': 1e-08, 'features': 1},
#             Current best combo with val score 0.4371:
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 20}
# Already Trained and Tested combination (val score of 0.3108):
#             {'n_estimators': 400, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-06, 'features': 0}
#             Current best combo (with val score 0.4371):
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 828 of 252000 combinations so far
# Trained and Tested combination 829 of 252000, taking 2.49 seconds to get val score of 0.3108:
#                 {'n_estimators': 800, 'max_depth': 6, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-06, 'features': 0},
#             Current best combo with val score 0.4371:
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 20}
# Already Trained and Tested combination (val score of 0.3108):
#             {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-06, 'features': 0}
#             Current best combo (with val score 0.4371):
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 829 of 252000 combinations so far
# Already Trained and Tested combination (val score of 0.3108):
#             {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 0.85, 'ccp_alpha': 1e-06, 'features': 0}
#             Current best combo (with val score 0.4371):
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 829 of 252000 combinations so far
# Already Trained and Tested combination (val score of 0.3108):
#             {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 0}
#             Current best combo (with val score 0.4371):
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 829 of 252000 combinations so far
# Trained and Tested combination 830 of 252000, taking 2.67 seconds to get val score of 0.3108:
#                 {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 0.0001, 'features': 0},
#             Current best combo with val score 0.4371:
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 20}
# Trained and Tested combination 831 of 252000, taking 3.08 seconds to get val score of 0.1172:
#                 {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-06, 'features': 1},
#             Current best combo with val score 0.4371:
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 20}
# % Combos Checked Thus Far: 831 out of 252000 which is 0.329762%
# Cruising Coordrdinate 149 of 528
#
# Cruising Coordrdinate 150 of 528
#
# Cruising Coordrdinate 151 of 528
#
# Cruising Coordrdinate 152 of 528
#
# Cruising Coordrdinate 153 of 528
#
# Cruising Coordrdinate 154 of 528
#
# Cruising Coordrdinate 155 of 528
#
# Cruising Coordrdinate 156 of 528
#
# Cruising Coordrdinate 157 of 528
#
# Cruising Coordrdinate 158 of 528
#
# Cruise suspended due to suspicious case
# Guidance: round 10
#
# 	round 10 iteration:  0
#
# Trained and Tested combination 832 of 252000, taking 0.13 seconds to get val score of 0.3108:
#                 {'n_estimators': 50, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 0},
#             Current best combo with val score 0.4371:
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 20}
# Already Trained and Tested combination (val score of 0.3108):
#             {'n_estimators': 25, 'max_depth': 6, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 0}
#             Current best combo (with val score 0.4371):
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 832 of 252000 combinations so far
# Trained and Tested combination 833 of 252000, taking 0.08 seconds to get val score of 0.3108:
#                 {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 0},
#             Current best combo with val score 0.4371:
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 20}
# Trained and Tested combination 834 of 252000, taking 0.07 seconds to get val score of 0.3108:
#                 {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 0.55, 'ccp_alpha': 1e-08, 'features': 0},
#             Current best combo with val score 0.4371:
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 20}
# Trained and Tested combination 835 of 252000, taking 0.08 seconds to get val score of 0.3108:
#                 {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-06, 'features': 0},
#             Current best combo with val score 0.4371:
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 20}
# Trained and Tested combination 836 of 252000, taking 0.09 seconds to get val score of 0.1178:
#                 {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 1},
#             Current best combo with val score 0.4371:
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 20}
# 	round 10 iteration:  1
#
# Already Trained and Tested combination (val score of 0.3108):
#             {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 0}
#             Current best combo (with val score 0.4371):
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 836 of 252000 combinations so far
# Trained and Tested combination 837 of 252000, taking 0.36 seconds to get val score of 0.3108:
#                 {'n_estimators': 100, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 0},
#             Current best combo with val score 0.4371:
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 20}
# Trained and Tested combination 838 of 252000, taking 0.14 seconds to get val score of 0.3108:
#                 {'n_estimators': 50, 'max_depth': 6, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 0},
#             Current best combo with val score 0.4371:
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 20}
# Trained and Tested combination 839 of 252000, taking 0.15 seconds to get val score of 0.3108:
#                 {'n_estimators': 50, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 0},
#             Current best combo with val score 0.4371:
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 20}
# Trained and Tested combination 840 of 252000, taking 0.14 seconds to get val score of 0.3108:
#                 {'n_estimators': 50, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 0.55, 'ccp_alpha': 1e-08, 'features': 0},
#             Current best combo with val score 0.4371:
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 20}
# Trained and Tested combination 841 of 252000, taking 0.15 seconds to get val score of 0.3108:
#                 {'n_estimators': 50, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-06, 'features': 0},
#             Current best combo with val score 0.4371:
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 20}
# Trained and Tested combination 842 of 252000, taking 0.22 seconds to get val score of 0.1017:
#                 {'n_estimators': 50, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 1},
#             Current best combo with val score 0.4371:
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 20}
# Already Trained and Tested combination (val score of 0.3108):
#             {'n_estimators': 50, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 0}
#             Current best combo (with val score 0.4371):
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 842 of 252000 combinations so far
# Trained and Tested combination 843 of 252000, taking 0.07 seconds to get val score of 0.3108:
#                 {'n_estimators': 25, 'max_depth': 6, 'max_samples': 0.55, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 0},
#             Current best combo with val score 0.4371:
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 20}
# Already Trained and Tested combination (val score of 0.3108):
#             {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 0}
#             Current best combo (with val score 0.4371):
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 843 of 252000 combinations so far
# Trained and Tested combination 844 of 252000, taking 0.09 seconds to get val score of 0.3108:
#                 {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.7, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 0},
#             Current best combo with val score 0.4371:
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 20}
# Trained and Tested combination 845 of 252000, taking 0.08 seconds to get val score of 0.3108:
#                 {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 0.55, 'ccp_alpha': 1e-08, 'features': 0},
#             Current best combo with val score 0.4371:
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 20}
# Trained and Tested combination 846 of 252000, taking 0.08 seconds to get val score of 0.3108:
#                 {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 0.4, 'ccp_alpha': 1e-06, 'features': 0},
#             Current best combo with val score 0.4371:
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 20}
# Trained and Tested combination 847 of 252000, taking 0.09 seconds to get val score of 0.1016:
#                 {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 1},
#             Current best combo with val score 0.4371:
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 20}
# Already Trained and Tested combination (val score of 0.3108):
#             {'n_estimators': 50, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 0.55, 'ccp_alpha': 1e-08, 'features': 0}
#             Current best combo (with val score 0.4371):
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 847 of 252000 combinations so far
# Trained and Tested combination 848 of 252000, taking 0.08 seconds to get val score of 0.3108:
#                 {'n_estimators': 25, 'max_depth': 6, 'max_samples': 0.4, 'max_features': 0.55, 'ccp_alpha': 1e-08, 'features': 0},
#             Current best combo with val score 0.4371:
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 20}
# Already Trained and Tested combination (val score of 0.3108):
#             {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 0.55, 'ccp_alpha': 1e-08, 'features': 0}
#             Current best combo (with val score 0.4371):
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 848 of 252000 combinations so far
# Already Trained and Tested combination (val score of 0.3108):
#             {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 0}
#             Current best combo (with val score 0.4371):
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 848 of 252000 combinations so far
# Trained and Tested combination 849 of 252000, taking 0.11 seconds to get val score of 0.3108:
#                 {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 0.7, 'ccp_alpha': 1e-08, 'features': 0},
#             Current best combo with val score 0.4371:
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 20}
# Trained and Tested combination 850 of 252000, taking 0.1 seconds to get val score of 0.3108:
#                 {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 0.55, 'ccp_alpha': 1e-06, 'features': 0},
#             Current best combo with val score 0.4371:
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 20}
# Trained and Tested combination 851 of 252000, taking 0.08 seconds to get val score of 0.1178:
#                 {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 0.55, 'ccp_alpha': 1e-08, 'features': 1},
#             Current best combo with val score 0.4371:
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 20}
# Already Trained and Tested combination (val score of 0.3108):
#             {'n_estimators': 50, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-06, 'features': 0}
#             Current best combo (with val score 0.4371):
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 851 of 252000 combinations so far
# Trained and Tested combination 852 of 252000, taking 0.08 seconds to get val score of 0.3108:
#                 {'n_estimators': 25, 'max_depth': 6, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-06, 'features': 0},
#             Current best combo with val score 0.4371:
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 20}
# Already Trained and Tested combination (val score of 0.3108):
#             {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 0.4, 'ccp_alpha': 1e-06, 'features': 0}
#             Current best combo (with val score 0.4371):
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 852 of 252000 combinations so far
# Already Trained and Tested combination (val score of 0.3108):
#             {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 0.55, 'ccp_alpha': 1e-06, 'features': 0}
#             Current best combo (with val score 0.4371):
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 852 of 252000 combinations so far
# Already Trained and Tested combination (val score of 0.3108):
#             {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 0}
#             Current best combo (with val score 0.4371):
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 852 of 252000 combinations so far
# Trained and Tested combination 853 of 252000, taking 0.06 seconds to get val score of 0.3108:
#                 {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 0.0001, 'features': 0},
#             Current best combo with val score 0.4371:
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 20}
# Trained and Tested combination 854 of 252000, taking 0.08 seconds to get val score of 0.1178:
#                 {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-06, 'features': 1},
#             Current best combo with val score 0.4371:
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 20}
# % Combos Checked Thus Far: 854 out of 252000 which is 0.338889%
# Cruising Coordrdinate 159 of 528
#
# Cruising Coordrdinate 160 of 528
#
# Cruising Coordrdinate 161 of 528
#
# Cruising Coordrdinate 162 of 528
#
# Cruising Coordrdinate 163 of 528
#
# Cruising Coordrdinate 164 of 528
#
# Cruising Coordrdinate 165 of 528
#
# Cruising Coordrdinate 166 of 528
#
# Cruising Coordrdinate 167 of 528
#
# Cruise suspended due to suspicious case
# Guidance: round 11
#
# 	round 11 iteration:  0
#
# Trained and Tested combination 855 of 252000, taking 0.15 seconds to get val score of 0.3108:
#                 {'n_estimators': 50, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 0},
#             Current best combo with val score 0.4371:
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 20}
# Trained and Tested combination 856 of 252000, taking 0.08 seconds to get val score of 0.3108:
#                 {'n_estimators': 25, 'max_depth': 12, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 0},
#             Current best combo with val score 0.4371:
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 20}
# Already Trained and Tested combination (val score of 0.3108):
#             {'n_estimators': 25, 'max_depth': 48, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 0}
#             Current best combo (with val score 0.4371):
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 856 of 252000 combinations so far
# Trained and Tested combination 857 of 252000, taking 0.11 seconds to get val score of 0.3108:
#                 {'n_estimators': 25, 'max_depth': 24, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 0},
#             Current best combo with val score 0.4371:
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 20}
# Trained and Tested combination 858 of 252000, taking 0.1 seconds to get val score of 0.3108:
#                 {'n_estimators': 25, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.85, 'ccp_alpha': 1e-08, 'features': 0},
#             Current best combo with val score 0.4371:
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 20}
# Trained and Tested combination 859 of 252000, taking 0.09 seconds to get val score of 0.3108:
#                 {'n_estimators': 25, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-06, 'features': 0},
#             Current best combo with val score 0.4371:
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 20}
# Trained and Tested combination 860 of 252000, taking 0.09 seconds to get val score of 0.4233:
#                 {'n_estimators': 25, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 1},
#             Current best combo with val score 0.4371:
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 20}
# ...
# 	round 28 iteration:  1
#
# Trained and Tested combination 1378 of 252000, taking 0.19 seconds to get val score of 0.2446:
#                 {'n_estimators': 50, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-06, 'features': 20},
#             Current best combo with val score 0.4371:
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 20}
# Trained and Tested combination 1379 of 252000, taking 0.09 seconds to get val score of 0.2963:
#                 {'n_estimators': 25, 'max_depth': 12, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-06, 'features': 20},
#             Current best combo with val score 0.4371:
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 20}
# Trained and Tested combination 1380 of 252000, taking 0.11 seconds to get val score of 0.3164:
#                 {'n_estimators': 25, 'max_depth': 48, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-06, 'features': 20},
#             Current best combo with val score 0.4371:
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 20}
# Trained and Tested combination 1381 of 252000, taking 0.13 seconds to get val score of 0.2789:
#                 {'n_estimators': 25, 'max_depth': 24, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-06, 'features': 20},
#             Current best combo with val score 0.4371:
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 20}
# Trained and Tested combination 1382 of 252000, taking 0.42 seconds to get val score of 0.2807:
#                 {'n_estimators': 25, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.85, 'ccp_alpha': 1e-06, 'features': 20},
#             Current best combo with val score 0.4371:
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 20}
# Already Trained and Tested combination (val score of 0.3018):
#             {'n_estimators': 25, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 20}
#             Current best combo (with val score 0.4371):
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 1382 of 252000 combinations so far
# Trained and Tested combination 1383 of 252000, taking 0.12 seconds to get val score of 0.2999:
#                 {'n_estimators': 25, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 0.0001, 'features': 20},
#             Current best combo with val score 0.4371:
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 20}
# Trained and Tested combination 1384 of 252000, taking 0.11 seconds to get val score of 0.1951:
#                 {'n_estimators': 25, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-06, 'features': 19},
#             Current best combo with val score 0.4371:
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 20}
# Trained and Tested combination 1385 of 252000, taking 0.11 seconds to get val score of 0.2716:
#                 {'n_estimators': 25, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-06, 'features': 21},
#             Current best combo with val score 0.4371:
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 20}
# % Combos Checked Thus Far: 1385 out of 252000 which is 0.549603%
# Cruising Coordrdinate 527 of 528
#
# Cruising Coordrdinate 528 of 528
#
# Cruise suspended due to suspicious case
# Guidance: round 29
#
# 	round 29 iteration:  0
#
# Already Trained and Tested combination (val score of 0.3481):
#             {'n_estimators': 50, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 20}
#             Current best combo (with val score 0.4371):
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 1385 of 252000 combinations so far
# Already Trained and Tested combination (val score of 0.3681):
#             {'n_estimators': 25, 'max_depth': 6, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 20}
#             Current best combo (with val score 0.4371):
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 1385 of 252000 combinations so far
# Already Trained and Tested combination (val score of 0.4371):
#             {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 20}
#             Current best combo (with val score 0.4371):
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 1385 of 252000 combinations so far
# Already Trained and Tested combination (val score of 0.051):
#             {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 0.85, 'ccp_alpha': 1e-08, 'features': 20}
#             Current best combo (with val score 0.4371):
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 1385 of 252000 combinations so far
# Already Trained and Tested combination (val score of 0.4285):
#             {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-06, 'features': 20}
#             Current best combo (with val score 0.4371):
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 1385 of 252000 combinations so far
# Already Trained and Tested combination (val score of 0.2775):
#             {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 19}
#             Current best combo (with val score 0.4371):
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 1385 of 252000 combinations so far
# Already Trained and Tested combination (val score of 0.1591):
#             {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 21}
#             Current best combo (with val score 0.4371):
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 1385 of 252000 combinations so far
# 	round 29 iteration:  1
#
# Already Trained and Tested combination (val score of 0.3534):
#             {'n_estimators': 50, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 20}
#             Current best combo (with val score 0.4371):
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 1385 of 252000 combinations so far
# Already Trained and Tested combination (val score of 0.3812):
#             {'n_estimators': 25, 'max_depth': 6, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 20}
#             Current best combo (with val score 0.4371):
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 1385 of 252000 combinations so far
# Already Trained and Tested combination (val score of 0.4285):
#             {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 20}
#             Current best combo (with val score 0.4371):
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 1385 of 252000 combinations so far
# Already Trained and Tested combination (val score of 0.4249):
#             {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.7, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 20}
#             Current best combo (with val score 0.4371):
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 1385 of 252000 combinations so far
# Already Trained and Tested combination (val score of 0.0629):
#             {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 0.85, 'ccp_alpha': 1e-08, 'features': 20}
#             Current best combo (with val score 0.4371):
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 1385 of 252000 combinations so far
# Already Trained and Tested combination (val score of 0.4371):
#             {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-06, 'features': 20}
#             Current best combo (with val score 0.4371):
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 1385 of 252000 combinations so far
# Already Trained and Tested combination (val score of 0.2812):
#             {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 19}
#             Current best combo (with val score 0.4371):
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 1385 of 252000 combinations so far
# Already Trained and Tested combination (val score of 0.0872):
#             {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 21}
#             Current best combo (with val score 0.4371):
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 1385 of 252000 combinations so far
# Trained and Tested combination 1386 of 252000, taking 0.17 seconds to get val score of 0.3481:
#                 {'n_estimators': 50, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-06, 'features': 20},
#             Current best combo with val score 0.4371:
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 20}
# Trained and Tested combination 1387 of 252000, taking 0.12 seconds to get val score of 0.3681:
#                 {'n_estimators': 25, 'max_depth': 6, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-06, 'features': 20},
#             Current best combo with val score 0.4371:
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 20}
# Already Trained and Tested combination (val score of 0.4371):
#             {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-06, 'features': 20}
#             Current best combo (with val score 0.4371):
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 1387 of 252000 combinations so far
# Trained and Tested combination 1388 of 252000, taking 0.18 seconds to get val score of 0.051:
#                 {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 0.85, 'ccp_alpha': 1e-06, 'features': 20},
#             Current best combo with val score 0.4371:
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 20}
# Already Trained and Tested combination (val score of 0.4285):
#             {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 20}
#             Current best combo (with val score 0.4371):
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 1388 of 252000 combinations so far
# Trained and Tested combination 1389 of 252000, taking 0.08 seconds to get val score of 0.4294:
#                 {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 0.0001, 'features': 20},
#             Current best combo with val score 0.4371:
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 20}
# Trained and Tested combination 1390 of 252000, taking 0.09 seconds to get val score of 0.2775:
#                 {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-06, 'features': 19},
#             Current best combo with val score 0.4371:
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 20}
# Trained and Tested combination 1391 of 252000, taking 0.08 seconds to get val score of 0.1591:
#                 {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-06, 'features': 21},
#             Current best combo with val score 0.4371:
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 20}
# % Combos Checked Thus Far: 1391 out of 252000 which is 0.551984%
# FINAL STAGE: Begin final Guidance system
#
#
# Guidance: round FINAL
#
# 	round FINAL iteration:  0
#
# % Combos Checked Thus Far: 1391 out of 252000 which is 0.551984%
# Max Val Score:
#  0.437141
# Max Val Score Std:
#  0.030639
# Best Combo Train Score:
#  0.80535
# Best Combo Train Score Std:
#  0.009483
# Max Combo Index:
#  (0, 0, 1, 4, 0, 20) out of [6, 7, 5, 5, 5, 48] (note best combo is 0-indexed)
# Max Combo Hyperparamer Combination:
#  {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.55, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 20}
# Max Combo Features:
#  ('procedure_224274', 'lods_score', 'procedure_224276', 'procedure_224267', 'race_AMERICAN INDIAN/ALASKA NATIVE', 'race_ASIAN', 'race_ASIAN - ASIAN INDIAN', 'race_ASIAN - CHINESE', 'race_ASIAN - KOREAN', 'race_ASIAN - SOUTH EAST ASIAN', 'race_BLACK/AFRICAN', 'race_BLACK/AFRICAN AMERICAN', 'race_BLACK/CAPE VERDEAN', 'race_BLACK/CARIBBEAN ISLAND', 'race_HISPANIC OR LATINO', 'race_HISPANIC/LATINO - CENTRAL AMERICAN', 'race_HISPANIC/LATINO - COLUMBIAN', 'race_HISPANIC/LATINO - CUBAN', 'race_HISPANIC/LATINO - DOMINICAN', 'race_HISPANIC/LATINO - GUATEMALAN', 'race_HISPANIC/LATINO - HONDURAN', 'race_HISPANIC/LATINO - MEXICAN', 'race_HISPANIC/LATINO - PUERTO RICAN', 'race_HISPANIC/LATINO - SALVADORAN', 'race_MULTIPLE RACE/ETHNICITY', 'race_NATIVE HAWAIIAN OR OTHER PACIFIC ISLANDER', 'race_OTHER', 'race_PATIENT DECLINED TO ANSWER', 'race_PORTUGUESE', 'race_SOUTH AMERICAN', 'race_UNABLE TO OBTAIN', 'race_WHITE', 'race_WHITE - BRAZILIAN', 'race_WHITE - EASTERN EUROPEAN', 'race_WHITE - OTHER EUROPEAN', 'race_WHITE - RUSSIAN', 'race_UNKNOWN', 'procedure_227712', 'procedure_225430', 'gender_F', 'gender_M', 'oasis_score', 'procedure_225446', 'procedure_224275', 'procedure_225802', 'hospital_stay_duration', 'procedure_226475', 'ventilation_used', 'procedure_224270', 'procedure_227194', 'icu_stay_duration', 'procedure_225400', 'procedure_221223', 'procedure_225792')
# % Combos Checked: 1391 out of 252000 which is 0.551984%
