# %% [markdown]
# # Tuning Script

# %%
# Parameters subject to change in every script - involved in naming

MODEL = 'rfc'
PREPROCESSING = 'smote_normalise'
TUNER = 'yangzhoub'
OPTIMISED_METRIC = 'f1'

# %% [markdown]
# ---

# %%
# detect whether this is a google environment

COLAB_ENVIRONMENT = False

try:
    from google.colab import drive
    drive.mount('/content/drive')
    COLAB_ENVIRONMENT = True
except:
    pass
# Out:
# Mounted at /content/drive

# %%
import sys
import os
import pickle

if COLAB_ENVIRONMENT:
    home_directory = './drive/MyDrive/LAB/COMP90089__GroupWork__Py/' # my home directory is stored in ./LAB of google drive
    if MODEL == 'ebr':
        # !pip install interpret==0.5.0
    elif MODEL == 'cbr':
        # !pip install catboost
    elif MODEL in ['tf', 'mlp']:
        # !pip install PyTorch2Sklearn
    # !pip install JXAutoML
else:
    home_directory = '../../'

from JXAutoML.YangZhouB_10CV import YangZhouB_10CV as Tuner

import pandas as pd
# Out:
# Collecting JXAutoML
#   Downloading JXAutoML-0.4.4-py3-none-any.whl.metadata (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.2/67.2 kB 683.1 kB/s eta 0:00:00
# Downloading JXAutoML-0.4.4-py3-none-any.whl (52 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.1/52.1 kB 2.0 MB/s eta 0:00:00
# Installing collected packages: JXAutoML
# Successfully installed JXAutoML-0.4.4

# %%
# Parameters that are same for every script

FOLDS = 10  # we have decided to do 10 fold validation

SEED = 42

TASK_TYPE = 'Classification'  # this task is a classification task

# we have decided to tune features as hp
TUNE_FEATURES_AS_HYPERPARAMETERS = True

# %% [markdown]
# ---

# %%
# model to use to tune
from sklearn.ensemble import RandomForestClassifier as clf

# what values to try for each hyperparameter
parameter_choices = {
    'n_estimators': (25, 50, 100, 200, 400, 800),
    'max_depth': (3, 6, 12, 24, 48, 96, 192),
    'max_samples': (0.4, 0.55, 0.7, 0.85, 1),
    'max_features': (0.4, 0.55, 0.7, 0.85, 1),
    'ccp_alpha': (0.00000001, 0.000001, 0.0001, 0.01, 0.1)
}

# what values to set non-tuneable parameters/hyperparameters
non_tunable_hyperparameters_dict = {
    'random_state': SEED,
    'n_jobs': -1
}

# %% [markdown]
# ---

# %% [markdown]
# Read in and Prepare Data

# %%
# Import data and store as lists

train_x_list = []
train_y_list = []
val_x_list = []
val_y_list = []

for i in range(FOLDS):
    train_data = pd.read_csv(
        f'{home_directory}data/curated/modelling/{PREPROCESSING}/train_{i}.csv')
    val_data = pd.read_csv(
        f'{home_directory}data/curated/modelling/{PREPROCESSING}/val_{i}.csv')

    # get the correct rows for X and y
    train_x = train_data.drop(
        ['mortality_status', 'subject_id', 'hadm_id', 'stay_id'], axis=1)
    train_y = train_data['mortality_status']
    val_x = val_data.drop(
        ['mortality_status', 'subject_id', 'hadm_id', 'stay_id'], axis=1)
    val_y = val_data['mortality_status']

    train_x_list.append(train_x)
    train_y_list.append(train_y)
    val_x_list.append(val_x)
    val_y_list.append(val_y)

# %%
# Import feature importance ordering

with open(f'{home_directory}models/xgb_feature_importance_ordering_{PREPROCESSING}.pickle', 'rb') as f:
    feature_importance_ordering = pickle.load(f)

# %% [markdown]
# Set parameters

# %%
# initialisation
tuner = Tuner()

print('---')

# define what model we are tuning
tuner.read_in_model(clf, TASK_TYPE, optimised_metric=OPTIMISED_METRIC)

print('---')

# read in the data for training and validation
tuner.read_in_data(train_x_list, train_y_list, val_x_list, val_y_list)

print('---')

# set what hp values to tune
tuner.set_hyperparameters(parameter_choices)
# WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

# set up hp values that need to be changed from default but NOT to be tuned
tuner.set_non_tuneable_hyperparameters(non_tunable_hyperparameters_dict)

print('---')

# set up feature importance ordering

if TUNE_FEATURES_AS_HYPERPARAMETERS:
    tuner.set_features(feature_importance_ordering)
    # WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

try:  # try to read in previous results to continue tuning ...
    tuner.read_in_tuning_result_df(
        f'{home_directory}models/tuning/{TUNER}_{MODEL}_{PREPROCESSING}.csv')
except:
    print('No previous tuning data read in')

print('---')

# set up where to save the tuning result csv
tuner.set_tuning_result_saving_address(
    f'{home_directory}models/tuning/{TUNER}_{MODEL}_{PREPROCESSING}.csv')

print('---')

# set up where to save the current best model
tuner.set_best_model_saving_address(
    f'{home_directory}models/tmp_models/{TUNER}_{MODEL}_{PREPROCESSING}')
# Out:
# YangZhouB Initialised
# ---
# Successfully read in model <class 'sklearn.ensemble._forest.RandomForestClassifier'>, which is a Classification model optimising for f1
# ---
# Read in Train X data list
# Read in Train y data list
# Read in Val X data list
# Read in Val y data list
# ---
# Successfully recorded hyperparameter choices
# ---
# Successfully recorded non_tuneable_hyperparameter choices
# ---
# Successfully recorded tuneable feature combination choices and updated relevant internal structures
# ---
# Successfully read in tuning result of 722 rows, for 722.0 combos
# ---
# Successfully set tuning output address
# ---
# Successfully set best model output address

# %%
# ignore warnings

import warnings
warnings.filterwarnings("ignore")

# %%
# begin tuning ... (or continue training)

tuner.tune()
# Out:
# Streaming output truncated to the last 5000 lines.
#             Current best combo (with val score 0.4861):
#                     {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 722 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.298):
#             {'n_estimators': 25, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 63}
#             Current best combo (with val score 0.4861):
#                     {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 722 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.1194):
#             {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 35}
#             Current best combo (with val score 0.4861):
#                     {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 722 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'n_estimators': 800, 'max_depth': 192, 'max_samples': 1, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 50}
#             Current best combo (with val score 0.4861):
#                     {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 722 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.1543):
#             {'n_estimators': 25, 'max_depth': 24, 'max_samples': 1, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 50}
#             Current best combo (with val score 0.4861):
#                     {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 722 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.0696):
#             {'n_estimators': 25, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 55}
#             Current best combo (with val score 0.4861):
#                     {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 722 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'n_estimators': 800, 'max_depth': 24, 'max_samples': 1, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 67}
#             Current best combo (with val score 0.4861):
#                     {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 722 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.0733):
#             {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 0.1, 'features': 5}
#             Current best combo (with val score 0.4861):
#                     {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 722 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.0782):
#             {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 0.1, 'features': 55}
#             Current best combo (with val score 0.4861):
#                     {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 722 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.0733):
#             {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 0.1, 'features': 5}
#             Current best combo (with val score 0.4861):
#                     {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 722 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.4369):
#             {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 25}
#             Current best combo (with val score 0.4861):
#                     {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 722 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.1543):
#             {'n_estimators': 25, 'max_depth': 24, 'max_samples': 1, 'max_features': 0.4, 'ccp_alpha': 0.1, 'features': 67}
#             Current best combo (with val score 0.4861):
#                     {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 722 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.0723):
#             {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 0.1, 'features': 15}
#             Current best combo (with val score 0.4861):
#                     {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 722 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.1543):
#             {'n_estimators': 25, 'max_depth': 3, 'max_samples': 1, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 40}
#             Current best combo (with val score 0.4861):
#                     {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 722 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.1543):
#             {'n_estimators': 25, 'max_depth': 192, 'max_samples': 1, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 5}
#             Current best combo (with val score 0.4861):
#                     {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 722 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.1543):
#             {'n_estimators': 25, 'max_depth': 24, 'max_samples': 1, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 25}
#             Current best combo (with val score 0.4861):
#                     {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 722 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.1543):
#             {'n_estimators': 25, 'max_depth': 192, 'max_samples': 1, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 50}
#             Current best combo (with val score 0.4861):
#                     {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 722 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.0545):
#             {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 0.1, 'features': 45}
#             Current best combo (with val score 0.4861):
#                     {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 722 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.1543):
#             {'n_estimators': 25, 'max_depth': 192, 'max_samples': 1, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#             Current best combo (with val score 0.4861):
#                     {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 722 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.1713):
#             {'n_estimators': 25, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 0.1, 'features': 71}
#             Current best combo (with val score 0.4861):
#                     {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 722 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'n_estimators': 800, 'max_depth': 24, 'max_samples': 1, 'max_features': 1, 'ccp_alpha': 0.1, 'features': 55}
#             Current best combo (with val score 0.4861):
#                     {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 722 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.2583):
#             {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 50}
#             Current best combo (with val score 0.4861):
#                     {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 722 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.1543):
#             {'n_estimators': 25, 'max_depth': 24, 'max_samples': 1, 'max_features': 1, 'ccp_alpha': 0.1, 'features': 35}
#             Current best combo (with val score 0.4861):
#                     {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 722 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'n_estimators': 800, 'max_depth': 3, 'max_samples': 1, 'max_features': 0.4, 'ccp_alpha': 0.1, 'features': 63}
#             Current best combo (with val score 0.4861):
#                     {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 722 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.1543):
#             {'n_estimators': 25, 'max_depth': 3, 'max_samples': 1, 'max_features': 0.4, 'ccp_alpha': 0.1, 'features': 20}
#             Current best combo (with val score 0.4861):
#                     {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 722 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.0669):
#             {'n_estimators': 25, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 0.1, 'features': 71}
#             Current best combo (with val score 0.4861):
#                     {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 722 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'n_estimators': 800, 'max_depth': 192, 'max_samples': 1, 'max_features': 0.4, 'ccp_alpha': 0.1, 'features': 40}
#             Current best combo (with val score 0.4861):
#                     {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 722 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.3862):
#             {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 20}
#             Current best combo (with val score 0.4861):
#                     {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 722 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.1543):
#             {'n_estimators': 25, 'max_depth': 24, 'max_samples': 1, 'max_features': 0.4, 'ccp_alpha': 0.1, 'features': 59}
#             Current best combo (with val score 0.4861):
#                     {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 722 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.28):
#             {'n_estimators': 25, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 45}
#             Current best combo (with val score 0.4861):
#                     {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 722 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.0765):
#             {'n_estimators': 25, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 0.1, 'features': 5}
#             Current best combo (with val score 0.4861):
#                     {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 722 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'n_estimators': 800, 'max_depth': 192, 'max_samples': 1, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 67}
#             Current best combo (with val score 0.4861):
#                     {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 722 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.3244):
#             {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 0}
#             Current best combo (with val score 0.4861):
#                     {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 722 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.1975):
#             {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 45}
#             Current best combo (with val score 0.4861):
#                     {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 722 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.1543):
#             {'n_estimators': 25, 'max_depth': 192, 'max_samples': 1, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 67}
#             Current best combo (with val score 0.4861):
#                     {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 722 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'n_estimators': 800, 'max_depth': 192, 'max_samples': 1, 'max_features': 1, 'ccp_alpha': 0.1, 'features': 5}
#             Current best combo (with val score 0.4861):
#                     {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 722 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'n_estimators': 800, 'max_depth': 3, 'max_samples': 1, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 40}
#             Current best combo (with val score 0.4861):
#                     {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 722 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.3427):
#             {'n_estimators': 25, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 10}
#             Current best combo (with val score 0.4861):
#                     {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 722 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.1543):
#             {'n_estimators': 25, 'max_depth': 3, 'max_samples': 1, 'max_features': 1, 'ccp_alpha': 0.1, 'features': 40}
#             Current best combo (with val score 0.4861):
#                     {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 722 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.0845):
#             {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 0.1, 'features': 5}
#             Current best combo (with val score 0.4861):
#                     {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 722 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'n_estimators': 800, 'max_depth': 3, 'max_samples': 1, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 50}
#             Current best combo (with val score 0.4861):
#                     {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 722 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.1122):
#             {'n_estimators': 25, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 0.1, 'features': 30}
#             Current best combo (with val score 0.4861):
#                     {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 722 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'n_estimators': 800, 'max_depth': 24, 'max_samples': 1, 'max_features': 0.4, 'ccp_alpha': 0.1, 'features': 35}
#             Current best combo (with val score 0.4861):
#                     {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 722 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.1543):
#             {'n_estimators': 25, 'max_depth': 3, 'max_samples': 1, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 0}
#             Current best combo (with val score 0.4861):
#                     {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 722 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.2585):
#             {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 71}
#             Current best combo (with val score 0.4861):
#                     {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 722 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'n_estimators': 800, 'max_depth': 24, 'max_samples': 1, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 50}
#             Current best combo (with val score 0.4861):
#                     {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 722 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.1543):
#             {'n_estimators': 25, 'max_depth': 192, 'max_samples': 1, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 67}
#             Current best combo (with val score 0.4861):
#                     {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 722 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.0676):
#             {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 0.1, 'features': 35}
#             Current best combo (with val score 0.4861):
#                     {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 722 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.1543):
#             {'n_estimators': 25, 'max_depth': 3, 'max_samples': 1, 'max_features': 0.4, 'ccp_alpha': 0.1, 'features': 67}
#             Current best combo (with val score 0.4861):
#                     {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 722 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.2624):
#             {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 67}
#             Current best combo (with val score 0.4861):
#                     {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 722 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.3244):
#             {'n_estimators': 25, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 0}
#             Current best combo (with val score 0.4861):
#                     {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 722 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.1543):
#             {'n_estimators': 25, 'max_depth': 24, 'max_samples': 1, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 59}
#             Current best combo (with val score 0.4861):
#                     {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 722 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'n_estimators': 800, 'max_depth': 192, 'max_samples': 1, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 20}
#             Current best combo (with val score 0.4861):
#                     {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 722 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.1543):
#             {'n_estimators': 25, 'max_depth': 24, 'max_samples': 1, 'max_features': 1, 'ccp_alpha': 0.1, 'features': 15}
#             Current best combo (with val score 0.4861):
#                     {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 722 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.1766):
#             {'n_estimators': 25, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 59}
#             Current best combo (with val score 0.4861):
#                     {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 722 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'n_estimators': 800, 'max_depth': 3, 'max_samples': 1, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 71}
#             Current best combo (with val score 0.4861):
#                     {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 722 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.0664):
#             {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 0.1, 'features': 67}
#             Current best combo (with val score 0.4861):
#                     {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 722 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.1543):
#             {'n_estimators': 25, 'max_depth': 24, 'max_samples': 1, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 45}
#             Current best combo (with val score 0.4861):
#                     {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 722 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.3335):
#             {'n_estimators': 25, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 5}
#             Current best combo (with val score 0.4861):
#                     {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 722 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.1543):
#             {'n_estimators': 25, 'max_depth': 3, 'max_samples': 1, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#             Current best combo (with val score 0.4861):
#                     {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 722 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.0488):
#             {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 0.1, 'features': 63}
#             Current best combo (with val score 0.4861):
#                     {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 722 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.1543):
#             {'n_estimators': 25, 'max_depth': 192, 'max_samples': 1, 'max_features': 1, 'ccp_alpha': 0.1, 'features': 5}
#             Current best combo (with val score 0.4861):
#                     {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 722 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.0488):
#             {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 0.1, 'features': 67}
#             Current best combo (with val score 0.4861):
#                     {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 722 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'n_estimators': 800, 'max_depth': 3, 'max_samples': 1, 'max_features': 1, 'ccp_alpha': 0.1, 'features': 15}
#             Current best combo (with val score 0.4861):
#                     {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 722 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.0422):
#             {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 0.1, 'features': 67}
#             Current best combo (with val score 0.4861):
#                     {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 722 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.1543):
#             {'n_estimators': 25, 'max_depth': 192, 'max_samples': 1, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 25}
#             Current best combo (with val score 0.4861):
#                     {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 722 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.1543):
#             {'n_estimators': 25, 'max_depth': 24, 'max_samples': 1, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 67}
#             Current best combo (with val score 0.4861):
#                     {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 722 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.0488):
#             {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 0.1, 'features': 50}
#             Current best combo (with val score 0.4861):
#                     {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 722 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.029):
#             {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 50}
#             Current best combo (with val score 0.4861):
#                     {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 722 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'n_estimators': 800, 'max_depth': 24, 'max_samples': 1, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 67}
#             Current best combo (with val score 0.4861):
#                     {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 722 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.0488):
#             {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 0.1, 'features': 35}
#             Current best combo (with val score 0.4861):
#                     {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 722 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.3835):
#             {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 25}
#             Current best combo (with val score 0.4861):
#                     {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 722 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'n_estimators': 800, 'max_depth': 3, 'max_samples': 1, 'max_features': 1, 'ccp_alpha': 0.1, 'features': 63}
#             Current best combo (with val score 0.4861):
#                     {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 722 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'n_estimators': 800, 'max_depth': 192, 'max_samples': 1, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 0}
#             Current best combo (with val score 0.4861):
#                     {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 722 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.1543):
#             {'n_estimators': 25, 'max_depth': 24, 'max_samples': 1, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 67}
#             Current best combo (with val score 0.4861):
#                     {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 722 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'n_estimators': 800, 'max_depth': 3, 'max_samples': 1, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 45}
#             Current best combo (with val score 0.4861):
#                     {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 722 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.0782):
#             {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 0.1, 'features': 55}
#             Current best combo (with val score 0.4861):
#                     {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 722 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.0782):
#             {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 0.1, 'features': 55}
#             Current best combo (with val score 0.4861):
#                     {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 722 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'n_estimators': 800, 'max_depth': 24, 'max_samples': 1, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 59}
#             Current best combo (with val score 0.4861):
#                     {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 722 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.3736):
#             {'n_estimators': 25, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 25}
#             Current best combo (with val score 0.4861):
#                     {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 722 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.1543):
#             {'n_estimators': 25, 'max_depth': 192, 'max_samples': 1, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 45}
#             Current best combo (with val score 0.4861):
#                     {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 722 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.1543):
#             {'n_estimators': 25, 'max_depth': 192, 'max_samples': 1, 'max_features': 0.4, 'ccp_alpha': 0.1, 'features': 67}
#             Current best combo (with val score 0.4861):
#                     {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 722 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.0566):
#             {'n_estimators': 25, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 0.1, 'features': 55}
#             Current best combo (with val score 0.4861):
#                     {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 722 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.026):
#             {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 67}
#             Current best combo (with val score 0.4861):
#                     {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 722 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.1543):
#             {'n_estimators': 25, 'max_depth': 24, 'max_samples': 1, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 50}
#             Current best combo (with val score 0.4861):
#                     {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 722 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.2599):
#             {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 63}
#             Current best combo (with val score 0.4861):
#                     {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 722 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.0033):
#             {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 50}
#             Current best combo (with val score 0.4861):
#                     {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 722 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.0782):
#             {'n_estimators': 25, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 0.1, 'features': 40}
#             Current best combo (with val score 0.4861):
#                     {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 722 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.269):
#             {'n_estimators': 25, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 35}
#             Current best combo (with val score 0.4861):
#                     {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 722 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'n_estimators': 800, 'max_depth': 3, 'max_samples': 1, 'max_features': 1, 'ccp_alpha': 0.1, 'features': 5}
#             Current best combo (with val score 0.4861):
#                     {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 722 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.0488):
#             {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 0.1, 'features': 63}
#             Current best combo (with val score 0.4861):
#                     {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 722 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.4861):
#             {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#             Current best combo (with val score 0.4861):
#                     {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 722 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.1543):
#             {'n_estimators': 25, 'max_depth': 192, 'max_samples': 1, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 15}
#             Current best combo (with val score 0.4861):
#                     {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 722 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.1546):
#             {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#             Current best combo (with val score 0.4861):
#                     {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 722 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.0228):
#             {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 63}
#             Current best combo (with val score 0.4861):
#                     {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 722 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.2891):
#             {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 15}
#             Current best combo (with val score 0.4861):
#                     {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 722 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'n_estimators': 800, 'max_depth': 24, 'max_samples': 1, 'max_features': 1, 'ccp_alpha': 0.1, 'features': 67}
#             Current best combo (with val score 0.4861):
#                     {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 722 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.0545):
#             {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 0.1, 'features': 30}
#             Current best combo (with val score 0.4861):
#                     {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 722 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.0488):
#             {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 0.1, 'features': 20}
#             Current best combo (with val score 0.4861):
#                     {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 722 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.1539):
#             {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 40}
#             Current best combo (with val score 0.4861):
#                     {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 722 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.0812):
#             {'n_estimators': 25, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 0.1, 'features': 30}
#             Current best combo (with val score 0.4861):
#                     {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 722 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.1543):
#             {'n_estimators': 25, 'max_depth': 192, 'max_samples': 1, 'max_features': 1, 'ccp_alpha': 0.1, 'features': 71}
#             Current best combo (with val score 0.4861):
#                     {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 722 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'n_estimators': 800, 'max_depth': 3, 'max_samples': 1, 'max_features': 1, 'ccp_alpha': 0.1, 'features': 50}
#             Current best combo (with val score 0.4861):
#                     {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 722 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.0611):
#             {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 0.1, 'features': 40}
#             Current best combo (with val score 0.4861):
#                     {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 722 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'n_estimators': 800, 'max_depth': 192, 'max_samples': 1, 'max_features': 0.4, 'ccp_alpha': 0.1, 'features': 30}
#             Current best combo (with val score 0.4861):
#                     {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 722 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.0782):
#             {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 0.1, 'features': 40}
#             Current best combo (with val score 0.4861):
#                     {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 722 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.1543):
#             {'n_estimators': 25, 'max_depth': 3, 'max_samples': 1, 'max_features': 1, 'ccp_alpha': 0.1, 'features': 63}
#             Current best combo (with val score 0.4861):
#                     {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 722 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.1543):
#             {'n_estimators': 25, 'max_depth': 192, 'max_samples': 1, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 15}
#             Current best combo (with val score 0.4861):
#                     {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 722 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'n_estimators': 800, 'max_depth': 24, 'max_samples': 1, 'max_features': 0.4, 'ccp_alpha': 0.1, 'features': 5}
#             Current best combo (with val score 0.4861):
#                     {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 722 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.0488):
#             {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 0.1, 'features': 50}
#             Current best combo (with val score 0.4861):
#                     {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 722 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'n_estimators': 800, 'max_depth': 192, 'max_samples': 1, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 59}
#             Current best combo (with val score 0.4861):
#                     {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 722 of 378000 combinations so far
# ...
#
# Cruising Coordrdinate 585 of 768
#
# Cruising Coordrdinate 586 of 768
#
# Cruising Coordrdinate 587 of 768
#
# Cruising Coordrdinate 588 of 768
#
# Cruising Coordrdinate 589 of 768
#
# Cruising Coordrdinate 590 of 768
#
# Cruising Coordrdinate 591 of 768
#
# Cruising Coordrdinate 592 of 768
#
# Cruising Coordrdinate 593 of 768
#
# Cruising Coordrdinate 594 of 768
#
# Cruising Coordrdinate 595 of 768
#
# Cruising Coordrdinate 596 of 768
#
# Cruising Coordrdinate 597 of 768
#
# Cruising Coordrdinate 598 of 768
#
# Cruising Coordrdinate 599 of 768
#
# Cruising Coordrdinate 600 of 768
#
# Cruising Coordrdinate 601 of 768
#
# Cruising Coordrdinate 602 of 768
#
# Cruising Coordrdinate 603 of 768
#
# Cruising Coordrdinate 604 of 768
#
# Cruising Coordrdinate 605 of 768
#
# Cruising Coordrdinate 606 of 768
#
# Cruising Coordrdinate 607 of 768
#
# Cruising Coordrdinate 608 of 768
#
# Cruising Coordrdinate 609 of 768
#
# Cruising Coordrdinate 610 of 768
#
# Cruising Coordrdinate 611 of 768
#
# Cruising Coordrdinate 612 of 768
#
# Cruising Coordrdinate 613 of 768
#
# Cruising Coordrdinate 614 of 768
#
# Cruising Coordrdinate 615 of 768
#
# Cruising Coordrdinate 616 of 768
#
# Cruising Coordrdinate 617 of 768
#
# Cruising Coordrdinate 618 of 768
#
# Cruising Coordrdinate 619 of 768
#
# Cruising Coordrdinate 620 of 768
#
# Cruising Coordrdinate 621 of 768
#
# Cruising Coordrdinate 622 of 768
#
# Cruising Coordrdinate 623 of 768
#
# Cruising Coordrdinate 624 of 768
#
# Cruising Coordrdinate 625 of 768
#
# Cruising Coordrdinate 626 of 768
#
# Cruising Coordrdinate 627 of 768
#
# Cruising Coordrdinate 628 of 768
#
# Cruising Coordrdinate 629 of 768
#
# Cruising Coordrdinate 630 of 768
#
# Cruising Coordrdinate 631 of 768
#
# Cruising Coordrdinate 632 of 768
#
# Cruising Coordrdinate 633 of 768
#
# Cruising Coordrdinate 634 of 768
#
# Cruising Coordrdinate 635 of 768
#
# Cruising Coordrdinate 636 of 768
#
# Cruising Coordrdinate 637 of 768
#
# Cruising Coordrdinate 638 of 768
#
# Cruising Coordrdinate 639 of 768
#
# Cruising Coordrdinate 640 of 768
#
# Cruising Coordrdinate 641 of 768
#
# Cruising Coordrdinate 642 of 768
#
# Cruising Coordrdinate 643 of 768
#
# Cruising Coordrdinate 644 of 768
#
# Cruising Coordrdinate 645 of 768
#
# Cruising Coordrdinate 646 of 768
#
# Cruising Coordrdinate 647 of 768
#
# Cruising Coordrdinate 648 of 768
#
# Cruising Coordrdinate 649 of 768
#
# Cruising Coordrdinate 650 of 768
#
# Cruising Coordrdinate 651 of 768
#
# Cruising Coordrdinate 652 of 768
#
# Cruising Coordrdinate 653 of 768
#
# Cruising Coordrdinate 654 of 768
#
# Cruising Coordrdinate 655 of 768
#
# Cruising Coordrdinate 656 of 768
#
# Cruising Coordrdinate 657 of 768
#
# Cruising Coordrdinate 658 of 768
#
# Cruising Coordrdinate 659 of 768
#
# Cruising Coordrdinate 660 of 768
#
# Cruising Coordrdinate 661 of 768
#
# Cruising Coordrdinate 662 of 768
#
# Cruising Coordrdinate 663 of 768
#
# Cruising Coordrdinate 664 of 768
#
# Cruising Coordrdinate 665 of 768
#
# Cruising Coordrdinate 666 of 768
#
# Cruising Coordrdinate 667 of 768
#
# Cruising Coordrdinate 668 of 768
#
# Cruising Coordrdinate 669 of 768
#
# Cruising Coordrdinate 670 of 768
#
# Cruising Coordrdinate 671 of 768
#
# Cruising Coordrdinate 672 of 768
#
# Cruising Coordrdinate 673 of 768
#
# Cruising Coordrdinate 674 of 768
#
# Cruising Coordrdinate 675 of 768
#
# Cruising Coordrdinate 676 of 768
#
# Cruising Coordrdinate 677 of 768
#
# Cruising Coordrdinate 678 of 768
#
# Cruising Coordrdinate 679 of 768
#
# Cruising Coordrdinate 680 of 768
#
# Cruising Coordrdinate 681 of 768
#
# Cruising Coordrdinate 682 of 768
#
# Cruising Coordrdinate 683 of 768
#
# Cruising Coordrdinate 684 of 768
#
# Cruising Coordrdinate 685 of 768
#
# Cruising Coordrdinate 686 of 768
#
# Cruising Coordrdinate 687 of 768
#
# Cruising Coordrdinate 688 of 768
#
# Cruising Coordrdinate 689 of 768
#
# Cruising Coordrdinate 690 of 768
#
# Cruising Coordrdinate 691 of 768
#
# Cruising Coordrdinate 692 of 768
#
# Cruising Coordrdinate 693 of 768
#
# Cruising Coordrdinate 694 of 768
#
# Cruising Coordrdinate 695 of 768
#
# Cruising Coordrdinate 696 of 768
#
# Cruising Coordrdinate 697 of 768
#
# Cruising Coordrdinate 698 of 768
#
# Cruising Coordrdinate 699 of 768
#
# Cruising Coordrdinate 700 of 768
#
# Cruising Coordrdinate 701 of 768
#
# Cruising Coordrdinate 702 of 768
#
# Cruising Coordrdinate 703 of 768
#
# Cruising Coordrdinate 704 of 768
#
# Cruising Coordrdinate 705 of 768
#
# Cruising Coordrdinate 706 of 768
#
# Cruising Coordrdinate 707 of 768
#
# Cruising Coordrdinate 708 of 768
#
# Cruising Coordrdinate 709 of 768
#
# Cruising Coordrdinate 710 of 768
#
# Cruising Coordrdinate 711 of 768
#
# Cruising Coordrdinate 712 of 768
#
# Cruising Coordrdinate 713 of 768
#
# Cruising Coordrdinate 714 of 768
#
# Cruising Coordrdinate 715 of 768
#
# Cruising Coordrdinate 716 of 768
#
# Cruising Coordrdinate 717 of 768
#
# Cruising Coordrdinate 718 of 768
#
# Cruising Coordrdinate 719 of 768
#
# Cruising Coordrdinate 720 of 768
#
# Cruising Coordrdinate 721 of 768
#
# Cruising Coordrdinate 722 of 768
#
# Cruising Coordrdinate 723 of 768
#
# Cruising Coordrdinate 724 of 768
#
# Cruising Coordrdinate 725 of 768
#
# Cruising Coordrdinate 726 of 768
#
# Cruising Coordrdinate 727 of 768
#
# Cruising Coordrdinate 728 of 768
#
# Cruising Coordrdinate 729 of 768
#
# Cruising Coordrdinate 730 of 768
#
# Cruising Coordrdinate 731 of 768
#
# Cruising Coordrdinate 732 of 768
#
# Cruising Coordrdinate 733 of 768
#
# Cruising Coordrdinate 734 of 768
#
# Cruising Coordrdinate 735 of 768
#
# Cruising Coordrdinate 736 of 768
#
# Cruising Coordrdinate 737 of 768
#
# Cruising Coordrdinate 738 of 768
#
# Cruising Coordrdinate 739 of 768
#
# Cruising Coordrdinate 740 of 768
#
# Cruising Coordrdinate 741 of 768
#
# Cruising Coordrdinate 742 of 768
#
# Cruising Coordrdinate 743 of 768
#
# Cruising Coordrdinate 744 of 768
#
# Cruising Coordrdinate 745 of 768
#
# Cruising Coordrdinate 746 of 768
#
# Cruising Coordrdinate 747 of 768
#
# Cruising Coordrdinate 748 of 768
#
# Cruising Coordrdinate 749 of 768
#
# Cruising Coordrdinate 750 of 768
#
# Cruising Coordrdinate 751 of 768
#
# Cruising Coordrdinate 752 of 768
#
# Cruising Coordrdinate 753 of 768
#
# Cruising Coordrdinate 754 of 768
#
# Cruising Coordrdinate 755 of 768
#
# Cruising Coordrdinate 756 of 768
#
# Cruising Coordrdinate 757 of 768
#
# Cruising Coordrdinate 758 of 768
#
# Cruising Coordrdinate 759 of 768
#
# Cruising Coordrdinate 760 of 768
#
# Cruising Coordrdinate 761 of 768
#
# Cruising Coordrdinate 762 of 768
#
# Cruising Coordrdinate 763 of 768
#
# Cruising Coordrdinate 764 of 768
#
# Cruising Coordrdinate 765 of 768
#
# Cruising Coordrdinate 766 of 768
#
# Cruising Coordrdinate 767 of 768
#
# Cruising Coordrdinate 768 of 768
#
# FINAL STAGE: Begin final Guidance system
#
#
# Guidance: round FINAL
#
# 	round FINAL iteration:  0
#
# Already Trained and Tested combination (val score of 0.5012):
#             {'n_estimators': 400, 'max_depth': 12, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#             Current best combo (with val score 0.5128):
#                     {'n_estimators': 800, 'max_depth': 12, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 859 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.4787):
#             {'n_estimators': 800, 'max_depth': 6, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#             Current best combo (with val score 0.5128):
#                     {'n_estimators': 800, 'max_depth': 12, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 859 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.4861):
#             {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#             Current best combo (with val score 0.5128):
#                     {'n_estimators': 800, 'max_depth': 12, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 859 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.4962):
#             {'n_estimators': 800, 'max_depth': 12, 'max_samples': 0.55, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#             Current best combo (with val score 0.5128):
#                     {'n_estimators': 800, 'max_depth': 12, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 859 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.4788):
#             {'n_estimators': 800, 'max_depth': 12, 'max_samples': 0.4, 'max_features': 0.55, 'ccp_alpha': 1e-08, 'features': 20}
#             Current best combo (with val score 0.5128):
#                     {'n_estimators': 800, 'max_depth': 12, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 859 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.5128):
#             {'n_estimators': 800, 'max_depth': 12, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-06, 'features': 20}
#             Current best combo (with val score 0.5128):
#                     {'n_estimators': 800, 'max_depth': 12, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 859 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.5017):
#             {'n_estimators': 800, 'max_depth': 12, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 19}
#             Current best combo (with val score 0.5128):
#                     {'n_estimators': 800, 'max_depth': 12, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 859 of 378000 combinations so far
# Already Trained and Tested combination (val score of 0.4974):
#             {'n_estimators': 800, 'max_depth': 12, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 21}
#             Current best combo (with val score 0.5128):
#                     {'n_estimators': 800, 'max_depth': 12, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 859 of 378000 combinations so far
# 	round FINAL iteration:  1
#
# Trained and Tested combination 860 of 378000, taking 2.42 seconds to get val score of 0.5012:
#                 {'n_estimators': 400, 'max_depth': 12, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-06, 'features': 20},
#             Current best combo with val score 0.5128:
#                     {'n_estimators': 800, 'max_depth': 12, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
# Trained and Tested combination 861 of 378000, taking 4.58 seconds to get val score of 0.4787:
#                 {'n_estimators': 800, 'max_depth': 6, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-06, 'features': 20},
#             Current best combo with val score 0.5128:
#                     {'n_estimators': 800, 'max_depth': 12, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
# Already Trained and Tested combination (val score of 0.4861):
#             {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-06, 'features': 20}
#             Current best combo (with val score 0.5128):
#                     {'n_estimators': 800, 'max_depth': 12, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 861 of 378000 combinations so far
# Trained and Tested combination 862 of 378000, taking 6.92 seconds to get val score of 0.4962:
#                 {'n_estimators': 800, 'max_depth': 12, 'max_samples': 0.55, 'max_features': 0.4, 'ccp_alpha': 1e-06, 'features': 20},
#             Current best combo with val score 0.5128:
#                     {'n_estimators': 800, 'max_depth': 12, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
# Trained and Tested combination 863 of 378000, taking 5.67 seconds to get val score of 0.4788:
#                 {'n_estimators': 800, 'max_depth': 12, 'max_samples': 0.4, 'max_features': 0.55, 'ccp_alpha': 1e-06, 'features': 20},
#             Current best combo with val score 0.5128:
#                     {'n_estimators': 800, 'max_depth': 12, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
# Already Trained and Tested combination (val score of 0.5128):
#             {'n_estimators': 800, 'max_depth': 12, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#             Current best combo (with val score 0.5128):
#                     {'n_estimators': 800, 'max_depth': 12, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 863 of 378000 combinations so far
# Trained and Tested combination 864 of 378000, taking 6.84 seconds to get val score of 0.5128:
#                 {'n_estimators': 800, 'max_depth': 12, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 0.0001, 'features': 20},
#             Current best combo with val score 0.5128:
#                     {'n_estimators': 800, 'max_depth': 12, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
# Trained and Tested combination 865 of 378000, taking 5.09 seconds to get val score of 0.5017:
#                 {'n_estimators': 800, 'max_depth': 12, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-06, 'features': 19},
#             Current best combo with val score 0.5128:
#                     {'n_estimators': 800, 'max_depth': 12, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
# Trained and Tested combination 866 of 378000, taking 6.83 seconds to get val score of 0.4974:
#                 {'n_estimators': 800, 'max_depth': 12, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-06, 'features': 21},
#             Current best combo with val score 0.5128:
#                     {'n_estimators': 800, 'max_depth': 12, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
# % Combos Checked Thus Far: 866 out of 378000 which is 0.229101%
# Max Val Score:
#  0.512788
# Max Val Score Std:
#  0.082905
# Best Combo Train Score:
#  0.969697
# Best Combo Train Score Std:
#  0.001026
# Max Combo Index:
#  (5, 2, 0, 0, 0, 20) out of [6, 7, 5, 5, 5, 72] (note best combo is 0-indexed)
# Max Combo Hyperparamer Combination:
#  {'n_estimators': 800, 'max_depth': 12, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
# Max Combo Features:
#  ('procedure_225469', 'lods_score', 'procedure_224274', 'marital_status_0', 'marital_status_DIVORCED', 'marital_status_MARRIED', 'marital_status_WIDOWED', 'marital_status_SINGLE', 'procedure_223253', 'race_AMERICAN INDIAN/ALASKA NATIVE', 'race_ASIAN', 'race_ASIAN - ASIAN INDIAN', 'race_ASIAN - CHINESE', 'race_ASIAN - KOREAN', 'race_ASIAN - SOUTH EAST ASIAN', 'race_BLACK/AFRICAN', 'race_BLACK/AFRICAN AMERICAN', 'race_BLACK/CAPE VERDEAN', 'race_BLACK/CARIBBEAN ISLAND', 'race_HISPANIC OR LATINO', 'race_HISPANIC/LATINO - CENTRAL AMERICAN', 'race_HISPANIC/LATINO - COLUMBIAN', 'race_HISPANIC/LATINO - CUBAN', 'race_HISPANIC/LATINO - DOMINICAN', 'race_HISPANIC/LATINO - GUATEMALAN', 'race_HISPANIC/LATINO - HONDURAN', 'race_HISPANIC/LATINO - MEXICAN', 'race_HISPANIC/LATINO - PUERTO RICAN', 'race_HISPANIC/LATINO - SALVADORAN', 'race_MULTIPLE RACE/ETHNICITY', 'race_NATIVE HAWAIIAN OR OTHER PACIFIC ISLANDER', 'race_OTHER', 'race_PATIENT DECLINED TO ANSWER', 'race_PORTUGUESE', 'race_SOUTH AMERICAN', 'race_UNABLE TO OBTAIN', 'race_UNKNOWN', 'race_WHITE', 'race_WHITE - BRAZILIAN', 'race_WHITE - EASTERN EUROPEAN', 'race_WHITE - RUSSIAN', 'race_WHITE - OTHER EUROPEAN', 'procedure_227712', 'procedure_224276', 'admission_type_DIRECT OBSERVATION', 'admission_type_ELECTIVE', 'admission_type_EU OBSERVATION', 'admission_type_EW EMER.', 'admission_type_OBSERVATION ADMIT', 'admission_type_SURGICAL SAME DAY ADMISSION', 'admission_type_URGENT', 'admission_type_DIRECT EMER.', 'insurance_Medicare', 'insurance_Other', 'insurance_Medicaid', 'procedure_225792', 'procedure_228130', 'procedure_225817', 'procedure_224267', 'gender_F', 'gender_M', 'ventilation_used', 'hospital_stay_duration', 'oasis_score', 'procedure_228125', 'procedure_226124', 'procedure_225451')
# % Combos Checked: 866 out of 378000 which is 0.229101%
