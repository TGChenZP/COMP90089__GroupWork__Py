# %% [markdown]
# # Tuning Script

# %%
# Parameters subject to change in every script - involved in naming

MODEL = 'gbc'
PREPROCESSING = 'smote_normalise'
TUNER = 'yangzhoub'
OPTIMISED_METRIC = 'f1'

# %% [markdown]
# ---

# %%
# detect whether this is a google environment

COLAB_ENVIRONMENT = False

try:
    from google.colab import drive
    drive.mount('/content/drive')
    COLAB_ENVIRONMENT = True
except:
    pass
# Out:
# Mounted at /content/drive

# %%
import sys
import os
import pickle

if COLAB_ENVIRONMENT:
    home_directory = './drive/MyDrive/LAB/COMP90089__GroupWork__Py/' # my home directory is stored in ./LAB of google drive
    if MODEL == 'ebr':
        # !pip install interpret==0.5.0
    elif MODEL == 'cbr':
        # !pip install catboost
    elif MODEL in ['tf', 'mlp']:
        # !pip install PyTorch2Sklearn
    # !pip install JXAutoML
else:
    home_directory = '../../'

from JXAutoML.JiaoCheng_10CV import JiaoCheng_10CV as Tuner

import pandas as pd
# Out:
# Collecting JXAutoML
#   Downloading JXAutoML-0.4.4-py3-none-any.whl.metadata (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.2/67.2 kB 4.8 MB/s eta 0:00:00
# Downloading JXAutoML-0.4.4-py3-none-any.whl (52 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.1/52.1 kB 4.0 MB/s eta 0:00:00
# Installing collected packages: JXAutoML
# Successfully installed JXAutoML-0.4.4

# %%
# Parameters that are same for every script

FOLDS = 10  # we have decided to do 10 fold validation

SEED = 42

TASK_TYPE = 'Classification'  # this task is a classification task

# we have decided to tune features as hp
TUNE_FEATURES_AS_HYPERPARAMETERS = True

# %% [markdown]
# ---

# %%
# model to use to tune
from sklearn.ensemble import GradientBoostingClassifier as clf

# what values to try for each hyperparameter
parameter_choices = {
    'n_estimators': (25, 50, 100, 200),
    'learning_rate': (0.0001, 0.001, 0.01, 0.1, 1, 10, 100),
    'subsample': (0.4, 0.55, 0.7, 0.85, 1),
    'max_features': (0.4, 0.55, 0.7, 0.85, 1),
    'max_depth': (3, 6, 12, 24, 48, 96, 192),
    'tol': (0.0001, 0.001, 0.01, 0.1, 1, 10),
    'ccp_alpha': (0.0001, 0.001, 0.01, 0.1, 1, 10)

}

# what values to set non-tuneable parameters/hyperparameters
non_tunable_hyperparameters_dict = {
                                    'random_state': 42,
                                    'verbose': 0
                                    }

# what order to tune hyperparameters in (JiaoCheng specific)
tuning_order = ['features',
                'max_depth',
                'max_features',
                'subsample',
                'n_estimators',
                'ccp_alpha',
                'tol',
                'learning_rate']

# what order to tune hyperparameters in (JiaoCheng specific)
default_hyperparameter_values = {
                                'features': 0,
                                'n_estimators': 50,
                                'max_depth': 12,
                                'subsample': 0.7,
                                'max_features': 0.7,
                                'tol': 0.0001,
                                'learning_rate': 0.001,
                                'ccp_alpha': 0.01
                                }

# %% [markdown]
# ---

# %% [markdown]
# Read in and Prepare Data

# %%
# Import data and store as lists

train_x_list = []
train_y_list = []
val_x_list = []
val_y_list = []

for i in range(FOLDS):
    train_data = pd.read_csv(
        f'{home_directory}data/curated/modelling/{PREPROCESSING}/train_{i}.csv')
    val_data = pd.read_csv(
        f'{home_directory}data/curated/modelling/{PREPROCESSING}/val_{i}.csv')

    # get the correct rows for X and y
    train_x = train_data.drop(
        ['mortality_status', 'subject_id', 'hadm_id', 'stay_id'], axis=1)
    train_y = train_data['mortality_status']
    val_x = val_data.drop(
        ['mortality_status', 'subject_id', 'hadm_id', 'stay_id'], axis=1)
    val_y = val_data['mortality_status']

    train_x_list.append(train_x)
    train_y_list.append(train_y)
    val_x_list.append(val_x)
    val_y_list.append(val_y)

# %%
# Import feature importance ordering

with open(f'{home_directory}models/xgb_feature_importance_ordering_{PREPROCESSING}.pickle', 'rb') as f:
    feature_importance_ordering = pickle.load(f)

# %% [markdown]
# Set parameters

# %%
# initialisation
tuner = Tuner()

print('---')

# define what model we are tuning
tuner.read_in_model(clf, TASK_TYPE, optimised_metric = OPTIMISED_METRIC)

print('---')

# read in the data for training and validation
tuner.read_in_data(train_x_list, train_y_list, val_x_list, val_y_list)

print('---')

# set what hp values to tune
tuner.set_hyperparameters(parameter_choices)
# WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

# set up hp values that need to be changed from default but NOT to be tuned
tuner.set_non_tuneable_hyperparameters(non_tunable_hyperparameters_dict)

print('---')

# set up feature importance ordering

if TUNE_FEATURES_AS_HYPERPARAMETERS:
  tuner.set_features(feature_importance_ordering)
  # WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

# set up the order of hyperparameters when iteratively tuning using JiaoCheng
tuner.set_tuning_order(tuning_order)

print('---')

# set up the default hp values for first iteration of tuning JiaoCheng
tuner.set_hyperparameter_default_values(default_hyperparameter_values)

print('---')

try: # try to read in previous results to continue tuning ...
  tuner.read_in_tuning_result_df(f'{home_directory}models/tuning/{TUNER}_{MODEL}_{PREPROCESSING}.csv')
except:
  print('No previous tuning data read in')

print('---')

# set up where to save the tuning result csv
tuner.set_tuning_result_saving_address(f'{home_directory}models/tuning/{TUNER}_{MODEL}_{PREPROCESSING}.csv')

print('---')

# set up where to save the current best model
tuner.set_best_model_saving_address(f'{home_directory}models/tmp_models/{TUNER}_{MODEL}_{PREPROCESSING}')
# Out:
# JiaoCheng Initialised
# ---
# Successfully read in model <class 'sklearn.ensemble._gb.GradientBoostingClassifier'>, which is a Classification model optimising for f1
# ---
# Read in Train X data list
# Read in Train y data list
# Read in Val X data list
# Read in Val y data list
# ---
# Successfully recorded hyperparameter choices
# ---
# Successfully recorded non_tuneable_hyperparameter choices
# ---
# Successfully recorded tuneable feature combination choices and updated relevant internal structures
# ---
# ---
# ---
# No previous tuning data read in
# ---
# Successfully set tuning output address
# ---
# Successfully set best model output address

# %%
# ignore warnings

import warnings
warnings.filterwarnings("ignore")

# %%
# begin tuning ... (or continue training)

tuner.tune()
# Out:
# Default combo: [1, 1, 2, 2, 2, 0, 2, 0]
#
#
# ROUND 1
#
# Round 1
# Hyperparameter: features (index: 7)
#
# Trained and Tested combination 1 of 8996400, taking 0.12 seconds to get val score of 0.317:
#                 {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 0},
#             Current best combo with val score 0.317:
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 0}
# Trained and Tested combination 2 of 8996400, taking 0.12 seconds to get val score of 0.3127:
#                 {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 1},
#             Current best combo with val score 0.317:
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 0}
# Trained and Tested combination 3 of 8996400, taking 0.32 seconds to get val score of 0.2162:
#                 {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 2},
#             Current best combo with val score 0.317:
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 0}
# Trained and Tested combination 4 of 8996400, taking 0.32 seconds to get val score of 0.3227:
#                 {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 3},
#             Current best combo with val score 0.3227:
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 3}
# Trained and Tested combination 5 of 8996400, taking 0.26 seconds to get val score of 0.2945:
#                 {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 4},
#             Current best combo with val score 0.3227:
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 3}
# Trained and Tested combination 6 of 8996400, taking 0.3 seconds to get val score of 0.2638:
#                 {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 5},
#             Current best combo with val score 0.3227:
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 3}
# Trained and Tested combination 7 of 8996400, taking 0.45 seconds to get val score of 0.2391:
#                 {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 6},
#             Current best combo with val score 0.3227:
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 3}
# Trained and Tested combination 8 of 8996400, taking 0.36 seconds to get val score of 0.3202:
#                 {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 7},
#             Current best combo with val score 0.3227:
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 3}
# Trained and Tested combination 9 of 8996400, taking 0.42 seconds to get val score of 0.2866:
#                 {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 8},
#             Current best combo with val score 0.3227:
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 3}
# Trained and Tested combination 10 of 8996400, taking 0.59 seconds to get val score of 0.0288:
#                 {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 9},
#             Current best combo with val score 0.3227:
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 3}
# Trained and Tested combination 11 of 8996400, taking 0.6 seconds to get val score of 0.0162:
#                 {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 10},
#             Current best combo with val score 0.3227:
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 3}
# Trained and Tested combination 12 of 8996400, taking 0.74 seconds to get val score of 0.051:
#                 {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 11},
#             Current best combo with val score 0.3227:
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 3}
# Trained and Tested combination 13 of 8996400, taking 1.37 seconds to get val score of 0.0464:
#                 {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 12},
#             Current best combo with val score 0.3227:
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 3}
# Trained and Tested combination 14 of 8996400, taking 1.12 seconds to get val score of 0.0716:
#                 {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 13},
#             Current best combo with val score 0.3227:
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 3}
# Trained and Tested combination 15 of 8996400, taking 1.03 seconds to get val score of 0.1055:
#                 {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 14},
#             Current best combo with val score 0.3227:
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 3}
# Trained and Tested combination 16 of 8996400, taking 1.14 seconds to get val score of 0.0681:
#                 {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 15},
#             Current best combo with val score 0.3227:
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 3}
# Trained and Tested combination 17 of 8996400, taking 1.16 seconds to get val score of 0.0787:
#                 {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 16},
#             Current best combo with val score 0.3227:
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 3}
# Trained and Tested combination 18 of 8996400, taking 1.31 seconds to get val score of 0.0932:
#                 {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 17},
#             Current best combo with val score 0.3227:
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 3}
# Trained and Tested combination 19 of 8996400, taking 1.34 seconds to get val score of 0.0321:
#                 {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 18},
#             Current best combo with val score 0.3227:
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 3}
# Trained and Tested combination 20 of 8996400, taking 1.34 seconds to get val score of 0.0427:
#                 {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features':

#                 {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.85, 'max_depth': 3, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 3},
#             Current best combo with val score 0.3242:
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 3, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 3}
# Trained and Tested combination 61 of 8996400, taking 0.14 seconds to get val score of 0.3158:
#                 {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 1, 'max_depth': 3, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 3},
#             Current best combo with val score 0.3242:
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 3, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 3}
#
# Best combo after this hyperparameter: (1, 1, 2, 2, 0, 0, 2, 3) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 1
# Hyperparameter: subsample (index: 2)
#
# Trained and Tested combination 62 of 8996400, taking 0.19 seconds to get val score of 0.2969:
#                 {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.4, 'max_features': 0.7, 'max_depth': 3, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 3},
#             Current best combo with val score 0.3242:
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 3, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 3}
# Trained and Tested combination 63 of 8996400, taking 0.13 seconds to get val score of 0.3226:
#                 {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.55, 'max_features': 0.7, 'max_depth': 3, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 3},
#             Current best combo with val score 0.3242:
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 3, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 3}
# Already Trained and Tested combination (val score of 0.3242):
#             {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 3, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 3}
#             Current best combo (with val score 0.3242):
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 3, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 3}
#         Has trained 63 of 8996400 combinations so far
# Trained and Tested combination 64 of 8996400, taking 0.15 seconds to get val score of 0.3104:
#                 {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.85, 'max_features': 0.7, 'max_depth': 3, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 3},
#             Current best combo with val score 0.3242:
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 3, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 3}
# Trained and Tested combination 65 of 8996400, taking 0.13 seconds to get val score of 0.2943:
#                 {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 1, 'max_features': 0.7, 'max_depth': 3, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 3},
#             Current best combo with val score 0.3242:
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 3, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 3}
#
# Best combo after this hyperparameter: (1, 1, 2, 2, 0, 0, 2, 3) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 1
# Hyperparameter: n_estimators (index: 0)
#
# Trained and Tested combination 66 of 8996400, taking 0.08 seconds to get val score of 0.2853:
#                 {'n_estimators': 25, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 3, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 3},
#             Current best combo with val score 0.3242:
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 3, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 3}
# Already Trained and Tested combination (val score of 0.3242):
#             {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 3, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 3}
#             Current best combo (with val score 0.3242):
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 3, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 3}
#         Has trained 66 of 8996400 combinations so far
# Trained and Tested combination 67 of 8996400, taking 0.29 seconds to get val score of 0.3041:
#                 {'n_estimators': 100, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 3, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 3},
#             Current best combo with val score 0.3242:
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 3, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 3}
# Trained and Tested combination 68 of 8996400, taking 0.55 seconds to get val score of 0.2614:
#                 {'n_estimators': 200, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 3, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 3},
#             Current best combo with val score 0.3242:
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 3, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 3}
#
# Best combo after this hyperparameter: (1, 1, 2, 2, 0, 0, 2, 3) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 1
# Hyperparameter: ccp_alpha (index: 6)
#
# Trained and Tested combination 69 of 8996400, taking 0.21 seconds to get val score of 0.1636:
#                 {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 3, 'tol': 0.0001, 'ccp_alpha': 0.0001, 'features': 3},
#             Current best combo with val score 0.3242:
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 3, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 3}
# Trained and Tested combination 70 of 8996400, taking 0.15 seconds to get val score of 0.1611:
#                 {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 3, 'tol': 0.0001, 'ccp_alpha': 0.001, 'features': 3},
#             Current best combo with val score 0.3242:
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 3, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 3}
# Already Trained and Tested combination (val score of 0.3242):
#             {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 3, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 3}
#             Current best combo (with val score 0.3242):
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 3, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 3}
#         Has trained 70 of 8996400 combinations so far
# Trained and Tested combination 71 of 8996400, taking 0.12 seconds to get val score of 0.3117:
#                 {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 3, 'tol': 0.0001, 'ccp_alpha': 0.1, 'features': 3},
#             Current best combo with val score 0.3242:
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 3, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 3}
# Trained and Tested combination 72 of 8996400, taking 0.17 seconds to get val score of 0.3117:
#                 {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 3, 'tol': 0.0001, 'ccp_alpha': 1, 'features': 3},
#             Current best combo with val score 0.3242:
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 3, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 3}
# Trained and Tested combination 73 of 8996400, taking 0.18 seconds to get val score of 0.3117:
#                 {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 3, 'tol': 0.0001, 'ccp_alpha': 10, 'features': 3},
#             Current best combo with val score 0.3242:
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 3, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 3}
#
# Best combo after this hyperparameter: (1, 1, 2, 2, 0, 0, 2, 3) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 1
# Hyperparameter: tol (index: 5)
#
# Already Trained and Tested combination (val score of 0.3242):
#             {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 3, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 3}
#             Current best combo (with val score 0.3242):
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 3, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 3}
#         Has trained 73 of 8996400 combinations so far
# Trained and Tested combination 74 of 8996400, taking 0.14 seconds to get val score of 0.3242:
#                 {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 3, 'tol': 0.001, 'ccp_alpha': 0.01, 'features': 3},
#             Current best combo with val score 0.3242:
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 3, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 3}
# Trained and Tested combination 75 of 8996400, taking 0.13 seconds to get val score of 0.3242:
#                 {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 3, 'tol': 0.01, 'ccp_alpha': 0.01, 'features': 3},
#             Current best combo with val score 0.3242:
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 3, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 3}
# Trained and Tested combination 76 of 8996400, taking 0.13 seconds to get val score of 0.3242:
#                 {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 3, 'tol': 0.1, 'ccp_alpha': 0.01, 'features': 3},
#             Current best combo with val score 0.3242:
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 3, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 3}
# Trained and Tested combination 77 of 8996400, taking 0.13 seconds to get val score of 0.3242:
#                 {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 3, 'tol': 1, 'ccp_alpha': 0.01, 'features': 3},
#             Current best combo with val score 0.3242:
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 3, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 3}
# Trained and Tested combination 78 of 8996400, taking 0.13 seconds to get val score of 0.3242:
#                 {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 3, 'tol': 10, 'ccp_alpha': 0.01, 'features': 3},
#             Current best combo with val score 0.3242:
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 3, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 3}
#
# Best combo after this hyperparameter: (1, 1, 2, 2, 0, 0, 2, 3) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 1
# Hyperparameter: learning_rate (index: 1)
#
# Trained and Tested combination 79 of 8996400, taking 0.13 seconds to get val score of 0.3227:
#                 {'n_estimators': 50, 'learning_rate': 0.0001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 3, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 3},
#             Current best combo with val score 0.3242:
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 3, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 3}
# Already Trained and Tested combination (val score of 0.3242):
#             {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 3, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 3}
#             Current best combo (with val score 0.3242):
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 3, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 3}
#         Has trained 79 of 8996400 combinations so far
# Trained and Tested combination 80 of 8996400, taking 0.19 seconds to get val score of 0.2075:
#                 {'n_estimators': 50, 'learning_rate': 0.01, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 3, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 3},
#             Current best combo with val score 0.3242:
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 3, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 3}
# Trained and Tested combination 81 of 8996400, taking 0.12 seconds to get val score of 0.1071:
#                 {'n_estimators': 50, 'learning_rate': 0.1, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 3, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 3},
#             Current best combo with val score 0.3242:
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 3, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 3}
# Trained and Tested combination 82 of 8996400, taking 0.12 seconds to get val score of 0.3226:
#                 {'n_estimators': 50, 'learning_rate': 1, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 3, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 3},
#             Current best combo with val score 0.3242:
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 3, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 3}
# Trained and Tested combination 83 of 8996400, taking 0.14 seconds to get val score of 0.2562:
#                 {'n_estimators': 50, 'learning_rate': 10, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 3, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 3},
#             Current best combo with val score 0.3242:
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 3, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 3}
# Trained and Tested combination 84 of 8996400, taking 0.14 seconds to get val score of 0.303:
#                 {'n_estimators': 50, 'learning_rate': 100, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 3, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 3},
#             Current best combo with val score 0.3242:
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 3, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 3}
#
# Best combo after this hyperparameter: (1, 1, 2, 2, 0, 0, 2, 3) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# ROUND 2
#
# Round 2
# Hyperparameter: features (index: 7)
#
# Trained and Tested combination 85 of 8996400, taking 0.1 seconds to get val score of 0.3127:
#                 {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 3, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 0},
#             Current best combo with val score 0.3242:
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 3, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 3}
# Trained and Tested combination 86 of 8996400, taking 0.1 seconds to get val score of 0.3127:
#                 {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 3, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 1},
#             Current best combo with val score 0.3242:
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 3, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 3}
# Trained and Tested combination 87 of 8996400, taking 0.19 seconds to get val score of 0.2177:
#                 {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 3, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 2},
#             Current best combo with val score 0.3242:
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 3, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 3}
# Already Trained and Tested combination (val score of 0.3242):
#             {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 3, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 3}
#             Current best combo (with val score 0.3242):
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 3, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 3}
#         Has trained 87 of 8996400 combinations so far
# Trained and Tested combination 88 of 8996400, taking 0.2 seconds to get val score of 0.2945:
# ...
#             Current best combo (with val score 0.3242):
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 3, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 3}
#         Has trained 134 of 8996400 combinations so far
#
# Best combo after this hyperparameter: (1, 1, 2, 2, 0, 0, 2, 3) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 2
# Hyperparameter: subsample (index: 2)
#
# Already Trained and Tested combination (val score of 0.2969):
#             {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.4, 'max_features': 0.7, 'max_depth': 3, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 3}
#             Current best combo (with val score 0.3242):
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 3, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 3}
#         Has trained 134 of 8996400 combinations so far
# Already Trained and Tested combination (val score of 0.3226):
#             {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.55, 'max_features': 0.7, 'max_depth': 3, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 3}
#             Current best combo (with val score 0.3242):
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 3, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 3}
#         Has trained 134 of 8996400 combinations so far
# Already Trained and Tested combination (val score of 0.3242):
#             {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 3, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 3}
#             Current best combo (with val score 0.3242):
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 3, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 3}
#         Has trained 134 of 8996400 combinations so far
# Already Trained and Tested combination (val score of 0.3104):
#             {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.85, 'max_features': 0.7, 'max_depth': 3, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 3}
#             Current best combo (with val score 0.3242):
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 3, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 3}
#         Has trained 134 of 8996400 combinations so far
# Already Trained and Tested combination (val score of 0.2943):
#             {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 1, 'max_features': 0.7, 'max_depth': 3, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 3}
#             Current best combo (with val score 0.3242):
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 3, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 3}
#         Has trained 134 of 8996400 combinations so far
#
# Best combo after this hyperparameter: (1, 1, 2, 2, 0, 0, 2, 3) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 2
# Hyperparameter: n_estimators (index: 0)
#
# Already Trained and Tested combination (val score of 0.2853):
#             {'n_estimators': 25, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 3, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 3}
#             Current best combo (with val score 0.3242):
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 3, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 3}
#         Has trained 134 of 8996400 combinations so far
# Already Trained and Tested combination (val score of 0.3242):
#             {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 3, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 3}
#             Current best combo (with val score 0.3242):
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 3, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 3}
#         Has trained 134 of 8996400 combinations so far
# Already Trained and Tested combination (val score of 0.3041):
#             {'n_estimators': 100, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 3, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 3}
#             Current best combo (with val score 0.3242):
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 3, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 3}
#         Has trained 134 of 8996400 combinations so far
# Already Trained and Tested combination (val score of 0.2614):
#             {'n_estimators': 200, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 3, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 3}
#             Current best combo (with val score 0.3242):
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 3, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 3}
#         Has trained 134 of 8996400 combinations so far
#
# Best combo after this hyperparameter: (1, 1, 2, 2, 0, 0, 2, 3) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 2
# Hyperparameter: ccp_alpha (index: 6)
#
# Already Trained and Tested combination (val score of 0.1636):
#             {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 3, 'tol': 0.0001, 'ccp_alpha': 0.0001, 'features': 3}
#             Current best combo (with val score 0.3242):
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 3, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 3}
#         Has trained 134 of 8996400 combinations so far
# Already Trained and Tested combination (val score of 0.1611):
#             {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 3, 'tol': 0.0001, 'ccp_alpha': 0.001, 'features': 3}
#             Current best combo (with val score 0.3242):
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 3, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 3}
#         Has trained 134 of 8996400 combinations so far
# Already Trained and Tested combination (val score of 0.3242):
#             {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 3, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 3}
#             Current best combo (with val score 0.3242):
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 3, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 3}
#         Has trained 134 of 8996400 combinations so far
# Already Trained and Tested combination (val score of 0.3117):
#             {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 3, 'tol': 0.0001, 'ccp_alpha': 0.1, 'features': 3}
#             Current best combo (with val score 0.3242):
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 3, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 3}
#         Has trained 134 of 8996400 combinations so far
# Already Trained and Tested combination (val score of 0.3117):
#             {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 3, 'tol': 0.0001, 'ccp_alpha': 1, 'features': 3}
#             Current best combo (with val score 0.3242):
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 3, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 3}
#         Has trained 134 of 8996400 combinations so far
# Already Trained and Tested combination (val score of 0.3117):
#             {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 3, 'tol': 0.0001, 'ccp_alpha': 10, 'features': 3}
#             Current best combo (with val score 0.3242):
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 3, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 3}
#         Has trained 134 of 8996400 combinations so far
#
# Best combo after this hyperparameter: (1, 1, 2, 2, 0, 0, 2, 3) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 2
# Hyperparameter: tol (index: 5)
#
# Already Trained and Tested combination (val score of 0.3242):
#             {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 3, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 3}
#             Current best combo (with val score 0.3242):
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 3, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 3}
#         Has trained 134 of 8996400 combinations so far
# Already Trained and Tested combination (val score of 0.3242):
#             {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 3, 'tol': 0.001, 'ccp_alpha': 0.01, 'features': 3}
#             Current best combo (with val score 0.3242):
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 3, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 3}
#         Has trained 134 of 8996400 combinations so far
# Already Trained and Tested combination (val score of 0.3242):
#             {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 3, 'tol': 0.01, 'ccp_alpha': 0.01, 'features': 3}
#             Current best combo (with val score 0.3242):
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 3, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 3}
#         Has trained 134 of 8996400 combinations so far
# Already Trained and Tested combination (val score of 0.3242):
#             {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 3, 'tol': 0.1, 'ccp_alpha': 0.01, 'features': 3}
#             Current best combo (with val score 0.3242):
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 3, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 3}
#         Has trained 134 of 8996400 combinations so far
# Already Trained and Tested combination (val score of 0.3242):
#             {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 3, 'tol': 1, 'ccp_alpha': 0.01, 'features': 3}
#             Current best combo (with val score 0.3242):
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 3, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 3}
#         Has trained 134 of 8996400 combinations so far
# Already Trained and Tested combination (val score of 0.3242):
#             {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 3, 'tol': 10, 'ccp_alpha': 0.01, 'features': 3}
#             Current best combo (with val score 0.3242):
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 3, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 3}
#         Has trained 134 of 8996400 combinations so far
#
# Best combo after this hyperparameter: (1, 1, 2, 2, 0, 0, 2, 3) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 2
# Hyperparameter: learning_rate (index: 1)
#
# Already Trained and Tested combination (val score of 0.3227):
#             {'n_estimators': 50, 'learning_rate': 0.0001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 3, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 3}
#             Current best combo (with val score 0.3242):
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 3, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 3}
#         Has trained 134 of 8996400 combinations so far
# Already Trained and Tested combination (val score of 0.3242):
#             {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 3, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 3}
#             Current best combo (with val score 0.3242):
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 3, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 3}
#         Has trained 134 of 8996400 combinations so far
# Already Trained and Tested combination (val score of 0.2075):
#             {'n_estimators': 50, 'learning_rate': 0.01, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 3, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 3}
#             Current best combo (with val score 0.3242):
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 3, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 3}
#         Has trained 134 of 8996400 combinations so far
# Already Trained and Tested combination (val score of 0.1071):
#             {'n_estimators': 50, 'learning_rate': 0.1, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 3, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 3}
#             Current best combo (with val score 0.3242):
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 3, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 3}
#         Has trained 134 of 8996400 combinations so far
# Already Trained and Tested combination (val score of 0.3226):
#             {'n_estimators': 50, 'learning_rate': 1, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 3, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 3}
#             Current best combo (with val score 0.3242):
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 3, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 3}
#         Has trained 134 of 8996400 combinations so far
# Already Trained and Tested combination (val score of 0.2562):
#             {'n_estimators': 50, 'learning_rate': 10, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 3, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 3}
#             Current best combo (with val score 0.3242):
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 3, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 3}
#         Has trained 134 of 8996400 combinations so far
# Already Trained and Tested combination (val score of 0.303):
#             {'n_estimators': 50, 'learning_rate': 100, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 3, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 3}
#             Current best combo (with val score 0.3242):
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 3, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 3}
#         Has trained 134 of 8996400 combinations so far
#
# Best combo after this hyperparameter: (1, 1, 2, 2, 0, 0, 2, 3) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
# Max Val Score:
#  0.324241
# Max Val Score Std:
#  0.044391
# Best Combo Train Score:
#  0.786861
# Best Combo Train Score Std:
#  0.004144
# Max Combo Index:
#  (1, 1, 2, 2, 0, 0, 2, 3) out of [4, 7, 5, 5, 7, 6, 6, 51] (note best combo is 0-indexed)
# Max Combo Hyperparamer Combination:
#  {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 3, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 3}
# Max Combo Features:
#  ('marital_status_DIVORCED', 'marital_status_MARRIED', 'marital_status_SINGLE', 'marital_status_WIDOWED', 'marital_status_0', 'procedure_224276', 'lods_score', 'procedure_227712')
# % Combos Checked: 134 out of 8996400 which is 0.0014889999999999999%
