# %% [markdown]
# # Tuning Script

# %%
# Parameters subject to change in every script - involved in naming

MODEL = '0R'
PREPROCESSING = 'normalise'
TUNER = 'yangzhoub'
OPTIMISED_METRIC = 'f1'

# %% [markdown]
# ---

# %%
# detect whether this is a google environment

COLAB_ENVIRONMENT = False

try:
    from google.colab import drive
    drive.mount('/content/drive')
    COLAB_ENVIRONMENT = True
except:
    pass

# %%
import sys
import os
import pickle

if COLAB_ENVIRONMENT:
    home_directory = './drive/MyDrive/LAB/COMP90089__GROUPWORK__PY/' # my home directory is stored in ./LAB of google drive
    if MODEL == 'ebr':
        # !pip install interpret==0.5.0
    elif MODEL == 'cbr':
        # !pip install catboost
    elif MODEL in ['tf', 'mlp']:
        # !pip install PyTorch2Sklearn
    # !pip install JXAutoML
else:
    home_directory = '../../'

from JXAutoML.YangZhouB_10CV import YangZhouB_10CV as Tuner

import pandas as pd

# %%
# Parameters that are same for every script

FOLDS = 10  # we have decided to do 10 fold validation

SEED = 42

TASK_TYPE = 'Classification'  # this task is a classification task

# we have decided to tune features as hp
TUNE_FEATURES_AS_HYPERPARAMETERS = True

# %% [markdown]
# ---

# %%
# model to use to tune
from sklearn.dummy import DummyClassifier as clf

# what values to try for each hyperparameter
parameter_choices = {
    'strategy': ("most_frequent", "prior", "stratified", "uniform"),
}

# what values to set non-tuneable parameters/hyperparameters
non_tunable_hyperparameters_dict = {
    'random_state': SEED,
}

# %% [markdown]
# ---

# %% [markdown]
# Read in and Prepare Data

# %%
# Import data and store as lists

train_x_list = []
train_y_list = []
val_x_list = []
val_y_list = []

for i in range(FOLDS):
    train_data = pd.read_csv(
        f'{home_directory}data/curated/modelling/{PREPROCESSING}/train_{i}.csv')
    val_data = pd.read_csv(
        f'{home_directory}data/curated/modelling/{PREPROCESSING}/val_{i}.csv')

    # get the correct rows for X and y
    train_x = train_data.drop(
        ['mortality_status', 'subject_id', 'hadm_id', 'stay_id'], axis=1)
    train_y = train_data['mortality_status']
    val_x = val_data.drop(
        ['mortality_status', 'subject_id', 'hadm_id', 'stay_id'], axis=1)
    val_y = val_data['mortality_status']

    train_x_list.append(train_x)
    train_y_list.append(train_y)
    val_x_list.append(val_x)
    val_y_list.append(val_y)

# %%
# Import feature importance ordering

with open(f'{home_directory}models/xgb_feature_importance_ordering_{PREPROCESSING}.pickle', 'rb') as f:
    feature_importance_ordering = pickle.load(f)

# %% [markdown]
# Set parameters

# %%
# initialisation
tuner = Tuner()

print('---')

# define what model we are tuning
tuner.read_in_model(clf, TASK_TYPE, optimised_metric=OPTIMISED_METRIC)

print('---')

# read in the data for training and validation
tuner.read_in_data(train_x_list, train_y_list, val_x_list, val_y_list)

print('---')

# set what hp values to tune
tuner.set_hyperparameters(parameter_choices)
# WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

# set up hp values that need to be changed from default but NOT to be tuned
tuner.set_non_tuneable_hyperparameters(non_tunable_hyperparameters_dict)

print('---')

# set up feature importance ordering

if TUNE_FEATURES_AS_HYPERPARAMETERS:
    tuner.set_features(feature_importance_ordering)
    # WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

try:  # try to read in previous results to continue tuning ...
    tuner.read_in_tuning_result_df(
        f'{home_directory}models/tuning/{TUNER}_{MODEL}_{PREPROCESSING}.csv')
except:
    print('No previous tuning data read in')

print('---')

# set up where to save the tuning result csv
tuner.set_tuning_result_saving_address(
    f'{home_directory}models/tuning/{TUNER}_{MODEL}_{PREPROCESSING}.csv')

print('---')

# set up where to save the current best model
tuner.set_best_model_saving_address(
    f'{home_directory}models/tmp_models/{TUNER}_{MODEL}_{PREPROCESSING}')
# Out:
# YangZhouB Initialised
# ---
# Successfully read in model <class 'sklearn.dummy.DummyClassifier'>, which is a Classification model optimising for f1
# ---
# Read in Train X data list
# Read in Train y data list
# Read in Val X data list
# Read in Val y data list
# ---
# Successfully recorded hyperparameter choices
# ---
# Successfully recorded non_tuneable_hyperparameter choices
# ---
# Successfully recorded tuneable feature combination choices and updated relevant internal structures
# ---
# No previous tuning data read in
# ---
# Successfully set tuning output address
# ---
# Successfully set best model output address

# %%
# ignore warnings

import warnings
warnings.filterwarnings("ignore")

# %%
# begin tuning ... (or continue training)

tuner.tune()
# Out:
# BEGIN TUNING
#
#
# STAGE ZERO: Tune all Cruise combinations
#
#
# Trained and Tested combination 1 of 288, taking 0.0 seconds to get val score of 0.0:
#                 {'strategy': 'most_frequent', 'features': 45},
#             Current best combo with val score 0.0:
#                     {'strategy': 'most_frequent', 'features': 45}
# Trained and Tested combination 2 of 288, taking 0.0 seconds to get val score of 0.2668:
#                 {'strategy': 'uniform', 'features': 45},
#             Current best combo with val score 0.2668:
#                     {'strategy': 'uniform', 'features': 45}
# Trained and Tested combination 3 of 288, taking 0.0 seconds to get val score of 0.2668:
#                 {'strategy': 'uniform', 'features': 63},
#             Current best combo with val score 0.2668:
#                     {'strategy': 'uniform', 'features': 45}
# Trained and Tested combination 4 of 288, taking 0.0 seconds to get val score of 0.0:
#                 {'strategy': 'most_frequent', 'features': 20},
#             Current best combo with val score 0.2668:
#                     {'strategy': 'uniform', 'features': 45}
# Trained and Tested combination 5 of 288, taking 0.0 seconds to get val score of 0.2668:
#                 {'strategy': 'uniform', 'features': 71},
#             Current best combo with val score 0.2668:
#                     {'strategy': 'uniform', 'features': 45}
# Trained and Tested combination 6 of 288, taking 0.0 seconds to get val score of 0.2668:
#                 {'strategy': 'uniform', 'features': 15},
#             Current best combo with val score 0.2668:
#                     {'strategy': 'uniform', 'features': 45}
# Trained and Tested combination 7 of 288, taking 0.0 seconds to get val score of 0.0:
#                 {'strategy': 'most_frequent', 'features': 40},
#             Current best combo with val score 0.2668:
#                     {'strategy': 'uniform', 'features': 45}
# Trained and Tested combination 8 of 288, taking 0.0 seconds to get val score of 0.2668:
#                 {'strategy': 'uniform', 'features': 67},
#             Current best combo with val score 0.2668:
#                     {'strategy': 'uniform', 'features': 45}
# Trained and Tested combination 9 of 288, taking 0.0 seconds to get val score of 0.2668:
#                 {'strategy': 'uniform', 'features': 5},
#             Current best combo with val score 0.2668:
#                     {'strategy': 'uniform', 'features': 45}
# Trained and Tested combination 10 of 288, taking 0.0 seconds to get val score of 0.0:
#                 {'strategy': 'most_frequent', 'features': 55},
#             Current best combo with val score 0.2668:
#                     {'strategy': 'uniform', 'features': 45}
# Trained and Tested combination 11 of 288, taking 0.0 seconds to get val score of 0.2668:
#                 {'strategy': 'uniform', 'features': 59},
#             Current best combo with val score 0.2668:
#                     {'strategy': 'uniform', 'features': 45}
# Trained and Tested combination 12 of 288, taking 0.0 seconds to get val score of 0.0:
#                 {'strategy': 'most_frequent', 'features': 63},
#             Current best combo with val score 0.2668:
#                     {'strategy': 'uniform', 'features': 45}
# Trained and Tested combination 13 of 288, taking 0.0 seconds to get val score of 0.2668:
#                 {'strategy': 'uniform', 'features': 25},
#             Current best combo with val score 0.2668:
#                     {'strategy': 'uniform', 'features': 45}
# Trained and Tested combination 14 of 288, taking 0.0 seconds to get val score of 0.0:
#                 {'strategy': 'most_frequent', 'features': 59},
#             Current best combo with val score 0.2668:
#                     {'strategy': 'uniform', 'features': 45}
# Trained and Tested combination 15 of 288, taking 0.0 seconds to get val score of 0.0:
#                 {'strategy': 'most_frequent', 'features': 25},
#             Current best combo with val score 0.2668:
#                     {'strategy': 'uniform', 'features': 45}
# Trained and Tested combination 16 of 288, taking 0.0 seconds to get val score of 0.2668:
#                 {'strategy': 'uniform', 'features': 40},
#             Current best combo with val score 0.2668:
#                     {'strategy': 'uniform', 'features': 45}
# Trained and Tested combination 17 of 288, taking 0.0 seconds to get val score of 0.0:
#                 {'strategy': 'most_frequent', 'features': 30},
#             Current best combo with val score 0.2668:
#                     {'strategy': 'uniform', 'features': 45}
# Trained and Tested combination 18 of 288, taking 0.0 seconds to get val score of 0.2668:
#                 {'strategy': 'uniform', 'features': 30},
#             Current best combo with val score 0.2668:
#                     {'strategy': 'uniform', 'features': 45}
# Trained and Tested combination 19 of 288, taking 0.0 seconds to get val score of 0.0:
#                 {'strategy': 'most_frequent', 'features': 5},
#             Current best combo with val score 0.2668:
#                     {'strategy': 'uniform', 'features': 45}
# Trained and Tested combination 20 of 288, taking 0.0 seconds to get val score of 0.0:
#                 {'strategy': 'most_frequent', 'features': 71},
#             Current best combo with val score 0.2668:
#                     {'strategy': 'uniform', 'features': 45}
# Trained and Tested combination 21 of 288, taking 0.0 seconds to get val score of 0.0:
#                 {'strategy': 'most_frequent', 'features': 35},
#             Current best combo with val score 0.2668:
#                     {'strategy': 'uniform', 'features': 45}
# Trained and Tested combination 22 of 288, taking 0.0 seconds to get val score of 0.2668:
#                 {'strategy': 'uniform', 'features': 50},
#             Current best combo with val score 0.2668:
#                     {'strategy': 'uniform', 'features': 45}
# Trained and Tested combination 23 of 288, taking 0.0 seconds to get val score of 0.0:
#                 {'strategy': 'most_frequent', 'features': 15},
#             Current best combo with val score 0.2668:
#                     {'strategy': 'uniform', 'features': 45}
# Trained and Tested combination 24 of 288, taking 0.0 seconds to get val score of 0.2668:
#                 {'strategy': 'uniform', 'features': 55},
#             Current best combo with val score 0.2668:
#                     {'strategy': 'uniform', 'features': 45}
# Trained and Tested combination 25 of 288, taking 0.0 seconds to get val score of 0.0:
#                 {'strategy': 'most_frequent', 'features': 67},
#             Current best combo with val score 0.2668:
#                     {'strategy': 'uniform', 'features': 45}
# Trained and Tested combination 26 of 288, taking 0.0 seconds to get val score of 0.0:
#                 {'strategy': 'most_frequent', 'features': 10},
#             Current best combo with val score 0.2668:
#                     {'strategy': 'uniform', 'features': 45}
# Trained and Tested combination 27 of 288, taking 0.0 seconds to get val score of 0.0:
#                 {'strategy': 'most_frequent', 'features': 0},
#             Current best combo with val score 0.2668:
#                     {'strategy': 'uniform', 'features': 45}
# Trained and Tested combination 28 of 288, taking 0.0 seconds to get val score of 0.2668:
#                 {'strategy': 'uniform', 'features': 20},
#             Current best combo with val score 0.2668:
#                     {'strategy': 'uniform', 'features': 45}
# Trained and Tested combination 29 of 288, taking 0.0 seconds to get val score of 0.2668:
#                 {'strategy': 'uniform', 'features': 10},
#             Current best combo with val score 0.2668:
#                     {'strategy': 'uniform', 'features': 45}
# Trained and Tested combination 30 of 288, taking 0.0 seconds to get val score of 0.0:
#                 {'strategy': 'most_frequent', 'features': 50},
#             Current best combo with val score 0.2668:
#                     {'strategy': 'uniform', 'features': 45}
# Trained and Tested combination 31 of 288, taking 0.0 seconds to get val score of 0.2668:
#                 {'strategy': 'uniform', 'features': 0},
#             Current best combo with val score 0.2668:
#                     {'strategy': 'uniform', 'features': 45}
# Trained and Tested combination 32 of 288, taking 0.0 seconds to get val score of 0.2668:
#                 {'strategy': 'uniform', 'features': 35},
#             Current best combo with val score 0.2668:
#                     {'strategy': 'uniform', 'features': 45}
# Trained and Tested combination 33 of 288, taking 0.0 seconds to get val score of 0.1448:
#                 {'strategy': 'stratified', 'features': 36},
#             Current best combo with val score 0.2668:
#                     {'strategy': 'uniform', 'features': 45}
#
#
# STAGE ONE: Begin initial Guidance system
#
#
# Guidance: initial round
#
# 	round 0 iteration:  0
#
# Trained and Tested combination 34 of 288, taking 0.0 seconds to get val score of 0.0:
#                 {'strategy': 'prior', 'features': 36},
#             Current best combo with val score 0.2668:
#                     {'strategy': 'uniform', 'features': 45}
# Trained and Tested combination 35 of 288, taking 0.0 seconds to get val score of 0.2668:
#                 {'strategy': 'uniform', 'features': 36},
#             Current best combo with val score 0.2668:
#                     {'strategy': 'uniform', 'features': 45}
# Trained and Tested combination 36 of 288, taking 0.0 seconds to get val score of 0.1448:
#                 {'strategy': 'stratified', 'features': 35},
#             Current best combo with val score 0.2668:
#                     {'strategy': 'uniform', 'features': 45}
# Trained and Tested combination 37 of 288, taking 0.0 seconds to get val score of 0.1448:
#                 {'strategy': 'stratified', 'features': 37},
#             Current best combo with val score 0.2668:
#                     {'strategy': 'uniform', 'features': 45}
# 	round 0 iteration:  1
#
# Already Trained and Tested combination (val score of 0.1448):
#             {'strategy': 'stratified', 'features': 36}
#             Current best combo (with val score 0.2668):
#                     {'strategy': 'uniform', 'features': 45}
#         Has trained 37 of 288 combinations so far
# Already Trained and Tested combination (val score of 0.2668):
#             {'strategy': 'uniform', 'features': 35}
#             Current best combo (with val score 0.2668):
#                     {'strategy': 'uniform', 'features': 45}
#         Has trained 37 of 288 combinations so far
# Trained and Tested combination 38 of 288, taking 0.0 seconds to get val score of 0.2668:
#                 {'strategy': 'uniform', 'features': 37},
#             Current best combo with val score 0.2668:
#                     {'strategy': 'uniform', 'features': 45}
# Trained and Tested combination 39 of 288, taking 0.0 seconds to get val score of 0.0:
#                 {'strategy': 'prior', 'features': 35},
#             Current best combo with val score 0.2668:
#                     {'strategy': 'uniform', 'features': 45}
# Already Trained and Tested combination (val score of 0.2668):
#             {'strategy': 'uniform', 'features': 35}
#             Current best combo (with val score 0.2668):
#                     {'strategy': 'uniform', 'features': 45}
#         Has trained 39 of 288 combinations so far
# Trained and Tested combination 40 of 288, taking 0.0 seconds to get val score of 0.1448:
#                 {'strategy': 'stratified', 'features': 34},
#             Current best combo with val score 0.2668:
#                     {'strategy': 'uniform', 'features': 45}
# Already Trained and Tested combination (val score of 0.1448):
#             {'strategy': 'stratified', 'features': 36}
#             Current best combo (with val score 0.2668):
#                     {'strategy': 'uniform', 'features': 45}
#         Has trained 40 of 288 combinations so far
# Trained and Tested combination 41 of 288, taking 0.0 seconds to get val score of 0.0:
#                 {'strategy': 'prior', 'features': 37},
#             Current best combo with val score 0.2668:
#                     {'strategy': 'uniform', 'features': 45}
# Already Trained and Tested combination (val score of 0.2668):
#             {'strategy': 'uniform', 'features': 37}
#             Current best combo (with val score 0.2668):
#                     {'strategy': 'uniform', 'features': 45}
#         Has trained 41 of 288 combinations so far
# Already Trained and Tested combination (val score of 0.1448):
#             {'strategy': 'stratified', 'features': 36}
#             Current best combo (with val score 0.2668):
#                     {'strategy': 'uniform', 'features': 45}
#         Has trained 41 of 288 combinations so far
# Trained and Tested combination 42 of 288, taking 0.0 seconds to get val score of 0.1448:
#                 {'strategy': 'stratified', 'features': 38},
#             Current best combo with val score 0.2668:
#                     {'strategy': 'uniform', 'features': 45}
# Trained and Tested combination 43 of 288, taking 0.0 seconds to get val score of 0.1448:
#                 {'strategy': 'stratified', 'features': 45},
#             Current best combo with val score 0.2668:
#                     {'strategy': 'uniform', 'features': 45}
# Trained and Tested combination 44 of 288, taking 0.0 seconds to get val score of 0.2668:
#                 {'strategy': 'uniform', 'features': 44},
#             Current best combo with val score 0.2668:
#                     {'strategy': 'uniform', 'features': 45}
# Trained and Tested combination 45 of 288, taking 0.0 seconds to get val score of 0.2668:
#                 {'strategy': 'uniform', 'features': 46},
#             Current best combo with val score 0.2668:
#                     {'strategy': 'uniform', 'features': 45}
# % Combos Checked Thus Far: 45 out of 288 which is 15.625%
# STAGE TWO: Begin Cruise system
#
#
# Cruising Coordrdinate 1 of 32
#
# Cruising Coordrdinate 2 of 32
#
# Cruise suspended due to suspicious case
# Guidance: round 1
#
# 	round 1 iteration:  0
#
# Trained and Tested combination 46 of 288, taking 0.0 seconds to get val score of 0.1448:
#                 {'strategy': 'stratified', 'features': 0},
#             Current best combo with val score 0.2668:
#                     {'strategy': 'uniform', 'features': 45}
# Trained and Tested combination 47 of 288, taking 0.0 seconds to get val score of 0.2668:
#                 {'strategy': 'uniform', 'features': 1},
#             Current best combo with val score 0.2668:
#                     {'strategy': 'uniform', 'features': 45}
# 	round 1 iteration:  1
#
# Trained and Tested combination 48 of 288, taking 0.0 seconds to get val score of 0.1448:
#                 {'strategy': 'stratified', 'features': 1},
#             Current best combo with val score 0.2668:
#                     {'strategy': 'uniform', 'features': 45}
# Already Trained and Tested combination (val score of 0.2668):
#             {'strategy': 'uniform', 'features': 0}
#             Current best combo (with val score 0.2668):
#                     {'strategy': 'uniform', 'features': 45}
#         Has trained 48 of 288 combinations so far
# Trained and Tested combination 49 of 288, taking 0.0 seconds to get val score of 0.2668:
#                 {'strategy': 'uniform', 'features': 2},
#             Current best combo with val score 0.2668:
#                     {'strategy': 'uniform', 'features': 45}
# % Combos Checked Thus Far: 49 out of 288 which is 17.013889%
# Cruising Coordrdinate 3 of 32
#
# Cruising Coordrdinate 4 of 32
#
# Cruise suspended due to suspicious case
# Guidance: round 2
#
# 	round 2 iteration:  0
#
# Trained and Tested combination 50 of 288, taking 0.0 seconds to get val score of 0.1448:
#                 {'strategy': 'stratified', 'features': 5},
#             Current best combo with val score 0.2668:
#                     {'strategy': 'uniform', 'features': 45}
# Trained and Tested combination 51 of 288, taking 0.0 seconds to get val score of 0.2668:
#                 {'strategy': 'uniform', 'features': 4},
#             Current best combo with val score 0.2668:
#                     {'strategy': 'uniform', 'features': 45}
# Trained and Tested combination 52 of 288, taking 0.0 seconds to get val score of 0.2668:
#                 {'strategy': 'uniform', 'features': 6},
#             Current best combo with val score 0.2668:
#                     {'strategy': 'uniform', 'features': 45}
# 	round 2 iteration:  1
#
# Trained and Tested combination 53 of 288, taking 0.0 seconds to get val score of 0.1448:
#                 {'strategy': 'stratified', 'features': 4},
#             Current best combo with val score 0.2668:
#                     {'strategy': 'uniform', 'features': 45}
# Trained and Tested combination 54 of 288, taking 0.0 seconds to get val score of 0.2668:
#                 {'strategy': 'uniform', 'features': 3},
#             Current best combo with val score 0.2668:
#                     {'strategy': 'uniform', 'features': 45}
# Already Trained and Tested combination (val score of 0.2668):
#             {'strategy': 'uniform', 'features': 5}
#             Current best combo (with val score 0.2668):
#                     {'strategy': 'uniform', 'features': 45}
#         Has trained 54 of 288 combinations so far
# Trained and Tested combination 55 of 288, taking 0.0 seconds to get val score of 0.1448:
#                 {'strategy': 'stratified', 'features': 6},
#             Current best combo with val score 0.2668:
#                     {'strategy': 'uniform', 'features': 45}
# Already Trained and Tested combination (val score of 0.2668):
#             {'strategy': 'uniform', 'features': 5}
#             Current best combo (with val score 0.2668):
#                     {'strategy': 'uniform', 'features': 45}
#         Has trained 55 of 288 combinations so far
# Trained and Tested combination 56 of 288, taking 0.0 seconds to get val score of 0.2668:
#                 {'strategy': 'uniform', 'features': 7},
#             Current best combo with val score 0.2668:
#                     {'strategy': 'uniform', 'features': 45}
# % Combos Checked Thus Far: 56 out of 288 which is 19.444444%
# Cruising Coordrdinate 5 of 32
#
# Cruising Coordrdinate 6 of 32
#
# Cruise suspended due to suspicious case
# Guidance: round 3
#
# 	round 3 iteration:  0
#
# Trained and Tested combination 57 of 288, taking 0.0 seconds to get val score of 0.1448:
#                 {'strategy': 'stratified', 'features': 10},
#             Current best combo with val score 0.2668:
#                     {'strategy': 'uniform', 'features': 45}
# Trained and Tested combination 58 of 288, taking 0.0 seconds to get val score of 0.2668:
#                 {'strategy': 'uniform', 'features': 9},
#             Current best combo with val score 0.2668:
#                     {'strategy': 'uniform', 'features': 45}
# Trained and Tested combination 59 of 288, taking 0.0 seconds to get val score of 0.2668:
#                 {'strategy': 'uniform', 'features': 11},
#             Current best combo with val score 0.2668:
#                     {'strategy': 'uniform', 'features': 45}
# 	round 3 iteration:  1
#
# Trained and Tested combination 60 of 288, taking 0.0 seconds to get val score of 0.1448:
#                 {'strategy': 'stratified', 'features': 9},
#             Current best combo with val score 0.2668:
#                     {'strategy': 'uniform', 'features': 45}
# Trained and Tested combination 61 of 288, taking 0.0 seconds to get val score of 0.2668:
#                 {'strategy': 'uniform', 'features': 8},
#             Current best combo with val score 0.2668:
#                     {'strategy': 'uniform', 'features': 45}
# Already Trained and Tested combination (val score of 0.2668):
#             {'strategy': 'uniform', 'features': 10}
#             Current best combo (with val score 0.2668):
#                     {'strategy': 'uniform', 'features': 45}
#         Has trained 61 of 288 combinations so far
# Trained and Tested combination 62 of 288, taking 0.0 seconds to get val score of 0.1448:
#                 {'strategy': 'stratified', 'features': 11},
#             Current best combo with val score 0.2668:
#                     {'strategy': 'uniform', 'features': 45}
# Already Trained and Tested combination (val score of 0.2668):
#             {'strategy': 'uniform', 'features': 10}
#             Current best combo (with val score 0.2668):
#                     {'strategy': 'uniform', 'features': 45}
#         Has trained 62 of 288 combinations so far
# Trained and Tested combination 63 of 288, taking 0.0 seconds to get val score of 0.2668:
#                 {'strategy': 'uniform', 'features': 12},
#             Current best combo with val score 0.2668:
#                     {'strategy': 'uniform', 'features': 45}
# % Combos Checked Thus Far: 63 out of 288 which is 21.875%
# Cruising Coordrdinate 7 of 32
#
# Cruising Coordrdinate 8 of 32
#
# Cruise suspended due to suspicious case
# Guidance: round 4
#
# 	round 4 iteration:  0
#
# Trained and Tested combination 64 of 288, taking 0.0 seconds to get val score of 0.1448:
#                 {'strategy': 'stratified', 'features': 15},
#             Current best combo with val score 0.2668:
#                     {'strategy': 'uniform', 'features': 45}
# Trained and Tested combination 65 of 288, taking 0.0 seconds to get val score of 0.2668:
#                 {'strategy': 'uniform', 'features': 14},
#             Current best combo with val score 0.2668:
#                     {'strategy': 'uniform', 'features': 45}
# Trained and Tested combination 66 of 288, taking 0.0 seconds to get val score of 0.2668:
#                 {'strategy': 'uniform', 'features': 16},
#             Current best combo with val score 0.2668:
#                     {'strategy': 'uniform', 'features': 45}
# 	round 4 iteration:  1
#
# Trained and Tested combination 67 of 288, taking 0.0 seconds to get val score of 0.1448:
#                 {'strategy': 'stratified', 'features': 14},
#             Current best combo with val score 0.2668:
#                     {'strategy': 'uniform', 'features': 45}
# Trained and Tested combination 68 of 288, taking 0.0 seconds to get val score of 0.2668:
#                 {'strategy': 'uniform', 'features': 13},
#             Current best combo with val score 0.2668:
#                     {'strategy': 'uniform', 'features': 45}
# Already Trained and Tested combination (val score of 0.2668):
#             {'strategy': 'uniform', 'features': 15}
#             Current best combo (with val score 0.2668):
#                     {'strategy': 'uniform', 'features': 45}
#         Has trained 68 of 288 combinations so far
# Trained and Tested combination 69 of 288, taking 0.0 seconds to get val score of 0.1448:
#                 {'strategy': 'stratified', 'features': 16},
#             Current best combo with val score 0.2668:
#                     {'strategy': 'uniform', 'features': 45}
# Already Trained and Tested combination (val score of 0.2668):
#             {'strategy': 'uniform', 'features': 15}
#             Current best combo (with val score 0.2668):
#                     {'strategy': 'uniform', 'features': 45}
#         Has trained 69 of 288 combinations so far
# Trained and Tested combination 70 of 288, taking 0.0 seconds to get val score of 0.2668:
#                 {'strategy': 'uniform', 'features': 17},
#             Current best combo with val score 0.2668:
#                     {'strategy': 'uniform', 'features': 45}
# % Combos Checked Thus Far: 70 out of 288 which is 24.305556%
# Cruising Coordrdinate 9 of 32
#
# Cruising Coordrdinate 10 of 32
#
# Cruise suspended due to suspicious case
# Guidance: round 5
#
# 	round 5 iteration:  0
#
# Trained and Tested combination 71 of 288, taking 0.0 seconds to get val score of 0.1448:
#                 {'strategy': 'stratified', 'features': 71},
#             Current best combo with val score 0.2668:
#                     {'strategy': 'uniform', 'features': 45}
# Trained and Tested combination 72 of 288, taking 0.0 seconds to get val score of 0.2668:
#                 {'strategy': 'uniform', 'features': 70},
#             Current best combo with val score 0.2668:
#                     {'strategy': 'uniform', 'features': 45}
# 	round 5 iteration:  1
#
# Trained and Tested combination 73 of 288, taking 0.0 seconds to get val score of 0.1448:
#                 {'strategy': 'stratified', 'features': 70},
#             Current best combo with val score 0.2668:
#                     {'strategy': 'uniform', 'features': 45}
# Trained and Tested combination 74 of 288, taking 0.0 seconds to get val score of 0.2668:
#                 {'strategy': 'uniform', 'features': 69},
#             Current best combo with val score 0.2668:
#                     {'strategy': 'uniform', 'features': 45}
# Already Trained and Tested combination (val score of 0.2668):
#             {'strategy': 'uniform', 'features': 71}
#             Current best combo (with val score 0.2668):
#                     {'strategy': 'uniform', 'features': 45}
#         Has trained 74 of 288 combinations so far
# % Combos Checked Thus Far: 74 out of 288 which is 25.694444%
# Cruising Coordrdinate 11 of 32
#
# Cruising Coordrdinate 12 of 32
#
# Cruise suspended due to suspicious case
# Guidance: round 6
#
# 	round 6 iteration:  0
#
# Trained and Tested combination 75 of 288, taking 0.0 seconds to get val score of 0.1448:
#                 {'strategy': 'stratified', 'features': 20},
#             Current best combo with val score 0.2668:
#                     {'strategy': 'uniform', 'features': 45}
# Trained and Tested combination 76 of 288, taking 0.0 seconds to get val score of 0.2668:
#                 {'strategy': 'uniform', 'features': 19},
#             Current best combo with val score 0.2668:
#                     {'strategy': 'uniform', 'features': 45}
# Trained and Tested combination 77 of 288, taking 0.0 seconds to get val score of 0.2668:
#                 {'strategy': 'uniform', 'features': 21},
#             Current best combo with val score 0.2668:
#                     {'strategy': 'uniform', 'features': 45}
# 	round 6 iteration:  1
#
# Trained and Tested combination 78 of 288, taking 0.0 seconds to get val score of 0.1448:
#                 {'strategy': 'stratified', 'features': 19},
#             Current best combo with val score 0.2668:
#                     {'strategy': 'uniform', 'features': 45}
# Trained and Tested combination 79 of 288, taking 0.0 seconds to get val score of 0.2668:
#                 {'strategy': 'uniform', 'features': 18},
#             Current best combo with val score 0.2668:
#                     {'strategy': 'uniform', 'features': 45}
# Already Trained and Tested combination (val score of 0.2668):
#             {'strategy': 'uniform', 'features': 20}
#             Current best combo (with val score 0.2668):
#                     {'strategy': 'uniform', 'features': 45}
#         Has trained 79 of 288 combinations so far
# Trained and Tested combination 80 of 288, taking 0.0 seconds to get val score of 0.1448:
#                 {'strategy': 'stratified', 'features': 21},
#             Current best combo with val score 0.2668:
#                     {'strategy': 'uniform', 'features': 45}
# Already Trained and Tested combination (val score of 0.2668):
#             {'strategy': 'uniform', 'features': 20}
#             Current best combo (with val score 0.2668):
#                     {'strategy': 'uniform', 'features': 45}
#         Has trained 80 of 288 combinations so far
# Trained and Tested combination 81 of 288, taking 0.0 seconds to get val score of 0.2668:
#                 {'strategy': 'uniform', 'features': 22},
#             Current best combo with val score 0.2668:
#                     {'strategy': 'uniform', 'features': 45}
# % Combos Checked Thus Far: 81 out of 288 which is 28.125%
# Cruising Coordrdinate 13 of 32
#
# Cruising Coordrdinate 14 of 32
#
# Cruise suspended due to suspicious case
# Guidance: round 7
#
# 	round 7 iteration:  0
#
# Trained and Tested combination 82 of 288, taking 0.0 seconds to get val score of 0.1448:
#                 {'strategy': 'stratified', 'features': 67},
#             Current best combo with val score 0.2668:
#                     {'strategy': 'uniform', 'features': 45}
# Trained and Tested combination 83 of 288, taking 0.0 seconds to get val score of 0.2668:
#                 {'strategy': 'uniform', 'features': 66},
#             Current best combo with val score 0.2668:
#                     {'strategy': 'uniform', 'features': 45}
# Trained and Tested combination 84 of 288, taking 0.0 seconds to get val score of 0.2668:
#                 {'strategy': 'uniform', 'features': 68},
#             Current best combo with val score 0.2668:
#                     {'strategy': 'uniform', 'features': 45}
# 	round 7 iteration:  1
#
# Trained and Tested combination 85 of 288, taking 0.0 seconds to get val score of 0.1448:
#                 {'strategy': 'stratified', 'features': 66},
#             Current best combo with val score 0.2668:
#                     {'strategy': 'uniform', 'features': 45}
# Trained and Tested combination 86 of 288, taking 0.0 seconds to get val score of 0.2668:
#                 {'strategy': 'uniform', 'features': 65},
#             Current best combo with val score 0.2668:
#                     {'strategy': 'uniform', 'features': 45}
# Already Trained and Tested combination (val score of 0.2668):
#             {'strategy': 'uniform', 'features': 67}
#             Current best combo (with val score 0.2668):
#                     {'strategy': 'uniform', 'features': 45}
#         Has trained 86 of 288 combinations so far
# Trained and Tested combination 87 of 288, taking 0.0 seconds to get val score of 0.1448:
#                 {'strategy': 'stratified', 'features': 68},
#             Current best combo with val score 0.2668:
#                     {'strategy': 'uniform', 'features': 45}
# Already Trained and Tested combination (val score of 0.2668):
#             {'strategy': 'uniform', 'features': 67}
#             Current best combo (with val score 0.2668):
#                     {'strategy': 'uniform', 'features': 45}
#         Has trained 87 of 288 combinations so far
# Already Trained and Tested combination (val score of 0.2668):
#             {'strategy': 'uniform', 'features': 69}
#             Current best combo (with val score 0.2668):
#                     {'strategy': 'uniform', 'features': 45}
#         Has trained 87 of 288 combinations so far
# % Combos Checked Thus Far: 87 out of 288 which is 30.208333%
# Cruising Coordrdinate 15 of 32
#
# Cruising Coordrdinate 16 of 32
#
# Cruise suspended due to suspicious case
# Guidance: round 8
#
# 	round 8 iteration:  0
#
# Trained and Tested combination 88 of 288, taking 0.0 seconds to get val score of 0.1448:
#                 {'strategy': 'stratified', 'features': 25},
#             Current best combo with val score 0.2668:
#                     {'strategy': 'uniform', 'features': 45}
# Trained and Tested combination 89 of 288, taking 0.0 seconds to get val score of 0.2668:
#                 {'strategy': 'uniform', 'features': 24},
#             Current best combo with val score 0.2668:
#                     {'strategy': 'uniform', 'features': 45}
# Trained and Tested combination 90 of 288, taking 0.0 seconds to get val score of 0.2668:
#                 {'strategy': 'uniform', 'features': 26},
#             Current best combo with val score 0.2668:
#                     {'strategy': 'uniform', 'features': 45}
# 	round 8 iteration:  1
#
# Trained and Tested combination 91 of 288, taking 0.0 seconds to get val score of 0.1448:
#                 {'strategy': 'stratified', 'features': 24},
#             Current best combo with val score 0.2668:
#                     {'strategy': 'uniform', 'features': 45}
# Trained and Tested combination 92 of 288, taking 0.0 seconds to get val score of 0.2668:
#                 {'strategy': 'uniform', 'features': 23},
#             Current best combo with val score 0.2668:
#                     {'strategy': 'uniform', 'features': 45}
# Already Trained and Tested combination (val score of 0.2668):
#             {'strategy': 'uniform', 'features': 25}
#             Current best combo (with val score 0.2668):
#                     {'strategy': 'uniform', 'features': 45}
#         Has trained 92 of 288 combinations so far
# Trained and Tested combination 93 of 288, taking 0.0 seconds to get val score of 0.1448:
#                 {'strategy': 'stratified', 'features': 26},
#             Current best combo with val score 0.2668:
#                     {'strategy': 'uniform', 'features': 45}
# Already Trained and Tested combination (val score of 0.2668):
#             {'strategy': 'uniform', 'features': 25}
#             Current best combo (with val score 0.2668):
#                     {'strategy': 'uniform', 'features': 45}
#         Has trained 93 of 288 combinations so far
# Trained and Tested combination 94 of 288, taking 0.0 seconds to get val score of 0.2668:
#                 {'strategy': 'uniform', 'features': 27},
#             Current best combo with val score 0.2668:
#                     {'strategy': 'uniform', 'features': 45}
# % Combos Checked Thus Far: 94 out of 288 which is 32.638889%
# Cruising Coordrdinate 17 of 32
#
# Cruising Coordrdinate 18 of 32
#
# Cruise suspended due to suspicious case
# Guidance: round 9
#
# 	round 9 iteration:  0
#
# Trained and Tested combination 95 of 288, taking 0.0 seconds to get val score of 0.1448:
#                 {'strategy': 'stratified', 'features': 63},
#             Current best combo with val score 0.2668:
#                     {'strategy': 'uniform', 'features': 45}
# Trained and Tested combination 96 of 288, taking 0.0 seconds to get val score of 0.2668:
#                 {'strategy': 'uniform', 'features': 62},
#             Current best combo with val score 0.2668:
#                     {'strategy': 'uniform', 'features': 45}
# Trained and Tested combination 97 of 288, taking 0.0 seconds to get val score of 0.2668:
#                 {'strategy': 'uniform', 'features': 64},
#             Current best combo with val score 0.2668:
#                     {'strategy': 'uniform', 'features': 45}
# 	round 9 iteration:  1
#
# Trained and Tested combination 98 of 288, taking 0.0 seconds to get val score of 0.1448:
#                 {'strategy': 'stratified', 'features': 62},
#             Current best combo with val score 0.2668:
#                     {'strategy': 'uniform', 'features': 45}
# Trained and Tested combination 99 of 288, taking 0.0 seconds to get val score of 0.2668:
#                 {'strategy': 'uniform', 'features': 61},
#             Current best combo with val score 0.2668:
#                     {'strategy': 'uniform', 'features': 45}
# Already Trained and Tested combination (val score of 0.2668):
#             {'strategy': 'uniform', 'features': 63}
#             Current best combo (with val score 0.2668):
#                     {'strategy': 'uniform', 'features': 45}
#         Has trained 99 of 288 combinations so far
# Trained and Tested combination 100 of 288, taking 0.0 seconds to get val score of 0.1448:
#                 {'strategy': 'stratified', 'features': 64},
#             Current best combo with val score 0.2668:
#                     {'strategy': 'uniform', 'features': 45}
# Already Trained and Tested combination (val score of 0.2668):
#             {'strategy': 'uniform', 'features': 63}
#             Current best combo (with val score 0.2668):
#                     {'strategy': 'uniform', 'features': 45}
#         Has trained 100 of 288 combinations so far
# Already Trained and Tested combination (val score of 0.2668):
#             {'strategy': 'uniform', 'features': 65}
#             Current best combo (with val score 0.2668):
#                     {'strategy': 'uniform', 'features': 45}
#         Has trained 100 of 288 combinations so far
# % Combos Checked Thus Far: 100 out of 288 which is 34.722222%
# Cruising Coordrdinate 19 of 32
#
# Cruising Coordrdinate 20 of 32
#
# Cruise suspended due to suspicious case
# Guidance: round 10
#
# 	round 10 iteration:  0
#
# Trained and Tested combination 101 of 288, taking 0.0 seconds to get val score of 0.1448:
#                 {'strategy': 'stratified', 'features': 30},
#             Current best combo with val score 0.2668:
#                     {'strategy': 'uniform', 'features': 45}
# Trained and Tested combination 102 of 288, taking 0.0 seconds to get val score of 0.2668:
#                 {'strategy': 'uniform', 'features': 29},
#             Current best combo with val score 0.2668:
#                     {'strategy': 'uniform', 'features': 45}
# Trained and Tested combination 103 of 288, taking 0.0 seconds to get val score of 0.2668:
#                 {'strategy': 'uniform', 'features': 31},
#             Current best combo with val score 0.2668:
#                     {'strategy': 'uniform', 'features': 45}
# 	round 10 iteration:  1
#
# Trained and Tested combination 104 of 288, taking 0.0 seconds to get val score of 0.1448:
#                 {'strategy': 'stratified', 'features': 29},
#             Current best combo with val score 0.2668:
#                     {'strategy': 'uniform', 'features': 45}
# Trained and Tested combination 105 of 288, taking 0.0 seconds to get val score of 0.2668:
#                 {'strategy': 'uniform', 'features': 28},
#             Current best combo with val score 0.2668:
#                     {'strategy': 'uniform', 'features': 45}
# Already Trained and Tested combination (val score of 0.2668):
#             {'strategy': 'uniform', 'features': 30}
#             Current best combo (with val score 0.2668):
#                     {'strategy': 'uniform', 'features': 45}
#         Has trained 105 of 288 combinations so far
# Trained and Tested combination 106 of 288, taking 0.0 seconds to get val score of 0.1448:
#                 {'strategy': 'stratified', 'features': 31},
#             Current best combo with val score 0.2668:
#                     {'strategy': 'uniform', 'features': 45}
# Already Trained and Tested combination (val score of 0.2668):
#             {'strategy': 'uniform', 'features': 30}
#             Current best combo (with val score 0.2668):
#                     {'strategy': 'uniform', 'features': 45}
#         Has trained 106 of 288 combinations so far
# Trained and Tested combination 107 of 288, taking 0.0 seconds to get val score of 0.2668:
#                 {'strategy': 'uniform', 'features': 32},
#             Current best combo with val score 0.2668:
#                     {'strategy': 'uniform', 'features': 45}
# % Combos Checked Thus Far: 107 out of 288 which is 37.152778%
# Cruising Coordrdinate 21 of 32
#
# Cruising Coordrdinate 22 of 32
#
# Cruise suspended due to suspicious case
# Guidance: round 11
#
# 	round 11 iteration:  0
#
# Trained and Tested combination 108 of 288, taking 0.0 seconds to get val score of 0.1448:
#                 {'strategy': 'stratified', 'features': 59},
#             Current best combo with val score 0.2668:
#                     {'strategy': 'uniform', 'features': 45}
# Trained and Tested combination 109 of 288, taking 0.0 seconds to get val score of 0.2668:
#                 {'strategy': 'uniform', 'features': 58},
#             Current best combo with val score 0.2668:
#                     {'strategy': 'uniform', 'features': 45}
# Trained and Tested combination 110 of 288, taking 0.0 seconds to get val score of 0.2668:
#                 {'strategy': 'uniform', 'features': 60},
#             Current best combo with val score 0.2668:
#                     {'strategy': 'uniform', 'features': 45}
# 	round 11 iteration:  1
#
# Trained and Tested combination 111 of 288, taking 0.0 seconds to get val score of 0.1448:
#                 {'strategy': 'stratified', 'features': 58},
#             Current best combo with val score 0.2668:
#                     {'strategy': 'uniform', 'features': 45}
# Trained and Tested combination 112 of 288, taking 0.0 seconds to get val score of 0.2668:
#                 {'strategy': 'uniform', 'features': 57},
#             Current best combo with val score 0.2668:
#                     {'strategy': 'uniform', 'features': 45}
# Already Trained and Tested combination (val score of 0.2668):
#             {'strategy': 'uniform', 'features': 59}
#             Current best combo (with val score 0.2668):
#                     {'strategy': 'uniform', 'features': 45}
#         Has trained 112 of 288 combinations so far
# Trained and Tested combination 113 of 288, taking 0.0 seconds to get val score of 0.1448:
#                 {'strategy': 'stratified', 'features': 60},
#             Current best combo with val score 0.2668:
#                     {'strategy': 'uniform', 'features': 45}
# Already Trained and Tested combination (val score of 0.2668):
#             {'strategy': 'uniform', 'features': 59}
#             Current best combo (with val score 0.2668):
#                     {'strategy': 'uniform', 'features': 45}
#         Has trained 113 of 288 combinations so far
# Already Trained and Tested combination (val score of 0.2668):
#             {'strategy': 'uniform', 'features': 61}
#             Current best combo (with val score 0.2668):
#                     {'strategy': 'uniform', 'features': 45}
#         Has trained 113 of 288 combinations so far
# % Combos Checked Thus Far: 113 out of 288 which is 39.236111%
# Cruising Coordrdinate 23 of 32
#
# Cruising Coordrdinate 24 of 32
#
# Cruising Coordrdinate 25 of 32
#
# Cruise suspended due to suspicious case
# Guidance: round 12
#
# 	round 12 iteration:  0
#
# Already Trained and Tested combination (val score of 0.1448):
#             {'strategy': 'stratified', 'features': 35}
#             Current best combo (with val score 0.2668):
#                     {'strategy': 'uniform', 'features': 45}
#         Has trained 113 of 288 combinations so far
# Trained and Tested combination 114 of 288, taking 0.0 seconds to get val score of 0.2668:
#                 {'strategy': 'uniform', 'features': 34},
#             Current best combo with val score 0.2668:
#                     {'strategy': 'uniform', 'features': 45}
# Already Trained and Tested combination (val score of 0.2668):
#             {'strategy': 'uniform', 'features': 36}
#             Current best combo (with val score 0.2668):
#                     {'strategy': 'uniform', 'features': 45}
#         Has trained 114 of 288 combinations so far
# 	round 12 iteration:  1
#
# Already Trained and Tested combination (val score of 0.1448):
#             {'strategy': 'stratified', 'features': 34}
#             Current best combo (with val score 0.2668):
#                     {'strategy': 'uniform', 'features': 45}
#         Has trained 114 of 288 combinations so far
# Trained and Tested combination 115 of 288, taking 0.0 seconds to get val score of 0.2668:
#                 {'strategy': 'uniform', 'features': 33},
#             Current best combo with val score 0.2668:
#                     {'strategy': 'uniform', 'features': 45}
# Already Trained and Tested combination (val score of 0.2668):
#             {'strategy': 'uniform', 'features': 35}
#             Current best combo (with val score 0.2668):
#                     {'strategy': 'uniform', 'features': 45}
#         Has trained 115 of 288 combinations so far
# % Combos Checked Thus Far: 115 out of 288 which is 39.930556%
# Cruising Coordrdinate 26 of 32
#
# Cruise suspended due to suspicious case
# Guidance: round 13
#
# 	round 13 iteration:  0
#
# Trained and Tested combination 116 of 288, taking 0.0 seconds to get val score of 0.1448:
#                 {'strategy': 'stratified', 'features': 55},
#             Current best combo with val score 0.2668:
#                     {'strategy': 'uniform', 'features': 45}
# Trained and Tested combination 117 of 288, taking 0.0 seconds to get val score of 0.2668:
#                 {'strategy': 'uniform', 'features': 54},
#             Current best combo with val score 0.2668:
#                     {'strategy': 'uniform', 'features': 45}
# Trained and Tested combination 118 of 288, taking 0.0 seconds to get val score of 0.2668:
#                 {'strategy': 'uniform', 'features': 56},
#             Current best combo with val score 0.2668:
#                     {'strategy': 'uniform', 'features': 45}
# 	round 13 iteration:  1
#
# Trained and Tested combination 119 of 288, taking 0.0 seconds to get val score of 0.1448:
#                 {'strategy': 'stratified', 'features': 54},
#             Current best combo with val score 0.2668:
#                     {'strategy': 'uniform', 'features': 45}
# Trained and Tested combination 120 of 288, taking 0.0 seconds to get val score of 0.2668:
#                 {'strategy': 'uniform', 'features': 53},
#             Current best combo with val score 0.2668:
#                     {'strategy': 'uniform', 'features': 45}
# Already Trained and Tested combination (val score of 0.2668):
#             {'strategy': 'uniform', 'features': 55}
#             Current best combo (with val score 0.2668):
#                     {'strategy': 'uniform', 'features': 45}
#         Has trained 120 of 288 combinations so far
# Trained and Tested combination 121 of 288, taking 0.0 seconds to get val score of 0.1448:
#                 {'strategy': 'stratified', 'features': 56},
#             Current best combo with val score 0.2668:
#                     {'strategy': 'uniform', 'features': 45}
# Already Trained and Tested combination (val score of 0.2668):
#             {'strategy': 'uniform', 'features': 55}
#             Current best combo (with val score 0.2668):
#                     {'strategy': 'uniform', 'features': 45}
#         Has trained 121 of 288 combinations so far
# Already Trained and Tested combination (val score of 0.2668):
#             {'strategy': 'uniform', 'features': 57}
#             Current best combo (with val score 0.2668):
#                     {'strategy': 'uniform', 'features': 45}
#         Has trained 121 of 288 combinations so far
# % Combos Checked Thus Far: 121 out of 288 which is 42.013889%
# Cruising Coordrdinate 27 of 32
#
# Cruising Coordrdinate 28 of 32
#
# Cruising Coordrdinate 29 of 32
#
# Cruise suspended due to suspicious case
# Guidance: round 14
#
# 	round 14 iteration:  0
#
# Trained and Tested combination 122 of 288, taking 0.0 seconds to get val score of 0.1448:
#                 {'strategy': 'stratified', 'features': 40},
#             Current best combo with val score 0.2668:
#                     {'strategy': 'uniform', 'features': 45}
# Trained and Tested combination 123 of 288, taking 0.0 seconds to get val score of 0.2668:
#                 {'strategy': 'uniform', 'features': 39},
#             Current best combo with val score 0.2668:
#                     {'strategy': 'uniform', 'features': 45}
# Trained and Tested combination 124 of 288, taking 0.0 seconds to get val score of 0.2668:
#                 {'strategy': 'uniform', 'features': 41},
#             Current best combo with val score 0.2668:
#                     {'strategy': 'uniform', 'features': 45}
# 	round 14 iteration:  1
#
# Trained and Tested combination 125 of 288, taking 0.0 seconds to get val score of 0.1448:
#                 {'strategy': 'stratified', 'features': 39},
#             Current best combo with val score 0.2668:
#                     {'strategy': 'uniform', 'features': 45}
# Trained and Tested combination 126 of 288, taking 0.0 seconds to get val score of 0.2668:
#                 {'strategy': 'uniform', 'features': 38},
#             Current best combo with val score 0.2668:
#                     {'strategy': 'uniform', 'features': 45}
# Already Trained and Tested combination (val score of 0.2668):
#             {'strategy': 'uniform', 'features': 40}
#             Current best combo (with val score 0.2668):
#                     {'strategy': 'uniform', 'features': 45}
#         Has trained 126 of 288 combinations so far
# Trained and Tested combination 127 of 288, taking 0.0 seconds to get val score of 0.1448:
#                 {'strategy': 'stratified', 'features': 41},
#             Current best combo with val score 0.2668:
#                     {'strategy': 'uniform', 'features': 45}
# Already Trained and Tested combination (val score of 0.2668):
#             {'strategy': 'uniform', 'features': 40}
#             Current best combo (with val score 0.2668):
#                     {'strategy': 'uniform', 'features': 45}
#         Has trained 127 of 288 combinations so far
# Trained and Tested combination 128 of 288, taking 0.0 seconds to get val score of 0.2668:
#                 {'strategy': 'uniform', 'features': 42},
#             Current best combo with val score 0.2668:
#                     {'strategy': 'uniform', 'features': 45}
# % Combos Checked Thus Far: 128 out of 288 which is 44.444444%
# Cruising Coordrdinate 30 of 32
#
# Cruise suspended due to suspicious case
# Guidance: round 15
#
# 	round 15 iteration:  0
#
# Trained and Tested combination 129 of 288, taking 0.0 seconds to get val score of 0.1448:
#                 {'strategy': 'stratified', 'features': 50},
#             Current best combo with val score 0.2668:
#                     {'strategy': 'uniform', 'features': 45}
# Trained and Tested combination 130 of 288, taking 0.0 seconds to get val score of 0.2668:
#                 {'strategy': 'uniform', 'features': 49},
#             Current best combo with val score 0.2668:
#                     {'strategy': 'uniform', 'features': 45}
# Trained and Tested combination 131 of 288, taking 0.0 seconds to get val score of 0.2668:
#                 {'strategy': 'uniform', 'features': 51},
#             Current best combo with val score 0.2668:
#                     {'strategy': 'uniform', 'features': 45}
# 	round 15 iteration:  1
#
# Trained and Tested combination 132 of 288, taking 0.0 seconds to get val score of 0.1448:
#                 {'strategy': 'stratified', 'features': 49},
#             Current best combo with val score 0.2668:
#                     {'strategy': 'uniform', 'features': 45}
# Trained and Tested combination 133 of 288, taking 0.0 seconds to get val score of 0.2668:
#                 {'strategy': 'uniform', 'features': 48},
#             Current best combo with val score 0.2668:
#                     {'strategy': 'uniform', 'features': 45}
# Already Trained and Tested combination (val score of 0.2668):
#             {'strategy': 'uniform', 'features': 50}
#             Current best combo (with val score 0.2668):
#                     {'strategy': 'uniform', 'features': 45}
#         Has trained 133 of 288 combinations so far
# Trained and Tested combination 134 of 288, taking 0.0 seconds to get val score of 0.1448:
#                 {'strategy': 'stratified', 'features': 51},
#             Current best combo with val score 0.2668:
#                     {'strategy': 'uniform', 'features': 45}
# Already Trained and Tested combination (val score of 0.2668):
#             {'strategy': 'uniform', 'features': 50}
#             Current best combo (with val score 0.2668):
#                     {'strategy': 'uniform', 'features': 45}
#         Has trained 134 of 288 combinations so far
# Trained and Tested combination 135 of 288, taking 0.0 seconds to get val score of 0.2668:
#                 {'strategy': 'uniform', 'features': 52},
#             Current best combo with val score 0.2668:
#                     {'strategy': 'uniform', 'features': 45}
# % Combos Checked Thus Far: 135 out of 288 which is 46.875%
# Cruising Coordrdinate 31 of 32
#
# Cruising Coordrdinate 32 of 32
#
# Cruise suspended due to suspicious case
# Guidance: round 16
#
# 	round 16 iteration:  0
#
# Already Trained and Tested combination (val score of 0.1448):
#             {'strategy': 'stratified', 'features': 45}
#             Current best combo (with val score 0.2668):
#                     {'strategy': 'uniform', 'features': 45}
#         Has trained 135 of 288 combinations so far
# Already Trained and Tested combination (val score of 0.2668):
#             {'strategy': 'uniform', 'features': 44}
#             Current best combo (with val score 0.2668):
#                     {'strategy': 'uniform', 'features': 45}
#         Has trained 135 of 288 combinations so far
# Already Trained and Tested combination (val score of 0.2668):
#             {'strategy': 'uniform', 'features': 46}
#             Current best combo (with val score 0.2668):
#                     {'strategy': 'uniform', 'features': 45}
#         Has trained 135 of 288 combinations so far
# 	round 16 iteration:  1
#
# Trained and Tested combination 136 of 288, taking 0.0 seconds to get val score of 0.1448:
#                 {'strategy': 'stratified', 'features': 44},
#             Current best combo with val score 0.2668:
#                     {'strategy': 'uniform', 'features': 45}
# Trained and Tested combination 137 of 288, taking 0.0 seconds to get val score of 0.2668:
#                 {'strategy': 'uniform', 'features': 43},
#             Current best combo with val score 0.2668:
#                     {'strategy': 'uniform', 'features': 45}
# Already Trained and Tested combination (val score of 0.2668):
#             {'strategy': 'uniform', 'features': 45}
#             Current best combo (with val score 0.2668):
#                     {'strategy': 'uniform', 'features': 45}
#         Has trained 137 of 288 combinations so far
# Trained and Tested combination 138 of 288, taking 0.0 seconds to get val score of 0.1448:
#                 {'strategy': 'stratified', 'features': 46},
#             Current best combo with val score 0.2668:
#                     {'strategy': 'uniform', 'features': 45}
# Already Trained and Tested combination (val score of 0.2668):
#             {'strategy': 'uniform', 'features': 45}
#             Current best combo (with val score 0.2668):
#                     {'strategy': 'uniform', 'features': 45}
#         Has trained 138 of 288 combinations so far
# Trained and Tested combination 139 of 288, taking 0.0 seconds to get val score of 0.2668:
#                 {'strategy': 'uniform', 'features': 47},
#             Current best combo with val score 0.2668:
#                     {'strategy': 'uniform', 'features': 45}
# % Combos Checked Thus Far: 139 out of 288 which is 48.263889%
# FINAL STAGE: Begin final Guidance system
#
#
# Guidance: round FINAL
#
# 	round FINAL iteration:  0
#
# % Combos Checked Thus Far: 139 out of 288 which is 48.263889%
# Max Val Score:
#  0.26682
# Max Val Score Std:
#  0.036608
# Best Combo Train Score:
#  0.262566
# Best Combo Train Score Std:
#  0.00924
# Max Combo Index:
#  (3, 45) out of [4, 72] (note best combo is 0-indexed)
# Max Combo Hyperparamer Combination:
#  {'strategy': 'uniform', 'features': 45}
# Max Combo Features:
#  ('procedure_228130', 'procedure_225792', 'procedure_228125', 'lods_score', 'ventilation_used', 'procedure_226236', 'hospital_stay_duration', 'procedure_225469', 'procedure_224270', 'procedure_225446', 'procedure_225802', 'procedure_227712', 'procedure_229580', 'procedure_225451', 'admission_type_DIRECT EMER.', 'admission_type_DIRECT OBSERVATION', 'admission_type_ELECTIVE', 'admission_type_EU OBSERVATION', 'admission_type_EW EMER.', 'admission_type_OBSERVATION ADMIT', 'admission_type_URGENT', 'admission_type_SURGICAL SAME DAY ADMISSION', 'procedure_224385', 'procedure_224267', 'oasis_score', 'procedure_225470', 'procedure_224276', 'icu_stay_duration', 'marital_status_DIVORCED', 'marital_status_MARRIED', 'marital_status_SINGLE', 'marital_status_WIDOWED', 'marital_status_0', 'procedure_225432', 'gender_M', 'gender_F', 'procedure_225457', 'procedure_224275', 'item_51301', 'procedure_225400', 'anchor_age', 'unique_drugs', 'procedure_225444', 'spo2', 'glucose', 'procedure_229582', 'potassium', 'procedure_225454', 'item_51265', 'urine_output_total', 'pt', 'creatinine', 'procedure_221223', 'mean_arterial_pressure', 'bun', 'procedure_224263', 'heart_rate', 'resp_rate')
# % Combos Checked: 139 out of 288 which is 48.263889%
