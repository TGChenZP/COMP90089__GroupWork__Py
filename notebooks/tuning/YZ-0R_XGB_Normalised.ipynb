# %% [markdown]
# # Tuning Script

# %%
# Parameters subject to change in every script - involved in naming

MODEL = '0R'
PREPROCESSING = 'normalise'
TUNER = 'yangzhoub'
OPTIMISED_METRIC = 'f1'

# %% [markdown]
# ---

# %%
# detect whether this is a google environment

COLAB_ENVIRONMENT = False

try:
    from google.colab import drive
    drive.mount('/content/drive')
    COLAB_ENVIRONMENT = True
except:
    pass
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import sys
import os
import pickle

if COLAB_ENVIRONMENT:
    home_directory = './drive/MyDrive/LAB/COMP90089__GroupWork__Py/' # my home directory is stored in ./LAB of google drive
    if MODEL == 'ebr':
        # !pip install interpret==0.5.0
    elif MODEL == 'cbr':
        # !pip install catboost
    elif MODEL in ['tf', 'mlp']:
        # !pip install PyTorch2Sklearn
    # !pip install JXAutoML
else:
    home_directory = '../../'

from JXAutoML.YangZhouB_10CV import YangZhouB_10CV as Tuner

import pandas as pd
# Out:
# Requirement already satisfied: JXAutoML in /usr/local/lib/python3.10/dist-packages (0.4.4)

# %%
# Parameters that are same for every script

FOLDS = 10  # we have decided to do 10 fold validation

SEED = 42

TASK_TYPE = 'Classification'  # this task is a classification task

# we have decided to tune features as hp
TUNE_FEATURES_AS_HYPERPARAMETERS = True

# %% [markdown]
# ---

# %%
# model to use to tune
from sklearn.dummy import DummyClassifier as clf

# what values to try for each hyperparameter
parameter_choices = {
    'strategy': ("most_frequent", "prior", "stratified", "uniform"),
}

# what values to set non-tuneable parameters/hyperparameters
non_tunable_hyperparameters_dict = {
    'random_state': SEED,
}

# %% [markdown]
# ---

# %% [markdown]
# Read in and Prepare Data

# %%
# Import data and store as lists

train_x_list = []
train_y_list = []
val_x_list = []
val_y_list = []

for i in range(FOLDS):
    train_data = pd.read_csv(
        f'{home_directory}data/curated/modelling/{PREPROCESSING}/train_{i}.csv')
    val_data = pd.read_csv(
        f'{home_directory}data/curated/modelling/{PREPROCESSING}/val_{i}.csv')

    # get the correct rows for X and y
    train_x = train_data.drop(
        ['mortality_status', 'subject_id', 'hadm_id', 'stay_id'], axis=1)
    train_y = train_data['mortality_status']
    val_x = val_data.drop(
        ['mortality_status', 'subject_id', 'hadm_id', 'stay_id'], axis=1)
    val_y = val_data['mortality_status']

    train_x_list.append(train_x)
    train_y_list.append(train_y)
    val_x_list.append(val_x)
    val_y_list.append(val_y)

# %%
# Import feature importance ordering

with open(f'{home_directory}models/xgb_feature_importance_ordering_{PREPROCESSING}.pickle', 'rb') as f:
    feature_importance_ordering = pickle.load(f)

# %% [markdown]
# Set parameters

# %%
# initialisation
tuner = Tuner()

print('---')

# define what model we are tuning
tuner.read_in_model(clf, TASK_TYPE, optimised_metric=OPTIMISED_METRIC)

print('---')

# read in the data for training and validation
tuner.read_in_data(train_x_list, train_y_list, val_x_list, val_y_list)

print('---')

# set what hp values to tune
tuner.set_hyperparameters(parameter_choices)
# WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

# set up hp values that need to be changed from default but NOT to be tuned
tuner.set_non_tuneable_hyperparameters(non_tunable_hyperparameters_dict)

print('---')

# set up feature importance ordering

if TUNE_FEATURES_AS_HYPERPARAMETERS:
    tuner.set_features(feature_importance_ordering)
    # WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

try:  # try to read in previous results to continue tuning ...
    tuner.read_in_tuning_result_df(
        f'{home_directory}models/tuning/{TUNER}_{MODEL}_{PREPROCESSING}.csv')
except:
    print('No previous tuning data read in')

print('---')

# set up where to save the tuning result csv
tuner.set_tuning_result_saving_address(
    f'{home_directory}models/tuning/{TUNER}_{MODEL}_{PREPROCESSING}.csv')

print('---')

# set up where to save the current best model
tuner.set_best_model_saving_address(
    f'{home_directory}models/tmp_models/{TUNER}_{MODEL}_{PREPROCESSING}')
# Out:
# YangZhouB Initialised
# ---
# Successfully read in model <class 'sklearn.dummy.DummyClassifier'>, which is a Classification model optimising for f1
# ---
# Read in Train X data list
# Read in Train y data list
# Read in Val X data list
# Read in Val y data list
# ---
# Successfully recorded hyperparameter choices
# ---
# Successfully recorded non_tuneable_hyperparameter choices
# ---
# Successfully recorded tuneable feature combination choices and updated relevant internal structures
# ---
# No previous tuning data read in
# ---
# Successfully set tuning output address
# ---
# Successfully set best model output address

# %%
# ignore warnings

import warnings
warnings.filterwarnings("ignore")

# %%
# begin tuning ... (or continue training)

tuner.tune()
# Out:
# BEGIN TUNING
#
#
# STAGE ZERO: Tune all Cruise combinations
#
#
# Trained and Tested combination 1 of 204, taking 0.0 seconds to get val score of 0.0:
#                 {'strategy': 'most_frequent', 'features': 30},
#             Current best combo with val score 0.0:
#                     {'strategy': 'most_frequent', 'features': 30}
# Trained and Tested combination 2 of 204, taking 0.0 seconds to get val score of 0.0:
#                 {'strategy': 'most_frequent', 'features': 25},
#             Current best combo with val score 0.0:
#                     {'strategy': 'most_frequent', 'features': 30}
# Trained and Tested combination 3 of 204, taking 0.0 seconds to get val score of 0.0:
#                 {'strategy': 'most_frequent', 'features': 40},
#             Current best combo with val score 0.0:
#                     {'strategy': 'most_frequent', 'features': 30}
# Trained and Tested combination 4 of 204, taking 0.0 seconds to get val score of 0.2729:
#                 {'strategy': 'uniform', 'features': 45},
#             Current best combo with val score 0.2729:
#                     {'strategy': 'uniform', 'features': 45}
# Trained and Tested combination 5 of 204, taking 0.0 seconds to get val score of 0.2729:
#                 {'strategy': 'uniform', 'features': 20},
#             Current best combo with val score 0.2729:
#                     {'strategy': 'uniform', 'features': 45}
# Trained and Tested combination 6 of 204, taking 0.0 seconds to get val score of 0.0:
#                 {'strategy': 'most_frequent', 'features': 20},
#             Current best combo with val score 0.2729:
#                     {'strategy': 'uniform', 'features': 45}
# Trained and Tested combination 7 of 204, taking 0.0 seconds to get val score of 0.0:
#                 {'strategy': 'most_frequent', 'features': 45},
#             Current best combo with val score 0.2729:
#                     {'strategy': 'uniform', 'features': 45}
# Trained and Tested combination 8 of 204, taking 0.0 seconds to get val score of 0.2729:
#                 {'strategy': 'uniform', 'features': 10},
#             Current best combo with val score 0.2729:
#                     {'strategy': 'uniform', 'features': 45}
# Trained and Tested combination 9 of 204, taking 0.0 seconds to get val score of 0.2729:
#                 {'strategy': 'uniform', 'features': 5},
#             Current best combo with val score 0.2729:
#                     {'strategy': 'uniform', 'features': 45}
# Trained and Tested combination 10 of 204, taking 0.0 seconds to get val score of 0.0:
#                 {'strategy': 'most_frequent', 'features': 35},
#             Current best combo with val score 0.2729:
#                     {'strategy': 'uniform', 'features': 45}
# Trained and Tested combination 11 of 204, taking 0.0 seconds to get val score of 0.0:
#                 {'strategy': 'most_frequent', 'features': 15},
#             Current best combo with val score 0.2729:
#                     {'strategy': 'uniform', 'features': 45}
# Trained and Tested combination 12 of 204, taking 0.0 seconds to get val score of 0.2729:
#                 {'strategy': 'uniform', 'features': 50},
#             Current best combo with val score 0.2729:
#                     {'strategy': 'uniform', 'features': 45}
# Trained and Tested combination 13 of 204, taking 0.0 seconds to get val score of 0.2729:
#                 {'strategy': 'uniform', 'features': 30},
#             Current best combo with val score 0.2729:
#                     {'strategy': 'uniform', 'features': 45}
# Trained and Tested combination 14 of 204, taking 0.0 seconds to get val score of 0.0:
#                 {'strategy': 'most_frequent', 'features': 5},
#             Current best combo with val score 0.2729:
#                     {'strategy': 'uniform', 'features': 45}
# Trained and Tested combination 15 of 204, taking 0.0 seconds to get val score of 0.2729:
#                 {'strategy': 'uniform', 'features': 40},
#             Current best combo with val score 0.2729:
#                     {'strategy': 'uniform', 'features': 45}
# Trained and Tested combination 16 of 204, taking 0.0 seconds to get val score of 0.2729:
#                 {'strategy': 'uniform', 'features': 15},
#             Current best combo with val score 0.2729:
#                     {'strategy': 'uniform', 'features': 45}
# Trained and Tested combination 17 of 204, taking 0.0 seconds to get val score of 0.0:
#                 {'strategy': 'most_frequent', 'features': 10},
#             Current best combo with val score 0.2729:
#                     {'strategy': 'uniform', 'features': 45}
# Trained and Tested combination 18 of 204, taking 0.0 seconds to get val score of 0.0:
#                 {'strategy': 'most_frequent', 'features': 0},
#             Current best combo with val score 0.2729:
#                     {'strategy': 'uniform', 'features': 45}
# Trained and Tested combination 19 of 204, taking 0.0 seconds to get val score of 0.2729:
#                 {'strategy': 'uniform', 'features': 35},
#             Current best combo with val score 0.2729:
#                     {'strategy': 'uniform', 'features': 45}
# Trained and Tested combination 20 of 204, taking 0.0 seconds to get val score of 0.0:
#                 {'strategy': 'most_frequent', 'features': 50},
#             Current best combo with val score 0.2729:
#                     {'strategy': 'uniform', 'features': 45}
# Trained and Tested combination 21 of 204, taking 0.0 seconds to get val score of 0.1815:
#                 {'strategy': 'stratified', 'features': 25},
#             Current best combo with val score 0.2729:
#                     {'strategy': 'uniform', 'features': 45}
# Trained and Tested combination 22 of 204, taking 0.0 seconds to get val score of 0.2729:
#                 {'strategy': 'uniform', 'features': 0},
#             Current best combo with val score 0.2729:
#                     {'strategy': 'uniform', 'features': 45}
# Trained and Tested combination 23 of 204, taking 0.0 seconds to get val score of 0.2729:
#                 {'strategy': 'uniform', 'features': 25},
#             Current best combo with val score 0.2729:
#                     {'strategy': 'uniform', 'features': 45}
#
#
# STAGE ONE: Begin initial Guidance system
#
#
# Guidance: initial round
#
# 	round 0 iteration:  0
#
# Trained and Tested combination 24 of 204, taking 0.0 seconds to get val score of 0.0:
#                 {'strategy': 'prior', 'features': 25},
#             Current best combo with val score 0.2729:
#                     {'strategy': 'uniform', 'features': 45}
# Already Trained and Tested combination (val score of 0.2729):
#             {'strategy': 'uniform', 'features': 25}
#             Current best combo (with val score 0.2729):
#                     {'strategy': 'uniform', 'features': 45}
#         Has trained 24 of 204 combinations so far
# Trained and Tested combination 25 of 204, taking 0.0 seconds to get val score of 0.1815:
#                 {'strategy': 'stratified', 'features': 24},
#             Current best combo with val score 0.2729:
#                     {'strategy': 'uniform', 'features': 45}
# Trained and Tested combination 26 of 204, taking 0.0 seconds to get val score of 0.1815:
#                 {'strategy': 'stratified', 'features': 26},
#             Current best combo with val score 0.2729:
#                     {'strategy': 'uniform', 'features': 45}
# 	round 0 iteration:  1
#
# Already Trained and Tested combination (val score of 0.1815):
#             {'strategy': 'stratified', 'features': 25}
#             Current best combo (with val score 0.2729):
#                     {'strategy': 'uniform', 'features': 45}
#         Has trained 26 of 204 combinations so far
# Trained and Tested combination 27 of 204, taking 0.0 seconds to get val score of 0.2729:
#                 {'strategy': 'uniform', 'features': 24},
#             Current best combo with val score 0.2729:
#                     {'strategy': 'uniform', 'features': 45}
# Trained and Tested combination 28 of 204, taking 0.0 seconds to get val score of 0.2729:
#                 {'strategy': 'uniform', 'features': 26},
#             Current best combo with val score 0.2729:
#                     {'strategy': 'uniform', 'features': 45}
# Trained and Tested combination 29 of 204, taking 0.0 seconds to get val score of 0.0:
#                 {'strategy': 'prior', 'features': 24},
#             Current best combo with val score 0.2729:
#                     {'strategy': 'uniform', 'features': 45}
# Already Trained and Tested combination (val score of 0.2729):
#             {'strategy': 'uniform', 'features': 24}
#             Current best combo (with val score 0.2729):
#                     {'strategy': 'uniform', 'features': 45}
#         Has trained 29 of 204 combinations so far
# Trained and Tested combination 30 of 204, taking 0.0 seconds to get val score of 0.1815:
#                 {'strategy': 'stratified', 'features': 23},
#             Current best combo with val score 0.2729:
#                     {'strategy': 'uniform', 'features': 45}
# Already Trained and Tested combination (val score of 0.1815):
#             {'strategy': 'stratified', 'features': 25}
#             Current best combo (with val score 0.2729):
#                     {'strategy': 'uniform', 'features': 45}
#         Has trained 30 of 204 combinations so far
# Trained and Tested combination 31 of 204, taking 0.0 seconds to get val score of 0.0:
#                 {'strategy': 'prior', 'features': 26},
#             Current best combo with val score 0.2729:
#                     {'strategy': 'uniform', 'features': 45}
# Already Trained and Tested combination (val score of 0.2729):
#             {'strategy': 'uniform', 'features': 26}
#             Current best combo (with val score 0.2729):
#                     {'strategy': 'uniform', 'features': 45}
#         Has trained 31 of 204 combinations so far
# Already Trained and Tested combination (val score of 0.1815):
#             {'strategy': 'stratified', 'features': 25}
#             Current best combo (with val score 0.2729):
#                     {'strategy': 'uniform', 'features': 45}
#         Has trained 31 of 204 combinations so far
# Trained and Tested combination 32 of 204, taking 0.0 seconds to get val score of 0.1815:
#                 {'strategy': 'stratified', 'features': 27},
#             Current best combo with val score 0.2729:
#                     {'strategy': 'uniform', 'features': 45}
# Trained and Tested combination 33 of 204, taking 0.0 seconds to get val score of 0.1815:
#                 {'strategy': 'stratified', 'features': 45},
#             Current best combo with val score 0.2729:
#                     {'strategy': 'uniform', 'features': 45}
# Trained and Tested combination 34 of 204, taking 0.0 seconds to get val score of 0.2729:
#                 {'strategy': 'uniform', 'features': 44},
#             Current best combo with val score 0.2729:
#                     {'strategy': 'uniform', 'features': 45}
# Trained and Tested combination 35 of 204, taking 0.0 seconds to get val score of 0.2729:
#                 {'strategy': 'uniform', 'features': 46},
#             Current best combo with val score 0.2729:
#                     {'strategy': 'uniform', 'features': 45}
# % Combos Checked Thus Far: 35 out of 204 which is 17.156863%
# STAGE TWO: Begin Cruise system
#
#
# Cruising Coordrdinate 1 of 22
#
# Cruising Coordrdinate 2 of 22
#
# Cruise suspended due to suspicious case
# Guidance: round 1
#
# 	round 1 iteration:  0
#
# Trained and Tested combination 36 of 204, taking 0.0 seconds to get val score of 0.1815:
#                 {'strategy': 'stratified', 'features': 0},
#             Current best combo with val score 0.2729:
#                     {'strategy': 'uniform', 'features': 45}
# Trained and Tested combination 37 of 204, taking 0.0 seconds to get val score of 0.2729:
#                 {'strategy': 'uniform', 'features': 1},
#             Current best combo with val score 0.2729:
#                     {'strategy': 'uniform', 'features': 45}
# 	round 1 iteration:  1
#
# Trained and Tested combination 38 of 204, taking 0.0 seconds to get val score of 0.1815:
#                 {'strategy': 'stratified', 'features': 1},
#             Current best combo with val score 0.2729:
#                     {'strategy': 'uniform', 'features': 45}
# Already Trained and Tested combination (val score of 0.2729):
#             {'strategy': 'uniform', 'features': 0}
#             Current best combo (with val score 0.2729):
#                     {'strategy': 'uniform', 'features': 45}
#         Has trained 38 of 204 combinations so far
# Trained and Tested combination 39 of 204, taking 0.0 seconds to get val score of 0.2729:
#                 {'strategy': 'uniform', 'features': 2},
#             Current best combo with val score 0.2729:
#                     {'strategy': 'uniform', 'features': 45}
# % Combos Checked Thus Far: 39 out of 204 which is 19.117646999999998%
# Cruising Coordrdinate 3 of 22
#
# Cruising Coordrdinate 4 of 22
#
# Cruise suspended due to suspicious case
# Guidance: round 2
#
# 	round 2 iteration:  0
#
# Trained and Tested combination 40 of 204, taking 0.0 seconds to get val score of 0.1815:
#                 {'strategy': 'stratified', 'features': 5},
#             Current best combo with val score 0.2729:
#                     {'strategy': 'uniform', 'features': 45}
# Trained and Tested combination 41 of 204, taking 0.0 seconds to get val score of 0.2729:
#                 {'strategy': 'uniform', 'features': 4},
#             Current best combo with val score 0.2729:
#                     {'strategy': 'uniform', 'features': 45}
# Trained and Tested combination 42 of 204, taking 0.0 seconds to get val score of 0.2729:
#                 {'strategy': 'uniform', 'features': 6},
#             Current best combo with val score 0.2729:
#                     {'strategy': 'uniform', 'features': 45}
# 	round 2 iteration:  1
#
# Trained and Tested combination 43 of 204, taking 0.0 seconds to get val score of 0.1815:
#                 {'strategy': 'stratified', 'features': 4},
#             Current best combo with val score 0.2729:
#                     {'strategy': 'uniform', 'features': 45}
# Trained and Tested combination 44 of 204, taking 0.0 seconds to get val score of 0.2729:
#                 {'strategy': 'uniform', 'features': 3},
#             Current best combo with val score 0.2729:
#                     {'strategy': 'uniform', 'features': 45}
# Already Trained and Tested combination (val score of 0.2729):
#             {'strategy': 'uniform', 'features': 5}
#             Current best combo (with val score 0.2729):
#                     {'strategy': 'uniform', 'features': 45}
#         Has trained 44 of 204 combinations so far
# Trained and Tested combination 45 of 204, taking 0.0 seconds to get val score of 0.1815:
#                 {'strategy': 'stratified', 'features': 6},
#             Current best combo with val score 0.2729:
#                     {'strategy': 'uniform', 'features': 45}
# Already Trained and Tested combination (val score of 0.2729):
#             {'strategy': 'uniform', 'features': 5}
#             Current best combo (with val score 0.2729):
#                     {'strategy': 'uniform', 'features': 45}
#         Has trained 45 of 204 combinations so far
# Trained and Tested combination 46 of 204, taking 0.0 seconds to get val score of 0.2729:
#                 {'strategy': 'uniform', 'features': 7},
#             Current best combo with val score 0.2729:
#                     {'strategy': 'uniform', 'features': 45}
# % Combos Checked Thus Far: 46 out of 204 which is 22.54902%
# Cruising Coordrdinate 5 of 22
#
# Cruising Coordrdinate 6 of 22
#
# Cruise suspended due to suspicious case
# Guidance: round 3
#
# 	round 3 iteration:  0
#
# Trained and Tested combination 47 of 204, taking 0.0 seconds to get val score of 0.1815:
#                 {'strategy': 'stratified', 'features': 10},
#             Current best combo with val score 0.2729:
#                     {'strategy': 'uniform', 'features': 45}
# Trained and Tested combination 48 of 204, taking 0.0 seconds to get val score of 0.2729:
#                 {'strategy': 'uniform', 'features': 9},
#             Current best combo with val score 0.2729:
#                     {'strategy': 'uniform', 'features': 45}
# Trained and Tested combination 49 of 204, taking 0.0 seconds to get val score of 0.2729:
#                 {'strategy': 'uniform', 'features': 11},
#             Current best combo with val score 0.2729:
#                     {'strategy': 'uniform', 'features': 45}
# 	round 3 iteration:  1
#
# Trained and Tested combination 50 of 204, taking 0.0 seconds to get val score of 0.1815:
#                 {'strategy': 'stratified', 'features': 9},
#             Current best combo with val score 0.2729:
#                     {'strategy': 'uniform', 'features': 45}
# Trained and Tested combination 51 of 204, taking 0.0 seconds to get val score of 0.2729:
#                 {'strategy': 'uniform', 'features': 8},
#             Current best combo with val score 0.2729:
#                     {'strategy': 'uniform', 'features': 45}
# Already Trained and Tested combination (val score of 0.2729):
#             {'strategy': 'uniform', 'features': 10}
#             Current best combo (with val score 0.2729):
#                     {'strategy': 'uniform', 'features': 45}
#         Has trained 51 of 204 combinations so far
# Trained and Tested combination 52 of 204, taking 0.0 seconds to get val score of 0.1815:
#                 {'strategy': 'stratified', 'features': 11},
#             Current best combo with val score 0.2729:
#                     {'strategy': 'uniform', 'features': 45}
# Already Trained and Tested combination (val score of 0.2729):
#             {'strategy': 'uniform', 'features': 10}
#             Current best combo (with val score 0.2729):
#                     {'strategy': 'uniform', 'features': 45}
#         Has trained 52 of 204 combinations so far
# Trained and Tested combination 53 of 204, taking 0.0 seconds to get val score of 0.2729:
#                 {'strategy': 'uniform', 'features': 12},
#             Current best combo with val score 0.2729:
#                     {'strategy': 'uniform', 'features': 45}
# % Combos Checked Thus Far: 53 out of 204 which is 25.980392000000002%
# Cruising Coordrdinate 7 of 22
#
# Cruising Coordrdinate 8 of 22
#
# Cruise suspended due to suspicious case
# Guidance: round 4
#
# 	round 4 iteration:  0
#
# Trained and Tested combination 54 of 204, taking 0.0 seconds to get val score of 0.1815:
#                 {'strategy': 'stratified', 'features': 15},
#             Current best combo with val score 0.2729:
#                     {'strategy': 'uniform', 'features': 45}
# Trained and Tested combination 55 of 204, taking 0.0 seconds to get val score of 0.2729:
#                 {'strategy': 'uniform', 'features': 14},
#             Current best combo with val score 0.2729:
#                     {'strategy': 'uniform', 'features': 45}
# Trained and Tested combination 56 of 204, taking 0.0 seconds to get val score of 0.2729:
#                 {'strategy': 'uniform', 'features': 16},
#             Current best combo with val score 0.2729:
#                     {'strategy': 'uniform', 'features': 45}
# 	round 4 iteration:  1
#
# Trained and Tested combination 57 of 204, taking 0.0 seconds to get val score of 0.1815:
#                 {'strategy': 'stratified', 'features': 14},
#             Current best combo with val score 0.2729:
#                     {'strategy': 'uniform', 'features': 45}
# Trained and Tested combination 58 of 204, taking 0.0 seconds to get val score of 0.2729:
#                 {'strategy': 'uniform', 'features': 13},
#             Current best combo with val score 0.2729:
#                     {'strategy': 'uniform', 'features': 45}
# Already Trained and Tested combination (val score of 0.2729):
#             {'strategy': 'uniform', 'features': 15}
#             Current best combo (with val score 0.2729):
#                     {'strategy': 'uniform', 'features': 45}
#         Has trained 58 of 204 combinations so far
# Trained and Tested combination 59 of 204, taking 0.0 seconds to get val score of 0.1815:
#                 {'strategy': 'stratified', 'features': 16},
#             Current best combo with val score 0.2729:
#                     {'strategy': 'uniform', 'features': 45}
# Already Trained and Tested combination (val score of 0.2729):
#             {'strategy': 'uniform', 'features': 15}
#             Current best combo (with val score 0.2729):
#                     {'strategy': 'uniform', 'features': 45}
#         Has trained 59 of 204 combinations so far
# Trained and Tested combination 60 of 204, taking 0.0 seconds to get val score of 0.2729:
#                 {'strategy': 'uniform', 'features': 17},
#             Current best combo with val score 0.2729:
#                     {'strategy': 'uniform', 'features': 45}
# % Combos Checked Thus Far: 60 out of 204 which is 29.411765000000003%
# Cruising Coordrdinate 9 of 22
#
# Cruising Coordrdinate 10 of 22
#
# Cruise suspended due to suspicious case
# Guidance: round 5
#
# 	round 5 iteration:  0
#
# Trained and Tested combination 61 of 204, taking 0.0 seconds to get val score of 0.1815:
#                 {'strategy': 'stratified', 'features': 20},
#             Current best combo with val score 0.2729:
#                     {'strategy': 'uniform', 'features': 45}
# Trained and Tested combination 62 of 204, taking 0.0 seconds to get val score of 0.2729:
#                 {'strategy': 'uniform', 'features': 19},
#             Current best combo with val score 0.2729:
#                     {'strategy': 'uniform', 'features': 45}
# Trained and Tested combination 63 of 204, taking 0.0 seconds to get val score of 0.2729:
#                 {'strategy': 'uniform', 'features': 21},
#             Current best combo with val score 0.2729:
#                     {'strategy': 'uniform', 'features': 45}
# 	round 5 iteration:  1
#
# Trained and Tested combination 64 of 204, taking 0.0 seconds to get val score of 0.1815:
#                 {'strategy': 'stratified', 'features': 19},
#             Current best combo with val score 0.2729:
#                     {'strategy': 'uniform', 'features': 45}
# Trained and Tested combination 65 of 204, taking 0.0 seconds to get val score of 0.2729:
#                 {'strategy': 'uniform', 'features': 18},
#             Current best combo with val score 0.2729:
#                     {'strategy': 'uniform', 'features': 45}
# Already Trained and Tested combination (val score of 0.2729):
#             {'strategy': 'uniform', 'features': 20}
#             Current best combo (with val score 0.2729):
#                     {'strategy': 'uniform', 'features': 45}
#         Has trained 65 of 204 combinations so far
# Trained and Tested combination 66 of 204, taking 0.0 seconds to get val score of 0.1815:
#                 {'strategy': 'stratified', 'features': 21},
#             Current best combo with val score 0.2729:
#                     {'strategy': 'uniform', 'features': 45}
# Already Trained and Tested combination (val score of 0.2729):
#             {'strategy': 'uniform', 'features': 20}
#             Current best combo (with val score 0.2729):
#                     {'strategy': 'uniform', 'features': 45}
#         Has trained 66 of 204 combinations so far
# Trained and Tested combination 67 of 204, taking 0.0 seconds to get val score of 0.2729:
#                 {'strategy': 'uniform', 'features': 22},
#             Current best combo with val score 0.2729:
#                     {'strategy': 'uniform', 'features': 45}
# % Combos Checked Thus Far: 67 out of 204 which is 32.843137%
# Cruising Coordrdinate 11 of 22
#
# Cruising Coordrdinate 12 of 22
#
# Cruise suspended due to suspicious case
# Guidance: round 6
#
# 	round 6 iteration:  0
#
# % Combos Checked Thus Far: 67 out of 204 which is 32.843137%
# Cruising Coordrdinate 13 of 22
#
# Cruising Coordrdinate 14 of 22
#
# Cruise suspended due to suspicious case
# Guidance: round 7
#
# 	round 7 iteration:  0
#
# Trained and Tested combination 68 of 204, taking 0.0 seconds to get val score of 0.1815:
#                 {'strategy': 'stratified', 'features': 30},
#             Current best combo with val score 0.2729:
#                     {'strategy': 'uniform', 'features': 45}
# Trained and Tested combination 69 of 204, taking 0.0 seconds to get val score of 0.2729:
#                 {'strategy': 'uniform', 'features': 29},
#             Current best combo with val score 0.2729:
#                     {'strategy': 'uniform', 'features': 45}
# Trained and Tested combination 70 of 204, taking 0.0 seconds to get val score of 0.2729:
#                 {'strategy': 'uniform', 'features': 31},
#             Current best combo with val score 0.2729:
#                     {'strategy': 'uniform', 'features': 45}
# 	round 7 iteration:  1
#
# Trained and Tested combination 71 of 204, taking 0.0 seconds to get val score of 0.1815:
#                 {'strategy': 'stratified', 'features': 29},
#             Current best combo with val score 0.2729:
#                     {'strategy': 'uniform', 'features': 45}
# Trained and Tested combination 72 of 204, taking 0.0 seconds to get val score of 0.2729:
#                 {'strategy': 'uniform', 'features': 28},
#             Current best combo with val score 0.2729:
#                     {'strategy': 'uniform', 'features': 45}
# Already Trained and Tested combination (val score of 0.2729):
#             {'strategy': 'uniform', 'features': 30}
#             Current best combo (with val score 0.2729):
#                     {'strategy': 'uniform', 'features': 45}
#         Has trained 72 of 204 combinations so far
# Trained and Tested combination 73 of 204, taking 0.0 seconds to get val score of 0.1815:
#                 {'strategy': 'stratified', 'features': 31},
#             Current best combo with val score 0.2729:
#                     {'strategy': 'uniform', 'features': 45}
# Already Trained and Tested combination (val score of 0.2729):
#             {'strategy': 'uniform', 'features': 30}
#             Current best combo (with val score 0.2729):
#                     {'strategy': 'uniform', 'features': 45}
#         Has trained 73 of 204 combinations so far
# Trained and Tested combination 74 of 204, taking 0.0 seconds to get val score of 0.2729:
#                 {'strategy': 'uniform', 'features': 32},
#             Current best combo with val score 0.2729:
#                     {'strategy': 'uniform', 'features': 45}
# % Combos Checked Thus Far: 74 out of 204 which is 36.27451%
# Cruising Coordrdinate 15 of 22
#
# Cruising Coordrdinate 16 of 22
#
# Cruise suspended due to suspicious case
# Guidance: round 8
#
# 	round 8 iteration:  0
#
# Trained and Tested combination 75 of 204, taking 0.0 seconds to get val score of 0.1815:
#                 {'strategy': 'stratified', 'features': 35},
#             Current best combo with val score 0.2729:
#                     {'strategy': 'uniform', 'features': 45}
# Trained and Tested combination 76 of 204, taking 0.0 seconds to get val score of 0.2729:
#                 {'strategy': 'uniform', 'features': 34},
#             Current best combo with val score 0.2729:
#                     {'strategy': 'uniform', 'features': 45}
# Trained and Tested combination 77 of 204, taking 0.0 seconds to get val score of 0.2729:
#                 {'strategy': 'uniform', 'features': 36},
#             Current best combo with val score 0.2729:
#                     {'strategy': 'uniform', 'features': 45}
# 	round 8 iteration:  1
#
# Trained and Tested combination 78 of 204, taking 0.0 seconds to get val score of 0.1815:
#                 {'strategy': 'stratified', 'features': 34},
#             Current best combo with val score 0.2729:
#                     {'strategy': 'uniform', 'features': 45}
# Trained and Tested combination 79 of 204, taking 0.0 seconds to get val score of 0.2729:
#                 {'strategy': 'uniform', 'features': 33},
#             Current best combo with val score 0.2729:
#                     {'strategy': 'uniform', 'features': 45}
# Already Trained and Tested combination (val score of 0.2729):
#             {'strategy': 'uniform', 'features': 35}
#             Current best combo (with val score 0.2729):
#                     {'strategy': 'uniform', 'features': 45}
#         Has trained 79 of 204 combinations so far
# Trained and Tested combination 80 of 204, taking 0.0 seconds to get val score of 0.1815:
#                 {'strategy': 'stratified', 'features': 36},
#             Current best combo with val score 0.2729:
#                     {'strategy': 'uniform', 'features': 45}
# Already Trained and Tested combination (val score of 0.2729):
#             {'strategy': 'uniform', 'features': 35}
#             Current best combo (with val score 0.2729):
#                     {'strategy': 'uniform', 'features': 45}
#         Has trained 80 of 204 combinations so far
# Trained and Tested combination 81 of 204, taking 0.0 seconds to get val score of 0.2729:
#                 {'strategy': 'uniform', 'features': 37},
#             Current best combo with val score 0.2729:
#                     {'strategy': 'uniform', 'features': 45}
# % Combos Checked Thus Far: 81 out of 204 which is 39.705881999999995%
# Cruising Coordrdinate 17 of 22
#
# Cruising Coordrdinate 18 of 22
#
# Cruising Coordrdinate 19 of 22
#
# Cruise suspended due to suspicious case
# Guidance: round 9
#
# 	round 9 iteration:  0
#
# Trained and Tested combination 82 of 204, taking 0.0 seconds to get val score of 0.1815:
#                 {'strategy': 'stratified', 'features': 40},
#             Current best combo with val score 0.2729:
#                     {'strategy': 'uniform', 'features': 45}
# Trained and Tested combination 83 of 204, taking 0.0 seconds to get val score of 0.2729:
#                 {'strategy': 'uniform', 'features': 39},
#             Current best combo with val score 0.2729:
#                     {'strategy': 'uniform', 'features': 45}
# Trained and Tested combination 84 of 204, taking 0.0 seconds to get val score of 0.2729:
#                 {'strategy': 'uniform', 'features': 41},
#             Current best combo with val score 0.2729:
#                     {'strategy': 'uniform', 'features': 45}
# 	round 9 iteration:  1
#
# Trained and Tested combination 85 of 204, taking 0.0 seconds to get val score of 0.1815:
#                 {'strategy': 'stratified', 'features': 39},
#             Current best combo with val score 0.2729:
#                     {'strategy': 'uniform', 'features': 45}
# Trained and Tested combination 86 of 204, taking 0.0 seconds to get val score of 0.2729:
#                 {'strategy': 'uniform', 'features': 38},
#             Current best combo with val score 0.2729:
#                     {'strategy': 'uniform', 'features': 45}
# Already Trained and Tested combination (val score of 0.2729):
#             {'strategy': 'uniform', 'features': 40}
#             Current best combo (with val score 0.2729):
#                     {'strategy': 'uniform', 'features': 45}
#         Has trained 86 of 204 combinations so far
# Trained and Tested combination 87 of 204, taking 0.0 seconds to get val score of 0.1815:
#                 {'strategy': 'stratified', 'features': 41},
#             Current best combo with val score 0.2729:
#                     {'strategy': 'uniform', 'features': 45}
# Already Trained and Tested combination (val score of 0.2729):
#             {'strategy': 'uniform', 'features': 40}
#             Current best combo (with val score 0.2729):
#                     {'strategy': 'uniform', 'features': 45}
#         Has trained 87 of 204 combinations so far
# Trained and Tested combination 88 of 204, taking 0.0 seconds to get val score of 0.2729:
#                 {'strategy': 'uniform', 'features': 42},
#             Current best combo with val score 0.2729:
#                     {'strategy': 'uniform', 'features': 45}
# % Combos Checked Thus Far: 88 out of 204 which is 43.137255%
# Cruising Coordrdinate 20 of 22
#
# Cruise suspended due to suspicious case
# Guidance: round 10
#
# 	round 10 iteration:  0
#
# Trained and Tested combination 89 of 204, taking 0.0 seconds to get val score of 0.1815:
#                 {'strategy': 'stratified', 'features': 50},
#             Current best combo with val score 0.2729:
#                     {'strategy': 'uniform', 'features': 45}
# Trained and Tested combination 90 of 204, taking 0.0 seconds to get val score of 0.2729:
#                 {'strategy': 'uniform', 'features': 49},
#             Current best combo with val score 0.2729:
#                     {'strategy': 'uniform', 'features': 45}
# 	round 10 iteration:  1
#
# Trained and Tested combination 91 of 204, taking 0.0 seconds to get val score of 0.1815:
#                 {'strategy': 'stratified', 'features': 49},
#             Current best combo with val score 0.2729:
#                     {'strategy': 'uniform', 'features': 45}
# Trained and Tested combination 92 of 204, taking 0.0 seconds to get val score of 0.2729:
#                 {'strategy': 'uniform', 'features': 48},
#             Current best combo with val score 0.2729:
#                     {'strategy': 'uniform', 'features': 45}
# Already Trained and Tested combination (val score of 0.2729):
#             {'strategy': 'uniform', 'features': 50}
#             Current best combo (with val score 0.2729):
#                     {'strategy': 'uniform', 'features': 45}
#         Has trained 92 of 204 combinations so far
# % Combos Checked Thus Far: 92 out of 204 which is 45.098039%
# Cruising Coordrdinate 21 of 22
#
# Cruising Coordrdinate 22 of 22
#
# Cruise suspended due to suspicious case
# Guidance: round 11
#
# 	round 11 iteration:  0
#
# Already Trained and Tested combination (val score of 0.1815):
#             {'strategy': 'stratified', 'features': 45}
#             Current best combo (with val score 0.2729):
#                     {'strategy': 'uniform', 'features': 45}
#         Has trained 92 of 204 combinations so far
# Already Trained and Tested combination (val score of 0.2729):
#             {'strategy': 'uniform', 'features': 44}
#             Current best combo (with val score 0.2729):
#                     {'strategy': 'uniform', 'features': 45}
#         Has trained 92 of 204 combinations so far
# Already Trained and Tested combination (val score of 0.2729):
#             {'strategy': 'uniform', 'features': 46}
#             Current best combo (with val score 0.2729):
#                     {'strategy': 'uniform', 'features': 45}
#         Has trained 92 of 204 combinations so far
# 	round 11 iteration:  1
#
# Trained and Tested combination 93 of 204, taking 0.0 seconds to get val score of 0.1815:
#                 {'strategy': 'stratified', 'features': 44},
#             Current best combo with val score 0.2729:
#                     {'strategy': 'uniform', 'features': 45}
# Trained and Tested combination 94 of 204, taking 0.0 seconds to get val score of 0.2729:
#                 {'strategy': 'uniform', 'features': 43},
#             Current best combo with val score 0.2729:
#                     {'strategy': 'uniform', 'features': 45}
# Already Trained and Tested combination (val score of 0.2729):
#             {'strategy': 'uniform', 'features': 45}
#             Current best combo (with val score 0.2729):
#                     {'strategy': 'uniform', 'features': 45}
#         Has trained 94 of 204 combinations so far
# Trained and Tested combination 95 of 204, taking 0.0 seconds to get val score of 0.1815:
#                 {'strategy': 'stratified', 'features': 46},
#             Current best combo with val score 0.2729:
#                     {'strategy': 'uniform', 'features': 45}
# Already Trained and Tested combination (val score of 0.2729):
#             {'strategy': 'uniform', 'features': 45}
#             Current best combo (with val score 0.2729):
#                     {'strategy': 'uniform', 'features': 45}
#         Has trained 95 of 204 combinations so far
# Trained and Tested combination 96 of 204, taking 0.0 seconds to get val score of 0.2729:
#                 {'strategy': 'uniform', 'features': 47},
#             Current best combo with val score 0.2729:
#                     {'strategy': 'uniform', 'features': 45}
# % Combos Checked Thus Far: 96 out of 204 which is 47.058824%
# FINAL STAGE: Begin final Guidance system
#
#
# Guidance: round FINAL
#
# 	round FINAL iteration:  0
#
# % Combos Checked Thus Far: 96 out of 204 which is 47.058824%
# Max Val Score:
#  0.272918
# Max Val Score Std:
#  0.037703
# Best Combo Train Score:
#  0.266346
# Best Combo Train Score Std:
#  0.013973
# Max Combo Index:
#  (3, 45) out of [4, 51] (note best combo is 0-indexed)
# Max Combo Hyperparamer Combination:
#  {'strategy': 'uniform', 'features': 45}
# Max Combo Features:
#  ('procedure_225792', 'ventilation_used', 'lods_score', 'race_AMERICAN INDIAN/ALASKA NATIVE', 'race_ASIAN', 'race_ASIAN - ASIAN INDIAN', 'race_ASIAN - CHINESE', 'race_ASIAN - KOREAN', 'race_ASIAN - SOUTH EAST ASIAN', 'race_BLACK/AFRICAN', 'race_BLACK/AFRICAN AMERICAN', 'race_BLACK/CAPE VERDEAN', 'race_BLACK/CARIBBEAN ISLAND', 'race_HISPANIC/LATINO - CENTRAL AMERICAN', 'race_HISPANIC/LATINO - COLUMBIAN', 'race_HISPANIC/LATINO - CUBAN', 'race_HISPANIC/LATINO - DOMINICAN', 'race_HISPANIC/LATINO - GUATEMALAN', 'race_HISPANIC/LATINO - HONDURAN', 'race_HISPANIC/LATINO - MEXICAN', 'race_HISPANIC/LATINO - PUERTO RICAN', 'race_HISPANIC/LATINO - SALVADORAN', 'race_MULTIPLE RACE/ETHNICITY', 'race_NATIVE HAWAIIAN OR OTHER PACIFIC ISLANDER', 'race_OTHER', 'race_PATIENT DECLINED TO ANSWER', 'race_PORTUGUESE', 'race_SOUTH AMERICAN', 'race_UNABLE TO OBTAIN', 'race_UNKNOWN', 'race_WHITE', 'race_WHITE - BRAZILIAN', 'race_WHITE - EASTERN EUROPEAN', 'race_WHITE - OTHER EUROPEAN', 'race_WHITE - RUSSIAN', 'race_HISPANIC OR LATINO', 'marital_status_DIVORCED', 'marital_status_MARRIED', 'marital_status_SINGLE', 'marital_status_WIDOWED', 'marital_status_0', 'hospital_stay_duration', 'procedure_225464', 'procedure_225802', 'procedure_227712', 'admission_type_DIRECT EMER.', 'admission_type_DIRECT OBSERVATION', 'admission_type_ELECTIVE', 'admission_type_EU OBSERVATION', 'admission_type_EW EMER.', 'admission_type_OBSERVATION ADMIT', 'admission_type_URGENT', 'admission_type_SURGICAL SAME DAY ADMISSION', 'procedure_225446', 'oasis_score', 'procedure_225400', 'procedure_224263', 'procedure_224276', 'unique_drugs', 'procedure_224267', 'procedure_229351', 'insurance_Medicare', 'insurance_Other', 'insurance_Medicaid', 'icu_stay_duration', 'gender_M', 'gender_F', 'anchor_age', 'item_51301', 'procedure_224275', 'resp_rate', 'item_51265', 'mean_arterial_pressure', 'creatinine', 'bun', 'systolic_bp', 'pt', 'spo2', 'heart_rate', 'procedure_227194', 'glucose', 'item_51222', 'urine_output_total', 'procedure_221223', 'procedure_224274', 'potassium', 'procedure_229380', 'procedure_224270', 'procedure_224385', 'procedure_225752', 'procedure_226124', 'procedure_226236')
# % Combos Checked: 96 out of 204 which is 47.058824%
