# %% [markdown]
# # Tuning Script

# %%
# Parameters subject to change in every script - involved in naming

MODEL = 'logrc'
PREPROCESSING = 'smote_normalise'
TUNER = 'yangzhoub'
OPTIMISED_METRIC = 'f1'

# %% [markdown]
# ---

# %%
# detect whether this is a google environment

COLAB_ENVIRONMENT = False

try:
    from google.colab import drive
    drive.mount('/content/drive')
    COLAB_ENVIRONMENT = True
except:
    pass
# Out:
# Mounted at /content/drive

# %%
import sys
import os
import pickle

if COLAB_ENVIRONMENT:
    home_directory = './drive/MyDrive/LAB/COMP90089__GroupWork__Py/' # my home directory is stored in ./LAB of google drive
    if MODEL == 'ebr':
        # !pip install interpret==0.5.0
    elif MODEL == 'cbr':
        # !pip install catboost
    elif MODEL in ['tf', 'mlp']:
        # !pip install PyTorch2Sklearn
    # !pip install JXAutoML
else:
    home_directory = '../../'

from JXAutoML.YangZhouB_10CV import YangZhouB_10CV as Tuner

import pandas as pd
# Out:
# Collecting JXAutoML
#   Downloading JXAutoML-0.4.4-py3-none-any.whl.metadata (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.2/67.2 kB 1.9 MB/s eta 0:00:00
# Downloading JXAutoML-0.4.4-py3-none-any.whl (52 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.1/52.1 kB 2.8 MB/s eta 0:00:00
# Installing collected packages: JXAutoML
# Successfully installed JXAutoML-0.4.4

# %%
# Parameters that are same for every script

FOLDS = 10  # we have decided to do 10 fold validation

SEED = 42

TASK_TYPE = 'Classification'  # this task is a classification task

# we have decided to tune features as hp
TUNE_FEATURES_AS_HYPERPARAMETERS = True

# %% [markdown]
# ---

# %%
# model to use to tune
from sklearn.linear_model import LogisticRegression as clf

# what values to try for each hyperparameter
parameter_choices = {
    'C': (0.0001, 0.001, 0.01, 0.1, 1, 10),
    'max_iter': (50, 100, 200, 400, 800, 1600),
    'penalty': ('l1', 'l2'),
    'tol': (0.00001, 0.0001, 0.001, 0.01, 0.1, 1)
}

# what values to set non-tuneable parameters/hyperparameters
non_tunable_hyperparameters_dict = {
                                    'random_state': 42,
                                    'n_jobs': -1,
                                    'verbose': 0,
                                    'multi_class': 'ovr',
                                    'solver': 'liblinear'
                                    }

# %% [markdown]
# ---

# %% [markdown]
# Read in and Prepare Data

# %%
# Import data and store as lists

train_x_list = []
train_y_list = []
val_x_list = []
val_y_list = []

for i in range(FOLDS):
    train_data = pd.read_csv(
        f'{home_directory}data/curated/modelling/{PREPROCESSING}/train_{i}.csv')
    val_data = pd.read_csv(
        f'{home_directory}data/curated/modelling/{PREPROCESSING}/val_{i}.csv')

    # get the correct rows for X and y
    train_x = train_data.drop(
        ['mortality_status', 'subject_id', 'hadm_id', 'stay_id'], axis=1)
    train_y = train_data['mortality_status']
    val_x = val_data.drop(
        ['mortality_status', 'subject_id', 'hadm_id', 'stay_id'], axis=1)
    val_y = val_data['mortality_status']

    train_x_list.append(train_x)
    train_y_list.append(train_y)
    val_x_list.append(val_x)
    val_y_list.append(val_y)

# %%
# Import feature importance ordering

with open(f'{home_directory}models/xgb_feature_importance_ordering_{PREPROCESSING}.pickle', 'rb') as f:
    feature_importance_ordering = pickle.load(f)

# %% [markdown]
# Set parameters

# %%
# initialisation
tuner = Tuner()

print('---')

# define what model we are tuning
tuner.read_in_model(clf, TASK_TYPE, optimised_metric=OPTIMISED_METRIC)

print('---')

# read in the data for training and validation
tuner.read_in_data(train_x_list, train_y_list, val_x_list, val_y_list)

print('---')

# set what hp values to tune
tuner.set_hyperparameters(parameter_choices)
# WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

# set up hp values that need to be changed from default but NOT to be tuned
tuner.set_non_tuneable_hyperparameters(non_tunable_hyperparameters_dict)

print('---')

# set up feature importance ordering

if TUNE_FEATURES_AS_HYPERPARAMETERS:
    tuner.set_features(feature_importance_ordering)
    # WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

try:  # try to read in previous results to continue tuning ...
    tuner.read_in_tuning_result_df(
        f'{home_directory}models/tuning/{TUNER}_{MODEL}_{PREPROCESSING}.csv')
except:
    print('No previous tuning data read in')

print('---')

# set up where to save the tuning result csv
tuner.set_tuning_result_saving_address(
    f'{home_directory}models/tuning/{TUNER}_{MODEL}_{PREPROCESSING}.csv')

print('---')

# set up where to save the current best model
tuner.set_best_model_saving_address(
    f'{home_directory}models/tmp_models/{TUNER}_{MODEL}_{PREPROCESSING}')
# Out:
# YangZhouB Initialised
# ---
# Successfully read in model <class 'sklearn.linear_model._logistic.LogisticRegression'>, which is a Classification model optimising for f1
# ---
# Read in Train X data list
# Read in Train y data list
# Read in Val X data list
# Read in Val y data list
# ---
# Successfully recorded hyperparameter choices
# ---
# Successfully recorded non_tuneable_hyperparameter choices
# ---
# Successfully recorded tuneable feature combination choices and updated relevant internal structures
# ---
# No previous tuning data read in
# ---
# Successfully set tuning output address
# ---
# Successfully set best model output address

# %%
# ignore warnings

import warnings
warnings.filterwarnings("ignore")

# %%
# begin tuning ... (or continue training)

tuner.tune()
# Out:
# Streaming output truncated to the last 5000 lines.
#         Has trained 388 of 31104 combinations so far
# Trained and Tested combination 389 of 31104, taking 0.01 seconds to get val score of 0.3244:
#                 {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 0.1, 'features': 0},
#             Current best combo with val score 0.4632:
#                     {'C': 0.1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 40}
# Trained and Tested combination 390 of 31104, taking 0.01 seconds to get val score of 0.0356:
#                 {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1, 'features': 1},
#             Current best combo with val score 0.4632:
#                     {'C': 0.1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 40}
# 	round 6 iteration:  1
#
# Trained and Tested combination 391 of 31104, taking 0.01 seconds to get val score of 0.3244:
#                 {'C': 0.1, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1, 'features': 0},
#             Current best combo with val score 0.4632:
#                     {'C': 0.1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 40}
# Already Trained and Tested combination (val score of 0.3244):
#             {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1, 'features': 0}
#             Current best combo (with val score 0.4632):
#                     {'C': 0.1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 40}
#         Has trained 391 of 31104 combinations so far
# Trained and Tested combination 392 of 31104, taking 0.0 seconds to get val score of 0.3244:
#                 {'C': 1, 'max_iter': 800, 'penalty': 'l1', 'tol': 1, 'features': 0},
#             Current best combo with val score 0.4632:
#                     {'C': 0.1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 40}
# Trained and Tested combination 393 of 31104, taking 0.0 seconds to get val score of 0.3244:
#                 {'C': 1, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1, 'features': 0},
#             Current best combo with val score 0.4632:
#                     {'C': 0.1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 40}
# Trained and Tested combination 394 of 31104, taking 0.0 seconds to get val score of 0.3244:
#                 {'C': 1, 'max_iter': 1600, 'penalty': 'l1', 'tol': 0.1, 'features': 0},
#             Current best combo with val score 0.4632:
#                     {'C': 0.1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 40}
# Trained and Tested combination 395 of 31104, taking 0.01 seconds to get val score of 0.0356:
#                 {'C': 1, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1, 'features': 1},
#             Current best combo with val score 0.4632:
#                     {'C': 0.1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 40}
# Already Trained and Tested combination (val score of 0.3244):
#             {'C': 1, 'max_iter': 800, 'penalty': 'l1', 'tol': 1, 'features': 0}
#             Current best combo (with val score 0.4632):
#                     {'C': 0.1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 40}
#         Has trained 395 of 31104 combinations so far
# Trained and Tested combination 396 of 31104, taking 0.0 seconds to get val score of 0.3244:
#                 {'C': 10, 'max_iter': 400, 'penalty': 'l1', 'tol': 1, 'features': 0},
#             Current best combo with val score 0.4632:
#                     {'C': 0.1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 40}
# Already Trained and Tested combination (val score of 0.3244):
#             {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1, 'features': 0}
#             Current best combo (with val score 0.4632):
#                     {'C': 0.1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 40}
#         Has trained 396 of 31104 combinations so far
# Trained and Tested combination 397 of 31104, taking 0.0 seconds to get val score of 0.3244:
#                 {'C': 10, 'max_iter': 800, 'penalty': 'l2', 'tol': 1, 'features': 0},
#             Current best combo with val score 0.4632:
#                     {'C': 0.1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 40}
# Trained and Tested combination 398 of 31104, taking 0.0 seconds to get val score of 0.3244:
#                 {'C': 10, 'max_iter': 800, 'penalty': 'l1', 'tol': 0.1, 'features': 0},
#             Current best combo with val score 0.4632:
#                     {'C': 0.1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 40}
# Trained and Tested combination 399 of 31104, taking 0.01 seconds to get val score of 0.0356:
#                 {'C': 10, 'max_iter': 800, 'penalty': 'l1', 'tol': 1, 'features': 1},
#             Current best combo with val score 0.4632:
#                     {'C': 0.1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 40}
# Already Trained and Tested combination (val score of 0.3244):
#             {'C': 1, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1, 'features': 0}
#             Current best combo (with val score 0.4632):
#                     {'C': 0.1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 40}
#         Has trained 399 of 31104 combinations so far
# Already Trained and Tested combination (val score of 0.3244):
#             {'C': 10, 'max_iter': 800, 'penalty': 'l2', 'tol': 1, 'features': 0}
#             Current best combo (with val score 0.4632):
#                     {'C': 0.1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 40}
#         Has trained 399 of 31104 combinations so far
# Already Trained and Tested combination (val score of 0.3244):
#             {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1, 'features': 0}
#             Current best combo (with val score 0.4632):
#                     {'C': 0.1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 40}
#         Has trained 399 of 31104 combinations so far
# Trained and Tested combination 400 of 31104, taking 0.0 seconds to get val score of 0.3244:
#                 {'C': 10, 'max_iter': 1600, 'penalty': 'l2', 'tol': 0.1, 'features': 0},
#             Current best combo with val score 0.4632:
#                     {'C': 0.1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 40}
# Trained and Tested combination 401 of 31104, taking 0.01 seconds to get val score of 0.0389:
#                 {'C': 10, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1, 'features': 1},
#             Current best combo with val score 0.4632:
#                     {'C': 0.1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 40}
# Already Trained and Tested combination (val score of 0.3244):
#             {'C': 1, 'max_iter': 1600, 'penalty': 'l1', 'tol': 0.1, 'features': 0}
#             Current best combo (with val score 0.4632):
#                     {'C': 0.1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 40}
#         Has trained 401 of 31104 combinations so far
# Already Trained and Tested combination (val score of 0.3244):
#             {'C': 10, 'max_iter': 800, 'penalty': 'l1', 'tol': 0.1, 'features': 0}
#             Current best combo (with val score 0.4632):
#                     {'C': 0.1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 40}
#         Has trained 401 of 31104 combinations so far
# Already Trained and Tested combination (val score of 0.3244):
#             {'C': 10, 'max_iter': 1600, 'penalty': 'l2', 'tol': 0.1, 'features': 0}
#             Current best combo (with val score 0.4632):
#                     {'C': 0.1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 40}
#         Has trained 401 of 31104 combinations so far
# Trained and Tested combination 402 of 31104, taking 0.0 seconds to get val score of 0.3244:
#                 {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 0.01, 'features': 0},
#             Current best combo with val score 0.4632:
#                     {'C': 0.1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 40}
# Already Trained and Tested combination (val score of 0.3244):
#             {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1, 'features': 0}
#             Current best combo (with val score 0.4632):
#                     {'C': 0.1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 40}
#         Has trained 402 of 31104 combinations so far
# Trained and Tested combination 403 of 31104, taking 0.01 seconds to get val score of 0.0389:
#                 {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 0.1, 'features': 1},
#             Current best combo with val score 0.4632:
#                     {'C': 0.1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 40}
# % Combos Checked Thus Far: 403 out of 31104 which is 1.2956530000000002%
# Cruising Coordrdinate 11 of 256
#
# Cruise suspended due to suspicious case
# Guidance: round 7
#
# 	round 7 iteration:  0
#
# % Combos Checked Thus Far: 403 out of 31104 which is 1.2956530000000002%
# Cruising Coordrdinate 12 of 256
#
# Cruise suspended due to suspicious case
# Guidance: round 8
#
# 	round 8 iteration:  0
#
# % Combos Checked Thus Far: 403 out of 31104 which is 1.2956530000000002%
# Cruising Coordrdinate 13 of 256
#
# Cruising Coordrdinate 14 of 256
#
# Cruising Coordrdinate 15 of 256
#
# Cruise suspended due to suspicious case
# Guidance: round 9
#
# 	round 9 iteration:  0
#
# Trained and Tested combination 404 of 31104, taking 0.0 seconds to get val score of 0.3244:
#                 {'C': 1, 'max_iter': 50, 'penalty': 'l1', 'tol': 1, 'features': 0},
#             Current best combo with val score 0.4632:
#                     {'C': 0.1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 40}
# Trained and Tested combination 405 of 31104, taking 0.0 seconds to get val score of 0.3244:
#                 {'C': 10, 'max_iter': 100, 'penalty': 'l1', 'tol': 1, 'features': 0},
#             Current best combo with val score 0.4632:
#                     {'C': 0.1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 40}
# Already Trained and Tested combination (val score of 0.3244):
#             {'C': 10, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 0}
#             Current best combo (with val score 0.4632):
#                     {'C': 0.1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 40}
#         Has trained 405 of 31104 combinations so far
# Trained and Tested combination 406 of 31104, taking 0.0 seconds to get val score of 0.3244:
#                 {'C': 10, 'max_iter': 50, 'penalty': 'l1', 'tol': 0.1, 'features': 0},
#             Current best combo with val score 0.4632:
#                     {'C': 0.1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 40}
# Trained and Tested combination 407 of 31104, taking 0.01 seconds to get val score of 0.0356:
#                 {'C': 10, 'max_iter': 50, 'penalty': 'l1', 'tol': 1, 'features': 1},
#             Current best combo with val score 0.4632:
#                     {'C': 0.1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 40}
# 	round 9 iteration:  1
#
# Trained and Tested combination 408 of 31104, taking 0.0 seconds to get val score of 0.3244:
#                 {'C': 0.1, 'max_iter': 50, 'penalty': 'l1', 'tol': 1, 'features': 0},
#             Current best combo with val score 0.4632:
#                     {'C': 0.1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 40}
# Already Trained and Tested combination (val score of 0.3244):
#             {'C': 10, 'max_iter': 50, 'penalty': 'l1', 'tol': 1, 'features': 0}
#             Current best combo (with val score 0.4632):
#                     {'C': 0.1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 40}
#         Has trained 408 of 31104 combinations so far
# Trained and Tested combination 409 of 31104, taking 0.0 seconds to get val score of 0.3244:
#                 {'C': 1, 'max_iter': 100, 'penalty': 'l1', 'tol': 1, 'features': 0},
#             Current best combo with val score 0.4632:
#                     {'C': 0.1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 40}
# Trained and Tested combination 410 of 31104, taking 0.0 seconds to get val score of 0.3244:
#                 {'C': 1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 0},
#             Current best combo with val score 0.4632:
#                     {'C': 0.1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 40}
# Trained and Tested combination 411 of 31104, taking 0.01 seconds to get val score of 0.3244:
#                 {'C': 1, 'max_iter': 50, 'penalty': 'l1', 'tol': 0.1, 'features': 0},
#             Current best combo with val score 0.4632:
#                     {'C': 0.1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 40}
# Trained and Tested combination 412 of 31104, taking 0.01 seconds to get val score of 0.0356:
#                 {'C': 1, 'max_iter': 50, 'penalty': 'l1', 'tol': 1, 'features': 1},
#             Current best combo with val score 0.4632:
#                     {'C': 0.1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 40}
# Already Trained and Tested combination (val score of 0.3244):
#             {'C': 1, 'max_iter': 100, 'penalty': 'l1', 'tol': 1, 'features': 0}
#             Current best combo (with val score 0.4632):
#                     {'C': 0.1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 40}
#         Has trained 412 of 31104 combinations so far
# Already Trained and Tested combination (val score of 0.3244):
#             {'C': 10, 'max_iter': 50, 'penalty': 'l1', 'tol': 1, 'features': 0}
#             Current best combo (with val score 0.4632):
#                     {'C': 0.1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 40}
#         Has trained 412 of 31104 combinations so far
# Trained and Tested combination 413 of 31104, taking 0.01 seconds to get val score of 0.3244:
#                 {'C': 10, 'max_iter': 200, 'penalty': 'l1', 'tol': 1, 'features': 0},
#             Current best combo with val score 0.4632:
#                     {'C': 0.1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 40}
# Trained and Tested combination 414 of 31104, taking 0.01 seconds to get val score of 0.3244:
#                 {'C': 10, 'max_iter': 100, 'penalty': 'l2', 'tol': 1, 'features': 0},
#             Current best combo with val score 0.4632:
#                     {'C': 0.1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 40}
# Trained and Tested combination 415 of 31104, taking 0.01 seconds to get val score of 0.3244:
#                 {'C': 10, 'max_iter': 100, 'penalty': 'l1', 'tol': 0.1, 'features': 0},
#             Current best combo with val score 0.4632:
#                     {'C': 0.1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 40}
# Trained and Tested combination 416 of 31104, taking 0.01 seconds to get val score of 0.0356:
#                 {'C': 10, 'max_iter': 100, 'penalty': 'l1', 'tol': 1, 'features': 1},
#             Current best combo with val score 0.4632:
#                     {'C': 0.1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 40}
# Already Trained and Tested combination (val score of 0.3244):
#             {'C': 1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 0}
#             Current best combo (with val score 0.4632):
#                     {'C': 0.1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 40}
#         Has trained 416 of 31104 combinations so far
# Already Trained and Tested combination (val score of 0.3244):
#             {'C': 10, 'max_iter': 100, 'penalty': 'l2', 'tol': 1, 'features': 0}
#             Current best combo (with val score 0.4632):
#                     {'C': 0.1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 40}
#         Has trained 416 of 31104 combinations so far
# Already Trained and Tested combination (val score of 0.3244):
#             {'C': 10, 'max_iter': 50, 'penalty': 'l1', 'tol': 1, 'features': 0}
#             Current best combo (with val score 0.4632):
#                     {'C': 0.1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 40}
#         Has trained 416 of 31104 combinations so far
# Trained and Tested combination 417 of 31104, taking 0.0 seconds to get val score of 0.3244:
#                 {'C': 10, 'max_iter': 50, 'penalty': 'l2', 'tol': 0.1, 'features': 0},
#             Current best combo with val score 0.4632:
#                     {'C': 0.1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 40}
# Trained and Tested combination 418 of 31104, taking 0.01 seconds to get val score of 0.0389:
#                 {'C': 10, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 1},
#             Current best combo with val score 0.4632:
#                     {'C': 0.1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 40}
# Already Trained and Tested combination (val score of 0.3244):
#             {'C': 1, 'max_iter': 50, 'penalty': 'l1', 'tol': 0.1, 'features': 0}
#             Current best combo (with val score 0.4632):
#                     {'C': 0.1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 40}
#         Has trained 418 of 31104 combinations so far
# Already Trained and Tested combination (val score of 0.3244):
#             {'C': 10, 'max_iter': 100, 'penalty': 'l1', 'tol': 0.1, 'features': 0}
#             Current best combo (with val score 0.4632):
#                     {'C': 0.1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 40}
#         Has trained 418 of 31104 combinations so far
# Already Trained and Tested combination (val score of 0.3244):
#             {'C': 10, 'max_iter': 50, 'penalty': 'l2', 'tol': 0.1, 'features': 0}
#             Current best combo (with val score 0.4632):
#                     {'C': 0.1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 40}
#         Has trained 418 of 31104 combinations so far
# Trained and Tested combination 419 of 31104, taking 0.0 seconds to get val score of 0.3244:
#                 {'C': 10, 'max_iter': 50, 'penalty': 'l1', 'tol': 0.01, 'features': 0},
#             Current best combo with val score 0.4632:
#                     {'C': 0.1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 40}
# Already Trained and Tested combination (val score of 0.3244):
#             {'C': 10, 'max_iter': 50, 'penalty': 'l1', 'tol': 1, 'features': 0}
#             Current best combo (with val score 0.4632):
#                     {'C': 0.1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 40}
#         Has trained 419 of 31104 combinations so far
# Trained and Tested combination 420 of 31104, taking 0.01 seconds to get val score of 0.0389:
#                 {'C': 10, 'max_iter': 50, 'penalty': 'l1', 'tol': 0.1, 'features': 1},
#             Current best combo with val score 0.4632:
#                     {'C': 0.1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 40}
# % Combos Checked Thus Far: 420 out of 31104 which is 1.350309%
# Cruising Coordrdinate 16 of 256
#
# Cruise suspended due to suspicious case
# Guidance: round 10
#
# 	round 10 iteration:  0
#
# % Combos Checked Thus Far: 420 out of 31104 which is 1.350309%
# Cruising Coordrdinate 17 of 256
#
# Cruising Coordrdinate 18 of 256
#
# Cruising Coordrdinate 19 of 256
#
# Cruising Coordrdinate 20 of 256
#
# Cruising Coordrdinate 21 of 256
#
# Cruising Coordrdinate 22 of 256
#
# Cruising Coordrdinate 23 of 256
#
# Cruising Coordrdinate 24 of 256
#
# Cruising Coordrdinate 25 of 256
#
# Cruising Coordrdinate 26 of 256
#
# Cruise suspended due to suspicious case
# Guidance: round 11
#
# 	round 11 iteration:  0
#
# Trained and Tested combination 421 of 31104, taking 0.01 seconds to get val score of 0.1778:
#                 {'C': 1, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1, 'features': 5},
#             Current best combo with val score 0.4632:
#                     {'C': 0.1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 40}
# Trained and Tested combination 422 of 31104, taking 0.01 seconds to get val score of 0.1891:
#                 {'C': 10, 'max_iter': 800, 'penalty': 'l1', 'tol': 1, 'features': 5},
#             Current best combo with val score 0.4632:
#                     {'C': 0.1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 40}
# Already Trained and Tested combination (val score of 0.0356):
#             {'C': 10, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1, 'features': 5}
#             Current best combo (with val score 0.4632):
#                     {'C': 0.1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 40}
#         Has trained 422 of 31104 combinations so far
# Trained and Tested combination 423 of 31104, taking 0.01 seconds to get val score of 0.0261:
#                 {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 0.1, 'features': 5},
#             Current best combo with val score 0.4632:
#                     {'C': 0.1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 40}
# Trained and Tested combination 424 of 31104, taking 0.01 seconds to get val score of 0.0704:
#                 {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1, 'features': 4},
#             Current best combo with val score 0.4632:
#                     {'C': 0.1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 40}
# Trained and Tested combination 425 of 31104, taking 0.01 seconds to get val score of 0.0295:
#                 {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1, 'features': 6},
#             Current best combo with val score 0.4632:
#                     {'C': 0.1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 40}
# 	round 11 iteration:  1
#
# Trained and Tested combination 426 of 31104, taking 0.01 seconds to get val score of 0.1778:
#                 {'C': 1, 'max_iter': 800, 'penalty': 'l1', 'tol': 1, 'features': 5},
#             Current best combo with val score 0.4632:
#                     {'C': 0.1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 40}
# Trained and Tested combination 427 of 31104, taking 0.01 seconds to get val score of 0.1891:
#                 {'C': 10, 'max_iter': 400, 'penalty': 'l1', 'tol': 1, 'features': 5},
#             Current best combo with val score 0.4632:
#                     {'C': 0.1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 40}
# Already Trained and Tested combination (val score of 0.1891):
#             {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1, 'features': 5}
#             Current best combo (with val score 0.4632):
#                     {'C': 0.1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 40}
#         Has trained 427 of 31104 combinations so far
# Trained and Tested combination 428 of 31104, taking 0.01 seconds to get val score of 0.0356:
#                 {'C': 10, 'max_iter': 800, 'penalty': 'l2', 'tol': 1, 'features': 5},
#             Current best combo with val score 0.4632:
#                     {'C': 0.1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 40}
# Trained and Tested combination 429 of 31104, taking 0.01 seconds to get val score of 0.0261:
#                 {'C': 10, 'max_iter': 800, 'penalty': 'l1', 'tol': 0.1, 'features': 5},
#             Current best combo with val score 0.4632:
#                     {'C': 0.1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 40}
# Trained and Tested combination 430 of 31104, taking 0.02 seconds to get val score of 0.0704:
#                 {'C': 10, 'max_iter': 800, 'penalty': 'l1', 'tol': 1, 'features': 4},
#             Current best combo with val score 0.4632:
#                     {'C': 0.1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 40}
# Trained and Tested combination 431 of 31104, taking 0.01 seconds to get val score of 0.0295:
#                 {'C': 10, 'max_iter': 800, 'penalty': 'l1', 'tol': 1, 'features': 6},
#             Current best combo with val score 0.4632:
#                     {'C': 0.1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 40}
# % Combos Checked Thus Far: 431 out of 31104 which is 1.3856739999999999%
# Cruising Coordrdinate 27 of 256
#
# Cruising Coordrdinate 28 of 256
#
# Cruising Coordrdinate 29 of 256
#
# Cruising Coordrdinate 30 of 256
#
# Cruising Coordrdinate 31 of 256
#
# Cruise suspended due to suspicious case
# Guidance: round 12
#
# 	round 12 iteration:  0
#
# Trained and Tested combination 432 of 31104, taking 0.01 seconds to get val score of 0.1778:
#                 {'C': 1, 'max_iter': 50, 'penalty': 'l1', 'tol': 1, 'features': 5},
#             Current best combo with val score 0.4632:
#                     {'C': 0.1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 40}
# Trained and Tested combination 433 of 31104, taking 0.02 seconds to get val score of 0.1891:
#                 {'C': 10, 'max_iter': 100, 'penalty': 'l1', 'tol': 1, 'features': 5},
#             Current best combo with val score 0.4632:
#                     {'C': 0.1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 40}
# Already Trained and Tested combination (val score of 0.0356):
#             {'C': 10, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 5}
#             Current best combo (with val score 0.4632):
#                     {'C': 0.1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 40}
#         Has trained 433 of 31104 combinations so far
# Trained and Tested combination 434 of 31104, taking 0.02 seconds to get val score of 0.0261:
#                 {'C': 10, 'max_iter': 50, 'penalty': 'l1', 'tol': 0.1, 'features': 5},
#             Current best combo with val score 0.4632:
#                     {'C': 0.1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 40}
# Trained and Tested combination 435 of 31104, taking 0.01 seconds to get val score of 0.0704:
#                 {'C': 10, 'max_iter': 50, 'penalty': 'l1', 'tol': 1, 'features': 4},
#             Current best combo with val score 0.4632:
#                     {'C': 0.1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 40}
# Trained and Tested combination 436 of 31104, taking 0.01 seconds to get val score of 0.0295:
#                 {'C': 10, 'max_iter': 50, 'penalty': 'l1', 'tol': 1, 'features': 6},
#             Current best combo with val score 0.4632:
#                     {'C': 0.1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 40}
# 	round 12 iteration:  1
#
# Trained and Tested combination 437 of 31104, taking 0.01 seconds to get val score of 0.1778:
#                 {'C': 1, 'max_iter': 100, 'penalty': 'l1', 'tol': 1, 'features': 5},
#             Current best combo with val score 0.4632:
#                     {'C': 0.1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 40}
# Already Trained and Tested combination (val score of 0.1891):
#             {'C': 10, 'max_iter': 50, 'penalty': 'l1', 'tol': 1, 'features': 5}
#             Current best combo (with val score 0.4632):
#                     {'C': 0.1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 40}
#         Has trained 437 of 31104 combinations so far
# Trained and Tested combination 438 of 31104, taking 0.01 seconds to get val score of 0.1891:
#                 {'C': 10, 'max_iter': 200, 'penalty': 'l1', 'tol': 1, 'features': 5},
#             Current best combo with val score 0.4632:
#                     {'C': 0.1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 40}
# Trained and Tested combination 439 of 31104, taking 0.01 seconds to get val score of 0.0356:
#                 {'C': 10, 'max_iter': 100, 'penalty': 'l2', 'tol': 1, 'features': 5},
#             Current best combo with val score 0.4632:
#                     {'C': 0.1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 40}
# Trained and Tested combination 440 of 31104, taking 0.01 seconds to get val score of 0.0261:
#                 {'C': 10, 'max_iter': 100, 'penalty': 'l1', 'tol': 0.1, 'features': 5},
#             Current best combo with val score 0.4632:
#                     {'C': 0.1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 40}
# Trained and Tested combination 441 of 31104, taking 0.01 seconds to get val score of 0.0704:
#                 {'C': 10, 'max_iter': 100, 'penalty': 'l1', 'tol': 1, 'features': 4},
#             Current best combo with val score 0.4632:
#                     {'C': 0.1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 40}
# Trained and Tested combination 442 of 31104, taking 0.01 seconds to get val score of 0.0295:
#                 {'C': 10, 'max_iter': 100, 'penalty': 'l1', 'tol': 1, 'features': 6},
#             Current best combo with val score 0.4632:
#                     {'C': 0.1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 40}
# % Combos Checked Thus Far: 442 out of 31104 which is 1.421039%
# Cruising Coordrdinate 32 of 256
#
# Cruising Coordrdinate 33 of 256
#
# Cruising Coordrdinate 34 of 256
#
# Cruising Coordrdinate 35 of 256
#
# Cruising Coordrdinate 36 of 256
#
# Cruising Coordrdinate 37 of 256
#
# Cruising Coordrdinate 38 of 256
#
# Cruising Coordrdinate 39 of 256
#
# Cruising Coordrdinate 40 of 256
#
# Cruising Coordrdinate 41 of 256
#
# Cruising Coordrdinate 42 of 256
#
# Cruising Coordrdinate 43 of 256
#
# Cruising Coordrdinate 44 of 256
#
# Cruising Coordrdinate 45 of 256
#
# Cruising Coordrdinate 46 of 256
#
# Cruising Coordrdinate 47 of 256
#
# Cruising Coordrdinate 48 of 256
#
# Cruising Coordrdinate 49 of 256
#
# Cruising Coordrdinate 50 of 256
#
# Cruising Coordrdinate 51 of 256
#
# Cruising Coordrdinate 52 of 256
#
# Cruising Coordrdinate 53 of 256
#
# Cruising Coordrdinate 54 of 256
#
# Cruising Coordrdinate 55 of 256
#
# Cruising Coordrdinate 56 of 256
#
# Cruising Coordrdinate 57 of 256
#
# Cruising Coordrdinate 58 of 256
#
# Cruising Coordrdinate 59 of 256
#
# Cruising Coordrdinate 60 of 256
#
# Cruise suspended due to suspicious case
# Guidance: round 13
#
# 	round 13 iteration:  0
#
# Trained and Tested combination 443 of 31104, taking 0.01 seconds to get val score of 0.3398:
#                 {'C': 1, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1, 'features': 10},
#             Current best combo with val score 0.4632:
#                     {'C': 0.1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 40}
# Trained and Tested combination 444 of 31104, taking 0.01 seconds to get val score of 0.3394:
#                 {'C': 10, 'max_iter': 800, 'penalty': 'l2', 'tol': 1, 'features': 10},
#             Current best combo with val score 0.4632:
#                     {'C': 0.1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 40}
# Already Trained and Tested combination (val score of 0.0264):
#             {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1, 'features': 10}
#             Current best combo (with val score 0.4632):
#                     {'C': 0.1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 40}
#         Has trained 444 of 31104 combinations so far
# Trained and Tested combination 445 of 31104, taking 0.01 seconds to get val score of 0.1016:
#                 {'C': 10, 'max_iter': 1600, 'penalty': 'l2', 'tol': 0.1, 'features': 10},
#             Current best combo with val score 0.4632:
#                     {'C': 0.1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 40}
# Trained and Tested combination 446 of 31104, taking 0.01 seconds to get val score of 0.0295:
#                 {'C': 10, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1, 'features': 9},
#             Current best combo with val score 0.4632:
#                     {'C': 0.1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 40}
# Trained and Tested combination 447 of 31104, taking 0.01 seconds to get val score of 0.376:
#                 {'C': 10, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1, 'features': 11},
#             Current best combo with val score 0.4632:
#                     {'C': 0.1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 40}
# 	round 13 iteration:  1
#
# Trained and Tested combination 448 of 31104, taking 0.01 seconds to get val score of 0.3204:
#                 {'C': 0.1, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1, 'features': 10},
#             Current best combo with val score 0.4632:
#                     {'C': 0.1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 40}
# Already Trained and Tested combination (val score of 0.3394):
#             {'C': 10, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1, 'features': 10}
#             Current best combo (with val score 0.4632):
#                     {'C': 0.1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 40}
#         Has trained 448 of 31104 combinations so far
# Trained and Tested combination 449 of 31104, taking 0.02 seconds to get val score of 0.3398:
#                 {'C': 1, 'max_iter': 800, 'penalty': 'l2', 'tol': 1, 'features': 10},
#             Current best combo with val score 0.4632:
#                     {'C': 0.1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 40}
# Trained and Tested combination 450 of 31104, taking 0.01 seconds to get val score of 0.0198:
#                 {'C': 1, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1, 'features': 10},
#             Current best combo with val score 0.4632:
#                     {'C': 0.1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 40}
# Trained and Tested combination 451 of 31104, taking 0.01 seconds to get val score of 0.1167:
#                 {'C': 1, 'max_iter': 1600, 'penalty': 'l2', 'tol': 0.1, 'features': 10},
#             Current best combo with val score 0.4632:
#                     {'C': 0.1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 40}
# Trained and Tested combination 452 of 31104, taking 0.01 seconds to get val score of 0.0424:
#                 {'C': 1, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1, 'features': 9},
#             Current best combo with val score 0.4632:
#                     {'C': 0.1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 40}
# Trained and Tested combination 453 of 31104, taking 0.01 seconds to get val score of 0.3729:
#                 {'C': 1, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1, 'features': 11},
#             Current best combo with val score 0.4632:
#                     {'C': 0.1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 40}
# Already Trained and Tested combination (val score of 0.3398):
#             {'C': 1, 'max_iter': 800, 'penalty': 'l2', 'tol': 1, 'features': 10}
#             Current best combo (with val score 0.4632):
#                     {'C': 0.1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 40}
#         Has trained 453 of 31104 combinations so far
# Trained and Tested combination 454 of 31104, taking 0.01 seconds to get val score of 0.3394:
#                 {'C': 10, 'max_iter': 400, 'penalty': 'l2', 'tol': 1, 'features': 10},
#             Current best combo with val score 0.4632:
#                     {'C': 0.1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 40}
# Already Trained and Tested combination (val score of 0.3394):
#             {'C': 10, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1, 'features': 10}
#             Current best combo (with val score 0.4632):
#                     {'C': 0.1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 40}
#         Has trained 454 of 31104 combinations so far
# Trained and Tested combination 455 of 31104, taking 0.01 seconds to get val score of 0.0264:
#                 {'C': 10, 'max_iter': 800, 'penalty': 'l1', 'tol': 1, 'features': 10},
#             Current best combo with val score 0.4632:
#                     {'C': 0.1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 40}
# Trained and Tested combination 456 of 31104, taking 0.01 seconds to get val score of 0.1016:
#                 {'C': 10, 'max_iter': 800, 'penalty': 'l2', 'tol': 0.1, 'features': 10},
#             Current best combo with val score 0.4632:
#                     {'C': 0.1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 40}
# Trained and Tested combination 457 of 31104, taking 0.01 seconds to get val score of 0.0295:
#                 {'C': 10, 'max_iter': 800, 'penalty': 'l2', 'tol': 1, 'features': 9},
#             Current best combo with val score 0.4632:
#                     {'C': 0.1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 40}
# Trained and Tested combination 458 of 31104, taking 0.01 seconds to get val score of 0.376:
#                 {'C': 10, 'max_iter': 800, 'penalty': 'l2', 'tol': 1, 'features': 11},
#             Current best combo with val score 0.4632:
#                     {'C': 0.1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 40}
# Already Trained and Tested combination (val score of 0.3729):
#             {'C': 1, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1, 'features': 11}
#             Current best combo (with val score 0.4632):
#                     {'C': 0.1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 40}
#         Has trained 458 of 31104 combinations so far
# Already Trained and Tested combination (val score of 0.376):
#             {'C': 10, 'max_iter': 800, 'penalty': 'l2', 'tol': 1, 'features': 11}
#             Current best combo (with val score 0.4632):
#                     {'C': 0.1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 40}
#         Has trained 458 of 31104 combinations so far
# Trained and Tested combination 459 of 31104, taking 0.01 seconds to get val score of 0.165:
#                 {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1, 'features': 11},
#             Current best combo with val score 0.4632:
#                     {'C': 0.1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 40}
# Trained and Tested combination 460 of 31104, taking 0.02 seconds to get val score of 0.2834:
#                 {'C': 10, 'max_iter': 1600, 'penalty': 'l2', 'tol': 0.1, 'features': 11},
#             Current best combo with val score 0.4632:
#                     {'C': 0.1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 40}
# Already Trained and Tested combination (val score of 0.3394):
#             {'C': 10, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1, 'features': 10}
#             Current best combo (with val score 0.4632):
#                     {'C': 0.1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 40}
#         Has trained 460 of 31104 combinations so far
# Trained and Tested combination 461 of 31104, taking 0.02 seconds to get val score of 0.3744:
#                 {'C': 10, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1, 'features': 12},
#             Current best combo with val score 0.4632:
#                     {'C': 0.1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 40}
# % Combos Checked Thus Far: 461 out of 31104 which is 1.482124%
# Cruising Coordrdinate 61 of 256
#
# Cruising Coordrdinate 62 of 256
#
# Cruising Coordrdinate 63 of 256
#
# Cruising Coordrdinate 64 of 256
#
# Cruise suspended due to suspicious case
# Guidance: round 14
#
# 	round 14 iteration:  0
#
# Trained and Tested combination 462 of 31104, taking 0.01 seconds to get val score of 0.3398:
#                 {'C': 1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 10},
#             Current best combo with val score 0.4632:
#                     {'C': 0.1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 40}
# Trained and Tested combination 463 of 31104, taking 0.01 seconds to get val score of 0.3394:
#                 {'C': 10, 'max_iter': 100, 'penalty': 'l2', 'tol': 1, 'features': 10},
#             Current best combo with val score 0.4632:
#                     {'C': 0.1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 40}
# Already Trained and Tested combination (val score of 0.0264):
#             {'C': 10, 'max_iter': 50, 'penalty': 'l1', 'tol': 1, 'features': 10}
#             Current best combo (with val score 0.4632):
#                     {'C': 0.1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 40}
#         Has trained 463 of 31104 combinations so far
# Trained and Tested combination 464 of 31104, taking 0.02 seconds to get val score of 0.1016:
#                 {'C': 10, 'max_iter': 50, 'penalty': 'l2', 'tol': 0.1, 'features': 10},
#             Current best combo with val score 0.4632:
#                     {'C': 0.1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 40}
# Trained and Tested combination 465 of 31104, taking 0.02 seconds to get val score of 0.0295:
#                 {'C': 10, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 9},
#             Current best combo with val score 0.4632:
#                     {'C': 0.1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 40}
# Trained and Tested combination 466 of 31104, taking 0.01 seconds to get val score of 0.376:
#                 {'C': 10, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 11},
#             Current best combo with val score 0.4632:
#                     {'C': 0.1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 40}
# 	round 14 iteration:  1
#
# Trained and Tested combination 467 of 31104, taking 0.02 seconds to get val score of 0.3204:
#                 {'C': 0.1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 10},
#             Current best combo with val score 0.4632:
#                     {'C': 0.1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 40}
# Already Trained and Tested combination (val score of 0.3394):
#             {'C': 10, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 10}
#             Current best combo (with val score 0.4632):
#                     {'C': 0.1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 40}
#         Has trained 467 of 31104 combinations so far
# Trained and Tested combination 468 of 31104, taking 0.02 seconds to get val score of 0.3398:
#                 {'C': 1, 'max_iter': 100, 'penalty': 'l2', 'tol': 1, 'features': 10},
#             Current best combo with val score 0.4632:
#                     {'C': 0.1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 40}
# Trained and Tested combination 469 of 31104, taking 0.01 seconds to get val score of 0.0198:
#                 {'C': 1, 'max_iter': 50, 'penalty': 'l1', 'tol': 1, 'features': 10},
#             Current best combo with val score 0.4632:
#                     {'C': 0.1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 40}
# Trained and Tested combination 470 of 31104, taking 0.02 seconds to get val score of 0.1167:
#                 {'C': 1, 'max_iter': 50, 'penalty': 'l2', 'tol': 0.1, 'features': 10},
#             Current best combo with val score 0.4632:
#                     {'C': 0.1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 40}
# Trained and Tested combination 471 of 31104, taking 0.01 seconds to get val score of 0.0424:
#                 {'C': 1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 9},
#             Current best combo with val score 0.4632:
#                     {'C': 0.1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 40}
# Trained and Tested combination 472 of 31104, taking 0.01 seconds to get val score of 0.3729:
#                 {'C': 1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 11},
#             Current best combo with val score 0.4632:
#                     {'C': 0.1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 40}
# Already Trained and Tested combination (val score of 0.3398):
#             {'C': 1, 'max_iter': 100, 'penalty': 'l2', 'tol': 1, 'features': 10}
#             Current best combo (with val score 0.4632):
#                     {'C': 0.1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 40}
#         Has trained 472 of 31104 combinations so far
# Already Trained and Tested combination (val score of 0.3394):
#             {'C': 10, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 10}
#             Current best combo (with val score 0.4632):
#                     {'C': 0.1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 40}
#         Has trained 472 of 31104 combinations so far
# Trained and Tested combination 473 of 31104, taking 0.01 seconds to get val score of 0.3394:
#                 {'C': 10, 'max_iter': 200, 'penalty': 'l2', 'tol': 1, 'features': 10},
#             Current best combo with val score 0.4632:
#                     {'C': 0.1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 40}
# Trained and Tested combination 474 of 31104, taking 0.01 seconds to get val score of 0.0264:
#                 {'C': 10, 'max_iter': 100, 'penalty': 'l1', 'tol': 1, 'features': 10},
#             Current best combo with val score 0.4632:
#                     {'C': 0.1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 40}
# Trained and Tested combination 475 of 31104, taking 0.02 seconds to get val score of 0.1016:
#                 {'C': 10, 'max_iter': 100, 'penalty': 'l2', 'tol': 0.1, 'features': 10},
#             Current best combo with val score 0.4632:
#                     {'C': 0.1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 40}
# Trained and Tested combination 476 of 31104, taking 0.01 seconds to get val score of 0.0295:
#                 {'C': 10, 'max_iter': 100, 'penalty': 'l2', 'tol': 1, 'features': 9},
#             Current best combo with val score 0.4632:
#                     {'C': 0.1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 40}
# Trained and Tested combination 477 of 31104, taking 0.01 seconds to get val score of 0.376:
#                 {'C': 10, 'max_iter': 100, 'penalty': 'l2', 'tol': 1, 'features': 11},
#             Current best combo with val score 0.4632:
#                     {'C': 0.1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 40}
# Already Trained and Tested combination (val score of 0.3729):
#             {'C': 1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 11}
#             Current best combo (with val score 0.4632):
#                     {'C': 0.1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 40}
#         Has trained 477 of 31104 combinations so far
# Already Trained and Tested combination (val score of 0.376):
#             {'C': 10, 'max_iter': 100, 'penalty': 'l2', 'tol': 1, 'features': 11}
#             Current best combo (with val score 0.4632):
#                     {'C': 0.1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 40}
#         Has trained 477 of 31104 combinations so far
# Trained and Tested combination 478 of 31104, taking 0.01 seconds to get val score of 0.165:
#                 {'C': 10, 'max_iter': 50, 'penalty': 'l1', 'tol': 1, 'features': 11},
#             Current best combo with val score 0.4632:
#                     {'C': 0.1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 40}
# Trained and Tested combination 479 of 31104, taking 0.02 seconds to get val score of 0.2834:
#                 {'C': 10, 'max_iter': 50, 'penalty': 'l2', 'tol': 0.1, 'features': 11},
#             Current best combo with val score 0.4632:
#                     {'C': 0.1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 40}
# Already Trained and Tested combination (val score of 0.3394):
#             {'C': 10, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 10}
#             Current best combo (with val score 0.4632):
#                     {'C': 0.1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 40}
#         Has trained 479 of 31104 combinations so far
# Trained and Tested combination 480 of 31104, taking 0.01 seconds to get val score of 0.3744:
#                 {'C': 10, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 12},
#             Current best combo with val score 0.4632:
#                     {'C': 0.1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 40}
# % Combos Checked Thus Far: 480 out of 31104 which is 1.54321%
# Cruising Coordrdinate 65 of 256
#
# Cruising Coordrdinate 66 of 256
#
# Cruising Coordrdinate 67 of 256
#
# Cruising Coordrdinate 68 of 256
#
# Cruising Coordrdinate 69 of 256
#
# Cruising Coordrdinate 70 of 256
#
# Cruising Coordrdinate 71 of 256
#
# Cruising Coordrdinate 72 of 256
#
# Cruising Coordrdinate 73 of 256
#
# Cruising Coordrdinate 74 of 256
#
# Cruising Coordrdinate 75 of 256
#
# Cruising Coordrdinate 76 of 256
#
# Cruising Coordrdinate 77 of 256
#
# Cruising Coordrdinate 78 of 256
#
# Cruising Coordrdinate 79 of 256
#
# Cruising Coordrdinate 80 of 256
#
# Cruising Coordrdinate 81 of 256
#
# Cruising Coordrdinate 82 of 256
#
# Cruising Coordrdinate 83 of 256
#
# Cruise suspended due to suspicious case
# Guidance: round 15
#
# 	round 15 iteration:  0
#
# Trained and Tested combination 481 of 31104, taking 0.33 seconds to get val score of 0.2793:
#                 {'C': 1, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1e-05, 'features': 15},
#             Current best combo with val score 0.4632:
#                     {'C': 0.1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 40}
# Trained and Tested combination 482 of 31104, taking 1.88 seconds to get val score of 0.2737:
# ...
# Already Trained and Tested combination (val score of 0.0738):
#             {'C': 10, 'max_iter': 50, 'penalty': 'l1', 'tol': 1, 'features': 40}
#             Current best combo (with val score 0.4632):
#                     {'C': 0.1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 40}
#         Has trained 965 of 31104 combinations so far
# Already Trained and Tested combination (val score of 0.0163):
#             {'C': 10, 'max_iter': 50, 'penalty': 'l2', 'tol': 0.1, 'features': 40}
#             Current best combo (with val score 0.4632):
#                     {'C': 0.1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 40}
#         Has trained 965 of 31104 combinations so far
# Already Trained and Tested combination (val score of 0.4402):
#             {'C': 10, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 39}
#             Current best combo (with val score 0.4632):
#                     {'C': 0.1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 40}
#         Has trained 965 of 31104 combinations so far
# Already Trained and Tested combination (val score of 0.4499):
#             {'C': 10, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 41}
#             Current best combo (with val score 0.4632):
#                     {'C': 0.1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 40}
#         Has trained 965 of 31104 combinations so far
# 	round 50 iteration:  1
#
# Already Trained and Tested combination (val score of 0.4632):
#             {'C': 0.1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 40}
#             Current best combo (with val score 0.4632):
#                     {'C': 0.1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 40}
#         Has trained 965 of 31104 combinations so far
# Already Trained and Tested combination (val score of 0.4494):
#             {'C': 10, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 40}
#             Current best combo (with val score 0.4632):
#                     {'C': 0.1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 40}
#         Has trained 965 of 31104 combinations so far
# Already Trained and Tested combination (val score of 0.4547):
#             {'C': 1, 'max_iter': 100, 'penalty': 'l2', 'tol': 1, 'features': 40}
#             Current best combo (with val score 0.4632):
#                     {'C': 0.1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 40}
#         Has trained 965 of 31104 combinations so far
# Already Trained and Tested combination (val score of 0.0681):
#             {'C': 1, 'max_iter': 50, 'penalty': 'l1', 'tol': 1, 'features': 40}
#             Current best combo (with val score 0.4632):
#                     {'C': 0.1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 40}
#         Has trained 965 of 31104 combinations so far
# Already Trained and Tested combination (val score of 0.0229):
#             {'C': 1, 'max_iter': 50, 'penalty': 'l2', 'tol': 0.1, 'features': 40}
#             Current best combo (with val score 0.4632):
#                     {'C': 0.1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 40}
#         Has trained 965 of 31104 combinations so far
# Already Trained and Tested combination (val score of 0.4478):
#             {'C': 1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 39}
#             Current best combo (with val score 0.4632):
#                     {'C': 0.1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 40}
#         Has trained 965 of 31104 combinations so far
# Already Trained and Tested combination (val score of 0.4513):
#             {'C': 1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 41}
#             Current best combo (with val score 0.4632):
#                     {'C': 0.1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 40}
#         Has trained 965 of 31104 combinations so far
# Already Trained and Tested combination (val score of 0.4547):
#             {'C': 1, 'max_iter': 100, 'penalty': 'l2', 'tol': 1, 'features': 40}
#             Current best combo (with val score 0.4632):
#                     {'C': 0.1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 40}
#         Has trained 965 of 31104 combinations so far
# Already Trained and Tested combination (val score of 0.4494):
#             {'C': 10, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 40}
#             Current best combo (with val score 0.4632):
#                     {'C': 0.1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 40}
#         Has trained 965 of 31104 combinations so far
# Trained and Tested combination 966 of 31104, taking 0.02 seconds to get val score of 0.4494:
#                 {'C': 10, 'max_iter': 200, 'penalty': 'l2', 'tol': 1, 'features': 40},
#             Current best combo with val score 0.4632:
#                     {'C': 0.1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 40}
# Trained and Tested combination 967 of 31104, taking 0.01 seconds to get val score of 0.0738:
#                 {'C': 10, 'max_iter': 100, 'penalty': 'l1', 'tol': 1, 'features': 40},
#             Current best combo with val score 0.4632:
#                     {'C': 0.1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 40}
# Trained and Tested combination 968 of 31104, taking 0.02 seconds to get val score of 0.0163:
#                 {'C': 10, 'max_iter': 100, 'penalty': 'l2', 'tol': 0.1, 'features': 40},
#             Current best combo with val score 0.4632:
#                     {'C': 0.1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 40}
# Trained and Tested combination 969 of 31104, taking 0.01 seconds to get val score of 0.4402:
#                 {'C': 10, 'max_iter': 100, 'penalty': 'l2', 'tol': 1, 'features': 39},
#             Current best combo with val score 0.4632:
#                     {'C': 0.1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 40}
# Trained and Tested combination 970 of 31104, taking 0.01 seconds to get val score of 0.4499:
#                 {'C': 10, 'max_iter': 100, 'penalty': 'l2', 'tol': 1, 'features': 41},
#             Current best combo with val score 0.4632:
#                     {'C': 0.1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 40}
# Already Trained and Tested combination (val score of 0.4513):
#             {'C': 1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 41}
#             Current best combo (with val score 0.4632):
#                     {'C': 0.1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 40}
#         Has trained 970 of 31104 combinations so far
# Already Trained and Tested combination (val score of 0.4499):
#             {'C': 10, 'max_iter': 100, 'penalty': 'l2', 'tol': 1, 'features': 41}
#             Current best combo (with val score 0.4632):
#                     {'C': 0.1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 40}
#         Has trained 970 of 31104 combinations so far
# Trained and Tested combination 971 of 31104, taking 0.01 seconds to get val score of 0.0:
#                 {'C': 10, 'max_iter': 50, 'penalty': 'l1', 'tol': 1, 'features': 41},
#             Current best combo with val score 0.4632:
#                     {'C': 0.1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 40}
# Trained and Tested combination 972 of 31104, taking 0.02 seconds to get val score of 0.0163:
#                 {'C': 10, 'max_iter': 50, 'penalty': 'l2', 'tol': 0.1, 'features': 41},
#             Current best combo with val score 0.4632:
#                     {'C': 0.1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 40}
# Already Trained and Tested combination (val score of 0.4494):
#             {'C': 10, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 40}
#             Current best combo (with val score 0.4632):
#                     {'C': 0.1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 40}
#         Has trained 972 of 31104 combinations so far
# Trained and Tested combination 973 of 31104, taking 0.03 seconds to get val score of 0.3398:
#                 {'C': 10, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 42},
#             Current best combo with val score 0.4632:
#                     {'C': 0.1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 40}
# % Combos Checked Thus Far: 973 out of 31104 which is 3.128215%
# FINAL STAGE: Begin final Guidance system
#
#
# Guidance: round FINAL
#
# 	round FINAL iteration:  0
#
# Already Trained and Tested combination (val score of 0.1003):
#             {'C': 0.01, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 40}
#             Current best combo (with val score 0.4632):
#                     {'C': 0.1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 40}
#         Has trained 973 of 31104 combinations so far
# Already Trained and Tested combination (val score of 0.4547):
#             {'C': 1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 40}
#             Current best combo (with val score 0.4632):
#                     {'C': 0.1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 40}
#         Has trained 973 of 31104 combinations so far
# Already Trained and Tested combination (val score of 0.4632):
#             {'C': 0.1, 'max_iter': 100, 'penalty': 'l2', 'tol': 1, 'features': 40}
#             Current best combo (with val score 0.4632):
#                     {'C': 0.1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 40}
#         Has trained 973 of 31104 combinations so far
# Already Trained and Tested combination (val score of 0.0131):
#             {'C': 0.1, 'max_iter': 50, 'penalty': 'l1', 'tol': 1, 'features': 40}
#             Current best combo (with val score 0.4632):
#                     {'C': 0.1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 40}
#         Has trained 973 of 31104 combinations so far
# Already Trained and Tested combination (val score of 0.01):
#             {'C': 0.1, 'max_iter': 50, 'penalty': 'l2', 'tol': 0.1, 'features': 40}
#             Current best combo (with val score 0.4632):
#                     {'C': 0.1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 40}
#         Has trained 973 of 31104 combinations so far
# Already Trained and Tested combination (val score of 0.4566):
#             {'C': 0.1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 39}
#             Current best combo (with val score 0.4632):
#                     {'C': 0.1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 40}
#         Has trained 973 of 31104 combinations so far
# Already Trained and Tested combination (val score of 0.4574):
#             {'C': 0.1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 41}
#             Current best combo (with val score 0.4632):
#                     {'C': 0.1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 40}
#         Has trained 973 of 31104 combinations so far
# 	round FINAL iteration:  1
#
# Trained and Tested combination 974 of 31104, taking 0.02 seconds to get val score of 0.1003:
#                 {'C': 0.01, 'max_iter': 100, 'penalty': 'l2', 'tol': 1, 'features': 40},
#             Current best combo with val score 0.4632:
#                     {'C': 0.1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 40}
# Already Trained and Tested combination (val score of 0.4547):
#             {'C': 1, 'max_iter': 100, 'penalty': 'l2', 'tol': 1, 'features': 40}
#             Current best combo (with val score 0.4632):
#                     {'C': 0.1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 40}
#         Has trained 974 of 31104 combinations so far
# Already Trained and Tested combination (val score of 0.4632):
#             {'C': 0.1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 40}
#             Current best combo (with val score 0.4632):
#                     {'C': 0.1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 40}
#         Has trained 974 of 31104 combinations so far
# Trained and Tested combination 975 of 31104, taking 0.02 seconds to get val score of 0.4632:
#                 {'C': 0.1, 'max_iter': 200, 'penalty': 'l2', 'tol': 1, 'features': 40},
#             Current best combo with val score 0.4632:
#                     {'C': 0.1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 40}
# Trained and Tested combination 976 of 31104, taking 0.01 seconds to get val score of 0.0131:
#                 {'C': 0.1, 'max_iter': 100, 'penalty': 'l1', 'tol': 1, 'features': 40},
#             Current best combo with val score 0.4632:
#                     {'C': 0.1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 40}
# Trained and Tested combination 977 of 31104, taking 0.03 seconds to get val score of 0.01:
#                 {'C': 0.1, 'max_iter': 100, 'penalty': 'l2', 'tol': 0.1, 'features': 40},
#             Current best combo with val score 0.4632:
#                     {'C': 0.1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 40}
# Trained and Tested combination 978 of 31104, taking 0.01 seconds to get val score of 0.4566:
#                 {'C': 0.1, 'max_iter': 100, 'penalty': 'l2', 'tol': 1, 'features': 39},
#             Current best combo with val score 0.4632:
#                     {'C': 0.1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 40}
# Trained and Tested combination 979 of 31104, taking 0.02 seconds to get val score of 0.4574:
#                 {'C': 0.1, 'max_iter': 100, 'penalty': 'l2', 'tol': 1, 'features': 41},
#             Current best combo with val score 0.4632:
#                     {'C': 0.1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 40}
# % Combos Checked Thus Far: 979 out of 31104 which is 3.1475049999999998%
# Max Val Score:
#  0.463242
# Max Val Score Std:
#  0.064829
# Best Combo Train Score:
#  0.887504
# Best Combo Train Score Std:
#  0.002195
# Max Combo Index:
#  (3, 0, 1, 5, 40) out of [6, 6, 2, 6, 72] (note best combo is 0-indexed)
# Max Combo Hyperparamer Combination:
#  {'C': 0.1, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 40}
# Max Combo Features:
#  ('procedure_225469', 'lods_score', 'procedure_224274', 'marital_status_0', 'marital_status_DIVORCED', 'marital_status_MARRIED', 'marital_status_WIDOWED', 'marital_status_SINGLE', 'procedure_223253', 'race_AMERICAN INDIAN/ALASKA NATIVE', 'race_ASIAN', 'race_ASIAN - ASIAN INDIAN', 'race_ASIAN - CHINESE', 'race_ASIAN - KOREAN', 'race_ASIAN - SOUTH EAST ASIAN', 'race_BLACK/AFRICAN', 'race_BLACK/AFRICAN AMERICAN', 'race_BLACK/CAPE VERDEAN', 'race_BLACK/CARIBBEAN ISLAND', 'race_HISPANIC OR LATINO', 'race_HISPANIC/LATINO - CENTRAL AMERICAN', 'race_HISPANIC/LATINO - COLUMBIAN', 'race_HISPANIC/LATINO - CUBAN', 'race_HISPANIC/LATINO - DOMINICAN', 'race_HISPANIC/LATINO - GUATEMALAN', 'race_HISPANIC/LATINO - HONDURAN', 'race_HISPANIC/LATINO - MEXICAN', 'race_HISPANIC/LATINO - PUERTO RICAN', 'race_HISPANIC/LATINO - SALVADORAN', 'race_MULTIPLE RACE/ETHNICITY', 'race_NATIVE HAWAIIAN OR OTHER PACIFIC ISLANDER', 'race_OTHER', 'race_PATIENT DECLINED TO ANSWER', 'race_PORTUGUESE', 'race_SOUTH AMERICAN', 'race_UNABLE TO OBTAIN', 'race_UNKNOWN', 'race_WHITE', 'race_WHITE - BRAZILIAN', 'race_WHITE - EASTERN EUROPEAN', 'race_WHITE - RUSSIAN', 'race_WHITE - OTHER EUROPEAN', 'procedure_227712', 'procedure_224276', 'admission_type_DIRECT OBSERVATION', 'admission_type_ELECTIVE', 'admission_type_EU OBSERVATION', 'admission_type_EW EMER.', 'admission_type_OBSERVATION ADMIT', 'admission_type_SURGICAL SAME DAY ADMISSION', 'admission_type_URGENT', 'admission_type_DIRECT EMER.', 'insurance_Medicare', 'insurance_Other', 'insurance_Medicaid', 'procedure_225792', 'procedure_228130', 'procedure_225817', 'procedure_224267', 'gender_F', 'gender_M', 'ventilation_used', 'hospital_stay_duration', 'oasis_score', 'procedure_228125', 'procedure_226124', 'procedure_225451', 'procedure_224275', 'procedure_229582', 'procedure_225427', 'procedure_229581', 'glucose', 'item_51301', 'spo2', 'procedure_228128', 'procedure_225401', 'procedure_225470', 'icu_stay_duration', 'unique_drugs', 'procedure_227194', 'procedure_224385', 'bun', 'anchor_age', 'heart_rate', 'procedure_225432', 'procedure_229614', 'pt')
# % Combos Checked: 979 out of 31104 which is 3.1475049999999998%
