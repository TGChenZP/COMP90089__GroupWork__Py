# %% [markdown]
# # Tuning Script

# %%
# Parameters subject to change in every script - involved in naming

MODEL = 'logrc'
PREPROCESSING = 'smote_normalise'
TUNER = 'yangzhoub'
OPTIMISED_METRIC = 'f1'

# %% [markdown]
# ---

# %%
# detect whether this is a google environment

COLAB_ENVIRONMENT = False

try:
    from google.colab import drive
    drive.mount('/content/drive')
    COLAB_ENVIRONMENT = True
except:
    pass
# Out:
# Mounted at /content/drive

# %%
import sys
import os
import pickle

if COLAB_ENVIRONMENT:
    home_directory = './drive/MyDrive/LAB/COMP90089__GroupWork__Py/' # my home directory is stored in ./LAB of google drive
    if MODEL == 'ebr':
        # !pip install interpret==0.5.0
    elif MODEL == 'cbr':
        # !pip install catboost
    elif MODEL in ['tf', 'mlp']:
        # !pip install PyTorch2Sklearn
    # !pip install JXAutoML
else:
    home_directory = '../../'

from JXAutoML.YangZhouB_10CV import YangZhouB_10CV as Tuner

import pandas as pd
# Out:
# Collecting JXAutoML
#   Downloading JXAutoML-0.4.4-py3-none-any.whl.metadata (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.2/67.2 kB 1.6 MB/s eta 0:00:00
# Downloading JXAutoML-0.4.4-py3-none-any.whl (52 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.1/52.1 kB 2.3 MB/s eta 0:00:00
# Installing collected packages: JXAutoML
# Successfully installed JXAutoML-0.4.4

# %%
# Parameters that are same for every script

FOLDS = 10  # we have decided to do 10 fold validation

SEED = 42

TASK_TYPE = 'Classification'  # this task is a classification task

# we have decided to tune features as hp
TUNE_FEATURES_AS_HYPERPARAMETERS = True

# %% [markdown]
# ---

# %%
# model to use to tune
from sklearn.linear_model import LogisticRegression as clf

# what values to try for each hyperparameter
parameter_choices = {
    'C': (0.0001, 0.001, 0.01, 0.1, 1, 10),
    'max_iter': (50, 100, 200, 400, 800, 1600),
    'penalty': ('l1', 'l2'),
    'tol': (0.00001, 0.0001, 0.001, 0.01, 0.1, 1)
}

# what values to set non-tuneable parameters/hyperparameters
non_tunable_hyperparameters_dict = {
                                    'random_state': 42,
                                    'n_jobs': -1,
                                    'verbose': 0,
                                    'multi_class': 'ovr',
                                    'solver': 'liblinear'
                                    }

# %% [markdown]
# ---

# %% [markdown]
# Read in and Prepare Data

# %%
# Import data and store as lists

train_x_list = []
train_y_list = []
val_x_list = []
val_y_list = []

for i in range(FOLDS):
    train_data = pd.read_csv(
        f'{home_directory}data/curated/modelling/{PREPROCESSING}/train_{i}.csv')
    val_data = pd.read_csv(
        f'{home_directory}data/curated/modelling/{PREPROCESSING}/val_{i}.csv')

    # get the correct rows for X and y
    train_x = train_data.drop(
        ['mortality_status', 'subject_id', 'hadm_id', 'stay_id'], axis=1)
    train_y = train_data['mortality_status']
    val_x = val_data.drop(
        ['mortality_status', 'subject_id', 'hadm_id', 'stay_id'], axis=1)
    val_y = val_data['mortality_status']

    train_x_list.append(train_x)
    train_y_list.append(train_y)
    val_x_list.append(val_x)
    val_y_list.append(val_y)

# %%
# Import feature importance ordering

with open(f'{home_directory}models/xgb_feature_importance_ordering_{PREPROCESSING}.pickle', 'rb') as f:
    feature_importance_ordering = pickle.load(f)

# %% [markdown]
# Set parameters

# %%
# initialisation
tuner = Tuner()

print('---')

# define what model we are tuning
tuner.read_in_model(clf, TASK_TYPE, optimised_metric=OPTIMISED_METRIC)

print('---')

# read in the data for training and validation
tuner.read_in_data(train_x_list, train_y_list, val_x_list, val_y_list)

print('---')

# set what hp values to tune
tuner.set_hyperparameters(parameter_choices)
# WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

# set up hp values that need to be changed from default but NOT to be tuned
tuner.set_non_tuneable_hyperparameters(non_tunable_hyperparameters_dict)

print('---')

# set up feature importance ordering

if TUNE_FEATURES_AS_HYPERPARAMETERS:
    tuner.set_features(feature_importance_ordering)
    # WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

try:  # try to read in previous results to continue tuning ...
    tuner.read_in_tuning_result_df(
        f'{home_directory}models/tuning/{TUNER}_{MODEL}_{PREPROCESSING}.csv')
except:
    print('No previous tuning data read in')

print('---')

# set up where to save the tuning result csv
tuner.set_tuning_result_saving_address(
    f'{home_directory}models/tuning/{TUNER}_{MODEL}_{PREPROCESSING}.csv')

print('---')

# set up where to save the current best model
tuner.set_best_model_saving_address(
    f'{home_directory}models/tmp_models/{TUNER}_{MODEL}_{PREPROCESSING}')
# Out:
# YangZhouB Initialised
# ---
# Successfully read in model <class 'sklearn.linear_model._logistic.LogisticRegression'>, which is a Classification model optimising for f1
# ---
# Read in Train X data list
# Read in Train y data list
# Read in Val X data list
# Read in Val y data list
# ---
# Successfully recorded hyperparameter choices
# ---
# Successfully recorded non_tuneable_hyperparameter choices
# ---
# Successfully recorded tuneable feature combination choices and updated relevant internal structures
# ---
# No previous tuning data read in
# ---
# Successfully set tuning output address
# ---
# Successfully set best model output address

# %%
# ignore warnings

import warnings
warnings.filterwarnings("ignore")

# %%
# begin tuning ... (or continue training)

tuner.tune()
# Out:
# BEGIN TUNING
#
#
# STAGE ZERO: Tune all Cruise combinations
#
#
# Trained and Tested combination 1 of 20736, taking 0.02 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'max_iter': 50, 'penalty': 'l1', 'tol': 1, 'features': 39},
#             Current best combo with val score 0.0:
#                     {'C': 0.0001, 'max_iter': 50, 'penalty': 'l1', 'tol': 1, 'features': 39}
# Trained and Tested combination 2 of 20736, taking 0.03 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1e-05, 'features': 25},
#             Current best combo with val score 0.0:
#                     {'C': 0.0001, 'max_iter': 50, 'penalty': 'l1', 'tol': 1, 'features': 39}
# Trained and Tested combination 3 of 20736, taking 0.92 seconds to get val score of 0.0066:
#                 {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1e-05, 'features': 15},
#             Current best combo with val score 0.0066:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1e-05, 'features': 15}
# Trained and Tested combination 4 of 20736, taking 0.0 seconds to get val score of 0.3108:
#                 {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1, 'features': 0},
#             Current best combo with val score 0.3108:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1, 'features': 0}
# Trained and Tested combination 5 of 20736, taking 0.01 seconds to get val score of 0.0:
#                 {'C': 10, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1, 'features': 10},
#             Current best combo with val score 0.3108:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1, 'features': 0}
# Trained and Tested combination 6 of 20736, taking 0.01 seconds to get val score of 0.3108:
#                 {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1e-05, 'features': 0},
#             Current best combo with val score 0.3108:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1, 'features': 0}
# Trained and Tested combination 7 of 20736, taking 0.01 seconds to get val score of 0.0:
#                 {'C': 10, 'max_iter': 50, 'penalty': 'l1', 'tol': 1, 'features': 25},
#             Current best combo with val score 0.3108:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1, 'features': 0}
# Trained and Tested combination 8 of 20736, taking 0.01 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1e-05, 'features': 10},
#             Current best combo with val score 0.3108:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1, 'features': 0}
# Trained and Tested combination 9 of 20736, taking 0.02 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'max_iter': 50, 'penalty': 'l1', 'tol': 1e-05, 'features': 39},
#             Current best combo with val score 0.3108:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1, 'features': 0}
# Trained and Tested combination 10 of 20736, taking 0.03 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'max_iter': 50, 'penalty': 'l1', 'tol': 1e-05, 'features': 10},
#             Current best combo with val score 0.3108:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1, 'features': 0}
# Trained and Tested combination 11 of 20736, taking 0.01 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1, 'features': 10},
#             Current best combo with val score 0.3108:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1, 'features': 0}
# Trained and Tested combination 12 of 20736, taking 0.0 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 0},
#             Current best combo with val score 0.3108:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1, 'features': 0}
# Trained and Tested combination 13 of 20736, taking 0.18 seconds to get val score of 0.0:
#                 {'C': 10, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1e-05, 'features': 43},
#             Current best combo with val score 0.3108:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1, 'features': 0}
# Trained and Tested combination 14 of 20736, taking 0.02 seconds to get val score of 0.0:
#                 {'C': 10, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 43},
#             Current best combo with val score 0.3108:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1, 'features': 0}
# Trained and Tested combination 15 of 20736, taking 0.02 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1e-05, 'features': 43},
#             Current best combo with val score 0.3108:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1, 'features': 0}
# Trained and Tested combination 16 of 20736, taking 0.02 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1e-05, 'features': 35},
#             Current best combo with val score 0.3108:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1, 'features': 0}
# Trained and Tested combination 17 of 20736, taking 0.03 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1, 'features': 35},
#             Current best combo with val score 0.3108:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1, 'features': 0}
# Trained and Tested combination 18 of 20736, taking 0.01 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'max_iter': 50, 'penalty': 'l1', 'tol': 1, 'features': 10},
#             Current best combo with val score 0.3108:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1, 'features': 0}
# Trained and Tested combination 19 of 20736, taking 1.44 seconds to get val score of 0.0:
#                 {'C': 10, 'max_iter': 50, 'penalty': 'l1', 'tol': 1e-05, 'features': 25},
#             Current best combo with val score 0.3108:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1, 'features': 0}
# Trained and Tested combination 20 of 20736, taking 0.02 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'max_iter': 50, 'penalty': 'l1', 'tol': 1, 'features': 30},
#             Current best combo with val score 0.3108:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1, 'features': 0}
# Trained and Tested combination 21 of 20736, taking 0.02 seconds to get val score of 0.0:
#                 {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1, 'features': 43},
#             Current best combo with val score 0.3108:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1, 'features': 0}
# Trained and Tested combination 22 of 20736, taking 0.01 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1, 'features': 0},
#             Current best combo with val score 0.3108:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1, 'features': 0}
# Trained and Tested combination 23 of 20736, taking 0.01 seconds to get val score of 0.3108:
#                 {'C': 10, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1e-05, 'features': 0},
#             Current best combo with val score 0.3108:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1, 'features': 0}
# Trained and Tested combination 24 of 20736, taking 0.0 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'max_iter': 50, 'penalty': 'l1', 'tol': 1, 'features': 0},
#             Current best combo with val score 0.3108:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1, 'features': 0}
# Trained and Tested combination 25 of 20736, taking 0.03 seconds to get val score of 0.0:
#                 {'C': 10, 'max_iter': 50, 'penalty': 'l1', 'tol': 1, 'features': 47},
#             Current best combo with val score 0.3108:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1, 'features': 0}
# Trained and Tested combination 26 of 20736, taking 0.0 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1e-05, 'features': 0},
#             Current best combo with val score 0.3108:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1, 'features': 0}
# Trained and Tested combination 27 of 20736, taking 0.51 seconds to get val score of 0.0066:
#                 {'C': 10, 'max_iter': 50, 'penalty': 'l1', 'tol': 1e-05, 'features': 15},
#             Current best combo with val score 0.3108:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1, 'features': 0}
# Trained and Tested combination 28 of 20736, taking 0.01 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1e-05, 'features': 30},
#             Current best combo with val score 0.3108:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1, 'features': 0}
# Trained and Tested combination 29 of 20736, taking 0.02 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1, 'features': 25},
#             Current best combo with val score 0.3108:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1, 'features': 0}
# Trained and Tested combination 30 of 20736, taking 0.01 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1, 'features': 25},
#             Current best combo with val score 0.3108:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1, 'features': 0}
# Trained and Tested combination 31 of 20736, taking 0.02 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1, 'features': 43},
#             Current best combo with val score 0.3108:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1, 'features': 0}
# Trained and Tested combination 32 of 20736, taking 0.01 seconds to get val score of 0.0:
#                 {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1, 'features': 25},
#             Current best combo with val score 0.3108:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1, 'features': 0}
# Trained and Tested combination 33 of 20736, taking 0.0 seconds to get val score of 0.3108:
#                 {'C': 0.0001, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1e-05, 'features': 0},
#             Current best combo with val score 0.3108:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1, 'features': 0}
# Trained and Tested combination 34 of 20736, taking 0.06 seconds to get val score of 0.0297:
#                 {'C': 10, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1e-05, 'features': 20},
#             Current best combo with val score 0.3108:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1, 'features': 0}
# Trained and Tested combination 35 of 20736, taking 0.1 seconds to get val score of 0.0:
#                 {'C': 10, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1e-05, 'features': 30},
#             Current best combo with val score 0.3108:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1, 'features': 0}
# Trained and Tested combination 36 of 20736, taking 0.02 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1e-05, 'features': 10},
#             Current best combo with val score 0.3108:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1, 'features': 0}
# Trained and Tested combination 37 of 20736, taking 1.21 seconds to get val score of 0.0362:
#                 {'C': 10, 'max_iter': 50, 'penalty': 'l1', 'tol': 1e-05, 'features': 20},
#             Current best combo with val score 0.3108:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1, 'features': 0}
# Trained and Tested combination 38 of 20736, taking 0.02 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1e-05, 'features': 15},
#             Current best combo with val score 0.3108:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1, 'features': 0}
# Trained and Tested combination 39 of 20736, taking 0.07 seconds to get val score of 0.0297:
#                 {'C': 10, 'max_iter': 50, 'penalty': 'l2', 'tol': 1e-05, 'features': 20},
#             Current best combo with val score 0.3108:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1, 'features': 0}
# Trained and Tested combination 40 of 20736, taking 0.02 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1e-05, 'features': 35},
#             Current best combo with val score 0.3108:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1, 'features': 0}
# Trained and Tested combination 41 of 20736, taking 0.01 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1, 'features': 20},
#             Current best combo with val score 0.3108:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1, 'features': 0}
# Trained and Tested combination 42 of 20736, taking 1.34 seconds to get val score of 0.0:
#                 {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1e-05, 'features': 25},
#             Current best combo with val score 0.3108:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1, 'features': 0}
# Trained and Tested combination 43 of 20736, taking 0.12 seconds to get val score of 0.0:
#                 {'C': 10, 'max_iter': 50, 'penalty': 'l2', 'tol': 1e-05, 'features': 39},
#             Current best combo with val score 0.3108:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1, 'features': 0}
# Trained and Tested combination 44 of 20736, taking 0.01 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'max_iter': 50, 'penalty': 'l1', 'tol': 1e-05, 'features': 15},
#             Current best combo with val score 0.3108:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1, 'features': 0}
# Trained and Tested combination 45 of 20736, taking 0.03 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'max_iter': 50, 'penalty': 'l2', 'tol': 1e-05, 'features': 47},
#             Current best combo with val score 0.3108:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1, 'features': 0}
# Trained and Tested combination 46 of 20736, taking 0.02 seconds to get val score of 0.0:
#                 {'C': 10, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1, 'features': 35},
#             Current best combo with val score 0.3108:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1, 'features': 0}
# Trained and Tested combination 47 of 20736, taking 0.01 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1, 'features': 10},
#             Current best combo with val score 0.3108:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1, 'features': 0}
# Trained and Tested combination 48 of 20736, taking 0.02 seconds to get val score of 0.0033:
#                 {'C': 10, 'max_iter': 50, 'penalty': 'l1', 'tol': 1, 'features': 20},
#             Current best combo with val score 0.3108:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1, 'features': 0}
# Trained and Tested combination 49 of 20736, taking 0.05 seconds to get val score of 0.0033:
#                 {'C': 10, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1e-05, 'features': 15},
#             Current best combo with val score 0.3108:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1, 'features': 0}
# Trained and Tested combination 50 of 20736, taking 0.14 seconds to get val score of 0.0:
#                 {'C': 10, 'max_iter': 50, 'penalty': 'l2', 'tol': 1e-05, 'features': 43},
#             Current best combo with val score 0.3108:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1, 'features': 0}
# Trained and Tested combination 51 of 20736, taking 0.02 seconds to get val score of 0.0:
#                 {'C': 10, 'max_iter': 50, 'penalty': 'l1', 'tol': 1, 'features': 35},
#             Current best combo with val score 0.3108:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1, 'features': 0}
# Trained and Tested combination 52 of 20736, taking 0.02 seconds to get val score of 0.0:
#                 {'C': 10, 'max_iter': 50, 'penalty': 'l1', 'tol': 1, 'features': 30},
#             Current best combo with val score 0.3108:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1, 'features': 0}
# Trained and Tested combination 53 of 20736, taking 0.01 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1, 'features': 20},
#             Current best combo with val score 0.3108:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1, 'features': 0}
# Trained and Tested combination 54 of 20736, taking 0.0 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1, 'features': 0},
#             Current best combo with val score 0.3108:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1, 'features': 0}
# Trained and Tested combination 55 of 20736, taking 0.02 seconds to get val score of 0.0:
#                 {'C': 10, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1, 'features': 39},
#             Current best combo with val score 0.3108:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1, 'features': 0}
# Trained and Tested combination 56 of 20736, taking 0.01 seconds to get val score of 0.0:
#                 {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1, 'features': 15},
#             Current best combo with val score 0.3108:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1, 'features': 0}
# Trained and Tested combination 57 of 20736, taking 0.01 seconds to get val score of 0.0:
#                 {'C': 10, 'max_iter': 50, 'penalty': 'l1', 'tol': 1, 'features': 10},
#             Current best combo with val score 0.3108:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1, 'features': 0}
# Trained and Tested combination 58 of 20736, taking 0.01 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1e-05, 'features': 20},
#             Current best combo with val score 0.3108:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1, 'features': 0}
# Trained and Tested combination 59 of 20736, taking 0.01 seconds to get val score of 0.0067:
#                 {'C': 10, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 15},
#             Current best combo with val score 0.3108:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1, 'features': 0}
# Trained and Tested combination 60 of 20736, taking 0.12 seconds to get val score of 0.0:
#                 {'C': 10, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1e-05, 'features': 39},
#             Current best combo with val score 0.3108:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1, 'features': 0}
# Trained and Tested combination 61 of 20736, taking 0.01 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'max_iter': 50, 'penalty': 'l1', 'tol': 1, 'features': 25},
#             Current best combo with val score 0.3108:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1, 'features': 0}
# Trained and Tested combination 62 of 20736, taking 0.03 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 47},
#             Current best combo with val score 0.3108:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1, 'features': 0}
# Trained and Tested combination 63 of 20736, taking 0.04 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'max_iter': 50, 'penalty': 'l1', 'tol': 1, 'features': 43},
#             Current best combo with val score 0.3108:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1, 'features': 0}
# Trained and Tested combination 64 of 20736, taking 0.03 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'max_iter': 50, 'penalty': 'l1', 'tol': 1e-05, 'features': 43},
#             Current best combo with val score 0.3108:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1, 'features': 0}
# Trained and Tested combination 65 of 20736, taking 0.01 seconds to get val score of 0.3108:
#                 {'C': 10, 'max_iter': 50, 'penalty': 'l1', 'tol': 1, 'features': 0},
#             Current best combo with val score 0.3108:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1, 'features': 0}
# Trained and Tested combination 66 of 20736, taking 3.17 seconds to get val score of 0.0:
#                 {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1e-05, 'features': 39},
#             Current best combo with val score 0.3108:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1, 'features': 0}
# Trained and Tested combination 67 of 20736, taking 0.02 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1e-05, 'features': 15},
#             Current best combo with val score 0.3108:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1, 'features': 0}
# Trained and Tested combination 68 of 20736, taking 0.01 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1e-05, 'features': 25},
#             Current best combo with val score 0.3108:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1, 'features': 0}
# Trained and Tested combination 69 of 20736, taking 0.13 seconds to get val score of 0.0197:
#                 {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1e-05, 'features': 5},
#             Current best combo with val score 0.3108:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1, 'features': 0}
# Trained and Tested combination 70 of 20736, taking 0.01 seconds to get val score of 0.1566:
#                 {'C': 10, 'max_iter': 50, 'penalty': 'l1', 'tol': 1, 'features': 5},
#             Current best combo with val score 0.3108:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1, 'features': 0}
# Trained and Tested combination 71 of 20736, taking 0.02 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'max_iter': 50, 'penalty': 'l2', 'tol': 1, 'features': 35},
#             Current best combo with val score 0.3108:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1, 'features': 0}
# Trained and Tested combination 72 of 20736, taking 0.11 seconds to get val score of 0.0:
#                 {'C': 10, 'max_iter': 50, 'penalty': 'l2', 'tol': 1e-05, 'features': 30},
#             Current best combo with val score 0.3108:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1, 'features': 0}
# Trained and Tested combination 73 of 20736, taking 2.44 seconds to get val score of 0.0:
#                 {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1e-05, 'features': 47},
#             Current best combo with val score 0.3108:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1, 'features': 0}
# Trained and Tested combination 74 of 20736, taking 0.01 seconds to get val score of 0.0033:
#                 {'C': 10, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1, 'features': 20},
#             Current best combo with val score 0.3108:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1, 'features': 0}
# Trained and Tested combination 75 of 20736, taking 0.02 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'max_iter': 50, 'penalty': 'l2', 'tol': 1e-05, 'features': 20},
#             Current best combo with val score 0.3108:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1, 'features': 0}
# Trained and Tested combination 76 of 20736, taking 2.63 seconds to get val score of 0.0:
#                 {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1e-05, 'features': 43},
#             Current best combo with val score 0.3108:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1, 'features': 0}
# Trained and Tested combination 77 of 20736, taking 0.02 seconds to get val score of 0.0167:
#                 {'C': 0.0001, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1e-05, 'features': 5},
#             Current best combo with val score 0.3108:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1, 'features': 0}
# Trained and Tested combination 78 of 20736, taking 2.0 seconds to get val score of 0.0:
#                 {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1e-05, 'features': 35},
#             Current best combo with val score 0.3108:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1, 'features': 0}
# Trained and Tested combination 79 of 20736, taking 0.03 seconds to get val score of 0.0197:
#                 {'C': 10, 'max_iter': 50, 'penalty': 'l2', 'tol': 1e-05, 'features': 5},
#             Current best combo with val score 0.3108:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1, 'features': 0}
# Trained and Tested combination 80 of 20736, taking 0.02 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'max_iter': 50, 'penalty': 'l1', 'tol': 1, 'features': 35},
#             Current best combo with val score 0.3108:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1, 'features': 0}
# Trained and Tested combination 81 of 20736, taking 0.22 seconds to get val score of 0.0:
#                 {'C': 10, 'max_iter': 50, 'penalty': 'l1', 'tol': 1e-05, 'features': 10},
#             Current best combo with val score 0.3108:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1, 'features': 0}
# Trained and Tested combination

#             Current best combo with val score 0.3108:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1, 'features': 0}
# Already Trained and Tested combination (val score of 0.3108):
#             {'C': 1, 'max_iter': 1600, 'penalty': 'l2', 'tol': 0.0001, 'features': 0}
#             Current best combo (with val score 0.3108):
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1, 'features': 0}
#         Has trained 311 of 20736 combinations so far
# Already Trained and Tested combination (val score of 0.3108):
#             {'C': 10, 'max_iter': 800, 'penalty': 'l2', 'tol': 0.0001, 'features': 0}
#             Current best combo (with val score 0.3108):
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1, 'features': 0}
#         Has trained 311 of 20736 combinations so far
# Already Trained and Tested combination (val score of 0.3108):
#             {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 0.0001, 'features': 0}
#             Current best combo (with val score 0.3108):
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1, 'features': 0}
#         Has trained 311 of 20736 combinations so far
# Already Trained and Tested combination (val score of 0.3108):
#             {'C': 10, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1e-05, 'features': 0}
#             Current best combo (with val score 0.3108):
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1, 'features': 0}
#         Has trained 311 of 20736 combinations so far
# Trained and Tested combination 312 of 20736, taking 0.01 seconds to get val score of 0.3108:
#                 {'C': 10, 'max_iter': 1600, 'penalty': 'l2', 'tol': 0.001, 'features': 0},
#             Current best combo with val score 0.3108:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1, 'features': 0}
# Trained and Tested combination 313 of 20736, taking 0.01 seconds to get val score of 0.0411:
#                 {'C': 10, 'max_iter': 1600, 'penalty': 'l2', 'tol': 0.0001, 'features': 1},
#             Current best combo with val score 0.3108:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1, 'features': 0}
# % Combos Checked Thus Far: 313 out of 20736 which is 1.509452%
# Cruising Coordrdinate 170 of 176
#
# Cruising Coordrdinate 171 of 176
#
# Cruising Coordrdinate 172 of 176
#
# Cruise suspended due to suspicious case
# Guidance: round 7
#
# 	round 7 iteration:  0
#
# % Combos Checked Thus Far: 313 out of 20736 which is 1.509452%
# Cruising Coordrdinate 173 of 176
#
# Cruise suspended due to suspicious case
# Guidance: round 8
#
# 	round 8 iteration:  0
#
# % Combos Checked Thus Far: 313 out of 20736 which is 1.509452%
# Cruising Coordrdinate 174 of 176
#
# Cruising Coordrdinate 175 of 176
#
# Cruise suspended due to suspicious case
# Guidance: round 9
#
# 	round 9 iteration:  0
#
# Trained and Tested combination 314 of 20736, taking 0.0 seconds to get val score of 0.3108:
#                 {'C': 1, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1, 'features': 0},
#             Current best combo with val score 0.3108:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1, 'features': 0}
# Trained and Tested combination 315 of 20736, taking 0.0 seconds to get val score of 0.3108:
#                 {'C': 10, 'max_iter': 800, 'penalty': 'l2', 'tol': 1, 'features': 0},
#             Current best combo with val score 0.3108:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1, 'features': 0}
# Already Trained and Tested combination (val score of 0.3108):
#             {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1, 'features': 0}
#             Current best combo (with val score 0.3108):
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1, 'features': 0}
#         Has trained 315 of 20736 combinations so far
# Trained and Tested combination 316 of 20736, taking 0.0 seconds to get val score of 0.3108:
#                 {'C': 10, 'max_iter': 1600, 'penalty': 'l2', 'tol': 0.1, 'features': 0},
#             Current best combo with val score 0.3108:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1, 'features': 0}
# Trained and Tested combination 317 of 20736, taking 0.01 seconds to get val score of 0.0538:
#                 {'C': 10, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1, 'features': 1},
#             Current best combo with val score 0.3108:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1, 'features': 0}
# 	round 9 iteration:  1
#
# Trained and Tested combination 318 of 20736, taking 0.0 seconds to get val score of 0.3108:
#                 {'C': 0.1, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1, 'features': 0},
#             Current best combo with val score 0.3108:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1, 'features': 0}
# Already Trained and Tested combination (val score of 0.3108):
#             {'C': 10, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1, 'features': 0}
#             Current best combo (with val score 0.3108):
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1, 'features': 0}
#         Has trained 318 of 20736 combinations so far
# Trained and Tested combination 319 of 20736, taking 0.0 seconds to get val score of 0.3108:
#                 {'C': 1, 'max_iter': 800, 'penalty': 'l2', 'tol': 1, 'features': 0},
#             Current best combo with val score 0.3108:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1, 'features': 0}
# Already Trained and Tested combination (val score of 0.3108):
#             {'C': 1, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1, 'features': 0}
#             Current best combo (with val score 0.3108):
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1, 'features': 0}
#         Has trained 319 of 20736 combinations so far
# Trained and Tested combination 320 of 20736, taking 0.0 seconds to get val score of 0.3108:
#                 {'C': 1, 'max_iter': 1600, 'penalty': 'l2', 'tol': 0.1, 'features': 0},
#             Current best combo with val score 0.3108:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1, 'features': 0}
# Trained and Tested combination 321 of 20736, taking 0.01 seconds to get val score of 0.0538:
#                 {'C': 1, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1, 'features': 1},
#             Current best combo with val score 0.3108:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1, 'features': 0}
# Already Trained and Tested combination (val score of 0.3108):
#             {'C': 1, 'max_iter': 800, 'penalty': 'l2', 'tol': 1, 'features': 0}
#             Current best combo (with val score 0.3108):
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1, 'features': 0}
#         Has trained 321 of 20736 combinations so far
# Trained and Tested combination 322 of 20736, taking 0.0 seconds to get val score of 0.3108:
#                 {'C': 10, 'max_iter': 400, 'penalty': 'l2', 'tol': 1, 'features': 0},
#             Current best combo with val score 0.3108:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1, 'features': 0}
# Already Trained and Tested combination (val score of 0.3108):
#             {'C': 10, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1, 'features': 0}
#             Current best combo (with val score 0.3108):
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1, 'features': 0}
#         Has trained 322 of 20736 combinations so far
# Already Trained and Tested combination (val score of 0.3108):
#             {'C': 10, 'max_iter': 800, 'penalty': 'l1', 'tol': 1, 'features': 0}
#             Current best combo (with val score 0.3108):
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1, 'features': 0}
#         Has trained 322 of 20736 combinations so far
# Trained and Tested combination 323 of 20736, taking 0.0 seconds to get val score of 0.3108:
#                 {'C': 10, 'max_iter': 800, 'penalty': 'l2', 'tol': 0.1, 'features': 0},
#             Current best combo with val score 0.3108:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1, 'features': 0}
# Trained and Tested combination 324 of 20736, taking 0.01 seconds to get val score of 0.0538:
#                 {'C': 10, 'max_iter': 800, 'penalty': 'l2', 'tol': 1, 'features': 1},
#             Current best combo with val score 0.3108:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1, 'features': 0}
# Already Trained and Tested combination (val score of 0.3108):
#             {'C': 1, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1, 'features': 0}
#             Current best combo (with val score 0.3108):
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1, 'features': 0}
#         Has trained 324 of 20736 combinations so far
# Already Trained and Tested combination (val score of 0.3108):
#             {'C': 10, 'max_iter': 800, 'penalty': 'l1', 'tol': 1, 'features': 0}
#             Current best combo (with val score 0.3108):
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1, 'features': 0}
#         Has trained 324 of 20736 combinations so far
# Already Trained and Tested combination (val score of 0.3108):
#             {'C': 10, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1, 'features': 0}
#             Current best combo (with val score 0.3108):
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1, 'features': 0}
#         Has trained 324 of 20736 combinations so far
# Already Trained and Tested combination (val score of 0.3108):
#             {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 0.1, 'features': 0}
#             Current best combo (with val score 0.3108):
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1, 'features': 0}
#         Has trained 324 of 20736 combinations so far
# Already Trained and Tested combination (val score of 0.0291):
#             {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1, 'features': 1}
#             Current best combo (with val score 0.3108):
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1, 'features': 0}
#         Has trained 324 of 20736 combinations so far
# Already Trained and Tested combination (val score of 0.3108):
#             {'C': 1, 'max_iter': 1600, 'penalty': 'l2', 'tol': 0.1, 'features': 0}
#             Current best combo (with val score 0.3108):
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1, 'features': 0}
#         Has trained 324 of 20736 combinations so far
# Already Trained and Tested combination (val score of 0.3108):
#             {'C': 10, 'max_iter': 800, 'penalty': 'l2', 'tol': 0.1, 'features': 0}
#             Current best combo (with val score 0.3108):
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1, 'features': 0}
#         Has trained 324 of 20736 combinations so far
# Already Trained and Tested combination (val score of 0.3108):
#             {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 0.1, 'features': 0}
#             Current best combo (with val score 0.3108):
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1, 'features': 0}
#         Has trained 324 of 20736 combinations so far
# Trained and Tested combination 325 of 20736, taking 0.01 seconds to get val score of 0.3108:
#                 {'C': 10, 'max_iter': 1600, 'penalty': 'l2', 'tol': 0.01, 'features': 0},
#             Current best combo with val score 0.3108:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1, 'features': 0}
# Already Trained and Tested combination (val score of 0.3108):
#             {'C': 10, 'max_iter': 1600, 'penalty': 'l2', 'tol': 1, 'features': 0}
#             Current best combo (with val score 0.3108):
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1, 'features': 0}
#         Has trained 325 of 20736 combinations so far
# Trained and Tested combination 326 of 20736, taking 0.01 seconds to get val score of 0.0354:
#                 {'C': 10, 'max_iter': 1600, 'penalty': 'l2', 'tol': 0.1, 'features': 1},
#             Current best combo with val score 0.3108:
#                     {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1, 'features': 0}
# % Combos Checked Thus Far: 326 out of 20736 which is 1.5721450000000001%
# Cruising Coordrdinate 176 of 176
#
# Cruise suspended due to suspicious case
# Guidance: round 10
#
# 	round 10 iteration:  0
#
# % Combos Checked Thus Far: 326 out of 20736 which is 1.5721450000000001%
# FINAL STAGE: Begin final Guidance system
#
#
# Guidance: round FINAL
#
# 	round FINAL iteration:  0
#
# % Combos Checked Thus Far: 326 out of 20736 which is 1.5721450000000001%
# Max Val Score:
#  0.310811
# Max Val Score Std:
#  0.016704
# Best Combo Train Score:
#  0.691408
# Best Combo Train Score Std:
#  0.001442
# Max Combo Index:
#  (5, 5, 0, 5, 0) out of [6, 6, 2, 6, 48] (note best combo is 0-indexed)
# Max Combo Hyperparamer Combination:
#  {'C': 10, 'max_iter': 1600, 'penalty': 'l1', 'tol': 1, 'features': 0}
# Max Combo Features:
#  ('procedure_224274',)
# % Combos Checked: 326 out of 20736 which is 1.5721450000000001%
