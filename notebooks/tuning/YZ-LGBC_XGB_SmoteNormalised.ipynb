# %% [markdown]
# # Tuning Script

# %%
# Parameters subject to change in every script - involved in naming

MODEL = 'lgbc'
PREPROCESSING = 'smote_normalise'
TUNER = 'yangzhoub'
OPTIMISED_METRIC = 'f1'

# %% [markdown]
# ---

# %%
# detect whether this is a google environment

COLAB_ENVIRONMENT = False

try:
    from google.colab import drive
    drive.mount('/content/drive')
    COLAB_ENVIRONMENT = True
except:
    pass
# Out:
# Mounted at /content/drive

# %%
import sys
import os
import pickle

if COLAB_ENVIRONMENT:
    home_directory = './drive/MyDrive/LAB/COMP90089__GroupWork__Py/' # my home directory is stored in ./LAB of google drive
    if MODEL == 'ebr':
        # !pip install interpret==0.5.0
    elif MODEL == 'cbr':
        # !pip install catboost
    elif MODEL in ['tf', 'mlp']:
        # !pip install PyTorch2Sklearn
    # !pip install JXAutoML
else:
    home_directory = '../../'

from JXAutoML.YangZhouB_10CV import YangZhouB_10CV as Tuner

import pandas as pd
# Out:
# Collecting JXAutoML
#   Downloading JXAutoML-0.4.4-py3-none-any.whl.metadata (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.2/67.2 kB 5.0 MB/s eta 0:00:00
# Downloading JXAutoML-0.4.4-py3-none-any.whl (52 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.1/52.1 kB 3.9 MB/s eta 0:00:00
# Installing collected packages: JXAutoML
# Successfully installed JXAutoML-0.4.4

# %%
# Parameters that are same for every script

FOLDS = 10  # we have decided to do 10 fold validation

SEED = 42

TASK_TYPE = 'Classification'  # this task is a classification task

# we have decided to tune features as hp
TUNE_FEATURES_AS_HYPERPARAMETERS = True

# %% [markdown]
# ---

# %%
# model to use to tune
from lightgbm import LGBMClassifier as clf

# what values to try for each hyperparameter
parameter_choices = {
    'n_estimators': (25, 50, 100, 200, 400, 800),
    'max_depth': (3, 6, 12, 24, 48, 96, 192),
    'subsample': (0.4, 0.55, 0.7, 0.85, 1),
    'colsample_bytree': (0.4, 0.55, 0.7, 0.85, 1),
    'learning_rate': (0.00000001, 0.000001, 0.0001, 0.01, 0.1),
    'reg_alpha': (0.0001, 0.001, 0.01, 0.1, 1, 10)
}

# what values to set non-tuneable parameters/hyperparameters
non_tunable_hyperparameters_dict = {
                                    'random_state': SEED,
                                    'n_jobs': -1,
                                    'verbose': -1
                                    }
# Out:
# /usr/local/lib/python3.10/dist-packages/dask/dataframe/__init__.py:42: FutureWarning:
# Dask dataframe query planning is disabled because dask-expr is not installed.
#
# You can install it with `pip install dask[dataframe]` or `conda install dask`.
# This will raise in a future version.
#
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ---

# %% [markdown]
# Read in and Prepare Data

# %%
# Import data and store as lists

train_x_list = []
train_y_list = []
val_x_list = []
val_y_list = []

for i in range(FOLDS):
    train_data = pd.read_csv(
        f'{home_directory}data/curated/modelling/{PREPROCESSING}/train_{i}.csv')
    val_data = pd.read_csv(
        f'{home_directory}data/curated/modelling/{PREPROCESSING}/val_{i}.csv')

    # get the correct rows for X and y
    train_x = train_data.drop(
        ['mortality_status', 'subject_id', 'hadm_id', 'stay_id'], axis=1)
    train_y = train_data['mortality_status']
    val_x = val_data.drop(
        ['mortality_status', 'subject_id', 'hadm_id', 'stay_id'], axis=1)
    val_y = val_data['mortality_status']

    train_x_list.append(train_x)
    train_y_list.append(train_y)
    val_x_list.append(val_x)
    val_y_list.append(val_y)

# %%
# Import feature importance ordering

with open(f'{home_directory}models/xgb_feature_importance_ordering_{PREPROCESSING}.pickle', 'rb') as f:
    feature_importance_ordering = pickle.load(f)

# %% [markdown]
# Set parameters

# %%
# initialisation
tuner = Tuner()

print('---')

# define what model we are tuning
tuner.read_in_model(clf, TASK_TYPE, optimised_metric=OPTIMISED_METRIC)

print('---')

# read in the data for training and validation
tuner.read_in_data(train_x_list, train_y_list, val_x_list, val_y_list)

print('---')

# set what hp values to tune
tuner.set_hyperparameters(parameter_choices)
# WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

# set up hp values that need to be changed from default but NOT to be tuned
tuner.set_non_tuneable_hyperparameters(non_tunable_hyperparameters_dict)

print('---')

# set up feature importance ordering

if TUNE_FEATURES_AS_HYPERPARAMETERS:
    tuner.set_features(feature_importance_ordering)
    # WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

try:  # try to read in previous results to continue tuning ...
    tuner.read_in_tuning_result_df(
        f'{home_directory}models/tuning/{TUNER}_{MODEL}_{PREPROCESSING}.csv')
except:
    print('No previous tuning data read in')

print('---')

# set up where to save the tuning result csv
tuner.set_tuning_result_saving_address(
    f'{home_directory}models/tuning/{TUNER}_{MODEL}_{PREPROCESSING}.csv')

print('---')

# set up where to save the current best model
tuner.set_best_model_saving_address(
    f'{home_directory}models/tmp_models/{TUNER}_{MODEL}_{PREPROCESSING}')
# Out:
# YangZhouB Initialised
# ---
# Successfully read in model <class 'lightgbm.sklearn.LGBMClassifier'>, which is a Classification model optimising for f1
# ---
# Read in Train X data list
# Read in Train y data list
# Read in Val X data list
# Read in Val y data list
# ---
# Successfully recorded hyperparameter choices
# ---
# Successfully recorded non_tuneable_hyperparameter choices
# ---
# Successfully recorded tuneable feature combination choices and updated relevant internal structures
# ---
# Successfully read in tuning result of 1354 rows, for 1354.0 combos
# ---
# Successfully set tuning output address
# ---
# Successfully set best model output address

# %%
# ignore warnings

import warnings
warnings.filterwarnings("ignore")

# %%
# begin tuning ... (or continue training)

tuner.tune()
# Out:
# Streaming output truncated to the last 5000 lines.
# Trained and Tested combination 1524 of 2268000, taking 0.09 seconds to get val score of 0.0372:
#                 {'n_estimators': 25, 'max_depth': 24, 'subsample': 1, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 40},
#             Current best combo with val score 0.5491:
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 20}
# Trained and Tested combination 1525 of 2268000, taking 0.38 seconds to get val score of 0.435:
#                 {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 25},
#             Current best combo with val score 0.5491:
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 20}
# Trained and Tested combination 1526 of 2268000, taking 0.58 seconds to get val score of 0.1266:
#                 {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 50},
#             Current best combo with val score 0.5491:
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 20}
# Trained and Tested combination 1527 of 2268000, taking 0.01 seconds to get val score of 0.3244:
#                 {'n_estimators': 25, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 0},
#             Current best combo with val score 0.5491:
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 20}
# Trained and Tested combination 1528 of 2268000, taking 2.52 seconds to get val score of 0.1104:
#                 {'n_estimators': 800, 'max_depth': 192, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 1e-08, 'reg_alpha': 0.0001, 'features': 55},
#             Current best combo with val score 0.5491:
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 20}
# Trained and Tested combination 1529 of 2268000, taking 1.23 seconds to get val score of 0.0638:
#                 {'n_estimators': 800, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 1e-08, 'reg_alpha': 10, 'features': 63},
#             Current best combo with val score 0.5491:
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 20}
# Trained and Tested combination 1530 of 2268000, taking 0.06 seconds to get val score of 0.0849:
#                 {'n_estimators': 25, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 50},
#             Current best combo with val score 0.5491:
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 20}
# Trained and Tested combination 1531 of 2268000, taking 0.07 seconds to get val score of 0.042:
#                 {'n_estimators': 25, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 55},
#             Current best combo with val score 0.5491:
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 20}
# Trained and Tested combination 1532 of 2268000, taking 0.98 seconds to get val score of 0.5402:
#                 {'n_estimators': 800, 'max_depth': 192, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 25},
#             Current best combo with val score 0.5491:
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 20}
# Trained and Tested combination 1533 of 2268000, taking 1.09 seconds to get val score of 0.3443:
#                 {'n_estimators': 800, 'max_depth': 24, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 1e-08, 'reg_alpha': 0.0001, 'features': 25},
#             Current best combo with val score 0.5491:
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 20}
# Trained and Tested combination 1534 of 2268000, taking 0.96 seconds to get val score of 0.3426:
#                 {'n_estimators': 25, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 30},
#             Current best combo with val score 0.5491:
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 20}
# Trained and Tested combination 1535 of 2268000, taking 0.99 seconds to get val score of 0.4135:
#                 {'n_estimators': 800, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 1e-08, 'reg_alpha': 0.0001, 'features': 20},
#             Current best combo with val score 0.5491:
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 20}
# Trained and Tested combination 1536 of 2268000, taking 0.01 seconds to get val score of 0.3244:
#                 {'n_estimators': 25, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 0},
#             Current best combo with val score 0.5491:
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 20}
# Trained and Tested combination 1537 of 2268000, taking 0.78 seconds to get val score of 0.5007:
#                 {'n_estimators': 800, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 1e-08, 'reg_alpha': 0.0001, 'features': 15},
#             Current best combo with val score 0.5491:
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 20}
#
#
# STAGE ONE: Begin initial Guidance system
#
#
# Guidance: initial round
#
# 	round 0 iteration:  0
#
# Trained and Tested combination 1538 of 2268000, taking 0.23 seconds to get val score of 0.1196:
#                 {'n_estimators': 100, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.7, 'learning_rate': 0.0001, 'reg_alpha': 0.1, 'features': 36},
#             Current best combo with val score 0.5491:
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 20}
# Trained and Tested combination 1539 of 2268000, taking 0.92 seconds to get val score of 0.1408:
#                 {'n_estimators': 400, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.7, 'learning_rate': 0.0001, 'reg_alpha': 0.1, 'features': 36},
#             Current best combo with val score 0.5491:
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 20}
# Trained and Tested combination 1540 of 2268000, taking 0.46 seconds to get val score of 0.1281:
#                 {'n_estimators': 200, 'max_depth': 12, 'subsample': 0.7, 'colsample_bytree': 0.7, 'learning_rate': 0.0001, 'reg_alpha': 0.1, 'features': 36},
#             Current best combo with val score 0.5491:
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 20}
# Trained and Tested combination 1541 of 2268000, taking 0.58 seconds to get val score of 0.1281:
#                 {'n_estimators': 200, 'max_depth': 48, 'subsample': 0.7, 'colsample_bytree': 0.7, 'learning_rate': 0.0001, 'reg_alpha': 0.1, 'features': 36},
#             Current best combo with val score 0.5491:
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 20}
# Trained and Tested combination 1542 of 2268000, taking 0.44 seconds to get val score of 0.1281:
#                 {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.55, 'colsample_bytree': 0.7, 'learning_rate': 0.0001, 'reg_alpha': 0.1, 'features': 36},
#             Current best combo with val score 0.5491:
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 20}
# Trained and Tested combination 1543 of 2268000, taking 0.47 seconds to get val score of 0.1281:
#                 {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.85, 'colsample_bytree': 0.7, 'learning_rate': 0.0001, 'reg_alpha': 0.1, 'features': 36},
#             Current best combo with val score 0.5491:
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 20}
# Trained and Tested combination 1544 of 2268000, taking 0.43 seconds to get val score of 0.1187:
#                 {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.55, 'learning_rate': 0.0001, 'reg_alpha': 0.1, 'features': 36},
#             Current best combo with val score 0.5491:
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 20}
# Trained and Tested combination 1545 of 2268000, taking 0.48 seconds to get val score of 0.1569:
#                 {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.85, 'learning_rate': 0.0001, 'reg_alpha': 0.1, 'features': 36},
#             Current best combo with val score 0.5491:
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 20}
# Trained and Tested combination 1546 of 2268000, taking 0.46 seconds to get val score of 0.1323:
#                 {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.7, 'learning_rate': 1e-06, 'reg_alpha': 0.1, 'features': 36},
#             Current best combo with val score 0.5491:
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 20}
# Trained and Tested combination 1547 of 2268000, taking 0.44 seconds to get val score of 0.1405:
#                 {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.7, 'learning_rate': 0.01, 'reg_alpha': 0.1, 'features': 36},
#             Current best combo with val score 0.5491:
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 20}
# Trained and Tested combination 1548 of 2268000, taking 0.45 seconds to get val score of 0.1279:
#                 {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.7, 'learning_rate': 0.0001, 'reg_alpha': 0.01, 'features': 36},
#             Current best combo with val score 0.5491:
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 20}
# Trained and Tested combination 1549 of 2268000, taking 0.44 seconds to get val score of 0.1253:
#                 {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.7, 'learning_rate': 0.0001, 'reg_alpha': 1, 'features': 36},
#             Current best combo with val score 0.5491:
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 20}
# Trained and Tested combination 1550 of 2268000, taking 2.7 seconds to get val score of 0.1604:
#                 {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.7, 'learning_rate': 0.0001, 'reg_alpha': 0.1, 'features': 35},
#             Current best combo with val score 0.5491:
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 20}
# Trained and Tested combination 1551 of 2268000, taking 0.49 seconds to get val score of 0.155:
#                 {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.7, 'learning_rate': 0.0001, 'reg_alpha': 0.1, 'features': 37},
#             Current best combo with val score 0.5491:
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 20}
# 	round 0 iteration:  1
#
# Already Trained and Tested combination (val score of 0.1281):
#             {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.7, 'learning_rate': 0.0001, 'reg_alpha': 0.1, 'features': 36}
#             Current best combo (with val score 0.5491):
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 20}
#         Has trained 1551 of 2268000 combinations so far
# Trained and Tested combination 1552 of 2268000, taking 1.81 seconds to get val score of 0.1447:
#                 {'n_estimators': 800, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.7, 'learning_rate': 0.0001, 'reg_alpha': 0.1, 'features': 36},
#             Current best combo with val score 0.5491:
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 20}
# Trained and Tested combination 1553 of 2268000, taking 0.9 seconds to get val score of 0.1408:
#                 {'n_estimators': 400, 'max_depth': 12, 'subsample': 0.7, 'colsample_bytree': 0.7, 'learning_rate': 0.0001, 'reg_alpha': 0.1, 'features': 36},
#             Current best combo with val score 0.5491:
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 20}
# Trained and Tested combination 1554 of 2268000, taking 0.87 seconds to get val score of 0.1408:
#                 {'n_estimators': 400, 'max_depth': 48, 'subsample': 0.7, 'colsample_bytree': 0.7, 'learning_rate': 0.0001, 'reg_alpha': 0.1, 'features': 36},
#             Current best combo with val score 0.5491:
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 20}
# Trained and Tested combination 1555 of 2268000, taking 0.9 seconds to get val score of 0.1408:
#                 {'n_estimators': 400, 'max_depth': 24, 'subsample': 0.55, 'colsample_bytree': 0.7, 'learning_rate': 0.0001, 'reg_alpha': 0.1, 'features': 36},
#             Current best combo with val score 0.5491:
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 20}
# Trained and Tested combination 1556 of 2268000, taking 0.88 seconds to get val score of 0.1408:
#                 {'n_estimators': 400, 'max_depth': 24, 'subsample': 0.85, 'colsample_bytree': 0.7, 'learning_rate': 0.0001, 'reg_alpha': 0.1, 'features': 36},
#             Current best combo with val score 0.5491:
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 20}
# Trained and Tested combination 1557 of 2268000, taking 0.87 seconds to get val score of 0.1252:
#                 {'n_estimators': 400, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.55, 'learning_rate': 0.0001, 'reg_alpha': 0.1, 'features': 36},
#             Current best combo with val score 0.5491:
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 20}
# Trained and Tested combination 1558 of 2268000, taking 0.99 seconds to get val score of 0.1553:
#                 {'n_estimators': 400, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.85, 'learning_rate': 0.0001, 'reg_alpha': 0.1, 'features': 36},
#             Current best combo with val score 0.5491:
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 20}
# Trained and Tested combination 1559 of 2268000, taking 0.9 seconds to get val score of 0.1345:
#                 {'n_estimators': 400, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.7, 'learning_rate': 1e-06, 'reg_alpha': 0.1, 'features': 36},
#             Current best combo with val score 0.5491:
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 20}
# Trained and Tested combination 1560 of 2268000, taking 0.93 seconds to get val score of 0.2123:
#                 {'n_estimators': 400, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.7, 'learning_rate': 0.01, 'reg_alpha': 0.1, 'features': 36},
#             Current best combo with val score 0.5491:
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 20}
# Trained and Tested combination 1561 of 2268000, taking 0.92 seconds to get val score of 0.1408:
#                 {'n_estimators': 400, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.7, 'learning_rate': 0.0001, 'reg_alpha': 0.01, 'features': 36},
#             Current best combo with val score 0.5491:
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 20}
# Trained and Tested combination 1562 of 2268000, taking 0.88 seconds to get val score of 0.1215:
#                 {'n_estimators': 400, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.7, 'learning_rate': 0.0001, 'reg_alpha': 1, 'features': 36},
#             Current best combo with val score 0.5491:
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 20}
# Trained and Tested combination 1563 of 2268000, taking 4.3 seconds to get val score of 0.1612:
#                 {'n_estimators': 400, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.7, 'learning_rate': 0.0001, 'reg_alpha': 0.1, 'features': 35},
#             Current best combo with val score 0.5491:
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 20}
# Trained and Tested combination 1564 of 2268000, taking 3.14 seconds to get val score of 0.1451:
#                 {'n_estimators': 400, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.7, 'learning_rate': 0.0001, 'reg_alpha': 0.1, 'features': 37},
#             Current best combo with val score 0.5491:
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 20}
# Trained and Tested combination 1565 of 2268000, taking 0.24 seconds to get val score of 0.1196:
#                 {'n_estimators': 100, 'max_depth': 12, 'subsample': 0.7, 'colsample_bytree': 0.7, 'learning_rate': 0.0001, 'reg_alpha': 0.1, 'features': 36},
#             Current best combo with val score 0.5491:
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 20}
# Already Trained and Tested combination (val score of 0.1408):
#             {'n_estimators': 400, 'max_depth': 12, 'subsample': 0.7, 'colsample_bytree': 0.7, 'learning_rate': 0.0001, 'reg_alpha': 0.1, 'features': 36}
#             Current best combo (with val score 0.5491):
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 20}
#         Has trained 1565 of 2268000 combinations so far
# Trained and Tested combination 1566 of 2268000, taking 0.4 seconds to get val score of 0.1283:
#                 {'n_estimators': 200, 'max_depth': 6, 'subsample': 0.7, 'colsample_bytree': 0.7, 'learning_rate': 0.0001, 'reg_alpha': 0.1, 'features': 36},
#             Current best combo with val score 0.5491:
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 20}
# Already Trained and Tested combination (val score of 0.1281):
#             {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.7, 'learning_rate': 0.0001, 'reg_alpha': 0.1, 'features': 36}
#             Current best combo (with val score 0.5491):
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 20}
#         Has trained 1566 of 2268000 combinations so far
# Trained and Tested combination 1567 of 2268000, taking 0.48 seconds to get val score of 0.1281:
#                 {'n_estimators': 200, 'max_depth': 12, 'subsample': 0.55, 'colsample_bytree': 0.7, 'learning_rate': 0.0001, 'reg_alpha': 0.1, 'features': 36},
#             Current best combo with val score 0.5491:
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 20}
# Trained and Tested combination 1568 of 2268000, taking 3.73 seconds to get val score of 0.1281:
#                 {'n_estimators': 200, 'max_depth': 12, 'subsample': 0.85, 'colsample_bytree': 0.7, 'learning_rate': 0.0001, 'reg_alpha': 0.1, 'features': 36},
#             Current best combo with val score 0.5491:
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 20}
# Trained and Tested combination 1569 of 2268000, taking 0.44 seconds to get val score of 0.1187:
#                 {'n_estimators': 200, 'max_depth': 12, 'subsample': 0.7, 'colsample_bytree': 0.55, 'learning_rate': 0.0001, 'reg_alpha': 0.1, 'features': 36},
#             Current best combo with val score 0.5491:
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 20}
# Trained and Tested combination 1570 of 2268000, taking 0.5 seconds to get val score of 0.1569:
#                 {'n_estimators': 200, 'max_depth': 12, 'subsample': 0.7, 'colsample_bytree': 0.85, 'learning_rate': 0.0001, 'reg_alpha': 0.1, 'features': 36},
#             Current best combo with val score 0.5491:
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 20}
# Trained and Tested combination 1571 of 2268000, taking 0.44 seconds to get val score of 0.1323:
#                 {'n_estimators': 200, 'max_depth': 12, 'subsample': 0.7, 'colsample_bytree': 0.7, 'learning_rate': 1e-06, 'reg_alpha': 0.1, 'features': 36},
#             Current best combo with val score 0.5491:
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 20}
# Trained and Tested combination 1572 of 2268000, taking 0.46 seconds to get val score of 0.1285:
#                 {'n_estimators': 200, 'max_depth': 12, 'subsample': 0.7, 'colsample_bytree': 0.7, 'learning_rate': 0.01, 'reg_alpha': 0.1, 'features': 36},
#             Current best combo with val score 0.5491:
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 20}
# Trained and Tested combination 1573 of 2268000, taking 0.43 seconds to get val score of 0.1279:
#                 {'n_estimators': 200, 'max_depth': 12, 'subsample': 0.7, 'colsample_bytree': 0.7, 'learning_rate': 0.0001, 'reg_alpha': 0.01, 'features': 36},
#             Current best combo with val score 0.5491:
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 20}
# Trained and Tested combination 1574 of 2268000, taking 0.45 seconds to get val score of 0.1253:
#                 {'n_estimators': 200, 'max_depth': 12, 'subsample': 0.7, 'colsample_bytree': 0.7, 'learning_rate': 0.0001, 'reg_alpha': 1, 'features': 36},
#             Current best combo with val score 0.5491:
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 20}
# Trained and Tested combination 1575 of 2268000, taking 0.53 seconds to get val score of 0.1604:
#                 {'n_estimators': 200, 'max_depth': 12, 'subsample': 0.7, 'colsample_bytree': 0.7, 'learning_rate': 0.0001, 'reg_alpha': 0.1, 'features': 35},
#             Current best combo with val score 0.5491:
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 20}
# Trained and Tested combination 1576 of 2268000, taking 0.47 seconds to get val score of 0.155:
#                 {'n_estimators': 200, 'max_depth': 12, 'subsample': 0.7, 'colsample_bytree': 0.7, 'learning_rate': 0.0001, 'reg_alpha': 0.1, 'features': 37},
#             Current best combo with val score 0.5491:
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 20}
# Trained and Tested combination 1577 of 2268000, taking 0.23 seconds to get val score of 0.1196:
#                 {'n_estimators': 100, 'max_depth': 48, 'subsample': 0.7, 'colsample_bytree': 0.7, 'learning_rate': 0.0001, 'reg_alpha': 0.1, 'features': 36},
#             Current best combo with val score 0.5491:
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 20}
# Already Trained and Tested combination (val score of 0.1408):
#             {'n_estimators': 400, 'max_depth': 48, 'subsample': 0.7, 'colsample_bytree': 0.7, 'learning_rate': 0.0001, 'reg_alpha': 0.1, 'features': 36}
#             Current best combo (with val score 0.5491):
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 20}
#         Has trained 1577 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.1281):
#             {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.7, 'learning_rate': 0.0001, 'reg_alpha': 0.1, 'features': 36}
#             Current best combo (with val score 0.5491):
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 20}
#         Has trained 1577 of 2268000 combinations so far
# Trained and Tested combination 1578 of 2268000, taking 0.46 seconds to get val score of 0.1281:
#                 {'n_estimators': 200, 'max_depth': 96, 'subsample': 0.7, 'colsample_bytree': 0.7, 'learning_rate': 0.0001, 'reg_alpha': 0.1, 'features': 36},
#             Current best combo with val score 0.5491:
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 20}
# Trained and Tested combination 1579 of 2268000, taking 0.43 seconds to get val score of 0.1281:
#                 {'n_estimators': 200, 'max_depth': 48, 'subsample': 0.55, 'colsample_bytree': 0.7, 'learning_rate': 0.0001, 'reg_alpha': 0.1, 'features': 36},
#             Current best combo with val score 0.5491:
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 20}
# Trained and Tested combination 1580 of 2268000, taking 0.46 seconds to get val score of 0.1281:
#                 {'n_estimators': 200, 'max_depth': 48, 'subsample': 0.85, 'colsample_bytree': 0.7, 'learning_rate': 0.0001, 'reg_alpha': 0.1, 'features': 36},
#             Current best combo with val score 0.5491:
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 20}
# Trained and Tested combination 1581 of 2268000, taking 3.74 seconds to get val score of 0.1187:
#                 {'n_estimators': 200, 'max_depth': 48, 'subsample': 0.7, 'colsample_bytree': 0.55, 'learning_rate': 0.0001, 'reg_alpha': 0.1, 'features': 36},
#             Current best combo with val score 0.5491:
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 20}
# Trained and Tested combination 1582 of 2268000, taking 0.47 seconds to get val score of 0.1569:
#                 {'n_estimators': 200, 'max_depth': 48, 'subsample': 0.7, 'colsample_bytree': 0.85, 'learning_rate': 0.0001, 'reg_alpha': 0.1, 'features': 36},
#             Current best combo with val score 0.5491:
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 20}
# Trained and Tested combination 1583 of 2268000, taking 0.49 seconds to get val score of 0.1323:
#                 {'n_estimators': 200, 'max_depth': 48, 'subsample': 0.7, 'colsample_bytree': 0.7, 'learning_rate': 1e-06, 'reg_alpha': 0.1, 'features': 36},
#             Current best combo with val score 0.5491:
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 20}
# Trained and Tested combination 1584 of 2268000, taking 0.44 seconds to get val score of 0.1405:
#                 {'n_estimators': 200, 'max_depth': 48, 'subsample': 0.7, 'colsample_bytree': 0.7, 'learning_rate': 0.01, 'reg_alpha': 0.1, 'features': 36},
#             Current best combo with val score 0.5491:
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 20}
# Trained and Tested combination 1585 of 2268000, taking 0.44 seconds to get val score of 0.1279:
#                 {'n_estimators': 200, 'max_depth': 48, 'subsample': 0.7, 'colsample_bytree': 0.7, 'learning_rate': 0.0001, 'reg_alpha': 0.01, 'features': 36},
#             Current best combo with val score 0.5491:
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 20}
# Trained and Tested combination 1586 of 2268000, taking 0.53 seconds to get val score of 0.1253:
#                 {'n_estimators': 200, 'max_depth': 48, 'subsample': 0.7, 'colsample_bytree': 0.7, 'learning_rate': 0.0001, 'reg_alpha': 1, 'features': 36},
#             Current best combo with val score 0.5491:
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 20}
# Trained and Tested combination 1587 of 2268000, taking 0.5 seconds to get val score of 0.1604:
#                 {'n_estimators': 200, 'max_depth': 48, 'subsample': 0.7, 'colsample_bytree': 0.7, 'learning_rate': 0.0001, 'reg_alpha': 0.1, 'features': 35},
#             Current best combo with val score 0.5491:
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 20}
# Trained and Tested combination 1588 of 2268000, taking 2.71 seconds to get val score of 0.155:
#                 {'n_estimators': 200, 'max_depth': 48, 'subsample': 0.7, 'colsample_bytree': 0.7, 'learning_rate': 0.0001, 'reg_alpha': 0.1, 'features': 37},
#             Current best combo with val score 0.5491:
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 20}
# Trained and Tested combination 1589 of 2268000, taking 0.26 seconds to get val score of 0.1196:
#                 {'n_estimators': 100, 'max_depth': 24, 'subsample': 0.55, 'colsample_bytree': 0.7, 'learning_rate': 0.0001, 'reg_alpha': 0.1, 'features': 36},
#             Current best combo with val score 0.5491:
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 20}
# Already Trained and Tested combination (val score of 0.1408):
#             {'n_estimators': 400, 'max_depth': 24, 'subsample': 0.55, 'colsample_bytree': 0.7, 'learning_rate': 0.0001, 'reg_alpha': 0.1, 'features': 36}
#             Current best combo (with val score 0.5491):
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 20}
#         Has trained 1589 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.1281):
#             {'n_estimators': 200, 'max_depth': 12, 'subsample': 0.55, 'colsample_bytree': 0.7, 'learning_rate': 0.0001, 'reg_alpha': 0.1, 'features': 36}
#             Current best combo (with val score 0.5491):
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 20}
#         Has trained 1589 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.1281):
#             {'n_estimators': 200, 'max_depth': 48, 'subsample': 0.55, 'colsample_bytree': 0.7, 'learning_rate': 0.0001, 'reg_alpha': 0.1, 'features': 36}
#             Current best combo (with val score 0.5491):
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 20}
#         Has trained 1589 of 2268000 combinations so far
# Trained and Tested combination 1590 of 2268000, taking 0.44 seconds to get val score of 0.1281:
#                 {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.7, 'learning_rate': 0.0001, 'reg_alpha': 0.1, 'features': 36},
#             Current best combo with val score 0.5491:
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 20}
# Already Trained and Tested combination (val score of 0.1281):
#             {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.7, 'learning_rate': 0.0001, 'reg_alpha': 0.1, 'features': 36}
#             Current best combo (with val score 0.5491):
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 20}
#         Has trained 1590 of 2268000 combinations so far
# Trained and Tested combination 1591 of 2268000, taking 0.45 seconds to get val score of 0.1187:
#                 {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.55, 'colsample_bytree': 0.55, 'learning_rate': 0.0001, 'reg_alpha': 0.1, 'features': 36},
#             Current best combo with val score 0.5491:
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 20}
# Trained and Tested combination 1592 of 2268000, taking 1.28 seconds to get val score of 0.1569:
#                 {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.55, 'colsample_bytree': 0.85, 'learning_rate': 0.0001, 'reg_alpha': 0.1, 'features': 36},
#             Current best combo with val score 0.5491:
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 20}
# Trained and Tested combination 1593 of 2268000, taking 0.44 seconds to get val score of 0.1323:
#                 {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.55, 'colsample_bytree': 0.7, 'learning_rate': 1e-06, 'reg_alpha': 0.1, 'features': 36},
#             Current best combo with val score 0.5491:
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 20}
# Trained and Tested combination 1594 of 2268000, taking 0.44 seconds to get val score of 0.1405:
#                 {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.55, 'colsample_bytree': 0.7, 'learning_rate': 0.01, 'reg_alpha': 0.1, 'features': 36},
#             Current best combo with val score 0.5491:
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 20}
# Trained and Tested combination 1595 of 2268000, taking 0.46 seconds to get val score of 0.1279:
#                 {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.55, 'colsample_bytree': 0.7, 'learning_rate': 0.0001, 'reg_alpha': 0.01, 'features': 36},
#             Current best combo with val score 0.5491:
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 20}
# Trained and Tested combination 1596 of 2268000, taking 0.42 seconds to get val score of 0.1253:
#                 {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.55, 'colsample_bytree': 0.7, 'learning_rate': 0.0001, 'reg_alpha': 1, 'features': 36},
#             Current best combo with val score 0.5491:
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 20}
# Trained and Tested combination 1597 of 2268000, taking 0.53 seconds to get val score of 0.1604:
#                 {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.55, 'colsample_bytree': 0.7, 'learning_rate': 0.0001, 'reg_alpha': 0.1, 'features': 35},
#             Current best combo with val score 0.5491:
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 20}
# Trained and Tested combination 1598 of 2268000, taking 0.54 seconds to get val score of 0.155:
#                 {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.55, 'colsample_bytree': 0.7, 'learning_rate': 0.0001, 'reg_alpha': 0.1, 'features': 37},
#             Current best combo with val score 0.5491:
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 20}
# Trained and Tested combination 1599 of 2268000, taking 0.23 seconds to get val score of 0.1196:
#                 {'n_estimators': 100, 'max_depth': 24, 'subsample': 0.85, 'colsample_bytree': 0.7, 'learning_rate': 0.0001, 'reg_alpha': 0.1, 'features': 36},
#             Current best combo with val score 0.5491:
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 20}
# Already Trained and Tested combination (val score of 0.1408):
#             {'n_estimators': 400, 'max_depth': 24, 'subsample': 0.85, 'colsample_bytree': 0.7, 'learning_rate': 0.0001, 'reg_alpha': 0.1, 'features': 36}
#             Current best combo (with val score 0.5491):
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 20}
#         Has trained 1599 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.1281):
#             {'n_estimators': 200, 'max_depth': 12, 'subsample': 0.85, 'colsample_bytree': 0.7, 'learning_rate': 0.0001, 'reg_alpha': 0.1, 'features': 36}
#             Current best combo (with val score 0.5491):
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 20}
#         Has trained 1599 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.1281):
#             {'n_estimators': 200, 'max_depth': 48, 'subsample': 0.85, 'colsample_bytree': 0.7, 'learning_rate': 0.0001, 'reg_alpha': 0.1, 'features': 36}
#             Current best combo (with val score 0.5491):
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 20}
#         Has trained 1599 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.1281):
#             {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.7, 'learning_rate': 0.0001, 'reg_alpha': 0.1, 'features': 36}
#             Current best combo (with val score 0.5491):
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 20}
#         Has trained 1599 of 2268000 combinations so far
# Trained and Tested combination 1600 of 2268000, taking 0.46 seconds to get val score of 0.1281:
#                 {'n_estimators': 200, 'max_depth': 24, 'subsample': 1, 'colsample_bytree': 0.7, 'learning_rate': 0.0001, 'reg_alpha': 0.1, 'features': 36},
#             Current best combo with val score 0.5491:
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 20}
# Trained and Tested combination 1601 of 2268000, taking 0.42 seconds to get val score of 0.1187:
#                 {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.85, 'colsample_bytree': 0.55, 'learning_rate': 0.0001, 'reg_alpha': 0.1, 'features': 36},
#             Current best combo with val score 0.5491:
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 20}
# Trained and Tested combination 1602 of 2268000, taking 0.48 seconds to get val score of 0.1569:
#                 {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.85, 'colsample_bytree': 0.85, 'learning_rate': 0.0001, 'reg_alpha': 0.1, 'features': 36},
#             Current best combo with val score 0.5491:
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 20}
# Trained and Tested combination 1603 of 2268000, taking 0.46 seconds to get val score of 0.1323:
#                 {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.85, 'colsample_bytree': 0.7, 'learning_rate': 1e-06, 'reg_alpha': 0.1, 'features': 36},
#             Current best combo with val score 0.5491:
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 20}
# Trained and Tested combination 1604 of 2268000, taking 0.45 seconds to get val score of 0.1405:
#                 {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.85, 'colsample_bytree': 0.7, 'learning_rate': 0.01, 'reg_alpha': 0.1, 'features': 36},
#             Current best combo with val score 0.5491:
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 20}
# Trained and Tested combination 1605 of 2268000, taking 1.43 seconds to get val score of 0.1279:
#                 {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.85, 'colsample_bytree': 0.7, 'learning_rate': 0.0001, 'reg_alpha': 0.01, 'features': 36},
#             Current best combo with val score 0.5491:
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 20}
# Trained and Tested combination 1606 of 2268000, taking 0.43 seconds to get val score of 0.1253:
#                 {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.85, 'colsample_bytree': 0.7, 'learning_rate': 0.0001, 'reg_alpha': 1, 'features': 36},
#             Current best combo with val score 0.5491:
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 20}
# Trained and Tested combination 1607 of 2268000, taking 0.48 seconds to get val score of 0.1604:
#                 {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.85, 'colsample_bytree': 0.7, 'learning_rate': 0.0001, 'reg_alpha': 0.1, 'features': 35},
#             Current best combo with val score 0.5491:
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 20}
# Trained and Tested combination 1608 of 2268000, taking 0.46 seconds to get val score of 0.155:
#                 {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.85, 'colsample_bytree': 0.7, 'learning_rate': 0.0001, 'reg_alpha': 0.1, 'features': 37},
#             Current best combo with val score 0.5491:
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 20}
# Trained and Tested combination 1609 of 2268000, taking 0.27 seconds to get val score of 0.1516:
#                 {'n_estimators': 100, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.85, 'learning_rate': 0.0001, 'reg_alpha': 0.1, 'features': 36},
#             Current best combo with val score 0.5491:
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 20}
# Already Trained and Tested combination (val score of 0.1553):
#             {'n_estimators': 400, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.85, 'learning_rate': 0.0001, 'reg_alpha': 0.1, 'features': 36}
#             Current best combo (with val score 0.5491):
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 20}
#         Has trained 1609 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.1569):
#             {'n_estimators': 200, 'max_depth': 12, 'subsample': 0.7, 'colsample_bytree': 0.85, 'learning_rate': 0.0001, 'reg_alpha': 0.1, 'features': 36}
#             Current best combo (with val score 0.5491):
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 20}
#         Has trained 1609 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.1569):
#             {'n_estimators': 200, 'max_depth': 48, 'subsample': 0.7, 'colsample_bytree': 0.85, 'learning_rate': 0.0001, 'reg_alpha': 0.1, 'features': 36}
#             Current best combo (with val score 0.5491):
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 20}
# ...
#             Current best combo with val score 0.5875:
#                     {'n_estimators': 800, 'max_depth': 12, 'subsample': 1, 'colsample_bytree': 0.7, 'learning_rate': 0.01, 'reg_alpha': 1, 'features': 19}
# Trained and Tested combination 1772 of 2268000, taking 0.78 seconds to get val score of 0.489:
#                 {'n_estimators': 800, 'max_depth': 12, 'subsample': 1, 'colsample_bytree': 0.7, 'learning_rate': 0.01, 'reg_alpha': 10, 'features': 19},
#             Current best combo with val score 0.5875:
#                     {'n_estimators': 800, 'max_depth': 12, 'subsample': 1, 'colsample_bytree': 0.7, 'learning_rate': 0.01, 'reg_alpha': 1, 'features': 19}
# Trained and Tested combination 1773 of 2268000, taking 0.97 seconds to get val score of 0.5814:
#                 {'n_estimators': 800, 'max_depth': 12, 'subsample': 1, 'colsample_bytree': 0.7, 'learning_rate': 0.01, 'reg_alpha': 1, 'features': 18},
#             Current best combo with val score 0.5875:
#                     {'n_estimators': 800, 'max_depth': 12, 'subsample': 1, 'colsample_bytree': 0.7, 'learning_rate': 0.01, 'reg_alpha': 1, 'features': 19}
# Trained and Tested combination 1774 of 2268000, taking 1.0 seconds to get val score of 0.5624:
#                 {'n_estimators': 800, 'max_depth': 12, 'subsample': 1, 'colsample_bytree': 0.7, 'learning_rate': 0.01, 'reg_alpha': 1, 'features': 20},
#             Current best combo with val score 0.5875:
#                     {'n_estimators': 800, 'max_depth': 12, 'subsample': 1, 'colsample_bytree': 0.7, 'learning_rate': 0.01, 'reg_alpha': 1, 'features': 19}
# % Combos Checked Thus Far: 1774 out of 2268000 which is 0.078219%
# Guidance: round FINAL
#
# 	round FINAL iteration:  0
#
# Already Trained and Tested combination (val score of 0.5297):
#             {'n_estimators': 400, 'max_depth': 12, 'subsample': 1, 'colsample_bytree': 0.7, 'learning_rate': 0.01, 'reg_alpha': 1, 'features': 19}
#             Current best combo (with val score 0.5875):
#                     {'n_estimators': 800, 'max_depth': 12, 'subsample': 1, 'colsample_bytree': 0.7, 'learning_rate': 0.01, 'reg_alpha': 1, 'features': 19}
#         Has trained 1774 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.5803):
#             {'n_estimators': 800, 'max_depth': 6, 'subsample': 1, 'colsample_bytree': 0.7, 'learning_rate': 0.01, 'reg_alpha': 1, 'features': 19}
#             Current best combo (with val score 0.5875):
#                     {'n_estimators': 800, 'max_depth': 12, 'subsample': 1, 'colsample_bytree': 0.7, 'learning_rate': 0.01, 'reg_alpha': 1, 'features': 19}
#         Has trained 1774 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.5828):
#             {'n_estimators': 800, 'max_depth': 24, 'subsample': 1, 'colsample_bytree': 0.7, 'learning_rate': 0.01, 'reg_alpha': 1, 'features': 19}
#             Current best combo (with val score 0.5875):
#                     {'n_estimators': 800, 'max_depth': 12, 'subsample': 1, 'colsample_bytree': 0.7, 'learning_rate': 0.01, 'reg_alpha': 1, 'features': 19}
#         Has trained 1774 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.5875):
#             {'n_estimators': 800, 'max_depth': 12, 'subsample': 0.85, 'colsample_bytree': 0.7, 'learning_rate': 0.01, 'reg_alpha': 1, 'features': 19}
#             Current best combo (with val score 0.5875):
#                     {'n_estimators': 800, 'max_depth': 12, 'subsample': 1, 'colsample_bytree': 0.7, 'learning_rate': 0.01, 'reg_alpha': 1, 'features': 19}
#         Has trained 1774 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.5821):
#             {'n_estimators': 800, 'max_depth': 12, 'subsample': 1, 'colsample_bytree': 0.55, 'learning_rate': 0.01, 'reg_alpha': 1, 'features': 19}
#             Current best combo (with val score 0.5875):
#                     {'n_estimators': 800, 'max_depth': 12, 'subsample': 1, 'colsample_bytree': 0.7, 'learning_rate': 0.01, 'reg_alpha': 1, 'features': 19}
#         Has trained 1774 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.5781):
#             {'n_estimators': 800, 'max_depth': 12, 'subsample': 1, 'colsample_bytree': 0.85, 'learning_rate': 0.01, 'reg_alpha': 1, 'features': 19}
#             Current best combo (with val score 0.5875):
#                     {'n_estimators': 800, 'max_depth': 12, 'subsample': 1, 'colsample_bytree': 0.7, 'learning_rate': 0.01, 'reg_alpha': 1, 'features': 19}
#         Has trained 1774 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.3199):
#             {'n_estimators': 800, 'max_depth': 12, 'subsample': 1, 'colsample_bytree': 0.7, 'learning_rate': 0.0001, 'reg_alpha': 1, 'features': 19}
#             Current best combo (with val score 0.5875):
#                     {'n_estimators': 800, 'max_depth': 12, 'subsample': 1, 'colsample_bytree': 0.7, 'learning_rate': 0.01, 'reg_alpha': 1, 'features': 19}
#         Has trained 1774 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.563):
#             {'n_estimators': 800, 'max_depth': 12, 'subsample': 1, 'colsample_bytree': 0.7, 'learning_rate': 0.1, 'reg_alpha': 1, 'features': 19}
#             Current best combo (with val score 0.5875):
#                     {'n_estimators': 800, 'max_depth': 12, 'subsample': 1, 'colsample_bytree': 0.7, 'learning_rate': 0.01, 'reg_alpha': 1, 'features': 19}
#         Has trained 1774 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.5801):
#             {'n_estimators': 800, 'max_depth': 12, 'subsample': 1, 'colsample_bytree': 0.7, 'learning_rate': 0.01, 'reg_alpha': 0.1, 'features': 19}
#             Current best combo (with val score 0.5875):
#                     {'n_estimators': 800, 'max_depth': 12, 'subsample': 1, 'colsample_bytree': 0.7, 'learning_rate': 0.01, 'reg_alpha': 1, 'features': 19}
#         Has trained 1774 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.489):
#             {'n_estimators': 800, 'max_depth': 12, 'subsample': 1, 'colsample_bytree': 0.7, 'learning_rate': 0.01, 'reg_alpha': 10, 'features': 19}
#             Current best combo (with val score 0.5875):
#                     {'n_estimators': 800, 'max_depth': 12, 'subsample': 1, 'colsample_bytree': 0.7, 'learning_rate': 0.01, 'reg_alpha': 1, 'features': 19}
#         Has trained 1774 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.5814):
#             {'n_estimators': 800, 'max_depth': 12, 'subsample': 1, 'colsample_bytree': 0.7, 'learning_rate': 0.01, 'reg_alpha': 1, 'features': 18}
#             Current best combo (with val score 0.5875):
#                     {'n_estimators': 800, 'max_depth': 12, 'subsample': 1, 'colsample_bytree': 0.7, 'learning_rate': 0.01, 'reg_alpha': 1, 'features': 19}
#         Has trained 1774 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.5624):
#             {'n_estimators': 800, 'max_depth': 12, 'subsample': 1, 'colsample_bytree': 0.7, 'learning_rate': 0.01, 'reg_alpha': 1, 'features': 20}
#             Current best combo (with val score 0.5875):
#                     {'n_estimators': 800, 'max_depth': 12, 'subsample': 1, 'colsample_bytree': 0.7, 'learning_rate': 0.01, 'reg_alpha': 1, 'features': 19}
#         Has trained 1774 of 2268000 combinations so far
# 	round FINAL iteration:  1
#
# Trained and Tested combination 1775 of 2268000, taking 0.54 seconds to get val score of 0.5297:
#                 {'n_estimators': 400, 'max_depth': 12, 'subsample': 0.85, 'colsample_bytree': 0.7, 'learning_rate': 0.01, 'reg_alpha': 1, 'features': 19},
#             Current best combo with val score 0.5875:
#                     {'n_estimators': 800, 'max_depth': 12, 'subsample': 1, 'colsample_bytree': 0.7, 'learning_rate': 0.01, 'reg_alpha': 1, 'features': 19}
# Trained and Tested combination 1776 of 2268000, taking 0.74 seconds to get val score of 0.5803:
#                 {'n_estimators': 800, 'max_depth': 6, 'subsample': 0.85, 'colsample_bytree': 0.7, 'learning_rate': 0.01, 'reg_alpha': 1, 'features': 19},
#             Current best combo with val score 0.5875:
#                     {'n_estimators': 800, 'max_depth': 12, 'subsample': 1, 'colsample_bytree': 0.7, 'learning_rate': 0.01, 'reg_alpha': 1, 'features': 19}
# Already Trained and Tested combination (val score of 0.5828):
#             {'n_estimators': 800, 'max_depth': 24, 'subsample': 0.85, 'colsample_bytree': 0.7, 'learning_rate': 0.01, 'reg_alpha': 1, 'features': 19}
#             Current best combo (with val score 0.5875):
#                     {'n_estimators': 800, 'max_depth': 12, 'subsample': 1, 'colsample_bytree': 0.7, 'learning_rate': 0.01, 'reg_alpha': 1, 'features': 19}
#         Has trained 1776 of 2268000 combinations so far
# Trained and Tested combination 1777 of 2268000, taking 1.2 seconds to get val score of 0.5875:
#                 {'n_estimators': 800, 'max_depth': 12, 'subsample': 0.7, 'colsample_bytree': 0.7, 'learning_rate': 0.01, 'reg_alpha': 1, 'features': 19},
#             Current best combo with val score 0.5875:
#                     {'n_estimators': 800, 'max_depth': 12, 'subsample': 1, 'colsample_bytree': 0.7, 'learning_rate': 0.01, 'reg_alpha': 1, 'features': 19}
# Already Trained and Tested combination (val score of 0.5875):
#             {'n_estimators': 800, 'max_depth': 12, 'subsample': 1, 'colsample_bytree': 0.7, 'learning_rate': 0.01, 'reg_alpha': 1, 'features': 19}
#             Current best combo (with val score 0.5875):
#                     {'n_estimators': 800, 'max_depth': 12, 'subsample': 1, 'colsample_bytree': 0.7, 'learning_rate': 0.01, 'reg_alpha': 1, 'features': 19}
#         Has trained 1777 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.5821):
#             {'n_estimators': 800, 'max_depth': 12, 'subsample': 0.85, 'colsample_bytree': 0.55, 'learning_rate': 0.01, 'reg_alpha': 1, 'features': 19}
#             Current best combo (with val score 0.5875):
#                     {'n_estimators': 800, 'max_depth': 12, 'subsample': 1, 'colsample_bytree': 0.7, 'learning_rate': 0.01, 'reg_alpha': 1, 'features': 19}
#         Has trained 1777 of 2268000 combinations so far
# Trained and Tested combination 1778 of 2268000, taking 1.03 seconds to get val score of 0.5781:
#                 {'n_estimators': 800, 'max_depth': 12, 'subsample': 0.85, 'colsample_bytree': 0.85, 'learning_rate': 0.01, 'reg_alpha': 1, 'features': 19},
#             Current best combo with val score 0.5875:
#                     {'n_estimators': 800, 'max_depth': 12, 'subsample': 1, 'colsample_bytree': 0.7, 'learning_rate': 0.01, 'reg_alpha': 1, 'features': 19}
# Trained and Tested combination 1779 of 2268000, taking 1.0 seconds to get val score of 0.3199:
#                 {'n_estimators': 800, 'max_depth': 12, 'subsample': 0.85, 'colsample_bytree': 0.7, 'learning_rate': 0.0001, 'reg_alpha': 1, 'features': 19},
#             Current best combo with val score 0.5875:
#                     {'n_estimators': 800, 'max_depth': 12, 'subsample': 1, 'colsample_bytree': 0.7, 'learning_rate': 0.01, 'reg_alpha': 1, 'features': 19}
# Trained and Tested combination 1780 of 2268000, taking 0.48 seconds to get val score of 0.563:
#                 {'n_estimators': 800, 'max_depth': 12, 'subsample': 0.85, 'colsample_bytree': 0.7, 'learning_rate': 0.1, 'reg_alpha': 1, 'features': 19},
#             Current best combo with val score 0.5875:
#                     {'n_estimators': 800, 'max_depth': 12, 'subsample': 1, 'colsample_bytree': 0.7, 'learning_rate': 0.01, 'reg_alpha': 1, 'features': 19}
# Trained and Tested combination 1781 of 2268000, taking 1.02 seconds to get val score of 0.5801:
#                 {'n_estimators': 800, 'max_depth': 12, 'subsample': 0.85, 'colsample_bytree': 0.7, 'learning_rate': 0.01, 'reg_alpha': 0.1, 'features': 19},
#             Current best combo with val score 0.5875:
#                     {'n_estimators': 800, 'max_depth': 12, 'subsample': 1, 'colsample_bytree': 0.7, 'learning_rate': 0.01, 'reg_alpha': 1, 'features': 19}
# Trained and Tested combination 1782 of 2268000, taking 0.77 seconds to get val score of 0.489:
#                 {'n_estimators': 800, 'max_depth': 12, 'subsample': 0.85, 'colsample_bytree': 0.7, 'learning_rate': 0.01, 'reg_alpha': 10, 'features': 19},
#             Current best combo with val score 0.5875:
#                     {'n_estimators': 800, 'max_depth': 12, 'subsample': 1, 'colsample_bytree': 0.7, 'learning_rate': 0.01, 'reg_alpha': 1, 'features': 19}
# Trained and Tested combination 1783 of 2268000, taking 1.01 seconds to get val score of 0.5814:
#                 {'n_estimators': 800, 'max_depth': 12, 'subsample': 0.85, 'colsample_bytree': 0.7, 'learning_rate': 0.01, 'reg_alpha': 1, 'features': 18},
#             Current best combo with val score 0.5875:
#                     {'n_estimators': 800, 'max_depth': 12, 'subsample': 1, 'colsample_bytree': 0.7, 'learning_rate': 0.01, 'reg_alpha': 1, 'features': 19}
# Trained and Tested combination 1784 of 2268000, taking 1.05 seconds to get val score of 0.5624:
#                 {'n_estimators': 800, 'max_depth': 12, 'subsample': 0.85, 'colsample_bytree': 0.7, 'learning_rate': 0.01, 'reg_alpha': 1, 'features': 20},
#             Current best combo with val score 0.5875:
#                     {'n_estimators': 800, 'max_depth': 12, 'subsample': 1, 'colsample_bytree': 0.7, 'learning_rate': 0.01, 'reg_alpha': 1, 'features': 19}
# % Combos Checked Thus Far: 1784 out of 2268000 which is 0.07866000000000001%
# Max Val Score:
#  0.587453
# Max Val Score Std:
#  0.034547
# Best Combo Train Score:
#  0.963749
# Best Combo Train Score Std:
#  0.00144
# Max Combo Index:
#  (5, 2, 4, 2, 3, 4, 19) out of [6, 7, 5, 5, 5, 6, 72] (note best combo is 0-indexed)
# Max Combo Hyperparamer Combination:
#  {'n_estimators': 800, 'max_depth': 12, 'subsample': 1, 'colsample_bytree': 0.7, 'learning_rate': 0.01, 'reg_alpha': 1, 'features': 19}
# Max Combo Features:
#  ('procedure_225469', 'lods_score', 'procedure_224274', 'marital_status_0', 'marital_status_DIVORCED', 'marital_status_MARRIED', 'marital_status_WIDOWED', 'marital_status_SINGLE', 'procedure_223253', 'race_AMERICAN INDIAN/ALASKA NATIVE', 'race_ASIAN', 'race_ASIAN - ASIAN INDIAN', 'race_ASIAN - CHINESE', 'race_ASIAN - KOREAN', 'race_ASIAN - SOUTH EAST ASIAN', 'race_BLACK/AFRICAN', 'race_BLACK/AFRICAN AMERICAN', 'race_BLACK/CAPE VERDEAN', 'race_BLACK/CARIBBEAN ISLAND', 'race_HISPANIC OR LATINO', 'race_HISPANIC/LATINO - CENTRAL AMERICAN', 'race_HISPANIC/LATINO - COLUMBIAN', 'race_HISPANIC/LATINO - CUBAN', 'race_HISPANIC/LATINO - DOMINICAN', 'race_HISPANIC/LATINO - GUATEMALAN', 'race_HISPANIC/LATINO - HONDURAN', 'race_HISPANIC/LATINO - MEXICAN', 'race_HISPANIC/LATINO - PUERTO RICAN', 'race_HISPANIC/LATINO - SALVADORAN', 'race_MULTIPLE RACE/ETHNICITY', 'race_NATIVE HAWAIIAN OR OTHER PACIFIC ISLANDER', 'race_OTHER', 'race_PATIENT DECLINED TO ANSWER', 'race_PORTUGUESE', 'race_SOUTH AMERICAN', 'race_UNABLE TO OBTAIN', 'race_UNKNOWN', 'race_WHITE', 'race_WHITE - BRAZILIAN', 'race_WHITE - EASTERN EUROPEAN', 'race_WHITE - RUSSIAN', 'race_WHITE - OTHER EUROPEAN', 'procedure_227712', 'procedure_224276', 'admission_type_DIRECT OBSERVATION', 'admission_type_ELECTIVE', 'admission_type_EU OBSERVATION', 'admission_type_EW EMER.', 'admission_type_OBSERVATION ADMIT', 'admission_type_SURGICAL SAME DAY ADMISSION', 'admission_type_URGENT', 'admission_type_DIRECT EMER.', 'insurance_Medicare', 'insurance_Other', 'insurance_Medicaid', 'procedure_225792', 'procedure_228130', 'procedure_225817', 'procedure_224267', 'gender_F', 'gender_M', 'ventilation_used', 'hospital_stay_duration', 'oasis_score', 'procedure_228125', 'procedure_226124')
# % Combos Checked: 1784 out of 2268000 which is 0.07866000000000001%
