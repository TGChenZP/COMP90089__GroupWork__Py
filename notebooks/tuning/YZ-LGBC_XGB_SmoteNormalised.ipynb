# %% [markdown]
# # Tuning Script

# %%
# Parameters subject to change in every script - involved in naming

MODEL = 'lgbc'
PREPROCESSING = 'smote_normalise'
TUNER = 'yangzhoub'
OPTIMISED_METRIC = 'f1'

# %% [markdown]
# ---

# %%
# detect whether this is a google environment

COLAB_ENVIRONMENT = False

try:
    from google.colab import drive
    drive.mount('/content/drive')
    COLAB_ENVIRONMENT = True
except:
    pass
# Out:
# Mounted at /content/drive

# %%
import sys
import os
import pickle

if COLAB_ENVIRONMENT:
    home_directory = './drive/MyDrive/LAB/COMP90089__GroupWork__Py/' # my home directory is stored in ./LAB of google drive
    if MODEL == 'ebr':
        # !pip install interpret==0.5.0
    elif MODEL == 'cbr':
        # !pip install catboost
    elif MODEL in ['tf', 'mlp']:
        # !pip install PyTorch2Sklearn
    # !pip install JXAutoML
else:
    home_directory = '../../'

from JXAutoML.YangZhouB_10CV import YangZhouB_10CV as Tuner

import pandas as pd
# Out:
# Collecting JXAutoML
#   Downloading JXAutoML-0.4.4-py3-none-any.whl.metadata (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.2/67.2 kB 1.9 MB/s eta 0:00:00
# Downloading JXAutoML-0.4.4-py3-none-any.whl (52 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.1/52.1 kB 1.8 MB/s eta 0:00:00
# Installing collected packages: JXAutoML
# Successfully installed JXAutoML-0.4.4

# %%
# Parameters that are same for every script

FOLDS = 10  # we have decided to do 10 fold validation

SEED = 42

TASK_TYPE = 'Classification'  # this task is a classification task

# we have decided to tune features as hp
TUNE_FEATURES_AS_HYPERPARAMETERS = True

# %% [markdown]
# ---

# %%
# model to use to tune
from lightgbm import LGBMClassifier as clf

# what values to try for each hyperparameter
parameter_choices = {
    'n_estimators': (25, 50, 100, 200, 400, 800),
    'max_depth': (3, 6, 12, 24, 48, 96, 192),
    'subsample': (0.4, 0.55, 0.7, 0.85, 1),
    'colsample_bytree': (0.4, 0.55, 0.7, 0.85, 1),
    'learning_rate': (0.00000001, 0.000001, 0.0001, 0.01, 0.1),
    'reg_alpha': (0.0001, 0.001, 0.01, 0.1, 1, 10)
}

# what values to set non-tuneable parameters/hyperparameters
non_tunable_hyperparameters_dict = {
                                    'random_state': SEED,
                                    'n_jobs': -1,
                                    'verbose': -1
                                    }
# Out:
# /usr/local/lib/python3.10/dist-packages/dask/dataframe/__init__.py:42: FutureWarning:
# Dask dataframe query planning is disabled because dask-expr is not installed.
#
# You can install it with `pip install dask[dataframe]` or `conda install dask`.
# This will raise in a future version.
#
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ---

# %% [markdown]
# Read in and Prepare Data

# %%
# Import data and store as lists

train_x_list = []
train_y_list = []
val_x_list = []
val_y_list = []

for i in range(FOLDS):
    train_data = pd.read_csv(
        f'{home_directory}data/curated/modelling/{PREPROCESSING}/train_{i}.csv')
    val_data = pd.read_csv(
        f'{home_directory}data/curated/modelling/{PREPROCESSING}/val_{i}.csv')

    # get the correct rows for X and y
    train_x = train_data.drop(
        ['mortality_status', 'subject_id', 'hadm_id', 'stay_id'], axis=1)
    train_y = train_data['mortality_status']
    val_x = val_data.drop(
        ['mortality_status', 'subject_id', 'hadm_id', 'stay_id'], axis=1)
    val_y = val_data['mortality_status']

    train_x_list.append(train_x)
    train_y_list.append(train_y)
    val_x_list.append(val_x)
    val_y_list.append(val_y)

# %%
# Import feature importance ordering

with open(f'{home_directory}models/xgb_feature_importance_ordering_{PREPROCESSING}.pickle', 'rb') as f:
    feature_importance_ordering = pickle.load(f)

# %% [markdown]
# Set parameters

# %%
# initialisation
tuner = Tuner()

print('---')

# define what model we are tuning
tuner.read_in_model(clf, TASK_TYPE, optimised_metric=OPTIMISED_METRIC)

print('---')

# read in the data for training and validation
tuner.read_in_data(train_x_list, train_y_list, val_x_list, val_y_list)

print('---')

# set what hp values to tune
tuner.set_hyperparameters(parameter_choices)
# WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

# set up hp values that need to be changed from default but NOT to be tuned
tuner.set_non_tuneable_hyperparameters(non_tunable_hyperparameters_dict)

print('---')

# set up feature importance ordering

if TUNE_FEATURES_AS_HYPERPARAMETERS:
    tuner.set_features(feature_importance_ordering)
    # WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

try:  # try to read in previous results to continue tuning ...
    tuner.read_in_tuning_result_df(
        f'{home_directory}models/tuning/{TUNER}_{MODEL}_{PREPROCESSING}.csv')
except:
    print('No previous tuning data read in')

print('---')

# set up where to save the tuning result csv
tuner.set_tuning_result_saving_address(
    f'{home_directory}models/tuning/{TUNER}_{MODEL}_{PREPROCESSING}.csv')

print('---')

# set up where to save the current best model
tuner.set_best_model_saving_address(
    f'{home_directory}models/tmp_models/{TUNER}_{MODEL}_{PREPROCESSING}')
# Out:
# YangZhouB Initialised
# ---
# Successfully read in model <class 'lightgbm.sklearn.LGBMClassifier'>, which is a Classification model optimising for f1
# ---
# Read in Train X data list
# Read in Train y data list
# Read in Val X data list
# Read in Val y data list
# ---
# Successfully recorded hyperparameter choices
# ---
# Successfully recorded non_tuneable_hyperparameter choices
# ---
# Successfully recorded tuneable feature combination choices and updated relevant internal structures
# ---
# Successfully read in tuning result of 2438 rows, for 2438.0 combos
# ---
# Successfully set tuning output address
# ---
# Successfully set best model output address

# %%
# ignore warnings

import warnings
warnings.filterwarnings("ignore")

# %%
# begin tuning ... (or continue training)

tuner.tune()
# Out:
# Streaming output truncated to the last 5000 lines.
#                 {'n_estimators': 25, 'max_depth': 12, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 15},
#             Current best combo with val score 0.4626:
#                     {'n_estimators': 800, 'max_depth': 12, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.01, 'features': 16}
# Already Trained and Tested combination (val score of 0.4257):
#             {'n_estimators': 25, 'max_depth': 48, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 15}
#             Current best combo (with val score 0.4626):
#                     {'n_estimators': 800, 'max_depth': 12, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.01, 'features': 16}
#         Has trained 2705 of 1512000 combinations so far
# Trained and Tested combination 2706 of 1512000, taking 0.05 seconds to get val score of 0.4257:
#                 {'n_estimators': 25, 'max_depth': 24, 'subsample': 0.55, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 15},
#             Current best combo with val score 0.4626:
#                     {'n_estimators': 800, 'max_depth': 12, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.01, 'features': 16}
# Trained and Tested combination 2707 of 1512000, taking 0.98 seconds to get val score of 0.3955:
#                 {'n_estimators': 25, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.55, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 15},
#             Current best combo with val score 0.4626:
#                     {'n_estimators': 800, 'max_depth': 12, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.01, 'features': 16}
# Trained and Tested combination 2708 of 1512000, taking 0.04 seconds to get val score of 0.3494:
#                 {'n_estimators': 25, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.0001, 'features': 15},
#             Current best combo with val score 0.4626:
#                     {'n_estimators': 800, 'max_depth': 12, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.01, 'features': 16}
# Trained and Tested combination 2709 of 1512000, taking 0.05 seconds to get val score of 0.4266:
#                 {'n_estimators': 25, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.001, 'features': 15},
#             Current best combo with val score 0.4626:
#                     {'n_estimators': 800, 'max_depth': 12, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.01, 'features': 16}
# Trained and Tested combination 2710 of 1512000, taking 0.05 seconds to get val score of 0.4122:
#                 {'n_estimators': 25, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 14},
#             Current best combo with val score 0.4626:
#                     {'n_estimators': 800, 'max_depth': 12, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.01, 'features': 16}
# Trained and Tested combination 2711 of 1512000, taking 0.04 seconds to get val score of 0.2694:
#                 {'n_estimators': 25, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 16},
#             Current best combo with val score 0.4626:
#                     {'n_estimators': 800, 'max_depth': 12, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.01, 'features': 16}
# 	round 37 iteration:  1
#
# Already Trained and Tested combination (val score of 0.4257):
#             {'n_estimators': 25, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 15}
#             Current best combo (with val score 0.4626):
#                     {'n_estimators': 800, 'max_depth': 12, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.01, 'features': 16}
#         Has trained 2711 of 1512000 combinations so far
# Trained and Tested combination 2712 of 1512000, taking 0.16 seconds to get val score of 0.4393:
#                 {'n_estimators': 100, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 15},
#             Current best combo with val score 0.4626:
#                     {'n_estimators': 800, 'max_depth': 12, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.01, 'features': 16}
# Trained and Tested combination 2713 of 1512000, taking 0.2 seconds to get val score of 0.4426:
#                 {'n_estimators': 50, 'max_depth': 12, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 15},
#             Current best combo with val score 0.4626:
#                     {'n_estimators': 800, 'max_depth': 12, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.01, 'features': 16}
# Trained and Tested combination 2714 of 1512000, taking 0.08 seconds to get val score of 0.4399:
#                 {'n_estimators': 50, 'max_depth': 48, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 15},
#             Current best combo with val score 0.4626:
#                     {'n_estimators': 800, 'max_depth': 12, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.01, 'features': 16}
# Trained and Tested combination 2715 of 1512000, taking 0.07 seconds to get val score of 0.4399:
#                 {'n_estimators': 50, 'max_depth': 24, 'subsample': 0.55, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 15},
#             Current best combo with val score 0.4626:
#                     {'n_estimators': 800, 'max_depth': 12, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.01, 'features': 16}
# Trained and Tested combination 2716 of 1512000, taking 0.08 seconds to get val score of 0.4066:
#                 {'n_estimators': 50, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.55, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 15},
#             Current best combo with val score 0.4626:
#                     {'n_estimators': 800, 'max_depth': 12, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.01, 'features': 16}
# Trained and Tested combination 2717 of 1512000, taking 0.07 seconds to get val score of 0.1557:
#                 {'n_estimators': 50, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.0001, 'features': 15},
#             Current best combo with val score 0.4626:
#                     {'n_estimators': 800, 'max_depth': 12, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.01, 'features': 16}
# Trained and Tested combination 2718 of 1512000, taking 0.07 seconds to get val score of 0.4452:
#                 {'n_estimators': 50, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.001, 'features': 15},
#             Current best combo with val score 0.4626:
#                     {'n_estimators': 800, 'max_depth': 12, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.01, 'features': 16}
# Trained and Tested combination 2719 of 1512000, taking 0.07 seconds to get val score of 0.4308:
#                 {'n_estimators': 50, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 14},
#             Current best combo with val score 0.4626:
#                     {'n_estimators': 800, 'max_depth': 12, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.01, 'features': 16}
# Trained and Tested combination 2720 of 1512000, taking 0.07 seconds to get val score of 0.4488:
#                 {'n_estimators': 50, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 16},
#             Current best combo with val score 0.4626:
#                     {'n_estimators': 800, 'max_depth': 12, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.01, 'features': 16}
# Already Trained and Tested combination (val score of 0.4399):
#             {'n_estimators': 50, 'max_depth': 24, 'subsample': 0.55, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 15}
#             Current best combo (with val score 0.4626):
#                     {'n_estimators': 800, 'max_depth': 12, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.01, 'features': 16}
#         Has trained 2720 of 1512000 combinations so far
# Trained and Tested combination 2721 of 1512000, taking 0.04 seconds to get val score of 0.4201:
#                 {'n_estimators': 25, 'max_depth': 12, 'subsample': 0.55, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 15},
#             Current best combo with val score 0.4626:
#                     {'n_estimators': 800, 'max_depth': 12, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.01, 'features': 16}
# Trained and Tested combination 2722 of 1512000, taking 0.04 seconds to get val score of 0.4257:
#                 {'n_estimators': 25, 'max_depth': 48, 'subsample': 0.55, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 15},
#             Current best combo with val score 0.4626:
#                     {'n_estimators': 800, 'max_depth': 12, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.01, 'features': 16}
# Already Trained and Tested combination (val score of 0.4257):
#             {'n_estimators': 25, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 15}
#             Current best combo (with val score 0.4626):
#                     {'n_estimators': 800, 'max_depth': 12, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.01, 'features': 16}
#         Has trained 2722 of 1512000 combinations so far
# Trained and Tested combination 2723 of 1512000, taking 0.04 seconds to get val score of 0.4257:
#                 {'n_estimators': 25, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 15},
#             Current best combo with val score 0.4626:
#                     {'n_estimators': 800, 'max_depth': 12, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.01, 'features': 16}
# Trained and Tested combination 2724 of 1512000, taking 0.07 seconds to get val score of 0.3955:
#                 {'n_estimators': 25, 'max_depth': 24, 'subsample': 0.55, 'colsample_bytree': 0.55, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 15},
#             Current best combo with val score 0.4626:
#                     {'n_estimators': 800, 'max_depth': 12, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.01, 'features': 16}
# Trained and Tested combination 2725 of 1512000, taking 0.16 seconds to get val score of 0.3494:
#                 {'n_estimators': 25, 'max_depth': 24, 'subsample': 0.55, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.0001, 'features': 15},
#             Current best combo with val score 0.4626:
#                     {'n_estimators': 800, 'max_depth': 12, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.01, 'features': 16}
# Trained and Tested combination 2726 of 1512000, taking 0.04 seconds to get val score of 0.4266:
#                 {'n_estimators': 25, 'max_depth': 24, 'subsample': 0.55, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.001, 'features': 15},
#             Current best combo with val score 0.4626:
#                     {'n_estimators': 800, 'max_depth': 12, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.01, 'features': 16}
# Trained and Tested combination 2727 of 1512000, taking 0.04 seconds to get val score of 0.4122:
#                 {'n_estimators': 25, 'max_depth': 24, 'subsample': 0.55, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 14},
#             Current best combo with val score 0.4626:
#                     {'n_estimators': 800, 'max_depth': 12, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.01, 'features': 16}
# Trained and Tested combination 2728 of 1512000, taking 0.04 seconds to get val score of 0.2694:
#                 {'n_estimators': 25, 'max_depth': 24, 'subsample': 0.55, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 16},
#             Current best combo with val score 0.4626:
#                     {'n_estimators': 800, 'max_depth': 12, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.01, 'features': 16}
# Already Trained and Tested combination (val score of 0.4452):
#             {'n_estimators': 50, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.001, 'features': 15}
#             Current best combo (with val score 0.4626):
#                     {'n_estimators': 800, 'max_depth': 12, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.01, 'features': 16}
#         Has trained 2728 of 1512000 combinations so far
# Trained and Tested combination 2729 of 1512000, taking 0.04 seconds to get val score of 0.4197:
#                 {'n_estimators': 25, 'max_depth': 12, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.001, 'features': 15},
#             Current best combo with val score 0.4626:
#                     {'n_estimators': 800, 'max_depth': 12, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.01, 'features': 16}
# Trained and Tested combination 2730 of 1512000, taking 0.04 seconds to get val score of 0.4266:
#                 {'n_estimators': 25, 'max_depth': 48, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.001, 'features': 15},
#             Current best combo with val score 0.4626:
#                     {'n_estimators': 800, 'max_depth': 12, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.01, 'features': 16}
# Already Trained and Tested combination (val score of 0.4266):
#             {'n_estimators': 25, 'max_depth': 24, 'subsample': 0.55, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.001, 'features': 15}
#             Current best combo (with val score 0.4626):
#                     {'n_estimators': 800, 'max_depth': 12, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.01, 'features': 16}
#         Has trained 2730 of 1512000 combinations so far
# Trained and Tested combination 2731 of 1512000, taking 0.05 seconds to get val score of 0.395:
#                 {'n_estimators': 25, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.55, 'learning_rate': 0.1, 'reg_alpha': 0.001, 'features': 15},
#             Current best combo with val score 0.4626:
#                     {'n_estimators': 800, 'max_depth': 12, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.01, 'features': 16}
# Trained and Tested combination 2732 of 1512000, taking 0.42 seconds to get val score of 0.3494:
#                 {'n_estimators': 25, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.001, 'features': 15},
#             Current best combo with val score 0.4626:
#                     {'n_estimators': 800, 'max_depth': 12, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.01, 'features': 16}
# Already Trained and Tested combination (val score of 0.4257):
#             {'n_estimators': 25, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 15}
#             Current best combo (with val score 0.4626):
#                     {'n_estimators': 800, 'max_depth': 12, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.01, 'features': 16}
#         Has trained 2732 of 1512000 combinations so far
# Trained and Tested combination 2733 of 1512000, taking 0.04 seconds to get val score of 0.4175:
#                 {'n_estimators': 25, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.01, 'features': 15},
#             Current best combo with val score 0.4626:
#                     {'n_estimators': 800, 'max_depth': 12, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.01, 'features': 16}
# Trained and Tested combination 2734 of 1512000, taking 0.04 seconds to get val score of 0.411:
#                 {'n_estimators': 25, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.001, 'features': 14},
#             Current best combo with val score 0.4626:
#                     {'n_estimators': 800, 'max_depth': 12, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.01, 'features': 16}
# Trained and Tested combination 2735 of 1512000, taking 0.04 seconds to get val score of 0.2661:
#                 {'n_estimators': 25, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.001, 'features': 16},
#             Current best combo with val score 0.4626:
#                     {'n_estimators': 800, 'max_depth': 12, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.01, 'features': 16}
# % Combos Checked Thus Far: 2735 out of 1512000 which is 0.180886%
# Cruising Coordrdinate 1009 of 1056
#
# Cruising Coordrdinate 1010 of 1056
#
# Cruise suspended due to suspicious case
# Guidance: round 38
#
# 	round 38 iteration:  0
#
# Trained and Tested combination 2736 of 1512000, taking 0.08 seconds to get val score of 0.4399:
#                 {'n_estimators': 50, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 15},
#             Current best combo with val score 0.4626:
#                     {'n_estimators': 800, 'max_depth': 12, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.01, 'features': 16}
# Trained and Tested combination 2737 of 1512000, taking 0.04 seconds to get val score of 0.4257:
#                 {'n_estimators': 25, 'max_depth': 96, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 15},
#             Current best combo with val score 0.4626:
#                     {'n_estimators': 800, 'max_depth': 12, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.01, 'features': 16}
# Trained and Tested combination 2738 of 1512000, taking 0.05 seconds to get val score of 0.4257:
#                 {'n_estimators': 25, 'max_depth': 192, 'subsample': 0.85, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 15},
#             Current best combo with val score 0.4626:
#                     {'n_estimators': 800, 'max_depth': 12, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.01, 'features': 16}
# Trained and Tested combination 2739 of 1512000, taking 0.47 seconds to get val score of 0.3955:
#                 {'n_estimators': 25, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.55, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 15},
#             Current best combo with val score 0.4626:
#                     {'n_estimators': 800, 'max_depth': 12, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.01, 'features': 16}
# Trained and Tested combination 2740 of 1512000, taking 0.04 seconds to get val score of 0.3494:
#                 {'n_estimators': 25, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.0001, 'features': 15},
#             Current best combo with val score 0.4626:
#                     {'n_estimators': 800, 'max_depth': 12, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.01, 'features': 16}
# Trained and Tested combination 2741 of 1512000, taking 0.07 seconds to get val score of 0.4266:
#                 {'n_estimators': 25, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.001, 'features': 15},
#             Current best combo with val score 0.4626:
#                     {'n_estimators': 800, 'max_depth': 12, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.01, 'features': 16}
# Trained and Tested combination 2742 of 1512000, taking 0.04 seconds to get val score of 0.4122:
#                 {'n_estimators': 25, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 14},
#             Current best combo with val score 0.4626:
#                     {'n_estimators': 800, 'max_depth': 12, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.01, 'features': 16}
# Trained and Tested combination 2743 of 1512000, taking 0.05 seconds to get val score of 0.2694:
#                 {'n_estimators': 25, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 16},
#             Current best combo with val score 0.4626:
#                     {'n_estimators': 800, 'max_depth': 12, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.01, 'features': 16}
# 	round 38 iteration:  1
#
# Already Trained and Tested combination (val score of 0.4257):
#             {'n_estimators': 25, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 15}
#             Current best combo (with val score 0.4626):
#                     {'n_estimators': 800, 'max_depth': 12, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.01, 'features': 16}
#         Has trained 2743 of 1512000 combinations so far
# Trained and Tested combination 2744 of 1512000, taking 0.13 seconds to get val score of 0.4393:
#                 {'n_estimators': 100, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 15},
#             Current best combo with val score 0.4626:
#                     {'n_estimators': 800, 'max_depth': 12, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.01, 'features': 16}
# Trained and Tested combination 2745 of 1512000, taking 0.25 seconds to get val score of 0.4399:
#                 {'n_estimators': 50, 'max_depth': 96, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 15},
#             Current best combo with val score 0.4626:
#                     {'n_estimators': 800, 'max_depth': 12, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.01, 'features': 16}
# Trained and Tested combination 2746 of 1512000, taking 0.07 seconds to get val score of 0.4399:
#                 {'n_estimators': 50, 'max_depth': 192, 'subsample': 0.85, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 15},
#             Current best combo with val score 0.4626:
#                     {'n_estimators': 800, 'max_depth': 12, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.01, 'features': 16}
# Trained and Tested combination 2747 of 1512000, taking 0.07 seconds to get val score of 0.4066:
#                 {'n_estimators': 50, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.55, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 15},
#             Current best combo with val score 0.4626:
#                     {'n_estimators': 800, 'max_depth': 12, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.01, 'features': 16}
# Trained and Tested combination 2748 of 1512000, taking 0.07 seconds to get val score of 0.1557:
#                 {'n_estimators': 50, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.0001, 'features': 15},
#             Current best combo with val score 0.4626:
#                     {'n_estimators': 800, 'max_depth': 12, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.01, 'features': 16}
# Trained and Tested combination 2749 of 1512000, taking 0.07 seconds to get val score of 0.4452:
#                 {'n_estimators': 50, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.001, 'features': 15},
#             Current best combo with val score 0.4626:
#                     {'n_estimators': 800, 'max_depth': 12, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.01, 'features': 16}
# Trained and Tested combination 2750 of 1512000, taking 0.07 seconds to get val score of 0.4308:
#                 {'n_estimators': 50, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 14},
#             Current best combo with val score 0.4626:
#                     {'n_estimators': 800, 'max_depth': 12, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.01, 'features': 16}
# Trained and Tested combination 2751 of 1512000, taking 0.49 seconds to get val score of 0.4488:
#                 {'n_estimators': 50, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 16},
#             Current best combo with val score 0.4626:
#                     {'n_estimators': 800, 'max_depth': 12, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.01, 'features': 16}
# Already Trained and Tested combination (val score of 0.4399):
#             {'n_estimators': 50, 'max_depth': 96, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 15}
#             Current best combo (with val score 0.4626):
#                     {'n_estimators': 800, 'max_depth': 12, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.01, 'features': 16}
#         Has trained 2751 of 1512000 combinations so far
# Trained and Tested combination 2752 of 1512000, taking 0.05 seconds to get val score of 0.4257:
#                 {'n_estimators': 25, 'max_depth': 48, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 15},
#             Current best combo with val score 0.4626:
#                     {'n_estimators': 800, 'max_depth': 12, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.01, 'features': 16}
# Already Trained and Tested combination (val score of 0.4257):
#             {'n_estimators': 25, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 15}
#             Current best combo (with val score 0.4626):
#                     {'n_estimators': 800, 'max_depth': 12, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.01, 'features': 16}
#         Has trained 2752 of 1512000 combinations so far
# Trained and Tested combination 2753 of 1512000, taking 0.04 seconds to get val score of 0.4257:
#                 {'n_estimators': 25, 'max_depth': 96, 'subsample': 0.85, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 15},
#             Current best combo with val score 0.4626:
#                     {'n_estimators': 800, 'max_depth': 12, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.01, 'features': 16}
# Trained and Tested combination 2754 of 1512000, taking 0.04 seconds to get val score of 0.3955:
#                 {'n_estimators': 25, 'max_depth': 96, 'subsample': 1, 'colsample_bytree': 0.55, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 15},
#             Current best combo with val score 0.4626:
#                     {'n_estimators': 800, 'max_depth': 12, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.01, 'features': 16}
# Trained and Tested combination 2755 of 1512000, taking 0.05 seconds to get val score of 0.3494:
#                 {'n_estimators': 25, 'max_depth': 96, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.0001, 'features': 15},
#             Current best combo with val score 0.4626:
#                     {'n_estimators': 800, 'max_depth': 12, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.01, 'features': 16}
# Trained and Tested combination 2756 of 1512000, taking 0.04 seconds to get val score of 0.4266:
#                 {'n_estimators': 25, 'max_depth': 96, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.001, 'features': 15},
#             Current best combo with val score 0.4626:
#                     {'n_estimators': 800, 'max_depth': 12, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.01, 'features': 16}
# Trained and Tested combination 2757 of 1512000, taking 0.05 seconds to get val score of 0.4122:
#                 {'n_estimators': 25, 'max_depth': 96, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 14},
#             Current best combo with val score 0.4626:
#                     {'n_estimators': 800, 'max_depth': 12, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.01, 'features': 16}
# Trained and Tested combination 2758 of 1512000, taking 0.34 seconds to get val score of 0.2694:
#                 {'n_estimators': 25, 'max_depth': 96, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 16},
#             Current best combo with val score 0.4626:
#                     {'n_estimators': 800, 'max_depth': 12, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.01, 'features': 16}
# Already Trained and Tested combination (val score of 0.4399):
#             {'n_estimators': 50, 'max_depth': 192, 'subsample': 0.85, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 15}
#             Current best combo (with val score 0.4626):
#                     {'n_estimators': 800, 'max_depth': 12, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.01, 'features': 16}
#         Has trained 2758 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.4257):
#             {'n_estimators': 25, 'max_depth': 96, 'subsample': 0.85, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 15}
#             Current best combo (with val score 0.4626):
#                     {'n_estimators': 800, 'max_depth': 12, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.01, 'features': 16}
#         Has trained 2758 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.4257):
#             {'n_estimators': 25, 'max_depth': 192, 'subsample': 0.7, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 15}
#             Current best combo (with val score 0.4626):
#                     {'n_estimators': 800, 'max_depth': 12, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.01, 'features': 16}
#         Has trained 2758 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.4257):
#             {'n_estimators': 25, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 15}
#             Current best combo (with val score 0.4626):
#                     {'n_estimators': 800, 'max_depth': 12, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.01, 'features': 16}
#         Has trained 2758 of 1512000 combinations so far
# Trained and Tested combination 2759 of 1512000, taking 0.04 seconds to get val score of 0.3955:
#                 {'n_estimators': 25, 'max_depth': 192, 'subsample': 0.85, 'colsample_bytree': 0.55, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 15},
#             Current best combo with val score 0.4626:
#                     {'n_estimators': 800, 'max_depth': 12, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.01, 'features': 16}
# Trained and Tested combination 2760 of 1512000, taking 0.04 seconds to get val score of 0.3494:
#                 {'n_estimators': 25, 'max_depth': 192, 'subsample': 0.85, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.0001, 'features': 15},
#             Current best combo with val score 0.4626:
#                     {'n_estimators': 800, 'max_depth': 12, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.01, 'features': 16}
# Trained and Tested combination 2761 of 1512000, taking 0.06 seconds to get val score of 0.4266:
#                 {'n_estimators': 25, 'max_depth': 192, 'subsample': 0.85, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.001, 'features': 15},
#             Current best combo with val score 0.4626:
#                     {'n_estimators': 800, 'max_depth': 12, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.01, 'features': 16}
# Trained and Tested combination 2762 of 1512000, taking 0.05 seconds to get val score of 0.4122:
#                 {'n_estimators': 25, 'max_depth': 192, 'subsample': 0.85, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 14},
#             Current best combo with val score 0.4626:
#                     {'n_estimators': 800, 'max_depth': 12, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.01, 'features': 16}
# Trained and Tested combination 2763 of 1512000, taking 0.04 seconds to get val score of 0.2694:
#                 {'n_estimators': 25, 'max_depth': 192, 'subsample': 0.85, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 16},
#             Current best combo with val score 0.4626:
#                     {'n_estimators': 800, 'max_depth': 12, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.01, 'features': 16}
# Already Trained and Tested combination (val score of 0.4452):
#             {'n_estimators': 50, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.001, 'features': 15}
#             Current best combo (with val score 0.4626):
#                     {'n_estimators': 800, 'max_depth': 12, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.01, 'features': 16}
#         Has trained 2763 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.4266):
#             {'n_estimators': 25, 'max_depth': 96, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.001, 'features': 15}
#             Current best combo (with val score 0.4626):
#                     {'n_estimators': 800, 'max_depth': 12, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.01, 'features': 16}
#         Has trained 2763 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.4266):
#             {'n_estimators': 25, 'max_depth': 192, 'subsample': 0.85, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.001, 'features': 15}
#             Current best combo (with val score 0.4626):
#                     {'n_estimators': 800, 'max_depth': 12, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.01, 'features': 16}
#         Has trained 2763 of 1512000 combinations so far
# Trained and Tested combination 2764 of 1512000, taking 0.05 seconds to get val score of 0.395:
#                 {'n_estimators': 25, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.55, 'learning_rate': 0.1, 'reg_alpha': 0.001, 'features': 15},
#             Current best combo with val score 0.4626:
#                     {'n_estimators': 800, 'max_depth': 12, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.01, 'features': 16}
# Trained and Tested combination 2765 of 1512000, taking 0.16 seconds to get val score of 0.3494:
#                 {'n_estimators': 25, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.001, 'features': 15},
#             Current best combo with val score 0.4626:
#                     {'n_estimators': 800, 'max_depth': 12, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.01, 'features': 16}
# Already Trained and Tested combination (val score of 0.4257):
#             {'n_estimators': 25, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 15}
#             Current best combo (with val score 0.4626):
#                     {'n_estimators': 800, 'max_depth': 12, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.01, 'features': 16}
#         Has trained 2765 of 1512000 combinations so far
# Trained and Tested combination 2766 of 1512000, taking 0.05 seconds to get val score of 0.4175:
#                 {'n_estimators': 25, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.01, 'features': 15},
#             Current best combo with val score 0.4626:
#                     {'n_estimators': 800, 'max_depth': 12, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.01, 'features': 16}
# Trained and Tested combination 2767 of 1512000, taking 0.04 seconds to get val score of 0.411:
#                 {'n_estimators': 25, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.001, 'features': 14},
#             Current best combo with val score 0.4626:
#                     {'n_estimators': 800, 'max_depth': 12, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.01, 'features': 16}
# Trained and Tested combination 2768 of 1512000, taking 0.04 seconds to get val score of 0.2661:
#                 {'n_estimators': 25, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.001, 'features': 16},
#             Current best combo with val score 0.4626:
#                     {'n_estimators': 800, 'max_depth': 12, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.01, 'features': 16}
# % Combos Checked Thus Far: 2768 out of 1512000 which is 0.183069%
# Cruising Coordrdinate 1011 of 1056
#
# Cruising Coordrdinate 1012 of 1056
#
# Cruising Coordrdinate 1013 of 1056
#
# Cruising Coordrdinate 1014 of 1056
#
# Cruising Coordrdinate 1015 of 1056
#
# Cruising Coordrdinate 1016 of 1056
#
# Cruising Coordrdinate 1017 of 1056
#
# Cruising Coordrdinate 1018 of 1056
#
# Cruising Coordrdinate 1019 of 1056
#
# Cruise suspended due to suspicious case
# Guidance: round 39
#
# 	round 39 iteration:  0
#
# Trained and Tested combination 2769 of 1512000, taking 0.33 seconds to get val score of 0.4174:
#                 {'n_estimators': 400, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 20},
#             Current best combo with val score 0.4626:
#                     {'n_estimators': 800, 'max_depth': 12, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.01, 'features': 16}
# Trained and Tested combination 2770 of 1512000, taking 0.45 seconds to get val score of 0.4147:
#                 {'n_estimators': 800, 'max_depth': 12, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 20},
#             Current best combo with val score 0.4626:
#                     {'n_estimators': 800, 'max_depth': 12, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.01, 'features': 16}
# Trained and Tested combination 2771 of 1512000, taking 0.42 seconds to get val score of 0.4174:
#                 {'n_estimators': 800, 'max_depth': 48, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 20},
#             Current best combo with val score 0.4626:
#                     {'n_estimators': 800, 'max_depth': 12, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.01, 'features': 16}
# Trained and Tested combination 2772 of 1512000, taking 0.47 seconds to get val score of 0.4174:
#                 {'n_estimators': 800, 'max_depth': 24, 'subsample': 0.55, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 20},
#             Current best combo with val score 0.4626:
#                     {'n_estimators': 800, 'max_depth': 12, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.01, 'features': 16}
# Trained and Tested combination 2773 of 1512000, taking 0.41 seconds to get val score of 0.3319:
#                 {'n_estimators': 800, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.55, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 20},
#             Current best combo with val score 0.4626:
#                     {'n_estimators': 800, 'max_depth': 12, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.01, 'features': 16}
# Trained and Tested combination 2774 of 1512000, taking 0.81 seconds to get val score of 0.3603:
#                 {'n_estimators': 800, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 10, 'features': 20},
#             Current best combo with val score 0.4626:
#                     {'n_estimators': 800, 'max_depth': 12, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.01, 'features': 16}
# Trained and Tested combination 2775 of 1512000, taking 0.74 seconds to get val score of 0.4476:
#                 {'n_estimators': 800, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 1, 'features': 20},
#             Current best combo with val score 0.4626:
#                     {'n_estimators': 800, 'max_depth': 12, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.01, 'features': 16}
# Trained and Tested combination 2776 of 1512000, taking 0.47 seconds to get val score of 0.3116:
#                 {'n_estimators': 800, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 19},
#             Current best combo with val score 0.4626:
#                     {'n_estimators': 800, 'max_depth': 12, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.01, 'features': 16}
# Trained and Tested combination 2777 of 1512000, taking 3.2 seconds to get val score of 0.3012:
#                 {'n_estimators': 800, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 21},
#             Current best combo with val score 0.4626:
#                     {'n_estimators': 800, 'max_depth': 12, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.01, 'features': 16}
# 	round 39 iteration:  1
#
# Trained and Tested combination 2778 of 1512000, taking 0.2 seconds to get val score of 0.4174:
#                 {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 20},
#             Current best combo with val score 0.4626:
#                     {'n_estimators': 800, 'max_depth': 12, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.01, 'features': 16}
# Already Trained and Tested combination (val score of 0.4174):
#             {'n_estimators': 800, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 20}
#             Current best combo (with val score 0.4626):
#                     {'n_estimators': 800, 'max_depth': 12, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.01, 'features': 16}
#         Has trained 2778 of 1512000 combinations so far
# Trained and Tested combination 2779 of 1512000, taking 0.27 seconds to get val score of 0.4147:
#                 {'n_estimators': 400, 'max_depth': 12, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 20},
#             Current best combo with val score 0.4626:
#                     {'n_estimators': 800, 'max_depth': 12, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.01, 'features': 16}
# Trained and Tested combination 2780 of 1512000, taking 2.03 seconds to get val score of 0.4174:
#                 {'n_estimators': 400, 'max_depth': 48, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 20},
#             Current best combo with val score 0.4626:
#                     {'n_estimators': 800, 'max_depth': 12, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.01, 'features': 16}
# Trained and Tested combination 2781 of 1512000, taking 0.25 seconds to get val score of 0.4174:
#                 {'n_estimators': 400, 'max_depth': 24, 'subsample': 0.55, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 20},
#             Current best combo with val score 0.4626:
#                     {'n_estimators': 800, 'max_depth': 12, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.01, 'features': 16}
# Trained and Tested combination 2782 of 1512000, taking 0.21 seconds to get val score of 0.3319:
#                 {'n_estimators': 400, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.55, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 20},
#             Current best combo with val score 0.4626:
#                     {'n_estimators': 800, 'max_depth': 12, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.01, 'features': 16}
# Trained and Tested combination 2783 of 1512000, taking 0.42 seconds to get val score of 0.3009:
#                 {'n_estimators': 400, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 10, 'features': 20},
#             Current best combo with val score 0.4626:
#                     {'n_estimators': 800, 'max_depth': 12, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.01, 'features': 16}
# Trained and Tested combination 2784 of 1512000, taking 2.53 seconds to get val score of 0.4456:
#                 {'n_estimators': 400, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 1, 'features': 20},
#             Current best combo with val score 0.4626:
#                     {'n_estimators': 800, 'max_depth': 12, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.01, 'features': 16}
# Trained and Tested combination 2785 of 1512000, taking 0.23 seconds to get val score of 0.3116:
#                 {'n_estimators': 400, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 19},
#             Current best combo with val score 0.4626:
#                     {'n_estimators': 800, 'max_depth': 12, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.01, 'features': 16}
# Trained and Tested combination 2786 of 1512000, taking 0.29 seconds to get val score of 0.3012:
# ...
#                     {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.1, 'features': 20}
# Trained and Tested combination 3425 of 1512000, taking 0.22 seconds to get val score of 0.4351:
#                 {'n_estimators': 200, 'max_depth': 6, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.1, 'features': 20},
#             Current best combo with val score 0.4873:
#                     {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.1, 'features': 20}
# Trained and Tested combination 3426 of 1512000, taking 0.14 seconds to get val score of 0.4873:
#                 {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.55, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.1, 'features': 20},
#             Current best combo with val score 0.4873:
#                     {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.1, 'features': 20}
# Trained and Tested combination 3427 of 1512000, taking 0.12 seconds to get val score of 0.4699:
#                 {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.55, 'learning_rate': 0.1, 'reg_alpha': 0.1, 'features': 20},
#             Current best combo with val score 0.4873:
#                     {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.1, 'features': 20}
# Trained and Tested combination 3428 of 1512000, taking 0.14 seconds to get val score of 0.0927:
#                 {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.1, 'features': 20},
#             Current best combo with val score 0.4873:
#                     {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.1, 'features': 20}
# Already Trained and Tested combination (val score of 0.4745):
#             {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.01, 'features': 20}
#             Current best combo (with val score 0.4873):
#                     {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.1, 'features': 20}
#         Has trained 3428 of 1512000 combinations so far
# Trained and Tested combination 3429 of 1512000, taking 0.14 seconds to get val score of 0.4816:
#                 {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 1, 'features': 20},
#             Current best combo with val score 0.4873:
#                     {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.1, 'features': 20}
# Trained and Tested combination 3430 of 1512000, taking 0.13 seconds to get val score of 0.4044:
#                 {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.1, 'features': 19},
#             Current best combo with val score 0.4873:
#                     {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.1, 'features': 20}
# Trained and Tested combination 3431 of 1512000, taking 0.14 seconds to get val score of 0.4079:
#                 {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.1, 'features': 21},
#             Current best combo with val score 0.4873:
#                     {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.1, 'features': 20}
# % Combos Checked Thus Far: 3431 out of 1512000 which is 0.226918%
# Guidance: round FINAL
#
# 	round FINAL iteration:  0
#
# Already Trained and Tested combination (val score of 0.4211):
#             {'n_estimators': 100, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.1, 'features': 20}
#             Current best combo (with val score 0.4873):
#                     {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.1, 'features': 20}
#         Has trained 3431 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.4663):
#             {'n_estimators': 400, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.1, 'features': 20}
#             Current best combo (with val score 0.4873):
#                     {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.1, 'features': 20}
#         Has trained 3431 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.4351):
#             {'n_estimators': 200, 'max_depth': 6, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.1, 'features': 20}
#             Current best combo (with val score 0.4873):
#                     {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.1, 'features': 20}
#         Has trained 3431 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.4873):
#             {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.55, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.1, 'features': 20}
#             Current best combo (with val score 0.4873):
#                     {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.1, 'features': 20}
#         Has trained 3431 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.4699):
#             {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.55, 'learning_rate': 0.1, 'reg_alpha': 0.1, 'features': 20}
#             Current best combo (with val score 0.4873):
#                     {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.1, 'features': 20}
#         Has trained 3431 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.0927):
#             {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.1, 'features': 20}
#             Current best combo (with val score 0.4873):
#                     {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.1, 'features': 20}
#         Has trained 3431 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.4745):
#             {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.01, 'features': 20}
#             Current best combo (with val score 0.4873):
#                     {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.1, 'features': 20}
#         Has trained 3431 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.4816):
#             {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 1, 'features': 20}
#             Current best combo (with val score 0.4873):
#                     {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.1, 'features': 20}
#         Has trained 3431 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.4044):
#             {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.1, 'features': 19}
#             Current best combo (with val score 0.4873):
#                     {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.1, 'features': 20}
#         Has trained 3431 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.4079):
#             {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.1, 'features': 21}
#             Current best combo (with val score 0.4873):
#                     {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.1, 'features': 20}
#         Has trained 3431 of 1512000 combinations so far
# 	round FINAL iteration:  1
#
# Trained and Tested combination 3432 of 1512000, taking 0.08 seconds to get val score of 0.4211:
#                 {'n_estimators': 100, 'max_depth': 3, 'subsample': 0.55, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.1, 'features': 20},
#             Current best combo with val score 0.4873:
#                     {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.1, 'features': 20}
# Trained and Tested combination 3433 of 1512000, taking 1.06 seconds to get val score of 0.4663:
#                 {'n_estimators': 400, 'max_depth': 3, 'subsample': 0.55, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.1, 'features': 20},
#             Current best combo with val score 0.4873:
#                     {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.1, 'features': 20}
# Trained and Tested combination 3434 of 1512000, taking 0.21 seconds to get val score of 0.4351:
#                 {'n_estimators': 200, 'max_depth': 6, 'subsample': 0.55, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.1, 'features': 20},
#             Current best combo with val score 0.4873:
#                     {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.1, 'features': 20}
# Already Trained and Tested combination (val score of 0.4873):
#             {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.1, 'features': 20}
#             Current best combo (with val score 0.4873):
#                     {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.1, 'features': 20}
#         Has trained 3434 of 1512000 combinations so far
# Trained and Tested combination 3435 of 1512000, taking 0.14 seconds to get val score of 0.4873:
#                 {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.7, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.1, 'features': 20},
#             Current best combo with val score 0.4873:
#                     {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.1, 'features': 20}
# Trained and Tested combination 3436 of 1512000, taking 0.13 seconds to get val score of 0.4699:
#                 {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.55, 'colsample_bytree': 0.55, 'learning_rate': 0.1, 'reg_alpha': 0.1, 'features': 20},
#             Current best combo with val score 0.4873:
#                     {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.1, 'features': 20}
# Trained and Tested combination 3437 of 1512000, taking 0.15 seconds to get val score of 0.0927:
#                 {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.55, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.1, 'features': 20},
#             Current best combo with val score 0.4873:
#                     {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.1, 'features': 20}
# Already Trained and Tested combination (val score of 0.4745):
#             {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.55, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.01, 'features': 20}
#             Current best combo (with val score 0.4873):
#                     {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.1, 'features': 20}
#         Has trained 3437 of 1512000 combinations so far
# Trained and Tested combination 3438 of 1512000, taking 0.16 seconds to get val score of 0.4816:
#                 {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.55, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 1, 'features': 20},
#             Current best combo with val score 0.4873:
#                     {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.1, 'features': 20}
# Trained and Tested combination 3439 of 1512000, taking 0.14 seconds to get val score of 0.4044:
#                 {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.55, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.1, 'features': 19},
#             Current best combo with val score 0.4873:
#                     {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.1, 'features': 20}
# Trained and Tested combination 3440 of 1512000, taking 0.41 seconds to get val score of 0.4079:
#                 {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.55, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.1, 'features': 21},
#             Current best combo with val score 0.4873:
#                     {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.1, 'features': 20}
# % Combos Checked Thus Far: 3440 out of 1512000 which is 0.22751300000000002%
# Max Val Score:
#  0.487265
# Max Val Score Std:
#  0.061514
# Best Combo Train Score:
#  0.935126
# Best Combo Train Score Std:
#  0.001881
# Max Combo Index:
#  (3, 0, 0, 0, 4, 3, 20) out of [6, 7, 5, 5, 5, 6, 48] (note best combo is 0-indexed)
# Max Combo Hyperparamer Combination:
#  {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.1, 'features': 20}
# Max Combo Features:
#  ('procedure_224274', 'lods_score', 'procedure_224276', 'procedure_224267', 'race_AMERICAN INDIAN/ALASKA NATIVE', 'race_ASIAN', 'race_ASIAN - ASIAN INDIAN', 'race_ASIAN - CHINESE', 'race_ASIAN - KOREAN', 'race_ASIAN - SOUTH EAST ASIAN', 'race_BLACK/AFRICAN', 'race_BLACK/AFRICAN AMERICAN', 'race_BLACK/CAPE VERDEAN', 'race_BLACK/CARIBBEAN ISLAND', 'race_HISPANIC OR LATINO', 'race_HISPANIC/LATINO - CENTRAL AMERICAN', 'race_HISPANIC/LATINO - COLUMBIAN', 'race_HISPANIC/LATINO - CUBAN', 'race_HISPANIC/LATINO - DOMINICAN', 'race_HISPANIC/LATINO - GUATEMALAN', 'race_HISPANIC/LATINO - HONDURAN', 'race_HISPANIC/LATINO - MEXICAN', 'race_HISPANIC/LATINO - PUERTO RICAN', 'race_HISPANIC/LATINO - SALVADORAN', 'race_MULTIPLE RACE/ETHNICITY', 'race_NATIVE HAWAIIAN OR OTHER PACIFIC ISLANDER', 'race_OTHER', 'race_PATIENT DECLINED TO ANSWER', 'race_PORTUGUESE', 'race_SOUTH AMERICAN', 'race_UNABLE TO OBTAIN', 'race_WHITE', 'race_WHITE - BRAZILIAN', 'race_WHITE - EASTERN EUROPEAN', 'race_WHITE - OTHER EUROPEAN', 'race_WHITE - RUSSIAN', 'race_UNKNOWN', 'procedure_227712', 'procedure_225430', 'gender_F', 'gender_M', 'oasis_score', 'procedure_225446', 'procedure_224275', 'procedure_225802', 'hospital_stay_duration', 'procedure_226475', 'ventilation_used', 'procedure_224270', 'procedure_227194', 'icu_stay_duration', 'procedure_225400', 'procedure_221223', 'procedure_225792')
# % Combos Checked: 3440 out of 1512000 which is 0.22751300000000002%
