# %% [markdown]
# # Tuning Script

# %%
# Parameters subject to change in every script - involved in naming

MODEL = 'adabc'
PREPROCESSING = 'smote_normalise'
TUNER = 'yangzhoub'
OPTIMISED_METRIC = 'f1'

# %% [markdown]
# ---

# %%
# detect whether this is a google environment

COLAB_ENVIRONMENT = False

try:
    from google.colab import drive
    drive.mount('/content/drive')
    COLAB_ENVIRONMENT = True
except:
    pass
# Out:
# Mounted at /content/drive

# %%
import sys
import os
import pickle

if COLAB_ENVIRONMENT:
    home_directory = './drive/MyDrive/LAB/COMP90089__GroupWork__Py/' # my home directory is stored in ./LAB of google drive
    if MODEL == 'ebr':
        # !pip install interpret==0.5.0
    elif MODEL == 'cbr':
        # !pip install catboost
    elif MODEL in ['tf', 'mlp']:
        # !pip install PyTorch2Sklearn
    # !pip install JXAutoML
else:
    home_directory = '../../'

from JXAutoML.YangZhouB_10CV import YangZhouB_10CV as Tuner

import pandas as pd
# Out:
# Collecting JXAutoML
#   Downloading JXAutoML-0.4.4-py3-none-any.whl.metadata (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.2/67.2 kB 2.0 MB/s eta 0:00:00
# Downloading JXAutoML-0.4.4-py3-none-any.whl (52 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.1/52.1 kB 3.4 MB/s eta 0:00:00
# Installing collected packages: JXAutoML
# Successfully installed JXAutoML-0.4.4

# %%
# Parameters that are same for every script

FOLDS = 10  # we have decided to do 10 fold validation

SEED = 42

TASK_TYPE = 'Classification'  # this task is a classification task

# we have decided to tune features as hp
TUNE_FEATURES_AS_HYPERPARAMETERS = True

# %% [markdown]
# ---

# %%
# model to use to tune
from sklearn.ensemble import AdaBoostClassifier as clf

# what values to try for each hyperparameter
parameter_choices = {
    'n_estimators': (25, 50, 100, 200, 400, 800),
    'learning_rate': (0.0001, 0.001, 0.01, 0.1, 1, 10, 100),
    'algorithm': {'SAMME', 'SAMME.R'},

}

# what values to set non-tuneable parameters/hyperparameters
non_tunable_hyperparameters_dict = {
                                    'random_state': 42,
                                    }

# %% [markdown]
# ---

# %% [markdown]
# Read in and Prepare Data

# %%
# Import data and store as lists

train_x_list = []
train_y_list = []
val_x_list = []
val_y_list = []

for i in range(FOLDS):
    train_data = pd.read_csv(
        f'{home_directory}data/curated/modelling/{PREPROCESSING}/train_{i}.csv')
    val_data = pd.read_csv(
        f'{home_directory}data/curated/modelling/{PREPROCESSING}/val_{i}.csv')

    # get the correct rows for X and y
    train_x = train_data.drop(
        ['mortality_status', 'subject_id', 'hadm_id', 'stay_id'], axis=1)
    train_y = train_data['mortality_status']
    val_x = val_data.drop(
        ['mortality_status', 'subject_id', 'hadm_id', 'stay_id'], axis=1)
    val_y = val_data['mortality_status']

    train_x_list.append(train_x)
    train_y_list.append(train_y)
    val_x_list.append(val_x)
    val_y_list.append(val_y)

# %%
# Import feature importance ordering

with open(f'{home_directory}models/xgb_feature_importance_ordering_{PREPROCESSING}.pickle', 'rb') as f:
    feature_importance_ordering = pickle.load(f)

# %% [markdown]
# Set parameters

# %%
# initialisation
tuner = Tuner()

print('---')

# define what model we are tuning
tuner.read_in_model(clf, TASK_TYPE, optimised_metric=OPTIMISED_METRIC)

print('---')

# read in the data for training and validation
tuner.read_in_data(train_x_list, train_y_list, val_x_list, val_y_list)

print('---')

# set what hp values to tune
tuner.set_hyperparameters(parameter_choices)
# WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

# set up hp values that need to be changed from default but NOT to be tuned
tuner.set_non_tuneable_hyperparameters(non_tunable_hyperparameters_dict)

print('---')

# set up feature importance ordering

if TUNE_FEATURES_AS_HYPERPARAMETERS:
    tuner.set_features(feature_importance_ordering)
    # WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

try:  # try to read in previous results to continue tuning ...
    tuner.read_in_tuning_result_df(
        f'{home_directory}models/tuning/{TUNER}_{MODEL}_{PREPROCESSING}.csv')
except:
    print('No previous tuning data read in')

print('---')

# set up where to save the tuning result csv
tuner.set_tuning_result_saving_address(
    f'{home_directory}models/tuning/{TUNER}_{MODEL}_{PREPROCESSING}.csv')

print('---')

# set up where to save the current best model
tuner.set_best_model_saving_address(
    f'{home_directory}models/tmp_models/{TUNER}_{MODEL}_{PREPROCESSING}')
# Out:
# YangZhouB Initialised
# ---
# Successfully read in model <class 'sklearn.ensemble._weight_boosting.AdaBoostClassifier'>, which is a Classification model optimising for f1
# ---
# Read in Train X data list
# Read in Train y data list
# Read in Val X data list
# Read in Val y data list
# ---
# Successfully recorded hyperparameter choices
# ---
# Successfully recorded non_tuneable_hyperparameter choices
# ---
# Successfully recorded tuneable feature combination choices and updated relevant internal structures
# ---
# No previous tuning data read in
# ---
# Successfully set tuning output address
# ---
# Successfully set best model output address

# %%
# ignore warnings

import warnings
warnings.filterwarnings("ignore")

# %%
# begin tuning ... (or continue training)

tuner.tune()
# Out:
# BEGIN TUNING
#
#
# STAGE ZERO: Tune all Cruise combinations
#
#
# Trained and Tested combination 1 of 4032, taking 0.97 seconds to get val score of 0.0409:
#                 {'n_estimators': 25, 'learning_rate': 0.0001, 'algorithm': 'SAMME', 'features': 39},
#             Current best combo with val score 0.0409:
#                     {'n_estimators': 25, 'learning_rate': 0.0001, 'algorithm': 'SAMME', 'features': 39}
# Trained and Tested combination 2 of 4032, taking 0.08 seconds to get val score of 0.3109:
#                 {'n_estimators': 800, 'learning_rate': 100, 'algorithm': 'SAMME', 'features': 47},
#             Current best combo with val score 0.3109:
#                     {'n_estimators': 800, 'learning_rate': 100, 'algorithm': 'SAMME', 'features': 47}
# Trained and Tested combination 3 of 4032, taking 0.06 seconds to get val score of 0.3109:
#                 {'n_estimators': 25, 'learning_rate': 100, 'algorithm': 'SAMME', 'features': 30},
#             Current best combo with val score 0.3109:
#                     {'n_estimators': 800, 'learning_rate': 100, 'algorithm': 'SAMME', 'features': 47}
# Trained and Tested combination 4 of 4032, taking 0.05 seconds to get val score of 0.3109:
#                 {'n_estimators': 25, 'learning_rate': 100, 'algorithm': 'SAMME', 'features': 43},
#             Current best combo with val score 0.3109:
#                     {'n_estimators': 800, 'learning_rate': 100, 'algorithm': 'SAMME', 'features': 47}
# Trained and Tested combination 5 of 4032, taking 0.04 seconds to get val score of 0.3109:
#                 {'n_estimators': 800, 'learning_rate': 100, 'algorithm': 'SAMME', 'features': 35},
#             Current best combo with val score 0.3109:
#                     {'n_estimators': 800, 'learning_rate': 100, 'algorithm': 'SAMME', 'features': 47}
# Trained and Tested combination 6 of 4032, taking 9.26 seconds to get val score of 0.0224:
#                 {'n_estimators': 800, 'learning_rate': 0.0001, 'algorithm': 'SAMME.R', 'features': 30},
#             Current best combo with val score 0.3109:
#                     {'n_estimators': 800, 'learning_rate': 100, 'algorithm': 'SAMME', 'features': 47}
# Trained and Tested combination 7 of 4032, taking 0.03 seconds to get val score of 0.3109:
#                 {'n_estimators': 800, 'learning_rate': 100, 'algorithm': 'SAMME', 'features': 39},
#             Current best combo with val score 0.3109:
#                     {'n_estimators': 800, 'learning_rate': 100, 'algorithm': 'SAMME', 'features': 47}
# Trained and Tested combination 8 of 4032, taking 0.01 seconds to get val score of 0.204:
#                 {'n_estimators': 25, 'learning_rate': 100, 'algorithm': 'SAMME', 'features': 0},
#             Current best combo with val score 0.3109:
#                     {'n_estimators': 800, 'learning_rate': 100, 'algorithm': 'SAMME', 'features': 47}
# Trained and Tested combination 9 of 4032, taking 0.14 seconds to get val score of 0.01:
#                 {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME', 'features': 15},
#             Current best combo with val score 0.3109:
#                     {'n_estimators': 800, 'learning_rate': 100, 'algorithm': 'SAMME', 'features': 47}
# Trained and Tested combination 10 of 4032, taking 6.6 seconds to get val score of 0.0409:
#                 {'n_estimators': 800, 'learning_rate': 0.0001, 'algorithm': 'SAMME', 'features': 25},
#             Current best combo with val score 0.3109:
#                     {'n_estimators': 800, 'learning_rate': 100, 'algorithm': 'SAMME', 'features': 47}
# Trained and Tested combination 11 of 4032, taking 0.11 seconds to get val score of 0.3108:
#                 {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 0},
#             Current best combo with val score 0.3109:
#                     {'n_estimators': 800, 'learning_rate': 100, 'algorithm': 'SAMME', 'features': 47}
# Trained and Tested combination 12 of 4032, taking 0.2 seconds to get val score of 0.0:
#                 {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 10},
#             Current best combo with val score 0.3109:
#                     {'n_estimators': 800, 'learning_rate': 100, 'algorithm': 'SAMME', 'features': 47}
# Trained and Tested combination 13 of 4032, taking 0.17 seconds to get val score of 0.0409:
#                 {'n_estimators': 25, 'learning_rate': 0.0001, 'algorithm': 'SAMME', 'features': 20},
#             Current best combo with val score 0.3109:
#                     {'n_estimators': 800, 'learning_rate': 100, 'algorithm': 'SAMME', 'features': 47}
# Trained and Tested combination 14 of 4032, taking 0.09 seconds to get val score of 0.1209:
#                 {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME', 'features': 5},
#             Current best combo with val score 0.3109:
#                     {'n_estimators': 800, 'learning_rate': 100, 'algorithm': 'SAMME', 'features': 47}
# Trained and Tested combination 15 of 4032, taking 0.01 seconds to get val score of 0.3109:
#                 {'n_estimators': 25, 'learning_rate': 100, 'algorithm': 'SAMME', 'features': 10},
#             Current best combo with val score 0.3109:
#                     {'n_estimators': 800, 'learning_rate': 100, 'algorithm': 'SAMME', 'features': 47}
# Trained and Tested combination 16 of 4032, taking 0.23 seconds to get val score of 0.0409:
#                 {'n_estimators': 25, 'learning_rate': 0.0001, 'algorithm': 'SAMME.R', 'features': 25},
#             Current best combo with val score 0.3109:
#                     {'n_estimators': 800, 'learning_rate': 100, 'algorithm': 'SAMME', 'features': 47}
# Trained and Tested combination 17 of 4032, taking 0.03 seconds to get val score of 0.3109:
#                 {'n_estimators': 25, 'learning_rate': 100, 'algorithm': 'SAMME', 'features': 39},
#             Current best combo with val score 0.3109:
#                     {'n_estimators': 800, 'learning_rate': 100, 'algorithm': 'SAMME', 'features': 47}
# Trained and Tested combination 18 of 4032, taking 12.22 seconds to get val score of 0.0033:
#                 {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME', 'features': 43},
#             Current best combo with val score 0.3109:
#                     {'n_estimators': 800, 'learning_rate': 100, 'algorithm': 'SAMME', 'features': 47}
# Trained and Tested combination 19 of 4032, taking 0.04 seconds to get val score of 0.3109:
#                 {'n_estimators': 800, 'learning_rate': 100, 'algorithm': 'SAMME.R', 'features': 30},
#             Current best combo with val score 0.3109:
#                     {'n_estimators': 800, 'learning_rate': 100, 'algorithm': 'SAMME', 'features': 47}
# Trained and Tested combination 20 of 4032, taking 13.82 seconds to get val score of 0.0224:
#                 {'n_estimators': 800, 'learning_rate': 0.0001, 'algorithm': 'SAMME.R', 'features': 47},
#             Current best combo with val score 0.3109:
#                     {'n_estimators': 800, 'learning_rate': 100, 'algorithm': 'SAMME', 'features': 47}
# Trained and Tested combination 21 of 4032, taking 0.04 seconds to get val score of 0.3109:
#                 {'n_estimators': 800, 'learning_rate': 100, 'algorithm': 'SAMME.R', 'features': 39},
#             Current best combo with val score 0.3109:
#                     {'n_estimators': 800, 'learning_rate': 100, 'algorithm': 'SAMME', 'features': 47}
# Trained and Tested combination 22 of 4032, taking 10.93 seconds to get val score of 0.0409:
#                 {'n_estimators': 800, 'learning_rate': 0.0001, 'algorithm': 'SAMME', 'features': 35},
#             Current best combo with val score 0.3109:
#                     {'n_estimators': 800, 'learning_rate': 100, 'algorithm': 'SAMME', 'features': 47}
# Trained and Tested combination 23 of 4032, taking 5.55 seconds to get val score of 0.0224:
#                 {'n_estimators': 800, 'learning_rate': 0.0001, 'algorithm': 'SAMME.R', 'features': 10},
#             Current best combo with val score 0.3109:
#                     {'n_estimators': 800, 'learning_rate': 100, 'algorithm': 'SAMME', 'features': 47}
# Trained and Tested combination 24 of 4032, taking 0.39 seconds to get val score of 0.0409:
#                 {'n_estimators': 25, 'learning_rate': 0.0001, 'algorithm': 'SAMME', 'features': 47},
#             Current best combo with val score 0.3109:
#                     {'n_estimators': 800, 'learning_rate': 100, 'algorithm': 'SAMME', 'features': 47}
# Trained and Tested combination 25 of 4032, taking 1.81 seconds to get val score of 0.3108:
#                 {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME', 'features': 0},
#             Current best combo with val score 0.3109:
#                     {'n_estimators': 800, 'learning_rate': 100, 'algorithm': 'SAMME', 'features': 47}
# Trained and Tested combination 26 of 4032, taking 0.02 seconds to get val score of 0.3109:
#                 {'n_estimators': 800, 'learning_rate': 100, 'algorithm': 'SAMME', 'features': 30},
#             Current best combo with val score 0.3109:
#                     {'n_estimators': 800, 'learning_rate': 100, 'algorithm': 'SAMME', 'features': 47}
# Trained and Tested combination 27 of 4032, taking 12.62 seconds to get val score of 0.0127:
#                 {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 43},
#             Current best combo with val score 0.3109:
#                     {'n_estimators': 800, 'learning_rate': 100, 'algorithm': 'SAMME', 'features': 47}
# Trained and Tested combination 28 of 4032, taking 0.05 seconds to get val score of 0.3109:
#                 {'n_estimators': 800, 'learning_rate': 100, 'algorithm': 'SAMME.R', 'features': 47},
#             Current best combo with val score 0.3109:
#                     {'n_estimators': 800, 'learning_rate': 100, 'algorithm': 'SAMME', 'features': 47}
# Trained and Tested combination 29 of 4032, taking 9.78 seconds to get val score of 0.0346:
#                 {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 30},
#             Current best combo with val score 0.3109:
#                     {'n_estimators': 800, 'learning_rate': 100, 'algorithm': 'SAMME', 'features': 47}
# Trained and Tested combination 30 of 4032, taking 4.48 seconds to get val score of 0.0996:
#                 {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 5},
#             Current best combo with val score 0.3109:
#                     {'n_estimators': 800, 'learning_rate': 100, 'algorithm': 'SAMME', 'features': 47}
# Trained and Tested combination 31 of 4032, taking 0.3 seconds to get val score of 0.0409:
#                 {'n_estimators': 25, 'learning_rate': 0.0001, 'algorithm': 'SAMME.R', 'features': 35},
#             Current best combo with val score 0.3109:
#                     {'n_estimators': 800, 'learning_rate': 100, 'algorithm': 'SAMME', 'features': 47}
# Trained and Tested combination 32 of 4032, taking 0.01 seconds to get val score of 0.31:
#                 {'n_estimators': 800, 'learning_rate': 100, 'algorithm': 'SAMME.R', 'features': 5},
#             Current best combo with val score 0.3109:
#                     {'n_estimators': 800, 'learning_rate': 100, 'algorithm': 'SAMME', 'features': 47}
# Trained and Tested combination 33 of 4032, taking 0.01 seconds to get val score of 0.3117:
#                 {'n_estimators': 25, 'learning_rate': 100, 'algorithm': 'SAMME.R', 'features': 0},
#             Current best combo with val score 0.3117:
#                     {'n_estimators': 25, 'learning_rate': 100, 'algorithm': 'SAMME.R', 'features': 0}
# Trained and Tested combination 34 of 4032, taking 0.02 seconds to get val score of 0.3109:
#                 {'n_estimators': 800, 'learning_rate': 100, 'algorithm': 'SAMME.R', 'features': 25},
#             Current best combo with val score 0.3117:
#                     {'n_estimators': 25, 'learning_rate': 100, 'algorithm': 'SAMME.R', 'features': 0}
# Trained and Tested combination 35 of 4032, taking 0.51 seconds to get val score of 0.0409:
#                 {'n_estimators': 25, 'learning_rate': 0.0001, 'algorithm': 'SAMME', 'features': 43},
#             Current best combo with val score 0.3117:
#                     {'n_estimators': 25, 'learning_rate': 100, 'algorithm': 'SAMME.R', 'features': 0}
# Trained and Tested combination 36 of 4032, taking 0.02 seconds to get val score of 0.3098:
#                 {'n_estimators': 25, 'learning_rate': 100, 'algorithm': 'SAMME', 'features': 5},
#             Current best combo with val score 0.3117:
#                     {'n_estimators': 25, 'learning_rate': 100, 'algorithm': 'SAMME.R', 'features': 0}
# Trained and Tested combination 37 of 4032, taking 12.88 seconds to get val score of 0.0409:
#                 {'n_estimators': 800, 'learning_rate': 0.0001, 'algorithm': 'SAMME', 'features': 43},
#             Current best combo with val score 0.3117:
#                     {'n_estimators': 25, 'learning_rate': 100, 'algorithm': 'SAMME.R', 'features': 0}
# Trained and Tested combination 38 of 4032, taking 11.51 seconds to get val score of 0.0033:
#                 {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME', 'features': 39},
#             Current best combo with val score 0.3117:
#                     {'n_estimators': 25, 'learning_rate': 100, 'algorithm': 'SAMME.R', 'features': 0}
# Trained and Tested combination 39 of 4032, taking 0.37 seconds to get val score of 0.0409:
#                 {'n_estimators': 25, 'learning_rate': 0.0001, 'algorithm': 'SAMME.R', 'features': 30},
#             Current best combo with val score 0.3117:
#                     {'n_estimators': 25, 'learning_rate': 100, 'algorithm': 'SAMME.R', 'features': 0}
# Trained and Tested combination 40 of 4032, taking 0.01 seconds to get val score of 0.3117:
#                 {'n_estimators': 800, 'learning_rate': 100, 'algorithm': 'SAMME.R', 'features': 0},
#             Current best combo with val score 0.3117:
#                     {'n_estimators': 25, 'learning_rate': 100, 'algorithm': 'SAMME.R', 'features': 0}
# Trained and Tested combination 41 of 4032, taking 0.04 seconds to get val score of 0.3109:
#                 {'n_estimators': 25, 'learning_rate': 100, 'algorithm': 'SAMME', 'features': 35},
#             Current best combo with val score 0.3117:
#                     {'n_estimators': 25, 'learning_rate': 100, 'algorithm': 'SAMME.R', 'features': 0}
# Trained and Tested combination 42 of 4032, taking 5.41 seconds to get val score of 0.0224:
#                 {'n_estimators': 800, 'learning_rate': 0.0001, 'algorithm': 'SAMME.R', 'features': 20},
#             Current best combo with val score 0.3117:
#                     {'n_estimators': 25, 'learning_rate': 100, 'algorithm': 'SAMME.R', 'features': 0}
# Trained and Tested combination 43 of 4032, taking 11.92 seconds to get val score of 0.0224:
#                 {'n_estimators': 800, 'learning_rate': 0.0001, 'algorithm': 'SAMME.R', 'features': 39},
#             Current best combo with val score 0.3117:
#                     {'n_estimators': 25, 'learning_rate': 100, 'algorithm': 'SAMME.R', 'features': 0}
# Trained and Tested combination 44 of 4032, taking 10.84 seconds to get val score of 0.0033:
#                 {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME', 'features': 35},
#             Current best combo with val score 0.3117:
#                     {'n_estimators': 25, 'learning_rate': 100, 'algorithm': 'SAMME.R', 'features': 0}
# Trained and Tested combination 45 of 4032, taking 0.37 seconds to get val score of 0.0:
#                 {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 47},
#             Current best combo with val score 0.3117:
#                     {'n_estimators': 25, 'learning_rate': 100, 'algorithm': 'SAMME.R', 'features': 0}
# Trained and Tested combination 46 of 4032, taking 8.39 seconds to get val score of 0.0224:
#                 {'n_estimators': 800, 'learning_rate': 0.0001, 'algorithm': 'SAMME.R', 'features': 25},
#             Current best combo with val score 0.3117:
#                     {'n_estimators': 25, 'learning_rate': 100, 'algorithm': 'SAMME.R', 'features': 0}
# Trained and Tested combination 47 of 4032, taking 0.16 seconds to get val score of 0.01:
#                 {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME', 'features': 20},
#             Current best combo with val score 0.3117:
#                     {'n_estimators': 25, 'learning_rate': 100, 'algorithm': 'SAMME.R', 'features': 0}
# Trained and Tested combination 48 of 4032, taking 0.52 seconds to get val score of 0.01:
#                 {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME', 'features': 47},
#             Current best combo with val score 0.3117:
#                     {'n_estimators': 25, 'learning_rate': 100, 'algorithm': 'SAMME.R', 'features': 0}
# Trained and Tested combination 49 of 4032, taking 1.81 seconds to get val score of 0.3108:
#                 {'n_estimators': 800, 'learning_rate': 0.0001, 'algorithm': 'SAMME', 'features': 0},
#             Current best combo with val score 0.3117:
#                     {'n_estimators': 25, 'learning_rate': 100, 'algorithm': 'SAMME.R', 'features': 0}
# Trained and Tested combination 50 of 4032, taking 0.32 seconds to get val score of 0.0:
#                 {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 25},
#             Current best combo with val score 0.3117:
#                     {'n_estimators': 25, 'learning_rate': 100, 'algorithm': 'SAMME.R', 'features': 0}
# Trained and Tested combination 51 of 4032, taking 5.49 seconds to get val score of 0.3034:
#                 {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 15},
#             Current best combo with val score 0.3117:
#                     {'n_estimators': 25, 'learning_rate': 100, 'algorithm': 'SAMME.R', 'features': 0}
# Trained and Tested combination 52 of 4032, taking 0.26 seconds to get val score of 0.0409:
#                 {'n_estimators': 25, 'learning_rate': 0.0001, 'algorithm': 'SAMME', 'features': 30},
#             Current best combo with val score 0.3117:
#                     {'n_estimators': 25, 'learning_rate': 100, 'algorithm': 'SAMME.R', 'features': 0}
# Trained and Tested combination 53 of 4032, taking 7.05 seconds to get val score of 0.3099:
#                 {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 20},
#             Current best combo with val score 0.3117:
#                     {'n_estimators': 25, 'learning_rate': 100, 'algorithm': 'SAMME.R', 'features': 0}
# Trained and Tested combination 54 of 4032, taking 3.57 seconds to get val score of 0.0409:
#                 {'n_estimators': 800, 'learning_rate': 0.0001, 'algorithm': 'SAMME', 'features': 10},
#             Current best combo with val score 0.3117:
#                     {'n_estimators': 25, 'learning_rate': 100, 'algorithm': 'SAMME.R', 'features': 0}
# Trained and Tested combination 55 of 4032, taking 13.44 seconds to get val score of 0.0097:
#                 {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 47},
#             Current best combo with val score 0.3117:
#                     {'n_estimators': 25, 'learning_rate': 100, 'algorithm': 'SAMME.R', 'features': 0}
# Trained and Tested combination 56 of 4032, taking 3.76 seconds to get val score of 0.0:
#                 {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME', 'features': 10},
#             Current best combo with val score 0.3117:
#                     {'n_estimators': 25, 'learning_rate': 100, 'algorithm': 'SAMME.R', 'features': 0}
# Trained and Tested combination 57 of 4032, taking 2.06 seconds to get val score of 0.3108:
#                 {'n_estimators': 800, 'learning_rate': 0.0001, 'algorithm': 'SAMME.R', 'features': 0},
#             Current best combo with val score 0.3117:
#                     {'n_estimators': 25, 'learning_rate': 100, 'algorithm': 'SAMME.R', 'features': 0}
# Trained and Tested combination 58 of 4032, taking 0.12 seconds to get val score of 0.0409:
#                 {'n_estimators': 25, 'learning_rate': 0.0001, 'algorithm': 'SAMME.R', 'features': 10},
#             Current best combo with val score 0.3117:
#                     {'n_estimators': 25, 'learning_rate': 100, 'algorithm': 'SAMME.R', 'features': 0}
# Trained and Tested combination 59 of 4032, taking 0.11 seconds to get val score of 0.0409:
#                 {'n_estimators': 25, 'learning_rate': 0.0001, 'algorithm': 'SAMME', 'features': 10},
#             Current best combo with val score 0.3117:
#                     {'n_estimators': 25, 'learning_rate': 100, 'algorithm': 'SAMME.R', 'features': 0}
# Trained and Tested combination 60 of 4032, taking 12.56 seconds to get val score of 0.0033:
#                 {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME', 'features': 47},
#             Current best combo with val score 0.3117:
#                     {'n_estimators': 25, 'learning_rate': 100, 'algorithm': 'SAMME.R', 'features': 0}
# Trained and Tested combination 61 of 4032, taking 0.37 seconds to get val score of 0.0409:
#                 {'n_estimators': 25, 'learning_rate': 0.0001, 'algorithm': 'SAMME.R', 'features': 43},
#             Current best combo with val score 0.3117:
#                     {'n_estimators': 25, 'learning_rate': 100, 'algorithm': 'SAMME.R', 'features': 0}
# Trained and Tested combination 62 of 4032, taking 0.27 seconds to get val score of 0.0:
#                 {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 30},
#             Current best combo with val score 0.3117:
#                     {'n_estimators': 25, 'learning_rate': 100, 'algorithm': 'SAMME.R', 'features': 0}
# Trained and Tested combination 63 of 4032, taking 0.02 seconds to get val score of 0.3109:
#                 {'n_estimators': 25, 'learning_rate': 100, 'algorithm': 'SAMME.R', 'features': 20},
#             Current best combo with val score 0.3117:
#                     {'n_estimators': 25, 'learning_rate': 100, 'algorithm': 'SAMME.R', 'features': 0}
# Trained and Tested combination 64 of 4032, taking 0.41 seconds to get val score of 0.01:
#                 {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME', 'features': 35},
#             Current best combo with val score 0.3117:
#                     {'n_estimators': 25, 'learning_rate': 100, 'algorithm': 'SAMME.R', 'features': 0}
# Trained and Tested combination 65 of 4032, taking 0.34 seconds to get val score of 0.0:
#                 {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 39},
#             Current best combo with val score 0.3117:
#                     {'n_estimators': 25, 'learning_rate': 100, 'algorithm': 'SAMME.R', 'features': 0}
# Trained and Tested combination 66 of 4032, taking 0.01 seconds to get val score of 0.3109:
#                 {'n_estimators': 25, 'learning_rate': 100, 'algorithm': 'SAMME.R', 'features': 15},
#             Current best combo with val score 0.3117:
#                     {'n_estimators': 25, 'learning_rate': 100, 'algorithm': 'SAMME.R', 'features': 0}
# Trained and Tested combination 67 of 4032, taking 0.15 seconds to get val score of 0.0033:
#                 {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 15},
#             Current best combo with val score 0.3117:
#                     {'n_estimators': 25, 'learning_rate': 100, 'algorithm': 'SAMME.R', 'features': 0}
# Trained and Tested combination 68 of 4032, taking 7.05 seconds to get val score of 0.0371:
#                 {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME', 'features': 25},
#             Current best combo with val score 0.3117:
#                     {'n_estimators': 25, 'learning_rate': 100, 'algorithm': 'SAMME.R', 'features': 0}
# Trained and Tested combination 69 of 4032, taking 0.41 seconds to get val score of 0.01:
#                 {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME', 'features': 39},
#             Current best combo with val score 0.3117:
#                     {'n_estimators': 25, 'learning_rate': 100, 'algorithm': 'SAMME.R', 'features': 0}
# Trained and Tested combination 70 of 4032, taking 5.21 seconds to get val score of 0.0409:
#                 {'n_estimators': 800, 'learning_rate': 0.0001, 'algorithm': 'SAMME', 'features': 20},
#             Current best combo with val score 0.3117:
#                     {'n_estimators': 25, 'learning_rate': 100, 'algorithm': 'SAMME.R', 'features': 0}
# Trained and Tested combination 71 of 4032, taking 0.28 seconds to get val score of 0.0033:
#                 {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 20},
#             Current best combo with val score 0.3117:
#                     {'n_estimators': 25, 'learning_rate': 100, 'algorithm': 'SAMME.R', 'features': 0}
# Trained and Tested combination 72 of 4032, taking 0.11 seconds to get val score of 0.0869:
#                 {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 5},
#             Current best combo with val score 0.3117:
#                     {'n_estimators': 25, 'learning_rate': 100, 'algorithm': 'SAMME.R', 'features': 0}
# Trained and Tested combination 73 of 4032, taking 0.37 seconds to get val score of 0.0:
#                 {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 43},
#             Current best combo with val score 0.3117:
#                     {'n_estimators': 25, 'learning_rate': 100, 'algorithm': 'SAMME.R', 'features': 0}
# Trained and Tested combination 74 of 4032, taking 0.1 seconds to get val score of 0.0655:
#                 {'n_estimators': 25, 'learning_rate': 0.0001, 'algorithm': 'SAMME', 'features': 5},
#             Current best combo with val score 0.3117:
#                     {'n_estimators': 25, 'learning_rate': 100, 'algorithm': 'SAMME.R', 'features': 0}
# Trained and Tested combination 75 of 4032, taking 6.47 seconds to get val score of 0.1633:
#                 {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME', 'features': 20},
#             Current best combo with val score 0.3117:
#                     {'n_estimators': 25, 'learning_rate': 100, 'algorithm': 'SAMME.R', 'features': 0}
# Trained and Tested combination 76 of 4032, taking 0.03 seconds to get val score of 0.3109:
#                 {'n_estimators': 800, 'learning_rate': 100, 'algorithm': 'SAMME', 'features': 43},
#             Current best combo with val score 0.3117:
#                     {'n_estimators': 25, 'learning_rate': 100, 'algorithm': 'SAMME.R', 'features': 0}
# Trained and Tested combination 77 of 4032, taking 0.01 seconds to get val score of 0.204:
#                 {'n_estimators': 800, 'learning_rate': 100, 'algorithm': 'SAMME', 'features': 0},
#             Current best combo with val score 0.3117:
#                     {'n_estimators': 25, 'learning_rate': 100, 'algorithm': 'SAMME.R', 'features': 0}
# Trained and Tested combination 78 of 4032, taking 7.51 seconds to get val score of 0.3474:
#                 {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 25},
#             Current best combo with val score 0.3474:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 25}
# Trained and Tested combination 79 of 4032, taking 4.55 seconds to get val score of 0.0409:
#                 {'n_estimators': 800, 'learning_rate': 0.0001, 'algorithm': 'SAMME', 'features': 15},
#             Current best combo with val score 0.3474:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 25}
# Trained and Tested combination 80 of 4032, taking 0.08 seconds to get val score of 0.3108:
#                 {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME', 'features': 0},
#             Current best combo with val score 0.3474:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 25}
# Trained and Tested combination 81 of 4032, taking 13.07 seconds to get val score of 0.0409:
#                 {'n_estimators': 800, 'learning_rate': 0.0001, 'algorithm': 'SAMME', 'features': 47},
#             Current best combo with val score 0.3474:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 25}
# Trained and Tested combination 82 of 4032, taking 0.02 seconds to get val score of 0.3109:
#                 {'n_estimators': 800, 'learning_rate': 100, 'algorithm': 'SAMME', 'features': 25},
#             Current best combo with val score 0.3474:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 25}
# Trained and Tested combination 83 of 4032, taking 0.01 seconds to get val score of 0.3109:
#                 {'n_estimators': 800, 'learning_rate': 100, 'algorithm': 'SAMME', 'features': 15},
#             Current best combo with val score 0.3474:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 25}
# Trained and Tested combination 84 of 4032, taking 0.02 seconds to get val score of 0.3109:
#                 {'n_estimators': 25, 'learning_rate': 100, 'algorithm': 'SAMME', 'features': 20},
#             Current best combo with val score 0.3474:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 25}
# Trained and Tested combination 85 of 4032, taking 5.08 seconds to get val score of 0.0:
#                 {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 10},
#             Current best combo with val score 0.3474:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 25}
# Trained and Tested combination 86 of 4032, taking 0.07 seconds to get val score of 0.3108:
#                 {'n_estimators': 25, 'learning_rate': 0.0001, 'algorithm': 'SAMME.R', 'features': 0},
#             Current best combo with val score 0.3474:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 25}
# Trained and Tested combination 87 of 4032, taking 0.21 seconds to get val score of 0.01:
#                 {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME', 'features': 25},
#             Current best combo with val score 0.3474:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 25}
# Trained and Tested combination 88 of 4032, taking 0.02 seconds to get val score of 0.3109:
#                 {'n_estimators': 800, 'learning_rate': 100, 'algorithm': 'SAMME.R', 'features': 20},
#             Current best combo with val score 0.3474:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 25}
# Trained and Tested combination 89 of 4032, taking 11.85 seconds to get val score of 0.013:
#                 {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 39},
#             Current best combo with val score 0.3474:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 25}
# Trained and Tested combination 90 of 4032, taking 0.34 seconds to get val score of 0.0409:
#                 {'n_estimators': 25, 'learning_rate': 0.0001, 'algorithm': 'SAMME.R', 'features': 39},
#             Current best combo with val score 0.3474:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 25}
# Trained and Tested combination 91 of 4032, taking 0.01 seconds to get val score of 0.3109:
#                 {'n_estimators': 800, 'learning_rate': 100, 'algorithm': 'SAMME', 'features': 10},
#             Current best combo with val score 0.3474:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 25}
# Trained and Tested combination 92 of 4032, taking 11.01 seconds to get val score of 0.0283:
#                 {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 35},
#             Current best combo with val score 0.3474:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 25}
# Trained and Tested combination 93 of 4032, taking 0.02 seconds to get val score of 0.3109:
#                 {'n_estimators': 25, 'learning_rate': 100, 'algorithm': 'SAMME.R', 'features': 30},
#             Current best combo with val score 0.3474:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 25}
# Trained and Tested combination 94 of 4032, taking 10.88 seconds to get val score of 0.0409:
#                 {'n_estimators': 800, 'learning_rate': 0.0001, 'algorithm': 'SAMME', 'features': 39},
#             Current best combo with val score 0.3474:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 25}
# Trained and Tested combination 95 of 4032, taking 0.02 seconds to get val score of 0.3098:
#                 {'n_estimators': 800, 'learning_rate': 100, 'algorithm': 'SAMME', 'features': 5},
#             Current best combo with val score 0.3474:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 25}
# Trained and Tested combination 96 of 4032, taking 8.18 seconds to get val score of 0.0409:
#                 {'n_estimators': 800, 'learning_rate': 0.0001, 'algorithm': 'SAMME', 'features': 30},
#             Current best combo with val score 0.3474:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 25}
# Trained and Tested combination 97 of 4032, taking 0.05 seconds to get val score of 0.3109:
#                 {'n_estimators': 25, 'learning_rate': 100, 'algorithm': 'SAMME.R', 'features': 47},
#             Current best combo with val score 0.3474:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 25}
# Trained and Tested combination 98 of 4032, taking 0.17 seconds to get val score of 0.0409:
#                 {'n_estimators': 25, 'learning_rate': 0.0001, 'algorithm': 'SAMME.R', 'features': 20},
#             Current best combo with val score 0.3474:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 25}
# Trained and Tested combination 99 of 4032, taking 4.29 seconds to get val score of 0.0444:
#                 {'n_estimators': 800, 'learning_rate': 0.0001, 'algorithm': 'SAMME.R', 'features': 5},
#             Current best combo with val score 0.3474:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 25}
# Trained and Tested combination 100 of 4032, taking 0.02 seconds to get val score of 0.3109:
#                 {'n_estimators': 800, 'learning_rate': 100, 'algorithm': 'SAMME', 'features': 20},
#             Current best combo with val score 0.3474:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 25}
# Trained and Tested combination 101 of 4032, taking 0.3 seconds to get val score of 0.0:
#                 {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 35},
#             Current best combo with val score 0.3474:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 25}
# Trained and Tested combination 102 of 4032, taking 0.03 seconds to get val score of 0.3109:
#                 {'n_estimators': 25, 'learning_rate': 100, 'algorithm': 'SAMME.R', 'features': 39},
#             Current best combo with val score 0.3474:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 25}
# Trained and Tested combination 103 of 4032, taking 13.31 seconds to get val score of 0.0224:
#                 {'n_estimators': 800, 'learning_rate': 0.0001, 'algorithm': 'SAMME.R', 'features': 43},
#             Current best combo with val score 0.3474:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 25}
# Trained and Tested combination 104 of 4032, taking 0.03 seconds to get val score of 0.3109:
#                 {'n_estimators': 25, 'learning_rate': 100, 'algorithm': 'SAMME.R', 'features': 35},
#             Current best combo with val score 0.3474:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 25}
# Trained and Tested combination 105 of 4032, taking 3.69 seconds to get val score of 0.0787:
#                 {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME', 'features': 5},
#             Current best combo with val score 0.3474:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 25}
# Trained and Tested combination 106 of 4032, taking 0.04 seconds to get val score of 0.3109:
#                 {'n_estimators': 25, 'learning_rate': 100, 'algorithm': 'SAMME', 'features': 47},
#             Current best combo with val score 0.3474:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 25}
# Trained and Tested combination 107 of 4032, taking 0.02 seconds to get val score of 0.3109:
#                 {'n_estimators': 25, 'learning_rate': 100, 'algorithm': 'SAMME', 'features': 25},
#             Current best combo with val score 0.3474:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 25}
# Trained and Tested combination 108 of 4032, taking 0.03 seconds to get val score of 0.3109:
#                 {'n_estimators': 25, 'learning_rate': 100, 'algorithm': 'SAMME.R', 'features': 43},
#             Current best combo with val score 0.3474:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 25}
# Trained and Tested combination 109 of 4032, taking 0.26 seconds to get val score of 0.01:
#                 {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME', 'features': 30},
#             Current best combo with val score 0.3474:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 25}
# Trained and Tested combination 110 of 4032, taking 0.3 seconds to get val score of 0.0409:
#                 {'n_estimators': 25, 'learning_rate': 0.0001, 'algorithm': 'SAMME', 'features': 25},
#             Current best combo with val score 0.3474:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 25}
# Trained and Tested combination 111 of 4032, taking 0.16 seconds to get val score of 0.0655:
#                 {'n_estimators': 25, 'learning_rate': 0.0001, 'algorithm': 'SAMME.R', 'features': 5},
#             Current best combo with val score 0.3474:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 25}
# Trained and Tested combination 112 of 4032, taking 0.06 seconds to get val score of 0.3108:
#                 {'n_estimators': 25, 'learning_rate': 0.0001, 'algorithm': 'SAMME', 'features': 0},
#             Current best combo with val score 0.3474:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 25}
# Trained and Tested combination 113 of 4032, taking 0.01 seconds to get val score of 0.3109:
#                 {'n_estimators': 800, 'learning_rate': 100, 'algorithm': 'SAMME.R', 'features': 10},
#             Current best combo with val score 0.3474:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 25}
# Trained and Tested combination 114 of 4032, taking 2.71 seconds to get val score of 0.3108:
#                 {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 0},
#             Current best combo with val score 0.3474:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 25}
# Trained and Tested combination 115 of 4032, taking 0.01 seconds to get val score of 0.3109:
#                 {'n_estimators': 25, 'learning_rate': 100, 'algorithm': 'SAMME', 'features': 15},
#             Current best combo with val score 0.3474:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 25}
# Trained and Tested combination 116 of 4032, taking 0.01 seconds to get val score of 0.31:
#                 {'n_estimators': 25, 'learning_rate': 100, 'algorithm': 'SAMME.R', 'features': 5},
#             Current best combo with val score 0.3474:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 25}
# Trained and Tested combination 117 of 4032, taking 4.21 seconds to get val score of 0.0655:
#                 {'n_estimators': 800, 'learning_rate': 0.0001, 'algorithm': 'SAMME', 'features': 5},
#             Current best combo with val score 0.3474:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 25}
# Trained and Tested combination 118 of 4032, taking 0.11 seconds to get val score of 0.01:
#                 {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME', 'features': 10},
#             Current best combo with val score 0.3474:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 25}
# Trained and Tested combination 119 of 4032, taking 0.02 seconds to get val score of 0.3109:
#                 {'n_estimators': 800, 'learning_rate': 100, 'algorithm': 'SAMME.R', 'features': 15},
#             Current best combo with val score 0.3474:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 25}
# Trained and Tested combination 120 of 4032, taking 0.03 seconds to get val score of 0.3109:
#                 {'n_estimators': 800, 'learning_rate': 100, 'algorithm': 'SAMME.R', 'features': 43},
#             Current best combo with val score 0.3474:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 25}
# Trained and Tested combination 121 of 4032, taking 0.02 seconds to get val score of 0.3109:
#                 {'n_estimators': 25, 'learning_rate': 100, 'algorithm': 'SAMME.R', 'features': 25},
#             Current best combo with val score 0.3474:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 25}
# Trained and Tested combination 122 of 4032, taking 0.38 seconds to get val score of 0.01:
#                 {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME', 'features': 43},
#             Current best combo with val score 0.3474:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 25}
# Trained and Tested combination 123 of 4032, taking 4.24 seconds to get val score of 0.1482:
#                 {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME', 'features': 15},
#             Current best combo with val score 0.3474:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 25}
# Trained and Tested combination 124 of 4032, taking 0.14 seconds to get val score of 0.0409:
#                 {'n_estimators': 25, 'learning_rate': 0.0001, 'algorithm': 'SAMME', 'features': 15},
#             Current best combo with val score 0.3474:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 25}
# Trained and Tested combination 125 of 4032, taking 0.15 seconds to get val score of 0.0409:
#                 {'n_estimators': 25, 'learning_rate': 0.0001, 'algorithm': 'SAMME.R', 'features': 15},
#             Current best combo with val score 0.3474:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 25}
# Trained and Tested combination 126 of 4032, taking 5.45 seconds to get val score of 0.0224:
#                 {'n_estimators': 800, 'learning_rate': 0.0001, 'algorithm': 'SAMME.R', 'features': 15},
#             Current best combo with val score 0.3474:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 25}
# Trained and Tested combination 127 of 4032, taking 0.02 seconds to get val score of 0.3109:
#                 {'n_estimators': 25, 'learning_rate': 100, 'algorithm': 'SAMME.R', 'features': 10},
#             Current best combo with val score 0.3474:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 25}
# Trained and Tested combination 128 of 4032, taking 0.37 seconds to get val score of 0.0409:
#                 {'n_estimators': 25, 'learning_rate': 0.0001, 'algorithm': 'SAMME.R', 'features': 47},
#             Current best combo with val score 0.3474:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 25}
# Trained and Tested combination 129 of 4032, taking 0.3 seconds to get val score of 0.0409:
#                 {'n_estimators': 25, 'learning_rate': 0.0001, 'algorithm': 'SAMME', 'features': 35},
#             Current best combo with val score 0.3474:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 25}
# Trained and Tested combination 130 of 4032, taking 9.59 seconds to get val score of 0.0224:
#                 {'n_estimators': 800, 'learning_rate': 0.0001, 'algorithm': 'SAMME.R', 'features': 35},
#             Current best combo with val score 0.3474:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 25}
# Trained and Tested combination 131 of 4032, taking 1.71 seconds to get val score of 0.0256:
#                 {'n_estimators': 200, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 24},
#             Current best combo with val score 0.3474:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 25}
# Trained and Tested combination 132 of 4032, taking 9.67 seconds to get val score of 0.0033:
#                 {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME', 'features': 30},
#             Current best combo with val score 0.3474:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 25}
# Trained and Tested combination 133 of 4032, taking 0.03 seconds to get val score of 0.3109:
#                 {'n_estimators': 800, 'learning_rate': 100, 'algorithm': 'SAMME.R', 'features': 35},
#             Current best combo with val score 0.3474:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 25}
#
#
# STAGE ONE: Begin initial Guidance system
#
#
# Guidance: initial round
#
# 	round 0 iteration:  0
#
# Trained and Tested combination 134 of 4032, taking 1.22 seconds to get val score of 0.0067:
#                 {'n_estimators': 100, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 24},
#             Current best combo with val score 0.3474:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 25}
# Trained and Tested combination 135 of 4032, taking 3.6 seconds to get val score of 0.0283:
#                 {'n_estimators': 400, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 24},
#             Current best combo with val score 0.3474:
#                     {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 25}
# Trained and Tested combination 136 of 4032, taking 1.71 seconds to get val score of 0.0:
#                 {'n_estimators': 200, 'learning_rate': 0.01, 'algorithm': 'SAMME.R', 'features': 24},
#             Current best combo with val score 0.3474:
# ...
#             Current best combo (with val score 0.4474):
#                     {'n_estimators': 800, 'learning_rate': 1, 'algorithm': 'SAMME.R', 'features': 6}
#         Has trained 596 of 4032 combinations so far
# Already Trained and Tested combination (val score of 0.3109):
#             {'n_estimators': 50, 'learning_rate': 100, 'algorithm': 'SAMME', 'features': 11}
#             Current best combo (with val score 0.4474):
#                     {'n_estimators': 800, 'learning_rate': 1, 'algorithm': 'SAMME.R', 'features': 6}
#         Has trained 596 of 4032 combinations so far
# Trained and Tested combination 597 of 4032, taking 0.11 seconds to get val score of 0.0409:
#                 {'n_estimators': 25, 'learning_rate': 10, 'algorithm': 'SAMME', 'features': 11},
#             Current best combo with val score 0.4474:
#                     {'n_estimators': 800, 'learning_rate': 1, 'algorithm': 'SAMME.R', 'features': 6}
# Already Trained and Tested combination (val score of 0.3109):
#             {'n_estimators': 25, 'learning_rate': 100, 'algorithm': 'SAMME.R', 'features': 11}
#             Current best combo (with val score 0.4474):
#                     {'n_estimators': 800, 'learning_rate': 1, 'algorithm': 'SAMME.R', 'features': 6}
#         Has trained 597 of 4032 combinations so far
# Already Trained and Tested combination (val score of 0.3109):
#             {'n_estimators': 25, 'learning_rate': 100, 'algorithm': 'SAMME', 'features': 10}
#             Current best combo (with val score 0.4474):
#                     {'n_estimators': 800, 'learning_rate': 1, 'algorithm': 'SAMME.R', 'features': 6}
#         Has trained 597 of 4032 combinations so far
# Trained and Tested combination 598 of 4032, taking 0.01 seconds to get val score of 0.3109:
#                 {'n_estimators': 25, 'learning_rate': 100, 'algorithm': 'SAMME', 'features': 12},
#             Current best combo with val score 0.4474:
#                     {'n_estimators': 800, 'learning_rate': 1, 'algorithm': 'SAMME.R', 'features': 6}
# % Combos Checked Thus Far: 598 out of 4032 which is 14.831349%
# Cruising Coordrdinate 124 of 132
#
# Cruise suspended due to suspicious case
# Guidance: round 56
#
# 	round 56 iteration:  0
#
# % Combos Checked Thus Far: 598 out of 4032 which is 14.831349%
# Cruising Coordrdinate 125 of 132
#
# Cruising Coordrdinate 126 of 132
#
# Cruising Coordrdinate 127 of 132
#
# Cruising Coordrdinate 128 of 132
#
# Cruising Coordrdinate 129 of 132
#
# Cruise suspended due to suspicious case
# Guidance: round 57
#
# 	round 57 iteration:  0
#
# Trained and Tested combination 599 of 4032, taking 0.01 seconds to get val score of 0.3109:
#                 {'n_estimators': 400, 'learning_rate': 100, 'algorithm': 'SAMME', 'features': 10},
#             Current best combo with val score 0.4474:
#                     {'n_estimators': 800, 'learning_rate': 1, 'algorithm': 'SAMME.R', 'features': 6}
# Trained and Tested combination 600 of 4032, taking 3.93 seconds to get val score of 0.0409:
#                 {'n_estimators': 800, 'learning_rate': 10, 'algorithm': 'SAMME', 'features': 10},
#             Current best combo with val score 0.4474:
#                     {'n_estimators': 800, 'learning_rate': 1, 'algorithm': 'SAMME.R', 'features': 6}
# Already Trained and Tested combination (val score of 0.3109):
#             {'n_estimators': 800, 'learning_rate': 100, 'algorithm': 'SAMME.R', 'features': 10}
#             Current best combo (with val score 0.4474):
#                     {'n_estimators': 800, 'learning_rate': 1, 'algorithm': 'SAMME.R', 'features': 6}
#         Has trained 600 of 4032 combinations so far
# Trained and Tested combination 601 of 4032, taking 0.02 seconds to get val score of 0.3109:
#                 {'n_estimators': 800, 'learning_rate': 100, 'algorithm': 'SAMME', 'features': 9},
#             Current best combo with val score 0.4474:
#                     {'n_estimators': 800, 'learning_rate': 1, 'algorithm': 'SAMME.R', 'features': 6}
# Trained and Tested combination 602 of 4032, taking 0.02 seconds to get val score of 0.3109:
#                 {'n_estimators': 800, 'learning_rate': 100, 'algorithm': 'SAMME', 'features': 11},
#             Current best combo with val score 0.4474:
#                     {'n_estimators': 800, 'learning_rate': 1, 'algorithm': 'SAMME.R', 'features': 6}
# 	round 57 iteration:  1
#
# Trained and Tested combination 603 of 4032, taking 0.01 seconds to get val score of 0.3109:
#                 {'n_estimators': 200, 'learning_rate': 100, 'algorithm': 'SAMME', 'features': 10},
#             Current best combo with val score 0.4474:
#                     {'n_estimators': 800, 'learning_rate': 1, 'algorithm': 'SAMME.R', 'features': 6}
# Already Trained and Tested combination (val score of 0.3109):
#             {'n_estimators': 800, 'learning_rate': 100, 'algorithm': 'SAMME', 'features': 10}
#             Current best combo (with val score 0.4474):
#                     {'n_estimators': 800, 'learning_rate': 1, 'algorithm': 'SAMME.R', 'features': 6}
#         Has trained 603 of 4032 combinations so far
# Trained and Tested combination 604 of 4032, taking 1.78 seconds to get val score of 0.0409:
#                 {'n_estimators': 400, 'learning_rate': 10, 'algorithm': 'SAMME', 'features': 10},
#             Current best combo with val score 0.4474:
#                     {'n_estimators': 800, 'learning_rate': 1, 'algorithm': 'SAMME.R', 'features': 6}
# Trained and Tested combination 605 of 4032, taking 0.01 seconds to get val score of 0.3109:
#                 {'n_estimators': 400, 'learning_rate': 100, 'algorithm': 'SAMME.R', 'features': 10},
#             Current best combo with val score 0.4474:
#                     {'n_estimators': 800, 'learning_rate': 1, 'algorithm': 'SAMME.R', 'features': 6}
# Trained and Tested combination 606 of 4032, taking 0.02 seconds to get val score of 0.3109:
#                 {'n_estimators': 400, 'learning_rate': 100, 'algorithm': 'SAMME', 'features': 9},
#             Current best combo with val score 0.4474:
#                     {'n_estimators': 800, 'learning_rate': 1, 'algorithm': 'SAMME.R', 'features': 6}
# Trained and Tested combination 607 of 4032, taking 0.02 seconds to get val score of 0.3109:
#                 {'n_estimators': 400, 'learning_rate': 100, 'algorithm': 'SAMME', 'features': 11},
#             Current best combo with val score 0.4474:
#                     {'n_estimators': 800, 'learning_rate': 1, 'algorithm': 'SAMME.R', 'features': 6}
# Already Trained and Tested combination (val score of 0.3109):
#             {'n_estimators': 400, 'learning_rate': 100, 'algorithm': 'SAMME.R', 'features': 10}
#             Current best combo (with val score 0.4474):
#                     {'n_estimators': 800, 'learning_rate': 1, 'algorithm': 'SAMME.R', 'features': 6}
#         Has trained 607 of 4032 combinations so far
# Trained and Tested combination 608 of 4032, taking 3.78 seconds to get val score of 0.0409:
#                 {'n_estimators': 800, 'learning_rate': 10, 'algorithm': 'SAMME.R', 'features': 10},
#             Current best combo with val score 0.4474:
#                     {'n_estimators': 800, 'learning_rate': 1, 'algorithm': 'SAMME.R', 'features': 6}
# Already Trained and Tested combination (val score of 0.3109):
#             {'n_estimators': 800, 'learning_rate': 100, 'algorithm': 'SAMME', 'features': 10}
#             Current best combo (with val score 0.4474):
#                     {'n_estimators': 800, 'learning_rate': 1, 'algorithm': 'SAMME.R', 'features': 6}
#         Has trained 608 of 4032 combinations so far
# Trained and Tested combination 609 of 4032, taking 0.01 seconds to get val score of 0.3109:
#                 {'n_estimators': 800, 'learning_rate': 100, 'algorithm': 'SAMME.R', 'features': 9},
#             Current best combo with val score 0.4474:
#                     {'n_estimators': 800, 'learning_rate': 1, 'algorithm': 'SAMME.R', 'features': 6}
# Trained and Tested combination 610 of 4032, taking 0.01 seconds to get val score of 0.3109:
#                 {'n_estimators': 800, 'learning_rate': 100, 'algorithm': 'SAMME.R', 'features': 11},
#             Current best combo with val score 0.4474:
#                     {'n_estimators': 800, 'learning_rate': 1, 'algorithm': 'SAMME.R', 'features': 6}
# Already Trained and Tested combination (val score of 0.3109):
#             {'n_estimators': 400, 'learning_rate': 100, 'algorithm': 'SAMME', 'features': 9}
#             Current best combo (with val score 0.4474):
#                     {'n_estimators': 800, 'learning_rate': 1, 'algorithm': 'SAMME.R', 'features': 6}
#         Has trained 610 of 4032 combinations so far
# Trained and Tested combination 611 of 4032, taking 4.05 seconds to get val score of 0.0409:
#                 {'n_estimators': 800, 'learning_rate': 10, 'algorithm': 'SAMME', 'features': 9},
#             Current best combo with val score 0.4474:
#                     {'n_estimators': 800, 'learning_rate': 1, 'algorithm': 'SAMME.R', 'features': 6}
# Already Trained and Tested combination (val score of 0.3109):
#             {'n_estimators': 800, 'learning_rate': 100, 'algorithm': 'SAMME.R', 'features': 9}
#             Current best combo (with val score 0.4474):
#                     {'n_estimators': 800, 'learning_rate': 1, 'algorithm': 'SAMME.R', 'features': 6}
#         Has trained 611 of 4032 combinations so far
# Trained and Tested combination 612 of 4032, taking 0.02 seconds to get val score of 0.3109:
#                 {'n_estimators': 800, 'learning_rate': 100, 'algorithm': 'SAMME', 'features': 8},
#             Current best combo with val score 0.4474:
#                     {'n_estimators': 800, 'learning_rate': 1, 'algorithm': 'SAMME.R', 'features': 6}
# Already Trained and Tested combination (val score of 0.3109):
#             {'n_estimators': 800, 'learning_rate': 100, 'algorithm': 'SAMME', 'features': 10}
#             Current best combo (with val score 0.4474):
#                     {'n_estimators': 800, 'learning_rate': 1, 'algorithm': 'SAMME.R', 'features': 6}
#         Has trained 612 of 4032 combinations so far
# Already Trained and Tested combination (val score of 0.3109):
#             {'n_estimators': 400, 'learning_rate': 100, 'algorithm': 'SAMME', 'features': 11}
#             Current best combo (with val score 0.4474):
#                     {'n_estimators': 800, 'learning_rate': 1, 'algorithm': 'SAMME.R', 'features': 6}
#         Has trained 612 of 4032 combinations so far
# Trained and Tested combination 613 of 4032, taking 4.33 seconds to get val score of 0.0409:
#                 {'n_estimators': 800, 'learning_rate': 10, 'algorithm': 'SAMME', 'features': 11},
#             Current best combo with val score 0.4474:
#                     {'n_estimators': 800, 'learning_rate': 1, 'algorithm': 'SAMME.R', 'features': 6}
# Already Trained and Tested combination (val score of 0.3109):
#             {'n_estimators': 800, 'learning_rate': 100, 'algorithm': 'SAMME.R', 'features': 11}
#             Current best combo (with val score 0.4474):
#                     {'n_estimators': 800, 'learning_rate': 1, 'algorithm': 'SAMME.R', 'features': 6}
#         Has trained 613 of 4032 combinations so far
# Already Trained and Tested combination (val score of 0.3109):
#             {'n_estimators': 800, 'learning_rate': 100, 'algorithm': 'SAMME', 'features': 10}
#             Current best combo (with val score 0.4474):
#                     {'n_estimators': 800, 'learning_rate': 1, 'algorithm': 'SAMME.R', 'features': 6}
#         Has trained 613 of 4032 combinations so far
# Trained and Tested combination 614 of 4032, taking 0.01 seconds to get val score of 0.3109:
#                 {'n_estimators': 800, 'learning_rate': 100, 'algorithm': 'SAMME', 'features': 12},
#             Current best combo with val score 0.4474:
#                     {'n_estimators': 800, 'learning_rate': 1, 'algorithm': 'SAMME.R', 'features': 6}
# % Combos Checked Thus Far: 614 out of 4032 which is 15.228175%
# Cruising Coordrdinate 130 of 132
#
# Cruise suspended due to suspicious case
# Guidance: round 58
#
# 	round 58 iteration:  0
#
# % Combos Checked Thus Far: 614 out of 4032 which is 15.228175%
# Cruising Coordrdinate 131 of 132
#
# Cruising Coordrdinate 132 of 132
#
# FINAL STAGE: Begin final Guidance system
#
#
# Guidance: round FINAL
#
# 	round FINAL iteration:  0
#
# Already Trained and Tested combination (val score of 0.4023):
#             {'n_estimators': 400, 'learning_rate': 1, 'algorithm': 'SAMME.R', 'features': 6}
#             Current best combo (with val score 0.4474):
#                     {'n_estimators': 800, 'learning_rate': 1, 'algorithm': 'SAMME.R', 'features': 6}
#         Has trained 614 of 4032 combinations so far
# Already Trained and Tested combination (val score of 0.0996):
#             {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 6}
#             Current best combo (with val score 0.4474):
#                     {'n_estimators': 800, 'learning_rate': 1, 'algorithm': 'SAMME.R', 'features': 6}
#         Has trained 614 of 4032 combinations so far
# Already Trained and Tested combination (val score of 0.0655):
#             {'n_estimators': 800, 'learning_rate': 10, 'algorithm': 'SAMME.R', 'features': 6}
#             Current best combo (with val score 0.4474):
#                     {'n_estimators': 800, 'learning_rate': 1, 'algorithm': 'SAMME.R', 'features': 6}
#         Has trained 614 of 4032 combinations so far
# Already Trained and Tested combination (val score of 0.1702):
#             {'n_estimators': 800, 'learning_rate': 1, 'algorithm': 'SAMME', 'features': 6}
#             Current best combo (with val score 0.4474):
#                     {'n_estimators': 800, 'learning_rate': 1, 'algorithm': 'SAMME.R', 'features': 6}
#         Has trained 614 of 4032 combinations so far
# Already Trained and Tested combination (val score of 0.4466):
#             {'n_estimators': 800, 'learning_rate': 1, 'algorithm': 'SAMME.R', 'features': 5}
#             Current best combo (with val score 0.4474):
#                     {'n_estimators': 800, 'learning_rate': 1, 'algorithm': 'SAMME.R', 'features': 6}
#         Has trained 614 of 4032 combinations so far
# Already Trained and Tested combination (val score of 0.4287):
#             {'n_estimators': 800, 'learning_rate': 1, 'algorithm': 'SAMME.R', 'features': 7}
#             Current best combo (with val score 0.4474):
#                     {'n_estimators': 800, 'learning_rate': 1, 'algorithm': 'SAMME.R', 'features': 6}
#         Has trained 614 of 4032 combinations so far
# % Combos Checked Thus Far: 614 out of 4032 which is 15.228175%
# Max Val Score:
#  0.447405
# Max Val Score Std:
#  0.057346
# Best Combo Train Score:
#  0.881599
# Best Combo Train Score Std:
#  0.002034
# Max Combo Index:
#  (5, 4, 1, 6) out of [6, 7, 2, 48] (note best combo is 0-indexed)
# Max Combo Hyperparamer Combination:
#  {'n_estimators': 800, 'learning_rate': 1, 'algorithm': 'SAMME.R', 'features': 6}
# Max Combo Features:
#  ('procedure_224274', 'lods_score', 'procedure_224276', 'procedure_224267', 'race_AMERICAN INDIAN/ALASKA NATIVE', 'race_ASIAN', 'race_ASIAN - ASIAN INDIAN', 'race_ASIAN - CHINESE', 'race_ASIAN - KOREAN', 'race_ASIAN - SOUTH EAST ASIAN', 'race_BLACK/AFRICAN', 'race_BLACK/AFRICAN AMERICAN', 'race_BLACK/CAPE VERDEAN', 'race_BLACK/CARIBBEAN ISLAND', 'race_HISPANIC OR LATINO', 'race_HISPANIC/LATINO - CENTRAL AMERICAN', 'race_HISPANIC/LATINO - COLUMBIAN', 'race_HISPANIC/LATINO - CUBAN', 'race_HISPANIC/LATINO - DOMINICAN', 'race_HISPANIC/LATINO - GUATEMALAN', 'race_HISPANIC/LATINO - HONDURAN', 'race_HISPANIC/LATINO - MEXICAN', 'race_HISPANIC/LATINO - PUERTO RICAN', 'race_HISPANIC/LATINO - SALVADORAN', 'race_MULTIPLE RACE/ETHNICITY', 'race_NATIVE HAWAIIAN OR OTHER PACIFIC ISLANDER', 'race_OTHER', 'race_PATIENT DECLINED TO ANSWER', 'race_PORTUGUESE', 'race_SOUTH AMERICAN', 'race_UNABLE TO OBTAIN', 'race_WHITE', 'race_WHITE - BRAZILIAN', 'race_WHITE - EASTERN EUROPEAN', 'race_WHITE - OTHER EUROPEAN', 'race_WHITE - RUSSIAN', 'race_UNKNOWN', 'procedure_227712', 'procedure_225430')
# % Combos Checked: 614 out of 4032 which is 15.228175%
