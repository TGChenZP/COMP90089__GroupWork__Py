# %% [markdown]
# # Tuning Script

# %%
# Parameters subject to change in every script - involved in naming

MODEL = 'adabc'
PREPROCESSING = 'smote_normalise'
TUNER = 'yangzhoub'
OPTIMISED_METRIC = 'f1'

# %% [markdown]
# ---

# %%
# detect whether this is a google environment

COLAB_ENVIRONMENT = False

try:
    from google.colab import drive
    drive.mount('/content/drive')
    COLAB_ENVIRONMENT = True
except:
    pass
# Out:
# Mounted at /content/drive

# %%
import sys
import os
import pickle

if COLAB_ENVIRONMENT:
    home_directory = './drive/MyDrive/LAB/COMP90089__GroupWork__Py/' # my home directory is stored in ./LAB of google drive
    if MODEL == 'ebr':
        # !pip install interpret==0.5.0
    elif MODEL == 'cbr':
        # !pip install catboost
    elif MODEL in ['tf', 'mlp']:
        # !pip install PyTorch2Sklearn
    # !pip install JXAutoML
else:
    home_directory = '../../'

from JXAutoML.YangZhouB_10CV import YangZhouB_10CV as Tuner

import pandas as pd
# Out:
# Collecting JXAutoML
#   Downloading JXAutoML-0.4.4-py3-none-any.whl.metadata (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.2/67.2 kB 2.4 MB/s eta 0:00:00
# Downloading JXAutoML-0.4.4-py3-none-any.whl (52 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.1/52.1 kB 2.6 MB/s eta 0:00:00
# Installing collected packages: JXAutoML
# Successfully installed JXAutoML-0.4.4

# %%
# Parameters that are same for every script

FOLDS = 10  # we have decided to do 10 fold validation

SEED = 42

TASK_TYPE = 'Classification'  # this task is a classification task

# we have decided to tune features as hp
TUNE_FEATURES_AS_HYPERPARAMETERS = True

# %% [markdown]
# ---

# %%
# model to use to tune
from sklearn.ensemble import AdaBoostClassifier as clf

# what values to try for each hyperparameter
parameter_choices = {
    'n_estimators': (25, 50, 100, 200, 400, 800),
    'learning_rate': (0.0001, 0.001, 0.01, 0.1, 1, 10, 100),
    'algorithm': {'SAMME', 'SAMME.R'},

}

# what values to set non-tuneable parameters/hyperparameters
non_tunable_hyperparameters_dict = {
                                    'random_state': 42,
                                    }

# %% [markdown]
# ---

# %% [markdown]
# Read in and Prepare Data

# %%
# Import data and store as lists

train_x_list = []
train_y_list = []
val_x_list = []
val_y_list = []

for i in range(FOLDS):
    train_data = pd.read_csv(
        f'{home_directory}data/curated/modelling/{PREPROCESSING}/train_{i}.csv')
    val_data = pd.read_csv(
        f'{home_directory}data/curated/modelling/{PREPROCESSING}/val_{i}.csv')

    # get the correct rows for X and y
    train_x = train_data.drop(
        ['mortality_status', 'subject_id', 'hadm_id', 'stay_id'], axis=1)
    train_y = train_data['mortality_status']
    val_x = val_data.drop(
        ['mortality_status', 'subject_id', 'hadm_id', 'stay_id'], axis=1)
    val_y = val_data['mortality_status']

    train_x_list.append(train_x)
    train_y_list.append(train_y)
    val_x_list.append(val_x)
    val_y_list.append(val_y)

# %%
# Import feature importance ordering

with open(f'{home_directory}models/xgb_feature_importance_ordering_{PREPROCESSING}.pickle', 'rb') as f:
    feature_importance_ordering = pickle.load(f)

# %% [markdown]
# Set parameters

# %%
# initialisation
tuner = Tuner()

print('---')

# define what model we are tuning
tuner.read_in_model(clf, TASK_TYPE, optimised_metric=OPTIMISED_METRIC)

print('---')

# read in the data for training and validation
tuner.read_in_data(train_x_list, train_y_list, val_x_list, val_y_list)

print('---')

# set what hp values to tune
tuner.set_hyperparameters(parameter_choices)
# WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

# set up hp values that need to be changed from default but NOT to be tuned
tuner.set_non_tuneable_hyperparameters(non_tunable_hyperparameters_dict)

print('---')

# set up feature importance ordering

if TUNE_FEATURES_AS_HYPERPARAMETERS:
    tuner.set_features(feature_importance_ordering)
    # WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

try:  # try to read in previous results to continue tuning ...
    tuner.read_in_tuning_result_df(
        f'{home_directory}models/tuning/{TUNER}_{MODEL}_{PREPROCESSING}.csv')
except:
    print('No previous tuning data read in')

print('---')

# set up where to save the tuning result csv
tuner.set_tuning_result_saving_address(
    f'{home_directory}models/tuning/{TUNER}_{MODEL}_{PREPROCESSING}.csv')

print('---')

# set up where to save the current best model
tuner.set_best_model_saving_address(
    f'{home_directory}models/tmp_models/{TUNER}_{MODEL}_{PREPROCESSING}')
# Out:
# YangZhouB Initialised
# ---
# Successfully read in model <class 'sklearn.ensemble._weight_boosting.AdaBoostClassifier'>, which is a Classification model optimising for f1
# ---
# Read in Train X data list
# Read in Train y data list
# Read in Val X data list
# Read in Val y data list
# ---
# Successfully recorded hyperparameter choices
# ---
# Successfully recorded non_tuneable_hyperparameter choices
# ---
# Successfully recorded tuneable feature combination choices and updated relevant internal structures
# ---
# No previous tuning data read in
# ---
# Successfully set tuning output address
# ---
# Successfully set best model output address

# %%
# ignore warnings

import warnings
warnings.filterwarnings("ignore")

# %%
# begin tuning ... (or continue training)

tuner.tune()
# Out:
# BEGIN TUNING
#
#
# STAGE ZERO: Tune all Cruise combinations
#
#
# Trained and Tested combination 1 of 4284, taking 0.54 seconds to get val score of 0.0409:
#                 {'n_estimators': 25, 'learning_rate': 0.0001, 'algorithm': 'SAMME', 'features': 40},
#             Current best combo with val score 0.0409:
#                     {'n_estimators': 25, 'learning_rate': 0.0001, 'algorithm': 'SAMME', 'features': 40}
# Trained and Tested combination 2 of 4284, taking 0.05 seconds to get val score of 0.3109:
#                 {'n_estimators': 800, 'learning_rate': 100, 'algorithm': 'SAMME', 'features': 50},
#             Current best combo with val score 0.3109:
#                     {'n_estimators': 800, 'learning_rate': 100, 'algorithm': 'SAMME', 'features': 50}
# Trained and Tested combination 3 of 4284, taking 0.03 seconds to get val score of 0.3109:
#                 {'n_estimators': 25, 'learning_rate': 100, 'algorithm': 'SAMME', 'features': 30},
#             Current best combo with val score 0.3109:
#                     {'n_estimators': 800, 'learning_rate': 100, 'algorithm': 'SAMME', 'features': 50}
# Trained and Tested combination 4 of 4284, taking 0.05 seconds to get val score of 0.3109:
#                 {'n_estimators': 25, 'learning_rate': 100, 'algorithm': 'SAMME', 'features': 45},
#             Current best combo with val score 0.3109:
#                     {'n_estimators': 800, 'learning_rate': 100, 'algorithm': 'SAMME', 'features': 50}
# Trained and Tested combination 5 of 4284, taking 0.03 seconds to get val score of 0.3109:
#                 {'n_estimators': 800, 'learning_rate': 100, 'algorithm': 'SAMME', 'features': 35},
#             Current best combo with val score 0.3109:
#                     {'n_estimators': 800, 'learning_rate': 100, 'algorithm': 'SAMME', 'features': 50}
# Trained and Tested combination 6 of 4284, taking 11.01 seconds to get val score of 0.0224:
#                 {'n_estimators': 800, 'learning_rate': 0.0001, 'algorithm': 'SAMME.R', 'features': 30},
#             Current best combo with val score 0.3109:
#                     {'n_estimators': 800, 'learning_rate': 100, 'algorithm': 'SAMME', 'features': 50}
# Trained and Tested combination 7 of 4284, taking 0.03 seconds to get val score of 0.3109:
#                 {'n_estimators': 800, 'learning_rate': 100, 'algorithm': 'SAMME', 'features': 40},
#             Current best combo with val score 0.3109:
#                     {'n_estimators': 800, 'learning_rate': 100, 'algorithm': 'SAMME', 'features': 50}
# Trained and Tested combination 8 of 4284, taking 0.01 seconds to get val score of 0.2572:
#                 {'n_estimators': 25, 'learning_rate': 100, 'algorithm': 'SAMME', 'features': 0},
#             Current best combo with val score 0.3109:
#                     {'n_estimators': 800, 'learning_rate': 100, 'algorithm': 'SAMME', 'features': 50}
# Trained and Tested combination 9 of 4284, taking 0.21 seconds to get val score of 0.023:
#                 {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME', 'features': 15},
#             Current best combo with val score 0.3109:
#                     {'n_estimators': 800, 'learning_rate': 100, 'algorithm': 'SAMME', 'features': 50}
# Trained and Tested combination 10 of 4284, taking 9.1 seconds to get val score of 0.0409:
#                 {'n_estimators': 800, 'learning_rate': 0.0001, 'algorithm': 'SAMME', 'features': 25},
#             Current best combo with val score 0.3109:
#                     {'n_estimators': 800, 'learning_rate': 100, 'algorithm': 'SAMME', 'features': 50}
# Trained and Tested combination 11 of 4284, taking 0.08 seconds to get val score of 0.3127:
#                 {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 0},
#             Current best combo with val score 0.3127:
#                     {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 0}
# Trained and Tested combination 12 of 4284, taking 0.13 seconds to get val score of 0.0:
#                 {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 10},
#             Current best combo with val score 0.3127:
#                     {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 0}
# Trained and Tested combination 13 of 4284, taking 0.21 seconds to get val score of 0.0409:
#                 {'n_estimators': 25, 'learning_rate': 0.0001, 'algorithm': 'SAMME', 'features': 20},
#             Current best combo with val score 0.3127:
#                     {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 0}
# Trained and Tested combination 14 of 4284, taking 0.14 seconds to get val score of 0.1129:
#                 {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME', 'features': 5},
#             Current best combo with val score 0.3127:
#                     {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 0}
# Trained and Tested combination 15 of 4284, taking 0.02 seconds to get val score of 0.3109:
#                 {'n_estimators': 25, 'learning_rate': 100, 'algorithm': 'SAMME', 'features': 10},
#             Current best combo with val score 0.3127:
#                     {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 0}
# Trained and Tested combination 16 of 4284, taking 0.26 seconds to get val score of 0.0409:
#                 {'n_estimators': 25, 'learning_rate': 0.0001, 'algorithm': 'SAMME.R', 'features': 25},
#             Current best combo with val score 0.3127:
#                     {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 0}
# Trained and Tested combination 17 of 4284, taking 0.04 seconds to get val score of 0.3109:
#                 {'n_estimators': 25, 'learning_rate': 100, 'algorithm': 'SAMME', 'features': 40},
#             Current best combo with val score 0.3127:
#                     {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 0}
# Trained and Tested combination 18 of 4284, taking 14.23 seconds to get val score of 0.0158:
#                 {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME', 'features': 45},
#             Current best combo with val score 0.3127:
#                     {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 0}
# Trained and Tested combination 19 of 4284, taking 0.03 seconds to get val score of 0.3109:
#                 {'n_estimators': 800, 'learning_rate': 100, 'algorithm': 'SAMME.R', 'features': 30},
#             Current best combo with val score 0.3127:
#                     {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 0}
# Trained and Tested combination 20 of 4284, taking 14.68 seconds to get val score of 0.0224:
#                 {'n_estimators': 800, 'learning_rate': 0.0001, 'algorithm': 'SAMME.R', 'features': 50},
#             Current best combo with val score 0.3127:
#                     {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 0}
# Trained and Tested combination 21 of 4284, taking 0.04 seconds to get val score of 0.3109:
#                 {'n_estimators': 800, 'learning_rate': 100, 'algorithm': 'SAMME.R', 'features': 40},
#             Current best combo with val score 0.3127:
#                     {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 0}
# Trained and Tested combination 22 of 4284, taking 13.29 seconds to get val score of 0.0409:
#                 {'n_estimators': 800, 'learning_rate': 0.0001, 'algorithm': 'SAMME', 'features': 35},
#             Current best combo with val score 0.3127:
#                     {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 0}
# Trained and Tested combination 23 of 4284, taking 5.54 seconds to get val score of 0.0224:
#                 {'n_estimators': 800, 'learning_rate': 0.0001, 'algorithm': 'SAMME.R', 'features': 10},
#             Current best combo with val score 0.3127:
#                     {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 0}
# Trained and Tested combination 24 of 4284, taking 0.44 seconds to get val score of 0.0409:
#                 {'n_estimators': 25, 'learning_rate': 0.0001, 'algorithm': 'SAMME', 'features': 50},
#             Current best combo with val score 0.3127:
#                     {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 0}
# Trained and Tested combination 25 of 4284, taking 2.33 seconds to get val score of 0.3127:
#                 {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME', 'features': 0},
#             Current best combo with val score 0.3127:
#                     {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 0}
# Trained and Tested combination 26 of 4284, taking 0.03 seconds to get val score of 0.3109:
#                 {'n_estimators': 800, 'learning_rate': 100, 'algorithm': 'SAMME', 'features': 30},
#             Current best combo with val score 0.3127:
#                     {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 0}
# Trained and Tested combination 27 of 4284, taking 14.59 seconds to get val score of 0.1048:
#                 {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 45},
#             Current best combo with val score 0.3127:
#                     {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 0}
# Trained and Tested combination 28 of 4284, taking 0.05 seconds to get val score of 0.3109:
#                 {'n_estimators': 800, 'learning_rate': 100, 'algorithm': 'SAMME.R', 'features': 50},
#             Current best combo with val score 0.3127:
#                     {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 0}
# Trained and Tested combination 29 of 4284, taking 10.05 seconds to get val score of 0.1579:
#                 {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 30},
#             Current best combo with val score 0.3127:
#                     {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 0}
# Trained and Tested combination 30 of 4284, taking 3.79 seconds to get val score of 0.0608:
#                 {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 5},
#             Current best combo with val score 0.3127:
#                     {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 0}
# Trained and Tested combination 31 of 4284, taking 0.35 seconds to get val score of 0.0409:
#                 {'n_estimators': 25, 'learning_rate': 0.0001, 'algorithm': 'SAMME.R', 'features': 35},
#             Current best combo with val score 0.3127:
#                     {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 0}
# Trained and Tested combination 32 of 4284, taking 0.01 seconds to get val score of 0.31:
#                 {'n_estimators': 800, 'learning_rate': 100, 'algorithm': 'SAMME.R', 'features': 5},
#             Current best combo with val score 0.3127:
#                     {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 0}
# Trained and Tested combination 33 of 4284, taking 0.01 seconds to get val score of 0.0:
#                 {'n_estimators': 25, 'learning_rate': 100, 'algorithm': 'SAMME.R', 'features': 0},
#             Current best combo with val score 0.3127:
#                     {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 0}
# Trained and Tested combination 34 of 4284, taking 0.02 seconds to get val score of 0.3109:
#                 {'n_estimators': 800, 'learning_rate': 100, 'algorithm': 'SAMME.R', 'features': 25},
#             Current best combo with val score 0.3127:
#                     {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 0}
# Trained and Tested combination 35 of 4284, taking 0.41 seconds to get val score of 0.0409:
#                 {'n_estimators': 25, 'learning_rate': 0.0001, 'algorithm': 'SAMME', 'features': 45},
#             Current best combo with val score 0.3127:
#                     {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 0}
# Trained and Tested combination 36 of 4284, taking 0.02 seconds to get val score of 0.3098:
#                 {'n_estimators': 25, 'learning_rate': 100, 'algorithm': 'SAMME', 'features': 5},
#             Current best combo with val score 0.3127:
#                     {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 0}
# Trained and Tested combination 37 of 4284, taking 14.4 seconds to get val score of 0.0409:
#                 {'n_estimators': 800, 'learning_rate': 0.0001, 'algorithm': 'SAMME', 'features': 45},
#             Current best combo with val score 0.3127:
#                     {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 0}
# Trained and Tested combination 38 of 4284, taking 13.71 seconds to get val score of 0.0156:
#                 {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME', 'features': 40},
#             Current best combo with val score 0.3127:
#                     {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 0}
# Trained and Tested combination 39 of 4284, taking 0.3 seconds to get val score of 0.0409:
#                 {'n_estimators': 25, 'learning_rate': 0.0001, 'algorithm': 'SAMME.R', 'features': 30},
#             Current best combo with val score 0.3127:
#                     {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 0}
# Trained and Tested combination 40 of 4284, taking 0.01 seconds to get val score of 0.0:
#                 {'n_estimators': 800, 'learning_rate': 100, 'algorithm': 'SAMME.R', 'features': 0},
#             Current best combo with val score 0.3127:
#                     {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 0}
# Trained and Tested combination 41 of 4284, taking 0.03 seconds to get val score of 0.3109:
#                 {'n_estimators': 25, 'learning_rate': 100, 'algorithm': 'SAMME', 'features': 35},
#             Current best combo with val score 0.3127:
#                     {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 0}
# Trained and Tested combination 42 of 4284, taking 8.3 seconds to get val score of 0.0224:
#                 {'n_estimators': 800, 'learning_rate': 0.0001, 'algorithm': 'SAMME.R', 'features': 20},
#             Current best combo with val score 0.3127:
#                     {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 0}
# Trained and Tested combination 43 of 4284, taking 13.25 seconds to get val score of 0.0224:
#                 {'n_estimators': 800, 'learning_rate': 0.0001, 'algorithm': 'SAMME.R', 'features': 40},
#             Current best combo with val score 0.3127:
#                     {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 0}
# Trained and Tested combination 44 of 4284, taking 11.57 seconds to get val score of 0.0156:
#                 {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME', 'features': 35},
#             Current best combo with val score 0.3127:
#                     {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 0}
# Trained and Tested combination 45 of 4284, taking 0.59 seconds to get val score of 0.0:
#                 {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 50},
#             Current best combo with val score 0.3127:
#                     {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 0}
# Trained and Tested combination 46 of 4284, taking 8.11 seconds to get val score of 0.0224:
#                 {'n_estimators': 800, 'learning_rate': 0.0001, 'algorithm': 'SAMME.R', 'features': 25},
#             Current best combo with val score 0.3127:
#                     {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 0}
# Trained and Tested combination 47 of 4284, taking 0.32 seconds to get val score of 0.023:
#                 {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME', 'features': 20},
#             Current best combo with val score 0.3127:
#                     {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 0}
# Trained and Tested combination 48 of 4284, taking 0.41 seconds to get val score of 0.023:
#                 {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME', 'features': 50},
#             Current best combo with val score 0.3127:
#                     {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 0}
# Trained and Tested combination 49 of 4284, taking 2.2 seconds to get val score of 0.3127:
#                 {'n_estimators': 800, 'learning_rate': 0.0001, 'algorithm': 'SAMME', 'features': 0},
#             Current best combo with val score 0.3127:
#                     {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 0}
# Trained and Tested combination 50 of 4284, taking 0.26 seconds to get val score of 0.0:
#                 {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 25},
#             Current best combo with val score 0.3127:
#                     {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 0}
# Trained and Tested combination 51 of 4284, taking 7.59 seconds to get val score of 0.3068:
#                 {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 15},
#             Current best combo with val score 0.3127:
#                     {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 0}
# Trained and Tested combination 52 of 4284, taking 0.29 seconds to get val score of 0.0409:
#                 {'n_estimators': 25, 'learning_rate': 0.0001, 'algorithm': 'SAMME', 'features': 30},
#             Current best combo with val score 0.3127:
#                     {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 0}
# Trained and Tested combination 53 of 4284, taking 7.23 seconds to get val score of 0.3081:
#                 {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 20},
#             Current best combo with val score 0.3127:
#                     {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 0}
# Trained and Tested combination 54 of 4284, taking 4.34 seconds to get val score of 0.0409:
#                 {'n_estimators': 800, 'learning_rate': 0.0001, 'algorithm': 'SAMME', 'features': 10},
#             Current best combo with val score 0.3127:
#                     {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 0}
# Trained and Tested combination 55 of 4284, taking 15.5 seconds to get val score of 0.1156:
#                 {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 50},
#             Current best combo with val score 0.3127:
#                     {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 0}
# Trained and Tested combination 56 of 4284, taking 3.48 seconds to get val score of 0.0:
#                 {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME', 'features': 10},
#             Current best combo with val score 0.3127:
#                     {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 0}
# Trained and Tested combination 57 of 4284, taking 2.78 seconds to get val score of 0.3127:
#                 {'n_estimators': 800, 'learning_rate': 0.0001, 'algorithm': 'SAMME.R', 'features': 0},
#             Current best combo with val score 0.3127:
#                     {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 0}
# Trained and Tested combination 58 of 4284, taking 0.13 seconds to get val score of 0.0409:
#                 {'n_estimators': 25, 'learning_rate': 0.0001, 'algorithm': 'SAMME.R', 'features': 10},
#             Current best combo with val score 0.3127:
#                     {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 0}
# Trained and Tested combination 59 of 4284, taking 0.12 seconds to get val score of 0.0409:
#                 {'n_estimators': 25, 'learning_rate': 0.0001, 'algorithm': 'SAMME', 'features': 10},
#             Current best combo with val score 0.3127:
#                     {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 0}
# Trained and Tested combination 60 of 4284, taking 14.58 seconds to get val score of 0.0158:
#                 {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME', 'features': 50},
#             Current best combo with val score 0.3127:
#                     {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 0}
# Trained and Tested combination 61 of 4284, taking 0.41 seconds to get val score of 0.0409:
#                 {'n_estimators': 25, 'learning_rate': 0.0001, 'algorithm': 'SAMME.R', 'features': 45},
#             Current best combo with val score 0.3127:
#                     {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 0}
# Trained and Tested combination 62 of 4284, taking 0.29 seconds to get val score of 0.0:
#                 {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 30},
#             Current best combo with val score 0.3127:
#                     {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 0}
# Trained and Tested combination 63 of 4284, taking 0.02 seconds to get val score of 0.3109:
#                 {'n_estimators': 25, 'learning_rate': 100, 'algorithm': 'SAMME.R', 'features': 20},
#             Current best combo with val score 0.3127:
#                     {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 0}
# Trained and Tested combination 64 of 4284, taking 0.45 seconds to get val score of 0.023:
#                 {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME', 'features': 35},
#             Current best combo with val score 0.3127:
#                     {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 0}
# Trained and Tested combination 65 of 4284, taking 0.38 seconds to get val score of 0.0:
#                 {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 40},
#             Current best combo with val score 0.3127:
#                     {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 0}
# Trained and Tested combination 66 of 4284, taking 0.02 seconds to get val score of 0.3109:
#                 {'n_estimators': 25, 'learning_rate': 100, 'algorithm': 'SAMME.R', 'features': 15},
#             Current best combo with val score 0.3127:
#                     {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 0}
# Trained and Tested combination 67 of 4284, taking 0.19 seconds to get val score of 0.0:
#                 {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 15},
#             Current best combo with val score 0.3127:
#                     {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 0}
# Trained and Tested combination 68 of 4284, taking 8.06 seconds to get val score of 0.0216:
#                 {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME', 'features': 25},
#             Current best combo with val score 0.3127:
#                     {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 0}
# Trained and Tested combination 69 of 4284, taking 0.37 seconds to get val score of 0.023:
#                 {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME', 'features': 40},
#             Current best combo with val score 0.3127:
#                     {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 0}
# Trained and Tested combination 70 of 4284, taking 7.13 seconds to get val score of 0.0409:
#                 {'n_estimators': 800, 'learning_rate': 0.0001, 'algorithm': 'SAMME', 'features': 20},
#             Current best combo with val score 0.3127:
#                     {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 0}
# Trained and Tested combination 71 of 4284, taking 0.22 seconds to get val score of 0.0:
#                 {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 20},
#             Current best combo with val score 0.3127:
#                     {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 0}
# Trained and Tested combination 72 of 4284, taking 0.09 seconds to get val score of 0.1096:
#                 {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 5},
#             Current best combo with val score 0.3127:
#                     {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 0}
# Trained and Tested combination 73 of 4284, taking 0.41 seconds to get val score of 0.0:
#                 {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 45},
#             Current best combo with val score 0.3127:
#                     {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 0}
# Trained and Tested combination 74 of 4284, taking 0.08 seconds to get val score of 0.0655:
#                 {'n_estimators': 25, 'learning_rate': 0.0001, 'algorithm': 'SAMME', 'features': 5},
#             Current best combo with val score 0.3127:
#                     {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 0}
# Trained and Tested combination 75 of 4284, taking 7.33 seconds to get val score of 0.0632:
#                 {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME', 'features': 20},
#             Current best combo with val score 0.3127:
#                     {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 0}
# Trained and Tested combination 76 of 4284, taking 0.04 seconds to get val score of 0.3109:
#                 {'n_estimators': 800, 'learning_rate': 100, 'algorithm': 'SAMME', 'features': 45},
#             Current best combo with val score 0.3127:
#                     {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 0}
# Trained and Tested combination 77 of 4284, taking 0.01 seconds to get val score of 0.2572:
#                 {'n_estimators': 800, 'learning_rate': 100, 'algorithm': 'SAMME', 'features': 0},
#             Current best combo with val score 0.3127:
#                     {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 0}
# Trained and Tested combination 78 of 4284, taking 8.99 seconds to get val score of 0.2018:
#                 {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 25},
#             Current best combo with val score 0.3127:
#                     {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 0}
# Trained and Tested combination 79 of 4284, taking 5.92 seconds to get val score of 0.0409:
#                 {'n_estimators': 800, 'learning_rate': 0.0001, 'algorithm': 'SAMME', 'features': 15},
#             Current best combo with val score 0.3127:
#                     {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 0}
# Trained and Tested combination 80 of 4284, taking 0.07 seconds to get val score of 0.3127:
#                 {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME', 'features': 0},
#             Current best combo with val score 0.3127:
#                     {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 0}
# Trained and Tested combination 81 of 4284, taking 14.38 seconds to get val score of 0.0409:
#                 {'n_estimators': 800, 'learning_rate': 0.0001, 'algorithm': 'SAMME', 'features': 50},
#             Current best combo with val score 0.3127:
#                     {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 0}
# Trained and Tested combination 82 of 4284, taking 0.02 seconds to get val score of 0.3109:
#                 {'n_estimators': 800, 'learning_rate': 100, 'algorithm': 'SAMME', 'features': 25},
#             Current best combo with val score 0.3127:
#                     {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 0}
# Trained and Tested combination 83 of 4284, taking 0.02 seconds to get val score of 0.3109:
#                 {'n_estimators': 800, 'learning_rate': 100, 'algorithm': 'SAMME', 'features': 15},
#             Current best combo with val score 0.3127:
#                     {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 0}
# Trained and Tested combination 84 of 4284, taking 0.02 seconds to get val score of 0.3109:
#                 {'n_estimators': 25, 'learning_rate': 100, 'algorithm': 'SAMME', 'features': 20},
#             Current best combo with val score 0.3127:
#                     {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 0}
# Trained and Tested combination 85 of 4284, taking 4.53 seconds to get val score of 0.0:
#                 {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 10},
#             Current best combo with val score 0.3127:
#                     {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 0}
# Trained and Tested combination 86 of 4284, taking 0.08 seconds to get val score of 0.3127:
#                 {'n_estimators': 25, 'learning_rate': 0.0001, 'algorithm': 'SAMME.R', 'features': 0},
#             Current best combo with val score 0.3127:
#                     {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 0}
# Trained and Tested combination 87 of 4284, taking 0.25 seconds to get val score of 0.023:
#                 {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME', 'features': 25},
#             Current best combo with val score 0.3127:
#                     {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 0}
# Trained and Tested combination 88 of 4284, taking 0.02 seconds to get val score of 0.3109:
#                 {'n_estimators': 800, 'learning_rate': 100, 'algorithm': 'SAMME.R', 'features': 20},
#             Current best combo with val score 0.3127:
#                     {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 0}
# Trained and Tested combination 89 of 4284, taking 13.26 seconds to get val score of 0.1327:
#                 {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 40},
#             Current best combo with val score 0.3127:
#                     {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 0}
# Trained and Tested combination 90 of 4284, taking 0.39 seconds to get val score of 0.0409:
#                 {'n_estimators': 25, 'learning_rate': 0.0001, 'algorithm': 'SAMME.R', 'features': 40},
#             Current best combo with val score 0.3127:
#                     {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 0}
# Trained and Tested combination 91 of 4284, taking 0.01 seconds to get val score of 0.3109:
#                 {'n_estimators': 800, 'learning_rate': 100, 'algorithm': 'SAMME', 'features': 10},
#             Current best combo with val score 0.3127:
#                     {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 0}
# Trained and Tested combination 92 of 4284, taking 11.84 seconds to get val score of 0.1371:
#                 {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 35},
#             Current best combo with val score 0.3127:
#                     {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 0}
# Trained and Tested combination 93 of 4284, taking 0.04 seconds to get val score of 0.3109:
#                 {'n_estimators': 25, 'learning_rate': 100, 'algorithm': 'SAMME.R', 'features': 30},
#             Current best combo with val score 0.3127:
#                     {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 0}
# Trained and Tested combination 94 of 4284, taking 13.07 seconds to get val score of 0.0409:
#                 {'n_estimators': 800, 'learning_rate': 0.0001, 'algorithm': 'SAMME', 'features': 40},
#             Current best combo with val score 0.3127:
#                     {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 0}
# Trained and Tested combination 95 of 4284, taking 0.01 seconds to get val score of 0.3098:
#                 {'n_estimators': 800, 'learning_rate': 100, 'algorithm': 'SAMME', 'features': 5},
#             Current best combo with val score 0.3127:
#                     {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 0}
# Trained and Tested combination 96 of 4284, taking 11.1 seconds to get val score of 0.0409:
#                 {'n_estimators': 800, 'learning_rate': 0.0001, 'algorithm': 'SAMME', 'features': 30},
#             Current best combo with val score 0.3127:
#                     {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 0}
# Trained and Tested combination 97 of 4284, taking 0.04 seconds to get val score of 0.3109:
#                 {'n_estimators': 25, 'learning_rate': 100, 'algorithm': 'SAMME.R', 'features': 50},
#             Current best combo with val score 0.3127:
#                     {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 0}
# Trained and Tested combination 98 of 4284, taking 0.21 seconds to get val score of 0.0409:
#                 {'n_estimators': 25, 'learning_rate': 0.0001, 'algorithm': 'SAMME.R', 'features': 20},
#             Current best combo with val score 0.3127:
#                     {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 0}
# Trained and Tested combination 99 of 4284, taking 4.17 seconds to get val score of 0.0444:
#                 {'n_estimators': 800, 'learning_rate': 0.0001, 'algorithm': 'SAMME.R', 'features': 5},
#             Current best combo with val score 0.3127:
#                     {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 0}
# Trained and Tested combination 100 of 4284, taking 0.02 seconds to get val score of 0.3109:
#                 {'n_estimators': 800, 'learning_rate': 100, 'algorithm': 'SAMME', 'features': 20},
#             Current best combo with val score 0.3127:
#                     {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 0}
# Trained and Tested combination 101 of 4284, taking 0.33 seconds to get val score of 0.0:
#                 {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 35},
#             Current best combo with val score 0.3127:
#                     {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 0}
# Trained and Tested combination 102 of 4284, taking 0.03 seconds to get val score of 0.3109:
#                 {'n_estimators': 25, 'learning_rate': 100, 'algorithm': 'SAMME.R', 'features': 40},
#             Current best combo with val score 0.3127:
#                     {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 0}
# Trained and Tested combination 103 of 4284, taking 14.34 seconds to get val score of 0.0224:
#                 {'n_estimators': 800, 'learning_rate': 0.0001, 'algorithm': 'SAMME.R', 'features': 45},
#             Current best combo with val score 0.3127:
#                     {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 0}
# Trained and Tested combination 104 of 4284, taking 0.03 seconds to get val score of 0.3109:
#                 {'n_estimators': 25, 'learning_rate': 100, 'algorithm': 'SAMME.R', 'features': 35},
#             Current best combo with val score 0.3127:
#                     {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 0}
# Trained and Tested combination 105 of 4284, taking 2.58 seconds to get val score of 0.0641:
#                 {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME', 'features': 5},
#             Current best combo with val score 0.3127:
#                     {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 0}
# Trained and Tested combination 106 of 4284, taking 0.05 seconds to get val score of 0.3109:
#                 {'n_estimators': 25, 'learning_rate': 100, 'algorithm': 'SAMME', 'features': 50},
#             Current best combo with val score 0.3127:
#                     {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 0}
# Trained and Tested combination 107 of 4284, taking 0.03 seconds to get val score of 0.3109:
#                 {'n_estimators': 25, 'learning_rate': 100, 'algorithm': 'SAMME', 'features': 25},
#             Current best combo with val score 0.3127:
#                     {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 0}
# Trained and Tested combination 108 of 4284, taking 0.05 seconds to get val score of 0.3109:
#                 {'n_estimators': 25, 'learning_rate': 100, 'algorithm': 'SAMME.R', 'features': 45},
#             Current best combo with val score 0.3127:
#                     {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 0}
# Trained and Tested combination 109 of 4284, taking 0.29 seconds to get val score of 0.023:
#                 {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME', 'features': 30},
#             Current best combo with val score 0.3127:
#                     {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 0}
# Trained and Tested combination 110 of 4284, taking 0.24 seconds to get val score of 0.0409:
#                 {'n_estimators': 25, 'learning_rate': 0.0001, 'algorithm': 'SAMME', 'features': 25},
#             Current best combo with val score 0.3127:
#                     {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 0}
# Trained and Tested combination 111 of 4284, taking 0.1 seconds to get val score of 0.0655:
#                 {'n_estimators': 25, 'learning_rate': 0.0001, 'algorithm': 'SAMME.R', 'features': 5},
#             Current best combo with val score 0.3127:
#                     {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 0}
# Trained and Tested combination 112 of 4284, taking 0.07 seconds to get val score of 0.3127:
#                 {'n_estimators': 25, 'learning_rate': 0.0001, 'algorithm': 'SAMME', 'features': 0},
#             Current best combo with val score 0.3127:
#                     {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 0}
# Trained and Tested combination 113 of 4284, taking 0.02 seconds to get val score of 0.3109:
#                 {'n_estimators': 800, 'learning_rate': 100, 'algorithm': 'SAMME.R', 'features': 10},
#             Current best combo with val score 0.3127:
#                     {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 0}
# Trained and Tested combination 114 of 4284, taking 2.6 seconds to get val score of 0.3127:
#                 {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 0},
#             Current best combo with val score 0.3127:
#                     {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 0}
# Trained and Tested combination 115 of 4284, taking 0.02 seconds to get val score of 0.3109:
#                 {'n_estimators': 25, 'learning_rate': 100, 'algorithm': 'SAMME', 'features': 15},
#             Current best combo with val score 0.3127:
#                     {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 0}
# Trained and Tested combination 116 of 4284, taking 0.01 seconds to get val score of 0.31:
#                 {'n_estimators': 25, 'learning_rate': 100, 'algorithm': 'SAMME.R', 'features': 5},
#             Current best combo with val score 0.3127:
#                     {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 0}
# Trained and Tested combination 117 of 4284, taking 2.61 seconds to get val score of 0.0655:
#                 {'n_estimators': 800, 'learning_rate': 0.0001, 'algorithm': 'SAMME', 'features': 5},
#             Current best combo with val score 0.3127:
#                     {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 0}
# Trained and Tested combination 118 of 4284, taking 0.17 seconds to get val score of 0.0229:
#                 {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME', 'features': 10},
#             Current best combo with val score 0.3127:
#                     {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 0}
# Trained and Tested combination 119 of 4284, taking 0.03 seconds to get val score of 0.3109:
#                 {'n_estimators': 800, 'learning_rate': 100, 'algorithm': 'SAMME.R', 'features': 15},
#             Current best combo with val score 0.3127:
#                     {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 0}
# Trained and Tested combination 120 of 4284, taking 0.04 seconds to get val score of 0.3109:
#                 {'n_estimators': 800, 'learning_rate': 100, 'algorithm': 'SAMME.R', 'features': 45},
#             Current best combo with val score 0.3127:
#                     {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 0}
# Trained and Tested combination 121 of 4284, taking 0.02 seconds to get val score of 0.3109:
#                 {'n_estimators': 25, 'learning_rate': 100, 'algorithm': 'SAMME.R', 'features': 25},
#             Current best combo with val score 0.3127:
#                     {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 0}
# Trained and Tested combination 122 of 4284, taking 0.4 seconds to get val score of 0.023:
#                 {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME', 'features': 45},
#             Current best combo with val score 0.3127:
#                     {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 0}
# Trained and Tested combination 123 of 4284, taking 6.14 seconds to get val score of 0.0766:
#                 {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME', 'features': 15},
#             Current best combo with val score 0.3127:
#                     {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 0}
# Trained and Tested combination 124 of 4284, taking 0.18 seconds to get val score of 0.0409:
#                 {'n_estimators': 25, 'learning_rate': 0.0001, 'algorithm': 'SAMME', 'features': 15},
#             Current best combo with val score 0.3127:
#                     {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 0}
# Trained and Tested combination 125 of 4284, taking 0.27 seconds to get val score of 0.0409:
#                 {'n_estimators': 25, 'learning_rate': 0.0001, 'algorithm': 'SAMME.R', 'features': 15},
#             Current best combo with val score 0.3127:
#                     {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 0}
# Trained and Tested combination 126 of 4284, taking 7.68 seconds to get val score of 0.0224:
#                 {'n_estimators': 800, 'learning_rate': 0.0001, 'algorithm': 'SAMME.R', 'features': 15},
#             Current best combo with val score 0.3127:
#                     {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 0}
# Trained and Tested combination 127 of 4284, taking 0.01 seconds to get val score of 0.3109:
#                 {'n_estimators': 25, 'learning_rate': 100, 'algorithm': 'SAMME.R', 'features': 10},
#             Current best combo with val score 0.3127:
#                     {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 0}
# Trained and Tested combination 128 of 4284, taking 0.42 seconds to get val score of 0.0409:
#                 {'n_estimators': 25, 'learning_rate': 0.0001, 'algorithm': 'SAMME.R', 'features': 50},
#             Current best combo with val score 0.3127:
#                     {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 0}
# Trained and Tested combination 129 of 4284, taking 0.46 seconds to get val score of 0.0409:
#                 {'n_estimators': 25, 'learning_rate': 0.0001, 'algorithm': 'SAMME', 'features': 35},
#             Current best combo with val score 0.3127:
#                     {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 0}
# Trained and Tested combination 130 of 4284, taking 11.63 seconds to get val score of 0.0224:
#                 {'n_estimators': 800, 'learning_rate': 0.0001, 'algorithm': 'SAMME.R', 'features': 35},
#             Current best combo with val score 0.3127:
#                     {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 0}
# Trained and Tested combination 131 of 4284, taking 1.94 seconds to get val score of 0.0292:
#                 {'n_estimators': 200, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 25},
#             Current best combo with val score 0.3127:
#                     {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 0}
# Trained and Tested combination 132 of 4284, taking 10.4 seconds to get val score of 0.0156:
#                 {'n_estimators': 800, 'learning_rate': 0.1, 'algorithm': 'SAMME', 'features': 30},
#             Current best combo with val score 0.3127:
#                     {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 0}
# Trained and Tested combination 133 of 4284, taking 0.03 seconds to get val score of 0.3109:
#                 {'n_estimators': 800, 'learning_rate': 100, 'algorithm': 'SAMME.R', 'features': 35},
#             Current best combo with val score 0.3127:
#                     {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 0}
#
#
# STAGE ONE: Begin initial Guidance system
#
#
# Guidance: initial round
#
# 	round 0 iteration:  0
#
# Trained and Tested combination 134 of 4284, taking 1.4 seconds to get val score of 0.0133:
#                 {'n_estimators': 100, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 25},
#             Current best combo with val score 0.3127:
#                     {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 0}
# Trained and Tested combination 135 of 4284, taking 4.0 seconds to get val score of 0.0127:
#                 {'n_estimators': 400, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 25},
#             Current best combo with val score 0.3127:
#                     {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 0}
# Trained and Tested combination 136 of 4284, taking 2.01 seconds to get val score of 0.0033:
#                 {'n_estimators': 200, 'learning_rate': 0.01, 'algorithm': 'SAMME.R', 'features': 25},
#             Current best combo with val score 0.3127:
#                     {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 0}
# ...
#             Current best combo with val score 0.3167:
#                     {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 1}
# Trained and Tested combination 541 of 4284, taking 0.07 seconds to get val score of 0.3127:
#                 {'n_estimators': 25, 'learning_rate': 10, 'algorithm': 'SAMME', 'features': 1},
#             Current best combo with val score 0.3167:
#                     {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 1}
# Already Trained and Tested combination (val score of 0.2572):
#             {'n_estimators': 50, 'learning_rate': 100, 'algorithm': 'SAMME', 'features': 1}
#             Current best combo (with val score 0.3167):
#                     {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 1}
#         Has trained 541 of 4284 combinations so far
# Already Trained and Tested combination (val score of 0.3127):
#             {'n_estimators': 25, 'learning_rate': 10, 'algorithm': 'SAMME', 'features': 1}
#             Current best combo (with val score 0.3167):
#                     {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 1}
#         Has trained 541 of 4284 combinations so far
# Trained and Tested combination 542 of 4284, taking 0.01 seconds to get val score of 0.0:
#                 {'n_estimators': 25, 'learning_rate': 100, 'algorithm': 'SAMME.R', 'features': 1},
#             Current best combo with val score 0.3167:
#                     {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 1}
# Already Trained and Tested combination (val score of 0.2572):
#             {'n_estimators': 25, 'learning_rate': 100, 'algorithm': 'SAMME', 'features': 0}
#             Current best combo (with val score 0.3167):
#                     {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 1}
#         Has trained 542 of 4284 combinations so far
# Trained and Tested combination 543 of 4284, taking 0.01 seconds to get val score of 0.3098:
#                 {'n_estimators': 25, 'learning_rate': 100, 'algorithm': 'SAMME', 'features': 2},
#             Current best combo with val score 0.3167:
#                     {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 1}
# % Combos Checked Thus Far: 543 out of 4284 which is 12.67507%
# Cruising Coordrdinate 129 of 132
#
# Cruise suspended due to suspicious case
# Guidance: round 50
#
# 	round 50 iteration:  0
#
# % Combos Checked Thus Far: 543 out of 4284 which is 12.67507%
# Cruising Coordrdinate 130 of 132
#
# Cruising Coordrdinate 131 of 132
#
# Cruise suspended due to suspicious case
# Guidance: round 51
#
# 	round 51 iteration:  0
#
# Trained and Tested combination 544 of 4284, taking 0.13 seconds to get val score of 0.3127:
#                 {'n_estimators': 50, 'learning_rate': 0.1, 'algorithm': 'SAMME', 'features': 0},
#             Current best combo with val score 0.3167:
#                     {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 1}
# Already Trained and Tested combination (val score of 0.3127):
#             {'n_estimators': 25, 'learning_rate': 0.01, 'algorithm': 'SAMME', 'features': 0}
#             Current best combo (with val score 0.3167):
#                     {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 1}
#         Has trained 544 of 4284 combinations so far
# Already Trained and Tested combination (val score of 0.3127):
#             {'n_estimators': 25, 'learning_rate': 1, 'algorithm': 'SAMME', 'features': 0}
#             Current best combo (with val score 0.3167):
#                     {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 1}
#         Has trained 544 of 4284 combinations so far
# Already Trained and Tested combination (val score of 0.3127):
#             {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 0}
#             Current best combo (with val score 0.3167):
#                     {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 1}
#         Has trained 544 of 4284 combinations so far
# Already Trained and Tested combination (val score of 0.3127):
#             {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME', 'features': 1}
#             Current best combo (with val score 0.3167):
#                     {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 1}
#         Has trained 544 of 4284 combinations so far
# 	round 51 iteration:  1
#
# Already Trained and Tested combination (val score of 0.3127):
#             {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME', 'features': 0}
#             Current best combo (with val score 0.3167):
#                     {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 1}
#         Has trained 544 of 4284 combinations so far
# Trained and Tested combination 545 of 4284, taking 0.25 seconds to get val score of 0.3127:
#                 {'n_estimators': 100, 'learning_rate': 0.1, 'algorithm': 'SAMME', 'features': 0},
#             Current best combo with val score 0.3167:
#                     {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 1}
# Trained and Tested combination 546 of 4284, taking 0.19 seconds to get val score of 0.3127:
#                 {'n_estimators': 50, 'learning_rate': 0.01, 'algorithm': 'SAMME', 'features': 0},
#             Current best combo with val score 0.3167:
#                     {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 1}
# Trained and Tested combination 547 of 4284, taking 0.14 seconds to get val score of 0.3127:
#                 {'n_estimators': 50, 'learning_rate': 1, 'algorithm': 'SAMME', 'features': 0},
#             Current best combo with val score 0.3167:
#                     {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 1}
# Already Trained and Tested combination (val score of 0.3127):
#             {'n_estimators': 50, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 0}
#             Current best combo (with val score 0.3167):
#                     {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 1}
#         Has trained 547 of 4284 combinations so far
# Trained and Tested combination 548 of 4284, taking 0.14 seconds to get val score of 0.2969:
#                 {'n_estimators': 50, 'learning_rate': 0.1, 'algorithm': 'SAMME', 'features': 1},
#             Current best combo with val score 0.3167:
#                     {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 1}
# Already Trained and Tested combination (val score of 0.3127):
#             {'n_estimators': 50, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 0}
#             Current best combo (with val score 0.3167):
#                     {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 1}
#         Has trained 548 of 4284 combinations so far
# Already Trained and Tested combination (val score of 0.3127):
#             {'n_estimators': 25, 'learning_rate': 0.01, 'algorithm': 'SAMME.R', 'features': 0}
#             Current best combo (with val score 0.3167):
#                     {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 1}
#         Has trained 548 of 4284 combinations so far
# Already Trained and Tested combination (val score of 0.3127):
#             {'n_estimators': 25, 'learning_rate': 1, 'algorithm': 'SAMME.R', 'features': 0}
#             Current best combo (with val score 0.3167):
#                     {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 1}
#         Has trained 548 of 4284 combinations so far
# Already Trained and Tested combination (val score of 0.3127):
#             {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME', 'features': 0}
#             Current best combo (with val score 0.3167):
#                     {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 1}
#         Has trained 548 of 4284 combinations so far
# Already Trained and Tested combination (val score of 0.3167):
#             {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 1}
#             Current best combo (with val score 0.3167):
#                     {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 1}
#         Has trained 548 of 4284 combinations so far
# Already Trained and Tested combination (val score of 0.2969):
#             {'n_estimators': 50, 'learning_rate': 0.1, 'algorithm': 'SAMME', 'features': 1}
#             Current best combo (with val score 0.3167):
#                     {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 1}
#         Has trained 548 of 4284 combinations so far
# Trained and Tested combination 549 of 4284, taking 0.07 seconds to get val score of 0.3127:
#                 {'n_estimators': 25, 'learning_rate': 0.01, 'algorithm': 'SAMME', 'features': 1},
#             Current best combo with val score 0.3167:
#                     {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 1}
# Trained and Tested combination 550 of 4284, taking 0.06 seconds to get val score of 0.2951:
#                 {'n_estimators': 25, 'learning_rate': 1, 'algorithm': 'SAMME', 'features': 1},
#             Current best combo with val score 0.3167:
#                     {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 1}
# Already Trained and Tested combination (val score of 0.3167):
#             {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 1}
#             Current best combo (with val score 0.3167):
#                     {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 1}
#         Has trained 550 of 4284 combinations so far
# Already Trained and Tested combination (val score of 0.3127):
#             {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME', 'features': 0}
#             Current best combo (with val score 0.3167):
#                     {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 1}
#         Has trained 550 of 4284 combinations so far
# Trained and Tested combination 551 of 4284, taking 0.08 seconds to get val score of 0.1129:
#                 {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME', 'features': 2},
#             Current best combo with val score 0.3167:
#                     {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 1}
# % Combos Checked Thus Far: 551 out of 4284 which is 12.861811000000001%
# Cruising Coordrdinate 132 of 132
#
# Cruise suspended due to suspicious case
# Guidance: round 52
#
# 	round 52 iteration:  0
#
# % Combos Checked Thus Far: 551 out of 4284 which is 12.861811000000001%
# FINAL STAGE: Begin final Guidance system
#
#
# Guidance: round FINAL
#
# 	round FINAL iteration:  0
#
# Already Trained and Tested combination (val score of 0.3021):
#             {'n_estimators': 50, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 1}
#             Current best combo (with val score 0.3167):
#                     {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 1}
#         Has trained 551 of 4284 combinations so far
# Already Trained and Tested combination (val score of 0.3127):
#             {'n_estimators': 25, 'learning_rate': 0.01, 'algorithm': 'SAMME.R', 'features': 1}
#             Current best combo (with val score 0.3167):
#                     {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 1}
#         Has trained 551 of 4284 combinations so far
# Already Trained and Tested combination (val score of 0.2951):
#             {'n_estimators': 25, 'learning_rate': 1, 'algorithm': 'SAMME.R', 'features': 1}
#             Current best combo (with val score 0.3167):
#                     {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 1}
#         Has trained 551 of 4284 combinations so far
# Already Trained and Tested combination (val score of 0.3127):
#             {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME', 'features': 1}
#             Current best combo (with val score 0.3167):
#                     {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 1}
#         Has trained 551 of 4284 combinations so far
# Already Trained and Tested combination (val score of 0.3127):
#             {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 0}
#             Current best combo (with val score 0.3167):
#                     {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 1}
#         Has trained 551 of 4284 combinations so far
# Already Trained and Tested combination (val score of 0.0988):
#             {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 2}
#             Current best combo (with val score 0.3167):
#                     {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 1}
#         Has trained 551 of 4284 combinations so far
# 	round FINAL iteration:  1
#
# Trained and Tested combination 552 of 4284, taking 0.15 seconds to get val score of 0.3127:
#                 {'n_estimators': 50, 'learning_rate': 0.01, 'algorithm': 'SAMME.R', 'features': 1},
#             Current best combo with val score 0.3167:
#                     {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 1}
# Trained and Tested combination 553 of 4284, taking 0.12 seconds to get val score of 0.3127:
#                 {'n_estimators': 25, 'learning_rate': 0.001, 'algorithm': 'SAMME.R', 'features': 1},
#             Current best combo with val score 0.3167:
#                     {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 1}
# Already Trained and Tested combination (val score of 0.3167):
#             {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 1}
#             Current best combo (with val score 0.3167):
#                     {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 1}
#         Has trained 553 of 4284 combinations so far
# Already Trained and Tested combination (val score of 0.3127):
#             {'n_estimators': 25, 'learning_rate': 0.01, 'algorithm': 'SAMME', 'features': 1}
#             Current best combo (with val score 0.3167):
#                     {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 1}
#         Has trained 553 of 4284 combinations so far
# Already Trained and Tested combination (val score of 0.3127):
#             {'n_estimators': 25, 'learning_rate': 0.01, 'algorithm': 'SAMME.R', 'features': 0}
#             Current best combo (with val score 0.3167):
#                     {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 1}
#         Has trained 553 of 4284 combinations so far
# Trained and Tested combination 554 of 4284, taking 0.14 seconds to get val score of 0.0353:
#                 {'n_estimators': 25, 'learning_rate': 0.01, 'algorithm': 'SAMME.R', 'features': 2},
#             Current best combo with val score 0.3167:
#                     {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 1}
# % Combos Checked Thus Far: 554 out of 4284 which is 12.931839%
# Max Val Score:
#  0.31669
# Max Val Score Std:
#  0.044294
# Best Combo Train Score:
#  0.636526
# Best Combo Train Score Std:
#  0.019638
# Max Combo Index:
#  (0, 3, 1, 1) out of [6, 7, 2, 51] (note best combo is 0-indexed)
# Max Combo Hyperparamer Combination:
#  {'n_estimators': 25, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'features': 1}
# Max Combo Features:
#  ('marital_status_DIVORCED', 'marital_status_MARRIED', 'marital_status_SINGLE', 'marital_status_WIDOWED', 'marital_status_0', 'procedure_224276')
# % Combos Checked: 554 out of 4284 which is 12.931839%
