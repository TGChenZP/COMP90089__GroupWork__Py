# %% [markdown]
# # Tuning Script

# %%
# Parameters subject to change in every script - involved in naming

MODEL = 'nb(bernoulli)'
PREPROCESSING = 'normalise'
TUNER = 'yangzhoub'
OPTIMISED_METRIC = 'f1'

# %% [markdown]
# ---

# %%
# detect whether this is a google environment

COLAB_ENVIRONMENT = False

try:
    from google.colab import drive
    drive.mount('/content/drive')
    COLAB_ENVIRONMENT = True
except:
    pass
# Out:
# Mounted at /content/drive

# %%
import sys
import os
import pickle

if COLAB_ENVIRONMENT:
    home_directory = './drive/MyDrive/LAB/COMP90089__GroupWork__Py/' # my home directory is stored in ./LAB of google drive
    if MODEL == 'ebr':
        # !pip install interpret==0.5.0
    elif MODEL == 'cbr':
        # !pip install catboost
    elif MODEL in ['tf', 'mlp']:
        # !pip install PyTorch2Sklearn
    # !pip install JXAutoML
else:
    home_directory = '../../'

from JXAutoML.YangZhouB_10CV import YangZhouB_10CV as Tuner

import pandas as pd
# Out:
# Collecting JXAutoML
#   Downloading JXAutoML-0.4.4-py3-none-any.whl.metadata (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.2/67.2 kB 1.7 MB/s eta 0:00:00
# Downloading JXAutoML-0.4.4-py3-none-any.whl (52 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.1/52.1 kB 4.0 MB/s eta 0:00:00
# Installing collected packages: JXAutoML
# Successfully installed JXAutoML-0.4.4

# %%
# Parameters that are same for every script

FOLDS = 10  # we have decided to do 10 fold validation

SEED = 42

TASK_TYPE = 'Classification'  # this task is a classification task

# we have decided to tune features as hp
TUNE_FEATURES_AS_HYPERPARAMETERS = True

# %% [markdown]
# ---

# %%
# model to use to tune
from sklearn.naive_bayes import BernoulliNB as clf

# what values to try for each hyperparameter
parameter_choices = {
    'alpha': (0.0001, 0.001, 0.01, 0.1, 1, 10, 100),
    'fit_prior': (False, True)
}

# what values to set non-tuneable parameters/hyperparameters
non_tunable_hyperparameters_dict = {}

# %% [markdown]
# ---

# %% [markdown]
# Read in and Prepare Data

# %%
# Import data and store as lists

train_x_list = []
train_y_list = []
val_x_list = []
val_y_list = []

for i in range(FOLDS):
    train_data = pd.read_csv(
        f'{home_directory}data/curated/modelling/{PREPROCESSING}/train_{i}.csv')
    val_data = pd.read_csv(
        f'{home_directory}data/curated/modelling/{PREPROCESSING}/val_{i}.csv')

    # get the correct rows for X and y
    train_x = train_data.drop(
        ['mortality_status', 'subject_id', 'hadm_id', 'stay_id'], axis=1)
    train_y = train_data['mortality_status']
    val_x = val_data.drop(
        ['mortality_status', 'subject_id', 'hadm_id', 'stay_id'], axis=1)
    val_y = val_data['mortality_status']

    train_x_list.append(train_x)
    train_y_list.append(train_y)
    val_x_list.append(val_x)
    val_y_list.append(val_y)

# %%
# Import feature importance ordering

with open(f'{home_directory}models/xgb_feature_importance_ordering_{PREPROCESSING}.pickle', 'rb') as f:
    feature_importance_ordering = pickle.load(f)

# %% [markdown]
# Set parameters

# %%
# initialisation
tuner = Tuner()

print('---')

# define what model we are tuning
tuner.read_in_model(clf, TASK_TYPE, optimised_metric=OPTIMISED_METRIC)

print('---')

# read in the data for training and validation
tuner.read_in_data(train_x_list, train_y_list, val_x_list, val_y_list)

print('---')

# set what hp values to tune
tuner.set_hyperparameters(parameter_choices)
# WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

# set up hp values that need to be changed from default but NOT to be tuned
tuner.set_non_tuneable_hyperparameters(non_tunable_hyperparameters_dict)

print('---')

# set up feature importance ordering

if TUNE_FEATURES_AS_HYPERPARAMETERS:
    tuner.set_features(feature_importance_ordering)
    # WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

try:  # try to read in previous results to continue tuning ...
    tuner.read_in_tuning_result_df(
        f'{home_directory}models/tuning/{TUNER}_{MODEL}_{PREPROCESSING}.csv')
except:
    print('No previous tuning data read in')

print('---')

# set up where to save the tuning result csv
tuner.set_tuning_result_saving_address(
    f'{home_directory}models/tuning/{TUNER}_{MODEL}_{PREPROCESSING}.csv')

print('---')

# set up where to save the current best model
tuner.set_best_model_saving_address(
    f'{home_directory}models/tmp_models/{TUNER}_{MODEL}_{PREPROCESSING}')
# Out:
# YangZhouB Initialised
# ---
# Successfully read in model <class 'sklearn.naive_bayes.BernoulliNB'>, which is a Classification model optimising for f1
# ---
# Read in Train X data list
# Read in Train y data list
# Read in Val X data list
# Read in Val y data list
# ---
# Successfully recorded hyperparameter choices
# ---
# Successfully recorded non_tuneable_hyperparameter choices
# ---
# Successfully recorded tuneable feature combination choices and updated relevant internal structures
# ---
# No previous tuning data read in
# ---
# Successfully set tuning output address
# ---
# Successfully set best model output address

# %%
# ignore warnings

import warnings
warnings.filterwarnings("ignore")

# %%
# begin tuning ... (or continue training)

tuner.tune()
# Out:
# BEGIN TUNING
#
#
# STAGE ZERO: Tune all Cruise combinations
#
#
# Trained and Tested combination 1 of 672, taking 0.02 seconds to get val score of 0.0357:
#                 {'alpha': 100, 'fit_prior': False, 'features': 35},
#             Current best combo with val score 0.0357:
#                     {'alpha': 100, 'fit_prior': False, 'features': 35}
# Trained and Tested combination 2 of 672, taking 0.03 seconds to get val score of 0.0132:
#                 {'alpha': 100, 'fit_prior': True, 'features': 47},
#             Current best combo with val score 0.0357:
#                     {'alpha': 100, 'fit_prior': False, 'features': 35}
# Trained and Tested combination 3 of 672, taking 0.05 seconds to get val score of 0.0773:
#                 {'alpha': 0.0001, 'fit_prior': True, 'features': 39},
#             Current best combo with val score 0.0773:
#                     {'alpha': 0.0001, 'fit_prior': True, 'features': 39}
# Trained and Tested combination 4 of 672, taking 0.03 seconds to get val score of 0.0387:
#                 {'alpha': 100, 'fit_prior': False, 'features': 30},
#             Current best combo with val score 0.0773:
#                     {'alpha': 0.0001, 'fit_prior': True, 'features': 39}
# Trained and Tested combination 5 of 672, taking 0.02 seconds to get val score of 0.0859:
#                 {'alpha': 0.0001, 'fit_prior': True, 'features': 30},
#             Current best combo with val score 0.0859:
#                     {'alpha': 0.0001, 'fit_prior': True, 'features': 30}
# Trained and Tested combination 6 of 672, taking 0.03 seconds to get val score of 0.0779:
#                 {'alpha': 0.0001, 'fit_prior': True, 'features': 47},
#             Current best combo with val score 0.0859:
#                     {'alpha': 0.0001, 'fit_prior': True, 'features': 30}
# Trained and Tested combination 7 of 672, taking 0.03 seconds to get val score of 0.1869:
#                 {'alpha': 0.0001, 'fit_prior': False, 'features': 47},
#             Current best combo with val score 0.1869:
#                     {'alpha': 0.0001, 'fit_prior': False, 'features': 47}
# Trained and Tested combination 8 of 672, taking 0.01 seconds to get val score of 0.2027:
#                 {'alpha': 0.0001, 'fit_prior': False, 'features': 39},
#             Current best combo with val score 0.2027:
#                     {'alpha': 0.0001, 'fit_prior': False, 'features': 39}
# Trained and Tested combination 9 of 672, taking 0.01 seconds to get val score of 0.0664:
#                 {'alpha': 0.1, 'fit_prior': True, 'features': 25},
#             Current best combo with val score 0.2027:
#                     {'alpha': 0.0001, 'fit_prior': False, 'features': 39}
# Trained and Tested combination 10 of 672, taking 0.01 seconds to get val score of 0.1762:
#                 {'alpha': 0.0001, 'fit_prior': False, 'features': 43},
#             Current best combo with val score 0.2027:
#                     {'alpha': 0.0001, 'fit_prior': False, 'features': 39}
# Trained and Tested combination 11 of 672, taking 0.01 seconds to get val score of 0.3517:
#                 {'alpha': 0.1, 'fit_prior': False, 'features': 15},
#             Current best combo with val score 0.3517:
#                     {'alpha': 0.1, 'fit_prior': False, 'features': 15}
# Trained and Tested combination 12 of 672, taking 0.0 seconds to get val score of 0.0456:
#                 {'alpha': 0.0001, 'fit_prior': True, 'features': 10},
#             Current best combo with val score 0.3517:
#                     {'alpha': 0.1, 'fit_prior': False, 'features': 15}
# Trained and Tested combination 13 of 672, taking 0.01 seconds to get val score of 0.0828:
#                 {'alpha': 0.1, 'fit_prior': True, 'features': 30},
#             Current best combo with val score 0.3517:
#                     {'alpha': 0.1, 'fit_prior': False, 'features': 15}
# Trained and Tested combination 14 of 672, taking 0.01 seconds to get val score of 0.1391:
#                 {'alpha': 0.1, 'fit_prior': True, 'features': 20},
#             Current best combo with val score 0.3517:
#                     {'alpha': 0.1, 'fit_prior': False, 'features': 15}
# Trained and Tested combination 15 of 672, taking 0.0 seconds to get val score of 0.4338:
#                 {'alpha': 100, 'fit_prior': False, 'features': 0},
#             Current best combo with val score 0.4338:
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
# Trained and Tested combination 16 of 672, taking 0.01 seconds to get val score of 0.346:
#                 {'alpha': 0.1, 'fit_prior': False, 'features': 20},
#             Current best combo with val score 0.4338:
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
# Trained and Tested combination 17 of 672, taking 0.01 seconds to get val score of 0.0:
#                 {'alpha': 100, 'fit_prior': True, 'features': 15},
#             Current best combo with val score 0.4338:
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
# Trained and Tested combination 18 of 672, taking 0.0 seconds to get val score of 0.0067:
#                 {'alpha': 100, 'fit_prior': True, 'features': 5},
#             Current best combo with val score 0.4338:
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
# Trained and Tested combination 19 of 672, taking 0.0 seconds to get val score of 0.0:
#                 {'alpha': 0.0001, 'fit_prior': True, 'features': 0},
#             Current best combo with val score 0.4338:
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
# Trained and Tested combination 20 of 672, taking 0.01 seconds to get val score of 0.0:
#                 {'alpha': 100, 'fit_prior': False, 'features': 10},
#             Current best combo with val score 0.4338:
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
# Trained and Tested combination 21 of 672, taking 0.02 seconds to get val score of 0.2641:
#                 {'alpha': 0.1, 'fit_prior': False, 'features': 35},
#             Current best combo with val score 0.4338:
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
# Trained and Tested combination 22 of 672, taking 0.02 seconds to get val score of 0.0067:
#                 {'alpha': 100, 'fit_prior': True, 'features': 30},
#             Current best combo with val score 0.4338:
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
# Trained and Tested combination 23 of 672, taking 0.0 seconds to get val score of 0.4338:
#                 {'alpha': 0.1, 'fit_prior': False, 'features': 0},
#             Current best combo with val score 0.4338:
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
# Trained and Tested combination 24 of 672, taking 0.01 seconds to get val score of 0.0067:
#                 {'alpha': 100, 'fit_prior': True, 'features': 39},
#             Current best combo with val score 0.4338:
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
# Trained and Tested combination 25 of 672, taking 0.0 seconds to get val score of 0.1271:
#                 {'alpha': 0.1, 'fit_prior': True, 'features': 5},
#             Current best combo with val score 0.4338:
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
# Trained and Tested combination 26 of 672, taking 0.01 seconds to get val score of 0.0664:
#                 {'alpha': 0.0001, 'fit_prior': True, 'features': 25},
#             Current best combo with val score 0.4338:
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
# Trained and Tested combination 27 of 672, taking 0.01 seconds to get val score of 0.3464:
#                 {'alpha': 0.0001, 'fit_prior': False, 'features': 20},
#             Current best combo with val score 0.4338:
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
# Trained and Tested combination 28 of 672, taking 0.0 seconds to get val score of 0.0456:
#                 {'alpha': 0.1, 'fit_prior': True, 'features': 10},
#             Current best combo with val score 0.4338:
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
# Trained and Tested combination 29 of 672, taking 0.01 seconds to get val score of 0.0451:
#                 {'alpha': 100, 'fit_prior': False, 'features': 20},
#             Current best combo with val score 0.4338:
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
# Trained and Tested combination 30 of 672, taking 0.01 seconds to get val score of 0.0261:
#                 {'alpha': 100, 'fit_prior': False, 'features': 39},
#             Current best combo with val score 0.4338:
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
# Trained and Tested combination 31 of 672, taking 0.01 seconds to get val score of 0.0921:
#                 {'alpha': 0.0001, 'fit_prior': True, 'features': 35},
#             Current best combo with val score 0.4338:
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
# Trained and Tested combination 32 of 672, taking 0.01 seconds to get val score of 0.0779:
#                 {'alpha': 0.1, 'fit_prior': True, 'features': 47},
#             Current best combo with val score 0.4338:
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
# Trained and Tested combination 33 of 672, taking 0.01 seconds to get val score of 0.026:
#                 {'alpha': 100, 'fit_prior': False, 'features': 25},
#             Current best combo with val score 0.4338:
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
# Trained and Tested combination 34 of 672, taking 0.02 seconds to get val score of 0.0261:
#                 {'alpha': 100, 'fit_prior': False, 'features': 43},
#             Current best combo with val score 0.4338:
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
# Trained and Tested combination 35 of 672, taking 0.01 seconds to get val score of 0.0753:
#                 {'alpha': 0.0001, 'fit_prior': True, 'features': 43},
#             Current best combo with val score 0.4338:
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
# Trained and Tested combination 36 of 672, taking 0.01 seconds to get val score of 0.0067:
#                 {'alpha': 100, 'fit_prior': True, 'features': 35},
#             Current best combo with val score 0.4338:
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
# Trained and Tested combination 37 of 672, taking 0.01 seconds to get val score of 0.1762:
#                 {'alpha': 0.1, 'fit_prior': False, 'features': 43},
#             Current best combo with val score 0.4338:
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
# Trained and Tested combination 38 of 672, taking 0.01 seconds to get val score of 0.1891:
#                 {'alpha': 0.1, 'fit_prior': False, 'features': 25},
#             Current best combo with val score 0.4338:
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
# Trained and Tested combination 39 of 672, taking 0.0 seconds to get val score of 0.3389:
#                 {'alpha': 0.1, 'fit_prior': False, 'features': 10},
#             Current best combo with val score 0.4338:
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
# Trained and Tested combination 40 of 672, taking 0.02 seconds to get val score of 0.1841:
#                 {'alpha': 0.1, 'fit_prior': False, 'features': 47},
#             Current best combo with val score 0.4338:
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
# Trained and Tested combination 41 of 672, taking 0.01 seconds to get val score of 0.0926:
#                 {'alpha': 0.0001, 'fit_prior': True, 'features': 15},
#             Current best combo with val score 0.4338:
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
# Trained and Tested combination 42 of 672, taking 0.01 seconds to get val score of 0.3389:
#                 {'alpha': 0.0001, 'fit_prior': False, 'features': 10},
#             Current best combo with val score 0.4338:
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
# Trained and Tested combination 43 of 672, taking 0.02 seconds to get val score of 0.2586:
#                 {'alpha': 0.0001, 'fit_prior': False, 'features': 30},
#             Current best combo with val score 0.4338:
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
# Trained and Tested combination 44 of 672, taking 0.0 seconds to get val score of 0.4338:
#                 {'alpha': 0.0001, 'fit_prior': False, 'features': 0},
#             Current best combo with val score 0.4338:
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
# Trained and Tested combination 45 of 672, taking 0.01 seconds to get val score of 0.0231:
#                 {'alpha': 100, 'fit_prior': False, 'features': 47},
#             Current best combo with val score 0.4338:
#                     {'alpha': 100, 'fit_prior': False, 'features': 0}
# Trained and Tested combination 46 of 672, taking 0.0 seconds to get val score of 0.4422:
#                 {'alpha': 0.1, 'fit_prior': False, 'features': 5},
#             Current best combo with val score 0.4422:
#                     {'alpha': 0.1, 'fit_prior': False, 'features': 5}
# Trained and Tested combination 47 of 672, taking 0.0 seconds to get val score of 0.0:
#                 {'alpha': 100, 'fit_prior': True, 'features': 10},
#             Current best combo with val score 0.4422:
#                     {'alpha': 0.1, 'fit_prior': False, 'features': 5}
# Trained and Tested combination 48 of 672, taking 0.0 seconds to get val score of 0.0:
#                 {'alpha': 0.1, 'fit_prior': True, 'features': 0},
#             Current best combo with val score 0.4422:
#                     {'alpha': 0.1, 'fit_prior': False, 'features': 5}
# Trained and Tested combination 49 of 672, taking 0.0 seconds to get val score of 0.1271:
#                 {'alpha': 0.0001, 'fit_prior': True, 'features': 5},
#             Current best combo with val score 0.4422:
#                     {'alpha': 0.1, 'fit_prior': False, 'features': 5}
# Trained and Tested combination 50 of 672, taking 0.0 seconds to get val score of 0.0:
#                 {'alpha': 100, 'fit_prior': True, 'features': 0},
#             Current best combo with val score 0.4422:
#                     {'alpha': 0.1, 'fit_prior': False, 'features': 5}
# Trained and Tested combination 51 of 672, taking 0.01 seconds to get val score of 0.3517:
#                 {'alpha': 0.0001, 'fit_prior': False, 'features': 15},
#             Current best combo with val score 0.4422:
#                     {'alpha': 0.1, 'fit_prior': False, 'features': 5}
# Trained and Tested combination 52 of 672, taking 0.01 seconds to get val score of 0.2027:
#                 {'alpha': 0.1, 'fit_prior': False, 'features': 39},
#             Current best combo with val score 0.4422:
#                     {'alpha': 0.1, 'fit_prior': False, 'features': 5}
# Trained and Tested combination 53 of 672, taking 0.01 seconds to get val score of 0.1391:
#                 {'alpha': 0.0001, 'fit_prior': True, 'features': 20},
#             Current best combo with val score 0.4422:
#                     {'alpha': 0.1, 'fit_prior': False, 'features': 5}
# Trained and Tested combination 54 of 672, taking 0.0 seconds to get val score of 0.1751:
#                 {'alpha': 100, 'fit_prior': False, 'features': 5},
#             Current best combo with val score 0.4422:
#                     {'alpha': 0.1, 'fit_prior': False, 'features': 5}
# Trained and Tested combination 55 of 672, taking 0.01 seconds to get val score of 0.0:
#                 {'alpha': 100, 'fit_prior': True, 'features': 25},
#             Current best combo with val score 0.4422:
#                     {'alpha': 0.1, 'fit_prior': False, 'features': 5}
# Trained and Tested combination 56 of 672, taking 0.01 seconds to get val score of 0.2641:
#                 {'alpha': 0.0001, 'fit_prior': False, 'features': 35},
#             Current best combo with val score 0.4422:
#                     {'alpha': 0.1, 'fit_prior': False, 'features': 5}
# Trained and Tested combination 57 of 672, taking 0.01 seconds to get val score of 0.0891:
#                 {'alpha': 0.1, 'fit_prior': True, 'features': 35},
#             Current best combo with val score 0.4422:
#                     {'alpha': 0.1, 'fit_prior': False, 'features': 5}
# Trained and Tested combination 58 of 672, taking 0.01 seconds to get val score of 0.2586:
#                 {'alpha': 0.1, 'fit_prior': False, 'features': 30},
#             Current best combo with val score 0.4422:
#                     {'alpha': 0.1, 'fit_prior': False, 'features': 5}
# Trained and Tested combination 59 of 672, taking 0.01 seconds to get val score of 0.1888:
#                 {'alpha': 0.0001, 'fit_prior': False, 'features': 25},
#             Current best combo with val score 0.4422:
#                     {'alpha': 0.1, 'fit_prior': False, 'features': 5}
# Trained and Tested combination 60 of 672, taking 0.0 seconds to get val score of 0.4422:
#                 {'alpha': 0.0001, 'fit_prior': False, 'features': 5},
#             Current best combo with val score 0.4422:
#                     {'alpha': 0.1, 'fit_prior': False, 'features': 5}
# Trained and Tested combination 61 of 672, taking 0.01 seconds to get val score of 0.0132:
#                 {'alpha': 100, 'fit_prior': True, 'features': 20},
#             Current best combo with val score 0.4422:
#                     {'alpha': 0.1, 'fit_prior': False, 'features': 5}
# Trained and Tested combination 62 of 672, taking 0.01 seconds to get val score of 0.0773:
#                 {'alpha': 0.1, 'fit_prior': True, 'features': 39},
#             Current best combo with val score 0.4422:
#                     {'alpha': 0.1, 'fit_prior': False, 'features': 5}
# Trained and Tested combination 63 of 672, taking 0.02 seconds to get val score of 0.0897:
#                 {'alpha': 0.1, 'fit_prior': True, 'features': 15},
#             Current best combo with val score 0.4422:
#                     {'alpha': 0.1, 'fit_prior': False, 'features': 5}
# Trained and Tested combination 64 of 672, taking 0.02 seconds to get val score of 0.0753:
#                 {'alpha': 0.1, 'fit_prior': True, 'features': 43},
#             Current best combo with val score 0.4422:
#                     {'alpha': 0.1, 'fit_prior': False, 'features': 5}
# Trained and Tested combination 65 of 672, taking 0.01 seconds to get val score of 0.0749:
#                 {'alpha': 0.1, 'fit_prior': True, 'features': 24},
#             Current best combo with val score 0.4422:
#                     {'alpha': 0.1, 'fit_prior': False, 'features': 5}
# Trained and Tested combination 66 of 672, taking 0.01 seconds to get val score of 0.0195:
#                 {'alpha': 100, 'fit_prior': False, 'features': 15},
#             Current best combo with val score 0.4422:
#                     {'alpha': 0.1, 'fit_prior': False, 'features': 5}
# Trained and Tested combination 67 of 672, taking 0.02 seconds to get val score of 0.0:
#                 {'alpha': 100, 'fit_prior': True, 'features': 43},
#             Current best combo with val score 0.4422:
#                     {'alpha': 0.1, 'fit_prior': False, 'features': 5}
#
#
# STAGE ONE: Begin initial Guidance system
#
#
# Guidance: initial round
#
# 	round 0 iteration:  0
#
# Trained and Tested combination 68 of 672, taking 0.01 seconds to get val score of 0.0719:
#                 {'alpha': 0.01, 'fit_prior': True, 'features': 24},
#             Current best combo with val score 0.4422:
#                     {'alpha': 0.1, 'fit_prior': False, 'features': 5}
# Trained and Tested combination 69 of 672, taking 0.01 seconds to get val score of 0.0783:
#                 {'alpha': 1, 'fit_prior': True, 'features': 24},
#             Current best combo with val score 0.4422:
#                     {'alpha': 0.1, 'fit_prior': False, 'features': 5}
# Trained and Tested combination 70 of 672, taking 0.01 seconds to get val score of 0.2022:
#                 {'alpha': 0.1, 'fit_prior': False, 'features': 24},
#             Current best combo with val score 0.4422:
#                     {'alpha': 0.1, 'fit_prior': False, 'features': 5}
# Trained and Tested combination 71 of 672, taking 0.01 seconds to get val score of 0.0871:
#                 {'alpha': 0.1, 'fit_prior': True, 'features': 23},
#             Current best combo with val score 0.4422:
#                     {'alpha': 0.1, 'fit_prior': False, 'features': 5}
# Already Trained and Tested combination (val score of 0.0664):
#             {'alpha': 0.1, 'fit_prior': True, 'features': 25}
#             Current best combo (with val score 0.4422):
#                     {'alpha': 0.1, 'fit_prior': False, 'features': 5}
#         Has trained 71 of 672 combinations so far
# 	round 0 iteration:  1
#
# Trained and Tested combination 72 of 672, taking 0.01 seconds to get val score of 0.0719:
#                 {'alpha': 0.001, 'fit_prior': True, 'features': 24},
#             Current best combo with val score 0.4422:
#                     {'alpha': 0.1, 'fit_prior': False, 'features': 5}
# Already Trained and Tested combination (val score of 0.0749):
#             {'alpha': 0.1, 'fit_prior': True, 'features': 24}
#             Current best combo (with val score 0.4422):
#                     {'alpha': 0.1, 'fit_prior': False, 'features': 5}
#         Has trained 72 of 672 combinations so far
# Trained and Tested combination 73 of 672, taking 0.01 seconds to get val score of 0.1997:
#                 {'alpha': 0.01, 'fit_prior': False, 'features': 24},
#             Current best combo with val score 0.4422:
#                     {'alpha': 0.1, 'fit_prior': False, 'features': 5}
# Trained and Tested combination 74 of 672, taking 0.01 seconds to get val score of 0.0871:
#                 {'alpha': 0.01, 'fit_prior': True, 'features': 23},
#             Current best combo with val score 0.4422:
#                     {'alpha': 0.1, 'fit_prior': False, 'features': 5}
# Trained and Tested combination 75 of 672, taking 0.01 seconds to get val score of 0.0664:
#                 {'alpha': 0.01, 'fit_prior': True, 'features': 25},
#             Current best combo with val score 0.4422:
#                     {'alpha': 0.1, 'fit_prior': False, 'features': 5}
# Already Trained and Tested combination (val score of 0.0749):
#             {'alpha': 0.1, 'fit_prior': True, 'features': 24}
#             Current best combo (with val score 0.4422):
#                     {'alpha': 0.1, 'fit_prior': False, 'features': 5}
#         Has trained 75 of 672 combinations so far
# Trained and Tested combination 76 of 672, taking 0.01 seconds to get val score of 0.0752:
#                 {'alpha': 10, 'fit_prior': True, 'features': 24},
#             Current best combo with val score 0.4422:
#                     {'alpha': 0.1, 'fit_prior': False, 'features': 5}
# Trained and Tested combination 77 of 672, taking 0.01 seconds to get val score of 0.2023:
#                 {'alpha': 1, 'fit_prior': False, 'features': 24},
#             Current best combo with val score 0.4422:
#                     {'alpha': 0.1, 'fit_prior': False, 'features': 5}
# Trained and Tested combination 78 of 672, taking 0.01 seconds to get val score of 0.0869:
#                 {'alpha': 1, 'fit_prior': True, 'features': 23},
#             Current best combo with val score 0.4422:
#                     {'alpha': 0.1, 'fit_prior': False, 'features': 5}
# Trained and Tested combination 79 of 672, taking 0.01 seconds to get val score of 0.0663:
#                 {'alpha': 1, 'fit_prior': True, 'features': 25},
#             Current best combo with val score 0.4422:
#                     {'alpha': 0.1, 'fit_prior': False, 'features': 5}
# Already Trained and Tested combination (val score of 0.1997):
#             {'alpha': 0.01, 'fit_prior': False, 'features': 24}
#             Current best combo (with val score 0.4422):
#                     {'alpha': 0.1, 'fit_prior': False, 'features': 5}
#         Has trained 79 of 672 combinations so far
# Already Trained and Tested combination (val score of 0.2023):
#             {'alpha': 1, 'fit_prior': False, 'features': 24}
#             Current best combo (with val score 0.4422):
#                     {'alpha': 0.1, 'fit_prior': False, 'features': 5}
#         Has trained 79 of 672 combinations so far
# Already Trained and Tested combination (val score of 0.0749):
#             {'alpha': 0.1, 'fit_prior': True, 'features': 24}
#             Current best combo (with val score 0.4422):
#                     {'alpha': 0.1, 'fit_prior': False, 'features': 5}
#         Has trained 79 of 672 combinations so far
# Trained and Tested combination 80 of 672, taking 0.01 seconds to get val score of 0.2365:
#                 {'alpha': 0.1, 'fit_prior': False, 'features': 23},
#             Current best combo with val score 0.4422:
#                     {'alpha': 0.1, 'fit_prior': False, 'features': 5}
# Already Trained and Tested combination (val score of 0.1891):
#             {'alpha': 0.1, 'fit_prior': False, 'features': 25}
#             Current best combo (with val score 0.4422):
#                     {'alpha': 0.1, 'fit_prior': False, 'features': 5}
#         Has trained 80 of 672 combinations so far
# Already Trained and Tested combination (val score of 0.0871):
#             {'alpha': 0.01, 'fit_prior': True, 'features': 23}
#             Current best combo (with val score 0.4422):
#                     {'alpha': 0.1, 'fit_prior': False, 'features': 5}
#         Has trained 80 of 672 combinations so far
# Already Trained and Tested combination (val score of 0.0869):
#             {'alpha': 1, 'fit_prior': True, 'features': 23}
#             Current best combo (with val score 0.4422):
#                     {'alpha': 0.1, 'fit_prior': False, 'features': 5}
#         Has trained 80 of 672 combinations so far
# Already Trained and Tested combination (val score of 0.2365):
#             {'alpha': 0.1, 'fit_prior': False, 'features': 23}
#             Current best combo (with val score 0.4422):
#                     {'alpha': 0.1, 'fit_prior': False, 'features': 5}
#         Has trained 80 of 672 combinations so far
# Trained and Tested combination 81 of 672, taking 0.01 seconds to get val score of 0.1088:
#                 {'alpha': 0.1, 'fit_prior': True, 'features': 22},
#             Current best combo with val score 0.4422:
#                     {'alpha': 0.1, 'fit_prior': False, 'features': 5}
# Already Trained and Tested combination (val score of 0.0749):
#             {'alpha': 0.1, 'fit_prior': True, 'features': 24}
#             Current best combo (with val score 0.4422):
#                     {'alpha': 0.1, 'fit_prior': False, 'features': 5}
#         Has trained 81 of 672 combinations so far
# Trained and Tested combination 82 of 672, taking 0.0 seconds to get val score of 0.4422:
#                 {'alpha': 0.01, 'fit_prior': False, 'features': 5},
#             Current best combo with val score 0.4422:
#                     {'alpha': 0.1, 'fit_prior': False, 'features': 5}
# Trained and Tested combination 83 of 672, taking 0.0 seconds to get val score of 0.4422:
#                 {'alpha': 1, 'fit_prior': False, 'features': 5},
#             Current best combo with val score 0.4422:
#                     {'alpha': 0.1, 'fit_prior': False, 'features': 5}
# Already Trained and Tested combination (val score of 0.1271):
#             {'alpha': 0.1, 'fit_prior': True, 'features': 5}
#             Current best combo (with val score 0.4422):
#                     {'alpha': 0.1, 'fit_prior': False, 'features': 5}
#         Has trained 83 of 672 combinations so far
# Trained and Tested combination 84 of 672, taking 0.0 seconds to get val score of 0.1715:
#                 {'alpha': 0.1, 'fit_prior': False, 'features': 4},
#             Current best combo with val score 0.4422:
#                     {'alpha': 0.1, 'fit_prior': False, 'features': 5}
# Trained and Tested combination 85 of 672, taking 0.0 seconds to get val score of 0.4773:
#                 {'alpha': 0.1, 'fit_prior': False, 'features': 6},
#             Current best combo with val score 0.4773:
#                     {'alpha': 0.1, 'fit_prior': False, 'features': 6}
# Trained and Tested combination 86 of 672, taking 0.0 seconds to get val score of 0.4773:
#                 {'alpha': 0.01, 'fit_prior': False, 'features': 6},
#             Current best combo with val score 0.4773:
#                     {'alpha': 0.1, 'fit_prior': False, 'features': 6}
# Trained and Tested combination 87 of 672, taking 0.01 seconds to get val score of 0.4781:
#                 {'alpha': 1, 'fit_prior': False, 'features': 6},
#             Current best combo with val score 0.4781:
#                     {'alpha': 1, 'fit_prior': False, 'features': 6}
# Trained and Tested combination 88 of 672, taking 0.0 seconds to get val score of 0.1036:
#                 {'alpha': 0.1, 'fit_prior': True, 'features': 6},
#             Current best combo with val score 0.4781:
#                     {'alpha': 1, 'fit_prior': False, 'features': 6}
# Already Trained and Tested combination (val score of 0.4422):
#             {'alpha': 0.1, 'fit_prior': False, 'features': 5}
#             Current best combo (with val score 0.4781):
#                     {'alpha': 1, 'fit_prior': False, 'features': 6}
#         Has trained 88 of 672 combinations so far
# Trained and Tested combination 89 of 672, taking 0.0 seconds to get val score of 0.476:
#                 {'alpha': 0.1, 'fit_prior': False, 'features': 7},
#             Current best combo with val score 0.4781:
#                     {'alpha': 1, 'fit_prior': False, 'features': 6}
# Already Trained and Tested combination (val score of 0.4773):
#             {'alpha': 0.1, 'fit_prior': False, 'features': 6}
#             Current best combo (with val score 0.4781):
#                     {'alpha': 1, 'fit_prior': False, 'features': 6}
#         Has trained 89 of 672 combinations so far
# Trained and Tested combination 90 of 672, taking 0.0 seconds to get val score of 0.4803:
#                 {'alpha': 10, 'fit_prior': False, 'features': 6},
#             Current best combo with val score 0.4803:
#                     {'alpha': 10, 'fit_prior': False, 'features': 6}
# Trained and Tested combination 91 of 672, taking 0.0 seconds to get val score of 0.1036:
#                 {'alpha': 1, 'fit_prior': True, 'features': 6},
#             Current best combo with val score 0.4803:
#                     {'alpha': 10, 'fit_prior': False, 'features': 6}
# Already Trained and Tested combination (val score of 0.4422):
#             {'alpha': 1, 'fit_prior': False, 'features': 5}
#             Current best combo (with val score 0.4803):
#                     {'alpha': 10, 'fit_prior': False, 'features': 6}
#         Has trained 91 of 672 combinations so far
# Trained and Tested combination 92 of 672, taking 0.0 seconds to get val score of 0.4765:
#                 {'alpha': 1, 'fit_prior': False, 'features': 7},
#             Current best combo with val score 0.4803:
#                     {'alpha': 10, 'fit_prior': False, 'features': 6}
# Already Trained and Tested combination (val score of 0.4781):
#             {'alpha': 1, 'fit_prior': False, 'features': 6}
#             Current best combo (with val score 0.4803):
#                     {'alpha': 10, 'fit_prior': False, 'features': 6}
#         Has trained 92 of 672 combinations so far
# Trained and Tested combination 93 of 672, taking 0.0 seconds to get val score of 0.1751:
#                 {'alpha': 100, 'fit_prior': False, 'features': 6},
#             Current best combo with val score 0.4803:
#                     {'alpha': 10, 'fit_prior': False, 'features': 6}
# Trained and Tested combination 94 of 672, taking 0.0 seconds to get val score of 0.1036:
#                 {'alpha': 10, 'fit_prior': True, 'features': 6},
#             Current best combo with val score 0.4803:
#                     {'alpha': 10, 'fit_prior': False, 'features': 6}
# Trained and Tested combination 95 of 672, taking 0.0 seconds to get val score of 0.4062:
#                 {'alpha': 10, 'fit_prior': False, 'features': 5},
#             Current best combo with val score 0.4803:
#                     {'alpha': 10, 'fit_prior': False, 'features': 6}
# Trained and Tested combination 96 of 672, taking 0.0 seconds to get val score of 0.4774:
#                 {'alpha': 10, 'fit_prior': False, 'features': 7},
#             Current best combo with val score 0.4803:
#                     {'alpha': 10, 'fit_prior': False, 'features': 6}
# % Combos Checked Thus Far: 96 out of 672 which is 14.285713999999999%
# STAGE TWO: Begin Cruise system
#
#
# Cruising Coordrdinate 1 of 66
#
# Cruising Coordrdinate 2 of 66
#
# Cruising Coordrdinate 3 of 66
#
# Cruising Coordrdinate 4 of 66
#
# Cruising Coordrdinate 5 of 66
#
# Cruising Coordrdinate 6 of 66
#
# Cruising Coordrdinate 7 of 66
#
# Cruising Coordrdinate 8 of 66
#
# Cruising Coordrdinate 9 of 66
#
# Cruising Coordrdinate 10 of 66
#
# Cruising Coordrdinate 11 of 66
#
# Cruising Coordrdinate 12 of 66
#
# Cruising Coordrdinate 13 of 66
#
# Cruising Coordrdinate 14 of 66
#
# Cruising Coordrdinate 15 of 66
#
# Cruising Coordrdinate 16 of 66
#
# Cruising Coordrdinate 17 of 66
#
# Cruising Coordrdinate 18 of 66
#
# Cruising Coordrdinate 19 of 66
#
# Cruising Coordrdinate 20 of 66
#
# Cruise suspended due to suspicious case
# Guidance: round 1
#
# 	round 1 iteration:  0
#
# Trained and Tested combination 97 of 672, taking 0.01 seconds to get val score of 0.2641:
#                 {'alpha': 0.001, 'fit_prior': False, 'features': 35},
#             Current best combo with val score 0.4803:
#                     {'alpha': 10, 'fit_prior': False, 'features': 6}
# Already Trained and Tested combination (val score of 0.0921):
#             {'alpha': 0.0001, 'fit_prior': True, 'features': 35}
#             Current best combo (with val score 0.4803):
#                     {'alpha': 10, 'fit_prior': False, 'features': 6}
#         Has trained 97 of 672 combinations so far
# Trained and Tested combination 98 of 672, taking 0.01 seconds to get val score of 0.2728:
#                 {'alpha': 0.0001, 'fit_prior': False, 'features': 34},
#             Current best combo with val score 0.4803:
#                     {'alpha': 10, 'fit_prior': False, 'features': 6}
# Trained and Tested combination 99 of 672, taking 0.01 seconds to get val score of 0.2141:
#                 {'alpha': 0.0001, 'fit_prior': False, 'features': 36},
#             Current best combo with val score 0.4803:
#                     {'alpha': 10, 'fit_prior': False, 'features': 6}
# 	round 1 iteration:  1
#
# Already Trained and Tested combination (val score of 0.2641):
#             {'alpha': 0.0001, 'fit_prior': False, 'features': 35}
#             Current best combo (with val score 0.4803):
#                     {'alpha': 10, 'fit_prior': False, 'features': 6}
#         Has trained 99 of 672 combinations so far
# Trained and Tested combination 100 of 672, taking 0.01 seconds to get val score of 0.2641:
#                 {'alpha': 0.01, 'fit_prior': False, 'features': 35},
#             Current best combo with val score 0.4803:
#                     {'alpha': 10, 'fit_prior': False, 'features': 6}
# Trained and Tested combination 101 of 672, taking 0.01 seconds to get val score of 0.0921:
#                 {'alpha': 0.001, 'fit_prior': True, 'features': 35},
#             Current best combo with val score 0.4803:
#                     {'alpha': 10, 'fit_prior': False, 'features': 6}
# Trained and Tested combination 102 of 672, taking 0.01 seconds to get val score of 0.2728:
#                 {'alpha': 0.001, 'fit_prior': False, 'features': 34},
#             Current best combo with val score 0.4803:
#                     {'alpha': 10, 'fit_prior': False, 'features': 6}
# Trained and Tested combination 103 of 672, taking 0.01 seconds to get val score of 0.2141:
#                 {'alpha': 0.001, 'fit_prior': False, 'features': 36},
#             Current best combo with val score 0.4803:
#                     {'alpha': 10, 'fit_prior': False, 'features': 6}
# Already Trained and Tested combination (val score of 0.2728):
#             {'alpha': 0.001, 'fit_prior': False, 'features': 34}
#             Current best combo (with val score 0.4803):
#                     {'alpha': 10, 'fit_prior': False, 'features': 6}
#         Has trained 103 of 672 combinations so far
# Trained and Tested combination 104 of 672, taking 0.01 seconds to get val score of 0.1113:
#                 {'alpha': 0.0001, 'fit_prior': True, 'features': 34},
#             Current best combo with val score 0.4803:
#                     {'alpha': 10, 'fit_prior': False, 'features': 6}
# Trained and Tested combination 105 of 672, taking 0.01 seconds to get val score of 0.2731:
#                 {'alpha': 0.0001, 'fit_prior': False, 'features': 33},
#             Current best combo with val score 0.4803:
#                     {'alpha': 10, 'fit_prior': False, 'features': 6}
# Already Trained and Tested combination (val score of 0.2641):
#             {'alpha': 0.0001, 'fit_prior': False, 'features': 35}
#             Current best combo (with val score 0.4803):
#                     {'alpha': 10, 'fit_prior': False, 'features': 6}
#         Has trained 105 of 672 combinations so far
# % Combos Checked Thus Far: 105 out of 672 which is 15.625%
# Cruising Coordrdinate 21 of 66
#
# Cruising Coordrdinate 22 of 66
#
# Cruise suspended due to suspicious case
# Guidance: round 2
#
# 	round 2 iteration:  0
#
# Already Trained and Tested combination (val score of 0.2641):
#             {'alpha': 0.01, 'fit_prior': False, 'features': 35}
#             Current best combo (with val score 0.4803):
#                     {'alpha': 10, 'fit_prior': False, 'features': 6}
#         Has trained 105 of 672 combinations so far
# Trained and Tested combination 106 of 672, taking 0.01 seconds to get val score of 0.2557:
#                 {'alpha': 1, 'fit_prior': False, 'features': 35},
#             Current best combo with val score 0.4803:
#                     {'alpha': 10, 'fit_prior': False, 'features': 6}
# Already Trained and Tested combination (val score of 0.0891):
#             {'alpha': 0.1, 'fit_prior': True, 'features': 35}
#             Current best combo (with val score 0.4803):
#                     {'alpha': 10, 'fit_prior': False, 'features': 6}
#         Has trained 106 of 672 combinations so far
# Trained and Tested combination 107 of 672, taking 0.01 seconds to get val score of 0.2721:
#                 {'alpha': 0.1, 'fit_prior': False, 'features': 34},
#             Current best combo with val score 0.4803:
#                     {'alpha': 10, 'fit_prior': False, 'features': 6}
# Trained and Tested combination 108 of 672, taking 0.01 seconds to get val score of 0.2141:
#                 {'alpha': 0.1, 'fit_prior': False, 'features': 36},
#             Current best combo with val score 0.4803:
#                     {'alpha': 10, 'fit_prior': False, 'features': 6}
# 	round 2 iteration:  1
#
# Trained and Tested combination 109 of 672, taking 0.02 seconds to get val score of 0.2725:
#                 {'alpha': 0.01, 'fit_prior': False, 'features': 34},
#             Current best combo with val score 0.4803:
#                     {'alpha': 10, 'fit_prior': False, 'features': 6}
# Trained and Tested combination 110 of 672, taking 0.01 seconds to get val score of 0.2659:
#                 {'alpha': 1, 'fit_prior': False, 'features': 34},
#             Current best combo with val score 0.4803:
#                     {'alpha': 10, 'fit_prior': False, 'features': 6}
# Trained and Tested combination 111 of 672, taking 0.02 seconds to get val score of 0.1113:
#                 {'alpha': 0.1, 'fit_prior': True, 'features': 34},
#             Current best combo with val score 0.4803:
#                     {'alpha': 10, 'fit_prior': False, 'features': 6}
# Trained and Tested combination 112 of 672, taking 0.01 seconds to get val score of 0.2728:
#                 {'alpha': 0.1, 'fit_prior': False, 'features': 33},
#             Current best combo with val score 0.4803:
#                     {'alpha': 10, 'fit_prior': False, 'features': 6}
# Already Trained and Tested combination (val score of 0.2641):
#             {'alpha': 0.1, 'fit_prior': False, 'features': 35}
#             Current best combo (with val score 0.4803):
#                     {'alpha': 10, 'fit_prior': False, 'features': 6}
#         Has trained 112 of 672 combinations so far
# % Combos Checked Thus Far: 112 out of 672 which is 16.666667%
# Cruising Coordrdinate 23 of 66
#
# Cruising Coordrdinate 24 of 66
#
# Cruising Coordrdinate 25 of 66
#
# Cruising Coordrdinate 26 of 66
#
# Cruise suspended due to suspicious case
# Guidance: round 3
#
# 	round 3 iteration:  0
#
# Trained and Tested combination 113 of 672, taking 0.01 seconds to get val score of 0.2586:
#                 {'alpha': 0.001, 'fit_prior': False, 'features': 30},
#             Current best combo with val score 0.4803:
#                     {'alpha': 10, 'fit_prior': False, 'features': 6}
# Already Trained and Tested combination (val score of 0.0859):
#             {'alpha': 0.0001, 'fit_prior': True, 'features': 30}
#             Current best combo (with val score 0.4803):
#                     {'alpha': 10, 'fit_prior': False, 'features': 6}
#         Has trained 113 of 672 combinations so far
# Trained and Tested combination 114 of 672, taking 0.01 seconds to get val score of 0.2869:
#                 {'alpha': 0.0001, 'fit_prior': False, 'features': 29},
#             Current best combo with val score 0.4803:
#                     {'alpha': 10, 'fit_prior': False, 'features': 6}
# Trained and Tested combination 115 of 672, taking 0.01 seconds to get val score of 0.2656:
#                 {'alpha': 0.0001, 'fit_prior': False, 'features': 31},
#             Current best combo with val score 0.4803:
#                     {'alpha': 10, 'fit_prior': False, 'features': 6}
# 	round 3 iteration:  1
#
# Already Trained and Tested combination (val score of 0.2586):
#             {'alpha': 0.0001, 'fit_prior': False, 'features': 30}
#             Current best combo (with val score 0.4803):
#                     {'alpha': 10, 'fit_prior': False, 'features': 6}
#         Has trained 115 of 672 combinations so far
# Trained and Tested combination 116 of 672, taking 0.01 seconds to get val score of 0.2586:
#                 {'alpha': 0.01, 'fit_prior': False, 'features': 30},
#             Current best combo with val score 0.4803:
#                     {'alpha': 10, 'fit_prior': False, 'features': 6}
# Trained and Tested combination 117 of 672, taking 0.01 seconds to get val score of 0.0859:
#                 {'alpha': 0.001, 'fit_prior': True, 'features': 30},
#             Current best combo with val score 0.4803:
#                     {'alpha': 10, 'fit_prior': False, 'features': 6}
# Trained and Tested combination 118 of 672, taking 0.01 seconds to get val score of 0.2869:
#                 {'alpha': 0.001, 'fit_prior': False, 'features': 29},
#             Current best combo with val score 0.4803:
#                     {'alpha': 10, 'fit_prior': False, 'features': 6}
# Trained and Tested combination 119 of 672, taking 0.01 seconds to get val score of 0.2656:
#                 {'alpha': 0.001, 'fit_prior': False, 'features': 31},
#             Current best combo with val score 0.4803:
#                     {'alpha': 10, 'fit_prior': False, 'features': 6}
# Already Trained and Tested combination (val score of 0.2869):
#             {'alpha': 0.001, 'fit_prior': False, 'features': 29}
#             Current best combo (with val score 0.4803):
#                     {'alpha': 10, 'fit_prior': False, 'features': 6}
#         Has trained 119 of 672 combinations so far
# Trained and Tested combination 120 of 672, taking 0.01 seconds to get val score of 0.1113:
#                 {'alpha': 0.0001, 'fit_prior': True, 'features': 29},
#             Current best combo with val score 0.4803:
#                     {'alpha': 10, 'fit_prior': False, 'features': 6}
# Trained and Tested combination 121 of 672, taking 0.02 seconds to get val score of 0.267:
#                 {'alpha': 0.0001, 'fit_prior': False, 'features': 28},
#             Current best combo with val score 0.4803:
#                     {'alpha': 10, 'fit_prior': False, 'features': 6}
# Already Trained and Tested combination (val score of 0.2586):
#             {'alpha': 0.0001, 'fit_prior': False, 'features': 30}
#             Current best combo (with val score 0.4803):
#                     {'alpha': 10, 'fit_prior': False, 'features': 6}
#         Has trained 121 of 672 combinations so far
# Already Trained and Tested combination (val score of 0.2656):
#             {'alpha': 0.001, 'fit_prior': False, 'features': 31}
#             Current best combo (with val score 0.4803):
#                     {'alpha': 10, 'fit_prior': False, 'features': 6}
#         Has trained 121 of 672 combinations so far
# Trained and Tested combination 122 of 672, taking 0.01 seconds to get val score of 0.0943:
#                 {'alpha': 0.0001, 'fit_prior': True, 'features': 31},
#             Current best combo with val score 0.4803:
#                     {'alpha': 10, 'fit_prior': False, 'features': 6}
# Already Trained and Tested combination (val score of 0.2586):
#             {'alpha': 0.0001, 'fit_prior': False, 'features': 30}
#             Current best combo (with val score 0.4803):
#                     {'alpha': 10, 'fit_prior': False, 'features': 6}
#         Has trained 122 of 672 combinations so far
# Trained and Tested combination 123 of 672, taking 0.02 seconds to get val score of 0.2698:
#                 {'alpha': 0.0001, 'fit_prior': False, 'features': 32},
#             Current best combo with val score 0.4803:
#                     {'alpha': 10, 'fit_prior': False, 'features': 6}
# % Combos Checked Thus Far: 123 out of 672 which is 18.303570999999998%
# Cruising Coordrdinate 27 of 66
#
# Cruising Coordrdinate 28 of 66
#
# Cruise suspended due to suspicious case
# Guidance: round 4
#
# 	round 4 iteration:  0
#
# Already Trained and Tested combination (val score of 0.2586):
#             {'alpha': 0.01, 'fit_prior': False, 'features': 30}
#             Current best combo (with val score 0.4803):
#                     {'alpha': 10, 'fit_prior': False, 'features': 6}
#         Has trained 123 of 672 combinations so far
# Trained and Tested combination 124 of 672, taking 0.02 seconds to get val score of 0.2501:
#                 {'alpha': 1, 'fit_prior': False, 'features': 30},
#             Current best combo with val score 0.4803:
#                     {'alpha': 10, 'fit_prior': False, 'features': 6}
# Already Trained and Tested combination (val score of 0.0828):
#             {'alpha': 0.1, 'fit_prior': True, 'features': 30}
#             Current best combo (with val score 0.4803):
#                     {'alpha': 10, 'fit_prior': False, 'features': 6}
#         Has trained 124 of 672 combinations so far
# Trained and Tested combination 125 of 672, taking 0.02 seconds to get val score of 0.2869:
#                 {'alpha': 0.1, 'fit_prior': False, 'features': 29},
#             Current best combo with val score 0.4803:
#                     {'alpha': 10, 'fit_prior': False, 'features': 6}
# Trained and Tested combination 126 of 672, taking 0.01 seconds to get val score of 0.2653:
#                 {'alpha': 0.1, 'fit_prior': False, 'features': 31},
#             Current best combo with val score 0.4803:
#                     {'alpha': 10, 'fit_prior': False, 'features': 6}
# 	round 4 iteration:  1
#
# Trained and Tested combination 127 of 672, taking 0.02 seconds to get val score of 0.2869:
#                 {'alpha': 0.01, 'fit_prior': False, 'features': 29},
#             Current best combo with val score 0.4803:
#                     {'alpha': 10, 'fit_prior': False, 'features': 6}
# Trained and Tested combination 128 of 672, taking 0.01 seconds to get val score of 0.285:
#                 {'alpha': 1, 'fit_prior': False, 'features': 29},
#             Current best combo with val score 0.4803:
#                     {'alpha': 10, 'fit_prior': False, 'features': 6}
# Trained and Tested combination 129 of 672, taking 0.01 seconds to get val score of 0.1113:
#                 {'alpha': 0.1, 'fit_prior': True, 'features': 29},
#             Current best combo with val score 0.4803:
# ...
#                 {'alpha': 0.001, 'fit_prior': False, 'features': 6},
#             Current best combo with val score 0.4803:
#                     {'alpha': 10, 'fit_prior': False, 'features': 6}
# Already Trained and Tested combination (val score of 0.4773):
#             {'alpha': 0.001, 'fit_prior': False, 'features': 6}
#             Current best combo (with val score 0.4803):
#                     {'alpha': 10, 'fit_prior': False, 'features': 6}
#         Has trained 200 of 672 combinations so far
# Trained and Tested combination 201 of 672, taking 0.0 seconds to get val score of 0.1036:
#                 {'alpha': 0.0001, 'fit_prior': True, 'features': 6},
#             Current best combo with val score 0.4803:
#                     {'alpha': 10, 'fit_prior': False, 'features': 6}
# Already Trained and Tested combination (val score of 0.4422):
#             {'alpha': 0.0001, 'fit_prior': False, 'features': 5}
#             Current best combo (with val score 0.4803):
#                     {'alpha': 10, 'fit_prior': False, 'features': 6}
#         Has trained 201 of 672 combinations so far
# Trained and Tested combination 202 of 672, taking 0.0 seconds to get val score of 0.4763:
#                 {'alpha': 0.0001, 'fit_prior': False, 'features': 7},
#             Current best combo with val score 0.4803:
#                     {'alpha': 10, 'fit_prior': False, 'features': 6}
# % Combos Checked Thus Far: 202 out of 672 which is 30.059524%
# Cruising Coordrdinate 59 of 66
#
# Cruising Coordrdinate 60 of 66
#
# Cruise suspended due to suspicious case
# Guidance: round 14
#
# 	round 14 iteration:  0
#
# Already Trained and Tested combination (val score of 0.3389):
#             {'alpha': 0.01, 'fit_prior': False, 'features': 10}
#             Current best combo (with val score 0.4803):
#                     {'alpha': 10, 'fit_prior': False, 'features': 6}
#         Has trained 202 of 672 combinations so far
# Trained and Tested combination 203 of 672, taking 0.0 seconds to get val score of 0.3436:
#                 {'alpha': 1, 'fit_prior': False, 'features': 10},
#             Current best combo with val score 0.4803:
#                     {'alpha': 10, 'fit_prior': False, 'features': 6}
# Already Trained and Tested combination (val score of 0.0456):
#             {'alpha': 0.1, 'fit_prior': True, 'features': 10}
#             Current best combo (with val score 0.4803):
#                     {'alpha': 10, 'fit_prior': False, 'features': 6}
#         Has trained 203 of 672 combinations so far
# Trained and Tested combination 204 of 672, taking 0.0 seconds to get val score of 0.417:
#                 {'alpha': 0.1, 'fit_prior': False, 'features': 9},
#             Current best combo with val score 0.4803:
#                     {'alpha': 10, 'fit_prior': False, 'features': 6}
# Trained and Tested combination 205 of 672, taking 0.0 seconds to get val score of 0.3378:
#                 {'alpha': 0.1, 'fit_prior': False, 'features': 11},
#             Current best combo with val score 0.4803:
#                     {'alpha': 10, 'fit_prior': False, 'features': 6}
# 	round 14 iteration:  1
#
# Already Trained and Tested combination (val score of 0.3389):
#             {'alpha': 0.1, 'fit_prior': False, 'features': 10}
#             Current best combo (with val score 0.4803):
#                     {'alpha': 10, 'fit_prior': False, 'features': 6}
#         Has trained 205 of 672 combinations so far
# Trained and Tested combination 206 of 672, taking 0.0 seconds to get val score of 0.143:
#                 {'alpha': 10, 'fit_prior': False, 'features': 10},
#             Current best combo with val score 0.4803:
#                     {'alpha': 10, 'fit_prior': False, 'features': 6}
# Trained and Tested combination 207 of 672, taking 0.0 seconds to get val score of 0.0456:
#                 {'alpha': 1, 'fit_prior': True, 'features': 10},
#             Current best combo with val score 0.4803:
#                     {'alpha': 10, 'fit_prior': False, 'features': 6}
# Trained and Tested combination 208 of 672, taking 0.0 seconds to get val score of 0.4203:
#                 {'alpha': 1, 'fit_prior': False, 'features': 9},
#             Current best combo with val score 0.4803:
#                     {'alpha': 10, 'fit_prior': False, 'features': 6}
# Trained and Tested combination 209 of 672, taking 0.01 seconds to get val score of 0.3419:
#                 {'alpha': 1, 'fit_prior': False, 'features': 11},
#             Current best combo with val score 0.4803:
#                     {'alpha': 10, 'fit_prior': False, 'features': 6}
# Trained and Tested combination 210 of 672, taking 0.0 seconds to get val score of 0.417:
#                 {'alpha': 0.01, 'fit_prior': False, 'features': 9},
#             Current best combo with val score 0.4803:
#                     {'alpha': 10, 'fit_prior': False, 'features': 6}
# Already Trained and Tested combination (val score of 0.4203):
#             {'alpha': 1, 'fit_prior': False, 'features': 9}
#             Current best combo (with val score 0.4803):
#                     {'alpha': 10, 'fit_prior': False, 'features': 6}
#         Has trained 210 of 672 combinations so far
# Trained and Tested combination 211 of 672, taking 0.0 seconds to get val score of 0.1156:
#                 {'alpha': 0.1, 'fit_prior': True, 'features': 9},
#             Current best combo with val score 0.4803:
#                     {'alpha': 10, 'fit_prior': False, 'features': 6}
# Trained and Tested combination 212 of 672, taking 0.0 seconds to get val score of 0.4803:
#                 {'alpha': 0.1, 'fit_prior': False, 'features': 8},
#             Current best combo with val score 0.4803:
#                     {'alpha': 10, 'fit_prior': False, 'features': 6}
# Already Trained and Tested combination (val score of 0.3389):
#             {'alpha': 0.1, 'fit_prior': False, 'features': 10}
#             Current best combo (with val score 0.4803):
#                     {'alpha': 10, 'fit_prior': False, 'features': 6}
#         Has trained 212 of 672 combinations so far
# Trained and Tested combination 213 of 672, taking 0.0 seconds to get val score of 0.3378:
#                 {'alpha': 0.01, 'fit_prior': False, 'features': 11},
#             Current best combo with val score 0.4803:
#                     {'alpha': 10, 'fit_prior': False, 'features': 6}
# Already Trained and Tested combination (val score of 0.3419):
#             {'alpha': 1, 'fit_prior': False, 'features': 11}
#             Current best combo (with val score 0.4803):
#                     {'alpha': 10, 'fit_prior': False, 'features': 6}
#         Has trained 213 of 672 combinations so far
# Trained and Tested combination 214 of 672, taking 0.0 seconds to get val score of 0.0457:
#                 {'alpha': 0.1, 'fit_prior': True, 'features': 11},
#             Current best combo with val score 0.4803:
#                     {'alpha': 10, 'fit_prior': False, 'features': 6}
# Already Trained and Tested combination (val score of 0.3389):
#             {'alpha': 0.1, 'fit_prior': False, 'features': 10}
#             Current best combo (with val score 0.4803):
#                     {'alpha': 10, 'fit_prior': False, 'features': 6}
#         Has trained 214 of 672 combinations so far
# Trained and Tested combination 215 of 672, taking 0.0 seconds to get val score of 0.3343:
#                 {'alpha': 0.1, 'fit_prior': False, 'features': 12},
#             Current best combo with val score 0.4803:
#                     {'alpha': 10, 'fit_prior': False, 'features': 6}
# % Combos Checked Thus Far: 215 out of 672 which is 31.994048000000003%
# Cruising Coordrdinate 61 of 66
#
# Cruising Coordrdinate 62 of 66
#
# Cruising Coordrdinate 63 of 66
#
# Cruising Coordrdinate 64 of 66
#
# Cruise suspended due to suspicious case
# Guidance: round 15
#
# 	round 15 iteration:  0
#
# Already Trained and Tested combination (val score of 0.4422):
#             {'alpha': 0.01, 'fit_prior': False, 'features': 5}
#             Current best combo (with val score 0.4803):
#                     {'alpha': 10, 'fit_prior': False, 'features': 6}
#         Has trained 215 of 672 combinations so far
# Already Trained and Tested combination (val score of 0.4422):
#             {'alpha': 1, 'fit_prior': False, 'features': 5}
#             Current best combo (with val score 0.4803):
#                     {'alpha': 10, 'fit_prior': False, 'features': 6}
#         Has trained 215 of 672 combinations so far
# Already Trained and Tested combination (val score of 0.1271):
#             {'alpha': 0.1, 'fit_prior': True, 'features': 5}
#             Current best combo (with val score 0.4803):
#                     {'alpha': 10, 'fit_prior': False, 'features': 6}
#         Has trained 215 of 672 combinations so far
# Already Trained and Tested combination (val score of 0.1715):
#             {'alpha': 0.1, 'fit_prior': False, 'features': 4}
#             Current best combo (with val score 0.4803):
#                     {'alpha': 10, 'fit_prior': False, 'features': 6}
#         Has trained 215 of 672 combinations so far
# Already Trained and Tested combination (val score of 0.4773):
#             {'alpha': 0.1, 'fit_prior': False, 'features': 6}
#             Current best combo (with val score 0.4803):
#                     {'alpha': 10, 'fit_prior': False, 'features': 6}
#         Has trained 215 of 672 combinations so far
# 	round 15 iteration:  1
#
# Already Trained and Tested combination (val score of 0.4422):
#             {'alpha': 0.1, 'fit_prior': False, 'features': 5}
#             Current best combo (with val score 0.4803):
#                     {'alpha': 10, 'fit_prior': False, 'features': 6}
#         Has trained 215 of 672 combinations so far
# Already Trained and Tested combination (val score of 0.4062):
#             {'alpha': 10, 'fit_prior': False, 'features': 5}
#             Current best combo (with val score 0.4803):
#                     {'alpha': 10, 'fit_prior': False, 'features': 6}
#         Has trained 215 of 672 combinations so far
# Trained and Tested combination 216 of 672, taking 0.0 seconds to get val score of 0.1271:
#                 {'alpha': 1, 'fit_prior': True, 'features': 5},
#             Current best combo with val score 0.4803:
#                     {'alpha': 10, 'fit_prior': False, 'features': 6}
# Trained and Tested combination 217 of 672, taking 0.0 seconds to get val score of 0.1715:
#                 {'alpha': 1, 'fit_prior': False, 'features': 4},
#             Current best combo with val score 0.4803:
#                     {'alpha': 10, 'fit_prior': False, 'features': 6}
# Already Trained and Tested combination (val score of 0.4781):
#             {'alpha': 1, 'fit_prior': False, 'features': 6}
#             Current best combo (with val score 0.4803):
#                     {'alpha': 10, 'fit_prior': False, 'features': 6}
#         Has trained 217 of 672 combinations so far
# Already Trained and Tested combination (val score of 0.4773):
#             {'alpha': 0.01, 'fit_prior': False, 'features': 6}
#             Current best combo (with val score 0.4803):
#                     {'alpha': 10, 'fit_prior': False, 'features': 6}
#         Has trained 217 of 672 combinations so far
# Already Trained and Tested combination (val score of 0.4781):
#             {'alpha': 1, 'fit_prior': False, 'features': 6}
#             Current best combo (with val score 0.4803):
#                     {'alpha': 10, 'fit_prior': False, 'features': 6}
#         Has trained 217 of 672 combinations so far
# Already Trained and Tested combination (val score of 0.1036):
#             {'alpha': 0.1, 'fit_prior': True, 'features': 6}
#             Current best combo (with val score 0.4803):
#                     {'alpha': 10, 'fit_prior': False, 'features': 6}
#         Has trained 217 of 672 combinations so far
# Already Trained and Tested combination (val score of 0.4422):
#             {'alpha': 0.1, 'fit_prior': False, 'features': 5}
#             Current best combo (with val score 0.4803):
#                     {'alpha': 10, 'fit_prior': False, 'features': 6}
#         Has trained 217 of 672 combinations so far
# Already Trained and Tested combination (val score of 0.476):
#             {'alpha': 0.1, 'fit_prior': False, 'features': 7}
#             Current best combo (with val score 0.4803):
#                     {'alpha': 10, 'fit_prior': False, 'features': 6}
#         Has trained 217 of 672 combinations so far
# % Combos Checked Thus Far: 217 out of 672 which is 32.291667000000004%
# Cruising Coordrdinate 65 of 66
#
# Cruising Coordrdinate 66 of 66
#
# FINAL STAGE: Begin final Guidance system
#
#
# Guidance: round FINAL
#
# 	round FINAL iteration:  0
#
# Already Trained and Tested combination (val score of 0.4781):
#             {'alpha': 1, 'fit_prior': False, 'features': 6}
#             Current best combo (with val score 0.4803):
#                     {'alpha': 10, 'fit_prior': False, 'features': 6}
#         Has trained 217 of 672 combinations so far
# Already Trained and Tested combination (val score of 0.1751):
#             {'alpha': 100, 'fit_prior': False, 'features': 6}
#             Current best combo (with val score 0.4803):
#                     {'alpha': 10, 'fit_prior': False, 'features': 6}
#         Has trained 217 of 672 combinations so far
# Already Trained and Tested combination (val score of 0.1036):
#             {'alpha': 10, 'fit_prior': True, 'features': 6}
#             Current best combo (with val score 0.4803):
#                     {'alpha': 10, 'fit_prior': False, 'features': 6}
#         Has trained 217 of 672 combinations so far
# Already Trained and Tested combination (val score of 0.4062):
#             {'alpha': 10, 'fit_prior': False, 'features': 5}
#             Current best combo (with val score 0.4803):
#                     {'alpha': 10, 'fit_prior': False, 'features': 6}
#         Has trained 217 of 672 combinations so far
# Already Trained and Tested combination (val score of 0.4774):
#             {'alpha': 10, 'fit_prior': False, 'features': 7}
#             Current best combo (with val score 0.4803):
#                     {'alpha': 10, 'fit_prior': False, 'features': 6}
#         Has trained 217 of 672 combinations so far
# 	round FINAL iteration:  1
#
# Already Trained and Tested combination (val score of 0.4765):
#             {'alpha': 1, 'fit_prior': False, 'features': 7}
#             Current best combo (with val score 0.4803):
#                     {'alpha': 10, 'fit_prior': False, 'features': 6}
#         Has trained 217 of 672 combinations so far
# Trained and Tested combination 218 of 672, taking 0.0 seconds to get val score of 0.192:
#                 {'alpha': 100, 'fit_prior': False, 'features': 7},
#             Current best combo with val score 0.4803:
#                     {'alpha': 10, 'fit_prior': False, 'features': 6}
# Trained and Tested combination 219 of 672, taking 0.0 seconds to get val score of 0.1191:
#                 {'alpha': 10, 'fit_prior': True, 'features': 7},
#             Current best combo with val score 0.4803:
#                     {'alpha': 10, 'fit_prior': False, 'features': 6}
# Already Trained and Tested combination (val score of 0.4803):
#             {'alpha': 10, 'fit_prior': False, 'features': 6}
#             Current best combo (with val score 0.4803):
#                     {'alpha': 10, 'fit_prior': False, 'features': 6}
#         Has trained 219 of 672 combinations so far
# Trained and Tested combination 220 of 672, taking 0.0 seconds to get val score of 0.4774:
#                 {'alpha': 10, 'fit_prior': False, 'features': 8},
#             Current best combo with val score 0.4803:
#                     {'alpha': 10, 'fit_prior': False, 'features': 6}
# % Combos Checked Thus Far: 220 out of 672 which is 32.738095%
# Max Val Score:
#  0.480334
# Max Val Score Std:
#  0.032096
# Best Combo Train Score:
#  0.478386
# Best Combo Train Score Std:
#  0.004432
# Max Combo Index:
#  (5, 0, 6) out of [7, 2, 48] (note best combo is 0-indexed)
# Max Combo Hyperparamer Combination:
#  {'alpha': 10, 'fit_prior': False, 'features': 6}
# Max Combo Features:
#  ('procedure_225792', 'ventilation_used', 'procedure_226475', 'lods_score', 'procedure_225802', 'hospital_stay_duration', 'procedure_224276')
# % Combos Checked: 220 out of 672 which is 32.738095%
