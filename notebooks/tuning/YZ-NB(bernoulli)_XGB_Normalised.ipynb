# %% [markdown]
# # Tuning Script

# %%
# Parameters subject to change in every script - involved in naming

MODEL = 'nb(bernoulli)'
PREPROCESSING = 'normalise'
TUNER = 'yangzhoub'
OPTIMISED_METRIC = 'f1'

# %% [markdown]
# ---

# %%
# detect whether this is a google environment

COLAB_ENVIRONMENT = False

try:
    from google.colab import drive
    drive.mount('/content/drive')
    COLAB_ENVIRONMENT = True
except:
    pass
# Out:
# Mounted at /content/drive

# %%
import sys
import os
import pickle

if COLAB_ENVIRONMENT:
    home_directory = './drive/MyDrive/LAB/COMP90089__GroupWork__Py/' # my home directory is stored in ./LAB of google drive
    if MODEL == 'ebr':
        # !pip install interpret==0.5.0
    elif MODEL == 'cbr':
        # !pip install catboost
    elif MODEL in ['tf', 'mlp']:
        # !pip install PyTorch2Sklearn
    # !pip install JXAutoML
else:
    home_directory = '../../'

from JXAutoML.YangZhouB_10CV import YangZhouB_10CV as Tuner

import pandas as pd
# Out:
# Requirement already satisfied: JXAutoML in /usr/local/lib/python3.10/dist-packages (0.4.4)

# %%
# Parameters that are same for every script

FOLDS = 10  # we have decided to do 10 fold validation

SEED = 42

TASK_TYPE = 'Classification'  # this task is a classification task

# we have decided to tune features as hp
TUNE_FEATURES_AS_HYPERPARAMETERS = True

# %% [markdown]
# ---

# %%
# model to use to tune
from sklearn.naive_bayes import BernoulliNB as clf

# what values to try for each hyperparameter
parameter_choices = {
    'alpha': (0.0001, 0.001, 0.01, 0.1, 1, 10, 100),
    'fit_prior': (False, True)
}

# what values to set non-tuneable parameters/hyperparameters
non_tunable_hyperparameters_dict = {}

# %% [markdown]
# ---

# %% [markdown]
# Read in and Prepare Data

# %%
# Import data and store as lists

train_x_list = []
train_y_list = []
val_x_list = []
val_y_list = []

for i in range(FOLDS):
    train_data = pd.read_csv(
        f'{home_directory}data/curated/modelling/{PREPROCESSING}/train_{i}.csv')
    val_data = pd.read_csv(
        f'{home_directory}data/curated/modelling/{PREPROCESSING}/val_{i}.csv')

    # get the correct rows for X and y
    train_x = train_data.drop(
        ['mortality_status', 'subject_id', 'hadm_id', 'stay_id'], axis=1)
    train_y = train_data['mortality_status']
    val_x = val_data.drop(
        ['mortality_status', 'subject_id', 'hadm_id', 'stay_id'], axis=1)
    val_y = val_data['mortality_status']

    train_x_list.append(train_x)
    train_y_list.append(train_y)
    val_x_list.append(val_x)
    val_y_list.append(val_y)

# %%
# Import feature importance ordering

with open(f'{home_directory}models/xgb_feature_importance_ordering_{PREPROCESSING}.pickle', 'rb') as f:
    feature_importance_ordering = pickle.load(f)

# %% [markdown]
# Set parameters

# %%
# initialisation
tuner = Tuner()

print('---')

# define what model we are tuning
tuner.read_in_model(clf, TASK_TYPE, optimised_metric=OPTIMISED_METRIC)

print('---')

# read in the data for training and validation
tuner.read_in_data(train_x_list, train_y_list, val_x_list, val_y_list)

print('---')

# set what hp values to tune
tuner.set_hyperparameters(parameter_choices)
# WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

# set up hp values that need to be changed from default but NOT to be tuned
tuner.set_non_tuneable_hyperparameters(non_tunable_hyperparameters_dict)

print('---')

# set up feature importance ordering

if TUNE_FEATURES_AS_HYPERPARAMETERS:
    tuner.set_features(feature_importance_ordering)
    # WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

try:  # try to read in previous results to continue tuning ...
    tuner.read_in_tuning_result_df(
        f'{home_directory}models/tuning/{TUNER}_{MODEL}_{PREPROCESSING}.csv')
except:
    print('No previous tuning data read in')

print('---')

# set up where to save the tuning result csv
tuner.set_tuning_result_saving_address(
    f'{home_directory}models/tuning/{TUNER}_{MODEL}_{PREPROCESSING}.csv')

print('---')

# set up where to save the current best model
tuner.set_best_model_saving_address(
    f'{home_directory}models/tmp_models/{TUNER}_{MODEL}_{PREPROCESSING}')
# Out:
# YangZhouB Initialised
# ---
# Successfully read in model <class 'sklearn.naive_bayes.BernoulliNB'>, which is a Classification model optimising for f1
# ---
# Read in Train X data list
# Read in Train y data list
# Read in Val X data list
# Read in Val y data list
# ---
# Successfully recorded hyperparameter choices
# ---
# Successfully recorded non_tuneable_hyperparameter choices
# ---
# Successfully recorded tuneable feature combination choices and updated relevant internal structures
# ---
# No previous tuning data read in
# ---
# Successfully set tuning output address
# ---
# Successfully set best model output address

# %%
# ignore warnings

import warnings
warnings.filterwarnings("ignore")

# %%
# begin tuning ... (or continue training)

tuner.tune()
# Out:
# BEGIN TUNING
#
#
# STAGE ZERO: Tune all Cruise combinations
#
#
# Trained and Tested combination 1 of 1008, taking 0.01 seconds to get val score of 0.3576:
#                 {'alpha': 0.1, 'fit_prior': True, 'features': 20},
#             Current best combo with val score 0.3576:
#                     {'alpha': 0.1, 'fit_prior': True, 'features': 20}
# Trained and Tested combination 2 of 1008, taking 0.01 seconds to get val score of 0.4325:
#                 {'alpha': 0.1, 'fit_prior': True, 'features': 15},
#             Current best combo with val score 0.4325:
#                     {'alpha': 0.1, 'fit_prior': True, 'features': 15}
# Trained and Tested combination 3 of 1008, taking 0.01 seconds to get val score of 0.4477:
#                 {'alpha': 0.1, 'fit_prior': False, 'features': 20},
#             Current best combo with val score 0.4477:
#                     {'alpha': 0.1, 'fit_prior': False, 'features': 20}
# Trained and Tested combination 4 of 1008, taking 0.02 seconds to get val score of 0.4417:
#                 {'alpha': 0.0001, 'fit_prior': False, 'features': 10},
#             Current best combo with val score 0.4477:
#                     {'alpha': 0.1, 'fit_prior': False, 'features': 20}
# Trained and Tested combination 5 of 1008, taking 0.03 seconds to get val score of 0.416:
#                 {'alpha': 0.1, 'fit_prior': False, 'features': 59},
#             Current best combo with val score 0.4477:
#                     {'alpha': 0.1, 'fit_prior': False, 'features': 20}
# Trained and Tested combination 6 of 1008, taking 0.01 seconds to get val score of 0.4477:
#                 {'alpha': 0.0001, 'fit_prior': False, 'features': 20},
#             Current best combo with val score 0.4477:
#                     {'alpha': 0.1, 'fit_prior': False, 'features': 20}
# Trained and Tested combination 7 of 1008, taking 0.01 seconds to get val score of 0.3589:
#                 {'alpha': 0.1, 'fit_prior': True, 'features': 25},
#             Current best combo with val score 0.4477:
#                     {'alpha': 0.1, 'fit_prior': False, 'features': 20}
# Trained and Tested combination 8 of 1008, taking 0.01 seconds to get val score of 0.3576:
#                 {'alpha': 0.0001, 'fit_prior': True, 'features': 20},
#             Current best combo with val score 0.4477:
#                     {'alpha': 0.1, 'fit_prior': False, 'features': 20}
# Trained and Tested combination 9 of 1008, taking 0.01 seconds to get val score of 0.3879:
#                 {'alpha': 0.0001, 'fit_prior': False, 'features': 40},
#             Current best combo with val score 0.4477:
#                     {'alpha': 0.1, 'fit_prior': False, 'features': 20}
# Trained and Tested combination 10 of 1008, taking 0.05 seconds to get val score of 0.1082:
#                 {'alpha': 100, 'fit_prior': False, 'features': 50},
#             Current best combo with val score 0.4477:
#                     {'alpha': 0.1, 'fit_prior': False, 'features': 20}
# Trained and Tested combination 11 of 1008, taking 0.03 seconds to get val score of 0.4146:
#                 {'alpha': 0.1, 'fit_prior': False, 'features': 67},
#             Current best combo with val score 0.4477:
#                     {'alpha': 0.1, 'fit_prior': False, 'features': 20}
# Trained and Tested combination 12 of 1008, taking 0.01 seconds to get val score of 0.2534:
#                 {'alpha': 0.0001, 'fit_prior': True, 'features': 45},
#             Current best combo with val score 0.4477:
#                     {'alpha': 0.1, 'fit_prior': False, 'features': 20}
# Trained and Tested combination 13 of 1008, taking 0.0 seconds to get val score of 0.2933:
#                 {'alpha': 0.0001, 'fit_prior': True, 'features': 0},
#             Current best combo with val score 0.4477:
#                     {'alpha': 0.1, 'fit_prior': False, 'features': 20}
# Trained and Tested combination 14 of 1008, taking 0.02 seconds to get val score of 0.298:
#                 {'alpha': 0.0001, 'fit_prior': True, 'features': 50},
#             Current best combo with val score 0.4477:
#                     {'alpha': 0.1, 'fit_prior': False, 'features': 20}
# Trained and Tested combination 15 of 1008, taking 0.0 seconds to get val score of 0.3867:
#                 {'alpha': 100, 'fit_prior': False, 'features': 5},
#             Current best combo with val score 0.4477:
#                     {'alpha': 0.1, 'fit_prior': False, 'features': 20}
# Trained and Tested combination 16 of 1008, taking 0.0 seconds to get val score of 0.2933:
#                 {'alpha': 0.1, 'fit_prior': True, 'features': 0},
#             Current best combo with val score 0.4477:
#                     {'alpha': 0.1, 'fit_prior': False, 'features': 20}
# Trained and Tested combination 17 of 1008, taking 0.03 seconds to get val score of 0.334:
#                 {'alpha': 0.0001, 'fit_prior': True, 'features': 55},
#             Current best combo with val score 0.4477:
#                     {'alpha': 0.1, 'fit_prior': False, 'features': 20}
# Trained and Tested combination 18 of 1008, taking 0.02 seconds to get val score of 0.4002:
#                 {'alpha': 0.1, 'fit_prior': False, 'features': 35},
#             Current best combo with val score 0.4477:
#                     {'alpha': 0.1, 'fit_prior': False, 'features': 20}
# Trained and Tested combination 19 of 1008, taking 0.03 seconds to get val score of 0.3367:
#                 {'alpha': 0.1, 'fit_prior': True, 'features': 55},
#             Current best combo with val score 0.4477:
#                     {'alpha': 0.1, 'fit_prior': False, 'features': 20}
# Trained and Tested combination 20 of 1008, taking 0.01 seconds to get val score of 0.1184:
#                 {'alpha': 100, 'fit_prior': False, 'features': 67},
#             Current best combo with val score 0.4477:
#                     {'alpha': 0.1, 'fit_prior': False, 'features': 20}
# Trained and Tested combination 21 of 1008, taking 0.01 seconds to get val score of 0.2969:
#                 {'alpha': 100, 'fit_prior': False, 'features': 20},
#             Current best combo with val score 0.4477:
#                     {'alpha': 0.1, 'fit_prior': False, 'features': 20}
# Trained and Tested combination 22 of 1008, taking 0.0 seconds to get val score of 0.431:
#                 {'alpha': 0.0001, 'fit_prior': True, 'features': 15},
#             Current best combo with val score 0.4477:
#                     {'alpha': 0.1, 'fit_prior': False, 'features': 20}
# Trained and Tested combination 23 of 1008, taking 0.01 seconds to get val score of 0.0695:
#                 {'alpha': 100, 'fit_prior': True, 'features': 55},
#             Current best combo with val score 0.4477:
#                     {'alpha': 0.1, 'fit_prior': False, 'features': 20}
# Trained and Tested combination 24 of 1008, taking 0.0 seconds to get val score of 0.4891:
#                 {'alpha': 0.1, 'fit_prior': False, 'features': 15},
#             Current best combo with val score 0.4891:
#                     {'alpha': 0.1, 'fit_prior': False, 'features': 15}
# Trained and Tested combination 25 of 1008, taking 0.01 seconds to get val score of 0.1238:
#                 {'alpha': 100, 'fit_prior': True, 'features': 45},
#             Current best combo with val score 0.4891:
#                     {'alpha': 0.1, 'fit_prior': False, 'features': 15}
# Trained and Tested combination 26 of 1008, taking 0.0 seconds to get val score of 0.1941:
#                 {'alpha': 100, 'fit_prior': True, 'features': 5},
#             Current best combo with val score 0.4891:
#                     {'alpha': 0.1, 'fit_prior': False, 'features': 15}
# Trained and Tested combination 27 of 1008, taking 0.01 seconds to get val score of 0.3477:
#                 {'alpha': 0.0001, 'fit_prior': True, 'features': 63},
#             Current best combo with val score 0.4891:
#                     {'alpha': 0.1, 'fit_prior': False, 'features': 15}
# Trained and Tested combination 28 of 1008, taking 0.01 seconds to get val score of 0.3446:
#                 {'alpha': 0.1, 'fit_prior': False, 'features': 45},
#             Current best combo with val score 0.4891:
#                     {'alpha': 0.1, 'fit_prior': False, 'features': 15}
# Trained and Tested combination 29 of 1008, taking 0.01 seconds to get val score of 0.282:
#                 {'alpha': 0.1, 'fit_prior': True, 'features': 35},
#             Current best combo with val score 0.4891:
#                     {'alpha': 0.1, 'fit_prior': False, 'features': 15}
# Trained and Tested combination 30 of 1008, taking 0.0 seconds to get val score of 0.299:
#                 {'alpha': 0.0001, 'fit_prior': True, 'features': 30},
#             Current best combo with val score 0.4891:
#                     {'alpha': 0.1, 'fit_prior': False, 'features': 15}
# Trained and Tested combination 31 of 1008, taking 0.0 seconds to get val score of 0.2423:
#                 {'alpha': 100, 'fit_prior': False, 'features': 30},
#             Current best combo with val score 0.4891:
#                     {'alpha': 0.1, 'fit_prior': False, 'features': 15}
# Trained and Tested combination 32 of 1008, taking 0.01 seconds to get val score of 0.222:
#                 {'alpha': 100, 'fit_prior': False, 'features': 35},
#             Current best combo with val score 0.4891:
#                     {'alpha': 0.1, 'fit_prior': False, 'features': 15}
# Trained and Tested combination 33 of 1008, taking 0.0 seconds to get val score of 0.4081:
#                 {'alpha': 0.1, 'fit_prior': False, 'features': 5},
#             Current best combo with val score 0.4891:
#                     {'alpha': 0.1, 'fit_prior': False, 'features': 15}
# Trained and Tested combination 34 of 1008, taking 0.0 seconds to get val score of 0.4296:
#                 {'alpha': 0.0001, 'fit_prior': True, 'features': 10},
#             Current best combo with val score 0.4891:
#                     {'alpha': 0.1, 'fit_prior': False, 'features': 15}
# Trained and Tested combination 35 of 1008, taking 0.0 seconds to get val score of 0.3958:
#                 {'alpha': 0.0001, 'fit_prior': True, 'features': 5},
#             Current best combo with val score 0.4891:
#                     {'alpha': 0.1, 'fit_prior': False, 'features': 15}
# Trained and Tested combination 36 of 1008, taking 0.01 seconds to get val score of 0.3589:
#                 {'alpha': 0.0001, 'fit_prior': True, 'features': 25},
#             Current best combo with val score 0.4891:
#                     {'alpha': 0.1, 'fit_prior': False, 'features': 15}
# Trained and Tested combination 37 of 1008, taking 0.01 seconds to get val score of 0.1159:
#                 {'alpha': 100, 'fit_prior': False, 'features': 71},
#             Current best combo with val score 0.4891:
#                     {'alpha': 0.1, 'fit_prior': False, 'features': 15}
# Trained and Tested combination 38 of 1008, taking 0.01 seconds to get val score of 0.3499:
#                 {'alpha': 0.1, 'fit_prior': True, 'features': 63},
#             Current best combo with val score 0.4891:
#                     {'alpha': 0.1, 'fit_prior': False, 'features': 15}
# Trained and Tested combination 39 of 1008, taking 0.01 seconds to get val score of 0.1169:
#                 {'alpha': 100, 'fit_prior': False, 'features': 59},
#             Current best combo with val score 0.4891:
#                     {'alpha': 0.1, 'fit_prior': False, 'features': 15}
# Trained and Tested combination 40 of 1008, taking 0.01 seconds to get val score of 0.4312:
#                 {'alpha': 0.0001, 'fit_prior': False, 'features': 30},
#             Current best combo with val score 0.4891:
#                     {'alpha': 0.1, 'fit_prior': False, 'features': 15}
# Trained and Tested combination 41 of 1008, taking 0.01 seconds to get val score of 0.1308:
#                 {'alpha': 100, 'fit_prior': True, 'features': 40},
#             Current best combo with val score 0.4891:
#                     {'alpha': 0.1, 'fit_prior': False, 'features': 15}
# Trained and Tested combination 42 of 1008, taking 0.01 seconds to get val score of 0.2897:
#                 {'alpha': 100, 'fit_prior': False, 'features': 25},
#             Current best combo with val score 0.4891:
#                     {'alpha': 0.1, 'fit_prior': False, 'features': 15}
# Trained and Tested combination 43 of 1008, taking 0.0 seconds to get val score of 0.4417:
#                 {'alpha': 0.1, 'fit_prior': False, 'features': 10},
#             Current best combo with val score 0.4891:
#                     {'alpha': 0.1, 'fit_prior': False, 'features': 15}
# Trained and Tested combination 44 of 1008, taking 0.01 seconds to get val score of 0.077:
#                 {'alpha': 100, 'fit_prior': True, 'features': 63},
#             Current best combo with val score 0.4891:
#                     {'alpha': 0.1, 'fit_prior': False, 'features': 15}
# Trained and Tested combination 45 of 1008, taking 0.01 seconds to get val score of 0.4066:
#                 {'alpha': 0.0001, 'fit_prior': False, 'features': 55},
#             Current best combo with val score 0.4891:
#                     {'alpha': 0.1, 'fit_prior': False, 'features': 15}
# Trained and Tested combination 46 of 1008, taking 0.0 seconds to get val score of 0.4298:
#                 {'alpha': 0.1, 'fit_prior': False, 'features': 30},
#             Current best combo with val score 0.4891:
#                     {'alpha': 0.1, 'fit_prior': False, 'features': 15}
# Trained and Tested combination 47 of 1008, taking 0.01 seconds to get val score of 0.4081:
#                 {'alpha': 0.1, 'fit_prior': False, 'features': 55},
#             Current best combo with val score 0.4891:
#                     {'alpha': 0.1, 'fit_prior': False, 'features': 15}
# Trained and Tested combination 48 of 1008, taking 0.01 seconds to get val score of 0.0778:
#                 {'alpha': 100, 'fit_prior': True, 'features': 59},
#             Current best combo with val score 0.4891:
#                     {'alpha': 0.1, 'fit_prior': False, 'features': 15}
# Trained and Tested combination 49 of 1008, taking 0.02 seconds to get val score of 0.282:
#                 {'alpha': 0.0001, 'fit_prior': True, 'features': 35},
#             Current best combo with val score 0.4891:
#                     {'alpha': 0.1, 'fit_prior': False, 'features': 15}
# Trained and Tested combination 50 of 1008, taking 0.0 seconds to get val score of 0.2659:
#                 {'alpha': 100, 'fit_prior': True, 'features': 15},
#             Current best combo with val score 0.4891:
#                     {'alpha': 0.1, 'fit_prior': False, 'features': 15}
# Trained and Tested combination 51 of 1008, taking 0.0 seconds to get val score of 0.1763:
#                 {'alpha': 100, 'fit_prior': True, 'features': 20},
#             Current best combo with val score 0.4891:
#                     {'alpha': 0.1, 'fit_prior': False, 'features': 15}
# Trained and Tested combination 52 of 1008, taking 0.01 seconds to get val score of 0.1997:
#                 {'alpha': 100, 'fit_prior': False, 'features': 45},
#             Current best combo with val score 0.4891:
#                     {'alpha': 0.1, 'fit_prior': False, 'features': 15}
# Trained and Tested combination 53 of 1008, taking 0.01 seconds to get val score of 0.4145:
#                 {'alpha': 0.1, 'fit_prior': False, 'features': 63},
#             Current best combo with val score 0.4891:
#                     {'alpha': 0.1, 'fit_prior': False, 'features': 15}
# Trained and Tested combination 54 of 1008, taking 0.01 seconds to get val score of 0.413:
#                 {'alpha': 0.0001, 'fit_prior': False, 'features': 63},
#             Current best combo with val score 0.4891:
#                     {'alpha': 0.1, 'fit_prior': False, 'features': 15}
# Trained and Tested combination 55 of 1008, taking 0.0 seconds to get val score of 0.438:
#                 {'alpha': 100, 'fit_prior': False, 'features': 10},
#             Current best combo with val score 0.4891:
#                     {'alpha': 0.1, 'fit_prior': False, 'features': 15}
# Trained and Tested combination 56 of 1008, taking 0.0 seconds to get val score of 0.4296:
#                 {'alpha': 0.1, 'fit_prior': True, 'features': 10},
#             Current best combo with val score 0.4891:
#                     {'alpha': 0.1, 'fit_prior': False, 'features': 15}
# Trained and Tested combination 57 of 1008, taking 0.0 seconds to get val score of 0.2933:
#                 {'alpha': 0.1, 'fit_prior': False, 'features': 0},
#             Current best combo with val score 0.4891:
#                     {'alpha': 0.1, 'fit_prior': False, 'features': 15}
# Trained and Tested combination 58 of 1008, taking 0.01 seconds to get val score of 0.3446:
#                 {'alpha': 0.0001, 'fit_prior': False, 'features': 45},
#             Current best combo with val score 0.4891:
#                     {'alpha': 0.1, 'fit_prior': False, 'features': 15}
# Trained and Tested combination 59 of 1008, taking 0.0 seconds to get val score of 0.4081:
#                 {'alpha': 0.0001, 'fit_prior': False, 'features': 5},
#             Current best combo with val score 0.4891:
#                     {'alpha': 0.1, 'fit_prior': False, 'features': 15}
# Trained and Tested combination 60 of 1008, taking 0.01 seconds to get val score of 0.301:
#                 {'alpha': 0.1, 'fit_prior': True, 'features': 50},
#             Current best combo with val score 0.4891:
#                     {'alpha': 0.1, 'fit_prior': False, 'features': 15}
# Trained and Tested combination 61 of 1008, taking 0.01 seconds to get val score of 0.1333:
#                 {'alpha': 100, 'fit_prior': True, 'features': 35},
#             Current best combo with val score 0.4891:
#                     {'alpha': 0.1, 'fit_prior': False, 'features': 15}
# Trained and Tested combination 62 of 1008, taking 0.02 seconds to get val score of 0.3458:
#                 {'alpha': 0.0001, 'fit_prior': True, 'features': 67},
#             Current best combo with val score 0.4891:
#                     {'alpha': 0.1, 'fit_prior': False, 'features': 15}
# Trained and Tested combination 63 of 1008, taking 0.01 seconds to get val score of 0.4834:
#                 {'alpha': 0.1, 'fit_prior': False, 'features': 25},
#             Current best combo with val score 0.4891:
#                     {'alpha': 0.1, 'fit_prior': False, 'features': 15}
# Trained and Tested combination 64 of 1008, taking 0.02 seconds to get val score of 0.1074:
#                 {'alpha': 100, 'fit_prior': False, 'features': 55},
#             Current best combo with val score 0.4891:
#                     {'alpha': 0.1, 'fit_prior': False, 'features': 15}
# Trained and Tested combination 65 of 1008, taking 0.01 seconds to get val score of 0.4177:
#                 {'alpha': 0.0001, 'fit_prior': False, 'features': 71},
#             Current best combo with val score 0.4891:
#                     {'alpha': 0.1, 'fit_prior': False, 'features': 15}
# Trained and Tested combination 66 of 1008, taking 0.01 seconds to get val score of 0.1179:
#                 {'alpha': 100, 'fit_prior': False, 'features': 63},
#             Current best combo with val score 0.4891:
#                     {'alpha': 0.1, 'fit_prior': False, 'features': 15}
# Trained and Tested combination 67 of 1008, taking 0.01 seconds to get val score of 0.3879:
#                 {'alpha': 0.1, 'fit_prior': False, 'features': 40},
#             Current best combo with val score 0.4891:
#                     {'alpha': 0.1, 'fit_prior': False, 'features': 15}
# Trained and Tested combination 68 of 1008, taking 0.01 seconds to get val score of 0.3489:
#                 {'alpha': 0.1, 'fit_prior': True, 'features': 71},
#             Current best combo with val score 0.4891:
#                     {'alpha': 0.1, 'fit_prior': False, 'features': 15}
# Trained and Tested combination 69 of 1008, taking 0.01 seconds to get val score of 0.348:
#                 {'alpha': 0.1, 'fit_prior': True, 'features': 67},
#             Current best combo with val score 0.4891:
#                     {'alpha': 0.1, 'fit_prior': False, 'features': 15}
# Trained and Tested combination 70 of 1008, taking 0.01 seconds to get val score of 0.2968:
#                 {'alpha': 0.1, 'fit_prior': True, 'features': 30},
#             Current best combo with val score 0.4891:
#                     {'alpha': 0.1, 'fit_prior': False, 'features': 15}
# Trained and Tested combination 71 of 1008, taking 0.0 seconds to get val score of 0.3958:
#                 {'alpha': 0.1, 'fit_prior': True, 'features': 5},
#             Current best combo with val score 0.4891:
#                     {'alpha': 0.1, 'fit_prior': False, 'features': 15}
# Trained and Tested combination 72 of 1008, taking 0.01 seconds to get val score of 0.0885:
#                 {'alpha': 100, 'fit_prior': True, 'features': 67},
#             Current best combo with val score 0.4891:
#                     {'alpha': 0.1, 'fit_prior': False, 'features': 15}
# Trained and Tested combination 73 of 1008, taking 0.01 seconds to get val score of 0.3475:
#                 {'alpha': 0.0001, 'fit_prior': True, 'features': 59},
#             Current best combo with val score 0.4891:
#                     {'alpha': 0.1, 'fit_prior': False, 'features': 15}
# Trained and Tested combination 74 of 1008, taking 0.0 seconds to get val score of 0.4834:
#                 {'alpha': 0.0001, 'fit_prior': False, 'features': 25},
#             Current best combo with val score 0.4891:
#                     {'alpha': 0.1, 'fit_prior': False, 'features': 15}
# Trained and Tested combination 75 of 1008, taking 0.01 seconds to get val score of 0.4165:
#                 {'alpha': 0.0001, 'fit_prior': False, 'features': 59},
#             Current best combo with val score 0.4891:
#                     {'alpha': 0.1, 'fit_prior': False, 'features': 15}
# Trained and Tested combination 76 of 1008, taking 0.0 seconds to get val score of 0.2933:
#                 {'alpha': 0.0001, 'fit_prior': False, 'features': 0},
#             Current best combo with val score 0.4891:
#                     {'alpha': 0.1, 'fit_prior': False, 'features': 15}
# Trained and Tested combination 77 of 1008, taking 0.01 seconds to get val score of 0.1733:
#                 {'alpha': 100, 'fit_prior': True, 'features': 25},
#             Current best combo with val score 0.4891:
#                     {'alpha': 0.1, 'fit_prior': False, 'features': 15}
# Trained and Tested combination 78 of 1008, taking 0.01 seconds to get val score of 0.0801:
#                 {'alpha': 100, 'fit_prior': True, 'features': 71},
#             Current best combo with val score 0.4891:
#                     {'alpha': 0.1, 'fit_prior': False, 'features': 15}
# Trained and Tested combination 79 of 1008, taking 0.01 seconds to get val score of 0.2868:
#                 {'alpha': 0.1, 'fit_prior': True, 'features': 40},
#             Current best combo with val score 0.4891:
#                     {'alpha': 0.1, 'fit_prior': False, 'features': 15}
# Trained and Tested combination 80 of 1008, taking 0.0 seconds to get val score of 0.3501:
#                 {'alpha': 100, 'fit_prior': False, 'features': 15},
#             Current best combo with val score 0.4891:
#                     {'alpha': 0.1, 'fit_prior': False, 'features': 15}
# Trained and Tested combination 81 of 1008, taking 0.01 seconds to get val score of 0.2868:
#                 {'alpha': 0.0001, 'fit_prior': True, 'features': 40},
#             Current best combo with val score 0.4891:
#                     {'alpha': 0.1, 'fit_prior': False, 'features': 15}
# Trained and Tested combination 82 of 1008, taking 0.0 seconds to get val score of 0.1564:
#                 {'alpha': 100, 'fit_prior': True, 'features': 30},
#             Current best combo with val score 0.4891:
#                     {'alpha': 0.1, 'fit_prior': False, 'features': 15}
# Trained and Tested combination 83 of 1008, taking 0.01 seconds to get val score of 0.4002:
#                 {'alpha': 0.0001, 'fit_prior': False, 'features': 35},
#             Current best combo with val score 0.4891:
#                     {'alpha': 0.1, 'fit_prior': False, 'features': 15}
# Trained and Tested combination 84 of 1008, taking 0.03 seconds to get val score of 0.3497:
#                 {'alpha': 0.1, 'fit_prior': True, 'features': 59},
#             Current best combo with val score 0.4891:
#                     {'alpha': 0.1, 'fit_prior': False, 'features': 15}
# Trained and Tested combination 85 of 1008, taking 0.04 seconds to get val score of 0.3471:
#                 {'alpha': 0.0001, 'fit_prior': True, 'features': 71},
#             Current best combo with val score 0.4891:
#                     {'alpha': 0.1, 'fit_prior': False, 'features': 15}
# Trained and Tested combination 86 of 1008, taking 0.03 seconds to get val score of 0.0634:
#                 {'alpha': 100, 'fit_prior': True, 'features': 50},
#             Current best combo with val score 0.4891:
#                     {'alpha': 0.1, 'fit_prior': False, 'features': 15}
# Trained and Tested combination 87 of 1008, taking 0.01 seconds to get val score of 0.4131:
#                 {'alpha': 0.0001, 'fit_prior': False, 'features': 67},
#             Current best combo with val score 0.4891:
#                     {'alpha': 0.1, 'fit_prior': False, 'features': 15}
# Trained and Tested combination 88 of 1008, taking 0.0 seconds to get val score of 0.2933:
#                 {'alpha': 100, 'fit_prior': True, 'features': 0},
#             Current best combo with val score 0.4891:
#                     {'alpha': 0.1, 'fit_prior': False, 'features': 15}
# Trained and Tested combination 89 of 1008, taking 0.01 seconds to get val score of 0.2534:
#                 {'alpha': 0.1, 'fit_prior': True, 'features': 45},
#             Current best combo with val score 0.4891:
#                     {'alpha': 0.1, 'fit_prior': False, 'features': 15}
# Trained and Tested combination 90 of 1008, taking 0.01 seconds to get val score of 0.3869:
#                 {'alpha': 0.0001, 'fit_prior': False, 'features': 50},
#             Current best combo with val score 0.4891:
#                     {'alpha': 0.1, 'fit_prior': False, 'features': 15}
# Trained and Tested combination 91 of 1008, taking 0.0 seconds to get val score of 0.4895:
#                 {'alpha': 0.0001, 'fit_prior': False, 'features': 15},
#             Current best combo with val score 0.4895:
#                     {'alpha': 0.0001, 'fit_prior': False, 'features': 15}
# Trained and Tested combination 92 of 1008, taking 0.0 seconds to get val score of 0.2671:
#                 {'alpha': 100, 'fit_prior': True, 'features': 10},
#             Current best combo with val score 0.4895:
#                     {'alpha': 0.0001, 'fit_prior': False, 'features': 15}
# Trained and Tested combination 93 of 1008, taking 0.01 seconds to get val score of 0.2104:
#                 {'alpha': 100, 'fit_prior': False, 'features': 40},
#             Current best combo with val score 0.4895:
#                     {'alpha': 0.0001, 'fit_prior': False, 'features': 15}
# Trained and Tested combination 94 of 1008, taking 0.01 seconds to get val score of 0.3899:
#                 {'alpha': 0.1, 'fit_prior': False, 'features': 50},
#             Current best combo with val score 0.4895:
#                     {'alpha': 0.0001, 'fit_prior': False, 'features': 15}
# Trained and Tested combination 95 of 1008, taking 0.01 seconds to get val score of 0.2811:
#                 {'alpha': 0.1, 'fit_prior': True, 'features': 36},
#             Current best combo with val score 0.4895:
#                     {'alpha': 0.0001, 'fit_prior': False, 'features': 15}
# Trained and Tested combination 96 of 1008, taking 0.01 seconds to get val score of 0.4192:
#                 {'alpha': 0.1, 'fit_prior': False, 'features': 71},
#             Current best combo with val score 0.4895:
#                     {'alpha': 0.0001, 'fit_prior': False, 'features': 15}
# Trained and Tested combination 97 of 1008, taking 0.0 seconds to get val score of 0.2933:
#                 {'alpha': 100, 'fit_prior': False, 'features': 0},
#             Current best combo with val score 0.4895:
#                     {'alpha': 0.0001, 'fit_prior': False, 'features': 15}
#
#
# STAGE ONE: Begin initial Guidance system
#
#
# Guidance: initial round
#
# 	round 0 iteration:  0
#
# Trained and Tested combination 98 of 1008, taking 0.01 seconds to get val score of 0.2811:
#                 {'alpha': 0.01, 'fit_prior': True, 'features': 36},
#             Current best combo with val score 0.4895:
#                     {'alpha': 0.0001, 'fit_prior': False, 'features': 15}
# Trained and Tested combination 99 of 1008, taking 0.01 seconds to get val score of 0.2834:
#                 {'alpha': 1, 'fit_prior': True, 'features': 36},
#             Current best combo with val score 0.4895:
#                     {'alpha': 0.0001, 'fit_prior': False, 'features': 15}
# Trained and Tested combination 100 of 1008, taking 0.01 seconds to get val score of 0.4045:
#                 {'alpha': 0.1, 'fit_prior': False, 'features': 36},
#             Current best combo with val score 0.4895:
#                     {'alpha': 0.0001, 'fit_prior': False, 'features': 15}
# Already Trained and Tested combination (val score of 0.282):
#             {'alpha': 0.1, 'fit_prior': True, 'features': 35}
#             Current best combo (with val score 0.4895):
#                     {'alpha': 0.0001, 'fit_prior': False, 'features': 15}
#         Has trained 100 of 1008 combinations so far
# Trained and Tested combination 101 of 1008, taking 0.01 seconds to get val score of 0.2884:
#                 {'alpha': 0.1, 'fit_prior': True, 'features': 37},
#             Current best combo with val score 0.4895:
#                     {'alpha': 0.0001, 'fit_prior': False, 'features': 15}
# 	round 0 iteration:  1
#
# Trained and Tested combination 102 of 1008, taking 0.01 seconds to get val score of 0.2811:
#                 {'alpha': 0.001, 'fit_prior': True, 'features': 36},
#             Current best combo with val score 0.4895:
#                     {'alpha': 0.0001, 'fit_prior': False, 'features': 15}
# Already Trained and Tested combination (val score of 0.2811):
#             {'alpha': 0.1, 'fit_prior': True, 'features': 36}
#             Current best combo (with val score 0.4895):
#                     {'alpha': 0.0001, 'fit_prior': False, 'features': 15}
#         Has trained 102 of 1008 combinations so far
# Trained and Tested combination 103 of 1008, taking 0.01 seconds to get val score of 0.4045:
#                 {'alpha': 0.01, 'fit_prior': False, 'features': 36},
#             Current best combo with val score 0.4895:
#                     {'alpha': 0.0001, 'fit_prior': False, 'features': 15}
# Trained and Tested combination 104 of 1008, taking 0.01 seconds to get val score of 0.282:
#                 {'alpha': 0.01, 'fit_prior': True, 'features': 35},
#             Current best combo with val score 0.4895:
#                     {'alpha': 0.0001, 'fit_prior': False, 'features': 15}
# Trained and Tested combination 105 of 1008, taking 0.02 seconds to get val score of 0.2884:
#                 {'alpha': 0.01, 'fit_prior': True, 'features': 37},
#             Current best combo with val score 0.4895:
#                     {'alpha': 0.0001, 'fit_prior': False, 'features': 15}
# Already Trained and Tested combination (val score of 0.2811):
#             {'alpha': 0.1, 'fit_prior': True, 'features': 36}
#             Current best combo (with val score 0.4895):
#                     {'alpha': 0.0001, 'fit_prior': False, 'features': 15}
#         Has trained 105 of 1008 combinations so far
# Trained and Tested combination 106 of 1008, taking 0.01 seconds to get val score of 0.2727:
#                 {'alpha': 10, 'fit_prior': True, 'features': 36},
#             Current best combo with val score 0.4895:
#                     {'alpha': 0.0001, 'fit_prior': False, 'features': 15}
# Trained and Tested combination 107 of 1008, taking 0.02 seconds to get val score of 0.4001:
#                 {'alpha': 1, 'fit_prior': False, 'features': 36},
#             Current best combo with val score 0.4895:
#                     {'alpha': 0.0001, 'fit_prior': False, 'features': 15}
# Trained and Tested combination 108 of 1008, taking 0.02 seconds to get val score of 0.2815:
#                 {'alpha': 1, 'fit_prior': True, 'features': 35},
#             Current best combo with val score 0.4895:
#                     {'alpha': 0.0001, 'fit_prior': False, 'features': 15}
# Trained and Tested combination 109 of 1008, taking 0.01 seconds to get val score of 0.2837:
#                 {'alpha': 1, 'fit_prior': True, 'features': 37},
#             Current best combo with val score 0.4895:
#                     {'alpha': 0.0001, 'fit_prior': False, 'features': 15}
# Already Trained and Tested combination (val score of 0.4045):
#             {'alpha': 0.01, 'fit_prior': False, 'features': 36}
#             Current best combo (with val score 0.4895):
#                     {'alpha': 0.0001, 'fit_prior': False, 'features': 15}
#         Has trained 109 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.4001):
#             {'alpha': 1, 'fit_prior': False, 'features': 36}
#             Current best combo (with val score 0.4895):
#                     {'alpha': 0.0001, 'fit_prior': False, 'features': 15}
#         Has trained 109 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.2811):
#             {'alpha': 0.1, 'fit_prior': True, 'features': 36}
#             Current best combo (with val score 0.4895):
#                     {'alpha': 0.0001, 'fit_prior': False, 'features': 15}
#         Has trained 109 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.4002):
#             {'alpha': 0.1, 'fit_prior': False, 'features': 35}
#             Current best combo (with val score 0.4895):
#                     {'alpha': 0.0001, 'fit_prior': False, 'features': 15}
#         Has trained 109 of 1008 combinations so far
# Trained and Tested combination 110 of 1008, taking 0.01 seconds to get val score of 0.4107:
#                 {'alpha': 0.1, 'fit_prior': False, 'features': 37},
#             Current best combo with val score 0.4895:
#                     {'alpha': 0.0001, 'fit_prior': False, 'features': 15}
# Already Trained and Tested combination (val score of 0.282):
#             {'alpha': 0.01, 'fit_prior': True, 'features': 35}
#             Current best combo (with val score 0.4895):
#                     {'alpha': 0.0001, 'fit_prior': False, 'features': 15}
#         Has trained 110 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.2815):
#             {'alpha': 1, 'fit_prior': True, 'features': 35}
#             Current best combo (with val score 0.4895):
#                     {'alpha': 0.0001, 'fit_prior': False, 'features': 15}
#         Has trained 110 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.4002):
#             {'alpha': 0.1, 'fit_prior': False, 'features': 35}
#             Current best combo (with val score 0.4895):
#                     {'alpha': 0.0001, 'fit_prior': False, 'features': 15}
#         Has trained 110 of 1008 combinations so far
# Trained and Tested combination 111 of 1008, taking 0.01 seconds to get val score of 0.2759:
#                 {'alpha': 0.1, 'fit_prior': True, 'features': 34},
#             Current best combo with val score 0.4895:
#                     {'alpha': 0.0001, 'fit_prior': False, 'features': 15}
# Already Trained and Tested combination (val score of 0.2811):
#             {'alpha': 0.1, 'fit_prior': True, 'features': 36}
#             Current best combo (with val score 0.4895):
#                     {'alpha': 0.0001, 'fit_prior': False, 'features': 15}
#         Has trained 111 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.2884):
#             {'alpha': 0.01, 'fit_prior': True, 'features': 37}
#             Current best combo (with val score 0.4895):
#                     {'alpha': 0.0001, 'fit_prior': False, 'features': 15}
#         Has trained 111 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.2837):
#             {'alpha': 1, 'fit_prior': True, 'features': 37}
#             Current best combo (with val score 0.4895):
#                     {'alpha': 0.0001, 'fit_prior': False, 'features': 15}
#         Has trained 111 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.4107):
#             {'alpha': 0.1, 'fit_prior': False, 'features': 37}
#             Current best combo (with val score 0.4895):
#                     {'alpha': 0.0001, 'fit_prior': False, 'features': 15}
#         Has trained 111 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.2811):
#             {'alpha': 0.1, 'fit_prior': True, 'features': 36}
#             Current best combo (with val score 0.4895):
#                     {'alpha': 0.0001, 'fit_prior': False, 'features': 15}
#         Has trained 111 of 1008 combinations so far
# Trained and Tested combination 112 of 1008, taking 0.01 seconds to get val score of 0.2823:
#                 {'alpha': 0.1, 'fit_prior': True, 'features': 38},
#             Current best combo with val score 0.4895:
#                     {'alpha': 0.0001, 'fit_prior': False, 'features': 15}
# Trained and Tested combination 113 of 1008, taking 0.0 seconds to get val score of 0.4895:
#                 {'alpha': 0.001, 'fit_prior': False, 'features': 15},
#             Current best combo with val score 0.4895:
#                     {'alpha': 0.0001, 'fit_prior': False, 'features': 15}
# Already Trained and Tested combination (val score of 0.431):
#             {'alpha': 0.0001, 'fit_prior': True, 'features': 15}
#             Current best combo (with val score 0.4895):
#                     {'alpha': 0.0001, 'fit_prior': False, 'features': 15}
#         Has trained 113 of 1008 combinations so far
# Trained and Tested combination 114 of 1008, taking 0.0 seconds to get val score of 0.4721:
#                 {'alpha': 0.0001, 'fit_prior': False, 'features': 14},
#             Current best combo with val score 0.4895:
#                     {'alpha': 0.0001, 'fit_prior': False, 'features': 15}
# Trained and Tested combination 115 of 1008, taking 0.0 seconds to get val score of 0.4911:
#                 {'alpha': 0.0001, 'fit_prior': False, 'features': 16},
#             Current best combo with val score 0.4911:
#                     {'alpha': 0.0001, 'fit_prior': False, 'features': 16}
# Trained and Tested combination 116 of 1008, taking 0.0 seconds to get val score of 0.4911:
#                 {'alpha': 0.001, 'fit_prior': False, 'features': 16},
#             Current best combo with val score 0.4911:
#                     {'alpha': 0.0001, 'fit_prior': False, 'features': 16}
# Trained and Tested combination 117 of 1008, taking 0.0 seconds to get val score of 0.432:
#                 {'alpha': 0.0001, 'fit_prior': True, 'features': 16},
#             Current best combo with val score 0.4911:
#                     {'alpha': 0.0001, 'fit_prior': False, 'features': 16}
# Already Trained and Tested combination (val score of 0.4895):
#             {'alpha': 0.0001, 'fit_prior': False, 'features': 15}
#             Current best combo (with val score 0.4911):
#                     {'alpha': 0.0001, 'fit_prior': False, 'features': 16}
#         Has trained 117 of 1008 combinations so far
# Trained and Tested combination 118 of 1008, taking 0.0 seconds to get val score of 0.4473:
#                 {'alpha': 0.0001, 'fit_prior': False, 'features': 17},
#             Current best combo with val score 0.4911:
#                     {'alpha': 0.0001, 'fit_prior': False, 'features': 16}
# % Combos Checked Thus Far: 118 out of 1008 which is 11.706349000000001%
# STAGE TWO: Begin Cruise system
#
#
# Cruising Coordrdinate 1 of 96
#
# Cruising Coordrdinate 2 of 96
#
# Cruising Coordrdinate 3 of 96
#
# Cruising Coordrdinate 4 of 96
#
# Cruising Coordrdinate 5 of 96
#
# Cruising Coordrdinate 6 of 96
#
# Cruising Coordrdinate 7 of 96
#
# Cruising Coordrdinate 8 of 96
#
# Cruising Coordrdinate 9 of 96
#
# Cruising Coordrdinate 10 of 96
#
# Cruising Coordrdinate 11 of 96
#
# Cruising Coordrdinate 12 of 96
#
# Cruising Coordrdinate 13 of 96
#
# Cruising Coordrdinate 14 of 96
#
# Cruising Coordrdinate 15 of 96
#
# Cruising Coordrdinate 16 of 96
#
# Cruising Coordrdinate 17 of 96
#
# Cruising Coordrdinate 18 of 96
#
# Cruising Coordrdinate 19 of 96
#
# Cruising Coordrdinate 20 of 96
#
# Cruising Coordrdinate 21 of 96
#
# Cruising Coordrdinate 22 of 96
#
# Cruising Coordrdinate 23 of 96
#
# Cruising Coordrdinate 24 of 96
#
# Cruising Coordrdinate 25 of 96
#
# Cruising Coordrdinate 26 of 96
#
# Cruising Coordrdinate 27 of 96
#
# Cruising Coordrdinate 28 of 96
#
# Cruising Coordrdinate 29 of 96
#
# Cruising Coordrdinate 30 of 96
#
# Cruising Coordrdinate 31 of 96
#
# Cruising Coordrdinate 32 of 96
#
# Cruising Coordrdinate 33 of 96
#
# Cruising Coordrdinate 34 of 96
#
# Cruising Coordrdinate 35 of 96
#
# Cruising Coordrdinate 36 of 96
#
# Cruising Coordrdinate 37 of 96
#
# Cruising Coordrdinate 38 of 96
#
# Cruising Coordrdinate 39 of 96
#
# Cruising Coordrdinate 40 of 96
#
# Cruising Coordrdinate 41 of 96
#
# Cruising Coordrdinate 42 of 96
#
# Cruising Coordrdinate 43 of 96
#
# Cruising Coordrdinate 44 of 96
#
# Cruising Coordrdinate 45 of 96
#
# Cruising Coordrdinate 46 of 96
#
# Cruising Coordrdinate 47 of 96
#
# Cruising Coordrdinate 48 of 96
#
# Cruising Coordrdinate 49 of 96
#
# Cruising Coordrdinate 50 of 96
#
# Cruising Coordrdinate 51 of 96
#
# Cruising Coordrdinate 52 of 96
#
# Cruising Coordrdinate 53 of 96
#
# Cruising Coordrdinate 54 of 96
#
# Cruising Coordrdinate 55 of 96
#
# Cruising Coordrdinate 56 of 96
#
# Cruising Coordrdinate 57 of 96
#
# Cruising Coordrdinate 58 of 96
#
# Cruising Coordrdinate 59 of 96
#
# Cruising Coordrdinate 60 of 96
#
# Cruising Coordrdinate 61 of 96
#
# Cruising Coordrdinate 62 of 96
#
# Cruising Coordrdinate 63 of 96
#
# Cruising Coordrdinate 64 of 96
#
# Cruising Coordrdinate 65 of 96
#
# Cruising Coordrdinate 66 of 96
#
# Cruising Coordrdinate 67 of 96
#
# Cruising Coordrdinate 68 of 96
#
# Cruising Coordrdinate 69 of 96
#
# Cruising Coordrdinate 70 of 96
#
# Cruising Coordrdinate 71 of 96
#
# Cruising Coordrdinate 72 of 96
#
# Cruising Coordrdinate 73 of 96
#
# Cruising Coordrdinate 74 of 96
#
# Cruising Coordrdinate 75 of 96
#
# Cruising Coordrdinate 76 of 96
#
# Cruise suspended due to suspicious case
# Guidance: round 1
#
# 	round 1 iteration:  0
#
# Trained and Tested combination 119 of 1008, taking 0.0 seconds to get val score of 0.4834:
#                 {'alpha': 0.01, 'fit_prior': False, 'features': 25},
#             Current best combo with val score 0.4911:
#                     {'alpha': 0.0001, 'fit_prior': False, 'features': 16}
# Trained and Tested combination 120 of 1008, taking 0.0 seconds to get val score of 0.4857:
#                 {'alpha': 1, 'fit_prior': False, 'features': 25},
#             Current best combo with val score 0.4911:
#                     {'alpha': 0.0001, 'fit_prior': False, 'features': 16}
# Already Trained and Tested combination (val score of 0.3589):
#             {'alpha': 0.1, 'fit_prior': True, 'features': 25}
#             Current best combo (with val score 0.4911):
#                     {'alpha': 0.0001, 'fit_prior': False, 'features': 16}
#         Has trained 120 of 1008 combinations so far
# Trained and Tested combination 121 of 1008, taking 0.0 seconds to get val score of 0.4858:
#                 {'alpha': 0.1, 'fit_prior': False, 'features': 24},
#             Current best combo with val score 0.4911:
#                     {'alpha': 0.0001, 'fit_prior': False, 'features': 16}
# Trained and Tested combination 122 of 1008, taking 0.0 seconds to get val score of 0.4612:
#                 {'alpha': 0.1, 'fit_prior': False, 'features': 26},
#             Current best combo with val score 0.4911:
#                     {'alpha': 0.0001, 'fit_prior': False, 'features': 16}
# 	round 1 iteration:  1
#
# Trained and Tested combination 123 of 1008, taking 0.0 seconds to get val score of 0.4834:
#                 {'alpha': 0.001, 'fit_prior': False, 'features': 25},
#             Current best combo with val score 0.4911:
#                     {'alpha': 0.0001, 'fit_prior': False, 'features': 16}
# Already Trained and Tested combination (val score of 0.4834):
#             {'alpha': 0.1, 'fit_prior': False, 'features': 25}
#             Current best combo (with val score 0.4911):
#                     {'alpha': 0.0001, 'fit_prior': False, 'features': 16}
#         Has trained 123 of 1008 combinations so far
# Trained and Tested combination 124 of 1008, taking 0.0 seconds to get val score of 0.3589:
#                 {'alpha': 0.01, 'fit_prior': True, 'features': 25},
#             Current best combo with val score 0.4911:
#                     {'alpha': 0.0001, 'fit_prior': False, 'features': 16}
# Trained and Tested combination 125 of 1008, taking 0.0 seconds to get val score of 0.486:
#                 {'alpha': 0.01, 'fit_prior': False, 'features': 24},
#             Current best combo with val score 0.4911:
#                     {'alpha': 0.0001, 'fit_prior': False, 'features': 16}
# Trained and Tested combination 126 of 1008, taking 0.01 seconds to get val score of 0.4618:
#                 {'alpha': 0.01, 'fit_prior': False, 'features': 26},
#             Current best combo with val score 0.4911:
#                     {'alpha': 0.0001, 'fit_prior': False, 'features': 16}
# Already Trained and Tested combination (val score of 0.4834):
#             {'alpha': 0.1, 'fit_prior': False, 'features': 25}
#             Current best combo (with val score 0.4911):
#                     {'alpha': 0.0001, 'fit_prior': False, 'features': 16}
#         Has trained 126 of 1008 combinations so far
# Trained and Tested combination 127 of 1008, taking 0.0 seconds to get val score of 0.478:
#                 {'alpha': 10, 'fit_prior': False, 'features': 25},
#             Current best combo with val score 0.4911:
#                     {'alpha': 0.0001, 'fit_prior': False, 'features': 16}
# Trained and Tested combination 128 of 1008, taking 0.0 seconds to get val score of 0.3609:
#                 {'alpha': 1, 'fit_prior': True, 'features': 25},
#             Current best combo with val score 0.4911:
#                     {'alpha': 0.0001, 'fit_prior': False, 'features': 16}
# Trained and Tested combination 129 of 1008, taking 0.0 seconds to get val score of 0.4879:
#                 {'alpha': 1, 'fit_prior': False, 'features': 24},
#             Current best combo with val score 0.4911:
#                     {'alpha': 0.0001, 'fit_prior': False, 'features': 16}
# Trained and Tested combination 130 of 1008, taking 0.0 seconds to get val score of 0.4594:
#                 {'alpha': 1, 'fit_prior': False, 'features': 26},
#             Current best combo with val score 0.4911:
#                     {'alpha': 0.0001, 'fit_prior': False, 'features': 16}
# Already Trained and Tested combination (val score of 0.486):
#             {'alpha': 0.01, 'fit_prior': False, 'features': 24}
#             Current best combo (with val score 0.4911):
#                     {'alpha': 0.0001, 'fit_prior': False, 'features': 16}
#         Has trained 130 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.4879):
#             {'alpha': 1, 'fit_prior': False, 'features': 24}
#             Current best combo (with val score 0.4911):
#                     {'alpha': 0.0001, 'fit_prior': False, 'features': 16}
#         Has trained 130 of 1008 combinations so far
# Trained and Tested combination 131 of 1008, taking 0.01 seconds to get val score of 0.3624:
#                 {'alpha': 0.1, 'fit_prior': True, 'features': 24},
#             Current best combo with val score 0.4911:
#                     {'alpha': 0.0001, 'fit_prior': False, 'features': 16}
# Trained and Tested combination 132 of 1008, taking 0.01 seconds to get val score of 0.4893:
#                 {'alpha': 0.1, 'fit_prior': False, 'features': 23},
#             Current best combo with val score 0.4911:
#                     {'alpha': 0.0001, 'fit_prior': False, 'features': 16}
# Already Trained and Tested combination (val score of 0.4834):
#             {'alpha': 0.1, 'fit_prior': False, 'features': 25}
#             Current best combo (with val score 0.4911):
#                     {'alpha': 0.0001, 'fit_prior': False, 'features': 16}
# ...
# Trained and Tested combination 151 of 1008, taking 0.0 seconds to get val score of 0.4468:
#                 {'alpha': 0.1, 'fit_prior': False, 'features': 18},
#             Current best combo with val score 0.4911:
#                     {'alpha': 0.0001, 'fit_prior': False, 'features': 16}
# Already Trained and Tested combination (val score of 0.4477):
#             {'alpha': 0.1, 'fit_prior': False, 'features': 20}
#             Current best combo (with val score 0.4911):
#                     {'alpha': 0.0001, 'fit_prior': False, 'features': 16}
#         Has trained 151 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.4908):
#             {'alpha': 0.01, 'fit_prior': False, 'features': 21}
#             Current best combo (with val score 0.4911):
#                     {'alpha': 0.0001, 'fit_prior': False, 'features': 16}
#         Has trained 151 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.4904):
#             {'alpha': 1, 'fit_prior': False, 'features': 21}
#             Current best combo (with val score 0.4911):
#                     {'alpha': 0.0001, 'fit_prior': False, 'features': 16}
#         Has trained 151 of 1008 combinations so far
# Trained and Tested combination 152 of 1008, taking 0.01 seconds to get val score of 0.3633:
#                 {'alpha': 0.1, 'fit_prior': True, 'features': 21},
#             Current best combo with val score 0.4911:
#                     {'alpha': 0.0001, 'fit_prior': False, 'features': 16}
# Already Trained and Tested combination (val score of 0.4477):
#             {'alpha': 0.1, 'fit_prior': False, 'features': 20}
#             Current best combo (with val score 0.4911):
#                     {'alpha': 0.0001, 'fit_prior': False, 'features': 16}
#         Has trained 152 of 1008 combinations so far
# Trained and Tested combination 153 of 1008, taking 0.0 seconds to get val score of 0.4895:
#                 {'alpha': 0.1, 'fit_prior': False, 'features': 22},
#             Current best combo with val score 0.4911:
#                     {'alpha': 0.0001, 'fit_prior': False, 'features': 16}
# % Combos Checked Thus Far: 153 out of 1008 which is 15.178571%
# Cruising Coordrdinate 91 of 96
#
# Cruising Coordrdinate 92 of 96
#
# Cruise suspended due to suspicious case
# Guidance: round 4
#
# 	round 4 iteration:  0
#
# Already Trained and Tested combination (val score of 0.4477):
#             {'alpha': 0.001, 'fit_prior': False, 'features': 20}
#             Current best combo (with val score 0.4911):
#                     {'alpha': 0.0001, 'fit_prior': False, 'features': 16}
#         Has trained 153 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.3576):
#             {'alpha': 0.0001, 'fit_prior': True, 'features': 20}
#             Current best combo (with val score 0.4911):
#                     {'alpha': 0.0001, 'fit_prior': False, 'features': 16}
#         Has trained 153 of 1008 combinations so far
# Trained and Tested combination 154 of 1008, taking 0.0 seconds to get val score of 0.4492:
#                 {'alpha': 0.0001, 'fit_prior': False, 'features': 19},
#             Current best combo with val score 0.4911:
#                     {'alpha': 0.0001, 'fit_prior': False, 'features': 16}
# Trained and Tested combination 155 of 1008, taking 0.0 seconds to get val score of 0.4908:
#                 {'alpha': 0.0001, 'fit_prior': False, 'features': 21},
#             Current best combo with val score 0.4911:
#                     {'alpha': 0.0001, 'fit_prior': False, 'features': 16}
# 	round 4 iteration:  1
#
# Trained and Tested combination 156 of 1008, taking 0.0 seconds to get val score of 0.4492:
#                 {'alpha': 0.001, 'fit_prior': False, 'features': 19},
#             Current best combo with val score 0.4911:
#                     {'alpha': 0.0001, 'fit_prior': False, 'features': 16}
# Trained and Tested combination 157 of 1008, taking 0.0 seconds to get val score of 0.3626:
#                 {'alpha': 0.0001, 'fit_prior': True, 'features': 19},
#             Current best combo with val score 0.4911:
#                     {'alpha': 0.0001, 'fit_prior': False, 'features': 16}
# Trained and Tested combination 158 of 1008, taking 0.0 seconds to get val score of 0.4468:
#                 {'alpha': 0.0001, 'fit_prior': False, 'features': 18},
#             Current best combo with val score 0.4911:
#                     {'alpha': 0.0001, 'fit_prior': False, 'features': 16}
# Already Trained and Tested combination (val score of 0.4477):
#             {'alpha': 0.0001, 'fit_prior': False, 'features': 20}
#             Current best combo (with val score 0.4911):
#                     {'alpha': 0.0001, 'fit_prior': False, 'features': 16}
#         Has trained 158 of 1008 combinations so far
# Trained and Tested combination 159 of 1008, taking 0.0 seconds to get val score of 0.4908:
#                 {'alpha': 0.001, 'fit_prior': False, 'features': 21},
#             Current best combo with val score 0.4911:
#                     {'alpha': 0.0001, 'fit_prior': False, 'features': 16}
# Trained and Tested combination 160 of 1008, taking 0.0 seconds to get val score of 0.3637:
#                 {'alpha': 0.0001, 'fit_prior': True, 'features': 21},
#             Current best combo with val score 0.4911:
#                     {'alpha': 0.0001, 'fit_prior': False, 'features': 16}
# Already Trained and Tested combination (val score of 0.4477):
#             {'alpha': 0.0001, 'fit_prior': False, 'features': 20}
#             Current best combo (with val score 0.4911):
#                     {'alpha': 0.0001, 'fit_prior': False, 'features': 16}
#         Has trained 160 of 1008 combinations so far
# Trained and Tested combination 161 of 1008, taking 0.0 seconds to get val score of 0.489:
#                 {'alpha': 0.0001, 'fit_prior': False, 'features': 22},
#             Current best combo with val score 0.4911:
#                     {'alpha': 0.0001, 'fit_prior': False, 'features': 16}
# % Combos Checked Thus Far: 161 out of 1008 which is 15.972222%
# Cruising Coordrdinate 93 of 96
#
# Cruising Coordrdinate 94 of 96
#
# Cruise suspended due to suspicious case
# Guidance: round 5
#
# 	round 5 iteration:  0
#
# Trained and Tested combination 162 of 1008, taking 0.0 seconds to get val score of 0.4895:
#                 {'alpha': 0.01, 'fit_prior': False, 'features': 15},
#             Current best combo with val score 0.4911:
#                     {'alpha': 0.0001, 'fit_prior': False, 'features': 16}
# Trained and Tested combination 163 of 1008, taking 0.0 seconds to get val score of 0.4876:
#                 {'alpha': 1, 'fit_prior': False, 'features': 15},
#             Current best combo with val score 0.4911:
#                     {'alpha': 0.0001, 'fit_prior': False, 'features': 16}
# Already Trained and Tested combination (val score of 0.4325):
#             {'alpha': 0.1, 'fit_prior': True, 'features': 15}
#             Current best combo (with val score 0.4911):
#                     {'alpha': 0.0001, 'fit_prior': False, 'features': 16}
#         Has trained 163 of 1008 combinations so far
# Trained and Tested combination 164 of 1008, taking 0.0 seconds to get val score of 0.4716:
#                 {'alpha': 0.1, 'fit_prior': False, 'features': 14},
#             Current best combo with val score 0.4911:
#                     {'alpha': 0.0001, 'fit_prior': False, 'features': 16}
# Trained and Tested combination 165 of 1008, taking 0.0 seconds to get val score of 0.4911:
#                 {'alpha': 0.1, 'fit_prior': False, 'features': 16},
#             Current best combo with val score 0.4911:
#                     {'alpha': 0.0001, 'fit_prior': False, 'features': 16}
# 	round 5 iteration:  1
#
# Already Trained and Tested combination (val score of 0.4895):
#             {'alpha': 0.001, 'fit_prior': False, 'features': 15}
#             Current best combo (with val score 0.4911):
#                     {'alpha': 0.0001, 'fit_prior': False, 'features': 16}
#         Has trained 165 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.4891):
#             {'alpha': 0.1, 'fit_prior': False, 'features': 15}
#             Current best combo (with val score 0.4911):
#                     {'alpha': 0.0001, 'fit_prior': False, 'features': 16}
#         Has trained 165 of 1008 combinations so far
# Trained and Tested combination 166 of 1008, taking 0.0 seconds to get val score of 0.431:
#                 {'alpha': 0.01, 'fit_prior': True, 'features': 15},
#             Current best combo with val score 0.4911:
#                     {'alpha': 0.0001, 'fit_prior': False, 'features': 16}
# Trained and Tested combination 167 of 1008, taking 0.0 seconds to get val score of 0.4721:
#                 {'alpha': 0.01, 'fit_prior': False, 'features': 14},
#             Current best combo with val score 0.4911:
#                     {'alpha': 0.0001, 'fit_prior': False, 'features': 16}
# Trained and Tested combination 168 of 1008, taking 0.01 seconds to get val score of 0.4911:
#                 {'alpha': 0.01, 'fit_prior': False, 'features': 16},
#             Current best combo with val score 0.4911:
#                     {'alpha': 0.0001, 'fit_prior': False, 'features': 16}
# Already Trained and Tested combination (val score of 0.4891):
#             {'alpha': 0.1, 'fit_prior': False, 'features': 15}
#             Current best combo (with val score 0.4911):
#                     {'alpha': 0.0001, 'fit_prior': False, 'features': 16}
#         Has trained 168 of 1008 combinations so far
# Trained and Tested combination 169 of 1008, taking 0.01 seconds to get val score of 0.4782:
#                 {'alpha': 10, 'fit_prior': False, 'features': 15},
#             Current best combo with val score 0.4911:
#                     {'alpha': 0.0001, 'fit_prior': False, 'features': 16}
# Trained and Tested combination 170 of 1008, taking 0.01 seconds to get val score of 0.4325:
#                 {'alpha': 1, 'fit_prior': True, 'features': 15},
#             Current best combo with val score 0.4911:
#                     {'alpha': 0.0001, 'fit_prior': False, 'features': 16}
# Trained and Tested combination 171 of 1008, taking 0.0 seconds to get val score of 0.47:
#                 {'alpha': 1, 'fit_prior': False, 'features': 14},
#             Current best combo with val score 0.4911:
#                     {'alpha': 0.0001, 'fit_prior': False, 'features': 16}
# Trained and Tested combination 172 of 1008, taking 0.0 seconds to get val score of 0.4887:
#                 {'alpha': 1, 'fit_prior': False, 'features': 16},
#             Current best combo with val score 0.4911:
#                     {'alpha': 0.0001, 'fit_prior': False, 'features': 16}
# Already Trained and Tested combination (val score of 0.4911):
#             {'alpha': 0.01, 'fit_prior': False, 'features': 16}
#             Current best combo (with val score 0.4911):
#                     {'alpha': 0.0001, 'fit_prior': False, 'features': 16}
#         Has trained 172 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.4887):
#             {'alpha': 1, 'fit_prior': False, 'features': 16}
#             Current best combo (with val score 0.4911):
#                     {'alpha': 0.0001, 'fit_prior': False, 'features': 16}
#         Has trained 172 of 1008 combinations so far
# Trained and Tested combination 173 of 1008, taking 0.0 seconds to get val score of 0.432:
#                 {'alpha': 0.1, 'fit_prior': True, 'features': 16},
#             Current best combo with val score 0.4911:
#                     {'alpha': 0.0001, 'fit_prior': False, 'features': 16}
# Already Trained and Tested combination (val score of 0.4891):
#             {'alpha': 0.1, 'fit_prior': False, 'features': 15}
#             Current best combo (with val score 0.4911):
#                     {'alpha': 0.0001, 'fit_prior': False, 'features': 16}
#         Has trained 173 of 1008 combinations so far
# Trained and Tested combination 174 of 1008, taking 0.0 seconds to get val score of 0.4473:
#                 {'alpha': 0.1, 'fit_prior': False, 'features': 17},
#             Current best combo with val score 0.4911:
#                     {'alpha': 0.0001, 'fit_prior': False, 'features': 16}
# % Combos Checked Thus Far: 174 out of 1008 which is 17.261905%
# Cruising Coordrdinate 95 of 96
#
# Cruising Coordrdinate 96 of 96
#
# Cruise suspended due to suspicious case
# Guidance: round 6
#
# 	round 6 iteration:  0
#
# Already Trained and Tested combination (val score of 0.4895):
#             {'alpha': 0.001, 'fit_prior': False, 'features': 15}
#             Current best combo (with val score 0.4911):
#                     {'alpha': 0.0001, 'fit_prior': False, 'features': 16}
#         Has trained 174 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.431):
#             {'alpha': 0.0001, 'fit_prior': True, 'features': 15}
#             Current best combo (with val score 0.4911):
#                     {'alpha': 0.0001, 'fit_prior': False, 'features': 16}
#         Has trained 174 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.4721):
#             {'alpha': 0.0001, 'fit_prior': False, 'features': 14}
#             Current best combo (with val score 0.4911):
#                     {'alpha': 0.0001, 'fit_prior': False, 'features': 16}
#         Has trained 174 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.4911):
#             {'alpha': 0.0001, 'fit_prior': False, 'features': 16}
#             Current best combo (with val score 0.4911):
#                     {'alpha': 0.0001, 'fit_prior': False, 'features': 16}
#         Has trained 174 of 1008 combinations so far
# 	round 6 iteration:  1
#
# Already Trained and Tested combination (val score of 0.4911):
#             {'alpha': 0.001, 'fit_prior': False, 'features': 16}
#             Current best combo (with val score 0.4911):
#                     {'alpha': 0.0001, 'fit_prior': False, 'features': 16}
#         Has trained 174 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.432):
#             {'alpha': 0.0001, 'fit_prior': True, 'features': 16}
#             Current best combo (with val score 0.4911):
#                     {'alpha': 0.0001, 'fit_prior': False, 'features': 16}
#         Has trained 174 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.4895):
#             {'alpha': 0.0001, 'fit_prior': False, 'features': 15}
#             Current best combo (with val score 0.4911):
#                     {'alpha': 0.0001, 'fit_prior': False, 'features': 16}
#         Has trained 174 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.4473):
#             {'alpha': 0.0001, 'fit_prior': False, 'features': 17}
#             Current best combo (with val score 0.4911):
#                     {'alpha': 0.0001, 'fit_prior': False, 'features': 16}
#         Has trained 174 of 1008 combinations so far
# % Combos Checked Thus Far: 174 out of 1008 which is 17.261905%
# FINAL STAGE: Begin final Guidance system
#
#
# Guidance: round FINAL
#
# 	round FINAL iteration:  0
#
# % Combos Checked Thus Far: 174 out of 1008 which is 17.261905%
# Max Val Score:
#  0.491118
# Max Val Score Std:
#  0.027764
# Best Combo Train Score:
#  0.540778
# Best Combo Train Score Std:
#  0.005955
# Max Combo Index:
#  (0, 0, 16) out of [7, 2, 72] (note best combo is 0-indexed)
# Max Combo Hyperparamer Combination:
#  {'alpha': 0.0001, 'fit_prior': False, 'features': 16}
# Max Combo Features:
#  ('procedure_228130', 'procedure_225792', 'procedure_228125', 'lods_score', 'ventilation_used', 'procedure_226236', 'hospital_stay_duration', 'procedure_225469', 'procedure_224270', 'procedure_225446', 'procedure_225802', 'procedure_227712', 'procedure_229580', 'procedure_225451', 'admission_type_DIRECT EMER.', 'admission_type_DIRECT OBSERVATION', 'admission_type_ELECTIVE', 'admission_type_EU OBSERVATION', 'admission_type_EW EMER.', 'admission_type_OBSERVATION ADMIT', 'admission_type_URGENT', 'admission_type_SURGICAL SAME DAY ADMISSION', 'procedure_224385', 'procedure_224267')
# % Combos Checked: 174 out of 1008 which is 17.261905%
