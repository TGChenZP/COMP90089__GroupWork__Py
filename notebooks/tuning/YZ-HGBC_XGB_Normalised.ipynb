# %% [markdown]
# # Tuning Script

# %%
# Parameters subject to change in every script - involved in naming

MODEL = 'hgbc'
PREPROCESSING = 'normalise'
TUNER = 'yangzhoub'
OPTIMISED_METRIC = 'f1'

# %% [markdown]
# ---

# %%
# detect whether this is a google environment

COLAB_ENVIRONMENT = False

try:
    from google.colab import drive
    drive.mount('/content/drive')
    COLAB_ENVIRONMENT = True
except:
    pass
# Out:
# Mounted at /content/drive

# %%
import sys
import os
import pickle

if COLAB_ENVIRONMENT:
    home_directory = './drive/MyDrive/LAB/COMP90089__GroupWork__Py/' # my home directory is stored in ./LAB of google drive
    if MODEL == 'ebr':
        # !pip install interpret==0.5.0
    elif MODEL == 'cbr':
        # !pip install catboost
    elif MODEL in ['tf', 'mlp']:
        # !pip install PyTorch2Sklearn
    # !pip install JXAutoML
else:
    home_directory = '../../'

from JXAutoML.YangZhouB_10CV import YangZhouB_10CV as Tuner

import pandas as pd
# Out:
# Collecting JXAutoML
#   Downloading JXAutoML-0.4.4-py3-none-any.whl.metadata (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.2/67.2 kB 2.1 MB/s eta 0:00:00
# Downloading JXAutoML-0.4.4-py3-none-any.whl (52 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.1/52.1 kB 2.8 MB/s eta 0:00:00
# Installing collected packages: JXAutoML
# Successfully installed JXAutoML-0.4.4

# %%
# Parameters that are same for every script

FOLDS = 10  # we have decided to do 10 fold validation

SEED = 42

TASK_TYPE = 'Classification'  # this task is a classification task

# we have decided to tune features as hp
TUNE_FEATURES_AS_HYPERPARAMETERS = True

# %% [markdown]
# ---

# %%
# model to use to tune
from sklearn.ensemble import HistGradientBoostingClassifier as clf

# what values to try for each hyperparameter
parameter_choices = {
    'max_depth': (3, 6, 12, 24, 48, 96, 192),
    'max_bins': (4, 16, 64, 255),
    'interaction_cst': ('no_interactions', 'pairwise'),
    'learning_rate': (0.00000001, 0.000001, 0.0001, 0.01, 0.1),
    'l2_regularization': (0.0001, 0.001, 0.01, 0.1, 1, 10),
    'max_iter': (25, 50, 100, 200, 400)

}

# what values to set non-tuneable parameters/hyperparameters
non_tunable_hyperparameters_dict = {
                                    'random_state': SEED,
                                    }

# %% [markdown]
# ---

# %% [markdown]
# Read in and Prepare Data

# %%
# Import data and store as lists

train_x_list = []
train_y_list = []
val_x_list = []
val_y_list = []

for i in range(FOLDS):
    train_data = pd.read_csv(
        f'{home_directory}data/curated/modelling/{PREPROCESSING}/train_{i}.csv')
    val_data = pd.read_csv(
        f'{home_directory}data/curated/modelling/{PREPROCESSING}/val_{i}.csv')

    # get the correct rows for X and y
    train_x = train_data.drop(
        ['mortality_status', 'subject_id', 'hadm_id', 'stay_id'], axis=1)
    train_y = train_data['mortality_status']
    val_x = val_data.drop(
        ['mortality_status', 'subject_id', 'hadm_id', 'stay_id'], axis=1)
    val_y = val_data['mortality_status']

    train_x_list.append(train_x)
    train_y_list.append(train_y)
    val_x_list.append(val_x)
    val_y_list.append(val_y)

# %%
# Import feature importance ordering

with open(f'{home_directory}models/xgb_feature_importance_ordering_{PREPROCESSING}.pickle', 'rb') as f:
    feature_importance_ordering = pickle.load(f)

# %% [markdown]
# Set parameters

# %%
# initialisation
tuner = Tuner()

print('---')

# define what model we are tuning
tuner.read_in_model(clf, TASK_TYPE, optimised_metric=OPTIMISED_METRIC)

print('---')

# read in the data for training and validation
tuner.read_in_data(train_x_list, train_y_list, val_x_list, val_y_list)

print('---')

# set what hp values to tune
tuner.set_hyperparameters(parameter_choices)
# WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

# set up hp values that need to be changed from default but NOT to be tuned
tuner.set_non_tuneable_hyperparameters(non_tunable_hyperparameters_dict)

print('---')

# set up feature importance ordering

if TUNE_FEATURES_AS_HYPERPARAMETERS:
    tuner.set_features(feature_importance_ordering)
    # WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

try:  # try to read in previous results to continue tuning ...
    tuner.read_in_tuning_result_df(
        f'{home_directory}models/tuning/{TUNER}_{MODEL}_{PREPROCESSING}.csv')
except:
    print('No previous tuning data read in')

print('---')

# set up where to save the tuning result csv
tuner.set_tuning_result_saving_address(
    f'{home_directory}models/tuning/{TUNER}_{MODEL}_{PREPROCESSING}.csv')

print('---')

# set up where to save the current best model
tuner.set_best_model_saving_address(
    f'{home_directory}models/tmp_models/{TUNER}_{MODEL}_{PREPROCESSING}')
# Out:
# YangZhouB Initialised
# ---
# Successfully read in model <class 'sklearn.ensemble._hist_gradient_boosting.gradient_boosting.HistGradientBoostingClassifier'>, which is a Classification model optimising for f1
# ---
# Read in Train X data list
# Read in Train y data list
# Read in Val X data list
# Read in Val y data list
# ---
# Successfully recorded hyperparameter choices
# ---
# Successfully recorded non_tuneable_hyperparameter choices
# ---
# Successfully recorded tuneable feature combination choices and updated relevant internal structures
# ---
# No previous tuning data read in
# ---
# Successfully set tuning output address
# ---
# Successfully set best model output address

# %%
# ignore warnings

import warnings
warnings.filterwarnings("ignore")

# %%
# begin tuning ... (or continue training)

tuner.tune()
# Out:
# Streaming output truncated to the last 5000 lines.
#                     {'max_depth': 24, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 200, 'features': 50}
#         Has trained 3002 of 428400 combinations so far
# Trained and Tested combination 3003 of 428400, taking 0.43 seconds to get val score of 0.0099:
#                 {'max_depth': 192, 'max_bins': 4, 'interaction_cst': 'no_interactions', 'learning_rate': 0.01, 'l2_regularization': 0.001, 'max_iter': 400, 'features': 10},
#             Current best combo with val score 0.5038:
#                     {'max_depth': 24, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 200, 'features': 50}
# Already Trained and Tested combination (val score of 0.4475):
#             {'max_depth': 192, 'max_bins': 4, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 400, 'features': 10}
#             Current best combo (with val score 0.5038):
#                     {'max_depth': 24, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 200, 'features': 50}
#         Has trained 3003 of 428400 combinations so far
# Trained and Tested combination 3004 of 428400, taking 0.45 seconds to get val score of 0.448:
#                 {'max_depth': 192, 'max_bins': 4, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.01, 'max_iter': 400, 'features': 10},
#             Current best combo with val score 0.5038:
#                     {'max_depth': 24, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 200, 'features': 50}
# Trained and Tested combination 3005 of 428400, taking 0.22 seconds to get val score of 0.378:
#                 {'max_depth': 192, 'max_bins': 4, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.001, 'max_iter': 200, 'features': 10},
#             Current best combo with val score 0.5038:
#                     {'max_depth': 24, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 200, 'features': 50}
# Trained and Tested combination 3006 of 428400, taking 0.43 seconds to get val score of 0.4398:
#                 {'max_depth': 192, 'max_bins': 4, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.001, 'max_iter': 400, 'features': 9},
#             Current best combo with val score 0.5038:
#                     {'max_depth': 24, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 200, 'features': 50}
# Trained and Tested combination 3007 of 428400, taking 0.56 seconds to get val score of 0.1691:
#                 {'max_depth': 192, 'max_bins': 4, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.001, 'max_iter': 400, 'features': 11},
#             Current best combo with val score 0.5038:
#                     {'max_depth': 24, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 200, 'features': 50}
# % Combos Checked Thus Far: 3007 out of 428400 which is 0.701914%
# Cruising Coordrdinate 345 of 1056
#
# Cruising Coordrdinate 346 of 1056
#
# Cruise suspended due to suspicious case
# Guidance: round 72
#
# 	round 72 iteration:  0
#
# Trained and Tested combination 3008 of 428400, taking 0.94 seconds to get val score of 0.4261:
#                 {'max_depth': 6, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 400, 'features': 10},
#             Current best combo with val score 0.5038:
#                     {'max_depth': 24, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 200, 'features': 50}
# Already Trained and Tested combination (val score of 0.4389):
#             {'max_depth': 3, 'max_bins': 64, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 400, 'features': 10}
#             Current best combo (with val score 0.5038):
#                     {'max_depth': 24, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 200, 'features': 50}
#         Has trained 3008 of 428400 combinations so far
# Already Trained and Tested combination (val score of 0.4064):
#             {'max_depth': 3, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 400, 'features': 10}
#             Current best combo (with val score 0.5038):
#                     {'max_depth': 24, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 200, 'features': 50}
#         Has trained 3008 of 428400 combinations so far
# Trained and Tested combination 3009 of 428400, taking 0.79 seconds to get val score of 0.4491:
#                 {'max_depth': 3, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.01, 'l2_regularization': 0.0001, 'max_iter': 400, 'features': 10},
#             Current best combo with val score 0.5038:
#                     {'max_depth': 24, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 200, 'features': 50}
# Trained and Tested combination 3010 of 428400, taking 0.69 seconds to get val score of 0.4432:
#                 {'max_depth': 3, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 0.001, 'max_iter': 400, 'features': 10},
#             Current best combo with val score 0.5038:
#                     {'max_depth': 24, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 200, 'features': 50}
# Trained and Tested combination 3011 of 428400, taking 0.36 seconds to get val score of 0.4555:
#                 {'max_depth': 3, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 200, 'features': 10},
#             Current best combo with val score 0.5038:
#                     {'max_depth': 24, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 200, 'features': 50}
# Trained and Tested combination 3012 of 428400, taking 0.68 seconds to get val score of 0.4409:
#                 {'max_depth': 3, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 400, 'features': 9},
#             Current best combo with val score 0.5038:
#                     {'max_depth': 24, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 200, 'features': 50}
# Trained and Tested combination 3013 of 428400, taking 0.99 seconds to get val score of 0.4709:
#                 {'max_depth': 3, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 400, 'features': 11},
#             Current best combo with val score 0.5038:
#                     {'max_depth': 24, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 200, 'features': 50}
# 	round 72 iteration:  1
#
# Trained and Tested combination 3014 of 428400, taking 1.67 seconds to get val score of 0.4461:
#                 {'max_depth': 6, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.01, 'l2_regularization': 0.0001, 'max_iter': 400, 'features': 10},
#             Current best combo with val score 0.5038:
#                     {'max_depth': 24, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 200, 'features': 50}
# Trained and Tested combination 3015 of 428400, taking 0.73 seconds to get val score of 0.4508:
#                 {'max_depth': 3, 'max_bins': 64, 'interaction_cst': 'pairwise', 'learning_rate': 0.01, 'l2_regularization': 0.0001, 'max_iter': 400, 'features': 10},
#             Current best combo with val score 0.5038:
#                     {'max_depth': 24, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 200, 'features': 50}
# Trained and Tested combination 3016 of 428400, taking 0.5 seconds to get val score of 0.4603:
#                 {'max_depth': 3, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.01, 'l2_regularization': 0.0001, 'max_iter': 400, 'features': 10},
#             Current best combo with val score 0.5038:
#                     {'max_depth': 24, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 200, 'features': 50}
# Trained and Tested combination 3017 of 428400, taking 1.1 seconds to get val score of 0.0:
#                 {'max_depth': 3, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.0001, 'l2_regularization': 0.0001, 'max_iter': 400, 'features': 10},
#             Current best combo with val score 0.5038:
#                     {'max_depth': 24, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 200, 'features': 50}
# Already Trained and Tested combination (val score of 0.4466):
#             {'max_depth': 3, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 400, 'features': 10}
#             Current best combo (with val score 0.5038):
#                     {'max_depth': 24, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 200, 'features': 50}
#         Has trained 3017 of 428400 combinations so far
# Trained and Tested combination 3018 of 428400, taking 0.74 seconds to get val score of 0.4494:
#                 {'max_depth': 3, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.01, 'l2_regularization': 0.001, 'max_iter': 400, 'features': 10},
#             Current best combo with val score 0.5038:
#                     {'max_depth': 24, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 200, 'features': 50}
# Trained and Tested combination 3019 of 428400, taking 0.39 seconds to get val score of 0.4256:
#                 {'max_depth': 3, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.01, 'l2_regularization': 0.0001, 'max_iter': 200, 'features': 10},
#             Current best combo with val score 0.5038:
#                     {'max_depth': 24, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 200, 'features': 50}
# Trained and Tested combination 3020 of 428400, taking 0.73 seconds to get val score of 0.4499:
#                 {'max_depth': 3, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.01, 'l2_regularization': 0.0001, 'max_iter': 400, 'features': 9},
#             Current best combo with val score 0.5038:
#                     {'max_depth': 24, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 200, 'features': 50}
# Trained and Tested combination 3021 of 428400, taking 0.77 seconds to get val score of 0.374:
#                 {'max_depth': 3, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.01, 'l2_regularization': 0.0001, 'max_iter': 400, 'features': 11},
#             Current best combo with val score 0.5038:
#                     {'max_depth': 24, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 200, 'features': 50}
# Trained and Tested combination 3022 of 428400, taking 0.85 seconds to get val score of 0.4278:
#                 {'max_depth': 6, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 0.001, 'max_iter': 400, 'features': 10},
#             Current best combo with val score 0.5038:
#                     {'max_depth': 24, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 200, 'features': 50}
# Trained and Tested combination 3023 of 428400, taking 0.98 seconds to get val score of 0.4317:
#                 {'max_depth': 3, 'max_bins': 64, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 0.001, 'max_iter': 400, 'features': 10},
#             Current best combo with val score 0.5038:
#                     {'max_depth': 24, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 200, 'features': 50}
# Trained and Tested combination 3024 of 428400, taking 0.44 seconds to get val score of 0.4064:
#                 {'max_depth': 3, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.001, 'max_iter': 400, 'features': 10},
#             Current best combo with val score 0.5038:
#                     {'max_depth': 24, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 200, 'features': 50}
# Already Trained and Tested combination (val score of 0.4494):
#             {'max_depth': 3, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.01, 'l2_regularization': 0.001, 'max_iter': 400, 'features': 10}
#             Current best combo (with val score 0.5038):
#                     {'max_depth': 24, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 200, 'features': 50}
#         Has trained 3024 of 428400 combinations so far
# Already Trained and Tested combination (val score of 0.4466):
#             {'max_depth': 3, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 400, 'features': 10}
#             Current best combo (with val score 0.5038):
#                     {'max_depth': 24, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 200, 'features': 50}
#         Has trained 3024 of 428400 combinations so far
# Trained and Tested combination 3025 of 428400, taking 0.69 seconds to get val score of 0.4455:
#                 {'max_depth': 3, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 0.01, 'max_iter': 400, 'features': 10},
#             Current best combo with val score 0.5038:
#                     {'max_depth': 24, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 200, 'features': 50}
# Trained and Tested combination 3026 of 428400, taking 0.36 seconds to get val score of 0.4511:
#                 {'max_depth': 3, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 0.001, 'max_iter': 200, 'features': 10},
#             Current best combo with val score 0.5038:
#                     {'max_depth': 24, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 200, 'features': 50}
# Trained and Tested combination 3027 of 428400, taking 0.7 seconds to get val score of 0.4392:
#                 {'max_depth': 3, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 0.001, 'max_iter': 400, 'features': 9},
#             Current best combo with val score 0.5038:
#                     {'max_depth': 24, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 200, 'features': 50}
# Trained and Tested combination 3028 of 428400, taking 0.95 seconds to get val score of 0.4864:
#                 {'max_depth': 3, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 0.001, 'max_iter': 400, 'features': 11},
#             Current best combo with val score 0.5038:
#                     {'max_depth': 24, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 200, 'features': 50}
# Trained and Tested combination 3029 of 428400, taking 0.44 seconds to get val score of 0.4398:
#                 {'max_depth': 6, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 200, 'features': 10},
#             Current best combo with val score 0.5038:
#                     {'max_depth': 24, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 200, 'features': 50}
# Trained and Tested combination 3030 of 428400, taking 0.36 seconds to get val score of 0.4463:
#                 {'max_depth': 3, 'max_bins': 64, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 200, 'features': 10},
#             Current best combo with val score 0.5038:
#                     {'max_depth': 24, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 200, 'features': 50}
# Trained and Tested combination 3031 of 428400, taking 0.23 seconds to get val score of 0.4164:
#                 {'max_depth': 3, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 200, 'features': 10},
#             Current best combo with val score 0.5038:
#                     {'max_depth': 24, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 200, 'features': 50}
# Already Trained and Tested combination (val score of 0.4256):
#             {'max_depth': 3, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.01, 'l2_regularization': 0.0001, 'max_iter': 200, 'features': 10}
#             Current best combo (with val score 0.5038):
#                     {'max_depth': 24, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 200, 'features': 50}
#         Has trained 3031 of 428400 combinations so far
# Already Trained and Tested combination (val score of 0.4511):
#             {'max_depth': 3, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 0.001, 'max_iter': 200, 'features': 10}
#             Current best combo (with val score 0.5038):
#                     {'max_depth': 24, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 200, 'features': 50}
#         Has trained 3031 of 428400 combinations so far
# Already Trained and Tested combination (val score of 0.4582):
#             {'max_depth': 3, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 100, 'features': 10}
#             Current best combo (with val score 0.5038):
#                     {'max_depth': 24, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 200, 'features': 50}
#         Has trained 3031 of 428400 combinations so far
# Already Trained and Tested combination (val score of 0.4466):
#             {'max_depth': 3, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 400, 'features': 10}
#             Current best combo (with val score 0.5038):
#                     {'max_depth': 24, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 200, 'features': 50}
#         Has trained 3031 of 428400 combinations so far
# Trained and Tested combination 3032 of 428400, taking 0.34 seconds to get val score of 0.4472:
#                 {'max_depth': 3, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 200, 'features': 9},
#             Current best combo with val score 0.5038:
#                     {'max_depth': 24, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 200, 'features': 50}
# Trained and Tested combination 3033 of 428400, taking 0.49 seconds to get val score of 0.5017:
#                 {'max_depth': 3, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 200, 'features': 11},
#             Current best combo with val score 0.5038:
#                     {'max_depth': 24, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 200, 'features': 50}
# Trained and Tested combination 3034 of 428400, taking 0.91 seconds to get val score of 0.4194:
#                 {'max_depth': 6, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 400, 'features': 11},
#             Current best combo with val score 0.5038:
#                     {'max_depth': 24, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 200, 'features': 50}
# Trained and Tested combination 3035 of 428400, taking 0.67 seconds to get val score of 0.4409:
#                 {'max_depth': 3, 'max_bins': 64, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 400, 'features': 11},
#             Current best combo with val score 0.5038:
#                     {'max_depth': 24, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 200, 'features': 50}
# Trained and Tested combination 3036 of 428400, taking 0.64 seconds to get val score of 0.4293:
#                 {'max_depth': 3, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 400, 'features': 11},
#             Current best combo with val score 0.5038:
#                     {'max_depth': 24, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 200, 'features': 50}
# Already Trained and Tested combination (val score of 0.374):
#             {'max_depth': 3, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.01, 'l2_regularization': 0.0001, 'max_iter': 400, 'features': 11}
#             Current best combo (with val score 0.5038):
#                     {'max_depth': 24, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 200, 'features': 50}
#         Has trained 3036 of 428400 combinations so far
# Already Trained and Tested combination (val score of 0.4864):
#             {'max_depth': 3, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 0.001, 'max_iter': 400, 'features': 11}
#             Current best combo (with val score 0.5038):
#                     {'max_depth': 24, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 200, 'features': 50}
#         Has trained 3036 of 428400 combinations so far
# Already Trained and Tested combination (val score of 0.5017):
#             {'max_depth': 3, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 200, 'features': 11}
#             Current best combo (with val score 0.5038):
#                     {'max_depth': 24, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 200, 'features': 50}
#         Has trained 3036 of 428400 combinations so far
# Already Trained and Tested combination (val score of 0.4466):
#             {'max_depth': 3, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 400, 'features': 10}
#             Current best combo (with val score 0.5038):
#                     {'max_depth': 24, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 200, 'features': 50}
#         Has trained 3036 of 428400 combinations so far
# Trained and Tested combination 3037 of 428400, taking 0.72 seconds to get val score of 0.49:
#                 {'max_depth': 3, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 400, 'features': 12},
#             Current best combo with val score 0.5038:
#                     {'max_depth': 24, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 200, 'features': 50}
# % Combos Checked Thus Far: 3037 out of 428400 which is 0.708917%
# Cruising Coordrdinate 347 of 1056
#
# Cruise suspended due to suspicious case
# Guidance: round 73
#
# 	round 73 iteration:  0
#
# Trained and Tested combination 3038 of 428400, taking 1.01 seconds to get val score of 0.4306:
#                 {'max_depth': 96, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 400, 'features': 10},
#             Current best combo with val score 0.5038:
#                     {'max_depth': 24, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 200, 'features': 50}
# Already Trained and Tested combination (val score of 0.421):
#             {'max_depth': 192, 'max_bins': 64, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 400, 'features': 10}
#             Current best combo (with val score 0.5038):
#                     {'max_depth': 24, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 200, 'features': 50}
#         Has trained 3038 of 428400 combinations so far
# Already Trained and Tested combination (val score of 0.4063):
#             {'max_depth': 192, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 400, 'features': 10}
#             Current best combo (with val score 0.5038):
#                     {'max_depth': 24, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 200, 'features': 50}
#         Has trained 3038 of 428400 combinations so far
# Trained and Tested combination 3039 of 428400, taking 1.23 seconds to get val score of 0.4459:
#                 {'max_depth': 192, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.01, 'l2_regularization': 0.0001, 'max_iter': 400, 'features': 10},
#             Current best combo with val score 0.5038:
#                     {'max_depth': 24, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 200, 'features': 50}
# Trained and Tested combination 3040 of 428400, taking 1.04 seconds to get val score of 0.4321:
#                 {'max_depth': 192, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 0.001, 'max_iter': 400, 'features': 10},
#             Current best combo with val score 0.5038:
#                     {'max_depth': 24, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 200, 'features': 50}
# Trained and Tested combination 3041 of 428400, taking 0.53 seconds to get val score of 0.447:
#                 {'max_depth': 192, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 200, 'features': 10},
#             Current best combo with val score 0.5038:
#                     {'max_depth': 24, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 200, 'features': 50}
# Trained and Tested combination 3042 of 428400, taking 1.06 seconds to get val score of 0.4292:
#                 {'max_depth': 192, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 400, 'features': 9},
#             Current best combo with val score 0.5038:
#                     {'max_depth': 24, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 200, 'features': 50}
# Trained and Tested combination 3043 of 428400, taking 1.11 seconds to get val score of 0.4166:
#                 {'max_depth': 192, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 400, 'features': 11},
#             Current best combo with val score 0.5038:
#                     {'max_depth': 24, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 200, 'features': 50}
# 	round 73 iteration:  1
#
# Trained and Tested combination 3044 of 428400, taking 1.01 seconds to get val score of 0.4306:
#                 {'max_depth': 48, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 400, 'features': 10},
#             Current best combo with val score 0.5038:
#                     {'max_depth': 24, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 200, 'features': 50}
# Already Trained and Tested combination (val score of 0.4306):
#             {'max_depth': 192, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 400, 'features': 10}
#             Current best combo (with val score 0.5038):
#                     {'max_depth': 24, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 200, 'features': 50}
#         Has trained 3044 of 428400 combinations so far
# Trained and Tested combination 3045 of 428400, taking 0.91 seconds to get val score of 0.421:
#                 {'max_depth': 96, 'max_bins': 64, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 400, 'features': 10},
#             Current best combo with val score 0.5038:
#                     {'max_depth': 24, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 200, 'features': 50}
# Trained and Tested combination 3046 of 428400, taking 0.53 seconds to get val score of 0.4063:
#                 {'max_depth': 96, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 400, 'features': 10},
#             Current best combo with val score 0.5038:
#                     {'max_depth': 24, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 200, 'features': 50}
# Trained and Tested combination 3047 of 428400, taking 1.93 seconds to get val score of 0.4459:
#                 {'max_depth': 96, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.01, 'l2_regularization': 0.0001, 'max_iter': 400, 'features': 10},
#             Current best combo with val score 0.5038:
#                     {'max_depth': 24, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 200, 'features': 50}
# Trained and Tested combination 3048 of 428400, taking 1.61 seconds to get val score of 0.4321:
#                 {'max_depth': 96, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 0.001, 'max_iter': 400, 'features': 10},
#             Current best combo with val score 0.5038:
#                     {'max_depth': 24, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 200, 'features': 50}
# Trained and Tested combination 3049 of 428400, taking 0.51 seconds to get val score of 0.447:
#                 {'max_depth': 96, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 200, 'features': 10},
#             Current best combo with val score 0.5038:
#                     {'max_depth': 24, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 200, 'features': 50}
# Trained and Tested combination 3050 of 428400, taking 1.03 seconds to get val score of 0.4292:
#                 {'max_depth': 96, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 400, 'features': 9},
#             Current best combo with val score 0.5038:
#                     {'max_depth': 24, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 200, 'features': 50}
# Trained and Tested combination 3051 of 428400, taking 1.14 seconds to get val score of 0.4166:
#                 {'max_depth': 96, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 400, 'features': 11},
#             Current best combo with val score 0.5038:
#                     {'max_depth': 24, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 200, 'features': 50}
# Already Trained and Tested combination (val score of 0.4459):
#             {'max_depth': 96, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.01, 'l2_regularization': 0.0001, 'max_iter': 400, 'features': 10}
#             Current best combo (with val score 0.5038):
#                     {'max_depth': 24, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 200, 'features': 50}
#         Has trained 3051 of 428400 combinations so far
# Trained and Tested combination 3052 of 428400, taking 1.2 seconds to get val score of 0.4483:
#                 {'max_depth': 192, 'max_bins': 64, 'interaction_cst': 'pairwise', 'learning_rate': 0.01, 'l2_regularization': 0.0001, 'max_iter': 400, 'features': 10},
#             Current best combo with val score 0.5038:
#                     {'max_depth': 24, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 200, 'features': 50}
# Trained and Tested combination 3053 of 428400, taking 0.76 seconds to get val score of 0.4627:
#                 {'max_depth': 192, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.01, 'l2_regularization': 0.0001, 'max_iter': 400, 'features': 10},
#             Current best combo with val score 0.5038:
#                     {'max_depth': 24, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 200, 'features': 50}
# Trained and Tested combination 3054 of 428400, taking 1.47 seconds to get val score of 0.0:
#                 {'max_depth': 192, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.0001, 'l2_regularization': 0.0001, 'max_iter': 400, 'features': 10},
#             Current best combo with val score 0.5038:
#                     {'max_depth': 24, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 200, 'features': 50}
# Already Trained and Tested combination (val score of 0.4306):
#             {'max_depth': 192, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 400, 'features': 10}
#             Current best combo (with val score 0.5038):
#                     {'max_depth': 24, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 200, 'features': 50}
#         Has trained 3054 of 428400 combinations so far
# Trained and Tested combination 3055 of 428400, taking 2.02 seconds to get val score of 0.4462:
#                 {'max_depth': 192, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.01, 'l2_regularization': 0.001, 'max_iter': 400, 'features': 10},
#             Current best combo with val score 0.5038:
#                     {'max_depth': 24, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 200, 'features': 50}
# Trained and Tested combination 3056 of 428400, taking 0.73 seconds to get val score of 0.4275:
#                 {'max_depth': 192, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.01, 'l2_regularization': 0.0001, 'max_iter': 200, 'features': 10},
#             Current best combo with val score 0.5038:
#                     {'max_depth': 24, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 200, 'features': 50}
# Trained and Tested combination 3057 of 428400, taking 1.86 seconds to get val score of 0.4471:
#                 {'max_depth': 192, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.01, 'l2_regularization': 0.0001, 'max_iter': 400, 'features': 9},
#             Current best combo with val score 0.5038:
#                     {'max_depth': 24, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 200, 'features': 50}
# Trained and Tested combination 3058 of 428400, taking 1.43 seconds to get val score of 0.4163:
#                 {'max_depth': 192, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.01, 'l2_regularization': 0.0001, 'max_iter': 400, 'features': 11},
#             Current best combo with val score 0.5038:
#                     {'max_depth': 24, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 200, 'features': 50}
# Already Trained and Tested combination (val score of 0.4321):
#             {'max_depth': 96, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 0.001, 'max_iter': 400, 'features': 10}
#             Current best combo (with val score 0.5038):
#                     {'max_depth': 24, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 200, 'features': 50}
#         Has trained 3058 of 428400 combinations so far
# Trained and Tested combination 3059 of 428400, taking 1.03 seconds to get val score of 0.4246:
#                 {'max_depth': 192, 'max_bins': 64, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 0.001, 'max_iter': 400, 'features': 10},
#             Current best combo with val score 0.5038:
#                     {'max_depth': 24, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 200, 'features': 50}
# Trained and Tested combination 3060 of 428400, taking 0.56 seconds to get val score of 0.4064:
#                 {'max_depth': 192, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.001, 'max_iter': 400, 'features': 10},
#             Current best combo with val score 0.5038:
#                     {'max_depth': 24, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 200, 'features': 50}
# Already Trained and Tested combination (val score of 0.4462):
#             {'max_depth': 192, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.01, 'l2_regularization': 0.001, 'max_iter': 400, 'features': 10}
#             Current best combo (with val score 0.5038):
#                     {'max_depth': 24, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 200, 'features': 50}
#         Has trained 3060 of 428400 combinations so far
# Already Trained and Tested combination (val score of 0.4306):
#             {'max_depth': 192, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 400, 'features': 10}
#             Current best combo (with val score 0.5038):
#                     {'max_depth': 24, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 200, 'features': 50}
#         Has trained 3060 of 428400 combinations so far
# Trained and Tested combination 3061 of 428400, taking 0.96 seconds to get val score of 0.4371:
#                 {'max_depth': 192, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 0.01, 'max_iter': 400, 'features': 10},
#             Current best combo with val score 0.5038:
#                     {'max_depth': 24, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 200, 'features': 50}
# Trained and Tested combination 3062 of 428400, taking 0.52 seconds to get val score of 0.4412:
#                 {'max_depth': 192, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 0.001, 'max_iter': 200, 'features': 10},
#             Current best combo with val score 0.5038:
#                     {'max_depth': 24, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 200, 'features': 50}
# Trained and Tested combination 3063 of 428400, taking 0.99 seconds to get val score of 0.4258:
#                 {'max_depth': 192, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 0.001, 'max_iter': 400, 'features': 9},
#             Current best combo with val score 0.5038:
#                     {'max_depth': 24, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 200, 'features': 50}
# Trained and Tested combination 3064 of 428400, taking 1.1 seconds to get val score of 0.4154:
#                 {'max_depth': 192, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 0.001, 'max_iter': 400, 'features': 11},
#             Current best combo with val score 0.5038:
#                     {'max_depth': 24, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 200, 'features': 50}
# Already Trained and Tested combination (val score of 0.447):
#             {'max_depth': 96, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 200, 'features': 10}
#             Current best combo (with val score 0.5038):
#                     {'max_depth': 24, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 200, 'features': 50}
#         Has trained 3064 of 428400 combinations so far
# Trained and Tested combination 3065 of 428400, taking 0.58 seconds to get val score of 0.4339:
#                 {'max_depth': 192, 'max_bins': 64, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 200, 'features': 10},
#             Current best combo with val score 0.5038:
#                     {'max_depth': 24, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 200, 'features': 50}
# Trained and Tested combination 3066 of 428400, taking 0.34 seconds to get val score of 0.3995:
#                 {'max_depth': 192, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 200, 'features': 10},
#             Current best combo with val score 0.5038:
#                     {'max_depth': 24, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 200, 'features': 50}
# Already Trained and Tested combination (val score of 0.4275):
#             {'max_depth': 192, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.01, 'l2_regularization': 0.0001, 'max_iter': 200, 'features': 10}
#             Current best combo (with val score 0.5038):
#                     {'max_depth': 24, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 200, 'features': 50}
#         Has trained 3066 of 428400 combinations so far
# Already Trained and Tested combination (val score of 0.4412):
#             {'max_depth': 192, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 0.001, 'max_iter': 200, 'features': 10}
#             Current best combo (with val score 0.5038):
#                     {'max_depth': 24, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 200, 'features': 50}
#         Has trained 3066 of 428400 combinations so far
# Already Trained and Tested combination (val score of 0.4551):
#             {'max_depth': 192, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 100, 'features': 10}
#             Current best combo (with val score 0.5038):
#                     {'max_depth': 24, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 200, 'features': 50}
#         Has trained 3066 of 428400 combinations so far
# Already Trained and Tested combination (val score of 0.4306):
#             {'max_depth': 192, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 400, 'features': 10}
#             Current best combo (with val score 0.5038):
#                     {'max_depth': 24, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 200, 'features': 50}
#         Has trained 3066 of 428400 combinations so far
# Trained and Tested combination 3067 of 428400, taking 0.69 seconds to get val score of 0.435:
#                 {'max_depth': 192, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 200, 'features': 9},
#             Current best combo with val score 0.5038:
#                     {'max_depth': 24, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 200, 'features': 50}
# Trained and Tested combination 3068 of 428400, taking 0.6 seconds to get val score of 0.48:
#                 {'max_depth': 192, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 200, 'features': 11},
#             Current best combo with val score 0.5038:
#                     {'max_depth': 24, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 200, 'features': 50}
# Already Trained and Tested combination (val score of 0.4292):
#             {'max_depth': 96, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 400, 'features': 9}
#             Current best combo (with val score 0.5038):
#                     {'max_depth': 24, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 200, 'features': 50}
#         Has trained 3068 of 428400 combinations so far
# Trained and Tested combination 3069 of 428400, taking 0.95 seconds to get val score of 0.4121:
# ...
# Trained and Tested combination 3523 of 428400, taking 1.17 seconds to get val score of 0.4892:
#                 {'max_depth': 24, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 1, 'max_iter': 400, 'features': 16},
#             Current best combo with val score 0.5194:
#                     {'max_depth': 3, 'max_bins': 64, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 14}
# Trained and Tested combination 3524 of 428400, taking 0.96 seconds to get val score of 0.4935:
#                 {'max_depth': 12, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 14},
#             Current best combo with val score 0.5194:
#                     {'max_depth': 3, 'max_bins': 64, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 14}
# Trained and Tested combination 3525 of 428400, taking 0.99 seconds to get val score of 0.4987:
#                 {'max_depth': 48, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 14},
#             Current best combo with val score 0.5194:
#                     {'max_depth': 3, 'max_bins': 64, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 14}
# Trained and Tested combination 3526 of 428400, taking 0.93 seconds to get val score of 0.487:
#                 {'max_depth': 24, 'max_bins': 64, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 14},
#             Current best combo with val score 0.5194:
#                     {'max_depth': 3, 'max_bins': 64, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 14}
# Trained and Tested combination 3527 of 428400, taking 0.85 seconds to get val score of 0.4922:
#                 {'max_depth': 24, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 14},
#             Current best combo with val score 0.5194:
#                     {'max_depth': 3, 'max_bins': 64, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 14}
# Trained and Tested combination 3528 of 428400, taking 1.25 seconds to get val score of 0.2402:
#                 {'max_depth': 24, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.01, 'l2_regularization': 10, 'max_iter': 400, 'features': 14},
#             Current best combo with val score 0.5194:
#                     {'max_depth': 3, 'max_bins': 64, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 14}
# Already Trained and Tested combination (val score of 0.4639):
#             {'max_depth': 24, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 1, 'max_iter': 400, 'features': 14}
#             Current best combo (with val score 0.5194):
#                     {'max_depth': 3, 'max_bins': 64, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 14}
#         Has trained 3528 of 428400 combinations so far
# Trained and Tested combination 3529 of 428400, taking 0.52 seconds to get val score of 0.4591:
#                 {'max_depth': 24, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 14},
#             Current best combo with val score 0.5194:
#                     {'max_depth': 3, 'max_bins': 64, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 14}
# Trained and Tested combination 3530 of 428400, taking 0.97 seconds to get val score of 0.4933:
#                 {'max_depth': 24, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 13},
#             Current best combo with val score 0.5194:
#                     {'max_depth': 3, 'max_bins': 64, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 14}
# Already Trained and Tested combination (val score of 0.4753):
#             {'max_depth': 24, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 15}
#             Current best combo (with val score 0.5194):
#                     {'max_depth': 3, 'max_bins': 64, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 14}
#         Has trained 3530 of 428400 combinations so far
# Trained and Tested combination 3531 of 428400, taking 1.25 seconds to get val score of 0.4744:
#                 {'max_depth': 12, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 16},
#             Current best combo with val score 0.5194:
#                     {'max_depth': 3, 'max_bins': 64, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 14}
# Trained and Tested combination 3532 of 428400, taking 1.74 seconds to get val score of 0.4791:
#                 {'max_depth': 48, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 16},
#             Current best combo with val score 0.5194:
#                     {'max_depth': 3, 'max_bins': 64, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 14}
# Trained and Tested combination 3533 of 428400, taking 1.6 seconds to get val score of 0.4059:
#                 {'max_depth': 24, 'max_bins': 64, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 16},
#             Current best combo with val score 0.5194:
#                     {'max_depth': 3, 'max_bins': 64, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 14}
# Trained and Tested combination 3534 of 428400, taking 0.85 seconds to get val score of 0.4167:
#                 {'max_depth': 24, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 16},
#             Current best combo with val score 0.5194:
#                     {'max_depth': 3, 'max_bins': 64, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 14}
# Trained and Tested combination 3535 of 428400, taking 1.8 seconds to get val score of 0.0948:
#                 {'max_depth': 24, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.01, 'l2_regularization': 10, 'max_iter': 400, 'features': 16},
#             Current best combo with val score 0.5194:
#                     {'max_depth': 3, 'max_bins': 64, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 14}
# Already Trained and Tested combination (val score of 0.4892):
#             {'max_depth': 24, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 1, 'max_iter': 400, 'features': 16}
#             Current best combo (with val score 0.5194):
#                     {'max_depth': 3, 'max_bins': 64, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 14}
#         Has trained 3535 of 428400 combinations so far
# Trained and Tested combination 3536 of 428400, taking 0.66 seconds to get val score of 0.3642:
#                 {'max_depth': 24, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 16},
#             Current best combo with val score 0.5194:
#                     {'max_depth': 3, 'max_bins': 64, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 14}
# Already Trained and Tested combination (val score of 0.4753):
#             {'max_depth': 24, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 15}
#             Current best combo (with val score 0.5194):
#                     {'max_depth': 3, 'max_bins': 64, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 14}
#         Has trained 3536 of 428400 combinations so far
# Trained and Tested combination 3537 of 428400, taking 1.2 seconds to get val score of 0.4799:
#                 {'max_depth': 24, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 17},
#             Current best combo with val score 0.5194:
#                     {'max_depth': 3, 'max_bins': 64, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 14}
# % Combos Checked Thus Far: 3537 out of 428400 which is 0.82563%
# Cruising Coordrdinate 1056 of 1056
#
# FINAL STAGE: Begin final Guidance system
#
#
# Guidance: round FINAL
#
# 	round FINAL iteration:  0
#
# Already Trained and Tested combination (val score of 0.4947):
#             {'max_depth': 6, 'max_bins': 64, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 14}
#             Current best combo (with val score 0.5194):
#                     {'max_depth': 3, 'max_bins': 64, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 14}
#         Has trained 3537 of 428400 combinations so far
# Already Trained and Tested combination (val score of 0.4402):
#             {'max_depth': 3, 'max_bins': 16, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 14}
#             Current best combo (with val score 0.5194):
#                     {'max_depth': 3, 'max_bins': 64, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 14}
#         Has trained 3537 of 428400 combinations so far
# Already Trained and Tested combination (val score of 0.5117):
#             {'max_depth': 3, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 14}
#             Current best combo (with val score 0.5194):
#                     {'max_depth': 3, 'max_bins': 64, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 14}
#         Has trained 3537 of 428400 combinations so far
# Already Trained and Tested combination (val score of 0.4921):
#             {'max_depth': 3, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 14}
#             Current best combo (with val score 0.5194):
#                     {'max_depth': 3, 'max_bins': 64, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 14}
#         Has trained 3537 of 428400 combinations so far
# Already Trained and Tested combination (val score of 0.2793):
#             {'max_depth': 3, 'max_bins': 64, 'interaction_cst': 'pairwise', 'learning_rate': 0.01, 'l2_regularization': 10, 'max_iter': 400, 'features': 14}
#             Current best combo (with val score 0.5194):
#                     {'max_depth': 3, 'max_bins': 64, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 14}
#         Has trained 3537 of 428400 combinations so far
# Already Trained and Tested combination (val score of 0.486):
#             {'max_depth': 3, 'max_bins': 64, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 1, 'max_iter': 400, 'features': 14}
#             Current best combo (with val score 0.5194):
#                     {'max_depth': 3, 'max_bins': 64, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 14}
#         Has trained 3537 of 428400 combinations so far
# Already Trained and Tested combination (val score of 0.4978):
#             {'max_depth': 3, 'max_bins': 64, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 14}
#             Current best combo (with val score 0.5194):
#                     {'max_depth': 3, 'max_bins': 64, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 14}
#         Has trained 3537 of 428400 combinations so far
# Already Trained and Tested combination (val score of 0.4945):
#             {'max_depth': 3, 'max_bins': 64, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 13}
#             Current best combo (with val score 0.5194):
#                     {'max_depth': 3, 'max_bins': 64, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 14}
#         Has trained 3537 of 428400 combinations so far
# Already Trained and Tested combination (val score of 0.3517):
#             {'max_depth': 3, 'max_bins': 64, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 15}
#             Current best combo (with val score 0.5194):
#                     {'max_depth': 3, 'max_bins': 64, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 14}
#         Has trained 3537 of 428400 combinations so far
# % Combos Checked Thus Far: 3537 out of 428400 which is 0.82563%
# Max Val Score:
#  0.519425
# Max Val Score Std:
#  0.082093
# Best Combo Train Score:
#  0.65949
# Best Combo Train Score Std:
#  0.008173
# Max Combo Index:
#  (0, 2, 1, 4, 5, 4, 14) out of [7, 4, 2, 5, 6, 5, 51] (note best combo is 0-indexed)
# Max Combo Hyperparamer Combination:
#  {'max_depth': 3, 'max_bins': 64, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 14}
# Max Combo Features:
#  ('procedure_225792', 'ventilation_used', 'lods_score', 'race_AMERICAN INDIAN/ALASKA NATIVE', 'race_ASIAN', 'race_ASIAN - ASIAN INDIAN', 'race_ASIAN - CHINESE', 'race_ASIAN - KOREAN', 'race_ASIAN - SOUTH EAST ASIAN', 'race_BLACK/AFRICAN', 'race_BLACK/AFRICAN AMERICAN', 'race_BLACK/CAPE VERDEAN', 'race_BLACK/CARIBBEAN ISLAND', 'race_HISPANIC/LATINO - CENTRAL AMERICAN', 'race_HISPANIC/LATINO - COLUMBIAN', 'race_HISPANIC/LATINO - CUBAN', 'race_HISPANIC/LATINO - DOMINICAN', 'race_HISPANIC/LATINO - GUATEMALAN', 'race_HISPANIC/LATINO - HONDURAN', 'race_HISPANIC/LATINO - MEXICAN', 'race_HISPANIC/LATINO - PUERTO RICAN', 'race_HISPANIC/LATINO - SALVADORAN', 'race_MULTIPLE RACE/ETHNICITY', 'race_NATIVE HAWAIIAN OR OTHER PACIFIC ISLANDER', 'race_OTHER', 'race_PATIENT DECLINED TO ANSWER', 'race_PORTUGUESE', 'race_SOUTH AMERICAN', 'race_UNABLE TO OBTAIN', 'race_UNKNOWN', 'race_WHITE', 'race_WHITE - BRAZILIAN', 'race_WHITE - EASTERN EUROPEAN', 'race_WHITE - OTHER EUROPEAN', 'race_WHITE - RUSSIAN', 'race_HISPANIC OR LATINO', 'marital_status_DIVORCED', 'marital_status_MARRIED', 'marital_status_SINGLE', 'marital_status_WIDOWED', 'marital_status_0', 'hospital_stay_duration', 'procedure_225464', 'procedure_225802', 'procedure_227712', 'admission_type_DIRECT EMER.', 'admission_type_DIRECT OBSERVATION', 'admission_type_ELECTIVE', 'admission_type_EU OBSERVATION', 'admission_type_EW EMER.', 'admission_type_OBSERVATION ADMIT', 'admission_type_URGENT', 'admission_type_SURGICAL SAME DAY ADMISSION', 'procedure_225446', 'oasis_score', 'procedure_225400', 'procedure_224263', 'procedure_224276')
# % Combos Checked: 3537 out of 428400 which is 0.82563%
