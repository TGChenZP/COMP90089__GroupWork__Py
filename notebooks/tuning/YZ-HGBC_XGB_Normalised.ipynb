# %% [markdown]
# # Tuning Script

# %%
# Parameters subject to change in every script - involved in naming

MODEL = 'hgbc'
PREPROCESSING = 'normalise'
TUNER = 'yangzhoub'
OPTIMISED_METRIC = 'f1'

# %% [markdown]
# ---

# %%
# detect whether this is a google environment

COLAB_ENVIRONMENT = False

try:
    from google.colab import drive
    drive.mount('/content/drive')
    COLAB_ENVIRONMENT = True
except:
    pass
# Out:
# Mounted at /content/drive

# %%
import sys
import os
import pickle

if COLAB_ENVIRONMENT:
    home_directory = './drive/MyDrive/LAB/COMP90089__GroupWork__Py/' # my home directory is stored in ./LAB of google drive
    if MODEL == 'ebr':
        # !pip install interpret==0.5.0
    elif MODEL == 'cbr':
        # !pip install catboost
    elif MODEL in ['tf', 'mlp']:
        # !pip install PyTorch2Sklearn
    # !pip install JXAutoML
else:
    home_directory = '../../'

from JXAutoML.YangZhouB_10CV import YangZhouB_10CV as Tuner

import pandas as pd
# Out:
# Collecting JXAutoML
#   Downloading JXAutoML-0.4.4-py3-none-any.whl.metadata (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.2/67.2 kB 3.9 MB/s eta 0:00:00
# Downloading JXAutoML-0.4.4-py3-none-any.whl (52 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.1/52.1 kB 3.7 MB/s eta 0:00:00
# Installing collected packages: JXAutoML
# Successfully installed JXAutoML-0.4.4

# %%
# Parameters that are same for every script

FOLDS = 10  # we have decided to do 10 fold validation

SEED = 42

TASK_TYPE = 'Classification'  # this task is a classification task

# we have decided to tune features as hp
TUNE_FEATURES_AS_HYPERPARAMETERS = True

# %% [markdown]
# ---

# %%
# model to use to tune
from sklearn.ensemble import HistGradientBoostingClassifier as clf

# what values to try for each hyperparameter
parameter_choices = {
    'max_depth': (3, 6, 12, 24, 48, 96, 192),
    'max_bins': (4, 16, 64, 255),
    'interaction_cst': ('no_interactions', 'pairwise'),
    'learning_rate': (0.00000001, 0.000001, 0.0001, 0.01, 0.1),
    'l2_regularization': (0.0001, 0.001, 0.01, 0.1, 1, 10),
    'max_iter': (25, 50, 100, 200, 400)

}

# what values to set non-tuneable parameters/hyperparameters
non_tunable_hyperparameters_dict = {
                                    'random_state': SEED,
                                    }

# %% [markdown]
# ---

# %% [markdown]
# Read in and Prepare Data

# %%
# Import data and store as lists

train_x_list = []
train_y_list = []
val_x_list = []
val_y_list = []

for i in range(FOLDS):
    train_data = pd.read_csv(
        f'{home_directory}data/curated/modelling/{PREPROCESSING}/train_{i}.csv')
    val_data = pd.read_csv(
        f'{home_directory}data/curated/modelling/{PREPROCESSING}/val_{i}.csv')

    # get the correct rows for X and y
    train_x = train_data.drop(
        ['mortality_status', 'subject_id', 'hadm_id', 'stay_id'], axis=1)
    train_y = train_data['mortality_status']
    val_x = val_data.drop(
        ['mortality_status', 'subject_id', 'hadm_id', 'stay_id'], axis=1)
    val_y = val_data['mortality_status']

    train_x_list.append(train_x)
    train_y_list.append(train_y)
    val_x_list.append(val_x)
    val_y_list.append(val_y)

# %%
# Import feature importance ordering

with open(f'{home_directory}models/xgb_feature_importance_ordering_{PREPROCESSING}.pickle', 'rb') as f:
    feature_importance_ordering = pickle.load(f)

# %% [markdown]
# Set parameters

# %%
# initialisation
tuner = Tuner()

print('---')

# define what model we are tuning
tuner.read_in_model(clf, TASK_TYPE, optimised_metric=OPTIMISED_METRIC)

print('---')

# read in the data for training and validation
tuner.read_in_data(train_x_list, train_y_list, val_x_list, val_y_list)

print('---')

# set what hp values to tune
tuner.set_hyperparameters(parameter_choices)
# WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

# set up hp values that need to be changed from default but NOT to be tuned
tuner.set_non_tuneable_hyperparameters(non_tunable_hyperparameters_dict)

print('---')

# set up feature importance ordering

if TUNE_FEATURES_AS_HYPERPARAMETERS:
    tuner.set_features(feature_importance_ordering)
    # WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

try:  # try to read in previous results to continue tuning ...
    tuner.read_in_tuning_result_df(
        f'{home_directory}models/tuning/{TUNER}_{MODEL}_{PREPROCESSING}.csv')
except:
    print('No previous tuning data read in')

print('---')

# set up where to save the tuning result csv
tuner.set_tuning_result_saving_address(
    f'{home_directory}models/tuning/{TUNER}_{MODEL}_{PREPROCESSING}.csv')

print('---')

# set up where to save the current best model
tuner.set_best_model_saving_address(
    f'{home_directory}models/tmp_models/{TUNER}_{MODEL}_{PREPROCESSING}')
# Out:
# YangZhouB Initialised
# ---
# Successfully read in model <class 'sklearn.ensemble._hist_gradient_boosting.gradient_boosting.HistGradientBoostingClassifier'>, which is a Classification model optimising for f1
# ---
# Read in Train X data list
# Read in Train y data list
# Read in Val X data list
# Read in Val y data list
# ---
# Successfully recorded hyperparameter choices
# ---
# Successfully recorded non_tuneable_hyperparameter choices
# ---
# Successfully recorded tuneable feature combination choices and updated relevant internal structures
# ---
# Successfully read in tuning result of 2312 rows, for 2312.0 combos
# ---
# Successfully set tuning output address
# ---
# Successfully set best model output address

# %%
# ignore warnings

import warnings
warnings.filterwarnings("ignore")

# %%
# begin tuning ... (or continue training)

tuner.tune()
# Out:
# Streaming output truncated to the last 5000 lines.
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 15}
# Trained and Tested combination 3414 of 403200, taking 0.9 seconds to get val score of 0.4719:
#                 {'max_depth': 24, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.01, 'l2_regularization': 0.0001, 'max_iter': 400, 'features': 31},
#             Current best combo with val score 0.5032:
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 15}
# Trained and Tested combination 3415 of 403200, taking 1.0 seconds to get val score of 0.3887:
#                 {'max_depth': 12, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.001, 'max_iter': 400, 'features': 30},
#             Current best combo with val score 0.5032:
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 15}
# Trained and Tested combination 3416 of 403200, taking 0.98 seconds to get val score of 0.3762:
#                 {'max_depth': 48, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.001, 'max_iter': 400, 'features': 30},
#             Current best combo with val score 0.5032:
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 15}
# Already Trained and Tested combination (val score of 0.42):
#             {'max_depth': 24, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.001, 'max_iter': 400, 'features': 30}
#             Current best combo (with val score 0.5032):
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 15}
#         Has trained 3416 of 403200 combinations so far
# Trained and Tested combination 3417 of 403200, taking 2.12 seconds to get val score of 0.056:
#                 {'max_depth': 24, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 0.001, 'max_iter': 400, 'features': 30},
#             Current best combo with val score 0.5032:
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 15}
# Already Trained and Tested combination (val score of 0.4719):
#             {'max_depth': 24, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.01, 'l2_regularization': 0.001, 'max_iter': 400, 'features': 30}
#             Current best combo (with val score 0.5032):
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 15}
#         Has trained 3417 of 403200 combinations so far
# Already Trained and Tested combination (val score of 0.3734):
#             {'max_depth': 24, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 400, 'features': 30}
#             Current best combo (with val score 0.5032):
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 15}
#         Has trained 3417 of 403200 combinations so far
# Trained and Tested combination 3418 of 403200, taking 1.26 seconds to get val score of 0.3869:
#                 {'max_depth': 24, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.01, 'max_iter': 400, 'features': 30},
#             Current best combo with val score 0.5032:
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 15}
# Trained and Tested combination 3419 of 403200, taking 0.49 seconds to get val score of 0.4067:
#                 {'max_depth': 24, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.001, 'max_iter': 200, 'features': 30},
#             Current best combo with val score 0.5032:
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 15}
# Trained and Tested combination 3420 of 403200, taking 0.98 seconds to get val score of 0.3836:
#                 {'max_depth': 24, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.001, 'max_iter': 400, 'features': 29},
#             Current best combo with val score 0.5032:
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 15}
# Trained and Tested combination 3421 of 403200, taking 1.1 seconds to get val score of 0.3938:
#                 {'max_depth': 24, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.001, 'max_iter': 400, 'features': 31},
#             Current best combo with val score 0.5032:
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 15}
# Trained and Tested combination 3422 of 403200, taking 0.5 seconds to get val score of 0.3998:
#                 {'max_depth': 12, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 200, 'features': 30},
#             Current best combo with val score 0.5032:
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 15}
# Trained and Tested combination 3423 of 403200, taking 0.49 seconds to get val score of 0.4053:
#                 {'max_depth': 48, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 200, 'features': 30},
#             Current best combo with val score 0.5032:
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 15}
# Already Trained and Tested combination (val score of 0.4597):
#             {'max_depth': 24, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 200, 'features': 30}
#             Current best combo (with val score 0.5032):
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 15}
#         Has trained 3423 of 403200 combinations so far
# Trained and Tested combination 3424 of 403200, taking 1.29 seconds to get val score of 0.0067:
#                 {'max_depth': 24, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 200, 'features': 30},
#             Current best combo with val score 0.5032:
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 15}
# Already Trained and Tested combination (val score of 0.0):
#             {'max_depth': 24, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.01, 'l2_regularization': 0.0001, 'max_iter': 200, 'features': 30}
#             Current best combo (with val score 0.5032):
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 15}
#         Has trained 3424 of 403200 combinations so far
# Already Trained and Tested combination (val score of 0.4067):
#             {'max_depth': 24, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.001, 'max_iter': 200, 'features': 30}
#             Current best combo (with val score 0.5032):
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 15}
#         Has trained 3424 of 403200 combinations so far
# Trained and Tested combination 3425 of 403200, taking 0.24 seconds to get val score of 0.4089:
#                 {'max_depth': 24, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 100, 'features': 30},
#             Current best combo with val score 0.5032:
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 15}
# Already Trained and Tested combination (val score of 0.3734):
#             {'max_depth': 24, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 400, 'features': 30}
#             Current best combo (with val score 0.5032):
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 15}
#         Has trained 3425 of 403200 combinations so far
# Trained and Tested combination 3426 of 403200, taking 0.7 seconds to get val score of 0.4088:
#                 {'max_depth': 24, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 200, 'features': 29},
#             Current best combo with val score 0.5032:
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 15}
# Trained and Tested combination 3427 of 403200, taking 0.49 seconds to get val score of 0.3604:
#                 {'max_depth': 24, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 200, 'features': 31},
#             Current best combo with val score 0.5032:
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 15}
# Trained and Tested combination 3428 of 403200, taking 0.98 seconds to get val score of 0.3877:
#                 {'max_depth': 12, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 400, 'features': 29},
#             Current best combo with val score 0.5032:
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 15}
# Trained and Tested combination 3429 of 403200, taking 0.97 seconds to get val score of 0.3868:
#                 {'max_depth': 48, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 400, 'features': 29},
#             Current best combo with val score 0.5032:
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 15}
# Already Trained and Tested combination (val score of 0.3531):
#             {'max_depth': 24, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 400, 'features': 29}
#             Current best combo (with val score 0.5032):
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 15}
#         Has trained 3429 of 403200 combinations so far
# Trained and Tested combination 3430 of 403200, taking 1.5 seconds to get val score of 0.0478:
#                 {'max_depth': 24, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 400, 'features': 29},
#             Current best combo with val score 0.5032:
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 15}
# Already Trained and Tested combination (val score of 0.4713):
#             {'max_depth': 24, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.01, 'l2_regularization': 0.0001, 'max_iter': 400, 'features': 29}
#             Current best combo (with val score 0.5032):
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 15}
#         Has trained 3430 of 403200 combinations so far
# Already Trained and Tested combination (val score of 0.3836):
#             {'max_depth': 24, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.001, 'max_iter': 400, 'features': 29}
#             Current best combo (with val score 0.5032):
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 15}
#         Has trained 3430 of 403200 combinations so far
# Already Trained and Tested combination (val score of 0.4088):
#             {'max_depth': 24, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 200, 'features': 29}
#             Current best combo (with val score 0.5032):
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 15}
#         Has trained 3430 of 403200 combinations so far
# Trained and Tested combination 3431 of 403200, taking 0.97 seconds to get val score of 0.4011:
#                 {'max_depth': 24, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 400, 'features': 28},
#             Current best combo with val score 0.5032:
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 15}
# Already Trained and Tested combination (val score of 0.3734):
#             {'max_depth': 24, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 400, 'features': 30}
#             Current best combo (with val score 0.5032):
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 15}
#         Has trained 3431 of 403200 combinations so far
# Trained and Tested combination 3432 of 403200, taking 1.0 seconds to get val score of 0.3916:
#                 {'max_depth': 12, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 400, 'features': 31},
#             Current best combo with val score 0.5032:
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 15}
# Trained and Tested combination 3433 of 403200, taking 0.99 seconds to get val score of 0.393:
#                 {'max_depth': 48, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 400, 'features': 31},
#             Current best combo with val score 0.5032:
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 15}
# Already Trained and Tested combination (val score of 0.4317):
#             {'max_depth': 24, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 400, 'features': 31}
#             Current best combo (with val score 0.5032):
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 15}
#         Has trained 3433 of 403200 combinations so far
# Trained and Tested combination 3434 of 403200, taking 1.76 seconds to get val score of 0.0472:
#                 {'max_depth': 24, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 400, 'features': 31},
#             Current best combo with val score 0.5032:
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 15}
# Already Trained and Tested combination (val score of 0.4719):
#             {'max_depth': 24, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.01, 'l2_regularization': 0.0001, 'max_iter': 400, 'features': 31}
#             Current best combo (with val score 0.5032):
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 15}
#         Has trained 3434 of 403200 combinations so far
# Already Trained and Tested combination (val score of 0.3938):
#             {'max_depth': 24, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.001, 'max_iter': 400, 'features': 31}
#             Current best combo (with val score 0.5032):
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 15}
#         Has trained 3434 of 403200 combinations so far
# Already Trained and Tested combination (val score of 0.3604):
#             {'max_depth': 24, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 200, 'features': 31}
#             Current best combo (with val score 0.5032):
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 15}
#         Has trained 3434 of 403200 combinations so far
# Already Trained and Tested combination (val score of 0.3734):
#             {'max_depth': 24, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 400, 'features': 30}
#             Current best combo (with val score 0.5032):
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 15}
#         Has trained 3434 of 403200 combinations so far
# Trained and Tested combination 3435 of 403200, taking 1.18 seconds to get val score of 0.4104:
#                 {'max_depth': 24, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.0001, 'max_iter': 400, 'features': 32},
#             Current best combo with val score 0.5032:
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 15}
# % Combos Checked Thus Far: 3435 out of 403200 which is 0.851935%
# Cruising Coordrdinate 789 of 1056
#
# Cruising Coordrdinate 790 of 1056
#
# Cruising Coordrdinate 791 of 1056
#
# Cruising Coordrdinate 792 of 1056
#
# Cruising Coordrdinate 793 of 1056
#
# Cruising Coordrdinate 794 of 1056
#
# Cruising Coordrdinate 795 of 1056
#
# Cruising Coordrdinate 796 of 1056
#
# Cruising Coordrdinate 797 of 1056
#
# Cruising Coordrdinate 798 of 1056
#
# Cruising Coordrdinate 799 of 1056
#
# Cruising Coordrdinate 800 of 1056
#
# Cruising Coordrdinate 801 of 1056
#
# Cruising Coordrdinate 802 of 1056
#
# Cruising Coordrdinate 803 of 1056
#
# Cruising Coordrdinate 804 of 1056
#
# Cruising Coordrdinate 805 of 1056
#
# Cruise suspended due to suspicious case
# Guidance: round 83
#
# 	round 83 iteration:  0
#
# Trained and Tested combination 3436 of 403200, taking 1.0 seconds to get val score of 0.4166:
#                 {'max_depth': 96, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 30},
#             Current best combo with val score 0.5032:
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 15}
# Trained and Tested combination 3437 of 403200, taking 0.92 seconds to get val score of 0.4927:
#                 {'max_depth': 192, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 30},
#             Current best combo with val score 0.5032:
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 15}
# Already Trained and Tested combination (val score of 0.3028):
#             {'max_depth': 192, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 30}
#             Current best combo (with val score 0.5032):
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 15}
#         Has trained 3437 of 403200 combinations so far
# Trained and Tested combination 3438 of 403200, taking 0.79 seconds to get val score of 0.0191:
#                 {'max_depth': 192, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.01, 'l2_regularization': 10, 'max_iter': 400, 'features': 30},
#             Current best combo with val score 0.5032:
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 15}
# Trained and Tested combination 3439 of 403200, taking 1.0 seconds to get val score of 0.4234:
#                 {'max_depth': 192, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 1, 'max_iter': 400, 'features': 30},
#             Current best combo with val score 0.5032:
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 15}
# Trained and Tested combination 3440 of 403200, taking 0.75 seconds to get val score of 0.4511:
#                 {'max_depth': 192, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 30},
#             Current best combo with val score 0.5032:
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 15}
# Trained and Tested combination 3441 of 403200, taking 1.24 seconds to get val score of 0.406:
#                 {'max_depth': 192, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 29},
#             Current best combo with val score 0.5032:
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 15}
# Trained and Tested combination 3442 of 403200, taking 1.0 seconds to get val score of 0.3786:
#                 {'max_depth': 192, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 31},
#             Current best combo with val score 0.5032:
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 15}
# 	round 83 iteration:  1
#
# Trained and Tested combination 3443 of 403200, taking 0.99 seconds to get val score of 0.4166:
#                 {'max_depth': 48, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 30},
#             Current best combo with val score 0.5032:
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 15}
# Already Trained and Tested combination (val score of 0.4166):
#             {'max_depth': 192, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 30}
#             Current best combo (with val score 0.5032):
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 15}
#         Has trained 3443 of 403200 combinations so far
# Trained and Tested combination 3444 of 403200, taking 0.89 seconds to get val score of 0.4927:
#                 {'max_depth': 96, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 30},
#             Current best combo with val score 0.5032:
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 15}
# Trained and Tested combination 3445 of 403200, taking 2.19 seconds to get val score of 0.3028:
#                 {'max_depth': 96, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 30},
#             Current best combo with val score 0.5032:
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 15}
# Trained and Tested combination 3446 of 403200, taking 0.83 seconds to get val score of 0.0191:
#                 {'max_depth': 96, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.01, 'l2_regularization': 10, 'max_iter': 400, 'features': 30},
#             Current best combo with val score 0.5032:
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 15}
# Trained and Tested combination 3447 of 403200, taking 1.02 seconds to get val score of 0.4234:
#                 {'max_depth': 96, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 1, 'max_iter': 400, 'features': 30},
#             Current best combo with val score 0.5032:
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 15}
# Trained and Tested combination 3448 of 403200, taking 0.5 seconds to get val score of 0.4511:
#                 {'max_depth': 96, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 30},
#             Current best combo with val score 0.5032:
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 15}
# Trained and Tested combination 3449 of 403200, taking 1.16 seconds to get val score of 0.406:
#                 {'max_depth': 96, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 29},
#             Current best combo with val score 0.5032:
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 15}
# Trained and Tested combination 3450 of 403200, taking 1.5 seconds to get val score of 0.3786:
#                 {'max_depth': 96, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 31},
#             Current best combo with val score 0.5032:
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 15}
# Already Trained and Tested combination (val score of 0.4927):
#             {'max_depth': 96, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 30}
#             Current best combo (with val score 0.5032):
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 15}
#         Has trained 3450 of 403200 combinations so far
# Trained and Tested combination 3451 of 403200, taking 0.57 seconds to get val score of 0.0826:
#                 {'max_depth': 192, 'max_bins': 16, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 30},
#             Current best combo with val score 0.5032:
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 15}
# Already Trained and Tested combination (val score of 0.4166):
#             {'max_depth': 192, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 30}
#             Current best combo (with val score 0.5032):
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 15}
#         Has trained 3451 of 403200 combinations so far
# Trained and Tested combination 3452 of 403200, taking 1.93 seconds to get val score of 0.2355:
#                 {'max_depth': 192, 'max_bins': 64, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 30},
#             Current best combo with val score 0.5032:
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 15}
# Trained and Tested combination 3453 of 403200, taking 0.74 seconds to get val score of 0.0067:
#                 {'max_depth': 192, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.01, 'l2_regularization': 10, 'max_iter': 400, 'features': 30},
#             Current best combo with val score 0.5032:
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 15}
# Trained and Tested combination 3454 of 403200, taking 0.98 seconds to get val score of 0.4548:
#                 {'max_depth': 192, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 1, 'max_iter': 400, 'features': 30},
#             Current best combo with val score 0.5032:
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 15}
# Trained and Tested combination 3455 of 403200, taking 0.44 seconds to get val score of 0.4855:
#                 {'max_depth': 192, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 30},
#             Current best combo with val score 0.5032:
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 15}
# Trained and Tested combination 3456 of 403200, taking 1.33 seconds to get val score of 0.4908:
#                 {'max_depth': 192, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 29},
#             Current best combo with val score 0.5032:
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 15}
# Trained and Tested combination 3457 of 403200, taking 1.19 seconds to get val score of 0.4499:
#                 {'max_depth': 192, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 31},
#             Current best combo with val score 0.5032:
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 15}
# Already Trained and Tested combination (val score of 0.4234):
#             {'max_depth': 96, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 1, 'max_iter': 400, 'features': 30}
#             Current best combo (with val score 0.5032):
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 15}
#         Has trained 3457 of 403200 combinations so far
# Already Trained and Tested combination (val score of 0.4548):
#             {'max_depth': 192, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 1, 'max_iter': 400, 'features': 30}
#             Current best combo (with val score 0.5032):
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 15}
#         Has trained 3457 of 403200 combinations so far
# Trained and Tested combination 3458 of 403200, taking 1.48 seconds to get val score of 0.1452:
#                 {'max_depth': 192, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 1, 'max_iter': 400, 'features': 30},
#             Current best combo with val score 0.5032:
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 15}
# Trained and Tested combination 3459 of 403200, taking 1.0 seconds to get val score of 0.3898:
#                 {'max_depth': 192, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.01, 'l2_regularization': 1, 'max_iter': 400, 'features': 30},
#             Current best combo with val score 0.5032:
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 15}
# Trained and Tested combination 3460 of 403200, taking 1.5 seconds to get val score of 0.3987:
#                 {'max_depth': 192, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 0.1, 'max_iter': 400, 'features': 30},
#             Current best combo with val score 0.5032:
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 15}
# Already Trained and Tested combination (val score of 0.4166):
#             {'max_depth': 192, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 30}
#             Current best combo (with val score 0.5032):
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 15}
#         Has trained 3460 of 403200 combinations so far
# Trained and Tested combination 3461 of 403200, taking 0.53 seconds to get val score of 0.4037:
#                 {'max_depth': 192, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 1, 'max_iter': 200, 'features': 30},
#             Current best combo with val score 0.5032:
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 15}
# Trained and Tested combination 3462 of 403200, taking 0.97 seconds to get val score of 0.4348:
#                 {'max_depth': 192, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 1, 'max_iter': 400, 'features': 29},
#             Current best combo with val score 0.5032:
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 15}
# Trained and Tested combination 3463 of 403200, taking 1.0 seconds to get val score of 0.3669:
#                 {'max_depth': 192, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 1, 'max_iter': 400, 'features': 31},
#             Current best combo with val score 0.5032:
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 15}
# Already Trained and Tested combination (val score of 0.4511):
#             {'max_depth': 96, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 30}
#             Current best combo (with val score 0.5032):
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 15}
#         Has trained 3463 of 403200 combinations so far
# Already Trained and Tested combination (val score of 0.4855):
#             {'max_depth': 192, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 30}
#             Current best combo (with val score 0.5032):
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 15}
#         Has trained 3463 of 403200 combinations so far
# Trained and Tested combination 3464 of 403200, taking 0.77 seconds to get val score of 0.1556:
#                 {'max_depth': 192, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 30},
#             Current best combo with val score 0.5032:
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 15}
# Trained and Tested combination 3465 of 403200, taking 0.41 seconds to get val score of 0.0:
#                 {'max_depth': 192, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.01, 'l2_regularization': 10, 'max_iter': 200, 'features': 30},
#             Current best combo with val score 0.5032:
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 15}
# Already Trained and Tested combination (val score of 0.4037):
#             {'max_depth': 192, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 1, 'max_iter': 200, 'features': 30}
#             Current best combo (with val score 0.5032):
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 15}
#         Has trained 3465 of 403200 combinations so far
# Trained and Tested combination 3466 of 403200, taking 0.33 seconds to get val score of 0.4981:
#                 {'max_depth': 192, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 100, 'features': 30},
#             Current best combo with val score 0.5032:
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 15}
# Already Trained and Tested combination (val score of 0.4166):
#             {'max_depth': 192, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 30}
#             Current best combo (with val score 0.5032):
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 15}
#         Has trained 3466 of 403200 combinations so far
# Trained and Tested combination 3467 of 403200, taking 0.5 seconds to get val score of 0.4458:
#                 {'max_depth': 192, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 29},
#             Current best combo with val score 0.5032:
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 15}
# Trained and Tested combination 3468 of 403200, taking 0.74 seconds to get val score of 0.4081:
#                 {'max_depth': 192, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 31},
#             Current best combo with val score 0.5032:
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 15}
# % Combos Checked Thus Far: 3468 out of 403200 which is 0.860119%
# Cruising Coordrdinate 806 of 1056
#
# Cruising Coordrdinate 807 of 1056
#
# Cruising Coordrdinate 808 of 1056
#
# Cruising Coordrdinate 809 of 1056
#
# Cruising Coordrdinate 810 of 1056
#
# Cruising Coordrdinate 811 of 1056
#
# Cruising Coordrdinate 812 of 1056
#
# Cruising Coordrdinate 813 of 1056
#
# Cruising Coordrdinate 814 of 1056
#
# Cruising Coordrdinate 815 of 1056
#
# Cruising Coordrdinate 816 of 1056
#
# Cruising Coordrdinate 817 of 1056
#
# Cruise suspended due to suspicious case
# Guidance: round 84
#
# 	round 84 iteration:  0
#
# Trained and Tested combination 3469 of 403200, taking 0.92 seconds to get val score of 0.4025:
#                 {'max_depth': 6, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 30},
#             Current best combo with val score 0.5032:
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 15}
# Trained and Tested combination 3470 of 403200, taking 0.53 seconds to get val score of 0.4876:
#                 {'max_depth': 3, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 30},
#             Current best combo with val score 0.5032:
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 15}
# Already Trained and Tested combination (val score of 0.2379):
#             {'max_depth': 3, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 30}
#             Current best combo (with val score 0.5032):
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 15}
#         Has trained 3470 of 403200 combinations so far
# Trained and Tested combination 3471 of 403200, taking 0.72 seconds to get val score of 0.0309:
#                 {'max_depth': 3, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.01, 'l2_regularization': 10, 'max_iter': 400, 'features': 30},
#             Current best combo with val score 0.5032:
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 15}
# Trained and Tested combination 3472 of 403200, taking 0.54 seconds to get val score of 0.4628:
#                 {'max_depth': 3, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 1, 'max_iter': 400, 'features': 30},
#             Current best combo with val score 0.5032:
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 15}
# Trained and Tested combination 3473 of 403200, taking 0.29 seconds to get val score of 0.4258:
#                 {'max_depth': 3, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 30},
#             Current best combo with val score 0.5032:
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 15}
# Trained and Tested combination 3474 of 403200, taking 0.54 seconds to get val score of 0.3891:
#                 {'max_depth': 3, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 29},
#             Current best combo with val score 0.5032:
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 15}
# Trained and Tested combination 3475 of 403200, taking 0.76 seconds to get val score of 0.3656:
#                 {'max_depth': 3, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 31},
#             Current best combo with val score 0.5032:
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 15}
# 	round 84 iteration:  1
#
# Already Trained and Tested combination (val score of 0.4048):
#             {'max_depth': 3, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 30}
#             Current best combo (with val score 0.5032):
#                     {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 15}
#         Has trained 3475 of 403200 combinations so far
# Trained and Tested combination 3476 of 403200, taking 1.52 seconds to get val score of 0.4155:
#                 {'max_depth': 12, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 30},
#             Current best combo with val score 0.5032:
# ...
#                     {'max_depth': 192, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 19}
#         Has trained 4062 of 403200 combinations so far
# Already Trained and Tested combination (val score of 0.4179):
#             {'max_depth': 24, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 21}
#             Current best combo (with val score 0.5074):
#                     {'max_depth': 192, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 19}
#         Has trained 4062 of 403200 combinations so far
# Trained and Tested combination 4063 of 403200, taking 0.73 seconds to get val score of 0.0191:
#                 {'max_depth': 24, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.01, 'l2_regularization': 10, 'max_iter': 400, 'features': 21},
#             Current best combo with val score 0.5074:
#                     {'max_depth': 192, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 19}
# Trained and Tested combination 4064 of 403200, taking 0.9 seconds to get val score of 0.3384:
#                 {'max_depth': 24, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 1, 'max_iter': 400, 'features': 21},
#             Current best combo with val score 0.5074:
#                     {'max_depth': 192, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 19}
# Already Trained and Tested combination (val score of 0.4104):
#             {'max_depth': 24, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 21}
#             Current best combo (with val score 0.5074):
#                     {'max_depth': 192, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 19}
#         Has trained 4064 of 403200 combinations so far
# Already Trained and Tested combination (val score of 0.3778):
#             {'max_depth': 24, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 20}
#             Current best combo (with val score 0.5074):
#                     {'max_depth': 192, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 19}
#         Has trained 4064 of 403200 combinations so far
# Trained and Tested combination 4065 of 403200, taking 0.92 seconds to get val score of 0.3751:
#                 {'max_depth': 24, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 22},
#             Current best combo with val score 0.5074:
#                     {'max_depth': 192, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 19}
# % Combos Checked Thus Far: 4065 out of 403200 which is 1.0081849999999999%
# FINAL STAGE: Begin final Guidance system
#
#
# Guidance: round FINAL
#
# 	round FINAL iteration:  0
#
# Already Trained and Tested combination (val score of 0.5074):
#             {'max_depth': 96, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 19}
#             Current best combo (with val score 0.5074):
#                     {'max_depth': 192, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 19}
#         Has trained 4065 of 403200 combinations so far
# Already Trained and Tested combination (val score of 0.1267):
#             {'max_depth': 192, 'max_bins': 16, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 19}
#             Current best combo (with val score 0.5074):
#                     {'max_depth': 192, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 19}
#         Has trained 4065 of 403200 combinations so far
# Already Trained and Tested combination (val score of 0.4073):
#             {'max_depth': 192, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 19}
#             Current best combo (with val score 0.5074):
#                     {'max_depth': 192, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 19}
#         Has trained 4065 of 403200 combinations so far
# Already Trained and Tested combination (val score of 0.118):
#             {'max_depth': 192, 'max_bins': 64, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 19}
#             Current best combo (with val score 0.5074):
#                     {'max_depth': 192, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 19}
#         Has trained 4065 of 403200 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'max_depth': 192, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.01, 'l2_regularization': 10, 'max_iter': 200, 'features': 19}
#             Current best combo (with val score 0.5074):
#                     {'max_depth': 192, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 19}
#         Has trained 4065 of 403200 combinations so far
# Already Trained and Tested combination (val score of 0.4301):
#             {'max_depth': 192, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 1, 'max_iter': 200, 'features': 19}
#             Current best combo (with val score 0.5074):
#                     {'max_depth': 192, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 19}
#         Has trained 4065 of 403200 combinations so far
# Already Trained and Tested combination (val score of 0.4538):
#             {'max_depth': 192, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 100, 'features': 19}
#             Current best combo (with val score 0.5074):
#                     {'max_depth': 192, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 19}
#         Has trained 4065 of 403200 combinations so far
# Already Trained and Tested combination (val score of 0.4654):
#             {'max_depth': 192, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 19}
#             Current best combo (with val score 0.5074):
#                     {'max_depth': 192, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 19}
#         Has trained 4065 of 403200 combinations so far
# Already Trained and Tested combination (val score of 0.5016):
#             {'max_depth': 192, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 18}
#             Current best combo (with val score 0.5074):
#                     {'max_depth': 192, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 19}
#         Has trained 4065 of 403200 combinations so far
# Already Trained and Tested combination (val score of 0.5066):
#             {'max_depth': 192, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 20}
#             Current best combo (with val score 0.5074):
#                     {'max_depth': 192, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 19}
#         Has trained 4065 of 403200 combinations so far
# 	round FINAL iteration:  1
#
# Trained and Tested combination 4066 of 403200, taking 0.4 seconds to get val score of 0.5074:
#                 {'max_depth': 48, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 19},
#             Current best combo with val score 0.5074:
#                     {'max_depth': 192, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 19}
# Already Trained and Tested combination (val score of 0.5074):
#             {'max_depth': 192, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 19}
#             Current best combo (with val score 0.5074):
#                     {'max_depth': 192, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 19}
#         Has trained 4066 of 403200 combinations so far
# Trained and Tested combination 4067 of 403200, taking 0.38 seconds to get val score of 0.1267:
#                 {'max_depth': 96, 'max_bins': 16, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 19},
#             Current best combo with val score 0.5074:
#                     {'max_depth': 192, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 19}
# Trained and Tested combination 4068 of 403200, taking 0.43 seconds to get val score of 0.4073:
#                 {'max_depth': 96, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 19},
#             Current best combo with val score 0.5074:
#                     {'max_depth': 192, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 19}
# Trained and Tested combination 4069 of 403200, taking 0.84 seconds to get val score of 0.118:
#                 {'max_depth': 96, 'max_bins': 64, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 19},
#             Current best combo with val score 0.5074:
#                     {'max_depth': 192, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 19}
# Trained and Tested combination 4070 of 403200, taking 0.36 seconds to get val score of 0.0:
#                 {'max_depth': 96, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.01, 'l2_regularization': 10, 'max_iter': 200, 'features': 19},
#             Current best combo with val score 0.5074:
#                     {'max_depth': 192, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 19}
# Trained and Tested combination 4071 of 403200, taking 0.66 seconds to get val score of 0.4301:
#                 {'max_depth': 96, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 1, 'max_iter': 200, 'features': 19},
#             Current best combo with val score 0.5074:
#                     {'max_depth': 192, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 19}
# Trained and Tested combination 4072 of 403200, taking 0.19 seconds to get val score of 0.4538:
#                 {'max_depth': 96, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 100, 'features': 19},
#             Current best combo with val score 0.5074:
#                     {'max_depth': 192, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 19}
# Trained and Tested combination 4073 of 403200, taking 1.11 seconds to get val score of 0.4654:
#                 {'max_depth': 96, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 19},
#             Current best combo with val score 0.5074:
#                     {'max_depth': 192, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 19}
# Trained and Tested combination 4074 of 403200, taking 0.39 seconds to get val score of 0.5016:
#                 {'max_depth': 96, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 18},
#             Current best combo with val score 0.5074:
#                     {'max_depth': 192, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 19}
# Already Trained and Tested combination (val score of 0.5066):
#             {'max_depth': 96, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 20}
#             Current best combo (with val score 0.5074):
#                     {'max_depth': 192, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 19}
#         Has trained 4074 of 403200 combinations so far
# % Combos Checked Thus Far: 4074 out of 403200 which is 1.0104170000000001%
# Max Val Score:
#  0.507422
# Max Val Score Std:
#  0.030809
# Best Combo Train Score:
#  0.607012
# Best Combo Train Score Std:
#  0.012738
# Max Combo Index:
#  (6, 2, 0, 4, 5, 3, 19) out of [7, 4, 2, 5, 6, 5, 48] (note best combo is 0-indexed)
# Max Combo Hyperparamer Combination:
#  {'max_depth': 192, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 19}
# Max Combo Features:
#  ('procedure_225792', 'ventilation_used', 'procedure_226475', 'lods_score', 'procedure_225802', 'hospital_stay_duration', 'procedure_224276', 'procedure_229519', 'procedure_226236', 'race_AMERICAN INDIAN/ALASKA NATIVE', 'race_ASIAN', 'race_ASIAN - ASIAN INDIAN', 'race_ASIAN - CHINESE', 'race_ASIAN - KOREAN', 'race_ASIAN - SOUTH EAST ASIAN', 'race_BLACK/AFRICAN', 'race_BLACK/AFRICAN AMERICAN', 'race_BLACK/CAPE VERDEAN', 'race_BLACK/CARIBBEAN ISLAND', 'race_HISPANIC OR LATINO', 'race_HISPANIC/LATINO - CENTRAL AMERICAN', 'race_HISPANIC/LATINO - COLUMBIAN', 'race_HISPANIC/LATINO - CUBAN', 'race_HISPANIC/LATINO - DOMINICAN', 'race_HISPANIC/LATINO - GUATEMALAN', 'race_HISPANIC/LATINO - HONDURAN', 'race_HISPANIC/LATINO - MEXICAN', 'race_HISPANIC/LATINO - PUERTO RICAN', 'race_HISPANIC/LATINO - SALVADORAN', 'race_MULTIPLE RACE/ETHNICITY', 'race_NATIVE HAWAIIAN OR OTHER PACIFIC ISLANDER', 'race_OTHER', 'race_PATIENT DECLINED TO ANSWER', 'race_PORTUGUESE', 'race_SOUTH AMERICAN', 'race_UNABLE TO OBTAIN', 'race_WHITE', 'race_WHITE - BRAZILIAN', 'race_WHITE - EASTERN EUROPEAN', 'race_WHITE - OTHER EUROPEAN', 'race_WHITE - RUSSIAN', 'race_UNKNOWN', 'oasis_score', 'procedure_224267', 'icu_stay_duration', 'procedure_229580', 'procedure_224270', 'procedure_225446', 'procedure_225400', 'procedure_221223', 'unique_drugs', 'procedure_227712')
# % Combos Checked: 4074 out of 403200 which is 1.0104170000000001%
