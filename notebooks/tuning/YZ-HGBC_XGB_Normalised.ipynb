# %% [markdown]
# # Tuning Script

# %%
# Parameters subject to change in every script - involved in naming

MODEL = 'hgbc'
PREPROCESSING = 'normalise'
TUNER = 'yangzhoub'
OPTIMISED_METRIC = 'f1'

# %% [markdown]
# ---

# %%
# detect whether this is a google environment

COLAB_ENVIRONMENT = False

try:
    from google.colab import drive
    drive.mount('/content/drive')
    COLAB_ENVIRONMENT = True
except:
    pass
# Out:
# Mounted at /content/drive

# %%
import sys
import os
import pickle

if COLAB_ENVIRONMENT:
    home_directory = './drive/MyDrive/LAB/COMP90089__GroupWork__Py/' # my home directory is stored in ./LAB of google drive
    if MODEL == 'ebr':
        # !pip install interpret==0.5.0
    elif MODEL == 'cbr':
        # !pip install catboost
    elif MODEL in ['tf', 'mlp']:
        # !pip install PyTorch2Sklearn
    # !pip install JXAutoML
else:
    home_directory = '../../'

from JXAutoML.YangZhouB_10CV import YangZhouB_10CV as Tuner

import pandas as pd
# Out:
# Collecting JXAutoML
#   Downloading JXAutoML-0.4.4-py3-none-any.whl.metadata (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.2/67.2 kB 1.9 MB/s eta 0:00:00
# Downloading JXAutoML-0.4.4-py3-none-any.whl (52 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.1/52.1 kB 3.5 MB/s eta 0:00:00
# Installing collected packages: JXAutoML
# Successfully installed JXAutoML-0.4.4

# %%
# Parameters that are same for every script

FOLDS = 10  # we have decided to do 10 fold validation

SEED = 42

TASK_TYPE = 'Classification'  # this task is a classification task

# we have decided to tune features as hp
TUNE_FEATURES_AS_HYPERPARAMETERS = True

# %% [markdown]
# ---

# %%
# model to use to tune
from sklearn.ensemble import HistGradientBoostingClassifier as clf

# what values to try for each hyperparameter
parameter_choices = {
    'max_depth': (3, 6, 12, 24, 48, 96, 192),
    'max_bins': (4, 16, 64, 255),
    'interaction_cst': ('no_interactions', 'pairwise'),
    'learning_rate': (0.00000001, 0.000001, 0.0001, 0.01, 0.1),
    'l2_regularization': (0.0001, 0.001, 0.01, 0.1, 1, 10),
    'max_iter': (25, 50, 100, 200, 400)

}

# what values to set non-tuneable parameters/hyperparameters
non_tunable_hyperparameters_dict = {
                                    'random_state': SEED,
                                    }

# %% [markdown]
# ---

# %% [markdown]
# Read in and Prepare Data

# %%
# Import data and store as lists

train_x_list = []
train_y_list = []
val_x_list = []
val_y_list = []

for i in range(FOLDS):
    train_data = pd.read_csv(
        f'{home_directory}data/curated/modelling/{PREPROCESSING}/train_{i}.csv')
    val_data = pd.read_csv(
        f'{home_directory}data/curated/modelling/{PREPROCESSING}/val_{i}.csv')

    # get the correct rows for X and y
    train_x = train_data.drop(
        ['mortality_status', 'subject_id', 'hadm_id', 'stay_id'], axis=1)
    train_y = train_data['mortality_status']
    val_x = val_data.drop(
        ['mortality_status', 'subject_id', 'hadm_id', 'stay_id'], axis=1)
    val_y = val_data['mortality_status']

    train_x_list.append(train_x)
    train_y_list.append(train_y)
    val_x_list.append(val_x)
    val_y_list.append(val_y)

# %%
# Import feature importance ordering

with open(f'{home_directory}models/xgb_feature_importance_ordering_{PREPROCESSING}.pickle', 'rb') as f:
    feature_importance_ordering = pickle.load(f)

# %% [markdown]
# Set parameters

# %%
# initialisation
tuner = Tuner()

print('---')

# define what model we are tuning
tuner.read_in_model(clf, TASK_TYPE, optimised_metric=OPTIMISED_METRIC)

print('---')

# read in the data for training and validation
tuner.read_in_data(train_x_list, train_y_list, val_x_list, val_y_list)

print('---')

# set what hp values to tune
tuner.set_hyperparameters(parameter_choices)
# WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

# set up hp values that need to be changed from default but NOT to be tuned
tuner.set_non_tuneable_hyperparameters(non_tunable_hyperparameters_dict)

print('---')

# set up feature importance ordering

if TUNE_FEATURES_AS_HYPERPARAMETERS:
    tuner.set_features(feature_importance_ordering)
    # WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

try:  # try to read in previous results to continue tuning ...
    tuner.read_in_tuning_result_df(
        f'{home_directory}models/tuning/{TUNER}_{MODEL}_{PREPROCESSING}.csv')
except:
    print('No previous tuning data read in')

print('---')

# set up where to save the tuning result csv
tuner.set_tuning_result_saving_address(
    f'{home_directory}models/tuning/{TUNER}_{MODEL}_{PREPROCESSING}.csv')

print('---')

# set up where to save the current best model
tuner.set_best_model_saving_address(
    f'{home_directory}models/tmp_models/{TUNER}_{MODEL}_{PREPROCESSING}')
# Out:
# YangZhouB Initialised
# ---
# Successfully read in model <class 'sklearn.ensemble._hist_gradient_boosting.gradient_boosting.HistGradientBoostingClassifier'>, which is a Classification model optimising for f1
# ---
# Read in Train X data list
# Read in Train y data list
# Read in Val X data list
# Read in Val y data list
# ---
# Successfully recorded hyperparameter choices
# ---
# Successfully recorded non_tuneable_hyperparameter choices
# ---
# Successfully recorded tuneable feature combination choices and updated relevant internal structures
# ---
# Successfully read in tuning result of 2741 rows, for 2741.0 combos
# ---
# Successfully set tuning output address
# ---
# Successfully set best model output address

# %%
# ignore warnings

import warnings
warnings.filterwarnings("ignore")

# %%
# begin tuning ... (or continue training)

tuner.tune()
# Out:
# Streaming output truncated to the last 5000 lines.
#             Current best combo (with val score 0.5792):
#                     {'max_depth': 3, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 33}
#         Has trained 2741 of 604800 combinations so far
# 	round 16 iteration:  1
#
# Already Trained and Tested combination (val score of 0.4915):
#             {'max_depth': 6, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 20}
#             Current best combo (with val score 0.5792):
#                     {'max_depth': 3, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 33}
#         Has trained 2741 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.4814):
#             {'max_depth': 24, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 20}
#             Current best combo (with val score 0.5792):
#                     {'max_depth': 3, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 33}
#         Has trained 2741 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.5198):
#             {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 20}
#             Current best combo (with val score 0.5792):
#                     {'max_depth': 3, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 33}
#         Has trained 2741 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.5292):
#             {'max_depth': 12, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 20}
#             Current best combo (with val score 0.5792):
#                     {'max_depth': 3, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 33}
#         Has trained 2741 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.2728):
#             {'max_depth': 12, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.01, 'l2_regularization': 10, 'max_iter': 400, 'features': 20}
#             Current best combo (with val score 0.5792):
#                     {'max_depth': 3, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 33}
#         Has trained 2741 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.4356):
#             {'max_depth': 12, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 1, 'max_iter': 400, 'features': 20}
#             Current best combo (with val score 0.5792):
#                     {'max_depth': 3, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 33}
#         Has trained 2741 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.5728):
#             {'max_depth': 12, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 20}
#             Current best combo (with val score 0.5792):
#                     {'max_depth': 3, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 33}
#         Has trained 2741 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.5537):
#             {'max_depth': 12, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 19}
#             Current best combo (with val score 0.5792):
#                     {'max_depth': 3, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 33}
#         Has trained 2741 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.5316):
#             {'max_depth': 12, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 21}
#             Current best combo (with val score 0.5792):
#                     {'max_depth': 3, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 33}
#         Has trained 2741 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.4814):
#             {'max_depth': 24, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 20}
#             Current best combo (with val score 0.5792):
#                     {'max_depth': 3, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 33}
#         Has trained 2741 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.4814):
#             {'max_depth': 96, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 20}
#             Current best combo (with val score 0.5792):
#                     {'max_depth': 3, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 33}
#         Has trained 2741 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.5263):
#             {'max_depth': 48, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 20}
#             Current best combo (with val score 0.5792):
#                     {'max_depth': 3, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 33}
#         Has trained 2741 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.5353):
#             {'max_depth': 48, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 20}
#             Current best combo (with val score 0.5792):
#                     {'max_depth': 3, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 33}
#         Has trained 2741 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.2728):
#             {'max_depth': 48, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.01, 'l2_regularization': 10, 'max_iter': 400, 'features': 20}
#             Current best combo (with val score 0.5792):
#                     {'max_depth': 3, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 33}
#         Has trained 2741 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.4369):
#             {'max_depth': 48, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 1, 'max_iter': 400, 'features': 20}
#             Current best combo (with val score 0.5792):
#                     {'max_depth': 3, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 33}
#         Has trained 2741 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.5748):
#             {'max_depth': 48, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 20}
#             Current best combo (with val score 0.5792):
#                     {'max_depth': 3, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 33}
#         Has trained 2741 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.5566):
#             {'max_depth': 48, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 19}
#             Current best combo (with val score 0.5792):
#                     {'max_depth': 3, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 33}
#         Has trained 2741 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.5331):
#             {'max_depth': 48, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 21}
#             Current best combo (with val score 0.5792):
#                     {'max_depth': 3, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 33}
#         Has trained 2741 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.5198):
#             {'max_depth': 12, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 20}
#             Current best combo (with val score 0.5792):
#                     {'max_depth': 3, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 33}
#         Has trained 2741 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.5263):
#             {'max_depth': 48, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 20}
#             Current best combo (with val score 0.5792):
#                     {'max_depth': 3, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 33}
#         Has trained 2741 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.5185):
#             {'max_depth': 24, 'max_bins': 16, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 20}
#             Current best combo (with val score 0.5792):
#                     {'max_depth': 3, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 33}
#         Has trained 2741 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.4814):
#             {'max_depth': 24, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 20}
#             Current best combo (with val score 0.5792):
#                     {'max_depth': 3, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 33}
#         Has trained 2741 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.5448):
#             {'max_depth': 24, 'max_bins': 64, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 20}
#             Current best combo (with val score 0.5792):
#                     {'max_depth': 3, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 33}
#         Has trained 2741 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.2513):
#             {'max_depth': 24, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.01, 'l2_regularization': 10, 'max_iter': 400, 'features': 20}
#             Current best combo (with val score 0.5792):
#                     {'max_depth': 3, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 33}
#         Has trained 2741 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.4607):
#             {'max_depth': 24, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 1, 'max_iter': 400, 'features': 20}
#             Current best combo (with val score 0.5792):
#                     {'max_depth': 3, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 33}
#         Has trained 2741 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.5758):
#             {'max_depth': 24, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 20}
#             Current best combo (with val score 0.5792):
#                     {'max_depth': 3, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 33}
#         Has trained 2741 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.5597):
#             {'max_depth': 24, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 19}
#             Current best combo (with val score 0.5792):
#                     {'max_depth': 3, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 33}
#         Has trained 2741 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.5482):
#             {'max_depth': 24, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 21}
#             Current best combo (with val score 0.5792):
#                     {'max_depth': 3, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 33}
#         Has trained 2741 of 604800 combinations so far
# % Combos Checked Thus Far: 2741 out of 604800 which is 0.453208%
# Cruising Coordrdinate 1447 of 1536
#
# Cruise suspended due to suspicious case
# Guidance: round 17
#
# 	round 17 iteration:  0
#
# Already Trained and Tested combination (val score of 0.3956):
#             {'max_depth': 6, 'max_bins': 4, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 20}
#             Current best combo (with val score 0.5792):
#                     {'max_depth': 3, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 33}
#         Has trained 2741 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.438):
#             {'max_depth': 3, 'max_bins': 16, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 20}
#             Current best combo (with val score 0.5792):
#                     {'max_depth': 3, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 33}
#         Has trained 2741 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.41):
#             {'max_depth': 3, 'max_bins': 4, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 20}
#             Current best combo (with val score 0.5792):
#                     {'max_depth': 3, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 33}
#         Has trained 2741 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.3977):
#             {'max_depth': 3, 'max_bins': 4, 'interaction_cst': 'pairwise', 'learning_rate': 0.01, 'l2_regularization': 10, 'max_iter': 400, 'features': 20}
#             Current best combo (with val score 0.5792):
#                     {'max_depth': 3, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 33}
#         Has trained 2741 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.3916):
#             {'max_depth': 3, 'max_bins': 4, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 1, 'max_iter': 400, 'features': 20}
#             Current best combo (with val score 0.5792):
#                     {'max_depth': 3, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 33}
#         Has trained 2741 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.4008):
#             {'max_depth': 3, 'max_bins': 4, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 20}
#             Current best combo (with val score 0.5792):
#                     {'max_depth': 3, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 33}
#         Has trained 2741 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.4403):
#             {'max_depth': 3, 'max_bins': 4, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 19}
#             Current best combo (with val score 0.5792):
#                     {'max_depth': 3, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 33}
#         Has trained 2741 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.4325):
#             {'max_depth': 3, 'max_bins': 4, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 21}
#             Current best combo (with val score 0.5792):
#                     {'max_depth': 3, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 33}
#         Has trained 2741 of 604800 combinations so far
# 	round 17 iteration:  1
#
# Already Trained and Tested combination (val score of 0.4651):
#             {'max_depth': 6, 'max_bins': 16, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 20}
#             Current best combo (with val score 0.5792):
#                     {'max_depth': 3, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 33}
#         Has trained 2741 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.4046):
#             {'max_depth': 3, 'max_bins': 4, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 20}
#             Current best combo (with val score 0.5792):
#                     {'max_depth': 3, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 33}
#         Has trained 2741 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.5659):
#             {'max_depth': 3, 'max_bins': 64, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 20}
#             Current best combo (with val score 0.5792):
#                     {'max_depth': 3, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 33}
#         Has trained 2741 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.5102):
#             {'max_depth': 3, 'max_bins': 16, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 20}
#             Current best combo (with val score 0.5792):
#                     {'max_depth': 3, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 33}
#         Has trained 2741 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.4207):
#             {'max_depth': 3, 'max_bins': 16, 'interaction_cst': 'pairwise', 'learning_rate': 0.01, 'l2_regularization': 10, 'max_iter': 400, 'features': 20}
#             Current best combo (with val score 0.5792):
#                     {'max_depth': 3, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 33}
#         Has trained 2741 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.4016):
#             {'max_depth': 3, 'max_bins': 16, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 1, 'max_iter': 400, 'features': 20}
#             Current best combo (with val score 0.5792):
#                     {'max_depth': 3, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 33}
#         Has trained 2741 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.4538):
#             {'max_depth': 3, 'max_bins': 16, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 20}
#             Current best combo (with val score 0.5792):
#                     {'max_depth': 3, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 33}
#         Has trained 2741 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.4672):
#             {'max_depth': 3, 'max_bins': 16, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 19}
#             Current best combo (with val score 0.5792):
#                     {'max_depth': 3, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 33}
#         Has trained 2741 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.5124):
#             {'max_depth': 3, 'max_bins': 16, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 21}
#             Current best combo (with val score 0.5792):
#                     {'max_depth': 3, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 33}
#         Has trained 2741 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.41):
#             {'max_depth': 6, 'max_bins': 4, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 20}
#             Current best combo (with val score 0.5792):
#                     {'max_depth': 3, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 33}
#         Has trained 2741 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.5102):
#             {'max_depth': 3, 'max_bins': 16, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 20}
#             Current best combo (with val score 0.5792):
#                     {'max_depth': 3, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 33}
#         Has trained 2741 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.4046):
#             {'max_depth': 3, 'max_bins': 4, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 20}
#             Current best combo (with val score 0.5792):
#                     {'max_depth': 3, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 33}
#         Has trained 2741 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.1764):
#             {'max_depth': 3, 'max_bins': 4, 'interaction_cst': 'no_interactions', 'learning_rate': 0.01, 'l2_regularization': 10, 'max_iter': 400, 'features': 20}
#             Current best combo (with val score 0.5792):
#                     {'max_depth': 3, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 33}
#         Has trained 2741 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.4179):
#             {'max_depth': 3, 'max_bins': 4, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 1, 'max_iter': 400, 'features': 20}
#             Current best combo (with val score 0.5792):
#                     {'max_depth': 3, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 33}
#         Has trained 2741 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.3728):
#             {'max_depth': 3, 'max_bins': 4, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 20}
#             Current best combo (with val score 0.5792):
#                     {'max_depth': 3, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 33}
#         Has trained 2741 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.4145):
#             {'max_depth': 3, 'max_bins': 4, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 19}
#             Current best combo (with val score 0.5792):
#                     {'max_depth': 3, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 33}
#         Has trained 2741 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.4109):
#             {'max_depth': 3, 'max_bins': 4, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 21}
#             Current best combo (with val score 0.5792):
#                     {'max_depth': 3, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 33}
#         Has trained 2741 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.3981):
#             {'max_depth': 6, 'max_bins': 4, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 20}
#             Current best combo (with val score 0.5792):
#                     {'max_depth': 3, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 33}
#         Has trained 2741 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.4538):
#             {'max_depth': 3, 'max_bins': 16, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 20}
#             Current best combo (with val score 0.5792):
#                     {'max_depth': 3, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 33}
#         Has trained 2741 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.3728):
#             {'max_depth': 3, 'max_bins': 4, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 20}
#             Current best combo (with val score 0.5792):
#                     {'max_depth': 3, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 33}
#         Has trained 2741 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.2905):
#             {'max_depth': 3, 'max_bins': 4, 'interaction_cst': 'pairwise', 'learning_rate': 0.01, 'l2_regularization': 10, 'max_iter': 200, 'features': 20}
#             Current best combo (with val score 0.5792):
#                     {'max_depth': 3, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 33}
#         Has trained 2741 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.3998):
#             {'max_depth': 3, 'max_bins': 4, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 1, 'max_iter': 200, 'features': 20}
#             Current best combo (with val score 0.5792):
#                     {'max_depth': 3, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 33}
#         Has trained 2741 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.4019):
#             {'max_depth': 3, 'max_bins': 4, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 100, 'features': 20}
#             Current best combo (with val score 0.5792):
#                     {'max_depth': 3, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 33}
#         Has trained 2741 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.4046):
#             {'max_depth': 3, 'max_bins': 4, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 20}
#             Current best combo (with val score 0.5792):
#                     {'max_depth': 3, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 33}
#         Has trained 2741 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.428):
#             {'max_depth': 3, 'max_bins': 4, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 19}
#             Current best combo (with val score 0.5792):
#                     {'max_depth': 3, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 33}
#         Has trained 2741 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.4459):
#             {'max_depth': 3, 'max_bins': 4, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 21}
#             Current best combo (with val score 0.5792):
#                     {'max_depth': 3, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 33}
#         Has trained 2741 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.4367):
#             {'max_depth': 6, 'max_bins': 4, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 19}
#             Current best combo (with val score 0.5792):
#                     {'max_depth': 3, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 33}
#         Has trained 2741 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.4672):
#             {'max_depth': 3, 'max_bins': 16, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 19}
#             Current best combo (with val score 0.5792):
#                     {'max_depth': 3, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 33}
#         Has trained 2741 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.4145):
#             {'max_depth': 3, 'max_bins': 4, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 19}
#             Current best combo (with val score 0.5792):
#                     {'max_depth': 3, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 33}
#         Has trained 2741 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.3977):
#             {'max_depth': 3, 'max_bins': 4, 'interaction_cst': 'pairwise', 'learning_rate': 0.01, 'l2_regularization': 10, 'max_iter': 400, 'features': 19}
#             Current best combo (with val score 0.5792):
#                     {'max_depth': 3, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 33}
#         Has trained 2741 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.4302):
#             {'max_depth': 3, 'max_bins': 4, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 1, 'max_iter': 400, 'features': 19}
#             Current best combo (with val score 0.5792):
#                     {'max_depth': 3, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 33}
#         Has trained 2741 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.428):
#             {'max_depth': 3, 'max_bins': 4, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 19}
#             Current best combo (with val score 0.5792):
#                     {'max_depth': 3, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 33}
#         Has trained 2741 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.4462):
#             {'max_depth': 3, 'max_bins': 4, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 18}
#             Current best combo (with val score 0.5792):
#                     {'max_depth': 3, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 33}
#         Has trained 2741 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.4046):
#             {'max_depth': 3, 'max_bins': 4, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 20}
#             Current best combo (with val score 0.5792):
#                     {'max_depth': 3, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 33}
#         Has trained 2741 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.4434):
#             {'max_depth': 6, 'max_bins': 4, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 21}
#             Current best combo (with val score 0.5792):
#                     {'max_depth': 3, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 33}
#         Has trained 2741 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.5124):
#             {'max_depth': 3, 'max_bins': 16, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 21}
#             Current best combo (with val score 0.5792):
#                     {'max_depth': 3, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 33}
#         Has trained 2741 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.4109):
#             {'max_depth': 3, 'max_bins': 4, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 21}
#             Current best combo (with val score 0.5792):
#                     {'max_depth': 3, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 33}
#         Has trained 2741 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.4091):
#             {'max_depth': 3, 'max_bins': 4, 'interaction_cst': 'pairwise', 'learning_rate': 0.01, 'l2_regularization': 10, 'max_iter': 400, 'features': 21}
#             Current best combo (with val score 0.5792):
#                     {'max_depth': 3, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 33}
#         Has trained 2741 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.4274):
#             {'max_depth': 3, 'max_bins': 4, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 1, 'max_iter': 400, 'features': 21}
#             Current best combo (with val score 0.5792):
#                     {'max_depth': 3, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 33}
#         Has trained 2741 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.4459):
#             {'max_depth': 3, 'max_bins': 4, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 21}
#             Current best combo (with val score 0.5792):
#                     {'max_depth': 3, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 33}
#         Has trained 2741 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.4046):
#             {'max_depth': 3, 'max_bins': 4, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 20}
#             Current best combo (with val score 0.5792):
#                     {'max_depth': 3, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 33}
#         Has trained 2741 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.4325):
#             {'max_depth': 3, 'max_bins': 4, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 22}
#             Current best combo (with val score 0.5792):
#                     {'max_depth': 3, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 33}
#         Has trained 2741 of 604800 combinations so far
# % Combos Checked Thus Far: 2741 out of 604800 which is 0.453208%
# Cruising Coordrdinate 1448 of 1536
#
# Cruise suspended due to suspicious case
# Guidance: round 18
#
# 	round 18 iteration:  0
#
# % Combos Checked Thus Far: 2741 out of 604800 which is 0.453208%
# Cruising Coordrdinate 1449 of 1536
#
# Cruise suspended due to suspicious case
# Guidance: round 19
#
# 	round 19 iteration:  0
#
# Already Trained and Tested combination (val score of 0.5366):
#             {'max_depth': 6, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 20}
#             Current best combo (with val score 0.5792):
#                     {'max_depth': 3, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 33}
#         Has trained 2741 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.5659):
#             {'max_depth': 3, 'max_bins': 64, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 20}
#             Current best combo (with val score 0.5792):
#                     {'max_depth': 3, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 33}
#         Has trained 2741 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.537):
#             {'max_depth': 3, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 20}
#             Current best combo (with val score 0.5792):
#                     {'max_depth': 3, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 33}
#         Has trained 2741 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.4111):
#             {'max_depth': 3, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.01, 'l2_regularization': 10, 'max_iter': 400, 'features': 20}
#             Current best combo (with val score 0.5792):
#                     {'max_depth': 3, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 33}
#         Has trained 2741 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.5127):
#             {'max_depth': 3, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 1, 'max_iter': 400, 'features': 20}
#             Current best combo (with val score 0.5792):
#                     {'max_depth': 3, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 33}
#         Has trained 2741 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.5553):
#             {'max_depth': 3, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 20}
#             Current best combo (with val score 0.5792):
#                     {'max_depth': 3, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 33}
#         Has trained 2741 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.5447):
#             {'max_depth': 3, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 19}
#             Current best combo (with val score 0.5792):
#                     {'max_depth': 3, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 33}
#         Has trained 2741 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.5695):
#             {'max_depth': 3, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 21}
#             Current best combo (with val score 0.5792):
#                     {'max_depth': 3, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 33}
#         Has trained 2741 of 604800 combinations so far
# 	round 19 iteration:  1
#
# Already Trained and Tested combination (val score of 0.5552):
#             {'max_depth': 6, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 20}
#             Current best combo (with val score 0.5792):
#                     {'max_depth': 3, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 33}
#         Has trained 2741 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.5605):
#             {'max_depth': 3, 'max_bins': 64, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 20}
#             Current best combo (with val score 0.5792):
#                     {'max_depth': 3, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 33}
#         Has trained 2741 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.5731):
#             {'max_depth': 3, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 20}
#             Current best combo (with val score 0.5792):
#                     {'max_depth': 3, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 33}
#         Has trained 2741 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.3849):
#             {'max_depth': 3, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.01, 'l2_regularization': 10, 'max_iter': 200, 'features': 20}
#             Current best combo (with val score 0.5792):
#                     {'max_depth': 3, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 33}
#         Has trained 2741 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.5408):
#             {'max_depth': 3, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 1, 'max_iter': 200, 'features': 20}
#             Current best combo (with val score 0.5792):
#                     {'max_depth': 3, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 33}
#         Has trained 2741 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.4814):
#             {'max_depth': 3, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 100, 'features': 20}
#             Current best combo (with val score 0.5792):
#                     {'max_depth': 3, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 33}
#         Has trained 2741 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.5508):
#             {'max_depth': 3, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 20}
#             Current best combo (with val score 0.5792):
#                     {'max_depth': 3, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 33}
#         Has trained 2741 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.5528):
# ...
#         Has trained 2741 of 604800 combinations so far
# % Combos Checked Thus Far: 2741 out of 604800 which is 0.453208%
# FINAL STAGE: Begin final Guidance system
#
#
# Guidance: round FINAL
#
# 	round FINAL iteration:  0
#
# Already Trained and Tested combination (val score of 0.5742):
#             {'max_depth': 6, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 21}
#             Current best combo (with val score 0.5826):
#                     {'max_depth': 3, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 21}
#         Has trained 2741 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.5787):
#             {'max_depth': 3, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 21}
#             Current best combo (with val score 0.5826):
#                     {'max_depth': 3, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 21}
#         Has trained 2741 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.5546):
#             {'max_depth': 3, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 21}
#             Current best combo (with val score 0.5826):
#                     {'max_depth': 3, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 21}
#         Has trained 2741 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'max_depth': 3, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.01, 'l2_regularization': 10, 'max_iter': 200, 'features': 21}
#             Current best combo (with val score 0.5826):
#                     {'max_depth': 3, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 21}
#         Has trained 2741 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.5202):
#             {'max_depth': 3, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 1, 'max_iter': 200, 'features': 21}
#             Current best combo (with val score 0.5826):
#                     {'max_depth': 3, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 21}
#         Has trained 2741 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.4531):
#             {'max_depth': 3, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 100, 'features': 21}
#             Current best combo (with val score 0.5826):
#                     {'max_depth': 3, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 21}
#         Has trained 2741 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.5521):
#             {'max_depth': 3, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 21}
#             Current best combo (with val score 0.5826):
#                     {'max_depth': 3, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 21}
#         Has trained 2741 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.5731):
#             {'max_depth': 3, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 20}
#             Current best combo (with val score 0.5826):
#                     {'max_depth': 3, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 21}
#         Has trained 2741 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.5826):
#             {'max_depth': 3, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 22}
#             Current best combo (with val score 0.5826):
#                     {'max_depth': 3, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 21}
#         Has trained 2741 of 604800 combinations so far
# 	round FINAL iteration:  1
#
# Already Trained and Tested combination (val score of 0.5778):
#             {'max_depth': 6, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 21}
#             Current best combo (with val score 0.5826):
#                     {'max_depth': 3, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 21}
#         Has trained 2741 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.4754):
#             {'max_depth': 3, 'max_bins': 16, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 21}
#             Current best combo (with val score 0.5826):
#                     {'max_depth': 3, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 21}
#         Has trained 2741 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.5826):
#             {'max_depth': 3, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 21}
#             Current best combo (with val score 0.5826):
#                     {'max_depth': 3, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 21}
#         Has trained 2741 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.5556):
#             {'max_depth': 3, 'max_bins': 64, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 21}
#             Current best combo (with val score 0.5826):
#                     {'max_depth': 3, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 21}
#         Has trained 2741 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'max_depth': 3, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.01, 'l2_regularization': 10, 'max_iter': 200, 'features': 21}
#             Current best combo (with val score 0.5826):
#                     {'max_depth': 3, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 21}
#         Has trained 2741 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.5459):
#             {'max_depth': 3, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 1, 'max_iter': 200, 'features': 21}
#             Current best combo (with val score 0.5826):
#                     {'max_depth': 3, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 21}
#         Has trained 2741 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.4399):
#             {'max_depth': 3, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 100, 'features': 21}
#             Current best combo (with val score 0.5826):
#                     {'max_depth': 3, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 21}
#         Has trained 2741 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.5603):
#             {'max_depth': 3, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 21}
#             Current best combo (with val score 0.5826):
#                     {'max_depth': 3, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 21}
#         Has trained 2741 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.5766):
#             {'max_depth': 3, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 20}
#             Current best combo (with val score 0.5826):
#                     {'max_depth': 3, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 21}
#         Has trained 2741 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.5787):
#             {'max_depth': 3, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 22}
#             Current best combo (with val score 0.5826):
#                     {'max_depth': 3, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 21}
#         Has trained 2741 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.5742):
#             {'max_depth': 6, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 22}
#             Current best combo (with val score 0.5826):
#                     {'max_depth': 3, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 21}
#         Has trained 2741 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.5787):
#             {'max_depth': 3, 'max_bins': 64, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 22}
#             Current best combo (with val score 0.5826):
#                     {'max_depth': 3, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 21}
#         Has trained 2741 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.5533):
#             {'max_depth': 3, 'max_bins': 255, 'interaction_cst': 'pairwise', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 22}
#             Current best combo (with val score 0.5826):
#                     {'max_depth': 3, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 21}
#         Has trained 2741 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'max_depth': 3, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.01, 'l2_regularization': 10, 'max_iter': 200, 'features': 22}
#             Current best combo (with val score 0.5826):
#                     {'max_depth': 3, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 21}
#         Has trained 2741 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.5202):
#             {'max_depth': 3, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 1, 'max_iter': 200, 'features': 22}
#             Current best combo (with val score 0.5826):
#                     {'max_depth': 3, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 21}
#         Has trained 2741 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.4531):
#             {'max_depth': 3, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 100, 'features': 22}
#             Current best combo (with val score 0.5826):
#                     {'max_depth': 3, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 21}
#         Has trained 2741 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.5513):
#             {'max_depth': 3, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 400, 'features': 22}
#             Current best combo (with val score 0.5826):
#                     {'max_depth': 3, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 21}
#         Has trained 2741 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.5826):
#             {'max_depth': 3, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 21}
#             Current best combo (with val score 0.5826):
#                     {'max_depth': 3, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 21}
#         Has trained 2741 of 604800 combinations so far
# Already Trained and Tested combination (val score of 0.5826):
#             {'max_depth': 3, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 23}
#             Current best combo (with val score 0.5826):
#                     {'max_depth': 3, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 21}
#         Has trained 2741 of 604800 combinations so far
# % Combos Checked Thus Far: 2741 out of 604800 which is 0.453208%
# Max Val Score:
#  0.58262
# Max Val Score Std:
#  0.03652
# Best Combo Train Score:
#  0.641593
# Best Combo Train Score Std:
#  0.008925
# Max Combo Index:
#  (0, 3, 0, 4, 5, 3, 21) out of [7, 4, 2, 5, 6, 5, 72] (note best combo is 0-indexed)
# Max Combo Hyperparamer Combination:
#  {'max_depth': 3, 'max_bins': 255, 'interaction_cst': 'no_interactions', 'learning_rate': 0.1, 'l2_regularization': 10, 'max_iter': 200, 'features': 21}
# Max Combo Features:
#  ('procedure_228130', 'procedure_225792', 'procedure_228125', 'lods_score', 'ventilation_used', 'procedure_226236', 'hospital_stay_duration', 'procedure_225469', 'procedure_224270', 'procedure_225446', 'procedure_225802', 'procedure_227712', 'procedure_229580', 'procedure_225451', 'admission_type_DIRECT EMER.', 'admission_type_DIRECT OBSERVATION', 'admission_type_ELECTIVE', 'admission_type_EU OBSERVATION', 'admission_type_EW EMER.', 'admission_type_OBSERVATION ADMIT', 'admission_type_URGENT', 'admission_type_SURGICAL SAME DAY ADMISSION', 'procedure_224385', 'procedure_224267', 'oasis_score', 'procedure_225470', 'procedure_224276', 'icu_stay_duration', 'marital_status_DIVORCED', 'marital_status_MARRIED', 'marital_status_SINGLE', 'marital_status_WIDOWED', 'marital_status_0')
# % Combos Checked: 2741 out of 604800 which is 0.453208%
