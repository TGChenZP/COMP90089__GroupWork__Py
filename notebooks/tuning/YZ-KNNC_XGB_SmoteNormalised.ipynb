# %% [markdown]
# # Tuning Script

# %%
# Parameters subject to change in every script - involved in naming

MODEL = 'knnc'
PREPROCESSING = 'smote_normalise'
TUNER = 'yangzhoub'
OPTIMISED_METRIC = 'f1'

# %% [markdown]
# ---

# %%
# detect whether this is a google environment

COLAB_ENVIRONMENT = False

try:
    from google.colab import drive
    drive.mount('/content/drive')
    COLAB_ENVIRONMENT = True
except:
    pass
# Out:
# Mounted at /content/drive

# %%
import sys
import os
import pickle

if COLAB_ENVIRONMENT:
    home_directory = './drive/MyDrive/LAB/COMP90089__GroupWork__Py/' # my home directory is stored in ./LAB of google drive
    if MODEL == 'ebr':
        # !pip install interpret==0.5.0
    elif MODEL == 'cbr':
        # !pip install catboost
    elif MODEL in ['tf', 'mlp']:
        # !pip install PyTorch2Sklearn
    # !pip install JXAutoML
else:
    home_directory = '../../'

from JXAutoML.YangZhouB_10CV import YangZhouB_10CV as Tuner

import pandas as pd
# Out:
# Collecting JXAutoML
#   Downloading JXAutoML-0.4.4-py3-none-any.whl.metadata (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.2/67.2 kB 1.8 MB/s eta 0:00:00
# Downloading JXAutoML-0.4.4-py3-none-any.whl (52 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.1/52.1 kB 3.8 MB/s eta 0:00:00
# Installing collected packages: JXAutoML
# Successfully installed JXAutoML-0.4.4

# %%
# Parameters that are same for every script

FOLDS = 10  # we have decided to do 10 fold validation

SEED = 42

TASK_TYPE = 'Classification'  # this task is a classification task

# we have decided to tune features as hp
TUNE_FEATURES_AS_HYPERPARAMETERS = True

# %% [markdown]
# ---

# %%
# model to use to tune
from sklearn.neighbors import KNeighborsClassifier as clf

# what values to try for each hyperparameter
parameter_choices = {
    'n_neighbors': [i for i in range(1, 101)],
    'p': (1, 2),
    'weights': ('uniform', 'distance')
}

# what values to set non-tuneable parameters/hyperparameters
non_tunable_hyperparameters_dict = {
                                    'n_jobs': -1
                                    }

# %% [markdown]
# ---

# %% [markdown]
# Read in and Prepare Data

# %%
# Import data and store as lists

train_x_list = []
train_y_list = []
val_x_list = []
val_y_list = []

for i in range(FOLDS):
    train_data = pd.read_csv(
        f'{home_directory}data/curated/modelling/{PREPROCESSING}/train_{i}.csv')
    val_data = pd.read_csv(
        f'{home_directory}data/curated/modelling/{PREPROCESSING}/val_{i}.csv')

    # get the correct rows for X and y
    train_x = train_data.drop(
        ['mortality_status', 'subject_id', 'hadm_id', 'stay_id'], axis=1)
    train_y = train_data['mortality_status']
    val_x = val_data.drop(
        ['mortality_status', 'subject_id', 'hadm_id', 'stay_id'], axis=1)
    val_y = val_data['mortality_status']

    train_x_list.append(train_x)
    train_y_list.append(train_y)
    val_x_list.append(val_x)
    val_y_list.append(val_y)

# %%
# Import feature importance ordering

with open(f'{home_directory}models/xgb_feature_importance_ordering_{PREPROCESSING}.pickle', 'rb') as f:
    feature_importance_ordering = pickle.load(f)

# %% [markdown]
# Set parameters

# %%
# initialisation
tuner = Tuner()

print('---')

# define what model we are tuning
tuner.read_in_model(clf, TASK_TYPE, optimised_metric=OPTIMISED_METRIC)

print('---')

# read in the data for training and validation
tuner.read_in_data(train_x_list, train_y_list, val_x_list, val_y_list)

print('---')

# set what hp values to tune
tuner.set_hyperparameters(parameter_choices)
# WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

# set up hp values that need to be changed from default but NOT to be tuned
tuner.set_non_tuneable_hyperparameters(non_tunable_hyperparameters_dict)

print('---')

# set up feature importance ordering

if TUNE_FEATURES_AS_HYPERPARAMETERS:
    tuner.set_features(feature_importance_ordering)
    # WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

try:  # try to read in previous results to continue tuning ...
    tuner.read_in_tuning_result_df(
        f'{home_directory}models/tuning/{TUNER}_{MODEL}_{PREPROCESSING}.csv')
except:
    print('No previous tuning data read in')

print('---')

# set up where to save the tuning result csv
tuner.set_tuning_result_saving_address(
    f'{home_directory}models/tuning/{TUNER}_{MODEL}_{PREPROCESSING}.csv')

print('---')

# set up where to save the current best model
tuner.set_best_model_saving_address(
    f'{home_directory}models/tmp_models/{TUNER}_{MODEL}_{PREPROCESSING}')
# Out:
# YangZhouB Initialised
# ---
# Successfully read in model <class 'sklearn.neighbors._classification.KNeighborsClassifier'>, which is a Classification model optimising for f1
# ---
# Read in Train X data list
# Read in Train y data list
# Read in Val X data list
# Read in Val y data list
# ---
# Successfully recorded hyperparameter choices
# ---
# Successfully recorded non_tuneable_hyperparameter choices
# ---
# Successfully recorded tuneable feature combination choices and updated relevant internal structures
# ---
# No previous tuning data read in
# ---
# Successfully set tuning output address
# ---
# Successfully set best model output address

# %%
# ignore warnings

import warnings
warnings.filterwarnings("ignore")

# %%
# begin tuning ... (or continue training)

tuner.tune()
# Out:
# Streaming output truncated to the last 5000 lines.
#                 {'n_neighbors': 66, 'p': 1, 'weights': 'distance', 'features': 39},
#             Current best combo with val score 0.3164:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 39}
# Trained and Tested combination 576 of 19200, taking 0.0 seconds to get val score of 0.0033:
#                 {'n_neighbors': 26, 'p': 1, 'weights': 'uniform', 'features': 35},
#             Current best combo with val score 0.3164:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 39}
# Trained and Tested combination 577 of 19200, taking 0.0 seconds to get val score of 0.0:
#                 {'n_neighbors': 56, 'p': 1, 'weights': 'uniform', 'features': 30},
#             Current best combo with val score 0.3164:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 39}
# Trained and Tested combination 578 of 19200, taking 0.01 seconds to get val score of 0.0:
#                 {'n_neighbors': 46, 'p': 1, 'weights': 'uniform', 'features': 39},
#             Current best combo with val score 0.3164:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 39}
# Trained and Tested combination 579 of 19200, taking 0.0 seconds to get val score of 0.0:
#                 {'n_neighbors': 56, 'p': 1, 'weights': 'uniform', 'features': 39},
#             Current best combo with val score 0.3164:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 39}
# Trained and Tested combination 580 of 19200, taking 0.0 seconds to get val score of 0.0:
#                 {'n_neighbors': 66, 'p': 2, 'weights': 'distance', 'features': 20},
#             Current best combo with val score 0.3164:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 39}
# Trained and Tested combination 581 of 19200, taking 0.0 seconds to get val score of 0.0:
#                 {'n_neighbors': 21, 'p': 2, 'weights': 'uniform', 'features': 15},
#             Current best combo with val score 0.3164:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 39}
# Trained and Tested combination 582 of 19200, taking 0.0 seconds to get val score of 0.0:
#                 {'n_neighbors': 86, 'p': 1, 'weights': 'distance', 'features': 39},
#             Current best combo with val score 0.3164:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 39}
# Trained and Tested combination 583 of 19200, taking 0.0 seconds to get val score of 0.0033:
#                 {'n_neighbors': 1, 'p': 2, 'weights': 'uniform', 'features': 15},
#             Current best combo with val score 0.3164:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 39}
# Trained and Tested combination 584 of 19200, taking 0.01 seconds to get val score of 0.0033:
#                 {'n_neighbors': 76, 'p': 1, 'weights': 'distance', 'features': 15},
#             Current best combo with val score 0.3164:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 39}
# Trained and Tested combination 585 of 19200, taking 0.0 seconds to get val score of 0.0:
#                 {'n_neighbors': 71, 'p': 1, 'weights': 'uniform', 'features': 39},
#             Current best combo with val score 0.3164:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 39}
# Trained and Tested combination 586 of 19200, taking 0.0 seconds to get val score of 0.0:
#                 {'n_neighbors': 51, 'p': 1, 'weights': 'distance', 'features': 35},
#             Current best combo with val score 0.3164:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 39}
# Trained and Tested combination 587 of 19200, taking 0.0 seconds to get val score of 0.0887:
#                 {'n_neighbors': 66, 'p': 2, 'weights': 'uniform', 'features': 5},
#             Current best combo with val score 0.3164:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 39}
# Trained and Tested combination 588 of 19200, taking 0.0 seconds to get val score of 0.0:
#                 {'n_neighbors': 51, 'p': 1, 'weights': 'distance', 'features': 47},
#             Current best combo with val score 0.3164:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 39}
# Trained and Tested combination 589 of 19200, taking 0.01 seconds to get val score of 0.0:
#                 {'n_neighbors': 16, 'p': 1, 'weights': 'distance', 'features': 30},
#             Current best combo with val score 0.3164:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 39}
# Trained and Tested combination 590 of 19200, taking 0.0 seconds to get val score of 0.0:
#                 {'n_neighbors': 41, 'p': 2, 'weights': 'distance', 'features': 0},
#             Current best combo with val score 0.3164:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 39}
# Trained and Tested combination 591 of 19200, taking 0.01 seconds to get val score of 0.3118:
#                 {'n_neighbors': 1, 'p': 2, 'weights': 'distance', 'features': 47},
#             Current best combo with val score 0.3164:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 39}
# Trained and Tested combination 592 of 19200, taking 0.01 seconds to get val score of 0.0:
#                 {'n_neighbors': 96, 'p': 1, 'weights': 'distance', 'features': 39},
#             Current best combo with val score 0.3164:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 39}
# Trained and Tested combination 593 of 19200, taking 0.0 seconds to get val score of 0.0:
#                 {'n_neighbors': 81, 'p': 1, 'weights': 'uniform', 'features': 43},
#             Current best combo with val score 0.3164:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 39}
# Trained and Tested combination 594 of 19200, taking 0.0 seconds to get val score of 0.0:
#                 {'n_neighbors': 31, 'p': 2, 'weights': 'distance', 'features': 20},
#             Current best combo with val score 0.3164:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 39}
# Trained and Tested combination 595 of 19200, taking 0.0 seconds to get val score of 0.0:
#                 {'n_neighbors': 86, 'p': 2, 'weights': 'distance', 'features': 15},
#             Current best combo with val score 0.3164:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 39}
# Trained and Tested combination 596 of 19200, taking 0.0 seconds to get val score of 0.188:
#                 {'n_neighbors': 11, 'p': 1, 'weights': 'uniform', 'features': 5},
#             Current best combo with val score 0.3164:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 39}
# Trained and Tested combination 597 of 19200, taking 0.0 seconds to get val score of 0.0:
#                 {'n_neighbors': 26, 'p': 2, 'weights': 'distance', 'features': 25},
#             Current best combo with val score 0.3164:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 39}
# Trained and Tested combination 598 of 19200, taking 0.0 seconds to get val score of 0.0545:
#                 {'n_neighbors': 66, 'p': 1, 'weights': 'uniform', 'features': 20},
#             Current best combo with val score 0.3164:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 39}
# Trained and Tested combination 599 of 19200, taking 0.0 seconds to get val score of 0.0:
#                 {'n_neighbors': 91, 'p': 1, 'weights': 'uniform', 'features': 35},
#             Current best combo with val score 0.3164:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 39}
# Trained and Tested combination 600 of 19200, taking 0.0 seconds to get val score of 0.1466:
#                 {'n_neighbors': 16, 'p': 1, 'weights': 'uniform', 'features': 5},
#             Current best combo with val score 0.3164:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 39}
# Trained and Tested combination 601 of 19200, taking 0.01 seconds to get val score of 0.0:
#                 {'n_neighbors': 16, 'p': 1, 'weights': 'distance', 'features': 47},
#             Current best combo with val score 0.3164:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 39}
# Trained and Tested combination 602 of 19200, taking 0.0 seconds to get val score of 0.0:
#                 {'n_neighbors': 11, 'p': 1, 'weights': 'distance', 'features': 30},
#             Current best combo with val score 0.3164:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 39}
# Trained and Tested combination 603 of 19200, taking 0.0 seconds to get val score of 0.0:
#                 {'n_neighbors': 36, 'p': 1, 'weights': 'uniform', 'features': 25},
#             Current best combo with val score 0.3164:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 39}
# Trained and Tested combination 604 of 19200, taking 0.0 seconds to get val score of 0.0:
#                 {'n_neighbors': 51, 'p': 2, 'weights': 'uniform', 'features': 10},
#             Current best combo with val score 0.3164:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 39}
# Trained and Tested combination 605 of 19200, taking 0.0 seconds to get val score of 0.0:
#                 {'n_neighbors': 100, 'p': 2, 'weights': 'uniform', 'features': 10},
#             Current best combo with val score 0.3164:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 39}
# Trained and Tested combination 606 of 19200, taking 0.01 seconds to get val score of 0.0:
#                 {'n_neighbors': 16, 'p': 1, 'weights': 'uniform', 'features': 43},
#             Current best combo with val score 0.3164:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 39}
# Trained and Tested combination 607 of 19200, taking 0.0 seconds to get val score of 0.023:
#                 {'n_neighbors': 1, 'p': 1, 'weights': 'uniform', 'features': 15},
#             Current best combo with val score 0.3164:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 39}
# Trained and Tested combination 608 of 19200, taking 0.0 seconds to get val score of 0.0:
#                 {'n_neighbors': 61, 'p': 2, 'weights': 'distance', 'features': 25},
#             Current best combo with val score 0.3164:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 39}
# Trained and Tested combination 609 of 19200, taking 0.01 seconds to get val score of 0.01:
#                 {'n_neighbors': 11, 'p': 1, 'weights': 'distance', 'features': 39},
#             Current best combo with val score 0.3164:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 39}
# Trained and Tested combination 610 of 19200, taking 0.01 seconds to get val score of 0.28:
#                 {'n_neighbors': 16, 'p': 2, 'weights': 'uniform', 'features': 39},
#             Current best combo with val score 0.3164:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 39}
# Trained and Tested combination 611 of 19200, taking 0.01 seconds to get val score of 0.0:
#                 {'n_neighbors': 21, 'p': 2, 'weights': 'uniform', 'features': 25},
#             Current best combo with val score 0.3164:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 39}
# Trained and Tested combination 612 of 19200, taking 0.0 seconds to get val score of 0.0:
#                 {'n_neighbors': 100, 'p': 1, 'weights': 'distance', 'features': 35},
#             Current best combo with val score 0.3164:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 39}
# Trained and Tested combination 613 of 19200, taking 0.0 seconds to get val score of 0.0568:
#                 {'n_neighbors': 36, 'p': 1, 'weights': 'uniform', 'features': 20},
#             Current best combo with val score 0.3164:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 39}
# Trained and Tested combination 614 of 19200, taking 0.0 seconds to get val score of 0.0:
#                 {'n_neighbors': 91, 'p': 1, 'weights': 'distance', 'features': 43},
#             Current best combo with val score 0.3164:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 39}
# Trained and Tested combination 615 of 19200, taking 0.0 seconds to get val score of 0.0:
#                 {'n_neighbors': 41, 'p': 1, 'weights': 'uniform', 'features': 35},
#             Current best combo with val score 0.3164:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 39}
# Trained and Tested combination 616 of 19200, taking 0.0 seconds to get val score of 0.0:
#                 {'n_neighbors': 56, 'p': 1, 'weights': 'distance', 'features': 0},
#             Current best combo with val score 0.3164:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 39}
# Trained and Tested combination 617 of 19200, taking 0.0 seconds to get val score of 0.0:
#                 {'n_neighbors': 100, 'p': 1, 'weights': 'distance', 'features': 10},
#             Current best combo with val score 0.3164:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 39}
# Trained and Tested combination 618 of 19200, taking 0.01 seconds to get val score of 0.2805:
#                 {'n_neighbors': 11, 'p': 2, 'weights': 'distance', 'features': 43},
#             Current best combo with val score 0.3164:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 39}
# Trained and Tested combination 619 of 19200, taking 0.0 seconds to get val score of 0.2182:
#                 {'n_neighbors': 16, 'p': 2, 'weights': 'distance', 'features': 5},
#             Current best combo with val score 0.3164:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 39}
# Trained and Tested combination 620 of 19200, taking 0.0 seconds to get val score of 0.2344:
#                 {'n_neighbors': 31, 'p': 2, 'weights': 'distance', 'features': 39},
#             Current best combo with val score 0.3164:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 39}
# Trained and Tested combination 621 of 19200, taking 0.01 seconds to get val score of 0.0:
#                 {'n_neighbors': 86, 'p': 2, 'weights': 'distance', 'features': 20},
#             Current best combo with val score 0.3164:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 39}
# Trained and Tested combination 622 of 19200, taking 0.0 seconds to get val score of 0.2805:
#                 {'n_neighbors': 11, 'p': 2, 'weights': 'uniform', 'features': 35},
#             Current best combo with val score 0.3164:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 39}
# Trained and Tested combination 623 of 19200, taking 0.0 seconds to get val score of 0.0:
#                 {'n_neighbors': 16, 'p': 2, 'weights': 'distance', 'features': 30},
#             Current best combo with val score 0.3164:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 39}
# Trained and Tested combination 624 of 19200, taking 0.0 seconds to get val score of 0.0:
#                 {'n_neighbors': 31, 'p': 1, 'weights': 'distance', 'features': 0},
#             Current best combo with val score 0.3164:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 39}
# Trained and Tested combination 625 of 19200, taking 0.0 seconds to get val score of 0.0033:
#                 {'n_neighbors': 76, 'p': 1, 'weights': 'uniform', 'features': 15},
#             Current best combo with val score 0.3164:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 39}
# Trained and Tested combination 626 of 19200, taking 0.0 seconds to get val score of 0.0:
#                 {'n_neighbors': 16, 'p': 1, 'weights': 'distance', 'features': 25},
#             Current best combo with val score 0.3164:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 39}
# Trained and Tested combination 627 of 19200, taking 0.01 seconds to get val score of 0.0:
#                 {'n_neighbors': 66, 'p': 1, 'weights': 'distance', 'features': 25},
#             Current best combo with val score 0.3164:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 39}
# Trained and Tested combination 628 of 19200, taking 0.0 seconds to get val score of 0.2366:
#                 {'n_neighbors': 76, 'p': 2, 'weights': 'distance', 'features': 39},
#             Current best combo with val score 0.3164:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 39}
# Trained and Tested combination 629 of 19200, taking 0.0 seconds to get val score of 0.0:
#                 {'n_neighbors': 41, 'p': 1, 'weights': 'distance', 'features': 10},
#             Current best combo with val score 0.3164:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 39}
# Trained and Tested combination 630 of 19200, taking 0.0 seconds to get val score of 0.0:
#                 {'n_neighbors': 51, 'p': 1, 'weights': 'distance', 'features': 25},
#             Current best combo with val score 0.3164:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 39}
# Trained and Tested combination 631 of 19200, taking 0.01 seconds to get val score of 0.0511:
#                 {'n_neighbors': 56, 'p': 1, 'weights': 'distance', 'features': 20},
#             Current best combo with val score 0.3164:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 39}
# Trained and Tested combination 632 of 19200, taking 0.0 seconds to get val score of 0.0:
#                 {'n_neighbors': 31, 'p': 1, 'weights': 'distance', 'features': 39},
#             Current best combo with val score 0.3164:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 39}
# Trained and Tested combination 633 of 19200, taking 0.0 seconds to get val score of 0.0:
#                 {'n_neighbors': 11, 'p': 2, 'weights': 'distance', 'features': 15},
#             Current best combo with val score 0.3164:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 39}
# Trained and Tested combination 634 of 19200, taking 0.01 seconds to get val score of 0.2373:
#                 {'n_neighbors': 66, 'p': 2, 'weights': 'distance', 'features': 39},
#             Current best combo with val score 0.3164:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 39}
# Trained and Tested combination 635 of 19200, taking 0.0 seconds to get val score of 0.0:
#                 {'n_neighbors': 51, 'p': 2, 'weights': 'uniform', 'features': 25},
#             Current best combo with val score 0.3164:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 39}
# Trained and Tested combination 636 of 19200, taking 0.0 seconds to get val score of 0.0:
#                 {'n_neighbors': 91, 'p': 1, 'weights': 'uniform', 'features': 43},
#             Current best combo with val score 0.3164:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 39}
# Trained and Tested combination 637 of 19200, taking 0.01 seconds to get val score of 0.0:
#                 {'n_neighbors': 26, 'p': 2, 'weights': 'distance', 'features': 30},
#             Current best combo with val score 0.3164:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 39}
# Trained and Tested combination 638 of 19200, taking 0.0 seconds to get val score of 0.292:
#                 {'n_neighbors': 1, 'p': 1, 'weights': 'distance', 'features': 35},
#             Current best combo with val score 0.3164:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 39}
# Trained and Tested combination 639 of 19200, taking 0.0 seconds to get val score of 0.0:
#                 {'n_neighbors': 81, 'p': 2, 'weights': 'uniform', 'features': 0},
#             Current best combo with val score 0.3164:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 39}
# Trained and Tested combination 640 of 19200, taking 0.01 seconds to get val score of 0.0:
#                 {'n_neighbors': 11, 'p': 2, 'weights': 'distance', 'features': 20},
#             Current best combo with val score 0.3164:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 39}
# Trained and Tested combination 641 of 19200, taking 0.0 seconds to get val score of 0.2393:
#                 {'n_neighbors': 56, 'p': 2, 'weights': 'uniform', 'features': 43},
#             Current best combo with val score 0.3164:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 39}
# Trained and Tested combination 642 of 19200, taking 0.0 seconds to get val score of 0.0:
#                 {'n_neighbors': 81, 'p': 1, 'weights': 'distance', 'features': 10},
#             Current best combo with val score 0.3164:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 39}
# Trained and Tested combination 643 of 19200, taking 0.0 seconds to get val score of 0.1477:
#                 {'n_neighbors': 1, 'p': 1, 'weights': 'distance', 'features': 43},
#             Current best combo with val score 0.3164:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 39}
# Trained and Tested combination 644 of 19200, taking 0.0 seconds to get val score of 0.2805:
#                 {'n_neighbors': 11, 'p': 2, 'weights': 'uniform', 'features': 39},
#             Current best combo with val score 0.3164:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 39}
# Trained and Tested combination 645 of 19200, taking 0.0 seconds to get val score of 0.0:
#                 {'n_neighbors': 71, 'p': 2, 'weights': 'uniform', 'features': 0},
#             Current best combo with val score 0.3164:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 39}
# Trained and Tested combination 646 of 19200, taking 0.01 seconds to get val score of 0.1478:
#                 {'n_neighbors': 36, 'p': 2, 'weights': 'uniform', 'features': 47},
#             Current best combo with val score 0.3164:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 39}
# Trained and Tested combination 647 of 19200, taking 0.0 seconds to get val score of 0.2489:
#                 {'n_neighbors': 26, 'p': 2, 'weights': 'distance', 'features': 35},
#             Current best combo with val score 0.3164:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 39}
# Trained and Tested combination 648 of 19200, taking 0.0 seconds to get val score of 0.1614:
#                 {'n_neighbors': 51, 'p': 1, 'weights': 'distance', 'features': 5},
#             Current best combo with val score 0.3164:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 39}
# Trained and Tested combination 649 of 19200, taking 0.0 seconds to get val score of 0.0:
#                 {'n_neighbors': 46, 'p': 1, 'weights': 'distance', 'features': 35},
#             Current best combo with val score 0.3164:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 39}
# Trained and Tested combination 650 of 19200, taking 0.01 seconds to get val score of 0.2517:
#                 {'n_neighbors': 31, 'p': 2, 'weights': 'distance', 'features': 35},
#             Current best combo with val score 0.3164:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 39}
# Trained and Tested combination 651 of 19200, taking 0.0 seconds to get val score of 0.0:
#                 {'n_neighbors': 31, 'p': 1, 'weights': 'distance', 'features': 47},
#             Current best combo with val score 0.3164:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 39}
# Trained and Tested combination 652 of 19200, taking 0.0 seconds to get val score of 0.0:
#                 {'n_neighbors': 61, 'p': 1, 'weights': 'uniform', 'features': 30},
#             Current best combo with val score 0.3164:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 39}
# Trained and Tested combination 653 of 19200, taking 0.0 seconds to get val score of 0.1321:
#                 {'n_neighbors': 26, 'p': 2, 'weights': 'uniform', 'features': 5},
#             Current best combo with val score 0.3164:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 39}
# Trained and Tested combination 654 of 19200, taking 0.0 seconds to get val score of 0.0:
#                 {'n_neighbors': 76, 'p': 1, 'weights': 'uniform', 'features': 10},
#             Current best combo with val score 0.3164:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 39}
# Trained and Tested combination 655 of 19200, taking 0.01 seconds to get val score of 0.0:
#                 {'n_neighbors': 71, 'p': 1, 'weights': 'distance', 'features': 30},
#             Current best combo with val score 0.3164:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 39}
# Trained and Tested combination 656 of 19200, taking 0.0 seconds to get val score of 0.1601:
#                 {'n_neighbors': 71, 'p': 2, 'weights': 'distance', 'features': 5},
#             Current best combo with val score 0.3164:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 39}
# Trained and Tested combination 657 of 19200, taking 0.01 seconds to get val score of 0.2302:
#                 {'n_neighbors': 66, 'p': 2, 'weights': 'uniform', 'features': 43},
#             Current best combo with val score 0.3164:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 39}
# Trained and Tested combination 658 of 19200, taking 0.0 seconds to get val score of 0.2251:
#                 {'n_neighbors': 76, 'p': 2, 'weights': 'uniform', 'features': 47},
#             Current best combo with val score 0.3164:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 39}
# Trained and Tested combination 659 of 19200, taking 0.0 seconds to get val score of 0.0:
#                 {'n_neighbors': 46, 'p': 2, 'weights': 'distance', 'features': 25},
#             Current best combo with val score 0.3164:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 39}
# Trained and Tested combination 660 of 19200, taking 0.0 seconds to get val score of 0.0:
#                 {'n_neighbors': 76, 'p': 1, 'weights': 'distance', 'features': 10},
#             Current best combo with val score 0.3164:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 39}
# Trained and Tested combination 661 of 19200, taking 0.0 seconds to get val score of 0.0:
#                 {'n_neighbors': 81, 'p': 1, 'weights': 'distance', 'features': 30},
#             Current best combo with val score 0.3164:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 39}
# Trained and Tested combination 662 of 19200, taking 0.0 seconds to get val score of 0.0:
#                 {'n_neighbors': 66, 'p': 1, 'weights': 'uniform', 'features': 30},
#             Current best combo with val score 0.3164:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 39}
# Trained and Tested combination 663 of 19200, taking 0.0 seconds to get val score of 0.0033:
#                 {'n_neighbors': 86, 'p': 1, 'weights': 'distance', 'features': 15},
#             Current best combo with val score 0.3164:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 39}
# Trained and Tested combination 664 of 19200, taking 0.0 seconds to get val score of 0.0:
#                 {'n_neighbors': 81, 'p': 1, 'weights': 'uniform', 'features': 47},
#             Current best combo with val score 0.3164:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 39}
# Trained and Tested combination 665 of 19200, taking 0.0 seconds to get val score of 0.1878:
#                 {'n_neighbors': 31, 'p': 2, 'weights': 'distance', 'features': 47},
#             Current best combo with val score 0.3164:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 39}
# Trained and Tested combination 666 of 19200, taking 0.0 seconds to get val score of 0.0:
#                 {'n_neighbors': 21, 'p': 1, 'weights': 'distance', 'features': 10},
#             Current best combo with val score 0.3164:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 39}
# Trained and Tested combination 667 of 19200, taking 0.0 seconds to get val score of 0.0:
#                 {'n_neighbors': 31, 'p': 1, 'weights': 'uniform', 'features': 30},
#             Current best combo with val score 0.3164:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 39}
# Trained and Tested combination 668 of 19200, taking 0.0 seconds to get val score of 0.2297:
#                 {'n_neighbors': 11, 'p': 1, 'weights': 'distance', 'features': 5},
#             Current best combo with val score 0.3164:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 39}
# Trained and Tested combination 669 of 19200, taking 0.0 seconds to get val score of 0.3117:
#                 {'n_neighbors': 1, 'p': 2, 'weights': 'uniform', 'features': 35},
#             Current best combo with val score 0.3164:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 39}
# Trained and Tested combination 670 of 19200, taking 0.01 seconds to get val score of 0.0967:
#                 {'n_neighbors': 86, 'p': 2, 'weights': 'uniform', 'features': 39},
#             Current best combo with val score 0.3164:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 39}
# Trained and Tested combination 671 of 19200, taking 0.0 seconds to get val score of 0.0:
#                 {'n_neighbors': 91, 'p': 1, 'weights': 'distance', 'features': 0},
#             Current best combo with val score 0.3164:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 39}
# Trained and Tested combination 672 of 19200, taking 0.0 seconds to get val score of 0.0:
#                 {'n_neighbors': 46, 'p': 2, 'weights': 'distance', 'features': 0},
#             Current best combo with val score 0.3164:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 39}
# Trained and Tested combination 673 of 19200, taking 0.0 seconds to get val score of 0.0:
#                 {'n_neighbors': 76, 'p': 1, 'weights': 'distance', 'features': 25},
#             Current best combo with val score 0.3164:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 39}
# Trained and Tested combination 674 of 19200, taking 0.0 seconds to get val score of 0.0:
#                 {'n_neighbors': 31, 'p': 1, 'weights': 'uniform', 'features': 25},
#             Current best combo with val score 0.3164:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 39}
# Trained and Tested combination 675 of 19200, taking 0.0 seconds to get val score of 0.2278:
#                 {'n_neighbors': 81, 'p': 2, 'weights': 'distance', 'features': 39},
#             Current best combo with val score 0.3164:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 39}
# Trained and Tested combination 676 of 19200, taking 0.01 seconds to get val score of 0.2466:
#                 {'n_neighbors': 36, 'p': 2, 'weights': 'distance', 'features': 39},
#             Current best combo with val score 0.3164:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 39}
# Trained and Tested combination 677 of 19200, taking 0.0 seconds to get val score of 0.0067:
#                 {'n_neighbors': 26, 'p': 1, 'weights': 'distance', 'features': 15},
#             Current best combo with val score 0.3164:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 39}
# Trained and Tested combination 678 of 19200, taking 0.0 seconds to get val score of 0.2237:
#                 {'n_neighbors': 41, 'p': 2, 'weights': 'uniform', 'features': 47},
#             Current best combo with val score 0.3164:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 39}
# Trained and Tested combination 679 of 19200, taking 0.0 seconds to get val score of 0.0:
#                 {'n_neighbors': 96, 'p': 1, 'weights': 'uniform', 'features': 30},
#             Current best combo with val score 0.3164:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 39}
# Trained and Tested combination 680 of 19200, taking 0.0 seconds to get val score of 0.0:
#                 {'n_neighbors': 11, 'p': 1, 'weights': 'distance', 'features': 0},
#             Current best combo with val score 0.3164:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 39}
# Trained and Tested combination 681 of 19200, taking 0.0 seconds to get val score of 0.2464:
#                 {'n_neighbors': 51, 'p': 2, 'weights': 'uniform', 'features': 47},
#             Current best combo with val score 0.3164:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 39}
# Trained and Tested combination 682 of 19200, taking 0.0 seconds to get val score of 0.2532:
#                 {'n_neighbors': 86, 'p': 2, 'weights': 'uniform', 'features': 47},
#             Current best combo with val score 0.3164:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 39}
# Trained and Tested combination 683 of 19200, taking 0.0 seconds to get val score of 0.0576:
#                 {'n_neighbors': 100, 'p': 1, 'weights': 'distance', 'features': 20},
#             Current best combo with val score 0.3164:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 39}
# Trained and Tested combination 684 of 19200, taking 0.0 seconds to get val score of 0.0:
#                 {'n_neighbors': 41, 'p': 1, 'weights': 'distance', 'features': 35},
#             Current best combo with val score 0.3164:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 39}
# Trained and Tested combination 685 of 19200, taking 0.0 seconds to get val score of 0.0:
#                 {'n_neighbors': 16, 'p': 2, 'weights': 'uniform', 'features': 10},
#             Current best combo with val score 0.3164:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 39}
# Trained and Tested combination 686 of 19200, taking 0.0 seconds to get val score of 0.1762:
#                 {'n_neighbors': 61, 'p': 2, 'weights': 'distance', 'features': 5},
#             Current best combo with val score 0.3164:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 39}
# Trained and Tested combination 687 of 19200, taking 0.0 seconds to get val score of 0.0033:
#                 {'n_neighbors': 31, 'p': 1, 'weights': 'distance', 'features': 35},
#             Current best combo with val score 0.3164:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 39}
# Trained and Tested combination 688 of 19200, taking 0.0 seconds to get val score of 0.1399:
#                 {'n_neighbors': 86, 'p': 1, 'weights': 'distance', 'features': 5},
#             Current best combo with val score 0.3164:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 39}
# Trained and Tested combination 689 of 19200, taking 0.0 seconds to get val score of 0.1709:
#                 {'n_neighbors': 41, 'p': 2, 'weights': 'distance', 'features': 5},
#             Current best combo with val score 0.3164:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 39}
# Trained and Tested combination 690 of 19200, taking 0.0 seconds to get val score of 0.3118:
#                 {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 47},
#             Current best combo with val score 0.3164:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 39}
# Trained and Tested combination 691 of 19200, taking 0.0 seconds to get val score of 0.0067:
#                 {'n_neighbors': 6, 'p': 1, 'weights': 'distance', 'features': 15},
#             Current best combo with val score 0.3164:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 39}
# Trained and Tested combination 692 of 19200, taking 0.0 seconds to get val score of 0.0:
#                 {'n_neighbors': 100, 'p': 2, 'weights': 'uniform', 'features': 30},
#             Current best combo with val score 0.3164:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 39}
# Trained and Tested combination 693 of 19200, taking 0.0 seconds to get val score of 0.1376:
#                 {'n_neighbors': 21, 'p': 1, 'weights': 'uniform', 'features': 5},
#             Current best combo with val score 0.3164:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 39}
# Trained and Tested combination 694 of 19200, taking 0.0 seconds to get val score of 0.0:
#                 {'n_neighbors': 76, 'p': 1, 'weights': 'distance', 'features': 47},
#             Current best combo with val score 0.3164:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 39}
# Trained and Tested combination 695 of 19200, taking 0.0 seconds to get val score of 0.0:
#                 {'n_neighbors': 86, 'p': 1, 'weights': 'distance', 'features': 47},
#             Current best combo with val score 0.3164:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 39}
# Trained and Tested combination 696 of 19200, taking 0.01 seconds to get val score of 0.0:
#                 {'n_neighbors': 51, 'p': 1, 'weights': 'distance', 'features': 0},
#             Current best combo with val score 0.3164:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 39}
# Trained and Tested combination 697 of 19200, taking 0.0 seconds to get val score of 0.0:
#                 {'n_neighbors': 21, 'p': 1, 'weights': 'uniform', 'features': 25},
#             Current best combo with val score 0.3164:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 39}
# Trained and Tested combination 698 of 19200, taking 0.0 seconds to get val score of 0.0:
#                 {'n_neighbors': 56, 'p': 2, 'weights': 'uniform', 'features': 15},
#             Current best combo with val score 0.3164:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 39}
# Trained and Tested combination 699 of 19200, taking 0.0 seconds to get val score of 0.0:
#                 {'n_neighbors': 91, 'p': 1, 'weights': 'uniform', 'features': 10},
#             Current best combo with val score 0.3164:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 39}
# Trained and Tested combination 700 of 19200, taking 0.0 seconds to get val score of 0.0695:
#                 {'n_neighbors': 6, 'p': 1, 'weights': 'uniform', 'features': 20},
#             Current best combo with val score 0.3164:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 39}
# Trained and Tested combination 701 of 19200, taking 0.0 seconds to get val score of 0.0:
#                 {'n_neighbors': 21, 'p': 1, 'weights': 'uniform', 'features': 47},
#             Current best combo with val score 0.3164:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 39}
# Trained and Tested combination 702 of 19200, taking 0.01 seconds to get val score of 0.0451:
#                 {'n_neighbors': 76, 'p': 1, 'weights': 'uniform', 'features': 20},
#             Current best combo with val score 0.3164:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 39}
# Trained and Tested combination 703 of 19200, taking 0.0 seconds to get val score of 0.0:
#                 {'n_neighbors': 76, 'p': 2, 'weights': 'distance', 'features': 0},
#             Current best combo with val score 0.3164:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 39}
# Trained and Tested combination 704 of 19200, taking 0.0 seconds to get val score of 0.0:
#                 {'n_neighbors': 96, 'p': 2, 'weights': 'uniform', 'features': 20},
#             Current best combo with val score 0.3164:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 39}
# Trained and Tested combination 705 of 19200, taking 0.0 seconds to get val score of 0.0:
#                 {'n_neighbors': 76, 'p': 2, 'weights': 'uniform', 'features': 30},
#             Current best combo with val score 0.3164:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 39}
# Trained and Tested combination 706 of 19200, taking 0.0 seconds to get val score of 0.0:
#                 {'n_neighbors': 51, 'p': 2, 'weights': 'uniform', 'features': 0},
#             Current best combo with val score 0.3164:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 39}
# Trained and Tested combination 707 of 19200, taking 0.0 seconds to get val score of 0.0:
#                 {'n_neighbors': 36, 'p': 2, 'weights': 'uniform', 'features': 25},
#             Current best combo with val score 0.3164:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 39}
# Trained and Tested combination 708 of 19200, taking 0.0 seconds to get val score of 0.0:
#                 {'n_neighbors': 21, 'p': 2, 'weights': 'distance', 'features': 25},
#             Current best combo with val score 0.3164:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 39}
# Trained and Tested combination 709 of 19200, taking 0.0 seconds to get val score of 0.0:
#                 {'n_neighbors': 46, 'p': 2, 'weights': 'distance', 'features': 10},
#             Current best combo with val score 0.3164:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 39}
# Trained and Tested combination 710 of 19200, taking 0.0 seconds to get val score of 0.0:
#                 {'n_neighbors': 21, 'p': 1, 'weights': 'uniform', 'features': 39},
#             Current best combo with val score 0.3164:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 39}
# Trained and Tested combination 711 of 19200, taking 0.01 seconds to get val score of 0.0:
#                 {'n_neighbors': 6, 'p': 1, 'weights': 'uniform', 'features': 43},
#             Current best combo with val score 0.3164:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 39}
# Trained and Tested combination 712 of 19200, taking 0.0 seconds to get val score of 0.0782:
#                 {'n_neighbors': 81, 'p': 2, 'weights': 'uniform', 'features': 5},
#             Current best combo with val score 0.3164:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 39}
# Trained and Tested combination 713 of 19200, taking 0.01 seconds to get val score of 0.0:
#                 {'n_neighbors': 66, 'p': 1, 'weights': 'distance', 'features': 47},
#             Current best combo with val score 0.3164:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 39}
# Trained and Tested combination 714 of 19200, taking 0.0 seconds to get val score of 0.0:
#                 {'n_neighbors': 51, 'p': 1, 'weights': 'uniform', 'features': 0},
#             Current best combo with val score 0.3164:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 39}
# Trained and Tested combination 715 of 19200, taking 0.0 seconds to get val score of 0.0538:
#                 {'n_neighbors': 51, 'p': 1, 'weights': 'uniform', 'features': 20},
#             Current best combo with val score 0.3164:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 39}
# Trained and Tested combination 716 of 19200, taking 0.0 seconds to get val score of 0.1897:
#                 {'n_neighbors': 36, 'p': 2, 'weights': 'distance', 'features': 5},
#             Current best combo with val score 0.3164:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 39}
# Trained and Tested combination 717 of 19200, taking 0.0 seconds to get val score of 0.0:
#                 {'n_neighbors': 51, 'p': 1, 'weights': 'uniform', 'features': 10},
#             Current best combo with val score 0.3164:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 39}
# Trained and Tested combination 718 of 19200, taking 0.0 seconds to get val score of 0.2704:
#                 {'n_neighbors': 96, 'p': 2, 'weights': 'uniform', 'features': 35},
#             Current best combo with val score 0.3164:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 39}
# Trained and Tested combination 719 of 19200, taking 0.0 seconds to get val score of 0.0:
#                 {'n_neighbors': 46, 'p': 2, 'weights': 'distance', 'features': 30},
#             Current best combo with val score 0.3164:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 39}
# Trained and Tested combination 720 of 19200, taking 0.0 seconds to get val score of 0.0:
#                 {'n_neighbors': 1, 'p': 2, 'weights': 'distance', 'features': 20},
#             Current best combo with val score 0.3164:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 39}
# Trained and Tested combination 721 of 19200, taking 0.0 seconds to get val score of 0.0:
#                 {'n_neighbors': 61, 'p': 1, 'weights': 'distance', 'features': 30},
#             Current best combo with val score 0.3164:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 39}
# Trained and Tested combination 722 of 19200, taking 0.0 seconds to get val score of 0.0:
#                 {'n_neighbors': 96, 'p': 1, 'weights': 'distance', 'features': 25},
#             Current best combo with val score 0.3164:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 39}
# Trained and Tested combination 723 of 19200, taking 0.0 seconds to get val score of 0.0205:
#                 {'n_neighbors': 6, 'p': 1, 'weights': 'distance', 'features': 0},
#             Current best combo with val score 0.3164:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 39}
# Trained and Tested combination 724 of 19200, taking 0.01 seconds to get val score of 0.0:
#                 {'n_neighbors': 76, 'p': 1, 'weights': 'uniform', 'features': 47},
#             Current best combo with val score 0.3164:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 39}
# Trained and Tested combination 725 of 19200, taking 0.0 seconds to get val score of 0.0:
#                 {'n_neighbors': 96, 'p': 1, 'weights': 'distance', 'features': 0},
#             Current best combo with val score 0.3164:
#                     {'n_neighbors': 6, 'p': 2, 'weights': 'distance', 'features': 39}
# ...
# Trained and Tested combination 1127 of 19200, taking 0.0 seconds to get val score of 0.4368:
#                 {'n_neighbors': 1, 'p': 1, 'weights': 'uniform', 'features': 2},
#             Current best combo with val score 0.4368:
#                     {'n_neighbors': 1, 'p': 1, 'weights': 'distance', 'features': 2}
# Trained and Tested combination 1128 of 19200, taking 0.0 seconds to get val score of 0.431:
#                 {'n_neighbors': 1, 'p': 1, 'weights': 'distance', 'features': 1},
#             Current best combo with val score 0.4368:
#                     {'n_neighbors': 1, 'p': 1, 'weights': 'distance', 'features': 2}
# Already Trained and Tested combination (val score of 0.407):
#             {'n_neighbors': 1, 'p': 1, 'weights': 'distance', 'features': 3}
#             Current best combo (with val score 0.4368):
#                     {'n_neighbors': 1, 'p': 1, 'weights': 'distance', 'features': 2}
#         Has trained 1128 of 19200 combinations so far
# % Combos Checked Thus Far: 1128 out of 19200 which is 5.875%
# Cruising Coordrdinate 650 of 924
#
# Cruising Coordrdinate 651 of 924
#
# Cruising Coordrdinate 652 of 924
#
# Cruising Coordrdinate 653 of 924
#
# Cruising Coordrdinate 654 of 924
#
# Cruising Coordrdinate 655 of 924
#
# Cruising Coordrdinate 656 of 924
#
# Cruising Coordrdinate 657 of 924
#
# Cruising Coordrdinate 658 of 924
#
# Cruising Coordrdinate 659 of 924
#
# Cruising Coordrdinate 660 of 924
#
# Cruising Coordrdinate 661 of 924
#
# Cruising Coordrdinate 662 of 924
#
# Cruising Coordrdinate 663 of 924
#
# Cruising Coordrdinate 664 of 924
#
# Cruising Coordrdinate 665 of 924
#
# Cruising Coordrdinate 666 of 924
#
# Cruising Coordrdinate 667 of 924
#
# Cruising Coordrdinate 668 of 924
#
# Cruising Coordrdinate 669 of 924
#
# Cruising Coordrdinate 670 of 924
#
# Cruising Coordrdinate 671 of 924
#
# Cruising Coordrdinate 672 of 924
#
# Cruising Coordrdinate 673 of 924
#
# Cruising Coordrdinate 674 of 924
#
# Cruising Coordrdinate 675 of 924
#
# Cruising Coordrdinate 676 of 924
#
# Cruising Coordrdinate 677 of 924
#
# Cruising Coordrdinate 678 of 924
#
# Cruising Coordrdinate 679 of 924
#
# Cruising Coordrdinate 680 of 924
#
# Cruising Coordrdinate 681 of 924
#
# Cruising Coordrdinate 682 of 924
#
# Cruising Coordrdinate 683 of 924
#
# Cruising Coordrdinate 684 of 924
#
# Cruising Coordrdinate 685 of 924
#
# Cruising Coordrdinate 686 of 924
#
# Cruising Coordrdinate 687 of 924
#
# Cruising Coordrdinate 688 of 924
#
# Cruising Coordrdinate 689 of 924
#
# Cruising Coordrdinate 690 of 924
#
# Cruising Coordrdinate 691 of 924
#
# Cruising Coordrdinate 692 of 924
#
# Cruising Coordrdinate 693 of 924
#
# Cruising Coordrdinate 694 of 924
#
# Cruising Coordrdinate 695 of 924
#
# Cruising Coordrdinate 696 of 924
#
# Cruising Coordrdinate 697 of 924
#
# Cruising Coordrdinate 698 of 924
#
# Cruising Coordrdinate 699 of 924
#
# Cruising Coordrdinate 700 of 924
#
# Cruising Coordrdinate 701 of 924
#
# Cruising Coordrdinate 702 of 924
#
# Cruising Coordrdinate 703 of 924
#
# Cruising Coordrdinate 704 of 924
#
# Cruising Coordrdinate 705 of 924
#
# Cruising Coordrdinate 706 of 924
#
# Cruising Coordrdinate 707 of 924
#
# Cruising Coordrdinate 708 of 924
#
# Cruising Coordrdinate 709 of 924
#
# Cruising Coordrdinate 710 of 924
#
# Cruising Coordrdinate 711 of 924
#
# Cruising Coordrdinate 712 of 924
#
# Cruising Coordrdinate 713 of 924
#
# Cruising Coordrdinate 714 of 924
#
# Cruising Coordrdinate 715 of 924
#
# Cruising Coordrdinate 716 of 924
#
# Cruising Coordrdinate 717 of 924
#
# Cruising Coordrdinate 718 of 924
#
# Cruising Coordrdinate 719 of 924
#
# Cruising Coordrdinate 720 of 924
#
# Cruising Coordrdinate 721 of 924
#
# Cruising Coordrdinate 722 of 924
#
# Cruising Coordrdinate 723 of 924
#
# Cruising Coordrdinate 724 of 924
#
# Cruising Coordrdinate 725 of 924
#
# Cruising Coordrdinate 726 of 924
#
# Cruising Coordrdinate 727 of 924
#
# Cruising Coordrdinate 728 of 924
#
# Cruising Coordrdinate 729 of 924
#
# Cruising Coordrdinate 730 of 924
#
# Cruising Coordrdinate 731 of 924
#
# Cruising Coordrdinate 732 of 924
#
# Cruising Coordrdinate 733 of 924
#
# Cruising Coordrdinate 734 of 924
#
# Cruising Coordrdinate 735 of 924
#
# Cruising Coordrdinate 736 of 924
#
# Cruising Coordrdinate 737 of 924
#
# Cruising Coordrdinate 738 of 924
#
# Cruising Coordrdinate 739 of 924
#
# Cruising Coordrdinate 740 of 924
#
# Cruising Coordrdinate 741 of 924
#
# Cruising Coordrdinate 742 of 924
#
# Cruising Coordrdinate 743 of 924
#
# Cruising Coordrdinate 744 of 924
#
# Cruising Coordrdinate 745 of 924
#
# Cruising Coordrdinate 746 of 924
#
# Cruising Coordrdinate 747 of 924
#
# Cruising Coordrdinate 748 of 924
#
# Cruising Coordrdinate 749 of 924
#
# Cruising Coordrdinate 750 of 924
#
# Cruising Coordrdinate 751 of 924
#
# Cruising Coordrdinate 752 of 924
#
# Cruising Coordrdinate 753 of 924
#
# Cruising Coordrdinate 754 of 924
#
# Cruising Coordrdinate 755 of 924
#
# Cruising Coordrdinate 756 of 924
#
# Cruising Coordrdinate 757 of 924
#
# Cruising Coordrdinate 758 of 924
#
# Cruising Coordrdinate 759 of 924
#
# Cruising Coordrdinate 760 of 924
#
# Cruising Coordrdinate 761 of 924
#
# Cruising Coordrdinate 762 of 924
#
# Cruising Coordrdinate 763 of 924
#
# Cruising Coordrdinate 764 of 924
#
# Cruising Coordrdinate 765 of 924
#
# Cruising Coordrdinate 766 of 924
#
# Cruising Coordrdinate 767 of 924
#
# Cruising Coordrdinate 768 of 924
#
# Cruising Coordrdinate 769 of 924
#
# Cruising Coordrdinate 770 of 924
#
# Cruising Coordrdinate 771 of 924
#
# Cruising Coordrdinate 772 of 924
#
# Cruising Coordrdinate 773 of 924
#
# Cruising Coordrdinate 774 of 924
#
# Cruising Coordrdinate 775 of 924
#
# Cruising Coordrdinate 776 of 924
#
# Cruising Coordrdinate 777 of 924
#
# Cruising Coordrdinate 778 of 924
#
# Cruising Coordrdinate 779 of 924
#
# Cruising Coordrdinate 780 of 924
#
# Cruising Coordrdinate 781 of 924
#
# Cruising Coordrdinate 782 of 924
#
# Cruising Coordrdinate 783 of 924
#
# Cruising Coordrdinate 784 of 924
#
# Cruising Coordrdinate 785 of 924
#
# Cruising Coordrdinate 786 of 924
#
# Cruising Coordrdinate 787 of 924
#
# Cruising Coordrdinate 788 of 924
#
# Cruising Coordrdinate 789 of 924
#
# Cruising Coordrdinate 790 of 924
#
# Cruising Coordrdinate 791 of 924
#
# Cruising Coordrdinate 792 of 924
#
# Cruising Coordrdinate 793 of 924
#
# Cruising Coordrdinate 794 of 924
#
# Cruising Coordrdinate 795 of 924
#
# Cruising Coordrdinate 796 of 924
#
# Cruising Coordrdinate 797 of 924
#
# Cruising Coordrdinate 798 of 924
#
# Cruising Coordrdinate 799 of 924
#
# Cruising Coordrdinate 800 of 924
#
# Cruising Coordrdinate 801 of 924
#
# Cruising Coordrdinate 802 of 924
#
# Cruising Coordrdinate 803 of 924
#
# Cruising Coordrdinate 804 of 924
#
# Cruising Coordrdinate 805 of 924
#
# Cruising Coordrdinate 806 of 924
#
# Cruising Coordrdinate 807 of 924
#
# Cruising Coordrdinate 808 of 924
#
# Cruising Coordrdinate 809 of 924
#
# Cruising Coordrdinate 810 of 924
#
# Cruising Coordrdinate 811 of 924
#
# Cruising Coordrdinate 812 of 924
#
# Cruising Coordrdinate 813 of 924
#
# Cruising Coordrdinate 814 of 924
#
# Cruising Coordrdinate 815 of 924
#
# Cruising Coordrdinate 816 of 924
#
# Cruising Coordrdinate 817 of 924
#
# Cruising Coordrdinate 818 of 924
#
# Cruising Coordrdinate 819 of 924
#
# Cruising Coordrdinate 820 of 924
#
# Cruising Coordrdinate 821 of 924
#
# Cruising Coordrdinate 822 of 924
#
# Cruising Coordrdinate 823 of 924
#
# Cruising Coordrdinate 824 of 924
#
# Cruising Coordrdinate 825 of 924
#
# Cruising Coordrdinate 826 of 924
#
# Cruising Coordrdinate 827 of 924
#
# Cruising Coordrdinate 828 of 924
#
# Cruising Coordrdinate 829 of 924
#
# Cruising Coordrdinate 830 of 924
#
# Cruising Coordrdinate 831 of 924
#
# Cruising Coordrdinate 832 of 924
#
# Cruising Coordrdinate 833 of 924
#
# Cruising Coordrdinate 834 of 924
#
# Cruising Coordrdinate 835 of 924
#
# Cruising Coordrdinate 836 of 924
#
# Cruising Coordrdinate 837 of 924
#
# Cruising Coordrdinate 838 of 924
#
# Cruising Coordrdinate 839 of 924
#
# Cruising Coordrdinate 840 of 924
#
# Cruising Coordrdinate 841 of 924
#
# Cruising Coordrdinate 842 of 924
#
# Cruising Coordrdinate 843 of 924
#
# Cruising Coordrdinate 844 of 924
#
# Cruising Coordrdinate 845 of 924
#
# Cruising Coordrdinate 846 of 924
#
# Cruising Coordrdinate 847 of 924
#
# Cruising Coordrdinate 848 of 924
#
# Cruising Coordrdinate 849 of 924
#
# Cruising Coordrdinate 850 of 924
#
# Cruising Coordrdinate 851 of 924
#
# Cruising Coordrdinate 852 of 924
#
# Cruising Coordrdinate 853 of 924
#
# Cruising Coordrdinate 854 of 924
#
# Cruising Coordrdinate 855 of 924
#
# Cruising Coordrdinate 856 of 924
#
# Cruising Coordrdinate 857 of 924
#
# Cruising Coordrdinate 858 of 924
#
# Cruising Coordrdinate 859 of 924
#
# Cruising Coordrdinate 860 of 924
#
# Cruising Coordrdinate 861 of 924
#
# Cruising Coordrdinate 862 of 924
#
# Cruising Coordrdinate 863 of 924
#
# Cruising Coordrdinate 864 of 924
#
# Cruising Coordrdinate 865 of 924
#
# Cruising Coordrdinate 866 of 924
#
# Cruising Coordrdinate 867 of 924
#
# Cruising Coordrdinate 868 of 924
#
# Cruising Coordrdinate 869 of 924
#
# Cruising Coordrdinate 870 of 924
#
# Cruising Coordrdinate 871 of 924
#
# Cruising Coordrdinate 872 of 924
#
# Cruising Coordrdinate 873 of 924
#
# Cruising Coordrdinate 874 of 924
#
# Cruising Coordrdinate 875 of 924
#
# Cruising Coordrdinate 876 of 924
#
# Cruising Coordrdinate 877 of 924
#
# Cruising Coordrdinate 878 of 924
#
# Cruising Coordrdinate 879 of 924
#
# Cruising Coordrdinate 880 of 924
#
# Cruising Coordrdinate 881 of 924
#
# Cruising Coordrdinate 882 of 924
#
# Cruising Coordrdinate 883 of 924
#
# Cruising Coordrdinate 884 of 924
#
# Cruising Coordrdinate 885 of 924
#
# Cruising Coordrdinate 886 of 924
#
# Cruising Coordrdinate 887 of 924
#
# Cruising Coordrdinate 888 of 924
#
# Cruising Coordrdinate 889 of 924
#
# Cruising Coordrdinate 890 of 924
#
# Cruising Coordrdinate 891 of 924
#
# Cruising Coordrdinate 892 of 924
#
# Cruising Coordrdinate 893 of 924
#
# Cruising Coordrdinate 894 of 924
#
# Cruising Coordrdinate 895 of 924
#
# Cruising Coordrdinate 896 of 924
#
# Cruising Coordrdinate 897 of 924
#
# Cruising Coordrdinate 898 of 924
#
# Cruising Coordrdinate 899 of 924
#
# Cruising Coordrdinate 900 of 924
#
# Cruising Coordrdinate 901 of 924
#
# Cruising Coordrdinate 902 of 924
#
# Cruising Coordrdinate 903 of 924
#
# Cruising Coordrdinate 904 of 924
#
# Cruising Coordrdinate 905 of 924
#
# Cruising Coordrdinate 906 of 924
#
# Cruising Coordrdinate 907 of 924
#
# Cruising Coordrdinate 908 of 924
#
# Cruising Coordrdinate 909 of 924
#
# Cruising Coordrdinate 910 of 924
#
# Cruising Coordrdinate 911 of 924
#
# Cruising Coordrdinate 912 of 924
#
# Cruising Coordrdinate 913 of 924
#
# Cruising Coordrdinate 914 of 924
#
# Cruising Coordrdinate 915 of 924
#
# Cruising Coordrdinate 916 of 924
#
# Cruising Coordrdinate 917 of 924
#
# Cruising Coordrdinate 918 of 924
#
# Cruising Coordrdinate 919 of 924
#
# Cruising Coordrdinate 920 of 924
#
# Cruising Coordrdinate 921 of 924
#
# Cruising Coordrdinate 922 of 924
#
# Cruising Coordrdinate 923 of 924
#
# Cruising Coordrdinate 924 of 924
#
# FINAL STAGE: Begin final Guidance system
#
#
# Guidance: round FINAL
#
# 	round FINAL iteration:  0
#
# Already Trained and Tested combination (val score of 0.4283):
#             {'n_neighbors': 2, 'p': 1, 'weights': 'distance', 'features': 2}
#             Current best combo (with val score 0.4368):
#                     {'n_neighbors': 1, 'p': 1, 'weights': 'distance', 'features': 2}
#         Has trained 1128 of 19200 combinations so far
# Already Trained and Tested combination (val score of 0.4368):
#             {'n_neighbors': 1, 'p': 2, 'weights': 'distance', 'features': 2}
#             Current best combo (with val score 0.4368):
#                     {'n_neighbors': 1, 'p': 1, 'weights': 'distance', 'features': 2}
#         Has trained 1128 of 19200 combinations so far
# Already Trained and Tested combination (val score of 0.4368):
#             {'n_neighbors': 1, 'p': 1, 'weights': 'uniform', 'features': 2}
#             Current best combo (with val score 0.4368):
#                     {'n_neighbors': 1, 'p': 1, 'weights': 'distance', 'features': 2}
#         Has trained 1128 of 19200 combinations so far
# Already Trained and Tested combination (val score of 0.431):
#             {'n_neighbors': 1, 'p': 1, 'weights': 'distance', 'features': 1}
#             Current best combo (with val score 0.4368):
#                     {'n_neighbors': 1, 'p': 1, 'weights': 'distance', 'features': 2}
#         Has trained 1128 of 19200 combinations so far
# Already Trained and Tested combination (val score of 0.407):
#             {'n_neighbors': 1, 'p': 1, 'weights': 'distance', 'features': 3}
#             Current best combo (with val score 0.4368):
#                     {'n_neighbors': 1, 'p': 1, 'weights': 'distance', 'features': 2}
#         Has trained 1128 of 19200 combinations so far
# 	round FINAL iteration:  1
#
# Trained and Tested combination 1129 of 19200, taking 0.01 seconds to get val score of 0.4283:
#                 {'n_neighbors': 2, 'p': 2, 'weights': 'distance', 'features': 2},
#             Current best combo with val score 0.4368:
#                     {'n_neighbors': 1, 'p': 1, 'weights': 'distance', 'features': 2}
# Already Trained and Tested combination (val score of 0.4368):
#             {'n_neighbors': 1, 'p': 1, 'weights': 'distance', 'features': 2}
#             Current best combo (with val score 0.4368):
#                     {'n_neighbors': 1, 'p': 1, 'weights': 'distance', 'features': 2}
#         Has trained 1129 of 19200 combinations so far
# Trained and Tested combination 1130 of 19200, taking 0.0 seconds to get val score of 0.4368:
#                 {'n_neighbors': 1, 'p': 2, 'weights': 'uniform', 'features': 2},
#             Current best combo with val score 0.4368:
#                     {'n_neighbors': 1, 'p': 1, 'weights': 'distance', 'features': 2}
# Trained and Tested combination 1131 of 19200, taking 0.0 seconds to get val score of 0.431:
#                 {'n_neighbors': 1, 'p': 2, 'weights': 'distance', 'features': 1},
#             Current best combo with val score 0.4368:
#                     {'n_neighbors': 1, 'p': 1, 'weights': 'distance', 'features': 2}
# Already Trained and Tested combination (val score of 0.407):
#             {'n_neighbors': 1, 'p': 2, 'weights': 'distance', 'features': 3}
#             Current best combo (with val score 0.4368):
#                     {'n_neighbors': 1, 'p': 1, 'weights': 'distance', 'features': 2}
#         Has trained 1131 of 19200 combinations so far
# Trained and Tested combination 1132 of 19200, taking 0.01 seconds to get val score of 0.4081:
#                 {'n_neighbors': 2, 'p': 1, 'weights': 'uniform', 'features': 2},
#             Current best combo with val score 0.4368:
#                     {'n_neighbors': 1, 'p': 1, 'weights': 'distance', 'features': 2}
# Already Trained and Tested combination (val score of 0.4368):
#             {'n_neighbors': 1, 'p': 2, 'weights': 'uniform', 'features': 2}
#             Current best combo (with val score 0.4368):
#                     {'n_neighbors': 1, 'p': 1, 'weights': 'distance', 'features': 2}
#         Has trained 1132 of 19200 combinations so far
# Already Trained and Tested combination (val score of 0.4368):
#             {'n_neighbors': 1, 'p': 1, 'weights': 'distance', 'features': 2}
#             Current best combo (with val score 0.4368):
#                     {'n_neighbors': 1, 'p': 1, 'weights': 'distance', 'features': 2}
#         Has trained 1132 of 19200 combinations so far
# Trained and Tested combination 1133 of 19200, taking 0.0 seconds to get val score of 0.431:
#                 {'n_neighbors': 1, 'p': 1, 'weights': 'uniform', 'features': 1},
#             Current best combo with val score 0.4368:
#                     {'n_neighbors': 1, 'p': 1, 'weights': 'distance', 'features': 2}
# Already Trained and Tested combination (val score of 0.407):
#             {'n_neighbors': 1, 'p': 1, 'weights': 'uniform', 'features': 3}
#             Current best combo (with val score 0.4368):
#                     {'n_neighbors': 1, 'p': 1, 'weights': 'distance', 'features': 2}
#         Has trained 1133 of 19200 combinations so far
# % Combos Checked Thus Far: 1133 out of 19200 which is 5.901042%
# Max Val Score:
#  0.436772
# Max Val Score Std:
#  0.060618
# Best Combo Train Score:
#  0.820664
# Best Combo Train Score Std:
#  0.007708
# Max Combo Index:
#  (0, 0, 0, 2) out of [100, 2, 2, 48] (note best combo is 0-indexed)
# Max Combo Hyperparamer Combination:
#  {'n_neighbors': 1, 'p': 1, 'weights': 'distance', 'features': 2}
# Max Combo Features:
#  ('procedure_224274', 'lods_score', 'procedure_224276')
# % Combos Checked: 1133 out of 19200 which is 5.901042%
