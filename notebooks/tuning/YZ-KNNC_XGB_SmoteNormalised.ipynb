# %% [markdown]
# # Tuning Script

# %%
# Parameters subject to change in every script - involved in naming

MODEL = 'knnc'
PREPROCESSING = 'smote_normalise'
TUNER = 'yangzhoub'
OPTIMISED_METRIC = 'f1'

# %% [markdown]
# ---

# %%
# detect whether this is a google environment

COLAB_ENVIRONMENT = False

try:
    from google.colab import drive
    drive.mount('/content/drive')
    COLAB_ENVIRONMENT = True
except:
    pass
# Out:
# Mounted at /content/drive

# %%
import sys
import os
import pickle

if COLAB_ENVIRONMENT:
    home_directory = './drive/MyDrive/LAB/COMP90089__GroupWork__Py/' # my home directory is stored in ./LAB of google drive
    if MODEL == 'ebr':
        # !pip install interpret==0.5.0
    elif MODEL == 'cbr':
        # !pip install catboost
    elif MODEL in ['tf', 'mlp']:
        # !pip install PyTorch2Sklearn
    # !pip install JXAutoML
else:
    home_directory = '../../'

from JXAutoML.YangZhouB_10CV import YangZhouB_10CV as Tuner

import pandas as pd
# Out:
# Collecting JXAutoML
#   Downloading JXAutoML-0.4.4-py3-none-any.whl.metadata (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.2/67.2 kB 1.4 MB/s eta 0:00:00
# Downloading JXAutoML-0.4.4-py3-none-any.whl (52 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.1/52.1 kB 3.7 MB/s eta 0:00:00
# Installing collected packages: JXAutoML
# Successfully installed JXAutoML-0.4.4

# %%
# Parameters that are same for every script

FOLDS = 10  # we have decided to do 10 fold validation

SEED = 42

TASK_TYPE = 'Classification'  # this task is a classification task

# we have decided to tune features as hp
TUNE_FEATURES_AS_HYPERPARAMETERS = True

# %% [markdown]
# ---

# %%
# model to use to tune
from sklearn.neighbors import KNeighborsClassifier as clf

# what values to try for each hyperparameter
parameter_choices = {
    'n_neighbors': [i for i in range(1, 101)],
    'p': (1, 2),
    'weights': ('uniform', 'distance')
}

# what values to set non-tuneable parameters/hyperparameters
non_tunable_hyperparameters_dict = {
                                    'n_jobs': -1
                                    }

# %% [markdown]
# ---

# %% [markdown]
# Read in and Prepare Data

# %%
# Import data and store as lists

train_x_list = []
train_y_list = []
val_x_list = []
val_y_list = []

for i in range(FOLDS):
    train_data = pd.read_csv(
        f'{home_directory}data/curated/modelling/{PREPROCESSING}/train_{i}.csv')
    val_data = pd.read_csv(
        f'{home_directory}data/curated/modelling/{PREPROCESSING}/val_{i}.csv')

    # get the correct rows for X and y
    train_x = train_data.drop(
        ['mortality_status', 'subject_id', 'hadm_id', 'stay_id'], axis=1)
    train_y = train_data['mortality_status']
    val_x = val_data.drop(
        ['mortality_status', 'subject_id', 'hadm_id', 'stay_id'], axis=1)
    val_y = val_data['mortality_status']

    train_x_list.append(train_x)
    train_y_list.append(train_y)
    val_x_list.append(val_x)
    val_y_list.append(val_y)

# %%
# Import feature importance ordering

with open(f'{home_directory}models/xgb_feature_importance_ordering_{PREPROCESSING}.pickle', 'rb') as f:
    feature_importance_ordering = pickle.load(f)

# %% [markdown]
# Set parameters

# %%
# initialisation
tuner = Tuner()

print('---')

# define what model we are tuning
tuner.read_in_model(clf, TASK_TYPE, optimised_metric=OPTIMISED_METRIC)

print('---')

# read in the data for training and validation
tuner.read_in_data(train_x_list, train_y_list, val_x_list, val_y_list)

print('---')

# set what hp values to tune
tuner.set_hyperparameters(parameter_choices)
# WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

# set up hp values that need to be changed from default but NOT to be tuned
tuner.set_non_tuneable_hyperparameters(non_tunable_hyperparameters_dict)

print('---')

# set up feature importance ordering

if TUNE_FEATURES_AS_HYPERPARAMETERS:
    tuner.set_features(feature_importance_ordering)
    # WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

try:  # try to read in previous results to continue tuning ...
    tuner.read_in_tuning_result_df(
        f'{home_directory}models/tuning/{TUNER}_{MODEL}_{PREPROCESSING}.csv')
except:
    print('No previous tuning data read in')

print('---')

# set up where to save the tuning result csv
tuner.set_tuning_result_saving_address(
    f'{home_directory}models/tuning/{TUNER}_{MODEL}_{PREPROCESSING}.csv')

print('---')

# set up where to save the current best model
tuner.set_best_model_saving_address(
    f'{home_directory}models/tmp_models/{TUNER}_{MODEL}_{PREPROCESSING}')
# Out:
# YangZhouB Initialised
# ---
# Successfully read in model <class 'sklearn.neighbors._classification.KNeighborsClassifier'>, which is a Classification model optimising for f1
# ---
# Read in Train X data list
# Read in Train y data list
# Read in Val X data list
# Read in Val y data list
# ---
# Successfully recorded hyperparameter choices
# ---
# Successfully recorded non_tuneable_hyperparameter choices
# ---
# Successfully recorded tuneable feature combination choices and updated relevant internal structures
# ---
# Successfully read in tuning result of 1932 rows, for 1932.0 combos
# ---
# Successfully set tuning output address
# ---
# Successfully set best model output address

# %%
# ignore warnings

import warnings
warnings.filterwarnings("ignore")

# %%
# begin tuning ... (or continue training)

tuner.tune()
# Out:
# Streaming output truncated to the last 5000 lines.
# Already Trained and Tested combination (val score of 0.3969):
#             {'n_neighbors': 76, 'p': 2, 'weights': 'distance', 'features': 15}
#             Current best combo (with val score 0.4877):
#                     {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 16}
#         Has trained 2469 of 28800 combinations so far
# Already Trained and Tested combination (val score of 0.4282):
#             {'n_neighbors': 76, 'p': 1, 'weights': 'uniform', 'features': 15}
#             Current best combo (with val score 0.4877):
#                     {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 16}
#         Has trained 2469 of 28800 combinations so far
# Trained and Tested combination 2470 of 28800, taking 0.0 seconds to get val score of 0.3312:
#                 {'n_neighbors': 76, 'p': 1, 'weights': 'distance', 'features': 14},
#             Current best combo with val score 0.4877:
#                     {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 16}
# Already Trained and Tested combination (val score of 0.4711):
#             {'n_neighbors': 76, 'p': 1, 'weights': 'distance', 'features': 16}
#             Current best combo (with val score 0.4877):
#                     {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 16}
#         Has trained 2470 of 28800 combinations so far
# 	round 119 iteration:  1
#
# Trained and Tested combination 2471 of 28800, taking 0.0 seconds to get val score of 0.3926:
#                 {'n_neighbors': 74, 'p': 1, 'weights': 'distance', 'features': 15},
#             Current best combo with val score 0.4877:
#                     {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 16}
# Already Trained and Tested combination (val score of 0.4001):
#             {'n_neighbors': 76, 'p': 1, 'weights': 'distance', 'features': 15}
#             Current best combo (with val score 0.4877):
#                     {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 16}
#         Has trained 2471 of 28800 combinations so far
# Trained and Tested combination 2472 of 28800, taking 0.0 seconds to get val score of 0.3981:
#                 {'n_neighbors': 75, 'p': 2, 'weights': 'distance', 'features': 15},
#             Current best combo with val score 0.4877:
#                     {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 16}
# Already Trained and Tested combination (val score of 0.4268):
#             {'n_neighbors': 75, 'p': 1, 'weights': 'uniform', 'features': 15}
#             Current best combo (with val score 0.4877):
#                     {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 16}
#         Has trained 2472 of 28800 combinations so far
# Trained and Tested combination 2473 of 28800, taking 0.0 seconds to get val score of 0.3329:
#                 {'n_neighbors': 75, 'p': 1, 'weights': 'distance', 'features': 14},
#             Current best combo with val score 0.4877:
#                     {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 16}
# Trained and Tested combination 2474 of 28800, taking 0.0 seconds to get val score of 0.4716:
#                 {'n_neighbors': 75, 'p': 1, 'weights': 'distance', 'features': 16},
#             Current best combo with val score 0.4877:
#                     {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 16}
# Already Trained and Tested combination (val score of 0.4001):
#             {'n_neighbors': 76, 'p': 1, 'weights': 'distance', 'features': 15}
#             Current best combo (with val score 0.4877):
#                     {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 16}
#         Has trained 2474 of 28800 combinations so far
# Trained and Tested combination 2475 of 28800, taking 0.0 seconds to get val score of 0.3992:
#                 {'n_neighbors': 78, 'p': 1, 'weights': 'distance', 'features': 15},
#             Current best combo with val score 0.4877:
#                     {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 16}
# Trained and Tested combination 2476 of 28800, taking 0.01 seconds to get val score of 0.3977:
#                 {'n_neighbors': 77, 'p': 2, 'weights': 'distance', 'features': 15},
#             Current best combo with val score 0.4877:
#                     {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 16}
# Already Trained and Tested combination (val score of 0.428):
#             {'n_neighbors': 77, 'p': 1, 'weights': 'uniform', 'features': 15}
#             Current best combo (with val score 0.4877):
#                     {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 16}
#         Has trained 2476 of 28800 combinations so far
# Trained and Tested combination 2477 of 28800, taking 0.0 seconds to get val score of 0.3302:
#                 {'n_neighbors': 77, 'p': 1, 'weights': 'distance', 'features': 14},
#             Current best combo with val score 0.4877:
#                     {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 16}
# Trained and Tested combination 2478 of 28800, taking 0.01 seconds to get val score of 0.4707:
#                 {'n_neighbors': 77, 'p': 1, 'weights': 'distance', 'features': 16},
#             Current best combo with val score 0.4877:
#                     {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 16}
# Already Trained and Tested combination (val score of 0.3981):
#             {'n_neighbors': 75, 'p': 2, 'weights': 'distance', 'features': 15}
#             Current best combo (with val score 0.4877):
#                     {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 16}
#         Has trained 2478 of 28800 combinations so far
# Already Trained and Tested combination (val score of 0.3977):
#             {'n_neighbors': 77, 'p': 2, 'weights': 'distance', 'features': 15}
#             Current best combo (with val score 0.4877):
#                     {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 16}
#         Has trained 2478 of 28800 combinations so far
# Already Trained and Tested combination (val score of 0.4001):
#             {'n_neighbors': 76, 'p': 1, 'weights': 'distance', 'features': 15}
#             Current best combo (with val score 0.4877):
#                     {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 16}
#         Has trained 2478 of 28800 combinations so far
# Already Trained and Tested combination (val score of 0.4095):
#             {'n_neighbors': 76, 'p': 2, 'weights': 'uniform', 'features': 15}
#             Current best combo (with val score 0.4877):
#                     {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 16}
#         Has trained 2478 of 28800 combinations so far
# Trained and Tested combination 2479 of 28800, taking 0.0 seconds to get val score of 0.3119:
#                 {'n_neighbors': 76, 'p': 2, 'weights': 'distance', 'features': 14},
#             Current best combo with val score 0.4877:
#                     {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 16}
# Trained and Tested combination 2480 of 28800, taking 0.01 seconds to get val score of 0.4689:
#                 {'n_neighbors': 76, 'p': 2, 'weights': 'distance', 'features': 16},
#             Current best combo with val score 0.4877:
#                     {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 16}
# % Combos Checked Thus Far: 2480 out of 28800 which is 8.611111000000001%
# Cruising Coordrdinate 1221 of 1344
#
# Cruise suspended due to suspicious case
# Guidance: round 120
#
# 	round 120 iteration:  0
#
# Already Trained and Tested combination (val score of 0.4145):
#             {'n_neighbors': 75, 'p': 2, 'weights': 'uniform', 'features': 15}
#             Current best combo (with val score 0.4877):
#                     {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 16}
#         Has trained 2480 of 28800 combinations so far
# Already Trained and Tested combination (val score of 0.4167):
#             {'n_neighbors': 77, 'p': 2, 'weights': 'uniform', 'features': 15}
#             Current best combo (with val score 0.4877):
#                     {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 16}
#         Has trained 2480 of 28800 combinations so far
# Already Trained and Tested combination (val score of 0.4282):
#             {'n_neighbors': 76, 'p': 1, 'weights': 'uniform', 'features': 15}
#             Current best combo (with val score 0.4877):
#                     {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 16}
#         Has trained 2480 of 28800 combinations so far
# Already Trained and Tested combination (val score of 0.3969):
#             {'n_neighbors': 76, 'p': 2, 'weights': 'distance', 'features': 15}
#             Current best combo (with val score 0.4877):
#                     {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 16}
#         Has trained 2480 of 28800 combinations so far
# Trained and Tested combination 2481 of 28800, taking 0.0 seconds to get val score of 0.3277:
#                 {'n_neighbors': 76, 'p': 2, 'weights': 'uniform', 'features': 14},
#             Current best combo with val score 0.4877:
#                     {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 16}
# Already Trained and Tested combination (val score of 0.4679):
#             {'n_neighbors': 76, 'p': 2, 'weights': 'uniform', 'features': 16}
#             Current best combo (with val score 0.4877):
#                     {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 16}
#         Has trained 2481 of 28800 combinations so far
# 	round 120 iteration:  1
#
# Trained and Tested combination 2482 of 28800, taking 0.01 seconds to get val score of 0.4061:
#                 {'n_neighbors': 74, 'p': 2, 'weights': 'uniform', 'features': 15},
#             Current best combo with val score 0.4877:
#                     {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 16}
# Already Trained and Tested combination (val score of 0.4095):
#             {'n_neighbors': 76, 'p': 2, 'weights': 'uniform', 'features': 15}
#             Current best combo (with val score 0.4877):
#                     {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 16}
#         Has trained 2482 of 28800 combinations so far
# Already Trained and Tested combination (val score of 0.4268):
#             {'n_neighbors': 75, 'p': 1, 'weights': 'uniform', 'features': 15}
#             Current best combo (with val score 0.4877):
#                     {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 16}
#         Has trained 2482 of 28800 combinations so far
# Already Trained and Tested combination (val score of 0.3981):
#             {'n_neighbors': 75, 'p': 2, 'weights': 'distance', 'features': 15}
#             Current best combo (with val score 0.4877):
#                     {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 16}
#         Has trained 2482 of 28800 combinations so far
# Trained and Tested combination 2483 of 28800, taking 0.0 seconds to get val score of 0.3273:
#                 {'n_neighbors': 75, 'p': 2, 'weights': 'uniform', 'features': 14},
#             Current best combo with val score 0.4877:
#                     {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 16}
# Trained and Tested combination 2484 of 28800, taking 0.01 seconds to get val score of 0.4669:
#                 {'n_neighbors': 75, 'p': 2, 'weights': 'uniform', 'features': 16},
#             Current best combo with val score 0.4877:
#                     {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 16}
# Already Trained and Tested combination (val score of 0.4095):
#             {'n_neighbors': 76, 'p': 2, 'weights': 'uniform', 'features': 15}
#             Current best combo (with val score 0.4877):
#                     {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 16}
#         Has trained 2484 of 28800 combinations so far
# Trained and Tested combination 2485 of 28800, taking 0.0 seconds to get val score of 0.4092:
#                 {'n_neighbors': 78, 'p': 2, 'weights': 'uniform', 'features': 15},
#             Current best combo with val score 0.4877:
#                     {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 16}
# Already Trained and Tested combination (val score of 0.428):
#             {'n_neighbors': 77, 'p': 1, 'weights': 'uniform', 'features': 15}
#             Current best combo (with val score 0.4877):
#                     {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 16}
#         Has trained 2485 of 28800 combinations so far
# Already Trained and Tested combination (val score of 0.3977):
#             {'n_neighbors': 77, 'p': 2, 'weights': 'distance', 'features': 15}
#             Current best combo (with val score 0.4877):
#                     {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 16}
#         Has trained 2485 of 28800 combinations so far
# Trained and Tested combination 2486 of 28800, taking 0.0 seconds to get val score of 0.3367:
#                 {'n_neighbors': 77, 'p': 2, 'weights': 'uniform', 'features': 14},
#             Current best combo with val score 0.4877:
#                     {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 16}
# Trained and Tested combination 2487 of 28800, taking 0.0 seconds to get val score of 0.4673:
#                 {'n_neighbors': 77, 'p': 2, 'weights': 'uniform', 'features': 16},
#             Current best combo with val score 0.4877:
#                     {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 16}
# % Combos Checked Thus Far: 2487 out of 28800 which is 8.635416999999999%
# Cruising Coordrdinate 1222 of 1344
#
# Cruise suspended due to suspicious case
# Guidance: round 121
#
# 	round 121 iteration:  0
#
# % Combos Checked Thus Far: 2487 out of 28800 which is 8.635416999999999%
# Cruising Coordrdinate 1223 of 1344
#
# Cruising Coordrdinate 1224 of 1344
#
# Cruising Coordrdinate 1225 of 1344
#
# Cruise suspended due to suspicious case
# Guidance: round 122
#
# 	round 122 iteration:  0
#
# Trained and Tested combination 2488 of 28800, taking 0.0 seconds to get val score of 0.3086:
#                 {'n_neighbors': 70, 'p': 2, 'weights': 'uniform', 'features': 30},
#             Current best combo with val score 0.4877:
#                     {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 16}
# Trained and Tested combination 2489 of 28800, taking 0.0 seconds to get val score of 0.3086:
#                 {'n_neighbors': 72, 'p': 2, 'weights': 'uniform', 'features': 30},
#             Current best combo with val score 0.4877:
#                     {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 16}
# Already Trained and Tested combination (val score of 0.1295):
#             {'n_neighbors': 71, 'p': 1, 'weights': 'uniform', 'features': 30}
#             Current best combo (with val score 0.4877):
#                     {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 16}
#         Has trained 2489 of 28800 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'n_neighbors': 71, 'p': 2, 'weights': 'distance', 'features': 30}
#             Current best combo (with val score 0.4877):
#                     {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 16}
#         Has trained 2489 of 28800 combinations so far
# Trained and Tested combination 2490 of 28800, taking 0.0 seconds to get val score of 0.3086:
#                 {'n_neighbors': 71, 'p': 2, 'weights': 'uniform', 'features': 29},
#             Current best combo with val score 0.4877:
#                     {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 16}
# Trained and Tested combination 2491 of 28800, taking 0.01 seconds to get val score of 0.3086:
#                 {'n_neighbors': 71, 'p': 2, 'weights': 'uniform', 'features': 31},
#             Current best combo with val score 0.4877:
#                     {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 16}
# 	round 122 iteration:  1
#
# Trained and Tested combination 2492 of 28800, taking 0.0 seconds to get val score of 0.3086:
#                 {'n_neighbors': 69, 'p': 2, 'weights': 'uniform', 'features': 30},
#             Current best combo with val score 0.4877:
#                     {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 16}
# Already Trained and Tested combination (val score of 0.3086):
#             {'n_neighbors': 71, 'p': 2, 'weights': 'uniform', 'features': 30}
#             Current best combo (with val score 0.4877):
#                     {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 16}
#         Has trained 2492 of 28800 combinations so far
# Trained and Tested combination 2493 of 28800, taking 0.0 seconds to get val score of 0.1181:
#                 {'n_neighbors': 70, 'p': 1, 'weights': 'uniform', 'features': 30},
#             Current best combo with val score 0.4877:
#                     {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 16}
# Trained and Tested combination 2494 of 28800, taking 0.01 seconds to get val score of 0.3086:
#                 {'n_neighbors': 70, 'p': 2, 'weights': 'distance', 'features': 30},
#             Current best combo with val score 0.4877:
#                     {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 16}
# Trained and Tested combination 2495 of 28800, taking 0.0 seconds to get val score of 0.3086:
#                 {'n_neighbors': 70, 'p': 2, 'weights': 'uniform', 'features': 29},
#             Current best combo with val score 0.4877:
#                     {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 16}
# Trained and Tested combination 2496 of 28800, taking 0.0 seconds to get val score of 0.3086:
#                 {'n_neighbors': 70, 'p': 2, 'weights': 'uniform', 'features': 31},
#             Current best combo with val score 0.4877:
#                     {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 16}
# Already Trained and Tested combination (val score of 0.3086):
#             {'n_neighbors': 71, 'p': 2, 'weights': 'uniform', 'features': 30}
#             Current best combo (with val score 0.4877):
#                     {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 16}
#         Has trained 2496 of 28800 combinations so far
# Trained and Tested combination 2497 of 28800, taking 0.0 seconds to get val score of 0.3086:
#                 {'n_neighbors': 73, 'p': 2, 'weights': 'uniform', 'features': 30},
#             Current best combo with val score 0.4877:
#                     {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 16}
# Trained and Tested combination 2498 of 28800, taking 0.0 seconds to get val score of 0.1181:
#                 {'n_neighbors': 72, 'p': 1, 'weights': 'uniform', 'features': 30},
#             Current best combo with val score 0.4877:
#                     {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 16}
# Trained and Tested combination 2499 of 28800, taking 0.0 seconds to get val score of 0.3086:
#                 {'n_neighbors': 72, 'p': 2, 'weights': 'distance', 'features': 30},
#             Current best combo with val score 0.4877:
#                     {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 16}
# Trained and Tested combination 2500 of 28800, taking 0.0 seconds to get val score of 0.3086:
#                 {'n_neighbors': 72, 'p': 2, 'weights': 'uniform', 'features': 29},
#             Current best combo with val score 0.4877:
#                     {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 16}
# Trained and Tested combination 2501 of 28800, taking 0.0 seconds to get val score of 0.3086:
#                 {'n_neighbors': 72, 'p': 2, 'weights': 'uniform', 'features': 31},
#             Current best combo with val score 0.4877:
#                     {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 16}
# Already Trained and Tested combination (val score of 0.3086):
#             {'n_neighbors': 70, 'p': 2, 'weights': 'distance', 'features': 30}
#             Current best combo (with val score 0.4877):
#                     {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 16}
#         Has trained 2501 of 28800 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'n_neighbors': 72, 'p': 2, 'weights': 'distance', 'features': 30}
#             Current best combo (with val score 0.4877):
#                     {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 16}
#         Has trained 2501 of 28800 combinations so far
# Already Trained and Tested combination (val score of 0.1564):
#             {'n_neighbors': 71, 'p': 1, 'weights': 'distance', 'features': 30}
#             Current best combo (with val score 0.4877):
#                     {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 16}
#         Has trained 2501 of 28800 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'n_neighbors': 71, 'p': 2, 'weights': 'uniform', 'features': 30}
#             Current best combo (with val score 0.4877):
#                     {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 16}
#         Has trained 2501 of 28800 combinations so far
# Trained and Tested combination 2502 of 28800, taking 0.0 seconds to get val score of 0.3086:
#                 {'n_neighbors': 71, 'p': 2, 'weights': 'distance', 'features': 29},
#             Current best combo with val score 0.4877:
#                     {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 16}
# Trained and Tested combination 2503 of 28800, taking 0.0 seconds to get val score of 0.3086:
#                 {'n_neighbors': 71, 'p': 2, 'weights': 'distance', 'features': 31},
#             Current best combo with val score 0.4877:
#                     {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 16}
# Already Trained and Tested combination (val score of 0.3086):
#             {'n_neighbors': 70, 'p': 2, 'weights': 'uniform', 'features': 29}
#             Current best combo (with val score 0.4877):
#                     {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 16}
#         Has trained 2503 of 28800 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'n_neighbors': 72, 'p': 2, 'weights': 'uniform', 'features': 29}
#             Current best combo (with val score 0.4877):
#                     {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 16}
#         Has trained 2503 of 28800 combinations so far
# Trained and Tested combination 2504 of 28800, taking 0.01 seconds to get val score of 0.1409:
#                 {'n_neighbors': 71, 'p': 1, 'weights': 'uniform', 'features': 29},
#             Current best combo with val score 0.4877:
#                     {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 16}
# Already Trained and Tested combination (val score of 0.3086):
#             {'n_neighbors': 71, 'p': 2, 'weights': 'distance', 'features': 29}
#             Current best combo (with val score 0.4877):
#                     {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 16}
#         Has trained 2504 of 28800 combinations so far
# Trained and Tested combination 2505 of 28800, taking 0.01 seconds to get val score of 0.3086:
#                 {'n_neighbors': 71, 'p': 2, 'weights': 'uniform', 'features': 28},
#             Current best combo with val score 0.4877:
#                     {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 16}
# Already Trained and Tested combination (val score of 0.3086):
#             {'n_neighbors': 71, 'p': 2, 'weights': 'uniform', 'features': 30}
#             Current best combo (with val score 0.4877):
#                     {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 16}
#         Has trained 2505 of 28800 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'n_neighbors': 70, 'p': 2, 'weights': 'uniform', 'features': 31}
#             Current best combo (with val score 0.4877):
#                     {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 16}
#         Has trained 2505 of 28800 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'n_neighbors': 72, 'p': 2, 'weights': 'uniform', 'features': 31}
#             Current best combo (with val score 0.4877):
#                     {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 16}
#         Has trained 2505 of 28800 combinations so far
# Trained and Tested combination 2506 of 28800, taking 0.0 seconds to get val score of 0.0814:
#                 {'n_neighbors': 71, 'p': 1, 'weights': 'uniform', 'features': 31},
#             Current best combo with val score 0.4877:
#                     {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 16}
# Already Trained and Tested combination (val score of 0.3086):
#             {'n_neighbors': 71, 'p': 2, 'weights': 'distance', 'features': 31}
#             Current best combo (with val score 0.4877):
#                     {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 16}
#         Has trained 2506 of 28800 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'n_neighbors': 71, 'p': 2, 'weights': 'uniform', 'features': 30}
#             Current best combo (with val score 0.4877):
#                     {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 16}
#         Has trained 2506 of 28800 combinations so far
# Trained and Tested combination 2507 of 28800, taking 0.0 seconds to get val score of 0.3086:
#                 {'n_neighbors': 71, 'p': 2, 'weights': 'uniform', 'features': 32},
#             Current best combo with val score 0.4877:
#                     {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 16}
# % Combos Checked Thus Far: 2507 out of 28800 which is 8.704861%
# Cruising Coordrdinate 1226 of 1344
#
# Cruise suspended due to suspicious case
# Guidance: round 123
#
# 	round 123 iteration:  0
#
# % Combos Checked Thus Far: 2507 out of 28800 which is 8.704861%
# Cruising Coordrdinate 1227 of 1344
#
# Cruising Coordrdinate 1228 of 1344
#
# Cruising Coordrdinate 1229 of 1344
#
# Cruise suspended due to suspicious case
# Guidance: round 124
#
# 	round 124 iteration:  0
#
# Trained and Tested combination 2508 of 28800, taking 0.01 seconds to get val score of 0.3086:
#                 {'n_neighbors': 65, 'p': 2, 'weights': 'uniform', 'features': 35},
#             Current best combo with val score 0.4877:
#                     {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 16}
# Trained and Tested combination 2509 of 28800, taking 0.0 seconds to get val score of 0.3086:
#                 {'n_neighbors': 67, 'p': 2, 'weights': 'uniform', 'features': 35},
#             Current best combo with val score 0.4877:
#                     {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 16}
# Already Trained and Tested combination (val score of 0.0225):
#             {'n_neighbors': 66, 'p': 1, 'weights': 'uniform', 'features': 35}
#             Current best combo (with val score 0.4877):
#                     {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 16}
#         Has trained 2509 of 28800 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'n_neighbors': 66, 'p': 2, 'weights': 'distance', 'features': 35}
#             Current best combo (with val score 0.4877):
#                     {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 16}
#         Has trained 2509 of 28800 combinations so far
# Trained and Tested combination 2510 of 28800, taking 0.01 seconds to get val score of 0.3086:
#                 {'n_neighbors': 66, 'p': 2, 'weights': 'uniform', 'features': 34},
#             Current best combo with val score 0.4877:
#                     {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 16}
# Trained and Tested combination 2511 of 28800, taking 0.0 seconds to get val score of 0.3086:
#                 {'n_neighbors': 66, 'p': 2, 'weights': 'uniform', 'features': 36},
#             Current best combo with val score 0.4877:
#                     {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 16}
# 	round 124 iteration:  1
#
# Trained and Tested combination 2512 of 28800, taking 0.0 seconds to get val score of 0.3086:
#                 {'n_neighbors': 64, 'p': 2, 'weights': 'uniform', 'features': 35},
#             Current best combo with val score 0.4877:
#                     {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 16}
# Already Trained and Tested combination (val score of 0.3086):
#             {'n_neighbors': 66, 'p': 2, 'weights': 'uniform', 'features': 35}
#             Current best combo (with val score 0.4877):
#                     {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 16}
#         Has trained 2512 of 28800 combinations so far
# Trained and Tested combination 2513 of 28800, taking 0.0 seconds to get val score of 0.0256:
#                 {'n_neighbors': 65, 'p': 1, 'weights': 'uniform', 'features': 35},
#             Current best combo with val score 0.4877:
#                     {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 16}
# Trained and Tested combination 2514 of 28800, taking 0.01 seconds to get val score of 0.3086:
#                 {'n_neighbors': 65, 'p': 2, 'weights': 'distance', 'features': 35},
#             Current best combo with val score 0.4877:
#                     {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 16}
# Trained and Tested combination 2515 of 28800, taking 0.0 seconds to get val score of 0.3086:
#                 {'n_neighbors': 65, 'p': 2, 'weights': 'uniform', 'features': 34},
#             Current best combo with val score 0.4877:
#                     {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 16}
# Trained and Tested combination 2516 of 28800, taking 0.01 seconds to get val score of 0.3086:
#                 {'n_neighbors': 65, 'p': 2, 'weights': 'uniform', 'features': 36},
#             Current best combo with val score 0.4877:
#                     {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 16}
# Already Trained and Tested combination (val score of 0.3086):
#             {'n_neighbors': 66, 'p': 2, 'weights': 'uniform', 'features': 35}
#             Current best combo (with val score 0.4877):
#                     {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 16}
#         Has trained 2516 of 28800 combinations so far
# Trained and Tested combination 2517 of 28800, taking 0.0 seconds to get val score of 0.3086:
#                 {'n_neighbors': 68, 'p': 2, 'weights': 'uniform', 'features': 35},
#             Current best combo with val score 0.4877:
#                     {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 16}
# Trained and Tested combination 2518 of 28800, taking 0.0 seconds to get val score of 0.0289:
#                 {'n_neighbors': 67, 'p': 1, 'weights': 'uniform', 'features': 35},
#             Current best combo with val score 0.4877:
#                     {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 16}
# Trained and Tested combination 2519 of 28800, taking 0.0 seconds to get val score of 0.3086:
#                 {'n_neighbors': 67, 'p': 2, 'weights': 'distance', 'features': 35},
#             Current best combo with val score 0.4877:
#                     {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 16}
# Trained and Tested combination 2520 of 28800, taking 0.01 seconds to get val score of 0.3086:
#                 {'n_neighbors': 67, 'p': 2, 'weights': 'uniform', 'features': 34},
#             Current best combo with val score 0.4877:
#                     {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 16}
# Trained and Tested combination 2521 of 28800, taking 0.0 seconds to get val score of 0.3086:
#                 {'n_neighbors': 67, 'p': 2, 'weights': 'uniform', 'features': 36},
#             Current best combo with val score 0.4877:
#                     {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 16}
# Already Trained and Tested combination (val score of 0.3086):
#             {'n_neighbors': 65, 'p': 2, 'weights': 'distance', 'features': 35}
#             Current best combo (with val score 0.4877):
#                     {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 16}
#         Has trained 2521 of 28800 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'n_neighbors': 67, 'p': 2, 'weights': 'distance', 'features': 35}
#             Current best combo (with val score 0.4877):
#                     {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 16}
#         Has trained 2521 of 28800 combinations so far
# Already Trained and Tested combination (val score of 0.0289):
#             {'n_neighbors': 66, 'p': 1, 'weights': 'distance', 'features': 35}
#             Current best combo (with val score 0.4877):
#                     {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 16}
#         Has trained 2521 of 28800 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'n_neighbors': 66, 'p': 2, 'weights': 'uniform', 'features': 35}
#             Current best combo (with val score 0.4877):
#                     {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 16}
#         Has trained 2521 of 28800 combinations so far
# Trained and Tested combination 2522 of 28800, taking 0.01 seconds to get val score of 0.3086:
#                 {'n_neighbors': 66, 'p': 2, 'weights': 'distance', 'features': 34},
#             Current best combo with val score 0.4877:
#                     {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 16}
# Trained and Tested combination 2523 of 28800, taking 0.0 seconds to get val score of 0.3086:
#                 {'n_neighbors': 66, 'p': 2, 'weights': 'distance', 'features': 36},
#             Current best combo with val score 0.4877:
#                     {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 16}
# Already Trained and Tested combination (val score of 0.3086):
#             {'n_neighbors': 65, 'p': 2, 'weights': 'uniform', 'features': 34}
#             Current best combo (with val score 0.4877):
#                     {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 16}
#         Has trained 2523 of 28800 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'n_neighbors': 67, 'p': 2, 'weights': 'uniform', 'features': 34}
#             Current best combo (with val score 0.4877):
#                     {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 16}
#         Has trained 2523 of 28800 combinations so far
# Trained and Tested combination 2524 of 28800, taking 0.0 seconds to get val score of 0.0448:
#                 {'n_neighbors': 66, 'p': 1, 'weights': 'uniform', 'features': 34},
#             Current best combo with val score 0.4877:
#                     {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 16}
# Already Trained and Tested combination (val score of 0.3086):
#             {'n_neighbors': 66, 'p': 2, 'weights': 'distance', 'features': 34}
#             Current best combo (with val score 0.4877):
#                     {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 16}
#         Has trained 2524 of 28800 combinations so far
# Trained and Tested combination 2525 of 28800, taking 0.01 seconds to get val score of 0.3086:
#                 {'n_neighbors': 66, 'p': 2, 'weights': 'uniform', 'features': 33},
#             Current best combo with val score 0.4877:
#                     {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 16}
# Already Trained and Tested combination (val score of 0.3086):
#             {'n_neighbors': 66, 'p': 2, 'weights': 'uniform', 'features': 35}
#             Current best combo (with val score 0.4877):
#                     {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 16}
#         Has trained 2525 of 28800 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'n_neighbors': 65, 'p': 2, 'weights': 'uniform', 'features': 36}
#             Current best combo (with val score 0.4877):
#                     {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 16}
#         Has trained 2525 of 28800 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'n_neighbors': 67, 'p': 2, 'weights': 'uniform', 'features': 36}
#             Current best combo (with val score 0.4877):
#                     {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 16}
#         Has trained 2525 of 28800 combinations so far
# Trained and Tested combination 2526 of 28800, taking 0.01 seconds to get val score of 0.01:
#                 {'n_neighbors': 66, 'p': 1, 'weights': 'uniform', 'features': 36},
#             Current best combo with val score 0.4877:
#                     {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 16}
# Already Trained and Tested combination (val score of 0.3086):
#             {'n_neighbors': 66, 'p': 2, 'weights': 'distance', 'features': 36}
#             Current best combo (with val score 0.4877):
#                     {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 16}
#         Has trained 2526 of 28800 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'n_neighbors': 66, 'p': 2, 'weights': 'uniform', 'features': 35}
#             Current best combo (with val score 0.4877):
#                     {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 16}
#         Has trained 2526 of 28800 combinations so far
# Trained and Tested combination 2527 of 28800, taking 0.0 seconds to get val score of 0.3172:
#                 {'n_neighbors': 66, 'p': 2, 'weights': 'uniform', 'features': 37},
#             Current best combo with val score 0.4877:
#                     {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 16}
# % Combos Checked Thus Far: 2527 out of 28800 which is 8.774306%
# Cruising Coordrdinate 1230 of 1344
#
# Cruise suspended due to suspicious case
# Guidance: round 125
#
# 	round 125 iteration:  0
#
# % Combos Checked Thus Far: 2527 out of 28800 which is 8.774306%
# Cruising Coordrdinate 1231 of 1344
#
# Cruising Coordrdinate 1232 of 1344
#
# Cruising Coordrdinate 1233 of 1344
#
# Cruising Coordrdinate 1234 of 1344
#
# Cruising Coordrdinate 1235 of 1344
#
# Cruising Coordrdinate 1236 of 1344
#
# Cruising Coordrdinate 1237 of 1344
#
# Cruising Coordrdinate 1238 of 1344
#
# Cruising Coordrdinate 1239 of 1344
#
# Cruising Coordrdinate 1240 of 1344
#
# Cruising Coordrdinate 1241 of 1344
#
# Cruising Coordrdinate 1242 of 1344
#
# Cruising Coordrdinate 1243 of 1344
#
# Cruising Coordrdinate 1244 of 1344
#
# Cruising Coordrdinate 1245 of 1344
#
# Cruise suspended due to suspicious case
# Guidance: round 126
#
# 	round 126 iteration:  0
#
# Trained and Tested combination 2528 of 28800, taking 0.0 seconds to get val score of 0.3086:
#                 {'n_neighbors': 60, 'p': 2, 'weights': 'uniform', 'features': 35},
#             Current best combo with val score 0.4877:
#                     {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 16}
# Trained and Tested combination 2529 of 28800, taking 0.01 seconds to get val score of 0.3086:
#                 {'n_neighbors': 62, 'p': 2, 'weights': 'uniform', 'features': 35},
#             Current best combo with val score 0.4877:
#                     {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 16}
# Already Trained and Tested combination (val score of 0.0256):
#             {'n_neighbors': 61, 'p': 1, 'weights': 'uniform', 'features': 35}
#             Current best combo (with val score 0.4877):
#                     {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 16}
#         Has trained 2529 of 28800 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'n_neighbors': 61, 'p': 2, 'weights': 'distance', 'features': 35}
#             Current best combo (with val score 0.4877):
#                     {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 16}
#         Has trained 2529 of 28800 combinations so far
# Trained and Tested combination 2530 of 28800, taking 0.0 seconds to get val score of 0.3086:
#                 {'n_neighbors': 61, 'p': 2, 'weights': 'uniform', 'features': 34},
#             Current best combo with val score 0.4877:
#                     {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 16}
# Trained and Tested combination 2531 of 28800, taking 0.01 seconds to get val score of 0.3086:
#                 {'n_neighbors': 61, 'p': 2, 'weights': 'uniform', 'features': 36},
#             Current best combo with val score 0.4877:
#                     {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 16}
# 	round 126 iteration:  1
#
# Trained and Tested combination 2532 of 28800, taking 0.0 seconds to get val score of 0.3086:
#                 {'n_neighbors': 59, 'p': 2, 'weights': 'uniform', 'features': 35},
#             Current best combo with val score 0.4877:
#                     {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 16}
# Already Trained and Tested combination (val score of 0.3086):
#             {'n_neighbors': 61, 'p': 2, 'weights': 'uniform', 'features': 35}
#             Current best combo (with val score 0.4877):
#                     {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 16}
#         Has trained 2532 of 28800 combinations so far
# Trained and Tested combination 2533 of 28800, taking 0.0 seconds to get val score of 0.0226:
#                 {'n_neighbors': 60, 'p': 1, 'weights': 'uniform', 'features': 35},
#             Current best combo with val score 0.4877:
#                     {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 16}
# Trained and Tested combination 2534 of 28800, taking 0.01 seconds to get val score of 0.3086:
#                 {'n_neighbors': 60, 'p': 2, 'weights': 'distance', 'features': 35},
#             Current best combo with val score 0.4877:
#                     {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 16}
# Trained and Tested combination 2535 of 28800, taking 0.0 seconds to get val score of 0.3086:
#                 {'n_neighbors': 60, 'p': 2, 'weights': 'uniform', 'features': 34},
#             Current best combo with val score 0.4877:
#                     {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 16}
# Trained and Tested combination 2536 of 28800, taking 0.0 seconds to get val score of 0.3086:
#                 {'n_neighbors': 60, 'p': 2, 'weights': 'uniform', 'features': 36},
#             Current best combo with val score 0.4877:
#                     {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 16}
# Already Trained and Tested combination (val score of 0.3086):
#             {'n_neighbors': 61, 'p': 2, 'weights': 'uniform', 'features': 35}
#             Current best combo (with val score 0.4877):
#                     {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 16}
#         Has trained 2536 of 28800 combinations so far
# Trained and Tested combination 2537 of 28800, taking 0.0 seconds to get val score of 0.3086:
#                 {'n_neighbors': 63, 'p': 2, 'weights': 'uniform', 'features': 35},
#             Current best combo with val score 0.4877:
#                     {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 16}
# Trained and Tested combination 2538 of 28800, taking 0.0 seconds to get val score of 0.0257:
#                 {'n_neighbors': 62, 'p': 1, 'weights': 'uniform', 'features': 35},
#             Current best combo with val score 0.4877:
#                     {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 16}
# Trained and Tested combination 2539 of 28800, taking 0.0 seconds to get val score of 0.3086:
#                 {'n_neighbors': 62, 'p': 2, 'weights': 'distance', 'features': 35},
#             Current best combo with val score 0.4877:
#                     {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 16}
# Trained and Tested combination 2540 of 28800, taking 0.01 seconds to get val score of 0.3086:
#                 {'n_neighbors': 62, 'p': 2, 'weights': 'uniform', 'features': 34},
#             Current best combo with val score 0.4877:
#                     {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 16}
# Trained and Tested combination 2541 of 28800, taking 0.0 seconds to get val score of 0.3087:
#                 {'n_neighbors': 62, 'p': 2, 'weights': 'uniform', 'features': 36},
#             Current best combo with val score 0.4877:
#                     {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 16}
# Already Trained and Tested combination (val score of 0.3086):
#             {'n_neighbors': 60, 'p': 2, 'weights': 'distance', 'features': 35}
#             Current best combo (with val score 0.4877):
#                     {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 16}
#         Has trained 2541 of 28800 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'n_neighbors': 62, 'p': 2, 'weights': 'distance', 'features': 35}
#             Current best combo (with val score 0.4877):
#                     {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 16}
#         Has trained 2541 of 28800 combinations so far
# Already Trained and Tested combination (val score of 0.0286):
#             {'n_neighbors': 61, 'p': 1, 'weights': 'distance', 'features': 35}
#             Current best combo (with val score 0.4877):
#                     {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 16}
#         Has trained 2541 of 28800 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'n_neighbors': 61, 'p': 2, 'weights': 'uniform', 'features': 35}
#             Current best combo (with val score 0.4877):
#                     {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 16}
#         Has trained 2541 of 28800 combinations so far
# Trained and Tested combination 2542 of 28800, taking 0.01 seconds to get val score of 0.3086:
#                 {'n_neighbors': 61, 'p': 2, 'weights': 'distance', 'features': 34},
#             Current best combo with val score 0.4877:
#                     {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 16}
# Trained and Tested combination 2543 of 28800, taking 0.0 seconds to get val score of 0.3086:
#                 {'n_neighbors': 61, 'p': 2, 'weights': 'distance', 'features': 36},
#             Current best combo with val score 0.4877:
#                     {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 16}
# Already Trained and Tested combination (val score of 0.3086):
#             {'n_neighbors': 60, 'p': 2, 'weights': 'uniform', 'features': 34}
#             Current best combo (with val score 0.4877):
#                     {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 16}
#         Has trained 2543 of 28800 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'n_neighbors': 62, 'p': 2, 'weights': 'uniform', 'features': 34}
#             Current best combo (with val score 0.4877):
#                     {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 16}
#         Has trained 2543 of 28800 combinations so far
# Trained and Tested combination 2544 of 28800, taking 0.01 seconds to get val score of 0.0477:
#                 {'n_neighbors': 61, 'p': 1, 'weights': 'uniform', 'features': 34},
#             Current best combo with val score 0.4877:
#                     {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 16}
# ...
#                     {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 16}
#         Has trained 2974 of 28800 combinations so far
# Already Trained and Tested combination (val score of 0.3721):
#             {'n_neighbors': 56, 'p': 2, 'weights': 'uniform', 'features': 15}
#             Current best combo (with val score 0.4877):
#                     {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 16}
#         Has trained 2974 of 28800 combinations so far
# Trained and Tested combination 2975 of 28800, taking 0.0 seconds to get val score of 0.3047:
#                 {'n_neighbors': 56, 'p': 2, 'weights': 'distance', 'features': 14},
#             Current best combo with val score 0.4877:
#                     {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 16}
# Trained and Tested combination 2976 of 28800, taking 0.0 seconds to get val score of 0.4763:
#                 {'n_neighbors': 56, 'p': 2, 'weights': 'distance', 'features': 16},
#             Current best combo with val score 0.4877:
#                     {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 16}
# % Combos Checked Thus Far: 2976 out of 28800 which is 10.333333%
# Cruising Coordrdinate 1342 of 1344
#
# Cruise suspended due to suspicious case
# Guidance: round 175
#
# 	round 175 iteration:  0
#
# % Combos Checked Thus Far: 2976 out of 28800 which is 10.333333%
# Cruising Coordrdinate 1343 of 1344
#
# Cruise suspended due to suspicious case
# Guidance: round 176
#
# 	round 176 iteration:  0
#
# Trained and Tested combination 2977 of 28800, taking 0.01 seconds to get val score of 0.3797:
#                 {'n_neighbors': 50, 'p': 1, 'weights': 'distance', 'features': 15},
#             Current best combo with val score 0.4877:
#                     {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 16}
# Trained and Tested combination 2978 of 28800, taking 0.0 seconds to get val score of 0.3765:
#                 {'n_neighbors': 52, 'p': 1, 'weights': 'distance', 'features': 15},
#             Current best combo with val score 0.4877:
#                     {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 16}
# Already Trained and Tested combination (val score of 0.3633):
#             {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 15}
#             Current best combo (with val score 0.4877):
#                     {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 16}
#         Has trained 2978 of 28800 combinations so far
# Already Trained and Tested combination (val score of 0.4124):
#             {'n_neighbors': 51, 'p': 1, 'weights': 'uniform', 'features': 15}
#             Current best combo (with val score 0.4877):
#                     {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 16}
#         Has trained 2978 of 28800 combinations so far
# Trained and Tested combination 2979 of 28800, taking 0.0 seconds to get val score of 0.3132:
#                 {'n_neighbors': 51, 'p': 1, 'weights': 'distance', 'features': 14},
#             Current best combo with val score 0.4877:
#                     {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 16}
# Already Trained and Tested combination (val score of 0.4707):
#             {'n_neighbors': 51, 'p': 1, 'weights': 'distance', 'features': 16}
#             Current best combo (with val score 0.4877):
#                     {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 16}
#         Has trained 2979 of 28800 combinations so far
# 	round 176 iteration:  1
#
# Trained and Tested combination 2980 of 28800, taking 0.0 seconds to get val score of 0.3811:
#                 {'n_neighbors': 49, 'p': 1, 'weights': 'distance', 'features': 15},
#             Current best combo with val score 0.4877:
#                     {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 16}
# Already Trained and Tested combination (val score of 0.3786):
#             {'n_neighbors': 51, 'p': 1, 'weights': 'distance', 'features': 15}
#             Current best combo (with val score 0.4877):
#                     {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 16}
#         Has trained 2980 of 28800 combinations so far
# Trained and Tested combination 2981 of 28800, taking 0.0 seconds to get val score of 0.3545:
#                 {'n_neighbors': 50, 'p': 2, 'weights': 'distance', 'features': 15},
#             Current best combo with val score 0.4877:
#                     {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 16}
# Already Trained and Tested combination (val score of 0.3875):
#             {'n_neighbors': 50, 'p': 1, 'weights': 'uniform', 'features': 15}
#             Current best combo (with val score 0.4877):
#                     {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 16}
#         Has trained 2981 of 28800 combinations so far
# Trained and Tested combination 2982 of 28800, taking 0.0 seconds to get val score of 0.3241:
#                 {'n_neighbors': 50, 'p': 1, 'weights': 'distance', 'features': 14},
#             Current best combo with val score 0.4877:
#                     {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 16}
# Trained and Tested combination 2983 of 28800, taking 0.0 seconds to get val score of 0.4735:
#                 {'n_neighbors': 50, 'p': 1, 'weights': 'distance', 'features': 16},
#             Current best combo with val score 0.4877:
#                     {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 16}
# Already Trained and Tested combination (val score of 0.3786):
#             {'n_neighbors': 51, 'p': 1, 'weights': 'distance', 'features': 15}
#             Current best combo (with val score 0.4877):
#                     {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 16}
#         Has trained 2983 of 28800 combinations so far
# Trained and Tested combination 2984 of 28800, taking 0.0 seconds to get val score of 0.3881:
#                 {'n_neighbors': 53, 'p': 1, 'weights': 'distance', 'features': 15},
#             Current best combo with val score 0.4877:
#                     {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 16}
# Trained and Tested combination 2985 of 28800, taking 0.0 seconds to get val score of 0.3549:
#                 {'n_neighbors': 52, 'p': 2, 'weights': 'distance', 'features': 15},
#             Current best combo with val score 0.4877:
#                     {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 16}
# Already Trained and Tested combination (val score of 0.401):
#             {'n_neighbors': 52, 'p': 1, 'weights': 'uniform', 'features': 15}
#             Current best combo (with val score 0.4877):
#                     {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 16}
#         Has trained 2985 of 28800 combinations so far
# Trained and Tested combination 2986 of 28800, taking 0.0 seconds to get val score of 0.3142:
#                 {'n_neighbors': 52, 'p': 1, 'weights': 'distance', 'features': 14},
#             Current best combo with val score 0.4877:
#                     {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 16}
# Trained and Tested combination 2987 of 28800, taking 0.0 seconds to get val score of 0.4681:
#                 {'n_neighbors': 52, 'p': 1, 'weights': 'distance', 'features': 16},
#             Current best combo with val score 0.4877:
#                     {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 16}
# % Combos Checked Thus Far: 2987 out of 28800 which is 10.371528000000001%
# Cruising Coordrdinate 1344 of 1344
#
# Cruise suspended due to suspicious case
# Guidance: round 177
#
# 	round 177 iteration:  0
#
# Already Trained and Tested combination (val score of 0.3545):
#             {'n_neighbors': 50, 'p': 2, 'weights': 'distance', 'features': 15}
#             Current best combo (with val score 0.4877):
#                     {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 16}
#         Has trained 2987 of 28800 combinations so far
# Already Trained and Tested combination (val score of 0.3549):
#             {'n_neighbors': 52, 'p': 2, 'weights': 'distance', 'features': 15}
#             Current best combo (with val score 0.4877):
#                     {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 16}
#         Has trained 2987 of 28800 combinations so far
# Already Trained and Tested combination (val score of 0.3786):
#             {'n_neighbors': 51, 'p': 1, 'weights': 'distance', 'features': 15}
#             Current best combo (with val score 0.4877):
#                     {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 16}
#         Has trained 2987 of 28800 combinations so far
# Already Trained and Tested combination (val score of 0.3857):
#             {'n_neighbors': 51, 'p': 2, 'weights': 'uniform', 'features': 15}
#             Current best combo (with val score 0.4877):
#                     {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 16}
#         Has trained 2987 of 28800 combinations so far
# Trained and Tested combination 2988 of 28800, taking 0.0 seconds to get val score of 0.2886:
#                 {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 14},
#             Current best combo with val score 0.4877:
#                     {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 16}
# Already Trained and Tested combination (val score of 0.4877):
#             {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 16}
#             Current best combo (with val score 0.4877):
#                     {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 16}
#         Has trained 2988 of 28800 combinations so far
# 	round 177 iteration:  1
#
# Trained and Tested combination 2989 of 28800, taking 0.0 seconds to get val score of 0.3692:
#                 {'n_neighbors': 50, 'p': 2, 'weights': 'uniform', 'features': 15},
#             Current best combo with val score 0.4877:
#                     {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 16}
# Trained and Tested combination 2990 of 28800, taking 0.0 seconds to get val score of 0.3735:
#                 {'n_neighbors': 52, 'p': 2, 'weights': 'uniform', 'features': 15},
#             Current best combo with val score 0.4877:
#                     {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 16}
# Already Trained and Tested combination (val score of 0.4124):
#             {'n_neighbors': 51, 'p': 1, 'weights': 'uniform', 'features': 15}
#             Current best combo (with val score 0.4877):
#                     {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 16}
#         Has trained 2990 of 28800 combinations so far
# Already Trained and Tested combination (val score of 0.3633):
#             {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 15}
#             Current best combo (with val score 0.4877):
#                     {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 16}
#         Has trained 2990 of 28800 combinations so far
# Trained and Tested combination 2991 of 28800, taking 0.0 seconds to get val score of 0.3066:
#                 {'n_neighbors': 51, 'p': 2, 'weights': 'uniform', 'features': 14},
#             Current best combo with val score 0.4877:
#                     {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 16}
# Already Trained and Tested combination (val score of 0.4841):
#             {'n_neighbors': 51, 'p': 2, 'weights': 'uniform', 'features': 16}
#             Current best combo (with val score 0.4877):
#                     {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 16}
#         Has trained 2991 of 28800 combinations so far
# Already Trained and Tested combination (val score of 0.4866):
#             {'n_neighbors': 50, 'p': 2, 'weights': 'distance', 'features': 16}
#             Current best combo (with val score 0.4877):
#                     {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 16}
#         Has trained 2991 of 28800 combinations so far
# Already Trained and Tested combination (val score of 0.4852):
#             {'n_neighbors': 52, 'p': 2, 'weights': 'distance', 'features': 16}
#             Current best combo (with val score 0.4877):
#                     {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 16}
#         Has trained 2991 of 28800 combinations so far
# Already Trained and Tested combination (val score of 0.4707):
#             {'n_neighbors': 51, 'p': 1, 'weights': 'distance', 'features': 16}
#             Current best combo (with val score 0.4877):
#                     {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 16}
#         Has trained 2991 of 28800 combinations so far
# Already Trained and Tested combination (val score of 0.4841):
#             {'n_neighbors': 51, 'p': 2, 'weights': 'uniform', 'features': 16}
#             Current best combo (with val score 0.4877):
#                     {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 16}
#         Has trained 2991 of 28800 combinations so far
# Already Trained and Tested combination (val score of 0.3633):
#             {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 15}
#             Current best combo (with val score 0.4877):
#                     {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 16}
#         Has trained 2991 of 28800 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 17}
#             Current best combo (with val score 0.4877):
#                     {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 16}
#         Has trained 2991 of 28800 combinations so far
# % Combos Checked Thus Far: 2991 out of 28800 which is 10.385417%
# FINAL STAGE: Begin final Guidance system
#
#
# Guidance: round FINAL
#
# 	round FINAL iteration:  0
#
# % Combos Checked Thus Far: 2991 out of 28800 which is 10.385417%
# Max Val Score:
#  0.487706
# Max Val Score Std:
#  0.034748
# Best Combo Train Score:
#  1.0
# Best Combo Train Score Std:
#  0.0
# Max Combo Index:
#  (50, 1, 0, 16) out of [100, 2, 2, 72] (note best combo is 0-indexed)
# Max Combo Hyperparamer Combination:
#  {'n_neighbors': 51, 'p': 2, 'weights': 'distance', 'features': 16}
# Max Combo Features:
#  ('procedure_225469', 'lods_score', 'procedure_224274', 'marital_status_0', 'marital_status_DIVORCED', 'marital_status_MARRIED', 'marital_status_WIDOWED', 'marital_status_SINGLE', 'procedure_223253', 'race_AMERICAN INDIAN/ALASKA NATIVE', 'race_ASIAN', 'race_ASIAN - ASIAN INDIAN', 'race_ASIAN - CHINESE', 'race_ASIAN - KOREAN', 'race_ASIAN - SOUTH EAST ASIAN', 'race_BLACK/AFRICAN', 'race_BLACK/AFRICAN AMERICAN', 'race_BLACK/CAPE VERDEAN', 'race_BLACK/CARIBBEAN ISLAND', 'race_HISPANIC OR LATINO', 'race_HISPANIC/LATINO - CENTRAL AMERICAN', 'race_HISPANIC/LATINO - COLUMBIAN', 'race_HISPANIC/LATINO - CUBAN', 'race_HISPANIC/LATINO - DOMINICAN', 'race_HISPANIC/LATINO - GUATEMALAN', 'race_HISPANIC/LATINO - HONDURAN', 'race_HISPANIC/LATINO - MEXICAN', 'race_HISPANIC/LATINO - PUERTO RICAN', 'race_HISPANIC/LATINO - SALVADORAN', 'race_MULTIPLE RACE/ETHNICITY', 'race_NATIVE HAWAIIAN OR OTHER PACIFIC ISLANDER', 'race_OTHER', 'race_PATIENT DECLINED TO ANSWER', 'race_PORTUGUESE', 'race_SOUTH AMERICAN', 'race_UNABLE TO OBTAIN', 'race_UNKNOWN', 'race_WHITE', 'race_WHITE - BRAZILIAN', 'race_WHITE - EASTERN EUROPEAN', 'race_WHITE - RUSSIAN', 'race_WHITE - OTHER EUROPEAN', 'procedure_227712', 'procedure_224276', 'admission_type_DIRECT OBSERVATION', 'admission_type_ELECTIVE', 'admission_type_EU OBSERVATION', 'admission_type_EW EMER.', 'admission_type_OBSERVATION ADMIT', 'admission_type_SURGICAL SAME DAY ADMISSION', 'admission_type_URGENT', 'admission_type_DIRECT EMER.', 'insurance_Medicare', 'insurance_Other', 'insurance_Medicaid', 'procedure_225792', 'procedure_228130', 'procedure_225817', 'procedure_224267', 'gender_F', 'gender_M', 'ventilation_used', 'hospital_stay_duration')
# % Combos Checked: 2991 out of 28800 which is 10.385417%
