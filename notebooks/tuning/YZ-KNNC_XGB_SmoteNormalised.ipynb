# %% [markdown]
# # Tuning Script

# %%
# Parameters subject to change in every script - involved in naming

MODEL = 'knnc'
PREPROCESSING = 'smote_normalise'
TUNER = 'yangzhoub'
OPTIMISED_METRIC = 'f1'

# %% [markdown]
# ---

# %%
# detect whether this is a google environment

COLAB_ENVIRONMENT = False

try:
    from google.colab import drive
    drive.mount('/content/drive')
    COLAB_ENVIRONMENT = True
except:
    pass
# Out:
# Mounted at /content/drive

# %%
import sys
import os
import pickle

if COLAB_ENVIRONMENT:
    home_directory = './drive/MyDrive/LAB/COMP90089__GroupWork__Py/' # my home directory is stored in ./LAB of google drive
    if MODEL == 'ebr':
        # !pip install interpret==0.5.0
    elif MODEL == 'cbr':
        # !pip install catboost
    elif MODEL in ['tf', 'mlp']:
        # !pip install PyTorch2Sklearn
    # !pip install JXAutoML
else:
    home_directory = '../../'

from JXAutoML.YangZhouB_10CV import YangZhouB_10CV as Tuner

import pandas as pd
# Out:
# Collecting JXAutoML
#   Downloading JXAutoML-0.4.4-py3-none-any.whl.metadata (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.2/67.2 kB 1.4 MB/s eta 0:00:00
# Downloading JXAutoML-0.4.4-py3-none-any.whl (52 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.1/52.1 kB 3.7 MB/s eta 0:00:00
# Installing collected packages: JXAutoML
# Successfully installed JXAutoML-0.4.4

# %%
# Parameters that are same for every script

FOLDS = 10  # we have decided to do 10 fold validation

SEED = 42

TASK_TYPE = 'Classification'  # this task is a classification task

# we have decided to tune features as hp
TUNE_FEATURES_AS_HYPERPARAMETERS = True

# %% [markdown]
# ---

# %%
# model to use to tune
from sklearn.neighbors import KNeighborsClassifier as clf

# what values to try for each hyperparameter
parameter_choices = {
    'n_neighbors': [i for i in range(1, 101)],
    'p': (1, 2),
    'weights': ('uniform', 'distance')
}

# what values to set non-tuneable parameters/hyperparameters
non_tunable_hyperparameters_dict = {
                                    'n_jobs': -1
                                    }

# %% [markdown]
# ---

# %% [markdown]
# Read in and Prepare Data

# %%
# Import data and store as lists

train_x_list = []
train_y_list = []
val_x_list = []
val_y_list = []

for i in range(FOLDS):
    train_data = pd.read_csv(
        f'{home_directory}data/curated/modelling/{PREPROCESSING}/train_{i}.csv')
    val_data = pd.read_csv(
        f'{home_directory}data/curated/modelling/{PREPROCESSING}/val_{i}.csv')

    # get the correct rows for X and y
    train_x = train_data.drop(
        ['mortality_status', 'subject_id', 'hadm_id', 'stay_id'], axis=1)
    train_y = train_data['mortality_status']
    val_x = val_data.drop(
        ['mortality_status', 'subject_id', 'hadm_id', 'stay_id'], axis=1)
    val_y = val_data['mortality_status']

    train_x_list.append(train_x)
    train_y_list.append(train_y)
    val_x_list.append(val_x)
    val_y_list.append(val_y)

# %%
# Import feature importance ordering

with open(f'{home_directory}models/xgb_feature_importance_ordering_{PREPROCESSING}.pickle', 'rb') as f:
    feature_importance_ordering = pickle.load(f)

# %% [markdown]
# Set parameters

# %%
# initialisation
tuner = Tuner()

print('---')

# define what model we are tuning
tuner.read_in_model(clf, TASK_TYPE, optimised_metric=OPTIMISED_METRIC)

print('---')

# read in the data for training and validation
tuner.read_in_data(train_x_list, train_y_list, val_x_list, val_y_list)

print('---')

# set what hp values to tune
tuner.set_hyperparameters(parameter_choices)
# WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

# set up hp values that need to be changed from default but NOT to be tuned
tuner.set_non_tuneable_hyperparameters(non_tunable_hyperparameters_dict)

print('---')

# set up feature importance ordering

if TUNE_FEATURES_AS_HYPERPARAMETERS:
    tuner.set_features(feature_importance_ordering)
    # WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

try:  # try to read in previous results to continue tuning ...
    tuner.read_in_tuning_result_df(
        f'{home_directory}models/tuning/{TUNER}_{MODEL}_{PREPROCESSING}.csv')
except:
    print('No previous tuning data read in')

print('---')

# set up where to save the tuning result csv
tuner.set_tuning_result_saving_address(
    f'{home_directory}models/tuning/{TUNER}_{MODEL}_{PREPROCESSING}.csv')

print('---')

# set up where to save the current best model
tuner.set_best_model_saving_address(
    f'{home_directory}models/tmp_models/{TUNER}_{MODEL}_{PREPROCESSING}')
# Out:
# YangZhouB Initialised
# ---
# Successfully read in model <class 'sklearn.neighbors._classification.KNeighborsClassifier'>, which is a Classification model optimising for f1
# ---
# Read in Train X data list
# Read in Train y data list
# Read in Val X data list
# Read in Val y data list
# ---
# Successfully recorded hyperparameter choices
# ---
# Successfully recorded non_tuneable_hyperparameter choices
# ---
# Successfully recorded tuneable feature combination choices and updated relevant internal structures
# ---
# Successfully read in tuning result of 1932 rows, for 1932.0 combos
# ---
# Successfully set tuning output address
# ---
# Successfully set best model output address

# %%
# ignore warnings

import warnings
warnings.filterwarnings("ignore")

# %%
# begin tuning ... (or continue training)

tuner.tune()
# Out:
# Streaming output truncated to the last 5000 lines.
# Already Trained and Tested combination (val score of 0.2806):
#             {'n_neighbors': 11, 'p': 2, 'weights': 'distance', 'features': 30}
#             Current best combo (with val score 0.3618):
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
#         Has trained 1402 of 20400 combinations so far
# Already Trained and Tested combination (val score of 0.2794):
#             {'n_neighbors': 11, 'p': 2, 'weights': 'uniform', 'features': 29}
#             Current best combo (with val score 0.3618):
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
#         Has trained 1402 of 20400 combinations so far
# Already Trained and Tested combination (val score of 0.2807):
#             {'n_neighbors': 11, 'p': 2, 'weights': 'uniform', 'features': 31}
#             Current best combo (with val score 0.3618):
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
#         Has trained 1402 of 20400 combinations so far
# 	round 63 iteration:  1
#
# Already Trained and Tested combination (val score of 0.2806):
#             {'n_neighbors': 10, 'p': 2, 'weights': 'distance', 'features': 30}
#             Current best combo (with val score 0.3618):
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
#         Has trained 1402 of 20400 combinations so far
# Already Trained and Tested combination (val score of 0.2807):
#             {'n_neighbors': 12, 'p': 2, 'weights': 'distance', 'features': 30}
#             Current best combo (with val score 0.3618):
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
#         Has trained 1402 of 20400 combinations so far
# Already Trained and Tested combination (val score of 0.0774):
#             {'n_neighbors': 11, 'p': 1, 'weights': 'distance', 'features': 30}
#             Current best combo (with val score 0.3618):
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
#         Has trained 1402 of 20400 combinations so far
# Already Trained and Tested combination (val score of 0.2807):
#             {'n_neighbors': 11, 'p': 2, 'weights': 'uniform', 'features': 30}
#             Current best combo (with val score 0.3618):
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
#         Has trained 1402 of 20400 combinations so far
# Already Trained and Tested combination (val score of 0.2806):
#             {'n_neighbors': 11, 'p': 2, 'weights': 'distance', 'features': 29}
#             Current best combo (with val score 0.3618):
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
#         Has trained 1402 of 20400 combinations so far
# Already Trained and Tested combination (val score of 0.2806):
#             {'n_neighbors': 11, 'p': 2, 'weights': 'distance', 'features': 31}
#             Current best combo (with val score 0.3618):
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
#         Has trained 1402 of 20400 combinations so far
# Already Trained and Tested combination (val score of 0.25):
#             {'n_neighbors': 10, 'p': 2, 'weights': 'uniform', 'features': 29}
#             Current best combo (with val score 0.3618):
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
#         Has trained 1402 of 20400 combinations so far
# Already Trained and Tested combination (val score of 0.248):
#             {'n_neighbors': 12, 'p': 2, 'weights': 'uniform', 'features': 29}
#             Current best combo (with val score 0.3618):
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
#         Has trained 1402 of 20400 combinations so far
# Already Trained and Tested combination (val score of 0.0994):
#             {'n_neighbors': 11, 'p': 1, 'weights': 'uniform', 'features': 29}
#             Current best combo (with val score 0.3618):
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
#         Has trained 1402 of 20400 combinations so far
# Already Trained and Tested combination (val score of 0.2806):
#             {'n_neighbors': 11, 'p': 2, 'weights': 'distance', 'features': 29}
#             Current best combo (with val score 0.3618):
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
#         Has trained 1402 of 20400 combinations so far
# Already Trained and Tested combination (val score of 0.2794):
#             {'n_neighbors': 11, 'p': 2, 'weights': 'uniform', 'features': 28}
#             Current best combo (with val score 0.3618):
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
#         Has trained 1402 of 20400 combinations so far
# Already Trained and Tested combination (val score of 0.2807):
#             {'n_neighbors': 11, 'p': 2, 'weights': 'uniform', 'features': 30}
#             Current best combo (with val score 0.3618):
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
#         Has trained 1402 of 20400 combinations so far
# Already Trained and Tested combination (val score of 0.248):
#             {'n_neighbors': 10, 'p': 2, 'weights': 'uniform', 'features': 31}
#             Current best combo (with val score 0.3618):
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
#         Has trained 1402 of 20400 combinations so far
# Already Trained and Tested combination (val score of 0.2568):
#             {'n_neighbors': 12, 'p': 2, 'weights': 'uniform', 'features': 31}
#             Current best combo (with val score 0.3618):
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
#         Has trained 1402 of 20400 combinations so far
# Already Trained and Tested combination (val score of 0.0735):
#             {'n_neighbors': 11, 'p': 1, 'weights': 'uniform', 'features': 31}
#             Current best combo (with val score 0.3618):
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
#         Has trained 1402 of 20400 combinations so far
# Already Trained and Tested combination (val score of 0.2806):
#             {'n_neighbors': 11, 'p': 2, 'weights': 'distance', 'features': 31}
#             Current best combo (with val score 0.3618):
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
#         Has trained 1402 of 20400 combinations so far
# Already Trained and Tested combination (val score of 0.2807):
#             {'n_neighbors': 11, 'p': 2, 'weights': 'uniform', 'features': 30}
#             Current best combo (with val score 0.3618):
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
#         Has trained 1402 of 20400 combinations so far
# Already Trained and Tested combination (val score of 0.2808):
#             {'n_neighbors': 11, 'p': 2, 'weights': 'uniform', 'features': 32}
#             Current best combo (with val score 0.3618):
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
#         Has trained 1402 of 20400 combinations so far
# % Combos Checked Thus Far: 1402 out of 20400 which is 6.872549%
# Cruising Coordrdinate 128 of 924
#
# Cruise suspended due to suspicious case
# Guidance: round 64
#
# 	round 64 iteration:  0
#
# % Combos Checked Thus Far: 1402 out of 20400 which is 6.872549%
# Cruising Coordrdinate 129 of 924
#
# Cruising Coordrdinate 130 of 924
#
# Cruising Coordrdinate 131 of 924
#
# Cruise suspended due to suspicious case
# Guidance: round 65
#
# 	round 65 iteration:  0
#
# Already Trained and Tested combination (val score of 0.2493):
#             {'n_neighbors': 10, 'p': 2, 'weights': 'uniform', 'features': 25}
#             Current best combo (with val score 0.3618):
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
#         Has trained 1402 of 20400 combinations so far
# Already Trained and Tested combination (val score of 0.2454):
#             {'n_neighbors': 12, 'p': 2, 'weights': 'uniform', 'features': 25}
#             Current best combo (with val score 0.3618):
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
#         Has trained 1402 of 20400 combinations so far
# Already Trained and Tested combination (val score of 0.1158):
#             {'n_neighbors': 11, 'p': 1, 'weights': 'uniform', 'features': 25}
#             Current best combo (with val score 0.3618):
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
#         Has trained 1402 of 20400 combinations so far
# Already Trained and Tested combination (val score of 0.2805):
#             {'n_neighbors': 11, 'p': 2, 'weights': 'distance', 'features': 25}
#             Current best combo (with val score 0.3618):
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
#         Has trained 1402 of 20400 combinations so far
# Already Trained and Tested combination (val score of 0.2779):
#             {'n_neighbors': 11, 'p': 2, 'weights': 'uniform', 'features': 24}
#             Current best combo (with val score 0.3618):
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
#         Has trained 1402 of 20400 combinations so far
# Already Trained and Tested combination (val score of 0.2782):
#             {'n_neighbors': 11, 'p': 2, 'weights': 'uniform', 'features': 26}
#             Current best combo (with val score 0.3618):
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
#         Has trained 1402 of 20400 combinations so far
# 	round 65 iteration:  1
#
# Already Trained and Tested combination (val score of 0.2805):
#             {'n_neighbors': 10, 'p': 2, 'weights': 'distance', 'features': 25}
#             Current best combo (with val score 0.3618):
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
#         Has trained 1402 of 20400 combinations so far
# Already Trained and Tested combination (val score of 0.2805):
#             {'n_neighbors': 12, 'p': 2, 'weights': 'distance', 'features': 25}
#             Current best combo (with val score 0.3618):
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
#         Has trained 1402 of 20400 combinations so far
# Already Trained and Tested combination (val score of 0.1271):
#             {'n_neighbors': 11, 'p': 1, 'weights': 'distance', 'features': 25}
#             Current best combo (with val score 0.3618):
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
#         Has trained 1402 of 20400 combinations so far
# Already Trained and Tested combination (val score of 0.2781):
#             {'n_neighbors': 11, 'p': 2, 'weights': 'uniform', 'features': 25}
#             Current best combo (with val score 0.3618):
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
#         Has trained 1402 of 20400 combinations so far
# Already Trained and Tested combination (val score of 0.2805):
#             {'n_neighbors': 11, 'p': 2, 'weights': 'distance', 'features': 24}
#             Current best combo (with val score 0.3618):
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
#         Has trained 1402 of 20400 combinations so far
# Already Trained and Tested combination (val score of 0.2805):
#             {'n_neighbors': 11, 'p': 2, 'weights': 'distance', 'features': 26}
#             Current best combo (with val score 0.3618):
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
#         Has trained 1402 of 20400 combinations so far
# Already Trained and Tested combination (val score of 0.2493):
#             {'n_neighbors': 10, 'p': 2, 'weights': 'uniform', 'features': 24}
#             Current best combo (with val score 0.3618):
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
#         Has trained 1402 of 20400 combinations so far
# Already Trained and Tested combination (val score of 0.2467):
#             {'n_neighbors': 12, 'p': 2, 'weights': 'uniform', 'features': 24}
#             Current best combo (with val score 0.3618):
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
#         Has trained 1402 of 20400 combinations so far
# Already Trained and Tested combination (val score of 0.0462):
#             {'n_neighbors': 11, 'p': 1, 'weights': 'uniform', 'features': 24}
#             Current best combo (with val score 0.3618):
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
#         Has trained 1402 of 20400 combinations so far
# Already Trained and Tested combination (val score of 0.2805):
#             {'n_neighbors': 11, 'p': 2, 'weights': 'distance', 'features': 24}
#             Current best combo (with val score 0.3618):
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
#         Has trained 1402 of 20400 combinations so far
# Already Trained and Tested combination (val score of 0.2493):
#             {'n_neighbors': 11, 'p': 2, 'weights': 'uniform', 'features': 23}
#             Current best combo (with val score 0.3618):
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
#         Has trained 1402 of 20400 combinations so far
# Already Trained and Tested combination (val score of 0.2781):
#             {'n_neighbors': 11, 'p': 2, 'weights': 'uniform', 'features': 25}
#             Current best combo (with val score 0.3618):
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
#         Has trained 1402 of 20400 combinations so far
# Already Trained and Tested combination (val score of 0.2493):
#             {'n_neighbors': 10, 'p': 2, 'weights': 'uniform', 'features': 26}
#             Current best combo (with val score 0.3618):
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
#         Has trained 1402 of 20400 combinations so far
# Trained and Tested combination 1403 of 20400, taking 0.0 seconds to get val score of 0.2455:
#                 {'n_neighbors': 12, 'p': 2, 'weights': 'uniform', 'features': 26},
#             Current best combo with val score 0.3618:
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
# Trained and Tested combination 1404 of 20400, taking 0.01 seconds to get val score of 0.1078:
#                 {'n_neighbors': 11, 'p': 1, 'weights': 'uniform', 'features': 26},
#             Current best combo with val score 0.3618:
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
# Already Trained and Tested combination (val score of 0.2805):
#             {'n_neighbors': 11, 'p': 2, 'weights': 'distance', 'features': 26}
#             Current best combo (with val score 0.3618):
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
#         Has trained 1404 of 20400 combinations so far
# Already Trained and Tested combination (val score of 0.2781):
#             {'n_neighbors': 11, 'p': 2, 'weights': 'uniform', 'features': 25}
#             Current best combo (with val score 0.3618):
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
#         Has trained 1404 of 20400 combinations so far
# Trained and Tested combination 1405 of 20400, taking 0.0 seconds to get val score of 0.2782:
#                 {'n_neighbors': 11, 'p': 2, 'weights': 'uniform', 'features': 27},
#             Current best combo with val score 0.3618:
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
# % Combos Checked Thus Far: 1405 out of 20400 which is 6.887255000000001%
# Cruising Coordrdinate 132 of 924
#
# Cruise suspended due to suspicious case
# Guidance: round 66
#
# 	round 66 iteration:  0
#
# % Combos Checked Thus Far: 1405 out of 20400 which is 6.887255000000001%
# Cruising Coordrdinate 133 of 924
#
# Cruising Coordrdinate 134 of 924
#
# Cruising Coordrdinate 135 of 924
#
# Cruising Coordrdinate 136 of 924
#
# Cruising Coordrdinate 137 of 924
#
# Cruising Coordrdinate 138 of 924
#
# Cruising Coordrdinate 139 of 924
#
# Cruise suspended due to suspicious case
# Guidance: round 67
#
# 	round 67 iteration:  0
#
# Trained and Tested combination 1406 of 20400, taking 0.01 seconds to get val score of 0.2806:
#                 {'n_neighbors': 15, 'p': 2, 'weights': 'uniform', 'features': 50},
#             Current best combo with val score 0.3618:
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
# Trained and Tested combination 1407 of 20400, taking 0.0 seconds to get val score of 0.2805:
#                 {'n_neighbors': 17, 'p': 2, 'weights': 'uniform', 'features': 50},
#             Current best combo with val score 0.3618:
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
# Already Trained and Tested combination (val score of 0.0):
#             {'n_neighbors': 16, 'p': 1, 'weights': 'uniform', 'features': 50}
#             Current best combo (with val score 0.3618):
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
#         Has trained 1407 of 20400 combinations so far
# Already Trained and Tested combination (val score of 0.2805):
#             {'n_neighbors': 16, 'p': 2, 'weights': 'distance', 'features': 50}
#             Current best combo (with val score 0.3618):
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
#         Has trained 1407 of 20400 combinations so far
# Trained and Tested combination 1408 of 20400, taking 0.01 seconds to get val score of 0.2806:
#                 {'n_neighbors': 16, 'p': 2, 'weights': 'uniform', 'features': 49},
#             Current best combo with val score 0.3618:
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
# 	round 67 iteration:  1
#
# Trained and Tested combination 1409 of 20400, taking 0.0 seconds to get val score of 0.2784:
#                 {'n_neighbors': 14, 'p': 2, 'weights': 'uniform', 'features': 50},
#             Current best combo with val score 0.3618:
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
# Already Trained and Tested combination (val score of 0.2806):
#             {'n_neighbors': 16, 'p': 2, 'weights': 'uniform', 'features': 50}
#             Current best combo (with val score 0.3618):
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
#         Has trained 1409 of 20400 combinations so far
# Trained and Tested combination 1410 of 20400, taking 0.0 seconds to get val score of 0.0033:
#                 {'n_neighbors': 15, 'p': 1, 'weights': 'uniform', 'features': 50},
#             Current best combo with val score 0.3618:
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
# Trained and Tested combination 1411 of 20400, taking 0.01 seconds to get val score of 0.2806:
#                 {'n_neighbors': 15, 'p': 2, 'weights': 'distance', 'features': 50},
#             Current best combo with val score 0.3618:
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
# Trained and Tested combination 1412 of 20400, taking 0.0 seconds to get val score of 0.2806:
#                 {'n_neighbors': 15, 'p': 2, 'weights': 'uniform', 'features': 49},
#             Current best combo with val score 0.3618:
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
# Already Trained and Tested combination (val score of 0.2806):
#             {'n_neighbors': 16, 'p': 2, 'weights': 'uniform', 'features': 50}
#             Current best combo (with val score 0.3618):
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
#         Has trained 1412 of 20400 combinations so far
# Trained and Tested combination 1413 of 20400, taking 0.01 seconds to get val score of 0.2807:
#                 {'n_neighbors': 18, 'p': 2, 'weights': 'uniform', 'features': 50},
#             Current best combo with val score 0.3618:
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
# Trained and Tested combination 1414 of 20400, taking 0.01 seconds to get val score of 0.0033:
#                 {'n_neighbors': 17, 'p': 1, 'weights': 'uniform', 'features': 50},
#             Current best combo with val score 0.3618:
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
# Trained and Tested combination 1415 of 20400, taking 0.0 seconds to get val score of 0.2805:
#                 {'n_neighbors': 17, 'p': 2, 'weights': 'distance', 'features': 50},
#             Current best combo with val score 0.3618:
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
# Trained and Tested combination 1416 of 20400, taking 0.01 seconds to get val score of 0.2805:
#                 {'n_neighbors': 17, 'p': 2, 'weights': 'uniform', 'features': 49},
#             Current best combo with val score 0.3618:
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
# Already Trained and Tested combination (val score of 0.2806):
#             {'n_neighbors': 15, 'p': 2, 'weights': 'distance', 'features': 50}
#             Current best combo (with val score 0.3618):
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
#         Has trained 1416 of 20400 combinations so far
# Already Trained and Tested combination (val score of 0.2805):
#             {'n_neighbors': 17, 'p': 2, 'weights': 'distance', 'features': 50}
#             Current best combo (with val score 0.3618):
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
#         Has trained 1416 of 20400 combinations so far
# Already Trained and Tested combination (val score of 0.0033):
#             {'n_neighbors': 16, 'p': 1, 'weights': 'distance', 'features': 50}
#             Current best combo (with val score 0.3618):
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
#         Has trained 1416 of 20400 combinations so far
# Already Trained and Tested combination (val score of 0.2806):
#             {'n_neighbors': 16, 'p': 2, 'weights': 'uniform', 'features': 50}
#             Current best combo (with val score 0.3618):
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
#         Has trained 1416 of 20400 combinations so far
# Trained and Tested combination 1417 of 20400, taking 0.0 seconds to get val score of 0.2805:
#                 {'n_neighbors': 16, 'p': 2, 'weights': 'distance', 'features': 49},
#             Current best combo with val score 0.3618:
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
# Already Trained and Tested combination (val score of 0.2806):
#             {'n_neighbors': 15, 'p': 2, 'weights': 'uniform', 'features': 49}
#             Current best combo (with val score 0.3618):
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
#         Has trained 1417 of 20400 combinations so far
# Already Trained and Tested combination (val score of 0.2805):
#             {'n_neighbors': 17, 'p': 2, 'weights': 'uniform', 'features': 49}
#             Current best combo (with val score 0.3618):
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
#         Has trained 1417 of 20400 combinations so far
# Trained and Tested combination 1418 of 20400, taking 0.0 seconds to get val score of 0.0033:
#                 {'n_neighbors': 16, 'p': 1, 'weights': 'uniform', 'features': 49},
#             Current best combo with val score 0.3618:
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
# Already Trained and Tested combination (val score of 0.2805):
#             {'n_neighbors': 16, 'p': 2, 'weights': 'distance', 'features': 49}
#             Current best combo (with val score 0.3618):
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
#         Has trained 1418 of 20400 combinations so far
# Trained and Tested combination 1419 of 20400, taking 0.0 seconds to get val score of 0.2806:
#                 {'n_neighbors': 16, 'p': 2, 'weights': 'uniform', 'features': 48},
#             Current best combo with val score 0.3618:
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
# Already Trained and Tested combination (val score of 0.2806):
#             {'n_neighbors': 16, 'p': 2, 'weights': 'uniform', 'features': 50}
#             Current best combo (with val score 0.3618):
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
#         Has trained 1419 of 20400 combinations so far
# % Combos Checked Thus Far: 1419 out of 20400 which is 6.955881999999999%
# Cruising Coordrdinate 140 of 924
#
# Cruise suspended due to suspicious case
# Guidance: round 68
#
# 	round 68 iteration:  0
#
# % Combos Checked Thus Far: 1419 out of 20400 which is 6.955881999999999%
# Cruising Coordrdinate 141 of 924
#
# Cruising Coordrdinate 142 of 924
#
# Cruising Coordrdinate 143 of 924
#
# Cruising Coordrdinate 144 of 924
#
# Cruising Coordrdinate 145 of 924
#
# Cruising Coordrdinate 146 of 924
#
# Cruising Coordrdinate 147 of 924
#
# Cruise suspended due to suspicious case
# Guidance: round 69
#
# 	round 69 iteration:  0
#
# Trained and Tested combination 1420 of 20400, taking 0.0 seconds to get val score of 0.2806:
#                 {'n_neighbors': 15, 'p': 2, 'weights': 'uniform', 'features': 45},
#             Current best combo with val score 0.3618:
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
# Trained and Tested combination 1421 of 20400, taking 0.0 seconds to get val score of 0.2805:
#                 {'n_neighbors': 17, 'p': 2, 'weights': 'uniform', 'features': 45},
#             Current best combo with val score 0.3618:
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
# Already Trained and Tested combination (val score of 0.0033):
#             {'n_neighbors': 16, 'p': 1, 'weights': 'uniform', 'features': 45}
#             Current best combo (with val score 0.3618):
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
#         Has trained 1421 of 20400 combinations so far
# Already Trained and Tested combination (val score of 0.2805):
#             {'n_neighbors': 16, 'p': 2, 'weights': 'distance', 'features': 45}
#             Current best combo (with val score 0.3618):
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
#         Has trained 1421 of 20400 combinations so far
# Trained and Tested combination 1422 of 20400, taking 0.0 seconds to get val score of 0.2806:
#                 {'n_neighbors': 16, 'p': 2, 'weights': 'uniform', 'features': 44},
#             Current best combo with val score 0.3618:
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
# Trained and Tested combination 1423 of 20400, taking 0.0 seconds to get val score of 0.2806:
#                 {'n_neighbors': 16, 'p': 2, 'weights': 'uniform', 'features': 46},
#             Current best combo with val score 0.3618:
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
# 	round 69 iteration:  1
#
# Trained and Tested combination 1424 of 20400, taking 0.0 seconds to get val score of 0.2784:
#                 {'n_neighbors': 14, 'p': 2, 'weights': 'uniform', 'features': 45},
#             Current best combo with val score 0.3618:
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
# Already Trained and Tested combination (val score of 0.2806):
#             {'n_neighbors': 16, 'p': 2, 'weights': 'uniform', 'features': 45}
#             Current best combo (with val score 0.3618):
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
#         Has trained 1424 of 20400 combinations so far
# Trained and Tested combination 1425 of 20400, taking 0.0 seconds to get val score of 0.0033:
#                 {'n_neighbors': 15, 'p': 1, 'weights': 'uniform', 'features': 45},
#             Current best combo with val score 0.3618:
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
# Trained and Tested combination 1426 of 20400, taking 0.01 seconds to get val score of 0.2806:
#                 {'n_neighbors': 15, 'p': 2, 'weights': 'distance', 'features': 45},
#             Current best combo with val score 0.3618:
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
# Trained and Tested combination 1427 of 20400, taking 0.01 seconds to get val score of 0.2806:
#                 {'n_neighbors': 15, 'p': 2, 'weights': 'uniform', 'features': 44},
#             Current best combo with val score 0.3618:
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
# Trained and Tested combination 1428 of 20400, taking 0.01 seconds to get val score of 0.2806:
#                 {'n_neighbors': 15, 'p': 2, 'weights': 'uniform', 'features': 46},
#             Current best combo with val score 0.3618:
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
# Already Trained and Tested combination (val score of 0.2806):
#             {'n_neighbors': 16, 'p': 2, 'weights': 'uniform', 'features': 45}
#             Current best combo (with val score 0.3618):
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
#         Has trained 1428 of 20400 combinations so far
# Trained and Tested combination 1429 of 20400, taking 0.0 seconds to get val score of 0.2807:
#                 {'n_neighbors': 18, 'p': 2, 'weights': 'uniform', 'features': 45},
#             Current best combo with val score 0.3618:
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
# Trained and Tested combination 1430 of 20400, taking 0.0 seconds to get val score of 0.0033:
#                 {'n_neighbors': 17, 'p': 1, 'weights': 'uniform', 'features': 45},
#             Current best combo with val score 0.3618:
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
# Trained and Tested combination 1431 of 20400, taking 0.01 seconds to get val score of 0.2805:
#                 {'n_neighbors': 17, 'p': 2, 'weights': 'distance', 'features': 45},
#             Current best combo with val score 0.3618:
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
# Trained and Tested combination 1432 of 20400, taking 0.01 seconds to get val score of 0.2805:
#                 {'n_neighbors': 17, 'p': 2, 'weights': 'uniform', 'features': 44},
#             Current best combo with val score 0.3618:
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
# Trained and Tested combination 1433 of 20400, taking 0.01 seconds to get val score of 0.2805:
#                 {'n_neighbors': 17, 'p': 2, 'weights': 'uniform', 'features': 46},
#             Current best combo with val score 0.3618:
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
# Already Trained and Tested combination (val score of 0.2806):
#             {'n_neighbors': 15, 'p': 2, 'weights': 'distance', 'features': 45}
#             Current best combo (with val score 0.3618):
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
#         Has trained 1433 of 20400 combinations so far
# Already Trained and Tested combination (val score of 0.2805):
#             {'n_neighbors': 17, 'p': 2, 'weights': 'distance', 'features': 45}
#             Current best combo (with val score 0.3618):
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
#         Has trained 1433 of 20400 combinations so far
# Already Trained and Tested combination (val score of 0.0033):
#             {'n_neighbors': 16, 'p': 1, 'weights': 'distance', 'features': 45}
#             Current best combo (with val score 0.3618):
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
#         Has trained 1433 of 20400 combinations so far
# Already Trained and Tested combination (val score of 0.2806):
#             {'n_neighbors': 16, 'p': 2, 'weights': 'uniform', 'features': 45}
#             Current best combo (with val score 0.3618):
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
#         Has trained 1433 of 20400 combinations so far
# Trained and Tested combination 1434 of 20400, taking 0.0 seconds to get val score of 0.2805:
#                 {'n_neighbors': 16, 'p': 2, 'weights': 'distance', 'features': 44},
#             Current best combo with val score 0.3618:
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
# Trained and Tested combination 1435 of 20400, taking 0.0 seconds to get val score of 0.2805:
#                 {'n_neighbors': 16, 'p': 2, 'weights': 'distance', 'features': 46},
#             Current best combo with val score 0.3618:
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
# Already Trained and Tested combination (val score of 0.2806):
#             {'n_neighbors': 15, 'p': 2, 'weights': 'uniform', 'features': 44}
#             Current best combo (with val score 0.3618):
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
#         Has trained 1435 of 20400 combinations so far
# Already Trained and Tested combination (val score of 0.2805):
#             {'n_neighbors': 17, 'p': 2, 'weights': 'uniform', 'features': 44}
#             Current best combo (with val score 0.3618):
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
#         Has trained 1435 of 20400 combinations so far
# Trained and Tested combination 1436 of 20400, taking 0.0 seconds to get val score of 0.0033:
#                 {'n_neighbors': 16, 'p': 1, 'weights': 'uniform', 'features': 44},
#             Current best combo with val score 0.3618:
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
# Already Trained and Tested combination (val score of 0.2805):
#             {'n_neighbors': 16, 'p': 2, 'weights': 'distance', 'features': 44}
#             Current best combo (with val score 0.3618):
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
#         Has trained 1436 of 20400 combinations so far
# Trained and Tested combination 1437 of 20400, taking 0.0 seconds to get val score of 0.2806:
#                 {'n_neighbors': 16, 'p': 2, 'weights': 'uniform', 'features': 43},
#             Current best combo with val score 0.3618:
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
# Already Trained and Tested combination (val score of 0.2806):
#             {'n_neighbors': 16, 'p': 2, 'weights': 'uniform', 'features': 45}
#             Current best combo (with val score 0.3618):
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
#         Has trained 1437 of 20400 combinations so far
# Already Trained and Tested combination (val score of 0.2806):
#             {'n_neighbors': 15, 'p': 2, 'weights': 'uniform', 'features': 46}
#             Current best combo (with val score 0.3618):
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
#         Has trained 1437 of 20400 combinations so far
# Already Trained and Tested combination (val score of 0.2805):
#             {'n_neighbors': 17, 'p': 2, 'weights': 'uniform', 'features': 46}
#             Current best combo (with val score 0.3618):
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
#         Has trained 1437 of 20400 combinations so far
# Trained and Tested combination 1438 of 20400, taking 0.0 seconds to get val score of 0.0033:
#                 {'n_neighbors': 16, 'p': 1, 'weights': 'uniform', 'features': 46},
#             Current best combo with val score 0.3618:
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
# Already Trained and Tested combination (val score of 0.2805):
#             {'n_neighbors': 16, 'p': 2, 'weights': 'distance', 'features': 46}
#             Current best combo (with val score 0.3618):
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
#         Has trained 1438 of 20400 combinations so far
# Already Trained and Tested combination (val score of 0.2806):
#             {'n_neighbors': 16, 'p': 2, 'weights': 'uniform', 'features': 45}
#             Current best combo (with val score 0.3618):
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
#         Has trained 1438 of 20400 combinations so far
# Trained and Tested combination 1439 of 20400, taking 0.01 seconds to get val score of 0.2806:
#                 {'n_neighbors': 16, 'p': 2, 'weights': 'uniform', 'features': 47},
#             Current best combo with val score 0.3618:
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
# % Combos Checked Thus Far: 1439 out of 20400 which is 7.053922%
# Cruising Coordrdinate 148 of 924
#
# Cruise suspended due to suspicious case
# Guidance: round 70
#
# 	round 70 iteration:  0
#
# % Combos Checked Thus Far: 1439 out of 20400 which is 7.053922%
# Cruising Coordrdinate 149 of 924
#
# Cruising Coordrdinate 150 of 924
#
# Cruising Coordrdinate 151 of 924
#
# Cruising Coordrdinate 152 of 924
#
# Cruising Coordrdinate 153 of 924
#
# Cruising Coordrdinate 154 of 924
#
# Cruising Coordrdinate 155 of 924
#
# Cruise suspended due to suspicious case
# Guidance: round 71
#
# 	round 71 iteration:  0
#
# Trained and Tested combination 1440 of 20400, taking 0.0 seconds to get val score of 0.2806:
#                 {'n_neighbors': 15, 'p': 2, 'weights': 'uniform', 'features': 40},
#             Current best combo with val score 0.3618:
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
# Trained and Tested combination 1441 of 20400, taking 0.01 seconds to get val score of 0.2807:
#                 {'n_neighbors': 17, 'p': 2, 'weights': 'uniform', 'features': 40},
#             Current best combo with val score 0.3618:
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
# Already Trained and Tested combination (val score of 0.0033):
#             {'n_neighbors': 16, 'p': 1, 'weights': 'uniform', 'features': 40}
#             Current best combo (with val score 0.3618):
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
#         Has trained 1441 of 20400 combinations so far
# Already Trained and Tested combination (val score of 0.2806):
#             {'n_neighbors': 16, 'p': 2, 'weights': 'distance', 'features': 40}
#             Current best combo (with val score 0.3618):
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
#         Has trained 1441 of 20400 combinations so far
# Trained and Tested combination 1442 of 20400, taking 0.01 seconds to get val score of 0.2794:
#                 {'n_neighbors': 16, 'p': 2, 'weights': 'uniform', 'features': 39},
#             Current best combo with val score 0.3618:
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
# Trained and Tested combination 1443 of 20400, taking 0.01 seconds to get val score of 0.28:
#                 {'n_neighbors': 16, 'p': 2, 'weights': 'uniform', 'features': 41},
#             Current best combo with val score 0.3618:
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
# 	round 71 iteration:  1
#
# Trained and Tested combination 1444 of 20400, taking 0.01 seconds to get val score of 0.2795:
#                 {'n_neighbors': 14, 'p': 2, 'weights': 'uniform', 'features': 40},
#             Current best combo with val score 0.3618:
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
# Already Trained and Tested combination (val score of 0.2795):
#             {'n_neighbors': 16, 'p': 2, 'weights': 'uniform', 'features': 40}
#             Current best combo (with val score 0.3618):
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
#         Has trained 1444 of 20400 combinations so far
# Trained and Tested combination 1445 of 20400, taking 0.0 seconds to get val score of 0.0033:
#                 {'n_neighbors': 15, 'p': 1, 'weights': 'uniform', 'features': 40},
#             Current best combo with val score 0.3618:
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
# Trained and Tested combination 1446 of 20400, taking 0.0 seconds to get val score of 0.2806:
#                 {'n_neighbors': 15, 'p': 2, 'weights': 'distance', 'features': 40},
#             Current best combo with val score 0.3618:
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
# Trained and Tested combination 1447 of 20400, taking 0.0 seconds to get val score of 0.2806:
#                 {'n_neighbors': 15, 'p': 2, 'weights': 'uniform', 'features': 39},
#             Current best combo with val score 0.3618:
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
# Trained and Tested combination 1448 of 20400, taking 0.0 seconds to get val score of 0.2806:
#                 {'n_neighbors': 15, 'p': 2, 'weights': 'uniform', 'features': 41},
#             Current best combo with val score 0.3618:
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
# Already Trained and Tested combination (val score of 0.2795):
#             {'n_neighbors': 16, 'p': 2, 'weights': 'uniform', 'features': 40}
#             Current best combo (with val score 0.3618):
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
#         Has trained 1448 of 20400 combinations so far
# Trained and Tested combination 1449 of 20400, taking 0.01 seconds to get val score of 0.2794:
#                 {'n_neighbors': 18, 'p': 2, 'weights': 'uniform', 'features': 40},
#             Current best combo with val score 0.3618:
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
# Trained and Tested combination 1450 of 20400, taking 0.0 seconds to get val score of 0.0033:
#                 {'n_neighbors': 17, 'p': 1, 'weights': 'uniform', 'features': 40},
#             Current best combo with val score 0.3618:
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
# Trained and Tested combination 1451 of 20400, taking 0.0 seconds to get val score of 0.2806:
#                 {'n_neighbors': 17, 'p': 2, 'weights': 'distance', 'features': 40},
#             Current best combo with val score 0.3618:
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
# Trained and Tested combination 1452 of 20400, taking 0.01 seconds to get val score of 0.2807:
#                 {'n_neighbors': 17, 'p': 2, 'weights': 'uniform', 'features': 39},
#             Current best combo with val score 0.3618:
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
# Trained and Tested combination 1453 of 20400, taking 0.0 seconds to get val score of 0.2807:
#                 {'n_neighbors': 17, 'p': 2, 'weights': 'uniform', 'features': 41},
#             Current best combo with val score 0.3618:
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
# Already Trained and Tested combination (val score of 0.2806):
#             {'n_neighbors': 15, 'p': 2, 'weights': 'distance', 'features': 40}
#             Current best combo (with val score 0.3618):
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
#         Has trained 1453 of 20400 combinations so far
# Already Trained and Tested combination (val score of 0.2806):
#             {'n_neighbors': 17, 'p': 2, 'weights': 'distance', 'features': 40}
#             Current best combo (with val score 0.3618):
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
#         Has trained 1453 of 20400 combinations so far
# Already Trained and Tested combination (val score of 0.0033):
#             {'n_neighbors': 16, 'p': 1, 'weights': 'distance', 'features': 40}
#             Current best combo (with val score 0.3618):
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
#         Has trained 1453 of 20400 combinations so far
# Already Trained and Tested combination (val score of 0.2795):
#             {'n_neighbors': 16, 'p': 2, 'weights': 'uniform', 'features': 40}
#             Current best combo (with val score 0.3618):
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
#         Has trained 1453 of 20400 combinations so far
# Trained and Tested combination 1454 of 20400, taking 0.0 seconds to get val score of 0.2806:
#                 {'n_neighbors': 16, 'p': 2, 'weights': 'distance', 'features': 39},
#             Current best combo with val score 0.3618:
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
# Trained and Tested combination 1455 of 20400, taking 0.01 seconds to get val score of 0.2806:
#                 {'n_neighbors': 16, 'p': 2, 'weights': 'distance', 'features': 41},
#             Current best combo with val score 0.3618:
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
# Already Trained and Tested combination (val score of 0.2806):
#             {'n_neighbors': 15, 'p': 2, 'weights': 'uniform', 'features': 39}
#             Current best combo (with val score 0.3618):
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
#         Has trained 1455 of 20400 combinations so far
# Already Trained and Tested combination (val score of 0.2807):
#             {'n_neighbors': 17, 'p': 2, 'weights': 'uniform', 'features': 39}
#             Current best combo (with val score 0.3618):
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
#         Has trained 1455 of 20400 combinations so far
# Trained and Tested combination 1456 of 20400, taking 0.01 seconds to get val score of 0.0:
#                 {'n_neighbors': 16, 'p': 1, 'weights': 'uniform', 'features': 39},
#             Current best combo with val score 0.3618:
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
# Already Trained and Tested combination (val score of 0.2806):
#             {'n_neighbors': 16, 'p': 2, 'weights': 'distance', 'features': 39}
#             Current best combo (with val score 0.3618):
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
#         Has trained 1456 of 20400 combinations so far
# Trained and Tested combination 1457 of 20400, taking 0.0 seconds to get val score of 0.2794:
#                 {'n_neighbors': 16, 'p': 2, 'weights': 'uniform', 'features': 38},
#             Current best combo with val score 0.3618:
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
# Already Trained and Tested combination (val score of 0.2795):
#             {'n_neighbors': 16, 'p': 2, 'weights': 'uniform', 'features': 40}
#             Current best combo (with val score 0.3618):
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
#         Has trained 1457 of 20400 combinations so far
# Already Trained and Tested combination (val score of 0.2806):
# ...
#         Has trained 1921 of 20400 combinations so far
# Already Trained and Tested combination (val score of 0.2241):
#             {'n_neighbors': 36, 'p': 2, 'weights': 'uniform', 'features': 35}
#             Current best combo (with val score 0.3618):
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
#         Has trained 1921 of 20400 combinations so far
# Trained and Tested combination 1922 of 20400, taking 0.01 seconds to get val score of 0.2233:
#                 {'n_neighbors': 36, 'p': 2, 'weights': 'uniform', 'features': 37},
#             Current best combo with val score 0.3618:
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
# % Combos Checked Thus Far: 1922 out of 20400 which is 9.421569%
# Cruising Coordrdinate 340 of 924
#
# Cruise suspended due to suspicious case
# Guidance: round 116
#
# 	round 116 iteration:  0
#
# % Combos Checked Thus Far: 1922 out of 20400 which is 9.421569%
# Cruising Coordrdinate 341 of 924
#
# Cruising Coordrdinate 342 of 924
#
# Cruising Coordrdinate 343 of 924
#
# Cruising Coordrdinate 344 of 924
#
# Cruising Coordrdinate 345 of 924
#
# Cruising Coordrdinate 346 of 924
#
# Cruising Coordrdinate 347 of 924
#
# Cruise suspended due to suspicious case
# Guidance: round 117
#
# 	round 117 iteration:  0
#
# Trained and Tested combination 1923 of 20400, taking 0.0 seconds to get val score of 0.2612:
#                 {'n_neighbors': 35, 'p': 2, 'weights': 'uniform', 'features': 20},
#             Current best combo with val score 0.3618:
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
# Trained and Tested combination 1924 of 20400, taking 0.01 seconds to get val score of 0.2426:
#                 {'n_neighbors': 37, 'p': 2, 'weights': 'uniform', 'features': 20},
#             Current best combo with val score 0.3618:
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
# Already Trained and Tested combination (val score of 0.0):
#             {'n_neighbors': 36, 'p': 1, 'weights': 'uniform', 'features': 20}
#             Current best combo (with val score 0.3618):
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
#         Has trained 1924 of 20400 combinations so far
# Already Trained and Tested combination (val score of 0.2513):
#             {'n_neighbors': 36, 'p': 2, 'weights': 'distance', 'features': 20}
#             Current best combo (with val score 0.3618):
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
#         Has trained 1924 of 20400 combinations so far
# Trained and Tested combination 1925 of 20400, taking 0.0 seconds to get val score of 0.0:
#                 {'n_neighbors': 36, 'p': 2, 'weights': 'uniform', 'features': 19},
#             Current best combo with val score 0.3618:
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
# Trained and Tested combination 1926 of 20400, taking 0.01 seconds to get val score of 0.2368:
#                 {'n_neighbors': 36, 'p': 2, 'weights': 'uniform', 'features': 21},
#             Current best combo with val score 0.3618:
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
# 	round 117 iteration:  1
#
# Trained and Tested combination 1927 of 20400, taking 0.0 seconds to get val score of 0.2144:
#                 {'n_neighbors': 34, 'p': 2, 'weights': 'uniform', 'features': 20},
#             Current best combo with val score 0.3618:
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
# Already Trained and Tested combination (val score of 0.235):
#             {'n_neighbors': 36, 'p': 2, 'weights': 'uniform', 'features': 20}
#             Current best combo (with val score 0.3618):
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
#         Has trained 1927 of 20400 combinations so far
# Trained and Tested combination 1928 of 20400, taking 0.01 seconds to get val score of 0.0033:
#                 {'n_neighbors': 35, 'p': 1, 'weights': 'uniform', 'features': 20},
#             Current best combo with val score 0.3618:
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
# Trained and Tested combination 1929 of 20400, taking 0.0 seconds to get val score of 0.2493:
#                 {'n_neighbors': 35, 'p': 2, 'weights': 'distance', 'features': 20},
#             Current best combo with val score 0.3618:
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
# Trained and Tested combination 1930 of 20400, taking 0.01 seconds to get val score of 0.0:
#                 {'n_neighbors': 35, 'p': 2, 'weights': 'uniform', 'features': 19},
#             Current best combo with val score 0.3618:
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
# Trained and Tested combination 1931 of 20400, taking 0.0 seconds to get val score of 0.2619:
#                 {'n_neighbors': 35, 'p': 2, 'weights': 'uniform', 'features': 21},
#             Current best combo with val score 0.3618:
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
# Already Trained and Tested combination (val score of 0.235):
#             {'n_neighbors': 36, 'p': 2, 'weights': 'uniform', 'features': 20}
#             Current best combo (with val score 0.3618):
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
#         Has trained 1931 of 20400 combinations so far
# Trained and Tested combination 1932 of 20400, taking 0.0 seconds to get val score of 0.2091:
#                 {'n_neighbors': 38, 'p': 2, 'weights': 'uniform', 'features': 20},
#             Current best combo with val score 0.3618:
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
# Trained and Tested combination 1933 of 20400, taking 0.0 seconds to get val score of 0.0033:
#                 {'n_neighbors': 37, 'p': 1, 'weights': 'uniform', 'features': 20},
#             Current best combo with val score 0.3618:
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
# Trained and Tested combination 1934 of 20400, taking 0.01 seconds to get val score of 0.2505:
#                 {'n_neighbors': 37, 'p': 2, 'weights': 'distance', 'features': 20},
#             Current best combo with val score 0.3618:
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
# Trained and Tested combination 1935 of 20400, taking 0.0 seconds to get val score of 0.0:
#                 {'n_neighbors': 37, 'p': 2, 'weights': 'uniform', 'features': 19},
#             Current best combo with val score 0.3618:
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
# Trained and Tested combination 1936 of 20400, taking 0.0 seconds to get val score of 0.2468:
#                 {'n_neighbors': 37, 'p': 2, 'weights': 'uniform', 'features': 21},
#             Current best combo with val score 0.3618:
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
# Already Trained and Tested combination (val score of 0.2493):
#             {'n_neighbors': 35, 'p': 2, 'weights': 'distance', 'features': 20}
#             Current best combo (with val score 0.3618):
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
#         Has trained 1936 of 20400 combinations so far
# Already Trained and Tested combination (val score of 0.2505):
#             {'n_neighbors': 37, 'p': 2, 'weights': 'distance', 'features': 20}
#             Current best combo (with val score 0.3618):
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
#         Has trained 1936 of 20400 combinations so far
# Already Trained and Tested combination (val score of 0.0033):
#             {'n_neighbors': 36, 'p': 1, 'weights': 'distance', 'features': 20}
#             Current best combo (with val score 0.3618):
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
#         Has trained 1936 of 20400 combinations so far
# Already Trained and Tested combination (val score of 0.235):
#             {'n_neighbors': 36, 'p': 2, 'weights': 'uniform', 'features': 20}
#             Current best combo (with val score 0.3618):
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
#         Has trained 1936 of 20400 combinations so far
# Trained and Tested combination 1937 of 20400, taking 0.0 seconds to get val score of 0.0:
#                 {'n_neighbors': 36, 'p': 2, 'weights': 'distance', 'features': 19},
#             Current best combo with val score 0.3618:
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
# Trained and Tested combination 1938 of 20400, taking 0.01 seconds to get val score of 0.252:
#                 {'n_neighbors': 36, 'p': 2, 'weights': 'distance', 'features': 21},
#             Current best combo with val score 0.3618:
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
# Already Trained and Tested combination (val score of 0.2619):
#             {'n_neighbors': 35, 'p': 2, 'weights': 'uniform', 'features': 21}
#             Current best combo (with val score 0.3618):
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
#         Has trained 1938 of 20400 combinations so far
# Already Trained and Tested combination (val score of 0.2468):
#             {'n_neighbors': 37, 'p': 2, 'weights': 'uniform', 'features': 21}
#             Current best combo (with val score 0.3618):
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
#         Has trained 1938 of 20400 combinations so far
# Trained and Tested combination 1939 of 20400, taking 0.01 seconds to get val score of 0.0:
#                 {'n_neighbors': 36, 'p': 1, 'weights': 'uniform', 'features': 21},
#             Current best combo with val score 0.3618:
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
# Already Trained and Tested combination (val score of 0.252):
#             {'n_neighbors': 36, 'p': 2, 'weights': 'distance', 'features': 21}
#             Current best combo (with val score 0.3618):
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
#         Has trained 1939 of 20400 combinations so far
# Already Trained and Tested combination (val score of 0.235):
#             {'n_neighbors': 36, 'p': 2, 'weights': 'uniform', 'features': 20}
#             Current best combo (with val score 0.3618):
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
#         Has trained 1939 of 20400 combinations so far
# Trained and Tested combination 1940 of 20400, taking 0.01 seconds to get val score of 0.2181:
#                 {'n_neighbors': 36, 'p': 2, 'weights': 'uniform', 'features': 22},
#             Current best combo with val score 0.3618:
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
# % Combos Checked Thus Far: 1940 out of 20400 which is 9.509803999999999%
# Cruising Coordrdinate 348 of 924
#
# Cruise suspended due to suspicious case
# Guidance: round 118
#
# 	round 118 iteration:  0
#
# % Combos Checked Thus Far: 1940 out of 20400 which is 9.509803999999999%
# Cruising Coordrdinate 349 of 924
#
# Cruising Coordrdinate 350 of 924
#
# Cruising Coordrdinate 351 of 924
#
# Cruise suspended due to suspicious case
# Guidance: round 119
#
# 	round 119 iteration:  0
#
# Trained and Tested combination 1941 of 20400, taking 0.0 seconds to get val score of 0.1971:
#                 {'n_neighbors': 35, 'p': 2, 'weights': 'uniform', 'features': 30},
#             Current best combo with val score 0.3618:
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
# Trained and Tested combination 1942 of 20400, taking 0.0 seconds to get val score of 0.2018:
#                 {'n_neighbors': 37, 'p': 2, 'weights': 'uniform', 'features': 30},
#             Current best combo with val score 0.3618:
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
# Already Trained and Tested combination (val score of 0.0033):
#             {'n_neighbors': 36, 'p': 1, 'weights': 'uniform', 'features': 30}
#             Current best combo (with val score 0.3618):
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
#         Has trained 1942 of 20400 combinations so far
# Already Trained and Tested combination (val score of 0.2096):
#             {'n_neighbors': 36, 'p': 2, 'weights': 'distance', 'features': 30}
#             Current best combo (with val score 0.3618):
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
#         Has trained 1942 of 20400 combinations so far
# Trained and Tested combination 1943 of 20400, taking 0.01 seconds to get val score of 0.1972:
#                 {'n_neighbors': 36, 'p': 2, 'weights': 'uniform', 'features': 29},
#             Current best combo with val score 0.3618:
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
# Trained and Tested combination 1944 of 20400, taking 0.0 seconds to get val score of 0.1947:
#                 {'n_neighbors': 36, 'p': 2, 'weights': 'uniform', 'features': 31},
#             Current best combo with val score 0.3618:
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
# 	round 119 iteration:  1
#
# Trained and Tested combination 1945 of 20400, taking 0.01 seconds to get val score of 0.1684:
#                 {'n_neighbors': 34, 'p': 2, 'weights': 'uniform', 'features': 30},
#             Current best combo with val score 0.3618:
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
# Already Trained and Tested combination (val score of 0.1931):
#             {'n_neighbors': 36, 'p': 2, 'weights': 'uniform', 'features': 30}
#             Current best combo (with val score 0.3618):
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
#         Has trained 1945 of 20400 combinations so far
# Trained and Tested combination 1946 of 20400, taking 0.01 seconds to get val score of 0.0033:
#                 {'n_neighbors': 35, 'p': 1, 'weights': 'uniform', 'features': 30},
#             Current best combo with val score 0.3618:
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
# Trained and Tested combination 1947 of 20400, taking 0.0 seconds to get val score of 0.2112:
#                 {'n_neighbors': 35, 'p': 2, 'weights': 'distance', 'features': 30},
#             Current best combo with val score 0.3618:
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
# Trained and Tested combination 1948 of 20400, taking 0.0 seconds to get val score of 0.2067:
#                 {'n_neighbors': 35, 'p': 2, 'weights': 'uniform', 'features': 29},
#             Current best combo with val score 0.3618:
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
# Trained and Tested combination 1949 of 20400, taking 0.0 seconds to get val score of 0.1981:
#                 {'n_neighbors': 35, 'p': 2, 'weights': 'uniform', 'features': 31},
#             Current best combo with val score 0.3618:
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
# Already Trained and Tested combination (val score of 0.1931):
#             {'n_neighbors': 36, 'p': 2, 'weights': 'uniform', 'features': 30}
#             Current best combo (with val score 0.3618):
#                     {'n_neighbors': 100, 'p': 2, 'weights': 'distance', 'features': 26}
#         Has trained 1949 of 20400 combinations so far
