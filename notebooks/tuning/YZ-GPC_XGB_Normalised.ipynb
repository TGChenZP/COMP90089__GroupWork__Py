# %% [markdown]
# # Tuning Script

# %%
# Parameters subject to change in every script - involved in naming

MODEL = 'gpc'
PREPROCESSING = 'normalise'
TUNER = 'yangzhoub'
OPTIMISED_METRIC = 'f1'

# %% [markdown]
# ---

# %%
# detect whether this is a google environment

COLAB_ENVIRONMENT = False

try:
    from google.colab import drive
    drive.mount('/content/drive')
    COLAB_ENVIRONMENT = True
except:
    pass
# Out:
# Mounted at /content/drive

# %%
import sys
import os
import pickle

if COLAB_ENVIRONMENT:
    home_directory = './drive/MyDrive/LAB/COMP90089__GroupWork__Py/' # my home directory is stored in ./LAB of google drive
    if MODEL == 'ebr':
        # !pip install interpret==0.5.0
    elif MODEL == 'cbr':
        # !pip install catboost
    elif MODEL in ['tf', 'mlp']:
        # !pip install PyTorch2Sklearn
    # !pip install JXAutoML
else:
    home_directory = '../../'

from JXAutoML.YangZhouB_10CV import YangZhouB_10CV as Tuner

import pandas as pd
# Out:
# Collecting JXAutoML
#   Downloading JXAutoML-0.4.4-py3-none-any.whl.metadata (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.2/67.2 kB 1.9 MB/s eta 0:00:00
# Downloading JXAutoML-0.4.4-py3-none-any.whl (52 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.1/52.1 kB 3.4 MB/s eta 0:00:00
# Installing collected packages: JXAutoML
# Successfully installed JXAutoML-0.4.4

# %%
# Parameters that are same for every script

FOLDS = 10  # we have decided to do 10 fold validation

SEED = 42

TASK_TYPE = 'Classification'  # this task is a classification task

# we have decided to tune features as hp
TUNE_FEATURES_AS_HYPERPARAMETERS = True

# %% [markdown]
# ---

# %%
# model to use to tune
from sklearn.gaussian_process import GaussianProcessClassifier as clf

# what values to try for each hyperparameter
parameter_choices = {
    'max_iter_predict': (25, 50, 100, 200, 400),
    'n_restarts_optimizer': list(range(0, 4))
}

# what values to set non-tuneable parameters/hyperparameters
non_tunable_hyperparameters_dict = {
                                    'random_state': 42,
                                    'multi_class': 'one_vs_rest',
                                    'n_jobs': -1
                                    }

# %% [markdown]
# ---

# %% [markdown]
# Read in and Prepare Data

# %%
# Import data and store as lists

train_x_list = []
train_y_list = []
val_x_list = []
val_y_list = []

for i in range(FOLDS):
    train_data = pd.read_csv(
        f'{home_directory}data/curated/modelling/{PREPROCESSING}/train_{i}.csv')
    val_data = pd.read_csv(
        f'{home_directory}data/curated/modelling/{PREPROCESSING}/val_{i}.csv')

    # get the correct rows for X and y
    train_x = train_data.drop(
        ['mortality_status', 'subject_id', 'hadm_id', 'stay_id'], axis=1)
    train_y = train_data['mortality_status']
    val_x = val_data.drop(
        ['mortality_status', 'subject_id', 'hadm_id', 'stay_id'], axis=1)
    val_y = val_data['mortality_status']

    train_x_list.append(train_x)
    train_y_list.append(train_y)
    val_x_list.append(val_x)
    val_y_list.append(val_y)

# %%
# Import feature importance ordering

with open(f'{home_directory}models/xgb_feature_importance_ordering_{PREPROCESSING}.pickle', 'rb') as f:
    feature_importance_ordering = pickle.load(f)

# %% [markdown]
# Set parameters

# %%
# initialisation
tuner = Tuner()

print('---')

# define what model we are tuning
tuner.read_in_model(clf, TASK_TYPE, optimised_metric=OPTIMISED_METRIC)

print('---')

# read in the data for training and validation
tuner.read_in_data(train_x_list, train_y_list, val_x_list, val_y_list)

print('---')

# set what hp values to tune
tuner.set_hyperparameters(parameter_choices)
# WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

# set up hp values that need to be changed from default but NOT to be tuned
tuner.set_non_tuneable_hyperparameters(non_tunable_hyperparameters_dict)

print('---')

# set up feature importance ordering

if TUNE_FEATURES_AS_HYPERPARAMETERS:
    tuner.set_features(feature_importance_ordering)
    # WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

try:  # try to read in previous results to continue tuning ...
    tuner.read_in_tuning_result_df(
        f'{home_directory}models/tuning/{TUNER}_{MODEL}_{PREPROCESSING}.csv')
except:
    print('No previous tuning data read in')

print('---')

# set up where to save the tuning result csv
tuner.set_tuning_result_saving_address(
    f'{home_directory}models/tuning/{TUNER}_{MODEL}_{PREPROCESSING}.csv')

print('---')

# set up where to save the current best model
tuner.set_best_model_saving_address(
    f'{home_directory}models/tmp_models/{TUNER}_{MODEL}_{PREPROCESSING}')
# Out:
# YangZhouB Initialised
# ---
# Successfully read in model <class 'sklearn.gaussian_process._gpc.GaussianProcessClassifier'>, which is a Classification model optimising for f1
# ---
# Read in Train X data list
# Read in Train y data list
# Read in Val X data list
# Read in Val y data list
# ---
# Successfully recorded hyperparameter choices
# ---
# Successfully recorded non_tuneable_hyperparameter choices
# ---
# Successfully recorded tuneable feature combination choices and updated relevant internal structures
# ---
# No previous tuning data read in
# ---
# Successfully set tuning output address
# ---
# Successfully set best model output address

# %%
# ignore warnings

import warnings
warnings.filterwarnings("ignore")

# %%
# begin tuning ... (or continue training)

tuner.tune()
# Out:
# BEGIN TUNING
#
#
# STAGE ZERO: Tune all Cruise combinations
#
#
# Trained and Tested combination 1 of 1020, taking 12.4 seconds to get val score of 0.3117:
#                 {'max_iter_predict': 400, 'n_restarts_optimizer': 3, 'features': 50},
#             Current best combo with val score 0.3117:
#                     {'max_iter_predict': 400, 'n_restarts_optimizer': 3, 'features': 50}
# Trained and Tested combination 2 of 1020, taking 13.21 seconds to get val score of 0.0:
#                 {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 25},
#             Current best combo with val score 0.3117:
#                     {'max_iter_predict': 400, 'n_restarts_optimizer': 3, 'features': 50}
# Trained and Tested combination 3 of 1020, taking 23.23 seconds to get val score of 0.3244:
#                 {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 10},
#             Current best combo with val score 0.3244:
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 10}
# Trained and Tested combination 4 of 1020, taking 15.13 seconds to get val score of 0.0:
#                 {'max_iter_predict': 400, 'n_restarts_optimizer': 3, 'features': 20},
#             Current best combo with val score 0.3244:
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 10}
# Trained and Tested combination 5 of 1020, taking 14.99 seconds to get val score of 0.0:
#                 {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 20},
#             Current best combo with val score 0.3244:
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 10}
# Trained and Tested combination 6 of 1020, taking 12.59 seconds to get val score of 0.3117:
#                 {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 40},
#             Current best combo with val score 0.3244:
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 10}
# Trained and Tested combination 7 of 1020, taking 14.4 seconds to get val score of 0.3117:
#                 {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 45},
#             Current best combo with val score 0.3244:
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 10}
# Trained and Tested combination 8 of 1020, taking 14.81 seconds to get val score of 0.0:
#                 {'max_iter_predict': 400, 'n_restarts_optimizer': 3, 'features': 0},
#             Current best combo with val score 0.3244:
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 10}
# Trained and Tested combination 9 of 1020, taking 12.4 seconds to get val score of 0.3117:
#                 {'max_iter_predict': 400, 'n_restarts_optimizer': 3, 'features': 40},
#             Current best combo with val score 0.3244:
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 10}
# Trained and Tested combination 10 of 1020, taking 15.19 seconds to get val score of 0.0:
#                 {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 20},
#             Current best combo with val score 0.3244:
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 10}
# Trained and Tested combination 11 of 1020, taking 12.59 seconds to get val score of 0.3118:
#                 {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 35},
#             Current best combo with val score 0.3244:
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 10}
# Trained and Tested combination 12 of 1020, taking 12.91 seconds to get val score of 0.3117:
#                 {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 40},
#             Current best combo with val score 0.3244:
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 10}
# Trained and Tested combination 13 of 1020, taking 14.46 seconds to get val score of 0.0:
#                 {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 0},
#             Current best combo with val score 0.3244:
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 10}
# Trained and Tested combination 14 of 1020, taking 11.76 seconds to get val score of 0.3117:
#                 {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 45},
#             Current best combo with val score 0.3244:
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 10}
# Trained and Tested combination 15 of 1020, taking 13.94 seconds to get val score of 0.0:
#                 {'max_iter_predict': 400, 'n_restarts_optimizer': 3, 'features': 25},
#             Current best combo with val score 0.3244:
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 10}
# Trained and Tested combination 16 of 1020, taking 12.75 seconds to get val score of 0.3117:
#                 {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 50},
#             Current best combo with val score 0.3244:
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 10}
# Trained and Tested combination 17 of 1020, taking 14.16 seconds to get val score of 0.0:
#                 {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 30},
#             Current best combo with val score 0.3244:
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 10}
# Trained and Tested combination 18 of 1020, taking 16.66 seconds to get val score of 0.3148:
#                 {'max_iter_predict': 400, 'n_restarts_optimizer': 3, 'features': 5},
#             Current best combo with val score 0.3244:
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 10}
# Trained and Tested combination 19 of 1020, taking 16.01 seconds to get val score of 0.3244:
#                 {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 10},
#             Current best combo with val score 0.3244:
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 10}
# Trained and Tested combination 20 of 1020, taking 16.38 seconds to get val score of 0.3148:
#                 {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 5},
#             Current best combo with val score 0.3244:
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 10}
# Trained and Tested combination 21 of 1020, taking 12.38 seconds to get val score of 0.3118:
#                 {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 35},
#             Current best combo with val score 0.3244:
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 10}
# Trained and Tested combination 22 of 1020, taking 10.15 seconds to get val score of 0.3117:
#                 {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 45},
#             Current best combo with val score 0.3244:
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 10}
# Trained and Tested combination 23 of 1020, taking 16.46 seconds to get val score of 0.3244:
#                 {'max_iter_predict': 400, 'n_restarts_optimizer': 3, 'features': 10},
#             Current best combo with val score 0.3244:
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 10}
# Trained and Tested combination 24 of 1020, taking 12.6 seconds to get val score of 0.3117:
#                 {'max_iter_predict': 400, 'n_restarts_optimizer': 3, 'features': 45},
#             Current best combo with val score 0.3244:
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 10}
# Trained and Tested combination 25 of 1020, taking 16.16 seconds to get val score of 0.0:
#                 {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 15},
#             Current best combo with val score 0.3244:
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 10}
# Trained and Tested combination 26 of 1020, taking 14.74 seconds to get val score of 0.0:
#                 {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 0},
#             Current best combo with val score 0.3244:
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 10}
# Trained and Tested combination 27 of 1020, taking 16.05 seconds to get val score of 0.3244:
#                 {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 10},
#             Current best combo with val score 0.3244:
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 10}
# Trained and Tested combination 28 of 1020, taking 14.64 seconds to get val score of 0.0:
#                 {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 0},
#             Current best combo with val score 0.3244:
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 10}
# Trained and Tested combination 29 of 1020, taking 16.09 seconds to get val score of 0.0:
#                 {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 15},
#             Current best combo with val score 0.3244:
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 10}
# Trained and Tested combination 30 of 1020, taking 11.57 seconds to get val score of 0.0:
#                 {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 25},
#             Current best combo with val score 0.3244:
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 10}
# Trained and Tested combination 31 of 1020, taking 13.67 seconds to get val score of 0.0:
#                 {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 30},
#             Current best combo with val score 0.3244:
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 10}
# Trained and Tested combination 32 of 1020, taking 11.72 seconds to get val score of 0.3118:
#                 {'max_iter_predict': 400, 'n_restarts_optimizer': 3, 'features': 35},
#             Current best combo with val score 0.3244:
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 10}
# Trained and Tested combination 33 of 1020, taking 16.16 seconds to get val score of 0.0:
#                 {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 15},
#             Current best combo with val score 0.3244:
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 10}
# Trained and Tested combination 34 of 1020, taking 11.43 seconds to get val score of 0.3117:
#                 {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 40},
#             Current best combo with val score 0.3244:
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 10}
# Trained and Tested combination 35 of 1020, taking 14.97 seconds to get val score of 0.0:
#                 {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 20},
#             Current best combo with val score 0.3244:
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 10}
# Trained and Tested combination 36 of 1020, taking 13.14 seconds to get val score of 0.0:
#                 {'max_iter_predict': 400, 'n_restarts_optimizer': 3, 'features': 30},
#             Current best combo with val score 0.3244:
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 10}
# Trained and Tested combination 37 of 1020, taking 11.41 seconds to get val score of 0.3118:
#                 {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 35},
#             Current best combo with val score 0.3244:
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 10}
# Trained and Tested combination 38 of 1020, taking 13.84 seconds to get val score of 0.0:
#                 {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 30},
#             Current best combo with val score 0.3244:
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 10}
# Trained and Tested combination 39 of 1020, taking 13.18 seconds to get val score of 0.0:
#                 {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 25},
#             Current best combo with val score 0.3244:
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 10}
# Trained and Tested combination 40 of 1020, taking 16.11 seconds to get val score of 0.3148:
#                 {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 5},
#             Current best combo with val score 0.3244:
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 10}
# Trained and Tested combination 41 of 1020, taking 18.03 seconds to get val score of 0.0:
#                 {'max_iter_predict': 400, 'n_restarts_optimizer': 3, 'features': 15},
#             Current best combo with val score 0.3244:
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 10}
# Trained and Tested combination 42 of 1020, taking 10.96 seconds to get val score of 0.3117:
#                 {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 50},
#             Current best combo with val score 0.3244:
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 10}
# Trained and Tested combination 43 of 1020, taking 13.29 seconds to get val score of 0.0:
#                 {'max_iter_predict': 100, 'n_restarts_optimizer': 2, 'features': 25},
#             Current best combo with val score 0.3244:
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 10}
# Trained and Tested combination 44 of 1020, taking 16.58 seconds to get val score of 0.3148:
#                 {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 5},
#             Current best combo with val score 0.3244:
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 10}
# Trained and Tested combination 45 of 1020, taking 12.41 seconds to get val score of 0.3117:
#                 {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 50},
#             Current best combo with val score 0.3244:
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 10}
#
#
# STAGE ONE: Begin initial Guidance system
#
#
# Guidance: initial round
#
# 	round 0 iteration:  0
#
# Trained and Tested combination 46 of 1020, taking 13.05 seconds to get val score of 0.0:
#                 {'max_iter_predict': 50, 'n_restarts_optimizer': 2, 'features': 25},
#             Current best combo with val score 0.3244:
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 10}
# Trained and Tested combination 47 of 1020, taking 11.91 seconds to get val score of 0.0:
#                 {'max_iter_predict': 200, 'n_restarts_optimizer': 2, 'features': 25},
#             Current best combo with val score 0.3244:
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 10}
# Trained and Tested combination 48 of 1020, taking 13.33 seconds to get val score of 0.0:
#                 {'max_iter_predict': 100, 'n_restarts_optimizer': 1, 'features': 25},
#             Current best combo with val score 0.3244:
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 10}
# Trained and Tested combination 49 of 1020, taking 13.46 seconds to get val score of 0.0:
#                 {'max_iter_predict': 100, 'n_restarts_optimizer': 3, 'features': 25},
#             Current best combo with val score 0.3244:
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 10}
# Trained and Tested combination 50 of 1020, taking 12.45 seconds to get val score of 0.0:
#                 {'max_iter_predict': 100, 'n_restarts_optimizer': 2, 'features': 24},
#             Current best combo with val score 0.3244:
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 10}
# Trained and Tested combination 51 of 1020, taking 12.99 seconds to get val score of 0.0:
#                 {'max_iter_predict': 100, 'n_restarts_optimizer': 2, 'features': 26},
#             Current best combo with val score 0.3244:
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 10}
# 	round 0 iteration:  1
#
# Trained and Tested combination 52 of 1020, taking 12.82 seconds to get val score of 0.0:
#                 {'max_iter_predict': 25, 'n_restarts_optimizer': 2, 'features': 25},
#             Current best combo with val score 0.3244:
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 10}
# Already Trained and Tested combination (val score of 0.0):
#             {'max_iter_predict': 100, 'n_restarts_optimizer': 2, 'features': 25}
#             Current best combo (with val score 0.3244):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 10}
#         Has trained 52 of 1020 combinations so far
# Trained and Tested combination 53 of 1020, taking 10.61 seconds to get val score of 0.0:
#                 {'max_iter_predict': 50, 'n_restarts_optimizer': 1, 'features': 25},
#             Current best combo with val score 0.3244:
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 10}
# Trained and Tested combination 54 of 1020, taking 12.88 seconds to get val score of 0.0:
#                 {'max_iter_predict': 50, 'n_restarts_optimizer': 3, 'features': 25},
#             Current best combo with val score 0.3244:
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 10}
# Trained and Tested combination 55 of 1020, taking 12.18 seconds to get val score of 0.0:
#                 {'max_iter_predict': 50, 'n_restarts_optimizer': 2, 'features': 24},
#             Current best combo with val score 0.3244:
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 10}
# Trained and Tested combination 56 of 1020, taking 12.36 seconds to get val score of 0.0:
#                 {'max_iter_predict': 50, 'n_restarts_optimizer': 2, 'features': 26},
#             Current best combo with val score 0.3244:
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 10}
# Already Trained and Tested combination (val score of 0.0):
#             {'max_iter_predict': 100, 'n_restarts_optimizer': 2, 'features': 25}
#             Current best combo (with val score 0.3244):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 10}
#         Has trained 56 of 1020 combinations so far
# Trained and Tested combination 57 of 1020, taking 12.97 seconds to get val score of 0.0:
#                 {'max_iter_predict': 400, 'n_restarts_optimizer': 2, 'features': 25},
#             Current best combo with val score 0.3244:
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 10}
# Trained and Tested combination 58 of 1020, taking 10.72 seconds to get val score of 0.0:
#                 {'max_iter_predict': 200, 'n_restarts_optimizer': 1, 'features': 25},
#             Current best combo with val score 0.3244:
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 10}
# Trained and Tested combination 59 of 1020, taking 11.79 seconds to get val score of 0.0:
#                 {'max_iter_predict': 200, 'n_restarts_optimizer': 3, 'features': 25},
#             Current best combo with val score 0.3244:
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 10}
# Trained and Tested combination 60 of 1020, taking 12.07 seconds to get val score of 0.0:
#                 {'max_iter_predict': 200, 'n_restarts_optimizer': 2, 'features': 24},
#             Current best combo with val score 0.3244:
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 10}
# Trained and Tested combination 61 of 1020, taking 11.77 seconds to get val score of 0.0:
#                 {'max_iter_predict': 200, 'n_restarts_optimizer': 2, 'features': 26},
#             Current best combo with val score 0.3244:
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 10}
# Already Trained and Tested combination (val score of 0.0):
#             {'max_iter_predict': 50, 'n_restarts_optimizer': 1, 'features': 25}
#             Current best combo (with val score 0.3244):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 10}
#         Has trained 61 of 1020 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'max_iter_predict': 200, 'n_restarts_optimizer': 1, 'features': 25}
#             Current best combo (with val score 0.3244):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 10}
#         Has trained 61 of 1020 combinations so far
# Trained and Tested combination 62 of 1020, taking 13.01 seconds to get val score of 0.0:
#                 {'max_iter_predict': 100, 'n_restarts_optimizer': 0, 'features': 25},
#             Current best combo with val score 0.3244:
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 10}
# Already Trained and Tested combination (val score of 0.0):
#             {'max_iter_predict': 100, 'n_restarts_optimizer': 2, 'features': 25}
#             Current best combo (with val score 0.3244):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 10}
#         Has trained 62 of 1020 combinations so far
# Trained and Tested combination 63 of 1020, taking 12.37 seconds to get val score of 0.0:
#                 {'max_iter_predict': 100, 'n_restarts_optimizer': 1, 'features': 24},
#             Current best combo with val score 0.3244:
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 10}
# Trained and Tested combination 64 of 1020, taking 12.95 seconds to get val score of 0.0:
#                 {'max_iter_predict': 100, 'n_restarts_optimizer': 1, 'features': 26},
#             Current best combo with val score 0.3244:
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 10}
# Already Trained and Tested combination (val score of 0.0):
#             {'max_iter_predict': 50, 'n_restarts_optimizer': 3, 'features': 25}
#             Current best combo (with val score 0.3244):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 10}
#         Has trained 64 of 1020 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'max_iter_predict': 200, 'n_restarts_optimizer': 3, 'features': 25}
#             Current best combo (with val score 0.3244):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 10}
#         Has trained 64 of 1020 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'max_iter_predict': 100, 'n_restarts_optimizer': 2, 'features': 25}
#             Current best combo (with val score 0.3244):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 10}
#         Has trained 64 of 1020 combinations so far
# Trained and Tested combination 65 of 1020, taking 11.45 seconds to get val score of 0.0:
#                 {'max_iter_predict': 100, 'n_restarts_optimizer': 3, 'features': 24},
#             Current best combo with val score 0.3244:
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 10}
# Trained and Tested combination 66 of 1020, taking 12.89 seconds to get val score of 0.0:
#                 {'max_iter_predict': 100, 'n_restarts_optimizer': 3, 'features': 26},
#             Current best combo with val score 0.3244:
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 10}
# Already Trained and Tested combination (val score of 0.0):
#             {'max_iter_predict': 50, 'n_restarts_optimizer': 2, 'features': 24}
#             Current best combo (with val score 0.3244):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 10}
#         Has trained 66 of 1020 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'max_iter_predict': 200, 'n_restarts_optimizer': 2, 'features': 24}
#             Current best combo (with val score 0.3244):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 10}
#         Has trained 66 of 1020 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'max_iter_predict': 100, 'n_restarts_optimizer': 1, 'features': 24}
#             Current best combo (with val score 0.3244):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 10}
#         Has trained 66 of 1020 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'max_iter_predict': 100, 'n_restarts_optimizer': 3, 'features': 24}
#             Current best combo (with val score 0.3244):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 10}
#         Has trained 66 of 1020 combinations so far
# Trained and Tested combination 67 of 1020, taking 14.22 seconds to get val score of 0.0:
#                 {'max_iter_predict': 100, 'n_restarts_optimizer': 2, 'features': 23},
#             Current best combo with val score 0.3244:
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 10}
# Already Trained and Tested combination (val score of 0.0):
#             {'max_iter_predict': 100, 'n_restarts_optimizer': 2, 'features': 25}
#             Current best combo (with val score 0.3244):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 10}
#         Has trained 67 of 1020 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'max_iter_predict': 50, 'n_restarts_optimizer': 2, 'features': 26}
#             Current best combo (with val score 0.3244):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 10}
#         Has trained 67 of 1020 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'max_iter_predict': 200, 'n_restarts_optimizer': 2, 'features': 26}
#             Current best combo (with val score 0.3244):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 10}
#         Has trained 67 of 1020 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'max_iter_predict': 100, 'n_restarts_optimizer': 1, 'features': 26}
#             Current best combo (with val score 0.3244):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 10}
#         Has trained 67 of 1020 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'max_iter_predict': 100, 'n_restarts_optimizer': 3, 'features': 26}
#             Current best combo (with val score 0.3244):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 10}
#         Has trained 67 of 1020 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'max_iter_predict': 100, 'n_restarts_optimizer': 2, 'features': 25}
#             Current best combo (with val score 0.3244):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 10}
#         Has trained 67 of 1020 combinations so far
# Trained and Tested combination 68 of 1020, taking 11.45 seconds to get val score of 0.0033:
#                 {'max_iter_predict': 100, 'n_restarts_optimizer': 2, 'features': 27},
#             Current best combo with val score 0.3244:
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 10}
# Trained and Tested combination 69 of 1020, taking 15.41 seconds to get val score of 0.3244:
#                 {'max_iter_predict': 50, 'n_restarts_optimizer': 0, 'features': 10},
#             Current best combo with val score 0.3244:
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 10}
# Trained and Tested combination 70 of 1020, taking 15.67 seconds to get val score of 0.3244:
#                 {'max_iter_predict': 25, 'n_restarts_optimizer': 1, 'features': 10},
#             Current best combo with val score 0.3244:
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 10}
# Trained and Tested combination 71 of 1020, taking 16.02 seconds to get val score of 0.3249:
#                 {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 9},
#             Current best combo with val score 0.3249:
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 9}
# Trained and Tested combination 72 of 1020, taking 16.05 seconds to get val score of 0.0:
#                 {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 11},
#             Current best combo with val score 0.3249:
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 9}
# Trained and Tested combination 73 of 1020, taking 16.07 seconds to get val score of 0.3249:
#                 {'max_iter_predict': 50, 'n_restarts_optimizer': 0, 'features': 9},
#             Current best combo with val score 0.3249:
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 9}
# Trained and Tested combination 74 of 1020, taking 15.43 seconds to get val score of 0.3249:
#                 {'max_iter_predict': 25, 'n_restarts_optimizer': 1, 'features': 9},
#             Current best combo with val score 0.3249:
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 9}
# Trained and Tested combination 75 of 1020, taking 15.41 seconds to get val score of 0.3255:
#                 {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 8},
#             Current best combo with val score 0.3255:
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 8}
# Already Trained and Tested combination (val score of 0.3244):
#             {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 10}
#             Current best combo (with val score 0.3255):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 8}
#         Has trained 75 of 1020 combinations so far
# Trained and Tested combination 76 of 1020, taking 15.34 seconds to get val score of 0.3255:
#                 {'max_iter_predict': 50, 'n_restarts_optimizer': 0, 'features': 8},
#             Current best combo with val score 0.3255:
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 8}
# Trained and Tested combination 77 of 1020, taking 15.06 seconds to get val score of 0.3255:
#                 {'max_iter_predict': 25, 'n_restarts_optimizer': 1, 'features': 8},
#             Current best combo with val score 0.3255:
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 8}
# Trained and Tested combination 78 of 1020, taking 14.87 seconds to get val score of 0.3167:
#                 {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 7},
#             Current best combo with val score 0.3255:
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 8}
# Already Trained and Tested combination (val score of 0.3249):
#             {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 9}
#             Current best combo (with val score 0.3255):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 8}
#         Has trained 78 of 1020 combinations so far
# % Combos Checked Thus Far: 78 out of 1020 which is 7.6470590000000005%
# STAGE TWO: Begin Cruise system
#
#
# Cruising Coordrdinate 1 of 44
#
# Cruising Coordrdinate 2 of 44
#
# Cruising Coordrdinate 3 of 44
#
# Cruising Coordrdinate 4 of 44
#
# Cruising Coordrdinate 5 of 44
#
# Cruising Coordrdinate 6 of 44
#
# Cruising Coordrdinate 7 of 44
#
# Cruising Coordrdinate 8 of 44
#
# Cruising Coordrdinate 9 of 44
#
# Cruising Coordrdinate 10 of 44
#
# Cruising Coordrdinate 11 of 44
#
# Cruising Coordrdinate 12 of 44
#
# Cruising Coordrdinate 13 of 44
#
# Cruising Coordrdinate 14 of 44
#
# Cruising Coordrdinate 15 of 44
#
# Cruising Coordrdinate 16 of 44
#
# Cruising Coordrdinate 17 of 44
#
# Cruising Coordrdinate 18 of 44
#
# Cruising Coordrdinate 19 of 44
#
# Cruising Coordrdinate 20 of 44
#
# Cruising Coordrdinate 21 of 44
#
# Cruising Coordrdinate 22 of 44
#
# Cruising Coordrdinate 23 of 44
#
# Cruising Coordrdinate 24 of 44
#
# Cruising Coordrdinate 25 of 44
#
# Cruising Coordrdinate 26 of 44
#
# Cruising Coordrdinate 27 of 44
#
# Cruising Coordrdinate 28 of 44
#
# Cruising Coordrdinate 29 of 44
#
# Cruising Coordrdinate 30 of 44
#
# Cruising Coordrdinate 31 of 44
#
# Cruising Coordrdinate 32 of 44
#
# Cruising Coordrdinate 33 of 44
#
# Cruising Coordrdinate 34 of 44
#
# Cruising Coordrdinate 35 of 44
#
# Cruising Coordrdinate 36 of 44
#
# Cruising Coordrdinate 37 of 44
#
# Cruising Coordrdinate 38 of 44
#
# Cruise suspended due to suspicious case
# Guidance: round 1
#
# 	round 1 iteration:  0
#
# Trained and Tested combination 79 of 1020, taking 15.94 seconds to get val score of 0.3244:
#                 {'max_iter_predict': 200, 'n_restarts_optimizer': 3, 'features': 10},
#             Current best combo with val score 0.3255:
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 8}
# Trained and Tested combination 80 of 1020, taking 16.3 seconds to get val score of 0.3244:
#                 {'max_iter_predict': 400, 'n_restarts_optimizer': 2, 'features': 10},
#             Current best combo with val score 0.3255:
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 8}
# Trained and Tested combination 81 of 1020, taking 16.01 seconds to get val score of 0.3249:
#                 {'max_iter_predict': 400, 'n_restarts_optimizer': 3, 'features': 9},
#             Current best combo with val score 0.3255:
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 8}
# Trained and Tested combination 82 of 1020, taking 15.59 seconds to get val score of 0.0:
#                 {'max_iter_predict': 400, 'n_restarts_optimizer': 3, 'features': 11},
#             Current best combo with val score 0.3255:
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 8}
# 	round 1 iteration:  1
#
# Trained and Tested combination 83 of 1020, taking 15.43 seconds to get val score of 0.3244:
#                 {'max_iter_predict': 100, 'n_restarts_optimizer': 3, 'features': 10},
#             Current best combo with val score 0.3255:
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 8}
# Already Trained and Tested combination (val score of 0.3244):
#             {'max_iter_predict': 400, 'n_restarts_optimizer': 3, 'features': 10}
#             Current best combo (with val score 0.3255):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 8}
#         Has trained 83 of 1020 combinations so far
# Trained and Tested combination 84 of 1020, taking 15.36 seconds to get val score of 0.3244:
#                 {'max_iter_predict': 200, 'n_restarts_optimizer': 2, 'features': 10},
#             Current best combo with val score 0.3255:
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 8}
# Trained and Tested combination 85 of 1020, taking 15.04 seconds to get val score of 0.3249:
#                 {'max_iter_predict': 200, 'n_restarts_optimizer': 3, 'features': 9},
#             Current best combo with val score 0.3255:
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 8}
# Trained and Tested combination 86 of 1020, taking 15.13 seconds to get val score of 0.0:
#                 {'max_iter_predict': 200, 'n_restarts_optimizer': 3, 'features': 11},
#             Current best combo with val score 0.3255:
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 8}
# Already Trained and Tested combination (val score of 0.3244):
#             {'max_iter_predict': 200, 'n_restarts_optimizer': 2, 'features': 10}
#             Current best combo (with val score 0.3255):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 8}
#         Has trained 86 of 1020 combinations so far
# Trained and Tested combination 87 of 1020, taking 15.05 seconds to get val score of 0.3244:
#                 {'max_iter_predict': 400, 'n_restarts_optimizer': 1, 'features': 10},
#             Current best combo with val score 0.3255:
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 8}
# Already Trained and Tested combination (val score of 0.3244):
#             {'max_iter_predict': 400, 'n_restarts_optimizer': 3, 'features': 10}
#             Current best combo (with val score 0.3255):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 8}
#         Has trained 87 of 1020 combinations so far
# Trained and Tested combination 88 of 1020, taking 15.63 seconds to get val score of 0.3249:
#                 {'max_iter_predict': 400, 'n_restarts_optimizer': 2, 'features': 9},
#             Current best combo with val score 0.3255:
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 8}
# Trained and Tested combination 89 of 1020, taking 14.81 seconds to get val score of 0.0:
#                 {'max_iter_predict': 400, 'n_restarts_optimizer': 2, 'features': 11},
#             Current best combo with val score 0.3255:
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 8}
# Already Trained and Tested combination (val score of 0.3249):
#             {'max_iter_predict': 200, 'n_restarts_optimizer': 3, 'features': 9}
#             Current best combo (with val score 0.3255):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 8}
#         Has trained 89 of 1020 combinations so far
# Already Trained and Tested combination (val score of 0.3249):
#             {'max_iter_predict': 400, 'n_restarts_optimizer': 2, 'features': 9}
#             Current best combo (with val score 0.3255):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 8}
#         Has trained 89 of 1020 combinations so far
# Trained and Tested combination 90 of 1020, taking 15.27 seconds to get val score of 0.3255:
#                 {'max_iter_predict': 400, 'n_restarts_optimizer': 3, 'features': 8},
#             Current best combo with val score 0.3255:
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 8}
# Already Trained and Tested combination (val score of 0.3244):
#             {'max_iter_predict': 400, 'n_restarts_optimizer': 3, 'features': 10}
#             Current best combo (with val score 0.3255):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 8}
#         Has trained 90 of 1020 combinations so far
# % Combos Checked Thus Far: 90 out of 1020 which is 8.823528999999999%
# Cruising Coordrdinate 39 of 44
#
# Cruising Coordrdinate 40 of 44
#
# Cruise suspended due to suspicious case
# Guidance: round 2
#
# 	round 2 iteration:  0
#
# Trained and Tested combination 91 of 1020, taking 15.28 seconds to get val score of 0.3244:
#                 {'max_iter_predict': 200, 'n_restarts_optimizer': 0, 'features': 10},
#             Current best combo with val score 0.3255:
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 8}
# Already Trained and Tested combination (val score of 0.3244):
#             {'max_iter_predict': 400, 'n_restarts_optimizer': 1, 'features': 10}
#             Current best combo (with val score 0.3255):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 8}
#         Has trained 91 of 1020 combinations so far
# Trained and Tested combination 92 of 1020, taking 15.27 seconds to get val score of 0.3249:
#                 {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 9},
#             Current best combo with val score 0.3255:
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 8}
# Trained and Tested combination 93 of 1020, taking 16.64 seconds to get val score of 0.0:
#                 {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 11},
#             Current best combo with val score 0.3255:
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 8}
# 	round 2 iteration:  1
#
# Trained and Tested combination 94 of 1020, taking 16.3 seconds to get val score of 0.3244:
#                 {'max_iter_predict': 100, 'n_restarts_optimizer': 0, 'features': 10},
#             Current best combo with val score 0.3255:
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 8}
# Already Trained and Tested combination (val score of 0.3244):
#             {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 10}
#             Current best combo (with val score 0.3255):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 8}
#         Has trained 94 of 1020 combinations so far
# Trained and Tested combination 95 of 1020, taking 16.86 seconds to get val score of 0.3244:
#                 {'max_iter_predict': 200, 'n_restarts_optimizer': 1, 'features': 10},
#             Current best combo with val score 0.3255:
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 8}
# Trained and Tested combination 96 of 1020, taking 15.53 seconds to get val score of 0.3249:
#                 {'max_iter_predict': 200, 'n_restarts_optimizer': 0, 'features': 9},
#             Current best combo with val score 0.3255:
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 8}
# Trained and Tested combination 97 of 1020, taking 15.77 seconds to get val score of 0.0:
#                 {'max_iter_predict': 200, 'n_restarts_optimizer': 0, 'features': 11},
#             Current best combo with val score 0.3255:
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 8}
# Already Trained and Tested combination (val score of 0.3249):
#             {'max_iter_predict': 200, 'n_restarts_optimizer': 0, 'features': 9}
#             Current best combo (with val score 0.3255):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 8}
#         Has trained 97 of 1020 combinations so far
# Trained and Tested combination 98 of 1020, taking 15.89 seconds to get val score of 0.3249:
#                 {'max_iter_predict': 400, 'n_restarts_optimizer': 1, 'features': 9},
#             Current best combo with val score 0.3255:
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 8}
# Trained and Tested combination 99 of 1020, taking 15.39 seconds to get val score of 0.3255:
#                 {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 8},
#             Current best combo with val score 0.3255:
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 8}
# Already Trained and Tested combination (val score of 0.3244):
#             {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 10}
#             Current best combo (with val score 0.3255):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 8}
#         Has trained 99 of 1020 combinations so far
# % Combos Checked Thus Far: 99 out of 1020 which is 9.705882%
# Cruising Coordrdinate 41 of 44
#
# Cruising Coordrdinate 42 of 44
#
# Cruise suspended due to suspicious case
# Guidance: round 3
#
# 	round 3 iteration:  0
#
# Trained and Tested combination 100 of 1020, taking 15.89 seconds to get val score of 0.3244:
#                 {'max_iter_predict': 50, 'n_restarts_optimizer': 3, 'features': 10},
#             Current best combo with val score 0.3255:
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 8}
# Trained and Tested combination 101 of 1020, taking 15.24 seconds to get val score of 0.3244:
#                 {'max_iter_predict': 25, 'n_restarts_optimizer': 2, 'features': 10},
#             Current best combo with val score 0.3255:
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 8}
# Trained and Tested combination 102 of 1020, taking 16.36 seconds to get val score of 0.3249:
#                 {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 9},
#             Current best combo with val score 0.3255:
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 8}
# Trained and Tested combination 103 of 1020, taking 16.37 seconds to get val score of 0.0:
#                 {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 11},
#             Current best combo with val score 0.3255:
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 8}
# 	round 3 iteration:  1
#
# Already Trained and Tested combination (val score of 0.3244):
#             {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 10}
#             Current best combo (with val score 0.3255):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 8}
#         Has trained 103 of 1020 combinations so far
# Already Trained and Tested combination (val score of 0.3244):
#             {'max_iter_predict': 100, 'n_restarts_optimizer': 3, 'features': 10}
#             Current best combo (with val score 0.3255):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 8}
#         Has trained 103 of 1020 combinations so far
# Trained and Tested combination 104 of 1020, taking 15.76 seconds to get val score of 0.3244:
#                 {'max_iter_predict': 50, 'n_restarts_optimizer': 2, 'features': 10},
#             Current best combo with val score 0.3255:
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 8}
# Trained and Tested combination 105 of 1020, taking 15.51 seconds to get val score of 0.3249:
#                 {'max_iter_predict': 50, 'n_restarts_optimizer': 3, 'features': 9},
#             Current best combo with val score 0.3255:
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 8}
# Trained and Tested combination 106 of 1020, taking 16.48 seconds to get val score of 0.0:
#                 {'max_iter_predict': 50, 'n_restarts_optimizer': 3, 'features': 11},
#             Current best combo with val score 0.3255:
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 8}
# Already Trained and Tested combination (val score of 0.3244):
#             {'max_iter_predict': 50, 'n_restarts_optimizer': 2, 'features': 10}
#             Current best combo (with val score 0.3255):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 8}
#         Has trained 106 of 1020 combinations so far
# Already Trained and Tested combination (val score of 0.3244):
#             {'max_iter_predict': 25, 'n_restarts_optimizer': 1, 'features': 10}
#             Current best combo (with val score 0.3255):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 8}
#         Has trained 106 of 1020 combinations so far
# Already Trained and Tested combination (val score of 0.3244):
#             {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 10}
#             Current best combo (with val score 0.3255):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 8}
#         Has trained 106 of 1020 combinations so far
# Trained and Tested combination 107 of 1020, taking 15.76 seconds to get val score of 0.3249:
#                 {'max_iter_predict': 25, 'n_restarts_optimizer': 2, 'features': 9},
#             Current best combo with val score 0.3255:
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 8}
# Trained and Tested combination 108 of 1020, taking 15.42 seconds to get val score of 0.0:
#                 {'max_iter_predict': 25, 'n_restarts_optimizer': 2, 'features': 11},
#             Current best combo with val score 0.3255:
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 8}
# Already Trained and Tested combination (val score of 0.3249):
#             {'max_iter_predict': 50, 'n_restarts_optimizer': 3, 'features': 9}
#             Current best combo (with val score 0.3255):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 8}
#         Has trained 108 of 1020 combinations so far
# Already Trained and Tested combination (val score of 0.3249):
#             {'max_iter_predict': 25, 'n_restarts_optimizer': 2, 'features': 9}
#             Current best combo (with val score 0.3255):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 8}
#         Has trained 108 of 1020 combinations so far
# Trained and Tested combination 109 of 1020, taking 14.81 seconds to get val score of 0.3255:
#                 {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 8},
#             Current best combo with val score 0.3255:
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 8}
# Already Trained and Tested combination (val score of 0.3244):
#             {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 10}
#             Current best combo (with val score 0.3255):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 8}
#         Has trained 109 of 1020 combinations so far
# % Combos Checked Thus Far: 109 out of 1020 which is 10.686275%
# Cruising Coordrdinate 43 of 44
#
# Cruising Coordrdinate 44 of 44
#
# Cruise suspended due to suspicious case
# Guidance: round 4
#
# 	round 4 iteration:  0
#
# Already Trained and Tested combination (val score of 0.3244):
#             {'max_iter_predict': 50, 'n_restarts_optimizer': 0, 'features': 10}
#             Current best combo (with val score 0.3255):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 8}
#         Has trained 109 of 1020 combinations so far
# Already Trained and Tested combination (val score of 0.3244):
#             {'max_iter_predict': 25, 'n_restarts_optimizer': 1, 'features': 10}
#             Current best combo (with val score 0.3255):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 8}
#         Has trained 109 of 1020 combinations so far
# Already Trained and Tested combination (val score of 0.3249):
#             {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 9}
#             Current best combo (with val score 0.3255):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 8}
#         Has trained 109 of 1020 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 11}
#             Current best combo (with val score 0.3255):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 8}
#         Has trained 109 of 1020 combinations so far
# 	round 4 iteration:  1
#
# Already Trained and Tested combination (val score of 0.3244):
#             {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 10}
#             Current best combo (with val score 0.3255):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 8}
#         Has trained 109 of 1020 combinations so far
# Already Trained and Tested combination (val score of 0.3244):
#             {'max_iter_predict': 100, 'n_restarts_optimizer': 0, 'features': 10}
#             Current best combo (with val score 0.3255):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 8}
#         Has trained 109 of 1020 combinations so far
# Trained and Tested combination 110 of 1020, taking 16.01 seconds to get val score of 0.3244:
#                 {'max_iter_predict': 50, 'n_restarts_optimizer': 1, 'features': 10},
#             Current best combo with val score 0.3255:
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 8}
# Already Trained and Tested combination (val score of 0.3249):
#             {'max_iter_predict': 50, 'n_restarts_optimizer': 0, 'features': 9}
#             Current best combo (with val score 0.3255):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 8}
#         Has trained 110 of 1020 combinations so far
# Trained and Tested combination 111 of 1020, taking 15.33 seconds to get val score of 0.0:
#                 {'max_iter_predict': 50, 'n_restarts_optimizer': 0, 'features': 11},
#             Current best combo with val score 0.3255:
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 8}
# Already Trained and Tested combination (val score of 0.3249):
#             {'max_iter_predict': 50, 'n_restarts_optimizer': 0, 'features': 9}
#             Current best combo (with val score 0.3255):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 8}
#         Has trained 111 of 1020 combinations so far
# Already Trained and Tested combination (val score of 0.3249):
#             {'max_iter_predict': 25, 'n_restarts_optimizer': 1, 'features': 9}
#             Current best combo (with val score 0.3255):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 8}
#         Has trained 111 of 1020 combinations so far
# Already Trained and Tested combination (val score of 0.3255):
#             {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 8}
#             Current best combo (with val score 0.3255):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 8}
#         Has trained 111 of 1020 combinations so far
# Already Trained and Tested combination (val score of 0.3244):
#             {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 10}
#             Current best combo (with val score 0.3255):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 8}
#         Has trained 111 of 1020 combinations so far
# % Combos Checked Thus Far: 111 out of 1020 which is 10.882353%
# FINAL STAGE: Begin final Guidance system
#
#
# Guidance: round FINAL
#
# 	round FINAL iteration:  0
#
# Already Trained and Tested combination (val score of 0.3255):
#             {'max_iter_predict': 50, 'n_restarts_optimizer': 0, 'features': 8}
#             Current best combo (with val score 0.3255):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 8}
#         Has trained 111 of 1020 combinations so far
# Already Trained and Tested combination (val score of 0.3255):
#             {'max_iter_predict': 25, 'n_restarts_optimizer': 1, 'features': 8}
#             Current best combo (with val score 0.3255):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 8}
#         Has trained 111 of 1020 combinations so far
# Already Trained and Tested combination (val score of 0.3167):
#             {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 7}
#             Current best combo (with val score 0.3255):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 8}
#         Has trained 111 of 1020 combinations so far
# Already Trained and Tested combination (val score of 0.3249):
#             {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 9}
#             Current best combo (with val score 0.3255):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 8}
#         Has trained 111 of 1020 combinations so far
# 	round FINAL iteration:  1
#
# Already Trained and Tested combination (val score of 0.3255):
#             {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 8}
#             Current best combo (with val score 0.3255):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 8}
#         Has trained 111 of 1020 combinations so far
# Trained and Tested combination 112 of 1020, taking 15.11 seconds to get val score of 0.3255:
#                 {'max_iter_predict': 100, 'n_restarts_optimizer': 0, 'features': 8},
#             Current best combo with val score 0.3255:
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 8}
# Trained and Tested combination 113 of 1020, taking 15.04 seconds to get val score of 0.3255:
#                 {'max_iter_predict': 50, 'n_restarts_optimizer': 1, 'features': 8},
#             Current best combo with val score 0.3255:
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 8}
# Trained and Tested combination 114 of 1020, taking 15.0 seconds to get val score of 0.3167:
#                 {'max_iter_predict': 50, 'n_restarts_optimizer': 0, 'features': 7},
#             Current best combo with val score 0.3255:
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 8}
# Already Trained and Tested combination (val score of 0.3249):
#             {'max_iter_predict': 50, 'n_restarts_optimizer': 0, 'features': 9}
#             Current best combo (with val score 0.3255):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 8}
#         Has trained 114 of 1020 combinations so far
# Already Trained and Tested combination (val score of 0.3255):
#             {'max_iter_predict': 50, 'n_restarts_optimizer': 1, 'features': 8}
#             Current best combo (with val score 0.3255):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 8}
#         Has trained 114 of 1020 combinations so far
# Already Trained and Tested combination (val score of 0.3255):
#             {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 8}
#             Current best combo (with val score 0.3255):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 8}
#         Has trained 114 of 1020 combinations so far
# Trained and Tested combination 115 of 1020, taking 14.91 seconds to get val score of 0.3255:
#                 {'max_iter_predict': 25, 'n_restarts_optimizer': 2, 'features': 8},
#             Current best combo with val score 0.3255:
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 8}
# Trained and Tested combination 116 of 1020, taking 15.45 seconds to get val score of 0.3167:
#                 {'max_iter_predict': 25, 'n_restarts_optimizer': 1, 'features': 7},
#             Current best combo with val score 0.3255:
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 8}
# Already Trained and Tested combination (val score of 0.3249):
#             {'max_iter_predict': 25, 'n_restarts_optimizer': 1, 'features': 9}
#             Current best combo (with val score 0.3255):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 8}
#         Has trained 116 of 1020 combinations so far
# % Combos Checked Thus Far: 116 out of 1020 which is 11.372549%
# Max Val Score:
#  0.325525
# Max Val Score Std:
#  0.062746
# Best Combo Train Score:
#  0.617527
# Best Combo Train Score Std:
#  0.00724
# Max Combo Index:
#  (0, 0, 8) out of [5, 4, 51] (note best combo is 0-indexed)
# Max Combo Hyperparamer Combination:
#  {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 8}
# Max Combo Features:
#  ('procedure_225792', 'ventilation_used', 'lods_score', 'race_AMERICAN INDIAN/ALASKA NATIVE', 'race_ASIAN', 'race_ASIAN - ASIAN INDIAN', 'race_ASIAN - CHINESE', 'race_ASIAN - KOREAN', 'race_ASIAN - SOUTH EAST ASIAN', 'race_BLACK/AFRICAN', 'race_BLACK/AFRICAN AMERICAN', 'race_BLACK/CAPE VERDEAN', 'race_BLACK/CARIBBEAN ISLAND', 'race_HISPANIC/LATINO - CENTRAL AMERICAN', 'race_HISPANIC/LATINO - COLUMBIAN', 'race_HISPANIC/LATINO - CUBAN', 'race_HISPANIC/LATINO - DOMINICAN', 'race_HISPANIC/LATINO - GUATEMALAN', 'race_HISPANIC/LATINO - HONDURAN', 'race_HISPANIC/LATINO - MEXICAN', 'race_HISPANIC/LATINO - PUERTO RICAN', 'race_HISPANIC/LATINO - SALVADORAN', 'race_MULTIPLE RACE/ETHNICITY', 'race_NATIVE HAWAIIAN OR OTHER PACIFIC ISLANDER', 'race_OTHER', 'race_PATIENT DECLINED TO ANSWER', 'race_PORTUGUESE', 'race_SOUTH AMERICAN', 'race_UNABLE TO OBTAIN', 'race_UNKNOWN', 'race_WHITE', 'race_WHITE - BRAZILIAN', 'race_WHITE - EASTERN EUROPEAN', 'race_WHITE - OTHER EUROPEAN', 'race_WHITE - RUSSIAN', 'race_HISPANIC OR LATINO', 'marital_status_DIVORCED', 'marital_status_MARRIED', 'marital_status_SINGLE', 'marital_status_WIDOWED', 'marital_status_0', 'hospital_stay_duration', 'procedure_225464', 'procedure_225802', 'procedure_227712')
# % Combos Checked: 116 out of 1020 which is 11.372549%
