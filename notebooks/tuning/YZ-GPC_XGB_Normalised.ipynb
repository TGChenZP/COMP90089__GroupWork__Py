# %% [markdown]
# # Tuning Script

# %%
# Parameters subject to change in every script - involved in naming

MODEL = 'gpc'
PREPROCESSING = 'normalise'
TUNER = 'yangzhoub'
OPTIMISED_METRIC = 'f1'

# %% [markdown]
# ---

# %%
# detect whether this is a google environment

COLAB_ENVIRONMENT = False

try:
    from google.colab import drive
    drive.mount('/content/drive')
    COLAB_ENVIRONMENT = True
except:
    pass
# Out:
# Mounted at /content/drive

# %%
import sys
import os
import pickle

if COLAB_ENVIRONMENT:
    home_directory = './drive/MyDrive/LAB/COMP90089__GroupWork__Py/' # my home directory is stored in ./LAB of google drive
    if MODEL == 'ebr':
        # !pip install interpret==0.5.0
    elif MODEL == 'cbr':
        # !pip install catboost
    elif MODEL in ['tf', 'mlp']:
        # !pip install PyTorch2Sklearn
    # !pip install JXAutoML
else:
    home_directory = '../../'

from JXAutoML.YangZhouB_10CV import YangZhouB_10CV as Tuner

import pandas as pd
# Out:
# Collecting JXAutoML
#   Downloading JXAutoML-0.4.4-py3-none-any.whl.metadata (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.2/67.2 kB 3.2 MB/s eta 0:00:00
# Downloading JXAutoML-0.4.4-py3-none-any.whl (52 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.1/52.1 kB 3.4 MB/s eta 0:00:00
# Installing collected packages: JXAutoML
# Successfully installed JXAutoML-0.4.4

# %%
# Parameters that are same for every script

FOLDS = 10  # we have decided to do 10 fold validation

SEED = 42

TASK_TYPE = 'Classification'  # this task is a classification task

# we have decided to tune features as hp
TUNE_FEATURES_AS_HYPERPARAMETERS = True

# %% [markdown]
# ---

# %%
# model to use to tune
from sklearn.gaussian_process import GaussianProcessClassifier as clf

# what values to try for each hyperparameter
parameter_choices = {
    'max_iter_predict': (25, 50, 100, 200, 400),
    'n_restarts_optimizer': list(range(0, 4))
}

# what values to set non-tuneable parameters/hyperparameters
non_tunable_hyperparameters_dict = {
                                    'random_state': 42,
                                    'multi_class': 'one_vs_rest',
                                    'n_jobs': -1
                                    }

# %% [markdown]
# ---

# %% [markdown]
# Read in and Prepare Data

# %%
# Import data and store as lists

train_x_list = []
train_y_list = []
val_x_list = []
val_y_list = []

for i in range(FOLDS):
    train_data = pd.read_csv(
        f'{home_directory}data/curated/modelling/{PREPROCESSING}/train_{i}.csv')
    val_data = pd.read_csv(
        f'{home_directory}data/curated/modelling/{PREPROCESSING}/val_{i}.csv')

    # get the correct rows for X and y
    train_x = train_data.drop(
        ['mortality_status', 'subject_id', 'hadm_id', 'stay_id'], axis=1)
    train_y = train_data['mortality_status']
    val_x = val_data.drop(
        ['mortality_status', 'subject_id', 'hadm_id', 'stay_id'], axis=1)
    val_y = val_data['mortality_status']

    train_x_list.append(train_x)
    train_y_list.append(train_y)
    val_x_list.append(val_x)
    val_y_list.append(val_y)

# %%
# Import feature importance ordering

with open(f'{home_directory}models/xgb_feature_importance_ordering_{PREPROCESSING}.pickle', 'rb') as f:
    feature_importance_ordering = pickle.load(f)

# %% [markdown]
# Set parameters

# %%
# initialisation
tuner = Tuner()

print('---')

# define what model we are tuning
tuner.read_in_model(clf, TASK_TYPE, optimised_metric=OPTIMISED_METRIC)

print('---')

# read in the data for training and validation
tuner.read_in_data(train_x_list, train_y_list, val_x_list, val_y_list)

print('---')

# set what hp values to tune
tuner.set_hyperparameters(parameter_choices)
# WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

# set up hp values that need to be changed from default but NOT to be tuned
tuner.set_non_tuneable_hyperparameters(non_tunable_hyperparameters_dict)

print('---')

# set up feature importance ordering

if TUNE_FEATURES_AS_HYPERPARAMETERS:
    tuner.set_features(feature_importance_ordering)
    # WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

try:  # try to read in previous results to continue tuning ...
    tuner.read_in_tuning_result_df(
        f'{home_directory}models/tuning/{TUNER}_{MODEL}_{PREPROCESSING}.csv')
except:
    print('No previous tuning data read in')

print('---')

# set up where to save the tuning result csv
tuner.set_tuning_result_saving_address(
    f'{home_directory}models/tuning/{TUNER}_{MODEL}_{PREPROCESSING}.csv')

print('---')

# set up where to save the current best model
tuner.set_best_model_saving_address(
    f'{home_directory}models/tmp_models/{TUNER}_{MODEL}_{PREPROCESSING}')
# Out:
# YangZhouB Initialised
# ---
# Successfully read in model <class 'sklearn.gaussian_process._gpc.GaussianProcessClassifier'>, which is a Classification model optimising for f1
# ---
# Read in Train X data list
# Read in Train y data list
# Read in Val X data list
# Read in Val y data list
# ---
# Successfully recorded hyperparameter choices
# ---
# Successfully recorded non_tuneable_hyperparameter choices
# ---
# Successfully recorded tuneable feature combination choices and updated relevant internal structures
# ---
# Error message: 5.0
# Error Importing this Row: (0, max_iter_predict                                                     25.0
# n_restarts_optimizer                                                  5.0
# features                ['procedure_228130', 'procedure_225792', 'proc...
# random_state                                                         42.0
# multi_class                                                   one_vs_rest
#                                               ...
# Mean Val f1                                                           0.0
# Mean Val f1 Std                                                       0.0
# Mean Train f1                                                    0.882018
# Mean Train f1 Std                                                0.004321
# Precedence                                                            0.0
# Name: 0, Length: 163, dtype: object)
# Error message: 800.0
# Error Importing this Row: (1, max_iter_predict                                                    800.0
# n_restarts_optimizer                                                  0.0
# features                ['procedure_228130', 'procedure_225792', 'proc...
# random_state                                                         42.0
# multi_class                                                   one_vs_rest
#                                               ...
# Mean Val f1                                                      0.308578
# Mean Val f1 Std                                                  0.000395
# Mean Train f1                                                    0.939586
# Mean Train f1 Std                                                0.002334
# Precedence                                                            1.0
# Name: 1, Length: 163, dtype: object)
# Error message: 800.0
# Error Importing this Row: (2, max_iter_predict                                                    800.0
# n_restarts_optimizer                                                  5.0
# features                ['procedure_228130', 'procedure_225792', 'proc...
# random_state                                                         42.0
# multi_class                                                   one_vs_rest
#                                               ...
# Mean Val f1                                                      0.308578
# Mean Val f1 Std                                                  0.000395
# Mean Train f1                                                    0.995269
# Mean Train f1 Std                                                0.000736
# Precedence                                                            2.0
# Name: 2, Length: 163, dtype: object)
# Error message: 800.0
# Error Importing this Row: (3, max_iter_predict                                                    800.0
# n_restarts_optimizer                                                  5.0
# features                ['procedure_228130', 'procedure_225792', 'proc...
# random_state                                                         42.0
# multi_class                                                   one_vs_rest
#                                               ...
# Mean Val f1                                                      0.308578
# Mean Val f1 Std                                                  0.000395
# Mean Train f1                                                         1.0
# Mean Train f1 Std                                                     0.0
# Precedence                                                            3.0
# Name: 3, Length: 163, dtype: object)
# Error message: 5.0
# Error Importing this Row: (4, max_iter_predict                                                     25.0
# n_restarts_optimizer                                                  5.0
# features                ['procedure_228130', 'procedure_225792', 'proc...
# random_state                                                         42.0
# multi_class                                                   one_vs_rest
#                                               ...
# Mean Val f1                                                      0.510246
# Mean Val f1 Std                                                  0.058661
# Mean Train f1                                                    0.731509
# Mean Train f1 Std                                                0.005348
# Precedence                                                            4.0
# Name: 4, Length: 163, dtype: object)
# Error message: 800.0
# Error Importing this Row: (5, max_iter_predict                                                    800.0
# n_restarts_optimizer                                                  5.0
# features                ['procedure_228130', 'procedure_225792', 'proc...
# random_state                                                         42.0
# multi_class                                                   one_vs_rest
#                                               ...
# Mean Val f1                                                      0.263946
# Mean Val f1 Std                                                  0.052844
# Mean Train f1                                                    0.412888
# Mean Train f1 Std                                                0.008463
# Precedence                                                            5.0
# Name: 5, Length: 163, dtype: object)
# Error message: 800.0
# Error Importing this Row: (6, max_iter_predict                                                    800.0
# n_restarts_optimizer                                                  0.0
# features                ['procedure_228130', 'procedure_225792', 'proc...
# random_state                                                         42.0
# multi_class                                                   one_vs_rest
#                                               ...
# Mean Val f1                                                           0.0
# Mean Val f1 Std                                                       0.0
# Mean Train f1                                                    0.882018
# Mean Train f1 Std                                                0.004321
# Precedence                                                            6.0
# Name: 6, Length: 163, dtype: object)
# Error message: 800.0
# Error Importing this Row: (7, max_iter_predict                                                    800.0
# n_restarts_optimizer                                                  0.0
# features                ['procedure_228130', 'procedure_225792', 'proc...
# random_state                                                         42.0
# multi_class                                                   one_vs_rest
#                                               ...
# Mean Val f1                                                      0.308578
# Mean Val f1 Std                                                  0.000395
# Mean Train f1                                                         1.0
# Mean Train f1 Std                                                     0.0
# Precedence                                                            7.0
# Name: 7, Length: 163, dtype: object)
# Error message: 5.0
# Error Importing this Row: (8, max_iter_predict                                                     25.0
# n_restarts_optimizer                                                  5.0
# features                ['procedure_228130', 'procedure_225792', 'proc...
# random_state                                                         42.0
# multi_class                                                   one_vs_rest
#                                               ...
# Mean Val f1                                                      0.263946
# Mean Val f1 Std                                                  0.052844
# Mean Train f1                                                    0.412888
# Mean Train f1 Std                                                0.008463
# Precedence                                                            8.0
# Name: 8, Length: 163, dtype: object)
# Error message: 5.0
# Error Importing this Row: (11, max_iter_predict                                                     25.0
# n_restarts_optimizer                                                  5.0
# features                ['procedure_228130', 'procedure_225792', 'proc...
# random_state                                                         42.0
# multi_class                                                   one_vs_rest
#                                               ...
# Mean Val f1                                                      0.308578
# Mean Val f1 Std                                                  0.000395
# Mean Train f1                                                    0.997356
# Mean Train f1 Std                                                0.000709
# Precedence                                                           11.0
# Name: 11, Length: 163, dtype: object)
# Error message: 800.0
# Error Importing this Row: (14, max_iter_predict                                                    800.0
# n_restarts_optimizer                                                  0.0
# features                ['procedure_228130', 'procedure_225792', 'proc...
# random_state                                                         42.0
# multi_class                                                   one_vs_rest
#                                               ...
# Mean Val f1                                                       0.51278
# Mean Val f1 Std                                                  0.046603
# Mean Train f1                                                    0.675174
# Mean Train f1 Std                                                0.004679
# Precedence                                                           14.0
# Name: 14, Length: 163, dtype: object)
# Error message: 800.0
# Error Importing this Row: (16, max_iter_predict                                                    800.0
# n_restarts_optimizer                                                  0.0
# features                ['procedure_228130', 'procedure_225792', 'proc...
# random_state                                                         42.0
# multi_class                                                   one_vs_rest
#                                               ...
# Mean Val f1                                                           0.0
# Mean Val f1 Std                                                       0.0
# Mean Train f1                                                    0.810283
# Mean Train f1 Std                                                0.003287
# Precedence                                                           16.0
# Name: 16, Length: 163, dtype: object)
# Error message: 5.0
# Error Importing this Row: (17, max_iter_predict                                                     25.0
# n_restarts_optimizer                                                  5.0
# features                ['procedure_228130', 'procedure_225792', 'proc...
# random_state                                                         42.0
# multi_class                                                   one_vs_rest
#                                               ...
# Mean Val f1                                                      0.308578
# Mean Val f1 Std                                                  0.000395
# Mean Train f1                                                    0.995269
# Mean Train f1 Std                                                0.000736
# Precedence                                                           17.0
# Name: 17, Length: 163, dtype: object)
# Error message: 800.0
# Error Importing this Row: (18, max_iter_predict                                                    800.0
# n_restarts_optimizer                                                  5.0
# features                ['procedure_228130', 'procedure_225792', 'proc...
# random_state                                                         42.0
# multi_class                                                   one_vs_rest
#                                               ...
# Mean Val f1                                                      0.308578
# Mean Val f1 Std                                                  0.000395
# Mean Train f1                                                    0.939586
# Mean Train f1 Std                                                0.002334
# Precedence                                                           18.0
# Name: 18, Length: 163, dtype: object)
# Error message: 800.0
# Error Importing this Row: (19, max_iter_predict                                                    800.0
# n_restarts_optimizer                                                  5.0
# features                ['procedure_228130', 'procedure_225792', 'proc...
# random_state                                                         42.0
# multi_class                                                   one_vs_rest
#                                               ...
# Mean Val f1                                                      0.308578
# Mean Val f1 Std                                                  0.000395
# Mean Train f1                                                         1.0
# Mean Train f1 Std                                                     0.0
# Precedence                                                           19.0
# Name: 19, Length: 163, dtype: object)
# Error message: 800.0
# Error Importing this Row: (20, max_iter_predict                                                    800.0
# n_restarts_optimizer                                                  0.0
# features                ['procedure_228130', 'procedure_225792', 'proc...
# random_state                                                         42.0
# multi_class                                                   one_vs_rest
#                                               ...
# Mean Val f1                                                      0.308578
# Mean Val f1 Std                                                  0.000395
# Mean Train f1                                                         1.0
# Mean Train f1 Std                                                     0.0
# Precedence                                                           20.0
# Name: 20, Length: 163, dtype: object)
# Error message: 800.0
# Error Importing this Row: (21, max_iter_predict                                                    800.0
# n_restarts_optimizer                                                  5.0
# features                ['procedure_228130', 'procedure_225792', 'proc...
# random_state                                                         42.0
# multi_class                                                   one_vs_rest
#                                               ...
# Mean Val f1                                                       0.51278
# Mean Val f1 Std                                                  0.046603
# Mean Train f1                                                    0.675174
# Mean Train f1 Std                                                0.004679
# Precedence                                                           21.0
# Name: 21, Length: 163, dtype: object)
# Error message: 800.0
# Error Importing this Row: (23, max_iter_predict                                                    800.0
# n_restarts_optimizer                                                  5.0
# features                ['procedure_228130', 'procedure_225792', 'proc...
# random_state                                                         42.0
# multi_class                                                   one_vs_rest
#                                               ...
# Mean Val f1                                                      0.308578
# Mean Val f1 Std                                                  0.000395
# Mean Train f1                                                         1.0
# Mean Train f1 Std                                                     0.0
# Precedence                                                           23.0
# Name: 23, Length: 163, dtype: object)
# Error message: 800.0
# Error Importing this Row: (24, max_iter_predict                                                    800.0
# n_restarts_optimizer                                                  5.0
# features                ['procedure_228130', 'procedure_225792', 'proc...
# random_state                                                         42.0
# multi_class                                                   one_vs_rest
#                                               ...
# Mean Val f1                                                      0.308578
# Mean Val f1 Std                                                  0.000395
# Mean Train f1                                                         1.0
# Mean Train f1 Std                                                     0.0
# Precedence                                                           24.0
# Name: 24, Length: 163, dtype: object)
# Error message: 800.0
# Error Importing this Row: (25, max_iter_predict                                                    800.0
# n_restarts_optimizer                                                  5.0
# features                ['procedure_228130', 'procedure_225792', 'proc...
# random_state                                                         42.0
# multi_class                                                   one_vs_rest
#                                               ...
# Mean Val f1                                                      0.510246
# Mean Val f1 Std                                                  0.058661
# Mean Train f1                                                    0.731509
# Mean Train f1 Std                                                0.005348
# Precedence                                                           25.0
# Name: 25, Length: 163, dtype: object)
# Error message: 800.0
# Error Importing this Row: (26, max_iter_predict                                                    800.0
# n_restarts_optimizer                                                  5.0
# features                ['procedure_228130', 'procedure_225792', 'proc...
# random_state                                                         42.0
# multi_class                                                   one_vs_rest
#                                               ...
# Mean Val f1                                                           0.0
# Mean Val f1 Std                                                       0.0
# Mean Train f1                                                    0.780958
# Mean Train f1 Std                                                0.005878
# Precedence                                                           26.0
# Name: 26, Length: 163, dtype: object)
# Error message: 800.0
# Error Importing this Row: (27, max_iter_predict                                                    800.0
# n_restarts_optimizer                                                  0.0
# features                ['procedure_228130', 'procedure_225792', 'proc...
# random_state                                                         42.0
# multi_class                                                   one_vs_rest
#                                               ...
# Mean Val f1                                                      0.308578
# Mean Val f1 Std                                                  0.000395
# Mean Train f1                                                    0.997356
# Mean Train f1 Std                                                0.000709
# Precedence                                                           27.0
# Name: 27, Length: 163, dtype: object)
# Error message: 5.0
# Error Importing this Row: (28, max_iter_predict                                                     25.0
# n_restarts_optimizer                                                  5.0
# features                ['procedure_228130', 'procedure_225792', 'proc...
# random_state                                                         42.0
# multi_class                                                   one_vs_rest
#                                               ...
# Mean Val f1                                                       0.51278
# Mean Val f1 Std                                                  0.046603
# Mean Train f1                                                    0.675174
# Mean Train f1 Std                                                0.004679
# Precedence                                                           28.0
# Name: 28, Length: 163, dtype: object)
# Error message: 5.0
# Error Importing this Row: (29, max_iter_predict                                                     25.0
# n_restarts_optimizer                                                  5.0
# features                ['procedure_228130', 'procedure_225792', 'proc...
# random_state                                                         42.0
# multi_class                                                   one_vs_rest
#                                               ...
# Mean Val f1                                                      0.308578
# Mean Val f1 Std                                                  0.000395
# Mean Train f1                                                         1.0
# Mean Train f1 Std                                                     0.0
# Precedence                                                           29.0
# Name: 29, Length: 163, dtype: object)
# Error message: 5.0
# Error Importing this Row: (30, max_iter_predict                        25.0
# n_restarts_optimizer                     5.0
# features                ['procedure_228130']
# random_state                            42.0
# multi_class                      one_vs_rest
#                                 ...
# Mean Val f1                         0.293289
# Mean Val f1 Std                     0.052458
# Mean Train f1                       0.294924
# Mean Train f1 Std                   0.005679
# Precedence                              30.0
# Name: 30, Length: 163, dtype: object)
# Error message: 800.0
# Error Importing this Row: (31, max_iter_predict                       800.0
# n_restarts_optimizer                     5.0
# features                ['procedure_228130']
# random_state                            42.0
# multi_class                      one_vs_rest
#                                 ...
# Mean Val f1                         0.293289
# Mean Val f1 Std                     0.052458
# Mean Train f1                       0.294924
# Mean Train f1 Std                   0.005679
# Precedence                              31.0
# Name: 31, Length: 163, dtype: object)
# Error message: 800.0
# Error Importing this Row: (32, max_iter_predict                                                    800.0
# n_restarts_optimizer                                                  0.0
# features                ['procedure_228130', 'procedure_225792', 'proc...
# random_state                                                         42.0
# multi_class                                                   one_vs_rest
#                                               ...
# Mean Val f1                                                      0.308578
# Mean Val f1 Std                                                  0.000395
# Mean Train f1                                                         1.0
# Mean Train f1 Std                                                     0.0
# Precedence                                                           32.0
# Name: 32, Length: 163, dtype: object)
# Error message: 5.0
# Error Importing this Row: (33, max_iter_predict                                                     25.0
# n_restarts_optimizer                                                  5.0
# features                ['procedure_228130', 'procedure_225792', 'proc...
# random_state                                                         42.0
# multi_class                                                   one_vs_rest
#                                               ...
# Mean Val f1                                                           0.0
# Mean Val f1 Std                                                       0.0
# Mean Train f1                                                    0.780958
# Mean Train f1 Std                                                0.005878
# Precedence                                                           33.0
# Name: 33, Length: 163, dtype: object)
# Error message: 800.0
# Error Importing this Row: (34, max_iter_predict                                                    800.0
# n_restarts_optimizer                                                  0.0
# features                ['procedure_228130', 'procedure_225792', 'proc...
# random_state                                                         42.0
# multi_class                                                   one_vs_rest
#                                               ...
# Mean Val f1                                                      0.510246
# Mean Val f1 Std                                                  0.058661
# Mean Train f1                                                    0.731509
# Mean Train f1 Std                                                0.005348
# Precedence                                                           34.0
# Name: 34, Length: 163, dtype: object)
# Error message: 5.0
# Error Importing this Row: (35, max_iter_predict                                                     25.0
# n_restarts_optimizer                                                  5.0
# features                ['procedure_228130', 'procedure_225792', 'proc...
# random_state                                                         42.0
# multi_class                                                   one_vs_rest
#                                               ...
# Mean Val f1                                                      0.308578
# Mean Val f1 Std                                                  0.000395
# Mean Train f1                                                         1.0
# Mean Train f1 Std                                                     0.0
# Precedence                                                           35.0
# Name: 35, Length: 163, dtype: object)
# Error message: 5.0
# Error Importing this Row: (36, max_iter_predict                                                     25.0
# n_restarts_optimizer                                                  5.0
# features                ['procedure_228130', 'procedure_225792', 'proc...
# random_state                                                         42.0
# multi_class                                                   one_vs_rest
#                                               ...
# Mean Val f1                                                      0.308578
# Mean Val f1 Std                                                  0.000395
# Mean Train f1                                                         1.0
# Mean Train f1 Std                                                     0.0
# Precedence                                                           36.0
# Name: 36, Length: 163, dtype: object)
# Error message: 5.0
# Error Importing this Row: (37, max_iter_predict                                                     25.0
# n_restarts_optimizer                                                  5.0
# features                ['procedure_228130', 'procedure_225792', 'proc...
# random_state                                                         42.0
# multi_class                                                   one_vs_rest
#                                               ...
# Mean Val f1                                                      0.308578
# Mean Val f1 Std                                                  0.000395
# Mean Train f1                                                    0.972221
# Mean Train f1 Std                                                0.001941
# Precedence                                                           37.0
# Name: 37, Length: 163, dtype: object)
# Error message: 800.0
# Error Importing this Row: (38, max_iter_predict                                                    800.0
# n_restarts_optimizer                                                  5.0
# features                ['procedure_228130', 'procedure_225792', 'proc...
# random_state                                                         42.0
# multi_class                                                   one_vs_rest
#                                               ...
# Mean Val f1                                                      0.308578
# Mean Val f1 Std                                                  0.000395
# Mean Train f1                                                         1.0
# Mean Train f1 Std                                                     0.0
# Precedence                                                           38.0
# Name: 38, Length: 163, dtype: object)
# Error message: 800.0
# Error Importing this Row: (43, max_iter_predict                                                    800.0
# n_restarts_optimizer                                                  5.0
# features                ['procedure_228130', 'procedure_225792', 'proc...
# random_state                                                         42.0
# multi_class                                                   one_vs_rest
#                                               ...
# Mean Val f1                                                           0.0
# Mean Val f1 Std                                                       0.0
# Mean Train f1                                                    0.810283
# Mean Train f1 Std                                                0.003287
# Precedence                                                           43.0
# Name: 43, Length: 163, dtype: object)
# Error message: 5.0
# Error Importing this Row: (44, max_iter_predict                                                     25.0
# n_restarts_optimizer                                                  5.0
# features                ['procedure_228130', 'procedure_225792', 'proc...
# random_state                                                         42.0
# multi_class                                                   one_vs_rest
#                                               ...
# Mean Val f1                                                      0.308578
# Mean Val f1 Std                                                  0.000395
# Mean Train f1                                                    0.939586
# Mean Train f1 Std                                                0.002334
# Precedence                                                           44.0
# Name: 44, Length: 163, dtype: object)
# Error message: 800.0
# Error Importing this Row: (45, max_iter_predict                                                    800.0
# n_restarts_optimizer                                                  5.0
# features                ['procedure_228130', 'procedure_225792', 'proc...
# random_state                                                         42.0
# multi_class                                                   one_vs_rest
#                                               ...
# Mean Val f1                                                      0.308578
# Mean Val f1 Std                                                  0.000395
# Mean Train f1                                                    0.972221
# Mean Train f1 Std                                                0.001941
# Precedence                                                           45.0
# Name: 45, Length: 163, dtype: object)
# Error message: 800.0
# Error Importing this Row: (46, max_iter_predict                                                    800.0
# n_restarts_optimizer                                                  0.0
# features                ['procedure_228130', 'procedure_225792', 'proc...
# random_state                                                         42.0
# multi_class                                                   one_vs_rest
#                                               ...
# Mean Val f1                                                      0.263946
# Mean Val f1 Std                                                  0.052844
# Mean Train f1                                                    0.412888
# Mean Train f1 Std                                                0.008463
# Precedence                                                           46.0
# Name: 46, Length: 163, dtype: object)
# Error message: 800.0
# Error Importing this Row: (48, max_iter_predict                                                    800.0
# n_restarts_optimizer                                                  5.0
# features                ['procedure_228130', 'procedure_225792', 'proc...
# random_state                                                         42.0
# multi_class                                                   one_vs_rest
#                                               ...
# Mean Val f1                                                           0.0
# Mean Val f1 Std                                                       0.0
# Mean Train f1                                                    0.882018
# Mean Train f1 Std                                                0.004321
# Precedence                                                           48.0
# Name: 48, Length: 163, dtype: object)
# Error message: 5.0
# Error Importing this Row: (50, max_iter_predict                                                     25.0
# n_restarts_optimizer                                                  5.0
# features                ['procedure_228130', 'procedure_225792', 'proc...
# random_state                                                         42.0
# multi_class                                                   one_vs_rest
#                                               ...
# Mean Val f1                                                      0.308578
# Mean Val f1 Std                                                  0.000395
# Mean Train f1                                                         1.0
# Mean Train f1 Std                                                     0.0
# Precedence                                                           50.0
# Name: 50, Length: 163, dtype: object)
# Error message: 800.0
# Error Importing this Row: (52, max_iter_predict                                                    800.0
# n_restarts_optimizer                                                  0.0
# features                ['procedure_228130', 'procedure_225792', 'proc...
# random_state                                                         42.0
# multi_class                                                   one_vs_rest
#                                               ...
# Mean Val f1                                                      0.308578
# Mean Val f1 Std                                                  0.000395
# Mean Train f1                                                         1.0
# Mean Train f1 Std                                                     0.0
# Precedence                                                           52.0
# Name: 52, Length: 163, dtype: object)
# Error message: 800.0
# Error Importing this Row: (53, max_iter_predict                                                    800.0
# n_restarts_optimizer                                                  5.0
# features                ['procedure_228130', 'procedure_225792', 'proc...
# random_state                                                         42.0
# multi_class                                                   one_vs_rest
#                                               ...
# Mean Val f1                                                      0.308578
# Mean Val f1 Std                                                  0.000395
# Mean Train f1                                                    0.997356
# Mean Train f1 Std                                                0.000709
# Precedence                                                           53.0
# Name: 53, Length: 163, dtype: object)
# Error message: 800.0
# Error Importing this Row: (55, max_iter_predict                                                    800.0
# n_restarts_optimizer                                                  0.0
# features                ['procedure_228130', 'procedure_225792', 'proc...
# random_state                                                         42.0
# multi_class                                                   one_vs_rest
#                                               ...
# Mean Val f1                                                      0.308578
# Mean Val f1 Std                                                  0.000395
# Mean Train f1                                                    0.972221
# Mean Train f1 Std                                                0.001941
# Precedence                                                           55.0
# Name: 55, Length: 163, dtype: object)
# Error message: 5.0
# Error Importing this Row: (56, max_iter_predict                                                     25.0
# n_restarts_optimizer                                                  5.0
# features                ['procedure_228130', 'procedure_225792', 'proc...
# random_state                                                         42.0
# multi_class                                                   one_vs_rest
#                                               ...
# Mean Val f1                                                      0.308578
# Mean Val f1 Std                                                  0.000395
# Mean Train f1                                                         1.0
# Mean Train f1 Std                                                     0.0
# Precedence                                                           56.0
# Name: 56, Length: 163, dtype: object)
# Error message: 800.0
# Error Importing this Row: (59, max_iter_predict                                                    800.0
# n_restarts_optimizer                                                  0.0
# features                ['procedure_228130', 'procedure_225792', 'proc...
# random_state                                                         42.0
# multi_class                                                   one_vs_rest
#                                               ...
# Mean Val f1                                                      0.308578
# Mean Val f1 Std                                                  0.000395
# Mean Train f1                                                    0.995269
# Mean Train f1 Std                                                0.000736
# Precedence                                                           59.0
# Name: 59, Length: 163, dtype: object)
# Error message: 800.0
# Error Importing this Row: (60, max_iter_predict                                                    800.0
# n_restarts_optimizer                                                  0.0
# features                ['procedure_228130', 'procedure_225792', 'proc...
# random_state                                                         42.0
# multi_class                                                   one_vs_rest
#                                               ...
# Mean Val f1                                                           0.0
# Mean Val f1 Std                                                       0.0
# Mean Train f1                                                    0.780958
# Mean Train f1 Std                                                0.005878
# Precedence                                                           60.0
# Name: 60, Length: 163, dtype: object)
# Error message: 5.0
# Error Importing this Row: (61, max_iter_predict                                                     25.0
# n_restarts_optimizer                                                  5.0
# features                ['procedure_228130', 'procedure_225792', 'proc...
# random_state                                                         42.0
# multi_class                                                   one_vs_rest
#                                               ...
# Mean Val f1                                                           0.0
# Mean Val f1 Std                                                       0.0
# Mean Train f1                                                    0.810283
# Mean Train f1 Std                                                0.003287
# Precedence                                                           61.0
# Name: 61, Length: 163, dtype: object)
# Error message: 800.0
# Error Importing this Row: (62, max_iter_predict                       800.0
# n_restarts_optimizer                     0.0
# features                ['procedure_228130']
# random_state                            42.0
# multi_class                      one_vs_rest
#                                 ...
# Mean Val f1                         0.293289
# Mean Val f1 Std                     0.052458
# Mean Train f1                       0.294924
# Mean Train f1 Std                   0.005679
# Precedence                              62.0
# Name: 62, Length: 163, dtype: object)
# Error message: 800.0
# Error Importing this Row: (63, max_iter_predict                                                    800.0
# n_restarts_optimizer                                                  0.0
# features                ['procedure_228130', 'procedure_225792', 'proc...
# random_state                                                         42.0
# multi_class                                                   one_vs_rest
#                                               ...
# Mean Val f1                                                      0.308578
# Mean Val f1 Std                                                  0.000395
# Mean Train f1                                                         1.0
# Mean Train f1 Std                                                     0.0
# Precedence                                                           63.0
# Name: 63, Length: 163, dtype: object)
# Error message: 4.0
# Error Importing this Row: (68, max_iter_predict                                                    200.0
# n_restarts_optimizer                                                  4.0
# features                ['procedure_228130', 'procedure_225792', 'proc...
# random_state                                                         42.0
# multi_class                                                   one_vs_rest
#                                               ...
# Mean Val f1                                                      0.308578
# Mean Val f1 Std                                                  0.000395
# Mean Train f1                                                    0.947678
# Mean Train f1 Std                                                0.001733
# Precedence                                                           68.0
# Name: 68, Length: 163, dtype: object)
# Error message: 4.0
# Error Importing this Row: (73, max_iter_predict                                                    100.0
# n_restarts_optimizer                                                  4.0
# features                ['procedure_228130', 'procedure_225792', 'proc...
# random_state                                                         42.0
# multi_class                                                   one_vs_rest
#                                               ...
# Mean Val f1                                                      0.308578
# Mean Val f1 Std                                                  0.000395
# Mean Train f1                                                    0.947678
# Mean Train f1 Std                                                0.001733
# Precedence                                                           73.0
# Name: 73, Length: 163, dtype: object)
# Error message: 800.0
# Error Importing this Row: (76, max_iter_predict                                                    800.0
# n_restarts_optimizer                                                  3.0
# features                ['procedure_228130', 'procedure_225792', 'proc...
# random_state                                                         42.0
# multi_class                                                   one_vs_rest
#                                               ...
# Mean Val f1                                                      0.308578
# Mean Val f1 Std                                                  0.000395
# Mean Train f1                                                    0.947678
# Mean Train f1 Std                                                0.001733
# Precedence                                                           76.0
# Name: 76, Length: 163, dtype: object)
# Error message: 4.0
# Error Importing this Row: (78, max_iter_predict                                                    400.0
# n_restarts_optimizer                                                  4.0
# features                ['procedure_228130', 'procedure_225792', 'proc...
# random_state                                                         42.0
# multi_class                                                   one_vs_rest
#                                               ...
# Mean Val f1                                                      0.308578
# Mean Val f1 Std                                                  0.000395
# Mean Train f1                                                    0.947678
# Mean Train f1 Std                                                0.001733
# Precedence                                                           78.0
# Name: 78, Length: 163, dtype: object)
# Error message: 5.0
# Error Importing this Row: (84, max_iter_predict                                                    200.0
# n_restarts_optimizer                                                  5.0
# features                ['procedure_228130', 'procedure_225792', 'proc...
# random_state                                                         42.0
# multi_class                                                   one_vs_rest
#                                               ...
# Mean Val f1                                                      0.308578
# Mean Val f1 Std                                                  0.000395
# Mean Train f1                                                    0.947678
# Mean Train f1 Std                                                0.001733
# Precedence                                                           84.0
# Name: 84, Length: 163, dtype: object)
# Error message: 4.0
# Error Importing this Row: (85, max_iter_predict                                                    200.0
# n_restarts_optimizer                                                  4.0
# features                ['procedure_228130', 'procedure_225792', 'proc...
# random_state                                                         42.0
# multi_class                                                   one_vs_rest
#                                               ...
# Mean Val f1                                                      0.308578
# Mean Val f1 Std                                                  0.000395
# Mean Train f1                                                    0.939586
# Mean Train f1 Std                                                0.002334
# Precedence                                                           85.0
# Name: 85, Length: 163, dtype: object)
# Error message: 4.0
# Error Importing this Row: (86, max_iter_predict                                                    200.0
# n_restarts_optimizer                                                  4.0
# features                ['procedure_228130', 'procedure_225792', 'proc...
# random_state                                                         42.0
# multi_class                                                   one_vs_rest
#                                               ...
# Mean Val f1                                                      0.308578
# Mean Val f1 Std                                                  0.000395
# Mean Train f1                                                    0.961368
# Mean Train f1 Std                                                0.001306
# Precedence                                                           86.0
# Name: 86, Length: 163, dtype: object)
# Error message: 800.0
# Error Importing this Row: (90, max_iter_predict                                                    800.0
# n_restarts_optimizer                                                  1.0
# features                ['procedure_228130', 'procedure_225792', 'proc...
# random_state                                                         42.0
# multi_class                                                   one_vs_rest
#                                               ...
# Mean Val f1                                                       0.51278
# Mean Val f1 Std                                                  0.046603
# Mean Train f1                                                    0.675174
# Mean Train f1 Std                                                0.004679
# Precedence                                                           90.0
# Name: 90, Length: 163, dtype: object)
# Error message: 800.0
# Error Importing this Row: (91, max_iter_predict                                                    800.0
# n_restarts_optimizer                                                  0.0
# features                ['procedure_228130', 'procedure_225792', 'proc...
# random_state                                                         42.0
# multi_class                                                   one_vs_rest
#                                               ...
# Mean Val f1                                                      0.519591
# Mean Val f1 Std                                                  0.043267
# Mean Train f1                                                    0.671945
# Mean Train f1 Std                                                 0.00446
# Precedence                                                           91.0
# Name: 91, Length: 163, dtype: object)
# Error message: 800.0
# Error Importing this Row: (92, max_iter_predict                                                    800.0
# n_restarts_optimizer                                                  0.0
# features                ['procedure_228130', 'procedure_225792', 'proc...
# random_state                                                         42.0
# multi_class                                                   one_vs_rest
#                                               ...
# Mean Val f1                                                      0.520905
# Mean Val f1 Std                                                  0.059857
# Mean Train f1                                                    0.678076
# Mean Train f1 Std                                                0.004707
# Precedence                                                           92.0
# Name: 92, Length: 163, dtype: object)
# Error message: 800.0
# Error Importing this Row: (94, max_iter_predict                                                    800.0
# n_restarts_optimizer                                                  1.0
# features                ['procedure_228130', 'procedure_225792', 'proc...
# random_state                                                         42.0
# multi_class                                                   one_vs_rest
#                                               ...
# Mean Val f1                                                      0.520905
# Mean Val f1 Std                                                  0.059857
# Mean Train f1                                                    0.678076
# Mean Train f1 Std                                                0.004707
# Precedence                                                           94.0
# Name: 94, Length: 163, dtype: object)
# Error message: 800.0
# Error Importing this Row: (95, max_iter_predict                                                    800.0
# n_restarts_optimizer                                                  0.0
# features                ['procedure_228130', 'procedure_225792', 'proc...
# random_state                                                         42.0
# multi_class                                                   one_vs_rest
#                                               ...
# Mean Val f1                                                      0.524285
# Mean Val f1 Std                                                  0.056633
# Mean Train f1                                                    0.681505
# Mean Train f1 Std                                                0.004508
# Precedence                                                           95.0
# Name: 95, Length: 163, dtype: object)
# Error message: 800.0
# Error Importing this Row: (97, max_iter_predict                                                    800.0
# n_restarts_optimizer                                                  1.0
# features                ['procedure_228130', 'procedure_225792', 'proc...
# random_state                                                         42.0
# multi_class                                                   one_vs_rest
#                                               ...
# Mean Val f1                                                      0.524285
# Mean Val f1 Std                                                  0.056633
# Mean Train f1                                                    0.681505
# Mean Train f1 Std                                                0.004508
# Precedence                                                           97.0
# Name: 97, Length: 163, dtype: object)
# Error message: 800.0
# Error Importing this Row: (98, max_iter_predict                                                    800.0
# n_restarts_optimizer                                                  0.0
# features                ['procedure_228130', 'procedure_225792', 'proc...
# random_state                                                         42.0
# multi_class                                                   one_vs_rest
#                                               ...
# Mean Val f1                                                      0.545016
# Mean Val f1 Std                                                  0.035576
# Mean Train f1                                                     0.70014
# Mean Train f1 Std                                                0.004555
# Precedence                                                           98.0
# Name: 98, Length: 163, dtype: object)
# Error message: 800.0
# Error Importing this Row: (100, max_iter_predict                                                    800.0
# n_restarts_optimizer                                                  1.0
# features                ['procedure_228130', 'procedure_225792', 'proc...
# random_state                                                         42.0
# multi_class                                                   one_vs_rest
#                                               ...
# Mean Val f1                                                      0.545016
# Mean Val f1 Std                                                  0.035576
# Mean Train f1                                                     0.70014
# Mean Train f1 Std                                                0.004555
# Precedence                                                          100.0
# Name: 100, Length: 163, dtype: object)
# Error message: 800.0
# Error Importing this Row: (101, max_iter_predict                                                    800.0
# n_restarts_optimizer                                                  0.0
# features                ['procedure_228130', 'procedure_225792', 'proc...
# random_state                                                         42.0
# multi_class                                                   one_vs_rest
#                                               ...
# Mean Val f1                                                      0.510044
# Mean Val f1 Std                                                  0.058702
# Mean Train f1                                                    0.721892
# Mean Train f1 Std                                                0.005713
# Precedence                                                          101.0
# Name: 101, Length: 163, dtype: object)
# Error message: 800.0
# Error Importing this Row: (105, max_iter_predict                                                    800.0
# n_restarts_optimizer                                                  2.0
# features                ['procedure_228130', 'procedure_225792', 'proc...
# random_state                                                         42.0
# multi_class                                                   one_vs_rest
#                                               ...
# Mean Val f1                                                      0.545016
# Mean Val f1 Std                                                  0.035576
# Mean Train f1                                                     0.70014
# Mean Train f1 Std                                                0.004555
# Precedence                                                          105.0
# Name: 105, Length: 163, dtype: object)
# Error message: 800.0
# Error Importing this Row: (106, max_iter_predict                                                    800.0
# n_restarts_optimizer                                                  1.0
# features                ['procedure_228130', 'procedure_225792', 'proc...
# random_state                                                         42.0
# multi_class                                                   one_vs_rest
#                                               ...
# Mean Val f1                                                      0.510044
# Mean Val f1 Std                                                  0.058702
# Mean Train f1                                                    0.721892
# Mean Train f1 Std                                                0.005713
# Precedence                                                          106.0
# Name: 106, Length: 163, dtype: object)
# Successfully read in tuning result of 178 rows, for 112.0 combos
# ---
# Successfully set tuning output address
# ---
# Successfully set best model output address

# %%
# ignore warnings

import warnings
warnings.filterwarnings("ignore")

# %%
# begin tuning ... (or continue training)

tuner.tune()
# Out:
# BEGIN TUNING
#
#
# STAGE ZERO: Tune all Cruise combinations
#
#
# As new Best Combo (0, 3, 30) was read in, best_clf is set to None
# Already Trained and Tested combination (val score of 0.0):
#             {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 30}
#             Current best combo (with val score 0.0):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 30}
#         Has trained 112 of 1440 combinations so far
# As new Best Combo (4, 0, 35) was read in, best_clf is set to None
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 35}
#             Current best combo (with val score 0.3086):
#                     {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 35}
#         Has trained 112 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 400, 'n_restarts_optimizer': 3, 'features': 45}
#             Current best combo (with val score 0.3086):
#                     {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 35}
#         Has trained 112 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 400, 'n_restarts_optimizer': 3, 'features': 63}
#             Current best combo (with val score 0.3086):
#                     {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 35}
#         Has trained 112 of 1440 combinations so far
# As new Best Combo (0, 3, 15) was read in, best_clf is set to None
# Already Trained and Tested combination (val score of 0.5102):
#             {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 15}
#             Current best combo (with val score 0.5102):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 15}
#         Has trained 112 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.2639):
#             {'max_iter_predict': 400, 'n_restarts_optimizer': 3, 'features': 5}
#             Current best combo (with val score 0.5102):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 15}
#         Has trained 112 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 30}
#             Current best combo (with val score 0.5102):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 15}
#         Has trained 112 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 55}
#             Current best combo (with val score 0.5102):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 15}
#         Has trained 112 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.2639):
#             {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 5}
#             Current best combo (with val score 0.5102):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 15}
#         Has trained 112 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 40}
#             Current best combo (with val score 0.5102):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 15}
#         Has trained 112 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 63}
#             Current best combo (with val score 0.5102):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 15}
#         Has trained 112 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 50}
#             Current best combo (with val score 0.5102):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 15}
#         Has trained 112 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 45}
#             Current best combo (with val score 0.5102):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 15}
#         Has trained 112 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 50}
#             Current best combo (with val score 0.5102):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 15}
#         Has trained 112 of 1440 combinations so far
# As new Best Combo (4, 0, 10) was read in, best_clf is set to None
# Already Trained and Tested combination (val score of 0.5128):
#             {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 10}
#             Current best combo (with val score 0.5128):
#                     {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 10}
#         Has trained 112 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 55}
#             Current best combo (with val score 0.5128):
#                     {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 10}
#         Has trained 112 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 25}
#             Current best combo (with val score 0.5128):
#                     {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 10}
#         Has trained 112 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 45}
#             Current best combo (with val score 0.5128):
#                     {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 10}
#         Has trained 112 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 400, 'n_restarts_optimizer': 3, 'features': 35}
#             Current best combo (with val score 0.5128):
#                     {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 10}
#         Has trained 112 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 400, 'n_restarts_optimizer': 3, 'features': 55}
#             Current best combo (with val score 0.5128):
#                     {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 10}
#         Has trained 112 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 67}
#             Current best combo (with val score 0.5128):
#                     {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 10}
#         Has trained 112 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.5128):
#             {'max_iter_predict': 400, 'n_restarts_optimizer': 3, 'features': 10}
#             Current best combo (with val score 0.5128):
#                     {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 10}
#         Has trained 112 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 20}
#             Current best combo (with val score 0.5128):
#                     {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 10}
#         Has trained 112 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 400, 'n_restarts_optimizer': 3, 'features': 59}
#             Current best combo (with val score 0.5128):
#                     {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 10}
#         Has trained 112 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 400, 'n_restarts_optimizer': 3, 'features': 71}
#             Current best combo (with val score 0.5128):
#                     {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 10}
#         Has trained 112 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.5102):
#             {'max_iter_predict': 400, 'n_restarts_optimizer': 3, 'features': 15}
#             Current best combo (with val score 0.5128):
#                     {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 10}
#         Has trained 112 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'max_iter_predict': 400, 'n_restarts_optimizer': 3, 'features': 20}
#             Current best combo (with val score 0.5128):
#                     {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 10}
#         Has trained 112 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 50}
#             Current best combo (with val score 0.5128):
#                     {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 10}
#         Has trained 112 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.5128):
#             {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 10}
#             Current best combo (with val score 0.5128):
#                     {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 10}
#         Has trained 112 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 63}
#             Current best combo (with val score 0.5128):
#                     {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 10}
#         Has trained 112 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.2933):
#             {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 0}
#             Current best combo (with val score 0.5128):
#                     {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 10}
#         Has trained 112 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.2933):
#             {'max_iter_predict': 400, 'n_restarts_optimizer': 3, 'features': 0}
#             Current best combo (with val score 0.5128):
#                     {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 10}
#         Has trained 112 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 59}
#             Current best combo (with val score 0.5128):
#                     {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 10}
#         Has trained 112 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 20}
#             Current best combo (with val score 0.5128):
#                     {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 10}
#         Has trained 112 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.5102):
#             {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 15}
#             Current best combo (with val score 0.5128):
#                     {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 10}
#         Has trained 112 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 71}
#             Current best combo (with val score 0.5128):
#                     {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 10}
#         Has trained 112 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 55}
#             Current best combo (with val score 0.5128):
#                     {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 10}
#         Has trained 112 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 40}
#             Current best combo (with val score 0.5128):
#                     {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 10}
#         Has trained 112 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 400, 'n_restarts_optimizer': 3, 'features': 67}
#             Current best combo (with val score 0.5128):
#                     {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 10}
#         Has trained 112 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 67}
#             Current best combo (with val score 0.5128):
#                     {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 10}
#         Has trained 112 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.5128):
#             {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 10}
#             Current best combo (with val score 0.5128):
#                     {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 10}
#         Has trained 112 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 30}
#             Current best combo (with val score 0.5128):
#                     {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 10}
#         Has trained 112 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.2933):
#             {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 0}
#             Current best combo (with val score 0.5128):
#                     {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 10}
#         Has trained 112 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'max_iter_predict': 400, 'n_restarts_optimizer': 3, 'features': 25}
#             Current best combo (with val score 0.5128):
#                     {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 10}
#         Has trained 112 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 35}
#             Current best combo (with val score 0.5128):
#                     {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 10}
#         Has trained 112 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 400, 'n_restarts_optimizer': 3, 'features': 40}
#             Current best combo (with val score 0.5128):
#                     {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 10}
#         Has trained 112 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.2639):
#             {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 5}
#             Current best combo (with val score 0.5128):
#                     {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 10}
#         Has trained 112 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 59}
#             Current best combo (with val score 0.5128):
#                     {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 10}
#         Has trained 112 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'max_iter_predict': 400, 'n_restarts_optimizer': 3, 'features': 30}
#             Current best combo (with val score 0.5128):
#                     {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 10}
#         Has trained 112 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.5102):
#             {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 15}
#             Current best combo (with val score 0.5128):
#                     {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 10}
#         Has trained 112 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 67}
#             Current best combo (with val score 0.5128):
#                     {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 10}
#         Has trained 112 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 71}
#             Current best combo (with val score 0.5128):
#                     {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 10}
#         Has trained 112 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 63}
#             Current best combo (with val score 0.5128):
#                     {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 10}
#         Has trained 112 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 400, 'n_restarts_optimizer': 3, 'features': 50}
#             Current best combo (with val score 0.5128):
#                     {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 10}
#         Has trained 112 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 35}
#             Current best combo (with val score 0.5128):
#                     {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 10}
#         Has trained 112 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 40}
#             Current best combo (with val score 0.5128):
#                     {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 10}
#         Has trained 112 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 59}
#             Current best combo (with val score 0.5128):
#                     {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 10}
#         Has trained 112 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 25}
#             Current best combo (with val score 0.5128):
#                     {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 10}
#         Has trained 112 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.2639):
#             {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 5}
#             Current best combo (with val score 0.5128):
#                     {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 10}
#         Has trained 112 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 45}
#             Current best combo (with val score 0.5128):
#                     {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 10}
#         Has trained 112 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 20}
#             Current best combo (with val score 0.5128):
#                     {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 10}
#         Has trained 112 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 25}
#             Current best combo (with val score 0.5128):
#                     {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 10}
#         Has trained 112 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.2933):
#             {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 0}
#             Current best combo (with val score 0.5128):
#                     {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 10}
#         Has trained 112 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 71}
#             Current best combo (with val score 0.5128):
#                     {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 10}
#         Has trained 112 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 100, 'n_restarts_optimizer': 2, 'features': 36}
#             Current best combo (with val score 0.5128):
#                     {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 10}
#         Has trained 112 of 1440 combinations so far
#
#
# STAGE ONE: Begin initial Guidance system
#
#
# Guidance: initial round
#
# 	round 0 iteration:  0
#
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 50, 'n_restarts_optimizer': 2, 'features': 36}
#             Current best combo (with val score 0.5128):
#                     {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 10}
#         Has trained 112 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 200, 'n_restarts_optimizer': 2, 'features': 36}
#             Current best combo (with val score 0.5128):
#                     {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 10}
#         Has trained 112 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 100, 'n_restarts_optimizer': 1, 'features': 36}
#             Current best combo (with val score 0.5128):
#                     {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 10}
#         Has trained 112 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 100, 'n_restarts_optimizer': 3, 'features': 36}
#             Current best combo (with val score 0.5128):
#                     {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 10}
#         Has trained 112 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 100, 'n_restarts_optimizer': 2, 'features': 35}
#             Current best combo (with val score 0.5128):
#                     {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 10}
#         Has trained 112 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 100, 'n_restarts_optimizer': 2, 'features': 37}
#             Current best combo (with val score 0.5128):
#                     {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 10}
#         Has trained 112 of 1440 combinations so far
# 	round 0 iteration:  1
#
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 25, 'n_restarts_optimizer': 2, 'features': 36}
#             Current best combo (with val score 0.5128):
#                     {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 10}
#         Has trained 112 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 100, 'n_restarts_optimizer': 2, 'features': 36}
#             Current best combo (with val score 0.5128):
#                     {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 10}
#         Has trained 112 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 50, 'n_restarts_optimizer': 1, 'features': 36}
#             Current best combo (with val score 0.5128):
#                     {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 10}
#         Has trained 112 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 50, 'n_restarts_optimizer': 3, 'features': 36}
#             Current best combo (with val score 0.5128):
#                     {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 10}
#         Has trained 112 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 50, 'n_restarts_optimizer': 2, 'features': 35}
#             Current best combo (with val score 0.5128):
#                     {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 10}
#         Has trained 112 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 50, 'n_restarts_optimizer': 2, 'features': 37}
#             Current best combo (with val score 0.5128):
#                     {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 10}
#         Has trained 112 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 100, 'n_restarts_optimizer': 2, 'features': 36}
#             Current best combo (with val score 0.5128):
#                     {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 10}
#         Has trained 112 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 400, 'n_restarts_optimizer': 2, 'features': 36}
#             Current best combo (with val score 0.5128):
#                     {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 10}
#         Has trained 112 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 200, 'n_restarts_optimizer': 1, 'features': 36}
#             Current best combo (with val score 0.5128):
#                     {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 10}
#         Has trained 112 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 200, 'n_restarts_optimizer': 3, 'features': 36}
#             Current best combo (with val score 0.5128):
#                     {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 10}
#         Has trained 112 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 200, 'n_restarts_optimizer': 2, 'features': 35}
#             Current best combo (with val score 0.5128):
#                     {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 10}
#         Has trained 112 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 200, 'n_restarts_optimizer': 2, 'features': 37}
#             Current best combo (with val score 0.5128):
#                     {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 10}
#         Has trained 112 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 50, 'n_restarts_optimizer': 1, 'features': 36}
#             Current best combo (with val score 0.5128):
#                     {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 10}
#         Has trained 112 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 200, 'n_restarts_optimizer': 1, 'features': 36}
#             Current best combo (with val score 0.5128):
#                     {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 10}
#         Has trained 112 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 100, 'n_restarts_optimizer': 0, 'features': 36}
#             Current best combo (with val score 0.5128):
#                     {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 10}
#         Has trained 112 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 100, 'n_restarts_optimizer': 2, 'features': 36}
#             Current best combo (with val score 0.5128):
#                     {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 10}
#         Has trained 112 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 100, 'n_restarts_optimizer': 1, 'features': 35}
#             Current best combo (with val score 0.5128):
#                     {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 10}
#         Has trained 112 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 100, 'n_restarts_optimizer': 1, 'features': 37}
#             Current best combo (with val score 0.5128):
#                     {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 10}
#         Has trained 112 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 50, 'n_restarts_optimizer': 3, 'features': 36}
#             Current best combo (with val score 0.5128):
#                     {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 10}
#         Has trained 112 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 200, 'n_restarts_optimizer': 3, 'features': 36}
#             Current best combo (with val score 0.5128):
#                     {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 10}
#         Has trained 112 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 100, 'n_restarts_optimizer': 2, 'features': 36}
#             Current best combo (with val score 0.5128):
#                     {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 10}
#         Has trained 112 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 100, 'n_restarts_optimizer': 3, 'features': 35}
#             Current best combo (with val score 0.5128):
#                     {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 10}
#         Has trained 112 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 100, 'n_restarts_optimizer': 3, 'features': 37}
#             Current best combo (with val score 0.5128):
#                     {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 10}
#         Has trained 112 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 50, 'n_restarts_optimizer': 2, 'features': 35}
#             Current best combo (with val score 0.5128):
#                     {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 10}
#         Has trained 112 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 200, 'n_restarts_optimizer': 2, 'features': 35}
#             Current best combo (with val score 0.5128):
#                     {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 10}
#         Has trained 112 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 100, 'n_restarts_optimizer': 1, 'features': 35}
#             Current best combo (with val score 0.5128):
#                     {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 10}
#         Has trained 112 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 100, 'n_restarts_optimizer': 3, 'features': 35}
#             Current best combo (with val score 0.5128):
#                     {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 10}
#         Has trained 112 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 100, 'n_restarts_optimizer': 2, 'features': 34}
#             Current best combo (with val score 0.5128):
#                     {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 10}
#         Has trained 112 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 100, 'n_restarts_optimizer': 2, 'features': 36}
#             Current best combo (with val score 0.5128):
#                     {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 10}
#         Has trained 112 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 50, 'n_restarts_optimizer': 2, 'features': 37}
#             Current best combo (with val score 0.5128):
#                     {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 10}
#         Has trained 112 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 200, 'n_restarts_optimizer': 2, 'features': 37}
#             Current best combo (with val score 0.5128):
#                     {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 10}
#         Has trained 112 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 100, 'n_restarts_optimizer': 1, 'features': 37}
#             Current best combo (with val score 0.5128):
#                     {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 10}
#         Has trained 112 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 100, 'n_restarts_optimizer': 3, 'features': 37}
#             Current best combo (with val score 0.5128):
#                     {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 10}
#         Has trained 112 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 100, 'n_restarts_optimizer': 2, 'features': 36}
#             Current best combo (with val score 0.5128):
#                     {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 10}
#         Has trained 112 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 100, 'n_restarts_optimizer': 2, 'features': 38}
#             Current best combo (with val score 0.5128):
#                     {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 10}
#         Has trained 112 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.5128):
#             {'max_iter_predict': 200, 'n_restarts_optimizer': 0, 'features': 10}
#             Current best combo (with val score 0.5128):
#                     {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 10}
#         Has trained 112 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.5128):
#             {'max_iter_predict': 400, 'n_restarts_optimizer': 1, 'features': 10}
#             Current best combo (with val score 0.5128):
#                     {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 10}
#         Has trained 112 of 1440 combinations so far
# As new Best Combo (4, 0, 9) was read in, best_clf is set to None
# Already Trained and Tested combination (val score of 0.5196):
#             {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 9}
#             Current best combo (with val score 0.5196):
#                     {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 9}
#         Has trained 112 of 1440 combinations so far
# As new Best Combo (4, 0, 11) was read in, best_clf is set to None
# Already Trained and Tested combination (val score of 0.5209):
#             {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 11}
#             Current best combo (with val score 0.5209):
#                     {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 11}
#         Has trained 112 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.5209):
#             {'max_iter_predict': 200, 'n_restarts_optimizer': 0, 'features': 11}
#             Current best combo (with val score 0.5209):
#                     {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 11}
#         Has trained 112 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.5209):
#             {'max_iter_predict': 400, 'n_restarts_optimizer': 1, 'features': 11}
#             Current best combo (with val score 0.5209):
#                     {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 11}
#         Has trained 112 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.5128):
#             {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 10}
#             Current best combo (with val score 0.5209):
#                     {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 11}
#         Has trained 112 of 1440 combinations so far
# As new Best Combo (4, 0, 12) was read in, best_clf is set to None
# Already Trained and Tested combination (val score of 0.5243):
#             {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 12}
#             Current best combo (with val score 0.5243):
#                     {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 12}
#         Has trained 112 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.5243):
#             {'max_iter_predict': 200, 'n_restarts_optimizer': 0, 'features': 12}
#             Current best combo (with val score 0.5243):
#                     {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 12}
#         Has trained 112 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.5243):
#             {'max_iter_predict': 400, 'n_restarts_optimizer': 1, 'features': 12}
#             Current best combo (with val score 0.5243):
#                     {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 12}
#         Has trained 112 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.5209):
#             {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 11}
#             Current best combo (with val score 0.5243):
#                     {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 12}
#         Has trained 112 of 1440 combinations so far
# As new Best Combo (4, 0, 13) was read in, best_clf is set to None
# Already Trained and Tested combination (val score of 0.545):
#             {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 13}
#             Current best combo (with val score 0.545):
#                     {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 13}
#         Has trained 112 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.545):
#             {'max_iter_predict': 200, 'n_restarts_optimizer': 0, 'features': 13}
#             Current best combo (with val score 0.545):
#                     {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 13}
#         Has trained 112 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.545):
#             {'max_iter_predict': 400, 'n_restarts_optimizer': 1, 'features': 13}
#             Current best combo (with val score 0.545):
#                     {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 13}
#         Has trained 112 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.5243):
#             {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 12}
#             Current best combo (with val score 0.545):
#                     {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 13}
#         Has trained 112 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.51):
#             {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 14}
#             Current best combo (with val score 0.545):
#                     {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 13}
#         Has trained 112 of 1440 combinations so far
# % Combos Checked Thus Far: 112 out of 1440 which is 7.7777780000000005%
# STAGE TWO: Begin Cruise system
#
#
# Cruising Coordrdinate 1 of 64
#
# Cruising Coordrdinate 2 of 64
#
# Cruising Coordrdinate 3 of 64
#
# Cruising Coordrdinate 4 of 64
#
# Cruising Coordrdinate 5 of 64
#
# Cruising Coordrdinate 6 of 64
#
# Cruising Coordrdinate 7 of 64
#
# Cruising Coordrdinate 8 of 64
#
# Cruising Coordrdinate 9 of 64
#
# Cruising Coordrdinate 10 of 64
#
# Cruising Coordrdinate 11 of 64
#
# Cruising Coordrdinate 12 of 64
#
# Cruising Coordrdinate 13 of 64
#
# Cruising Coordrdinate 14 of 64
#
# Cruising Coordrdinate 15 of 64
#
# Cruising Coordrdinate 16 of 64
#
# Cruising Coordrdinate 17 of 64
#
# Cruising Coordrdinate 18 of 64
#
# Cruising Coordrdinate 19 of 64
#
# Cruising Coordrdinate 20 of 64
#
# Cruising Coordrdinate 21 of 64
#
# Cruising Coordrdinate 22 of 64
#
# Cruising Coordrdinate 23 of 64
#
# Cruising Coordrdinate 24 of 64
#
# Cruising Coordrdinate 25 of 64
#
# Cruising Coordrdinate 26 of 64
#
# Cruising Coordrdinate 27 of 64
#
# Cruising Coordrdinate 28 of 64
#
# Cruising Coordrdinate 29 of 64
#
# Cruising Coordrdinate 30 of 64
#
# Cruising Coordrdinate 31 of 64
#
# Cruising Coordrdinate 32 of 64
#
# Cruising Coordrdinate 33 of 64
#
# Cruising Coordrdinate 34 of 64
#
# Cruising Coordrdinate 35 of 64
#
# Cruising Coordrdinate 36 of 64
#
# Cruising Coordrdinate 37 of 64
#
# Cruising Coordrdinate 38 of 64
#
# Cruising Coordrdinate 39 of 64
#
# Cruising Coordrdinate 40 of 64
#
# Cruising Coordrdinate 41 of 64
#
# Cruising Coordrdinate 42 of 64
#
# Cruising Coordrdinate 43 of 64
#
# Cruising Coordrdinate 44 of 64
#
# Cruising Coordrdinate 45 of 64
#
# Cruising Coordrdinate 46 of 64
#
# Cruising Coordrdinate 47 of 64
#
# Cruising Coordrdinate 48 of 64
#
# Cruising Coordrdinate 49 of 64
#
# Cruising Coordrdinate 50 of 64
#
# Cruising Coordrdinate 51 of 64
#
# Cruising Coordrdinate 52 of 64
#
# Cruising Coordrdinate 53 of 64
#
# Cruising Coordrdinate 54 of 64
#
# Cruising Coordrdinate 55 of 64
#
# Cruising Coordrdinate 56 of 64
#
# Cruising Coordrdinate 57 of 64
#
# Cruising Coordrdinate 58 of 64
#
# Cruising Coordrdinate 59 of 64
#
# Cruising Coordrdinate 60 of 64
#
# Cruising Coordrdinate 61 of 64
#
# Cruising Coordrdinate 62 of 64
#
# Cruising Coordrdinate 63 of 64
#
# Cruising Coordrdinate 64 of 64
#
# FINAL STAGE: Begin final Guidance system
#
#
# Guidance: round FINAL
#
# 	round FINAL iteration:  0
#
# Already Trained and Tested combination (val score of 0.545):
#             {'max_iter_predict': 200, 'n_restarts_optimizer': 0, 'features': 13}
#             Current best combo (with val score 0.545):
#                     {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 13}
#         Has trained 112 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.545):
#             {'max_iter_predict': 400, 'n_restarts_optimizer': 1, 'features': 13}
#             Current best combo (with val score 0.545):
#                     {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 13}
#         Has trained 112 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.5243):
#             {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 12}
#             Current best combo (with val score 0.545):
#                     {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 13}
#         Has trained 112 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.51):
#             {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 14}
#             Current best combo (with val score 0.545):
#                     {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 13}
#         Has trained 112 of 1440 combinations so far
# 	round FINAL iteration:  1
#
# Already Trained and Tested combination (val score of 0.545):
#             {'max_iter_predict': 100, 'n_restarts_optimizer': 0, 'features': 13}
#             Current best combo (with val score 0.545):
#                     {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 13}
#         Has trained 112 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.545):
#             {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 13}
#             Current best combo (with val score 0.545):
#                     {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 13}
#         Has trained 112 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.545):
#             {'max_iter_predict': 200, 'n_restarts_optimizer': 1, 'features': 13}
#             Current best combo (with val score 0.545):
#                     {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 13}
#         Has trained 112 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.5243):
#             {'max_iter_predict': 200, 'n_restarts_optimizer': 0, 'features': 12}
#             Current best combo (with val score 0.545):
#                     {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 13}
#         Has trained 112 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.51):
#             {'max_iter_predict': 200, 'n_restarts_optimizer': 0, 'features': 14}
#             Current best combo (with val score 0.545):
#                     {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 13}
#         Has trained 112 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.545):
#             {'max_iter_predict': 200, 'n_restarts_optimizer': 1, 'features': 13}
#             Current best combo (with val score 0.545):
#                     {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 13}
#         Has trained 112 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.545):
#             {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 13}
#             Current best combo (with val score 0.545):
#                     {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 13}
#         Has trained 112 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.545):
#             {'max_iter_predict': 400, 'n_restarts_optimizer': 2, 'features': 13}
#             Current best combo (with val score 0.545):
#                     {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 13}
#         Has trained 112 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.5243):
#             {'max_iter_predict': 400, 'n_restarts_optimizer': 1, 'features': 12}
#             Current best combo (with val score 0.545):
#                     {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 13}
#         Has trained 112 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.51):
#             {'max_iter_predict': 400, 'n_restarts_optimizer': 1, 'features': 14}
#             Current best combo (with val score 0.545):
#                     {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 13}
#         Has trained 112 of 1440 combinations so far
# % Combos Checked Thus Far: 112 out of 1440 which is 7.7777780000000005%
# Max Val Score:
#  0.545016
# Max Val Score Std:
#  0.035576
# Best Combo Train Score:
#  0.70014
# Best Combo Train Score Std:
#  0.004555
# Max Combo Index:
#  (4, 0, 13) out of [5, 4, 72] (note best combo is 0-indexed)
# Max Combo Hyperparamer Combination:
#  {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 13}
# Max Combo Features:
#  ('procedure_228130', 'procedure_225792', 'procedure_228125', 'lods_score', 'ventilation_used', 'procedure_226236', 'hospital_stay_duration', 'procedure_225469', 'procedure_224270', 'procedure_225446', 'procedure_225802', 'procedure_227712', 'procedure_229580', 'procedure_225451')
# % Combos Checked: 112 out of 1440 which is 7.7777780000000005%
