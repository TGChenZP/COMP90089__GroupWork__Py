# %% [markdown]
# # Tuning Script

# %%
# Parameters subject to change in every script - involved in naming

MODEL = 'epc'
PREPROCESSING = 'smote_normalise'
TUNER = 'yangzhoub'
OPTIMISED_METRIC = 'f1'

# %% [markdown]
# ---

# %%
# detect whether this is a google environment

COLAB_ENVIRONMENT = False

try:
    from google.colab import drive
    drive.mount('/content/drive')
    COLAB_ENVIRONMENT = True
except:
    pass
# Out:
# Mounted at /content/drive

# %%
import sys
import os
import pickle

if COLAB_ENVIRONMENT:
    home_directory = './drive/MyDrive/LAB/COMP90089__GroupWork__Py/' # my home directory is stored in ./LAB of google drive
    if MODEL == 'ebr':
        # !pip install interpret==0.5.0
    elif MODEL == 'cbr':
        # !pip install catboost
    elif MODEL == 'epc':
        # !pip install scikit-learn-extra
    elif MODEL in ['tf', 'mlp']:
        # !pip install PyTorch2Sklearn
    # !pip install JXAutoML
else:
    home_directory = '../../'

from JXAutoML.YangZhouB_10CV import YangZhouB_10CV as Tuner

import pandas as pd
# Out:
# Collecting scikit-learn-extra
#   Downloading scikit_learn_extra-0.3.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.6 kB)
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.10/dist-packages (from scikit-learn-extra) (1.26.4)
# Requirement already satisfied: scipy>=0.19.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn-extra) (1.13.1)
# Requirement already satisfied: scikit-learn>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn-extra) (1.5.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.23.0->scikit-learn-extra) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.23.0->scikit-learn-extra) (3.5.0)
# Downloading scikit_learn_extra-0.3.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 23.3 MB/s eta 0:00:00
# Installing collected packages: scikit-learn-extra
# Successfully installed scikit-learn-extra-0.3.0
# Collecting JXAutoML
#   Downloading JXAutoML-0.4.4-py3-none-any.whl.metadata (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.2/67.2 kB 2.4 MB/s eta 0:00:00
# Downloading JXAutoML-0.4.4-py3-none-any.whl (52 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.1/52.1 kB 2.9 MB/s eta 0:00:00
# Installing collected packages: JXAutoML
# Successfully installed JXAutoML-0.4.4

# %%
# Parameters that are same for every script

FOLDS = 10  # we have decided to do 10 fold validation

SEED = 42

TASK_TYPE = 'Classification'  # this task is a classification task

# we have decided to tune features as hp
TUNE_FEATURES_AS_HYPERPARAMETERS = True

# %% [markdown]
# ---

# %%
# model to use to tune
from sklearn_extra.kernel_methods import EigenProClassifier as clf

# what values to try for each hyperparameter
parameter_choices = {
    'batch_size': (32, 64, 128, 256),
    'n_epoch': list(range(1, 10))

}

# what values to set non-tuneable parameters/hyperparameters
non_tunable_hyperparameters_dict = {
                                    'random_state': 42,

                                    }

# %% [markdown]
# ---

# %% [markdown]
# Read in and Prepare Data

# %%
# Import data and store as lists

train_x_list = []
train_y_list = []
val_x_list = []
val_y_list = []

for i in range(FOLDS):
    train_data = pd.read_csv(
        f'{home_directory}data/curated/modelling/{PREPROCESSING}/train_{i}.csv')
    val_data = pd.read_csv(
        f'{home_directory}data/curated/modelling/{PREPROCESSING}/val_{i}.csv')

    # get the correct rows for X and y
    train_x = train_data.drop(
        ['mortality_status', 'subject_id', 'hadm_id', 'stay_id'], axis=1)
    train_y = train_data['mortality_status']
    val_x = val_data.drop(
        ['mortality_status', 'subject_id', 'hadm_id', 'stay_id'], axis=1)
    val_y = val_data['mortality_status']

    train_x_list.append(train_x)
    train_y_list.append(train_y)
    val_x_list.append(val_x)
    val_y_list.append(val_y)

# %%
# Import feature importance ordering

with open(f'{home_directory}models/xgb_feature_importance_ordering_{PREPROCESSING}.pickle', 'rb') as f:
    feature_importance_ordering = pickle.load(f)

# %% [markdown]
# Set parameters

# %%
# initialisation
tuner = Tuner()

print('---')

# define what model we are tuning
tuner.read_in_model(clf, TASK_TYPE, optimised_metric=OPTIMISED_METRIC)

print('---')

# read in the data for training and validation
tuner.read_in_data(train_x_list, train_y_list, val_x_list, val_y_list)

print('---')

# set what hp values to tune
tuner.set_hyperparameters(parameter_choices)
# WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

# set up hp values that need to be changed from default but NOT to be tuned
tuner.set_non_tuneable_hyperparameters(non_tunable_hyperparameters_dict)

print('---')

# set up feature importance ordering

if TUNE_FEATURES_AS_HYPERPARAMETERS:
    tuner.set_features(feature_importance_ordering)
    # WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

try:  # try to read in previous results to continue tuning ...
    tuner.read_in_tuning_result_df(
        f'{home_directory}models/tuning/{TUNER}_{MODEL}_{PREPROCESSING}.csv')
except:
    print('No previous tuning data read in')

print('---')

# set up where to save the tuning result csv
tuner.set_tuning_result_saving_address(
    f'{home_directory}models/tuning/{TUNER}_{MODEL}_{PREPROCESSING}.csv')

print('---')

# set up where to save the current best model
tuner.set_best_model_saving_address(
    f'{home_directory}models/tmp_models/{TUNER}_{MODEL}_{PREPROCESSING}')
# Out:
# YangZhouB Initialised
# ---
# Successfully read in model <class 'sklearn_extra.kernel_methods._eigenpro.EigenProClassifier'>, which is a Classification model optimising for f1
# ---
# Read in Train X data list
# Read in Train y data list
# Read in Val X data list
# Read in Val y data list
# ---
# Successfully recorded hyperparameter choices
# ---
# Successfully recorded non_tuneable_hyperparameter choices
# ---
# Successfully recorded tuneable feature combination choices and updated relevant internal structures
# ---
# Successfully read in tuning result of 765 rows, for 765.0 combos
# ---
# Successfully set tuning output address
# ---
# Successfully set best model output address

# %%
# ignore warnings

import warnings
warnings.filterwarnings("ignore")

# %%
# begin tuning ... (or continue training)

tuner.tune()
# Out:
# Streaming output truncated to the last 5000 lines.
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 765 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 256, 'n_epoch': 9, 'features': 40}
#             Current best combo (with val score 0.3086):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 765 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 256, 'n_epoch': 8, 'features': 39}
#             Current best combo (with val score 0.3086):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 765 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 256, 'n_epoch': 8, 'features': 41}
#             Current best combo (with val score 0.3086):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 765 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 128, 'n_epoch': 9, 'features': 39}
#             Current best combo (with val score 0.3086):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 765 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 256, 'n_epoch': 8, 'features': 39}
#             Current best combo (with val score 0.3086):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 765 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 256, 'n_epoch': 9, 'features': 38}
#             Current best combo (with val score 0.3086):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 765 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 256, 'n_epoch': 9, 'features': 40}
#             Current best combo (with val score 0.3086):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 765 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 128, 'n_epoch': 9, 'features': 41}
#             Current best combo (with val score 0.3086):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 765 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 256, 'n_epoch': 8, 'features': 41}
#             Current best combo (with val score 0.3086):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 765 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 256, 'n_epoch': 9, 'features': 40}
#             Current best combo (with val score 0.3086):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 765 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 256, 'n_epoch': 9, 'features': 42}
#             Current best combo (with val score 0.3086):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 765 of 2592 combinations so far
# % Combos Checked Thus Far: 765 out of 2592 which is 29.513889%
# Cruising Coordrdinate 54 of 96
#
# Cruise suspended due to suspicious case
# Guidance: round 18
#
# 	round 18 iteration:  0
#
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 64, 'n_epoch': 9, 'features': 40}
#             Current best combo (with val score 0.3086):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 765 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 32, 'n_epoch': 8, 'features': 40}
#             Current best combo (with val score 0.3086):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 765 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 32, 'n_epoch': 9, 'features': 39}
#             Current best combo (with val score 0.3086):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 765 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 32, 'n_epoch': 9, 'features': 41}
#             Current best combo (with val score 0.3086):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 765 of 2592 combinations so far
# 	round 18 iteration:  1
#
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 64, 'n_epoch': 8, 'features': 40}
#             Current best combo (with val score 0.3086):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 765 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 32, 'n_epoch': 7, 'features': 40}
#             Current best combo (with val score 0.3086):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 765 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 32, 'n_epoch': 9, 'features': 40}
#             Current best combo (with val score 0.3086):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 765 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 32, 'n_epoch': 8, 'features': 39}
#             Current best combo (with val score 0.3086):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 765 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 32, 'n_epoch': 8, 'features': 41}
#             Current best combo (with val score 0.3086):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 765 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 64, 'n_epoch': 9, 'features': 39}
#             Current best combo (with val score 0.3086):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 765 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 32, 'n_epoch': 8, 'features': 39}
#             Current best combo (with val score 0.3086):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 765 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 32, 'n_epoch': 9, 'features': 38}
#             Current best combo (with val score 0.3086):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 765 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 32, 'n_epoch': 9, 'features': 40}
#             Current best combo (with val score 0.3086):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 765 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 64, 'n_epoch': 9, 'features': 41}
#             Current best combo (with val score 0.3086):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 765 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 32, 'n_epoch': 8, 'features': 41}
#             Current best combo (with val score 0.3086):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 765 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 32, 'n_epoch': 9, 'features': 40}
#             Current best combo (with val score 0.3086):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 765 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 32, 'n_epoch': 9, 'features': 42}
#             Current best combo (with val score 0.3086):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 765 of 2592 combinations so far
# % Combos Checked Thus Far: 765 out of 2592 which is 29.513889%
# Cruising Coordrdinate 55 of 96
#
# Cruise suspended due to suspicious case
# Guidance: round 19
#
# 	round 19 iteration:  0
#
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 128, 'n_epoch': 1, 'features': 45}
#             Current best combo (with val score 0.3086):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 765 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 256, 'n_epoch': 2, 'features': 45}
#             Current best combo (with val score 0.3086):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 765 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 256, 'n_epoch': 1, 'features': 44}
#             Current best combo (with val score 0.3086):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 765 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 256, 'n_epoch': 1, 'features': 46}
#             Current best combo (with val score 0.3086):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 765 of 2592 combinations so far
# 	round 19 iteration:  1
#
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 64, 'n_epoch': 1, 'features': 45}
#             Current best combo (with val score 0.3086):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 765 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 256, 'n_epoch': 1, 'features': 45}
#             Current best combo (with val score 0.3086):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 765 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 128, 'n_epoch': 2, 'features': 45}
#             Current best combo (with val score 0.3086):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 765 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 128, 'n_epoch': 1, 'features': 44}
#             Current best combo (with val score 0.3086):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 765 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 128, 'n_epoch': 1, 'features': 46}
#             Current best combo (with val score 0.3086):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 765 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 128, 'n_epoch': 2, 'features': 45}
#             Current best combo (with val score 0.3086):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 765 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 256, 'n_epoch': 1, 'features': 45}
#             Current best combo (with val score 0.3086):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 765 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 256, 'n_epoch': 3, 'features': 45}
#             Current best combo (with val score 0.3086):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 765 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 256, 'n_epoch': 2, 'features': 44}
#             Current best combo (with val score 0.3086):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 765 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 256, 'n_epoch': 2, 'features': 46}
#             Current best combo (with val score 0.3086):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 765 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 128, 'n_epoch': 1, 'features': 44}
#             Current best combo (with val score 0.3086):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 765 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 256, 'n_epoch': 2, 'features': 44}
#             Current best combo (with val score 0.3086):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 765 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 256, 'n_epoch': 1, 'features': 43}
#             Current best combo (with val score 0.3086):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 765 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 256, 'n_epoch': 1, 'features': 45}
#             Current best combo (with val score 0.3086):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 765 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 128, 'n_epoch': 1, 'features': 46}
#             Current best combo (with val score 0.3086):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 765 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 256, 'n_epoch': 2, 'features': 46}
#             Current best combo (with val score 0.3086):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 765 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 256, 'n_epoch': 1, 'features': 45}
#             Current best combo (with val score 0.3086):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 765 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 256, 'n_epoch': 1, 'features': 47}
#             Current best combo (with val score 0.3086):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 765 of 2592 combinations so far
# % Combos Checked Thus Far: 765 out of 2592 which is 29.513889%
# Cruising Coordrdinate 56 of 96
#
# Cruise suspended due to suspicious case
# Guidance: round 20
#
# 	round 20 iteration:  0
#
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 64, 'n_epoch': 1, 'features': 45}
#             Current best combo (with val score 0.3086):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 765 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 32, 'n_epoch': 2, 'features': 45}
#             Current best combo (with val score 0.3086):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 765 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 32, 'n_epoch': 1, 'features': 44}
#             Current best combo (with val score 0.3086):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 765 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 32, 'n_epoch': 1, 'features': 46}
#             Current best combo (with val score 0.3086):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 765 of 2592 combinations so far
# 	round 20 iteration:  1
#
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 64, 'n_epoch': 2, 'features': 45}
#             Current best combo (with val score 0.3086):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 765 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 32, 'n_epoch': 1, 'features': 45}
#             Current best combo (with val score 0.3086):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 765 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 32, 'n_epoch': 3, 'features': 45}
#             Current best combo (with val score 0.3086):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 765 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 32, 'n_epoch': 2, 'features': 44}
#             Current best combo (with val score 0.3086):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 765 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 32, 'n_epoch': 2, 'features': 46}
#             Current best combo (with val score 0.3086):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 765 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 64, 'n_epoch': 1, 'features': 44}
#             Current best combo (with val score 0.3086):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 765 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 32, 'n_epoch': 2, 'features': 44}
#             Current best combo (with val score 0.3086):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 765 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 32, 'n_epoch': 1, 'features': 43}
#             Current best combo (with val score 0.3086):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 765 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 32, 'n_epoch': 1, 'features': 45}
#             Current best combo (with val score 0.3086):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 765 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 64, 'n_epoch': 1, 'features': 46}
#             Current best combo (with val score 0.3086):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 765 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 32, 'n_epoch': 2, 'features': 46}
#             Current best combo (with val score 0.3086):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 765 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 32, 'n_epoch': 1, 'features': 45}
#             Current best combo (with val score 0.3086):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 765 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 32, 'n_epoch': 1, 'features': 47}
#             Current best combo (with val score 0.3086):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 765 of 2592 combinations so far
# % Combos Checked Thus Far: 765 out of 2592 which is 29.513889%
# Cruising Coordrdinate 57 of 96
#
# Cruise suspended due to suspicious case
# Guidance: round 21
#
# 	round 21 iteration:  0
#
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 128, 'n_epoch': 5, 'features': 45}
#             Current best combo (with val score 0.3086):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 765 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 256, 'n_epoch': 4, 'features': 45}
#             Current best combo (with val score 0.3086):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 765 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 256, 'n_epoch': 6, 'features': 45}
#             Current best combo (with val score 0.3086):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 765 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 256, 'n_epoch': 5, 'features': 44}
#             Current best combo (with val score 0.3086):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 765 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 256, 'n_epoch': 5, 'features': 46}
#             Current best combo (with val score 0.3086):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 765 of 2592 combinations so far
# 	round 21 iteration:  1
#
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 64, 'n_epoch': 5, 'features': 45}
#             Current best combo (with val score 0.3086):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 765 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 256, 'n_epoch': 5, 'features': 45}
#             Current best combo (with val score 0.3086):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 765 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 128, 'n_epoch': 4, 'features': 45}
#             Current best combo (with val score 0.3086):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 765 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 128, 'n_epoch': 6, 'features': 45}
#             Current best combo (with val score 0.3086):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 765 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 128, 'n_epoch': 5, 'features': 44}
#             Current best combo (with val score 0.3086):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 765 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 128, 'n_epoch': 5, 'features': 46}
#             Current best combo (with val score 0.3086):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 765 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 128, 'n_epoch': 4, 'features': 45}
#             Current best combo (with val score 0.3086):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 765 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 256, 'n_epoch': 3, 'features': 45}
#             Current best combo (with val score 0.3086):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 765 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 256, 'n_epoch': 5, 'features': 45}
#             Current best combo (with val score 0.3086):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 765 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 256, 'n_epoch': 4, 'features': 44}
#             Current best combo (with val score 0.3086):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 765 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 256, 'n_epoch': 4, 'features': 46}
#             Current best combo (with val score 0.3086):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 765 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 128, 'n_epoch': 6, 'features': 45}
#             Current best combo (with val score 0.3086):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 765 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 256, 'n_epoch': 5, 'features': 45}
#             Current best combo (with val score 0.3086):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 765 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 256, 'n_epoch': 7, 'features': 45}
#             Current best combo (with val score 0.3086):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 765 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 256, 'n_epoch': 6, 'features': 44}
#             Current best combo (with val score 0.3086):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 765 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 256, 'n_epoch': 6, 'features': 46}
#             Current best combo (with val score 0.3086):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 765 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 128, 'n_epoch': 5, 'features': 44}
#             Current best combo (with val score 0.3086):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 765 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 256, 'n_epoch': 4, 'features': 44}
#             Current best combo (with val score 0.3086):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 765 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 256, 'n_epoch': 6, 'features': 44}
#             Current best combo (with val score 0.3086):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 765 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 256, 'n_epoch': 5, 'features': 43}
#             Current best combo (with val score 0.3086):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 765 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 256, 'n_epoch': 5, 'features': 45}
#             Current best combo (with val score 0.3086):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 765 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 128, 'n_epoch': 5, 'features': 46}
#             Current best combo (with val score 0.3086):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 765 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 256, 'n_epoch': 4, 'features': 46}
#             Current best combo (with val score 0.3086):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 765 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 256, 'n_epoch': 6, 'features': 46}
#             Current best combo (with val score 0.3086):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 765 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 256, 'n_epoch': 5, 'features': 45}
#             Current best combo (with val score 0.3086):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 765 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 256, 'n_epoch': 5, 'features': 47}
#             Current best combo (with val score 0.3086):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 765 of 2592 combinations so far
# % Combos Checked Thus Far: 765 out of 2592 which is 29.513889%
# Cruising Coordrdinate 58 of 96
#
# Cruise suspended due to suspicious case
# Guidance: round 22
#
# 	round 22 iteration:  0
#
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 128, 'n_epoch': 1, 'features': 71}
#             Current best combo (with val score 0.3086):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 765 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 256, 'n_epoch': 2, 'features': 71}
#             Current best combo (with val score 0.3086):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 765 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 256, 'n_epoch': 1, 'features': 70}
#             Current best combo (with val score 0.3086):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 765 of 2592 combinations so far
# 	round 22 iteration:  1
#
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 64, 'n_epoch': 1, 'features': 71}
#             Current best combo (with val score 0.3086):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 765 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 256, 'n_epoch': 1, 'features': 71}
#             Current best combo (with val score 0.3086):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 765 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 128, 'n_epoch': 2, 'features': 71}
#             Current best combo (with val score 0.3086):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 765 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 128, 'n_epoch': 1, 'features': 70}
#             Current best combo (with val score 0.3086):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 765 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 128, 'n_epoch': 2, 'features': 71}
#             Current best combo (with val score 0.3086):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 765 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 256, 'n_epoch': 1, 'features': 71}
#             Current best combo (with val score 0.3086):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 765 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 256, 'n_epoch': 3, 'features': 71}
#             Current best combo (with val score 0.3086):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 765 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 256, 'n_epoch': 2, 'features': 70}
#             Current best combo (with val score 0.3086):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 765 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 128, 'n_epoch': 1, 'features': 70}
#             Current best combo (with val score 0.3086):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 765 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 256, 'n_epoch': 2, 'features': 70}
#             Current best combo (with val score 0.3086):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 765 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 256, 'n_epoch': 1, 'features': 69}
#             Current best combo (with val score 0.3086):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 765 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 256, 'n_epoch': 1, 'features': 71}
#             Current best combo (with val score 0.3086):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 765 of 2592 combinations so far
# % Combos Checked Thus Far: 765 out of 2592 which is 29.513889%
# Cruising Coordrdinate 59 of 96
#
# Cruise suspended due to suspicious case
# Guidance: round 23
#
# 	round 23 iteration:  0
#
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 64, 'n_epoch': 5, 'features': 45}
#             Current best combo (with val score 0.3086):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 765 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 32, 'n_epoch': 4, 'features': 45}
#             Current best combo (with val score 0.3086):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 765 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 32, 'n_epoch': 6, 'features': 45}
#             Current best combo (with val score 0.3086):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 765 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 32, 'n_epoch': 5, 'features': 44}
#             Current best combo (with val score 0.3086):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 765 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 32, 'n_epoch': 5, 'features': 46}
#             Current best combo (with val score 0.3086):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 765 of 2592 combinations so far
# 	round 23 iteration:  1
#
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 64, 'n_epoch': 4, 'features': 45}
#             Current best combo (with val score 0.3086):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 765 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 32, 'n_epoch': 3, 'features': 45}
#             Current best combo (with val score 0.3086):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 765 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 32, 'n_epoch': 5, 'features': 45}
#             Current best combo (with val score 0.3086):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 765 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 32, 'n_epoch': 4, 'features': 44}
#             Current best combo (with val score 0.3086):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 765 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 32, 'n_epoch': 4, 'features': 46}
#             Current best combo (with val score 0.3086):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 765 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 64, 'n_epoch': 6, 'features': 45}
#             Current best combo (with val score 0.3086):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 765 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 32, 'n_epoch': 5, 'features': 45}
#             Current best combo (with val score 0.3086):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 765 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 32, 'n_epoch': 7, 'features': 45}
#             Current best combo (with val score 0.3086):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 765 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 32, 'n_epoch': 6, 'features': 44}
#             Current best combo (with val score 0.3086):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 765 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 32, 'n_epoch': 6, 'features': 46}
#             Current best combo (with val score 0.3086):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 765 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 64, 'n_epoch': 5, 'features': 44}
#             Current best combo (with val score 0.3086):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 765 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 32, 'n_epoch': 4, 'features': 44}
#             Current best combo (with val score 0.3086):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 765 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 32, 'n_epoch': 6, 'features': 44}
#             Current best combo (with val score 0.3086):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 765 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 32, 'n_epoch': 5, 'features': 43}
#             Current best combo (with val score 0.3086):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 765 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 32, 'n_epoch': 5, 'features': 45}
#             Current best combo (with val score 0.3086):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 765 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 64, 'n_epoch': 5, 'features': 46}
#             Current best combo (with val score 0.3086):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 765 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 32, 'n_epoch': 4, 'features': 46}
#             Current best combo (with val score 0.3086):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 765 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 32, 'n_epoch': 6, 'features': 46}
#             Current best combo (with val score 0.3086):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 765 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 32, 'n_epoch': 5, 'features': 45}
#             Current best combo (with val score 0.3086):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 765 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 32, 'n_epoch': 5, 'features': 47}
#             Current best combo (with val score 0.3086):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 765 of 2592 combinations so far
# % Combos Checked Thus Far: 765 out of 2592 which is 29.513889%
# Cruising Coordrdinate 60 of 96
#
# Cruise suspended due to suspicious case
# Guidance: round 24
#
# 	round 24 iteration:  0
#
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 64, 'n_epoch': 1, 'features': 71}
#             Current best combo (with val score 0.3086):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 765 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 32, 'n_epoch': 2, 'features': 71}
#             Current best combo (with val score 0.3086):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 765 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 32, 'n_epoch': 1, 'features': 70}
#             Current best combo (with val score 0.3086):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 765 of 2592 combinations so far
# 	round 24 iteration:  1
#
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 64, 'n_epoch': 2, 'features': 71}
#             Current best combo (with val score 0.3086):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 765 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 32, 'n_epoch': 1, 'features': 71}
#             Current best combo (with val score 0.3086):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 765 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 32, 'n_epoch': 3, 'features': 71}
#             Current best combo (with val score 0.3086):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 765 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 32, 'n_epoch': 2, 'features': 70}
#             Current best combo (with val score 0.3086):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 765 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 64, 'n_epoch': 1, 'features': 70}
#             Current best combo (with val score 0.3086):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 765 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 32, 'n_epoch': 2, 'features': 70}
#             Current best combo (with val score 0.3086):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 765 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 32, 'n_epoch': 1, 'features': 69}
#             Current best combo (with val score 0.3086):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 765 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 32, 'n_epoch': 1, 'features': 71}
#             Current best combo (with val score 0.3086):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 765 of 2592 combinations so far
# % Combos Checked Thus Far: 765 out of 2592 which is 29.513889%
# Cruising Coordrdinate 61 of 96
#
# Cruise suspended due to suspicious case
# Guidance: round 25
#
# 	round 25 iteration:  0
#
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 128, 'n_epoch': 9, 'features': 45}
#             Current best combo (with val score 0.3086):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 765 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 256, 'n_epoch': 8, 'features': 45}
#             Current best combo (with val score 0.3086):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 765 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 256, 'n_epoch': 9, 'features': 44}
#             Current best combo (with val score 0.3086):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 765 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 256, 'n_epoch': 9, 'features': 46}
#             Current best combo (with val score 0.3086):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 765 of 2592 combinations so far
# 	round 25 iteration:  1
#
# ...
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 32, 'n_epoch': 8, 'features': 64}
#             Current best combo (with val score 0.3086):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 822 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 32, 'n_epoch': 9, 'features': 63}
#             Current best combo (with val score 0.3086):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 822 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 32, 'n_epoch': 9, 'features': 65}
#             Current best combo (with val score 0.3086):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 822 of 2592 combinations so far
# % Combos Checked Thus Far: 822 out of 2592 which is 31.712963%
# Cruising Coordrdinate 95 of 96
#
# Cruise suspended due to suspicious case
# Guidance: round 59
#
# 	round 59 iteration:  0
#
# Trained and Tested combination 823 of 2592, taking 15.61 seconds to get val score of 0.3086:
#                 {'batch_size': 128, 'n_epoch': 9, 'features': 59},
#             Current best combo with val score 0.3086:
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
# Trained and Tested combination 824 of 2592, taking 13.96 seconds to get val score of 0.3086:
#                 {'batch_size': 256, 'n_epoch': 8, 'features': 59},
#             Current best combo with val score 0.3086:
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
# Trained and Tested combination 825 of 2592, taking 13.88 seconds to get val score of 0.3086:
#                 {'batch_size': 256, 'n_epoch': 9, 'features': 58},
#             Current best combo with val score 0.3086:
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
# Trained and Tested combination 826 of 2592, taking 14.24 seconds to get val score of 0.3086:
#                 {'batch_size': 256, 'n_epoch': 9, 'features': 60},
#             Current best combo with val score 0.3086:
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
# 	round 59 iteration:  1
#
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 64, 'n_epoch': 9, 'features': 59}
#             Current best combo (with val score 0.3086):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 826 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 256, 'n_epoch': 9, 'features': 59}
#             Current best combo (with val score 0.3086):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 826 of 2592 combinations so far
# Trained and Tested combination 827 of 2592, taking 14.05 seconds to get val score of 0.3086:
#                 {'batch_size': 128, 'n_epoch': 8, 'features': 59},
#             Current best combo with val score 0.3086:
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
# Trained and Tested combination 828 of 2592, taking 15.12 seconds to get val score of 0.3086:
#                 {'batch_size': 128, 'n_epoch': 9, 'features': 58},
#             Current best combo with val score 0.3086:
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
# Trained and Tested combination 829 of 2592, taking 15.04 seconds to get val score of 0.3086:
#                 {'batch_size': 128, 'n_epoch': 9, 'features': 60},
#             Current best combo with val score 0.3086:
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 128, 'n_epoch': 8, 'features': 59}
#             Current best combo (with val score 0.3086):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 829 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 256, 'n_epoch': 7, 'features': 59}
#             Current best combo (with val score 0.3086):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 829 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 256, 'n_epoch': 9, 'features': 59}
#             Current best combo (with val score 0.3086):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 829 of 2592 combinations so far
# Trained and Tested combination 830 of 2592, taking 14.31 seconds to get val score of 0.3086:
#                 {'batch_size': 256, 'n_epoch': 8, 'features': 58},
#             Current best combo with val score 0.3086:
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
# Trained and Tested combination 831 of 2592, taking 14.21 seconds to get val score of 0.3086:
#                 {'batch_size': 256, 'n_epoch': 8, 'features': 60},
#             Current best combo with val score 0.3086:
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 128, 'n_epoch': 9, 'features': 58}
#             Current best combo (with val score 0.3086):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 831 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 256, 'n_epoch': 8, 'features': 58}
#             Current best combo (with val score 0.3086):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 831 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 256, 'n_epoch': 9, 'features': 57}
#             Current best combo (with val score 0.3086):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 831 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 256, 'n_epoch': 9, 'features': 59}
#             Current best combo (with val score 0.3086):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 831 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 128, 'n_epoch': 9, 'features': 60}
#             Current best combo (with val score 0.3086):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 831 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 256, 'n_epoch': 8, 'features': 60}
#             Current best combo (with val score 0.3086):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 831 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 256, 'n_epoch': 9, 'features': 59}
#             Current best combo (with val score 0.3086):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 831 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 256, 'n_epoch': 9, 'features': 61}
#             Current best combo (with val score 0.3086):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 831 of 2592 combinations so far
# % Combos Checked Thus Far: 831 out of 2592 which is 32.060185000000004%
# Cruising Coordrdinate 96 of 96
#
# Cruise suspended due to suspicious case
# Guidance: round 60
#
# 	round 60 iteration:  0
#
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 64, 'n_epoch': 9, 'features': 59}
#             Current best combo (with val score 0.3086):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 831 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 32, 'n_epoch': 8, 'features': 59}
#             Current best combo (with val score 0.3086):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 831 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 32, 'n_epoch': 9, 'features': 58}
#             Current best combo (with val score 0.3086):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 831 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 32, 'n_epoch': 9, 'features': 60}
#             Current best combo (with val score 0.3086):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 831 of 2592 combinations so far
# 	round 60 iteration:  1
#
# Trained and Tested combination 832 of 2592, taking 18.66 seconds to get val score of 0.3086:
#                 {'batch_size': 64, 'n_epoch': 8, 'features': 59},
#             Current best combo with val score 0.3086:
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 32, 'n_epoch': 7, 'features': 59}
#             Current best combo (with val score 0.3086):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 832 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#             Current best combo (with val score 0.3086):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 832 of 2592 combinations so far
# Trained and Tested combination 833 of 2592, taking 23.25 seconds to get val score of 0.3086:
#                 {'batch_size': 32, 'n_epoch': 8, 'features': 58},
#             Current best combo with val score 0.3086:
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
# Trained and Tested combination 834 of 2592, taking 20.24 seconds to get val score of 0.3086:
#                 {'batch_size': 32, 'n_epoch': 8, 'features': 60},
#             Current best combo with val score 0.3086:
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
# Trained and Tested combination 835 of 2592, taking 17.38 seconds to get val score of 0.3086:
#                 {'batch_size': 64, 'n_epoch': 9, 'features': 58},
#             Current best combo with val score 0.3086:
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 32, 'n_epoch': 8, 'features': 58}
#             Current best combo (with val score 0.3086):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 835 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 32, 'n_epoch': 9, 'features': 57}
#             Current best combo (with val score 0.3086):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 835 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#             Current best combo (with val score 0.3086):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 835 of 2592 combinations so far
# Trained and Tested combination 836 of 2592, taking 17.62 seconds to get val score of 0.3086:
#                 {'batch_size': 64, 'n_epoch': 9, 'features': 60},
#             Current best combo with val score 0.3086:
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 32, 'n_epoch': 8, 'features': 60}
#             Current best combo (with val score 0.3086):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 836 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#             Current best combo (with val score 0.3086):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 836 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 32, 'n_epoch': 9, 'features': 61}
#             Current best combo (with val score 0.3086):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#         Has trained 836 of 2592 combinations so far
# % Combos Checked Thus Far: 836 out of 2592 which is 32.253085999999996%
# FINAL STAGE: Begin final Guidance system
#
#
# Guidance: round FINAL
#
# 	round FINAL iteration:  0
#
# % Combos Checked Thus Far: 836 out of 2592 which is 32.253085999999996%
# Max Val Score:
#  0.308578
# Max Val Score Std:
#  0.000395
# Best Combo Train Score:
#  0.996756
# Best Combo Train Score Std:
#  0.000316
# Max Combo Index:
#  (0, 8, 59) out of [4, 9, 72] (note best combo is 0-indexed)
# Max Combo Hyperparamer Combination:
#  {'batch_size': 32, 'n_epoch': 9, 'features': 59}
# Max Combo Features:
#  ('procedure_225469', 'lods_score', 'procedure_224274', 'marital_status_0', 'marital_status_DIVORCED', 'marital_status_MARRIED', 'marital_status_WIDOWED', 'marital_status_SINGLE', 'procedure_223253', 'race_AMERICAN INDIAN/ALASKA NATIVE', 'race_ASIAN', 'race_ASIAN - ASIAN INDIAN', 'race_ASIAN - CHINESE', 'race_ASIAN - KOREAN', 'race_ASIAN - SOUTH EAST ASIAN', 'race_BLACK/AFRICAN', 'race_BLACK/AFRICAN AMERICAN', 'race_BLACK/CAPE VERDEAN', 'race_BLACK/CARIBBEAN ISLAND', 'race_HISPANIC OR LATINO', 'race_HISPANIC/LATINO - CENTRAL AMERICAN', 'race_HISPANIC/LATINO - COLUMBIAN', 'race_HISPANIC/LATINO - CUBAN', 'race_HISPANIC/LATINO - DOMINICAN', 'race_HISPANIC/LATINO - GUATEMALAN', 'race_HISPANIC/LATINO - HONDURAN', 'race_HISPANIC/LATINO - MEXICAN', 'race_HISPANIC/LATINO - PUERTO RICAN', 'race_HISPANIC/LATINO - SALVADORAN', 'race_MULTIPLE RACE/ETHNICITY', 'race_NATIVE HAWAIIAN OR OTHER PACIFIC ISLANDER', 'race_OTHER', 'race_PATIENT DECLINED TO ANSWER', 'race_PORTUGUESE', 'race_SOUTH AMERICAN', 'race_UNABLE TO OBTAIN', 'race_UNKNOWN', 'race_WHITE', 'race_WHITE - BRAZILIAN', 'race_WHITE - EASTERN EUROPEAN', 'race_WHITE - RUSSIAN', 'race_WHITE - OTHER EUROPEAN', 'procedure_227712', 'procedure_224276', 'admission_type_DIRECT OBSERVATION', 'admission_type_ELECTIVE', 'admission_type_EU OBSERVATION', 'admission_type_EW EMER.', 'admission_type_OBSERVATION ADMIT', 'admission_type_SURGICAL SAME DAY ADMISSION', 'admission_type_URGENT', 'admission_type_DIRECT EMER.', 'insurance_Medicare', 'insurance_Other', 'insurance_Medicaid', 'procedure_225792', 'procedure_228130', 'procedure_225817', 'procedure_224267', 'gender_F', 'gender_M', 'ventilation_used', 'hospital_stay_duration', 'oasis_score', 'procedure_228125', 'procedure_226124', 'procedure_225451', 'procedure_224275', 'procedure_229582', 'procedure_225427', 'procedure_229581', 'glucose', 'item_51301', 'spo2', 'procedure_228128', 'procedure_225401', 'procedure_225470', 'icu_stay_duration', 'unique_drugs', 'procedure_227194', 'procedure_224385', 'bun', 'anchor_age', 'heart_rate', 'procedure_225432', 'procedure_229614', 'pt', 'procedure_225454', 'creatinine', 'potassium', 'resp_rate', 'urine_output_total', 'procedure_221223', 'procedure_225444', 'procedure_224263', 'item_51265', 'mean_arterial_pressure', 'procedure_229351', 'procedure_225459', 'item_51222', 'systolic_bp', 'procedure_221214', 'procedure_225752', 'procedure_225802', 'procedure_225400', 'procedure_224270')
# % Combos Checked: 836 out of 2592 which is 32.253085999999996%
