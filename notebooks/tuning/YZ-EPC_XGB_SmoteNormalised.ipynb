# %% [markdown]
# # Tuning Script

# %%
# Parameters subject to change in every script - involved in naming

MODEL = 'epc'
PREPROCESSING = 'smote_normalise'
TUNER = 'yangzhoub'
OPTIMISED_METRIC = 'f1'

# %% [markdown]
# ---

# %%
# detect whether this is a google environment

COLAB_ENVIRONMENT = False

try:
    from google.colab import drive
    drive.mount('/content/drive')
    COLAB_ENVIRONMENT = True
except:
    pass
# Out:
# Mounted at /content/drive

# %%
import sys
import os
import pickle

if COLAB_ENVIRONMENT:
    home_directory = './drive/MyDrive/LAB/COMP90089__GroupWork__Py/' # my home directory is stored in ./LAB of google drive
    if MODEL == 'ebr':
        # !pip install interpret==0.5.0
    elif MODEL == 'cbr':
        # !pip install catboost
    elif MODEL == 'epc':
        # !pip install scikit-learn-extra
    elif MODEL in ['tf', 'mlp']:
        # !pip install PyTorch2Sklearn
    # !pip install JXAutoML
else:
    home_directory = '../../'

from JXAutoML.YangZhouB_10CV import YangZhouB_10CV as Tuner

import pandas as pd
# Out:
# Collecting scikit-learn-extra
#   Downloading scikit_learn_extra-0.3.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.6 kB)
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.10/dist-packages (from scikit-learn-extra) (1.26.4)
# Requirement already satisfied: scipy>=0.19.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn-extra) (1.13.1)
# Requirement already satisfied: scikit-learn>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn-extra) (1.5.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.23.0->scikit-learn-extra) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.23.0->scikit-learn-extra) (3.5.0)
# Downloading scikit_learn_extra-0.3.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 33.4 MB/s eta 0:00:00
# Installing collected packages: scikit-learn-extra
# Successfully installed scikit-learn-extra-0.3.0
# Collecting JXAutoML
#   Downloading JXAutoML-0.4.4-py3-none-any.whl.metadata (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.2/67.2 kB 4.6 MB/s eta 0:00:00
# Downloading JXAutoML-0.4.4-py3-none-any.whl (52 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.1/52.1 kB 4.2 MB/s eta 0:00:00
# Installing collected packages: JXAutoML
# Successfully installed JXAutoML-0.4.4

# %%
# Parameters that are same for every script

FOLDS = 10  # we have decided to do 10 fold validation

SEED = 42

TASK_TYPE = 'Classification'  # this task is a classification task

# we have decided to tune features as hp
TUNE_FEATURES_AS_HYPERPARAMETERS = True

# %% [markdown]
# ---

# %%
# model to use to tune
from sklearn_extra.kernel_methods import EigenProClassifier as clf

# what values to try for each hyperparameter
parameter_choices = {
    'batch_size': (32, 64, 128, 256),
    'n_epoch': list(range(1, 10))

}

# what values to set non-tuneable parameters/hyperparameters
non_tunable_hyperparameters_dict = {
                                    'random_state': 42,

                                    }

# %% [markdown]
# ---

# %% [markdown]
# Read in and Prepare Data

# %%
# Import data and store as lists

train_x_list = []
train_y_list = []
val_x_list = []
val_y_list = []

for i in range(FOLDS):
    train_data = pd.read_csv(
        f'{home_directory}data/curated/modelling/{PREPROCESSING}/train_{i}.csv')
    val_data = pd.read_csv(
        f'{home_directory}data/curated/modelling/{PREPROCESSING}/val_{i}.csv')

    # get the correct rows for X and y
    train_x = train_data.drop(
        ['mortality_status', 'subject_id', 'hadm_id', 'stay_id'], axis=1)
    train_y = train_data['mortality_status']
    val_x = val_data.drop(
        ['mortality_status', 'subject_id', 'hadm_id', 'stay_id'], axis=1)
    val_y = val_data['mortality_status']

    train_x_list.append(train_x)
    train_y_list.append(train_y)
    val_x_list.append(val_x)
    val_y_list.append(val_y)

# %%
# Import feature importance ordering

with open(f'{home_directory}models/xgb_feature_importance_ordering_{PREPROCESSING}.pickle', 'rb') as f:
    feature_importance_ordering = pickle.load(f)

# %% [markdown]
# Set parameters

# %%
# initialisation
tuner = Tuner()

print('---')

# define what model we are tuning
tuner.read_in_model(clf, TASK_TYPE, optimised_metric=OPTIMISED_METRIC)

print('---')

# read in the data for training and validation
tuner.read_in_data(train_x_list, train_y_list, val_x_list, val_y_list)

print('---')

# set what hp values to tune
tuner.set_hyperparameters(parameter_choices)
# WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

# set up hp values that need to be changed from default but NOT to be tuned
tuner.set_non_tuneable_hyperparameters(non_tunable_hyperparameters_dict)

print('---')

# set up feature importance ordering

if TUNE_FEATURES_AS_HYPERPARAMETERS:
    tuner.set_features(feature_importance_ordering)
    # WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

try:  # try to read in previous results to continue tuning ...
    tuner.read_in_tuning_result_df(
        f'{home_directory}models/tuning/{TUNER}_{MODEL}_{PREPROCESSING}.csv')
except:
    print('No previous tuning data read in')

print('---')

# set up where to save the tuning result csv
tuner.set_tuning_result_saving_address(
    f'{home_directory}models/tuning/{TUNER}_{MODEL}_{PREPROCESSING}.csv')

print('---')

# set up where to save the current best model
tuner.set_best_model_saving_address(
    f'{home_directory}models/tmp_models/{TUNER}_{MODEL}_{PREPROCESSING}')
# Out:
# YangZhouB Initialised
# ---
# Successfully read in model <class 'sklearn_extra.kernel_methods._eigenpro.EigenProClassifier'>, which is a Classification model optimising for f1
# ---
# Read in Train X data list
# Read in Train y data list
# Read in Val X data list
# Read in Val y data list
# ---
# Successfully recorded hyperparameter choices
# ---
# Successfully recorded non_tuneable_hyperparameter choices
# ---
# Successfully recorded tuneable feature combination choices and updated relevant internal structures
# ---
# No previous tuning data read in
# ---
# Successfully set tuning output address
# ---
# Successfully set best model output address

# %%
# ignore warnings

import warnings
warnings.filterwarnings("ignore")

# %%
# begin tuning ... (or continue training)

tuner.tune()
# Out:
# BEGIN TUNING
#
#
# STAGE ZERO: Tune all Cruise combinations
#
#
# Trained and Tested combination 1 of 1836, taking 12.1 seconds to get val score of 0.3118:
#                 {'batch_size': 256, 'n_epoch': 5, 'features': 35},
#             Current best combo with val score 0.3118:
#                     {'batch_size': 256, 'n_epoch': 5, 'features': 35}
# Trained and Tested combination 2 of 1836, taking 14.5 seconds to get val score of 0.3118:
#                 {'batch_size': 256, 'n_epoch': 9, 'features': 50},
#             Current best combo with val score 0.3118:
#                     {'batch_size': 256, 'n_epoch': 5, 'features': 35}
# Trained and Tested combination 3 of 1836, taking 15.06 seconds to get val score of 0.3118:
#                 {'batch_size': 32, 'n_epoch': 5, 'features': 40},
#             Current best combo with val score 0.3118:
#                     {'batch_size': 256, 'n_epoch': 5, 'features': 35}
# Trained and Tested combination 4 of 1836, taking 11.91 seconds to get val score of 0.3118:
#                 {'batch_size': 256, 'n_epoch': 5, 'features': 30},
#             Current best combo with val score 0.3118:
#                     {'batch_size': 256, 'n_epoch': 5, 'features': 35}
# Trained and Tested combination 5 of 1836, taking 13.04 seconds to get val score of 0.3118:
#                 {'batch_size': 32, 'n_epoch': 5, 'features': 30},
#             Current best combo with val score 0.3118:
#                     {'batch_size': 256, 'n_epoch': 5, 'features': 35}
# Trained and Tested combination 6 of 1836, taking 16.52 seconds to get val score of 0.3118:
#                 {'batch_size': 32, 'n_epoch': 5, 'features': 50},
#             Current best combo with val score 0.3118:
#                     {'batch_size': 256, 'n_epoch': 5, 'features': 35}
# Trained and Tested combination 7 of 1836, taking 10.76 seconds to get val score of 0.3122:
#                 {'batch_size': 32, 'n_epoch': 1, 'features': 50},
#             Current best combo with val score 0.3122:
#                     {'batch_size': 32, 'n_epoch': 1, 'features': 50}
# Trained and Tested combination 8 of 1836, taking 13.45 seconds to get val score of 0.3118:
#                 {'batch_size': 32, 'n_epoch': 1, 'features': 40},
#             Current best combo with val score 0.3122:
#                     {'batch_size': 32, 'n_epoch': 1, 'features': 50}
# Trained and Tested combination 9 of 1836, taking 6.63 seconds to get val score of 0.2805:
#                 {'batch_size': 256, 'n_epoch': 1, 'features': 25},
#             Current best combo with val score 0.3122:
#                     {'batch_size': 32, 'n_epoch': 1, 'features': 50}
# Trained and Tested combination 10 of 1836, taking 11.24 seconds to get val score of 0.3124:
#                 {'batch_size': 32, 'n_epoch': 1, 'features': 45},
#             Current best combo with val score 0.3124:
#                     {'batch_size': 32, 'n_epoch': 1, 'features': 45}
# Trained and Tested combination 11 of 1836, taking 16.39 seconds to get val score of 0.0:
#                 {'batch_size': 32, 'n_epoch': 9, 'features': 15},
#             Current best combo with val score 0.3124:
#                     {'batch_size': 32, 'n_epoch': 1, 'features': 45}
# Trained and Tested combination 12 of 1836, taking 16.91 seconds to get val score of 0.0:
#                 {'batch_size': 32, 'n_epoch': 5, 'features': 10},
#             Current best combo with val score 0.3124:
#                     {'batch_size': 32, 'n_epoch': 1, 'features': 45}
# Trained and Tested combination 13 of 1836, taking 8.61 seconds to get val score of 0.2805:
#                 {'batch_size': 256, 'n_epoch': 1, 'features': 30},
#             Current best combo with val score 0.3124:
#                     {'batch_size': 32, 'n_epoch': 1, 'features': 45}
# Trained and Tested combination 14 of 1836, taking 6.98 seconds to get val score of 0.2805:
#                 {'batch_size': 256, 'n_epoch': 1, 'features': 20},
#             Current best combo with val score 0.3124:
#                     {'batch_size': 32, 'n_epoch': 1, 'features': 45}
# Trained and Tested combination 15 of 1836, taking 9.27 seconds to get val score of 0.0289:
#                 {'batch_size': 256, 'n_epoch': 5, 'features': 0},
#             Current best combo with val score 0.3124:
#                     {'batch_size': 32, 'n_epoch': 1, 'features': 45}
# Trained and Tested combination 16 of 1836, taking 19.68 seconds to get val score of 0.3117:
#                 {'batch_size': 32, 'n_epoch': 9, 'features': 20},
#             Current best combo with val score 0.3124:
#                     {'batch_size': 32, 'n_epoch': 1, 'features': 45}
# Trained and Tested combination 17 of 1836, taking 12.6 seconds to get val score of 0.0:
#                 {'batch_size': 256, 'n_epoch': 9, 'features': 15},
#             Current best combo with val score 0.3124:
#                     {'batch_size': 32, 'n_epoch': 1, 'features': 45}
# Trained and Tested combination 18 of 1836, taking 10.48 seconds to get val score of 0.0196:
#                 {'batch_size': 256, 'n_epoch': 9, 'features': 5},
#             Current best combo with val score 0.3124:
#                     {'batch_size': 32, 'n_epoch': 1, 'features': 45}
# Trained and Tested combination 19 of 1836, taking 10.31 seconds to get val score of 0.0574:
#                 {'batch_size': 32, 'n_epoch': 5, 'features': 0},
#             Current best combo with val score 0.3124:
#                     {'batch_size': 32, 'n_epoch': 1, 'features': 45}
# Trained and Tested combination 20 of 1836, taking 10.22 seconds to get val score of 0.0:
#                 {'batch_size': 256, 'n_epoch': 5, 'features': 10},
#             Current best combo with val score 0.3124:
#                     {'batch_size': 32, 'n_epoch': 1, 'features': 45}
# Trained and Tested combination 21 of 1836, taking 18.85 seconds to get val score of 0.3117:
#                 {'batch_size': 32, 'n_epoch': 9, 'features': 35},
#             Current best combo with val score 0.3124:
#                     {'batch_size': 32, 'n_epoch': 1, 'features': 45}
# Trained and Tested combination 22 of 1836, taking 18.62 seconds to get val score of 0.3117:
#                 {'batch_size': 256, 'n_epoch': 9, 'features': 30},
#             Current best combo with val score 0.3124:
#                     {'batch_size': 32, 'n_epoch': 1, 'features': 45}
# Trained and Tested combination 23 of 1836, taking 14.34 seconds to get val score of 0.1849:
#                 {'batch_size': 32, 'n_epoch': 9, 'features': 0},
#             Current best combo with val score 0.3124:
#                     {'batch_size': 32, 'n_epoch': 1, 'features': 45}
# Trained and Tested combination 24 of 1836, taking 14.39 seconds to get val score of 0.3119:
#                 {'batch_size': 256, 'n_epoch': 9, 'features': 40},
#             Current best combo with val score 0.3124:
#                     {'batch_size': 32, 'n_epoch': 1, 'features': 45}
# Trained and Tested combination 25 of 1836, taking 13.26 seconds to get val score of 0.0196:
#                 {'batch_size': 256, 'n_epoch': 1, 'features': 5},
#             Current best combo with val score 0.3124:
#                     {'batch_size': 32, 'n_epoch': 1, 'features': 45}
# Trained and Tested combination 26 of 1836, taking 12.28 seconds to get val score of 0.3117:
#                 {'batch_size': 32, 'n_epoch': 5, 'features': 25},
#             Current best combo with val score 0.3124:
#                     {'batch_size': 32, 'n_epoch': 1, 'features': 45}
# Trained and Tested combination 27 of 1836, taking 7.04 seconds to get val score of 0.2805:
#                 {'batch_size': 32, 'n_epoch': 1, 'features': 20},
#             Current best combo with val score 0.3124:
#                     {'batch_size': 32, 'n_epoch': 1, 'features': 45}
# Trained and Tested combination 28 of 1836, taking 8.9 seconds to get val score of 0.0:
#                 {'batch_size': 256, 'n_epoch': 1, 'features': 10},
#             Current best combo with val score 0.3124:
#                     {'batch_size': 32, 'n_epoch': 1, 'features': 45}
# Trained and Tested combination 29 of 1836, taking 11.88 seconds to get val score of 0.3117:
#                 {'batch_size': 256, 'n_epoch': 5, 'features': 20},
#             Current best combo with val score 0.3124:
#                     {'batch_size': 32, 'n_epoch': 1, 'features': 45}
# Trained and Tested combination 30 of 1836, taking 12.72 seconds to get val score of 0.3118:
#                 {'batch_size': 256, 'n_epoch': 5, 'features': 40},
#             Current best combo with val score 0.3124:
#                     {'batch_size': 32, 'n_epoch': 1, 'features': 45}
# Trained and Tested combination 31 of 1836, taking 13.81 seconds to get val score of 0.3118:
#                 {'batch_size': 32, 'n_epoch': 5, 'features': 35},
#             Current best combo with val score 0.3124:
#                     {'batch_size': 32, 'n_epoch': 1, 'features': 45}
# Trained and Tested combination 32 of 1836, taking 10.55 seconds to get val score of 0.3119:
#                 {'batch_size': 256, 'n_epoch': 1, 'features': 50},
#             Current best combo with val score 0.3124:
#                     {'batch_size': 32, 'n_epoch': 1, 'features': 45}
# Trained and Tested combination 33 of 1836, taking 11.86 seconds to get val score of 0.3117:
#                 {'batch_size': 256, 'n_epoch': 5, 'features': 25},
#             Current best combo with val score 0.3124:
#                     {'batch_size': 32, 'n_epoch': 1, 'features': 45}
# Trained and Tested combination 34 of 1836, taking 14.92 seconds to get val score of 0.3118:
#                 {'batch_size': 256, 'n_epoch': 5, 'features': 45},
#             Current best combo with val score 0.3124:
#                     {'batch_size': 32, 'n_epoch': 1, 'features': 45}
# Trained and Tested combination 35 of 1836, taking 16.27 seconds to get val score of 0.3118:
#                 {'batch_size': 32, 'n_epoch': 5, 'features': 45},
#             Current best combo with val score 0.3124:
#                     {'batch_size': 32, 'n_epoch': 1, 'features': 45}
# Trained and Tested combination 36 of 1836, taking 13.01 seconds to get val score of 0.3117:
#                 {'batch_size': 256, 'n_epoch': 9, 'features': 35},
#             Current best combo with val score 0.3124:
#                     {'batch_size': 32, 'n_epoch': 1, 'features': 45}
# Trained and Tested combination 37 of 1836, taking 20.68 seconds to get val score of 0.3118:
#                 {'batch_size': 32, 'n_epoch': 9, 'features': 45},
#             Current best combo with val score 0.3124:
#                     {'batch_size': 32, 'n_epoch': 1, 'features': 45}
# Trained and Tested combination 38 of 1836, taking 17.15 seconds to get val score of 0.3117:
#                 {'batch_size': 32, 'n_epoch': 9, 'features': 25},
#             Current best combo with val score 0.3124:
#                     {'batch_size': 32, 'n_epoch': 1, 'features': 45}
# Trained and Tested combination 39 of 1836, taking 18.28 seconds to get val score of 0.0033:
#                 {'batch_size': 32, 'n_epoch': 9, 'features': 10},
#             Current best combo with val score 0.3124:
#                     {'batch_size': 32, 'n_epoch': 1, 'features': 45}
# Trained and Tested combination 40 of 1836, taking 23.46 seconds to get val score of 0.3118:
#                 {'batch_size': 32, 'n_epoch': 9, 'features': 50},
#             Current best combo with val score 0.3124:
#                     {'batch_size': 32, 'n_epoch': 1, 'features': 45}
# Trained and Tested combination 41 of 1836, taking 11.19 seconds to get val score of 0.0:
#                 {'batch_size': 32, 'n_epoch': 5, 'features': 15},
#             Current best combo with val score 0.3124:
#                     {'batch_size': 32, 'n_epoch': 1, 'features': 45}
# Trained and Tested combination 42 of 1836, taking 10.41 seconds to get val score of 0.0:
#                 {'batch_size': 32, 'n_epoch': 1, 'features': 10},
#             Current best combo with val score 0.3124:
#                     {'batch_size': 32, 'n_epoch': 1, 'features': 45}
# Trained and Tested combination 43 of 1836, taking 9.97 seconds to get val score of 0.2805:
#                 {'batch_size': 32, 'n_epoch': 1, 'features': 30},
#             Current best combo with val score 0.3124:
#                     {'batch_size': 32, 'n_epoch': 1, 'features': 45}
# Trained and Tested combination 44 of 1836, taking 13.61 seconds to get val score of 0.0:
#                 {'batch_size': 32, 'n_epoch': 1, 'features': 0},
#             Current best combo with val score 0.3124:
#                     {'batch_size': 32, 'n_epoch': 1, 'features': 45}
# Trained and Tested combination 45 of 1836, taking 11.91 seconds to get val score of 0.3118:
#                 {'batch_size': 256, 'n_epoch': 5, 'features': 50},
#             Current best combo with val score 0.3124:
#                     {'batch_size': 32, 'n_epoch': 1, 'features': 45}
# Trained and Tested combination 46 of 1836, taking 12.08 seconds to get val score of 0.0196:
#                 {'batch_size': 32, 'n_epoch': 9, 'features': 5},
#             Current best combo with val score 0.3124:
#                     {'batch_size': 32, 'n_epoch': 1, 'features': 45}
# Trained and Tested combination 47 of 1836, taking 13.39 seconds to get val score of 0.0033:
#                 {'batch_size': 256, 'n_epoch': 9, 'features': 10},
#             Current best combo with val score 0.3124:
#                     {'batch_size': 32, 'n_epoch': 1, 'features': 45}
# Trained and Tested combination 48 of 1836, taking 8.25 seconds to get val score of 0.0:
#                 {'batch_size': 256, 'n_epoch': 1, 'features': 0},
#             Current best combo with val score 0.3124:
#                     {'batch_size': 32, 'n_epoch': 1, 'features': 45}
# Trained and Tested combination 49 of 1836, taking 11.15 seconds to get val score of 0.0196:
#                 {'batch_size': 32, 'n_epoch': 5, 'features': 5},
#             Current best combo with val score 0.3124:
#                     {'batch_size': 32, 'n_epoch': 1, 'features': 45}
# Trained and Tested combination 50 of 1836, taking 12.56 seconds to get val score of 0.1202:
#                 {'batch_size': 256, 'n_epoch': 9, 'features': 0},
#             Current best combo with val score 0.3124:
#                     {'batch_size': 32, 'n_epoch': 1, 'features': 45}
# Trained and Tested combination 51 of 1836, taking 9.33 seconds to get val score of 0.0:
#                 {'batch_size': 32, 'n_epoch': 1, 'features': 15},
#             Current best combo with val score 0.3124:
#                     {'batch_size': 32, 'n_epoch': 1, 'features': 45}
# Trained and Tested combination 52 of 1836, taking 21.22 seconds to get val score of 0.3118:
#                 {'batch_size': 32, 'n_epoch': 9, 'features': 40},
#             Current best combo with val score 0.3124:
#                     {'batch_size': 32, 'n_epoch': 1, 'features': 45}
# Trained and Tested combination 53 of 1836, taking 10.95 seconds to get val score of 0.3117:
#                 {'batch_size': 32, 'n_epoch': 5, 'features': 20},
#             Current best combo with val score 0.3124:
#                     {'batch_size': 32, 'n_epoch': 1, 'features': 45}
# Trained and Tested combination 54 of 1836, taking 9.97 seconds to get val score of 0.0196:
#                 {'batch_size': 256, 'n_epoch': 5, 'features': 5},
#             Current best combo with val score 0.3124:
#                     {'batch_size': 32, 'n_epoch': 1, 'features': 45}
# Trained and Tested combination 55 of 1836, taking 13.89 seconds to get val score of 0.3117:
#                 {'batch_size': 256, 'n_epoch': 9, 'features': 25},
#             Current best combo with val score 0.3124:
#                     {'batch_size': 32, 'n_epoch': 1, 'features': 45}
# Trained and Tested combination 56 of 1836, taking 7.63 seconds to get val score of 0.3043:
#                 {'batch_size': 32, 'n_epoch': 1, 'features': 35},
#             Current best combo with val score 0.3124:
#                     {'batch_size': 32, 'n_epoch': 1, 'features': 45}
# Trained and Tested combination 57 of 1836, taking 10.36 seconds to get val score of 0.299:
#                 {'batch_size': 256, 'n_epoch': 1, 'features': 35},
#             Current best combo with val score 0.3124:
#                     {'batch_size': 32, 'n_epoch': 1, 'features': 45}
# Trained and Tested combination 58 of 1836, taking 21.13 seconds to get val score of 0.3117:
#                 {'batch_size': 32, 'n_epoch': 9, 'features': 30},
#             Current best combo with val score 0.3124:
#                     {'batch_size': 32, 'n_epoch': 1, 'features': 45}
# Trained and Tested combination 59 of 1836, taking 10.22 seconds to get val score of 0.2805:
#                 {'batch_size': 32, 'n_epoch': 1, 'features': 25},
#             Current best combo with val score 0.3124:
#                     {'batch_size': 32, 'n_epoch': 1, 'features': 45}
# Trained and Tested combination 60 of 1836, taking 10.32 seconds to get val score of 0.0196:
#                 {'batch_size': 32, 'n_epoch': 1, 'features': 5},
#             Current best combo with val score 0.3124:
#                     {'batch_size': 32, 'n_epoch': 1, 'features': 45}
# Trained and Tested combination 61 of 1836, taking 13.33 seconds to get val score of 0.3117:
#                 {'batch_size': 256, 'n_epoch': 9, 'features': 20},
#             Current best combo with val score 0.3124:
#                     {'batch_size': 32, 'n_epoch': 1, 'features': 45}
# Trained and Tested combination 62 of 1836, taking 10.25 seconds to get val score of 0.3118:
#                 {'batch_size': 256, 'n_epoch': 1, 'features': 40},
#             Current best combo with val score 0.3124:
#                     {'batch_size': 32, 'n_epoch': 1, 'features': 45}
# Trained and Tested combination 63 of 1836, taking 7.32 seconds to get val score of 0.0:
#                 {'batch_size': 256, 'n_epoch': 1, 'features': 15},
#             Current best combo with val score 0.3124:
#                     {'batch_size': 32, 'n_epoch': 1, 'features': 45}
# Trained and Tested combination 64 of 1836, taking 6.74 seconds to get val score of 0.3115:
#                 {'batch_size': 256, 'n_epoch': 1, 'features': 45},
#             Current best combo with val score 0.3124:
#                     {'batch_size': 32, 'n_epoch': 1, 'features': 45}
# Trained and Tested combination 65 of 1836, taking 11.87 seconds to get val score of 0.3117:
#                 {'batch_size': 128, 'n_epoch': 5, 'features': 25},
#             Current best combo with val score 0.3124:
#                     {'batch_size': 32, 'n_epoch': 1, 'features': 45}
# Trained and Tested combination 66 of 1836, taking 9.73 seconds to get val score of 0.0:
#                 {'batch_size': 256, 'n_epoch': 5, 'features': 15},
#             Current best combo with val score 0.3124:
#                     {'batch_size': 32, 'n_epoch': 1, 'features': 45}
# Trained and Tested combination 67 of 1836, taking 13.44 seconds to get val score of 0.3118:
#                 {'batch_size': 256, 'n_epoch': 9, 'features': 45},
#             Current best combo with val score 0.3124:
#                     {'batch_size': 32, 'n_epoch': 1, 'features': 45}
#
#
# STAGE ONE: Begin initial Guidance system
#
#
# Guidance: initial round
#
# 	round 0 iteration:  0
#
# Trained and Tested combination 68 of 1836, taking 11.4 seconds to get val score of 0.3117:
#                 {'batch_size': 64, 'n_epoch': 5, 'features': 25},
#             Current best combo with val score 0.3124:
#                     {'batch_size': 32, 'n_epoch': 1, 'features': 45}
# Already Trained and Tested combination (val score of 0.3117):
#             {'batch_size': 256, 'n_epoch': 5, 'features': 25}
#             Current best combo (with val score 0.3124):
#                     {'batch_size': 32, 'n_epoch': 1, 'features': 45}
#         Has trained 68 of 1836 combinations so far
# Trained and Tested combination 69 of 1836, taking 12.01 seconds to get val score of 0.3117:
#                 {'batch_size': 128, 'n_epoch': 4, 'features': 25},
#             Current best combo with val score 0.3124:
#                     {'batch_size': 32, 'n_epoch': 1, 'features': 45}
# Trained and Tested combination 70 of 1836, taking 16.71 seconds to get val score of 0.3117:
#                 {'batch_size': 128, 'n_epoch': 6, 'features': 25},
#             Current best combo with val score 0.3124:
#                     {'batch_size': 32, 'n_epoch': 1, 'features': 45}
# Trained and Tested combination 71 of 1836, taking 12.18 seconds to get val score of 0.3117:
#                 {'batch_size': 128, 'n_epoch': 5, 'features': 24},
#             Current best combo with val score 0.3124:
#                     {'batch_size': 32, 'n_epoch': 1, 'features': 45}
# Trained and Tested combination 72 of 1836, taking 11.16 seconds to get val score of 0.3117:
#                 {'batch_size': 128, 'n_epoch': 5, 'features': 26},
#             Current best combo with val score 0.3124:
#                     {'batch_size': 32, 'n_epoch': 1, 'features': 45}
# 	round 0 iteration:  1
#
# Already Trained and Tested combination (val score of 0.3117):
#             {'batch_size': 32, 'n_epoch': 5, 'features': 25}
#             Current best combo (with val score 0.3124):
#                     {'batch_size': 32, 'n_epoch': 1, 'features': 45}
#         Has trained 72 of 1836 combinations so far
# Already Trained and Tested combination (val score of 0.3117):
#             {'batch_size': 128, 'n_epoch': 5, 'features': 25}
#             Current best combo (with val score 0.3124):
#                     {'batch_size': 32, 'n_epoch': 1, 'features': 45}
#         Has trained 72 of 1836 combinations so far
# Trained and Tested combination 73 of 1836, taking 10.84 seconds to get val score of 0.3117:
#                 {'batch_size': 64, 'n_epoch': 4, 'features': 25},
#             Current best combo with val score 0.3124:
#                     {'batch_size': 32, 'n_epoch': 1, 'features': 45}
# Trained and Tested combination 74 of 1836, taking 16.27 seconds to get val score of 0.3117:
#                 {'batch_size': 64, 'n_epoch': 6, 'features': 25},
#             Current best combo with val score 0.3124:
#                     {'batch_size': 32, 'n_epoch': 1, 'features': 45}
# Trained and Tested combination 75 of 1836, taking 11.73 seconds to get val score of 0.3117:
#                 {'batch_size': 64, 'n_epoch': 5, 'features': 24},
#             Current best combo with val score 0.3124:
#                     {'batch_size': 32, 'n_epoch': 1, 'features': 45}
# Trained and Tested combination 76 of 1836, taking 13.04 seconds to get val score of 0.3117:
#                 {'batch_size': 64, 'n_epoch': 5, 'features': 26},
#             Current best combo with val score 0.3124:
#                     {'batch_size': 32, 'n_epoch': 1, 'features': 45}
# Already Trained and Tested combination (val score of 0.3117):
#             {'batch_size': 128, 'n_epoch': 5, 'features': 25}
#             Current best combo (with val score 0.3124):
#                     {'batch_size': 32, 'n_epoch': 1, 'features': 45}
#         Has trained 76 of 1836 combinations so far
# Trained and Tested combination 77 of 1836, taking 12.36 seconds to get val score of 0.3117:
#                 {'batch_size': 256, 'n_epoch': 4, 'features': 25},
#             Current best combo with val score 0.3124:
#                     {'batch_size': 32, 'n_epoch': 1, 'features': 45}
# Trained and Tested combination 78 of 1836, taking 9.24 seconds to get val score of 0.3117:
#                 {'batch_size': 256, 'n_epoch': 6, 'features': 25},
#             Current best combo with val score 0.3124:
#                     {'batch_size': 32, 'n_epoch': 1, 'features': 45}
# Trained and Tested combination 79 of 1836, taking 8.88 seconds to get val score of 0.3117:
#                 {'batch_size': 256, 'n_epoch': 5, 'features': 24},
#             Current best combo with val score 0.3124:
#                     {'batch_size': 32, 'n_epoch': 1, 'features': 45}
# Trained and Tested combination 80 of 1836, taking 8.53 seconds to get val score of 0.3117:
#                 {'batch_size': 256, 'n_epoch': 5, 'features': 26},
#             Current best combo with val score 0.3124:
#                     {'batch_size': 32, 'n_epoch': 1, 'features': 45}
# Already Trained and Tested combination (val score of 0.3117):
#             {'batch_size': 64, 'n_epoch': 4, 'features': 25}
#             Current best combo (with val score 0.3124):
#                     {'batch_size': 32, 'n_epoch': 1, 'features': 45}
#         Has trained 80 of 1836 combinations so far
# Already Trained and Tested combination (val score of 0.3117):
#             {'batch_size': 256, 'n_epoch': 4, 'features': 25}
#             Current best combo (with val score 0.3124):
#                     {'batch_size': 32, 'n_epoch': 1, 'features': 45}
#         Has trained 80 of 1836 combinations so far
# Trained and Tested combination 81 of 1836, taking 11.01 seconds to get val score of 0.3117:
#                 {'batch_size': 128, 'n_epoch': 3, 'features': 25},
#             Current best combo with val score 0.3124:
#                     {'batch_size': 32, 'n_epoch': 1, 'features': 45}
# Already Trained and Tested combination (val score of 0.3117):
#             {'batch_size': 128, 'n_epoch': 5, 'features': 25}
#             Current best combo (with val score 0.3124):
#                     {'batch_size': 32, 'n_epoch': 1, 'features': 45}
#         Has trained 81 of 1836 combinations so far
# Trained and Tested combination 82 of 1836, taking 10.08 seconds to get val score of 0.3117:
#                 {'batch_size': 128, 'n_epoch': 4, 'features': 24},
#             Current best combo with val score 0.3124:
#                     {'batch_size': 32, 'n_epoch': 1, 'features': 45}
# Trained and Tested combination 83 of 1836, taking 8.76 seconds to get val score of 0.3117:
#                 {'batch_size': 128, 'n_epoch': 4, 'features': 26},
#             Current best combo with val score 0.3124:
#                     {'batch_size': 32, 'n_epoch': 1, 'features': 45}
# Already Trained and Tested combination (val score of 0.3117):
#             {'batch_size': 64, 'n_epoch': 6, 'features': 25}
#             Current best combo (with val score 0.3124):
#                     {'batch_size': 32, 'n_epoch': 1, 'features': 45}
#         Has trained 83 of 1836 combinations so far
# Already Trained and Tested combination (val score of 0.3117):
#             {'batch_size': 256, 'n_epoch': 6, 'features': 25}
#             Current best combo (with val score 0.3124):
#                     {'batch_size': 32, 'n_epoch': 1, 'features': 45}
#         Has trained 83 of 1836 combinations so far
# Already Trained and Tested combination (val score of 0.3117):
#             {'batch_size': 128, 'n_epoch': 5, 'features': 25}
#             Current best combo (with val score 0.3124):
#                     {'batch_size': 32, 'n_epoch': 1, 'features': 45}
#         Has trained 83 of 1836 combinations so far
# Trained and Tested combination 84 of 1836, taking 13.7 seconds to get val score of 0.3117:
#                 {'batch_size': 128, 'n_epoch': 7, 'features': 25},
#             Current best combo with val score 0.3124:
#                     {'batch_size': 32, 'n_epoch': 1, 'features': 45}
# Trained and Tested combination 85 of 1836, taking 12.51 seconds to get val score of 0.3117:
#                 {'batch_size': 128, 'n_epoch': 6, 'features': 24},
#             Current best combo with val score 0.3124:
#                     {'batch_size': 32, 'n_epoch': 1, 'features': 45}
# Trained and Tested combination 86 of 1836, taking 12.03 seconds to get val score of 0.3117:
#                 {'batch_size': 128, 'n_epoch': 6, 'features': 26},
#             Current best combo with val score 0.3124:
#                     {'batch_size': 32, 'n_epoch': 1, 'features': 45}
# Already Trained and Tested combination (val score of 0.3117):
#             {'batch_size': 64, 'n_epoch': 5, 'features': 24}
#             Current best combo (with val score 0.3124):
#                     {'batch_size': 32, 'n_epoch': 1, 'features': 45}
#         Has trained 86 of 1836 combinations so far
# Already Trained and Tested combination (val score of 0.3117):
#             {'batch_size': 256, 'n_epoch': 5, 'features': 24}
#             Current best combo (with val score 0.3124):
#                     {'batch_size': 32, 'n_epoch': 1, 'features': 45}
#         Has trained 86 of 1836 combinations so far
# Already Trained and Tested combination (val score of 0.3117):
#             {'batch_size': 128, 'n_epoch': 4, 'features': 24}
#             Current best combo (with val score 0.3124):
#                     {'batch_size': 32, 'n_epoch': 1, 'features': 45}
#         Has trained 86 of 1836 combinations so far
# Already Trained and Tested combination (val score of 0.3117):
#             {'batch_size': 128, 'n_epoch': 6, 'features': 24}
#             Current best combo (with val score 0.3124):
#                     {'batch_size': 32, 'n_epoch': 1, 'features': 45}
#         Has trained 86 of 1836 combinations so far
# Trained and Tested combination 87 of 1836, taking 11.45 seconds to get val score of 0.3117:
#                 {'batch_size': 128, 'n_epoch': 5, 'features': 23},
#             Current best combo with val score 0.3124:
#                     {'batch_size': 32, 'n_epoch': 1, 'features': 45}
# Already Trained and Tested combination (val score of 0.3117):
#             {'batch_size': 128, 'n_epoch': 5, 'features': 25}
#             Current best combo (with val score 0.3124):
#                     {'batch_size': 32, 'n_epoch': 1, 'features': 45}
#         Has trained 87 of 1836 combinations so far
# Already Trained and Tested combination (val score of 0.3117):
#             {'batch_size': 64, 'n_epoch': 5, 'features': 26}
#             Current best combo (with val score 0.3124):
#                     {'batch_size': 32, 'n_epoch': 1, 'features': 45}
#         Has trained 87 of 1836 combinations so far
# Already Trained and Tested combination (val score of 0.3117):
#             {'batch_size': 256, 'n_epoch': 5, 'features': 26}
#             Current best combo (with val score 0.3124):
#                     {'batch_size': 32, 'n_epoch': 1, 'features': 45}
#         Has trained 87 of 1836 combinations so far
# Already Trained and Tested combination (val score of 0.3117):
#             {'batch_size': 128, 'n_epoch': 4, 'features': 26}
#             Current best combo (with val score 0.3124):
#                     {'batch_size': 32, 'n_epoch': 1, 'features': 45}
#         Has trained 87 of 1836 combinations so far
# Already Trained and Tested combination (val score of 0.3117):
#             {'batch_size': 128, 'n_epoch': 6, 'features': 26}
#             Current best combo (with val score 0.3124):
#                     {'batch_size': 32, 'n_epoch': 1, 'features': 45}
#         Has trained 87 of 1836 combinations so far
# Already Trained and Tested combination (val score of 0.3117):
#             {'batch_size': 128, 'n_epoch': 5, 'features': 25}
#             Current best combo (with val score 0.3124):
#                     {'batch_size': 32, 'n_epoch': 1, 'features': 45}
#         Has trained 87 of 1836 combinations so far
# Trained and Tested combination 88 of 1836, taking 8.94 seconds to get val score of 0.3117:
#                 {'batch_size': 128, 'n_epoch': 5, 'features': 27},
#             Current best combo with val score 0.3124:
#                     {'batch_size': 32, 'n_epoch': 1, 'features': 45}
# Trained and Tested combination 89 of 1836, taking 9.83 seconds to get val score of 0.3125:
#                 {'batch_size': 64, 'n_epoch': 1, 'features': 45},
#             Current best combo with val score 0.3125:
#                     {'batch_size': 64, 'n_epoch': 1, 'features': 45}
# Trained and Tested combination 90 of 1836, taking 10.31 seconds to get val score of 0.3118:
#                 {'batch_size': 32, 'n_epoch': 2, 'features': 45},
#             Current best combo with val score 0.3125:
#                     {'batch_size': 64, 'n_epoch': 1, 'features': 45}
# Trained and Tested combination 91 of 1836, taking 11.23 seconds to get val score of 0.3119:
#                 {'batch_size': 32, 'n_epoch': 1, 'features': 44},
#             Current best combo with val score 0.3125:
#                     {'batch_size': 64, 'n_epoch': 1, 'features': 45}
# Trained and Tested combination 92 of 1836, taking 7.97 seconds to get val score of 0.312:
#                 {'batch_size': 32, 'n_epoch': 1, 'features': 46},
#             Current best combo with val score 0.3125:
#                     {'batch_size': 64, 'n_epoch': 1, 'features': 45}
# Already Trained and Tested combination (val score of 0.3124):
#             {'batch_size': 32, 'n_epoch': 1, 'features': 45}
#             Current best combo (with val score 0.3125):
#                     {'batch_size': 64, 'n_epoch': 1, 'features': 45}
#         Has trained 92 of 1836 combinations so far
# Trained and Tested combination 93 of 1836, taking 8.5 seconds to get val score of 0.3116:
#                 {'batch_size': 128, 'n_epoch': 1, 'features': 45},
#             Current best combo with val score 0.3125:
#                     {'batch_size': 64, 'n_epoch': 1, 'features': 45}
# Trained and Tested combination 94 of 1836, taking 9.29 seconds to get val score of 0.3118:
#                 {'batch_size': 64, 'n_epoch': 2, 'features': 45},
#             Current best combo with val score 0.3125:
#                     {'batch_size': 64, 'n_epoch': 1, 'features': 45}
# Trained and Tested combination 95 of 1836, taking 7.02 seconds to get val score of 0.3119:
#                 {'batch_size': 64, 'n_epoch': 1, 'features': 44},
#             Current best combo with val score 0.3125:
#                     {'batch_size': 64, 'n_epoch': 1, 'features': 45}
# Trained and Tested combination 96 of 1836, taking 13.14 seconds to get val score of 0.3123:
#                 {'batch_size': 64, 'n_epoch': 1, 'features': 46},
#             Current best combo with val score 0.3125:
#                     {'batch_size': 64, 'n_epoch': 1, 'features': 45}
# % Combos Checked Thus Far: 96 out of 1836 which is 5.228758%
# STAGE TWO: Begin Cruise system
#
#
# Cruising Coordrdinate 1 of 66
#
# Cruising Coordrdinate 2 of 66
#
# Cruising Coordrdinate 3 of 66
#
# Cruising Coordrdinate 4 of 66
#
# Cruising Coordrdinate 5 of 66
#
# Cruising Coordrdinate 6 of 66
#
# Cruising Coordrdinate 7 of 66
#
# Cruising Coordrdinate 8 of 66
#
# Cruising Coordrdinate 9 of 66
#
# Cruising Coordrdinate 10 of 66
#
# Cruising Coordrdinate 11 of 66
#
# Cruising Coordrdinate 12 of 66
#
# Cruising Coordrdinate 13 of 66
#
# Cruising Coordrdinate 14 of 66
#
# Cruising Coordrdinate 15 of 66
#
# Cruising Coordrdinate 16 of 66
#
# Cruising Coordrdinate 17 of 66
#
# Cruising Coordrdinate 18 of 66
#
# Cruising Coordrdinate 19 of 66
#
# Cruising Coordrdinate 20 of 66
#
# Cruising Coordrdinate 21 of 66
#
# Cruising Coordrdinate 22 of 66
#
# Cruising Coordrdinate 23 of 66
#
# Cruising Coordrdinate 24 of 66
#
# Cruising Coordrdinate 25 of 66
#
# Cruising Coordrdinate 26 of 66
#
# Cruising Coordrdinate 27 of 66
#
# Cruising Coordrdinate 28 of 66
#
# Cruising Coordrdinate 29 of 66
#
# Cruising Coordrdinate 30 of 66
#
# Cruising Coordrdinate 31 of 66
#
# Cruising Coordrdinate 32 of 66
#
# Cruising Coordrdinate 33 of 66
#
# Cruising Coordrdinate 34 of 66
#
# Cruising Coordrdinate 35 of 66
#
# Cruising Coordrdinate 36 of 66
#
# Cruising Coordrdinate 37 of 66
#
# Cruising Coordrdinate 38 of 66
#
# Cruising Coordrdinate 39 of 66
#
# Cruising Coordrdinate 40 of 66
#
# Cruising Coordrdinate 41 of 66
#
# Cruising Coordrdinate 42 of 66
#
# Cruising Coordrdinate 43 of 66
#
# Cruising Coordrdinate 44 of 66
#
# Cruising Coordrdinate 45 of 66
#
# Cruising Coordrdinate 46 of 66
#
# Cruising Coordrdinate 47 of 66
#
# Cruising Coordrdinate 48 of 66
#
# Cruising Coordrdinate 49 of 66
#
# Cruise suspended due to suspicious case
# Guidance: round 1
#
# 	round 1 iteration:  0
#
# Trained and Tested combination 97 of 1836, taking 13.88 seconds to get val score of 0.3118:
#                 {'batch_size': 128, 'n_epoch': 9, 'features': 40},
#             Current best combo with val score 0.3125:
#                     {'batch_size': 64, 'n_epoch': 1, 'features': 45}
# Trained and Tested combination 98 of 1836, taking 13.58 seconds to get val score of 0.3118:
#                 {'batch_size': 256, 'n_epoch': 8, 'features': 40},
#             Current best combo with val score 0.3125:
#                     {'batch_size': 64, 'n_epoch': 1, 'features': 45}
# Trained and Tested combination 99 of 1836, taking 17.03 seconds to get val score of 0.3119:
#                 {'batch_size': 256, 'n_epoch': 9, 'features': 39},
#             Current best combo with val score 0.3125:
#                     {'batch_size': 64, 'n_epoch': 1, 'features': 45}
# Trained and Tested combination 100 of 1836, taking 13.46 seconds to get val score of 0.3062:
#                 {'batch_size': 256, 'n_epoch': 9, 'features': 41},
#             Current best combo with val score 0.3125:
#                     {'batch_size': 64, 'n_epoch': 1, 'features': 45}
# 	round 1 iteration:  1
#
# Trained and Tested combination 101 of 1836, taking 17.9 seconds to get val score of 0.3118:
#                 {'batch_size': 64, 'n_epoch': 9, 'features': 40},
#             Current best combo with val score 0.3125:
#                     {'batch_size': 64, 'n_epoch': 1, 'features': 45}
# Already Trained and Tested combination (val score of 0.3119):
#             {'batch_size': 256, 'n_epoch': 9, 'features': 40}
#             Current best combo (with val score 0.3125):
#                     {'batch_size': 64, 'n_epoch': 1, 'features': 45}
#         Has trained 101 of 1836 combinations so far
# Trained and Tested combination 102 of 1836, taking 13.05 seconds to get val score of 0.3118:
#                 {'batch_size': 128, 'n_epoch': 8, 'features': 40},
#             Current best combo with val score 0.3125:
#                     {'batch_size': 64, 'n_epoch': 1, 'features': 45}
# Trained and Tested combination 103 of 1836, taking 13.98 seconds to get val score of 0.3119:
#                 {'batch_size': 128, 'n_epoch': 9, 'features': 39},
#             Current best combo with val score 0.3125:
#                     {'batch_size': 64, 'n_epoch': 1, 'features': 45}
# Trained and Tested combination 104 of 1836, taking 15.26 seconds to get val score of 0.3051:
#                 {'batch_size': 128, 'n_epoch': 9, 'features': 41},
#             Current best combo with val score 0.3125:
#                     {'batch_size': 64, 'n_epoch': 1, 'features': 45}
# Already Trained and Tested combination (val score of 0.3118):
#             {'batch_size': 128, 'n_epoch': 8, 'features': 40}
#             Current best combo (with val score 0.3125):
#                     {'batch_size': 64, 'n_epoch': 1, 'features': 45}
#         Has trained 104 of 1836 combinations so far
# Trained and Tested combination 105 of 1836, taking 13.45 seconds to get val score of 0.3118:
#                 {'batch_size': 256, 'n_epoch': 7, 'features': 40},
#             Current best combo with val score 0.3125:
#                     {'batch_size': 64, 'n_epoch': 1, 'features': 45}
# Already Trained and Tested combination (val score of 0.3119):
#             {'batch_size': 256, 'n_epoch': 9, 'features': 40}
#             Current best combo (with val score 0.3125):
#                     {'batch_size': 64, 'n_epoch': 1, 'features': 45}
#         Has trained 105 of 1836 combinations so far
# Trained and Tested combination 106 of 1836, taking 13.13 seconds to get val score of 0.3118:
#                 {'batch_size': 256, 'n_epoch': 8, 'features': 39},
#             Current best combo with val score 0.3125:
#                     {'batch_size': 64, 'n_epoch': 1, 'features': 45}
# Trained and Tested combination 107 of 1836, taking 13.7 seconds to get val score of 0.3072:
#                 {'batch_size': 256, 'n_epoch': 8, 'features': 41},
#             Current best combo with val score 0.3125:
#                     {'batch_size': 64, 'n_epoch': 1, 'features': 45}
# Already Trained and Tested combination (val score of 0.3119):
#             {'batch_size': 128, 'n_epoch': 9, 'features': 39}
#             Current best combo (with val score 0.3125):
#                     {'batch_size': 64, 'n_epoch': 1, 'features': 45}
#         Has trained 107 of 1836 combinations so far
# Already Trained and Tested combination (val score of 0.3118):
#             {'batch_size': 256, 'n_epoch': 8, 'features': 39}
#             Current best combo (with val score 0.3125):
#                     {'batch_size': 64, 'n_epoch': 1, 'features': 45}
#         Has trained 107 of 1836 combinations so far
# Trained and Tested combination 108 of 1836, taking 15.22 seconds to get val score of 0.3118:
#                 {'batch_size': 256, 'n_epoch': 9, 'features': 38},
#             Current best combo with val score 0.3125:
#                     {'batch_size': 64, 'n_epoch': 1, 'features': 45}
# Already Trained and Tested combination (val score of 0.3119):
#             {'batch_size': 256, 'n_epoch': 9, 'features': 40}
#             Current best combo (with val score 0.3125):
#                     {'batch_size': 64, 'n_epoch': 1, 'features': 45}
#         Has trained 108 of 1836 combinations so far
# % Combos Checked Thus Far: 108 out of 1836 which is 5.882353%
# Cruising Coordrdinate 50 of 66
#
# Cruising Coordrdinate 51 of 66
#
# Cruising Coordrdinate 52 of 66
#
# Cruising Coordrdinate 53 of 66
#
# Cruising Coordrdinate 54 of 66
#
# Cruising Coordrdinate 55 of 66
#
# Cruising Coordrdinate 56 of 66
#
# Cruising Coordrdinate 57 of 66
#
# Cruising Coordrdinate 58 of 66
#
# Cruising Coordrdinate 59 of 66
#
# Cruising Coordrdinate 60 of 66
#
# Cruise suspended due to suspicious case
# Guidance: round 2
#
# 	round 2 iteration:  0
#
# Trained and Tested combination 109 of 1836, taking 10.61 seconds to get val score of 0.3129:
#                 {'batch_size': 128, 'n_epoch': 1, 'features': 50},
#             Current best combo with val score 0.3129:
#                     {'batch_size': 128, 'n_epoch': 1, 'features': 50}
# Trained and Tested combination 110 of 1836, taking 10.2 seconds to get val score of 0.3118:
#                 {'batch_size': 256, 'n_epoch': 2, 'features': 50},
#             Current best combo with val score 0.3129:
#                     {'batch_size': 128, 'n_epoch': 1, 'features': 50}
# Trained and Tested combination 111 of 1836, taking 10.07 seconds to get val score of 0.3118:
#                 {'batch_size': 256, 'n_epoch': 1, 'features': 49},
#             Current best combo with val score 0.3129:
#                     {'batch_size': 128, 'n_epoch': 1, 'features': 50}
# 	round 2 iteration:  1
#
# Trained and Tested combination 112 of 1836, taking 10.08 seconds to get val score of 0.3125:
#                 {'batch_size': 64, 'n_epoch': 1, 'features': 50},
#             Current best combo with val score 0.3129:
#                     {'batch_size': 128, 'n_epoch': 1, 'features': 50}
# Already Trained and Tested combination (val score of 0.3119):
#             {'batch_size': 256, 'n_epoch': 1, 'features': 50}
#             Current best combo (with val score 0.3129):
#                     {'batch_size': 128, 'n_epoch': 1, 'features': 50}
#         Has trained 112 of 1836 combinations so far
# Trained and Tested combination 113 of 1836, taking 9.47 seconds to get val score of 0.3118:
#                 {'batch_size': 128, 'n_epoch': 2, 'features': 50},
#             Current best combo with val score 0.3129:
#                     {'batch_size': 128, 'n_epoch': 1, 'features': 50}
# Trained and Tested combination 114 of 1836, taking 9.51 seconds to get val score of 0.3127:
#                 {'batch_size': 128, 'n_epoch': 1, 'features': 49},
#             Current best combo with val score 0.3129:
#                     {'batch_size': 128, 'n_epoch': 1, 'features': 50}
# Already Trained and Tested combination (val score of 0.3118):
#             {'batch_size': 128, 'n_epoch': 2, 'features': 50}
#             Current best combo (with val score 0.3129):
#                     {'batch_size': 128, 'n_epoch': 1, 'features': 50}
#         Has trained 114 of 1836 combinations so far
# Already Trained and Tested combination (val score of 0.3119):
#             {'batch_size': 256, 'n_epoch': 1, 'features': 50}
#             Current best combo (with val score 0.3129):
#                     {'batch_size': 128, 'n_epoch': 1, 'features': 50}
#         Has trained 114 of 1836 combinations so far
# Trained and Tested combination 115 of 1836, taking 7.96 seconds to get val score of 0.3118:
#                 {'batch_size': 256, 'n_epoch': 3, 'features': 50},
#             Current best combo with val score 0.3129:
#                     {'batch_size': 128, 'n_epoch': 1, 'features': 50}
# Trained and Tested combination 116 of 1836, taking 12.94 seconds to get val score of 0.3118:
#                 {'batch_size': 256, 'n_epoch': 2, 'features': 49},
#             Current best combo with val score 0.3129:
#                     {'batch_size': 128, 'n_epoch': 1, 'features': 50}
# Already Trained and Tested combination (val score of 0.3127):
#             {'batch_size': 128, 'n_epoch': 1, 'features': 49}
#             Current best combo (with val score 0.3129):
#                     {'batch_size': 128, 'n_epoch': 1, 'features': 50}
#         Has trained 116 of 1836 combinations so far
# Already Trained and Tested combination (val score of 0.3118):
#             {'batch_size': 256, 'n_epoch': 2, 'features': 49}
#             Current best combo (with val score 0.3129):
#                     {'batch_size': 128, 'n_epoch': 1, 'features': 50}
#         Has trained 116 of 1836 combinations so far
# Trained and Tested combination 117 of 1836, taking 10.37 seconds to get val score of 0.312:
#                 {'batch_size': 256, 'n_epoch': 1, 'features': 48},
#             Current best combo with val score 0.3129:
#                     {'batch_size': 128, 'n_epoch': 1, 'features': 50}
# Already Trained and Tested combination (val score of 0.3119):
#             {'batch_size': 256, 'n_epoch': 1, 'features': 50}
#             Current best combo (with val score 0.3129):
#                     {'batch_size': 128, 'n_epoch': 1, 'features': 50}
#         Has trained 117 of 1836 combinations so far
# Already Trained and Tested combination (val score of 0.3125):
#             {'batch_size': 64, 'n_epoch': 1, 'features': 50}
#             Current best combo (with val score 0.3129):
#                     {'batch_size': 128, 'n_epoch': 1, 'features': 50}
#         Has trained 117 of 1836 combinations so far
# Already Trained and Tested combination (val score of 0.3119):
#             {'batch_size': 256, 'n_epoch': 1, 'features': 50}
#             Current best combo (with val score 0.3129):
#                     {'batch_size': 128, 'n_epoch': 1, 'features': 50}
#         Has trained 117 of 1836 combinations so far
# Already Trained and Tested combination (val score of 0.3118):
#             {'batch_size': 128, 'n_epoch': 2, 'features': 50}
#             Current best combo (with val score 0.3129):
#                     {'batch_size': 128, 'n_epoch': 1, 'features': 50}
#         Has trained 117 of 1836 combinations so far
# Already Trained and Tested combination (val score of 0.3127):
#             {'batch_size': 128, 'n_epoch': 1, 'features': 49}
#             Current best combo (with val score 0.3129):
#                     {'batch_size': 128, 'n_epoch': 1, 'features': 50}
#         Has trained 117 of 1836 combinations so far
# % Combos Checked Thus Far: 117 out of 1836 which is 6.372548999999999%
# Cruising Coordrdinate 61 of 66
#
# Cruising Coordrdinate 62 of 66
#
# Cruising Coordrdinate 63 of 66
#
# Cruising Coordrdinate 64 of 66
#
# Cruise suspended due to suspicious case
# Guidance: round 3
#
# 	round 3 iteration:  0
#
# Already Trained and Tested combination (val score of 0.3125):
#             {'batch_size': 64, 'n_epoch': 1, 'features': 45}
#             Current best combo (with val score 0.3129):
#                     {'batch_size': 128, 'n_epoch': 1, 'features': 50}
#         Has trained 117 of 1836 combinations so far
# Already Trained and Tested combination (val score of 0.3118):
#             {'batch_size': 32, 'n_epoch': 2, 'features': 45}
#             Current best combo (with val score 0.3129):
#                     {'batch_size': 128, 'n_epoch': 1, 'features': 50}
#         Has trained 117 of 1836 combinations so far
# Already Trained and Tested combination (val score of 0.3119):
#             {'batch_size': 32, 'n_epoch': 1, 'features': 44}
#             Current best combo (with val score 0.3129):
#                     {'batch_size': 128, 'n_epoch': 1, 'features': 50}
#         Has trained 117 of 1836 combinations so far
# Already Trained and Tested combination (val score of 0.312):
#             {'batch_size': 32, 'n_epoch': 1, 'features': 46}
#             Current best combo (with val score 0.3129):
#                     {'batch_size': 128, 'n_epoch': 1, 'features': 50}
#         Has trained 117 of 1836 combinations so far
# 	round 3 iteration:  1
#
# Already Trained and Tested combination (val score of 0.3124):
#             {'batch_size': 32, 'n_epoch': 1, 'features': 45}
#             Current best combo (with val score 0.3129):
#                     {'batch_size': 128, 'n_epoch': 1, 'features': 50}
#         Has trained 117 of 1836 combinations so far
# Already Trained and Tested combination (val score of 0.3116):
#             {'batch_size': 128, 'n_epoch': 1, 'features': 45}
#             Current best combo (with val score 0.3129):
#                     {'batch_size': 128, 'n_epoch': 1, 'features': 50}
#         Has trained 117 of 1836 combinations so far
# Already Trained and Tested combination (val score of 0.3118):
#             {'batch_size': 64, 'n_epoch': 2, 'features': 45}
#             Current best combo (with val score 0.3129):
#                     {'batch_size': 128, 'n_epoch': 1, 'features': 50}
#         Has trained 117 of 1836 combinations so far
# Already Trained and Tested combination (val score of 0.3119):
#             {'batch_size': 64, 'n_epoch': 1, 'features': 44}
#             Current best combo (with val score 0.3129):
#                     {'batch_size': 128, 'n_epoch': 1, 'features': 50}
#         Has trained 117 of 1836 combinations so far
# Already Trained and Tested combination (val score of 0.3123):
#             {'batch_size': 64, 'n_epoch': 1, 'features': 46}
#             Current best combo (with val score 0.3129):
#                     {'batch_size': 128, 'n_epoch': 1, 'features': 50}
#         Has trained 117 of 1836 combinations so far
# Already Trained and Tested combination (val score of 0.3118):
#             {'batch_size': 64, 'n_epoch': 2, 'features': 45}
#             Current best combo (with val score 0.3129):
#                     {'batch_size': 128, 'n_epoch': 1, 'features': 50}
#         Has trained 117 of 1836 combinations so far
# Already Trained and Tested combination (val score of 0.3124):
#             {'batch_size': 32, 'n_epoch': 1, 'features': 45}
#             Current best combo (with val score 0.3129):
#                     {'batch_size': 128, 'n_epoch': 1, 'features': 50}
#         Has trained 117 of 1836 combinations so far
# Trained and Tested combination 118 of 1836, taking 11.0 seconds to get val score of 0.3118:
#                 {'batch_size': 32, 'n_epoch': 3, 'features': 45},
#             Current best combo with val score 0.3129:
#                     {'batch_size': 128, 'n_epoch': 1, 'features': 50}
# Trained and Tested combination 119 of 1836, taking 10.78 seconds to get val score of 0.3118:
#                 {'batch_size': 32, 'n_epoch': 2, 'features': 44},
#             Current best combo with val score 0.3129:
#                     {'batch_size': 128, 'n_epoch': 1, 'features': 50}
# Trained and Tested combination 120 of 1836, taking 12.28 seconds to get val score of 0.3118:
#                 {'batch_size': 32, 'n_epoch': 2, 'features': 46},
#             Current best combo with val score 0.3129:
#                     {'batch_size': 128, 'n_epoch': 1, 'features': 50}
# Already Trained and Tested combination (val score of 0.3119):
#             {'batch_size': 64, 'n_epoch': 1, 'features': 44}
#             Current best combo (with val score 0.3129):
#                     {'batch_size': 128, 'n_epoch': 1, 'features': 50}
#         Has trained 120 of 1836 combinations so far
# Already Trained and Tested combination (val score of 0.3118):
#             {'batch_size': 32, 'n_epoch': 2, 'features': 44}
#             Current best combo (with val score 0.3129):
#                     {'batch_size': 128, 'n_epoch': 1, 'features': 50}
#         Has trained 120 of 1836 combinations so far
# Trained and Tested combination 121 of 1836, taking 11.03 seconds to get val score of 0.3119:
#                 {'batch_size': 32, 'n_epoch': 1, 'features': 43},
#             Current best combo with val score 0.3129:
#                     {'batch_size': 128, 'n_epoch': 1, 'features': 50}
# Already Trained and Tested combination (val score of 0.3124):
#             {'batch_size': 32, 'n_epoch': 1, 'features': 45}
#             Current best combo (with val score 0.3129):
#                     {'batch_size': 128, 'n_epoch': 1, 'features': 50}
#         Has trained 121 of 1836 combinations so far
# Already Trained and Tested combination (val score of 0.3123):
#             {'batch_size': 64, 'n_epoch': 1, 'features': 46}
#             Current best combo (with val score 0.3129):
#                     {'batch_size': 128, 'n_epoch': 1, 'features': 50}
#         Has trained 121 of 1836 combinations so far
# Already Trained and Tested combination (val score of 0.3118):
#             {'batch_size': 32, 'n_epoch': 2, 'features': 46}
#             Current best combo (with val score 0.3129):
#                     {'batch_size': 128, 'n_epoch': 1, 'features': 50}
#         Has trained 121 of 1836 combinations so far
# Already Trained and Tested combination (val score of 0.3124):
#             {'batch_size': 32, 'n_epoch': 1, 'features': 45}
#             Current best combo (with val score 0.3129):
#                     {'batch_size': 128, 'n_epoch': 1, 'features': 50}
#         Has trained 121 of 1836 combinations so far
# Trained and Tested combination 122 of 1836, taking 8.53 seconds to get val score of 0.3122:
#                 {'batch_size': 32, 'n_epoch': 1, 'features': 47},
#             Current best combo with val score 0.3129:
#                     {'batch_size': 128, 'n_epoch': 1, 'features': 50}
# % Combos Checked Thus Far: 122 out of 1836 which is 6.644880000000001%
# Cruising Coordrdinate 65 of 66
#
# Cruising Coordrdinate 66 of 66
#
# Cruise suspended due to suspicious case
# Guidance: round 4
#
# 	round 4 iteration:  0
#
# Already Trained and Tested combination (val score of 0.3125):
#             {'batch_size': 64, 'n_epoch': 1, 'features': 50}
#             Current best combo (with val score 0.3129):
#                     {'batch_size': 128, 'n_epoch': 1, 'features': 50}
#         Has trained 122 of 1836 combinations so far
# Trained and Tested combination 123 of 1836, taking 8.97 seconds to get val score of 0.3118:
#                 {'batch_size': 32, 'n_epoch': 2, 'features': 50},
#             Current best combo with val score 0.3129:
#                     {'batch_size': 128, 'n_epoch': 1, 'features': 50}
# Trained and Tested combination 124 of 1836, taking 11.53 seconds to get val score of 0.312:
#                 {'batch_size': 32, 'n_epoch': 1, 'features': 49},
#             Current best combo with val score 0.3129:
#                     {'batch_size': 128, 'n_epoch': 1, 'features': 50}
# 	round 4 iteration:  1
#
# Trained and Tested combination 125 of 1836, taking 9.44 seconds to get val score of 0.3118:
#                 {'batch_size': 64, 'n_epoch': 2, 'features': 50},
#             Current best combo with val score 0.3129:
#                     {'batch_size': 128, 'n_epoch': 1, 'features': 50}
# Already Trained and Tested combination (val score of 0.3122):
#             {'batch_size': 32, 'n_epoch': 1, 'features': 50}
#             Current best combo (with val score 0.3129):
#                     {'batch_size': 128, 'n_epoch': 1, 'features': 50}
#         Has trained 125 of 1836 combinations so far
# Trained and Tested combination 126 of 1836, taking 13.39 seconds to get val score of 0.3118:
#                 {'batch_size': 32, 'n_epoch': 3, 'features': 50},
#             Current best combo with val score 0.3129:
#                     {'batch_size': 128, 'n_epoch': 1, 'features': 50}
# Trained and Tested combination 127 of 1836, taking 13.18 seconds to get val score of 0.3118:
#                 {'batch_size': 32, 'n_epoch': 2, 'features': 49},
#             Current best combo with val score 0.3129:
#                     {'batch_size': 128, 'n_epoch': 1, 'features': 50}
# Trained and Tested combination 128 of 1836, taking 10.31 seconds to get val score of 0.3123:
#                 {'batch_size': 64, 'n_epoch': 1, 'features': 49},
#             Current best combo with val score 0.3129:
#                     {'batch_size': 128, 'n_epoch': 1, 'features': 50}
# Already Trained and Tested combination (val score of 0.3118):
#             {'batch_size': 32, 'n_epoch': 2, 'features': 49}
#             Current best combo (with val score 0.3129):
#                     {'batch_size': 128, 'n_epoch': 1, 'features': 50}
#         Has trained 128 of 1836 combinations so far
# Trained and Tested combination 129 of 1836, taking 7.71 seconds to get val score of 0.3117:
#                 {'batch_size': 32, 'n_epoch': 1, 'features': 48},
#             Current best combo with val score 0.3129:
#                     {'batch_size': 128, 'n_epoch': 1, 'features': 50}
# Already Trained and Tested combination (val score of 0.3122):
#             {'batch_size': 32, 'n_epoch': 1, 'features': 50}
#             Current best combo (with val score 0.3129):
#                     {'batch_size': 128, 'n_epoch': 1, 'features': 50}
#         Has trained 129 of 1836 combinations so far
# % Combos Checked Thus Far: 129 out of 1836 which is 7.0261439999999995%
# FINAL STAGE: Begin final Guidance system
#
#
# Guidance: round FINAL
#
# 	round FINAL iteration:  0
#
# % Combos Checked Thus Far: 129 out of 1836 which is 7.0261439999999995%
# Max Val Score:
#  0.312857
# Max Val Score Std:
#  0.003799
# Best Combo Train Score:
#  0.966751
# Best Combo Train Score Std:
#  0.002046
# Max Combo Index:
#  (2, 0, 50) out of [4, 9, 51] (note best combo is 0-indexed)
# Max Combo Hyperparamer Combination:
#  {'batch_size': 128, 'n_epoch': 1, 'features': 50}
# Max Combo Features:
#  ('marital_status_DIVORCED', 'marital_status_MARRIED', 'marital_status_SINGLE', 'marital_status_WIDOWED', 'marital_status_0', 'procedure_224276', 'lods_score', 'procedure_227712', 'procedure_224274', 'procedure_224267', 'procedure_229519', 'admission_type_DIRECT EMER.', 'admission_type_DIRECT OBSERVATION', 'admission_type_ELECTIVE', 'admission_type_EU OBSERVATION', 'admission_type_OBSERVATION ADMIT', 'admission_type_SURGICAL SAME DAY ADMISSION', 'admission_type_URGENT', 'admission_type_EW EMER.', 'gender_M', 'gender_F', 'oasis_score', 'procedure_224275', 'race_AMERICAN INDIAN/ALASKA NATIVE', 'race_ASIAN - ASIAN INDIAN', 'race_ASIAN - CHINESE', 'race_ASIAN - KOREAN', 'race_ASIAN - SOUTH EAST ASIAN', 'race_BLACK/AFRICAN', 'race_BLACK/AFRICAN AMERICAN', 'race_BLACK/CAPE VERDEAN', 'race_BLACK/CARIBBEAN ISLAND', 'race_HISPANIC OR LATINO', 'race_HISPANIC/LATINO - CENTRAL AMERICAN', 'race_HISPANIC/LATINO - COLUMBIAN', 'race_HISPANIC/LATINO - CUBAN', 'race_HISPANIC/LATINO - DOMINICAN', 'race_HISPANIC/LATINO - GUATEMALAN', 'race_HISPANIC/LATINO - HONDURAN', 'race_HISPANIC/LATINO - MEXICAN', 'race_HISPANIC/LATINO - PUERTO RICAN', 'race_HISPANIC/LATINO - SALVADORAN', 'race_MULTIPLE RACE/ETHNICITY', 'race_NATIVE HAWAIIAN OR OTHER PACIFIC ISLANDER', 'race_OTHER', 'race_PATIENT DECLINED TO ANSWER', 'race_PORTUGUESE', 'race_SOUTH AMERICAN', 'race_UNABLE TO OBTAIN', 'race_UNKNOWN', 'race_WHITE', 'race_WHITE - BRAZILIAN', 'race_WHITE - EASTERN EUROPEAN', 'race_WHITE - OTHER EUROPEAN', 'race_WHITE - RUSSIAN', 'race_ASIAN', 'hospital_stay_duration', 'insurance_Medicaid', 'insurance_Medicare', 'insurance_Other', 'procedure_226124', 'unique_drugs', 'ventilation_used', 'item_51301', 'procedure_226236', 'procedure_227194', 'spo2', 'procedure_225400', 'anchor_age', 'procedure_229351', 'glucose', 'procedure_225792', 'icu_stay_duration', 'procedure_225446', 'creatinine', 'procedure_224270', 'pt', 'procedure_221223', 'resp_rate', 'procedure_224385', 'item_51222', 'urine_output_total', 'mean_arterial_pressure', 'heart_rate', 'potassium', 'procedure_224263', 'item_51265', 'bun', 'systolic_bp', 'procedure_225752', 'procedure_225430', 'procedure_225464', 'procedure_225802', 'procedure_226475', 'procedure_229298', 'procedure_229380', 'procedure_229580')
# % Combos Checked: 129 out of 1836 which is 7.0261439999999995%
