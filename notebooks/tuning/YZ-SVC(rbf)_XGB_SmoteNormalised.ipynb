# %% [markdown]
# # Tuning Script

# %%
# Parameters subject to change in every script - involved in naming

MODEL = 'svc(rbf)'
PREPROCESSING = 'smote_normalise'
TUNER = 'yangzhoub'
OPTIMISED_METRIC = 'f1'

# %% [markdown]
# ---

# %%
# detect whether this is a google environment

COLAB_ENVIRONMENT = False

try:
    from google.colab import drive
    drive.mount('/content/drive')
    COLAB_ENVIRONMENT = True
except:
    pass
# Out:
# Mounted at /content/drive

# %%
import sys
import os
import pickle

if COLAB_ENVIRONMENT:
    home_directory = './drive/MyDrive/LAB/COMP90089__GroupWork__Py/' # my home directory is stored in ./LAB of google drive
    if MODEL == 'ebr':
        # !pip install interpret==0.5.0
    elif MODEL == 'cbr':
        # !pip install catboost
    elif MODEL in ['tf', 'mlp']:
        # !pip install PyTorch2Sklearn
    # !pip install JXAutoML
else:
    home_directory = '../../'

from JXAutoML.YangZhouB_10CV import YangZhouB_10CV as Tuner

import pandas as pd
# Out:
# Collecting JXAutoML
#   Downloading JXAutoML-0.4.4-py3-none-any.whl.metadata (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.2/67.2 kB 1.6 MB/s eta 0:00:00
# Downloading JXAutoML-0.4.4-py3-none-any.whl (52 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.1/52.1 kB 4.0 MB/s eta 0:00:00
# Installing collected packages: JXAutoML
# Successfully installed JXAutoML-0.4.4

# %%
# Parameters that are same for every script

FOLDS = 10  # we have decided to do 10 fold validation

SEED = 42

TASK_TYPE = 'Classification'  # this task is a classification task

# we have decided to tune features as hp
TUNE_FEATURES_AS_HYPERPARAMETERS = True

# %% [markdown]
# ---

# %%
# model to use to tune
from sklearn.svm import SVC as clf

# what values to try for each hyperparameter
parameter_choices = {
    'C': (0.0001, 0.001, 0.01, 0.1, 1, 10),
    'tol': (0.0001, 0.001, 0.01, 0.1, 1, 10),
    'max_iter': (50, 100, 200, 400, 800, 1600),
    'gamma': ('scale', 'auto')
}

# what values to set non-tuneable parameters/hyperparameters
non_tunable_hyperparameters_dict = {
                                    'verbose': False,
                                    'decision_function_shape': 'ovr',
                                    'random_state': 42,
                                    'kernel': 'rbf'
                                    }

# %% [markdown]
# ---

# %% [markdown]
# Read in and Prepare Data

# %%
# Import data and store as lists

train_x_list = []
train_y_list = []
val_x_list = []
val_y_list = []

for i in range(FOLDS):
    train_data = pd.read_csv(
        f'{home_directory}data/curated/modelling/{PREPROCESSING}/train_{i}.csv')
    val_data = pd.read_csv(
        f'{home_directory}data/curated/modelling/{PREPROCESSING}/val_{i}.csv')

    # get the correct rows for X and y
    train_x = train_data.drop(
        ['mortality_status', 'subject_id', 'hadm_id', 'stay_id'], axis=1)
    train_y = train_data['mortality_status']
    val_x = val_data.drop(
        ['mortality_status', 'subject_id', 'hadm_id', 'stay_id'], axis=1)
    val_y = val_data['mortality_status']

    train_x_list.append(train_x)
    train_y_list.append(train_y)
    val_x_list.append(val_x)
    val_y_list.append(val_y)

# %%
# Import feature importance ordering

with open(f'{home_directory}models/xgb_feature_importance_ordering_{PREPROCESSING}.pickle', 'rb') as f:
    feature_importance_ordering = pickle.load(f)

# %% [markdown]
# Set parameters

# %%
# initialisation
tuner = Tuner()

print('---')

# define what model we are tuning
tuner.read_in_model(clf, TASK_TYPE, optimised_metric=OPTIMISED_METRIC)

print('---')

# read in the data for training and validation
tuner.read_in_data(train_x_list, train_y_list, val_x_list, val_y_list)

print('---')

# set what hp values to tune
tuner.set_hyperparameters(parameter_choices)
# WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

# set up hp values that need to be changed from default but NOT to be tuned
tuner.set_non_tuneable_hyperparameters(non_tunable_hyperparameters_dict)

print('---')

# set up feature importance ordering

if TUNE_FEATURES_AS_HYPERPARAMETERS:
    tuner.set_features(feature_importance_ordering)
    # WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

try:  # try to read in previous results to continue tuning ...
    tuner.read_in_tuning_result_df(
        f'{home_directory}models/tuning/{TUNER}_{MODEL}_{PREPROCESSING}.csv')
except:
    print('No previous tuning data read in')

print('---')

# set up where to save the tuning result csv
tuner.set_tuning_result_saving_address(
    f'{home_directory}models/tuning/{TUNER}_{MODEL}_{PREPROCESSING}.csv')

print('---')

# set up where to save the current best model
tuner.set_best_model_saving_address(
    f'{home_directory}models/tmp_models/{TUNER}_{MODEL}_{PREPROCESSING}')
# Out:
# YangZhouB Initialised
# ---
# Successfully read in model <class 'sklearn.svm._classes.SVC'>, which is a Classification model optimising for f1
# ---
# Read in Train X data list
# Read in Train y data list
# Read in Val X data list
# Read in Val y data list
# ---
# Successfully recorded hyperparameter choices
# ---
# Successfully recorded non_tuneable_hyperparameter choices
# ---
# Successfully recorded tuneable feature combination choices and updated relevant internal structures
# ---
# No previous tuning data read in
# ---
# Successfully set tuning output address
# ---
# Successfully set best model output address

# %%
# ignore warnings

import warnings
warnings.filterwarnings("ignore")

# %%
# begin tuning ... (or continue training)

tuner.tune()
# Out:
# BEGIN TUNING
#
#
# STAGE ZERO: Tune all Cruise combinations
#
#
# Trained and Tested combination 1 of 31104, taking 0.01 seconds to get val score of 0.3086:
#                 {'C': 0.0001, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 40},
#             Current best combo with val score 0.3086:
#                     {'C': 0.0001, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 40}
# Trained and Tested combination 2 of 31104, taking 0.01 seconds to get val score of 0.3086:
#                 {'C': 10, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 0},
#             Current best combo with val score 0.3086:
#                     {'C': 0.0001, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 40}
# Trained and Tested combination 3 of 31104, taking 0.02 seconds to get val score of 0.3086:
#                 {'C': 10, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 45},
#             Current best combo with val score 0.3086:
#                     {'C': 0.0001, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 40}
# Trained and Tested combination 4 of 31104, taking 0.01 seconds to get val score of 0.3086:
#                 {'C': 0.0001, 'tol': 10, 'max_iter': 1600, 'gamma': 'scale', 'features': 35},
#             Current best combo with val score 0.3086:
#                     {'C': 0.0001, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 40}
# Trained and Tested combination 5 of 31104, taking 0.01 seconds to get val score of 0.3086:
#                 {'C': 10, 'tol': 10, 'max_iter': 50, 'gamma': 'scale', 'features': 5},
#             Current best combo with val score 0.3086:
#                     {'C': 0.0001, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 40}
# Trained and Tested combination 6 of 31104, taking 0.05 seconds to get val score of 0.0:
#                 {'C': 10, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 35},
#             Current best combo with val score 0.3086:
#                     {'C': 0.0001, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 40}
# Trained and Tested combination 7 of 31104, taking 0.98 seconds to get val score of 0.4027:
#                 {'C': 0.0001, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 20},
#             Current best combo with val score 0.4027:
#                     {'C': 0.0001, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 20}
# Trained and Tested combination 8 of 31104, taking 0.01 seconds to get val score of 0.3086:
#                 {'C': 10, 'tol': 10, 'max_iter': 1600, 'gamma': 'scale', 'features': 5},
#             Current best combo with val score 0.4027:
#                     {'C': 0.0001, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 20}
# Trained and Tested combination 9 of 31104, taking 0.01 seconds to get val score of 0.3086:
#                 {'C': 10, 'tol': 10, 'max_iter': 1600, 'gamma': 'scale', 'features': 10},
#             Current best combo with val score 0.4027:
#                     {'C': 0.0001, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 20}
# Trained and Tested combination 10 of 31104, taking 0.05 seconds to get val score of 0.0:
#                 {'C': 10, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 63},
#             Current best combo with val score 0.4027:
#                     {'C': 0.0001, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 20}
# Trained and Tested combination 11 of 31104, taking 0.01 seconds to get val score of 0.3086:
#                 {'C': 0.0001, 'tol': 10, 'max_iter': 50, 'gamma': 'auto', 'features': 67},
#             Current best combo with val score 0.4027:
#                     {'C': 0.0001, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 20}
# Trained and Tested combination 12 of 31104, taking 0.5 seconds to get val score of 0.0:
#                 {'C': 10, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 45},
#             Current best combo with val score 0.4027:
#                     {'C': 0.0001, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 20}
# Trained and Tested combination 13 of 31104, taking 0.0 seconds to get val score of 0.3086:
#                 {'C': 10, 'tol': 10, 'max_iter': 50, 'gamma': 'auto', 'features': 5},
#             Current best combo with val score 0.4027:
#                     {'C': 0.0001, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 20}
# Trained and Tested combination 14 of 31104, taking 0.01 seconds to get val score of 0.3086:
#                 {'C': 0.0001, 'tol': 10, 'max_iter': 50, 'gamma': 'scale', 'features': 59},
#             Current best combo with val score 0.4027:
#                     {'C': 0.0001, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 20}
# Trained and Tested combination 15 of 31104, taking 0.01 seconds to get val score of 0.3086:
#                 {'C': 10, 'tol': 10, 'max_iter': 50, 'gamma': 'scale', 'features': 30},
#             Current best combo with val score 0.4027:
#                     {'C': 0.0001, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 20}
# Trained and Tested combination 16 of 31104, taking 0.01 seconds to get val score of 0.3086:
#                 {'C': 0.0001, 'tol': 10, 'max_iter': 50, 'gamma': 'scale', 'features': 50},
#             Current best combo with val score 0.4027:
#                     {'C': 0.0001, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 20}
# Trained and Tested combination 17 of 31104, taking 1.35 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 59},
#             Current best combo with val score 0.4027:
#                     {'C': 0.0001, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 20}
# Trained and Tested combination 18 of 31104, taking 0.01 seconds to get val score of 0.3086:
#                 {'C': 10, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 40},
#             Current best combo with val score 0.4027:
#                     {'C': 0.0001, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 20}
# Trained and Tested combination 19 of 31104, taking 0.01 seconds to get val score of 0.3086:
#                 {'C': 10, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 59},
#             Current best combo with val score 0.4027:
#                     {'C': 0.0001, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 20}
# Trained and Tested combination 20 of 31104, taking 0.03 seconds to get val score of 0.1621:
#                 {'C': 10, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 10},
#             Current best combo with val score 0.4027:
#                     {'C': 0.0001, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 20}
# Trained and Tested combination 21 of 31104, taking 0.01 seconds to get val score of 0.3086:
#                 {'C': 10, 'tol': 10, 'max_iter': 1600, 'gamma': 'scale', 'features': 71},
#             Current best combo with val score 0.4027:
#                     {'C': 0.0001, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 20}
# Trained and Tested combination 22 of 31104, taking 0.01 seconds to get val score of 0.3086:
#                 {'C': 0.0001, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 55},
#             Current best combo with val score 0.4027:
#                     {'C': 0.0001, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 20}
# Trained and Tested combination 23 of 31104, taking 1.01 seconds to get val score of 0.4884:
#                 {'C': 0.0001, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10},
#             Current best combo with val score 0.4884:
#                     {'C': 0.0001, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
# Trained and Tested combination 24 of 31104, taking 0.01 seconds to get val score of 0.3086:
#                 {'C': 10, 'tol': 10, 'max_iter': 1600, 'gamma': 'scale', 'features': 35},
#             Current best combo with val score 0.4884:
#                     {'C': 0.0001, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
# Trained and Tested combination 25 of 31104, taking 0.01 seconds to get val score of 0.3086:
#                 {'C': 10, 'tol': 10, 'max_iter': 1600, 'gamma': 'scale', 'features': 55},
#             Current best combo with val score 0.4884:
#                     {'C': 0.0001, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
# Trained and Tested combination 26 of 31104, taking 1.26 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 45},
#             Current best combo with val score 0.4884:
#                     {'C': 0.0001, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
# Trained and Tested combination 27 of 31104, taking 0.01 seconds to get val score of 0.3086:
#                 {'C': 0.0001, 'tol': 10, 'max_iter': 1600, 'gamma': 'scale', 'features': 10},
#             Current best combo with val score 0.4884:
#                     {'C': 0.0001, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
# Trained and Tested combination 28 of 31104, taking 1.82 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 71},
#             Current best combo with val score 0.4884:
#                     {'C': 0.0001, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
# Trained and Tested combination 29 of 31104, taking 1.73 seconds to get val score of 0.3095:
#                 {'C': 0.0001, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 15},
#             Current best combo with val score 0.4884:
#                     {'C': 0.0001, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
# Trained and Tested combination 30 of 31104, taking 0.01 seconds to get val score of 0.3086:
#                 {'C': 0.0001, 'tol': 10, 'max_iter': 50, 'gamma': 'auto', 'features': 63},
#             Current best combo with val score 0.4884:
#                     {'C': 0.0001, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
# Trained and Tested combination 31 of 31104, taking 1.25 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 55},
#             Current best combo with val score 0.4884:
#                     {'C': 0.0001, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
# Trained and Tested combination 32 of 31104, taking 0.01 seconds to get val score of 0.3086:
#                 {'C': 10, 'tol': 10, 'max_iter': 50, 'gamma': 'auto', 'features': 10},
#             Current best combo with val score 0.4884:
#                     {'C': 0.0001, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
# Trained and Tested combination 33 of 31104, taking 0.05 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 67},
#             Current best combo with val score 0.4884:
#                     {'C': 0.0001, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
# Trained and Tested combination 34 of 31104, taking 0.04 seconds to get val score of 0.0:
#                 {'C': 10, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 50},
#             Current best combo with val score 0.4884:
#                     {'C': 0.0001, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
# Trained and Tested combination 35 of 31104, taking 0.01 seconds to get val score of 0.3086:
#                 {'C': 0.0001, 'tol': 10, 'max_iter': 50, 'gamma': 'scale', 'features': 63},
#             Current best combo with val score 0.4884:
#                     {'C': 0.0001, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
# Trained and Tested combination 36 of 31104, taking 0.05 seconds to get val score of 0.0:
#                 {'C': 10, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 59},
#             Current best combo with val score 0.4884:
#                     {'C': 0.0001, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
# Trained and Tested combination 37 of 31104, taking 1.03 seconds to get val score of 0.3319:
#                 {'C': 0.0001, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 10},
#             Current best combo with val score 0.4884:
#                     {'C': 0.0001, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
# Trained and Tested combination 38 of 31104, taking 0.02 seconds to get val score of 0.2535:
#                 {'C': 0.0001, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 0},
#             Current best combo with val score 0.4884:
#                     {'C': 0.0001, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
# Trained and Tested combination 39 of 31104, taking 0.01 seconds to get val score of 0.3086:
#                 {'C': 0.0001, 'tol': 10, 'max_iter': 1600, 'gamma': 'scale', 'features': 59},
#             Current best combo with val score 0.4884:
#                     {'C': 0.0001, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
# Trained and Tested combination 40 of 31104, taking 0.07 seconds to get val score of 0.0:
#                 {'C': 10, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 45},
#             Current best combo with val score 0.4884:
#                     {'C': 0.0001, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
# Trained and Tested combination 41 of 31104, taking 0.06 seconds to get val score of 0.0:
#                 {'C': 10, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 71},
#             Current best combo with val score 0.4884:
#                     {'C': 0.0001, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
# Trained and Tested combination 42 of 31104, taking 0.04 seconds to get val score of 0.0:
#                 {'C': 10, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 55},
#             Current best combo with val score 0.4884:
#                     {'C': 0.0001, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
# Trained and Tested combination 43 of 31104, taking 0.01 seconds to get val score of 0.3086:
#                 {'C': 10, 'tol': 10, 'max_iter': 50, 'gamma': 'auto', 'features': 50},
#             Current best combo with val score 0.4884:
#                     {'C': 0.0001, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
# Trained and Tested combination 44 of 31104, taking 0.01 seconds to get val score of 0.3086:
#                 {'C': 10, 'tol': 10, 'max_iter': 50, 'gamma': 'auto', 'features': 35},
#             Current best combo with val score 0.4884:
#                     {'C': 0.0001, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
# Trained and Tested combination 45 of 31104, taking 0.01 seconds to get val score of 0.3086:
#                 {'C': 10, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 50},
#             Current best combo with val score 0.4884:
#                     {'C': 0.0001, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
# Trained and Tested combination 46 of 31104, taking 0.01 seconds to get val score of 0.3086:
#                 {'C': 10, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 30},
#             Current best combo with val score 0.4884:
#                     {'C': 0.0001, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
# Trained and Tested combination 47 of 31104, taking 0.04 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 55},
#             Current best combo with val score 0.4884:
#                     {'C': 0.0001, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
# Trained and Tested combination 48 of 31104, taking 1.15 seconds to get val score of 0.493:
#                 {'C': 0.0001, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 15},
#             Current best combo with val score 0.493:
#                     {'C': 0.0001, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 15}
# Trained and Tested combination 49 of 31104, taking 0.01 seconds to get val score of 0.3086:
#                 {'C': 10, 'tol': 10, 'max_iter': 50, 'gamma': 'auto', 'features': 71},
#             Current best combo with val score 0.493:
#                     {'C': 0.0001, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 15}
# Trained and Tested combination 50 of 31104, taking 1.2 seconds to get val score of 0.1329:
#                 {'C': 0.0001, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 5},
#             Current best combo with val score 0.493:
#                     {'C': 0.0001, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 15}
# Trained and Tested combination 51 of 31104, taking 0.01 seconds to get val score of 0.3086:
#                 {'C': 10, 'tol': 10, 'max_iter': 50, 'gamma': 'scale', 'features': 40},
#             Current best combo with val score 0.493:
#                     {'C': 0.0001, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 15}
# Trained and Tested combination 52 of 31104, taking 0.0 seconds to get val score of 0.3086:
#                 {'C': 10, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 5},
#             Current best combo with val score 0.493:
#                     {'C': 0.0001, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 15}
# Trained and Tested combination 53 of 31104, taking 0.48 seconds to get val score of 0.0:
#                 {'C': 10, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 50},
#             Current best combo with val score 0.493:
#                     {'C': 0.0001, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 15}
# Trained and Tested combination 54 of 31104, taking 0.01 seconds to get val score of 0.3086:
#                 {'C': 0.0001, 'tol': 10, 'max_iter': 50, 'gamma': 'scale', 'features': 25},
#             Current best combo with val score 0.493:
#                     {'C': 0.0001, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 15}
# Trained and Tested combination 55 of 31104, taking 0.03 seconds to get val score of 0.1795:
#                 {'C': 0.0001, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 5},
#             Current best combo with val score 0.493:
#                     {'C': 0.0001, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 15}
# Trained and Tested combination 56 of 31104, taking 0.04 seconds to get val score of 0.0:
#                 {'C': 10, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 67},
#             Current best combo with val score 0.493:
#                     {'C': 0.0001, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 15}
# Trained and Tested combination
 'tol': 0.0001, 'max_iter': 800, 'gamma': 'scale', 'features': 15}
#             Current best combo (with val score 0.529):
#                     {'C': 10, 'tol': 0.0001, 'max_iter': 800, 'gamma': 'scale', 'features': 16}
#         Has trained 606 of 31104 combinations so far
# Trained and Tested combination 607 of 31104, taking 0.49 seconds to get val score of 0.4393:
#                 {'C': 0.0001, 'tol': 0.0001, 'max_iter': 800, 'gamma': 'auto', 'features': 14},
#             Current best combo with val score 0.529:
#                     {'C': 10, 'tol': 0.0001, 'max_iter': 800, 'gamma': 'scale', 'features': 16}
# Trained and Tested combination 608 of 31104, taking 0.51 seconds to get val score of 0.3142:
#                 {'C': 0.0001, 'tol': 0.0001, 'max_iter': 800, 'gamma': 'auto', 'features': 16},
#             Current best combo with val score 0.529:
#                     {'C': 10, 'tol': 0.0001, 'max_iter': 800, 'gamma': 'scale', 'features': 16}
# Already Trained and Tested combination (val score of 0.5053):
#             {'C': 0.001, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 15}
#             Current best combo (with val score 0.529):
#                     {'C': 10, 'tol': 0.0001, 'max_iter': 800, 'gamma': 'scale', 'features': 16}
#         Has trained 608 of 31104 combinations so far
# Already Trained and Tested combination (val score of 0.493):
#             {'C': 0.0001, 'tol': 0.001, 'max_iter': 1600, 'gamma': 'scale', 'features': 15}
#             Current best combo (with val score 0.529):
#                     {'C': 10, 'tol': 0.0001, 'max_iter': 800, 'gamma': 'scale', 'features': 16}
#         Has trained 608 of 31104 combinations so far
# Already Trained and Tested combination (val score of 0.4747):
#             {'C': 0.0001, 'tol': 0.0001, 'max_iter': 800, 'gamma': 'scale', 'features': 15}
#             Current best combo (with val score 0.529):
#                     {'C': 10, 'tol': 0.0001, 'max_iter': 800, 'gamma': 'scale', 'features': 16}
#         Has trained 608 of 31104 combinations so far
# Already Trained and Tested combination (val score of 0.3095):
#             {'C': 0.0001, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 15}
#             Current best combo (with val score 0.529):
#                     {'C': 10, 'tol': 0.0001, 'max_iter': 800, 'gamma': 'scale', 'features': 16}
#         Has trained 608 of 31104 combinations so far
# Already Trained and Tested combination (val score of 0.4993):
#             {'C': 0.0001, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 14}
#             Current best combo (with val score 0.529):
#                     {'C': 10, 'tol': 0.0001, 'max_iter': 800, 'gamma': 'scale', 'features': 16}
#         Has trained 608 of 31104 combinations so far
# Already Trained and Tested combination (val score of 0.4235):
#             {'C': 0.0001, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16}
#             Current best combo (with val score 0.529):
#                     {'C': 10, 'tol': 0.0001, 'max_iter': 800, 'gamma': 'scale', 'features': 16}
#         Has trained 608 of 31104 combinations so far
# Already Trained and Tested combination (val score of 0.3205):
#             {'C': 0.001, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 14}
#             Current best combo (with val score 0.529):
#                     {'C': 10, 'tol': 0.0001, 'max_iter': 800, 'gamma': 'scale', 'features': 16}
#         Has trained 608 of 31104 combinations so far
# Already Trained and Tested combination (val score of 0.3256):
#             {'C': 0.0001, 'tol': 0.001, 'max_iter': 1600, 'gamma': 'auto', 'features': 14}
#             Current best combo (with val score 0.529):
#                     {'C': 10, 'tol': 0.0001, 'max_iter': 800, 'gamma': 'scale', 'features': 16}
#         Has trained 608 of 31104 combinations so far
# Already Trained and Tested combination (val score of 0.4393):
#             {'C': 0.0001, 'tol': 0.0001, 'max_iter': 800, 'gamma': 'auto', 'features': 14}
#             Current best combo (with val score 0.529):
#                     {'C': 10, 'tol': 0.0001, 'max_iter': 800, 'gamma': 'scale', 'features': 16}
#         Has trained 608 of 31104 combinations so far
# Already Trained and Tested combination (val score of 0.4993):
#             {'C': 0.0001, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 14}
#             Current best combo (with val score 0.529):
#                     {'C': 10, 'tol': 0.0001, 'max_iter': 800, 'gamma': 'scale', 'features': 16}
#         Has trained 608 of 31104 combinations so far
# Trained and Tested combination 609 of 31104, taking 1.07 seconds to get val score of 0.3331:
#                 {'C': 0.0001, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 13},
#             Current best combo with val score 0.529:
#                     {'C': 10, 'tol': 0.0001, 'max_iter': 800, 'gamma': 'scale', 'features': 16}
# Already Trained and Tested combination (val score of 0.3095):
#             {'C': 0.0001, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 15}
#             Current best combo (with val score 0.529):
#                     {'C': 10, 'tol': 0.0001, 'max_iter': 800, 'gamma': 'scale', 'features': 16}
#         Has trained 609 of 31104 combinations so far
# Already Trained and Tested combination (val score of 0.348):
#             {'C': 0.001, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 16}
#             Current best combo (with val score 0.529):
#                     {'C': 10, 'tol': 0.0001, 'max_iter': 800, 'gamma': 'scale', 'features': 16}
#         Has trained 609 of 31104 combinations so far
# Already Trained and Tested combination (val score of 0.3406):
#             {'C': 0.0001, 'tol': 0.001, 'max_iter': 1600, 'gamma': 'auto', 'features': 16}
#             Current best combo (with val score 0.529):
#                     {'C': 10, 'tol': 0.0001, 'max_iter': 800, 'gamma': 'scale', 'features': 16}
#         Has trained 609 of 31104 combinations so far
# Already Trained and Tested combination (val score of 0.3142):
#             {'C': 0.0001, 'tol': 0.0001, 'max_iter': 800, 'gamma': 'auto', 'features': 16}
#             Current best combo (with val score 0.529):
#                     {'C': 10, 'tol': 0.0001, 'max_iter': 800, 'gamma': 'scale', 'features': 16}
#         Has trained 609 of 31104 combinations so far
# Already Trained and Tested combination (val score of 0.4235):
#             {'C': 0.0001, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16}
#             Current best combo (with val score 0.529):
#                     {'C': 10, 'tol': 0.0001, 'max_iter': 800, 'gamma': 'scale', 'features': 16}
#         Has trained 609 of 31104 combinations so far
# Already Trained and Tested combination (val score of 0.3095):
#             {'C': 0.0001, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 15}
#             Current best combo (with val score 0.529):
#                     {'C': 10, 'tol': 0.0001, 'max_iter': 800, 'gamma': 'scale', 'features': 16}
#         Has trained 609 of 31104 combinations so far
# Trained and Tested combination 610 of 31104, taking 1.44 seconds to get val score of 0.3418:
#                 {'C': 0.0001, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 17},
#             Current best combo with val score 0.529:
#                     {'C': 10, 'tol': 0.0001, 'max_iter': 800, 'gamma': 'scale', 'features': 16}
# % Combos Checked Thus Far: 610 out of 31104 which is 1.9611630000000002%
# Cruising Coordrdinate 256 of 256
#
# Cruise suspended due to suspicious case
# Guidance: round 18
#
# 	round 18 iteration:  0
#
# % Combos Checked Thus Far: 610 out of 31104 which is 1.9611630000000002%
# FINAL STAGE: Begin final Guidance system
#
#
# Guidance: round FINAL
#
# 	round FINAL iteration:  0
#
# Already Trained and Tested combination (val score of 0.4492):
#             {'C': 1, 'tol': 0.0001, 'max_iter': 800, 'gamma': 'scale', 'features': 16}
#             Current best combo (with val score 0.529):
#                     {'C': 10, 'tol': 0.0001, 'max_iter': 800, 'gamma': 'scale', 'features': 16}
#         Has trained 610 of 31104 combinations so far
# Already Trained and Tested combination (val score of 0.529):
#             {'C': 10, 'tol': 0.001, 'max_iter': 800, 'gamma': 'scale', 'features': 16}
#             Current best combo (with val score 0.529):
#                     {'C': 10, 'tol': 0.0001, 'max_iter': 800, 'gamma': 'scale', 'features': 16}
#         Has trained 610 of 31104 combinations so far
# Already Trained and Tested combination (val score of 0.4698):
#             {'C': 10, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'scale', 'features': 16}
#             Current best combo (with val score 0.529):
#                     {'C': 10, 'tol': 0.0001, 'max_iter': 800, 'gamma': 'scale', 'features': 16}
#         Has trained 610 of 31104 combinations so far
# Already Trained and Tested combination (val score of 0.5244):
#             {'C': 10, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16}
#             Current best combo (with val score 0.529):
#                     {'C': 10, 'tol': 0.0001, 'max_iter': 800, 'gamma': 'scale', 'features': 16}
#         Has trained 610 of 31104 combinations so far
# Already Trained and Tested combination (val score of 0.467):
#             {'C': 10, 'tol': 0.0001, 'max_iter': 800, 'gamma': 'auto', 'features': 16}
#             Current best combo (with val score 0.529):
#                     {'C': 10, 'tol': 0.0001, 'max_iter': 800, 'gamma': 'scale', 'features': 16}
#         Has trained 610 of 31104 combinations so far
# Already Trained and Tested combination (val score of 0.3339):
#             {'C': 10, 'tol': 0.0001, 'max_iter': 800, 'gamma': 'scale', 'features': 15}
#             Current best combo (with val score 0.529):
#                     {'C': 10, 'tol': 0.0001, 'max_iter': 800, 'gamma': 'scale', 'features': 16}
#         Has trained 610 of 31104 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'C': 10, 'tol': 0.0001, 'max_iter': 800, 'gamma': 'scale', 'features': 17}
#             Current best combo (with val score 0.529):
#                     {'C': 10, 'tol': 0.0001, 'max_iter': 800, 'gamma': 'scale', 'features': 16}
#         Has trained 610 of 31104 combinations so far
# 	round FINAL iteration:  1
#
# Trained and Tested combination 611 of 31104, taking 0.42 seconds to get val score of 0.4492:
#                 {'C': 1, 'tol': 0.001, 'max_iter': 800, 'gamma': 'scale', 'features': 16},
#             Current best combo with val score 0.529:
#                     {'C': 10, 'tol': 0.0001, 'max_iter': 800, 'gamma': 'scale', 'features': 16}
# Already Trained and Tested combination (val score of 0.529):
#             {'C': 10, 'tol': 0.0001, 'max_iter': 800, 'gamma': 'scale', 'features': 16}
#             Current best combo (with val score 0.529):
#                     {'C': 10, 'tol': 0.0001, 'max_iter': 800, 'gamma': 'scale', 'features': 16}
#         Has trained 611 of 31104 combinations so far
# Trained and Tested combination 612 of 31104, taking 0.31 seconds to get val score of 0.529:
#                 {'C': 10, 'tol': 0.01, 'max_iter': 800, 'gamma': 'scale', 'features': 16},
#             Current best combo with val score 0.529:
#                     {'C': 10, 'tol': 0.0001, 'max_iter': 800, 'gamma': 'scale', 'features': 16}
# Trained and Tested combination 613 of 31104, taking 0.33 seconds to get val score of 0.4698:
#                 {'C': 10, 'tol': 0.001, 'max_iter': 400, 'gamma': 'scale', 'features': 16},
#             Current best combo with val score 0.529:
#                     {'C': 10, 'tol': 0.0001, 'max_iter': 800, 'gamma': 'scale', 'features': 16}
# Already Trained and Tested combination (val score of 0.5244):
#             {'C': 10, 'tol': 0.001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16}
#             Current best combo (with val score 0.529):
#                     {'C': 10, 'tol': 0.0001, 'max_iter': 800, 'gamma': 'scale', 'features': 16}
#         Has trained 613 of 31104 combinations so far
# Trained and Tested combination 614 of 31104, taking 0.37 seconds to get val score of 0.467:
#                 {'C': 10, 'tol': 0.001, 'max_iter': 800, 'gamma': 'auto', 'features': 16},
#             Current best combo with val score 0.529:
#                     {'C': 10, 'tol': 0.0001, 'max_iter': 800, 'gamma': 'scale', 'features': 16}
# Already Trained and Tested combination (val score of 0.3339):
#             {'C': 10, 'tol': 0.001, 'max_iter': 800, 'gamma': 'scale', 'features': 15}
#             Current best combo (with val score 0.529):
#                     {'C': 10, 'tol': 0.0001, 'max_iter': 800, 'gamma': 'scale', 'features': 16}
#         Has trained 614 of 31104 combinations so far
# Trained and Tested combination 615 of 31104, taking 0.25 seconds to get val score of 0.0:
#                 {'C': 10, 'tol': 0.001, 'max_iter': 800, 'gamma': 'scale', 'features': 17},
#             Current best combo with val score 0.529:
#                     {'C': 10, 'tol': 0.0001, 'max_iter': 800, 'gamma': 'scale', 'features': 16}
# % Combos Checked Thus Far: 615 out of 31104 which is 1.9772379999999998%
# Max Val Score:
#  0.529004
# Max Val Score Std:
#  0.036559
# Best Combo Train Score:
#  0.971886
# Best Combo Train Score Std:
#  0.002238
# Max Combo Index:
#  (5, 0, 4, 1, 16) out of [6, 6, 6, 2, 72] (note best combo is 0-indexed)
# Max Combo Hyperparamer Combination:
#  {'C': 10, 'tol': 0.0001, 'max_iter': 800, 'gamma': 'scale', 'features': 16}
# Max Combo Features:
#  ('procedure_225469', 'lods_score', 'procedure_224274', 'marital_status_0', 'marital_status_DIVORCED', 'marital_status_MARRIED', 'marital_status_WIDOWED', 'marital_status_SINGLE', 'procedure_223253', 'race_AMERICAN INDIAN/ALASKA NATIVE', 'race_ASIAN', 'race_ASIAN - ASIAN INDIAN', 'race_ASIAN - CHINESE', 'race_ASIAN - KOREAN', 'race_ASIAN - SOUTH EAST ASIAN', 'race_BLACK/AFRICAN', 'race_BLACK/AFRICAN AMERICAN', 'race_BLACK/CAPE VERDEAN', 'race_BLACK/CARIBBEAN ISLAND', 'race_HISPANIC OR LATINO', 'race_HISPANIC/LATINO - CENTRAL AMERICAN', 'race_HISPANIC/LATINO - COLUMBIAN', 'race_HISPANIC/LATINO - CUBAN', 'race_HISPANIC/LATINO - DOMINICAN', 'race_HISPANIC/LATINO - GUATEMALAN', 'race_HISPANIC/LATINO - HONDURAN', 'race_HISPANIC/LATINO - MEXICAN', 'race_HISPANIC/LATINO - PUERTO RICAN', 'race_HISPANIC/LATINO - SALVADORAN', 'race_MULTIPLE RACE/ETHNICITY', 'race_NATIVE HAWAIIAN OR OTHER PACIFIC ISLANDER', 'race_OTHER', 'race_PATIENT DECLINED TO ANSWER', 'race_PORTUGUESE', 'race_SOUTH AMERICAN', 'race_UNABLE TO OBTAIN', 'race_UNKNOWN', 'race_WHITE', 'race_WHITE - BRAZILIAN', 'race_WHITE - EASTERN EUROPEAN', 'race_WHITE - RUSSIAN', 'race_WHITE - OTHER EUROPEAN', 'procedure_227712', 'procedure_224276', 'admission_type_DIRECT OBSERVATION', 'admission_type_ELECTIVE', 'admission_type_EU OBSERVATION', 'admission_type_EW EMER.', 'admission_type_OBSERVATION ADMIT', 'admission_type_SURGICAL SAME DAY ADMISSION', 'admission_type_URGENT', 'admission_type_DIRECT EMER.', 'insurance_Medicare', 'insurance_Other', 'insurance_Medicaid', 'procedure_225792', 'procedure_228130', 'procedure_225817', 'procedure_224267', 'gender_F', 'gender_M', 'ventilation_used', 'hospital_stay_duration')
# % Combos Checked: 615 out of 31104 which is 1.9772379999999998%
