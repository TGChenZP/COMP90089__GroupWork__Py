# %% [markdown]
# # Tuning Script

# %%
# Parameters subject to change in every script - involved in naming

MODEL = 'svc(rbf)'
PREPROCESSING = 'smote_normalise'
TUNER = 'yangzhoub'
OPTIMISED_METRIC = 'f1'

# %% [markdown]
# ---

# %%
# detect whether this is a google environment

COLAB_ENVIRONMENT = False

try:
    from google.colab import drive
    drive.mount('/content/drive')
    COLAB_ENVIRONMENT = True
except:
    pass
# Out:
# Mounted at /content/drive

# %%
import sys
import os
import pickle

if COLAB_ENVIRONMENT:
    home_directory = './drive/MyDrive/LAB/COMP90089__GroupWork__Py/' # my home directory is stored in ./LAB of google drive
    if MODEL == 'ebr':
        # !pip install interpret==0.5.0
    elif MODEL == 'cbr':
        # !pip install catboost
    elif MODEL in ['tf', 'mlp']:
        # !pip install PyTorch2Sklearn
    # !pip install JXAutoML
else:
    home_directory = '../../'

from JXAutoML.YangZhouB_10CV import YangZhouB_10CV as Tuner

import pandas as pd
# Out:
# Collecting JXAutoML
#   Downloading JXAutoML-0.4.4-py3-none-any.whl.metadata (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.2/67.2 kB 1.9 MB/s eta 0:00:00
# Downloading JXAutoML-0.4.4-py3-none-any.whl (52 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.1/52.1 kB 3.7 MB/s eta 0:00:00
# Installing collected packages: JXAutoML
# Successfully installed JXAutoML-0.4.4

# %%
# Parameters that are same for every script

FOLDS = 10  # we have decided to do 10 fold validation

SEED = 42

TASK_TYPE = 'Classification'  # this task is a classification task

# we have decided to tune features as hp
TUNE_FEATURES_AS_HYPERPARAMETERS = True

# %% [markdown]
# ---

# %%
# model to use to tune
from sklearn.svm import SVC as clf

# what values to try for each hyperparameter
parameter_choices = {
    'C': (0.0001, 0.001, 0.01, 0.1, 1, 10),
    'tol': (0.0001, 0.001, 0.01, 0.1, 1, 10),
    'max_iter': (50, 100, 200, 400, 800, 1600),
    'gamma': ('scale', 'auto')
}

# what values to set non-tuneable parameters/hyperparameters
non_tunable_hyperparameters_dict = {
                                    'verbose': False,
                                    'decision_function_shape': 'ovr',
                                    'random_state': 42,
                                    'kernel': 'rbf'
                                    }

# %% [markdown]
# ---

# %% [markdown]
# Read in and Prepare Data

# %%
# Import data and store as lists

train_x_list = []
train_y_list = []
val_x_list = []
val_y_list = []

for i in range(FOLDS):
    train_data = pd.read_csv(
        f'{home_directory}data/curated/modelling/{PREPROCESSING}/train_{i}.csv')
    val_data = pd.read_csv(
        f'{home_directory}data/curated/modelling/{PREPROCESSING}/val_{i}.csv')

    # get the correct rows for X and y
    train_x = train_data.drop(
        ['mortality_status', 'subject_id', 'hadm_id', 'stay_id'], axis=1)
    train_y = train_data['mortality_status']
    val_x = val_data.drop(
        ['mortality_status', 'subject_id', 'hadm_id', 'stay_id'], axis=1)
    val_y = val_data['mortality_status']

    train_x_list.append(train_x)
    train_y_list.append(train_y)
    val_x_list.append(val_x)
    val_y_list.append(val_y)

# %%
# Import feature importance ordering

with open(f'{home_directory}models/xgb_feature_importance_ordering_{PREPROCESSING}.pickle', 'rb') as f:
    feature_importance_ordering = pickle.load(f)

# %% [markdown]
# Set parameters

# %%
# initialisation
tuner = Tuner()

print('---')

# define what model we are tuning
tuner.read_in_model(clf, TASK_TYPE, optimised_metric=OPTIMISED_METRIC)

print('---')

# read in the data for training and validation
tuner.read_in_data(train_x_list, train_y_list, val_x_list, val_y_list)

print('---')

# set what hp values to tune
tuner.set_hyperparameters(parameter_choices)
# WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

# set up hp values that need to be changed from default but NOT to be tuned
tuner.set_non_tuneable_hyperparameters(non_tunable_hyperparameters_dict)

print('---')

# set up feature importance ordering

if TUNE_FEATURES_AS_HYPERPARAMETERS:
    tuner.set_features(feature_importance_ordering)
    # WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

try:  # try to read in previous results to continue tuning ...
    tuner.read_in_tuning_result_df(
        f'{home_directory}models/tuning/{TUNER}_{MODEL}_{PREPROCESSING}.csv')
except:
    print('No previous tuning data read in')

print('---')

# set up where to save the tuning result csv
tuner.set_tuning_result_saving_address(
    f'{home_directory}models/tuning/{TUNER}_{MODEL}_{PREPROCESSING}.csv')

print('---')

# set up where to save the current best model
tuner.set_best_model_saving_address(
    f'{home_directory}models/tmp_models/{TUNER}_{MODEL}_{PREPROCESSING}')
# Out:
# YangZhouB Initialised
# ---
# Successfully read in model <class 'sklearn.svm._classes.SVC'>, which is a Classification model optimising for f1
# ---
# Read in Train X data list
# Read in Train y data list
# Read in Val X data list
# Read in Val y data list
# ---
# Successfully recorded hyperparameter choices
# ---
# Successfully recorded non_tuneable_hyperparameter choices
# ---
# Successfully recorded tuneable feature combination choices and updated relevant internal structures
# ---
# No previous tuning data read in
# ---
# Successfully set tuning output address
# ---
# Successfully set best model output address

# %%
# ignore warnings

import warnings
warnings.filterwarnings("ignore")

# %%
# begin tuning ... (or continue training)

tuner.tune()
# Out:
# BEGIN TUNING
#
#
# STAGE ZERO: Tune all Cruise combinations
#
#
# Trained and Tested combination 1 of 20736, taking 0.07 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 39},
#             Current best combo with val score 0.0:
#                     {'C': 0.0001, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 39}
# Trained and Tested combination 2 of 20736, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 0.0001, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 25},
#             Current best combo with val score 0.3117:
#                     {'C': 0.0001, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 25}
# Trained and Tested combination 3 of 20736, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 10, 'tol': 10, 'max_iter': 50, 'gamma': 'auto', 'features': 15},
#             Current best combo with val score 0.3117:
#                     {'C': 0.0001, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 25}
# Trained and Tested combination 4 of 20736, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 10, 'tol': 10, 'max_iter': 50, 'gamma': 'scale', 'features': 0},
#             Current best combo with val score 0.3117:
#                     {'C': 0.0001, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 25}
# Trained and Tested combination 5 of 20736, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 10, 'tol': 10, 'max_iter': 1600, 'gamma': 'scale', 'features': 10},
#             Current best combo with val score 0.3117:
#                     {'C': 0.0001, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 25}
# Trained and Tested combination 6 of 20736, taking 0.0 seconds to get val score of 0.3117:
#                 {'C': 10, 'tol': 10, 'max_iter': 50, 'gamma': 'auto', 'features': 0},
#             Current best combo with val score 0.3117:
#                     {'C': 0.0001, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 25}
# Trained and Tested combination 7 of 20736, taking 0.04 seconds to get val score of 0.0:
#                 {'C': 10, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 25},
#             Current best combo with val score 0.3117:
#                     {'C': 0.0001, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 25}
# Trained and Tested combination 8 of 20736, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 0.0001, 'tol': 10, 'max_iter': 50, 'gamma': 'auto', 'features': 10},
#             Current best combo with val score 0.3117:
#                     {'C': 0.0001, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 25}
# Trained and Tested combination 9 of 20736, taking 0.06 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 39},
#             Current best combo with val score 0.3117:
#                     {'C': 0.0001, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 25}
# Trained and Tested combination 10 of 20736, taking 0.03 seconds to get val score of 0.0937:
#                 {'C': 0.0001, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 10},
#             Current best combo with val score 0.3117:
#                     {'C': 0.0001, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 25}
# Trained and Tested combination 11 of 20736, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 0.0001, 'tol': 10, 'max_iter': 1600, 'gamma': 'scale', 'features': 10},
#             Current best combo with val score 0.3117:
#                     {'C': 0.0001, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 25}
# Trained and Tested combination 12 of 20736, taking 0.5 seconds to get val score of 0.089:
#                 {'C': 0.0001, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 0},
#             Current best combo with val score 0.3117:
#                     {'C': 0.0001, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 25}
# Trained and Tested combination 13 of 20736, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 10, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 43},
#             Current best combo with val score 0.3117:
#                     {'C': 0.0001, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 25}
# Trained and Tested combination 14 of 20736, taking 0.51 seconds to get val score of 0.0:
#                 {'C': 10, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 43},
#             Current best combo with val score 0.3117:
#                     {'C': 0.0001, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 25}
# Trained and Tested combination 15 of 20736, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 0.0001, 'tol': 10, 'max_iter': 50, 'gamma': 'auto', 'features': 43},
#             Current best combo with val score 0.3117:
#                     {'C': 0.0001, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 25}
# Trained and Tested combination 16 of 20736, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 0.0001, 'tol': 10, 'max_iter': 50, 'gamma': 'auto', 'features': 35},
#             Current best combo with val score 0.3117:
#                     {'C': 0.0001, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 25}
# Trained and Tested combination 17 of 20736, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 0.0001, 'tol': 10, 'max_iter': 50, 'gamma': 'scale', 'features': 35},
#             Current best combo with val score 0.3117:
#                     {'C': 0.0001, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 25}
# Trained and Tested combination 18 of 20736, taking 0.03 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 10},
#             Current best combo with val score 0.3117:
#                     {'C': 0.0001, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 25}
# Trained and Tested combination 19 of 20736, taking 0.06 seconds to get val score of 0.1511:
#                 {'C': 10, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 25},
#             Current best combo with val score 0.3117:
#                     {'C': 0.0001, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 25}
# Trained and Tested combination 20 of 20736, taking 0.05 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 30},
#             Current best combo with val score 0.3117:
#                     {'C': 0.0001, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 25}
# Trained and Tested combination 21 of 20736, taking 0.02 seconds to get val score of 0.3117:
#                 {'C': 10, 'tol': 10, 'max_iter': 50, 'gamma': 'scale', 'features': 43},
#             Current best combo with val score 0.3117:
#                     {'C': 0.0001, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 25}
# Trained and Tested combination 22 of 20736, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 0.0001, 'tol': 10, 'max_iter': 1600, 'gamma': 'scale', 'features': 0},
#             Current best combo with val score 0.3117:
#                     {'C': 0.0001, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 25}
# Trained and Tested combination 23 of 20736, taking 0.0 seconds to get val score of 0.3117:
#                 {'C': 10, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 0},
#             Current best combo with val score 0.3117:
#                     {'C': 0.0001, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 25}
# Trained and Tested combination 24 of 20736, taking 0.02 seconds to get val score of 0.2538:
#                 {'C': 0.0001, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 0},
#             Current best combo with val score 0.3117:
#                     {'C': 0.0001, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 25}
# Trained and Tested combination 25 of 20736, taking 0.04 seconds to get val score of 0.0:
#                 {'C': 10, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 47},
#             Current best combo with val score 0.3117:
#                     {'C': 0.0001, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 25}
# Trained and Tested combination 26 of 20736, taking 0.0 seconds to get val score of 0.3117:
#                 {'C': 0.0001, 'tol': 10, 'max_iter': 50, 'gamma': 'auto', 'features': 0},
#             Current best combo with val score 0.3117:
#                     {'C': 0.0001, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 25}
# Trained and Tested combination 27 of 20736, taking 0.03 seconds to get val score of 0.0828:
#                 {'C': 10, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 15},
#             Current best combo with val score 0.3117:
#                     {'C': 0.0001, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 25}
# Trained and Tested combination 28 of 20736, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 0.0001, 'tol': 10, 'max_iter': 50, 'gamma': 'auto', 'features': 30},
#             Current best combo with val score 0.3117:
#                     {'C': 0.0001, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 25}
# Trained and Tested combination 29 of 20736, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 0.0001, 'tol': 10, 'max_iter': 50, 'gamma': 'scale', 'features': 25},
#             Current best combo with val score 0.3117:
#                     {'C': 0.0001, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 25}
# Trained and Tested combination 30 of 20736, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 0.0001, 'tol': 10, 'max_iter': 1600, 'gamma': 'scale', 'features': 25},
#             Current best combo with val score 0.3117:
#                     {'C': 0.0001, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 25}
# Trained and Tested combination 31 of 20736, taking 0.02 seconds to get val score of 0.3117:
#                 {'C': 0.0001, 'tol': 10, 'max_iter': 1600, 'gamma': 'scale', 'features': 43},
#             Current best combo with val score 0.3117:
#                     {'C': 0.0001, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 25}
# Trained and Tested combination 32 of 20736, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 10, 'tol': 10, 'max_iter': 50, 'gamma': 'scale', 'features': 25},
#             Current best combo with val score 0.3117:
#                     {'C': 0.0001, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 25}
# Trained and Tested combination 33 of 20736, taking 0.0 seconds to get val score of 0.3117:
#                 {'C': 0.0001, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 0},
#             Current best combo with val score 0.3117:
#                     {'C': 0.0001, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 25}
# Trained and Tested combination 34 of 20736, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 10, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 20},
#             Current best combo with val score 0.3117:
#                     {'C': 0.0001, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 25}
# Trained and Tested combination 35 of 20736, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 10, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 30},
#             Current best combo with val score 0.3117:
#                     {'C': 0.0001, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 25}
# Trained and Tested combination 36 of 20736, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 0.0001, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 10},
#             Current best combo with val score 0.3117:
#                     {'C': 0.0001, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 25}
# Trained and Tested combination 37 of 20736, taking 0.03 seconds to get val score of 0.2653:
#                 {'C': 10, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 20},
#             Current best combo with val score 0.3117:
#                     {'C': 0.0001, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 25}
# Trained and Tested combination 38 of 20736, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 0.0001, 'tol': 10, 'max_iter': 50, 'gamma': 'auto', 'features': 15},
#             Current best combo with val score 0.3117:
#                     {'C': 0.0001, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 25}
# Trained and Tested combination 39 of 20736, taking 0.47 seconds to get val score of 0.0033:
#                 {'C': 10, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 20},
#             Current best combo with val score 0.3117:
#                     {'C': 0.0001, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 25}
# Trained and Tested combination 40 of 20736, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 0.0001, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 35},
#             Current best combo with val score 0.3117:
#                     {'C': 0.0001, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 25}
# Trained and Tested combination 41 of 20736, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 0.0001, 'tol': 10, 'max_iter': 50, 'gamma': 'scale', 'features': 20},
#             Current best combo with val score 0.3117:
#                     {'C': 0.0001, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 25}
# Trained and Tested combination 42 of 20736, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 10, 'tol': 10, 'max_iter': 50, 'gamma': 'auto', 'features': 25},
#             Current best combo with val score 0.3117:
#                     {'C': 0.0001, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 25}
# Trained and Tested combination 43 of 20736, taking 0.49 seconds to get val score of 0.0:
#                 {'C': 10, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 39},
#             Current best combo with val score 0.3117:
#                     {'C': 0.0001, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 25}
# Trained and Tested combination 44 of 20736, taking 0.03 seconds to get val score of 0.1982:
#                 {'C': 0.0001, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 15},
#             Current best combo with val score 0.3117:
#                     {'C': 0.0001, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 25}
# Trained and Tested combination 45 of 20736, taking 1.07 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 47},
#             Current best combo with val score 0.3117:
#                     {'C': 0.0001, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 25}
# Trained and Tested combination 46 of 20736, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 10, 'tol': 10, 'max_iter': 1600, 'gamma': 'scale', 'features': 35},
#             Current best combo with val score 0.3117:
#                     {'C': 0.0001, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 25}
# Trained and Tested combination 47 of 20736, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 0.0001, 'tol': 10, 'max_iter': 50, 'gamma': 'scale', 'features': 10},
#             Current best combo with val score 0.3117:
#                     {'C': 0.0001, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 25}
# Trained and Tested combination 48 of 20736, taking 0.05 seconds to get val score of 0.0:
#                 {'C': 10, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 20},
#             Current best combo with val score 0.3117:
#                     {'C': 0.0001, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 25}
# Trained and Tested combination 49 of 20736, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 10, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 15},
#             Current best combo with val score 0.3117:
#                     {'C': 0.0001, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 25}
# Trained and Tested combination 50 of 20736, taking 0.52 seconds to get val score of 0.0:
#                 {'C': 10, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 43},
#             Current best combo with val score 0.3117:
#                     {'C': 0.0001, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 25}
# Trained and Tested combination 51 of 20736, taking 0.05 seconds to get val score of 0.0:
#                 {'C': 10, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 35},
#             Current best combo with val score 0.3117:
#                     {'C': 0.0001, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 25}
# Trained and Tested combination 52 of 20736, taking 0.04 seconds to get val score of 0.0:
#                 {'C': 10, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 30},
#             Current best combo with val score 0.3117:
#                     {'C': 0.0001, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 25}
# Trained and Tested combination 53 of 20736, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 0.0001, 'tol': 10, 'max_iter': 1600, 'gamma': 'scale', 'features': 20},
#             Current best combo with val score 0.3117:
#                     {'C': 0.0001, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 25}
# Trained and Tested combination 54 of 20736, taking 0.0 seconds to get val score of 0.3117:
#                 {'C': 0.0001, 'tol': 10, 'max_iter': 50, 'gamma': 'scale', 'features': 0},
#             Current best combo with val score 0.3117:
#                     {'C': 0.0001, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 25}
# Trained and Tested combination 55 of 20736, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 10, 'tol': 10, 'max_iter': 1600, 'gamma': 'scale', 'features': 39},
#             Current best combo with val score 0.3117:
#                     {'C': 0.0001, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 25}
# Trained and Tested combination 56 of 20736, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 10, 'tol': 10, 'max_iter': 50, 'gamma': 'scale', 'features': 15},
#             Current best combo with val score 0.3117:
#                     {'C': 0.0001, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 25}
# Trained and Tested combination 57 of 20736, taking 0.03 seconds to get val score of 0.0:
#                 {'C': 10, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 10},
#             Current best combo with val score 0.3117:
#                     {'C': 0.0001, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 25}
# Trained and Tested combination 58 of 20736, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 0.0001, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 20},
#             Current best combo with val score 0.3117:
#                     {'C': 0.0001, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 25}
# Trained and Tested combination 59 of 20736, taking 0.64 seconds to get val score of 0.016:
#                 {'C': 10, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 15},
#             Current best combo with val score 0.3117:
#                     {'C': 0.0001, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 25}
# Trained and Tested combination 60 of 20736, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 10, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 39},
#             Current best combo with val score 0.3117:
#                     {'C': 0.0001, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 25}
# Trained and Tested combination 61 of 20736, taking 0.03 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 25},
#             Current best combo with val score 0.3117:
#                     {'C': 0.0001, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 25}
# Trained and Tested combination 62 of 20736, taking 1.62 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 47},
#             Current best combo with val score 0.3117:
#                     {'C': 0.0001, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 25}
# Trained and Tested combination 63 of 20736, taking 0.05 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 43},
#             Current best combo with val score 0.3117:
#                     {'C': 0.0001, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 25}
# Trained and Tested combination 64 of 20736, taking 0.04 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 43},
#             Current best combo with val score 0.3117:
#                     {'C': 0.0001, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 25}
# Trained and Tested combination 65 of 20736, taking 0.02 seconds to get val score of 0.1223:
#                 {'C': 10, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 0},
#             Current best combo with val score 0.3117:
#                     {'C': 0.0001, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 25}
# Trained and Tested combination 66 of 20736, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 10, 'tol': 10, 'max_iter': 50, 'gamma': 'auto', 'features': 39},
#             Current best combo with val score 0.3117:
#                     {'C': 0.0001, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 25}
# Trained and Tested combination 67 of 20736, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 0.0001, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 15},
#             Current best combo with val score 0.3117:
#                     {'C': 0.0001, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 25}
# Trained and Tested combination 68 of 20736, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 0.0001, 'tol': 10, 'max_iter': 50, 'gamma': 'auto', 'features': 25},
#             Current best combo with val score 0.3117:
#                     {'C': 0.0001, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 25}
# Trained and Tested combination 69 of 20736, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 10, 'tol': 10, 'max_iter': 50, 'gamma': 'auto', 'features': 5},
#             Current best combo with val score 0.3117:
#                     {'C': 0.0001, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 25}
# Trained and Tested combination 70 of 20736, taking 0.03 seconds to get val score of 0.1523:
#                 {'C': 10, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 5},
#             Current best combo with val score 0.3117:
#                     {'C': 0.0001, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 25}
# Trained and Tested combination 71 of 20736, taking 1.06 seconds to get val score of 0.062:
#                 {'C': 0.0001, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 35},
#             Current best combo with val score 0.3117:
#                     {'C': 0.0001, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 25}
# Trained and Tested combination 72 of 20736, taking 0.42 seconds to get val score of 0.0:
#                 {'C': 10, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 30},
#             Current best combo with val score 0.3117:
#                     {'C': 0.0001, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 25}
# Trained and Tested combination 73 of 20736, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 10, 'tol': 10, 'max_iter': 50, 'gamma': 'auto', 'features': 47},
#             Current best combo with val score 0.3117:
#                     {'C': 0.0001, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 25}
# Trained and Tested combination 74 of 20736, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 10, 'tol': 10, 'max_iter': 1600, 'gamma': 'scale', 'features': 20},
#             Current best combo with val score 0.3117:
#                     {'C': 0.0001, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 25}
# Trained and Tested combination 75 of 20736, taking 2.32 seconds to get val score of 0.0772:
#                 {'C': 0.0001, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 20},
#             Current best combo with val score 0.3117:
#                     {'C': 0.0001, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 25}
# Trained and Tested combination 76 of 20736, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 10, 'tol': 10, 'max_iter': 50, 'gamma': 'auto', 'features': 43},
#             Current best combo with val score 0.3117:
#                     {'C': 0.0001, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 25}
# Trained and Tested combination 77 of 20736, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 0.0001, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 5},
#             Current best combo with val score 0.3117:
#                     {'C': 0.0001, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 25}
# Trained and Tested combination 78 of 20736, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 10, 'tol': 10, 'max_iter': 50, 'gamma': 'auto', 'features': 35},
#             Current best combo with val score 0.3117:
#                     {'C': 0.0001, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 25}
# Trained and Tested combination 79 of 20736, taking 0.61 seconds to get val score of 0.0166:
#                 {'C': 10, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 5},
#             Current best combo with val score 0.3117:
#                     {'C': 0.0001, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 25}
# Trained and Tested combination 80 of 20736, taking 0.04 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 35},
#             Current best combo with val score 0.3117:
#                     {'C': 0.0001, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 25}
# Trained and Tested combination 81 of 20736, taking 0.03 seconds to get val score of 0.0624:
#                 {'C': 10, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 10},
#             Current best combo with val score 0.3117:
#                     {'C': 0.0001, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 25}
# Trained and Tested combination 82 of 20736, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 10, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 25},
#             Current best combo with val score 0.3117:
#                     {'C': 0.0001, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 25}
# Trained and Tested combination 83 of 20736, taking 0.03 seconds to get val score of 0.154:
#                 {'C': 0.0001, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 25},
#             Current best combo with val score 0.3117:
#                     {'C': 0.0001, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 25}
# Trained and Tested combination 84 of 20736, taking 1.01 seconds to get val score of 0.2407:
#                 {'C': 0.0001, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10},
#             Current best combo with val score 0.3117:
#                     {'C': 0.0001, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 25}
# Trained and Tested combination 85 of 20736, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 10, 'tol': 10, 'max_iter': 1600, 'gamma': 'scale', 'features': 30},
#             Current best combo with val score 0.3117:
#                     {'C': 0.0001, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 25}
# Trained and Tested combination 86 of 20736, taking 0.46 seconds to get val score of 0.0:
#                 {'C': 10, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 35},
#             Current best combo with val score 0.3117:
#                     {'C': 0.0001, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 25}
# Trained and Tested combination 87 of 20736, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 10, 'tol': 10, 'max_iter': 50, 'gamma': 'auto', 'features': 30},
#             Current best combo with val score 0.3117:
#                     {'C': 0.0001, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 25}
# Trained and Tested combination 88 of 20736, taking 0.49 seconds to get val score of 0.3108:
#                 {'C': 0.0001, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 0},
#             Current best combo with val score 0.3117:
#                     {'C': 0.0001, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 25}
# Trained and Tested combination 89 of 20736, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 10, 'tol': 10, 'max_iter': 50, 'gamma': 'scale', 'features': 30},
#             Current best combo with val score 0.3117:
#                     {'C': 0.0001, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 25}
# Trained and Tested combination 90 of 20736, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 0.0001, 'tol': 10, 'max_iter': 1600, 'gamma': 'scale', 'features': 47},
#             Current best combo with val score 0.3117:
#                     {'C': 0.0001, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 25}
# Trained and Tested combination 91 of 20736, taking 0.02 seconds to get val score of 0.3117:
#                 {'C': 0.0001, 'tol': 10, 'max_iter': 50, 'gamma': 'scale', 'features': 47},
#             Current best combo with val score 0.3117:
#                     {'C': 0.0001, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 25}
# Trained and Tested combination 92 of 20736, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 0.0001, 'tol': 10, 'max_iter': 50, 'gamma': 'auto', 'features': 39},
#             Current best combo with val score 0.3117:
#                     {'C': 0.0001, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 25}
# Trained and Tested combination 93 of 20736, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 0.0001, 'tol': 10, 'max_iter': 50, 'gamma': 'scale', 'features': 43},
#             Current best combo with val score 0.3117:
#                     {'C': 0.0001, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 25}
# Trained and Tested combination 94 of 20736, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 0.0001, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 30},
#             Current best combo with val score 0.3117:
#                     {'C': 0.0001, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 25}
# Trained and Tested combination 95 of 20736, taking 0.02 seconds to get val score of 0.3117:
#                 {'C': 0.0001, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 47},
#             Current best combo with val score 0.3117:
#                     {'C': 0.0001, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 25}
# Trained and Tested combination 96 of 20736, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 10, 'tol': 10, 'max_iter': 50, 'gamma': 'auto', 'features': 20},
#             Current best combo with val score 0.3117:
#                     {'C': 0.0001, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 25}
# Trained and Tested combination 97 of 20736, taking 0.04 seconds to get val score of 0.226:
#                 {'C': 0.0001, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 5},
#             Current best combo with val score 0.3117:
#                     {'C': 0.0001, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 25}
# Trained and Tested combination 98 of 20736, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 0.0001, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 39},
#             Current best combo with val score 0.3117:
#                     {'C': 0.0001, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 25}
# Trained and Tested combination 99 of 20736, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 10, 'tol': 10, 'max_iter': 1600, 'gamma': 'scale', 'features': 15},
#             Current best combo with val score 0.3117:
#                     {'C': 0.0001, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 25}
# Trained and Tested combination 100 of 20736, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 10, 'tol': 10, 'max_iter': 50, 'gamma': 'scale', 'features': 47},
#             Current best combo with val score 0.3117:
#                     {'C': 0.0001, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 25}
# Trained and Tested combination 101 of 20736, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 10, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 10},
#             Current best combo with val score 0.3117:
#                     {'C': 0.0001, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 25}
# Trained and Tested combination 102 of 20736, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 10, 'tol': 10, 'max_iter': 50, 'gamma': 'scale', 'features': 39},
#             Current best combo with val score 0.3117:
#                     {'C': 0.0001, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 25}
# Trained and Tested combination 103 of 20736, taking 1.64 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 25},
#             Current best combo with val score 0.3117:
#                     {'C': 0.0001, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 25}
# Trained and Tested combination 104 of 20736, taking 0.03 seconds to get val score of 0.2779:
#                 {'C': 0.0001, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 20},
#             Current best combo with val score 0.3117:
#                     {'C': 0.0001, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 25}
# Trained and Tested combination 105 of 20736, taking 0.49 seconds to get val score of 0.0736:
#                 {'C': 10, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10},
#             Current best combo with val score 0.3117:
#                     {'C': 0.0001, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 25}
# Trained and Tested combination 106 of 20736, taking 0.67 seconds to get val score of 0.3108:
#                 {'C': 10, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 0},
#             Current best combo with val score 0.3117:
#                     {'C': 0.0001, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 25}
# Trained and Tested combination 107 of 20736, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 0.0001, 'tol': 10, 'max_iter': 1600, 'gamma': 'scale', 'features': 5},
#             Current best combo with val score 0.3117:
#                     {'C': 0.0001, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 25}
# Trained and Tested combination 108 of 20736, taking 1.08 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 35},
#             Current best combo with val score 0.3117:
#                     {'C': 0.0001, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 25}
# Trained and Tested combination 109 of 20736, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 0.0001, 'tol': 10, 'max_iter': 1600, 'gamma': 'scale', 'features': 39},
#             Current best combo with val score 0.3117:
#                     {'C': 0.0001, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 25}
# Trained and Tested combination 110 of 20736, taking 0.05 seconds to get val score of 0.0:
#                 {'C': 10, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 39},
#             Current best combo with val score 0.3117:
#                     {'C': 0.0001, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 25}
# Trained and Tested combination 111 of 20736, taking 1.7 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 39},
#             Current best combo with val score 0.3117:
#                     {'C': 0.0001, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 25}
# Trained and Tested combination 112 of 20736, taking 0.03 seconds to get val score of 0.0:
#                 {'C': 10, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 15},
#             Current best combo with val score 0.3117:
#                     {'C': 0.0001, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 25}
# Trained and Tested combination 113 of 20736, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 0.0001, 'tol': 10, 'max_iter': 50, 'gamma': 'scale', 'features': 15},
#             Current best combo with val score 0.3117:
#                     {'C': 0.0001, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 25}
# Trained and Tested combination 114 of 20736, taking 0.02 seconds to get val score of 0.3128:
#                 {'C': 10, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 0},
#             Current best combo with val score 0.3128:
#                     {'C': 10, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 0}
# Trained and Tested combination 115 of 20736, taking 0.92 seconds to get val score of 0.0861:
#                 {'C': 0.0001, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 15},
#             Current best combo with val score 0.3128:
#                     {'C': 10, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 0}
# Trained and Tested combination 116 of 20736, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 10, 'tol': 10, 'max_iter': 50, 'gamma': 'scale', 'features': 20},
#             Current best combo with val score 0.3128:
#                     {'C': 10, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 0}
# Trained and Tested combination 117 of 20736, taking 0.05 seconds to get val score of 0.2958:
#                 {'C': 10, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 5},
#             Current best combo with val score 0.3128:
#                     {'C': 10, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 0}
# Trained and Tested combination 118 of 20736, taking 0.04 seconds to get val score of 0.0:
#                 {'C': 10, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 39},
#             Current best combo with val score 0.3128:
#                     {'C': 10, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 0}
# Trained and Tested combination 119 of 20736, taking 1.63 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 39},
#             Current best combo with val score 0.3128:
#                     {'C': 10, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 0}
# Trained and Tested combination 120 of 20736, taking 0.67 seconds to get val score of 0.212:
#                 {'C': 10, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 0},
#             Current best combo with val score 0.3128:
#                     {'C': 10, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 0}
# Trained and Tested combination 121 of 20736, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 0.0001, 'tol': 10, 'max_iter': 1600, 'gamma': 'scale', 'features': 30},
#             Current best combo with val score 0.3128:
#                     {'C': 10, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 0}
# Trained and Tested combination 122 of 20736, taking 0.99 seconds to get val score of 0.033:
#                 {'C': 0.0001, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 20},
#             Current best combo with val score 0.3128:
#                     {'C': 10, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 0}
# Trained and Tested combination 123 of 20736, taking 0.89 seconds to get val score of 0.2477:
#                 {'C': 0.0001, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 5},
#             Current best combo with val score 0.3128:
#                     {'C': 10, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 0}
# Trained and Tested combination 124 of 20736, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 0.0001, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 43},
#             Current best combo with val score 0.3128:
#                     {'C': 10, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 0}
# Trained and Tested combination 125 of 20736, taking 1.23 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 43},
#             Current best combo with val score 0.3128:
#                     {'C': 10, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 0}
# Trained and Tested combination 126 of 20736, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 10, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 5},
#             Current best combo with val score 0.3128:
#                     {'C': 10, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 0}
# Trained and Tested combination 127 of 20736, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 0.0001, 'tol': 10, 'max_iter': 50, 'gamma': 'scale', 'features': 30},
#             Current best combo with val score 0.3128:
#                     {'C': 10, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 0}
# Trained and Tested combination 128 of 20736, taking 0.05 seconds to get val score of 0.0062:
#                 {'C': 0.0001, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 15},
#             Current best combo with val score 0.3128:
#                     {'C': 10, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 0}
# Trained and Tested combination 129 of 20736, taking 1.01 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 10},
#             Current best combo with val score 0.3128:
#                     {'C': 10, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 0}
# Trained and Tested combination 130 of 20736, taking 1.1 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 25},
#             Current best combo with val score 0.3128:
#                     {'C': 10, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 0}
# Trained and Tested combination 131 of 20736, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 0.0001, 'tol': 10, 'max_iter': 50, 'gamma': 'auto', 'features': 5},
#             Current best combo with val score 0.3128:
#                     {'C': 10, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 0}
# Trained and Tested combination 132 of 20736, taking 0.45 seconds to get val score of 0.0:
#                 {'C': 10, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 15},
#             Current best combo with val score 0.3128:
#                     {'C': 10, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 0}
# Trained and Tested combination 133 of 20736, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 10, 'tol': 10, 'max_iter': 50, 'gamma': 'scale', 'features': 10},
#             Current best combo with val score 0.3128:
#                     {'C': 10, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 0}
# Trained and Tested combination 134 of 20736, taking 0.04 seconds to get val score of 0.0:
#                 {'C': 10, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 43},
#             Current best combo with val score 0.3128:
#                     {'C': 10, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 0}
# Trained and Tested combination 135 of 20736, taking 0.39 seconds to get val score of 0.0131:
#                 {'C': 10, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 30},
#             Current best combo with val score 0.3128:
#                     {'C': 10, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 0}
# Trained and Tested combination 136 of 20736, taking 1.37 seconds to get val score of 0.1868:
#                 {'C': 0.0001, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 5},
#             Current best combo with val score 0.3128:
#                     {'C': 10, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 0}
# Trained and Tested combination 137 of 20736, taking 0.02 seconds to get val score of 0.3117:
#                 {'C': 0.0001, 'tol': 10, 'max_iter': 50, 'gamma': 'auto', 'features': 47},
#             Current best combo with val score 0.3128:
#                     {'C': 10, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 0}
# Trained and Tested combination 138 of 20736, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 10, 'tol': 10, 'max_iter': 1600, 'gamma': 'scale', 'features': 43},
#             Current best combo with val score 0.3128:
#                     {'C': 10, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 0}
# Trained and Tested combination 139 of 20736, taking 0.94 seconds to get val score of 0.2615:
#                 {'C': 0.0001, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 30},
#             Current best combo with val score 0.3128:
#                     {'C': 10, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 0}
# Trained and Tested combination 140 of 20736, taking 0.05 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 30},
#             Current best combo with val score 0.3128:
#                     {'C': 10, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 0}
# Trained and Tested combination 141 of 20736, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 10, 'tol': 10, 'max_iter': 50, 'gamma': 'scale', 'features': 35},
#             Current best combo with val score 0.3128:
#                     {'C': 10, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 0}
# Trained and Tested combination 142 of 20736, taking 0.82 seconds to get val score of 0.0414:
#                 {'C': 10, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 5},
#             Current best combo with val score 0.3128:
#                     {'C': 10, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 0}
# ...
#
# Cruising Coordrdinate 36 of 176
#
# Cruising Coordrdinate 37 of 176
#
# Cruising Coordrdinate 38 of 176
#
# Cruising Coordrdinate 39 of 176
#
# Cruising Coordrdinate 40 of 176
#
# Cruising Coordrdinate 41 of 176
#
# Cruising Coordrdinate 42 of 176
#
# Cruising Coordrdinate 43 of 176
#
# Cruising Coordrdinate 44 of 176
#
# Cruising Coordrdinate 45 of 176
#
# Cruising Coordrdinate 46 of 176
#
# Cruising Coordrdinate 47 of 176
#
# Cruising Coordrdinate 48 of 176
#
# Cruising Coordrdinate 49 of 176
#
# Cruising Coordrdinate 50 of 176
#
# Cruising Coordrdinate 51 of 176
#
# Cruising Coordrdinate 52 of 176
#
# Cruising Coordrdinate 53 of 176
#
# Cruising Coordrdinate 54 of 176
#
# Cruising Coordrdinate 55 of 176
#
# Cruising Coordrdinate 56 of 176
#
# Cruising Coordrdinate 57 of 176
#
# Cruising Coordrdinate 58 of 176
#
# Cruising Coordrdinate 59 of 176
#
# Cruising Coordrdinate 60 of 176
#
# Cruising Coordrdinate 61 of 176
#
# Cruising Coordrdinate 62 of 176
#
# Cruising Coordrdinate 63 of 176
#
# Cruising Coordrdinate 64 of 176
#
# Cruising Coordrdinate 65 of 176
#
# Cruising Coordrdinate 66 of 176
#
# Cruising Coordrdinate 67 of 176
#
# Cruising Coordrdinate 68 of 176
#
# Cruising Coordrdinate 69 of 176
#
# Cruising Coordrdinate 70 of 176
#
# Cruising Coordrdinate 71 of 176
#
# Cruising Coordrdinate 72 of 176
#
# Cruising Coordrdinate 73 of 176
#
# Cruising Coordrdinate 74 of 176
#
# Cruising Coordrdinate 75 of 176
#
# Cruising Coordrdinate 76 of 176
#
# Cruising Coordrdinate 77 of 176
#
# Cruising Coordrdinate 78 of 176
#
# Cruising Coordrdinate 79 of 176
#
# Cruising Coordrdinate 80 of 176
#
# Cruising Coordrdinate 81 of 176
#
# Cruising Coordrdinate 82 of 176
#
# Cruising Coordrdinate 83 of 176
#
# Cruising Coordrdinate 84 of 176
#
# Cruising Coordrdinate 85 of 176
#
# Cruising Coordrdinate 86 of 176
#
# Cruising Coordrdinate 87 of 176
#
# Cruising Coordrdinate 88 of 176
#
# Cruising Coordrdinate 89 of 176
#
# Cruising Coordrdinate 90 of 176
#
# Cruising Coordrdinate 91 of 176
#
# Cruising Coordrdinate 92 of 176
#
# Cruising Coordrdinate 93 of 176
#
# Cruising Coordrdinate 94 of 176
#
# Cruising Coordrdinate 95 of 176
#
# Cruising Coordrdinate 96 of 176
#
# Cruising Coordrdinate 97 of 176
#
# Cruising Coordrdinate 98 of 176
#
# Cruising Coordrdinate 99 of 176
#
# Cruising Coordrdinate 100 of 176
#
# Cruising Coordrdinate 101 of 176
#
# Cruising Coordrdinate 102 of 176
#
# Cruising Coordrdinate 103 of 176
#
# Cruising Coordrdinate 104 of 176
#
# Cruising Coordrdinate 105 of 176
#
# Cruising Coordrdinate 106 of 176
#
# Cruising Coordrdinate 107 of 176
#
# Cruising Coordrdinate 108 of 176
#
# Cruising Coordrdinate 109 of 176
#
# Cruising Coordrdinate 110 of 176
#
# Cruising Coordrdinate 111 of 176
#
# Cruising Coordrdinate 112 of 176
#
# Cruising Coordrdinate 113 of 176
#
# Cruising Coordrdinate 114 of 176
#
# Cruising Coordrdinate 115 of 176
#
# Cruising Coordrdinate 116 of 176
#
# Cruising Coordrdinate 117 of 176
#
# Cruising Coordrdinate 118 of 176
#
# Cruising Coordrdinate 119 of 176
#
# Cruising Coordrdinate 120 of 176
#
# Cruising Coordrdinate 121 of 176
#
# Cruising Coordrdinate 122 of 176
#
# Cruising Coordrdinate 123 of 176
#
# Cruising Coordrdinate 124 of 176
#
# Cruising Coordrdinate 125 of 176
#
# Cruising Coordrdinate 126 of 176
#
# Cruising Coordrdinate 127 of 176
#
# Cruising Coordrdinate 128 of 176
#
# Cruising Coordrdinate 129 of 176
#
# Cruising Coordrdinate 130 of 176
#
# Cruising Coordrdinate 131 of 176
#
# Cruising Coordrdinate 132 of 176
#
# Cruising Coordrdinate 133 of 176
#
# Cruising Coordrdinate 134 of 176
#
# Cruising Coordrdinate 135 of 176
#
# Cruising Coordrdinate 136 of 176
#
# Cruising Coordrdinate 137 of 176
#
# Cruising Coordrdinate 138 of 176
#
# Cruising Coordrdinate 139 of 176
#
# Cruising Coordrdinate 140 of 176
#
# Cruising Coordrdinate 141 of 176
#
# Cruising Coordrdinate 142 of 176
#
# Cruising Coordrdinate 143 of 176
#
# Cruising Coordrdinate 144 of 176
#
# Cruising Coordrdinate 145 of 176
#
# Cruising Coordrdinate 146 of 176
#
# Cruising Coordrdinate 147 of 176
#
# Cruising Coordrdinate 148 of 176
#
# Cruising Coordrdinate 149 of 176
#
# Cruising Coordrdinate 150 of 176
#
# Cruising Coordrdinate 151 of 176
#
# Cruising Coordrdinate 152 of 176
#
# Cruising Coordrdinate 153 of 176
#
# Cruising Coordrdinate 154 of 176
#
# Cruising Coordrdinate 155 of 176
#
# Cruising Coordrdinate 156 of 176
#
# Cruising Coordrdinate 157 of 176
#
# Cruising Coordrdinate 158 of 176
#
# Cruising Coordrdinate 159 of 176
#
# Cruising Coordrdinate 160 of 176
#
# Cruising Coordrdinate 161 of 176
#
# Cruising Coordrdinate 162 of 176
#
# Cruising Coordrdinate 163 of 176
#
# Cruising Coordrdinate 164 of 176
#
# Cruising Coordrdinate 165 of 176
#
# Cruising Coordrdinate 166 of 176
#
# Cruising Coordrdinate 167 of 176
#
# Cruising Coordrdinate 168 of 176
#
# Cruising Coordrdinate 169 of 176
#
# Cruising Coordrdinate 170 of 176
#
# Cruising Coordrdinate 171 of 176
#
# Cruising Coordrdinate 172 of 176
#
# Cruising Coordrdinate 173 of 176
#
# Cruising Coordrdinate 174 of 176
#
# Cruising Coordrdinate 175 of 176
#
# Cruising Coordrdinate 176 of 176
#
# FINAL STAGE: Begin final Guidance system
#
#
# Guidance: round FINAL
#
# 	round FINAL iteration:  0
#
# Already Trained and Tested combination (val score of 0.4446):
#             {'C': 0.001, 'tol': 0.1, 'max_iter': 400, 'gamma': 'auto', 'features': 21}
#             Current best combo (with val score 0.4605):
#                     {'C': 0.01, 'tol': 0.1, 'max_iter': 400, 'gamma': 'auto', 'features': 21}
#         Has trained 247 of 20736 combinations so far
# Already Trained and Tested combination (val score of 0.4384):
#             {'C': 0.1, 'tol': 0.1, 'max_iter': 400, 'gamma': 'auto', 'features': 21}
#             Current best combo (with val score 0.4605):
#                     {'C': 0.01, 'tol': 0.1, 'max_iter': 400, 'gamma': 'auto', 'features': 21}
#         Has trained 247 of 20736 combinations so far
# Already Trained and Tested combination (val score of 0.4605):
#             {'C': 0.01, 'tol': 0.01, 'max_iter': 400, 'gamma': 'auto', 'features': 21}
#             Current best combo (with val score 0.4605):
#                     {'C': 0.01, 'tol': 0.1, 'max_iter': 400, 'gamma': 'auto', 'features': 21}
#         Has trained 247 of 20736 combinations so far
# Already Trained and Tested combination (val score of 0.4605):
#             {'C': 0.01, 'tol': 1, 'max_iter': 400, 'gamma': 'auto', 'features': 21}
#             Current best combo (with val score 0.4605):
#                     {'C': 0.01, 'tol': 0.1, 'max_iter': 400, 'gamma': 'auto', 'features': 21}
#         Has trained 247 of 20736 combinations so far
# Already Trained and Tested combination (val score of 0.3535):
#             {'C': 0.01, 'tol': 0.1, 'max_iter': 200, 'gamma': 'auto', 'features': 21}
#             Current best combo (with val score 0.4605):
#                     {'C': 0.01, 'tol': 0.1, 'max_iter': 400, 'gamma': 'auto', 'features': 21}
#         Has trained 247 of 20736 combinations so far
# Already Trained and Tested combination (val score of 0.4288):
#             {'C': 0.01, 'tol': 0.1, 'max_iter': 800, 'gamma': 'auto', 'features': 21}
#             Current best combo (with val score 0.4605):
#                     {'C': 0.01, 'tol': 0.1, 'max_iter': 400, 'gamma': 'auto', 'features': 21}
#         Has trained 247 of 20736 combinations so far
# Already Trained and Tested combination (val score of 0.1411):
#             {'C': 0.01, 'tol': 0.1, 'max_iter': 400, 'gamma': 'scale', 'features': 21}
#             Current best combo (with val score 0.4605):
#                     {'C': 0.01, 'tol': 0.1, 'max_iter': 400, 'gamma': 'auto', 'features': 21}
#         Has trained 247 of 20736 combinations so far
# Already Trained and Tested combination (val score of 0.326):
#             {'C': 0.01, 'tol': 0.1, 'max_iter': 400, 'gamma': 'auto', 'features': 20}
#             Current best combo (with val score 0.4605):
#                     {'C': 0.01, 'tol': 0.1, 'max_iter': 400, 'gamma': 'auto', 'features': 21}
#         Has trained 247 of 20736 combinations so far
# Already Trained and Tested combination (val score of 0.419):
#             {'C': 0.01, 'tol': 0.1, 'max_iter': 400, 'gamma': 'auto', 'features': 22}
#             Current best combo (with val score 0.4605):
#                     {'C': 0.01, 'tol': 0.1, 'max_iter': 400, 'gamma': 'auto', 'features': 21}
#         Has trained 247 of 20736 combinations so far
# 	round FINAL iteration:  1
#
# Trained and Tested combination 248 of 20736, taking 0.23 seconds to get val score of 0.4446:
#                 {'C': 0.001, 'tol': 0.01, 'max_iter': 400, 'gamma': 'auto', 'features': 21},
#             Current best combo with val score 0.4605:
#                     {'C': 0.01, 'tol': 0.1, 'max_iter': 400, 'gamma': 'auto', 'features': 21}
# Already Trained and Tested combination (val score of 0.4384):
#             {'C': 0.1, 'tol': 0.01, 'max_iter': 400, 'gamma': 'auto', 'features': 21}
#             Current best combo (with val score 0.4605):
#                     {'C': 0.01, 'tol': 0.1, 'max_iter': 400, 'gamma': 'auto', 'features': 21}
#         Has trained 248 of 20736 combinations so far
# Trained and Tested combination 249 of 20736, taking 0.35 seconds to get val score of 0.4605:
#                 {'C': 0.01, 'tol': 0.001, 'max_iter': 400, 'gamma': 'auto', 'features': 21},
#             Current best combo with val score 0.4605:
#                     {'C': 0.01, 'tol': 0.1, 'max_iter': 400, 'gamma': 'auto', 'features': 21}
# Already Trained and Tested combination (val score of 0.4605):
#             {'C': 0.01, 'tol': 0.1, 'max_iter': 400, 'gamma': 'auto', 'features': 21}
#             Current best combo (with val score 0.4605):
#                     {'C': 0.01, 'tol': 0.1, 'max_iter': 400, 'gamma': 'auto', 'features': 21}
#         Has trained 249 of 20736 combinations so far
# Trained and Tested combination 250 of 20736, taking 0.11 seconds to get val score of 0.3535:
#                 {'C': 0.01, 'tol': 0.01, 'max_iter': 200, 'gamma': 'auto', 'features': 21},
#             Current best combo with val score 0.4605:
#                     {'C': 0.01, 'tol': 0.1, 'max_iter': 400, 'gamma': 'auto', 'features': 21}
# Trained and Tested combination 251 of 20736, taking 0.48 seconds to get val score of 0.4288:
#                 {'C': 0.01, 'tol': 0.01, 'max_iter': 800, 'gamma': 'auto', 'features': 21},
#             Current best combo with val score 0.4605:
#                     {'C': 0.01, 'tol': 0.1, 'max_iter': 400, 'gamma': 'auto', 'features': 21}
# Trained and Tested combination 252 of 20736, taking 0.22 seconds to get val score of 0.1411:
#                 {'C': 0.01, 'tol': 0.01, 'max_iter': 400, 'gamma': 'scale', 'features': 21},
#             Current best combo with val score 0.4605:
#                     {'C': 0.01, 'tol': 0.1, 'max_iter': 400, 'gamma': 'auto', 'features': 21}
# Trained and Tested combination 253 of 20736, taking 0.34 seconds to get val score of 0.326:
#                 {'C': 0.01, 'tol': 0.01, 'max_iter': 400, 'gamma': 'auto', 'features': 20},
#             Current best combo with val score 0.4605:
#                     {'C': 0.01, 'tol': 0.1, 'max_iter': 400, 'gamma': 'auto', 'features': 21}
# Trained and Tested combination 254 of 20736, taking 0.22 seconds to get val score of 0.419:
#                 {'C': 0.01, 'tol': 0.01, 'max_iter': 400, 'gamma': 'auto', 'features': 22},
#             Current best combo with val score 0.4605:
#                     {'C': 0.01, 'tol': 0.1, 'max_iter': 400, 'gamma': 'auto', 'features': 21}
# Trained and Tested combination 255 of 20736, taking 0.35 seconds to get val score of 0.4446:
#                 {'C': 0.001, 'tol': 1, 'max_iter': 400, 'gamma': 'auto', 'features': 21},
#             Current best combo with val score 0.4605:
#                     {'C': 0.01, 'tol': 0.1, 'max_iter': 400, 'gamma': 'auto', 'features': 21}
# Already Trained and Tested combination (val score of 0.4384):
#             {'C': 0.1, 'tol': 1, 'max_iter': 400, 'gamma': 'auto', 'features': 21}
#             Current best combo (with val score 0.4605):
#                     {'C': 0.01, 'tol': 0.1, 'max_iter': 400, 'gamma': 'auto', 'features': 21}
#         Has trained 255 of 20736 combinations so far
# Already Trained and Tested combination (val score of 0.4605):
#             {'C': 0.01, 'tol': 0.1, 'max_iter': 400, 'gamma': 'auto', 'features': 21}
#             Current best combo (with val score 0.4605):
#                     {'C': 0.01, 'tol': 0.1, 'max_iter': 400, 'gamma': 'auto', 'features': 21}
#         Has trained 255 of 20736 combinations so far
# Trained and Tested combination 256 of 20736, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 0.01, 'tol': 10, 'max_iter': 400, 'gamma': 'auto', 'features': 21},
#             Current best combo with val score 0.4605:
#                     {'C': 0.01, 'tol': 0.1, 'max_iter': 400, 'gamma': 'auto', 'features': 21}
# Trained and Tested combination 257 of 20736, taking 0.11 seconds to get val score of 0.3535:
#                 {'C': 0.01, 'tol': 1, 'max_iter': 200, 'gamma': 'auto', 'features': 21},
#             Current best combo with val score 0.4605:
#                     {'C': 0.01, 'tol': 0.1, 'max_iter': 400, 'gamma': 'auto', 'features': 21}
# Trained and Tested combination 258 of 20736, taking 0.48 seconds to get val score of 0.4288:
#                 {'C': 0.01, 'tol': 1, 'max_iter': 800, 'gamma': 'auto', 'features': 21},
#             Current best combo with val score 0.4605:
#                     {'C': 0.01, 'tol': 0.1, 'max_iter': 400, 'gamma': 'auto', 'features': 21}
# Trained and Tested combination 259 of 20736, taking 0.23 seconds to get val score of 0.1411:
#                 {'C': 0.01, 'tol': 1, 'max_iter': 400, 'gamma': 'scale', 'features': 21},
#             Current best combo with val score 0.4605:
#                     {'C': 0.01, 'tol': 0.1, 'max_iter': 400, 'gamma': 'auto', 'features': 21}
# Trained and Tested combination 260 of 20736, taking 0.34 seconds to get val score of 0.326:
#                 {'C': 0.01, 'tol': 1, 'max_iter': 400, 'gamma': 'auto', 'features': 20},
#             Current best combo with val score 0.4605:
#                     {'C': 0.01, 'tol': 0.1, 'max_iter': 400, 'gamma': 'auto', 'features': 21}
# Trained and Tested combination 261 of 20736, taking 0.22 seconds to get val score of 0.419:
#                 {'C': 0.01, 'tol': 1, 'max_iter': 400, 'gamma': 'auto', 'features': 22},
#             Current best combo with val score 0.4605:
#                     {'C': 0.01, 'tol': 0.1, 'max_iter': 400, 'gamma': 'auto', 'features': 21}
# % Combos Checked Thus Far: 261 out of 20736 which is 1.258681%
# Max Val Score:
#  0.460481
# Max Val Score Std:
#  0.049721
# Best Combo Train Score:
#  0.673744
# Best Combo Train Score Std:
#  0.00195
# Max Combo Index:
#  (2, 3, 3, 0, 21) out of [6, 6, 6, 2, 48] (note best combo is 0-indexed)
# Max Combo Hyperparamer Combination:
#  {'C': 0.01, 'tol': 0.1, 'max_iter': 400, 'gamma': 'auto', 'features': 21}
# Max Combo Features:
#  ('procedure_224274', 'lods_score', 'procedure_224276', 'procedure_224267', 'race_AMERICAN INDIAN/ALASKA NATIVE', 'race_ASIAN', 'race_ASIAN - ASIAN INDIAN', 'race_ASIAN - CHINESE', 'race_ASIAN - KOREAN', 'race_ASIAN - SOUTH EAST ASIAN', 'race_BLACK/AFRICAN', 'race_BLACK/AFRICAN AMERICAN', 'race_BLACK/CAPE VERDEAN', 'race_BLACK/CARIBBEAN ISLAND', 'race_HISPANIC OR LATINO', 'race_HISPANIC/LATINO - CENTRAL AMERICAN', 'race_HISPANIC/LATINO - COLUMBIAN', 'race_HISPANIC/LATINO - CUBAN', 'race_HISPANIC/LATINO - DOMINICAN', 'race_HISPANIC/LATINO - GUATEMALAN', 'race_HISPANIC/LATINO - HONDURAN', 'race_HISPANIC/LATINO - MEXICAN', 'race_HISPANIC/LATINO - PUERTO RICAN', 'race_HISPANIC/LATINO - SALVADORAN', 'race_MULTIPLE RACE/ETHNICITY', 'race_NATIVE HAWAIIAN OR OTHER PACIFIC ISLANDER', 'race_OTHER', 'race_PATIENT DECLINED TO ANSWER', 'race_PORTUGUESE', 'race_SOUTH AMERICAN', 'race_UNABLE TO OBTAIN', 'race_WHITE', 'race_WHITE - BRAZILIAN', 'race_WHITE - EASTERN EUROPEAN', 'race_WHITE - OTHER EUROPEAN', 'race_WHITE - RUSSIAN', 'race_UNKNOWN', 'procedure_227712', 'procedure_225430', 'gender_F', 'gender_M', 'oasis_score', 'procedure_225446', 'procedure_224275', 'procedure_225802', 'hospital_stay_duration', 'procedure_226475', 'ventilation_used', 'procedure_224270', 'procedure_227194', 'icu_stay_duration', 'procedure_225400', 'procedure_221223', 'procedure_225792', 'unique_drugs')
# % Combos Checked: 261 out of 20736 which is 1.258681%
