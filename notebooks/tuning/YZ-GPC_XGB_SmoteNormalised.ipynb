# %% [markdown]
# # Tuning Script

# %%
# Parameters subject to change in every script - involved in naming

MODEL = 'gpc'
PREPROCESSING = 'smote_normalise'
TUNER = 'yangzhoub'
OPTIMISED_METRIC = 'f1'

# %% [markdown]
# ---

# %%
# detect whether this is a google environment

COLAB_ENVIRONMENT = False

try:
    from google.colab import drive
    drive.mount('/content/drive')
    COLAB_ENVIRONMENT = True
except:
    pass
# Out:
# Mounted at /content/drive

# %%
import sys
import os
import pickle

if COLAB_ENVIRONMENT:
    home_directory = './drive/MyDrive/LAB/COMP90089__GroupWork__Py/' # my home directory is stored in ./LAB of google drive
    if MODEL == 'ebr':
        # !pip install interpret==0.5.0
    elif MODEL == 'cbr':
        # !pip install catboost
    elif MODEL in ['tf', 'mlp']:
        # !pip install PyTorch2Sklearn
    # !pip install JXAutoML
else:
    home_directory = '../../'

from JXAutoML.YangZhouB_10CV import YangZhouB_10CV as Tuner

import pandas as pd
# Out:
# Collecting JXAutoML
#   Downloading JXAutoML-0.4.4-py3-none-any.whl.metadata (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.2/67.2 kB 1.8 MB/s eta 0:00:00
# Downloading JXAutoML-0.4.4-py3-none-any.whl (52 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.1/52.1 kB 3.4 MB/s eta 0:00:00
# Installing collected packages: JXAutoML
# Successfully installed JXAutoML-0.4.4

# %%
# Parameters that are same for every script

FOLDS = 10  # we have decided to do 10 fold validation

SEED = 42

TASK_TYPE = 'Classification'  # this task is a classification task

# we have decided to tune features as hp
TUNE_FEATURES_AS_HYPERPARAMETERS = True

# %% [markdown]
# ---

# %%
# model to use to tune
from sklearn.gaussian_process import GaussianProcessClassifier as clf

# what values to try for each hyperparameter
parameter_choices = {
    'max_iter_predict': (25, 50, 100, 200, 400),
    'n_restarts_optimizer': list(range(0, 4))
}

# what values to set non-tuneable parameters/hyperparameters
non_tunable_hyperparameters_dict = {
                                    'random_state': 42,
                                    'multi_class': 'one_vs_rest',
                                    'n_jobs': -1
                                    }

# %% [markdown]
# ---

# %% [markdown]
# Read in and Prepare Data

# %%
# Import data and store as lists

train_x_list = []
train_y_list = []
val_x_list = []
val_y_list = []

for i in range(FOLDS):
    train_data = pd.read_csv(
        f'{home_directory}data/curated/modelling/{PREPROCESSING}/train_{i}.csv')
    val_data = pd.read_csv(
        f'{home_directory}data/curated/modelling/{PREPROCESSING}/val_{i}.csv')

    # get the correct rows for X and y
    train_x = train_data.drop(
        ['mortality_status', 'subject_id', 'hadm_id', 'stay_id'], axis=1)
    train_y = train_data['mortality_status']
    val_x = val_data.drop(
        ['mortality_status', 'subject_id', 'hadm_id', 'stay_id'], axis=1)
    val_y = val_data['mortality_status']

    train_x_list.append(train_x)
    train_y_list.append(train_y)
    val_x_list.append(val_x)
    val_y_list.append(val_y)

# %%
# Import feature importance ordering

with open(f'{home_directory}models/xgb_feature_importance_ordering_{PREPROCESSING}.pickle', 'rb') as f:
    feature_importance_ordering = pickle.load(f)

# %% [markdown]
# Set parameters

# %%
# initialisation
tuner = Tuner()

print('---')

# define what model we are tuning
tuner.read_in_model(clf, TASK_TYPE, optimised_metric=OPTIMISED_METRIC)

print('---')

# read in the data for training and validation
tuner.read_in_data(train_x_list, train_y_list, val_x_list, val_y_list)

print('---')

# set what hp values to tune
tuner.set_hyperparameters(parameter_choices)
# WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

# set up hp values that need to be changed from default but NOT to be tuned
tuner.set_non_tuneable_hyperparameters(non_tunable_hyperparameters_dict)

print('---')

# set up feature importance ordering

if TUNE_FEATURES_AS_HYPERPARAMETERS:
    tuner.set_features(feature_importance_ordering)
    # WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

try:  # try to read in previous results to continue tuning ...
    tuner.read_in_tuning_result_df(
        f'{home_directory}models/tuning/{TUNER}_{MODEL}_{PREPROCESSING}.csv')
except:
    print('No previous tuning data read in')

print('---')

# set up where to save the tuning result csv
tuner.set_tuning_result_saving_address(
    f'{home_directory}models/tuning/{TUNER}_{MODEL}_{PREPROCESSING}.csv')

print('---')

# set up where to save the current best model
tuner.set_best_model_saving_address(
    f'{home_directory}models/tmp_models/{TUNER}_{MODEL}_{PREPROCESSING}')
# Out:
# YangZhouB Initialised
# ---
# Successfully read in model <class 'sklearn.gaussian_process._gpc.GaussianProcessClassifier'>, which is a Classification model optimising for f1
# ---
# Read in Train X data list
# Read in Train y data list
# Read in Val X data list
# Read in Val y data list
# ---
# Successfully recorded hyperparameter choices
# ---
# Successfully recorded non_tuneable_hyperparameter choices
# ---
# Successfully recorded tuneable feature combination choices and updated relevant internal structures
# ---
# Successfully read in tuning result of 70 rows, for 70.0 combos
# ---
# Successfully set tuning output address
# ---
# Successfully set best model output address

# %%
# ignore warnings

import warnings
warnings.filterwarnings("ignore")

# %%
# begin tuning ... (or continue training)

tuner.tune()
# Out:
# BEGIN TUNING
#
#
# STAGE ZERO: Tune all Cruise combinations
#
#
# As new Best Combo (4, 3, 47) was read in, best_clf is set to None
# Already Trained and Tested combination (val score of 0.3118):
#             {'max_iter_predict': 400, 'n_restarts_optimizer': 3, 'features': 47}
#             Current best combo (with val score 0.3118):
#                     {'max_iter_predict': 400, 'n_restarts_optimizer': 3, 'features': 47}
#         Has trained 70 of 960 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 25}
#             Current best combo (with val score 0.3118):
#                     {'max_iter_predict': 400, 'n_restarts_optimizer': 3, 'features': 47}
#         Has trained 70 of 960 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 10}
#             Current best combo (with val score 0.3118):
#                     {'max_iter_predict': 400, 'n_restarts_optimizer': 3, 'features': 47}
#         Has trained 70 of 960 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'max_iter_predict': 400, 'n_restarts_optimizer': 3, 'features': 20}
#             Current best combo (with val score 0.3118):
#                     {'max_iter_predict': 400, 'n_restarts_optimizer': 3, 'features': 47}
#         Has trained 70 of 960 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 20}
#             Current best combo (with val score 0.3118):
#                     {'max_iter_predict': 400, 'n_restarts_optimizer': 3, 'features': 47}
#         Has trained 70 of 960 combinations so far
# As new Best Combo (0, 3, 39) was read in, best_clf is set to None
# Already Trained and Tested combination (val score of 0.3138):
#             {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 39}
#             Current best combo (with val score 0.3138):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 39}
#         Has trained 70 of 960 combinations so far
# Already Trained and Tested combination (val score of 0.3118):
#             {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 43}
#             Current best combo (with val score 0.3138):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 39}
#         Has trained 70 of 960 combinations so far
# Already Trained and Tested combination (val score of 0.3108):
#             {'max_iter_predict': 400, 'n_restarts_optimizer': 3, 'features': 0}
#             Current best combo (with val score 0.3138):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 39}
#         Has trained 70 of 960 combinations so far
# Already Trained and Tested combination (val score of 0.3138):
#             {'max_iter_predict': 400, 'n_restarts_optimizer': 3, 'features': 39}
#             Current best combo (with val score 0.3138):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 39}
#         Has trained 70 of 960 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 20}
#             Current best combo (with val score 0.3138):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 39}
#         Has trained 70 of 960 combinations so far
# Already Trained and Tested combination (val score of 0.3117):
#             {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 35}
#             Current best combo (with val score 0.3138):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 39}
#         Has trained 70 of 960 combinations so far
# Already Trained and Tested combination (val score of 0.3138):
#             {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 39}
#             Current best combo (with val score 0.3138):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 39}
#         Has trained 70 of 960 combinations so far
# Already Trained and Tested combination (val score of 0.3108):
#             {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 0}
#             Current best combo (with val score 0.3138):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 39}
#         Has trained 70 of 960 combinations so far
# Already Trained and Tested combination (val score of 0.3118):
#             {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 43}
#             Current best combo (with val score 0.3138):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 39}
#         Has trained 70 of 960 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'max_iter_predict': 400, 'n_restarts_optimizer': 3, 'features': 25}
#             Current best combo (with val score 0.3138):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 39}
#         Has trained 70 of 960 combinations so far
# Already Trained and Tested combination (val score of 0.3118):
#             {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 47}
#             Current best combo (with val score 0.3138):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 39}
#         Has trained 70 of 960 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 30}
#             Current best combo (with val score 0.3138):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 39}
#         Has trained 70 of 960 combinations so far
# Already Trained and Tested combination (val score of 0.0327):
#             {'max_iter_predict': 400, 'n_restarts_optimizer': 3, 'features': 5}
#             Current best combo (with val score 0.3138):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 39}
#         Has trained 70 of 960 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 10}
#             Current best combo (with val score 0.3138):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 39}
#         Has trained 70 of 960 combinations so far
# Already Trained and Tested combination (val score of 0.0327):
#             {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 5}
#             Current best combo (with val score 0.3138):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 39}
#         Has trained 70 of 960 combinations so far
# Already Trained and Tested combination (val score of 0.3117):
#             {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 35}
#             Current best combo (with val score 0.3138):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 39}
#         Has trained 70 of 960 combinations so far
# Already Trained and Tested combination (val score of 0.3118):
#             {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 43}
#             Current best combo (with val score 0.3138):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 39}
#         Has trained 70 of 960 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'max_iter_predict': 400, 'n_restarts_optimizer': 3, 'features': 10}
#             Current best combo (with val score 0.3138):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 39}
#         Has trained 70 of 960 combinations so far
# Already Trained and Tested combination (val score of 0.3118):
#             {'max_iter_predict': 400, 'n_restarts_optimizer': 3, 'features': 43}
#             Current best combo (with val score 0.3138):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 39}
#         Has trained 70 of 960 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 15}
#             Current best combo (with val score 0.3138):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 39}
#         Has trained 70 of 960 combinations so far
# Already Trained and Tested combination (val score of 0.3108):
#             {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 0}
#             Current best combo (with val score 0.3138):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 39}
#         Has trained 70 of 960 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 10}
#             Current best combo (with val score 0.3138):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 39}
#         Has trained 70 of 960 combinations so far
# Already Trained and Tested combination (val score of 0.3108):
#             {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 0}
#             Current best combo (with val score 0.3138):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 39}
#         Has trained 70 of 960 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 15}
#             Current best combo (with val score 0.3138):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 39}
#         Has trained 70 of 960 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 25}
#             Current best combo (with val score 0.3138):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 39}
#         Has trained 70 of 960 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 30}
#             Current best combo (with val score 0.3138):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 39}
#         Has trained 70 of 960 combinations so far
# Already Trained and Tested combination (val score of 0.3117):
#             {'max_iter_predict': 400, 'n_restarts_optimizer': 3, 'features': 35}
#             Current best combo (with val score 0.3138):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 39}
#         Has trained 70 of 960 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 15}
#             Current best combo (with val score 0.3138):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 39}
#         Has trained 70 of 960 combinations so far
# Already Trained and Tested combination (val score of 0.3138):
#             {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 39}
#             Current best combo (with val score 0.3138):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 39}
#         Has trained 70 of 960 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 20}
#             Current best combo (with val score 0.3138):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 39}
#         Has trained 70 of 960 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'max_iter_predict': 400, 'n_restarts_optimizer': 3, 'features': 30}
#             Current best combo (with val score 0.3138):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 39}
#         Has trained 70 of 960 combinations so far
# Already Trained and Tested combination (val score of 0.3117):
#             {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 35}
#             Current best combo (with val score 0.3138):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 39}
#         Has trained 70 of 960 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 30}
#             Current best combo (with val score 0.3138):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 39}
#         Has trained 70 of 960 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 25}
#             Current best combo (with val score 0.3138):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 39}
#         Has trained 70 of 960 combinations so far
# Already Trained and Tested combination (val score of 0.0327):
#             {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 5}
#             Current best combo (with val score 0.3138):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 39}
#         Has trained 70 of 960 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'max_iter_predict': 400, 'n_restarts_optimizer': 3, 'features': 15}
#             Current best combo (with val score 0.3138):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 39}
#         Has trained 70 of 960 combinations so far
# Already Trained and Tested combination (val score of 0.3118):
#             {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 47}
#             Current best combo (with val score 0.3138):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 39}
#         Has trained 70 of 960 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'max_iter_predict': 100, 'n_restarts_optimizer': 2, 'features': 24}
#             Current best combo (with val score 0.3138):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 39}
#         Has trained 70 of 960 combinations so far
# Already Trained and Tested combination (val score of 0.0327):
#             {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 5}
#             Current best combo (with val score 0.3138):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 39}
#         Has trained 70 of 960 combinations so far
# Already Trained and Tested combination (val score of 0.3118):
#             {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 47}
#             Current best combo (with val score 0.3138):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 39}
#         Has trained 70 of 960 combinations so far
#
#
# STAGE ONE: Begin initial Guidance system
#
#
# Guidance: initial round
#
# 	round 0 iteration:  0
#
# Already Trained and Tested combination (val score of 0.0):
#             {'max_iter_predict': 50, 'n_restarts_optimizer': 2, 'features': 24}
#             Current best combo (with val score 0.3138):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 39}
#         Has trained 70 of 960 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'max_iter_predict': 200, 'n_restarts_optimizer': 2, 'features': 24}
#             Current best combo (with val score 0.3138):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 39}
#         Has trained 70 of 960 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'max_iter_predict': 100, 'n_restarts_optimizer': 1, 'features': 24}
#             Current best combo (with val score 0.3138):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 39}
#         Has trained 70 of 960 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'max_iter_predict': 100, 'n_restarts_optimizer': 3, 'features': 24}
#             Current best combo (with val score 0.3138):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 39}
#         Has trained 70 of 960 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'max_iter_predict': 100, 'n_restarts_optimizer': 2, 'features': 23}
#             Current best combo (with val score 0.3138):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 39}
#         Has trained 70 of 960 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'max_iter_predict': 100, 'n_restarts_optimizer': 2, 'features': 25}
#             Current best combo (with val score 0.3138):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 39}
#         Has trained 70 of 960 combinations so far
# 	round 0 iteration:  1
#
# Already Trained and Tested combination (val score of 0.0):
#             {'max_iter_predict': 25, 'n_restarts_optimizer': 2, 'features': 24}
#             Current best combo (with val score 0.3138):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 39}
#         Has trained 70 of 960 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'max_iter_predict': 100, 'n_restarts_optimizer': 2, 'features': 24}
#             Current best combo (with val score 0.3138):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 39}
#         Has trained 70 of 960 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'max_iter_predict': 50, 'n_restarts_optimizer': 1, 'features': 24}
#             Current best combo (with val score 0.3138):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 39}
#         Has trained 70 of 960 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'max_iter_predict': 50, 'n_restarts_optimizer': 3, 'features': 24}
#             Current best combo (with val score 0.3138):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 39}
#         Has trained 70 of 960 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'max_iter_predict': 50, 'n_restarts_optimizer': 2, 'features': 23}
#             Current best combo (with val score 0.3138):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 39}
#         Has trained 70 of 960 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'max_iter_predict': 50, 'n_restarts_optimizer': 2, 'features': 25}
#             Current best combo (with val score 0.3138):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 39}
#         Has trained 70 of 960 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'max_iter_predict': 100, 'n_restarts_optimizer': 2, 'features': 24}
#             Current best combo (with val score 0.3138):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 39}
#         Has trained 70 of 960 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'max_iter_predict': 400, 'n_restarts_optimizer': 2, 'features': 24}
#             Current best combo (with val score 0.3138):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 39}
#         Has trained 70 of 960 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'max_iter_predict': 200, 'n_restarts_optimizer': 1, 'features': 24}
#             Current best combo (with val score 0.3138):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 39}
#         Has trained 70 of 960 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'max_iter_predict': 200, 'n_restarts_optimizer': 3, 'features': 24}
#             Current best combo (with val score 0.3138):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 39}
#         Has trained 70 of 960 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'max_iter_predict': 200, 'n_restarts_optimizer': 2, 'features': 23}
#             Current best combo (with val score 0.3138):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 39}
#         Has trained 70 of 960 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'max_iter_predict': 200, 'n_restarts_optimizer': 2, 'features': 25}
#             Current best combo (with val score 0.3138):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 39}
#         Has trained 70 of 960 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'max_iter_predict': 50, 'n_restarts_optimizer': 1, 'features': 24}
#             Current best combo (with val score 0.3138):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 39}
#         Has trained 70 of 960 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'max_iter_predict': 200, 'n_restarts_optimizer': 1, 'features': 24}
#             Current best combo (with val score 0.3138):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 39}
#         Has trained 70 of 960 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'max_iter_predict': 100, 'n_restarts_optimizer': 0, 'features': 24}
#             Current best combo (with val score 0.3138):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 39}
#         Has trained 70 of 960 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'max_iter_predict': 100, 'n_restarts_optimizer': 2, 'features': 24}
#             Current best combo (with val score 0.3138):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 39}
#         Has trained 70 of 960 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'max_iter_predict': 100, 'n_restarts_optimizer': 1, 'features': 23}
#             Current best combo (with val score 0.3138):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 39}
#         Has trained 70 of 960 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'max_iter_predict': 100, 'n_restarts_optimizer': 1, 'features': 25}
#             Current best combo (with val score 0.3138):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 39}
#         Has trained 70 of 960 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'max_iter_predict': 50, 'n_restarts_optimizer': 3, 'features': 24}
#             Current best combo (with val score 0.3138):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 39}
#         Has trained 70 of 960 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'max_iter_predict': 200, 'n_restarts_optimizer': 3, 'features': 24}
#             Current best combo (with val score 0.3138):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 39}
#         Has trained 70 of 960 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'max_iter_predict': 100, 'n_restarts_optimizer': 2, 'features': 24}
#             Current best combo (with val score 0.3138):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 39}
#         Has trained 70 of 960 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'max_iter_predict': 100, 'n_restarts_optimizer': 3, 'features': 23}
#             Current best combo (with val score 0.3138):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 39}
#         Has trained 70 of 960 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'max_iter_predict': 100, 'n_restarts_optimizer': 3, 'features': 25}
#             Current best combo (with val score 0.3138):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 39}
#         Has trained 70 of 960 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'max_iter_predict': 50, 'n_restarts_optimizer': 2, 'features': 23}
#             Current best combo (with val score 0.3138):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 39}
#         Has trained 70 of 960 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'max_iter_predict': 200, 'n_restarts_optimizer': 2, 'features': 23}
#             Current best combo (with val score 0.3138):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 39}
#         Has trained 70 of 960 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'max_iter_predict': 100, 'n_restarts_optimizer': 1, 'features': 23}
#             Current best combo (with val score 0.3138):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 39}
#         Has trained 70 of 960 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'max_iter_predict': 100, 'n_restarts_optimizer': 3, 'features': 23}
#             Current best combo (with val score 0.3138):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 39}
#         Has trained 70 of 960 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'max_iter_predict': 100, 'n_restarts_optimizer': 2, 'features': 22}
#             Current best combo (with val score 0.3138):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 39}
#         Has trained 70 of 960 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'max_iter_predict': 100, 'n_restarts_optimizer': 2, 'features': 24}
#             Current best combo (with val score 0.3138):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 39}
#         Has trained 70 of 960 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'max_iter_predict': 50, 'n_restarts_optimizer': 2, 'features': 25}
#             Current best combo (with val score 0.3138):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 39}
#         Has trained 70 of 960 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'max_iter_predict': 200, 'n_restarts_optimizer': 2, 'features': 25}
#             Current best combo (with val score 0.3138):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 39}
#         Has trained 70 of 960 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'max_iter_predict': 100, 'n_restarts_optimizer': 1, 'features': 25}
#             Current best combo (with val score 0.3138):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 39}
#         Has trained 70 of 960 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'max_iter_predict': 100, 'n_restarts_optimizer': 3, 'features': 25}
#             Current best combo (with val score 0.3138):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 39}
#         Has trained 70 of 960 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'max_iter_predict': 100, 'n_restarts_optimizer': 2, 'features': 24}
#             Current best combo (with val score 0.3138):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 39}
#         Has trained 70 of 960 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'max_iter_predict': 100, 'n_restarts_optimizer': 2, 'features': 26}
#             Current best combo (with val score 0.3138):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 39}
#         Has trained 70 of 960 combinations so far
# Already Trained and Tested combination (val score of 0.3138):
#             {'max_iter_predict': 50, 'n_restarts_optimizer': 3, 'features': 39}
#             Current best combo (with val score 0.3138):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 39}
#         Has trained 70 of 960 combinations so far
# Already Trained and Tested combination (val score of 0.3138):
#             {'max_iter_predict': 25, 'n_restarts_optimizer': 2, 'features': 39}
#             Current best combo (with val score 0.3138):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 39}
#         Has trained 70 of 960 combinations so far
# Trained and Tested combination 71 of 960, taking 42.55 seconds to get val score of 0.3125:
#                 {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 38},
#             Current best combo with val score 0.3138:
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 39}
# Trained and Tested combination 72 of 960, taking 43.17 seconds to get val score of 0.3138:
#                 {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 40},
#             Current best combo with val score 0.3138:
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 39}
# % Combos Checked Thus Far: 72 out of 960 which is 7.5%
# STAGE TWO: Begin Cruise system
#
#
# Cruising Coordrdinate 1 of 44
#
# Cruising Coordrdinate 2 of 44
#
# Cruising Coordrdinate 3 of 44
#
# Cruising Coordrdinate 4 of 44
#
# Cruising Coordrdinate 5 of 44
#
# Cruising Coordrdinate 6 of 44
#
# Cruising Coordrdinate 7 of 44
#
# Cruising Coordrdinate 8 of 44
#
# Cruising Coordrdinate 9 of 44
#
# Cruising Coordrdinate 10 of 44
#
# Cruising Coordrdinate 11 of 44
#
# Cruising Coordrdinate 12 of 44
#
# Cruising Coordrdinate 13 of 44
#
# Cruising Coordrdinate 14 of 44
#
# Cruising Coordrdinate 15 of 44
#
# Cruising Coordrdinate 16 of 44
#
# Cruising Coordrdinate 17 of 44
#
# Cruising Coordrdinate 18 of 44
#
# Cruising Coordrdinate 19 of 44
#
# Cruising Coordrdinate 20 of 44
#
# Cruising Coordrdinate 21 of 44
#
# Cruising Coordrdinate 22 of 44
#
# Cruising Coordrdinate 23 of 44
#
# Cruising Coordrdinate 24 of 44
#
# Cruising Coordrdinate 25 of 44
#
# Cruising Coordrdinate 26 of 44
#
# Cruising Coordrdinate 27 of 44
#
# Cruising Coordrdinate 28 of 44
#
# Cruising Coordrdinate 29 of 44
#
# Cruising Coordrdinate 30 of 44
#
# Cruising Coordrdinate 31 of 44
#
# Cruising Coordrdinate 32 of 44
#
# Cruising Coordrdinate 33 of 44
#
# Cruising Coordrdinate 34 of 44
#
# Cruising Coordrdinate 35 of 44
#
# Cruising Coordrdinate 36 of 44
#
# Cruising Coordrdinate 37 of 44
#
# Cruising Coordrdinate 38 of 44
#
# Cruising Coordrdinate 39 of 44
#
# Cruise suspended due to suspicious case
# Guidance: round 1
#
# 	round 1 iteration:  0
#
# Trained and Tested combination 73 of 960, taking 40.84 seconds to get val score of 0.3138:
#                 {'max_iter_predict': 200, 'n_restarts_optimizer': 0, 'features': 39},
#             Current best combo with val score 0.3138:
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 39}
# Trained and Tested combination 74 of 960, taking 40.87 seconds to get val score of 0.3138:
#                 {'max_iter_predict': 400, 'n_restarts_optimizer': 1, 'features': 39},
#             Current best combo with val score 0.3138:
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 39}
# Trained and Tested combination 75 of 960, taking 41.27 seconds to get val score of 0.3125:
#                 {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 38},
#             Current best combo with val score 0.3138:
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 39}
# Trained and Tested combination 76 of 960, taking 43.4 seconds to get val score of 0.3138:
#                 {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 40},
#             Current best combo with val score 0.3138:
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 39}
# 	round 1 iteration:  1
#
# Trained and Tested combination 77 of 960, taking 42.14 seconds to get val score of 0.3138:
#                 {'max_iter_predict': 100, 'n_restarts_optimizer': 0, 'features': 39},
#             Current best combo with val score 0.3138:
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 39}
# Already Trained and Tested combination (val score of 0.3138):
#             {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 39}
#             Current best combo (with val score 0.3138):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 39}
#         Has trained 77 of 960 combinations so far
# Trained and Tested combination 78 of 960, taking 41.17 seconds to get val score of 0.3138:
#                 {'max_iter_predict': 200, 'n_restarts_optimizer': 1, 'features': 39},
#             Current best combo with val score 0.3138:
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 39}
# Trained and Tested combination 79 of 960, taking 41.59 seconds to get val score of 0.3125:
#                 {'max_iter_predict': 200, 'n_restarts_optimizer': 0, 'features': 38},
#             Current best combo with val score 0.3138:
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 39}
# Trained and Tested combination 80 of 960, taking 42.46 seconds to get val score of 0.3138:
#                 {'max_iter_predict': 200, 'n_restarts_optimizer': 0, 'features': 40},
#             Current best combo with val score 0.3138:
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 39}
# Already Trained and Tested combination (val score of 0.3138):
#             {'max_iter_predict': 200, 'n_restarts_optimizer': 1, 'features': 39}
#             Current best combo (with val score 0.3138):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 39}
#         Has trained 80 of 960 combinations so far
# Already Trained and Tested combination (val score of 0.3138):
#             {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 39}
#             Current best combo (with val score 0.3138):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 39}
#         Has trained 80 of 960 combinations so far
# Trained and Tested combination 81 of 960, taking 40.88 seconds to get val score of 0.3138:
#                 {'max_iter_predict': 400, 'n_restarts_optimizer': 2, 'features': 39},
#             Current best combo with val score 0.3138:
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 39}
# Trained and Tested combination 82 of 960, taking 41.48 seconds to get val score of 0.3125:
#                 {'max_iter_predict': 400, 'n_restarts_optimizer': 1, 'features': 38},
#             Current best combo with val score 0.3138:
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 39}
# Trained and Tested combination 83 of 960, taking 41.49 seconds to get val score of 0.3138:
#                 {'max_iter_predict': 400, 'n_restarts_optimizer': 1, 'features': 40},
#             Current best combo with val score 0.3138:
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 39}
# Already Trained and Tested combination (val score of 0.3125):
#             {'max_iter_predict': 200, 'n_restarts_optimizer': 0, 'features': 38}
#             Current best combo (with val score 0.3138):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 39}
#         Has trained 83 of 960 combinations so far
# Already Trained and Tested combination (val score of 0.3125):
#             {'max_iter_predict': 400, 'n_restarts_optimizer': 1, 'features': 38}
#             Current best combo (with val score 0.3138):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 39}
#         Has trained 83 of 960 combinations so far
# Trained and Tested combination 84 of 960, taking 42.48 seconds to get val score of 0.3117:
#                 {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 37},
#             Current best combo with val score 0.3138:
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 39}
# Already Trained and Tested combination (val score of 0.3138):
#             {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 39}
#             Current best combo (with val score 0.3138):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 39}
#         Has trained 84 of 960 combinations so far
# Already Trained and Tested combination (val score of 0.3138):
#             {'max_iter_predict': 200, 'n_restarts_optimizer': 0, 'features': 40}
#             Current best combo (with val score 0.3138):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 39}
#         Has trained 84 of 960 combinations so far
# Already Trained and Tested combination (val score of 0.3138):
#             {'max_iter_predict': 400, 'n_restarts_optimizer': 1, 'features': 40}
#             Current best combo (with val score 0.3138):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 39}
#         Has trained 84 of 960 combinations so far
# Already Trained and Tested combination (val score of 0.3138):
#             {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 39}
#             Current best combo (with val score 0.3138):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 39}
#         Has trained 84 of 960 combinations so far
# Trained and Tested combination 85 of 960, taking 42.7 seconds to get val score of 0.2948:
#                 {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 41},
#             Current best combo with val score 0.3138:
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 39}
# % Combos Checked Thus Far: 85 out of 960 which is 8.854167%
# Cruising Coordrdinate 40 of 44
#
# Cruising Coordrdinate 41 of 44
#
# Cruising Coordrdinate 42 of 44
#
# Cruise suspended due to suspicious case
# Guidance: round 2
#
# 	round 2 iteration:  0
#
# Trained and Tested combination 86 of 960, taking 42.24 seconds to get val score of 0.3138:
#                 {'max_iter_predict': 200, 'n_restarts_optimizer': 3, 'features': 39},
#             Current best combo with val score 0.3138:
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 39}
# Already Trained and Tested combination (val score of 0.3138):
#             {'max_iter_predict': 400, 'n_restarts_optimizer': 2, 'features': 39}
#             Current best combo (with val score 0.3138):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 39}
#         Has trained 86 of 960 combinations so far
# Trained and Tested combination 87 of 960, taking 42.35 seconds to get val score of 0.3125:
#                 {'max_iter_predict': 400, 'n_restarts_optimizer': 3, 'features': 38},
#             Current best combo with val score 0.3138:
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 39}
# Trained and Tested combination 88 of 960, taking 42.28 seconds to get val score of 0.3138:
#                 {'max_iter_predict': 400, 'n_restarts_optimizer': 3, 'features': 40},
#             Current best combo with val score 0.3138:
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 39}
# 	round 2 iteration:  1
#
# Trained and Tested combination 89 of 960, taking 41.84 seconds to get val score of 0.3138:
#                 {'max_iter_predict': 100, 'n_restarts_optimizer': 3, 'features': 39},
#             Current best combo with val score 0.3138:
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 39}
# Already Trained and Tested combination (val score of 0.3138):
#             {'max_iter_predict': 400, 'n_restarts_optimizer': 3, 'features': 39}
#             Current best combo (with val score 0.3138):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 39}
#         Has trained 89 of 960 combinations so far
# Trained and Tested combination 90 of 960, taking 40.74 seconds to get val score of 0.3138:
#                 {'max_iter_predict': 200, 'n_restarts_optimizer': 2, 'features': 39},
#             Current best combo with val score 0.3138:
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 39}
# Trained and Tested combination 91 of 960, taking 40.22 seconds to get val score of 0.3125:
#                 {'max_iter_predict': 200, 'n_restarts_optimizer': 3, 'features': 38},
#             Current best combo with val score 0.3138:
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 39}
# Trained and Tested combination 92 of 960, taking 42.57 seconds to get val score of 0.3138:
#                 {'max_iter_predict': 200, 'n_restarts_optimizer': 3, 'features': 40},
#             Current best combo with val score 0.3138:
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 39}
# Already Trained and Tested combination (val score of 0.3125):
#             {'max_iter_predict': 200, 'n_restarts_optimizer': 3, 'features': 38}
#             Current best combo (with val score 0.3138):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 39}
#         Has trained 92 of 960 combinations so far
# Trained and Tested combination 93 of 960, taking 42.49 seconds to get val score of 0.3125:
#                 {'max_iter_predict': 400, 'n_restarts_optimizer': 2, 'features': 38},
#             Current best combo with val score 0.3138:
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 39}
# Trained and Tested combination 94 of 960, taking 42.22 seconds to get val score of 0.3117:
#                 {'max_iter_predict': 400, 'n_restarts_optimizer': 3, 'features': 37},
#             Current best combo with val score 0.3138:
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 39}
# Already Trained and Tested combination (val score of 0.3138):
#             {'max_iter_predict': 400, 'n_restarts_optimizer': 3, 'features': 39}
#             Current best combo (with val score 0.3138):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 39}
#         Has trained 94 of 960 combinations so far
# Already Trained and Tested combination (val score of 0.3138):
#             {'max_iter_predict': 200, 'n_restarts_optimizer': 3, 'features': 40}
#             Current best combo (with val score 0.3138):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 39}
#         Has trained 94 of 960 combinations so far
# Trained and Tested combination 95 of 960, taking 41.82 seconds to get val score of 0.3138:
#                 {'max_iter_predict': 400, 'n_restarts_optimizer': 2, 'features': 40},
#             Current best combo with val score 0.3138:
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 39}
# Already Trained and Tested combination (val score of 0.3138):
#             {'max_iter_predict': 400, 'n_restarts_optimizer': 3, 'features': 39}
#             Current best combo (with val score 0.3138):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 39}
#         Has trained 95 of 960 combinations so far
# Trained and Tested combination 96 of 960, taking 42.5 seconds to get val score of 0.2948:
#                 {'max_iter_predict': 400, 'n_restarts_optimizer': 3, 'features': 41},
#             Current best combo with val score 0.3138:
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 39}
# % Combos Checked Thus Far: 96 out of 960 which is 10.0%
# Cruising Coordrdinate 43 of 44
#
# Cruise suspended due to suspicious case
# Guidance: round 3
#
# 	round 3 iteration:  0
#
# Trained and Tested combination 97 of 960, taking 42.21 seconds to get val score of 0.3138:
#                 {'max_iter_predict': 50, 'n_restarts_optimizer': 0, 'features': 39},
#             Current best combo with val score 0.3138:
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 39}
# Trained and Tested combination 98 of 960, taking 41.31 seconds to get val score of 0.3138:
#                 {'max_iter_predict': 25, 'n_restarts_optimizer': 1, 'features': 39},
#             Current best combo with val score 0.3138:
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 39}
# Trained and Tested combination 99 of 960, taking 42.29 seconds to get val score of 0.3125:
#                 {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 38},
#             Current best combo with val score 0.3138:
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 39}
# Trained and Tested combination 100 of 960, taking 42.71 seconds to get val score of 0.3138:
#                 {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 40},
#             Current best combo with val score 0.3138:
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 39}
# 	round 3 iteration:  1
#
# Already Trained and Tested combination (val score of 0.3138):
#             {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 39}
#             Current best combo (with val score 0.3138):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 39}
#         Has trained 100 of 960 combinations so far
# Already Trained and Tested combination (val score of 0.3138):
#             {'max_iter_predict': 100, 'n_restarts_optimizer': 0, 'features': 39}
#             Current best combo (with val score 0.3138):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 39}
#         Has trained 100 of 960 combinations so far
# Trained and Tested combination 101 of 960, taking 41.08 seconds to get val score of 0.3138:
#                 {'max_iter_predict': 50, 'n_restarts_optimizer': 1, 'features': 39},
#             Current best combo with val score 0.3138:
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 39}
# Trained and Tested combination 102 of 960, taking 41.23 seconds to get val score of 0.3125:
#                 {'max_iter_predict': 50, 'n_restarts_optimizer': 0, 'features': 38},
#             Current best combo with val score 0.3138:
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 39}
# Trained and Tested combination 103 of 960, taking 39.09 seconds to get val score of 0.3138:
#                 {'max_iter_predict': 50, 'n_restarts_optimizer': 0, 'features': 40},
#             Current best combo with val score 0.3138:
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 39}
# Already Trained and Tested combination (val score of 0.3138):
#             {'max_iter_predict': 50, 'n_restarts_optimizer': 1, 'features': 39}
#             Current best combo (with val score 0.3138):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 39}
#         Has trained 103 of 960 combinations so far
# Already Trained and Tested combination (val score of 0.3138):
#             {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 39}
#             Current best combo (with val score 0.3138):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 39}
#         Has trained 103 of 960 combinations so far
# Already Trained and Tested combination (val score of 0.3138):
#             {'max_iter_predict': 25, 'n_restarts_optimizer': 2, 'features': 39}
#             Current best combo (with val score 0.3138):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 39}
#         Has trained 103 of 960 combinations so far
# Trained and Tested combination 104 of 960, taking 38.32 seconds to get val score of 0.3125:
#                 {'max_iter_predict': 25, 'n_restarts_optimizer': 1, 'features': 38},
#             Current best combo with val score 0.3138:
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 39}
# Trained and Tested combination 105 of 960, taking 40.71 seconds to get val score of 0.3138:
#                 {'max_iter_predict': 25, 'n_restarts_optimizer': 1, 'features': 40},
#             Current best combo with val score 0.3138:
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 39}
# Already Trained and Tested combination (val score of 0.3125):
#             {'max_iter_predict': 50, 'n_restarts_optimizer': 0, 'features': 38}
#             Current best combo (with val score 0.3138):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 39}
#         Has trained 105 of 960 combinations so far
# Already Trained and Tested combination (val score of 0.3125):
#             {'max_iter_predict': 25, 'n_restarts_optimizer': 1, 'features': 38}
#             Current best combo (with val score 0.3138):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 39}
#         Has trained 105 of 960 combinations so far
# Trained and Tested combination 106 of 960, taking 39.95 seconds to get val score of 0.3117:
#                 {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 37},
#             Current best combo with val score 0.3138:
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 39}
# Already Trained and Tested combination (val score of 0.3138):
#             {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 39}
#             Current best combo (with val score 0.3138):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 39}
#         Has trained 106 of 960 combinations so far
# Already Trained and Tested combination (val score of 0.3138):
#             {'max_iter_predict': 50, 'n_restarts_optimizer': 0, 'features': 40}
#             Current best combo (with val score 0.3138):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 39}
#         Has trained 106 of 960 combinations so far
# Already Trained and Tested combination (val score of 0.3138):
#             {'max_iter_predict': 25, 'n_restarts_optimizer': 1, 'features': 40}
#             Current best combo (with val score 0.3138):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 39}
#         Has trained 106 of 960 combinations so far
# Already Trained and Tested combination (val score of 0.3138):
#             {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 39}
#             Current best combo (with val score 0.3138):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 39}
#         Has trained 106 of 960 combinations so far
# Trained and Tested combination 107 of 960, taking 39.66 seconds to get val score of 0.2948:
#                 {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 41},
#             Current best combo with val score 0.3138:
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 39}
# % Combos Checked Thus Far: 107 out of 960 which is 11.145833%
# Cruising Coordrdinate 44 of 44
#
# Cruise suspended due to suspicious case
# Guidance: round 4
#
# 	round 4 iteration:  0
#
# Already Trained and Tested combination (val score of 0.3138):
#             {'max_iter_predict': 50, 'n_restarts_optimizer': 3, 'features': 39}
#             Current best combo (with val score 0.3138):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 39}
#         Has trained 107 of 960 combinations so far
# Already Trained and Tested combination (val score of 0.3138):
#             {'max_iter_predict': 25, 'n_restarts_optimizer': 2, 'features': 39}
#             Current best combo (with val score 0.3138):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 39}
#         Has trained 107 of 960 combinations so far
# Already Trained and Tested combination (val score of 0.3125):
#             {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 38}
#             Current best combo (with val score 0.3138):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 39}
#         Has trained 107 of 960 combinations so far
# Already Trained and Tested combination (val score of 0.3138):
#             {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 40}
#             Current best combo (with val score 0.3138):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 39}
#         Has trained 107 of 960 combinations so far
# 	round 4 iteration:  1
#
# Already Trained and Tested combination (val score of 0.3138):
#             {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 39}
#             Current best combo (with val score 0.3138):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 39}
#         Has trained 107 of 960 combinations so far
# Already Trained and Tested combination (val score of 0.3138):
#             {'max_iter_predict': 100, 'n_restarts_optimizer': 3, 'features': 39}
#             Current best combo (with val score 0.3138):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 39}
#         Has trained 107 of 960 combinations so far
# Trained and Tested combination 108 of 960, taking 49.49 seconds to get val score of 0.3138:
#                 {'max_iter_predict': 50, 'n_restarts_optimizer': 2, 'features': 39},
#             Current best combo with val score 0.3138:
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 39}
# Trained and Tested combination 109 of 960, taking 40.28 seconds to get val score of 0.3125:
#                 {'max_iter_predict': 50, 'n_restarts_optimizer': 3, 'features': 38},
#             Current best combo with val score 0.3138:
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 39}
# Trained and Tested combination 110 of 960, taking 41.85 seconds to get val score of 0.3138:
#                 {'max_iter_predict': 50, 'n_restarts_optimizer': 3, 'features': 40},
#             Current best combo with val score 0.3138:
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 39}
# Already Trained and Tested combination (val score of 0.3125):
#             {'max_iter_predict': 50, 'n_restarts_optimizer': 3, 'features': 38}
#             Current best combo (with val score 0.3138):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 39}
#         Has trained 110 of 960 combinations so far
# Trained and Tested combination 111 of 960, taking 39.31 seconds to get val score of 0.3125:
#                 {'max_iter_predict': 25, 'n_restarts_optimizer': 2, 'features': 38},
#             Current best combo with val score 0.3138:
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 39}
# Trained and Tested combination 112 of 960, taking 41.59 seconds to get val score of 0.3117:
#                 {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 37},
#             Current best combo with val score 0.3138:
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 39}
# Already Trained and Tested combination (val score of 0.3138):
#             {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 39}
#             Current best combo (with val score 0.3138):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 39}
#         Has trained 112 of 960 combinations so far
# Already Trained and Tested combination (val score of 0.3138):
#             {'max_iter_predict': 50, 'n_restarts_optimizer': 3, 'features': 40}
#             Current best combo (with val score 0.3138):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 39}
#         Has trained 112 of 960 combinations so far
# Trained and Tested combination 113 of 960, taking 41.76 seconds to get val score of 0.3138:
#                 {'max_iter_predict': 25, 'n_restarts_optimizer': 2, 'features': 40},
#             Current best combo with val score 0.3138:
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 39}
# Already Trained and Tested combination (val score of 0.3138):
#             {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 39}
#             Current best combo (with val score 0.3138):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 39}
#         Has trained 113 of 960 combinations so far
# Trained and Tested combination 114 of 960, taking 41.47 seconds to get val score of 0.2948:
#                 {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 41},
#             Current best combo with val score 0.3138:
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 39}
# % Combos Checked Thus Far: 114 out of 960 which is 11.875%
# FINAL STAGE: Begin final Guidance system
#
#
# Guidance: round FINAL
#
# 	round FINAL iteration:  0
#
# % Combos Checked Thus Far: 114 out of 960 which is 11.875%
# Max Val Score:
#  0.313838
# Max Val Score Std:
#  0.006634
# Best Combo Train Score:
#  0.998996
# Best Combo Train Score Std:
#  0.000358
# Max Combo Index:
#  (0, 3, 39) out of [5, 4, 48] (note best combo is 0-indexed)
# Max Combo Hyperparamer Combination:
#  {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 39}
# Max Combo Features:
#  ('procedure_224274', 'lods_score', 'procedure_224276', 'procedure_224267', 'race_AMERICAN INDIAN/ALASKA NATIVE', 'race_ASIAN', 'race_ASIAN - ASIAN INDIAN', 'race_ASIAN - CHINESE', 'race_ASIAN - KOREAN', 'race_ASIAN - SOUTH EAST ASIAN', 'race_BLACK/AFRICAN', 'race_BLACK/AFRICAN AMERICAN', 'race_BLACK/CAPE VERDEAN', 'race_BLACK/CARIBBEAN ISLAND', 'race_HISPANIC OR LATINO', 'race_HISPANIC/LATINO - CENTRAL AMERICAN', 'race_HISPANIC/LATINO - COLUMBIAN', 'race_HISPANIC/LATINO - CUBAN', 'race_HISPANIC/LATINO - DOMINICAN', 'race_HISPANIC/LATINO - GUATEMALAN', 'race_HISPANIC/LATINO - HONDURAN', 'race_HISPANIC/LATINO - MEXICAN', 'race_HISPANIC/LATINO - PUERTO RICAN', 'race_HISPANIC/LATINO - SALVADORAN', 'race_MULTIPLE RACE/ETHNICITY', 'race_NATIVE HAWAIIAN OR OTHER PACIFIC ISLANDER', 'race_OTHER', 'race_PATIENT DECLINED TO ANSWER', 'race_PORTUGUESE', 'race_SOUTH AMERICAN', 'race_UNABLE TO OBTAIN', 'race_WHITE', 'race_WHITE - BRAZILIAN', 'race_WHITE - EASTERN EUROPEAN', 'race_WHITE - OTHER EUROPEAN', 'race_WHITE - RUSSIAN', 'race_UNKNOWN', 'procedure_227712', 'procedure_225430', 'gender_F', 'gender_M', 'oasis_score', 'procedure_225446', 'procedure_224275', 'procedure_225802', 'hospital_stay_duration', 'procedure_226475', 'ventilation_used', 'procedure_224270', 'procedure_227194', 'icu_stay_duration', 'procedure_225400', 'procedure_221223', 'procedure_225792', 'unique_drugs', 'procedure_229351', 'glucose', 'item_51301', 'procedure_226236', 'potassium', 'pt', 'resp_rate', 'creatinine', 'anchor_age', 'procedure_226124', 'systolic_bp', 'item_51222', 'spo2', 'procedure_224385', 'procedure_225752', 'procedure_224263', 'heart_rate', 'bun')
# % Combos Checked: 114 out of 960 which is 11.875%
