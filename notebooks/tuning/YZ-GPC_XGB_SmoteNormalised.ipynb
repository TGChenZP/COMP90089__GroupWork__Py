# %% [markdown]
# # Tuning Script

# %%
# Parameters subject to change in every script - involved in naming

MODEL = 'gpc'
PREPROCESSING = 'smote_normalise'
TUNER = 'yangzhoub'
OPTIMISED_METRIC = 'f1'

# %% [markdown]
# ---

# %%
# detect whether this is a google environment

COLAB_ENVIRONMENT = False

try:
    from google.colab import drive
    drive.mount('/content/drive')
    COLAB_ENVIRONMENT = True
except:
    pass
# Out:
# Mounted at /content/drive

# %%
import sys
import os
import pickle

if COLAB_ENVIRONMENT:
    home_directory = './drive/MyDrive/LAB/COMP90089__GroupWork__Py/' # my home directory is stored in ./LAB of google drive
    if MODEL == 'ebr':
        # !pip install interpret==0.5.0
    elif MODEL == 'cbr':
        # !pip install catboost
    elif MODEL in ['tf', 'mlp']:
        # !pip install PyTorch2Sklearn
    # !pip install JXAutoML
else:
    home_directory = '../../'

from JXAutoML.YangZhouB_10CV import YangZhouB_10CV as Tuner

import pandas as pd
# Out:
# Collecting JXAutoML
#   Downloading JXAutoML-0.4.4-py3-none-any.whl.metadata (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.2/67.2 kB 1.9 MB/s eta 0:00:00
# Downloading JXAutoML-0.4.4-py3-none-any.whl (52 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.1/52.1 kB 3.7 MB/s eta 0:00:00
# Installing collected packages: JXAutoML
# Successfully installed JXAutoML-0.4.4

# %%
# Parameters that are same for every script

FOLDS = 10  # we have decided to do 10 fold validation

SEED = 42

TASK_TYPE = 'Classification'  # this task is a classification task

# we have decided to tune features as hp
TUNE_FEATURES_AS_HYPERPARAMETERS = True

# %% [markdown]
# ---

# %%
# model to use to tune
from sklearn.gaussian_process import GaussianProcessClassifier as clf

# what values to try for each hyperparameter
parameter_choices = {
    'max_iter_predict': (25, 50, 100, 200, 400),
    'n_restarts_optimizer': list(range(0, 4))
}

# what values to set non-tuneable parameters/hyperparameters
non_tunable_hyperparameters_dict = {
                                    'random_state': 42,
                                    'multi_class': 'one_vs_rest',
                                    'n_jobs': -1
                                    }

# %% [markdown]
# ---

# %% [markdown]
# Read in and Prepare Data

# %%
# Import data and store as lists

train_x_list = []
train_y_list = []
val_x_list = []
val_y_list = []

for i in range(FOLDS):
    train_data = pd.read_csv(
        f'{home_directory}data/curated/modelling/{PREPROCESSING}/train_{i}.csv')
    val_data = pd.read_csv(
        f'{home_directory}data/curated/modelling/{PREPROCESSING}/val_{i}.csv')

    # get the correct rows for X and y
    train_x = train_data.drop(
        ['mortality_status', 'subject_id', 'hadm_id', 'stay_id'], axis=1)
    train_y = train_data['mortality_status']
    val_x = val_data.drop(
        ['mortality_status', 'subject_id', 'hadm_id', 'stay_id'], axis=1)
    val_y = val_data['mortality_status']

    train_x_list.append(train_x)
    train_y_list.append(train_y)
    val_x_list.append(val_x)
    val_y_list.append(val_y)

# %%
# Import feature importance ordering

with open(f'{home_directory}models/xgb_feature_importance_ordering_{PREPROCESSING}.pickle', 'rb') as f:
    feature_importance_ordering = pickle.load(f)

# %% [markdown]
# Set parameters

# %%
# initialisation
tuner = Tuner()

print('---')

# define what model we are tuning
tuner.read_in_model(clf, TASK_TYPE, optimised_metric=OPTIMISED_METRIC)

print('---')

# read in the data for training and validation
tuner.read_in_data(train_x_list, train_y_list, val_x_list, val_y_list)

print('---')

# set what hp values to tune
tuner.set_hyperparameters(parameter_choices)
# WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

# set up hp values that need to be changed from default but NOT to be tuned
tuner.set_non_tuneable_hyperparameters(non_tunable_hyperparameters_dict)

print('---')

# set up feature importance ordering

if TUNE_FEATURES_AS_HYPERPARAMETERS:
    tuner.set_features(feature_importance_ordering)
    # WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

try:  # try to read in previous results to continue tuning ...
    tuner.read_in_tuning_result_df(
        f'{home_directory}models/tuning/{TUNER}_{MODEL}_{PREPROCESSING}.csv')
except:
    print('No previous tuning data read in')

print('---')

# set up where to save the tuning result csv
tuner.set_tuning_result_saving_address(
    f'{home_directory}models/tuning/{TUNER}_{MODEL}_{PREPROCESSING}.csv')

print('---')

# set up where to save the current best model
tuner.set_best_model_saving_address(
    f'{home_directory}models/tmp_models/{TUNER}_{MODEL}_{PREPROCESSING}')
# Out:
# YangZhouB Initialised
# ---
# Successfully read in model <class 'sklearn.gaussian_process._gpc.GaussianProcessClassifier'>, which is a Classification model optimising for f1
# ---
# Read in Train X data list
# Read in Train y data list
# Read in Val X data list
# Read in Val y data list
# ---
# Successfully recorded hyperparameter choices
# ---
# Successfully recorded non_tuneable_hyperparameter choices
# ---
# Successfully recorded tuneable feature combination choices and updated relevant internal structures
# ---
# Successfully read in tuning result of 423 rows, for 423.0 combos
# ---
# Successfully set tuning output address
# ---
# Successfully set best model output address

# %%
# ignore warnings

import warnings
warnings.filterwarnings("ignore")

# %%
# begin tuning ... (or continue training)

tuner.tune()
# Out:
# Streaming output truncated to the last 5000 lines.
#             Current best combo (with val score 0.3086):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 30}
#         Has trained 493 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 50}
#             Current best combo (with val score 0.3086):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 30}
#         Has trained 493 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.1995):
#             {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 10}
#             Current best combo (with val score 0.3086):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 30}
#         Has trained 493 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 55}
#             Current best combo (with val score 0.3086):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 30}
#         Has trained 493 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.0067):
#             {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 25}
#             Current best combo (with val score 0.3086):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 30}
#         Has trained 493 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3077):
#             {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 45}
#             Current best combo (with val score 0.3086):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 30}
#         Has trained 493 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 400, 'n_restarts_optimizer': 3, 'features': 35}
#             Current best combo (with val score 0.3086):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 30}
#         Has trained 493 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 400, 'n_restarts_optimizer': 3, 'features': 55}
#             Current best combo (with val score 0.3086):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 30}
#         Has trained 493 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 67}
#             Current best combo (with val score 0.3086):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 30}
#         Has trained 493 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.1995):
#             {'max_iter_predict': 400, 'n_restarts_optimizer': 3, 'features': 10}
#             Current best combo (with val score 0.3086):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 30}
#         Has trained 493 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 20}
#             Current best combo (with val score 0.3086):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 30}
#         Has trained 493 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 400, 'n_restarts_optimizer': 3, 'features': 59}
#             Current best combo (with val score 0.3086):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 30}
#         Has trained 493 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 400, 'n_restarts_optimizer': 3, 'features': 71}
#             Current best combo (with val score 0.3086):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 30}
#         Has trained 493 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.2305):
#             {'max_iter_predict': 400, 'n_restarts_optimizer': 3, 'features': 15}
#             Current best combo (with val score 0.3086):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 30}
#         Has trained 493 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'max_iter_predict': 400, 'n_restarts_optimizer': 3, 'features': 20}
#             Current best combo (with val score 0.3086):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 30}
#         Has trained 493 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 50}
#             Current best combo (with val score 0.3086):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 30}
#         Has trained 493 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.1995):
#             {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 10}
#             Current best combo (with val score 0.3086):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 30}
#         Has trained 493 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 63}
#             Current best combo (with val score 0.3086):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 30}
#         Has trained 493 of 1440 combinations so far
# As new Best Combo (0, 3, 0) was read in, best_clf is set to None
# Already Trained and Tested combination (val score of 0.3244):
#             {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 0}
#             Current best combo (with val score 0.3244):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 0}
#         Has trained 493 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3244):
#             {'max_iter_predict': 400, 'n_restarts_optimizer': 3, 'features': 0}
#             Current best combo (with val score 0.3244):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 0}
#         Has trained 493 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 59}
#             Current best combo (with val score 0.3244):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 0}
#         Has trained 493 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 20}
#             Current best combo (with val score 0.3244):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 0}
#         Has trained 493 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.2305):
#             {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 15}
#             Current best combo (with val score 0.3244):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 0}
#         Has trained 493 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 71}
#             Current best combo (with val score 0.3244):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 0}
#         Has trained 493 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 55}
#             Current best combo (with val score 0.3244):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 0}
#         Has trained 493 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 40}
#             Current best combo (with val score 0.3244):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 0}
#         Has trained 493 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 400, 'n_restarts_optimizer': 3, 'features': 67}
#             Current best combo (with val score 0.3244):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 0}
#         Has trained 493 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 67}
#             Current best combo (with val score 0.3244):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 0}
#         Has trained 493 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.1995):
#             {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 10}
#             Current best combo (with val score 0.3244):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 0}
#         Has trained 493 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 30}
#             Current best combo (with val score 0.3244):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 0}
#         Has trained 493 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3244):
#             {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 0}
#             Current best combo (with val score 0.3244):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 0}
#         Has trained 493 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.0067):
#             {'max_iter_predict': 400, 'n_restarts_optimizer': 3, 'features': 25}
#             Current best combo (with val score 0.3244):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 0}
#         Has trained 493 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 35}
#             Current best combo (with val score 0.3244):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 0}
#         Has trained 493 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 400, 'n_restarts_optimizer': 3, 'features': 40}
#             Current best combo (with val score 0.3244):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 0}
#         Has trained 493 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.0647):
#             {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 5}
#             Current best combo (with val score 0.3244):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 0}
#         Has trained 493 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 59}
#             Current best combo (with val score 0.3244):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 0}
#         Has trained 493 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 400, 'n_restarts_optimizer': 3, 'features': 30}
#             Current best combo (with val score 0.3244):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 0}
#         Has trained 493 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.2305):
#             {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 15}
#             Current best combo (with val score 0.3244):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 0}
#         Has trained 493 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 67}
#             Current best combo (with val score 0.3244):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 0}
#         Has trained 493 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 71}
#             Current best combo (with val score 0.3244):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 0}
#         Has trained 493 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 63}
#             Current best combo (with val score 0.3244):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 0}
#         Has trained 493 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 400, 'n_restarts_optimizer': 3, 'features': 50}
#             Current best combo (with val score 0.3244):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 0}
#         Has trained 493 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 35}
#             Current best combo (with val score 0.3244):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 0}
#         Has trained 493 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 40}
#             Current best combo (with val score 0.3244):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 0}
#         Has trained 493 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 59}
#             Current best combo (with val score 0.3244):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 0}
#         Has trained 493 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.0067):
#             {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 25}
#             Current best combo (with val score 0.3244):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 0}
#         Has trained 493 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.0647):
#             {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 5}
#             Current best combo (with val score 0.3244):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 0}
#         Has trained 493 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3077):
#             {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 45}
#             Current best combo (with val score 0.3244):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 0}
#         Has trained 493 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 20}
#             Current best combo (with val score 0.3244):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 0}
#         Has trained 493 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.0067):
#             {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 25}
#             Current best combo (with val score 0.3244):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 0}
#         Has trained 493 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3244):
#             {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 0}
#             Current best combo (with val score 0.3244):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 0}
#         Has trained 493 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 71}
#             Current best combo (with val score 0.3244):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 0}
#         Has trained 493 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 100, 'n_restarts_optimizer': 2, 'features': 36}
#             Current best combo (with val score 0.3244):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 0}
#         Has trained 493 of 1440 combinations so far
#
#
# STAGE ONE: Begin initial Guidance system
#
#
# Guidance: initial round
#
# 	round 0 iteration:  0
#
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 50, 'n_restarts_optimizer': 2, 'features': 36}
#             Current best combo (with val score 0.3244):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 0}
#         Has trained 493 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 200, 'n_restarts_optimizer': 2, 'features': 36}
#             Current best combo (with val score 0.3244):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 0}
#         Has trained 493 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 100, 'n_restarts_optimizer': 1, 'features': 36}
#             Current best combo (with val score 0.3244):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 0}
#         Has trained 493 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 100, 'n_restarts_optimizer': 3, 'features': 36}
#             Current best combo (with val score 0.3244):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 0}
#         Has trained 493 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 100, 'n_restarts_optimizer': 2, 'features': 35}
#             Current best combo (with val score 0.3244):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 0}
#         Has trained 493 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 100, 'n_restarts_optimizer': 2, 'features': 37}
#             Current best combo (with val score 0.3244):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 0}
#         Has trained 493 of 1440 combinations so far
# 	round 0 iteration:  1
#
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 25, 'n_restarts_optimizer': 2, 'features': 36}
#             Current best combo (with val score 0.3244):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 0}
#         Has trained 493 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 100, 'n_restarts_optimizer': 2, 'features': 36}
#             Current best combo (with val score 0.3244):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 0}
#         Has trained 493 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 50, 'n_restarts_optimizer': 1, 'features': 36}
#             Current best combo (with val score 0.3244):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 0}
#         Has trained 493 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 50, 'n_restarts_optimizer': 3, 'features': 36}
#             Current best combo (with val score 0.3244):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 0}
#         Has trained 493 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 50, 'n_restarts_optimizer': 2, 'features': 35}
#             Current best combo (with val score 0.3244):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 0}
#         Has trained 493 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 50, 'n_restarts_optimizer': 2, 'features': 37}
#             Current best combo (with val score 0.3244):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 0}
#         Has trained 493 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 100, 'n_restarts_optimizer': 2, 'features': 36}
#             Current best combo (with val score 0.3244):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 0}
#         Has trained 493 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 400, 'n_restarts_optimizer': 2, 'features': 36}
#             Current best combo (with val score 0.3244):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 0}
#         Has trained 493 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 200, 'n_restarts_optimizer': 1, 'features': 36}
#             Current best combo (with val score 0.3244):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 0}
#         Has trained 493 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 200, 'n_restarts_optimizer': 3, 'features': 36}
#             Current best combo (with val score 0.3244):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 0}
#         Has trained 493 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 200, 'n_restarts_optimizer': 2, 'features': 35}
#             Current best combo (with val score 0.3244):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 0}
#         Has trained 493 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 200, 'n_restarts_optimizer': 2, 'features': 37}
#             Current best combo (with val score 0.3244):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 0}
#         Has trained 493 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 50, 'n_restarts_optimizer': 1, 'features': 36}
#             Current best combo (with val score 0.3244):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 0}
#         Has trained 493 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 200, 'n_restarts_optimizer': 1, 'features': 36}
#             Current best combo (with val score 0.3244):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 0}
#         Has trained 493 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 100, 'n_restarts_optimizer': 0, 'features': 36}
#             Current best combo (with val score 0.3244):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 0}
#         Has trained 493 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 100, 'n_restarts_optimizer': 2, 'features': 36}
#             Current best combo (with val score 0.3244):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 0}
#         Has trained 493 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 100, 'n_restarts_optimizer': 1, 'features': 35}
#             Current best combo (with val score 0.3244):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 0}
#         Has trained 493 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 100, 'n_restarts_optimizer': 1, 'features': 37}
#             Current best combo (with val score 0.3244):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 0}
#         Has trained 493 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 50, 'n_restarts_optimizer': 3, 'features': 36}
#             Current best combo (with val score 0.3244):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 0}
#         Has trained 493 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 200, 'n_restarts_optimizer': 3, 'features': 36}
#             Current best combo (with val score 0.3244):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 0}
#         Has trained 493 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 100, 'n_restarts_optimizer': 2, 'features': 36}
#             Current best combo (with val score 0.3244):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 0}
#         Has trained 493 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 100, 'n_restarts_optimizer': 3, 'features': 35}
#             Current best combo (with val score 0.3244):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 0}
#         Has trained 493 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 100, 'n_restarts_optimizer': 3, 'features': 37}
#             Current best combo (with val score 0.3244):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 0}
#         Has trained 493 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 50, 'n_restarts_optimizer': 2, 'features': 35}
#             Current best combo (with val score 0.3244):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 0}
#         Has trained 493 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 200, 'n_restarts_optimizer': 2, 'features': 35}
#             Current best combo (with val score 0.3244):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 0}
#         Has trained 493 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 100, 'n_restarts_optimizer': 1, 'features': 35}
#             Current best combo (with val score 0.3244):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 0}
#         Has trained 493 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 100, 'n_restarts_optimizer': 3, 'features': 35}
#             Current best combo (with val score 0.3244):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 0}
#         Has trained 493 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 100, 'n_restarts_optimizer': 2, 'features': 34}
#             Current best combo (with val score 0.3244):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 0}
#         Has trained 493 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 100, 'n_restarts_optimizer': 2, 'features': 36}
#             Current best combo (with val score 0.3244):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 0}
#         Has trained 493 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 50, 'n_restarts_optimizer': 2, 'features': 37}
#             Current best combo (with val score 0.3244):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 0}
#         Has trained 493 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 200, 'n_restarts_optimizer': 2, 'features': 37}
#             Current best combo (with val score 0.3244):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 0}
#         Has trained 493 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 100, 'n_restarts_optimizer': 1, 'features': 37}
#             Current best combo (with val score 0.3244):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 0}
#         Has trained 493 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 100, 'n_restarts_optimizer': 3, 'features': 37}
#             Current best combo (with val score 0.3244):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 0}
#         Has trained 493 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 100, 'n_restarts_optimizer': 2, 'features': 36}
#             Current best combo (with val score 0.3244):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 0}
#         Has trained 493 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 100, 'n_restarts_optimizer': 2, 'features': 38}
#             Current best combo (with val score 0.3244):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 0}
#         Has trained 493 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3244):
#             {'max_iter_predict': 50, 'n_restarts_optimizer': 3, 'features': 0}
#             Current best combo (with val score 0.3244):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 0}
#         Has trained 493 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3244):
#             {'max_iter_predict': 25, 'n_restarts_optimizer': 2, 'features': 0}
#             Current best combo (with val score 0.3244):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 0}
#         Has trained 493 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.0794):
#             {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 1}
#             Current best combo (with val score 0.3244):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 0}
#         Has trained 493 of 1440 combinations so far
# % Combos Checked Thus Far: 493 out of 1440 which is 34.236111%
# STAGE TWO: Begin Cruise system
#
#
# Cruising Coordrdinate 1 of 64
#
# Cruise suspended due to suspicious case
# Guidance: round 1
#
# 	round 1 iteration:  0
#
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 200, 'n_restarts_optimizer': 0, 'features': 71}
#             Current best combo (with val score 0.3244):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 0}
#         Has trained 493 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 400, 'n_restarts_optimizer': 1, 'features': 71}
#             Current best combo (with val score 0.3244):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 0}
#         Has trained 493 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 70}
#             Current best combo (with val score 0.3244):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 0}
#         Has trained 493 of 1440 combinations so far
# 	round 1 iteration:  1
#
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 100, 'n_restarts_optimizer': 0, 'features': 71}
#             Current best combo (with val score 0.3244):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 0}
#         Has trained 493 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 71}
#             Current best combo (with val score 0.3244):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 0}
#         Has trained 493 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 200, 'n_restarts_optimizer': 1, 'features': 71}
#             Current best combo (with val score 0.3244):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 0}
#         Has trained 493 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 200, 'n_restarts_optimizer': 0, 'features': 70}
#             Current best combo (with val score 0.3244):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 0}
#         Has trained 493 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 200, 'n_restarts_optimizer': 1, 'features': 71}
#             Current best combo (with val score 0.3244):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 0}
#         Has trained 493 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 71}
#             Current best combo (with val score 0.3244):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 0}
#         Has trained 493 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 400, 'n_restarts_optimizer': 2, 'features': 71}
#             Current best combo (with val score 0.3244):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 0}
#         Has trained 493 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 400, 'n_restarts_optimizer': 1, 'features': 70}
#             Current best combo (with val score 0.3244):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 0}
#         Has trained 493 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 200, 'n_restarts_optimizer': 0, 'features': 70}
#             Current best combo (with val score 0.3244):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 0}
#         Has trained 493 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 400, 'n_restarts_optimizer': 1, 'features': 70}
#             Current best combo (with val score 0.3244):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 0}
#         Has trained 493 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 69}
#             Current best combo (with val score 0.3244):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 0}
#         Has trained 493 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 71}
#             Current best combo (with val score 0.3244):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 0}
#         Has trained 493 of 1440 combinations so far
# % Combos Checked Thus Far: 493 out of 1440 which is 34.236111%
# Cruising Coordrdinate 2 of 64
#
# Cruise suspended due to suspicious case
# Guidance: round 2
#
# 	round 2 iteration:  0
#
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 200, 'n_restarts_optimizer': 3, 'features': 71}
#             Current best combo (with val score 0.3244):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 0}
#         Has trained 493 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 400, 'n_restarts_optimizer': 2, 'features': 71}
#             Current best combo (with val score 0.3244):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 0}
#         Has trained 493 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 400, 'n_restarts_optimizer': 3, 'features': 70}
#             Current best combo (with val score 0.3244):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 0}
#         Has trained 493 of 1440 combinations so far
# 	round 2 iteration:  1
#
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 100, 'n_restarts_optimizer': 3, 'features': 71}
#             Current best combo (with val score 0.3244):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 0}
#         Has trained 493 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 400, 'n_restarts_optimizer': 3, 'features': 71}
#             Current best combo (with val score 0.3244):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 0}
#         Has trained 493 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 200, 'n_restarts_optimizer': 2, 'features': 71}
#             Current best combo (with val score 0.3244):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 0}
#         Has trained 493 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 200, 'n_restarts_optimizer': 3, 'features': 70}
#             Current best combo (with val score 0.3244):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 0}
#         Has trained 493 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 200, 'n_restarts_optimizer': 3, 'features': 70}
#             Current best combo (with val score 0.3244):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 0}
#         Has trained 493 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 400, 'n_restarts_optimizer': 2, 'features': 70}
#             Current best combo (with val score 0.3244):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 0}
#         Has trained 493 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 400, 'n_restarts_optimizer': 3, 'features': 69}
#             Current best combo (with val score 0.3244):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 0}
#         Has trained 493 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 400, 'n_restarts_optimizer': 3, 'features': 71}
#             Current best combo (with val score 0.3244):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 0}
#         Has trained 493 of 1440 combinations so far
# % Combos Checked Thus Far: 493 out of 1440 which is 34.236111%
# Cruising Coordrdinate 3 of 64
#
# Cruise suspended due to suspicious case
# Guidance: round 3
#
# 	round 3 iteration:  0
#
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 50, 'n_restarts_optimizer': 0, 'features': 71}
#             Current best combo (with val score 0.3244):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 0}
#         Has trained 493 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 25, 'n_restarts_optimizer': 1, 'features': 71}
#             Current best combo (with val score 0.3244):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 0}
#         Has trained 493 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 70}
#             Current best combo (with val score 0.3244):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 0}
#         Has trained 493 of 1440 combinations so far
# 	round 3 iteration:  1
#
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 71}
#             Current best combo (with val score 0.3244):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 0}
#         Has trained 493 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 100, 'n_restarts_optimizer': 0, 'features': 71}
#             Current best combo (with val score 0.3244):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 0}
#         Has trained 493 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 50, 'n_restarts_optimizer': 1, 'features': 71}
#             Current best combo (with val score 0.3244):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 0}
#         Has trained 493 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 50, 'n_restarts_optimizer': 0, 'features': 70}
#             Current best combo (with val score 0.3244):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 0}
#         Has trained 493 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 50, 'n_restarts_optimizer': 1, 'features': 71}
#             Current best combo (with val score 0.3244):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 0}
#         Has trained 493 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 71}
#             Current best combo (with val score 0.3244):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 0}
#         Has trained 493 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 25, 'n_restarts_optimizer': 2, 'features': 71}
#             Current best combo (with val score 0.3244):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 0}
#         Has trained 493 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 25, 'n_restarts_optimizer': 1, 'features': 70}
#             Current best combo (with val score 0.3244):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 0}
#         Has trained 493 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 50, 'n_restarts_optimizer': 0, 'features': 70}
#             Current best combo (with val score 0.3244):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 0}
#         Has trained 493 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 25, 'n_restarts_optimizer': 1, 'features': 70}
#             Current best combo (with val score 0.3244):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 0}
#         Has trained 493 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 69}
#             Current best combo (with val score 0.3244):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 0}
#         Has trained 493 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 71}
#             Current best combo (with val score 0.3244):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 0}
#         Has trained 493 of 1440 combinations so far
# % Combos Checked Thus Far: 493 out of 1440 which is 34.236111%
# Cruising Coordrdinate 4 of 64
#
# Cruise suspended due to suspicious case
# Guidance: round 4
#
# 	round 4 iteration:  0
#
# Already Trained and Tested combination (val score of 0.3086):
#             {'max_iter_predict': 50, 'n_restarts_optimizer': 3, 'features': 71}
#             Current best combo (with val score 0.3244):
#                     {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 0}
#         Has trained 493 of 1440 combinations so far
# ...
#             {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 15}
#             Current best combo (with val score 0.4404):
#                     {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 16}
#         Has trained 523 of 1440 combinations so far
# Trained and Tested combination 524 of 1440, taking 45.02 seconds to get val score of 0.0:
#                 {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 17},
#             Current best combo with val score 0.4404:
#                     {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 16}
# Already Trained and Tested combination (val score of 0.4404):
#             {'max_iter_predict': 200, 'n_restarts_optimizer': 0, 'features': 16}
#             Current best combo (with val score 0.4404):
#                     {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 16}
#         Has trained 524 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.4404):
#             {'max_iter_predict': 400, 'n_restarts_optimizer': 1, 'features': 16}
#             Current best combo (with val score 0.4404):
#                     {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 16}
#         Has trained 524 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.2305):
#             {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 15}
#             Current best combo (with val score 0.4404):
#                     {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 16}
#         Has trained 524 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 17}
#             Current best combo (with val score 0.4404):
#                     {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 16}
#         Has trained 524 of 1440 combinations so far
# % Combos Checked Thus Far: 524 out of 1440 which is 36.388889%
# Cruising Coordrdinate 50 of 64
#
# Cruise suspended due to suspicious case
# Guidance: round 42
#
# 	round 42 iteration:  0
#
# Already Trained and Tested combination (val score of 0.3244):
#             {'max_iter_predict': 50, 'n_restarts_optimizer': 3, 'features': 0}
#             Current best combo (with val score 0.4404):
#                     {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 16}
#         Has trained 524 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3244):
#             {'max_iter_predict': 25, 'n_restarts_optimizer': 2, 'features': 0}
#             Current best combo (with val score 0.4404):
#                     {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 16}
#         Has trained 524 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.0794):
#             {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 1}
#             Current best combo (with val score 0.4404):
#                     {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 16}
#         Has trained 524 of 1440 combinations so far
# 	round 42 iteration:  1
#
# Already Trained and Tested combination (val score of 0.3244):
#             {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 0}
#             Current best combo (with val score 0.4404):
#                     {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 16}
#         Has trained 524 of 1440 combinations so far
# Trained and Tested combination 525 of 1440, taking 34.81 seconds to get val score of 0.3244:
#                 {'max_iter_predict': 100, 'n_restarts_optimizer': 3, 'features': 0},
#             Current best combo with val score 0.4404:
#                     {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 16}
# Trained and Tested combination 526 of 1440, taking 35.51 seconds to get val score of 0.3244:
#                 {'max_iter_predict': 50, 'n_restarts_optimizer': 2, 'features': 0},
#             Current best combo with val score 0.4404:
#                     {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 16}
# Trained and Tested combination 527 of 1440, taking 42.38 seconds to get val score of 0.0794:
#                 {'max_iter_predict': 50, 'n_restarts_optimizer': 3, 'features': 1},
#             Current best combo with val score 0.4404:
#                     {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 16}
# Already Trained and Tested combination (val score of 0.3244):
#             {'max_iter_predict': 50, 'n_restarts_optimizer': 2, 'features': 0}
#             Current best combo (with val score 0.4404):
#                     {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 16}
#         Has trained 527 of 1440 combinations so far
# Trained and Tested combination 528 of 1440, taking 36.79 seconds to get val score of 0.3244:
#                 {'max_iter_predict': 25, 'n_restarts_optimizer': 1, 'features': 0},
#             Current best combo with val score 0.4404:
#                     {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 16}
# Already Trained and Tested combination (val score of 0.3244):
#             {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 0}
#             Current best combo (with val score 0.4404):
#                     {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 16}
#         Has trained 528 of 1440 combinations so far
# Trained and Tested combination 529 of 1440, taking 40.41 seconds to get val score of 0.0794:
#                 {'max_iter_predict': 25, 'n_restarts_optimizer': 2, 'features': 1},
#             Current best combo with val score 0.4404:
#                     {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 16}
# % Combos Checked Thus Far: 529 out of 1440 which is 36.736111%
# Cruising Coordrdinate 51 of 64
#
# Cruise suspended due to suspicious case
# Guidance: round 43
#
# 	round 43 iteration:  0
#
# Trained and Tested combination 530 of 1440, taking 33.73 seconds to get val score of 0.3244:
#                 {'max_iter_predict': 50, 'n_restarts_optimizer': 0, 'features': 0},
#             Current best combo with val score 0.4404:
#                     {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 16}
# Already Trained and Tested combination (val score of 0.3244):
#             {'max_iter_predict': 25, 'n_restarts_optimizer': 1, 'features': 0}
#             Current best combo (with val score 0.4404):
#                     {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 16}
#         Has trained 530 of 1440 combinations so far
# Trained and Tested combination 531 of 1440, taking 39.82 seconds to get val score of 0.0794:
#                 {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 1},
#             Current best combo with val score 0.4404:
#                     {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 16}
# 	round 43 iteration:  1
#
# Already Trained and Tested combination (val score of 0.3244):
#             {'max_iter_predict': 25, 'n_restarts_optimizer': 0, 'features': 0}
#             Current best combo (with val score 0.4404):
#                     {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 16}
#         Has trained 531 of 1440 combinations so far
# Trained and Tested combination 532 of 1440, taking 33.39 seconds to get val score of 0.3244:
#                 {'max_iter_predict': 100, 'n_restarts_optimizer': 0, 'features': 0},
#             Current best combo with val score 0.4404:
#                     {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 16}
# Trained and Tested combination 533 of 1440, taking 35.69 seconds to get val score of 0.3244:
#                 {'max_iter_predict': 50, 'n_restarts_optimizer': 1, 'features': 0},
#             Current best combo with val score 0.4404:
#                     {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 16}
# Trained and Tested combination 534 of 1440, taking 37.85 seconds to get val score of 0.0794:
#                 {'max_iter_predict': 50, 'n_restarts_optimizer': 0, 'features': 1},
#             Current best combo with val score 0.4404:
#                     {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 16}
# % Combos Checked Thus Far: 534 out of 1440 which is 37.083333%
# Cruising Coordrdinate 52 of 64
#
# Cruise suspended due to suspicious case
# Guidance: round 44
#
# 	round 44 iteration:  0
#
# Trained and Tested combination 535 of 1440, taking 36.11 seconds to get val score of 0.3244:
#                 {'max_iter_predict': 200, 'n_restarts_optimizer': 3, 'features': 0},
#             Current best combo with val score 0.4404:
#                     {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 16}
# Trained and Tested combination 536 of 1440, taking 33.69 seconds to get val score of 0.3244:
#                 {'max_iter_predict': 400, 'n_restarts_optimizer': 2, 'features': 0},
#             Current best combo with val score 0.4404:
#                     {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 16}
# Trained and Tested combination 537 of 1440, taking 39.35 seconds to get val score of 0.0794:
#                 {'max_iter_predict': 400, 'n_restarts_optimizer': 3, 'features': 1},
#             Current best combo with val score 0.4404:
#                     {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 16}
# 	round 44 iteration:  1
#
# Already Trained and Tested combination (val score of 0.3244):
#             {'max_iter_predict': 100, 'n_restarts_optimizer': 3, 'features': 0}
#             Current best combo (with val score 0.4404):
#                     {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 16}
#         Has trained 537 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3244):
#             {'max_iter_predict': 400, 'n_restarts_optimizer': 3, 'features': 0}
#             Current best combo (with val score 0.4404):
#                     {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 16}
#         Has trained 537 of 1440 combinations so far
# Trained and Tested combination 538 of 1440, taking 33.7 seconds to get val score of 0.3244:
#                 {'max_iter_predict': 200, 'n_restarts_optimizer': 2, 'features': 0},
#             Current best combo with val score 0.4404:
#                     {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 16}
# Trained and Tested combination 539 of 1440, taking 37.69 seconds to get val score of 0.0794:
#                 {'max_iter_predict': 200, 'n_restarts_optimizer': 3, 'features': 1},
#             Current best combo with val score 0.4404:
#                     {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 16}
# Already Trained and Tested combination (val score of 0.3244):
#             {'max_iter_predict': 200, 'n_restarts_optimizer': 2, 'features': 0}
#             Current best combo (with val score 0.4404):
#                     {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 16}
#         Has trained 539 of 1440 combinations so far
# Trained and Tested combination 540 of 1440, taking 34.25 seconds to get val score of 0.3244:
#                 {'max_iter_predict': 400, 'n_restarts_optimizer': 1, 'features': 0},
#             Current best combo with val score 0.4404:
#                     {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 16}
# Already Trained and Tested combination (val score of 0.3244):
#             {'max_iter_predict': 400, 'n_restarts_optimizer': 3, 'features': 0}
#             Current best combo (with val score 0.4404):
#                     {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 16}
#         Has trained 540 of 1440 combinations so far
# Trained and Tested combination 541 of 1440, taking 38.48 seconds to get val score of 0.0794:
#                 {'max_iter_predict': 400, 'n_restarts_optimizer': 2, 'features': 1},
#             Current best combo with val score 0.4404:
#                     {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 16}
# % Combos Checked Thus Far: 541 out of 1440 which is 37.569444000000004%
# Cruising Coordrdinate 53 of 64
#
# Cruise suspended due to suspicious case
# Guidance: round 45
#
# 	round 45 iteration:  0
#
# Trained and Tested combination 542 of 1440, taking 33.99 seconds to get val score of 0.3244:
#                 {'max_iter_predict': 200, 'n_restarts_optimizer': 0, 'features': 0},
#             Current best combo with val score 0.4404:
#                     {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 16}
# Already Trained and Tested combination (val score of 0.3244):
#             {'max_iter_predict': 400, 'n_restarts_optimizer': 1, 'features': 0}
#             Current best combo (with val score 0.4404):
#                     {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 16}
#         Has trained 542 of 1440 combinations so far
# Trained and Tested combination 543 of 1440, taking 37.95 seconds to get val score of 0.0794:
#                 {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 1},
#             Current best combo with val score 0.4404:
#                     {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 16}
# 	round 45 iteration:  1
#
# Already Trained and Tested combination (val score of 0.3244):
#             {'max_iter_predict': 100, 'n_restarts_optimizer': 0, 'features': 0}
#             Current best combo (with val score 0.4404):
#                     {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 16}
#         Has trained 543 of 1440 combinations so far
# Already Trained and Tested combination (val score of 0.3244):
#             {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 0}
#             Current best combo (with val score 0.4404):
#                     {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 16}
#         Has trained 543 of 1440 combinations so far
# Trained and Tested combination 544 of 1440, taking 34.17 seconds to get val score of 0.3244:
#                 {'max_iter_predict': 200, 'n_restarts_optimizer': 1, 'features': 0},
#             Current best combo with val score 0.4404:
#                     {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 16}
# Trained and Tested combination 545 of 1440, taking 38.67 seconds to get val score of 0.0794:
#                 {'max_iter_predict': 200, 'n_restarts_optimizer': 0, 'features': 1},
#             Current best combo with val score 0.4404:
#                     {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 16}
# % Combos Checked Thus Far: 545 out of 1440 which is 37.847222%
# Cruising Coordrdinate 54 of 64
#
# Cruising Coordrdinate 55 of 64
#
# Cruising Coordrdinate 56 of 64
#
# Cruising Coordrdinate 57 of 64
#
# Cruising Coordrdinate 58 of 64
#
# Cruise suspended due to suspicious case
# Guidance: round 46
#
# 	round 46 iteration:  0
#
# Trained and Tested combination 546 of 1440, taking 49.83 seconds to get val score of 0.1995:
#                 {'max_iter_predict': 50, 'n_restarts_optimizer': 3, 'features': 10},
#             Current best combo with val score 0.4404:
#                     {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 16}
# Trained and Tested combination 547 of 1440, taking 50.07 seconds to get val score of 0.1995:
#                 {'max_iter_predict': 25, 'n_restarts_optimizer': 2, 'features': 10},
#             Current best combo with val score 0.4404:
#                     {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 16}
# Trained and Tested combination 548 of 1440, taking 52.59 seconds to get val score of 0.0423:
#                 {'max_iter_predict': 25, 'n_restarts_optimizer': 3, 'features': 9},
#             Current best combo with val score 0.4404:
#                     {'max_iter_predict': 400, 'n_restarts_optimizer': 0, 'features': 16}
