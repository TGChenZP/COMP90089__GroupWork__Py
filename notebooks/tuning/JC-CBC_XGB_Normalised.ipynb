# %% [markdown]
# # Tuning Script

# %%
# Parameters subject to change in every script - involved in naming

MODEL = 'cbc'
PREPROCESSING = 'normalise'
TUNER = 'yangzhoub'
OPTIMISED_METRIC = 'f1'

# %% [markdown]
# ---

# %%
# detect whether this is a google environment

COLAB_ENVIRONMENT = False

try:
    from google.colab import drive
    drive.mount('/content/drive')
    COLAB_ENVIRONMENT = True
except:
    pass
# Out:
# Mounted at /content/drive

# %%
import sys
import os
import pickle

if COLAB_ENVIRONMENT:
    home_directory = './drive/MyDrive/LAB/COMP90089__GroupWork__Py/' # my home directory is stored in ./LAB of google drive
    if MODEL == 'ebc':
        # !pip install interpret==0.5.0
    elif MODEL == 'cbc':
        # !pip install catboost
    elif MODEL in ['tf', 'mlp']:
        # !pip install PyTorch2Sklearn
    # !pip install JXAutoML
else:
    home_directory = '../../'

from JXAutoML.JiaoCheng_10CV import JiaoCheng_10CV as Tuner

import pandas as pd
# Out:
# Collecting catboost
#   Downloading catboost-1.2.7-cp310-cp310-manylinux2014_x86_64.whl.metadata (1.2 kB)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.10/dist-packages (from catboost) (0.20.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from catboost) (3.7.1)
# Requirement already satisfied: numpy<2.0,>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from catboost) (1.26.4)
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.10/dist-packages (from catboost) (2.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from catboost) (1.13.1)
# Requirement already satisfied: plotly in /usr/local/lib/python3.10/dist-packages (from catboost) (5.24.1)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from catboost) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2024.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (3.1.4)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly->catboost) (9.0.0)
# Downloading catboost-1.2.7-cp310-cp310-manylinux2014_x86_64.whl (98.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.7/98.7 MB 9.6 MB/s eta 0:00:00
# Installing collected packages: catboost
# Successfully installed catboost-1.2.7
# Collecting JXAutoML
#   Downloading JXAutoML-0.4.4-py3-none-any.whl.metadata (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.2/67.2 kB 4.5 MB/s eta 0:00:00
# Downloading JXAutoML-0.4.4-py3-none-any.whl (52 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.1/52.1 kB 4.0 MB/s eta 0:00:00
# Installing collected packages: JXAutoML
# Successfully installed JXAutoML-0.4.4

# %%
# Parameters that are same for every script

FOLDS = 10  # we have decided to do 10 fold validation

SEED = 42

TASK_TYPE = 'Classification'  # this task is a classification task

# we have decided to tune features as hp
TUNE_FEATURES_AS_HYPERPARAMETERS = True

# %% [markdown]
# ---

# %%
# model to use to tune
from catboost import CatBoostClassifier as clf

# what values to try for each hyperparameter
parameter_choices = {

    'n_estimators': (25, 50, 100, 200),
    'max_depth': (2, 4, 8, 16),
    'subsample': (0.4, 0.55, 0.7, 0.85, 1),
    'colsample_bylevel': (0.4, 0.55, 0.7, 0.85, 1),
    'reg_lambda': (0.01, 0.1, 1),
    'learning_rate': (0.001, 0.01, 0.1, 1),

}

# what values to set non-tuneable parameters/hyperparameters
non_tunable_hyperparameters_dict = {
      'random_state': 19260817,
      'verbose': False,
      'max_bin': 64
      }

# what order to tune hyperparameters in (JiaoCheng specific)
tuning_order = ['features',
                'max_depth',
                'colsample_bylevel',
                'subsample',
                'n_estimators',
                'reg_lambda',
                'learning_rate']

# what order to tune hyperparameters in (JiaoCheng specific)
default_hyperparameter_values = {
                                'features': 0,
                                'n_estimators': 50,
                                'max_depth': 4,
                                'subsample': 0.7,
                                'colsample_bylevel': 0.7,
                                'learning_rate': 0.01,
                                'reg_lambda': 0.01
                                }

# %% [markdown]
# ---

# %% [markdown]
# Read in and Prepare Data

# %%
# Import data and store as lists

train_x_list = []
train_y_list = []
val_x_list = []
val_y_list = []

for i in range(FOLDS):
    train_data = pd.read_csv(
        f'{home_directory}data/curated/modelling/{PREPROCESSING}/train_{i}.csv')
    val_data = pd.read_csv(
        f'{home_directory}data/curated/modelling/{PREPROCESSING}/val_{i}.csv')

    # get the correct rows for X and y
    train_x = train_data.drop(
        ['mortality_status', 'subject_id', 'hadm_id', 'stay_id'], axis=1)
    train_y = train_data['mortality_status']
    val_x = val_data.drop(
        ['mortality_status', 'subject_id', 'hadm_id', 'stay_id'], axis=1)
    val_y = val_data['mortality_status']

    train_x_list.append(train_x)
    train_y_list.append(train_y)
    val_x_list.append(val_x)
    val_y_list.append(val_y)

# %%
# Import feature importance ordering

with open(f'{home_directory}models/xgb_feature_importance_ordering_{PREPROCESSING}.pickle', 'rb') as f:
    feature_importance_ordering = pickle.load(f)

# %% [markdown]
# Set parameters

# %%
# initialisation
tuner = Tuner()

print('---')

# define what model we are tuning
tuner.read_in_model(clf, TASK_TYPE, optimised_metric = OPTIMISED_METRIC)

print('---')

# read in the data for training and validation
tuner.read_in_data(train_x_list, train_y_list, val_x_list, val_y_list)

print('---')

# set what hp values to tune
tuner.set_hyperparameters(parameter_choices)
# WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

# set up hp values that need to be changed from default but NOT to be tuned
tuner.set_non_tuneable_hyperparameters(non_tunable_hyperparameters_dict)

print('---')

# set up feature importance ordering

if TUNE_FEATURES_AS_HYPERPARAMETERS:
  tuner.set_features(feature_importance_ordering)
  # WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

# set up the order of hyperparameters when iteratively tuning using JiaoCheng
tuner.set_tuning_order(tuning_order)

print('---')

# set up the default hp values for first iteration of tuning JiaoCheng
tuner.set_hyperparameter_default_values(default_hyperparameter_values)

print('---')

try: # try to read in previous results to continue tuning ...
  tuner.read_in_tuning_result_df(f'{home_directory}models/tuning/{TUNER}_{MODEL}_{PREPROCESSING}.csv')
except:
  print('No previous tuning data read in')

print('---')

# set up where to save the tuning result csv
tuner.set_tuning_result_saving_address(f'{home_directory}models/tuning/{TUNER}_{MODEL}_{PREPROCESSING}.csv')

print('---')

# set up where to save the current best model
tuner.set_best_model_saving_address(f'{home_directory}models/tmp_models/{TUNER}_{MODEL}_{PREPROCESSING}')
# Out:
# JiaoCheng Initialised
# ---
# Successfully read in model <class 'catboost.core.CatBoostClassifier'>, which is a Classification model optimising for f1
# ---
# Read in Train X data list
# Read in Train y data list
# Read in Val X data list
# Read in Val y data list
# ---
# Successfully recorded hyperparameter choices
# ---
# Successfully recorded non_tuneable_hyperparameter choices
# ---
# Successfully recorded tuneable feature combination choices and updated relevant internal structures
# ---
# ---
# ---
# No previous tuning data read in
# ---
# Successfully set tuning output address
# ---
# Successfully set best model output address

# %%
# ignore warnings

import warnings
warnings.filterwarnings("ignore")

# %%
# begin tuning ... (or continue training)

tuner.tune()
# Out:
# Default combo: [1, 1, 2, 2, 0, 1, 0]
#
#
# ROUND 1
#
# Round 1
# Hyperparameter: features (index: 6)
#
# Trained and Tested combination 1 of 244800, taking 0.03 seconds to get val score of 0.0:
#                 {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.7, 'colsample_bylevel': 0.7, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 0},
#             Current best combo with val score 0.0:
#                     {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.7, 'colsample_bylevel': 0.7, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 0}
# Trained and Tested combination 2 of 244800, taking 0.04 seconds to get val score of 0.0:
#                 {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.7, 'colsample_bylevel': 0.7, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 1},
#             Current best combo with val score 0.0:
#                     {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.7, 'colsample_bylevel': 0.7, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 0}
# Trained and Tested combination 3 of 244800, taking 0.04 seconds to get val score of 0.0:
#                 {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.7, 'colsample_bylevel': 0.7, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 2},
#             Current best combo with val score 0.0:
#                     {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.7, 'colsample_bylevel': 0.7, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 0}
# Trained and Tested combination 4 of 244800, taking 0.11 seconds to get val score of 0.0:
#                 {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.7, 'colsample_bylevel': 0.7, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 3},
#             Current best combo with val score 0.0:
#                     {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.7, 'colsample_bylevel': 0.7, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 0}
# Trained and Tested combination 5 of 244800, taking 0.13 seconds to get val score of 0.0:
#                 {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.7, 'colsample_bylevel': 0.7, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 4},
#             Current best combo with val score 0.0:
#                     {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.7, 'colsample_bylevel': 0.7, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 0}
# Trained and Tested combination 6 of 244800, taking 0.11 seconds to get val score of 0.4462:
#                 {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.7, 'colsample_bylevel': 0.7, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 5},
#             Current best combo with val score 0.4462:
#                     {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.7, 'colsample_bylevel': 0.7, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 5}
# Trained and Tested combination 7 of 244800, taking 0.25 seconds to get val score of 0.4461:
#                 {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.7, 'colsample_bylevel': 0.7, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 6},
#             Current best combo with val score 0.4462:
#                     {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.7, 'colsample_bylevel': 0.7, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 5}
# Trained and Tested combination 8 of 244800, taking 0.14 seconds to get val score of 0.4492:
#                 {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.7, 'colsample_bylevel': 0.7, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 7},
#             Current best combo with val score 0.4492:
#                     {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.7, 'colsample_bylevel': 0.7, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 7}
# Trained and Tested combination 9 of 244800, taking 0.13 seconds to get val score of 0.4606:
#                 {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.7, 'colsample_bylevel': 0.7, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 8},
#             Current best combo with val score 0.4606:
#                     {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.7, 'colsample_bylevel': 0.7, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 8}
# Trained and Tested combination 10 of 244800, taking 0.52 seconds to get val score of 0.4602:
#                 {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.7, 'colsample_bylevel': 0.7, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 9},
#             Current best combo with val score 0.4606:
#                     {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.7, 'colsample_bylevel': 0.7, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 8}
# Trained and Tested combination 11 of 244800, taking 0.09 seconds to get val score of 0.4559:
#                 {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.7, 'colsample_bylevel': 0.7, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 10},
#             Current best combo with val score 0.4606:
#                     {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.7, 'colsample_bylevel': 0.7, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 8}
# Trained and Tested combination 12 of 244800, taking 0.09 seconds to get val score of 0.237:
#                 {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.7, 'colsample_bylevel': 0.7, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 11},
#             Current best combo with val score 0.4606:
#                     {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.7, 'colsample_bylevel': 0.7, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 8}
# Trained and Tested combination 13 of 244800, taking 0.09 seconds to get val score of 0.196:
#                 {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.7, 'colsample_bylevel': 0.7, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 12},
#             Current best combo with val score 0.4606:
#                     {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.7, 'colsample_bylevel': 0.7, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 8}
# Trained and Tested combination 14 of 244800, taking 0.09 seconds to get val score of 0.3099:
#                 {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.7, 'colsample_bylevel': 0.7, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 13},
#             Current best combo with val score 0.4606:
#                     {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.7, 'colsample_bylevel': 0.7, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 8}
# Trained and Tested combination 15 of 244800, taking 0.1 seconds to get val score of 0.2504:
#                 {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.7, 'colsample_bylevel': 0.7, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 14},
#             Current best combo with val score 0.4606:
#                     {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.7, 'colsample_bylevel': 0.7, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 8}
# Trained and Tested combination 16 of 244800, taking 0.1 seconds to get val score of 0.233:
#                 {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.7, 'colsample_bylevel': 0.7, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 15},
#             Current best combo with val score 0.4606:
#                     {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.7, 'colsample_bylevel': 0.7, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 8}
# Trained and Tested combination 17 of 244800, taking 0.1 seconds to get val score of 0.2363:
#                 {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.7, 'colsample_bylevel': 0.7, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 16},
#             Current best combo with val score 0.4606:
#                     {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.7, 'colsample_bylevel': 0.7, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 8}
# Trained and Tested combination 18 of 244800, taking 0.21 seconds to get val score of 0.215:
#                 {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.7, 'colsample_bylevel': 0.7, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 17},
#             Current best combo with val score 0.4606:
#                     {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.7, 'colsample_bylevel': 0.7, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 8}
# Trained and Tested combination 19 of 244800, taking 0.16 seconds to get val score of 0.2543:
#                 {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.7, 'colsample_bylevel': 0.7, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 18},
#             Current best combo with val score 0.4606:
#                     {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.7, 'colsample_bylevel': 0.7, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 8}
# Trained and Tested combination 20 of 244800, taking 0.11 seconds to get val score of 0.2513:
#                 {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.7, 'colsample_bylevel': 0.7, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 19},
#             Current best combo with val score 0.4606:
#                     {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.7, 'colsample_bylevel': 0.7, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 8}
# Trained and Tested combination 21 of 244800, taking 0.11 seconds to get val score of 0.2291:
#                 {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.7, 'colsample_bylevel': 0.7, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 20},
#             Current best combo with val score 0.4606:
#                     {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.7, 'colsample_bylevel': 0.7, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 8}
# Trained and Tested combination 22 of 244800, taking 0.11 seconds to get val score of 0.2203:
#                 {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.7, 'colsample_bylevel': 0.7, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 21},
#             Current best combo with val score 0.4606:
#                     {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.7, 'colsample_bylevel': 0.7, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 8}
# Trained and Tested combination 23 of 244800, taking 0.11 seconds to get val score of 0.159:
#                 {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.7, 'colsample_bylevel': 0.7, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 22},
#             Current best combo with val score 0.4606:
#                     {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.7, 'colsample_bylevel': 0.7, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 8}
# Trained and Tested combination 24 of 244800, taking 0.11 seconds to get val score of 0.1123:
#                 {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.7, 'colsample_bylevel': 0.7, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 23},
#             Current best combo with val score 0.4606:
#                     {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.7, 'colsample_bylevel': 0.7, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 8}
# Trained and Tested combination 25 of 244800, taking 0.11 seconds to get val score of 0.1101:
#                 {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.7, 'colsample_bylevel': 0.7, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 24},
#             Current best combo with val score 0.4606:
#                     {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.7, 'colsample_bylevel': 0.7, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 8}
# Trained and Tested combination 26 of 244800, taking 0.11 seconds to get val score of 0.084:
#                 {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.7, 'colsample_bylevel': 0.7, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 25},
#             Current best combo with val score 0.4606:
#                     {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.7, 'colsample_bylevel': 0.7, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 8}
# Trained and Tested combination 27 of 244800, taking 0.24 seconds to get val score of 0.1255:
#                 {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.7, 'colsample_bylevel': 0.7, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 26},
#             Current best combo with val score 0.4606:
#                     {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.7, 'colsample_bylevel': 0.7, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 8}
# Trained and Tested combination 28 of 244800, taking 0.14 seconds to get val score of 0.0781:
#                 {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.7, 'colsample_bylevel': 0.7, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 27},
#             Current best combo with val score 0.4606:
#                     {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.7, 'colsample_bylevel': 0.7, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 8}
# Trained and Tested combination 29 of 244800, taking 0.13 seconds to get val score of 0.0244:
#                 {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.7, 'colsample_bylevel': 0.7, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 28},
#             Current best combo with val score 0.4606:
#                     {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.7, 'colsample_bylevel': 0.7, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 8}
# Trained and Tested combination 30 of 244800, taking 0.12 seconds to get val score of 0.2143:
#                 {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.7, 'colsample_bylevel': 0.7, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 29},
#             Current best combo with val score 0.4606:
#                     {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.7, 'colsample_bylevel': 0.7, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 8}
# Trained and Tested combination 31 of 244800, taking 0.12 seconds to get val score of 0.1203:
#                 {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.7, 'colsample_bylevel': 0.7, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 30},
#             Current best combo with val score 0.4606:
#                     {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.7, 'colsample_bylevel': 0.7, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 8}
# Trained and Tested combination 32 of 244800, taking 0.12 seconds to get val score of 0.0286:
#                 {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.7, 'colsample_bylevel': 0.7, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 31},
#             Current best combo with val score 0.4606:
#                     {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.7, 'colsample_bylevel': 0.7, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 8}
# Trained and Tested combination 33 of 244800, taking 0.12 seconds to get val score of 0.1778:
#                 {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.7, 'colsample_bylevel': 0.7, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 32},
#             Current best combo with val score 0.4606:
#                     {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.7, 'colsample_bylevel': 0.7, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 8}
# Trained and Tested combination 34 of 244800, taking 0.12 seconds to get val score of 0.1127:
#                 {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.7, 'colsample_bylevel': 0.7, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 33},
#             Current best combo with val score 0.4606:
#                     {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.7, 'colsample_bylevel': 0.7, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 8}
# Trained and Tested combination 35 of 244800, taking 0.21 seconds to get val score of 0.0701:
#                 {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.7, 'colsample_bylevel': 0.7, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 34},
#             Current best combo with val score 0.4606:
#                     {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.7, 'colsample_bylevel': 0.7, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 8}
# Trained and Tested combination 36 of 244800, taking 0.12 seconds to get val score of 0.086:
#                 {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.7, 'colsample_bylevel': 0.7, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 35},
#             Current best combo with val score 0.4606:
#                     {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.7, 'colsample_bylevel': 0.7, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 8}
# Trained and Tested combination 37 of 244800, taking 0.13 seconds to get val score of 0.0465:
#                 {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.7, 'colsample_bylevel': 0.7, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 36},
#             Current best combo with val score 0.4606:
#                     {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.7, 'colsample_bylevel': 0.7, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 8}
# Trained and Tested combination 38 of 244800, taking 0.13 seconds to get val score of 0.1473:
#                 {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.7, 'colsample_bylevel': 0.7, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 37},
#             Current best combo with val score 0.4606:
#                     {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.7, 'colsample_bylevel': 0.7, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 8}
# Trained and Tested combination 39 of 244800, taking 0.14 seconds to get val score of 0.2017:
#                 {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.7, 'colsample_bylevel': 0.7, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 38},
#             Current best combo with val score 0.4606:
#                     {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.7, 'colsample_bylevel': 0.7, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 8}
# Trained and Tested combination 40 of 244800, taking 0.12 seconds to get val score of 0.0943:
#                 {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.7, 'colsample_bylevel': 0.7, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 39},
#             Current best combo with val score 0.4606:
#                     {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.7, 'colsample_bylevel': 0.7, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 8}
# Trained and Tested combination 41 of 244800, taking 0.13 seconds to get val score of 0.0895:
#                 {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.7, 'colsample_bylevel': 0.7, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 40},
#             Current best combo with val score 0.4606:
#                     {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.7, 'colsample_bylevel': 0.7, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 8}
# Trained and Tested combination 42 of 244800, taking 0.24 seconds to get val score of 0.085:
#                 {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.7, 'colsample_bylevel': 0.7, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 41},
#             Current best combo with val score 0.4606:
#                     {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.7, 'colsample_bylevel': 0.7, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 8}
# Trained and Tested combination 43 of 244800, taking 0.13 seconds to get val score of 0.0985:
#                 {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.7, 'colsample_bylevel': 0.7, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 42},
#             Current best combo with val score 0.4606:
#                     {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.7, 'colsample_bylevel': 0.7, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 8}
# Trained and Tested combination 44 of 244800, taking 0.13 seconds to get val score of 0.1211:
#                 {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.7, 'colsample_bylevel': 0.7, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 43},
#             Current best combo with val score 0.4606:
#                     {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.7, 'colsample_bylevel': 0.7, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 8}
# Trained and Tested combination 45 of 244800, taking 0.13 seconds to get val score of 0.3311:
#                 {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.7, 'colsample_bylevel': 0.7, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 44},
#             Current best combo with val score 0.4606:
#                     {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.7, 'colsample_bylevel': 0.7, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 8}
# Trained and Tested combination 46 of 244800, taking 0.13 seconds to get val score of 0.0915:
#                 {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.7, 'colsample_bylevel': 0.7, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 45},
#             Current best combo with val score 0.4606:
#                     {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.7, 'colsample_bylevel': 0.7, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 8}
# Trained and Tested combination 47 of 244800, taking 0.13 seconds to get val score of 0.0578:
#                 {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.7, 'colsample_bylevel': 0.7, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 46},
#             Current best combo with val score 0.4606:
#                     {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.7, 'colsample_bylevel': 0.7, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 8}
# Trained and Tested combination 48 of 244800, taking 0.14 seconds to get val score of 0.1325:
#                 {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.7, 'colsample_bylevel': 0.7, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 47},
#             Current best combo with val score 0.4606:
#                     {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.7, 'colsample_bylevel': 0.7, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 8}
# Trained and Tested combination 49 of 244800, taking 0.29 seconds to get val score of 0.0993:
#                 {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.7, 'colsample_bylevel': 0.7, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 48},
#             Current best combo with val score 0.4606:
#                     {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.7, 'colsample_bylevel': 0.7, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 8}
# Trained and Tested combination 50 of 244800, taking 0.13 seconds to get val score of 0.1699:
#                 {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.7, 'colsample_bylevel': 0.7, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 49},
#             Current best combo with val score 0.4606:
#                     {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.7, 'colsample_bylevel': 0.7, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 8}
# Trained and Tested combination 51 of 244800, taking 0.13 seconds to get val score of 0.1887:
#                 {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.7, 'colsample_bylevel': 0.7, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 50},
#             Current best combo with val score 0.4606:
#                     {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.7, 'colsample_bylevel': 0.7, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 8}
#
# Best combo after this hyperparameter: (1, 1, 2, 2, 0, 1, 8) , UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 1
# Hyperparameter: max_depth (index: 1)
#
# Trained and Tested combination 52 of 244800, taking 0.09 seconds to get val score of 0.26:
#                 {'n_estimators': 50, 'max_depth': 2, 'subsample': 0.7, 'colsample_bylevel': 0.7, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 8},
#             Current best combo with val score 0.4606:
#                     {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.7, 'colsample_bylevel': 0.7, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 8}
# Already Trained and Tested combination (val score of 0.4606):
#             {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.7, 'colsample_bylevel': 0.7, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 8}
#             Current best combo (with val score 0.4606):
#                     {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.7, 'colsample_bylevel': 0.7, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 8}
#         Has trained 52 of 244800 combinations so far
# Trained and Tested combination 53 of 244800, taking 0.12 seconds to get val score of 0.4582:
#                 {'n_estimators': 50, 'max_depth': 8, 'subsample': 0.7, 'colsample_bylevel': 0.7, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 8},
#             Current best combo with val score 0.4606:
#                     {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.7, 'colsample_bylevel': 0.7, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 8}
# Trained and Tested combination 54 of 244800, taking 2.59 seconds to get val score of 0.4598:
#                 {'n_estimators': 50, 'max_depth': 16, 'subsample': 0.7, 'colsample_bylevel': 0.7, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 8},
#             Current best combo with val score 0.4606:
#                     {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.7, 'colsample_bylevel': 0.7, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 8}
#
# Best combo after this hyperparameter: (1, 1, 2, 2, 0, 1, 8) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 1
# Hyperparameter: colsample_bylevel (index: 3)
#
# Trained and Tested combination 55 of 244800, taking 0.18 seconds to get val score of 0.4647:
#                 {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.7, 'colsample_bylevel': 0.4, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 8},
#             Current best combo with val score 0.4647:
#                     {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.7, 'colsample_bylevel': 0.4, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 8}
# Trained and Tested combination 56 of 244800, taking 0.17 seconds to get val score of 0.4508:
#                 {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.7, 'colsample_bylevel': 0.55, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 8},
#             Current best combo with val score 0.4647:
#                     {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.7, 'colsample_bylevel': 0.4, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 8}
# Already Trained and Tested combination (val score of 0.4606):
#             {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.7, 'colsample_bylevel': 0.7, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 8}
#             Current best combo (with val score 0.4647):
#                     {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.7, 'colsample_bylevel': 0.4, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 8}
#         Has trained 56 of 244800 combinations so far
# Trained and Tested combination 57 of 244800, taking 0.09 seconds to get val score of 0.462:
#                 {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.7, 'colsample_bylevel': 0.85, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 8},
#             Current best combo with val score 0.4647:
#                     {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.7, 'colsample_bylevel': 0.4, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 8}
# Trained and Tested combination 58 of 244800, taking 0.09 seconds to get val score of 0.4499:
#                 {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.7, 'colsample_bylevel': 1, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 8},
#             Current best combo with val score 0.4647:
#                     {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.7, 'colsample_bylevel': 0.4, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 8}
#
# Best combo after this hyperparameter: (1, 1, 2, 0, 0, 1, 8) , UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 1
# Hyperparameter: subsample (index: 2)
#
# Trained and Tested combination 59 of 244800, taking 0.08 seconds to get val score of 0.4711:
#                 {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.4, 'colsample_bylevel': 0.4, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 8},
#             Current best combo with val score 0.4711:
#                     {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.4, 'colsample_bylevel': 0.4, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 8}
# Trained and Tested combination 60 of 244800, taking 0.08 seconds to get val score of 0.4525:
#                 {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.55, 'colsample_bylevel': 0.4, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 8},
#             Current best combo with val score 0.4711:
#                     {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.4, 'colsample_bylevel': 0.4, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 8}
# Already Trained and Tested combination (val score of 0.4647):
#             {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.7, 'colsample_bylevel': 0.4, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 8}
#             Current best combo (with val score 0.4711):
#                     {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.4, 'colsample_bylevel': 0.4, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 8}
#         Has trained 60 of 244800 combinations so far
# Trained and Tested combination 61 of 244800, taking 0.09 seconds to get val score of 0.4581:
#                 {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.85, 'colsample_bylevel': 0.4, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 8},
#             Current best combo with val score 0.4711:
#                     {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.4, 'colsample_bylevel': 0.4, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 8}
# Trained and Tested combination 62 of 244800, taking 0.08 seconds to get val score of 0.4405:
#                 {'n_estimators': 50, 'max_depth': 4, 'subsample': 1, 'colsample_bylevel': 0.4, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 8},
#             Current best combo with val score 0.4711:
#                     {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.4, 'colsample_bylevel': 0.4, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 8}
#
# Best combo after this hyperparameter: (1, 1, 0, 0, 0, 1, 8) , UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 1
# Hyperparameter: n_estimators (index: 0)
#
# Trained and Tested combination 63 of 244800, taking 0.06 seconds to get val score of 0.4582:
#                 {'n_estimators': 25, 'max_depth': 4, 'subsample': 0.4, 'colsample_bylevel': 0.4, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 8},
#             Current best combo with val score 0.4711:
#                     {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.4, 'colsample_bylevel': 0.4, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 8}
# Already Trained and Tested combination (val score of 0.4711):
#             {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.4, 'colsample_bylevel': 0.4, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 8}
#             Current best combo (with val score 0.4711):
#                     {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.4, 'colsample_bylevel': 0.4, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 8}
#         Has trained 63 of 244800 combinations so far
# Trained and Tested combination 64 of 244800, taking 0.13 seconds to get val score of 0.4632:
#                 {'n_estimators': 100, 'max_depth': 4, 'subsample': 0.4, 'colsample_bylevel': 0.4, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 8},
#             Current best combo with val score 0.4711:
#                     {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.4, 'colsample_bylevel': 0.4, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 8}
# Trained and Tested combination 65 of 244800, taking 0.39 seconds to get val score of 0.4671:
#                 {'n_estimators': 200, 'max_depth': 4, 'subsample': 0.4, 'colsample_bylevel': 0.4, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 8},
#             Current best combo with val score 0.4711:
#                     {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.4, 'colsample_bylevel': 0.4, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 8}
#
# Best combo after this hyperparameter: (1, 1, 0, 0, 0, 1, 8) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 1
# Hyperparameter: reg_lambda (index: 4)
#
# Already Trained and Tested combination (val score of 0.4711):
#             {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.4, 'colsample_bylevel': 0.4, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 8}
#             Current best combo (with val score 0.4711):
#                     {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.4, 'colsample_bylevel': 0.4, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 8}
#         Has trained 65 of 244800 combinations so far
# Trained and Tested combination 66 of 244800, taking 0.08 seconds to get val score of 0.4547:
#                 {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.4, 'colsample_bylevel': 0.4, 'reg_lambda': 0.1, 'learning_rate': 0.01, 'features': 8},
#             Current best combo with val score 0.4711:
#                     {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.4, 'colsample_bylevel': 0.4, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 8}
# Trained and Tested combination 67 of 244800, taking 0.08 seconds to get val score of 0.4708:
#                 {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.4, 'colsample_bylevel': 0.4, 'reg_lambda': 1, 'learning_rate': 0.01, 'features': 8},
#             Current best combo with val score 0.4711:
#                     {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.4, 'colsample_bylevel': 0.4, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 8}
#
# Best combo after this hyperparameter: (1, 1, 0, 0, 0, 1, 8) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 1
# Hyperparameter: learning_rate (index: 5)
#
# Trained and Tested combination 68 of 244800, taking 0.08 seconds to get val score of 0.427:
#                 {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.4, 'colsample_bylevel': 0.4, 'reg_lambda': 0.01, 'learning_rate': 0.001, 'features': 8},
#             Current best combo with val score 0.4711:
#                     {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.4, 'colsample_bylevel': 0.4, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 8}
# Already Trained and Tested combination (val score of 0.4711):
#             {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.4, 'colsample_bylevel': 0.4, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 8}
#             Current best combo (with val score 0.4711):
#                     {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.4, 'colsample_bylevel': 0.4, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 8}
#         Has trained 68 of 244800 combinations so far
# Trained and Tested combination 69 of 244800, taking 0.08 seconds to get val score of 0.4626:
#                 {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.4, 'colsample_bylevel': 0.4, 'reg_lambda': 0.01, 'learning_rate': 0.1, 'features': 8},
#             Current best combo with val score 0.4711:
#                     {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.4, 'colsample_bylevel': 0.4, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 8}
# Trained and Tested combination 70 of 244800, taking 0.09 seconds to get val score of 0.3994:
#                 {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.4, 'colsample_bylevel': 0.4, 'reg_lambda': 0.01, 'learning_rate': 1, 'features': 8},
#             Current best combo with val score 0.4711:
#                     {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.4, 'colsample_bylevel': 0.4, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 8}
#
# Best combo after this hyperparameter: (1, 1, 0, 0, 0, 1, 8) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# ROUND 2
#
# Round 2
# Hyperparameter: features (index: 6)
#
# Trained and Tested combination 71 of 244800, taking 0.03 seconds to get val score of 0.0:
#                 {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.4, 'colsample_bylevel': 0.4, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 0},
#             Current best combo with val score 0.4711:
#                     {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.4, 'colsample_bylevel': 0.4, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 8}
# Trained and Tested combination 72 of 244800, taking 0.04 seconds to get val score of 0.0:
#                 {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.4, 'colsample_bylevel': 0.4, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 1},
#             Current best combo with val score 0.4711:
#                     {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.4, 'colsample_bylevel': 0.4, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 8}
# Trained and Tested combination 73 of 244800, taking 0.04 seconds to get val score of 0.0:
#                 {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.4, 'colsample_bylevel': 0.4, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 2},
#             Current best combo with val score 0.4711:
#                     {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.4, 'colsample_bylevel': 0.4, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 8}
# Trained and Tested combination 74 of 244800, taking 0.09 seconds to get val score of 0.0:
#                 {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.4, 'colsample_bylevel': 0.4, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 3},
#             Current best combo with val score 0.4711:
#                     {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.4, 'colsample_bylevel': 0.4, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 8}
# Trained and Tested combination 75 of 244800, taking 0.11 seconds to get val score of 0.0:
#                 {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.4, 'colsample_bylevel': 0.4, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 4},
#             Current best combo with val score 0.4711:
#                     {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.4, 'colsample_bylevel': 0.4, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 8}
# Trained and Tested combination 76 of 244800, taking 0.14 seconds to get val score of 0.4496:
#                 {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.4, 'colsample_bylevel': 0.4, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 5},
#             Current best combo with val score 0.4711:
#                     {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.4, 'colsample_bylevel': 0.4, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 8}
# Trained and Tested combination 77 of 244800, taking 0.12 seconds to get val score of 0.4476:
#                 {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.4, 'colsample_bylevel': 0.4, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 6},
#             Current best combo with val score 0.4711:
#                     {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.4, 'colsample_bylevel': 0.4, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 8}
# Trained and Tested combination 78 of 244800, taking 0.09 seconds to get val score of 0.453:
#                 {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.4, 'colsample_bylevel': 0.4, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 7},
#             Current best combo with val score 0.4711:
#                     {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.4, 'colsample_bylevel': 0.4, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 8}
# Already Trained and Tested combination (val score of 0.4711):
#             {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.4, 'colsample_bylevel': 0.4, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 8}
#             Current best combo (with val score 0.4711):
#                     {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.4, 'colsample_bylevel': 0.4, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 8}
#         Has trained 78 of 244800 combinations so far
# Trained and Tested combination 79 of 244800, taking 0.09 seconds to get val score of 0.4573:
#                 {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.4, 'colsample_bylevel': 0.4, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 9},
#             Current best combo with val score 0.4711:
#                     {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.4, 'colsample_bylevel': 0.4, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 8}
# Trained and Tested combination 80 of 244800, taking 0.09 seconds to get val score of 0.4538:
#                 {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.4, 'colsample_bylevel': 0.4, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 10},
#             Current best combo with val score 0.4711:
#                     {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.4, 'colsample_bylevel': 0.4, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 8}
# Trained and Tested combination 81 of 244800, taking 0.09 seconds to get val score of 0.103:
#                 {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.4, 'colsample_bylevel': 0.4, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 11},
#             Current best combo with val score 0.4711:
#                     {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.4, 'colsample_bylevel': 0.4, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 8}
# Trained and Tested combination 82 of 244800, taking 0.09 seconds to get val score of 0.2434:
#                 {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.4, 'colsample_bylevel': 0.4, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 12},
#             Current best combo with val score 0.4711:
#                     {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.4, 'colsample_bylevel': 0.4, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 8}
# Trained and Tested combination 83 of 244800, taking 0.09 seconds to get val score of 0.3219:
#                 {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.4, 'colsample_bylevel': 0.4, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 13},
#             Current best combo with val score 0.4711:
#                     {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.4, 'colsample_bylevel': 0.4, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 8}
# Trained and Tested combination 84 of 244800, taking 0.11 seconds to get val score of 0.2527:
#                 {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.4, 'colsample_bylevel': 0.4, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 14},
#             Current best combo with val score 0.4711:
#                     {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.4, 'colsample_bylevel': 0.4, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 8}
# Trained and Tested combination 85 of 244800, taking 0.15 seconds to get val score of 0.264:
#                 {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.4, 'colsample_bylevel': 0.4, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 15},
#             Current best combo with val score 0.4711:
#                     {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.4, 'colsample_bylevel': 0.4, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 8}
# Trained and Tested combination 86 of 244800, taking 0.12 seconds to get val score of 0.2175:
#                 {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.4, 'colsample_bylevel': 0.4, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 16},
#             Current best combo with val score 0.4711:
#                     {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.4, 'colsample_bylevel': 0.4, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 8}
# Trained and Tested combination 87 of 244800, taking 0.1 seconds to get val score of 0.282:
#                 {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.4, 'colsample_bylevel': 0.4, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 17},
#             Current best combo with val score 0.4711:
#                     {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.4, 'colsample_bylevel': 0.4, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 8}
# Trained and Tested combination 88 of 244800, taking 0.09 seconds to get val score of 0.1973:
#                 {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.4, 'colsample_bylevel': 0.4, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 18},
#             Current best combo with val score 0.4711:
#                     {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.4, 'colsample_bylevel': 0.4, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 8}
# Trained and Tested combination 89 of 244800, taking 0.09 seconds to get val score of 0.1362:
#                 {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.4, 'colsample_bylevel': 0.4, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 19},
#             Current best combo with val score 0.4711:
#                     {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.4, 'colsample_bylevel': 0.4, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 8}
# Trained and Tested combination 90 of 244800, taking 0.11 seconds to get val score of 0.2018:
#                 {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.4, 'colsample_bylevel': 0.4, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 20},
#             Current best combo with val score 0.4711:
#                     {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.4, 'colsample_bylevel': 0.4, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 8}
# Trained and Tested combination 91 of 244800, taking 0.12 seconds to get val score of 0.1491:
#                 {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.4, 'colsample_bylevel': 0.4, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 21},
#             Current best combo with val score 0.4711:
#                     {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.4, 'colsample_bylevel': 0.4, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 8}
# Trained and Tested combination 92 of 244800, taking 0.1 seconds to get val score of 0.075:
#                 {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.4, 'colsample_bylevel': 0.4, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 22},
#             Current best combo with val score 0.4711:
#                     {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.4, 'colsample_bylevel': 0.4, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 8}
# Trained and Tested combination 93 of 244800, taking 0.12 seconds to get val score of 0.0881:
#                 {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.4, 'colsample_bylevel': 0.4, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 23},
#             Current best combo with val score 0.4711:
#                     {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.4, 'colsample_bylevel': 0.4, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 8}
# Trained and Tested combination 94 of 244800, taking 0.18 seconds to get val score of 0.0258:
# ...
#             Current best combo with val score 0.4711:
#                     {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.4, 'colsample_bylevel': 0.4, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 8}
# Trained and Tested combination 119 of 244800, taking 0.12 seconds to get val score of 0.1252:
#                 {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.4, 'colsample_bylevel': 0.4, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 49},
#             Current best combo with val score 0.4711:
#                     {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.4, 'colsample_bylevel': 0.4, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 8}
# Trained and Tested combination 120 of 244800, taking 0.13 seconds to get val score of 0.1224:
#                 {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.4, 'colsample_bylevel': 0.4, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 50},
#             Current best combo with val score 0.4711:
#                     {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.4, 'colsample_bylevel': 0.4, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 8}
#
# Best combo after this hyperparameter: (1, 1, 0, 0, 0, 1, 8) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 2
# Hyperparameter: max_depth (index: 1)
#
# Trained and Tested combination 121 of 244800, taking 0.08 seconds to get val score of 0.1009:
#                 {'n_estimators': 50, 'max_depth': 2, 'subsample': 0.4, 'colsample_bylevel': 0.4, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 8},
#             Current best combo with val score 0.4711:
#                     {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.4, 'colsample_bylevel': 0.4, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 8}
# Already Trained and Tested combination (val score of 0.4711):
#             {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.4, 'colsample_bylevel': 0.4, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 8}
#             Current best combo (with val score 0.4711):
#                     {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.4, 'colsample_bylevel': 0.4, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 8}
#         Has trained 121 of 244800 combinations so far
# Trained and Tested combination 122 of 244800, taking 0.12 seconds to get val score of 0.4605:
#                 {'n_estimators': 50, 'max_depth': 8, 'subsample': 0.4, 'colsample_bylevel': 0.4, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 8},
#             Current best combo with val score 0.4711:
#                     {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.4, 'colsample_bylevel': 0.4, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 8}
# Trained and Tested combination 123 of 244800, taking 3.71 seconds to get val score of 0.4633:
#                 {'n_estimators': 50, 'max_depth': 16, 'subsample': 0.4, 'colsample_bylevel': 0.4, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 8},
#             Current best combo with val score 0.4711:
#                     {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.4, 'colsample_bylevel': 0.4, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 8}
#
# Best combo after this hyperparameter: (1, 1, 0, 0, 0, 1, 8) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 2
# Hyperparameter: colsample_bylevel (index: 3)
#
# Already Trained and Tested combination (val score of 0.4711):
#             {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.4, 'colsample_bylevel': 0.4, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 8}
#             Current best combo (with val score 0.4711):
#                     {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.4, 'colsample_bylevel': 0.4, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 8}
#         Has trained 123 of 244800 combinations so far
# Trained and Tested combination 124 of 244800, taking 0.08 seconds to get val score of 0.4587:
#                 {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.4, 'colsample_bylevel': 0.55, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 8},
#             Current best combo with val score 0.4711:
#                     {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.4, 'colsample_bylevel': 0.4, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 8}
# Trained and Tested combination 125 of 244800, taking 0.09 seconds to get val score of 0.4591:
#                 {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.4, 'colsample_bylevel': 0.7, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 8},
#             Current best combo with val score 0.4711:
#                     {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.4, 'colsample_bylevel': 0.4, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 8}
# Trained and Tested combination 126 of 244800, taking 0.09 seconds to get val score of 0.4622:
#                 {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.4, 'colsample_bylevel': 0.85, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 8},
#             Current best combo with val score 0.4711:
#                     {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.4, 'colsample_bylevel': 0.4, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 8}
# Trained and Tested combination 127 of 244800, taking 0.08 seconds to get val score of 0.4573:
#                 {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.4, 'colsample_bylevel': 1, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 8},
#             Current best combo with val score 0.4711:
#                     {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.4, 'colsample_bylevel': 0.4, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 8}
#
# Best combo after this hyperparameter: (1, 1, 0, 0, 0, 1, 8) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 2
# Hyperparameter: subsample (index: 2)
#
# Already Trained and Tested combination (val score of 0.4711):
#             {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.4, 'colsample_bylevel': 0.4, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 8}
#             Current best combo (with val score 0.4711):
#                     {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.4, 'colsample_bylevel': 0.4, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 8}
#         Has trained 127 of 244800 combinations so far
# Already Trained and Tested combination (val score of 0.4525):
#             {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.55, 'colsample_bylevel': 0.4, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 8}
#             Current best combo (with val score 0.4711):
#                     {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.4, 'colsample_bylevel': 0.4, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 8}
#         Has trained 127 of 244800 combinations so far
# Already Trained and Tested combination (val score of 0.4647):
#             {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.7, 'colsample_bylevel': 0.4, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 8}
#             Current best combo (with val score 0.4711):
#                     {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.4, 'colsample_bylevel': 0.4, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 8}
#         Has trained 127 of 244800 combinations so far
# Already Trained and Tested combination (val score of 0.4581):
#             {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.85, 'colsample_bylevel': 0.4, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 8}
#             Current best combo (with val score 0.4711):
#                     {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.4, 'colsample_bylevel': 0.4, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 8}
#         Has trained 127 of 244800 combinations so far
# Already Trained and Tested combination (val score of 0.4405):
#             {'n_estimators': 50, 'max_depth': 4, 'subsample': 1, 'colsample_bylevel': 0.4, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 8}
#             Current best combo (with val score 0.4711):
#                     {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.4, 'colsample_bylevel': 0.4, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 8}
#         Has trained 127 of 244800 combinations so far
#
# Best combo after this hyperparameter: (1, 1, 0, 0, 0, 1, 8) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 2
# Hyperparameter: n_estimators (index: 0)
#
# Already Trained and Tested combination (val score of 0.4582):
#             {'n_estimators': 25, 'max_depth': 4, 'subsample': 0.4, 'colsample_bylevel': 0.4, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 8}
#             Current best combo (with val score 0.4711):
#                     {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.4, 'colsample_bylevel': 0.4, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 8}
#         Has trained 127 of 244800 combinations so far
# Already Trained and Tested combination (val score of 0.4711):
#             {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.4, 'colsample_bylevel': 0.4, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 8}
#             Current best combo (with val score 0.4711):
#                     {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.4, 'colsample_bylevel': 0.4, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 8}
#         Has trained 127 of 244800 combinations so far
# Already Trained and Tested combination (val score of 0.4632):
#             {'n_estimators': 100, 'max_depth': 4, 'subsample': 0.4, 'colsample_bylevel': 0.4, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 8}
#             Current best combo (with val score 0.4711):
#                     {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.4, 'colsample_bylevel': 0.4, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 8}
#         Has trained 127 of 244800 combinations so far
# Already Trained and Tested combination (val score of 0.4671):
#             {'n_estimators': 200, 'max_depth': 4, 'subsample': 0.4, 'colsample_bylevel': 0.4, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 8}
#             Current best combo (with val score 0.4711):
#                     {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.4, 'colsample_bylevel': 0.4, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 8}
#         Has trained 127 of 244800 combinations so far
#
# Best combo after this hyperparameter: (1, 1, 0, 0, 0, 1, 8) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 2
# Hyperparameter: reg_lambda (index: 4)
#
# Already Trained and Tested combination (val score of 0.4711):
#             {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.4, 'colsample_bylevel': 0.4, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 8}
#             Current best combo (with val score 0.4711):
#                     {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.4, 'colsample_bylevel': 0.4, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 8}
#         Has trained 127 of 244800 combinations so far
# Already Trained and Tested combination (val score of 0.4547):
#             {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.4, 'colsample_bylevel': 0.4, 'reg_lambda': 0.1, 'learning_rate': 0.01, 'features': 8}
#             Current best combo (with val score 0.4711):
#                     {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.4, 'colsample_bylevel': 0.4, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 8}
#         Has trained 127 of 244800 combinations so far
# Already Trained and Tested combination (val score of 0.4708):
#             {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.4, 'colsample_bylevel': 0.4, 'reg_lambda': 1, 'learning_rate': 0.01, 'features': 8}
#             Current best combo (with val score 0.4711):
#                     {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.4, 'colsample_bylevel': 0.4, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 8}
#         Has trained 127 of 244800 combinations so far
#
# Best combo after this hyperparameter: (1, 1, 0, 0, 0, 1, 8) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 2
# Hyperparameter: learning_rate (index: 5)
#
# Already Trained and Tested combination (val score of 0.427):
#             {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.4, 'colsample_bylevel': 0.4, 'reg_lambda': 0.01, 'learning_rate': 0.001, 'features': 8}
#             Current best combo (with val score 0.4711):
#                     {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.4, 'colsample_bylevel': 0.4, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 8}
#         Has trained 127 of 244800 combinations so far
# Already Trained and Tested combination (val score of 0.4711):
#             {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.4, 'colsample_bylevel': 0.4, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 8}
#             Current best combo (with val score 0.4711):
#                     {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.4, 'colsample_bylevel': 0.4, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 8}
#         Has trained 127 of 244800 combinations so far
# Already Trained and Tested combination (val score of 0.4626):
#             {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.4, 'colsample_bylevel': 0.4, 'reg_lambda': 0.01, 'learning_rate': 0.1, 'features': 8}
#             Current best combo (with val score 0.4711):
#                     {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.4, 'colsample_bylevel': 0.4, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 8}
#         Has trained 127 of 244800 combinations so far
# Already Trained and Tested combination (val score of 0.3994):
#             {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.4, 'colsample_bylevel': 0.4, 'reg_lambda': 0.01, 'learning_rate': 1, 'features': 8}
#             Current best combo (with val score 0.4711):
#                     {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.4, 'colsample_bylevel': 0.4, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 8}
#         Has trained 127 of 244800 combinations so far
#
# Best combo after this hyperparameter: (1, 1, 0, 0, 0, 1, 8) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
# Max Val Score:
#  0.471054
# Max Val Score Std:
#  0.050395
# Best Combo Train Score:
#  0.407204
# Best Combo Train Score Std:
#  0.019294
# Max Combo Index:
#  (1, 1, 0, 0, 0, 1, 8) out of [4, 4, 5, 5, 3, 4, 51] (note best combo is 0-indexed)
# Max Combo Hyperparamer Combination:
#  {'n_estimators': 50, 'max_depth': 4, 'subsample': 0.4, 'colsample_bylevel': 0.4, 'reg_lambda': 0.01, 'learning_rate': 0.01, 'features': 8}
# Max Combo Features:
#  ('procedure_225792', 'ventilation_used', 'lods_score', 'race_AMERICAN INDIAN/ALASKA NATIVE', 'race_ASIAN', 'race_ASIAN - ASIAN INDIAN', 'race_ASIAN - CHINESE', 'race_ASIAN - KOREAN', 'race_ASIAN - SOUTH EAST ASIAN', 'race_BLACK/AFRICAN', 'race_BLACK/AFRICAN AMERICAN', 'race_BLACK/CAPE VERDEAN', 'race_BLACK/CARIBBEAN ISLAND', 'race_HISPANIC/LATINO - CENTRAL AMERICAN', 'race_HISPANIC/LATINO - COLUMBIAN', 'race_HISPANIC/LATINO - CUBAN', 'race_HISPANIC/LATINO - DOMINICAN', 'race_HISPANIC/LATINO - GUATEMALAN', 'race_HISPANIC/LATINO - HONDURAN', 'race_HISPANIC/LATINO - MEXICAN', 'race_HISPANIC/LATINO - PUERTO RICAN', 'race_HISPANIC/LATINO - SALVADORAN', 'race_MULTIPLE RACE/ETHNICITY', 'race_NATIVE HAWAIIAN OR OTHER PACIFIC ISLANDER', 'race_OTHER', 'race_PATIENT DECLINED TO ANSWER', 'race_PORTUGUESE', 'race_SOUTH AMERICAN', 'race_UNABLE TO OBTAIN', 'race_UNKNOWN', 'race_WHITE', 'race_WHITE - BRAZILIAN', 'race_WHITE - EASTERN EUROPEAN', 'race_WHITE - OTHER EUROPEAN', 'race_WHITE - RUSSIAN', 'race_HISPANIC OR LATINO', 'marital_status_DIVORCED', 'marital_status_MARRIED', 'marital_status_SINGLE', 'marital_status_WIDOWED', 'marital_status_0', 'hospital_stay_duration', 'procedure_225464', 'procedure_225802', 'procedure_227712')
# % Combos Checked: 127 out of 244800 which is 0.051879%
