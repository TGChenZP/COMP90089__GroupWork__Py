# %% [markdown]
# # Tuning Script

# %%
# Parameters subject to change in every script - involved in naming

MODEL = 'lda'
PREPROCESSING = 'normalise'
TUNER = 'yangzhoub'
OPTIMISED_METRIC = 'f1'

# %% [markdown]
# ---

# %%
# detect whether this is a google environment

COLAB_ENVIRONMENT = False

try:
    from google.colab import drive
    drive.mount('/content/drive')
    COLAB_ENVIRONMENT = True
except:
    pass
# Out:
# Mounted at /content/drive

# %%
import sys
import os
import pickle

if COLAB_ENVIRONMENT:
    home_directory = './drive/MyDrive/LAB/COMP90089__GroupWork__Py/' # my home directory is stored in ./LAB of google drive
    if MODEL == 'ebr':
        # !pip install interpret==0.5.0
    elif MODEL == 'cbr':
        # !pip install catboost
    elif MODEL in ['tf', 'mlp']:
        # !pip install PyTorch2Sklearn
    # !pip install JXAutoML
else:
    home_directory = '../../'

from JXAutoML.YangZhouB_10CV import YangZhouB_10CV as Tuner

import pandas as pd
# Out:
# Collecting JXAutoML
#   Downloading JXAutoML-0.4.4-py3-none-any.whl.metadata (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.2/67.2 kB 2.9 MB/s eta 0:00:00
# Downloading JXAutoML-0.4.4-py3-none-any.whl (52 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.1/52.1 kB 5.2 MB/s eta 0:00:00
# Installing collected packages: JXAutoML
# Successfully installed JXAutoML-0.4.4

# %%
# Parameters that are same for every script

FOLDS = 10  # we have decided to do 10 fold validation

SEED = 42

TASK_TYPE = 'Classification'  # this task is a classification task

# we have decided to tune features as hp
TUNE_FEATURES_AS_HYPERPARAMETERS = True

# %% [markdown]
# ---

# %%
# model to use to tune
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as clf

# what values to try for each hyperparameter
parameter_choices = {
    'tol': (0.00001, 0.0001, 0.001, 0.01, 0.1, 1, 10),
    'solver': ('eigen', 'lsqr')
}

# what values to set non-tuneable parameters/hyperparameters
non_tunable_hyperparameters_dict = {
    'shrinkage': 'auto',

}

# %% [markdown]
# ---

# %% [markdown]
# Read in and Prepare Data

# %%
# Import data and store as lists

train_x_list = []
train_y_list = []
val_x_list = []
val_y_list = []

for i in range(FOLDS):
    train_data = pd.read_csv(
        f'{home_directory}data/curated/modelling/{PREPROCESSING}/train_{i}.csv')
    val_data = pd.read_csv(
        f'{home_directory}data/curated/modelling/{PREPROCESSING}/val_{i}.csv')

    # get the correct rows for X and y
    train_x = train_data.drop(
        ['mortality_status', 'subject_id', 'hadm_id', 'stay_id'], axis=1)
    train_y = train_data['mortality_status']
    val_x = val_data.drop(
        ['mortality_status', 'subject_id', 'hadm_id', 'stay_id'], axis=1)
    val_y = val_data['mortality_status']

    train_x_list.append(train_x)
    train_y_list.append(train_y)
    val_x_list.append(val_x)
    val_y_list.append(val_y)

# %%
# Import feature importance ordering

with open(f'{home_directory}models/xgb_feature_importance_ordering_{PREPROCESSING}.pickle', 'rb') as f:
    feature_importance_ordering = pickle.load(f)

# %% [markdown]
# Set parameters

# %%
# initialisation
tuner = Tuner()

print('---')

# define what model we are tuning
tuner.read_in_model(clf, TASK_TYPE, optimised_metric=OPTIMISED_METRIC)

print('---')

# read in the data for training and validation
tuner.read_in_data(train_x_list, train_y_list, val_x_list, val_y_list)

print('---')

# set what hp values to tune
tuner.set_hyperparameters(parameter_choices)
# WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

# set up hp values that need to be changed from default but NOT to be tuned
tuner.set_non_tuneable_hyperparameters(non_tunable_hyperparameters_dict)

print('---')

# set up feature importance ordering

if TUNE_FEATURES_AS_HYPERPARAMETERS:
    tuner.set_features(feature_importance_ordering)
    # WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

try:  # try to read in previous results to continue tuning ...
    tuner.read_in_tuning_result_df(
        f'{home_directory}models/tuning/{TUNER}_{MODEL}_{PREPROCESSING}.csv')
except:
    print('No previous tuning data read in')

print('---')

# set up where to save the tuning result csv
tuner.set_tuning_result_saving_address(
    f'{home_directory}models/tuning/{TUNER}_{MODEL}_{PREPROCESSING}.csv')

print('---')

# set up where to save the current best model
tuner.set_best_model_saving_address(
    f'{home_directory}models/tmp_models/{TUNER}_{MODEL}_{PREPROCESSING}')
# Out:
# YangZhouB Initialised
# ---
# Successfully read in model <class 'sklearn.discriminant_analysis.LinearDiscriminantAnalysis'>, which is a Classification model optimising for f1
# ---
# Read in Train X data list
# Read in Train y data list
# Read in Val X data list
# Read in Val y data list
# ---
# Successfully recorded hyperparameter choices
# ---
# Successfully recorded non_tuneable_hyperparameter choices
# ---
# Successfully recorded tuneable feature combination choices and updated relevant internal structures
# ---
# No previous tuning data read in
# ---
# Successfully set tuning output address
# ---
# Successfully set best model output address

# %%
# ignore warnings

import warnings
warnings.filterwarnings("ignore")

# %%
# begin tuning ... (or continue training)

tuner.tune()
# Out:
# BEGIN TUNING
#
#
# STAGE ZERO: Tune all Cruise combinations
#
#
# Trained and Tested combination 1 of 714, taking 0.13 seconds to get val score of 0.0:
#                 {'tol': 10, 'solver': 'eigen', 'features': 35},
#             Current best combo with val score 0.0:
#                     {'tol': 10, 'solver': 'eigen', 'features': 35}
# Trained and Tested combination 2 of 714, taking 0.05 seconds to get val score of 0.0:
#                 {'tol': 10, 'solver': 'lsqr', 'features': 50},
#             Current best combo with val score 0.0:
#                     {'tol': 10, 'solver': 'eigen', 'features': 35}
# Trained and Tested combination 3 of 714, taking 0.14 seconds to get val score of 0.0:
#                 {'tol': 1e-05, 'solver': 'lsqr', 'features': 40},
#             Current best combo with val score 0.0:
#                     {'tol': 10, 'solver': 'eigen', 'features': 35}
# Trained and Tested combination 4 of 714, taking 0.09 seconds to get val score of 0.0033:
#                 {'tol': 10, 'solver': 'eigen', 'features': 30},
#             Current best combo with val score 0.0033:
#                     {'tol': 10, 'solver': 'eigen', 'features': 30}
# Trained and Tested combination 5 of 714, taking 0.22 seconds to get val score of 0.0033:
#                 {'tol': 1e-05, 'solver': 'lsqr', 'features': 30},
#             Current best combo with val score 0.0033:
#                     {'tol': 10, 'solver': 'eigen', 'features': 30}
# Trained and Tested combination 6 of 714, taking 0.21 seconds to get val score of 0.0:
#                 {'tol': 1e-05, 'solver': 'lsqr', 'features': 50},
#             Current best combo with val score 0.0033:
#                     {'tol': 10, 'solver': 'eigen', 'features': 30}
# Trained and Tested combination 7 of 714, taking 0.14 seconds to get val score of 0.0:
#                 {'tol': 1e-05, 'solver': 'eigen', 'features': 50},
#             Current best combo with val score 0.0033:
#                     {'tol': 10, 'solver': 'eigen', 'features': 30}
# Trained and Tested combination 8 of 714, taking 0.16 seconds to get val score of 0.0:
#                 {'tol': 1e-05, 'solver': 'eigen', 'features': 40},
#             Current best combo with val score 0.0033:
#                     {'tol': 10, 'solver': 'eigen', 'features': 30}
# Trained and Tested combination 9 of 714, taking 0.04 seconds to get val score of 0.0033:
#                 {'tol': 0.01, 'solver': 'lsqr', 'features': 25},
#             Current best combo with val score 0.0033:
#                     {'tol': 10, 'solver': 'eigen', 'features': 30}
# Trained and Tested combination 10 of 714, taking 0.08 seconds to get val score of 0.0:
#                 {'tol': 1e-05, 'solver': 'eigen', 'features': 45},
#             Current best combo with val score 0.0033:
#                     {'tol': 10, 'solver': 'eigen', 'features': 30}
# Trained and Tested combination 11 of 714, taking 0.06 seconds to get val score of 0.023:
#                 {'tol': 0.01, 'solver': 'eigen', 'features': 15},
#             Current best combo with val score 0.023:
#                     {'tol': 0.01, 'solver': 'eigen', 'features': 15}
# Trained and Tested combination 12 of 714, taking 0.03 seconds to get val score of 0.2185:
#                 {'tol': 1e-05, 'solver': 'lsqr', 'features': 10},
#             Current best combo with val score 0.2185:
#                     {'tol': 1e-05, 'solver': 'lsqr', 'features': 10}
# Trained and Tested combination 13 of 714, taking 0.32 seconds to get val score of 0.0033:
#                 {'tol': 0.01, 'solver': 'lsqr', 'features': 30},
#             Current best combo with val score 0.2185:
#                     {'tol': 1e-05, 'solver': 'lsqr', 'features': 10}
# Trained and Tested combination 14 of 714, taking 0.42 seconds to get val score of 0.0263:
#                 {'tol': 0.01, 'solver': 'lsqr', 'features': 20},
#             Current best combo with val score 0.2185:
#                     {'tol': 1e-05, 'solver': 'lsqr', 'features': 10}
# Trained and Tested combination 15 of 714, taking 0.0 seconds to get val score of 0.0:
#                 {'tol': 10, 'solver': 'eigen', 'features': 0},
#             Current best combo with val score 0.2185:
#                     {'tol': 1e-05, 'solver': 'lsqr', 'features': 10}
# Trained and Tested combination 16 of 714, taking 0.04 seconds to get val score of 0.0263:
#                 {'tol': 0.01, 'solver': 'eigen', 'features': 20},
#             Current best combo with val score 0.2185:
#                     {'tol': 1e-05, 'solver': 'lsqr', 'features': 10}
# Trained and Tested combination 17 of 714, taking 0.03 seconds to get val score of 0.023:
#                 {'tol': 10, 'solver': 'lsqr', 'features': 15},
#             Current best combo with val score 0.2185:
#                     {'tol': 1e-05, 'solver': 'lsqr', 'features': 10}
# Trained and Tested combination 18 of 714, taking 0.02 seconds to get val score of 0.1905:
#                 {'tol': 10, 'solver': 'lsqr', 'features': 5},
#             Current best combo with val score 0.2185:
#                     {'tol': 1e-05, 'solver': 'lsqr', 'features': 10}
# Trained and Tested combination 19 of 714, taking 0.0 seconds to get val score of 0.0:
#                 {'tol': 1e-05, 'solver': 'lsqr', 'features': 0},
#             Current best combo with val score 0.2185:
#                     {'tol': 1e-05, 'solver': 'lsqr', 'features': 10}
# Trained and Tested combination 20 of 714, taking 0.05 seconds to get val score of 0.2185:
#                 {'tol': 10, 'solver': 'eigen', 'features': 10},
#             Current best combo with val score 0.2185:
#                     {'tol': 1e-05, 'solver': 'lsqr', 'features': 10}
# Trained and Tested combination 21 of 714, taking 0.05 seconds to get val score of 0.0:
#                 {'tol': 0.01, 'solver': 'eigen', 'features': 35},
#             Current best combo with val score 0.2185:
#                     {'tol': 1e-05, 'solver': 'lsqr', 'features': 10}
# Trained and Tested combination 22 of 714, taking 0.04 seconds to get val score of 0.0033:
#                 {'tol': 10, 'solver': 'lsqr', 'features': 30},
#             Current best combo with val score 0.2185:
#                     {'tol': 1e-05, 'solver': 'lsqr', 'features': 10}
# Trained and Tested combination 23 of 714, taking 0.0 seconds to get val score of 0.0:
#                 {'tol': 0.01, 'solver': 'eigen', 'features': 0},
#             Current best combo with val score 0.2185:
#                     {'tol': 1e-05, 'solver': 'lsqr', 'features': 10}
# Trained and Tested combination 24 of 714, taking 0.2 seconds to get val score of 0.0:
#                 {'tol': 10, 'solver': 'lsqr', 'features': 40},
#             Current best combo with val score 0.2185:
#                     {'tol': 1e-05, 'solver': 'lsqr', 'features': 10}
# Trained and Tested combination 25 of 714, taking 0.02 seconds to get val score of 0.1905:
#                 {'tol': 0.01, 'solver': 'lsqr', 'features': 5},
#             Current best combo with val score 0.2185:
#                     {'tol': 1e-05, 'solver': 'lsqr', 'features': 10}
# Trained and Tested combination 26 of 714, taking 0.03 seconds to get val score of 0.0033:
#                 {'tol': 1e-05, 'solver': 'lsqr', 'features': 25},
#             Current best combo with val score 0.2185:
#                     {'tol': 1e-05, 'solver': 'lsqr', 'features': 10}
# Trained and Tested combination 27 of 714, taking 0.05 seconds to get val score of 0.0263:
#                 {'tol': 1e-05, 'solver': 'eigen', 'features': 20},
#             Current best combo with val score 0.2185:
#                     {'tol': 1e-05, 'solver': 'lsqr', 'features': 10}
# Trained and Tested combination 28 of 714, taking 0.03 seconds to get val score of 0.2185:
#                 {'tol': 0.01, 'solver': 'lsqr', 'features': 10},
#             Current best combo with val score 0.2185:
#                     {'tol': 1e-05, 'solver': 'lsqr', 'features': 10}
# Trained and Tested combination 29 of 714, taking 0.06 seconds to get val score of 0.0263:
#                 {'tol': 10, 'solver': 'eigen', 'features': 20},
#             Current best combo with val score 0.2185:
#                     {'tol': 1e-05, 'solver': 'lsqr', 'features': 10}
# Trained and Tested combination 30 of 714, taking 0.06 seconds to get val score of 0.0:
#                 {'tol': 10, 'solver': 'eigen', 'features': 40},
#             Current best combo with val score 0.2185:
#                     {'tol': 1e-05, 'solver': 'lsqr', 'features': 10}
# Trained and Tested combination 31 of 714, taking 0.13 seconds to get val score of 0.0:
#                 {'tol': 1e-05, 'solver': 'lsqr', 'features': 35},
#             Current best combo with val score 0.2185:
#                     {'tol': 1e-05, 'solver': 'lsqr', 'features': 10}
# Trained and Tested combination 32 of 714, taking 0.07 seconds to get val score of 0.0:
#                 {'tol': 0.01, 'solver': 'lsqr', 'features': 50},
#             Current best combo with val score 0.2185:
#                     {'tol': 1e-05, 'solver': 'lsqr', 'features': 10}
# Trained and Tested combination 33 of 714, taking 0.21 seconds to get val score of 0.0033:
#                 {'tol': 10, 'solver': 'eigen', 'features': 25},
#             Current best combo with val score 0.2185:
#                     {'tol': 1e-05, 'solver': 'lsqr', 'features': 10}
# Trained and Tested combination 34 of 714, taking 0.55 seconds to get val score of 0.0:
#                 {'tol': 10, 'solver': 'eigen', 'features': 45},
#             Current best combo with val score 0.2185:
#                     {'tol': 1e-05, 'solver': 'lsqr', 'features': 10}
# Trained and Tested combination 35 of 714, taking 0.04 seconds to get val score of 0.0:
#                 {'tol': 1e-05, 'solver': 'lsqr', 'features': 45},
#             Current best combo with val score 0.2185:
#                     {'tol': 1e-05, 'solver': 'lsqr', 'features': 10}
# Trained and Tested combination 36 of 714, taking 0.04 seconds to get val score of 0.0:
#                 {'tol': 10, 'solver': 'lsqr', 'features': 35},
#             Current best combo with val score 0.2185:
#                     {'tol': 1e-05, 'solver': 'lsqr', 'features': 10}
# Trained and Tested combination 37 of 714, taking 0.08 seconds to get val score of 0.0:
#                 {'tol': 0.01, 'solver': 'eigen', 'features': 45},
#             Current best combo with val score 0.2185:
#                     {'tol': 1e-05, 'solver': 'lsqr', 'features': 10}
# Trained and Tested combination 38 of 714, taking 0.05 seconds to get val score of 0.0033:
#                 {'tol': 0.01, 'solver': 'eigen', 'features': 25},
#             Current best combo with val score 0.2185:
#                     {'tol': 1e-05, 'solver': 'lsqr', 'features': 10}
# Trained and Tested combination 39 of 714, taking 0.04 seconds to get val score of 0.2185:
#                 {'tol': 0.01, 'solver': 'eigen', 'features': 10},
#             Current best combo with val score 0.2185:
#                     {'tol': 1e-05, 'solver': 'lsqr', 'features': 10}
# Trained and Tested combination 40 of 714, taking 0.17 seconds to get val score of 0.0:
#                 {'tol': 0.01, 'solver': 'eigen', 'features': 50},
#             Current best combo with val score 0.2185:
#                     {'tol': 1e-05, 'solver': 'lsqr', 'features': 10}
# Trained and Tested combination 41 of 714, taking 0.25 seconds to get val score of 0.023:
#                 {'tol': 1e-05, 'solver': 'lsqr', 'features': 15},
#             Current best combo with val score 0.2185:
#                     {'tol': 1e-05, 'solver': 'lsqr', 'features': 10}
# Trained and Tested combination 42 of 714, taking 0.07 seconds to get val score of 0.2185:
#                 {'tol': 1e-05, 'solver': 'eigen', 'features': 10},
#             Current best combo with val score 0.2185:
#                     {'tol': 1e-05, 'solver': 'lsqr', 'features': 10}
# Trained and Tested combination 43 of 714, taking 0.06 seconds to get val score of 0.0033:
#                 {'tol': 1e-05, 'solver': 'eigen', 'features': 30},
#             Current best combo with val score 0.2185:
#                     {'tol': 1e-05, 'solver': 'lsqr', 'features': 10}
# Trained and Tested combination 44 of 714, taking 0.0 seconds to get val score of 0.0:
#                 {'tol': 1e-05, 'solver': 'eigen', 'features': 0},
#             Current best combo with val score 0.2185:
#                     {'tol': 1e-05, 'solver': 'lsqr', 'features': 10}
# Trained and Tested combination 45 of 714, taking 0.06 seconds to get val score of 0.0:
#                 {'tol': 10, 'solver': 'eigen', 'features': 50},
#             Current best combo with val score 0.2185:
#                     {'tol': 1e-05, 'solver': 'lsqr', 'features': 10}
# Trained and Tested combination 46 of 714, taking 0.03 seconds to get val score of 0.1905:
#                 {'tol': 0.01, 'solver': 'eigen', 'features': 5},
#             Current best combo with val score 0.2185:
#                     {'tol': 1e-05, 'solver': 'lsqr', 'features': 10}
# Trained and Tested combination 47 of 714, taking 0.03 seconds to get val score of 0.2185:
#                 {'tol': 10, 'solver': 'lsqr', 'features': 10},
#             Current best combo with val score 0.2185:
#                     {'tol': 1e-05, 'solver': 'lsqr', 'features': 10}
# Trained and Tested combination 48 of 714, taking 0.0 seconds to get val score of 0.0:
#                 {'tol': 0.01, 'solver': 'lsqr', 'features': 0},
#             Current best combo with val score 0.2185:
#                     {'tol': 1e-05, 'solver': 'lsqr', 'features': 10}
# Trained and Tested combination 49 of 714, taking 0.02 seconds to get val score of 0.1905:
#                 {'tol': 1e-05, 'solver': 'lsqr', 'features': 5},
#             Current best combo with val score 0.2185:
#                     {'tol': 1e-05, 'solver': 'lsqr', 'features': 10}
# Trained and Tested combination 50 of 714, taking 0.0 seconds to get val score of 0.0:
#                 {'tol': 10, 'solver': 'lsqr', 'features': 0},
#             Current best combo with val score 0.2185:
#                     {'tol': 1e-05, 'solver': 'lsqr', 'features': 10}
# Trained and Tested combination 51 of 714, taking 0.04 seconds to get val score of 0.023:
#                 {'tol': 1e-05, 'solver': 'eigen', 'features': 15},
#             Current best combo with val score 0.2185:
#                     {'tol': 1e-05, 'solver': 'lsqr', 'features': 10}
# Trained and Tested combination 52 of 714, taking 0.06 seconds to get val score of 0.0:
#                 {'tol': 0.01, 'solver': 'eigen', 'features': 40},
#             Current best combo with val score 0.2185:
#                     {'tol': 1e-05, 'solver': 'lsqr', 'features': 10}
# Trained and Tested combination 53 of 714, taking 0.06 seconds to get val score of 0.0263:
#                 {'tol': 1e-05, 'solver': 'lsqr', 'features': 20},
#             Current best combo with val score 0.2185:
#                     {'tol': 1e-05, 'solver': 'lsqr', 'features': 10}
# Trained and Tested combination 54 of 714, taking 0.05 seconds to get val score of 0.1905:
#                 {'tol': 10, 'solver': 'eigen', 'features': 5},
#             Current best combo with val score 0.2185:
#                     {'tol': 1e-05, 'solver': 'lsqr', 'features': 10}
# Trained and Tested combination 55 of 714, taking 0.04 seconds to get val score of 0.0033:
#                 {'tol': 10, 'solver': 'lsqr', 'features': 25},
#             Current best combo with val score 0.2185:
#                     {'tol': 1e-05, 'solver': 'lsqr', 'features': 10}
# Trained and Tested combination 56 of 714, taking 0.06 seconds to get val score of 0.0:
#                 {'tol': 1e-05, 'solver': 'eigen', 'features': 35},
#             Current best combo with val score 0.2185:
#                     {'tol': 1e-05, 'solver': 'lsqr', 'features': 10}
# Trained and Tested combination 57 of 714, taking 0.16 seconds to get val score of 0.0:
#                 {'tol': 0.01, 'solver': 'lsqr', 'features': 35},
#             Current best combo with val score 0.2185:
#                     {'tol': 1e-05, 'solver': 'lsqr', 'features': 10}
# Trained and Tested combination 58 of 714, taking 0.1 seconds to get val score of 0.0033:
#                 {'tol': 0.01, 'solver': 'eigen', 'features': 30},
#             Current best combo with val score 0.2185:
#                     {'tol': 1e-05, 'solver': 'lsqr', 'features': 10}
# Trained and Tested combination 59 of 714, taking 0.05 seconds to get val score of 0.0033:
#                 {'tol': 1e-05, 'solver': 'eigen', 'features': 25},
#             Current best combo with val score 0.2185:
#                     {'tol': 1e-05, 'solver': 'lsqr', 'features': 10}
# Trained and Tested combination 60 of 714, taking 0.03 seconds to get val score of 0.1905:
#                 {'tol': 1e-05, 'solver': 'eigen', 'features': 5},
#             Current best combo with val score 0.2185:
#                     {'tol': 1e-05, 'solver': 'lsqr', 'features': 10}
# Trained and Tested combination 61 of 714, taking 0.03 seconds to get val score of 0.0263:
#                 {'tol': 10, 'solver': 'lsqr', 'features': 20},
#             Current best combo with val score 0.2185:
#                     {'tol': 1e-05, 'solver': 'lsqr', 'features': 10}
# Trained and Tested combination 62 of 714, taking 0.05 seconds to get val score of 0.0:
#                 {'tol': 0.01, 'solver': 'lsqr', 'features': 40},
#             Current best combo with val score 0.2185:
#                     {'tol': 1e-05, 'solver': 'lsqr', 'features': 10}
# Trained and Tested combination 63 of 714, taking 0.15 seconds to get val score of 0.023:
#                 {'tol': 0.01, 'solver': 'lsqr', 'features': 15},
#             Current best combo with val score 0.2185:
#                     {'tol': 1e-05, 'solver': 'lsqr', 'features': 10}
# Trained and Tested combination 64 of 714, taking 0.05 seconds to get val score of 0.0:
#                 {'tol': 0.01, 'solver': 'lsqr', 'features': 45},
#             Current best combo with val score 0.2185:
#                     {'tol': 1e-05, 'solver': 'lsqr', 'features': 10}
# Already Trained and Tested combination (val score of 0.0033):
#             {'tol': 0.01, 'solver': 'lsqr', 'features': 25}
#             Current best combo (with val score 0.2185):
#                     {'tol': 1e-05, 'solver': 'lsqr', 'features': 10}
#         Has trained 64 of 714 combinations so far
# Trained and Tested combination 65 of 714, taking 0.08 seconds to get val score of 0.023:
#                 {'tol': 10, 'solver': 'eigen', 'features': 15},
#             Current best combo with val score 0.2185:
#                     {'tol': 1e-05, 'solver': 'lsqr', 'features': 10}
# Trained and Tested combination 66 of 714, taking 0.05 seconds to get val score of 0.0:
#                 {'tol': 10, 'solver': 'lsqr', 'features': 45},
#             Current best combo with val score 0.2185:
#                     {'tol': 1e-05, 'solver': 'lsqr', 'features': 10}
#
#
# STAGE ONE: Begin initial Guidance system
#
#
# Guidance: initial round
#
# 	round 0 iteration:  0
#
# Trained and Tested combination 67 of 714, taking 0.05 seconds to get val score of 0.0033:
#                 {'tol': 0.001, 'solver': 'lsqr', 'features': 25},
#             Current best combo with val score 0.2185:
#                     {'tol': 1e-05, 'solver': 'lsqr', 'features': 10}
# Trained and Tested combination 68 of 714, taking 0.04 seconds to get val score of 0.0033:
#                 {'tol': 0.1, 'solver': 'lsqr', 'features': 25},
#             Current best combo with val score 0.2185:
#                     {'tol': 1e-05, 'solver': 'lsqr', 'features': 10}
# Already Trained and Tested combination (val score of 0.0033):
#             {'tol': 0.01, 'solver': 'eigen', 'features': 25}
#             Current best combo (with val score 0.2185):
#                     {'tol': 1e-05, 'solver': 'lsqr', 'features': 10}
#         Has trained 68 of 714 combinations so far
# Trained and Tested combination 69 of 714, taking 0.05 seconds to get val score of 0.0033:
#                 {'tol': 0.01, 'solver': 'lsqr', 'features': 24},
#             Current best combo with val score 0.2185:
#                     {'tol': 1e-05, 'solver': 'lsqr', 'features': 10}
# Trained and Tested combination 70 of 714, taking 0.36 seconds to get val score of 0.0033:
#                 {'tol': 0.01, 'solver': 'lsqr', 'features': 26},
#             Current best combo with val score 0.2185:
#                     {'tol': 1e-05, 'solver': 'lsqr', 'features': 10}
# 	round 0 iteration:  1
#
# Trained and Tested combination 71 of 714, taking 0.18 seconds to get val score of 0.0033:
#                 {'tol': 0.0001, 'solver': 'lsqr', 'features': 25},
#             Current best combo with val score 0.2185:
#                     {'tol': 1e-05, 'solver': 'lsqr', 'features': 10}
# Already Trained and Tested combination (val score of 0.0033):
#             {'tol': 0.01, 'solver': 'lsqr', 'features': 25}
#             Current best combo (with val score 0.2185):
#                     {'tol': 1e-05, 'solver': 'lsqr', 'features': 10}
#         Has trained 71 of 714 combinations so far
# Trained and Tested combination 72 of 714, taking 0.05 seconds to get val score of 0.0033:
#                 {'tol': 0.001, 'solver': 'eigen', 'features': 25},
#             Current best combo with val score 0.2185:
#                     {'tol': 1e-05, 'solver': 'lsqr', 'features': 10}
# Trained and Tested combination 73 of 714, taking 0.18 seconds to get val score of 0.0033:
#                 {'tol': 0.001, 'solver': 'lsqr', 'features': 24},
#             Current best combo with val score 0.2185:
#                     {'tol': 1e-05, 'solver': 'lsqr', 'features': 10}
# Trained and Tested combination 74 of 714, taking 0.05 seconds to get val score of 0.0033:
#                 {'tol': 0.001, 'solver': 'lsqr', 'features': 26},
#             Current best combo with val score 0.2185:
#                     {'tol': 1e-05, 'solver': 'lsqr', 'features': 10}
# Already Trained and Tested combination (val score of 0.0033):
#             {'tol': 0.01, 'solver': 'lsqr', 'features': 25}
#             Current best combo (with val score 0.2185):
#                     {'tol': 1e-05, 'solver': 'lsqr', 'features': 10}
#         Has trained 74 of 714 combinations so far
# Trained and Tested combination 75 of 714, taking 0.04 seconds to get val score of 0.0033:
#                 {'tol': 1, 'solver': 'lsqr', 'features': 25},
#             Current best combo with val score 0.2185:
#                     {'tol': 1e-05, 'solver': 'lsqr', 'features': 10}
# Trained and Tested combination 76 of 714, taking 0.05 seconds to get val score of 0.0033:
#                 {'tol': 0.1, 'solver': 'eigen', 'features': 25},
#             Current best combo with val score 0.2185:
#                     {'tol': 1e-05, 'solver': 'lsqr', 'features': 10}
# Trained and Tested combination 77 of 714, taking 0.06 seconds to get val score of 0.0033:
#                 {'tol': 0.1, 'solver': 'lsqr', 'features': 24},
#             Current best combo with val score 0.2185:
#                     {'tol': 1e-05, 'solver': 'lsqr', 'features': 10}
# Trained and Tested combination 78 of 714, taking 0.13 seconds to get val score of 0.0033:
#                 {'tol': 0.1, 'solver': 'lsqr', 'features': 26},
#             Current best combo with val score 0.2185:
#                     {'tol': 1e-05, 'solver': 'lsqr', 'features': 10}
# Already Trained and Tested combination (val score of 0.0033):
#             {'tol': 0.001, 'solver': 'eigen', 'features': 25}
#             Current best combo (with val score 0.2185):
#                     {'tol': 1e-05, 'solver': 'lsqr', 'features': 10}
#         Has trained 78 of 714 combinations so far
# Already Trained and Tested combination (val score of 0.0033):
#             {'tol': 0.1, 'solver': 'eigen', 'features': 25}
#             Current best combo (with val score 0.2185):
#                     {'tol': 1e-05, 'solver': 'lsqr', 'features': 10}
#         Has trained 78 of 714 combinations so far
# Already Trained and Tested combination (val score of 0.0033):
#             {'tol': 0.01, 'solver': 'lsqr', 'features': 25}
#             Current best combo (with val score 0.2185):
#                     {'tol': 1e-05, 'solver': 'lsqr', 'features': 10}
#         Has trained 78 of 714 combinations so far
# Trained and Tested combination 79 of 714, taking 0.17 seconds to get val score of 0.0033:
#                 {'tol': 0.01, 'solver': 'eigen', 'features': 24},
#             Current best combo with val score 0.2185:
#                     {'tol': 1e-05, 'solver': 'lsqr', 'features': 10}
# Trained and Tested combination 80 of 714, taking 0.06 seconds to get val score of 0.0033:
#                 {'tol': 0.01, 'solver': 'eigen', 'features': 26},
#             Current best combo with val score 0.2185:
#                     {'tol': 1e-05, 'solver': 'lsqr', 'features': 10}
# Already Trained and Tested combination (val score of 0.0033):
#             {'tol': 0.001, 'solver': 'lsqr', 'features': 24}
#             Current best combo (with val score 0.2185):
#                     {'tol': 1e-05, 'solver': 'lsqr', 'features': 10}
#         Has trained 80 of 714 combinations so far
# Already Trained and Tested combination (val score of 0.0033):
#             {'tol': 0.1, 'solver': 'lsqr', 'features': 24}
#             Current best combo (with val score 0.2185):
#                     {'tol': 1e-05, 'solver': 'lsqr', 'features': 10}
#         Has trained 80 of 714 combinations so far
# Already Trained and Tested combination (val score of 0.0033):
#             {'tol': 0.01, 'solver': 'eigen', 'features': 24}
#             Current best combo (with val score 0.2185):
#                     {'tol': 1e-05, 'solver': 'lsqr', 'features': 10}
#         Has trained 80 of 714 combinations so far
# Trained and Tested combination 81 of 714, taking 0.04 seconds to get val score of 0.0132:
#                 {'tol': 0.01, 'solver': 'lsqr', 'features': 23},
#             Current best combo with val score 0.2185:
#                     {'tol': 1e-05, 'solver': 'lsqr', 'features': 10}
# Already Trained and Tested combination (val score of 0.0033):
#             {'tol': 0.01, 'solver': 'lsqr', 'features': 25}
#             Current best combo (with val score 0.2185):
#                     {'tol': 1e-05, 'solver': 'lsqr', 'features': 10}
#         Has trained 81 of 714 combinations so far
# Already Trained and Tested combination (val score of 0.0033):
#             {'tol': 0.001, 'solver': 'lsqr', 'features': 26}
#             Current best combo (with val score 0.2185):
#                     {'tol': 1e-05, 'solver': 'lsqr', 'features': 10}
#         Has trained 81 of 714 combinations so far
# Already Trained and Tested combination (val score of 0.0033):
#             {'tol': 0.1, 'solver': 'lsqr', 'features': 26}
#             Current best combo (with val score 0.2185):
#                     {'tol': 1e-05, 'solver': 'lsqr', 'features': 10}
#         Has trained 81 of 714 combinations so far
# Already Trained and Tested combination (val score of 0.0033):
#             {'tol': 0.01, 'solver': 'eigen', 'features': 26}
#             Current best combo (with val score 0.2185):
#                     {'tol': 1e-05, 'solver': 'lsqr', 'features': 10}
#         Has trained 81 of 714 combinations so far
# Already Trained and Tested combination (val score of 0.0033):
#             {'tol': 0.01, 'solver': 'lsqr', 'features': 25}
#             Current best combo (with val score 0.2185):
#                     {'tol': 1e-05, 'solver': 'lsqr', 'features': 10}
#         Has trained 81 of 714 combinations so far
# Trained and Tested combination 82 of 714, taking 0.04 seconds to get val score of 0.0033:
#                 {'tol': 0.01, 'solver': 'lsqr', 'features': 27},
#             Current best combo with val score 0.2185:
#                     {'tol': 1e-05, 'solver': 'lsqr', 'features': 10}
# Trained and Tested combination 83 of 714, taking 0.03 seconds to get val score of 0.2185:
#                 {'tol': 0.0001, 'solver': 'lsqr', 'features': 10},
#             Current best combo with val score 0.2185:
#                     {'tol': 1e-05, 'solver': 'lsqr', 'features': 10}
# Already Trained and Tested combination (val score of 0.2185):
#             {'tol': 1e-05, 'solver': 'eigen', 'features': 10}
#             Current best combo (with val score 0.2185):
#                     {'tol': 1e-05, 'solver': 'lsqr', 'features': 10}
#         Has trained 83 of 714 combinations so far
# Trained and Tested combination 84 of 714, taking 0.05 seconds to get val score of 0.2172:
#                 {'tol': 1e-05, 'solver': 'lsqr', 'features': 9},
#             Current best combo with val score 0.2185:
#                     {'tol': 1e-05, 'solver': 'lsqr', 'features': 10}
# Trained and Tested combination 85 of 714, taking 0.04 seconds to get val score of 0.0067:
#                 {'tol': 1e-05, 'solver': 'lsqr', 'features': 11},
#             Current best combo with val score 0.2185:
#                     {'tol': 1e-05, 'solver': 'lsqr', 'features': 10}
# % Combos Checked Thus Far: 85 out of 714 which is 11.904762%
# STAGE TWO: Begin Cruise system
#
#
# Cruising Coordrdinate 1 of 66
#
# Cruising Coordrdinate 2 of 66
#
# Cruising Coordrdinate 3 of 66
#
# Cruising Coordrdinate 4 of 66
#
# Cruising Coordrdinate 5 of 66
#
# Cruising Coordrdinate 6 of 66
#
# Cruising Coordrdinate 7 of 66
#
# Cruising Coordrdinate 8 of 66
#
# Cruising Coordrdinate 9 of 66
#
# Cruising Coordrdinate 10 of 66
#
# Cruising Coordrdinate 11 of 66
#
# Cruising Coordrdinate 12 of 66
#
# Cruising Coordrdinate 13 of 66
#
# Cruising Coordrdinate 14 of 66
#
# Cruising Coordrdinate 15 of 66
#
# Cruising Coordrdinate 16 of 66
#
# Cruising Coordrdinate 17 of 66
#
# Cruising Coordrdinate 18 of 66
#
# Cruising Coordrdinate 19 of 66
#
# Cruising Coordrdinate 20 of 66
#
# Cruising Coordrdinate 21 of 66
#
# Cruising Coordrdinate 22 of 66
#
# Cruising Coordrdinate 23 of 66
#
# Cruising Coordrdinate 24 of 66
#
# Cruising Coordrdinate 25 of 66
#
# Cruising Coordrdinate 26 of 66
#
# Cruising Coordrdinate 27 of 66
#
# Cruising Coordrdinate 28 of 66
#
# Cruising Coordrdinate 29 of 66
#
# Cruising Coordrdinate 30 of 66
#
# Cruising Coordrdinate 31 of 66
#
# Cruising Coordrdinate 32 of 66
#
# Cruising Coordrdinate 33 of 66
#
# Cruising Coordrdinate 34 of 66
#
# Cruising Coordrdinate 35 of 66
#
# Cruising Coordrdinate 36 of 66
#
# Cruising Coordrdinate 37 of 66
#
# Cruising Coordrdinate 38 of 66
#
# Cruising Coordrdinate 39 of 66
#
# Cruising Coordrdinate 40 of 66
#
# Cruising Coordrdinate 41 of 66
#
# Cruising Coordrdinate 42 of 66
#
# Cruising Coordrdinate 43 of 66
#
# Cruising Coordrdinate 44 of 66
#
# Cruising Coordrdinate 45 of 66
#
# Cruising Coordrdinate 46 of 66
#
# Cruising Coordrdinate 47 of 66
#
# Cruising Coordrdinate 48 of 66
#
# Cruise suspended due to suspicious case
# Guidance: round 1
#
# 	round 1 iteration:  0
#
# Trained and Tested combination 86 of 714, taking 0.06 seconds to get val score of 0.1905:
#                 {'tol': 1, 'solver': 'eigen', 'features': 5},
#             Current best combo with val score 0.2185:
#                     {'tol': 1e-05, 'solver': 'lsqr', 'features': 10}
# Already Trained and Tested combination (val score of 0.1905):
#             {'tol': 10, 'solver': 'lsqr', 'features': 5}
#             Current best combo (with val score 0.2185):
#                     {'tol': 1e-05, 'solver': 'lsqr', 'features': 10}
#         Has trained 86 of 714 combinations so far
# Trained and Tested combination 87 of 714, taking 0.05 seconds to get val score of 0.1356:
#                 {'tol': 10, 'solver': 'eigen', 'features': 4},
#             Current best combo with val score 0.2185:
#                     {'tol': 1e-05, 'solver': 'lsqr', 'features': 10}
# Trained and Tested combination 88 of 714, taking 0.04 seconds to get val score of 0.1743:
#                 {'tol': 10, 'solver': 'eigen', 'features': 6},
#             Current best combo with val score 0.2185:
#                     {'tol': 1e-05, 'solver': 'lsqr', 'features': 10}
# 	round 1 iteration:  1
#
# Trained and Tested combination 89 of 714, taking 0.04 seconds to get val score of 0.1905:
#                 {'tol': 0.1, 'solver': 'eigen', 'features': 5},
#             Current best combo with val score 0.2185:
#                     {'tol': 1e-05, 'solver': 'lsqr', 'features': 10}
# Already Trained and Tested combination (val score of 0.1905):
#             {'tol': 10, 'solver': 'eigen', 'features': 5}
#             Current best combo (with val score 0.2185):
#                     {'tol': 1e-05, 'solver': 'lsqr', 'features': 10}
#         Has trained 89 of 714 combinations so far
# Trained and Tested combination 90 of 714, taking 0.02 seconds to get val score of 0.1905:
#                 {'tol': 1, 'solver': 'lsqr', 'features': 5},
#             Current best combo with val score 0.2185:
#                     {'tol': 1e-05, 'solver': 'lsqr', 'features': 10}
# Trained and Tested combination 91 of 714, taking 0.03 seconds to get val score of 0.1356:
#                 {'tol': 1, 'solver': 'eigen', 'features': 4},
#             Current best combo with val score 0.2185:
#                     {'tol': 1e-05, 'solver': 'lsqr', 'features': 10}
# Trained and Tested combination 92 of 714, taking 0.04 seconds to get val score of 0.1743:
#                 {'tol': 1, 'solver': 'eigen', 'features': 6},
#             Current best combo with val score 0.2185:
#                     {'tol': 1e-05, 'solver': 'lsqr', 'features': 10}
# Already Trained and Tested combination (val score of 0.1905):
#             {'tol': 1, 'solver': 'lsqr', 'features': 5}
#             Current best combo (with val score 0.2185):
#                     {'tol': 1e-05, 'solver': 'lsqr', 'features': 10}
#         Has trained 92 of 714 combinations so far
# Already Trained and Tested combination (val score of 0.1905):
#             {'tol': 10, 'solver': 'eigen', 'features': 5}
#             Current best combo (with val score 0.2185):
#                     {'tol': 1e-05, 'solver': 'lsqr', 'features': 10}
#         Has trained 92 of 714 combinations so far
# Trained and Tested combination 93 of 714, taking 0.02 seconds to get val score of 0.1356:
#                 {'tol': 10, 'solver': 'lsqr', 'features': 4},
#             Current best combo with val score 0.2185:
#                     {'tol': 1e-05, 'solver': 'lsqr', 'features': 10}
# Trained and Tested combination 94 of 714, taking 0.02 seconds to get val score of 0.1743:
#                 {'tol': 10, 'solver': 'lsqr', 'features': 6},
#             Current best combo with val score 0.2185:
#                     {'tol': 1e-05, 'solver': 'lsqr', 'features': 10}
# % Combos Checked Thus Far: 94 out of 714 which is 13.165266%
# Cruising Coordrdinate 49 of 66
#
# Cruising Coordrdinate 50 of 66
#
# Cruise suspended due to suspicious case
# Guidance: round 2
#
# 	round 2 iteration:  0
#
# % Combos Checked Thus Far: 94 out of 714 which is 13.165266%
# Cruising Coordrdinate 51 of 66
#
# Cruising Coordrdinate 52 of 66
#
# Cruise suspended due to suspicious case
# Guidance: round 3
#
# 	round 3 iteration:  0
#
# Trained and Tested combination 95 of 714, taking 0.05 seconds to get val score of 0.2185:
#                 {'tol': 1, 'solver': 'eigen', 'features': 10},
#             Current best combo with val score 0.2185:
#                     {'tol': 1e-05, 'solver': 'lsqr', 'features': 10}
# Already Trained and Tested combination (val score of 0.2185):
#             {'tol': 10, 'solver': 'lsqr', 'features': 10}
#             Current best combo (with val score 0.2185):
#                     {'tol': 1e-05, 'solver': 'lsqr', 'features': 10}
#         Has trained 95 of 714 combinations so far
# Trained and Tested combination 96 of 714, taking 0.05 seconds to get val score of 0.2172:
#                 {'tol': 10, 'solver': 'eigen', 'features': 9},
#             Current best combo with val score 0.2185:
#                     {'tol': 1e-05, 'solver': 'lsqr', 'features': 10}
# Trained and Tested combination 97 of 714, taking 0.04 seconds to get val score of 0.0067:
#                 {'tol': 10, 'solver': 'eigen', 'features': 11},
#             Current best combo with val score 0.2185:
#                     {'tol': 1e-05, 'solver': 'lsqr', 'features': 10}
# 	round 3 iteration:  1
#
# Trained and Tested combination 98 of 714, taking 0.07 seconds to get val score of 0.2185:
#                 {'tol': 0.1, 'solver': 'eigen', 'features': 10},
#             Current best combo with val score 0.2185:
#                     {'tol': 1e-05, 'solver': 'lsqr', 'features': 10}
# Already Trained and Tested combination (val score of 0.2185):
#             {'tol': 10, 'solver': 'eigen', 'features': 10}
#             Current best combo (with val score 0.2185):
#                     {'tol': 1e-05, 'solver': 'lsqr', 'features': 10}
#         Has trained 98 of 714 combinations so far
# Trained and Tested combination 99 of 714, taking 0.18 seconds to get val score of 0.2185:
#                 {'tol': 1, 'solver': 'lsqr', 'features': 10},
#             Current best combo with val score 0.2185:
#                     {'tol': 1e-05, 'solver': 'lsqr', 'features': 10}
# Trained and Tested combination 100 of 714, taking 0.04 seconds to get val score of 0.2172:
#                 {'tol': 1, 'solver': 'eigen', 'features': 9},
#             Current best combo with val score 0.2185:
#                     {'tol': 1e-05, 'solver': 'lsqr', 'features': 10}
# Trained and Tested combination 101 of 714, taking 0.04 seconds to get val score of 0.0067:
#                 {'tol': 1, 'solver': 'eigen', 'features': 11},
#             Current best combo with val score 0.2185:
#                     {'tol': 1e-05, 'solver': 'lsqr', 'features': 10}
# Already Trained and Tested combination (val score of 0.2185):
#             {'tol': 1, 'solver': 'lsqr', 'features': 10}
#             Current best combo (with val score 0.2185):
#                     {'tol': 1e-05, 'solver': 'lsqr', 'features': 10}
#         Has trained 101 of 714 combinations so far
# Already Trained and Tested combination (val score of 0.2185):
#             {'tol': 10, 'solver': 'eigen', 'features': 10}
#             Current best combo (with val score 0.2185):
#                     {'tol': 1e-05, 'solver': 'lsqr', 'features': 10}
#         Has trained 101 of 714 combinations so far
# Trained and Tested combination 102 of 714, taking 0.03 seconds to get val score of 0.2172:
#                 {'tol': 10, 'solver': 'lsqr', 'features': 9},
#             Current best combo with val score 0.2185:
#                     {'tol': 1e-05, 'solver': 'lsqr', 'features': 10}
# Trained and Tested combination 103 of 714, taking 0.03 seconds to get val score of 0.0067:
#                 {'tol': 10, 'solver': 'lsqr', 'features': 11},
#             Current best combo with val score 0.2185:
#                     {'tol': 1e-05, 'solver': 'lsqr', 'features': 10}
# Already Trained and Tested combination (val score of 0.2172):
#             {'tol': 1, 'solver': 'eigen', 'features': 9}
#             Current best combo (with val score 0.2185):
#                     {'tol': 1e-05, 'solver': 'lsqr', 'features': 10}
#         Has trained 103 of 714 combinations so far
# Already Trained and Tested combination (val score of 0.2172):
#             {'tol': 10, 'solver': 'lsqr', 'features': 9}
#             Current best combo (with val score 0.2185):
#                     {'tol': 1e-05, 'solver': 'lsqr', 'features': 10}
#         Has trained 103 of 714 combinations so far
# Trained and Tested combination 104 of 714, taking 0.04 seconds to get val score of 0.2053:
#                 {'tol': 10, 'solver': 'eigen', 'features': 8},
#             Current best combo with val score 0.2185:
#                     {'tol': 1e-05, 'solver': 'lsqr', 'features': 10}
# Already Trained and Tested combination (val score of 0.2185):
#             {'tol': 10, 'solver': 'eigen', 'features': 10}
#             Current best combo (with val score 0.2185):
#                     {'tol': 1e-05, 'solver': 'lsqr', 'features': 10}
#         Has trained 104 of 714 combinations so far
# % Combos Checked Thus Far: 104 out of 714 which is 14.565826000000001%
# Cruising Coordrdinate 53 of 66
#
# Cruise suspended due to suspicious case
# Guidance: round 4
#
# 	round 4 iteration:  0
#
# % Combos Checked Thus Far: 104 out of 714 which is 14.565826000000001%
# Cruising Coordrdinate 54 of 66
#
# Cruise suspended due to suspicious case
# Guidance: round 5
#
# 	round 5 iteration:  0
#
# Trained and Tested combination 105 of 714, taking 0.04 seconds to get val score of 0.1905:
#                 {'tol': 0.001, 'solver': 'eigen', 'features': 5},
#             Current best combo with val score 0.2185:
#                     {'tol': 1e-05, 'solver': 'lsqr', 'features': 10}
# Already Trained and Tested combination (val score of 0.1905):
#             {'tol': 0.1, 'solver': 'eigen', 'features': 5}
#             Current best combo (with val score 0.2185):
#                     {'tol': 1e-05, 'solver': 'lsqr', 'features': 10}
#         Has trained 105 of 714 combinations so far
# Already Trained and Tested combination (val score of 0.1905):
#             {'tol': 0.01, 'solver': 'lsqr', 'features': 5}
#             Current best combo (with val score 0.2185):
#                     {'tol': 1e-05, 'solver': 'lsqr', 'features': 10}
#         Has trained 105 of 714 combinations so far
# Trained and Tested combination 106 of 714, taking 0.04 seconds to get val score of 0.1356:
#                 {'tol': 0.01, 'solver': 'eigen', 'features': 4},
#             Current best combo with val score 0.2185:
#                     {'tol': 1e-05, 'solver': 'lsqr', 'features': 10}
# Trained and Tested combination 107 of 714, taking 0.03 seconds to get val score of 0.1743:
#                 {'tol': 0.01, 'solver': 'eigen', 'features': 6},
#             Current best combo with val score 0.2185:
#                     {'tol': 1e-05, 'solver': 'lsqr', 'features': 10}
# 	round 5 iteration:  1
#
# Trained and Tested combination 108 of 714, taking 0.03 seconds to get val score of 0.1905:
#                 {'tol': 0.0001, 'solver': 'eigen', 'features': 5},
#             Current best combo with val score 0.2185:
#                     {'tol': 1e-05, 'solver': 'lsqr', 'features': 10}
# Already Trained and Tested combination (val score of 0.1905):
#             {'tol': 0.01, 'solver': 'eigen', 'features': 5}
#             Current best combo (with val score 0.2185):
#                     {'tol': 1e-05, 'solver': 'lsqr', 'features': 10}
#         Has trained 108 of 714 combinations so far
# Trained and Tested combination 109 of 714, taking 0.02 seconds to get val score of 0.1905:
#                 {'tol': 0.001, 'solver': 'lsqr', 'features': 5},
#             Current best combo with val score 0.2185:
#                     {'tol': 1e-05, 'solver': 'lsqr', 'features': 10}
# Trained and Tested combination 110 of 714, taking 0.03 seconds to get val score of 0.1356:
#                 {'tol': 0.001, 'solver': 'eigen', 'features': 4},
#             Current best combo with val score 0.2185:
#                     {'tol': 1e-05, 'solver': 'lsqr', 'features': 10}
# Trained and Tested combination 111 of 714, taking 0.07 seconds to get val score of 0.1743:
#                 {'tol': 0.001, 'solver': 'eigen', 'features': 6},
#             Current best combo with val score 0.2185:
#                     {'tol': 1e-05, 'solver': 'lsqr', 'features': 10}
# Already Trained and Tested combination (val score of 0.1905):
#             {'tol': 0.001, 'solver': 'lsqr', 'features': 5}
#             Current best combo (with val score 0.2185):
#                     {'tol': 1e-05, 'solver': 'lsqr', 'features': 10}
#         Has trained 111 of 714 combinations so far
# Trained and Tested combination 112 of 714, taking 0.04 seconds to get val score of 0.1905:
#                 {'tol': 0.1, 'solver': 'lsqr', 'features': 5},
#             Current best combo with val score 0.2185:
#                     {'tol': 1e-05, 'solver': 'lsqr', 'features': 10}
# Already Trained and Tested combination (val score of 0.1905):
#             {'tol': 0.01, 'solver': 'eigen', 'features': 5}
#             Current best combo (with val score 0.2185):
#                     {'tol': 1e-05, 'solver': 'lsqr', 'features': 10}
#         Has trained 112 of 714 combinations so far
# Trained and Tested combination 113 of 714, taking 0.02 seconds to get val score of 0.1356:
#                 {'tol': 0.01, 'solver': 'lsqr', 'features': 4},
#             Current best combo with val score 0.2185:
#                     {'tol': 1e-05, 'solver': 'lsqr', 'features': 10}
# Trained and Tested combination 114 of 714, taking 0.02 seconds to get val score of 0.1743:
#                 {'tol': 0.01, 'solver': 'lsqr', 'features': 6},
#             Current best combo with val score 0.2185:
#                     {'tol': 1e-05, 'solver': 'lsqr', 'features': 10}
# % Combos Checked Thus Far: 114 out of 714 which is 15.966387000000001%
# Cruising Coordrdinate 55 of 66
#
# Cruising Coordrdinate 56 of 66
#
# Cruise suspended due to suspicious case
# Guidance: round 6
#
# 	round 6 iteration:  0
#
# % Combos Checked Thus Far: 114 out of 714 which is 15.966387000000001%
# Cruising Coordrdinate 57 of 66
#
# Cruising Coordrdinate 58 of 66
#
# Cruise suspended due to suspicious case
# Guidance: round 7
#
# 	round 7 iteration:  0
#
# Already Trained and Tested combination (val score of 0.1905):
#             {'tol': 0.0001, 'solver': 'eigen', 'features': 5}
#             Current best combo (with val score 0.2185):
#                     {'tol': 1e-05, 'solver': 'lsqr', 'features': 10}
#         Has trained 114 of 714 combinations so far
# Already Trained and Tested combination (val score of 0.1905):
#             {'tol': 1e-05, 'solver': 'lsqr', 'features': 5}
#             Current best combo (with val score 0.2185):
#                     {'tol': 1e-05, 'solver': 'lsqr', 'features': 10}
#         Has trained 114 of 714 combinations so far
# Trained and Tested combination 115 of 714, taking 0.05 seconds to get val score of 0.1356:
#                 {'tol': 1e-05, 'solver': 'eigen', 'features': 4},
#             Current best combo with val score 0.2185:
#                     {'tol': 1e-05, 'solver': 'lsqr', 'features': 10}
# Trained and Tested combination 116 of 714, taking 0.05 seconds to get val score of 0.1743:
#                 {'tol': 1e-05, 'solver': 'eigen', 'features': 6},
#             Current best combo with val score 0.2185:
#                     {'tol': 1e-05, 'solver': 'lsqr', 'features': 10}
# 	round 7 iteration:  1
#
# Trained and Tested combination 117 of 714, taking 0.02 seconds to get val score of 0.1905:
#                 {'tol': 0.0001, 'solver': 'lsqr', 'features': 5},
#             Current best combo with val score 0.2185:
#                     {'tol': 1e-05, 'solver': 'lsqr', 'features': 10}
# Already Trained and Tested combination (val score of 0.1905):
#             {'tol': 1e-05, 'solver': 'eigen', 'features': 5}
#             Current best combo (with val score 0.2185):
#                     {'tol': 1e-05, 'solver': 'lsqr', 'features': 10}
#         Has trained 117 of 714 combinations so far
# Trained and Tested combination 118 of 714, taking 0.02 seconds to get val score of 0.1356:
#                 {'tol': 1e-05, 'solver': 'lsqr', 'features': 4},
#             Current best combo with val score 0.2185:
#                     {'tol': 1e-05, 'solver': 'lsqr', 'features': 10}
# Trained and Tested combination 119 of 714, taking 0.02 seconds to get val score of 0.1743:
#                 {'tol': 1e-05, 'solver': 'lsqr', 'features': 6},
#             Current best combo with val score 0.2185:
#                     {'tol': 1e-05, 'solver': 'lsqr', 'features': 10}
# % Combos Checked Thus Far: 119 out of 714 which is 16.666667%
# Cruising Coordrdinate 59 of 66
#
# Cruising Coordrdinate 60 of 66
#
# Cruise suspended due to suspicious case
# Guidance: round 8
#
# 	round 8 iteration:  0
#
# % Combos Checked Thus Far: 119 out of 714 which is 16.666667%
# Cruising Coordrdinate 61 of 66
#
# Cruising Coordrdinate 62 of 66
#
# Cruise suspended due to suspicious case
# Guidance: round 9
#
# 	round 9 iteration:  0
#
# Trained and Tested combination 120 of 714, taking 0.05 seconds to get val score of 0.2185:
#                 {'tol': 0.001, 'solver': 'eigen', 'features': 10},
#             Current best combo with val score 0.2185:
#                     {'tol': 1e-05, 'solver': 'lsqr', 'features': 10}
# Already Trained and Tested combination (val score of 0.2185):
#             {'tol': 0.1, 'solver': 'eigen', 'features': 10}
#             Current best combo (with val score 0.2185):
#                     {'tol': 1e-05, 'solver': 'lsqr', 'features': 10}
#         Has trained 120 of 714 combinations so far
# Already Trained and Tested combination (val score of 0.2185):
#             {'tol': 0.01, 'solver': 'lsqr', 'features': 10}
#             Current best combo (with val score 0.2185):
#                     {'tol': 1e-05, 'solver': 'lsqr', 'features': 10}
#         Has trained 120 of 714 combinations so far
# Trained and Tested combination 121 of 714, taking 0.06 seconds to get val score of 0.2172:
#                 {'tol': 0.01, 'solver': 'eigen', 'features': 9},
#             Current best combo with val score 0.2185:
#                     {'tol': 1e-05, 'solver': 'lsqr', 'features': 10}
# Trained and Tested combination 122 of 714, taking 0.04 seconds to get val score of 0.0067:
#                 {'tol': 0.01, 'solver': 'eigen', 'features': 11},
#             Current best combo with val score 0.2185:
#                     {'tol': 1e-05, 'solver': 'lsqr', 'features': 10}
# 	round 9 iteration:  1
#
# Trained and Tested combination 123 of 714, taking 0.06 seconds to get val score of 0.2185:
#                 {'tol': 0.0001, 'solver': 'eigen', 'features': 10},
#             Current best combo with val score 0.2185:
#                     {'tol': 1e-05, 'solver': 'lsqr', 'features': 10}
# Already Trained and Tested combination (val score of 0.2185):
#             {'tol': 0.01, 'solver': 'eigen', 'features': 10}
#             Current best combo (with val score 0.2185):
#                     {'tol': 1e-05, 'solver': 'lsqr', 'features': 10}
#         Has trained 123 of 714 combinations so far
# Trained and Tested combination 124 of 714, taking 0.36 seconds to get val score of 0.2185:
#                 {'tol': 0.001, 'solver': 'lsqr', 'features': 10},
#             Current best combo with val score 0.2185:
#                     {'tol': 1e-05, 'solver': 'lsqr', 'features': 10}
# Trained and Tested combination 125 of 714, taking 0.07 seconds to get val score of 0.2172:
#                 {'tol': 0.001, 'solver': 'eigen', 'features': 9},
#             Current best combo with val score 0.2185:
#                     {'tol': 1e-05, 'solver': 'lsqr', 'features': 10}
# Trained and Tested combination 126 of 714, taking 0.04 seconds to get val score of 0.0067:
#                 {'tol': 0.001, 'solver': 'eigen', 'features': 11},
#             Current best combo with val score 0.2185:
#                     {'tol': 1e-05, 'solver': 'lsqr', 'features': 10}
# Already Trained and Tested combination (val score of 0.2185):
#             {'tol': 0.001, 'solver': 'lsqr', 'features': 10}
#             Current best combo (with val score 0.2185):
#                     {'tol': 1e-05, 'solver': 'lsqr', 'features': 10}
#         Has trained 126 of 714 combinations so far
# Trained and Tested combination 127 of 714, taking 0.02 seconds to get val score of 0.2185:
#                 {'tol': 0.1, 'solver': 'lsqr', 'features': 10},
#             Current best combo with val score 0.2185:
#                     {'tol': 1e-05, 'solver': 'lsqr', 'features': 10}
# Already Trained and Tested combination (val score of 0.2185):
#             {'tol': 0.01, 'solver': 'eigen', 'features': 10}
#             Current best combo (with val score 0.2185):
#                     {'tol': 1e-05, 'solver': 'lsqr', 'features': 10}
#         Has trained 127 of 714 combinations so far
# Trained and Tested combination 128 of 714, taking 0.04 seconds to get val score of 0.2172:
#                 {'tol': 0.01, 'solver': 'lsqr', 'features': 9},
#             Current best combo with val score 0.2185:
#                     {'tol': 1e-05, 'solver': 'lsqr', 'features': 10}
# Trained and Tested combination 129 of 714, taking 0.15 seconds to get val score of 0.0067:
#                 {'tol': 0.01, 'solver': 'lsqr', 'features': 11},
#             Current best combo with val score 0.2185:
#                     {'tol': 1e-05, 'solver': 'lsqr', 'features': 10}
# Already Trained and Tested combination (val score of 0.2172):
#             {'tol': 0.001, 'solver': 'eigen', 'features': 9}
#             Current best combo (with val score 0.2185):
#                     {'tol': 1e-05, 'solver': 'lsqr', 'features': 10}
#         Has trained 129 of 714 combinations so far
# Trained and Tested combination 130 of 714, taking 0.04 seconds to get val score of 0.2172:
#                 {'tol': 0.1, 'solver': 'eigen', 'features': 9},
#             Current best combo with val score 0.2185:
#                     {'tol': 1e-05, 'solver': 'lsqr', 'features': 10}
# Already Trained and Tested combination (val score of 0.2172):
#             {'tol': 0.01, 'solver': 'lsqr', 'features': 9}
#             Current best combo (with val score 0.2185):
#                     {'tol': 1e-05, 'solver': 'lsqr', 'features': 10}
#         Has trained 130 of 714 combinations so far
# Trained and Tested combination 131 of 714, taking 0.03 seconds to get val score of 0.2053:
#                 {'tol': 0.01, 'solver': 'eigen', 'features': 8},
#             Current best combo with val score 0.2185:
#                     {'tol': 1e-05, 'solver': 'lsqr', 'features': 10}
# Already Trained and Tested combination (val score of 0.2185):
#             {'tol': 0.01, 'solver': 'eigen', 'features': 10}
#             Current best combo (with val score 0.2185):
#                     {'tol': 1e-05, 'solver': 'lsqr', 'features': 10}
#         Has trained 131 of 714 combinations so far
# % Combos Checked Thus Far: 131 out of 714 which is 18.347338999999998%
# Cruising Coordrdinate 63 of 66
#
# Cruise suspended due to suspicious case
# Guidance: round 10
#
# 	round 10 iteration:  0
#
# % Combos Checked Thus Far: 131 out of 714 which is 18.347338999999998%
# Cruising Coordrdinate 64 of 66
#
# Cruise suspended due to suspicious case
# Guidance: round 11
#
# 	round 11 iteration:  0
#
# Already Trained and Tested combination (val score of 0.2185):
#             {'tol': 0.0001, 'solver': 'eigen', 'features': 10}
#             Current best combo (with val score 0.2185):
#                     {'tol': 1e-05, 'solver': 'lsqr', 'features': 10}
#         Has trained 131 of 714 combinations so far
# Already Trained and Tested combination (val score of 0.2185):
#             {'tol': 1e-05, 'solver': 'lsqr', 'features': 10}
#             Current best combo (with val score 0.2185):
#                     {'tol': 1e-05, 'solver': 'lsqr', 'features': 10}
#         Has trained 131 of 714 combinations so far
# Trained and Tested combination 132 of 714, taking 0.06 seconds to get val score of 0.2172:
#                 {'tol': 1e-05, 'solver': 'eigen', 'features': 9},
#             Current best combo with val score 0.2185:
#                     {'tol': 1e-05, 'solver': 'lsqr', 'features': 10}
# Trained and Tested combination 133 of 714, taking 0.06 seconds to get val score of 0.0067:
#                 {'tol': 1e-05, 'solver': 'eigen', 'features': 11},
#             Current best combo with val score 0.2185:
#                     {'tol': 1e-05, 'solver': 'lsqr', 'features': 10}
# 	round 11 iteration:  1
#
# Already Trained and Tested combination (val score of 0.2185):
#             {'tol': 0.0001, 'solver': 'lsqr', 'features': 10}
#             Current best combo (with val score 0.2185):
#                     {'tol': 1e-05, 'solver': 'lsqr', 'features': 10}
#         Has trained 133 of 714 combinations so far
# Already Trained and Tested combination (val score of 0.2185):
#             {'tol': 1e-05, 'solver': 'eigen', 'features': 10}
#             Current best combo (with val score 0.2185):
#                     {'tol': 1e-05, 'solver': 'lsqr', 'features': 10}
#         Has trained 133 of 714 combinations so far
# Already Trained and Tested combination (val score of 0.2172):
#             {'tol': 1e-05, 'solver': 'lsqr', 'features': 9}
#             Current best combo (with val score 0.2185):
#                     {'tol': 1e-05, 'solver': 'lsqr', 'features': 10}
#         Has trained 133 of 714 combinations so far
# Already Trained and Tested combination (val score of 0.0067):
#             {'tol': 1e-05, 'solver': 'lsqr', 'features': 11}
#             Current best combo (with val score 0.2185):
#                     {'tol': 1e-05, 'solver': 'lsqr', 'features': 10}
#         Has trained 133 of 714 combinations so far
# Trained and Tested combination 134 of 714, taking 0.06 seconds to get val score of 0.2172:
#                 {'tol': 0.0001, 'solver': 'eigen', 'features': 9},
#             Current best combo with val score 0.2185:
#                     {'tol': 1e-05, 'solver': 'lsqr', 'features': 10}
# Already Trained and Tested combination (val score of 0.2172):
#             {'tol': 1e-05, 'solver': 'lsqr', 'features': 9}
#             Current best combo (with val score 0.2185):
#                     {'tol': 1e-05, 'solver': 'lsqr', 'features': 10}
#         Has trained 134 of 714 combinations so far
# Trained and Tested combination 135 of 714, taking 0.04 seconds to get val score of 0.2053:
#                 {'tol': 1e-05, 'solver': 'eigen', 'features': 8},
#             Current best combo with val score 0.2185:
#                     {'tol': 1e-05, 'solver': 'lsqr', 'features': 10}
# Already Trained and Tested combination (val score of 0.2185):
#             {'tol': 1e-05, 'solver': 'eigen', 'features': 10}
#             Current best combo (with val score 0.2185):
#                     {'tol': 1e-05, 'solver': 'lsqr', 'features': 10}
#         Has trained 135 of 714 combinations so far
# % Combos Checked Thus Far: 135 out of 714 which is 18.907563%
# Cruising Coordrdinate 65 of 66
#
# Cruise suspended due to suspicious case
# Guidance: round 12
#
# 	round 12 iteration:  0
#
# % Combos Checked Thus Far: 135 out of 714 which is 18.907563%
# FINAL STAGE: Begin final Guidance system
#
#
# Guidance: round FINAL
#
# 	round FINAL iteration:  0
#
# % Combos Checked Thus Far: 135 out of 714 which is 18.907563%
# Max Val Score:
#  0.218461
# Max Val Score Std:
#  0.078873
# Best Combo Train Score:
#  0.500738
# Best Combo Train Score Std:
#  0.010721
# Max Combo Index:
#  (0, 1, 10) out of [7, 2, 51] (note best combo is 0-indexed)
# Max Combo Hyperparamer Combination:
#  {'tol': 1e-05, 'solver': 'lsqr', 'features': 10}
# Max Combo Features:
#  ('procedure_225792', 'ventilation_used', 'lods_score', 'race_AMERICAN INDIAN/ALASKA NATIVE', 'race_ASIAN', 'race_ASIAN - ASIAN INDIAN', 'race_ASIAN - CHINESE', 'race_ASIAN - KOREAN', 'race_ASIAN - SOUTH EAST ASIAN', 'race_BLACK/AFRICAN', 'race_BLACK/AFRICAN AMERICAN', 'race_BLACK/CAPE VERDEAN', 'race_BLACK/CARIBBEAN ISLAND', 'race_HISPANIC/LATINO - CENTRAL AMERICAN', 'race_HISPANIC/LATINO - COLUMBIAN', 'race_HISPANIC/LATINO - CUBAN', 'race_HISPANIC/LATINO - DOMINICAN', 'race_HISPANIC/LATINO - GUATEMALAN', 'race_HISPANIC/LATINO - HONDURAN', 'race_HISPANIC/LATINO - MEXICAN', 'race_HISPANIC/LATINO - PUERTO RICAN', 'race_HISPANIC/LATINO - SALVADORAN', 'race_MULTIPLE RACE/ETHNICITY', 'race_NATIVE HAWAIIAN OR OTHER PACIFIC ISLANDER', 'race_OTHER', 'race_PATIENT DECLINED TO ANSWER', 'race_PORTUGUESE', 'race_SOUTH AMERICAN', 'race_UNABLE TO OBTAIN', 'race_UNKNOWN', 'race_WHITE', 'race_WHITE - BRAZILIAN', 'race_WHITE - EASTERN EUROPEAN', 'race_WHITE - OTHER EUROPEAN', 'race_WHITE - RUSSIAN', 'race_HISPANIC OR LATINO', 'marital_status_DIVORCED', 'marital_status_MARRIED', 'marital_status_SINGLE', 'marital_status_WIDOWED', 'marital_status_0', 'hospital_stay_duration', 'procedure_225464', 'procedure_225802', 'procedure_227712', 'admission_type_DIRECT EMER.', 'admission_type_DIRECT OBSERVATION', 'admission_type_ELECTIVE', 'admission_type_EU OBSERVATION', 'admission_type_EW EMER.', 'admission_type_OBSERVATION ADMIT', 'admission_type_URGENT', 'admission_type_SURGICAL SAME DAY ADMISSION', 'procedure_225446')
# % Combos Checked: 135 out of 714 which is 18.907563%
