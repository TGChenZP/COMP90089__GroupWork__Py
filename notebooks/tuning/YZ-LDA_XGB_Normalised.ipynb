# %% [markdown]
# # Tuning Script

# %%
# Parameters subject to change in every script - involved in naming

MODEL = 'lda'
PREPROCESSING = 'normalise'
TUNER = 'yangzhoub'
OPTIMISED_METRIC = 'f1'

# %% [markdown]
# ---

# %%
# detect whether this is a google environment

COLAB_ENVIRONMENT = False

try:
    from google.colab import drive
    drive.mount('/content/drive')
    COLAB_ENVIRONMENT = True
except:
    pass
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import sys
import os
import pickle

if COLAB_ENVIRONMENT:
    home_directory = './drive/MyDrive/LAB/COMP90089__GroupWork__Py/' # my home directory is stored in ./LAB of google drive
    if MODEL == 'ebr':
        # !pip install interpret==0.5.0
    elif MODEL == 'cbr':
        # !pip install catboost
    elif MODEL in ['tf', 'mlp']:
        # !pip install PyTorch2Sklearn
    # !pip install JXAutoML
else:
    home_directory = '../../'

from JXAutoML.YangZhouB_10CV import YangZhouB_10CV as Tuner

import pandas as pd
# Out:
# Requirement already satisfied: JXAutoML in /usr/local/lib/python3.10/dist-packages (0.4.4)

# %%
# Parameters that are same for every script

FOLDS = 10  # we have decided to do 10 fold validation

SEED = 42

TASK_TYPE = 'Classification'  # this task is a classification task

# we have decided to tune features as hp
TUNE_FEATURES_AS_HYPERPARAMETERS = True

# %% [markdown]
# ---

# %%
# model to use to tune
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as clf

# what values to try for each hyperparameter
parameter_choices = {
    'tol': (0.00001, 0.0001, 0.001, 0.01, 0.1, 1, 10),
    'solver': ('eigen', 'lsqr')
}

# what values to set non-tuneable parameters/hyperparameters
non_tunable_hyperparameters_dict = {
    'shrinkage': 'auto',

}

# %% [markdown]
# ---

# %% [markdown]
# Read in and Prepare Data

# %%
# Import data and store as lists

train_x_list = []
train_y_list = []
val_x_list = []
val_y_list = []

for i in range(FOLDS):
    train_data = pd.read_csv(
        f'{home_directory}data/curated/modelling/{PREPROCESSING}/train_{i}.csv')
    val_data = pd.read_csv(
        f'{home_directory}data/curated/modelling/{PREPROCESSING}/val_{i}.csv')

    # get the correct rows for X and y
    train_x = train_data.drop(
        ['mortality_status', 'subject_id', 'hadm_id', 'stay_id'], axis=1)
    train_y = train_data['mortality_status']
    val_x = val_data.drop(
        ['mortality_status', 'subject_id', 'hadm_id', 'stay_id'], axis=1)
    val_y = val_data['mortality_status']

    train_x_list.append(train_x)
    train_y_list.append(train_y)
    val_x_list.append(val_x)
    val_y_list.append(val_y)

# %%
# Import feature importance ordering

with open(f'{home_directory}models/xgb_feature_importance_ordering_{PREPROCESSING}.pickle', 'rb') as f:
    feature_importance_ordering = pickle.load(f)

# %% [markdown]
# Set parameters

# %%
# initialisation
tuner = Tuner()

print('---')

# define what model we are tuning
tuner.read_in_model(clf, TASK_TYPE, optimised_metric=OPTIMISED_METRIC)

print('---')

# read in the data for training and validation
tuner.read_in_data(train_x_list, train_y_list, val_x_list, val_y_list)

print('---')

# set what hp values to tune
tuner.set_hyperparameters(parameter_choices)
# WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

# set up hp values that need to be changed from default but NOT to be tuned
tuner.set_non_tuneable_hyperparameters(non_tunable_hyperparameters_dict)

print('---')

# set up feature importance ordering

if TUNE_FEATURES_AS_HYPERPARAMETERS:
    tuner.set_features(feature_importance_ordering)
    # WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

try:  # try to read in previous results to continue tuning ...
    tuner.read_in_tuning_result_df(
        f'{home_directory}models/tuning/{TUNER}_{MODEL}_{PREPROCESSING}.csv')
except:
    print('No previous tuning data read in')

print('---')

# set up where to save the tuning result csv
tuner.set_tuning_result_saving_address(
    f'{home_directory}models/tuning/{TUNER}_{MODEL}_{PREPROCESSING}.csv')

print('---')

# set up where to save the current best model
tuner.set_best_model_saving_address(
    f'{home_directory}models/tmp_models/{TUNER}_{MODEL}_{PREPROCESSING}')
# Out:
# YangZhouB Initialised
# ---
# Successfully read in model <class 'sklearn.discriminant_analysis.LinearDiscriminantAnalysis'>, which is a Classification model optimising for f1
# ---
# Read in Train X data list
# Read in Train y data list
# Read in Val X data list
# Read in Val y data list
# ---
# Successfully recorded hyperparameter choices
# ---
# Successfully recorded non_tuneable_hyperparameter choices
# ---
# Successfully recorded tuneable feature combination choices and updated relevant internal structures
# ---
# Successfully read in tuning result of 187 rows, for 187.0 combos
# ---
# Successfully set tuning output address
# ---
# Successfully set best model output address

# %%
# ignore warnings

import warnings
warnings.filterwarnings("ignore")

# %%
# begin tuning ... (or continue training)

tuner.tune()
# Out:
# BEGIN TUNING
#
#
# STAGE ZERO: Tune all Cruise combinations
#
#
# As new Best Combo (3, 1, 20) was read in, best_clf is set to None
# Already Trained and Tested combination (val score of 0.3015):
#             {'tol': 0.01, 'solver': 'lsqr', 'features': 20}
#             Current best combo (with val score 0.3015):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 20}
#         Has trained 187 of 1008 combinations so far
# As new Best Combo (3, 1, 15) was read in, best_clf is set to None
# Already Trained and Tested combination (val score of 0.3766):
#             {'tol': 0.01, 'solver': 'lsqr', 'features': 15}
#             Current best combo (with val score 0.3766):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 15}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.3015):
#             {'tol': 0.01, 'solver': 'eigen', 'features': 20}
#             Current best combo (with val score 0.3766):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 15}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.3666):
#             {'tol': 1e-05, 'solver': 'eigen', 'features': 10}
#             Current best combo (with val score 0.3766):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 15}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.2234):
#             {'tol': 0.01, 'solver': 'eigen', 'features': 59}
#             Current best combo (with val score 0.3766):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 15}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.3015):
#             {'tol': 1e-05, 'solver': 'eigen', 'features': 20}
#             Current best combo (with val score 0.3766):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 15}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.3139):
#             {'tol': 0.01, 'solver': 'lsqr', 'features': 25}
#             Current best combo (with val score 0.3766):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 15}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.3015):
#             {'tol': 1e-05, 'solver': 'lsqr', 'features': 20}
#             Current best combo (with val score 0.3766):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 15}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.2384):
#             {'tol': 1e-05, 'solver': 'eigen', 'features': 40}
#             Current best combo (with val score 0.3766):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 15}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.2157):
#             {'tol': 10, 'solver': 'eigen', 'features': 50}
#             Current best combo (with val score 0.3766):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 15}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.226):
#             {'tol': 0.01, 'solver': 'eigen', 'features': 67}
#             Current best combo (with val score 0.3766):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 15}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.1986):
#             {'tol': 1e-05, 'solver': 'lsqr', 'features': 45}
#             Current best combo (with val score 0.3766):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 15}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.2933):
#             {'tol': 1e-05, 'solver': 'lsqr', 'features': 0}
#             Current best combo (with val score 0.3766):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 15}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.2157):
#             {'tol': 1e-05, 'solver': 'lsqr', 'features': 50}
#             Current best combo (with val score 0.3766):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 15}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.2941):
#             {'tol': 10, 'solver': 'eigen', 'features': 5}
#             Current best combo (with val score 0.3766):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 15}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.2933):
#             {'tol': 0.01, 'solver': 'lsqr', 'features': 0}
#             Current best combo (with val score 0.3766):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 15}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.2231):
#             {'tol': 1e-05, 'solver': 'lsqr', 'features': 55}
#             Current best combo (with val score 0.3766):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 15}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.2628):
#             {'tol': 0.01, 'solver': 'eigen', 'features': 35}
#             Current best combo (with val score 0.3766):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 15}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.2231):
#             {'tol': 0.01, 'solver': 'lsqr', 'features': 55}
#             Current best combo (with val score 0.3766):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 15}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.226):
#             {'tol': 10, 'solver': 'eigen', 'features': 67}
#             Current best combo (with val score 0.3766):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 15}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.3015):
#             {'tol': 10, 'solver': 'eigen', 'features': 20}
#             Current best combo (with val score 0.3766):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 15}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.3766):
#             {'tol': 1e-05, 'solver': 'lsqr', 'features': 15}
#             Current best combo (with val score 0.3766):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 15}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.2231):
#             {'tol': 10, 'solver': 'lsqr', 'features': 55}
#             Current best combo (with val score 0.3766):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 15}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.3766):
#             {'tol': 0.01, 'solver': 'eigen', 'features': 15}
#             Current best combo (with val score 0.3766):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 15}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.1986):
#             {'tol': 10, 'solver': 'lsqr', 'features': 45}
#             Current best combo (with val score 0.3766):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 15}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.2941):
#             {'tol': 10, 'solver': 'lsqr', 'features': 5}
#             Current best combo (with val score 0.3766):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 15}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.2234):
#             {'tol': 1e-05, 'solver': 'lsqr', 'features': 63}
#             Current best combo (with val score 0.3766):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 15}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.1986):
#             {'tol': 0.01, 'solver': 'eigen', 'features': 45}
#             Current best combo (with val score 0.3766):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 15}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.2628):
#             {'tol': 0.01, 'solver': 'lsqr', 'features': 35}
#             Current best combo (with val score 0.3766):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 15}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.2548):
#             {'tol': 1e-05, 'solver': 'lsqr', 'features': 30}
#             Current best combo (with val score 0.3766):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 15}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.2548):
#             {'tol': 10, 'solver': 'eigen', 'features': 30}
#             Current best combo (with val score 0.3766):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 15}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.2628):
#             {'tol': 10, 'solver': 'eigen', 'features': 35}
#             Current best combo (with val score 0.3766):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 15}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.2941):
#             {'tol': 0.01, 'solver': 'eigen', 'features': 5}
#             Current best combo (with val score 0.3766):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 15}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.3666):
#             {'tol': 1e-05, 'solver': 'lsqr', 'features': 10}
#             Current best combo (with val score 0.3766):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 15}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.2941):
#             {'tol': 1e-05, 'solver': 'lsqr', 'features': 5}
#             Current best combo (with val score 0.3766):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 15}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.3139):
#             {'tol': 1e-05, 'solver': 'lsqr', 'features': 25}
#             Current best combo (with val score 0.3766):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 15}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.2249):
#             {'tol': 10, 'solver': 'eigen', 'features': 71}
#             Current best combo (with val score 0.3766):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 15}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.2234):
#             {'tol': 0.01, 'solver': 'lsqr', 'features': 63}
#             Current best combo (with val score 0.3766):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 15}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.2234):
#             {'tol': 10, 'solver': 'eigen', 'features': 59}
#             Current best combo (with val score 0.3766):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 15}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.2548):
#             {'tol': 1e-05, 'solver': 'eigen', 'features': 30}
#             Current best combo (with val score 0.3766):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 15}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.2384):
#             {'tol': 10, 'solver': 'lsqr', 'features': 40}
#             Current best combo (with val score 0.3766):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 15}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.3139):
#             {'tol': 10, 'solver': 'eigen', 'features': 25}
#             Current best combo (with val score 0.3766):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 15}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.3666):
#             {'tol': 0.01, 'solver': 'eigen', 'features': 10}
#             Current best combo (with val score 0.3766):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 15}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.2234):
#             {'tol': 10, 'solver': 'lsqr', 'features': 63}
#             Current best combo (with val score 0.3766):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 15}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.2231):
#             {'tol': 1e-05, 'solver': 'eigen', 'features': 55}
#             Current best combo (with val score 0.3766):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 15}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.2548):
#             {'tol': 0.01, 'solver': 'eigen', 'features': 30}
#             Current best combo (with val score 0.3766):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 15}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.2231):
#             {'tol': 0.01, 'solver': 'eigen', 'features': 55}
#             Current best combo (with val score 0.3766):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 15}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.2234):
#             {'tol': 10, 'solver': 'lsqr', 'features': 59}
#             Current best combo (with val score 0.3766):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 15}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.2628):
#             {'tol': 1e-05, 'solver': 'lsqr', 'features': 35}
#             Current best combo (with val score 0.3766):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 15}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.3766):
#             {'tol': 10, 'solver': 'lsqr', 'features': 15}
#             Current best combo (with val score 0.3766):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 15}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.3015):
#             {'tol': 10, 'solver': 'lsqr', 'features': 20}
#             Current best combo (with val score 0.3766):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 15}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.1986):
#             {'tol': 10, 'solver': 'eigen', 'features': 45}
#             Current best combo (with val score 0.3766):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 15}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.2234):
#             {'tol': 0.01, 'solver': 'eigen', 'features': 63}
#             Current best combo (with val score 0.3766):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 15}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.2234):
#             {'tol': 1e-05, 'solver': 'eigen', 'features': 63}
#             Current best combo (with val score 0.3766):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 15}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.3666):
#             {'tol': 10, 'solver': 'eigen', 'features': 10}
#             Current best combo (with val score 0.3766):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 15}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.3666):
#             {'tol': 0.01, 'solver': 'lsqr', 'features': 10}
#             Current best combo (with val score 0.3766):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 15}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.2933):
#             {'tol': 0.01, 'solver': 'eigen', 'features': 0}
#             Current best combo (with val score 0.3766):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 15}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.1986):
#             {'tol': 1e-05, 'solver': 'eigen', 'features': 45}
#             Current best combo (with val score 0.3766):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 15}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.2941):
#             {'tol': 1e-05, 'solver': 'eigen', 'features': 5}
#             Current best combo (with val score 0.3766):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 15}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.2157):
#             {'tol': 0.01, 'solver': 'lsqr', 'features': 50}
#             Current best combo (with val score 0.3766):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 15}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.2628):
#             {'tol': 10, 'solver': 'lsqr', 'features': 35}
#             Current best combo (with val score 0.3766):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 15}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.226):
#             {'tol': 1e-05, 'solver': 'lsqr', 'features': 67}
#             Current best combo (with val score 0.3766):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 15}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.3139):
#             {'tol': 0.01, 'solver': 'eigen', 'features': 25}
#             Current best combo (with val score 0.3766):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 15}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.2231):
#             {'tol': 10, 'solver': 'eigen', 'features': 55}
#             Current best combo (with val score 0.3766):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 15}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.2249):
#             {'tol': 1e-05, 'solver': 'eigen', 'features': 71}
#             Current best combo (with val score 0.3766):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 15}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.2234):
#             {'tol': 10, 'solver': 'eigen', 'features': 63}
#             Current best combo (with val score 0.3766):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 15}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.2384):
#             {'tol': 0.01, 'solver': 'eigen', 'features': 40}
#             Current best combo (with val score 0.3766):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 15}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.2249):
#             {'tol': 0.01, 'solver': 'lsqr', 'features': 71}
#             Current best combo (with val score 0.3766):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 15}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.226):
#             {'tol': 0.01, 'solver': 'lsqr', 'features': 67}
#             Current best combo (with val score 0.3766):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 15}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.2548):
#             {'tol': 0.01, 'solver': 'lsqr', 'features': 30}
#             Current best combo (with val score 0.3766):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 15}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.2941):
#             {'tol': 0.01, 'solver': 'lsqr', 'features': 5}
#             Current best combo (with val score 0.3766):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 15}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.226):
#             {'tol': 10, 'solver': 'lsqr', 'features': 67}
#             Current best combo (with val score 0.3766):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 15}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.2234):
#             {'tol': 1e-05, 'solver': 'lsqr', 'features': 59}
#             Current best combo (with val score 0.3766):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 15}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.3139):
#             {'tol': 1e-05, 'solver': 'eigen', 'features': 25}
#             Current best combo (with val score 0.3766):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 15}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.2234):
#             {'tol': 1e-05, 'solver': 'eigen', 'features': 59}
#             Current best combo (with val score 0.3766):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 15}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.2933):
#             {'tol': 1e-05, 'solver': 'eigen', 'features': 0}
#             Current best combo (with val score 0.3766):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 15}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.3139):
#             {'tol': 10, 'solver': 'lsqr', 'features': 25}
#             Current best combo (with val score 0.3766):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 15}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.2249):
#             {'tol': 10, 'solver': 'lsqr', 'features': 71}
#             Current best combo (with val score 0.3766):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 15}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.2384):
#             {'tol': 0.01, 'solver': 'lsqr', 'features': 40}
#             Current best combo (with val score 0.3766):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 15}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.3766):
#             {'tol': 10, 'solver': 'eigen', 'features': 15}
#             Current best combo (with val score 0.3766):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 15}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.2384):
#             {'tol': 1e-05, 'solver': 'lsqr', 'features': 40}
#             Current best combo (with val score 0.3766):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 15}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.2548):
#             {'tol': 10, 'solver': 'lsqr', 'features': 30}
#             Current best combo (with val score 0.3766):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 15}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.2628):
#             {'tol': 1e-05, 'solver': 'eigen', 'features': 35}
#             Current best combo (with val score 0.3766):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 15}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.2234):
#             {'tol': 0.01, 'solver': 'lsqr', 'features': 59}
#             Current best combo (with val score 0.3766):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 15}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.2249):
#             {'tol': 1e-05, 'solver': 'lsqr', 'features': 71}
#             Current best combo (with val score 0.3766):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 15}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.2157):
#             {'tol': 10, 'solver': 'lsqr', 'features': 50}
#             Current best combo (with val score 0.3766):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 15}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.226):
#             {'tol': 1e-05, 'solver': 'eigen', 'features': 67}
#             Current best combo (with val score 0.3766):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 15}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.2933):
#             {'tol': 10, 'solver': 'lsqr', 'features': 0}
#             Current best combo (with val score 0.3766):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 15}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.1986):
#             {'tol': 0.01, 'solver': 'lsqr', 'features': 45}
#             Current best combo (with val score 0.3766):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 15}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.2157):
#             {'tol': 1e-05, 'solver': 'eigen', 'features': 50}
#             Current best combo (with val score 0.3766):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 15}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.3766):
#             {'tol': 1e-05, 'solver': 'eigen', 'features': 15}
#             Current best combo (with val score 0.3766):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 15}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.3666):
#             {'tol': 10, 'solver': 'lsqr', 'features': 10}
#             Current best combo (with val score 0.3766):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 15}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.2384):
#             {'tol': 10, 'solver': 'eigen', 'features': 40}
#             Current best combo (with val score 0.3766):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 15}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.2157):
#             {'tol': 0.01, 'solver': 'eigen', 'features': 50}
#             Current best combo (with val score 0.3766):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 15}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.2626):
#             {'tol': 0.01, 'solver': 'lsqr', 'features': 36}
#             Current best combo (with val score 0.3766):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 15}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.2249):
#             {'tol': 0.01, 'solver': 'eigen', 'features': 71}
#             Current best combo (with val score 0.3766):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 15}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.2933):
#             {'tol': 10, 'solver': 'eigen', 'features': 0}
#             Current best combo (with val score 0.3766):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 15}
#         Has trained 187 of 1008 combinations so far
#
#
# STAGE ONE: Begin initial Guidance system
#
#
# Guidance: initial round
#
# 	round 0 iteration:  0
#
# Already Trained and Tested combination (val score of 0.2626):
#             {'tol': 0.001, 'solver': 'lsqr', 'features': 36}
#             Current best combo (with val score 0.3766):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 15}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.2626):
#             {'tol': 0.1, 'solver': 'lsqr', 'features': 36}
#             Current best combo (with val score 0.3766):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 15}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.2626):
#             {'tol': 0.01, 'solver': 'eigen', 'features': 36}
#             Current best combo (with val score 0.3766):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 15}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.2628):
#             {'tol': 0.01, 'solver': 'lsqr', 'features': 35}
#             Current best combo (with val score 0.3766):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 15}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.2604):
#             {'tol': 0.01, 'solver': 'lsqr', 'features': 37}
#             Current best combo (with val score 0.3766):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 15}
#         Has trained 187 of 1008 combinations so far
# 	round 0 iteration:  1
#
# Already Trained and Tested combination (val score of 0.2626):
#             {'tol': 0.0001, 'solver': 'lsqr', 'features': 36}
#             Current best combo (with val score 0.3766):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 15}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.2626):
#             {'tol': 0.01, 'solver': 'lsqr', 'features': 36}
#             Current best combo (with val score 0.3766):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 15}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.2626):
#             {'tol': 0.001, 'solver': 'eigen', 'features': 36}
#             Current best combo (with val score 0.3766):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 15}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.2628):
#             {'tol': 0.001, 'solver': 'lsqr', 'features': 35}
#             Current best combo (with val score 0.3766):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 15}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.2604):
#             {'tol': 0.001, 'solver': 'lsqr', 'features': 37}
#             Current best combo (with val score 0.3766):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 15}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.2626):
#             {'tol': 0.01, 'solver': 'lsqr', 'features': 36}
#             Current best combo (with val score 0.3766):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 15}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.2626):
#             {'tol': 1, 'solver': 'lsqr', 'features': 36}
#             Current best combo (with val score 0.3766):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 15}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.2626):
#             {'tol': 0.1, 'solver': 'eigen', 'features': 36}
#             Current best combo (with val score 0.3766):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 15}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.2628):
#             {'tol': 0.1, 'solver': 'lsqr', 'features': 35}
#             Current best combo (with val score 0.3766):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 15}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.2604):
#             {'tol': 0.1, 'solver': 'lsqr', 'features': 37}
#             Current best combo (with val score 0.3766):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 15}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.2626):
#             {'tol': 0.001, 'solver': 'eigen', 'features': 36}
#             Current best combo (with val score 0.3766):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 15}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.2626):
#             {'tol': 0.1, 'solver': 'eigen', 'features': 36}
#             Current best combo (with val score 0.3766):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 15}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.2626):
#             {'tol': 0.01, 'solver': 'lsqr', 'features': 36}
#             Current best combo (with val score 0.3766):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 15}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.2628):
#             {'tol': 0.01, 'solver': 'eigen', 'features': 35}
#             Current best combo (with val score 0.3766):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 15}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.2604):
#             {'tol': 0.01, 'solver': 'eigen', 'features': 37}
#             Current best combo (with val score 0.3766):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 15}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.2628):
#             {'tol': 0.001, 'solver': 'lsqr', 'features': 35}
#             Current best combo (with val score 0.3766):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 15}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.2628):
#             {'tol': 0.1, 'solver': 'lsqr', 'features': 35}
#             Current best combo (with val score 0.3766):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 15}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.2628):
#             {'tol': 0.01, 'solver': 'eigen', 'features': 35}
#             Current best combo (with val score 0.3766):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 15}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.2629):
#             {'tol': 0.01, 'solver': 'lsqr', 'features': 34}
#             Current best combo (with val score 0.3766):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 15}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.2626):
#             {'tol': 0.01, 'solver': 'lsqr', 'features': 36}
#             Current best combo (with val score 0.3766):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 15}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.2604):
#             {'tol': 0.001, 'solver': 'lsqr', 'features': 37}
#             Current best combo (with val score 0.3766):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 15}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.2604):
#             {'tol': 0.1, 'solver': 'lsqr', 'features': 37}
#             Current best combo (with val score 0.3766):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 15}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.2604):
#             {'tol': 0.01, 'solver': 'eigen', 'features': 37}
#             Current best combo (with val score 0.3766):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 15}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.2626):
#             {'tol': 0.01, 'solver': 'lsqr', 'features': 36}
#             Current best combo (with val score 0.3766):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 15}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.2407):
#             {'tol': 0.01, 'solver': 'lsqr', 'features': 38}
#             Current best combo (with val score 0.3766):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 15}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.3766):
#             {'tol': 0.001, 'solver': 'lsqr', 'features': 15}
#             Current best combo (with val score 0.3766):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 15}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.3766):
#             {'tol': 0.1, 'solver': 'lsqr', 'features': 15}
#             Current best combo (with val score 0.3766):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 15}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.3766):
#             {'tol': 0.01, 'solver': 'eigen', 'features': 15}
#             Current best combo (with val score 0.3766):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 15}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.3744):
#             {'tol': 0.01, 'solver': 'lsqr', 'features': 14}
#             Current best combo (with val score 0.3766):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 15}
#         Has trained 187 of 1008 combinations so far
# As new Best Combo (3, 1, 16) was read in, best_clf is set to None
# Already Trained and Tested combination (val score of 0.3792):
#             {'tol': 0.01, 'solver': 'lsqr', 'features': 16}
#             Current best combo (with val score 0.3792):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 16}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.3792):
#             {'tol': 0.001, 'solver': 'lsqr', 'features': 16}
#             Current best combo (with val score 0.3792):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 16}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.3792):
#             {'tol': 0.1, 'solver': 'lsqr', 'features': 16}
#             Current best combo (with val score 0.3792):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 16}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.3792):
#             {'tol': 0.01, 'solver': 'eigen', 'features': 16}
#             Current best combo (with val score 0.3792):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 16}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.3766):
#             {'tol': 0.01, 'solver': 'lsqr', 'features': 15}
#             Current best combo (with val score 0.3792):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 16}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.2827):
#             {'tol': 0.01, 'solver': 'lsqr', 'features': 17}
#             Current best combo (with val score 0.3792):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 16}
#         Has trained 187 of 1008 combinations so far
# % Combos Checked Thus Far: 187 out of 1008 which is 18.551587%
# STAGE TWO: Begin Cruise system
#
#
# Cruising Coordrdinate 1 of 96
#
# Cruising Coordrdinate 2 of 96
#
# Cruising Coordrdinate 3 of 96
#
# Cruising Coordrdinate 4 of 96
#
# Cruising Coordrdinate 5 of 96
#
# Cruising Coordrdinate 6 of 96
#
# Cruising Coordrdinate 7 of 96
#
# Cruising Coordrdinate 8 of 96
#
# Cruising Coordrdinate 9 of 96
#
# Cruising Coordrdinate 10 of 96
#
# Cruising Coordrdinate 11 of 96
#
# Cruising Coordrdinate 12 of 96
#
# Cruising Coordrdinate 13 of 96
#
# Cruising Coordrdinate 14 of 96
#
# Cruising Coordrdinate 15 of 96
#
# Cruising Coordrdinate 16 of 96
#
# Cruising Coordrdinate 17 of 96
#
# Cruising Coordrdinate 18 of 96
#
# Cruising Coordrdinate 19 of 96
#
# Cruising Coordrdinate 20 of 96
#
# Cruising Coordrdinate 21 of 96
#
# Cruising Coordrdinate 22 of 96
#
# Cruising Coordrdinate 23 of 96
#
# Cruising Coordrdinate 24 of 96
#
# Cruising Coordrdinate 25 of 96
#
# Cruising Coordrdinate 26 of 96
#
# Cruising Coordrdinate 27 of 96
#
# Cruising Coordrdinate 28 of 96
#
# Cruising Coordrdinate 29 of 96
#
# Cruising Coordrdinate 30 of 96
#
# Cruising Coordrdinate 31 of 96
#
# Cruising Coordrdinate 32 of 96
#
# Cruising Coordrdinate 33 of 96
#
# Cruising Coordrdinate 34 of 96
#
# Cruising Coordrdinate 35 of 96
#
# Cruising Coordrdinate 36 of 96
#
# Cruising Coordrdinate 37 of 96
#
# Cruising Coordrdinate 38 of 96
#
# Cruising Coordrdinate 39 of 96
#
# Cruising Coordrdinate 40 of 96
#
# Cruising Coordrdinate 41 of 96
#
# Cruising Coordrdinate 42 of 96
#
# Cruising Coordrdinate 43 of 96
#
# Cruising Coordrdinate 44 of 96
#
# Cruising Coordrdinate 45 of 96
#
# Cruising Coordrdinate 46 of 96
#
# Cruising Coordrdinate 47 of 96
#
# Cruising Coordrdinate 48 of 96
#
# Cruising Coordrdinate 49 of 96
#
# Cruising Coordrdinate 50 of 96
#
# Cruising Coordrdinate 51 of 96
#
# Cruising Coordrdinate 52 of 96
#
# Cruising Coordrdinate 53 of 96
#
# Cruising Coordrdinate 54 of 96
#
# Cruising Coordrdinate 55 of 96
#
# Cruising Coordrdinate 56 of 96
#
# Cruising Coordrdinate 57 of 96
#
# Cruising Coordrdinate 58 of 96
#
# Cruising Coordrdinate 59 of 96
#
# Cruising Coordrdinate 60 of 96
#
# Cruising Coordrdinate 61 of 96
#
# Cruising Coordrdinate 62 of 96
#
# Cruising Coordrdinate 63 of 96
#
# Cruising Coordrdinate 64 of 96
#
# Cruising Coordrdinate 65 of 96
#
# Cruising Coordrdinate 66 of 96
#
# Cruising Coordrdinate 67 of 96
#
# Cruising Coordrdinate 68 of 96
#
# Cruising Coordrdinate 69 of 96
#
# Cruising Coordrdinate 70 of 96
#
# Cruising Coordrdinate 71 of 96
#
# Cruising Coordrdinate 72 of 96
#
# Cruising Coordrdinate 73 of 96
#
# Cruising Coordrdinate 74 of 96
#
# Cruising Coordrdinate 75 of 96
#
# Cruising Coordrdinate 76 of 96
#
# Cruising Coordrdinate 77 of 96
#
# Cruising Coordrdinate 78 of 96
#
# Cruising Coordrdinate 79 of 96
#
# Cruise suspended due to suspicious case
# Guidance: round 1
#
# 	round 1 iteration:  0
#
# Already Trained and Tested combination (val score of 0.3666):
#             {'tol': 0.0001, 'solver': 'eigen', 'features': 10}
#             Current best combo (with val score 0.3792):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 16}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.3666):
#             {'tol': 1e-05, 'solver': 'lsqr', 'features': 10}
#             Current best combo (with val score 0.3792):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 16}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.3721):
#             {'tol': 1e-05, 'solver': 'eigen', 'features': 9}
#             Current best combo (with val score 0.3792):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 16}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.3727):
#             {'tol': 1e-05, 'solver': 'eigen', 'features': 11}
#             Current best combo (with val score 0.3792):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 16}
#         Has trained 187 of 1008 combinations so far
# 	round 1 iteration:  1
#
# Already Trained and Tested combination (val score of 0.3666):
#             {'tol': 1e-05, 'solver': 'eigen', 'features': 10}
#             Current best combo (with val score 0.3792):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 16}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.3666):
#             {'tol': 0.001, 'solver': 'eigen', 'features': 10}
#             Current best combo (with val score 0.3792):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 16}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.3666):
#             {'tol': 0.0001, 'solver': 'lsqr', 'features': 10}
#             Current best combo (with val score 0.3792):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 16}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.3721):
#             {'tol': 0.0001, 'solver': 'eigen', 'features': 9}
#             Current best combo (with val score 0.3792):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 16}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.3727):
#             {'tol': 0.0001, 'solver': 'eigen', 'features': 11}
#             Current best combo (with val score 0.3792):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 16}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.3666):
#             {'tol': 0.0001, 'solver': 'lsqr', 'features': 10}
#             Current best combo (with val score 0.3792):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 16}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.3666):
#             {'tol': 1e-05, 'solver': 'eigen', 'features': 10}
#             Current best combo (with val score 0.3792):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 16}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.3721):
#             {'tol': 1e-05, 'solver': 'lsqr', 'features': 9}
#             Current best combo (with val score 0.3792):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 16}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.3727):
#             {'tol': 1e-05, 'solver': 'lsqr', 'features': 11}
#             Current best combo (with val score 0.3792):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 16}
#         Has trained 187 of 1008 combinations so far
# ...
#             {'tol': 1, 'solver': 'lsqr', 'features': 15}
#             Current best combo (with val score 0.3792):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 16}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.3766):
#             {'tol': 10, 'solver': 'eigen', 'features': 15}
#             Current best combo (with val score 0.3792):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 16}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.3744):
#             {'tol': 10, 'solver': 'lsqr', 'features': 14}
#             Current best combo (with val score 0.3792):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 16}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.3792):
#             {'tol': 10, 'solver': 'lsqr', 'features': 16}
#             Current best combo (with val score 0.3792):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 16}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.3744):
#             {'tol': 1, 'solver': 'eigen', 'features': 14}
#             Current best combo (with val score 0.3792):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 16}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.3744):
#             {'tol': 10, 'solver': 'lsqr', 'features': 14}
#             Current best combo (with val score 0.3792):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 16}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.3703):
#             {'tol': 10, 'solver': 'eigen', 'features': 13}
#             Current best combo (with val score 0.3792):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 16}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.3766):
#             {'tol': 10, 'solver': 'eigen', 'features': 15}
#             Current best combo (with val score 0.3792):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 16}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.3792):
#             {'tol': 1, 'solver': 'eigen', 'features': 16}
#             Current best combo (with val score 0.3792):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 16}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.3792):
#             {'tol': 10, 'solver': 'lsqr', 'features': 16}
#             Current best combo (with val score 0.3792):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 16}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.3766):
#             {'tol': 10, 'solver': 'eigen', 'features': 15}
#             Current best combo (with val score 0.3792):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 16}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.2827):
#             {'tol': 10, 'solver': 'eigen', 'features': 17}
#             Current best combo (with val score 0.3792):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 16}
#         Has trained 187 of 1008 combinations so far
# % Combos Checked Thus Far: 187 out of 1008 which is 18.551587%
# Cruising Coordrdinate 93 of 96
#
# Cruise suspended due to suspicious case
# Guidance: round 9
#
# 	round 9 iteration:  0
#
# % Combos Checked Thus Far: 187 out of 1008 which is 18.551587%
# Cruising Coordrdinate 94 of 96
#
# Cruise suspended due to suspicious case
# Guidance: round 10
#
# 	round 10 iteration:  0
#
# % Combos Checked Thus Far: 187 out of 1008 which is 18.551587%
# Cruising Coordrdinate 95 of 96
#
# Cruise suspended due to suspicious case
# Guidance: round 11
#
# 	round 11 iteration:  0
#
# Already Trained and Tested combination (val score of 0.3766):
#             {'tol': 0.001, 'solver': 'eigen', 'features': 15}
#             Current best combo (with val score 0.3792):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 16}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.3766):
#             {'tol': 0.1, 'solver': 'eigen', 'features': 15}
#             Current best combo (with val score 0.3792):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 16}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.3766):
#             {'tol': 0.01, 'solver': 'lsqr', 'features': 15}
#             Current best combo (with val score 0.3792):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 16}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.3744):
#             {'tol': 0.01, 'solver': 'eigen', 'features': 14}
#             Current best combo (with val score 0.3792):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 16}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.3792):
#             {'tol': 0.01, 'solver': 'eigen', 'features': 16}
#             Current best combo (with val score 0.3792):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 16}
#         Has trained 187 of 1008 combinations so far
# 	round 11 iteration:  1
#
# Already Trained and Tested combination (val score of 0.3766):
#             {'tol': 0.001, 'solver': 'lsqr', 'features': 15}
#             Current best combo (with val score 0.3792):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 16}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.3766):
#             {'tol': 0.1, 'solver': 'lsqr', 'features': 15}
#             Current best combo (with val score 0.3792):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 16}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.3766):
#             {'tol': 0.01, 'solver': 'eigen', 'features': 15}
#             Current best combo (with val score 0.3792):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 16}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.3744):
#             {'tol': 0.01, 'solver': 'lsqr', 'features': 14}
#             Current best combo (with val score 0.3792):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 16}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.3792):
#             {'tol': 0.01, 'solver': 'lsqr', 'features': 16}
#             Current best combo (with val score 0.3792):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 16}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.3744):
#             {'tol': 0.001, 'solver': 'eigen', 'features': 14}
#             Current best combo (with val score 0.3792):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 16}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.3744):
#             {'tol': 0.1, 'solver': 'eigen', 'features': 14}
#             Current best combo (with val score 0.3792):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 16}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.3744):
#             {'tol': 0.01, 'solver': 'lsqr', 'features': 14}
#             Current best combo (with val score 0.3792):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 16}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.3703):
#             {'tol': 0.01, 'solver': 'eigen', 'features': 13}
#             Current best combo (with val score 0.3792):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 16}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.3766):
#             {'tol': 0.01, 'solver': 'eigen', 'features': 15}
#             Current best combo (with val score 0.3792):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 16}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.3792):
#             {'tol': 0.001, 'solver': 'eigen', 'features': 16}
#             Current best combo (with val score 0.3792):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 16}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.3792):
#             {'tol': 0.1, 'solver': 'eigen', 'features': 16}
#             Current best combo (with val score 0.3792):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 16}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.3792):
#             {'tol': 0.01, 'solver': 'lsqr', 'features': 16}
#             Current best combo (with val score 0.3792):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 16}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.3766):
#             {'tol': 0.01, 'solver': 'eigen', 'features': 15}
#             Current best combo (with val score 0.3792):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 16}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.2827):
#             {'tol': 0.01, 'solver': 'eigen', 'features': 17}
#             Current best combo (with val score 0.3792):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 16}
#         Has trained 187 of 1008 combinations so far
# % Combos Checked Thus Far: 187 out of 1008 which is 18.551587%
# Cruising Coordrdinate 96 of 96
#
# Cruise suspended due to suspicious case
# Guidance: round 12
#
# 	round 12 iteration:  0
#
# % Combos Checked Thus Far: 187 out of 1008 which is 18.551587%
# FINAL STAGE: Begin final Guidance system
#
#
# Guidance: round FINAL
#
# 	round FINAL iteration:  0
#
# Already Trained and Tested combination (val score of 0.3792):
#             {'tol': 0.001, 'solver': 'lsqr', 'features': 16}
#             Current best combo (with val score 0.3792):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 16}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.3792):
#             {'tol': 0.1, 'solver': 'lsqr', 'features': 16}
#             Current best combo (with val score 0.3792):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 16}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.3792):
#             {'tol': 0.01, 'solver': 'eigen', 'features': 16}
#             Current best combo (with val score 0.3792):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 16}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.3766):
#             {'tol': 0.01, 'solver': 'lsqr', 'features': 15}
#             Current best combo (with val score 0.3792):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 16}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.2827):
#             {'tol': 0.01, 'solver': 'lsqr', 'features': 17}
#             Current best combo (with val score 0.3792):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 16}
#         Has trained 187 of 1008 combinations so far
# 	round FINAL iteration:  1
#
# Already Trained and Tested combination (val score of 0.3792):
#             {'tol': 0.0001, 'solver': 'lsqr', 'features': 16}
#             Current best combo (with val score 0.3792):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 16}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.3792):
#             {'tol': 0.01, 'solver': 'lsqr', 'features': 16}
#             Current best combo (with val score 0.3792):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 16}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.3792):
#             {'tol': 0.001, 'solver': 'eigen', 'features': 16}
#             Current best combo (with val score 0.3792):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 16}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.3766):
#             {'tol': 0.001, 'solver': 'lsqr', 'features': 15}
#             Current best combo (with val score 0.3792):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 16}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.2827):
#             {'tol': 0.001, 'solver': 'lsqr', 'features': 17}
#             Current best combo (with val score 0.3792):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 16}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.3792):
#             {'tol': 0.01, 'solver': 'lsqr', 'features': 16}
#             Current best combo (with val score 0.3792):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 16}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.3792):
#             {'tol': 1, 'solver': 'lsqr', 'features': 16}
#             Current best combo (with val score 0.3792):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 16}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.3792):
#             {'tol': 0.1, 'solver': 'eigen', 'features': 16}
#             Current best combo (with val score 0.3792):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 16}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.3766):
#             {'tol': 0.1, 'solver': 'lsqr', 'features': 15}
#             Current best combo (with val score 0.3792):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 16}
#         Has trained 187 of 1008 combinations so far
# Already Trained and Tested combination (val score of 0.2827):
#             {'tol': 0.1, 'solver': 'lsqr', 'features': 17}
#             Current best combo (with val score 0.3792):
#                     {'tol': 0.01, 'solver': 'lsqr', 'features': 16}
#         Has trained 187 of 1008 combinations so far
# % Combos Checked Thus Far: 187 out of 1008 which is 18.551587%
# Max Val Score:
#  0.37915
# Max Val Score Std:
#  0.041836
# Best Combo Train Score:
#  0.569394
# Best Combo Train Score Std:
#  0.006436
# Max Combo Index:
#  (3, 1, 16) out of [7, 2, 72] (note best combo is 0-indexed)
# Max Combo Hyperparamer Combination:
#  {'tol': 0.01, 'solver': 'lsqr', 'features': 16}
# Max Combo Features:
#  ('procedure_228130', 'procedure_225792', 'procedure_228125', 'lods_score', 'ventilation_used', 'procedure_226236', 'hospital_stay_duration', 'procedure_225469', 'procedure_224270', 'procedure_225446', 'procedure_225802', 'procedure_227712', 'procedure_229580', 'procedure_225451', 'admission_type_DIRECT EMER.', 'admission_type_DIRECT OBSERVATION', 'admission_type_ELECTIVE', 'admission_type_EU OBSERVATION', 'admission_type_EW EMER.', 'admission_type_OBSERVATION ADMIT', 'admission_type_URGENT', 'admission_type_SURGICAL SAME DAY ADMISSION', 'procedure_224385', 'procedure_224267')
# % Combos Checked: 187 out of 1008 which is 18.551587%
