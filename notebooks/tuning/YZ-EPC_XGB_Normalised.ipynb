# %% [markdown]
# # Tuning Script

# %%
# Parameters subject to change in every script - involved in naming

MODEL = 'epc'
PREPROCESSING = 'normalise'
TUNER = 'yangzhoub'
OPTIMISED_METRIC = 'f1'

# %% [markdown]
# ---

# %%
# detect whether this is a google environment

COLAB_ENVIRONMENT = False

try:
    from google.colab import drive
    drive.mount('/content/drive')
    COLAB_ENVIRONMENT = True
except:
    pass
# Out:
# Mounted at /content/drive

# %%
import sys
import os
import pickle

if COLAB_ENVIRONMENT:
    home_directory = './drive/MyDrive/LAB/COMP90089__GroupWork__Py/' # my home directory is stored in ./LAB of google drive
    if MODEL == 'ebr':
        # !pip install interpret==0.5.0
    elif MODEL == 'cbr':
        # !pip install catboost
    elif MODEL == 'epc':
        # !pip install scikit-learn-extra
    elif MODEL in ['tf', 'mlp']:
        # !pip install PyTorch2Sklearn
    # !pip install JXAutoML
else:
    home_directory = '../../'

from JXAutoML.YangZhouB_10CV import YangZhouB_10CV as Tuner

import pandas as pd
# Out:
# Collecting scikit-learn-extra
#   Downloading scikit_learn_extra-0.3.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.6 kB)
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.10/dist-packages (from scikit-learn-extra) (1.26.4)
# Requirement already satisfied: scipy>=0.19.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn-extra) (1.13.1)
# Requirement already satisfied: scikit-learn>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn-extra) (1.3.2)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.23.0->scikit-learn-extra) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.23.0->scikit-learn-extra) (3.5.0)
# Downloading scikit_learn_extra-0.3.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 23.5 MB/s eta 0:00:00
# Installing collected packages: scikit-learn-extra
# Successfully installed scikit-learn-extra-0.3.0
# Collecting JXAutoML
#   Downloading JXAutoML-0.4.4-py3-none-any.whl.metadata (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.2/67.2 kB 3.0 MB/s eta 0:00:00
# Downloading JXAutoML-0.4.4-py3-none-any.whl (52 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.1/52.1 kB 3.3 MB/s eta 0:00:00
# Installing collected packages: JXAutoML
# Successfully installed JXAutoML-0.4.4

# %%
# Parameters that are same for every script

FOLDS = 10  # we have decided to do 10 fold validation

SEED = 42

TASK_TYPE = 'Classification'  # this task is a classification task

# we have decided to tune features as hp
TUNE_FEATURES_AS_HYPERPARAMETERS = True

# %% [markdown]
# ---

# %%
# model to use to tune
from sklearn_extra.kernel_methods import EigenProClassifier as clf

# what values to try for each hyperparameter
parameter_choices = {
    'batch_size': (32, 64, 128, 256),
    'n_epoch': list(range(1, 10))

}

# what values to set non-tuneable parameters/hyperparameters
non_tunable_hyperparameters_dict = {
                                    'random_state': 42,

                                    }

# %% [markdown]
# ---

# %% [markdown]
# Read in and Prepare Data

# %%
# Import data and store as lists

train_x_list = []
train_y_list = []
val_x_list = []
val_y_list = []

for i in range(FOLDS):
    train_data = pd.read_csv(
        f'{home_directory}data/curated/modelling/{PREPROCESSING}/train_{i}.csv')
    val_data = pd.read_csv(
        f'{home_directory}data/curated/modelling/{PREPROCESSING}/val_{i}.csv')

    # get the correct rows for X and y
    train_x = train_data.drop(
        ['mortality_status', 'subject_id', 'hadm_id', 'stay_id'], axis=1)
    train_y = train_data['mortality_status']
    val_x = val_data.drop(
        ['mortality_status', 'subject_id', 'hadm_id', 'stay_id'], axis=1)
    val_y = val_data['mortality_status']

    train_x_list.append(train_x)
    train_y_list.append(train_y)
    val_x_list.append(val_x)
    val_y_list.append(val_y)

# %%
# Import feature importance ordering

with open(f'{home_directory}models/xgb_feature_importance_ordering_{PREPROCESSING}.pickle', 'rb') as f:
    feature_importance_ordering = pickle.load(f)

# %% [markdown]
# Set parameters

# %%
# initialisation
tuner = Tuner()

print('---')

# define what model we are tuning
tuner.read_in_model(clf, TASK_TYPE, optimised_metric=OPTIMISED_METRIC)

print('---')

# read in the data for training and validation
tuner.read_in_data(train_x_list, train_y_list, val_x_list, val_y_list)

print('---')

# set what hp values to tune
tuner.set_hyperparameters(parameter_choices)
# WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

# set up hp values that need to be changed from default but NOT to be tuned
tuner.set_non_tuneable_hyperparameters(non_tunable_hyperparameters_dict)

print('---')

# set up feature importance ordering

if TUNE_FEATURES_AS_HYPERPARAMETERS:
    tuner.set_features(feature_importance_ordering)
    # WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

try:  # try to read in previous results to continue tuning ...
    tuner.read_in_tuning_result_df(
        f'{home_directory}models/tuning/{TUNER}_{MODEL}_{PREPROCESSING}.csv')
except:
    print('No previous tuning data read in')

print('---')

# set up where to save the tuning result csv
tuner.set_tuning_result_saving_address(
    f'{home_directory}models/tuning/{TUNER}_{MODEL}_{PREPROCESSING}.csv')

print('---')

# set up where to save the current best model
tuner.set_best_model_saving_address(
    f'{home_directory}models/tmp_models/{TUNER}_{MODEL}_{PREPROCESSING}')
# Out:
# YangZhouB Initialised
# ---
# Successfully read in model <class 'sklearn_extra.kernel_methods._eigenpro.EigenProClassifier'>, which is a Classification model optimising for f1
# ---
# Read in Train X data list
# Read in Train y data list
# Read in Val X data list
# Read in Val y data list
# ---
# Successfully recorded hyperparameter choices
# ---
# Successfully recorded non_tuneable_hyperparameter choices
# ---
# Successfully recorded tuneable feature combination choices and updated relevant internal structures
# ---
# Successfully read in tuning result of 137 rows, for 137.0 combos
# ---
# Successfully set tuning output address
# ---
# Successfully set best model output address

# %%
# ignore warnings

import warnings
warnings.filterwarnings("ignore")

# %%
# begin tuning ... (or continue training)

tuner.tune()
# Out:
# BEGIN TUNING
#
#
# STAGE ZERO: Tune all Cruise combinations
#
#
# As new Best Combo (3, 0, 20) was read in, best_clf is set to None
# Already Trained and Tested combination (val score of 0.0194):
#             {'batch_size': 256, 'n_epoch': 1, 'features': 20}
#             Current best combo (with val score 0.0194):
#                     {'batch_size': 256, 'n_epoch': 1, 'features': 20}
#         Has trained 137 of 2592 combinations so far
# As new Best Combo (3, 0, 15) was read in, best_clf is set to None
# Already Trained and Tested combination (val score of 0.4084):
#             {'batch_size': 256, 'n_epoch': 1, 'features': 15}
#             Current best combo (with val score 0.4084):
#                     {'batch_size': 256, 'n_epoch': 1, 'features': 15}
#         Has trained 137 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.1473):
#             {'batch_size': 32, 'n_epoch': 9, 'features': 20}
#             Current best combo (with val score 0.4084):
#                     {'batch_size': 256, 'n_epoch': 1, 'features': 15}
#         Has trained 137 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.4055):
#             {'batch_size': 32, 'n_epoch': 1, 'features': 10}
#             Current best combo (with val score 0.4084):
#                     {'batch_size': 256, 'n_epoch': 1, 'features': 15}
#         Has trained 137 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 32, 'n_epoch': 9, 'features': 59}
#             Current best combo (with val score 0.4084):
#                     {'batch_size': 256, 'n_epoch': 1, 'features': 15}
#         Has trained 137 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.0226):
#             {'batch_size': 32, 'n_epoch': 1, 'features': 20}
#             Current best combo (with val score 0.4084):
#                     {'batch_size': 256, 'n_epoch': 1, 'features': 15}
#         Has trained 137 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.0196):
#             {'batch_size': 256, 'n_epoch': 1, 'features': 25}
#             Current best combo (with val score 0.4084):
#                     {'batch_size': 256, 'n_epoch': 1, 'features': 15}
#         Has trained 137 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.1156):
#             {'batch_size': 32, 'n_epoch': 5, 'features': 20}
#             Current best combo (with val score 0.4084):
#                     {'batch_size': 256, 'n_epoch': 1, 'features': 15}
#         Has trained 137 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 32, 'n_epoch': 1, 'features': 40}
#             Current best combo (with val score 0.4084):
#                     {'batch_size': 256, 'n_epoch': 1, 'features': 15}
#         Has trained 137 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 256, 'n_epoch': 5, 'features': 50}
#             Current best combo (with val score 0.4084):
#                     {'batch_size': 256, 'n_epoch': 1, 'features': 15}
#         Has trained 137 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 32, 'n_epoch': 9, 'features': 67}
#             Current best combo (with val score 0.4084):
#                     {'batch_size': 256, 'n_epoch': 1, 'features': 15}
#         Has trained 137 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 32, 'n_epoch': 5, 'features': 45}
#             Current best combo (with val score 0.4084):
#                     {'batch_size': 256, 'n_epoch': 1, 'features': 15}
#         Has trained 137 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.2609):
#             {'batch_size': 32, 'n_epoch': 5, 'features': 0}
#             Current best combo (with val score 0.4084):
#                     {'batch_size': 256, 'n_epoch': 1, 'features': 15}
#         Has trained 137 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 32, 'n_epoch': 5, 'features': 50}
#             Current best combo (with val score 0.4084):
#                     {'batch_size': 256, 'n_epoch': 1, 'features': 15}
#         Has trained 137 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.2914):
#             {'batch_size': 256, 'n_epoch': 5, 'features': 5}
#             Current best combo (with val score 0.4084):
#                     {'batch_size': 256, 'n_epoch': 1, 'features': 15}
#         Has trained 137 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.2933):
#             {'batch_size': 256, 'n_epoch': 1, 'features': 0}
#             Current best combo (with val score 0.4084):
#                     {'batch_size': 256, 'n_epoch': 1, 'features': 15}
#         Has trained 137 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 32, 'n_epoch': 5, 'features': 55}
#             Current best combo (with val score 0.4084):
#                     {'batch_size': 256, 'n_epoch': 1, 'features': 15}
#         Has trained 137 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 32, 'n_epoch': 9, 'features': 35}
#             Current best combo (with val score 0.4084):
#                     {'batch_size': 256, 'n_epoch': 1, 'features': 15}
#         Has trained 137 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 256, 'n_epoch': 1, 'features': 55}
#             Current best combo (with val score 0.4084):
#                     {'batch_size': 256, 'n_epoch': 1, 'features': 15}
#         Has trained 137 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 256, 'n_epoch': 5, 'features': 67}
#             Current best combo (with val score 0.4084):
#                     {'batch_size': 256, 'n_epoch': 1, 'features': 15}
#         Has trained 137 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.1156):
#             {'batch_size': 256, 'n_epoch': 5, 'features': 20}
#             Current best combo (with val score 0.4084):
#                     {'batch_size': 256, 'n_epoch': 1, 'features': 15}
#         Has trained 137 of 2592 combinations so far
# As new Best Combo (0, 4, 15) was read in, best_clf is set to None
# Already Trained and Tested combination (val score of 0.4639):
#             {'batch_size': 32, 'n_epoch': 5, 'features': 15}
#             Current best combo (with val score 0.4639):
#                     {'batch_size': 32, 'n_epoch': 5, 'features': 15}
#         Has trained 137 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 256, 'n_epoch': 9, 'features': 55}
#             Current best combo (with val score 0.4639):
#                     {'batch_size': 32, 'n_epoch': 5, 'features': 15}
#         Has trained 137 of 2592 combinations so far
# As new Best Combo (0, 8, 15) was read in, best_clf is set to None
# Already Trained and Tested combination (val score of 0.4772):
#             {'batch_size': 32, 'n_epoch': 9, 'features': 15}
#             Current best combo (with val score 0.4772):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 15}
#         Has trained 137 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 256, 'n_epoch': 9, 'features': 45}
#             Current best combo (with val score 0.4772):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 15}
#         Has trained 137 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.291):
#             {'batch_size': 256, 'n_epoch': 9, 'features': 5}
#             Current best combo (with val score 0.4772):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 15}
#         Has trained 137 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 32, 'n_epoch': 5, 'features': 63}
#             Current best combo (with val score 0.4772):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 15}
#         Has trained 137 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 32, 'n_epoch': 9, 'features': 45}
#             Current best combo (with val score 0.4772):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 15}
#         Has trained 137 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 256, 'n_epoch': 1, 'features': 35}
#             Current best combo (with val score 0.4772):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 15}
#         Has trained 137 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'batch_size': 32, 'n_epoch': 5, 'features': 30}
#             Current best combo (with val score 0.4772):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 15}
#         Has trained 137 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'batch_size': 256, 'n_epoch': 5, 'features': 30}
#             Current best combo (with val score 0.4772):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 15}
#         Has trained 137 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 256, 'n_epoch': 5, 'features': 35}
#             Current best combo (with val score 0.4772):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 15}
#         Has trained 137 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.291):
#             {'batch_size': 32, 'n_epoch': 9, 'features': 5}
#             Current best combo (with val score 0.4772):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 15}
#         Has trained 137 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.4336):
#             {'batch_size': 32, 'n_epoch': 5, 'features': 10}
#             Current best combo (with val score 0.4772):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 15}
#         Has trained 137 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.2914):
#             {'batch_size': 32, 'n_epoch': 5, 'features': 5}
#             Current best combo (with val score 0.4772):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 15}
#         Has trained 137 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.1038):
#             {'batch_size': 32, 'n_epoch': 5, 'features': 25}
#             Current best combo (with val score 0.4772):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 15}
#         Has trained 137 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 256, 'n_epoch': 5, 'features': 71}
#             Current best combo (with val score 0.4772):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 15}
#         Has trained 137 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 256, 'n_epoch': 1, 'features': 63}
#             Current best combo (with val score 0.4772):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 15}
#         Has trained 137 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 256, 'n_epoch': 5, 'features': 59}
#             Current best combo (with val score 0.4772):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 15}
#         Has trained 137 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'batch_size': 32, 'n_epoch': 1, 'features': 30}
#             Current best combo (with val score 0.4772):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 15}
#         Has trained 137 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 256, 'n_epoch': 9, 'features': 40}
#             Current best combo (with val score 0.4772):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 15}
#         Has trained 137 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.1129):
#             {'batch_size': 256, 'n_epoch': 5, 'features': 25}
#             Current best combo (with val score 0.4772):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 15}
#         Has trained 137 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.4539):
#             {'batch_size': 32, 'n_epoch': 9, 'features': 10}
#             Current best combo (with val score 0.4772):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 15}
#         Has trained 137 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 256, 'n_epoch': 9, 'features': 63}
#             Current best combo (with val score 0.4772):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 15}
#         Has trained 137 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 32, 'n_epoch': 1, 'features': 55}
#             Current best combo (with val score 0.4772):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 15}
#         Has trained 137 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.0033):
#             {'batch_size': 32, 'n_epoch': 9, 'features': 30}
#             Current best combo (with val score 0.4772):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 15}
#         Has trained 137 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 32, 'n_epoch': 9, 'features': 55}
#             Current best combo (with val score 0.4772):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 15}
#         Has trained 137 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 256, 'n_epoch': 9, 'features': 59}
#             Current best combo (with val score 0.4772):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 15}
#         Has trained 137 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 32, 'n_epoch': 5, 'features': 35}
#             Current best combo (with val score 0.4772):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 15}
#         Has trained 137 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.4769):
#             {'batch_size': 256, 'n_epoch': 9, 'features': 15}
#             Current best combo (with val score 0.4772):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 15}
#         Has trained 137 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.1416):
#             {'batch_size': 256, 'n_epoch': 9, 'features': 20}
#             Current best combo (with val score 0.4772):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 15}
#         Has trained 137 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 256, 'n_epoch': 5, 'features': 45}
#             Current best combo (with val score 0.4772):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 15}
#         Has trained 137 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 32, 'n_epoch': 9, 'features': 63}
#             Current best combo (with val score 0.4772):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 15}
#         Has trained 137 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 32, 'n_epoch': 1, 'features': 63}
#             Current best combo (with val score 0.4772):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 15}
#         Has trained 137 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.4354):
#             {'batch_size': 256, 'n_epoch': 5, 'features': 10}
#             Current best combo (with val score 0.4772):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 15}
#         Has trained 137 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3993):
#             {'batch_size': 256, 'n_epoch': 1, 'features': 10}
#             Current best combo (with val score 0.4772):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 15}
#         Has trained 137 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.2933):
#             {'batch_size': 32, 'n_epoch': 9, 'features': 0}
#             Current best combo (with val score 0.4772):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 15}
#         Has trained 137 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 32, 'n_epoch': 1, 'features': 45}
#             Current best combo (with val score 0.4772):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 15}
#         Has trained 137 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.2918):
#             {'batch_size': 32, 'n_epoch': 1, 'features': 5}
#             Current best combo (with val score 0.4772):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 15}
#         Has trained 137 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 256, 'n_epoch': 1, 'features': 50}
#             Current best combo (with val score 0.4772):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 15}
#         Has trained 137 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 256, 'n_epoch': 9, 'features': 35}
#             Current best combo (with val score 0.4772):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 15}
#         Has trained 137 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 32, 'n_epoch': 5, 'features': 67}
#             Current best combo (with val score 0.4772):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 15}
#         Has trained 137 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.1352):
#             {'batch_size': 32, 'n_epoch': 9, 'features': 25}
#             Current best combo (with val score 0.4772):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 15}
#         Has trained 137 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 256, 'n_epoch': 5, 'features': 55}
#             Current best combo (with val score 0.4772):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 15}
#         Has trained 137 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 32, 'n_epoch': 1, 'features': 71}
#             Current best combo (with val score 0.4772):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 15}
#         Has trained 137 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 256, 'n_epoch': 5, 'features': 63}
#             Current best combo (with val score 0.4772):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 15}
#         Has trained 137 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 32, 'n_epoch': 9, 'features': 40}
#             Current best combo (with val score 0.4772):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 15}
#         Has trained 137 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 256, 'n_epoch': 1, 'features': 71}
#             Current best combo (with val score 0.4772):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 15}
#         Has trained 137 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 256, 'n_epoch': 1, 'features': 67}
#             Current best combo (with val score 0.4772):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 15}
#         Has trained 137 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'batch_size': 256, 'n_epoch': 1, 'features': 30}
#             Current best combo (with val score 0.4772):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 15}
#         Has trained 137 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.2896):
#             {'batch_size': 256, 'n_epoch': 1, 'features': 5}
#             Current best combo (with val score 0.4772):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 15}
#         Has trained 137 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 256, 'n_epoch': 9, 'features': 67}
#             Current best combo (with val score 0.4772):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 15}
#         Has trained 137 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 32, 'n_epoch': 5, 'features': 59}
#             Current best combo (with val score 0.4772):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 15}
#         Has trained 137 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.0229):
#             {'batch_size': 32, 'n_epoch': 1, 'features': 25}
#             Current best combo (with val score 0.4772):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 15}
#         Has trained 137 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 32, 'n_epoch': 1, 'features': 59}
#             Current best combo (with val score 0.4772):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 15}
#         Has trained 137 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.2609):
#             {'batch_size': 32, 'n_epoch': 1, 'features': 0}
#             Current best combo (with val score 0.4772):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 15}
#         Has trained 137 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.1321):
#             {'batch_size': 256, 'n_epoch': 9, 'features': 25}
#             Current best combo (with val score 0.4772):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 15}
#         Has trained 137 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 256, 'n_epoch': 9, 'features': 71}
#             Current best combo (with val score 0.4772):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 15}
#         Has trained 137 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 256, 'n_epoch': 1, 'features': 40}
#             Current best combo (with val score 0.4772):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 15}
#         Has trained 137 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.4607):
#             {'batch_size': 256, 'n_epoch': 5, 'features': 15}
#             Current best combo (with val score 0.4772):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 15}
#         Has trained 137 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 32, 'n_epoch': 5, 'features': 40}
#             Current best combo (with val score 0.4772):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 15}
#         Has trained 137 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.0099):
#             {'batch_size': 256, 'n_epoch': 9, 'features': 30}
#             Current best combo (with val score 0.4772):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 15}
#         Has trained 137 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 32, 'n_epoch': 1, 'features': 35}
#             Current best combo (with val score 0.4772):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 15}
#         Has trained 137 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 256, 'n_epoch': 1, 'features': 59}
#             Current best combo (with val score 0.4772):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 15}
#         Has trained 137 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 32, 'n_epoch': 5, 'features': 71}
#             Current best combo (with val score 0.4772):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 15}
#         Has trained 137 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 256, 'n_epoch': 9, 'features': 50}
#             Current best combo (with val score 0.4772):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 15}
#         Has trained 137 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 32, 'n_epoch': 1, 'features': 67}
#             Current best combo (with val score 0.4772):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 15}
#         Has trained 137 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.2609):
#             {'batch_size': 256, 'n_epoch': 9, 'features': 0}
#             Current best combo (with val score 0.4772):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 15}
#         Has trained 137 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 256, 'n_epoch': 1, 'features': 45}
#             Current best combo (with val score 0.4772):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 15}
#         Has trained 137 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 32, 'n_epoch': 1, 'features': 50}
#             Current best combo (with val score 0.4772):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 15}
#         Has trained 137 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.4054):
#             {'batch_size': 32, 'n_epoch': 1, 'features': 15}
#             Current best combo (with val score 0.4772):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 15}
#         Has trained 137 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.4549):
#             {'batch_size': 256, 'n_epoch': 9, 'features': 10}
#             Current best combo (with val score 0.4772):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 15}
#         Has trained 137 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 256, 'n_epoch': 5, 'features': 40}
#             Current best combo (with val score 0.4772):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 15}
#         Has trained 137 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 32, 'n_epoch': 9, 'features': 50}
#             Current best combo (with val score 0.4772):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 15}
#         Has trained 137 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 128, 'n_epoch': 5, 'features': 36}
#             Current best combo (with val score 0.4772):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 15}
#         Has trained 137 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 32, 'n_epoch': 9, 'features': 71}
#             Current best combo (with val score 0.4772):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 15}
#         Has trained 137 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.2609):
#             {'batch_size': 256, 'n_epoch': 5, 'features': 0}
#             Current best combo (with val score 0.4772):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 15}
#         Has trained 137 of 2592 combinations so far
#
#
# STAGE ONE: Begin initial Guidance system
#
#
# Guidance: initial round
#
# 	round 0 iteration:  0
#
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 64, 'n_epoch': 5, 'features': 36}
#             Current best combo (with val score 0.4772):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 15}
#         Has trained 137 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 256, 'n_epoch': 5, 'features': 36}
#             Current best combo (with val score 0.4772):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 15}
#         Has trained 137 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 128, 'n_epoch': 4, 'features': 36}
#             Current best combo (with val score 0.4772):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 15}
#         Has trained 137 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 128, 'n_epoch': 6, 'features': 36}
#             Current best combo (with val score 0.4772):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 15}
#         Has trained 137 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 128, 'n_epoch': 5, 'features': 35}
#             Current best combo (with val score 0.4772):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 15}
#         Has trained 137 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 128, 'n_epoch': 5, 'features': 37}
#             Current best combo (with val score 0.4772):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 15}
#         Has trained 137 of 2592 combinations so far
# 	round 0 iteration:  1
#
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 32, 'n_epoch': 5, 'features': 36}
#             Current best combo (with val score 0.4772):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 15}
#         Has trained 137 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 128, 'n_epoch': 5, 'features': 36}
#             Current best combo (with val score 0.4772):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 15}
#         Has trained 137 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 64, 'n_epoch': 4, 'features': 36}
#             Current best combo (with val score 0.4772):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 15}
#         Has trained 137 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 64, 'n_epoch': 6, 'features': 36}
#             Current best combo (with val score 0.4772):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 15}
#         Has trained 137 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 64, 'n_epoch': 5, 'features': 35}
#             Current best combo (with val score 0.4772):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 15}
#         Has trained 137 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 64, 'n_epoch': 5, 'features': 37}
#             Current best combo (with val score 0.4772):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 15}
#         Has trained 137 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 128, 'n_epoch': 5, 'features': 36}
#             Current best combo (with val score 0.4772):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 15}
#         Has trained 137 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 256, 'n_epoch': 4, 'features': 36}
#             Current best combo (with val score 0.4772):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 15}
#         Has trained 137 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 256, 'n_epoch': 6, 'features': 36}
#             Current best combo (with val score 0.4772):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 15}
#         Has trained 137 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 256, 'n_epoch': 5, 'features': 35}
#             Current best combo (with val score 0.4772):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 15}
#         Has trained 137 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 256, 'n_epoch': 5, 'features': 37}
#             Current best combo (with val score 0.4772):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 15}
#         Has trained 137 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 64, 'n_epoch': 4, 'features': 36}
#             Current best combo (with val score 0.4772):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 15}
#         Has trained 137 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 256, 'n_epoch': 4, 'features': 36}
#             Current best combo (with val score 0.4772):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 15}
#         Has trained 137 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 128, 'n_epoch': 3, 'features': 36}
#             Current best combo (with val score 0.4772):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 15}
#         Has trained 137 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 128, 'n_epoch': 5, 'features': 36}
#             Current best combo (with val score 0.4772):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 15}
#         Has trained 137 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 128, 'n_epoch': 4, 'features': 35}
#             Current best combo (with val score 0.4772):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 15}
#         Has trained 137 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 128, 'n_epoch': 4, 'features': 37}
#             Current best combo (with val score 0.4772):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 15}
#         Has trained 137 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 64, 'n_epoch': 6, 'features': 36}
#             Current best combo (with val score 0.4772):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 15}
#         Has trained 137 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 256, 'n_epoch': 6, 'features': 36}
#             Current best combo (with val score 0.4772):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 15}
#         Has trained 137 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 128, 'n_epoch': 5, 'features': 36}
#             Current best combo (with val score 0.4772):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 15}
#         Has trained 137 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 128, 'n_epoch': 7, 'features': 36}
#             Current best combo (with val score 0.4772):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 15}
#         Has trained 137 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 128, 'n_epoch': 6, 'features': 35}
#             Current best combo (with val score 0.4772):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 15}
#         Has trained 137 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 128, 'n_epoch': 6, 'features': 37}
#             Current best combo (with val score 0.4772):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 15}
#         Has trained 137 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 64, 'n_epoch': 5, 'features': 35}
#             Current best combo (with val score 0.4772):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 15}
#         Has trained 137 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 256, 'n_epoch': 5, 'features': 35}
#             Current best combo (with val score 0.4772):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 15}
#         Has trained 137 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 128, 'n_epoch': 4, 'features': 35}
#             Current best combo (with val score 0.4772):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 15}
#         Has trained 137 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 128, 'n_epoch': 6, 'features': 35}
#             Current best combo (with val score 0.4772):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 15}
#         Has trained 137 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 128, 'n_epoch': 5, 'features': 34}
#             Current best combo (with val score 0.4772):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 15}
#         Has trained 137 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 128, 'n_epoch': 5, 'features': 36}
#             Current best combo (with val score 0.4772):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 15}
#         Has trained 137 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 64, 'n_epoch': 5, 'features': 37}
#             Current best combo (with val score 0.4772):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 15}
#         Has trained 137 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 256, 'n_epoch': 5, 'features': 37}
#             Current best combo (with val score 0.4772):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 15}
#         Has trained 137 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 128, 'n_epoch': 4, 'features': 37}
#             Current best combo (with val score 0.4772):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 15}
#         Has trained 137 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 128, 'n_epoch': 6, 'features': 37}
#             Current best combo (with val score 0.4772):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 15}
#         Has trained 137 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 128, 'n_epoch': 5, 'features': 36}
#             Current best combo (with val score 0.4772):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 15}
#         Has trained 137 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'batch_size': 128, 'n_epoch': 5, 'features': 38}
#             Current best combo (with val score 0.4772):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 15}
#         Has trained 137 of 2592 combinations so far
# As new Best Combo (1, 8, 15) was read in, best_clf is set to None
# Already Trained and Tested combination (val score of 0.4786):
#             {'batch_size': 64, 'n_epoch': 9, 'features': 15}
#             Current best combo (with val score 0.4786):
#                     {'batch_size': 64, 'n_epoch': 9, 'features': 15}
#         Has trained 137 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.4768):
#             {'batch_size': 32, 'n_epoch': 8, 'features': 15}
#             Current best combo (with val score 0.4786):
#                     {'batch_size': 64, 'n_epoch': 9, 'features': 15}
#         Has trained 137 of 2592 combinations so far
# As new Best Combo (0, 8, 14) was read in, best_clf is set to None
# Already Trained and Tested combination (val score of 0.4846):
#             {'batch_size': 32, 'n_epoch': 9, 'features': 14}
#             Current best combo (with val score 0.4846):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 14}
#         Has trained 137 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.4732):
#             {'batch_size': 32, 'n_epoch': 9, 'features': 16}
#             Current best combo (with val score 0.4846):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 14}
#         Has trained 137 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.4846):
#             {'batch_size': 64, 'n_epoch': 9, 'features': 14}
#             Current best combo (with val score 0.4846):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 14}
#         Has trained 137 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.4801):
#             {'batch_size': 32, 'n_epoch': 8, 'features': 14}
#             Current best combo (with val score 0.4846):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 14}
#         Has trained 137 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.4761):
#             {'batch_size': 32, 'n_epoch': 9, 'features': 13}
#             Current best combo (with val score 0.4846):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 14}
#         Has trained 137 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.4772):
#             {'batch_size': 32, 'n_epoch': 9, 'features': 15}
#             Current best combo (with val score 0.4846):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 14}
#         Has trained 137 of 2592 combinations so far
# % Combos Checked Thus Far: 137 out of 2592 which is 5.285494%
# STAGE TWO: Begin Cruise system
#
#
# Cruising Coordrdinate 1 of 96
#
# Cruising Coordrdinate 2 of 96
#
# Cruising Coordrdinate 3 of 96
#
# Cruising Coordrdinate 4 of 96
#
# Cruising Coordrdinate 5 of 96
#
# Cruising Coordrdinate 6 of 96
#
# Cruising Coordrdinate 7 of 96
#
# Cruising Coordrdinate 8 of 96
#
# Cruising Coordrdinate 9 of 96
#
# Cruising Coordrdinate 10 of 96
#
# Cruising Coordrdinate 11 of 96
#
# Cruising Coordrdinate 12 of 96
#
# Cruising Coordrdinate 13 of 96
#
# Cruising Coordrdinate 14 of 96
#
# Cruising Coordrdinate 15 of 96
#
# Cruising Coordrdinate 16 of 96
#
# Cruising Coordrdinate 17 of 96
#
# Cruising Coordrdinate 18 of 96
#
# Cruising Coordrdinate 19 of 96
#
# Cruising Coordrdinate 20 of 96
#
# Cruising Coordrdinate 21 of 96
#
# Cruising Coordrdinate 22 of 96
#
# Cruising Coordrdinate 23 of 96
#
# Cruising Coordrdinate 24 of 96
#
# Cruising Coordrdinate 25 of 96
#
# Cruising Coordrdinate 26 of 96
#
# Cruising Coordrdinate 27 of 96
#
# Cruising Coordrdinate 28 of 96
#
# Cruising Coordrdinate 29 of 96
#
# Cruising Coordrdinate 30 of 96
#
# Cruising Coordrdinate 31 of 96
#
# Cruising Coordrdinate 32 of 96
#
# Cruising Coordrdinate 33 of 96
#
# Cruising Coordrdinate 34 of 96
#
# Cruising Coordrdinate 35 of 96
#
# Cruising Coordrdinate 36 of 96
#
# Cruising Coordrdinate 37 of 96
#
# Cruising Coordrdinate 38 of 96
#
# Cruising Coordrdinate 39 of 96
#
# Cruising Coordrdinate 40 of 96
#
# Cruising Coordrdinate 41 of 96
#
# Cruising Coordrdinate 42 of 96
#
# Cruising Coordrdinate 43 of 96
#
# Cruising Coordrdinate 44 of 96
#
# Cruising Coordrdinate 45 of 96
#
# Cruising Coordrdinate 46 of 96
#
# Cruising Coordrdinate 47 of 96
#
# Cruising Coordrdinate 48 of 96
#
# Cruising Coordrdinate 49 of 96
#
# Cruising Coordrdinate 50 of 96
#
# Cruising Coordrdinate 51 of 96
#
# Cruising Coordrdinate 52 of 96
#
# Cruising Coordrdinate 53 of 96
#
# Cruising Coordrdinate 54 of 96
#
# Cruising Coordrdinate 55 of 96
#
# Cruising Coordrdinate 56 of 96
#
# Cruising Coordrdinate 57 of 96
#
# Cruising Coordrdinate 58 of 96
#
# Cruising Coordrdinate 59 of 96
#
# Cruising Coordrdinate 60 of 96
#
# Cruising Coordrdinate 61 of 96
#
# Cruising Coordrdinate 62 of 96
#
# Cruising Coordrdinate 63 of 96
#
# Cruising Coordrdinate 64 of 96
#
# Cruising Coordrdinate 65 of 96
#
# Cruising Coordrdinate 66 of 96
#
# Cruising Coordrdinate 67 of 96
#
# Cruising Coordrdinate 68 of 96
#
# Cruising Coordrdinate 69 of 96
#
# Cruising Coordrdinate 70 of 96
#
# Cruising Coordrdinate 71 of 96
#
# Cruising Coordrdinate 72 of 96
#
# Cruising Coordrdinate 73 of 96
#
# Cruising Coordrdinate 74 of 96
#
# Cruising Coordrdinate 75 of 96
#
# Cruising Coordrdinate 76 of 96
#
# Cruising Coordrdinate 77 of 96
#
# Cruising Coordrdinate 78 of 96
#
# Cruising Coordrdinate 79 of 96
#
# Cruising Coordrdinate 80 of 96
#
# Cruising Coordrdinate 81 of 96
#
# Cruising Coordrdinate 82 of 96
#
# Cruising Coordrdinate 83 of 96
#
# Cruising Coordrdinate 84 of 96
#
# Cruising Coordrdinate 85 of 96
#
# Cruising Coordrdinate 86 of 96
#
# Cruising Coordrdinate 87 of 96
#
# Cruising Coordrdinate 88 of 96
#
# Cruising Coordrdinate 89 of 96
#
# Cruising Coordrdinate 90 of 96
#
# Cruising Coordrdinate 91 of 96
#
# Cruising Coordrdinate 92 of 96
#
# Cruising Coordrdinate 93 of 96
#
# Cruising Coordrdinate 94 of 96
#
# Cruising Coordrdinate 95 of 96
#
# Cruising Coordrdinate 96 of 96
#
# FINAL STAGE: Begin final Guidance system
#
#
# Guidance: round FINAL
#
# 	round FINAL iteration:  0
#
# Already Trained and Tested combination (val score of 0.4846):
#             {'batch_size': 64, 'n_epoch': 9, 'features': 14}
#             Current best combo (with val score 0.4846):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 14}
#         Has trained 137 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.4801):
#             {'batch_size': 32, 'n_epoch': 8, 'features': 14}
#             Current best combo (with val score 0.4846):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 14}
#         Has trained 137 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.4761):
#             {'batch_size': 32, 'n_epoch': 9, 'features': 13}
#             Current best combo (with val score 0.4846):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 14}
#         Has trained 137 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.4772):
#             {'batch_size': 32, 'n_epoch': 9, 'features': 15}
#             Current best combo (with val score 0.4846):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 14}
#         Has trained 137 of 2592 combinations so far
# 	round FINAL iteration:  1
#
# Already Trained and Tested combination (val score of 0.4846):
#             {'batch_size': 32, 'n_epoch': 9, 'features': 14}
#             Current best combo (with val score 0.4846):
#                     {'batch_size': 32, 'n_epoch': 9, 'features': 14}
#         Has trained 137 of 2592 combinations so far
# As new Best Combo (2, 8, 14) was read in, best_clf is set to None
# Already Trained and Tested combination (val score of 0.4859):
#             {'batch_size': 128, 'n_epoch': 9, 'features': 14}
#             Current best combo (with val score 0.4859):
#                     {'batch_size': 128, 'n_epoch': 9, 'features': 14}
#         Has trained 137 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.4795):
#             {'batch_size': 64, 'n_epoch': 8, 'features': 14}
#             Current best combo (with val score 0.4859):
#                     {'batch_size': 128, 'n_epoch': 9, 'features': 14}
#         Has trained 137 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.4761):
#             {'batch_size': 64, 'n_epoch': 9, 'features': 13}
#             Current best combo (with val score 0.4859):
#                     {'batch_size': 128, 'n_epoch': 9, 'features': 14}
#         Has trained 137 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.4786):
#             {'batch_size': 64, 'n_epoch': 9, 'features': 15}
#             Current best combo (with val score 0.4859):
#                     {'batch_size': 128, 'n_epoch': 9, 'features': 14}
#         Has trained 137 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.4795):
#             {'batch_size': 64, 'n_epoch': 8, 'features': 14}
#             Current best combo (with val score 0.4859):
#                     {'batch_size': 128, 'n_epoch': 9, 'features': 14}
#         Has trained 137 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.4722):
#             {'batch_size': 32, 'n_epoch': 7, 'features': 14}
#             Current best combo (with val score 0.4859):
#                     {'batch_size': 128, 'n_epoch': 9, 'features': 14}
#         Has trained 137 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.4846):
#             {'batch_size': 32, 'n_epoch': 9, 'features': 14}
#             Current best combo (with val score 0.4859):
#                     {'batch_size': 128, 'n_epoch': 9, 'features': 14}
#         Has trained 137 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.4743):
#             {'batch_size': 32, 'n_epoch': 8, 'features': 13}
#             Current best combo (with val score 0.4859):
#                     {'batch_size': 128, 'n_epoch': 9, 'features': 14}
#         Has trained 137 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.4768):
#             {'batch_size': 32, 'n_epoch': 8, 'features': 15}
#             Current best combo (with val score 0.4859):
#                     {'batch_size': 128, 'n_epoch': 9, 'features': 14}
#         Has trained 137 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.4846):
#             {'batch_size': 64, 'n_epoch': 9, 'features': 14}
#             Current best combo (with val score 0.4859):
#                     {'batch_size': 128, 'n_epoch': 9, 'features': 14}
#         Has trained 137 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.4855):
#             {'batch_size': 256, 'n_epoch': 9, 'features': 14}
#             Current best combo (with val score 0.4859):
#                     {'batch_size': 128, 'n_epoch': 9, 'features': 14}
#         Has trained 137 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.4764):
#             {'batch_size': 128, 'n_epoch': 8, 'features': 14}
#             Current best combo (with val score 0.4859):
#                     {'batch_size': 128, 'n_epoch': 9, 'features': 14}
#         Has trained 137 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.475):
#             {'batch_size': 128, 'n_epoch': 9, 'features': 13}
#             Current best combo (with val score 0.4859):
#                     {'batch_size': 128, 'n_epoch': 9, 'features': 14}
#         Has trained 137 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.4769):
#             {'batch_size': 128, 'n_epoch': 9, 'features': 15}
#             Current best combo (with val score 0.4859):
#                     {'batch_size': 128, 'n_epoch': 9, 'features': 14}
#         Has trained 137 of 2592 combinations so far
# % Combos Checked Thus Far: 137 out of 2592 which is 5.285494%
# Guidance: round FINAL
#
# 	round FINAL iteration:  0
#
# Already Trained and Tested combination (val score of 0.4846):
#             {'batch_size': 64, 'n_epoch': 9, 'features': 14}
#             Current best combo (with val score 0.4859):
#                     {'batch_size': 128, 'n_epoch': 9, 'features': 14}
#         Has trained 137 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.4855):
#             {'batch_size': 256, 'n_epoch': 9, 'features': 14}
#             Current best combo (with val score 0.4859):
#                     {'batch_size': 128, 'n_epoch': 9, 'features': 14}
#         Has trained 137 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.4764):
#             {'batch_size': 128, 'n_epoch': 8, 'features': 14}
#             Current best combo (with val score 0.4859):
#                     {'batch_size': 128, 'n_epoch': 9, 'features': 14}
#         Has trained 137 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.475):
#             {'batch_size': 128, 'n_epoch': 9, 'features': 13}
#             Current best combo (with val score 0.4859):
#                     {'batch_size': 128, 'n_epoch': 9, 'features': 14}
#         Has trained 137 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.4769):
#             {'batch_size': 128, 'n_epoch': 9, 'features': 15}
#             Current best combo (with val score 0.4859):
#                     {'batch_size': 128, 'n_epoch': 9, 'features': 14}
#         Has trained 137 of 2592 combinations so far
# 	round FINAL iteration:  1
#
# Already Trained and Tested combination (val score of 0.4859):
#             {'batch_size': 128, 'n_epoch': 9, 'features': 14}
#             Current best combo (with val score 0.4859):
#                     {'batch_size': 128, 'n_epoch': 9, 'features': 14}
#         Has trained 137 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.4764):
#             {'batch_size': 256, 'n_epoch': 8, 'features': 14}
#             Current best combo (with val score 0.4859):
#                     {'batch_size': 128, 'n_epoch': 9, 'features': 14}
#         Has trained 137 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.475):
#             {'batch_size': 256, 'n_epoch': 9, 'features': 13}
#             Current best combo (with val score 0.4859):
#                     {'batch_size': 128, 'n_epoch': 9, 'features': 14}
#         Has trained 137 of 2592 combinations so far
# Already Trained and Tested combination (val score of 0.4769):
#             {'batch_size': 256, 'n_epoch': 9, 'features': 15}
#             Current best combo (with val score 0.4859):
#                     {'batch_size': 128, 'n_epoch': 9, 'features': 14}
#         Has trained 137 of 2592 combinations so far
# % Combos Checked Thus Far: 137 out of 2592 which is 5.285494%
# Max Val Score:
#  0.485938
# Max Val Score Std:
#  0.033583
# Best Combo Train Score:
#  0.656438
# Best Combo Train Score Std:
#  0.004377
# Max Combo Index:
#  (2, 8, 14) out of [4, 9, 72] (note best combo is 0-indexed)
# Max Combo Hyperparamer Combination:
#  {'batch_size': 128, 'n_epoch': 9, 'features': 14}
# Max Combo Features:
#  ('procedure_228130', 'procedure_225792', 'procedure_228125', 'lods_score', 'ventilation_used', 'procedure_226236', 'hospital_stay_duration', 'procedure_225469', 'procedure_224270', 'procedure_225446', 'procedure_225802', 'procedure_227712', 'procedure_229580', 'procedure_225451', 'admission_type_DIRECT EMER.', 'admission_type_DIRECT OBSERVATION', 'admission_type_ELECTIVE', 'admission_type_EU OBSERVATION', 'admission_type_EW EMER.', 'admission_type_OBSERVATION ADMIT', 'admission_type_URGENT', 'admission_type_SURGICAL SAME DAY ADMISSION')
# % Combos Checked: 137 out of 2592 which is 5.285494%
