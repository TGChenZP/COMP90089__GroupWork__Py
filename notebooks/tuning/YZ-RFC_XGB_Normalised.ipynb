# %% [markdown]
# # Tuning Script

# %%
# Parameters subject to change in every script - involved in naming

MODEL = 'rfc'
PREPROCESSING = 'normalise'
TUNER = 'yangzhoub'
OPTIMISED_METRIC = 'f1'

# %% [markdown]
# ---

# %%
# detect whether this is a google environment

COLAB_ENVIRONMENT = False

try:
    from google.colab import drive
    drive.mount('/content/drive')
    COLAB_ENVIRONMENT = True
except:
    pass
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import sys
import os
import pickle

if COLAB_ENVIRONMENT:
    home_directory = './drive/MyDrive/LAB/COMP90089__GroupWork__Py/' # my home directory is stored in ./LAB of google drive
    if MODEL == 'ebr':
        # !pip install interpret==0.5.0
    elif MODEL == 'cbr':
        # !pip install catboost
    elif MODEL in ['tf', 'mlp']:
        # !pip install PyTorch2Sklearn
    # !pip install JXAutoML
else:
    home_directory = '../../'

from JXAutoML.YangZhouB_10CV import YangZhouB_10CV as Tuner

import pandas as pd
# Out:
# Requirement already satisfied: JXAutoML in /usr/local/lib/python3.10/dist-packages (0.4.4)

# %%
# Parameters that are same for every script

FOLDS = 10  # we have decided to do 10 fold validation

SEED = 42

TASK_TYPE = 'Classification'  # this task is a classification task

# we have decided to tune features as hp
TUNE_FEATURES_AS_HYPERPARAMETERS = True

# %% [markdown]
# ---

# %%
# model to use to tune
from sklearn.ensemble import RandomForestClassifier as clf

# what values to try for each hyperparameter
parameter_choices = {
    'n_estimators': (25, 50, 100, 200, 400, 800),
    'max_depth': (3, 6, 12, 24, 48, 96, 192),
    'max_samples': (0.4, 0.55, 0.7, 0.85, 1),
    'max_features': (0.4, 0.55, 0.7, 0.85, 1),
    'ccp_alpha': (0.00000001, 0.000001, 0.0001, 0.01, 0.1)
}

# what values to set non-tuneable parameters/hyperparameters
non_tunable_hyperparameters_dict = {
    'random_state': SEED,
    'n_jobs': -1
}

# %% [markdown]
# ---

# %% [markdown]
# Read in and Prepare Data

# %%
# Import data and store as lists

train_x_list = []
train_y_list = []
val_x_list = []
val_y_list = []

for i in range(FOLDS):
    train_data = pd.read_csv(
        f'{home_directory}data/curated/modelling/{PREPROCESSING}/train_{i}.csv')
    val_data = pd.read_csv(
        f'{home_directory}data/curated/modelling/{PREPROCESSING}/val_{i}.csv')

    # get the correct rows for X and y
    train_x = train_data.drop(
        ['mortality_status', 'subject_id', 'hadm_id', 'stay_id'], axis=1)
    train_y = train_data['mortality_status']
    val_x = val_data.drop(
        ['mortality_status', 'subject_id', 'hadm_id', 'stay_id'], axis=1)
    val_y = val_data['mortality_status']

    train_x_list.append(train_x)
    train_y_list.append(train_y)
    val_x_list.append(val_x)
    val_y_list.append(val_y)

# %%
# Import feature importance ordering

with open(f'{home_directory}models/xgb_feature_importance_ordering_{PREPROCESSING}.pickle', 'rb') as f:
    feature_importance_ordering = pickle.load(f)

# %% [markdown]
# Set parameters

# %%
# initialisation
tuner = Tuner()

print('---')

# define what model we are tuning
tuner.read_in_model(clf, TASK_TYPE, optimised_metric=OPTIMISED_METRIC)

print('---')

# read in the data for training and validation
tuner.read_in_data(train_x_list, train_y_list, val_x_list, val_y_list)

print('---')

# set what hp values to tune
tuner.set_hyperparameters(parameter_choices)
# WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

# set up hp values that need to be changed from default but NOT to be tuned
tuner.set_non_tuneable_hyperparameters(non_tunable_hyperparameters_dict)

print('---')

# set up feature importance ordering

if TUNE_FEATURES_AS_HYPERPARAMETERS:
    tuner.set_features(feature_importance_ordering)
    # WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

try:  # try to read in previous results to continue tuning ...
    tuner.read_in_tuning_result_df(
        f'{home_directory}models/tuning/{TUNER}_{MODEL}_{PREPROCESSING}.csv')
except:
    print('No previous tuning data read in')

print('---')

# set up where to save the tuning result csv
tuner.set_tuning_result_saving_address(
    f'{home_directory}models/tuning/{TUNER}_{MODEL}_{PREPROCESSING}.csv')

print('---')

# set up where to save the current best model
tuner.set_best_model_saving_address(
    f'{home_directory}models/tmp_models/{TUNER}_{MODEL}_{PREPROCESSING}')
# Out:
# YangZhouB Initialised
# ---
# Successfully read in model <class 'sklearn.ensemble._forest.RandomForestClassifier'>, which is a Classification model optimising for f1
# ---
# Read in Train X data list
# Read in Train y data list
# Read in Val X data list
# Read in Val y data list
# ---
# Successfully recorded hyperparameter choices
# ---
# Successfully recorded non_tuneable_hyperparameter choices
# ---
# Successfully recorded tuneable feature combination choices and updated relevant internal structures
# ---
# No previous tuning data read in
# ---
# Successfully set tuning output address
# ---
# Successfully set best model output address

# %%
# ignore warnings

import warnings
warnings.filterwarnings("ignore")

# %%
# begin tuning ... (or continue training)

tuner.tune()
# Out:
# BEGIN TUNING
#
#
# STAGE ZERO: Tune all Cruise combinations
#
#
# Trained and Tested combination 1 of 267750, taking 2.25 seconds to get val score of 0.4464:
#                 {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 5},
#             Current best combo with val score 0.4464:
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 5}
# Trained and Tested combination 2 of 267750, taking 2.92 seconds to get val score of 0.0384:
#                 {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 45},
#             Current best combo with val score 0.4464:
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 5}
# Trained and Tested combination 3 of 267750, taking 2.3 seconds to get val score of 0.214:
#                 {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 20},
#             Current best combo with val score 0.4464:
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 5}
# Trained and Tested combination 4 of 267750, taking 2.23 seconds to get val score of 0.0:
#                 {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 0.1, 'features': 0},
#             Current best combo with val score 0.4464:
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 5}
# Trained and Tested combination 5 of 267750, taking 0.1 seconds to get val score of 0.1154:
#                 {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 35},
#             Current best combo with val score 0.4464:
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 5}
# Trained and Tested combination 6 of 267750, taking 0.06 seconds to get val score of 0.0:
#                 {'n_estimators': 25, 'max_depth': 3, 'max_samples': 1, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 15},
#             Current best combo with val score 0.4464:
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 5}
# Trained and Tested combination 7 of 267750, taking 4.39 seconds to get val score of 0.0:
#                 {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 0.1, 'features': 20},
#             Current best combo with val score 0.4464:
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 5}
# Trained and Tested combination 8 of 267750, taking 1.72 seconds to get val score of 0.0:
#                 {'n_estimators': 800, 'max_depth': 3, 'max_samples': 1, 'max_features': 0.4, 'ccp_alpha': 0.1, 'features': 5},
#             Current best combo with val score 0.4464:
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 5}
# Trained and Tested combination 9 of 267750, taking 1.73 seconds to get val score of 0.0:
#                 {'n_estimators': 800, 'max_depth': 24, 'max_samples': 1, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 45},
#             Current best combo with val score 0.4464:
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 5}
# Trained and Tested combination 10 of 267750, taking 0.07 seconds to get val score of 0.2713:
#                 {'n_estimators': 25, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 40},
#             Current best combo with val score 0.4464:
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 5}
# Trained and Tested combination 11 of 267750, taking 2.03 seconds to get val score of 0.0:
#                 {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 0.1, 'features': 15},
#             Current best combo with val score 0.4464:
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 5}
# Trained and Tested combination 12 of 267750, taking 2.51 seconds to get val score of 0.0:
#                 {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 0.1, 'features': 50},
#             Current best combo with val score 0.4464:
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 5}
# Trained and Tested combination 13 of 267750, taking 2.18 seconds to get val score of 0.0:
#                 {'n_estimators': 800, 'max_depth': 192, 'max_samples': 1, 'max_features': 1, 'ccp_alpha': 0.1, 'features': 40},
#             Current best combo with val score 0.4464:
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 5}
# Trained and Tested combination 14 of 267750, taking 0.08 seconds to get val score of 0.4601:
#                 {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 10},
#             Current best combo with val score 0.4601:
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 10}
# Trained and Tested combination 15 of 267750, taking 1.69 seconds to get val score of 0.0:
#                 {'n_estimators': 800, 'max_depth': 24, 'max_samples': 1, 'max_features': 1, 'ccp_alpha': 0.1, 'features': 40},
#             Current best combo with val score 0.4601:
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 10}
# Trained and Tested combination 16 of 267750, taking 5.41 seconds to get val score of 0.0:
#                 {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 0.1, 'features': 30},
#             Current best combo with val score 0.4601:
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 10}
# Trained and Tested combination 17 of 267750, taking 3.28 seconds to get val score of 0.0261:
#                 {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 40},
#             Current best combo with val score 0.4601:
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 10}
# Trained and Tested combination 18 of 267750, taking 1.71 seconds to get val score of 0.0:
#                 {'n_estimators': 800, 'max_depth': 24, 'max_samples': 1, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20},
#             Current best combo with val score 0.4601:
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 10}
# Trained and Tested combination 19 of 267750, taking 2.37 seconds to get val score of 0.0:
#                 {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 0.1, 'features': 40},
#             Current best combo with val score 0.4601:
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 10}
# Trained and Tested combination 20 of 267750, taking 1.7 seconds to get val score of 0.0:
#                 {'n_estimators': 800, 'max_depth': 24, 'max_samples': 1, 'max_features': 0.4, 'ccp_alpha': 0.1, 'features': 50},
#             Current best combo with val score 0.4601:
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 10}
# Trained and Tested combination 21 of 267750, taking 0.11 seconds to get val score of 0.0:
#                 {'n_estimators': 25, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 0.1, 'features': 5},
#             Current best combo with val score 0.4601:
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 10}
# Trained and Tested combination 22 of 267750, taking 2.24 seconds to get val score of 0.0:
#                 {'n_estimators': 800, 'max_depth': 3, 'max_samples': 1, 'max_features': 0.4, 'ccp_alpha': 0.1, 'features': 35},
#             Current best combo with val score 0.4601:
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 10}
# Trained and Tested combination 23 of 267750, taking 1.77 seconds to get val score of 0.0:
#                 {'n_estimators': 800, 'max_depth': 3, 'max_samples': 1, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 0},
#             Current best combo with val score 0.4601:
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 10}
# Trained and Tested combination 24 of 267750, taking 0.1 seconds to get val score of 0.0:
#                 {'n_estimators': 25, 'max_depth': 192, 'max_samples': 1, 'max_features': 1, 'ccp_alpha': 0.1, 'features': 40},
#             Current best combo with val score 0.4601:
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 10}
# Trained and Tested combination 25 of 267750, taking 0.23 seconds to get val score of 0.2649:
#                 {'n_estimators': 25, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 25},
#             Current best combo with val score 0.4601:
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 10}
# Trained and Tested combination 26 of 267750, taking 0.07 seconds to get val score of 0.0:
#                 {'n_estimators': 25, 'max_depth': 192, 'max_samples': 1, 'max_features': 0.4, 'ccp_alpha': 0.1, 'features': 0},
#             Current best combo with val score 0.4601:
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 10}
# Trained and Tested combination 27 of 267750, taking 0.06 seconds to get val score of 0.0:
#                 {'n_estimators': 25, 'max_depth': 3, 'max_samples': 1, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 5},
#             Current best combo with val score 0.4601:
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 10}
# Trained and Tested combination 28 of 267750, taking 0.08 seconds to get val score of 0.0:
#                 {'n_estimators': 25, 'max_depth': 192, 'max_samples': 1, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 15},
#             Current best combo with val score 0.4601:
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 10}
# Trained and Tested combination 29 of 267750, taking 3.01 seconds to get val score of 0.0:
#                 {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 0.1, 'features': 10},
#             Current best combo with val score 0.4601:
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 10}
# Trained and Tested combination 30 of 267750, taking 1.66 seconds to get val score of 0.0:
#                 {'n_estimators': 800, 'max_depth': 192, 'max_samples': 1, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 25},
#             Current best combo with val score 0.4601:
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 10}
# Trained and Tested combination 31 of 267750, taking 2.19 seconds to get val score of 0.0:
#                 {'n_estimators': 800, 'max_depth': 3, 'max_samples': 1, 'max_features': 0.4, 'ccp_alpha': 0.1, 'features': 20},
#             Current best combo with val score 0.4601:
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 10}
# Trained and Tested combination 32 of 267750, taking 1.75 seconds to get val score of 0.0:
#                 {'n_estimators': 800, 'max_depth': 24, 'max_samples': 1, 'max_features': 1, 'ccp_alpha': 0.1, 'features': 45},
#             Current best combo with val score 0.4601:
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 10}
# Trained and Tested combination 33 of 267750, taking 2.2 seconds to get val score of 0.0:
#                 {'n_estimators': 800, 'max_depth': 24, 'max_samples': 1, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 0},
#             Current best combo with val score 0.4601:
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 10}
# Trained and Tested combination 34 of 267750, taking 1.77 seconds to get val score of 0.0:
#                 {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 0.1, 'features': 0},
#             Current best combo with val score 0.4601:
#                     {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 10}
# Trained and Tested combination 35 of 267750, taking 3.44 seconds to get val score of 0.4935:
#                 {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20},
#             Current best combo with val score 0.4935:
#                     {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
# Trained and Tested combination 36 of 267750, taking 1.82 seconds to get val score of 0.0:
#                 {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30},
#             Current best combo with val score 0.4935:
#                     {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
# Trained and Tested combination 37 of 267750, taking 0.07 seconds to get val score of 0.0:
#                 {'n_estimators': 25, 'max_depth': 3, 'max_samples': 1, 'max_features': 1, 'ccp_alpha': 0.1, 'features': 35},
#             Current best combo with val score 0.4935:
#                     {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
# Trained and Tested combination 38 of 267750, taking 0.08 seconds to get val score of 0.0:
#                 {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 0.1, 'features': 45},
#             Current best combo with val score 0.4935:
#                     {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
# Trained and Tested combination 39 of 267750, taking 0.08 seconds to get val score of 0.0:
#                 {'n_estimators': 25, 'max_depth': 3, 'max_samples': 1, 'max_features': 1, 'ccp_alpha': 0.1, 'features': 45},
#             Current best combo with val score 0.4935:
#                     {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
# Trained and Tested combination 40 of 267750, taking 0.08 seconds to get val score of 0.0:
#                 {'n_estimators': 25, 'max_depth': 3, 'max_samples': 1, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 30},
#             Current best combo with val score 0.4935:
#                     {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
# Trained and Tested combination 41 of 267750, taking 0.07 seconds to get val score of 0.0:
#                 {'n_estimators': 25, 'max_depth': 3, 'max_samples': 1, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 20},
#             Current best combo with val score 0.4935:
#                     {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
# Trained and Tested combination 42 of 267750, taking 1.7 seconds to get val score of 0.0:
#                 {'n_estimators': 800, 'max_depth': 192, 'max_samples': 1, 'max_features': 1, 'ccp_alpha': 0.1, 'features': 25},
#             Current best combo with val score 0.4935:
#                     {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
# Trained and Tested combination 43 of 267750, taking 1.71 seconds to get val score of 0.0:
#                 {'n_estimators': 800, 'max_depth': 192, 'max_samples': 1, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 30},
#             Current best combo with val score 0.4935:
#                     {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
# Trained and Tested combination 44 of 267750, taking 0.08 seconds to get val score of 0.4038:
#                 {'n_estimators': 25, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 10},
#             Current best combo with val score 0.4935:
#                     {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
# Trained and Tested combination 45 of 267750, taking 2.23 seconds to get val score of 0.0:
#                 {'n_estimators': 800, 'max_depth': 192, 'max_samples': 1, 'max_features': 1, 'ccp_alpha': 0.1, 'features': 50},
#             Current best combo with val score 0.4935:
#                     {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
# Trained and Tested combination 46 of 267750, taking 0.13 seconds to get val score of 0.0:
#                 {'n_estimators': 25, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 0.1, 'features': 20},
#             Current best combo with val score 0.4935:
#                     {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
# Trained and Tested combination 47 of 267750, taking 0.1 seconds to get val score of 0.2223:
#                 {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 50},
#             Current best combo with val score 0.4935:
#                     {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
# Trained and Tested combination 48 of 267750, taking 0.07 seconds to get val score of 0.0:
#                 {'n_estimators': 25, 'max_depth': 24, 'max_samples': 1, 'max_features': 0.4, 'ccp_alpha': 0.1, 'features': 45},
#             Current best combo with val score 0.4935:
#                     {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
# Trained and Tested combination 49 of 267750, taking 2.17 seconds to get val score of 0.0:
#                 {'n_estimators': 800, 'max_depth': 3, 'max_samples': 1, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 45},
#             Current best combo with val score 0.4935:
#                     {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
# Trained and Tested combination 50 of 267750, taking 1.74 seconds to get val score of 0.0:
#                 {'n_estimators': 800, 'max_depth': 192, 'max_samples': 1, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 0},
#             Current best combo with val score 0.4935:
#                     {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
# Trained and Tested combination 51 of 267750, taking 0.08 seconds to get val score of 0.3167:
#                 {'n_estimators': 25, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 20},
#             Current best combo with val score 0.4935:
#                     {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
# Trained and Tested combination 52 of 267750, taking 1.73 seconds to get val score of 0.0:
#                 {'n_estimators': 800, 'max_depth': 3, 'max_samples': 1, 'max_features': 1, 'ccp_alpha': 0.1, 'features': 0},
#             Current best combo with val score 0.4935:
#                     {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
# Trained and Tested combination 53 of 267750, taking 2.34 seconds to get val score of 0.0:
#                 {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 0.1, 'features': 35},
#             Current best combo with val score 0.4935:
#                     {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
# Trained and Tested combination 54 of 267750, taking 2.49 seconds to get val score of 0.4409:
#                 {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 5},
#             Current best combo with val score 0.4935:
#                     {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
# Trained and Tested combination 55 of 267750, taking 3.98 seconds to get val score of 0.3944:
#                 {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 10},
#             Current best combo with val score 0.4935:
#                     {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
# Trained and Tested combination 56 of 267750, taking 1.8 seconds to get val score of 0.0:
#                 {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 0.1, 'features': 35},
#             Current best combo with val score 0.4935:
#                     {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
# Trained and Tested combination 57 of 267750, taking 1.97 seconds to get val score of 0.4494:
#                 {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 10},
#             Current best combo with val score 0.4935:
#                     {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
# Trained and Tested combination 58 of 267750, taking 0.07 seconds to get val score of 0.0:
#                 {'n_estimators': 25, 'max_depth': 3, 'max_samples': 1, 'max_features': 0.4, 'ccp_alpha': 0.1, 'features': 25},
#             Current best combo with val score 0.4935:
#                     {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
# Trained and Tested combination 59 of 267750, taking 1.75 seconds to get val score of 0.0:
#                 {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 0.1, 'features': 20},
#             Current best combo with val score 0.4935:
#                     {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
# Trained and Tested combination 60 of 267750, taking 1.98 seconds to get val score of 0.0:
#                 {'n_estimators': 800, 'max_depth': 3, 'max_samples': 1, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 25},
#             Current best combo with val score 0.4935:
#                     {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
# Trained and Tested combination 61 of 267750, taking 1.72 seconds to get val score of 0.0:
#                 {'n_estimators': 800, 'max_depth': 24, 'max_samples': 1, 'max_features': 0.4, 'ccp_alpha': 0.1, 'features': 30},
#             Current best combo with val score 0.4935:
#                     {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
# Trained and Tested combination 62 of 267750, taking 2.18 seconds to get val score of 0.0:
#                 {'n_estimators': 800, 'max_depth': 3, 'max_samples': 1, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 15},
#             Current best combo with val score 0.4935:
#                     {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
# Trained and Tested combination 63 of 267750, taking 0.07 seconds to get val score of 0.0:
#                 {'n_estimators': 25, 'max_depth': 192, 'max_samples': 1, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20},
#             Current best combo with val score 0.4935:
#                     {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
# Trained and Tested combination 64 of 267750, taking 1.73 seconds to get val score of 0.0:
#                 {'n_estimators': 800, 'max_depth': 3, 'max_samples': 1, 'max_features': 1, 'ccp_alpha': 0.1, 'features': 25},
#             Current best combo with val score 0.4935:
#                     {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
# Trained and Tested combination 65 of 267750, taking 0.07 seconds to get val score of 0.0:
#                 {'n_estimators': 25, 'max_depth': 24, 'max_samples': 1, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 45},
#             Current best combo with val score 0.4935:
#                     {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
# Trained and Tested combination 66 of 267750, taking 0.09 seconds to get val score of 0.0:
#                 {'n_estimators': 25, 'max_depth': 24, 'max_samples': 1, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 20},
#             Current best combo with val score 0.4935:
#                     {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
# Trained and Tested combination
'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-06, 'features': 20},
#             Current best combo with val score 0.507:
#                     {'n_estimators': 800, 'max_depth': 6, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
# Already Trained and Tested combination (val score of 0.4904):
#             {'n_estimators': 800, 'max_depth': 12, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-06, 'features': 20}
#             Current best combo (with val score 0.507):
#                     {'n_estimators': 800, 'max_depth': 6, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 740 of 267750 combinations so far
# Trained and Tested combination 741 of 267750, taking 2.96 seconds to get val score of 0.4881:
#                 {'n_estimators': 800, 'max_depth': 6, 'max_samples': 0.55, 'max_features': 0.4, 'ccp_alpha': 1e-06, 'features': 20},
#             Current best combo with val score 0.507:
#                     {'n_estimators': 800, 'max_depth': 6, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
# Trained and Tested combination 742 of 267750, taking 3.03 seconds to get val score of 0.4774:
#                 {'n_estimators': 800, 'max_depth': 6, 'max_samples': 0.4, 'max_features': 0.55, 'ccp_alpha': 1e-06, 'features': 20},
#             Current best combo with val score 0.507:
#                     {'n_estimators': 800, 'max_depth': 6, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
# Already Trained and Tested combination (val score of 0.507):
#             {'n_estimators': 800, 'max_depth': 6, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#             Current best combo (with val score 0.507):
#                     {'n_estimators': 800, 'max_depth': 6, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 742 of 267750 combinations so far
# Trained and Tested combination 743 of 267750, taking 2.98 seconds to get val score of 0.5073:
#                 {'n_estimators': 800, 'max_depth': 6, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 0.0001, 'features': 20},
#             Current best combo with val score 0.5073:
#                     {'n_estimators': 800, 'max_depth': 6, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 0.0001, 'features': 20}
# Trained and Tested combination 744 of 267750, taking 2.7 seconds to get val score of 0.5016:
#                 {'n_estimators': 800, 'max_depth': 6, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-06, 'features': 19},
#             Current best combo with val score 0.5073:
#                     {'n_estimators': 800, 'max_depth': 6, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 0.0001, 'features': 20}
# Trained and Tested combination 745 of 267750, taking 4.31 seconds to get val score of 0.4931:
#                 {'n_estimators': 800, 'max_depth': 6, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-06, 'features': 21},
#             Current best combo with val score 0.5073:
#                     {'n_estimators': 800, 'max_depth': 6, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 0.0001, 'features': 20}
# Trained and Tested combination 746 of 267750, taking 1.33 seconds to get val score of 0.4874:
#                 {'n_estimators': 400, 'max_depth': 6, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 0.0001, 'features': 20},
#             Current best combo with val score 0.5073:
#                     {'n_estimators': 800, 'max_depth': 6, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 0.0001, 'features': 20}
# Trained and Tested combination 747 of 267750, taking 2.2 seconds to get val score of 0.28:
#                 {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 0.0001, 'features': 20},
#             Current best combo with val score 0.5073:
#                     {'n_estimators': 800, 'max_depth': 6, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 0.0001, 'features': 20}
# Trained and Tested combination 748 of 267750, taking 3.31 seconds to get val score of 0.4898:
#                 {'n_estimators': 800, 'max_depth': 12, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 0.0001, 'features': 20},
#             Current best combo with val score 0.5073:
#                     {'n_estimators': 800, 'max_depth': 6, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 0.0001, 'features': 20}
# Trained and Tested combination 749 of 267750, taking 2.96 seconds to get val score of 0.4888:
#                 {'n_estimators': 800, 'max_depth': 6, 'max_samples': 0.55, 'max_features': 0.4, 'ccp_alpha': 0.0001, 'features': 20},
#             Current best combo with val score 0.5073:
#                     {'n_estimators': 800, 'max_depth': 6, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 0.0001, 'features': 20}
# Trained and Tested combination 750 of 267750, taking 4.0 seconds to get val score of 0.4776:
#                 {'n_estimators': 800, 'max_depth': 6, 'max_samples': 0.4, 'max_features': 0.55, 'ccp_alpha': 0.0001, 'features': 20},
#             Current best combo with val score 0.5073:
#                     {'n_estimators': 800, 'max_depth': 6, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 0.0001, 'features': 20}
# Already Trained and Tested combination (val score of 0.507):
#             {'n_estimators': 800, 'max_depth': 6, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-06, 'features': 20}
#             Current best combo (with val score 0.5073):
#                     {'n_estimators': 800, 'max_depth': 6, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 0.0001, 'features': 20}
#         Has trained 750 of 267750 combinations so far
# Trained and Tested combination 751 of 267750, taking 2.74 seconds to get val score of 0.1978:
#                 {'n_estimators': 800, 'max_depth': 6, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 0.01, 'features': 20},
#             Current best combo with val score 0.5073:
#                     {'n_estimators': 800, 'max_depth': 6, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 0.0001, 'features': 20}
# Trained and Tested combination 752 of 267750, taking 3.07 seconds to get val score of 0.5019:
#                 {'n_estimators': 800, 'max_depth': 6, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 0.0001, 'features': 19},
#             Current best combo with val score 0.5073:
#                     {'n_estimators': 800, 'max_depth': 6, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 0.0001, 'features': 20}
# Trained and Tested combination 753 of 267750, taking 2.76 seconds to get val score of 0.4938:
#                 {'n_estimators': 800, 'max_depth': 6, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 0.0001, 'features': 21},
#             Current best combo with val score 0.5073:
#                     {'n_estimators': 800, 'max_depth': 6, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 0.0001, 'features': 20}
# % Combos Checked Thus Far: 753 out of 267750 which is 0.28123200000000004%
# Guidance: round FINAL
#
# 	round FINAL iteration:  0
#
# Already Trained and Tested combination (val score of 0.4874):
#             {'n_estimators': 400, 'max_depth': 6, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 0.0001, 'features': 20}
#             Current best combo (with val score 0.5073):
#                     {'n_estimators': 800, 'max_depth': 6, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 0.0001, 'features': 20}
#         Has trained 753 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.28):
#             {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 0.0001, 'features': 20}
#             Current best combo (with val score 0.5073):
#                     {'n_estimators': 800, 'max_depth': 6, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 0.0001, 'features': 20}
#         Has trained 753 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.4898):
#             {'n_estimators': 800, 'max_depth': 12, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 0.0001, 'features': 20}
#             Current best combo (with val score 0.5073):
#                     {'n_estimators': 800, 'max_depth': 6, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 0.0001, 'features': 20}
#         Has trained 753 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.4888):
#             {'n_estimators': 800, 'max_depth': 6, 'max_samples': 0.55, 'max_features': 0.4, 'ccp_alpha': 0.0001, 'features': 20}
#             Current best combo (with val score 0.5073):
#                     {'n_estimators': 800, 'max_depth': 6, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 0.0001, 'features': 20}
#         Has trained 753 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.4776):
#             {'n_estimators': 800, 'max_depth': 6, 'max_samples': 0.4, 'max_features': 0.55, 'ccp_alpha': 0.0001, 'features': 20}
#             Current best combo (with val score 0.5073):
#                     {'n_estimators': 800, 'max_depth': 6, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 0.0001, 'features': 20}
#         Has trained 753 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.507):
#             {'n_estimators': 800, 'max_depth': 6, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-06, 'features': 20}
#             Current best combo (with val score 0.5073):
#                     {'n_estimators': 800, 'max_depth': 6, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 0.0001, 'features': 20}
#         Has trained 753 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.1978):
#             {'n_estimators': 800, 'max_depth': 6, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 0.01, 'features': 20}
#             Current best combo (with val score 0.5073):
#                     {'n_estimators': 800, 'max_depth': 6, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 0.0001, 'features': 20}
#         Has trained 753 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.5019):
#             {'n_estimators': 800, 'max_depth': 6, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 0.0001, 'features': 19}
#             Current best combo (with val score 0.5073):
#                     {'n_estimators': 800, 'max_depth': 6, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 0.0001, 'features': 20}
#         Has trained 753 of 267750 combinations so far
# Already Trained and Tested combination (val score of 0.4938):
#             {'n_estimators': 800, 'max_depth': 6, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 0.0001, 'features': 21}
#             Current best combo (with val score 0.5073):
#                     {'n_estimators': 800, 'max_depth': 6, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 0.0001, 'features': 20}
#         Has trained 753 of 267750 combinations so far
# % Combos Checked Thus Far: 753 out of 267750 which is 0.28123200000000004%
# Max Val Score:
#  0.507298
# Max Val Score Std:
#  0.06299
# Best Combo Train Score:
#  0.59846
# Best Combo Train Score Std:
#  0.008998
# Max Combo Index:
#  (5, 1, 0, 0, 2, 20) out of [6, 7, 5, 5, 5, 51] (note best combo is 0-indexed)
# Max Combo Hyperparamer Combination:
#  {'n_estimators': 800, 'max_depth': 6, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 0.0001, 'features': 20}
# Max Combo Features:
#  ('procedure_225792', 'ventilation_used', 'lods_score', 'race_AMERICAN INDIAN/ALASKA NATIVE', 'race_ASIAN', 'race_ASIAN - ASIAN INDIAN', 'race_ASIAN - CHINESE', 'race_ASIAN - KOREAN', 'race_ASIAN - SOUTH EAST ASIAN', 'race_BLACK/AFRICAN', 'race_BLACK/AFRICAN AMERICAN', 'race_BLACK/CAPE VERDEAN', 'race_BLACK/CARIBBEAN ISLAND', 'race_HISPANIC/LATINO - CENTRAL AMERICAN', 'race_HISPANIC/LATINO - COLUMBIAN', 'race_HISPANIC/LATINO - CUBAN', 'race_HISPANIC/LATINO - DOMINICAN', 'race_HISPANIC/LATINO - GUATEMALAN', 'race_HISPANIC/LATINO - HONDURAN', 'race_HISPANIC/LATINO - MEXICAN', 'race_HISPANIC/LATINO - PUERTO RICAN', 'race_HISPANIC/LATINO - SALVADORAN', 'race_MULTIPLE RACE/ETHNICITY', 'race_NATIVE HAWAIIAN OR OTHER PACIFIC ISLANDER', 'race_OTHER', 'race_PATIENT DECLINED TO ANSWER', 'race_PORTUGUESE', 'race_SOUTH AMERICAN', 'race_UNABLE TO OBTAIN', 'race_UNKNOWN', 'race_WHITE', 'race_WHITE - BRAZILIAN', 'race_WHITE - EASTERN EUROPEAN', 'race_WHITE - OTHER EUROPEAN', 'race_WHITE - RUSSIAN', 'race_HISPANIC OR LATINO', 'marital_status_DIVORCED', 'marital_status_MARRIED', 'marital_status_SINGLE', 'marital_status_WIDOWED', 'marital_status_0', 'hospital_stay_duration', 'procedure_225464', 'procedure_225802', 'procedure_227712', 'admission_type_DIRECT EMER.', 'admission_type_DIRECT OBSERVATION', 'admission_type_ELECTIVE', 'admission_type_EU OBSERVATION', 'admission_type_EW EMER.', 'admission_type_OBSERVATION ADMIT', 'admission_type_URGENT', 'admission_type_SURGICAL SAME DAY ADMISSION', 'procedure_225446', 'oasis_score', 'procedure_225400', 'procedure_224263', 'procedure_224276', 'unique_drugs', 'procedure_224267', 'procedure_229351', 'insurance_Medicare', 'insurance_Other', 'insurance_Medicaid', 'icu_stay_duration', 'gender_M', 'gender_F')
# % Combos Checked: 753 out of 267750 which is 0.28123200000000004%
