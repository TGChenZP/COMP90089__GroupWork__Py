# %% [markdown]
# # Tuning Script

# %%
# Parameters subject to change in every script - involved in naming

MODEL = 'rfc'
PREPROCESSING = 'normalise'
TUNER = 'yangzhoub'
OPTIMISED_METRIC = 'f1'

# %% [markdown]
# ---

# %%
# detect whether this is a google environment

COLAB_ENVIRONMENT = False

try:
    from google.colab import drive
    drive.mount('/content/drive')
    COLAB_ENVIRONMENT = True
except:
    pass
# Out:
# Mounted at /content/drive

# %%
import sys
import os
import pickle

if COLAB_ENVIRONMENT:
    home_directory = './drive/MyDrive/LAB/COMP90089__GroupWork__Py/' # my home directory is stored in ./LAB of google drive
    if MODEL == 'ebr':
        # !pip install interpret==0.5.0
    elif MODEL == 'cbr':
        # !pip install catboost
    elif MODEL in ['tf', 'mlp']:
        # !pip install PyTorch2Sklearn
    # !pip install JXAutoML
else:
    home_directory = '../../'

from JXAutoML.YangZhouB_10CV import YangZhouB_10CV as Tuner

import pandas as pd
# Out:
# Collecting JXAutoML
#   Downloading JXAutoML-0.4.4-py3-none-any.whl.metadata (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.2/67.2 kB 1.8 MB/s eta 0:00:00
# Downloading JXAutoML-0.4.4-py3-none-any.whl (52 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.1/52.1 kB 3.6 MB/s eta 0:00:00
# Installing collected packages: JXAutoML
# Successfully installed JXAutoML-0.4.4

# %%
# Parameters that are same for every script

FOLDS = 10  # we have decided to do 10 fold validation

SEED = 42

TASK_TYPE = 'Classification'  # this task is a classification task

# we have decided to tune features as hp
TUNE_FEATURES_AS_HYPERPARAMETERS = True

# %% [markdown]
# ---

# %%
# model to use to tune
from sklearn.ensemble import RandomForestClassifier as clf

# what values to try for each hyperparameter
parameter_choices = {
    'n_estimators': (25, 50, 100, 200, 400, 800),
    'max_depth': (3, 6, 12, 24, 48, 96, 192),
    'max_samples': (0.4, 0.55, 0.7, 0.85, 1),
    'max_features': (0.4, 0.55, 0.7, 0.85, 1),
    'ccp_alpha': (0.00000001, 0.000001, 0.0001, 0.01, 0.1)
}

# what values to set non-tuneable parameters/hyperparameters
non_tunable_hyperparameters_dict = {
    'random_state': SEED,
    'n_jobs': -1
}

# %% [markdown]
# ---

# %% [markdown]
# Read in and Prepare Data

# %%
# Import data and store as lists

train_x_list = []
train_y_list = []
val_x_list = []
val_y_list = []

for i in range(FOLDS):
    train_data = pd.read_csv(
        f'{home_directory}data/curated/modelling/{PREPROCESSING}/train_{i}.csv')
    val_data = pd.read_csv(
        f'{home_directory}data/curated/modelling/{PREPROCESSING}/val_{i}.csv')

    # get the correct rows for X and y
    train_x = train_data.drop(
        ['mortality_status', 'subject_id', 'hadm_id', 'stay_id'], axis=1)
    train_y = train_data['mortality_status']
    val_x = val_data.drop(
        ['mortality_status', 'subject_id', 'hadm_id', 'stay_id'], axis=1)
    val_y = val_data['mortality_status']

    train_x_list.append(train_x)
    train_y_list.append(train_y)
    val_x_list.append(val_x)
    val_y_list.append(val_y)

# %%
# Import feature importance ordering

with open(f'{home_directory}models/xgb_feature_importance_ordering_{PREPROCESSING}.pickle', 'rb') as f:
    feature_importance_ordering = pickle.load(f)

# %% [markdown]
# Set parameters

# %%
# initialisation
tuner = Tuner()

print('---')

# define what model we are tuning
tuner.read_in_model(clf, TASK_TYPE, optimised_metric=OPTIMISED_METRIC)

print('---')

# read in the data for training and validation
tuner.read_in_data(train_x_list, train_y_list, val_x_list, val_y_list)

print('---')

# set what hp values to tune
tuner.set_hyperparameters(parameter_choices)
# WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

# set up hp values that need to be changed from default but NOT to be tuned
tuner.set_non_tuneable_hyperparameters(non_tunable_hyperparameters_dict)

print('---')

# set up feature importance ordering

if TUNE_FEATURES_AS_HYPERPARAMETERS:
    tuner.set_features(feature_importance_ordering)
    # WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

try:  # try to read in previous results to continue tuning ...
    tuner.read_in_tuning_result_df(
        f'{home_directory}models/tuning/{TUNER}_{MODEL}_{PREPROCESSING}.csv')
except:
    print('No previous tuning data read in')

print('---')

# set up where to save the tuning result csv
tuner.set_tuning_result_saving_address(
    f'{home_directory}models/tuning/{TUNER}_{MODEL}_{PREPROCESSING}.csv')

print('---')

# set up where to save the current best model
tuner.set_best_model_saving_address(
    f'{home_directory}models/tmp_models/{TUNER}_{MODEL}_{PREPROCESSING}')
# Out:
# YangZhouB Initialised
# ---
# Successfully read in model <class 'sklearn.ensemble._forest.RandomForestClassifier'>, which is a Classification model optimising for f1
# ---
# Read in Train X data list
# Read in Train y data list
# Read in Val X data list
# Read in Val y data list
# ---
# Successfully recorded hyperparameter choices
# ---
# Successfully recorded non_tuneable_hyperparameter choices
# ---
# Successfully recorded tuneable feature combination choices and updated relevant internal structures
# ---
# Successfully read in tuning result of 624 rows, for 624.0 combos
# ---
# Successfully set tuning output address
# ---
# Successfully set best model output address

# %%
# ignore warnings

import warnings
warnings.filterwarnings("ignore")

# %%
# begin tuning ... (or continue training)

tuner.tune()
# Out:
# BEGIN TUNING
#
#
# STAGE ZERO: Tune all Cruise combinations
#
#
# As new Best Combo (5, 0, 0, 0, 0, 5) was read in, best_clf is set to None
# Already Trained and Tested combination (val score of 0.4464):
#             {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 5}
#             Current best combo (with val score 0.4464):
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 5}
#         Has trained 624 of 252000 combinations so far
# Already Trained and Tested combination (val score of 0.0732):
#             {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 43}
#             Current best combo (with val score 0.4464):
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 5}
#         Has trained 624 of 252000 combinations so far
# Already Trained and Tested combination (val score of 0.3711):
#             {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 20}
#             Current best combo (with val score 0.4464):
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 5}
#         Has trained 624 of 252000 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 0.1, 'features': 0}
#             Current best combo (with val score 0.4464):
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 5}
#         Has trained 624 of 252000 combinations so far
# Already Trained and Tested combination (val score of 0.1949):
#             {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 35}
#             Current best combo (with val score 0.4464):
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 5}
#         Has trained 624 of 252000 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 25, 'max_depth': 3, 'max_samples': 1, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 15}
#             Current best combo (with val score 0.4464):
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 5}
#         Has trained 624 of 252000 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 0.1, 'features': 20}
#             Current best combo (with val score 0.4464):
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 5}
#         Has trained 624 of 252000 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 800, 'max_depth': 3, 'max_samples': 1, 'max_features': 0.4, 'ccp_alpha': 0.1, 'features': 5}
#             Current best combo (with val score 0.4464):
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 5}
#         Has trained 624 of 252000 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 800, 'max_depth': 24, 'max_samples': 1, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 43}
#             Current best combo (with val score 0.4464):
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 5}
#         Has trained 624 of 252000 combinations so far
# Already Trained and Tested combination (val score of 0.2482):
#             {'n_estimators': 25, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 39}
#             Current best combo (with val score 0.4464):
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 5}
#         Has trained 624 of 252000 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 0.1, 'features': 15}
#             Current best combo (with val score 0.4464):
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 5}
#         Has trained 624 of 252000 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 0.1, 'features': 47}
#             Current best combo (with val score 0.4464):
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 5}
#         Has trained 624 of 252000 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 800, 'max_depth': 192, 'max_samples': 1, 'max_features': 1, 'ccp_alpha': 0.1, 'features': 39}
#             Current best combo (with val score 0.4464):
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 5}
#         Has trained 624 of 252000 combinations so far
# Already Trained and Tested combination (val score of 0.3082):
#             {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 10}
#             Current best combo (with val score 0.4464):
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 5}
#         Has trained 624 of 252000 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 800, 'max_depth': 24, 'max_samples': 1, 'max_features': 1, 'ccp_alpha': 0.1, 'features': 39}
#             Current best combo (with val score 0.4464):
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 5}
#         Has trained 624 of 252000 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 0.1, 'features': 30}
#             Current best combo (with val score 0.4464):
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 5}
#         Has trained 624 of 252000 combinations so far
# Already Trained and Tested combination (val score of 0.1118):
#             {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 39}
#             Current best combo (with val score 0.4464):
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 5}
#         Has trained 624 of 252000 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 800, 'max_depth': 24, 'max_samples': 1, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#             Current best combo (with val score 0.4464):
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 5}
#         Has trained 624 of 252000 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 0.1, 'features': 39}
#             Current best combo (with val score 0.4464):
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 5}
#         Has trained 624 of 252000 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 800, 'max_depth': 24, 'max_samples': 1, 'max_features': 0.4, 'ccp_alpha': 0.1, 'features': 47}
#             Current best combo (with val score 0.4464):
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 5}
#         Has trained 624 of 252000 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 25, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 0.1, 'features': 5}
#             Current best combo (with val score 0.4464):
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 5}
#         Has trained 624 of 252000 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 800, 'max_depth': 3, 'max_samples': 1, 'max_features': 0.4, 'ccp_alpha': 0.1, 'features': 35}
#             Current best combo (with val score 0.4464):
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 5}
#         Has trained 624 of 252000 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 800, 'max_depth': 3, 'max_samples': 1, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 0}
#             Current best combo (with val score 0.4464):
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 5}
#         Has trained 624 of 252000 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 25, 'max_depth': 192, 'max_samples': 1, 'max_features': 1, 'ccp_alpha': 0.1, 'features': 39}
#             Current best combo (with val score 0.4464):
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 5}
#         Has trained 624 of 252000 combinations so far
# Already Trained and Tested combination (val score of 0.3042):
#             {'n_estimators': 25, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 25}
#             Current best combo (with val score 0.4464):
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 5}
#         Has trained 624 of 252000 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 25, 'max_depth': 192, 'max_samples': 1, 'max_features': 0.4, 'ccp_alpha': 0.1, 'features': 0}
#             Current best combo (with val score 0.4464):
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 5}
#         Has trained 624 of 252000 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 25, 'max_depth': 3, 'max_samples': 1, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 5}
#             Current best combo (with val score 0.4464):
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 5}
#         Has trained 624 of 252000 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 25, 'max_depth': 192, 'max_samples': 1, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 15}
#             Current best combo (with val score 0.4464):
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 5}
#         Has trained 624 of 252000 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 0.1, 'features': 10}
#             Current best combo (with val score 0.4464):
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 5}
#         Has trained 624 of 252000 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 800, 'max_depth': 192, 'max_samples': 1, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 25}
#             Current best combo (with val score 0.4464):
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 5}
#         Has trained 624 of 252000 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 800, 'max_depth': 3, 'max_samples': 1, 'max_features': 0.4, 'ccp_alpha': 0.1, 'features': 20}
#             Current best combo (with val score 0.4464):
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 5}
#         Has trained 624 of 252000 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 800, 'max_depth': 24, 'max_samples': 1, 'max_features': 1, 'ccp_alpha': 0.1, 'features': 43}
#             Current best combo (with val score 0.4464):
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 5}
#         Has trained 624 of 252000 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 800, 'max_depth': 24, 'max_samples': 1, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 0}
#             Current best combo (with val score 0.4464):
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 5}
#         Has trained 624 of 252000 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 0.1, 'features': 0}
#             Current best combo (with val score 0.4464):
#                     {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 5}
#         Has trained 624 of 252000 combinations so far
# As new Best Combo (5, 6, 0, 0, 0, 20) was read in, best_clf is set to None
# Already Trained and Tested combination (val score of 0.4932):
#             {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#             Current best combo (with val score 0.4932):
#                     {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 624 of 252000 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#             Current best combo (with val score 0.4932):
#                     {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 624 of 252000 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 25, 'max_depth': 3, 'max_samples': 1, 'max_features': 1, 'ccp_alpha': 0.1, 'features': 35}
#             Current best combo (with val score 0.4932):
#                     {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 624 of 252000 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 0.1, 'features': 43}
#             Current best combo (with val score 0.4932):
#                     {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 624 of 252000 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 25, 'max_depth': 3, 'max_samples': 1, 'max_features': 1, 'ccp_alpha': 0.1, 'features': 43}
#             Current best combo (with val score 0.4932):
#                     {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 624 of 252000 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 25, 'max_depth': 3, 'max_samples': 1, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 30}
#             Current best combo (with val score 0.4932):
#                     {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 624 of 252000 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 25, 'max_depth': 3, 'max_samples': 1, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 20}
#             Current best combo (with val score 0.4932):
#                     {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 624 of 252000 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 800, 'max_depth': 192, 'max_samples': 1, 'max_features': 1, 'ccp_alpha': 0.1, 'features': 25}
#             Current best combo (with val score 0.4932):
#                     {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 624 of 252000 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 800, 'max_depth': 192, 'max_samples': 1, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 30}
#             Current best combo (with val score 0.4932):
#                     {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 624 of 252000 combinations so far
# Already Trained and Tested combination (val score of 0.3342):
#             {'n_estimators': 25, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 10}
#             Current best combo (with val score 0.4932):
#                     {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 624 of 252000 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 800, 'max_depth': 192, 'max_samples': 1, 'max_features': 1, 'ccp_alpha': 0.1, 'features': 47}
#             Current best combo (with val score 0.4932):
#                     {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 624 of 252000 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 25, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 0.1, 'features': 20}
#             Current best combo (with val score 0.4932):
#                     {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 624 of 252000 combinations so far
# Already Trained and Tested combination (val score of 0.0947):
#             {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 47}
#             Current best combo (with val score 0.4932):
#                     {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 624 of 252000 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 25, 'max_depth': 24, 'max_samples': 1, 'max_features': 0.4, 'ccp_alpha': 0.1, 'features': 43}
#             Current best combo (with val score 0.4932):
#                     {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 624 of 252000 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 800, 'max_depth': 3, 'max_samples': 1, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 43}
#             Current best combo (with val score 0.4932):
#                     {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 624 of 252000 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 800, 'max_depth': 192, 'max_samples': 1, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 0}
#             Current best combo (with val score 0.4932):
#                     {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 624 of 252000 combinations so far
# Already Trained and Tested combination (val score of 0.3585):
#             {'n_estimators': 25, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 20}
#             Current best combo (with val score 0.4932):
#                     {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 624 of 252000 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 800, 'max_depth': 3, 'max_samples': 1, 'max_features': 1, 'ccp_alpha': 0.1, 'features': 0}
#             Current best combo (with val score 0.4932):
#                     {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 624 of 252000 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 0.1, 'features': 35}
#             Current best combo (with val score 0.4932):
#                     {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 624 of 252000 combinations so far
# Already Trained and Tested combination (val score of 0.3308):
#             {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 5}
#             Current best combo (with val score 0.4932):
#                     {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 624 of 252000 combinations so far
# Already Trained and Tested combination (val score of 0.4697):
#             {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 10}
#             Current best combo (with val score 0.4932):
#                     {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 624 of 252000 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 0.1, 'features': 35}
#             Current best combo (with val score 0.4932):
#                     {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 624 of 252000 combinations so far
# Already Trained and Tested combination (val score of 0.3655):
#             {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 10}
#             Current best combo (with val score 0.4932):
#                     {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 624 of 252000 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 25, 'max_depth': 3, 'max_samples': 1, 'max_features': 0.4, 'ccp_alpha': 0.1, 'features': 25}
#             Current best combo (with val score 0.4932):
#                     {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 624 of 252000 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 0.1, 'features': 20}
#             Current best combo (with val score 0.4932):
#                     {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 624 of 252000 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 800, 'max_depth': 3, 'max_samples': 1, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 25}
#             Current best combo (with val score 0.4932):
#                     {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 624 of 252000 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 800, 'max_depth': 24, 'max_samples': 1, 'max_features': 0.4, 'ccp_alpha': 0.1, 'features': 30}
#             Current best combo (with val score 0.4932):
#                     {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 624 of 252000 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 800, 'max_depth': 3, 'max_samples': 1, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 15}
#             Current best combo (with val score 0.4932):
#                     {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 624 of 252000 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 25, 'max_depth': 192, 'max_samples': 1, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#             Current best combo (with val score 0.4932):
#                     {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 624 of 252000 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 800, 'max_depth': 3, 'max_samples': 1, 'max_features': 1, 'ccp_alpha': 0.1, 'features': 25}
#             Current best combo (with val score 0.4932):
#                     {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 624 of 252000 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 25, 'max_depth': 24, 'max_samples': 1, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 43}
#             Current best combo (with val score 0.4932):
#                     {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 624 of 252000 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 25, 'max_depth': 24, 'max_samples': 1, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 20}
#             Current best combo (with val score 0.4932):
#                     {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 624 of 252000 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 800, 'max_depth': 192, 'max_samples': 1, 'max_features': 0.4, 'ccp_alpha': 0.1, 'features': 5}
#             Current best combo (with val score 0.4932):
#                     {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 624 of 252000 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 0.1, 'features': 30}
#             Current best combo (with val score 0.4932):
#                     {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 624 of 252000 combinations so far
# Already Trained and Tested combination (val score of 0.1792):
#             {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 43}
#             Current best combo (with val score 0.4932):
#                     {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 624 of 252000 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 800, 'max_depth': 192, 'max_samples': 1, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 15}
#             Current best combo (with val score 0.4932):
#                     {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 624 of 252000 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 800, 'max_depth': 3, 'max_samples': 1, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 35}
#             Current best combo (with val score 0.4932):
#                     {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 624 of 252000 combinations so far
# Already Trained and Tested combination (val score of 0.1042):
#             {'n_estimators': 25, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 25}
#             Current best combo (with val score 0.4932):
#                     {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 624 of 252000 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 25, 'max_depth': 24, 'max_samples': 1, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 0}
#             Current best combo (with val score 0.4932):
#                     {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 624 of 252000 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 25, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 0.1, 'features': 47}
#             Current best combo (with val score 0.4932):
#                     {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 624 of 252000 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 800, 'max_depth': 24, 'max_samples': 1, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 35}
#             Current best combo (with val score 0.4932):
#                     {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 624 of 252000 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 25, 'max_depth': 192, 'max_samples': 1, 'max_features': 1, 'ccp_alpha': 0.1, 'features': 15}
#             Current best combo (with val score 0.4932):
#                     {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 624 of 252000 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 25, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 0.1, 'features': 39}
#             Current best combo (with val score 0.4932):
#                     {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 624 of 252000 combinations so far
# Already Trained and Tested combination (val score of 0.3241):
#             {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 30}
#             Current best combo (with val score 0.4932):
#                     {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 624 of 252000 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 800, 'max_depth': 192, 'max_samples': 1, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 47}
#             Current best combo (with val score 0.4932):
#                     {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 624 of 252000 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 800, 'max_depth': 192, 'max_samples': 1, 'max_features': 0.4, 'ccp_alpha': 0.1, 'features': 30}
#             Current best combo (with val score 0.4932):
#                     {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 624 of 252000 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 25, 'max_depth': 192, 'max_samples': 1, 'max_features': 1, 'ccp_alpha': 0.1, 'features': 5}
#             Current best combo (with val score 0.4932):
#                     {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 624 of 252000 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 0.1, 'features': 35}
#             Current best combo (with val score 0.4932):
#                     {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 624 of 252000 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 0}
#             Current best combo (with val score 0.4932):
#                     {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 624 of 252000 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 800, 'max_depth': 24, 'max_samples': 1, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 39}
#             Current best combo (with val score 0.4932):
#                     {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 624 of 252000 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 800, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 0}
#             Current best combo (with val score 0.4932):
#                     {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 624 of 252000 combinations so far
# Already Trained and Tested combination (val score of 0.1859):
#             {'n_estimators': 25, 'max_depth': 3, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 30}
#             Current best combo (with val score 0.4932):
#                     {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 624 of 252000 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 25, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 0.1, 'features': 25}
#             Current best combo (with val score 0.4932):
#                     {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 624 of 252000 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 0.1, 'features': 5}
#             Current best combo (with val score 0.4932):
#                     {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 624 of 252000 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 25, 'max_depth': 3, 'max_samples': 1, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 39}
#             Current best combo (with val score 0.4932):
#                     {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 624 of 252000 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 800, 'max_depth': 24, 'max_samples': 1, 'max_features': 0.4, 'ccp_alpha': 0.1, 'features': 15}
#             Current best combo (with val score 0.4932):
#                     {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 624 of 252000 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 800, 'max_depth': 24, 'max_samples': 1, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 47}
#             Current best combo (with val score 0.4932):
#                     {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 624 of 252000 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 800, 'max_depth': 24, 'max_samples': 1, 'max_features': 1, 'ccp_alpha': 0.1, 'features': 47}
#             Current best combo (with val score 0.4932):
#                     {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 624 of 252000 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 25, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 0.1, 'features': 15}
#             Current best combo (with val score 0.4932):
#                     {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 624 of 252000 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 25, 'max_depth': 24, 'max_samples': 1, 'max_features': 1, 'ccp_alpha': 0.1, 'features': 35}
#             Current best combo (with val score 0.4932):
#                     {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 624 of 252000 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 25, 'max_depth': 3, 'max_samples': 1, 'max_features': 1, 'ccp_alpha': 0.1, 'features': 10}
#             Current best combo (with val score 0.4932):
#                     {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 624 of 252000 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 800, 'max_depth': 24, 'max_samples': 1, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 30}
#             Current best combo (with val score 0.4932):
#                     {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 624 of 252000 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 25, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 0.1, 'features': 35}
#             Current best combo (with val score 0.4932):
#                     {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 624 of 252000 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 0.1, 'features': 15}
#             Current best combo (with val score 0.4932):
#                     {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 624 of 252000 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 25, 'max_depth': 24, 'max_samples': 1, 'max_features': 1, 'ccp_alpha': 0.1, 'features': 43}
#             Current best combo (with val score 0.4932):
#                     {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 624 of 252000 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 0.1, 'features': 20}
#             Current best combo (with val score 0.4932):
#                     {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 624 of 252000 combinations so far
# Already Trained and Tested combination (val score of 0.1997):
#             {'n_estimators': 25, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 39}
#             Current best combo (with val score 0.4932):
#                     {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 624 of 252000 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 25, 'max_depth': 3, 'max_samples': 1, 'max_features': 0.4, 'ccp_alpha': 0.1, 'features': 0}
#             Current best combo (with val score 0.4932):
#                     {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 624 of 252000 combinations so far
# Already Trained and Tested combination (val score of 0.2683):
#             {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 15}
#             Current best combo (with val score 0.4932):
#                     {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 624 of 252000 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 25, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 0.1, 'features': 43}
#             Current best combo (with val score 0.4932):
#                     {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 624 of 252000 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 25, 'max_depth': 3, 'max_samples': 1, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 15}
#             Current best combo (with val score 0.4932):
#                     {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 624 of 252000 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 25, 'max_depth': 24, 'max_samples': 1, 'max_features': 0.4, 'ccp_alpha': 0.1, 'features': 30}
#             Current best combo (with val score 0.4932):
#                     {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 624 of 252000 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 1, 'ccp_alpha': 0.1, 'features': 10}
#             Current best combo (with val score 0.4932):
#                     {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 624 of 252000 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 25, 'max_depth': 192, 'max_samples': 1, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 25}
#             Current best combo (with val score 0.4932):
#                     {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 624 of 252000 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 25, 'max_depth': 3, 'max_samples': 1, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 25}
#             Current best combo (with val score 0.4932):
#                     {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 624 of 252000 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 800, 'max_depth': 192, 'max_samples': 1, 'max_features': 0.4, 'ccp_alpha': 0.1, 'features': 20}
#             Current best combo (with val score 0.4932):
#                     {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 624 of 252000 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 25, 'max_depth': 24, 'max_samples': 1, 'max_features': 1, 'ccp_alpha': 1e-08, 'features': 5}
#             Current best combo (with val score 0.4932):
#                     {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
# ...
#                 {'n_estimators': 400, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-06, 'features': 20},
#             Current best combo with val score 0.4932:
#                     {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
# Already Trained and Tested combination (val score of 0.493):
#             {'n_estimators': 800, 'max_depth': 12, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-06, 'features': 20}
#             Current best combo (with val score 0.4932):
#                     {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 639 of 252000 combinations so far
# Already Trained and Tested combination (val score of 0.4932):
#             {'n_estimators': 800, 'max_depth': 48, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-06, 'features': 20}
#             Current best combo (with val score 0.4932):
#                     {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 639 of 252000 combinations so far
# Trained and Tested combination 640 of 252000, taking 4.01 seconds to get val score of 0.4861:
#                 {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.55, 'max_features': 0.4, 'ccp_alpha': 1e-06, 'features': 20},
#             Current best combo with val score 0.4932:
#                     {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
# Trained and Tested combination 641 of 252000, taking 4.89 seconds to get val score of 0.4809:
#                 {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.55, 'ccp_alpha': 1e-06, 'features': 20},
#             Current best combo with val score 0.4932:
#                     {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
# Already Trained and Tested combination (val score of 0.4923):
#             {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#             Current best combo (with val score 0.4932):
#                     {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 641 of 252000 combinations so far
# Trained and Tested combination 642 of 252000, taking 2.73 seconds to get val score of 0.4923:
#                 {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 0.0001, 'features': 20},
#             Current best combo with val score 0.4932:
#                     {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
# Trained and Tested combination 643 of 252000, taking 3.62 seconds to get val score of 0.4878:
#                 {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-06, 'features': 19},
#             Current best combo with val score 0.4932:
#                     {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
# Trained and Tested combination 644 of 252000, taking 2.86 seconds to get val score of 0.4693:
#                 {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-06, 'features': 21},
#             Current best combo with val score 0.4932:
#                     {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
# Trained and Tested combination 645 of 252000, taking 1.86 seconds to get val score of 0.483:
#                 {'n_estimators': 400, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 19},
#             Current best combo with val score 0.4932:
#                     {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
# Already Trained and Tested combination (val score of 0.4876):
#             {'n_estimators': 800, 'max_depth': 12, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 19}
#             Current best combo (with val score 0.4932):
#                     {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 645 of 252000 combinations so far
# Already Trained and Tested combination (val score of 0.4878):
#             {'n_estimators': 800, 'max_depth': 48, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 19}
#             Current best combo (with val score 0.4932):
#                     {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 645 of 252000 combinations so far
# Trained and Tested combination 646 of 252000, taking 4.08 seconds to get val score of 0.4782:
#                 {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.55, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 19},
#             Current best combo with val score 0.4932:
#                     {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
# Trained and Tested combination 647 of 252000, taking 3.05 seconds to get val score of 0.4835:
#                 {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.55, 'ccp_alpha': 1e-08, 'features': 19},
#             Current best combo with val score 0.4932:
#                     {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
# Already Trained and Tested combination (val score of 0.4878):
#             {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-06, 'features': 19}
#             Current best combo (with val score 0.4932):
#                     {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 647 of 252000 combinations so far
# Trained and Tested combination 648 of 252000, taking 2.79 seconds to get val score of 0.4927:
#                 {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 18},
#             Current best combo with val score 0.4932:
#                     {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
# Already Trained and Tested combination (val score of 0.4923):
#             {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#             Current best combo (with val score 0.4932):
#                     {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 648 of 252000 combinations so far
# % Combos Checked Thus Far: 648 out of 252000 which is 0.257143%
# Cruising Coordrdinate 528 of 528
#
# Cruise suspended due to suspicious case
# Guidance: round 2
#
# 	round 2 iteration:  0
#
# Already Trained and Tested combination (val score of 0.4839):
#             {'n_estimators': 400, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#             Current best combo (with val score 0.4932):
#                     {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 648 of 252000 combinations so far
# Already Trained and Tested combination (val score of 0.4932):
#             {'n_estimators': 800, 'max_depth': 96, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#             Current best combo (with val score 0.4932):
#                     {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 648 of 252000 combinations so far
# Already Trained and Tested combination (val score of 0.4875):
#             {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.55, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#             Current best combo (with val score 0.4932):
#                     {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 648 of 252000 combinations so far
# Already Trained and Tested combination (val score of 0.4809):
#             {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.55, 'ccp_alpha': 1e-08, 'features': 20}
#             Current best combo (with val score 0.4932):
#                     {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 648 of 252000 combinations so far
# Already Trained and Tested combination (val score of 0.4932):
#             {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-06, 'features': 20}
#             Current best combo (with val score 0.4932):
#                     {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 648 of 252000 combinations so far
# Already Trained and Tested combination (val score of 0.4878):
#             {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 19}
#             Current best combo (with val score 0.4932):
#                     {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 648 of 252000 combinations so far
# Already Trained and Tested combination (val score of 0.4752):
#             {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 21}
#             Current best combo (with val score 0.4932):
#                     {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 648 of 252000 combinations so far
# 	round 2 iteration:  1
#
# Trained and Tested combination 649 of 252000, taking 1.43 seconds to get val score of 0.4839:
#                 {'n_estimators': 400, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-06, 'features': 20},
#             Current best combo with val score 0.4932:
#                     {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
# Trained and Tested combination 650 of 252000, taking 4.03 seconds to get val score of 0.4932:
#                 {'n_estimators': 800, 'max_depth': 96, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-06, 'features': 20},
#             Current best combo with val score 0.4932:
#                     {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
# Trained and Tested combination 651 of 252000, taking 4.91 seconds to get val score of 0.4875:
#                 {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.55, 'max_features': 0.4, 'ccp_alpha': 1e-06, 'features': 20},
#             Current best combo with val score 0.4932:
#                     {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
# Trained and Tested combination 652 of 252000, taking 3.69 seconds to get val score of 0.4809:
#                 {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.55, 'ccp_alpha': 1e-06, 'features': 20},
#             Current best combo with val score 0.4932:
#                     {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
# Already Trained and Tested combination (val score of 0.4932):
#             {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#             Current best combo (with val score 0.4932):
#                     {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
#         Has trained 652 of 252000 combinations so far
# Trained and Tested combination 653 of 252000, taking 2.9 seconds to get val score of 0.4932:
#                 {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 0.0001, 'features': 20},
#             Current best combo with val score 0.4932:
#                     {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
# Trained and Tested combination 654 of 252000, taking 3.9 seconds to get val score of 0.4878:
#                 {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-06, 'features': 19},
#             Current best combo with val score 0.4932:
#                     {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
# Trained and Tested combination 655 of 252000, taking 2.85 seconds to get val score of 0.4752:
#                 {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-06, 'features': 21},
#             Current best combo with val score 0.4932:
#                     {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
# % Combos Checked Thus Far: 655 out of 252000 which is 0.25992099999999996%
# FINAL STAGE: Begin final Guidance system
#
#
# Guidance: round FINAL
#
# 	round FINAL iteration:  0
#
# % Combos Checked Thus Far: 655 out of 252000 which is 0.25992099999999996%
# Max Val Score:
#  0.493236
# Max Val Score Std:
#  0.05384
# Best Combo Train Score:
#  0.846786
# Best Combo Train Score Std:
#  0.005792
# Max Combo Index:
#  (5, 6, 0, 0, 0, 20) out of [6, 7, 5, 5, 5, 48] (note best combo is 0-indexed)
# Max Combo Hyperparamer Combination:
#  {'n_estimators': 800, 'max_depth': 192, 'max_samples': 0.4, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'features': 20}
# Max Combo Features:
#  ('procedure_225792', 'ventilation_used', 'procedure_226475', 'lods_score', 'procedure_225802', 'hospital_stay_duration', 'procedure_224276', 'procedure_229519', 'procedure_226236', 'race_AMERICAN INDIAN/ALASKA NATIVE', 'race_ASIAN', 'race_ASIAN - ASIAN INDIAN', 'race_ASIAN - CHINESE', 'race_ASIAN - KOREAN', 'race_ASIAN - SOUTH EAST ASIAN', 'race_BLACK/AFRICAN', 'race_BLACK/AFRICAN AMERICAN', 'race_BLACK/CAPE VERDEAN', 'race_BLACK/CARIBBEAN ISLAND', 'race_HISPANIC OR LATINO', 'race_HISPANIC/LATINO - CENTRAL AMERICAN', 'race_HISPANIC/LATINO - COLUMBIAN', 'race_HISPANIC/LATINO - CUBAN', 'race_HISPANIC/LATINO - DOMINICAN', 'race_HISPANIC/LATINO - GUATEMALAN', 'race_HISPANIC/LATINO - HONDURAN', 'race_HISPANIC/LATINO - MEXICAN', 'race_HISPANIC/LATINO - PUERTO RICAN', 'race_HISPANIC/LATINO - SALVADORAN', 'race_MULTIPLE RACE/ETHNICITY', 'race_NATIVE HAWAIIAN OR OTHER PACIFIC ISLANDER', 'race_OTHER', 'race_PATIENT DECLINED TO ANSWER', 'race_PORTUGUESE', 'race_SOUTH AMERICAN', 'race_UNABLE TO OBTAIN', 'race_WHITE', 'race_WHITE - BRAZILIAN', 'race_WHITE - EASTERN EUROPEAN', 'race_WHITE - OTHER EUROPEAN', 'race_WHITE - RUSSIAN', 'race_UNKNOWN', 'oasis_score', 'procedure_224267', 'icu_stay_duration', 'procedure_229580', 'procedure_224270', 'procedure_225446', 'procedure_225400', 'procedure_221223', 'unique_drugs', 'procedure_227712', 'procedure_224263')
# % Combos Checked: 655 out of 252000 which is 0.25992099999999996%
