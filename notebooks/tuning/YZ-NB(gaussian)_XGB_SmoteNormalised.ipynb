# %% [markdown]
# # Tuning Script

# %%
# Parameters subject to change in every script - involved in naming

MODEL = 'nb(gaussian)'
PREPROCESSING = 'smote_normalise'
TUNER = 'yangzhoub'
OPTIMISED_METRIC = 'f1'

# %% [markdown]
# ---

# %%
# detect whether this is a google environment

COLAB_ENVIRONMENT = False

try:
    from google.colab import drive
    drive.mount('/content/drive')
    COLAB_ENVIRONMENT = True
except:
    pass
# Out:
# Mounted at /content/drive

# %%
import sys
import os
import pickle

if COLAB_ENVIRONMENT:
    home_directory = './drive/MyDrive/LAB/COMP90089__GroupWork__Py/' # my home directory is stored in ./LAB of google drive
    if MODEL == 'ebr':
        # !pip install interpret==0.5.0
    elif MODEL == 'cbr':
        # !pip install catboost
    elif MODEL in ['tf', 'mlp']:
        # !pip install PyTorch2Sklearn
    # !pip install JXAutoML
else:
    home_directory = '../../'

from JXAutoML.YangZhouB_10CV import YangZhouB_10CV as Tuner

import pandas as pd
# Out:
# Collecting JXAutoML
#   Downloading JXAutoML-0.4.4-py3-none-any.whl.metadata (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.2/67.2 kB 1.8 MB/s eta 0:00:00
# Downloading JXAutoML-0.4.4-py3-none-any.whl (52 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.1/52.1 kB 3.1 MB/s eta 0:00:00
# Installing collected packages: JXAutoML
# Successfully installed JXAutoML-0.4.4

# %%
# Parameters that are same for every script

FOLDS = 10  # we have decided to do 10 fold validation

SEED = 42

TASK_TYPE = 'Classification'  # this task is a classification task

# we have decided to tune features as hp
TUNE_FEATURES_AS_HYPERPARAMETERS = True

# %% [markdown]
# ---

# %%
# model to use to tune
from sklearn.naive_bayes import GaussianNB as clf

# what values to try for each hyperparameter
parameter_choices = {
    'var_smoothing': (0.00001, 0.0001, 0.001, 0.01, 0.1, 1, 10, 100),
}

# what values to set non-tuneable parameters/hyperparameters
non_tunable_hyperparameters_dict = {}

# %% [markdown]
# ---

# %% [markdown]
# Read in and Prepare Data

# %%
# Import data and store as lists

train_x_list = []
train_y_list = []
val_x_list = []
val_y_list = []

for i in range(FOLDS):
    train_data = pd.read_csv(
        f'{home_directory}data/curated/modelling/{PREPROCESSING}/train_{i}.csv')
    val_data = pd.read_csv(
        f'{home_directory}data/curated/modelling/{PREPROCESSING}/val_{i}.csv')

    # get the correct rows for X and y
    train_x = train_data.drop(
        ['mortality_status', 'subject_id', 'hadm_id', 'stay_id'], axis=1)
    train_y = train_data['mortality_status']
    val_x = val_data.drop(
        ['mortality_status', 'subject_id', 'hadm_id', 'stay_id'], axis=1)
    val_y = val_data['mortality_status']

    train_x_list.append(train_x)
    train_y_list.append(train_y)
    val_x_list.append(val_x)
    val_y_list.append(val_y)

# %%
# Import feature importance ordering

with open(f'{home_directory}models/xgb_feature_importance_ordering_{PREPROCESSING}.pickle', 'rb') as f:
    feature_importance_ordering = pickle.load(f)

# %% [markdown]
# Set parameters

# %%
# initialisation
tuner = Tuner()

print('---')

# define what model we are tuning
tuner.read_in_model(clf, TASK_TYPE, optimised_metric=OPTIMISED_METRIC)

print('---')

# read in the data for training and validation
tuner.read_in_data(train_x_list, train_y_list, val_x_list, val_y_list)

print('---')

# set what hp values to tune
tuner.set_hyperparameters(parameter_choices)
# WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

# set up hp values that need to be changed from default but NOT to be tuned
tuner.set_non_tuneable_hyperparameters(non_tunable_hyperparameters_dict)

print('---')

# set up feature importance ordering

if TUNE_FEATURES_AS_HYPERPARAMETERS:
    tuner.set_features(feature_importance_ordering)
    # WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

try:  # try to read in previous results to continue tuning ...
    tuner.read_in_tuning_result_df(
        f'{home_directory}models/tuning/{TUNER}_{MODEL}_{PREPROCESSING}.csv')
except:
    print('No previous tuning data read in')

print('---')

# set up where to save the tuning result csv
tuner.set_tuning_result_saving_address(
    f'{home_directory}models/tuning/{TUNER}_{MODEL}_{PREPROCESSING}.csv')

print('---')

# set up where to save the current best model
tuner.set_best_model_saving_address(
    f'{home_directory}models/tmp_models/{TUNER}_{MODEL}_{PREPROCESSING}')
# Out:
# YangZhouB Initialised
# ---
# Successfully read in model <class 'sklearn.naive_bayes.GaussianNB'>, which is a Classification model optimising for f1
# ---
# Read in Train X data list
# Read in Train y data list
# Read in Val X data list
# Read in Val y data list
# ---
# Successfully recorded hyperparameter choices
# ---
# Successfully recorded non_tuneable_hyperparameter choices
# ---
# Successfully recorded tuneable feature combination choices and updated relevant internal structures
# ---
# No previous tuning data read in
# ---
# Successfully set tuning output address
# ---
# Successfully set best model output address

# %%
# ignore warnings

import warnings
warnings.filterwarnings("ignore")

# %%
# begin tuning ... (or continue training)

tuner.tune()
# Out:
# BEGIN TUNING
#
#
# STAGE ZERO: Tune all Cruise combinations
#
#
# Trained and Tested combination 1 of 384, taking 0.01 seconds to get val score of 0.3196:
#                 {'var_smoothing': 1e-05, 'features': 43},
#             Current best combo with val score 0.3196:
#                     {'var_smoothing': 1e-05, 'features': 43}
# Trained and Tested combination 2 of 384, taking 0.01 seconds to get val score of 0.0:
#                 {'var_smoothing': 100, 'features': 25},
#             Current best combo with val score 0.3196:
#                     {'var_smoothing': 1e-05, 'features': 43}
# Trained and Tested combination 3 of 384, taking 0.01 seconds to get val score of 0.3204:
#                 {'var_smoothing': 1e-05, 'features': 47},
#             Current best combo with val score 0.3204:
#                     {'var_smoothing': 1e-05, 'features': 47}
# Trained and Tested combination 4 of 384, taking 0.01 seconds to get val score of 0.3211:
#                 {'var_smoothing': 1e-05, 'features': 20},
#             Current best combo with val score 0.3211:
#                     {'var_smoothing': 1e-05, 'features': 20}
# Trained and Tested combination 5 of 384, taking 0.01 seconds to get val score of 0.0:
#                 {'var_smoothing': 100, 'features': 43},
#             Current best combo with val score 0.3211:
#                     {'var_smoothing': 1e-05, 'features': 20}
# Trained and Tested combination 6 of 384, taking 0.01 seconds to get val score of 0.0:
#                 {'var_smoothing': 100, 'features': 15},
#             Current best combo with val score 0.3211:
#                     {'var_smoothing': 1e-05, 'features': 20}
# Trained and Tested combination 7 of 384, taking 0.02 seconds to get val score of 0.3139:
#                 {'var_smoothing': 1e-05, 'features': 39},
#             Current best combo with val score 0.3211:
#                     {'var_smoothing': 1e-05, 'features': 20}
# Trained and Tested combination 8 of 384, taking 0.01 seconds to get val score of 0.0:
#                 {'var_smoothing': 0.1, 'features': 30},
#             Current best combo with val score 0.3211:
#                     {'var_smoothing': 1e-05, 'features': 20}
# Trained and Tested combination 9 of 384, taking 0.01 seconds to get val score of 0.0:
#                 {'var_smoothing': 100, 'features': 39},
#             Current best combo with val score 0.3211:
#                     {'var_smoothing': 1e-05, 'features': 20}
# Trained and Tested combination 10 of 384, taking 0.0 seconds to get val score of 0.3108:
#                 {'var_smoothing': 0.1, 'features': 0},
#             Current best combo with val score 0.3211:
#                     {'var_smoothing': 1e-05, 'features': 20}
# Trained and Tested combination 11 of 384, taking 0.01 seconds to get val score of 0.3118:
#                 {'var_smoothing': 0.1, 'features': 39},
#             Current best combo with val score 0.3211:
#                     {'var_smoothing': 1e-05, 'features': 20}
# Trained and Tested combination 12 of 384, taking 0.01 seconds to get val score of 0.0:
#                 {'var_smoothing': 0.1, 'features': 10},
#             Current best combo with val score 0.3211:
#                     {'var_smoothing': 1e-05, 'features': 20}
# Trained and Tested combination 13 of 384, taking 0.01 seconds to get val score of 0.0:
#                 {'var_smoothing': 0.1, 'features': 24},
#             Current best combo with val score 0.3211:
#                     {'var_smoothing': 1e-05, 'features': 20}
# Trained and Tested combination 14 of 384, taking 0.01 seconds to get val score of 0.2621:
#                 {'var_smoothing': 0.1, 'features': 5},
#             Current best combo with val score 0.3211:
#                     {'var_smoothing': 1e-05, 'features': 20}
# Trained and Tested combination 15 of 384, taking 0.01 seconds to get val score of 0.3216:
#                 {'var_smoothing': 1e-05, 'features': 25},
#             Current best combo with val score 0.3216:
#                     {'var_smoothing': 1e-05, 'features': 25}
# Trained and Tested combination 16 of 384, taking 0.01 seconds to get val score of 0.0:
#                 {'var_smoothing': 100, 'features': 20},
#             Current best combo with val score 0.3216:
#                     {'var_smoothing': 1e-05, 'features': 25}
# Trained and Tested combination 17 of 384, taking 0.01 seconds to get val score of 0.0:
#                 {'var_smoothing': 0.1, 'features': 25},
#             Current best combo with val score 0.3216:
#                     {'var_smoothing': 1e-05, 'features': 25}
# Trained and Tested combination 18 of 384, taking 0.01 seconds to get val score of 0.3237:
#                 {'var_smoothing': 1e-05, 'features': 30},
#             Current best combo with val score 0.3237:
#                     {'var_smoothing': 1e-05, 'features': 30}
# Trained and Tested combination 19 of 384, taking 0.01 seconds to get val score of 0.0:
#                 {'var_smoothing': 100, 'features': 10},
#             Current best combo with val score 0.3237:
#                     {'var_smoothing': 1e-05, 'features': 30}
# Trained and Tested combination 20 of 384, taking 0.01 seconds to get val score of 0.3229:
#                 {'var_smoothing': 1e-05, 'features': 5},
#             Current best combo with val score 0.3237:
#                     {'var_smoothing': 1e-05, 'features': 30}
# Trained and Tested combination 21 of 384, taking 0.01 seconds to get val score of 0.0:
#                 {'var_smoothing': 0.1, 'features': 20},
#             Current best combo with val score 0.3237:
#                     {'var_smoothing': 1e-05, 'features': 30}
# Trained and Tested combination 22 of 384, taking 0.01 seconds to get val score of 0.3146:
#                 {'var_smoothing': 1e-05, 'features': 35},
#             Current best combo with val score 0.3237:
#                     {'var_smoothing': 1e-05, 'features': 30}
# Trained and Tested combination 23 of 384, taking 0.0 seconds to get val score of 0.3108:
#                 {'var_smoothing': 100, 'features': 0},
#             Current best combo with val score 0.3237:
#                     {'var_smoothing': 1e-05, 'features': 30}
# Trained and Tested combination 24 of 384, taking 0.01 seconds to get val score of 0.0:
#                 {'var_smoothing': 100, 'features': 30},
#             Current best combo with val score 0.3237:
#                     {'var_smoothing': 1e-05, 'features': 30}
# Trained and Tested combination 25 of 384, taking 0.01 seconds to get val score of 0.3232:
#                 {'var_smoothing': 1e-05, 'features': 15},
#             Current best combo with val score 0.3237:
#                     {'var_smoothing': 1e-05, 'features': 30}
# Trained and Tested combination 26 of 384, taking 0.02 seconds to get val score of 0.0:
#                 {'var_smoothing': 100, 'features': 35},
#             Current best combo with val score 0.3237:
#                     {'var_smoothing': 1e-05, 'features': 30}
# Trained and Tested combination 27 of 384, taking 0.03 seconds to get val score of 0.0:
#                 {'var_smoothing': 0.1, 'features': 15},
#             Current best combo with val score 0.3237:
#                     {'var_smoothing': 1e-05, 'features': 30}
# Trained and Tested combination 28 of 384, taking 0.01 seconds to get val score of 0.3259:
#                 {'var_smoothing': 1e-05, 'features': 10},
#             Current best combo with val score 0.3259:
#                     {'var_smoothing': 1e-05, 'features': 10}
# Trained and Tested combination 29 of 384, taking 0.01 seconds to get val score of 0.3108:
#                 {'var_smoothing': 1e-05, 'features': 0},
#             Current best combo with val score 0.3259:
#                     {'var_smoothing': 1e-05, 'features': 10}
# Trained and Tested combination 30 of 384, taking 0.02 seconds to get val score of 0.3118:
#                 {'var_smoothing': 0.1, 'features': 43},
#             Current best combo with val score 0.3259:
#                     {'var_smoothing': 1e-05, 'features': 10}
# Trained and Tested combination 31 of 384, taking 0.02 seconds to get val score of 0.3118:
#                 {'var_smoothing': 0.1, 'features': 35},
#             Current best combo with val score 0.3259:
#                     {'var_smoothing': 1e-05, 'features': 10}
# Trained and Tested combination 32 of 384, taking 0.03 seconds to get val score of 0.3118:
#                 {'var_smoothing': 0.1, 'features': 47},
#             Current best combo with val score 0.3259:
#                     {'var_smoothing': 1e-05, 'features': 10}
# Trained and Tested combination 33 of 384, taking 0.01 seconds to get val score of 0.0:
#                 {'var_smoothing': 100, 'features': 5},
#             Current best combo with val score 0.3259:
#                     {'var_smoothing': 1e-05, 'features': 10}
# Trained and Tested combination 34 of 384, taking 0.03 seconds to get val score of 0.0:
#                 {'var_smoothing': 100, 'features': 47},
#             Current best combo with val score 0.3259:
#                     {'var_smoothing': 1e-05, 'features': 10}
#
#
# STAGE ONE: Begin initial Guidance system
#
#
# Guidance: initial round
#
# 	round 0 iteration:  0
#
# Trained and Tested combination 35 of 384, taking 0.01 seconds to get val score of 0.0929:
#                 {'var_smoothing': 0.01, 'features': 24},
#             Current best combo with val score 0.3259:
#                     {'var_smoothing': 1e-05, 'features': 10}
# Trained and Tested combination 36 of 384, taking 0.01 seconds to get val score of 0.0:
#                 {'var_smoothing': 1, 'features': 24},
#             Current best combo with val score 0.3259:
#                     {'var_smoothing': 1e-05, 'features': 10}
# Trained and Tested combination 37 of 384, taking 0.01 seconds to get val score of 0.0:
#                 {'var_smoothing': 0.1, 'features': 23},
#             Current best combo with val score 0.3259:
#                     {'var_smoothing': 1e-05, 'features': 10}
# Already Trained and Tested combination (val score of 0.0):
#             {'var_smoothing': 0.1, 'features': 25}
#             Current best combo (with val score 0.3259):
#                     {'var_smoothing': 1e-05, 'features': 10}
#         Has trained 37 of 384 combinations so far
# 	round 0 iteration:  1
#
# Trained and Tested combination 38 of 384, taking 0.01 seconds to get val score of 0.242:
#                 {'var_smoothing': 0.001, 'features': 24},
#             Current best combo with val score 0.3259:
#                     {'var_smoothing': 1e-05, 'features': 10}
# Already Trained and Tested combination (val score of 0.0):
#             {'var_smoothing': 0.1, 'features': 24}
#             Current best combo (with val score 0.3259):
#                     {'var_smoothing': 1e-05, 'features': 10}
#         Has trained 38 of 384 combinations so far
# Trained and Tested combination 39 of 384, taking 0.01 seconds to get val score of 0.093:
#                 {'var_smoothing': 0.01, 'features': 23},
#             Current best combo with val score 0.3259:
#                     {'var_smoothing': 1e-05, 'features': 10}
# Trained and Tested combination 40 of 384, taking 0.01 seconds to get val score of 0.104:
#                 {'var_smoothing': 0.01, 'features': 25},
#             Current best combo with val score 0.3259:
#                     {'var_smoothing': 1e-05, 'features': 10}
# Already Trained and Tested combination (val score of 0.0):
#             {'var_smoothing': 0.1, 'features': 24}
#             Current best combo (with val score 0.3259):
#                     {'var_smoothing': 1e-05, 'features': 10}
#         Has trained 40 of 384 combinations so far
# Trained and Tested combination 41 of 384, taking 0.01 seconds to get val score of 0.0:
#                 {'var_smoothing': 10, 'features': 24},
#             Current best combo with val score 0.3259:
#                     {'var_smoothing': 1e-05, 'features': 10}
# Trained and Tested combination 42 of 384, taking 0.01 seconds to get val score of 0.0:
#                 {'var_smoothing': 1, 'features': 23},
#             Current best combo with val score 0.3259:
#                     {'var_smoothing': 1e-05, 'features': 10}
# Trained and Tested combination 43 of 384, taking 0.01 seconds to get val score of 0.0:
#                 {'var_smoothing': 1, 'features': 25},
#             Current best combo with val score 0.3259:
#                     {'var_smoothing': 1e-05, 'features': 10}
# Already Trained and Tested combination (val score of 0.093):
#             {'var_smoothing': 0.01, 'features': 23}
#             Current best combo (with val score 0.3259):
#                     {'var_smoothing': 1e-05, 'features': 10}
#         Has trained 43 of 384 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'var_smoothing': 1, 'features': 23}
#             Current best combo (with val score 0.3259):
#                     {'var_smoothing': 1e-05, 'features': 10}
#         Has trained 43 of 384 combinations so far
# Trained and Tested combination 44 of 384, taking 0.01 seconds to get val score of 0.0:
#                 {'var_smoothing': 0.1, 'features': 22},
#             Current best combo with val score 0.3259:
#                     {'var_smoothing': 1e-05, 'features': 10}
# Already Trained and Tested combination (val score of 0.0):
#             {'var_smoothing': 0.1, 'features': 24}
#             Current best combo (with val score 0.3259):
#                     {'var_smoothing': 1e-05, 'features': 10}
#         Has trained 44 of 384 combinations so far
# Already Trained and Tested combination (val score of 0.104):
#             {'var_smoothing': 0.01, 'features': 25}
#             Current best combo (with val score 0.3259):
#                     {'var_smoothing': 1e-05, 'features': 10}
#         Has trained 44 of 384 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'var_smoothing': 1, 'features': 25}
#             Current best combo (with val score 0.3259):
#                     {'var_smoothing': 1e-05, 'features': 10}
#         Has trained 44 of 384 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'var_smoothing': 0.1, 'features': 24}
#             Current best combo (with val score 0.3259):
#                     {'var_smoothing': 1e-05, 'features': 10}
#         Has trained 44 of 384 combinations so far
# Trained and Tested combination 45 of 384, taking 0.01 seconds to get val score of 0.125:
#                 {'var_smoothing': 0.1, 'features': 26},
#             Current best combo with val score 0.3259:
#                     {'var_smoothing': 1e-05, 'features': 10}
# Trained and Tested combination 46 of 384, taking 0.01 seconds to get val score of 0.3338:
#                 {'var_smoothing': 0.0001, 'features': 10},
#             Current best combo with val score 0.3338:
#                     {'var_smoothing': 0.0001, 'features': 10}
# Trained and Tested combination 47 of 384, taking 0.01 seconds to get val score of 0.3245:
#                 {'var_smoothing': 1e-05, 'features': 9},
#             Current best combo with val score 0.3338:
#                     {'var_smoothing': 0.0001, 'features': 10}
# Trained and Tested combination 48 of 384, taking 0.01 seconds to get val score of 0.327:
#                 {'var_smoothing': 1e-05, 'features': 11},
#             Current best combo with val score 0.3338:
#                     {'var_smoothing': 0.0001, 'features': 10}
# Already Trained and Tested combination (val score of 0.3259):
#             {'var_smoothing': 1e-05, 'features': 10}
#             Current best combo (with val score 0.3338):
#                     {'var_smoothing': 0.0001, 'features': 10}
#         Has trained 48 of 384 combinations so far
# Trained and Tested combination 49 of 384, taking 0.01 seconds to get val score of 0.2091:
#                 {'var_smoothing': 0.001, 'features': 10},
#             Current best combo with val score 0.3338:
#                     {'var_smoothing': 0.0001, 'features': 10}
# Trained and Tested combination 50 of 384, taking 0.01 seconds to get val score of 0.3317:
#                 {'var_smoothing': 0.0001, 'features': 9},
#             Current best combo with val score 0.3338:
#                     {'var_smoothing': 0.0001, 'features': 10}
# Trained and Tested combination 51 of 384, taking 0.01 seconds to get val score of 0.3343:
#                 {'var_smoothing': 0.0001, 'features': 11},
#             Current best combo with val score 0.3343:
#                     {'var_smoothing': 0.0001, 'features': 11}
# Already Trained and Tested combination (val score of 0.327):
#             {'var_smoothing': 1e-05, 'features': 11}
#             Current best combo (with val score 0.3343):
#                     {'var_smoothing': 0.0001, 'features': 11}
#         Has trained 51 of 384 combinations so far
# Trained and Tested combination 52 of 384, taking 0.01 seconds to get val score of 0.2349:
#                 {'var_smoothing': 0.001, 'features': 11},
#             Current best combo with val score 0.3343:
#                     {'var_smoothing': 0.0001, 'features': 11}
# Already Trained and Tested combination (val score of 0.3338):
#             {'var_smoothing': 0.0001, 'features': 10}
#             Current best combo (with val score 0.3343):
#                     {'var_smoothing': 0.0001, 'features': 11}
#         Has trained 52 of 384 combinations so far
# Trained and Tested combination 53 of 384, taking 0.01 seconds to get val score of 0.3337:
#                 {'var_smoothing': 0.0001, 'features': 12},
#             Current best combo with val score 0.3343:
#                     {'var_smoothing': 0.0001, 'features': 11}
# % Combos Checked Thus Far: 53 out of 384 which is 13.802083000000001%
# STAGE TWO: Begin Cruise system
#
#
# Cruising Coordrdinate 1 of 33
#
# Cruising Coordrdinate 2 of 33
#
# Cruise suspended due to suspicious case
# Guidance: round 1
#
# 	round 1 iteration:  0
#
# Trained and Tested combination 54 of 384, taking 0.01 seconds to get val score of 0.3119:
#                 {'var_smoothing': 0.01, 'features': 47},
#             Current best combo with val score 0.3343:
#                     {'var_smoothing': 0.0001, 'features': 11}
# Trained and Tested combination 55 of 384, taking 0.01 seconds to get val score of 0.3118:
#                 {'var_smoothing': 1, 'features': 47},
#             Current best combo with val score 0.3343:
#                     {'var_smoothing': 0.0001, 'features': 11}
# Trained and Tested combination 56 of 384, taking 0.01 seconds to get val score of 0.3118:
#                 {'var_smoothing': 0.1, 'features': 46},
#             Current best combo with val score 0.3343:
#                     {'var_smoothing': 0.0001, 'features': 11}
# 	round 1 iteration:  1
#
# Trained and Tested combination 57 of 384, taking 0.01 seconds to get val score of 0.3179:
#                 {'var_smoothing': 0.001, 'features': 47},
#             Current best combo with val score 0.3343:
#                     {'var_smoothing': 0.0001, 'features': 11}
# Already Trained and Tested combination (val score of 0.3118):
#             {'var_smoothing': 0.1, 'features': 47}
#             Current best combo (with val score 0.3343):
#                     {'var_smoothing': 0.0001, 'features': 11}
#         Has trained 57 of 384 combinations so far
# Trained and Tested combination 58 of 384, taking 0.01 seconds to get val score of 0.3119:
#                 {'var_smoothing': 0.01, 'features': 46},
#             Current best combo with val score 0.3343:
#                     {'var_smoothing': 0.0001, 'features': 11}
# Already Trained and Tested combination (val score of 0.3118):
#             {'var_smoothing': 0.1, 'features': 47}
#             Current best combo (with val score 0.3343):
#                     {'var_smoothing': 0.0001, 'features': 11}
#         Has trained 58 of 384 combinations so far
# Trained and Tested combination 59 of 384, taking 0.01 seconds to get val score of 0.2805:
#                 {'var_smoothing': 10, 'features': 47},
#             Current best combo with val score 0.3343:
#                     {'var_smoothing': 0.0001, 'features': 11}
# Trained and Tested combination 60 of 384, taking 0.01 seconds to get val score of 0.3118:
#                 {'var_smoothing': 1, 'features': 46},
#             Current best combo with val score 0.3343:
#                     {'var_smoothing': 0.0001, 'features': 11}
# Already Trained and Tested combination (val score of 0.3119):
#             {'var_smoothing': 0.01, 'features': 46}
#             Current best combo (with val score 0.3343):
#                     {'var_smoothing': 0.0001, 'features': 11}
#         Has trained 60 of 384 combinations so far
# Already Trained and Tested combination (val score of 0.3118):
#             {'var_smoothing': 1, 'features': 46}
#             Current best combo (with val score 0.3343):
#                     {'var_smoothing': 0.0001, 'features': 11}
#         Has trained 60 of 384 combinations so far
# Trained and Tested combination 61 of 384, taking 0.01 seconds to get val score of 0.3118:
#                 {'var_smoothing': 0.1, 'features': 45},
#             Current best combo with val score 0.3343:
#                     {'var_smoothing': 0.0001, 'features': 11}
# Already Trained and Tested combination (val score of 0.3118):
#             {'var_smoothing': 0.1, 'features': 47}
#             Current best combo (with val score 0.3343):
#                     {'var_smoothing': 0.0001, 'features': 11}
#         Has trained 61 of 384 combinations so far
# % Combos Checked Thus Far: 61 out of 384 which is 15.885416999999999%
# Cruising Coordrdinate 3 of 33
#
# Cruise suspended due to suspicious case
# Guidance: round 2
#
# 	round 2 iteration:  0
#
# Trained and Tested combination 62 of 384, taking 0.01 seconds to get val score of 0.32:
#                 {'var_smoothing': 0.0001, 'features': 47},
#             Current best combo with val score 0.3343:
#                     {'var_smoothing': 0.0001, 'features': 11}
# Trained and Tested combination 63 of 384, taking 0.01 seconds to get val score of 0.3207:
#                 {'var_smoothing': 1e-05, 'features': 46},
#             Current best combo with val score 0.3343:
#                     {'var_smoothing': 0.0001, 'features': 11}
# 	round 2 iteration:  1
#
# Already Trained and Tested combination (val score of 0.3204):
#             {'var_smoothing': 1e-05, 'features': 47}
#             Current best combo (with val score 0.3343):
#                     {'var_smoothing': 0.0001, 'features': 11}
#         Has trained 63 of 384 combinations so far
# Already Trained and Tested combination (val score of 0.3179):
#             {'var_smoothing': 0.001, 'features': 47}
#             Current best combo (with val score 0.3343):
#                     {'var_smoothing': 0.0001, 'features': 11}
#         Has trained 63 of 384 combinations so far
# Trained and Tested combination 64 of 384, taking 0.01 seconds to get val score of 0.3205:
#                 {'var_smoothing': 0.0001, 'features': 46},
#             Current best combo with val score 0.3343:
#                     {'var_smoothing': 0.0001, 'features': 11}
# Already Trained and Tested combination (val score of 0.3205):
#             {'var_smoothing': 0.0001, 'features': 46}
#             Current best combo (with val score 0.3343):
#                     {'var_smoothing': 0.0001, 'features': 11}
#         Has trained 64 of 384 combinations so far
# Trained and Tested combination 65 of 384, taking 0.01 seconds to get val score of 0.3208:
#                 {'var_smoothing': 1e-05, 'features': 45},
#             Current best combo with val score 0.3343:
#                     {'var_smoothing': 0.0001, 'features': 11}
# Already Trained and Tested combination (val score of 0.3204):
#             {'var_smoothing': 1e-05, 'features': 47}
#             Current best combo (with val score 0.3343):
#                     {'var_smoothing': 0.0001, 'features': 11}
#         Has trained 65 of 384 combinations so far
# % Combos Checked Thus Far: 65 out of 384 which is 16.927083%
# Cruising Coordrdinate 4 of 33
#
# Cruising Coordrdinate 5 of 33
#
# Cruise suspended due to suspicious case
# Guidance: round 3
#
# 	round 3 iteration:  0
#
# Trained and Tested combination 66 of 384, taking 0.01 seconds to get val score of 0.3118:
#                 {'var_smoothing': 0.01, 'features': 43},
#             Current best combo with val score 0.3343:
#                     {'var_smoothing': 0.0001, 'features': 11}
# Trained and Tested combination 67 of 384, taking 0.01 seconds to get val score of 0.3118:
#                 {'var_smoothing': 1, 'features': 43},
#             Current best combo with val score 0.3343:
#                     {'var_smoothing': 0.0001, 'features': 11}
# Trained and Tested combination 68 of 384, taking 0.02 seconds to get val score of 0.3118:
#                 {'var_smoothing': 0.1, 'features': 42},
#             Current best combo with val score 0.3343:
#                     {'var_smoothing': 0.0001, 'features': 11}
# Trained and Tested combination 69 of 384, taking 0.02 seconds to get val score of 0.3118:
#                 {'var_smoothing': 0.1, 'features': 44},
#             Current best combo with val score 0.3343:
#                     {'var_smoothing': 0.0001, 'features': 11}
# 	round 3 iteration:  1
#
# Trained and Tested combination 70 of 384, taking 0.02 seconds to get val score of 0.3168:
#                 {'var_smoothing': 0.001, 'features': 43},
#             Current best combo with val score 0.3343:
#                     {'var_smoothing': 0.0001, 'features': 11}
# Already Trained and Tested combination (val score of 0.3118):
#             {'var_smoothing': 0.1, 'features': 43}
#             Current best combo (with val score 0.3343):
#                     {'var_smoothing': 0.0001, 'features': 11}
#         Has trained 70 of 384 combinations so far
# Trained and Tested combination 71 of 384, taking 0.02 seconds to get val score of 0.3122:
#                 {'var_smoothing': 0.01, 'features': 42},
#             Current best combo with val score 0.3343:
#                     {'var_smoothing': 0.0001, 'features': 11}
# Trained and Tested combination 72 of 384, taking 0.01 seconds to get val score of 0.3118:
#                 {'var_smoothing': 0.01, 'features': 44},
#             Current best combo with val score 0.3343:
#                     {'var_smoothing': 0.0001, 'features': 11}
# Already Trained and Tested combination (val score of 0.3118):
#             {'var_smoothing': 0.1, 'features': 43}
#             Current best combo (with val score 0.3343):
#                     {'var_smoothing': 0.0001, 'features': 11}
#         Has trained 72 of 384 combinations so far
# Trained and Tested combination 73 of 384, taking 0.01 seconds to get val score of 0.2805:
#                 {'var_smoothing': 10, 'features': 43},
#             Current best combo with val score 0.3343:
#                     {'var_smoothing': 0.0001, 'features': 11}
# Trained and Tested combination 74 of 384, taking 0.01 seconds to get val score of 0.3118:
#                 {'var_smoothing': 1, 'features': 42},
#             Current best combo with val score 0.3343:
#                     {'var_smoothing': 0.0001, 'features': 11}
# Trained and Tested combination 75 of 384, taking 0.01 seconds to get val score of 0.3118:
#                 {'var_smoothing': 1, 'features': 44},
#             Current best combo with val score 0.3343:
#                     {'var_smoothing': 0.0001, 'features': 11}
# Already Trained and Tested combination (val score of 0.3122):
#             {'var_smoothing': 0.01, 'features': 42}
#             Current best combo (with val score 0.3343):
#                     {'var_smoothing': 0.0001, 'features': 11}
#         Has trained 75 of 384 combinations so far
# Already Trained and Tested combination (val score of 0.3118):
#             {'var_smoothing': 1, 'features': 42}
#             Current best combo (with val score 0.3343):
#                     {'var_smoothing': 0.0001, 'features': 11}
#         Has trained 75 of 384 combinations so far
# Trained and Tested combination 76 of 384, taking 0.01 seconds to get val score of 0.3118:
#                 {'var_smoothing': 0.1, 'features': 41},
#             Current best combo with val score 0.3343:
#                     {'var_smoothing': 0.0001, 'features': 11}
# Already Trained and Tested combination (val score of 0.3118):
#             {'var_smoothing': 0.1, 'features': 43}
#             Current best combo (with val score 0.3343):
#                     {'var_smoothing': 0.0001, 'features': 11}
#         Has trained 76 of 384 combinations so far
# Already Trained and Tested combination (val score of 0.3118):
#             {'var_smoothing': 0.01, 'features': 44}
#             Current best combo (with val score 0.3343):
#                     {'var_smoothing': 0.0001, 'features': 11}
#         Has trained 76 of 384 combinations so far
# Already Trained and Tested combination (val score of 0.3118):
#             {'var_smoothing': 1, 'features': 44}
#             Current best combo (with val score 0.3343):
#                     {'var_smoothing': 0.0001, 'features': 11}
#         Has trained 76 of 384 combinations so far
# Already Trained and Tested combination (val score of 0.3118):
#             {'var_smoothing': 0.1, 'features': 43}
#             Current best combo (with val score 0.3343):
#                     {'var_smoothing': 0.0001, 'features': 11}
#         Has trained 76 of 384 combinations so far
# Already Trained and Tested combination (val score of 0.3118):
#             {'var_smoothing': 0.1, 'features': 45}
#             Current best combo (with val score 0.3343):
#                     {'var_smoothing': 0.0001, 'features': 11}
#         Has trained 76 of 384 combinations so far
# % Combos Checked Thus Far: 76 out of 384 which is 19.791667%
# Cruising Coordrdinate 6 of 33
#
# Cruise suspended due to suspicious case
# Guidance: round 4
#
# 	round 4 iteration:  0
#
# Trained and Tested combination 77 of 384, taking 0.01 seconds to get val score of 0.3193:
#                 {'var_smoothing': 0.0001, 'features': 43},
#             Current best combo with val score 0.3343:
#                     {'var_smoothing': 0.0001, 'features': 11}
# Trained and Tested combination 78 of 384, taking 0.01 seconds to get val score of 0.3198:
#                 {'var_smoothing': 1e-05, 'features': 42},
#             Current best combo with val score 0.3343:
#                     {'var_smoothing': 0.0001, 'features': 11}
# Trained and Tested combination 79 of 384, taking 0.01 seconds to get val score of 0.3196:
#                 {'var_smoothing': 1e-05, 'features': 44},
#             Current best combo with val score 0.3343:
#                     {'var_smoothing': 0.0001, 'features': 11}
# 	round 4 iteration:  1
#
# Already Trained and Tested combination (val score of 0.3196):
#             {'var_smoothing': 1e-05, 'features': 43}
#             Current best combo (with val score 0.3343):
#                     {'var_smoothing': 0.0001, 'features': 11}
#         Has trained 79 of 384 combinations so far
# Already Trained and Tested combination (val score of 0.3168):
#             {'var_smoothing': 0.001, 'features': 43}
#             Current best combo (with val score 0.3343):
#                     {'var_smoothing': 0.0001, 'features': 11}
#         Has trained 79 of 384 combinations so far
# Trained and Tested combination 80 of 384, taking 0.02 seconds to get val score of 0.3193:
#                 {'var_smoothing': 0.0001, 'features': 42},
#             Current best combo with val score 0.3343:
#                     {'var_smoothing': 0.0001, 'features': 11}
# Trained and Tested combination 81 of 384, taking 0.01 seconds to get val score of 0.3194:
#                 {'var_smoothing': 0.0001, 'features': 44},
#             Current best combo with val score 0.3343:
#                     {'var_smoothing': 0.0001, 'features': 11}
# Already Trained and Tested combination (val score of 0.3193):
#             {'var_smoothing': 0.0001, 'features': 42}
#             Current best combo (with val score 0.3343):
#                     {'var_smoothing': 0.0001, 'features': 11}
#         Has trained 81 of 384 combinations so far
# Trained and Tested combination 82 of 384, taking 0.01 seconds to get val score of 0.3198:
#                 {'var_smoothing': 1e-05, 'features': 41},
#             Current best combo with val score 0.3343:
#                     {'var_smoothing': 0.0001, 'features': 11}
# Already Trained and Tested combination (val score of 0.3196):
#             {'var_smoothing': 1e-05, 'features': 43}
#             Current best combo (with val score 0.3343):
#                     {'var_smoothing': 0.0001, 'features': 11}
#         Has trained 82 of 384 combinations so far
# Already Trained and Tested combination (val score of 0.3194):
#             {'var_smoothing': 0.0001, 'features': 44}
#             Current best combo (with val score 0.3343):
#                     {'var_smoothing': 0.0001, 'features': 11}
#         Has trained 82 of 384 combinations so far
# Already Trained and Tested combination (val score of 0.3196):
#             {'var_smoothing': 1e-05, 'features': 43}
#             Current best combo (with val score 0.3343):
#                     {'var_smoothing': 0.0001, 'features': 11}
#         Has trained 82 of 384 combinations so far
# Already Trained and Tested combination (val score of 0.3208):
#             {'var_smoothing': 1e-05, 'features': 45}
#             Current best combo (with val score 0.3343):
#                     {'var_smoothing': 0.0001, 'features': 11}
#         Has trained 82 of 384 combinations so far
# % Combos Checked Thus Far: 82 out of 384 which is 21.354167%
# Cruising Coordrdinate 7 of 33
#
# Cruising Coordrdinate 8 of 33
#
# Cruise suspended due to suspicious case
# Guidance: round 5
#
# 	round 5 iteration:  0
#
# Trained and Tested combination 83 of 384, taking 0.01 seconds to get val score of 0.3118:
#                 {'var_smoothing': 0.01, 'features': 39},
#             Current best combo with val score 0.3343:
#                     {'var_smoothing': 0.0001, 'features': 11}
# Trained and Tested combination 84 of 384, taking 0.01 seconds to get val score of 0.3118:
#                 {'var_smoothing': 1, 'features': 39},
#             Current best combo with val score 0.3343:
#                     {'var_smoothing': 0.0001, 'features': 11}
# Trained and Tested combination 85 of 384, taking 0.01 seconds to get val score of 0.3118:
#                 {'var_smoothing': 0.1, 'features': 38},
#             Current best combo with val score 0.3343:
#                     {'var_smoothing': 0.0001, 'features': 11}
# Trained and Tested combination 86 of 384, taking 0.01 seconds to get val score of 0.3118:
#                 {'var_smoothing': 0.1, 'features': 40},
#             Current best combo with val score 0.3343:
#                     {'var_smoothing': 0.0001, 'features': 11}
# 	round 5 iteration:  1
#
# Trained and Tested combination 87 of 384, taking 0.01 seconds to get val score of 0.3135:
#                 {'var_smoothing': 0.001, 'features': 39},
#             Current best combo with val score 0.3343:
#                     {'var_smoothing': 0.0001, 'features': 11}
# Already Trained and Tested combination (val score of 0.3118):
#             {'var_smoothing': 0.1, 'features': 39}
#             Current best combo (with val score 0.3343):
#                     {'var_smoothing': 0.0001, 'features': 11}
#         Has trained 87 of 384 combinations so far
# Trained and Tested combination 88 of 384, taking 0.01 seconds to get val score of 0.3118:
#                 {'var_smoothing': 0.01, 'features': 38},
#             Current best combo with val score 0.3343:
#                     {'var_smoothing': 0.0001, 'features': 11}
# Trained and Tested combination 89 of 384, taking 0.01 seconds to get val score of 0.3118:
#                 {'var_smoothing': 0.01, 'features': 40},
#             Current best combo with val score 0.3343:
#                     {'var_smoothing': 0.0001, 'features': 11}
# Already Trained and Tested combination (val score of 0.3118):
#             {'var_smoothing': 0.1, 'features': 39}
#             Current best combo (with val score 0.3343):
#                     {'var_smoothing': 0.0001, 'features': 11}
#         Has trained 89 of 384 combinations so far
# Trained and Tested combination 90 of 384, taking 0.01 seconds to get val score of 0.2805:
#                 {'var_smoothing': 10, 'features': 39},
#             Current best combo with val score 0.3343:
#                     {'var_smoothing': 0.0001, 'features': 11}
# Trained and Tested combination 91 of 384, taking 0.02 seconds to get val score of 0.3118:
#                 {'var_smoothing': 1, 'features': 38},
#             Current best combo with val score 0.3343:
#                     {'var_smoothing': 0.0001, 'features': 11}
# Trained and Tested combination 92 of 384, taking 0.01 seconds to get val score of 0.3118:
#                 {'var_smoothing': 1, 'features': 40},
#             Current best combo with val score 0.3343:
#                     {'var_smoothing': 0.0001, 'features': 11}
# Already Trained and Tested combination (val score of 0.3118):
#             {'var_smoothing': 0.01, 'features': 38}
#             Current best combo (with val score 0.3343):
#                     {'var_smoothing': 0.0001, 'features': 11}
#         Has trained 92 of 384 combinations so far
# Already Trained and Tested combination (val score of 0.3118):
#             {'var_smoothing': 1, 'features': 38}
#             Current best combo (with val score 0.3343):
#                     {'var_smoothing': 0.0001, 'features': 11}
#         Has trained 92 of 384 combinations so far
# Trained and Tested combination 93 of 384, taking 0.01 seconds to get val score of 0.3118:
#                 {'var_smoothing': 0.1, 'features': 37},
#             Current best combo with val score 0.3343:
#                     {'var_smoothing': 0.0001, 'features': 11}
# Already Trained and Tested combination (val score of 0.3118):
#             {'var_smoothing': 0.1, 'features': 39}
#             Current best combo (with val score 0.3343):
#                     {'var_smoothing': 0.0001, 'features': 11}
#         Has trained 93 of 384 combinations so far
# Already Trained and Tested combination (val score of 0.3118):
#             {'var_smoothing': 0.01, 'features': 40}
#             Current best combo (with val score 0.3343):
#                     {'var_smoothing': 0.0001, 'features': 11}
#         Has trained 93 of 384 combinations so far
# Already Trained and Tested combination (val score of 0.3118):
#             {'var_smoothing': 1, 'features': 40}
#             Current best combo (with val score 0.3343):
#                     {'var_smoothing': 0.0001, 'features': 11}
#         Has trained 93 of 384 combinations so far
# Already Trained and Tested combination (val score of 0.3118):
#             {'var_smoothing': 0.1, 'features': 39}
#             Current best combo (with val score 0.3343):
#                     {'var_smoothing': 0.0001, 'features': 11}
#         Has trained 93 of 384 combinations so far
# Already Trained and Tested combination (val score of 0.3118):
#             {'var_smoothing': 0.1, 'features': 41}
#             Current best combo (with val score 0.3343):
#                     {'var_smoothing': 0.0001, 'features': 11}
#         Has trained 93 of 384 combinations so far
# % Combos Checked Thus Far: 93 out of 384 which is 24.21875%
# Cruising Coordrdinate 9 of 33
#
# Cruise suspended due to suspicious case
# Guidance: round 6
#
# 	round 6 iteration:  0
#
# Trained and Tested combination 94 of 384, taking 0.01 seconds to get val score of 0.3132:
#                 {'var_smoothing': 0.0001, 'features': 39},
#             Current best combo with val score 0.3343:
#                     {'var_smoothing': 0.0001, 'features': 11}
# Trained and Tested combination 95 of 384, taking 0.01 seconds to get val score of 0.3139:
#                 {'var_smoothing': 1e-05, 'features': 38},
#             Current best combo with val score 0.3343:
#                     {'var_smoothing': 0.0001, 'features': 11}
# Trained and Tested combination 96 of 384, taking 0.02 seconds to get val score of 0.3199:
#                 {'var_smoothing': 1e-05, 'features': 40},
#             Current best combo with val score 0.3343:
#                     {'var_smoothing': 0.0001, 'features': 11}
# 	round 6 iteration:  1
#
# Already Trained and Tested combination (val score of 0.3139):
#             {'var_smoothing': 1e-05, 'features': 39}
#             Current best combo (with val score 0.3343):
#                     {'var_smoothing': 0.0001, 'features': 11}
#         Has trained 96 of 384 combinations so far
# Already Trained and Tested combination (val score of 0.3135):
#             {'var_smoothing': 0.001, 'features': 39}
#             Current best combo (with val score 0.3343):
#                     {'var_smoothing': 0.0001, 'features': 11}
#         Has trained 96 of 384 combinations so far
# Trained and Tested combination 97 of 384, taking 0.01 seconds to get val score of 0.3132:
#                 {'var_smoothing': 0.0001, 'features': 38},
#             Current best combo with val score 0.3343:
#                     {'var_smoothing': 0.0001, 'features': 11}
# Trained and Tested combination 98 of 384, taking 0.01 seconds to get val score of 0.3193:
#                 {'var_smoothing': 0.0001, 'features': 40},
#             Current best combo with val score 0.3343:
#                     {'var_smoothing': 0.0001, 'features': 11}
# Already Trained and Tested combination (val score of 0.3132):
#             {'var_smoothing': 0.0001, 'features': 38}
#             Current best combo (with val score 0.3343):
#                     {'var_smoothing': 0.0001, 'features': 11}
#         Has trained 98 of 384 combinations so far
# Trained and Tested combination 99 of 384, taking 0.01 seconds to get val score of 0.3146:
#                 {'var_smoothing': 1e-05, 'features': 37},
#             Current best combo with val score 0.3343:
#                     {'var_smoothing': 0.0001, 'features': 11}
# Already Trained and Tested combination (val score of 0.3139):
#             {'var_smoothing': 1e-05, 'features': 39}
#             Current best combo (with val score 0.3343):
#                     {'var_smoothing': 0.0001, 'features': 11}
#         Has trained 99 of 384 combinations so far
# Already Trained and Tested combination (val score of 0.3193):
#             {'var_smoothing': 0.0001, 'features': 40}
#             Current best combo (with val score 0.3343):
#                     {'var_smoothing': 0.0001, 'features': 11}
#         Has trained 99 of 384 combinations so far
# Already Trained and Tested combination (val score of 0.3139):
#             {'var_smoothing': 1e-05, 'features': 39}
#             Current best combo (with val score 0.3343):
#                     {'var_smoothing': 0.0001, 'features': 11}
#         Has trained 99 of 384 combinations so far
# Already Trained and Tested combination (val score of 0.3198):
#             {'var_smoothing': 1e-05, 'features': 41}
#             Current best combo (with val score 0.3343):
#                     {'var_smoothing': 0.0001, 'features': 11}
#         Has trained 99 of 384 combinations so far
# % Combos Checked Thus Far: 99 out of 384 which is 25.78125%
# Cruising Coordrdinate 10 of 33
#
# Cruising Coordrdinate 11 of 33
#
# Cruise suspended due to suspicious case
# Guidance: round 7
#
# 	round 7 iteration:  0
#
# Trained and Tested combination 100 of 384, taking 0.01 seconds to get val score of 0.3122:
#                 {'var_smoothing': 0.01, 'features': 35},
#             Current best combo with val score 0.3343:
#                     {'var_smoothing': 0.0001, 'features': 11}
# Trained and Tested combination 101 of 384, taking 0.01 seconds to get val score of 0.3118:
#                 {'var_smoothing': 1, 'features': 35},
#             Current best combo with val score 0.3343:
#                     {'var_smoothing': 0.0001, 'features': 11}
# Trained and Tested combination 102 of 384, taking 0.01 seconds to get val score of 0.3118:
#                 {'var_smoothing': 0.1, 'features': 34},
#             Current best combo with val score 0.3343:
#                     {'var_smoothing': 0.0001, 'features': 11}
# Trained and Tested combination 103 of 384, taking 0.01 seconds to get val score of 0.3118:
#                 {'var_smoothing': 0.1, 'features': 36},
#             Current best combo with val score 0.3343:
#                     {'var_smoothing': 0.0001, 'features': 11}
# 	round 7 iteration:  1
#
# Trained and Tested combination 104 of 384, taking 0.01 seconds to get val score of 0.3139:
#                 {'var_smoothing': 0.001, 'features': 35},
#             Current best combo with val score 0.3343:
#                     {'var_smoothing': 0.0001, 'features': 11}
# Already Trained and Tested combination (val score of 0.3118):
#             {'var_smoothing': 0.1, 'features': 35}
#             Current best combo (with val score 0.3343):
#                     {'var_smoothing': 0.0001, 'features': 11}
#         Has trained 104 of 384 combinations so far
# Trained and Tested combination 105 of 384, taking 0.01 seconds to get val score of 0.3122:
#                 {'var_smoothing': 0.01, 'features': 34},
#             Current best combo with val score 0.3343:
#                     {'var_smoothing': 0.0001, 'features': 11}
# Trained and Tested combination 106 of 384, taking 0.01 seconds to get val score of 0.3122:
#                 {'var_smoothing': 0.01, 'features': 36},
#             Current best combo with val score 0.3343:
#                     {'var_smoothing': 0.0001, 'features': 11}
# Already Trained and Tested combination (val score of 0.3118):
#             {'var_smoothing': 0.1, 'features': 35}
#             Current best combo (with val score 0.3343):
#                     {'var_smoothing': 0.0001, 'features': 11}
#         Has trained 106 of 384 combinations so far
# Trained and Tested combination 107 of 384, taking 0.02 seconds to get val score of 0.2838:
#                 {'var_smoothing': 10, 'features': 35},
#             Current best combo with val score 0.3343:
#                     {'var_smoothing': 0.0001, 'features': 11}
# Trained and Tested combination 108 of 384, taking 0.01 seconds to get val score of 0.3118:
#                 {'var_smoothing': 1, 'features': 34},
#             Current best combo with val score 0.3343:
#                     {'var_smoothing': 0.0001, 'features': 11}
# Trained and Tested combination 109 of 384, taking 0.01 seconds to get val score of 0.3118:
#                 {'var_smoothing': 1, 'features': 36},
#             Current best combo with val score 0.3343:
#                     {'var_smoothing': 0.0001, 'features': 11}
# Already Trained and Tested combination (val score of 0.3122):
#             {'var_smoothing': 0.01, 'features': 34}
#             Current best combo (with val score 0.3343):
#                     {'var_smoothing': 0.0001, 'features': 11}
#         Has trained 109 of 384 combinations so far
# Already Trained and Tested combination (val score of 0.3118):
#             {'var_smoothing': 1, 'features': 34}
#             Current best combo (with val score 0.3343):
#                     {'var_smoothing': 0.0001, 'features': 11}
#         Has trained 109 of 384 combinations so far
# Trained and Tested combination 110 of 384, taking 0.01 seconds to get val score of 0.0:
#                 {'var_smoothing': 0.1, 'features': 33},
#             Current best combo with val score 0.3343:
#                     {'var_smoothing': 0.0001, 'features': 11}
# Already Trained and Tested combination (val score of 0.3118):
#             {'var_smoothing': 0.1, 'features': 35}
#             Current best combo (with val score 0.3343):
#                     {'var_smoothing': 0.0001, 'features': 11}
#         Has trained 110 of 384 combinations so far
# Already Trained and Tested combination (val score of 0.3122):
#             {'var_smoothing': 0.01, 'features': 36}
#             Current best combo (with val score 0.3343):
#                     {'var_smoothing': 0.0001, 'features': 11}
#         Has trained 110 of 384 combinations so far
# Already Trained and Tested combination (val score of 0.3118):
#             {'var_smoothing': 1, 'features': 36}
#             Current best combo (with val score 0.3343):
#                     {'var_smoothing': 0.0001, 'features': 11}
#         Has trained 110 of 384 combinations so far
# Already Trained and Tested combination (val score of 0.3118):
# ...
# Already Trained and Tested combination (val score of 0.3461):
#             {'var_smoothing': 0.0001, 'features': 14}
#             Current best combo (with val score 0.3461):
#                     {'var_smoothing': 0.0001, 'features': 14}
#         Has trained 159 of 384 combinations so far
# Trained and Tested combination 160 of 384, taking 0.01 seconds to get val score of 0.3222:
#                 {'var_smoothing': 1e-05, 'features': 13},
#             Current best combo with val score 0.3461:
#                     {'var_smoothing': 0.0001, 'features': 14}
# Already Trained and Tested combination (val score of 0.3232):
#             {'var_smoothing': 1e-05, 'features': 15}
#             Current best combo (with val score 0.3461):
#                     {'var_smoothing': 0.0001, 'features': 14}
#         Has trained 160 of 384 combinations so far
# Already Trained and Tested combination (val score of 0.3446):
#             {'var_smoothing': 0.0001, 'features': 16}
#             Current best combo (with val score 0.3461):
#                     {'var_smoothing': 0.0001, 'features': 14}
#         Has trained 160 of 384 combinations so far
# Already Trained and Tested combination (val score of 0.3232):
#             {'var_smoothing': 1e-05, 'features': 15}
#             Current best combo (with val score 0.3461):
#                     {'var_smoothing': 0.0001, 'features': 14}
#         Has trained 160 of 384 combinations so far
# Trained and Tested combination 161 of 384, taking 0.01 seconds to get val score of 0.3234:
#                 {'var_smoothing': 1e-05, 'features': 17},
#             Current best combo with val score 0.3461:
#                     {'var_smoothing': 0.0001, 'features': 14}
# Already Trained and Tested combination (val score of 0.3234):
#             {'var_smoothing': 1e-05, 'features': 14}
#             Current best combo (with val score 0.3461):
#                     {'var_smoothing': 0.0001, 'features': 14}
#         Has trained 161 of 384 combinations so far
# Trained and Tested combination 162 of 384, taking 0.01 seconds to get val score of 0.2855:
#                 {'var_smoothing': 0.001, 'features': 14},
#             Current best combo with val score 0.3461:
#                     {'var_smoothing': 0.0001, 'features': 14}
# Trained and Tested combination 163 of 384, taking 0.01 seconds to get val score of 0.3265:
#                 {'var_smoothing': 0.0001, 'features': 13},
#             Current best combo with val score 0.3461:
#                     {'var_smoothing': 0.0001, 'features': 14}
# Already Trained and Tested combination (val score of 0.3444):
#             {'var_smoothing': 0.0001, 'features': 15}
#             Current best combo (with val score 0.3461):
#                     {'var_smoothing': 0.0001, 'features': 14}
#         Has trained 163 of 384 combinations so far
# % Combos Checked Thus Far: 163 out of 384 which is 42.447917000000004%
# Cruising Coordrdinate 28 of 33
#
# Cruising Coordrdinate 29 of 33
#
# Cruising Coordrdinate 30 of 33
#
# Cruise suspended due to suspicious case
# Guidance: round 17
#
# 	round 17 iteration:  0
#
# Trained and Tested combination 164 of 384, taking 0.01 seconds to get val score of 0.3438:
#                 {'var_smoothing': 0.0001, 'features': 25},
#             Current best combo with val score 0.3461:
#                     {'var_smoothing': 0.0001, 'features': 14}
# Trained and Tested combination 165 of 384, taking 0.01 seconds to get val score of 0.3219:
#                 {'var_smoothing': 1e-05, 'features': 24},
#             Current best combo with val score 0.3461:
#                     {'var_smoothing': 0.0001, 'features': 14}
# Trained and Tested combination 166 of 384, taking 0.01 seconds to get val score of 0.3203:
#                 {'var_smoothing': 1e-05, 'features': 26},
#             Current best combo with val score 0.3461:
#                     {'var_smoothing': 0.0001, 'features': 14}
# 	round 17 iteration:  1
#
# Already Trained and Tested combination (val score of 0.3216):
#             {'var_smoothing': 1e-05, 'features': 25}
#             Current best combo (with val score 0.3461):
#                     {'var_smoothing': 0.0001, 'features': 14}
#         Has trained 166 of 384 combinations so far
# Trained and Tested combination 167 of 384, taking 0.01 seconds to get val score of 0.2791:
#                 {'var_smoothing': 0.001, 'features': 25},
#             Current best combo with val score 0.3461:
#                     {'var_smoothing': 0.0001, 'features': 14}
# Trained and Tested combination 168 of 384, taking 0.01 seconds to get val score of 0.3495:
#                 {'var_smoothing': 0.0001, 'features': 24},
#             Current best combo with val score 0.3495:
#                     {'var_smoothing': 0.0001, 'features': 24}
# Trained and Tested combination 169 of 384, taking 0.01 seconds to get val score of 0.325:
#                 {'var_smoothing': 0.0001, 'features': 26},
#             Current best combo with val score 0.3495:
#                     {'var_smoothing': 0.0001, 'features': 24}
# Already Trained and Tested combination (val score of 0.3495):
#             {'var_smoothing': 0.0001, 'features': 24}
#             Current best combo (with val score 0.3495):
#                     {'var_smoothing': 0.0001, 'features': 24}
#         Has trained 169 of 384 combinations so far
# Trained and Tested combination 170 of 384, taking 0.01 seconds to get val score of 0.3209:
#                 {'var_smoothing': 1e-05, 'features': 23},
#             Current best combo with val score 0.3495:
#                     {'var_smoothing': 0.0001, 'features': 24}
# Already Trained and Tested combination (val score of 0.3216):
#             {'var_smoothing': 1e-05, 'features': 25}
#             Current best combo (with val score 0.3495):
#                     {'var_smoothing': 0.0001, 'features': 24}
#         Has trained 170 of 384 combinations so far
# Already Trained and Tested combination (val score of 0.325):
#             {'var_smoothing': 0.0001, 'features': 26}
#             Current best combo (with val score 0.3495):
#                     {'var_smoothing': 0.0001, 'features': 24}
#         Has trained 170 of 384 combinations so far
# Already Trained and Tested combination (val score of 0.3216):
#             {'var_smoothing': 1e-05, 'features': 25}
#             Current best combo (with val score 0.3495):
#                     {'var_smoothing': 0.0001, 'features': 24}
#         Has trained 170 of 384 combinations so far
# Trained and Tested combination 171 of 384, taking 0.01 seconds to get val score of 0.3199:
#                 {'var_smoothing': 1e-05, 'features': 27},
#             Current best combo with val score 0.3495:
#                     {'var_smoothing': 0.0001, 'features': 24}
# Already Trained and Tested combination (val score of 0.3219):
#             {'var_smoothing': 1e-05, 'features': 24}
#             Current best combo (with val score 0.3495):
#                     {'var_smoothing': 0.0001, 'features': 24}
#         Has trained 171 of 384 combinations so far
# Already Trained and Tested combination (val score of 0.242):
#             {'var_smoothing': 0.001, 'features': 24}
#             Current best combo (with val score 0.3495):
#                     {'var_smoothing': 0.0001, 'features': 24}
#         Has trained 171 of 384 combinations so far
# Trained and Tested combination 172 of 384, taking 0.01 seconds to get val score of 0.3477:
#                 {'var_smoothing': 0.0001, 'features': 23},
#             Current best combo with val score 0.3495:
#                     {'var_smoothing': 0.0001, 'features': 24}
# Already Trained and Tested combination (val score of 0.3438):
#             {'var_smoothing': 0.0001, 'features': 25}
#             Current best combo (with val score 0.3495):
#                     {'var_smoothing': 0.0001, 'features': 24}
#         Has trained 172 of 384 combinations so far
# % Combos Checked Thus Far: 172 out of 384 which is 44.791667000000004%
# Cruising Coordrdinate 31 of 33
#
# Cruising Coordrdinate 32 of 33
#
# Cruising Coordrdinate 33 of 33
#
# Cruise suspended due to suspicious case
# Guidance: round 18
#
# 	round 18 iteration:  0
#
# Trained and Tested combination 173 of 384, taking 0.01 seconds to get val score of 0.3438:
#                 {'var_smoothing': 0.0001, 'features': 20},
#             Current best combo with val score 0.3495:
#                     {'var_smoothing': 0.0001, 'features': 24}
# Trained and Tested combination 174 of 384, taking 0.01 seconds to get val score of 0.3205:
#                 {'var_smoothing': 1e-05, 'features': 19},
#             Current best combo with val score 0.3495:
#                     {'var_smoothing': 0.0001, 'features': 24}
# Trained and Tested combination 175 of 384, taking 0.01 seconds to get val score of 0.3206:
#                 {'var_smoothing': 1e-05, 'features': 21},
#             Current best combo with val score 0.3495:
#                     {'var_smoothing': 0.0001, 'features': 24}
# 	round 18 iteration:  1
#
# Already Trained and Tested combination (val score of 0.3211):
#             {'var_smoothing': 1e-05, 'features': 20}
#             Current best combo (with val score 0.3495):
#                     {'var_smoothing': 0.0001, 'features': 24}
#         Has trained 175 of 384 combinations so far
# Trained and Tested combination 176 of 384, taking 0.01 seconds to get val score of 0.2871:
#                 {'var_smoothing': 0.001, 'features': 20},
#             Current best combo with val score 0.3495:
#                     {'var_smoothing': 0.0001, 'features': 24}
# Trained and Tested combination 177 of 384, taking 0.01 seconds to get val score of 0.3278:
#                 {'var_smoothing': 0.0001, 'features': 19},
#             Current best combo with val score 0.3495:
#                     {'var_smoothing': 0.0001, 'features': 24}
# Trained and Tested combination 178 of 384, taking 0.01 seconds to get val score of 0.3492:
#                 {'var_smoothing': 0.0001, 'features': 21},
#             Current best combo with val score 0.3495:
#                     {'var_smoothing': 0.0001, 'features': 24}
# Already Trained and Tested combination (val score of 0.3278):
#             {'var_smoothing': 0.0001, 'features': 19}
#             Current best combo (with val score 0.3495):
#                     {'var_smoothing': 0.0001, 'features': 24}
#         Has trained 178 of 384 combinations so far
# Trained and Tested combination 179 of 384, taking 0.01 seconds to get val score of 0.3215:
#                 {'var_smoothing': 1e-05, 'features': 18},
#             Current best combo with val score 0.3495:
#                     {'var_smoothing': 0.0001, 'features': 24}
# Already Trained and Tested combination (val score of 0.3211):
#             {'var_smoothing': 1e-05, 'features': 20}
#             Current best combo (with val score 0.3495):
#                     {'var_smoothing': 0.0001, 'features': 24}
#         Has trained 179 of 384 combinations so far
# Already Trained and Tested combination (val score of 0.3492):
#             {'var_smoothing': 0.0001, 'features': 21}
#             Current best combo (with val score 0.3495):
#                     {'var_smoothing': 0.0001, 'features': 24}
#         Has trained 179 of 384 combinations so far
# Already Trained and Tested combination (val score of 0.3211):
#             {'var_smoothing': 1e-05, 'features': 20}
#             Current best combo (with val score 0.3495):
#                     {'var_smoothing': 0.0001, 'features': 24}
#         Has trained 179 of 384 combinations so far
# Trained and Tested combination 180 of 384, taking 0.01 seconds to get val score of 0.3213:
#                 {'var_smoothing': 1e-05, 'features': 22},
#             Current best combo with val score 0.3495:
#                     {'var_smoothing': 0.0001, 'features': 24}
# % Combos Checked Thus Far: 180 out of 384 which is 46.875%
# FINAL STAGE: Begin final Guidance system
#
#
# Guidance: round FINAL
#
# 	round FINAL iteration:  0
#
# Already Trained and Tested combination (val score of 0.3219):
#             {'var_smoothing': 1e-05, 'features': 24}
#             Current best combo (with val score 0.3495):
#                     {'var_smoothing': 0.0001, 'features': 24}
#         Has trained 180 of 384 combinations so far
# Already Trained and Tested combination (val score of 0.242):
#             {'var_smoothing': 0.001, 'features': 24}
#             Current best combo (with val score 0.3495):
#                     {'var_smoothing': 0.0001, 'features': 24}
#         Has trained 180 of 384 combinations so far
# Already Trained and Tested combination (val score of 0.3477):
#             {'var_smoothing': 0.0001, 'features': 23}
#             Current best combo (with val score 0.3495):
#                     {'var_smoothing': 0.0001, 'features': 24}
#         Has trained 180 of 384 combinations so far
# Already Trained and Tested combination (val score of 0.3438):
#             {'var_smoothing': 0.0001, 'features': 25}
#             Current best combo (with val score 0.3495):
#                     {'var_smoothing': 0.0001, 'features': 24}
#         Has trained 180 of 384 combinations so far
# 	round FINAL iteration:  1
#
# Already Trained and Tested combination (val score of 0.3209):
#             {'var_smoothing': 1e-05, 'features': 23}
#             Current best combo (with val score 0.3495):
#                     {'var_smoothing': 0.0001, 'features': 24}
#         Has trained 180 of 384 combinations so far
# Trained and Tested combination 181 of 384, taking 0.01 seconds to get val score of 0.2467:
#                 {'var_smoothing': 0.001, 'features': 23},
#             Current best combo with val score 0.3495:
#                     {'var_smoothing': 0.0001, 'features': 24}
# Trained and Tested combination 182 of 384, taking 0.01 seconds to get val score of 0.3444:
#                 {'var_smoothing': 0.0001, 'features': 22},
#             Current best combo with val score 0.3495:
#                     {'var_smoothing': 0.0001, 'features': 24}
# Already Trained and Tested combination (val score of 0.3495):
#             {'var_smoothing': 0.0001, 'features': 24}
#             Current best combo (with val score 0.3495):
#                     {'var_smoothing': 0.0001, 'features': 24}
#         Has trained 182 of 384 combinations so far
# % Combos Checked Thus Far: 182 out of 384 which is 47.395832999999996%
# Max Val Score:
#  0.349461
# Max Val Score Std:
#  0.034112
# Best Combo Train Score:
#  0.712132
# Best Combo Train Score Std:
#  0.003139
# Max Combo Index:
#  (1, 24) out of [8, 48] (note best combo is 0-indexed)
# Max Combo Hyperparamer Combination:
#  {'var_smoothing': 0.0001, 'features': 24}
# Max Combo Features:
#  ('procedure_224274', 'lods_score', 'procedure_224276', 'procedure_224267', 'race_AMERICAN INDIAN/ALASKA NATIVE', 'race_ASIAN', 'race_ASIAN - ASIAN INDIAN', 'race_ASIAN - CHINESE', 'race_ASIAN - KOREAN', 'race_ASIAN - SOUTH EAST ASIAN', 'race_BLACK/AFRICAN', 'race_BLACK/AFRICAN AMERICAN', 'race_BLACK/CAPE VERDEAN', 'race_BLACK/CARIBBEAN ISLAND', 'race_HISPANIC OR LATINO', 'race_HISPANIC/LATINO - CENTRAL AMERICAN', 'race_HISPANIC/LATINO - COLUMBIAN', 'race_HISPANIC/LATINO - CUBAN', 'race_HISPANIC/LATINO - DOMINICAN', 'race_HISPANIC/LATINO - GUATEMALAN', 'race_HISPANIC/LATINO - HONDURAN', 'race_HISPANIC/LATINO - MEXICAN', 'race_HISPANIC/LATINO - PUERTO RICAN', 'race_HISPANIC/LATINO - SALVADORAN', 'race_MULTIPLE RACE/ETHNICITY', 'race_NATIVE HAWAIIAN OR OTHER PACIFIC ISLANDER', 'race_OTHER', 'race_PATIENT DECLINED TO ANSWER', 'race_PORTUGUESE', 'race_SOUTH AMERICAN', 'race_UNABLE TO OBTAIN', 'race_WHITE', 'race_WHITE - BRAZILIAN', 'race_WHITE - EASTERN EUROPEAN', 'race_WHITE - OTHER EUROPEAN', 'race_WHITE - RUSSIAN', 'race_UNKNOWN', 'procedure_227712', 'procedure_225430', 'gender_F', 'gender_M', 'oasis_score', 'procedure_225446', 'procedure_224275', 'procedure_225802', 'hospital_stay_duration', 'procedure_226475', 'ventilation_used', 'procedure_224270', 'procedure_227194', 'icu_stay_duration', 'procedure_225400', 'procedure_221223', 'procedure_225792', 'unique_drugs', 'procedure_229351', 'glucose', 'item_51301')
# % Combos Checked: 182 out of 384 which is 47.395832999999996%
