# %% [markdown]
# # Tuning Script

# %%
# Parameters subject to change in every script - involved in naming

MODEL = 'svc(rbf)'
PREPROCESSING = 'normalise'
TUNER = 'yangzhoub'
OPTIMISED_METRIC = 'f1'

# %% [markdown]
# ---

# %%
# detect whether this is a google environment

COLAB_ENVIRONMENT = False

try:
    from google.colab import drive
    drive.mount('/content/drive')
    COLAB_ENVIRONMENT = True
except:
    pass
# Out:
# Mounted at /content/drive

# %%
import sys
import os
import pickle

if COLAB_ENVIRONMENT:
    home_directory = './drive/MyDrive/LAB/COMP90089__GroupWork__Py/' # my home directory is stored in ./LAB of google drive
    if MODEL == 'ebr':
        # !pip install interpret==0.5.0
    elif MODEL == 'cbr':
        # !pip install catboost
    elif MODEL in ['tf', 'mlp']:
        # !pip install PyTorch2Sklearn
    # !pip install JXAutoML
else:
    home_directory = '../../'

from JXAutoML.YangZhouB_10CV import YangZhouB_10CV as Tuner

import pandas as pd
# Out:
# Collecting JXAutoML
#   Downloading JXAutoML-0.4.4-py3-none-any.whl.metadata (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.2/67.2 kB 2.0 MB/s eta 0:00:00
# Downloading JXAutoML-0.4.4-py3-none-any.whl (52 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.1/52.1 kB 3.4 MB/s eta 0:00:00
# Installing collected packages: JXAutoML
# Successfully installed JXAutoML-0.4.4

# %%
# Parameters that are same for every script

FOLDS = 10  # we have decided to do 10 fold validation

SEED = 42

TASK_TYPE = 'Classification'  # this task is a classification task

# we have decided to tune features as hp
TUNE_FEATURES_AS_HYPERPARAMETERS = True

# %% [markdown]
# ---

# %%
# model to use to tune
from sklearn.svm import SVC as clf

# what values to try for each hyperparameter
parameter_choices = {
    'C': (0.0001, 0.001, 0.01, 0.1, 1, 10),
    'tol': (0.0001, 0.001, 0.01, 0.1, 1, 10),
    'max_iter': (50, 100, 200, 400, 800, 1600),
    'gamma': ('scale', 'auto')
}

# what values to set non-tuneable parameters/hyperparameters
non_tunable_hyperparameters_dict = {
                                    'verbose': False,
                                    'decision_function_shape': 'ovr',
                                    'random_state': 42,
                                    'kernel': 'rbf'
                                    }

# %% [markdown]
# ---

# %% [markdown]
# Read in and Prepare Data

# %%
# Import data and store as lists

train_x_list = []
train_y_list = []
val_x_list = []
val_y_list = []

for i in range(FOLDS):
    train_data = pd.read_csv(
        f'{home_directory}data/curated/modelling/{PREPROCESSING}/train_{i}.csv')
    val_data = pd.read_csv(
        f'{home_directory}data/curated/modelling/{PREPROCESSING}/val_{i}.csv')

    # get the correct rows for X and y
    train_x = train_data.drop(
        ['mortality_status', 'subject_id', 'hadm_id', 'stay_id'], axis=1)
    train_y = train_data['mortality_status']
    val_x = val_data.drop(
        ['mortality_status', 'subject_id', 'hadm_id', 'stay_id'], axis=1)
    val_y = val_data['mortality_status']

    train_x_list.append(train_x)
    train_y_list.append(train_y)
    val_x_list.append(val_x)
    val_y_list.append(val_y)

# %%
# Import feature importance ordering

with open(f'{home_directory}models/xgb_feature_importance_ordering_{PREPROCESSING}.pickle', 'rb') as f:
    feature_importance_ordering = pickle.load(f)

# %% [markdown]
# Set parameters

# %%
# initialisation
tuner = Tuner()

print('---')

# define what model we are tuning
tuner.read_in_model(clf, TASK_TYPE, optimised_metric=OPTIMISED_METRIC)

print('---')

# read in the data for training and validation
tuner.read_in_data(train_x_list, train_y_list, val_x_list, val_y_list)

print('---')

# set what hp values to tune
tuner.set_hyperparameters(parameter_choices)
# WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

# set up hp values that need to be changed from default but NOT to be tuned
tuner.set_non_tuneable_hyperparameters(non_tunable_hyperparameters_dict)

print('---')

# set up feature importance ordering

if TUNE_FEATURES_AS_HYPERPARAMETERS:
    tuner.set_features(feature_importance_ordering)
    # WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

try:  # try to read in previous results to continue tuning ...
    tuner.read_in_tuning_result_df(
        f'{home_directory}models/tuning/{TUNER}_{MODEL}_{PREPROCESSING}.csv')
except:
    print('No previous tuning data read in')

print('---')

# set up where to save the tuning result csv
tuner.set_tuning_result_saving_address(
    f'{home_directory}models/tuning/{TUNER}_{MODEL}_{PREPROCESSING}.csv')

print('---')

# set up where to save the current best model
tuner.set_best_model_saving_address(
    f'{home_directory}models/tmp_models/{TUNER}_{MODEL}_{PREPROCESSING}')
# Out:
# YangZhouB Initialised
# ---
# Successfully read in model <class 'sklearn.svm._classes.SVC'>, which is a Classification model optimising for f1
# ---
# Read in Train X data list
# Read in Train y data list
# Read in Val X data list
# Read in Val y data list
# ---
# Successfully recorded hyperparameter choices
# ---
# Successfully recorded non_tuneable_hyperparameter choices
# ---
# Successfully recorded tuneable feature combination choices and updated relevant internal structures
# ---
# No previous tuning data read in
# ---
# Successfully set tuning output address
# ---
# Successfully set best model output address

# %%
# ignore warnings

import warnings
warnings.filterwarnings("ignore")

# %%
# begin tuning ... (or continue training)

tuner.tune()
# Out:
# Streaming output truncated to the last 5000 lines.
#                     {'C': 0.0001, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 10}
# Trained and Tested combination 33 of 22032, taking 0.0 seconds to get val score of 0.3117:
#                 {'C': 0.0001, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 0},
#             Current best combo with val score 0.3328:
#                     {'C': 0.0001, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 10}
# Trained and Tested combination 34 of 22032, taking 0.0 seconds to get val score of 0.3117:
#                 {'C': 10, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 20},
#             Current best combo with val score 0.3328:
#                     {'C': 0.0001, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 10}
# Trained and Tested combination 35 of 22032, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 10, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 30},
#             Current best combo with val score 0.3328:
#                     {'C': 0.0001, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 10}
# Trained and Tested combination 36 of 22032, taking 0.0 seconds to get val score of 0.3117:
#                 {'C': 0.0001, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 10},
#             Current best combo with val score 0.3328:
#                     {'C': 0.0001, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 10}
# Trained and Tested combination 37 of 22032, taking 0.02 seconds to get val score of 0.2458:
#                 {'C': 10, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 20},
#             Current best combo with val score 0.3328:
#                     {'C': 0.0001, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 10}
# Trained and Tested combination 38 of 22032, taking 0.0 seconds to get val score of 0.3117:
#                 {'C': 0.0001, 'tol': 10, 'max_iter': 50, 'gamma': 'auto', 'features': 15},
#             Current best combo with val score 0.3328:
#                     {'C': 0.0001, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 10}
# Trained and Tested combination 39 of 22032, taking 0.29 seconds to get val score of 0.0:
#                 {'C': 10, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 20},
#             Current best combo with val score 0.3328:
#                     {'C': 0.0001, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 10}
# Trained and Tested combination 40 of 22032, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 0.0001, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 35},
#             Current best combo with val score 0.3328:
#                     {'C': 0.0001, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 10}
# Trained and Tested combination 41 of 22032, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 0.0001, 'tol': 10, 'max_iter': 50, 'gamma': 'scale', 'features': 20},
#             Current best combo with val score 0.3328:
#                     {'C': 0.0001, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 10}
# Trained and Tested combination 42 of 22032, taking 0.0 seconds to get val score of 0.3117:
#                 {'C': 10, 'tol': 10, 'max_iter': 50, 'gamma': 'auto', 'features': 25},
#             Current best combo with val score 0.3328:
#                     {'C': 0.0001, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 10}
# Trained and Tested combination 43 of 22032, taking 0.25 seconds to get val score of 0.2805:
#                 {'C': 10, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 40},
#             Current best combo with val score 0.3328:
#                     {'C': 0.0001, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 10}
# Trained and Tested combination 44 of 22032, taking 0.02 seconds to get val score of 0.2673:
#                 {'C': 0.0001, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 15},
#             Current best combo with val score 0.3328:
#                     {'C': 0.0001, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 10}
# Trained and Tested combination 45 of 22032, taking 0.22 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 50},
#             Current best combo with val score 0.3328:
#                     {'C': 0.0001, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 10}
# Trained and Tested combination 46 of 22032, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 10, 'tol': 10, 'max_iter': 1600, 'gamma': 'scale', 'features': 35},
#             Current best combo with val score 0.3328:
#                     {'C': 0.0001, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 10}
# Trained and Tested combination 47 of 22032, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 0.0001, 'tol': 10, 'max_iter': 50, 'gamma': 'scale', 'features': 10},
#             Current best combo with val score 0.3328:
#                     {'C': 0.0001, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 10}
# Trained and Tested combination 48 of 22032, taking 0.02 seconds to get val score of 0.0252:
#                 {'C': 10, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 20},
#             Current best combo with val score 0.3328:
#                     {'C': 0.0001, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 10}
# Trained and Tested combination 49 of 22032, taking 0.0 seconds to get val score of 0.3117:
#                 {'C': 10, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 15},
#             Current best combo with val score 0.3328:
#                     {'C': 0.0001, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 10}
# Trained and Tested combination 50 of 22032, taking 0.27 seconds to get val score of 0.3117:
#                 {'C': 10, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 45},
#             Current best combo with val score 0.3328:
#                     {'C': 0.0001, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 10}
# Trained and Tested combination 51 of 22032, taking 0.02 seconds to get val score of 0.0312:
#                 {'C': 10, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 35},
#             Current best combo with val score 0.3328:
#                     {'C': 0.0001, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 10}
# Trained and Tested combination 52 of 22032, taking 0.04 seconds to get val score of 0.0:
#                 {'C': 10, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 30},
#             Current best combo with val score 0.3328:
#                     {'C': 0.0001, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 10}
# Trained and Tested combination 53 of 22032, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 0.0001, 'tol': 10, 'max_iter': 1600, 'gamma': 'scale', 'features': 20},
#             Current best combo with val score 0.3328:
#                     {'C': 0.0001, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 10}
# Trained and Tested combination 54 of 22032, taking 0.0 seconds to get val score of 0.3117:
#                 {'C': 0.0001, 'tol': 10, 'max_iter': 50, 'gamma': 'scale', 'features': 0},
#             Current best combo with val score 0.3328:
#                     {'C': 0.0001, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 10}
# Trained and Tested combination 55 of 22032, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 10, 'tol': 10, 'max_iter': 1600, 'gamma': 'scale', 'features': 40},
#             Current best combo with val score 0.3328:
#                     {'C': 0.0001, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 10}
# Trained and Tested combination 56 of 22032, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 10, 'tol': 10, 'max_iter': 50, 'gamma': 'scale', 'features': 15},
#             Current best combo with val score 0.3328:
#                     {'C': 0.0001, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 10}
# Trained and Tested combination 57 of 22032, taking 0.02 seconds to get val score of 0.2438:
#                 {'C': 10, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 10},
#             Current best combo with val score 0.3328:
#                     {'C': 0.0001, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 10}
# Trained and Tested combination 58 of 22032, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 0.0001, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 20},
#             Current best combo with val score 0.3328:
#                     {'C': 0.0001, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 10}
# Trained and Tested combination 59 of 22032, taking 0.22 seconds to get val score of 0.0:
#                 {'C': 10, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 15},
#             Current best combo with val score 0.3328:
#                     {'C': 0.0001, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 10}
# Trained and Tested combination 60 of 22032, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 10, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 40},
#             Current best combo with val score 0.3328:
#                     {'C': 0.0001, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 10}
# Trained and Tested combination 61 of 22032, taking 0.02 seconds to get val score of 0.0308:
#                 {'C': 0.0001, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 25},
#             Current best combo with val score 0.3328:
#                     {'C': 0.0001, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 10}
# Trained and Tested combination 62 of 22032, taking 0.32 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 50},
#             Current best combo with val score 0.3328:
#                     {'C': 0.0001, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 10}
# Trained and Tested combination 63 of 22032, taking 0.03 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 45},
#             Current best combo with val score 0.3328:
#                     {'C': 0.0001, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 10}
# Trained and Tested combination 64 of 22032, taking 0.03 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 45},
#             Current best combo with val score 0.3328:
#                     {'C': 0.0001, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 10}
# Trained and Tested combination 65 of 22032, taking 0.01 seconds to get val score of 0.3225:
#                 {'C': 10, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 0},
#             Current best combo with val score 0.3328:
#                     {'C': 0.0001, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 10}
# Trained and Tested combination 66 of 22032, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 10, 'tol': 10, 'max_iter': 50, 'gamma': 'auto', 'features': 40},
#             Current best combo with val score 0.3328:
#                     {'C': 0.0001, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 10}
# Trained and Tested combination 67 of 22032, taking 0.0 seconds to get val score of 0.3117:
#                 {'C': 0.0001, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 15},
#             Current best combo with val score 0.3328:
#                     {'C': 0.0001, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 10}
# Trained and Tested combination 68 of 22032, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 0.0001, 'tol': 10, 'max_iter': 50, 'gamma': 'auto', 'features': 25},
#             Current best combo with val score 0.3328:
#                     {'C': 0.0001, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 10}
# Trained and Tested combination 69 of 22032, taking 0.0 seconds to get val score of 0.3117:
#                 {'C': 10, 'tol': 10, 'max_iter': 50, 'gamma': 'auto', 'features': 5},
#             Current best combo with val score 0.3328:
#                     {'C': 0.0001, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 10}
# Trained and Tested combination 70 of 22032, taking 0.02 seconds to get val score of 0.1882:
#                 {'C': 10, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 5},
#             Current best combo with val score 0.3328:
#                     {'C': 0.0001, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 10}
# Trained and Tested combination 71 of 22032, taking 0.31 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 35},
#             Current best combo with val score 0.3328:
#                     {'C': 0.0001, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 10}
# Trained and Tested combination 72 of 22032, taking 0.23 seconds to get val score of 0.0527:
#                 {'C': 10, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 30},
#             Current best combo with val score 0.3328:
#                     {'C': 0.0001, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 10}
# Trained and Tested combination 73 of 22032, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 10, 'tol': 10, 'max_iter': 50, 'gamma': 'auto', 'features': 50},
#             Current best combo with val score 0.3328:
#                     {'C': 0.0001, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 10}
# Trained and Tested combination 74 of 22032, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 10, 'tol': 10, 'max_iter': 1600, 'gamma': 'scale', 'features': 20},
#             Current best combo with val score 0.3328:
#                     {'C': 0.0001, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 10}
# Trained and Tested combination 75 of 22032, taking 0.19 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 20},
#             Current best combo with val score 0.3328:
#                     {'C': 0.0001, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 10}
# Trained and Tested combination 76 of 22032, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 10, 'tol': 10, 'max_iter': 50, 'gamma': 'auto', 'features': 45},
#             Current best combo with val score 0.3328:
#                     {'C': 0.0001, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 10}
# Trained and Tested combination 77 of 22032, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 0.0001, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 5},
#             Current best combo with val score 0.3328:
#                     {'C': 0.0001, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 10}
# Trained and Tested combination 78 of 22032, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 10, 'tol': 10, 'max_iter': 50, 'gamma': 'auto', 'features': 35},
#             Current best combo with val score 0.3328:
#                     {'C': 0.0001, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 10}
# Trained and Tested combination 79 of 22032, taking 0.2 seconds to get val score of 0.2824:
#                 {'C': 10, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 5},
#             Current best combo with val score 0.3328:
#                     {'C': 0.0001, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 10}
# Trained and Tested combination 80 of 22032, taking 0.02 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 35},
#             Current best combo with val score 0.3328:
#                     {'C': 0.0001, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 10}
# Trained and Tested combination 81 of 22032, taking 0.02 seconds to get val score of 0.3405:
#                 {'C': 10, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 10},
#             Current best combo with val score 0.3405:
#                     {'C': 10, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 10}
# Trained and Tested combination 82 of 22032, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 10, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 25},
#             Current best combo with val score 0.3405:
#                     {'C': 10, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 10}
# Trained and Tested combination 83 of 22032, taking 0.02 seconds to get val score of 0.0437:
#                 {'C': 0.0001, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 25},
#             Current best combo with val score 0.3405:
#                     {'C': 10, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 10}
# Trained and Tested combination 84 of 22032, taking 0.29 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10},
#             Current best combo with val score 0.3405:
#                     {'C': 10, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 10}
# Trained and Tested combination 85 of 22032, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 10, 'tol': 10, 'max_iter': 1600, 'gamma': 'scale', 'features': 30},
#             Current best combo with val score 0.3405:
#                     {'C': 10, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 10}
# Trained and Tested combination 86 of 22032, taking 0.22 seconds to get val score of 0.2805:
#                 {'C': 10, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 35},
#             Current best combo with val score 0.3405:
#                     {'C': 10, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 10}
# Trained and Tested combination 87 of 22032, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 10, 'tol': 10, 'max_iter': 50, 'gamma': 'auto', 'features': 30},
#             Current best combo with val score 0.3405:
#                     {'C': 10, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 10}
# Trained and Tested combination 88 of 22032, taking 0.11 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 0},
#             Current best combo with val score 0.3405:
#                     {'C': 10, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 10}
# Trained and Tested combination 89 of 22032, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 10, 'tol': 10, 'max_iter': 50, 'gamma': 'scale', 'features': 30},
#             Current best combo with val score 0.3405:
#                     {'C': 10, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 10}
# Trained and Tested combination 90 of 22032, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 0.0001, 'tol': 10, 'max_iter': 1600, 'gamma': 'scale', 'features': 50},
#             Current best combo with val score 0.3405:
#                     {'C': 10, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 10}
# Trained and Tested combination 91 of 22032, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 0.0001, 'tol': 10, 'max_iter': 50, 'gamma': 'scale', 'features': 50},
#             Current best combo with val score 0.3405:
#                     {'C': 10, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 10}
# Trained and Tested combination 92 of 22032, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 0.0001, 'tol': 10, 'max_iter': 50, 'gamma': 'auto', 'features': 40},
#             Current best combo with val score 0.3405:
#                     {'C': 10, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 10}
# Trained and Tested combination 93 of 22032, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 0.0001, 'tol': 10, 'max_iter': 50, 'gamma': 'scale', 'features': 45},
#             Current best combo with val score 0.3405:
#                     {'C': 10, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 10}
# Trained and Tested combination 94 of 22032, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 0.0001, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 30},
#             Current best combo with val score 0.3405:
#                     {'C': 10, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 10}
# Trained and Tested combination 95 of 22032, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 0.0001, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 50},
#             Current best combo with val score 0.3405:
#                     {'C': 10, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 10}
# Trained and Tested combination 96 of 22032, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 10, 'tol': 10, 'max_iter': 50, 'gamma': 'auto', 'features': 20},
#             Current best combo with val score 0.3405:
#                     {'C': 10, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 10}
# Trained and Tested combination 97 of 22032, taking 0.04 seconds to get val score of 0.3045:
#                 {'C': 0.0001, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 5},
#             Current best combo with val score 0.3405:
#                     {'C': 10, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 10}
# Trained and Tested combination 98 of 22032, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 0.0001, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 40},
#             Current best combo with val score 0.3405:
#                     {'C': 10, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 10}
# Trained and Tested combination 99 of 22032, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 10, 'tol': 10, 'max_iter': 1600, 'gamma': 'scale', 'features': 15},
#             Current best combo with val score 0.3405:
#                     {'C': 10, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 10}
# Trained and Tested combination 100 of 22032, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 10, 'tol': 10, 'max_iter': 50, 'gamma': 'scale', 'features': 50},
#             Current best combo with val score 0.3405:
#                     {'C': 10, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 10}
# Trained and Tested combination 101 of 22032, taking 0.0 seconds to get val score of 0.3117:
#                 {'C': 10, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 10},
#             Current best combo with val score 0.3405:
#                     {'C': 10, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 10}
# Trained and Tested combination 102 of 22032, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 10, 'tol': 10, 'max_iter': 50, 'gamma': 'scale', 'features': 40},
#             Current best combo with val score 0.3405:
#                     {'C': 10, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 10}
# Trained and Tested combination 103 of 22032, taking 0.2 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 25},
#             Current best combo with val score 0.3405:
#                     {'C': 10, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 10}
# Trained and Tested combination 104 of 22032, taking 0.02 seconds to get val score of 0.3488:
#                 {'C': 0.0001, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 20},
#             Current best combo with val score 0.3488:
#                     {'C': 0.0001, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 20}
# Trained and Tested combination 105 of 22032, taking 0.31 seconds to get val score of 0.4231:
#                 {'C': 10, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10},
#             Current best combo with val score 0.4231:
#                     {'C': 10, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
# Trained and Tested combination 106 of 22032, taking 0.11 seconds to get val score of 0.0:
#                 {'C': 10, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 0},
#             Current best combo with val score 0.4231:
#                     {'C': 10, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
# Trained and Tested combination 107 of 22032, taking 0.0 seconds to get val score of 0.3117:
#                 {'C': 0.0001, 'tol': 10, 'max_iter': 1600, 'gamma': 'scale', 'features': 5},
#             Current best combo with val score 0.4231:
#                     {'C': 10, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
# Trained and Tested combination 108 of 22032, taking 0.21 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 35},
#             Current best combo with val score 0.4231:
#                     {'C': 10, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
# Trained and Tested combination 109 of 22032, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 0.0001, 'tol': 10, 'max_iter': 1600, 'gamma': 'scale', 'features': 40},
#             Current best combo with val score 0.4231:
#                     {'C': 10, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
# Trained and Tested combination 110 of 22032, taking 0.04 seconds to get val score of 0.0:
#                 {'C': 10, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 40},
#             Current best combo with val score 0.4231:
#                     {'C': 10, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
# Trained and Tested combination 111 of 22032, taking 0.24 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 40},
#             Current best combo with val score 0.4231:
#                     {'C': 10, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
# Trained and Tested combination 112 of 22032, taking 0.02 seconds to get val score of 0.0:
#                 {'C': 10, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 15},
#             Current best combo with val score 0.4231:
#                     {'C': 10, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
# Trained and Tested combination 113 of 22032, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 0.0001, 'tol': 10, 'max_iter': 50, 'gamma': 'scale', 'features': 15},
#             Current best combo with val score 0.4231:
#                     {'C': 10, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
# Trained and Tested combination 114 of 22032, taking 0.01 seconds to get val score of 0.3251:
#                 {'C': 10, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 0},
#             Current best combo with val score 0.4231:
#                     {'C': 10, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
# Trained and Tested combination 115 of 22032, taking 0.29 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 15},
#             Current best combo with val score 0.4231:
#                     {'C': 10, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
# Trained and Tested combination 116 of 22032, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 10, 'tol': 10, 'max_iter': 50, 'gamma': 'scale', 'features': 20},
#             Current best combo with val score 0.4231:
#                     {'C': 10, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
# Trained and Tested combination 117 of 22032, taking 0.03 seconds to get val score of 0.2949:
#                 {'C': 10, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 5},
#             Current best combo with val score 0.4231:
#                     {'C': 10, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
# Trained and Tested combination 118 of 22032, taking 0.04 seconds to get val score of 0.0:
#                 {'C': 10, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 40},
#             Current best combo with val score 0.4231:
#                     {'C': 10, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
# Trained and Tested combination 119 of 22032, taking 0.22 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 40},
#             Current best combo with val score 0.4231:
#                     {'C': 10, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
# Trained and Tested combination 120 of 22032, taking 0.11 seconds to get val score of 0.0:
#                 {'C': 10, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 0},
#             Current best combo with val score 0.4231:
#                     {'C': 10, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
# Trained and Tested combination 121 of 22032, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 0.0001, 'tol': 10, 'max_iter': 1600, 'gamma': 'scale', 'features': 30},
#             Current best combo with val score 0.4231:
#                     {'C': 10, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
# Trained and Tested combination 122 of 22032, taking 0.19 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 20},
#             Current best combo with val score 0.4231:
#                     {'C': 10, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
# Trained and Tested combination 123 of 22032, taking 0.19 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 5},
#             Current best combo with val score 0.4231:
#                     {'C': 10, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
# Trained and Tested combination 124 of 22032, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 0.0001, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 45},
#             Current best combo with val score 0.4231:
#                     {'C': 10, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
# Trained and Tested combination 125 of 22032, taking 0.25 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 45},
#             Current best combo with val score 0.4231:
#                     {'C': 10, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
# Trained and Tested combination 126 of 22032, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 10, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 5},
#             Current best combo with val score 0.4231:
#                     {'C': 10, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
# Trained and Tested combination 127 of 22032, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 0.0001, 'tol': 10, 'max_iter': 50, 'gamma': 'scale', 'features': 30},
#             Current best combo with val score 0.4231:
#                     {'C': 10, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
# Trained and Tested combination 128 of 22032, taking 0.02 seconds to get val score of 0.0373:
#                 {'C': 0.0001, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 15},
#             Current best combo with val score 0.4231:
#                     {'C': 10, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
# Trained and Tested combination 129 of 22032, taking 0.19 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 10},
#             Current best combo with val score 0.4231:
#                     {'C': 10, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
# Trained and Tested combination 130 of 22032, taking 0.31 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 25},
#             Current best combo with val score 0.4231:
#                     {'C': 10, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
# Trained and Tested combination 131 of 22032, taking 0.0 seconds to get val score of 0.3117:
#                 {'C': 0.0001, 'tol': 10, 'max_iter': 50, 'gamma': 'auto', 'features': 5},
#             Current best combo with val score 0.4231:
#                     {'C': 10, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
# Trained and Tested combination 132 of 22032, taking 0.2 seconds to get val score of 0.0:
#                 {'C': 10, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 15},
#             Current best combo with val score 0.4231:
#                     {'C': 10, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
# Trained and Tested combination 133 of 22032, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 10, 'tol': 10, 'max_iter': 50, 'gamma': 'scale', 'features': 10},
#             Current best combo with val score 0.4231:
#                     {'C': 10, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
# Trained and Tested combination 134 of 22032, taking 0.03 seconds to get val score of 0.0:
#                 {'C': 10, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 45},
#             Current best combo with val score 0.4231:
#                     {'C': 10, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
# Trained and Tested combination 135 of 22032, taking 0.4 seconds to get val score of 0.0:
#                 {'C': 10, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 30},
#             Current best combo with val score 0.4231:
#                     {'C': 10, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
# Trained and Tested combination 136 of 22032, taking 0.2 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 5},
#             Current best combo with val score 0.4231:
#                     {'C': 10, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
# Trained and Tested combination 137 of 22032, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 0.0001, 'tol': 10, 'max_iter': 50, 'gamma': 'auto', 'features': 50},
#             Current best combo with val score 0.4231:
#                     {'C': 10, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
# Trained and Tested combination 138 of 22032, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 10, 'tol': 10, 'max_iter': 1600, 'gamma': 'scale', 'features': 45},
#             Current best combo with val score 0.4231:
#                     {'C': 10, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
# Trained and Tested combination 139 of 22032, taking 0.37 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 30},
#             Current best combo with val score 0.4231:
#                     {'C': 10, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
# Trained and Tested combination 140 of 22032, taking 0.02 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 30},
#             Current best combo with val score 0.4231:
#                     {'C': 10, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
# Trained and Tested combination 141 of 22032, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 10, 'tol': 10, 'max_iter': 50, 'gamma': 'scale', 'features': 35},
#             Current best combo with val score 0.4231:
#                     {'C': 10, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
# Trained and Tested combination 142 of 22032, taking 0.2 seconds to get val score of 0.4111:
#                 {'C': 10, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 5},
#             Current best combo with val score 0.4231:
#                     {'C': 10, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
# Trained and Tested combination 143 of 22032, taking 0.01 seconds to get val score of 0.3338:
#                 {'C': 0.0001, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 0},
#             Current best combo with val score 0.4231:
#                     {'C': 10, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
# Trained and Tested combination 144 of 22032, taking 0.41 seconds to get val score of 0.0:
#                 {'C': 10, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 50},
#             Current best combo with val score 0.4231:
#                     {'C': 10, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
# Trained and Tested combination 145 of 22032, taking 0.24 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 45},
#             Current best combo with val score 0.4231:
#                     {'C': 10, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
# Trained and Tested combination 146 of 22032, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 10, 'tol': 10, 'max_iter': 1600, 'gamma': 'scale', 'features': 50},
#             Current best combo with val score 0.4231:
#                     {'C': 10, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
# Trained and Tested combination 147 of 22032, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 0.0001, 'tol': 10, 'max_iter': 1600, 'gamma': 'scale', 'features': 15},
#             Current best combo with val score 0.4231:
#                     {'C': 10, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
# Trained and Tested combination 148 of 22032, taking 0.33 seconds to get val score of 0.0082:
#                 {'C': 10, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 25},
#             Current best combo with val score 0.4231:
#                     {'C': 10, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
# Trained and Tested combination 149 of 22032, taking 0.2 seconds to get val score of 0.0033:
#                 {'C': 10, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 20},
#             Current best combo with val score 0.4231:
#                     {'C': 10, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
# Trained and Tested combination 150 of 22032, taking 0.03 seconds to get val score of 0.0:
#                 {'C': 10, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 45},
#             Current best combo with val score 0.4231:
#                     {'C': 10, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
# Trained and Tested combination 151 of 22032, taking 0.02 seconds to get val score of 0.0:
#                 {'C': 10, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 50},
#             Current best combo with val score 0.4231:
#                     {'C': 10, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
# Trained and Tested combination 152 of 22032, taking 0.27 seconds to get val score of 0.0:
#                 {'C': 10, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 40},
#             Current best combo with val score 0.4231:
#                     {'C': 10, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
# Trained and Tested combination 153 of 22032, taking 0.0 seconds to get val score of 0.3117:
#                 {'C': 0.0001, 'tol': 10, 'max_iter': 50, 'gamma': 'scale', 'features': 5},
#             Current best combo with val score 0.4231:
#                     {'C': 10, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
# Trained and Tested combination 154 of 22032, taking 0.02 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 50},
#             Current best combo with val score 0.4231:
#                     {'C': 10, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
# Trained and Tested combination 155 of 22032, taking 0.21 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 15},
#             Current best combo with val score 0.4231:
#                     {'C': 10, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
# Trained and Tested combination 156 of 22032, taking 0.02 seconds to get val score of 0.3282:
#                 {'C': 0.0001, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 5},
#             Current best combo with val score 0.4231:
#                     {'C': 10, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
# Trained and Tested combination 157 of 22032, taking 0.0 seconds to get val score of 0.3117:
#                 {'C': 10, 'tol': 10, 'max_iter': 1600, 'gamma': 'scale', 'features': 0},
#             Current best combo with val score 0.4231:
#                     {'C': 10, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
# Trained and Tested combination 158 of 22032, taking 0.02 seconds to get val score of 0.0:
#                 {'C': 10, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 35},
#             Current best combo with val score 0.4231:
#                     {'C': 10, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
# Trained and Tested combination 159 of 22032, taking 0.2 seconds to get val score of 0.3454:
#                 {'C': 10, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 10},
#             Current best combo with val score 0.4231:
#                     {'C': 10, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
# Trained and Tested combination 160 of 22032, taking 0.0 seconds to get val score of 0.3117:
#                 {'C': 10, 'tol': 10, 'max_iter': 50, 'gamma': 'auto', 'features': 10},
#             Current best combo with val score 0.4231:
#                     {'C': 10, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
# Trained and Tested combination 161 of 22032, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 0.0001, 'tol': 10, 'max_iter': 50, 'gamma': 'auto', 'features': 20},
#             Current best combo with val score 0.4231:
#                     {'C': 10, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
# Trained and Tested combination 162 of 22032, taking 0.0 seconds to get val score of 0.3117:
#                 {'C': 10, 'tol': 10, 'max_iter': 1600, 'gamma': 'scale', 'features': 5},
#             Current best combo with val score 0.4231:
#                     {'C': 10, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
# Trained and Tested combination 163 of 22032, taking 0.02 seconds to get val score of 0.0378:
#                 {'C': 0.0001, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 20},
#             Current best combo with val score 0.4231:
#                     {'C': 10, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
# Trained and Tested combination 164 of 22032, taking 0.23 seconds to get val score of 0.2805:
#                 {'C': 10, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 50},
#             Current best combo with val score 0.4231:
#                     {'C': 10, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
# Trained and Tested combination 165 of 22032, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 0.0001, 'tol': 10, 'max_iter': 50, 'gamma': 'scale', 'features': 40},
#             Current best combo with val score 0.4231:
#                     {'C': 10, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
# Trained and Tested combination 166 of 22032, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 10, 'tol': 10, 'max_iter': 1600, 'gamma': 'scale', 'features': 25},
#             Current best combo with val score 0.4231:
#                     {'C': 10, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
# Trained and Tested combination 167 of 22032, taking 0.24 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 30},
#             Current best combo with val score 0.4231:
#                     {'C': 10, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
# Trained and Tested combination 168 of 22032, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 10, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 35},
#             Current best combo with val score 0.4231:
#                     {'C': 10, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
# Trained and Tested combination 169 of 22032, taking 0.21 seconds to get val score of 0.0067:
#                 {'C': 10, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 25},
#             Current best combo with val score 0.4231:
#                     {'C': 10, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
# Trained and Tested combination 170 of 22032, taking 0.02 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 50},
#             Current best combo with val score 0.4231:
#                     {'C': 10, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
# Trained and Tested combination 171 of 22032, taking 0.03 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 35},
#             Current best combo with val score 0.4231:
#                     {'C': 10, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
# Trained and Tested combination 172 of 22032, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 10, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 50},
#             Current best combo with val score 0.4231:
#                     {'C': 10, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
# Trained and Tested combination 173 of 22032, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 10, 'tol': 10, 'max_iter': 50, 'gamma': 'scale', 'features': 5},
#             Current best combo with val score 0.4231:
#                     {'C': 10, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
# Trained and Tested combination 174 of 22032, taking 0.01 seconds to get val score of 0.3117:
# ...
#                     {'C': 10, 'tol': 1, 'max_iter': 1600, 'gamma': 'scale', 'features': 6}
#         Has trained 695 of 22032 combinations so far
# % Combos Checked Thus Far: 695 out of 22032 which is 3.154503%
# Cruising Coordrdinate 166 of 176
#
# Cruising Coordrdinate 167 of 176
#
# Cruising Coordrdinate 168 of 176
#
# Cruising Coordrdinate 169 of 176
#
# Cruising Coordrdinate 170 of 176
#
# Cruising Coordrdinate 171 of 176
#
# Cruising Coordrdinate 172 of 176
#
# Cruise suspended due to suspicious case
# Guidance: round 43
#
# 	round 43 iteration:  0
#
# Trained and Tested combination 696 of 22032, taking 0.18 seconds to get val score of 0.0563:
#                 {'C': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 10},
#             Current best combo with val score 0.4642:
#                     {'C': 10, 'tol': 1, 'max_iter': 1600, 'gamma': 'scale', 'features': 6}
# Trained and Tested combination 697 of 22032, taking 0.18 seconds to get val score of 0.3454:
#                 {'C': 10, 'tol': 0.001, 'max_iter': 1600, 'gamma': 'auto', 'features': 10},
#             Current best combo with val score 0.4642:
#                     {'C': 10, 'tol': 1, 'max_iter': 1600, 'gamma': 'scale', 'features': 6}
# Trained and Tested combination 698 of 22032, taking 0.17 seconds to get val score of 0.3498:
#                 {'C': 10, 'tol': 0.0001, 'max_iter': 800, 'gamma': 'auto', 'features': 10},
#             Current best combo with val score 0.4642:
#                     {'C': 10, 'tol': 1, 'max_iter': 1600, 'gamma': 'scale', 'features': 6}
# Already Trained and Tested combination (val score of 0.4231):
#             {'C': 10, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
#             Current best combo (with val score 0.4642):
#                     {'C': 10, 'tol': 1, 'max_iter': 1600, 'gamma': 'scale', 'features': 6}
#         Has trained 698 of 22032 combinations so far
# Trained and Tested combination 699 of 22032, taking 0.18 seconds to get val score of 0.3415:
#                 {'C': 10, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 9},
#             Current best combo with val score 0.4642:
#                     {'C': 10, 'tol': 1, 'max_iter': 1600, 'gamma': 'scale', 'features': 6}
# Trained and Tested combination 700 of 22032, taking 0.18 seconds to get val score of 0.0033:
#                 {'C': 10, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 11},
#             Current best combo with val score 0.4642:
#                     {'C': 10, 'tol': 1, 'max_iter': 1600, 'gamma': 'scale', 'features': 6}
# 	round 43 iteration:  1
#
# Trained and Tested combination 701 of 22032, taking 0.18 seconds to get val score of 0.0563:
#                 {'C': 1, 'tol': 0.001, 'max_iter': 1600, 'gamma': 'auto', 'features': 10},
#             Current best combo with val score 0.4642:
#                     {'C': 10, 'tol': 1, 'max_iter': 1600, 'gamma': 'scale', 'features': 6}
# Already Trained and Tested combination (val score of 0.3454):
#             {'C': 10, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 10}
#             Current best combo (with val score 0.4642):
#                     {'C': 10, 'tol': 1, 'max_iter': 1600, 'gamma': 'scale', 'features': 6}
#         Has trained 701 of 22032 combinations so far
# Trained and Tested combination 702 of 22032, taking 0.18 seconds to get val score of 0.3423:
#                 {'C': 10, 'tol': 0.01, 'max_iter': 1600, 'gamma': 'auto', 'features': 10},
#             Current best combo with val score 0.4642:
#                     {'C': 10, 'tol': 1, 'max_iter': 1600, 'gamma': 'scale', 'features': 6}
# Trained and Tested combination 703 of 22032, taking 0.26 seconds to get val score of 0.3498:
#                 {'C': 10, 'tol': 0.001, 'max_iter': 800, 'gamma': 'auto', 'features': 10},
#             Current best combo with val score 0.4642:
#                     {'C': 10, 'tol': 1, 'max_iter': 1600, 'gamma': 'scale', 'features': 6}
# Trained and Tested combination 704 of 22032, taking 0.2 seconds to get val score of 0.4231:
#                 {'C': 10, 'tol': 0.001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10},
#             Current best combo with val score 0.4642:
#                     {'C': 10, 'tol': 1, 'max_iter': 1600, 'gamma': 'scale', 'features': 6}
# Trained and Tested combination 705 of 22032, taking 0.18 seconds to get val score of 0.3415:
#                 {'C': 10, 'tol': 0.001, 'max_iter': 1600, 'gamma': 'auto', 'features': 9},
#             Current best combo with val score 0.4642:
#                     {'C': 10, 'tol': 1, 'max_iter': 1600, 'gamma': 'scale', 'features': 6}
# Trained and Tested combination 706 of 22032, taking 0.29 seconds to get val score of 0.0033:
#                 {'C': 10, 'tol': 0.001, 'max_iter': 1600, 'gamma': 'auto', 'features': 11},
#             Current best combo with val score 0.4642:
#                     {'C': 10, 'tol': 1, 'max_iter': 1600, 'gamma': 'scale', 'features': 6}
# Trained and Tested combination 707 of 22032, taking 0.17 seconds to get val score of 0.0563:
#                 {'C': 1, 'tol': 0.0001, 'max_iter': 800, 'gamma': 'auto', 'features': 10},
#             Current best combo with val score 0.4642:
#                     {'C': 10, 'tol': 1, 'max_iter': 1600, 'gamma': 'scale', 'features': 6}
# Already Trained and Tested combination (val score of 0.3498):
#             {'C': 10, 'tol': 0.001, 'max_iter': 800, 'gamma': 'auto', 'features': 10}
#             Current best combo (with val score 0.4642):
#                     {'C': 10, 'tol': 1, 'max_iter': 1600, 'gamma': 'scale', 'features': 6}
#         Has trained 707 of 22032 combinations so far
# Trained and Tested combination 708 of 22032, taking 0.13 seconds to get val score of 0.3967:
#                 {'C': 10, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'auto', 'features': 10},
#             Current best combo with val score 0.4642:
#                     {'C': 10, 'tol': 1, 'max_iter': 1600, 'gamma': 'scale', 'features': 6}
# Already Trained and Tested combination (val score of 0.3454):
#             {'C': 10, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 10}
#             Current best combo (with val score 0.4642):
#                     {'C': 10, 'tol': 1, 'max_iter': 1600, 'gamma': 'scale', 'features': 6}
#         Has trained 708 of 22032 combinations so far
# Trained and Tested combination 709 of 22032, taking 0.24 seconds to get val score of 0.4502:
#                 {'C': 10, 'tol': 0.0001, 'max_iter': 800, 'gamma': 'scale', 'features': 10},
#             Current best combo with val score 0.4642:
#                     {'C': 10, 'tol': 1, 'max_iter': 1600, 'gamma': 'scale', 'features': 6}
# Trained and Tested combination 710 of 22032, taking 0.16 seconds to get val score of 0.3394:
#                 {'C': 10, 'tol': 0.0001, 'max_iter': 800, 'gamma': 'auto', 'features': 9},
#             Current best combo with val score 0.4642:
#                     {'C': 10, 'tol': 1, 'max_iter': 1600, 'gamma': 'scale', 'features': 6}
# Trained and Tested combination 711 of 22032, taking 0.17 seconds to get val score of 0.01:
#                 {'C': 10, 'tol': 0.0001, 'max_iter': 800, 'gamma': 'auto', 'features': 11},
#             Current best combo with val score 0.4642:
#                     {'C': 10, 'tol': 1, 'max_iter': 1600, 'gamma': 'scale', 'features': 6}
# Trained and Tested combination 712 of 22032, taking 0.19 seconds to get val score of 0.2893:
#                 {'C': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10},
#             Current best combo with val score 0.4642:
#                     {'C': 10, 'tol': 1, 'max_iter': 1600, 'gamma': 'scale', 'features': 6}
# Already Trained and Tested combination (val score of 0.4231):
#             {'C': 10, 'tol': 0.001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
#             Current best combo (with val score 0.4642):
#                     {'C': 10, 'tol': 1, 'max_iter': 1600, 'gamma': 'scale', 'features': 6}
#         Has trained 712 of 22032 combinations so far
# Already Trained and Tested combination (val score of 0.4502):
#             {'C': 10, 'tol': 0.0001, 'max_iter': 800, 'gamma': 'scale', 'features': 10}
#             Current best combo (with val score 0.4642):
#                     {'C': 10, 'tol': 1, 'max_iter': 1600, 'gamma': 'scale', 'features': 6}
#         Has trained 712 of 22032 combinations so far
# Already Trained and Tested combination (val score of 0.3454):
#             {'C': 10, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 10}
#             Current best combo (with val score 0.4642):
#                     {'C': 10, 'tol': 1, 'max_iter': 1600, 'gamma': 'scale', 'features': 6}
#         Has trained 712 of 22032 combinations so far
# Trained and Tested combination 713 of 22032, taking 0.19 seconds to get val score of 0.4289:
#                 {'C': 10, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 9},
#             Current best combo with val score 0.4642:
#                     {'C': 10, 'tol': 1, 'max_iter': 1600, 'gamma': 'scale', 'features': 6}
# Trained and Tested combination 714 of 22032, taking 0.31 seconds to get val score of 0.0:
#                 {'C': 10, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 11},
#             Current best combo with val score 0.4642:
#                     {'C': 10, 'tol': 1, 'max_iter': 1600, 'gamma': 'scale', 'features': 6}
# Trained and Tested combination 715 of 22032, taking 0.18 seconds to get val score of 0.0657:
#                 {'C': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 9},
#             Current best combo with val score 0.4642:
#                     {'C': 10, 'tol': 1, 'max_iter': 1600, 'gamma': 'scale', 'features': 6}
# Already Trained and Tested combination (val score of 0.3415):
#             {'C': 10, 'tol': 0.001, 'max_iter': 1600, 'gamma': 'auto', 'features': 9}
#             Current best combo (with val score 0.4642):
#                     {'C': 10, 'tol': 1, 'max_iter': 1600, 'gamma': 'scale', 'features': 6}
#         Has trained 715 of 22032 combinations so far
# Already Trained and Tested combination (val score of 0.3394):
#             {'C': 10, 'tol': 0.0001, 'max_iter': 800, 'gamma': 'auto', 'features': 9}
#             Current best combo (with val score 0.4642):
#                     {'C': 10, 'tol': 1, 'max_iter': 1600, 'gamma': 'scale', 'features': 6}
#         Has trained 715 of 22032 combinations so far
# Already Trained and Tested combination (val score of 0.4289):
#             {'C': 10, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 9}
#             Current best combo (with val score 0.4642):
#                     {'C': 10, 'tol': 1, 'max_iter': 1600, 'gamma': 'scale', 'features': 6}
#         Has trained 715 of 22032 combinations so far
# Trained and Tested combination 716 of 22032, taking 0.21 seconds to get val score of 0.3039:
#                 {'C': 10, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 8},
#             Current best combo with val score 0.4642:
#                     {'C': 10, 'tol': 1, 'max_iter': 1600, 'gamma': 'scale', 'features': 6}
# Already Trained and Tested combination (val score of 0.3454):
#             {'C': 10, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 10}
#             Current best combo (with val score 0.4642):
#                     {'C': 10, 'tol': 1, 'max_iter': 1600, 'gamma': 'scale', 'features': 6}
#         Has trained 716 of 22032 combinations so far
# % Combos Checked Thus Far: 716 out of 22032 which is 3.2498180000000003%
# Cruising Coordrdinate 173 of 176
#
# Cruise suspended due to suspicious case
# Guidance: round 44
#
# 	round 44 iteration:  0
#
# % Combos Checked Thus Far: 716 out of 22032 which is 3.2498180000000003%
# Cruising Coordrdinate 174 of 176
#
# Cruising Coordrdinate 175 of 176
#
# Cruising Coordrdinate 176 of 176
#
# FINAL STAGE: Begin final Guidance system
#
#
# Guidance: round FINAL
#
# 	round FINAL iteration:  0
#
# Already Trained and Tested combination (val score of 0.3127):
#             {'C': 1, 'tol': 1, 'max_iter': 1600, 'gamma': 'scale', 'features': 6}
#             Current best combo (with val score 0.4642):
#                     {'C': 10, 'tol': 1, 'max_iter': 1600, 'gamma': 'scale', 'features': 6}
#         Has trained 716 of 22032 combinations so far
# Already Trained and Tested combination (val score of 0.4146):
#             {'C': 10, 'tol': 0.1, 'max_iter': 1600, 'gamma': 'scale', 'features': 6}
#             Current best combo (with val score 0.4642):
#                     {'C': 10, 'tol': 1, 'max_iter': 1600, 'gamma': 'scale', 'features': 6}
#         Has trained 716 of 22032 combinations so far
# Already Trained and Tested combination (val score of 0.3117):
#             {'C': 10, 'tol': 10, 'max_iter': 1600, 'gamma': 'scale', 'features': 6}
#             Current best combo (with val score 0.4642):
#                     {'C': 10, 'tol': 1, 'max_iter': 1600, 'gamma': 'scale', 'features': 6}
#         Has trained 716 of 22032 combinations so far
# Already Trained and Tested combination (val score of 0.4443):
#             {'C': 10, 'tol': 1, 'max_iter': 800, 'gamma': 'scale', 'features': 6}
#             Current best combo (with val score 0.4642):
#                     {'C': 10, 'tol': 1, 'max_iter': 1600, 'gamma': 'scale', 'features': 6}
#         Has trained 716 of 22032 combinations so far
# Already Trained and Tested combination (val score of 0.1988):
#             {'C': 10, 'tol': 1, 'max_iter': 1600, 'gamma': 'auto', 'features': 6}
#             Current best combo (with val score 0.4642):
#                     {'C': 10, 'tol': 1, 'max_iter': 1600, 'gamma': 'scale', 'features': 6}
#         Has trained 716 of 22032 combinations so far
# Already Trained and Tested combination (val score of 0.4218):
#             {'C': 10, 'tol': 1, 'max_iter': 1600, 'gamma': 'scale', 'features': 5}
#             Current best combo (with val score 0.4642):
#                     {'C': 10, 'tol': 1, 'max_iter': 1600, 'gamma': 'scale', 'features': 6}
#         Has trained 716 of 22032 combinations so far
# Already Trained and Tested combination (val score of 0.4354):
#             {'C': 10, 'tol': 1, 'max_iter': 1600, 'gamma': 'scale', 'features': 7}
#             Current best combo (with val score 0.4642):
#                     {'C': 10, 'tol': 1, 'max_iter': 1600, 'gamma': 'scale', 'features': 6}
#         Has trained 716 of 22032 combinations so far
# % Combos Checked Thus Far: 716 out of 22032 which is 3.2498180000000003%
# Max Val Score:
#  0.464239
# Max Val Score Std:
#  0.07022
# Best Combo Train Score:
#  0.645297
# Best Combo Train Score Std:
#  0.006012
# Max Combo Index:
#  (5, 4, 5, 1, 6) out of [6, 6, 6, 2, 51] (note best combo is 0-indexed)
# Max Combo Hyperparamer Combination:
#  {'C': 10, 'tol': 1, 'max_iter': 1600, 'gamma': 'scale', 'features': 6}
# Max Combo Features:
#  ('procedure_225792', 'ventilation_used', 'lods_score', 'race_AMERICAN INDIAN/ALASKA NATIVE', 'race_ASIAN', 'race_ASIAN - ASIAN INDIAN', 'race_ASIAN - CHINESE', 'race_ASIAN - KOREAN', 'race_ASIAN - SOUTH EAST ASIAN', 'race_BLACK/AFRICAN', 'race_BLACK/AFRICAN AMERICAN', 'race_BLACK/CAPE VERDEAN', 'race_BLACK/CARIBBEAN ISLAND', 'race_HISPANIC/LATINO - CENTRAL AMERICAN', 'race_HISPANIC/LATINO - COLUMBIAN', 'race_HISPANIC/LATINO - CUBAN', 'race_HISPANIC/LATINO - DOMINICAN', 'race_HISPANIC/LATINO - GUATEMALAN', 'race_HISPANIC/LATINO - HONDURAN', 'race_HISPANIC/LATINO - MEXICAN', 'race_HISPANIC/LATINO - PUERTO RICAN', 'race_HISPANIC/LATINO - SALVADORAN', 'race_MULTIPLE RACE/ETHNICITY', 'race_NATIVE HAWAIIAN OR OTHER PACIFIC ISLANDER', 'race_OTHER', 'race_PATIENT DECLINED TO ANSWER', 'race_PORTUGUESE', 'race_SOUTH AMERICAN', 'race_UNABLE TO OBTAIN', 'race_UNKNOWN', 'race_WHITE', 'race_WHITE - BRAZILIAN', 'race_WHITE - EASTERN EUROPEAN', 'race_WHITE - OTHER EUROPEAN', 'race_WHITE - RUSSIAN', 'race_HISPANIC OR LATINO', 'marital_status_DIVORCED', 'marital_status_MARRIED', 'marital_status_SINGLE', 'marital_status_WIDOWED', 'marital_status_0', 'hospital_stay_duration', 'procedure_225464')
# % Combos Checked: 716 out of 22032 which is 3.2498180000000003%
