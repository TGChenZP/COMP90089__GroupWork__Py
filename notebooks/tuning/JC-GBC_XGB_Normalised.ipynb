# %% [markdown]
# # Tuning Script

# %%
# Parameters subject to change in every script - involved in naming

MODEL = 'gbc'
PREPROCESSING = 'normalise'
TUNER = 'yangzhoub'
OPTIMISED_METRIC = 'f1'

# %% [markdown]
# ---

# %%
# detect whether this is a google environment

COLAB_ENVIRONMENT = False

try:
    from google.colab import drive
    drive.mount('/content/drive')
    COLAB_ENVIRONMENT = True
except:
    pass
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import sys
import os
import pickle

if COLAB_ENVIRONMENT:
    home_directory = './drive/MyDrive/LAB/COMP90089__GroupWork__Py/' # my home directory is stored in ./LAB of google drive
    if MODEL == 'ebr':
        # !pip install interpret==0.5.0
    elif MODEL == 'cbr':
        # !pip install catboost
    elif MODEL in ['tf', 'mlp']:
        # !pip install PyTorch2Sklearn
    # !pip install JXAutoML
else:
    home_directory = '../../'

from JXAutoML.JiaoCheng_10CV import JiaoCheng_10CV as Tuner

import pandas as pd
# Out:
# Requirement already satisfied: JXAutoML in /usr/local/lib/python3.10/dist-packages (0.4.4)

# %%
# Parameters that are same for every script

FOLDS = 10  # we have decided to do 10 fold validation

SEED = 42

TASK_TYPE = 'Classification'  # this task is a classification task

# we have decided to tune features as hp
TUNE_FEATURES_AS_HYPERPARAMETERS = True

# %% [markdown]
# ---

# %%
# model to use to tune
from sklearn.ensemble import GradientBoostingClassifier as clf

# what values to try for each hyperparameter
parameter_choices = {
    'n_estimators': (25, 50, 100, 200),
    'learning_rate': (0.0001, 0.001, 0.01, 0.1, 1, 10, 100),
    'subsample': (0.4, 0.55, 0.7, 0.85, 1),
    'max_features': (0.4, 0.55, 0.7, 0.85, 1),
    'max_depth': (3, 6, 12, 24, 48, 96, 192),
    'tol': (0.0001, 0.001, 0.01, 0.1, 1, 10),
    'ccp_alpha': (0.0001, 0.001, 0.01, 0.1, 1, 10)

}

# what values to set non-tuneable parameters/hyperparameters
non_tunable_hyperparameters_dict = {
                                    'random_state': 42,
                                    'verbose': 0
                                    }

# what order to tune hyperparameters in (JiaoCheng specific)
tuning_order = ['features',
                'max_depth',
                'max_features',
                'subsample',
                'n_estimators',
                'ccp_alpha',
                'tol',
                'learning_rate']

# what order to tune hyperparameters in (JiaoCheng specific)
default_hyperparameter_values = {
                                'features': 0,
                                'n_estimators': 50,
                                'max_depth': 12,
                                'subsample': 0.7,
                                'max_features': 0.7,
                                'tol': 0.0001,
                                'learning_rate': 0.001,
                                'ccp_alpha': 0.01
                                }

# %% [markdown]
# ---

# %% [markdown]
# Read in and Prepare Data

# %%
# Import data and store as lists

train_x_list = []
train_y_list = []
val_x_list = []
val_y_list = []

for i in range(FOLDS):
    train_data = pd.read_csv(
        f'{home_directory}data/curated/modelling/{PREPROCESSING}/train_{i}.csv')
    val_data = pd.read_csv(
        f'{home_directory}data/curated/modelling/{PREPROCESSING}/val_{i}.csv')

    # get the correct rows for X and y
    train_x = train_data.drop(
        ['mortality_status', 'subject_id', 'hadm_id', 'stay_id'], axis=1)
    train_y = train_data['mortality_status']
    val_x = val_data.drop(
        ['mortality_status', 'subject_id', 'hadm_id', 'stay_id'], axis=1)
    val_y = val_data['mortality_status']

    train_x_list.append(train_x)
    train_y_list.append(train_y)
    val_x_list.append(val_x)
    val_y_list.append(val_y)

# %%
# Import feature importance ordering

with open(f'{home_directory}models/xgb_feature_importance_ordering_{PREPROCESSING}.pickle', 'rb') as f:
    feature_importance_ordering = pickle.load(f)

# %% [markdown]
# Set parameters

# %%
# initialisation
tuner = Tuner()

print('---')

# define what model we are tuning
tuner.read_in_model(clf, TASK_TYPE, optimised_metric = OPTIMISED_METRIC)

print('---')

# read in the data for training and validation
tuner.read_in_data(train_x_list, train_y_list, val_x_list, val_y_list)

print('---')

# set what hp values to tune
tuner.set_hyperparameters(parameter_choices)
# WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

# set up hp values that need to be changed from default but NOT to be tuned
tuner.set_non_tuneable_hyperparameters(non_tunable_hyperparameters_dict)

print('---')

# set up feature importance ordering

if TUNE_FEATURES_AS_HYPERPARAMETERS:
  tuner.set_features(feature_importance_ordering)
  # WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

# set up the order of hyperparameters when iteratively tuning using JiaoCheng
tuner.set_tuning_order(tuning_order)

print('---')

# set up the default hp values for first iteration of tuning JiaoCheng
tuner.set_hyperparameter_default_values(default_hyperparameter_values)

print('---')

try: # try to read in previous results to continue tuning ...
  tuner.read_in_tuning_result_df(f'{home_directory}models/tuning/{TUNER}_{MODEL}_{PREPROCESSING}.csv')
except:
  print('No previous tuning data read in')

print('---')

# set up where to save the tuning result csv
tuner.set_tuning_result_saving_address(f'{home_directory}models/tuning/{TUNER}_{MODEL}_{PREPROCESSING}.csv')

print('---')

# set up where to save the current best model
tuner.set_best_model_saving_address(f'{home_directory}models/tmp_models/{TUNER}_{MODEL}_{PREPROCESSING}')
# Out:
# JiaoCheng Initialised
# ---
# Successfully read in model <class 'sklearn.ensemble._gb.GradientBoostingClassifier'>, which is a Classification model optimising for f1
# ---
# Read in Train X data list
# Read in Train y data list
# Read in Val X data list
# Read in Val y data list
# ---
# Successfully recorded hyperparameter choices
# ---
# Successfully recorded non_tuneable_hyperparameter choices
# ---
# Successfully recorded tuneable feature combination choices and updated relevant internal structures
# ---
# ---
# ---
# No previous tuning data read in
# ---
# Successfully set tuning output address
# ---
# Successfully set best model output address

# %%
# ignore warnings

import warnings
warnings.filterwarnings("ignore")

# %%
# begin tuning ... (or continue training)

tuner.tune()
# Out:
# Default combo: [1, 1, 2, 2, 2, 0, 2, 0]
#
#
# ROUND 1
#
# Round 1
# Hyperparameter: features (index: 7)
#
# Trained and Tested combination 1 of 12700800, taking 0.06 seconds to get val score of 0.0:
#                 {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 0},
#             Current best combo with val score 0.0:
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 0}
# Trained and Tested combination 2 of 12700800, taking 0.06 seconds to get val score of 0.0:
#                 {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 1},
#             Current best combo with val score 0.0:
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 0}
# Trained and Tested combination 3 of 12700800, taking 0.07 seconds to get val score of 0.0:
#                 {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 2},
#             Current best combo with val score 0.0:
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 0}
# Trained and Tested combination 4 of 12700800, taking 0.08 seconds to get val score of 0.0:
#                 {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 3},
#             Current best combo with val score 0.0:
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 0}
# Trained and Tested combination 5 of 12700800, taking 0.1 seconds to get val score of 0.0:
#                 {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 4},
#             Current best combo with val score 0.0:
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 0}
# Trained and Tested combination 6 of 12700800, taking 0.1 seconds to get val score of 0.0:
#                 {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 5},
#             Current best combo with val score 0.0:
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 0}
# Trained and Tested combination 7 of 12700800, taking 0.22 seconds to get val score of 0.0:
#                 {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 6},
#             Current best combo with val score 0.0:
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 0}
# Trained and Tested combination 8 of 12700800, taking 0.35 seconds to get val score of 0.0:
#                 {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 7},
#             Current best combo with val score 0.0:
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 0}
# Trained and Tested combination 9 of 12700800, taking 0.26 seconds to get val score of 0.0:
#                 {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 8},
#             Current best combo with val score 0.0:
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 0}
# Trained and Tested combination 10 of 12700800, taking 0.26 seconds to get val score of 0.0:
#                 {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 9},
#             Current best combo with val score 0.0:
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 0}
# Trained and Tested combination 11 of 12700800, taking 0.26 seconds to get val score of 0.0:
#                 {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 10},
#             Current best combo with val score 0.0:
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 0}
# Trained and Tested combination 12 of 12700800, taking 0.37 seconds to get val score of 0.0:
#                 {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 11},
#             Current best combo with val score 0.0:
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 0}
# Trained and Tested combination 13 of 12700800, taking 0.28 seconds to get val score of 0.0:
#                 {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 12},
#             Current best combo with val score 0.0:
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 0}
# Trained and Tested combination 14 of 12700800, taking 0.26 seconds to get val score of 0.0:
#                 {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 13},
#             Current best combo with val score 0.0:
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 0}
# Trained and Tested combination 15 of 12700800, taking 0.34 seconds to get val score of 0.0:
#                 {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 14},
#             Current best combo with val score 0.0:
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 0}
# Trained and Tested combination 16 of 12700800, taking 0.47 seconds to get val score of 0.0:
#                 {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 15},
#             Current best combo with val score 0.0:
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 0}
# Trained and Tested combination 17 of 12700800, taking 0.34 seconds to get val score of 0.0:
#                 {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 16},
#             Current best combo with val score 0.0:
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 0}
# Trained and Tested combination 18 of 12700800, taking 0.39 seconds to get val score of 0.0:
#                 {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 17},
#             Current best combo with val score 0.0:
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 0}
# Trained and Tested combination 19 of 12700800, taking 0.41 seconds to get val score of 0.0:
#                 {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 18},
#             Current best combo with val score 0.0:
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 0}
# Trained and Tested combination 20 of 12700800, taking 0.38 seconds to get val score of 0.0:
#                 {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 19},
#             Current best combo with val score 0.0:
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 0}
# Trained and Tested combination 21 of 12700800, taking 0.51 seconds to get val score of 0.0:
#                 {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 20},
#             Current best combo with val score 0.0:
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 0}
# Trained and Tested combination 22 of 12700800, taking 0.8 seconds to get val score of 0.0:
#                 {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 21},
#             Current best combo with val score 0.0:
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 0}
# Trained and Tested combination 23 of 12700800, taking 0.54 seconds to get val score of 0.0:
#                 {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 22},
#             Current best combo with val score 0.0:
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 0}
# Trained and Tested combination 24 of 12700800, taking 0.84 seconds to get val score of 0.0:
#                 {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 23},
#             Current best combo with val score 0.0:
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 0}
# Trained and Tested combination 25 of 12700800, taking 0.59 seconds to get val score of 0.0:
#                 {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 24},
#             Current best combo with val score 0.0:
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 0}
# Trained and Tested combination 26 of 12700800, taking 0.84 seconds to get val score of 0.0:
#                 {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 25},
#             Current best combo with val score 0.0:
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 0}
# Trained and Tested combination 27 of 12700800, taking 0.68 seconds to get val score of 0.0:
#                 {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 26},
#             Current best combo with val score 0.0:
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 0}
# Trained and Tested combination 28 of 12700800, taking 0.94 seconds to get val score of 0.0:
#                 {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 27},
#             Current best combo with val score 0.0:
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 0}
# Trained and Tested combination 29 of 12700800, taking 0.73 seconds to get val score of 0.0:
#                 {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 28},
#             Current best combo with val score 0.0:
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 0}
# Trained and Tested combination 30 of 12700800, taking 0.76 seconds to get val score of 0.0:
#                 {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 29},
#             Current best combo with val score 0.0:
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 0}
# Trained and Tested combination
 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 0},
#             Current best combo with val score 0.0:
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 0}
# Trained and Tested combination 89 of 12700800, taking 0.34 seconds to get val score of 0.0:
#                 {'n_estimators': 200, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 0},
#             Current best combo with val score 0.0:
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 0}
#
# Best combo after this hyperparameter: (1, 1, 2, 2, 2, 0, 2, 0) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 1
# Hyperparameter: ccp_alpha (index: 6)
#
# Trained and Tested combination 90 of 12700800, taking 0.08 seconds to get val score of 0.0:
#                 {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.0001, 'features': 0},
#             Current best combo with val score 0.0:
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 0}
# Trained and Tested combination 91 of 12700800, taking 0.09 seconds to get val score of 0.0:
#                 {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.001, 'features': 0},
#             Current best combo with val score 0.0:
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 0}
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 0}
#             Current best combo (with val score 0.0):
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 0}
#         Has trained 91 of 12700800 combinations so far
# Trained and Tested combination 92 of 12700800, taking 0.06 seconds to get val score of 0.0:
#                 {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.1, 'features': 0},
#             Current best combo with val score 0.0:
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 0}
# ...
# Trained and Tested combination 392 of 12700800, taking 0.06 seconds to get val score of 0.3742:
#                 {'n_estimators': 25, 'learning_rate': 1, 'subsample': 0.4, 'max_features': 1, 'max_depth': 24, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 7},
#             Current best combo with val score 0.4285:
#                     {'n_estimators': 25, 'learning_rate': 1, 'subsample': 0.4, 'max_features': 0.4, 'max_depth': 24, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 7}
#
# Best combo after this hyperparameter: (0, 4, 0, 0, 3, 0, 2, 7) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 4
# Hyperparameter: subsample (index: 2)
#
# Already Trained and Tested combination (val score of 0.4285):
#             {'n_estimators': 25, 'learning_rate': 1, 'subsample': 0.4, 'max_features': 0.4, 'max_depth': 24, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 7}
#             Current best combo (with val score 0.4285):
#                     {'n_estimators': 25, 'learning_rate': 1, 'subsample': 0.4, 'max_features': 0.4, 'max_depth': 24, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 7}
#         Has trained 392 of 12700800 combinations so far
# Trained and Tested combination 393 of 12700800, taking 0.12 seconds to get val score of 0.4133:
#                 {'n_estimators': 25, 'learning_rate': 1, 'subsample': 0.55, 'max_features': 0.4, 'max_depth': 24, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 7},
#             Current best combo with val score 0.4285:
#                     {'n_estimators': 25, 'learning_rate': 1, 'subsample': 0.4, 'max_features': 0.4, 'max_depth': 24, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 7}
# Trained and Tested combination 394 of 12700800, taking 0.15 seconds to get val score of 0.4041:
#                 {'n_estimators': 25, 'learning_rate': 1, 'subsample': 0.7, 'max_features': 0.4, 'max_depth': 24, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 7},
#             Current best combo with val score 0.4285:
#                     {'n_estimators': 25, 'learning_rate': 1, 'subsample': 0.4, 'max_features': 0.4, 'max_depth': 24, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 7}
# Trained and Tested combination 395 of 12700800, taking 0.14 seconds to get val score of 0.4159:
#                 {'n_estimators': 25, 'learning_rate': 1, 'subsample': 0.85, 'max_features': 0.4, 'max_depth': 24, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 7},
#             Current best combo with val score 0.4285:
#                     {'n_estimators': 25, 'learning_rate': 1, 'subsample': 0.4, 'max_features': 0.4, 'max_depth': 24, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 7}
# Trained and Tested combination 396 of 12700800, taking 0.13 seconds to get val score of 0.2933:
#                 {'n_estimators': 25, 'learning_rate': 1, 'subsample': 1, 'max_features': 0.4, 'max_depth': 24, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 7},
#             Current best combo with val score 0.4285:
#                     {'n_estimators': 25, 'learning_rate': 1, 'subsample': 0.4, 'max_features': 0.4, 'max_depth': 24, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 7}
#
# Best combo after this hyperparameter: (0, 4, 0, 0, 3, 0, 2, 7) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 4
# Hyperparameter: n_estimators (index: 0)
#
# Already Trained and Tested combination (val score of 0.4285):
#             {'n_estimators': 25, 'learning_rate': 1, 'subsample': 0.4, 'max_features': 0.4, 'max_depth': 24, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 7}
#             Current best combo (with val score 0.4285):
#                     {'n_estimators': 25, 'learning_rate': 1, 'subsample': 0.4, 'max_features': 0.4, 'max_depth': 24, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 7}
#         Has trained 396 of 12700800 combinations so far
# Already Trained and Tested combination (val score of 0.4279):
#             {'n_estimators': 50, 'learning_rate': 1, 'subsample': 0.4, 'max_features': 0.4, 'max_depth': 24, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 7}
#             Current best combo (with val score 0.4285):
#                     {'n_estimators': 25, 'learning_rate': 1, 'subsample': 0.4, 'max_features': 0.4, 'max_depth': 24, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 7}
#         Has trained 396 of 12700800 combinations so far
# Already Trained and Tested combination (val score of 0.4285):
#             {'n_estimators': 100, 'learning_rate': 1, 'subsample': 0.4, 'max_features': 0.4, 'max_depth': 24, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 7}
#             Current best combo (with val score 0.4285):
#                     {'n_estimators': 25, 'learning_rate': 1, 'subsample': 0.4, 'max_features': 0.4, 'max_depth': 24, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 7}
#         Has trained 396 of 12700800 combinations so far
# Already Trained and Tested combination (val score of 0.4285):
#             {'n_estimators': 200, 'learning_rate': 1, 'subsample': 0.4, 'max_features': 0.4, 'max_depth': 24, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 7}
#             Current best combo (with val score 0.4285):
#                     {'n_estimators': 25, 'learning_rate': 1, 'subsample': 0.4, 'max_features': 0.4, 'max_depth': 24, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 7}
#         Has trained 396 of 12700800 combinations so far
#
# Best combo after this hyperparameter: (0, 4, 0, 0, 3, 0, 2, 7) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 4
# Hyperparameter: ccp_alpha (index: 6)
#
# Already Trained and Tested combination (val score of 0.3381):
#             {'n_estimators': 25, 'learning_rate': 1, 'subsample': 0.4, 'max_features': 0.4, 'max_depth': 24, 'tol': 0.0001, 'ccp_alpha': 0.0001, 'features': 7}
#             Current best combo (with val score 0.4285):
#                     {'n_estimators': 25, 'learning_rate': 1, 'subsample': 0.4, 'max_features': 0.4, 'max_depth': 24, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 7}
#         Has trained 396 of 12700800 combinations so far
# Already Trained and Tested combination (val score of 0.3347):
#             {'n_estimators': 25, 'learning_rate': 1, 'subsample': 0.4, 'max_features': 0.4, 'max_depth': 24, 'tol': 0.0001, 'ccp_alpha': 0.001, 'features': 7}
#             Current best combo (with val score 0.4285):
#                     {'n_estimators': 25, 'learning_rate': 1, 'subsample': 0.4, 'max_features': 0.4, 'max_depth': 24, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 7}
#         Has trained 396 of 12700800 combinations so far
# Already Trained and Tested combination (val score of 0.4285):
#             {'n_estimators': 25, 'learning_rate': 1, 'subsample': 0.4, 'max_features': 0.4, 'max_depth': 24, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 7}
#             Current best combo (with val score 0.4285):
#                     {'n_estimators': 25, 'learning_rate': 1, 'subsample': 0.4, 'max_features': 0.4, 'max_depth': 24, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 7}
#         Has trained 396 of 12700800 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 25, 'learning_rate': 1, 'subsample': 0.4, 'max_features': 0.4, 'max_depth': 24, 'tol': 0.0001, 'ccp_alpha': 0.1, 'features': 7}
#             Current best combo (with val score 0.4285):
#                     {'n_estimators': 25, 'learning_rate': 1, 'subsample': 0.4, 'max_features': 0.4, 'max_depth': 24, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 7}
#         Has trained 396 of 12700800 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 25, 'learning_rate': 1, 'subsample': 0.4, 'max_features': 0.4, 'max_depth': 24, 'tol': 0.0001, 'ccp_alpha': 1, 'features': 7}
#             Current best combo (with val score 0.4285):
#                     {'n_estimators': 25, 'learning_rate': 1, 'subsample': 0.4, 'max_features': 0.4, 'max_depth': 24, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 7}
#         Has trained 396 of 12700800 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 25, 'learning_rate': 1, 'subsample': 0.4, 'max_features': 0.4, 'max_depth': 24, 'tol': 0.0001, 'ccp_alpha': 10, 'features': 7}
#             Current best combo (with val score 0.4285):
#                     {'n_estimators': 25, 'learning_rate': 1, 'subsample': 0.4, 'max_features': 0.4, 'max_depth': 24, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 7}
#         Has trained 396 of 12700800 combinations so far
#
# Best combo after this hyperparameter: (0, 4, 0, 0, 3, 0, 2, 7) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 4
# Hyperparameter: tol (index: 5)
#
# Already Trained and Tested combination (val score of 0.4285):
#             {'n_estimators': 25, 'learning_rate': 1, 'subsample': 0.4, 'max_features': 0.4, 'max_depth': 24, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 7}
#             Current best combo (with val score 0.4285):
#                     {'n_estimators': 25, 'learning_rate': 1, 'subsample': 0.4, 'max_features': 0.4, 'max_depth': 24, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 7}
#         Has trained 396 of 12700800 combinations so far
# Already Trained and Tested combination (val score of 0.4285):
#             {'n_estimators': 25, 'learning_rate': 1, 'subsample': 0.4, 'max_features': 0.4, 'max_depth': 24, 'tol': 0.001, 'ccp_alpha': 0.01, 'features': 7}
#             Current best combo (with val score 0.4285):
#                     {'n_estimators': 25, 'learning_rate': 1, 'subsample': 0.4, 'max_features': 0.4, 'max_depth': 24, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 7}
#         Has trained 396 of 12700800 combinations so far
# Already Trained and Tested combination (val score of 0.4285):
#             {'n_estimators': 25, 'learning_rate': 1, 'subsample': 0.4, 'max_features': 0.4, 'max_depth': 24, 'tol': 0.01, 'ccp_alpha': 0.01, 'features': 7}
#             Current best combo (with val score 0.4285):
#                     {'n_estimators': 25, 'learning_rate': 1, 'subsample': 0.4, 'max_features': 0.4, 'max_depth': 24, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 7}
#         Has trained 396 of 12700800 combinations so far
# Already Trained and Tested combination (val score of 0.4285):
#             {'n_estimators': 25, 'learning_rate': 1, 'subsample': 0.4, 'max_features': 0.4, 'max_depth': 24, 'tol': 0.1, 'ccp_alpha': 0.01, 'features': 7}
#             Current best combo (with val score 0.4285):
#                     {'n_estimators': 25, 'learning_rate': 1, 'subsample': 0.4, 'max_features': 0.4, 'max_depth': 24, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 7}
#         Has trained 396 of 12700800 combinations so far
# Already Trained and Tested combination (val score of 0.4285):
#             {'n_estimators': 25, 'learning_rate': 1, 'subsample': 0.4, 'max_features': 0.4, 'max_depth': 24, 'tol': 1, 'ccp_alpha': 0.01, 'features': 7}
#             Current best combo (with val score 0.4285):
#                     {'n_estimators': 25, 'learning_rate': 1, 'subsample': 0.4, 'max_features': 0.4, 'max_depth': 24, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 7}
#         Has trained 396 of 12700800 combinations so far
# Already Trained and Tested combination (val score of 0.4285):
#             {'n_estimators': 25, 'learning_rate': 1, 'subsample': 0.4, 'max_features': 0.4, 'max_depth': 24, 'tol': 10, 'ccp_alpha': 0.01, 'features': 7}
#             Current best combo (with val score 0.4285):
#                     {'n_estimators': 25, 'learning_rate': 1, 'subsample': 0.4, 'max_features': 0.4, 'max_depth': 24, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 7}
#         Has trained 396 of 12700800 combinations so far
#
# Best combo after this hyperparameter: (0, 4, 0, 0, 3, 0, 2, 7) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 4
# Hyperparameter: learning_rate (index: 1)
#
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 25, 'learning_rate': 0.0001, 'subsample': 0.4, 'max_features': 0.4, 'max_depth': 24, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 7}
#             Current best combo (with val score 0.4285):
#                     {'n_estimators': 25, 'learning_rate': 1, 'subsample': 0.4, 'max_features': 0.4, 'max_depth': 24, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 7}
#         Has trained 396 of 12700800 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 25, 'learning_rate': 0.001, 'subsample': 0.4, 'max_features': 0.4, 'max_depth': 24, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 7}
#             Current best combo (with val score 0.4285):
#                     {'n_estimators': 25, 'learning_rate': 1, 'subsample': 0.4, 'max_features': 0.4, 'max_depth': 24, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 7}
#         Has trained 396 of 12700800 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 25, 'learning_rate': 0.01, 'subsample': 0.4, 'max_features': 0.4, 'max_depth': 24, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 7}
#             Current best combo (with val score 0.4285):
#                     {'n_estimators': 25, 'learning_rate': 1, 'subsample': 0.4, 'max_features': 0.4, 'max_depth': 24, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 7}
#         Has trained 396 of 12700800 combinations so far
# Already Trained and Tested combination (val score of 0.2115):
#             {'n_estimators': 25, 'learning_rate': 0.1, 'subsample': 0.4, 'max_features': 0.4, 'max_depth': 24, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 7}
#             Current best combo (with val score 0.4285):
#                     {'n_estimators': 25, 'learning_rate': 1, 'subsample': 0.4, 'max_features': 0.4, 'max_depth': 24, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 7}
#         Has trained 396 of 12700800 combinations so far
# Already Trained and Tested combination (val score of 0.4285):
#             {'n_estimators': 25, 'learning_rate': 1, 'subsample': 0.4, 'max_features': 0.4, 'max_depth': 24, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 7}
#             Current best combo (with val score 0.4285):
#                     {'n_estimators': 25, 'learning_rate': 1, 'subsample': 0.4, 'max_features': 0.4, 'max_depth': 24, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 7}
#         Has trained 396 of 12700800 combinations so far
# Already Trained and Tested combination (val score of 0.2662):
#             {'n_estimators': 25, 'learning_rate': 10, 'subsample': 0.4, 'max_features': 0.4, 'max_depth': 24, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 7}
#             Current best combo (with val score 0.4285):
#                     {'n_estimators': 25, 'learning_rate': 1, 'subsample': 0.4, 'max_features': 0.4, 'max_depth': 24, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 7}
#         Has trained 396 of 12700800 combinations so far
# Already Trained and Tested combination (val score of 0.2905):
#             {'n_estimators': 25, 'learning_rate': 100, 'subsample': 0.4, 'max_features': 0.4, 'max_depth': 24, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 7}
#             Current best combo (with val score 0.4285):
#                     {'n_estimators': 25, 'learning_rate': 1, 'subsample': 0.4, 'max_features': 0.4, 'max_depth': 24, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 7}
#         Has trained 396 of 12700800 combinations so far
#
# Best combo after this hyperparameter: (0, 4, 0, 0, 3, 0, 2, 7) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
# Max Val Score:
#  0.428536
# Max Val Score Std:
#  0.042075
# Best Combo Train Score:
#  0.534886
# Best Combo Train Score Std:
#  0.048354
# Max Combo Index:
#  (0, 4, 0, 0, 3, 0, 2, 7) out of [4, 7, 5, 5, 7, 6, 6, 72] (note best combo is 0-indexed)
# Max Combo Hyperparamer Combination:
#  {'n_estimators': 25, 'learning_rate': 1, 'subsample': 0.4, 'max_features': 0.4, 'max_depth': 24, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 7}
# Max Combo Features:
#  ('procedure_228130', 'procedure_225792', 'procedure_228125', 'lods_score', 'ventilation_used', 'procedure_226236', 'hospital_stay_duration', 'procedure_225469')
# % Combos Checked: 396 out of 12700800 which is 0.003118%
