# %% [markdown]
# # Tuning Script

# %%
# Parameters subject to change in every script - involved in naming

MODEL = 'gbc'
PREPROCESSING = 'normalise'
TUNER = 'yangzhoub'
OPTIMISED_METRIC = 'f1'

# %% [markdown]
# ---

# %%
# detect whether this is a google environment

COLAB_ENVIRONMENT = False

try:
    from google.colab import drive
    drive.mount('/content/drive')
    COLAB_ENVIRONMENT = True
except:
    pass
# Out:
# Mounted at /content/drive

# %%
import sys
import os
import pickle

if COLAB_ENVIRONMENT:
    home_directory = './drive/MyDrive/LAB/COMP90089__GroupWork__Py/' # my home directory is stored in ./LAB of google drive
    if MODEL == 'ebr':
        # !pip install interpret==0.5.0
    elif MODEL == 'cbr':
        # !pip install catboost
    elif MODEL in ['tf', 'mlp']:
        # !pip install PyTorch2Sklearn
    # !pip install JXAutoML
else:
    home_directory = '../../'

from JXAutoML.JiaoCheng_10CV import JiaoCheng_10CV as Tuner

import pandas as pd
# Out:
# Collecting JXAutoML
#   Downloading JXAutoML-0.4.4-py3-none-any.whl.metadata (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.2/67.2 kB 1.8 MB/s eta 0:00:00
# Downloading JXAutoML-0.4.4-py3-none-any.whl (52 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.1/52.1 kB 3.6 MB/s eta 0:00:00
# Installing collected packages: JXAutoML
# Successfully installed JXAutoML-0.4.4

# %%
# Parameters that are same for every script

FOLDS = 10  # we have decided to do 10 fold validation

SEED = 42

TASK_TYPE = 'Classification'  # this task is a classification task

# we have decided to tune features as hp
TUNE_FEATURES_AS_HYPERPARAMETERS = True

# %% [markdown]
# ---

# %%
# model to use to tune
from sklearn.ensemble import GradientBoostingClassifier as clf

# what values to try for each hyperparameter
parameter_choices = {
    'n_estimators': (25, 50, 100, 200),
    'learning_rate': (0.0001, 0.001, 0.01, 0.1, 1, 10, 100),
    'subsample': (0.4, 0.55, 0.7, 0.85, 1),
    'max_features': (0.4, 0.55, 0.7, 0.85, 1),
    'max_depth': (3, 6, 12, 24, 48, 96, 192),
    'tol': (0.0001, 0.001, 0.01, 0.1, 1, 10),
    'ccp_alpha': (0.0001, 0.001, 0.01, 0.1, 1, 10)

}

# what values to set non-tuneable parameters/hyperparameters
non_tunable_hyperparameters_dict = {
                                    'random_state': 42,
                                    'verbose': 0
                                    }

# what order to tune hyperparameters in (JiaoCheng specific)
tuning_order = ['features',
                'max_depth',
                'max_features',
                'subsample',
                'n_estimators',
                'ccp_alpha',
                'tol',
                'learning_rate']

# what order to tune hyperparameters in (JiaoCheng specific)
default_hyperparameter_values = {
                                'features': 0,
                                'n_estimators': 50,
                                'max_depth': 12,
                                'subsample': 0.7,
                                'max_features': 0.7,
                                'tol': 0.0001,
                                'learning_rate': 0.001,
                                'ccp_alpha': 0.01
                                }

# %% [markdown]
# ---

# %% [markdown]
# Read in and Prepare Data

# %%
# Import data and store as lists

train_x_list = []
train_y_list = []
val_x_list = []
val_y_list = []

for i in range(FOLDS):
    train_data = pd.read_csv(
        f'{home_directory}data/curated/modelling/{PREPROCESSING}/train_{i}.csv')
    val_data = pd.read_csv(
        f'{home_directory}data/curated/modelling/{PREPROCESSING}/val_{i}.csv')

    # get the correct rows for X and y
    train_x = train_data.drop(
        ['mortality_status', 'subject_id', 'hadm_id', 'stay_id'], axis=1)
    train_y = train_data['mortality_status']
    val_x = val_data.drop(
        ['mortality_status', 'subject_id', 'hadm_id', 'stay_id'], axis=1)
    val_y = val_data['mortality_status']

    train_x_list.append(train_x)
    train_y_list.append(train_y)
    val_x_list.append(val_x)
    val_y_list.append(val_y)

# %%
# Import feature importance ordering

with open(f'{home_directory}models/xgb_feature_importance_ordering_{PREPROCESSING}.pickle', 'rb') as f:
    feature_importance_ordering = pickle.load(f)

# %% [markdown]
# Set parameters

# %%
# initialisation
tuner = Tuner()

print('---')

# define what model we are tuning
tuner.read_in_model(clf, TASK_TYPE, optimised_metric = OPTIMISED_METRIC)

print('---')

# read in the data for training and validation
tuner.read_in_data(train_x_list, train_y_list, val_x_list, val_y_list)

print('---')

# set what hp values to tune
tuner.set_hyperparameters(parameter_choices)
# WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

# set up hp values that need to be changed from default but NOT to be tuned
tuner.set_non_tuneable_hyperparameters(non_tunable_hyperparameters_dict)

print('---')

# set up feature importance ordering

if TUNE_FEATURES_AS_HYPERPARAMETERS:
  tuner.set_features(feature_importance_ordering)
  # WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

# set up the order of hyperparameters when iteratively tuning using JiaoCheng
tuner.set_tuning_order(tuning_order)

print('---')

# set up the default hp values for first iteration of tuning JiaoCheng
tuner.set_hyperparameter_default_values(default_hyperparameter_values)

print('---')

try: # try to read in previous results to continue tuning ...
  tuner.read_in_tuning_result_df(f'{home_directory}models/tuning/{TUNER}_{MODEL}_{PREPROCESSING}.csv')
except:
  print('No previous tuning data read in')

print('---')

# set up where to save the tuning result csv
tuner.set_tuning_result_saving_address(f'{home_directory}models/tuning/{TUNER}_{MODEL}_{PREPROCESSING}.csv')

print('---')

# set up where to save the current best model
tuner.set_best_model_saving_address(f'{home_directory}models/tmp_models/{TUNER}_{MODEL}_{PREPROCESSING}')
# Out:
# JiaoCheng Initialised
# ---
# Successfully read in model <class 'sklearn.ensemble._gb.GradientBoostingClassifier'>, which is a Classification model optimising for f1
# ---
# Read in Train X data list
# Read in Train y data list
# Read in Val X data list
# Read in Val y data list
# ---
# Successfully recorded hyperparameter choices
# ---
# Successfully recorded non_tuneable_hyperparameter choices
# ---
# Successfully recorded tuneable feature combination choices and updated relevant internal structures
# ---
# ---
# ---
# No previous tuning data read in
# ---
# Successfully set tuning output address
# ---
# Successfully set best model output address

# %%
# ignore warnings

import warnings
warnings.filterwarnings("ignore")

# %%
# begin tuning ... (or continue training)

tuner.tune()
# Out:
# Default combo: [1, 1, 2, 2, 2, 0, 2, 0]
#
#
# ROUND 1
#
# Round 1
# Hyperparameter: features (index: 7)
#
# Trained and Tested combination 1 of 8467200, taking 0.08 seconds to get val score of 0.0:
#                 {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 0},
#             Current best combo with val score 0.0:
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 0}
# Trained and Tested combination 2 of 8467200, taking 0.07 seconds to get val score of 0.0:
#                 {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 1},
#             Current best combo with val score 0.0:
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 0}
# Trained and Tested combination 3 of 8467200, taking 0.08 seconds to get val score of 0.0:
#                 {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 2},
#             Current best combo with val score 0.0:
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 0}
# Trained and Tested combination 4 of 8467200, taking 0.09 seconds to get val score of 0.0:
#                 {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 3},
#             Current best combo with val score 0.0:
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 0}
# Trained and Tested combination 5 of 8467200, taking 0.1 seconds to get val score of 0.0:
#                 {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 4},
#             Current best combo with val score 0.0:
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 0}
# Trained and Tested combination 6 of 8467200, taking 0.33 seconds to get val score of 0.0:
#                 {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 5},
#             Current best combo with val score 0.0:
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 0}
# Trained and Tested combination 7 of 8467200, taking 0.22 seconds to get val score of 0.0:
#                 {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 6},
#             Current best combo with val score 0.0:
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 0}
# Trained and Tested combination 8 of 8467200, taking 0.24 seconds to get val score of 0.0:
#                 {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 7},
#             Current best combo with val score 0.0:
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 0}
# Trained and Tested combination 9 of 8467200, taking 0.25 seconds to get val score of 0.0:
#                 {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 8},
#             Current best combo with val score 0.0:
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 0}
# Trained and Tested combination 10 of 8467200, taking 0.53 seconds to get val score of 0.0:
#                 {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 9},
#             Current best combo with val score 0.0:
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 0}
# Trained and Tested combination 11 of 8467200, taking 0.4 seconds to get val score of 0.0:
#                 {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 10},
#             Current best combo with val score 0.0:
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 0}
# Trained and Tested combination 12 of 8467200, taking 0.39 seconds to get val score of 0.0:
#                 {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 11},
#             Current best combo with val score 0.0:
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 0}
# Trained and Tested combination 13 of 8467200, taking 0.73 seconds to get val score of 0.0:
#                 {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 12},
#             Current best combo with val score 0.0:
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 0}
# Trained and Tested combination 14 of 8467200, taking 0.53 seconds to get val score of 0.0:
#                 {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 13},
#             Current best combo with val score 0.0:
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 0}
# Trained and Tested combination 15 of 8467200, taking 0.76 seconds to get val score of 0.0:
#                 {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 14},
#             Current best combo with val score 0.0:
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 0}
# Trained and Tested combination 16 of 8467200, taking 0.52 seconds to get val score of 0.0:
#                 {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 15},
#             Current best combo with val score 0.0:
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 0}
# Trained and Tested combination 17 of 8467200, taking 0.53 seconds to get val score of 0.0:
#                 {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 16},
#             Current best combo with val score 0.0:
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 0}
# Trained and Tested combination 18 of 8467200, taking 0.55 seconds to get val score of 0.0:
#                 {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 17},
#             Current best combo with val score 0.0:
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 0}
# Trained and Tested combination 19 of 8467200, taking 0.6 seconds to get val score of 0.0:
#                 {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 18},
#             Current best combo with val score 0.0:
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 0}
# Trained and Tested combination 20 of 8467200, taking 0.6 seconds to get val score of 0.0:
#                 {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 19},
#             Current best combo with val score 0.0:
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 0}
# Trained and Tested combination 21 of 8467200, taking 0.62 seconds to get val score of 0.0:
#                 {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 20},
#             Current best combo with val score 0.0:
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 0}
# Trained and Tested combination 22 of 8467200, taking 0.77 seconds to get val score of 0.0:
#                 {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 21},
#             Current best combo with val score 0.0:
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 0}
# Trained and Tested combination 23 of 8467200, taking 0.99 seconds to get val score of 0.0:
#                 {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 22},
#             Current best combo with val score 0.0:
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 0}
# Trained and Tested combination 24 of 8467200, taking 0.77 seconds to get val score of 0.0:
#                 {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 23},
#             Current best combo with val score 0.0:
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 0}
# Trained and Tested combination 25 of 8467200, taking 0.83 seconds to get val score of 0.0:
#                 {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 24},
#             Current best combo with val score 0.0:
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 0}
# Trained and Tested combination 26 of 8467200, taking 0.95 seconds to get val score of 0.0:
#                 {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 25},
#             Current best combo with val score 0.0:
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 0}
# Trained and Tested combination 27 of 8467200, taking 0.92 seconds to get val score of 0.0:
#                 {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 26},
#             Current best combo with val score 0.0:
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 0}
# Trained and Tested combination 28 of 8467200, taking 0.94 seconds to get val score of 0.0:
#                 {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 27},
#             Current best combo with val score 0.0:
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 0}
# Trained and Tested combination 29 of 8467200, taking 1.32 seconds to get val score of 0.0:
#                 {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 28},
#             Current best combo with val score 0.0:
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 0}
# Trained and Tested combination 30 of 8467200, taking 1.02 seconds to get val score of 0.0:
#                 {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 29},
#             Current best combo with val score 0.0:
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 0}
# Trained and Tested combination 31 of 8467200, taking 1.01 seconds to get val score of 0.0:
#                 {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 30},
#             Current best combo with val score 0.0:
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 0}
# Trained and Tested combination 32 of 8467200, taking 1.11 seconds to get val score of 0.0:
#                 {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 31},
#             Current best combo with val score 0.0:
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 0}
# Trained and Tested combination 33 of 8467200, taking 1.17 seconds to get val score of 0.0:
#                 {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 32},
#             Current best combo with val score 0.0:
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 0}
# Trained and Tested combination 34 of 8467200, taking 1.3 seconds to get val score of 0.0:
#                 {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 33},
#             Current best combo with val score 0.0:
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 0}
# Trained and Tested combination 35 of 8467200, taking 1.2 seconds to get val score of 0.0:
#                 {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 34},
#             Current best combo with val score 0.0:
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 0}
# Trained and Tested combination 36 of 8467200, taking 1.24 seconds to get val score of 0.0:
#                 {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 35},
#             Current best combo with val score 0.0:
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 0}
# Trained and Tested combination 37 of 8467200, taking 1.29 seconds to get val score of 0.0:
#                 {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 36},
#             Current best combo with val score 0.0:
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 0}
# Trained and Tested combination 38 of 8467200, taking 1.32 seconds to get val score of 0.0:
#                 {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 37},
#             Current best combo with val score 0.0:
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 0}
# Trained and Tested combination 39 of 8467200, taking 1.28 seconds to get val score of 0.0:
#                 {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 38},
#             Current best combo with val score 0.0:
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 0}
# Trained and Tested combination 40 of 8467200, taking 1.41 seconds to get val score of 0.0:
#                 {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 39},
#             Current best combo with val score 0.0:
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 0}
# Trained and Tested combination 41 of 8467200, taking 1.43 seconds to get val score of 0.0:
#                 {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 40},
#             Current best combo with val score 0.0:
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 0}
# Trained and Tested combination 42 of 8467200, taking 1.6 seconds to get val score of 0.0:
#                 {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 41},
#             Current best combo with val score 0.0:
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 0}
# Trained and Tested combination 43 of 8467200, taking 1.48 seconds to get val score of 0.0:
#                 {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 42},
#             Current best combo with val score 0.0:
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 0}
# Trained and Tested combination 44 of 8467200, taking 1.81 seconds to get val score of 0.0:
#                 {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 43},
#             Current best combo with val score 0.0:
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 0}
# Trained and Tested combination 45 of 8467200, taking 2.1 seconds to get val score of 0.0:
#                 {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 44},
#             Current best combo with val score 0.0:
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 0}
# Trained and Tested combination 46 of 8467200, taking 1.57 seconds to get val score of 0.0:
#                 {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 45},
#             Current best combo with val score 0.0:
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 0}
# Trained and Tested combination 47 of 8467200, taking 1.48 seconds to get val score of 0.0:
#                 {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 46},
#             Current best combo with val score 0.0:
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 0}
# Trained and Tested combination 48 of 8467200, taking 1.48 seconds to get val score of 0.0:
#                 {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 47},
#             Current best combo with val score 0.0:
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 0}
#
# Best combo after this hyperparameter: (1, 1, 2, 2, 2, 0, 2, 0) , UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 1
# Hyperparameter: max_depth (index: 4)
#
# Trained and Tested combination 49 of 8467200, taking 0.08 seconds to get val score of 0.0:
#                 {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 3, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 0},
#             Current best combo with val score 0.0:
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 0}
# Trained and Tested combination 50 of 8467200, taking 0.08 seconds to get val score of 0.0:
#                 {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 6, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 0},
#             Current best combo with val score 0.0:
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 0}
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 0}
#             Current best combo (with val score 0.0):
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 0}
#         Has trained 50 of 8467200 combinations so far
# Trained and Tested combination 51 of 8467200, taking 0.08 seconds to get val score of 0.0:
#                 {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 24, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 0},
#             Current best combo with val score 0.0:
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 0}
# Trained and Tested combination 52 of 8467200, taking 0.07 seconds to get val score of 0.0:
#                 {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 48, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 0},
#             Current best combo with val score 0.0:
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 0}
# Trained and Tested combination 53 of 8467200, taking 0.1 seconds to get val score of 0.0:
#                 {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 96, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 0},
#             Current best combo with val score 0.0:
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 0}
# Trained and Tested combination 54 of 8467200, taking 0.1 seconds to get val score of 0.0:
#                 {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 192, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 0},
#             Current best combo with val score 0.0:
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 0}
#
# Best combo after this hyperparameter: (1, 1, 2, 2, 2, 0, 2, 0) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 1
# Hyperparameter: max_features (index: 3)
#
# Trained and Tested combination 55 of 8467200, taking 0.1 seconds to get val score of 0.0:
#                 {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.4, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 0},
#             Current best combo with val score 0.0:
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 0}
# Trained and Tested combination 56 of 8467200, taking 0.07 seconds to get val score of 0.0:
#                 {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.55, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 0},
#             Current best combo with val score 0.0:
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 0}
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 0}
#             Current best combo (with val score 0.0):
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 0}
#         Has trained 56 of 8467200 combinations so far
# Trained and Tested combination 57 of 8467200, taking 0.07 seconds to get val score of 0.0:
#                 {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.85, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 0},
#             Current best combo with val score 0.0:
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 0}
# Trained and Tested combination 58 of 8467200, taking 0.07 seconds to get val score of 0.0:
#                 {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 1, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 0},
#             Current best combo with val score 0.0:
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 0}
#
# Best combo after this hyperparameter: (1, 1, 2, 2, 2, 0, 2, 0) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 1
# Hyperparameter: subsample (index: 2)
#
# Trained and Tested combination 59 of 8467200, taking 0.07 seconds to get val score of 0.0:
#                 {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.4, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 0},
#             Current best combo with val score 0.0:
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 0}
# Trained and Tested combination 60 of 8467200, taking 0.08 seconds to get val score of 0.0:
#                 {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.55, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 0},
#             Current best combo with val score 0.0:
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 0}
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 0}
#             Current best combo (with val score 0.0):
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 0}
#         Has trained 60 of 8467200 combinations so far
# Trained and Tested combination 61 of 8467200, taking 0.07 seconds to get val score of 0.0:
#                 {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.85, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 0},
#             Current best combo with val score 0.0:
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 0}
# Trained and Tested combination 62 of 8467200, taking 0.06 seconds to get val score of 0.0:
#                 {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 1, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 0},
#             Current best combo with val score 0.0:
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 0}
#
# Best combo after this hyperparameter: (1, 1, 2, 2, 2, 0, 2, 0) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 1
# Hyperparameter: n_estimators (index: 0)
#
# Trained and Tested combination 63 of 8467200, taking 0.04 seconds to get val score of 0.0:
#                 {'n_estimators': 25, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 0},
#             Current best combo with val score 0.0:
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 0}
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 0}
#             Current best combo (with val score 0.0):
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 0}
#         Has trained 63 of 8467200 combinations so far
# Trained and Tested combination 64 of 8467200, taking 0.14 seconds to get val score of 0.0:
#                 {'n_estimators': 100, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 0},
#             Current best combo with val score 0.0:
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 0}
# Trained and Tested combination 65 of 8467200, taking 0.38 seconds to get val score of 0.0:
#                 {'n_estimators': 200, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 0},
#             Current best combo with val score 0.0:
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 0}
#
# Best combo after this hyperparameter: (1, 1, 2, 2, 2, 0, 2, 0) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 1
# Hyperparameter: ccp_alpha (index: 6)
#
# Trained and Tested combination 66 of 8467200, taking 0.07 seconds to get val score of 0.0:
#                 {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.0001, 'features': 0},
#             Current best combo with val score 0.0:
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 0}
# Trained and Tested combination 67 of 8467200, taking 0.07 seconds to get val score of 0.0:
#                 {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.001, 'features': 0},
#             Current best combo with val score 0.0:
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 0}
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 0}
#             Current best combo (with val score 0.0):
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 0}
#         Has trained 67 of 8467200 combinations so far
# Trained and Tested combination 68 of 8467200, taking 0.07 seconds to get val score of 0.0:
#                 {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.1, 'features': 0},
#             Current best combo with val score 0.0:
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 0}
# Trained and Tested combination 69 of 8467200, taking 0.07 seconds to get val score of 0.0:
#                 {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 1, 'features': 0},
#             Current best combo with val score 0.0:
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 0}
# Trained and Tested combination 70 of 8467200, taking 0.07 seconds to get val score of 0.0:
#                 {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 10, 'features': 0},
#             Current best combo with val score 0.0:
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 0}
#
# Best combo after this hyperparameter: (1, 1, 2, 2, 2, 0, 2, 0) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 1
# Hyperparameter: tol (index: 5)
#
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 0}
#             Current best combo (with val score 0.0):
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 0}
#         Has trained 70 of 8467200 combinations so far
# Trained and Tested combination 71 of 8467200, taking 0.08 seconds to get val score of 0.0:
#                 {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.001, 'ccp_alpha': 0.01, 'features': 0},
#             Current best combo with val score 0.0:
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 0}
# Trained and Tested combination 72 of 8467200, taking 0.07 seconds to get val score of 0.0:
#                 {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.01, 'ccp_alpha': 0.01, 'features': 0},
#             Current best combo with val score 0.0:
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 0}
# Trained and Tested combination 73 of 8467200, taking 0.07 seconds to get val score of 0.0:
#                 {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.1, 'ccp_alpha': 0.01, 'features': 0},
#             Current best combo with val score 0.0:
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 0}
# Trained and Tested combination 74 of 8467200, taking 0.07 seconds to get val score of 0.0:
#                 {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 1, 'ccp_alpha': 0.01, 'features': 0},
#             Current best combo with val score 0.0:
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 0}
# Trained and Tested combination 75 of 8467200, taking 0.1 seconds to get val score of 0.0:
#                 {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 10, 'ccp_alpha': 0.01, 'features': 0},
#             Current best combo with val score 0.0:
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 0}
#
# Best combo after this hyperparameter: (1, 1, 2, 2, 2, 0, 2, 0) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 1
# Hyperparameter: learning_rate (index: 1)
#
# Trained and Tested combination 76 of 8467200, taking 0.1 seconds to get val score of 0.0:
#                 {'n_estimators': 50, 'learning_rate': 0.0001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 0},
#             Current best combo with val score 0.0:
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 0}
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 0}
#             Current best combo (with val score 0.0):
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 0}
#         Has trained 76 of 8467200 combinations so far
# Trained and Tested combination 77 of 8467200, taking 0.1 seconds to get val score of 0.0:
#                 {'n_estimators': 50, 'learning_rate': 0.01, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 0},
#             Current best combo with val score 0.0:
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 0}
# Trained and Tested combination 78 of 8467200, taking 0.07 seconds to get val score of 0.0:
#                 {'n_estimators': 50, 'learning_rate': 0.1, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 0},
#             Current best combo with val score 0.0:
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 0}
# Trained and Tested combination 79 of 8467200, taking 0.07 seconds to get val score of 0.0:
#                 {'n_estimators': 50, 'learning_rate': 1, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 0},
#             Current best combo with val score 0.0:
#                     {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 0}
# Trained and Tested combination 80 of 8467200, taking 0.07 seconds to get val score of 0.0928:
#                 {'n_estimators': 50, 'learning_rate': 10, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 0},
#             Current best combo with val score 0.0928:
#                     {'n_estimators': 50, 'learning_rate': 10, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 0}
# Trained and Tested combination 81 of 8467200, taking 0.07 seconds to get val score of 0.3117:
#                 {'n_estimators': 50, 'learning_rate': 100, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 0},
#             Current best combo with val score 0.3117:
#                     {'n_estimators': 50, 'learning_rate': 100, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 0}
#
# Best combo after this hyperparameter: (1, 6, 2, 2, 2, 0, 2, 0) , UPDATED SINCE LAST HYPERPARAMETER
#
#
# ROUND 2
#
# Round 2
# Hyperparameter: features (index: 7)
#
# Already Trained and Tested combination (val score of 0.3117):
#             {'n_estimators': 50, 'learning_rate': 100, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 0}
#             Current best combo (with val score 0.3117):
#                     {'n_estimators': 50, 'learning_rate': 100, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 0}
#         Has trained 81 of 8467200 combinations so far
# Trained and Tested combination 82 of 8467200, taking 0.08 seconds to get val score of 0.1642:
#                 {'n_estimators': 50, 'learning_rate': 100, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 1},
#             Current best combo with val score 0.3117:
#                     {'n_estimators': 50, 'learning_rate': 100, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 0}
# Trained and Tested combination 83 of 8467200, taking 0.07 seconds to get val score of 0.1556:
#                 {'n_estimators': 50, 'learning_rate': 100, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 2},
#             Current best combo with val score 0.3117:
#                     {'n_estimators': 50, 'learning_rate': 100, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 0}
# Trained and Tested combination 84 of 8467200, taking 0.09 seconds to get val score of 0.3117:
#                 {'n_estimators': 50, 'learning_rate': 100, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 3},
#             Current best combo with val score 0.3117:
#                     {'n_estimators': 50, 'learning_rate': 100, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 0}
# Trained and Tested combination 85 of 8467200, taking 0.1 seconds to get val score of 0.1556:
#                 {'n_estimators': 50, 'learning_rate': 100, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 4},
#             Current best combo with val score 0.3117:
#                     {'n_estimators': 50, 'learning_rate': 100, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 0}
# Trained and Tested combination 86 of 8467200, taking 0.3 seconds to get val score of 0.2967:
#                 {'n_estimators': 50, 'learning_rate': 100, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 5},
#             Current best combo with val score 0.3117:
#                     {'n_estimators': 50, 'learning_rate': 100, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 0}
# Trained and Tested combination 87 of 8467200, taking 0.31 seconds to get val score of 0.2548:
#                 {'n_estimators': 50, 'learning_rate': 100, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 6},
#             Current best combo with val score 0.3117:
#                     {'n_estimators': 50, 'learning_rate': 100, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 0}
# Trained and Tested combination 88 of 8467200, taking 0.21 seconds to get val score of 0.3079:
#                 {'n_estimators': 50, 'learning_rate': 100, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 7},
#             Current best combo with val score 0.3117:
#                     {'n_estimators': 50, 'learning_rate': 100, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 12, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 0}
# Trained and Tested combination 89 of 8467200, taking 0.23 seconds to get val score of 0.2862:
# ...
#             Current best combo (with val score 0.3376):
#                     {'n_estimators': 50, 'learning_rate': 100, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 6, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 25}
#         Has trained 208 of 8467200 combinations so far
# Already Trained and Tested combination (val score of 0.3376):
#             {'n_estimators': 50, 'learning_rate': 100, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 6, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 25}
#             Current best combo (with val score 0.3376):
#                     {'n_estimators': 50, 'learning_rate': 100, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 6, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 25}
#         Has trained 208 of 8467200 combinations so far
# Already Trained and Tested combination (val score of 0.3117):
#             {'n_estimators': 50, 'learning_rate': 100, 'subsample': 0.85, 'max_features': 0.7, 'max_depth': 6, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 25}
#             Current best combo (with val score 0.3376):
#                     {'n_estimators': 50, 'learning_rate': 100, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 6, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 25}
#         Has trained 208 of 8467200 combinations so far
# Already Trained and Tested combination (val score of 0.3117):
#             {'n_estimators': 50, 'learning_rate': 100, 'subsample': 1, 'max_features': 0.7, 'max_depth': 6, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 25}
#             Current best combo (with val score 0.3376):
#                     {'n_estimators': 50, 'learning_rate': 100, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 6, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 25}
#         Has trained 208 of 8467200 combinations so far
#
# Best combo after this hyperparameter: (1, 6, 2, 2, 1, 0, 2, 25) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 3
# Hyperparameter: n_estimators (index: 0)
#
# Already Trained and Tested combination (val score of 0.3376):
#             {'n_estimators': 25, 'learning_rate': 100, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 6, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 25}
#             Current best combo (with val score 0.3376):
#                     {'n_estimators': 50, 'learning_rate': 100, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 6, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 25}
#         Has trained 208 of 8467200 combinations so far
# Already Trained and Tested combination (val score of 0.3376):
#             {'n_estimators': 50, 'learning_rate': 100, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 6, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 25}
#             Current best combo (with val score 0.3376):
#                     {'n_estimators': 50, 'learning_rate': 100, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 6, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 25}
#         Has trained 208 of 8467200 combinations so far
# Already Trained and Tested combination (val score of 0.3376):
#             {'n_estimators': 100, 'learning_rate': 100, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 6, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 25}
#             Current best combo (with val score 0.3376):
#                     {'n_estimators': 50, 'learning_rate': 100, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 6, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 25}
#         Has trained 208 of 8467200 combinations so far
# Already Trained and Tested combination (val score of 0.3376):
#             {'n_estimators': 200, 'learning_rate': 100, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 6, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 25}
#             Current best combo (with val score 0.3376):
#                     {'n_estimators': 50, 'learning_rate': 100, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 6, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 25}
#         Has trained 208 of 8467200 combinations so far
#
# Best combo after this hyperparameter: (1, 6, 2, 2, 1, 0, 2, 25) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 3
# Hyperparameter: ccp_alpha (index: 6)
#
# Already Trained and Tested combination (val score of 0.2403):
#             {'n_estimators': 50, 'learning_rate': 100, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 6, 'tol': 0.0001, 'ccp_alpha': 0.0001, 'features': 25}
#             Current best combo (with val score 0.3376):
#                     {'n_estimators': 50, 'learning_rate': 100, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 6, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 25}
#         Has trained 208 of 8467200 combinations so far
# Already Trained and Tested combination (val score of 0.2139):
#             {'n_estimators': 50, 'learning_rate': 100, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 6, 'tol': 0.0001, 'ccp_alpha': 0.001, 'features': 25}
#             Current best combo (with val score 0.3376):
#                     {'n_estimators': 50, 'learning_rate': 100, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 6, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 25}
#         Has trained 208 of 8467200 combinations so far
# Already Trained and Tested combination (val score of 0.3376):
#             {'n_estimators': 50, 'learning_rate': 100, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 6, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 25}
#             Current best combo (with val score 0.3376):
#                     {'n_estimators': 50, 'learning_rate': 100, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 6, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 25}
#         Has trained 208 of 8467200 combinations so far
# Already Trained and Tested combination (val score of 0.1556):
#             {'n_estimators': 50, 'learning_rate': 100, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 6, 'tol': 0.0001, 'ccp_alpha': 0.1, 'features': 25}
#             Current best combo (with val score 0.3376):
#                     {'n_estimators': 50, 'learning_rate': 100, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 6, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 25}
#         Has trained 208 of 8467200 combinations so far
# Already Trained and Tested combination (val score of 0.1556):
#             {'n_estimators': 50, 'learning_rate': 100, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 6, 'tol': 0.0001, 'ccp_alpha': 1, 'features': 25}
#             Current best combo (with val score 0.3376):
#                     {'n_estimators': 50, 'learning_rate': 100, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 6, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 25}
#         Has trained 208 of 8467200 combinations so far
# Already Trained and Tested combination (val score of 0.1556):
#             {'n_estimators': 50, 'learning_rate': 100, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 6, 'tol': 0.0001, 'ccp_alpha': 10, 'features': 25}
#             Current best combo (with val score 0.3376):
#                     {'n_estimators': 50, 'learning_rate': 100, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 6, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 25}
#         Has trained 208 of 8467200 combinations so far
#
# Best combo after this hyperparameter: (1, 6, 2, 2, 1, 0, 2, 25) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 3
# Hyperparameter: tol (index: 5)
#
# Already Trained and Tested combination (val score of 0.3376):
#             {'n_estimators': 50, 'learning_rate': 100, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 6, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 25}
#             Current best combo (with val score 0.3376):
#                     {'n_estimators': 50, 'learning_rate': 100, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 6, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 25}
#         Has trained 208 of 8467200 combinations so far
# Already Trained and Tested combination (val score of 0.3376):
#             {'n_estimators': 50, 'learning_rate': 100, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 6, 'tol': 0.001, 'ccp_alpha': 0.01, 'features': 25}
#             Current best combo (with val score 0.3376):
#                     {'n_estimators': 50, 'learning_rate': 100, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 6, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 25}
#         Has trained 208 of 8467200 combinations so far
# Already Trained and Tested combination (val score of 0.3376):
#             {'n_estimators': 50, 'learning_rate': 100, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 6, 'tol': 0.01, 'ccp_alpha': 0.01, 'features': 25}
#             Current best combo (with val score 0.3376):
#                     {'n_estimators': 50, 'learning_rate': 100, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 6, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 25}
#         Has trained 208 of 8467200 combinations so far
# Already Trained and Tested combination (val score of 0.3376):
#             {'n_estimators': 50, 'learning_rate': 100, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 6, 'tol': 0.1, 'ccp_alpha': 0.01, 'features': 25}
#             Current best combo (with val score 0.3376):
#                     {'n_estimators': 50, 'learning_rate': 100, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 6, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 25}
#         Has trained 208 of 8467200 combinations so far
# Already Trained and Tested combination (val score of 0.3376):
#             {'n_estimators': 50, 'learning_rate': 100, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 6, 'tol': 1, 'ccp_alpha': 0.01, 'features': 25}
#             Current best combo (with val score 0.3376):
#                     {'n_estimators': 50, 'learning_rate': 100, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 6, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 25}
#         Has trained 208 of 8467200 combinations so far
# Already Trained and Tested combination (val score of 0.3376):
#             {'n_estimators': 50, 'learning_rate': 100, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 6, 'tol': 10, 'ccp_alpha': 0.01, 'features': 25}
#             Current best combo (with val score 0.3376):
#                     {'n_estimators': 50, 'learning_rate': 100, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 6, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 25}
#         Has trained 208 of 8467200 combinations so far
#
# Best combo after this hyperparameter: (1, 6, 2, 2, 1, 0, 2, 25) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 3
# Hyperparameter: learning_rate (index: 1)
#
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 50, 'learning_rate': 0.0001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 6, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 25}
#             Current best combo (with val score 0.3376):
#                     {'n_estimators': 50, 'learning_rate': 100, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 6, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 25}
#         Has trained 208 of 8467200 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 50, 'learning_rate': 0.001, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 6, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 25}
#             Current best combo (with val score 0.3376):
#                     {'n_estimators': 50, 'learning_rate': 100, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 6, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 25}
#         Has trained 208 of 8467200 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 50, 'learning_rate': 0.01, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 6, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 25}
#             Current best combo (with val score 0.3376):
#                     {'n_estimators': 50, 'learning_rate': 100, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 6, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 25}
#         Has trained 208 of 8467200 combinations so far
# Already Trained and Tested combination (val score of 0.0033):
#             {'n_estimators': 50, 'learning_rate': 0.1, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 6, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 25}
#             Current best combo (with val score 0.3376):
#                     {'n_estimators': 50, 'learning_rate': 100, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 6, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 25}
#         Has trained 208 of 8467200 combinations so far
# Already Trained and Tested combination (val score of 0.146):
#             {'n_estimators': 50, 'learning_rate': 1, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 6, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 25}
#             Current best combo (with val score 0.3376):
#                     {'n_estimators': 50, 'learning_rate': 100, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 6, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 25}
#         Has trained 208 of 8467200 combinations so far
# Already Trained and Tested combination (val score of 0.2918):
#             {'n_estimators': 50, 'learning_rate': 10, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 6, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 25}
#             Current best combo (with val score 0.3376):
#                     {'n_estimators': 50, 'learning_rate': 100, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 6, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 25}
#         Has trained 208 of 8467200 combinations so far
# Already Trained and Tested combination (val score of 0.3376):
#             {'n_estimators': 50, 'learning_rate': 100, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 6, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 25}
#             Current best combo (with val score 0.3376):
#                     {'n_estimators': 50, 'learning_rate': 100, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 6, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 25}
#         Has trained 208 of 8467200 combinations so far
#
# Best combo after this hyperparameter: (1, 6, 2, 2, 1, 0, 2, 25) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
# Max Val Score:
#  0.337603
# Max Val Score Std:
#  0.053557
# Best Combo Train Score:
#  0.323712
# Best Combo Train Score Std:
#  0.062315
# Max Combo Index:
#  (1, 6, 2, 2, 1, 0, 2, 25) out of [4, 7, 5, 5, 7, 6, 6, 48] (note best combo is 0-indexed)
# Max Combo Hyperparamer Combination:
#  {'n_estimators': 50, 'learning_rate': 100, 'subsample': 0.7, 'max_features': 0.7, 'max_depth': 6, 'tol': 0.0001, 'ccp_alpha': 0.01, 'features': 25}
# Max Combo Features:
#  ('procedure_225792', 'ventilation_used', 'procedure_226475', 'lods_score', 'procedure_225802', 'hospital_stay_duration', 'procedure_224276', 'procedure_229519', 'procedure_226236', 'race_AMERICAN INDIAN/ALASKA NATIVE', 'race_ASIAN', 'race_ASIAN - ASIAN INDIAN', 'race_ASIAN - CHINESE', 'race_ASIAN - KOREAN', 'race_ASIAN - SOUTH EAST ASIAN', 'race_BLACK/AFRICAN', 'race_BLACK/AFRICAN AMERICAN', 'race_BLACK/CAPE VERDEAN', 'race_BLACK/CARIBBEAN ISLAND', 'race_HISPANIC OR LATINO', 'race_HISPANIC/LATINO - CENTRAL AMERICAN', 'race_HISPANIC/LATINO - COLUMBIAN', 'race_HISPANIC/LATINO - CUBAN', 'race_HISPANIC/LATINO - DOMINICAN', 'race_HISPANIC/LATINO - GUATEMALAN', 'race_HISPANIC/LATINO - HONDURAN', 'race_HISPANIC/LATINO - MEXICAN', 'race_HISPANIC/LATINO - PUERTO RICAN', 'race_HISPANIC/LATINO - SALVADORAN', 'race_MULTIPLE RACE/ETHNICITY', 'race_NATIVE HAWAIIAN OR OTHER PACIFIC ISLANDER', 'race_OTHER', 'race_PATIENT DECLINED TO ANSWER', 'race_PORTUGUESE', 'race_SOUTH AMERICAN', 'race_UNABLE TO OBTAIN', 'race_WHITE', 'race_WHITE - BRAZILIAN', 'race_WHITE - EASTERN EUROPEAN', 'race_WHITE - OTHER EUROPEAN', 'race_WHITE - RUSSIAN', 'race_UNKNOWN', 'oasis_score', 'procedure_224267', 'icu_stay_duration', 'procedure_229580', 'procedure_224270', 'procedure_225446', 'procedure_225400', 'procedure_221223', 'unique_drugs', 'procedure_227712', 'procedure_224263', 'creatinine', 'heart_rate', 'item_51301', 'anchor_age', 'spo2')
# % Combos Checked: 208 out of 8467200 which is 0.002457%
