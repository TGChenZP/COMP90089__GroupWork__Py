# %% [markdown]
# # Tuning Script

# %%
# Parameters subject to change in every script - involved in naming

MODEL = 'dtc'
PREPROCESSING = 'normalise'
TUNER = 'yangzhoub'
OPTIMISED_METRIC = 'f1'

# %% [markdown]
# ---

# %%
# detect whether this is a google environment

COLAB_ENVIRONMENT = False

try:
    from google.colab import drive
    drive.mount('/content/drive')
    COLAB_ENVIRONMENT = True
except:
    pass
# Out:
# Mounted at /content/drive

# %%
import sys
import os
import pickle

if COLAB_ENVIRONMENT:
    home_directory = './drive/MyDrive/LAB/COMP90089__GroupWork__Py/' # my home directory is stored in ./LAB of google drive
    if MODEL == 'ebr':
        # !pip install interpret==0.5.0
    elif MODEL == 'cbr':
        # !pip install catboost
    elif MODEL in ['tf', 'mlp']:
        # !pip install PyTorch2Sklearn
    # !pip install JXAutoML
else:
    home_directory = '../../'

from JXAutoML.YangZhouB_10CV import YangZhouB_10CV as Tuner

import pandas as pd
# Out:
# Collecting JXAutoML
#   Downloading JXAutoML-0.4.4-py3-none-any.whl.metadata (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.2/67.2 kB 6.5 MB/s eta 0:00:00
# Downloading JXAutoML-0.4.4-py3-none-any.whl (52 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.1/52.1 kB 5.2 MB/s eta 0:00:00
# Installing collected packages: JXAutoML
# Successfully installed JXAutoML-0.4.4

# %%
# Parameters that are same for every script

FOLDS = 10  # we have decided to do 10 fold validation

SEED = 42

TASK_TYPE = 'Classification'  # this task is a classification task

# we have decided to tune features as hp
TUNE_FEATURES_AS_HYPERPARAMETERS = True

# %% [markdown]
# ---

# %%
# model to use to tune
from sklearn.tree import DecisionTreeClassifier as clf

# what values to try for each hyperparameter
parameter_choices = {
    'max_depth': (3, 6, 12, 24, 48, 96, 192),
    'max_features': (0.4, 0.55, 0.7, 0.85, 1),
    'ccp_alpha': (0.00000001, 0.000001, 0.0001, 0.01, 0.1),
    'splitter': ('best', 'random')
}

# what values to set non-tuneable parameters/hyperparameters
non_tunable_hyperparameters_dict = {
                                    'random_state': SEED,
                                    }

# %% [markdown]
# ---

# %% [markdown]
# Read in and Prepare Data

# %%
# Import data and store as lists

train_x_list = []
train_y_list = []
val_x_list = []
val_y_list = []

for i in range(FOLDS):
    train_data = pd.read_csv(
        f'{home_directory}data/curated/modelling/{PREPROCESSING}/train_{i}.csv')
    val_data = pd.read_csv(
        f'{home_directory}data/curated/modelling/{PREPROCESSING}/val_{i}.csv')

    # get the correct rows for X and y
    train_x = train_data.drop(
        ['mortality_status', 'subject_id', 'hadm_id', 'stay_id'], axis=1)
    train_y = train_data['mortality_status']
    val_x = val_data.drop(
        ['mortality_status', 'subject_id', 'hadm_id', 'stay_id'], axis=1)
    val_y = val_data['mortality_status']

    train_x_list.append(train_x)
    train_y_list.append(train_y)
    val_x_list.append(val_x)
    val_y_list.append(val_y)

# %%
# Import feature importance ordering

with open(f'{home_directory}models/xgb_feature_importance_ordering_{PREPROCESSING}.pickle', 'rb') as f:
    feature_importance_ordering = pickle.load(f)

# %% [markdown]
# Set parameters

# %%
# initialisation
tuner = Tuner()

print('---')

# define what model we are tuning
tuner.read_in_model(clf, TASK_TYPE, optimised_metric=OPTIMISED_METRIC)

print('---')

# read in the data for training and validation
tuner.read_in_data(train_x_list, train_y_list, val_x_list, val_y_list)

print('---')

# set what hp values to tune
tuner.set_hyperparameters(parameter_choices)
# WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

# set up hp values that need to be changed from default but NOT to be tuned
tuner.set_non_tuneable_hyperparameters(non_tunable_hyperparameters_dict)

print('---')

# set up feature importance ordering

if TUNE_FEATURES_AS_HYPERPARAMETERS:
    tuner.set_features(feature_importance_ordering)
    # WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

try:  # try to read in previous results to continue tuning ...
    tuner.read_in_tuning_result_df(
        f'{home_directory}models/tuning/{TUNER}_{MODEL}_{PREPROCESSING}.csv')
except:
    print('No previous tuning data read in')

print('---')

# set up where to save the tuning result csv
tuner.set_tuning_result_saving_address(
    f'{home_directory}models/tuning/{TUNER}_{MODEL}_{PREPROCESSING}.csv')

print('---')

# set up where to save the current best model
tuner.set_best_model_saving_address(
    f'{home_directory}models/tmp_models/{TUNER}_{MODEL}_{PREPROCESSING}')
# Out:
# YangZhouB Initialised
# ---
# Successfully read in model <class 'sklearn.tree._classes.DecisionTreeClassifier'>, which is a Classification model optimising for f1
# ---
# Read in Train X data list
# Read in Train y data list
# Read in Val X data list
# Read in Val y data list
# ---
# Successfully recorded hyperparameter choices
# ---
# Successfully recorded non_tuneable_hyperparameter choices
# ---
# Successfully recorded tuneable feature combination choices and updated relevant internal structures
# ---
# No previous tuning data read in
# ---
# Successfully set tuning output address
# ---
# Successfully set best model output address

# %%
# ignore warnings

import warnings
warnings.filterwarnings("ignore")

# %%
# begin tuning ... (or continue training)

tuner.tune()
# Out:
# Streaming output truncated to the last 5000 lines.
#                 {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 1e-06, 'splitter': 'best', 'features': 25},
#             Current best combo with val score 0.4338:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 5}
# Trained and Tested combination 877 of 16800, taking 0.01 seconds to get val score of 0.2261:
#                 {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 1e-06, 'splitter': 'random', 'features': 24},
#             Current best combo with val score 0.4338:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 5}
# Trained and Tested combination 878 of 16800, taking 0.02 seconds to get val score of 0.2522:
#                 {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 1e-06, 'splitter': 'random', 'features': 26},
#             Current best combo with val score 0.4338:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 5}
# Already Trained and Tested combination (val score of 0.2037):
#             {'max_depth': 96, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 25}
#             Current best combo (with val score 0.4338):
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 5}
#         Has trained 878 of 16800 combinations so far
# Already Trained and Tested combination (val score of 0.0641):
#             {'max_depth': 192, 'max_features': 0.55, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 25}
#             Current best combo (with val score 0.4338):
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 5}
#         Has trained 878 of 16800 combinations so far
# Already Trained and Tested combination (val score of 0.2037):
#             {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 1e-06, 'splitter': 'best', 'features': 25}
#             Current best combo (with val score 0.4338):
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 5}
#         Has trained 878 of 16800 combinations so far
# Already Trained and Tested combination (val score of 0.1982):
#             {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 25}
#             Current best combo (with val score 0.4338):
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 5}
#         Has trained 878 of 16800 combinations so far
# Trained and Tested combination 879 of 16800, taking 0.02 seconds to get val score of 0.184:
#                 {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 24},
#             Current best combo with val score 0.4338:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 5}
# Trained and Tested combination 880 of 16800, taking 0.03 seconds to get val score of 0.1773:
#                 {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 26},
#             Current best combo with val score 0.4338:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 5}
# Already Trained and Tested combination (val score of 0.2261):
#             {'max_depth': 96, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 24}
#             Current best combo (with val score 0.4338):
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 5}
#         Has trained 880 of 16800 combinations so far
# Already Trained and Tested combination (val score of 0.2975):
#             {'max_depth': 192, 'max_features': 0.55, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 24}
#             Current best combo (with val score 0.4338):
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 5}
#         Has trained 880 of 16800 combinations so far
# Already Trained and Tested combination (val score of 0.2261):
#             {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 1e-06, 'splitter': 'random', 'features': 24}
#             Current best combo (with val score 0.4338):
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 5}
#         Has trained 880 of 16800 combinations so far
# Already Trained and Tested combination (val score of 0.184):
#             {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 24}
#             Current best combo (with val score 0.4338):
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 5}
#         Has trained 880 of 16800 combinations so far
# Trained and Tested combination 881 of 16800, taking 0.01 seconds to get val score of 0.2996:
#                 {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 23},
#             Current best combo with val score 0.4338:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 5}
# Already Trained and Tested combination (val score of 0.1982):
#             {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 25}
#             Current best combo (with val score 0.4338):
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 5}
#         Has trained 881 of 16800 combinations so far
# Already Trained and Tested combination (val score of 0.2522):
#             {'max_depth': 96, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 26}
#             Current best combo (with val score 0.4338):
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 5}
#         Has trained 881 of 16800 combinations so far
# Already Trained and Tested combination (val score of 0.3458):
#             {'max_depth': 192, 'max_features': 0.55, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 26}
#             Current best combo (with val score 0.4338):
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 5}
#         Has trained 881 of 16800 combinations so far
# Already Trained and Tested combination (val score of 0.2522):
#             {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 1e-06, 'splitter': 'random', 'features': 26}
#             Current best combo (with val score 0.4338):
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 5}
#         Has trained 881 of 16800 combinations so far
# Already Trained and Tested combination (val score of 0.1773):
#             {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 26}
#             Current best combo (with val score 0.4338):
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 5}
#         Has trained 881 of 16800 combinations so far
# Already Trained and Tested combination (val score of 0.1982):
#             {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 25}
#             Current best combo (with val score 0.4338):
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 5}
#         Has trained 881 of 16800 combinations so far
# Trained and Tested combination 882 of 16800, taking 0.01 seconds to get val score of 0.2833:
#                 {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 27},
#             Current best combo with val score 0.4338:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 5}
# % Combos Checked Thus Far: 882 out of 16800 which is 5.25%
# Cruising Coordrdinate 130 of 264
#
# Cruise suspended due to suspicious case
# Guidance: round 39
#
# 	round 39 iteration:  0
#
# % Combos Checked Thus Far: 882 out of 16800 which is 5.25%
# Cruising Coordrdinate 131 of 264
#
# Cruising Coordrdinate 132 of 264
#
# Cruising Coordrdinate 133 of 264
#
# Cruising Coordrdinate 134 of 264
#
# Cruise suspended due to suspicious case
# Guidance: round 40
#
# 	round 40 iteration:  0
#
# Trained and Tested combination 883 of 16800, taking 0.01 seconds to get val score of 0.108:
#                 {'max_depth': 12, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 25},
#             Current best combo with val score 0.4338:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 5}
# Already Trained and Tested combination (val score of 0.2371):
#             {'max_depth': 48, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 25}
#             Current best combo (with val score 0.4338):
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 5}
#         Has trained 883 of 16800 combinations so far
# Trained and Tested combination 884 of 16800, taking 0.01 seconds to get val score of 0.2312:
#                 {'max_depth': 24, 'max_features': 0.85, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 25},
#             Current best combo with val score 0.4338:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 5}
# Trained and Tested combination 885 of 16800, taking 0.0 seconds to get val score of 0.1684:
#                 {'max_depth': 24, 'max_features': 1, 'ccp_alpha': 1e-06, 'splitter': 'random', 'features': 25},
#             Current best combo with val score 0.4338:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 5}
# Already Trained and Tested combination (val score of 0.2323):
#             {'max_depth': 24, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 25}
#             Current best combo (with val score 0.4338):
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 5}
#         Has trained 885 of 16800 combinations so far
# Trained and Tested combination 886 of 16800, taking 0.0 seconds to get val score of 0.2973:
#                 {'max_depth': 24, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 24},
#             Current best combo with val score 0.4338:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 5}
# Trained and Tested combination 887 of 16800, taking 0.01 seconds to get val score of 0.1965:
#                 {'max_depth': 24, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 26},
#             Current best combo with val score 0.4338:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 5}
# 	round 40 iteration:  1
#
# Trained and Tested combination 888 of 16800, taking 0.01 seconds to get val score of 0.2599:
#                 {'max_depth': 12, 'max_features': 0.85, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 25},
#             Current best combo with val score 0.4338:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 5}
# Trained and Tested combination 889 of 16800, taking 0.01 seconds to get val score of 0.2324:
#                 {'max_depth': 48, 'max_features': 0.85, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 25},
#             Current best combo with val score 0.4338:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 5}
# Trained and Tested combination 890 of 16800, taking 0.01 seconds to get val score of 0.2948:
#                 {'max_depth': 24, 'max_features': 0.7, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 25},
#             Current best combo with val score 0.4338:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 5}
# Already Trained and Tested combination (val score of 0.1684):
#             {'max_depth': 24, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 25}
#             Current best combo (with val score 0.4338):
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 5}
#         Has trained 890 of 16800 combinations so far
# Trained and Tested combination 891 of 16800, taking 0.01 seconds to get val score of 0.2312:
#                 {'max_depth': 24, 'max_features': 0.85, 'ccp_alpha': 1e-06, 'splitter': 'random', 'features': 25},
#             Current best combo with val score 0.4338:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 5}
# Trained and Tested combination 892 of 16800, taking 0.03 seconds to get val score of 0.311:
#                 {'max_depth': 24, 'max_features': 0.85, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 25},
#             Current best combo with val score 0.4338:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 5}
# Trained and Tested combination 893 of 16800, taking 0.01 seconds to get val score of 0.283:
#                 {'max_depth': 24, 'max_features': 0.85, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 24},
#             Current best combo with val score 0.4338:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 5}
# Trained and Tested combination 894 of 16800, taking 0.01 seconds to get val score of 0.2818:
#                 {'max_depth': 24, 'max_features': 0.85, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 26},
#             Current best combo with val score 0.4338:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 5}
# Trained and Tested combination 895 of 16800, taking 0.0 seconds to get val score of 0.108:
#                 {'max_depth': 12, 'max_features': 1, 'ccp_alpha': 1e-06, 'splitter': 'random', 'features': 25},
#             Current best combo with val score 0.4338:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 5}
# Trained and Tested combination 896 of 16800, taking 0.01 seconds to get val score of 0.2371:
#                 {'max_depth': 48, 'max_features': 1, 'ccp_alpha': 1e-06, 'splitter': 'random', 'features': 25},
#             Current best combo with val score 0.4338:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 5}
# Already Trained and Tested combination (val score of 0.2312):
#             {'max_depth': 24, 'max_features': 0.85, 'ccp_alpha': 1e-06, 'splitter': 'random', 'features': 25}
#             Current best combo (with val score 0.4338):
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 5}
#         Has trained 896 of 16800 combinations so far
# Already Trained and Tested combination (val score of 0.1684):
#             {'max_depth': 24, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 25}
#             Current best combo (with val score 0.4338):
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 5}
#         Has trained 896 of 16800 combinations so far
# Trained and Tested combination 897 of 16800, taking 0.01 seconds to get val score of 0.1684:
#                 {'max_depth': 24, 'max_features': 1, 'ccp_alpha': 0.0001, 'splitter': 'random', 'features': 25},
#             Current best combo with val score 0.4338:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 5}
# Trained and Tested combination 898 of 16800, taking 0.01 seconds to get val score of 0.2323:
#                 {'max_depth': 24, 'max_features': 1, 'ccp_alpha': 1e-06, 'splitter': 'best', 'features': 25},
#             Current best combo with val score 0.4338:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 5}
# Trained and Tested combination 899 of 16800, taking 0.01 seconds to get val score of 0.2973:
#                 {'max_depth': 24, 'max_features': 1, 'ccp_alpha': 1e-06, 'splitter': 'random', 'features': 24},
#             Current best combo with val score 0.4338:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 5}
# Trained and Tested combination 900 of 16800, taking 0.01 seconds to get val score of 0.1965:
#                 {'max_depth': 24, 'max_features': 1, 'ccp_alpha': 1e-06, 'splitter': 'random', 'features': 26},
#             Current best combo with val score 0.4338:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 5}
# Trained and Tested combination 901 of 16800, taking 0.01 seconds to get val score of 0.2486:
#                 {'max_depth': 12, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 25},
#             Current best combo with val score 0.4338:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 5}
# Trained and Tested combination 902 of 16800, taking 0.01 seconds to get val score of 0.2166:
#                 {'max_depth': 48, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 25},
#             Current best combo with val score 0.4338:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 5}
# Already Trained and Tested combination (val score of 0.311):
#             {'max_depth': 24, 'max_features': 0.85, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 25}
#             Current best combo (with val score 0.4338):
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 5}
#         Has trained 902 of 16800 combinations so far
# Already Trained and Tested combination (val score of 0.2323):
#             {'max_depth': 24, 'max_features': 1, 'ccp_alpha': 1e-06, 'splitter': 'best', 'features': 25}
#             Current best combo (with val score 0.4338):
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 5}
#         Has trained 902 of 16800 combinations so far
# Already Trained and Tested combination (val score of 0.1684):
#             {'max_depth': 24, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 25}
#             Current best combo (with val score 0.4338):
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 5}
#         Has trained 902 of 16800 combinations so far
# Trained and Tested combination 903 of 16800, taking 0.01 seconds to get val score of 0.2821:
#                 {'max_depth': 24, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 24},
#             Current best combo with val score 0.4338:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 5}
# Trained and Tested combination 904 of 16800, taking 0.01 seconds to get val score of 0.2357:
#                 {'max_depth': 24, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 26},
#             Current best combo with val score 0.4338:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 5}
# Trained and Tested combination 905 of 16800, taking 0.0 seconds to get val score of 0.1083:
#                 {'max_depth': 12, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 24},
#             Current best combo with val score 0.4338:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 5}
# Trained and Tested combination 906 of 16800, taking 0.01 seconds to get val score of 0.3187:
#                 {'max_depth': 48, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 24},
#             Current best combo with val score 0.4338:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 5}
# Already Trained and Tested combination (val score of 0.283):
#             {'max_depth': 24, 'max_features': 0.85, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 24}
#             Current best combo (with val score 0.4338):
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 5}
#         Has trained 906 of 16800 combinations so far
# Already Trained and Tested combination (val score of 0.2973):
#             {'max_depth': 24, 'max_features': 1, 'ccp_alpha': 1e-06, 'splitter': 'random', 'features': 24}
#             Current best combo (with val score 0.4338):
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 5}
#         Has trained 906 of 16800 combinations so far
# Already Trained and Tested combination (val score of 0.2821):
#             {'max_depth': 24, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 24}
#             Current best combo (with val score 0.4338):
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 5}
#         Has trained 906 of 16800 combinations so far
# Trained and Tested combination 907 of 16800, taking 0.01 seconds to get val score of 0.2656:
#                 {'max_depth': 24, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 23},
#             Current best combo with val score 0.4338:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 5}
# Already Trained and Tested combination (val score of 0.1684):
#             {'max_depth': 24, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 25}
#             Current best combo (with val score 0.4338):
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 5}
#         Has trained 907 of 16800 combinations so far
# Trained and Tested combination 908 of 16800, taking 0.0 seconds to get val score of 0.1948:
#                 {'max_depth': 12, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 26},
#             Current best combo with val score 0.4338:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 5}
# Trained and Tested combination 909 of 16800, taking 0.01 seconds to get val score of 0.1749:
#                 {'max_depth': 48, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 26},
#             Current best combo with val score 0.4338:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 5}
# Already Trained and Tested combination (val score of 0.2818):
#             {'max_depth': 24, 'max_features': 0.85, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 26}
#             Current best combo (with val score 0.4338):
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 5}
#         Has trained 909 of 16800 combinations so far
# Already Trained and Tested combination (val score of 0.1965):
#             {'max_depth': 24, 'max_features': 1, 'ccp_alpha': 1e-06, 'splitter': 'random', 'features': 26}
#             Current best combo (with val score 0.4338):
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 5}
#         Has trained 909 of 16800 combinations so far
# Already Trained and Tested combination (val score of 0.2357):
#             {'max_depth': 24, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 26}
#             Current best combo (with val score 0.4338):
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 5}
#         Has trained 909 of 16800 combinations so far
# Already Trained and Tested combination (val score of 0.1684):
#             {'max_depth': 24, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 25}
#             Current best combo (with val score 0.4338):
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 5}
#         Has trained 909 of 16800 combinations so far
# Trained and Tested combination 910 of 16800, taking 0.0 seconds to get val score of 0.1924:
#                 {'max_depth': 24, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 27},
#             Current best combo with val score 0.4338:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 5}
# % Combos Checked Thus Far: 910 out of 16800 which is 5.416667%
# Cruising Coordrdinate 135 of 264
#
# Cruising Coordrdinate 136 of 264
#
# Cruise suspended due to suspicious case
# Guidance: round 41
#
# 	round 41 iteration:  0
#
# % Combos Checked Thus Far: 910 out of 16800 which is 5.416667%
# Cruising Coordrdinate 137 of 264
#
# Cruising Coordrdinate 138 of 264
#
# Cruising Coordrdinate 139 of 264
#
# Cruising Coordrdinate 140 of 264
#
# Cruising Coordrdinate 141 of 264
#
# Cruise suspended due to suspicious case
# Guidance: round 42
#
# 	round 42 iteration:  0
#
# Trained and Tested combination 911 of 16800, taking 0.01 seconds to get val score of 0.1547:
#                 {'max_depth': 12, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 25},
#             Current best combo with val score 0.4338:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 5}
# Already Trained and Tested combination (val score of 0.1982):
#             {'max_depth': 48, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 25}
#             Current best combo (with val score 0.4338):
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 5}
#         Has trained 911 of 16800 combinations so far
# Trained and Tested combination 912 of 16800, taking 0.01 seconds to get val score of 0.2993:
#                 {'max_depth': 24, 'max_features': 0.55, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 25},
#             Current best combo with val score 0.4338:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 5}
# Trained and Tested combination 913 of 16800, taking 0.01 seconds to get val score of 0.1977:
#                 {'max_depth': 24, 'max_features': 0.4, 'ccp_alpha': 1e-06, 'splitter': 'random', 'features': 25},
#             Current best combo with val score 0.4338:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 5}
# Already Trained and Tested combination (val score of 0.2061):
#             {'max_depth': 24, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 25}
#             Current best combo (with val score 0.4338):
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 5}
#         Has trained 913 of 16800 combinations so far
# Trained and Tested combination 914 of 16800, taking 0.01 seconds to get val score of 0.3319:
#                 {'max_depth': 24, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 24},
#             Current best combo with val score 0.4338:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 5}
# Trained and Tested combination 915 of 16800, taking 0.01 seconds to get val score of 0.3019:
#                 {'max_depth': 24, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 26},
#             Current best combo with val score 0.4338:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 5}
# 	round 42 iteration:  1
#
# Trained and Tested combination 916 of 16800, taking 0.01 seconds to get val score of 0.2802:
#                 {'max_depth': 12, 'max_features': 0.55, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 25},
#             Current best combo with val score 0.4338:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 5}
# Trained and Tested combination 917 of 16800, taking 0.02 seconds to get val score of 0.2358:
#                 {'max_depth': 48, 'max_features': 0.55, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 25},
#             Current best combo with val score 0.4338:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 5}
# Already Trained and Tested combination (val score of 0.1977):
#             {'max_depth': 24, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 25}
#             Current best combo (with val score 0.4338):
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 5}
#         Has trained 917 of 16800 combinations so far
# Already Trained and Tested combination (val score of 0.2948):
#             {'max_depth': 24, 'max_features': 0.7, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 25}
#             Current best combo (with val score 0.4338):
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 5}
#         Has trained 917 of 16800 combinations so far
# Trained and Tested combination 918 of 16800, taking 0.01 seconds to get val score of 0.2993:
#                 {'max_depth': 24, 'max_features': 0.55, 'ccp_alpha': 1e-06, 'splitter': 'random', 'features': 25},
#             Current best combo with val score 0.4338:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 5}
# Trained and Tested combination 919 of 16800, taking 0.03 seconds to get val score of 0.064:
#                 {'max_depth': 24, 'max_features': 0.55, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 25},
#             Current best combo with val score 0.4338:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 5}
# Trained and Tested combination 920 of 16800, taking 0.01 seconds to get val score of 0.3161:
#                 {'max_depth': 24, 'max_features': 0.55, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 24},
#             Current best combo with val score 0.4338:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 5}
# Trained and Tested combination 921 of 16800, taking 0.01 seconds to get val score of 0.334:
#                 {'max_depth': 24, 'max_features': 0.55, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 26},
#             Current best combo with val score 0.4338:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 5}
# Trained and Tested combination 922 of 16800, taking 0.01 seconds to get val score of 0.1547:
#                 {'max_depth': 12, 'max_features': 0.4, 'ccp_alpha': 1e-06, 'splitter': 'random', 'features': 25},
#             Current best combo with val score 0.4338:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 5}
# Trained and Tested combination 923 of 16800, taking 0.01 seconds to get val score of 0.1982:
#                 {'max_depth': 48, 'max_features': 0.4, 'ccp_alpha': 1e-06, 'splitter': 'random', 'features': 25},
#             Current best combo with val score 0.4338:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 5}
# Already Trained and Tested combination (val score of 0.2993):
#             {'max_depth': 24, 'max_features': 0.55, 'ccp_alpha': 1e-06, 'splitter': 'random', 'features': 25}
#             Current best combo (with val score 0.4338):
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 5}
#         Has trained 923 of 16800 combinations so far
# Already Trained and Tested combination (val score of 0.1977):
#             {'max_depth': 24, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 25}
#             Current best combo (with val score 0.4338):
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 5}
#         Has trained 923 of 16800 combinations so far
# Trained and Tested combination 924 of 16800, taking 0.01 seconds to get val score of 0.1977:
#                 {'max_depth': 24, 'max_features': 0.4, 'ccp_alpha': 0.0001, 'splitter': 'random', 'features': 25},
#             Current best combo with val score 0.4338:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 5}
# Trained and Tested combination 925 of 16800, taking 0.02 seconds to get val score of 0.2061:
#                 {'max_depth': 24, 'max_features': 0.4, 'ccp_alpha': 1e-06, 'splitter': 'best', 'features': 25},
#             Current best combo with val score 0.4338:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 5}
# Trained and Tested combination 926 of 16800, taking 0.01 seconds to get val score of 0.3319:
#                 {'max_depth': 24, 'max_features': 0.4, 'ccp_alpha': 1e-06, 'splitter': 'random', 'features': 24},
#             Current best combo with val score 0.4338:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 5}
# Trained and Tested combination 927 of 16800, taking 0.01 seconds to get val score of 0.3019:
#                 {'max_depth': 24, 'max_features': 0.4, 'ccp_alpha': 1e-06, 'splitter': 'random', 'features': 26},
#             Current best combo with val score 0.4338:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 5}
# Trained and Tested combination 928 of 16800, taking 0.02 seconds to get val score of 0.2084:
#                 {'max_depth': 12, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 25},
#             Current best combo with val score 0.4338:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 5}
# Trained and Tested combination 929 of 16800, taking 0.02 seconds to get val score of 0.2037:
#                 {'max_depth': 48, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 25},
#             Current best combo with val score 0.4338:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 5}
# Already Trained and Tested combination (val score of 0.064):
#             {'max_depth': 24, 'max_features': 0.55, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 25}
#             Current best combo (with val score 0.4338):
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 5}
#         Has trained 929 of 16800 combinations so far
# Already Trained and Tested combination (val score of 0.2061):
#             {'max_depth': 24, 'max_features': 0.4, 'ccp_alpha': 1e-06, 'splitter': 'best', 'features': 25}
#             Current best combo (with val score 0.4338):
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 5}
#         Has trained 929 of 16800 combinations so far
# Already Trained and Tested combination (val score of 0.1977):
#             {'max_depth': 24, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 25}
#             Current best combo (with val score 0.4338):
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 5}
#         Has trained 929 of 16800 combinations so far
# Trained and Tested combination 930 of 16800, taking 0.01 seconds to get val score of 0.1583:
#                 {'max_depth': 24, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 24},
#             Current best combo with val score 0.4338:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 5}
# Trained and Tested combination 931 of 16800, taking 0.02 seconds to get val score of 0.1773:
#                 {'max_depth': 24, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 26},
#             Current best combo with val score 0.4338:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 5}
# Trained and Tested combination 932 of 16800, taking 0.01 seconds to get val score of 0.2349:
#                 {'max_depth': 12, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 24},
#             Current best combo with val score 0.4338:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 5}
# Trained and Tested combination 933 of 16800, taking 0.01 seconds to get val score of 0.2261:
#                 {'max_depth': 48, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 24},
#             Current best combo with val score 0.4338:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 5}
# Already Trained and Tested combination (val score of 0.3161):
#             {'max_depth': 24, 'max_features': 0.55, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 24}
#             Current best combo (with val score 0.4338):
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 5}
#         Has trained 933 of 16800 combinations so far
# Already Trained and Tested combination (val score of 0.3319):
#             {'max_depth': 24, 'max_features': 0.4, 'ccp_alpha': 1e-06, 'splitter': 'random', 'features': 24}
#             Current best combo (with val score 0.4338):
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 5}
#         Has trained 933 of 16800 combinations so far
# Already Trained and Tested combination (val score of 0.1583):
#             {'max_depth': 24, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 24}
#             Current best combo (with val score 0.4338):
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 5}
#         Has trained 933 of 16800 combinations so far
# Trained and Tested combination 934 of 16800, taking 0.01 seconds to get val score of 0.2733:
#                 {'max_depth': 24, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 23},
#             Current best combo with val score 0.4338:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 5}
# Already Trained and Tested combination (val score of 0.1977):
#             {'max_depth': 24, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 25}
#             Current best combo (with val score 0.4338):
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 5}
#         Has trained 934 of 16800 combinations so far
# Trained and Tested combination 935 of 16800, taking 0.02 seconds to get val score of 0.2407:
#                 {'max_depth': 12, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 26},
#             Current best combo with val score 0.4338:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 5}
# Trained and Tested combination 936 of 16800, taking 0.01 seconds to get val score of 0.2522:
#                 {'max_depth': 48, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 26},
#             Current best combo with val score 0.4338:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 5}
# Already Trained and Tested combination (val score of 0.334):
#             {'max_depth': 24, 'max_features': 0.55, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 26}
#             Current best combo (with val score 0.4338):
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 5}
#         Has trained 936 of 16800 combinations so far
# Already Trained and Tested combination (val score of 0.3019):
#             {'max_depth': 24, 'max_features': 0.4, 'ccp_alpha': 1e-06, 'splitter': 'random', 'features': 26}
#             Current best combo (with val score 0.4338):
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 5}
#         Has trained 936 of 16800 combinations so far
# Already Trained and Tested combination (val score of 0.1773):
#             {'max_depth': 24, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 26}
#             Current best combo (with val score 0.4338):
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 5}
#         Has trained 936 of 16800 combinations so far
# Already Trained and Tested combination (val score of 0.1977):
#             {'max_depth': 24, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 25}
#             Current best combo (with val score 0.4338):
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 5}
#         Has trained 936 of 16800 combinations so far
# Trained and Tested combination 937 of 16800, taking 0.01 seconds to get val score of 0.2149:
#                 {'max_depth': 24, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 27},
#             Current best combo with val score 0.4338:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 5}
# % Combos Checked Thus Far: 937 out of 16800 which is 5.577381%
# Cruising Coordrdinate 142 of 264
#
# Cruise suspended due to suspicious case
# Guidance: round 43
#
# 	round 43 iteration:  0
#
# % Combos Checked Thus Far: 937 out of 16800 which is 5.577381%
# Cruising Coordrdinate 143 of 264
#
# Cruising Coordrdinate 144 of 264
#
# Cruise suspended due to suspicious case
# Guidance: round 44
#
# 	round 44 iteration:  0
#
# Trained and Tested combination 938 of 16800, taking 0.01 seconds to get val score of 0.243:
#                 {'max_depth': 6, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 25},
#             Current best combo with val score 0.4338:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 5}
# Trained and Tested combination 939 of 16800, taking 0.01 seconds to get val score of 0.1759:
#                 {'max_depth': 3, 'max_features': 0.55, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 25},
#             Current best combo with val score 0.4338:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 5}
# Trained and Tested combination 940 of 16800, taking 0.01 seconds to get val score of 0.3028:
#                 {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-06, 'splitter': 'best', 'features': 25},
#             Current best combo with val score 0.4338:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 5}
# Already Trained and Tested combination (val score of 0.0):
#             {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 25}
#             Current best combo (with val score 0.4338):
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 5}
#         Has trained 940 of 16800 combinations so far
# Trained and Tested combination 941 of 16800, taking 0.01 seconds to get val score of 0.1589:
#                 {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 24},
#             Current best combo with val score 0.4338:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 5}
# Trained and Tested combination 942 of 16800, taking 0.01 seconds to get val score of 0.2988:
#                 {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 26},
#             Current best combo with val score 0.4338:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 5}
# 	round 44 iteration:  1
#
# Trained and Tested combination 943 of 16800, taking 0.01 seconds to get val score of 0.243:
#                 {'max_depth': 6, 'max_features': 0.4, 'ccp_alpha': 1e-06, 'splitter': 'best', 'features': 25},
#             Current best combo with val score 0.4338:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 5}
# Trained and Tested combination 944 of 16800, taking 0.02 seconds to get val score of 0.1759:
#                 {'max_depth': 3, 'max_features': 0.55, 'ccp_alpha': 1e-06, 'splitter': 'best', 'features': 25},
#             Current best combo with val score 0.4338:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 5}
# Already Trained and Tested combination (val score of 0.3028):
#             {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 25}
#             Current best combo (with val score 0.4338):
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 5}
#         Has trained 944 of 16800 combinations so far
# Trained and Tested combination 945 of 16800, taking 0.01 seconds to get val score of 0.3028:
#                 {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 0.0001, 'splitter': 'best', 'features': 25},
#             Current best combo with val score 0.4338:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 5}
# Trained and Tested combination 946 of 16800, taking 0.0 seconds to get val score of 0.0:
#                 {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-06, 'splitter': 'random', 'features': 25},
#             Current best combo with val score 0.4338:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 5}
# Trained and Tested combination 947 of 16800, taking 0.01 seconds to get val score of 0.1589:
#                 {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-06, 'splitter': 'best', 'features': 24},
#             Current best combo with val score 0.4338:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 5}
# Trained and Tested combination 948 of 16800, taking 0.01 seconds to get val score of 0.2988:
# ...
#                     {'max_depth': 3, 'max_features': 0.85, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 7}
#         Has trained 1466 of 16800 combinations so far
# Trained and Tested combination 1467 of 16800, taking 0.0 seconds to get val score of 0.0033:
#                 {'max_depth': 24, 'max_features': 0.55, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 4},
#             Current best combo with val score 0.4694:
#                     {'max_depth': 3, 'max_features': 0.85, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 7}
# Trained and Tested combination 1468 of 16800, taking 0.01 seconds to get val score of 0.3767:
#                 {'max_depth': 24, 'max_features': 0.55, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 6},
#             Current best combo with val score 0.4694:
#                     {'max_depth': 3, 'max_features': 0.85, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 7}
# Already Trained and Tested combination (val score of 0.302):
#             {'max_depth': 12, 'max_features': 0.4, 'ccp_alpha': 1e-06, 'splitter': 'random', 'features': 5}
#             Current best combo (with val score 0.4694):
#                     {'max_depth': 3, 'max_features': 0.85, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 7}
#         Has trained 1468 of 16800 combinations so far
# Trained and Tested combination 1469 of 16800, taking 0.01 seconds to get val score of 0.295:
#                 {'max_depth': 48, 'max_features': 0.4, 'ccp_alpha': 1e-06, 'splitter': 'random', 'features': 5},
#             Current best combo with val score 0.4694:
#                     {'max_depth': 3, 'max_features': 0.85, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 7}
# Already Trained and Tested combination (val score of 0.3044):
#             {'max_depth': 24, 'max_features': 0.55, 'ccp_alpha': 1e-06, 'splitter': 'random', 'features': 5}
#             Current best combo (with val score 0.4694):
#                     {'max_depth': 3, 'max_features': 0.85, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 7}
#         Has trained 1469 of 16800 combinations so far
# Already Trained and Tested combination (val score of 0.2967):
#             {'max_depth': 24, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 5}
#             Current best combo (with val score 0.4694):
#                     {'max_depth': 3, 'max_features': 0.85, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 7}
#         Has trained 1469 of 16800 combinations so far
# Trained and Tested combination 1470 of 16800, taking 0.01 seconds to get val score of 0.2967:
#                 {'max_depth': 24, 'max_features': 0.4, 'ccp_alpha': 0.0001, 'splitter': 'random', 'features': 5},
#             Current best combo with val score 0.4694:
#                     {'max_depth': 3, 'max_features': 0.85, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 7}
# Already Trained and Tested combination (val score of 0.3083):
#             {'max_depth': 24, 'max_features': 0.4, 'ccp_alpha': 1e-06, 'splitter': 'best', 'features': 5}
#             Current best combo (with val score 0.4694):
#                     {'max_depth': 3, 'max_features': 0.85, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 7}
#         Has trained 1470 of 16800 combinations so far
# Trained and Tested combination 1471 of 16800, taking 0.0 seconds to get val score of 0.0033:
#                 {'max_depth': 24, 'max_features': 0.4, 'ccp_alpha': 1e-06, 'splitter': 'random', 'features': 4},
#             Current best combo with val score 0.4694:
#                     {'max_depth': 3, 'max_features': 0.85, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 7}
# Trained and Tested combination 1472 of 16800, taking 0.0 seconds to get val score of 0.383:
#                 {'max_depth': 24, 'max_features': 0.4, 'ccp_alpha': 1e-06, 'splitter': 'random', 'features': 6},
#             Current best combo with val score 0.4694:
#                     {'max_depth': 3, 'max_features': 0.85, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 7}
# % Combos Checked Thus Far: 1472 out of 16800 which is 8.761905%
# Cruising Coordrdinate 263 of 264
#
# Cruise suspended due to suspicious case
# Guidance: round 79
#
# 	round 79 iteration:  0
#
# Already Trained and Tested combination (val score of 0.2926):
#             {'max_depth': 6, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 5}
#             Current best combo (with val score 0.4694):
#                     {'max_depth': 3, 'max_features': 0.85, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 7}
#         Has trained 1472 of 16800 combinations so far
# Already Trained and Tested combination (val score of 0.349):
#             {'max_depth': 3, 'max_features': 0.55, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 5}
#             Current best combo (with val score 0.4694):
#                     {'max_depth': 3, 'max_features': 0.85, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 7}
#         Has trained 1472 of 16800 combinations so far
# Already Trained and Tested combination (val score of 0.4338):
#             {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-06, 'splitter': 'best', 'features': 5}
#             Current best combo (with val score 0.4694):
#                     {'max_depth': 3, 'max_features': 0.85, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 7}
#         Has trained 1472 of 16800 combinations so far
# Already Trained and Tested combination (val score of 0.0033):
#             {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 5}
#             Current best combo (with val score 0.4694):
#                     {'max_depth': 3, 'max_features': 0.85, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 7}
#         Has trained 1472 of 16800 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 4}
#             Current best combo (with val score 0.4694):
#                     {'max_depth': 3, 'max_features': 0.85, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 7}
#         Has trained 1472 of 16800 combinations so far
# Already Trained and Tested combination (val score of 0.4176):
#             {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 6}
#             Current best combo (with val score 0.4694):
#                     {'max_depth': 3, 'max_features': 0.85, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 7}
#         Has trained 1472 of 16800 combinations so far
# 	round 79 iteration:  1
#
# Trained and Tested combination 1473 of 16800, taking 0.0 seconds to get val score of 0.2926:
#                 {'max_depth': 6, 'max_features': 0.4, 'ccp_alpha': 1e-06, 'splitter': 'best', 'features': 5},
#             Current best combo with val score 0.4694:
#                     {'max_depth': 3, 'max_features': 0.85, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 7}
# Trained and Tested combination 1474 of 16800, taking 0.0 seconds to get val score of 0.349:
#                 {'max_depth': 3, 'max_features': 0.55, 'ccp_alpha': 1e-06, 'splitter': 'best', 'features': 5},
#             Current best combo with val score 0.4694:
#                     {'max_depth': 3, 'max_features': 0.85, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 7}
# Already Trained and Tested combination (val score of 0.4338):
#             {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 5}
#             Current best combo (with val score 0.4694):
#                     {'max_depth': 3, 'max_features': 0.85, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 7}
#         Has trained 1474 of 16800 combinations so far
# Trained and Tested combination 1475 of 16800, taking 0.0 seconds to get val score of 0.4338:
#                 {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 0.0001, 'splitter': 'best', 'features': 5},
#             Current best combo with val score 0.4694:
#                     {'max_depth': 3, 'max_features': 0.85, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 7}
# Trained and Tested combination 1476 of 16800, taking 0.0 seconds to get val score of 0.0033:
#                 {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-06, 'splitter': 'random', 'features': 5},
#             Current best combo with val score 0.4694:
#                     {'max_depth': 3, 'max_features': 0.85, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 7}
# Trained and Tested combination 1477 of 16800, taking 0.0 seconds to get val score of 0.0:
#                 {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-06, 'splitter': 'best', 'features': 4},
#             Current best combo with val score 0.4694:
#                     {'max_depth': 3, 'max_features': 0.85, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 7}
# Trained and Tested combination 1478 of 16800, taking 0.0 seconds to get val score of 0.4176:
#                 {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-06, 'splitter': 'best', 'features': 6},
#             Current best combo with val score 0.4694:
#                     {'max_depth': 3, 'max_features': 0.85, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 7}
# % Combos Checked Thus Far: 1478 out of 16800 which is 8.797619%
# Cruising Coordrdinate 264 of 264
#
# FINAL STAGE: Begin final Guidance system
#
#
# Guidance: round FINAL
#
# 	round FINAL iteration:  0
#
# Already Trained and Tested combination (val score of 0.1478):
#             {'max_depth': 6, 'max_features': 0.85, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 7}
#             Current best combo (with val score 0.4694):
#                     {'max_depth': 3, 'max_features': 0.85, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 7}
#         Has trained 1478 of 16800 combinations so far
# Already Trained and Tested combination (val score of 0.0185):
#             {'max_depth': 3, 'max_features': 0.7, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 7}
#             Current best combo (with val score 0.4694):
#                     {'max_depth': 3, 'max_features': 0.85, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 7}
#         Has trained 1478 of 16800 combinations so far
# Already Trained and Tested combination (val score of 0.0114):
#             {'max_depth': 3, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 7}
#             Current best combo (with val score 0.4694):
#                     {'max_depth': 3, 'max_features': 0.85, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 7}
#         Has trained 1478 of 16800 combinations so far
# Already Trained and Tested combination (val score of 0.4694):
#             {'max_depth': 3, 'max_features': 0.85, 'ccp_alpha': 1e-06, 'splitter': 'random', 'features': 7}
#             Current best combo (with val score 0.4694):
#                     {'max_depth': 3, 'max_features': 0.85, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 7}
#         Has trained 1478 of 16800 combinations so far
# Already Trained and Tested combination (val score of 0.432):
#             {'max_depth': 3, 'max_features': 0.85, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 7}
#             Current best combo (with val score 0.4694):
#                     {'max_depth': 3, 'max_features': 0.85, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 7}
#         Has trained 1478 of 16800 combinations so far
# Already Trained and Tested combination (val score of 0.4494):
#             {'max_depth': 3, 'max_features': 0.85, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 6}
#             Current best combo (with val score 0.4694):
#                     {'max_depth': 3, 'max_features': 0.85, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 7}
#         Has trained 1478 of 16800 combinations so far
# Already Trained and Tested combination (val score of 0.0908):
#             {'max_depth': 3, 'max_features': 0.85, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 8}
#             Current best combo (with val score 0.4694):
#                     {'max_depth': 3, 'max_features': 0.85, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 7}
#         Has trained 1478 of 16800 combinations so far
# 	round FINAL iteration:  1
#
# Trained and Tested combination 1479 of 16800, taking 0.0 seconds to get val score of 0.1478:
#                 {'max_depth': 6, 'max_features': 0.85, 'ccp_alpha': 1e-06, 'splitter': 'random', 'features': 7},
#             Current best combo with val score 0.4694:
#                     {'max_depth': 3, 'max_features': 0.85, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 7}
# Trained and Tested combination 1480 of 16800, taking 0.0 seconds to get val score of 0.0185:
#                 {'max_depth': 3, 'max_features': 0.7, 'ccp_alpha': 1e-06, 'splitter': 'random', 'features': 7},
#             Current best combo with val score 0.4694:
#                     {'max_depth': 3, 'max_features': 0.85, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 7}
# Trained and Tested combination 1481 of 16800, taking 0.0 seconds to get val score of 0.0114:
#                 {'max_depth': 3, 'max_features': 1, 'ccp_alpha': 1e-06, 'splitter': 'random', 'features': 7},
#             Current best combo with val score 0.4694:
#                     {'max_depth': 3, 'max_features': 0.85, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 7}
# Already Trained and Tested combination (val score of 0.4694):
#             {'max_depth': 3, 'max_features': 0.85, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 7}
#             Current best combo (with val score 0.4694):
#                     {'max_depth': 3, 'max_features': 0.85, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 7}
#         Has trained 1481 of 16800 combinations so far
# Trained and Tested combination 1482 of 16800, taking 0.0 seconds to get val score of 0.4694:
#                 {'max_depth': 3, 'max_features': 0.85, 'ccp_alpha': 0.0001, 'splitter': 'random', 'features': 7},
#             Current best combo with val score 0.4694:
#                     {'max_depth': 3, 'max_features': 0.85, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 7}
# Trained and Tested combination 1483 of 16800, taking 0.0 seconds to get val score of 0.432:
#                 {'max_depth': 3, 'max_features': 0.85, 'ccp_alpha': 1e-06, 'splitter': 'best', 'features': 7},
#             Current best combo with val score 0.4694:
#                     {'max_depth': 3, 'max_features': 0.85, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 7}
# Already Trained and Tested combination (val score of 0.4494):
#             {'max_depth': 3, 'max_features': 0.85, 'ccp_alpha': 1e-06, 'splitter': 'random', 'features': 6}
#             Current best combo (with val score 0.4694):
#                     {'max_depth': 3, 'max_features': 0.85, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 7}
#         Has trained 1483 of 16800 combinations so far
# Trained and Tested combination 1484 of 16800, taking 0.0 seconds to get val score of 0.0908:
#                 {'max_depth': 3, 'max_features': 0.85, 'ccp_alpha': 1e-06, 'splitter': 'random', 'features': 8},
#             Current best combo with val score 0.4694:
#                     {'max_depth': 3, 'max_features': 0.85, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 7}
# % Combos Checked Thus Far: 1484 out of 16800 which is 8.833333%
# Max Val Score:
#  0.469371
# Max Val Score Std:
#  0.039703
# Best Combo Train Score:
#  0.505808
# Best Combo Train Score Std:
#  0.033796
# Max Combo Index:
#  (0, 3, 0, 1, 7) out of [7, 5, 5, 2, 48] (note best combo is 0-indexed)
# Max Combo Hyperparamer Combination:
#  {'max_depth': 3, 'max_features': 0.85, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 7}
# Max Combo Features:
#  ('procedure_225792', 'ventilation_used', 'procedure_226475', 'lods_score', 'procedure_225802', 'hospital_stay_duration', 'procedure_224276', 'procedure_229519')
# % Combos Checked: 1484 out of 16800 which is 8.833333%
