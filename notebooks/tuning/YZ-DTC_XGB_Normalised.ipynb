# %% [markdown]
# # Tuning Script

# %%
# Parameters subject to change in every script - involved in naming

MODEL = 'dtc'
PREPROCESSING = 'normalise'
TUNER = 'yangzhoub'
OPTIMISED_METRIC = 'f1'

# %% [markdown]
# ---

# %%
# detect whether this is a google environment

COLAB_ENVIRONMENT = False

try:
    from google.colab import drive
    drive.mount('/content/drive')
    COLAB_ENVIRONMENT = True
except:
    pass
# Out:
# Mounted at /content/drive

# %%
import sys
import os
import pickle

if COLAB_ENVIRONMENT:
    home_directory = './drive/MyDrive/LAB/COMP90089__GroupWork__Py/' # my home directory is stored in ./LAB of google drive
    if MODEL == 'ebr':
        # !pip install interpret==0.5.0
    elif MODEL == 'cbr':
        # !pip install catboost
    elif MODEL in ['tf', 'mlp']:
        # !pip install PyTorch2Sklearn
    # !pip install JXAutoML
else:
    home_directory = '../../'

from JXAutoML.YangZhouB_10CV import YangZhouB_10CV as Tuner

import pandas as pd
# Out:
# Collecting JXAutoML
#   Downloading JXAutoML-0.4.4-py3-none-any.whl.metadata (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.2/67.2 kB 1.9 MB/s eta 0:00:00
# Downloading JXAutoML-0.4.4-py3-none-any.whl (52 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.1/52.1 kB 3.5 MB/s eta 0:00:00
# Installing collected packages: JXAutoML
# Successfully installed JXAutoML-0.4.4

# %%
# Parameters that are same for every script

FOLDS = 10  # we have decided to do 10 fold validation

SEED = 42

TASK_TYPE = 'Classification'  # this task is a classification task

# we have decided to tune features as hp
TUNE_FEATURES_AS_HYPERPARAMETERS = True

# %% [markdown]
# ---

# %%
# model to use to tune
from sklearn.tree import DecisionTreeClassifier as clf

# what values to try for each hyperparameter
parameter_choices = {
    'max_depth': (3, 6, 12, 24, 48, 96, 192),
    'max_features': (0.4, 0.55, 0.7, 0.85, 1),
    'ccp_alpha': (0.00000001, 0.000001, 0.0001, 0.01, 0.1),
    'splitter': ('best', 'random')
}

# what values to set non-tuneable parameters/hyperparameters
non_tunable_hyperparameters_dict = {
                                    'random_state': SEED,
                                    }

# %% [markdown]
# ---

# %% [markdown]
# Read in and Prepare Data

# %%
# Import data and store as lists

train_x_list = []
train_y_list = []
val_x_list = []
val_y_list = []

for i in range(FOLDS):
    train_data = pd.read_csv(
        f'{home_directory}data/curated/modelling/{PREPROCESSING}/train_{i}.csv')
    val_data = pd.read_csv(
        f'{home_directory}data/curated/modelling/{PREPROCESSING}/val_{i}.csv')

    # get the correct rows for X and y
    train_x = train_data.drop(
        ['mortality_status', 'subject_id', 'hadm_id', 'stay_id'], axis=1)
    train_y = train_data['mortality_status']
    val_x = val_data.drop(
        ['mortality_status', 'subject_id', 'hadm_id', 'stay_id'], axis=1)
    val_y = val_data['mortality_status']

    train_x_list.append(train_x)
    train_y_list.append(train_y)
    val_x_list.append(val_x)
    val_y_list.append(val_y)

# %%
# Import feature importance ordering

with open(f'{home_directory}models/xgb_feature_importance_ordering_{PREPROCESSING}.pickle', 'rb') as f:
    feature_importance_ordering = pickle.load(f)

# %% [markdown]
# Set parameters

# %%
# initialisation
tuner = Tuner()

print('---')

# define what model we are tuning
tuner.read_in_model(clf, TASK_TYPE, optimised_metric=OPTIMISED_METRIC)

print('---')

# read in the data for training and validation
tuner.read_in_data(train_x_list, train_y_list, val_x_list, val_y_list)

print('---')

# set what hp values to tune
tuner.set_hyperparameters(parameter_choices)
# WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

# set up hp values that need to be changed from default but NOT to be tuned
tuner.set_non_tuneable_hyperparameters(non_tunable_hyperparameters_dict)

print('---')

# set up feature importance ordering

if TUNE_FEATURES_AS_HYPERPARAMETERS:
    tuner.set_features(feature_importance_ordering)
    # WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

try:  # try to read in previous results to continue tuning ...
    tuner.read_in_tuning_result_df(
        f'{home_directory}models/tuning/{TUNER}_{MODEL}_{PREPROCESSING}.csv')
except:
    print('No previous tuning data read in')

print('---')

# set up where to save the tuning result csv
tuner.set_tuning_result_saving_address(
    f'{home_directory}models/tuning/{TUNER}_{MODEL}_{PREPROCESSING}.csv')

print('---')

# set up where to save the current best model
tuner.set_best_model_saving_address(
    f'{home_directory}models/tmp_models/{TUNER}_{MODEL}_{PREPROCESSING}')
# Out:
# YangZhouB Initialised
# ---
# Successfully read in model <class 'sklearn.tree._classes.DecisionTreeClassifier'>, which is a Classification model optimising for f1
# ---
# Read in Train X data list
# Read in Train y data list
# Read in Val X data list
# Read in Val y data list
# ---
# Successfully recorded hyperparameter choices
# ---
# Successfully recorded non_tuneable_hyperparameter choices
# ---
# Successfully recorded tuneable feature combination choices and updated relevant internal structures
# ---
# No previous tuning data read in
# ---
# Successfully set tuning output address
# ---
# Successfully set best model output address

# %%
# ignore warnings

import warnings
warnings.filterwarnings("ignore")

# %%
# begin tuning ... (or continue training)

tuner.tune()
# Out:
# BEGIN TUNING
#
#
# STAGE ZERO: Tune all Cruise combinations
#
#
# Trained and Tested combination 1 of 17850, taking 0.01 seconds to get val score of 0.0:
#                 {'max_depth': 192, 'max_features': 1, 'ccp_alpha': 0.1, 'splitter': 'best', 'features': 15},
#             Current best combo with val score 0.0:
#                     {'max_depth': 192, 'max_features': 1, 'ccp_alpha': 0.1, 'splitter': 'best', 'features': 15}
# Trained and Tested combination 2 of 17850, taking 0.0 seconds to get val score of 0.0:
#                 {'max_depth': 24, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 0},
#             Current best combo with val score 0.0:
#                     {'max_depth': 192, 'max_features': 1, 'ccp_alpha': 0.1, 'splitter': 'best', 'features': 15}
# Trained and Tested combination 3 of 17850, taking 0.01 seconds to get val score of 0.1469:
#                 {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 5},
#             Current best combo with val score 0.1469:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 5}
# Trained and Tested combination 4 of 17850, taking 0.03 seconds to get val score of 0.0:
#                 {'max_depth': 192, 'max_features': 1, 'ccp_alpha': 0.1, 'splitter': 'best', 'features': 30},
#             Current best combo with val score 0.1469:
#                     {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 5}
# Trained and Tested combination 5 of 17850, taking 0.01 seconds to get val score of 0.2709:
#                 {'max_depth': 24, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 45},
#             Current best combo with val score 0.2709:
#                     {'max_depth': 24, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 45}
# Trained and Tested combination 6 of 17850, taking 0.0 seconds to get val score of 0.0:
#                 {'max_depth': 3, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 35},
#             Current best combo with val score 0.2709:
#                     {'max_depth': 24, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 45}
# Trained and Tested combination 7 of 17850, taking 0.0 seconds to get val score of 0.0:
#                 {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 0.1, 'splitter': 'random', 'features': 0},
#             Current best combo with val score 0.2709:
#                     {'max_depth': 24, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 45}
# Trained and Tested combination 8 of 17850, taking 0.0 seconds to get val score of 0.0:
#                 {'max_depth': 3, 'max_features': 1, 'ccp_alpha': 0.1, 'splitter': 'random', 'features': 45},
#             Current best combo with val score 0.2709:
#                     {'max_depth': 24, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 45}
# Trained and Tested combination 9 of 17850, taking 0.0 seconds to get val score of 0.0:
#                 {'max_depth': 3, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 0},
#             Current best combo with val score 0.2709:
#                     {'max_depth': 24, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 45}
# Trained and Tested combination 10 of 17850, taking 0.02 seconds to get val score of 0.267:
#                 {'max_depth': 24, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 25},
#             Current best combo with val score 0.2709:
#                     {'max_depth': 24, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 45}
# Trained and Tested combination 11 of 17850, taking 0.01 seconds to get val score of 0.0:
#                 {'max_depth': 192, 'max_features': 1, 'ccp_alpha': 0.1, 'splitter': 'best', 'features': 25},
#             Current best combo with val score 0.2709:
#                     {'max_depth': 24, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 45}
# Trained and Tested combination 12 of 17850, taking 0.0 seconds to get val score of 0.0:
#                 {'max_depth': 24, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 0},
#             Current best combo with val score 0.2709:
#                     {'max_depth': 24, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 45}
# Trained and Tested combination 13 of 17850, taking 0.01 seconds to get val score of 0.3117:
#                 {'max_depth': 24, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 5},
#             Current best combo with val score 0.3117:
#                     {'max_depth': 24, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 5}
# Trained and Tested combination 14 of 17850, taking 0.01 seconds to get val score of 0.0:
#                 {'max_depth': 24, 'max_features': 1, 'ccp_alpha': 0.1, 'splitter': 'random', 'features': 35},
#             Current best combo with val score 0.3117:
#                     {'max_depth': 24, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 5}
# Trained and Tested combination 15 of 17850, taking 0.01 seconds to get val score of 0.3363:
#                 {'max_depth': 192, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 20},
#             Current best combo with val score 0.3363:
#                     {'max_depth': 192, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 20}
# Trained and Tested combination 16 of 17850, taking 0.01 seconds to get val score of 0.2219:
#                 {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 45},
#             Current best combo with val score 0.3363:
#                     {'max_depth': 192, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 20}
# Trained and Tested combination 17 of 17850, taking 0.01 seconds to get val score of 0.0:
#                 {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 0.1, 'splitter': 'best', 'features': 5},
#             Current best combo with val score 0.3363:
#                     {'max_depth': 192, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 20}
# Trained and Tested combination 18 of 17850, taking 0.02 seconds to get val score of 0.1667:
#                 {'max_depth': 24, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 25},
#             Current best combo with val score 0.3363:
#                     {'max_depth': 192, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 20}
# Trained and Tested combination 19 of 17850, taking 0.01 seconds to get val score of 0.2644:
#                 {'max_depth': 192, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 45},
#             Current best combo with val score 0.3363:
#                     {'max_depth': 192, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 20}
# Trained and Tested combination 20 of 17850, taking 0.0 seconds to get val score of 0.0:
#                 {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 0},
#             Current best combo with val score 0.3363:
#                     {'max_depth': 192, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 20}
# Trained and Tested combination 21 of 17850, taking 0.02 seconds to get val score of 0.2489:
#                 {'max_depth': 24, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 15},
#             Current best combo with val score 0.3363:
#                     {'max_depth': 192, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 20}
# Trained and Tested combination 22 of 17850, taking 0.04 seconds to get val score of 0.1887:
#                 {'max_depth': 24, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 40},
#             Current best combo with val score 0.3363:
#                     {'max_depth': 192, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 20}
# Trained and Tested combination 23 of 17850, taking 0.01 seconds to get val score of 0.3283:
#                 {'max_depth': 24, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 15},
#             Current best combo with val score 0.3363:
#                     {'max_depth': 192, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 20}
# Trained and Tested combination 24 of 17850, taking 0.01 seconds to get val score of 0.3114:
#                 {'max_depth': 24, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 20},
#             Current best combo with val score 0.3363:
#                     {'max_depth': 192, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 20}
# Trained and Tested combination 25 of 17850, taking 0.01 seconds to get val score of 0.0:
#                 {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 0.1, 'splitter': 'random', 'features': 10},
#             Current best combo with val score 0.3363:
#                     {'max_depth': 192, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 20}
# Trained and Tested combination 26 of 17850, taking 0.02 seconds to get val score of 0.0:
#                 {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 0.1, 'splitter': 'random', 'features': 25},
#             Current best combo with val score 0.3363:
#                     {'max_depth': 192, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 20}
# Trained and Tested combination 27 of 17850, taking 0.0 seconds to get val score of 0.0:
#                 {'max_depth': 3, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 30},
#             Current best combo with val score 0.3363:
#                     {'max_depth': 192, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 20}
# Trained and Tested combination 28 of 17850, taking 0.0 seconds to get val score of 0.0:
#                 {'max_depth': 192, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 0},
#             Current best combo with val score 0.3363:
#                     {'max_depth': 192, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 20}
# Trained and Tested combination 29 of 17850, taking 0.01 seconds to get val score of 0.0:
#                 {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 0.1, 'splitter': 'random', 'features': 10},
#             Current best combo with val score 0.3363:
#                     {'max_depth': 192, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 20}
# Trained and Tested combination 30 of 17850, taking 0.01 seconds to get val score of 0.2632:
#                 {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 45},
#             Current best combo with val score 0.3363:
#                     {'max_depth': 192, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 20}
# Trained and Tested combination 31 of 17850, taking 0.01 seconds to get val score of 0.0:
#                 {'max_depth': 24, 'max_features': 1, 'ccp_alpha': 0.1, 'splitter': 'best', 'features': 5},
#             Current best combo with val score 0.3363:
#                     {'max_depth': 192, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 20}
# Trained and Tested combination 32 of 17850, taking 0.0 seconds to get val score of 0.0:
#                 {'max_depth': 24, 'max_features': 0.4, 'ccp_alpha': 0.1, 'splitter': 'random', 'features': 0},
#             Current best combo with val score 0.3363:
#                     {'max_depth': 192, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 20}
# Trained and Tested combination 33 of 17850, taking 0.0 seconds to get val score of 0.0:
#                 {'max_depth': 24, 'max_features': 1, 'ccp_alpha': 0.1, 'splitter': 'random', 'features': 0},
#             Current best combo with val score 0.3363:
#                     {'max_depth': 192, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 20}
# Trained and Tested combination 34 of 17850, taking 0.03 seconds to get val score of 0.0:
#                 {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 0.1, 'splitter': 'best', 'features': 40},
#             Current best combo with val score 0.3363:
#                     {'max_depth': 192, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 20}
# Trained and Tested combination 35 of 17850, taking 0.0 seconds to get val score of 0.0:
#                 {'max_depth': 3, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 0},
#             Current best combo with val score 0.3363:
#                     {'max_depth': 192, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 20}
# Trained and Tested combination 36 of 17850, taking 0.0 seconds to get val score of 0.1155:
#                 {'max_depth': 3, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 10},
#             Current best combo with val score 0.3363:
#                     {'max_depth': 192, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 20}
# Trained and Tested combination 37 of 17850, taking 0.01 seconds to get val score of 0.0:
#                 {'max_depth': 192, 'max_features': 1, 'ccp_alpha': 0.1, 'splitter': 'random', 'features': 40},
#             Current best combo with val score 0.3363:
#                     {'max_depth': 192, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 20}
# Trained and Tested combination 38 of 17850, taking 0.01 seconds to get val score of 0.0:
#                 {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 0.1, 'splitter': 'best', 'features': 20},
#             Current best combo with val score 0.3363:
#                     {'max_depth': 192, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 20}
# Trained and Tested combination 39 of 17850, taking 0.0 seconds to get val score of 0.0:
#                 {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 30},
#             Current best combo with val score 0.3363:
#                     {'max_depth': 192, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 20}
# Trained and Tested combination 40 of 17850, taking 0.01 seconds to get val score of 0.332:
#                 {'max_depth': 24, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 10},
#             Current best combo with val score 0.3363:
#                     {'max_depth': 192, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 20}
# Trained and Tested combination 41 of 17850, taking 0.01 seconds to get val score of 0.2888:
#                 {'max_depth': 24, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 35},
#             Current best combo with val score 0.3363:
#                     {'max_depth': 192, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 20}
# Trained and Tested combination 42 of 17850, taking 0.01 seconds to get val score of 0.0:
#                 {'max_depth': 24, 'max_features': 1, 'ccp_alpha': 0.1, 'splitter': 'best', 'features': 35},
#             Current best combo with val score 0.3363:
#                     {'max_depth': 192, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 20}
# Trained and Tested combination 43 of 17850, taking 0.0 seconds to get val score of 0.2857:
#                 {'max_depth': 3, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 15},
#             Current best combo with val score 0.3363:
#                     {'max_depth': 192, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 20}
# Trained and Tested combination 44 of 17850, taking 0.01 seconds to get val score of 0.0:
#                 {'max_depth': 24, 'max_features': 0.4, 'ccp_alpha': 0.1, 'splitter': 'random', 'features': 15},
#             Current best combo with val score 0.3363:
#                     {'max_depth': 192, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 20}
# Trained and Tested combination 45 of 17850, taking 0.01 seconds to get val score of 0.3156:
#                 {'max_depth': 192, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 5},
#             Current best combo with val score 0.3363:
#                     {'max_depth': 192, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 20}
# Trained and Tested combination 46 of 17850, taking 0.01 seconds to get val score of 0.0:
#                 {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 0.1, 'splitter': 'best', 'features': 40},
#             Current best combo with val score 0.3363:
#                     {'max_depth': 192, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 20}
# Trained and Tested combination 47 of 17850, taking 0.01 seconds to get val score of 0.0:
#                 {'max_depth': 24, 'max_features': 1, 'ccp_alpha': 0.1, 'splitter': 'best', 'features': 10},
#             Current best combo with val score 0.3363:
#                     {'max_depth': 192, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 20}
# Trained and Tested combination 48 of 17850, taking 0.0 seconds to get val score of 0.0:
#                 {'max_depth': 3, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 40},
#             Current best combo with val score 0.3363:
#                     {'max_depth': 192, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 20}
# Trained and Tested combination 49 of 17850, taking 0.03 seconds to get val score of 0.0:
#                 {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 0.1, 'splitter': 'best', 'features': 50},
#             Current best combo with val score 0.3363:
#                     {'max_depth': 192, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 20}
# Trained and Tested combination 50 of 17850, taking 0.01 seconds to get val score of 0.0:
#                 {'max_depth': 192, 'max_features': 1, 'ccp_alpha': 0.1, 'splitter': 'best', 'features': 45},
#             Current best combo with val score 0.3363:
#                     {'max_depth': 192, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 20}
# Trained and Tested combination 51 of 17850, taking 0.02 seconds to get val score of 0.337:
#                 {'max_depth': 24, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 40},
#             Current best combo with val score 0.337:
#                     {'max_depth': 24, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 40}
# Trained and Tested combination 52 of 17850, taking 0.01 seconds to get val score of 0.2346:
#                 {'max_depth': 24, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 35},
#             Current best combo with val score 0.337:
#                     {'max_depth': 24, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 40}
# Trained and Tested combination 53 of 17850, taking 0.0 seconds to get val score of 0.0:
#                 {'max_depth': 3, 'max_features': 1, 'ccp_alpha': 0.1, 'splitter': 'random', 'features': 25},
#             Current best combo with val score 0.337:
#                     {'max_depth': 24, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 40}
# Trained and Tested combination 54 of 17850, taking 0.01 seconds to get val score of 0.0956:
#                 {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 25},
#             Current best combo with val score 0.337:
#                     {'max_depth': 24, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 40}
# Trained and Tested combination 55 of 17850, taking 0.01 seconds to get val score of 0.0:
#                 {'max_depth': 24, 'max_features': 0.4, 'ccp_alpha': 0.1, 'splitter': 'best', 'features': 5},
#             Current best combo with val score 0.337:
#                     {'max_depth': 24, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 40}
# Trained and Tested combination 56 of 17850, taking 0.04 seconds to get val score of 0.1887:
#                 {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 40},
#             Current best combo with val score 0.337:
#                     {'max_depth': 24, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 40}
# Trained and Tested combination 57 of 17850, taking 0.01 seconds to get val score of 0.325:
#                 {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 20},
#             Current best combo with val score 0.337:
#                     {'max_depth': 24, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 40}
# Trained and Tested combination 58 of 17850, taking 0.01 seconds to get val score of 0.2415:
#                 {'max_depth': 24, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 20},
#             Current best combo with val score 0.337:
#                     {'max_depth': 24, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 40}
# Trained and Tested combination 59 of 17850, taking 0.01 seconds to get val score of 0.0:
#                 {'max_depth': 192, 'max_features': 1, 'ccp_alpha': 0.1, 'splitter': 'best', 'features': 35},
#             Current best combo with val score 0.337:
#                     {'max_depth': 24, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 40}
# Trained and Tested combination 60 of 17850, taking 0.01 seconds to get val score of 0.0:
#                 {'max_depth': 24, 'max_features': 1, 'ccp_alpha': 0.1, 'splitter': 'best', 'features': 45},
#             Current best combo with val score 0.337:
#                     {'max_depth': 24, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 40}
# Trained and Tested combination 61 of 17850, taking 0.0 seconds to get val score of 0.0:
#                 {'max_depth': 3, 'max_features': 1, 'ccp_alpha': 0.1, 'splitter': 'random', 'features': 0},
#             Current best combo with val score 0.337:
#                     {'max_depth': 24, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 40}
# Trained and Tested combination 62 of 17850, taking 0.01 seconds to get val score of 0.0:
#                 {'max_depth': 192, 'max_features': 1, 'ccp_alpha': 0.1, 'splitter': 'best', 'features': 5},
#             Current best combo with val score 0.337:
#                     {'max_depth': 24, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 40}
# Trained and Tested combination 63 of 17850, taking 0.01 seconds to get val score of 0.0:
#                 {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 0.1, 'splitter': 'best', 'features': 25},
#             Current best combo with val score 0.337:
#                     {'max_depth': 24, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 40}
# Trained and Tested combination 64 of 17850, taking 0.0 seconds to get val score of 0.0:
#                 {'max_depth': 3, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 50},
#             Current best combo with val score 0.337:
#                     {'max_depth': 24, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 40}
# Trained and Tested combination 65 of 17850, taking 0.01 seconds to get val score of 0.0:
#                 {'max_depth': 192, 'max_features': 1, 'ccp_alpha': 0.1, 'splitter': 'best', 'features': 20},
#             Current best combo with val score 0.337:
#                     {'max_depth': 24, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 40}
# Trained and Tested combination 66 of 17850, taking 0.01 seconds to get val score of 0.0:
#                 {'max_depth': 24, 'max_features': 1, 'ccp_alpha': 0.1, 'splitter': 'best', 'features': 50},
#             Current best combo with val score 0.337:
#                     {'max_depth': 24, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 40}
# Trained and Tested combination 67 of 17850, taking 0.0 seconds to get val score of 0.0:
#                 {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 0.1, 'splitter': 'random', 'features': 5},
#             Current best combo with val score 0.337:
#                     {'max_depth': 24, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 40}
# Trained and Tested combination 68 of 17850, taking 0.0 seconds to get val score of 0.0:
#                 {'max_depth': 3, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 20},
#             Current best combo with val score 0.337:
#                     {'max_depth': 24, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 40}
# Trained and Tested combination 69 of 17850, taking 0.01 seconds to get val score of 0.2845:
#                 {'max_depth': 192, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 25},
#             Current best combo with val score 0.337:
#                     {'max_depth': 24, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 40}
# Trained and Tested combination 70 of 17850, taking 0.01 seconds to get val score of 0.3727:
#                 {'max_depth': 24, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 20},
#             Current best combo with val score 0.3727:
#                     {'max_depth': 24, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 20}
# Trained and Tested combination 71 of 17850, taking 0.0 seconds to get val score of 0.1895:
#                 {'max_depth': 24, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 20},
#             Current best combo with val score 0.3727:
#                     {'max_depth': 24, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 20}
# Trained and Tested combination 72 of 17850, taking 0.01 seconds to get val score of 0.336:
#                 {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 50},
#             Current best combo with val score 0.3727:
#                     {'max_depth': 24, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 20}
# Trained and Tested combination 73 of 17850, taking 0.01 seconds to get val score of 0.3196:
#                 {'max_depth': 24, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 5},
#             Current best combo with val score 0.3727:
#                     {'max_depth': 24, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 20}
# Trained and Tested combination 74 of 17850, taking 0.0 seconds to get val score of 0.2759:
#                 {'max_depth': 24, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 15},
#             Current best combo with val score 0.3727:
#                     {'max_depth': 24, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 20}
# Trained and Tested combination 75 of 17850, taking 0.01 seconds to get val score of 0.3729:
#                 {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 20},
#             Current best combo with val score 0.3729:
#                     {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 20}
# Trained and Tested combination 76 of 17850, taking 0.01 seconds to get val score of 0.0:
#                 {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 0.1, 'splitter': 'random', 'features': 45},
#             Current best combo with val score 0.3729:
#                     {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 20}
# Trained and Tested combination 77 of 17850, taking 0.01 seconds to get val score of 0.0:
#                 {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 0.1, 'splitter': 'random', 'features': 35},
#             Current best combo with val score 0.3729:
#                     {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 20}
# Trained and Tested combination 78 of 17850, taking 0.0 seconds to get val score of 0.0:
#                 {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 0.1, 'splitter': 'random', 'features': 40},
#             Current best combo with val score 0.3729:
#                     {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 20}
# Trained and Tested combination 79 of 17850, taking 0.01 seconds to get val score of 0.268:
#                 {'max_depth': 24, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 50},
#             Current best combo with val score 0.3729:
#                     {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 20}
# Trained and Tested combination 80 of 17850, taking 0.01 seconds to get val score of 0.3215:
#                 {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 15},
#             Current best combo with val score 0.3729:
#                     {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 20}
# Trained and Tested combination 81 of 17850, taking 0.02 seconds to get val score of 0.2579:
#                 {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 35},
#             Current best combo with val score 0.3729:
#                     {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 20}
# Trained and Tested combination 82 of 17850, taking 0.01 seconds to get val score of 0.3862:
#                 {'max_depth': 24, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 5},
#             Current best combo with val score 0.3862:
#                     {'max_depth': 24, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 5}
# Trained and Tested combination 83 of 17850, taking 0.01 seconds to get val score of 0.2771:
#                 {'max_depth': 24, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 40},
#             Current best combo with val score 0.3862:
#                     {'max_depth': 24, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 5}
# Trained and Tested combination 84 of 17850, taking 0.01 seconds to get val score of 0.2455:
#                 {'max_depth': 24, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 25},
#             Current best combo with val score 0.3862:
#                     {'max_depth': 24, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 5}
# Trained and Tested combination 85 of 17850, taking 0.01 seconds to get val score of 0.1784:
#                 {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 25},
#             Current best combo with val score 0.3862:
#                     {'max_depth': 24, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 5}
# Trained and Tested combination 86 of 17850, taking 0.0 seconds to get val score of 0.0:
#                 {'max_depth': 3, 'max_features': 1, 'ccp_alpha': 0.1, 'splitter': 'random', 'features': 5},
#             Current best combo with val score 0.3862:
#                     {'max_depth': 24, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 5}
# Trained and Tested combination 87 of 17850, taking 0.01 seconds to get val score of 0.0:
#                 {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 0.1, 'splitter': 'best', 'features': 50},
#             Current best combo with val score 0.3862:
#                     {'max_depth': 24, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 5}
# Trained and Tested combination 88 of 17850, taking 0.0 seconds to get val score of 0.0:
#                 {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 0.1, 'splitter': 'random', 'features': 35},
#             Current best combo with val score 0.3862:
#                     {'max_depth': 24, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 5}
# Trained and Tested combination 89 of 17850, taking 0.01 seconds to get val score of 0.3895:
#                 {'max_depth': 24, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 10},
#             Current best combo with val score 0.3895:
#                     {'max_depth': 24, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 10}
# Trained and Tested combination 90 of 17850, taking 0.0 seconds to get val score of 0.0:
#                 {'max_depth': 24, 'max_features': 1, 'ccp_alpha': 0.1, 'splitter': 'random', 'features': 10},
#             Current best combo with val score 0.3895:
#                     {'max_depth': 24, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 10}
# Trained and Tested combination 91 of 17850, taking 0.0 seconds to get val score of 0.2022:
#                 {'max_depth': 3, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 45},
#             Current best combo with val score 0.3895:
#                     {'max_depth': 24, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 10}
# Trained and Tested combination 92 of 17850, taking 0.01 seconds to get val score of 0.0:
#                 {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 0.1, 'splitter': 'best', 'features': 10},
#             Current best combo with val score 0.3895:
#                     {'max_depth': 24, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 10}
# Trained and Tested combination 93 of 17850, taking 0.02 seconds to get val score of 0.0:
#                 {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 0.1, 'splitter': 'best', 'features': 20},
#             Current best combo with val score 0.3895:
#                     {'max_depth': 24, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 10}
# Trained and Tested combination 94 of 17850, taking 0.0 seconds to get val score of 0.0:
#                 {'max_depth': 3, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 25},
#             Current best combo with val score 0.3895:
#                     {'max_depth': 24, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 10}
# Trained and Tested combination 95 of 17850, taking 0.01 seconds to get val score of 0.0:
#                 {'max_depth': 192, 'max_features': 1, 'ccp_alpha': 0.1, 'splitter': 'random', 'features': 25},
#             Current best combo with val score 0.3895:
#                     {'max_depth': 24, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 10}
# Trained and Tested combination 96 of 17850, taking 0.02 seconds to get val score of 0.0:
#                 {'max_depth': 24, 'max_features': 0.4, 'ccp_alpha': 0.1, 'splitter': 'best', 'features': 25},
#             Current best combo with val score 0.3895:
#                     {'max_depth': 24, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 10}
# Trained and Tested combination 97 of 17850, taking 0.01 seconds to get val score of 0.0:
#                 {'max_depth': 24, 'max_features': 1, 'ccp_alpha': 0.1, 'splitter': 'random', 'features': 25},
#             Current best combo with val score 0.3895:
#                     {'max_depth': 24, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 10}
# Trained and Tested combination 98 of 17850, taking 0.0 seconds to get val score of 0.0:
#                 {'max_depth': 24, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 0},
#             Current best combo with val score 0.3895:
#                     {'max_depth': 24, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 10}
# Trained and Tested combination 99 of 17850, taking 0.01 seconds to get val score of 0.3314:
#                 {'max_depth': 24, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 15},
#             Current best combo with val score 0.3895:
#                     {'max_depth': 24, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 10}
# Trained and Tested combination 100 of 17850, taking 0.01 seconds to get val score of 0.0:
#                 {'max_depth': 24, 'max_features': 1, 'ccp_alpha': 0.1, 'splitter': 'best', 'features': 25},
#             Current best combo with val score 0.3895:
#                     {'max_depth': 24, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 10}
# Trained and Tested combination 101 of 17850, taking 0.01 seconds to get val score of 0.3932:
#                 {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 10},
#             Current best combo with val score 0.3932:
#                     {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 10}
# Trained and Tested combination 102 of 17850, taking 0.0 seconds to get val score of 0.0:
#                 {'max_depth': 3, 'max_features': 1, 'ccp_alpha': 0.1, 'splitter': 'best', 'features': 20},
#             Current best combo with val score 0.3932:
#                     {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 10}
# Trained and Tested combination 103 of 17850, taking 0.01 seconds to get val score of 0.0:
#                 {'max_depth': 192, 'max_features': 1, 'ccp_alpha': 0.1, 'splitter': 'random', 'features': 30},
#             Current best combo with val score 0.3932:
#                     {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 10}
# Trained and Tested combination 104 of 17850, taking 0.01 seconds to get val score of 0.0:
#                 {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 0.1, 'splitter': 'random', 'features': 15},
#             Current best combo with val score 0.3932:
#                     {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 10}
# Trained and Tested combination 105 of 17850, taking 0.01 seconds to get val score of 0.2773:
#                 {'max_depth': 192, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 25},
#             Current best combo with val score 0.3932:
#                     {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 10}
# Trained and Tested combination 106 of 17850, taking 0.03 seconds to get val score of 0.0:
#                 {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 0.1, 'splitter': 'best', 'features': 45},
#             Current best combo with val score 0.3932:
#                     {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 10}
# Trained and Tested combination 107 of 17850, taking 0.0 seconds to get val score of 0.0295:
#                 {'max_depth': 3, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 10},
#             Current best combo with val score 0.3932:
#                     {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 10}
# Trained and Tested combination 108 of 17850, taking 0.0 seconds to get val score of 0.0:
#                 {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 0.1, 'splitter': 'best', 'features': 0},
#             Current best combo with val score 0.3932:
#                     {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 10}
# Trained and Tested combination 109 of 17850, taking 0.01 seconds to get val score of 0.0:
#                 {'max_depth': 192, 'max_features': 1, 'ccp_alpha': 0.1, 'splitter': 'best', 'features': 50},
#             Current best combo with val score 0.3932:
#                     {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 10}
# Trained and Tested combination 110 of 17850, taking 0.0 seconds to get val score of 0.0:
#                 {'max_depth': 192, 'max_features': 1, 'ccp_alpha': 0.1, 'splitter': 'best', 'features': 0},
#             Current best combo with val score 0.3932:
#                     {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 10}
# Trained and Tested combination 111 of 17850, taking 0.01 seconds to get val score of 0.0:
#                 {'max_depth': 24, 'max_features': 1, 'ccp_alpha': 0.1, 'splitter': 'random', 'features': 45},
#             Current best combo with val score 0.3932:
#                     {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 10}
# Trained and Tested combination 112 of 17850, taking 0.0 seconds to get val score of 0.0:
#                 {'max_depth': 3, 'max_features': 1, 'ccp_alpha': 0.1, 'splitter': 'best', 'features': 5},
#             Current best combo with val score 0.3932:
#                     {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 10}
# Trained and Tested combination 113 of 17850, taking 0.02 seconds to get val score of 0.0:
#                 {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 0.1, 'splitter': 'random', 'features': 40},
#             Current best combo with val score 0.3932:
#                     {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 10}
# Trained and Tested combination 114 of 17850, taking 0.04 seconds to get val score of 0.0:
#                 {'max_depth': 24, 'max_features': 0.4, 'ccp_alpha': 0.1, 'splitter': 'best', 'features': 35},
#             Current best combo with val score 0.3932:
#                     {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 10}
# Trained and Tested combination 115 of 17850, taking 0.01 seconds to get val score of 0.2619:
#                 {'max_depth': 3, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 15},
#             Current best combo with val score 0.3932:
#                     {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 10}
# Trained and Tested combination 116 of 17850, taking 0.01 seconds to get val score of 0.2955:
#                 {'max_depth': 192, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 35},
#             Current best combo with val score 0.3932:
#                     {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 10}
# Trained and Tested combination 117 of 17850, taking 0.01 seconds to get val score of 0.0:
#                 {'max_depth': 24, 'max_features': 0.4, 'ccp_alpha': 0.1, 'splitter': 'best', 'features': 20},
#             Current best combo with val score 0.3932:
#                     {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 10}
# Trained and Tested combination 118 of 17850, taking 0.03 seconds to get val score of 0.0:
#                 {'max_depth': 24, 'max_features': 0.4, 'ccp_alpha': 0.1, 'splitter': 'best', 'features': 40},
#             Current best combo with val score 0.3932:
#                     {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 10}
# Trained and Tested combination 119 of 17850, taking 0.0 seconds to get val score of 0.0:
#                 {'max_depth': 3, 'max_features': 1, 'ccp_alpha': 0.1, 'splitter': 'random', 'features': 50},
#             Current best combo with val score 0.3932:
#                     {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 10}
# Trained and Tested combination 120 of 17850, taking 0.0 seconds to get val score of 0.0:
#                 {'max_depth': 3, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 25},
#             Current best combo with val score 0.3932:
#                     {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 10}
# Trained and Tested combination 121 of 17850, taking 0.03 seconds to get val score of 0.0:
#                 {'max_depth': 24, 'max_features': 0.4, 'ccp_alpha': 0.1, 'splitter': 'best', 'features': 45},
#             Current best combo with val score 0.3932:
#                     {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 10}
# Trained and Tested combination 122 of 17850, taking 0.02 seconds to get val score of 0.1759:
#                 {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 45},
#             Current best combo with val score 0.3932:
#                     {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 10}
# Trained and Tested combination 123 of 17850, taking 0.01 seconds to get val score of 0.0:
#                 {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 0.1, 'splitter': 'random', 'features': 20},
#             Current best combo with val score 0.3932:
#                     {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 10}
# Trained and Tested combination 124 of 17850, taking 0.0 seconds to get val score of 0.0:
#                 {'max_depth': 24, 'max_features': 1, 'ccp_alpha': 0.1, 'splitter': 'best', 'features': 0},
#             Current best combo with val score 0.3932:
#                     {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 10}
# Trained and Tested combination 125 of 17850, taking 0.01 seconds to get val score of 0.3045:
#                 {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 30},
#             Current best combo with val score 0.3932:
#                     {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 10}
# Trained and Tested combination 126 of 17850, taking 0.02 seconds to get val score of 0.282:
#                 {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 30},
#             Current best combo with val score 0.3932:
#                     {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 10}
# Trained and Tested combination 127 of 17850, taking 0.0 seconds to get val score of 0.0:
#                 {'max_depth': 3, 'max_features': 1, 'ccp_alpha': 0.1, 'splitter': 'best', 'features': 35},
#             Current best combo with val score 0.3932:
#                     {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 10}
# Trained and Tested combination 128 of 17850, taking 0.0 seconds to get val score of 0.0:
#                 {'max_depth': 3, 'max_features': 1, 'ccp_alpha': 0.1, 'splitter': 'random', 'features': 40},
#             Current best combo with val score 0.3932:
#                     {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 10}
# ...
#                 {'max_depth': 48, 'max_features': 1, 'ccp_alpha': 1e-06, 'splitter': 'random', 'features': 10},
#             Current best combo with val score 0.4072:
#                     {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 0.0001, 'splitter': 'random', 'features': 10}
# Already Trained and Tested combination (val score of 0.3687):
#             {'max_depth': 48, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 10}
#             Current best combo (with val score 0.4072):
#                     {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 0.0001, 'splitter': 'random', 'features': 10}
#         Has trained 552 of 17850 combinations so far
# Trained and Tested combination 553 of 17850, taking 0.01 seconds to get val score of 0.3611:
#                 {'max_depth': 48, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 9},
#             Current best combo with val score 0.4072:
#                     {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 0.0001, 'splitter': 'random', 'features': 10}
# Trained and Tested combination 554 of 17850, taking 0.01 seconds to get val score of 0.2833:
#                 {'max_depth': 48, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 11},
#             Current best combo with val score 0.4072:
#                     {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 0.0001, 'splitter': 'random', 'features': 10}
# Trained and Tested combination 555 of 17850, taking 0.01 seconds to get val score of 0.3854:
#                 {'max_depth': 12, 'max_features': 0.85, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 10},
#             Current best combo with val score 0.4072:
#                     {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 0.0001, 'splitter': 'random', 'features': 10}
# Already Trained and Tested combination (val score of 0.379):
#             {'max_depth': 48, 'max_features': 0.85, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 10}
#             Current best combo (with val score 0.4072):
#                     {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 0.0001, 'splitter': 'random', 'features': 10}
#         Has trained 555 of 17850 combinations so far
# Already Trained and Tested combination (val score of 0.3885):
#             {'max_depth': 24, 'max_features': 0.7, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 10}
#             Current best combo (with val score 0.4072):
#                     {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 0.0001, 'splitter': 'random', 'features': 10}
#         Has trained 555 of 17850 combinations so far
# Already Trained and Tested combination (val score of 0.343):
#             {'max_depth': 24, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 10}
#             Current best combo (with val score 0.4072):
#                     {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 0.0001, 'splitter': 'random', 'features': 10}
#         Has trained 555 of 17850 combinations so far
# Trained and Tested combination 556 of 17850, taking 0.01 seconds to get val score of 0.4046:
#                 {'max_depth': 24, 'max_features': 0.85, 'ccp_alpha': 1e-06, 'splitter': 'random', 'features': 10},
#             Current best combo with val score 0.4072:
#                     {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 0.0001, 'splitter': 'random', 'features': 10}
# Trained and Tested combination 557 of 17850, taking 0.02 seconds to get val score of 0.3093:
#                 {'max_depth': 24, 'max_features': 0.85, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 10},
#             Current best combo with val score 0.4072:
#                     {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 0.0001, 'splitter': 'random', 'features': 10}
# Trained and Tested combination 558 of 17850, taking 0.01 seconds to get val score of 0.3651:
#                 {'max_depth': 24, 'max_features': 0.85, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 9},
#             Current best combo with val score 0.4072:
#                     {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 0.0001, 'splitter': 'random', 'features': 10}
# Trained and Tested combination 559 of 17850, taking 0.01 seconds to get val score of 0.3578:
#                 {'max_depth': 24, 'max_features': 0.85, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 11},
#             Current best combo with val score 0.4072:
#                     {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 0.0001, 'splitter': 'random', 'features': 10}
# Trained and Tested combination 560 of 17850, taking 0.0 seconds to get val score of 0.2381:
#                 {'max_depth': 12, 'max_features': 1, 'ccp_alpha': 1e-06, 'splitter': 'random', 'features': 10},
#             Current best combo with val score 0.4072:
#                     {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 0.0001, 'splitter': 'random', 'features': 10}
# Already Trained and Tested combination (val score of 0.3796):
#             {'max_depth': 48, 'max_features': 1, 'ccp_alpha': 1e-06, 'splitter': 'random', 'features': 10}
#             Current best combo (with val score 0.4072):
#                     {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 0.0001, 'splitter': 'random', 'features': 10}
#         Has trained 560 of 17850 combinations so far
# Already Trained and Tested combination (val score of 0.4046):
#             {'max_depth': 24, 'max_features': 0.85, 'ccp_alpha': 1e-06, 'splitter': 'random', 'features': 10}
#             Current best combo (with val score 0.4072):
#                     {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 0.0001, 'splitter': 'random', 'features': 10}
#         Has trained 560 of 17850 combinations so far
# Already Trained and Tested combination (val score of 0.343):
#             {'max_depth': 24, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 10}
#             Current best combo (with val score 0.4072):
#                     {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 0.0001, 'splitter': 'random', 'features': 10}
#         Has trained 560 of 17850 combinations so far
# Trained and Tested combination 561 of 17850, taking 0.01 seconds to get val score of 0.3476:
#                 {'max_depth': 24, 'max_features': 1, 'ccp_alpha': 0.0001, 'splitter': 'random', 'features': 10},
#             Current best combo with val score 0.4072:
#                     {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 0.0001, 'splitter': 'random', 'features': 10}
# Trained and Tested combination 562 of 17850, taking 0.01 seconds to get val score of 0.3375:
#                 {'max_depth': 24, 'max_features': 1, 'ccp_alpha': 1e-06, 'splitter': 'best', 'features': 10},
#             Current best combo with val score 0.4072:
#                     {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 0.0001, 'splitter': 'random', 'features': 10}
# Trained and Tested combination 563 of 17850, taking 0.01 seconds to get val score of 0.2766:
#                 {'max_depth': 24, 'max_features': 1, 'ccp_alpha': 1e-06, 'splitter': 'random', 'features': 9},
#             Current best combo with val score 0.4072:
#                     {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 0.0001, 'splitter': 'random', 'features': 10}
# Trained and Tested combination 564 of 17850, taking 0.01 seconds to get val score of 0.1524:
#                 {'max_depth': 24, 'max_features': 1, 'ccp_alpha': 1e-06, 'splitter': 'random', 'features': 11},
#             Current best combo with val score 0.4072:
#                     {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 0.0001, 'splitter': 'random', 'features': 10}
# % Combos Checked Thus Far: 564 out of 17850 which is 3.1596640000000003%
# Cruising Coordrdinate 264 of 264
#
# Cruise suspended due to suspicious case
# Guidance: round 16
#
# 	round 16 iteration:  0
#
# % Combos Checked Thus Far: 564 out of 17850 which is 3.1596640000000003%
# FINAL STAGE: Begin final Guidance system
#
#
# Guidance: round FINAL
#
# 	round FINAL iteration:  0
#
# Already Trained and Tested combination (val score of 0.4072):
#             {'max_depth': 96, 'max_features': 0.4, 'ccp_alpha': 0.0001, 'splitter': 'random', 'features': 10}
#             Current best combo (with val score 0.4072):
#                     {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 0.0001, 'splitter': 'random', 'features': 10}
#         Has trained 564 of 17850 combinations so far
# Already Trained and Tested combination (val score of 0.394):
#             {'max_depth': 192, 'max_features': 0.55, 'ccp_alpha': 0.0001, 'splitter': 'random', 'features': 10}
#             Current best combo (with val score 0.4072):
#                     {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 0.0001, 'splitter': 'random', 'features': 10}
#         Has trained 564 of 17850 combinations so far
# Already Trained and Tested combination (val score of 0.3932):
#             {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 1e-06, 'splitter': 'random', 'features': 10}
#             Current best combo (with val score 0.4072):
#                     {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 0.0001, 'splitter': 'random', 'features': 10}
#         Has trained 564 of 17850 combinations so far
# Already Trained and Tested combination (val score of 0.0411):
#             {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 0.01, 'splitter': 'random', 'features': 10}
#             Current best combo (with val score 0.4072):
#                     {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 0.0001, 'splitter': 'random', 'features': 10}
#         Has trained 564 of 17850 combinations so far
# Already Trained and Tested combination (val score of 0.3385):
#             {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 0.0001, 'splitter': 'best', 'features': 10}
#             Current best combo (with val score 0.4072):
#                     {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 0.0001, 'splitter': 'random', 'features': 10}
#         Has trained 564 of 17850 combinations so far
# Already Trained and Tested combination (val score of 0.3908):
#             {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 0.0001, 'splitter': 'random', 'features': 9}
#             Current best combo (with val score 0.4072):
#                     {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 0.0001, 'splitter': 'random', 'features': 10}
#         Has trained 564 of 17850 combinations so far
# Already Trained and Tested combination (val score of 0.2519):
#             {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 0.0001, 'splitter': 'random', 'features': 11}
#             Current best combo (with val score 0.4072):
#                     {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 0.0001, 'splitter': 'random', 'features': 10}
#         Has trained 564 of 17850 combinations so far
# 	round FINAL iteration:  1
#
# Trained and Tested combination 565 of 17850, taking 0.01 seconds to get val score of 0.4072:
#                 {'max_depth': 48, 'max_features': 0.4, 'ccp_alpha': 0.0001, 'splitter': 'random', 'features': 10},
#             Current best combo with val score 0.4072:
#                     {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 0.0001, 'splitter': 'random', 'features': 10}
# Already Trained and Tested combination (val score of 0.4072):
#             {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 0.0001, 'splitter': 'random', 'features': 10}
#             Current best combo (with val score 0.4072):
#                     {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 0.0001, 'splitter': 'random', 'features': 10}
#         Has trained 565 of 17850 combinations so far
# Trained and Tested combination 566 of 17850, taking 0.01 seconds to get val score of 0.394:
#                 {'max_depth': 96, 'max_features': 0.55, 'ccp_alpha': 0.0001, 'splitter': 'random', 'features': 10},
#             Current best combo with val score 0.4072:
#                     {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 0.0001, 'splitter': 'random', 'features': 10}
# Already Trained and Tested combination (val score of 0.3932):
#             {'max_depth': 96, 'max_features': 0.4, 'ccp_alpha': 1e-06, 'splitter': 'random', 'features': 10}
#             Current best combo (with val score 0.4072):
#                     {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 0.0001, 'splitter': 'random', 'features': 10}
#         Has trained 566 of 17850 combinations so far
# Trained and Tested combination 567 of 17850, taking 0.01 seconds to get val score of 0.0411:
#                 {'max_depth': 96, 'max_features': 0.4, 'ccp_alpha': 0.01, 'splitter': 'random', 'features': 10},
#             Current best combo with val score 0.4072:
#                     {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 0.0001, 'splitter': 'random', 'features': 10}
# Trained and Tested combination 568 of 17850, taking 0.01 seconds to get val score of 0.3385:
#                 {'max_depth': 96, 'max_features': 0.4, 'ccp_alpha': 0.0001, 'splitter': 'best', 'features': 10},
#             Current best combo with val score 0.4072:
#                     {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 0.0001, 'splitter': 'random', 'features': 10}
# Trained and Tested combination 569 of 17850, taking 0.01 seconds to get val score of 0.3908:
#                 {'max_depth': 96, 'max_features': 0.4, 'ccp_alpha': 0.0001, 'splitter': 'random', 'features': 9},
#             Current best combo with val score 0.4072:
#                     {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 0.0001, 'splitter': 'random', 'features': 10}
# Trained and Tested combination 570 of 17850, taking 0.01 seconds to get val score of 0.2519:
#                 {'max_depth': 96, 'max_features': 0.4, 'ccp_alpha': 0.0001, 'splitter': 'random', 'features': 11},
#             Current best combo with val score 0.4072:
#                     {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 0.0001, 'splitter': 'random', 'features': 10}
# % Combos Checked Thus Far: 570 out of 17850 which is 3.193277%
# Max Val Score:
#  0.407239
# Max Val Score Std:
#  0.050504
# Best Combo Train Score:
#  0.993256
# Best Combo Train Score Std:
#  0.002395
# Max Combo Index:
#  (6, 0, 2, 1, 10) out of [7, 5, 5, 2, 51] (note best combo is 0-indexed)
# Max Combo Hyperparamer Combination:
#  {'max_depth': 192, 'max_features': 0.4, 'ccp_alpha': 0.0001, 'splitter': 'random', 'features': 10}
# Max Combo Features:
#  ('procedure_225792', 'ventilation_used', 'lods_score', 'race_AMERICAN INDIAN/ALASKA NATIVE', 'race_ASIAN', 'race_ASIAN - ASIAN INDIAN', 'race_ASIAN - CHINESE', 'race_ASIAN - KOREAN', 'race_ASIAN - SOUTH EAST ASIAN', 'race_BLACK/AFRICAN', 'race_BLACK/AFRICAN AMERICAN', 'race_BLACK/CAPE VERDEAN', 'race_BLACK/CARIBBEAN ISLAND', 'race_HISPANIC/LATINO - CENTRAL AMERICAN', 'race_HISPANIC/LATINO - COLUMBIAN', 'race_HISPANIC/LATINO - CUBAN', 'race_HISPANIC/LATINO - DOMINICAN', 'race_HISPANIC/LATINO - GUATEMALAN', 'race_HISPANIC/LATINO - HONDURAN', 'race_HISPANIC/LATINO - MEXICAN', 'race_HISPANIC/LATINO - PUERTO RICAN', 'race_HISPANIC/LATINO - SALVADORAN', 'race_MULTIPLE RACE/ETHNICITY', 'race_NATIVE HAWAIIAN OR OTHER PACIFIC ISLANDER', 'race_OTHER', 'race_PATIENT DECLINED TO ANSWER', 'race_PORTUGUESE', 'race_SOUTH AMERICAN', 'race_UNABLE TO OBTAIN', 'race_UNKNOWN', 'race_WHITE', 'race_WHITE - BRAZILIAN', 'race_WHITE - EASTERN EUROPEAN', 'race_WHITE - OTHER EUROPEAN', 'race_WHITE - RUSSIAN', 'race_HISPANIC OR LATINO', 'marital_status_DIVORCED', 'marital_status_MARRIED', 'marital_status_SINGLE', 'marital_status_WIDOWED', 'marital_status_0', 'hospital_stay_duration', 'procedure_225464', 'procedure_225802', 'procedure_227712', 'admission_type_DIRECT EMER.', 'admission_type_DIRECT OBSERVATION', 'admission_type_ELECTIVE', 'admission_type_EU OBSERVATION', 'admission_type_EW EMER.', 'admission_type_OBSERVATION ADMIT', 'admission_type_URGENT', 'admission_type_SURGICAL SAME DAY ADMISSION', 'procedure_225446')
# % Combos Checked: 570 out of 17850 which is 3.193277%
