#                     {'max_depth': 24, 'max_features': 0.85, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 9}
# Trained and Tested combination 517 of 25200, taking 0.0 seconds to get val score of 0.4965:
#                 {'max_depth': 192, 'max_features': 1, 'ccp_alpha': 1e-06, 'splitter': 'random', 'features': 9},
#             Current best combo with val score 0.5493:
#                     {'max_depth': 24, 'max_features': 0.85, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 9}
# Trained and Tested combination 518 of 25200, taking 0.0 seconds to get val score of 0.4838:
#                 {'max_depth': 192, 'max_features': 1, 'ccp_alpha': 1e-06, 'splitter': 'random', 'features': 11},
#             Current best combo with val score 0.5493:
#                     {'max_depth': 24, 'max_features': 0.85, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 9}
# % Combos Checked Thus Far: 518 out of 25200 which is 2.055556%
# FINAL STAGE: Begin final Guidance system
#
#
# Guidance: round FINAL
#
# 	round FINAL iteration:  0
#
# Already Trained and Tested combination (val score of 0.5066):
#             {'max_depth': 12, 'max_features': 0.85, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 9}
#             Current best combo (with val score 0.5493):
#                     {'max_depth': 24, 'max_features': 0.85, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 9}
#         Has trained 518 of 25200 combinations so far
# Already Trained and Tested combination (val score of 0.5251):
#             {'max_depth': 48, 'max_features': 0.85, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 9}
#             Current best combo (with val score 0.5493):
#                     {'max_depth': 24, 'max_features': 0.85, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 9}
#         Has trained 518 of 25200 combinations so far
# Already Trained and Tested combination (val score of 0.4318):
#             {'max_depth': 24, 'max_features': 0.7, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 9}
#             Current best combo (with val score 0.5493):
#                     {'max_depth': 24, 'max_features': 0.85, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 9}
#         Has trained 518 of 25200 combinations so far
# Already Trained and Tested combination (val score of 0.5027):
#             {'max_depth': 24, 'max_features': 1, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 9}
#             Current best combo (with val score 0.5493):
#                     {'max_depth': 24, 'max_features': 0.85, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 9}
#         Has trained 518 of 25200 combinations so far
# Already Trained and Tested combination (val score of 0.5493):
#             {'max_depth': 24, 'max_features': 0.85, 'ccp_alpha': 1e-06, 'splitter': 'random', 'features': 9}
#             Current best combo (with val score 0.5493):
#                     {'max_depth': 24, 'max_features': 0.85, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 9}
#         Has trained 518 of 25200 combinations so far
# Already Trained and Tested combination (val score of 0.3409):
#             {'max_depth': 24, 'max_features': 0.85, 'ccp_alpha': 1e-08, 'splitter': 'best', 'features': 9}
#             Current best combo (with val score 0.5493):
#                     {'max_depth': 24, 'max_features': 0.85, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 9}
#         Has trained 518 of 25200 combinations so far
# Already Trained and Tested combination (val score of 0.5054):
#             {'max_depth': 24, 'max_features': 0.85, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 8}
#             Current best combo (with val score 0.5493):
#                     {'max_depth': 24, 'max_features': 0.85, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 9}
#         Has trained 518 of 25200 combinations so far
# Already Trained and Tested combination (val score of 0.4986):
#             {'max_depth': 24, 'max_features': 0.85, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 10}
#             Current best combo (with val score 0.5493):
#                     {'max_depth': 24, 'max_features': 0.85, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 9}
#         Has trained 518 of 25200 combinations so far
# 	round FINAL iteration:  1
#
# Trained and Tested combination 519 of 25200, taking 0.0 seconds to get val score of 0.5066:
#                 {'max_depth': 12, 'max_features': 0.85, 'ccp_alpha': 1e-06, 'splitter': 'random', 'features': 9},
#             Current best combo with val score 0.5493:
#                     {'max_depth': 24, 'max_features': 0.85, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 9}
# Trained and Tested combination 520 of 25200, taking 0.0 seconds to get val score of 0.5251:
#                 {'max_depth': 48, 'max_features': 0.85, 'ccp_alpha': 1e-06, 'splitter': 'random', 'features': 9},
#             Current best combo with val score 0.5493:
#                     {'max_depth': 24, 'max_features': 0.85, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 9}
# Trained and Tested combination 521 of 25200, taking 0.01 seconds to get val score of 0.4318:
#                 {'max_depth': 24, 'max_features': 0.7, 'ccp_alpha': 1e-06, 'splitter': 'random', 'features': 9},
#             Current best combo with val score 0.5493:
#                     {'max_depth': 24, 'max_features': 0.85, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 9}
# Already Trained and Tested combination (val score of 0.5027):
#             {'max_depth': 24, 'max_features': 1, 'ccp_alpha': 1e-06, 'splitter': 'random', 'features': 9}
#             Current best combo (with val score 0.5493):
#                     {'max_depth': 24, 'max_features': 0.85, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 9}
#         Has trained 521 of 25200 combinations so far
# Already Trained and Tested combination (val score of 0.5493):
#             {'max_depth': 24, 'max_features': 0.85, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 9}
#             Current best combo (with val score 0.5493):
#                     {'max_depth': 24, 'max_features': 0.85, 'ccp_alpha': 1e-08, 'splitter': 'random', 'features': 9}
#         Has trained 521 of 25200 combinations so far
# Trained and Tested combination 522 of 25200, taking 0.01 seconds to get val score of 0.5495:
#                 {'max_depth': 24, 'max_features': 0.85, 'ccp_alpha': 0.0001, 'splitter': 'random', 'features': 9},
#             Current best combo with val score 0.5495:
#                     {'max_depth': 24, 'max_features': 0.85, 'ccp_alpha': 0.0001, 'splitter': 'random', 'features': 9}
# Trained and Tested combination 523 of 25200, taking 0.01 seconds to get val score of 0.3409:
#                 {'max_depth': 24, 'max_features': 0.85, 'ccp_alpha': 1e-06, 'splitter': 'best', 'features': 9},
#             Current best combo with val score 0.5495:
#                     {'max_depth': 24, 'max_features': 0.85, 'ccp_alpha': 0.0001, 'splitter': 'random', 'features': 9}
# Trained and Tested combination 524 of 25200, taking 0.0 seconds to get val score of 0.5054:
#                 {'max_depth': 24, 'max_features': 0.85, 'ccp_alpha': 1e-06, 'splitter': 'random', 'features': 8},
#             Current best combo with val score 0.5495:
#                     {'max_depth': 24, 'max_features': 0.85, 'ccp_alpha': 0.0001, 'splitter': 'random', 'features': 9}
# Already Trained and Tested combination (val score of 0.4986):
#             {'max_depth': 24, 'max_features': 0.85, 'ccp_alpha': 1e-06, 'splitter': 'random', 'features': 10}
#             Current best combo (with val score 0.5495):
#                     {'max_depth': 24, 'max_features': 0.85, 'ccp_alpha': 0.0001, 'splitter': 'random', 'features': 9}
#         Has trained 524 of 25200 combinations so far
# Trained and Tested combination 525 of 25200, taking 0.0 seconds to get val score of 0.5051:
#                 {'max_depth': 12, 'max_features': 0.85, 'ccp_alpha': 0.0001, 'splitter': 'random', 'features': 9},
#             Current best combo with val score 0.5495:
#                     {'max_depth': 24, 'max_features': 0.85, 'ccp_alpha': 0.0001, 'splitter': 'random', 'features': 9}
# Trained and Tested combination 526 of 25200, taking 0.0 seconds to get val score of 0.5254:
#                 {'max_depth': 48, 'max_features': 0.85, 'ccp_alpha': 0.0001, 'splitter': 'random', 'features': 9},
#             Current best combo with val score 0.5495:
#                     {'max_depth': 24, 'max_features': 0.85, 'ccp_alpha': 0.0001, 'splitter': 'random', 'features': 9}
# Trained and Tested combination 527 of 25200, taking 0.0 seconds to get val score of 0.4318:
#                 {'max_depth': 24, 'max_features': 0.7, 'ccp_alpha': 0.0001, 'splitter': 'random', 'features': 9},
#             Current best combo with val score 0.5495:
#                     {'max_depth': 24, 'max_features': 0.85, 'ccp_alpha': 0.0001, 'splitter': 'random', 'features': 9}
# Trained and Tested combination 528 of 25200, taking 0.0 seconds to get val score of 0.5046:
#                 {'max_depth': 24, 'max_features': 1, 'ccp_alpha': 0.0001, 'splitter': 'random', 'features': 9},
#             Current best combo with val score 0.5495:
#                     {'max_depth': 24, 'max_features': 0.85, 'ccp_alpha': 0.0001, 'splitter': 'random', 'features': 9}
# Already Trained and Tested combination (val score of 0.5493):
#             {'max_depth': 24, 'max_features': 0.85, 'ccp_alpha': 1e-06, 'splitter': 'random', 'features': 9}
#             Current best combo (with val score 0.5495):
#                     {'max_depth': 24, 'max_features': 0.85, 'ccp_alpha': 0.0001, 'splitter': 'random', 'features': 9}
#         Has trained 528 of 25200 combinations so far
# Trained and Tested combination 529 of 25200, taking 0.01 seconds to get val score of 0.2933:
#                 {'max_depth': 24, 'max_features': 0.85, 'ccp_alpha': 0.01, 'splitter': 'random', 'features': 9},
#             Current best combo with val score 0.5495:
#                     {'max_depth': 24, 'max_features': 0.85, 'ccp_alpha': 0.0001, 'splitter': 'random', 'features': 9}
# Trained and Tested combination 530 of 25200, taking 0.02 seconds to get val score of 0.3409:
#                 {'max_depth': 24, 'max_features': 0.85, 'ccp_alpha': 0.0001, 'splitter': 'best', 'features': 9},
#             Current best combo with val score 0.5495:
#                     {'max_depth': 24, 'max_features': 0.85, 'ccp_alpha': 0.0001, 'splitter': 'random', 'features': 9}
# Trained and Tested combination 531 of 25200, taking 0.01 seconds to get val score of 0.5054:
#                 {'max_depth': 24, 'max_features': 0.85, 'ccp_alpha': 0.0001, 'splitter': 'random', 'features': 8},
#             Current best combo with val score 0.5495:
#                     {'max_depth': 24, 'max_features': 0.85, 'ccp_alpha': 0.0001, 'splitter': 'random', 'features': 9}
# Trained and Tested combination 532 of 25200, taking 0.01 seconds to get val score of 0.5012:
#                 {'max_depth': 24, 'max_features': 0.85, 'ccp_alpha': 0.0001, 'splitter': 'random', 'features': 10},
#             Current best combo with val score 0.5495:
#                     {'max_depth': 24, 'max_features': 0.85, 'ccp_alpha': 0.0001, 'splitter': 'random', 'features': 9}
# % Combos Checked Thus Far: 532 out of 25200 which is 2.1111109999999997%
# Guidance: round FINAL
#
# 	round FINAL iteration:  0
#
# Already Trained and Tested combination (val score of 0.5051):
#             {'max_depth': 12, 'max_features': 0.85, 'ccp_alpha': 0.0001, 'splitter': 'random', 'features': 9}
#             Current best combo (with val score 0.5495):
#                     {'max_depth': 24, 'max_features': 0.85, 'ccp_alpha': 0.0001, 'splitter': 'random', 'features': 9}
#         Has trained 532 of 25200 combinations so far
# Already Trained and Tested combination (val score of 0.5254):
#             {'max_depth': 48, 'max_features': 0.85, 'ccp_alpha': 0.0001, 'splitter': 'random', 'features': 9}
#             Current best combo (with val score 0.5495):
#                     {'max_depth': 24, 'max_features': 0.85, 'ccp_alpha': 0.0001, 'splitter': 'random', 'features': 9}
#         Has trained 532 of 25200 combinations so far
# Already Trained and Tested combination (val score of 0.4318):
#             {'max_depth': 24, 'max_features': 0.7, 'ccp_alpha': 0.0001, 'splitter': 'random', 'features': 9}
#             Current best combo (with val score 0.5495):
#                     {'max_depth': 24, 'max_features': 0.85, 'ccp_alpha': 0.0001, 'splitter': 'random', 'features': 9}
#         Has trained 532 of 25200 combinations so far
# Already Trained and Tested combination (val score of 0.5046):
#             {'max_depth': 24, 'max_features': 1, 'ccp_alpha': 0.0001, 'splitter': 'random', 'features': 9}
#             Current best combo (with val score 0.5495):
#                     {'max_depth': 24, 'max_features': 0.85, 'ccp_alpha': 0.0001, 'splitter': 'random', 'features': 9}
#         Has trained 532 of 25200 combinations so far
# Already Trained and Tested combination (val score of 0.5493):
#             {'max_depth': 24, 'max_features': 0.85, 'ccp_alpha': 1e-06, 'splitter': 'random', 'features': 9}
#             Current best combo (with val score 0.5495):
#                     {'max_depth': 24, 'max_features': 0.85, 'ccp_alpha': 0.0001, 'splitter': 'random', 'features': 9}
#         Has trained 532 of 25200 combinations so far
# Already Trained and Tested combination (val score of 0.2933):
#             {'max_depth': 24, 'max_features': 0.85, 'ccp_alpha': 0.01, 'splitter': 'random', 'features': 9}
#             Current best combo (with val score 0.5495):
#                     {'max_depth': 24, 'max_features': 0.85, 'ccp_alpha': 0.0001, 'splitter': 'random', 'features': 9}
#         Has trained 532 of 25200 combinations so far
# Already Trained and Tested combination (val score of 0.3409):
#             {'max_depth': 24, 'max_features': 0.85, 'ccp_alpha': 0.0001, 'splitter': 'best', 'features': 9}
#             Current best combo (with val score 0.5495):
#                     {'max_depth': 24, 'max_features': 0.85, 'ccp_alpha': 0.0001, 'splitter': 'random', 'features': 9}
#         Has trained 532 of 25200 combinations so far
# Already Trained and Tested combination (val score of 0.5054):
#             {'max_depth': 24, 'max_features': 0.85, 'ccp_alpha': 0.0001, 'splitter': 'random', 'features': 8}
#             Current best combo (with val score 0.5495):
#                     {'max_depth': 24, 'max_features': 0.85, 'ccp_alpha': 0.0001, 'splitter': 'random', 'features': 9}
#         Has trained 532 of 25200 combinations so far
# Already Trained and Tested combination (val score of 0.5012):
#             {'max_depth': 24, 'max_features': 0.85, 'ccp_alpha': 0.0001, 'splitter': 'random', 'features': 10}
#             Current best combo (with val score 0.5495):
#                     {'max_depth': 24, 'max_features': 0.85, 'ccp_alpha': 0.0001, 'splitter': 'random', 'features': 9}
#         Has trained 532 of 25200 combinations so far
# % Combos Checked Thus Far: 532 out of 25200 which is 2.1111109999999997%
# Max Val Score:
#  0.549492
# Max Val Score Std:
#  0.035753
# Best Combo Train Score:
#  0.980528
# Best Combo Train Score Std:
#  0.003284
# Max Combo Index:
#  (3, 3, 2, 1, 9) out of [7, 5, 5, 2, 72] (note best combo is 0-indexed)
# Max Combo Hyperparamer Combination:
#  {'max_depth': 24, 'max_features': 0.85, 'ccp_alpha': 0.0001, 'splitter': 'random', 'features': 9}
# Max Combo Features:
#  ('procedure_228130', 'procedure_225792', 'procedure_228125', 'lods_score', 'ventilation_used', 'procedure_226236', 'hospital_stay_duration', 'procedure_225469', 'procedure_224270', 'procedure_225446')
# % Combos Checked: 532 out of 25200 which is 2.1111109999999997%
