# %% [markdown]
# # Tuning Script

# %%
# Parameters subject to change in every script - involved in naming

MODEL = 'xgbc'
PREPROCESSING = 'smote_normalise'
TUNER = 'yangzhoub'
OPTIMISED_METRIC = 'f1'

# %% [markdown]
# ---

# %%
# detect whether this is a google environment

COLAB_ENVIRONMENT = False

try:
    from google.colab import drive
    drive.mount('/content/drive')
    COLAB_ENVIRONMENT = True
except:
    pass
# Out:
# Mounted at /content/drive

# %%
import sys
import os
import pickle

if COLAB_ENVIRONMENT:
    home_directory = './drive/MyDrive/LAB/COMP90089__GroupWork__Py/' # my home directory is stored in ./LAB of google drive
    if MODEL == 'ebr':
        # !pip install interpret==0.5.0
    elif MODEL == 'cbr':
        # !pip install catboost
    elif MODEL in ['tf', 'mlp']:
        # !pip install PyTorch2Sklearn
    # !pip install JXAutoML
else:
    home_directory = '../../'

from JXAutoML.YangZhouB_10CV import YangZhouB_10CV as Tuner

import pandas as pd
# Out:
# Collecting JXAutoML
#   Downloading JXAutoML-0.4.4-py3-none-any.whl.metadata (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.2/67.2 kB 1.7 MB/s eta 0:00:00
# Downloading JXAutoML-0.4.4-py3-none-any.whl (52 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.1/52.1 kB 4.0 MB/s eta 0:00:00
# Installing collected packages: JXAutoML
# Successfully installed JXAutoML-0.4.4

# %%
# Parameters that are same for every script

FOLDS = 10  # we have decided to do 10 fold validation

SEED = 42

TASK_TYPE = 'Classification'  # this task is a classification task

# we have decided to tune features as hp
TUNE_FEATURES_AS_HYPERPARAMETERS = True

# %% [markdown]
# ---

# %%
# model to use to tune
from xgboost import XGBClassifier as clf

# what values to try for each hyperparameter
parameter_choices = {
        'n_estimators': (25, 50, 100, 200, 400, 800),
        'max_depth': (3, 6, 12, 24, 48, 96, 192),
        'subsample': (0.4, 0.55, 0.7, 0.85, 1),
        'colsample_bytree': (0.4, 0.55, 0.7, 0.85, 1),
        'gamma': (0.00000001, 0.000001, 0.0001, 0.01, 0.1),
        'eta': (0.0001, 0.001, 0.01, 0.1, 1, 10)
}

# what values to set non-tuneable parameters/hyperparameters
non_tunable_hyperparameters_dict = {
                                    'random_state': SEED,
                                    'n_jobs': -1
                                    }

# %% [markdown]
# ---

# %% [markdown]
# Read in and Prepare Data

# %%
# Import data and store as lists

train_x_list = []
train_y_list = []
val_x_list = []
val_y_list = []

for i in range(FOLDS):
    train_data = pd.read_csv(
        f'{home_directory}data/curated/modelling/{PREPROCESSING}/train_{i}.csv')
    val_data = pd.read_csv(
        f'{home_directory}data/curated/modelling/{PREPROCESSING}/val_{i}.csv')

    # get the correct rows for X and y
    train_x = train_data.drop(
        ['mortality_status', 'subject_id', 'hadm_id', 'stay_id'], axis=1)
    train_y = train_data['mortality_status']
    val_x = val_data.drop(
        ['mortality_status', 'subject_id', 'hadm_id', 'stay_id'], axis=1)
    val_y = val_data['mortality_status']

    train_x_list.append(train_x)
    train_y_list.append(train_y)
    val_x_list.append(val_x)
    val_y_list.append(val_y)

# %%
# Import feature importance ordering

with open(f'{home_directory}models/xgb_feature_importance_ordering_{PREPROCESSING}.pickle', 'rb') as f:
    feature_importance_ordering = pickle.load(f)

# %% [markdown]
# Set parameters

# %%
# initialisation
tuner = Tuner()

print('---')

# define what model we are tuning
tuner.read_in_model(clf, TASK_TYPE, optimised_metric=OPTIMISED_METRIC)

print('---')

# read in the data for training and validation
tuner.read_in_data(train_x_list, train_y_list, val_x_list, val_y_list)

print('---')

# set what hp values to tune
tuner.set_hyperparameters(parameter_choices)
# WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

# set up hp values that need to be changed from default but NOT to be tuned
tuner.set_non_tuneable_hyperparameters(non_tunable_hyperparameters_dict)

print('---')

# set up feature importance ordering

if TUNE_FEATURES_AS_HYPERPARAMETERS:
    tuner.set_features(feature_importance_ordering)
    # WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

try:  # try to read in previous results to continue tuning ...
    tuner.read_in_tuning_result_df(
        f'{home_directory}models/tuning/{TUNER}_{MODEL}_{PREPROCESSING}.csv')
except:
    print('No previous tuning data read in')

print('---')

# set up where to save the tuning result csv
tuner.set_tuning_result_saving_address(
    f'{home_directory}models/tuning/{TUNER}_{MODEL}_{PREPROCESSING}.csv')

print('---')

# set up where to save the current best model
tuner.set_best_model_saving_address(
    f'{home_directory}models/tmp_models/{TUNER}_{MODEL}_{PREPROCESSING}')
# Out:
# YangZhouB Initialised
# ---
# Successfully read in model <class 'xgboost.sklearn.XGBClassifier'>, which is a Classification model optimising for f1
# ---
# Read in Train X data list
# Read in Train y data list
# Read in Val X data list
# Read in Val y data list
# ---
# Successfully recorded hyperparameter choices
# ---
# Successfully recorded non_tuneable_hyperparameter choices
# ---
# Successfully recorded tuneable feature combination choices and updated relevant internal structures
# ---
# Successfully read in tuning result of 1362 rows, for 1362.0 combos
# ---
# Successfully set tuning output address
# ---
# Successfully set best model output address

# %%
# ignore warnings

import warnings
warnings.filterwarnings("ignore")

# %%
# begin tuning ... (or continue training)

tuner.tune()
# Out:
# Streaming output truncated to the last 5000 lines.
#             Current best combo (with val score 0.3985):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 5}
#         Has trained 1362 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.1762):
#             {'n_estimators': 800, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 1, 'gamma': 1e-08, 'eta': 10, 'features': 35}
#             Current best combo (with val score 0.3985):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 5}
#         Has trained 1362 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.1098):
#             {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 1, 'gamma': 1e-08, 'eta': 10, 'features': 25}
#             Current best combo (with val score 0.3985):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 5}
#         Has trained 1362 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.1158):
#             {'n_estimators': 800, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 1, 'gamma': 1e-08, 'eta': 0.0001, 'features': 20}
#             Current best combo (with val score 0.3985):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 5}
#         Has trained 1362 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.2084):
#             {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 1, 'gamma': 1e-08, 'eta': 10, 'features': 20}
#             Current best combo (with val score 0.3985):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 5}
#         Has trained 1362 of 1512000 combinations so far
#
#
# STAGE ONE: Begin initial Guidance system
#
#
# Guidance: initial round
#
# 	round 0 iteration:  0
#
# Already Trained and Tested combination (val score of 0.0133):
#             {'n_estimators': 100, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.7, 'gamma': 0.0001, 'eta': 0.1, 'features': 24}
#             Current best combo (with val score 0.3985):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 5}
#         Has trained 1362 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.0067):
#             {'n_estimators': 400, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.7, 'gamma': 0.0001, 'eta': 0.1, 'features': 24}
#             Current best combo (with val score 0.3985):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 5}
#         Has trained 1362 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.0099):
#             {'n_estimators': 200, 'max_depth': 12, 'subsample': 0.7, 'colsample_bytree': 0.7, 'gamma': 0.0001, 'eta': 0.1, 'features': 24}
#             Current best combo (with val score 0.3985):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 5}
#         Has trained 1362 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.0067):
#             {'n_estimators': 200, 'max_depth': 48, 'subsample': 0.7, 'colsample_bytree': 0.7, 'gamma': 0.0001, 'eta': 0.1, 'features': 24}
#             Current best combo (with val score 0.3985):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 5}
#         Has trained 1362 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.01):
#             {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.55, 'colsample_bytree': 0.7, 'gamma': 0.0001, 'eta': 0.1, 'features': 24}
#             Current best combo (with val score 0.3985):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 5}
#         Has trained 1362 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.047):
#             {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.85, 'colsample_bytree': 0.7, 'gamma': 0.0001, 'eta': 0.1, 'features': 24}
#             Current best combo (with val score 0.3985):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 5}
#         Has trained 1362 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.0133):
#             {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.55, 'gamma': 0.0001, 'eta': 0.1, 'features': 24}
#             Current best combo (with val score 0.3985):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 5}
#         Has trained 1362 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.85, 'gamma': 0.0001, 'eta': 0.1, 'features': 24}
#             Current best combo (with val score 0.3985):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 5}
#         Has trained 1362 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.0132):
#             {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.7, 'gamma': 1e-06, 'eta': 0.1, 'features': 24}
#             Current best combo (with val score 0.3985):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 5}
#         Has trained 1362 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.01):
#             {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.7, 'gamma': 0.01, 'eta': 0.1, 'features': 24}
#             Current best combo (with val score 0.3985):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 5}
#         Has trained 1362 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.0748):
#             {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.7, 'gamma': 0.0001, 'eta': 0.01, 'features': 24}
#             Current best combo (with val score 0.3985):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 5}
#         Has trained 1362 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.0888):
#             {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.7, 'gamma': 0.0001, 'eta': 1, 'features': 24}
#             Current best combo (with val score 0.3985):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 5}
#         Has trained 1362 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.0656):
#             {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.7, 'gamma': 0.0001, 'eta': 0.1, 'features': 23}
#             Current best combo (with val score 0.3985):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 5}
#         Has trained 1362 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.01):
#             {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.7, 'gamma': 0.0001, 'eta': 0.1, 'features': 25}
#             Current best combo (with val score 0.3985):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 5}
#         Has trained 1362 of 1512000 combinations so far
# 	round 0 iteration:  1
#
# Already Trained and Tested combination (val score of 0.0261):
#             {'n_estimators': 50, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.7, 'gamma': 0.0001, 'eta': 0.1, 'features': 24}
#             Current best combo (with val score 0.3985):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 5}
#         Has trained 1362 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.0067):
#             {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.7, 'gamma': 0.0001, 'eta': 0.1, 'features': 24}
#             Current best combo (with val score 0.3985):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 5}
#         Has trained 1362 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.0131):
#             {'n_estimators': 100, 'max_depth': 12, 'subsample': 0.7, 'colsample_bytree': 0.7, 'gamma': 0.0001, 'eta': 0.1, 'features': 24}
#             Current best combo (with val score 0.3985):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 5}
#         Has trained 1362 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.0133):
#             {'n_estimators': 100, 'max_depth': 48, 'subsample': 0.7, 'colsample_bytree': 0.7, 'gamma': 0.0001, 'eta': 0.1, 'features': 24}
#             Current best combo (with val score 0.3985):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 5}
#         Has trained 1362 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.0067):
#             {'n_estimators': 100, 'max_depth': 24, 'subsample': 0.55, 'colsample_bytree': 0.7, 'gamma': 0.0001, 'eta': 0.1, 'features': 24}
#             Current best combo (with val score 0.3985):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 5}
#         Has trained 1362 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.0729):
#             {'n_estimators': 100, 'max_depth': 24, 'subsample': 0.85, 'colsample_bytree': 0.7, 'gamma': 0.0001, 'eta': 0.1, 'features': 24}
#             Current best combo (with val score 0.3985):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 5}
#         Has trained 1362 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.0258):
#             {'n_estimators': 100, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.55, 'gamma': 0.0001, 'eta': 0.1, 'features': 24}
#             Current best combo (with val score 0.3985):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 5}
#         Has trained 1362 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.0033):
#             {'n_estimators': 100, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.85, 'gamma': 0.0001, 'eta': 0.1, 'features': 24}
#             Current best combo (with val score 0.3985):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 5}
#         Has trained 1362 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.0225):
#             {'n_estimators': 100, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.7, 'gamma': 1e-06, 'eta': 0.1, 'features': 24}
#             Current best combo (with val score 0.3985):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 5}
#         Has trained 1362 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.0099):
#             {'n_estimators': 100, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.7, 'gamma': 0.01, 'eta': 0.1, 'features': 24}
#             Current best combo (with val score 0.3985):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 5}
#         Has trained 1362 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.1054):
#             {'n_estimators': 100, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.7, 'gamma': 0.0001, 'eta': 0.01, 'features': 24}
#             Current best combo (with val score 0.3985):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 5}
#         Has trained 1362 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.0885):
#             {'n_estimators': 100, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.7, 'gamma': 0.0001, 'eta': 1, 'features': 24}
#             Current best combo (with val score 0.3985):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 5}
#         Has trained 1362 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.078):
#             {'n_estimators': 100, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.7, 'gamma': 0.0001, 'eta': 0.1, 'features': 23}
#             Current best combo (with val score 0.3985):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 5}
#         Has trained 1362 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.01):
#             {'n_estimators': 100, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.7, 'gamma': 0.0001, 'eta': 0.1, 'features': 25}
#             Current best combo (with val score 0.3985):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 5}
#         Has trained 1362 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.0067):
#             {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.7, 'gamma': 0.0001, 'eta': 0.1, 'features': 24}
#             Current best combo (with val score 0.3985):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 5}
#         Has trained 1362 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.0067):
#             {'n_estimators': 800, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.7, 'gamma': 0.0001, 'eta': 0.1, 'features': 24}
#             Current best combo (with val score 0.3985):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 5}
#         Has trained 1362 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.0166):
#             {'n_estimators': 400, 'max_depth': 12, 'subsample': 0.7, 'colsample_bytree': 0.7, 'gamma': 0.0001, 'eta': 0.1, 'features': 24}
#             Current best combo (with val score 0.3985):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 5}
#         Has trained 1362 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.0067):
#             {'n_estimators': 400, 'max_depth': 48, 'subsample': 0.7, 'colsample_bytree': 0.7, 'gamma': 0.0001, 'eta': 0.1, 'features': 24}
#             Current best combo (with val score 0.3985):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 5}
#         Has trained 1362 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.01):
#             {'n_estimators': 400, 'max_depth': 24, 'subsample': 0.55, 'colsample_bytree': 0.7, 'gamma': 0.0001, 'eta': 0.1, 'features': 24}
#             Current best combo (with val score 0.3985):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 5}
#         Has trained 1362 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.0382):
#             {'n_estimators': 400, 'max_depth': 24, 'subsample': 0.85, 'colsample_bytree': 0.7, 'gamma': 0.0001, 'eta': 0.1, 'features': 24}
#             Current best combo (with val score 0.3985):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 5}
#         Has trained 1362 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.0099):
#             {'n_estimators': 400, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.55, 'gamma': 0.0001, 'eta': 0.1, 'features': 24}
#             Current best combo (with val score 0.3985):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 5}
#         Has trained 1362 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.0099):
#             {'n_estimators': 400, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.85, 'gamma': 0.0001, 'eta': 0.1, 'features': 24}
#             Current best combo (with val score 0.3985):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 5}
#         Has trained 1362 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.0132):
#             {'n_estimators': 400, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.7, 'gamma': 1e-06, 'eta': 0.1, 'features': 24}
#             Current best combo (with val score 0.3985):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 5}
#         Has trained 1362 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.0067):
#             {'n_estimators': 400, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.7, 'gamma': 0.01, 'eta': 0.1, 'features': 24}
#             Current best combo (with val score 0.3985):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 5}
#         Has trained 1362 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.0328):
#             {'n_estimators': 400, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.7, 'gamma': 0.0001, 'eta': 0.01, 'features': 24}
#             Current best combo (with val score 0.3985):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 5}
#         Has trained 1362 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.1145):
#             {'n_estimators': 400, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.7, 'gamma': 0.0001, 'eta': 1, 'features': 24}
#             Current best combo (with val score 0.3985):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 5}
#         Has trained 1362 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.0485):
#             {'n_estimators': 400, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.7, 'gamma': 0.0001, 'eta': 0.1, 'features': 23}
#             Current best combo (with val score 0.3985):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 5}
#         Has trained 1362 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.0132):
#             {'n_estimators': 400, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.7, 'gamma': 0.0001, 'eta': 0.1, 'features': 25}
#             Current best combo (with val score 0.3985):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 5}
#         Has trained 1362 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.0131):
#             {'n_estimators': 100, 'max_depth': 12, 'subsample': 0.7, 'colsample_bytree': 0.7, 'gamma': 0.0001, 'eta': 0.1, 'features': 24}
#             Current best combo (with val score 0.3985):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 5}
#         Has trained 1362 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.0166):
#             {'n_estimators': 400, 'max_depth': 12, 'subsample': 0.7, 'colsample_bytree': 0.7, 'gamma': 0.0001, 'eta': 0.1, 'features': 24}
#             Current best combo (with val score 0.3985):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 5}
#         Has trained 1362 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.0288):
#             {'n_estimators': 200, 'max_depth': 6, 'subsample': 0.7, 'colsample_bytree': 0.7, 'gamma': 0.0001, 'eta': 0.1, 'features': 24}
#             Current best combo (with val score 0.3985):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 5}
#         Has trained 1362 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.0067):
#             {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.7, 'gamma': 0.0001, 'eta': 0.1, 'features': 24}
#             Current best combo (with val score 0.3985):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 5}
#         Has trained 1362 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 200, 'max_depth': 12, 'subsample': 0.55, 'colsample_bytree': 0.7, 'gamma': 0.0001, 'eta': 0.1, 'features': 24}
#             Current best combo (with val score 0.3985):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 5}
#         Has trained 1362 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.0379):
#             {'n_estimators': 200, 'max_depth': 12, 'subsample': 0.85, 'colsample_bytree': 0.7, 'gamma': 0.0001, 'eta': 0.1, 'features': 24}
#             Current best combo (with val score 0.3985):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 5}
#         Has trained 1362 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.0232):
#             {'n_estimators': 200, 'max_depth': 12, 'subsample': 0.7, 'colsample_bytree': 0.55, 'gamma': 0.0001, 'eta': 0.1, 'features': 24}
#             Current best combo (with val score 0.3985):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 5}
#         Has trained 1362 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.0033):
#             {'n_estimators': 200, 'max_depth': 12, 'subsample': 0.7, 'colsample_bytree': 0.85, 'gamma': 0.0001, 'eta': 0.1, 'features': 24}
#             Current best combo (with val score 0.3985):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 5}
#         Has trained 1362 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.0033):
#             {'n_estimators': 200, 'max_depth': 12, 'subsample': 0.7, 'colsample_bytree': 0.7, 'gamma': 1e-06, 'eta': 0.1, 'features': 24}
#             Current best combo (with val score 0.3985):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 5}
#         Has trained 1362 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.0165):
#             {'n_estimators': 200, 'max_depth': 12, 'subsample': 0.7, 'colsample_bytree': 0.7, 'gamma': 0.01, 'eta': 0.1, 'features': 24}
#             Current best combo (with val score 0.3985):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 5}
#         Has trained 1362 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.0803):
#             {'n_estimators': 200, 'max_depth': 12, 'subsample': 0.7, 'colsample_bytree': 0.7, 'gamma': 0.0001, 'eta': 0.01, 'features': 24}
#             Current best combo (with val score 0.3985):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 5}
#         Has trained 1362 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.1441):
#             {'n_estimators': 200, 'max_depth': 12, 'subsample': 0.7, 'colsample_bytree': 0.7, 'gamma': 0.0001, 'eta': 1, 'features': 24}
#             Current best combo (with val score 0.3985):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 5}
#         Has trained 1362 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.044):
#             {'n_estimators': 200, 'max_depth': 12, 'subsample': 0.7, 'colsample_bytree': 0.7, 'gamma': 0.0001, 'eta': 0.1, 'features': 23}
#             Current best combo (with val score 0.3985):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 5}
#         Has trained 1362 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 200, 'max_depth': 12, 'subsample': 0.7, 'colsample_bytree': 0.7, 'gamma': 0.0001, 'eta': 0.1, 'features': 25}
#             Current best combo (with val score 0.3985):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 5}
#         Has trained 1362 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.0133):
#             {'n_estimators': 100, 'max_depth': 48, 'subsample': 0.7, 'colsample_bytree': 0.7, 'gamma': 0.0001, 'eta': 0.1, 'features': 24}
#             Current best combo (with val score 0.3985):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 5}
#         Has trained 1362 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.0067):
#             {'n_estimators': 400, 'max_depth': 48, 'subsample': 0.7, 'colsample_bytree': 0.7, 'gamma': 0.0001, 'eta': 0.1, 'features': 24}
#             Current best combo (with val score 0.3985):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 5}
#         Has trained 1362 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.0067):
#             {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.7, 'gamma': 0.0001, 'eta': 0.1, 'features': 24}
#             Current best combo (with val score 0.3985):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 5}
#         Has trained 1362 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.0067):
#             {'n_estimators': 200, 'max_depth': 96, 'subsample': 0.7, 'colsample_bytree': 0.7, 'gamma': 0.0001, 'eta': 0.1, 'features': 24}
#             Current best combo (with val score 0.3985):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 5}
#         Has trained 1362 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.01):
#             {'n_estimators': 200, 'max_depth': 48, 'subsample': 0.55, 'colsample_bytree': 0.7, 'gamma': 0.0001, 'eta': 0.1, 'features': 24}
#             Current best combo (with val score 0.3985):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 5}
#         Has trained 1362 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.0442):
#             {'n_estimators': 200, 'max_depth': 48, 'subsample': 0.85, 'colsample_bytree': 0.7, 'gamma': 0.0001, 'eta': 0.1, 'features': 24}
#             Current best combo (with val score 0.3985):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 5}
#         Has trained 1362 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.0133):
#             {'n_estimators': 200, 'max_depth': 48, 'subsample': 0.7, 'colsample_bytree': 0.55, 'gamma': 0.0001, 'eta': 0.1, 'features': 24}
#             Current best combo (with val score 0.3985):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 5}
#         Has trained 1362 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.0033):
#             {'n_estimators': 200, 'max_depth': 48, 'subsample': 0.7, 'colsample_bytree': 0.85, 'gamma': 0.0001, 'eta': 0.1, 'features': 24}
#             Current best combo (with val score 0.3985):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 5}
#         Has trained 1362 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.0132):
#             {'n_estimators': 200, 'max_depth': 48, 'subsample': 0.7, 'colsample_bytree': 0.7, 'gamma': 1e-06, 'eta': 0.1, 'features': 24}
#             Current best combo (with val score 0.3985):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 5}
#         Has trained 1362 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.01):
#             {'n_estimators': 200, 'max_depth': 48, 'subsample': 0.7, 'colsample_bytree': 0.7, 'gamma': 0.01, 'eta': 0.1, 'features': 24}
#             Current best combo (with val score 0.3985):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 5}
#         Has trained 1362 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.0748):
#             {'n_estimators': 200, 'max_depth': 48, 'subsample': 0.7, 'colsample_bytree': 0.7, 'gamma': 0.0001, 'eta': 0.01, 'features': 24}
#             Current best combo (with val score 0.3985):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 5}
#         Has trained 1362 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.0888):
#             {'n_estimators': 200, 'max_depth': 48, 'subsample': 0.7, 'colsample_bytree': 0.7, 'gamma': 0.0001, 'eta': 1, 'features': 24}
#             Current best combo (with val score 0.3985):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 5}
#         Has trained 1362 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.0766):
#             {'n_estimators': 200, 'max_depth': 48, 'subsample': 0.7, 'colsample_bytree': 0.7, 'gamma': 0.0001, 'eta': 0.1, 'features': 23}
#             Current best combo (with val score 0.3985):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 5}
#         Has trained 1362 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.01):
#             {'n_estimators': 200, 'max_depth': 48, 'subsample': 0.7, 'colsample_bytree': 0.7, 'gamma': 0.0001, 'eta': 0.1, 'features': 25}
#             Current best combo (with val score 0.3985):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 5}
#         Has trained 1362 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.0067):
#             {'n_estimators': 100, 'max_depth': 24, 'subsample': 0.55, 'colsample_bytree': 0.7, 'gamma': 0.0001, 'eta': 0.1, 'features': 24}
#             Current best combo (with val score 0.3985):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 5}
#         Has trained 1362 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.01):
#             {'n_estimators': 400, 'max_depth': 24, 'subsample': 0.55, 'colsample_bytree': 0.7, 'gamma': 0.0001, 'eta': 0.1, 'features': 24}
#             Current best combo (with val score 0.3985):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 5}
#         Has trained 1362 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 200, 'max_depth': 12, 'subsample': 0.55, 'colsample_bytree': 0.7, 'gamma': 0.0001, 'eta': 0.1, 'features': 24}
#             Current best combo (with val score 0.3985):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 5}
#         Has trained 1362 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.01):
#             {'n_estimators': 200, 'max_depth': 48, 'subsample': 0.55, 'colsample_bytree': 0.7, 'gamma': 0.0001, 'eta': 0.1, 'features': 24}
#             Current best combo (with val score 0.3985):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 5}
#         Has trained 1362 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.0033):
#             {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.7, 'gamma': 0.0001, 'eta': 0.1, 'features': 24}
#             Current best combo (with val score 0.3985):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 5}
#         Has trained 1362 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.0067):
#             {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.7, 'gamma': 0.0001, 'eta': 0.1, 'features': 24}
#             Current best combo (with val score 0.3985):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 5}
#         Has trained 1362 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.0165):
#             {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.55, 'colsample_bytree': 0.55, 'gamma': 0.0001, 'eta': 0.1, 'features': 24}
#             Current best combo (with val score 0.3985):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 5}
#         Has trained 1362 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.0067):
#             {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.55, 'colsample_bytree': 0.85, 'gamma': 0.0001, 'eta': 0.1, 'features': 24}
#             Current best combo (with val score 0.3985):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 5}
#         Has trained 1362 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.0067):
#             {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.55, 'colsample_bytree': 0.7, 'gamma': 1e-06, 'eta': 0.1, 'features': 24}
#             Current best combo (with val score 0.3985):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 5}
#         Has trained 1362 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.0096):
#             {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.55, 'colsample_bytree': 0.7, 'gamma': 0.01, 'eta': 0.1, 'features': 24}
#             Current best combo (with val score 0.3985):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 5}
#         Has trained 1362 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.0371):
#             {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.55, 'colsample_bytree': 0.7, 'gamma': 0.0001, 'eta': 0.01, 'features': 24}
#             Current best combo (with val score 0.3985):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 5}
#         Has trained 1362 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.0824):
#             {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.55, 'colsample_bytree': 0.7, 'gamma': 0.0001, 'eta': 1, 'features': 24}
#             Current best combo (with val score 0.3985):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 5}
#         Has trained 1362 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.0363):
#             {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.55, 'colsample_bytree': 0.7, 'gamma': 0.0001, 'eta': 0.1, 'features': 23}
#             Current best combo (with val score 0.3985):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 5}
#         Has trained 1362 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.0033):
#             {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.55, 'colsample_bytree': 0.7, 'gamma': 0.0001, 'eta': 0.1, 'features': 25}
#             Current best combo (with val score 0.3985):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 5}
#         Has trained 1362 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.0729):
#             {'n_estimators': 100, 'max_depth': 24, 'subsample': 0.85, 'colsample_bytree': 0.7, 'gamma': 0.0001, 'eta': 0.1, 'features': 24}
#             Current best combo (with val score 0.3985):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 5}
#         Has trained 1362 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.0382):
#             {'n_estimators': 400, 'max_depth': 24, 'subsample': 0.85, 'colsample_bytree': 0.7, 'gamma': 0.0001, 'eta': 0.1, 'features': 24}
#             Current best combo (with val score 0.3985):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 5}
#         Has trained 1362 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.0379):
#             {'n_estimators': 200, 'max_depth': 12, 'subsample': 0.85, 'colsample_bytree': 0.7, 'gamma': 0.0001, 'eta': 0.1, 'features': 24}
#             Current best combo (with val score 0.3985):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 5}
#         Has trained 1362 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.0442):
#             {'n_estimators': 200, 'max_depth': 48, 'subsample': 0.85, 'colsample_bytree': 0.7, 'gamma': 0.0001, 'eta': 0.1, 'features': 24}
#             Current best combo (with val score 0.3985):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 5}
#         Has trained 1362 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.0067):
#             {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.7, 'gamma': 0.0001, 'eta': 0.1, 'features': 24}
#             Current best combo (with val score 0.3985):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 5}
#         Has trained 1362 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.0633):
#             {'n_estimators': 200, 'max_depth': 24, 'subsample': 1, 'colsample_bytree': 0.7, 'gamma': 0.0001, 'eta': 0.1, 'features': 24}
#             Current best combo (with val score 0.3985):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 5}
#         Has trained 1362 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.044):
#             {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.85, 'colsample_bytree': 0.55, 'gamma': 0.0001, 'eta': 0.1, 'features': 24}
#             Current best combo (with val score 0.3985):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 5}
#         Has trained 1362 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.0165):
#             {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.85, 'colsample_bytree': 0.85, 'gamma': 0.0001, 'eta': 0.1, 'features': 24}
#             Current best combo (with val score 0.3985):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 5}
#         Has trained 1362 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.0498):
#             {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.85, 'colsample_bytree': 0.7, 'gamma': 1e-06, 'eta': 0.1, 'features': 24}
#             Current best combo (with val score 0.3985):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 5}
#         Has trained 1362 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.0451):
#             {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.85, 'colsample_bytree': 0.7, 'gamma': 0.01, 'eta': 0.1, 'features': 24}
#             Current best combo (with val score 0.3985):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 5}
#         Has trained 1362 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.0981):
#             {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.85, 'colsample_bytree': 0.7, 'gamma': 0.0001, 'eta': 0.01, 'features': 24}
#             Current best combo (with val score 0.3985):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 5}
#         Has trained 1362 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.0944):
#             {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.85, 'colsample_bytree': 0.7, 'gamma': 0.0001, 'eta': 1, 'features': 24}
#             Current best combo (with val score 0.3985):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 5}
#         Has trained 1362 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.1092):
#             {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.85, 'colsample_bytree': 0.7, 'gamma': 0.0001, 'eta': 0.1, 'features': 23}
#             Current best combo (with val score 0.3985):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 5}
#         Has trained 1362 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.0165):
#             {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.85, 'colsample_bytree': 0.7, 'gamma': 0.0001, 'eta': 0.1, 'features': 25}
#             Current best combo (with val score 0.3985):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 5}
#         Has trained 1362 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.0258):
#             {'n_estimators': 100, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.55, 'gamma': 0.0001, 'eta': 0.1, 'features': 24}
#             Current best combo (with val score 0.3985):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 5}
#         Has trained 1362 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.0099):
# ...
#         Has trained 1362 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.3992):
#             {'n_estimators': 800, 'max_depth': 192, 'subsample': 0.55, 'colsample_bytree': 0.55, 'gamma': 1e-08, 'eta': 1, 'features': 5}
#             Current best combo (with val score 0.405):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 0.7, 'colsample_bytree': 0.55, 'gamma': 1e-08, 'eta': 0.1, 'features': 5}
#         Has trained 1362 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.4011):
#             {'n_estimators': 800, 'max_depth': 192, 'subsample': 0.85, 'colsample_bytree': 0.55, 'gamma': 1e-08, 'eta': 1, 'features': 5}
#             Current best combo (with val score 0.405):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 0.7, 'colsample_bytree': 0.55, 'gamma': 1e-08, 'eta': 0.1, 'features': 5}
#         Has trained 1362 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.3944):
#             {'n_estimators': 800, 'max_depth': 192, 'subsample': 0.7, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 1, 'features': 5}
#             Current best combo (with val score 0.405):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 0.7, 'colsample_bytree': 0.55, 'gamma': 1e-08, 'eta': 0.1, 'features': 5}
#         Has trained 1362 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.3911):
#             {'n_estimators': 800, 'max_depth': 192, 'subsample': 0.7, 'colsample_bytree': 0.7, 'gamma': 1e-08, 'eta': 1, 'features': 5}
#             Current best combo (with val score 0.405):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 0.7, 'colsample_bytree': 0.55, 'gamma': 1e-08, 'eta': 0.1, 'features': 5}
#         Has trained 1362 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.4039):
#             {'n_estimators': 800, 'max_depth': 192, 'subsample': 0.7, 'colsample_bytree': 0.55, 'gamma': 1e-06, 'eta': 1, 'features': 5}
#             Current best combo (with val score 0.405):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 0.7, 'colsample_bytree': 0.55, 'gamma': 1e-08, 'eta': 0.1, 'features': 5}
#         Has trained 1362 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.405):
#             {'n_estimators': 800, 'max_depth': 192, 'subsample': 0.7, 'colsample_bytree': 0.55, 'gamma': 1e-08, 'eta': 0.1, 'features': 5}
#             Current best combo (with val score 0.405):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 0.7, 'colsample_bytree': 0.55, 'gamma': 1e-08, 'eta': 0.1, 'features': 5}
#         Has trained 1362 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.1799):
#             {'n_estimators': 800, 'max_depth': 192, 'subsample': 0.7, 'colsample_bytree': 0.55, 'gamma': 1e-08, 'eta': 10, 'features': 5}
#             Current best combo (with val score 0.405):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 0.7, 'colsample_bytree': 0.55, 'gamma': 1e-08, 'eta': 0.1, 'features': 5}
#         Has trained 1362 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.3999):
#             {'n_estimators': 800, 'max_depth': 192, 'subsample': 0.7, 'colsample_bytree': 0.55, 'gamma': 1e-08, 'eta': 1, 'features': 4}
#             Current best combo (with val score 0.405):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 0.7, 'colsample_bytree': 0.55, 'gamma': 1e-08, 'eta': 0.1, 'features': 5}
#         Has trained 1362 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.3993):
#             {'n_estimators': 800, 'max_depth': 192, 'subsample': 0.7, 'colsample_bytree': 0.55, 'gamma': 1e-08, 'eta': 1, 'features': 6}
#             Current best combo (with val score 0.405):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 0.7, 'colsample_bytree': 0.55, 'gamma': 1e-08, 'eta': 0.1, 'features': 5}
#         Has trained 1362 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.3987):
#             {'n_estimators': 400, 'max_depth': 192, 'subsample': 0.7, 'colsample_bytree': 0.55, 'gamma': 1e-08, 'eta': 0.1, 'features': 4}
#             Current best combo (with val score 0.405):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 0.7, 'colsample_bytree': 0.55, 'gamma': 1e-08, 'eta': 0.1, 'features': 5}
#         Has trained 1362 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.4004):
#             {'n_estimators': 800, 'max_depth': 96, 'subsample': 0.7, 'colsample_bytree': 0.55, 'gamma': 1e-08, 'eta': 0.1, 'features': 4}
#             Current best combo (with val score 0.405):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 0.7, 'colsample_bytree': 0.55, 'gamma': 1e-08, 'eta': 0.1, 'features': 5}
#         Has trained 1362 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.3995):
#             {'n_estimators': 800, 'max_depth': 192, 'subsample': 0.55, 'colsample_bytree': 0.55, 'gamma': 1e-08, 'eta': 0.1, 'features': 4}
#             Current best combo (with val score 0.405):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 0.7, 'colsample_bytree': 0.55, 'gamma': 1e-08, 'eta': 0.1, 'features': 5}
#         Has trained 1362 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.3987):
#             {'n_estimators': 800, 'max_depth': 192, 'subsample': 0.85, 'colsample_bytree': 0.55, 'gamma': 1e-08, 'eta': 0.1, 'features': 4}
#             Current best combo (with val score 0.405):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 0.7, 'colsample_bytree': 0.55, 'gamma': 1e-08, 'eta': 0.1, 'features': 5}
#         Has trained 1362 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.3992):
#             {'n_estimators': 800, 'max_depth': 192, 'subsample': 0.7, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.1, 'features': 4}
#             Current best combo (with val score 0.405):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 0.7, 'colsample_bytree': 0.55, 'gamma': 1e-08, 'eta': 0.1, 'features': 5}
#         Has trained 1362 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.3962):
#             {'n_estimators': 800, 'max_depth': 192, 'subsample': 0.7, 'colsample_bytree': 0.7, 'gamma': 1e-08, 'eta': 0.1, 'features': 4}
#             Current best combo (with val score 0.405):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 0.7, 'colsample_bytree': 0.55, 'gamma': 1e-08, 'eta': 0.1, 'features': 5}
#         Has trained 1362 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.4004):
#             {'n_estimators': 800, 'max_depth': 192, 'subsample': 0.7, 'colsample_bytree': 0.55, 'gamma': 1e-06, 'eta': 0.1, 'features': 4}
#             Current best combo (with val score 0.405):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 0.7, 'colsample_bytree': 0.55, 'gamma': 1e-08, 'eta': 0.1, 'features': 5}
#         Has trained 1362 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.3951):
#             {'n_estimators': 800, 'max_depth': 192, 'subsample': 0.7, 'colsample_bytree': 0.55, 'gamma': 1e-08, 'eta': 0.01, 'features': 4}
#             Current best combo (with val score 0.405):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 0.7, 'colsample_bytree': 0.55, 'gamma': 1e-08, 'eta': 0.1, 'features': 5}
#         Has trained 1362 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.3999):
#             {'n_estimators': 800, 'max_depth': 192, 'subsample': 0.7, 'colsample_bytree': 0.55, 'gamma': 1e-08, 'eta': 1, 'features': 4}
#             Current best combo (with val score 0.405):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 0.7, 'colsample_bytree': 0.55, 'gamma': 1e-08, 'eta': 0.1, 'features': 5}
#         Has trained 1362 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.3987):
#             {'n_estimators': 800, 'max_depth': 192, 'subsample': 0.7, 'colsample_bytree': 0.55, 'gamma': 1e-08, 'eta': 0.1, 'features': 3}
#             Current best combo (with val score 0.405):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 0.7, 'colsample_bytree': 0.55, 'gamma': 1e-08, 'eta': 0.1, 'features': 5}
#         Has trained 1362 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.405):
#             {'n_estimators': 800, 'max_depth': 192, 'subsample': 0.7, 'colsample_bytree': 0.55, 'gamma': 1e-08, 'eta': 0.1, 'features': 5}
#             Current best combo (with val score 0.405):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 0.7, 'colsample_bytree': 0.55, 'gamma': 1e-08, 'eta': 0.1, 'features': 5}
#         Has trained 1362 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.3978):
#             {'n_estimators': 400, 'max_depth': 192, 'subsample': 0.7, 'colsample_bytree': 0.55, 'gamma': 1e-08, 'eta': 0.1, 'features': 6}
#             Current best combo (with val score 0.405):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 0.7, 'colsample_bytree': 0.55, 'gamma': 1e-08, 'eta': 0.1, 'features': 5}
#         Has trained 1362 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.402):
#             {'n_estimators': 800, 'max_depth': 96, 'subsample': 0.7, 'colsample_bytree': 0.55, 'gamma': 1e-08, 'eta': 0.1, 'features': 6}
#             Current best combo (with val score 0.405):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 0.7, 'colsample_bytree': 0.55, 'gamma': 1e-08, 'eta': 0.1, 'features': 5}
#         Has trained 1362 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.4015):
#             {'n_estimators': 800, 'max_depth': 192, 'subsample': 0.55, 'colsample_bytree': 0.55, 'gamma': 1e-08, 'eta': 0.1, 'features': 6}
#             Current best combo (with val score 0.405):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 0.7, 'colsample_bytree': 0.55, 'gamma': 1e-08, 'eta': 0.1, 'features': 5}
#         Has trained 1362 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.4024):
#             {'n_estimators': 800, 'max_depth': 192, 'subsample': 0.85, 'colsample_bytree': 0.55, 'gamma': 1e-08, 'eta': 0.1, 'features': 6}
#             Current best combo (with val score 0.405):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 0.7, 'colsample_bytree': 0.55, 'gamma': 1e-08, 'eta': 0.1, 'features': 5}
#         Has trained 1362 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.4013):
#             {'n_estimators': 800, 'max_depth': 192, 'subsample': 0.7, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.1, 'features': 6}
#             Current best combo (with val score 0.405):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 0.7, 'colsample_bytree': 0.55, 'gamma': 1e-08, 'eta': 0.1, 'features': 5}
#         Has trained 1362 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.4033):
#             {'n_estimators': 800, 'max_depth': 192, 'subsample': 0.7, 'colsample_bytree': 0.7, 'gamma': 1e-08, 'eta': 0.1, 'features': 6}
#             Current best combo (with val score 0.405):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 0.7, 'colsample_bytree': 0.55, 'gamma': 1e-08, 'eta': 0.1, 'features': 5}
#         Has trained 1362 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.402):
#             {'n_estimators': 800, 'max_depth': 192, 'subsample': 0.7, 'colsample_bytree': 0.55, 'gamma': 1e-06, 'eta': 0.1, 'features': 6}
#             Current best combo (with val score 0.405):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 0.7, 'colsample_bytree': 0.55, 'gamma': 1e-08, 'eta': 0.1, 'features': 5}
#         Has trained 1362 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.3972):
#             {'n_estimators': 800, 'max_depth': 192, 'subsample': 0.7, 'colsample_bytree': 0.55, 'gamma': 1e-08, 'eta': 0.01, 'features': 6}
#             Current best combo (with val score 0.405):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 0.7, 'colsample_bytree': 0.55, 'gamma': 1e-08, 'eta': 0.1, 'features': 5}
#         Has trained 1362 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.3993):
#             {'n_estimators': 800, 'max_depth': 192, 'subsample': 0.7, 'colsample_bytree': 0.55, 'gamma': 1e-08, 'eta': 1, 'features': 6}
#             Current best combo (with val score 0.405):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 0.7, 'colsample_bytree': 0.55, 'gamma': 1e-08, 'eta': 0.1, 'features': 5}
#         Has trained 1362 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.405):
#             {'n_estimators': 800, 'max_depth': 192, 'subsample': 0.7, 'colsample_bytree': 0.55, 'gamma': 1e-08, 'eta': 0.1, 'features': 5}
#             Current best combo (with val score 0.405):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 0.7, 'colsample_bytree': 0.55, 'gamma': 1e-08, 'eta': 0.1, 'features': 5}
#         Has trained 1362 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.3997):
#             {'n_estimators': 800, 'max_depth': 192, 'subsample': 0.7, 'colsample_bytree': 0.55, 'gamma': 1e-08, 'eta': 0.1, 'features': 7}
#             Current best combo (with val score 0.405):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 0.7, 'colsample_bytree': 0.55, 'gamma': 1e-08, 'eta': 0.1, 'features': 5}
#         Has trained 1362 of 1512000 combinations so far
# % Combos Checked Thus Far: 1362 out of 1512000 which is 0.090079%
# Max Val Score:
#  0.404974
# Max Val Score Std:
#  0.098556
# Best Combo Train Score:
#  0.893325
# Best Combo Train Score Std:
#  0.002717
# Max Combo Index:
#  (5, 6, 2, 1, 0, 3, 5) out of [6, 7, 5, 5, 5, 6, 48] (note best combo is 0-indexed)
# Max Combo Hyperparamer Combination:
#  {'n_estimators': 800, 'max_depth': 192, 'subsample': 0.7, 'colsample_bytree': 0.55, 'gamma': 1e-08, 'eta': 0.1, 'features': 5}
# Max Combo Features:
#  ('procedure_224274', 'lods_score', 'procedure_224276', 'procedure_224267', 'race_AMERICAN INDIAN/ALASKA NATIVE', 'race_ASIAN', 'race_ASIAN - ASIAN INDIAN', 'race_ASIAN - CHINESE', 'race_ASIAN - KOREAN', 'race_ASIAN - SOUTH EAST ASIAN', 'race_BLACK/AFRICAN', 'race_BLACK/AFRICAN AMERICAN', 'race_BLACK/CAPE VERDEAN', 'race_BLACK/CARIBBEAN ISLAND', 'race_HISPANIC OR LATINO', 'race_HISPANIC/LATINO - CENTRAL AMERICAN', 'race_HISPANIC/LATINO - COLUMBIAN', 'race_HISPANIC/LATINO - CUBAN', 'race_HISPANIC/LATINO - DOMINICAN', 'race_HISPANIC/LATINO - GUATEMALAN', 'race_HISPANIC/LATINO - HONDURAN', 'race_HISPANIC/LATINO - MEXICAN', 'race_HISPANIC/LATINO - PUERTO RICAN', 'race_HISPANIC/LATINO - SALVADORAN', 'race_MULTIPLE RACE/ETHNICITY', 'race_NATIVE HAWAIIAN OR OTHER PACIFIC ISLANDER', 'race_OTHER', 'race_PATIENT DECLINED TO ANSWER', 'race_PORTUGUESE', 'race_SOUTH AMERICAN', 'race_UNABLE TO OBTAIN', 'race_WHITE', 'race_WHITE - BRAZILIAN', 'race_WHITE - EASTERN EUROPEAN', 'race_WHITE - OTHER EUROPEAN', 'race_WHITE - RUSSIAN', 'race_UNKNOWN', 'procedure_227712')
# % Combos Checked: 1362 out of 1512000 which is 0.090079%
