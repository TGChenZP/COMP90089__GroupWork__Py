# %% [markdown]
# # Tuning Script

# %%
# Parameters subject to change in every script - involved in naming

MODEL = 'xgbc'
PREPROCESSING = 'smote_normalise'
TUNER = 'yangzhoub'
OPTIMISED_METRIC = 'f1'

# %% [markdown]
# ---

# %%
# detect whether this is a google environment

COLAB_ENVIRONMENT = False

try:
    from google.colab import drive
    drive.mount('/content/drive')
    COLAB_ENVIRONMENT = True
except:
    pass
# Out:
# Mounted at /content/drive

# %%
import sys
import os
import pickle

if COLAB_ENVIRONMENT:
    home_directory = './drive/MyDrive/LAB/COMP90089__GroupWork__Py/' # my home directory is stored in ./LAB of google drive
    if MODEL == 'ebr':
        # !pip install interpret==0.5.0
    elif MODEL == 'cbr':
        # !pip install catboost
    elif MODEL in ['tf', 'mlp']:
        # !pip install PyTorch2Sklearn
    # !pip install JXAutoML
else:
    home_directory = '../../'

from JXAutoML.YangZhouB_10CV import YangZhouB_10CV as Tuner

import pandas as pd
# Out:
# Collecting JXAutoML
#   Downloading JXAutoML-0.4.4-py3-none-any.whl.metadata (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.2/67.2 kB 2.6 MB/s eta 0:00:00
# Downloading JXAutoML-0.4.4-py3-none-any.whl (52 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.1/52.1 kB 4.1 MB/s eta 0:00:00
# Installing collected packages: JXAutoML
# Successfully installed JXAutoML-0.4.4

# %%
# Parameters that are same for every script

FOLDS = 10  # we have decided to do 10 fold validation

SEED = 42

TASK_TYPE = 'Classification'  # this task is a classification task

# we have decided to tune features as hp
TUNE_FEATURES_AS_HYPERPARAMETERS = True

# %% [markdown]
# ---

# %%
# model to use to tune
from xgboost import XGBClassifier as clf

# what values to try for each hyperparameter
parameter_choices = {
        'n_estimators': (25, 50, 100, 200, 400, 800),
        'max_depth': (3, 6, 12, 24, 48, 96, 192),
        'subsample': (0.4, 0.55, 0.7, 0.85, 1),
        'colsample_bytree': (0.4, 0.55, 0.7, 0.85, 1),
        'gamma': (0.00000001, 0.000001, 0.0001, 0.01, 0.1),
        'eta': (0.0001, 0.001, 0.01, 0.1, 1, 10)
}

# what values to set non-tuneable parameters/hyperparameters
non_tunable_hyperparameters_dict = {
                                    'random_state': SEED,
                                    'n_jobs': -1
                                    }

# %% [markdown]
# ---

# %% [markdown]
# Read in and Prepare Data

# %%
# Import data and store as lists

train_x_list = []
train_y_list = []
val_x_list = []
val_y_list = []

for i in range(FOLDS):
    train_data = pd.read_csv(
        f'{home_directory}data/curated/modelling/{PREPROCESSING}/train_{i}.csv')
    val_data = pd.read_csv(
        f'{home_directory}data/curated/modelling/{PREPROCESSING}/val_{i}.csv')

    # get the correct rows for X and y
    train_x = train_data.drop(
        ['mortality_status', 'subject_id', 'hadm_id', 'stay_id'], axis=1)
    train_y = train_data['mortality_status']
    val_x = val_data.drop(
        ['mortality_status', 'subject_id', 'hadm_id', 'stay_id'], axis=1)
    val_y = val_data['mortality_status']

    train_x_list.append(train_x)
    train_y_list.append(train_y)
    val_x_list.append(val_x)
    val_y_list.append(val_y)

# %%
# Import feature importance ordering

with open(f'{home_directory}models/xgb_feature_importance_ordering_{PREPROCESSING}.pickle', 'rb') as f:
    feature_importance_ordering = pickle.load(f)

# %% [markdown]
# Set parameters

# %%
# initialisation
tuner = Tuner()

print('---')

# define what model we are tuning
tuner.read_in_model(clf, TASK_TYPE, optimised_metric=OPTIMISED_METRIC)

print('---')

# read in the data for training and validation
tuner.read_in_data(train_x_list, train_y_list, val_x_list, val_y_list)

print('---')

# set what hp values to tune
tuner.set_hyperparameters(parameter_choices)
# WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

# set up hp values that need to be changed from default but NOT to be tuned
tuner.set_non_tuneable_hyperparameters(non_tunable_hyperparameters_dict)

print('---')

# set up feature importance ordering

if TUNE_FEATURES_AS_HYPERPARAMETERS:
    tuner.set_features(feature_importance_ordering)
    # WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

try:  # try to read in previous results to continue tuning ...
    tuner.read_in_tuning_result_df(
        f'{home_directory}models/tuning/{TUNER}_{MODEL}_{PREPROCESSING}.csv')
except:
    print('No previous tuning data read in')

print('---')

# set up where to save the tuning result csv
tuner.set_tuning_result_saving_address(
    f'{home_directory}models/tuning/{TUNER}_{MODEL}_{PREPROCESSING}.csv')

print('---')

# set up where to save the current best model
tuner.set_best_model_saving_address(
    f'{home_directory}models/tmp_models/{TUNER}_{MODEL}_{PREPROCESSING}')
# Out:
# YangZhouB Initialised
# ---
# Successfully read in model <class 'xgboost.sklearn.XGBClassifier'>, which is a Classification model optimising for f1
# ---
# Read in Train X data list
# Read in Train y data list
# Read in Val X data list
# Read in Val y data list
# ---
# Successfully recorded hyperparameter choices
# ---
# Successfully recorded non_tuneable_hyperparameter choices
# ---
# Successfully recorded tuneable feature combination choices and updated relevant internal structures
# ---
# Successfully read in tuning result of 481 rows, for 481.0 combos
# ---
# Successfully set tuning output address
# ---
# Successfully set best model output address

# %%
# ignore warnings

import warnings
warnings.filterwarnings("ignore")

# %%
# begin tuning ... (or continue training)

tuner.tune()
# Out:
# Streaming output truncated to the last 5000 lines.
#         Has trained 1247 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.364):
#             {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 1, 'gamma': 1e-08, 'eta': 0.0001, 'features': 59}
#             Current best combo (with val score 0.5632):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 20}
#         Has trained 1247 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.1161):
#             {'n_estimators': 800, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 1, 'gamma': 0.1, 'eta': 10, 'features': 59}
#             Current best combo (with val score 0.5632):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 20}
#         Has trained 1247 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.3528):
#             {'n_estimators': 25, 'max_depth': 24, 'subsample': 1, 'colsample_bytree': 1, 'gamma': 1e-08, 'eta': 0.0001, 'features': 59}
#             Current best combo (with val score 0.5632):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 20}
#         Has trained 1247 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.368):
#             {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 1, 'gamma': 1e-08, 'eta': 0.0001, 'features': 35}
#             Current best combo (with val score 0.5632):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 20}
#         Has trained 1247 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.4026):
#             {'n_estimators': 800, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 1, 'gamma': 1e-08, 'eta': 0.0001, 'features': 25}
#             Current best combo (with val score 0.5632):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 20}
#         Has trained 1247 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 800, 'max_depth': 24, 'subsample': 1, 'colsample_bytree': 1, 'gamma': 0.1, 'eta': 10, 'features': 0}
#             Current best combo (with val score 0.5632):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 20}
#         Has trained 1247 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.1334):
#             {'n_estimators': 800, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'gamma': 0.1, 'eta': 10, 'features': 25}
#             Current best combo (with val score 0.5632):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 20}
#         Has trained 1247 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.3061):
#             {'n_estimators': 800, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 1, 'gamma': 1e-08, 'eta': 0.0001, 'features': 30}
#             Current best combo (with val score 0.5632):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 20}
#         Has trained 1247 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.1114):
#             {'n_estimators': 800, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 1, 'gamma': 0.1, 'eta': 10, 'features': 30}
#             Current best combo (with val score 0.5632):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 20}
#         Has trained 1247 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.1241):
#             {'n_estimators': 800, 'max_depth': 192, 'subsample': 0.4, 'colsample_bytree': 1, 'gamma': 1e-08, 'eta': 10, 'features': 55}
#             Current best combo (with val score 0.5632):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 20}
#         Has trained 1247 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.2801):
#             {'n_estimators': 800, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 20}
#             Current best combo (with val score 0.5632):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 20}
#         Has trained 1247 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.1987):
#             {'n_estimators': 25, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 0.1, 'eta': 10, 'features': 25}
#             Current best combo (with val score 0.5632):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 20}
#         Has trained 1247 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.1838):
#             {'n_estimators': 25, 'max_depth': 192, 'subsample': 0.4, 'colsample_bytree': 1, 'gamma': 0.1, 'eta': 10, 'features': 55}
#             Current best combo (with val score 0.5632):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 20}
#         Has trained 1247 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.3025):
#             {'n_estimators': 800, 'max_depth': 24, 'subsample': 1, 'colsample_bytree': 1, 'gamma': 0.1, 'eta': 0.0001, 'features': 25}
#             Current best combo (with val score 0.5632):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 20}
#         Has trained 1247 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 800, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 10, 'features': 0}
#             Current best combo (with val score 0.5632):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 20}
#         Has trained 1247 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.1114):
#             {'n_estimators': 25, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 1, 'gamma': 1e-08, 'eta': 10, 'features': 30}
#             Current best combo (with val score 0.5632):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 20}
#         Has trained 1247 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.2299):
#             {'n_estimators': 800, 'max_depth': 24, 'subsample': 1, 'colsample_bytree': 1, 'gamma': 0.1, 'eta': 10, 'features': 10}
#             Current best combo (with val score 0.5632):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 20}
#         Has trained 1247 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.0617):
#             {'n_estimators': 25, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.4, 'gamma': 0.1, 'eta': 10, 'features': 63}
#             Current best combo (with val score 0.5632):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 20}
#         Has trained 1247 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.1133):
#             {'n_estimators': 800, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 35}
#             Current best combo (with val score 0.5632):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 20}
#         Has trained 1247 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.1749):
#             {'n_estimators': 25, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 0.1, 'eta': 10, 'features': 40}
#             Current best combo (with val score 0.5632):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 20}
#         Has trained 1247 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 800, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 1, 'gamma': 0.1, 'eta': 10, 'features': 0}
#             Current best combo (with val score 0.5632):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 20}
#         Has trained 1247 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.4005):
#             {'n_estimators': 800, 'max_depth': 24, 'subsample': 1, 'colsample_bytree': 1, 'gamma': 0.1, 'eta': 0.0001, 'features': 10}
#             Current best combo (with val score 0.5632):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 20}
#         Has trained 1247 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.1334):
#             {'n_estimators': 25, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'gamma': 0.1, 'eta': 10, 'features': 25}
#             Current best combo (with val score 0.5632):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 20}
#         Has trained 1247 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.3983):
#             {'n_estimators': 25, 'max_depth': 24, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 5}
#             Current best combo (with val score 0.5632):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 20}
#         Has trained 1247 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.4697):
#             {'n_estimators': 800, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.4, 'gamma': 0.1, 'eta': 0.0001, 'features': 15}
#             Current best combo (with val score 0.5632):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 20}
#         Has trained 1247 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.3244):
#             {'n_estimators': 25, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 1, 'gamma': 0.1, 'eta': 0.0001, 'features': 0}
#             Current best combo (with val score 0.5632):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 20}
#         Has trained 1247 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.1488):
#             {'n_estimators': 800, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 1, 'gamma': 0.1, 'eta': 0.0001, 'features': 45}
#             Current best combo (with val score 0.5632):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 20}
#         Has trained 1247 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.1542):
#             {'n_estimators': 800, 'max_depth': 192, 'subsample': 0.4, 'colsample_bytree': 0.4, 'gamma': 0.1, 'eta': 10, 'features': 59}
#             Current best combo (with val score 0.5632):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 20}
#         Has trained 1247 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.0956):
#             {'n_estimators': 25, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 1, 'gamma': 1e-08, 'eta': 10, 'features': 55}
#             Current best combo (with val score 0.5632):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 20}
#         Has trained 1247 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.3869):
#             {'n_estimators': 25, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 0.1, 'eta': 0.0001, 'features': 35}
#             Current best combo (with val score 0.5632):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 20}
#         Has trained 1247 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.5462):
#             {'n_estimators': 25, 'max_depth': 24, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 25}
#             Current best combo (with val score 0.5632):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 20}
#         Has trained 1247 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.1188):
#             {'n_estimators': 25, 'max_depth': 24, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 10, 'features': 71}
#             Current best combo (with val score 0.5632):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 20}
#         Has trained 1247 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.1898):
#             {'n_estimators': 25, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 1, 'gamma': 1e-08, 'eta': 10, 'features': 20}
#             Current best combo (with val score 0.5632):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 20}
#         Has trained 1247 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.1704):
#             {'n_estimators': 25, 'max_depth': 192, 'subsample': 0.4, 'colsample_bytree': 0.4, 'gamma': 0.1, 'eta': 0.0001, 'features': 63}
#             Current best combo (with val score 0.5632):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 20}
#         Has trained 1247 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.3416):
#             {'n_estimators': 800, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 1, 'gamma': 0.1, 'eta': 0.0001, 'features': 30}
#             Current best combo (with val score 0.5632):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 20}
#         Has trained 1247 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.1551):
#             {'n_estimators': 25, 'max_depth': 192, 'subsample': 0.4, 'colsample_bytree': 0.4, 'gamma': 0.1, 'eta': 10, 'features': 45}
#             Current best combo (with val score 0.5632):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 20}
#         Has trained 1247 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.1131):
#             {'n_estimators': 25, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'gamma': 0.1, 'eta': 0.0001, 'features': 35}
#             Current best combo (with val score 0.5632):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 20}
#         Has trained 1247 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.3184):
#             {'n_estimators': 25, 'max_depth': 192, 'subsample': 0.4, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 10, 'features': 10}
#             Current best combo (with val score 0.5632):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 20}
#         Has trained 1247 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.1586):
#             {'n_estimators': 800, 'max_depth': 24, 'subsample': 1, 'colsample_bytree': 1, 'gamma': 1e-08, 'eta': 10, 'features': 5}
#             Current best combo (with val score 0.5632):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 20}
#         Has trained 1247 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.3066):
#             {'n_estimators': 25, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 1, 'gamma': 0.1, 'eta': 10, 'features': 15}
#             Current best combo (with val score 0.5632):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 20}
#         Has trained 1247 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.1161):
#             {'n_estimators': 25, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 1, 'gamma': 0.1, 'eta': 10, 'features': 63}
#             Current best combo (with val score 0.5632):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 20}
#         Has trained 1247 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.0611):
#             {'n_estimators': 800, 'max_depth': 192, 'subsample': 0.4, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 67}
#             Current best combo (with val score 0.5632):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 20}
#         Has trained 1247 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.2195):
#             {'n_estimators': 800, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 1, 'gamma': 1e-08, 'eta': 0.0001, 'features': 50}
#             Current best combo (with val score 0.5632):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 20}
#         Has trained 1247 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.1994):
#             {'n_estimators': 800, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 1, 'gamma': 1e-08, 'eta': 0.0001, 'features': 10}
#             Current best combo (with val score 0.5632):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 20}
#         Has trained 1247 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.2494):
#             {'n_estimators': 25, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 10, 'features': 5}
#             Current best combo (with val score 0.5632):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 20}
#         Has trained 1247 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.4144):
#             {'n_estimators': 800, 'max_depth': 24, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 0.1, 'eta': 0.0001, 'features': 5}
#             Current best combo (with val score 0.5632):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 20}
#         Has trained 1247 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.2022):
#             {'n_estimators': 800, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 10, 'features': 50}
#             Current best combo (with val score 0.5632):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 20}
#         Has trained 1247 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 25, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 10, 'features': 0}
#             Current best combo (with val score 0.5632):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 20}
#         Has trained 1247 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.1173):
#             {'n_estimators': 800, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 1, 'gamma': 1e-08, 'eta': 10, 'features': 35}
#             Current best combo (with val score 0.5632):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 20}
#         Has trained 1247 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.3324):
#             {'n_estimators': 25, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 1, 'gamma': 0.1, 'eta': 0.0001, 'features': 40}
#             Current best combo (with val score 0.5632):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 20}
#         Has trained 1247 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.361):
#             {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 1, 'gamma': 1e-08, 'eta': 0.0001, 'features': 40}
#             Current best combo (with val score 0.5632):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 20}
#         Has trained 1247 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.0887):
#             {'n_estimators': 800, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 1, 'gamma': 0.1, 'eta': 10, 'features': 25}
#             Current best combo (with val score 0.5632):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 20}
#         Has trained 1247 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.2443):
#             {'n_estimators': 25, 'max_depth': 192, 'subsample': 0.4, 'colsample_bytree': 1, 'gamma': 0.1, 'eta': 0.0001, 'features': 50}
#             Current best combo (with val score 0.5632):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 20}
#         Has trained 1247 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.4612):
#             {'n_estimators': 800, 'max_depth': 192, 'subsample': 0.4, 'colsample_bytree': 1, 'gamma': 1e-08, 'eta': 0.0001, 'features': 15}
#             Current best combo (with val score 0.5632):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 20}
#         Has trained 1247 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.344):
#             {'n_estimators': 25, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 1, 'gamma': 1e-08, 'eta': 0.0001, 'features': 20}
#             Current best combo (with val score 0.5632):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 20}
#         Has trained 1247 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.0801):
#             {'n_estimators': 800, 'max_depth': 192, 'subsample': 0.4, 'colsample_bytree': 0.4, 'gamma': 0.1, 'eta': 10, 'features': 20}
#             Current best combo (with val score 0.5632):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 20}
#         Has trained 1247 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.1512):
#             {'n_estimators': 800, 'max_depth': 192, 'subsample': 0.4, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 10, 'features': 35}
#             Current best combo (with val score 0.5632):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 20}
#         Has trained 1247 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.1801):
#             {'n_estimators': 25, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 55}
#             Current best combo (with val score 0.5632):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 20}
#         Has trained 1247 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.3869):
#             {'n_estimators': 25, 'max_depth': 24, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 0.1, 'eta': 0.0001, 'features': 35}
#             Current best combo (with val score 0.5632):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 20}
#         Has trained 1247 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.1088):
#             {'n_estimators': 25, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 0.1, 'eta': 0.0001, 'features': 45}
#             Current best combo (with val score 0.5632):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 20}
#         Has trained 1247 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.139):
#             {'n_estimators': 800, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 0.1, 'eta': 10, 'features': 20}
#             Current best combo (with val score 0.5632):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 20}
#         Has trained 1247 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.4083):
#             {'n_estimators': 800, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 15}
#             Current best combo (with val score 0.5632):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 20}
#         Has trained 1247 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.2151):
#             {'n_estimators': 800, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 1, 'gamma': 0.1, 'eta': 0.0001, 'features': 63}
#             Current best combo (with val score 0.5632):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 20}
#         Has trained 1247 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.3847):
#             {'n_estimators': 25, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 67}
#             Current best combo (with val score 0.5632):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 20}
#         Has trained 1247 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.15):
#             {'n_estimators': 25, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 1, 'gamma': 1e-08, 'eta': 10, 'features': 71}
#             Current best combo (with val score 0.5632):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 20}
#         Has trained 1247 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.1438):
#             {'n_estimators': 800, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 55}
#             Current best combo (with val score 0.5632):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 20}
#         Has trained 1247 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.1831):
#             {'n_estimators': 25, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 30}
#             Current best combo (with val score 0.5632):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 20}
#         Has trained 1247 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.099):
#             {'n_estimators': 25, 'max_depth': 192, 'subsample': 0.4, 'colsample_bytree': 1, 'gamma': 0.1, 'eta': 10, 'features': 45}
#             Current best combo (with val score 0.5632):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 20}
#         Has trained 1247 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.3244):
#             {'n_estimators': 25, 'max_depth': 192, 'subsample': 0.4, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 0}
#             Current best combo (with val score 0.5632):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 20}
#         Has trained 1247 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.4023):
#             {'n_estimators': 25, 'max_depth': 192, 'subsample': 0.4, 'colsample_bytree': 1, 'gamma': 0.1, 'eta': 0.0001, 'features': 20}
#             Current best combo (with val score 0.5632):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 20}
#         Has trained 1247 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.1704):
#             {'n_estimators': 25, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.4, 'gamma': 0.1, 'eta': 0.0001, 'features': 63}
#             Current best combo (with val score 0.5632):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 20}
#         Has trained 1247 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.3244):
#             {'n_estimators': 800, 'max_depth': 192, 'subsample': 0.4, 'colsample_bytree': 1, 'gamma': 0.1, 'eta': 0.0001, 'features': 0}
#             Current best combo (with val score 0.5632):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 20}
#         Has trained 1247 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.2239):
#             {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 0.1, 'eta': 0.0001, 'features': 55}
#             Current best combo (with val score 0.5632):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 20}
#         Has trained 1247 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.2612):
#             {'n_estimators': 800, 'max_depth': 192, 'subsample': 0.4, 'colsample_bytree': 1, 'gamma': 0.1, 'eta': 10, 'features': 71}
#             Current best combo (with val score 0.5632):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 20}
#         Has trained 1247 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.1422):
#             {'n_estimators': 25, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 1, 'gamma': 1e-08, 'eta': 10, 'features': 10}
#             Current best combo (with val score 0.5632):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 20}
#         Has trained 1247 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.0218):
#             {'n_estimators': 25, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 59}
#             Current best combo (with val score 0.5632):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 20}
#         Has trained 1247 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.361):
#             {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 1, 'gamma': 0.1, 'eta': 0.0001, 'features': 40}
#             Current best combo (with val score 0.5632):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 20}
#         Has trained 1247 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.1436):
#             {'n_estimators': 800, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 1, 'gamma': 0.1, 'eta': 0.0001, 'features': 71}
#             Current best combo (with val score 0.5632):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 20}
#         Has trained 1247 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.1161):
#             {'n_estimators': 800, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 1, 'gamma': 1e-08, 'eta': 10, 'features': 67}
#             Current best combo (with val score 0.5632):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 20}
#         Has trained 1247 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.3589):
#             {'n_estimators': 25, 'max_depth': 24, 'subsample': 1, 'colsample_bytree': 1, 'gamma': 1e-08, 'eta': 0.0001, 'features': 45}
#             Current best combo (with val score 0.5632):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 20}
#         Has trained 1247 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.1781):
#             {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 1, 'gamma': 1e-08, 'eta': 10, 'features': 67}
#             Current best combo (with val score 0.5632):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 20}
#         Has trained 1247 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.2173):
#             {'n_estimators': 800, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 1, 'gamma': 0.1, 'eta': 0.0001, 'features': 59}
#             Current best combo (with val score 0.5632):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 20}
#         Has trained 1247 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.3295):
#             {'n_estimators': 25, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 1, 'gamma': 1e-08, 'eta': 0.0001, 'features': 35}
#             Current best combo (with val score 0.5632):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 20}
#         Has trained 1247 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.1046):
#             {'n_estimators': 25, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 1, 'gamma': 1e-08, 'eta': 10, 'features': 5}
#             Current best combo (with val score 0.5632):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 20}
#         Has trained 1247 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.0771):
#             {'n_estimators': 25, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'gamma': 0.1, 'eta': 10, 'features': 59}
#             Current best combo (with val score 0.5632):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 20}
#         Has trained 1247 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.1206):
#             {'n_estimators': 25, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 1, 'gamma': 0.1, 'eta': 10, 'features': 30}
#             Current best combo (with val score 0.5632):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 20}
#         Has trained 1247 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.3656):
#             {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 1, 'gamma': 0.1, 'eta': 0.0001, 'features': 71}
#             Current best combo (with val score 0.5632):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 20}
#         Has trained 1247 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.1234):
#             {'n_estimators': 25, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 10, 'features': 63}
#             Current best combo (with val score 0.5632):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 20}
#         Has trained 1247 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.4661):
#             {'n_estimators': 800, 'max_depth': 192, 'subsample': 0.4, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 20}
#             Current best combo (with val score 0.5632):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 20}
#         Has trained 1247 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.3816):
#             {'n_estimators': 800, 'max_depth': 24, 'subsample': 1, 'colsample_bytree': 1, 'gamma': 1e-08, 'eta': 0.0001, 'features': 50}
#             Current best combo (with val score 0.5632):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 20}
#         Has trained 1247 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.16):
#             {'n_estimators': 25, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 1, 'gamma': 1e-08, 'eta': 0.0001, 'features': 67}
#             Current best combo (with val score 0.5632):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 20}
#         Has trained 1247 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.4657):
#             {'n_estimators': 25, 'max_depth': 24, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 0.1, 'eta': 0.0001, 'features': 15}
#             Current best combo (with val score 0.5632):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 20}
#         Has trained 1247 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.3011):
#             {'n_estimators': 25, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 40}
#             Current best combo (with val score 0.5632):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 20}
#         Has trained 1247 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.4364):
#             {'n_estimators': 25, 'max_depth': 24, 'subsample': 1, 'colsample_bytree': 1, 'gamma': 1e-08, 'eta': 0.0001, 'features': 15}
#             Current best combo (with val score 0.5632):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 20}
#         Has trained 1247 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.3528):
#             {'n_estimators': 25, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 1, 'gamma': 1e-08, 'eta': 0.0001, 'features': 63}
#             Current best combo (with val score 0.5632):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 20}
#         Has trained 1247 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.3184):
#             {'n_estimators': 800, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 10, 'features': 10}
#             Current best combo (with val score 0.5632):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 20}
#         Has trained 1247 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.2285):
#             {'n_estimators': 25, 'max_depth': 24, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 10, 'features': 30}
#             Current best combo (with val score 0.5632):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 20}
#         Has trained 1247 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.1542):
#             {'n_estimators': 800, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.4, 'gamma': 0.1, 'eta': 10, 'features': 59}
#             Current best combo (with val score 0.5632):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 20}
#         Has trained 1247 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.1658):
#             {'n_estimators': 25, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 1, 'gamma': 0.1, 'eta': 10, 'features': 20}
#             Current best combo (with val score 0.5632):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 20}
#         Has trained 1247 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.2005):
#             {'n_estimators': 25, 'max_depth': 192, 'subsample': 0.4, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 30}
#             Current best combo (with val score 0.5632):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 20}
#         Has trained 1247 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.1532):
#             {'n_estimators': 25, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 1, 'gamma': 1e-08, 'eta': 10, 'features': 35}
#             Current best combo (with val score 0.5632):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 20}
#         Has trained 1247 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.1628):
#             {'n_estimators': 25, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 1, 'gamma': 0.1, 'eta': 0.0001, 'features': 55}
#             Current best combo (with val score 0.5632):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 20}
#         Has trained 1247 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.4082):
#             {'n_estimators': 800, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 0.1, 'eta': 0.0001, 'features': 15}
#             Current best combo (with val score 0.5632):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 20}
#         Has trained 1247 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.393):
#             {'n_estimators': 25, 'max_depth': 24, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 0.1, 'eta': 0.0001, 'features': 30}
#             Current best combo (with val score 0.5632):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 20}
#         Has trained 1247 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.2297):
#             {'n_estimators': 25, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 10, 'features': 15}
# ...
#             Current best combo with val score 0.5632:
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 20}
# Already Trained and Tested combination (val score of 0.0716):
#             {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.7, 'gamma': 0.0001, 'eta': 0.1, 'features': 36}
#             Current best combo (with val score 0.5632):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 20}
#         Has trained 1566 of 2268000 combinations so far
# Trained and Tested combination 1567 of 2268000, taking 0.95 seconds to get val score of 0.0477:
#                 {'n_estimators': 200, 'max_depth': 12, 'subsample': 0.55, 'colsample_bytree': 0.7, 'gamma': 0.0001, 'eta': 0.1, 'features': 36},
#             Current best combo with val score 0.5632:
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 20}
# Trained and Tested combination 1568 of 2268000, taking 1.02 seconds to get val score of 0.1278:
#                 {'n_estimators': 200, 'max_depth': 12, 'subsample': 0.85, 'colsample_bytree': 0.7, 'gamma': 0.0001, 'eta': 0.1, 'features': 36},
#             Current best combo with val score 0.5632:
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 20}
# Trained and Tested combination 1569 of 2268000, taking 0.92 seconds to get val score of 0.082:
#                 {'n_estimators': 200, 'max_depth': 12, 'subsample': 0.7, 'colsample_bytree': 0.55, 'gamma': 0.0001, 'eta': 0.1, 'features': 36},
#             Current best combo with val score 0.5632:
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 20}
# Trained and Tested combination 1570 of 2268000, taking 1.28 seconds to get val score of 0.0774:
#                 {'n_estimators': 200, 'max_depth': 12, 'subsample': 0.7, 'colsample_bytree': 0.85, 'gamma': 0.0001, 'eta': 0.1, 'features': 36},
#             Current best combo with val score 0.5632:
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 20}
# Trained and Tested combination 1571 of 2268000, taking 2.02 seconds to get val score of 0.0882:
#                 {'n_estimators': 200, 'max_depth': 12, 'subsample': 0.7, 'colsample_bytree': 0.7, 'gamma': 1e-06, 'eta': 0.1, 'features': 36},
#             Current best combo with val score 0.5632:
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 20}
# Trained and Tested combination 1572 of 2268000, taking 4.12 seconds to get val score of 0.0689:
#                 {'n_estimators': 200, 'max_depth': 12, 'subsample': 0.7, 'colsample_bytree': 0.7, 'gamma': 0.01, 'eta': 0.1, 'features': 36},
#             Current best combo with val score 0.5632:
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 20}
# Trained and Tested combination 1573 of 2268000, taking 1.77 seconds to get val score of 0.2051:
#                 {'n_estimators': 200, 'max_depth': 12, 'subsample': 0.7, 'colsample_bytree': 0.7, 'gamma': 0.0001, 'eta': 0.01, 'features': 36},
#             Current best combo with val score 0.5632:
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 20}
# Trained and Tested combination 1574 of 2268000, taking 0.52 seconds to get val score of 0.0895:
#                 {'n_estimators': 200, 'max_depth': 12, 'subsample': 0.7, 'colsample_bytree': 0.7, 'gamma': 0.0001, 'eta': 1, 'features': 36},
#             Current best combo with val score 0.5632:
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 20}
# Trained and Tested combination 1575 of 2268000, taking 0.98 seconds to get val score of 0.1337:
#                 {'n_estimators': 200, 'max_depth': 12, 'subsample': 0.7, 'colsample_bytree': 0.7, 'gamma': 0.0001, 'eta': 0.1, 'features': 35},
#             Current best combo with val score 0.5632:
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 20}
# Trained and Tested combination 1576 of 2268000, taking 0.99 seconds to get val score of 0.0843:
#                 {'n_estimators': 200, 'max_depth': 12, 'subsample': 0.7, 'colsample_bytree': 0.7, 'gamma': 0.0001, 'eta': 0.1, 'features': 37},
#             Current best combo with val score 0.5632:
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 20}
# Already Trained and Tested combination (val score of 0.0744):
#             {'n_estimators': 100, 'max_depth': 48, 'subsample': 0.7, 'colsample_bytree': 0.7, 'gamma': 0.0001, 'eta': 0.1, 'features': 36}
#             Current best combo (with val score 0.5632):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 20}
#         Has trained 1576 of 2268000 combinations so far
# Trained and Tested combination 1577 of 2268000, taking 3.3 seconds to get val score of 0.0572:
#                 {'n_estimators': 400, 'max_depth': 48, 'subsample': 0.7, 'colsample_bytree': 0.7, 'gamma': 0.0001, 'eta': 0.1, 'features': 36},
#             Current best combo with val score 0.5632:
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 20}
# Already Trained and Tested combination (val score of 0.0716):
#             {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.7, 'gamma': 0.0001, 'eta': 0.1, 'features': 36}
#             Current best combo (with val score 0.5632):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 20}
#         Has trained 1577 of 2268000 combinations so far
# Trained and Tested combination 1578 of 2268000, taking 1.0 seconds to get val score of 0.0716:
#                 {'n_estimators': 200, 'max_depth': 96, 'subsample': 0.7, 'colsample_bytree': 0.7, 'gamma': 0.0001, 'eta': 0.1, 'features': 36},
#             Current best combo with val score 0.5632:
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 20}
# Trained and Tested combination 1579 of 2268000, taking 0.95 seconds to get val score of 0.0624:
#                 {'n_estimators': 200, 'max_depth': 48, 'subsample': 0.55, 'colsample_bytree': 0.7, 'gamma': 0.0001, 'eta': 0.1, 'features': 36},
#             Current best combo with val score 0.5632:
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 20}
# Trained and Tested combination 1580 of 2268000, taking 1.06 seconds to get val score of 0.1371:
#                 {'n_estimators': 200, 'max_depth': 48, 'subsample': 0.85, 'colsample_bytree': 0.7, 'gamma': 0.0001, 'eta': 0.1, 'features': 36},
#             Current best combo with val score 0.5632:
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 20}
# Trained and Tested combination 1581 of 2268000, taking 0.96 seconds to get val score of 0.0797:
#                 {'n_estimators': 200, 'max_depth': 48, 'subsample': 0.7, 'colsample_bytree': 0.55, 'gamma': 0.0001, 'eta': 0.1, 'features': 36},
#             Current best combo with val score 0.5632:
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 20}
# Trained and Tested combination 1582 of 2268000, taking 1.05 seconds to get val score of 0.0727:
#                 {'n_estimators': 200, 'max_depth': 48, 'subsample': 0.7, 'colsample_bytree': 0.85, 'gamma': 0.0001, 'eta': 0.1, 'features': 36},
#             Current best combo with val score 0.5632:
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 20}
# Trained and Tested combination 1583 of 2268000, taking 1.02 seconds to get val score of 0.0841:
#                 {'n_estimators': 200, 'max_depth': 48, 'subsample': 0.7, 'colsample_bytree': 0.7, 'gamma': 1e-06, 'eta': 0.1, 'features': 36},
#             Current best combo with val score 0.5632:
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 20}
# Trained and Tested combination 1584 of 2268000, taking 1.01 seconds to get val score of 0.0765:
#                 {'n_estimators': 200, 'max_depth': 48, 'subsample': 0.7, 'colsample_bytree': 0.7, 'gamma': 0.01, 'eta': 0.1, 'features': 36},
#             Current best combo with val score 0.5632:
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 20}
# Trained and Tested combination 1585 of 2268000, taking 1.94 seconds to get val score of 0.1997:
#                 {'n_estimators': 200, 'max_depth': 48, 'subsample': 0.7, 'colsample_bytree': 0.7, 'gamma': 0.0001, 'eta': 0.01, 'features': 36},
#             Current best combo with val score 0.5632:
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 20}
# Trained and Tested combination 1586 of 2268000, taking 0.53 seconds to get val score of 0.054:
#                 {'n_estimators': 200, 'max_depth': 48, 'subsample': 0.7, 'colsample_bytree': 0.7, 'gamma': 0.0001, 'eta': 1, 'features': 36},
#             Current best combo with val score 0.5632:
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 20}
# Trained and Tested combination 1587 of 2268000, taking 0.99 seconds to get val score of 0.153:
#                 {'n_estimators': 200, 'max_depth': 48, 'subsample': 0.7, 'colsample_bytree': 0.7, 'gamma': 0.0001, 'eta': 0.1, 'features': 35},
#             Current best combo with val score 0.5632:
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 20}
# Trained and Tested combination 1588 of 2268000, taking 1.04 seconds to get val score of 0.0758:
#                 {'n_estimators': 200, 'max_depth': 48, 'subsample': 0.7, 'colsample_bytree': 0.7, 'gamma': 0.0001, 'eta': 0.1, 'features': 37},
#             Current best combo with val score 0.5632:
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 20}
# Already Trained and Tested combination (val score of 0.1721):
#             {'n_estimators': 100, 'max_depth': 24, 'subsample': 0.85, 'colsample_bytree': 0.7, 'gamma': 0.0001, 'eta': 0.1, 'features': 36}
#             Current best combo (with val score 0.5632):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 20}
#         Has trained 1588 of 2268000 combinations so far
# Trained and Tested combination 1589 of 2268000, taking 4.5 seconds to get val score of 0.1094:
#                 {'n_estimators': 400, 'max_depth': 24, 'subsample': 0.85, 'colsample_bytree': 0.7, 'gamma': 0.0001, 'eta': 0.1, 'features': 36},
#             Current best combo with val score 0.5632:
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 20}
# Already Trained and Tested combination (val score of 0.1278):
#             {'n_estimators': 200, 'max_depth': 12, 'subsample': 0.85, 'colsample_bytree': 0.7, 'gamma': 0.0001, 'eta': 0.1, 'features': 36}
#             Current best combo (with val score 0.5632):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 20}
#         Has trained 1589 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.1371):
#             {'n_estimators': 200, 'max_depth': 48, 'subsample': 0.85, 'colsample_bytree': 0.7, 'gamma': 0.0001, 'eta': 0.1, 'features': 36}
#             Current best combo (with val score 0.5632):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 20}
#         Has trained 1589 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.0716):
#             {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.7, 'gamma': 0.0001, 'eta': 0.1, 'features': 36}
#             Current best combo (with val score 0.5632):
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 20}
#         Has trained 1589 of 2268000 combinations so far
# Trained and Tested combination 1590 of 2268000, taking 1.09 seconds to get val score of 0.1302:
#                 {'n_estimators': 200, 'max_depth': 24, 'subsample': 1, 'colsample_bytree': 0.7, 'gamma': 0.0001, 'eta': 0.1, 'features': 36},
#             Current best combo with val score 0.5632:
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 20}
# Trained and Tested combination 1591 of 2268000, taking 1.01 seconds to get val score of 0.1118:
#                 {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.85, 'colsample_bytree': 0.55, 'gamma': 0.0001, 'eta': 0.1, 'features': 36},
#             Current best combo with val score 0.5632:
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 20}
# Trained and Tested combination 1592 of 2268000, taking 1.1 seconds to get val score of 0.0994:
#                 {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.85, 'colsample_bytree': 0.85, 'gamma': 0.0001, 'eta': 0.1, 'features': 36},
#             Current best combo with val score 0.5632:
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 20}
# Trained and Tested combination 1593 of 2268000, taking 1.05 seconds to get val score of 0.15:
#                 {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.85, 'colsample_bytree': 0.7, 'gamma': 1e-06, 'eta': 0.1, 'features': 36},
#             Current best combo with val score 0.5632:
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 20}
# Trained and Tested combination 1594 of 2268000, taking 1.12 seconds to get val score of 0.1169:
#                 {'n_estimators': 200, 'max_depth': 24, 'subsample': 0.85, 'colsample_bytree': 0.7, 'gamma': 0.01, 'eta': 0.1, 'features': 36},
#             Current best combo with val score 0.5632:
#                     {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.4, 'gamma': 1e-08, 'eta': 0.0001, 'features': 20}
