# %% [markdown]
# # Tuning Script

# %%
# Parameters subject to change in every script - involved in naming

MODEL = 'svc(poly)'
PREPROCESSING = 'normalise'
TUNER = 'yangzhoub'
OPTIMISED_METRIC = 'f1'

# %% [markdown]
# ---

# %%
# detect whether this is a google environment

COLAB_ENVIRONMENT = False

try:
    from google.colab import drive
    drive.mount('/content/drive')
    COLAB_ENVIRONMENT = True
except:
    pass
# Out:
# Mounted at /content/drive

# %%
import sys
import os
import pickle

if COLAB_ENVIRONMENT:
    home_directory = './drive/MyDrive/LAB/COMP90089__GroupWork__Py/' # my home directory is stored in ./LAB of google drive
    if MODEL == 'ebr':
        # !pip install interpret==0.5.0
    elif MODEL == 'cbr':
        # !pip install catboost
    elif MODEL in ['tf', 'mlp']:
        # !pip install PyTorch2Sklearn
    # !pip install JXAutoML
else:
    home_directory = '../../'

from JXAutoML.YangZhouB_10CV import YangZhouB_10CV as Tuner

import pandas as pd
# Out:
# Collecting JXAutoML
#   Downloading JXAutoML-0.4.4-py3-none-any.whl.metadata (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.2/67.2 kB 3.8 MB/s eta 0:00:00
# Downloading JXAutoML-0.4.4-py3-none-any.whl (52 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.1/52.1 kB 3.4 MB/s eta 0:00:00
# Installing collected packages: JXAutoML
# Successfully installed JXAutoML-0.4.4

# %%
# Parameters that are same for every script

FOLDS = 10  # we have decided to do 10 fold validation

SEED = 42

TASK_TYPE = 'Classification'  # this task is a classification task

# we have decided to tune features as hp
TUNE_FEATURES_AS_HYPERPARAMETERS = True

# %% [markdown]
# ---

# %%
# model to use to tune
from sklearn.svm import SVC as clf

# what values to try for each hyperparameter
parameter_choices = {
    'C': (0.0001, 0.001, 0.01, 0.1, 1, 10),
    'degree': list(range(1, 10)),
    'tol': (0.0001, 0.001, 0.01, 0.1, 1, 10),
    'max_iter': (50, 100, 200, 400, 800, 1600),
    'gamma': ('scale', 'auto')
}

# what values to set non-tuneable parameters/hyperparameters
non_tunable_hyperparameters_dict = {
                                    'verbose': False,
                                    'decision_function_shape': 'ovr',
                                    'random_state': 42,
                                    'kernel': 'poly'
                                    }

# %% [markdown]
# ---

# %% [markdown]
# Read in and Prepare Data

# %%
# Import data and store as lists

train_x_list = []
train_y_list = []
val_x_list = []
val_y_list = []

for i in range(FOLDS):
    train_data = pd.read_csv(
        f'{home_directory}data/curated/modelling/{PREPROCESSING}/train_{i}.csv')
    val_data = pd.read_csv(
        f'{home_directory}data/curated/modelling/{PREPROCESSING}/val_{i}.csv')

    # get the correct rows for X and y
    train_x = train_data.drop(
        ['mortality_status', 'subject_id', 'hadm_id', 'stay_id'], axis=1)
    train_y = train_data['mortality_status']
    val_x = val_data.drop(
        ['mortality_status', 'subject_id', 'hadm_id', 'stay_id'], axis=1)
    val_y = val_data['mortality_status']

    train_x_list.append(train_x)
    train_y_list.append(train_y)
    val_x_list.append(val_x)
    val_y_list.append(val_y)

# %%
# Import feature importance ordering

with open(f'{home_directory}models/xgb_feature_importance_ordering_{PREPROCESSING}.pickle', 'rb') as f:
    feature_importance_ordering = pickle.load(f)

# %% [markdown]
# Set parameters

# %%
# initialisation
tuner = Tuner()

print('---')

# define what model we are tuning
tuner.read_in_model(clf, TASK_TYPE, optimised_metric=OPTIMISED_METRIC)

print('---')

# read in the data for training and validation
tuner.read_in_data(train_x_list, train_y_list, val_x_list, val_y_list)

print('---')

# set what hp values to tune
tuner.set_hyperparameters(parameter_choices)
# WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

# set up hp values that need to be changed from default but NOT to be tuned
tuner.set_non_tuneable_hyperparameters(non_tunable_hyperparameters_dict)

print('---')

# set up feature importance ordering

if TUNE_FEATURES_AS_HYPERPARAMETERS:
    tuner.set_features(feature_importance_ordering)
    # WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

try:  # try to read in previous results to continue tuning ...
    tuner.read_in_tuning_result_df(
        f'{home_directory}models/tuning/{TUNER}_{MODEL}_{PREPROCESSING}.csv')
except:
    print('No previous tuning data read in')

print('---')

# set up where to save the tuning result csv
tuner.set_tuning_result_saving_address(
    f'{home_directory}models/tuning/{TUNER}_{MODEL}_{PREPROCESSING}.csv')

print('---')

# set up where to save the current best model
tuner.set_best_model_saving_address(
    f'{home_directory}models/tmp_models/{TUNER}_{MODEL}_{PREPROCESSING}')
# Out:
# YangZhouB Initialised
# ---
# Successfully read in model <class 'sklearn.svm._classes.SVC'>, which is a Classification model optimising for f1
# ---
# Read in Train X data list
# Read in Train y data list
# Read in Val X data list
# Read in Val y data list
# ---
# Successfully recorded hyperparameter choices
# ---
# Successfully recorded non_tuneable_hyperparameter choices
# ---
# Successfully recorded tuneable feature combination choices and updated relevant internal structures
# ---
# No previous tuning data read in
# ---
# Successfully set tuning output address
# ---
# Successfully set best model output address

# %%
# ignore warnings

import warnings
warnings.filterwarnings("ignore")

# %%
# begin tuning ... (or continue training)

tuner.tune()
# Out:
# Streaming output truncated to the last 5000 lines.
#             Current best combo with val score 0.4337:
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
# Trained and Tested combination 4261 of 198288, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 10, 'degree': 1, 'tol': 10, 'max_iter': 100, 'gamma': 'auto', 'features': 20},
#             Current best combo with val score 0.4337:
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
# Already Trained and Tested combination (val score of 0.3117):
#             {'C': 10, 'degree': 1, 'tol': 10, 'max_iter': 50, 'gamma': 'scale', 'features': 20}
#             Current best combo (with val score 0.4337):
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
#         Has trained 4261 of 198288 combinations so far
# Trained and Tested combination 4262 of 198288, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 10, 'degree': 1, 'tol': 10, 'max_iter': 50, 'gamma': 'auto', 'features': 19},
#             Current best combo with val score 0.4337:
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
# Trained and Tested combination 4263 of 198288, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 10, 'degree': 1, 'tol': 10, 'max_iter': 50, 'gamma': 'auto', 'features': 21},
#             Current best combo with val score 0.4337:
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
# 	round 206 iteration:  1
#
# Trained and Tested combination 4264 of 198288, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 0.1, 'degree': 1, 'tol': 10, 'max_iter': 50, 'gamma': 'auto', 'features': 20},
#             Current best combo with val score 0.4337:
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
# Already Trained and Tested combination (val score of 0.3117):
#             {'C': 10, 'degree': 1, 'tol': 10, 'max_iter': 50, 'gamma': 'auto', 'features': 20}
#             Current best combo (with val score 0.4337):
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
#         Has trained 4264 of 198288 combinations so far
# Trained and Tested combination 4265 of 198288, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 1, 'degree': 2, 'tol': 10, 'max_iter': 50, 'gamma': 'auto', 'features': 20},
#             Current best combo with val score 0.4337:
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
# Trained and Tested combination 4266 of 198288, taking 0.02 seconds to get val score of 0.3117:
#                 {'C': 1, 'degree': 1, 'tol': 1, 'max_iter': 50, 'gamma': 'auto', 'features': 20},
#             Current best combo with val score 0.4337:
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
# Trained and Tested combination 4267 of 198288, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 1, 'degree': 1, 'tol': 10, 'max_iter': 100, 'gamma': 'auto', 'features': 20},
#             Current best combo with val score 0.4337:
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
# Trained and Tested combination 4268 of 198288, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 1, 'degree': 1, 'tol': 10, 'max_iter': 50, 'gamma': 'scale', 'features': 20},
#             Current best combo with val score 0.4337:
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
# Trained and Tested combination 4269 of 198288, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 1, 'degree': 1, 'tol': 10, 'max_iter': 50, 'gamma': 'auto', 'features': 19},
#             Current best combo with val score 0.4337:
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
# Trained and Tested combination 4270 of 198288, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 1, 'degree': 1, 'tol': 10, 'max_iter': 50, 'gamma': 'auto', 'features': 21},
#             Current best combo with val score 0.4337:
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
# Already Trained and Tested combination (val score of 0.3117):
#             {'C': 1, 'degree': 2, 'tol': 10, 'max_iter': 50, 'gamma': 'auto', 'features': 20}
#             Current best combo (with val score 0.4337):
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
#         Has trained 4270 of 198288 combinations so far
# Already Trained and Tested combination (val score of 0.3117):
#             {'C': 10, 'degree': 1, 'tol': 10, 'max_iter': 50, 'gamma': 'auto', 'features': 20}
#             Current best combo (with val score 0.4337):
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
#         Has trained 4270 of 198288 combinations so far
# Trained and Tested combination 4271 of 198288, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 10, 'degree': 3, 'tol': 10, 'max_iter': 50, 'gamma': 'auto', 'features': 20},
#             Current best combo with val score 0.4337:
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
# Trained and Tested combination 4272 of 198288, taking 0.02 seconds to get val score of 0.3117:
#                 {'C': 10, 'degree': 2, 'tol': 1, 'max_iter': 50, 'gamma': 'auto', 'features': 20},
#             Current best combo with val score 0.4337:
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
# Trained and Tested combination 4273 of 198288, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 10, 'degree': 2, 'tol': 10, 'max_iter': 100, 'gamma': 'auto', 'features': 20},
#             Current best combo with val score 0.4337:
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
# Trained and Tested combination 4274 of 198288, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 10, 'degree': 2, 'tol': 10, 'max_iter': 50, 'gamma': 'scale', 'features': 20},
#             Current best combo with val score 0.4337:
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
# Trained and Tested combination 4275 of 198288, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 10, 'degree': 2, 'tol': 10, 'max_iter': 50, 'gamma': 'auto', 'features': 19},
#             Current best combo with val score 0.4337:
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
# Trained and Tested combination 4276 of 198288, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 10, 'degree': 2, 'tol': 10, 'max_iter': 50, 'gamma': 'auto', 'features': 21},
#             Current best combo with val score 0.4337:
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
# Already Trained and Tested combination (val score of 0.3117):
#             {'C': 1, 'degree': 1, 'tol': 10, 'max_iter': 100, 'gamma': 'auto', 'features': 20}
#             Current best combo (with val score 0.4337):
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
#         Has trained 4276 of 198288 combinations so far
# Already Trained and Tested combination (val score of 0.3117):
#             {'C': 10, 'degree': 2, 'tol': 10, 'max_iter': 100, 'gamma': 'auto', 'features': 20}
#             Current best combo (with val score 0.4337):
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
#         Has trained 4276 of 198288 combinations so far
# Trained and Tested combination 4277 of 198288, taking 0.04 seconds to get val score of 0.3135:
#                 {'C': 10, 'degree': 1, 'tol': 1, 'max_iter': 100, 'gamma': 'auto', 'features': 20},
#             Current best combo with val score 0.4337:
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
# Already Trained and Tested combination (val score of 0.3117):
#             {'C': 10, 'degree': 1, 'tol': 10, 'max_iter': 50, 'gamma': 'auto', 'features': 20}
#             Current best combo (with val score 0.4337):
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
#         Has trained 4277 of 198288 combinations so far
# Trained and Tested combination 4278 of 198288, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 10, 'degree': 1, 'tol': 10, 'max_iter': 200, 'gamma': 'auto', 'features': 20},
#             Current best combo with val score 0.4337:
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
# Trained and Tested combination 4279 of 198288, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 10, 'degree': 1, 'tol': 10, 'max_iter': 100, 'gamma': 'scale', 'features': 20},
#             Current best combo with val score 0.4337:
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
# Trained and Tested combination 4280 of 198288, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 10, 'degree': 1, 'tol': 10, 'max_iter': 100, 'gamma': 'auto', 'features': 19},
#             Current best combo with val score 0.4337:
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
# Trained and Tested combination 4281 of 198288, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 10, 'degree': 1, 'tol': 10, 'max_iter': 100, 'gamma': 'auto', 'features': 21},
#             Current best combo with val score 0.4337:
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
# Already Trained and Tested combination (val score of 0.3117):
#             {'C': 1, 'degree': 1, 'tol': 10, 'max_iter': 50, 'gamma': 'scale', 'features': 20}
#             Current best combo (with val score 0.4337):
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
#         Has trained 4281 of 198288 combinations so far
# Already Trained and Tested combination (val score of 0.3117):
#             {'C': 10, 'degree': 2, 'tol': 10, 'max_iter': 50, 'gamma': 'scale', 'features': 20}
#             Current best combo (with val score 0.4337):
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
#         Has trained 4281 of 198288 combinations so far
# Trained and Tested combination 4282 of 198288, taking 0.02 seconds to get val score of 0.2131:
#                 {'C': 10, 'degree': 1, 'tol': 1, 'max_iter': 50, 'gamma': 'scale', 'features': 20},
#             Current best combo with val score 0.4337:
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
# Already Trained and Tested combination (val score of 0.3117):
#             {'C': 10, 'degree': 1, 'tol': 10, 'max_iter': 100, 'gamma': 'scale', 'features': 20}
#             Current best combo (with val score 0.4337):
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
#         Has trained 4282 of 198288 combinations so far
# Already Trained and Tested combination (val score of 0.3117):
#             {'C': 10, 'degree': 1, 'tol': 10, 'max_iter': 50, 'gamma': 'auto', 'features': 20}
#             Current best combo (with val score 0.4337):
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
#         Has trained 4282 of 198288 combinations so far
# Trained and Tested combination 4283 of 198288, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 10, 'degree': 1, 'tol': 10, 'max_iter': 50, 'gamma': 'scale', 'features': 19},
#             Current best combo with val score 0.4337:
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
# Trained and Tested combination 4284 of 198288, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 10, 'degree': 1, 'tol': 10, 'max_iter': 50, 'gamma': 'scale', 'features': 21},
#             Current best combo with val score 0.4337:
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
# Already Trained and Tested combination (val score of 0.3117):
#             {'C': 1, 'degree': 1, 'tol': 10, 'max_iter': 50, 'gamma': 'auto', 'features': 19}
#             Current best combo (with val score 0.4337):
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
#         Has trained 4284 of 198288 combinations so far
# Already Trained and Tested combination (val score of 0.3117):
#             {'C': 10, 'degree': 2, 'tol': 10, 'max_iter': 50, 'gamma': 'auto', 'features': 19}
#             Current best combo (with val score 0.4337):
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
#         Has trained 4284 of 198288 combinations so far
# Trained and Tested combination 4285 of 198288, taking 0.03 seconds to get val score of 0.2491:
#                 {'C': 10, 'degree': 1, 'tol': 1, 'max_iter': 50, 'gamma': 'auto', 'features': 19},
#             Current best combo with val score 0.4337:
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
# Already Trained and Tested combination (val score of 0.3117):
#             {'C': 10, 'degree': 1, 'tol': 10, 'max_iter': 100, 'gamma': 'auto', 'features': 19}
#             Current best combo (with val score 0.4337):
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
#         Has trained 4285 of 198288 combinations so far
# Already Trained and Tested combination (val score of 0.3117):
#             {'C': 10, 'degree': 1, 'tol': 10, 'max_iter': 50, 'gamma': 'scale', 'features': 19}
#             Current best combo (with val score 0.4337):
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
#         Has trained 4285 of 198288 combinations so far
# Trained and Tested combination 4286 of 198288, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 10, 'degree': 1, 'tol': 10, 'max_iter': 50, 'gamma': 'auto', 'features': 18},
#             Current best combo with val score 0.4337:
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
# Already Trained and Tested combination (val score of 0.3117):
#             {'C': 10, 'degree': 1, 'tol': 10, 'max_iter': 50, 'gamma': 'auto', 'features': 20}
#             Current best combo (with val score 0.4337):
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
#         Has trained 4286 of 198288 combinations so far
# Already Trained and Tested combination (val score of 0.3117):
#             {'C': 1, 'degree': 1, 'tol': 10, 'max_iter': 50, 'gamma': 'auto', 'features': 21}
#             Current best combo (with val score 0.4337):
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
#         Has trained 4286 of 198288 combinations so far
# Already Trained and Tested combination (val score of 0.3117):
#             {'C': 10, 'degree': 2, 'tol': 10, 'max_iter': 50, 'gamma': 'auto', 'features': 21}
#             Current best combo (with val score 0.4337):
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
#         Has trained 4286 of 198288 combinations so far
# Trained and Tested combination 4287 of 198288, taking 0.02 seconds to get val score of 0.3217:
#                 {'C': 10, 'degree': 1, 'tol': 1, 'max_iter': 50, 'gamma': 'auto', 'features': 21},
#             Current best combo with val score 0.4337:
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
# Already Trained and Tested combination (val score of 0.3117):
#             {'C': 10, 'degree': 1, 'tol': 10, 'max_iter': 100, 'gamma': 'auto', 'features': 21}
#             Current best combo (with val score 0.4337):
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
#         Has trained 4287 of 198288 combinations so far
# Already Trained and Tested combination (val score of 0.3117):
#             {'C': 10, 'degree': 1, 'tol': 10, 'max_iter': 50, 'gamma': 'scale', 'features': 21}
#             Current best combo (with val score 0.4337):
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
#         Has trained 4287 of 198288 combinations so far
# Already Trained and Tested combination (val score of 0.3117):
#             {'C': 10, 'degree': 1, 'tol': 10, 'max_iter': 50, 'gamma': 'auto', 'features': 20}
#             Current best combo (with val score 0.4337):
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
#         Has trained 4287 of 198288 combinations so far
# Trained and Tested combination 4288 of 198288, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 10, 'degree': 1, 'tol': 10, 'max_iter': 50, 'gamma': 'auto', 'features': 22},
#             Current best combo with val score 0.4337:
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
# % Combos Checked Thus Far: 4288 out of 198288 which is 2.162511%
# Cruising Coordrdinate 299 of 528
#
# Cruise suspended due to suspicious case
# Guidance: round 207
#
# 	round 207 iteration:  0
#
# Trained and Tested combination 4289 of 198288, taking 0.0 seconds to get val score of 0.3117:
#                 {'C': 1, 'degree': 9, 'tol': 10, 'max_iter': 50, 'gamma': 'auto', 'features': 0},
#             Current best combo with val score 0.4337:
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
# Trained and Tested combination 4290 of 198288, taking 0.0 seconds to get val score of 0.3117:
#                 {'C': 10, 'degree': 8, 'tol': 10, 'max_iter': 50, 'gamma': 'auto', 'features': 0},
#             Current best combo with val score 0.4337:
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
# Trained and Tested combination 4291 of 198288, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 10, 'degree': 9, 'tol': 1, 'max_iter': 50, 'gamma': 'auto', 'features': 0},
#             Current best combo with val score 0.4337:
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
# Trained and Tested combination 4292 of 198288, taking 0.0 seconds to get val score of 0.3117:
#                 {'C': 10, 'degree': 9, 'tol': 10, 'max_iter': 100, 'gamma': 'auto', 'features': 0},
#             Current best combo with val score 0.4337:
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
# Already Trained and Tested combination (val score of 0.3117):
#             {'C': 10, 'degree': 9, 'tol': 10, 'max_iter': 50, 'gamma': 'scale', 'features': 0}
#             Current best combo (with val score 0.4337):
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
#         Has trained 4292 of 198288 combinations so far
# Trained and Tested combination 4293 of 198288, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 10, 'degree': 9, 'tol': 10, 'max_iter': 50, 'gamma': 'auto', 'features': 1},
#             Current best combo with val score 0.4337:
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
# 	round 207 iteration:  1
#
# Trained and Tested combination 4294 of 198288, taking 0.0 seconds to get val score of 0.3117:
#                 {'C': 0.1, 'degree': 9, 'tol': 10, 'max_iter': 50, 'gamma': 'auto', 'features': 0},
#             Current best combo with val score 0.4337:
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
# Already Trained and Tested combination (val score of 0.3117):
#             {'C': 10, 'degree': 9, 'tol': 10, 'max_iter': 50, 'gamma': 'auto', 'features': 0}
#             Current best combo (with val score 0.4337):
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
#         Has trained 4294 of 198288 combinations so far
# Trained and Tested combination 4295 of 198288, taking 0.0 seconds to get val score of 0.3117:
#                 {'C': 1, 'degree': 8, 'tol': 10, 'max_iter': 50, 'gamma': 'auto', 'features': 0},
#             Current best combo with val score 0.4337:
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
# Trained and Tested combination 4296 of 198288, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 1, 'degree': 9, 'tol': 1, 'max_iter': 50, 'gamma': 'auto', 'features': 0},
#             Current best combo with val score 0.4337:
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
# Trained and Tested combination 4297 of 198288, taking 0.0 seconds to get val score of 0.3117:
#                 {'C': 1, 'degree': 9, 'tol': 10, 'max_iter': 100, 'gamma': 'auto', 'features': 0},
#             Current best combo with val score 0.4337:
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
# Trained and Tested combination 4298 of 198288, taking 0.0 seconds to get val score of 0.3117:
#                 {'C': 1, 'degree': 9, 'tol': 10, 'max_iter': 50, 'gamma': 'scale', 'features': 0},
#             Current best combo with val score 0.4337:
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
# Trained and Tested combination 4299 of 198288, taking 0.0 seconds to get val score of 0.3117:
#                 {'C': 1, 'degree': 9, 'tol': 10, 'max_iter': 50, 'gamma': 'auto', 'features': 1},
#             Current best combo with val score 0.4337:
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
# Already Trained and Tested combination (val score of 0.3117):
#             {'C': 1, 'degree': 8, 'tol': 10, 'max_iter': 50, 'gamma': 'auto', 'features': 0}
#             Current best combo (with val score 0.4337):
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
#         Has trained 4299 of 198288 combinations so far
# Trained and Tested combination 4300 of 198288, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 10, 'degree': 7, 'tol': 10, 'max_iter': 50, 'gamma': 'auto', 'features': 0},
#             Current best combo with val score 0.4337:
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
# Already Trained and Tested combination (val score of 0.3117):
#             {'C': 10, 'degree': 9, 'tol': 10, 'max_iter': 50, 'gamma': 'auto', 'features': 0}
#             Current best combo (with val score 0.4337):
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
#         Has trained 4300 of 198288 combinations so far
# Trained and Tested combination 4301 of 198288, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 10, 'degree': 8, 'tol': 1, 'max_iter': 50, 'gamma': 'auto', 'features': 0},
#             Current best combo with val score 0.4337:
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
# Trained and Tested combination 4302 of 198288, taking 0.0 seconds to get val score of 0.3117:
#                 {'C': 10, 'degree': 8, 'tol': 10, 'max_iter': 100, 'gamma': 'auto', 'features': 0},
#             Current best combo with val score 0.4337:
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
# Trained and Tested combination 4303 of 198288, taking 0.0 seconds to get val score of 0.3117:
#                 {'C': 10, 'degree': 8, 'tol': 10, 'max_iter': 50, 'gamma': 'scale', 'features': 0},
#             Current best combo with val score 0.4337:
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
# Trained and Tested combination 4304 of 198288, taking 0.0 seconds to get val score of 0.3117:
#                 {'C': 10, 'degree': 8, 'tol': 10, 'max_iter': 50, 'gamma': 'auto', 'features': 1},
#             Current best combo with val score 0.4337:
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
# Already Trained and Tested combination (val score of 0.3117):
#             {'C': 1, 'degree': 9, 'tol': 1, 'max_iter': 50, 'gamma': 'auto', 'features': 0}
#             Current best combo (with val score 0.4337):
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
#         Has trained 4304 of 198288 combinations so far
# Already Trained and Tested combination (val score of 0.3117):
#             {'C': 10, 'degree': 8, 'tol': 1, 'max_iter': 50, 'gamma': 'auto', 'features': 0}
#             Current best combo (with val score 0.4337):
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
#         Has trained 4304 of 198288 combinations so far
# Trained and Tested combination 4305 of 198288, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 10, 'degree': 9, 'tol': 0.1, 'max_iter': 50, 'gamma': 'auto', 'features': 0},
#             Current best combo with val score 0.4337:
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
# Already Trained and Tested combination (val score of 0.3117):
#             {'C': 10, 'degree': 9, 'tol': 10, 'max_iter': 50, 'gamma': 'auto', 'features': 0}
#             Current best combo (with val score 0.4337):
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
#         Has trained 4305 of 198288 combinations so far
# Trained and Tested combination 4306 of 198288, taking 0.02 seconds to get val score of 0.3117:
#                 {'C': 10, 'degree': 9, 'tol': 1, 'max_iter': 100, 'gamma': 'auto', 'features': 0},
#             Current best combo with val score 0.4337:
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
# Trained and Tested combination 4307 of 198288, taking 0.02 seconds to get val score of 0.2039:
#                 {'C': 10, 'degree': 9, 'tol': 1, 'max_iter': 50, 'gamma': 'scale', 'features': 0},
#             Current best combo with val score 0.4337:
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
# Trained and Tested combination 4308 of 198288, taking 0.01 seconds to get val score of 0.3311:
#                 {'C': 10, 'degree': 9, 'tol': 1, 'max_iter': 50, 'gamma': 'auto', 'features': 1},
#             Current best combo with val score 0.4337:
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
# Already Trained and Tested combination (val score of 0.3117):
#             {'C': 1, 'degree': 9, 'tol': 10, 'max_iter': 100, 'gamma': 'auto', 'features': 0}
#             Current best combo (with val score 0.4337):
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
#         Has trained 4308 of 198288 combinations so far
# Already Trained and Tested combination (val score of 0.3117):
#             {'C': 10, 'degree': 8, 'tol': 10, 'max_iter': 100, 'gamma': 'auto', 'features': 0}
#             Current best combo (with val score 0.4337):
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
#         Has trained 4308 of 198288 combinations so far
# Already Trained and Tested combination (val score of 0.3117):
#             {'C': 10, 'degree': 9, 'tol': 1, 'max_iter': 100, 'gamma': 'auto', 'features': 0}
#             Current best combo (with val score 0.4337):
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
#         Has trained 4308 of 198288 combinations so far
# Already Trained and Tested combination (val score of 0.3117):
#             {'C': 10, 'degree': 9, 'tol': 10, 'max_iter': 50, 'gamma': 'auto', 'features': 0}
#             Current best combo (with val score 0.4337):
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
#         Has trained 4308 of 198288 combinations so far
# Trained and Tested combination 4309 of 198288, taking 0.0 seconds to get val score of 0.3117:
#                 {'C': 10, 'degree': 9, 'tol': 10, 'max_iter': 200, 'gamma': 'auto', 'features': 0},
#             Current best combo with val score 0.4337:
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
# Trained and Tested combination 4310 of 198288, taking 0.0 seconds to get val score of 0.3117:
#                 {'C': 10, 'degree': 9, 'tol': 10, 'max_iter': 100, 'gamma': 'scale', 'features': 0},
#             Current best combo with val score 0.4337:
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
# Trained and Tested combination 4311 of 198288, taking 0.0 seconds to get val score of 0.3117:
#                 {'C': 10, 'degree': 9, 'tol': 10, 'max_iter': 100, 'gamma': 'auto', 'features': 1},
#             Current best combo with val score 0.4337:
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
# Already Trained and Tested combination (val score of 0.3117):
#             {'C': 1, 'degree': 9, 'tol': 10, 'max_iter': 50, 'gamma': 'scale', 'features': 0}
#             Current best combo (with val score 0.4337):
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
#         Has trained 4311 of 198288 combinations so far
# Already Trained and Tested combination (val score of 0.3117):
#             {'C': 10, 'degree': 8, 'tol': 10, 'max_iter': 50, 'gamma': 'scale', 'features': 0}
#             Current best combo (with val score 0.4337):
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
#         Has trained 4311 of 198288 combinations so far
# Already Trained and Tested combination (val score of 0.2039):
#             {'C': 10, 'degree': 9, 'tol': 1, 'max_iter': 50, 'gamma': 'scale', 'features': 0}
#             Current best combo (with val score 0.4337):
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
#         Has trained 4311 of 198288 combinations so far
# Already Trained and Tested combination (val score of 0.3117):
#             {'C': 10, 'degree': 9, 'tol': 10, 'max_iter': 100, 'gamma': 'scale', 'features': 0}
#             Current best combo (with val score 0.4337):
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
#         Has trained 4311 of 198288 combinations so far
# Already Trained and Tested combination (val score of 0.3117):
#             {'C': 10, 'degree': 9, 'tol': 10, 'max_iter': 50, 'gamma': 'auto', 'features': 0}
#             Current best combo (with val score 0.4337):
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
#         Has trained 4311 of 198288 combinations so far
# Trained and Tested combination 4312 of 198288, taking 0.0 seconds to get val score of 0.3117:
#                 {'C': 10, 'degree': 9, 'tol': 10, 'max_iter': 50, 'gamma': 'scale', 'features': 1},
#             Current best combo with val score 0.4337:
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
# Already Trained and Tested combination (val score of 0.3117):
#             {'C': 1, 'degree': 9, 'tol': 10, 'max_iter': 50, 'gamma': 'auto', 'features': 1}
#             Current best combo (with val score 0.4337):
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
#         Has trained 4312 of 198288 combinations so far
# Already Trained and Tested combination (val score of 0.3117):
#             {'C': 10, 'degree': 8, 'tol': 10, 'max_iter': 50, 'gamma': 'auto', 'features': 1}
#             Current best combo (with val score 0.4337):
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
#         Has trained 4312 of 198288 combinations so far
# Already Trained and Tested combination (val score of 0.3311):
#             {'C': 10, 'degree': 9, 'tol': 1, 'max_iter': 50, 'gamma': 'auto', 'features': 1}
#             Current best combo (with val score 0.4337):
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
#         Has trained 4312 of 198288 combinations so far
# Already Trained and Tested combination (val score of 0.3117):
#             {'C': 10, 'degree': 9, 'tol': 10, 'max_iter': 100, 'gamma': 'auto', 'features': 1}
#             Current best combo (with val score 0.4337):
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
#         Has trained 4312 of 198288 combinations so far
# Already Trained and Tested combination (val score of 0.3117):
#             {'C': 10, 'degree': 9, 'tol': 10, 'max_iter': 50, 'gamma': 'scale', 'features': 1}
#             Current best combo (with val score 0.4337):
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
#         Has trained 4312 of 198288 combinations so far
# Already Trained and Tested combination (val score of 0.3117):
#             {'C': 10, 'degree': 9, 'tol': 10, 'max_iter': 50, 'gamma': 'auto', 'features': 0}
#             Current best combo (with val score 0.4337):
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
#         Has trained 4312 of 198288 combinations so far
# Trained and Tested combination 4313 of 198288, taking 0.0 seconds to get val score of 0.3117:
#                 {'C': 10, 'degree': 9, 'tol': 10, 'max_iter': 50, 'gamma': 'auto', 'features': 2},
#             Current best combo with val score 0.4337:
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
# % Combos Checked Thus Far: 4313 out of 198288 which is 2.175119%
# Cruising Coordrdinate 300 of 528
#
# Cruise suspended due to suspicious case
# Guidance: round 208
#
# 	round 208 iteration:  0
#
# Trained and Tested combination 4314 of 198288, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 1, 'degree': 9, 'tol': 10, 'max_iter': 50, 'gamma': 'auto', 'features': 20},
#             Current best combo with val score 0.4337:
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
# Trained and Tested combination 4315 of 198288, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 10, 'degree': 8, 'tol': 10, 'max_iter': 50, 'gamma': 'auto', 'features': 20},
#             Current best combo with val score 0.4337:
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
# Trained and Tested combination 4316 of 198288, taking 0.02 seconds to get val score of 0.3117:
#                 {'C': 10, 'degree': 9, 'tol': 1, 'max_iter': 50, 'gamma': 'auto', 'features': 20},
#             Current best combo with val score 0.4337:
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
# Trained and Tested combination 4317 of 198288, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 10, 'degree': 9, 'tol': 10, 'max_iter': 100, 'gamma': 'auto', 'features': 20},
#             Current best combo with val score 0.4337:
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
# Already Trained and Tested combination (val score of 0.3117):
#             {'C': 10, 'degree': 9, 'tol': 10, 'max_iter': 50, 'gamma': 'scale', 'features': 20}
#             Current best combo (with val score 0.4337):
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
#         Has trained 4317 of 198288 combinations so far
# Trained and Tested combination 4318 of 198288, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 10, 'degree': 9, 'tol': 10, 'max_iter': 50, 'gamma': 'auto', 'features': 19},
#             Current best combo with val score 0.4337:
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
# Trained and Tested combination 4319 of 198288, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 10, 'degree': 9, 'tol': 10, 'max_iter': 50, 'gamma': 'auto', 'features': 21},
#             Current best combo with val score 0.4337:
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
# 	round 208 iteration:  1
#
# Trained and Tested combination 4320 of 198288, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 0.1, 'degree': 9, 'tol': 10, 'max_iter': 50, 'gamma': 'auto', 'features': 20},
#             Current best combo with val score 0.4337:
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
# Already Trained and Tested combination (val score of 0.3117):
#             {'C': 10, 'degree': 9, 'tol': 10, 'max_iter': 50, 'gamma': 'auto', 'features': 20}
#             Current best combo (with val score 0.4337):
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
#         Has trained 4320 of 198288 combinations so far
# Trained and Tested combination 4321 of 198288, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 1, 'degree': 8, 'tol': 10, 'max_iter': 50, 'gamma': 'auto', 'features': 20},
#             Current best combo with val score 0.4337:
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
# Trained and Tested combination 4322 of 198288, taking 0.03 seconds to get val score of 0.3117:
#                 {'C': 1, 'degree': 9, 'tol': 1, 'max_iter': 50, 'gamma': 'auto', 'features': 20},
#             Current best combo with val score 0.4337:
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
# Trained and Tested combination 4323 of 198288, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 1, 'degree': 9, 'tol': 10, 'max_iter': 100, 'gamma': 'auto', 'features': 20},
#             Current best combo with val score 0.4337:
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
# Trained and Tested combination 4324 of 198288, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 1, 'degree': 9, 'tol': 10, 'max_iter': 50, 'gamma': 'scale', 'features': 20},
#             Current best combo with val score 0.4337:
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
# Trained and Tested combination 4325 of 198288, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 1, 'degree': 9, 'tol': 10, 'max_iter': 50, 'gamma': 'auto', 'features': 19},
#             Current best combo with val score 0.4337:
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
# Trained and Tested combination 4326 of 198288, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 1, 'degree': 9, 'tol': 10, 'max_iter': 50, 'gamma': 'auto', 'features': 21},
#             Current best combo with val score 0.4337:
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
# Already Trained and Tested combination (val score of 0.3117):
#             {'C': 1, 'degree': 8, 'tol': 10, 'max_iter': 50, 'gamma': 'auto', 'features': 20}
#             Current best combo (with val score 0.4337):
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
#         Has trained 4326 of 198288 combinations so far
# Trained and Tested combination 4327 of 198288, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 10, 'degree': 7, 'tol': 10, 'max_iter': 50, 'gamma': 'auto', 'features': 20},
#             Current best combo with val score 0.4337:
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
# Already Trained and Tested combination (val score of 0.3117):
#             {'C': 10, 'degree': 9, 'tol': 10, 'max_iter': 50, 'gamma': 'auto', 'features': 20}
#             Current best combo (with val score 0.4337):
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
#         Has trained 4327 of 198288 combinations so far
# Trained and Tested combination 4328 of 198288, taking 0.02 seconds to get val score of 0.3117:
#                 {'C': 10, 'degree': 8, 'tol': 1, 'max_iter': 50, 'gamma': 'auto', 'features': 20},
#             Current best combo with val score 0.4337:
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
# Trained and Tested combination 4329 of 198288, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 10, 'degree': 8, 'tol': 10, 'max_iter': 100, 'gamma': 'auto', 'features': 20},
#             Current best combo with val score 0.4337:
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
# Trained and Tested combination 4330 of 198288, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 10, 'degree': 8, 'tol': 10, 'max_iter': 50, 'gamma': 'scale', 'features': 20},
#             Current best combo with val score 0.4337:
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
# Trained and Tested combination 4331 of 198288, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 10, 'degree': 8, 'tol': 10, 'max_iter': 50, 'gamma': 'auto', 'features': 19},
#             Current best combo with val score 0.4337:
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
# Trained and Tested combination 4332 of 198288, taking 0.01 seconds to get val score of 0.3117:
#                 {'C': 10, 'degree': 8, 'tol': 10, 'max_iter': 50, 'gamma': 'auto', 'features': 21},
#             Current best combo with val score 0.4337:
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
# Already Trained and Tested combination (val score of 0.3117):
#             {'C': 1, 'degree': 9, 'tol': 1, 'max_iter': 50, 'gamma': 'auto', 'features': 20}
#             Current best combo (with val score 0.4337):
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
#         Has trained 4332 of 198288 combinations so far
# Already Trained and Tested combination (val score of 0.3117):
#             {'C': 10, 'degree': 8, 'tol': 1, 'max_iter': 50, 'gamma': 'auto', 'features': 20}
#             Current best combo (with val score 0.4337):
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
#         Has trained 4332 of 198288 combinations so far
# Trained and Tested combination 4333 of 198288, taking 0.02 seconds to get val score of 0.3117:
#                 {'C': 10, 'degree': 9, 'tol': 0.1, 'max_iter': 50, 'gamma': 'auto', 'features': 20},
#             Current best combo with val score 0.4337:
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
# Already Trained and Tested combination (val score of 0.3117):
#             {'C': 10, 'degree': 9, 'tol': 10, 'max_iter': 50, 'gamma': 'auto', 'features': 20}
#             Current best combo (with val score 0.4337):
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
#         Has trained 4333 of 198288 combinations so far
# Trained and Tested combination 4334 of 198288, taking 0.04 seconds to get val score of 0.3117:
#                 {'C': 10, 'degree': 9, 'tol': 1, 'max_iter': 100, 'gamma': 'auto', 'features': 20},
#             Current best combo with val score 0.4337:
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
# Trained and Tested combination 4335 of 198288, taking 0.02 seconds to get val score of 0.3167:
#                 {'C': 10, 'degree': 9, 'tol': 1, 'max_iter': 50, 'gamma': 'scale', 'features': 20},
#             Current best combo with val score 0.4337:
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
# Trained and Tested combination 4336 of 198288, taking 0.03 seconds to get val score of 0.3117:
#                 {'C': 10, 'degree': 9, 'tol': 1, 'max_iter': 50, 'gamma': 'auto', 'features': 19},
#             Current best combo with val score 0.4337:
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
# Trained and Tested combination 4337 of 198288, taking 0.02 seconds to get val score of 0.3117:
#                 {'C': 10, 'degree': 9, 'tol': 1, 'max_iter': 50, 'gamma': 'auto', 'features': 21},
#             Current best combo with val score 0.4337:
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
# Already Trained and Tested combination (val score of 0.3117):
#             {'C': 1, 'degree': 9, 'tol': 10, 'max_iter': 100, 'gamma': 'auto', 'features': 20}
#             Current best combo (with val score 0.4337):
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
#         Has trained 4337 of 198288 combinations so far
# Already Trained and Tested combination (val score of 0.3117):
#             {'C': 10, 'degree': 8, 'tol': 10, 'max_iter': 100, 'gamma': 'auto', 'features': 20}
#             Current best combo (with val score 0.4337):
# ...
#                 {'C': 10, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 7},
#             Current best combo with val score 0.4338:
#                     {'C': 10, 'degree': 1, 'tol': 0.0001, 'max_iter': 200, 'gamma': 'auto', 'features': 0}
# % Combos Checked Thus Far: 4775 out of 198288 which is 2.4081129999999997%
# Cruising Coordrdinate 506 of 528
#
# Cruising Coordrdinate 507 of 528
#
# Cruising Coordrdinate 508 of 528
#
# Cruising Coordrdinate 509 of 528
#
# Cruising Coordrdinate 510 of 528
#
# Cruising Coordrdinate 511 of 528
#
# Cruising Coordrdinate 512 of 528
#
# Cruising Coordrdinate 513 of 528
#
# Cruising Coordrdinate 514 of 528
#
# Cruising Coordrdinate 515 of 528
#
# Cruising Coordrdinate 516 of 528
#
# Cruising Coordrdinate 517 of 528
#
# Cruising Coordrdinate 518 of 528
#
# Cruising Coordrdinate 519 of 528
#
# Cruising Coordrdinate 520 of 528
#
# Cruising Coordrdinate 521 of 528
#
# Cruising Coordrdinate 522 of 528
#
# Cruising Coordrdinate 523 of 528
#
# Cruising Coordrdinate 524 of 528
#
# Cruising Coordrdinate 525 of 528
#
# Cruising Coordrdinate 526 of 528
#
# Cruising Coordrdinate 527 of 528
#
# Cruising Coordrdinate 528 of 528
#
# FINAL STAGE: Begin final Guidance system
#
#
# Guidance: round FINAL
#
# 	round FINAL iteration:  0
#
# Already Trained and Tested combination (val score of 0.4338):
#             {'C': 1, 'degree': 1, 'tol': 0.0001, 'max_iter': 200, 'gamma': 'auto', 'features': 0}
#             Current best combo (with val score 0.4338):
#                     {'C': 10, 'degree': 1, 'tol': 0.0001, 'max_iter': 200, 'gamma': 'auto', 'features': 0}
#         Has trained 4775 of 198288 combinations so far
# Already Trained and Tested combination (val score of 0.4338):
#             {'C': 10, 'degree': 2, 'tol': 0.0001, 'max_iter': 200, 'gamma': 'auto', 'features': 0}
#             Current best combo (with val score 0.4338):
#                     {'C': 10, 'degree': 1, 'tol': 0.0001, 'max_iter': 200, 'gamma': 'auto', 'features': 0}
#         Has trained 4775 of 198288 combinations so far
# Already Trained and Tested combination (val score of 0.4338):
#             {'C': 10, 'degree': 1, 'tol': 0.001, 'max_iter': 200, 'gamma': 'auto', 'features': 0}
#             Current best combo (with val score 0.4338):
#                     {'C': 10, 'degree': 1, 'tol': 0.0001, 'max_iter': 200, 'gamma': 'auto', 'features': 0}
#         Has trained 4775 of 198288 combinations so far
# Already Trained and Tested combination (val score of 0.3117):
#             {'C': 10, 'degree': 1, 'tol': 0.0001, 'max_iter': 100, 'gamma': 'auto', 'features': 0}
#             Current best combo (with val score 0.4338):
#                     {'C': 10, 'degree': 1, 'tol': 0.0001, 'max_iter': 200, 'gamma': 'auto', 'features': 0}
#         Has trained 4775 of 198288 combinations so far
# Already Trained and Tested combination (val score of 0.4338):
#             {'C': 10, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'auto', 'features': 0}
#             Current best combo (with val score 0.4338):
#                     {'C': 10, 'degree': 1, 'tol': 0.0001, 'max_iter': 200, 'gamma': 'auto', 'features': 0}
#         Has trained 4775 of 198288 combinations so far
# Already Trained and Tested combination (val score of 0.3073):
#             {'C': 10, 'degree': 1, 'tol': 0.0001, 'max_iter': 200, 'gamma': 'scale', 'features': 0}
#             Current best combo (with val score 0.4338):
#                     {'C': 10, 'degree': 1, 'tol': 0.0001, 'max_iter': 200, 'gamma': 'auto', 'features': 0}
#         Has trained 4775 of 198288 combinations so far
# Already Trained and Tested combination (val score of 0.4002):
#             {'C': 10, 'degree': 1, 'tol': 0.0001, 'max_iter': 200, 'gamma': 'auto', 'features': 1}
#             Current best combo (with val score 0.4338):
#                     {'C': 10, 'degree': 1, 'tol': 0.0001, 'max_iter': 200, 'gamma': 'auto', 'features': 0}
#         Has trained 4775 of 198288 combinations so far
# 	round FINAL iteration:  1
#
# Trained and Tested combination 4776 of 198288, taking 0.03 seconds to get val score of 0.4338:
#                 {'C': 0.1, 'degree': 1, 'tol': 0.0001, 'max_iter': 200, 'gamma': 'auto', 'features': 0},
#             Current best combo with val score 0.4338:
#                     {'C': 10, 'degree': 1, 'tol': 0.0001, 'max_iter': 200, 'gamma': 'auto', 'features': 0}
# Already Trained and Tested combination (val score of 0.4338):
#             {'C': 10, 'degree': 1, 'tol': 0.0001, 'max_iter': 200, 'gamma': 'auto', 'features': 0}
#             Current best combo (with val score 0.4338):
#                     {'C': 10, 'degree': 1, 'tol': 0.0001, 'max_iter': 200, 'gamma': 'auto', 'features': 0}
#         Has trained 4776 of 198288 combinations so far
# Trained and Tested combination 4777 of 198288, taking 0.03 seconds to get val score of 0.4338:
#                 {'C': 1, 'degree': 2, 'tol': 0.0001, 'max_iter': 200, 'gamma': 'auto', 'features': 0},
#             Current best combo with val score 0.4338:
#                     {'C': 10, 'degree': 1, 'tol': 0.0001, 'max_iter': 200, 'gamma': 'auto', 'features': 0}
# Trained and Tested combination 4778 of 198288, taking 0.03 seconds to get val score of 0.4338:
#                 {'C': 1, 'degree': 1, 'tol': 0.001, 'max_iter': 200, 'gamma': 'auto', 'features': 0},
#             Current best combo with val score 0.4338:
#                     {'C': 10, 'degree': 1, 'tol': 0.0001, 'max_iter': 200, 'gamma': 'auto', 'features': 0}
# Already Trained and Tested combination (val score of 0.3117):
#             {'C': 1, 'degree': 1, 'tol': 0.0001, 'max_iter': 100, 'gamma': 'auto', 'features': 0}
#             Current best combo (with val score 0.4338):
#                     {'C': 10, 'degree': 1, 'tol': 0.0001, 'max_iter': 200, 'gamma': 'auto', 'features': 0}
#         Has trained 4778 of 198288 combinations so far
# Trained and Tested combination 4779 of 198288, taking 0.1 seconds to get val score of 0.4338:
#                 {'C': 1, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'auto', 'features': 0},
#             Current best combo with val score 0.4338:
#                     {'C': 10, 'degree': 1, 'tol': 0.0001, 'max_iter': 200, 'gamma': 'auto', 'features': 0}
# Trained and Tested combination 4780 of 198288, taking 0.02 seconds to get val score of 0.3073:
#                 {'C': 1, 'degree': 1, 'tol': 0.0001, 'max_iter': 200, 'gamma': 'scale', 'features': 0},
#             Current best combo with val score 0.4338:
#                     {'C': 10, 'degree': 1, 'tol': 0.0001, 'max_iter': 200, 'gamma': 'auto', 'features': 0}
# Trained and Tested combination 4781 of 198288, taking 0.03 seconds to get val score of 0.4126:
#                 {'C': 1, 'degree': 1, 'tol': 0.0001, 'max_iter': 200, 'gamma': 'auto', 'features': 1},
#             Current best combo with val score 0.4338:
#                     {'C': 10, 'degree': 1, 'tol': 0.0001, 'max_iter': 200, 'gamma': 'auto', 'features': 0}
# Already Trained and Tested combination (val score of 0.4338):
#             {'C': 1, 'degree': 2, 'tol': 0.0001, 'max_iter': 200, 'gamma': 'auto', 'features': 0}
#             Current best combo (with val score 0.4338):
#                     {'C': 10, 'degree': 1, 'tol': 0.0001, 'max_iter': 200, 'gamma': 'auto', 'features': 0}
#         Has trained 4781 of 198288 combinations so far
# Already Trained and Tested combination (val score of 0.4338):
#             {'C': 10, 'degree': 1, 'tol': 0.0001, 'max_iter': 200, 'gamma': 'auto', 'features': 0}
#             Current best combo (with val score 0.4338):
#                     {'C': 10, 'degree': 1, 'tol': 0.0001, 'max_iter': 200, 'gamma': 'auto', 'features': 0}
#         Has trained 4781 of 198288 combinations so far
# Trained and Tested combination 4782 of 198288, taking 0.02 seconds to get val score of 0.4338:
#                 {'C': 10, 'degree': 3, 'tol': 0.0001, 'max_iter': 200, 'gamma': 'auto', 'features': 0},
#             Current best combo with val score 0.4338:
#                     {'C': 10, 'degree': 1, 'tol': 0.0001, 'max_iter': 200, 'gamma': 'auto', 'features': 0}
# Trained and Tested combination 4783 of 198288, taking 0.02 seconds to get val score of 0.4338:
#                 {'C': 10, 'degree': 2, 'tol': 0.001, 'max_iter': 200, 'gamma': 'auto', 'features': 0},
#             Current best combo with val score 0.4338:
#                     {'C': 10, 'degree': 1, 'tol': 0.0001, 'max_iter': 200, 'gamma': 'auto', 'features': 0}
# Already Trained and Tested combination (val score of 0.3117):
#             {'C': 10, 'degree': 2, 'tol': 0.0001, 'max_iter': 100, 'gamma': 'auto', 'features': 0}
#             Current best combo (with val score 0.4338):
#                     {'C': 10, 'degree': 1, 'tol': 0.0001, 'max_iter': 200, 'gamma': 'auto', 'features': 0}
#         Has trained 4783 of 198288 combinations so far
# Trained and Tested combination 4784 of 198288, taking 0.07 seconds to get val score of 0.4338:
#                 {'C': 10, 'degree': 2, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'auto', 'features': 0},
#             Current best combo with val score 0.4338:
#                     {'C': 10, 'degree': 1, 'tol': 0.0001, 'max_iter': 200, 'gamma': 'auto', 'features': 0}
# Trained and Tested combination 4785 of 198288, taking 0.05 seconds to get val score of 0.392:
#                 {'C': 10, 'degree': 2, 'tol': 0.0001, 'max_iter': 200, 'gamma': 'scale', 'features': 0},
#             Current best combo with val score 0.4338:
#                     {'C': 10, 'degree': 1, 'tol': 0.0001, 'max_iter': 200, 'gamma': 'auto', 'features': 0}
# Trained and Tested combination 4786 of 198288, taking 0.03 seconds to get val score of 0.4002:
#                 {'C': 10, 'degree': 2, 'tol': 0.0001, 'max_iter': 200, 'gamma': 'auto', 'features': 1},
#             Current best combo with val score 0.4338:
#                     {'C': 10, 'degree': 1, 'tol': 0.0001, 'max_iter': 200, 'gamma': 'auto', 'features': 0}
# Already Trained and Tested combination (val score of 0.4338):
#             {'C': 1, 'degree': 1, 'tol': 0.001, 'max_iter': 200, 'gamma': 'auto', 'features': 0}
#             Current best combo (with val score 0.4338):
#                     {'C': 10, 'degree': 1, 'tol': 0.0001, 'max_iter': 200, 'gamma': 'auto', 'features': 0}
#         Has trained 4786 of 198288 combinations so far
# Already Trained and Tested combination (val score of 0.4338):
#             {'C': 10, 'degree': 2, 'tol': 0.001, 'max_iter': 200, 'gamma': 'auto', 'features': 0}
#             Current best combo (with val score 0.4338):
#                     {'C': 10, 'degree': 1, 'tol': 0.0001, 'max_iter': 200, 'gamma': 'auto', 'features': 0}
#         Has trained 4786 of 198288 combinations so far
# Already Trained and Tested combination (val score of 0.4338):
#             {'C': 10, 'degree': 1, 'tol': 0.0001, 'max_iter': 200, 'gamma': 'auto', 'features': 0}
#             Current best combo (with val score 0.4338):
#                     {'C': 10, 'degree': 1, 'tol': 0.0001, 'max_iter': 200, 'gamma': 'auto', 'features': 0}
#         Has trained 4786 of 198288 combinations so far
# Trained and Tested combination 4787 of 198288, taking 0.03 seconds to get val score of 0.4338:
#                 {'C': 10, 'degree': 1, 'tol': 0.01, 'max_iter': 200, 'gamma': 'auto', 'features': 0},
#             Current best combo with val score 0.4338:
#                     {'C': 10, 'degree': 1, 'tol': 0.0001, 'max_iter': 200, 'gamma': 'auto', 'features': 0}
# Already Trained and Tested combination (val score of 0.3117):
#             {'C': 10, 'degree': 1, 'tol': 0.001, 'max_iter': 100, 'gamma': 'auto', 'features': 0}
#             Current best combo (with val score 0.4338):
#                     {'C': 10, 'degree': 1, 'tol': 0.0001, 'max_iter': 200, 'gamma': 'auto', 'features': 0}
#         Has trained 4787 of 198288 combinations so far
# Trained and Tested combination 4788 of 198288, taking 0.04 seconds to get val score of 0.4338:
#                 {'C': 10, 'degree': 1, 'tol': 0.001, 'max_iter': 400, 'gamma': 'auto', 'features': 0},
#             Current best combo with val score 0.4338:
#                     {'C': 10, 'degree': 1, 'tol': 0.0001, 'max_iter': 200, 'gamma': 'auto', 'features': 0}
# Trained and Tested combination 4789 of 198288, taking 0.02 seconds to get val score of 0.3073:
#                 {'C': 10, 'degree': 1, 'tol': 0.001, 'max_iter': 200, 'gamma': 'scale', 'features': 0},
#             Current best combo with val score 0.4338:
#                     {'C': 10, 'degree': 1, 'tol': 0.0001, 'max_iter': 200, 'gamma': 'auto', 'features': 0}
# Trained and Tested combination 4790 of 198288, taking 0.05 seconds to get val score of 0.4002:
#                 {'C': 10, 'degree': 1, 'tol': 0.001, 'max_iter': 200, 'gamma': 'auto', 'features': 1},
#             Current best combo with val score 0.4338:
#                     {'C': 10, 'degree': 1, 'tol': 0.0001, 'max_iter': 200, 'gamma': 'auto', 'features': 0}
# Already Trained and Tested combination (val score of 0.4338):
#             {'C': 1, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'auto', 'features': 0}
#             Current best combo (with val score 0.4338):
#                     {'C': 10, 'degree': 1, 'tol': 0.0001, 'max_iter': 200, 'gamma': 'auto', 'features': 0}
#         Has trained 4790 of 198288 combinations so far
# Already Trained and Tested combination (val score of 0.4338):
#             {'C': 10, 'degree': 2, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'auto', 'features': 0}
#             Current best combo (with val score 0.4338):
#                     {'C': 10, 'degree': 1, 'tol': 0.0001, 'max_iter': 200, 'gamma': 'auto', 'features': 0}
#         Has trained 4790 of 198288 combinations so far
# Already Trained and Tested combination (val score of 0.4338):
#             {'C': 10, 'degree': 1, 'tol': 0.001, 'max_iter': 400, 'gamma': 'auto', 'features': 0}
#             Current best combo (with val score 0.4338):
#                     {'C': 10, 'degree': 1, 'tol': 0.0001, 'max_iter': 200, 'gamma': 'auto', 'features': 0}
#         Has trained 4790 of 198288 combinations so far
# Already Trained and Tested combination (val score of 0.4338):
#             {'C': 10, 'degree': 1, 'tol': 0.0001, 'max_iter': 200, 'gamma': 'auto', 'features': 0}
#             Current best combo (with val score 0.4338):
#                     {'C': 10, 'degree': 1, 'tol': 0.0001, 'max_iter': 200, 'gamma': 'auto', 'features': 0}
#         Has trained 4790 of 198288 combinations so far
# Trained and Tested combination 4791 of 198288, taking 0.06 seconds to get val score of 0.4338:
#                 {'C': 10, 'degree': 1, 'tol': 0.0001, 'max_iter': 800, 'gamma': 'auto', 'features': 0},
#             Current best combo with val score 0.4338:
#                     {'C': 10, 'degree': 1, 'tol': 0.0001, 'max_iter': 200, 'gamma': 'auto', 'features': 0}
# Trained and Tested combination 4792 of 198288, taking 0.04 seconds to get val score of 0.3073:
#                 {'C': 10, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'scale', 'features': 0},
#             Current best combo with val score 0.4338:
#                     {'C': 10, 'degree': 1, 'tol': 0.0001, 'max_iter': 200, 'gamma': 'auto', 'features': 0}
# Trained and Tested combination 4793 of 198288, taking 0.04 seconds to get val score of 0.3931:
#                 {'C': 10, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'auto', 'features': 1},
#             Current best combo with val score 0.4338:
#                     {'C': 10, 'degree': 1, 'tol': 0.0001, 'max_iter': 200, 'gamma': 'auto', 'features': 0}
# % Combos Checked Thus Far: 4793 out of 198288 which is 2.4171910000000003%
# Max Val Score:
#  0.433759
# Max Val Score Std:
#  0.030599
# Best Combo Train Score:
#  0.433746
# Best Combo Train Score Std:
#  0.003337
# Max Combo Index:
#  (5, 0, 0, 2, 0, 0) out of [6, 9, 6, 6, 2, 51] (note best combo is 0-indexed)
# Max Combo Hyperparamer Combination:
#  {'C': 10, 'degree': 1, 'tol': 0.0001, 'max_iter': 200, 'gamma': 'auto', 'features': 0}
# Max Combo Features:
#  ('procedure_225792',)
# % Combos Checked: 4793 out of 198288 which is 2.4171910000000003%
