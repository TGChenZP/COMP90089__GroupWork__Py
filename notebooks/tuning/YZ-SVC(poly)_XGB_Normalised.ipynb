# %% [markdown]
# # Tuning Script

# %%
# Parameters subject to change in every script - involved in naming

MODEL = 'svc(poly)'
PREPROCESSING = 'normalise'
TUNER = 'yangzhoub'
OPTIMISED_METRIC = 'f1'

# %% [markdown]
# ---

# %%
# detect whether this is a google environment

COLAB_ENVIRONMENT = False

try:
    from google.colab import drive
    drive.mount('/content/drive')
    COLAB_ENVIRONMENT = True
except:
    pass
# Out:
# Mounted at /content/drive

# %%
import sys
import os
import pickle

if COLAB_ENVIRONMENT:
    home_directory = './drive/MyDrive/LAB/COMP90089__GroupWork__Py/' # my home directory is stored in ./LAB of google drive
    if MODEL == 'ebr':
        # !pip install interpret==0.5.0
    elif MODEL == 'cbr':
        # !pip install catboost
    elif MODEL in ['tf', 'mlp']:
        # !pip install PyTorch2Sklearn
    # !pip install JXAutoML
else:
    home_directory = '../../'

from JXAutoML.YangZhouB_10CV import YangZhouB_10CV as Tuner

import pandas as pd
# Out:
# Collecting JXAutoML
#   Downloading JXAutoML-0.4.4-py3-none-any.whl.metadata (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.2/67.2 kB 3.9 MB/s eta 0:00:00
# Downloading JXAutoML-0.4.4-py3-none-any.whl (52 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.1/52.1 kB 3.2 MB/s eta 0:00:00
# Installing collected packages: JXAutoML
# Successfully installed JXAutoML-0.4.4

# %%
# Parameters that are same for every script

FOLDS = 10  # we have decided to do 10 fold validation

SEED = 42

TASK_TYPE = 'Classification'  # this task is a classification task

# we have decided to tune features as hp
TUNE_FEATURES_AS_HYPERPARAMETERS = True

# %% [markdown]
# ---

# %%
# model to use to tune
from sklearn.svm import SVC as clf

# what values to try for each hyperparameter
parameter_choices = {
    'C': (0.0001, 0.001, 0.01, 0.1, 1, 10),
    'degree': list(range(1, 10)),
    'tol': (0.0001, 0.001, 0.01, 0.1, 1, 10),
    'max_iter': (50, 100, 200, 400, 800, 1600),
    'gamma': ('scale', 'auto')
}

# what values to set non-tuneable parameters/hyperparameters
non_tunable_hyperparameters_dict = {
                                    'verbose': False,
                                    'decision_function_shape': 'ovr',
                                    'random_state': 42,
                                    'kernel': 'poly'
                                    }

# %% [markdown]
# ---

# %% [markdown]
# Read in and Prepare Data

# %%
# Import data and store as lists

train_x_list = []
train_y_list = []
val_x_list = []
val_y_list = []

for i in range(FOLDS):
    train_data = pd.read_csv(
        f'{home_directory}data/curated/modelling/{PREPROCESSING}/train_{i}.csv')
    val_data = pd.read_csv(
        f'{home_directory}data/curated/modelling/{PREPROCESSING}/val_{i}.csv')

    # get the correct rows for X and y
    train_x = train_data.drop(
        ['mortality_status', 'subject_id', 'hadm_id', 'stay_id'], axis=1)
    train_y = train_data['mortality_status']
    val_x = val_data.drop(
        ['mortality_status', 'subject_id', 'hadm_id', 'stay_id'], axis=1)
    val_y = val_data['mortality_status']

    train_x_list.append(train_x)
    train_y_list.append(train_y)
    val_x_list.append(val_x)
    val_y_list.append(val_y)

# %%
# Import feature importance ordering

with open(f'{home_directory}models/xgb_feature_importance_ordering_{PREPROCESSING}.pickle', 'rb') as f:
    feature_importance_ordering = pickle.load(f)

# %% [markdown]
# Set parameters

# %%
# initialisation
tuner = Tuner()

print('---')

# define what model we are tuning
tuner.read_in_model(clf, TASK_TYPE, optimised_metric=OPTIMISED_METRIC)

print('---')

# read in the data for training and validation
tuner.read_in_data(train_x_list, train_y_list, val_x_list, val_y_list)

print('---')

# set what hp values to tune
tuner.set_hyperparameters(parameter_choices)
# WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

# set up hp values that need to be changed from default but NOT to be tuned
tuner.set_non_tuneable_hyperparameters(non_tunable_hyperparameters_dict)

print('---')

# set up feature importance ordering

if TUNE_FEATURES_AS_HYPERPARAMETERS:
    tuner.set_features(feature_importance_ordering)
    # WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

try:  # try to read in previous results to continue tuning ...
    tuner.read_in_tuning_result_df(
        f'{home_directory}models/tuning/{TUNER}_{MODEL}_{PREPROCESSING}.csv')
except:
    print('No previous tuning data read in')

print('---')

# set up where to save the tuning result csv
tuner.set_tuning_result_saving_address(
    f'{home_directory}models/tuning/{TUNER}_{MODEL}_{PREPROCESSING}.csv')

print('---')

# set up where to save the current best model
tuner.set_best_model_saving_address(
    f'{home_directory}models/tmp_models/{TUNER}_{MODEL}_{PREPROCESSING}')
# Out:
# YangZhouB Initialised
# ---
# Successfully read in model <class 'sklearn.svm._classes.SVC'>, which is a Classification model optimising for f1
# ---
# Read in Train X data list
# Read in Train y data list
# Read in Val X data list
# Read in Val y data list
# ---
# Successfully recorded hyperparameter choices
# ---
# Successfully recorded non_tuneable_hyperparameter choices
# ---
# Successfully recorded tuneable feature combination choices and updated relevant internal structures
# ---
# Successfully read in tuning result of 6215 rows, for 6215.0 combos
# ---
# Successfully set tuning output address
# ---
# Successfully set best model output address

# %%
# ignore warnings

import warnings
warnings.filterwarnings("ignore")

# %%
# begin tuning ... (or continue training)

tuner.tune()
# Out:
# Streaming output truncated to the last 5000 lines.
# Already Trained and Tested combination (val score of 0.3086):
#             {'C': 0.0001, 'degree': 6, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 21}
#             Current best combo (with val score 0.5222):
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16}
#         Has trained 9202 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'C': 0.0001, 'degree': 5, 'tol': 0.001, 'max_iter': 50, 'gamma': 'auto', 'features': 21}
#             Current best combo (with val score 0.5222):
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16}
#         Has trained 9202 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'C': 0.0001, 'degree': 5, 'tol': 0.0001, 'max_iter': 100, 'gamma': 'auto', 'features': 21}
#             Current best combo (with val score 0.5222):
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16}
#         Has trained 9202 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'C': 0.0001, 'degree': 5, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 21}
#             Current best combo (with val score 0.5222):
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16}
#         Has trained 9202 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'C': 0.0001, 'degree': 5, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 20}
#             Current best combo (with val score 0.5222):
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16}
#         Has trained 9202 of 279936 combinations so far
# Trained and Tested combination 9203 of 279936, taking 0.02 seconds to get val score of 0.3086:
#                 {'C': 0.0001, 'degree': 5, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 22},
#             Current best combo with val score 0.5222:
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16}
# % Combos Checked Thus Far: 9203 out of 279936 which is 3.287537%
# Cruising Coordrdinate 706 of 768
#
# Cruise suspended due to suspicious case
# Guidance: round 470
#
# 	round 470 iteration:  0
#
# Trained and Tested combination 9204 of 279936, taking 0.0 seconds to get val score of 0.3086:
#                 {'C': 0.001, 'degree': 5, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 20},
#             Current best combo with val score 0.5222:
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16}
# Trained and Tested combination 9205 of 279936, taking 0.0 seconds to get val score of 0.3086:
#                 {'C': 0.0001, 'degree': 4, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 20},
#             Current best combo with val score 0.5222:
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16}
# Trained and Tested combination 9206 of 279936, taking 0.0 seconds to get val score of 0.3086:
#                 {'C': 0.0001, 'degree': 6, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 20},
#             Current best combo with val score 0.5222:
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16}
# Trained and Tested combination 9207 of 279936, taking 0.13 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'degree': 5, 'tol': 1, 'max_iter': 1600, 'gamma': 'auto', 'features': 20},
#             Current best combo with val score 0.5222:
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16}
# Trained and Tested combination 9208 of 279936, taking 0.0 seconds to get val score of 0.3086:
#                 {'C': 0.0001, 'degree': 5, 'tol': 10, 'max_iter': 800, 'gamma': 'auto', 'features': 20},
#             Current best combo with val score 0.5222:
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16}
# Already Trained and Tested combination (val score of 0.3086):
#             {'C': 0.0001, 'degree': 5, 'tol': 10, 'max_iter': 1600, 'gamma': 'scale', 'features': 20}
#             Current best combo (with val score 0.5222):
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16}
#         Has trained 9208 of 279936 combinations so far
# Trained and Tested combination 9209 of 279936, taking 0.0 seconds to get val score of 0.3086:
#                 {'C': 0.0001, 'degree': 5, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 19},
#             Current best combo with val score 0.5222:
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16}
# Trained and Tested combination 9210 of 279936, taking 0.0 seconds to get val score of 0.3086:
#                 {'C': 0.0001, 'degree': 5, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 21},
#             Current best combo with val score 0.5222:
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16}
# 	round 470 iteration:  1
#
# Already Trained and Tested combination (val score of 0.3086):
#             {'C': 0.0001, 'degree': 5, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 20}
#             Current best combo (with val score 0.5222):
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16}
#         Has trained 9210 of 279936 combinations so far
# Trained and Tested combination 9211 of 279936, taking 0.01 seconds to get val score of 0.3086:
#                 {'C': 0.01, 'degree': 5, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 20},
#             Current best combo with val score 0.5222:
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16}
# Trained and Tested combination 9212 of 279936, taking 0.01 seconds to get val score of 0.3086:
#                 {'C': 0.001, 'degree': 4, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 20},
#             Current best combo with val score 0.5222:
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16}
# Trained and Tested combination 9213 of 279936, taking 0.0 seconds to get val score of 0.3086:
#                 {'C': 0.001, 'degree': 6, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 20},
#             Current best combo with val score 0.5222:
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16}
# Trained and Tested combination 9214 of 279936, taking 0.13 seconds to get val score of 0.0:
#                 {'C': 0.001, 'degree': 5, 'tol': 1, 'max_iter': 1600, 'gamma': 'auto', 'features': 20},
#             Current best combo with val score 0.5222:
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16}
# Trained and Tested combination 9215 of 279936, taking 0.0 seconds to get val score of 0.3086:
#                 {'C': 0.001, 'degree': 5, 'tol': 10, 'max_iter': 800, 'gamma': 'auto', 'features': 20},
#             Current best combo with val score 0.5222:
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16}
# Trained and Tested combination 9216 of 279936, taking 0.01 seconds to get val score of 0.3086:
#                 {'C': 0.001, 'degree': 5, 'tol': 10, 'max_iter': 1600, 'gamma': 'scale', 'features': 20},
#             Current best combo with val score 0.5222:
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16}
# Trained and Tested combination 9217 of 279936, taking 0.01 seconds to get val score of 0.3086:
#                 {'C': 0.001, 'degree': 5, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 19},
#             Current best combo with val score 0.5222:
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16}
# Trained and Tested combination 9218 of 279936, taking 0.0 seconds to get val score of 0.3086:
#                 {'C': 0.001, 'degree': 5, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 21},
#             Current best combo with val score 0.5222:
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16}
# Already Trained and Tested combination (val score of 0.3086):
#             {'C': 0.001, 'degree': 4, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 20}
#             Current best combo (with val score 0.5222):
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16}
#         Has trained 9218 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'C': 0.0001, 'degree': 3, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 20}
#             Current best combo (with val score 0.5222):
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16}
#         Has trained 9218 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'C': 0.0001, 'degree': 5, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 20}
#             Current best combo (with val score 0.5222):
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16}
#         Has trained 9218 of 279936 combinations so far
# Trained and Tested combination 9219 of 279936, taking 0.13 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'degree': 4, 'tol': 1, 'max_iter': 1600, 'gamma': 'auto', 'features': 20},
#             Current best combo with val score 0.5222:
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16}
# Trained and Tested combination 9220 of 279936, taking 0.0 seconds to get val score of 0.3086:
#                 {'C': 0.0001, 'degree': 4, 'tol': 10, 'max_iter': 800, 'gamma': 'auto', 'features': 20},
#             Current best combo with val score 0.5222:
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16}
# Trained and Tested combination 9221 of 279936, taking 0.01 seconds to get val score of 0.3086:
#                 {'C': 0.0001, 'degree': 4, 'tol': 10, 'max_iter': 1600, 'gamma': 'scale', 'features': 20},
#             Current best combo with val score 0.5222:
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16}
# Trained and Tested combination 9222 of 279936, taking 0.0 seconds to get val score of 0.3086:
#                 {'C': 0.0001, 'degree': 4, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 19},
#             Current best combo with val score 0.5222:
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16}
# Trained and Tested combination 9223 of 279936, taking 0.0 seconds to get val score of 0.3086:
#                 {'C': 0.0001, 'degree': 4, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 21},
#             Current best combo with val score 0.5222:
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16}
# Already Trained and Tested combination (val score of 0.3086):
#             {'C': 0.001, 'degree': 6, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 20}
#             Current best combo (with val score 0.5222):
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16}
#         Has trained 9223 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'C': 0.0001, 'degree': 5, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 20}
#             Current best combo (with val score 0.5222):
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16}
#         Has trained 9223 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'C': 0.0001, 'degree': 7, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 20}
#             Current best combo (with val score 0.5222):
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16}
#         Has trained 9223 of 279936 combinations so far
# Trained and Tested combination 9224 of 279936, taking 0.13 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'degree': 6, 'tol': 1, 'max_iter': 1600, 'gamma': 'auto', 'features': 20},
#             Current best combo with val score 0.5222:
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16}
# Trained and Tested combination 9225 of 279936, taking 0.01 seconds to get val score of 0.3086:
#                 {'C': 0.0001, 'degree': 6, 'tol': 10, 'max_iter': 800, 'gamma': 'auto', 'features': 20},
#             Current best combo with val score 0.5222:
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16}
# Trained and Tested combination 9226 of 279936, taking 0.01 seconds to get val score of 0.3086:
#                 {'C': 0.0001, 'degree': 6, 'tol': 10, 'max_iter': 1600, 'gamma': 'scale', 'features': 20},
#             Current best combo with val score 0.5222:
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16}
# Trained and Tested combination 9227 of 279936, taking 0.0 seconds to get val score of 0.3086:
#                 {'C': 0.0001, 'degree': 6, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 19},
#             Current best combo with val score 0.5222:
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16}
# Trained and Tested combination 9228 of 279936, taking 0.0 seconds to get val score of 0.3086:
#                 {'C': 0.0001, 'degree': 6, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 21},
#             Current best combo with val score 0.5222:
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16}
# Already Trained and Tested combination (val score of 0.3086):
#             {'C': 0.001, 'degree': 5, 'tol': 10, 'max_iter': 800, 'gamma': 'auto', 'features': 20}
#             Current best combo (with val score 0.5222):
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16}
#         Has trained 9228 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'C': 0.0001, 'degree': 4, 'tol': 10, 'max_iter': 800, 'gamma': 'auto', 'features': 20}
#             Current best combo (with val score 0.5222):
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16}
#         Has trained 9228 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'C': 0.0001, 'degree': 6, 'tol': 10, 'max_iter': 800, 'gamma': 'auto', 'features': 20}
#             Current best combo (with val score 0.5222):
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16}
#         Has trained 9228 of 279936 combinations so far
# Trained and Tested combination 9229 of 279936, taking 0.13 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'degree': 5, 'tol': 1, 'max_iter': 800, 'gamma': 'auto', 'features': 20},
#             Current best combo with val score 0.5222:
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16}
# Trained and Tested combination 9230 of 279936, taking 0.01 seconds to get val score of 0.3086:
#                 {'C': 0.0001, 'degree': 5, 'tol': 10, 'max_iter': 400, 'gamma': 'auto', 'features': 20},
#             Current best combo with val score 0.5222:
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16}
# Already Trained and Tested combination (val score of 0.3086):
#             {'C': 0.0001, 'degree': 5, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 20}
#             Current best combo (with val score 0.5222):
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16}
#         Has trained 9230 of 279936 combinations so far
# Trained and Tested combination 9231 of 279936, taking 0.0 seconds to get val score of 0.3086:
#                 {'C': 0.0001, 'degree': 5, 'tol': 10, 'max_iter': 800, 'gamma': 'scale', 'features': 20},
#             Current best combo with val score 0.5222:
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16}
# Trained and Tested combination 9232 of 279936, taking 0.0 seconds to get val score of 0.3086:
#                 {'C': 0.0001, 'degree': 5, 'tol': 10, 'max_iter': 800, 'gamma': 'auto', 'features': 19},
#             Current best combo with val score 0.5222:
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16}
# Trained and Tested combination 9233 of 279936, taking 0.0 seconds to get val score of 0.3086:
#                 {'C': 0.0001, 'degree': 5, 'tol': 10, 'max_iter': 800, 'gamma': 'auto', 'features': 21},
#             Current best combo with val score 0.5222:
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16}
# Already Trained and Tested combination (val score of 0.3086):
#             {'C': 0.001, 'degree': 5, 'tol': 10, 'max_iter': 1600, 'gamma': 'scale', 'features': 20}
#             Current best combo (with val score 0.5222):
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16}
#         Has trained 9233 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'C': 0.0001, 'degree': 4, 'tol': 10, 'max_iter': 1600, 'gamma': 'scale', 'features': 20}
#             Current best combo (with val score 0.5222):
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16}
#         Has trained 9233 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'C': 0.0001, 'degree': 6, 'tol': 10, 'max_iter': 1600, 'gamma': 'scale', 'features': 20}
#             Current best combo (with val score 0.5222):
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16}
#         Has trained 9233 of 279936 combinations so far
# Trained and Tested combination 9234 of 279936, taking 0.13 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'degree': 5, 'tol': 1, 'max_iter': 1600, 'gamma': 'scale', 'features': 20},
#             Current best combo with val score 0.5222:
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16}
# Already Trained and Tested combination (val score of 0.3086):
#             {'C': 0.0001, 'degree': 5, 'tol': 10, 'max_iter': 800, 'gamma': 'scale', 'features': 20}
#             Current best combo (with val score 0.5222):
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16}
#         Has trained 9234 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'C': 0.0001, 'degree': 5, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 20}
#             Current best combo (with val score 0.5222):
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16}
#         Has trained 9234 of 279936 combinations so far
# Trained and Tested combination 9235 of 279936, taking 0.01 seconds to get val score of 0.3086:
#                 {'C': 0.0001, 'degree': 5, 'tol': 10, 'max_iter': 1600, 'gamma': 'scale', 'features': 19},
#             Current best combo with val score 0.5222:
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16}
# Trained and Tested combination 9236 of 279936, taking 0.0 seconds to get val score of 0.3086:
#                 {'C': 0.0001, 'degree': 5, 'tol': 10, 'max_iter': 1600, 'gamma': 'scale', 'features': 21},
#             Current best combo with val score 0.5222:
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16}
# Already Trained and Tested combination (val score of 0.3086):
#             {'C': 0.001, 'degree': 5, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 19}
#             Current best combo (with val score 0.5222):
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16}
#         Has trained 9236 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'C': 0.0001, 'degree': 4, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 19}
#             Current best combo (with val score 0.5222):
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16}
#         Has trained 9236 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'C': 0.0001, 'degree': 6, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 19}
#             Current best combo (with val score 0.5222):
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16}
#         Has trained 9236 of 279936 combinations so far
# Trained and Tested combination 9237 of 279936, taking 0.14 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'degree': 5, 'tol': 1, 'max_iter': 1600, 'gamma': 'auto', 'features': 19},
#             Current best combo with val score 0.5222:
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16}
# Already Trained and Tested combination (val score of 0.3086):
#             {'C': 0.0001, 'degree': 5, 'tol': 10, 'max_iter': 800, 'gamma': 'auto', 'features': 19}
#             Current best combo (with val score 0.5222):
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16}
#         Has trained 9237 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'C': 0.0001, 'degree': 5, 'tol': 10, 'max_iter': 1600, 'gamma': 'scale', 'features': 19}
#             Current best combo (with val score 0.5222):
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16}
#         Has trained 9237 of 279936 combinations so far
# Trained and Tested combination 9238 of 279936, taking 0.0 seconds to get val score of 0.3086:
#                 {'C': 0.0001, 'degree': 5, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 18},
#             Current best combo with val score 0.5222:
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16}
# Already Trained and Tested combination (val score of 0.3086):
#             {'C': 0.0001, 'degree': 5, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 20}
#             Current best combo (with val score 0.5222):
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16}
#         Has trained 9238 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'C': 0.001, 'degree': 5, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 21}
#             Current best combo (with val score 0.5222):
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16}
#         Has trained 9238 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'C': 0.0001, 'degree': 4, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 21}
#             Current best combo (with val score 0.5222):
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16}
#         Has trained 9238 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'C': 0.0001, 'degree': 6, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 21}
#             Current best combo (with val score 0.5222):
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16}
#         Has trained 9238 of 279936 combinations so far
# Trained and Tested combination 9239 of 279936, taking 0.2 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'degree': 5, 'tol': 1, 'max_iter': 1600, 'gamma': 'auto', 'features': 21},
#             Current best combo with val score 0.5222:
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16}
# Already Trained and Tested combination (val score of 0.3086):
#             {'C': 0.0001, 'degree': 5, 'tol': 10, 'max_iter': 800, 'gamma': 'auto', 'features': 21}
#             Current best combo (with val score 0.5222):
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16}
#         Has trained 9239 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'C': 0.0001, 'degree': 5, 'tol': 10, 'max_iter': 1600, 'gamma': 'scale', 'features': 21}
#             Current best combo (with val score 0.5222):
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16}
#         Has trained 9239 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.3086):
#             {'C': 0.0001, 'degree': 5, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 20}
#             Current best combo (with val score 0.5222):
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16}
#         Has trained 9239 of 279936 combinations so far
# Trained and Tested combination 9240 of 279936, taking 0.0 seconds to get val score of 0.3086:
#                 {'C': 0.0001, 'degree': 5, 'tol': 10, 'max_iter': 1600, 'gamma': 'auto', 'features': 22},
#             Current best combo with val score 0.5222:
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16}
# % Combos Checked Thus Far: 9240 out of 279936 which is 3.3007540000000004%
# Cruising Coordrdinate 707 of 768
#
# Cruise suspended due to suspicious case
# Guidance: round 471
#
# 	round 471 iteration:  0
#
# % Combos Checked Thus Far: 9240 out of 279936 which is 3.3007540000000004%
# Cruising Coordrdinate 708 of 768
#
# Cruise suspended due to suspicious case
# Guidance: round 472
#
# 	round 472 iteration:  0
#
# % Combos Checked Thus Far: 9240 out of 279936 which is 3.3007540000000004%
# Cruising Coordrdinate 709 of 768
#
# Cruising Coordrdinate 710 of 768
#
# Cruise suspended due to suspicious case
# Guidance: round 473
#
# 	round 473 iteration:  0
#
# % Combos Checked Thus Far: 9240 out of 279936 which is 3.3007540000000004%
# Cruising Coordrdinate 711 of 768
#
# Cruise suspended due to suspicious case
# Guidance: round 474
#
# 	round 474 iteration:  0
#
# % Combos Checked Thus Far: 9240 out of 279936 which is 3.3007540000000004%
# Cruising Coordrdinate 712 of 768
#
# Cruise suspended due to suspicious case
# Guidance: round 475
#
# 	round 475 iteration:  0
#
# % Combos Checked Thus Far: 9240 out of 279936 which is 3.3007540000000004%
# Cruising Coordrdinate 713 of 768
#
# Cruise suspended due to suspicious case
# Guidance: round 476
#
# 	round 476 iteration:  0
#
# % Combos Checked Thus Far: 9240 out of 279936 which is 3.3007540000000004%
# Cruising Coordrdinate 714 of 768
#
# Cruise suspended due to suspicious case
# Guidance: round 477
#
# 	round 477 iteration:  0
#
# % Combos Checked Thus Far: 9240 out of 279936 which is 3.3007540000000004%
# Cruising Coordrdinate 715 of 768
#
# Cruise suspended due to suspicious case
# Guidance: round 478
#
# 	round 478 iteration:  0
#
# Trained and Tested combination 9241 of 279936, taking 0.1 seconds to get val score of 0.3469:
#                 {'C': 1, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 10},
#             Current best combo with val score 0.5222:
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16}
# Trained and Tested combination 9242 of 279936, taking 0.11 seconds to get val score of 0.4233:
#                 {'C': 10, 'degree': 2, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 10},
#             Current best combo with val score 0.5222:
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16}
# Trained and Tested combination 9243 of 279936, taking 0.13 seconds to get val score of 0.4121:
#                 {'C': 10, 'degree': 1, 'tol': 0.001, 'max_iter': 1600, 'gamma': 'auto', 'features': 10},
#             Current best combo with val score 0.5222:
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16}
# Trained and Tested combination 9244 of 279936, taking 0.09 seconds to get val score of 0.3733:
#                 {'C': 10, 'degree': 1, 'tol': 0.0001, 'max_iter': 800, 'gamma': 'auto', 'features': 10},
#             Current best combo with val score 0.5222:
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16}
# Already Trained and Tested combination (val score of 0.3784):
#             {'C': 10, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
#             Current best combo (with val score 0.5222):
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16}
#         Has trained 9244 of 279936 combinations so far
# Trained and Tested combination 9245 of 279936, taking 0.11 seconds to get val score of 0.3755:
#                 {'C': 10, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 9},
#             Current best combo with val score 0.5222:
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16}
# Trained and Tested combination 9246 of 279936, taking 0.13 seconds to get val score of 0.4237:
#                 {'C': 10, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 11},
#             Current best combo with val score 0.5222:
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16}
# 	round 478 iteration:  1
#
# Trained and Tested combination 9247 of 279936, taking 0.09 seconds to get val score of 0.4047:
#                 {'C': 1, 'degree': 2, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 10},
#             Current best combo with val score 0.5222:
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16}
# Already Trained and Tested combination (val score of 0.4121):
#             {'C': 10, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 10}
#             Current best combo (with val score 0.5222):
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16}
#         Has trained 9247 of 279936 combinations so far
# Trained and Tested combination 9248 of 279936, taking 0.1 seconds to get val score of 0.4182:
#                 {'C': 10, 'degree': 3, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 10},
#             Current best combo with val score 0.5222:
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16}
# Trained and Tested combination 9249 of 279936, taking 0.19 seconds to get val score of 0.4233:
#                 {'C': 10, 'degree': 2, 'tol': 0.001, 'max_iter': 1600, 'gamma': 'auto', 'features': 10},
#             Current best combo with val score 0.5222:
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16}
# Trained and Tested combination 9250 of 279936, taking 0.09 seconds to get val score of 0.4726:
#                 {'C': 10, 'degree': 2, 'tol': 0.0001, 'max_iter': 800, 'gamma': 'auto', 'features': 10},
#             Current best combo with val score 0.5222:
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16}
# Trained and Tested combination 9251 of 279936, taking 0.1 seconds to get val score of 0.4548:
#                 {'C': 10, 'degree': 2, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10},
#             Current best combo with val score 0.5222:
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16}
# Trained and Tested combination 9252 of 279936, taking 0.18 seconds to get val score of 0.4224:
#                 {'C': 10, 'degree': 2, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 9},
#             Current best combo with val score 0.5222:
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16}
# Trained and Tested combination 9253 of 279936, taking 0.11 seconds to get val score of 0.4215:
#                 {'C': 10, 'degree': 2, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 11},
#             Current best combo with val score 0.5222:
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16}
# Trained and Tested combination 9254 of 279936, taking 0.1 seconds to get val score of 0.3465:
#                 {'C': 1, 'degree': 1, 'tol': 0.001, 'max_iter': 1600, 'gamma': 'auto', 'features': 10},
#             Current best combo with val score 0.5222:
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16}
# Already Trained and Tested combination (val score of 0.4233):
#             {'C': 10, 'degree': 2, 'tol': 0.001, 'max_iter': 1600, 'gamma': 'auto', 'features': 10}
#             Current best combo (with val score 0.5222):
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16}
#         Has trained 9254 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.4121):
#             {'C': 10, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 10}
#             Current best combo (with val score 0.5222):
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16}
#         Has trained 9254 of 279936 combinations so far
# Trained and Tested combination 9255 of 279936, taking 0.18 seconds to get val score of 0.4121:
#                 {'C': 10, 'degree': 1, 'tol': 0.01, 'max_iter': 1600, 'gamma': 'auto', 'features': 10},
#             Current best combo with val score 0.5222:
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16}
# Trained and Tested combination 9256 of 279936, taking 0.09 seconds to get val score of 0.3733:
#                 {'C': 10, 'degree': 1, 'tol': 0.001, 'max_iter': 800, 'gamma': 'auto', 'features': 10},
#             Current best combo with val score 0.5222:
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16}
# Trained and Tested combination 9257 of 279936, taking 0.11 seconds to get val score of 0.3784:
#                 {'C': 10, 'degree': 1, 'tol': 0.001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10},
#             Current best combo with val score 0.5222:
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16}
# Trained and Tested combination 9258 of 279936, taking 0.12 seconds to get val score of 0.3852:
#                 {'C': 10, 'degree': 1, 'tol': 0.001, 'max_iter': 1600, 'gamma': 'auto', 'features': 9},
#             Current best combo with val score 0.5222:
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16}
# Trained and Tested combination 9259 of 279936, taking 0.12 seconds to get val score of 0.4237:
#                 {'C': 10, 'degree': 1, 'tol': 0.001, 'max_iter': 1600, 'gamma': 'auto', 'features': 11},
#             Current best combo with val score 0.5222:
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16}
# Trained and Tested combination 9260 of 279936, taking 0.12 seconds to get val score of 0.3411:
#                 {'C': 1, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 11},
#             Current best combo with val score 0.5222:
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16}
# Already Trained and Tested combination (val score of 0.4215):
#             {'C': 10, 'degree': 2, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 11}
#             Current best combo (with val score 0.5222):
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16}
#         Has trained 9260 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.4237):
#             {'C': 10, 'degree': 1, 'tol': 0.001, 'max_iter': 1600, 'gamma': 'auto', 'features': 11}
#             Current best combo (with val score 0.5222):
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16}
#         Has trained 9260 of 279936 combinations so far
# Trained and Tested combination 9261 of 279936, taking 0.1 seconds to get val score of 0.4319:
#                 {'C': 10, 'degree': 1, 'tol': 0.0001, 'max_iter': 800, 'gamma': 'auto', 'features': 11},
#             Current best combo with val score 0.5222:
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16}
# Trained and Tested combination 9262 of 279936, taking 0.11 seconds to get val score of 0.3447:
#                 {'C': 10, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 11},
#             Current best combo with val score 0.5222:
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16}
# Already Trained and Tested combination (val score of 0.4121):
#             {'C': 10, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 10}
#             Current best combo (with val score 0.5222):
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16}
#         Has trained 9262 of 279936 combinations so far
# Trained and Tested combination 9263 of 279936, taking 0.12 seconds to get val score of 0.4153:
#                 {'C': 10, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 12},
#             Current best combo with val score 0.5222:
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16}
# % Combos Checked Thus Far: 9263 out of 279936 which is 3.308971%
# Cruising Coordrdinate 716 of 768
#
# Cruising Coordrdinate 717 of 768
#
# Cruising Coordrdinate 718 of 768
#
# Cruise suspended due to suspicious case
# Guidance: round 479
#
# 	round 479 iteration:  0
#
# Trained and Tested combination 9264 of 279936, taking 0.11 seconds to get val score of 0.3974:
#                 {'C': 1, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10},
#             Current best combo with val score 0.5222:
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16}
# Already Trained and Tested combination (val score of 0.4548):
#             {'C': 10, 'degree': 2, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
#             Current best combo (with val score 0.5222):
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16}
#         Has trained 9264 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.3784):
#             {'C': 10, 'degree': 1, 'tol': 0.001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
#             Current best combo (with val score 0.5222):
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16}
#         Has trained 9264 of 279936 combinations so far
# Trained and Tested combination 9265 of 279936, taking 0.14 seconds to get val score of 0.4023:
#                 {'C': 10, 'degree': 1, 'tol': 0.0001, 'max_iter': 800, 'gamma': 'scale', 'features': 10},
#             Current best combo with val score 0.5222:
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16}
# Already Trained and Tested combination (val score of 0.4121):
#             {'C': 10, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 10}
#             Current best combo (with val score 0.5222):
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16}
#         Has trained 9265 of 279936 combinations so far
# Trained and Tested combination 9266 of 279936, taking 0.12 seconds to get val score of 0.3715:
#                 {'C': 10, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 9},
#             Current best combo with val score 0.5222:
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16}
# Already Trained and Tested combination (val score of 0.3447):
#             {'C': 10, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 11}
#             Current best combo (with val score 0.5222):
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16}
#         Has trained 9266 of 279936 combinations so far
# 	round 479 iteration:  1
#
# Trained and Tested combination 9267 of 279936, taking 0.1 seconds to get val score of 0.2984:
#                 {'C': 0.1, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10},
#             Current best combo with val score 0.5222:
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16}
# Already Trained and Tested combination (val score of 0.3784):
#             {'C': 10, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
#             Current best combo (with val score 0.5222):
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16}
#         Has trained 9267 of 279936 combinations so far
# Trained and Tested combination 9268 of 279936, taking 0.18 seconds to get val score of 0.4196:
#                 {'C': 1, 'degree': 2, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10},
#             Current best combo with val score 0.5222:
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16}
# Trained and Tested combination 9269 of 279936, taking 0.11 seconds to get val score of 0.3974:
#                 {'C': 1, 'degree': 1, 'tol': 0.001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10},
#             Current best combo with val score 0.5222:
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16}
# Trained and Tested combination 9270 of 279936, taking 0.1 seconds to get val score of 0.4076:
#                 {'C': 1, 'degree': 1, 'tol': 0.0001, 'max_iter': 800, 'gamma': 'scale', 'features': 10},
#             Current best combo with val score 0.5222:
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16}
# Already Trained and Tested combination (val score of 0.3469):
#             {'C': 1, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 10}
#             Current best combo (with val score 0.5222):
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16}
#         Has trained 9270 of 279936 combinations so far
# Trained and Tested combination 9271 of 279936, taking 0.18 seconds to get val score of 0.3773:
#                 {'C': 1, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 9},
#             Current best combo with val score 0.5222:
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16}
# Trained and Tested combination 9272 of 279936, taking 0.11 seconds to get val score of 0.396:
#                 {'C': 1, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 11},
#             Current best combo with val score 0.5222:
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16}
# Already Trained and Tested combination (val score of 0.3974):
#             {'C': 1, 'degree': 1, 'tol': 0.001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
#             Current best combo (with val score 0.5222):
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16}
#         Has trained 9272 of 279936 combinations so far
# Trained and Tested combination 9273 of 279936, taking 0.1 seconds to get val score of 0.4548:
#                 {'C': 10, 'degree': 2, 'tol': 0.001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10},
#             Current best combo with val score 0.5222:
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16}
# Already Trained and Tested combination (val score of 0.3784):
#             {'C': 10, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 10}
#             Current best combo (with val score 0.5222):
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16}
#         Has trained 9273 of 279936 combinations so far
# Trained and Tested combination 9274 of 279936, taking 0.18 seconds to get val score of 0.3784:
#                 {'C': 10, 'degree': 1, 'tol': 0.01, 'max_iter': 1600, 'gamma': 'scale', 'features': 10},
#             Current best combo with val score 0.5222:
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16}
# Trained and Tested combination 9275 of 279936, taking 0.08 seconds to get val score of 0.4023:
#                 {'C': 10, 'degree': 1, 'tol': 0.001, 'max_iter': 800, 'gamma': 'scale', 'features': 10},
#             Current best combo with val score 0.5222:
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16}
# Already Trained and Tested combination (val score of 0.4121):
#             {'C': 10, 'degree': 1, 'tol': 0.001, 'max_iter': 1600, 'gamma': 'auto', 'features': 10}
# ...
# Trained and Tested combination 9777 of 279936, taking 0.12 seconds to get val score of 0.1401:
#                 {'C': 10, 'degree': 4, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 15},
#             Current best combo with val score 0.5222:
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16}
# Trained and Tested combination 9778 of 279936, taking 0.14 seconds to get val score of 0.4618:
#                 {'C': 10, 'degree': 4, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 14},
#             Current best combo with val score 0.5222:
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16}
# Trained and Tested combination 9779 of 279936, taking 0.19 seconds to get val score of 0.4604:
#                 {'C': 10, 'degree': 4, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16},
#             Current best combo with val score 0.5222:
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16}
# Already Trained and Tested combination (val score of 0.5183):
#             {'C': 1, 'degree': 5, 'tol': 0.001, 'max_iter': 1600, 'gamma': 'scale', 'features': 15}
#             Current best combo (with val score 0.5222):
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16}
#         Has trained 9779 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.4639):
#             {'C': 10, 'degree': 4, 'tol': 0.001, 'max_iter': 1600, 'gamma': 'scale', 'features': 15}
#             Current best combo (with val score 0.5222):
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16}
#         Has trained 9779 of 279936 combinations so far
# Trained and Tested combination 9780 of 279936, taking 0.11 seconds to get val score of 0.3762:
#                 {'C': 10, 'degree': 6, 'tol': 0.001, 'max_iter': 1600, 'gamma': 'scale', 'features': 15},
#             Current best combo with val score 0.5222:
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16}
# Already Trained and Tested combination (val score of 0.4214):
#             {'C': 10, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 15}
#             Current best combo (with val score 0.5222):
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16}
#         Has trained 9780 of 279936 combinations so far
# Trained and Tested combination 9781 of 279936, taking 0.11 seconds to get val score of 0.4214:
#                 {'C': 10, 'degree': 5, 'tol': 0.01, 'max_iter': 1600, 'gamma': 'scale', 'features': 15},
#             Current best combo with val score 0.5222:
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16}
# Trained and Tested combination 9782 of 279936, taking 0.14 seconds to get val score of 0.3525:
#                 {'C': 10, 'degree': 5, 'tol': 0.001, 'max_iter': 800, 'gamma': 'scale', 'features': 15},
#             Current best combo with val score 0.5222:
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16}
# Trained and Tested combination 9783 of 279936, taking 0.14 seconds to get val score of 0.0:
#                 {'C': 10, 'degree': 5, 'tol': 0.001, 'max_iter': 1600, 'gamma': 'auto', 'features': 15},
#             Current best combo with val score 0.5222:
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16}
# Trained and Tested combination 9784 of 279936, taking 0.1 seconds to get val score of 0.4157:
#                 {'C': 10, 'degree': 5, 'tol': 0.001, 'max_iter': 1600, 'gamma': 'scale', 'features': 14},
#             Current best combo with val score 0.5222:
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16}
# Trained and Tested combination 9785 of 279936, taking 0.18 seconds to get val score of 0.4321:
#                 {'C': 10, 'degree': 5, 'tol': 0.001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16},
#             Current best combo with val score 0.5222:
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16}
# Already Trained and Tested combination (val score of 0.5222):
#             {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16}
#             Current best combo (with val score 0.5222):
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16}
#         Has trained 9785 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.4604):
#             {'C': 10, 'degree': 4, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16}
#             Current best combo (with val score 0.5222):
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16}
#         Has trained 9785 of 279936 combinations so far
# Trained and Tested combination 9786 of 279936, taking 0.11 seconds to get val score of 0.3501:
#                 {'C': 10, 'degree': 6, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16},
#             Current best combo with val score 0.5222:
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16}
# Already Trained and Tested combination (val score of 0.4321):
#             {'C': 10, 'degree': 5, 'tol': 0.001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16}
#             Current best combo (with val score 0.5222):
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16}
#         Has trained 9786 of 279936 combinations so far
# Trained and Tested combination 9787 of 279936, taking 0.08 seconds to get val score of 0.3644:
#                 {'C': 10, 'degree': 5, 'tol': 0.0001, 'max_iter': 800, 'gamma': 'scale', 'features': 16},
#             Current best combo with val score 0.5222:
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16}
# Trained and Tested combination 9788 of 279936, taking 0.23 seconds to get val score of 0.0:
#                 {'C': 10, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 16},
#             Current best combo with val score 0.5222:
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16}
# Already Trained and Tested combination (val score of 0.4214):
#             {'C': 10, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 15}
#             Current best combo (with val score 0.5222):
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16}
#         Has trained 9788 of 279936 combinations so far
# Trained and Tested combination 9789 of 279936, taking 0.12 seconds to get val score of 0.0312:
#                 {'C': 10, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 17},
#             Current best combo with val score 0.5222:
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16}
# % Combos Checked Thus Far: 9789 out of 279936 which is 3.496871%
# FINAL STAGE: Begin final Guidance system
#
#
# Guidance: round FINAL
#
# 	round FINAL iteration:  0
#
# Already Trained and Tested combination (val score of 0.3597):
#             {'C': 0.1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16}
#             Current best combo (with val score 0.5222):
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16}
#         Has trained 9789 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.4321):
#             {'C': 10, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16}
#             Current best combo (with val score 0.5222):
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16}
#         Has trained 9789 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.5051):
#             {'C': 1, 'degree': 4, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16}
#             Current best combo (with val score 0.5222):
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16}
#         Has trained 9789 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.3868):
#             {'C': 1, 'degree': 6, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16}
#             Current best combo (with val score 0.5222):
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16}
#         Has trained 9789 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.5222):
#             {'C': 1, 'degree': 5, 'tol': 0.001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16}
#             Current best combo (with val score 0.5222):
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16}
#         Has trained 9789 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.4099):
#             {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 800, 'gamma': 'scale', 'features': 16}
#             Current best combo (with val score 0.5222):
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16}
#         Has trained 9789 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 16}
#             Current best combo (with val score 0.5222):
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16}
#         Has trained 9789 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.5183):
#             {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 15}
#             Current best combo (with val score 0.5222):
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16}
#         Has trained 9789 of 279936 combinations so far
# Already Trained and Tested combination (val score of 0.2029):
#             {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 17}
#             Current best combo (with val score 0.5222):
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16}
#         Has trained 9789 of 279936 combinations so far
# 	round FINAL iteration:  1
#
# Trained and Tested combination 9790 of 279936, taking 0.13 seconds to get val score of 0.3597:
#                 {'C': 0.1, 'degree': 5, 'tol': 0.001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16},
#             Current best combo with val score 0.5222:
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16}
# Already Trained and Tested combination (val score of 0.4321):
#             {'C': 10, 'degree': 5, 'tol': 0.001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16}
#             Current best combo (with val score 0.5222):
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16}
#         Has trained 9790 of 279936 combinations so far
# Trained and Tested combination 9791 of 279936, taking 0.2 seconds to get val score of 0.5051:
#                 {'C': 1, 'degree': 4, 'tol': 0.001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16},
#             Current best combo with val score 0.5222:
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16}
# Trained and Tested combination 9792 of 279936, taking 0.11 seconds to get val score of 0.3868:
#                 {'C': 1, 'degree': 6, 'tol': 0.001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16},
#             Current best combo with val score 0.5222:
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16}
# Already Trained and Tested combination (val score of 0.5222):
#             {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16}
#             Current best combo (with val score 0.5222):
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16}
#         Has trained 9792 of 279936 combinations so far
# Trained and Tested combination 9793 of 279936, taking 0.12 seconds to get val score of 0.5222:
#                 {'C': 1, 'degree': 5, 'tol': 0.01, 'max_iter': 1600, 'gamma': 'scale', 'features': 16},
#             Current best combo with val score 0.5222:
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16}
# Trained and Tested combination 9794 of 279936, taking 0.17 seconds to get val score of 0.4099:
#                 {'C': 1, 'degree': 5, 'tol': 0.001, 'max_iter': 800, 'gamma': 'scale', 'features': 16},
#             Current best combo with val score 0.5222:
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16}
# Trained and Tested combination 9795 of 279936, taking 0.14 seconds to get val score of 0.0:
#                 {'C': 1, 'degree': 5, 'tol': 0.001, 'max_iter': 1600, 'gamma': 'auto', 'features': 16},
#             Current best combo with val score 0.5222:
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16}
# Already Trained and Tested combination (val score of 0.5183):
#             {'C': 1, 'degree': 5, 'tol': 0.001, 'max_iter': 1600, 'gamma': 'scale', 'features': 15}
#             Current best combo (with val score 0.5222):
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16}
#         Has trained 9795 of 279936 combinations so far
# Trained and Tested combination 9796 of 279936, taking 0.13 seconds to get val score of 0.2029:
#                 {'C': 1, 'degree': 5, 'tol': 0.001, 'max_iter': 1600, 'gamma': 'scale', 'features': 17},
#             Current best combo with val score 0.5222:
#                     {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16}
# % Combos Checked Thus Far: 9796 out of 279936 which is 3.4993709999999996%
# Max Val Score:
#  0.52215
# Max Val Score Std:
#  0.034173
# Best Combo Train Score:
#  0.770932
# Best Combo Train Score Std:
#  0.012822
# Max Combo Index:
#  (4, 4, 0, 5, 1, 16) out of [6, 9, 6, 6, 2, 72] (note best combo is 0-indexed)
# Max Combo Hyperparamer Combination:
#  {'C': 1, 'degree': 5, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'features': 16}
# Max Combo Features:
#  ('procedure_228130', 'procedure_225792', 'procedure_228125', 'lods_score', 'ventilation_used', 'procedure_226236', 'hospital_stay_duration', 'procedure_225469', 'procedure_224270', 'procedure_225446', 'procedure_225802', 'procedure_227712', 'procedure_229580', 'procedure_225451', 'admission_type_DIRECT EMER.', 'admission_type_DIRECT OBSERVATION', 'admission_type_ELECTIVE', 'admission_type_EU OBSERVATION', 'admission_type_EW EMER.', 'admission_type_OBSERVATION ADMIT', 'admission_type_URGENT', 'admission_type_SURGICAL SAME DAY ADMISSION', 'procedure_224385', 'procedure_224267')
# % Combos Checked: 9796 out of 279936 which is 3.4993709999999996%
