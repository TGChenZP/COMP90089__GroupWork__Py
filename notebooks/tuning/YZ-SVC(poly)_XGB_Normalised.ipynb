# %% [markdown]
# # Tuning Script

# %%
# Parameters subject to change in every script - involved in naming

MODEL = 'svc(poly)'
PREPROCESSING = 'normalise'
TUNER = 'yangzhoub'
OPTIMISED_METRIC = 'f1'

# %% [markdown]
# ---

# %%
# detect whether this is a google environment

COLAB_ENVIRONMENT = False

try:
    from google.colab import drive
    drive.mount('/content/drive')
    COLAB_ENVIRONMENT = True
except:
    pass
# Out:
# Mounted at /content/drive

# %%
import sys
import os
import pickle

if COLAB_ENVIRONMENT:
    home_directory = './drive/MyDrive/LAB/COMP90089__GroupWork__Py/' # my home directory is stored in ./LAB of google drive
    if MODEL == 'ebr':
        # !pip install interpret==0.5.0
    elif MODEL == 'cbr':
        # !pip install catboost
    elif MODEL in ['tf', 'mlp']:
        # !pip install PyTorch2Sklearn
    # !pip install JXAutoML
else:
    home_directory = '../../'

from JXAutoML.YangZhouB_10CV import YangZhouB_10CV as Tuner

import pandas as pd
# Out:
# Collecting JXAutoML
#   Downloading JXAutoML-0.4.4-py3-none-any.whl.metadata (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.2/67.2 kB 804.5 kB/s eta 0:00:00
# Downloading JXAutoML-0.4.4-py3-none-any.whl (52 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.1/52.1 kB 2.0 MB/s eta 0:00:00
# Installing collected packages: JXAutoML
# Successfully installed JXAutoML-0.4.4

# %%
# Parameters that are same for every script

FOLDS = 10  # we have decided to do 10 fold validation

SEED = 42

TASK_TYPE = 'Classification'  # this task is a classification task

# we have decided to tune features as hp
TUNE_FEATURES_AS_HYPERPARAMETERS = True

# %% [markdown]
# ---

# %%
# model to use to tune
from sklearn.svm import SVC as clf

# what values to try for each hyperparameter
parameter_choices = {
    'C': (0.0001, 0.001, 0.01, 0.1, 1, 10),
    'degree': list(range(1, 10)),
    'tol': (0.0001, 0.001, 0.01, 0.1, 1, 10),
    'max_iter': (50, 100, 200, 400, 800, 1600),
    'gamma': ('scale', 'auto')
}

# what values to set non-tuneable parameters/hyperparameters
non_tunable_hyperparameters_dict = {
                                    'verbose': False,
                                    'decision_function_shape': 'ovr',
                                    'random_state': 42,
                                    'kernel': 'poly'
                                    }

# %% [markdown]
# ---

# %% [markdown]
# Read in and Prepare Data

# %%
# Import data and store as lists

train_x_list = []
train_y_list = []
val_x_list = []
val_y_list = []

for i in range(FOLDS):
    train_data = pd.read_csv(
        f'{home_directory}data/curated/modelling/{PREPROCESSING}/train_{i}.csv')
    val_data = pd.read_csv(
        f'{home_directory}data/curated/modelling/{PREPROCESSING}/val_{i}.csv')

    # get the correct rows for X and y
    train_x = train_data.drop(
        ['mortality_status', 'subject_id', 'hadm_id', 'stay_id'], axis=1)
    train_y = train_data['mortality_status']
    val_x = val_data.drop(
        ['mortality_status', 'subject_id', 'hadm_id', 'stay_id'], axis=1)
    val_y = val_data['mortality_status']

    train_x_list.append(train_x)
    train_y_list.append(train_y)
    val_x_list.append(val_x)
    val_y_list.append(val_y)

# %%
# Import feature importance ordering

with open(f'{home_directory}models/xgb_feature_importance_ordering_{PREPROCESSING}.pickle', 'rb') as f:
    feature_importance_ordering = pickle.load(f)

# %% [markdown]
# Set parameters

# %%
# initialisation
tuner = Tuner()

print('---')

# define what model we are tuning
tuner.read_in_model(clf, TASK_TYPE, optimised_metric=OPTIMISED_METRIC)

print('---')

# read in the data for training and validation
tuner.read_in_data(train_x_list, train_y_list, val_x_list, val_y_list)

print('---')

# set what hp values to tune
tuner.set_hyperparameters(parameter_choices)
# WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

# set up hp values that need to be changed from default but NOT to be tuned
tuner.set_non_tuneable_hyperparameters(non_tunable_hyperparameters_dict)

print('---')

# set up feature importance ordering

if TUNE_FEATURES_AS_HYPERPARAMETERS:
    tuner.set_features(feature_importance_ordering)
    # WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

try:  # try to read in previous results to continue tuning ...
    tuner.read_in_tuning_result_df(
        f'{home_directory}models/tuning/{TUNER}_{MODEL}_{PREPROCESSING}.csv')
except:
    print('No previous tuning data read in')

print('---')

# set up where to save the tuning result csv
tuner.set_tuning_result_saving_address(
    f'{home_directory}models/tuning/{TUNER}_{MODEL}_{PREPROCESSING}.csv')

print('---')

# set up where to save the current best model
tuner.set_best_model_saving_address(
    f'{home_directory}models/tmp_models/{TUNER}_{MODEL}_{PREPROCESSING}')
# Out:
# YangZhouB Initialised
# ---
# Successfully read in model <class 'sklearn.svm._classes.SVC'>, which is a Classification model optimising for f1
# ---
# Read in Train X data list
# Read in Train y data list
# Read in Val X data list
# Read in Val y data list
# ---
# Successfully recorded hyperparameter choices
# ---
# Successfully recorded non_tuneable_hyperparameter choices
# ---
# Successfully recorded tuneable feature combination choices and updated relevant internal structures
# ---
# Successfully read in tuning result of 5840 rows, for 5840.0 combos
# ---
# Successfully set tuning output address
# ---
# Successfully set best model output address

# %%
# ignore warnings

import warnings
warnings.filterwarnings("ignore")

# %%
# begin tuning ... (or continue training)

tuner.tune()
# Out:
# Streaming output truncated to the last 5000 lines.
# Already Trained and Tested combination (val score of 0.3117):
#             {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 10}
#             Current best combo (with val score 0.4424):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'scale', 'features': 2}
#         Has trained 5840 of 186624 combinations so far
# Already Trained and Tested combination (val score of 0.3117):
#             {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 9}
#             Current best combo (with val score 0.4424):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'scale', 'features': 2}
#         Has trained 5840 of 186624 combinations so far
# Already Trained and Tested combination (val score of 0.3154):
#             {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 11}
#             Current best combo (with val score 0.4424):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'scale', 'features': 2}
#         Has trained 5840 of 186624 combinations so far
# 	round 298 iteration:  1
#
# Already Trained and Tested combination (val score of 0.3117):
#             {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 10}
#             Current best combo (with val score 0.4424):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'scale', 'features': 2}
#         Has trained 5840 of 186624 combinations so far
# Already Trained and Tested combination (val score of 0.3117):
#             {'C': 0.01, 'degree': 1, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 10}
#             Current best combo (with val score 0.4424):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'scale', 'features': 2}
#         Has trained 5840 of 186624 combinations so far
# Already Trained and Tested combination (val score of 0.3117):
#             {'C': 0.001, 'degree': 2, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 10}
#             Current best combo (with val score 0.4424):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'scale', 'features': 2}
#         Has trained 5840 of 186624 combinations so far
# Already Trained and Tested combination (val score of 0.3117):
#             {'C': 0.001, 'degree': 1, 'tol': 0.001, 'max_iter': 50, 'gamma': 'auto', 'features': 10}
#             Current best combo (with val score 0.4424):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'scale', 'features': 2}
#         Has trained 5840 of 186624 combinations so far
# Already Trained and Tested combination (val score of 0.3117):
#             {'C': 0.001, 'degree': 1, 'tol': 0.0001, 'max_iter': 100, 'gamma': 'auto', 'features': 10}
#             Current best combo (with val score 0.4424):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'scale', 'features': 2}
#         Has trained 5840 of 186624 combinations so far
# Already Trained and Tested combination (val score of 0.3117):
#             {'C': 0.001, 'degree': 1, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 10}
#             Current best combo (with val score 0.4424):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'scale', 'features': 2}
#         Has trained 5840 of 186624 combinations so far
# Already Trained and Tested combination (val score of 0.3117):
#             {'C': 0.001, 'degree': 1, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 9}
#             Current best combo (with val score 0.4424):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'scale', 'features': 2}
#         Has trained 5840 of 186624 combinations so far
# Already Trained and Tested combination (val score of 0.3154):
#             {'C': 0.001, 'degree': 1, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 11}
#             Current best combo (with val score 0.4424):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'scale', 'features': 2}
#         Has trained 5840 of 186624 combinations so far
# Already Trained and Tested combination (val score of 0.3117):
#             {'C': 0.001, 'degree': 2, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 10}
#             Current best combo (with val score 0.4424):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'scale', 'features': 2}
#         Has trained 5840 of 186624 combinations so far
# Already Trained and Tested combination (val score of 0.3117):
#             {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 10}
#             Current best combo (with val score 0.4424):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'scale', 'features': 2}
#         Has trained 5840 of 186624 combinations so far
# Already Trained and Tested combination (val score of 0.3117):
#             {'C': 0.0001, 'degree': 3, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 10}
#             Current best combo (with val score 0.4424):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'scale', 'features': 2}
#         Has trained 5840 of 186624 combinations so far
# Already Trained and Tested combination (val score of 0.3117):
#             {'C': 0.0001, 'degree': 2, 'tol': 0.001, 'max_iter': 50, 'gamma': 'auto', 'features': 10}
#             Current best combo (with val score 0.4424):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'scale', 'features': 2}
#         Has trained 5840 of 186624 combinations so far
# Already Trained and Tested combination (val score of 0.3117):
#             {'C': 0.0001, 'degree': 2, 'tol': 0.0001, 'max_iter': 100, 'gamma': 'auto', 'features': 10}
#             Current best combo (with val score 0.4424):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'scale', 'features': 2}
#         Has trained 5840 of 186624 combinations so far
# Already Trained and Tested combination (val score of 0.3117):
#             {'C': 0.0001, 'degree': 2, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 10}
#             Current best combo (with val score 0.4424):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'scale', 'features': 2}
#         Has trained 5840 of 186624 combinations so far
# Already Trained and Tested combination (val score of 0.3117):
#             {'C': 0.0001, 'degree': 2, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 9}
#             Current best combo (with val score 0.4424):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'scale', 'features': 2}
#         Has trained 5840 of 186624 combinations so far
# Already Trained and Tested combination (val score of 0.3117):
#             {'C': 0.0001, 'degree': 2, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 11}
#             Current best combo (with val score 0.4424):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'scale', 'features': 2}
#         Has trained 5840 of 186624 combinations so far
# Already Trained and Tested combination (val score of 0.3117):
#             {'C': 0.001, 'degree': 1, 'tol': 0.001, 'max_iter': 50, 'gamma': 'auto', 'features': 10}
#             Current best combo (with val score 0.4424):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'scale', 'features': 2}
#         Has trained 5840 of 186624 combinations so far
# Already Trained and Tested combination (val score of 0.3117):
#             {'C': 0.0001, 'degree': 2, 'tol': 0.001, 'max_iter': 50, 'gamma': 'auto', 'features': 10}
#             Current best combo (with val score 0.4424):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'scale', 'features': 2}
#         Has trained 5840 of 186624 combinations so far
# Already Trained and Tested combination (val score of 0.3117):
#             {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 10}
#             Current best combo (with val score 0.4424):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'scale', 'features': 2}
#         Has trained 5840 of 186624 combinations so far
# Already Trained and Tested combination (val score of 0.3117):
#             {'C': 0.0001, 'degree': 1, 'tol': 0.01, 'max_iter': 50, 'gamma': 'auto', 'features': 10}
#             Current best combo (with val score 0.4424):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'scale', 'features': 2}
#         Has trained 5840 of 186624 combinations so far
# Already Trained and Tested combination (val score of 0.3117):
#             {'C': 0.0001, 'degree': 1, 'tol': 0.001, 'max_iter': 100, 'gamma': 'auto', 'features': 10}
#             Current best combo (with val score 0.4424):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'scale', 'features': 2}
#         Has trained 5840 of 186624 combinations so far
# Already Trained and Tested combination (val score of 0.3117):
#             {'C': 0.0001, 'degree': 1, 'tol': 0.001, 'max_iter': 50, 'gamma': 'scale', 'features': 10}
#             Current best combo (with val score 0.4424):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'scale', 'features': 2}
#         Has trained 5840 of 186624 combinations so far
# Already Trained and Tested combination (val score of 0.3117):
#             {'C': 0.0001, 'degree': 1, 'tol': 0.001, 'max_iter': 50, 'gamma': 'auto', 'features': 9}
#             Current best combo (with val score 0.4424):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'scale', 'features': 2}
#         Has trained 5840 of 186624 combinations so far
# Already Trained and Tested combination (val score of 0.3154):
#             {'C': 0.0001, 'degree': 1, 'tol': 0.001, 'max_iter': 50, 'gamma': 'auto', 'features': 11}
#             Current best combo (with val score 0.4424):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'scale', 'features': 2}
#         Has trained 5840 of 186624 combinations so far
# Already Trained and Tested combination (val score of 0.3117):
#             {'C': 0.001, 'degree': 1, 'tol': 0.0001, 'max_iter': 100, 'gamma': 'auto', 'features': 10}
#             Current best combo (with val score 0.4424):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'scale', 'features': 2}
#         Has trained 5840 of 186624 combinations so far
# Already Trained and Tested combination (val score of 0.3117):
#             {'C': 0.0001, 'degree': 2, 'tol': 0.0001, 'max_iter': 100, 'gamma': 'auto', 'features': 10}
#             Current best combo (with val score 0.4424):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'scale', 'features': 2}
#         Has trained 5840 of 186624 combinations so far
# Already Trained and Tested combination (val score of 0.3117):
#             {'C': 0.0001, 'degree': 1, 'tol': 0.001, 'max_iter': 100, 'gamma': 'auto', 'features': 10}
#             Current best combo (with val score 0.4424):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'scale', 'features': 2}
#         Has trained 5840 of 186624 combinations so far
# Already Trained and Tested combination (val score of 0.3117):
#             {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 10}
#             Current best combo (with val score 0.4424):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'scale', 'features': 2}
#         Has trained 5840 of 186624 combinations so far
# Already Trained and Tested combination (val score of 0.3223):
#             {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 200, 'gamma': 'auto', 'features': 10}
#             Current best combo (with val score 0.4424):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'scale', 'features': 2}
#         Has trained 5840 of 186624 combinations so far
# Already Trained and Tested combination (val score of 0.3117):
#             {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 100, 'gamma': 'scale', 'features': 10}
#             Current best combo (with val score 0.4424):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'scale', 'features': 2}
#         Has trained 5840 of 186624 combinations so far
# Already Trained and Tested combination (val score of 0.3117):
#             {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 100, 'gamma': 'auto', 'features': 9}
#             Current best combo (with val score 0.4424):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'scale', 'features': 2}
#         Has trained 5840 of 186624 combinations so far
# Already Trained and Tested combination (val score of 0.3117):
#             {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 100, 'gamma': 'auto', 'features': 11}
#             Current best combo (with val score 0.4424):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'scale', 'features': 2}
#         Has trained 5840 of 186624 combinations so far
# Already Trained and Tested combination (val score of 0.3117):
#             {'C': 0.001, 'degree': 1, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 10}
#             Current best combo (with val score 0.4424):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'scale', 'features': 2}
#         Has trained 5840 of 186624 combinations so far
# Already Trained and Tested combination (val score of 0.3117):
#             {'C': 0.0001, 'degree': 2, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 10}
#             Current best combo (with val score 0.4424):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'scale', 'features': 2}
#         Has trained 5840 of 186624 combinations so far
# Already Trained and Tested combination (val score of 0.3117):
#             {'C': 0.0001, 'degree': 1, 'tol': 0.001, 'max_iter': 50, 'gamma': 'scale', 'features': 10}
#             Current best combo (with val score 0.4424):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'scale', 'features': 2}
#         Has trained 5840 of 186624 combinations so far
# Already Trained and Tested combination (val score of 0.3117):
#             {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 100, 'gamma': 'scale', 'features': 10}
#             Current best combo (with val score 0.4424):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'scale', 'features': 2}
#         Has trained 5840 of 186624 combinations so far
# Already Trained and Tested combination (val score of 0.3117):
#             {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 10}
#             Current best combo (with val score 0.4424):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'scale', 'features': 2}
#         Has trained 5840 of 186624 combinations so far
# Already Trained and Tested combination (val score of 0.3117):
#             {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 9}
#             Current best combo (with val score 0.4424):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'scale', 'features': 2}
#         Has trained 5840 of 186624 combinations so far
# Already Trained and Tested combination (val score of 0.3154):
#             {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 11}
#             Current best combo (with val score 0.4424):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'scale', 'features': 2}
#         Has trained 5840 of 186624 combinations so far
# Already Trained and Tested combination (val score of 0.3117):
#             {'C': 0.001, 'degree': 1, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 9}
#             Current best combo (with val score 0.4424):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'scale', 'features': 2}
#         Has trained 5840 of 186624 combinations so far
# Already Trained and Tested combination (val score of 0.3117):
#             {'C': 0.0001, 'degree': 2, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 9}
#             Current best combo (with val score 0.4424):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'scale', 'features': 2}
#         Has trained 5840 of 186624 combinations so far
# Already Trained and Tested combination (val score of 0.3117):
#             {'C': 0.0001, 'degree': 1, 'tol': 0.001, 'max_iter': 50, 'gamma': 'auto', 'features': 9}
#             Current best combo (with val score 0.4424):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'scale', 'features': 2}
#         Has trained 5840 of 186624 combinations so far
# Already Trained and Tested combination (val score of 0.3117):
#             {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 100, 'gamma': 'auto', 'features': 9}
#             Current best combo (with val score 0.4424):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'scale', 'features': 2}
#         Has trained 5840 of 186624 combinations so far
# Already Trained and Tested combination (val score of 0.3117):
#             {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 9}
#             Current best combo (with val score 0.4424):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'scale', 'features': 2}
#         Has trained 5840 of 186624 combinations so far
# Already Trained and Tested combination (val score of 0.3117):
#             {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 8}
#             Current best combo (with val score 0.4424):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'scale', 'features': 2}
#         Has trained 5840 of 186624 combinations so far
# Already Trained and Tested combination (val score of 0.3117):
#             {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 10}
#             Current best combo (with val score 0.4424):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'scale', 'features': 2}
#         Has trained 5840 of 186624 combinations so far
# Already Trained and Tested combination (val score of 0.3154):
#             {'C': 0.001, 'degree': 1, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 11}
#             Current best combo (with val score 0.4424):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'scale', 'features': 2}
#         Has trained 5840 of 186624 combinations so far
# Already Trained and Tested combination (val score of 0.3117):
#             {'C': 0.0001, 'degree': 2, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 11}
#             Current best combo (with val score 0.4424):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'scale', 'features': 2}
#         Has trained 5840 of 186624 combinations so far
# Already Trained and Tested combination (val score of 0.3154):
#             {'C': 0.0001, 'degree': 1, 'tol': 0.001, 'max_iter': 50, 'gamma': 'auto', 'features': 11}
#             Current best combo (with val score 0.4424):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'scale', 'features': 2}
#         Has trained 5840 of 186624 combinations so far
# Already Trained and Tested combination (val score of 0.3117):
#             {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 100, 'gamma': 'auto', 'features': 11}
#             Current best combo (with val score 0.4424):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'scale', 'features': 2}
#         Has trained 5840 of 186624 combinations so far
# Already Trained and Tested combination (val score of 0.3154):
#             {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'scale', 'features': 11}
#             Current best combo (with val score 0.4424):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'scale', 'features': 2}
#         Has trained 5840 of 186624 combinations so far
# Already Trained and Tested combination (val score of 0.3117):
#             {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 10}
#             Current best combo (with val score 0.4424):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'scale', 'features': 2}
#         Has trained 5840 of 186624 combinations so far
# Already Trained and Tested combination (val score of 0.3117):
#             {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 50, 'gamma': 'auto', 'features': 12}
#             Current best combo (with val score 0.4424):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'scale', 'features': 2}
#         Has trained 5840 of 186624 combinations so far
# % Combos Checked Thus Far: 5840 out of 186624 which is 3.129287%
# Cruising Coordrdinate 470 of 528
#
# Cruise suspended due to suspicious case
# Guidance: round 299
#
# 	round 299 iteration:  0
#
# % Combos Checked Thus Far: 5840 out of 186624 which is 3.129287%
# Cruising Coordrdinate 471 of 528
#
# Cruise suspended due to suspicious case
# Guidance: round 300
#
# 	round 300 iteration:  0
#
# % Combos Checked Thus Far: 5840 out of 186624 which is 3.129287%
# Cruising Coordrdinate 472 of 528
#
# Cruising Coordrdinate 473 of 528
#
# Cruising Coordrdinate 474 of 528
#
# Cruising Coordrdinate 475 of 528
#
# Cruise suspended due to suspicious case
# Guidance: round 301
#
# 	round 301 iteration:  0
#
# Already Trained and Tested combination (val score of 0.3117):
#             {'C': 1, 'degree': 1, 'tol': 10, 'max_iter': 50, 'gamma': 'auto', 'features': 5}
#             Current best combo (with val score 0.4424):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'scale', 'features': 2}
#         Has trained 5840 of 186624 combinations so far
# Already Trained and Tested combination (val score of 0.3117):
#             {'C': 10, 'degree': 2, 'tol': 10, 'max_iter': 50, 'gamma': 'auto', 'features': 5}
#             Current best combo (with val score 0.4424):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'scale', 'features': 2}
#         Has trained 5840 of 186624 combinations so far
# Already Trained and Tested combination (val score of 0.2871):
#             {'C': 10, 'degree': 1, 'tol': 1, 'max_iter': 50, 'gamma': 'auto', 'features': 5}
#             Current best combo (with val score 0.4424):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'scale', 'features': 2}
#         Has trained 5840 of 186624 combinations so far
# Already Trained and Tested combination (val score of 0.3117):
#             {'C': 10, 'degree': 1, 'tol': 10, 'max_iter': 100, 'gamma': 'auto', 'features': 5}
#             Current best combo (with val score 0.4424):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'scale', 'features': 2}
#         Has trained 5840 of 186624 combinations so far
# Already Trained and Tested combination (val score of 0.3117):
#             {'C': 10, 'degree': 1, 'tol': 10, 'max_iter': 50, 'gamma': 'scale', 'features': 5}
#             Current best combo (with val score 0.4424):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'scale', 'features': 2}
#         Has trained 5840 of 186624 combinations so far
# Already Trained and Tested combination (val score of 0.3117):
#             {'C': 10, 'degree': 1, 'tol': 10, 'max_iter': 50, 'gamma': 'auto', 'features': 4}
#             Current best combo (with val score 0.4424):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'scale', 'features': 2}
#         Has trained 5840 of 186624 combinations so far
# Already Trained and Tested combination (val score of 0.3117):
#             {'C': 10, 'degree': 1, 'tol': 10, 'max_iter': 50, 'gamma': 'auto', 'features': 6}
#             Current best combo (with val score 0.4424):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'scale', 'features': 2}
#         Has trained 5840 of 186624 combinations so far
# 	round 301 iteration:  1
#
# Already Trained and Tested combination (val score of 0.3117):
#             {'C': 0.1, 'degree': 1, 'tol': 10, 'max_iter': 50, 'gamma': 'auto', 'features': 5}
#             Current best combo (with val score 0.4424):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'scale', 'features': 2}
#         Has trained 5840 of 186624 combinations so far
# Already Trained and Tested combination (val score of 0.3117):
#             {'C': 10, 'degree': 1, 'tol': 10, 'max_iter': 50, 'gamma': 'auto', 'features': 5}
#             Current best combo (with val score 0.4424):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'scale', 'features': 2}
#         Has trained 5840 of 186624 combinations so far
# Already Trained and Tested combination (val score of 0.3117):
#             {'C': 1, 'degree': 2, 'tol': 10, 'max_iter': 50, 'gamma': 'auto', 'features': 5}
#             Current best combo (with val score 0.4424):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'scale', 'features': 2}
#         Has trained 5840 of 186624 combinations so far
# Already Trained and Tested combination (val score of 0.3172):
#             {'C': 1, 'degree': 1, 'tol': 1, 'max_iter': 50, 'gamma': 'auto', 'features': 5}
#             Current best combo (with val score 0.4424):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'scale', 'features': 2}
#         Has trained 5840 of 186624 combinations so far
# Already Trained and Tested combination (val score of 0.3117):
#             {'C': 1, 'degree': 1, 'tol': 10, 'max_iter': 100, 'gamma': 'auto', 'features': 5}
#             Current best combo (with val score 0.4424):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'scale', 'features': 2}
#         Has trained 5840 of 186624 combinations so far
# Already Trained and Tested combination (val score of 0.3117):
#             {'C': 1, 'degree': 1, 'tol': 10, 'max_iter': 50, 'gamma': 'scale', 'features': 5}
#             Current best combo (with val score 0.4424):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'scale', 'features': 2}
#         Has trained 5840 of 186624 combinations so far
# Already Trained and Tested combination (val score of 0.3117):
#             {'C': 1, 'degree': 1, 'tol': 10, 'max_iter': 50, 'gamma': 'auto', 'features': 4}
#             Current best combo (with val score 0.4424):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'scale', 'features': 2}
#         Has trained 5840 of 186624 combinations so far
# Already Trained and Tested combination (val score of 0.3117):
#             {'C': 1, 'degree': 1, 'tol': 10, 'max_iter': 50, 'gamma': 'auto', 'features': 6}
#             Current best combo (with val score 0.4424):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'scale', 'features': 2}
#         Has trained 5840 of 186624 combinations so far
# Already Trained and Tested combination (val score of 0.3117):
#             {'C': 1, 'degree': 2, 'tol': 10, 'max_iter': 50, 'gamma': 'auto', 'features': 5}
#             Current best combo (with val score 0.4424):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'scale', 'features': 2}
#         Has trained 5840 of 186624 combinations so far
# Already Trained and Tested combination (val score of 0.3117):
#             {'C': 10, 'degree': 1, 'tol': 10, 'max_iter': 50, 'gamma': 'auto', 'features': 5}
#             Current best combo (with val score 0.4424):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'scale', 'features': 2}
#         Has trained 5840 of 186624 combinations so far
# Already Trained and Tested combination (val score of 0.3117):
#             {'C': 10, 'degree': 3, 'tol': 10, 'max_iter': 50, 'gamma': 'auto', 'features': 5}
#             Current best combo (with val score 0.4424):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'scale', 'features': 2}
#         Has trained 5840 of 186624 combinations so far
# Already Trained and Tested combination (val score of 0.3117):
#             {'C': 10, 'degree': 2, 'tol': 1, 'max_iter': 50, 'gamma': 'auto', 'features': 5}
#             Current best combo (with val score 0.4424):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'scale', 'features': 2}
#         Has trained 5840 of 186624 combinations so far
# Already Trained and Tested combination (val score of 0.3117):
#             {'C': 10, 'degree': 2, 'tol': 10, 'max_iter': 100, 'gamma': 'auto', 'features': 5}
#             Current best combo (with val score 0.4424):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'scale', 'features': 2}
#         Has trained 5840 of 186624 combinations so far
# Already Trained and Tested combination (val score of 0.3117):
#             {'C': 10, 'degree': 2, 'tol': 10, 'max_iter': 50, 'gamma': 'scale', 'features': 5}
#             Current best combo (with val score 0.4424):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'scale', 'features': 2}
#         Has trained 5840 of 186624 combinations so far
# Already Trained and Tested combination (val score of 0.3117):
#             {'C': 10, 'degree': 2, 'tol': 10, 'max_iter': 50, 'gamma': 'auto', 'features': 4}
#             Current best combo (with val score 0.4424):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'scale', 'features': 2}
#         Has trained 5840 of 186624 combinations so far
# Already Trained and Tested combination (val score of 0.3117):
#             {'C': 10, 'degree': 2, 'tol': 10, 'max_iter': 50, 'gamma': 'auto', 'features': 6}
#             Current best combo (with val score 0.4424):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'scale', 'features': 2}
#         Has trained 5840 of 186624 combinations so far
# Already Trained and Tested combination (val score of 0.3117):
#             {'C': 1, 'degree': 1, 'tol': 10, 'max_iter': 100, 'gamma': 'auto', 'features': 5}
#             Current best combo (with val score 0.4424):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'scale', 'features': 2}
#         Has trained 5840 of 186624 combinations so far
# Already Trained and Tested combination (val score of 0.3117):
#             {'C': 10, 'degree': 2, 'tol': 10, 'max_iter': 100, 'gamma': 'auto', 'features': 5}
#             Current best combo (with val score 0.4424):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'scale', 'features': 2}
#         Has trained 5840 of 186624 combinations so far
# Already Trained and Tested combination (val score of 0.294):
#             {'C': 10, 'degree': 1, 'tol': 1, 'max_iter': 100, 'gamma': 'auto', 'features': 5}
#             Current best combo (with val score 0.4424):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'scale', 'features': 2}
#         Has trained 5840 of 186624 combinations so far
# Already Trained and Tested combination (val score of 0.3117):
#             {'C': 10, 'degree': 1, 'tol': 10, 'max_iter': 50, 'gamma': 'auto', 'features': 5}
#             Current best combo (with val score 0.4424):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'scale', 'features': 2}
#         Has trained 5840 of 186624 combinations so far
# Already Trained and Tested combination (val score of 0.3117):
#             {'C': 10, 'degree': 1, 'tol': 10, 'max_iter': 200, 'gamma': 'auto', 'features': 5}
#             Current best combo (with val score 0.4424):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'scale', 'features': 2}
#         Has trained 5840 of 186624 combinations so far
# Already Trained and Tested combination (val score of 0.3117):
#             {'C': 10, 'degree': 1, 'tol': 10, 'max_iter': 100, 'gamma': 'scale', 'features': 5}
#             Current best combo (with val score 0.4424):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'scale', 'features': 2}
#         Has trained 5840 of 186624 combinations so far
# Already Trained and Tested combination (val score of 0.3117):
#             {'C': 10, 'degree': 1, 'tol': 10, 'max_iter': 100, 'gamma': 'auto', 'features': 4}
#             Current best combo (with val score 0.4424):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'scale', 'features': 2}
#         Has trained 5840 of 186624 combinations so far
# Already Trained and Tested combination (val score of 0.3117):
#             {'C': 10, 'degree': 1, 'tol': 10, 'max_iter': 100, 'gamma': 'auto', 'features': 6}
#             Current best combo (with val score 0.4424):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'scale', 'features': 2}
#         Has trained 5840 of 186624 combinations so far
# Already Trained and Tested combination (val score of 0.3117):
#             {'C': 1, 'degree': 1, 'tol': 10, 'max_iter': 50, 'gamma': 'scale', 'features': 5}
#             Current best combo (with val score 0.4424):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'scale', 'features': 2}
#         Has trained 5840 of 186624 combinations so far
# Already Trained and Tested combination (val score of 0.3117):
#             {'C': 10, 'degree': 2, 'tol': 10, 'max_iter': 50, 'gamma': 'scale', 'features': 5}
#             Current best combo (with val score 0.4424):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'scale', 'features': 2}
#         Has trained 5840 of 186624 combinations so far
# Already Trained and Tested combination (val score of 0.2805):
#             {'C': 10, 'degree': 1, 'tol': 1, 'max_iter': 50, 'gamma': 'scale', 'features': 5}
#             Current best combo (with val score 0.4424):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'scale', 'features': 2}
#         Has trained 5840 of 186624 combinations so far
# Already Trained and Tested combination (val score of 0.3117):
#             {'C': 10, 'degree': 1, 'tol': 10, 'max_iter': 100, 'gamma': 'scale', 'features': 5}
#             Current best combo (with val score 0.4424):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'scale', 'features': 2}
#         Has trained 5840 of 186624 combinations so far
# Already Trained and Tested combination (val score of 0.3117):
#             {'C': 10, 'degree': 1, 'tol': 10, 'max_iter': 50, 'gamma': 'auto', 'features': 5}
#             Current best combo (with val score 0.4424):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'scale', 'features': 2}
#         Has trained 5840 of 186624 combinations so far
# Already Trained and Tested combination (val score of 0.3117):
#             {'C': 10, 'degree': 1, 'tol': 10, 'max_iter': 50, 'gamma': 'scale', 'features': 4}
#             Current best combo (with val score 0.4424):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'scale', 'features': 2}
#         Has trained 5840 of 186624 combinations so far
# Already Trained and Tested combination (val score of 0.3117):
#             {'C': 10, 'degree': 1, 'tol': 10, 'max_iter': 50, 'gamma': 'scale', 'features': 6}
#             Current best combo (with val score 0.4424):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'scale', 'features': 2}
#         Has trained 5840 of 186624 combinations so far
# Already Trained and Tested combination (val score of 0.3117):
#             {'C': 1, 'degree': 1, 'tol': 10, 'max_iter': 50, 'gamma': 'auto', 'features': 4}
#             Current best combo (with val score 0.4424):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'scale', 'features': 2}
#         Has trained 5840 of 186624 combinations so far
# Already Trained and Tested combination (val score of 0.3117):
#             {'C': 10, 'degree': 2, 'tol': 10, 'max_iter': 50, 'gamma': 'auto', 'features': 4}
#             Current best combo (with val score 0.4424):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'scale', 'features': 2}
#         Has trained 5840 of 186624 combinations so far
# Already Trained and Tested combination (val score of 0.1853):
#             {'C': 10, 'degree': 1, 'tol': 1, 'max_iter': 50, 'gamma': 'auto', 'features': 4}
#             Current best combo (with val score 0.4424):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'scale', 'features': 2}
#         Has trained 5840 of 186624 combinations so far
# Already Trained and Tested combination (val score of 0.3117):
#             {'C': 10, 'degree': 1, 'tol': 10, 'max_iter': 100, 'gamma': 'auto', 'features': 4}
#             Current best combo (with val score 0.4424):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'scale', 'features': 2}
#         Has trained 5840 of 186624 combinations so far
# Already Trained and Tested combination (val score of 0.3117):
#             {'C': 10, 'degree': 1, 'tol': 10, 'max_iter': 50, 'gamma': 'scale', 'features': 4}
#             Current best combo (with val score 0.4424):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'scale', 'features': 2}
#         Has trained 5840 of 186624 combinations so far
# Already Trained and Tested combination (val score of 0.3117):
#             {'C': 10, 'degree': 1, 'tol': 10, 'max_iter': 50, 'gamma': 'auto', 'features': 3}
#             Current best combo (with val score 0.4424):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'scale', 'features': 2}
#         Has trained 5840 of 186624 combinations so far
# Already Trained and Tested combination (val score of 0.3117):
#             {'C': 10, 'degree': 1, 'tol': 10, 'max_iter': 50, 'gamma': 'auto', 'features': 5}
#             Current best combo (with val score 0.4424):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'scale', 'features': 2}
#         Has trained 5840 of 186624 combinations so far
# Already Trained and Tested combination (val score of 0.3117):
#             {'C': 1, 'degree': 1, 'tol': 10, 'max_iter': 50, 'gamma': 'auto', 'features': 6}
#             Current best combo (with val score 0.4424):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'scale', 'features': 2}
#         Has trained 5840 of 186624 combinations so far
# Already Trained and Tested combination (val score of 0.3117):
#             {'C': 10, 'degree': 2, 'tol': 10, 'max_iter': 50, 'gamma': 'auto', 'features': 6}
#             Current best combo (with val score 0.4424):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'scale', 'features': 2}
#         Has trained 5840 of 186624 combinations so far
# Already Trained and Tested combination (val score of 0.3117):
#             {'C': 10, 'degree': 1, 'tol': 1, 'max_iter': 50, 'gamma': 'auto', 'features': 6}
#             Current best combo (with val score 0.4424):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'scale', 'features': 2}
#         Has trained 5840 of 186624 combinations so far
# Already Trained and Tested combination (val score of 0.3117):
#             {'C': 10, 'degree': 1, 'tol': 10, 'max_iter': 100, 'gamma': 'auto', 'features': 6}
#             Current best combo (with val score 0.4424):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'scale', 'features': 2}
#         Has trained 5840 of 186624 combinations so far
# Already Trained and Tested combination (val score of 0.3117):
#             {'C': 10, 'degree': 1, 'tol': 10, 'max_iter': 50, 'gamma': 'scale', 'features': 6}
#             Current best combo (with val score 0.4424):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'scale', 'features': 2}
#         Has trained 5840 of 186624 combinations so far
# Already Trained and Tested combination (val score of 0.3117):
#             {'C': 10, 'degree': 1, 'tol': 10, 'max_iter': 50, 'gamma': 'auto', 'features': 5}
#             Current best combo (with val score 0.4424):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'scale', 'features': 2}
#         Has trained 5840 of 186624 combinations so far
# Already Trained and Tested combination (val score of 0.3117):
#             {'C': 10, 'degree': 1, 'tol': 10, 'max_iter': 50, 'gamma': 'auto', 'features': 7}
#             Current best combo (with val score 0.4424):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'scale', 'features': 2}
#         Has trained 5840 of 186624 combinations so far
# % Combos Checked Thus Far: 5840 out of 186624 which is 3.129287%
# Cruising Coordrdinate 476 of 528
#
# Cruising Coordrdinate 477 of 528
#
# Cruise suspended due to suspicious case
# Guidance: round 302
#
# 	round 302 iteration:  0
#
# % Combos Checked Thus Far: 5840 out of 186624 which is 3.129287%
# Cruising Coordrdinate 478 of 528
#
# Cruise suspended due to suspicious case
# Guidance: round 303
#
# 	round 303 iteration:  0
#
# Already Trained and Tested combination (val score of 0.3117):
#             {'C': 1, 'degree': 1, 'tol': 10, 'max_iter': 50, 'gamma': 'auto', 'features': 0}
#             Current best combo (with val score 0.4424):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'scale', 'features': 2}
#         Has trained 5840 of 186624 combinations so far
# Already Trained and Tested combination (val score of 0.3117):
#             {'C': 10, 'degree': 2, 'tol': 10, 'max_iter': 50, 'gamma': 'auto', 'features': 0}
#             Current best combo (with val score 0.4424):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'scale', 'features': 2}
#         Has trained 5840 of 186624 combinations so far
# Already Trained and Tested combination (val score of 0.3117):
#             {'C': 10, 'degree': 1, 'tol': 1, 'max_iter': 50, 'gamma': 'auto', 'features': 0}
#             Current best combo (with val score 0.4424):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'scale', 'features': 2}
#         Has trained 5840 of 186624 combinations so far
# Already Trained and Tested combination (val score of 0.3117):
#             {'C': 10, 'degree': 1, 'tol': 10, 'max_iter': 100, 'gamma': 'auto', 'features': 0}
#             Current best combo (with val score 0.4424):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'scale', 'features': 2}
#         Has trained 5840 of 186624 combinations so far
# Already Trained and Tested combination (val score of 0.3117):
#             {'C': 10, 'degree': 1, 'tol': 10, 'max_iter': 50, 'gamma': 'scale', 'features': 0}
#             Current best combo (with val score 0.4424):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'scale', 'features': 2}
#         Has trained 5840 of 186624 combinations so far
# Already Trained and Tested combination (val score of 0.3117):
#             {'C': 10, 'degree': 1, 'tol': 10, 'max_iter': 50, 'gamma': 'auto', 'features': 1}
#             Current best combo (with val score 0.4424):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'scale', 'features': 2}
#         Has trained 5840 of 186624 combinations so far
# 	round 303 iteration:  1
#
# Already Trained and Tested combination (val score of 0.3117):
#             {'C': 0.1, 'degree': 1, 'tol': 10, 'max_iter': 50, 'gamma': 'auto', 'features': 0}
#             Current best combo (with val score 0.4424):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'scale', 'features': 2}
#         Has trained 5840 of 186624 combinations so far
# Already Trained and Tested combination (val score of 0.3117):
#             {'C': 10, 'degree': 1, 'tol': 10, 'max_iter': 50, 'gamma': 'auto', 'features': 0}
#             Current best combo (with val score 0.4424):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'scale', 'features': 2}
#         Has trained 5840 of 186624 combinations so far
# Already Trained and Tested combination (val score of 0.3117):
#             {'C': 1, 'degree': 2, 'tol': 10, 'max_iter': 50, 'gamma': 'auto', 'features': 0}
#             Current best combo (with val score 0.4424):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'scale', 'features': 2}
#         Has trained 5840 of 186624 combinations so far
# Already Trained and Tested combination (val score of 0.3117):
#             {'C': 1, 'degree': 1, 'tol': 1, 'max_iter': 50, 'gamma': 'auto', 'features': 0}
#             Current best combo (with val score 0.4424):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'scale', 'features': 2}
#         Has trained 5840 of 186624 combinations so far
# Already Trained and Tested combination (val score of 0.3117):
#             {'C': 1, 'degree': 1, 'tol': 10, 'max_iter': 100, 'gamma': 'auto', 'features': 0}
#             Current best combo (with val score 0.4424):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'scale', 'features': 2}
#         Has trained 5840 of 186624 combinations so far
# Already Trained and Tested combination (val score of 0.3117):
#             {'C': 1, 'degree': 1, 'tol': 10, 'max_iter': 50, 'gamma': 'scale', 'features': 0}
#             Current best combo (with val score 0.4424):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'scale', 'features': 2}
#         Has trained 5840 of 186624 combinations so far
# Already Trained and Tested combination (val score of 0.3117):
#             {'C': 1, 'degree': 1, 'tol': 10, 'max_iter': 50, 'gamma': 'auto', 'features': 1}
#             Current best combo (with val score 0.4424):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'scale', 'features': 2}
#         Has trained 5840 of 186624 combinations so far
# Already Trained and Tested combination (val score of 0.3117):
#             {'C': 1, 'degree': 2, 'tol': 10, 'max_iter': 50, 'gamma': 'auto', 'features': 0}
#             Current best combo (with val score 0.4424):
# ...
#         Has trained 6221 of 186624 combinations so far
# Already Trained and Tested combination (val score of 0.4424):
#             {'C': 0.0001, 'degree': 1, 'tol': 0.001, 'max_iter': 400, 'gamma': 'scale', 'features': 2}
#             Current best combo (with val score 0.4424):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'scale', 'features': 2}
#         Has trained 6221 of 186624 combinations so far
# Already Trained and Tested combination (val score of 0.4117):
#             {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 200, 'gamma': 'scale', 'features': 2}
#             Current best combo (with val score 0.4424):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'scale', 'features': 2}
#         Has trained 6221 of 186624 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 800, 'gamma': 'scale', 'features': 2}
#             Current best combo (with val score 0.4424):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'scale', 'features': 2}
#         Has trained 6221 of 186624 combinations so far
# Already Trained and Tested combination (val score of 0.4422):
#             {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'auto', 'features': 2}
#             Current best combo (with val score 0.4424):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'scale', 'features': 2}
#         Has trained 6221 of 186624 combinations so far
# Already Trained and Tested combination (val score of 0.4422):
#             {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'scale', 'features': 1}
#             Current best combo (with val score 0.4424):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'scale', 'features': 2}
#         Has trained 6221 of 186624 combinations so far
# Already Trained and Tested combination (val score of 0.3672):
#             {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'scale', 'features': 3}
#             Current best combo (with val score 0.4424):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'scale', 'features': 2}
#         Has trained 6221 of 186624 combinations so far
# 	round FINAL iteration:  1
#
# Already Trained and Tested combination (val score of 0.4424):
#             {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'scale', 'features': 2}
#             Current best combo (with val score 0.4424):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'scale', 'features': 2}
#         Has trained 6221 of 186624 combinations so far
# Trained and Tested combination 6222 of 186624, taking 0.05 seconds to get val score of 0.4424:
#                 {'C': 0.01, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'scale', 'features': 2},
#             Current best combo with val score 0.4424:
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'scale', 'features': 2}
# Trained and Tested combination 6223 of 186624, taking 0.06 seconds to get val score of 0.4368:
#                 {'C': 0.001, 'degree': 2, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'scale', 'features': 2},
#             Current best combo with val score 0.4424:
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'scale', 'features': 2}
# Trained and Tested combination 6224 of 186624, taking 0.05 seconds to get val score of 0.4424:
#                 {'C': 0.001, 'degree': 1, 'tol': 0.001, 'max_iter': 400, 'gamma': 'scale', 'features': 2},
#             Current best combo with val score 0.4424:
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'scale', 'features': 2}
# Trained and Tested combination 6225 of 186624, taking 0.03 seconds to get val score of 0.4117:
#                 {'C': 0.001, 'degree': 1, 'tol': 0.0001, 'max_iter': 200, 'gamma': 'scale', 'features': 2},
#             Current best combo with val score 0.4424:
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'scale', 'features': 2}
# Trained and Tested combination 6226 of 186624, taking 0.16 seconds to get val score of 0.0:
#                 {'C': 0.001, 'degree': 1, 'tol': 0.0001, 'max_iter': 800, 'gamma': 'scale', 'features': 2},
#             Current best combo with val score 0.4424:
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'scale', 'features': 2}
# Trained and Tested combination 6227 of 186624, taking 0.05 seconds to get val score of 0.4422:
#                 {'C': 0.001, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'auto', 'features': 2},
#             Current best combo with val score 0.4424:
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'scale', 'features': 2}
# Already Trained and Tested combination (val score of 0.4422):
#             {'C': 0.001, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'scale', 'features': 1}
#             Current best combo (with val score 0.4424):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'scale', 'features': 2}
#         Has trained 6227 of 186624 combinations so far
# Trained and Tested combination 6228 of 186624, taking 0.06 seconds to get val score of 0.386:
#                 {'C': 0.001, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'scale', 'features': 3},
#             Current best combo with val score 0.4424:
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'scale', 'features': 2}
# Already Trained and Tested combination (val score of 0.4424):
#             {'C': 0.001, 'degree': 1, 'tol': 0.001, 'max_iter': 400, 'gamma': 'scale', 'features': 2}
#             Current best combo (with val score 0.4424):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'scale', 'features': 2}
#         Has trained 6228 of 186624 combinations so far
# Trained and Tested combination 6229 of 186624, taking 0.07 seconds to get val score of 0.4368:
#                 {'C': 0.0001, 'degree': 2, 'tol': 0.001, 'max_iter': 400, 'gamma': 'scale', 'features': 2},
#             Current best combo with val score 0.4424:
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'scale', 'features': 2}
# Already Trained and Tested combination (val score of 0.4424):
#             {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'scale', 'features': 2}
#             Current best combo (with val score 0.4424):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'scale', 'features': 2}
#         Has trained 6229 of 186624 combinations so far
# Trained and Tested combination 6230 of 186624, taking 0.1 seconds to get val score of 0.4424:
#                 {'C': 0.0001, 'degree': 1, 'tol': 0.01, 'max_iter': 400, 'gamma': 'scale', 'features': 2},
#             Current best combo with val score 0.4424:
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'scale', 'features': 2}
# Trained and Tested combination 6231 of 186624, taking 0.03 seconds to get val score of 0.4117:
#                 {'C': 0.0001, 'degree': 1, 'tol': 0.001, 'max_iter': 200, 'gamma': 'scale', 'features': 2},
#             Current best combo with val score 0.4424:
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'scale', 'features': 2}
# Trained and Tested combination 6232 of 186624, taking 0.07 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'degree': 1, 'tol': 0.001, 'max_iter': 800, 'gamma': 'scale', 'features': 2},
#             Current best combo with val score 0.4424:
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'scale', 'features': 2}
# Trained and Tested combination 6233 of 186624, taking 0.05 seconds to get val score of 0.4422:
#                 {'C': 0.0001, 'degree': 1, 'tol': 0.001, 'max_iter': 400, 'gamma': 'auto', 'features': 2},
#             Current best combo with val score 0.4424:
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'scale', 'features': 2}
# Already Trained and Tested combination (val score of 0.4422):
#             {'C': 0.0001, 'degree': 1, 'tol': 0.001, 'max_iter': 400, 'gamma': 'scale', 'features': 1}
#             Current best combo (with val score 0.4424):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'scale', 'features': 2}
#         Has trained 6233 of 186624 combinations so far
# Trained and Tested combination 6234 of 186624, taking 0.06 seconds to get val score of 0.3672:
#                 {'C': 0.0001, 'degree': 1, 'tol': 0.001, 'max_iter': 400, 'gamma': 'scale', 'features': 3},
#             Current best combo with val score 0.4424:
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'scale', 'features': 2}
# Already Trained and Tested combination (val score of 0.4422):
#             {'C': 0.001, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'auto', 'features': 2}
#             Current best combo (with val score 0.4424):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'scale', 'features': 2}
#         Has trained 6234 of 186624 combinations so far
# Trained and Tested combination 6235 of 186624, taking 0.13 seconds to get val score of 0.4368:
#                 {'C': 0.0001, 'degree': 2, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'auto', 'features': 2},
#             Current best combo with val score 0.4424:
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'scale', 'features': 2}
# Already Trained and Tested combination (val score of 0.4422):
#             {'C': 0.0001, 'degree': 1, 'tol': 0.001, 'max_iter': 400, 'gamma': 'auto', 'features': 2}
#             Current best combo (with val score 0.4424):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'scale', 'features': 2}
#         Has trained 6235 of 186624 combinations so far
# Trained and Tested combination 6236 of 186624, taking 0.03 seconds to get val score of 0.4347:
#                 {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 200, 'gamma': 'auto', 'features': 2},
#             Current best combo with val score 0.4424:
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'scale', 'features': 2}
# Trained and Tested combination 6237 of 186624, taking 0.07 seconds to get val score of 0.0:
#                 {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 800, 'gamma': 'auto', 'features': 2},
#             Current best combo with val score 0.4424:
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'scale', 'features': 2}
# Already Trained and Tested combination (val score of 0.4424):
#             {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'scale', 'features': 2}
#             Current best combo (with val score 0.4424):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'scale', 'features': 2}
#         Has trained 6237 of 186624 combinations so far
# Already Trained and Tested combination (val score of 0.4422):
#             {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'auto', 'features': 1}
#             Current best combo (with val score 0.4424):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'scale', 'features': 2}
#         Has trained 6237 of 186624 combinations so far
# Trained and Tested combination 6238 of 186624, taking 0.06 seconds to get val score of 0.3539:
#                 {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'auto', 'features': 3},
#             Current best combo with val score 0.4424:
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'scale', 'features': 2}
# Already Trained and Tested combination (val score of 0.4422):
#             {'C': 0.001, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'scale', 'features': 1}
#             Current best combo (with val score 0.4424):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'scale', 'features': 2}
#         Has trained 6238 of 186624 combinations so far
# Already Trained and Tested combination (val score of 0.3578):
#             {'C': 0.0001, 'degree': 2, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'scale', 'features': 1}
#             Current best combo (with val score 0.4424):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'scale', 'features': 2}
#         Has trained 6238 of 186624 combinations so far
# Already Trained and Tested combination (val score of 0.4422):
#             {'C': 0.0001, 'degree': 1, 'tol': 0.001, 'max_iter': 400, 'gamma': 'scale', 'features': 1}
#             Current best combo (with val score 0.4424):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'scale', 'features': 2}
#         Has trained 6238 of 186624 combinations so far
# Already Trained and Tested combination (val score of 0.4126):
#             {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 200, 'gamma': 'scale', 'features': 1}
#             Current best combo (with val score 0.4424):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'scale', 'features': 2}
#         Has trained 6238 of 186624 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 800, 'gamma': 'scale', 'features': 1}
#             Current best combo (with val score 0.4424):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'scale', 'features': 2}
#         Has trained 6238 of 186624 combinations so far
# Already Trained and Tested combination (val score of 0.4422):
#             {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'auto', 'features': 1}
#             Current best combo (with val score 0.4424):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'scale', 'features': 2}
#         Has trained 6238 of 186624 combinations so far
# Already Trained and Tested combination (val score of 0.1301):
#             {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'scale', 'features': 0}
#             Current best combo (with val score 0.4424):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'scale', 'features': 2}
#         Has trained 6238 of 186624 combinations so far
# Already Trained and Tested combination (val score of 0.4424):
#             {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'scale', 'features': 2}
#             Current best combo (with val score 0.4424):
#                     {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'scale', 'features': 2}
#         Has trained 6238 of 186624 combinations so far
# % Combos Checked Thus Far: 6238 out of 186624 which is 3.3425499999999997%
# Max Val Score:
#  0.442366
# Max Val Score Std:
#  0.035228
# Best Combo Train Score:
#  0.439633
# Best Combo Train Score Std:
#  0.005737
# Max Combo Index:
#  (0, 0, 0, 3, 1, 2) out of [6, 9, 6, 6, 2, 48] (note best combo is 0-indexed)
# Max Combo Hyperparamer Combination:
#  {'C': 0.0001, 'degree': 1, 'tol': 0.0001, 'max_iter': 400, 'gamma': 'scale', 'features': 2}
# Max Combo Features:
#  ('procedure_225792', 'ventilation_used', 'procedure_226475')
# % Combos Checked: 6238 out of 186624 which is 3.3425499999999997%
