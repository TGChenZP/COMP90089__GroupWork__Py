# %% [markdown]
# # Tuning Script

# %%
# Parameters subject to change in every script - involved in naming

MODEL = 'lgbc'
PREPROCESSING = 'normalise'
TUNER = 'yangzhoub'
OPTIMISED_METRIC = 'f1'

# %% [markdown]
# ---

# %%
# detect whether this is a google environment

COLAB_ENVIRONMENT = False

try:
    from google.colab import drive
    drive.mount('/content/drive')
    COLAB_ENVIRONMENT = True
except:
    pass
# Out:
# Mounted at /content/drive

# %%
import sys
import os
import pickle

if COLAB_ENVIRONMENT:
    home_directory = './drive/MyDrive/LAB/COMP90089__GroupWork__Py/' # my home directory is stored in ./LAB of google drive
    if MODEL == 'ebr':
        # !pip install interpret==0.5.0
    elif MODEL == 'cbr':
        # !pip install catboost
    elif MODEL in ['tf', 'mlp']:
        # !pip install PyTorch2Sklearn
    # !pip install JXAutoML
else:
    home_directory = '../../'

from JXAutoML.YangZhouB_10CV import YangZhouB_10CV as Tuner

import pandas as pd
# Out:
# Collecting JXAutoML
#   Downloading JXAutoML-0.4.4-py3-none-any.whl.metadata (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.2/67.2 kB 4.8 MB/s eta 0:00:00
# Downloading JXAutoML-0.4.4-py3-none-any.whl (52 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.1/52.1 kB 3.9 MB/s eta 0:00:00
# Installing collected packages: JXAutoML
# Successfully installed JXAutoML-0.4.4

# %%
# Parameters that are same for every script

FOLDS = 10  # we have decided to do 10 fold validation

SEED = 42

TASK_TYPE = 'Classification'  # this task is a classification task

# we have decided to tune features as hp
TUNE_FEATURES_AS_HYPERPARAMETERS = True

# %% [markdown]
# ---

# %%
# model to use to tune
from lightgbm import LGBMClassifier as clf

# what values to try for each hyperparameter
parameter_choices = {
    'n_estimators': (25, 50, 100, 200, 400, 800),
    'max_depth': (3, 6, 12, 24, 48, 96, 192),
    'subsample': (0.4, 0.55, 0.7, 0.85, 1),
    'colsample_bytree': (0.4, 0.55, 0.7, 0.85, 1),
    'learning_rate': (0.00000001, 0.000001, 0.0001, 0.01, 0.1),
    'reg_alpha': (0.0001, 0.001, 0.01, 0.1, 1, 10)
}

# what values to set non-tuneable parameters/hyperparameters
non_tunable_hyperparameters_dict = {
                                    'random_state': SEED,
                                    'n_jobs': -1,
                                    'verbose': -1
                                    }
# Out:
# /usr/local/lib/python3.10/dist-packages/dask/dataframe/__init__.py:42: FutureWarning:
# Dask dataframe query planning is disabled because dask-expr is not installed.
#
# You can install it with `pip install dask[dataframe]` or `conda install dask`.
# This will raise in a future version.
#
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ---

# %% [markdown]
# Read in and Prepare Data

# %%
# Import data and store as lists

train_x_list = []
train_y_list = []
val_x_list = []
val_y_list = []

for i in range(FOLDS):
    train_data = pd.read_csv(
        f'{home_directory}data/curated/modelling/{PREPROCESSING}/train_{i}.csv')
    val_data = pd.read_csv(
        f'{home_directory}data/curated/modelling/{PREPROCESSING}/val_{i}.csv')

    # get the correct rows for X and y
    train_x = train_data.drop(
        ['mortality_status', 'subject_id', 'hadm_id', 'stay_id'], axis=1)
    train_y = train_data['mortality_status']
    val_x = val_data.drop(
        ['mortality_status', 'subject_id', 'hadm_id', 'stay_id'], axis=1)
    val_y = val_data['mortality_status']

    train_x_list.append(train_x)
    train_y_list.append(train_y)
    val_x_list.append(val_x)
    val_y_list.append(val_y)

# %%
# Import feature importance ordering

with open(f'{home_directory}models/xgb_feature_importance_ordering_{PREPROCESSING}.pickle', 'rb') as f:
    feature_importance_ordering = pickle.load(f)

# %% [markdown]
# Set parameters

# %%
# initialisation
tuner = Tuner()

print('---')

# define what model we are tuning
tuner.read_in_model(clf, TASK_TYPE, optimised_metric=OPTIMISED_METRIC)

print('---')

# read in the data for training and validation
tuner.read_in_data(train_x_list, train_y_list, val_x_list, val_y_list)

print('---')

# set what hp values to tune
tuner.set_hyperparameters(parameter_choices)
# WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

# set up hp values that need to be changed from default but NOT to be tuned
tuner.set_non_tuneable_hyperparameters(non_tunable_hyperparameters_dict)

print('---')

# set up feature importance ordering

if TUNE_FEATURES_AS_HYPERPARAMETERS:
    tuner.set_features(feature_importance_ordering)
    # WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

try:  # try to read in previous results to continue tuning ...
    tuner.read_in_tuning_result_df(
        f'{home_directory}models/tuning/{TUNER}_{MODEL}_{PREPROCESSING}.csv')
except:
    print('No previous tuning data read in')

print('---')

# set up where to save the tuning result csv
tuner.set_tuning_result_saving_address(
    f'{home_directory}models/tuning/{TUNER}_{MODEL}_{PREPROCESSING}.csv')

print('---')

# set up where to save the current best model
tuner.set_best_model_saving_address(
    f'{home_directory}models/tmp_models/{TUNER}_{MODEL}_{PREPROCESSING}')
# Out:
# YangZhouB Initialised
# ---
# Successfully read in model <class 'lightgbm.sklearn.LGBMClassifier'>, which is a Classification model optimising for f1
# ---
# Read in Train X data list
# Read in Train y data list
# Read in Val X data list
# Read in Val y data list
# ---
# Successfully recorded hyperparameter choices
# ---
# Successfully recorded non_tuneable_hyperparameter choices
# ---
# Successfully recorded tuneable feature combination choices and updated relevant internal structures
# ---
# Successfully read in tuning result of 5642 rows, for 5642.0 combos
# ---
# Successfully set tuning output address
# ---
# Successfully set best model output address

# %%
# ignore warnings

import warnings
warnings.filterwarnings("ignore")

# %%
# begin tuning ... (or continue training)

tuner.tune()
# Out:
# Streaming output truncated to the last 5000 lines.
#             Current best combo (with val score 0.5207):
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.001, 'features': 19}
#         Has trained 5642 of 1606500 combinations so far
# % Combos Checked Thus Far: 5642 out of 1606500 which is 0.351198%
# Cruising Coordrdinate 999 of 1056
#
# Cruising Coordrdinate 1000 of 1056
#
# Cruising Coordrdinate 1001 of 1056
#
# Cruising Coordrdinate 1002 of 1056
#
# Cruising Coordrdinate 1003 of 1056
#
# Cruising Coordrdinate 1004 of 1056
#
# Cruising Coordrdinate 1005 of 1056
#
# Cruising Coordrdinate 1006 of 1056
#
# Cruising Coordrdinate 1007 of 1056
#
# Cruising Coordrdinate 1008 of 1056
#
# Cruising Coordrdinate 1009 of 1056
#
# Cruising Coordrdinate 1010 of 1056
#
# Cruising Coordrdinate 1011 of 1056
#
# Cruising Coordrdinate 1012 of 1056
#
# Cruising Coordrdinate 1013 of 1056
#
# Cruising Coordrdinate 1014 of 1056
#
# Cruising Coordrdinate 1015 of 1056
#
# Cruising Coordrdinate 1016 of 1056
#
# Cruising Coordrdinate 1017 of 1056
#
# Cruising Coordrdinate 1018 of 1056
#
# Cruising Coordrdinate 1019 of 1056
#
# Cruising Coordrdinate 1020 of 1056
#
# Cruise suspended due to suspicious case
# Guidance: round 108
#
# 	round 108 iteration:  0
#
# Already Trained and Tested combination (val score of 0.4765):
#             {'n_estimators': 400, 'max_depth': 24, 'subsample': 1, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 15}
#             Current best combo (with val score 0.5207):
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.001, 'features': 19}
#         Has trained 5642 of 1606500 combinations so far
# Already Trained and Tested combination (val score of 0.4722):
#             {'n_estimators': 800, 'max_depth': 12, 'subsample': 1, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 15}
#             Current best combo (with val score 0.5207):
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.001, 'features': 19}
#         Has trained 5642 of 1606500 combinations so far
# Already Trained and Tested combination (val score of 0.4796):
#             {'n_estimators': 800, 'max_depth': 48, 'subsample': 1, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 15}
#             Current best combo (with val score 0.5207):
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.001, 'features': 19}
#         Has trained 5642 of 1606500 combinations so far
# Already Trained and Tested combination (val score of 0.4783):
#             {'n_estimators': 800, 'max_depth': 24, 'subsample': 0.85, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 15}
#             Current best combo (with val score 0.5207):
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.001, 'features': 19}
#         Has trained 5642 of 1606500 combinations so far
# Already Trained and Tested combination (val score of 0.5006):
#             {'n_estimators': 800, 'max_depth': 24, 'subsample': 1, 'colsample_bytree': 0.85, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 15}
#             Current best combo (with val score 0.5207):
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.001, 'features': 19}
#         Has trained 5642 of 1606500 combinations so far
# Already Trained and Tested combination (val score of 0.3946):
#             {'n_estimators': 800, 'max_depth': 24, 'subsample': 1, 'colsample_bytree': 1, 'learning_rate': 0.01, 'reg_alpha': 0.0001, 'features': 15}
#             Current best combo (with val score 0.5207):
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.001, 'features': 19}
#         Has trained 5642 of 1606500 combinations so far
# Already Trained and Tested combination (val score of 0.4731):
#             {'n_estimators': 800, 'max_depth': 24, 'subsample': 1, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.001, 'features': 15}
#             Current best combo (with val score 0.5207):
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.001, 'features': 19}
#         Has trained 5642 of 1606500 combinations so far
# Already Trained and Tested combination (val score of 0.4428):
#             {'n_estimators': 800, 'max_depth': 24, 'subsample': 1, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 14}
#             Current best combo (with val score 0.5207):
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.001, 'features': 19}
#         Has trained 5642 of 1606500 combinations so far
# Already Trained and Tested combination (val score of 0.4703):
#             {'n_estimators': 800, 'max_depth': 24, 'subsample': 1, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 16}
#             Current best combo (with val score 0.5207):
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.001, 'features': 19}
#         Has trained 5642 of 1606500 combinations so far
# 	round 108 iteration:  1
#
# Already Trained and Tested combination (val score of 0.4353):
#             {'n_estimators': 200, 'max_depth': 24, 'subsample': 1, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 15}
#             Current best combo (with val score 0.5207):
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.001, 'features': 19}
#         Has trained 5642 of 1606500 combinations so far
# Already Trained and Tested combination (val score of 0.4783):
#             {'n_estimators': 800, 'max_depth': 24, 'subsample': 1, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 15}
#             Current best combo (with val score 0.5207):
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.001, 'features': 19}
#         Has trained 5642 of 1606500 combinations so far
# Already Trained and Tested combination (val score of 0.4686):
#             {'n_estimators': 400, 'max_depth': 12, 'subsample': 1, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 15}
#             Current best combo (with val score 0.5207):
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.001, 'features': 19}
#         Has trained 5642 of 1606500 combinations so far
# Already Trained and Tested combination (val score of 0.4765):
#             {'n_estimators': 400, 'max_depth': 48, 'subsample': 1, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 15}
#             Current best combo (with val score 0.5207):
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.001, 'features': 19}
#         Has trained 5642 of 1606500 combinations so far
# Already Trained and Tested combination (val score of 0.4765):
#             {'n_estimators': 400, 'max_depth': 24, 'subsample': 0.85, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 15}
#             Current best combo (with val score 0.5207):
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.001, 'features': 19}
#         Has trained 5642 of 1606500 combinations so far
# Already Trained and Tested combination (val score of 0.491):
#             {'n_estimators': 400, 'max_depth': 24, 'subsample': 1, 'colsample_bytree': 0.85, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 15}
#             Current best combo (with val score 0.5207):
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.001, 'features': 19}
#         Has trained 5642 of 1606500 combinations so far
# Already Trained and Tested combination (val score of 0.1965):
#             {'n_estimators': 400, 'max_depth': 24, 'subsample': 1, 'colsample_bytree': 1, 'learning_rate': 0.01, 'reg_alpha': 0.0001, 'features': 15}
#             Current best combo (with val score 0.5207):
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.001, 'features': 19}
#         Has trained 5642 of 1606500 combinations so far
# Already Trained and Tested combination (val score of 0.484):
#             {'n_estimators': 400, 'max_depth': 24, 'subsample': 1, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.001, 'features': 15}
#             Current best combo (with val score 0.5207):
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.001, 'features': 19}
#         Has trained 5642 of 1606500 combinations so far
# Already Trained and Tested combination (val score of 0.4422):
#             {'n_estimators': 400, 'max_depth': 24, 'subsample': 1, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 14}
#             Current best combo (with val score 0.5207):
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.001, 'features': 19}
#         Has trained 5642 of 1606500 combinations so far
# Already Trained and Tested combination (val score of 0.4827):
#             {'n_estimators': 400, 'max_depth': 24, 'subsample': 1, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 16}
#             Current best combo (with val score 0.5207):
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.001, 'features': 19}
#         Has trained 5642 of 1606500 combinations so far
# Already Trained and Tested combination (val score of 0.4765):
#             {'n_estimators': 400, 'max_depth': 24, 'subsample': 0.85, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 15}
#             Current best combo (with val score 0.5207):
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.001, 'features': 19}
#         Has trained 5642 of 1606500 combinations so far
# Already Trained and Tested combination (val score of 0.4722):
#             {'n_estimators': 800, 'max_depth': 12, 'subsample': 0.85, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 15}
#             Current best combo (with val score 0.5207):
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.001, 'features': 19}
#         Has trained 5642 of 1606500 combinations so far
# Already Trained and Tested combination (val score of 0.4796):
#             {'n_estimators': 800, 'max_depth': 48, 'subsample': 0.85, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 15}
#             Current best combo (with val score 0.5207):
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.001, 'features': 19}
#         Has trained 5642 of 1606500 combinations so far
# Already Trained and Tested combination (val score of 0.4783):
#             {'n_estimators': 800, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 15}
#             Current best combo (with val score 0.5207):
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.001, 'features': 19}
#         Has trained 5642 of 1606500 combinations so far
# Already Trained and Tested combination (val score of 0.4783):
#             {'n_estimators': 800, 'max_depth': 24, 'subsample': 1, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 15}
#             Current best combo (with val score 0.5207):
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.001, 'features': 19}
#         Has trained 5642 of 1606500 combinations so far
# Already Trained and Tested combination (val score of 0.5006):
#             {'n_estimators': 800, 'max_depth': 24, 'subsample': 0.85, 'colsample_bytree': 0.85, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 15}
#             Current best combo (with val score 0.5207):
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.001, 'features': 19}
#         Has trained 5642 of 1606500 combinations so far
# Already Trained and Tested combination (val score of 0.3946):
#             {'n_estimators': 800, 'max_depth': 24, 'subsample': 0.85, 'colsample_bytree': 1, 'learning_rate': 0.01, 'reg_alpha': 0.0001, 'features': 15}
#             Current best combo (with val score 0.5207):
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.001, 'features': 19}
#         Has trained 5642 of 1606500 combinations so far
# Already Trained and Tested combination (val score of 0.4731):
#             {'n_estimators': 800, 'max_depth': 24, 'subsample': 0.85, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.001, 'features': 15}
#             Current best combo (with val score 0.5207):
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.001, 'features': 19}
#         Has trained 5642 of 1606500 combinations so far
# Already Trained and Tested combination (val score of 0.4428):
#             {'n_estimators': 800, 'max_depth': 24, 'subsample': 0.85, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 14}
#             Current best combo (with val score 0.5207):
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.001, 'features': 19}
#         Has trained 5642 of 1606500 combinations so far
# Already Trained and Tested combination (val score of 0.4703):
#             {'n_estimators': 800, 'max_depth': 24, 'subsample': 0.85, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 16}
#             Current best combo (with val score 0.5207):
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.001, 'features': 19}
#         Has trained 5642 of 1606500 combinations so far
# Already Trained and Tested combination (val score of 0.491):
#             {'n_estimators': 400, 'max_depth': 24, 'subsample': 1, 'colsample_bytree': 0.85, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 15}
#             Current best combo (with val score 0.5207):
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.001, 'features': 19}
#         Has trained 5642 of 1606500 combinations so far
# Already Trained and Tested combination (val score of 0.4619):
#             {'n_estimators': 800, 'max_depth': 12, 'subsample': 1, 'colsample_bytree': 0.85, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 15}
#             Current best combo (with val score 0.5207):
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.001, 'features': 19}
#         Has trained 5642 of 1606500 combinations so far
# Already Trained and Tested combination (val score of 0.4979):
#             {'n_estimators': 800, 'max_depth': 48, 'subsample': 1, 'colsample_bytree': 0.85, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 15}
#             Current best combo (with val score 0.5207):
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.001, 'features': 19}
#         Has trained 5642 of 1606500 combinations so far
# Already Trained and Tested combination (val score of 0.5006):
#             {'n_estimators': 800, 'max_depth': 24, 'subsample': 0.85, 'colsample_bytree': 0.85, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 15}
#             Current best combo (with val score 0.5207):
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.001, 'features': 19}
#         Has trained 5642 of 1606500 combinations so far
# Already Trained and Tested combination (val score of 0.4906):
#             {'n_estimators': 800, 'max_depth': 24, 'subsample': 1, 'colsample_bytree': 0.7, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 15}
#             Current best combo (with val score 0.5207):
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.001, 'features': 19}
#         Has trained 5642 of 1606500 combinations so far
# Already Trained and Tested combination (val score of 0.4783):
#             {'n_estimators': 800, 'max_depth': 24, 'subsample': 1, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 15}
#             Current best combo (with val score 0.5207):
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.001, 'features': 19}
#         Has trained 5642 of 1606500 combinations so far
# Already Trained and Tested combination (val score of 0.4273):
#             {'n_estimators': 800, 'max_depth': 24, 'subsample': 1, 'colsample_bytree': 0.85, 'learning_rate': 0.01, 'reg_alpha': 0.0001, 'features': 15}
#             Current best combo (with val score 0.5207):
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.001, 'features': 19}
#         Has trained 5642 of 1606500 combinations so far
# Already Trained and Tested combination (val score of 0.48):
#             {'n_estimators': 800, 'max_depth': 24, 'subsample': 1, 'colsample_bytree': 0.85, 'learning_rate': 0.1, 'reg_alpha': 0.001, 'features': 15}
#             Current best combo (with val score 0.5207):
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.001, 'features': 19}
#         Has trained 5642 of 1606500 combinations so far
# Already Trained and Tested combination (val score of 0.4547):
#             {'n_estimators': 800, 'max_depth': 24, 'subsample': 1, 'colsample_bytree': 0.85, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 14}
#             Current best combo (with val score 0.5207):
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.001, 'features': 19}
#         Has trained 5642 of 1606500 combinations so far
# Already Trained and Tested combination (val score of 0.4819):
#             {'n_estimators': 800, 'max_depth': 24, 'subsample': 1, 'colsample_bytree': 0.85, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 16}
#             Current best combo (with val score 0.5207):
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.001, 'features': 19}
#         Has trained 5642 of 1606500 combinations so far
# % Combos Checked Thus Far: 5642 out of 1606500 which is 0.351198%
# Cruising Coordrdinate 1021 of 1056
#
# Cruising Coordrdinate 1022 of 1056
#
# Cruising Coordrdinate 1023 of 1056
#
# Cruising Coordrdinate 1024 of 1056
#
# Cruising Coordrdinate 1025 of 1056
#
# Cruising Coordrdinate 1026 of 1056
#
# Cruising Coordrdinate 1027 of 1056
#
# Cruise suspended due to suspicious case
# Guidance: round 109
#
# 	round 109 iteration:  0
#
# Already Trained and Tested combination (val score of 0.3759):
#             {'n_estimators': 400, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 20}
#             Current best combo (with val score 0.5207):
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.001, 'features': 19}
#         Has trained 5642 of 1606500 combinations so far
# Already Trained and Tested combination (val score of 0.3949):
#             {'n_estimators': 800, 'max_depth': 96, 'subsample': 1, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 20}
#             Current best combo (with val score 0.5207):
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.001, 'features': 19}
#         Has trained 5642 of 1606500 combinations so far
# Already Trained and Tested combination (val score of 0.3949):
#             {'n_estimators': 800, 'max_depth': 192, 'subsample': 0.85, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 20}
#             Current best combo (with val score 0.5207):
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.001, 'features': 19}
#         Has trained 5642 of 1606500 combinations so far
# Already Trained and Tested combination (val score of 0.4068):
#             {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.85, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 20}
#             Current best combo (with val score 0.5207):
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.001, 'features': 19}
#         Has trained 5642 of 1606500 combinations so far
# Already Trained and Tested combination (val score of 0.3625):
#             {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 1, 'learning_rate': 0.01, 'reg_alpha': 0.0001, 'features': 20}
#             Current best combo (with val score 0.5207):
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.001, 'features': 19}
#         Has trained 5642 of 1606500 combinations so far
# Already Trained and Tested combination (val score of 0.4118):
#             {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.001, 'features': 20}
#             Current best combo (with val score 0.5207):
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.001, 'features': 19}
#         Has trained 5642 of 1606500 combinations so far
# Already Trained and Tested combination (val score of 0.407):
#             {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 19}
#             Current best combo (with val score 0.5207):
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.001, 'features': 19}
#         Has trained 5642 of 1606500 combinations so far
# Already Trained and Tested combination (val score of 0.3352):
#             {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 21}
#             Current best combo (with val score 0.5207):
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.001, 'features': 19}
#         Has trained 5642 of 1606500 combinations so far
# 	round 109 iteration:  1
#
# Already Trained and Tested combination (val score of 0.3759):
#             {'n_estimators': 400, 'max_depth': 96, 'subsample': 1, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 20}
#             Current best combo (with val score 0.5207):
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.001, 'features': 19}
#         Has trained 5642 of 1606500 combinations so far
# Already Trained and Tested combination (val score of 0.3949):
#             {'n_estimators': 800, 'max_depth': 48, 'subsample': 1, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 20}
#             Current best combo (with val score 0.5207):
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.001, 'features': 19}
#         Has trained 5642 of 1606500 combinations so far
# Already Trained and Tested combination (val score of 0.3949):
#             {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 20}
#             Current best combo (with val score 0.5207):
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.001, 'features': 19}
#         Has trained 5642 of 1606500 combinations so far
# Already Trained and Tested combination (val score of 0.3949):
#             {'n_estimators': 800, 'max_depth': 96, 'subsample': 0.85, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 20}
#             Current best combo (with val score 0.5207):
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.001, 'features': 19}
#         Has trained 5642 of 1606500 combinations so far
# Already Trained and Tested combination (val score of 0.4068):
#             {'n_estimators': 800, 'max_depth': 96, 'subsample': 1, 'colsample_bytree': 0.85, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 20}
#             Current best combo (with val score 0.5207):
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.001, 'features': 19}
#         Has trained 5642 of 1606500 combinations so far
# Already Trained and Tested combination (val score of 0.3625):
#             {'n_estimators': 800, 'max_depth': 96, 'subsample': 1, 'colsample_bytree': 1, 'learning_rate': 0.01, 'reg_alpha': 0.0001, 'features': 20}
#             Current best combo (with val score 0.5207):
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.001, 'features': 19}
#         Has trained 5642 of 1606500 combinations so far
# Already Trained and Tested combination (val score of 0.4118):
#             {'n_estimators': 800, 'max_depth': 96, 'subsample': 1, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.001, 'features': 20}
#             Current best combo (with val score 0.5207):
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.001, 'features': 19}
#         Has trained 5642 of 1606500 combinations so far
# Already Trained and Tested combination (val score of 0.407):
#             {'n_estimators': 800, 'max_depth': 96, 'subsample': 1, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 19}
#             Current best combo (with val score 0.5207):
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.001, 'features': 19}
#         Has trained 5642 of 1606500 combinations so far
# Already Trained and Tested combination (val score of 0.3352):
#             {'n_estimators': 800, 'max_depth': 96, 'subsample': 1, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 21}
#             Current best combo (with val score 0.5207):
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.001, 'features': 19}
#         Has trained 5642 of 1606500 combinations so far
# Already Trained and Tested combination (val score of 0.3759):
#             {'n_estimators': 400, 'max_depth': 192, 'subsample': 0.85, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 20}
#             Current best combo (with val score 0.5207):
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.001, 'features': 19}
#         Has trained 5642 of 1606500 combinations so far
# Already Trained and Tested combination (val score of 0.3949):
#             {'n_estimators': 800, 'max_depth': 96, 'subsample': 0.85, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 20}
#             Current best combo (with val score 0.5207):
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.001, 'features': 19}
#         Has trained 5642 of 1606500 combinations so far
# Already Trained and Tested combination (val score of 0.3949):
#             {'n_estimators': 800, 'max_depth': 192, 'subsample': 0.7, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 20}
#             Current best combo (with val score 0.5207):
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.001, 'features': 19}
#         Has trained 5642 of 1606500 combinations so far
# Already Trained and Tested combination (val score of 0.3949):
#             {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 20}
#             Current best combo (with val score 0.5207):
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.001, 'features': 19}
#         Has trained 5642 of 1606500 combinations so far
# Already Trained and Tested combination (val score of 0.4068):
#             {'n_estimators': 800, 'max_depth': 192, 'subsample': 0.85, 'colsample_bytree': 0.85, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 20}
#             Current best combo (with val score 0.5207):
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.001, 'features': 19}
#         Has trained 5642 of 1606500 combinations so far
# Already Trained and Tested combination (val score of 0.3625):
#             {'n_estimators': 800, 'max_depth': 192, 'subsample': 0.85, 'colsample_bytree': 1, 'learning_rate': 0.01, 'reg_alpha': 0.0001, 'features': 20}
#             Current best combo (with val score 0.5207):
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.001, 'features': 19}
#         Has trained 5642 of 1606500 combinations so far
# Already Trained and Tested combination (val score of 0.4118):
#             {'n_estimators': 800, 'max_depth': 192, 'subsample': 0.85, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.001, 'features': 20}
#             Current best combo (with val score 0.5207):
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.001, 'features': 19}
#         Has trained 5642 of 1606500 combinations so far
# Already Trained and Tested combination (val score of 0.407):
#             {'n_estimators': 800, 'max_depth': 192, 'subsample': 0.85, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 19}
#             Current best combo (with val score 0.5207):
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.001, 'features': 19}
#         Has trained 5642 of 1606500 combinations so far
# Already Trained and Tested combination (val score of 0.3352):
#             {'n_estimators': 800, 'max_depth': 192, 'subsample': 0.85, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 21}
#             Current best combo (with val score 0.5207):
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.001, 'features': 19}
#         Has trained 5642 of 1606500 combinations so far
# Already Trained and Tested combination (val score of 0.4078):
#             {'n_estimators': 400, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.85, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 20}
#             Current best combo (with val score 0.5207):
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.001, 'features': 19}
#         Has trained 5642 of 1606500 combinations so far
# Already Trained and Tested combination (val score of 0.4068):
#             {'n_estimators': 800, 'max_depth': 96, 'subsample': 1, 'colsample_bytree': 0.85, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 20}
#             Current best combo (with val score 0.5207):
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.001, 'features': 19}
#         Has trained 5642 of 1606500 combinations so far
# Already Trained and Tested combination (val score of 0.4068):
#             {'n_estimators': 800, 'max_depth': 192, 'subsample': 0.85, 'colsample_bytree': 0.85, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 20}
#             Current best combo (with val score 0.5207):
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.001, 'features': 19}
#         Has trained 5642 of 1606500 combinations so far
# Already Trained and Tested combination (val score of 0.4176):
#             {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.7, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 20}
#             Current best combo (with val score 0.5207):
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.001, 'features': 19}
#         Has trained 5642 of 1606500 combinations so far
# Already Trained and Tested combination (val score of 0.3949):
#             {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 20}
#             Current best combo (with val score 0.5207):
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.001, 'features': 19}
#         Has trained 5642 of 1606500 combinations so far
# Already Trained and Tested combination (val score of 0.4142):
#             {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.85, 'learning_rate': 0.01, 'reg_alpha': 0.0001, 'features': 20}
#             Current best combo (with val score 0.5207):
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.001, 'features': 19}
#         Has trained 5642 of 1606500 combinations so far
# Already Trained and Tested combination (val score of 0.419):
#             {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.85, 'learning_rate': 0.1, 'reg_alpha': 0.001, 'features': 20}
#             Current best combo (with val score 0.5207):
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.001, 'features': 19}
#         Has trained 5642 of 1606500 combinations so far
# Already Trained and Tested combination (val score of 0.4194):
#             {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.85, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 19}
#             Current best combo (with val score 0.5207):
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.001, 'features': 19}
#         Has trained 5642 of 1606500 combinations so far
# Already Trained and Tested combination (val score of 0.382):
#             {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.85, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 21}
#             Current best combo (with val score 0.5207):
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.001, 'features': 19}
#         Has trained 5642 of 1606500 combinations so far
# Already Trained and Tested combination (val score of 0.4144):
#             {'n_estimators': 400, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.001, 'features': 20}
#             Current best combo (with val score 0.5207):
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.001, 'features': 19}
#         Has trained 5642 of 1606500 combinations so far
# Already Trained and Tested combination (val score of 0.4118):
#             {'n_estimators': 800, 'max_depth': 96, 'subsample': 1, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.001, 'features': 20}
#             Current best combo (with val score 0.5207):
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.001, 'features': 19}
#         Has trained 5642 of 1606500 combinations so far
# Already Trained and Tested combination (val score of 0.4118):
#             {'n_estimators': 800, 'max_depth': 192, 'subsample': 0.85, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.001, 'features': 20}
#             Current best combo (with val score 0.5207):
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.001, 'features': 19}
#         Has trained 5642 of 1606500 combinations so far
# Already Trained and Tested combination (val score of 0.419):
#             {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.85, 'learning_rate': 0.1, 'reg_alpha': 0.001, 'features': 20}
#             Current best combo (with val score 0.5207):
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.001, 'features': 19}
#         Has trained 5642 of 1606500 combinations so far
# Already Trained and Tested combination (val score of 0.3532):
#             {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 1, 'learning_rate': 0.01, 'reg_alpha': 0.001, 'features': 20}
#             Current best combo (with val score 0.5207):
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.001, 'features': 19}
#         Has trained 5642 of 1606500 combinations so far
# Already Trained and Tested combination (val score of 0.3949):
#             {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 20}
#             Current best combo (with val score 0.5207):
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.001, 'features': 19}
#         Has trained 5642 of 1606500 combinations so far
# Already Trained and Tested combination (val score of 0.394):
#             {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.01, 'features': 20}
#             Current best combo (with val score 0.5207):
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.001, 'features': 19}
#         Has trained 5642 of 1606500 combinations so far
# Already Trained and Tested combination (val score of 0.3885):
#             {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.001, 'features': 19}
#             Current best combo (with val score 0.5207):
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.001, 'features': 19}
#         Has trained 5642 of 1606500 combinations so far
# Already Trained and Tested combination (val score of 0.3075):
#             {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.001, 'features': 21}
#             Current best combo (with val score 0.5207):
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.001, 'features': 19}
#         Has trained 5642 of 1606500 combinations so far
# Already Trained and Tested combination (val score of 0.3999):
#             {'n_estimators': 400, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 19}
#             Current best combo (with val score 0.5207):
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.001, 'features': 19}
#         Has trained 5642 of 1606500 combinations so far
# Already Trained and Tested combination (val score of 0.407):
#             {'n_estimators': 800, 'max_depth': 96, 'subsample': 1, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 19}
#             Current best combo (with val score 0.5207):
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.001, 'features': 19}
#         Has trained 5642 of 1606500 combinations so far
# Already Trained and Tested combination (val score of 0.407):
#             {'n_estimators': 800, 'max_depth': 192, 'subsample': 0.85, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 19}
#             Current best combo (with val score 0.5207):
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.001, 'features': 19}
#         Has trained 5642 of 1606500 combinations so far
# Already Trained and Tested combination (val score of 0.4194):
#             {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 0.85, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 19}
#             Current best combo (with val score 0.5207):
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.001, 'features': 19}
#         Has trained 5642 of 1606500 combinations so far
# Already Trained and Tested combination (val score of 0.3477):
#             {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 1, 'learning_rate': 0.01, 'reg_alpha': 0.0001, 'features': 19}
#             Current best combo (with val score 0.5207):
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.001, 'features': 19}
#         Has trained 5642 of 1606500 combinations so far
# Already Trained and Tested combination (val score of 0.3885):
#             {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.001, 'features': 19}
#             Current best combo (with val score 0.5207):
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.001, 'features': 19}
#         Has trained 5642 of 1606500 combinations so far
# Already Trained and Tested combination (val score of 0.4818):
#             {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 18}
#             Current best combo (with val score 0.5207):
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.001, 'features': 19}
#         Has trained 5642 of 1606500 combinations so far
# Already Trained and Tested combination (val score of 0.3949):
#             {'n_estimators': 800, 'max_depth': 192, 'subsample': 1, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 20}
#             Current best combo (with val score 0.5207):
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.001, 'features': 19}
#         Has trained 5642 of 1606500 combinations so far
# % Combos Checked Thus Far: 5642 out of 1606500 which is 0.351198%
# Cruising Coordrdinate 1028 of 1056
#
# Cruising Coordrdinate 1029 of 1056
#
# Cruise suspended due to suspicious case
# Guidance: round 110
#
# 	round 110 iteration:  0
#
# Already Trained and Tested combination (val score of 0.4991):
#             {'n_estimators': 400, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 15}
#             Current best combo (with val score 0.5207):
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.001, 'features': 19}
#         Has trained 5642 of 1606500 combinations so far
# Already Trained and Tested combination (val score of 0.433):
#             {'n_estimators': 800, 'max_depth': 6, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 15}
#             Current best combo (with val score 0.5207):
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.001, 'features': 19}
#         Has trained 5642 of 1606500 combinations so far
# Already Trained and Tested combination (val score of 0.4934):
#             {'n_estimators': 800, 'max_depth': 3, 'subsample': 0.55, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 15}
#             Current best combo (with val score 0.5207):
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.001, 'features': 19}
#         Has trained 5642 of 1606500 combinations so far
# Already Trained and Tested combination (val score of 0.5046):
#             {'n_estimators': 800, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.85, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 15}
#             Current best combo (with val score 0.5207):
# ...
#             {'n_estimators': 800, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.001, 'features': 19}
#             Current best combo (with val score 0.5207):
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.001, 'features': 19}
#         Has trained 5642 of 1606500 combinations so far
# Already Trained and Tested combination (val score of 0.5128):
#             {'n_estimators': 800, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.0001, 'features': 19}
#             Current best combo (with val score 0.5207):
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.001, 'features': 19}
#         Has trained 5642 of 1606500 combinations so far
# Already Trained and Tested combination (val score of 0.5104):
#             {'n_estimators': 800, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.01, 'features': 19}
#             Current best combo (with val score 0.5207):
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.001, 'features': 19}
#         Has trained 5642 of 1606500 combinations so far
# Already Trained and Tested combination (val score of 0.4848):
#             {'n_estimators': 800, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.001, 'features': 18}
#             Current best combo (with val score 0.5207):
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.001, 'features': 19}
#         Has trained 5642 of 1606500 combinations so far
# Already Trained and Tested combination (val score of 0.4916):
#             {'n_estimators': 800, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.001, 'features': 20}
#             Current best combo (with val score 0.5207):
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.001, 'features': 19}
#         Has trained 5642 of 1606500 combinations so far
# 	round FINAL iteration:  1
#
# Already Trained and Tested combination (val score of 0.3623):
#             {'n_estimators': 400, 'max_depth': 48, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.001, 'features': 19}
#             Current best combo (with val score 0.5207):
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.001, 'features': 19}
#         Has trained 5642 of 1606500 combinations so far
# Already Trained and Tested combination (val score of 0.5207):
#             {'n_estimators': 800, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.001, 'features': 19}
#             Current best combo (with val score 0.5207):
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.001, 'features': 19}
#         Has trained 5642 of 1606500 combinations so far
# Already Trained and Tested combination (val score of 0.5207):
#             {'n_estimators': 800, 'max_depth': 96, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.001, 'features': 19}
#             Current best combo (with val score 0.5207):
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.001, 'features': 19}
#         Has trained 5642 of 1606500 combinations so far
# Already Trained and Tested combination (val score of 0.5207):
#             {'n_estimators': 800, 'max_depth': 48, 'subsample': 0.55, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.001, 'features': 19}
#             Current best combo (with val score 0.5207):
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.001, 'features': 19}
#         Has trained 5642 of 1606500 combinations so far
# Already Trained and Tested combination (val score of 0.512):
#             {'n_estimators': 800, 'max_depth': 48, 'subsample': 0.4, 'colsample_bytree': 0.55, 'learning_rate': 0.01, 'reg_alpha': 0.001, 'features': 19}
#             Current best combo (with val score 0.5207):
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.001, 'features': 19}
#         Has trained 5642 of 1606500 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 800, 'max_depth': 48, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.0001, 'reg_alpha': 0.001, 'features': 19}
#             Current best combo (with val score 0.5207):
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.001, 'features': 19}
#         Has trained 5642 of 1606500 combinations so far
# Already Trained and Tested combination (val score of 0.4506):
#             {'n_estimators': 800, 'max_depth': 48, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.001, 'features': 19}
#             Current best combo (with val score 0.5207):
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.001, 'features': 19}
#         Has trained 5642 of 1606500 combinations so far
# Already Trained and Tested combination (val score of 0.5128):
#             {'n_estimators': 800, 'max_depth': 48, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.0001, 'features': 19}
#             Current best combo (with val score 0.5207):
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.001, 'features': 19}
#         Has trained 5642 of 1606500 combinations so far
# Already Trained and Tested combination (val score of 0.5104):
#             {'n_estimators': 800, 'max_depth': 48, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.01, 'features': 19}
#             Current best combo (with val score 0.5207):
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.001, 'features': 19}
#         Has trained 5642 of 1606500 combinations so far
# Already Trained and Tested combination (val score of 0.4848):
#             {'n_estimators': 800, 'max_depth': 48, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.001, 'features': 18}
#             Current best combo (with val score 0.5207):
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.001, 'features': 19}
#         Has trained 5642 of 1606500 combinations so far
# Already Trained and Tested combination (val score of 0.4916):
#             {'n_estimators': 800, 'max_depth': 48, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.001, 'features': 20}
#             Current best combo (with val score 0.5207):
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.001, 'features': 19}
#         Has trained 5642 of 1606500 combinations so far
# Already Trained and Tested combination (val score of 0.3623):
#             {'n_estimators': 400, 'max_depth': 24, 'subsample': 0.55, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.001, 'features': 19}
#             Current best combo (with val score 0.5207):
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.001, 'features': 19}
#         Has trained 5642 of 1606500 combinations so far
# Already Trained and Tested combination (val score of 0.5128):
#             {'n_estimators': 800, 'max_depth': 12, 'subsample': 0.55, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.001, 'features': 19}
#             Current best combo (with val score 0.5207):
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.001, 'features': 19}
#         Has trained 5642 of 1606500 combinations so far
# Already Trained and Tested combination (val score of 0.5207):
#             {'n_estimators': 800, 'max_depth': 48, 'subsample': 0.55, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.001, 'features': 19}
#             Current best combo (with val score 0.5207):
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.001, 'features': 19}
#         Has trained 5642 of 1606500 combinations so far
# Already Trained and Tested combination (val score of 0.5207):
#             {'n_estimators': 800, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.001, 'features': 19}
#             Current best combo (with val score 0.5207):
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.001, 'features': 19}
#         Has trained 5642 of 1606500 combinations so far
# Already Trained and Tested combination (val score of 0.5207):
#             {'n_estimators': 800, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.001, 'features': 19}
#             Current best combo (with val score 0.5207):
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.001, 'features': 19}
#         Has trained 5642 of 1606500 combinations so far
# Already Trained and Tested combination (val score of 0.512):
#             {'n_estimators': 800, 'max_depth': 24, 'subsample': 0.55, 'colsample_bytree': 0.55, 'learning_rate': 0.01, 'reg_alpha': 0.001, 'features': 19}
#             Current best combo (with val score 0.5207):
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.001, 'features': 19}
#         Has trained 5642 of 1606500 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 800, 'max_depth': 24, 'subsample': 0.55, 'colsample_bytree': 0.4, 'learning_rate': 0.0001, 'reg_alpha': 0.001, 'features': 19}
#             Current best combo (with val score 0.5207):
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.001, 'features': 19}
#         Has trained 5642 of 1606500 combinations so far
# Already Trained and Tested combination (val score of 0.4506):
#             {'n_estimators': 800, 'max_depth': 24, 'subsample': 0.55, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.001, 'features': 19}
#             Current best combo (with val score 0.5207):
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.001, 'features': 19}
#         Has trained 5642 of 1606500 combinations so far
# Already Trained and Tested combination (val score of 0.5128):
#             {'n_estimators': 800, 'max_depth': 24, 'subsample': 0.55, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.0001, 'features': 19}
#             Current best combo (with val score 0.5207):
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.001, 'features': 19}
#         Has trained 5642 of 1606500 combinations so far
# Already Trained and Tested combination (val score of 0.5104):
#             {'n_estimators': 800, 'max_depth': 24, 'subsample': 0.55, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.01, 'features': 19}
#             Current best combo (with val score 0.5207):
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.001, 'features': 19}
#         Has trained 5642 of 1606500 combinations so far
# Already Trained and Tested combination (val score of 0.4848):
#             {'n_estimators': 800, 'max_depth': 24, 'subsample': 0.55, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.001, 'features': 18}
#             Current best combo (with val score 0.5207):
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.001, 'features': 19}
#         Has trained 5642 of 1606500 combinations so far
# Already Trained and Tested combination (val score of 0.4916):
#             {'n_estimators': 800, 'max_depth': 24, 'subsample': 0.55, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.001, 'features': 20}
#             Current best combo (with val score 0.5207):
#                     {'n_estimators': 800, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.001, 'features': 19}
#         Has trained 5642 of 1606500 combinations so far
# % Combos Checked Thus Far: 5642 out of 1606500 which is 0.351198%
# Max Val Score:
#  0.520662
# Max Val Score Std:
#  0.048894
# Best Combo Train Score:
#  0.897926
# Best Combo Train Score Std:
#  0.003966
# Max Combo Index:
#  (5, 3, 0, 0, 3, 1, 19) out of [6, 7, 5, 5, 5, 6, 51] (note best combo is 0-indexed)
# Max Combo Hyperparamer Combination:
#  {'n_estimators': 800, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.001, 'features': 19}
# Max Combo Features:
#  ('procedure_225792', 'ventilation_used', 'lods_score', 'race_AMERICAN INDIAN/ALASKA NATIVE', 'race_ASIAN', 'race_ASIAN - ASIAN INDIAN', 'race_ASIAN - CHINESE', 'race_ASIAN - KOREAN', 'race_ASIAN - SOUTH EAST ASIAN', 'race_BLACK/AFRICAN', 'race_BLACK/AFRICAN AMERICAN', 'race_BLACK/CAPE VERDEAN', 'race_BLACK/CARIBBEAN ISLAND', 'race_HISPANIC/LATINO - CENTRAL AMERICAN', 'race_HISPANIC/LATINO - COLUMBIAN', 'race_HISPANIC/LATINO - CUBAN', 'race_HISPANIC/LATINO - DOMINICAN', 'race_HISPANIC/LATINO - GUATEMALAN', 'race_HISPANIC/LATINO - HONDURAN', 'race_HISPANIC/LATINO - MEXICAN', 'race_HISPANIC/LATINO - PUERTO RICAN', 'race_HISPANIC/LATINO - SALVADORAN', 'race_MULTIPLE RACE/ETHNICITY', 'race_NATIVE HAWAIIAN OR OTHER PACIFIC ISLANDER', 'race_OTHER', 'race_PATIENT DECLINED TO ANSWER', 'race_PORTUGUESE', 'race_SOUTH AMERICAN', 'race_UNABLE TO OBTAIN', 'race_UNKNOWN', 'race_WHITE', 'race_WHITE - BRAZILIAN', 'race_WHITE - EASTERN EUROPEAN', 'race_WHITE - OTHER EUROPEAN', 'race_WHITE - RUSSIAN', 'race_HISPANIC OR LATINO', 'marital_status_DIVORCED', 'marital_status_MARRIED', 'marital_status_SINGLE', 'marital_status_WIDOWED', 'marital_status_0', 'hospital_stay_duration', 'procedure_225464', 'procedure_225802', 'procedure_227712', 'admission_type_DIRECT EMER.', 'admission_type_DIRECT OBSERVATION', 'admission_type_ELECTIVE', 'admission_type_EU OBSERVATION', 'admission_type_EW EMER.', 'admission_type_OBSERVATION ADMIT', 'admission_type_URGENT', 'admission_type_SURGICAL SAME DAY ADMISSION', 'procedure_225446', 'oasis_score', 'procedure_225400', 'procedure_224263', 'procedure_224276', 'unique_drugs', 'procedure_224267', 'procedure_229351', 'insurance_Medicare', 'insurance_Other', 'insurance_Medicaid', 'icu_stay_duration')
# % Combos Checked: 5642 out of 1606500 which is 0.351198%
