# %% [markdown]
# # Tuning Script

# %%
# Parameters subject to change in every script - involved in naming

MODEL = 'lgbc'
PREPROCESSING = 'normalise'
TUNER = 'yangzhoub'
OPTIMISED_METRIC = 'f1'

# %% [markdown]
# ---

# %%
# detect whether this is a google environment

COLAB_ENVIRONMENT = False

try:
    from google.colab import drive
    drive.mount('/content/drive')
    COLAB_ENVIRONMENT = True
except:
    pass
# Out:
# Mounted at /content/drive

# %%
import sys
import os
import pickle

if COLAB_ENVIRONMENT:
    home_directory = './drive/MyDrive/LAB/COMP90089__GroupWork__Py/' # my home directory is stored in ./LAB of google drive
    if MODEL == 'ebr':
        # !pip install interpret==0.5.0
    elif MODEL == 'cbr':
        # !pip install catboost
    elif MODEL in ['tf', 'mlp']:
        # !pip install PyTorch2Sklearn
    # !pip install JXAutoML
else:
    home_directory = '../../'

from JXAutoML.YangZhouB_10CV import YangZhouB_10CV as Tuner

import pandas as pd
# Out:
# Collecting JXAutoML
#   Downloading JXAutoML-0.4.4-py3-none-any.whl.metadata (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.2/67.2 kB 3.2 MB/s eta 0:00:00
# Downloading JXAutoML-0.4.4-py3-none-any.whl (52 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.1/52.1 kB 3.7 MB/s eta 0:00:00
# Installing collected packages: JXAutoML
# Successfully installed JXAutoML-0.4.4

# %%
# Parameters that are same for every script

FOLDS = 10  # we have decided to do 10 fold validation

SEED = 42

TASK_TYPE = 'Classification'  # this task is a classification task

# we have decided to tune features as hp
TUNE_FEATURES_AS_HYPERPARAMETERS = True

# %% [markdown]
# ---

# %%
# model to use to tune
from lightgbm import LGBMClassifier as clf

# what values to try for each hyperparameter
parameter_choices = {
    'n_estimators': (25, 50, 100, 200, 400, 800),
    'max_depth': (3, 6, 12, 24, 48, 96, 192),
    'subsample': (0.4, 0.55, 0.7, 0.85, 1),
    'colsample_bytree': (0.4, 0.55, 0.7, 0.85, 1),
    'learning_rate': (0.00000001, 0.000001, 0.0001, 0.01, 0.1),
    'reg_alpha': (0.0001, 0.001, 0.01, 0.1, 1, 10)
}

# what values to set non-tuneable parameters/hyperparameters
non_tunable_hyperparameters_dict = {
                                    'random_state': SEED,
                                    'n_jobs': -1,
                                    'verbose': -1
                                    }
# Out:
# /usr/local/lib/python3.10/dist-packages/dask/dataframe/__init__.py:42: FutureWarning:
# Dask dataframe query planning is disabled because dask-expr is not installed.
#
# You can install it with `pip install dask[dataframe]` or `conda install dask`.
# This will raise in a future version.
#
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ---

# %% [markdown]
# Read in and Prepare Data

# %%
# Import data and store as lists

train_x_list = []
train_y_list = []
val_x_list = []
val_y_list = []

for i in range(FOLDS):
    train_data = pd.read_csv(
        f'{home_directory}data/curated/modelling/{PREPROCESSING}/train_{i}.csv')
    val_data = pd.read_csv(
        f'{home_directory}data/curated/modelling/{PREPROCESSING}/val_{i}.csv')

    # get the correct rows for X and y
    train_x = train_data.drop(
        ['mortality_status', 'subject_id', 'hadm_id', 'stay_id'], axis=1)
    train_y = train_data['mortality_status']
    val_x = val_data.drop(
        ['mortality_status', 'subject_id', 'hadm_id', 'stay_id'], axis=1)
    val_y = val_data['mortality_status']

    train_x_list.append(train_x)
    train_y_list.append(train_y)
    val_x_list.append(val_x)
    val_y_list.append(val_y)

# %%
# Import feature importance ordering

with open(f'{home_directory}models/xgb_feature_importance_ordering_{PREPROCESSING}.pickle', 'rb') as f:
    feature_importance_ordering = pickle.load(f)

# %% [markdown]
# Set parameters

# %%
# initialisation
tuner = Tuner()

print('---')

# define what model we are tuning
tuner.read_in_model(clf, TASK_TYPE, optimised_metric=OPTIMISED_METRIC)

print('---')

# read in the data for training and validation
tuner.read_in_data(train_x_list, train_y_list, val_x_list, val_y_list)

print('---')

# set what hp values to tune
tuner.set_hyperparameters(parameter_choices)
# WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

# set up hp values that need to be changed from default but NOT to be tuned
tuner.set_non_tuneable_hyperparameters(non_tunable_hyperparameters_dict)

print('---')

# set up feature importance ordering

if TUNE_FEATURES_AS_HYPERPARAMETERS:
    tuner.set_features(feature_importance_ordering)
    # WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

try:  # try to read in previous results to continue tuning ...
    tuner.read_in_tuning_result_df(
        f'{home_directory}models/tuning/{TUNER}_{MODEL}_{PREPROCESSING}.csv')
except:
    print('No previous tuning data read in')

print('---')

# set up where to save the tuning result csv
tuner.set_tuning_result_saving_address(
    f'{home_directory}models/tuning/{TUNER}_{MODEL}_{PREPROCESSING}.csv')

print('---')

# set up where to save the current best model
tuner.set_best_model_saving_address(
    f'{home_directory}models/tmp_models/{TUNER}_{MODEL}_{PREPROCESSING}')
# Out:
# YangZhouB Initialised
# ---
# Successfully read in model <class 'lightgbm.sklearn.LGBMClassifier'>, which is a Classification model optimising for f1
# ---
# Read in Train X data list
# Read in Train y data list
# Read in Val X data list
# Read in Val y data list
# ---
# Successfully recorded hyperparameter choices
# ---
# Successfully recorded non_tuneable_hyperparameter choices
# ---
# Successfully recorded tuneable feature combination choices and updated relevant internal structures
# ---
# /usr/local/lib/python3.10/dist-packages/JXAutoML/YangZhouB_10CV.py:1230: DtypeWarning: Columns (9) have mixed types. Specify dtype option on import or set low_memory=False.
#   self.tuning_result = pd.read_csv(address)
# Successfully read in tuning result of 6477 rows, for 6477.0 combos
# ---
# Successfully set tuning output address
# ---
# Successfully set best model output address

# %%
# ignore warnings

import warnings
warnings.filterwarnings("ignore")

# %%
# begin tuning ... (or continue training)

tuner.tune()
# Out:
# Streaming output truncated to the last 5000 lines.
#                     {'n_estimators': 50, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 16}
#         Has trained 6477 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.5223):
#             {'n_estimators': 25, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 8}
#             Current best combo (with val score 0.5722):
#                     {'n_estimators': 50, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 16}
#         Has trained 6477 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.5266):
#             {'n_estimators': 25, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 10}
#             Current best combo (with val score 0.5722):
#                     {'n_estimators': 50, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 16}
#         Has trained 6477 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.4661):
#             {'n_estimators': 50, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 11}
#             Current best combo (with val score 0.5722):
#                     {'n_estimators': 50, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 16}
#         Has trained 6477 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.4479):
#             {'n_estimators': 25, 'max_depth': 6, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 11}
#             Current best combo (with val score 0.5722):
#                     {'n_estimators': 50, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 16}
#         Has trained 6477 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.5253):
#             {'n_estimators': 25, 'max_depth': 3, 'subsample': 0.55, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 11}
#             Current best combo (with val score 0.5722):
#                     {'n_estimators': 50, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 16}
#         Has trained 6477 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.5059):
#             {'n_estimators': 25, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.85, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 11}
#             Current best combo (with val score 0.5722):
#                     {'n_estimators': 50, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 16}
#         Has trained 6477 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 25, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.01, 'reg_alpha': 0.0001, 'features': 11}
#             Current best combo (with val score 0.5722):
#                     {'n_estimators': 50, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 16}
#         Has trained 6477 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.5253):
#             {'n_estimators': 25, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.001, 'features': 11}
#             Current best combo (with val score 0.5722):
#                     {'n_estimators': 50, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 16}
#         Has trained 6477 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.5266):
#             {'n_estimators': 25, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 10}
#             Current best combo (with val score 0.5722):
#                     {'n_estimators': 50, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 16}
#         Has trained 6477 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.5277):
#             {'n_estimators': 25, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 12}
#             Current best combo (with val score 0.5722):
#                     {'n_estimators': 50, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 16}
#         Has trained 6477 of 2268000 combinations so far
# % Combos Checked Thus Far: 6477 out of 2268000 which is 0.285582%
# Cruising Coordrdinate 1503 of 1536
#
# Cruising Coordrdinate 1504 of 1536
#
# Cruising Coordrdinate 1505 of 1536
#
# Cruising Coordrdinate 1506 of 1536
#
# Cruise suspended due to suspicious case
# Guidance: round 113
#
# 	round 113 iteration:  0
#
# Already Trained and Tested combination (val score of 0.5153):
#             {'n_estimators': 50, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 15}
#             Current best combo (with val score 0.5722):
#                     {'n_estimators': 50, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 16}
#         Has trained 6477 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.4677):
#             {'n_estimators': 25, 'max_depth': 12, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 15}
#             Current best combo (with val score 0.5722):
#                     {'n_estimators': 50, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 16}
#         Has trained 6477 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.4677):
#             {'n_estimators': 25, 'max_depth': 48, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 15}
#             Current best combo (with val score 0.5722):
#                     {'n_estimators': 50, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 16}
#         Has trained 6477 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.4677):
#             {'n_estimators': 25, 'max_depth': 24, 'subsample': 0.55, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 15}
#             Current best combo (with val score 0.5722):
#                     {'n_estimators': 50, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 16}
#         Has trained 6477 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.4701):
#             {'n_estimators': 25, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.85, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 15}
#             Current best combo (with val score 0.5722):
#                     {'n_estimators': 50, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 16}
#         Has trained 6477 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 25, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.01, 'reg_alpha': 10, 'features': 15}
#             Current best combo (with val score 0.5722):
#                     {'n_estimators': 50, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 16}
#         Has trained 6477 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.4476):
#             {'n_estimators': 25, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 1, 'features': 15}
#             Current best combo (with val score 0.5722):
#                     {'n_estimators': 50, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 16}
#         Has trained 6477 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.4686):
#             {'n_estimators': 25, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 14}
#             Current best combo (with val score 0.5722):
#                     {'n_estimators': 50, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 16}
#         Has trained 6477 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.4776):
#             {'n_estimators': 25, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 16}
#             Current best combo (with val score 0.5722):
#                     {'n_estimators': 50, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 16}
#         Has trained 6477 of 2268000 combinations so far
# 	round 113 iteration:  1
#
# Already Trained and Tested combination (val score of 0.4677):
#             {'n_estimators': 25, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 15}
#             Current best combo (with val score 0.5722):
#                     {'n_estimators': 50, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 16}
#         Has trained 6477 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.5084):
#             {'n_estimators': 100, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 15}
#             Current best combo (with val score 0.5722):
#                     {'n_estimators': 50, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 16}
#         Has trained 6477 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.5153):
#             {'n_estimators': 50, 'max_depth': 12, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 15}
#             Current best combo (with val score 0.5722):
#                     {'n_estimators': 50, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 16}
#         Has trained 6477 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.5153):
#             {'n_estimators': 50, 'max_depth': 48, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 15}
#             Current best combo (with val score 0.5722):
#                     {'n_estimators': 50, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 16}
#         Has trained 6477 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.5153):
#             {'n_estimators': 50, 'max_depth': 24, 'subsample': 0.55, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 15}
#             Current best combo (with val score 0.5722):
#                     {'n_estimators': 50, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 16}
#         Has trained 6477 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.5215):
#             {'n_estimators': 50, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.85, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 15}
#             Current best combo (with val score 0.5722):
#                     {'n_estimators': 50, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 16}
#         Has trained 6477 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 50, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.01, 'reg_alpha': 10, 'features': 15}
#             Current best combo (with val score 0.5722):
#                     {'n_estimators': 50, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 16}
#         Has trained 6477 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.4507):
#             {'n_estimators': 50, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 1, 'features': 15}
#             Current best combo (with val score 0.5722):
#                     {'n_estimators': 50, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 16}
#         Has trained 6477 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.5061):
#             {'n_estimators': 50, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 14}
#             Current best combo (with val score 0.5722):
#                     {'n_estimators': 50, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 16}
#         Has trained 6477 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.5091):
#             {'n_estimators': 50, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 16}
#             Current best combo (with val score 0.5722):
#                     {'n_estimators': 50, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 16}
#         Has trained 6477 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.5153):
#             {'n_estimators': 50, 'max_depth': 12, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 15}
#             Current best combo (with val score 0.5722):
#                     {'n_estimators': 50, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 16}
#         Has trained 6477 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.4541):
#             {'n_estimators': 25, 'max_depth': 6, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 15}
#             Current best combo (with val score 0.5722):
#                     {'n_estimators': 50, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 16}
#         Has trained 6477 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.4677):
#             {'n_estimators': 25, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 15}
#             Current best combo (with val score 0.5722):
#                     {'n_estimators': 50, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 16}
#         Has trained 6477 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.4677):
#             {'n_estimators': 25, 'max_depth': 12, 'subsample': 0.55, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 15}
#             Current best combo (with val score 0.5722):
#                     {'n_estimators': 50, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 16}
#         Has trained 6477 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.4701):
#             {'n_estimators': 25, 'max_depth': 12, 'subsample': 0.4, 'colsample_bytree': 0.85, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 15}
#             Current best combo (with val score 0.5722):
#                     {'n_estimators': 50, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 16}
#         Has trained 6477 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 25, 'max_depth': 12, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.01, 'reg_alpha': 10, 'features': 15}
#             Current best combo (with val score 0.5722):
#                     {'n_estimators': 50, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 16}
#         Has trained 6477 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.4463):
#             {'n_estimators': 25, 'max_depth': 12, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 1, 'features': 15}
#             Current best combo (with val score 0.5722):
#                     {'n_estimators': 50, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 16}
#         Has trained 6477 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.4686):
#             {'n_estimators': 25, 'max_depth': 12, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 14}
#             Current best combo (with val score 0.5722):
#                     {'n_estimators': 50, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 16}
#         Has trained 6477 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.4776):
#             {'n_estimators': 25, 'max_depth': 12, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 16}
#             Current best combo (with val score 0.5722):
#                     {'n_estimators': 50, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 16}
#         Has trained 6477 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.5153):
#             {'n_estimators': 50, 'max_depth': 24, 'subsample': 0.55, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 15}
#             Current best combo (with val score 0.5722):
#                     {'n_estimators': 50, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 16}
#         Has trained 6477 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.4677):
#             {'n_estimators': 25, 'max_depth': 12, 'subsample': 0.55, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 15}
#             Current best combo (with val score 0.5722):
#                     {'n_estimators': 50, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 16}
#         Has trained 6477 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.4677):
#             {'n_estimators': 25, 'max_depth': 48, 'subsample': 0.55, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 15}
#             Current best combo (with val score 0.5722):
#                     {'n_estimators': 50, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 16}
#         Has trained 6477 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.4677):
#             {'n_estimators': 25, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 15}
#             Current best combo (with val score 0.5722):
#                     {'n_estimators': 50, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 16}
#         Has trained 6477 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.4677):
#             {'n_estimators': 25, 'max_depth': 24, 'subsample': 0.7, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 15}
#             Current best combo (with val score 0.5722):
#                     {'n_estimators': 50, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 16}
#         Has trained 6477 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.4701):
#             {'n_estimators': 25, 'max_depth': 24, 'subsample': 0.55, 'colsample_bytree': 0.85, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 15}
#             Current best combo (with val score 0.5722):
#                     {'n_estimators': 50, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 16}
#         Has trained 6477 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 25, 'max_depth': 24, 'subsample': 0.55, 'colsample_bytree': 1, 'learning_rate': 0.01, 'reg_alpha': 10, 'features': 15}
#             Current best combo (with val score 0.5722):
#                     {'n_estimators': 50, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 16}
#         Has trained 6477 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.4476):
#             {'n_estimators': 25, 'max_depth': 24, 'subsample': 0.55, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 1, 'features': 15}
#             Current best combo (with val score 0.5722):
#                     {'n_estimators': 50, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 16}
#         Has trained 6477 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.4686):
#             {'n_estimators': 25, 'max_depth': 24, 'subsample': 0.55, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 14}
#             Current best combo (with val score 0.5722):
#                     {'n_estimators': 50, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 16}
#         Has trained 6477 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.4776):
#             {'n_estimators': 25, 'max_depth': 24, 'subsample': 0.55, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 16}
#             Current best combo (with val score 0.5722):
#                     {'n_estimators': 50, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 16}
#         Has trained 6477 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.5215):
#             {'n_estimators': 50, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.85, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 15}
#             Current best combo (with val score 0.5722):
#                     {'n_estimators': 50, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 16}
#         Has trained 6477 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.4701):
#             {'n_estimators': 25, 'max_depth': 12, 'subsample': 0.4, 'colsample_bytree': 0.85, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 15}
#             Current best combo (with val score 0.5722):
#                     {'n_estimators': 50, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 16}
#         Has trained 6477 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.4701):
#             {'n_estimators': 25, 'max_depth': 48, 'subsample': 0.4, 'colsample_bytree': 0.85, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 15}
#             Current best combo (with val score 0.5722):
#                     {'n_estimators': 50, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 16}
#         Has trained 6477 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.4701):
#             {'n_estimators': 25, 'max_depth': 24, 'subsample': 0.55, 'colsample_bytree': 0.85, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 15}
#             Current best combo (with val score 0.5722):
#                     {'n_estimators': 50, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 16}
#         Has trained 6477 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.4821):
#             {'n_estimators': 25, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.7, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 15}
#             Current best combo (with val score 0.5722):
#                     {'n_estimators': 50, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 16}
#         Has trained 6477 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.4677):
#             {'n_estimators': 25, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 15}
#             Current best combo (with val score 0.5722):
#                     {'n_estimators': 50, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 16}
#         Has trained 6477 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 25, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.85, 'learning_rate': 0.01, 'reg_alpha': 10, 'features': 15}
#             Current best combo (with val score 0.5722):
#                     {'n_estimators': 50, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 16}
#         Has trained 6477 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.4608):
#             {'n_estimators': 25, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.85, 'learning_rate': 0.1, 'reg_alpha': 1, 'features': 15}
#             Current best combo (with val score 0.5722):
#                     {'n_estimators': 50, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 16}
#         Has trained 6477 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.4837):
#             {'n_estimators': 25, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.85, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 14}
#             Current best combo (with val score 0.5722):
#                     {'n_estimators': 50, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 16}
#         Has trained 6477 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.4698):
#             {'n_estimators': 25, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.85, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 16}
#             Current best combo (with val score 0.5722):
#                     {'n_estimators': 50, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 16}
#         Has trained 6477 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.5061):
#             {'n_estimators': 50, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 14}
#             Current best combo (with val score 0.5722):
#                     {'n_estimators': 50, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 16}
#         Has trained 6477 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.4686):
#             {'n_estimators': 25, 'max_depth': 12, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 14}
#             Current best combo (with val score 0.5722):
#                     {'n_estimators': 50, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 16}
#         Has trained 6477 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.4686):
#             {'n_estimators': 25, 'max_depth': 48, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 14}
#             Current best combo (with val score 0.5722):
#                     {'n_estimators': 50, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 16}
#         Has trained 6477 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.4686):
#             {'n_estimators': 25, 'max_depth': 24, 'subsample': 0.55, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 14}
#             Current best combo (with val score 0.5722):
#                     {'n_estimators': 50, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 16}
#         Has trained 6477 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.4837):
#             {'n_estimators': 25, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.85, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 14}
#             Current best combo (with val score 0.5722):
#                     {'n_estimators': 50, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 16}
#         Has trained 6477 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 25, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.01, 'reg_alpha': 10, 'features': 14}
#             Current best combo (with val score 0.5722):
#                     {'n_estimators': 50, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 16}
#         Has trained 6477 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.4493):
#             {'n_estimators': 25, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 1, 'features': 14}
#             Current best combo (with val score 0.5722):
#                     {'n_estimators': 50, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 16}
#         Has trained 6477 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.465):
#             {'n_estimators': 25, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 13}
#             Current best combo (with val score 0.5722):
#                     {'n_estimators': 50, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 16}
#         Has trained 6477 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.4677):
#             {'n_estimators': 25, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 15}
#             Current best combo (with val score 0.5722):
#                     {'n_estimators': 50, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 16}
#         Has trained 6477 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.5091):
#             {'n_estimators': 50, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 16}
#             Current best combo (with val score 0.5722):
#                     {'n_estimators': 50, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 16}
#         Has trained 6477 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.4776):
#             {'n_estimators': 25, 'max_depth': 12, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 16}
#             Current best combo (with val score 0.5722):
#                     {'n_estimators': 50, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 16}
#         Has trained 6477 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.4776):
#             {'n_estimators': 25, 'max_depth': 48, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 16}
#             Current best combo (with val score 0.5722):
#                     {'n_estimators': 50, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 16}
#         Has trained 6477 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.4776):
#             {'n_estimators': 25, 'max_depth': 24, 'subsample': 0.55, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 16}
#             Current best combo (with val score 0.5722):
#                     {'n_estimators': 50, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 16}
#         Has trained 6477 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.4698):
#             {'n_estimators': 25, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.85, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 16}
#             Current best combo (with val score 0.5722):
#                     {'n_estimators': 50, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 16}
#         Has trained 6477 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 25, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.01, 'reg_alpha': 10, 'features': 16}
#             Current best combo (with val score 0.5722):
#                     {'n_estimators': 50, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 16}
#         Has trained 6477 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.4559):
#             {'n_estimators': 25, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 1, 'features': 16}
#             Current best combo (with val score 0.5722):
#                     {'n_estimators': 50, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 16}
#         Has trained 6477 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.4677):
#             {'n_estimators': 25, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 15}
#             Current best combo (with val score 0.5722):
#                     {'n_estimators': 50, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 16}
#         Has trained 6477 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.1922):
#             {'n_estimators': 25, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 17}
#             Current best combo (with val score 0.5722):
#                     {'n_estimators': 50, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 16}
#         Has trained 6477 of 2268000 combinations so far
# % Combos Checked Thus Far: 6477 out of 2268000 which is 0.285582%
# Cruising Coordrdinate 1507 of 1536
#
# Cruise suspended due to suspicious case
# Guidance: round 114
#
# 	round 114 iteration:  0
#
# Already Trained and Tested combination (val score of 0.477):
#             {'n_estimators': 50, 'max_depth': 24, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 15}
#             Current best combo (with val score 0.5722):
#                     {'n_estimators': 50, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 16}
#         Has trained 6477 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.4145):
#             {'n_estimators': 25, 'max_depth': 12, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 15}
#             Current best combo (with val score 0.5722):
#                     {'n_estimators': 50, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 16}
#         Has trained 6477 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.4145):
#             {'n_estimators': 25, 'max_depth': 48, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 15}
#             Current best combo (with val score 0.5722):
#                     {'n_estimators': 50, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 16}
#         Has trained 6477 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.4145):
#             {'n_estimators': 25, 'max_depth': 24, 'subsample': 0.85, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 15}
#             Current best combo (with val score 0.5722):
#                     {'n_estimators': 50, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 16}
#         Has trained 6477 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.4641):
#             {'n_estimators': 25, 'max_depth': 24, 'subsample': 1, 'colsample_bytree': 0.55, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 15}
#             Current best combo (with val score 0.5722):
#                     {'n_estimators': 50, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 16}
#         Has trained 6477 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 25, 'max_depth': 24, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 10, 'features': 15}
#             Current best combo (with val score 0.5722):
#                     {'n_estimators': 50, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 16}
#         Has trained 6477 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.5491):
#             {'n_estimators': 25, 'max_depth': 24, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 1, 'features': 15}
#             Current best combo (with val score 0.5722):
#                     {'n_estimators': 50, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 16}
#         Has trained 6477 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.3978):
#             {'n_estimators': 25, 'max_depth': 24, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 14}
#             Current best combo (with val score 0.5722):
#                     {'n_estimators': 50, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 16}
#         Has trained 6477 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.4006):
#             {'n_estimators': 25, 'max_depth': 24, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 16}
#             Current best combo (with val score 0.5722):
#                     {'n_estimators': 50, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 16}
#         Has trained 6477 of 2268000 combinations so far
# 	round 114 iteration:  1
#
# Already Trained and Tested combination (val score of 0.4145):
#             {'n_estimators': 25, 'max_depth': 24, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 15}
#             Current best combo (with val score 0.5722):
#                     {'n_estimators': 50, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 16}
#         Has trained 6477 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.5328):
#             {'n_estimators': 100, 'max_depth': 24, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 15}
#             Current best combo (with val score 0.5722):
#                     {'n_estimators': 50, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 16}
#         Has trained 6477 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.477):
#             {'n_estimators': 50, 'max_depth': 12, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 15}
#             Current best combo (with val score 0.5722):
#                     {'n_estimators': 50, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 16}
#         Has trained 6477 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.477):
#             {'n_estimators': 50, 'max_depth': 48, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 15}
#             Current best combo (with val score 0.5722):
#                     {'n_estimators': 50, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 16}
#         Has trained 6477 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.477):
#             {'n_estimators': 50, 'max_depth': 24, 'subsample': 0.85, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 15}
#             Current best combo (with val score 0.5722):
#                     {'n_estimators': 50, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 16}
#         Has trained 6477 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.5274):
#             {'n_estimators': 50, 'max_depth': 24, 'subsample': 1, 'colsample_bytree': 0.55, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 15}
#             Current best combo (with val score 0.5722):
#                     {'n_estimators': 50, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 16}
#         Has trained 6477 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 50, 'max_depth': 24, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 10, 'features': 15}
#             Current best combo (with val score 0.5722):
#                     {'n_estimators': 50, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 16}
#         Has trained 6477 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.5431):
#             {'n_estimators': 50, 'max_depth': 24, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 1, 'features': 15}
#             Current best combo (with val score 0.5722):
#                     {'n_estimators': 50, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 16}
#         Has trained 6477 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.4954):
#             {'n_estimators': 50, 'max_depth': 24, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 14}
#             Current best combo (with val score 0.5722):
#                     {'n_estimators': 50, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 16}
#         Has trained 6477 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.4527):
#             {'n_estimators': 50, 'max_depth': 24, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 16}
#             Current best combo (with val score 0.5722):
#                     {'n_estimators': 50, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 16}
#         Has trained 6477 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.477):
#             {'n_estimators': 50, 'max_depth': 12, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 15}
#             Current best combo (with val score 0.5722):
#                     {'n_estimators': 50, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 16}
#         Has trained 6477 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.4145):
#             {'n_estimators': 25, 'max_depth': 6, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 15}
#             Current best combo (with val score 0.5722):
#                     {'n_estimators': 50, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 16}
#         Has trained 6477 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.4145):
#             {'n_estimators': 25, 'max_depth': 24, 'subsample': 1, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 10, 'features': 15}
#             Current best combo (with val score 0.5722):
#                     {'n_estimators': 50, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 16}
#         Has trained 6477 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.4145):
# ...
#             Current best combo (with val score 0.5722):
#                     {'n_estimators': 50, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 16}
#         Has trained 6523 of 2268000 combinations so far
# Trained and Tested combination 6524 of 2268000, taking 0.02 seconds to get val score of 0.4327:
#                 {'n_estimators': 25, 'max_depth': 24, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 17},
#             Current best combo with val score 0.5722:
#                     {'n_estimators': 50, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 16}
# % Combos Checked Thus Far: 6524 out of 2268000 which is 0.28765399999999997%
# FINAL STAGE: Begin final Guidance system
#
#
# Guidance: round FINAL
#
# 	round FINAL iteration:  0
#
# Already Trained and Tested combination (val score of 0.5199):
#             {'n_estimators': 25, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 16}
#             Current best combo (with val score 0.5722):
#                     {'n_estimators': 50, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 16}
#         Has trained 6524 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.5165):
#             {'n_estimators': 100, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 16}
#             Current best combo (with val score 0.5722):
#                     {'n_estimators': 50, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 16}
#         Has trained 6524 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.566):
#             {'n_estimators': 50, 'max_depth': 6, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 16}
#             Current best combo (with val score 0.5722):
#                     {'n_estimators': 50, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 16}
#         Has trained 6524 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.5722):
#             {'n_estimators': 50, 'max_depth': 3, 'subsample': 0.55, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 16}
#             Current best combo (with val score 0.5722):
#                     {'n_estimators': 50, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 16}
#         Has trained 6524 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.5259):
#             {'n_estimators': 50, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.55, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 16}
#             Current best combo (with val score 0.5722):
#                     {'n_estimators': 50, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 16}
#         Has trained 6524 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 50, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.0001, 'features': 16}
#             Current best combo (with val score 0.5722):
#                     {'n_estimators': 50, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 16}
#         Has trained 6524 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.5719):
#             {'n_estimators': 50, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.001, 'features': 16}
#             Current best combo (with val score 0.5722):
#                     {'n_estimators': 50, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 16}
#         Has trained 6524 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.5587):
#             {'n_estimators': 50, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 15}
#             Current best combo (with val score 0.5722):
#                     {'n_estimators': 50, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 16}
#         Has trained 6524 of 2268000 combinations so far
# Already Trained and Tested combination (val score of 0.4485):
#             {'n_estimators': 50, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 17}
#             Current best combo (with val score 0.5722):
#                     {'n_estimators': 50, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 16}
#         Has trained 6524 of 2268000 combinations so far
# 	round FINAL iteration:  1
#
# Already Trained and Tested combination (val score of 0.5199):
#             {'n_estimators': 25, 'max_depth': 3, 'subsample': 0.55, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 16}
#             Current best combo (with val score 0.5722):
#                     {'n_estimators': 50, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 16}
#         Has trained 6524 of 2268000 combinations so far
# Trained and Tested combination 6525 of 2268000, taking 0.97 seconds to get val score of 0.5165:
#                 {'n_estimators': 100, 'max_depth': 3, 'subsample': 0.55, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 16},
#             Current best combo with val score 0.5722:
#                     {'n_estimators': 50, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 16}
# Trained and Tested combination 6526 of 2268000, taking 0.04 seconds to get val score of 0.566:
#                 {'n_estimators': 50, 'max_depth': 6, 'subsample': 0.55, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 16},
#             Current best combo with val score 0.5722:
#                     {'n_estimators': 50, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 16}
# Already Trained and Tested combination (val score of 0.5722):
#             {'n_estimators': 50, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 16}
#             Current best combo (with val score 0.5722):
#                     {'n_estimators': 50, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 16}
#         Has trained 6526 of 2268000 combinations so far
# Trained and Tested combination 6527 of 2268000, taking 0.03 seconds to get val score of 0.5722:
#                 {'n_estimators': 50, 'max_depth': 3, 'subsample': 0.7, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 16},
#             Current best combo with val score 0.5722:
#                     {'n_estimators': 50, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 16}
# Trained and Tested combination 6528 of 2268000, taking 0.02 seconds to get val score of 0.5259:
#                 {'n_estimators': 50, 'max_depth': 3, 'subsample': 0.55, 'colsample_bytree': 0.55, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 16},
#             Current best combo with val score 0.5722:
#                     {'n_estimators': 50, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 16}
# Trained and Tested combination 6529 of 2268000, taking 0.02 seconds to get val score of 0.0:
#                 {'n_estimators': 50, 'max_depth': 3, 'subsample': 0.55, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.0001, 'features': 16},
#             Current best combo with val score 0.5722:
#                     {'n_estimators': 50, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 16}
# Trained and Tested combination 6530 of 2268000, taking 0.02 seconds to get val score of 0.5719:
#                 {'n_estimators': 50, 'max_depth': 3, 'subsample': 0.55, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.001, 'features': 16},
#             Current best combo with val score 0.5722:
#                     {'n_estimators': 50, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 16}
# Already Trained and Tested combination (val score of 0.5587):
#             {'n_estimators': 50, 'max_depth': 3, 'subsample': 0.55, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 15}
#             Current best combo (with val score 0.5722):
#                     {'n_estimators': 50, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 16}
#         Has trained 6530 of 2268000 combinations so far
# Trained and Tested combination 6531 of 2268000, taking 0.02 seconds to get val score of 0.4485:
#                 {'n_estimators': 50, 'max_depth': 3, 'subsample': 0.55, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 17},
#             Current best combo with val score 0.5722:
#                     {'n_estimators': 50, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 16}
# Already Trained and Tested combination (val score of 0.5199):
#             {'n_estimators': 25, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.001, 'features': 16}
#             Current best combo (with val score 0.5722):
#                     {'n_estimators': 50, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 16}
#         Has trained 6531 of 2268000 combinations so far
# Trained and Tested combination 6532 of 2268000, taking 0.04 seconds to get val score of 0.5148:
#                 {'n_estimators': 100, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.001, 'features': 16},
#             Current best combo with val score 0.5722:
#                     {'n_estimators': 50, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 16}
# Trained and Tested combination 6533 of 2268000, taking 0.04 seconds to get val score of 0.5643:
#                 {'n_estimators': 50, 'max_depth': 6, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.001, 'features': 16},
#             Current best combo with val score 0.5722:
#                     {'n_estimators': 50, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 16}
# Already Trained and Tested combination (val score of 0.5719):
#             {'n_estimators': 50, 'max_depth': 3, 'subsample': 0.55, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.001, 'features': 16}
#             Current best combo (with val score 0.5722):
#                     {'n_estimators': 50, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 16}
#         Has trained 6533 of 2268000 combinations so far
# Trained and Tested combination 6534 of 2268000, taking 0.03 seconds to get val score of 0.5248:
#                 {'n_estimators': 50, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.55, 'learning_rate': 0.1, 'reg_alpha': 0.001, 'features': 16},
#             Current best combo with val score 0.5722:
#                     {'n_estimators': 50, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 16}
# Trained and Tested combination 6535 of 2268000, taking 0.02 seconds to get val score of 0.0:
#                 {'n_estimators': 50, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.001, 'features': 16},
#             Current best combo with val score 0.5722:
#                     {'n_estimators': 50, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 16}
# Already Trained and Tested combination (val score of 0.5722):
#             {'n_estimators': 50, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 16}
#             Current best combo (with val score 0.5722):
#                     {'n_estimators': 50, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 16}
#         Has trained 6535 of 2268000 combinations so far
# Trained and Tested combination 6536 of 2268000, taking 0.06 seconds to get val score of 0.5706:
#                 {'n_estimators': 50, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.01, 'features': 16},
#             Current best combo with val score 0.5722:
#                     {'n_estimators': 50, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 16}
# Already Trained and Tested combination (val score of 0.5582):
#             {'n_estimators': 50, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.001, 'features': 15}
#             Current best combo (with val score 0.5722):
#                     {'n_estimators': 50, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 16}
#         Has trained 6536 of 2268000 combinations so far
# Trained and Tested combination 6537 of 2268000, taking 0.03 seconds to get val score of 0.4447:
#                 {'n_estimators': 50, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.001, 'features': 17},
#             Current best combo with val score 0.5722:
#                     {'n_estimators': 50, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 16}
# % Combos Checked Thus Far: 6537 out of 2268000 which is 0.288228%
# Max Val Score:
#  0.572235
# Max Val Score Std:
#  0.031061
# Best Combo Train Score:
#  0.629437
# Best Combo Train Score Std:
#  0.008564
# Max Combo Index:
#  (1, 0, 0, 0, 4, 0, 16) out of [6, 7, 5, 5, 5, 6, 72] (note best combo is 0-indexed)
# Max Combo Hyperparamer Combination:
#  {'n_estimators': 50, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 16}
# Max Combo Features:
#  ('procedure_228130', 'procedure_225792', 'procedure_228125', 'lods_score', 'ventilation_used', 'procedure_226236', 'hospital_stay_duration', 'procedure_225469', 'procedure_224270', 'procedure_225446', 'procedure_225802', 'procedure_227712', 'procedure_229580', 'procedure_225451', 'admission_type_DIRECT EMER.', 'admission_type_DIRECT OBSERVATION', 'admission_type_ELECTIVE', 'admission_type_EU OBSERVATION', 'admission_type_EW EMER.', 'admission_type_OBSERVATION ADMIT', 'admission_type_URGENT', 'admission_type_SURGICAL SAME DAY ADMISSION', 'procedure_224385', 'procedure_224267')
# % Combos Checked: 6537 out of 2268000 which is 0.288228%
