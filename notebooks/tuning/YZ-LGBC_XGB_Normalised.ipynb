# %% [markdown]
# # Tuning Script

# %%
# Parameters subject to change in every script - involved in naming

MODEL = 'lgbc'
PREPROCESSING = 'normalise'
TUNER = 'yangzhoub'
OPTIMISED_METRIC = 'f1'

# %% [markdown]
# ---

# %%
# detect whether this is a google environment

COLAB_ENVIRONMENT = False

try:
    from google.colab import drive
    drive.mount('/content/drive')
    COLAB_ENVIRONMENT = True
except:
    pass
# Out:
# Mounted at /content/drive

# %%
import sys
import os
import pickle

if COLAB_ENVIRONMENT:
    home_directory = './drive/MyDrive/LAB/COMP90089__GroupWork__Py/' # my home directory is stored in ./LAB of google drive
    if MODEL == 'ebr':
        # !pip install interpret==0.5.0
    elif MODEL == 'cbr':
        # !pip install catboost
    elif MODEL in ['tf', 'mlp']:
        # !pip install PyTorch2Sklearn
    # !pip install JXAutoML
else:
    home_directory = '../../'

from JXAutoML.YangZhouB_10CV import YangZhouB_10CV as Tuner

import pandas as pd
# Out:
# Collecting JXAutoML
#   Downloading JXAutoML-0.4.4-py3-none-any.whl.metadata (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.2/67.2 kB 656.5 kB/s eta 0:00:00
# Downloading JXAutoML-0.4.4-py3-none-any.whl (52 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.1/52.1 kB 2.1 MB/s eta 0:00:00
# Installing collected packages: JXAutoML
# Successfully installed JXAutoML-0.4.4

# %%
# Parameters that are same for every script

FOLDS = 10  # we have decided to do 10 fold validation

SEED = 42

TASK_TYPE = 'Classification'  # this task is a classification task

# we have decided to tune features as hp
TUNE_FEATURES_AS_HYPERPARAMETERS = True

# %% [markdown]
# ---

# %%
# model to use to tune
from lightgbm import LGBMClassifier as clf

# what values to try for each hyperparameter
parameter_choices = {
    'n_estimators': (25, 50, 100, 200, 400, 800),
    'max_depth': (3, 6, 12, 24, 48, 96, 192),
    'subsample': (0.4, 0.55, 0.7, 0.85, 1),
    'colsample_bytree': (0.4, 0.55, 0.7, 0.85, 1),
    'learning_rate': (0.00000001, 0.000001, 0.0001, 0.01, 0.1),
    'reg_alpha': (0.0001, 0.001, 0.01, 0.1, 1, 10)
}

# what values to set non-tuneable parameters/hyperparameters
non_tunable_hyperparameters_dict = {
                                    'random_state': SEED,
                                    'n_jobs': -1,
                                    'verbose': -1
                                    }
# Out:
# /usr/local/lib/python3.10/dist-packages/dask/dataframe/__init__.py:42: FutureWarning:
# Dask dataframe query planning is disabled because dask-expr is not installed.
#
# You can install it with `pip install dask[dataframe]` or `conda install dask`.
# This will raise in a future version.
#
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ---

# %% [markdown]
# Read in and Prepare Data

# %%
# Import data and store as lists

train_x_list = []
train_y_list = []
val_x_list = []
val_y_list = []

for i in range(FOLDS):
    train_data = pd.read_csv(
        f'{home_directory}data/curated/modelling/{PREPROCESSING}/train_{i}.csv')
    val_data = pd.read_csv(
        f'{home_directory}data/curated/modelling/{PREPROCESSING}/val_{i}.csv')

    # get the correct rows for X and y
    train_x = train_data.drop(
        ['mortality_status', 'subject_id', 'hadm_id', 'stay_id'], axis=1)
    train_y = train_data['mortality_status']
    val_x = val_data.drop(
        ['mortality_status', 'subject_id', 'hadm_id', 'stay_id'], axis=1)
    val_y = val_data['mortality_status']

    train_x_list.append(train_x)
    train_y_list.append(train_y)
    val_x_list.append(val_x)
    val_y_list.append(val_y)

# %%
# Import feature importance ordering

with open(f'{home_directory}models/xgb_feature_importance_ordering_{PREPROCESSING}.pickle', 'rb') as f:
    feature_importance_ordering = pickle.load(f)

# %% [markdown]
# Set parameters

# %%
# initialisation
tuner = Tuner()

print('---')

# define what model we are tuning
tuner.read_in_model(clf, TASK_TYPE, optimised_metric=OPTIMISED_METRIC)

print('---')

# read in the data for training and validation
tuner.read_in_data(train_x_list, train_y_list, val_x_list, val_y_list)

print('---')

# set what hp values to tune
tuner.set_hyperparameters(parameter_choices)
# WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

# set up hp values that need to be changed from default but NOT to be tuned
tuner.set_non_tuneable_hyperparameters(non_tunable_hyperparameters_dict)

print('---')

# set up feature importance ordering

if TUNE_FEATURES_AS_HYPERPARAMETERS:
    tuner.set_features(feature_importance_ordering)
    # WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

try:  # try to read in previous results to continue tuning ...
    tuner.read_in_tuning_result_df(
        f'{home_directory}models/tuning/{TUNER}_{MODEL}_{PREPROCESSING}.csv')
except:
    print('No previous tuning data read in')

print('---')

# set up where to save the tuning result csv
tuner.set_tuning_result_saving_address(
    f'{home_directory}models/tuning/{TUNER}_{MODEL}_{PREPROCESSING}.csv')

print('---')

# set up where to save the current best model
tuner.set_best_model_saving_address(
    f'{home_directory}models/tmp_models/{TUNER}_{MODEL}_{PREPROCESSING}')
# Out:
# YangZhouB Initialised
# ---
# Successfully read in model <class 'lightgbm.sklearn.LGBMClassifier'>, which is a Classification model optimising for f1
# ---
# Read in Train X data list
# Read in Train y data list
# Read in Val X data list
# Read in Val y data list
# ---
# Successfully recorded hyperparameter choices
# ---
# Successfully recorded non_tuneable_hyperparameter choices
# ---
# Successfully recorded tuneable feature combination choices and updated relevant internal structures
# ---
# Successfully read in tuning result of 2850 rows, for 2850.0 combos
# ---
# Successfully set tuning output address
# ---
# Successfully set best model output address

# %%
# ignore warnings

import warnings
warnings.filterwarnings("ignore")

# %%
# begin tuning ... (or continue training)

tuner.tune()
# Out:
# Streaming output truncated to the last 5000 lines.
#             {'n_estimators': 800, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 11}
#             Current best combo (with val score 0.5072):
#                     {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 20}
#         Has trained 2850 of 1512000 combinations so far
# 	round 30 iteration:  1
#
# Already Trained and Tested combination (val score of 0.4775):
#             {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 10}
#             Current best combo (with val score 0.5072):
#                     {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 20}
#         Has trained 2850 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.4143):
#             {'n_estimators': 800, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 10}
#             Current best combo (with val score 0.5072):
#                     {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 20}
#         Has trained 2850 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.4345):
#             {'n_estimators': 400, 'max_depth': 6, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 10}
#             Current best combo (with val score 0.5072):
#                     {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 20}
#         Has trained 2850 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.4463):
#             {'n_estimators': 400, 'max_depth': 3, 'subsample': 0.55, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 10}
#             Current best combo (with val score 0.5072):
#                     {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 20}
#         Has trained 2850 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.4478):
#             {'n_estimators': 400, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.55, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 10}
#             Current best combo (with val score 0.5072):
#                     {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 20}
#         Has trained 2850 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.2985):
#             {'n_estimators': 400, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.0001, 'features': 10}
#             Current best combo (with val score 0.5072):
#                     {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 20}
#         Has trained 2850 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.4616):
#             {'n_estimators': 400, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.001, 'features': 10}
#             Current best combo (with val score 0.5072):
#                     {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 20}
#         Has trained 2850 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.3857):
#             {'n_estimators': 400, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 9}
#             Current best combo (with val score 0.5072):
#                     {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 20}
#         Has trained 2850 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.4595):
#             {'n_estimators': 400, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 11}
#             Current best combo (with val score 0.5072):
#                     {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 20}
#         Has trained 2850 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.4345):
#             {'n_estimators': 400, 'max_depth': 6, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 10}
#             Current best combo (with val score 0.5072):
#                     {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 20}
#         Has trained 2850 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.4143):
#             {'n_estimators': 800, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 10}
#             Current best combo (with val score 0.5072):
#                     {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 20}
#         Has trained 2850 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.3666):
#             {'n_estimators': 800, 'max_depth': 12, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 10}
#             Current best combo (with val score 0.5072):
#                     {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 20}
#         Has trained 2850 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.4168):
#             {'n_estimators': 800, 'max_depth': 6, 'subsample': 0.55, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 10}
#             Current best combo (with val score 0.5072):
#                     {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 20}
#         Has trained 2850 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.4502):
#             {'n_estimators': 800, 'max_depth': 6, 'subsample': 0.4, 'colsample_bytree': 0.55, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 10}
#             Current best combo (with val score 0.5072):
#                     {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 20}
#         Has trained 2850 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.4267):
#             {'n_estimators': 800, 'max_depth': 6, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.0001, 'features': 10}
#             Current best combo (with val score 0.5072):
#                     {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 20}
#         Has trained 2850 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.414):
#             {'n_estimators': 800, 'max_depth': 6, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.001, 'features': 10}
#             Current best combo (with val score 0.5072):
#                     {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 20}
#         Has trained 2850 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.3763):
#             {'n_estimators': 800, 'max_depth': 6, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 9}
#             Current best combo (with val score 0.5072):
#                     {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 20}
#         Has trained 2850 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.4424):
#             {'n_estimators': 800, 'max_depth': 6, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 11}
#             Current best combo (with val score 0.5072):
#                     {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 20}
#         Has trained 2850 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.4463):
#             {'n_estimators': 400, 'max_depth': 3, 'subsample': 0.55, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 10}
#             Current best combo (with val score 0.5072):
#                     {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 20}
#         Has trained 2850 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.4168):
#             {'n_estimators': 800, 'max_depth': 6, 'subsample': 0.55, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 10}
#             Current best combo (with val score 0.5072):
#                     {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 20}
#         Has trained 2850 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.4143):
#             {'n_estimators': 800, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 10}
#             Current best combo (with val score 0.5072):
#                     {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 20}
#         Has trained 2850 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.4143):
#             {'n_estimators': 800, 'max_depth': 3, 'subsample': 0.7, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 10}
#             Current best combo (with val score 0.5072):
#                     {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 20}
#         Has trained 2850 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.4396):
#             {'n_estimators': 800, 'max_depth': 3, 'subsample': 0.55, 'colsample_bytree': 0.55, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 10}
#             Current best combo (with val score 0.5072):
#                     {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 20}
#         Has trained 2850 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.4649):
#             {'n_estimators': 800, 'max_depth': 3, 'subsample': 0.55, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.0001, 'features': 10}
#             Current best combo (with val score 0.5072):
#                     {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 20}
#         Has trained 2850 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.4405):
#             {'n_estimators': 800, 'max_depth': 3, 'subsample': 0.55, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.001, 'features': 10}
#             Current best combo (with val score 0.5072):
#                     {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 20}
#         Has trained 2850 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.3762):
#             {'n_estimators': 800, 'max_depth': 3, 'subsample': 0.55, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 9}
#             Current best combo (with val score 0.5072):
#                     {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 20}
#         Has trained 2850 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.437):
#             {'n_estimators': 800, 'max_depth': 3, 'subsample': 0.55, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 11}
#             Current best combo (with val score 0.5072):
#                     {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 20}
#         Has trained 2850 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.4478):
#             {'n_estimators': 400, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.55, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 10}
#             Current best combo (with val score 0.5072):
#                     {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 20}
#         Has trained 2850 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.4502):
#             {'n_estimators': 800, 'max_depth': 6, 'subsample': 0.4, 'colsample_bytree': 0.55, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 10}
#             Current best combo (with val score 0.5072):
#                     {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 20}
#         Has trained 2850 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.4396):
#             {'n_estimators': 800, 'max_depth': 3, 'subsample': 0.55, 'colsample_bytree': 0.55, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 10}
#             Current best combo (with val score 0.5072):
#                     {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 20}
#         Has trained 2850 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.4143):
#             {'n_estimators': 800, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 10}
#             Current best combo (with val score 0.5072):
#                     {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 20}
#         Has trained 2850 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.4431):
#             {'n_estimators': 800, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.7, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 10}
#             Current best combo (with val score 0.5072):
#                     {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 20}
#         Has trained 2850 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.4749):
#             {'n_estimators': 800, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.55, 'learning_rate': 0.01, 'reg_alpha': 0.0001, 'features': 10}
#             Current best combo (with val score 0.5072):
#                     {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 20}
#         Has trained 2850 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.4334):
#             {'n_estimators': 800, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.55, 'learning_rate': 0.1, 'reg_alpha': 0.001, 'features': 10}
#             Current best combo (with val score 0.5072):
#                     {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 20}
#         Has trained 2850 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.383):
#             {'n_estimators': 800, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.55, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 9}
#             Current best combo (with val score 0.5072):
#                     {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 20}
#         Has trained 2850 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.437):
#             {'n_estimators': 800, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.55, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 11}
#             Current best combo (with val score 0.5072):
#                     {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 20}
#         Has trained 2850 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.2985):
#             {'n_estimators': 400, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.0001, 'features': 10}
#             Current best combo (with val score 0.5072):
#                     {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 20}
#         Has trained 2850 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.4267):
#             {'n_estimators': 800, 'max_depth': 6, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.0001, 'features': 10}
#             Current best combo (with val score 0.5072):
#                     {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 20}
#         Has trained 2850 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.4649):
#             {'n_estimators': 800, 'max_depth': 3, 'subsample': 0.55, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.0001, 'features': 10}
#             Current best combo (with val score 0.5072):
#                     {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 20}
#         Has trained 2850 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.4749):
#             {'n_estimators': 800, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.55, 'learning_rate': 0.01, 'reg_alpha': 0.0001, 'features': 10}
#             Current best combo (with val score 0.5072):
#                     {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 20}
#         Has trained 2850 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.0):
#             {'n_estimators': 800, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.0001, 'reg_alpha': 0.0001, 'features': 10}
#             Current best combo (with val score 0.5072):
#                     {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 20}
#         Has trained 2850 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.4143):
#             {'n_estimators': 800, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 10}
#             Current best combo (with val score 0.5072):
#                     {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 20}
#         Has trained 2850 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.4592):
#             {'n_estimators': 800, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.001, 'features': 10}
#             Current best combo (with val score 0.5072):
#                     {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 20}
#         Has trained 2850 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.4399):
#             {'n_estimators': 800, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.0001, 'features': 9}
#             Current best combo (with val score 0.5072):
#                     {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 20}
#         Has trained 2850 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.4737):
#             {'n_estimators': 800, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.0001, 'features': 11}
#             Current best combo (with val score 0.5072):
#                     {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 20}
#         Has trained 2850 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.4616):
#             {'n_estimators': 400, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.001, 'features': 10}
#             Current best combo (with val score 0.5072):
#                     {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 20}
#         Has trained 2850 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.414):
#             {'n_estimators': 800, 'max_depth': 6, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.001, 'features': 10}
#             Current best combo (with val score 0.5072):
#                     {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 20}
#         Has trained 2850 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.4405):
#             {'n_estimators': 800, 'max_depth': 3, 'subsample': 0.55, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.001, 'features': 10}
#             Current best combo (with val score 0.5072):
#                     {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 20}
#         Has trained 2850 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.4334):
#             {'n_estimators': 800, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.55, 'learning_rate': 0.1, 'reg_alpha': 0.001, 'features': 10}
#             Current best combo (with val score 0.5072):
#                     {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 20}
#         Has trained 2850 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.4592):
#             {'n_estimators': 800, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.001, 'features': 10}
#             Current best combo (with val score 0.5072):
#                     {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 20}
#         Has trained 2850 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.4143):
#             {'n_estimators': 800, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 10}
#             Current best combo (with val score 0.5072):
#                     {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 20}
#         Has trained 2850 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.4381):
#             {'n_estimators': 800, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.01, 'features': 10}
#             Current best combo (with val score 0.5072):
#                     {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 20}
#         Has trained 2850 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.3887):
#             {'n_estimators': 800, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.001, 'features': 9}
#             Current best combo (with val score 0.5072):
#                     {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 20}
#         Has trained 2850 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.4292):
#             {'n_estimators': 800, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.001, 'features': 11}
#             Current best combo (with val score 0.5072):
#                     {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 20}
#         Has trained 2850 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.4595):
#             {'n_estimators': 400, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 11}
#             Current best combo (with val score 0.5072):
#                     {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 20}
#         Has trained 2850 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.4424):
#             {'n_estimators': 800, 'max_depth': 6, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 11}
#             Current best combo (with val score 0.5072):
#                     {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 20}
#         Has trained 2850 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.437):
#             {'n_estimators': 800, 'max_depth': 3, 'subsample': 0.55, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 11}
#             Current best combo (with val score 0.5072):
#                     {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 20}
#         Has trained 2850 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.437):
#             {'n_estimators': 800, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.55, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 11}
#             Current best combo (with val score 0.5072):
#                     {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 20}
#         Has trained 2850 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.4737):
#             {'n_estimators': 800, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.01, 'reg_alpha': 0.0001, 'features': 11}
#             Current best combo (with val score 0.5072):
#                     {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 20}
#         Has trained 2850 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.4292):
#             {'n_estimators': 800, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.001, 'features': 11}
#             Current best combo (with val score 0.5072):
#                     {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 20}
#         Has trained 2850 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.4143):
#             {'n_estimators': 800, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 10}
#             Current best combo (with val score 0.5072):
#                     {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 20}
#         Has trained 2850 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.4025):
#             {'n_estimators': 800, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 12}
#             Current best combo (with val score 0.5072):
#                     {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 20}
#         Has trained 2850 of 1512000 combinations so far
# % Combos Checked Thus Far: 2850 out of 1512000 which is 0.188492%
# Cruising Coordrdinate 772 of 1056
#
# Cruising Coordrdinate 773 of 1056
#
# Cruising Coordrdinate 774 of 1056
#
# Cruising Coordrdinate 775 of 1056
#
# Cruise suspended due to suspicious case
# Guidance: round 31
#
# 	round 31 iteration:  0
#
# Already Trained and Tested combination (val score of 0.4803):
#             {'n_estimators': 400, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 10}
#             Current best combo (with val score 0.5072):
#                     {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 20}
#         Has trained 2850 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.3514):
#             {'n_estimators': 800, 'max_depth': 6, 'subsample': 1, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 10}
#             Current best combo (with val score 0.5072):
#                     {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 20}
#         Has trained 2850 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.4553):
#             {'n_estimators': 800, 'max_depth': 3, 'subsample': 0.85, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 10}
#             Current best combo (with val score 0.5072):
#                     {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 20}
#         Has trained 2850 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.4734):
#             {'n_estimators': 800, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 0.85, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 10}
#             Current best combo (with val score 0.5072):
#                     {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 20}
#         Has trained 2850 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.44):
#             {'n_estimators': 800, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 1, 'learning_rate': 0.01, 'reg_alpha': 0.0001, 'features': 10}
#             Current best combo (with val score 0.5072):
#                     {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 20}
#         Has trained 2850 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.4697):
#             {'n_estimators': 800, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.001, 'features': 10}
#             Current best combo (with val score 0.5072):
#                     {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 20}
#         Has trained 2850 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.3425):
#             {'n_estimators': 800, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 9}
#             Current best combo (with val score 0.5072):
#                     {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 20}
#         Has trained 2850 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.486):
#             {'n_estimators': 800, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 11}
#             Current best combo (with val score 0.5072):
#                     {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 20}
#         Has trained 2850 of 1512000 combinations so far
# 	round 31 iteration:  1
#
# Already Trained and Tested combination (val score of 0.4763):
#             {'n_estimators': 200, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 10}
#             Current best combo (with val score 0.5072):
#                     {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 20}
#         Has trained 2850 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.4553):
#             {'n_estimators': 800, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 10}
#             Current best combo (with val score 0.5072):
#                     {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 20}
#         Has trained 2850 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.3794):
#             {'n_estimators': 400, 'max_depth': 6, 'subsample': 1, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 10}
#             Current best combo (with val score 0.5072):
#                     {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 20}
#         Has trained 2850 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.4803):
#             {'n_estimators': 400, 'max_depth': 3, 'subsample': 0.85, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 10}
#             Current best combo (with val score 0.5072):
#                     {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 20}
#         Has trained 2850 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.4691):
#             {'n_estimators': 400, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 0.85, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 10}
#             Current best combo (with val score 0.5072):
#                     {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 20}
#         Has trained 2850 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.3804):
#             {'n_estimators': 400, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 1, 'learning_rate': 0.01, 'reg_alpha': 0.0001, 'features': 10}
#             Current best combo (with val score 0.5072):
#                     {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 20}
#         Has trained 2850 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.4731):
#             {'n_estimators': 400, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.001, 'features': 10}
#             Current best combo (with val score 0.5072):
#                     {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 20}
#         Has trained 2850 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.3485):
#             {'n_estimators': 400, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 9}
#             Current best combo (with val score 0.5072):
#                     {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 20}
#         Has trained 2850 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.4845):
#             {'n_estimators': 400, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 11}
#             Current best combo (with val score 0.5072):
#                     {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 20}
#         Has trained 2850 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.4803):
#             {'n_estimators': 400, 'max_depth': 3, 'subsample': 0.85, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 10}
#             Current best combo (with val score 0.5072):
#                     {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 20}
#         Has trained 2850 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.3514):
#             {'n_estimators': 800, 'max_depth': 6, 'subsample': 0.85, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 10}
#             Current best combo (with val score 0.5072):
#                     {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 20}
#         Has trained 2850 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.4553):
#             {'n_estimators': 800, 'max_depth': 3, 'subsample': 0.7, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 10}
#             Current best combo (with val score 0.5072):
#                     {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 20}
#         Has trained 2850 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.4553):
#             {'n_estimators': 800, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 10}
#             Current best combo (with val score 0.5072):
#                     {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 20}
#         Has trained 2850 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.4734):
#             {'n_estimators': 800, 'max_depth': 3, 'subsample': 0.85, 'colsample_bytree': 0.85, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 10}
#             Current best combo (with val score 0.5072):
#                     {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 20}
#         Has trained 2850 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.44):
#             {'n_estimators': 800, 'max_depth': 3, 'subsample': 0.85, 'colsample_bytree': 1, 'learning_rate': 0.01, 'reg_alpha': 0.0001, 'features': 10}
#             Current best combo (with val score 0.5072):
#                     {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 20}
#         Has trained 2850 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.4697):
#             {'n_estimators': 800, 'max_depth': 3, 'subsample': 0.85, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.001, 'features': 10}
#             Current best combo (with val score 0.5072):
#                     {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 20}
#         Has trained 2850 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.3425):
#             {'n_estimators': 800, 'max_depth': 3, 'subsample': 0.85, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 9}
#             Current best combo (with val score 0.5072):
#                     {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 20}
#         Has trained 2850 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.486):
#             {'n_estimators': 800, 'max_depth': 3, 'subsample': 0.85, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 11}
#             Current best combo (with val score 0.5072):
#                     {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 20}
#         Has trained 2850 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.4691):
#             {'n_estimators': 400, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 0.85, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 10}
#             Current best combo (with val score 0.5072):
#                     {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 20}
#         Has trained 2850 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.4229):
#             {'n_estimators': 800, 'max_depth': 6, 'subsample': 1, 'colsample_bytree': 0.85, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 10}
#             Current best combo (with val score 0.5072):
#                     {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 20}
#         Has trained 2850 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.4734):
#             {'n_estimators': 800, 'max_depth': 3, 'subsample': 0.85, 'colsample_bytree': 0.85, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 10}
#             Current best combo (with val score 0.5072):
#                     {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 20}
#         Has trained 2850 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.4431):
#             {'n_estimators': 800, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 0.7, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 10}
#             Current best combo (with val score 0.5072):
#                     {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 20}
#         Has trained 2850 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.4553):
#             {'n_estimators': 800, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 10}
#             Current best combo (with val score 0.5072):
#                     {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 20}
#         Has trained 2850 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.4683):
#             {'n_estimators': 800, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 0.85, 'learning_rate': 0.01, 'reg_alpha': 0.0001, 'features': 10}
#             Current best combo (with val score 0.5072):
#                     {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 20}
#         Has trained 2850 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.4651):
#             {'n_estimators': 800, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 0.85, 'learning_rate': 0.1, 'reg_alpha': 0.001, 'features': 10}
#             Current best combo (with val score 0.5072):
#                     {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 20}
#         Has trained 2850 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.3568):
#             {'n_estimators': 800, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 0.85, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 9}
#             Current best combo (with val score 0.5072):
#                     {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 20}
#         Has trained 2850 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.4655):
#             {'n_estimators': 800, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 0.85, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 11}
#             Current best combo (with val score 0.5072):
#                     {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 20}
#         Has trained 2850 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.4731):
#             {'n_estimators': 400, 'max_depth': 3, 'subsample': 1, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.001, 'features': 10}
# ...
#
# 	round FINAL iteration:  0
#
# Already Trained and Tested combination (val score of 0.4771):
#             {'n_estimators': 100, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 20}
#             Current best combo (with val score 0.5072):
#                     {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 20}
#         Has trained 2850 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.4944):
#             {'n_estimators': 400, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 20}
#             Current best combo (with val score 0.5072):
#                     {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 20}
#         Has trained 2850 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.3271):
#             {'n_estimators': 200, 'max_depth': 6, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 20}
#             Current best combo (with val score 0.5072):
#                     {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 20}
#         Has trained 2850 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.5072):
#             {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.55, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 20}
#             Current best combo (with val score 0.5072):
#                     {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 20}
#         Has trained 2850 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.42):
#             {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.85, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 20}
#             Current best combo (with val score 0.5072):
#                     {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 20}
#         Has trained 2850 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.236):
#             {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.01, 'reg_alpha': 0.0001, 'features': 20}
#             Current best combo (with val score 0.5072):
#                     {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 20}
#         Has trained 2850 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.5034):
#             {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.001, 'features': 20}
#             Current best combo (with val score 0.5072):
#                     {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 20}
#         Has trained 2850 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.4931):
#             {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 19}
#             Current best combo (with val score 0.5072):
#                     {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 20}
#         Has trained 2850 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.4427):
#             {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 21}
#             Current best combo (with val score 0.5072):
#                     {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 20}
#         Has trained 2850 of 1512000 combinations so far
# 	round FINAL iteration:  1
#
# Already Trained and Tested combination (val score of 0.4771):
#             {'n_estimators': 100, 'max_depth': 3, 'subsample': 0.55, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 20}
#             Current best combo (with val score 0.5072):
#                     {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 20}
#         Has trained 2850 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.4944):
#             {'n_estimators': 400, 'max_depth': 3, 'subsample': 0.55, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 20}
#             Current best combo (with val score 0.5072):
#                     {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 20}
#         Has trained 2850 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.3271):
#             {'n_estimators': 200, 'max_depth': 6, 'subsample': 0.55, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 20}
#             Current best combo (with val score 0.5072):
#                     {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 20}
#         Has trained 2850 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.5072):
#             {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 20}
#             Current best combo (with val score 0.5072):
#                     {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 20}
#         Has trained 2850 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.5072):
#             {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.7, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 20}
#             Current best combo (with val score 0.5072):
#                     {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 20}
#         Has trained 2850 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.42):
#             {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.55, 'colsample_bytree': 0.85, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 20}
#             Current best combo (with val score 0.5072):
#                     {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 20}
#         Has trained 2850 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.236):
#             {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.55, 'colsample_bytree': 1, 'learning_rate': 0.01, 'reg_alpha': 0.0001, 'features': 20}
#             Current best combo (with val score 0.5072):
#                     {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 20}
#         Has trained 2850 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.5034):
#             {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.55, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.001, 'features': 20}
#             Current best combo (with val score 0.5072):
#                     {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 20}
#         Has trained 2850 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.4931):
#             {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.55, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 19}
#             Current best combo (with val score 0.5072):
#                     {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 20}
#         Has trained 2850 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.4427):
#             {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.55, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 21}
#             Current best combo (with val score 0.5072):
#                     {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 20}
#         Has trained 2850 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.429):
#             {'n_estimators': 100, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.001, 'features': 20}
#             Current best combo (with val score 0.5072):
#                     {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 20}
#         Has trained 2850 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.4916):
#             {'n_estimators': 400, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.001, 'features': 20}
#             Current best combo (with val score 0.5072):
#                     {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 20}
#         Has trained 2850 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.3241):
#             {'n_estimators': 200, 'max_depth': 6, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.001, 'features': 20}
#             Current best combo (with val score 0.5072):
#                     {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 20}
#         Has trained 2850 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.5034):
#             {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.55, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.001, 'features': 20}
#             Current best combo (with val score 0.5072):
#                     {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 20}
#         Has trained 2850 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.4035):
#             {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 0.85, 'learning_rate': 0.1, 'reg_alpha': 0.001, 'features': 20}
#             Current best combo (with val score 0.5072):
#                     {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 20}
#         Has trained 2850 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.2359):
#             {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.01, 'reg_alpha': 0.001, 'features': 20}
#             Current best combo (with val score 0.5072):
#                     {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 20}
#         Has trained 2850 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.5072):
#             {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 20}
#             Current best combo (with val score 0.5072):
#                     {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 20}
#         Has trained 2850 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.4947):
#             {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.01, 'features': 20}
#             Current best combo (with val score 0.5072):
#                     {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 20}
#         Has trained 2850 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.4804):
#             {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.001, 'features': 19}
#             Current best combo (with val score 0.5072):
#                     {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 20}
#         Has trained 2850 of 1512000 combinations so far
# Already Trained and Tested combination (val score of 0.4623):
#             {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.001, 'features': 21}
#             Current best combo (with val score 0.5072):
#                     {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 20}
#         Has trained 2850 of 1512000 combinations so far
# % Combos Checked Thus Far: 2850 out of 1512000 which is 0.188492%
# Max Val Score:
#  0.507214
# Max Val Score Std:
#  0.061495
# Best Combo Train Score:
#  0.792755
# Best Combo Train Score Std:
#  0.010081
# Max Combo Index:
#  (3, 0, 0, 4, 4, 0, 20) out of [6, 7, 5, 5, 5, 6, 48] (note best combo is 0-indexed)
# Max Combo Hyperparamer Combination:
#  {'n_estimators': 200, 'max_depth': 3, 'subsample': 0.4, 'colsample_bytree': 1, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 20}
# Max Combo Features:
#  ('procedure_225792', 'ventilation_used', 'procedure_226475', 'lods_score', 'procedure_225802', 'hospital_stay_duration', 'procedure_224276', 'procedure_229519', 'procedure_226236', 'race_AMERICAN INDIAN/ALASKA NATIVE', 'race_ASIAN', 'race_ASIAN - ASIAN INDIAN', 'race_ASIAN - CHINESE', 'race_ASIAN - KOREAN', 'race_ASIAN - SOUTH EAST ASIAN', 'race_BLACK/AFRICAN', 'race_BLACK/AFRICAN AMERICAN', 'race_BLACK/CAPE VERDEAN', 'race_BLACK/CARIBBEAN ISLAND', 'race_HISPANIC OR LATINO', 'race_HISPANIC/LATINO - CENTRAL AMERICAN', 'race_HISPANIC/LATINO - COLUMBIAN', 'race_HISPANIC/LATINO - CUBAN', 'race_HISPANIC/LATINO - DOMINICAN', 'race_HISPANIC/LATINO - GUATEMALAN', 'race_HISPANIC/LATINO - HONDURAN', 'race_HISPANIC/LATINO - MEXICAN', 'race_HISPANIC/LATINO - PUERTO RICAN', 'race_HISPANIC/LATINO - SALVADORAN', 'race_MULTIPLE RACE/ETHNICITY', 'race_NATIVE HAWAIIAN OR OTHER PACIFIC ISLANDER', 'race_OTHER', 'race_PATIENT DECLINED TO ANSWER', 'race_PORTUGUESE', 'race_SOUTH AMERICAN', 'race_UNABLE TO OBTAIN', 'race_WHITE', 'race_WHITE - BRAZILIAN', 'race_WHITE - EASTERN EUROPEAN', 'race_WHITE - OTHER EUROPEAN', 'race_WHITE - RUSSIAN', 'race_UNKNOWN', 'oasis_score', 'procedure_224267', 'icu_stay_duration', 'procedure_229580', 'procedure_224270', 'procedure_225446', 'procedure_225400', 'procedure_221223', 'unique_drugs', 'procedure_227712', 'procedure_224263')
# % Combos Checked: 2850 out of 1512000 which is 0.188492%
