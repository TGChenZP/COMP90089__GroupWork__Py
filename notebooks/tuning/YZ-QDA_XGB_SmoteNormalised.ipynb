# %% [markdown]
# # Tuning Script

# %%
# Parameters subject to change in every script - involved in naming

MODEL = 'qda'
PREPROCESSING = 'smote_normalise'
TUNER = 'yangzhoub'
OPTIMISED_METRIC = 'f1'

# %% [markdown]
# ---

# %%
# detect whether this is a google environment

COLAB_ENVIRONMENT = False

try:
    from google.colab import drive
    drive.mount('/content/drive')
    COLAB_ENVIRONMENT = True
except:
    pass
# Out:
# Mounted at /content/drive

# %%
import sys
import os
import pickle

if COLAB_ENVIRONMENT:
    home_directory = './drive/MyDrive/LAB/COMP90089__GroupWork__Py/' # my home directory is stored in ./LAB of google drive
    if MODEL == 'ebr':
        # !pip install interpret==0.5.0
    elif MODEL == 'cbr':
        # !pip install catboost
    elif MODEL in ['tf', 'mlp']:
        # !pip install PyTorch2Sklearn
    # !pip install JXAutoML
else:
    home_directory = '../../'

from JXAutoML.YangZhouB_10CV import YangZhouB_10CV as Tuner

import pandas as pd
# Out:
# Collecting JXAutoML
#   Downloading JXAutoML-0.4.4-py3-none-any.whl.metadata (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.2/67.2 kB 2.0 MB/s eta 0:00:00
# Downloading JXAutoML-0.4.4-py3-none-any.whl (52 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.1/52.1 kB 4.1 MB/s eta 0:00:00
# Installing collected packages: JXAutoML
# Successfully installed JXAutoML-0.4.4

# %%
# Parameters that are same for every script

FOLDS = 10  # we have decided to do 10 fold validation

SEED = 42

TASK_TYPE = 'Classification'  # this task is a classification task

# we have decided to tune features as hp
TUNE_FEATURES_AS_HYPERPARAMETERS = True

# %% [markdown]
# ---

# %%
# model to use to tune
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis as clf

# what values to try for each hyperparameter
parameter_choices = {
    'tol': (0.00001, 0.0001, 0.001, 0.01, 0.1, 1, 10),
    'reg_param': (0.00001, 0.0001, 0.001, 0.01, 0.1, 1)
}

# what values to set non-tuneable parameters/hyperparameters
non_tunable_hyperparameters_dict = {}

# %% [markdown]
# ---

# %% [markdown]
# Read in and Prepare Data

# %%
# Import data and store as lists

train_x_list = []
train_y_list = []
val_x_list = []
val_y_list = []

for i in range(FOLDS):
    train_data = pd.read_csv(
        f'{home_directory}data/curated/modelling/{PREPROCESSING}/train_{i}.csv')
    val_data = pd.read_csv(
        f'{home_directory}data/curated/modelling/{PREPROCESSING}/val_{i}.csv')

    # get the correct rows for X and y
    train_x = train_data.drop(
        ['mortality_status', 'subject_id', 'hadm_id', 'stay_id'], axis=1)
    train_y = train_data['mortality_status']
    val_x = val_data.drop(
        ['mortality_status', 'subject_id', 'hadm_id', 'stay_id'], axis=1)
    val_y = val_data['mortality_status']

    train_x_list.append(train_x)
    train_y_list.append(train_y)
    val_x_list.append(val_x)
    val_y_list.append(val_y)

# %%
# Import feature importance ordering

with open(f'{home_directory}models/xgb_feature_importance_ordering_{PREPROCESSING}.pickle', 'rb') as f:
    feature_importance_ordering = pickle.load(f)

# %% [markdown]
# Set parameters

# %%
# initialisation
tuner = Tuner()

print('---')

# define what model we are tuning
tuner.read_in_model(clf, TASK_TYPE, optimised_metric=OPTIMISED_METRIC)

print('---')

# read in the data for training and validation
tuner.read_in_data(train_x_list, train_y_list, val_x_list, val_y_list)

print('---')

# set what hp values to tune
tuner.set_hyperparameters(parameter_choices)
# WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

# set up hp values that need to be changed from default but NOT to be tuned
tuner.set_non_tuneable_hyperparameters(non_tunable_hyperparameters_dict)

print('---')

# set up feature importance ordering

if TUNE_FEATURES_AS_HYPERPARAMETERS:
    tuner.set_features(feature_importance_ordering)
    # WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

try:  # try to read in previous results to continue tuning ...
    tuner.read_in_tuning_result_df(
        f'{home_directory}models/tuning/{TUNER}_{MODEL}_{PREPROCESSING}.csv')
except:
    print('No previous tuning data read in')

print('---')

# set up where to save the tuning result csv
tuner.set_tuning_result_saving_address(
    f'{home_directory}models/tuning/{TUNER}_{MODEL}_{PREPROCESSING}.csv')

print('---')

# set up where to save the current best model
tuner.set_best_model_saving_address(
    f'{home_directory}models/tmp_models/{TUNER}_{MODEL}_{PREPROCESSING}')
# Out:
# YangZhouB Initialised
# ---
# Successfully read in model <class 'sklearn.discriminant_analysis.QuadraticDiscriminantAnalysis'>, which is a Classification model optimising for f1
# ---
# Read in Train X data list
# Read in Train y data list
# Read in Val X data list
# Read in Val y data list
# ---
# Successfully recorded hyperparameter choices
# ---
# Successfully recorded non_tuneable_hyperparameter choices
# ---
# Successfully recorded tuneable feature combination choices and updated relevant internal structures
# ---
# No previous tuning data read in
# ---
# Successfully set tuning output address
# ---
# Successfully set best model output address

# %%
# ignore warnings

import warnings
warnings.filterwarnings("ignore")

# %%
# begin tuning ... (or continue training)

tuner.tune()
# Out:
# BEGIN TUNING
#
#
# STAGE ZERO: Tune all Cruise combinations
#
#
# Trained and Tested combination 1 of 2016, taking 0.12 seconds to get val score of 0.3121:
#                 {'tol': 10, 'reg_param': 1e-05, 'features': 35},
#             Current best combo with val score 0.3121:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 35}
# Trained and Tested combination 2 of 2016, taking 0.18 seconds to get val score of 0.0:
#                 {'tol': 10, 'reg_param': 1, 'features': 47},
#             Current best combo with val score 0.3121:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 35}
# Trained and Tested combination 3 of 2016, taking 0.08 seconds to get val score of 0.0:
#                 {'tol': 1e-05, 'reg_param': 1, 'features': 39},
#             Current best combo with val score 0.3121:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 35}
# Trained and Tested combination 4 of 2016, taking 0.06 seconds to get val score of 0.3781:
#                 {'tol': 10, 'reg_param': 1e-05, 'features': 30},
#             Current best combo with val score 0.3781:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 30}
# Trained and Tested combination 5 of 2016, taking 0.11 seconds to get val score of 0.0:
#                 {'tol': 1e-05, 'reg_param': 1, 'features': 30},
#             Current best combo with val score 0.3781:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 30}
# Trained and Tested combination 6 of 2016, taking 0.16 seconds to get val score of 0.0:
#                 {'tol': 1e-05, 'reg_param': 1, 'features': 47},
#             Current best combo with val score 0.3781:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 30}
# Trained and Tested combination 7 of 2016, taking 0.05 seconds to get val score of 0.3095:
#                 {'tol': 1e-05, 'reg_param': 1e-05, 'features': 47},
#             Current best combo with val score 0.3781:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 30}
# Trained and Tested combination 8 of 2016, taking 0.04 seconds to get val score of 0.3089:
#                 {'tol': 1e-05, 'reg_param': 1e-05, 'features': 39},
#             Current best combo with val score 0.3781:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 30}
# Trained and Tested combination 9 of 2016, taking 0.03 seconds to get val score of 0.0:
#                 {'tol': 0.01, 'reg_param': 1, 'features': 25},
#             Current best combo with val score 0.3781:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 30}
# Trained and Tested combination 10 of 2016, taking 0.04 seconds to get val score of 0.3152:
#                 {'tol': 1e-05, 'reg_param': 1e-05, 'features': 43},
#             Current best combo with val score 0.3781:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 30}
# Trained and Tested combination 11 of 2016, taking 0.02 seconds to get val score of 0.3361:
#                 {'tol': 0.01, 'reg_param': 1e-05, 'features': 15},
#             Current best combo with val score 0.3781:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 30}
# Trained and Tested combination 12 of 2016, taking 0.01 seconds to get val score of 0.0:
#                 {'tol': 1e-05, 'reg_param': 1, 'features': 10},
#             Current best combo with val score 0.3781:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 30}
# Trained and Tested combination 13 of 2016, taking 0.03 seconds to get val score of 0.0:
#                 {'tol': 0.01, 'reg_param': 1, 'features': 30},
#             Current best combo with val score 0.3781:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 30}
# Trained and Tested combination 14 of 2016, taking 0.03 seconds to get val score of 0.0:
#                 {'tol': 0.01, 'reg_param': 1, 'features': 20},
#             Current best combo with val score 0.3781:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 30}
# Trained and Tested combination 15 of 2016, taking 0.0 seconds to get val score of 0.3108:
#                 {'tol': 10, 'reg_param': 1e-05, 'features': 0},
#             Current best combo with val score 0.3781:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 30}
# Trained and Tested combination 16 of 2016, taking 0.03 seconds to get val score of 0.3335:
#                 {'tol': 0.01, 'reg_param': 1e-05, 'features': 20},
#             Current best combo with val score 0.3781:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 30}
# Trained and Tested combination 17 of 2016, taking 0.05 seconds to get val score of 0.0:
#                 {'tol': 10, 'reg_param': 1, 'features': 15},
#             Current best combo with val score 0.3781:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 30}
# Trained and Tested combination 18 of 2016, taking 0.02 seconds to get val score of 0.01:
#                 {'tol': 10, 'reg_param': 1, 'features': 5},
#             Current best combo with val score 0.3781:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 30}
# Trained and Tested combination 19 of 2016, taking 0.0 seconds to get val score of 0.3108:
#                 {'tol': 1e-05, 'reg_param': 1, 'features': 0},
#             Current best combo with val score 0.3781:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 30}
# Trained and Tested combination 20 of 2016, taking 0.03 seconds to get val score of 0.3315:
#                 {'tol': 10, 'reg_param': 1e-05, 'features': 10},
#             Current best combo with val score 0.3781:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 30}
# Trained and Tested combination 21 of 2016, taking 0.04 seconds to get val score of 0.3121:
#                 {'tol': 0.01, 'reg_param': 1e-05, 'features': 35},
#             Current best combo with val score 0.3781:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 30}
# Trained and Tested combination 22 of 2016, taking 0.03 seconds to get val score of 0.0:
#                 {'tol': 10, 'reg_param': 1, 'features': 30},
#             Current best combo with val score 0.3781:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 30}
# Trained and Tested combination 23 of 2016, taking 0.0 seconds to get val score of 0.3108:
#                 {'tol': 0.01, 'reg_param': 1e-05, 'features': 0},
#             Current best combo with val score 0.3781:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 30}
# Trained and Tested combination 24 of 2016, taking 0.04 seconds to get val score of 0.0:
#                 {'tol': 10, 'reg_param': 1, 'features': 39},
#             Current best combo with val score 0.3781:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 30}
# Trained and Tested combination 25 of 2016, taking 0.01 seconds to get val score of 0.01:
#                 {'tol': 0.01, 'reg_param': 1, 'features': 5},
#             Current best combo with val score 0.3781:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 30}
# Trained and Tested combination 26 of 2016, taking 0.03 seconds to get val score of 0.0:
#                 {'tol': 1e-05, 'reg_param': 1, 'features': 25},
#             Current best combo with val score 0.3781:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 30}
# Trained and Tested combination 27 of 2016, taking 0.03 seconds to get val score of 0.3335:
#                 {'tol': 1e-05, 'reg_param': 1e-05, 'features': 20},
#             Current best combo with val score 0.3781:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 30}
# Trained and Tested combination 28 of 2016, taking 0.02 seconds to get val score of 0.0:
#                 {'tol': 0.01, 'reg_param': 1, 'features': 10},
#             Current best combo with val score 0.3781:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 30}
# Trained and Tested combination 29 of 2016, taking 0.03 seconds to get val score of 0.3335:
#                 {'tol': 10, 'reg_param': 1e-05, 'features': 20},
#             Current best combo with val score 0.3781:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 30}
# Trained and Tested combination 30 of 2016, taking 0.04 seconds to get val score of 0.3089:
#                 {'tol': 10, 'reg_param': 1e-05, 'features': 39},
#             Current best combo with val score 0.3781:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 30}
# Trained and Tested combination 31 of 2016, taking 0.05 seconds to get val score of 0.0:
#                 {'tol': 1e-05, 'reg_param': 1, 'features': 35},
#             Current best combo with val score 0.3781:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 30}
# Trained and Tested combination 32 of 2016, taking 0.08 seconds to get val score of 0.0:
#                 {'tol': 0.01, 'reg_param': 1, 'features': 47},
#             Current best combo with val score 0.3781:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 30}
# Trained and Tested combination 33 of 2016, taking 0.03 seconds to get val score of 0.3389:
#                 {'tol': 10, 'reg_param': 1e-05, 'features': 25},
#             Current best combo with val score 0.3781:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 30}
# Trained and Tested combination 34 of 2016, taking 0.04 seconds to get val score of 0.3152:
#                 {'tol': 10, 'reg_param': 1e-05, 'features': 43},
#             Current best combo with val score 0.3781:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 30}
# Trained and Tested combination 35 of 2016, taking 0.04 seconds to get val score of 0.0:
#                 {'tol': 1e-05, 'reg_param': 1, 'features': 43},
#             Current best combo with val score 0.3781:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 30}
# Trained and Tested combination 36 of 2016, taking 0.04 seconds to get val score of 0.0:
#                 {'tol': 10, 'reg_param': 1, 'features': 35},
#             Current best combo with val score 0.3781:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 30}
# Trained and Tested combination 37 of 2016, taking 0.06 seconds to get val score of 0.3152:
#                 {'tol': 0.01, 'reg_param': 1e-05, 'features': 43},
#             Current best combo with val score 0.3781:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 30}
# Trained and Tested combination 38 of 2016, taking 0.03 seconds to get val score of 0.3389:
#                 {'tol': 0.01, 'reg_param': 1e-05, 'features': 25},
#             Current best combo with val score 0.3781:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 30}
# Trained and Tested combination 39 of 2016, taking 0.02 seconds to get val score of 0.3315:
#                 {'tol': 0.01, 'reg_param': 1e-05, 'features': 10},
#             Current best combo with val score 0.3781:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 30}
# Trained and Tested combination 40 of 2016, taking 0.05 seconds to get val score of 0.3095:
#                 {'tol': 0.01, 'reg_param': 1e-05, 'features': 47},
#             Current best combo with val score 0.3781:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 30}
# Trained and Tested combination 41 of 2016, taking 0.02 seconds to get val score of 0.0:
#                 {'tol': 1e-05, 'reg_param': 1, 'features': 15},
#             Current best combo with val score 0.3781:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 30}
# Trained and Tested combination 42 of 2016, taking 0.02 seconds to get val score of 0.3315:
#                 {'tol': 1e-05, 'reg_param': 1e-05, 'features': 10},
#             Current best combo with val score 0.3781:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 30}
# Trained and Tested combination 43 of 2016, taking 0.08 seconds to get val score of 0.3781:
#                 {'tol': 1e-05, 'reg_param': 1e-05, 'features': 30},
#             Current best combo with val score 0.3781:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 30}
# Trained and Tested combination 44 of 2016, taking 0.0 seconds to get val score of 0.3108:
#                 {'tol': 1e-05, 'reg_param': 1e-05, 'features': 0},
#             Current best combo with val score 0.3781:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 30}
# Trained and Tested combination 45 of 2016, taking 0.14 seconds to get val score of 0.3095:
#                 {'tol': 10, 'reg_param': 1e-05, 'features': 47},
#             Current best combo with val score 0.3781:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 30}
# Trained and Tested combination 46 of 2016, taking 0.02 seconds to get val score of 0.3232:
#                 {'tol': 0.01, 'reg_param': 1e-05, 'features': 5},
#             Current best combo with val score 0.3781:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 30}
# Trained and Tested combination 47 of 2016, taking 0.02 seconds to get val score of 0.0:
#                 {'tol': 10, 'reg_param': 1, 'features': 10},
#             Current best combo with val score 0.3781:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 30}
# Trained and Tested combination 48 of 2016, taking 0.0 seconds to get val score of 0.3108:
#                 {'tol': 0.01, 'reg_param': 1, 'features': 0},
#             Current best combo with val score 0.3781:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 30}
# Trained and Tested combination 49 of 2016, taking 0.02 seconds to get val score of 0.01:
#                 {'tol': 1e-05, 'reg_param': 1, 'features': 5},
#             Current best combo with val score 0.3781:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 30}
# Trained and Tested combination 50 of 2016, taking 0.0 seconds to get val score of 0.3108:
#                 {'tol': 10, 'reg_param': 1, 'features': 0},
#             Current best combo with val score 0.3781:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 30}
# Trained and Tested combination 51 of 2016, taking 0.02 seconds to get val score of 0.3361:
#                 {'tol': 1e-05, 'reg_param': 1e-05, 'features': 15},
#             Current best combo with val score 0.3781:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 30}
# Trained and Tested combination 52 of 2016, taking 0.04 seconds to get val score of 0.3089:
#                 {'tol': 0.01, 'reg_param': 1e-05, 'features': 39},
#             Current best combo with val score 0.3781:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 30}
# Trained and Tested combination 53 of 2016, taking 0.03 seconds to get val score of 0.0:
#                 {'tol': 1e-05, 'reg_param': 1, 'features': 20},
#             Current best combo with val score 0.3781:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 30}
# Trained and Tested combination 54 of 2016, taking 0.02 seconds to get val score of 0.3232:
#                 {'tol': 10, 'reg_param': 1e-05, 'features': 5},
#             Current best combo with val score 0.3781:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 30}
# Trained and Tested combination 55 of 2016, taking 0.03 seconds to get val score of 0.0:
#                 {'tol': 10, 'reg_param': 1, 'features': 25},
#             Current best combo with val score 0.3781:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 30}
# Trained and Tested combination 56 of 2016, taking 0.04 seconds to get val score of 0.3121:
#                 {'tol': 1e-05, 'reg_param': 1e-05, 'features': 35},
#             Current best combo with val score 0.3781:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 30}
# Trained and Tested combination 57 of 2016, taking 0.06 seconds to get val score of 0.0:
#                 {'tol': 0.01, 'reg_param': 1, 'features': 35},
#             Current best combo with val score 0.3781:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 30}
# Trained and Tested combination 58 of 2016, taking 0.08 seconds to get val score of 0.3781:
#                 {'tol': 0.01, 'reg_param': 1e-05, 'features': 30},
#             Current best combo with val score 0.3781:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 30}
# Trained and Tested combination 59 of 2016, taking 0.04 seconds to get val score of 0.3389:
#                 {'tol': 1e-05, 'reg_param': 1e-05, 'features': 25},
#             Current best combo with val score 0.3781:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 30}
# Trained and Tested combination 60 of 2016, taking 0.04 seconds to get val score of 0.3232:
#                 {'tol': 1e-05, 'reg_param': 1e-05, 'features': 5},
#             Current best combo with val score 0.3781:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 30}
# Trained and Tested combination 61 of 2016, taking 0.02 seconds to get val score of 0.0:
#                 {'tol': 10, 'reg_param': 1, 'features': 20},
#             Current best combo with val score 0.3781:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 30}
# Trained and Tested combination 62 of 2016, taking 0.04 seconds to get val score of 0.0:
#                 {'tol': 0.01, 'reg_param': 1, 'features': 39},
#             Current best combo with val score 0.3781:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 30}
# Trained and Tested combination 63 of 2016, taking 0.02 seconds to get val score of 0.0:
#                 {'tol': 0.01, 'reg_param': 1, 'features': 15},
#             Current best combo with val score 0.3781:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 30}
# Trained and Tested combination 64 of 2016, taking 0.04 seconds to get val score of 0.0:
#                 {'tol': 0.01, 'reg_param': 1, 'features': 43},
#             Current best combo with val score 0.3781:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 30}
# Trained and Tested combination 65 of 2016, taking 0.03 seconds to get val score of 0.0977:
#                 {'tol': 0.01, 'reg_param': 0.01, 'features': 24},
#             Current best combo with val score 0.3781:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 30}
# Trained and Tested combination 66 of 2016, taking 0.02 seconds to get val score of 0.3361:
#                 {'tol': 10, 'reg_param': 1e-05, 'features': 15},
#             Current best combo with val score 0.3781:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 30}
# Trained and Tested combination 67 of 2016, taking 0.04 seconds to get val score of 0.0:
#                 {'tol': 10, 'reg_param': 1, 'features': 43},
#             Current best combo with val score 0.3781:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 30}
#
#
# STAGE ONE: Begin initial Guidance system
#
#
# Guidance: initial round
#
# 	round 0 iteration:  0
#
# Trained and Tested combination 68 of 2016, taking 0.03 seconds to get val score of 0.0977:
#                 {'tol': 0.001, 'reg_param': 0.01, 'features': 24},
#             Current best combo with val score 0.3781:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 30}
# Trained and Tested combination 69 of 2016, taking 0.06 seconds to get val score of 0.0977:
#                 {'tol': 0.1, 'reg_param': 0.01, 'features': 24},
#             Current best combo with val score 0.3781:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 30}
# Trained and Tested combination 70 of 2016, taking 0.07 seconds to get val score of 0.1874:
#                 {'tol': 0.01, 'reg_param': 0.001, 'features': 24},
#             Current best combo with val score 0.3781:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 30}
# Trained and Tested combination 71 of 2016, taking 0.09 seconds to get val score of 0.0:
#                 {'tol': 0.01, 'reg_param': 0.1, 'features': 24},
#             Current best combo with val score 0.3781:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 30}
# Trained and Tested combination 72 of 2016, taking 0.03 seconds to get val score of 0.0977:
#                 {'tol': 0.01, 'reg_param': 0.01, 'features': 23},
#             Current best combo with val score 0.3781:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 30}
# Trained and Tested combination 73 of 2016, taking 0.05 seconds to get val score of 0.0997:
#                 {'tol': 0.01, 'reg_param': 0.01, 'features': 25},
#             Current best combo with val score 0.3781:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 30}
# 	round 0 iteration:  1
#
# Trained and Tested combination 74 of 2016, taking 0.03 seconds to get val score of 0.0977:
#                 {'tol': 0.0001, 'reg_param': 0.01, 'features': 24},
#             Current best combo with val score 0.3781:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 30}
# Already Trained and Tested combination (val score of 0.0977):
#             {'tol': 0.01, 'reg_param': 0.01, 'features': 24}
#             Current best combo (with val score 0.3781):
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 30}
#         Has trained 74 of 2016 combinations so far
# Trained and Tested combination 75 of 2016, taking 0.03 seconds to get val score of 0.1874:
#                 {'tol': 0.001, 'reg_param': 0.001, 'features': 24},
#             Current best combo with val score 0.3781:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 30}
# Trained and Tested combination 76 of 2016, taking 0.03 seconds to get val score of 0.0:
#                 {'tol': 0.001, 'reg_param': 0.1, 'features': 24},
#             Current best combo with val score 0.3781:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 30}
# Trained and Tested combination 77 of 2016, taking 0.03 seconds to get val score of 0.0977:
#                 {'tol': 0.001, 'reg_param': 0.01, 'features': 23},
#             Current best combo with val score 0.3781:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 30}
# Trained and Tested combination 78 of 2016, taking 0.03 seconds to get val score of 0.0997:
#                 {'tol': 0.001, 'reg_param': 0.01, 'features': 25},
#             Current best combo with val score 0.3781:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 30}
# Already Trained and Tested combination (val score of 0.0977):
#             {'tol': 0.01, 'reg_param': 0.01, 'features': 24}
#             Current best combo (with val score 0.3781):
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 30}
#         Has trained 78 of 2016 combinations so far
# Trained and Tested combination 79 of 2016, taking 0.03 seconds to get val score of 0.0977:
#                 {'tol': 1, 'reg_param': 0.01, 'features': 24},
#             Current best combo with val score 0.3781:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 30}
# Trained and Tested combination 80 of 2016, taking 0.03 seconds to get val score of 0.1874:
#                 {'tol': 0.1, 'reg_param': 0.001, 'features': 24},
#             Current best combo with val score 0.3781:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 30}
# Trained and Tested combination 81 of 2016, taking 0.05 seconds to get val score of 0.0:
#                 {'tol': 0.1, 'reg_param': 0.1, 'features': 24},
#             Current best combo with val score 0.3781:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 30}
# Trained and Tested combination 82 of 2016, taking 0.05 seconds to get val score of 0.0977:
#                 {'tol': 0.1, 'reg_param': 0.01, 'features': 23},
#             Current best combo with val score 0.3781:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 30}
# Trained and Tested combination 83 of 2016, taking 0.05 seconds to get val score of 0.0997:
#                 {'tol': 0.1, 'reg_param': 0.01, 'features': 25},
#             Current best combo with val score 0.3781:
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 30}
# Already Trained and Tested combination (val score of 0.1874):
#             {'tol': 0.001, 'reg_param': 0.001, 'features': 24}
#             Current best combo (with val score 0.3781):
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 30}
#         Has trained 83 of 2016 combinations so far
# Already Trained and Tested combination (val score of 0.1874):
#             {'tol': 0.1, 'reg_param': 0.001, 'features': 24}
#             Current best combo (with val score 0.3781):
#                     {'tol': 10, 'reg_param': 1e-05, 'features': 30}
#         Has trained 83 of 2016 combinations so far
# Trained and Tested combination 84 of 2016, taking 0.03 seconds to get val score of 0.4132:
#                 {'tol': 0.01, 'reg_param': 0.0001, 'features': 24},
#             Current best combo with val score 0.4132:
#                     {'tol': 0.01, 'reg_param': 0.0001, 'features': 24}
# Already Trained and Tested combination (val score of 0.0977):
#             {'tol': 0.01, 'reg_param': 0.01, 'features': 24}
#             Current best combo (with val score 0.4132):
#                     {'tol': 0.01, 'reg_param': 0.0001, 'features': 24}
#         Has trained 84 of 2016 combinations so far
# Trained and Tested combination 85 of 2016, taking 0.03 seconds to get val score of 0.1961:
#                 {'tol': 0.01, 'reg_param': 0.001, 'features': 23},
#             Current best combo with val score 0.4132:
#                     {'tol': 0.01, 'reg_param': 0.0001, 'features': 24}
# Trained and Tested combination 86 of 2016, taking 0.03 seconds to get val score of 0.2149:
#                 {'tol': 0.01, 'reg_param': 0.001, 'features': 25},
#             Current best combo with val score 0.4132:
#                     {'tol': 0.01, 'reg_param': 0.0001, 'features': 24}
# Already Trained and Tested combination (val score of 0.0977):
#             {'tol': 0.001, 'reg_param': 0.01, 'features': 23}
#             Current best combo (with val score 0.4132):
#                     {'tol': 0.01, 'reg_param': 0.0001, 'features': 24}
#         Has trained 86 of 2016 combinations so far
# Already Trained and Tested combination (val score of 0.0977):
#             {'tol': 0.1, 'reg_param': 0.01, 'features': 23}
#             Current best combo (with val score 0.4132):
#                     {'tol': 0.01, 'reg_param': 0.0001, 'features': 24}
#         Has trained 86 of 2016 combinations so far
# Already Trained and Tested combination (val score of 0.1961):
#             {'tol': 0.01, 'reg_param': 0.001, 'features': 23}
#             Current best combo (with val score 0.4132):
#                     {'tol': 0.01, 'reg_param': 0.0001, 'features': 24}
#         Has trained 86 of 2016 combinations so far
# Trained and Tested combination 87 of 2016, taking 0.03 seconds to get val score of 0.0:
#                 {'tol': 0.01, 'reg_param': 0.1, 'features': 23},
#             Current best combo with val score 0.4132:
#                     {'tol': 0.01, 'reg_param': 0.0001, 'features': 24}
# Trained and Tested combination 88 of 2016, taking 0.03 seconds to get val score of 0.1024:
#                 {'tol': 0.01, 'reg_param': 0.01, 'features': 22},
#             Current best combo with val score 0.4132:
#                     {'tol': 0.01, 'reg_param': 0.0001, 'features': 24}
# Already Trained and Tested combination (val score of 0.0977):
#             {'tol': 0.01, 'reg_param': 0.01, 'features': 24}
#             Current best combo (with val score 0.4132):
#                     {'tol': 0.01, 'reg_param': 0.0001, 'features': 24}
#         Has trained 88 of 2016 combinations so far
# Already Trained and Tested combination (val score of 0.0997):
#             {'tol': 0.001, 'reg_param': 0.01, 'features': 25}
#             Current best combo (with val score 0.4132):
#                     {'tol': 0.01, 'reg_param': 0.0001, 'features': 24}
#         Has trained 88 of 2016 combinations so far
# Already Trained and Tested combination (val score of 0.0997):
#             {'tol': 0.1, 'reg_param': 0.01, 'features': 25}
#             Current best combo (with val score 0.4132):
#                     {'tol': 0.01, 'reg_param': 0.0001, 'features': 24}
#         Has trained 88 of 2016 combinations so far
# Already Trained and Tested combination (val score of 0.2149):
#             {'tol': 0.01, 'reg_param': 0.001, 'features': 25}
#             Current best combo (with val score 0.4132):
#                     {'tol': 0.01, 'reg_param': 0.0001, 'features': 24}
#         Has trained 88 of 2016 combinations so far
# Trained and Tested combination 89 of 2016, taking 0.03 seconds to get val score of 0.0:
#                 {'tol': 0.01, 'reg_param': 0.1, 'features': 25},
#             Current best combo with val score 0.4132:
#                     {'tol': 0.01, 'reg_param': 0.0001, 'features': 24}
# Already Trained and Tested combination (val score of 0.0977):
#             {'tol': 0.01, 'reg_param': 0.01, 'features': 24}
#             Current best combo (with val score 0.4132):
#                     {'tol': 0.01, 'reg_param': 0.0001, 'features': 24}
#         Has trained 89 of 2016 combinations so far
# Trained and Tested combination 90 of 2016, taking 0.03 seconds to get val score of 0.3083:
#                 {'tol': 0.01, 'reg_param': 0.01, 'features': 26},
#             Current best combo with val score 0.4132:
#                     {'tol': 0.01, 'reg_param': 0.0001, 'features': 24}
# Trained and Tested combination 91 of 2016, taking 0.03 seconds to get val score of 0.4132:
#                 {'tol': 0.001, 'reg_param': 0.0001, 'features': 24},
#             Current best combo with val score 0.4132:
#                     {'tol': 0.01, 'reg_param': 0.0001, 'features': 24}
# Trained and Tested combination 92 of 2016, taking 0.03 seconds to get val score of 0.4132:
#                 {'tol': 0.1, 'reg_param': 0.0001, 'features': 24},
#             Current best combo with val score 0.4132:
#                     {'tol': 0.01, 'reg_param': 0.0001, 'features': 24}
# Trained and Tested combination 93 of 2016, taking 0.04 seconds to get val score of 0.3434:
#                 {'tol': 0.01, 'reg_param': 1e-05, 'features': 24},
#             Current best combo with val score 0.4132:
#                     {'tol': 0.01, 'reg_param': 0.0001, 'features': 24}
# Already Trained and Tested combination (val score of 0.1874):
#             {'tol': 0.01, 'reg_param': 0.001, 'features': 24}
#             Current best combo (with val score 0.4132):
#                     {'tol': 0.01, 'reg_param': 0.0001, 'features': 24}
#         Has trained 93 of 2016 combinations so far
# Trained and Tested combination 94 of 2016, taking 0.04 seconds to get val score of 0.4149:
#                 {'tol': 0.01, 'reg_param': 0.0001, 'features': 23},
#             Current best combo with val score 0.4149:
#                     {'tol': 0.01, 'reg_param': 0.0001, 'features': 23}
# Trained and Tested combination 95 of 2016, taking 0.06 seconds to get val score of 0.4196:
#                 {'tol': 0.01, 'reg_param': 0.0001, 'features': 25},
#             Current best combo with val score 0.4196:
#                     {'tol': 0.01, 'reg_param': 0.0001, 'features': 25}
# Trained and Tested combination 96 of 2016, taking 0.03 seconds to get val score of 0.4196:
#                 {'tol': 0.001, 'reg_param': 0.0001, 'features': 25},
#             Current best combo with val score 0.4196:
#                     {'tol': 0.01, 'reg_param': 0.0001, 'features': 25}
# Trained and Tested combination 97 of 2016, taking 0.03 seconds to get val score of 0.4196:
#                 {'tol': 0.1, 'reg_param': 0.0001, 'features': 25},
#             Current best combo with val score 0.4196:
#                     {'tol': 0.01, 'reg_param': 0.0001, 'features': 25}
# Already Trained and Tested combination (val score of 0.3389):
#             {'tol': 0.01, 'reg_param': 1e-05, 'features': 25}
#             Current best combo (with val score 0.4196):
#                     {'tol': 0.01, 'reg_param': 0.0001, 'features': 25}
#         Has trained 97 of 2016 combinations so far
# Already Trained and Tested combination (val score of 0.2149):
#             {'tol': 0.01, 'reg_param': 0.001, 'features': 25}
#             Current best combo (with val score 0.4196):
#                     {'tol': 0.01, 'reg_param': 0.0001, 'features': 25}
#         Has trained 97 of 2016 combinations so far
# Already Trained and Tested combination (val score of 0.4132):
#             {'tol': 0.01, 'reg_param': 0.0001, 'features': 24}
#             Current best combo (with val score 0.4196):
#                     {'tol': 0.01, 'reg_param': 0.0001, 'features': 25}
#         Has trained 97 of 2016 combinations so far
# Trained and Tested combination 98 of 2016, taking 0.03 seconds to get val score of 0.376:
#                 {'tol': 0.01, 'reg_param': 0.0001, 'features': 26},
#             Current best combo with val score 0.4196:
#                     {'tol': 0.01, 'reg_param': 0.0001, 'features': 25}
# % Combos Checked Thus Far: 98 out of 2016 which is 4.861111%
# STAGE TWO: Begin Cruise system
#
#
# Cruising Coordrdinate 1 of 66
#
# Cruise suspended due to suspicious case
# Guidance: round 1
#
# 	round 1 iteration:  0
#
# Trained and Tested combination 99 of 2016, taking 0.0 seconds to get val score of 0.3108:
#                 {'tol': 0.0001, 'reg_param': 1, 'features': 0},
#             Current best combo with val score 0.4196:
#                     {'tol': 0.01, 'reg_param': 0.0001, 'features': 25}
# Trained and Tested combination 100 of 2016, taking 0.0 seconds to get val score of 0.3108:
#                 {'tol': 1e-05, 'reg_param': 0.1, 'features': 0},
#             Current best combo with val score 0.4196:
#                     {'tol': 0.01, 'reg_param': 0.0001, 'features': 25}
# Trained and Tested combination 101 of 2016, taking 0.0 seconds to get val score of 0.01:
#                 {'tol': 1e-05, 'reg_param': 1, 'features': 1},
#             Current best combo with val score 0.4196:
#                     {'tol': 0.01, 'reg_param': 0.0001, 'features': 25}
# 	round 1 iteration:  1
#
# Already Trained and Tested combination (val score of 0.3108):
#             {'tol': 1e-05, 'reg_param': 1, 'features': 0}
#             Current best combo (with val score 0.4196):
#                     {'tol': 0.01, 'reg_param': 0.0001, 'features': 25}
#         Has trained 101 of 2016 combinations so far
# Trained and Tested combination 102 of 2016, taking 0.0 seconds to get val score of 0.3108:
#                 {'tol': 0.001, 'reg_param': 1, 'features': 0},
#             Current best combo with val score 0.4196:
#                     {'tol': 0.01, 'reg_param': 0.0001, 'features': 25}
# Trained and Tested combination 103 of 2016, taking 0.0 seconds to get val score of 0.3108:
#                 {'tol': 0.0001, 'reg_param': 0.1, 'features': 0},
#             Current best combo with val score 0.4196:
#                     {'tol': 0.01, 'reg_param': 0.0001, 'features': 25}
# Trained and Tested combination 104 of 2016, taking 0.0 seconds to get val score of 0.01:
#                 {'tol': 0.0001, 'reg_param': 1, 'features': 1},
#             Current best combo with val score 0.4196:
#                     {'tol': 0.01, 'reg_param': 0.0001, 'features': 25}
# Already Trained and Tested combination (val score of 0.3108):
#             {'tol': 0.0001, 'reg_param': 0.1, 'features': 0}
#             Current best combo (with val score 0.4196):
#                     {'tol': 0.01, 'reg_param': 0.0001, 'features': 25}
#         Has trained 104 of 2016 combinations so far
# Trained and Tested combination 105 of 2016, taking 0.0 seconds to get val score of 0.3108:
#                 {'tol': 1e-05, 'reg_param': 0.01, 'features': 0},
#             Current best combo with val score 0.4196:
#                     {'tol': 0.01, 'reg_param': 0.0001, 'features': 25}
# Already Trained and Tested combination (val score of 0.3108):
#             {'tol': 1e-05, 'reg_param': 1, 'features': 0}
#             Current best combo (with val score 0.4196):
#                     {'tol': 0.01, 'reg_param': 0.0001, 'features': 25}
#         Has trained 105 of 2016 combinations so far
# Trained and Tested combination 106 of 2016, taking 0.0 seconds to get val score of 0.0291:
#                 {'tol': 1e-05, 'reg_param': 0.1, 'features': 1},
#             Current best combo with val score 0.4196:
#                     {'tol': 0.01, 'reg_param': 0.0001, 'features': 25}
# % Combos Checked Thus Far: 106 out of 2016 which is 5.257937%
# Cruising Coordrdinate 2 of 66
#
# Cruise suspended due to suspicious case
# Guidance: round 2
#
# 	round 2 iteration:  0
#
# Trained and Tested combination 107 of 2016, taking 0.0 seconds to get val score of 0.3108:
#                 {'tol': 1, 'reg_param': 1, 'features': 0},
#             Current best combo with val score 0.4196:
#                     {'tol': 0.01, 'reg_param': 0.0001, 'features': 25}
# Trained and Tested combination 108 of 2016, taking 0.0 seconds to get val score of 0.3108:
#                 {'tol': 10, 'reg_param': 0.1, 'features': 0},
#             Current best combo with val score 0.4196:
#                     {'tol': 0.01, 'reg_param': 0.0001, 'features': 25}
# Trained and Tested combination 109 of 2016, taking 0.0 seconds to get val score of 0.01:
#                 {'tol': 10, 'reg_param': 1, 'features': 1},
#             Current best combo with val score 0.4196:
#                     {'tol': 0.01, 'reg_param': 0.0001, 'features': 25}
# 	round 2 iteration:  1
#
# Trained and Tested combination 110 of 2016, taking 0.0 seconds to get val score of 0.3108:
#                 {'tol': 0.1, 'reg_param': 1, 'features': 0},
#             Current best combo with val score 0.4196:
#                     {'tol': 0.01, 'reg_param': 0.0001, 'features': 25}
# Already Trained and Tested combination (val score of 0.3108):
#             {'tol': 10, 'reg_param': 1, 'features': 0}
#             Current best combo (with val score 0.4196):
#                     {'tol': 0.01, 'reg_param': 0.0001, 'features': 25}
#         Has trained 110 of 2016 combinations so far
# Trained and Tested combination 111 of 2016, taking 0.0 seconds to get val score of 0.3108:
#                 {'tol': 1, 'reg_param': 0.1, 'features': 0},
#             Current best combo with val score 0.4196:
#                     {'tol': 0.01, 'reg_param': 0.0001, 'features': 25}
# Trained and Tested combination 112 of 2016, taking 0.0 seconds to get val score of 0.01:
#                 {'tol': 1, 'reg_param': 1, 'features': 1},
#             Current best combo with val score 0.4196:
#                     {'tol': 0.01, 'reg_param': 0.0001, 'features': 25}
# Already Trained and Tested combination (val score of 0.3108):
#             {'tol': 1, 'reg_param': 0.1, 'features': 0}
#             Current best combo (with val score 0.4196):
#                     {'tol': 0.01, 'reg_param': 0.0001, 'features': 25}
#         Has trained 112 of 2016 combinations so far
# Trained and Tested combination 113 of 2016, taking 0.0 seconds to get val score of 0.3108:
#                 {'tol': 10, 'reg_param': 0.01, 'features': 0},
#             Current best combo with val score 0.4196:
#                     {'tol': 0.01, 'reg_param': 0.0001, 'features': 25}
# Already Trained and Tested combination (val score of 0.3108):
#             {'tol': 10, 'reg_param': 1, 'features': 0}
#             Current best combo (with val score 0.4196):
#                     {'tol': 0.01, 'reg_param': 0.0001, 'features': 25}
#         Has trained 113 of 2016 combinations so far
# Trained and Tested combination 114 of 2016, taking 0.0 seconds to get val score of 0.0291:
#                 {'tol': 10, 'reg_param': 0.1, 'features': 1},
#             Current best combo with val score 0.4196:
#                     {'tol': 0.01, 'reg_param': 0.0001, 'features': 25}
# % Combos Checked Thus Far: 114 out of 2016 which is 5.654762%
# Cruising Coordrdinate 3 of 66
#
# Cruise suspended due to suspicious case
# Guidance: round 3
#
# 	round 3 iteration:  0
#
# Already Trained and Tested combination (val score of 0.3108):
#             {'tol': 0.001, 'reg_param': 1, 'features': 0}
#             Current best combo (with val score 0.4196):
#                     {'tol': 0.01, 'reg_param': 0.0001, 'features': 25}
#         Has trained 114 of 2016 combinations so far
# Already Trained and Tested combination (val score of 0.3108):
#             {'tol': 0.1, 'reg_param': 1, 'features': 0}
#             Current best combo (with val score 0.4196):
#                     {'tol': 0.01, 'reg_param': 0.0001, 'features': 25}
#         Has trained 114 of 2016 combinations so far
# Trained and Tested combination 115 of 2016, taking 0.0 seconds to get val score of 0.3108:
#                 {'tol': 0.01, 'reg_param': 0.1, 'features': 0},
#             Current best combo with val score 0.4196:
#                     {'tol': 0.01, 'reg_param': 0.0001, 'features': 25}
# Trained and Tested combination 116 of 2016, taking 0.0 seconds to get val score of 0.01:
#                 {'tol': 0.01, 'reg_param': 1, 'features': 1},
#             Current best combo with val score 0.4196:
#                     {'tol': 0.01, 'reg_param': 0.0001, 'features': 25}
# 	round 3 iteration:  1
#
# Trained and Tested combination 117 of 2016, taking 0.0 seconds to get val score of 0.3108:
#                 {'tol': 0.001, 'reg_param': 0.1, 'features': 0},
#             Current best combo with val score 0.4196:
#                     {'tol': 0.01, 'reg_param': 0.0001, 'features': 25}
# Trained and Tested combination 118 of 2016, taking 0.0 seconds to get val score of 0.3108:
#                 {'tol': 0.1, 'reg_param': 0.1, 'features': 0},
#             Current best combo with val score 0.4196:
#                     {'tol': 0.01, 'reg_param': 0.0001, 'features': 25}
# Trained and Tested combination 119 of 2016, taking 0.0 seconds to get val score of 0.3108:
#                 {'tol': 0.01, 'reg_param': 0.01, 'features': 0},
#             Current best combo with val score 0.4196:
#                     {'tol': 0.01, 'reg_param': 0.0001, 'features': 25}
# Already Trained and Tested combination (val score of 0.3108):
#             {'tol': 0.01, 'reg_param': 1, 'features': 0}
#             Current best combo (with val score 0.4196):
#                     {'tol': 0.01, 'reg_param': 0.0001, 'features': 25}
#         Has trained 119 of 2016 combinations so far
# Trained and Tested combination 120 of 2016, taking 0.0 seconds to get val score of 0.0291:
#                 {'tol': 0.01, 'reg_param': 0.1, 'features': 1},
#             Current best combo with val score 0.4196:
#                     {'tol': 0.01, 'reg_param': 0.0001, 'features': 25}
# % Combos Checked Thus Far: 120 out of 2016 which is 5.952381%
# Cruising Coordrdinate 4 of 66
#
# Cruise suspended due to suspicious case
# Guidance: round 4
#
# 	round 4 iteration:  0
#
# Trained and Tested combination 121 of 2016, taking 0.0 seconds to get val score of 0.3108:
#                 {'tol': 0.0001, 'reg_param': 1e-05, 'features': 0},
#             Current best combo with val score 0.4196:
#                     {'tol': 0.01, 'reg_param': 0.0001, 'features': 25}
# Trained and Tested combination 122 of 2016, taking 0.0 seconds to get val score of 0.3108:
#                 {'tol': 1e-05, 'reg_param': 0.0001, 'features': 0},
#             Current best combo with val score 0.4196:
#                     {'tol': 0.01, 'reg_param': 0.0001, 'features': 25}
# Trained and Tested combination 123 of 2016, taking 0.0 seconds to get val score of 0.0603:
#                 {'tol': 1e-05, 'reg_param': 1e-05, 'features': 1},
#             Current best combo with val score 0.4196:
#                     {'tol': 0.01, 'reg_param': 0.0001, 'features': 25}
# 	round 4 iteration:  1
#
# Already Trained and Tested combination (val score of 0.3108):
#             {'tol': 1e-05, 'reg_param': 1e-05, 'features': 0}
#             Current best combo (with val score 0.4196):
#                     {'tol': 0.01, 'reg_param': 0.0001, 'features': 25}
#         Has trained 123 of 2016 combinations so far
# Trained and Tested combination 124 of 2016, taking 0.0 seconds to get val score of 0.3108:
#                 {'tol': 0.001, 'reg_param': 1e-05, 'features': 0},
#             Current best combo with val score 0.4196:
#                     {'tol': 0.01, 'reg_param': 0.0001, 'features': 25}
# Trained and Tested combination 125 of 2016, taking 0.0 seconds to get val score of 0.3108:
#                 {'tol': 0.0001, 'reg_param': 0.0001, 'features': 0},
#             Current best combo with val score 0.4196:
#                     {'tol': 0.01, 'reg_param': 0.0001, 'features': 25}
# Trained and Tested combination 126 of 2016, taking 0.0 seconds to get val score of 0.0603:
#                 {'tol': 0.0001, 'reg_param': 1e-05, 'features': 1},
#             Current best combo with val score 0.4196:
#                     {'tol': 0.01, 'reg_param': 0.0001, 'features': 25}
# Already Trained and Tested combination (val score of 0.3108):
#             {'tol': 0.0001, 'reg_param': 0.0001, 'features': 0}
#             Current best combo (with val score 0.4196):
#                     {'tol': 0.01, 'reg_param': 0.0001, 'features': 25}
#         Has trained 126 of 2016 combinations so far
# Already Trained and Tested combination (val score of 0.3108):
#             {'tol': 1e-05, 'reg_param': 1e-05, 'features': 0}
#             Current best combo (with val score 0.4196):
#                     {'tol': 0.01, 'reg_param': 0.0001, 'features': 25}
#         Has trained 126 of 2016 combinations so far
# Trained and Tested combination 127 of 2016, taking 0.0 seconds to get val score of 0.3108:
#                 {'tol': 1e-05, 'reg_param': 0.001, 'features': 0},
#             Current best combo with val score 0.4196:
#                     {'tol': 0.01, 'reg_param': 0.0001, 'features': 25}
# Trained and Tested combination 128 of 2016, taking 0.0 seconds to get val score of 0.0603:
#                 {'tol': 1e-05, 'reg_param': 0.0001, 'features': 1},
#             Current best combo with val score 0.4196:
#                     {'tol': 0.01, 'reg_param': 0.0001, 'features': 25}
# % Combos Checked Thus Far: 128 out of 2016 which is 6.349206000000001%
# Cruising Coordrdinate 5 of 66
#
# Cruise suspended due to suspicious case
# Guidance: round 5
#
# 	round 5 iteration:  0
#
# Trained and Tested combination 129 of 2016, taking 0.0 seconds to get val score of 0.3108:
#                 {'tol': 1, 'reg_param': 1e-05, 'features': 0},
#             Current best combo with val score 0.4196:
#                     {'tol': 0.01, 'reg_param': 0.0001, 'features': 25}
# Trained and Tested combination 130 of 2016, taking 0.0 seconds to get val score of 0.3108:
#                 {'tol': 10, 'reg_param': 0.0001, 'features': 0},
#             Current best combo with val score 0.4196:
#                     {'tol': 0.01, 'reg_param': 0.0001, 'features': 25}
# Trained and Tested combination 131 of 2016, taking 0.0 seconds to get val score of 0.0603:
#                 {'tol': 10, 'reg_param': 1e-05, 'features': 1},
#             Current best combo with val score 0.4196:
#                     {'tol': 0.01, 'reg_param': 0.0001, 'features': 25}
# 	round 5 iteration:  1
#
# Trained and Tested combination 132 of 2016, taking 0.0 seconds to get val score of 0.3108:
#                 {'tol': 0.1, 'reg_param': 1e-05, 'features': 0},
#             Current best combo with val score 0.4196:
#                     {'tol': 0.01, 'reg_param': 0.0001, 'features': 25}
# Already Trained and Tested combination (val score of 0.3108):
#             {'tol': 10, 'reg_param': 1e-05, 'features': 0}
#             Current best combo (with val score 0.4196):
#                     {'tol': 0.01, 'reg_param': 0.0001, 'features': 25}
#         Has trained 132 of 2016 combinations so far
# Trained and Tested combination 133 of 2016, taking 0.0 seconds to get val score of 0.3108:
#                 {'tol': 1, 'reg_param': 0.0001, 'features': 0},
#             Current best combo with val score 0.4196:
#                     {'tol': 0.01, 'reg_param': 0.0001, 'features': 25}
# Trained and Tested combination 134 of 2016, taking 0.0 seconds to get val score of 0.0603:
#                 {'tol': 1, 'reg_param': 1e-05, 'features': 1},
#             Current best combo with val score 0.4196:
# ...
#             {'tol': 0.01, 'reg_param': 1e-05, 'features': 25}
#             Current best combo (with val score 0.431):
#                     {'tol': 1e-05, 'reg_param': 0.0001, 'features': 21}
#         Has trained 394 of 2016 combinations so far
# % Combos Checked Thus Far: 394 out of 2016 which is 19.543651%
# Cruising Coordrdinate 65 of 66
#
# Cruise suspended due to suspicious case
# Guidance: round 29
#
# 	round 29 iteration:  0
#
# Already Trained and Tested combination (val score of 0.3389):
#             {'tol': 0.0001, 'reg_param': 1e-05, 'features': 25}
#             Current best combo (with val score 0.431):
#                     {'tol': 1e-05, 'reg_param': 0.0001, 'features': 21}
#         Has trained 394 of 2016 combinations so far
# Trained and Tested combination 395 of 2016, taking 0.02 seconds to get val score of 0.4196:
#                 {'tol': 1e-05, 'reg_param': 0.0001, 'features': 25},
#             Current best combo with val score 0.431:
#                     {'tol': 1e-05, 'reg_param': 0.0001, 'features': 21}
# Trained and Tested combination 396 of 2016, taking 0.02 seconds to get val score of 0.3434:
#                 {'tol': 1e-05, 'reg_param': 1e-05, 'features': 24},
#             Current best combo with val score 0.431:
#                     {'tol': 1e-05, 'reg_param': 0.0001, 'features': 21}
# Trained and Tested combination 397 of 2016, taking 0.02 seconds to get val score of 0.3275:
#                 {'tol': 1e-05, 'reg_param': 1e-05, 'features': 26},
#             Current best combo with val score 0.431:
#                     {'tol': 1e-05, 'reg_param': 0.0001, 'features': 21}
# 	round 29 iteration:  1
#
# Trained and Tested combination 398 of 2016, taking 0.02 seconds to get val score of 0.4196:
#                 {'tol': 0.0001, 'reg_param': 0.0001, 'features': 25},
#             Current best combo with val score 0.431:
#                     {'tol': 1e-05, 'reg_param': 0.0001, 'features': 21}
# Already Trained and Tested combination (val score of 0.3389):
#             {'tol': 1e-05, 'reg_param': 1e-05, 'features': 25}
#             Current best combo (with val score 0.431):
#                     {'tol': 1e-05, 'reg_param': 0.0001, 'features': 21}
#         Has trained 398 of 2016 combinations so far
# Trained and Tested combination 399 of 2016, taking 0.02 seconds to get val score of 0.2149:
#                 {'tol': 1e-05, 'reg_param': 0.001, 'features': 25},
#             Current best combo with val score 0.431:
#                     {'tol': 1e-05, 'reg_param': 0.0001, 'features': 21}
# Trained and Tested combination 400 of 2016, taking 0.02 seconds to get val score of 0.4132:
#                 {'tol': 1e-05, 'reg_param': 0.0001, 'features': 24},
#             Current best combo with val score 0.431:
#                     {'tol': 1e-05, 'reg_param': 0.0001, 'features': 21}
# Trained and Tested combination 401 of 2016, taking 0.03 seconds to get val score of 0.376:
#                 {'tol': 1e-05, 'reg_param': 0.0001, 'features': 26},
#             Current best combo with val score 0.431:
#                     {'tol': 1e-05, 'reg_param': 0.0001, 'features': 21}
# Trained and Tested combination 402 of 2016, taking 0.02 seconds to get val score of 0.3434:
#                 {'tol': 0.0001, 'reg_param': 1e-05, 'features': 24},
#             Current best combo with val score 0.431:
#                     {'tol': 1e-05, 'reg_param': 0.0001, 'features': 21}
# Already Trained and Tested combination (val score of 0.4132):
#             {'tol': 1e-05, 'reg_param': 0.0001, 'features': 24}
#             Current best combo (with val score 0.431):
#                     {'tol': 1e-05, 'reg_param': 0.0001, 'features': 21}
#         Has trained 402 of 2016 combinations so far
# Trained and Tested combination 403 of 2016, taking 0.04 seconds to get val score of 0.3418:
#                 {'tol': 1e-05, 'reg_param': 1e-05, 'features': 23},
#             Current best combo with val score 0.431:
#                     {'tol': 1e-05, 'reg_param': 0.0001, 'features': 21}
# Already Trained and Tested combination (val score of 0.3389):
#             {'tol': 1e-05, 'reg_param': 1e-05, 'features': 25}
#             Current best combo (with val score 0.431):
#                     {'tol': 1e-05, 'reg_param': 0.0001, 'features': 21}
#         Has trained 403 of 2016 combinations so far
# % Combos Checked Thus Far: 403 out of 2016 which is 19.990078999999998%
# Cruising Coordrdinate 66 of 66
#
# Cruise suspended due to suspicious case
# Guidance: round 30
#
# 	round 30 iteration:  0
#
# Already Trained and Tested combination (val score of 0.3335):
#             {'tol': 0.001, 'reg_param': 1e-05, 'features': 20}
#             Current best combo (with val score 0.431):
#                     {'tol': 1e-05, 'reg_param': 0.0001, 'features': 21}
#         Has trained 403 of 2016 combinations so far
# Already Trained and Tested combination (val score of 0.3335):
#             {'tol': 0.1, 'reg_param': 1e-05, 'features': 20}
#             Current best combo (with val score 0.431):
#                     {'tol': 1e-05, 'reg_param': 0.0001, 'features': 21}
#         Has trained 403 of 2016 combinations so far
# Trained and Tested combination 404 of 2016, taking 0.03 seconds to get val score of 0.4193:
#                 {'tol': 0.01, 'reg_param': 0.0001, 'features': 20},
#             Current best combo with val score 0.431:
#                     {'tol': 1e-05, 'reg_param': 0.0001, 'features': 21}
# Trained and Tested combination 405 of 2016, taking 0.07 seconds to get val score of 0.3289:
#                 {'tol': 0.01, 'reg_param': 1e-05, 'features': 19},
#             Current best combo with val score 0.431:
#                     {'tol': 1e-05, 'reg_param': 0.0001, 'features': 21}
# Trained and Tested combination 406 of 2016, taking 0.02 seconds to get val score of 0.3405:
#                 {'tol': 0.01, 'reg_param': 1e-05, 'features': 21},
#             Current best combo with val score 0.431:
#                     {'tol': 1e-05, 'reg_param': 0.0001, 'features': 21}
# 	round 30 iteration:  1
#
# Trained and Tested combination 407 of 2016, taking 0.02 seconds to get val score of 0.4193:
#                 {'tol': 0.001, 'reg_param': 0.0001, 'features': 20},
#             Current best combo with val score 0.431:
#                     {'tol': 1e-05, 'reg_param': 0.0001, 'features': 21}
# Trained and Tested combination 408 of 2016, taking 0.02 seconds to get val score of 0.4193:
#                 {'tol': 0.1, 'reg_param': 0.0001, 'features': 20},
#             Current best combo with val score 0.431:
#                     {'tol': 1e-05, 'reg_param': 0.0001, 'features': 21}
# Already Trained and Tested combination (val score of 0.3335):
#             {'tol': 0.01, 'reg_param': 1e-05, 'features': 20}
#             Current best combo (with val score 0.431):
#                     {'tol': 1e-05, 'reg_param': 0.0001, 'features': 21}
#         Has trained 408 of 2016 combinations so far
# Trained and Tested combination 409 of 2016, taking 0.02 seconds to get val score of 0.278:
#                 {'tol': 0.01, 'reg_param': 0.001, 'features': 20},
#             Current best combo with val score 0.431:
#                     {'tol': 1e-05, 'reg_param': 0.0001, 'features': 21}
# Trained and Tested combination 410 of 2016, taking 0.02 seconds to get val score of 0.3916:
#                 {'tol': 0.01, 'reg_param': 0.0001, 'features': 19},
#             Current best combo with val score 0.431:
#                     {'tol': 1e-05, 'reg_param': 0.0001, 'features': 21}
# Trained and Tested combination 411 of 2016, taking 0.03 seconds to get val score of 0.431:
#                 {'tol': 0.01, 'reg_param': 0.0001, 'features': 21},
#             Current best combo with val score 0.431:
#                     {'tol': 1e-05, 'reg_param': 0.0001, 'features': 21}
# Trained and Tested combination 412 of 2016, taking 0.02 seconds to get val score of 0.3289:
#                 {'tol': 0.001, 'reg_param': 1e-05, 'features': 19},
#             Current best combo with val score 0.431:
#                     {'tol': 1e-05, 'reg_param': 0.0001, 'features': 21}
# Trained and Tested combination 413 of 2016, taking 0.02 seconds to get val score of 0.3289:
#                 {'tol': 0.1, 'reg_param': 1e-05, 'features': 19},
#             Current best combo with val score 0.431:
#                     {'tol': 1e-05, 'reg_param': 0.0001, 'features': 21}
# Already Trained and Tested combination (val score of 0.3916):
#             {'tol': 0.01, 'reg_param': 0.0001, 'features': 19}
#             Current best combo (with val score 0.431):
#                     {'tol': 1e-05, 'reg_param': 0.0001, 'features': 21}
#         Has trained 413 of 2016 combinations so far
# Trained and Tested combination 414 of 2016, taking 0.03 seconds to get val score of 0.3332:
#                 {'tol': 0.01, 'reg_param': 1e-05, 'features': 18},
#             Current best combo with val score 0.431:
#                     {'tol': 1e-05, 'reg_param': 0.0001, 'features': 21}
# Already Trained and Tested combination (val score of 0.3335):
#             {'tol': 0.01, 'reg_param': 1e-05, 'features': 20}
#             Current best combo (with val score 0.431):
#                     {'tol': 1e-05, 'reg_param': 0.0001, 'features': 21}
#         Has trained 414 of 2016 combinations so far
# Trained and Tested combination 415 of 2016, taking 0.02 seconds to get val score of 0.3405:
#                 {'tol': 0.001, 'reg_param': 1e-05, 'features': 21},
#             Current best combo with val score 0.431:
#                     {'tol': 1e-05, 'reg_param': 0.0001, 'features': 21}
# Trained and Tested combination 416 of 2016, taking 0.02 seconds to get val score of 0.3405:
#                 {'tol': 0.1, 'reg_param': 1e-05, 'features': 21},
#             Current best combo with val score 0.431:
#                     {'tol': 1e-05, 'reg_param': 0.0001, 'features': 21}
# Already Trained and Tested combination (val score of 0.431):
#             {'tol': 0.01, 'reg_param': 0.0001, 'features': 21}
#             Current best combo (with val score 0.431):
#                     {'tol': 1e-05, 'reg_param': 0.0001, 'features': 21}
#         Has trained 416 of 2016 combinations so far
# Already Trained and Tested combination (val score of 0.3335):
#             {'tol': 0.01, 'reg_param': 1e-05, 'features': 20}
#             Current best combo (with val score 0.431):
#                     {'tol': 1e-05, 'reg_param': 0.0001, 'features': 21}
#         Has trained 416 of 2016 combinations so far
# Trained and Tested combination 417 of 2016, taking 0.02 seconds to get val score of 0.3404:
#                 {'tol': 0.01, 'reg_param': 1e-05, 'features': 22},
#             Current best combo with val score 0.431:
#                     {'tol': 1e-05, 'reg_param': 0.0001, 'features': 21}
# % Combos Checked Thus Far: 417 out of 2016 which is 20.684524%
# FINAL STAGE: Begin final Guidance system
#
#
# Guidance: round FINAL
#
# 	round FINAL iteration:  0
#
# Already Trained and Tested combination (val score of 0.431):
#             {'tol': 0.0001, 'reg_param': 0.0001, 'features': 21}
#             Current best combo (with val score 0.431):
#                     {'tol': 1e-05, 'reg_param': 0.0001, 'features': 21}
#         Has trained 417 of 2016 combinations so far
# Already Trained and Tested combination (val score of 0.3405):
#             {'tol': 1e-05, 'reg_param': 1e-05, 'features': 21}
#             Current best combo (with val score 0.431):
#                     {'tol': 1e-05, 'reg_param': 0.0001, 'features': 21}
#         Has trained 417 of 2016 combinations so far
# Already Trained and Tested combination (val score of 0.2124):
#             {'tol': 1e-05, 'reg_param': 0.001, 'features': 21}
#             Current best combo (with val score 0.431):
#                     {'tol': 1e-05, 'reg_param': 0.0001, 'features': 21}
#         Has trained 417 of 2016 combinations so far
# Already Trained and Tested combination (val score of 0.4193):
#             {'tol': 1e-05, 'reg_param': 0.0001, 'features': 20}
#             Current best combo (with val score 0.431):
#                     {'tol': 1e-05, 'reg_param': 0.0001, 'features': 21}
#         Has trained 417 of 2016 combinations so far
# Already Trained and Tested combination (val score of 0.4229):
#             {'tol': 1e-05, 'reg_param': 0.0001, 'features': 22}
#             Current best combo (with val score 0.431):
#                     {'tol': 1e-05, 'reg_param': 0.0001, 'features': 21}
#         Has trained 417 of 2016 combinations so far
# 	round FINAL iteration:  1
#
# Already Trained and Tested combination (val score of 0.431):
#             {'tol': 1e-05, 'reg_param': 0.0001, 'features': 21}
#             Current best combo (with val score 0.431):
#                     {'tol': 1e-05, 'reg_param': 0.0001, 'features': 21}
#         Has trained 417 of 2016 combinations so far
# Trained and Tested combination 418 of 2016, taking 0.04 seconds to get val score of 0.431:
#                 {'tol': 0.001, 'reg_param': 0.0001, 'features': 21},
#             Current best combo with val score 0.431:
#                     {'tol': 1e-05, 'reg_param': 0.0001, 'features': 21}
# Already Trained and Tested combination (val score of 0.3405):
#             {'tol': 0.0001, 'reg_param': 1e-05, 'features': 21}
#             Current best combo (with val score 0.431):
#                     {'tol': 1e-05, 'reg_param': 0.0001, 'features': 21}
#         Has trained 418 of 2016 combinations so far
# Trained and Tested combination 419 of 2016, taking 0.05 seconds to get val score of 0.2124:
#                 {'tol': 0.0001, 'reg_param': 0.001, 'features': 21},
#             Current best combo with val score 0.431:
#                     {'tol': 1e-05, 'reg_param': 0.0001, 'features': 21}
# Already Trained and Tested combination (val score of 0.4193):
#             {'tol': 0.0001, 'reg_param': 0.0001, 'features': 20}
#             Current best combo (with val score 0.431):
#                     {'tol': 1e-05, 'reg_param': 0.0001, 'features': 21}
#         Has trained 419 of 2016 combinations so far
# Trained and Tested combination 420 of 2016, taking 0.02 seconds to get val score of 0.4229:
#                 {'tol': 0.0001, 'reg_param': 0.0001, 'features': 22},
#             Current best combo with val score 0.431:
#                     {'tol': 1e-05, 'reg_param': 0.0001, 'features': 21}
# % Combos Checked Thus Far: 420 out of 2016 which is 20.833333%
# Max Val Score:
#  0.431006
# Max Val Score Std:
#  0.046718
# Best Combo Train Score:
#  0.741171
# Best Combo Train Score Std:
#  0.016005
# Max Combo Index:
#  (0, 1, 21) out of [7, 6, 48] (note best combo is 0-indexed)
# Max Combo Hyperparamer Combination:
#  {'tol': 1e-05, 'reg_param': 0.0001, 'features': 21}
# Max Combo Features:
#  ('procedure_224274', 'lods_score', 'procedure_224276', 'procedure_224267', 'race_AMERICAN INDIAN/ALASKA NATIVE', 'race_ASIAN', 'race_ASIAN - ASIAN INDIAN', 'race_ASIAN - CHINESE', 'race_ASIAN - KOREAN', 'race_ASIAN - SOUTH EAST ASIAN', 'race_BLACK/AFRICAN', 'race_BLACK/AFRICAN AMERICAN', 'race_BLACK/CAPE VERDEAN', 'race_BLACK/CARIBBEAN ISLAND', 'race_HISPANIC OR LATINO', 'race_HISPANIC/LATINO - CENTRAL AMERICAN', 'race_HISPANIC/LATINO - COLUMBIAN', 'race_HISPANIC/LATINO - CUBAN', 'race_HISPANIC/LATINO - DOMINICAN', 'race_HISPANIC/LATINO - GUATEMALAN', 'race_HISPANIC/LATINO - HONDURAN', 'race_HISPANIC/LATINO - MEXICAN', 'race_HISPANIC/LATINO - PUERTO RICAN', 'race_HISPANIC/LATINO - SALVADORAN', 'race_MULTIPLE RACE/ETHNICITY', 'race_NATIVE HAWAIIAN OR OTHER PACIFIC ISLANDER', 'race_OTHER', 'race_PATIENT DECLINED TO ANSWER', 'race_PORTUGUESE', 'race_SOUTH AMERICAN', 'race_UNABLE TO OBTAIN', 'race_WHITE', 'race_WHITE - BRAZILIAN', 'race_WHITE - EASTERN EUROPEAN', 'race_WHITE - OTHER EUROPEAN', 'race_WHITE - RUSSIAN', 'race_UNKNOWN', 'procedure_227712', 'procedure_225430', 'gender_F', 'gender_M', 'oasis_score', 'procedure_225446', 'procedure_224275', 'procedure_225802', 'hospital_stay_duration', 'procedure_226475', 'ventilation_used', 'procedure_224270', 'procedure_227194', 'icu_stay_duration', 'procedure_225400', 'procedure_221223', 'procedure_225792', 'unique_drugs')
# % Combos Checked: 420 out of 2016 which is 20.833333%
